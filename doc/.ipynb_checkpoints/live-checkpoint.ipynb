# %% [markdown]
# # <center>Pymarketcap live demo</center>

# %% [markdown]
# ## Basic usage
# The first response takes a long time because some data is cached at instantiation of the wrapper.

# %%
from pymarketcap import Pymarketcap
cmc = Pymarketcap()

cmc.exchanges()
# Out:
# [{'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Cardano',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Qtum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Status',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'NEO',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Stellar',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Steem',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Upbit'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'NEO',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'ICON',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'NEO',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bluzelle',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'TRON',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'VeChain',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Binance Coin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Binance'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ethereum Classic',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum Classic',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'OKEx'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'BitMEX'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'EOS',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Qtum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Monero',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bithumb'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ripple',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'EOS',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Tether',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bitfinex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Huobi Token',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Huobi Token',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Huobi Token',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'EOS',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'TRON',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Elastos',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Elastos',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Huobi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Litecoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'GDAX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ripple',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ripple',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ripple',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Kraken'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ripple',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Cardano',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'NuBits',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Lisk',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'NEO',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Stellar',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bittrex'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Monero',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Dash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ripple',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Zcash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'EOS',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'HitBTC'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ripple',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ripple',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ethereum',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bitstamp'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Qtum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'IOTA',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'}],
#   'name': 'Coinone'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'}],
#   'name': 'bitFlyer'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ripple',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ripple',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Stellar',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Monero',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum Classic',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Poloniex'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Litecoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'EDUCare',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'TRON',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Hshare',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Lisk',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Zcash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Factom',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bit-Z'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'QASH',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ethereum',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Quoine'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'NEM',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'MonaCoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'NEM',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'COMSA [ETH]',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Counterparty',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'COMSA [XEM]',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Pepe Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Zaif'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'MonaCoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'MonaCoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'}],
#   'name': 'Fisco'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'}],
#   'name': 'Gemini'},
#  {'markets': [{'name': 'ATMCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'ATMCoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ripple',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Dogecoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'ATMCoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'ATMCoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bits Blockchain'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'BTCBOX'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'NEO',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'TRON',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Lisk',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ruff',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Qtum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Qbao',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ripple',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Achain',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'CoinEgg'},
#  {'markets': [{'name': 'Stellar',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Status',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Civic',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': '0x',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Enigma',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Zcash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'GOPAX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'EOS',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'BitShares',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Qtum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Hshare',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ripple',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ink',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Qtum',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'ZB.COM'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'}],
#   'name': 'Korbit'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'MonaCoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'MonaCoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'}],
#   'name': 'Bitbank'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ink',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Lightning Bitcoin [Futures]',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Hyper Pay',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'EXX'},
#  {'markets': [{'name': 'TRON',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Hshare',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Qtum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Energo',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Profile Utility Token',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Storm',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin Diamond',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'ENTCash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Coinnest'},
#  {'markets': [{'name': 'Jibrel Network',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Jibrel Network',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bibox Token',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bibox Token',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bibox Token',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
# ...
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'DigiByte',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'alcurEX'},
#  {'markets': [{'name': 'E-Dinar Coin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'}],
#   'name': 'LocalTrade'},
#  {'markets': [{'name': 'Litecoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Electroneum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Monero',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Verge',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Aeon',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'BitCoal',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Sumokoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'TradeOgre'},
#  {'markets': [{'name': 'NVO',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Pepe Cash',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Counterparty',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Storjcoin X',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Rustbits',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Storjcoin X',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'FoldingCoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Bitcrystals',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'}],
#   'name': 'Counterparty DEX'},
#  {'markets': [{'name': 'Peercoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Dogecoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Dogecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Vertcoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Dash',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Litecoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Coingi'},
#  {'markets': [{'name': 'Centurion',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'ExcambrioRex'},
#  {'markets': [{'name': 'Gulden',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'GuldenTrader'},
#  {'markets': [{'name': 'LEOcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'LEOcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'LEOcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'LEOcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'LEOxChange'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'TCC Exchange'},
#  {'markets': [{'name': 'BriaCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Litecoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'}],
#   'name': 'Ore.Bz'},
#  {'markets': [{'name': 'SACoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'DC-Ex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'}],
#   'name': 'CoinCorner'},
#  {'markets': [{'name': 'CRTCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Dogecoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'}],
#   'name': 'NIX-E'},
#  {'markets': [{'name': 'HEAT',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bismuth',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Golem',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'FIMKrypto',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Elastic',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Elastic',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'HEAT',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'Heat Wallet'},
#  {'markets': [{'name': 'SnakeEyes',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'CCMiner',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'}],
#   'name': 'Burst Asset Exchange'},
#  {'markets': [{'name': 'MaidSafeCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'Omni DEX'},
#  {'markets': [{'name': 'Golem',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Lunyr',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'SingularDTV',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'TokenCard',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Swarm City',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Etheroll',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.226227,
#     'volume': 149037000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Melon',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.09,
#     'price': 908.495,
#     'volume': 121868000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Numeraire',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 118.999,
#     'volume': 112050000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Edgeless',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.405553,
#     'volume': 89734000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum Movie Venture',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29004,
#     'volume': 59825000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'CryptoDerivatives'},
#  {'markets': [{'name': 'Virtacoinplus',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Virtacoinplus',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'}],
#   'name': 'VirtacoinWorld'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.67,
#     'price': 0.938014,
#     'volume': 350968000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.386241,
#     'volume': 333760000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.57,
#     'price': 30.1084,
#     'volume': 276653000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Siacoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.17,
#     'price': 8937.81,
#     'volume': 267135000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.56,
#     'price': 1358.28,
#     'volume': 156936000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'}],
#   'name': 'BITHOLIC'}]

# %% [markdown]
# All methods are self explained in docstrings:

# %%
print(cmc.exchanges.__doc__)
# Out:
# Get all the exchanges in coninmarketcap ranked by volumes
#         along with other metadata.
#
#         Args:
#             convert (str, optional): Convert volumes and prices
#                 between "USD" and "BTC". As default "USD".
#
#         Returns (list):
#             Exchanges with markets and other data included.

# %% [markdown]
# ___________________________________
#
# ## Coinmarketcap API
# #### `ticker(currency=None, limit=0, start=0, convert="USD")`
# If `currency == None`, you will obtain data for all currencies in coinmarketcap:

# %%
cmc.ticker()
# Out:
# [{'24h_volume_usd': 8318950000.0,
#   'available_supply': 16855037.0,
#   'id': 'bitcoin',
#   'last_updated': 1518199767,
#   'market_cap_usd': 146298013052,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin',
#   'percent_change_1h': 2.88,
#   'percent_change_24h': 5.73,
#   'percent_change_7d': 0.12,
#   'price_btc': 1.0,
#   'price_usd': 8679.78,
#   'rank': 1,
#   'symbol': 'BTC',
#   'total_supply': 16855037.0},
#  {'24h_volume_usd': 3171200000.0,
#   'available_supply': 97512178.0,
#   'id': 'ethereum',
#   'last_updated': 1518199754,
#   'market_cap_usd': 85126181122.0,
#   'max_supply': None,
#   'name': 'Ethereum',
#   'percent_change_1h': 2.41,
#   'percent_change_24h': 8.76,
#   'percent_change_7d': -3.3,
#   'price_btc': 0.10064,
#   'price_usd': 872.98,
#   'rank': 2,
#   'symbol': 'ETH',
#   'total_supply': 97512178.0},
#  {'24h_volume_usd': 1699310000.0,
#   'available_supply': 39009215838.0,
#   'id': 'ripple',
#   'last_updated': 1518199741,
#   'market_cap_usd': 36277790545.0,
#   'max_supply': 100000000000,
#   'name': 'Ripple',
#   'percent_change_1h': 1.57,
#   'percent_change_24h': 22.91,
#   'percent_change_7d': 10.57,
#   'price_btc': 0.00010721,
#   'price_usd': 0.92998,
#   'rank': 3,
#   'symbol': 'XRP',
#   'total_supply': 99992725510.0},
#  {'24h_volume_usd': 1389630000.0,
#   'available_supply': 16958325.0,
#   'id': 'bitcoin-cash',
#   'last_updated': 1518199753,
#   'market_cap_usd': 22386006500.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Cash',
#   'percent_change_1h': 2.31,
#   'percent_change_24h': 3.42,
#   'percent_change_7d': 13.6,
#   'price_btc': 0.15218,
#   'price_usd': 1320.06,
#   'rank': 4,
#   'symbol': 'BCH',
#   'total_supply': 16958325.0},
#  {'24h_volume_usd': 419226000.0,
#   'available_supply': 25927070538.0,
#   'id': 'cardano',
#   'last_updated': 1518199754,
#   'market_cap_usd': 10000382231.0,
#   'max_supply': 45000000000.0,
#   'name': 'Cardano',
#   'percent_change_1h': 1.92,
#   'percent_change_24h': 11.42,
#   'percent_change_7d': 8.94,
#   'price_btc': 4.447e-05,
#   'price_usd': 0.385712,
#   'rank': 5,
#   'symbol': 'ADA',
#   'total_supply': 31112483745.0},
#  {'24h_volume_usd': 743332000.0,
#   'available_supply': 55143458.0,
#   'id': 'litecoin',
#   'last_updated': 1518199741,
#   'market_cap_usd': 8763729230.0,
#   'max_supply': 84000000.0,
#   'name': 'Litecoin',
#   'percent_change_1h': 3.71,
#   'percent_change_24h': 10.21,
#   'percent_change_7d': 24.56,
#   'price_btc': 0.0183215,
#   'price_usd': 158.926,
#   'rank': 6,
#   'symbol': 'LTC',
#   'total_supply': 55143458.0},
#  {'24h_volume_usd': 431493000.0,
#   'available_supply': 65000000.0,
#   'id': 'neo',
#   'last_updated': 1518199747,
#   'market_cap_usd': 7538895000.0,
#   'max_supply': None,
#   'name': 'NEO',
#   'percent_change_1h': 1.35,
#   'percent_change_24h': 5.18,
#   'percent_change_7d': -0.79,
#   'price_btc': 0.0133709,
#   'price_usd': 115.983,
#   'rank': 7,
#   'symbol': 'NEO',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 168150000.0,
#   'available_supply': 18432189242.0,
#   'id': 'stellar',
#   'last_updated': 1518199743,
#   'market_cap_usd': 7415712105.0,
#   'max_supply': None,
#   'name': 'Stellar',
#   'percent_change_1h': 3.06,
#   'percent_change_24h': 14.3,
#   'percent_change_7d': 3.46,
#   'price_btc': 4.638e-05,
#   'price_usd': 0.402324,
#   'rank': 8,
#   'symbol': 'XLM',
#   'total_supply': 103669352049},
#  {'24h_volume_usd': 549988000.0,
#   'available_supply': 657693007.0,
#   'id': 'eos',
#   'last_updated': 1518199752,
#   'market_cap_usd': 6214488606.0,
#   'max_supply': 1000000000.0,
#   'name': 'EOS',
#   'percent_change_1h': 2.64,
#   'percent_change_24h': 15.48,
#   'percent_change_7d': -0.26,
#   'price_btc': 0.0010893,
#   'price_usd': 9.44892,
#   'rank': 9,
#   'symbol': 'EOS',
#   'total_supply': 900000000.0},
#  {'24h_volume_usd': 62659800.0,
#   'available_supply': 2779530283.0,
#   'id': 'iota',
#   'last_updated': 1518199751,
#   'market_cap_usd': 5455523063.0,
#   'max_supply': 2779530283.0,
#   'name': 'IOTA',
#   'percent_change_1h': 3.71,
#   'percent_change_24h': 10.09,
#   'percent_change_7d': 11.92,
#   'price_btc': 0.00022627,
#   'price_usd': 1.96275,
#   'rank': 10,
#   'symbol': 'MIOTA',
#   'total_supply': 2779530283.0},
#  {'24h_volume_usd': 55234700.0,
#   'available_supply': 8999999999.0,
#   'id': 'nem',
#   'last_updated': 1518199745,
#   'market_cap_usd': 5102432999.0,
#   'max_supply': None,
#   'name': 'NEM',
#   'percent_change_1h': 1.32,
#   'percent_change_24h': 4.45,
#   'percent_change_7d': 2.27,
#   'price_btc': 6.536e-05,
#   'price_usd': 0.566937,
#   'rank': 11,
#   'symbol': 'XEM',
#   'total_supply': 8999999999.0},
#  {'24h_volume_usd': 102046000.0,
#   'available_supply': 7874281.0,
#   'id': 'dash',
#   'last_updated': 1518199742,
#   'market_cap_usd': 5002570186.0,
#   'max_supply': 18900000.0,
#   'name': 'Dash',
#   'percent_change_1h': 3.61,
#   'percent_change_24h': 11.08,
#   'percent_change_7d': 13.82,
#   'price_btc': 0.0732401,
#   'price_usd': 635.305,
#   'rank': 12,
#   'symbol': 'DASH',
#   'total_supply': 7874281.0},
#  {'24h_volume_usd': 92225700.0,
#   'available_supply': 15702526.0,
#   'id': 'monero',
#   'last_updated': 1518199742,
#   'market_cap_usd': 4004097065.0,
#   'max_supply': None,
#   'name': 'Monero',
#   'percent_change_1h': 2.76,
#   'percent_change_24h': 6.02,
#   'percent_change_7d': 10.16,
#   'price_btc': 0.0293968,
#   'price_usd': 254.997,
#   'rank': 13,
#   'symbol': 'XMR',
#   'total_supply': 15702526.0},
#  {'24h_volume_usd': 89024100.0,
#   'available_supply': 117891928.0,
#   'id': 'lisk',
#   'last_updated': 1518199746,
#   'market_cap_usd': 3104483508.0,
#   'max_supply': None,
#   'name': 'Lisk',
#   'percent_change_1h': 1.34,
#   'percent_change_24h': 16.71,
#   'percent_change_7d': 31.17,
#   'price_btc': 0.00303579,
#   'price_usd': 26.3333,
#   'rank': 14,
#   'symbol': 'LSK',
#   'total_supply': 117891928.0},
#  {'24h_volume_usd': 253072000.0,
#   'available_supply': 65748192475.0,
#   'id': 'tron',
#   'last_updated': 1518199753,
#   'market_cap_usd': 2886030058.0,
#   'max_supply': None,
#   'name': 'TRON',
#   'percent_change_1h': 4.11,
#   'percent_change_24h': 21.56,
#   'percent_change_7d': 12.14,
#   'price_btc': 5.06e-06,
#   'price_usd': 0.0438952,
#   'rank': 15,
#   'symbol': 'TRX',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 113104000.0,
#   'available_supply': 16814349.0,
#   'id': 'bitcoin-gold',
#   'last_updated': 1518199756,
#   'market_cap_usd': 2686428474.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Gold',
#   'percent_change_1h': 0.65,
#   'percent_change_24h': 56.42,
#   'percent_change_7d': 50.14,
#   'price_btc': 0.0184188,
#   'price_usd': 159.77,
#   'rank': 16,
#   'symbol': 'BTG',
#   'total_supply': 16914349.0},
#  {'24h_volume_usd': 398903000.0,
#   'available_supply': 99735533.0,
#   'id': 'ethereum-classic',
#   'last_updated': 1518199747,
#   'market_cap_usd': 2612522419.0,
#   'max_supply': None,
#   'name': 'Ethereum Classic',
#   'percent_change_1h': 3.96,
#   'percent_change_24h': 28.45,
#   'percent_change_7d': 17.89,
#   'price_btc': 0.00301979,
#   'price_usd': 26.1945,
#   'rank': 17,
#   'symbol': 'ETC',
#   'total_supply': 99735533.0},
#  {'24h_volume_usd': 2587600000.0,
#   'available_supply': 2217140814.0,
#   'id': 'tether',
#   'last_updated': 1518199746,
#   'market_cap_usd': 2307356273.0,
#   'max_supply': None,
#   'name': 'Tether',
#   'percent_change_1h': 0.98,
#   'percent_change_24h': 2.59,
#   'percent_change_7d': 5.06,
#   'price_btc': 0.00011997,
#   'price_usd': 1.04069,
#   'rank': 18,
#   'symbol': 'USDT',
#   'total_supply': 2280109970.0},
#  {'24h_volume_usd': 613331000.0,
#   'available_supply': 73869524.0,
#   'id': 'qtum',
#   'last_updated': 1518199750,
#   'market_cap_usd': 2221175330.0,
#   'max_supply': None,
#   'name': 'Qtum',
#   'percent_change_1h': 0.82,
#   'percent_change_24h': 24.46,
#   'percent_change_7d': 4.01,
#   'price_btc': 0.00346644,
#   'price_usd': 30.0689,
#   'rank': 19,
#   'symbol': 'QTUM',
#   'total_supply': 100369524.0},
#  {'24h_volume_usd': 66787500.0,
#   'available_supply': 466139235.0,
#   'id': 'vechain',
#   'last_updated': 1518199756,
#   'market_cap_usd': 2112524366.0,
#   'max_supply': None,
#   'name': 'VeChain',
#   'percent_change_1h': 3.06,
#   'percent_change_24h': 6.97,
#   'percent_change_7d': -5.16,
#   'price_btc': 0.00052246,
#   'price_usd': 4.53196,
#   'rank': 20,
#   'symbol': 'VEN',
#   'total_supply': 873378637.0},
#  {'24h_volume_usd': 105028000.0,
#   'available_supply': 381495014.0,
#   'id': 'icon',
#   'last_updated': 1518199755,
#   'market_cap_usd': 1721454286.0,
#   'max_supply': None,
#   'name': 'ICON',
#   'percent_change_1h': 3.3,
#   'percent_change_24h': 5.06,
#   'percent_change_7d': -13.07,
#   'price_btc': 0.0005202,
#   'price_usd': 4.51239,
#   'rank': 21,
#   'symbol': 'ICX',
#   'total_supply': 400230000.0},
#  {'24h_volume_usd': 31977200.0,
#   'available_supply': 133248289.0,
#   'id': 'raiblocks',
#   'last_updated': 1518199749,
#   'market_cap_usd': 1590758051.0,
#   'max_supply': 133248290.0,
#   'name': 'Nano',
#   'percent_change_1h': 3.05,
#   'percent_change_24h': 7.54,
#   'percent_change_7d': -29.07,
#   'price_btc': 0.00137629,
#   'price_usd': 11.9383,
#   'rank': 22,
#   'symbol': 'XRB',
#   'total_supply': 133248289.0},
#  {'24h_volume_usd': 116798000.0,
#   'available_supply': 3242444.0,
#   'id': 'zcash',
#   'last_updated': 1518199748,
#   'market_cap_usd': 1462666376.0,
#   'max_supply': None,
#   'name': 'Zcash',
#   'percent_change_1h': 4.24,
#   'percent_change_24h': 11.34,
#   'percent_change_7d': 23.9,
#   'price_btc': 0.0520043,
#   'price_usd': 451.1,
#   'rank': 23,
#   'symbol': 'ZEC',
#   'total_supply': 3242444.0},
#  {'24h_volume_usd': 12368700.0,
#   'available_supply': 37004027.0,
#   'id': 'populous',
#   'last_updated': 1518199752,
#   'market_cap_usd': 1343568111.0,
#   'max_supply': 53252246.0,
#   'name': 'Populous',
#   'percent_change_1h': 3.34,
#   'percent_change_24h': 3.25,
#   'percent_change_7d': -33.45,
#   'price_btc': 0.00418579,
#   'price_usd': 36.3087,
#   'rank': 24,
#   'symbol': 'PPT',
#   'total_supply': 53252246.0},
#  {'24h_volume_usd': 47464900.0,
#   'available_supply': 102042552.0,
#   'id': 'omisego',
#   'last_updated': 1518199752,
#   'market_cap_usd': 1335124747.0,
#   'max_supply': None,
#   'name': 'OmiseGO',
#   'percent_change_1h': 2.55,
#   'percent_change_24h': 12.34,
#   'percent_change_7d': 2.89,
#   'price_btc': 0.00150837,
#   'price_usd': 13.084,
#   'rank': 25,
#   'symbol': 'OMG',
#   'total_supply': 140245398.0},
#  {'24h_volume_usd': 68764300.0,
#   'available_supply': 249203123.0,
#   'id': 'steem',
#   'last_updated': 1518199746,
#   'market_cap_usd': 1062734193.0,
#   'max_supply': None,
#   'name': 'Steem',
#   'percent_change_1h': 0.72,
#   'percent_change_24h': 13.63,
#   'percent_change_7d': 5.56,
#   'price_btc': 0.00049163,
#   'price_usd': 4.26453,
#   'rank': 26,
#   'symbol': 'STEEM',
#   'total_supply': 266177217.0},
#  {'24h_volume_usd': 85493100.0,
#   'available_supply': 99014000.0,
#   'id': 'binance-coin',
#   'last_updated': 1518199752,
#   'market_cap_usd': 875696648.0,
#   'max_supply': None,
#   'name': 'Binance Coin',
#   'percent_change_1h': 1.81,
#   'percent_change_24h': 4.31,
#   'percent_change_7d': -4.54,
#   'price_btc': 0.00101958,
#   'price_usd': 8.84417,
#   'rank': 27,
#   'symbol': 'BNB',
#   'total_supply': 197192382.0},
#  {'24h_volume_usd': 5759890.0,
#   'available_supply': 183717153435,
#   'id': 'bytecoin-bcn',
#   'last_updated': 1518199743,
#   'market_cap_usd': 871728707.0,
#   'max_supply': 184470000000,
#   'name': 'Bytecoin',
#   'percent_change_1h': 3.26,
#   'percent_change_24h': 7.42,
#   'percent_change_7d': 4.48,
#   'price_btc': 5.5e-07,
#   'price_usd': 0.00474495,
#   'rank': 28,
#   'symbol': 'BCN',
#   'total_supply': 183717153435},
#  {'24h_volume_usd': 23580400.0,
#   'available_supply': 14576502046.0,
#   'id': 'verge',
#   'last_updated': 1518199744,
#   'market_cap_usd': 829822770.0,
#   'max_supply': 16555000000.0,
#   'name': 'Verge',
#   'percent_change_1h': 3.51,
#   'percent_change_24h': 10.51,
#   'percent_change_7d': 8.59,
#   'price_btc': 6.56e-06,
#   'price_usd': 0.0569288,
#   'rank': 29,
#   'symbol': 'XVG',
#   'total_supply': 14576502046.0},
#  {'24h_volume_usd': 16067000.0,
#   'available_supply': 32364340065.0,
#   'id': 'siacoin',
#   'last_updated': 1518199745,
#   'market_cap_usd': 808208773.0,
#   'max_supply': None,
#   'name': 'Siacoin',
#   'percent_change_1h': 4.09,
#   'percent_change_24h': 14.95,
#   'percent_change_7d': -1.43,
#   'price_btc': 2.88e-06,
#   'price_usd': 0.0249722,
#   'rank': 30,
#   'symbol': 'SC',
#   'total_supply': 32364340065.0},
#  {'24h_volume_usd': 17370100.0,
#   'available_supply': 98734058.0,
#   'id': 'stratis',
#   'last_updated': 1518199747,
#   'market_cap_usd': 792968766.0,
#   'max_supply': None,
#   'name': 'Stratis',
#   'percent_change_1h': 2.43,
#   'percent_change_24h': 14.62,
#   'percent_change_7d': -9.15,
#   'price_btc': 0.00092588,
#   'price_usd': 8.03136,
#   'rank': 31,
#   'symbol': 'STRAT',
#   'total_supply': 98734058.0},
#  {'24h_volume_usd': 166048000.0,
#   'available_supply': 3470483788.0,
#   'id': 'status',
#   'last_updated': 1518199752,
#   'market_cap_usd': 784790910.0,
#   'max_supply': None,
#   'name': 'Status',
#   'percent_change_1h': 0.83,
#   'percent_change_24h': 6.16,
#   'percent_change_7d': 36.04,
#   'price_btc': 2.607e-05,
#   'price_usd': 0.226133,
#   'rank': 32,
#   'symbol': 'SNT',
#   'total_supply': 6804870174.0},
#  {'24h_volume_usd': 21990600.0,
#   'available_supply': 233020472.0,
#   'id': 'aeternity',
#   'last_updated': 1518199751,
#   'market_cap_usd': 705350639.0,
#   'max_supply': None,
#   'name': 'Aeternity',
#   'percent_change_1h': 2.84,
#   'percent_change_24h': 6.89,
#   'percent_change_7d': 18.26,
#   'price_btc': 0.00034896,
#   'price_usd': 3.02699,
#   'rank': 33,
#   'symbol': 'AE',
#   'total_supply': 273685830.0},
#  {'24h_volume_usd': 28683200.0,
#   'available_supply': 2608390000.0,
#   'id': 'bitshares',
#   'last_updated': 1518199744,
#   'market_cap_usd': 678718728.0,
#   'max_supply': 3600570502.0,
#   'name': 'BitShares',
#   'percent_change_1h': 3.09,
#   'percent_change_24h': 12.37,
#   'percent_change_7d': -15.54,
#   'price_btc': 3e-05,
#   'price_usd': 0.260206,
#   'rank': 34,
#   'symbol': 'BTS',
#   'total_supply': 2608390000.0},
#  {'24h_volume_usd': 636429.0,
#   'available_supply': 618228.0,
#   'id': 'maker',
#   'last_updated': 1518199749,
#   'market_cap_usd': 671982675.0,
#   'max_supply': None,
#   'name': 'Maker',
#   'percent_change_1h': 2.6,
#   'percent_change_24h': 8.96,
#   'percent_change_7d': -4.12,
#   'price_btc': 0.125307,
#   'price_usd': 1086.95,
#   'rank': 35,
#   'symbol': 'MKR',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 6402670.0,
#   'available_supply': 11000000.0,
#   'id': 'augur',
#   'last_updated': 1518199745,
#   'market_cap_usd': 621132600.0,
#   'max_supply': None,
#   'name': 'Augur',
#   'percent_change_1h': 2.47,
#   'percent_change_24h': 9.79,
#   'percent_change_7d': 0.81,
#   'price_btc': 0.00650966,
#   'price_usd': 56.4666,
#   'rank': 36,
#   'symbol': 'REP',
#   'total_supply': 11000000.0},
#  {'24h_volume_usd': 25758900.0,
#   'available_supply': 2000000.0,
#   'id': 'digixdao',
#   'last_updated': 1518199747,
#   'market_cap_usd': 614916000.0,
#   'max_supply': None,
#   'name': 'DigixDAO',
#   'percent_change_1h': 3.06,
#   'percent_change_24h': 6.64,
#   'percent_change_7d': -13.39,
#   'price_btc': 0.0354447,
#   'price_usd': 307.458,
#   'rank': 37,
#   'symbol': 'DGD',
#   'total_supply': 2000000.0},
#  {'24h_volume_usd': 27672700.0,
#   'available_supply': 100000000.0,
#   'id': 'waves',
#   'last_updated': 1518199747,
#   'market_cap_usd': 604181000.0,
#   'max_supply': None,
#   'name': 'Waves',
#   'percent_change_1h': 4.16,
#   'percent_change_24h': 12.22,
#   'percent_change_7d': -1.11,
#   'price_btc': 0.00069652,
#   'price_usd': 6.04181,
#   'rank': 38,
#   'symbol': 'WAVES',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 17364700.0,
#   'available_supply': 24898178.0,
#   'id': 'walton',
#   'last_updated': 1518199754,
#   'market_cap_usd': 596373609.0,
#   'max_supply': 100000000.0,
#   'name': 'Walton',
#   'percent_change_1h': 3.02,
#   'percent_change_24h': 6.54,
#   'percent_change_7d': -1.28,
#   'price_btc': 0.00276132,
#   'price_usd': 23.9525,
#   'rank': 39,
#   'symbol': 'WTC',
#   'total_supply': 70000000.0},
#  {'24h_volume_usd': 167268.0,
#   'available_supply': 2036645.0,
#   'id': 'veritaseum',
#   'last_updated': 1518199751,
#   'market_cap_usd': 591997840.0,
#   'max_supply': None,
#   'name': 'Veritaseum',
#   'percent_change_1h': 4.33,
#   'percent_change_24h': 5.91,
#   'percent_change_7d': -10.36,
#   'price_btc': 0.0335098,
#   'price_usd': 290.673,
#   'rank': 40,
#   'symbol': 'VERI',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 13750200.0,
#   'available_supply': 507188082.0,
#   'id': '0x',
#   'last_updated': 1518199754,
#   'market_cap_usd': 580091297.0,
#   'max_supply': None,
#   'name': '0x',
#   'percent_change_1h': 2.02,
#   'percent_change_24h': 7.73,
#   'percent_change_7d': -11.28,
#   'price_btc': 0.00013185,
#   'price_usd': 1.14374,
#   'rank': 41,
#   'symbol': 'ZRX',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 10103700.0,
#   'available_supply': 113132925740,
#   'id': 'dogecoin',
#   'last_updated': 1518199742,
#   'market_cap_usd': 557657080.0,
#   'max_supply': None,
#   'name': 'Dogecoin',
#   'percent_change_1h': 3.14,
#   'percent_change_24h': 8.81,
#   'percent_change_7d': 13.36,
#   'price_btc': 5.7e-07,
#   'price_usd': 0.00492922,
#   'rank': 42,
#   'symbol': 'DOGE',
#   'total_supply': 113132925740},
#  {'24h_volume_usd': 1861490.0,
#   'available_supply': 6723547.0,
#   'id': 'decred',
#   'last_updated': 1518199746,
#   'market_cap_usd': 545695139.0,
#   'max_supply': 21000000.0,
#   'name': 'Decred',
#   'percent_change_1h': 1.92,
#   'percent_change_24h': 8.81,
#   'percent_change_7d': 5.11,
#   'price_btc': 0.0093566,
#   'price_usd': 81.1618,
#   'rank': 43,
#   'symbol': 'DCR',
#   'total_supply': 7143547.0},
#  {'24h_volume_usd': 2902840.0,
#   'available_supply': 91043076.0,
#   'id': 'kucoin-shares',
#   'last_updated': 1518199755,
#   'market_cap_usd': 540940630.0,
#   'max_supply': None,
#   'name': 'KuCoin Shares',
#   'percent_change_1h': 4.48,
#   'percent_change_24h': 3.94,
#   'percent_change_7d': -7.97,
#   'price_btc': 0.00068497,
#   'price_usd': 5.94159,
#   'rank': 44,
#   'symbol': 'KCS',
#   'total_supply': 181043076.0},
#  {'24h_volume_usd': 78981400.0,
#   'available_supply': 42603178.0,
#   'id': 'hshare',
#   'last_updated': 1518199753,
#   'market_cap_usd': 526443205.0,
#   'max_supply': 84000000.0,
#   'name': 'Hshare',
#   'percent_change_1h': 1.09,
#   'percent_change_24h': 15.8,
#   'percent_change_7d': 10.45,
#   'price_btc': 0.00142454,
#   'price_usd': 12.3569,
#   'rank': 45,
#   'symbol': 'HSR',
#   'total_supply': 42603178.0},
#  {'24h_volume_usd': 71633000.0,
#   'available_supply': 998999495.0,
#   'id': 'ardor',
#   'last_updated': 1518199748,
#   'market_cap_usd': 515866356.0,
#   'max_supply': 998999495.0,
#   'name': 'Ardor',
#   'percent_change_1h': 4.87,
#   'percent_change_24h': 17.67,
#   'percent_change_7d': 6.83,
#   'price_btc': 5.953e-05,
#   'price_usd': 0.516383,
#   'rank': 46,
#   'symbol': 'ARDR',
#   'total_supply': 998999495.0},
#  {'24h_volume_usd': 741230.0,
#   'available_supply': 344166289.0,
#   'id': 'rchain',
#   'last_updated': 1518199755,
#   'market_cap_usd': 511902613.0,
#   'max_supply': 1000000000.0,
#   'name': 'RChain',
#   'percent_change_1h': 6.23,
#   'percent_change_24h': 11.49,
#   'percent_change_7d': -8.88,
#   'price_btc': 0.00017147,
#   'price_usd': 1.48737,
#   'rank': 47,
#   'symbol': 'RHOC',
#   'total_supply': 870663574.0},
#  {'24h_volume_usd': 4910790.0,
#   'available_supply': 103154199.0,
#   'id': 'komodo',
#   'last_updated': 1518199748,
#   'market_cap_usd': 453383337.0,
#   'max_supply': None,
#   'name': 'Komodo',
#   'percent_change_1h': 2.15,
#   'percent_change_24h': 12.83,
#   'percent_change_7d': 1.94,
#   'price_btc': 0.00050669,
#   'price_usd': 4.3952,
#   'rank': 48,
#   'symbol': 'KMD',
#   'total_supply': 103154199.0},
#  {'24h_volume_usd': 5583500.0,
#   'available_supply': 184450000.0,
#   'id': 'revain',
#   'last_updated': 1518199757,
#   'market_cap_usd': 452712236.0,
#   'max_supply': 484450000.0,
#   'name': 'Revain',
#   'percent_change_1h': 3.06,
#   'percent_change_24h': 19.99,
#   'percent_change_7d': 66.69,
#   'price_btc': 0.00028295,
#   'price_usd': 2.45439,
#   'rank': 49,
#   'symbol': 'R',
#   'total_supply': 484450000.0},
#  {'24h_volume_usd': 7598710.0,
#   'available_supply': 134132697.0,
#   'id': 'kyber-network',
#   'last_updated': 1518199754,
#   'market_cap_usd': 448047472.0,
#   'max_supply': None,
#   'name': 'Kyber Network',
#   'percent_change_1h': 3.03,
#   'percent_change_24h': 8.68,
#   'percent_change_7d': 1.03,
#   'price_btc': 0.00038508,
#   'price_usd': 3.34033,
#   'rank': 50,
#   'symbol': 'KNC',
#   'total_supply': 215625349.0},
#  {'24h_volume_usd': 2622600.0,
#   'available_supply': 6104889451.0,
#   'id': 'electroneum',
#   'last_updated': 1518199756,
#   'market_cap_usd': 443090434.0,
#   'max_supply': 21000000000.0,
#   'name': 'Electroneum',
#   'percent_change_1h': 3.29,
#   'percent_change_24h': 7.44,
#   'percent_change_7d': 10.67,
#   'price_btc': 8.37e-06,
#   'price_usd': 0.0725796,
#   'rank': 51,
#   'symbol': 'ETN',
#   'total_supply': 6104889451.0},
#  {'24h_volume_usd': 9368740.0,
#   'available_supply': 100525998.0,
#   'id': 'ark',
#   'last_updated': 1518199750,
#   'market_cap_usd': 433011715.0,
#   'max_supply': None,
#   'name': 'Ark',
#   'percent_change_1h': 1.39,
#   'percent_change_24h': 12.97,
#   'percent_change_7d': -1.1,
#   'price_btc': 0.00049658,
#   'price_usd': 4.30746,
#   'rank': 52,
#   'symbol': 'ARK',
#   'total_supply': 131775998.0},
#  {'24h_volume_usd': 9115140.0,
#   'available_supply': 9675198.0,
#   'id': 'gas',
#   'last_updated': 1518199752,
#   'market_cap_usd': 421356829.0,
#   'max_supply': 100000000.0,
#   'name': 'Gas',
#   'percent_change_1h': 3.32,
#   'percent_change_24h': 6.79,
#   'percent_change_7d': -5.47,
#   'price_btc': 0.00502061,
#   'price_usd': 43.5502,
#   'rank': 53,
#   'symbol': 'GAS',
#   'total_supply': 15257384.0},
#  {'24h_volume_usd': 2353350.0,
#   'available_supply': 238421940.0,
#   'id': 'dragonchain',
#   'last_updated': 1518199757,
#   'market_cap_usd': 397263405.0,
#   'max_supply': None,
#   'name': 'Dragonchain',
#   'percent_change_1h': 5.45,
#   'percent_change_24h': 12.37,
#   'percent_change_7d': -0.71,
#   'price_btc': 0.00019209,
#   'price_usd': 1.66622,
#   'rank': 54,
#   'symbol': 'DRGN',
#   'total_supply': 433494437.0},
#  {'24h_volume_usd': 5884150.0,
#   'available_supply': 1000000000.0,
#   'id': 'basic-attention-token',
#   'last_updated': 1518199751,
#   'market_cap_usd': 396245000.0,
#   'max_supply': None,
#   'name': 'Basic Attention Token',
#   'percent_change_1h': 4.75,
#   'percent_change_24h': 5.74,
#   'percent_change_7d': -2.43,
#   'price_btc': 4.568e-05,
#   'price_usd': 0.396245,
#   'rank': 55,
#   'symbol': 'BAT',
#   'total_supply': 1500000000.0},
#  {'24h_volume_usd': 7029520.0,
#   'available_supply': 9818417643.0,
#   'id': 'digibyte',
#   'last_updated': 1518199741,
#   'market_cap_usd': 393116678.0,
#   'max_supply': 21000000000.0,
#   'name': 'DigiByte',
#   'percent_change_1h': 5.0,
#   'percent_change_24h': 22.16,
#   'percent_change_7d': -1.25,
#   'price_btc': 4.62e-06,
#   'price_usd': 0.0400387,
#   'rank': 56,
#   'symbol': 'DGB',
#   'total_supply': 9818417643.0},
#  {'24h_volume_usd': 12246000.0,
#   'available_supply': 6508988220.0,
#   'id': 'zilliqa',
#   'last_updated': 1518199760,
#   'market_cap_usd': 390917465.0,
#   'max_supply': None,
#   'name': 'Zilliqa',
#   'percent_change_1h': 2.56,
#   'percent_change_24h': 4.48,
#   'percent_change_7d': -10.86,
#   'price_btc': 6.92e-06,
#   'price_usd': 0.0600581,
#   'rank': 57,
#   'symbol': 'ZIL',
#   'total_supply': 12600000000.0},
#  {'24h_volume_usd': 3003160.0,
#   'available_supply': 561202251.0,
#   'id': 'loopring',
#   'last_updated': 1518199753,
#   'market_cap_usd': 384027895.0,
#   'max_supply': None,
#   'name': 'Loopring',
#   'percent_change_1h': 3.25,
#   'percent_change_24h': 8.91,
#   'percent_change_7d': -9.67,
#   'price_btc': 7.889e-05,
#   'price_usd': 0.684295,
#   'rank': 58,
#   'symbol': 'LRC',
#   'total_supply': 1374956357.0},
#  {'24h_volume_usd': 585815.0,
#   'available_supply': 325226613094,
#   'id': 'dentacoin',
#   'last_updated': 1518199753,
#   'market_cap_usd': 373464224.0,
#   'max_supply': 8000000000000,
#   'name': 'Dentacoin',
#   'percent_change_1h': 4.79,
#   'percent_change_24h': 8.01,
#   'percent_change_7d': 8.27,
#   'price_btc': 1.3e-07,
#   'price_usd': 0.00114832,
#   'rank': 59,
#   'symbol': 'DCN',
#   'total_supply': 1963173416169},
#  {'24h_volume_usd': 45452400.0,
#   'available_supply': 250000000.0,
#   'id': 'aelf',
#   'last_updated': 1518199758,
#   'market_cap_usd': 343575000.0,
#   'max_supply': None,
#   'name': 'aelf',
#   'percent_change_1h': 2.71,
#   'percent_change_24h': 7.83,
#   'percent_change_7d': -11.71,
#   'price_btc': 0.00015843,
#   'price_usd': 1.3743,
#   'rank': 60,
#   'symbol': 'ELF',
#   'total_supply': 260000000.0},
#  {'24h_volume_usd': 17010400.0,
#   'available_supply': 987000000.0,
#   'id': 'bytom',
#   'last_updated': 1518199752,
#   'market_cap_usd': 342627180.0,
#   'max_supply': None,
#   'name': 'Bytom',
#   'percent_change_1h': 2.63,
#   'percent_change_24h': 18.5,
#   'percent_change_7d': 6.19,
#   'price_btc': 4.002e-05,
#   'price_usd': 0.34714,
#   'rank': 61,
#   'symbol': 'BTM',
#   'total_supply': 1407000000.0},
#  {'24h_volume_usd': 14831800.0,
#   'available_supply': 55526279.0,
#   'id': 'pivx',
#   'last_updated': 1518199746,
#   'market_cap_usd': 342085747.0,
#   'max_supply': None,
#   'name': 'PIVX',
#   'percent_change_1h': 2.78,
#   'percent_change_24h': 14.91,
#   'percent_change_7d': 8.14,
#   'price_btc': 0.00071024,
#   'price_usd': 6.16079,
#   'rank': 62,
#   'symbol': 'PIVX',
#   'total_supply': 55526279.0},
#  {'24h_volume_usd': 819694.0,
#   'available_supply': 645222.0,
#   'id': 'byteball',
#   'last_updated': 1518199749,
#   'market_cap_usd': 341024373.0,
#   'max_supply': None,
#   'name': 'Byteball Bytes',
#   'percent_change_1h': 7.28,
#   'percent_change_24h': 14.57,
#   'percent_change_7d': -0.69,
#   'price_btc': 0.0609316,
#   'price_usd': 528.538,
#   'rank': 63,
#   'symbol': 'GBYTE',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 7139620.0,
#   'available_supply': 75601200.0,
#   'id': 'ethos',
#   'last_updated': 1518199752,
#   'market_cap_usd': 338958734.0,
#   'max_supply': None,
#   'name': 'Ethos',
#   'percent_change_1h': 3.11,
#   'percent_change_24h': 6.78,
#   'percent_change_7d': 20.68,
#   'price_btc': 0.00051687,
#   'price_usd': 4.48351,
#   'rank': 64,
#   'symbol': 'ETHOS',
#   'total_supply': 222295208.0},
#  {'24h_volume_usd': 4827700.0,
#   'available_supply': 3264950.0,
#   'id': 'zclassic',
#   'last_updated': 1518199748,
#   'market_cap_usd': 337612155.0,
#   'max_supply': 21000000.0,
#   'name': 'ZClassic',
#   'percent_change_1h': 4.9,
#   'percent_change_24h': 5.73,
#   'percent_change_7d': 6.08,
#   'price_btc': 0.0119209,
#   'price_usd': 103.405,
#   'rank': 65,
#   'symbol': 'ZCL',
#   'total_supply': 3264950.0},
#  {'24h_volume_usd': 3133300.0,
#   'available_supply': 350000000.0,
#   'id': 'qash',
#   'last_updated': 1518199757,
#   'market_cap_usd': 320499200.0,
#   'max_supply': None,
#   'name': 'QASH',
#   'percent_change_1h': 3.57,
#   'percent_change_24h': 9.62,
#   'percent_change_7d': 0.27,
#   'price_btc': 0.00010557,
#   'price_usd': 0.915712,
#   'rank': 66,
#   'symbol': 'QASH',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 291136.0,
#   'available_supply': 227384800.0,
#   'id': 'pillar',
#   'last_updated': 1518199752,
#   'market_cap_usd': 317472384.0,
#   'max_supply': None,
#   'name': 'Pillar',
#   'percent_change_1h': 0.9,
#   'percent_change_24h': 3.09,
#   'percent_change_7d': 7.32,
#   'price_btc': 0.00016096,
#   'price_usd': 1.39619,
#   'rank': 67,
#   'symbol': 'PLR',
#   'total_supply': 800000000.0},
#  {'24h_volume_usd': 7368280.0,
#   'available_supply': 35500000.0,
#   'id': 'nebulas-token',
#   'last_updated': 1518199753,
#   'market_cap_usd': 308613570.0,
#   'max_supply': 100000000.0,
#   'name': 'Nebulas',
#   'percent_change_1h': 2.64,
#   'percent_change_24h': 11.37,
#   'percent_change_7d': -2.42,
#   'price_btc': 0.0010022,
#   'price_usd': 8.69334,
#   'rank': 68,
#   'symbol': 'NAS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 486891.0,
#   'available_supply': 4981227.0,
#   'id': 'e-coin',
#   'last_updated': 1518199750,
#   'market_cap_usd': 306765398.0,
#   'max_supply': None,
#   'name': 'E-coin',
#   'percent_change_1h': -6.25,
#   'percent_change_24h': 838.28,
#   'percent_change_7d': 1138.28,
#   'price_btc': 0.00709963,
#   'price_usd': 61.5843,
#   'rank': 69,
#   'symbol': 'ECN',
#   'total_supply': 213270119.0},
#  {'24h_volume_usd': 30379600.0,
#   'available_supply': 4503688789.0,
#   'id': 'funfair',
#   'last_updated': 1518199751,
#   'market_cap_usd': 299683108.0,
#   'max_supply': None,
#   'name': 'FunFair',
#   'percent_change_1h': 3.04,
#   'percent_change_24h': 7.87,
#   'percent_change_7d': 11.23,
#   'price_btc': 7.67e-06,
#   'price_usd': 0.0665417,
#   'rank': 70,
#   'symbol': 'FUN',
#   'total_supply': 10999873621.0},
#  {'24h_volume_usd': 7118560.0,
#   'available_supply': 834262000.0,
#   'id': 'golem-network-tokens',
#   'last_updated': 1518199748,
#   'market_cap_usd': 297337651.0,
#   'max_supply': None,
#   'name': 'Golem',
#   'percent_change_1h': 4.18,
#   'percent_change_24h': 9.92,
#   'percent_change_7d': -0.15,
#   'price_btc': 4.109e-05,
#   'price_usd': 0.356408,
#   'rank': 71,
#   'symbol': 'GNT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 231936.0,
#   'available_supply': 45106547.0,
#   'id': 'cryptonex',
#   'last_updated': 1518199755,
#   'market_cap_usd': 293141136.0,
#   'max_supply': 210000000.0,
#   'name': 'Cryptonex',
#   'percent_change_1h': 3.31,
#   'percent_change_24h': 4.55,
#   'percent_change_7d': 3.22,
#   'price_btc': 0.00074921,
#   'price_usd': 6.49886,
#   'rank': 72,
#   'symbol': 'CNX',
#   'total_supply': 106544173.0},
#  {'24h_volume_usd': 12465500.0,
#   'available_supply': 1445976590.0,
#   'id': 'cindicator',
#   'last_updated': 1518199755,
#   'market_cap_usd': 291258727.0,
#   'max_supply': None,
#   'name': 'Cindicator',
#   'percent_change_1h': 3.12,
#   'percent_change_24h': 6.86,
#   'percent_change_7d': 4.8,
#   'price_btc': 2.322e-05,
#   'price_usd': 0.201427,
#   'rank': 73,
#   'symbol': 'CND',
#   'total_supply': 2000000005.0},
#  {'24h_volume_usd': 3025430.0,
#   'available_supply': 10614760961.0,
#   'id': 'dent',
#   'last_updated': 1518199753,
#   'market_cap_usd': 288687531.0,
#   'max_supply': None,
#   'name': 'Dent',
#   'percent_change_1h': 2.93,
#   'percent_change_24h': 6.11,
#   'percent_change_7d': 22.1,
#   'price_btc': 3.14e-06,
#   'price_usd': 0.0271968,
#   'rank': 74,
#   'symbol': 'DENT',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 3928270.0,
#   'available_supply': 530835550.0,
#   'id': 'syscoin',
#   'last_updated': 1518199743,
#   'market_cap_usd': 287651291.0,
#   'max_supply': 888000000.0,
#   'name': 'Syscoin',
#   'percent_change_1h': 4.15,
#   'percent_change_24h': 4.39,
#   'percent_change_7d': 15.96,
#   'price_btc': 6.247e-05,
#   'price_usd': 0.541884,
#   'rank': 75,
#   'symbol': 'SYS',
#   'total_supply': 530835550.0},
#  {'24h_volume_usd': 1446540.0,
#   'available_supply': 11168247.0,
#   'id': 'bitcore',
#   'last_updated': 1518199750,
#   'market_cap_usd': 277683931.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcore',
#   'percent_change_1h': 1.5,
#   'percent_change_24h': 2.49,
#   'percent_change_7d': 10.55,
#   'price_btc': 0.00286637,
#   'price_usd': 24.8637,
#   'rank': 76,
#   'symbol': 'BTX',
#   'total_supply': 16795184.0},
#  {'24h_volume_usd': 40383900.0,
#   'available_supply': 6794109922.0,
#   'id': 'iostoken',
#   'last_updated': 1518199760,
#   'market_cap_usd': 275548037.0,
#   'max_supply': None,
#   'name': 'IOStoken',
#   'percent_change_1h': 2.67,
#   'percent_change_24h': 4.5,
#   'percent_change_7d': -10.52,
#   'price_btc': 4.68e-06,
#   'price_usd': 0.0405569,
#   'rank': 77,
#   'symbol': 'IOST',
#   'total_supply': 21000000000.0},
#  {'24h_volume_usd': 17848200.0,
#   'available_supply': 60000000.0,
#   'id': 'gxshares',
#   'last_updated': 1518199751,
#   'market_cap_usd': 271090200.0,
#   'max_supply': 100000000.0,
#   'name': 'GXShares',
#   'percent_change_1h': 2.67,
#   'percent_change_24h': 8.84,
#   'percent_change_7d': 4.23,
#   'price_btc': 0.00052087,
#   'price_usd': 4.51817,
#   'rank': 78,
#   'symbol': 'GXS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 18888600.0,
#   'available_supply': 363837589.0,
#   'id': 'power-ledger',
#   'last_updated': 1518199756,
#   'market_cap_usd': 265482829.0,
#   'max_supply': None,
#   'name': 'Power Ledger',
#   'percent_change_1h': 2.75,
#   'percent_change_24h': 8.85,
#   'percent_change_7d': 10.65,
#   'price_btc': 8.412e-05,
#   'price_usd': 0.729674,
#   'rank': 79,
#   'symbol': 'POWR',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 6784840.0,
#   'available_supply': 52847204.0,
#   'id': 'salt',
#   'last_updated': 1518199755,
#   'market_cap_usd': 249223713.0,
#   'max_supply': None,
#   'name': 'SALT',
#   'percent_change_1h': 3.51,
#   'percent_change_24h': 6.93,
#   'percent_change_7d': 4.19,
#   'price_btc': 0.00054367,
#   'price_usd': 4.71593,
#   'rank': 80,
#   'symbol': 'SALT',
#   'total_supply': 120000000.0},
#  {'24h_volume_usd': 5535430.0,
#   'available_supply': 8745102.0,
#   'id': 'factom',
#   'last_updated': 1518199746,
#   'market_cap_usd': 249136587.0,
#   'max_supply': None,
#   'name': 'Factom',
#   'percent_change_1h': 4.03,
#   'percent_change_24h': 12.98,
#   'percent_change_7d': 3.11,
#   'price_btc': 0.00328427,
#   'price_usd': 28.4887,
#   'rank': 81,
#   'symbol': 'FCT',
#   'total_supply': 8745102.0},
#  {'24h_volume_usd': 5156670.0,
#   'available_supply': 79265735.0,
#   'id': 'aion',
#   'last_updated': 1518199756,
#   'market_cap_usd': 236151648.0,
#   'max_supply': None,
#   'name': 'Aion',
#   'percent_change_1h': 2.91,
#   'percent_change_24h': 6.34,
#   'percent_change_7d': -7.21,
#   'price_btc': 0.00034346,
#   'price_usd': 2.97924,
#   'rank': 82,
#   'symbol': 'AION',
#   'total_supply': 465934587.0},
#  {'24h_volume_usd': 3421890.0,
#   'available_supply': 57307950.0,
#   'id': 'monacoin',
#   'last_updated': 1518199742,
#   'market_cap_usd': 232684604.0,
#   'max_supply': None,
#   'name': 'MonaCoin',
#   'percent_change_1h': 5.7,
#   'percent_change_24h': 10.36,
#   'percent_change_7d': 5.88,
#   'price_btc': 0.00046808,
#   'price_usd': 4.06025,
#   'rank': 83,
#   'symbol': 'MONA',
#   'total_supply': 57307950.0},
#  {'24h_volume_usd': 161494.0,
#   'available_supply': 756097560976,
#   'id': 'kin',
#   'last_updated': 1518199754,
#   'market_cap_usd': 229068073.0,
#   'max_supply': None,
#   'name': 'Kin',
#   'percent_change_1h': 1.53,
#   'percent_change_24h': 12.31,
#   'percent_change_7d': 3.99,
#   'price_btc': 3e-08,
#   'price_usd': 0.000302961,
#   'rank': 84,
#   'symbol': 'KIN',
#   'total_supply': 10000000000000},
#  {'24h_volume_usd': 284297.0,
#   'available_supply': 682579465.0,
#   'id': 'smartcash',
#   'last_updated': 1518199752,
#   'market_cap_usd': 221198749.0,
#   'max_supply': 5000000000.0,
#   'name': 'SmartCash',
#   'percent_change_1h': 0.93,
#   'percent_change_24h': 1.14,
#   'percent_change_7d': -7.53,
#   'price_btc': 3.736e-05,
#   'price_usd': 0.324063,
#   'rank': 85,
#   'symbol': 'SMART',
#   'total_supply': 1283623744.0},
#  {'24h_volume_usd': 7416760.0,
#   'available_supply': 4068762.0,
#   'id': 'zcoin',
#   'last_updated': 1518199748,
#   'market_cap_usd': 220067130.0,
#   'max_supply': None,
#   'name': 'ZCoin',
#   'percent_change_1h': 3.69,
#   'percent_change_24h': 10.2,
#   'percent_change_7d': 2.1,
#   'price_btc': 0.00623532,
#   'price_usd': 54.087,
#   'rank': 86,
#   'symbol': 'XZC',
#   'total_supply': 4068762.0},
#  {'24h_volume_usd': 8117140.0,
#   'available_supply': 74836171.0,
#   'id': 'enigma-project',
#   'last_updated': 1518199755,
#   'market_cap_usd': 211906850.0,
#   'max_supply': None,
#   'name': 'Enigma',
#   'percent_change_1h': 3.09,
#   'percent_change_24h': 16.13,
#   'percent_change_7d': 8.28,
#   'price_btc': 0.00032644,
#   'price_usd': 2.83161,
#   'rank': 87,
#   'symbol': 'ENG',
#   'total_supply': 150000000.0},
#  {'24h_volume_usd': 386131.0,
#   'available_supply': 8865530.0,
#   'id': 'particl',
#   'last_updated': 1518199752,
#   'market_cap_usd': 211252290.0,
#   'max_supply': None,
#   'name': 'Particl',
#   'percent_change_1h': 3.28,
#   'percent_change_24h': 17.78,
#   'percent_change_7d': 10.99,
#   'price_btc': 0.00274703,
#   'price_usd': 23.8285,
#   'rank': 88,
#   'symbol': 'PART',
#   'total_supply': 8865530.0},
#  {'24h_volume_usd': 980271.0,
#   'available_supply': 454443782.0,
#   'id': 'singularitynet',
#   'last_updated': 1518199760,
#   'market_cap_usd': 207065946.0,
#   'max_supply': None,
#   'name': 'SingularityNET',
#   'percent_change_1h': 5.27,
#   'percent_change_24h': 9.26,
#   'percent_change_7d': -13.68,
#   'price_btc': 5.253e-05,
#   'price_usd': 0.455647,
#   'rank': 89,
#   'symbol': 'AGI',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 6911730.0,
#   'available_supply': 38986587.0,
#   'id': 'bancor',
#   'last_updated': 1518199751,
#   'market_cap_usd': 206785248.0,
#   'max_supply': None,
#   'name': 'Bancor',
#   'percent_change_1h': 3.3,
#   'percent_change_24h': 9.38,
#   'percent_change_7d': -7.53,
#   'price_btc': 0.00061146,
#   'price_usd': 5.30401,
#   'rank': 90,
#   'symbol': 'BNT',
#   'total_supply': 74985159.0},
#  {'24h_volume_usd': 19933700.0,
#   'available_supply': 617314171.0,
#   'id': 'quantstamp',
#   'last_updated': 1518199757,
#   'market_cap_usd': 206045889.0,
#   'max_supply': None,
#   'name': 'Quantstamp',
#   'percent_change_1h': 3.19,
#   'percent_change_24h': 9.73,
#   'percent_change_7d': 25.32,
#   'price_btc': 3.848e-05,
#   'price_usd': 0.333778,
#   'rank': 91,
#   'symbol': 'QSP',
#   'total_supply': 976442388.0},
#  {'24h_volume_usd': 10477600.0,
#   'available_supply': 998999942.0,
#   'id': 'nxt',
#   'last_updated': 1518199741,
#   'market_cap_usd': 204061722.0,
#   'max_supply': 1000000000.0,
#   'name': 'Nxt',
#   'percent_change_1h': 4.5,
#   'percent_change_24h': 15.29,
#   'percent_change_7d': -5.08,
#   'price_btc': 2.355e-05,
#   'price_usd': 0.204266,
#   'rank': 92,
#   'symbol': 'NXT',
#   'total_supply': 998999942.0},
#  {'24h_volume_usd': 17133000.0,
#   'available_supply': 761143950.0,
#   'id': 'ignis',
#   'last_updated': 1518199758,
#   'market_cap_usd': 199476040.0,
#   'max_supply': 999449694.0,
#   'name': 'Ignis',
#   'percent_change_1h': 7.49,
#   'percent_change_24h': 34.25,
#   'percent_change_7d': -2.65,
#   'price_btc': 3.021e-05,
#   'price_usd': 0.262074,
#   'rank': 93,
#   'symbol': 'IGNIS',
#   'total_supply': 999449694.0},
#  {'24h_volume_usd': 1975860.0,
#   'available_supply': 452552412.0,
#   'id': 'maidsafecoin',
#   'last_updated': 1518199743,
#   'market_cap_usd': 195860611.0,
#   'max_supply': None,
#   'name': 'MaidSafeCoin',
#   'percent_change_1h': -0.18,
#   'percent_change_24h': 5.75,
#   'percent_change_7d': 5.01,
#   'price_btc': 4.989e-05,
#   'price_usd': 0.432791,
#   'rank': 94,
#   'symbol': 'MAID',
#   'total_supply': 452552412.0},
#  {'24h_volume_usd': 6461390.0,
#   'available_supply': 641462769.0,
#   'id': 'request-network',
#   'last_updated': 1518199755,
#   'market_cap_usd': 194266358.0,
#   'max_supply': None,
#   'name': 'Request Network',
#   'percent_change_1h': 3.35,
#   'percent_change_24h': 5.28,
#   'percent_change_7d': -3.04,
#   'price_btc': 3.491e-05,
#   'price_usd': 0.302849,
#   'rank': 95,
#   'symbol': 'REQ',
#   'total_supply': 999999999.0},
#  {'24h_volume_usd': 1941990.0,
#   'available_supply': 28740055495.0,
#   'id': 'reddcoin',
#   'last_updated': 1518199741,
#   'market_cap_usd': 192049385.0,
#   'max_supply': None,
#   'name': 'ReddCoin',
#   'percent_change_1h': 2.49,
#   'percent_change_24h': 12.16,
#   'percent_change_7d': -3.1,
#   'price_btc': 7.7e-07,
#   'price_usd': 0.00668229,
#   'rank': 96,
#   'symbol': 'RDD',
#   'total_supply': 28740055495.0},
#  {'24h_volume_usd': 1570960.0,
#   'available_supply': 1000000000.0,
#   'id': 'xplay',
#   'last_updated': 1518199754,
#   'market_cap_usd': 191484000.0,
#   'max_supply': None,
#   'name': 'XPlay',
#   'percent_change_1h': 2.63,
#   'percent_change_24h': 6.91,
#   'percent_change_7d': 34.91,
#   'price_btc': 2.207e-05,
#   'price_usd': 0.191484,
#   'rank': 97,
#   'symbol': 'XPA',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 693756.0,
#   'available_supply': 55514652.0,
#   'id': 'nexus',
#   'last_updated': 1518199744,
#   'market_cap_usd': 186602511.0,
#   'max_supply': None,
#   'name': 'Nexus',
#   'percent_change_1h': 4.84,
#   'percent_change_24h': 7.7,
#   'percent_change_7d': -6.99,
#   'price_btc': 0.0003875,
#   'price_usd': 3.36132,
#   'rank': 98,
#   'symbol': 'NXS',
#   'total_supply': 55514652.0},
#  {'24h_volume_usd': 784645.0,
#   'available_supply': 213753441795,
#   'id': 'experience-points',
#   'last_updated': 1518199747,
#   'market_cap_usd': 184242000.0,
#   'max_supply': None,
#   'name': 'Experience Points',
#   'percent_change_1h': 5.46,
#   'percent_change_24h': 20.94,
#   'percent_change_7d': 67.27,
#   'price_btc': 1e-07,
#   'price_usd': 0.000861937,
#   'rank': 99,
#   'symbol': 'XP',
#   'total_supply': 248785209661},
#  {'24h_volume_usd': 3814660.0,
#   'available_supply': 104661310.0,
#   'id': 'tenx',
#   'last_updated': 1518199752,
#   'market_cap_usd': 181393749.0,
#   'max_supply': None,
#   'name': 'TenX',
#   'percent_change_1h': 2.3,
#   'percent_change_24h': 12.14,
#   'percent_change_7d': -5.89,
#   'price_btc': 0.0001998,
#   'price_usd': 1.73315,
#   'rank': 100,
#   'symbol': 'PAY',
#   'total_supply': 205218256.0},
#  {'24h_volume_usd': 1390460.0,
#   'available_supply': 99735687.0,
#   'id': 'iconomi',
#   'last_updated': 1518199748,
#   'market_cap_usd': 174909466.0,
#   'max_supply': None,
#   'name': 'Iconomi',
#   'percent_change_1h': 3.63,
#   'percent_change_24h': 11.14,
#   'percent_change_7d': -8.72,
#   'price_btc': 0.00020218,
#   'price_usd': 1.75373,
#   'rank': 101,
#   'symbol': 'ICN',
#   'total_supply': 99735687.0},
#  {'24h_volume_usd': 13251400.0,
#   'available_supply': 342699966.0,
#   'id': 'civic',
#   'last_updated': 1518199752,
#   'market_cap_usd': 167505917.0,
#   'max_supply': None,
#   'name': 'Civic',
#   'percent_change_1h': 4.71,
#   'percent_change_24h': 3.93,
#   'percent_change_7d': 15.98,
#   'price_btc': 5.635e-05,
#   'price_usd': 0.488783,
#   'rank': 102,
#   'symbol': 'CVC',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 4080660.0,
#   'available_supply': 492954537.0,
#   'id': 'wax',
#   'last_updated': 1518199758,
#   'market_cap_usd': 165998004.0,
#   'max_supply': None,
#   'name': 'WAX',
#   'percent_change_1h': 1.6,
#   'percent_change_24h': 6.86,
#   'percent_change_7d': 1.08,
#   'price_btc': 3.882e-05,
#   'price_usd': 0.336741,
#   'rank': 103,
#   'symbol': 'WAX',
#   'total_supply': 1850000000.0},
#  {'24h_volume_usd': 977694.0,
#   'available_supply': 41282413.0,
#   'id': 'emercoin',
#   'last_updated': 1518199743,
#   'market_cap_usd': 162366620.0,
#   'max_supply': None,
#   'name': 'Emercoin',
#   'percent_change_1h': 3.52,
#   'percent_change_24h': 2.2,
#   'percent_change_7d': -1.43,
#   'price_btc': 0.00045342,
#   'price_usd': 3.93307,
#   'rank': 104,
#   'symbol': 'EMC',
#   'total_supply': 41282413.0},
#  {'24h_volume_usd': 479576.0,
#   'available_supply': 1104590.0,
#   'id': 'gnosis-gno',
#   'last_updated': 1518199751,
#   'market_cap_usd': 161040385.0,
#   'max_supply': None,
#   'name': 'Gnosis',
#   'percent_change_1h': 3.12,
#   'percent_change_24h': 3.98,
#   'percent_change_7d': -6.74,
#   'price_btc': 0.0168074,
#   'price_usd': 145.792,
#   'rank': 105,
#   'symbol': 'GNO',
#   'total_supply': 10000000.0},
#  {'24h_volume_usd': 4653500.0,
#   'available_supply': 226091449.0,
#   'id': 'substratum',
#   'last_updated': 1518199754,
#   'market_cap_usd': 156248635.0,
#   'max_supply': None,
#   'name': 'Substratum',
#   'percent_change_1h': 3.07,
#   'percent_change_24h': 7.55,
#   'percent_change_7d': 7.17,
#   'price_btc': 7.967e-05,
#   'price_usd': 0.691086,
#   'rank': 106,
#   'symbol': 'SUB',
#   'total_supply': 352000000.0},
#  {'24h_volume_usd': 3432740.0,
#   'available_supply': 12801437.0,
#   'id': 'neblio',
#   'last_updated': 1518199753,
#   'market_cap_usd': 156171132.0,
#   'max_supply': None,
#   'name': 'Neblio',
#   'percent_change_1h': 2.67,
#   'percent_change_24h': 7.16,
#   'percent_change_7d': -3.84,
#   'price_btc': 0.0014064,
#   'price_usd': 12.1995,
#   'rank': 107,
#   'symbol': 'NEBL',
#   'total_supply': 13547743.0},
#  {'24h_volume_usd': 2062190.0,
#   'available_supply': 64355352.0,
#   'id': 'gamecredits',
#   'last_updated': 1518199744,
#   'market_cap_usd': 155837128.0,
#   'max_supply': 84000000.0,
#   'name': 'GameCredits',
#   'percent_change_1h': 2.59,
#   'percent_change_24h': 3.89,
#   'percent_change_7d': -8.81,
#   'price_btc': 0.00027916,
#   'price_usd': 2.42151,
#   'rank': 108,
#   'symbol': 'GAME',
#   'total_supply': 64355352.0},
#  {'24h_volume_usd': 4590980.0,
#   'available_supply': 50148936.0,
#   'id': 'raiden-network-token',
#   'last_updated': 1518199756,
#   'market_cap_usd': 154428634.0,
#   'max_supply': None,
#   'name': 'Raiden Network Token',
#   'percent_change_1h': 4.09,
#   'percent_change_24h': 11.48,
#   'percent_change_7d': -1.31,
#   'price_btc': 0.000355,
#   'price_usd': 3.0794,
#   'rank': 109,
#   'symbol': 'RDN',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 5584630.0,
#   'available_supply': 350000000.0,
#   'id': 'chainlink',
#   'last_updated': 1518199754,
#   'market_cap_usd': 153258350.0,
#   'max_supply': None,
#   'name': 'ChainLink',
#   'percent_change_1h': 2.87,
#   'percent_change_24h': 6.83,
#   'percent_change_7d': -6.06,
#   'price_btc': 5.048e-05,
#   'price_usd': 0.437881,
#   'rank': 110,
#   'symbol': 'LINK',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 2308360.0,
#   'available_supply': 42856025.0,
#   'id': 'vertcoin',
#   'last_updated': 1518199741,
#   'market_cap_usd': 144037814.0,
#   'max_supply': 84000000.0,
#   'name': 'Vertcoin',
#   'percent_change_1h': 3.08,
#   'percent_change_24h': 12.07,
#   'percent_change_7d': 9.36,
#   'price_btc': 0.00038746,
#   'price_usd': 3.36097,
#   'rank': 111,
#   'symbol': 'VTC',
#   'total_supply': 42856025.0},
#  {'24h_volume_usd': 7411980.0,
#   'available_supply': 22216600.0,
#   'id': 'high-performance-blockchain',
#   'last_updated': 1518199758,
#   'market_cap_usd': 142334425.0,
#   'max_supply': None,
#   'name': 'High Performance Blockchain',
#   'percent_change_1h': 3.63,
#   'percent_change_24h': 4.73,
#   'percent_change_7d': -10.54,
#   'price_btc': 0.00073858,
#   'price_usd': 6.40667,
#   'rank': 112,
#   'symbol': 'HPB',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 1762700.0,
#   'available_supply': 2966384100.0,
#   'id': 'medibloc',
#   'last_updated': 1518199759,
#   'market_cap_usd': 141489402.0,
#   'max_supply': 10000000000.0,
#   'name': 'MediBloc',
#   'percent_change_1h': 4.0,
#   'percent_change_24h': 9.52,
#   'percent_change_7d': -7.83,
#   'price_btc': 5.5e-06,
#   'price_usd': 0.0476976,
#   'rank': 113,
#   'symbol': 'MED',
#   'total_supply': 4097545844.0},
#  {'24h_volume_usd': 45255.9,
#   'available_supply': 1288862.0,
#   'id': 'bitcoindark',
#   'last_updated': 1518199743,
#   'market_cap_usd': 141478402.0,
#   'max_supply': None,
#   'name': 'BitcoinDark',
#   'percent_change_1h': 2.7,
#   'percent_change_24h': 4.79,
#   'percent_change_7d': 4.68,
#   'price_btc': 0.0126547,
#   'price_usd': 109.77,
#   'rank': 114,
#   'symbol': 'BTCD',
#   'total_supply': 1288862.0},
#  {'24h_volume_usd': 273556.0,
#   'available_supply': 5007442.0,
#   'id': 'blocknet',
#   'last_updated': 1518199743,
#   'market_cap_usd': 140866850.0,
#   'max_supply': None,
#   'name': 'Blocknet',
#   'percent_change_1h': 3.21,
#   'percent_change_24h': 5.25,
#   'percent_change_7d': -2.55,
#   'price_btc': 0.00324309,
#   'price_usd': 28.1315,
#   'rank': 115,
#   'symbol': 'BLOCK',
#   'total_supply': 5007442.0},
#  {'24h_volume_usd': 11671400.0,
#   'available_supply': 133425493.0,
#   'id': 'storj',
#   'last_updated': 1518199751,
#   'market_cap_usd': 138975993.0,
#   'max_supply': None,
#   'name': 'Storj',
#   'percent_change_1h': 2.77,
#   'percent_change_24h': 11.84,
#   'percent_change_7d': 5.56,
#   'price_btc': 0.00012008,
#   'price_usd': 1.0416,
#   'rank': 116,
#   'symbol': 'STORJ',
#   'total_supply': 424999998.0},
#  {'24h_volume_usd': 82756900.0,
#   'available_supply': 165000000.0,
#   'id': 'bluzelle',
#   'last_updated': 1518199761,
#   'market_cap_usd': 137204430.0,
#   'max_supply': None,
#   'name': 'Bluzelle',
#   'percent_change_1h': 3.05,
#   'percent_change_24h': 6.86,
#   'percent_change_7d': None,
#   'price_btc': 9.586e-05,
#   'price_usd': 0.831542,
#   'rank': 117,
#   'symbol': 'BLZ',
#   'total_supply': 500000000.0},
#  {'24h_volume_usd': 11546600.0,
#   'available_supply': 300000000.0,
#   'id': 'achain',
#   'last_updated': 1518199753,
#   'market_cap_usd': 135419700.0,
#   'max_supply': 1000000000.0,
#   'name': 'Achain',
#   'percent_change_1h': 5.76,
#   'percent_change_24h': 22.6,
#   'percent_change_7d': 17.18,
#   'price_btc': 5.204e-05,
#   'price_usd': 0.451399,
#   'rank': 118,
#   'symbol': 'ACT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 6663760.0,
#   'available_supply': 6895434080.0,
#   'id': 'digitalnote',
#   'last_updated': 1518199743,
#   'market_cap_usd': 133907951.0,
#   'max_supply': None,
#   'name': 'DigitalNote',
#   'percent_change_1h': 5.63,
#   'percent_change_24h': 14.95,
#   'percent_change_7d': 3.68,
#   'price_btc': 2.24e-06,
#   'price_usd': 0.0194198,
#   'rank': 119,
#   'symbol': 'XDN',
#   'total_supply': 6895434080.0},
#  {'24h_volume_usd': 30805.7,
#   'available_supply': 816061.0,
#   'id': 'supernet-unity',
#   'last_updated': 1518199743,
#   'market_cap_usd': 133709926.0,
#   'max_supply': None,
#   'name': 'SuperNET',
#   'percent_change_1h': 1.94,
#   'percent_change_24h': 13.2,
#   'percent_change_7d': 51.55,
#   'price_btc': 0.0188889,
#   'price_usd': 163.848,
#   'rank': 120,
#   'symbol': 'UNITY',
#   'total_supply': 816061.0},
# ...
#   'max_supply': None,
#   'name': 'Triangles',
#   'percent_change_1h': 3.33,
#   'percent_change_24h': -12.78,
#   'percent_change_7d': 1.79,
#   'price_btc': 0.00110784,
#   'price_usd': 9.60972,
#   'rank': 960,
#   'symbol': 'TRI',
#   'total_supply': 104747.0},
#  {'24h_volume_usd': 379.95,
#   'available_supply': 2136604462.0,
#   'id': 'bigup',
#   'last_updated': 1518199747,
#   'market_cap_usd': 971525.0,
#   'max_supply': None,
#   'name': 'BigUp',
#   'percent_change_1h': 3.17,
#   'percent_change_24h': 2.19,
#   'percent_change_7d': 14.71,
#   'price_btc': 5e-08,
#   'price_usd': 0.000454705,
#   'rank': 961,
#   'symbol': 'BIGUP',
#   'total_supply': 2136604462.0},
#  {'24h_volume_usd': None,
#   'available_supply': 445371.0,
#   'id': 'nimfamoney',
#   'last_updated': 1518198259,
#   'market_cap_usd': 969978.0,
#   'max_supply': None,
#   'name': 'Nimfamoney',
#   'percent_change_1h': 1.69,
#   'percent_change_24h': -1.33,
#   'percent_change_7d': -34.75,
#   'price_btc': 0.00025302,
#   'price_usd': 2.17791,
#   'rank': 962,
#   'symbol': 'NIMFA',
#   'total_supply': 1542580.0},
#  {'24h_volume_usd': 50.8966,
#   'available_supply': 24101381.0,
#   'id': 'gaia',
#   'last_updated': 1518199743,
#   'market_cap_usd': 961686.0,
#   'max_supply': None,
#   'name': 'GAIA',
#   'percent_change_1h': 3.33,
#   'percent_change_24h': 2.3,
#   'percent_change_7d': 12.59,
#   'price_btc': 4.6e-06,
#   'price_usd': 0.0399017,
#   'rank': 963,
#   'symbol': 'GAIA',
#   'total_supply': 24101381.0},
#  {'24h_volume_usd': 26.4357,
#   'available_supply': 8035193.0,
#   'id': 'woodcoin',
#   'last_updated': 1518199744,
#   'market_cap_usd': 947221.0,
#   'max_supply': None,
#   'name': 'Woodcoin',
#   'percent_change_1h': 3.33,
#   'percent_change_24h': -12.94,
#   'percent_change_7d': 0.75,
#   'price_btc': 1.359e-05,
#   'price_usd': 0.117884,
#   'rank': 964,
#   'symbol': 'LOG',
#   'total_supply': 8035193.0},
#  {'24h_volume_usd': 306.795,
#   'available_supply': 64151405.0,
#   'id': 'hobonickels',
#   'last_updated': 1518199741,
#   'market_cap_usd': 940428.0,
#   'max_supply': 120000000.0,
#   'name': 'HoboNickels',
#   'percent_change_1h': 3.33,
#   'percent_change_24h': 9.9,
#   'percent_change_7d': -14.7,
#   'price_btc': 1.69e-06,
#   'price_usd': 0.0146595,
#   'rank': 965,
#   'symbol': 'HBN',
#   'total_supply': 64151405.0},
#  {'24h_volume_usd': 44.1989,
#   'available_supply': 23079737.0,
#   'id': 'bitstar',
#   'last_updated': 1518199743,
#   'market_cap_usd': 934515.0,
#   'max_supply': None,
#   'name': 'Bitstar',
#   'percent_change_1h': 1.1,
#   'percent_change_24h': 3.61,
#   'percent_change_7d': -11.21,
#   'price_btc': 4.67e-06,
#   'price_usd': 0.0404907,
#   'rank': 966,
#   'symbol': 'BITS',
#   'total_supply': 23079737.0},
#  {'24h_volume_usd': 249.612,
#   'available_supply': 1.0,
#   'id': 'bit20',
#   'last_updated': 1518199752,
#   'market_cap_usd': 925288.0,
#   'max_supply': None,
#   'name': 'Bit20',
#   'percent_change_1h': 3.06,
#   'percent_change_24h': 9.37,
#   'percent_change_7d': 2.33,
#   'price_btc': 104.99,
#   'price_usd': 910717.0,
#   'rank': 967,
#   'symbol': 'BTWTY',
#   'total_supply': 1.0},
#  {'24h_volume_usd': 270.679,
#   'available_supply': 318929301.0,
#   'id': 'nyancoin',
#   'last_updated': 1518199741,
#   'market_cap_usd': 908288.0,
#   'max_supply': 337000000.0,
#   'name': 'Nyancoin',
#   'percent_change_1h': 8.89,
#   'percent_change_24h': 8.71,
#   'percent_change_7d': 0.55,
#   'price_btc': 3.3e-07,
#   'price_usd': 0.00284793,
#   'rank': 968,
#   'symbol': 'NYAN',
#   'total_supply': 318929301.0},
#  {'24h_volume_usd': 478.744,
#   'available_supply': 75000000.0,
#   'id': 'bitpark-coin',
#   'last_updated': 1518199749,
#   'market_cap_usd': 883410.0,
#   'max_supply': None,
#   'name': 'Bitpark Coin',
#   'percent_change_1h': 3.17,
#   'percent_change_24h': 24.95,
#   'percent_change_7d': -32.5,
#   'price_btc': 1.36e-06,
#   'price_usd': 0.0117788,
#   'rank': 969,
#   'symbol': 'BPC',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 160.748,
#   'available_supply': 10291781.0,
#   'id': 'bankcoin',
#   'last_updated': 1518199750,
#   'market_cap_usd': 880329.0,
#   'max_supply': None,
#   'name': 'Bankcoin',
#   'percent_change_1h': 91.55,
#   'percent_change_24h': 194.55,
#   'percent_change_7d': 66.75,
#   'price_btc': 9.86e-06,
#   'price_usd': 0.0855371,
#   'rank': 970,
#   'symbol': 'B@',
#   'total_supply': 25000000.0},
#  {'24h_volume_usd': 444.458,
#   'available_supply': 50936480.0,
#   'id': 'visio',
#   'last_updated': 1518199749,
#   'market_cap_usd': 839545.0,
#   'max_supply': None,
#   'name': 'Visio',
#   'percent_change_1h': 3.39,
#   'percent_change_24h': -6.85,
#   'percent_change_7d': -16.96,
#   'price_btc': 1.9e-06,
#   'price_usd': 0.0164822,
#   'rank': 971,
#   'symbol': 'VISIO',
#   'total_supply': 62936480.0},
#  {'24h_volume_usd': 326.806,
#   'available_supply': 65290635.0,
#   'id': 'btctalkcoin',
#   'last_updated': 1518199742,
#   'market_cap_usd': 821206.0,
#   'max_supply': None,
#   'name': 'BTCtalkcoin',
#   'percent_change_1h': 3.33,
#   'percent_change_24h': 8.18,
#   'percent_change_7d': 12.15,
#   'price_btc': 1.45e-06,
#   'price_usd': 0.0125777,
#   'rank': 972,
#   'symbol': 'TALK',
#   'total_supply': 65290635.0},
#  {'24h_volume_usd': 200.839,
#   'available_supply': 9503724.0,
#   'id': 'wavesgo',
#   'last_updated': 1518199750,
#   'market_cap_usd': 819488.0,
#   'max_supply': None,
#   'name': 'WavesGo',
#   'percent_change_1h': 3.35,
#   'percent_change_24h': 11.69,
#   'percent_change_7d': -8.55,
#   'price_btc': 9.94e-06,
#   'price_usd': 0.0862281,
#   'rank': 973,
#   'symbol': 'WGO',
#   'total_supply': 9503724.0},
#  {'24h_volume_usd': None,
#   'available_supply': 23020335.0,
#   'id': 'janus',
#   'last_updated': 1517536153,
#   'market_cap_usd': 744390.0,
#   'max_supply': None,
#   'name': 'Janus',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': None,
#   'price_btc': 3.72e-06,
#   'price_usd': 0.0323362,
#   'rank': 974,
#   'symbol': 'JNS',
#   'total_supply': 25201489.0},
#  {'24h_volume_usd': 482.493,
#   'available_supply': 61445805.0,
#   'id': 'maxcoin',
#   'last_updated': 1518199741,
#   'market_cap_usd': 719549.0,
#   'max_supply': None,
#   'name': 'MaxCoin',
#   'percent_change_1h': 3.33,
#   'percent_change_24h': 3.4,
#   'percent_change_7d': 4.81,
#   'price_btc': 1.35e-06,
#   'price_usd': 0.0117103,
#   'rank': 975,
#   'symbol': 'MAX',
#   'total_supply': 61445805.0},
#  {'24h_volume_usd': 4.32916,
#   'available_supply': 1990891.0,
#   'id': 'bitz',
#   'last_updated': 1518199744,
#   'market_cap_usd': 690781.0,
#   'max_supply': None,
#   'name': 'Bitz',
#   'percent_change_1h': 3.33,
#   'percent_change_24h': 51.06,
#   'percent_change_7d': -11.74,
#   'price_btc': 4e-05,
#   'price_usd': 0.346971,
#   'rank': 976,
#   'symbol': 'BITZ',
#   'total_supply': 1990891.0},
#  {'24h_volume_usd': 225.316,
#   'available_supply': 196336.0,
#   'id': 'prototanium',
#   'last_updated': 1518199759,
#   'market_cap_usd': 681230.0,
#   'max_supply': None,
#   'name': 'Prototanium',
#   'percent_change_1h': 3.26,
#   'percent_change_24h': -1.41,
#   'percent_change_7d': -5.35,
#   'price_btc': 0.0004,
#   'price_usd': 3.46971,
#   'rank': 977,
#   'symbol': 'PR',
#   'total_supply': 196336.0},
#  {'24h_volume_usd': 193.131,
#   'available_supply': 353635.0,
#   'id': 'swagbucks',
#   'last_updated': 1518199745,
#   'market_cap_usd': 662496.0,
#   'max_supply': None,
#   'name': 'SwagBucks',
#   'percent_change_1h': 3.49,
#   'percent_change_24h': 5.68,
#   'percent_change_7d': -6.86,
#   'price_btc': 0.00021597,
#   'price_usd': 1.87339,
#   'rank': 978,
#   'symbol': 'BUCKS',
#   'total_supply': 353635.0},
#  {'24h_volume_usd': 208.56,
#   'available_supply': 21268092.0,
#   'id': 'britcoin',
#   'last_updated': 1518199743,
#   'market_cap_usd': 654479.0,
#   'max_supply': None,
#   'name': 'BritCoin',
#   'percent_change_1h': 3.33,
#   'percent_change_24h': 5.97,
#   'percent_change_7d': 8.8,
#   'price_btc': 3.55e-06,
#   'price_usd': 0.0307728,
#   'rank': 979,
#   'symbol': 'BRIT',
#   'total_supply': 21268092.0},
#  {'24h_volume_usd': 391.982,
#   'available_supply': 169198948.0,
#   'id': 'truckcoin',
#   'last_updated': 1518199743,
#   'market_cap_usd': 645780.0,
#   'max_supply': None,
#   'name': 'Truckcoin',
#   'percent_change_1h': 3.26,
#   'percent_change_24h': 19.25,
#   'percent_change_7d': -3.16,
#   'price_btc': 4.4e-07,
#   'price_usd': 0.00381669,
#   'rank': 980,
#   'symbol': 'TRK',
#   'total_supply': 169198948.0},
#  {'24h_volume_usd': 259.167,
#   'available_supply': 18697228.0,
#   'id': 'motocoin',
#   'last_updated': 1518199742,
#   'market_cap_usd': 642254.0,
#   'max_supply': None,
#   'name': 'Motocoin',
#   'percent_change_1h': 3.41,
#   'percent_change_24h': 11.94,
#   'percent_change_7d': -15.81,
#   'price_btc': 3.96e-06,
#   'price_usd': 0.0343502,
#   'rank': 981,
#   'symbol': 'MOTO',
#   'total_supply': 31227858.0},
#  {'24h_volume_usd': 126.453,
#   'available_supply': 107972766.0,
#   'id': 'signatum',
#   'last_updated': 1518199752,
#   'market_cap_usd': 636878.0,
#   'max_supply': None,
#   'name': 'Signatum',
#   'percent_change_1h': 3.33,
#   'percent_change_24h': 8.72,
#   'percent_change_7d': -6.85,
#   'price_btc': 6.8e-07,
#   'price_usd': 0.00589851,
#   'rank': 982,
#   'symbol': 'SIGT',
#   'total_supply': 107972766.0},
#  {'24h_volume_usd': 113.51,
#   'available_supply': 77777777.0,
#   'id': 'ammo-rewards',
#   'last_updated': 1518199751,
#   'market_cap_usd': 613947.0,
#   'max_supply': None,
#   'name': 'Ammo Reloaded',
#   'percent_change_1h': 3.26,
#   'percent_change_24h': 5.69,
#   'percent_change_7d': -10.25,
#   'price_btc': 9.1e-07,
#   'price_usd': 0.0078936,
#   'rank': 983,
#   'symbol': 'AMMO',
#   'total_supply': 77777777.0},
#  {'24h_volume_usd': 3.812,
#   'available_supply': 2358819009.0,
#   'id': 'colossuscoin-v2',
#   'last_updated': 1518199744,
#   'market_cap_usd': 613833.0,
#   'max_supply': None,
#   'name': 'Colossuscoin V2',
#   'percent_change_1h': 3.26,
#   'percent_change_24h': 58.55,
#   'percent_change_7d': 50.23,
#   'price_btc': 3e-08,
#   'price_usd': 0.000260229,
#   'rank': 984,
#   'symbol': 'CV2',
#   'total_supply': 22977351798.0},
#  {'24h_volume_usd': 56.5276,
#   'available_supply': 169598616.0,
#   'id': 'bitcurrency',
#   'last_updated': 1518199748,
#   'market_cap_usd': 603171.0,
#   'max_supply': None,
#   'name': 'Bitcurrency',
#   'percent_change_1h': 3.33,
#   'percent_change_24h': 5.7,
#   'percent_change_7d': -48.19,
#   'price_btc': 4.1e-07,
#   'price_usd': 0.00355646,
#   'rank': 985,
#   'symbol': 'BTCR',
#   'total_supply': 169598616.0},
#  {'24h_volume_usd': 173.986,
#   'available_supply': 9436367.0,
#   'id': 'mineum',
#   'last_updated': 1518199747,
#   'market_cap_usd': 598032.0,
#   'max_supply': None,
#   'name': 'Mineum',
#   'percent_change_1h': 3.07,
#   'percent_change_24h': -11.3,
#   'percent_change_7d': 13.83,
#   'price_btc': 7.31e-06,
#   'price_usd': 0.0633752,
#   'rank': 986,
#   'symbol': 'MNM',
#   'total_supply': 9586367.0},
#  {'24h_volume_usd': 401.053,
#   'available_supply': 868095.0,
#   'id': 'litebar',
#   'last_updated': 1518199743,
#   'market_cap_usd': 594803.0,
#   'max_supply': None,
#   'name': 'LiteBar',
#   'percent_change_1h': 3.25,
#   'percent_change_24h': 5.28,
#   'percent_change_7d': 13.79,
#   'price_btc': 7.899e-05,
#   'price_usd': 0.685182,
#   'rank': 987,
#   'symbol': 'LTB',
#   'total_supply': 868095.0},
#  {'24h_volume_usd': 1.28379,
#   'available_supply': 90421856.0,
#   'id': 'tattoocoin',
#   'last_updated': 1518199749,
#   'market_cap_usd': 580415.0,
#   'max_supply': None,
#   'name': 'Tattoocoin (Standard Edition)',
#   'percent_change_1h': 3.33,
#   'percent_change_24h': 1.33,
#   'percent_change_7d': -2.48,
#   'price_btc': 7.4e-07,
#   'price_usd': 0.00641897,
#   'rank': 988,
#   'symbol': 'TSE',
#   'total_supply': 90421856.0},
#  {'24h_volume_usd': 8.67428,
#   'available_supply': 6097661228.0,
#   'id': 'valorbit',
#   'last_updated': 1518199746,
#   'market_cap_usd': 528929.0,
#   'max_supply': None,
#   'name': 'Valorbit',
#   'percent_change_1h': 3.41,
#   'percent_change_24h': 5.7,
#   'percent_change_7d': 0.15,
#   'price_btc': 1e-08,
#   'price_usd': 8.67429e-05,
#   'rank': 989,
#   'symbol': 'VAL',
#   'total_supply': 922343297661228},
#  {'24h_volume_usd': 87.977,
#   'available_supply': 5428300.0,
#   'id': 'blockpay',
#   'last_updated': 1518199747,
#   'market_cap_usd': 515330.0,
#   'max_supply': None,
#   'name': 'BlockPay',
#   'percent_change_1h': 2.68,
#   'percent_change_24h': 7.03,
#   'percent_change_7d': -24.41,
#   'price_btc': 1.094e-05,
#   'price_usd': 0.094934,
#   'rank': 990,
#   'symbol': 'BLOCKPAY',
#   'total_supply': 98928316.0},
#  {'24h_volume_usd': 292.512,
#   'available_supply': 590751.0,
#   'id': 'zozocoin',
#   'last_updated': 1518199757,
#   'market_cap_usd': 515099.0,
#   'max_supply': 27000000.0,
#   'name': 'ZoZoCoin',
#   'percent_change_1h': 3.8,
#   'percent_change_24h': 6.2,
#   'percent_change_7d': -6.04,
#   'price_btc': 0.00010052,
#   'price_usd': 0.871939,
#   'rank': 991,
#   'symbol': 'ZZC',
#   'total_supply': 7296311.0},
#  {'24h_volume_usd': 364.053,
#   'available_supply': 7089144.0,
#   'id': 'sativacoin',
#   'last_updated': 1518199744,
#   'market_cap_usd': 501884.0,
#   'max_supply': None,
#   'name': 'Sativacoin',
#   'percent_change_1h': 5.45,
#   'percent_change_24h': 5.72,
#   'percent_change_7d': -1.12,
#   'price_btc': 8.16e-06,
#   'price_usd': 0.0707962,
#   'rank': 992,
#   'symbol': 'STV',
#   'total_supply': 7089144.0},
#  {'24h_volume_usd': 15.9985,
#   'available_supply': 21948.0,
#   'id': 'bitsilver',
#   'last_updated': 1518199744,
#   'market_cap_usd': 501591.0,
#   'max_supply': None,
#   'name': 'bitSilver',
#   'percent_change_1h': 1.63,
#   'percent_change_24h': 25.66,
#   'percent_change_7d': 22.07,
#   'price_btc': 0.00263465,
#   'price_usd': 22.8537,
#   'rank': 993,
#   'symbol': 'BITSILVER',
#   'total_supply': 21948.0},
#  {'24h_volume_usd': 236.188,
#   'available_supply': 43536800.0,
#   'id': 'tigercoin',
#   'last_updated': 1518199741,
#   'market_cap_usd': 498501.0,
#   'max_supply': None,
#   'name': 'Tigercoin',
#   'percent_change_1h': 3.33,
#   'percent_change_24h': 6.48,
#   'percent_change_7d': -23.83,
#   'price_btc': 1.32e-06,
#   'price_usd': 0.0114501,
#   'rank': 994,
#   'symbol': 'TGC',
#   'total_supply': 43536800.0},
#  {'24h_volume_usd': 34.4035,
#   'available_supply': 65171010.0,
#   'id': 'globalcoin',
#   'last_updated': 1518199741,
#   'market_cap_usd': 497474.0,
#   'max_supply': None,
#   'name': 'GlobalCoin',
#   'percent_change_1h': 3.33,
#   'percent_change_24h': 34.15,
#   'percent_change_7d': -1.04,
#   'price_btc': 8.8e-07,
#   'price_usd': 0.00763337,
#   'rank': 995,
#   'symbol': 'GLC',
#   'total_supply': 65171010.0},
#  {'24h_volume_usd': 180.75,
#   'available_supply': 210806.0,
#   'id': 'flycoin',
#   'last_updated': 1518199745,
#   'market_cap_usd': 493736.0,
#   'max_supply': None,
#   'name': 'Flycoin',
#   'percent_change_1h': -10.12,
#   'percent_change_24h': 7.57,
#   'percent_change_7d': -22.69,
#   'price_btc': 0.00027001,
#   'price_usd': 2.34214,
#   'rank': 996,
#   'symbol': 'FLY',
#   'total_supply': 210806.0},
#  {'24h_volume_usd': 30.5661,
#   'available_supply': 43699481.0,
#   'id': 'ambercoin',
#   'last_updated': 1518199744,
#   'market_cap_usd': 470036.0,
#   'max_supply': None,
#   'name': 'AmberCoin',
#   'percent_change_1h': 49.11,
#   'percent_change_24h': -1.46,
#   'percent_change_7d': -38.31,
#   'price_btc': 1.24e-06,
#   'price_usd': 0.0107561,
#   'rank': 997,
#   'symbol': 'AMBER',
#   'total_supply': 43699481.0},
#  {'24h_volume_usd': 343.231,
#   'available_supply': 73729962.0,
#   'id': 'chronos',
#   'last_updated': 1518199747,
#   'market_cap_usd': 452507.0,
#   'max_supply': None,
#   'name': 'Chronos',
#   'percent_change_1h': -4.64,
#   'percent_change_24h': 7.68,
#   'percent_change_7d': -19.93,
#   'price_btc': 7.1e-07,
#   'price_usd': 0.00613736,
#   'rank': 998,
#   'symbol': 'CRX',
#   'total_supply': 73729962.0},
#  {'24h_volume_usd': 22.618,
#   'available_supply': 3052070.0,
#   'id': 'joincoin',
#   'last_updated': 1518199743,
#   'market_cap_usd': 450333.0,
#   'max_supply': None,
#   'name': 'Joincoin',
#   'percent_change_1h': 3.33,
#   'percent_change_24h': 8.9,
#   'percent_change_7d': -2.27,
#   'price_btc': 1.701e-05,
#   'price_usd': 0.14755,
#   'rank': 999,
#   'symbol': 'J',
#   'total_supply': 3052070.0},
#  {'24h_volume_usd': 409.392,
#   'available_supply': 12481553.0,
#   'id': 'gapcoin',
#   'last_updated': 1518199744,
#   'market_cap_usd': 442818.0,
#   'max_supply': None,
#   'name': 'Gapcoin',
#   'percent_change_1h': 3.33,
#   'percent_change_24h': 3.16,
#   'percent_change_7d': -1.16,
#   'price_btc': 4.09e-06,
#   'price_usd': 0.0354778,
#   'rank': 1000,
#   'symbol': 'GAP',
#   'total_supply': 12481553.0},
#  ...]

# %% [markdown]
# You can pass a currency through symbol or coin slug:

# %%
data_from_symbol = cmc.ticker("BTC")
data_from_slug = cmc.ticker("bitcoin")

data_from_slug
# Out:
# {'24h_volume_usd': 8318950000.0,
#  'available_supply': 16855037.0,
#  'id': 'bitcoin',
#  'last_updated': 1518199767,
#  'market_cap_usd': 146298013052,
#  'max_supply': 21000000.0,
#  'name': 'Bitcoin',
#  'percent_change_1h': 2.88,
#  'percent_change_24h': 5.73,
#  'percent_change_7d': 0.12,
#  'price_btc': 1.0,
#  'price_usd': 8679.78,
#  'rank': 1,
#  'symbol': 'BTC',
#  'total_supply': 16855037.0}

# %% [markdown]
# To get all symbols and slugs you can use the next attributes:

# %%
all_symbols = cmc.symbols
all_slugs = cmc.coins

all_symbols
# Out:
# ['ADT',
#  'PULSE',
#  'STORM',
#  'BLC',
#  'BLRY',
#  'SSC',
#  'FRN',
#  'SPHTX',
#  'CANN',
#  'DBG',
#  'PROC',
#  'GOLOS',
#  'XPTX',
#  'MAX',
#  'CRT',
#  'OX',
#  'ETT',
#  'CRAVE',
#  'SGR',
#  'SUB',
#  'PCOIN',
#  'EVIL',
#  'DLT',
#  'ION',
#  'HLC',
#  'STRC',
#  'IND',
#  'OAX',
#  'BITEUR',
#  'AEON',
#  'XLC',
#  'P7C',
#  'HIGH',
#  'AXP',
#  'CRED',
#  'CHESS',
#  'BTCA',
#  'SCRT',
#  'TAAS',
#  'NETKO',
#  'HYTV',
#  'STAR',
#  'METAL',
#  'XOC',
#  'VAL',
#  'TIT',
#  'SNC',
#  'BXT',
#  'FCT',
#  'PRE',
#  'XID',
#  'RNT',
#  'PURA',
#  'DXT',
#  'SANDG',
#  'BIOB',
#  'VEE',
#  'SBC',
#  'ZBC',
#  'WTC',
#  'SPEX',
#  'LEV',
#  'NOBL',
#  'IPY',
#  'FLASH',
#  'TOA',
#  'BCH',
#  'SUMO',
#  'MEN',
#  'ACC',
#  'TOPC',
#  'MCO',
#  'ALL',
#  'PART',
#  'BELA',
#  'HMQ',
#  'GBC',
#  'ASN',
#  'SEQ',
#  'WOMEN',
#  'QTL',
#  'ACN',
#  'WINK',
#  'ESP',
#  'TEAM',
#  'BLUE',
#  'ERC20',
#  'CXT',
#  'ATN',
#  'FRST',
#  'OBITS',
#  'MINEX',
#  'SNT',
#  'AVT',
#  'GP',
#  'DGD',
#  'GRLC',
#  'EXP',
#  'HERO',
#  'CYP',
#  'JNS',
#  'CMPCO',
#  'DRM',
#  'SIC',
#  'MTLMC3',
#  'BTC2X',
#  'TSE',
#  'CAT',
#  'GAT',
#  'FDX',
#  'MTNC',
#  'LDCN',
#  'HGT',
#  'CHAN',
#  'BTB',
#  'HKN',
#  'OCL',
#  'PLBT',
#  'IFLT',
#  'SSS',
#  'DDD',
#  'SMC',
#  'STEPS',
#  'MANA',
#  'PAYX',
#  'IGNIS',
#  'ECO',
#  'SONG',
#  'LCT',
#  'RDN',
#  'FIL',
#  'HYP',
#  'AMP',
#  'BRX',
#  'HBN',
#  'UNY',
#  'BITOK',
#  'HEAT',
#  'IOST',
#  'JIN',
#  'XIN',
#  'ZSE',
#  'PZM',
#  'BTCZ',
#  'REQ',
#  'FXE',
#  'BTWTY',
#  'NTO',
#  'OXY',
#  'POST',
#  'MNC',
#  'UQC',
#  'DMT',
#  'DCN',
#  'XJO',
#  'SAN',
#  'TES',
#  'XOT',
#  'UAHPAY',
#  'FJC',
#  'DIM',
#  'TZC',
#  'CHIPS',
#  'IDT',
#  'ATM',
#  'POLIS',
#  'DEUS',
#  'SXUT',
#  'RLC',
#  'WOW',
#  'ATMC',
#  'FUTC',
#  'CAN',
#  'BPT',
#  'PIPL',
#  'NLG',
#  'ZSC',
#  'FNC',
#  'XMCC',
#  'ARK',
#  'QRK',
#  'XSPEC',
#  'SPT',
#  'TTC',
#  'SDRN',
#  'STU',
#  'SFE',
#  'HPB',
#  'MGO',
#  'NYC',
#  'SIGMA',
#  'MAR',
#  'DOPE',
#  'DOVU',
#  'BITB',
#  'DRP',
#  'DALC',
#  '8BIT',
#  'ALQO',
#  'XCS',
#  'START',
#  'RADS',
#  'SWM',
#  'XFT',
#  'RYZ',
#  'TNT',
#  'GVT',
#  'MDT',
#  'ENT',
#  'BNT',
#  'STN',
#  'GNT',
#  'AHT',
#  'PHS',
#  'TCR',
#  'ZEPH',
#  'VRM',
#  'YEE',
#  'UNI',
#  'PLU',
#  'BTC',
#  'PASL',
#  'MUE',
#  'GUP',
#  'EBIT',
#  'PEC',
#  'PKT',
#  'SBD',
#  'ELE',
#  'LINX',
#  'RICHX',
#  'CEFS',
#  '$$$',
#  'BSTY',
#  'EAC',
#  'LOC',
#  'SKR',
#  'PASC',
#  'POKE',
#  'ZCL',
#  'MEC',
#  'BET',
#  'SH',
#  'BRO',
#  'MBI',
#  'FUEL',
#  'DON',
#  'PAK',
#  'ECN',
#  'ITNS',
#  'BLOCK',
#  'BENJI',
#  'GSR',
#  'UFR',
#  'EVO',
#  'MIOTA',
#  'IOC',
#  'AWR',
#  'PRO',
#  'HAC',
#  'CRC',
#  'TOK',
#  'NTWK',
#  'BIX',
#  'ING',
#  'FOR',
#  'SLFI',
#  'REBL',
#  'EFL',
#  'CREVA',
#  'VSX',
#  'JIYO',
#  'XWC',
#  'LEA',
#  'WHL',
#  'BAT',
#  'GET',
#  'PUT',
#  'CJ',
#  'ARGUS',
#  'LTCU',
#  'QASH',
#  'LTC',
#  'MER',
#  'ECASH',
#  'PCS',
#  'KICK',
#  'BLITZ',
#  'SKY',
#  'SLG',
#  'PEX',
#  'XHI',
#  'XZC',
#  'RAIN',
#  'RVT',
#  'SC',
#  'RIDE',
#  'ICON',
#  'SOON',
#  'HPC',
#  'DEM',
#  'ADK',
#  'VRC',
#  'SCL',
#  'UNB',
#  'RIYA',
#  'ZEC',
#  'OMNI',
#  'TESLA',
#  'BOLI',
#  'ARC',
#  'LVPS',
#  'BTE',
#  'CESC',
#  'MINT',
#  'TKY',
#  'GTC',
#  'BSR',
#  'ASTRO',
#  'NODC',
#  'EAGLE',
#  'CF',
#  'NEVA',
#  'BCX',
#  'MMXVI',
#  'HUC',
#  'RBIES',
#  'SRC',
#  'HMC',
#  'TODAY',
#  'KAYI',
#  'JS',
#  'WGR',
#  '611',
#  'CFI',
#  'HT',
#  'NOX',
#  'GLS',
#  'BTO',
#  'FLY',
#  'MOAC',
#  'DYN',
#  'DOT',
#  'DMB',
#  'LMC',
#  'TSTR',
#  'KARMA',
#  'AIT',
#  'BXC',
#  'ZRC',
#  'XPM',
#  'BURST',
#  'C2',
#  'XCP',
#  'RISE',
#  'BNB',
#  'MST',
#  'ZNE',
#  'WORM',
#  'CON',
#  'ZAP',
#  'ATL',
#  'UGC',
#  'STEX',
#  'ALTCOM',
#  'BLU',
#  'GRWI',
#  'TGT',
#  'VPRC',
#  'VOX',
#  'KBR',
#  'ALTC',
#  'DAV',
#  'NKA',
#  'UNO',
#  'BNTY',
#  'DNA',
#  'GLC',
#  'PLC',
#  'SHIFT',
#  'LDOGE',
#  'FUCK',
#  'ANI',
#  'ECA',
#  'SPF',
#  'TX',
#  'UGT',
#  'FBL',
#  'ACP',
#  'BIGUP',
#  'ECC',
#  'XDN',
#  'IRL',
#  'VC',
#  'VLC',
#  'KIN',
#  'TRK',
#  'DLC',
#  'NEOS',
#  'LEPEN',
#  'PRM',
#  'ESZ',
#  'FAIR',
#  'BCC',
#  'TRAC',
#  'SWING',
#  'UR',
#  'ZER',
#  'XGR',
#  'EMC2',
#  'MOD',
#  'ABY',
#  'FLIK',
#  'BAY',
#  'QORA',
#  'BON',
#  'BCAP',
#  'ATOM',
#  'BTCM',
#  'XCO',
#  'LINDA',
#  'EXN',
#  'BTQ',
#  'QVT',
#  'XAS',
#  'TCOIN',
#  'MOJO',
#  'MOF',
#  'XCT',
#  'UNITS',
#  'ZEIT',
#  'UNC',
#  'RPC',
#  'DLISK',
#  'AURA',
#  'KRM',
#  'NULS',
#  'WISH',
#  'EXRN',
#  'MDC',
#  'LAZ',
#  'ABC',
#  '42',
#  'GDC',
#  'CLUB',
#  'HTML',
#  'ZMC',
#  'PRIX',
#  'EBST',
#  'TGC',
#  'WRC',
#  'QWARK',
#  'ROC',
#  'LEND',
#  'SWTC',
#  'NLC2',
#  'GCS',
#  'BRIT',
#  'DRXNE',
#  'LIGHT',
#  'PXC',
#  'CNO',
#  'ZLA',
#  'TCT',
#  'DRT',
#  'GAIA',
#  'MYB',
#  'TRI',
#  'REC',
#  'KED',
#  'BAR',
#  'MAG',
#  'DIME',
#  'PTC',
#  'CMP',
#  'PGL',
#  'ELLA',
#  'FST',
#  'TFL',
#  'AGI',
#  'AMMO',
#  'EGC',
#  'CREDO',
#  'UBTC',
#  'PURE',
#  'CHC',
#  'EOS',
#  'CFC',
#  'EGO',
#  'ZNY',
#  'CARBON',
#  'QRL',
#  'UNITY',
#  'REE',
#  'XEL',
#  'MAN',
#  'FAP',
#  'IFT',
#  'SAC',
#  'MONK',
#  'QCN',
#  'TALK',
#  'ITC',
#  'GOLF',
#  'INN',
#  'SMS',
#  'CTIC3',
#  'GOOD',
#  'KDC',
#  'I0C',
#  'TSL',
#  'STAK',
#  'XPY',
#  'DRS',
#  'UTA',
#  'WDC',
#  'OFF',
#  'PLNC',
#  'NAS',
#  'MNX',
#  'FLDC',
#  'CFD',
#  'CRDNC',
#  'BTPL',
#  'XBC',
#  'EGOLD',
#  'XCXT',
#  'EBTC',
#  'NDC',
#  'AC',
#  'PIRL',
#  'DGPT',
#  'DUB',
#  'HYPER',
#  'FLT',
#  'QLC',
#  'ELC',
#  'DICE',
#  'V',
#  'BOS',
#  'RCT',
#  'MTN',
#  'AV',
#  'R',
#  'RUP',
#  'EMC',
#  'BAS',
#  'BRK',
#  'OST',
#  'PING',
#  'AERM',
#  'PXI',
#  'NMS',
#  'NXS',
#  'ARCT',
#  'TEK',
#  'LINK',
#  'SEXC',
#  'JOBS',
#  'XAU',
#  'CAB',
#  'GAME',
#  'CHSB',
#  'XSH',
#  'PFR',
#  'SCS',
#  'XUC',
#  'MDA',
#  'TIX',
#  'XBTC21',
#  'CANDY',
#  'PRA',
#  'PR',
#  'TRIG',
#  'SLS',
#  'VIBE',
#  'HODL',
#  'BIG',
#  'PPP',
#  'BCDN',
#  'DDF',
#  'CYDER',
#  'MSCN',
#  'DUO',
#  'ULA',
#  'PDC',
#  'MUSIC',
#  'HTML5',
#  'COR',
#  'YTN',
#  'NRO',
#  'STARS',
#  'XRP',
#  'HPY',
#  'SOC',
#  'BITSILVER',
#  'BLN',
#  'EKT',
#  'IPC',
#  'XLM',
#  'DIVX',
#  'TRIA',
#  'JNT',
#  'DP',
#  'CACH',
#  'RHFC',
#  'NTC',
#  'WAND',
#  'IMS',
#  'BUB',
#  'FRD',
#  'MEME',
#  'KMD',
#  'VIB',
#  'RBY',
#  'RUPX',
#  'BSTAR',
#  'ELS',
#  'INS',
#  'WCT',
#  'JET',
#  'VIVO',
#  'BTG',
#  'ANT',
#  'NXC',
#  'CNX',
#  'GBX',
#  'PPT',
#  'EVX',
#  'PCN',
#  'ISL',
#  'EPY',
#  'XAUR',
#  'BCN',
#  'CRX',
#  'STEEM',
#  'COUPE',
#  'CCT',
#  'FFC',
#  'BTX',
#  'GAP',
#  'J',
#  'DTB',
#  'DGC',
#  'ROOFS',
#  'WAY',
#  'HC',
#  'XTZ',
#  'MGC',
#  'ELF',
#  'CV2',
#  'APC',
#  'PXS',
#  'EMD',
#  'ART',
#  'ATB',
#  'GMT',
#  'KB3',
#  'ELTC2',
#  'CWXT',
#  'HVN',
#  'OPT',
#  'GLT',
#  'IDH',
#  'BRAIN',
#  'GOD',
#  'TKN',
#  'ICE',
#  'CRB',
#  'CDX',
#  'PPC',
#  'ETHOS',
#  'PIZZA',
#  'IBANK',
#  'VLTC',
#  'YAC',
#  'FLAX',
#  'TERA',
#  'MND',
#  'XCRE',
#  'SPANK',
#  'KLN',
#  'BYC',
#  'CAPP',
#  'LNK',
#  'KCASH',
#  'MED',
#  'AGRS',
#  'PRC',
#  'EL',
#  'BOAT',
#  'KRB',
#  'SOCC',
#  'XMRG',
#  'LOG',
#  'IETH',
#  'XRE',
#  'DAR',
#  'XP',
#  'AIB',
#  'OP',
#  'B2X',
#  'CMT',
#  'YES',
#  'FRK',
#  'BDL',
#  'DBC',
#  'BPC',
#  'JINN',
#  'IQT',
#  'INCNT',
#  'PRN',
#  'LKK',
#  'RPX',
#  'AUR',
#  'CPC',
#  'XMR',
#  'PLX',
#  'MTL',
#  'TOPAZ',
#  'MNM',
#  'BBP',
#  'MONA',
#  'XBY',
#  'ZENGOLD',
#  'DSR',
#  'SPK',
#  'AI',
#  'NUMUS',
#  'RCN',
#  'BITGOLD',
#  'SHND',
#  'YOYOW',
#  'CCRB',
#  'XCPO',
#  'ANC',
#  'FC',
#  'MOTO',
#  'BPL',
#  'HOLD',
#  'XMG',
#  'VEC2',
#  'NVST',
#  'CLAM',
#  'ETN',
#  'FID',
#  '888',
#  'IBTC',
#  'CHEAP',
#  'ZIL',
#  'DAT',
#  'BUMBA',
#  'THS',
#  'TAJ',
#  'ETG',
#  'MCRN',
#  'RBT',
#  'XST',
#  'NKC',
#  'PRS',
#  'TCC',
#  'ADL',
#  'GAY',
#  'ADB',
#  'UIS',
#  'PEPECASH',
#  'DENT',
#  'ICOS',
#  'EBT',
#  'INF',
#  'BIS',
#  'WAVES',
#  'TKR',
#  'BLOCKPAY',
#  'AMM',
#  'CDT',
#  'ELITE',
#  'GRC',
#  'UTK',
#  'AIX',
#  'DOGE',
#  'VSL',
#  'KORE',
#  'LBTC',
#  'EOT',
#  'ASAFE2',
#  '1337',
#  'HORSE',
#  'CALC',
#  'ORME',
#  'OMC',
#  'MAD',
#  'CME',
#  'MBL',
#  'BWK',
#  'REF',
#  'MZC',
#  'BSD',
#  'XDE2',
#  'SPORT',
#  'XEM',
#  'FLO',
#  'TROLL',
#  'SRN',
#  'MILO',
#  'ADX',
#  'BITCF',
#  'DCT',
#  'SLT',
#  'APW',
#  'FIMK',
#  'PAY',
#  '10MT',
#  'PIVX',
#  'PPY',
#  'ALIS',
#  'BTW',
#  'KNC',
#  'VERI',
#  'BQ',
#  'DAY',
#  'OS76',
#  'UTC',
#  'EGG',
#  'IC',
#  'GBG',
#  'MOIN',
#  'ENG',
#  'ATMS',
#  'KUSH',
#  'MOON',
#  'AIDOC',
#  'GPU',
#  'TRCT',
#  'ALT',
#  'TAG',
#  'RSGP',
#  'TNB',
#  'ACT',
#  'OTX',
#  'EVC',
#  'SXDT',
#  'EAG',
#  'UTT',
#  'XPD',
#  'ETH',
#  'POT',
#  'KEY',
#  'AID',
#  'RUSTBITS',
#  'QUN',
#  'TOP',
#  'BDG',
#  'SYS',
#  'SHA',
#  'MLN',
#  'XVC',
#  'AIR',
#  'FUN',
#  'OCT',
#  'RUNNERS',
#  'MOT',
#  'BLX',
#  'RLT',
#  'SIB',
#  'UNIC',
#  'CCN',
#  'AKY',
#  'EVE',
#  'NBIT',
#  'ORLY',
#  'SCT',
#  'EMV',
#  'ARB',
#  'COSS',
#  'BASH',
#  'ZZC',
#  'QSP',
#  'SWP',
#  'HUSH',
#  'DTR',
#  'OMG',
#  'TAGR',
#  'EXCL',
#  'BIRDS',
#  'SMART',
#  'PX',
#  'ICN',
#  'GCN',
#  'ONION',
#  'GMX',
#  'GBYTE',
#  'BSN',
#  'WSX',
#  'SIGT',
#  'CXO',
#  'SOJ',
#  'POS',
#  'TMC',
#  'STC',
#  'DBIX',
#  'GRID',
#  'OPC',
#  'BTS',
#  'XSTC',
#  'BTDX',
#  'ADST',
#  'SHOW',
#  'PLACO',
#  'CVCOIN',
#  'BTM',
#  'SPACE',
#  'MAID',
#  'GEERT',
#  'STRAT',
#  'INSN',
#  'DNT',
#  'ICOB',
#  'POE',
#  'BITBTC',
#  'BIT',
#  'VIU',
#  'BITUSD',
#  'DFS',
#  'UFO',
#  'DUTCH',
#  'MSD',
#  'SNRG',
#  'BUN',
#  'VOT',
#  'SCORE',
#  'CDN',
#  'DAI',
#  'MYST',
#  'DNR',
#  'SAGA',
#  'XPA',
#  'OTN',
#  'WABI',
#  'VZT',
#  'DRPU',
#  'YOC',
#  'EUSD',
#  'EGAS',
#  'ICOO',
#  'ATX',
#  'EVR',
#  'VISIO',
#  'HONEY',
#  'PRX',
#  'CND',
#  'IFC',
#  'OK',
#  'CPAY',
#  'PRG',
#  'AMS',
#  'PBL',
#  'HMP',
#  'TYCHO',
#  'CREA',
#  'FOTA',
#  'PNX',
#  'TKS',
#  'MCR',
#  'INDIA',
#  'ESC',
#  '300',
#  'WC',
#  'DCRE',
#  'TRC',
#  'TIE',
#  'SND',
#  'FYN',
#  'SUPER',
#  'OCN',
#  'LBC',
#  'HAT',
#  'ZYD',
#  'CCO',
#  'CAG',
#  'AAC',
#  'RED',
#  'CHAT',
#  'SKULL',
#  'KOBO',
#  'ARN',
#  'CRTM',
#  'LSK',
#  'WETH',
#  'GRS',
#  'QBIC',
#  'ACOIN',
#  'BITZ',
#  'MAO',
#  'NVC',
#  'C20',
#  'ONX',
#  'RDD',
#  'ONG',
#  'COAL',
#  ...]

# %% [markdown]
# Other parameters:

# %%
print(cmc.ticker.__doc__)
# Out:
# Get currencies with other aditional data.
#
#         Args:
#             currency (str, optional): Specify a currency to return,
#                 in this case the method returns a dict, otherwise
#                 returns a list. If you dont specify a currency,
#                 returns data for all in coinmarketcap. As default, None.
#             limit (int, optional): Limit amount of coins on response.
#                 if limit == 0, returns all coins in coinmarketcap.
#                 Only works if currency == None. As default 0.
#             start (int, optional): Rank of first currency to retrieve.
#                 The count starts at 0 for the first currency ranked.
#                 Only works if currency == None. As default 0.
#             convert (str, optional): As default, "USD". Allow to
#                 convert price, 24h volume and market cap in terms
#                 of one of next badges:
#                    ["AUD", "BRL", "CAD", "CHF", "CLP", "CNY", "CZK", "DKK",
#                     "EUR", "GBP", "HKD", "HUF", "IDR", "ILS", "INR", "JPY",
#                     "KRW", "MXN", "MYR", "NOK", "NZD", "PHP", "PKR", "PLN",
#                     "RUB", "SEK", "SGD", "THB", "TRY", "TWD", "ZAR"]
#
#         Returns:
#             dict/list: If currency param is provided or not.

# %% [markdown]
# If you want to get the valid badges that can be passed to `convert` param programatically, use this:

# %%
cmc.ticker_badges
# Out:
# ['AUD',
#  'BRL',
#  'CAD',
#  'CHF',
#  'CLP',
#  'CNY',
#  'CZK',
#  'DKK',
#  'EUR',
#  'GBP',
#  'HKD',
#  'HUF',
#  'IDR',
#  'ILS',
#  'INR',
#  'JPY',
#  'KRW',
#  'MXN',
#  'MYR',
#  'NOK',
#  'NZD',
#  'PHP',
#  'PKR',
#  'PLN',
#  'RUB',
#  'SEK',
#  'SGD',
#  'THB',
#  'TRY',
#  'TWD',
#  'ZAR']

# %% [markdown]
# #### `stats()`

# %%
cmc.stats()
# Out:
# {'active_assets': 593,
#  'active_currencies': 888,
#  'active_markets': 8659,
#  'bitcoin_percentage_of_market_cap': 34.54,
#  'last_updated': 1518199767,
#  'total_24h_volume_usd': 24382136999.0,
#  'total_market_cap_usd': 423594245703.0}

# %% [markdown]
# _____________________________________________
#
# ## Web scraper
# #### `markets(currency, [convert="USD"])`
# Get all markets for a exchange in coinmarketcap. You can convert the response fields `"volume_24h"` and `"price"` between `"USD"` and `"BTC"`.

# %%
cmc.markets("BTC", convert="BTC")
# Out:
# [{'pair': 'BTC/USD',
#   'percent_volume': 7.14021601284,
#   'price': 1.00676,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 68477.3},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 5.80939902271,
#   'price': 0.999013,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 55714.3},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0,
#   'price': 0.897456,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 55320.2},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 4.49294682622,
#   'price': 0.998104,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 43088.9},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 3.81839054208,
#   'price': 0.995404,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 36619.7},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 3.25174451103,
#   'price': 1.03971,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 31185.4},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 3.13334014509,
#   'price': 1.00433,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 30049.8},
#  {'pair': 'BTC/USD',
#   'percent_volume': 3.07408987913,
#   'price': 1.00285,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 29481.6},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 2.91190594967,
#   'price': 1.00347,
#   'source': 'bitFlyer',
#   'updated': True,
#   'volume_24h': 27926.2},
#  {'pair': 'BTC/USD',
#   'percent_volume': 2.21115645604,
#   'price': 1.00406,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 21205.8},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 1.6035557372,
#   'price': 1.00775,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 15378.7},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 1.58910679833,
#   'price': 1.03155,
#   'source': 'Bithumb',
#   'updated': True,
#   'volume_24h': 15240.1},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 1.43830651705,
#   'price': 0.997922,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 13793.8},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 1.41107952326,
#   'price': 0.999845,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 13532.7},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 1.25099922466,
#   'price': 0.995162,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 11997.5},
#  {'pair': 'BTC/USD',
#   'percent_volume': 1.16202164937,
#   'price': 1.00347,
#   'source': 'Gemini',
#   'updated': True,
#   'volume_24h': 11144.2},
#  {'pair': 'BTC/USD',
#   'percent_volume': 1.13940821859,
#   'price': 1.00654,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 10927.3},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0,
#   'price': 1.00279,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 10717.8},
#  {'pair': 'HT/BTC',
#   'percent_volume': 1.03332752331,
#   'price': 0.996962,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 9909.99},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.869501559692,
#   'price': 1.00705,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 8338.84},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.868478594053,
#   'price': 0.979896,
#   'source': 'BTCC',
#   'updated': True,
#   'volume_24h': 8329.02},
#  {'pair': 'ICX/BTC',
#   'percent_volume': 0.0,
#   'price': 1.02613,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 8227.62},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.0,
#   'price': 0.944922,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 6502.58},
#  {'pair': 'BLZ/BTC',
#   'percent_volume': 0.0,
#   'price': 0.958234,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 6472.01},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.0,
#   'price': 1.19245,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 6330.83},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.580104460298,
#   'price': 1.00662,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 5563.41},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.547899674839,
#   'price': 1.00526,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 5254.56},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.538180900234,
#   'price': 0.995647,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 5161.34},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.489171109335,
#   'price': 0.997612,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 4691.32},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.473069317642,
#   'price': 1.00375,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 4536.9},
#  {'pair': 'VEN/BTC',
#   'percent_volume': 0.0,
#   'price': 0.994982,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 4387.33},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.449188900041,
#   'price': 0.999917,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 4307.88},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.445956520955,
#   'price': 0.998394,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 4276.89},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.430578378281,
#   'price': 0.997549,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 4129.4},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.421196184615,
#   'price': 0.998532,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 4039.42},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.407970957873,
#   'price': 1.00753,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 3912.59},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.389878530343,
#   'price': 1.00377,
#   'source': 'itBit',
#   'updated': True,
#   'volume_24h': 3739.07},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.375663996057,
#   'price': 0.995982,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 3602.75},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.368521267708,
#   'price': 1.03897,
#   'source': 'Coinone',
#   'updated': True,
#   'volume_24h': 3534.25},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.355871834787,
#   'price': 0.996892,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 3412.94},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0,
#   'price': 1.11617,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 3218.95},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.326572464073,
#   'price': 0.980687,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 3131.95},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.320595748261,
#   'price': 0.99688,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 3074.62},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.315815096857,
#   'price': 0.997463,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 3028.78},
#  {'pair': 'ELA/BTC',
#   'percent_volume': 0.309244556104,
#   'price': 0.996786,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 2965.77},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.299817885671,
#   'price': 0.990601,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 2875.36},
#  {'pair': 'ADA/BTC',
#   'percent_volume': 0.295515660029,
#   'price': 1.02924,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 2834.1},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.292814597996,
#   'price': 1.02025,
#   'source': 'CEX.IO',
#   'updated': True,
#   'volume_24h': 2808.2},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.283256901412,
#   'price': 1.07694,
#   'source': 'LakeBTC',
#   'updated': True,
#   'volume_24h': 2716.54},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.280192812795,
#   'price': 0.996858,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 2687.15},
#  {'pair': 'BNB/BTC',
#   'percent_volume': 0.0,
#   'price': 1.08216,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 2673.89},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.270974101299,
#   'price': 0.99474,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 2598.74},
#  {'pair': 'ADA/BTC',
#   'percent_volume': 0.0,
#   'price': 1.02236,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 2550.15},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.2614981458,
#   'price': 0.998118,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 2507.86},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.259344027792,
#   'price': 1.03632,
#   'source': 'Korbit',
#   'updated': True,
#   'volume_24h': 2487.2},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.257942408597,
#   'price': 0.999917,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 2473.76},
#  {'pair': 'ELF/BTC',
#   'percent_volume': 0.254261655618,
#   'price': 0.999324,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 2438.46},
#  {'pair': 'FUN/BTC',
#   'percent_volume': 0.0,
#   'price': 0.932578,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 2417.35},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.250519596824,
#   'price': 0.997869,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 2402.57},
#  {'pair': 'NANO/BTC',
#   'percent_volume': 0.0,
#   'price': 0.972523,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 2381.65},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0,
#   'price': 1.00288,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 2380.18},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.244149802559,
#   'price': 0.996892,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 2341.48},
#  {'pair': 'TRUE/BTC',
#   'percent_volume': 0.240924635922,
#   'price': 0.997984,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 2310.55},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.240788801471,
#   'price': 0.999728,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 2309.25},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0,
#   'price': 1.06466,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 2300.72},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0,
#   'price': 1.10883,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 2261.91},
#  {'pair': 'DGD/BTC',
#   'percent_volume': 0.0,
#   'price': 0.896079,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 2206.94},
#  {'pair': 'ADA/BTC',
#   'percent_volume': 0.223119504264,
#   'price': 1.02448,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 2139.8},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.206413068957,
#   'price': 0.999023,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 1979.57},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.20499822694,
#   'price': 0.996799,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1966.0},
#  {'pair': 'NBT/BTC',
#   'percent_volume': 0.20485998834,
#   'price': 0.996536,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1964.68},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.204433251793,
#   'price': 0.998995,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 1960.59},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.203775716887,
#   'price': 0.971726,
#   'source': 'CoinsBank',
#   'updated': True,
#   'volume_24h': 1954.28},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.200768125785,
#   'price': 0.993189,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1925.43},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.197069341684,
#   'price': 0.997748,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 1889.97},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.190783692654,
#   'price': 0.988284,
#   'source': 'CoinsBank',
#   'updated': True,
#   'volume_24h': 1829.68},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.181086555395,
#   'price': 1.01027,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1736.68},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.17556422385,
#   'price': 1.0085,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 1683.73},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.0,
#   'price': 1.04247,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 1670.53},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.172450850167,
#   'price': 1.02176,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 1653.86},
#  {'pair': 'SWFTC/BTC',
#   'percent_volume': 0.162562583018,
#   'price': 0.997122,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 1559.03},
#  {'pair': 'CTR/BTC',
#   'percent_volume': 0.0,
#   'price': 0.979652,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 1548.64},
#  {'pair': 'BTC/GBP',
#   'percent_volume': 0.160599594901,
#   'price': 1.00172,
#   'source': 'CoinsBank',
#   'updated': True,
#   'volume_24h': 1540.21},
#  {'pair': 'BTC/BITCNY',
#   'percent_volume': 0.158181020441,
#   'price': 1.05258,
#   'source': 'AEX',
#   'updated': True,
#   'volume_24h': 1517.01},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.156662799993,
#   'price': 1.00137,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1502.45},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.156304581708,
#   'price': 1.02144,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 1499.02},
#  {'pair': 'AE/BTC',
#   'percent_volume': 0.0,
#   'price': 0.944959,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 1488.33},
#  {'pair': 'WTC/BTC',
#   'percent_volume': 0.0,
#   'price': 1.00339,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 1459.8},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.150958955157,
#   'price': 0.993956,
#   'source': 'Coinbene',
#   'updated': True,
#   'volume_24h': 1447.75},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.148063157009,
#   'price': 0.996318,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 1419.98},
#  {'pair': 'BTC/TRY',
#   'percent_volume': 0.146945227463,
#   'price': 0.979369,
#   'source': 'Paribu',
#   'updated': True,
#   'volume_24h': 1409.25},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.145243089573,
#   'price': 1.0171,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1392.93},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.14514692359,
#   'price': 1.00452,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 1392.01},
#  {'pair': 'AIDOC/BTC',
#   'percent_volume': 0.14394004051,
#   'price': 0.994009,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1380.43},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.143664765385,
#   'price': 1.00526,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1377.8},
#  {'pair': 'BTC/PLN',
#   'percent_volume': 0.136999260724,
#   'price': 0.999832,
#   'source': 'BitBay',
#   'updated': True,
#   'volume_24h': 1313.87},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.135655341119,
#   'price': 0.996219,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 1300.98},
#  {'pair': 'EKT/BTC',
#   'percent_volume': 0.134759795407,
#   'price': 0.983661,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 1292.4},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.134472499534,
#   'price': 1.0034,
#   'source': 'Bitbank',
#   'updated': True,
#   'volume_24h': 1289.64},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.133471171242,
#   'price': 1.00526,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 1280.04},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.131312244935,
#   'price': 1.03432,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 1259.34},
#  {'pair': 'IOST/BTC',
#   'percent_volume': 0.0,
#   'price': 1.07437,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 1235.85},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.128267389514,
#   'price': 1.00028,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 1230.13},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.126753977365,
#   'price': 0.992583,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1215.61},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.123879816563,
#   'price': 1.00109,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 1188.05},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.123515587905,
#   'price': 0.990723,
#   'source': 'Liqui',
#   'updated': True,
#   'volume_24h': 1184.56},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.121413159113,
#   'price': 0.991655,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1164.39},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0,
#   'price': 1.21136,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 1142.87},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.115905492881,
#   'price': 0.985168,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 1111.58},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.114790688729,
#   'price': 0.991934,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 1100.88},
#  {'pair': 'EPC/BTC',
#   'percent_volume': 0.111583072383,
#   'price': 0.987886,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 1070.12},
#  {'pair': 'STR/BTC',
#   'percent_volume': 0.109605058331,
#   'price': 1.01598,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 1051.15},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.10929143702,
#   'price': 0.993682,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 1048.14},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.10921185967,
#   'price': 0.995562,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 1047.38},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.10870518515,
#   'price': 1.00248,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 1042.52},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.108340115039,
#   'price': 1.00202,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 1039.02},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.108219186316,
#   'price': 0.993014,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1037.86},
#  {'pair': 'CND/BTC',
#   'percent_volume': 0.0,
#   'price': 0.991408,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 1036.73},
#  {'pair': 'WAVES/BTC',
#   'percent_volume': 0.108026012898,
#   'price': 1.00029,
#   'source': 'Tidex',
#   'updated': True,
#   'volume_24h': 1036.01},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.106899428413,
#   'price': 0.99329,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 1025.2},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.105883675223,
#   'price': 1.00995,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 1015.46},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.104973103577,
#   'price': 0.994977,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 1006.73},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.101645520168,
#   'price': 0.999865,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 974.817},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.101435998533,
#   'price': 0.997217,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 972.807},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.0992575986152,
#   'price': 1.0171,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 951.916},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0990531256949,
#   'price': 1.0002,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 949.955},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0976071499408,
#   'price': 0.995726,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 936.088},
#  {'pair': 'MTL/BTC',
#   'percent_volume': 0.0,
#   'price': 0.970498,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 914.385},
#  {'pair': 'IOTA/BTC',
#   'percent_volume': 0.0,
#   'price': 1.07129,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 913.959},
#  {'pair': 'IGNIS/BTC',
#   'percent_volume': 0.094662787972,
#   'price': 1.00199,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 907.85},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0941049050661,
#   'price': 0.999759,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 902.5},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0936511218363,
#   'price': 0.998269,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 898.147},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0934760997482,
#   'price': 0.999508,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 896.469},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0932228225918,
#   'price': 0.995303,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 894.04},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0929461049772,
#   'price': 1.00068,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 891.387},
#  {'pair': 'BTC/RUB',
#   'percent_volume': 0.0928222912747,
#   'price': 0.949945,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 890.199},
#  {'pair': 'XVG/BTC',
#   'percent_volume': 0.0,
#   'price': 1.02517,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 889.324},
#  {'pair': 'QSP/BTC',
#   'percent_volume': 0.0,
#   'price': 1.01137,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 872.231},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0907169775032,
#   'price': 1.00684,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 870.008},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.090265117593,
#   'price': 0.998682,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 865.674},
#  {'pair': 'BTC/BRL',
#   'percent_volume': 0.0874356739733,
#   'price': 1.00081,
#   'source': 'Negocie Coins',
#   'updated': True,
#   'volume_24h': 838.539},
#  {'pair': 'INS/BTC',
#   'percent_volume': 0.0,
#   'price': 1.01676,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 837.187},
#  {'pair': 'SC/BTC',
#   'percent_volume': 0.0862293919305,
#   'price': 0.998982,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 826.971},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.0851843081158,
#   'price': 0.970562,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 816.948},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0847278803214,
#   'price': 0.996343,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 812.571},
#  {'pair': 'BTC/ZAR',
#   'percent_volume': 0.0844599378527,
#   'price': 1.03251,
#   'source': 'Luno',
#   'updated': True,
#   'volume_24h': 810.001},
#  {'pair': 'ARDR/BTC',
#   'percent_volume': 0.0840993154184,
#   'price': 1.00603,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 806.542},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0840078375276,
#   'price': 1.00996,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 805.665},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0840007452864,
#   'price': 0.994285,
#   'source': 'Neraex',
#   'updated': True,
#   'volume_24h': 805.597},
#  {'pair': 'MIOTA/BTC',
#   'percent_volume': 0.0837907428221,
#   'price': 1.00214,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 803.583},
#  {'pair': 'RUFF/BTC',
#   'percent_volume': 0.0837769189621,
#   'price': 0.957318,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 803.45},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0832892372234,
#   'price': 0.995827,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 798.773},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0817262995931,
#   'price': 1.00468,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 783.784},
#  {'pair': 'STK/BTC',
#   'percent_volume': 0.0811057885911,
#   'price': 0.995384,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 777.834},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0,
#   'price': 1.29192,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 776.515},
#  {'pair': 'ARDR/BTC',
#   'percent_volume': 0.080189326778,
#   'price': 1.00216,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 769.044},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0799975958504,
#   'price': 0.995718,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 767.206},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0794286538566,
#   'price': 0.997963,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 761.749},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0,
#   'price': 0.956246,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 750.756},
#  {'pair': 'PROPY/BTC',
#   'percent_volume': 0.0775498109737,
#   'price': 0.997808,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 743.73},
#  {'pair': 'XVG/BTC',
#   'percent_volume': 0.0771142992806,
#   'price': 0.9973,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 739.554},
#  {'pair': 'SC/BTC',
#   'percent_volume': 0.0770793189044,
#   'price': 0.998982,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 739.219},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0769740171536,
#   'price': 0.999257,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 738.208},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0767195379225,
#   'price': 1.00334,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 735.768},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0760457750077,
#   'price': 1.00165,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 729.306},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.075928692924,
#   'price': 0.992631,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 728.184},
#  {'pair': 'IOST/BTC',
#   'percent_volume': 0.0751748718288,
#   'price': 0.997073,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 720.954},
#  {'pair': 'INS/BTC',
#   'percent_volume': 0.0743809014359,
#   'price': 0.999733,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 713.339},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0740694438601,
#   'price': 0.999287,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 710.353},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0736418658605,
#   'price': 0.998427,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 706.252},
#  {'pair': 'RUFF/BTC',
#   'percent_volume': 0.0731925303073,
#   'price': 0.999012,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 701.942},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.0719611249016,
#   'price': 1.01155,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 690.133},
#  {'pair': 'BTC/AUD',
#   'percent_volume': 0.0718856346053,
#   'price': 0.992233,
#   'source': 'BTC Markets',
#   'updated': True,
#   'volume_24h': 689.409},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0714486804224,
#   'price': 0.98089,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 685.219},
#  {'pair': 'BTC/IDR',
#   'percent_volume': 0.0713674201672,
#   'price': 0.996339,
#   'source': 'Bitcoin Indonesia',
#   'updated': True,
#   'volume_24h': 684.44},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0712860397045,
#   'price': 0.995924,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 683.659},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.070877093864,
#   'price': 0.99679,
#   'source': 'Tidex',
#   'updated': True,
#   'volume_24h': 679.737},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0707988387958,
#   'price': 1.00998,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 678.986},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0700660540092,
#   'price': 1.00101,
#   'source': 'Gate.io',
#   'updated': True,
#   'volume_24h': 671.959},
#  {'pair': 'IGNIS/BTC',
#   'percent_volume': 0.0690486179145,
#   'price': 0.999324,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 662.201},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0679443920206,
#   'price': 1.00578,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 651.611},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0677382361957,
#   'price': 0.998009,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 649.634},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0675979540687,
#   'price': 0.993856,
#   'source': 'bitFlyer',
#   'updated': True,
#   'volume_24h': 648.289},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.0675443415335,
#   'price': 0.995248,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 647.774},
#  {'pair': 'MDS/BTC',
#   'percent_volume': 0.0673839847577,
#   'price': 0.996575,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 646.237},
#  {'pair': 'BRD/BTC',
#   'percent_volume': 0.0,
#   'price': 1.03336,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 642.48},
#  {'pair': 'PPT/BTC',
#   'percent_volume': 0.0,
#   'price': 0.92356,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 635.969},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0661725337933,
#   'price': 1.08407,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 634.618},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0659746722844,
#   'price': 1.01221,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 632.72},
#  {'pair': 'ZIL/BTC',
#   'percent_volume': 0.0649692569375,
#   'price': 0.996914,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 623.079},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0647098491997,
#   'price': 1.00708,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 620.591},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0645445639173,
#   'price': 0.99485,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 619.006},
#  {'pair': 'LET/BTC',
#   'percent_volume': 0.0642624369662,
#   'price': 0.997538,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 616.3},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0640036302658,
#   'price': 0.935787,
#   'source': 'CoolCoin',
#   'updated': True,
#   'volume_24h': 613.818},
#  {'pair': 'BCN/BTC',
#   'percent_volume': 0.0639465317137,
#   'price': 1.00449,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 613.27},
#  {'pair': 'BTC/GBP',
#   'percent_volume': 0.063469909063,
#   'price': 1.00512,
#   'source': 'Coinfloor',
#   'updated': True,
#   'volume_24h': 608.699},
#  {'pair': 'POWR/BTC',
#   'percent_volume': 0.0,
#   'price': 1.02419,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 604.889},
#  {'pair': 'BTC/CAD',
#   'percent_volume': 0.0623314240379,
#   'price': 1.01651,
#   'source': 'Coinsquare',
#   'updated': True,
#   'volume_24h': 597.78},
#  {'pair': 'POE/BTC',
#   'percent_volume': 0.0,
#   'price': 1.10577,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 597.68},
#  {'pair': 'THETA/BTC',
#   'percent_volume': 0.0622150631991,
#   'price': 0.996927,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 596.665},
#  {'pair': 'ZRX/BTC',
#   'percent_volume': 0.0,
#   'price': 1.01572,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 595.246},
#  {'pair': 'QBT/BTC',
#   'percent_volume': 0.0620349923969,
#   'price': 1.01953,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 594.937},
#  {'pair': 'JNT/BTC',
#   'percent_volume': 0.0617499804663,
#   'price': 0.993008,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 592.204},
#  {'pair': 'BTS/BTC',
#   'percent_volume': 0.0,
#   'price': 1.06636,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 587.611},
#  {'pair': 'OC/BTC',
#   'percent_volume': 0.0606070477644,
#   'price': 0.977585,
#   'source': 'Allcoin',
#   'updated': True,
#   'volume_24h': 581.243},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0604178411939,
#   'price': 1.00279,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 579.429},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.0601117929546,
#   'price': 0.970628,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 576.494},
#  {'pair': 'ICX/BTC',
#   'percent_volume': 0.0592762307743,
#   'price': 0.995629,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 568.48},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0591935280294,
#   'price': 1.01474,
#   'source': 'GetBTC',
#   'updated': True,
#   'volume_24h': 567.687},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0591329434604,
#   'price': 1.0137,
#   'source': 'GetBTC',
#   'updated': True,
#   'volume_24h': 567.106},
#  {'pair': 'BTC/GBP',
#   'percent_volume': 0.0590575733716,
#   'price': 1.00965,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 566.384},
#  {'pair': 'BQX/BTC',
#   'percent_volume': 0.0,
#   'price': 1.07766,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 565.733},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0589302736523,
#   'price': 0.995847,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 565.162},
#  {'pair': 'VIBE/BTC',
#   'percent_volume': 0.0,
#   'price': 0.988378,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 560.52},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0578811027834,
#   'price': 0.994524,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 555.1},
#  {'pair': 'BTC/CAD',
#   'percent_volume': 0.0575108637508,
#   'price': 0.951456,
#   'source': 'QuadrigaCX',
#   'updated': True,
#   'volume_24h': 551.549},
#  {'pair': 'XVG/BTC',
#   'percent_volume': 0.0569083838706,
#   'price': 0.995795,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 545.772},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0566829948491,
#   'price': 1.00135,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 543.61},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0566007729341,
#   'price': 1.00273,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 542.822},
#  {'pair': 'SRN/BTC',
#   'percent_volume': 0.0564460659098,
#   'price': 1.02005,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 541.338},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0559628318478,
#   'price': 0.993493,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 536.703},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0,
#   'price': 1.18508,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 534.487},
#  {'pair': 'BTC/BRL',
#   'percent_volume': 0.0547280606327,
#   'price': 1.00677,
#   'source': 'Foxbit',
#   'updated': True,
#   'volume_24h': 524.862},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0544441305694,
#   'price': 1.00151,
#   'source': 'xBTCe',
#   'updated': True,
#   'volume_24h': 522.138},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0540595868469,
#   'price': 1.00024,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 518.451},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0539209876246,
#   'price': 1.00234,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 517.122},
#  {'pair': 'WAVES/BTC',
#   'percent_volume': 0.0538535512294,
#   'price': 1.0126,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 516.475},
#  {'pair': 'VEN/BTC',
#   'percent_volume': 0.0537933272829,
#   'price': 0.998665,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 515.898},
#  {'pair': 'ADX/BTC',
#   'percent_volume': 0.0,
#   'price': 1.01954,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 514.43},
#  {'pair': 'ZCL/BTC',
#   'percent_volume': 0.053378010446,
#   'price': 0.988973,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 511.914},
#  {'pair': 'BTC/ETH',
#   'percent_volume': 0.0525089103793,
#   'price': 1.03045,
#   'source': 'Mr. Exchange',
#   'updated': True,
#   'volume_24h': 503.579},
#  {'pair': 'FCT/BTC',
#   'percent_volume': 0.0524566201263,
#   'price': 0.98921,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 503.078},
#  {'pair': 'DTA/BTC',
#   'percent_volume': 0.0522868871673,
#   'price': 1.00274,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 501.451},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0520415437044,
#   'price': 0.998124,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 499.097},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0510797636721,
#   'price': 1.00766,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 489.873},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0507062790376,
#   'price': 1.0019,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 486.291},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0506234560852,
#   'price': 1.00204,
#   'source': 'Lbank',
#   'updated': True,
#   'volume_24h': 485.497},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0,
#   'price': 1.09953,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 483.268},
#  {'pair': 'GXS/BTC',
#   'percent_volume': 0.0495155037595,
#   'price': 0.996646,
#   'source': 'Gate.io',
#   'updated': True,
#   'volume_24h': 474.872},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0494088797264,
#   'price': 0.999449,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 473.849},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0491244688332,
#   'price': 1.00047,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 471.121},
#  {'pair': 'ACT/BTC',
#   'percent_volume': 0.049059556795,
#   'price': 0.987631,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 470.499},
#  {'pair': 'MANA/BTC',
#   'percent_volume': 0.0484658520607,
#   'price': 0.982852,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 464.805},
#  {'pair': 'WAVES/BTC',
#   'percent_volume': 0.0482172629959,
#   'price': 1.00233,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 462.421},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0,
#   'price': 1.03494,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 455.06},
#  {'pair': 'MANA/BTC',
#   'percent_volume': 0.0470302141496,
#   'price': 0.982852,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 451.036},
#  {'pair': 'BIX/BTC',
#   'percent_volume': 0.0467531359126,
#   'price': 0.989272,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 448.379},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0464635560978,
#   'price': 1.00848,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 445.603},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.0463058438865,
#   'price': 0.99896,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 444.09},
#  {'pair': 'STRAT/BTC',
#   'percent_volume': 0.0462534334261,
#   'price': 1.01695,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 443.588},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0460814165249,
#   'price': 1.00332,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 441.938},
#  {'pair': 'BTC/THB',
#   'percent_volume': 0.0453887810361,
#   'price': 1.00411,
#   'source': 'BX Thailand',
#   'updated': True,
#   'volume_24h': 435.295},
#  {'pair': 'BTC/TRY',
#   'percent_volume': 0.0452718191599,
#   'price': 0.986891,
#   'source': 'BTCTurk',
#   'updated': True,
#   'volume_24h': 434.173},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0451788987793,
#   'price': 1.00301,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 433.281},
#  {'pair': 'RISE/BTC',
#   'percent_volume': 0.0450318850336,
#   'price': 0.992246,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 431.872},
#  {'pair': 'PIVX/BTC',
#   'percent_volume': 0.044746873103,
#   'price': 1.0204,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 429.138},
#  {'pair': 'MANA/BTC',
#   'percent_volume': 0.0,
#   'price': 1.08395,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 427.532},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0,
#   'price': 1.06636,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 427.471},
#  {'pair': 'ENG/BTC',
#   'percent_volume': 0.0,
#   'price': 1.30345,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 427.244},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0445262923806,
#   'price': 0.996802,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 427.023},
#  {'pair': 'STRAT/BTC',
#   'percent_volume': 0.0,
#   'price': 1.1259,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 424.817},
#  {'pair': 'CTR/BTC',
#   'percent_volume': 0.0442520991231,
#   'price': 0.994869,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 424.393},
#  {'pair': 'GNT/BTC',
#   'percent_volume': 0.0441988472103,
#   'price': 0.993756,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 423.883},
#  {'pair': 'GXS/BTC',
#   'percent_volume': 0.0,
#   'price': 1.0331,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 421.966},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.04376129199,
#   'price': 1.02411,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 419.686},
#  {'pair': 'NKC/BTC',
#   'percent_volume': 0.0431217882064,
#   'price': 0.992201,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 413.553},
#  {'pair': 'GAS/BTC',
#   'percent_volume': 0.0,
#   'price': 0.974775,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 413.336},
#  {'pair': 'VIB/BTC',
#   'percent_volume': 0.0424828854603,
#   'price': 0.995598,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 407.426},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 0.960554,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 397.391},
#  {'pair': 'ADK/BTC',
#   'percent_volume': 0.0414202513538,
#   'price': 0.995945,
#   'source': 'AidosMarket',
#   'updated': True,
#   'volume_24h': 397.235},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.0412827339989,
#   'price': 0.969306,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 395.917},
#  {'pair': 'VEN/BTC',
#   'percent_volume': 0.0412370551572,
#   'price': 0.994163,
#   'source': 'Lbank',
#   'updated': True,
#   'volume_24h': 395.478},
#  {'pair': 'SUB/BTC',
#   'percent_volume': 0.0,
#   'price': 1.13098,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 383.505},
#  {'pair': 'AION/BTC',
#   'percent_volume': 0.0,
#   'price': 0.994672,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 381.612},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0397444389015,
#   'price': 1.03312,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 381.164},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0394484880904,
#   'price': 1.00167,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 378.325},
#  {'pair': 'NBT/BTC',
#   'percent_volume': 0.0393871822766,
#   'price': 0.996278,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 377.737},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0391930471995,
#   'price': 1.00404,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 375.875},
#  {'pair': 'ITC/BTC',
#   'percent_volume': 0.0391147921312,
#   'price': 1.00508,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 375.124},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0389462612469,
#   'price': 1.0016,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 373.509},
#  {'pair': 'CVC/BTC',
#   'percent_volume': 0.0388737761376,
#   'price': 0.998103,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 372.813},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0388243708641,
#   'price': 0.995325,
#   'source': 'BtcTrade.im',
#   'updated': True,
#   'volume_24h': 372.34},
#  {'pair': 'BTC/PEN',
#   'percent_volume': 0.0,
#   'price': 0.963549,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 370.953},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0386029486894,
#   'price': 0.9961,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 370.216},
#  {'pair': 'RISE/BTC',
#   'percent_volume': 0.038580469891,
#   'price': 0.975154,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 370.0},
#  {'pair': 'RLC/BTC',
#   'percent_volume': 0.0383666207875,
#   'price': 0.994721,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 367.95},
#  {'pair': 'MEE/BTC',
#   'percent_volume': 0.0379490200085,
#   'price': 0.993165,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 363.945},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0378663172636,
#   'price': 0.99248,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 363.151},
#  {'pair': 'WINGS/BTC',
#   'percent_volume': 0.0,
#   'price': 1.01233,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 361.252},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.0376113572025,
#   'price': 0.970165,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 360.706},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.0,
#   'price': 1.19474,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 358.487},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0369451673589,
#   'price': 0.995718,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 354.318},
#  {'pair': 'MTN/BTC',
#   'percent_volume': 0.0368135401703,
#   'price': 0.995177,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 353.055},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0367826468485,
#   'price': 0.986352,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 352.759},
#  {'pair': 'STEEM/BTC',
#   'percent_volume': 0.0367528353939,
#   'price': 1.02995,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 352.473},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0365197530938,
#   'price': 1.01982,
#   'source': 'Allcoin',
#   'updated': True,
#   'volume_24h': 350.238},
#  {'pair': 'KNC/BTC',
#   'percent_volume': 0.0,
#   'price': 1.02779,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 349.976},
#  {'pair': 'NAS/BTC',
#   'percent_volume': 0.0364443830051,
#   'price': 0.995368,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 349.515},
#  {'pair': 'PIVX/BTC',
#   'percent_volume': 0.0363300656934,
#   'price': 1.02038,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 348.418},
#  {'pair': 'STEEM/BTC',
#   'percent_volume': 0.0359675199394,
#   'price': 1.02856,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 344.941},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0358836151197,
#   'price': 0.986026,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 344.137},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0358306036219,
#   'price': 0.986494,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 343.629},
#  {'pair': 'SNT/BTC',
#   'percent_volume': 0.0,
#   'price': 0.970151,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 342.784},
#  {'pair': 'ELF/BTC',
#   'percent_volume': 0.0,
#   'price': 1.01429,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 342.687},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.035302411963,
#   'price': 0.992222,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 338.562},
#  {'pair': 'DGB/BTC',
#   'percent_volume': 0.0352716388487,
#   'price': 0.987537,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 338.267},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0350482933543,
#   'price': 1.28183,
#   'source': 'BtcTrade.im',
#   'updated': True,
#   'volume_24h': 336.126},
#  {'pair': 'ORME/BTC',
#   'percent_volume': 0.0349459967905,
#   'price': 1.00262,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 335.145},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0344036206492,
#   'price': 0.989148,
#   'source': 'BtcTrade.im',
#   'updated': True,
#   'volume_24h': 329.943},
#  {'pair': 'SRN/BTC',
#   'percent_volume': 0.0343697221404,
#   'price': 1.01234,
#   'source': 'Liqui',
#   'updated': True,
#   'volume_24h': 329.618},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0343272889006,
#   'price': 0.993014,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 329.211},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.034319836037,
#   'price': 0.997294,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 329.14},
#  {'pair': 'BTC/MXN',
#   'percent_volume': 0.0343153883603,
#   'price': 0.986084,
#   'source': 'Bitso',
#   'updated': True,
#   'volume_24h': 329.097},
#  {'pair': 'LBTC/BTC',
#   'percent_volume': 0.0341207724533,
#   'price': 1.07003,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 327.231},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0338489833453,
#   'price': 1.00562,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 324.624},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.033723967568,
#   'price': 0.997679,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 323.425},
#  {'pair': 'BTM/BTC',
#   'percent_volume': 0.0337135095174,
#   'price': 0.996023,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 323.325},
#  {'pair': 'LBTC/BTC',
#   'percent_volume': 0.0336901892667,
#   'price': 0.942952,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 323.101},
#  {'pair': 'BCD/BTC',
#   'percent_volume': 0.0,
#   'price': 0.919118,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 322.449},
#  {'pair': 'ELF/BTC',
#   'percent_volume': 0.033611333161,
#   'price': 0.991821,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 322.345},
#  {'pair': 'BTC/BRL',
#   'percent_volume': 0.0,
#   'price': 0.976198,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 320.283},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.0331943334195,
#   'price': 1.03148,
#   'source': 'ZB.COM',
#   'updated': True,
#   'volume_24h': 318.345},
#  {'pair': 'SNC/BTC',
#   'percent_volume': 0.0330027226994,
#   'price': 0.99903,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 316.508},
#  {'pair': 'XRB/BTC',
#   'percent_volume': 0.0,
#   'price': 1.14408,
#   'source': 'BitGrail',
#   'updated': False,
#   'volume_24h': 326.189},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0327377854176,
#   'price': 0.995175,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 313.967},
#  {'pair': 'MANA/BTC',
#   'percent_volume': 0.032713743922,
#   'price': 0.989095,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 313.736},
#  {'pair': 'RLC/BTC',
#   'percent_volume': 0.032483426394,
#   'price': 0.994721,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 311.528},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.0324002428191,
#   'price': 1.02837,
#   'source': 'Coinnest',
#   'updated': True,
#   'volume_24h': 310.729},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0323338882912,
#   'price': 0.994081,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 310.094},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.032181224794,
#   'price': 1.07786,
#   'source': 'BTC-Alpha',
#   'updated': True,
#   'volume_24h': 308.629},
#  {'pair': 'BTC/CNY',
#   'percent_volume': 0.0,
#   'price': 0.96273,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 308.483},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.031884793153,
#   'price': 0.999752,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 305.787},
#  {'pair': 'SOC/BTC',
#   'percent_volume': 0.0318658003714,
#   'price': 0.995478,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 305.605},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0318215640195,
#   'price': 0.993336,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 305.18},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.0317969214865,
#   'price': 1.00781,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 304.943},
#  {'pair': 'HPB/BTC',
#   'percent_volume': 0.0316263470751,
#   'price': 0.994536,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 303.308},
#  {'pair': 'ADT/BTC',
#   'percent_volume': 0.0316227408507,
#   'price': 0.99427,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 303.273},
#  {'pair': 'BTC/BRL',
#   'percent_volume': 0.0313807631973,
#   'price': 0.994226,
#   'source': 'Mercado Bitcoin',
#   'updated': True,
#   'volume_24h': 300.952},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0313804025748,
#   'price': 0.953655,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 300.949},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0312954158878,
#   'price': 1.01152,
#   'source': 'BL3P',
#   'updated': True,
#   'volume_24h': 300.135},
#  {'pair': 'SXUT/BTC',
#   'percent_volume': 0.0311453969551,
#   'price': 0.978093,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 298.696},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0304448277727,
#   'price': 0.998394,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 291.977},
#  {'pair': 'WABI/BTC',
#   'percent_volume': 0.0,
#   'price': 1.58977,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 286.814},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.0297138460984,
#   'price': 0.996956,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 284.966},
#  {'pair': 'XDN/BTC',
#   'percent_volume': 0.0296972574664,
#   'price': 0.953146,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 284.807},
#  {'pair': 'DSH/BTC',
#   'percent_volume': 0.0293486557799,
#   'price': 1.00006,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 281.464},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0292052482585,
#   'price': 1.00756,
#   'source': 'C2CX',
#   'updated': True,
#   'volume_24h': 280.089},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0290350344695,
#   'price': 0.995339,
#   'source': 'ZB.COM',
#   'updated': True,
#   'volume_24h': 278.456},
#  {'pair': 'GAS/BTC',
#   'percent_volume': 0.0289905577026,
#   'price': 0.992137,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 278.03},
#  {'pair': 'SNC/BTC',
#   'percent_volume': 0.0289694011864,
#   'price': 1.00425,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 277.826},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.028949927575,
#   'price': 1.00241,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 277.64},
#  {'pair': 'ADX/BTC',
#   'percent_volume': 0.0288424620896,
#   'price': 0.997041,
#   'source': 'Liqui',
#   'updated': True,
#   'volume_24h': 276.609},
#  {'pair': 'MANA/BTC',
#   'percent_volume': 0.0287965428329,
#   'price': 0.989444,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 276.169},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.0283176362402,
#   'price': 1.02615,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 271.576},
#  {'pair': 'TKY/BTC',
#   'percent_volume': 0.0282259179344,
#   'price': 1.01326,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 270.696},
#  {'pair': 'QUN/BTC',
#   'percent_volume': 0.0282160609211,
#   'price': 0.992223,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 270.602},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0282027178911,
#   'price': 1.00022,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 270.474},
#  {'pair': 'LEND/BTC',
#   'percent_volume': 0.0,
#   'price': 1.03999,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 270.382},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.028008342399,
#   'price': 0.999935,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 268.61},
#  {'pair': 'APPC/BTC',
#   'percent_volume': 0.0,
#   'price': 1.10082,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 267.231},
#  {'pair': 'ICX/BTC',
#   'percent_volume': 0.0277601139567,
#   'price': 1.00043,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 266.229},
#  {'pair': 'OST/BTC',
#   'percent_volume': 0.0,
#   'price': 1.01753,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 263.055},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0272088424621,
#   'price': 0.988182,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 260.942},
#  {'pair': 'TRIG/BTC',
#   'percent_volume': 0.0,
#   'price': 0.951821,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 260.754},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0271087096328,
#   'price': 0.997757,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 259.982},
#  {'pair': 'NEBL/BTC',
#   'percent_volume': 0.0,
#   'price': 1.15846,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 259.816},
#  {'pair': 'NXT/BTC',
#   'percent_volume': 0.0268544708166,
#   'price': 0.988483,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 257.544},
#  {'pair': 'ENJ/BTC',
#   'percent_volume': 0.0,
#   'price': 1.02239,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 257.024},
#  {'pair': 'NULS/BTC',
#   'percent_volume': 0.0,
#   'price': 0.992333,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 256.636},
#  {'pair': 'STORJ/BTC',
#   'percent_volume': 0.0265186111228,
#   'price': 1.00529,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 254.323},
#  {'pair': 'IOTA/BTC',
#   'percent_volume': 0.0264984162665,
#   'price': 1.01631,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 254.129},
#  {'pair': 'REQ/BTC',
#   'percent_volume': 0.0,
#   'price': 1.06167,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 253.378},
#  {'pair': 'SYS/BTC',
#   'percent_volume': 0.0263390211505,
#   'price': 0.986084,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 252.601},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0,
#   'price': 1.06958,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 251.465},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0261784239598,
#   'price': 1.01242,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 251.06},
#  {'pair': 'VIB/BTC',
#   'percent_volume': 0.0,
#   'price': 1.05748,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 249.151},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0259231032763,
#   'price': 0.999867,
#   'source': 'Bitonic',
#   'updated': True,
#   'volume_24h': 248.612},
#  {'pair': 'SNT/BTC',
#   'percent_volume': 0.0258775446421,
#   'price': 1.03122,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 248.175},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0258513394118,
#   'price': 0.99595,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 247.924},
#  {'pair': 'ACT/BTC',
#   'percent_volume': 0.025625349353,
#   'price': 0.999452,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 245.756},
#  {'pair': 'ADX/BTC',
#   'percent_volume': 0.0256067171939,
#   'price': 0.997778,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 245.577},
#  {'pair': 'CHAT/BTC',
#   'percent_volume': 0.0255606777298,
#   'price': 0.996546,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 245.136},
#  {'pair': 'BTC/PLN',
#   'percent_volume': 0.0255076662319,
#   'price': 1.00491,
#   'source': 'BitMarket',
#   'updated': True,
#   'volume_24h': 244.627},
#  {'pair': 'XDN/BTC',
#   'percent_volume': 0.0254154670962,
#   'price': 1.0626,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 243.744},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 1.00521,
#   'source': 'BitMEX',
#   'updated': True,
#   'volume_24h': 212436.0},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 1.00233,
#   'source': 'Zaif',
#   'updated': True,
#   'volume_24h': 16589.1},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 1.00021,
#   'source': 'Fisco',
#   'updated': True,
#   'volume_24h': 16557.4},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 1.00648,
#   'source': 'Quoine',
#   'updated': True,
#   'volume_24h': 15155.7},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 0.986855,
#   'source': 'BTCBOX',
#   'updated': True,
#   'volume_24h': 14882.4},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0,
#   'price': 0.998223,
#   'source': 'ZB.COM',
#   'updated': True,
#   'volume_24h': 3026.8},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 1.00306,
#   'source': 'Quoine',
#   'updated': True,
#   'volume_24h': 1886.15},
#  {'pair': 'BTC/AUD',
#   'percent_volume': 0.0,
#   'price': 1.00306,
#   'source': 'ACX',
#   'updated': True,
#   'volume_24h': 614.818},
#  {'pair': 'BTC/SGD',
#   'percent_volume': 0.0,
#   'price': 1.00464,
#   'source': 'Quoine',
#   'updated': True,
#   'volume_24h': 479.775},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 0.9972,
#   'source': 'bitFlyer',
#   'updated': True,
#   'volume_24h': 461.319},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.0,
#   'price': 1.03897,
#   'source': 'GOPAX',
#   'updated': True,
#   'volume_24h': 460.708},
#  {'pair': 'BTC/XRP',
#   'percent_volume': 0.0,
#   'price': 1.01851e-08,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 1899.9},
#  {'pair': 'BTC/RUB',
#   'percent_volume': 0.0,
#   'price': 1.7774,
#   'source': 'GetBTC',
#   'updated': True,
#   'volume_24h': 994.348},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0,
#   'price': 1.23929,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 650.887},
#  {'pair': 'BTC/LTC',
#   'percent_volume': 0.0,
#   'price': 0.000324789,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 344.844},
#  {'pair': 'BTC/ETH',
#   'percent_volume': 0.0,
#   'price': 0.00988585,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 334.243}]

# %% [markdown]
# #### `ranks([convert="USD"])`
# Get gainers and losers rankings:

# %%
cmc.ranks()
# Out:
# {'gainers': {'1h': [{'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0},
#    {'name': 'Bitcoin White',
#     'percent_change': 30.22,
#     'price': 0.30826,
#     'symbol': 'BTW',
#     'volume_24h': 197191.0}],
#   '24h': [{'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 838.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0}],
#   '7d': [{'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0},
#    {'name': 'E-coin',
#     'percent_change': 1138.28,
#     'price': 61.5843,
#     'symbol': 'ECN',
#     'volume_24h': 486891.0}]},
#  'losers': {'1h': [{'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7},
#    {'name': 'onG.social',
#     'percent_change': -24.77,
#     'price': 0.502971,
#     'symbol': 'ONG',
#     'volume_24h': 73063.7}],
#   '24h': [{'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731242,
#     'symbol': 'DAV',
#     'volume_24h': 430000.0}],
#   '7d': [{'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.05,
#     'price': 0.262799,
#     'symbol': 'GJC',
#     'volume_24h': 55533.6}]}}

# %% [markdown]
# #### `historical(currency, [start=datetime(2008, 8, 18), end=datetime.now(), revert=False])`
# Get historical prices for a currency. You can filter by `start` and `end` datetimes provided in `datetime` objects. With parameter `revert` active, the response will be ordered in chronological order.

# %%
from datetime import datetime

list(cmc.historical("ETH", start=datetime(2018, 2, 1), revert=True))
# Out:
# [{'close': 1036.79,
#   'date': datetime.datetime(2018, 2, 1, 0, 0),
#   'high': 1161.35,
#   'low': 984.819,
#   'market_cap': 697.951,
#   'open': 1119.37,
#   'volume': 644.599},
#  {'close': 915.785,
#   'date': datetime.datetime(2018, 2, 2, 0, 0),
#   'high': 1035.77,
#   'low': 757.98,
#   'market_cap': 856.646,
#   'open': 1035.77,
#   'volume': 834.958},
#  {'close': 964.019,
#   'date': datetime.datetime(2018, 2, 3, 0, 0),
#   'high': 991.943,
#   'low': 847.69,
#   'market_cap': 793.122,
#   'open': 919.211,
#   'volume': 574.419},
#  {'close': 834.682,
#   'date': datetime.datetime(2018, 2, 4, 0, 0),
#   'high': 969.032,
#   'low': 805.064,
#   'market_cap': 796.439,
#   'open': 964.667,
#   'volume': 707.737},
#  {'close': 697.951,
#   'date': datetime.datetime(2018, 2, 5, 0, 0),
#   'high': 856.646,
#   'low': 644.599,
#   'market_cap': 757.068,
#   'open': 834.958,
#   'volume': 723.433},
#  {'close': 793.122,
#   'date': datetime.datetime(2018, 2, 6, 0, 0),
#   'high': 796.439,
#   'low': 574.419,
#   'market_cap': 851.2,
#   'open': 707.737,
#   'volume': 790.428},
#  {'close': 757.068,
#   'date': datetime.datetime(2018, 2, 7, 0, 0),
#   'high': 851.2,
#   'low': 723.433,
#   'market_cap': 817.807,
#   'open': 790.428,
#   'volume': 755.843},
#  {'close': 817.807,
#   'date': datetime.datetime(2018, 2, 8, 0, 0),
#   'high': 845.086,
#   'low': 755.843,
#   'market_cap': 845.086,
#   'open': 755.843,
#   'volume': 755.843}]

# %% [markdown]
# #### `recently([convert="USD"])`
# Get recently added coins in coinmarketcap along with other metadata. this method returns a `generator` object.

# %%
list(cmc.recently())
# Out:
# []
