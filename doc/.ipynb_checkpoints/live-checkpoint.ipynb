# %% [markdown]
# # <center>Pymarketcap live documentation</center>

# %% [markdown]
# ## Basic usage
#
# #### `Pymarketcap([timeout=20, debug=False])`
#
# The first response takes a long time because some data is cached at instantiation of the wrapper.

# %%
from pymarketcap import Pymarketcap
cmc = Pymarketcap(timeout=10)

cmc.exchanges()
# Out:
# [{'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BitMEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Gifto',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'TRON',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'NEO',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'ICON',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'NEO',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Binance Coin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Binance'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'EOS',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'OKEx'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Cardano',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'NEO',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Status',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Qtum',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Stellar',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Upbit'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Qtum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Zcash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bithumb'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Tether',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'EOS',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bitfinex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Huobi Token',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'TRON',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Huobi Token',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Elastos',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'EOS',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Huobi Token',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'IOStoken',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Elastos',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Huobi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Ripple',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ripple',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Kraken'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'GDAX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'NuBits',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ripple',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'NEO',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Cardano',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bittrex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Monero',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Dash',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Zcash',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bytecoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'HitBTC'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Qtum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'IOTA',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'}],
#   'name': 'Coinone'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ripple',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bitstamp'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'TRON',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'EDUCare',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Ink',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ink',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Lisk',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Hshare',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bit-Z'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'}],
#   'name': 'bitFlyer'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEM',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Counterparty',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'COMSA [ETH]',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'NEM',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'COMSA [XEM]',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Pepe Cash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Zaif'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ripple',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Stellar',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Monero',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Poloniex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'MonaCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'}],
#   'name': 'Fisco'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BTCBOX'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEO',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'TRON',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Lisk',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ruff',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Qtum',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Qbao',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ripple',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Achain',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Lightning Bitcoin [Futures]',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'CoinEgg'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'QASH',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Quoine'},
#  {'markets': [{'name': 'Stellar',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Status',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Qtum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'EOS',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Cindicator',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Civic',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'GOPAX'},
#  {'markets': [{'name': 'Ink',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'BitShares',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Hshare',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'EOS',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'ZB.COM'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ink',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ink',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Hyper Pay',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Lightning Bitcoin [Futures]',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'EXX'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'}],
#   'name': 'Korbit'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'}],
#   'name': 'Bitbank'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Zcash',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Dash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Zcash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'WEX'},
#  {'markets': [{'name': 'ATMCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'ATMCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'ATMCoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Dogecoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'ATMCoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bits Blockchain'},
#  {'markets': [{'name': 'TRON',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Hshare',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Storm',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Qtum',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Profile Utility Token',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Energo',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Walton',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Kyber Network',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Coinnest'},
#  {'markets': [{'name': 'Qtum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'VeChain',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ink',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Zcash',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
# ...
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'BCEX'},
#  {'markets': [{'name': 'NVO',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcrystals',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Rustbits',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Pepe Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Counterparty',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Storjcoin X',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Storjcoin X',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'FoldingCoin',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'}],
#   'name': 'Counterparty DEX'},
#  {'markets': [{'name': 'Counterparty',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Pepe Cash',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Monero',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Zcash',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Dash',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'PotCoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Namecoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Tux Exchange'},
#  {'markets': [{'name': 'Litecoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Electroneum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'BitCoal',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Monero',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Aeon',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Verge',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Sumokoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'}],
#   'name': 'TradeOgre'},
#  {'markets': [{'name': 'E-Dinar Coin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'}],
#   'name': 'LocalTrade'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Rippex'},
#  {'markets': [{'name': 'BriaCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'}],
#   'name': 'Ore.Bz'},
#  {'markets': [{'name': 'Gulden',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'GuldenTrader'},
#  {'markets': [{'name': 'GBCGoldCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'CRTCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'}],
#   'name': 'NIX-E'},
#  {'markets': [{'name': 'Centurion',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ExcambrioRex'},
#  {'markets': [{'name': 'Auroracoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ISX'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'TCC Exchange'},
#  {'markets': [{'name': 'SnakeEyes',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Burst Asset Exchange'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'CoinCorner'},
#  {'markets': [{'name': 'Golem',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Lunyr',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'SingularDTV',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'TokenCard',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Swarm City',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Etheroll',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Melon',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Numeraire',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Edgeless',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum Movie Venture',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'CryptoDerivatives'},
#  {'markets': [{'name': 'MaidSafeCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Omni DEX'},
#  {'markets': [{'name': 'LEOcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'LEOcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'LEOcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'LEOcoin',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'}],
#   'name': 'LEOxChange'},
#  {'markets': [{'name': 'Virtacoinplus',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Virtacoinplus',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'VirtacoinWorld'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Siacoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'}],
#   'name': 'BITHOLIC'},
#  {'markets': [{'name': 'Raiden Network Token',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'RChain',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'TRON',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'ChainLink',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Aion',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'SALT',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Dragonchain',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Populous',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Global Jobcoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bounty0x',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Token Store'}]

# %% [markdown]
# > All methods are self explained in docstrings:

# %%
print(cmc.exchanges.__doc__)
# Out:
# Get all the exchanges in coninmarketcap ranked by volumes
#         along with other metadata.
#
#         Args:
#             convert (str, optional): Convert volumes and prices
#                 between "USD" and "BTC". As default "USD".
#
#         Returns (list):
#             Exchanges with markets and other data included.

# %% [markdown]
# ___________________________________
#
# ## Coinmarketcap API
# #### `ticker(currency=None, limit=0, start=0, convert="USD")`
# If `currency == None`, you will obtain data for all currencies in coinmarketcap:

# %%
cmc.ticker()
# Out:
# [{'24h_volume_usd': 6038960000.0,
#   'available_supply': 16859762.0,
#   'id': 'bitcoin',
#   'last_updated': 1518420567,
#   'market_cap_usd': 143999564437,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin',
#   'percent_change_1h': 0.71,
#   'percent_change_24h': 6.18,
#   'percent_change_7d': 6.4,
#   'price_btc': 1.0,
#   'price_usd': 8541.02,
#   'rank': 1,
#   'symbol': 'BTC',
#   'total_supply': 16859762.0},
#  {'24h_volume_usd': 2365900000.0,
#   'available_supply': 97564206.0,
#   'id': 'ethereum',
#   'last_updated': 1518420550,
#   'market_cap_usd': 83055530915.0,
#   'max_supply': None,
#   'name': 'Ethereum',
#   'percent_change_1h': 0.68,
#   'percent_change_24h': 6.01,
#   'percent_change_7d': 4.12,
#   'price_btc': 0.100115,
#   'price_usd': 851.291,
#   'rank': 2,
#   'symbol': 'ETH',
#   'total_supply': 97564206.0},
#  {'24h_volume_usd': 2400310000.0,
#   'available_supply': 39009215838.0,
#   'id': 'ripple',
#   'last_updated': 1518420841,
#   'market_cap_usd': 41569000581.0,
#   'max_supply': 100000000000,
#   'name': 'Ripple',
#   'percent_change_1h': 0.46,
#   'percent_change_24h': 11.04,
#   'percent_change_7d': 34.32,
#   'price_btc': 0.00012504,
#   'price_usd': 1.06562,
#   'rank': 3,
#   'symbol': 'XRP',
#   'total_supply': 99992725510.0},
#  {'24h_volume_usd': 534935000.0,
#   'available_supply': 16963013.0,
#   'id': 'bitcoin-cash',
#   'last_updated': 1518420553,
#   'market_cap_usd': 21375431312.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Cash',
#   'percent_change_1h': 0.59,
#   'percent_change_24h': 4.08,
#   'percent_change_7d': 16.36,
#   'price_btc': 0.148195,
#   'price_usd': 1260.12,
#   'rank': 4,
#   'symbol': 'BCH',
#   'total_supply': 16963013.0},
#  {'24h_volume_usd': 272246000.0,
#   'available_supply': 25927070538.0,
#   'id': 'cardano',
#   'last_updated': 1518420555,
#   'market_cap_usd': 9903337206.0,
#   'max_supply': 45000000000.0,
#   'name': 'Cardano',
#   'percent_change_1h': 0.2,
#   'percent_change_24h': 3.43,
#   'percent_change_7d': 5.91,
#   'price_btc': 4.492e-05,
#   'price_usd': 0.381969,
#   'rank': 5,
#   'symbol': 'ADA',
#   'total_supply': 31112483745.0},
#  {'24h_volume_usd': 475515000.0,
#   'available_supply': 55179983.0,
#   'id': 'litecoin',
#   'last_updated': 1518420841,
#   'market_cap_usd': 8541364772.0,
#   'max_supply': 84000000.0,
#   'name': 'Litecoin',
#   'percent_change_1h': 0.85,
#   'percent_change_24h': 7.04,
#   'percent_change_7d': 6.91,
#   'price_btc': 0.0181626,
#   'price_usd': 154.791,
#   'rank': 6,
#   'symbol': 'LTC',
#   'total_supply': 55179983.0},
#  {'24h_volume_usd': 328442000.0,
#   'available_supply': 65000000.0,
#   'id': 'neo',
#   'last_updated': 1518420547,
#   'market_cap_usd': 7340450000.0,
#   'max_supply': None,
#   'name': 'NEO',
#   'percent_change_1h': 0.47,
#   'percent_change_24h': 13.65,
#   'percent_change_7d': 10.03,
#   'price_btc': 0.0132811,
#   'price_usd': 112.93,
#   'rank': 7,
#   'symbol': 'NEO',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 75856600.0,
#   'available_supply': 18432256791.0,
#   'id': 'stellar',
#   'last_updated': 1518420843,
#   'market_cap_usd': 7183529710.0,
#   'max_supply': None,
#   'name': 'Stellar',
#   'percent_change_1h': 0.71,
#   'percent_change_24h': 7.25,
#   'percent_change_7d': 3.4,
#   'price_btc': 4.573e-05,
#   'price_usd': 0.389726,
#   'rank': 8,
#   'symbol': 'XLM',
#   'total_supply': 103669352049},
#  {'24h_volume_usd': 363551000.0,
#   'available_supply': 664042138.0,
#   'id': 'eos',
#   'last_updated': 1518420551,
#   'market_cap_usd': 5902683849.0,
#   'max_supply': 1000000000.0,
#   'name': 'EOS',
#   'percent_change_1h': 0.74,
#   'percent_change_24h': 6.88,
#   'percent_change_7d': 5.07,
#   'price_btc': 0.00104538,
#   'price_usd': 8.88902,
#   'rank': 9,
#   'symbol': 'EOS',
#   'total_supply': 900000000.0},
#  {'24h_volume_usd': 43616700.0,
#   'available_supply': 2779530283.0,
#   'id': 'iota',
#   'last_updated': 1518420551,
#   'market_cap_usd': 5058800706.0,
#   'max_supply': 2779530283.0,
#   'name': 'IOTA',
#   'percent_change_1h': 1.27,
#   'percent_change_24h': 8.13,
#   'percent_change_7d': 10.98,
#   'price_btc': 0.00021404,
#   'price_usd': 1.82002,
#   'rank': 10,
#   'symbol': 'MIOTA',
#   'total_supply': 2779530283.0},
#  {'24h_volume_usd': 24404000.0,
#   'available_supply': 8999999999.0,
#   'id': 'nem',
#   'last_updated': 1518420845,
#   'market_cap_usd': 4917275999.0,
#   'max_supply': None,
#   'name': 'NEM',
#   'percent_change_1h': 0.8,
#   'percent_change_24h': 4.04,
#   'percent_change_7d': 3.64,
#   'price_btc': 6.411e-05,
#   'price_usd': 0.546364,
#   'rank': 11,
#   'symbol': 'XEM',
#   'total_supply': 8999999999.0},
#  {'24h_volume_usd': 78079200.0,
#   'available_supply': 7879304.0,
#   'id': 'dash',
#   'last_updated': 1518420842,
#   'market_cap_usd': 4803917386.0,
#   'max_supply': 18900000.0,
#   'name': 'Dash',
#   'percent_change_1h': 0.85,
#   'percent_change_24h': 7.04,
#   'percent_change_7d': 15.4,
#   'price_btc': 0.0715386,
#   'price_usd': 609.688,
#   'rank': 12,
#   'symbol': 'DASH',
#   'total_supply': 7879304.0},
#  {'24h_volume_usd': 50357300.0,
#   'available_supply': 15711966.0,
#   'id': 'monero',
#   'last_updated': 1518420843,
#   'market_cap_usd': 3807637806.0,
#   'max_supply': None,
#   'name': 'Monero',
#   'percent_change_1h': 0.43,
#   'percent_change_24h': 8.19,
#   'percent_change_7d': 15.95,
#   'price_btc': 0.0284353,
#   'price_usd': 242.34,
#   'rank': 13,
#   'symbol': 'XMR',
#   'total_supply': 15711966.0},
#  {'24h_volume_usd': 57029000.0,
#   'available_supply': 117979860.0,
#   'id': 'lisk',
#   'last_updated': 1518420847,
#   'market_cap_usd': 3162013622.0,
#   'max_supply': None,
#   'name': 'Lisk',
#   'percent_change_1h': 0.9,
#   'percent_change_24h': 12.08,
#   'percent_change_7d': 39.47,
#   'price_btc': 0.00314477,
#   'price_usd': 26.8013,
#   'rank': 14,
#   'symbol': 'LSK',
#   'total_supply': 117979860.0},
#  {'24h_volume_usd': 264124000.0,
#   'available_supply': 65748192475.0,
#   'id': 'tron',
#   'last_updated': 1518420554,
#   'market_cap_usd': 2989267870.0,
#   'max_supply': None,
#   'name': 'TRON',
#   'percent_change_1h': 0.74,
#   'percent_change_24h': 9.47,
#   'percent_change_7d': 24.73,
#   'price_btc': 5.35e-06,
#   'price_usd': 0.0454654,
#   'rank': 15,
#   'symbol': 'TRX',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 378473000.0,
#   'available_supply': 99796816.0,
#   'id': 'ethereum-classic',
#   'last_updated': 1518420547,
#   'market_cap_usd': 2533960914.0,
#   'max_supply': None,
#   'name': 'Ethereum Classic',
#   'percent_change_1h': 1.03,
#   'percent_change_24h': 15.55,
#   'percent_change_7d': 25.67,
#   'price_btc': 0.0029861,
#   'price_usd': 25.3912,
#   'rank': 16,
#   'symbol': 'ETC',
#   'total_supply': 99796816.0},
#  {'24h_volume_usd': 41312800.0,
#   'available_supply': 16819286.0,
#   'id': 'bitcoin-gold',
#   'last_updated': 1518420555,
#   'market_cap_usd': 2260730701.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Gold',
#   'percent_change_1h': -0.03,
#   'percent_change_24h': 13.28,
#   'percent_change_7d': 37.28,
#   'price_btc': 0.0158075,
#   'price_usd': 134.413,
#   'rank': 17,
#   'symbol': 'BTG',
#   'total_supply': 16919286.0},
#  {'24h_volume_usd': 2201560000.0,
#   'available_supply': 2217140814.0,
#   'id': 'tether',
#   'last_updated': 1518420846,
#   'market_cap_usd': 2221996352.0,
#   'max_supply': None,
#   'name': 'Tether',
#   'percent_change_1h': 0.1,
#   'percent_change_24h': -0.31,
#   'percent_change_7d': 0.12,
#   'price_btc': 0.00011759,
#   'price_usd': 1.00219,
#   'rank': 18,
#   'symbol': 'USDT',
#   'total_supply': 2280109970.0},
#  {'24h_volume_usd': 266935000.0,
#   'available_supply': 73875664.0,
#   'id': 'qtum',
#   'last_updated': 1518420550,
#   'market_cap_usd': 2155965215.0,
#   'max_supply': None,
#   'name': 'Qtum',
#   'percent_change_1h': 0.37,
#   'percent_change_24h': 8.25,
#   'percent_change_7d': 17.69,
#   'price_btc': 0.00343213,
#   'price_usd': 29.1837,
#   'rank': 19,
#   'symbol': 'QTUM',
#   'total_supply': 100375664.0},
#  {'24h_volume_usd': 56358300.0,
#   'available_supply': 471002549.0,
#   'id': 'vechain',
#   'last_updated': 1518420553,
#   'market_cap_usd': 2028612687.0,
#   'max_supply': None,
#   'name': 'VeChain',
#   'percent_change_1h': 1.14,
#   'percent_change_24h': 11.88,
#   'percent_change_7d': 1.1,
#   'price_btc': 0.00050652,
#   'price_usd': 4.30701,
#   'rank': 20,
#   'symbol': 'VEN',
#   'total_supply': 873378637.0},
#  {'24h_volume_usd': 69269900.0,
#   'available_supply': 381495014.0,
#   'id': 'icon',
#   'last_updated': 1518420556,
#   'market_cap_usd': 1610931366.0,
#   'max_supply': None,
#   'name': 'ICON',
#   'percent_change_1h': 0.67,
#   'percent_change_24h': 19.38,
#   'percent_change_7d': 6.16,
#   'price_btc': 0.0004966,
#   'price_usd': 4.22268,
#   'rank': 21,
#   'symbol': 'ICX',
#   'total_supply': 400230000.0},
#  {'24h_volume_usd': 84900700.0,
#   'available_supply': 3260894.0,
#   'id': 'zcash',
#   'last_updated': 1518420548,
#   'market_cap_usd': 1487228422.0,
#   'max_supply': None,
#   'name': 'Zcash',
#   'percent_change_1h': 0.42,
#   'percent_change_24h': 8.19,
#   'percent_change_7d': 36.3,
#   'price_btc': 0.0536369,
#   'price_usd': 456.08,
#   'rank': 22,
#   'symbol': 'ZEC',
#   'total_supply': 3260894.0},
#  {'24h_volume_usd': 27585900.0,
#   'available_supply': 102042552.0,
#   'id': 'omisego',
#   'last_updated': 1518420552,
#   'market_cap_usd': 1267195021.0,
#   'max_supply': None,
#   'name': 'OmiseGO',
#   'percent_change_1h': 0.71,
#   'percent_change_24h': 10.08,
#   'percent_change_7d': 5.51,
#   'price_btc': 0.00146044,
#   'price_usd': 12.4183,
#   'rank': 23,
#   'symbol': 'OMG',
#   'total_supply': 140245398.0},
#  {'24h_volume_usd': 26964100.0,
#   'available_supply': 133248289.0,
#   'id': 'raiblocks',
#   'last_updated': 1518420550,
#   'market_cap_usd': 1165084399.0,
#   'max_supply': 133248290.0,
#   'name': 'Nano',
#   'percent_change_1h': 0.3,
#   'percent_change_24h': 3.05,
#   'percent_change_7d': -24.53,
#   'price_btc': 0.00102829,
#   'price_usd': 8.74371,
#   'rank': 24,
#   'symbol': 'XRB',
#   'total_supply': 133248289.0},
#  {'24h_volume_usd': 14630400.0,
#   'available_supply': 37004027.0,
#   'id': 'populous',
#   'last_updated': 1518420552,
#   'market_cap_usd': 1147313554.0,
#   'max_supply': 53252246.0,
#   'name': 'Populous',
#   'percent_change_1h': 6.61,
#   'percent_change_24h': 24.34,
#   'percent_change_7d': -28.18,
#   'price_btc': 0.00364632,
#   'price_usd': 31.0051,
#   'rank': 25,
#   'symbol': 'PPT',
#   'total_supply': 53252246.0},
#  {'24h_volume_usd': 2072620.0,
#   'available_supply': 8628818330.0,
#   'id': 'ucash',
#   'last_updated': 1518420560,
#   'market_cap_usd': 1046106161.0,
#   'max_supply': 21000000000.0,
#   'name': 'U.CASH',
#   'percent_change_1h': -3.13,
#   'percent_change_24h': 773.39,
#   'percent_change_7d': None,
#   'price_btc': 1.426e-05,
#   'price_usd': 0.121234,
#   'rank': 26,
#   'symbol': 'UCASH',
#   'total_supply': 21000000000.0},
#  {'24h_volume_usd': 27063300.0,
#   'available_supply': 249238021.0,
#   'id': 'steem',
#   'last_updated': 1518420847,
#   'market_cap_usd': 1021016016.0,
#   'max_supply': None,
#   'name': 'Steem',
#   'percent_change_1h': 0.23,
#   'percent_change_24h': 5.45,
#   'percent_change_7d': 11.87,
#   'price_btc': 0.00048067,
#   'price_usd': 4.09655,
#   'rank': 27,
#   'symbol': 'STEEM',
#   'total_supply': 266212115.0},
#  {'24h_volume_usd': 73294000.0,
#   'available_supply': 99014000.0,
#   'id': 'binance-coin',
#   'last_updated': 1518420552,
#   'market_cap_usd': 905360253.0,
#   'max_supply': None,
#   'name': 'Binance Coin',
#   'percent_change_1h': 0.86,
#   'percent_change_24h': 8.38,
#   'percent_change_7d': 13.16,
#   'price_btc': 0.00107534,
#   'price_usd': 9.14376,
#   'rank': 28,
#   'symbol': 'BNB',
#   'total_supply': 197192382.0},
#  {'24h_volume_usd': 3362490.0,
#   'available_supply': 183722372476,
#   'id': 'bytecoin-bcn',
#   'last_updated': 1518420843,
#   'market_cap_usd': 852043735.0,
#   'max_supply': 184470000000,
#   'name': 'Bytecoin',
#   'percent_change_1h': 1.26,
#   'percent_change_24h': 7.67,
#   'percent_change_7d': 10.63,
#   'price_btc': 5.4e-07,
#   'price_usd': 0.00463767,
#   'rank': 29,
#   'symbol': 'BCN',
#   'total_supply': 183722372476},
#  {'24h_volume_usd': 14377200.0,
#   'available_supply': 14585775328.0,
#   'id': 'verge',
#   'last_updated': 1518420844,
#   'market_cap_usd': 798315948.0,
#   'max_supply': 16555000000.0,
#   'name': 'Verge',
#   'percent_change_1h': 0.63,
#   'percent_change_24h': 9.64,
#   'percent_change_7d': 7.74,
#   'price_btc': 6.42e-06,
#   'price_usd': 0.0547325,
#   'rank': 30,
#   'symbol': 'XVG',
#   'total_supply': 14585775328.0},
#  {'24h_volume_usd': 99892900.0,
#   'available_supply': 3470483788.0,
#   'id': 'status',
#   'last_updated': 1518420551,
#   'market_cap_usd': 768441461.0,
#   'max_supply': None,
#   'name': 'Status',
#   'percent_change_1h': 0.17,
#   'percent_change_24h': 2.81,
#   'percent_change_7d': 6.16,
#   'price_btc': 2.604e-05,
#   'price_usd': 0.221422,
#   'rank': 31,
#   'symbol': 'SNT',
#   'total_supply': 6804870174.0},
#  {'24h_volume_usd': 11211200.0,
#   'available_supply': 32422297685.0,
#   'id': 'siacoin',
#   'last_updated': 1518420845,
#   'market_cap_usd': 764767431.0,
#   'max_supply': None,
#   'name': 'Siacoin',
#   'percent_change_1h': 0.51,
#   'percent_change_24h': 8.86,
#   'percent_change_7d': 6.57,
#   'price_btc': 2.77e-06,
#   'price_usd': 0.0235877,
#   'rank': 32,
#   'symbol': 'SC',
#   'total_supply': 32422297685.0},
#  {'24h_volume_usd': 8722580.0,
#   'available_supply': 98737352.0,
#   'id': 'stratis',
#   'last_updated': 1518420848,
#   'market_cap_usd': 724979009.0,
#   'max_supply': None,
#   'name': 'Stratis',
#   'percent_change_1h': 1.29,
#   'percent_change_24h': 7.84,
#   'percent_change_7d': -2.85,
#   'price_btc': 0.00086154,
#   'price_usd': 7.3425,
#   'rank': 33,
#   'symbol': 'STRAT',
#   'total_supply': 98737352.0},
#  {'24h_volume_usd': 574282.0,
#   'available_supply': 618228.0,
#   'id': 'maker',
#   'last_updated': 1518420549,
#   'market_cap_usd': 645639989.0,
#   'max_supply': None,
#   'name': 'Maker',
#   'percent_change_1h': 0.98,
#   'percent_change_24h': 5.7,
#   'percent_change_7d': 4.75,
#   'price_btc': 0.122819,
#   'price_usd': 1044.34,
#   'rank': 34,
#   'symbol': 'MKR',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 17672400.0,
#   'available_supply': 2608580000.0,
#   'id': 'bitshares',
#   'last_updated': 1518420843,
#   'market_cap_usd': 643414083.0,
#   'max_supply': 3600570502.0,
#   'name': 'BitShares',
#   'percent_change_1h': 1.0,
#   'percent_change_24h': 8.02,
#   'percent_change_7d': -1.78,
#   'price_btc': 2.894e-05,
#   'price_usd': 0.246653,
#   'rank': 35,
#   'symbol': 'BTS',
#   'total_supply': 2608580000.0},
#  {'24h_volume_usd': 4752930.0,
#   'available_supply': 233020472.0,
#   'id': 'aeternity',
#   'last_updated': 1518420551,
#   'market_cap_usd': 620843434.0,
#   'max_supply': None,
#   'name': 'Aeternity',
#   'percent_change_1h': 1.19,
#   'percent_change_24h': 10.12,
#   'percent_change_7d': 7.87,
#   'price_btc': 0.00031333,
#   'price_usd': 2.66433,
#   'rank': 36,
#   'symbol': 'AE',
#   'total_supply': 273685830.0},
#  {'24h_volume_usd': 8821250.0,
#   'available_supply': 11000000.0,
#   'id': 'augur',
#   'last_updated': 1518420845,
#   'market_cap_usd': 592135500.0,
#   'max_supply': None,
#   'name': 'Augur',
#   'percent_change_1h': -1.47,
#   'percent_change_24h': 10.17,
#   'percent_change_7d': 11.81,
#   'price_btc': 0.00631628,
#   'price_usd': 53.8305,
#   'rank': 37,
#   'symbol': 'REP',
#   'total_supply': 11000000.0},
#  {'24h_volume_usd': 10450400.0,
#   'available_supply': 113160894892,
#   'id': 'dogecoin',
#   'last_updated': 1518420842,
#   'market_cap_usd': 586534419.0,
#   'max_supply': None,
#   'name': 'Dogecoin',
#   'percent_change_1h': 1.01,
#   'percent_change_24h': 10.63,
#   'percent_change_7d': 22.17,
#   'price_btc': 6.1e-07,
#   'price_usd': 0.00518319,
#   'rank': 38,
#   'symbol': 'DOGE',
#   'total_supply': 113160894892},
#  {'24h_volume_usd': 22448100.0,
#   'available_supply': 100000000.0,
#   'id': 'waves',
#   'last_updated': 1518420847,
#   'market_cap_usd': 569468000.0,
#   'max_supply': None,
#   'name': 'Waves',
#   'percent_change_1h': -1.19,
#   'percent_change_24h': 11.11,
#   'percent_change_7d': 1.77,
#   'price_btc': 0.00066819,
#   'price_usd': 5.69468,
#   'rank': 39,
#   'symbol': 'WAVES',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 624989.0,
#   'available_supply': 344166289.0,
#   'id': 'rchain',
#   'last_updated': 1518420554,
#   'market_cap_usd': 557026255.0,
#   'max_supply': 1000000000.0,
#   'name': 'RChain',
#   'percent_change_1h': 2.08,
#   'percent_change_24h': 17.28,
#   'percent_change_7d': 10.95,
#   'price_btc': 0.00019034,
#   'price_usd': 1.61848,
#   'rank': 40,
#   'symbol': 'RHOC',
#   'total_supply': 870663574.0},
#  {'24h_volume_usd': 119451.0,
#   'available_supply': 2036645.0,
#   'id': 'veritaseum',
#   'last_updated': 1518420551,
#   'market_cap_usd': 555729258.0,
#   'max_supply': None,
#   'name': 'Veritaseum',
#   'percent_change_1h': 0.63,
#   'percent_change_24h': 3.63,
#   'percent_change_7d': -6.94,
#   'price_btc': 0.03209,
#   'price_usd': 272.865,
#   'rank': 41,
#   'symbol': 'VERI',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 6232340.0,
#   'available_supply': 24898178.0,
#   'id': 'walton',
#   'last_updated': 1518420553,
#   'market_cap_usd': 540088787.0,
#   'max_supply': 100000000.0,
#   'name': 'Walton',
#   'percent_change_1h': 1.55,
#   'percent_change_24h': 10.0,
#   'percent_change_7d': -3.1,
#   'price_btc': 0.00255105,
#   'price_usd': 21.6919,
#   'rank': 42,
#   'symbol': 'WTC',
#   'total_supply': 70000000.0},
#  {'24h_volume_usd': 4770730.0,
#   'available_supply': 507436130.0,
#   'id': '0x',
#   'last_updated': 1518420553,
#   'market_cap_usd': 535877925.0,
#   'max_supply': None,
#   'name': '0x',
#   'percent_change_1h': 0.71,
#   'percent_change_24h': 10.46,
#   'percent_change_7d': -0.35,
#   'price_btc': 0.0001242,
#   'price_usd': 1.05605,
#   'rank': 43,
#   'symbol': 'ZRX',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 11952500.0,
#   'available_supply': 998999495.0,
#   'id': 'ardor',
#   'last_updated': 1518420847,
#   'market_cap_usd': 516331890.0,
#   'max_supply': 998999495.0,
#   'name': 'Ardor',
#   'percent_change_1h': 0.22,
#   'percent_change_24h': 9.93,
#   'percent_change_7d': 23.47,
#   'price_btc': 6.065e-05,
#   'price_usd': 0.516849,
#   'rank': 44,
#   'symbol': 'ARDR',
#   'total_supply': 998999495.0},
#  {'24h_volume_usd': 66485900.0,
#   'available_supply': 42613630.0,
#   'id': 'hshare',
#   'last_updated': 1518420553,
#   'market_cap_usd': 515855041.0,
#   'max_supply': 84000000.0,
#   'name': 'Hshare',
#   'percent_change_1h': 0.23,
#   'percent_change_24h': 8.19,
#   'percent_change_7d': 20.62,
#   'price_btc': 0.00142364,
#   'price_usd': 12.1054,
#   'rank': 45,
#   'symbol': 'HSR',
#   'total_supply': 42613630.0},
#  {'24h_volume_usd': 801241.0,
#   'available_supply': 6740210.0,
#   'id': 'decred',
#   'last_updated': 1518420846,
#   'market_cap_usd': 503418203.0,
#   'max_supply': 21000000.0,
#   'name': 'Decred',
#   'percent_change_1h': -0.18,
#   'percent_change_24h': 4.66,
#   'percent_change_7d': 5.86,
#   'price_btc': 0.00876372,
#   'price_usd': 74.6888,
#   'rank': 46,
#   'symbol': 'DCR',
#   'total_supply': 7160210.0},
#  {'24h_volume_usd': 1653550.0,
#   'available_supply': 91043076.0,
#   'id': 'kucoin-shares',
#   'last_updated': 1518420556,
#   'market_cap_usd': 489038793.0,
#   'max_supply': None,
#   'name': 'KuCoin Shares',
#   'percent_change_1h': -0.13,
#   'percent_change_24h': 3.0,
#   'percent_change_7d': -7.89,
#   'price_btc': 0.00063171,
#   'price_usd': 5.37151,
#   'rank': 47,
#   'symbol': 'KCS',
#   'total_supply': 181043076.0},
#  {'24h_volume_usd': 18322300.0,
#   'available_supply': 184450000.0,
#   'id': 'revain',
#   'last_updated': 1518420556,
#   'market_cap_usd': 481949405.0,
#   'max_supply': 484450000.0,
#   'name': 'Revain',
#   'percent_change_1h': 1.08,
#   'percent_change_24h': 11.83,
#   'percent_change_7d': 73.78,
#   'price_btc': 0.00030729,
#   'price_usd': 2.6129,
#   'rank': 48,
#   'symbol': 'R',
#   'total_supply': 484450000.0},
#  {'24h_volume_usd': 7262810.0,
#   'available_supply': 2000000.0,
#   'id': 'digixdao',
#   'last_updated': 1518420846,
#   'market_cap_usd': 475980000.0,
#   'max_supply': None,
#   'name': 'DigixDAO',
#   'percent_change_1h': 0.56,
#   'percent_change_24h': 5.23,
#   'percent_change_7d': -18.03,
#   'price_btc': 0.0279249,
#   'price_usd': 237.99,
#   'rank': 49,
#   'symbol': 'DGD',
#   'total_supply': 2000000.0},
#  {'24h_volume_usd': 2043960.0,
#   'available_supply': 103247396.0,
#   'id': 'komodo',
#   'last_updated': 1518420549,
#   'market_cap_usd': 421163680.0,
#   'max_supply': None,
#   'name': 'Komodo',
#   'percent_change_1h': -0.22,
#   'percent_change_24h': 5.94,
#   'percent_change_7d': -0.43,
#   'price_btc': 0.00047973,
#   'price_usd': 4.07917,
#   'rank': 50,
#   'symbol': 'KMD',
#   'total_supply': 103247396.0},
#  {'24h_volume_usd': 1822990.0,
#   'available_supply': 6129583053.0,
#   'id': 'electroneum',
#   'last_updated': 1518420556,
#   'market_cap_usd': 414110340.0,
#   'max_supply': 21000000000.0,
#   'name': 'Electroneum',
#   'percent_change_1h': 0.89,
#   'percent_change_24h': 8.96,
#   'percent_change_7d': 17.54,
#   'price_btc': 7.95e-06,
#   'price_usd': 0.0675593,
#   'rank': 51,
#   'symbol': 'ETN',
#   'total_supply': 6129583053.0},
#  {'24h_volume_usd': 1844790.0,
#   'available_supply': 100578952.0,
#   'id': 'ark',
#   'last_updated': 1518420550,
#   'market_cap_usd': 403085237.0,
#   'max_supply': None,
#   'name': 'Ark',
#   'percent_change_1h': 0.51,
#   'percent_change_24h': 8.88,
#   'percent_change_7d': 1.09,
#   'price_btc': 0.00047131,
#   'price_usd': 4.00765,
#   'rank': 52,
#   'symbol': 'ARK',
#   'total_supply': 131828952.0},
#  {'24h_volume_usd': 4319210.0,
#   'available_supply': 9690946.0,
#   'id': 'gas',
#   'last_updated': 1518420553,
#   'market_cap_usd': 393158755.0,
#   'max_supply': 100000000.0,
#   'name': 'Gas',
#   'percent_change_1h': 1.81,
#   'percent_change_24h': 9.49,
#   'percent_change_7d': 2.15,
#   'price_btc': 0.00477116,
#   'price_usd': 40.5697,
#   'rank': 53,
#   'symbol': 'GAS',
#   'total_supply': 15329112.0},
#  {'24h_volume_usd': 10475600.0,
#   'available_supply': 134132697.0,
#   'id': 'kyber-network',
#   'last_updated': 1518420554,
#   'market_cap_usd': 390238962.0,
#   'max_supply': None,
#   'name': 'Kyber Network',
#   'percent_change_1h': 0.84,
#   'percent_change_24h': -3.19,
#   'percent_change_7d': -7.93,
#   'price_btc': 0.00034215,
#   'price_usd': 2.90935,
#   'rank': 54,
#   'symbol': 'KNC',
#   'total_supply': 215625349.0},
#  {'24h_volume_usd': 3402440.0,
#   'available_supply': 1000000000.0,
#   'id': 'basic-attention-token',
#   'last_updated': 1518420551,
#   'market_cap_usd': 365587000.0,
#   'max_supply': None,
#   'name': 'Basic Attention Token',
#   'percent_change_1h': 1.56,
#   'percent_change_24h': 9.98,
#   'percent_change_7d': 1.65,
#   'price_btc': 4.299e-05,
#   'price_usd': 0.365587,
#   'rank': 55,
#   'symbol': 'BAT',
#   'total_supply': 1500000000.0},
#  {'24h_volume_usd': 10967700.0,
#   'available_supply': 987000000.0,
#   'id': 'bytom',
#   'last_updated': 1518420552,
#   'market_cap_usd': 362203338.0,
#   'max_supply': None,
#   'name': 'Bytom',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': 10.56,
#   'percent_change_7d': 25.18,
#   'price_btc': 4.316e-05,
#   'price_usd': 0.366974,
#   'rank': 56,
#   'symbol': 'BTM',
#   'total_supply': 1407000000.0},
#  {'24h_volume_usd': 494929.0,
#   'available_supply': 325226613094,
#   'id': 'dentacoin',
#   'last_updated': 1518420553,
#   'market_cap_usd': 359294101.0,
#   'max_supply': 8000000000000,
#   'name': 'Dentacoin',
#   'percent_change_1h': 3.91,
#   'percent_change_24h': 8.02,
#   'percent_change_7d': -0.77,
#   'price_btc': 1.3e-07,
#   'price_usd': 0.00110475,
#   'rank': 57,
#   'symbol': 'DCN',
#   'total_supply': 1963173416169},
#  {'24h_volume_usd': 2030600.0,
#   'available_supply': 561202251.0,
#   'id': 'loopring',
#   'last_updated': 1518420553,
#   'market_cap_usd': 356017168.0,
#   'max_supply': None,
#   'name': 'Loopring',
#   'percent_change_1h': 0.38,
#   'percent_change_24h': 3.88,
#   'percent_change_7d': -3.74,
#   'price_btc': 7.461e-05,
#   'price_usd': 0.634383,
#   'rank': 58,
#   'symbol': 'LRC',
#   'total_supply': 1374956357.0},
#  {'24h_volume_usd': 2390890.0,
#   'available_supply': 238421940.0,
#   'id': 'dragonchain',
#   'last_updated': 1518420557,
#   'market_cap_usd': 352697576.0,
#   'max_supply': None,
#   'name': 'Dragonchain',
#   'percent_change_1h': 0.35,
#   'percent_change_24h': 12.26,
#   'percent_change_7d': -0.18,
#   'price_btc': 0.00017397,
#   'price_usd': 1.4793,
#   'rank': 59,
#   'symbol': 'DRGN',
#   'total_supply': 433494437.0},
#  {'24h_volume_usd': 3130480.0,
#   'available_supply': 9830343124.0,
#   'id': 'digibyte',
#   'last_updated': 1518420842,
#   'market_cap_usd': 347944995.0,
#   'max_supply': 21000000000.0,
#   'name': 'DigiByte',
#   'percent_change_1h': 1.63,
#   'percent_change_24h': 7.79,
#   'percent_change_7d': 3.25,
#   'price_btc': 4.15e-06,
#   'price_usd': 0.035395,
#   'rank': 60,
#   'symbol': 'DGB',
#   'total_supply': 9830343124.0},
#  {'24h_volume_usd': 441667.0,
#   'available_supply': 645222.0,
#   'id': 'byteball',
#   'last_updated': 1518420548,
#   'market_cap_usd': 342334819.0,
#   'max_supply': None,
#   'name': 'Byteball Bytes',
#   'percent_change_1h': 2.13,
#   'percent_change_24h': 13.16,
#   'percent_change_7d': 9.86,
#   'price_btc': 0.0623971,
#   'price_usd': 530.569,
#   'rank': 61,
#   'symbol': 'GBYTE',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 11033900.0,
#   'available_supply': 6508988220.0,
#   'id': 'zilliqa',
#   'last_updated': 1518420560,
#   'market_cap_usd': 331048443.0,
#   'max_supply': None,
#   'name': 'Zilliqa',
#   'percent_change_1h': 1.39,
#   'percent_change_24h': -0.12,
#   'percent_change_7d': -13.81,
#   'price_btc': 5.98e-06,
#   'price_usd': 0.0508602,
#   'rank': 62,
#   'symbol': 'ZIL',
#   'total_supply': 12600000000.0},
#  {'24h_volume_usd': 2752340.0,
#   'available_supply': 3295538.0,
#   'id': 'zclassic',
#   'last_updated': 1518420548,
#   'market_cap_usd': 328038132.0,
#   'max_supply': 21000000.0,
#   'name': 'ZClassic',
#   'percent_change_1h': 1.39,
#   'percent_change_24h': 10.53,
#   'percent_change_7d': 10.64,
#   'price_btc': 0.0117063,
#   'price_usd': 99.5401,
#   'rank': 63,
#   'symbol': 'ZCL',
#   'total_supply': 3295538.0},
#  {'24h_volume_usd': 2916250.0,
#   'available_supply': 55542612.0,
#   'id': 'pivx',
#   'last_updated': 1518420846,
#   'market_cap_usd': 316970581.0,
#   'max_supply': None,
#   'name': 'PIVX',
#   'percent_change_1h': 0.24,
#   'percent_change_24h': 5.45,
#   'percent_change_7d': 0.15,
#   'price_btc': 0.00066962,
#   'price_usd': 5.7068,
#   'rank': 64,
#   'symbol': 'PIVX',
#   'total_supply': 55542612.0},
#  {'24h_volume_usd': 265324.0,
#   'available_supply': 45111985.0,
#   'id': 'cryptonex',
#   'last_updated': 1518420555,
#   'market_cap_usd': 306461053.0,
#   'max_supply': 210000000.0,
#   'name': 'Cryptonex',
#   'percent_change_1h': 2.01,
#   'percent_change_24h': 7.16,
#   'percent_change_7d': 18.8,
#   'price_btc': 0.00079892,
#   'price_usd': 6.79334,
#   'rank': 65,
#   'symbol': 'CNX',
#   'total_supply': 106549611.0},
#  {'24h_volume_usd': 1895430.0,
#   'available_supply': 75633252.0,
#   'id': 'ethos',
#   'last_updated': 1518420552,
#   'market_cap_usd': 305166557.0,
#   'max_supply': None,
#   'name': 'Ethos',
#   'percent_change_1h': 1.3,
#   'percent_change_24h': 11.71,
#   'percent_change_7d': 18.17,
#   'price_btc': 0.00047451,
#   'price_usd': 4.03482,
#   'rank': 66,
#   'symbol': 'ETHOS',
#   'total_supply': 222295208.0},
#  {'24h_volume_usd': 3651950.0,
#   'available_supply': 350000000.0,
#   'id': 'qash',
#   'last_updated': 1518420557,
#   'market_cap_usd': 303719850.0,
#   'max_supply': None,
#   'name': 'QASH',
#   'percent_change_1h': 0.2,
#   'percent_change_24h': 8.18,
#   'percent_change_7d': 6.2,
#   'price_btc': 0.00010205,
#   'price_usd': 0.867771,
#   'rank': 67,
#   'symbol': 'QASH',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 8597680.0,
#   'available_supply': 35500000.0,
#   'id': 'nebulas-token',
#   'last_updated': 1518420553,
#   'market_cap_usd': 297436040.0,
#   'max_supply': 100000000.0,
#   'name': 'Nebulas',
#   'percent_change_1h': -4.63,
#   'percent_change_24h': 10.4,
#   'percent_change_7d': 13.15,
#   'price_btc': 0.00098534,
#   'price_usd': 8.37848,
#   'rank': 68,
#   'symbol': 'NAS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 38089700.0,
#   'available_supply': 250000000.0,
#   'id': 'aelf',
#   'last_updated': 1518420558,
#   'market_cap_usd': 296292500.0,
#   'max_supply': None,
#   'name': 'aelf',
#   'percent_change_1h': 0.45,
#   'percent_change_24h': 3.7,
#   'percent_change_7d': -9.67,
#   'price_btc': 0.00013938,
#   'price_usd': 1.18517,
#   'rank': 69,
#   'symbol': 'ELF',
#   'total_supply': 260000000.0},
#  {'24h_volume_usd': 1511450.0,
#   'available_supply': 11172859.0,
#   'id': 'bitcore',
#   'last_updated': 1518420551,
#   'market_cap_usd': 291882003.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcore',
#   'percent_change_1h': 1.58,
#   'percent_change_24h': 6.65,
#   'percent_change_7d': 4.95,
#   'price_btc': 0.00307231,
#   'price_usd': 26.1242,
#   'rank': 70,
#   'symbol': 'BTX',
#   'total_supply': 16799797.0},
#  {'24h_volume_usd': 4274690.0,
#   'available_supply': 834262000.0,
#   'id': 'golem-network-tokens',
#   'last_updated': 1518420548,
#   'market_cap_usd': 289463886.0,
#   'max_supply': None,
#   'name': 'Golem',
#   'percent_change_1h': 0.24,
#   'percent_change_24h': 10.36,
#   'percent_change_7d': 4.55,
#   'price_btc': 4.081e-05,
#   'price_usd': 0.34697,
#   'rank': 71,
#   'symbol': 'GNT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 13946000.0,
#   'available_supply': 60000000.0,
#   'id': 'gxshares',
#   'last_updated': 1518420551,
#   'market_cap_usd': 283236000.0,
#   'max_supply': 100000000.0,
#   'name': 'GXShares',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': 4.9,
#   'percent_change_7d': 12.9,
#   'price_btc': 0.00055516,
#   'price_usd': 4.7206,
#   'rank': 72,
#   'symbol': 'GXS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 1934150.0,
#   'available_supply': 530893937.0,
#   'id': 'syscoin',
#   'last_updated': 1518420844,
#   'market_cap_usd': 280532851.0,
#   'max_supply': 888000000.0,
#   'name': 'Syscoin',
#   'percent_change_1h': 0.47,
#   'percent_change_24h': 8.33,
#   'percent_change_7d': 22.09,
#   'price_btc': 6.2e-05,
#   'price_usd': 0.528416,
#   'rank': 73,
#   'symbol': 'SYS',
#   'total_supply': 530893937.0},
#  {'24h_volume_usd': 9385380.0,
#   'available_supply': 363837589.0,
#   'id': 'power-ledger',
#   'last_updated': 1518420556,
#   'market_cap_usd': 270793038.0,
#   'max_supply': None,
#   'name': 'Power Ledger',
#   'percent_change_1h': -0.03,
#   'percent_change_24h': 11.58,
#   'percent_change_7d': 28.33,
#   'price_btc': 8.753e-05,
#   'price_usd': 0.744269,
#   'rank': 74,
#   'symbol': 'POWR',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 420200.0,
#   'available_supply': 227384800.0,
#   'id': 'pillar',
#   'last_updated': 1518420552,
#   'market_cap_usd': 268539175.0,
#   'max_supply': None,
#   'name': 'Pillar',
#   'percent_change_1h': -1.76,
#   'percent_change_24h': 10.01,
#   'percent_change_7d': 3.6,
#   'price_btc': 0.00013889,
#   'price_usd': 1.18099,
#   'rank': 75,
#   'symbol': 'PLR',
#   'total_supply': 800000000.0},
#  {'24h_volume_usd': 5867840.0,
#   'available_supply': 1445976590.0,
#   'id': 'cindicator',
#   'last_updated': 1518420555,
#   'market_cap_usd': 258416260.0,
#   'max_supply': None,
#   'name': 'Cindicator',
#   'percent_change_1h': 3.43,
#   'percent_change_24h': 12.56,
#   'percent_change_7d': 1.46,
#   'price_btc': 2.102e-05,
#   'price_usd': 0.178714,
#   'rank': 76,
#   'symbol': 'CND',
#   'total_supply': 2000000005.0},
#  {'24h_volume_usd': 54730200.0,
#   'available_supply': 6794109922.0,
#   'id': 'iostoken',
#   'last_updated': 1518420559,
#   'market_cap_usd': 257343219.0,
#   'max_supply': None,
#   'name': 'IOStoken',
#   'percent_change_1h': 0.51,
#   'percent_change_24h': 10.49,
#   'percent_change_7d': 0.27,
#   'price_btc': 4.45e-06,
#   'price_usd': 0.0378774,
#   'rank': 77,
#   'symbol': 'IOST',
#   'total_supply': 21000000000.0},
#  {'24h_volume_usd': 2350790.0,
#   'available_supply': 10614760961.0,
#   'id': 'dent',
#   'last_updated': 1518420553,
#   'market_cap_usd': 256803973.0,
#   'max_supply': None,
#   'name': 'Dent',
#   'percent_change_1h': 0.39,
#   'percent_change_24h': 11.01,
#   'percent_change_7d': 3.66,
#   'price_btc': 2.85e-06,
#   'price_usd': 0.0241931,
#   'rank': 78,
#   'symbol': 'DENT',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 4751520.0,
#   'available_supply': 4503688789.0,
#   'id': 'funfair',
#   'last_updated': 1518420551,
#   'market_cap_usd': 242547511.0,
#   'max_supply': None,
#   'name': 'FunFair',
#   'percent_change_1h': 1.42,
#   'percent_change_24h': 3.06,
#   'percent_change_7d': 11.61,
#   'price_btc': 6.33e-06,
#   'price_usd': 0.0538553,
#   'rank': 79,
#   'symbol': 'FUN',
#   'total_supply': 10999873621.0},
#  {'24h_volume_usd': 4277760.0,
#   'available_supply': 8745102.0,
#   'id': 'factom',
#   'last_updated': 1518420846,
#   'market_cap_usd': 242241074.0,
#   'max_supply': None,
#   'name': 'Factom',
#   'percent_change_1h': 3.91,
#   'percent_change_24h': 12.16,
#   'percent_change_7d': 7.72,
#   'price_btc': 0.00325024,
#   'price_usd': 27.7002,
#   'rank': 80,
#   'symbol': 'FCT',
#   'total_supply': 8745102.0},
#  {'24h_volume_usd': 3702950.0,
#   'available_supply': 79265735.0,
#   'id': 'aion',
#   'last_updated': 1518420555,
#   'market_cap_usd': 227135963.0,
#   'max_supply': None,
#   'name': 'Aion',
#   'percent_change_1h': 0.46,
#   'percent_change_24h': 11.65,
#   'percent_change_7d': -1.15,
#   'price_btc': 0.00033699,
#   'price_usd': 2.8655,
#   'rank': 81,
#   'symbol': 'AION',
#   'total_supply': 465934587.0},
#  {'24h_volume_usd': 2509220.0,
#   'available_supply': 57366575.0,
#   'id': 'monacoin',
#   'last_updated': 1518420842,
#   'market_cap_usd': 227107386.0,
#   'max_supply': None,
#   'name': 'MonaCoin',
#   'percent_change_1h': 1.02,
#   'percent_change_24h': 2.02,
#   'percent_change_7d': 4.08,
#   'price_btc': 0.00046452,
#   'price_usd': 3.95888,
#   'rank': 82,
#   'symbol': 'MONA',
#   'total_supply': 57366575.0},
#  {'24h_volume_usd': 11184000.0,
#   'available_supply': 74836171.0,
#   'id': 'enigma-project',
#   'last_updated': 1518420555,
#   'market_cap_usd': 220784665.0,
#   'max_supply': None,
#   'name': 'Enigma',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': 18.32,
#   'percent_change_7d': 27.92,
#   'price_btc': 0.00034696,
#   'price_usd': 2.95024,
#   'rank': 83,
#   'symbol': 'ENG',
#   'total_supply': 150000000.0},
#  {'24h_volume_usd': 3320910.0,
#   'available_supply': 53005985.0,
#   'id': 'salt',
#   'last_updated': 1518420554,
#   'market_cap_usd': 220605610.0,
#   'max_supply': None,
#   'name': 'SALT',
#   'percent_change_1h': 0.63,
#   'percent_change_24h': 2.34,
#   'percent_change_7d': 2.36,
#   'price_btc': 0.00048946,
#   'price_usd': 4.1619,
#   'rank': 84,
#   'symbol': 'SALT',
#   'total_supply': 120000000.0},
#  {'24h_volume_usd': 6404460.0,
#   'available_supply': 4085695.0,
#   'id': 'zcoin',
#   'last_updated': 1518420848,
#   'market_cap_usd': 219247393.0,
#   'max_supply': None,
#   'name': 'ZCoin',
#   'percent_change_1h': 1.94,
#   'percent_change_24h': 9.93,
#   'percent_change_7d': 14.22,
#   'price_btc': 0.00629653,
#   'price_usd': 53.6622,
#   'rank': 85,
#   'symbol': 'XZC',
#   'total_supply': 4085695.0},
#  {'24h_volume_usd': 194001.0,
#   'available_supply': 691507898.0,
#   'id': 'smartcash',
#   'last_updated': 1518420552,
#   'market_cap_usd': 218579423.0,
#   'max_supply': 5000000000.0,
#   'name': 'SmartCash',
#   'percent_change_1h': 0.26,
#   'percent_change_24h': 2.26,
#   'percent_change_7d': -8.26,
#   'price_btc': 3.717e-05,
#   'price_usd': 0.316091,
#   'rank': 86,
#   'symbol': 'SMART',
#   'total_supply': 1292552177.0},
#  {'24h_volume_usd': 455911.0,
#   'available_supply': 756097560976,
#   'id': 'kin',
#   'last_updated': 1518420554,
#   'market_cap_usd': 204877488.0,
#   'max_supply': None,
#   'name': 'Kin',
#   'percent_change_1h': 3.22,
#   'percent_change_24h': 0.13,
#   'percent_change_7d': -2.49,
#   'price_btc': 3e-08,
#   'price_usd': 0.000270967,
#   'rank': 87,
#   'symbol': 'KIN',
#   'total_supply': 10000000000000},
#  {'24h_volume_usd': 270523.0,
#   'available_supply': 8868441.0,
#   'id': 'particl',
#   'last_updated': 1518420552,
#   'market_cap_usd': 204728837.0,
#   'max_supply': None,
#   'name': 'Particl',
#   'percent_change_1h': 1.16,
#   'percent_change_24h': 5.54,
#   'percent_change_7d': 24.11,
#   'price_btc': 0.0027149,
#   'price_usd': 23.0851,
#   'rank': 88,
#   'symbol': 'PART',
#   'total_supply': 8868441.0},
#  {'24h_volume_usd': 2820700.0,
#   'available_supply': 452552412.0,
#   'id': 'maidsafecoin',
#   'last_updated': 1518420842,
#   'market_cap_usd': 197903433.0,
#   'max_supply': None,
#   'name': 'MaidSafeCoin',
#   'percent_change_1h': 1.02,
#   'percent_change_24h': 15.6,
#   'percent_change_7d': 16.91,
#   'price_btc': 5.131e-05,
#   'price_usd': 0.437305,
#   'rank': 89,
#   'symbol': 'MAID',
#   'total_supply': 452552412.0},
#  {'24h_volume_usd': 3726570.0,
#   'available_supply': 38750987.0,
#   'id': 'bancor',
#   'last_updated': 1518420551,
#   'market_cap_usd': 196416354.0,
#   'max_supply': None,
#   'name': 'Bancor',
#   'percent_change_1h': 0.73,
#   'percent_change_24h': 5.97,
#   'percent_change_7d': 0.13,
#   'price_btc': 0.0005961,
#   'price_usd': 5.06868,
#   'rank': 90,
#   'symbol': 'BNT',
#   'total_supply': 74903592.0},
#  {'24h_volume_usd': 3800540.0,
#   'available_supply': 104661310.0,
#   'id': 'tenx',
#   'last_updated': 1518420551,
#   'market_cap_usd': 191299942.0,
#   'max_supply': None,
#   'name': 'TenX',
#   'percent_change_1h': 0.85,
#   'percent_change_24h': 12.43,
#   'percent_change_7d': 12.15,
#   'price_btc': 0.00021496,
#   'price_usd': 1.8278,
#   'rank': 91,
#   'symbol': 'PAY',
#   'total_supply': 205218256.0},
#  {'24h_volume_usd': 4117710.0,
#   'available_supply': 998999942.0,
#   'id': 'nxt',
#   'last_updated': 1518420841,
#   'market_cap_usd': 189741058.0,
#   'max_supply': 1000000000.0,
#   'name': 'Nxt',
#   'percent_change_1h': 1.12,
#   'percent_change_24h': 7.23,
#   'percent_change_7d': 3.1,
#   'price_btc': 2.229e-05,
#   'price_usd': 0.189931,
#   'rank': 92,
#   'symbol': 'NXT',
#   'total_supply': 998999942.0},
#  {'24h_volume_usd': 159901.0,
#   'available_supply': 239570250.0,
#   'id': 'polymath-network',
#   'last_updated': 1518420560,
#   'market_cap_usd': 184585763.0,
#   'max_supply': None,
#   'name': 'Polymath',
#   'percent_change_1h': 2.88,
#   'percent_change_24h': 2.85,
#   'percent_change_7d': -22.41,
#   'price_btc': 9.061e-05,
#   'price_usd': 0.770487,
#   'rank': 93,
#   'symbol': 'POLY',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 1159020.0,
#   'available_supply': 214015940521,
#   'id': 'experience-points',
#   'last_updated': 1518420847,
#   'market_cap_usd': 184559643.0,
#   'max_supply': None,
#   'name': 'Experience Points',
#   'percent_change_1h': -1.97,
#   'percent_change_24h': 12.38,
#   'percent_change_7d': 60.69,
#   'price_btc': 1e-07,
#   'price_usd': 0.000862364,
#   'rank': 94,
#   'symbol': 'XP',
#   'total_supply': 249047708386},
#  {'24h_volume_usd': 1056970.0,
#   'available_supply': 28750718900.0,
#   'id': 'reddcoin',
#   'last_updated': 1518420842,
#   'market_cap_usd': 184387848.0,
#   'max_supply': None,
#   'name': 'ReddCoin',
#   'percent_change_1h': 0.55,
#   'percent_change_24h': 8.43,
#   'percent_change_7d': 4.35,
#   'price_btc': 7.5e-07,
#   'price_usd': 0.00641333,
#   'rank': 95,
#   'symbol': 'RDD',
#   'total_supply': 28750718900.0},
#  {'24h_volume_usd': 4790000.0,
#   'available_supply': 617314171.0,
#   'id': 'quantstamp',
#   'last_updated': 1518420557,
#   'market_cap_usd': 181348384.0,
#   'max_supply': None,
#   'name': 'Quantstamp',
#   'percent_change_1h': 1.2,
#   'percent_change_24h': 12.75,
#   'percent_change_7d': 20.71,
#   'price_btc': 3.455e-05,
#   'price_usd': 0.29377,
#   'rank': 96,
#   'symbol': 'QSP',
#   'total_supply': 976442388.0},
#  {'24h_volume_usd': 5485230.0,
#   'available_supply': 761143950.0,
#   'id': 'ignis',
#   'last_updated': 1518420557,
#   'market_cap_usd': 177636536.0,
#   'max_supply': 999449694.0,
#   'name': 'Ignis',
#   'percent_change_1h': 0.3,
#   'percent_change_24h': 8.33,
#   'percent_change_7d': 5.51,
#   'price_btc': 2.745e-05,
#   'price_usd': 0.233381,
#   'rank': 97,
#   'symbol': 'IGNIS',
#   'total_supply': 999449694.0},
#  {'24h_volume_usd': 2486660.0,
#   'available_supply': 641462769.0,
#   'id': 'request-network',
#   'last_updated': 1518420555,
#   'market_cap_usd': 172511790.0,
#   'max_supply': None,
#   'name': 'Request Network',
#   'percent_change_1h': 1.59,
#   'percent_change_24h': 6.15,
#   'percent_change_7d': 2.0,
#   'price_btc': 3.163e-05,
#   'price_usd': 0.268935,
#   'rank': 98,
#   'symbol': 'REQ',
#   'total_supply': 999999999.0},
#  {'24h_volume_usd': 843090.0,
#   'available_supply': 455552782.0,
#   'id': 'singularitynet',
#   'last_updated': 1518420559,
#   'market_cap_usd': 168064355.0,
#   'max_supply': None,
#   'name': 'SingularityNET',
#   'percent_change_1h': -3.03,
#   'percent_change_24h': 0.91,
#   'percent_change_7d': -15.54,
#   'price_btc': 4.339e-05,
#   'price_usd': 0.368924,
#   'rank': 99,
#   'symbol': 'AGI',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 945614.0,
#   'available_supply': 41332601.0,
#   'id': 'emercoin',
#   'last_updated': 1518420844,
#   'market_cap_usd': 164442166.0,
#   'max_supply': None,
#   'name': 'Emercoin',
#   'percent_change_1h': 0.38,
#   'percent_change_24h': 14.68,
#   'percent_change_7d': 20.84,
#   'price_btc': 0.00046682,
#   'price_usd': 3.97851,
#   'rank': 100,
#   'symbol': 'EMC',
#   'total_supply': 41332601.0},
#  {'24h_volume_usd': 92999.5,
#   'available_supply': 4981227.0,
#   'id': 'e-coin',
#   'last_updated': 1518420550,
#   'market_cap_usd': 163002196.0,
#   'max_supply': None,
#   'name': 'E-coin',
#   'percent_change_1h': 7.35,
#   'percent_change_24h': 24.88,
#   'percent_change_7d': 461.1,
#   'price_btc': 0.0038484,
#   'price_usd': 32.7233,
#   'rank': 101,
#   'symbol': 'ECN',
#   'total_supply': 213270119.0},
#  {'24h_volume_usd': 935801.0,
#   'available_supply': 55519477.0,
#   'id': 'nexus',
#   'last_updated': 1518420844,
#   'market_cap_usd': 160738324.0,
#   'max_supply': None,
#   'name': 'Nexus',
#   'percent_change_1h': 2.51,
#   'percent_change_24h': 2.67,
#   'percent_change_7d': -3.8,
#   'price_btc': 0.00033971,
#   'price_usd': 2.89517,
#   'rank': 102,
#   'symbol': 'NXS',
#   'total_supply': 55519477.0},
#  {'24h_volume_usd': 182663.0,
#   'available_supply': 1000000000.0,
#   'id': 'xplay',
#   'last_updated': 1518420554,
#   'market_cap_usd': 159691000.0,
#   'max_supply': None,
#   'name': 'XPlay',
#   'percent_change_1h': 0.49,
#   'percent_change_24h': 5.12,
#   'percent_change_7d': 19.76,
#   'price_btc': 1.878e-05,
#   'price_usd': 0.159691,
#   'rank': 103,
#   'symbol': 'XPA',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 3810710.0,
#   'available_supply': 492954537.0,
#   'id': 'wax',
#   'last_updated': 1518420558,
#   'market_cap_usd': 159316498.0,
#   'max_supply': None,
#   'name': 'WAX',
#   'percent_change_1h': 1.25,
#   'percent_change_24h': -2.43,
#   'percent_change_7d': 3.8,
#   'price_btc': 3.801e-05,
#   'price_usd': 0.323187,
#   'rank': 104,
#   'symbol': 'WAX',
#   'total_supply': 1850000000.0},
#  {'24h_volume_usd': 508301.0,
#   'available_supply': 99735687.0,
#   'id': 'iconomi',
#   'last_updated': 1518420547,
#   'market_cap_usd': 159206082.0,
#   'max_supply': None,
#   'name': 'Iconomi',
#   'percent_change_1h': 0.15,
#   'percent_change_24h': 6.05,
#   'percent_change_7d': -2.88,
#   'price_btc': 0.00018773,
#   'price_usd': 1.59628,
#   'rank': 105,
#   'symbol': 'ICN',
#   'total_supply': 99735687.0},
#  {'24h_volume_usd': 3023820.0,
#   'available_supply': 226091449.0,
#   'id': 'substratum',
#   'last_updated': 1518420554,
#   'market_cap_usd': 157661481.0,
#   'max_supply': None,
#   'name': 'Substratum',
#   'percent_change_1h': 1.85,
#   'percent_change_24h': 12.4,
#   'percent_change_7d': 16.68,
#   'price_btc': 8.201e-05,
#   'price_usd': 0.697335,
#   'rank': 106,
#   'symbol': 'SUB',
#   'total_supply': 352000000.0},
#  {'24h_volume_usd': 3644600.0,
#   'available_supply': 350000000.0,
#   'id': 'chainlink',
#   'last_updated': 1518420554,
#   'market_cap_usd': 156473100.0,
#   'max_supply': None,
#   'name': 'ChainLink',
#   'percent_change_1h': 0.57,
#   'percent_change_24h': 15.81,
#   'percent_change_7d': 12.28,
#   'price_btc': 5.258e-05,
#   'price_usd': 0.447066,
#   'rank': 107,
#   'symbol': 'LINK',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 255374.0,
#   'available_supply': 1104590.0,
#   'id': 'gnosis-gno',
#   'last_updated': 1518420551,
#   'market_cap_usd': 155775909.0,
#   'max_supply': None,
#   'name': 'Gnosis',
#   'percent_change_1h': 0.84,
#   'percent_change_24h': 5.46,
#   'percent_change_7d': 5.09,
#   'price_btc': 0.0165853,
#   'price_usd': 141.026,
#   'rank': 108,
#   'symbol': 'GNO',
#   'total_supply': 10000000.0},
#  {'24h_volume_usd': 2742500.0,
#   'available_supply': 12809069.0,
#   'id': 'neblio',
#   'last_updated': 1518420554,
#   'market_cap_usd': 154657978.0,
#   'max_supply': None,
#   'name': 'Neblio',
#   'percent_change_1h': -2.24,
#   'percent_change_24h': 12.86,
#   'percent_change_7d': 6.0,
#   'price_btc': 0.00141996,
#   'price_usd': 12.0741,
#   'rank': 109,
#   'symbol': 'NEBL',
#   'total_supply': 13555908.0},
#  {'24h_volume_usd': 1007470.0,
#   'available_supply': 64355352.0,
#   'id': 'gamecredits',
#   'last_updated': 1518420843,
#   'market_cap_usd': 150568356.0,
#   'max_supply': 84000000.0,
#   'name': 'GameCredits',
#   'percent_change_1h': 1.12,
#   'percent_change_24h': 6.76,
#   'percent_change_7d': 1.06,
#   'price_btc': 0.00027453,
#   'price_usd': 2.33964,
#   'rank': 110,
#   'symbol': 'GAME',
#   'total_supply': 64355352.0},
#  {'24h_volume_usd': 5730350.0,
#   'available_supply': 6895574489.0,
#   'id': 'digitalnote',
#   'last_updated': 1518420843,
#   'market_cap_usd': 146009652.0,
#   'max_supply': None,
#   'name': 'DigitalNote',
#   'percent_change_1h': 1.78,
#   'percent_change_24h': 6.99,
#   'percent_change_7d': 26.58,
#   'price_btc': 2.48e-06,
#   'price_usd': 0.0211744,
#   'rank': 111,
#   'symbol': 'XDN',
#   'total_supply': 6895574489.0},
#  {'24h_volume_usd': 4243040.0,
#   'available_supply': 342699966.0,
#   'id': 'civic',
#   'last_updated': 1518420552,
#   'market_cap_usd': 145097795.0,
#   'max_supply': None,
#   'name': 'Civic',
#   'percent_change_1h': -0.3,
#   'percent_change_24h': 8.61,
#   'percent_change_7d': 21.17,
#   'price_btc': 4.979e-05,
#   'price_usd': 0.423396,
#   'rank': 112,
#   'symbol': 'CVC',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 23617600.0,
#   'available_supply': 2216707776.0,
#   'id': 'poet',
#   'last_updated': 1518420553,
#   'market_cap_usd': 143429860.0,
#   'max_supply': None,
#   'name': 'Po.et',
#   'percent_change_1h': 0.95,
#   'percent_change_24h': 21.28,
#   'percent_change_7d': 13.79,
#   'price_btc': 7.61e-06,
#   'price_usd': 0.064704,
#   'rank': 113,
#   'symbol': 'POE',
#   'total_supply': 3141592653.0},
#  {'24h_volume_usd': 175932.0,
#   'available_supply': 5011081.0,
#   'id': 'blocknet',
#   'last_updated': 1518420844,
#   'market_cap_usd': 142257070.0,
#   'max_supply': None,
#   'name': 'Blocknet',
#   'percent_change_1h': 0.76,
#   'percent_change_24h': 9.34,
#   'percent_change_7d': 6.92,
#   'price_btc': 0.00333101,
#   'price_usd': 28.3885,
#   'rank': 114,
#   'symbol': 'BLOCK',
#   'total_supply': 5011081.0},
#  {'24h_volume_usd': 1860290.0,
#   'available_supply': 42893550.0,
#   'id': 'vertcoin',
#   'last_updated': 1518420841,
#   'market_cap_usd': 137388041.0,
#   'max_supply': 84000000.0,
#   'name': 'Vertcoin',
#   'percent_change_1h': 0.45,
#   'percent_change_24h': 8.22,
#   'percent_change_7d': 14.07,
#   'price_btc': 0.00037583,
#   'price_usd': 3.203,
#   'rank': 115,
#   'symbol': 'VTC',
#   'total_supply': 42893550.0},
#  {'24h_volume_usd': 4575410.0,
#   'available_supply': 22216600.0,
#   'id': 'high-performance-blockchain',
#   'last_updated': 1518420558,
#   'market_cap_usd': 136340386.0,
#   'max_supply': None,
#   'name': 'High Performance Blockchain',
#   'percent_change_1h': 0.72,
#   'percent_change_24h': 9.17,
#   'percent_change_7d': -7.36,
#   'price_btc': 0.00072172,
#   'price_usd': 6.13687,
#   'rank': 116,
#   'symbol': 'HPB',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 9037020.0,
#   'available_supply': 543348500.0,
#   'id': 'red-pulse',
#   'last_updated': 1518420556,
#   'market_cap_usd': 133996804.0,
#   'max_supply': None,
#   'name': 'Red Pulse',
#   'percent_change_1h': -0.52,
#   'percent_change_24h': 66.58,
#   'percent_change_7d': 90.79,
#   'price_btc': 2.9e-05,
#   'price_usd': 0.246613,
#   'rank': 117,
#   'symbol': 'RPX',
#   'total_supply': 1358371250.0},
#  {'24h_volume_usd': 2558470.0,
#   'available_supply': 50148936.0,
#   'id': 'raiden-network-token',
#   'last_updated': 1518420556,
#   'market_cap_usd': 133356051.0,
#   'max_supply': None,
#   'name': 'Raiden Network Token',
#   'percent_change_1h': 1.43,
#   'percent_change_24h': 10.01,
#   'percent_change_7d': -4.14,
#   'price_btc': 0.00031273,
#   'price_usd': 2.6592,
#   'rank': 118,
#   'symbol': 'RDN',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 537316.0,
#   'available_supply': 7447126.0,
#   'id': 'skycoin',
#   'last_updated': 1518420549,
#   'market_cap_usd': 132476924.0,
#   'max_supply': 100000000.0,
#   'name': 'Skycoin',
#   'percent_change_1h': 1.08,
#   'percent_change_24h': 7.99,
#   'percent_change_7d': 5.67,
#   'price_btc': 0.00209205,
#   'price_usd': 17.789,
#   'rank': 119,
#   'symbol': 'SKY',
#   'total_supply': 25000000.0},
#  {'24h_volume_usd': 42273.2,
#   'available_supply': 1288862.0,
#   'id': 'bitcoindark',
#   'last_updated': 1518420843,
#   'market_cap_usd': 132475700.0,
#   'max_supply': None,
#   'name': 'BitcoinDark',
#   'percent_change_1h': 1.04,
#   'percent_change_24h': 3.74,
#   'percent_change_7d': 13.03,
#   'price_btc': 0.0120604,
#   'price_usd': 102.785,
#   'rank': 120,
#   'symbol': 'BTCD',
#   'total_supply': 1288862.0},
#  {'24h_volume_usd': 3561750.0,
# ...
#   'name': 'Rasputin Online Coin',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': -0.73,
#   'price_btc': 0.00016259,
#   'price_usd': 1.30922,
#   'rank': 960,
#   'symbol': 'ROC',
#   'total_supply': 5000000.0},
#  {'24h_volume_usd': 0.881823,
#   'available_supply': 6695133.0,
#   'id': 'shadowcash',
#   'last_updated': 1518420843,
#   'market_cap_usd': 1342602.0,
#   'max_supply': None,
#   'name': 'ShadowCash',
#   'percent_change_1h': 1.03,
#   'percent_change_24h': 6.85,
#   'percent_change_7d': -12.85,
#   'price_btc': 2.353e-05,
#   'price_usd': 0.200534,
#   'rank': 961,
#   'symbol': 'SDC',
#   'total_supply': 6695133.0},
#  {'24h_volume_usd': 142.287,
#   'available_supply': 10343113.0,
#   'id': 'ultimate-secure-cash',
#   'last_updated': 1518420549,
#   'market_cap_usd': 1340333.0,
#   'max_supply': 200084200.0,
#   'name': 'Ultimate Secure Cash',
#   'percent_change_1h': 61.54,
#   'percent_change_24h': -9.63,
#   'percent_change_7d': -39.1,
#   'price_btc': 1.524e-05,
#   'price_usd': 0.129587,
#   'rank': 962,
#   'symbol': 'USC',
#   'total_supply': 38602656.0},
#  {'24h_volume_usd': 224.067,
#   'available_supply': 3141567.0,
#   'id': 'orbitcoin',
#   'last_updated': 1518420841,
#   'market_cap_usd': 1330667.0,
#   'max_supply': None,
#   'name': 'Orbitcoin',
#   'percent_change_1h': 5.5,
#   'percent_change_24h': 15.34,
#   'percent_change_7d': 7.15,
#   'price_btc': 4.97e-05,
#   'price_usd': 0.423568,
#   'rank': 963,
#   'symbol': 'ORB',
#   'total_supply': 3141567.0},
#  {'24h_volume_usd': None,
#   'available_supply': 7656898.0,
#   'id': 'emphy',
#   'last_updated': 1518193757,
#   'market_cap_usd': 1300930.0,
#   'max_supply': None,
#   'name': 'Emphy',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': -47.51,
#   'price_btc': 2.029e-05,
#   'price_usd': 0.169903,
#   'rank': 964,
#   'symbol': 'EPY',
#   'total_supply': 15375000.0},
#  {'24h_volume_usd': 24.9908,
#   'available_supply': 10291781.0,
#   'id': 'bankcoin',
#   'last_updated': 1518420549,
#   'market_cap_usd': 1196245.0,
#   'max_supply': None,
#   'name': 'Bankcoin',
#   'percent_change_1h': -0.43,
#   'percent_change_24h': -26.9,
#   'percent_change_7d': 16.7,
#   'price_btc': 1.367e-05,
#   'price_usd': 0.116233,
#   'rank': 965,
#   'symbol': 'B@',
#   'total_supply': 25000000.0},
#  {'24h_volume_usd': 3.10645,
#   'available_supply': 100000000.0,
#   'id': 'shorty',
#   'last_updated': 1518420848,
#   'market_cap_usd': 1150540.0,
#   'max_supply': None,
#   'name': 'Shorty',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': -14.73,
#   'percent_change_7d': -14.52,
#   'price_btc': 1.35e-06,
#   'price_usd': 0.0115054,
#   'rank': 966,
#   'symbol': 'SHORTY',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 410.711,
#   'available_supply': 20988240.0,
#   'id': 'i0coin',
#   'last_updated': 1518420841,
#   'market_cap_usd': 1144783.0,
#   'max_supply': None,
#   'name': 'I0Coin',
#   'percent_change_1h': -18.13,
#   'percent_change_24h': 2.9,
#   'percent_change_7d': 19.08,
#   'price_btc': 6.4e-06,
#   'price_usd': 0.054544,
#   'rank': 967,
#   'symbol': 'I0C',
#   'total_supply': 20988240.0},
#  {'24h_volume_usd': 163.27,
#   'available_supply': 4788240.0,
#   'id': 'netko',
#   'last_updated': 1518420550,
#   'market_cap_usd': 1126735.0,
#   'max_supply': None,
#   'name': 'Netko',
#   'percent_change_1h': 14.26,
#   'percent_change_24h': 10.2,
#   'percent_change_7d': 24.66,
#   'price_btc': 2.767e-05,
#   'price_usd': 0.235313,
#   'rank': 968,
#   'symbol': 'NETKO',
#   'total_supply': 4788240.0},
#  {'24h_volume_usd': 193.823,
#   'available_supply': 6914679.0,
#   'id': 'fantomcoin',
#   'last_updated': 1518420843,
#   'market_cap_usd': 1119673.0,
#   'max_supply': None,
#   'name': 'Fantomcoin',
#   'percent_change_1h': 7.64,
#   'percent_change_24h': 12.69,
#   'percent_change_7d': 7.42,
#   'price_btc': 1.9e-05,
#   'price_usd': 0.161927,
#   'rank': 969,
#   'symbol': 'FCN',
#   'total_supply': 6914679.0},
#  {'24h_volume_usd': None,
#   'available_supply': 900000.0,
#   'id': 'giga-watt-token',
#   'last_updated': 1518292153,
#   'market_cap_usd': 1115019.0,
#   'max_supply': None,
#   'name': 'Giga Watt Token',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': -0.93,
#   'price_btc': 0.0001472,
#   'price_usd': 1.23891,
#   'rank': 970,
#   'symbol': 'WTT',
#   'total_supply': 17300000.0},
#  {'24h_volume_usd': 337.542,
#   'available_supply': 24700248.0,
#   'id': 'kobocoin',
#   'last_updated': 1518420845,
#   'market_cap_usd': 1079146.0,
#   'max_supply': None,
#   'name': 'Kobocoin',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': 8.53,
#   'percent_change_7d': -13.83,
#   'price_btc': 5.13e-06,
#   'price_usd': 0.0436897,
#   'rank': 971,
#   'symbol': 'KOBO',
#   'total_supply': 24700248.0},
#  {'24h_volume_usd': 100.327,
#   'available_supply': 45707116.0,
#   'id': 'ultracoin',
#   'last_updated': 1518420841,
#   'market_cap_usd': 1063440.0,
#   'max_supply': None,
#   'name': 'UltraCoin',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': 0.5,
#   'percent_change_7d': 27.78,
#   'price_btc': 2.73e-06,
#   'price_usd': 0.0232664,
#   'rank': 972,
#   'symbol': 'UTC',
#   'total_supply': 45707116.0},
#  {'24h_volume_usd': 479.588,
#   'available_supply': 23079737.0,
#   'id': 'bitstar',
#   'last_updated': 1518420842,
#   'market_cap_usd': 1005974.0,
#   'max_supply': None,
#   'name': 'Bitstar',
#   'percent_change_1h': 0.9,
#   'percent_change_24h': 37.41,
#   'percent_change_7d': 10.85,
#   'price_btc': 5.11e-06,
#   'price_usd': 0.0435869,
#   'rank': 973,
#   'symbol': 'BITS',
#   'total_supply': 23079737.0},
#  {'24h_volume_usd': None,
#   'available_supply': 448747.0,
#   'id': 'nimfamoney',
#   'last_updated': 1518198259,
#   'market_cap_usd': 977330.0,
#   'max_supply': None,
#   'name': 'Nimfamoney',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': -14.19,
#   'price_btc': 0.00025302,
#   'price_usd': 2.17791,
#   'rank': 974,
#   'symbol': 'NIMFA',
#   'total_supply': 1542580.0},
#  {'24h_volume_usd': 413.56,
#   'available_supply': 569188964.0,
#   'id': 'trollcoin',
#   'last_updated': 1518420844,
#   'market_cap_usd': 955241.0,
#   'max_supply': None,
#   'name': 'Trollcoin',
#   'percent_change_1h': -1.8,
#   'percent_change_24h': 10.44,
#   'percent_change_7d': 7.7,
#   'price_btc': 2e-07,
#   'price_usd': 0.00167825,
#   'rank': 975,
#   'symbol': 'TROLL',
#   'total_supply': 569188964.0},
#  {'24h_volume_usd': 116.461,
#   'available_supply': 8035193.0,
#   'id': 'woodcoin',
#   'last_updated': 1518420844,
#   'market_cap_usd': 925164.0,
#   'max_supply': None,
#   'name': 'Woodcoin',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': 6.36,
#   'percent_change_7d': 2.67,
#   'price_btc': 1.351e-05,
#   'price_usd': 0.115139,
#   'rank': 976,
#   'symbol': 'LOG',
#   'total_supply': 8035193.0},
#  {'24h_volume_usd': 311.598,
#   'available_supply': 248425538.0,
#   'id': 'qubitcoin',
#   'last_updated': 1518420841,
#   'market_cap_usd': 910398.0,
#   'max_supply': None,
#   'name': 'QubitCoin',
#   'percent_change_1h': 1.03,
#   'percent_change_24h': -2.33,
#   'percent_change_7d': -20.52,
#   'price_btc': 4.3e-07,
#   'price_usd': 0.00366467,
#   'rank': 977,
#   'symbol': 'Q2C',
#   'total_supply': 248425538.0},
#  {'24h_volume_usd': 163.506,
#   'available_supply': 50939818.0,
#   'id': 'visio',
#   'last_updated': 1518420550,
#   'market_cap_usd': 846981.0,
#   'max_supply': None,
#   'name': 'Visio',
#   'percent_change_1h': 0.8,
#   'percent_change_24h': -3.58,
#   'percent_change_7d': 2.21,
#   'price_btc': 1.96e-06,
#   'price_usd': 0.0166271,
#   'rank': 978,
#   'symbol': 'VISIO',
#   'total_supply': 62939818.0},
#  {'24h_volume_usd': 311.337,
#   'available_supply': 2985382.0,
#   'id': 'unicoin',
#   'last_updated': 1518420845,
#   'market_cap_usd': 843433.0,
#   'max_supply': None,
#   'name': 'UniCoin',
#   'percent_change_1h': 1.03,
#   'percent_change_24h': -1.84,
#   'percent_change_7d': -13.15,
#   'price_btc': 3.315e-05,
#   'price_usd': 0.282521,
#   'rank': 979,
#   'symbol': 'UNIC',
#   'total_supply': 2985382.0},
#  {'24h_volume_usd': 295.042,
#   'available_supply': 1.0,
#   'id': 'bit20',
#   'last_updated': 1518420553,
#   'market_cap_usd': 839364.0,
#   'max_supply': None,
#   'name': 'Bit20',
#   'percent_change_1h': 0.63,
#   'percent_change_24h': 11.04,
#   'percent_change_7d': -21.67,
#   'price_btc': 97.1581,
#   'price_usd': 826146.0,
#   'rank': 980,
#   'symbol': 'BTWTY',
#   'total_supply': 1.0},
#  {'24h_volume_usd': 358.046,
#   'available_supply': 34644058.0,
#   'id': 'deutsche-emark',
#   'last_updated': 1518420842,
#   'market_cap_usd': 800534.0,
#   'max_supply': None,
#   'name': 'Deutsche eMark',
#   'percent_change_1h': 1.14,
#   'percent_change_24h': -0.06,
#   'percent_change_7d': -17.98,
#   'price_btc': 2.71e-06,
#   'price_usd': 0.0231074,
#   'rank': 981,
#   'symbol': 'DEM',
#   'total_supply': 41626034.0},
#  {'24h_volume_usd': 19.6507,
#   'available_supply': 65290635.0,
#   'id': 'btctalkcoin',
#   'last_updated': 1518420842,
#   'market_cap_usd': 795710.0,
#   'max_supply': None,
#   'name': 'BTCtalkcoin',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': 6.76,
#   'percent_change_7d': 38.28,
#   'price_btc': 1.43e-06,
#   'price_usd': 0.0121872,
#   'rank': 982,
#   'symbol': 'TALK',
#   'total_supply': 65290635.0},
#  {'24h_volume_usd': 218.076,
#   'available_supply': 5428300.0,
#   'id': 'blockpay',
#   'last_updated': 1518420848,
#   'market_cap_usd': 795306.0,
#   'max_supply': None,
#   'name': 'BlockPay',
#   'percent_change_1h': 1.59,
#   'percent_change_24h': 56.61,
#   'percent_change_7d': 34.42,
#   'price_btc': 1.719e-05,
#   'price_usd': 0.146511,
#   'rank': 983,
#   'symbol': 'BLOCKPAY',
#   'total_supply': 98928316.0},
#  {'24h_volume_usd': 81.6621,
#   'available_supply': 61445805.0,
#   'id': 'maxcoin',
#   'last_updated': 1518420842,
#   'market_cap_usd': 759323.0,
#   'max_supply': None,
#   'name': 'MaxCoin',
#   'percent_change_1h': 1.03,
#   'percent_change_24h': 8.25,
#   'percent_change_7d': 17.81,
#   'price_btc': 1.45e-06,
#   'price_usd': 0.0123576,
#   'rank': 984,
#   'symbol': 'MAX',
#   'total_supply': 61445805.0},
#  {'24h_volume_usd': None,
#   'available_supply': 23020335.0,
#   'id': 'janus',
#   'last_updated': 1517536153,
#   'market_cap_usd': 744390.0,
#   'max_supply': None,
#   'name': 'Janus',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': None,
#   'price_btc': 3.72e-06,
#   'price_usd': 0.0323362,
#   'rank': 985,
#   'symbol': 'JNS',
#   'total_supply': 25201489.0},
#  {'24h_volume_usd': 14.2047,
#   'available_supply': 169598616.0,
#   'id': 'bitcurrency',
#   'last_updated': 1518420848,
#   'market_cap_usd': 737155.0,
#   'max_supply': None,
#   'name': 'Bitcurrency',
#   'percent_change_1h': 28.86,
#   'percent_change_24h': 7.73,
#   'percent_change_7d': -21.36,
#   'price_btc': 5.1e-07,
#   'price_usd': 0.00434647,
#   'rank': 986,
#   'symbol': 'BTCR',
#   'total_supply': 169598616.0},
#  {'24h_volume_usd': 0.0286356,
#   'available_supply': 1990891.0,
#   'id': 'bitz',
#   'last_updated': 1518420845,
#   'market_cap_usd': 695661.0,
#   'max_supply': None,
#   'name': 'Bitz',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': 4.21,
#   'percent_change_7d': 3.21,
#   'price_btc': 4.1e-05,
#   'price_usd': 0.349422,
#   'rank': 987,
#   'symbol': 'BITZ',
#   'total_supply': 1990891.0},
#  {'24h_volume_usd': 376.153,
#   'available_supply': 15145360.0,
#   'id': 'opal',
#   'last_updated': 1518420844,
#   'market_cap_usd': 673202.0,
#   'max_supply': None,
#   'name': 'Opal',
#   'percent_change_1h': 0.06,
#   'percent_change_24h': -13.69,
#   'percent_change_7d': 7.98,
#   'price_btc': 5.22e-06,
#   'price_usd': 0.0444494,
#   'rank': 988,
#   'symbol': 'OPAL',
#   'total_supply': 15145360.0},
#  {'24h_volume_usd': 239.439,
#   'available_supply': 4225992.0,
#   'id': 'sterlingcoin',
#   'last_updated': 1518420844,
#   'market_cap_usd': 673124.0,
#   'max_supply': None,
#   'name': 'Sterlingcoin',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': 0.76,
#   'percent_change_7d': -7.8,
#   'price_btc': 1.869e-05,
#   'price_usd': 0.159282,
#   'rank': 989,
#   'symbol': 'SLG',
#   'total_supply': 4225992.0},
#  {'24h_volume_usd': 219.84,
#   'available_supply': 64083659.0,
#   'id': 'phoenixcoin',
#   'last_updated': 1518420841,
#   'market_cap_usd': 666303.0,
#   'max_supply': None,
#   'name': 'Phoenixcoin',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': 3.71,
#   'percent_change_7d': 7.36,
#   'price_btc': 1.22e-06,
#   'price_usd': 0.0103974,
#   'rank': 990,
#   'symbol': 'PXC',
#   'total_supply': 64083659.0},
#  {'24h_volume_usd': 445.431,
#   'available_supply': 5848581.0,
#   'id': 'funcoin',
#   'last_updated': 1518420551,
#   'market_cap_usd': 647181.0,
#   'max_supply': 100000000.0,
#   'name': 'FUNCoin',
#   'percent_change_1h': -1.06,
#   'percent_change_24h': -5.93,
#   'percent_change_7d': -18.35,
#   'price_btc': 1.301e-05,
#   'price_usd': 0.110656,
#   'rank': 991,
#   'symbol': 'FUNC',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 383.036,
#   'available_supply': 11856917.0,
#   'id': 'paycoin2',
#   'last_updated': 1518420844,
#   'market_cap_usd': 646420.0,
#   'max_supply': None,
#   'name': 'PayCoin',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': 8.21,
#   'percent_change_7d': 21.6,
#   'price_btc': 6.4e-06,
#   'price_usd': 0.0545184,
#   'rank': 992,
#   'symbol': 'XPY',
#   'total_supply': 11856917.0},
#  {'24h_volume_usd': None,
#   'available_supply': 3284266.0,
#   'id': 'btsr',
#   'last_updated': 1518393547,
#   'market_cap_usd': 640205.0,
#   'max_supply': None,
#   'name': 'BTSR',
#   'percent_change_1h': None,
#   'percent_change_24h': 0.43,
#   'percent_change_7d': 48.8,
#   'price_btc': 2.42e-05,
#   'price_usd': 0.194931,
#   'rank': 993,
#   'symbol': 'BTSR',
#   'total_supply': 3284266.0},
#  {'24h_volume_usd': 5.23997,
#   'available_supply': 43699481.0,
#   'id': 'ambercoin',
#   'last_updated': 1518420844,
#   'market_cap_usd': 618230.0,
#   'max_supply': None,
#   'name': 'AmberCoin',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': 11.66,
#   'percent_change_7d': 0.9,
#   'price_btc': 1.66e-06,
#   'price_usd': 0.0141473,
#   'rank': 994,
#   'symbol': 'AMBER',
#   'total_supply': 43699481.0},
#  {'24h_volume_usd': 140.709,
#   'available_supply': 870581.0,
#   'id': 'litebar',
#   'last_updated': 1518420842,
#   'market_cap_usd': 615895.0,
#   'max_supply': None,
#   'name': 'LiteBar',
#   'percent_change_1h': 1.03,
#   'percent_change_24h': 1.84,
#   'percent_change_7d': 33.72,
#   'price_btc': 8.301e-05,
#   'price_usd': 0.707453,
#   'rank': 995,
#   'symbol': 'LTB',
#   'total_supply': 870581.0},
#  {'24h_volume_usd': 8.5225,
#   'available_supply': 48017503.0,
#   'id': 'supercoin',
#   'last_updated': 1518420842,
#   'market_cap_usd': 609750.0,
#   'max_supply': None,
#   'name': 'SuperCoin',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': -12.49,
#   'percent_change_7d': -4.73,
#   'price_btc': 1.49e-06,
#   'price_usd': 0.0126985,
#   'rank': 996,
#   'symbol': 'SUPER',
#   'total_supply': 48017503.0},
#  {'24h_volume_usd': 377.55,
#   'available_supply': 6513460.0,
#   'id': 'whalecoin',
#   'last_updated': 1518420554,
#   'market_cap_usd': 603897.0,
#   'max_supply': None,
#   'name': 'WhaleCoin',
#   'percent_change_1h': 0.58,
#   'percent_change_24h': -22.41,
#   'percent_change_7d': -27.14,
#   'price_btc': 1.09e-05,
#   'price_usd': 0.0927152,
#   'rank': 997,
#   'symbol': 'WHL',
#   'total_supply': 6513460.0},
#  {'24h_volume_usd': 20.7981,
#   'available_supply': 2358819009.0,
#   'id': 'colossuscoin-v2',
#   'last_updated': 1518420845,
#   'market_cap_usd': 603091.0,
#   'max_supply': None,
#   'name': 'Colossuscoin V2',
#   'percent_change_1h': 1.03,
#   'percent_change_24h': 6.76,
#   'percent_change_7d': 35.32,
#   'price_btc': 3e-08,
#   'price_usd': 0.000255675,
#   'rank': 998,
#   'symbol': 'CV2',
#   'total_supply': 22977351798.0},
#  {'24h_volume_usd': 272.091,
#   'available_supply': 77777777.0,
#   'id': 'ammo-rewards',
#   'last_updated': 1518420550,
#   'market_cap_usd': 601831.0,
#   'max_supply': None,
#   'name': 'Ammo Reloaded',
#   'percent_change_1h': 0.8,
#   'percent_change_24h': -3.61,
#   'percent_change_7d': -3.45,
#   'price_btc': 9.1e-07,
#   'price_usd': 0.00773783,
#   'rank': 999,
#   'symbol': 'AMMO',
#   'total_supply': 77777777.0},
#  {'24h_volume_usd': 175.395,
#   'available_supply': 169681853.0,
#   'id': 'truckcoin',
#   'last_updated': 1518420843,
#   'market_cap_usd': 592906.0,
#   'max_supply': None,
#   'name': 'Truckcoin',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': -0.52,
#   'percent_change_7d': 9.67,
#   'price_btc': 4.1e-07,
#   'price_usd': 0.00349422,
#   'rank': 1000,
#   'symbol': 'TRK',
#   'total_supply': 169681853.0},
#  ...]

# %% [markdown]
# You can pass a currency through symbol or coin slug:

# %%
data_from_symbol = cmc.ticker("BTC")
data_from_slug = cmc.ticker("bitcoin")

data_from_slug
# Out:
# {'24h_volume_usd': 6038960000.0,
#  'available_supply': 16859762.0,
#  'id': 'bitcoin',
#  'last_updated': 1518420567,
#  'market_cap_usd': 143999564437,
#  'max_supply': 21000000.0,
#  'name': 'Bitcoin',
#  'percent_change_1h': 0.71,
#  'percent_change_24h': 6.18,
#  'percent_change_7d': 6.4,
#  'price_btc': 1.0,
#  'price_usd': 8541.02,
#  'rank': 1,
#  'symbol': 'BTC',
#  'total_supply': 16859762.0}

# %% [markdown]
# To get all symbols and slugs you can use the next attributes:

# %%
all_symbols = cmc.symbols
all_slugs = cmc.coins

all_symbols
# Out:
# ['GOOD',
#  'BOST',
#  'GAY',
#  'EVX',
#  'TRIA',
#  'VOYA',
#  'RUBIT',
#  'BMC',
#  'GTO',
#  'GOLF',
#  'LINX',
#  'ADCN',
#  'XUC',
#  'CMT',
#  'BAC',
#  'SHND',
#  'BLN',
#  'MONEY',
#  'ALTC',
#  'VIP',
#  'BNTY',
#  'DOPE',
#  'STRAT',
#  'CJ',
#  'DBET',
#  'SOC',
#  'TOP',
#  'FLIXX',
#  'AVT',
#  'SPHR',
#  'BCAP',
#  'ACP',
#  '2GIVE',
#  'PCOIN',
#  'ELTCOIN',
#  'MARS',
#  'BLK',
#  'MOD',
#  'FID',
#  'BSN',
#  'SHDW',
#  'ZLA',
#  'ZENI',
#  'UIP',
#  'DEUS',
#  'ERC',
#  'LOCI',
#  'BOAT',
#  'HXX',
#  '42',
#  'GAM',
#  'OCL',
#  'NTO',
#  'EPY',
#  'GTC',
#  'NET',
#  'NAV',
#  'NULS',
#  'MBL',
#  'SLT',
#  'PHS',
#  'UCASH',
#  'ICE',
#  'CUBE',
#  'VZT',
#  'DRS',
#  'BIOS',
#  'ATL',
#  'ICOO',
#  'ELTC2',
#  'FDX',
#  'RUSTBITS',
#  'UTK',
#  'SHA',
#  'EKO',
#  'PCS',
#  'POST',
#  'TAJ',
#  'UKG',
#  'TFL',
#  'FBL',
#  'CSC',
#  'LTCU',
#  'UNI',
#  'LTH',
#  'TSTR',
#  'SPR',
#  'MNX',
#  'GMX',
#  'B2X',
#  'MED',
#  'OS76',
#  'SOAR',
#  'BRD',
#  'RHOC',
#  'NIMFA',
#  'TEL',
#  'MNE',
#  'FUNC',
#  'XVC',
#  'KLN',
#  'SPHTX',
#  'KARMA',
#  'KORE',
#  'ORE',
#  'BTCD',
#  'AU',
#  'BNB',
#  'FST',
#  'GRIM',
#  'TRST',
#  'INDIA',
#  'PRN',
#  'IVZ',
#  'ASAFE2',
#  'NEBL',
#  'BYC',
#  'TRUMP',
#  'AMM',
#  'VERI',
#  'GRWI',
#  'KB3',
#  'KOBO',
#  'MBI',
#  'HPC',
#  'EVIL',
#  'MAID',
#  'ACT',
#  'ELA',
#  'BLUE',
#  'BIRDS',
#  'UTT',
#  'INSN',
#  'DUTCH',
#  'INF',
#  'MILO',
#  'IOST',
#  'SLFI',
#  'CME',
#  'FRWC',
#  'VRM',
#  'RKC',
#  'VOLT',
#  'GEERT',
#  '1337',
#  'ARG',
#  'PPY',
#  'WOMEN',
#  'TOKC',
#  'ARK',
#  'UNIT',
#  'ADK',
#  'ACE',
#  'WCT',
#  'COSS',
#  'DCN',
#  'LUX',
#  'MND',
#  'BUB',
#  'IXT',
#  'PLX',
#  'ICON',
#  'EMC',
#  'OMC',
#  'XZC',
#  'SKY',
#  'ZRC',
#  'DNA',
#  'UFO',
#  'SUR',
#  'PLU',
#  'SONG',
#  'STV',
#  'ENJ',
#  'COV',
#  'HBC',
#  'WRC',
#  'FOR',
#  'ETG',
#  'XID',
#  'GRX',
#  'VAL',
#  'UNC',
#  'CFI',
#  'CYDER',
#  'PAYP',
#  'ZYD',
#  'APPC',
#  'GCC',
#  'SIC',
#  'CHSB',
#  'SNM',
#  'OCN',
#  'UBQ',
#  'GET',
#  'MDS',
#  'VIA',
#  'BCY',
#  'EAC',
#  'BLT',
#  'LLT',
#  'LAZ',
#  'MKR',
#  'DOVU',
#  'STK',
#  'ETH',
#  'INN',
#  'KMD',
#  'EXP',
#  'LDCN',
#  'XOC',
#  'TURBO',
#  'ATMC',
#  'PYLNT',
#  'MRJA',
#  'KIN',
#  'HALLO',
#  'RADS',
#  'EOT',
#  'MBRS',
#  'CHAT',
#  'CON',
#  'TRX',
#  'BTW',
#  'ATS',
#  'MAO',
#  'NMS',
#  'FUCK',
#  'DAI',
#  'MYST',
#  'UTC',
#  'UNY',
#  'ZIL',
#  'MOF',
#  'NTWK',
#  'REC',
#  'XDE2',
#  'BIS',
#  '10MT',
#  'BLZ',
#  'SWING',
#  'TIO',
#  'ARC',
#  'BPT',
#  'LSK',
#  'TIE',
#  'AC',
#  'TAGR',
#  'IPY',
#  'NLC2',
#  'PTOY',
#  'CURE',
#  'BON',
#  'COLX',
#  'XRE',
#  'PING',
#  'WDC',
#  'MAC',
#  'NEWB',
#  'DUO',
#  'UQC',
#  'PRO',
#  'ADX',
#  'KUSH',
#  'CHEAP',
#  'MOT',
#  'AUR',
#  'SANDG',
#  'HNC',
#  'XAUR',
#  'RED',
#  'LINDA',
#  'IGNIS',
#  'BCDN',
#  'QBC',
#  'REQ',
#  'RBT',
#  'PROC',
#  'LKK',
#  'QVT',
#  'ATN',
#  'BPC',
#  'WABI',
#  'AKY',
#  'RBBT',
#  'WTC',
#  'ZMC',
#  'MNC',
#  'HKN',
#  'NYC',
#  'PRES',
#  'PARETO',
#  'SOON',
#  'ELS',
#  'ANTX',
#  'TKY',
#  'MGC',
#  'VIU',
#  'RDD',
#  'NEU',
#  'SEQ',
#  'XBTC21',
#  'SXC',
#  'XST',
#  'CXT',
#  'RPX',
#  'AXP',
#  'SFC',
#  'KURT',
#  'DAV',
#  'MAGN',
#  'SNRG',
#  'IDT',
#  'ZNE',
#  'BOS',
#  'SHOW',
#  'HGT',
#  'NIO',
#  'BTG',
#  'UAHPAY',
#  'GML',
#  'HDG',
#  'PLC',
#  'AMMO',
#  'UBTC',
#  'DDF',
#  'TESLA',
#  'PPC',
#  'SCRT',
#  'STC',
#  'AURA',
#  'PST',
#  'RIDE',
#  'UTA',
#  'OC',
#  'SPT',
#  'EAG',
#  'AEON',
#  'FRC',
#  'STEEM',
#  'XRY',
#  'SIB',
#  'TTC',
#  'EL',
#  'KZC',
#  'GLD',
#  'MAX',
#  'HERO',
#  'SSC',
#  'OST',
#  'IBTC',
#  'EFYT',
#  'LTG',
#  'AV',
#  'RMC',
#  'ONX',
#  'TALK',
#  'KASHH',
#  'LDOGE',
#  'MARX',
#  'CXO',
#  'XBY',
#  'FUEL',
#  'CHIPS',
#  'CYC',
#  'EDRC',
#  'XEM',
#  'MAD',
#  'WSX',
#  'FOTA',
#  'OPAL',
#  'GJC',
#  'EXCL',
#  'DTA',
#  'CACH',
#  'LEA',
#  'BSTAR',
#  'SKR',
#  'PHO',
#  'TKS',
#  'TCC',
#  'DGCS',
#  'XTZ',
#  'OFF',
#  'PLAY',
#  'GRC',
#  'THETA',
#  'BTPL',
#  'DBG',
#  'GCN',
#  'RAIN',
#  'ABN',
#  '300',
#  'FLIK',
#  'REX',
#  'UGT',
#  'RSGP',
#  'PND',
#  'TZC',
#  'ELITE',
#  'CFT',
#  'DAR',
#  'ISL',
#  'MTNC',
#  'INCNT',
#  'RLT',
#  'PAYX',
#  'SAFEX',
#  'PONZI',
#  'JNS',
#  'XCXT',
#  'NANOX',
#  'CPC',
#  'ADL',
#  'SMS',
#  'FLAP',
#  'LEAF',
#  'CV',
#  'CDT',
#  'MEC',
#  'DGB',
#  'DFT',
#  'DTR',
#  'BSC',
#  'TLE',
#  'ICX',
#  'SPANK',
#  'JS',
#  'KEY',
#  'WIC',
#  'EDT',
#  'ARCT',
#  'PPP',
#  'BCC',
#  'NMC',
#  'TX',
#  'APW',
#  'PHR',
#  'STN',
#  'XCN',
#  'GRLC',
#  'QCN',
#  'ADB',
#  'GLS',
#  'LMC',
#  'TKR',
#  'BCPT',
#  'DFS',
#  'QRL',
#  'AIT',
#  'SHELL',
#  'INT',
#  'PAY',
#  'ACES',
#  'EQT',
#  'NVC',
#  'XTD',
#  'WORM',
#  'HEAT',
#  'ATM',
#  'MNM',
#  'MANA',
#  'GCR',
#  'BURST',
#  'MDA',
#  'VLC',
#  'KAYI',
#  'PFR',
#  'GLT',
#  'EPC',
#  'BTX',
#  'VTC',
#  'DENT',
#  'PKB',
#  'TCR',
#  'INDI',
#  'RYZ',
#  'ETT',
#  'SPRTS',
#  'DIM',
#  'TRIG',
#  'LTCR',
#  'OBITS',
#  'XAU',
#  'ADST',
#  'VPRC',
#  'BLRY',
#  'GAIA',
#  'UNRC',
#  'MNTP',
#  'CREDO',
#  'DAY',
#  'CHAN',
#  'BRO',
#  'XNG',
#  'REBL',
#  'XIOS',
#  'MUSIC',
#  'KEK',
#  'BUN',
#  'MCI',
#  'EBCH',
#  'SOJ',
#  'NRO',
#  'DMB',
#  'BIP',
#  'CBX',
#  'PURA',
#  'ENT',
#  'BCD',
#  'HTC',
#  'CCN',
#  'GRN',
#  'STRC',
#  'MCR',
#  'XBL',
#  'AGI',
#  'POS',
#  'AE',
#  'ANI',
#  'CNT',
#  'BTS',
#  'BITOK',
#  'CASH',
#  'STAR',
#  'BTCRED',
#  'ETHOS',
#  'IPC',
#  'CFC',
#  'CRC',
#  'OF',
#  'DLC',
#  'DGD',
#  'SCORE',
#  'EGG',
#  'CRM',
#  'EVE',
#  'XCRE',
#  'B@',
#  'IFLT',
#  'UNIFY',
#  'SOCC',
#  'HLC',
#  'ORB',
#  'RPC',
#  'SENSE',
#  'SKULL',
#  'BBR',
#  'WC',
#  'ZUR',
#  'SPORT',
#  'POP',
#  'MGO',
#  'INK',
#  'AMB',
#  'CEFS',
#  'TRICK',
#  'GUN',
#  'XLM',
#  'OAX',
#  'BAT',
#  'ECOB',
#  'QSP',
#  'HORSE',
#  'CTX',
#  'ZNY',
#  'ESZ',
#  'TYCHO',
#  'BPL',
#  'TGT',
#  'BTC2X',
#  'EDR',
#  'MINT',
#  'MEN',
#  'ECASH',
#  'DUBI',
#  'XMR',
#  'BXC',
#  'JEW',
#  'FIL',
#  'IRL',
#  'LKC',
#  'MOON',
#  'ORLY',
#  'VUC',
#  'SBD',
#  'IXC',
#  'NTC',
#  'PRX',
#  'CRT',
#  'ULA',
#  'KRONE',
#  'DUB',
#  'XCO',
#  'XOT',
#  'ETP',
#  'CTIC2',
#  'J',
#  'GUP',
#  'FUTC',
#  'FLO',
#  'XFT',
#  'CRB',
#  'ZCG',
#  'XMRG',
#  'INFX',
#  'ERC20',
#  'SLEVIN',
#  'SNT',
#  'LBTC',
#  '611',
#  'XIN',
#  'ADZ',
#  'VASH',
#  'HMP',
#  'BASH',
#  'WAVES',
#  'C2',
#  'DMD',
#  'DCY',
#  'INS',
#  'RUP',
#  'ICN',
#  'G3N',
#  'ACOIN',
#  'XP',
#  'ELF',
#  'CREA',
#  'CFUN',
#  'VRC',
#  'BUCKS',
#  'DCRE',
#  'EBET',
#  'DEW',
#  'BELA',
#  'PASC',
#  'NSR',
#  'KNC',
#  'STU',
#  'LEND',
#  'METAL',
#  'ESC',
#  'CNX',
#  'ATMS',
#  'ABC',
#  'ZEN',
#  'POLY',
#  'ZSE',
#  'AVH',
#  'BCA',
#  'CRPT',
#  'CCO',
#  'SMART',
#  'ARGUS',
#  'ABY',
#  'HODL',
#  'WPR',
#  'PIE',
#  'YES',
#  'CCRB',
#  'CV2',
#  'EKT',
#  'BRX',
#  'HOT',
#  'P7C',
#  'GRS',
#  'INPAY',
#  'MSCN',
#  'VTR',
#  'WETH',
#  'Q2C',
#  'SHIFT',
#  'TNT',
#  'PRE',
#  'DCR',
#  'DSH',
#  'TCOIN',
#  'DIVX',
#  'RCN',
#  'SWM',
#  'XWC',
#  'FTC',
#  'VOT',
#  'BSTY',
#  'USC',
#  'BITEUR',
#  'COR',
#  'LBC',
#  'FRCT',
#  'UNIC',
#  'NAMO',
#  'TSL',
#  'GAME',
#  'HWC',
#  'CANDY',
#  'NUMUS',
#  'SISA',
#  'AMP',
#  'ZSC',
#  'EFL',
#  'YOYOW',
#  'DATA',
#  'KCS',
#  'PIX',
#  'QUBE',
#  'VOISE',
#  'UNITS',
#  'EMD',
#  'MAG',
#  'SNAKE',
#  'QTL',
#  'BKX',
#  'UNB',
#  'TMC',
#  'HYP',
#  'SFE',
#  'CHESS',
#  'GMT',
#  'PCN',
#  'NEVA',
#  'EGAS',
#  'CAT',
#  'DLISK',
#  'BCN',
#  'FC',
#  'OTN',
#  'CFD',
#  'HVN',
#  'XSPEC',
#  'BENJI',
#  'ZPT',
#  'RCT',
#  'VIDZ',
#  'SNC',
#  'MSD',
#  'ATOM',
#  'TERA',
#  'HVCO',
#  'JWL',
#  'SPC',
#  'BTE',
#  'XBC',
#  'FFC',
#  'BOT',
#  'AIR',
#  'BITB',
#  'CDN',
#  'FCT',
#  'YTN',
#  'IDH',
#  'XPA',
#  'SKIN',
#  'BRIT',
#  'ARI',
#  'EOS',
#  'ITC',
#  'SIFT',
#  'READ',
#  'ZOI',
#  'HYTV',
#  'OCT',
#  'ITI',
#  'REGA',
#  'TROLL',
#  'WA',
#  '1ST',
#  'HDLB',
#  'CMPCO',
#  'ELC',
#  'MAN',
#  'PEPECASH',
#  'MRT',
#  'SRC',
#  'DMC',
#  'SXDT',
#  'REF',
#  'GP',
#  'KED',
#  'CND',
#  'IMPS',
#  'MCO',
#  'AXIOM',
#  'DISK',
#  'ARB',
#  'EXN',
#  'ALL',
#  'XGOX',
#  'CCT',
#  'B2B',
#  'WGR',
#  'DIME',
#  'MER',
#  'BLX',
#  'VIB',
#  'SOIL',
#  'BTC',
#  'FUN',
#  'BITBTC',
#  'XJO',
#  'DRPU',
#  'REP',
#  'GPU',
#  'MONK',
#  'IETH',
#  'TOR',
#  'SAC',
#  'ARDR',
#  'KDC',
#  'BUMBA',
#  'XMG',
#  'XMY',
#  'POLL',
#  'FLAX',
#  'BTQ',
#  'GXS',
#  'XQN',
#  'IMS',
#  'IC',
#  'XCPO',
#  'ZZC',
#  'FLT',
#  'HMC',
#  'NXT',
#  'PIPL',
#  'CL',
#  'NKA',
#  'TELL',
#  'TEK',
#  'FRGC',
#  'FAP',
#  'QAU',
#  'PLNC',
#  'CPAY',
#  'FLASH',
#  'STEPS',
#  'MONETA',
#  'ZEPH',
#  'ADT',
#  'XTO',
#  'EAGLE',
#  'QASH',
#  'MOAC',
#  'IBANK',
#  'WGO',
#  'MONA',
#  'VSX',
#  'CNNC',
#  'ECC',
#  'PUT',
#  'LCP',
#  'KBR',
#  'UNO',
#  'DMT',
#  'DGC',
#  'OP',
#  'SUPER',
#  'GBYTE',
#  'XHI',
#  'POE',
#  'ECO',
#  'TRAC',
#  'PBL',
#  'CAN',
#  'FRST',
#  'RBY',
#  'ASN',
#  'EGO',
#  'BRAT',
#  'ONG',
#  'BCF',
#  'PIGGY',
#  'SUB',
#  'VEE',
#  'ETN',
#  'STA',
#  'SSS',
#  'BTO',
#  'GSR',
#  'START',
#  'AIB',
#  'SWT',
#  'SWTC',
#  'ZER',
#  'HMQ',
#  'MXT',
#  'HCC',
#  'BIGUP',
#  'HT',
#  'LA',
#  'UET',
#  'UIS',
#  'BLOCKPAY',
#  'TRC',
#  'VIVO',
#  'ADA',
#  'COVAL',
#  'LEPEN',
#  'NEOG',
#  'SEND',
#  'DXT',
#  'NODC',
#  'ITT',
#  'RUFF',
#  '$$$',
#  'COFI',
#  'XBTS',
#  '8BIT',
#  'BUZZ',
#  'BTDX',
#  'GLC',
#  'ENRG',
#  'BRK',
#  'BITCF',
#  'WAX',
#  'BTWTY',
#  'MGM',
#  'EVC',
#  'CMP',
#  'SYS',
#  'FXE',
#  'XLR',
#  'TKN',
#  'FYN',
#  'FJC',
#  'BXT',
#  'BAR',
#  'AERM',
#  'BNT',
#  'LUN',
#  'SIGMA',
#  'LRC',
#  'SBC',
#  'XMCC',
#  'CARBON',
#  'IDXM',
#  'CAPP',
#  'BAY',
#  'ROC',
#  'QRK',
#  'LEV',
#  'PRG',
#  'OPC',
#  'SPF',
#  'ANTI',
#  'MLM',
#  'WINGS',
#  'IND',
#  'TAU',
#  'EGC',
#  'LOG',
#  'ASTRO',
#  'BEST',
#  'SDC',
#  'NLG',
#  'PBT',
#  'PXC',
#  'BIG',
#  'BITZ',
#  'AMS',
#  'RVT',
#  'WOW',
#  'ERO',
#  'TSE',
#  'PRIX',
#  'GB',
#  'SCT',
#  'USNBT',
#  'STX',
#  'HST',
#  'EVR',
#  'AST',
#  'VIBE',
#  'BRAIN',
#  'RNT',
#  'CYP',
#  'COUPE',
#  'HPB',
#  'CTO',
#  'CPN',
#  'MOIN',
#  'RDN',
#  'XGR',
#  'YAC',
#  'DRP',
#  'CRAVE',
#  'AWR',
#  'GBC',
#  'BIT',
#  'PRC',
#  'RUPX',
#  'CAB',
#  'HPY',
#  'XRP',
#  'AIDOC',
#  'MCRN',
#  'HBN',
#  'VISIO',
#  'URC',
#  'BTCS',
#  'WAY',
#  ...]

# %% [markdown]
# Other parameters:

# %%
print(cmc.ticker.__doc__)
# Out:
# Get currencies with other aditional data.
#
#         Args:
#             currency (str, optional): Specify a currency to return,
#                 in this case the method returns a dict, otherwise
#                 returns a list. If you dont specify a currency,
#                 returns data for all in coinmarketcap. As default, None.
#             limit (int, optional): Limit amount of coins on response.
#                 if limit == 0, returns all coins in coinmarketcap.
#                 Only works if currency == None. As default 0.
#             start (int, optional): Rank of first currency to retrieve.
#                 The count starts at 0 for the first currency ranked.
#                 Only works if currency == None. As default 0.
#             convert (str, optional): As default, "USD". Allow to
#                 convert price, 24h volume and market cap in terms
#                 of one of next badges:
#                    ["AUD", "BRL", "CAD", "CHF", "CLP", "CNY", "CZK", "DKK",
#                     "EUR", "GBP", "HKD", "HUF", "IDR", "ILS", "INR", "JPY",
#                     "KRW", "MXN", "MYR", "NOK", "NZD", "PHP", "PKR", "PLN",
#                     "RUB", "SEK", "SGD", "THB", "TRY", "TWD", "ZAR"]
#
#         Returns:
#             dict/list: If currency param is provided or not.

# %% [markdown]
# If you want to get the valid badges that can be passed to `convert` param programatically, use this:

# %%
cmc.ticker_badges
# Out:
# ['AUD',
#  'BRL',
#  'CAD',
#  'CHF',
#  'CLP',
#  'CNY',
#  'CZK',
#  'DKK',
#  'EUR',
#  'GBP',
#  'HKD',
#  'HUF',
#  'IDR',
#  'ILS',
#  'INR',
#  'JPY',
#  'KRW',
#  'MXN',
#  'MYR',
#  'NOK',
#  'NZD',
#  'PHP',
#  'PKR',
#  'PLN',
#  'RUB',
#  'SEK',
#  'SGD',
#  'THB',
#  'TRY',
#  'TWD',
#  'ZAR']

# %% [markdown]
# #### `stats([convert="USD"])`
# Get global criptocurrency statistics. The `convert` parameter works just like in previous method.

# %%
cmc.stats()
# Out:
# {'active_assets': 598,
#  'active_currencies': 896,
#  'active_markets': 8682,
#  'bitcoin_percentage_of_market_cap': 34.38,
#  'last_updated': 1518420567,
#  'total_24h_volume_usd': 18643370814.0,
#  'total_market_cap_usd': 418828837494.0}

# %% [markdown]
# _____________________________________________
#
# ## Web scraper
# #### `markets(currency, [convert="USD"])`
# Get all markets for a exchange in coinmarketcap. You can convert the response fields `"volume_24h"` and `"price"` between `"USD"` and `"BTC"`.

# %%
cmc.markets("BTC", convert="BTC")
# Out:
# [{'pair': 'BTC/USD',
#   'percent_volume': 6.94348033436,
#   'price': 1.00183,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 49313.0},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 5.87420681707,
#   'price': 1.00094,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 41718.9},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 5.68849603243,
#   'price': 0.999103,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 40400.0},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 4.98681892246,
#   'price': 1.00057,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 35416.7},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 3.38823241088,
#   'price': 1.00237,
#   'source': 'bitFlyer',
#   'updated': True,
#   'volume_24h': 24063.4},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 2.53114774729,
#   'price': 0.999601,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 17976.4},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 2.33844900446,
#   'price': 1.00164,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 16607.8},
#  {'pair': 'BTC/USD',
#   'percent_volume': 2.29436856677,
#   'price': 0.999635,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 16294.7},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 2.28492985547,
#   'price': 1.05402,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 16227.7},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 1.81710095778,
#   'price': 1.05706,
#   'source': 'Bithumb',
#   'updated': True,
#   'volume_24h': 12905.2},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 1.81342482812,
#   'price': 0.99862,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 12879.0},
#  {'pair': 'BTC/USD',
#   'percent_volume': 1.69186416204,
#   'price': 1.00159,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 12015.8},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 1.59886470518,
#   'price': 0.995475,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 11355.2},
#  {'pair': 'GTO/BTC',
#   'percent_volume': 1.4037334243,
#   'price': 0.996302,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 9969.4},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 1.32587067972,
#   'price': 1.001,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 9416.41},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 1.22941036205,
#   'price': 1.00008,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 8731.34},
#  {'pair': 'BTC/USD',
#   'percent_volume': 1.19217878575,
#   'price': 0.99787,
#   'source': 'BTCC',
#   'updated': True,
#   'volume_24h': 8466.93},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 1.1358777008,
#   'price': 1.01942,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 8067.07},
#  {'pair': 'BTC/USD',
#   'percent_volume': 1.08727496125,
#   'price': 1.00253,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 7721.89},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 1.02438333753,
#   'price': 0.998279,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 7275.23},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.997565806033,
#   'price': 0.999699,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 7068.65},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.893743293547,
#   'price': 0.999713,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 6347.42},
#  {'pair': 'ICX/BTC',
#   'percent_volume': 0.808919085405,
#   'price': 0.998184,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 5744.99},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.80438022441,
#   'price': 1.00199,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 5712.76},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.665053254203,
#   'price': 1.00052,
#   'source': 'Gemini',
#   'updated': True,
#   'volume_24h': 4723.24},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.586948746142,
#   'price': 1.00251,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 4168.55},
#  {'pair': 'ELA/BTC',
#   'percent_volume': 0.568621087075,
#   'price': 1.00281,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 4038.39},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.567606011631,
#   'price': 0.999462,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 4031.17},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.552406374608,
#   'price': 1.00215,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 3923.22},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.547852610383,
#   'price': 1.00034,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 3890.89},
#  {'pair': 'HT/BTC',
#   'percent_volume': 0.547044524223,
#   'price': 0.997993,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 3885.14},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.508302754117,
#   'price': 0.994809,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 3610.0},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.495911547684,
#   'price': 0.990062,
#   'source': 'Lbank',
#   'updated': True,
#   'volume_24h': 3521.99},
#  {'pair': 'BNB/BTC',
#   'percent_volume': 0.487007696689,
#   'price': 0.998003,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 3458.75},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.449832421477,
#   'price': 1.00145,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 3194.74},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.441549538331,
#   'price': 1.01345,
#   'source': 'ZB.COM',
#   'updated': True,
#   'volume_24h': 3135.92},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.44120345225,
#   'price': 0.986129,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 3133.45},
#  {'pair': 'VEN/BTC',
#   'percent_volume': 0.412746565634,
#   'price': 0.988586,
#   'source': 'Lbank',
#   'updated': True,
#   'volume_24h': 2931.35},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.400683230225,
#   'price': 0.999533,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 2839.2},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.397132950044,
#   'price': 1.00286,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 2820.46},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.395957250917,
#   'price': 1.00256,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 2812.11},
#  {'pair': 'WICC/BTC',
#   'percent_volume': 0.387223959092,
#   'price': 0.999071,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 2750.08},
#  {'pair': 'ELF/BTC',
#   'percent_volume': 0.386000238452,
#   'price': 1.0008,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 2741.39},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.344514618411,
#   'price': 0.998621,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 2441.2},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.344057586074,
#   'price': 0.997463,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 2437.96},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.34282061812,
#   'price': 0.999977,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 2434.73},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.340525520951,
#   'price': 1.01751,
#   'source': 'Liqui',
#   'updated': True,
#   'volume_24h': 2418.43},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.335690251302,
#   'price': 1.05587,
#   'source': 'Coinone',
#   'updated': True,
#   'volume_24h': 2384.09},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.333790917641,
#   'price': 1.00396,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 2370.6},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.33081523971,
#   'price': 0.999111,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 2349.47},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.329184164161,
#   'price': 1.00133,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 2337.88},
#  {'pair': 'POE/BTC',
#   'percent_volume': 0.309803343622,
#   'price': 1.00004,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 2200.25},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.305103858943,
#   'price': 1.01751,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 2166.86},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.300641170003,
#   'price': 0.992587,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 2130.31},
#  {'pair': 'VEN/BTC',
#   'percent_volume': 0.293389921443,
#   'price': 1.00474,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 2083.68},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.291285254415,
#   'price': 1.01034,
#   'source': 'CEX.IO',
#   'updated': True,
#   'volume_24h': 2068.72},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.286441705194,
#   'price': 1.0099,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 2034.32},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.284108521997,
#   'price': 0.989587,
#   'source': 'CoinsBank',
#   'updated': True,
#   'volume_24h': 2017.75},
#  {'pair': 'RISE/BTC',
#   'percent_volume': 0.0,
#   'price': 1.90029,
#   'source': 'Upbit',
#   'updated': False,
#   'volume_24h': 2017.95},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.267936863301,
#   'price': 1.00184,
#   'source': 'itBit',
#   'updated': True,
#   'volume_24h': 1902.9},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.266486282406,
#   'price': 1.07561,
#   'source': 'LakeBTC',
#   'updated': True,
#   'volume_24h': 1892.6},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.26618490601,
#   'price': 1.01223,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1890.46},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.263840131413,
#   'price': 1.00557,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 1873.81},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.262811808656,
#   'price': 0.997542,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 1866.5},
#  {'pair': 'NANO/BTC',
#   'percent_volume': 0.262530303231,
#   'price': 1.00055,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1864.5},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.258428603601,
#   'price': 0.986118,
#   'source': 'CoinsBank',
#   'updated': True,
#   'volume_24h': 1835.38},
#  {'pair': 'BLZ/BTC',
#   'percent_volume': 0.246241074622,
#   'price': 0.998753,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1748.82},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.234436061838,
#   'price': 0.995814,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 1661.19},
#  {'pair': 'EKT/BTC',
#   'percent_volume': 0.233061653,
#   'price': 0.992173,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 1655.22},
#  {'pair': 'NBT/BTC',
#   'percent_volume': 0.228309179064,
#   'price': 1.00475,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1617.78},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.221562984355,
#   'price': 1.02347,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 1573.55},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.215914660803,
#   'price': 1.05695,
#   'source': 'Korbit',
#   'updated': True,
#   'volume_24h': 1533.44},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.214916144502,
#   'price': 1.00078,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 1526.35},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.214657821877,
#   'price': 0.999306,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1524.52},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.214483950879,
#   'price': 1.00087,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 1523.27},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.213795090545,
#   'price': 1.00307,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1518.39},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.208694874614,
#   'price': 1.00088,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 1482.16},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.206012293507,
#   'price': 0.996885,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 1459.79},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.205467497715,
#   'price': 0.998314,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1459.24},
#  {'pair': 'NAV/BTC',
#   'percent_volume': 0.20379171248,
#   'price': 0.997083,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1444.05},
#  {'pair': 'ADA/BTC',
#   'percent_volume': 0.202819690808,
#   'price': 1.04967,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1440.44},
#  {'pair': 'BTC/BITCNY',
#   'percent_volume': 0.199524421424,
#   'price': 1.00917,
#   'source': 'AEX',
#   'updated': True,
#   'volume_24h': 1417.03},
#  {'pair': 'WAVES/BTC',
#   'percent_volume': 0.196667969319,
#   'price': 1.0067,
#   'source': 'Tidex',
#   'updated': True,
#   'volume_24h': 1396.74},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.196096678898,
#   'price': 1.02992,
#   'source': 'Gate.io',
#   'updated': True,
#   'volume_24h': 1392.69},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.195424377707,
#   'price': 1.0151,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 1387.91},
#  {'pair': 'BTC/GBP',
#   'percent_volume': 0.194386119464,
#   'price': 1.00346,
#   'source': 'CoinsBank',
#   'updated': True,
#   'volume_24h': 1380.55},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.193977108641,
#   'price': 0.996061,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1374.51},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.193477022534,
#   'price': 1.00377,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1374.09},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.190105581093,
#   'price': 0.939071,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 1350.14},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.189332269132,
#   'price': 1.00133,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1344.65},
#  {'pair': 'AIDOC/BTC',
#   'percent_volume': 0.186204247089,
#   'price': 1.00136,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1322.43},
#  {'pair': 'RISE/BTC',
#   'percent_volume': 0.0,
#   'price': 1.92429,
#   'source': 'Bittrex',
#   'updated': False,
#   'volume_24h': 1340.6},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.174710546187,
#   'price': 1.0137,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1240.81},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.174488653675,
#   'price': 1.00049,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 1239.23},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.173720309457,
#   'price': 1.00376,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 1233.77},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.173258309378,
#   'price': 0.999415,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1230.49},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.171459986488,
#   'price': 1.0228,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 1217.72},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.167770609509,
#   'price': 1.00011,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 1188.81},
#  {'pair': 'PPT/BTC',
#   'percent_volume': 0.163947931432,
#   'price': 0.988382,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1164.37},
#  {'pair': 'ADA/BTC',
#   'percent_volume': 0.161298634202,
#   'price': 1.05213,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1145.55},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.150724296899,
#   'price': 1.02134,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 1070.45},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.149312629989,
#   'price': 1.00204,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 1060.43},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.145907573489,
#   'price': 0.995853,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1036.24},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.145310450806,
#   'price': 0.998312,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1032.0},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.141395372713,
#   'price': 0.976589,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 1004.2},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.133378429398,
#   'price': 1.00488,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 947.262},
#  {'pair': 'ITC/BTC',
#   'percent_volume': 0.131271940864,
#   'price': 0.987307,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 932.3},
#  {'pair': 'BTC/PLN',
#   'percent_volume': 0.129592347027,
#   'price': 0.998696,
#   'source': 'BitBay',
#   'updated': True,
#   'volume_24h': 920.373},
#  {'pair': 'BTC/TRY',
#   'percent_volume': 0.127990415568,
#   'price': 0.999621,
#   'source': 'Paribu',
#   'updated': True,
#   'volume_24h': 908.995},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.127415813319,
#   'price': 1.00377,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 904.914},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.12677977665,
#   'price': 1.00218,
#   'source': 'Bitbank',
#   'updated': True,
#   'volume_24h': 900.398},
#  {'pair': 'BTC/RUB',
#   'percent_volume': 0.126654092758,
#   'price': 0.969618,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 899.504},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.126489329288,
#   'price': 1.0104,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 898.335},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.125772815187,
#   'price': 1.03522,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 891.214},
#  {'pair': 'SWFTC/BTC',
#   'percent_volume': 0.125717342059,
#   'price': 0.997387,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 892.852},
#  {'pair': 'EPC/BTC',
#   'percent_volume': 0.124833746208,
#   'price': 0.993088,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 886.577},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.12450653755,
#   'price': 1.02341,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 884.252},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.123367434128,
#   'price': 0.994887,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 876.163},
#  {'pair': 'ENG/BTC',
#   'percent_volume': 0.118649403208,
#   'price': 0.99621,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 842.655},
#  {'pair': 'PROPY/BTC',
#   'percent_volume': 0.117089366381,
#   'price': 0.997602,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 831.576},
#  {'pair': 'BTC/ZAR',
#   'percent_volume': 0.116336587757,
#   'price': 1.02827,
#   'source': 'Luno',
#   'updated': True,
#   'volume_24h': 826.23},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.114721905759,
#   'price': 0.986369,
#   'source': 'Lbank',
#   'updated': True,
#   'volume_24h': 814.761},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.110931021235,
#   'price': 1.00078,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 787.838},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.110777683575,
#   'price': 0.997282,
#   'source': 'Simex',
#   'updated': True,
#   'volume_24h': 786.75},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.110121113569,
#   'price': 1.00018,
#   'source': 'Neraex',
#   'updated': True,
#   'volume_24h': 782.087},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.108314179925,
#   'price': 1.00087,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 769.253},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.108036648694,
#   'price': 0.994922,
#   'source': 'Tidex',
#   'updated': True,
#   'volume_24h': 767.282},
#  {'pair': 'OC/BTC',
#   'percent_volume': 0.107901194908,
#   'price': 1.03188,
#   'source': 'Allcoin',
#   'updated': True,
#   'volume_24h': 766.321},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.107159179726,
#   'price': 1.00338,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 761.05},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.103475432856,
#   'price': 0.999572,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 734.889},
#  {'pair': 'MTL/BTC',
#   'percent_volume': 0.101549438976,
#   'price': 1.01551,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 721.21},
#  {'pair': 'RUFF/BTC',
#   'percent_volume': 0.0995630042259,
#   'price': 0.97215,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 707.102},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0995219375522,
#   'price': 0.998713,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 706.811},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.098896167552,
#   'price': 1.01224,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 702.367},
#  {'pair': 'INS/BTC',
#   'percent_volume': 0.0971197027303,
#   'price': 0.995793,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 689.75},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.095494919655,
#   'price': 1.00067,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 678.211},
#  {'pair': 'DLT/BTC',
#   'percent_volume': 0.0947585345821,
#   'price': 1.00354,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 672.98},
#  {'pair': 'INS/BTC',
#   'percent_volume': 0.094629538861,
#   'price': 0.997769,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 672.065},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0922223362963,
#   'price': 1.00496,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 654.968},
#  {'pair': 'ADA/BTC',
#   'percent_volume': 0.0920627061613,
#   'price': 1.05188,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 653.835},
#  {'pair': 'GXS/BTC',
#   'percent_volume': 0.0914991985375,
#   'price': 1.00096,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 649.833},
#  {'pair': 'IOTA/BTC',
#   'percent_volume': 0.0912142156928,
#   'price': 1.00225,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 647.809},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0907316822764,
#   'price': 1.00301,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 644.382},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0901105488362,
#   'price': 1.00307,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 639.97},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0892103938426,
#   'price': 1.00826,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 633.578},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.0888908023898,
#   'price': 1.03383,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 629.871},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0882254560388,
#   'price': 0.996226,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 625.158},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0881265979573,
#   'price': 1.00098,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 625.88},
#  {'pair': 'IOST/BTC',
#   'percent_volume': 0.0875346086081,
#   'price': 0.993017,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 621.676},
#  {'pair': 'BRD/BTC',
#   'percent_volume': 0.0873312623366,
#   'price': 0.996324,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 620.232},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0867285095447,
#   'price': 0.997753,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 615.95},
#  {'pair': 'KNC/BTC',
#   'percent_volume': 0.0860312040484,
#   'price': 0.997757,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 610.999},
#  {'pair': 'SC/BTC',
#   'percent_volume': 0.0847038231749,
#   'price': 1.00562,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 601.571},
#  {'pair': 'MANA/BTC',
#   'percent_volume': 0.0838911004544,
#   'price': 0.997891,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 595.8},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.081581100057,
#   'price': 1.01053,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 579.394},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0813385086174,
#   'price': 1.00221,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 577.671},
#  {'pair': 'ADX/BTC',
#   'percent_volume': 0.0806829321605,
#   'price': 0.998608,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 573.015},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.080287334243,
#   'price': 0.997569,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 570.205},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0801330030336,
#   'price': 1.014,
#   'source': 'GetBTC',
#   'updated': True,
#   'volume_24h': 569.109},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0801326718508,
#   'price': 0.999992,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 569.107},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0799130976195,
#   'price': 1.01122,
#   'source': 'GetBTC',
#   'updated': True,
#   'volume_24h': 567.547},
#  {'pair': 'R/BTC',
#   'percent_volume': 0.079682594354,
#   'price': 0.996576,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 565.91},
#  {'pair': 'BTC/RUB',
#   'percent_volume': 0.079409534092,
#   'price': 1.00485,
#   'source': 'GetBTC',
#   'updated': True,
#   'volume_24h': 563.971},
#  {'pair': 'QBT/BTC',
#   'percent_volume': 0.079281366328,
#   'price': 0.93446,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 563.061},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0790853060792,
#   'price': 0.997303,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 561.668},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0784371812365,
#   'price': 1.00613,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 555.798},
#  {'pair': 'IOTA/BTC',
#   'percent_volume': 0.0772987401804,
#   'price': 1.00604,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 548.981},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0767166863168,
#   'price': 0.997466,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 544.846},
#  {'pair': 'SC/BTC',
#   'percent_volume': 0.0764606819717,
#   'price': 1.00562,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 543.028},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0760039808179,
#   'price': 1.04598,
#   'source': 'CoolCoin',
#   'updated': True,
#   'volume_24h': 539.784},
#  {'pair': 'CND/BTC',
#   'percent_volume': 0.0727769351014,
#   'price': 1.00593,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 516.866},
#  {'pair': 'SRN/BTC',
#   'percent_volume': 0.0724763866626,
#   'price': 0.994738,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 514.731},
#  {'pair': 'XVG/BTC',
#   'percent_volume': 0.0722415780201,
#   'price': 0.99392,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 513.064},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.0721650747811,
#   'price': 0.998431,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 512.521},
#  {'pair': 'WAVES/BTC',
#   'percent_volume': 0.0713957370143,
#   'price': 0.993715,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 507.057},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.071199842357,
#   'price': 0.99727,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 505.665},
#  {'pair': 'BTC/IDR',
#   'percent_volume': 0.0708900207983,
#   'price': 1.02096,
#   'source': 'Bitcoin Indonesia',
#   'updated': True,
#   'volume_24h': 503.465},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.0708701498271,
#   'price': 1.04252,
#   'source': 'Coinnest',
#   'updated': True,
#   'volume_24h': 503.324},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0702274895015,
#   'price': 1.00207,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 498.76},
#  {'pair': 'BIX/BTC',
#   'percent_volume': 0.0701051174374,
#   'price': 0.993682,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 497.891},
#  {'pair': 'MIOTA/BTC',
#   'percent_volume': 0.0699873819333,
#   'price': 1.00367,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 497.054},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0698106958814,
#   'price': 0.997753,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 495.8},
#  {'pair': 'MDS/BTC',
#   'percent_volume': 0.0689444871302,
#   'price': 1.00029,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 489.647},
#  {'pair': 'ZIL/BTC',
#   'percent_volume': 0.0685141150132,
#   'price': 0.99564,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 486.592},
#  {'pair': 'XVG/BTC',
#   'percent_volume': 0.0680888762303,
#   'price': 0.997016,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 483.571},
#  {'pair': 'IOST/BTC',
#   'percent_volume': 0.06790540093,
#   'price': 0.996353,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 482.268},
#  {'pair': 'CDT/BTC',
#   'percent_volume': 0.0665930888762,
#   'price': 0.997346,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 472.948},
#  {'pair': 'STR/BTC',
#   'percent_volume': 0.065628187635,
#   'price': 1.03545,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 465.035},
#  {'pair': 'RPX/BTC',
#   'percent_volume': 0.0652983295137,
#   'price': 1.00795,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 463.753},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0645773444434,
#   'price': 1.01053,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 458.632},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.064218673414,
#   'price': 0.99295,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 456.084},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0639115013181,
#   'price': 1.00165,
#   'source': 'Gate.io',
#   'updated': True,
#   'volume_24h': 453.904},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0638739120643,
#   'price': 0.995556,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 453.636},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0636487077245,
#   'price': 0.997752,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 451.008},
#  {'pair': 'VIB/BTC',
#   'percent_volume': 0.0633206711089,
#   'price': 1.00285,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 449.708},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0631703140938,
#   'price': 1.03031,
#   'source': 'BtcTrade.im',
#   'updated': True,
#   'volume_24h': 448.64},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0629429570655,
#   'price': 1.00116,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 447.025},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 0.993818,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 433.839},
#  {'pair': 'ACT/BTC',
#   'percent_volume': 0.0606005007485,
#   'price': 0.937718,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 430.388},
#  {'pair': 'BTC/AUD',
#   'percent_volume': 0.0604420297535,
#   'price': 1.00675,
#   'source': 'BTC Markets',
#   'updated': True,
#   'volume_24h': 429.263},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.0599873156967,
#   'price': 1.04198,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 425.065},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0593350510684,
#   'price': 1.00056,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 421.401},
#  {'pair': 'WTC/BTC',
#   'percent_volume': 0.059225760727,
#   'price': 1.00241,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 420.625},
#  {'pair': 'BTC/GBP',
#   'percent_volume': 0.0587308079537,
#   'price': 1.00358,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 417.11},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0583830659584,
#   'price': 0.998295,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 414.64},
#  {'pair': 'FCT/BTC',
#   'percent_volume': 0.0579346443759,
#   'price': 1.00204,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 411.455},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0569526872177,
#   'price': 0.994246,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 404.482},
#  {'pair': 'RPX/BTC',
#   'percent_volume': 0.0562209387047,
#   'price': 1.00865,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 399.284},
#  {'pair': 'R/BTC',
#   'percent_volume': 0.0556461708639,
#   'price': 0.993802,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 395.203},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0549775126843,
#   'price': 1.00199,
#   'source': 'xBTCe',
#   'updated': True,
#   'volume_24h': 390.454},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.054618510472,
#   'price': 0.999922,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 387.904},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0546102309007,
#   'price': 0.994416,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 386.963},
#  {'pair': 'DGD/BTC',
#   'percent_volume': 0.0545923470266,
#   'price': 1.00173,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 387.719},
#  {'pair': 'NAV/BTC',
#   'percent_volume': 0.0543179620332,
#   'price': 0.99751,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 384.892},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0527180176719,
#   'price': 1.0027,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 374.406},
#  {'pair': 'NAS/BTC',
#   'percent_volume': 0.0524472756899,
#   'price': 1.01064,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 372.484},
#  {'pair': 'JNT/BTC',
#   'percent_volume': 0.0524239272987,
#   'price': 0.991328,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 372.318},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.0521848132791,
#   'price': 1.03313,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 369.776},
#  {'pair': 'AMB/BTC',
#   'percent_volume': 0.0521256971399,
#   'price': 0.997942,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 370.2},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0518749917204,
#   'price': 0.988808,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 368.419},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.051769178799,
#   'price': 1.00928,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 367.668},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0514682991773,
#   'price': 0.996987,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 365.53},
#  {'pair': 'BTC/BRL',
#   'percent_volume': 0.0511920926782,
#   'price': 1.03483,
#   'source': 'Negocie Coins',
#   'updated': True,
#   'volume_24h': 363.569},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.0509504947872,
#   'price': 1.00333,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 361.853},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0507541033555,
#   'price': 1.01097,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 360.459},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0488123782903,
#   'price': 0.993454,
#   'source': 'RightBTC',
#   'updated': True,
#   'volume_24h': 346.668},
#  {'pair': 'QUN/BTC',
#   'percent_volume': 0.0487936664591,
#   'price': 0.997624,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 346.536},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0482137652841,
#   'price': 1.00283,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 342.417},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0478804297429,
#   'price': 0.997567,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 340.05},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0475499092559,
#   'price': 1.00252,
#   'source': 'BtcTrade.im',
#   'updated': True,
#   'volume_24h': 337.702},
#  {'pair': 'BCN/BTC',
#   'percent_volume': 0.0475136447335,
#   'price': 0.998021,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 336.677},
#  {'pair': 'LBTC/BTC',
#   'percent_volume': 0.0474785393511,
#   'price': 0.904115,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 337.195},
#  {'pair': 'MANA/BTC',
#   'percent_volume': 0.0473404361016,
#   'price': 1.00142,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 336.215},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0472578059798,
#   'price': 0.9994,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 335.628},
#  {'pair': 'XVG/BTC',
#   'percent_volume': 0.0472374382344,
#   'price': 0.99392,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 335.483},
#  {'pair': 'REBL/BTC',
#   'percent_volume': 0.0471866016665,
#   'price': 0.996658,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 335.122},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0468444897797,
#   'price': 0.997967,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 332.693},
#  {'pair': 'DSH/BTC',
#   'percent_volume': 0.0467648403036,
#   'price': 1.00675,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 332.127},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0467313908355,
#   'price': 0.998295,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 331.889},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0466646574907,
#   'price': 1.02653,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 331.416},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0466476015738,
#   'price': 1.00215,
#   'source': 'Coinbene',
#   'updated': True,
#   'volume_24h': 331.294},
#  {'pair': 'NKC/BTC',
#   'percent_volume': 0.0465532144608,
#   'price': 1.001,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 330.623},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0465354961781,
#   'price': 1.01115,
#   'source': 'Allcoin',
#   'updated': True,
#   'volume_24h': 330.498},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0450817690463,
#   'price': 1.00168,
#   'source': 'C2CX',
#   'updated': True,
#   'volume_24h': 320.174},
#  {'pair': 'BTC/GBP',
#   'percent_volume': 0.045031926027,
#   'price': 1.00179,
#   'source': 'Coinfloor',
#   'updated': True,
#   'volume_24h': 319.82},
#  {'pair': 'ADK/BTC',
#   'percent_volume': 0.0444242054923,
#   'price': 0.998105,
#   'source': 'AidosMarket',
#   'updated': True,
#   'volume_24h': 315.503},
#  {'pair': 'STK/BTC',
#   'percent_volume': 0.0442950441798,
#   'price': 1.00106,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 314.586},
#  {'pair': 'BTC/PLN',
#   'percent_volume': 0.0442087710467,
#   'price': 0.978734,
#   'source': 'Coinroom',
#   'updated': True,
#   'volume_24h': 313.973},
#  {'pair': 'FUN/BTC',
#   'percent_volume': 0.043896631208,
#   'price': 0.99531,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 311.757},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0437997602236,
#   'price': 1.0089,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 311.068},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.0436222462146,
#   'price': 0.988535,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 309.807},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0435058354419,
#   'price': 1.00165,
#   'source': 'Lbank',
#   'updated': True,
#   'volume_24h': 308.981},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0432708612079,
#   'price': 1.01044,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 307.312},
#  {'pair': 'NBT/BTC',
#   'percent_volume': 0.042925603084,
#   'price': 0.998491,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 304.167},
#  {'pair': 'ION/BTC',
#   'percent_volume': 0.0421514631658,
#   'price': 0.997797,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 299.362},
#  {'pair': 'BTC/CAD',
#   'percent_volume': 0.0420400201359,
#   'price': 1.01098,
#   'source': 'Coinsquare',
#   'updated': True,
#   'volume_24h': 298.57},
#  {'pair': 'BTC/THB',
#   'percent_volume': 0.0419683190483,
#   'price': 1.03146,
#   'source': 'BX Thailand',
#   'updated': True,
#   'volume_24h': 298.061},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.041602693179,
#   'price': 1.00071,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 295.465},
#  {'pair': 'XRB/BTC',
#   'percent_volume': 0.0415662630652,
#   'price': 1.00967,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 295.206},
#  {'pair': 'BTC/TRY',
#   'percent_volume': 0.0415246996172,
#   'price': 0.999158,
#   'source': 'BTCTurk',
#   'updated': True,
#   'volume_24h': 294.911},
#  {'pair': 'AION/BTC',
#   'percent_volume': 0.0410855511545,
#   'price': 0.989251,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 291.792},
#  {'pair': 'VEN/BTC',
#   'percent_volume': 0.0410198113582,
#   'price': 1.0016,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 291.325},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0409010823056,
#   'price': 1.01117,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 290.482},
#  {'pair': 'BTC/AUD',
#   'percent_volume': 0.0407181037795,
#   'price': 1.00685,
#   'source': 'ACX',
#   'updated': True,
#   'volume_24h': 289.183},
#  {'pair': 'LET/BTC',
#   'percent_volume': 0.0407171102309,
#   'price': 0.997071,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 289.176},
#  {'pair': 'YOYO/BTC',
#   'percent_volume': 0.0407017102283,
#   'price': 1.00113,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 289.066},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0402501424086,
#   'price': 1.00773,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 285.859},
#  {'pair': 'RUFF/BTC',
#   'percent_volume': 0.0398898154649,
#   'price': 1.01471,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 283.299},
#  {'pair': 'BTC/PEN',
#   'percent_volume': 0.0,
#   'price': 0.986815,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 282.293},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0396823294077,
#   'price': 0.998373,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 281.185},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0392511293335,
#   'price': 1.00274,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 278.763},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0392484798707,
#   'price': 0.9953,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 278.745},
#  {'pair': 'STRAT/BTC',
#   'percent_volume': 0.0391891981401,
#   'price': 1.00643,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 278.324},
#  {'pair': 'THETA/BTC',
#   'percent_volume': 0.0391858863116,
#   'price': 0.992384,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 278.301},
#  {'pair': 'ZCL/BTC',
#   'percent_volume': 0.0389919787513,
#   'price': 0.996385,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 276.923},
#  {'pair': 'DTA/BTC',
#   'percent_volume': 0.0384693722098,
#   'price': 1.00078,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 273.212},
#  {'pair': 'XRB/BTC',
#   'percent_volume': 0.0378528753295,
#   'price': 0.990536,
#   'source': 'RightBTC',
#   'updated': True,
#   'volume_24h': 268.834},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0378066753216,
#   'price': 1.00425,
#   'source': 'BL3P',
#   'updated': True,
#   'volume_24h': 268.506},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0377126193914,
#   'price': 0.999652,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 267.837},
#  {'pair': 'SRN/BTC',
#   'percent_volume': 0.0376556559408,
#   'price': 0.99545,
#   'source': 'Liqui',
#   'updated': True,
#   'volume_24h': 267.433},
#  {'pair': 'ELF/BTC',
#   'percent_volume': 0.0375309655967,
#   'price': 1.00101,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 266.547},
#  {'pair': 'SUB/BTC',
#   'percent_volume': 0.0372423397406,
#   'price': 0.993886,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 264.498},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0371679891902,
#   'price': 1.00321,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 263.969},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0,
#   'price': 0.991581,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 263.93},
#  {'pair': 'CHAT/BTC',
#   'percent_volume': 0.0371217891822,
#   'price': 0.99577,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 263.641},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.037053731106,
#   'price': 1.00488,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 263.158},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0369341740962,
#   'price': 0.989002,
#   'source': 'RightBTC',
#   'updated': True,
#   'volume_24h': 262.309},
#  {'pair': 'OF/BTC',
#   'percent_volume': 0.0368308450462,
#   'price': 1.00395,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 261.575},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0365968643608,
#   'price': 0.99536,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 259.322},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0364455137971,
#   'price': 0.997543,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 258.838},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0363304277558,
#   'price': 1.07211,
#   'source': 'BTC-Alpha',
#   'updated': True,
#   'volume_24h': 258.021},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0362749546279,
#   'price': 1.00093,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 257.627},
#  {'pair': 'BTC/RUR',
#   'percent_volume': 0.0362537589254,
#   'price': 1.0118,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 257.476},
#  {'pair': 'QSP/BTC',
#   'percent_volume': 0.0359523825294,
#   'price': 1.00149,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 255.336},
#  {'pair': 'NULS/BTC',
#   'percent_volume': 0.035934333064,
#   'price': 1.02493,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 255.208},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.035897074993,
#   'price': 0.991922,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 254.364},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0355875846172,
#   'price': 1.00951,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 252.745},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0354079179196,
#   'price': 1.01739,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 251.469},
#  {'pair': 'WPR/BTC',
#   'percent_volume': 0.0352913415555,
#   'price': 1.0021,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 250.641},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0347253500603,
#   'price': 0.988013,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 246.622},
#  {'pair': 'VIBE/BTC',
#   'percent_volume': 0.0346480188642,
#   'price': 0.998294,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 246.072},
#  {'pair': 'HPB/BTC',
#   'percent_volume': 0.0343708188165,
#   'price': 0.993998,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 244.104},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.0341684660935,
#   'price': 0.992134,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 242.667},
#  {'pair': 'BTC/CAD',
#   'percent_volume': 0.0341129929657,
#   'price': 0.983097,
#   'source': 'QuadrigaCX',
#   'updated': True,
#   'volume_24h': 242.273},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0338086359241,
#   'price': 1.01587,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 240.111},
#  {'pair': 'XDN/BTC',
#   'percent_volume': 0.0336047928782,
#   'price': 1.01672,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 238.12},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.0334380423119,
#   'price': 1.01385,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 237.479},
#  {'pair': 'ADX/BTC',
#   'percent_volume': 0.032911792759,
#   'price': 0.993803,
#   'source': 'Liqui',
#   'updated': True,
#   'volume_24h': 233.741},
#  {'pair': 'HLC/BTC',
#   'percent_volume': 0.0328924185621,
#   'price': 0.997103,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 233.604},
#  {'pair': 'LBTC/BTC',
#   'percent_volume': 0.032700498099,
#   'price': 1.02506,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 232.24},
#  {'pair': 'SOC/BTC',
#   'percent_volume': 0.0324827453734,
#   'price': 0.996714,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 230.694},
#  {'pair': 'NAV/BTC',
#   'percent_volume': 0.0323150012585,
#   'price': 0.99751,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 228.981},
#  {'pair': 'ZLA/BTC',
#   'percent_volume': 0.0322848636189,
#   'price': 0.996645,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 229.289},
#  {'pair': 'RCN/BTC',
#   'percent_volume': 0.0319521904434,
#   'price': 0.983333,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 226.926},
#  {'pair': 'BTC/TRY',
#   'percent_volume': 0.0319460635606,
#   'price': 1.00113,
#   'source': 'Vebitcoin',
#   'updated': True,
#   'volume_24h': 226.883},
#  {'pair': 'LEND/BTC',
#   'percent_volume': 0.0319223839866,
#   'price': 0.998284,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 226.714},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0318145839681,
#   'price': 1.00199,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 225.949},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0317266549207,
#   'price': 0.996892,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 225.325},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0315552677945,
#   'price': 1.00034,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 224.108},
#  {'pair': 'VIU/BTC',
#   'percent_volume': 0.031280882801,
#   'price': 0.992085,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 222.159},
#  {'pair': 'VIB/BTC',
#   'percent_volume': 0.0312547193557,
#   'price': 0.997852,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 221.972},
#  {'pair': 'XDN/BTC',
#   'percent_volume': 0.0310593214726,
#   'price': 0.982992,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 220.084},
#  {'pair': 'R/BTC',
#   'percent_volume': 0.0309374461828,
#   'price': 0.993802,
#   'source': 'BTC-Alpha',
#   'updated': True,
#   'volume_24h': 219.719},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0307771536821,
#   'price': 0.9899,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 218.084},
#  {'pair': 'PUT/BTC',
#   'percent_volume': 0.0306292805384,
#   'price': 0.977298,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 217.531},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0305360525653,
#   'price': 1.01342,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 216.869},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0,
#   'price': 0.658557,
#   'source': 'HitBTC',
#   'updated': False,
#   'volume_24h': 234.1},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0304747837376,
#   'price': 0.984015,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 215.941},
#  {'pair': 'STRAT/BTC',
#   'percent_volume': 0.0304193106098,
#   'price': 1.00526,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 216.04},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0303863579159,
#   'price': 1.00274,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 215.806},
#  {'pair': 'SXUT/BTC',
#   'percent_volume': 0.0302815385431,
#   'price': 0.984017,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 215.062},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.030067097646,
#   'price': 1.0046,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 213.538},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0299339621392,
#   'price': 0.964827,
#   'source': 'BtcTrade.im',
#   'updated': True,
#   'volume_24h': 212.593},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0299021685853,
#   'price': 1.00014,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 212.367},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0299005126711,
#   'price': 1.07276,
#   'source': 'LakeBTC',
#   'updated': True,
#   'volume_24h': 212.355},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0294572244227,
#   'price': 1.00043,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 209.207},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.0293792308609,
#   'price': 1.05494,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 208.653},
#  {'pair': 'ION/BTC',
#   'percent_volume': 0.0293378330044,
#   'price': 0.997797,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 208.359},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0293168028932,
#   'price': 1.00279,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 208.209},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0292518910541,
#   'price': 0.997298,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 207.749},
#  {'pair': 'BTM/BTC',
#   'percent_volume': 0.0292492415913,
#   'price': 0.989091,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 207.73},
#  {'pair': 'GAS/BTC',
#   'percent_volume': 0.0286683468677,
#   'price': 0.998169,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 203.605},
#  {'pair': 'BTM/BTC',
#   'percent_volume': 0.0282951037927,
#   'price': 0.993896,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 200.954},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.0282177725966,
#   'price': 1.06312,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 200.404},
#  {'pair': 'DOGE/BTC',
#   'percent_volume': 0.0281116284923,
#   'price': 0.990205,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 199.196},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.0279372607204,
#   'price': 0.930685,
#   'source': 'Exrates',
#   'updated': True,
#   'volume_24h': 198.412},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0277824327368,
#   'price': 0.994799,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 197.312},
#  {'pair': 'STEEM/BTC',
#   'percent_volume': 0.0274221057931,
#   'price': 1.04604,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 194.753},
#  {'pair': 'BTC/ARS',
#   'percent_volume': 0.0,
#   'price': 1.00193,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 193.446},
#  {'pair': 'TKY/BTC',
#   'percent_volume': 0.0269596089393,
#   'price': 0.984878,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 191.469},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0267185078225,
#   'price': 1.02182,
#   'source': 'Exrates',
#   'updated': True,
#   'volume_24h': 189.756},
#  {'pair': 'WAVES/BTC',
#   'percent_volume': 0.0264562110032,
#   'price': 0.99756,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 187.894},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0264086862639,
#   'price': 0.998319,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 187.556},
#  {'pair': 'IGNIS/BTC',
#   'percent_volume': 0.0263417873276,
#   'price': 1.01741,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 187.081},
#  {'pair': 'DOGE/BTC',
#   'percent_volume': 0.0262303442977,
#   'price': 0.990205,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 185.865},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0260993614795,
#   'price': 0.997696,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 185.36},
#  {'pair': 'CTR/BTC',
#   'percent_volume': 0.0258667055255,
#   'price': 1.00433,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 183.707},
#  {'pair': 'BTS/BTC',
#   'percent_volume': 0.0258667055255,
#   'price': 0.997218,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 183.289},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0258471657371,
#   'price': 1.0011,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 183.568},
#  {'pair': 'EKT/BTC',
#   'percent_volume': 0.025829613046,
#   'price': 1.05479,
#   'source': 'BigONE',
#   'updated': True,
#   'volume_24h': 183.444},
#  {'pair': 'EMC2/BTC',
#   'percent_volume': 0.0258289506802,
#   'price': 1.04318,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 183.021},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0258277915403,
#   'price': 0.996573,
#   'source': 'Bitonic',
#   'updated': True,
#   'volume_24h': 183.43},
#  {'pair': 'APPC/BTC',
#   'percent_volume': 0.0256711420509,
#   'price': 0.997449,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 182.318},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0255782452608,
#   'price': 0.982972,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 181.658},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0253937764118,
#   'price': 1.00168,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 180.349},
#  {'pair': 'BTS/BTC',
#   'percent_volume': 0.0252637871422,
#   'price': 0.994815,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 179.016},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0251097871157,
#   'price': 1.01232,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 178.331},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0249395591294,
#   'price': 0.995582,
#   'source': 'ZB.COM',
#   'updated': True,
#   'volume_24h': 177.123},
#  {'pair': 'LINK/BTC',
#   'percent_volume': 0.0249319419238,
#   'price': 0.997533,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 177.068},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0248829268616,
#   'price': 0.993642,
#   'source': 'TOPBTC',
#   'updated': True,
#   'volume_24h': 176.72},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0246673268245,
#   'price': 1.00771,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 175.189},
#  {'pair': 'WAX/BTC',
#   'percent_volume': 0.0246497741333,
#   'price': 1.00623,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 175.064},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0245855246599,
#   'price': 1.00422,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 174.608},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0245678063773,
#   'price': 1.01334,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 174.482},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0245444579861,
#   'price': 1.0178,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 174.316},
#  {'pair': 'SWT/BTC',
#   'percent_volume': 0.0244662988329,
#   'price': 0.997957,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 173.761},
#  {'pair': 'HMQ/BTC',
#   'percent_volume': 0.0243227310663,
#   'price': 0.96981,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 172.741},
#  {'pair': 'IGNIS/BTC',
#   'percent_volume': 0.0241318041517,
#   'price': 1.01741,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 171.386},
#  {'pair': 'NEBL/BTC',
#   'percent_volume': 0.0240920622094,
#   'price': 1.02417,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 171.104},
#  {'pair': 'DGD/BTC',
#   'percent_volume': 0.0240836170466,
#   'price': 0.994873,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 171.044},
#  {'pair': 'XDN/BTC',
#   'percent_volume': 0.0238948428206,
#   'price': 0.982992,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 169.316},
#  {'pair': 'AST/BTC',
#   'percent_volume': 0.0238761309894,
#   'price': 0.998807,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 169.57},
#  {'pair': 'BCD/BTC',
#   'percent_volume': 0.0235522341595,
#   'price': 0.539639,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 167.269},
#  {'pair': 'ZRX/BTC',
#   'percent_volume': 0.0235100083458,
#   'price': 0.997054,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 166.969},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0235081868401,
#   'price': 1.0141,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 166.957},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0232099566813,
#   'price': 0.991214,
#   'source': 'bitFlyer',
#   'updated': True,
#   'volume_24h': 164.839},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 1.00169,
#   'source': 'BitMEX',
#   'updated': True,
#   'volume_24h': 205599.0},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 1.00111,
#   'source': 'Fisco',
#   'updated': True,
#   'volume_24h': 17312.4},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 1.00068,
#   'source': 'Zaif',
#   'updated': True,
#   'volume_24h': 17306.6},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 0.996623,
#   'source': 'BTCBOX',
#   'updated': True,
#   'volume_24h': 15061.5},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 1.00167,
#   'source': 'Quoine',
#   'updated': True,
#   'volume_24h': 9585.07},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0,
#   'price': 0.999671,
#   'source': 'ZB.COM',
#   'updated': True,
#   'volume_24h': 2035.94},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 1.00804,
#   'source': 'Quoine',
#   'updated': True,
#   'volume_24h': 1571.74},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.0,
#   'price': 1.05717,
#   'source': 'GOPAX',
#   'updated': True,
#   'volume_24h': 639.197},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0,
#   'price': 0.997016,
#   'source': 'Quoine',
#   'updated': True,
#   'volume_24h': 330.375},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 0.997846,
#   'source': 'bitFlyer',
#   'updated': True,
#   'volume_24h': 293.639},
#  {'pair': 'BTC/SGD',
#   'percent_volume': 0.0,
#   'price': 1.00406,
#   'source': 'Quoine',
#   'updated': True,
#   'volume_24h': 222.198},
#  {'pair': 'BTC/ETH',
#   'percent_volume': 0.0,
#   'price': 0.00977014,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 370.132},
#  {'pair': 'BTC/XRP',
#   'percent_volume': 0.0,
#   'price': 1.42112e-08,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 329.328},
#  {'pair': 'BTC/LTC',
#   'percent_volume': 0.0,
#   'price': 0.000327214,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 315.228}]

# %% [markdown]
# #### `ranks([convert="USD"])`
# Get gainers and losers rankings:

# %%
cmc.ranks()
# Out:
# {'gainers': {'1h': [{'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7},
#    {'name': 'Pioneer Coin',
#     'percent_change': 38.6,
#     'price': 0.406194,
#     'symbol': 'PCOIN',
#     'volume_24h': 60987.7}],
#   '24h': [{'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0},
#    {'name': 'U.CASH',
#     'percent_change': 773.39,
#     'price': 0.121234,
#     'symbol': 'UCASH',
#     'volume_24h': 2072620.0}],
#   '7d': [{'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 2310.9,
#     'price': 0.058919,
#     'symbol': 'UNY',
#     'volume_24h': 1887210.0}]},
#  'losers': {'1h': [{'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7},
#    {'name': 'LIFE',
#     'percent_change': -22.02,
#     'price': 0.000899348,
#     'symbol': 'LIFE',
#     'volume_24h': 58748.7}],
#   '24h': [{'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0},
#    {'name': 'HomeBlockCoin',
#     'percent_change': -69.98,
#     'price': 0.384109,
#     'symbol': 'HBC',
#     'volume_24h': 251326.0}],
#   '7d': [{'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0},
#    {'name': 'WomenCoin',
#     'percent_change': -35.61,
#     'price': 0.00185712,
#     'symbol': 'WOMEN',
#     'volume_24h': 243084.0}]}}

# %% [markdown]
# #### `historical(currency, [start=datetime(2008, 8, 18), end=datetime.now(), revert=False])`
# Get historical prices for a currency. You can filter by `start` and `end` datetimes provided in `datetime` objects. With parameter `revert` active, the response will be ordered in chronological order.

# %%
from datetime import datetime

cmc.historical("ETH", start=datetime(2018, 2, 1), revert=True)
# Out:
# [{'close': 1036.79,
#   'date': datetime.datetime(2018, 2, 1, 0, 0),
#   'high': 1161.35,
#   'low': 984.819,
#   'market_cap': 796.439,
#   'open': 1119.37,
#   'volume': 707.737},
#  {'close': 915.785,
#   'date': datetime.datetime(2018, 2, 2, 0, 0),
#   'high': 1035.77,
#   'low': 757.98,
#   'market_cap': 757.068,
#   'open': 1035.77,
#   'volume': 723.433},
#  {'close': 964.019,
#   'date': datetime.datetime(2018, 2, 3, 0, 0),
#   'high': 991.943,
#   'low': 847.69,
#   'market_cap': 851.2,
#   'open': 919.211,
#   'volume': 790.428},
#  {'close': 834.682,
#   'date': datetime.datetime(2018, 2, 4, 0, 0),
#   'high': 969.032,
#   'low': 805.064,
#   'market_cap': 817.807,
#   'open': 964.667,
#   'volume': 755.843},
#  {'close': 697.951,
#   'date': datetime.datetime(2018, 2, 5, 0, 0),
#   'high': 856.646,
#   'low': 644.599,
#   'market_cap': 845.086,
#   'open': 834.958,
#   'volume': 755.843},
#  {'close': 793.122,
#   'date': datetime.datetime(2018, 2, 6, 0, 0),
#   'high': 796.439,
#   'low': 574.419,
#   'market_cap': 883.865,
#   'open': 707.737,
#   'volume': 788.834},
#  {'close': 757.068,
#   'date': datetime.datetime(2018, 2, 7, 0, 0),
#   'high': 851.2,
#   'low': 723.433,
#   'market_cap': 884.004,
#   'open': 790.428,
#   'volume': 818.48},
#  {'close': 817.807,
#   'date': datetime.datetime(2018, 2, 8, 0, 0),
#   'high': 845.086,
#   'low': 755.843,
#   'market_cap': 860.415,
#   'open': 755.843,
#   'volume': 825.577},
#  {'close': 883.865,
#   'date': datetime.datetime(2018, 2, 9, 0, 0),
#   'high': 884.004,
#   'low': 788.834,
#   'market_cap': 917.4,
#   'open': 818.48,
#   'volume': 882.467},
#  {'close': 860.415,
#   'date': datetime.datetime(2018, 2, 10, 0, 0),
#   'high': 917.4,
#   'low': 825.577,
#   'market_cap': 814.66,
#   'open': 882.467,
#   'volume': 788.222},
#  {'close': 814.66,
#   'date': datetime.datetime(2018, 2, 11, 0, 0),
#   'high': 859.288,
#   'low': 788.222,
#   'market_cap': 859.288,
#   'open': 859.288,
#   'volume': 859.288}]

# %% [markdown]
# #### `recently([convert="USD"])`
# Get recently added coins in coinmarketcap along with other metadata. This method returns a `generator` object.

# %%
list(cmc.recently())
# Out:
# [{'added': '2 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Indicoin',
#   'percent_change': 54.68,
#   'price': 0.0467671,
#   'symbol': 'INDI',
#   'volume_24h': 18812.1},
#  {'added': '2 days ago',
#   'circulating_supply': 66000000.0,
#   'market_cap': 43860432.0,
#   'name': 'LOCIcoin',
#   'percent_change': 34.23,
#   'price': 0.664552,
#   'symbol': 'LOCI',
#   'volume_24h': 361374.0},
#  {'added': '2 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Animation Vision Cash',
#   'percent_change': 4.35,
#   'price': 0.0364254,
#   'symbol': 'AVH',
#   'volume_24h': 779130.0},
#  {'added': '2 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'MktCoin',
#   'percent_change': -1.38,
#   'price': 0.0264611,
#   'symbol': 'MLM',
#   'volume_24h': 187755.0},
#  {'added': '2 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ACChain',
#   'percent_change': 40.37,
#   'price': 1.4319,
#   'symbol': 'ACC',
#   'volume_24h': 458117.0},
#  {'added': '2 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Shekel',
#   'percent_change': -2.58,
#   'price': 0.097947,
#   'symbol': 'JEW',
#   'volume_24h': 152687.0},
#  {'added': '3 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GoldMint',
#   'percent_change': -6.39,
#   'price': 3.56391,
#   'symbol': 'MNTP',
#   'volume_24h': 75421.1},
#  {'added': '3 days ago',
#   'circulating_supply': 8628818329.63,
#   'market_cap': 1046106161.37,
#   'name': 'U.CASH',
#   'percent_change': 773.39,
#   'price': 0.121234,
#   'symbol': 'UCASH',
#   'volume_24h': 2072620.0},
#  {'added': '3 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'WePower',
#   'percent_change': 0.43,
#   'price': 0.128506,
#   'symbol': 'WPR',
#   'volume_24h': 4912530.0},
#  {'added': '3 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Datawallet',
#   'percent_change': 16.79,
#   'price': 0.126068,
#   'symbol': 'DXT',
#   'volume_24h': 91581.8},
#  {'added': '3 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EtherSportz',
#   'percent_change': -8.81,
#   'price': 0.381023,
#   'symbol': 'ESZ',
#   'volume_24h': 88247.8},
#  {'added': '4 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DRP Utility',
#   'percent_change': 6.02,
#   'price': 0.718759,
#   'symbol': 'DRPU',
#   'volume_24h': 20637.0},
#  {'added': '5 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'THEKEY',
#   'percent_change': 17.9,
#   'price': 0.0286266,
#   'symbol': 'TKY',
#   'volume_24h': 7324340.0},
#  {'added': '5 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Swarm',
#   'percent_change': -4.46,
#   'price': 1.31638,
#   'symbol': 'SWM',
#   'volume_24h': 7129.62},
#  {'added': '5 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Medicalchain',
#   'percent_change': 12.78,
#   'price': 0.322106,
#   'symbol': 'MTN',
#   'volume_24h': 5093740.0},
#  {'added': '6 days ago',
#   'circulating_supply': 165000000.0,
#   'market_cap': 110752125.0,
#   'name': 'Bluzelle',
#   'percent_change': 21.85,
#   'price': 0.671225,
#   'symbol': 'BLZ',
#   'volume_24h': 21631800.0},
#  {'added': '8 days ago',
#   'circulating_supply': 40000000.0,
#   'market_cap': 10570680.0,
#   'name': 'Iungo',
#   'percent_change': 15.84,
#   'price': 0.264267,
#   'symbol': 'ING',
#   'volume_24h': 123533.0},
#  {'added': '9 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DMarket',
#   'percent_change': None,
#   'price': 0.671872,
#   'symbol': 'DMT',
#   'volume_24h': None},
#  {'added': '9 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Huobi Token',
#   'percent_change': 7.4,
#   'price': 1.58846,
#   'symbol': 'HT',
#   'volume_24h': 122380000.0},
#  {'added': '9 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'adbank',
#   'percent_change': 19.11,
#   'price': 0.0240374,
#   'symbol': 'ADB',
#   'volume_24h': 71266.0},
#  {'added': '9 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Zilla',
#   'percent_change': 1.95,
#   'price': 0.331656,
#   'symbol': 'ZLA',
#   'volume_24h': 3736280.0},
#  {'added': '10 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SwissBorg',
#   'percent_change': 9.58,
#   'price': 0.0634675,
#   'symbol': 'CHSB',
#   'volume_24h': 386060.0},
#  {'added': '10 days ago',
#   'circulating_supply': 150000000.0,
#   'market_cap': 89733900.0,
#   'name': 'Jibrel Network',
#   'percent_change': 8.25,
#   'price': 0.598226,
#   'symbol': 'JNT',
#   'volume_24h': 7448820.0},
#  {'added': '10 days ago',
#   'circulating_supply': 239570250.0,
#   'market_cap': 184585763.212,
#   'name': 'Polymath',
#   'percent_change': 2.85,
#   'price': 0.770487,
#   'symbol': 'POLY',
#   'volume_24h': 159901.0},
#  {'added': '10 days ago',
#   'circulating_supply': 200000000.0,
#   'market_cap': 8546800.0,
#   'name': 'Pareto Network',
#   'percent_change': 21.52,
#   'price': 0.042734,
#   'symbol': 'PARETO',
#   'volume_24h': 284507.0},
#  {'added': '10 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Monero Gold',
#   'percent_change': -17.01,
#   'price': 0.000170062,
#   'symbol': 'XMRG',
#   'volume_24h': 1810.53},
#  {'added': '11 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'STK',
#   'percent_change': 2.0,
#   'price': 0.179417,
#   'symbol': 'STK',
#   'volume_24h': 5520050.0},
#  {'added': '12 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Elastos',
#   'percent_change': 8.98,
#   'price': 50.6132,
#   'symbol': 'ELA',
#   'volume_24h': 66259600.0},
#  {'added': '12 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Travelflex',
#   'percent_change': -4.01,
#   'price': 0.113816,
#   'symbol': 'TRF',
#   'volume_24h': 47149.6},
#  {'added': '12 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CargoX',
#   'percent_change': 2.15,
#   'price': 0.0970129,
#   'symbol': 'CXO',
#   'volume_24h': 199330.0},
#  {'added': '13 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bitcoin White',
#   'percent_change': 4.83,
#   'price': 0.248477,
#   'symbol': 'BTW',
#   'volume_24h': 264642.0},
#  {'added': '13 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ValueChain',
#   'percent_change': -2.64,
#   'price': 0.0821316,
#   'symbol': 'VLC',
#   'volume_24h': 593814.0},
#  {'added': '13 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Electronic PK Chain',
#   'percent_change': 6.34,
#   'price': 0.137025,
#   'symbol': 'EPC',
#   'volume_24h': 8876490.0},
#  {'added': '13 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Speed Mining Service',
#   'percent_change': 74.51,
#   'price': 73.9441,
#   'symbol': 'SMS',
#   'volume_24h': 594709.0},
#  {'added': '13 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Candy',
#   'percent_change': 1.51,
#   'price': 0.000677374,
#   'symbol': 'CANDY',
#   'volume_24h': 310864.0},
#  {'added': '13 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Health Mutual Society',
#   'percent_change': 6.07,
#   'price': 0.0717166,
#   'symbol': 'HMC',
#   'volume_24h': 330824.0},
#  {'added': '13 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'OceanChain',
#   'percent_change': 35.95,
#   'price': 0.0168532,
#   'symbol': 'OC',
#   'volume_24h': 12880400.0},
#  {'added': '13 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CPChain',
#   'percent_change': -2.49,
#   'price': 0.241653,
#   'symbol': 'CPC',
#   'volume_24h': 699265.0},
#  {'added': '13 days ago',
#   'circulating_supply': 234565044.0,
#   'market_cap': 21226682.1787,
#   'name': 'Zeepin',
#   'percent_change': 16.79,
#   'price': 0.0904938,
#   'symbol': 'ZPT',
#   'volume_24h': 509013.0},
#  {'added': '14 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'HalalChain',
#   'percent_change': 0.68,
#   'price': 0.357613,
#   'symbol': 'HLC',
#   'volume_24h': 2304590.0},
#  {'added': '14 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Equal',
#   'percent_change': -1.29,
#   'price': 0.00362749,
#   'symbol': 'EQL',
#   'volume_24h': 6357.95},
#  {'added': '14 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CoinFi',
#   'percent_change': 11.92,
#   'price': 0.0986706,
#   'symbol': 'COFI',
#   'volume_24h': 309028.0},
#  {'added': '14 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Nework',
#   'percent_change': 0.84,
#   'price': 0.0539634,
#   'symbol': 'NKC',
#   'volume_24h': 5560040.0},
#  {'added': '15 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Ruff',
#   'percent_change': 11.43,
#   'price': 0.13619,
#   'symbol': 'RUFF',
#   'volume_24h': 15090800.0},
#  {'added': '16 days ago',
#   'circulating_supply': 2280876.15202,
#   'market_cap': 533143.396154,
#   'name': 'Garlicoin',
#   'percent_change': -3.45,
#   'price': 0.233745,
#   'symbol': 'GRLC',
#   'volume_24h': 10017.4},
#  {'added': '16 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Matrix AI Network',
#   'percent_change': 11.21,
#   'price': 0.659991,
#   'symbol': 'MAN',
#   'volume_24h': 508323.0},
#  {'added': '16 days ago',
#   'circulating_supply': 439951479.697,
#   'market_cap': 55238108.0334,
#   'name': 'All Sports',
#   'percent_change': 16.57,
#   'price': 0.125555,
#   'symbol': 'SOC',
#   'volume_24h': 4339310.0},
#  {'added': '17 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Fortuna',
#   'percent_change': 8.62,
#   'price': 0.0853845,
#   'symbol': 'FOTA',
#   'volume_24h': 1642900.0},
#  {'added': '18 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Smartlands',
#   'percent_change': 3.63,
#   'price': 0.866203,
#   'symbol': 'SLT',
#   'volume_24h': 42559.8},
#  {'added': '18 days ago',
#   'circulating_supply': 192929698.0,
#   'market_cap': 18335015.9705,
#   'name': 'CoinMeet',
#   'percent_change': 9.58,
#   'price': 0.0950347,
#   'symbol': 'MEE',
#   'volume_24h': 1771890.0},
#  {'added': '18 days ago',
#   'circulating_supply': 6508988220.4,
#   'market_cap': 331048442.687,
#   'name': 'Zilliqa',
#   'percent_change': -0.12,
#   'price': 0.0508602,
#   'symbol': 'ZIL',
#   'volume_24h': 11033900.0},
#  {'added': '18 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LinkEye',
#   'percent_change': 9.82,
#   'price': 0.071103,
#   'symbol': 'LET',
#   'volume_24h': 7754800.0},
#  {'added': '18 days ago',
#   'circulating_supply': 254507605.599,
#   'market_cap': 46180150.5283,
#   'name': 'OriginTrail',
#   'percent_change': 5.2,
#   'price': 0.181449,
#   'symbol': 'TRAC',
#   'volume_24h': 382959.0},
#  {'added': '18 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'aXpire',
#   'percent_change': 10.7,
#   'price': 0.059058,
#   'symbol': 'AXP',
#   'volume_24h': 213506.0},
#  {'added': '18 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Pundi X',
#   'percent_change': 11.47,
#   'price': 1.64262,
#   'symbol': 'PXS',
#   'volume_24h': 401118.0},
#  {'added': '19 days ago',
#   'circulating_supply': 49596285.4494,
#   'market_cap': 13692592.0832,
#   'name': 'Blockport',
#   'percent_change': 4.93,
#   'price': 0.276081,
#   'symbol': 'BPT',
#   'volume_24h': 55741.7},
#  {'added': '19 days ago',
#   'circulating_supply': 62918410.0,
#   'market_cap': 5704592.02026,
#   'name': 'Devery',
#   'percent_change': 3.42,
#   'price': 0.0906665,
#   'symbol': 'EVE',
#   'volume_24h': 29740.8},
#  {'added': '19 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bitcoin Lightning',
#   'percent_change': -14.84,
#   'price': 7.6528,
#   'symbol': 'BLT',
#   'volume_24h': 228625.0},
#  {'added': '19 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'AidCoin',
#   'percent_change': 8.09,
#   'price': 0.29045,
#   'symbol': 'AID',
#   'volume_24h': 503968.0},
#  {'added': '19 days ago',
#   'circulating_supply': 206729.959584,
#   'market_cap': 1655340.53618,
#   'name': 'Qbic',
#   'percent_change': 16.31,
#   'price': 8.00726,
#   'symbol': 'QBIC',
#   'volume_24h': 110626.0},
#  {'added': '19 days ago',
#   'circulating_supply': 399934364.226,
#   'market_cap': 46729530.9193,
#   'name': 'indaHash',
#   'percent_change': -2.7,
#   'price': 0.116843,
#   'symbol': 'IDH',
#   'volume_24h': 178387.0},
#  {'added': '19 days ago',
#   'circulating_supply': 2000000000.0,
#   'market_cap': 41713200.0,
#   'name': 'Odyssey',
#   'percent_change': 7.4,
#   'price': 0.0208566,
#   'symbol': 'OCN',
#   'volume_24h': 8660690.0},
#  {'added': '19 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'True Chain',
#   'percent_change': 11.32,
#   'price': 1.05091,
#   'symbol': 'TRUE',
#   'volume_24h': 1713760.0},
#  {'added': '19 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'OFCOIN',
#   'percent_change': 4.7,
#   'price': 0.00359637,
#   'symbol': 'OF',
#   'volume_24h': 18049000.0},
#  {'added': '19 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'PressOne',
#   'percent_change': 7.82,
#   'price': 0.658154,
#   'symbol': 'PRS',
#   'volume_24h': 199158.0},
#  {'added': '19 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'UnlimitedIP',
#   'percent_change': 6.09,
#   'price': 0.058354,
#   'symbol': 'UIP',
#   'volume_24h': 454764.0},
#  {'added': '20 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EDUCare',
#   'percent_change': 6.72,
#   'price': 0.128144,
#   'symbol': 'EKT',
#   'volume_24h': 15634300.0},
#  {'added': '20 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Tokenbox',
#   'percent_change': -0.88,
#   'price': 0.716383,
#   'symbol': 'TBX',
#   'volume_24h': 51646.4},
#  {'added': '20 days ago',
#   'circulating_supply': 68430738.22,
#   'market_cap': 10386143.7241,
#   'name': 'Block Array',
#   'percent_change': 5.51,
#   'price': 0.151776,
#   'symbol': 'ARY',
#   'volume_24h': 208970.0},
#  {'added': '20 days ago',
#   'circulating_supply': 17500000.0,
#   'market_cap': 19222700.0,
#   'name': 'Covesting',
#   'percent_change': 3.05,
#   'price': 1.09844,
#   'symbol': 'COV',
#   'volume_24h': 88089.7},
#  {'added': '21 days ago',
#   'circulating_supply': 5171589622.24,
#   'market_cap': 40387425.7231,
#   'name': 'carVertical',
#   'percent_change': 4.9,
#   'price': 0.00780948,
#   'symbol': 'CV',
#   'volume_24h': 419838.0},
#  {'added': '21 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Decentralized Universa...',
#   'percent_change': None,
#   'price': 123.813,
#   'symbol': 'DUBI',
#   'volume_24h': None},
#  {'added': '21 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sparks',
#   'percent_change': 1.67,
#   'price': 2.03618,
#   'symbol': 'SPK',
#   'volume_24h': 28390.5},
#  {'added': '21 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Crypterium',
#   'percent_change': -2.92,
#   'price': 0.678002,
#   'symbol': 'CRPT',
#   'volume_24h': 62849.0},
#  {'added': '21 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DATA',
#   'percent_change': 4.5,
#   'price': 0.0204284,
#   'symbol': 'DTA',
#   'volume_24h': 7800860.0},
#  {'added': '21 days ago',
#   'circulating_supply': 39335007.2487,
#   'market_cap': 93980379.3688,
#   'name': 'CRYPTO20',
#   'percent_change': 8.13,
#   'price': 2.38923,
#   'symbol': 'C20',
#   'volume_24h': 2459020.0},
#  {'added': '21 days ago',
#   'circulating_supply': 333333333.0,
#   'market_cap': 68637999.9314,
#   'name': 'Trinity Network Credit',
#   'percent_change': 14.66,
#   'price': 0.205914,
#   'symbol': 'TNC',
#   'volume_24h': 3345650.0},
#  {'added': '21 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TimesCoin',
#   'percent_change': 3.61,
#   'price': 1.04588,
#   'symbol': 'TMC',
#   'volume_24h': 94583.5},
#  {'added': '23 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Molecular Future',
#   'percent_change': 1.48,
#   'price': 0.321959,
#   'symbol': 'MOF',
#   'volume_24h': 470936.0},
#  {'added': '23 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Read',
#   'percent_change': 4.56,
#   'price': 0.0356766,
#   'symbol': 'READ',
#   'volume_24h': 358291.0},
#  {'added': '23 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SelfSell',
#   'percent_change': -0.16,
#   'price': 0.0919477,
#   'symbol': 'SSC',
#   'volume_24h': 299510.0},
#  {'added': '23 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Acute Angle Cloud',
#   'percent_change': 1.14,
#   'price': 0.169746,
#   'symbol': 'AAC',
#   'volume_24h': 553709.0},
#  {'added': '23 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Yee',
#   'percent_change': 5.27,
#   'price': 0.0242081,
#   'symbol': 'YEE',
#   'volume_24h': 1826220.0},
#  {'added': '23 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'RefToken',
#   'percent_change': 4.1,
#   'price': 26.6244,
#   'symbol': 'REF',
#   'volume_24h': 248227.0},
#  {'added': '23 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LightChain',
#   'percent_change': 9.55,
#   'price': 0.00424611,
#   'symbol': 'LIGHT',
#   'volume_24h': 1924030.0},
#  {'added': '23 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maggie',
#   'percent_change': 6.89,
#   'price': 0.0323974,
#   'symbol': 'MAG',
#   'volume_24h': 49151.0},
#  {'added': '23 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'IPChain',
#   'percent_change': 4.69,
#   'price': 0.695756,
#   'symbol': 'IPC',
#   'volume_24h': 46553.6},
#  {'added': '23 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'StarChain',
#   'percent_change': 3.12,
#   'price': 0.111562,
#   'symbol': 'STC',
#   'volume_24h': 768092.0},
#  {'added': '23 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Titanium Blockchain',
#   'percent_change': 6.78,
#   'price': 1.25631,
#   'symbol': 'BAR',
#   'volume_24h': 441598.0},
#  {'added': '24 days ago',
#   'circulating_supply': 229389301.0,
#   'market_cap': 21503365.9765,
#   'name': 'Hydro Protocol',
#   'percent_change': 32.53,
#   'price': 0.0937418,
#   'symbol': 'HOT',
#   'volume_24h': 426866.0},
#  {'added': '24 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Mobius',
#   'percent_change': 35.11,
#   'price': 0.251799,
#   'symbol': 'MOBI',
#   'volume_24h': 587553.0},
#  {'added': '24 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Scry.info',
#   'percent_change': 10.25,
#   'price': 0.297451,
#   'symbol': 'DDD',
#   'volume_24h': 434648.0},
#  {'added': '24 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ChatCoin',
#   'percent_change': 3.1,
#   'price': 0.256321,
#   'symbol': 'CHAT',
#   'volume_24h': 6072170.0},
#  {'added': '24 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ShareX',
#   'percent_change': 18.77,
#   'price': 0.0279417,
#   'symbol': 'SEXC',
#   'volume_24h': 1614720.0},
#  {'added': '24 days ago',
#   'circulating_supply': 529861448.67,
#   'market_cap': 13532767.3713,
#   'name': 'Gatcoin',
#   'percent_change': 5.88,
#   'price': 0.0255402,
#   'symbol': 'GAT',
#   'volume_24h': 157758.0},
#  {'added': '25 days ago',
#   'circulating_supply': 455552782.0,
#   'market_cap': 168064354.547,
#   'name': 'SingularityNET',
#   'percent_change': 0.91,
#   'price': 0.368924,
#   'symbol': 'AGI',
#   'volume_24h': 843090.0},
#  {'added': '25 days ago',
#   'circulating_supply': 100000000.0,
#   'market_cap': 28788400.0,
#   'name': 'Aurora DAO',
#   'percent_change': 41.63,
#   'price': 0.287884,
#   'symbol': 'AURA',
#   'volume_24h': 128320.0},
#  {'added': '25 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'IDEX Membership',
#   'percent_change': 11.56,
#   'price': 5927.12,
#   'symbol': 'IDXM',
#   'volume_24h': 19080.9},
#  {'added': '25 days ago',
#   'circulating_supply': 201000000.0,
#   'market_cap': 31996386.0,
#   'name': 'InsurePal',
#   'percent_change': 2.27,
#   'price': 0.159186,
#   'symbol': 'IPL',
#   'volume_24h': 72054.9},
#  {'added': '25 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Nitro',
#   'percent_change': 13.44,
#   'price': 0.389855,
#   'symbol': 'NOX',
#   'volume_24h': 230627.0},
#  {'added': '26 days ago',
#   'circulating_supply': 20923342.6892,
#   'market_cap': 16926482.0754,
#   'name': 'Profile Utility Token',
#   'percent_change': -1.49,
#   'price': 0.808976,
#   'symbol': 'PUT',
#   'volume_24h': 3197110.0},
#  {'added': '26 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maverick Chain',
#   'percent_change': 24.02,
#   'price': 0.107564,
#   'symbol': 'MVC',
#   'volume_24h': 12741.8},
#  {'added': '26 days ago',
#   'circulating_supply': 563264706.0,
#   'market_cap': 67395185.3376,
#   'name': 'Theta Token',
#   'percent_change': 6.71,
#   'price': 0.119651,
#   'symbol': 'THETA',
#   'volume_24h': 7602780.0},
#  {'added': '26 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ArbitrageCT',
#   'percent_change': 4.43,
#   'price': 0.0160216,
#   'symbol': 'ARCT',
#   'volume_24h': 5684.71},
#  {'added': '27 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'RealChain',
#   'percent_change': -3.96,
#   'price': 0.07865,
#   'symbol': 'RCT',
#   'volume_24h': 1336620.0},
#  {'added': '27 days ago',
#   'circulating_supply': 100336600.0,
#   'market_cap': 11029099.4086,
#   'name': 'Ethorse',
#   'percent_change': 11.51,
#   'price': 0.109921,
#   'symbol': 'HORSE',
#   'volume_24h': 24786.5},
#  {'added': '27 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Harvest Masternode Coin',
#   'percent_change': 9.32,
#   'price': 1.33856,
#   'symbol': 'HC',
#   'volume_24h': 9884.11},
#  {'added': '27 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Galactrum',
#   'percent_change': 0.44,
#   'price': 2.76649,
#   'symbol': 'ORE',
#   'volume_24h': 18727.6},
#  {'added': '27 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SpaceChain',
#   'percent_change': -2.87,
#   'price': 0.202598,
#   'symbol': 'SPC',
#   'volume_24h': 206398.0},
#  {'added': '27 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EtherDelta Token',
#   'percent_change': None,
#   'price': 0.0395089,
#   'symbol': 'EDT',
#   'volume_24h': None},
#  {'added': '27 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Qube',
#   'percent_change': 9.07,
#   'price': 0.0733118,
#   'symbol': 'QUBE',
#   'volume_24h': 1411920.0},
#  {'added': '27 days ago',
#   'circulating_supply': 193535756.218,
#   'market_cap': 14415955.9341,
#   'name': 'AICHAIN',
#   'percent_change': 9.44,
#   'price': 0.0744873,
#   'symbol': 'AIT',
#   'volume_24h': 42595.2},
#  {'added': '27 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'InvestDigital',
#   'percent_change': 4.79,
#   'price': 0.0689907,
#   'symbol': 'IDT',
#   'volume_24h': 592779.0},
#  {'added': '27 days ago',
#   'circulating_supply': 6794109921.69,
#   'market_cap': 257343219.148,
#   'name': 'IOStoken',
#   'percent_change': 10.49,
#   'price': 0.0378774,
#   'symbol': 'IOST',
#   'volume_24h': 54730200.0},
#  {'added': '27 days ago',
#   'circulating_supply': 118123560.253,
#   'market_cap': 893304.699469,
#   'name': 'TOKYO',
#   'percent_change': -20.42,
#   'price': 0.00756246,
#   'symbol': 'TOKC',
#   'volume_24h': 54051.2},
#  {'added': '28 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'MOAC',
#   'percent_change': -2.31,
#   'price': 12.9322,
#   'symbol': 'MOAC',
#   'volume_24h': 78593.6},
#  {'added': '28 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sense',
#   'percent_change': 5.3,
#   'price': 0.0409603,
#   'symbol': 'SENSE',
#   'volume_24h': 1534.8},
#  {'added': '28 days ago',
#   'circulating_supply': 13449994.7564,
#   'market_cap': 5948233.28103,
#   'name': 'Global Jobcoin',
#   'percent_change': -1.11,
#   'price': 0.442248,
#   'symbol': 'GJC',
#   'volume_24h': None},
#  {'added': '28 days ago',
#   'circulating_supply': 185501578.891,
#   'market_cap': 14285309.639,
#   'name': 'OneRoot Network',
#   'percent_change': 4.31,
#   'price': 0.0770091,
#   'symbol': 'RNT',
#   'volume_24h': 290627.0},
#  {'added': '28 days ago',
#   'circulating_supply': 150000000.0,
#   'market_cap': 48317550.0,
#   'name': 'Internet Node Token',
#   'percent_change': 3.81,
#   'price': 0.322117,
#   'symbol': 'INT',
#   'volume_24h': 2104730.0},
#  {'added': '28 days ago',
#   'circulating_supply': 1877455408.41,
#   'market_cap': 27680076.0684,
#   'name': 'Selfkey',
#   'percent_change': 4.21,
#   'price': 0.0147434,
#   'symbol': 'KEY',
#   'volume_24h': 933684.0},
#  {'added': '28 days ago',
#   'circulating_supply': 324308731.314,
#   'market_cap': 12406203.5003,
#   'name': 'Hackspace Capital',
#   'percent_change': 8.12,
#   'price': 0.0382543,
#   'symbol': 'HAC',
#   'volume_24h': 125290.0},
#  {'added': '28 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EchoLink',
#   'percent_change': 3.23,
#   'price': 0.0838892,
#   'symbol': 'EKO',
#   'volume_24h': 1350000.0},
#  {'added': '29 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'WETH',
#   'percent_change': 3.97,
#   'price': 846.971,
#   'symbol': 'WETH',
#   'volume_24h': 218545.0},
#  {'added': '29 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Ignition',
#   'percent_change': -9.15,
#   'price': 12.4678,
#   'symbol': 'IC',
#   'volume_24h': 37016.6},
#  {'added': '29 days ago',
#   'circulating_supply': 20970629778.4,
#   'market_cap': 71440854.1725,
#   'name': 'Telcoin',
#   'percent_change': 5.12,
#   'price': 0.00340671,
#   'symbol': 'TEL',
#   'volume_24h': 918034.0},
#  {'added': '29 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'AWARE',
#   'percent_change': 2.62,
#   'price': 0.0272303,
#   'symbol': 'AWR',
#   'volume_24h': 267269.0},
#  {'added': '29 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bottos',
#   'percent_change': 8.37,
#   'price': 0.139199,
#   'symbol': 'BTO',
#   'volume_24h': 694146.0}]

# %% [markdown]
# #### `exchange(name [convert="USD"])`
# Get data about a exchange:

# %%
cmc.exchange("okex")
# Out:
# {'markets': [{'currency': 'Bitcoin',
#    'pair': 'BTC/USDT',
#    'perc_volume': 21.0398362065,
#    'price': 8495.48,
#    'updated': True,
#    'vol_24h': 343526000.0},
#   {'currency': 'Ethereum',
#    'pair': 'ETH/BTC',
#    'perc_volume': 18.4445682518,
#    'price': 846.238,
#    'updated': True,
#    'vol_24h': 301152000.0},
#   {'currency': 'Ethereum',
#    'pair': 'ETH/USDT',
#    'perc_volume': 11.9400454942,
#    'price': 846.843,
#    'updated': True,
#    'vol_24h': 194950000.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/BTC',
#    'perc_volume': 9.36186537072,
#    'price': 154.471,
#    'updated': True,
#    'vol_24h': 152855000.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/BTC',
#    'perc_volume': 8.64913744347,
#    'price': 1250.04,
#    'updated': True,
#    'vol_24h': 141218000.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/BTC',
#    'perc_volume': 4.54717600234,
#    'price': 25.0646,
#    'updated': True,
#    'vol_24h': 74243600.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/USDT',
#    'perc_volume': 4.32862325373,
#    'price': 154.026,
#    'updated': True,
#    'vol_24h': 70675200.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/USDT',
#    'perc_volume': 3.81416929047,
#    'price': 1251.65,
#    'updated': True,
#    'vol_24h': 62275500.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/USDT',
#    'perc_volume': 2.24716004718,
#    'price': 25.0842,
#    'updated': True,
#    'vol_24h': 36690300.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/USDT',
#    'perc_volume': 1.60748106715,
#    'price': 8.85649,
#    'updated': True,
#    'vol_24h': 26246000.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/ETH',
#    'perc_volume': 1.51673794633,
#    'price': 25.0498,
#    'updated': True,
#    'vol_24h': 24764400.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/USDT',
#    'perc_volume': 0.989299681225,
#    'price': 1.02357,
#    'updated': True,
#    'vol_24h': 16152700.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/BTC',
#    'perc_volume': 0.972052608585,
#    'price': 8.85131,
#    'updated': True,
#    'vol_24h': 15871100.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/USDT',
#    'perc_volume': 0.932946586281,
#    'price': 0.00360061,
#    'updated': True,
#    'vol_24h': 15232600.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/BTC',
#    'perc_volume': 0.861955528408,
#    'price': 1.02505,
#    'updated': True,
#    'vol_24h': 14073500.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/BTC',
#    'perc_volume': 0.464986223099,
#    'price': 0.0187068,
#    'updated': True,
#    'vol_24h': 7592020.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/BTC',
#    'perc_volume': 0.410296588713,
#    'price': 111.291,
#    'updated': True,
#    'vol_24h': 6699080.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/USDT',
#    'perc_volume': 0.408157241244,
#    'price': 111.009,
#    'updated': True,
#    'vol_24h': 6664150.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/ETH',
#    'perc_volume': 0.391328483611,
#    'price': 0.0186617,
#    'updated': True,
#    'vol_24h': 6389380.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/BTC',
#    'perc_volume': 0.368098220182,
#    'price': 28.2015,
#    'updated': True,
#    'vol_24h': 6010090.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/BTC',
#    'perc_volume': 0.350002880652,
#    'price': 2.22765,
#    'updated': True,
#    'vol_24h': 5714640.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/ETH',
#    'perc_volume': 0.31707175133,
#    'price': 8.80247,
#    'updated': True,
#    'vol_24h': 5176960.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/USDT',
#    'perc_volume': 0.300827287281,
#    'price': 28.1067,
#    'updated': True,
#    'vol_24h': 4911730.0},
#   {'currency': 'Revain',
#    'pair': 'R/BTC',
#    'perc_volume': 0.29471915321,
#    'price': 2.61989,
#    'updated': True,
#    'vol_24h': 4812000.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/BTC',
#    'perc_volume': 0.285902077296,
#    'price': 1.80011,
#    'updated': True,
#    'vol_24h': 4668040.0},
#   {'currency': 'Revain',
#    'pair': 'R/ETH',
#    'perc_volume': 0.26970293581,
#    'price': 2.59761,
#    'updated': True,
#    'vol_24h': 4403550.0},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/ETH',
#    'perc_volume': 0.211556537291,
#    'price': 0.0563067,
#    'updated': True,
#    'vol_24h': 3454170.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/ETH',
#    'perc_volume': 0.188566360952,
#    'price': 1.02117,
#    'updated': True,
#    'vol_24h': 3078800.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/USDT',
#    'perc_volume': 0.177849412193,
#    'price': 1.7969,
#    'updated': True,
#    'vol_24h': 2903820.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/BTC',
#    'perc_volume': 0.175096372722,
#    'price': 0.120149,
#    'updated': True,
#    'vol_24h': 2858870.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/BTC',
#    'perc_volume': 0.136224925305,
#    'price': 0.00357131,
#    'updated': True,
#    'vol_24h': 2224200.0},
#   {'currency': 'Viberate',
#    'pair': 'VIB/BTC',
#    'perc_volume': 0.115600709251,
#    'price': 0.255944,
#    'updated': True,
#    'vol_24h': 1887460.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/ETH',
#    'perc_volume': 0.0928928802314,
#    'price': 2.21935,
#    'updated': True,
#    'vol_24h': 1516700.0},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/USDT',
#    'perc_volume': 0.0888512100485,
#    'price': 0.0383064,
#    'updated': True,
#    'vol_24h': 1450710.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/USDT',
#    'perc_volume': 0.0887158548264,
#    'price': 1.05518,
#    'updated': True,
#    'vol_24h': 1448500.0},
#   {'currency': 'Hshare',
#    'pair': 'HSR/BTC',
#    'perc_volume': 0.0869488873347,
#    'price': 11.9419,
#    'updated': True,
#    'vol_24h': 1419650.0},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/BTC',
#    'perc_volume': 0.0833653425187,
#    'price': 0.225332,
#    'updated': True,
#    'vol_24h': 1361140.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/USDT',
#    'perc_volume': 0.0826769295341,
#    'price': 1.26521,
#    'updated': True,
#    'vol_24h': 1349900.0},
#   {'currency': 'Hshare',
#    'pair': 'HSR/USDT',
#    'perc_volume': 0.0822598394607,
#    'price': 11.912,
#    'updated': True,
#    'vol_24h': 1343090.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/BTC',
#    'perc_volume': 0.0813607378046,
#    'price': 0.379239,
#    'updated': True,
#    'vol_24h': 1328410.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/ETH',
#    'perc_volume': 0.0714804190606,
#    'price': 111.085,
#    'updated': True,
#    'vol_24h': 1167090.0},
#   {'currency': 'SunContract',
#    'pair': 'SNC/BTC',
#    'perc_volume': 0.0709904454061,
#    'price': 0.255093,
#    'updated': True,
#    'vol_24h': 1159090.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/BTC',
#    'perc_volume': 0.0700166227677,
#    'price': 4.23761,
#    'updated': True,
#    'vol_24h': 1143190.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/BTC',
#    'perc_volume': 0.068555276343,
#    'price': 0.322863,
#    'updated': True,
#    'vol_24h': 1119330.0},
#   {'currency': 'ugChain',
#    'pair': 'UGC/BTC',
#    'perc_volume': 0.0684627938157,
#    'price': 0.100422,
#    'updated': True,
#    'vol_24h': 1117820.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/BTC',
#    'perc_volume': 0.0684364577318,
#    'price': 0.36776,
#    'updated': True,
#    'vol_24h': 1117390.0},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/USDT',
#    'perc_volume': 0.0531182888763,
#    'price': 0.17773,
#    'updated': True,
#    'vol_24h': 867284.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/ETH',
#    'perc_volume': 0.0501914924975,
#    'price': 0.0770767,
#    'updated': True,
#    'vol_24h': 819497.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/ETH',
#    'perc_volume': 0.0495796991431,
#    'price': 0.00427592,
#    'updated': True,
#    'vol_24h': 809508.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/ETH',
#    'perc_volume': 0.0493953465556,
#    'price': 1.79011,
#    'updated': True,
#    'vol_24h': 806498.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/ETH',
#    'perc_volume': 0.0479603362148,
#    'price': 28.1405,
#    'updated': True,
#    'vol_24h': 783068.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/ETH',
#    'perc_volume': 0.0418185164551,
#    'price': 0.37524,
#    'updated': True,
#    'vol_24h': 682788.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/BTC',
#    'perc_volume': 0.0416252218484,
#    'price': 0.376008,
#    'updated': True,
#    'vol_24h': 679632.0},
#   {'currency': 'SingularDTV',
#    'pair': 'SNGLS/USDT',
#    'perc_volume': 0.0408656401904,
#    'price': 0.145224,
#    'updated': True,
#    'vol_24h': 667230.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/BTC',
#    'perc_volume': 0.0405322131185,
#    'price': 1.18091,
#    'updated': True,
#    'vol_24h': 661786.0},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/USDT',
#    'perc_volume': 0.0398495573243,
#    'price': 6.49639,
#    'updated': True,
#    'vol_24h': 650640.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/USDT',
#    'perc_volume': 0.0395927498826,
#    'price': 0.111519,
#    'updated': True,
#    'vol_24h': 646447.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/BTC',
#    'perc_volume': 0.0377582272733,
#    'price': 8.5015,
#    'updated': True,
#    'vol_24h': 616494.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/BTC',
#    'perc_volume': 0.0372296681934,
#    'price': 0.00527193,
#    'updated': True,
#    'vol_24h': 607864.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/USDT',
#    'perc_volume': 0.0363818912777,
#    'price': 0.00420071,
#    'updated': True,
#    'vol_24h': 594022.0},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/BTC',
#    'perc_volume': 0.0363327101721,
#    'price': 0.038179,
#    'updated': True,
#    'vol_24h': 593219.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/ETH',
#    'perc_volume': 0.0362696260641,
#    'price': 0.00358161,
#    'updated': True,
#    'vol_24h': 592189.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/USDT',
#    'perc_volume': 0.0359596564808,
#    'price': 0.366962,
#    'updated': True,
#    'vol_24h': 587128.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/BTC',
#    'perc_volume': 0.0344861832082,
#    'price': 0.125676,
#    'updated': True,
#    'vol_24h': 563070.0},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/BTC',
#    'perc_volume': 0.0341964250383,
#    'price': 6.54093,
#    'updated': True,
#    'vol_24h': 558339.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/USDT',
#    'perc_volume': 0.0338230651135,
#    'price': 0.381464,
#    'updated': True,
#    'vol_24h': 552243.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/USDT',
#    'perc_volume': 0.0328403004559,
#    'price': 0.00540091,
#    'updated': True,
#    'vol_24h': 536197.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/USDT',
#    'perc_volume': 0.0325824518202,
#    'price': 0.322054,
#    'updated': True,
#    'vol_24h': 531987.0},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/USDT',
#    'perc_volume': 0.0324188618663,
#    'price': 6.94957,
#    'updated': True,
#    'vol_24h': 529316.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/BTC',
#    'perc_volume': 0.0318787271588,
#    'price': 0.00425156,
#    'updated': True,
#    'vol_24h': 520497.0},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/ETH',
#    'perc_volume': 0.0312312269743,
#    'price': 0.0513534,
#    'updated': True,
#    'vol_24h': 509925.0},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/BTC',
#    'perc_volume': 0.0309995919292,
#    'price': 0.178565,
#    'updated': True,
#    'vol_24h': 506143.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/USDT',
#    'perc_volume': 0.030758341151,
#    'price': 0.0450076,
#    'updated': True,
#    'vol_24h': 502204.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/ETH',
#    'perc_volume': 0.0301458128361,
#    'price': 1243.83,
#    'updated': True,
#    'vol_24h': 492203.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/BTC',
#    'perc_volume': 0.0291046800669,
#    'price': 0.0454917,
#    'updated': True,
#    'vol_24h': 475204.0},
#   {'currency': 'BitcoinX',
#    'pair': 'BCX/BTC',
#    'perc_volume': 0.0289833503407,
#    'price': 0.00952349,
#    'updated': True,
#    'vol_24h': 473223.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/USDT',
#    'perc_volume': 0.0289616690065,
#    'price': 0.0187031,
#    'updated': True,
#    'vol_24h': 472869.0},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/BTC',
#    'perc_volume': 0.0285285322959,
#    'price': 2.39074,
#    'updated': True,
#    'vol_24h': 465797.0},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/BTC',
#    'perc_volume': 0.028127611353,
#    'price': 0.0564607,
#    'updated': True,
#    'vol_24h': 459251.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/USDT',
#    'perc_volume': 0.0265423015938,
#    'price': 1.1732,
#    'updated': True,
#    'vol_24h': 433367.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/ETH',
#    'perc_volume': 0.0256719858899,
#    'price': 0.319212,
#    'updated': True,
#    'vol_24h': 419157.0},
#   {'currency': 'Dash',
#    'pair': 'DASH/USDT',
#    'perc_volume': 0.0249696699028,
#    'price': 605.61,
#    'updated': True,
#    'vol_24h': 407690.0},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/USDT',
#    'perc_volume': 0.0249122817385,
#    'price': 0.0570096,
#    'updated': True,
#    'vol_24h': 406753.0},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/ETH',
#    'perc_volume': 0.0242300546712,
#    'price': 0.321956,
#    'updated': True,
#    'vol_24h': 395614.0},
#   {'currency': 'LAToken',
#    'pair': 'LA/BTC',
#    'perc_volume': 0.0232847117515,
#    'price': 0.323288,
#    'updated': True,
#    'vol_24h': 380179.0},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/BTC',
#    'perc_volume': 0.0230926420789,
#    'price': 0.0147954,
#    'updated': True,
#    'vol_24h': 377043.0},
#   {'currency': 'NEM',
#    'pair': 'XEM/BTC',
#    'perc_volume': 0.0228958564099,
#    'price': 0.542499,
#    'updated': True,
#    'vol_24h': 373830.0},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/USDT',
#    'perc_volume': 0.0217973967231,
#    'price': 0.435173,
#    'updated': True,
#    'vol_24h': 355895.0},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/BTC',
#    'perc_volume': 0.0208470315734,
#    'price': 2.90977,
#    'updated': True,
#    'vol_24h': 340378.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/BTC',
#    'perc_volume': 0.0208342922584,
#    'price': 0.161219,
#    'updated': True,
#    'vol_24h': 340170.0},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/BTC',
#    'perc_volume': 0.0207549777731,
#    'price': 115.027,
#    'updated': True,
#    'vol_24h': 338875.0},
#   {'currency': 'Loopring',
#    'pair': 'LRC/BTC',
#    'perc_volume': 0.0203637338099,
#    'price': 0.631186,
#    'updated': True,
#    'vol_24h': 332487.0},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/BTC',
#    'perc_volume': 0.0199011374333,
#    'price': 451.45,
#    'updated': True,
#    'vol_24h': 324934.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/USDT',
#    'perc_volume': 0.0195682003351,
#    'price': 8.43142,
#    'updated': True,
#    'vol_24h': 319498.0},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/USDT',
#    'perc_volume': 0.018957999395,
#    'price': 0.0752127,
#    'updated': True,
#    'vol_24h': 309535.0},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/BTC',
#    'perc_volume': 0.0182147706078,
#    'price': 0.121169,
#    'updated': True,
#    'vol_24h': 297400.0},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/BTC',
#    'perc_volume': 0.0169750760151,
#    'price': 12.3964,
#    'updated': True,
#    'vol_24h': 277159.0},
#   {'currency': 'Datum',
#    'pair': 'DAT/BTC',
#    'perc_volume': 0.0163488284379,
#    'price': 0.052039,
#    'updated': True,
#    'vol_24h': 266934.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/BTC',
#    'perc_volume': 0.0163245134952,
#    'price': 1.24452,
#    'updated': True,
#    'vol_24h': 266537.0},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/BTC',
#    'perc_volume': 0.0161928943223,
#    'price': 0.518945,
#    'updated': True,
#    'vol_24h': 264388.0},
#   {'currency': 'Super Bitcoin',
#    'pair': 'SBTC/BTC',
#    'perc_volume': 0.0156857715898,
#    'price': 21.9904,
#    'updated': True,
#    'vol_24h': 256108.0},
#   {'currency': 'Loopring',
#    'pair': 'LRC/USDT',
#    'perc_volume': 0.0155914516613,
#    'price': 0.626906,
#    'updated': True,
#    'vol_24h': 254568.0},
#   {'currency': 'LAToken',
#    'pair': 'LA/ETH',
#    'perc_volume': 0.0150816953205,
#    'price': 0.322032,
#    'updated': True,
#    'vol_24h': 246245.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/USDT',
#    'perc_volume': 0.0150211223274,
#    'price': 0.378064,
#    'updated': True,
#    'vol_24h': 245256.0},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/BTC',
#    'perc_volume': 0.0150163450843,
#    'price': 0.0675147,
#    'updated': True,
#    'vol_24h': 245178.0},
#   {'currency': 'Health Mutual Society',
#    'pair': 'HMC/BTC',
#    'perc_volume': 0.0149855379908,
#    'price': 0.0721064,
#    'updated': True,
#    'vol_24h': 244675.0},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/BTC',
#    'perc_volume': 0.0147792590822,
#    'price': 0.437145,
#    'updated': True,
#    'vol_24h': 241307.0},
#   {'currency': 'Ace',
#    'pair': 'ACE/BTC',
#    'perc_volume': 0.0147052730604,
#    'price': 0.36878,
#    'updated': True,
#    'vol_24h': 240099.0},
#   {'currency': 'Gas',
#    'pair': 'GAS/BTC',
#    'perc_volume': 0.0143687836531,
#    'price': 41.4187,
#    'updated': True,
#    'vol_24h': 234605.0},
#   {'currency': 'Monero',
#    'pair': 'XMR/BTC',
#    'perc_volume': 0.0141157122605,
#    'price': 245.257,
#    'updated': True,
#    'vol_24h': 230473.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/BTC',
#    'perc_volume': 0.0140311305584,
#    'price': 0.170572,
#    'updated': True,
#    'vol_24h': 229092.0},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/ETH',
#    'perc_volume': 0.0134036580471,
#    'price': 0.0681777,
#    'updated': True,
#    'vol_24h': 218847.0},
#   {'currency': 'Yee',
#    'pair': 'YEE/USDT',
#    'perc_volume': 0.0133855902686,
#    'price': 0.0244041,
#    'updated': True,
#    'vol_24h': 218552.0},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/USDT',
#    'perc_volume': 0.0132134257757,
#    'price': 2.3614,
#    'updated': True,
#    'vol_24h': 215741.0},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/BTC',
#    'perc_volume': 0.0130933209836,
#    'price': 0.423625,
#    'updated': True,
#    'vol_24h': 213780.0},
#   {'currency': 'Status',
#    'pair': 'SNT/BTC',
#    'perc_volume': 0.0130322580169,
#    'price': 0.204925,
#    'updated': True,
#    'vol_24h': 212783.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/USDT',
#    'perc_volume': 0.012948901249,
#    'price': 0.12072,
#    'updated': True,
#    'vol_24h': 211422.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/ETH',
#    'perc_volume': 0.0128873483086,
#    'price': 0.00532585,
#    'updated': True,
#    'vol_24h': 210417.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/USDT',
#    'perc_volume': 0.0128310013383,
#    'price': 0.124721,
#    'updated': True,
#    'vol_24h': 209497.0},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/USDT',
#    'perc_volume': 0.0128034403203,
#    'price': 0.0940158,
#    'updated': True,
#    'vol_24h': 209047.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/USDT',
#    'perc_volume': 0.0126212313675,
#    'price': 0.169028,
#    'updated': True,
#    'vol_24h': 206072.0},
#   {'currency': 'Yee',
#    'pair': 'YEE/BTC',
#    'perc_volume': 0.0124490056279,
#    'price': 0.0239788,
#    'updated': True,
#    'vol_24h': 203260.0},
#   {'currency': 'Datum',
#    'pair': 'DAT/USDT',
#    'perc_volume': 0.0124279367608,
#    'price': 0.0517087,
#    'updated': True,
#    'vol_24h': 202916.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/ETH',
#    'perc_volume': 0.0118187770147,
#    'price': 153.963,
#    'updated': True,
#    'vol_24h': 192970.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/BCH',
#    'perc_volume': 0.0114991916986,
#    'price': 8.79231,
#    'updated': True,
#    'vol_24h': 187752.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/ETH',
#    'perc_volume': 0.0113460749315,
#    'price': 0.124213,
#    'updated': True,
#    'vol_24h': 185252.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/ETH',
#    'perc_volume': 0.0113431963363,
#    'price': 0.365875,
#    'updated': True,
#    'vol_24h': 185205.0},
#   {'currency': 'Nuls',
#    'pair': 'NULS/BTC',
#    'perc_volume': 0.0112965263457,
#    'price': 2.43427,
#    'updated': True,
#    'vol_24h': 184443.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/ETH',
#    'perc_volume': 0.0112949339313,
#    'price': 1.02485,
#    'updated': True,
#    'vol_24h': 184417.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/BTC',
#    'perc_volume': 0.0104151862346,
#    'price': 0.0789939,
#    'updated': True,
#    'vol_24h': 170053.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/ETH',
#    'perc_volume': 0.0103788669374,
#    'price': 0.12009,
#    'updated': True,
#    'vol_24h': 169460.0},
#   {'currency': 'Populous',
#    'pair': 'PPT/BTC',
#    'perc_volume': 0.0102397144195,
#    'price': 29.5541,
#    'updated': True,
#    'vol_24h': 167188.0},
#   {'currency': 'Primas',
#    'pair': 'PST/USDT',
#    'perc_volume': 0.00991069711052,
#    'price': 0.319654,
#    'updated': True,
#    'vol_24h': 161816.0},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/BTC',
#    'perc_volume': 0.00978642754238,
#    'price': 0.0755076,
#    'updated': True,
#    'vol_24h': 159787.0},
#   {'currency': 'QunQun',
#    'pair': 'QUN/ETH',
#    'perc_volume': 0.00969467997557,
#    'price': 0.0660524,
#    'updated': True,
#    'vol_24h': 158289.0},
#   {'currency': 'Dash',
#    'pair': 'DASH/BTC',
#    'perc_volume': 0.00966901760541,
#    'price': 609.669,
#    'updated': True,
#    'vol_24h': 157870.0},
#   {'currency': 'ugChain',
#    'pair': 'UGC/USDT',
#    'perc_volume': 0.00929222786507,
#    'price': 0.089215,
#    'updated': True,
#    'vol_24h': 151718.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/BCH',
#    'perc_volume': 0.00923373726006,
#    'price': 25.3286,
#    'updated': True,
#    'vol_24h': 150763.0},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/BTC',
#    'perc_volume': 0.00917671657601,
#    'price': 0.093024,
#    'updated': True,
#    'vol_24h': 149832.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/ETH',
#    'perc_volume': 0.00910254681405,
#    'price': 8.38674,
#    'updated': True,
#    'vol_24h': 148621.0},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/BTC',
#    'perc_volume': 0.00903719657788,
#    'price': 52.0585,
#    'updated': True,
#    'vol_24h': 147554.0},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/USDT',
#    'perc_volume': 0.00891549937143,
#    'price': 0.0142024,
#    'updated': True,
#    'vol_24h': 145567.0},
#   {'currency': 'Gifto',
#    'pair': 'GTO/BTC',
#    'perc_volume': 0.00884365698433,
#    'price': 0.370396,
#    'updated': True,
#    'vol_24h': 144394.0},
#   {'currency': 'Populous',
#    'pair': 'PPT/USDT',
#    'perc_volume': 0.00876826228824,
#    'price': 29.2194,
#    'updated': True,
#    'vol_24h': 143163.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/USDT',
#    'perc_volume': 0.00873672023422,
#    'price': 4.24911,
#    'updated': True,
#    'vol_24h': 142648.0},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/ETH',
#    'perc_volume': 0.0085379746706,
#    'price': 0.0771444,
#    'updated': True,
#    'vol_24h': 139403.0},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/BTC',
#    'perc_volume': 0.00849816431117,
#    'price': 7.01932,
#    'updated': True,
#    'vol_24h': 138753.0},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/ETH',
#    'perc_volume': 0.00824546039883,
#    'price': 0.179191,
#    'updated': True,
#    'vol_24h': 134627.0},
#   {'currency': 'Status',
#    'pair': 'SNT/USDT',
#    'perc_volume': 0.0081139637193,
#    'price': 0.209335,
#    'updated': True,
#    'vol_24h': 132480.0},
#   {'currency': 'Yee',
#    'pair': 'YEE/ETH',
#    'perc_volume': 0.00793855315097,
#    'price': 0.0245548,
#    'updated': True,
#    'vol_24h': 129616.0},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/ETH',
#    'perc_volume': 0.00781452856966,
#    'price': 0.0931389,
#    'updated': True,
#    'vol_24h': 127591.0},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/USDT',
#    'perc_volume': 0.00772621081843,
#    'price': 0.0763128,
#    'updated': True,
#    'vol_24h': 126149.0},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/USDT',
#    'perc_volume': 0.00767892836076,
#    'price': 0.513887,
#    'updated': True,
#    'vol_24h': 125377.0},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/USDT',
#    'perc_volume': 0.0076010837964,
#    'price': 12.2056,
#    'updated': True,
#    'vol_24h': 124106.0},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/USDT',
#    'perc_volume': 0.00732682104327,
#    'price': 2.88028,
#    'updated': True,
#    'vol_24h': 119628.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/USDT',
#    'perc_volume': 0.00731218308034,
#    'price': 0.158627,
#    'updated': True,
#    'vol_24h': 119389.0},
#   {'currency': '0x',
#    'pair': 'ZRX/BTC',
#    'perc_volume': 0.00729442153536,
#    'price': 1.05158,
#    'updated': True,
#    'vol_24h': 119099.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/ETH',
#    'perc_volume': 0.00726049085978,
#    'price': 0.169394,
#    'updated': True,
#    'vol_24h': 118545.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/ETH',
#    'perc_volume': 0.00720304144879,
#    'price': 0.111767,
#    'updated': True,
#    'vol_24h': 117607.0},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/BTC',
#    'perc_volume': 0.00702971326849,
#    'price': 0.495901,
#    'updated': True,
#    'vol_24h': 114777.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/ETH',
#    'perc_volume': 0.00693496461304,
#    'price': 4.23752,
#    'updated': True,
#    'vol_24h': 113230.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/USDT',
#    'perc_volume': 0.00689111197096,
#    'price': 0.0761128,
#    'updated': True,
#    'vol_24h': 112514.0},
#   {'currency': 'UTRUST',
#    'pair': 'UTK/BTC',
#    'perc_volume': 0.00671845750444,
#    'price': 0.285109,
#    'updated': True,
#    'vol_24h': 109695.0},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/USDT',
#    'perc_volume': 0.00665500591618,
#    'price': 0.0677114,
#    'updated': True,
#    'vol_24h': 108659.0},
#   {'currency': 'NEM',
#    'pair': 'XEM/USDT',
#    'perc_volume': 0.00663013975321,
#    'price': 0.525088,
#    'updated': True,
#    'vol_24h': 108253.0},
#   {'currency': 'RefToken',
#    'pair': 'REF/BTC',
#    'perc_volume': 0.00649190593592,
#    'price': 25.6877,
#    'updated': True,
#    'vol_24h': 105996.0},
#   {'currency': 'RefToken',
#    'pair': 'REF/USDT',
#    'perc_volume': 0.00636445153903,
#    'price': 27.5043,
#    'updated': True,
#    'vol_24h': 103915.0},
#   {'currency': 'SmartMesh',
#    'pair': 'SMT/BTC',
#    'perc_volume': 0.00632433494606,
#    'price': 0.0667494,
#    'updated': True,
#    'vol_24h': 103260.0},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/USDT',
#    'perc_volume': 0.00631618913406,
#    'price': 114.128,
#    'updated': True,
#    'vol_24h': 103127.0},
#   {'currency': 'Gifto',
#    'pair': 'GTO/ETH',
#    'perc_volume': 0.00613814495734,
#    'price': 0.382903,
#    'updated': True,
#    'vol_24h': 100220.0},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/ETH',
#    'perc_volume': 0.00612761052376,
#    'price': 0.521121,
#    'updated': True,
#    'vol_24h': 100048.0},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/ETH',
#    'perc_volume': 0.00605871410326,
#    'price': 0.438566,
#    'updated': True,
#    'vol_24h': 98923.1},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/USDT',
#    'perc_volume': 0.00599155096457,
#    'price': 0.0909153,
#    'updated': True,
#    'vol_24h': 97826.5},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/ETH',
#    'perc_volume': 0.00594613653146,
#    'price': 0.0384579,
#    'updated': True,
#    'vol_24h': 97085.0},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/USDT',
#    'perc_volume': 0.0056126543375,
#    'price': 0.0346058,
#    'updated': True,
#    'vol_24h': 91640.1},
#   {'currency': 'Stellar',
#    'pair': 'XLM/ETH',
#    'perc_volume': 0.0055737994267,
#    'price': 0.377636,
#    'updated': True,
#    'vol_24h': 91005.7},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/BTC',
#    'perc_volume': 0.00552612499011,
#    'price': 0.0939594,
#    'updated': True,
#    'vol_24h': 90227.3},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/USDT',
#    'perc_volume': 0.00531125316858,
#    'price': 2.24258,
#    'updated': True,
#    'vol_24h': 86719.0},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/USDT',
#    'perc_volume': 0.00527953349912,
#    'price': 450.975,
#    'updated': True,
#    'vol_24h': 86201.1},
#   {'currency': 'Viuly',
#    'pair': 'VIU/BTC',
#    'perc_volume': 0.00516477554455,
#    'price': 0.0247441,
#    'updated': True,
#    'vol_24h': 84327.4},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/BTC',
#    'perc_volume': 0.00495145938938,
#    'price': 1.03398,
#    'updated': True,
#    'vol_24h': 80844.5},
#   {'currency': 'SmartMesh',
#    'pair': 'SMT/USDT',
#    'perc_volume': 0.00492800802534,
#    'price': 0.0630106,
#    'updated': True,
#    'vol_24h': 80461.6},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/BTC',
#    'perc_volume': 0.00490590408885,
#    'price': 0.029931,
#    'updated': True,
#    'vol_24h': 80100.7},
#   {'currency': 'TenX',
#    'pair': 'PAY/BTC',
#    'perc_volume': 0.00485821740292,
#    'price': 1.87817,
#    'updated': True,
#    'vol_24h': 79322.1},
#   {'currency': 'Nuls',
#    'pair': 'NULS/USDT',
#    'perc_volume': 0.00469628111009,
#    'price': 2.45221,
#    'updated': True,
#    'vol_24h': 76678.1},
#   {'currency': 'aelf',
#    'pair': 'ELF/ETH',
#    'perc_volume': 0.00465694847497,
#    'price': 1.1843,
#    'updated': True,
#    'vol_24h': 76035.9},
#   {'currency': 'Gifto',
#    'pair': 'GTO/USDT',
#    'perc_volume': 0.0045993275732,
#    'price': 0.370062,
#    'updated': True,
#    'vol_24h': 75095.1},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/ETH',
#    'perc_volume': 0.00455459297853,
#    'price': 0.158565,
#    'updated': True,
#    'vol_24h': 74364.7},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/BTC',
#    'perc_volume': 0.00453587598493,
#    'price': 0.0357981,
#    'updated': True,
#    'vol_24h': 74059.1},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/BTC',
#    'perc_volume': 0.00451863503696,
#    'price': 0.0343526,
#    'updated': True,
#    'vol_24h': 73777.6},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/ETH',
#    'perc_volume': 0.00448838528846,
#    'price': 0.01508,
#    'updated': True,
#    'vol_24h': 73283.7},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/BTC',
#    'perc_volume': 0.00443198932083,
#    'price': 0.116833,
#    'updated': True,
#    'vol_24h': 72362.9},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/USDT',
#    'perc_volume': 0.00432557316773,
#    'price': 0.181431,
#    'updated': True,
#    'vol_24h': 70625.4},
#   {'currency': 'UTRUST',
#    'pair': 'UTK/USDT',
#    'perc_volume': 0.00422949545874,
#    'price': 0.29585,
#    'updated': True,
#    'vol_24h': 69056.7},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/USDT',
#    'perc_volume': 0.00417164794415,
#    'price': 0.338257,
#    'updated': True,
#    'vol_24h': 68112.2},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/BTC',
#    'perc_volume': 0.0041091763032,
#    'price': 0.152376,
#    'updated': True,
#    'vol_24h': 67092.2},
#   {'currency': 'TenX',
#    'pair': 'PAY/USDT',
#    'perc_volume': 0.00395988133066,
#    'price': 1.8003,
#    'updated': True,
#    'vol_24h': 64654.6},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/USDT',
#    'perc_volume': 0.00379459484297,
#    'price': 0.0348059,
#    'updated': True,
#    'vol_24h': 61955.9},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/USDT',
#    'perc_volume': 0.0037358653758,
#    'price': 0.12002,
#    'updated': True,
#    'vol_24h': 60997.0},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/BTC',
#    'perc_volume': 0.00363629047985,
#    'price': 0.450665,
#    'updated': True,
#    'vol_24h': 59371.2},
#   {'currency': 'FunFair',
#    'pair': 'FUN/BTC',
#    'perc_volume': 0.0035667999663,
#    'price': 0.0539948,
#    'updated': True,
#    'vol_24h': 58236.6},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/ETH',
#    'perc_volume': 0.00350560838152,
#    'price': 0.11617,
#    'updated': True,
#    'vol_24h': 57237.5},
#   {'currency': 'Datum',
#    'pair': 'DAT/ETH',
#    'perc_volume': 0.00350296252378,
#    'price': 0.0522086,
#    'updated': True,
#    'vol_24h': 57194.3},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/BTC',
#    'perc_volume': 0.00348352894371,
#    'price': 0.0828203,
#    'updated': True,
#    'vol_24h': 56877.0},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/BTC',
#    'perc_volume': 0.00345971009943,
#    'price': 236.982,
#    'updated': True,
#    'vol_24h': 56488.1},
#   {'currency': 'ugChain',
#    'pair': 'UGC/ETH',
#    'perc_volume': 0.00344300199781,
#    'price': 0.0862805,
#    'updated': True,
#    'vol_24h': 56215.3},
#   {'currency': 'Walton',
#    'pair': 'WTC/ETH',
#    'perc_volume': 0.00340584362078,
#    'price': 21.2397,
#    'updated': True,
#    'vol_24h': 55608.6},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/BTC',
#    'perc_volume': 0.00331895291782,
#    'price': 38.2385,
#    'updated': True,
#    'vol_24h': 54189.9},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/ETH',
#    'perc_volume': 0.00329690410336,
#    'price': 0.0300077,
#    'updated': True,
#    'vol_24h': 53829.9},
#   {'currency': 'TRON',
#    'pair': 'TRX/ETH',
#    'perc_volume': 0.0032722461792,
#    'price': 0.0457143,
#    'updated': True,
#    'vol_24h': 53427.3},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/BTC',
#    'perc_volume': 0.00326460259019,
#    'price': 0.0716812,
#    'updated': True,
#    'vol_24h': 53302.5},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/ETH',
#    'perc_volume': 0.00317572136925,
#    'price': 0.090785,
#    'updated': True,
#    'vol_24h': 51851.3},
#   {'currency': 'Viuly',
#    'pair': 'VIU/USDT',
#    'perc_volume': 0.00317403708481,
#    'price': 0.0253043,
#    'updated': True,
#    'vol_24h': 51823.8},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/USDT',
#    'perc_volume': 0.00315520372247,
#    'price': 0.0819138,
#    'updated': True,
#    'vol_24h': 51516.3},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/USDT',
#    'perc_volume': 0.00315261298677,
#    'price': 0.700118,
#    'updated': True,
#    'vol_24h': 51474.0},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/ETH',
#    'perc_volume': 0.00313239544885,
#    'price': 6.98945,
#    'updated': True,
#    'vol_24h': 51143.9},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/ETH',
#    'perc_volume': 0.0029960541548,
#    'price': 2.92212,
#    'updated': True,
#    'vol_24h': 48917.8},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/BTC',
#    'perc_volume': 0.00297551200933,
#    'price': 0.0513588,
#    'updated': True,
#    'vol_24h': 48582.4},
#   {'currency': 'Bread',
#    'pair': 'BRD/BTC',
#    'perc_volume': 0.00297052040273,
#    'price': 0.851162,
#    'updated': True,
#    'vol_24h': 48500.9},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/USDT',
#    'perc_volume': 0.00292921562365,
#    'price': 0.319654,
#    'updated': True,
#    'vol_24h': 47826.5},
#   {'currency': 'Read',
#    'pair': 'READ/USDT',
#    'perc_volume': 0.00292287658949,
#    'price': 0.035606,
#    'updated': True,
#    'vol_24h': 47723.0},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/ETH',
#    'perc_volume': 0.00292202526027,
#    'price': 0.12434,
#    'updated': True,
#    'vol_24h': 47709.1},
#   {'currency': 'Enigma',
#    'pair': 'ENG/USDT',
#    'perc_volume': 0.00291948352193,
#    'price': 2.89739,
#    'updated': True,
#    'vol_24h': 47667.6},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/USDT',
#    'perc_volume': 0.00291915891439,
#    'price': 0.0716121,
#    'updated': True,
#    'vol_24h': 47662.3},
#   {'currency': 'QunQun',
#    'pair': 'QUN/BTC',
#    'perc_volume': 0.00291102535172,
#    'price': 0.0675997,
#    'updated': True,
#    'vol_24h': 47529.5},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/ETH',
#    'perc_volume': 0.00290759553614,
#    'price': 2.40294,
#    'updated': True,
#    'vol_24h': 47473.5},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/BCH',
#    'perc_volume': 0.00288327446886,
#    'price': 154.538,
#    'updated': True,
#    'vol_24h': 47076.4},
#   {'currency': 'Centra',
#    'pair': 'CTR/BTC',
#    'perc_volume': 0.00286766880797,
#    'price': 0.931091,
#    'updated': True,
#    'vol_24h': 46821.6},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/ETH',
#    'perc_volume': 0.0028019204682,
#    'price': 0.336392,
#    'updated': True,
#    'vol_24h': 45748.1},
#   {'currency': '0x',
#    'pair': 'ZRX/USDT',
#    'perc_volume': 0.00268538635913,
#    'price': 1.03537,
#    'updated': True,
#    'vol_24h': 43845.4},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/BTC',
#    'perc_volume': 0.00264347523766,
#    'price': 0.356621,
#    'updated': True,
#    'vol_24h': 43161.1},
#   {'currency': 'Leverj',
#    'pair': 'LEV/BTC',
#    'perc_volume': 0.00255294035564,
#    'price': 0.0937043,
#    'updated': True,
#    'vol_24h': 41682.9},
#   {'currency': 'Po.et',
#    'pair': 'POE/USDT',
#    'perc_volume': 0.00251978751324,
#    'price': 0.0633107,
#    'updated': True,
#    'vol_24h': 41141.6},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/BTC',
#    'perc_volume': 0.00249797756094,
#    'price': 0.719108,
#    'updated': True,
#    'vol_24h': 40785.5},
#   {'currency': 'Po.et',
#    'pair': 'POE/BTC',
#    'perc_volume': 0.00247386473247,
#    'price': 0.0637733,
#    'updated': True,
#    'vol_24h': 40391.8},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/ETH',
#    'perc_volume': 0.00247358299761,
#    'price': 0.223703,
#    'updated': True,
#    'vol_24h': 40387.2},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/USDT',
#    'perc_volume': 0.00219717660974,
#    'price': 0.115319,
#    'updated': True,
#    'vol_24h': 35874.2},
#   {'currency': 'Dent',
#    'pair': 'DENT/BTC',
#    'perc_volume': 0.00218075636765,
#    'price': 0.0238087,
#    'updated': True,
#    'vol_24h': 35606.1},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/ETH',
#    'perc_volume': 0.00215859730912,
#    'price': 0.0754933,
#    'updated': True,
#    'vol_24h': 35244.3},
#   {'currency': 'ProChain',
#    'pair': 'PRA/USDT',
#    'perc_volume': 0.00215062298789,
#    'price': 0.350059,
#    'updated': True,
#    'vol_24h': 35114.1},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/ETH',
#    'perc_volume': 0.00213485808556,
#    'price': 12.2918,
#    'updated': True,
#    'vol_24h': 34856.7},
#   {'currency': 'Health Mutual Society',
#    'pair': 'HMC/USDT',
#    'perc_volume': 0.0021139790832,
#    'price': 0.0721121,
#    'updated': True,
#    'vol_24h': 34515.8},
#   {'currency': 'Po.et',
#    'pair': 'POE/ETH',
#    'perc_volume': 0.00211133935014,
#    'price': 0.0640965,
#    'updated': True,
#    'vol_24h': 34472.7},
#   {'currency': 'ProChain',
#    'pair': 'PRA/ETH',
#    'perc_volume': 0.0020574299988,
#    'price': 0.350897,
#    'updated': True,
#    'vol_24h': 33592.5},
#   {'currency': 'Monaco',
#    'pair': 'MCO/BTC',
#    'perc_volume': 0.00203661224315,
#    'price': 7.56896,
#    'updated': True,
#    'vol_24h': 33252.6},
#   {'currency': 'Monero',
#    'pair': 'XMR/USDT',
#    'perc_volume': 0.00200941870532,
#    'price': 238.487,
#    'updated': True,
#    'vol_24h': 32808.6},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/BTC',
#    'perc_volume': 0.00199886589774,
#    'price': 0.181286,
#    'updated': True,
#    'vol_24h': 32636.3},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/USDT',
#    'perc_volume': 0.00196088069017,
#    'price': 237.14,
#    'updated': True,
#    'vol_24h': 32016.1},
#   {'currency': 'Dash',
#    'pair': 'DASH/ETH',
#    'perc_volume': 0.00194842311,
#    'price': 605.565,
#    'updated': True,
#    'vol_24h': 31812.7},
#   {'currency': 'RefToken',
#    'pair': 'REF/ETH',
#    'perc_volume': 0.00194230456399,
#    'price': 26.2483,
#    'updated': True,
#    'vol_24h': 31712.8},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/USDT',
#    'perc_volume': 0.00192941825687,
#    'price': 0.151225,
#    'updated': True,
#    'vol_24h': 31502.4},
#   {'currency': 'Delphy',
#    'pair': 'DPY/ETH',
#    'perc_volume': 0.00191006429752,
#    'price': 1.23476,
#    'updated': True,
#    'vol_24h': 31186.4},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/ETH',
#    'perc_volume': 0.00178929191634,
#    'price': 0.0340042,
#    'updated': True,
#    'vol_24h': 29214.5},
#   {'currency': 'SunContract',
#    'pair': 'SNC/ETH',
#    'perc_volume': 0.00178867332461,
#    'price': 0.251238,
#    'updated': True,
#    'vol_24h': 29204.4},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/ETH',
#    'perc_volume': 0.00176394190439,
#    'price': 451.293,
#    'updated': True,
#    'vol_24h': 28800.6},
#   {'currency': 'Enigma',
#    'pair': 'ENG/BTC',
#    'perc_volume': 0.00172086097082,
#    'price': 2.98009,
#    'updated': True,
#    'vol_24h': 28097.2},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/ETH',
#    'perc_volume': 0.00170747244071,
#    'price': 51.8106,
#    'updated': True,
#    'vol_24h': 27878.6},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/BTC',
#    'perc_volume': 0.00168404557535,
#    'price': 0.326009,
#    'updated': True,
#    'vol_24h': 27496.1},
#   {'currency': 'Golem',
#    'pair': 'GNT/BTC',
#    'perc_volume': 0.00165638656255,
#    'price': 0.347607,
#    'updated': True,
#    'vol_24h': 27044.5},
#   {'currency': 'Aventus',
#    'pair': 'AVT/BTC',
#    'perc_volume': 0.00163524419936,
#    'price': 2.20588,
#    'updated': True,
#    'vol_24h': 26699.3},
#   {'currency': 'FunFair',
#    'pair': 'FUN/ETH',
#    'perc_volume': 0.00160293656151,
#    'price': 0.0529876,
#    'updated': True,
#    'vol_24h': 26171.8},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/BTC',
#    'perc_volume': 0.0015988024088,
#    'price': 1.30999,
#    'updated': True,
#    'vol_24h': 26104.3},
#   {'currency': 'Status',
#    'pair': 'SNT/ETH',
#    'perc_volume': 0.00159342494794,
#    'price': 0.207742,
#    'updated': True,
#    'vol_24h': 26016.5},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/BTC',
#    'perc_volume': 0.00157600638452,
#    'price': 0.179586,
#    'updated': True,
#    'vol_24h': 25732.1},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/BTC',
#    'perc_volume': 0.0015357550488,
#    'price': 0.0797592,
#    'updated': True,
#    'vol_24h': 25074.9},
#   {'currency': 'Revain',
#    'pair': 'R/USDT',
#    'perc_volume': 0.00147268931479,
#    'price': 2.79807,
#    'updated': True,
#    'vol_24h': 24045.2},
#   {'currency': 'NAGA',
#    'pair': 'NGC/BTC',
#    'perc_volume': 0.00144477306582,
#    'price': 0.880072,
#    'updated': True,
#    'vol_24h': 23589.4},
#   {'currency': 'ProChain',
#    'pair': 'PRA/BTC',
#    'perc_volume': 0.00143634551896,
#    'price': 0.358491,
#    'updated': True,
#    'vol_24h': 23451.8},
#   {'currency': 'Ark',
#    'pair': 'ARK/USDT',
#    'perc_volume': 0.00142051936992,
#    'price': 3.92636,
#    'updated': True,
#    'vol_24h': 23193.4},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/USDT',
#    'perc_volume': 0.00138771563375,
#    'price': 0.0289049,
#    'updated': True,
#    'vol_24h': 22657.8},
#   {'currency': 'Viberate',
#    'pair': 'VIB/ETH',
#    'perc_volume': 0.00136770020996,
#    'price': 0.260958,
#    'updated': True,
#    'vol_24h': 22331.0},
#   {'currency': '0x',
#    'pair': 'ZRX/ETH',
#    'perc_volume': 0.00136321082635,
#    'price': 1.04554,
#    'updated': True,
#    'vol_24h': 22257.7},
#   {'currency': 'BT2 [CST]',
#    'pair': 'BT2/BTC',
#    'perc_volume': 0.00133754845619,
#    'price': 59.5218,
#    'updated': True,
#    'vol_24h': 21838.7},
#   {'currency': 'FunFair',
#    'pair': 'FUN/USDT',
#    'perc_volume': 0.00133030297078,
#    'price': 0.0528089,
#    'updated': True,
#    'vol_24h': 21720.4},
#   {'currency': 'Metal',
#    'pair': 'MTL/BTC',
#    'perc_volume': 0.00130643512913,
#    'price': 3.75829,
#    'updated': True,
#    'vol_24h': 21330.7},
#   {'currency': 'Populous',
#    'pair': 'PPT/ETH',
#    'perc_volume': 0.00130080655677,
#    'price': 30.5386,
#    'updated': True,
#    'vol_24h': 21238.8},
#   {'currency': 'Ark',
#    'pair': 'ARK/BTC',
#    'perc_volume': 0.00128310013383,
#    'price': 3.9701,
#    'updated': True,
#    'vol_24h': 20949.7},
#   {'currency': 'Monaco',
#    'pair': 'MCO/USDT',
#    'perc_volume': 0.00128042365274,
#    'price': 7.49216,
#    'updated': True,
#    'vol_24h': 20906.0},
#   {'currency': 'LAToken',
#    'pair': 'LA/USDT',
#    'perc_volume': 0.00127699383716,
#    'price': 0.331756,
#    'updated': True,
#    'vol_24h': 20850.0},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/USDT',
#    'perc_volume': 0.00127521155799,
#    'price': 0.312653,
#    'updated': True,
#    'vol_24h': 20820.9},
#   {'currency': 'IPChain',
#    'pair': 'IPC/BTC',
#    'perc_volume': 0.00125616383217,
#    'price': 0.693769,
#    'updated': True,
#    'vol_24h': 20509.9},
#   {'currency': 'Centra',
#    'pair': 'CTR/USDT',
#    'perc_volume': 0.00124107264361,
#    'price': 0.924556,
#    'updated': True,
#    'vol_24h': 20263.5},
#   {'currency': 'district0x',
#    'pair': 'DNT/BTC',
#    'perc_volume': 0.00123921074373,
#    'price': 0.0806945,
#    'updated': True,
#    'vol_24h': 20233.1},
#   {'currency': 'Substratum',
#    'pair': 'SUB/BTC',
#    'perc_volume': 0.00123876976744,
#    'price': 0.688242,
#    'updated': True,
#    'vol_24h': 20225.9},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/ETH',
#    'perc_volume': 0.00121175996973,
#    'price': 0.694393,
#    'updated': True,
#    'vol_24h': 19784.9},
#   {'currency': 'Civic',
#    'pair': 'CVC/USDT',
#    'perc_volume': 0.00120319768012,
#    'price': 0.430472,
#    'updated': True,
#    'vol_24h': 19645.1},
#   {'currency': 'Simple Token',
#    'pair': 'OST/BTC',
#    'perc_volume': 0.00116277485362,
#    'price': 0.27448,
#    'updated': True,
#    'vol_24h': 18985.1},
#   {'currency': 'AirSwap',
#    'pair': 'AST/BTC',
#    'perc_volume': 0.00114395986528,
#    'price': 0.555763,
#    'updated': True,
#    'vol_24h': 18677.9},
#   {'currency': 'AirSwap',
#    'pair': 'AST/USDT',
#    'perc_volume': 0.00111619060841,
#    'price': 0.558094,
#    'updated': True,
#    'vol_24h': 18224.5},
#   {'currency': 'Nano',
#    'pair': 'NANO/BTC',
#    'perc_volume': 0.00110548468406,
#    'price': 8.6435,
#    'updated': True,
#    'vol_24h': 18049.7},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/USDT',
#    'perc_volume': 0.001102342728,
#    'price': 1.27992,
#    'updated': True,
#    'vol_24h': 17998.4},
#   {'currency': 'Walton',
#    'pair': 'WTC/BTC',
#    'perc_volume': 0.0011000031038,
#    'price': 21.4027,
#    'updated': True,
#    'vol_24h': 17960.2},
#   {'currency': 'BitcoinX',
#    'pair': 'BCX/BCH',
#    'perc_volume': 0.00108548763428,
#    'price': 0.0095159,
#    'updated': True,
#    'vol_24h': 17723.2},
#   {'currency': 'NEM',
#    'pair': 'XEM/ETH',
#    'perc_volume': 0.00107425498825,
#    'price': 0.536082,
#    'updated': True,
#    'vol_24h': 17539.8},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/USDT',
#    'perc_volume': 0.0010222075368,
#    'price': 37.0007,
#    'updated': True,
#    'vol_24h': 16690.0},
#   {'currency': 'IPChain',
#    'pair': 'IPC/ETH',
#    'perc_volume': 0.00100309856427,
#    'price': 0.689118,
#    'updated': True,
#    'vol_24h': 16378.0},
#   {'currency': 'Golem',
#    'pair': 'GNT/USDT',
#    'perc_volume': 0.000978740748969,
#    'price': 0.343358,
#    'updated': True,
#    'vol_24h': 15980.3},
#   {'currency': 'Maker',
#    'pair': 'MKR/BTC',
#    'perc_volume': 0.000942856303444,
#    'price': 1045.88,
#    'updated': True,
#    'vol_24h': 15394.4},
#   {'currency': 'Enigma',
#    'pair': 'ENG/ETH',
#    'perc_volume': 0.000936002796952,
#    'price': 2.93811,
#    'updated': True,
#    'vol_24h': 15282.5},
#   {'currency': 'QunQun',
#    'pair': 'QUN/USDT',
#    'perc_volume': 0.000910309803441,
#    'price': 0.0673113,
#    'updated': True,
#    'vol_24h': 14863.0},
#   {'currency': 'Viberate',
#    'pair': 'VIB/USDT',
#    'perc_volume': 0.000902384479579,
#    'price': 0.258944,
#    'updated': True,
#    'vol_24h': 14733.6},
#   {'currency': 'Nano',
#    'pair': 'NANO/USDT',
#    'perc_volume': 0.000897398997644,
#    'price': 8.9015,
#    'updated': True,
#    'vol_24h': 14652.2},
#   {'currency': 'SingularDTV',
#    'pair': 'SNGLS/BTC',
#    'perc_volume': 0.000884126836276,
#    'price': 0.146849,
#    'updated': True,
#    'vol_24h': 14435.5},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/BCH',
#    'perc_volume': 0.00087850438859,
#    'price': 6.55971,
#    'updated': True,
#    'vol_24h': 14343.7},
#   {'currency': 'Achain',
#    'pair': 'ACT/BCH',
#    'perc_volume': 0.000878302274458,
#    'price': 0.380098,
#    'updated': True,
#    'vol_24h': 14340.4},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/BTC',
#    'perc_volume': 0.000873433161266,
#    'price': 0.510272,
#    'updated': True,
#    'vol_24h': 14260.9},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/BTC',
#    'perc_volume': 0.000838767525207,
#    'price': 0.30016,
#    'updated': True,
#    'vol_24h': 13694.9},
#   {'currency': 'Centra',
#    'pair': 'CTR/ETH',
#    'perc_volume': 0.00083646464903,
#    'price': 0.933802,
#    'updated': True,
#    'vol_24h': 13657.3},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/USDT',
#    'perc_volume': 0.000827112276899,
#    'price': 0.420571,
#    'updated': True,
#    'vol_24h': 13504.6},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/USDT',
#    'perc_volume': 0.000814936431584,
#    'price': 0.220037,
#    'updated': True,
#    'vol_24h': 13305.8},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/USDT',
#    'perc_volume': 0.000809479350006,
#    'price': 0.0514087,
#    'updated': True,
#    'vol_24h': 13216.7},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/USDT',
#    'perc_volume': 0.00079559472157,
#    'price': 0.494383,
#    'updated': True,
#    'vol_24h': 12990.0},
#   {'currency': 'Read',
#    'pair': 'READ/BTC',
#    'perc_volume': 0.000787191673395,
#    'price': 0.0351179,
#    'updated': True,
#    'vol_24h': 12852.8},
#   {'currency': 'Nuls',
#    'pair': 'NULS/ETH',
#    'perc_volume': 0.000780191174806,
#    'price': 2.39822,
#    'updated': True,
#    'vol_24h': 12738.5},
#   {'currency': 'Bread',
#    'pair': 'BRD/USDT',
#    'perc_volume': 0.000764205784326,
#    'price': 0.836241,
#    'updated': True,
#    'vol_24h': 12477.5},
#   {'currency': 'Nano',
#    'pair': 'NANO/ETH',
#    'perc_volume': 0.000740037833816,
#    'price': 8.46802,
#    'updated': True,
# ...
#    'vol_24h': 10471.4},
#   {'currency': 'Gas',
#    'pair': 'GAS/USDT',
#    'perc_volume': 0.000633756423474,
#    'price': 40.6474,
#    'updated': True,
#    'vol_24h': 10347.6},
#   {'currency': 'Maggie',
#    'pair': 'MAG/USDT',
#    'perc_volume': 0.000621635700194,
#    'price': 0.0322054,
#    'updated': True,
#    'vol_24h': 10149.7},
#   {'currency': 'Walton',
#    'pair': 'WTC/USDT',
#    'perc_volume': 0.000612453593908,
#    'price': 21.1573,
#    'updated': True,
#    'vol_24h': 9999.78},
#   {'currency': 'Request Network',
#    'pair': 'REQ/USDT',
#    'perc_volume': 0.000604361066536,
#    'price': 0.278347,
#    'updated': True,
#    'vol_24h': 9867.65},
#   {'currency': 'Bancor',
#    'pair': 'BNT/BTC',
#    'perc_volume': 0.000603125107993,
#    'price': 5.04549,
#    'updated': True,
#    'vol_24h': 9847.47},
#   {'currency': 'IPChain',
#    'pair': 'IPC/USDT',
#    'perc_volume': 0.000591997806298,
#    'price': 0.71122,
#    'updated': True,
#    'vol_24h': 9665.79},
#   {'currency': 'Viuly',
#    'pair': 'VIU/ETH',
#    'perc_volume': 0.00057645277964,
#    'price': 0.0255455,
#    'updated': True,
#    'vol_24h': 9411.98},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/BTC',
#    'perc_volume': 0.000550107508702,
#    'price': 1.64399,
#    'updated': True,
#    'vol_24h': 8981.83},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/USDT',
#    'perc_volume': 0.000549079788962,
#    'price': 2.43001,
#    'updated': True,
#    'vol_24h': 8965.05},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/BTC',
#    'perc_volume': 0.000540140219635,
#    'price': 0.698276,
#    'updated': True,
#    'vol_24h': 8819.09},
#   {'currency': 'Request Network',
#    'pair': 'REQ/BTC',
#    'perc_volume': 0.000532982317009,
#    'price': 0.279922,
#    'updated': True,
#    'vol_24h': 8702.22},
#   {'currency': 'Civic',
#    'pair': 'CVC/BTC',
#    'perc_volume': 0.000524722586127,
#    'price': 0.428557,
#    'updated': True,
#    'vol_24h': 8567.36},
#   {'currency': 'Health Mutual Society',
#    'pair': 'HMC/ETH',
#    'perc_volume': 0.000518689173039,
#    'price': 0.0716577,
#    'updated': True,
#    'vol_24h': 8468.85},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/BTC',
#    'perc_volume': 0.000493350185494,
#    'price': 2.50366,
#    'updated': True,
#    'vol_24h': 8055.13},
#   {'currency': 'Simple Token',
#    'pair': 'OST/USDT',
#    'perc_volume': 0.000485125977702,
#    'price': 0.269145,
#    'updated': True,
#    'vol_24h': 7920.85},
#   {'currency': 'Ark',
#    'pair': 'ARK/ETH',
#    'perc_volume': 0.000483911455506,
#    'price': 3.96592,
#    'updated': True,
#    'vol_24h': 7901.02},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/ETH',
#    'perc_volume': 0.000480029026761,
#    'price': 0.49969,
#    'updated': True,
#    'vol_24h': 7837.63},
#   {'currency': 'SunContract',
#    'pair': 'SNC/USDT',
#    'perc_volume': 0.000476170484231,
#    'price': 0.23754,
#    'updated': True,
#    'vol_24h': 7774.63},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/ETH',
#    'perc_volume': 0.000472419123439,
#    'price': 0.152079,
#    'updated': True,
#    'vol_24h': 7713.38},
#   {'currency': 'SALT',
#    'pair': 'SALT/BTC',
#    'perc_volume': 0.000467747224642,
#    'price': 4.161,
#    'updated': True,
#    'vol_24h': 7637.1},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/ETH',
#    'perc_volume': 0.000465628701054,
#    'price': 38.6516,
#    'updated': True,
#    'vol_24h': 7602.51},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/BTC',
#    'perc_volume': 0.000465603589904,
#    'price': 1.90206,
#    'updated': True,
#    'vol_24h': 7602.1},
#   {'currency': 'Loopring',
#    'pair': 'LRC/ETH',
#    'perc_volume': 0.000460667105334,
#    'price': 0.631185,
#    'updated': True,
#    'vol_24h': 7521.5},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/USDT',
#    'perc_volume': 0.00045613484903,
#    'price': 50.3595,
#    'updated': True,
#    'vol_24h': 7447.5},
#   {'currency': 'Primas',
#    'pair': 'PST/BTC',
#    'perc_volume': 0.000452536605004,
#    'price': 0.332472,
#    'updated': True,
#    'vol_24h': 7388.75},
#   {'currency': 'Ace',
#    'pair': 'ACE/USDT',
#    'perc_volume': 0.000449544703376,
#    'price': 0.368662,
#    'updated': True,
#    'vol_24h': 7339.9},
#   {'currency': 'Change',
#    'pair': 'CAG/BTC',
#    'perc_volume': 0.000448703173624,
#    'price': 0.263426,
#    'updated': True,
#    'vol_24h': 7326.16},
#   {'currency': 'Maker',
#    'pair': 'MKR/USDT',
#    'perc_volume': 0.000437280662803,
#    'price': 1011.64,
#    'updated': True,
#    'vol_24h': 7139.66},
#   {'currency': 'Storj',
#    'pair': 'STORJ/BTC',
#    'perc_volume': 0.000426855860835,
#    'price': 0.976582,
#    'updated': True,
#    'vol_24h': 6969.45},
#   {'currency': 'SmartMesh',
#    'pair': 'SMT/ETH',
#    'perc_volume': 0.000418794569284,
#    'price': 0.0656799,
#    'updated': True,
#    'vol_24h': 6837.83},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/USDT',
#    'perc_volume': 0.000410216355527,
#    'price': 0.182531,
#    'updated': True,
#    'vol_24h': 6697.77},
#   {'currency': 'Aventus',
#    'pair': 'AVT/ETH',
#    'perc_volume': 0.000407455353983,
#    'price': 2.15914,
#    'updated': True,
#    'vol_24h': 6652.69},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/USDT',
#    'perc_volume': 0.000390915680807,
#    'price': 0.452376,
#    'updated': True,
#    'vol_24h': 6382.64},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/USDT',
#    'perc_volume': 0.000386849511941,
#    'price': 0.699418,
#    'updated': True,
#    'vol_24h': 6316.25},
#   {'currency': 'Bread',
#    'pair': 'BRD/ETH',
#    'perc_volume': 0.000375723435181,
#    'price': 0.815203,
#    'updated': True,
#    'vol_24h': 6134.59},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/USDT',
#    'perc_volume': 0.000373278466645,
#    'price': 1.95393,
#    'updated': True,
#    'vol_24h': 6094.67},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/ETH',
#    'perc_volume': 0.000371615006087,
#    'price': 0.18665,
#    'updated': True,
#    'vol_24h': 6067.51},
#   {'currency': 'OAX',
#    'pair': 'OAX/BTC',
#    'perc_volume': 0.000371589894938,
#    'price': 0.658736,
#    'updated': True,
#    'vol_24h': 6067.1},
#   {'currency': 'Primas',
#    'pair': 'PST/ETH',
#    'perc_volume': 0.000371178317068,
#    'price': 0.319771,
#    'updated': True,
#    'vol_24h': 6060.38},
#   {'currency': 'Everex',
#    'pair': 'EVX/BTC',
#    'perc_volume': 0.00034585035393,
#    'price': 1.72418,
#    'updated': True,
#    'vol_24h': 5646.84},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/ETH',
#    'perc_volume': 0.000341755399112,
#    'price': 0.442876,
#    'updated': True,
#    'vol_24h': 5579.98},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/ETH',
#    'perc_volume': 0.000330124649487,
#    'price': 1.30531,
#    'updated': True,
#    'vol_24h': 5390.08},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/BCH',
#    'perc_volume': 0.000325706924525,
#    'price': 0.180264,
#    'updated': True,
#    'vol_24h': 5317.95},
#   {'currency': 'AirSwap',
#    'pair': 'AST/ETH',
#    'perc_volume': 0.000319938097209,
#    'price': 0.568977,
#    'updated': True,
#    'vol_24h': 5223.76},
#   {'currency': 'OAX',
#    'pair': 'OAX/USDT',
#    'perc_volume': 0.000307686305978,
#    'price': 0.682615,
#    'updated': True,
#    'vol_24h': 5023.72},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/ETH',
#    'perc_volume': 0.000302500547311,
#    'price': 237.875,
#    'updated': True,
#    'vol_24h': 4939.05},
#   {'currency': 'Aventus',
#    'pair': 'AVT/USDT',
#    'perc_volume': 0.000287905457076,
#    'price': 2.21637,
#    'updated': True,
#    'vol_24h': 4700.75},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/USDT',
#    'perc_volume': 0.000287379960332,
#    'price': 0.524488,
#    'updated': True,
#    'vol_24h': 4692.17},
#   {'currency': 'Metal',
#    'pair': 'MTL/USDT',
#    'perc_volume': 0.000286273844807,
#    'price': 3.82294,
#    'updated': True,
#    'vol_24h': 4674.11},
#   {'currency': 'Everex',
#    'pair': 'EVX/USDT',
#    'perc_volume': 0.000283299092257,
#    'price': 1.7879,
#    'updated': True,
#    'vol_24h': 4625.54},
#   {'currency': 'Maggie',
#    'pair': 'MAG/BTC',
#    'perc_volume': 0.000279771894411,
#    'price': 0.032907,
#    'updated': True,
#    'vol_24h': 4567.95},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/ETH',
#    'perc_volume': 0.000267822049444,
#    'price': 0.0347916,
#    'updated': True,
#    'vol_24h': 4372.84},
#   {'currency': 'Civic',
#    'pair': 'CVC/ETH',
#    'perc_volume': 0.000256330329843,
#    'price': 0.425645,
#    'updated': True,
#    'vol_24h': 4185.21},
#   {'currency': 'Ace',
#    'pair': 'ACE/ETH',
#    'perc_volume': 0.000247376673773,
#    'price': 0.357789,
#    'updated': True,
#    'vol_24h': 4039.02},
#   {'currency': 'StarChain',
#    'pair': 'STC/BTC',
#    'perc_volume': 0.000247295215653,
#    'price': 0.112496,
#    'updated': True,
#    'vol_24h': 4037.69},
#   {'currency': 'Maggie',
#    'pair': 'MAG/ETH',
#    'perc_volume': 0.000246006584942,
#    'price': 0.0332845,
#    'updated': True,
#    'vol_24h': 4016.65},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/USDT',
#    'perc_volume': 0.000238805809621,
#    'price': 1.68818,
#    'updated': True,
#    'vol_24h': 3899.08},
#   {'currency': 'Monetha',
#    'pair': 'MTH/BTC',
#    'perc_volume': 0.000238642280914,
#    'price': 0.145148,
#    'updated': True,
#    'vol_24h': 3896.41},
#   {'currency': 'Everex',
#    'pair': 'EVX/ETH',
#    'perc_volume': 0.000236889400165,
#    'price': 1.71293,
#    'updated': True,
#    'vol_24h': 3867.79},
#   {'currency': 'SONM',
#    'pair': 'SNM/BTC',
#    'perc_volume': 0.000219005361774,
#    'price': 0.226778,
#    'updated': True,
#    'vol_24h': 3575.79},
#   {'currency': 'TenX',
#    'pair': 'PAY/ETH',
#    'perc_volume': 0.00021152530147,
#    'price': 1.92395,
#    'updated': True,
#    'vol_24h': 3453.66},
#   {'currency': 'SALT',
#    'pair': 'SALT/USDT',
#    'perc_volume': 0.00020425347997,
#    'price': 4.1677,
#    'updated': True,
#    'vol_24h': 3334.93},
#   {'currency': 'Storj',
#    'pair': 'STORJ/USDT',
#    'perc_volume': 0.000192459201638,
#    'price': 0.954061,
#    'updated': True,
#    'vol_24h': 3142.36},
#   {'currency': 'Leverj',
#    'pair': 'LEV/ETH',
#    'perc_volume': 0.000180815590204,
#    'price': 0.0909374,
#    'updated': True,
#    'vol_24h': 2952.25},
#   {'currency': 'Dent',
#    'pair': 'DENT/ETH',
#    'perc_volume': 0.000179517772487,
#    'price': 0.022963,
#    'updated': True,
#    'vol_24h': 2931.06},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/ETH',
#    'perc_volume': 0.000172108145896,
#    'price': 0.321753,
#    'updated': True,
#    'vol_24h': 2810.08},
#   {'currency': 'Change',
#    'pair': 'CAG/USDT',
#    'perc_volume': 0.000169492911515,
#    'price': 0.264344,
#    'updated': True,
#    'vol_24h': 2767.38},
#   {'currency': 'district0x',
#    'pair': 'DNT/USDT',
#    'perc_volume': 0.000168769587907,
#    'price': 0.0795134,
#    'updated': True,
#    'vol_24h': 2755.57},
#   {'currency': 'district0x',
#    'pair': 'DNT/ETH',
#    'perc_volume': 0.000166883801805,
#    'price': 0.0798285,
#    'updated': True,
#    'vol_24h': 2724.78},
#   {'currency': 'Monetha',
#    'pair': 'MTH/USDT',
#    'perc_volume': 0.000166193551419,
#    'price': 0.148325,
#    'updated': True,
#    'vol_24h': 2713.51},
#   {'currency': 'Simple Token',
#    'pair': 'OST/ETH',
#    'perc_volume': 0.000165728076447,
#    'price': 0.263405,
#    'updated': True,
#    'vol_24h': 2705.91},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/USDT',
#    'perc_volume': 0.00014741286124,
#    'price': 1.59127,
#    'updated': True,
#    'vol_24h': 2406.87},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/ETH',
#    'perc_volume': 0.00014361495295,
#    'price': 0.179267,
#    'updated': True,
#    'vol_24h': 2344.86},
#   {'currency': 'Golem',
#    'pair': 'GNT/ETH',
#    'perc_volume': 0.00013965412842,
#    'price': 0.342963,
#    'updated': True,
#    'vol_24h': 2280.19},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/ETH',
#    'perc_volume': 0.00013523579099,
#    'price': 2.48459,
#    'updated': True,
#    'vol_24h': 2208.05},
#   {'currency': 'Maker',
#    'pair': 'MKR/ETH',
#    'perc_volume': 0.000132928015077,
#    'price': 1044.42,
#    'updated': True,
#    'vol_24h': 2170.37},
#   {'currency': 'Metal',
#    'pair': 'MTL/ETH',
#    'perc_volume': 0.000122526486858,
#    'price': 3.82244,
#    'updated': True,
#    'vol_24h': 2000.54},
#   {'currency': 'Monetha',
#    'pair': 'MTH/ETH',
#    'perc_volume': 0.000118438881645,
#    'price': 0.150157,
#    'updated': True,
#    'vol_24h': 1933.8},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/BTC',
#    'perc_volume': 0.000112460590593,
#    'price': 1.56967,
#    'updated': True,
#    'vol_24h': 1836.19},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/ETH',
#    'perc_volume': 0.000107032907435,
#    'price': 1.93282,
#    'updated': True,
#    'vol_24h': 1747.57},
#   {'currency': 'OAX',
#    'pair': 'OAX/ETH',
#    'perc_volume': 9.59803267221e-05,
#    'price': 0.677442,
#    'updated': True,
#    'vol_24h': 1567.11},
#   {'currency': 'Request Network',
#    'pair': 'REQ/ETH',
#    'perc_volume': 9.41067899605e-05,
#    'price': 0.270501,
#    'updated': True,
#    'vol_24h': 1536.52},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/ETH',
#    'perc_volume': 9.31372545916e-05,
#    'price': 0.506879,
#    'updated': True,
#    'vol_24h': 1520.69},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/BCH',
#    'perc_volume': 8.45694527748e-05,
#    'price': 1.91685,
#    'updated': True,
#    'vol_24h': 1380.8},
#   {'currency': 'Read',
#    'pair': 'READ/ETH',
#    'perc_volume': 8.34627247826e-05,
#    'price': 0.034961,
#    'updated': True,
#    'vol_24h': 1362.73},
#   {'currency': 'Super Bitcoin',
#    'pair': 'SBTC/BCH',
#    'perc_volume': 7.7169625657e-05,
#    'price': 21.8991,
#    'updated': True,
#    'vol_24h': 1259.98},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/ETH',
#    'perc_volume': 7.68670669253e-05,
#    'price': 1.68785,
#    'updated': True,
#    'vol_24h': 1255.04},
#   {'currency': 'Monaco',
#    'pair': 'MCO/ETH',
#    'perc_volume': 7.25265128131e-05,
#    'price': 7.57878,
#    'updated': True,
#    'vol_24h': 1184.17},
#   {'currency': 'Substratum',
#    'pair': 'SUB/ETH',
#    'perc_volume': 6.6785858983e-05,
#    'price': 0.685071,
#    'updated': True,
#    'vol_24h': 1090.44},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/ETH',
#    'perc_volume': 6.67472735577e-05,
#    'price': 0.696137,
#    'updated': True,
#    'vol_24h': 1089.81},
#   {'currency': 'Storj',
#    'pair': 'STORJ/ETH',
#    'perc_volume': 6.60484486329e-05,
#    'price': 0.959068,
#    'updated': True,
#    'vol_24h': 1078.4},
#   {'currency': 'SONM',
#    'pair': 'SNM/USDT',
#    'perc_volume': 6.25567738772e-05,
#    'price': 0.223738,
#    'updated': True,
#    'vol_24h': 1021.39},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/BCH',
#    'perc_volume': 6.24661287511e-05,
#    'price': 112.701,
#    'updated': True,
#    'vol_24h': 1019.91},
#   {'currency': 'Change',
#    'pair': 'CAG/ETH',
#    'perc_volume': 3.7159356974e-05,
#    'price': 0.274938,
#    'updated': True,
#    'vol_24h': 606.716},
#   {'currency': 'Gas',
#    'pair': 'GAS/ETH',
#    'perc_volume': 3.71343070709e-05,
#    'price': 40.2738,
#    'updated': True,
#    'vol_24h': 606.307},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/ETH',
#    'perc_volume': 2.73609250771e-05,
#    'price': 1.60391,
#    'updated': True,
#    'vol_24h': 446.733},
#   {'currency': 'SALT',
#    'pair': 'SALT/ETH',
#    'perc_volume': 2.64494515862e-05,
#    'price': 4.18866,
#    'updated': True,
#    'vol_24h': 431.851},
#   {'currency': 'Monero',
#    'pair': 'XMR/ETH',
#    'perc_volume': 2.30255156882e-05,
#    'price': 242.181,
#    'updated': True,
#    'vol_24h': 375.947},
#   {'currency': 'SONM',
#    'pair': 'SNM/ETH',
#    'perc_volume': 2.18481089964e-05,
#    'price': 0.224719,
#    'updated': True,
#    'vol_24h': 356.723},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/BCH',
#    'perc_volume': 1.59771834209e-05,
#    'price': 247.756,
#    'updated': True,
#    'vol_24h': 260.866},
#   {'currency': 'SingularDTV',
#    'pair': 'SNGLS/ETH',
#    'perc_volume': 9.84816422286e-06,
#    'price': 0.146482,
#    'updated': True,
#    'vol_24h': 160.795},
#   {'currency': 'Dash',
#    'pair': 'DASH/BCH',
#    'perc_volume': 6.96626168023e-06,
#    'price': 609.864,
#    'updated': True,
#    'vol_24h': 113.741},
#   {'currency': 'Aventus',
#    'pair': 'AVT/BCH',
#    'perc_volume': 2.05836094874e-06,
#    'price': 2.19854,
#    'updated': True,
#    'vol_24h': 33.6077},
#   {'currency': 'Bancor',
#    'pair': 'BNT/ETH',
#    'perc_volume': 5.75061254461e-07,
#    'price': 5.06423,
#    'updated': True,
#    'vol_24h': 9.38926}],
#  'name': 'OKEx ',
#  'social': {'twitter': {'link': 'https://twitter.com/CoinMarketCap',
#    'username': '@OKEx_'}},
#  'volume': 1632740847.55,
#  'web': 'https://www.okex.com'}

# %% [markdown]
# In order to obtain all available values for the `name` parameter, use:

# %%
cmc.exchange_slugs
# Out:
# ['abucoins',
#  'acx',
#  'aex',
#  'aidos-market',
#  'alcurex',
#  'allcoin',
#  'altcoin-trader',
#  'bancor-network',
#  'barterdex',
#  'bcex',
#  'bibox',
#  'bigone',
#  'binance',
#  'bisq',
#  'bit-z',
#  'bit2c',
#  'bitbank',
#  'bitbay',
#  'bitcoin-indonesia',
#  'bitcointoyou',
#  'bitcointrade',
#  'bitex-la',
#  'bitfinex',
#  'bitflip',
#  'bitflyer',
#  'bitholic',
#  'bithumb',
#  'bitinka',
#  'bitkonan',
#  'bitlish',
#  'bitmarket',
#  'bitmaszyna',
#  'bitmex',
#  'bitonic',
#  'bits-blockchain',
#  'bitsane',
#  'bitshares-asset-exchange',
#  'bitso',
#  'bitstamp',
#  'bitstamp-ripple-gateway',
#  'bittrex',
#  'bittylicious',
#  'bl3p',
#  'bleutrade',
#  'braziliex',
#  'btc-alpha',
#  'btc-markets',
#  'btc-trade-ua',
#  'btcbox',
#  'btcc',
#  'btctrade-im',
#  'btcturk',
#  'burst-asset-exchange',
#  'bx-thailand',
#  'c-cex',
#  'c2cx',
#  'cex-io',
#  'chaoex',
#  'cobinhood',
#  'coinbene',
#  'coincorner',
#  'coinegg',
#  'coinex',
#  'coinexchange',
#  'coinfalcon',
#  'coinfloor',
#  'coingi',
#  'coinhouse',
#  'coinlink',
#  'coinmate',
#  'coinnest',
#  'coinone',
#  'coinrail',
#  'coinrate',
#  'coinroom',
#  'coinsbank',
#  'coinsecure',
#  'coinsquare',
#  'coinut',
#  'coolcoin',
#  'coss',
#  'counterparty-dex',
#  'cryptobridge',
#  'cryptoderivatives',
#  'cryptomarket',
#  'cryptomate',
#  'cryptopia',
#  'cryptox',
#  'dgtmarket',
#  'dsx',
#  'ethexindia',
#  'excambriorex',
#  'exmo',
#  'exrates',
#  'exx',
#  'ezbtc',
#  'fargobase',
#  'fatbtc',
#  'fisco',
#  'foxbit',
#  'freiexchange',
#  'gate-io',
#  'gatecoin',
#  'gatehub',
#  'gdax',
#  'gemini',
#  'getbtc',
#  'gopax',
#  'guldentrader',
#  'heat-wallet',
#  'hitbtc',
#  'huobi',
#  'idex',
#  'independent-reserve',
#  'infinitycoin-exchange',
#  'iquant',
#  'isx',
#  'itbit',
#  'koineks',
#  'koinex',
#  'koinim',
#  'korbit',
#  'kraken',
#  'kucoin',
#  'kuna',
#  'lakebtc',
#  'lbank',
#  'leoxchange',
#  'liqui',
#  'litebit',
#  'livecoin',
#  'localtrade',
#  'luno',
#  'lykke-exchange',
#  'mercado-bitcoin',
#  'mercatox',
#  'mr-exchange',
#  'negocie-coins',
#  'neraexpro',
#  'nix-e',
#  'nocks',
#  'oasisdex',
#  'oex',
#  'okcoin-cn',
#  'okcoin-intl',
#  'okex',
#  'omni-dex',
#  'openledger',
#  'ore-bz',
#  'paribu',
#  'paymium',
#  'poloniex',
#  'qbtc',
#  'qryptos',
#  'quadrigacx',
#  'quoine',
#  'radar-relay',
#  'rfinex',
#  'rightbtc',
#  'rippex',
#  'ripple-china',
#  'ripplefox',
#  'simex',
#  'southxchange',
#  'stellar-decentralized-exchange',
#  'stocks-exchange',
#  'stronghold',
#  'surbtc',
#  'tcc-exchange',
#  'tdax',
#  'therocktrading',
#  'tidebit',
#  'tidex',
#  'token-store',
#  'topbtc',
#  'trade-by-trade',
#  'trade-satoshi',
#  'tradeogre',
#  'triple-dice-exchange',
#  'tux-exchange',
#  'upbit',
#  'vebitcoin',
#  'virtacoinworld',
#  'waves-dex',
#  'wex',
#  'xbtce',
#  'yobit',
#  'zaif',
#  'zb-com']

# %% [markdown]
# If you want to get all formatted exchange names:

# %%
cmc.exchange_names
# Out:
# ['ACX',
#  'AEX',
#  'Abucoins',
#  'AidosMarket',
#  'Allcoin',
#  'Altcoin Trader',
#  'BCEX',
#  'BITHOLIC',
#  'BL3P',
#  'BTC Markets',
#  'BTC Trade UA',
#  'BTC-Alpha',
#  'BTCBOX',
#  'BTCC',
#  'BTCTurk',
#  'BX Thailand',
#  'Bancor Network',
#  'BarterDEX',
#  'Bibox',
#  'BigONE',
#  'Binance',
#  'Bisq',
#  'Bit-Z',
#  'Bit2C',
#  'BitBay',
#  'BitFlip',
#  'BitKonan',
#  'BitMEX',
#  'BitMarket',
#  'BitShares Asset Exchange',
#  'Bitbank',
#  'Bitcoin Indonesia',
#  'BitcoinToYou',
#  'BitcoinTrade',
#  'Bitex.la',
#  'Bitfinex',
#  'Bithumb',
#  'Bitinka',
#  'Bitlish',
#  'Bitmaszyna',
#  'Bitonic',
#  'Bits Blockchain',
#  'Bitsane',
#  'Bitso',
#  'Bitstamp',
#  'Bitstamp (Ripple Gateway)',
#  'Bittrex',
#  'Bittylicious',
#  'Bleutrade',
#  'Braziliex',
#  'BtcTrade.im',
#  'Burst Asset Exchange',
#  'C-CEX',
#  'C2CX',
#  'CEX.IO',
#  'COSS',
#  'ChaoEX',
#  'Cobinhood',
#  'CoinCorner',
#  'CoinEgg',
#  'CoinEx',
#  'CoinExchange',
#  'CoinFalcon',
#  'CoinMate',
#  'Coinbene',
#  'Coinfloor',
#  'Coingi',
#  'Coinhouse',
#  'Coinlink',
#  'Coinnest',
#  'Coinone',
#  'Coinrail',
#  'Coinrate',
#  'Coinroom',
#  'CoinsBank',
#  'Coinsecure',
#  'Coinsquare',
#  'Coinut',
#  'CoolCoin',
#  'Counterparty DEX',
#  'CryptoBridge',
#  'CryptoDerivatives',
#  'CryptoMarket',
#  'Cryptomate',
#  'Cryptopia',
#  'Cryptox',
#  'DSX',
#  'Dgtmarket',
#  'ETHEXIndia',
#  'EXX',
#  'ExcambrioRex',
#  'Exmo',
#  'Exrates',
#  'Fargobase',
#  'Fatbtc',
#  'Fisco',
#  'Foxbit',
#  'FreiExchange',
#  'GDAX',
#  'GOPAX',
#  'Gate.io',
#  'Gatecoin',
#  'Gatehub',
#  'Gemini',
#  'GetBTC',
#  'GuldenTrader',
#  'Heat Wallet',
#  'HitBTC',
#  'Huobi',
#  'IDEX',
#  'ISX',
#  'Independent Reserve',
#  'InfinityCoin Exchange',
#  'Iquant',
#  'Koineks',
#  'Koinex',
#  'Koinim',
#  'Korbit',
#  'Kraken',
#  'Kucoin',
#  'Kuna',
#  'LEOxChange',
#  'LakeBTC',
#  'Lbank',
#  'Liqui',
#  'LiteBit.eu',
#  'Livecoin',
#  'LocalTrade',
#  'Luno',
#  'Lykke Exchange',
#  'Mercado Bitcoin',
#  'Mercatox',
#  'Mr. Exchange',
#  'NIX-E',
#  'Negocie Coins',
#  'Neraex',
#  'Nocks',
#  'OEX',
#  'OKCoin.cn',
#  'OKEx',
#  'OasisDEX',
#  'OkCoin Intl.',
#  'Omni DEX',
#  'OpenLedger DEX',
#  'Ore.Bz',
#  'Paribu',
#  'Paymium',
#  'Poloniex',
#  'QBTC',
#  'Qryptos',
#  'QuadrigaCX',
#  'Quoine',
#  'Radar Relay',
#  'Rfinex',
#  'RightBTC',
#  'Rippex',
#  'Ripple China',
#  'RippleFox',
#  'Simex',
#  'SouthXchange',
#  'Stellar Decentralized Exchange',
#  'Stocks.Exchange',
#  'Stronghold',
#  'SurBTC',
#  'TCC Exchange',
#  'TDAX',
#  'TOPBTC',
#  'The Rock Trading',
#  'Tidebit',
#  'Tidex',
#  'Token Store',
#  'Trade By Trade',
#  'Trade Satoshi',
#  'TradeOgre',
#  'Tripe Dice Exchange',
#  'Tux Exchange',
#  'Upbit',
#  'Vebitcoin',
#  'VirtacoinWorld',
#  'WEX',
#  'Waves Decentralized Exchange',
#  'YoBit',
#  'ZB.COM',
#  'Zaif',
#  'alcurEX',
#  'bitFlyer',
#  'ezBtc',
#  'itBit',
#  'xBTCe']

# %% [markdown]
# #### `exchanges([convert="USD"])`
# Get all available exchanges in coinmarketcap ranked by volumes with some metadata:

# %%
cmc.exchanges()
# Out:
# [{'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BitMEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Gifto',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'TRON',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'NEO',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'ICON',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'NEO',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Binance Coin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Binance'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'EOS',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'OKEx'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Cardano',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'NEO',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Status',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Qtum',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Stellar',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Upbit'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Qtum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Zcash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bithumb'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Tether',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'EOS',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bitfinex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Huobi Token',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'TRON',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Huobi Token',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Elastos',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'EOS',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Huobi Token',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'IOStoken',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Elastos',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Huobi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Ripple',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ripple',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Kraken'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'GDAX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'NuBits',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ripple',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'NEO',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Cardano',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bittrex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Monero',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Dash',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Zcash',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bytecoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'HitBTC'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Qtum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'IOTA',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'}],
#   'name': 'Coinone'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ripple',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bitstamp'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'TRON',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'EDUCare',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Ink',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ink',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Lisk',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Hshare',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bit-Z'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'}],
#   'name': 'bitFlyer'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEM',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Counterparty',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'COMSA [ETH]',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'NEM',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'COMSA [XEM]',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Pepe Cash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Zaif'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ripple',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Stellar',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Monero',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Poloniex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'MonaCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'}],
#   'name': 'Fisco'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BTCBOX'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEO',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'TRON',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Lisk',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ruff',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Qtum',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Qbao',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ripple',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Achain',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Lightning Bitcoin [Futures]',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'CoinEgg'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'QASH',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Quoine'},
#  {'markets': [{'name': 'Stellar',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Status',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Qtum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'EOS',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Cindicator',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Civic',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'GOPAX'},
#  {'markets': [{'name': 'Ink',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'BitShares',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Hshare',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'EOS',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'ZB.COM'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ink',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ink',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Hyper Pay',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Lightning Bitcoin [Futures]',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'EXX'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'}],
#   'name': 'Korbit'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'}],
#   'name': 'Bitbank'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Zcash',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Dash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Zcash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'WEX'},
#  {'markets': [{'name': 'ATMCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'ATMCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'ATMCoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Dogecoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'ATMCoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bits Blockchain'},
#  {'markets': [{'name': 'TRON',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Hshare',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Storm',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Qtum',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Profile Utility Token',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Energo',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Walton',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Kyber Network',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Coinnest'},
#  {'markets': [{'name': 'Qtum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'VeChain',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ink',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Zcash',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
# ...
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'BCEX'},
#  {'markets': [{'name': 'NVO',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcrystals',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Rustbits',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Pepe Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Counterparty',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Storjcoin X',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Storjcoin X',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'FoldingCoin',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'}],
#   'name': 'Counterparty DEX'},
#  {'markets': [{'name': 'Counterparty',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Pepe Cash',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Monero',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Zcash',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Dash',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'PotCoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Namecoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Tux Exchange'},
#  {'markets': [{'name': 'Litecoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Electroneum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'BitCoal',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Monero',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Aeon',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Verge',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Sumokoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'}],
#   'name': 'TradeOgre'},
#  {'markets': [{'name': 'E-Dinar Coin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'}],
#   'name': 'LocalTrade'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Rippex'},
#  {'markets': [{'name': 'BriaCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'}],
#   'name': 'Ore.Bz'},
#  {'markets': [{'name': 'Gulden',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'GuldenTrader'},
#  {'markets': [{'name': 'GBCGoldCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'CRTCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'}],
#   'name': 'NIX-E'},
#  {'markets': [{'name': 'Centurion',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ExcambrioRex'},
#  {'markets': [{'name': 'Auroracoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ISX'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'TCC Exchange'},
#  {'markets': [{'name': 'SnakeEyes',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Burst Asset Exchange'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'CoinCorner'},
#  {'markets': [{'name': 'Golem',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Lunyr',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'SingularDTV',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'TokenCard',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Swarm City',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Etheroll',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Melon',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Numeraire',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Edgeless',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum Movie Venture',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'CryptoDerivatives'},
#  {'markets': [{'name': 'MaidSafeCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Omni DEX'},
#  {'markets': [{'name': 'LEOcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'LEOcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'LEOcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'LEOcoin',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'}],
#   'name': 'LEOxChange'},
#  {'markets': [{'name': 'Virtacoinplus',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Virtacoinplus',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'VirtacoinWorld'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Siacoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'}],
#   'name': 'BITHOLIC'},
#  {'markets': [{'name': 'Raiden Network Token',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8517.5,
#     'volume': 1748230000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'RChain',
#     'pair': 'BTC/USDT',
#     'perc_volume': 21.53,
#     'price': 8511.14,
#     'volume': 354741000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'TRON',
#     'pair': 'ETH/USDT',
#     'perc_volume': 8.79,
#     'price': 848.143,
#     'volume': 144911000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'ChainLink',
#     'pair': 'ETH/BTC',
#     'perc_volume': 6.65,
#     'price': 847.888,
#     'volume': 109512000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Aion',
#     'pair': 'GTO/BTC',
#     'perc_volume': 5.14,
#     'price': 0.369205,
#     'volume': 84770900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=GTO_BTC'},
#    {'name': 'SALT',
#     'pair': 'TRX/BTC',
#     'perc_volume': 4.16,
#     'price': 0.0451515,
#     'volume': 68595200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Dragonchain',
#     'pair': 'NEO/USDT',
#     'perc_volume': 4.02,
#     'price': 111.537,
#     'volume': 66188600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Populous',
#     'pair': 'XRP/BTC',
#     'perc_volume': 3.65,
#     'price': 1.02488,
#     'volume': 60161500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XRP_BTC'},
#    {'name': 'Global Jobcoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 2.96,
#     'price': 4.22435,
#     'volume': 48850300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bounty0x',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.01,
#     'price': 111.34,
#     'volume': 33084600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Token Store'}]

# %% [markdown]
# #### `tokens([convert="USD"])`
# Get platforms tokens data:

# %%
cmc.tokens()
# Out:
# [{'circulating_supply': 664042138.381,
#   'market_cap': 5902683848.91,
#   'name': 'EOS',
#   'platform': 'Ethereum',
#   'price': 8.88902,
#   'symbol': 'EOS',
#   'volume_24h': 363551000.0},
#  {'circulating_supply': 65748192475.5,
#   'market_cap': 2989267870.18,
#   'name': 'TRON',
#   'platform': 'Ethereum',
#   'price': 0.0454654,
#   'symbol': 'TRX',
#   'volume_24h': 264124000.0},
#  {'circulating_supply': 2217140813.52,
#   'market_cap': 2219180583.07,
#   'name': 'Tether',
#   'platform': 'Omni',
#   'price': 1.00092,
#   'symbol': 'USDT',
#   'volume_24h': 2200200000.0},
#  {'circulating_supply': 471002548.662,
#   'market_cap': 2028612687.11,
#   'name': 'VeChain',
#   'platform': 'Ethereum',
#   'price': 4.30701,
#   'symbol': 'VEN',
#   'volume_24h': 56358300.0},
#  {'circulating_supply': 381495014.0,
#   'market_cap': 1610931365.72,
#   'name': 'ICON',
#   'platform': 'Ethereum',
#   'price': 4.22268,
#   'symbol': 'ICX',
#   'volume_24h': 69269900.0},
#  {'circulating_supply': 102042551.763,
#   'market_cap': 1267195020.56,
#   'name': 'OmiseGO',
#   'platform': 'Ethereum',
#   'price': 12.4183,
#   'symbol': 'OMG',
#   'volume_24h': 27585900.0},
#  {'circulating_supply': 37004026.8944,
#   'market_cap': 1147313554.26,
#   'name': 'Populous',
#   'platform': 'Ethereum',
#   'price': 31.0051,
#   'symbol': 'PPT',
#   'volume_24h': 14630400.0},
#  {'circulating_supply': 8628818329.63,
#   'market_cap': 1046106161.37,
#   'name': 'U.CASH',
#   'platform': 'Ethereum',
#   'price': 0.121234,
#   'symbol': 'UCASH',
#   'volume_24h': 2072620.0},
#  {'circulating_supply': 99014000.0,
#   'market_cap': 905360252.64,
#   'name': 'Binance Coin',
#   'platform': 'Ethereum',
#   'price': 9.14376,
#   'symbol': 'BNB',
#   'volume_24h': 73294000.0},
#  {'circulating_supply': 3470483788.0,
#   'market_cap': 768441461.307,
#   'name': 'Status',
#   'platform': 'Ethereum',
#   'price': 0.221422,
#   'symbol': 'SNT',
#   'volume_24h': 99892900.0},
#  {'circulating_supply': 618227.770106,
#   'market_cap': 645639989.432,
#   'name': 'Maker',
#   'platform': 'Ethereum',
#   'price': 1044.34,
#   'symbol': 'MKR',
#   'volume_24h': 574282.0},
#  {'circulating_supply': 233020472.114,
#   'market_cap': 620843434.467,
#   'name': 'Aeternity',
#   'platform': 'Ethereum',
#   'price': 2.66433,
#   'symbol': 'AE',
#   'volume_24h': 4752930.0},
#  {'circulating_supply': 11000000.0,
#   'market_cap': 594151800.0,
#   'name': 'Augur',
#   'platform': 'Ethereum',
#   'price': 54.0138,
#   'symbol': 'REP',
#   'volume_24h': 8831640.0},
#  {'circulating_supply': 344166288.9,
#   'market_cap': 557026255.259,
#   'name': 'RChain',
#   'platform': 'Ethereum',
#   'price': 1.61848,
#   'symbol': 'RHOC',
#   'volume_24h': 624989.0},
#  {'circulating_supply': 2036645.44,
#   'market_cap': 555729257.986,
#   'name': 'Veritaseum',
#   'platform': 'Ethereum',
#   'price': 272.865,
#   'symbol': 'VERI',
#   'volume_24h': 119451.0},
#  {'circulating_supply': 24898178.0,
#   'market_cap': 540088787.358,
#   'name': 'Walton',
#   'platform': 'Ethereum',
#   'price': 21.6919,
#   'symbol': 'WTC',
#   'volume_24h': 6232340.0},
#  {'circulating_supply': 507436130.341,
#   'market_cap': 535877925.446,
#   'name': '0x',
#   'platform': 'Ethereum',
#   'price': 1.05605,
#   'symbol': 'ZRX',
#   'volume_24h': 4770730.0},
#  {'circulating_supply': 91043076.0001,
#   'market_cap': 489038793.165,
#   'name': 'KuCoin Shares',
#   'platform': 'Ethereum',
#   'price': 5.37151,
#   'symbol': 'KCS',
#   'volume_24h': 1653550.0},
#  {'circulating_supply': 184450000.0,
#   'market_cap': 481949405.0,
#   'name': 'Revain',
#   'platform': 'Ethereum',
#   'price': 2.6129,
#   'symbol': 'R',
#   'volume_24h': 18322300.0},
#  {'circulating_supply': 2000000.0,
#   'market_cap': 474322000.0,
#   'name': 'DigixDAO',
#   'platform': 'Ethereum',
#   'price': 237.161,
#   'symbol': 'DGD',
#   'volume_24h': 7241820.0},
#  {'circulating_supply': 9690945.59306,
#   'market_cap': 393158755.427,
#   'name': 'Gas',
#   'platform': 'NEO',
#   'price': 40.5697,
#   'symbol': 'GAS',
#   'volume_24h': 4319210.0},
#  {'circulating_supply': 134132696.93,
#   'market_cap': 390238961.813,
#   'name': 'Kyber Network',
#   'platform': 'Ethereum',
#   'price': 2.90935,
#   'symbol': 'KNC',
#   'volume_24h': 10475600.0},
#  {'circulating_supply': 1000000000.0,
#   'market_cap': 365587000.0,
#   'name': 'Basic Attenti...',
#   'platform': 'Ethereum',
#   'price': 0.365587,
#   'symbol': 'BAT',
#   'volume_24h': 3402440.0},
#  {'circulating_supply': 987000000.0,
#   'market_cap': 362203338.0,
#   'name': 'Bytom',
#   'platform': 'Ethereum',
#   'price': 0.366974,
#   'symbol': 'BTM',
#   'volume_24h': 10967700.0},
#  {'circulating_supply': 325226613094.0,
#   'market_cap': 359294100.816,
#   'name': 'Dentacoin',
#   'platform': 'Ethereum',
#   'price': 0.00110475,
#   'symbol': 'DCN',
#   'volume_24h': 494929.0},
#  {'circulating_supply': 561202251.418,
#   'market_cap': 356017167.861,
#   'name': 'Loopring',
#   'platform': 'Ethereum',
#   'price': 0.634383,
#   'symbol': 'LRC',
#   'volume_24h': 2030600.0},
#  {'circulating_supply': 238421940.0,
#   'market_cap': 352697575.842,
#   'name': 'Dragonchain',
#   'platform': 'Ethereum',
#   'price': 1.4793,
#   'symbol': 'DRGN',
#   'volume_24h': 2390890.0},
#  {'circulating_supply': 6508988220.4,
#   'market_cap': 331048442.687,
#   'name': 'Zilliqa',
#   'platform': 'Ethereum',
#   'price': 0.0508602,
#   'symbol': 'ZIL',
#   'volume_24h': 11033900.0},
#  {'circulating_supply': 75633251.7085,
#   'market_cap': 305166556.658,
#   'name': 'Ethos',
#   'platform': 'Ethereum',
#   'price': 4.03482,
#   'symbol': 'ETHOS',
#   'volume_24h': 1895430.0},
#  {'circulating_supply': 350000000.0,
#   'market_cap': 303719850.0,
#   'name': 'QASH',
#   'platform': 'Ethereum',
#   'price': 0.867771,
#   'symbol': 'QASH',
#   'volume_24h': 3651950.0},
#  {'circulating_supply': 35500000.0,
#   'market_cap': 297436040.0,
#   'name': 'Nebulas',
#   'platform': 'Ethereum',
#   'price': 8.37848,
#   'symbol': 'NAS',
#   'volume_24h': 8597680.0},
#  {'circulating_supply': 250000000.0,
#   'market_cap': 296292500.0,
#   'name': 'aelf',
#   'platform': 'Ethereum',
#   'price': 1.18517,
#   'symbol': 'ELF',
#   'volume_24h': 38089700.0},
#  {'circulating_supply': 834262000.0,
#   'market_cap': 289463886.14,
#   'name': 'Golem',
#   'platform': 'Ethereum',
#   'price': 0.34697,
#   'symbol': 'GNT',
#   'volume_24h': 4274690.0},
#  {'circulating_supply': 363837588.92,
#   'market_cap': 270793038.468,
#   'name': 'Power Ledger',
#   'platform': 'Ethereum',
#   'price': 0.744269,
#   'symbol': 'POWR',
#   'volume_24h': 9385380.0},
#  {'circulating_supply': 227384800.0,
#   'market_cap': 268539174.952,
#   'name': 'Pillar',
#   'platform': 'Ethereum',
#   'price': 1.18099,
#   'symbol': 'PLR',
#   'volume_24h': 420200.0},
#  {'circulating_supply': 1445976590.33,
#   'market_cap': 258416260.364,
#   'name': 'Cindicator',
#   'platform': 'Ethereum',
#   'price': 0.178714,
#   'symbol': 'CND',
#   'volume_24h': 5867840.0},
#  {'circulating_supply': 6794109921.69,
#   'market_cap': 257343219.148,
#   'name': 'IOStoken',
#   'platform': 'Ethereum',
#   'price': 0.0378774,
#   'symbol': 'IOST',
#   'volume_24h': 54730200.0},
#  {'circulating_supply': 10614760961.2,
#   'market_cap': 256803973.41,
#   'name': 'Dent',
#   'platform': 'Ethereum',
#   'price': 0.0241931,
#   'symbol': 'DENT',
#   'volume_24h': 2350790.0},
#  {'circulating_supply': 4503688788.66,
#   'market_cap': 242547510.82,
#   'name': 'FunFair',
#   'platform': 'Ethereum',
#   'price': 0.0538553,
#   'symbol': 'FUN',
#   'volume_24h': 4751520.0},
#  {'circulating_supply': 79265734.9086,
#   'market_cap': 227135963.381,
#   'name': 'Aion',
#   'platform': 'Ethereum',
#   'price': 2.8655,
#   'symbol': 'AION',
#   'volume_24h': 3702950.0},
#  {'circulating_supply': 74836171.09,
#   'market_cap': 220784665.397,
#   'name': 'Enigma',
#   'platform': 'Ethereum',
#   'price': 2.95024,
#   'symbol': 'ENG',
#   'volume_24h': 11184000.0},
#  {'circulating_supply': 53005985.1339,
#   'market_cap': 220605609.529,
#   'name': 'SALT',
#   'platform': 'Ethereum',
#   'price': 4.1619,
#   'symbol': 'SALT',
#   'volume_24h': 3320910.0},
#  {'circulating_supply': 756097560976.0,
#   'market_cap': 204877487.805,
#   'name': 'Kin',
#   'platform': 'Ethereum',
#   'price': 0.000270967,
#   'symbol': 'KIN',
#   'volume_24h': 455911.0},
#  {'circulating_supply': 452552412.0,
#   'market_cap': 197454500.537,
#   'name': 'MaidSafeCoin',
#   'platform': 'Omni',
#   'price': 0.436313,
#   'symbol': 'MAID',
#   'volume_24h': 2812040.0},
#  {'circulating_supply': 38750987.2901,
#   'market_cap': 196416354.258,
#   'name': 'Bancor',
#   'platform': 'Ethereum',
#   'price': 5.06868,
#   'symbol': 'BNT',
#   'volume_24h': 3726570.0},
#  {'circulating_supply': 104661310.0,
#   'market_cap': 191299942.418,
#   'name': 'TenX',
#   'platform': 'Ethereum',
#   'price': 1.8278,
#   'symbol': 'PAY',
#   'volume_24h': 3800540.0},
#  {'circulating_supply': 239570250.0,
#   'market_cap': 184585763.212,
#   'name': 'Polymath',
#   'platform': 'Ethereum',
#   'price': 0.770487,
#   'symbol': 'POLY',
#   'volume_24h': 159901.0},
#  {'circulating_supply': 617314170.819,
#   'market_cap': 181348383.961,
#   'name': 'Quantstamp',
#   'platform': 'Ethereum',
#   'price': 0.29377,
#   'symbol': 'QSP',
#   'volume_24h': 4790000.0},
#  {'circulating_supply': 761143950.0,
#   'market_cap': 177636536.195,
#   'name': 'Ignis',
#   'platform': 'Ardor',
#   'price': 0.233381,
#   'symbol': 'IGNIS',
#   'volume_24h': 5485230.0},
#  {'circulating_supply': 641462768.585,
#   'market_cap': 172511789.669,
#   'name': 'Request Network',
#   'platform': 'Ethereum',
#   'price': 0.268935,
#   'symbol': 'REQ',
#   'volume_24h': 2486660.0},
#  {'circulating_supply': 455552782.0,
#   'market_cap': 168064354.547,
#   'name': 'SingularityNET',
#   'platform': 'Ethereum',
#   'price': 0.368924,
#   'symbol': 'AGI',
#   'volume_24h': 843090.0},
#  {'circulating_supply': 1000000000.0,
#   'market_cap': 159691000.0,
#   'name': 'XPlay',
#   'platform': 'Ethereum',
#   'price': 0.159691,
#   'symbol': 'XPA',
#   'volume_24h': 182663.0},
#  {'circulating_supply': 492954537.351,
#   'market_cap': 159316498.063,
#   'name': 'WAX',
#   'platform': 'Ethereum',
#   'price': 0.323187,
#   'symbol': 'WAX',
#   'volume_24h': 3810710.0},
#  {'circulating_supply': 99735686.8829,
#   'market_cap': 159206082.257,
#   'name': 'Iconomi',
#   'platform': 'Ethereum',
#   'price': 1.59628,
#   'symbol': 'ICN',
#   'volume_24h': 508301.0},
#  {'circulating_supply': 226091448.88,
#   'market_cap': 157661480.505,
#   'name': 'Substratum',
#   'platform': 'Ethereum',
#   'price': 0.697335,
#   'symbol': 'SUB',
#   'volume_24h': 3023820.0},
#  {'circulating_supply': 350000000.0,
#   'market_cap': 156473100.0,
#   'name': 'ChainLink',
#   'platform': 'Ethereum',
#   'price': 0.447066,
#   'symbol': 'LINK',
#   'volume_24h': 3644600.0},
#  {'circulating_supply': 1104590.0,
#   'market_cap': 155775909.34,
#   'name': 'Gnosis',
#   'platform': 'Ethereum',
#   'price': 141.026,
#   'symbol': 'GNO',
#   'volume_24h': 255374.0},
#  {'circulating_supply': 342699966.0,
#   'market_cap': 145097794.805,
#   'name': 'Civic',
#   'platform': 'Ethereum',
#   'price': 0.423396,
#   'symbol': 'CVC',
#   'volume_24h': 4243040.0},
#  {'circulating_supply': 2216707776.0,
#   'market_cap': 143429859.938,
#   'name': 'Po.et',
#   'platform': 'Ethereum',
#   'price': 0.064704,
#   'symbol': 'POE',
#   'volume_24h': 23617600.0},
#  {'circulating_supply': 543348500.0,
#   'market_cap': 133996803.631,
#   'name': 'Red Pulse',
#   'platform': 'NEO',
#   'price': 0.246613,
#   'symbol': 'RPX',
#   'volume_24h': 9037020.0},
#  {'circulating_supply': 50148936.0,
#   'market_cap': 133356050.611,
#   'name': 'Raiden Networ...',
#   'platform': 'Ethereum',
#   'price': 2.6592,
#   'symbol': 'RDN',
#   'volume_24h': 2558470.0},
#  {'circulating_supply': 133425492.59,
#   'market_cap': 131065195.626,
#   'name': 'Storj',
#   'platform': 'Ethereum',
#   'price': 0.98231,
#   'symbol': 'STORJ',
#   'volume_24h': 3561750.0},
#  {'circulating_supply': 1051043445.16,
#   'market_cap': 126126264.462,
#   'name': 'Decentraland',
#   'platform': 'Ethereum',
#   'price': 0.120001,
#   'symbol': 'MANA',
#   'volume_24h': 15992400.0},
#  {'circulating_supply': 1631622325.37,
#   'market_cap': 123482646.044,
#   'name': 'Time New Bank',
#   'platform': 'Ethereum',
#   'price': 0.0756809,
#   'symbol': 'TNB',
#   'volume_24h': 22768800.0},
#  {'circulating_supply': 816060.7785,
#   'market_cap': 122831020.197,
#   'name': 'SuperNET',
#   'platform': 'Nxt',
#   'price': 150.517,
#   'symbol': 'UNITY',
#   'volume_24h': 7979.78},
#  {'circulating_supply': 103244552.962,
#   'market_cap': 120426511.466,
#   'name': 'DEW',
#   'platform': 'Ethereum',
#   'price': 1.16642,
#   'symbol': 'DEW',
#   'volume_24h': 251696.0},
#  {'circulating_supply': 26680106.3681,
#   'market_cap': 117029618.573,
#   'name': 'Aragon',
#   'platform': 'Ethereum',
#   'price': 4.3864,
#   'symbol': 'ANT',
#   'volume_24h': 290210.0},
#  {'circulating_supply': 165000000.0,
#   'market_cap': 110752125.0,
#   'name': 'Bluzelle',
#   'platform': 'Ethereum',
#   'price': 0.671225,
#   'symbol': 'BLZ',
#   'volume_24h': 21631800.0},
#  {'circulating_supply': 756192535.064,
#   'market_cap': 110351176.642,
#   'name': 'Enjin Coin',
#   'platform': 'Ethereum',
#   'price': 0.14593,
#   'symbol': 'ENJ',
#   'volume_24h': 1326370.0},
#  {'circulating_supply': 82500000.0,
#   'market_cap': 109435425.0,
#   'name': 'PayPie',
#   'platform': 'Ethereum',
#   'price': 1.32649,
#   'symbol': 'PPP',
#   'volume_24h': 287024.0},
#  {'circulating_supply': 2734798357.25,
#   'market_cap': 108037115.184,
#   'name': 'Storm',
#   'platform': 'Ethereum',
#   'price': 0.0395046,
#   'symbol': 'STORM',
#   'volume_24h': 2057260.0},
#  {'circulating_supply': 79070793.2388,
#   'market_cap': 107197855.81,
#   'name': 'iExec RLC',
#   'platform': 'Ethereum',
#   'price': 1.35572,
#   'symbol': 'RLC',
#   'volume_24h': 747061.0},
#  {'circulating_supply': 62660370.957,
#   'market_cap': 105959940.496,
#   'name': 'Santiment Net...',
#   'platform': 'Ethereum',
#   'price': 1.69102,
#   'symbol': 'SAN',
#   'volume_24h': 1987380.0},
#  {'circulating_supply': 98939459.119,
#   'market_cap': 105279499.659,
#   'name': 'SIRIN LABS Token',
#   'platform': 'Ethereum',
#   'price': 1.06408,
#   'symbol': 'SRN',
#   'volume_24h': 15170900.0},
#  {'circulating_supply': 997237841.0,
#   'market_cap': 102959820.894,
#   'name': 'Dynamic Tradi...',
#   'platform': 'Ethereum',
#   'price': 0.103245,
#   'symbol': 'DTR',
#   'volume_24h': 70081.9},
#  {'circulating_supply': 13195542.215,
#   'market_cap': 101720080.406,
#   'name': 'Monaco',
#   'platform': 'Ethereum',
#   'price': 7.70867,
#   'symbol': 'MCO',
#   'volume_24h': 4223570.0},
#  {'circulating_supply': 1494971208.89,
#   'market_cap': 101392983.809,
#   'name': 'BLOCKv',
#   'platform': 'Ethereum',
#   'price': 0.0678227,
#   'symbol': 'VEE',
#   'volume_24h': 573610.0},
#  {'circulating_supply': 42000000.0,
#   'market_cap': 100539600.0,
#   'name': 'Agoras Tokens',
#   'platform': 'Omni',
#   'price': 2.3938,
#   'symbol': 'AGRS',
#   'volume_24h': 154502.0},
#  {'circulating_supply': 39335007.2487,
#   'market_cap': 93980379.3688,
#   'name': 'CRYPTO20',
#   'platform': 'Ethereum',
#   'price': 2.38923,
#   'symbol': 'C20',
#   'volume_24h': 2459020.0},
#  {'circulating_supply': 38327424.5,
#   'market_cap': 92497489.9171,
#   'name': 'IoT Chain',
#   'platform': 'Ethereum',
#   'price': 2.41335,
#   'symbol': 'ITC',
#   'volume_24h': 12766500.0},
#  {'circulating_supply': 490533008.753,
#   'market_cap': 91645791.4923,
#   'name': 'Ripio Credit ...',
#   'platform': 'Ethereum',
#   'price': 0.186829,
#   'symbol': 'RCN',
#   'volume_24h': 6550210.0},
#  {'circulating_supply': 105253066.049,
#   'market_cap': 90092414.415,
#   'name': 'Bibox Token',
#   'platform': 'Ethereum',
#   'price': 0.85596,
#   'symbol': 'BIX',
#   'volume_24h': 14977600.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 89733900.0,
#   'name': 'Jibrel Network',
#   'platform': 'Ethereum',
#   'price': 0.598226,
#   'symbol': 'JNT',
#   'volume_24h': 7448820.0},
#  {'circulating_supply': 900000000.0,
#   'market_cap': 89503290.0,
#   'name': 'DeepBrain Chain',
#   'platform': 'NEO',
#   'price': 0.0994481,
#   'symbol': 'DBC',
#   'volume_24h': 2542630.0},
#  {'circulating_supply': 199902472.36,
#   'market_cap': 87560281.4307,
#   'name': 'VIBE',
#   'platform': 'Ethereum',
#   'price': 0.438015,
#   'symbol': 'VIBE',
#   'volume_24h': 2632270.0},
#  {'circulating_supply': 189600317.903,
#   'market_cap': 87433617.8,
#   'name': 'SophiaTX',
#   'platform': 'Ethereum',
#   'price': 0.461147,
#   'symbol': 'SPHTX',
#   'volume_24h': 233990.0},
#  {'circulating_supply': 1042852948.02,
#   'market_cap': 86509032.0209,
#   'name': 'ETHLend',
#   'platform': 'Ethereum',
#   'price': 0.0829542,
#   'symbol': 'LEND',
#   'volume_24h': 3781720.0},
#  {'circulating_supply': 482511957.017,
#   'market_cap': 86138999.5907,
#   'name': 'MediShares',
#   'platform': 'Ethereum',
#   'price': 0.178522,
#   'symbol': 'MDS',
#   'volume_24h': 5507240.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 85672200.0,
#   'name': 'SingularDTV',
#   'platform': 'Ethereum',
#   'price': 0.142787,
#   'symbol': 'SNGLS',
#   'volume_24h': 1483480.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 83781600.0,
#   'name': 'AirSwap',
#   'platform': 'Ethereum',
#   'price': 0.558544,
#   'symbol': 'AST',
#   'volume_24h': 2955180.0},
#  {'circulating_supply': 443411828.912,
#   'market_cap': 82861255.2925,
#   'name': 'CyberMiles',
#   'platform': 'Ethereum',
#   'price': 0.186872,
#   'symbol': 'CMT',
#   'volume_24h': 5413510.0},
#  {'circulating_supply': 359600000.0,
#   'market_cap': 82243756.4,
#   'name': 'SONM',
#   'platform': 'Ethereum',
#   'price': 0.228709,
#   'symbol': 'SNM',
#   'volume_24h': 1144160.0},
#  {'circulating_supply': 300043386.0,
#   'market_cap': 81385868.3223,
#   'name': 'SpankChain',
#   'platform': 'Ethereum',
#   'price': 0.271247,
#   'symbol': 'SPANK',
#   'volume_24h': 408155.0},
#  {'circulating_supply': 358169121.008,
#   'market_cap': 79549719.9451,
#   'name': 'Cobinhood',
#   'platform': 'Ethereum',
#   'price': 0.222101,
#   'symbol': 'COB',
#   'volume_24h': 2949.73},
#  {'circulating_supply': 60248315.0,
#   'market_cap': 76267136.9922,
#   'name': 'AdEx',
#   'platform': 'Ethereum',
#   'price': 1.26588,
#   'symbol': 'ADX',
#   'volume_24h': 14841400.0},
#  {'circulating_supply': 144590975.0,
#   'market_cap': 75714919.4678,
#   'name': 'Ambrosus',
#   'platform': 'Ethereum',
#   'price': 0.523649,
#   'symbol': 'AMB',
#   'volume_24h': 5076830.0},
#  {'circulating_supply': 272889439.003,
#   'market_cap': 74967640.9041,
#   'name': 'Simple Token',
#   'platform': 'Ethereum',
#   'price': 0.274718,
#   'symbol': 'OST',
#   'volume_24h': 1952460.0},
#  {'circulating_supply': 52000000.0,
#   'market_cap': 74919520.0,
#   'name': 'Quantum Resis...',
#   'platform': 'Ethereum',
#   'price': 1.44076,
#   'symbol': 'QRL',
#   'volume_24h': 697428.0},
#  {'circulating_supply': 265118238.708,
#   'market_cap': 74210306.6697,
#   'name': 'UTRUST',
#   'platform': 'Ethereum',
#   'price': 0.279914,
#   'symbol': 'UTK',
#   'volume_24h': 1996970.0},
#  {'circulating_supply': 19300994.0,
#   'market_cap': 74176036.0613,
#   'name': 'Metal',
#   'platform': 'Ethereum',
#   'price': 3.84312,
#   'symbol': 'MTL',
#   'volume_24h': 9989030.0},
#  {'circulating_supply': 20970629778.4,
#   'market_cap': 71440854.1725,
#   'name': 'Telcoin',
#   'platform': 'Ethereum',
#   'price': 0.00340671,
#   'symbol': 'TEL',
#   'volume_24h': 918034.0},
#  {'circulating_supply': 45248032.811,
#   'market_cap': 69647582.024,
#   'name': 'WaBi',
#   'platform': 'Ethereum',
#   'price': 1.53924,
#   'symbol': 'WABI',
#   'volume_24h': 1243710.0},
#  {'circulating_supply': 333333333.0,
#   'market_cap': 68637999.9314,
#   'name': 'Trinity Netwo...',
#   'platform': 'NEO',
#   'price': 0.205914,
#   'symbol': 'TNC',
#   'volume_24h': 3345650.0},
#  {'circulating_supply': 82046276.0,
#   'market_cap': 68192023.8809,
#   'name': 'Edgeless',
#   'platform': 'Ethereum',
#   'price': 0.831141,
#   'symbol': 'EDG',
#   'volume_24h': 529436.0},
#  {'circulating_supply': 69966926.2205,
#   'market_cap': 67647242.7486,
#   'name': 'Oyster',
#   'platform': 'Ethereum',
#   'price': 0.966846,
#   'symbol': 'PRL',
#   'volume_24h': 2154530.0},
#  {'circulating_supply': 563264706.0,
#   'market_cap': 67395185.3376,
#   'name': 'Theta Token',
#   'platform': 'Ethereum',
#   'price': 0.119651,
#   'symbol': 'THETA',
#   'volume_24h': 7602780.0},
#  {'circulating_supply': 599400.0,
#   'market_cap': 64788546.6,
#   'name': 'Melon',
#   'platform': 'Ethereum',
#   'price': 108.089,
#   'symbol': 'MLN',
#   'volume_24h': 209591.0},
#  {'circulating_supply': 240000000.0,
#   'market_cap': 64443120.0,
#   'name': 'QLINK',
#   'platform': 'NEO',
#   'price': 0.268513,
#   'symbol': 'QLC',
#   'volume_24h': 1317100.0},
#  {'circulating_supply': 68000000.0,
#   'market_cap': 63058508.0,
#   'name': 'Centra',
#   'platform': 'Ethereum',
#   'price': 0.927331,
#   'symbol': 'CTR',
#   'volume_24h': 2308210.0},
#  {'circulating_supply': 98028877.0,
#   'market_cap': 62957771.8778,
#   'name': 'MobileGo',
#   'platform': 'Ethereum',
#   'price': 0.642237,
#   'symbol': 'MGO',
#   'volume_24h': 168681.0},
#  {'circulating_supply': 28173693.3685,
#   'market_cap': 62783103.5133,
#   'name': 'INS Ecosystem',
#   'platform': 'Ethereum',
#   'price': 2.22843,
#   'symbol': 'INS',
#   'volume_24h': 13608800.0},
#  {'circulating_supply': 677154514.0,
#   'market_cap': 62131228.9848,
#   'name': 'Streamr DATAcoin',
#   'platform': 'Ethereum',
#   'price': 0.0917534,
#   'symbol': 'DATA',
#   'volume_24h': 448616.0},
#  {'circulating_supply': 100054311.845,
#   'market_cap': 62003156.7788,
#   'name': 'AppCoins',
#   'platform': 'Ethereum',
#   'price': 0.619695,
#   'symbol': 'APPC',
#   'volume_24h': 2774130.0},
#  {'circulating_supply': 18266200.0,
#   'market_cap': 61953653.202,
#   'name': 'Modum',
#   'platform': 'Ethereum',
#   'price': 3.39171,
#   'symbol': 'MOD',
#   'volume_24h': 576614.0},
#  {'circulating_supply': 428481269.499,
#   'market_cap': 61514056.4931,
#   'name': 'Tierion',
#   'platform': 'Ethereum',
#   'price': 0.143563,
#   'symbol': 'TNT',
#   'volume_24h': 3085750.0},
#  {'circulating_supply': 183000000.0,
#   'market_cap': 60935157.0,
#   'name': 'Wagerr',
#   'platform': 'Waves',
#   'price': 0.332979,
#   'symbol': 'WGR',
#   'volume_24h': 112968.0},
#  {'circulating_supply': 140423304.35,
#   'market_cap': 60841907.1922,
#   'name': 'Unikoin Gold',
#   'platform': 'Ethereum',
#   'price': 0.433275,
#   'symbol': 'UKG',
#   'volume_24h': 1827360.0},
#  {'circulating_supply': 157861326.54,
#   'market_cap': 58288716.2116,
#   'name': 'Gifto',
#   'platform': 'Ethereum',
#   'price': 0.36924,
#   'symbol': 'GTO',
#   'volume_24h': 118041000.0},
#  {'circulating_supply': 29261461.2776,
#   'market_cap': 57894678.9816,
#   'name': 'Eidoo',
#   'platform': 'Ethereum',
#   'price': 1.97853,
#   'symbol': 'EDO',
#   'volume_24h': 1157040.0},
#  {'circulating_supply': 651246649.17,
#   'market_cap': 57594951.1593,
#   'name': 'CoinDash',
#   'platform': 'Ethereum',
#   'price': 0.088438,
#   'symbol': 'CDT',
#   'volume_24h': 5340170.0},
#  {'circulating_supply': 32105577.5103,
#   'market_cap': 56884662.2327,
#   'name': 'Triggers',
#   'platform': 'Counterparty',
#   'price': 1.7718,
#   'symbol': 'TRIG',
#   'volume_24h': 1540500.0},
#  {'circulating_supply': 89708333.0,
#   'market_cap': 56519568.9983,
#   'name': 'Wings',
#   'platform': 'Ethereum',
#   'price': 0.630037,
#   'symbol': 'WINGS',
#   'volume_24h': 1630080.0},
#  {'circulating_supply': 23564882.3,
#   'market_cap': 55900142.4944,
#   'name': 'Nuls',
#   'platform': 'Ethereum',
#   'price': 2.37218,
#   'symbol': 'NULS',
#   'volume_24h': 5612730.0},
#  {'circulating_supply': 3726780.89997,
#   'market_cap': 54358826.2069,
#   'name': 'Genesis Vision',
#   'platform': 'Ethereum',
#   'price': 14.586,
#   'symbol': 'GVT',
#   'volume_24h': 979542.0},
#  {'circulating_supply': 57672338.0,
#   'market_cap': 54175779.4917,
#   'name': 'NAGA',
#   'platform': 'Ethereum',
#   'price': 0.939372,
#   'symbol': 'NGC',
#   'volume_24h': 143698.0},
#  {'circulating_supply': 485146252.554,
#   'market_cap': 53803204.5545,
#   'name': 'Etherparty',
#   'platform': 'Ethereum',
#   'price': 0.110901,
#   'symbol': 'FUEL',
#   'volume_24h': 713856.0},
#  {'circulating_supply': 59888398.693,
#   'market_cap': 50254930.5444,
#   'name': 'Bread',
#   'platform': 'Ethereum',
#   'price': 0.839143,
#   'symbol': 'BRD',
#   'volume_24h': 5758140.0},
#  {'circulating_supply': 4660285459.8,
#   'market_cap': 49472658.3841,
#   'name': 'ATMChain',
#   'platform': 'Ethereum',
#   'price': 0.0106158,
#   'symbol': 'ATM',
#   'volume_24h': 42268.7},
#  {'circulating_supply': 375000000.0,
#   'market_cap': 48846375.0,
#   'name': 'Hive',
#   'platform': 'Ethereum',
#   'price': 0.130257,
#   'symbol': 'HVN',
#   'volume_24h': 136629.0},
#  {'circulating_supply': 100000000.0,
#   'market_cap': 48703600.0,
#   'name': 'Mercury',
#   'platform': 'Waves',
#   'price': 0.487036,
#   'symbol': 'MER',
#   'volume_24h': 7433760.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 48487260.0,
#   'name': 'district0x',
#   'platform': 'Ethereum',
#   'price': 0.0808121,
#   'symbol': 'DNT',
#   'volume_24h': 958927.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 48317550.0,
#   'name': 'Internet Node...',
#   'platform': 'Ethereum',
#   'price': 0.322117,
#   'symbol': 'INT',
#   'volume_24h': 2104730.0},
#  {'circulating_supply': 399934364.226,
#   'market_cap': 46729530.9193,
#   'name': 'indaHash',
#   'platform': 'Ethereum',
#   'price': 0.116843,
#   'symbol': 'IDH',
#   'volume_24h': 178387.0},
#  {'circulating_supply': 254507605.599,
#   'market_cap': 46180150.5283,
#   'name': 'OriginTrail',
#   'platform': 'Ethereum',
#   'price': 0.181449,
#   'symbol': 'TRAC',
#   'volume_24h': 382959.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 45425160.0,
#   'name': 'adToken',
#   'platform': 'Ethereum',
#   'price': 0.0757086,
#   'symbol': 'ADT',
#   'volume_24h': 972944.0},
#  {'circulating_supply': 582029028.5,
#   'market_cap': 44238745.9924,
#   'name': 'Energo',
#   'platform': 'Ethereum',
#   'price': 0.0760078,
#   'symbol': 'TSL',
#   'volume_24h': 2001980.0},
#  {'circulating_supply': 329118078.46,
#   'market_cap': 44188709.6864,
#   'name': 'Cappasity',
#   'platform': 'Ethereum',
#   'price': 0.134264,
#   'symbol': 'CAPP',
#   'volume_24h': 132306.0},
#  {'circulating_supply': 1543157590.0,
#   'market_cap': 44003755.9419,
#   'name': 'Safe Exchange...',
#   'platform': 'Omni',
#   'price': 0.0285154,
#   'symbol': 'SAFEX',
#   'volume_24h': 11275.6},
#  {'circulating_supply': 66000000.0,
#   'market_cap': 43860432.0,
#   'name': 'LOCIcoin',
#   'platform': 'Ethereum',
#   'price': 0.664552,
#   'symbol': 'LOCI',
#   'volume_24h': 361374.0},
#  {'circulating_supply': 31432398.8758,
#   'market_cap': 43184972.8154,
#   'name': 'Decision Token',
#   'platform': 'Ethereum',
#   'price': 1.3739,
#   'symbol': 'HST',
#   'volume_24h': 218716.0},
#  {'circulating_supply': 85558370.5,
#   'market_cap': 43052800.9189,
#   'name': 'FirstBlood',
#   'platform': 'Ethereum',
#   'price': 0.503198,
#   'symbol': '1ST',
#   'volume_24h': 2686770.0},
#  {'circulating_supply': 8146000.7794,
#   'market_cap': 42629081.0587,
#   'name': 'TaaS',
#   'platform': 'Ethereum',
#   'price': 5.23313,
#   'symbol': 'TAAS',
#   'volume_24h': 198969.0},
#  {'circulating_supply': 155000000.0,
#   'market_cap': 42491855.0,
#   'name': 'Presearch',
#   'platform': 'Ethereum',
#   'price': 0.274141,
#   'symbol': 'PRE',
#   'volume_24h': 27269.7},
#  {'circulating_supply': 806408544.994,
#   'market_cap': 42324352.484,
#   'name': 'Datum',
#   'platform': 'Ethereum',
#   'price': 0.052485,
#   'symbol': 'DAT',
#   'volume_24h': 1778420.0},
#  {'circulating_supply': 64918537.4672,
#   'market_cap': 42299620.6429,
#   'name': 'COSS',
#   'platform': 'Ethereum',
#   'price': 0.65158,
#   'symbol': 'COSS',
#   'volume_24h': 291345.0},
#  {'circulating_supply': 164966467.432,
#   'market_cap': 42053911.7435,
#   'name': 'Viberate',
#   'platform': 'Ethereum',
#   'price': 0.254924,
#   'symbol': 'VIB',
#   'volume_24h': 8112700.0},
#  {'circulating_supply': 346139198.325,
#   'market_cap': 41852382.7479,
#   'name': 'BitDegree',
#   'platform': 'Ethereum',
#   'price': 0.120912,
#   'symbol': 'BDG',
#   'volume_24h': 104680.0},
#  {'circulating_supply': 2000000000.0,
#   'market_cap': 41713200.0,
#   'name': 'Odyssey',
#   'platform': 'Ethereum',
#   'price': 0.0208566,
#   'symbol': 'OCN',
#   'volume_24h': 8660690.0},
#  {'circulating_supply': 5171589622.24,
#   'market_cap': 40387425.7231,
#   'name': 'carVertical',
#   'platform': 'Ethereum',
#   'price': 0.00780948,
#   'symbol': 'CV',
#   'volume_24h': 419838.0},
#  {'circulating_supply': 24462686.2941,
#   'market_cap': 40060828.9558,
#   'name': 'TokenCard',
#   'platform': 'Ethereum',
#   'price': 1.63763,
#   'symbol': 'TKN',
#   'volume_24h': 78572.7},
#  {'circulating_supply': 2297853.07853,
#   'market_cap': 39283866.4453,
#   'name': 'Lunyr',
#   'platform': 'Ethereum',
#   'price': 17.0959,
#   'symbol': 'LUN',
#   'volume_24h': 1766320.0},
#  {'circulating_supply': 65351403.0,
#   'market_cap': 38786907.2487,
#   'name': 'Qbao',
#   'platform': 'Qtum',
#   'price': 0.593513,
#   'symbol': 'QBT',
#   'volume_24h': 5597830.0},
#  {'circulating_supply': 178250000.0,
#   'market_cap': 38645847.75,
#   'name': 'Ink',
#   'platform': 'Qtum',
#   'price': 0.216807,
#   'symbol': 'INK',
#   'volume_24h': 89021000.0},
#  {'circulating_supply': 30333338.8577,
#   'market_cap': 38250036.9662,
#   'name': 'Delphy',
#   'platform': 'Ethereum',
#   'price': 1.26099,
#   'symbol': 'DPY',
#   'volume_24h': 1666220.0},
#  {'circulating_supply': 162862944.036,
#   'market_cap': 37921985.0669,
#   'name': 'Humaniq',
#   'platform': 'Ethereum',
#   'price': 0.232846,
#   'symbol': 'HMQ',
#   'volume_24h': 2950440.0},
#  {'circulating_supply': 231436247.173,
#   'market_cap': 35406274.2738,
#   'name': 'YOYOW',
#   'platform': 'BitShares',
#   'price': 0.152985,
#   'symbol': 'YOYOW',
#   'volume_24h': 4019470.0},
#  {'circulating_supply': 10500000.0,
#   'market_cap': 35209755.0,
#   'name': 'Nimiq',
#   'platform': 'Ethereum',
#   'price': 3.35331,
#   'symbol': 'NET',
#   'volume_24h': 210312.0},
#  {'circulating_supply': 211901000.0,
#   'market_cap': 34552788.961,
#   'name': 'bitCNY',
#   'platform': 'BitShares',
#   'price': 0.163061,
#   'symbol': 'BITCNY',
#   'volume_24h': 46386100.0},
#  {'circulating_supply': 325000000.0,
#   'market_cap': 33464275.0,
#   'name': 'Cofound.it',
#   'platform': 'Ethereum',
#   'price': 0.102967,
#   'symbol': 'CFI',
#   'volume_24h': 206996.0},
#  {'circulating_supply': 92147500.0,
#   'market_cap': 33145455.75,
#   'name': 'WeTrust',
#   'platform': 'Ethereum',
#   'price': 0.3597,
#   'symbol': 'TRST',
#   'volume_24h': 177040.0},
#  {'circulating_supply': 142215728.19,
#   'market_cap': 32996466.6075,
#   'name': 'Lamden',
#   'platform': 'Ethereum',
#   'price': 0.232017,
#   'symbol': 'TAU',
#   'volume_24h': 141244.0},
#  {'circulating_supply': 1750000000.0,
#   'market_cap': 32702600.0,
#   'name': 'SwftCoin',
#   'platform': 'Ethereum',
#   'price': 0.0186872,
#   'symbol': 'SWFTC',
#   'volume_24h': 15653300.0},
#  {'circulating_supply': 701884009.0,
#   'market_cap': 32619146.8691,
#   'name': 'Pepe Cash',
#   'platform': 'Counterparty',
#   'price': 0.0464737,
#   'symbol': 'PEPECASH',
#   'volume_24h': 101560.0},
#  {'circulating_supply': 1153170765.0,
#   'market_cap': 32584223.77,
#   'name': 'Zeusshield',
#   'platform': 'Ethereum',
#   'price': 0.0282562,
#   'symbol': 'ZSC',
#   'volume_24h': 891096.0},
#  {'circulating_supply': 39483257.6434,
#   'market_cap': 32006786.9426,
#   'name': 'Bloom',
#   'platform': 'Ethereum',
#   'price': 0.810642,
#   'symbol': 'BLT',
#   'volume_24h': 718571.0},
#  {'circulating_supply': 201000000.0,
#   'market_cap': 31996386.0,
#   'name': 'InsurePal',
#   'platform': 'Ethereum',
#   'price': 0.159186,
#   'symbol': 'IPL',
#   'volume_24h': 72054.9},
#  {'circulating_supply': 85978873.0,
#   'market_cap': 31355635.1944,
#   'name': 'Agrello',
#   'platform': 'Ethereum',
#   'price': 0.36469,
#   'symbol': 'DLT',
#   'volume_24h': 7730840.0},
#  {'circulating_supply': 216973356.3,
#   'market_cap': 31142185.8297,
#   'name': 'Monetha',
#   'platform': 'Ethereum',
#   'price': 0.14353,
#   'symbol': 'MTH',
#   'volume_24h': 705266.0},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 30694680.0,
#   'name': 'Blocktix',
#   'platform': 'Ethereum',
#   'price': 0.767367,
#   'symbol': 'TIX',
#   'volume_24h': 1746940.0},
#  {'circulating_supply': 100000000.0,
#   'market_cap': 28788400.0,
#   'name': 'Aurora DAO',
#   'platform': 'Ethereum',
#   'price': 0.287884,
#   'symbol': 'AURA',
#   'volume_24h': 128320.0},
#  {'circulating_supply': 84285535.961,
#   'market_cap': 28786966.2377,
#   'name': 'Trade Token',
#   'platform': 'Ethereum',
#   'price': 0.341541,
#   'symbol': 'TIO',
#   'volume_24h': 267022.0},
#  {'circulating_supply': 1005414013.0,
#   'market_cap': 28765799.7845,
#   'name': 'Karma',
#   'platform': 'BitShares',
#   'price': 0.0286109,
#   'symbol': 'KRM',
#   'volume_24h': 71134.1},
#  {'circulating_supply': 114378947.154,
#   'market_cap': 28689328.1779,
#   'name': 'SunContract',
#   'platform': 'Ethereum',
#   'price': 0.250827,
#   'symbol': 'SNC',
#   'volume_24h': 4433000.0},
#  {'circulating_supply': 16500000.0,
#   'market_cap': 28224405.0,
#   'name': 'Everex',
#   'platform': 'Ethereum',
#   'price': 1.71057,
#   'symbol': 'EVX',
#   'volume_24h': 3292100.0},
#  {'circulating_supply': 175109299.0,
#   'market_cap': 28024492.212,
#   'name': 'Worldcore',
#   'platform': 'Ethereum',
#   'price': 0.16004,
#   'symbol': 'WRC',
#   'volume_24h': 573285.0},
#  {'circulating_supply': 35778843.8312,
#   'market_cap': 27851647.4131,
#   'name': 'iXledger',
#   'platform': 'Ethereum',
#   'price': 0.778439,
#   'symbol': 'IXT',
#   'volume_24h': 490971.0},
#  {'circulating_supply': 82256324.0,
#   'market_cap': 27817608.163,
#   'name': 'Synereo',
#   'platform': 'Omni',
#   'price': 0.338182,
#   'symbol': 'AMP',
#   'volume_24h': 754510.0},
#  {'circulating_supply': 1877455408.41,
#   'market_cap': 27680076.0684,
#   'name': 'Selfkey',
#   'platform': 'Ethereum',
#   'price': 0.0147434,
#   'symbol': 'KEY',
#   'volume_24h': 933684.0},
#  {'circulating_supply': 17029321.0837,
#   'market_cap': 27060783.2545,
#   'name': 'Ormeus Coin',
#   'platform': 'Ethereum',
#   'price': 1.58907,
#   'symbol': 'ORME',
#   'volume_24h': 2150680.0},
#  {'circulating_supply': 501394405.74,
#   'market_cap': 26890985.3264,
#   'name': 'BitClave',
#   'platform': 'Ethereum',
#   'price': 0.0536324,
#   'symbol': 'CAT',
#   'volume_24h': 634968.0},
#  {'circulating_supply': 30150150.1476,
#   'market_cap': 26406134.6524,
#   'name': 'Maecenas',
#   'platform': 'Ethereum',
#   'price': 0.875821,
#   'symbol': 'ART',
#   'volume_24h': 7106.22},
#  {'circulating_supply': 19628888.0,
#   'market_cap': 26342556.5626,
#   'name': 'Moeda Loyalty...',
#   'platform': 'Ethereum',
#   'price': 1.34203,
#   'symbol': 'MDA',
#   'volume_24h': 657889.0},
#  {'circulating_supply': 36764950.0647,
#   'market_cap': 26092305.6506,
#   'name': 'Olympus Labs',
#   'platform': 'Ethereum',
#   'price': 0.709706,
#   'symbol': 'MOT',
#   'volume_24h': 639885.0},
#  {'circulating_supply': 263034654.051,
#   'market_cap': 25555552.6698,
#   'name': 'HelloGold',
#   'platform': 'Ethereum',
#   'price': 0.0971566,
#   'symbol': 'HGT',
#   'volume_24h': 75857.9},
#  {'circulating_supply': 15000000.0,
#   'market_cap': 25275000.0,
#   'name': 'NVO',
#   'platform': 'Counterparty',
#   'price': 1.685,
#   'symbol': 'NVST',
#   'volume_24h': 4981.59},
#  {'circulating_supply': 77839404.0,
#   'market_cap': 25155515.8695,
#   'name': 'LAToken',
#   'platform': 'Ethereum',
#   'price': 0.323172,
#   'symbol': 'LA',
#   'volume_24h': 657945.0},
#  {'circulating_supply': 591500000.0,
#   'market_cap': 24902386.6,
#   'name': 'DomRaider',
#   'platform': 'Ethereum',
#   'price': 0.0421004,
#   'symbol': 'DRT',
#   'volume_24h': 982.923},
#  {'circulating_supply': 28728253.2784,
#   'market_cap': 24808828.9553,
#   'name': 'Neumark',
#   'platform': 'Ethereum',
#   'price': 0.863569,
#   'symbol': 'NEU',
#   'volume_24h': 85536.3},
#  {'circulating_supply': 75000000.0,
#   'market_cap': 24266475.0,
#   'name': 'Matchpool',
#   'platform': 'Ethereum',
#   'price': 0.323553,
#   'symbol': 'GUP',
#   'volume_24h': 3675750.0},
#  {'circulating_supply': 16681759.3911,
#   'market_cap': 24144678.0898,
#   'name': 'Propy',
#   'platform': 'Ethereum',
#   'price': 1.44737,
#   'symbol': 'PRO',
#   'volume_24h': 10155600.0},
#  {'circulating_supply': 1292802.22735,
#   'market_cap': 23671984.4641,
#   'name': 'Numeraire',
#   'platform': 'Ethereum',
#   'price': 18.3106,
#   'symbol': 'NMR',
#   'volume_24h': 538688.0},
#  {'circulating_supply': 349367127.0,
#   'market_cap': 23476248.1495,
#   'name': 'QunQun',
#   'platform': 'Ethereum',
#   'price': 0.0671965,
#   'symbol': 'QUN',
#   'volume_24h': 9169510.0},
#  {'circulating_supply': 300000000.0,
#   'market_cap': 23309190.0,
#   'name': 'Game.com',
#   'platform': 'Ethereum',
#   'price': 0.0776973,
#   'symbol': 'GTC',
#   'volume_24h': 809160.0},
#  {'circulating_supply': 987831611.047,
#   'market_cap': 23015093.5731,
#   'name': 'Soarcoin',
#   'platform': 'Ethereum',
#   'price': 0.0232986,
#   'symbol': 'SOAR',
#   'volume_24h': 78800.2},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 22646600.0,
#   'name': 'Bodhi',
#   'platform': 'Qtum',
#   'price': 0.566165,
#   'symbol': 'BOT',
#   'volume_24h': 1128780.0},
#  {'circulating_supply': 3592379.31019,
#   'market_cap': 21847378.089,
#   'name': 'Open Trading ...',
#   'platform': 'Ethereum',
#   'price': 6.08159,
#   'symbol': 'OTN',
#   'volume_24h': 52873.9},
#  {'circulating_supply': 36883548.0906,
#   'market_cap': 21655474.474,
#   'name': 'CanYaCoin',
#   'platform': 'Ethereum',
#   'price': 0.587131,
#   'symbol': 'CAN',
#   'volume_24h': 239090.0},
#  {'circulating_supply': 229389301.0,
#   'market_cap': 21503365.9765,
#   'name': 'Hydro Protocol',
#   'platform': 'Ethereum',
#   'price': 0.0937418,
#   'symbol': 'HOT',
#   'volume_24h': 426866.0},
#  {'circulating_supply': 8049000.11223,
#   'market_cap': 21484632.5696,
#   'name': 'Swarm City',
#   'platform': 'Ethereum',
#   'price': 2.66923,
#   'symbol': 'SWT',
#   'volume_24h': 2635450.0},
#  {'circulating_supply': 45166200.0,
#   'market_cap': 21448886.3856,
#   'name': 'BlockMason Cr...',
#   'platform': 'Ethereum',
#   'price': 0.474888,
#   'symbol': 'BCPT',
#   'volume_24h': 551779.0},
#  {'circulating_supply': 234565044.0,
#   'market_cap': 21226682.1787,
#   'name': 'Zeepin',
#   'platform': 'NEO',
#   'price': 0.0904938,
#   'symbol': 'ZPT',
#   'volume_24h': 509013.0},
#  {'circulating_supply': 3798358.94793,
#   'market_cap': 20707779.3616,
#   'name': 'Hacken',
#   'platform': 'Ethereum',
#   'price': 5.45177,
#   'symbol': 'HKN',
#   'volume_24h': 277492.0},
#  {'circulating_supply': 140000000.0,
#   'market_cap': 20309380.0,
#   'name': 'Mothership',
#   'platform': 'Ethereum',
#   'price': 0.145067,
#   'symbol': 'MSP',
#   'volume_24h': 34760.5},
#  {'circulating_supply': 13000000.0,
#   'market_cap': 20258420.0,
#   'name': 'Aeron',
#   'platform': 'Ethereum',
#   'price': 1.55834,
#   'symbol': 'ARN',
#   'volume_24h': 803031.0},
#  {'circulating_supply': 2799476.19933,
#   'market_cap': 20152589.3161,
#   'name': 'MyBit Token',
#   'platform': 'Ethereum',
#   'price': 7.1987,
#   'symbol': 'MYB',
#   'volume_24h': 583797.0},
#  {'circulating_supply': 42205591.5281,
#   'market_cap': 19618256.2876,
#   'name': 'Stox',
#   'platform': 'Ethereum',
#   'price': 0.464826,
#   'symbol': 'STX',
#   'volume_24h': 1221920.0},
#  {'circulating_supply': 13631512.4213,
#   'market_cap': 19224794.598,
#   'name': 'Playkey',
#   'platform': 'Ethereum',
#   'price': 1.41032,
#   'symbol': 'PKT',
#   'volume_24h': 3376.95},
#  {'circulating_supply': 17500000.0,
#   'market_cap': 19222700.0,
#   'name': 'Covesting',
#   'platform': 'Ethereum',
#   'price': 1.09844,
#   'symbol': 'COV',
#   'volume_24h': 88089.7},
#  {'circulating_supply': 10000000.0,
#   'market_cap': 19116700.0,
#   'name': 'Uquid Coin',
#   'platform': 'Ethereum',
#   'price': 1.91167,
#   'symbol': 'UQC',
#   'volume_24h': 39868.2},
#  {'circulating_supply': 62166377.609,
#   'market_cap': 19047529.4339,
#   'name': 'EncrypGen',
#   'platform': 'Ethereum',
#   'price': 0.306396,
#   'symbol': 'DNA',
#   'volume_24h': 131845.0},
#  {'circulating_supply': 7001622.64879,
#   'market_cap': 18780032.3335,
#   'name': 'Etheroll',
#   'platform': 'Ethereum',
#   'price': 2.68224,
#   'symbol': 'DICE',
#   'volume_24h': 70927.2},
#  {'circulating_supply': 405001426.0,
#   'market_cap': 18751768.5245,
#   'name': 'Snovio',
#   'platform': 'Ethereum',
#   'price': 0.0463005,
#   'symbol': 'SNOV',
#   'volume_24h': 603212.0},
#  {'circulating_supply': 1050000000.0,
#   'market_cap': 18607995.0,
#   'name': 'AirToken',
#   'platform': 'Ethereum',
#   'price': 0.0177219,
#   'symbol': 'AIR',
#   'volume_24h': 304810.0},
#  {'circulating_supply': 9973579.0,
#   'market_cap': 18354377.4337,
#   'name': 'Waves Communi...',
#   'platform': 'Waves',
#   'price': 1.8403,
#   'symbol': 'WCT',
#   'volume_24h': 50816.9},
#  {'circulating_supply': 192929698.0,
#   'market_cap': 18335015.9705,
#   'name': 'CoinMeet',
#   'platform': 'Ethereum',
#   'price': 0.0950347,
#   'symbol': 'MEE',
#   'volume_24h': 1771890.0},
#  {'circulating_supply': 498887536.723,
#   'market_cap': 17922335.2017,
#   'name': 'Voise',
#   'platform': 'Ethereum',
#   'price': 0.0359246,
#   'symbol': 'VOISE',
#   'volume_24h': 621893.0},
#  {'circulating_supply': 2777600756.0,
#   'market_cap': 17916469.2605,
#   'name': 'NuShares',
#   'platform': 'NuBits',
#   'price': 0.00645034,
#   'symbol': 'NSR',
#   'volume_24h': 9573.89},
#  {'circulating_supply': 321137782.25,
#   'market_cap': 17483800.6204,
#   'name': 'KickCoin',
#   'platform': 'Ethereum',
#   'price': 0.0544433,
#   'symbol': 'KICK',
#   'volume_24h': 208296.0},
#  {'circulating_supply': 26244468.18,
#   'market_cap': 17264975.8811,
#   'name': 'Rivetz',
#   'platform': 'Ethereum',
#   'price': 0.657852,
#   'symbol': 'RVT',
#   'volume_24h': 3909.13},
#  {'circulating_supply': 581656.675065,
#   'market_cap': 17200227.704,
#   'name': 'ICOS',
#   'platform': 'Ethereum',
#   'price': 29.5711,
#   'symbol': 'ICOS',
#   'volume_24h': 229866.0},
#  {'circulating_supply': 127134644.724,
#   'market_cap': 17122493.9514,
#   'name': 'Xaurum',
#   'platform': 'Ethereum',
#   'price': 0.13468,
#   'symbol': 'XAUR',
#   'volume_24h': 50794.3},
#  {'circulating_supply': 122873786.567,
#   'market_cap': 17039890.9736,
#   'name': 'Bounty0x',
#   'platform': 'Ethereum',
#   'price': 0.138678,
#   'symbol': 'BNTY',
#   'volume_24h': 243723.0},
#  {'circulating_supply': 30000000.0,
#   'market_cap': 16976490.0,
#   'name': 'OracleChain',
#   'platform': 'BitShares',
#   'price': 0.565883,
#   'symbol': 'OCT',
#   'volume_24h': 76090.2},
#  {'circulating_supply': 20923342.6892,
#   'market_cap': 16926482.0754,
#   'name': 'Profile Utili...',
#   'platform': 'Qtum',
#   'price': 0.808976,
#   'symbol': 'PUT',
#   'volume_24h': 3197110.0},
#  {'circulating_supply': 25009249.58,
#   'market_cap': 16816669.5841,
#   'name': 'OAX',
#   'platform': 'Ethereum',
#   'price': 0.672418,
#   'symbol': 'OAX',
#   'volume_24h': 325169.0},
#  {'circulating_supply': 20941493.2783,
#   'market_cap': 16634707.6537,
#   'name': 'Blackmoon',
#   'platform': 'Ethereum',
#   'price': 0.794342,
#   'symbol': 'BMC',
#   'volume_24h': 430357.0},
#  {'circulating_supply': 3820953.60641,
#   'market_cap': 16586874.234,
#   'name': 'Polybius',
#   'platform': 'Ethereum',
#   'price': 4.34103,
#   'symbol': 'PLBT',
#   'volume_24h': 26092.6},
#  {'circulating_supply': 64936616.7192,
#   'market_cap': 16585201.5298,
#   'name': 'Paragon',
#   'platform': 'Ethereum',
#   'price': 0.255406,
#   'symbol': 'PRG',
#   'volume_24h': 55619.9},
#  {'circulating_supply': 18897126.0,
#   'market_cap': 16532982.1546,
#   'name': 'eBitcoin',
#   'platform': 'Ethereum',
#   'price': 0.874894,
#   'symbol': 'EBTC',
#   'volume_24h': 116018.0},
#  {'circulating_supply': 46648224.09,
#   'market_cap': 16517949.5574,
#   'name': 'ProChain',
#   'platform': 'Ethereum',
#   'price': 0.354096,
#   'symbol': 'PRA',
#   'volume_24h': 387576.0},
#  {'circulating_supply': 51200000.0,
#   'market_cap': 16383283.2,
#   'name': 'Primas',
#   'platform': 'Ethereum',
#   'price': 0.319986,
#   'symbol': 'PST',
#   'volume_24h': 359825.0},
#  {'circulating_supply': 6999991.0,
#   'market_cap': 16381028.9386,
#   'name': 'ClearPoll',
#   'platform': 'Ethereum',
#   'price': 2.34015,
#   'symbol': 'POLL',
#   'volume_24h': 313015.0},
#  {'circulating_supply': 66521026.0,
#   'market_cap': 16358118.9826,
#   'name': 'Nexium',
#   'platform': 'Ethereum',
#   'price': 0.245909,
#   'symbol': 'NXC',
#   'volume_24h': 39697.0},
#  {'circulating_supply': 9292966.0,
#   'market_cap': 16308040.1741,
#   'name': 'LockChain',
#   'platform': 'Ethereum',
#   'price': 1.75488,
#   'symbol': 'LOC',
#   'volume_24h': 16670.8},
#  {'circulating_supply': 618932216.98,
#   'market_cap': 16159825.0396,
#   'name': 'Viuly',
#   'platform': 'Ethereum',
#   'price': 0.0261092,
#   'symbol': 'VIU',
#   'volume_24h': 2035410.0},
#  {'circulating_supply': 70000000.0,
#   'market_cap': 16070880.0,
#   'name': 'BitDice',
#   'platform': 'Ethereum',
#   'price': 0.229584,
#   'symbol': 'CSNO',
#   'volume_24h': 21997.4},
#  {'circulating_supply': 14836000.0,
#   'market_cap': 15889801.08,
#   'name': 'bitUSD',
#   'platform': 'BitShares',
#   'price': 1.07103,
#   'symbol': 'BITUSD',
#   'volume_24h': 1679420.0},
#  {'circulating_supply': 36645278.3876,
#   'market_cap': 15416668.6177,
#   'name': 'BLUE',
#   'platform': 'Ethereum',
#   'price': 0.4207,
#   'symbol': 'BLUE',
#   'volume_24h': 35636.5},
#  {'circulating_supply': 191381257.0,
#   'market_cap': 15217240.4735,
#   'name': 'InvestFeed',
#   'platform': 'Ethereum',
#   'price': 0.0795127,
#   'symbol': 'IFT',
#   'volume_24h': 25048.8},
#  {'circulating_supply': 76091017.5262,
#   'market_cap': 15063282.1936,
#   'name': 'Quantum',
#   'platform': 'Ethereum',
#   'price': 0.197964,
#   'symbol': 'QAU',
#   'volume_24h': 12036.1},
#  {'circulating_supply': 2913286556.81,
#   'market_cap': 14740326.8586,
#   'name': 'bitqy',
#   'platform': 'Ethereum',
#   'price': 0.00505969,
#   'symbol': 'BQ',
#   'volume_24h': 909.026},
#  {'circulating_supply': 444444444.4,
#   'market_cap': 14738622.2207,
#   'name': 'Ecobit',
#   'platform': 'NEM',
#   'price': 0.0331619,
#   'symbol': 'ECOB',
#   'volume_24h': 3667.68},
#  {'circulating_supply': 22747808.5,
#   'market_cap': 14696585.6464,
#   'name': 'Databits',
#   'platform': 'Counterparty',
#   'price': 0.646066,
#   'symbol': 'DTB',
#   'volume_24h': 46330.6},
#  {'circulating_supply': 574512758.0,
#   'market_cap': 14681788.4332,
#   'name': 'FoldingCoin',
#   'platform': 'Counterparty',
#   'price': 0.0255552,
#   'symbol': 'FLDC',
#   'volume_24h': 265435.0},
#  {'circulating_supply': 3709674.34,
#   'market_cap': 14610107.2272,
#   'name': 'Hedge',
#   'platform': 'Ethereum',
#   'price': 3.93838,
#   'symbol': 'HDG',
#   'volume_24h': 37350.0},
#  {'circulating_supply': 14347568.22,
#   'market_cap': 14419736.4882,
#   'name': 'Dai',
#   'platform': 'Ethereum',
#   'price': 1.00503,
#   'symbol': 'DAI',
#   'volume_24h': 1484220.0},
#  {'circulating_supply': 193535756.218,
#   'market_cap': 14415955.9341,
#   'name': 'AICHAIN',
#   'platform': 'Ethereum',
#   'price': 0.0744873,
#   'symbol': 'AIT',
#   'volume_24h': 42595.2},
#  {'circulating_supply': 710112.8108,
#   'market_cap': 14334266.1875,
#   'name': 'Chronobank',
#   'platform': 'Ethereum',
#   'price': 20.1859,
#   'symbol': 'TIME',
#   'volume_24h': 258635.0},
#  {'circulating_supply': 185501578.891,
#   'market_cap': 14285309.639,
#   'name': 'OneRoot Network',
#   'platform': 'Ethereum',
#   'price': 0.0770091,
#   'symbol': 'RNT',
#   'volume_24h': 290627.0},
#  {'circulating_supply': 1000000000.0,
#   'market_cap': 14115200.0,
#   'name': 'Circuits of V...',
#   'platform': 'Counterparty',
#   'price': 0.0141152,
#   'symbol': 'COVAL',
#   'volume_24h': 90223.5},
#  {'circulating_supply': 38538648.0864,
#   'market_cap': 14020244.5579,
#   'name': 'ALIS',
#   'platform': 'Ethereum',
#   'price': 0.363797,
#   'symbol': 'ALIS',
#   'volume_24h': 34216.1},
#  {'circulating_supply': 5143006.61546,
#   'market_cap': 14016853.0899,
#   'name': 'Divi',
#   'platform': 'Ethereum',
#   'price': 2.72542,
#   'symbol': 'DIVX',
#   'volume_24h': 70980.3},
#  {'circulating_supply': 2000000.0,
#   'market_cap': 13936800.0,
#   'name': 'Exchange Union',
#   'platform': 'Ethereum',
#   'price': 6.9684,
#   'symbol': 'XUC',
#   'volume_24h': 734053.0},
#  {'circulating_supply': 70000000.0,
#   'market_cap': 13712090.0,
#   'name': 'Patientory',
#   'platform': 'Ethereum',
#   'price': 0.195887,
#   'symbol': 'PTOY',
#   'volume_24h': 261236.0},
#  {'circulating_supply': 49596285.4494,
#   'market_cap': 13692592.0832,
#   'name': 'Blockport',
#   'platform': 'Ethereum',
#   'price': 0.276081,
#   'symbol': 'BPT',
#   'volume_24h': 55741.7},
#  {'circulating_supply': 10384393.4012,
#   'market_cap': 13628581.7437,
#   'name': 'GET Protocol',
#   'platform': 'Ethereum',
#   'price': 1.31241,
#   'symbol': 'GET',
#   'volume_24h': 3463.47},
#  {'circulating_supply': 529861448.67,
#   'market_cap': 13532767.3713,
#   'name': 'Gatcoin',
#   'platform': 'Ethereum',
#   'price': 0.0255402,
#   'symbol': 'GAT',
#   'volume_24h': 157758.0},
#  {'circulating_supply': 46016602.0,
#   'market_cap': 13462156.9151,
#   'name': 'Incent',
#   'platform': 'Waves',
#   'price': 0.29255,
#   'symbol': 'INCNT',
#   'volume_24h': 78912.9},
#  {'circulating_supply': 6000000.0,
#   'market_cap': 13338540.0,
#   'name': 'Aventus',
#   'platform': 'Ethereum',
#   'price': 2.22309,
#   'symbol': 'AVT',
#   'volume_24h': 148510.0},
#  {'circulating_supply': 19429024.2167,
#   'market_cap': 13189684.5248,
#   'name': 'Mysterium',
#   'platform': 'Ethereum',
#   'price': 0.678865,
#   'symbol': 'MYST',
#   'volume_24h': 136970.0},
#  {'circulating_supply': 104685163.124,
#   'market_cap': 13031313.7909,
#   'name': 'DecentBet',
#   'platform': 'Ethereum',
#   'price': 0.124481,
#   'symbol': 'DBET',
#   'volume_24h': 29630.5},
#  {'circulating_supply': 23676581.5131,
#   'market_cap': 12549014.3804,
#   'name': 'Spectre.ai Ut...',
#   'platform': 'Ethereum',
# ...
#   'market_cap': None,
#   'name': 'BigONE Token',
#   'platform': 'Ethereum',
#   'price': 4.16938,
#   'symbol': 'BIG',
#   'volume_24h': 338685.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'COMSA [ETH]',
#   'platform': 'Ethereum',
#   'price': 1.18352,
#   'symbol': 'CMS',
#   'volume_24h': 321429.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CoinFi',
#   'platform': 'Ethereum',
#   'price': 0.0986706,
#   'symbol': 'COFI',
#   'volume_24h': 309028.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'AWARE',
#   'platform': 'Qtum',
#   'price': 0.0272303,
#   'symbol': 'AWR',
#   'volume_24h': 267269.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CryptopiaFeeS...',
#   'platform': 'Ubiq',
#   'price': 2198.21,
#   'symbol': 'CEFS',
#   'volume_24h': 257372.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'RefToken',
#   'platform': 'Ethereum',
#   'price': 26.6244,
#   'symbol': 'REF',
#   'volume_24h': 248227.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'iQuant',
#   'platform': 'Ethereum',
#   'price': 0.134026,
#   'symbol': 'IQT',
#   'volume_24h': 232236.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Nitro',
#   'platform': 'Ethereum',
#   'price': 0.389855,
#   'symbol': 'NOX',
#   'volume_24h': 230627.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TokenClub',
#   'platform': 'Ethereum',
#   'price': 0.0296135,
#   'symbol': 'TCT',
#   'volume_24h': 224751.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'COMSA [XEM]',
#   'platform': 'NEM',
#   'price': 1.17795,
#   'symbol': 'CMS',
#   'volume_24h': 220162.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'WETH',
#   'platform': 'Ethereum',
#   'price': 846.971,
#   'symbol': 'WETH',
#   'volume_24h': 218545.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Vezt',
#   'platform': 'Ethereum',
#   'price': 0.239214,
#   'symbol': 'VZT',
#   'volume_24h': 216147.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'aXpire',
#   'platform': 'Ethereum',
#   'price': 0.059058,
#   'symbol': 'AXP',
#   'volume_24h': 213506.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SpaceChain',
#   'platform': 'Qtum',
#   'price': 0.202598,
#   'symbol': 'SPC',
#   'volume_24h': 206398.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CargoX',
#   'platform': 'Ethereum',
#   'price': 0.0970129,
#   'symbol': 'CXO',
#   'volume_24h': 199330.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Content and A...',
#   'platform': 'Ethereum',
#   'price': 0.0344383,
#   'symbol': 'CAN',
#   'volume_24h': 195314.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Mixin',
#   'platform': 'Ethereum',
#   'price': 857.331,
#   'symbol': 'XIN',
#   'volume_24h': 185512.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Datawallet',
#   'platform': 'Ethereum',
#   'price': 0.126068,
#   'symbol': 'DXT',
#   'volume_24h': 91581.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EtherSportz',
#   'platform': 'Ethereum',
#   'price': 0.381023,
#   'symbol': 'ESZ',
#   'volume_24h': 88247.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'MOAC',
#   'platform': 'Ethereum',
#   'price': 12.9322,
#   'symbol': 'MOAC',
#   'volume_24h': 78593.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'adbank',
#   'platform': 'Ethereum',
#   'price': 0.0240374,
#   'symbol': 'ADB',
#   'volume_24h': 71266.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Crypterium',
#   'platform': 'Ethereum',
#   'price': 0.678002,
#   'symbol': 'CRPT',
#   'volume_24h': 62849.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'President Trump',
#   'platform': 'Omni',
#   'price': 0.0440078,
#   'symbol': 'PRES',
#   'volume_24h': 57607.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sphre AIR ',
#   'platform': 'Ethereum',
#   'price': 0.229639,
#   'symbol': 'XID',
#   'volume_24h': 54332.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Tokenbox',
#   'platform': 'Ethereum',
#   'price': 0.716383,
#   'symbol': 'TBX',
#   'volume_24h': 51646.4},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maggie',
#   'platform': 'Ethereum',
#   'price': 0.0323974,
#   'symbol': 'MAG',
#   'volume_24h': 49151.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'IPChain',
#   'platform': 'Ethereum',
#   'price': 0.695756,
#   'symbol': 'IPC',
#   'volume_24h': 46553.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Smartlands',
#   'platform': 'Stellar',
#   'price': 0.866203,
#   'symbol': 'SLT',
#   'volume_24h': 42559.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BlockCDN',
#   'platform': 'Ethereum',
#   'price': 0.114496,
#   'symbol': 'BCDN',
#   'volume_24h': 40149.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Zap',
#   'platform': 'Ethereum',
#   'price': 0.262565,
#   'symbol': 'ZAP',
#   'volume_24h': 32928.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GameChain System',
#   'platform': 'Ethereum',
#   'price': 0.0214455,
#   'symbol': 'GCS',
#   'volume_24h': 31573.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DIMCOIN',
#   'platform': 'NEM',
#   'price': 0.00593823,
#   'symbol': 'DIM',
#   'volume_24h': 30276.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ZenGold',
#   'platform': 'BitShares',
#   'price': 0.033509,
#   'symbol': 'ZENGOLD',
#   'volume_24h': 26845.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Wi Coin',
#   'platform': 'Ethereum',
#   'price': 0.00478026,
#   'symbol': 'WIC',
#   'volume_24h': 24238.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DRP Utility',
#   'platform': 'Ethereum',
#   'price': 0.718759,
#   'symbol': 'DRPU',
#   'volume_24h': 20637.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'IDEX Membership',
#   'platform': 'Ethereum',
#   'price': 5927.12,
#   'symbol': 'IDXM',
#   'volume_24h': 19080.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Indicoin',
#   'platform': 'Ethereum',
#   'price': 0.0467671,
#   'symbol': 'INDI',
#   'volume_24h': 18812.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bitair',
#   'platform': 'Ethereum',
#   'price': 0.00363448,
#   'symbol': 'BTCA',
#   'volume_24h': 17997.4},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maverick Chain',
#   'platform': 'Ethereum',
#   'price': 0.107564,
#   'symbol': 'MVC',
#   'volume_24h': 12741.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'FidentiaX',
#   'platform': 'Ethereum',
#   'price': 0.247418,
#   'symbol': 'FDX',
#   'volume_24h': 9119.15},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Swarm',
#   'platform': 'Ethereum',
#   'price': 1.31638,
#   'symbol': 'SWM',
#   'volume_24h': 7129.62},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CORION',
#   'platform': 'Ethereum Classic',
#   'price': 0.416567,
#   'symbol': 'COR',
#   'volume_24h': 6546.56},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Equal',
#   'platform': 'Ethereum',
#   'price': 0.00362749,
#   'symbol': 'EQL',
#   'volume_24h': 6357.95},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ArbitrageCT',
#   'platform': 'Ethereum',
#   'price': 0.0160216,
#   'symbol': 'ARCT',
#   'volume_24h': 5684.71},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'OX Fina',
#   'platform': 'Ethereum',
#   'price': 0.00101598,
#   'symbol': 'OX',
#   'volume_24h': 5625.34},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bankex',
#   'platform': 'Ethereum',
#   'price': 0.763739,
#   'symbol': 'BKX',
#   'volume_24h': 4439.21},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Alphabit',
#   'platform': 'Ethereum',
#   'price': 85.029,
#   'symbol': 'ABC',
#   'volume_24h': 3960.87},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GOLD Reward T...',
#   'platform': 'Ethereum',
#   'price': 0.0614721,
#   'symbol': 'GRX',
#   'volume_24h': 3942.13},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Macro',
#   'platform': 'Ethereum',
#   'price': 0.642558,
#   'symbol': 'MCR',
#   'volume_24h': 3881.53},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Musiconomi',
#   'platform': 'Ethereum',
#   'price': 0.120999,
#   'symbol': 'MCI',
#   'volume_24h': 3850.77},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'NEO GOLD',
#   'platform': 'Ethereum',
#   'price': 0.00555312,
#   'symbol': 'NEOG',
#   'volume_24h': 3725.09},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Cloud',
#   'platform': 'Ethereum',
#   'price': 0.0603945,
#   'symbol': 'CLD',
#   'volume_24h': 3662.95},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BitSerial',
#   'platform': 'Ethereum',
#   'price': 0.0791488,
#   'symbol': 'BTE',
#   'volume_24h': 2966.67},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Storjcoin X',
#   'platform': 'Counterparty',
#   'price': 1.08306,
#   'symbol': 'SJCX',
#   'volume_24h': 2793.81},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Escroco',
#   'platform': 'Waves',
#   'price': 0.762304,
#   'symbol': 'ESC',
#   'volume_24h': 2033.24},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Monero Gold',
#   'platform': 'Ethereum',
#   'price': 0.000170062,
#   'symbol': 'XMRG',
#   'volume_24h': 1810.53},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Internet of T...',
#   'platform': 'Nxt',
#   'price': 702.243,
#   'symbol': 'XOT',
#   'volume_24h': 1707.99},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sense',
#   'platform': 'Ethereum',
#   'price': 0.0409603,
#   'symbol': 'SENSE',
#   'volume_24h': 1534.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Minex',
#   'platform': 'Waves',
#   'price': 0.017923,
#   'symbol': 'MINEX',
#   'volume_24h': 1488.66},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Ethereum Lite',
#   'platform': 'Ethereum',
#   'price': 0.359512,
#   'symbol': 'ELITE',
#   'volume_24h': 1481.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SISA',
#   'platform': 'Ethereum',
#   'price': 0.0089681,
#   'symbol': 'SISA',
#   'volume_24h': 1473.64},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'First Bitcoin...',
#   'platform': 'Omni',
#   'price': 0.227288,
#   'symbol': 'BITCF',
#   'volume_24h': 1404.69},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'United Trader...',
#   'platform': 'Ethereum',
#   'price': 0.694438,
#   'symbol': 'UTT',
#   'volume_24h': 1270.59},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'PlexCoin',
#   'platform': 'Ethereum',
#   'price': 0.0246744,
#   'symbol': 'PLX',
#   'volume_24h': 1076.71},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EncryptoTel [...',
#   'platform': 'Ethereum',
#   'price': 0.0838869,
#   'symbol': 'ETT',
#   'volume_24h': 923.644},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sand Coin',
#   'platform': 'Ethereum',
#   'price': 2.12578,
#   'symbol': 'SND',
#   'volume_24h': 900.48},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eGold',
#   'platform': 'Ethereum',
#   'price': 0.0108519,
#   'symbol': 'EGOLD',
#   'volume_24h': 674.339},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BTCMoon',
#   'platform': 'Ethereum',
#   'price': 0.00866713,
#   'symbol': 'BTCM',
#   'volume_24h': 664.997},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'President Joh...',
#   'platform': 'Omni',
#   'price': 0.144808,
#   'symbol': 'GARY',
#   'volume_24h': 550.217},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TeslaCoilCoin',
#   'platform': 'Omni',
#   'price': 1.05235,
#   'symbol': 'TESLA',
#   'volume_24h': 516.822},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'HODL Bucks',
#   'platform': 'Ethereum',
#   'price': 0.153651,
#   'symbol': 'HDLB',
#   'volume_24h': 340.568},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'FAPcoin',
#   'platform': 'Ethereum',
#   'price': 0.00421837,
#   'symbol': 'FAP',
#   'volume_24h': 174.608},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Natcoin',
#   'platform': 'Ethereum',
#   'price': 0.0278307,
#   'symbol': 'NTC',
#   'volume_24h': 81.2241},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SnakeEyes',
#   'platform': 'Burst',
#   'price': 0.0218022,
#   'symbol': 'SNAKE',
#   'volume_24h': 45.1088},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'STEX',
#   'platform': 'Nxt',
#   'price': 1.35897,
#   'symbol': 'STEX',
#   'volume_24h': 29.2833},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ANRYZE',
#   'platform': 'Waves',
#   'price': 0.0122445,
#   'symbol': 'RYZ',
#   'volume_24h': 15.2719},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LLToken',
#   'platform': 'Ethereum',
#   'price': None,
#   'symbol': 'LLT',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Blockchain Index',
#   'platform': 'Ethereum',
#   'price': 4.21102,
#   'symbol': 'BLX',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Facecoin',
#   'platform': 'Ethereum',
#   'price': 0.00182733,
#   'symbol': 'FC',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eLTC',
#   'platform': 'Ethereum',
#   'price': 0.000650587,
#   'symbol': 'ELTC2',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Swapcoin',
#   'platform': 'Ethereum',
#   'price': 0.259564,
#   'symbol': 'SWP',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eUSD',
#   'platform': 'Ethereum',
#   'price': 0.0005738,
#   'symbol': 'EUSD',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': '10M Token',
#   'platform': 'Ethereum',
#   'price': 0.00519545,
#   'symbol': '10MT',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LiteCoin Gold',
#   'platform': 'Ethereum',
#   'price': 0.00613188,
#   'symbol': 'LTG',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bitcoin Silver',
#   'platform': 'Ethereum',
#   'price': 0.00480626,
#   'symbol': 'BTCS',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Cash Poker Pro',
#   'platform': 'Ethereum',
#   'price': 0.0542897,
#   'symbol': 'CASH',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'iBTC',
#   'platform': 'Ethereum',
#   'price': 0.00480388,
#   'symbol': 'IBTC',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eBIT',
#   'platform': 'Ethereum',
#   'price': 0.00419491,
#   'symbol': 'EBIT',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Faceblock',
#   'platform': 'Ethereum',
#   'price': 0.00323005,
#   'symbol': 'FBL',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Infinity Pay',
#   'platform': 'Ethereum',
#   'price': 0.00120303,
#   'symbol': 'IPY',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bitcoin2x',
#   'platform': 'Ethereum',
#   'price': 0.00578223,
#   'symbol': 'BTC2X',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Hyper TV',
#   'platform': 'Ethereum',
#   'price': 0.00118039,
#   'symbol': 'HYTV',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'UAHPay',
#   'platform': 'Ethereum',
#   'price': 0.000108135,
#   'symbol': 'UAHPAY',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EtherDelta Token',
#   'platform': 'Ethereum',
#   'price': 0.0395089,
#   'symbol': 'EDT',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Decentralized...',
#   'platform': 'Ethereum',
#   'price': 123.813,
#   'symbol': 'DUBI',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DMarket',
#   'platform': 'Ethereum',
#   'price': 0.671872,
#   'symbol': 'DMT',
#   'volume_24h': None}]

# %% [markdown]
# _________________________________
#
# ## Graphs API
# The graphs API is used internally by coinmarketcap for display graphs info. The params `start` and `end` are passed in unix microseconds timestamps and only are valid those that returns the methods, not whatever.
#
# #### `graphs.currency(name, [start=None, end=None])`
#
# Get graphs data for a currency:

# %%
cmc.graphs.currency("BTC")
# Out:
# {'market_cap_by_available_supply': [[1367174841000, 1500517590],
