# %% [markdown]
# # <center>Pymarketcap live demo</center>

# %% [markdown]
# ## Basic usage
# The first response takes a long time because some data is cached at instantiation of the wrapper.

# %%
from pymarketcap import Pymarketcap
cmc = Pymarketcap()

cmc.exchanges()
# Out:
# [{'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Cardano',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Qtum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Status',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'NEO',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Stellar',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Steem',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Upbit'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'NEO',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'ICON',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'NEO',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bluzelle',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'TRON',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'VeChain',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Binance Coin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Binance'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ethereum Classic',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum Classic',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'OKEx'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'BitMEX'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'EOS',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Qtum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Monero',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bithumb'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ripple',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'EOS',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Tether',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bitfinex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Huobi Token',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Huobi Token',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Huobi Token',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'EOS',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'TRON',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Elastos',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Elastos',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Huobi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Litecoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'GDAX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ripple',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ripple',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ripple',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Kraken'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ripple',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Cardano',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'NuBits',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Lisk',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'NEO',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Stellar',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bittrex'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Monero',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Dash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ripple',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Zcash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'EOS',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'HitBTC'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ripple',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ripple',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bitstamp'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Qtum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'IOTA',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'}],
#   'name': 'Coinone'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'}],
#   'name': 'bitFlyer'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ripple',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ripple',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Stellar',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Monero',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Poloniex'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Litecoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'EDUCare',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'TRON',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Hshare',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Lisk',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Zcash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Factom',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bit-Z'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'QASH',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ethereum',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Quoine'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'NEM',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'MonaCoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'NEM',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'COMSA [ETH]',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Counterparty',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'COMSA [XEM]',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Pepe Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Zaif'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'}],
#   'name': 'Gemini'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'MonaCoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'MonaCoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'}],
#   'name': 'Fisco'},
#  {'markets': [{'name': 'ATMCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'ATMCoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ripple',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Dogecoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'ATMCoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'ATMCoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bits Blockchain'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'BTCBOX'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'NEO',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'TRON',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Lisk',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ruff',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Qtum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Qbao',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ripple',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Achain',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'CoinEgg'},
#  {'markets': [{'name': 'Stellar',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Status',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Civic',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': '0x',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Enigma',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Zcash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'GOPAX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'EOS',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'BitShares',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Qtum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Hshare',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ripple',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ink',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Qtum',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'ZB.COM'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'}],
#   'name': 'Korbit'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'MonaCoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'MonaCoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'}],
#   'name': 'Bitbank'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ink',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Lightning Bitcoin [Futures]',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Hyper Pay',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'EXX'},
#  {'markets': [{'name': 'TRON',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Hshare',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Qtum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Energo',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Profile Utility Token',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Storm',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin Diamond',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'ENTCash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Coinnest'},
#  {'markets': [{'name': 'Jibrel Network',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Jibrel Network',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bibox Token',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bibox Token',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bibox Token',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
# ...
#    {'name': 'E-Dinar Coin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'DigiByte',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'alcurEX'},
#  {'markets': [{'name': 'E-Dinar Coin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'}],
#   'name': 'LocalTrade'},
#  {'markets': [{'name': 'Litecoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Electroneum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Monero',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Verge',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Aeon',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'BitCoal',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Sumokoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'TradeOgre'},
#  {'markets': [{'name': 'NVO',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Pepe Cash',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Counterparty',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Storjcoin X',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Rustbits',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Storjcoin X',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'FoldingCoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Bitcrystals',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'}],
#   'name': 'Counterparty DEX'},
#  {'markets': [{'name': 'Peercoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Dogecoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Dogecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Vertcoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Dash',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Litecoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Coingi'},
#  {'markets': [{'name': 'Centurion',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'ExcambrioRex'},
#  {'markets': [{'name': 'Gulden',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'GuldenTrader'},
#  {'markets': [{'name': 'LEOcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'LEOcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'LEOcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'LEOcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'LEOxChange'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'TCC Exchange'},
#  {'markets': [{'name': 'SACoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'DC-Ex'},
#  {'markets': [{'name': 'BriaCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Litecoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'}],
#   'name': 'Ore.Bz'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'}],
#   'name': 'CoinCorner'},
#  {'markets': [{'name': 'CRTCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Dogecoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'}],
#   'name': 'NIX-E'},
#  {'markets': [{'name': 'HEAT',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bismuth',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Golem',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'FIMKrypto',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Elastic',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Elastic',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'HEAT',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'Heat Wallet'},
#  {'markets': [{'name': 'SnakeEyes',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'CCMiner',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'}],
#   'name': 'Burst Asset Exchange'},
#  {'markets': [{'name': 'MaidSafeCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'Omni DEX'},
#  {'markets': [{'name': 'Golem',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Lunyr',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'SingularDTV',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'TokenCard',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Swarm City',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Etheroll',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227311,
#     'volume': 149172000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Melon',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.01,
#     'price': 910.255,
#     'volume': 119787000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Numeraire',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.69,
#     'price': 119.453,
#     'volume': 112100000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Edgeless',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.75,
#     'price': 0.406767,
#     'volume': 89769100.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum Movie Venture',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.5,
#     'price': 4.29314,
#     'volume': 59684700.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'CryptoDerivatives'},
#  {'markets': [{'name': 'Virtacoinplus',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Virtacoinplus',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'}],
#   'name': 'VirtacoinWorld'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.66,
#     'price': 0.938692,
#     'volume': 350634000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.99,
#     'price': 0.390201,
#     'volume': 334422000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.59,
#     'price': 30.1762,
#     'volume': 277147000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Siacoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.1,
#     'price': 8956.23,
#     'volume': 265372000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.68,
#     'price': 1358.8,
#     'volume': 159756000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'}],
#   'name': 'BITHOLIC'}]

# %% [markdown]
# All methods are self explained in docstrings:

# %%
print(cmc.exchanges.__doc__)
# Out:
# Get all the exchanges in coninmarketcap ranked by volumes
#         along with other metadata.
#
#         Args:
#             convert (str, optional): Convert volumes and prices
#                 between "USD" and "BTC". As default "USD".
#
#         Returns (list):
#             Exchanges with markets and other data included.

# %% [markdown]
# ___________________________________
#
# ## Coinmarketcap API
# #### `ticker(currency=None, limit=0, start=0, convert="USD")`
# If `currency == None`, you will obtain data for all currencies in coinmarketcap:

# %%
cmc.ticker()
# Out:
# [{'24h_volume_usd': 8305260000.0,
#   'available_supply': 16855000.0,
#   'id': 'bitcoin',
#   'last_updated': 1518198868,
#   'market_cap_usd': 145979300950,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin',
#   'percent_change_1h': 2.66,
#   'percent_change_24h': 5.59,
#   'percent_change_7d': 0.12,
#   'price_btc': 1.0,
#   'price_usd': 8660.89,
#   'rank': 1,
#   'symbol': 'BTC',
#   'total_supply': 16855000.0},
#  {'24h_volume_usd': 3168610000.0,
#   'available_supply': 97511865.0,
#   'id': 'ethereum',
#   'last_updated': 1518198854,
#   'market_cap_usd': 85060672251.0,
#   'max_supply': None,
#   'name': 'Ethereum',
#   'percent_change_1h': 2.38,
#   'percent_change_24h': 8.8,
#   'percent_change_7d': -3.17,
#   'price_btc': 0.100135,
#   'price_usd': 872.311,
#   'rank': 2,
#   'symbol': 'ETH',
#   'total_supply': 97511865.0},
#  {'24h_volume_usd': 1687460000.0,
#   'available_supply': 39009215838.0,
#   'id': 'ripple',
#   'last_updated': 1518198841,
#   'market_cap_usd': 36291716835.0,
#   'max_supply': 100000000000,
#   'name': 'Ripple',
#   'percent_change_1h': 1.93,
#   'percent_change_24h': 23.1,
#   'percent_change_7d': 11.07,
#   'price_btc': 0.0001068,
#   'price_usd': 0.930337,
#   'rank': 3,
#   'symbol': 'XRP',
#   'total_supply': 99992725510.0},
#  {'24h_volume_usd': 1404470000.0,
#   'available_supply': 16958275.0,
#   'id': 'bitcoin-cash',
#   'last_updated': 1518198852,
#   'market_cap_usd': 22409851664.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Cash',
#   'percent_change_1h': 2.65,
#   'percent_change_24h': 4.31,
#   'percent_change_7d': 14.0,
#   'price_btc': 0.151695,
#   'price_usd': 1321.47,
#   'rank': 4,
#   'symbol': 'BCH',
#   'total_supply': 16958275.0},
#  {'24h_volume_usd': 416754000.0,
#   'available_supply': 25927070538.0,
#   'id': 'cardano',
#   'last_updated': 1518198855,
#   'market_cap_usd': 10004245365.0,
#   'max_supply': 45000000000.0,
#   'name': 'Cardano',
#   'percent_change_1h': 2.37,
#   'percent_change_24h': 11.57,
#   'percent_change_7d': 9.59,
#   'price_btc': 4.429e-05,
#   'price_usd': 0.385861,
#   'rank': 5,
#   'symbol': 'ADA',
#   'total_supply': 31112483745.0},
#  {'24h_volume_usd': 738886000.0,
#   'available_supply': 55143283.0,
#   'id': 'litecoin',
#   'last_updated': 1518198841,
#   'market_cap_usd': 8757084224.0,
#   'max_supply': 84000000.0,
#   'name': 'Litecoin',
#   'percent_change_1h': 3.79,
#   'percent_change_24h': 10.39,
#   'percent_change_7d': 24.79,
#   'price_btc': 0.0182298,
#   'price_usd': 158.806,
#   'rank': 6,
#   'symbol': 'LTC',
#   'total_supply': 55143283.0},
#  {'24h_volume_usd': 430883000.0,
#   'available_supply': 65000000.0,
#   'id': 'neo',
#   'last_updated': 1518198847,
#   'market_cap_usd': 7538830000.0,
#   'max_supply': None,
#   'name': 'NEO',
#   'percent_change_1h': 1.41,
#   'percent_change_24h': 5.27,
#   'percent_change_7d': -0.44,
#   'price_btc': 0.0133139,
#   'price_usd': 115.982,
#   'rank': 7,
#   'symbol': 'NEO',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 167762000.0,
#   'available_supply': 18432188642.0,
#   'id': 'stellar',
#   'last_updated': 1518198843,
#   'market_cap_usd': 7359862332.0,
#   'max_supply': None,
#   'name': 'Stellar',
#   'percent_change_1h': 2.49,
#   'percent_change_24h': 13.52,
#   'percent_change_7d': 3.11,
#   'price_btc': 4.584e-05,
#   'price_usd': 0.399294,
#   'rank': 8,
#   'symbol': 'XLM',
#   'total_supply': 103669352049},
#  {'24h_volume_usd': 546172000.0,
#   'available_supply': 657692895.0,
#   'id': 'eos',
#   'last_updated': 1518198851,
#   'market_cap_usd': 6206897776.0,
#   'max_supply': 1000000000.0,
#   'name': 'EOS',
#   'percent_change_1h': 3.38,
#   'percent_change_24h': 15.67,
#   'percent_change_7d': -0.07,
#   'price_btc': 0.00108335,
#   'price_usd': 9.43738,
#   'rank': 9,
#   'symbol': 'EOS',
#   'total_supply': 900000000.0},
#  {'24h_volume_usd': 61769700.0,
#   'available_supply': 2779530283.0,
#   'id': 'iota',
#   'last_updated': 1518198851,
#   'market_cap_usd': 5410522468.0,
#   'max_supply': 2779530283.0,
#   'name': 'IOTA',
#   'percent_change_1h': 3.12,
#   'percent_change_24h': 9.2,
#   'percent_change_7d': 11.36,
#   'price_btc': 0.00022345,
#   'price_usd': 1.94656,
#   'rank': 10,
#   'symbol': 'MIOTA',
#   'total_supply': 2779530283.0},
#  {'24h_volume_usd': 54673800.0,
#   'available_supply': 8999999999.0,
#   'id': 'nem',
#   'last_updated': 1518198845,
#   'market_cap_usd': 5129927999.0,
#   'max_supply': None,
#   'name': 'NEM',
#   'percent_change_1h': 1.78,
#   'percent_change_24h': 4.99,
#   'percent_change_7d': 3.18,
#   'price_btc': 6.543e-05,
#   'price_usd': 0.569992,
#   'rank': 11,
#   'symbol': 'XEM',
#   'total_supply': 8999999999.0},
#  {'24h_volume_usd': 101313000.0,
#   'available_supply': 7874249.0,
#   'id': 'dash',
#   'last_updated': 1518198841,
#   'market_cap_usd': 4982895460.0,
#   'max_supply': 18900000.0,
#   'name': 'Dash',
#   'percent_change_1h': 3.21,
#   'percent_change_24h': 10.92,
#   'percent_change_7d': 13.8,
#   'price_btc': 0.0726421,
#   'price_usd': 632.809,
#   'rank': 12,
#   'symbol': 'DASH',
#   'total_supply': 7874249.0},
#  {'24h_volume_usd': 92321900.0,
#   'available_supply': 15702500.0,
#   'id': 'monero',
#   'last_updated': 1518198842,
#   'market_cap_usd': 4032401999.0,
#   'max_supply': None,
#   'name': 'Monero',
#   'percent_change_1h': 3.63,
#   'percent_change_24h': 7.24,
#   'percent_change_7d': 11.35,
#   'price_btc': 0.0294789,
#   'price_usd': 256.8,
#   'rank': 13,
#   'symbol': 'XMR',
#   'total_supply': 15702500.0},
#  {'24h_volume_usd': 89478500.0,
#   'available_supply': 117891448.0,
#   'id': 'lisk',
#   'last_updated': 1518198846,
#   'market_cap_usd': 3142479070.0,
#   'max_supply': None,
#   'name': 'Lisk',
#   'percent_change_1h': 3.01,
#   'percent_change_24h': 18.22,
#   'percent_change_7d': 33.4,
#   'price_btc': 0.00305989,
#   'price_usd': 26.6557,
#   'rank': 14,
#   'symbol': 'LSK',
#   'total_supply': 117891448.0},
#  {'24h_volume_usd': 252351000.0,
#   'available_supply': 65748192475.0,
#   'id': 'tron',
#   'last_updated': 1518198854,
#   'market_cap_usd': 2877673463.0,
#   'max_supply': None,
#   'name': 'TRON',
#   'percent_change_1h': 3.58,
#   'percent_change_24h': 21.35,
#   'percent_change_7d': 12.35,
#   'price_btc': 5.02e-06,
#   'price_usd': 0.0437681,
#   'rank': 15,
#   'symbol': 'TRX',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 113129000.0,
#   'available_supply': 16814349.0,
#   'id': 'bitcoin-gold',
#   'last_updated': 1518198855,
#   'market_cap_usd': 2694247146.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Gold',
#   'percent_change_1h': 1.82,
#   'percent_change_24h': 57.28,
#   'percent_change_7d': 50.97,
#   'price_btc': 0.0183938,
#   'price_usd': 160.235,
#   'rank': 16,
#   'symbol': 'BTG',
#   'total_supply': 16914349.0},
#  {'24h_volume_usd': 401958000.0,
#   'available_supply': 99735533.0,
#   'id': 'ethereum-classic',
#   'last_updated': 1518198847,
#   'market_cap_usd': 2605391329.0,
#   'max_supply': None,
#   'name': 'Ethereum Classic',
#   'percent_change_1h': 4.2,
#   'percent_change_24h': 28.54,
#   'percent_change_7d': 17.92,
#   'price_btc': 0.00299874,
#   'price_usd': 26.123,
#   'rank': 17,
#   'symbol': 'ETC',
#   'total_supply': 99735533.0},
#  {'24h_volume_usd': 2577930000.0,
#   'available_supply': 2217140814.0,
#   'id': 'tether',
#   'last_updated': 1518198845,
#   'market_cap_usd': 2320614775.0,
#   'max_supply': None,
#   'name': 'Tether',
#   'percent_change_1h': 1.5,
#   'percent_change_24h': 3.26,
#   'percent_change_7d': 5.71,
#   'price_btc': 0.00012015,
#   'price_usd': 1.04667,
#   'rank': 18,
#   'symbol': 'USDT',
#   'total_supply': 2280109970.0},
#  {'24h_volume_usd': 611843000.0,
#   'available_supply': 73869496.0,
#   'id': 'qtum',
#   'last_updated': 1518198850,
#   'market_cap_usd': 2215316637.0,
#   'max_supply': None,
#   'name': 'Qtum',
#   'percent_change_1h': 0.55,
#   'percent_change_24h': 24.35,
#   'percent_change_7d': 4.1,
#   'price_btc': 0.0034426,
#   'price_usd': 29.9896,
#   'rank': 19,
#   'symbol': 'QTUM',
#   'total_supply': 100369496.0},
#  {'24h_volume_usd': 66505100.0,
#   'available_supply': 466139235.0,
#   'id': 'vechain',
#   'last_updated': 1518198854,
#   'market_cap_usd': 2119660958.0,
#   'max_supply': None,
#   'name': 'VeChain',
#   'percent_change_1h': 3.54,
#   'percent_change_24h': 7.48,
#   'percent_change_7d': -4.46,
#   'price_btc': 0.000522,
#   'price_usd': 4.54727,
#   'rank': 20,
#   'symbol': 'VEN',
#   'total_supply': 873378637.0},
#  {'24h_volume_usd': 105421000.0,
#   'available_supply': 381495014.0,
#   'id': 'icon',
#   'last_updated': 1518198856,
#   'market_cap_usd': 1727562021.0,
#   'max_supply': None,
#   'name': 'ICON',
#   'percent_change_1h': 3.65,
#   'percent_change_24h': 5.57,
#   'percent_change_7d': -12.46,
#   'price_btc': 0.00051983,
#   'price_usd': 4.5284,
#   'rank': 21,
#   'symbol': 'ICX',
#   'total_supply': 400230000.0},
#  {'24h_volume_usd': 32013200.0,
#   'available_supply': 133248289.0,
#   'id': 'raiblocks',
#   'last_updated': 1518198849,
#   'market_cap_usd': 1597820211.0,
#   'max_supply': 133248290.0,
#   'name': 'Nano',
#   'percent_change_1h': 3.58,
#   'percent_change_24h': 8.13,
#   'percent_change_7d': -28.52,
#   'price_btc': 0.00137652,
#   'price_usd': 11.9913,
#   'rank': 22,
#   'symbol': 'XRB',
#   'total_supply': 133248289.0},
#  {'24h_volume_usd': 116925000.0,
#   'available_supply': 3242394.0,
#   'id': 'zcash',
#   'last_updated': 1518198848,
#   'market_cap_usd': 1466505512.0,
#   'max_supply': None,
#   'name': 'Zcash',
#   'percent_change_1h': 4.86,
#   'percent_change_24h': 12.04,
#   'percent_change_7d': 24.58,
#   'price_btc': 0.0519198,
#   'price_usd': 452.291,
#   'rank': 23,
#   'symbol': 'ZEC',
#   'total_supply': 3242394.0},
#  {'24h_volume_usd': 12602600.0,
#   'available_supply': 37004027.0,
#   'id': 'populous',
#   'last_updated': 1518198852,
#   'market_cap_usd': 1349126116.0,
#   'max_supply': 53252246.0,
#   'name': 'Populous',
#   'percent_change_1h': 4.03,
#   'percent_change_24h': 3.5,
#   'percent_change_7d': -32.99,
#   'price_btc': 0.00418523,
#   'price_usd': 36.4589,
#   'rank': 24,
#   'symbol': 'PPT',
#   'total_supply': 53252246.0},
#  {'24h_volume_usd': 47166200.0,
#   'available_supply': 102042552.0,
#   'id': 'omisego',
#   'last_updated': 1518198852,
#   'market_cap_usd': 1332206330.0,
#   'max_supply': None,
#   'name': 'OmiseGO',
#   'percent_change_1h': 2.55,
#   'percent_change_24h': 12.18,
#   'percent_change_7d': 2.98,
#   'price_btc': 0.00149867,
#   'price_usd': 13.0554,
#   'rank': 25,
#   'symbol': 'OMG',
#   'total_supply': 140245398.0},
#  {'24h_volume_usd': 68709500.0,
#   'available_supply': 249203123.0,
#   'id': 'steem',
#   'last_updated': 1518198846,
#   'market_cap_usd': 1065500348.0,
#   'max_supply': None,
#   'name': 'Steem',
#   'percent_change_1h': 0.99,
#   'percent_change_24h': 14.1,
#   'percent_change_7d': 6.35,
#   'price_btc': 0.00049081,
#   'price_usd': 4.27563,
#   'rank': 26,
#   'symbol': 'STEEM',
#   'total_supply': 266177217.0},
#  {'24h_volume_usd': 5480660.0,
#   'available_supply': 183717070429,
#   'id': 'bytecoin-bcn',
#   'last_updated': 1518198843,
#   'market_cap_usd': 880421805.0,
#   'max_supply': 184470000000,
#   'name': 'Bytecoin',
#   'percent_change_1h': 4.43,
#   'percent_change_24h': 8.55,
#   'percent_change_7d': 5.8,
#   'price_btc': 5.5e-07,
#   'price_usd': 0.00479227,
#   'rank': 27,
#   'symbol': 'BCN',
#   'total_supply': 183717070429},
#  {'24h_volume_usd': 85484400.0,
#   'available_supply': 99014000.0,
#   'id': 'binance-coin',
#   'last_updated': 1518198853,
#   'market_cap_usd': 876577873.0,
#   'max_supply': None,
#   'name': 'Binance Coin',
#   'percent_change_1h': 1.84,
#   'percent_change_24h': 4.47,
#   'percent_change_7d': -4.04,
#   'price_btc': 0.00101627,
#   'price_usd': 8.85307,
#   'rank': 28,
#   'symbol': 'BNB',
#   'total_supply': 197192382.0},
#  {'24h_volume_usd': 23397800.0,
#   'available_supply': 14575261692.0,
#   'id': 'verge',
#   'last_updated': 1518198843,
#   'market_cap_usd': 832101690.0,
#   'max_supply': 16555000000.0,
#   'name': 'Verge',
#   'percent_change_1h': 4.01,
#   'percent_change_24h': 11.02,
#   'percent_change_7d': 9.34,
#   'price_btc': 6.55e-06,
#   'price_usd': 0.05709,
#   'rank': 29,
#   'symbol': 'XVG',
#   'total_supply': 14575261692.0},
#  {'24h_volume_usd': 16037700.0,
#   'available_supply': 32364022122.0,
#   'id': 'siacoin',
#   'last_updated': 1518198846,
#   'market_cap_usd': 813696244.0,
#   'max_supply': None,
#   'name': 'Siacoin',
#   'percent_change_1h': 4.96,
#   'percent_change_24h': 16.04,
#   'percent_change_7d': -0.22,
#   'price_btc': 2.89e-06,
#   'price_usd': 0.025142,
#   'rank': 30,
#   'symbol': 'SC',
#   'total_supply': 32364022122.0},
#  {'24h_volume_usd': 17354400.0,
#   'available_supply': 98734037.0,
#   'id': 'stratis',
#   'last_updated': 1518198847,
#   'market_cap_usd': 795754872.0,
#   'max_supply': None,
#   'name': 'Stratis',
#   'percent_change_1h': 2.55,
#   'percent_change_24h': 15.31,
#   'percent_change_7d': -8.5,
#   'price_btc': 0.00092518,
#   'price_usd': 8.05958,
#   'rank': 31,
#   'symbol': 'STRAT',
#   'total_supply': 98734037.0},
#  {'24h_volume_usd': 165969000.0,
#   'available_supply': 3470483788.0,
#   'id': 'status',
#   'last_updated': 1518198852,
#   'market_cap_usd': 785769587.0,
#   'max_supply': None,
#   'name': 'Status',
#   'percent_change_1h': 1.32,
#   'percent_change_24h': 6.36,
#   'percent_change_7d': 36.77,
#   'price_btc': 2.599e-05,
#   'price_usd': 0.226415,
#   'rank': 32,
#   'symbol': 'SNT',
#   'total_supply': 6804870174.0},
#  {'24h_volume_usd': 22089300.0,
#   'available_supply': 233020472.0,
#   'id': 'aeternity',
#   'last_updated': 1518198850,
#   'market_cap_usd': 707471125.0,
#   'max_supply': None,
#   'name': 'Aeternity',
#   'percent_change_1h': 3.23,
#   'percent_change_24h': 7.32,
#   'percent_change_7d': 18.9,
#   'price_btc': 0.00034852,
#   'price_usd': 3.03609,
#   'rank': 33,
#   'symbol': 'AE',
#   'total_supply': 273685830.0},
#  {'24h_volume_usd': 28830900.0,
#   'available_supply': 2608390000.0,
#   'id': 'bitshares',
#   'last_updated': 1518198844,
#   'market_cap_usd': 678053589.0,
#   'max_supply': 3600570502.0,
#   'name': 'BitShares',
#   'percent_change_1h': 3.31,
#   'percent_change_24h': 12.4,
#   'percent_change_7d': -15.29,
#   'price_btc': 2.984e-05,
#   'price_usd': 0.259951,
#   'rank': 34,
#   'symbol': 'BTS',
#   'total_supply': 2608390000.0},
#  {'24h_volume_usd': 642509.0,
#   'available_supply': 618228.0,
#   'id': 'maker',
#   'last_updated': 1518198849,
#   'market_cap_usd': 675110907.0,
#   'max_supply': None,
#   'name': 'Maker',
#   'percent_change_1h': 3.17,
#   'percent_change_24h': 9.62,
#   'percent_change_7d': -3.57,
#   'price_btc': 0.125355,
#   'price_usd': 1092.01,
#   'rank': 35,
#   'symbol': 'MKR',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 6477000.0,
#   'available_supply': 11000000.0,
#   'id': 'augur',
#   'last_updated': 1518198846,
#   'market_cap_usd': 624411700.0,
#   'max_supply': None,
#   'name': 'Augur',
#   'percent_change_1h': 3.24,
#   'percent_change_24h': 10.43,
#   'percent_change_7d': 1.74,
#   'price_btc': 0.00651619,
#   'price_usd': 56.7647,
#   'rank': 36,
#   'symbol': 'REP',
#   'total_supply': 11000000.0},
#  {'24h_volume_usd': 25862200.0,
#   'available_supply': 2000000.0,
#   'id': 'digixdao',
#   'last_updated': 1518198846,
#   'market_cap_usd': 617420000.0,
#   'max_supply': None,
#   'name': 'DigixDAO',
#   'percent_change_1h': 3.6,
#   'percent_change_24h': 7.21,
#   'percent_change_7d': -12.61,
#   'price_btc': 0.0354377,
#   'price_usd': 308.71,
#   'rank': 37,
#   'symbol': 'DGD',
#   'total_supply': 2000000.0},
#  {'24h_volume_usd': 27870800.0,
#   'available_supply': 100000000.0,
#   'id': 'waves',
#   'last_updated': 1518198847,
#   'market_cap_usd': 609085000.0,
#   'max_supply': None,
#   'name': 'Waves',
#   'percent_change_1h': 5.15,
#   'percent_change_24h': 13.33,
#   'percent_change_7d': -0.13,
#   'price_btc': 0.00069919,
#   'price_usd': 6.09085,
#   'rank': 38,
#   'symbol': 'WAVES',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 17406700.0,
#   'available_supply': 24898178.0,
#   'id': 'walton',
#   'last_updated': 1518198853,
#   'market_cap_usd': 598213584.0,
#   'max_supply': 100000000.0,
#   'name': 'Walton',
#   'percent_change_1h': 3.49,
#   'percent_change_24h': 7.0,
#   'percent_change_7d': -0.51,
#   'price_btc': 0.00275806,
#   'price_usd': 24.0264,
#   'rank': 39,
#   'symbol': 'WTC',
#   'total_supply': 70000000.0},
#  {'24h_volume_usd': 171554.0,
#   'available_supply': 2036645.0,
#   'id': 'veritaseum',
#   'last_updated': 1518198851,
#   'market_cap_usd': 586158778.0,
#   'max_supply': None,
#   'name': 'Veritaseum',
#   'percent_change_1h': 0.81,
#   'percent_change_24h': 4.81,
#   'percent_change_7d': -10.95,
#   'price_btc': 0.0330382,
#   'price_usd': 287.806,
#   'rank': 40,
#   'symbol': 'VERI',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 13762100.0,
#   'available_supply': 507188082.0,
#   'id': '0x',
#   'last_updated': 1518198852,
#   'market_cap_usd': 585122603.0,
#   'max_supply': None,
#   'name': '0x',
#   'percent_change_1h': 2.81,
#   'percent_change_24h': 8.79,
#   'percent_change_7d': -10.32,
#   'price_btc': 0.00013243,
#   'price_usd': 1.15366,
#   'rank': 41,
#   'symbol': 'ZRX',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 10303300.0,
#   'available_supply': 113132925740,
#   'id': 'dogecoin',
#   'last_updated': 1518198841,
#   'market_cap_usd': 556927373.0,
#   'max_supply': None,
#   'name': 'Dogecoin',
#   'percent_change_1h': 3.07,
#   'percent_change_24h': 8.62,
#   'percent_change_7d': 13.49,
#   'price_btc': 5.7e-07,
#   'price_usd': 0.00492277,
#   'rank': 42,
#   'symbol': 'DOGE',
#   'total_supply': 113132925740},
#  {'24h_volume_usd': 1842530.0,
#   'available_supply': 6723418.0,
#   'id': 'decred',
#   'last_updated': 1518198846,
#   'market_cap_usd': 549129075.0,
#   'max_supply': 21000000.0,
#   'name': 'Decred',
#   'percent_change_1h': 2.83,
#   'percent_change_24h': 9.74,
#   'percent_change_7d': 6.05,
#   'price_btc': 0.00937562,
#   'price_usd': 81.6741,
#   'rank': 43,
#   'symbol': 'DCR',
#   'total_supply': 7143418.0},
#  {'24h_volume_usd': 2894520.0,
#   'available_supply': 91043076.0,
#   'id': 'kucoin-shares',
#   'last_updated': 1518198855,
#   'market_cap_usd': 540990704.0,
#   'max_supply': None,
#   'name': 'KuCoin Shares',
#   'percent_change_1h': 4.05,
#   'percent_change_24h': 3.95,
#   'percent_change_7d': -7.62,
#   'price_btc': 0.00068212,
#   'price_usd': 5.94214,
#   'rank': 44,
#   'symbol': 'KCS',
#   'total_supply': 181043076.0},
#  {'24h_volume_usd': 80750100.0,
#   'available_supply': 42603128.0,
#   'id': 'hshare',
#   'last_updated': 1518198852,
#   'market_cap_usd': 530315217.0,
#   'max_supply': 84000000.0,
#   'name': 'Hshare',
#   'percent_change_1h': 0.38,
#   'percent_change_24h': 16.75,
#   'percent_change_7d': 11.47,
#   'price_btc': 0.00142892,
#   'price_usd': 12.4478,
#   'rank': 45,
#   'symbol': 'HSR',
#   'total_supply': 42603128.0},
#  {'24h_volume_usd': 744666.0,
#   'available_supply': 344166289.0,
#   'id': 'rchain',
#   'last_updated': 1518198854,
#   'market_cap_usd': 507500726.0,
#   'max_supply': 1000000000.0,
#   'name': 'RChain',
#   'percent_change_1h': 3.82,
#   'percent_change_24h': 10.5,
#   'percent_change_7d': -9.42,
#   'price_btc': 0.00016927,
#   'price_usd': 1.47458,
#   'rank': 46,
#   'symbol': 'RHOC',
#   'total_supply': 870663574.0},
#  {'24h_volume_usd': 68752900.0,
#   'available_supply': 998999495.0,
#   'id': 'ardor',
#   'last_updated': 1518198847,
#   'market_cap_usd': 499199049.0,
#   'max_supply': 998999495.0,
#   'name': 'Ardor',
#   'percent_change_1h': 1.35,
#   'percent_change_24h': 13.91,
#   'percent_change_7d': 3.92,
#   'price_btc': 5.736e-05,
#   'price_usd': 0.499699,
#   'rank': 47,
#   'symbol': 'ARDR',
#   'total_supply': 998999495.0},
#  {'24h_volume_usd': 5563900.0,
#   'available_supply': 184450000.0,
#   'id': 'revain',
#   'last_updated': 1518198856,
#   'market_cap_usd': 456847605.0,
#   'max_supply': 484450000.0,
#   'name': 'Revain',
#   'percent_change_1h': 4.19,
#   'percent_change_24h': 20.76,
#   'percent_change_7d': 68.33,
#   'price_btc': 0.00028432,
#   'price_usd': 2.47681,
#   'rank': 48,
#   'symbol': 'R',
#   'total_supply': 484450000.0},
#  {'24h_volume_usd': 4915810.0,
#   'available_supply': 103151593.0,
#   'id': 'komodo',
#   'last_updated': 1518198849,
#   'market_cap_usd': 455334856.0,
#   'max_supply': None,
#   'name': 'Komodo',
#   'percent_change_1h': 2.52,
#   'percent_change_24h': 13.34,
#   'percent_change_7d': 2.72,
#   'price_btc': 0.00050672,
#   'price_usd': 4.41423,
#   'rank': 49,
#   'symbol': 'KMD',
#   'total_supply': 103151593.0},
#  {'24h_volume_usd': 7627580.0,
#   'available_supply': 134132697.0,
#   'id': 'kyber-network',
#   'last_updated': 1518198854,
#   'market_cap_usd': 449399529.0,
#   'max_supply': None,
#   'name': 'Kyber Network',
#   'percent_change_1h': 2.97,
#   'percent_change_24h': 9.13,
#   'percent_change_7d': 1.65,
#   'price_btc': 0.0003846,
#   'price_usd': 3.35041,
#   'rank': 50,
#   'symbol': 'KNC',
#   'total_supply': 215625349.0},
#  {'24h_volume_usd': 2632450.0,
#   'available_supply': 6104760774.0,
#   'id': 'electroneum',
#   'last_updated': 1518198856,
#   'market_cap_usd': 446384381.0,
#   'max_supply': 21000000000.0,
#   'name': 'Electroneum',
#   'percent_change_1h': 4.65,
#   'percent_change_24h': 8.26,
#   'percent_change_7d': 12.13,
#   'price_btc': 8.39e-06,
#   'price_usd': 0.0731207,
#   'rank': 51,
#   'symbol': 'ETN',
#   'total_supply': 6104760774.0},
#  {'24h_volume_usd': 9378320.0,
#   'available_supply': 100525698.0,
#   'id': 'ark',
#   'last_updated': 1518198849,
#   'market_cap_usd': 438083955.0,
#   'max_supply': None,
#   'name': 'Ark',
#   'percent_change_1h': 2.31,
#   'percent_change_24h': 14.34,
#   'percent_change_7d': 0.37,
#   'price_btc': 0.00050026,
#   'price_usd': 4.35793,
#   'rank': 52,
#   'symbol': 'ARK',
#   'total_supply': 131775698.0},
#  {'24h_volume_usd': 9153900.0,
#   'available_supply': 9675198.0,
#   'id': 'gas',
#   'last_updated': 1518198853,
#   'market_cap_usd': 422313706.0,
#   'max_supply': 100000000.0,
#   'name': 'Gas',
#   'percent_change_1h': 3.61,
#   'percent_change_24h': 7.26,
#   'percent_change_7d': -4.97,
#   'price_btc': 0.00501061,
#   'price_usd': 43.6491,
#   'rank': 53,
#   'symbol': 'GAS',
#   'total_supply': 15257384.0},
#  {'24h_volume_usd': 2357780.0,
#   'available_supply': 238421940.0,
#   'id': 'dragonchain',
#   'last_updated': 1518198857,
#   'market_cap_usd': 399771604.0,
#   'max_supply': None,
#   'name': 'Dragonchain',
#   'percent_change_1h': 6.82,
#   'percent_change_24h': 12.8,
#   'percent_change_7d': 0.4,
#   'price_btc': 0.00019248,
#   'price_usd': 1.67674,
#   'rank': 54,
#   'symbol': 'DRGN',
#   'total_supply': 433494437.0},
#  {'24h_volume_usd': 6908420.0,
#   'available_supply': 9818352393.0,
#   'id': 'digibyte',
#   'last_updated': 1518198841,
#   'market_cap_usd': 395491089.0,
#   'max_supply': 21000000000.0,
#   'name': 'DigiByte',
#   'percent_change_1h': 5.96,
#   'percent_change_24h': 23.15,
#   'percent_change_7d': -0.32,
#   'price_btc': 4.62e-06,
#   'price_usd': 0.0402808,
#   'rank': 55,
#   'symbol': 'DGB',
#   'total_supply': 9818352393.0},
#  {'24h_volume_usd': 5881110.0,
#   'available_supply': 1000000000.0,
#   'id': 'basic-attention-token',
#   'last_updated': 1518198851,
#   'market_cap_usd': 394429000.0,
#   'max_supply': None,
#   'name': 'Basic Attention Token',
#   'percent_change_1h': 4.52,
#   'percent_change_24h': 5.55,
#   'percent_change_7d': -2.55,
#   'price_btc': 4.528e-05,
#   'price_usd': 0.394429,
#   'rank': 56,
#   'symbol': 'BAT',
#   'total_supply': 1500000000.0},
#  {'24h_volume_usd': 12268100.0,
#   'available_supply': 6508988220.0,
#   'id': 'zilliqa',
#   'last_updated': 1518198860,
#   'market_cap_usd': 392044171.0,
#   'max_supply': None,
#   'name': 'Zilliqa',
#   'percent_change_1h': 2.79,
#   'percent_change_24h': 5.11,
#   'percent_change_7d': -10.23,
#   'price_btc': 6.91e-06,
#   'price_usd': 0.0602312,
#   'rank': 57,
#   'symbol': 'ZIL',
#   'total_supply': 12600000000.0},
#  {'24h_volume_usd': 3015360.0,
#   'available_supply': 561202251.0,
#   'id': 'loopring',
#   'last_updated': 1518198854,
#   'market_cap_usd': 385927564.0,
#   'max_supply': None,
#   'name': 'Loopring',
#   'percent_change_1h': 3.85,
#   'percent_change_24h': 9.6,
#   'percent_change_7d': -8.92,
#   'price_btc': 7.894e-05,
#   'price_usd': 0.68768,
#   'rank': 58,
#   'symbol': 'LRC',
#   'total_supply': 1374956357.0},
#  {'24h_volume_usd': 609942.0,
#   'available_supply': 325226613094,
#   'id': 'dentacoin',
#   'last_updated': 1518198853,
#   'market_cap_usd': 372553590.0,
#   'max_supply': 8000000000000,
#   'name': 'Dentacoin',
#   'percent_change_1h': 4.54,
#   'percent_change_24h': 7.92,
#   'percent_change_7d': 8.82,
#   'price_btc': 1.3e-07,
#   'price_usd': 0.00114552,
#   'rank': 59,
#   'symbol': 'DCN',
#   'total_supply': 1963173416169},
#  {'24h_volume_usd': 45525000.0,
#   'available_supply': 250000000.0,
#   'id': 'aelf',
#   'last_updated': 1518198858,
#   'market_cap_usd': 347160000.0,
#   'max_supply': None,
#   'name': 'aelf',
#   'percent_change_1h': 3.89,
#   'percent_change_24h': 9.12,
#   'percent_change_7d': -10.51,
#   'price_btc': 0.00015941,
#   'price_usd': 1.38864,
#   'rank': 60,
#   'symbol': 'ELF',
#   'total_supply': 260000000.0},
#  {'24h_volume_usd': 17000000.0,
#   'available_supply': 987000000.0,
#   'id': 'bytom',
#   'last_updated': 1518198853,
#   'market_cap_usd': 344584401.0,
#   'max_supply': None,
#   'name': 'Bytom',
#   'percent_change_1h': 3.41,
#   'percent_change_24h': 19.18,
#   'percent_change_7d': 7.03,
#   'price_btc': 4.008e-05,
#   'price_usd': 0.349123,
#   'rank': 61,
#   'symbol': 'BTM',
#   'total_supply': 1407000000.0},
#  {'24h_volume_usd': 7167410.0,
#   'available_supply': 75601200.0,
#   'id': 'ethos',
#   'last_updated': 1518198852,
#   'market_cap_usd': 340246223.0,
#   'max_supply': None,
#   'name': 'Ethos',
#   'percent_change_1h': 3.57,
#   'percent_change_24h': 7.32,
#   'percent_change_7d': 21.63,
#   'price_btc': 0.00051663,
#   'price_usd': 4.50054,
#   'rank': 62,
#   'symbol': 'ETHOS',
#   'total_supply': 222295208.0},
#  {'24h_volume_usd': 14677300.0,
#   'available_supply': 55526163.0,
#   'id': 'pivx',
#   'last_updated': 1518198846,
#   'market_cap_usd': 339764033.0,
#   'max_supply': None,
#   'name': 'PIVX',
#   'percent_change_1h': 1.84,
#   'percent_change_24h': 14.25,
#   'percent_change_7d': 7.91,
#   'price_btc': 0.00070242,
#   'price_usd': 6.11899,
#   'rank': 63,
#   'symbol': 'PIVX',
#   'total_supply': 55526163.0},
#  {'24h_volume_usd': 485386.0,
#   'available_supply': 4981227.0,
#   'id': 'e-coin',
#   'last_updated': 1518198850,
#   'market_cap_usd': 337437305.0,
#   'max_supply': None,
#   'name': 'E-coin',
#   'percent_change_1h': 2.93,
#   'percent_change_24h': 983.43,
#   'percent_change_7d': 1271.98,
#   'price_btc': 0.00777629,
#   'price_usd': 67.7418,
#   'rank': 64,
#   'symbol': 'ECN',
#   'total_supply': 213270119.0},
#  {'24h_volume_usd': 4798770.0,
#   'available_supply': 3264950.0,
#   'id': 'zclassic',
#   'last_updated': 1518198848,
#   'market_cap_usd': 336952635.0,
#   'max_supply': 21000000.0,
#   'name': 'ZClassic',
#   'percent_change_1h': 4.58,
#   'percent_change_24h': 5.61,
#   'percent_change_7d': 6.31,
#   'price_btc': 0.011847,
#   'price_usd': 103.203,
#   'rank': 65,
#   'symbol': 'ZCL',
#   'total_supply': 3264950.0},
#  {'24h_volume_usd': 800091.0,
#   'available_supply': 645222.0,
#   'id': 'byteball',
#   'last_updated': 1518198848,
#   'market_cap_usd': 335632253.0,
#   'max_supply': None,
#   'name': 'Byteball Bytes',
#   'percent_change_1h': 5.6,
#   'percent_change_24h': 13.13,
#   'percent_change_7d': -1.87,
#   'price_btc': 0.0597131,
#   'price_usd': 520.181,
#   'rank': 66,
#   'symbol': 'GBYTE',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 289445.0,
#   'available_supply': 227384800.0,
#   'id': 'pillar',
#   'last_updated': 1518198852,
#   'market_cap_usd': 324744150.0,
#   'max_supply': None,
#   'name': 'Pillar',
#   'percent_change_1h': 2.79,
#   'percent_change_24h': 5.17,
#   'percent_change_7d': 10.18,
#   'price_btc': 0.00016394,
#   'price_usd': 1.42817,
#   'rank': 67,
#   'symbol': 'PLR',
#   'total_supply': 800000000.0},
#  {'24h_volume_usd': 3097430.0,
#   'available_supply': 350000000.0,
#   'id': 'qash',
#   'last_updated': 1518198857,
#   'market_cap_usd': 316508850.0,
#   'max_supply': None,
#   'name': 'QASH',
#   'percent_change_1h': 2.56,
#   'percent_change_24h': 8.18,
#   'percent_change_7d': -0.68,
#   'price_btc': 0.00010381,
#   'price_usd': 0.904311,
#   'rank': 68,
#   'symbol': 'QASH',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 7307720.0,
#   'available_supply': 35500000.0,
#   'id': 'nebulas-token',
#   'last_updated': 1518198853,
#   'market_cap_usd': 309129740.0,
#   'max_supply': 100000000.0,
#   'name': 'Nebulas',
#   'percent_change_1h': 2.93,
#   'percent_change_24h': 11.79,
#   'percent_change_7d': -1.87,
#   'price_btc': 0.0009996,
#   'price_usd': 8.70788,
#   'rank': 69,
#   'symbol': 'NAS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 30502400.0,
#   'available_supply': 4503688789.0,
#   'id': 'funfair',
#   'last_updated': 1518198851,
#   'market_cap_usd': 301032413.0,
#   'max_supply': None,
#   'name': 'FunFair',
#   'percent_change_1h': 3.52,
#   'percent_change_24h': 8.46,
#   'percent_change_7d': 11.87,
#   'price_btc': 7.67e-06,
#   'price_usd': 0.0668413,
#   'rank': 70,
#   'symbol': 'FUN',
#   'total_supply': 10999873621.0},
#  {'24h_volume_usd': 7165220.0,
#   'available_supply': 834262000.0,
#   'id': 'golem-network-tokens',
#   'last_updated': 1518198848,
#   'market_cap_usd': 298310400.0,
#   'max_supply': None,
#   'name': 'Golem',
#   'percent_change_1h': 4.9,
#   'percent_change_24h': 10.37,
#   'percent_change_7d': 0.44,
#   'price_btc': 4.105e-05,
#   'price_usd': 0.357574,
#   'rank': 71,
#   'symbol': 'GNT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 233063.0,
#   'available_supply': 45106529.0,
#   'id': 'cryptonex',
#   'last_updated': 1518198855,
#   'market_cap_usd': 294387313.0,
#   'max_supply': 210000000.0,
#   'name': 'Cryptonex',
#   'percent_change_1h': 3.83,
#   'percent_change_24h': 5.13,
#   'percent_change_7d': 3.8,
#   'price_btc': 0.0007492,
#   'price_usd': 6.52649,
#   'rank': 72,
#   'symbol': 'CNX',
#   'total_supply': 106544155.0},
#  {'24h_volume_usd': 12510400.0,
#   'available_supply': 1445976590.0,
#   'id': 'cindicator',
#   'last_updated': 1518198855,
#   'market_cap_usd': 292241991.0,
#   'max_supply': None,
#   'name': 'Cindicator',
#   'percent_change_1h': 3.55,
#   'percent_change_24h': 7.35,
#   'percent_change_7d': 5.51,
#   'price_btc': 2.32e-05,
#   'price_usd': 0.202107,
#   'rank': 73,
#   'symbol': 'CND',
#   'total_supply': 2000000005.0},
#  {'24h_volume_usd': 2896540.0,
#   'available_supply': 10614760961.0,
#   'id': 'dent',
#   'last_updated': 1518198853,
#   'market_cap_usd': 289898675.0,
#   'max_supply': None,
#   'name': 'Dent',
#   'percent_change_1h': 3.46,
#   'percent_change_24h': 6.8,
#   'percent_change_7d': 23.36,
#   'price_btc': 3.14e-06,
#   'price_usd': 0.0273109,
#   'rank': 74,
#   'symbol': 'DENT',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 3973650.0,
#   'available_supply': 530835167.0,
#   'id': 'syscoin',
#   'last_updated': 1518198843,
#   'market_cap_usd': 285475190.0,
#   'max_supply': 888000000.0,
#   'name': 'Syscoin',
#   'percent_change_1h': 3.34,
#   'percent_change_24h': 3.83,
#   'percent_change_7d': 15.47,
#   'price_btc': 6.173e-05,
#   'price_usd': 0.537785,
#   'rank': 75,
#   'symbol': 'SYS',
#   'total_supply': 530835167.0},
#  {'24h_volume_usd': 1421120.0,
#   'available_supply': 11168225.0,
#   'id': 'bitcore',
#   'last_updated': 1518198850,
#   'market_cap_usd': 279418929.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcore',
#   'percent_change_1h': 1.6,
#   'percent_change_24h': 3.15,
#   'percent_change_7d': 11.57,
#   'price_btc': 0.00287202,
#   'price_usd': 25.0191,
#   'rank': 76,
#   'symbol': 'BTX',
#   'total_supply': 16795163.0},
#  {'24h_volume_usd': 40545900.0,
#   'available_supply': 6794109922.0,
#   'id': 'iostoken',
#   'last_updated': 1518198859,
#   'market_cap_usd': 276935394.0,
#   'max_supply': None,
#   'name': 'IOStoken',
#   'percent_change_1h': 2.32,
#   'percent_change_24h': 5.4,
#   'percent_change_7d': -9.8,
#   'price_btc': 4.68e-06,
#   'price_usd': 0.0407611,
#   'rank': 77,
#   'symbol': 'IOST',
#   'total_supply': 21000000000.0},
#  {'24h_volume_usd': 17671800.0,
#   'available_supply': 60000000.0,
#   'id': 'gxshares',
#   'last_updated': 1518198851,
#   'market_cap_usd': 272122800.0,
#   'max_supply': 100000000.0,
#   'name': 'GXShares',
#   'percent_change_1h': 3.12,
#   'percent_change_24h': 9.36,
#   'percent_change_7d': 4.85,
#   'price_btc': 0.00052063,
#   'price_usd': 4.53538,
#   'rank': 78,
#   'symbol': 'GXS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 18813500.0,
#   'available_supply': 363837589.0,
#   'id': 'power-ledger',
#   'last_updated': 1518198856,
#   'market_cap_usd': 264970909.0,
#   'max_supply': None,
#   'name': 'Power Ledger',
#   'percent_change_1h': 2.46,
#   'percent_change_24h': 8.86,
#   'percent_change_7d': 11.04,
#   'price_btc': 8.36e-05,
#   'price_usd': 0.728267,
#   'rank': 79,
#   'symbol': 'POWR',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 6809100.0,
#   'available_supply': 52847204.0,
#   'id': 'salt',
#   'last_updated': 1518198855,
#   'market_cap_usd': 250129514.0,
#   'max_supply': None,
#   'name': 'SALT',
#   'percent_change_1h': 4.0,
#   'percent_change_24h': 7.53,
#   'percent_change_7d': 4.99,
#   'price_btc': 0.00054332,
#   'price_usd': 4.73307,
#   'rank': 80,
#   'symbol': 'SALT',
#   'total_supply': 120000000.0},
#  {'24h_volume_usd': 5521950.0,
#   'available_supply': 8745102.0,
#   'id': 'factom',
#   'last_updated': 1518198845,
#   'market_cap_usd': 249668290.0,
#   'max_supply': None,
#   'name': 'Factom',
#   'percent_change_1h': 4.71,
#   'percent_change_24h': 13.3,
#   'percent_change_7d': 3.73,
#   'price_btc': 0.00327729,
#   'price_usd': 28.5495,
#   'rank': 81,
#   'symbol': 'FCT',
#   'total_supply': 8745102.0},
#  {'24h_volume_usd': 5175980.0,
#   'available_supply': 79265735.0,
#   'id': 'aion',
#   'last_updated': 1518198855,
#   'market_cap_usd': 236958573.0,
#   'max_supply': None,
#   'name': 'Aion',
#   'percent_change_1h': 3.43,
#   'percent_change_24h': 6.86,
#   'percent_change_7d': -6.58,
#   'price_btc': 0.00034316,
#   'price_usd': 2.98942,
#   'rank': 82,
#   'symbol': 'AION',
#   'total_supply': 465934587.0},
#  {'24h_volume_usd': 164014.0,
#   'available_supply': 756097560976,
#   'id': 'kin',
#   'last_updated': 1518198854,
#   'market_cap_usd': 228764878.0,
#   'max_supply': None,
#   'name': 'Kin',
#   'percent_change_1h': 0.97,
#   'percent_change_24h': 12.52,
#   'percent_change_7d': 4.41,
#   'price_btc': 3e-08,
#   'price_usd': 0.00030256,
#   'rank': 83,
#   'symbol': 'KIN',
#   'total_supply': 10000000000000},
#  {'24h_volume_usd': 3271970.0,
#   'available_supply': 57307800.0,
#   'id': 'monacoin',
#   'last_updated': 1518198843,
#   'market_cap_usd': 227208234.0,
#   'max_supply': None,
#   'name': 'MonaCoin',
#   'percent_change_1h': 3.45,
#   'percent_change_24h': 7.8,
#   'percent_change_7d': 3.77,
#   'price_btc': 0.00045512,
#   'price_usd': 3.9647,
#   'rank': 84,
#   'symbol': 'MONA',
#   'total_supply': 57307800.0},
#  {'24h_volume_usd': 287603.0,
#   'available_supply': 682538353.0,
#   'id': 'smartcash',
#   'last_updated': 1518198852,
#   'market_cap_usd': 222096615.0,
#   'max_supply': 5000000000.0,
#   'name': 'SmartCash',
#   'percent_change_1h': 1.91,
#   'percent_change_24h': 1.89,
#   'percent_change_7d': -7.04,
#   'price_btc': 3.735e-05,
#   'price_usd': 0.325398,
#   'rank': 85,
#   'symbol': 'SMART',
#   'total_supply': 1283582632.0},
#  {'24h_volume_usd': 7382650.0,
#   'available_supply': 4068712.0,
#   'id': 'zcoin',
#   'last_updated': 1518198848,
#   'market_cap_usd': 219043992.0,
#   'max_supply': None,
#   'name': 'ZCoin',
#   'percent_change_1h': 3.05,
#   'percent_change_24h': 10.03,
#   'percent_change_7d': 2.05,
#   'price_btc': 0.00618002,
#   'price_usd': 53.8362,
#   'rank': 86,
#   'symbol': 'XZC',
#   'total_supply': 4068712.0},
#  {'24h_volume_usd': 8131100.0,
#   'available_supply': 74836171.0,
#   'id': 'enigma-project',
#   'last_updated': 1518198855,
#   'market_cap_usd': 214750625.0,
#   'max_supply': None,
#   'name': 'Enigma',
#   'percent_change_1h': 5.77,
#   'percent_change_24h': 17.85,
#   'percent_change_7d': 10.15,
#   'price_btc': 0.00032941,
#   'price_usd': 2.86961,
#   'rank': 87,
#   'symbol': 'ENG',
#   'total_supply': 150000000.0},
#  {'24h_volume_usd': 386675.0,
#   'available_supply': 8865517.0,
#   'id': 'particl',
#   'last_updated': 1518198852,
#   'market_cap_usd': 212225397.0,
#   'max_supply': None,
#   'name': 'Particl',
#   'percent_change_1h': 3.69,
#   'percent_change_24h': 18.49,
#   'percent_change_7d': 11.95,
#   'price_btc': 0.00274796,
#   'price_usd': 23.9383,
#   'rank': 88,
#   'symbol': 'PART',
#   'total_supply': 8865517.0},
#  {'24h_volume_usd': 7088820.0,
#   'available_supply': 38986587.0,
#   'id': 'bancor',
#   'last_updated': 1518198851,
#   'market_cap_usd': 206903378.0,
#   'max_supply': None,
#   'name': 'Bancor',
#   'percent_change_1h': 3.54,
#   'percent_change_24h': 9.62,
#   'percent_change_7d': -7.26,
#   'price_btc': 0.00060921,
#   'price_usd': 5.30704,
#   'rank': 89,
#   'symbol': 'BNT',
#   'total_supply': 74985159.0},
#  {'24h_volume_usd': 19956900.0,
#   'available_supply': 617314171.0,
#   'id': 'quantstamp',
#   'last_updated': 1518198857,
#   'market_cap_usd': 206084163.0,
#   'max_supply': None,
#   'name': 'Quantstamp',
#   'percent_change_1h': 3.23,
#   'percent_change_24h': 9.97,
#   'percent_change_7d': 25.99,
#   'price_btc': 3.832e-05,
#   'price_usd': 0.33384,
#   'rank': 90,
#   'symbol': 'QSP',
#   'total_supply': 976442388.0},
#  {'24h_volume_usd': 16316600.0,
#   'available_supply': 761143950.0,
#   'id': 'ignis',
#   'last_updated': 1518198858,
#   'market_cap_usd': 205274434.0,
#   'max_supply': 999449694.0,
#   'name': 'Ignis',
#   'percent_change_1h': 12.06,
#   'percent_change_24h': 38.16,
#   'percent_change_7d': 0.67,
#   'price_btc': 3.096e-05,
#   'price_usd': 0.269692,
#   'rank': 91,
#   'symbol': 'IGNIS',
#   'total_supply': 999449694.0},
#  {'24h_volume_usd': 977670.0,
#   'available_supply': 454443782.0,
#   'id': 'singularitynet',
#   'last_updated': 1518198860,
#   'market_cap_usd': 204764643.0,
#   'max_supply': None,
#   'name': 'SingularityNET',
#   'percent_change_1h': 4.51,
#   'percent_change_24h': 8.16,
#   'percent_change_7d': -14.32,
#   'price_btc': 5.172e-05,
#   'price_usd': 0.450583,
#   'rank': 92,
#   'symbol': 'AGI',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 10371600.0,
#   'available_supply': 998999942.0,
#   'id': 'nxt',
#   'last_updated': 1518198841,
#   'market_cap_usd': 204263520.0,
#   'max_supply': 1000000000.0,
#   'name': 'Nxt',
#   'percent_change_1h': 5.03,
#   'percent_change_24h': 15.54,
#   'percent_change_7d': -4.67,
#   'price_btc': 2.347e-05,
#   'price_usd': 0.204468,
#   'rank': 93,
#   'symbol': 'NXT',
#   'total_supply': 998999942.0},
#  {'24h_volume_usd': 1976090.0,
#   'available_supply': 452552412.0,
#   'id': 'maidsafecoin',
#   'last_updated': 1518198842,
#   'market_cap_usd': 198089432.0,
#   'max_supply': None,
#   'name': 'MaidSafeCoin',
#   'percent_change_1h': 0.53,
#   'percent_change_24h': 6.96,
#   'percent_change_7d': 6.69,
#   'price_btc': 5.025e-05,
#   'price_usd': 0.437716,
#   'rank': 94,
#   'symbol': 'MAID',
#   'total_supply': 452552412.0},
#  {'24h_volume_usd': 6485600.0,
#   'available_supply': 641462769.0,
#   'id': 'request-network',
#   'last_updated': 1518198855,
#   'market_cap_usd': 194963628.0,
#   'max_supply': None,
#   'name': 'Request Network',
#   'percent_change_1h': 3.97,
#   'percent_change_24h': 5.9,
#   'percent_change_7d': -2.37,
#   'price_btc': 3.489e-05,
#   'price_usd': 0.303936,
#   'rank': 95,
#   'symbol': 'REQ',
#   'total_supply': 999999999.0},
#  {'24h_volume_usd': 1943520.0,
#   'available_supply': 28740055495.0,
#   'id': 'reddcoin',
#   'last_updated': 1518198841,
#   'market_cap_usd': 194935749.0,
#   'max_supply': None,
#   'name': 'ReddCoin',
#   'percent_change_1h': 4.15,
#   'percent_change_24h': 14.01,
#   'percent_change_7d': -1.18,
#   'price_btc': 7.8e-07,
#   'price_usd': 0.00678272,
#   'rank': 96,
#   'symbol': 'RDD',
#   'total_supply': 28740055495.0},
#  {'24h_volume_usd': 1575710.0,
#   'available_supply': 1000000000.0,
#   'id': 'xplay',
#   'last_updated': 1518198855,
#   'market_cap_usd': 192063000.0,
#   'max_supply': None,
#   'name': 'XPlay',
#   'percent_change_1h': 2.88,
#   'percent_change_24h': 7.36,
#   'percent_change_7d': 35.6,
#   'price_btc': 2.205e-05,
#   'price_usd': 0.192063,
#   'rank': 97,
#   'symbol': 'XPA',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 687041.0,
#   'available_supply': 55514503.0,
#   'id': 'nexus',
#   'last_updated': 1518198845,
#   'market_cap_usd': 187815555.0,
#   'max_supply': None,
#   'name': 'Nexus',
#   'percent_change_1h': 5.91,
#   'percent_change_24h': 8.2,
#   'percent_change_7d': -5.95,
#   'price_btc': 0.00038837,
#   'price_usd': 3.38318,
#   'rank': 98,
#   'symbol': 'NXS',
#   'total_supply': 55514503.0},
#  {'24h_volume_usd': 779333.0,
#   'available_supply': 213751713741,
#   'id': 'experience-points',
#   'last_updated': 1518198847,
#   'market_cap_usd': 184326225.0,
#   'max_supply': None,
#   'name': 'Experience Points',
#   'percent_change_1h': 5.98,
#   'percent_change_24h': 20.45,
#   'percent_change_7d': 68.41,
#   'price_btc': 1e-07,
#   'price_usd': 0.000862338,
#   'rank': 99,
#   'symbol': 'XP',
#   'total_supply': 248783481606},
#  {'24h_volume_usd': 3893490.0,
#   'available_supply': 104661310.0,
#   'id': 'tenx',
#   'last_updated': 1518198851,
#   'market_cap_usd': 181700407.0,
#   'max_supply': None,
#   'name': 'TenX',
#   'percent_change_1h': 2.83,
#   'percent_change_24h': 12.42,
#   'percent_change_7d': -5.43,
#   'price_btc': 0.00019929,
#   'price_usd': 1.73608,
#   'rank': 100,
#   'symbol': 'PAY',
#   'total_supply': 205218256.0},
#  {'24h_volume_usd': 1363330.0,
#   'available_supply': 99735687.0,
#   'id': 'iconomi',
#   'last_updated': 1518198848,
#   'market_cap_usd': 175112927.0,
#   'max_supply': None,
#   'name': 'Iconomi',
#   'percent_change_1h': 3.7,
#   'percent_change_24h': 11.3,
#   'percent_change_7d': -8.39,
#   'price_btc': 0.00020155,
#   'price_usd': 1.75577,
#   'rank': 101,
#   'symbol': 'ICN',
#   'total_supply': 99735687.0},
#  {'24h_volume_usd': 4069780.0,
#   'available_supply': 492954537.0,
#   'id': 'wax',
#   'last_updated': 1518198858,
#   'market_cap_usd': 167597148.0,
#   'max_supply': None,
#   'name': 'WAX',
#   'percent_change_1h': 2.91,
#   'percent_change_24h': 8.21,
#   'percent_change_7d': 2.24,
#   'price_btc': 3.903e-05,
#   'price_usd': 0.339985,
#   'rank': 102,
#   'symbol': 'WAX',
#   'total_supply': 1850000000.0},
#  {'24h_volume_usd': 13326000.0,
#   'available_supply': 342699966.0,
#   'id': 'civic',
#   'last_updated': 1518198852,
#   'market_cap_usd': 167000092.0,
#   'max_supply': None,
#   'name': 'Civic',
#   'percent_change_1h': 4.33,
#   'percent_change_24h': 3.19,
#   'percent_change_7d': 15.97,
#   'price_btc': 5.594e-05,
#   'price_usd': 0.487307,
#   'rank': 103,
#   'symbol': 'CVC',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 487057.0,
#   'available_supply': 1104590.0,
#   'id': 'gnosis-gno',
#   'last_updated': 1518198850,
#   'market_cap_usd': 161584948.0,
#   'max_supply': None,
#   'name': 'Gnosis',
#   'percent_change_1h': 3.14,
#   'percent_change_24h': 4.41,
#   'percent_change_7d': -6.14,
#   'price_btc': 0.0167925,
#   'price_usd': 146.285,
#   'rank': 104,
#   'symbol': 'GNO',
#   'total_supply': 10000000.0},
#  {'24h_volume_usd': 960224.0,
#   'available_supply': 41282364.0,
#   'id': 'emercoin',
#   'last_updated': 1518198843,
#   'market_cap_usd': 160190846.0,
#   'max_supply': None,
#   'name': 'Emercoin',
#   'percent_change_1h': 2.02,
#   'percent_change_24h': 0.81,
#   'percent_change_7d': -2.39,
#   'price_btc': 0.00044544,
#   'price_usd': 3.88037,
#   'rank': 105,
#   'symbol': 'EMC',
#   'total_supply': 41282364.0},
#  {'24h_volume_usd': 4670930.0,
#   'available_supply': 226091449.0,
#   'id': 'substratum',
#   'last_updated': 1518198855,
#   'market_cap_usd': 156906109.0,
#   'max_supply': None,
#   'name': 'Substratum',
#   'percent_change_1h': 3.69,
#   'percent_change_24h': 8.14,
#   'percent_change_7d': 8.35,
#   'price_btc': 7.967e-05,
#   'price_usd': 0.693994,
#   'rank': 106,
#   'symbol': 'SUB',
#   'total_supply': 352000000.0},
#  {'24h_volume_usd': 3441810.0,
#   'available_supply': 12801406.0,
#   'id': 'neblio',
#   'last_updated': 1518198854,
#   'market_cap_usd': 156791617.0,
#   'max_supply': None,
#   'name': 'Neblio',
#   'percent_change_1h': 3.04,
#   'percent_change_24h': 7.72,
#   'percent_change_7d': -3.19,
#   'price_btc': 0.00140598,
#   'price_usd': 12.248,
#   'rank': 107,
#   'symbol': 'NEBL',
#   'total_supply': 13547711.0},
#  {'24h_volume_usd': 2060870.0,
#   'available_supply': 64355352.0,
#   'id': 'gamecredits',
#   'last_updated': 1518198844,
#   'market_cap_usd': 156104847.0,
#   'max_supply': 84000000.0,
#   'name': 'GameCredits',
#   'percent_change_1h': 2.87,
#   'percent_change_24h': 4.29,
#   'percent_change_7d': -8.23,
#   'price_btc': 0.00027845,
#   'price_usd': 2.42567,
#   'rank': 108,
#   'symbol': 'GAME',
#   'total_supply': 64355352.0},
#  {'24h_volume_usd': 4589520.0,
#   'available_supply': 50148936.0,
#   'id': 'raiden-network-token',
#   'last_updated': 1518198857,
#   'market_cap_usd': 154577576.0,
#   'max_supply': None,
#   'name': 'Raiden Network Token',
#   'percent_change_1h': 4.36,
#   'percent_change_24h': 11.79,
#   'percent_change_7d': -0.95,
#   'price_btc': 0.00035383,
#   'price_usd': 3.08237,
#   'rank': 109,
#   'symbol': 'RDN',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 5628210.0,
#   'available_supply': 350000000.0,
#   'id': 'chainlink',
#   'last_updated': 1518198855,
#   'market_cap_usd': 154007000.0,
#   'max_supply': None,
#   'name': 'ChainLink',
#   'percent_change_1h': 3.39,
#   'percent_change_24h': 7.48,
#   'percent_change_7d': -5.14,
#   'price_btc': 5.051e-05,
#   'price_usd': 0.44002,
#   'rank': 110,
#   'symbol': 'LINK',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 2303760.0,
#   'available_supply': 42855900.0,
#   'id': 'vertcoin',
#   'last_updated': 1518198841,
#   'market_cap_usd': 144509238.0,
#   'max_supply': 84000000.0,
#   'name': 'Vertcoin',
#   'percent_change_1h': 3.26,
#   'percent_change_24h': 12.89,
#   'percent_change_7d': 10.12,
#   'price_btc': 0.00038708,
#   'price_usd': 3.37198,
#   'rank': 111,
#   'symbol': 'VTC',
#   'total_supply': 42855900.0},
#  {'24h_volume_usd': 43566.5,
#   'available_supply': 1288862.0,
#   'id': 'bitcoindark',
#   'last_updated': 1518198843,
#   'market_cap_usd': 143139745.0,
#   'max_supply': None,
#   'name': 'BitcoinDark',
#   'percent_change_1h': 3.88,
#   'percent_change_24h': 6.35,
#   'percent_change_7d': 6.19,
#   'price_btc': 0.0127488,
#   'price_usd': 111.059,
#   'rank': 112,
#   'symbol': 'BTCD',
#   'total_supply': 1288862.0},
#  {'24h_volume_usd': 7402200.0,
#   'available_supply': 22216600.0,
#   'id': 'high-performance-blockchain',
#   'last_updated': 1518198859,
#   'market_cap_usd': 142541483.0,
#   'max_supply': None,
#   'name': 'High Performance Blockchain',
#   'percent_change_1h': 3.8,
#   'percent_change_24h': 4.91,
#   'percent_change_7d': -10.03,
#   'price_btc': 0.00073651,
#   'price_usd': 6.41599,
#   'rank': 113,
#   'symbol': 'HPB',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 493741.0,
#   'available_supply': 82500000.0,
#   'id': 'paypie',
#   'last_updated': 1518198855,
#   'market_cap_usd': 142172250.0,
#   'max_supply': 165000000.0,
#   'name': 'PayPie',
#   'percent_change_1h': 14.07,
#   'percent_change_24h': 9.63,
#   'percent_change_7d': 9.64,
#   'price_btc': 0.00019782,
#   'price_usd': 1.7233,
#   'rank': 114,
#   'symbol': 'PPP',
#   'total_supply': 165000000.0},
#  {'24h_volume_usd': 1741700.0,
#   'available_supply': 2966384100.0,
#   'id': 'medibloc',
#   'last_updated': 1518198858,
#   'market_cap_usd': 141453212.0,
#   'max_supply': 10000000000.0,
#   'name': 'MediBloc',
#   'percent_change_1h': 4.72,
#   'percent_change_24h': 9.71,
#   'percent_change_7d': -7.28,
#   'price_btc': 5.47e-06,
#   'price_usd': 0.0476854,
#   'rank': 115,
#   'symbol': 'MED',
#   'total_supply': 4097545844.0},
#  {'24h_volume_usd': 277317.0,
#   'available_supply': 5007424.0,
#   'id': 'blocknet',
#   'last_updated': 1518198844,
#   'market_cap_usd': 141349560.0,
#   'max_supply': None,
#   'name': 'Blocknet',
#   'percent_change_1h': 3.77,
#   'percent_change_24h': 5.99,
#   'percent_change_7d': -2.0,
#   'price_btc': 0.00324037,
#   'price_usd': 28.228,
#   'rank': 116,
#   'symbol': 'BLOCK',
#   'total_supply': 5007424.0},
#  {'24h_volume_usd': 11633800.0,
#   'available_supply': 133425493.0,
#   'id': 'storj',
#   'last_updated': 1518198852,
#   'market_cap_usd': 138507670.0,
#   'max_supply': None,
#   'name': 'Storj',
#   'percent_change_1h': 2.5,
#   'percent_change_24h': 11.62,
#   'percent_change_7d': 5.7,
#   'price_btc': 0.00011917,
#   'price_usd': 1.03809,
#   'rank': 117,
#   'symbol': 'STORJ',
#   'total_supply': 424999998.0},
#  {'24h_volume_usd': 83066700.0,
#   'available_supply': 165000000.0,
#   'id': 'bluzelle',
#   'last_updated': 1518198860,
#   'market_cap_usd': 137712465.0,
#   'max_supply': None,
#   'name': 'Bluzelle',
#   'percent_change_1h': 3.53,
#   'percent_change_24h': 7.38,
#   'percent_change_7d': None,
#   'price_btc': 9.581e-05,
#   'price_usd': 0.834621,
#   'rank': 118,
#   'symbol': 'BLZ',
#   'total_supply': 500000000.0},
#  {'24h_volume_usd': 31055.1,
#   'available_supply': 816061.0,
#   'id': 'supernet-unity',
#   'last_updated': 1518198843,
#   'market_cap_usd': 134268112.0,
#   'max_supply': None,
#   'name': 'SuperNET',
#   'percent_change_1h': 2.03,
#   'percent_change_24h': 13.77,
#   'percent_change_7d': 52.79,
#   'price_btc': 0.0188871,
#   'price_usd': 164.532,
#   'rank': 119,
#   'symbol': 'UNITY',
#   'total_supply': 816061.0},
#  {'24h_volume_usd': 11413000.0,
#   'available_supply': 300000000.0,
#   'id': 'achain',
#   'last_updated': 1518198854,
#   'market_cap_usd': 134114700.0,
#   'max_supply': 1000000000.0,
#   'name': 'Achain',
#   'percent_change_1h': 4.96,
#   'percent_change_24h': 21.62,
#   'percent_change_7d': 16.29,
#   'price_btc': 5.132e-05,
#   'price_usd': 0.447049,
#   'rank': 120,
#   'symbol': 'ACT',
#   'total_supply': 1000000000.0},
# ...
#   'max_supply': None,
#   'name': 'Triangles',
#   'percent_change_1h': 3.85,
#   'percent_change_24h': -12.36,
#   'percent_change_7d': 2.55,
#   'price_btc': 0.00110784,
#   'price_usd': 9.65076,
#   'rank': 960,
#   'symbol': 'TRI',
#   'total_supply': 104746.0},
#  {'24h_volume_usd': 386.222,
#   'available_supply': 2136580256.0,
#   'id': 'bigup',
#   'last_updated': 1518198846,
#   'market_cap_usd': 970913.0,
#   'max_supply': None,
#   'name': 'BigUp',
#   'percent_change_1h': 3.25,
#   'percent_change_24h': 3.33,
#   'percent_change_7d': 15.35,
#   'price_btc': 5e-08,
#   'price_usd': 0.000454424,
#   'rank': 961,
#   'symbol': 'BIGUP',
#   'total_supply': 2136580256.0},
#  {'24h_volume_usd': None,
#   'available_supply': 445371.0,
#   'id': 'nimfamoney',
#   'last_updated': 1518198259,
#   'market_cap_usd': 969978.0,
#   'max_supply': None,
#   'name': 'Nimfamoney',
#   'percent_change_1h': 1.65,
#   'percent_change_24h': -4.34,
#   'percent_change_7d': -34.51,
#   'price_btc': 0.00025302,
#   'price_usd': 2.17791,
#   'rank': 962,
#   'symbol': 'NIMFA',
#   'total_supply': 1542580.0},
#  {'24h_volume_usd': 51.1139,
#   'available_supply': 24101381.0,
#   'id': 'gaia',
#   'last_updated': 1518198843,
#   'market_cap_usd': 965793.0,
#   'max_supply': None,
#   'name': 'GAIA',
#   'percent_change_1h': 3.84,
#   'percent_change_24h': 2.2,
#   'percent_change_7d': 13.29,
#   'price_btc': 4.6e-06,
#   'price_usd': 0.0400721,
#   'rank': 963,
#   'symbol': 'GAIA',
#   'total_supply': 24101381.0},
#  {'24h_volume_usd': 26.5486,
#   'available_supply': 8035193.0,
#   'id': 'woodcoin',
#   'last_updated': 1518198844,
#   'market_cap_usd': 951262.0,
#   'max_supply': None,
#   'name': 'Woodcoin',
#   'percent_change_1h': 3.89,
#   'percent_change_24h': -12.46,
#   'percent_change_7d': 1.37,
#   'price_btc': 1.359e-05,
#   'price_usd': 0.118387,
#   'rank': 964,
#   'symbol': 'LOG',
#   'total_supply': 8035193.0},
#  {'24h_volume_usd': 308.105,
#   'available_supply': 64151405.0,
#   'id': 'hobonickels',
#   'last_updated': 1518198841,
#   'market_cap_usd': 944443.0,
#   'max_supply': 120000000.0,
#   'name': 'HoboNickels',
#   'percent_change_1h': 3.84,
#   'percent_change_24h': 10.65,
#   'percent_change_7d': -14.22,
#   'price_btc': 1.69e-06,
#   'price_usd': 0.0147221,
#   'rank': 965,
#   'symbol': 'HBN',
#   'total_supply': 64151405.0},
#  {'24h_volume_usd': 44.3877,
#   'available_supply': 23079737.0,
#   'id': 'bitstar',
#   'last_updated': 1518198843,
#   'market_cap_usd': 938505.0,
#   'max_supply': None,
#   'name': 'Bitstar',
#   'percent_change_1h': 3.02,
#   'percent_change_24h': 4.33,
#   'percent_change_7d': -11.1,
#   'price_btc': 4.67e-06,
#   'price_usd': 0.0406636,
#   'rank': 966,
#   'symbol': 'BITS',
#   'total_supply': 23079737.0},
#  {'24h_volume_usd': 250.514,
#   'available_supply': 1.0,
#   'id': 'bit20',
#   'last_updated': 1518198851,
#   'market_cap_usd': 928630.0,
#   'max_supply': None,
#   'name': 'Bit20',
#   'percent_change_1h': 3.71,
#   'percent_change_24h': 9.9,
#   'percent_change_7d': 3.15,
#   'price_btc': 104.922,
#   'price_usd': 914006.0,
#   'rank': 967,
#   'symbol': 'BTWTY',
#   'total_supply': 1.0},
#  {'24h_volume_usd': 271.835,
#   'available_supply': 318929301.0,
#   'id': 'nyancoin',
#   'last_updated': 1518198841,
#   'market_cap_usd': 912167.0,
#   'max_supply': 337000000.0,
#   'name': 'Nyancoin',
#   'percent_change_1h': 10.44,
#   'percent_change_24h': 9.28,
#   'percent_change_7d': 1.04,
#   'price_btc': 3.3e-07,
#   'price_usd': 0.00286009,
#   'rank': 968,
#   'symbol': 'NYAN',
#   'total_supply': 318929301.0},
#  {'24h_volume_usd': 480.63,
#   'available_supply': 75000000.0,
#   'id': 'bitpark-coin',
#   'last_updated': 1518198848,
#   'market_cap_usd': 887033.0,
#   'max_supply': None,
#   'name': 'Bitpark Coin',
#   'percent_change_1h': 3.75,
#   'percent_change_24h': 23.95,
#   'percent_change_7d': -32.08,
#   'price_btc': 1.36e-06,
#   'price_usd': 0.0118271,
#   'rank': 969,
#   'symbol': 'BPC',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 446.356,
#   'available_supply': 50936463.0,
#   'id': 'visio',
#   'last_updated': 1518198850,
#   'market_cap_usd': 843131.0,
#   'max_supply': None,
#   'name': 'Visio',
#   'percent_change_1h': 3.86,
#   'percent_change_24h': -6.33,
#   'percent_change_7d': -16.62,
#   'price_btc': 1.9e-06,
#   'price_usd': 0.0165526,
#   'rank': 970,
#   'symbol': 'VISIO',
#   'total_supply': 62936463.0},
#  {'24h_volume_usd': 328.202,
#   'available_supply': 65290635.0,
#   'id': 'btctalkcoin',
#   'last_updated': 1518198842,
#   'market_cap_usd': 824712.0,
#   'max_supply': None,
#   'name': 'BTCtalkcoin',
#   'percent_change_1h': 3.89,
#   'percent_change_24h': 9.76,
#   'percent_change_7d': 12.97,
#   'price_btc': 1.45e-06,
#   'price_usd': 0.0126314,
#   'rank': 971,
#   'symbol': 'TALK',
#   'total_supply': 65290635.0},
#  {'24h_volume_usd': 201.583,
#   'available_supply': 9503724.0,
#   'id': 'wavesgo',
#   'last_updated': 1518198850,
#   'market_cap_usd': 822526.0,
#   'max_supply': None,
#   'name': 'WavesGo',
#   'percent_change_1h': 3.98,
#   'percent_change_24h': 12.15,
#   'percent_change_7d': -7.93,
#   'price_btc': 9.94e-06,
#   'price_usd': 0.0865478,
#   'rank': 972,
#   'symbol': 'WGO',
#   'total_supply': 9503724.0},
#  {'24h_volume_usd': None,
#   'available_supply': 23020335.0,
#   'id': 'janus',
#   'last_updated': 1517536153,
#   'market_cap_usd': 744390.0,
#   'max_supply': None,
#   'name': 'Janus',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': None,
#   'price_btc': 3.72e-06,
#   'price_usd': 0.0323362,
#   'rank': 973,
#   'symbol': 'JNS',
#   'total_supply': 25201489.0},
#  {'24h_volume_usd': 484.554,
#   'available_supply': 61445805.0,
#   'id': 'maxcoin',
#   'last_updated': 1518198841,
#   'market_cap_usd': 722621.0,
#   'max_supply': None,
#   'name': 'MaxCoin',
#   'percent_change_1h': 3.89,
#   'percent_change_24h': 3.97,
#   'percent_change_7d': 5.46,
#   'price_btc': 1.35e-06,
#   'price_usd': 0.0117603,
#   'rank': 974,
#   'symbol': 'MAX',
#   'total_supply': 61445805.0},
#  {'24h_volume_usd': 4.34765,
#   'available_supply': 1990891.0,
#   'id': 'bitz',
#   'last_updated': 1518198844,
#   'market_cap_usd': 693732.0,
#   'max_supply': None,
#   'name': 'Bitz',
#   'percent_change_1h': 3.89,
#   'percent_change_24h': None,
#   'percent_change_7d': -11.2,
#   'price_btc': 4e-05,
#   'price_usd': 0.348453,
#   'rank': 975,
#   'symbol': 'BITZ',
#   'total_supply': 1990891.0},
#  {'24h_volume_usd': 226.278,
#   'available_supply': 196336.0,
#   'id': 'prototanium',
#   'last_updated': 1518198846,
#   'market_cap_usd': 684139.0,
#   'max_supply': None,
#   'name': 'Prototanium',
#   'percent_change_1h': 3.84,
#   'percent_change_24h': -0.86,
#   'percent_change_7d': -4.23,
#   'price_btc': 0.0004,
#   'price_usd': 3.48453,
#   'rank': 976,
#   'symbol': 'PR',
#   'total_supply': 196336.0},
#  {'24h_volume_usd': 193.956,
#   'available_supply': 353634.0,
#   'id': 'swagbucks',
#   'last_updated': 1518198846,
#   'market_cap_usd': 665323.0,
#   'max_supply': None,
#   'name': 'SwagBucks',
#   'percent_change_1h': 3.92,
#   'percent_change_24h': 6.12,
#   'percent_change_7d': -6.3,
#   'price_btc': 0.00021597,
#   'price_usd': 1.88139,
#   'rank': 977,
#   'symbol': 'BUCKS',
#   'total_supply': 353634.0},
#  {'24h_volume_usd': 209.45,
#   'available_supply': 21268092.0,
#   'id': 'britcoin',
#   'last_updated': 1518198843,
#   'market_cap_usd': 657273.0,
#   'max_supply': None,
#   'name': 'BritCoin',
#   'percent_change_1h': 3.84,
#   'percent_change_24h': 0.83,
#   'percent_change_7d': 8.73,
#   'price_btc': 3.55e-06,
#   'price_usd': 0.0309042,
#   'rank': 978,
#   'symbol': 'BRIT',
#   'total_supply': 21268092.0},
#  {'24h_volume_usd': 393.656,
#   'available_supply': 169197348.0,
#   'id': 'truckcoin',
#   'last_updated': 1518198843,
#   'market_cap_usd': 648530.0,
#   'max_supply': None,
#   'name': 'Truckcoin',
#   'percent_change_1h': 1.86,
#   'percent_change_24h': 19.91,
#   'percent_change_7d': -2.4,
#   'price_btc': 4.4e-07,
#   'price_usd': 0.00383298,
#   'rank': 979,
#   'symbol': 'TRK',
#   'total_supply': 169197348.0},
#  {'24h_volume_usd': 260.274,
#   'available_supply': 18697068.0,
#   'id': 'motocoin',
#   'last_updated': 1518198843,
#   'market_cap_usd': 644991.0,
#   'max_supply': None,
#   'name': 'Motocoin',
#   'percent_change_1h': 3.84,
#   'percent_change_24h': 14.85,
#   'percent_change_7d': -15.11,
#   'price_btc': 3.96e-06,
#   'price_usd': 0.0344969,
#   'rank': 980,
#   'symbol': 'MOTO',
#   'total_supply': 31227698.0},
#  {'24h_volume_usd': 133.571,
#   'available_supply': 107972766.0,
#   'id': 'signatum',
#   'last_updated': 1518198852,
#   'market_cap_usd': 639598.0,
#   'max_supply': None,
#   'name': 'Signatum',
#   'percent_change_1h': 3.89,
#   'percent_change_24h': 9.6,
#   'percent_change_7d': -6.31,
#   'price_btc': 6.8e-07,
#   'price_usd': 0.0059237,
#   'rank': 981,
#   'symbol': 'SIGT',
#   'total_supply': 107972766.0},
#  {'24h_volume_usd': 113.995,
#   'available_supply': 77777777.0,
#   'id': 'ammo-rewards',
#   'last_updated': 1518198850,
#   'market_cap_usd': 616569.0,
#   'max_supply': None,
#   'name': 'Ammo Reloaded',
#   'percent_change_1h': 3.89,
#   'percent_change_24h': 5.7,
#   'percent_change_7d': -9.39,
#   'price_btc': 9.1e-07,
#   'price_usd': 0.00792731,
#   'rank': 982,
#   'symbol': 'AMMO',
#   'total_supply': 77777777.0},
#  {'24h_volume_usd': 3.82828,
#   'available_supply': 2358819009.0,
#   'id': 'colossuscoin-v2',
#   'last_updated': 1518198844,
#   'market_cap_usd': 616454.0,
#   'max_supply': None,
#   'name': 'Colossuscoin V2',
#   'percent_change_1h': 3.84,
#   'percent_change_24h': 59.42,
#   'percent_change_7d': 51.16,
#   'price_btc': 3e-08,
#   'price_usd': 0.00026134,
#   'rank': 983,
#   'symbol': 'CV2',
#   'total_supply': 22977351798.0},
#  {'24h_volume_usd': 405.161,
#   'available_supply': 868077.0,
#   'id': 'litebar',
#   'last_updated': 1518198841,
#   'market_cap_usd': 615934.0,
#   'max_supply': None,
#   'name': 'LiteBar',
#   'percent_change_1h': 7.06,
#   'percent_change_24h': 9.17,
#   'percent_change_7d': 18.11,
#   'price_btc': 8.145e-05,
#   'price_usd': 0.709538,
#   'rank': 984,
#   'symbol': 'LTB',
#   'total_supply': 868077.0},
#  {'24h_volume_usd': 56.769,
#   'available_supply': 169598616.0,
#   'id': 'bitcurrency',
#   'last_updated': 1518198848,
#   'market_cap_usd': 605745.0,
#   'max_supply': None,
#   'name': 'Bitcurrency',
#   'percent_change_1h': 3.84,
#   'percent_change_24h': 6.28,
#   'percent_change_7d': -47.92,
#   'price_btc': 4.1e-07,
#   'price_usd': 0.00357164,
#   'rank': 985,
#   'symbol': 'BTCR',
#   'total_supply': 169598616.0},
#  {'24h_volume_usd': 183.324,
#   'available_supply': 9436367.0,
#   'id': 'mineum',
#   'last_updated': 1518198847,
#   'market_cap_usd': 601680.0,
#   'max_supply': None,
#   'name': 'Mineum',
#   'percent_change_1h': 5.25,
#   'percent_change_24h': -12.42,
#   'percent_change_7d': 14.51,
#   'price_btc': 7.32e-06,
#   'price_usd': 0.0637618,
#   'rank': 986,
#   'symbol': 'MNM',
#   'total_supply': 9586367.0},
#  {'24h_volume_usd': 1.28928,
#   'available_supply': 90421856.0,
#   'id': 'tattoocoin',
#   'last_updated': 1518198849,
#   'market_cap_usd': 582894.0,
#   'max_supply': None,
#   'name': 'Tattoocoin (Standard Edition)',
#   'percent_change_1h': 3.84,
#   'percent_change_24h': 1.34,
#   'percent_change_7d': -1.88,
#   'price_btc': 7.4e-07,
#   'price_usd': 0.00644638,
#   'rank': 987,
#   'symbol': 'TSE',
#   'total_supply': 90421856.0},
#  {'24h_volume_usd': 8.71133,
#   'available_supply': 6097652084.0,
#   'id': 'valorbit',
#   'last_updated': 1518198846,
#   'market_cap_usd': 531187.0,
#   'max_supply': None,
#   'name': 'Valorbit',
#   'percent_change_1h': 3.89,
#   'percent_change_24h': 6.28,
#   'percent_change_7d': 0.77,
#   'price_btc': 1e-08,
#   'price_usd': 8.71133e-05,
#   'rank': 988,
#   'symbol': 'VAL',
#   'total_supply': 922343297652084},
#  {'24h_volume_usd': 88.1515,
#   'available_supply': 5428300.0,
#   'id': 'blockpay',
#   'last_updated': 1518198848,
#   'market_cap_usd': 516521.0,
#   'max_supply': None,
#   'name': 'BlockPay',
#   'percent_change_1h': 2.78,
#   'percent_change_24h': 7.41,
#   'percent_change_7d': -23.98,
#   'price_btc': 1.092e-05,
#   'price_usd': 0.0951534,
#   'rank': 989,
#   'symbol': 'BLOCKPAY',
#   'total_supply': 98928316.0},
#  {'24h_volume_usd': 285.705,
#   'available_supply': 590751.0,
#   'id': 'zozocoin',
#   'last_updated': 1518198857,
#   'market_cap_usd': 514623.0,
#   'max_supply': 27000000.0,
#   'name': 'ZoZoCoin',
#   'percent_change_1h': 3.89,
#   'percent_change_24h': 5.1,
#   'percent_change_7d': -5.78,
#   'price_btc': 0.0001,
#   'price_usd': 0.871133,
#   'rank': 990,
#   'symbol': 'ZZC',
#   'total_supply': 7296311.0},
#  {'24h_volume_usd': 365.608,
#   'available_supply': 7089143.0,
#   'id': 'sativacoin',
#   'last_updated': 1518198844,
#   'market_cap_usd': 504027.0,
#   'max_supply': None,
#   'name': 'Sativacoin',
#   'percent_change_1h': 8.43,
#   'percent_change_24h': 6.3,
#   'percent_change_7d': -0.2,
#   'price_btc': 8.16e-06,
#   'price_usd': 0.0710985,
#   'rank': 991,
#   'symbol': 'STV',
#   'total_supply': 7089143.0},
#  {'24h_volume_usd': 237.197,
#   'available_supply': 43536800.0,
#   'id': 'tigercoin',
#   'last_updated': 1518198841,
#   'market_cap_usd': 500630.0,
#   'max_supply': None,
#   'name': 'Tigercoin',
#   'percent_change_1h': 4.07,
#   'percent_change_24h': 7.06,
#   'percent_change_7d': -23.33,
#   'price_btc': 1.32e-06,
#   'price_usd': 0.011499,
#   'rank': 992,
#   'symbol': 'TGC',
#   'total_supply': 43536800.0},
#  {'24h_volume_usd': 15.9524,
#   'available_supply': 21948.0,
#   'id': 'bitsilver',
#   'last_updated': 1518198844,
#   'market_cap_usd': 500142.0,
#   'max_supply': None,
#   'name': 'bitSilver',
#   'percent_change_1h': 0.3,
#   'percent_change_24h': 25.58,
#   'percent_change_7d': 21.94,
#   'price_btc': 0.00261587,
#   'price_usd': 22.7877,
#   'rank': 993,
#   'symbol': 'BITSILVER',
#   'total_supply': 21948.0},
#  {'24h_volume_usd': 34.5504,
#   'available_supply': 65171010.0,
#   'id': 'globalcoin',
#   'last_updated': 1518198841,
#   'market_cap_usd': 499599.0,
#   'max_supply': None,
#   'name': 'GlobalCoin',
#   'percent_change_1h': 3.84,
#   'percent_change_24h': 34.93,
#   'percent_change_7d': -0.47,
#   'price_btc': 8.8e-07,
#   'price_usd': 0.00766597,
#   'rank': 994,
#   'symbol': 'GLC',
#   'total_supply': 65171010.0},
#  {'24h_volume_usd': 181.522,
#   'available_supply': 210806.0,
#   'id': 'flycoin',
#   'last_updated': 1518198859,
#   'market_cap_usd': 495846.0,
#   'max_supply': None,
#   'name': 'Flycoin',
#   'percent_change_1h': -19.58,
#   'percent_change_24h': 8.07,
#   'percent_change_7d': -22.26,
#   'price_btc': 0.00027001,
#   'price_usd': 2.35215,
#   'rank': 995,
#   'symbol': 'FLY',
#   'total_supply': 210806.0},
#  {'24h_volume_usd': 363.921,
#   'available_supply': 9497141.0,
#   'id': 'bitquark',
#   'last_updated': 1518198843,
#   'market_cap_usd': 491432.0,
#   'max_supply': None,
#   'name': 'BitQuark',
#   'percent_change_1h': 68.07,
#   'percent_change_24h': 71.09,
#   'percent_change_7d': -32.99,
#   'price_btc': 5.94e-06,
#   'price_usd': 0.0517453,
#   'rank': 996,
#   'symbol': 'BTQ',
#   'total_supply': 9497141.0},
#  {'24h_volume_usd': 425.712,
#   'available_supply': 73729962.0,
#   'id': 'chronos',
#   'last_updated': 1518198847,
#   'market_cap_usd': 481631.0,
#   'max_supply': None,
#   'name': 'Chronos',
#   'percent_change_1h': 0.18,
#   'percent_change_24h': 14.6,
#   'percent_change_7d': -14.6,
#   'price_btc': 7.5e-07,
#   'price_usd': 0.00653237,
#   'rank': 997,
#   'symbol': 'CRX',
#   'total_supply': 73729962.0},
#  {'24h_volume_usd': 67.2608,
#   'available_supply': 10291781.0,
#   'id': 'bankcoin',
#   'last_updated': 1518198849,
#   'market_cap_usd': 478001.0,
#   'max_supply': None,
#   'name': 'Bankcoin',
#   'percent_change_1h': 4.1,
#   'percent_change_24h': 58.17,
#   'percent_change_7d': None,
#   'price_btc': 5.33e-06,
#   'price_usd': 0.0464449,
#   'rank': 998,
#   'symbol': 'B@',
#   'total_supply': 25000000.0},
#  {'24h_volume_usd': 22.7146,
#   'available_supply': 3052062.0,
#   'id': 'joincoin',
#   'last_updated': 1518198843,
#   'market_cap_usd': 452254.0,
#   'max_supply': None,
#   'name': 'Joincoin',
#   'percent_change_1h': 3.89,
#   'percent_change_24h': 9.5,
#   'percent_change_7d': -1.78,
#   'price_btc': 1.701e-05,
#   'price_usd': 0.14818,
#   'rank': 999,
#   'symbol': 'J',
#   'total_supply': 3052062.0},
#  {'24h_volume_usd': 411.14,
#   'available_supply': 12481447.0,
#   'id': 'gapcoin',
#   'last_updated': 1518198843,
#   'market_cap_usd': 444705.0,
#   'max_supply': None,
#   'name': 'Gapcoin',
#   'percent_change_1h': 3.89,
#   'percent_change_24h': 3.7,
#   'percent_change_7d': -0.57,
#   'price_btc': 4.09e-06,
#   'price_usd': 0.0356293,
#   'rank': 1000,
#   'symbol': 'GAP',
#   'total_supply': 12481447.0},
#  ...]

# %% [markdown]
# You can pass a currency through symbol or coin slug:

# %%
data_from_symbol = cmc.ticker("BTC")
data_from_slug = cmc.ticker("bitcoin")

data_from_slug
# Out:
# {'24h_volume_usd': 8305260000.0,
#  'available_supply': 16855000.0,
#  'id': 'bitcoin',
#  'last_updated': 1518198868,
#  'market_cap_usd': 145979300950,
#  'max_supply': 21000000.0,
#  'name': 'Bitcoin',
#  'percent_change_1h': 2.66,
#  'percent_change_24h': 5.59,
#  'percent_change_7d': 0.12,
#  'price_btc': 1.0,
#  'price_usd': 8660.89,
#  'rank': 1,
#  'symbol': 'BTC',
#  'total_supply': 16855000.0}

# %% [markdown]
# To get all symbols and slugs you can use the next attributes:

# %%
all_symbols = cmc.symbols
all_slugs = cmc.coins

all_symbols
# Out:
# ['VRS',
#  'POT',
#  'PRN',
#  'TLE',
#  'BTB',
#  'BPC',
#  'KRONE',
#  'FUZZ',
#  'AC',
#  'SEQ',
#  'XSH',
#  'SANDG',
#  'SND',
#  'NTO',
#  'CRED',
#  'STC',
#  'ZYD',
#  'DGC',
#  'XCO',
#  'PST',
#  'DCRE',
#  'BTM',
#  'VIB',
#  'QTUM',
#  'AIB',
#  'LDCN',
#  'SIGMA',
#  'EOS',
#  'DBG',
#  'FRCT',
#  'SALT',
#  'MST',
#  'SIFT',
#  'SUPER',
#  'CAN',
#  'VISIO',
#  'KMD',
#  'TRC',
#  'GMX',
#  'MOF',
#  'PASC',
#  'OK',
#  'SCS',
#  'DOPE',
#  'STRAT',
#  'HPB',
#  'IDXM',
#  'OCL',
#  'UBQ',
#  'ULA',
#  'CC',
#  'GCN',
#  'TODAY',
#  'EUSD',
#  'LLT',
#  'MOBI',
#  'REAL',
#  'BITS',
#  'MZC',
#  'WISH',
#  'DIVX',
#  'OAX',
#  'VLC',
#  'MLN',
#  'ACT',
#  'DRT',
#  'MOJO',
#  'UNIFY',
#  'DFS',
#  'ELF',
#  'ECA',
#  'SPACE',
#  'DTR',
#  'INDIA',
#  'MBL',
#  'KED',
#  'STEX',
#  'XMR',
#  'GB',
#  'TCT',
#  'TCOIN',
#  'BLK',
#  'ATB',
#  'TRST',
#  'OTN',
#  'STN',
#  'ONION',
#  'OS76',
#  'KBR',
#  'SBD',
#  'PXI',
#  'INSN',
#  'UIS',
#  'ICOS',
#  'XAUR',
#  'HALLO',
#  'VIBE',
#  'KB3',
#  'SUMO',
#  'IFT',
#  'CDN',
#  'EGO',
#  'DSR',
#  'EFL',
#  'BENJI',
#  'STU',
#  'VASH',
#  'CDX',
#  'MONA',
#  'PZM',
#  'SNC',
#  'SNT',
#  'TRCT',
#  'ONG',
#  'FRK',
#  'FYP',
#  'STA',
#  'KLC',
#  'CHIPS',
#  'AIT',
#  'CVCOIN',
#  'XEM',
#  'FCT',
#  'SHA',
#  'CF',
#  'GAS',
#  'RDD',
#  'BMC',
#  'WTC',
#  'APX',
#  'IDH',
#  'ETN',
#  'BSTY',
#  'TOPAZ',
#  'GP',
#  'INFX',
#  'ITT',
#  'EXCL',
#  'EVR',
#  'JET',
#  'DRXNE',
#  'FC',
#  'HVN',
#  'EBT',
#  'SJCX',
#  'PCN',
#  'DES',
#  'XVC',
#  'XRB',
#  'UGC',
#  'VRC',
#  'SIB',
#  'ANT',
#  'DMB',
#  'XGOX',
#  'ATS',
#  'HAT',
#  'QSP',
#  'HEAT',
#  'LUNA',
#  'WAVES',
#  'SAC',
#  'PFR',
#  'DUB',
#  'BTCM',
#  'SOCC',
#  'BRX',
#  'MEME',
#  'STAK',
#  'SIGT',
#  'AUR',
#  'WABI',
#  'BTCRED',
#  'SEXC',
#  'NANOX',
#  'BTX',
#  'SXUT',
#  'OBITS',
#  'ZIL',
#  'RPX',
#  'EREAL',
#  'HPC',
#  'XRE',
#  'QUBE',
#  'POLL',
#  'SWP',
#  'DAV',
#  'MEC',
#  'VOT',
#  'ADB',
#  'AIX',
#  'WOW',
#  'JIN',
#  'ANTI',
#  'EXRN',
#  'GAIA',
#  'ELLA',
#  'ETT',
#  'WINGS',
#  'POE',
#  'IXC',
#  'LNK',
#  'BRAIN',
#  'DYN',
#  'POLY',
#  'BUN',
#  'AI',
#  'CON',
#  'MDC',
#  'DUO',
#  'PONZI',
#  'UNRC',
#  'CASH',
#  'I0C',
#  'CAPP',
#  'WDC',
#  'PBL',
#  'GCC',
#  'HDLB',
#  'AGRS',
#  'ZENGOLD',
#  'LTCR',
#  'GBG',
#  'PIGGY',
#  'PCS',
#  'HPY',
#  'PKB',
#  'LINX',
#  'FLT',
#  'XAU',
#  'SBTC',
#  'OMG',
#  'NKA',
#  'PHR',
#  'OF',
#  'GUN',
#  'ZEC',
#  'RUPX',
#  'BTO',
#  'ART',
#  'CV',
#  'BLUE',
#  'QAU',
#  'TMC',
#  'NUMUS',
#  'MND',
#  'KCS',
#  'VSL',
#  'OPC',
#  'RCN',
#  'WSX',
#  'DDF',
#  'ZPT',
#  'NRO',
#  'NEOS',
#  'UGT',
#  'TOA',
#  'DENT',
#  'CRT',
#  'MOAC',
#  'SNM',
#  'BTA',
#  'REGA',
#  'ZZC',
#  'BYC',
#  'LIFE',
#  'RUSTBITS',
#  'FCN',
#  'CFC',
#  'DFT',
#  'PAYP',
#  'BAC',
#  'CTIC3',
#  'XPY',
#  'GEERT',
#  'JWL',
#  'NAS',
#  'CALC',
#  '808',
#  'ICOO',
#  'QORA',
#  'MVC',
#  '42',
#  'BUMBA',
#  'PDC',
#  'BLN',
#  'BERN',
#  'MNC',
#  'BITCF',
#  'CTX',
#  'SGR',
#  'HODL',
#  'NOTE',
#  'RBBT',
#  'PX',
#  'BLITZ',
#  'MGO',
#  'SPHTX',
#  'SOAR',
#  'EQT',
#  'PSY',
#  'CYC',
#  'LKK',
#  'EQL',
#  'SKIN',
#  'CHESS',
#  'TROLL',
#  'SLS',
#  'WGR',
#  'PIX',
#  'ADX',
#  'MDA',
#  'IOP',
#  'BITCNY',
#  '2GIVE',
#  'DOT',
#  'UFR',
#  'DRM',
#  'LRC',
#  'PDG',
#  'HBC',
#  'EBCH',
#  'RAIN',
#  'BIOS',
#  'ADL',
#  'OST',
#  'ICX',
#  'BOT',
#  'ELTCOIN',
#  'NAV',
#  'PIPL',
#  'DON',
#  'TRICK',
#  'CDT',
#  'CRB',
#  'ALIS',
#  'XPM',
#  'IBTC',
#  'NETKO',
#  'START',
#  'BSC',
#  'LSK',
#  'NAMO',
#  'CLAM',
#  'TAG',
#  'EBST',
#  'RBY',
#  'HAC',
#  'IC',
#  'EDG',
#  'CNT',
#  'ALL',
#  'MTH',
#  'BCH',
#  'TIX',
#  'APC',
#  'OCN',
#  'FLIXX',
#  'MTX',
#  'WAND',
#  'NTWK',
#  'JOBS',
#  'REQ',
#  'MTLMC3',
#  'RNS',
#  'SRC',
#  'NEO',
#  'XSPEC',
#  'NBIT',
#  'SBC',
#  'FONZ',
#  'TEK',
#  'TYCHO',
#  'IMPS',
#  'VTA',
#  'FRST',
#  'URO',
#  'BTW',
#  'POLIS',
#  'CWXT',
#  'BTBc',
#  '1337',
#  'TIT',
#  'IMS',
#  'XQN',
#  'KEK',
#  'METAL',
#  'MONK',
#  'MCAP',
#  'DDD',
#  'CJ',
#  'VOYA',
#  'IXT',
#  'GBC',
#  'WGO',
#  'PNX',
#  'GIM',
#  'RIDE',
#  'DAT',
#  'PIE',
#  'AMP',
#  'YOC',
#  'VTC',
#  'PPP',
#  'ARGUS',
#  'EVE',
#  'GSR',
#  'HMQ',
#  'ABJ',
#  'ELC',
#  'BLOCKPAY',
#  'USDT',
#  'CTO',
#  'MED',
#  'IMX',
#  'TOKC',
#  'BBP',
#  'XPD',
#  'SCORE',
#  'BOLI',
#  'XRC',
#  'MAGN',
#  'ENRG',
#  'URC',
#  'LEA',
#  'EVIL',
#  'AVT',
#  'LET',
#  'DRGN',
#  'CCN',
#  'MUE',
#  'UR',
#  'MSD',
#  'STORJ',
#  'MRT',
#  'YAC',
#  'EMD',
#  'YTN',
#  'ERC20',
#  'CURE',
#  'FIL',
#  'CONX',
#  'IPL',
#  'AXIOM',
#  'MIOTA',
#  'XVE',
#  'GOLF',
#  'HBN',
#  'TIME',
#  'WA',
#  'XTO',
#  'XMY',
#  'SOJ',
#  'ORME',
#  'NLG',
#  'EDR',
#  'MYST',
#  'FUN',
#  'MOT',
#  'SLR',
#  'DUBI',
#  'BLX',
#  'CESC',
#  'XOT',
#  'CME',
#  'STORM',
#  'RDN',
#  'ARCO',
#  'GARY',
#  'CREDO',
#  'CHAT',
#  'IOC',
#  'DEM',
#  'UQC',
#  'DAR',
#  'MER',
#  'ANC',
#  'MKR',
#  'DSH',
#  'BT2',
#  'PEX',
#  'DRPU',
#  'XTD',
#  'IFLT',
#  'SNRG',
#  'NYC',
#  'ZCL',
#  'DBTC',
#  'ICOB',
#  'PLU',
#  'GRID',
#  'SOIL',
#  'CFT',
#  'FIMK',
#  'FRGC',
#  'XBTC21',
#  'XUC',
#  'BITGOLD',
#  'APPC',
#  'XPTX',
#  'TRF',
#  'SCRT',
#  'SFE',
#  'PRO',
#  'BCC',
#  'FYN',
#  'PLNC',
#  'TGC',
#  'FRD',
#  'PARETO',
#  'QRK',
#  'SONG',
#  'FLY',
#  'UIP',
#  'PHS',
#  'INN',
#  'XNN',
#  'NIMFA',
#  'ODN',
#  'RNT',
#  'BBR',
#  'MEN',
#  'UET',
#  'HMP',
#  'HTML',
#  'YEE',
#  'SWFTC',
#  'IPC',
#  'XDE2',
#  'NMS',
#  'NKC',
#  'BKX',
#  'XIOS',
#  'UNITS',
#  'B@',
#  'WCT',
#  'EDT',
#  'ELITE',
#  'ETC',
#  'COXST',
#  'MAID',
#  'WORM',
#  'X2',
#  'ING',
#  'PART',
#  'KUSH',
#  'DGCS',
#  'RBX',
#  'BAS',
#  'ETBS',
#  'REP',
#  'ACOIN',
#  'UBTC',
#  'SLG',
#  'VIDZ',
#  'HTC',
#  'GPL',
#  'RADS',
#  'EOT',
#  'MBI',
#  'FUEL',
#  'GNX',
#  'UNY',
#  'OMNI',
#  'UTT',
#  'IGNIS',
#  'AIDOC',
#  'RYZ',
#  'YEL',
#  'MAN',
#  'RICHX',
#  'ENG',
#  'DAXX',
#  'BCAP',
#  'EPC',
#  'MGM',
#  'BOS',
#  'TEAM',
#  'HORSE',
#  'HUSH',
#  'VTR',
#  'UNITY',
#  'TAGR',
#  'INXT',
#  'BNT',
#  'CRDNC',
#  'BIGUP',
#  'FOTA',
#  'GOOD',
#  'OC',
#  'EMC',
#  'ABN',
#  'DISK',
#  'JINN',
#  'ELS',
#  'THC',
#  'SYS',
#  'GCS',
#  'FLAP',
#  'DRP',
#  'XBC',
#  'SMT',
#  'MAX',
#  'ANI',
#  'BLAS',
#  'GAT',
#  'BRO',
#  'BAT',
#  'EKT',
#  'CHEAP',
#  'BRAT',
#  'POST',
#  'HIGH',
#  'ACE',
#  'ENJ',
#  'RLT',
#  'MINEX',
#  'CPN',
#  'DIM',
#  'ITI',
#  'VPRC',
#  'DRS',
#  'ABC',
#  'Q2C',
#  'C2',
#  'DP',
#  'SKY',
#  'XRA',
#  'EAGLE',
#  'LOG',
#  'MARS',
#  'XST',
#  'MRJA',
#  'GTC',
#  'ION',
#  'ADST',
#  'NGC',
#  'EGC',
#  'NXC',
#  'PRG',
#  'NTC',
#  'TX',
#  'WOMEN',
#  'BITSILVER',
#  'LTCU',
#  'BNTY',
#  'LCP',
#  'MCI',
#  'TKN',
#  'PRA',
#  'SMS',
#  'UNI',
#  'B2X',
#  'ROC',
#  'AURA',
#  'BBT',
#  'READ',
#  'GAP',
#  'FNC',
#  'VULC',
#  'BSN',
#  'OPT',
#  'ROOFS',
#  'SPANK',
#  'XCN',
#  'TIO',
#  'BTPL',
#  'EXP',
#  'SAK',
#  'NMR',
#  'HNC',
#  'BITEUR',
#  'GRIM',
#  'TRAC',
#  'LBC',
#  'RED',
#  '8BIT',
#  'XBL',
#  'TER',
#  'STEEM',
#  '611',
#  'BASH',
#  'QRL',
#  'NOX',
#  'UNIT',
#  'SLFI',
#  'BLU',
#  'ELA',
#  'CANN',
#  'G3N',
#  'ASAFE2',
#  'KASHH',
#  'TIPS',
#  'ZENI',
#  'QBIC',
#  'PYLNT',
#  'BSTAR',
#  'ASN',
#  'GRWI',
#  'ACES',
#  'ARC',
#  'CXT',
#  'XVG',
#  'PURA',
#  'HONEY',
#  'PUT',
#  'PRIMU',
#  'BCPT',
#  'CBX',
#  'GLT',
#  'BTCZ',
#  'DNT',
#  'IOST',
#  'CHAN',
#  'BAY',
#  'MGC',
#  'MCO',
#  'PLACO',
#  'MXT',
#  'MAD',
#  'C20',
#  'TSL',
#  'IFC',
#  '1ST',
#  'ITNS',
#  'COFI',
#  'TBX',
#  'QUN',
#  'DASHS',
#  'PASL',
#  'TRUMP',
#  'LTC',
#  'ATM',
#  'DBIX',
#  'CMT',
#  'ADCN',
#  'PAC',
#  'HKN',
#  'DNR',
#  'LOC',
#  'UNC',
#  'PTOY',
#  'EVO',
#  'BTCS',
#  'NVC',
#  'BITB',
#  'WINK',
#  'BLOCK',
#  'TAAS',
#  'HOLD',
#  'BOAT',
#  'SPHR',
#  'BELA',
#  'DATA',
#  'KDC',
#  'VSX',
#  'PPY',
#  'ABY',
#  'SWING',
#  'POP',
#  'RSGP',
#  'ECASH',
#  'PXS',
#  'FUTC',
#  'BCX',
#  'BURST',
#  'TSTR',
#  'KNC',
#  'CV2',
#  'KLN',
#  'BITOK',
#  'GAM',
#  'SENSE',
#  'AU',
#  'XRY',
#  'VRM',
#  'WC',
#  'FLDC',
#  'CTR',
#  'REF',
#  'RHOC',
#  'XLR',
#  'MDS',
#  'CPAY',
#  'CTIC2',
#  'LIGHT',
#  'XRL',
#  'GOD',
#  'LUN',
#  'TTC',
#  'FUCK',
#  'AHT',
#  'AV',
#  'SUB',
#  'EGG',
#  'XCXT',
#  'CXO',
#  'TRK',
#  'SKR',
#  'COSS',
#  'BTCR',
#  'FLASH',
#  'EAG',
#  'BNX',
#  'EL',
#  'WILD',
#  'GTO',
#  'BUB',
#  'NUKO',
#  'MOD',
#  'HOT',
#  'GJC',
#  'KCASH',
#  'HXX',
#  'ORB',
#  'PKT',
#  'TEL',
#  'ETHOS',
#  'VAL',
#  'SHOW',
#  'KZC',
#  'CRX',
#  'EMV',
#  'KAYI',
#  'SAN',
#  'PURE',
#  'CRW',
#  'PR',
#  'LKC',
#  'XTZ',
#  'COVAL',
#  'FRC',
#  'CFI',
#  'JIYO',
#  'TCR',
#  'PRM',
#  'ZSC',
#  'CLOAK',
#  'ZLA',
#  'BTQ',
#  'SPK',
#  'FAZZ',
#  'EFYT',
#  'IETH',
#  'KEY',
#  'CND',
#  'ARG',
#  'SHORTY',
#  'ADA',
#  'TKS',
#  'GCR',
#  'AE',
#  'VOISE',
#  'ECOB',
#  'ELE',
#  'XCT',
#  'KIN',
#  'PAK',
#  'AEON',
#  'NEVA',
#  'DTA',
#  'SHND',
#  'REBL',
#  'BTE',
#  'IVZ',
#  'FID',
#  'SNAKE',
#  'VOX',
#  'MAR',
#  'SOC',
#  'AIR',
#  'TALK',
#  'SXDT',
#  'HERO',
#  'PCOIN',
#  'BLRY',
#  'R',
#  'EVC',
#  'TNC',
#  'BPT',
#  'GLD',
#  'EPY',
#  'KARMA',
#  'ECC',
#  'JNS',
#  'XCRE',
#  'XMRG',
#  'CNNC',
#  'SDP',
#  'HSR',
#  'GPU',
#  'GVT',
#  'ACC',
#  'DLISK',
#  'XRP',
#  'JNT',
#  'CPC',
#  'SPORT',
#  'EXN',
#  'TCC',
#  'ATN',
#  'WETH',
#  'PLBT',
#  'MTN',
#  'ZER',
#  'STAR',
#  'DGPT',
#  'LA',
#  'PPC',
#  'ARB',
#  'HBT',
#  'AXP',
#  'TOP',
#  'TNB',
#  'MAC',
#  'NEU',
#  'DIBC',
#  'UKG',
#  'TRIA',
#  'XMCC',
#  'LTH',
#  'HC',
#  'VZT',
#  'NEOG',
#  'IND',
#  'CAT',
#  'DOGE',
#  'DALC',
#  'NDC',
#  'EMC2',
#  'LMC',
#  'INF',
#  'CHC',
#  'NIO',
#  'WAX',
#  'XCS',
#  'SCT',
#  'BTDX',
#  '300',
#  'ADK',
#  'BUCKS',
#  'ALT',
#  'BTCD',
#  'RC',
#  'PLC',
#  'EBET',
#  'LTB',
#  'INS',
#  'PRX',
#  'ETHD',
#  'PHO',
#  'XNG',
#  'ETP',
#  'NLC2',
#  'GBX',
#  'LIR',
#  'CFD',
#  'POSW',
#  'MTL',
#  'DGD',
#  'BIG',
#  'GNO',
#  'CRC',
#  'COUPE',
#  'LGD',
#  'PRC',
#  'GBYTE',
#  'RIYA',
#  'BON',
#  'SPEX',
#  'COAL',
#  'HTML5',
#  'ERC',
#  'TSE',
#  'GRC',
#  'RKC',
#  'GNT',
#  'NODC',
#  'CREVA',
#  'CRTM',
#  'BPL',
#  'BTC',
#  'SWT',
#  'BLAZR',
#  'SH',
#  '10MT',
#  'HST',
#  'LANA',
#  'XMG',
#  'ZBC',
#  'VERI',
#  'HYP',
#  'RUP',
#  'XIN',
#  'XAS',
#  'GAME',
#  'PROC',
#  'BEST',
#  'ARCT',
#  'XOC',
#  ...]

# %% [markdown]
# Other parameters:

# %%
print(cmc.ticker.__doc__)
# Out:
# Get currencies with other aditional data.
#
#         Args:
#             currency (str, optional): Specify a currency to return,
#                 in this case the method returns a dict, otherwise
#                 returns a list. If you dont specify a currency,
#                 returns data for all in coinmarketcap. As default, None.
#             limit (int, optional): Limit amount of coins on response.
#                 if limit == 0, returns all coins in coinmarketcap.
#                 Only works if currency == None. As default 0.
#             start (int, optional): Rank of first currency to retrieve.
#                 The count starts at 0 for the first currency ranked.
#                 Only works if currency == None. As default 0.
#             convert (str, optional): As default, "USD". Allow to
#                 convert price, 24h volume and market cap in terms
#                 of one of next badges:
#                    ["AUD", "BRL", "CAD", "CHF", "CLP", "CNY", "CZK", "DKK",
#                     "EUR", "GBP", "HKD", "HUF", "IDR", "ILS", "INR", "JPY",
#                     "KRW", "MXN", "MYR", "NOK", "NZD", "PHP", "PKR", "PLN",
#                     "RUB", "SEK", "SGD", "THB", "TRY", "TWD", "ZAR"]
#
#         Returns:
#             dict/list: If currency param is provided or not.

# %% [markdown]
# If you want to get the valid badges that can be passed to `convert` param programatically, use this:

# %%
cmc.ticker_badges
# Out:
# ['AUD',
#  'BRL',
#  'CAD',
#  'CHF',
#  'CLP',
#  'CNY',
#  'CZK',
#  'DKK',
#  'EUR',
#  'GBP',
#  'HKD',
#  'HUF',
#  'IDR',
#  'ILS',
#  'INR',
#  'JPY',
#  'KRW',
#  'MXN',
#  'MYR',
#  'NOK',
#  'NZD',
#  'PHP',
#  'PKR',
#  'PLN',
#  'RUB',
#  'SEK',
#  'SGD',
#  'THB',
#  'TRY',
#  'TWD',
#  'ZAR']

# %% [markdown]
# #### `stats()`

# %%
cmc.stats()
# Out:
# {'active_assets': 593,
#  'active_currencies': 888,
#  'active_markets': 8659,
#  'bitcoin_percentage_of_market_cap': 34.48,
#  'last_updated': 1518198868,
#  'total_24h_volume_usd': 24345332854.0,
#  'total_market_cap_usd': 423389158561.0}

# %% [markdown]
# _____________________________________________
#
# ## Web scraper
# #### `markets(currency, [convert="USD"])`
# Get all markets for a exchange in coinmarketcap. You can convert the response fields `"volume_24h"` and `"price"` between `"USD"` and `"BTC"`.

# %%
cmc.markets("BTC", convert="BTC")
# Out:
# []

# %% [markdown]
# #### `ranks([convert="USD"])`
# Get gainers and losers rankings:

# %%
cmc.ranks()
# Out:
# {'gainers': {'1h': [{'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 70.51,
#     'price': 0.033829,
#     'symbol': 'UNY',
#     'volume_24h': 2067800.0}],
#   '24h': [{'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 983.43,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0}],
#   '7d': [{'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0},
#    {'name': 'E-coin',
#     'percent_change': 1271.98,
#     'price': 67.7418,
#     'symbol': 'ECN',
#     'volume_24h': 485386.0}]},
#  'losers': {'1h': [{'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.18,
#     'price': 0.0875082,
#     'symbol': 'VLC',
#     'volume_24h': 563342.0}],
#   '24h': [{'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.81,
#     'price': 0.0743076,
#     'symbol': 'DAV',
#     'volume_24h': 433983.0}],
#   '7d': [{'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1},
#    {'name': 'Global Jobcoin',
#     'percent_change': -63.04,
#     'price': 0.263622,
#     'symbol': 'GJC',
#     'volume_24h': 58132.1}]}}

# %% [markdown]
# #### `historical(currency, [start=datetime(2008, 8, 18), end=datetime.now(), revert=False])`
# Get historical prices for a currency. You can filter by `start` and `end` datetimes provided in `datetime` objects. With parameter `revert` active, the response will be ordered in chronological order.

# %%
from datetime import datetime

list(cmc.historical("ETH", start=datetime(2018, 2, 1), revert=True))
# Out:
# [{'close': 1036.79,
#   'date': datetime.datetime(2018, 2, 1, 0, 0),
#   'high': 1161.35,
#   'low': 984.819,
#   'market_cap': 697.951,
#   'open': 1119.37,
#   'volume': 644.599},
#  {'close': 915.785,
#   'date': datetime.datetime(2018, 2, 2, 0, 0),
#   'high': 1035.77,
#   'low': 757.98,
#   'market_cap': 856.646,
#   'open': 1035.77,
#   'volume': 834.958},
#  {'close': 964.019,
#   'date': datetime.datetime(2018, 2, 3, 0, 0),
#   'high': 991.943,
#   'low': 847.69,
#   'market_cap': 793.122,
#   'open': 919.211,
#   'volume': 574.419},
#  {'close': 834.682,
#   'date': datetime.datetime(2018, 2, 4, 0, 0),
#   'high': 969.032,
#   'low': 805.064,
#   'market_cap': 796.439,
#   'open': 964.667,
#   'volume': 707.737},
#  {'close': 697.951,
#   'date': datetime.datetime(2018, 2, 5, 0, 0),
#   'high': 856.646,
#   'low': 644.599,
#   'market_cap': 757.068,
#   'open': 834.958,
#   'volume': 723.433},
#  {'close': 793.122,
#   'date': datetime.datetime(2018, 2, 6, 0, 0),
#   'high': 796.439,
#   'low': 574.419,
#   'market_cap': 851.2,
#   'open': 707.737,
#   'volume': 790.428},
#  {'close': 757.068,
#   'date': datetime.datetime(2018, 2, 7, 0, 0),
#   'high': 851.2,
#   'low': 723.433,
#   'market_cap': 817.807,
#   'open': 790.428,
#   'volume': 755.843},
#  {'close': 817.807,
#   'date': datetime.datetime(2018, 2, 8, 0, 0),
#   'high': 845.086,
#   'low': 755.843,
#   'market_cap': 845.086,
#   'open': 755.843,
#   'volume': 755.843}]

# %% [markdown]
# #### `recently([convert="USD"])`
# Get recently added coins in coinmarketcap along with other metadata. this method returns a `generator` object.

# %%
cmc.recently()
