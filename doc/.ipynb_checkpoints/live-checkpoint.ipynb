# %% [markdown]
# # <center>Pymarketcap live demo</center>

# %% [markdown]
# ## Basic usage
# The first response takes a long time because some data is cached at instantiation of the wrapper.

# %%
from pymarketcap import Pymarketcap
cmc = Pymarketcap()

cmc.exchanges()
# Out:
# [{'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'NEO',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'ICON',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'NEO',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Bluzelle',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'TRON',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Binance Coin',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'VeChain',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Binance'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'OKEx'},
#  {'markets': [{'name': 'Qtum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Cardano',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'NEO',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Status',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Stellar',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Steem',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Upbit'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'BitMEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Tether',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'EOS',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Bitfinex'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Qtum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Zcash',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Bithumb'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Huobi Token',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Huobi Token',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Huobi Token',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'EOS',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'TRON',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Elastos',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Elastos',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Huobi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'GDAX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Ripple',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Kraken'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Cardano',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'NuBits',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Lisk',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'NEO',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Bittrex'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Monero',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Dash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Zcash',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'EOS',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'HitBTC'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Ripple',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Bitstamp'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'}],
#   'name': 'bitFlyer'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Qtum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'IOTA',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'}],
#   'name': 'Coinone'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Monero',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Stellar',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Ripple',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Poloniex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'}],
#   'name': 'Gemini'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'QASH',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Quoine'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'NEM',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'COMSA [ETH]',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Counterparty',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'NEM',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'COMSA [XEM]',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Pepe Cash',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Zaif'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'}],
#   'name': 'Fisco'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'EDUCare',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Hshare',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'TRON',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Zcash',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Lisk',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Factom',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Bit-Z'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'BTCBOX'},
#  {'markets': [{'name': 'ATMCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'ATMCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Dogecoin',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'ATMCoin',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'ATMCoin',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Bits Blockchain'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'NEO',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'TRON',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Lisk',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ruff',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Qtum',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Qbao',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Achain',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Ripple',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'CoinEgg'},
#  {'markets': [{'name': 'Qtum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'VeChain',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ink',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Zcash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bodhi',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Zcash',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'NEO',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Primas',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Lbank'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'BitShares',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Qtum',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Hshare',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Ink',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Qtum',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'ZB.COM'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Korbit'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ink',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Lightning Bitcoin [Futures]',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Hyper Pay',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'EXX'},
#  {'markets': [{'name': 'Jibrel Network',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Jibrel Network',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bibox Token',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bibox Token',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bibox Token',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Spectre.ai Utility Token',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'High Performance Blockchain',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Spectre.ai Utility Token',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'High Performance Blockchain',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Bytom',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Bibox'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Stellar',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Status',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Civic',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': '0x',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Enigma',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Zcash',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'GOPAX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Zcash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Dash',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
# ...
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'}],
#   'name': 'BitKonan'},
#  {'markets': [{'name': 'Auroracoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'ISX'},
#  {'markets': [{'name': 'NVO',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Pepe Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Counterparty',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Storjcoin X',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Rustbits',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Storjcoin X',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'FoldingCoin',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Bitcrystals',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'}],
#   'name': 'Counterparty DEX'},
#  {'markets': [{'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Electroneum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Monero',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Verge',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'BitCoal',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Aeon',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Sumokoin',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'}],
#   'name': 'TradeOgre'},
#  {'markets': [{'name': 'E-Dinar Coin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'}],
#   'name': 'LocalTrade'},
#  {'markets': [{'name': 'Adelphoi',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'SuperNET',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'}],
#   'name': 'Nxt Asset Exchange'},
#  {'markets': [{'name': 'Peercoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Vertcoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Dogecoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'}],
#   'name': 'Coingi'},
#  {'markets': [{'name': 'Gulden',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'GuldenTrader'},
#  {'markets': [{'name': 'Centurion',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'ExcambrioRex'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'TCC Exchange'},
#  {'markets': [{'name': 'BriaCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Ore.Bz'},
#  {'markets': [{'name': 'SACoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'DC-Ex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'}],
#   'name': 'CoinCorner'},
#  {'markets': [{'name': 'LEOcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'LEOcoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'LEOcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'LEOcoin',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'}],
#   'name': 'LEOxChange'},
#  {'markets': [{'name': 'CRTCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'}],
#   'name': 'NIX-E'},
#  {'markets': [{'name': 'SnakeEyes',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'CCMiner',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'}],
#   'name': 'Burst Asset Exchange'},
#  {'markets': [{'name': 'HEAT',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bismuth',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Golem',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'FIMKrypto',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Elastic',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Elastic',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'HEAT',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'}],
#   'name': 'Heat Wallet'},
#  {'markets': [{'name': 'MaidSafeCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'Omni DEX'},
#  {'markets': [{'name': 'Golem',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Lunyr',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'SingularDTV',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'TokenCard',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Swarm City',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Etheroll',
#     'pair': 'NEO/BTC',
#     'perc_volume': 0.0,
#     'price': 115.524,
#     'volume': 53538700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Melon',
#     'pair': 'BLZ/BTC',
#     'perc_volume': 0.0,
#     'price': 0.790247,
#     'volume': 53287000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BLZ_BTC'},
#    {'name': 'Numeraire',
#     'pair': 'TRX/BTC',
#     'perc_volume': 0.0,
#     'price': 0.0363919,
#     'volume': 52124600.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Edgeless',
#     'pair': 'BNB/USDT',
#     'perc_volume': 0.0,
#     'price': 8.28059,
#     'volume': 36972200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BNB_USDT'},
#    {'name': 'Ethereum Movie Venture',
#     'pair': 'VEN/BTC',
#     'perc_volume': 0.0,
#     'price': 4.2977,
#     'volume': 36122900.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'CryptoDerivatives'},
#  {'markets': [{'name': 'Virtacoinplus',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Virtacoinplus',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'}],
#   'name': 'VirtacoinWorld'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 0.0,
#     'price': 7785.42,
#     'volume': 479902000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/USDT',
#     'perc_volume': 0.0,
#     'price': 781.801,
#     'volume': 284345000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'perc_volume': 0.0,
#     'price': 109.22,
#     'volume': 126648000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Siacoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 0.0,
#     'price': 825.799,
#     'volume': 88244200.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'perc_volume': 0.0,
#     'price': 4.26246,
#     'volume': 67741800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'}],
#   'name': 'BITHOLIC'}]

# %% [markdown]
# All methods are self explained in docstrings:

# %%
print(cmc.exchanges.__doc__)
# Out:
# Get all the exchanges in coninmarketcap ranked by volumes
#         along with other metadata.
#
#         Args:
#             convert (str, optional): Convert volumes and prices
#                 between "USD" and "BTC". As default "USD".
#
#         Returns (list):
#             Exchanges with markets and other data included.

# %% [markdown]
# ___________________________________
#
# ## Coinmarketcap API
# #### `ticker(currency=None, limit=0, start=0, convert="USD")`
# If `currency == None`, you will obtain data for all currencies in coinmarketcap:

# %%
cmc.ticker()
# Out:
# [{'24h_volume_usd': 8107680000.0,
#   'available_supply': 16854700.0,
#   'id': 'bitcoin',
#   'last_updated': 1518183267,
#   'market_cap_usd': 139667651379,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin',
#   'percent_change_1h': 0.13,
#   'percent_change_24h': -1.93,
#   'percent_change_7d': -2.73,
#   'price_btc': 1.0,
#   'price_usd': 8286.57,
#   'rank': 1,
#   'symbol': 'BTC',
#   'total_supply': 16854700.0},
#  {'24h_volume_usd': 3093570000.0,
#   'available_supply': 97508169.0,
#   'id': 'ethereum',
#   'last_updated': 1518183252,
#   'market_cap_usd': 81065951770.0,
#   'max_supply': None,
#   'name': 'Ethereum',
#   'percent_change_1h': 0.17,
#   'percent_change_24h': 0.68,
#   'percent_change_7d': -6.81,
#   'price_btc': 0.100975,
#   'price_usd': 831.376,
#   'rank': 2,
#   'symbol': 'ETH',
#   'total_supply': 97508169.0},
#  {'24h_volume_usd': 905623000.0,
#   'available_supply': 39009215838.0,
#   'id': 'ripple',
#   'last_updated': 1518183241,
#   'market_cap_usd': 32437723338.0,
#   'max_supply': 100000000000,
#   'name': 'Ripple',
#   'percent_change_1h': 0.85,
#   'percent_change_24h': 7.01,
#   'percent_change_7d': 4.28,
#   'price_btc': 0.000101,
#   'price_usd': 0.83154,
#   'rank': 3,
#   'symbol': 'XRP',
#   'total_supply': 99992725510.0},
#  {'24h_volume_usd': 1614720000.0,
#   'available_supply': 16958063.0,
#   'id': 'bitcoin-cash',
#   'last_updated': 1518183253,
#   'market_cap_usd': 22304430864.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Cash',
#   'percent_change_1h': 0.18,
#   'percent_change_24h': 7.81,
#   'percent_change_7d': 15.24,
#   'price_btc': 0.159747,
#   'price_usd': 1315.27,
#   'rank': 4,
#   'symbol': 'BCH',
#   'total_supply': 16958063.0},
#  {'24h_volume_usd': 311948000.0,
#   'available_supply': 25927070538.0,
#   'id': 'cardano',
#   'last_updated': 1518183254,
#   'market_cap_usd': 9394699937.0,
#   'max_supply': 45000000000.0,
#   'name': 'Cardano',
#   'percent_change_1h': -0.02,
#   'percent_change_24h': 1.98,
#   'percent_change_7d': 9.11,
#   'price_btc': 4.401e-05,
#   'price_usd': 0.362351,
#   'rank': 5,
#   'symbol': 'ADA',
#   'total_supply': 31112483745.0},
#  {'24h_volume_usd': 678900000.0,
#   'available_supply': 55140658.0,
#   'id': 'litecoin',
#   'last_updated': 1518183241,
#   'market_cap_usd': 8189380268.0,
#   'max_supply': 84000000.0,
#   'name': 'Litecoin',
#   'percent_change_1h': 0.2,
#   'percent_change_24h': 0.4,
#   'percent_change_7d': 19.36,
#   'price_btc': 0.0180384,
#   'price_usd': 148.518,
#   'rank': 6,
#   'symbol': 'LTC',
#   'total_supply': 55140658.0},
#  {'24h_volume_usd': 422512000.0,
#   'available_supply': 65000000.0,
#   'id': 'neo',
#   'last_updated': 1518183247,
#   'market_cap_usd': 7342400000.0,
#   'max_supply': None,
#   'name': 'NEO',
#   'percent_change_1h': 0.01,
#   'percent_change_24h': 0.17,
#   'percent_change_7d': 1.48,
#   'price_btc': 0.0137196,
#   'price_usd': 112.96,
#   'rank': 7,
#   'symbol': 'NEO',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 122571000.0,
#   'available_supply': 18432181842.0,
#   'id': 'stellar',
#   'last_updated': 1518183243,
#   'market_cap_usd': 6802488870.0,
#   'max_supply': None,
#   'name': 'Stellar',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': 1.34,
#   'percent_change_7d': -0.17,
#   'price_btc': 4.482e-05,
#   'price_usd': 0.369055,
#   'rank': 8,
#   'symbol': 'XLM',
#   'total_supply': 103669352049},
#  {'24h_volume_usd': 417279000.0,
#   'available_supply': 657684822.0,
#   'id': 'eos',
#   'last_updated': 1518183251,
#   'market_cap_usd': 5645185055.0,
#   'max_supply': 1000000000.0,
#   'name': 'EOS',
#   'percent_change_1h': -0.13,
#   'percent_change_24h': 2.32,
#   'percent_change_7d': -4.69,
#   'price_btc': 0.0010425,
#   'price_usd': 8.58342,
#   'rank': 9,
#   'symbol': 'EOS',
#   'total_supply': 900000000.0},
#  {'24h_volume_usd': 51272000.0,
#   'available_supply': 2779530283.0,
#   'id': 'iota',
#   'last_updated': 1518183251,
#   'market_cap_usd': 5047071088.0,
#   'max_supply': 2779530283.0,
#   'name': 'IOTA',
#   'percent_change_1h': 0.8,
#   'percent_change_24h': -0.67,
#   'percent_change_7d': 8.45,
#   'price_btc': 0.00022054,
#   'price_usd': 1.8158,
#   'rank': 10,
#   'symbol': 'MIOTA',
#   'total_supply': 2779530283.0},
#  {'24h_volume_usd': 40978500.0,
#   'available_supply': 8999999999.0,
#   'id': 'nem',
#   'last_updated': 1518183244,
#   'market_cap_usd': 4851152999.0,
#   'max_supply': None,
#   'name': 'NEM',
#   'percent_change_1h': -0.31,
#   'percent_change_24h': -5.44,
#   'percent_change_7d': 1.28,
#   'price_btc': 6.547e-05,
#   'price_usd': 0.539017,
#   'rank': 11,
#   'symbol': 'XEM',
#   'total_supply': 8999999999.0},
#  {'24h_volume_usd': 93692900.0,
#   'available_supply': 7873870.0,
#   'id': 'dash',
#   'last_updated': 1518183242,
#   'market_cap_usd': 4736770837.0,
#   'max_supply': 18900000.0,
#   'name': 'Dash',
#   'percent_change_1h': -0.63,
#   'percent_change_24h': 2.45,
#   'percent_change_7d': 10.82,
#   'price_btc': 0.0730654,
#   'price_usd': 601.581,
#   'rank': 12,
#   'symbol': 'DASH',
#   'total_supply': 7873870.0},
#  {'24h_volume_usd': 85685400.0,
#   'available_supply': 15701840.0,
#   'id': 'monero',
#   'last_updated': 1518183242,
#   'market_cap_usd': 3771472156.0,
#   'max_supply': None,
#   'name': 'Monero',
#   'percent_change_1h': -0.67,
#   'percent_change_24h': 0.27,
#   'percent_change_7d': 8.08,
#   'price_btc': 0.0291728,
#   'price_usd': 240.193,
#   'rank': 13,
#   'symbol': 'XMR',
#   'total_supply': 15701840.0},
#  {'24h_volume_usd': 83794900.0,
#   'available_supply': 117885208.0,
#   'id': 'lisk',
#   'last_updated': 1518183246,
#   'market_cap_usd': 3007204502.0,
#   'max_supply': None,
#   'name': 'Lisk',
#   'percent_change_1h': -0.8,
#   'percent_change_24h': 11.38,
#   'percent_change_7d': 32.35,
#   'price_btc': 0.00309829,
#   'price_usd': 25.5096,
#   'rank': 14,
#   'symbol': 'LSK',
#   'total_supply': 117885208.0},
#  {'24h_volume_usd': 223117000.0,
#   'available_supply': 65748192475.0,
#   'id': 'tron',
#   'last_updated': 1518183253,
#   'market_cap_usd': 2707162101.0,
#   'max_supply': None,
#   'name': 'TRON',
#   'percent_change_1h': 8.1,
#   'percent_change_24h': 10.42,
#   'percent_change_7d': 8.9,
#   'price_btc': 5e-06,
#   'price_usd': 0.0411747,
#   'rank': 15,
#   'symbol': 'TRX',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 327151000.0,
#   'available_supply': 99731053.0,
#   'id': 'ethereum-classic',
#   'last_updated': 1518183247,
#   'market_cap_usd': 2390214255.0,
#   'max_supply': None,
#   'name': 'Ethereum Classic',
#   'percent_change_1h': 1.7,
#   'percent_change_24h': 15.79,
#   'percent_change_7d': 11.03,
#   'price_btc': 0.00291088,
#   'price_usd': 23.9666,
#   'rank': 16,
#   'symbol': 'ETC',
#   'total_supply': 99731053.0},
#  {'24h_volume_usd': 100572000.0,
#   'available_supply': 16813886.0,
#   'id': 'bitcoin-gold',
#   'last_updated': 1518183255,
#   'market_cap_usd': 2268714464.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Gold',
#   'percent_change_1h': 5.63,
#   'percent_change_24h': 29.82,
#   'percent_change_7d': 29.33,
#   'price_btc': 0.0163882,
#   'price_usd': 134.931,
#   'rank': 17,
#   'symbol': 'BTG',
#   'total_supply': 16913886.0},
#  {'24h_volume_usd': 2451330000.0,
#   'available_supply': 2217140814.0,
#   'id': 'tether',
#   'last_updated': 1518183245,
#   'market_cap_usd': 2266937796.0,
#   'max_supply': None,
#   'name': 'Tether',
#   'percent_change_1h': -0.01,
#   'percent_change_24h': -0.33,
#   'percent_change_7d': 3.6,
#   'price_btc': 0.00012418,
#   'price_usd': 1.02246,
#   'rank': 18,
#   'symbol': 'USDT',
#   'total_supply': 2280109970.0},
#  {'24h_volume_usd': 618982000.0,
#   'available_supply': 73869068.0,
#   'id': 'qtum',
#   'last_updated': 1518183250,
#   'market_cap_usd': 2190860527.0,
#   'max_supply': None,
#   'name': 'Qtum',
#   'percent_change_1h': 1.56,
#   'percent_change_24h': 19.86,
#   'percent_change_7d': 6.46,
#   'price_btc': 0.00360222,
#   'price_usd': 29.6587,
#   'rank': 19,
#   'symbol': 'QTUM',
#   'total_supply': 100369068.0},
#  {'24h_volume_usd': 93535500.0,
#   'available_supply': 466139235.0,
#   'id': 'vechain',
#   'last_updated': 1518183252,
#   'market_cap_usd': 1995611984.0,
#   'max_supply': None,
#   'name': 'VeChain',
#   'percent_change_1h': -0.55,
#   'percent_change_24h': -2.1,
#   'percent_change_7d': -6.09,
#   'price_btc': 0.00051997,
#   'price_usd': 4.28115,
#   'rank': 20,
#   'symbol': 'VEN',
#   'total_supply': 873378637.0},
#  {'24h_volume_usd': 99685800.0,
#   'available_supply': 381495014.0,
#   'id': 'icon',
#   'last_updated': 1518183255,
#   'market_cap_usd': 1629143938.0,
#   'max_supply': None,
#   'name': 'ICON',
#   'percent_change_1h': -0.32,
#   'percent_change_24h': -3.76,
#   'percent_change_7d': -15.21,
#   'price_btc': 0.00051867,
#   'price_usd': 4.27042,
#   'rank': 21,
#   'symbol': 'ICX',
#   'total_supply': 400230000.0},
#  {'24h_volume_usd': 33074500.0,
#   'available_supply': 133248289.0,
#   'id': 'raiblocks',
#   'last_updated': 1518183249,
#   'market_cap_usd': 1506238661.0,
#   'max_supply': 133248290.0,
#   'name': 'Nano',
#   'percent_change_1h': -0.18,
#   'percent_change_24h': -2.92,
#   'percent_change_7d': -28.86,
#   'price_btc': 0.00137293,
#   'price_usd': 11.304,
#   'rank': 22,
#   'symbol': 'XRB',
#   'total_supply': 133248289.0},
#  {'24h_volume_usd': 116989000.0,
#   'available_supply': 3241206.0,
#   'id': 'zcash',
#   'last_updated': 1518183248,
#   'market_cap_usd': 1384559039.0,
#   'max_supply': None,
#   'name': 'Zcash',
#   'percent_change_1h': -0.15,
#   'percent_change_24h': 5.87,
#   'percent_change_7d': 20.41,
#   'price_btc': 0.0518827,
#   'price_usd': 427.174,
#   'rank': 23,
#   'symbol': 'ZEC',
#   'total_supply': 3241206.0},
#  {'24h_volume_usd': 40878500.0,
#   'available_supply': 102042552.0,
#   'id': 'omisego',
#   'last_updated': 1518183252,
#   'market_cap_usd': 1246562017.0,
#   'max_supply': None,
#   'name': 'OmiseGO',
#   'percent_change_1h': -0.73,
#   'percent_change_24h': 1.35,
#   'percent_change_7d': -0.69,
#   'price_btc': 0.00148372,
#   'price_usd': 12.2161,
#   'rank': 24,
#   'symbol': 'OMG',
#   'total_supply': 140245398.0},
#  {'24h_volume_usd': 11728400.0,
#   'available_supply': 37004027.0,
#   'id': 'populous',
#   'last_updated': 1518183251,
#   'market_cap_usd': 1200536446.0,
#   'max_supply': 53252246.0,
#   'name': 'Populous',
#   'percent_change_1h': -5.53,
#   'percent_change_24h': -10.62,
#   'percent_change_7d': -38.33,
#   'price_btc': 0.00394044,
#   'price_usd': 32.4434,
#   'rank': 25,
#   'symbol': 'PPT',
#   'total_supply': 53252246.0},
#  {'24h_volume_usd': 59427100.0,
#   'available_supply': 249202065.0,
#   'id': 'steem',
#   'last_updated': 1518183246,
#   'market_cap_usd': 1030624980.0,
#   'max_supply': None,
#   'name': 'Steem',
#   'percent_change_1h': -0.26,
#   'percent_change_24h': 7.19,
#   'percent_change_7d': 7.77,
#   'price_btc': 0.0005023,
#   'price_usd': 4.1357,
#   'rank': 26,
#   'symbol': 'STEEM',
#   'total_supply': 266176159.0},
#  {'24h_volume_usd': 81810100.0,
#   'available_supply': 99014000.0,
#   'id': 'binance-coin',
#   'last_updated': 1518183253,
#   'market_cap_usd': 848064811.0,
#   'max_supply': None,
#   'name': 'Binance Coin',
#   'percent_change_1h': -0.06,
#   'percent_change_24h': -0.91,
#   'percent_change_7d': -2.24,
#   'price_btc': 0.00104028,
#   'price_usd': 8.5651,
#   'rank': 27,
#   'symbol': 'BNB',
#   'total_supply': 197192382.0},
#  {'24h_volume_usd': 4844660.0,
#   'available_supply': 183716746903,
#   'id': 'bytecoin-bcn',
#   'last_updated': 1518183242,
#   'market_cap_usd': 824912077.0,
#   'max_supply': 184470000000,
#   'name': 'Bytecoin',
#   'percent_change_1h': -0.15,
#   'percent_change_24h': -4.04,
#   'percent_change_7d': 1.9,
#   'price_btc': 5.5e-07,
#   'price_usd': 0.00449013,
#   'rank': 28,
#   'symbol': 'BCN',
#   'total_supply': 183716746903},
#  {'24h_volume_usd': 20929800.0,
#   'available_supply': 14574516208.0,
#   'id': 'verge',
#   'last_updated': 1518183245,
#   'market_cap_usd': 775502720.0,
#   'max_supply': 16555000000.0,
#   'name': 'Verge',
#   'percent_change_1h': 0.42,
#   'percent_change_24h': -0.16,
#   'percent_change_7d': 6.41,
#   'price_btc': 6.46e-06,
#   'price_usd': 0.0532095,
#   'rank': 29,
#   'symbol': 'XVG',
#   'total_supply': 14574516208.0},
#  {'24h_volume_usd': 119868000.0,
#   'available_supply': 3470483788.0,
#   'id': 'status',
#   'last_updated': 1518183251,
#   'market_cap_usd': 754969043.0,
#   'max_supply': None,
#   'name': 'Status',
#   'percent_change_1h': -0.36,
#   'percent_change_24h': 0.34,
#   'percent_change_7d': 37.06,
#   'price_btc': 2.642e-05,
#   'price_usd': 0.21754,
#   'rank': 30,
#   'symbol': 'SNT',
#   'total_supply': 6804870174.0},
#  {'24h_volume_usd': 15025800.0,
#   'available_supply': 98733803.0,
#   'id': 'stratis',
#   'last_updated': 1518183247,
#   'market_cap_usd': 741193674.0,
#   'max_supply': None,
#   'name': 'Stratis',
#   'percent_change_1h': -0.77,
#   'percent_change_24h': 3.89,
#   'percent_change_7d': -12.71,
#   'price_btc': 0.00091177,
#   'price_usd': 7.50699,
#   'rank': 31,
#   'symbol': 'STRAT',
#   'total_supply': 98733803.0},
#  {'24h_volume_usd': 13479000.0,
#   'available_supply': 32360206494.0,
#   'id': 'siacoin',
#   'last_updated': 1518183245,
#   'market_cap_usd': 736485940.0,
#   'max_supply': None,
#   'name': 'Siacoin',
#   'percent_change_1h': -0.63,
#   'percent_change_24h': 2.18,
#   'percent_change_7d': -4.43,
#   'price_btc': 2.76e-06,
#   'price_usd': 0.022759,
#   'rank': 32,
#   'symbol': 'SC',
#   'total_supply': 32360206494.0},
#  {'24h_volume_usd': 20853800.0,
#   'available_supply': 233020472.0,
#   'id': 'aeternity',
#   'last_updated': 1518183251,
#   'market_cap_usd': 672497083.0,
#   'max_supply': None,
#   'name': 'Aeternity',
#   'percent_change_1h': -0.27,
#   'percent_change_24h': -0.77,
#   'percent_change_7d': 17.45,
#   'price_btc': 0.00035052,
#   'price_usd': 2.886,
#   'rank': 33,
#   'symbol': 'AE',
#   'total_supply': 273685830.0},
#  {'24h_volume_usd': 627835.0,
#   'available_supply': 618228.0,
#   'id': 'maker',
#   'last_updated': 1518183249,
#   'market_cap_usd': 640842542.0,
#   'max_supply': None,
#   'name': 'Maker',
#   'percent_change_1h': 0.32,
#   'percent_change_24h': 0.9,
#   'percent_change_7d': -7.66,
#   'price_btc': 0.125898,
#   'price_usd': 1036.58,
#   'rank': 34,
#   'symbol': 'MKR',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 25625200.0,
#   'available_supply': 2608380000.0,
#   'id': 'bitshares',
#   'last_updated': 1518183244,
#   'market_cap_usd': 619837165.0,
#   'max_supply': 3600570502.0,
#   'name': 'BitShares',
#   'percent_change_1h': -0.09,
#   'percent_change_24h': -0.26,
#   'percent_change_7d': -20.33,
#   'price_btc': 2.886e-05,
#   'price_usd': 0.237633,
#   'rank': 35,
#   'symbol': 'BTS',
#   'total_supply': 2608380000.0},
#  {'24h_volume_usd': 24293200.0,
#   'available_supply': 2000000.0,
#   'id': 'digixdao',
#   'last_updated': 1518183246,
#   'market_cap_usd': 583816000.0,
#   'max_supply': None,
#   'name': 'DigixDAO',
#   'percent_change_1h': -0.06,
#   'percent_change_24h': -1.92,
#   'percent_change_7d': -16.45,
#   'price_btc': 0.0354539,
#   'price_usd': 291.908,
#   'rank': 36,
#   'symbol': 'DGD',
#   'total_supply': 2000000.0},
#  {'24h_volume_usd': 5002990.0,
#   'available_supply': 11000000.0,
#   'id': 'augur',
#   'last_updated': 1518183245,
#   'market_cap_usd': 583053900.0,
#   'max_supply': None,
#   'name': 'Augur',
#   'percent_change_1h': 0.01,
#   'percent_change_24h': -0.27,
#   'percent_change_7d': -0.87,
#   'price_btc': 0.00643774,
#   'price_usd': 53.0049,
#   'rank': 37,
#   'symbol': 'REP',
#   'total_supply': 11000000.0},
#  {'24h_volume_usd': 29415600.0,
#   'available_supply': 100000000.0,
#   'id': 'waves',
#   'last_updated': 1518183247,
#   'market_cap_usd': 568717000.0,
#   'max_supply': None,
#   'name': 'Waves',
#   'percent_change_1h': 0.15,
#   'percent_change_24h': 1.34,
#   'percent_change_7d': -5.56,
#   'price_btc': 0.00069074,
#   'price_usd': 5.68717,
#   'rank': 38,
#   'symbol': 'WAVES',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 16394900.0,
#   'available_supply': 24898178.0,
#   'id': 'walton',
#   'last_updated': 1518183253,
#   'market_cap_usd': 567596294.0,
#   'max_supply': 100000000.0,
#   'name': 'Walton',
#   'percent_change_1h': 0.18,
#   'percent_change_24h': -1.73,
#   'percent_change_7d': -0.88,
#   'price_btc': 0.00276879,
#   'price_usd': 22.7967,
#   'rank': 39,
#   'symbol': 'WTC',
#   'total_supply': 70000000.0},
#  {'24h_volume_usd': 263646.0,
#   'available_supply': 2036645.0,
#   'id': 'veritaseum',
#   'last_updated': 1518183250,
#   'market_cap_usd': 559759779.0,
#   'max_supply': None,
#   'name': 'Veritaseum',
#   'percent_change_1h': -2.33,
#   'percent_change_24h': -7.24,
#   'percent_change_7d': -12.02,
#   'price_btc': 0.0333814,
#   'price_usd': 274.844,
#   'rank': 40,
#   'symbol': 'VERI',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 12369200.0,
#   'available_supply': 507188082.0,
#   'id': '0x',
#   'last_updated': 1518183252,
#   'market_cap_usd': 550253422.0,
#   'max_supply': None,
#   'name': '0x',
#   'percent_change_1h': 0.11,
#   'percent_change_24h': -1.61,
#   'percent_change_7d': -14.5,
#   'price_btc': 0.00013177,
#   'price_usd': 1.08491,
#   'rank': 41,
#   'symbol': 'ZRX',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 9462050.0,
#   'available_supply': 113132925740,
#   'id': 'dogecoin',
#   'last_updated': 1518183241,
#   'market_cap_usd': 520112787.0,
#   'max_supply': None,
#   'name': 'Dogecoin',
#   'percent_change_1h': -0.24,
#   'percent_change_24h': -3.32,
#   'percent_change_7d': 6.84,
#   'price_btc': 5.6e-07,
#   'price_usd': 0.00459736,
#   'rank': 42,
#   'symbol': 'DOGE',
#   'total_supply': 113132925740},
#  {'24h_volume_usd': 1394710.0,
#   'available_supply': 6722448.0,
#   'id': 'decred',
#   'last_updated': 1518183246,
#   'market_cap_usd': 516171053.0,
#   'max_supply': 21000000.0,
#   'name': 'Decred',
#   'percent_change_1h': 0.08,
#   'percent_change_24h': -0.95,
#   'percent_change_7d': 1.68,
#   'price_btc': 0.00932575,
#   'price_usd': 76.7832,
#   'rank': 43,
#   'symbol': 'DCR',
#   'total_supply': 7142448.0},
#  {'24h_volume_usd': 2513720.0,
#   'available_supply': 91043076.0,
#   'id': 'kucoin-shares',
#   'last_updated': 1518183255,
#   'market_cap_usd': 511439032.0,
#   'max_supply': None,
#   'name': 'KuCoin Shares',
#   'percent_change_1h': -0.8,
#   'percent_change_24h': -8.25,
#   'percent_change_7d': -9.47,
#   'price_btc': 0.00068228,
#   'price_usd': 5.61755,
#   'rank': 44,
#   'symbol': 'KCS',
#   'total_supply': 181043076.0},
#  {'24h_volume_usd': 70862500.0,
#   'available_supply': 42602395.0,
#   'id': 'hshare',
#   'last_updated': 1518183253,
#   'market_cap_usd': 488700596.0,
#   'max_supply': 84000000.0,
#   'name': 'Hshare',
#   'percent_change_1h': -0.46,
#   'percent_change_24h': 5.15,
#   'percent_change_7d': 4.47,
#   'price_btc': 0.00139324,
#   'price_usd': 11.4712,
#   'rank': 45,
#   'symbol': 'HSR',
#   'total_supply': 42602395.0},
#  {'24h_volume_usd': 607170.0,
#   'available_supply': 344166289.0,
#   'id': 'rchain',
#   'last_updated': 1518183255,
#   'market_cap_usd': 487122640.0,
#   'max_supply': 1000000000.0,
#   'name': 'RChain',
#   'percent_change_1h': 1.93,
#   'percent_change_24h': 0.87,
#   'percent_change_7d': -9.14,
#   'price_btc': 0.00017191,
#   'price_usd': 1.41537,
#   'rank': 46,
#   'symbol': 'RHOC',
#   'total_supply': 870663574.0},
#  {'24h_volume_usd': 63708400.0,
#   'available_supply': 998999495.0,
#   'id': 'ardor',
#   'last_updated': 1518183247,
#   'market_cap_usd': 486450816.0,
#   'max_supply': 998999495.0,
#   'name': 'Ardor',
#   'percent_change_1h': 0.43,
#   'percent_change_24h': 10.45,
#   'percent_change_7d': 5.97,
#   'price_btc': 5.914e-05,
#   'price_usd': 0.486938,
#   'rank': 47,
#   'symbol': 'ARDR',
#   'total_supply': 998999495.0},
#  {'24h_volume_usd': 4637840.0,
#   'available_supply': 103125385.0,
#   'id': 'komodo',
#   'last_updated': 1518183249,
#   'market_cap_usd': 436261630.0,
#   'max_supply': None,
#   'name': 'Komodo',
#   'percent_change_1h': 0.0,
#   'percent_change_24h': 5.87,
#   'percent_change_7d': 1.86,
#   'price_btc': 0.00051381,
#   'price_usd': 4.2304,
#   'rank': 48,
#   'symbol': 'KMD',
#   'total_supply': 103125385.0},
#  {'24h_volume_usd': 4831550.0,
#   'available_supply': 184450000.0,
#   'id': 'revain',
#   'last_updated': 1518183256,
#   'market_cap_usd': 432105482.0,
#   'max_supply': 484450000.0,
#   'name': 'Revain',
#   'percent_change_1h': 2.12,
#   'percent_change_24h': 7.26,
#   'percent_change_7d': 59.73,
#   'price_btc': 0.00028453,
#   'price_usd': 2.34267,
#   'rank': 49,
#   'symbol': 'R',
#   'total_supply': 484450000.0},
#  {'24h_volume_usd': 6896630.0,
#   'available_supply': 134132697.0,
#   'id': 'kyber-network',
#   'last_updated': 1518183254,
#   'market_cap_usd': 426422598.0,
#   'max_supply': None,
#   'name': 'Kyber Network',
#   'percent_change_1h': 1.16,
#   'percent_change_24h': -0.65,
#   'percent_change_7d': -1.62,
#   'price_btc': 0.00038612,
#   'price_usd': 3.17911,
#   'rank': 50,
#   'symbol': 'KNC',
#   'total_supply': 215625349.0},
#  {'24h_volume_usd': 8697620.0,
#   'available_supply': 100521798.0,
#   'id': 'ark',
#   'last_updated': 1518183249,
#   'market_cap_usd': 424399010.0,
#   'max_supply': None,
#   'name': 'Ark',
#   'percent_change_1h': -0.14,
#   'percent_change_24h': 7.7,
#   'percent_change_7d': -0.13,
#   'price_btc': 0.00051278,
#   'price_usd': 4.22196,
#   'rank': 51,
#   'symbol': 'ARK',
#   'total_supply': 131771798.0},
#  {'24h_volume_usd': 2321360.0,
#   'available_supply': 6102748092.0,
#   'id': 'electroneum',
#   'last_updated': 1518183256,
#   'market_cap_usd': 410742409.0,
#   'max_supply': 21000000000.0,
#   'name': 'Electroneum',
#   'percent_change_1h': 0.62,
#   'percent_change_24h': -5.87,
#   'percent_change_7d': 12.35,
#   'price_btc': 8.17e-06,
#   'price_usd': 0.0673045,
#   'rank': 52,
#   'symbol': 'ETN',
#   'total_supply': 6102748092.0},
#  {'24h_volume_usd': 8391320.0,
#   'available_supply': 9673811.0,
#   'id': 'gas',
#   'last_updated': 1518183251,
#   'market_cap_usd': 394813366.0,
#   'max_supply': 100000000.0,
#   'name': 'Gas',
#   'percent_change_1h': -0.43,
#   'percent_change_24h': -3.06,
#   'percent_change_7d': -8.42,
#   'price_btc': 0.00495692,
#   'price_usd': 40.8126,
#   'rank': 53,
#   'symbol': 'GAS',
#   'total_supply': 15253312.0},
#  {'24h_volume_usd': 2269630.0,
#   'available_supply': 238421940.0,
#   'id': 'dragonchain',
#   'last_updated': 1518183257,
#   'market_cap_usd': 376093921.0,
#   'max_supply': None,
#   'name': 'Dragonchain',
#   'percent_change_1h': 2.6,
#   'percent_change_24h': -1.4,
#   'percent_change_7d': -1.6,
#   'price_btc': 0.00019159,
#   'price_usd': 1.57743,
#   'rank': 54,
#   'symbol': 'DRGN',
#   'total_supply': 433494437.0},
#  {'24h_volume_usd': 12281400.0,
#   'available_supply': 6508988220.0,
#   'id': 'zilliqa',
#   'last_updated': 1518183260,
#   'market_cap_usd': 374550615.0,
#   'max_supply': None,
#   'name': 'Zilliqa',
#   'percent_change_1h': -0.32,
#   'percent_change_24h': -2.89,
#   'percent_change_7d': -11.95,
#   'price_btc': 6.99e-06,
#   'price_usd': 0.0575436,
#   'rank': 55,
#   'symbol': 'ZIL',
#   'total_supply': 12600000000.0},
#  {'24h_volume_usd': 5238540.0,
#   'available_supply': 1000000000.0,
#   'id': 'basic-attention-token',
#   'last_updated': 1518183250,
#   'market_cap_usd': 371255000.0,
#   'max_supply': None,
#   'name': 'Basic Attention Token',
#   'percent_change_1h': 0.52,
#   'percent_change_24h': -3.67,
#   'percent_change_7d': -4.65,
#   'price_btc': 4.509e-05,
#   'price_usd': 0.371255,
#   'rank': 56,
#   'symbol': 'BAT',
#   'total_supply': 1500000000.0},
#  {'24h_volume_usd': 2737390.0,
#   'available_supply': 561202251.0,
#   'id': 'loopring',
#   'last_updated': 1518183253,
#   'market_cap_usd': 362188148.0,
#   'max_supply': None,
#   'name': 'Loopring',
#   'percent_change_1h': -0.07,
#   'percent_change_24h': -0.64,
#   'percent_change_7d': -11.02,
#   'price_btc': 7.838e-05,
#   'price_usd': 0.645379,
#   'rank': 57,
#   'symbol': 'LRC',
#   'total_supply': 1374956357.0},
#  {'24h_volume_usd': 540483.0,
#   'available_supply': 325226613094,
#   'id': 'dentacoin',
#   'last_updated': 1518183252,
#   'market_cap_usd': 348675452.0,
#   'max_supply': 8000000000000,
#   'name': 'Dentacoin',
#   'percent_change_1h': 2.47,
#   'percent_change_24h': -0.79,
#   'percent_change_7d': 11.48,
#   'price_btc': 1.3e-07,
#   'price_usd': 0.0010721,
#   'rank': 58,
#   'symbol': 'DCN',
#   'total_supply': 1963173416169},
#  {'24h_volume_usd': 3852640.0,
#   'available_supply': 9817507362.0,
#   'id': 'digibyte',
#   'last_updated': 1518183242,
#   'market_cap_usd': 346727853.0,
#   'max_supply': 21000000000.0,
#   'name': 'DigiByte',
#   'percent_change_1h': 4.22,
#   'percent_change_24h': 3.9,
#   'percent_change_7d': -9.22,
#   'price_btc': 4.29e-06,
#   'price_usd': 0.0353173,
#   'rank': 59,
#   'symbol': 'DGB',
#   'total_supply': 9817507362.0},
#  {'24h_volume_usd': 13256700.0,
#   'available_supply': 55525009.0,
#   'id': 'pivx',
#   'last_updated': 1518183245,
#   'market_cap_usd': 336055121.0,
#   'max_supply': None,
#   'name': 'PIVX',
#   'percent_change_1h': -2.67,
#   'percent_change_24h': 10.08,
#   'percent_change_7d': 12.86,
#   'price_btc': 0.00073509,
#   'price_usd': 6.05232,
#   'rank': 60,
#   'symbol': 'PIVX',
#   'total_supply': 55525009.0},
#  {'24h_volume_usd': 15951600.0,
#   'available_supply': 987000000.0,
#   'id': 'bytom',
#   'last_updated': 1518183253,
#   'market_cap_usd': 332307108.0,
#   'max_supply': None,
#   'name': 'Bytom',
#   'percent_change_1h': -0.48,
#   'percent_change_24h': 11.07,
#   'percent_change_7d': 5.54,
#   'price_btc': 4.089e-05,
#   'price_usd': 0.336684,
#   'rank': 61,
#   'symbol': 'BTM',
#   'total_supply': 1407000000.0},
#  {'24h_volume_usd': 6770290.0,
#   'available_supply': 75601200.0,
#   'id': 'ethos',
#   'last_updated': 1518183252,
#   'market_cap_usd': 321719393.0,
#   'max_supply': None,
#   'name': 'Ethos',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': -1.86,
#   'percent_change_7d': 19.18,
#   'price_btc': 0.00051685,
#   'price_usd': 4.25548,
#   'rank': 62,
#   'symbol': 'ETHOS',
#   'total_supply': 222295208.0},
#  {'24h_volume_usd': 4916070.0,
#   'available_supply': 3264950.0,
#   'id': 'zclassic',
#   'last_updated': 1518183248,
#   'market_cap_usd': 320881245.0,
#   'max_supply': 21000000.0,
#   'name': 'ZClassic',
#   'percent_change_1h': -0.71,
#   'percent_change_24h': -4.23,
#   'percent_change_7d': 5.03,
#   'price_btc': 0.0119367,
#   'price_usd': 98.2806,
#   'rank': 63,
#   'symbol': 'ZCL',
#   'total_supply': 3264950.0},
#  {'24h_volume_usd': 383071.0,
#   'available_supply': 4981227.0,
#   'id': 'e-coin',
#   'last_updated': 1518183250,
#   'market_cap_usd': 319161680.0,
#   'max_supply': None,
#   'name': 'E-coin',
#   'percent_change_1h': 8.18,
#   'percent_change_24h': 2217.18,
#   'percent_change_7d': 1345.17,
#   'price_btc': 0.00778202,
#   'price_usd': 64.0729,
#   'rank': 64,
#   'symbol': 'ECN',
#   'total_supply': 213270119.0},
#  {'24h_volume_usd': 316820.0,
#   'available_supply': 227384800.0,
#   'id': 'pillar',
#   'last_updated': 1518183252,
#   'market_cap_usd': 307067255.0,
#   'max_supply': None,
#   'name': 'Pillar',
#   'percent_change_1h': -0.91,
#   'percent_change_24h': -5.86,
#   'percent_change_7d': 7.07,
#   'price_btc': 0.00016402,
#   'price_usd': 1.35043,
#   'rank': 65,
#   'symbol': 'PLR',
#   'total_supply': 800000000.0},
#  {'24h_volume_usd': 39442300.0,
#   'available_supply': 250000000.0,
#   'id': 'aelf',
#   'last_updated': 1518183258,
#   'market_cap_usd': 305147500.0,
#   'max_supply': None,
#   'name': 'aelf',
#   'percent_change_1h': -0.94,
#   'percent_change_24h': -7.17,
#   'percent_change_7d': -18.9,
#   'price_btc': 0.00014825,
#   'price_usd': 1.22059,
#   'rank': 66,
#   'symbol': 'ELF',
#   'total_supply': 260000000.0},
#  {'24h_volume_usd': 715165.0,
#   'available_supply': 645222.0,
#   'id': 'byteball',
#   'last_updated': 1518183248,
#   'market_cap_usd': 296986033.0,
#   'max_supply': None,
#   'name': 'Byteball Bytes',
#   'percent_change_1h': 0.81,
#   'percent_change_24h': -4.88,
#   'percent_change_7d': -7.88,
#   'price_btc': 0.0559042,
#   'price_usd': 460.285,
#   'rank': 67,
#   'symbol': 'GBYTE',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 3380240.0,
#   'available_supply': 350000000.0,
#   'id': 'qash',
#   'last_updated': 1518183257,
#   'market_cap_usd': 294394450.0,
#   'max_supply': None,
#   'name': 'QASH',
#   'percent_change_1h': 0.15,
#   'percent_change_24h': -2.44,
#   'percent_change_7d': -4.26,
#   'price_btc': 0.00010216,
#   'price_usd': 0.841127,
#   'rank': 68,
#   'symbol': 'QASH',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 6261750.0,
#   'available_supply': 35500000.0,
#   'id': 'nebulas-token',
#   'last_updated': 1518183253,
#   'market_cap_usd': 292388650.0,
#   'max_supply': 100000000.0,
#   'name': 'Nebulas',
#   'percent_change_1h': 1.83,
#   'percent_change_24h': 3.56,
#   'percent_change_7d': -3.34,
#   'price_btc': 0.00100035,
#   'price_usd': 8.2363,
#   'rank': 69,
#   'symbol': 'NAS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 220828.0,
#   'available_supply': 45106254.0,
#   'id': 'cryptonex',
#   'last_updated': 1518183254,
#   'market_cap_usd': 286338107.0,
#   'max_supply': 210000000.0,
#   'name': 'Cryptonex',
#   'percent_change_1h': 0.07,
#   'percent_change_24h': -2.26,
#   'percent_change_7d': 0.19,
#   'price_btc': 0.00077101,
#   'price_usd': 6.34808,
#   'rank': 70,
#   'symbol': 'CNX',
#   'total_supply': 106543879.0},
#  {'24h_volume_usd': 28980500.0,
#   'available_supply': 4503688789.0,
#   'id': 'funfair',
#   'last_updated': 1518183251,
#   'market_cap_usd': 284437671.0,
#   'max_supply': None,
#   'name': 'FunFair',
#   'percent_change_1h': -0.02,
#   'percent_change_24h': -1.54,
#   'percent_change_7d': 7.23,
#   'price_btc': 7.67e-06,
#   'price_usd': 0.0631566,
#   'rank': 71,
#   'symbol': 'FUN',
#   'total_supply': 10999873621.0},
#  {'24h_volume_usd': 3441540.0,
#   'available_supply': 530831093.0,
#   'id': 'syscoin',
#   'last_updated': 1518183243,
#   'market_cap_usd': 277529112.0,
#   'max_supply': 888000000.0,
#   'name': 'Syscoin',
#   'percent_change_1h': 0.81,
#   'percent_change_24h': -3.29,
#   'percent_change_7d': 16.14,
#   'price_btc': 6.35e-05,
#   'price_usd': 0.52282,
#   'rank': 72,
#   'symbol': 'SYS',
#   'total_supply': 530831093.0},
#  {'24h_volume_usd': 11773500.0,
#   'available_supply': 1445976590.0,
#   'id': 'cindicator',
#   'last_updated': 1518183255,
#   'market_cap_usd': 275828710.0,
#   'max_supply': None,
#   'name': 'Cindicator',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': -1.99,
#   'percent_change_7d': 3.43,
#   'price_btc': 2.317e-05,
#   'price_usd': 0.190756,
#   'rank': 73,
#   'symbol': 'CND',
#   'total_supply': 2000000005.0},
#  {'24h_volume_usd': 2653290.0,
#   'available_supply': 10614760961.0,
#   'id': 'dent',
#   'last_updated': 1518183253,
#   'market_cap_usd': 272735668.0,
#   'max_supply': None,
#   'name': 'Dent',
#   'percent_change_1h': -0.63,
#   'percent_change_24h': -3.0,
#   'percent_change_7d': 23.93,
#   'price_btc': 3.12e-06,
#   'price_usd': 0.025694,
#   'rank': 74,
#   'symbol': 'DENT',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 7071850.0,
#   'available_supply': 834262000.0,
#   'id': 'golem-network-tokens',
#   'last_updated': 1518183248,
#   'market_cap_usd': 272731927.0,
#   'max_supply': None,
#   'name': 'Golem',
#   'percent_change_1h': 0.06,
#   'percent_change_24h': -4.6,
#   'percent_change_7d': -5.89,
#   'price_btc': 3.971e-05,
#   'price_usd': 0.326914,
#   'rank': 75,
#   'symbol': 'GNT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 1302810.0,
#   'available_supply': 11167853.0,
#   'id': 'bitcore',
#   'last_updated': 1518183250,
#   'market_cap_usd': 271391106.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcore',
#   'percent_change_1h': -0.3,
#   'percent_change_24h': -0.29,
#   'percent_change_7d': 12.03,
#   'price_btc': 0.00295151,
#   'price_usd': 24.3011,
#   'rank': 76,
#   'symbol': 'BTX',
#   'total_supply': 16794791.0},
#  {'24h_volume_usd': 39329700.0,
#   'available_supply': 6794109922.0,
#   'id': 'iostoken',
#   'last_updated': 1518183259,
#   'market_cap_usd': 264443743.0,
#   'max_supply': None,
#   'name': 'IOStoken',
#   'percent_change_1h': 1.14,
#   'percent_change_24h': 4.5,
#   'percent_change_7d': -11.96,
#   'price_btc': 4.73e-06,
#   'price_usd': 0.0389225,
#   'rank': 77,
#   'symbol': 'IOST',
#   'total_supply': 21000000000.0},
#  {'24h_volume_usd': 14071200.0,
#   'available_supply': 60000000.0,
#   'id': 'gxshares',
#   'last_updated': 1518183251,
#   'market_cap_usd': 254760000.0,
#   'max_supply': 100000000.0,
#   'name': 'GXShares',
#   'percent_change_1h': -1.04,
#   'percent_change_24h': 0.1,
#   'percent_change_7d': -0.26,
#   'price_btc': 0.0005157,
#   'price_usd': 4.246,
#   'rank': 78,
#   'symbol': 'GXS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 16949900.0,
#   'available_supply': 363837589.0,
#   'id': 'power-ledger',
#   'last_updated': 1518183256,
#   'market_cap_usd': 250669181.0,
#   'max_supply': None,
#   'name': 'Power Ledger',
#   'percent_change_1h': 0.02,
#   'percent_change_24h': 0.24,
#   'percent_change_7d': 10.84,
#   'price_btc': 8.368e-05,
#   'price_usd': 0.688959,
#   'rank': 79,
#   'symbol': 'POWR',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 6332710.0,
#   'available_supply': 52847204.0,
#   'id': 'salt',
#   'last_updated': 1518183254,
#   'market_cap_usd': 233154992.0,
#   'max_supply': None,
#   'name': 'SALT',
#   'percent_change_1h': -0.16,
#   'percent_change_24h': -2.64,
#   'percent_change_7d': 0.56,
#   'price_btc': 0.00053585,
#   'price_usd': 4.41187,
#   'rank': 80,
#   'symbol': 'SALT',
#   'total_supply': 120000000.0},
#  {'24h_volume_usd': 4791150.0,
#   'available_supply': 8745102.0,
#   'id': 'factom',
#   'last_updated': 1518183245,
#   'market_cap_usd': 224645929.0,
#   'max_supply': None,
#   'name': 'Factom',
#   'percent_change_1h': -0.43,
#   'percent_change_24h': -1.81,
#   'percent_change_7d': -4.29,
#   'price_btc': 0.00311998,
#   'price_usd': 25.6882,
#   'rank': 81,
#   'symbol': 'FCT',
#   'total_supply': 8745102.0},
#  {'24h_volume_usd': 4875230.0,
#   'available_supply': 79265735.0,
#   'id': 'aion',
#   'last_updated': 1518183255,
#   'market_cap_usd': 224119110.0,
#   'max_supply': None,
#   'name': 'Aion',
#   'percent_change_1h': -0.15,
#   'percent_change_24h': -2.08,
#   'percent_change_7d': -9.86,
#   'price_btc': 0.00034341,
#   'price_usd': 2.82744,
#   'rank': 82,
#   'symbol': 'AION',
#   'total_supply': 465934587.0},
#  {'24h_volume_usd': 297673.0,
#   'available_supply': 681827722.0,
#   'id': 'smartcash',
#   'last_updated': 1518183252,
#   'market_cap_usd': 216980081.0,
#   'max_supply': 5000000000.0,
#   'name': 'SmartCash',
#   'percent_change_1h': -1.15,
#   'percent_change_24h': -4.23,
#   'percent_change_7d': -7.1,
#   'price_btc': 3.865e-05,
#   'price_usd': 0.318233,
#   'rank': 83,
#   'symbol': 'SMART',
#   'total_supply': 1282872001.0},
#  {'24h_volume_usd': 2993950.0,
#   'available_supply': 57303600.0,
#   'id': 'monacoin',
#   'last_updated': 1518183242,
#   'market_cap_usd': 214854690.0,
#   'max_supply': None,
#   'name': 'MonaCoin',
#   'percent_change_1h': 0.15,
#   'percent_change_24h': -2.61,
#   'percent_change_7d': 5.11,
#   'price_btc': 0.00045539,
#   'price_usd': 3.74941,
#   'rank': 84,
#   'symbol': 'MONA',
#   'total_supply': 57303600.0},
#  {'24h_volume_usd': 415558.0,
#   'available_supply': 756097560976,
#   'id': 'kin',
#   'last_updated': 1518183254,
#   'market_cap_usd': 209214463.0,
#   'max_supply': None,
#   'name': 'Kin',
#   'percent_change_1h': -1.48,
#   'percent_change_24h': -6.88,
#   'percent_change_7d': 1.57,
#   'price_btc': 3e-08,
#   'price_usd': 0.000276703,
#   'rank': 85,
#   'symbol': 'KIN',
#   'total_supply': 10000000000000},
#  {'24h_volume_usd': 6608810.0,
#   'available_supply': 4067062.0,
#   'id': 'zcoin',
#   'last_updated': 1518183248,
#   'market_cap_usd': 198248930.0,
#   'max_supply': None,
#   'name': 'ZCoin',
#   'percent_change_1h': -0.51,
#   'percent_change_24h': -3.59,
#   'percent_change_7d': -4.41,
#   'price_btc': 0.00592036,
#   'price_usd': 48.745,
#   'rank': 86,
#   'symbol': 'XZC',
#   'total_supply': 4067062.0},
#  {'24h_volume_usd': 319580.0,
#   'available_supply': 8865318.0,
#   'id': 'particl',
#   'last_updated': 1518183252,
#   'market_cap_usd': 197193936.0,
#   'max_supply': None,
#   'name': 'Particl',
#   'percent_change_1h': 1.28,
#   'percent_change_24h': 6.41,
#   'percent_change_7d': 9.96,
#   'price_btc': 0.00270157,
#   'price_usd': 22.2433,
#   'rank': 87,
#   'symbol': 'PART',
#   'total_supply': 8865318.0},
#  {'24h_volume_usd': 6786250.0,
#   'available_supply': 38963852.0,
#   'id': 'bancor',
#   'last_updated': 1518183251,
#   'market_cap_usd': 194122195.0,
#   'max_supply': None,
#   'name': 'Bancor',
#   'percent_change_1h': 0.29,
#   'percent_change_24h': -0.61,
#   'percent_change_7d': -11.39,
#   'price_btc': 0.00060511,
#   'price_usd': 4.98211,
#   'rank': 88,
#   'symbol': 'BNT',
#   'total_supply': 74962423.0},
#  {'24h_volume_usd': 18523600.0,
#   'available_supply': 617314171.0,
#   'id': 'quantstamp',
#   'last_updated': 1518183257,
#   'market_cap_usd': 191013672.0,
#   'max_supply': None,
#   'name': 'Quantstamp',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': -1.26,
#   'percent_change_7d': 25.36,
#   'price_btc': 3.758e-05,
#   'price_usd': 0.309427,
#   'rank': 89,
#   'symbol': 'QSP',
#   'total_supply': 976442388.0},
#  {'24h_volume_usd': 6661200.0,
#   'available_supply': 74836171.0,
#   'id': 'enigma-project',
#   'last_updated': 1518183255,
#   'market_cap_usd': 187505768.0,
#   'max_supply': None,
#   'name': 'Enigma',
#   'percent_change_1h': -0.52,
#   'percent_change_24h': 1.37,
#   'percent_change_7d': 0.15,
#   'price_btc': 0.00030431,
#   'price_usd': 2.50555,
#   'rank': 90,
#   'symbol': 'ENG',
#   'total_supply': 150000000.0},
#  {'24h_volume_usd': 1250470.0,
#   'available_supply': 454443782.0,
#   'id': 'singularitynet',
#   'last_updated': 1518183260,
#   'market_cap_usd': 186629609.0,
#   'max_supply': None,
#   'name': 'SingularityNET',
#   'percent_change_1h': -1.66,
#   'percent_change_24h': -4.62,
#   'percent_change_7d': -18.89,
#   'price_btc': 4.988e-05,
#   'price_usd': 0.410677,
#   'rank': 91,
#   'symbol': 'AGI',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 2869830.0,
#   'available_supply': 1000000000.0,
#   'id': 'xplay',
#   'last_updated': 1518183254,
#   'market_cap_usd': 185315000.0,
#   'max_supply': None,
#   'name': 'XPlay',
#   'percent_change_1h': -0.06,
#   'percent_change_24h': 15.93,
#   'percent_change_7d': 31.92,
#   'price_btc': 2.251e-05,
#   'price_usd': 0.185315,
#   'rank': 92,
#   'symbol': 'XPA',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 1798300.0,
#   'available_supply': 452552412.0,
#   'id': 'maidsafecoin',
#   'last_updated': 1518183243,
#   'market_cap_usd': 184689807.0,
#   'max_supply': None,
#   'name': 'MaidSafeCoin',
#   'percent_change_1h': 0.39,
#   'percent_change_24h': -2.58,
#   'percent_change_7d': 3.3,
#   'price_btc': 4.957e-05,
#   'price_usd': 0.408107,
#   'rank': 93,
#   'symbol': 'MAID',
#   'total_supply': 452552412.0},
#  {'24h_volume_usd': 8094510.0,
#   'available_supply': 998999942.0,
#   'id': 'nxt',
#   'last_updated': 1518183241,
#   'market_cap_usd': 183505300.0,
#   'max_supply': 1000000000.0,
#   'name': 'Nxt',
#   'percent_change_1h': 0.43,
#   'percent_change_24h': 0.59,
#   'percent_change_7d': -11.45,
#   'price_btc': 2.231e-05,
#   'price_usd': 0.183689,
#   'rank': 94,
#   'symbol': 'NXT',
#   'total_supply': 998999942.0},
#  {'24h_volume_usd': 6129330.0,
#   'available_supply': 641462769.0,
#   'id': 'request-network',
#   'last_updated': 1518183255,
#   'market_cap_usd': 181737949.0,
#   'max_supply': None,
#   'name': 'Request Network',
#   'percent_change_1h': 0.06,
#   'percent_change_24h': -1.63,
#   'percent_change_7d': -6.5,
#   'price_btc': 3.441e-05,
#   'price_usd': 0.283318,
#   'rank': 95,
#   'symbol': 'REQ',
#   'total_supply': 999999999.0},
#  {'24h_volume_usd': 3087570.0,
#   'available_supply': 28740055495.0,
#   'id': 'reddcoin',
#   'last_updated': 1518183241,
#   'market_cap_usd': 174209283.0,
#   'max_supply': None,
#   'name': 'ReddCoin',
#   'percent_change_1h': -0.22,
#   'percent_change_24h': -6.42,
#   'percent_change_7d': -6.17,
#   'price_btc': 7.4e-07,
#   'price_usd': 0.00606155,
#   'rank': 96,
#   'symbol': 'RDD',
#   'total_supply': 28740055495.0},
#  {'24h_volume_usd': 552563.0,
#   'available_supply': 55510926.0,
#   'id': 'nexus',
#   'last_updated': 1518183243,
#   'market_cap_usd': 172196002.0,
#   'max_supply': None,
#   'name': 'Nexus',
#   'percent_change_1h': -3.31,
#   'percent_change_24h': -4.26,
#   'percent_change_7d': -8.57,
#   'price_btc': 0.00037676,
#   'price_usd': 3.10202,
#   'rank': 97,
#   'symbol': 'NXS',
#   'total_supply': 55510926.0},
#  {'24h_volume_usd': 10646500.0,
#   'available_supply': 761143950.0,
#   'id': 'ignis',
#   'last_updated': 1518183257,
#   'market_cap_usd': 170226039.0,
#   'max_supply': 999449694.0,
#   'name': 'Ignis',
#   'percent_change_1h': 2.37,
#   'percent_change_24h': 9.73,
#   'percent_change_7d': -11.53,
#   'price_btc': 2.716e-05,
#   'price_usd': 0.223645,
#   'rank': 98,
#   'symbol': 'IGNIS',
#   'total_supply': 999449694.0},
#  {'24h_volume_usd': 3605690.0,
#   'available_supply': 104661310.0,
#   'id': 'tenx',
#   'last_updated': 1518183251,
#   'market_cap_usd': 168279687.0,
#   'max_supply': None,
#   'name': 'TenX',
#   'percent_change_1h': -0.43,
#   'percent_change_24h': 0.53,
#   'percent_change_7d': -9.32,
#   'price_btc': 0.00019528,
#   'price_usd': 1.60785,
#   'rank': 99,
#   'symbol': 'PAY',
#   'total_supply': 205218256.0},
#  {'24h_volume_usd': 1238300.0,
#   'available_supply': 99735687.0,
#   'id': 'iconomi',
#   'last_updated': 1518183248,
#   'market_cap_usd': 165939238.0,
#   'max_supply': None,
#   'name': 'Iconomi',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': 0.13,
#   'percent_change_7d': -10.71,
#   'price_btc': 0.00020208,
#   'price_usd': 1.66379,
#   'rank': 100,
#   'symbol': 'ICN',
#   'total_supply': 99735687.0},
#  {'24h_volume_usd': 16510700.0,
#   'available_supply': 342699966.0,
#   'id': 'civic',
#   'last_updated': 1518183252,
#   'market_cap_usd': 158846917.0,
#   'max_supply': None,
#   'name': 'Civic',
#   'percent_change_1h': 0.18,
#   'percent_change_24h': -12.77,
#   'percent_change_7d': 14.09,
#   'price_btc': 5.63e-05,
#   'price_usd': 0.463516,
#   'rank': 101,
#   'symbol': 'CVC',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 3889330.0,
#   'available_supply': 492954537.0,
#   'id': 'wax',
#   'last_updated': 1518183258,
#   'market_cap_usd': 157533482.0,
#   'max_supply': None,
#   'name': 'WAX',
#   'percent_change_1h': 1.18,
#   'percent_change_24h': -4.2,
#   'percent_change_7d': -3.58,
#   'price_btc': 3.881e-05,
#   'price_usd': 0.31957,
#   'rank': 102,
#   'symbol': 'WAX',
#   'total_supply': 1850000000.0},
#  {'24h_volume_usd': 948395.0,
#   'available_supply': 41281846.0,
#   'id': 'emercoin',
#   'last_updated': 1518183243,
#   'market_cap_usd': 154425892.0,
#   'max_supply': None,
#   'name': 'Emercoin',
#   'percent_change_1h': -0.99,
#   'percent_change_24h': -11.61,
#   'percent_change_7d': -2.48,
#   'price_btc': 0.00045434,
#   'price_usd': 3.74077,
#   'rank': 103,
#   'symbol': 'EMC',
#   'total_supply': 41281846.0},
#  {'24h_volume_usd': 431121.0,
#   'available_supply': 1104590.0,
#   'id': 'gnosis-gno',
#   'last_updated': 1518183250,
#   'market_cap_usd': 154377498.0,
#   'max_supply': None,
#   'name': 'Gnosis',
#   'percent_change_1h': -0.16,
#   'percent_change_24h': -3.14,
#   'percent_change_7d': -8.64,
#   'price_btc': 0.0169747,
#   'price_usd': 139.76,
#   'rank': 104,
#   'symbol': 'GNO',
#   'total_supply': 10000000.0},
#  {'24h_volume_usd': 1691150.0,
#   'available_supply': 64355352.0,
#   'id': 'gamecredits',
#   'last_updated': 1518183245,
#   'market_cap_usd': 150094057.0,
#   'max_supply': 84000000.0,
#   'name': 'GameCredits',
#   'percent_change_1h': -0.46,
#   'percent_change_24h': -2.01,
#   'percent_change_7d': -5.51,
#   'price_btc': 0.00028327,
#   'price_usd': 2.33227,
#   'rank': 105,
#   'symbol': 'GAME',
#   'total_supply': 64355352.0},
#  {'24h_volume_usd': 663614.0,
#   'available_supply': 213734052158,
#   'id': 'experience-points',
#   'last_updated': 1518183247,
#   'market_cap_usd': 149335769.0,
#   'max_supply': None,
#   'name': 'Experience Points',
#   'percent_change_1h': -5.31,
#   'percent_change_24h': -6.01,
#   'percent_change_7d': 48.45,
#   'price_btc': 8e-08,
#   'price_usd': 0.000698699,
#   'rank': 106,
#   'symbol': 'XP',
#   'total_supply': 248765820023},
#  {'24h_volume_usd': 3237960.0,
#   'available_supply': 12800945.0,
#   'id': 'neblio',
#   'last_updated': 1518183254,
#   'market_cap_usd': 148306623.0,
#   'max_supply': None,
#   'name': 'Neblio',
#   'percent_change_1h': -0.09,
#   'percent_change_24h': -1.41,
#   'percent_change_7d': -7.66,
#   'price_btc': 0.00140713,
#   'price_usd': 11.5856,
#   'rank': 107,
#   'symbol': 'NEBL',
#   'total_supply': 13547205.0},
#  {'24h_volume_usd': 4354280.0,
#   'available_supply': 226091449.0,
#   'id': 'substratum',
#   'last_updated': 1518183254,
#   'market_cap_usd': 147326388.0,
#   'max_supply': None,
#   'name': 'Substratum',
#   'percent_change_1h': 0.12,
#   'percent_change_24h': -2.0,
#   'percent_change_7d': 10.26,
#   'price_btc': 7.914e-05,
#   'price_usd': 0.651623,
#   'rank': 108,
#   'symbol': 'SUB',
#   'total_supply': 352000000.0},
#  {'24h_volume_usd': 5289640.0,
#   'available_supply': 350000000.0,
#   'id': 'chainlink',
#   'last_updated': 1518183253,
#   'market_cap_usd': 144185650.0,
#   'max_supply': None,
#   'name': 'ChainLink',
#   'percent_change_1h': -0.51,
#   'percent_change_24h': -2.56,
#   'percent_change_7d': -5.01,
#   'price_btc': 5.003e-05,
#   'price_usd': 0.411959,
#   'rank': 109,
#   'symbol': 'LINK',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 4142880.0,
#   'available_supply': 50148936.0,
#   'id': 'raiden-network-token',
#   'last_updated': 1518183257,
#   'market_cap_usd': 140046922.0,
#   'max_supply': None,
#   'name': 'Raiden Network Token',
#   'percent_change_1h': 0.51,
#   'percent_change_24h': -2.16,
#   'percent_change_7d': -8.33,
#   'price_btc': 0.00033918,
#   'price_usd': 2.79262,
#   'rank': 110,
#   'symbol': 'RDN',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 6767120.0,
#   'available_supply': 22216600.0,
#   'id': 'high-performance-blockchain',
#   'last_updated': 1518183258,
#   'market_cap_usd': 135715877.0,
#   'max_supply': None,
#   'name': 'High Performance Blockchain',
#   'percent_change_1h': -0.45,
#   'percent_change_24h': -4.78,
#   'percent_change_7d': -9.75,
#   'price_btc': 0.00074194,
#   'price_usd': 6.10876,
#   'rank': 111,
#   'symbol': 'HPB',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 2063740.0,
#   'available_supply': 42853650.0,
#   'id': 'vertcoin',
#   'last_updated': 1518183254,
#   'market_cap_usd': 135529382.0,
#   'max_supply': 84000000.0,
#   'name': 'Vertcoin',
#   'percent_change_1h': 0.02,
#   'percent_change_24h': 2.2,
#   'percent_change_7d': 8.0,
#   'price_btc': 0.00038412,
#   'price_usd': 3.16261,
#   'rank': 112,
#   'symbol': 'VTC',
#   'total_supply': 42853650.0},
#  {'24h_volume_usd': 72516.1,
#   'available_supply': 1288862.0,
#   'id': 'bitcoindark',
#   'last_updated': 1518183243,
#   'market_cap_usd': 134210508.0,
#   'max_supply': None,
#   'name': 'BitcoinDark',
#   'percent_change_1h': -0.69,
#   'percent_change_24h': 5.62,
#   'percent_change_7d': 2.79,
#   'price_btc': 0.0126473,
#   'price_usd': 104.131,
#   'rank': 113,
#   'symbol': 'BTCD',
#   'total_supply': 1288862.0},
#  {'24h_volume_usd': 248449.0,
#   'available_supply': 5007164.0,
#   'id': 'blocknet',
#   'last_updated': 1518183244,
#   'market_cap_usd': 133573111.0,
#   'max_supply': None,
#   'name': 'Blocknet',
#   'percent_change_1h': 0.11,
#   'percent_change_24h': -2.16,
#   'percent_change_7d': -6.61,
#   'price_btc': 0.00324,
#   'price_usd': 26.6764,
#   'rank': 114,
#   'symbol': 'BLOCK',
#   'total_supply': 5007164.0},
#  {'24h_volume_usd': 15153700.0,
#   'available_supply': 133425493.0,
#   'id': 'storj',
#   'last_updated': 1518183251,
#   'market_cap_usd': 130635432.0,
#   'max_supply': None,
#   'name': 'Storj',
#   'percent_change_1h': -0.07,
#   'percent_change_24h': -0.15,
#   'percent_change_7d': 4.25,
#   'price_btc': 0.00011892,
#   'price_usd': 0.979089,
#   'rank': 115,
#   'symbol': 'STORJ',
#   'total_supply': 424999998.0},
#  {'24h_volume_usd': 400951.0,
#   'available_supply': 82500000.0,
#   'id': 'paypie',
#   'last_updated': 1518183255,
#   'market_cap_usd': 130346700.0,
#   'max_supply': 165000000.0,
#   'name': 'PayPie',
#   'percent_change_1h': -6.16,
#   'percent_change_24h': -0.86,
#   'percent_change_7d': 4.91,
#   'price_btc': 0.0001919,
#   'price_usd': 1.57996,
#   'rank': 116,
#   'symbol': 'PPP',
#   'total_supply': 165000000.0},
#  {'24h_volume_usd': 78498100.0,
#   'available_supply': 165000000.0,
#   'id': 'bluzelle',
#   'last_updated': 1518183260,
#   'market_cap_usd': 130122465.0,
#   'max_supply': None,
#   'name': 'Bluzelle',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': -1.85,
#   'percent_change_7d': None,
#   'price_btc': 9.578e-05,
#   'price_usd': 0.788621,
#   'rank': 117,
#   'symbol': 'BLZ',
#   'total_supply': 500000000.0},
#  {'24h_volume_usd': 1476610.0,
#   'available_supply': 2966384100.0,
#   'id': 'medibloc',
#   'last_updated': 1518183258,
#   'market_cap_usd': 129471690.0,
#   'max_supply': 10000000000.0,
#   'name': 'MediBloc',
#   'percent_change_1h': -0.01,
#   'percent_change_24h': -3.64,
#   'percent_change_7d': -7.85,
#   'price_btc': 5.3e-06,
#   'price_usd': 0.0436463,
#   'rank': 118,
#   'symbol': 'MED',
#   'total_supply': 4097545844.0},
#  {'24h_volume_usd': 31049.6,
#   'available_supply': 816061.0,
#   'id': 'supernet-unity',
#   'last_updated': 1518183245,
#   'market_cap_usd': 128589145.0,
#   'max_supply': None,
#   'name': 'SuperNET',
#   'percent_change_1h': -0.75,
#   'percent_change_24h': 7.03,
#   'percent_change_7d': 42.49,
#   'price_btc': 0.0191382,
#   'price_usd': 157.573,
#   'rank': 119,
#   'symbol': 'UNITY',
#   'total_supply': 816061.0},
#  {'24h_volume_usd': 1180840.0,
#   'available_supply': 3180125.0,
#   'id': 'zencash',
#   'last_updated': 1518183250,
#   'market_cap_usd': 125937084.0,
#   'max_supply': 21000000.0,
#   'name': 'ZenCash',
#   'percent_change_1h': -1.71,
#   'percent_change_24h': -7.49,
#   'percent_change_7d': 9.28,
#   'price_btc': 0.0048098,
# ...
#   'percent_change_24h': -9.88,
#   'percent_change_7d': 29.32,
#   'price_btc': 5e-08,
#   'price_usd': 0.000450126,
#   'rank': 960,
#   'symbol': 'BIGUP',
#   'total_supply': 2136444447.0},
#  {'24h_volume_usd': 451.83,
#   'available_supply': 104740.0,
#   'id': 'triangles',
#   'last_updated': 1518183244,
#   'market_cap_usd': 955345.0,
#   'max_supply': None,
#   'name': 'Triangles',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': -20.26,
#   'percent_change_7d': 0.45,
#   'price_btc': 0.00110781,
#   'price_usd': 9.12111,
#   'rank': 961,
#   'symbol': 'TRI',
#   'total_supply': 104740.0},
#  {'24h_volume_usd': 480.796,
#   'available_supply': 15541550.0,
#   'id': 'universe',
#   'last_updated': 1518183250,
#   'market_cap_usd': 950748.0,
#   'max_supply': None,
#   'name': 'Universe',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': None,
#   'percent_change_7d': -26.48,
#   'price_btc': 7.43e-06,
#   'price_usd': 0.0611746,
#   'rank': 962,
#   'symbol': 'UNI',
#   'total_supply': 26741550.0},
#  {'24h_volume_usd': 254.94,
#   'available_supply': 4773.0,
#   'id': 'sovereign-hero',
#   'last_updated': 1518183252,
#   'market_cap_usd': 936434.0,
#   'max_supply': None,
#   'name': 'Sovereign Hero',
#   'percent_change_1h': -0.73,
#   'percent_change_24h': 5.61,
#   'percent_change_7d': 10.99,
#   'price_btc': 0.0238288,
#   'price_usd': 196.194,
#   'rank': 963,
#   'symbol': 'HERO',
#   'total_supply': 4773.0},
#  {'24h_volume_usd': 55.8126,
#   'available_supply': 24101381.0,
#   'id': 'gaia',
#   'last_updated': 1518183243,
#   'market_cap_usd': 912813.0,
#   'max_supply': None,
#   'name': 'GAIA',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': -11.22,
#   'percent_change_7d': 5.91,
#   'price_btc': 4.6e-06,
#   'price_usd': 0.0378739,
#   'rank': 964,
#   'symbol': 'GAIA',
#   'total_supply': 24101381.0},
#  {'24h_volume_usd': 25.0922,
#   'available_supply': 8035193.0,
#   'id': 'woodcoin',
#   'last_updated': 1518183244,
#   'market_cap_usd': 899082.0,
#   'max_supply': None,
#   'name': 'Woodcoin',
#   'percent_change_1h': -0.0,
#   'percent_change_24h': -20.04,
#   'percent_change_7d': -2.69,
#   'price_btc': 1.359e-05,
#   'price_usd': 0.111893,
#   'rank': 965,
#   'symbol': 'LOG',
#   'total_supply': 8035193.0},
#  {'24h_volume_usd': 59.0983,
#   'available_supply': 23079737.0,
#   'id': 'bitstar',
#   'last_updated': 1518183243,
#   'market_cap_usd': 888794.0,
#   'max_supply': None,
#   'name': 'Bitstar',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': -3.38,
#   'percent_change_7d': -20.42,
#   'price_btc': 4.68e-06,
#   'price_usd': 0.0385097,
#   'rank': 966,
#   'symbol': 'BITS',
#   'total_supply': 23079737.0},
#  {'24h_volume_usd': 275.129,
#   'available_supply': 64151405.0,
#   'id': 'hobonickels',
#   'last_updated': 1518183241,
#   'market_cap_usd': 887355.0,
#   'max_supply': 120000000.0,
#   'name': 'HoboNickels',
#   'percent_change_1h': 0.64,
#   'percent_change_24h': 2.91,
#   'percent_change_7d': -17.71,
#   'price_btc': 1.68e-06,
#   'price_usd': 0.0138322,
#   'rank': 967,
#   'symbol': 'HBN',
#   'total_supply': 64151405.0},
#  {'24h_volume_usd': 59.2887,
#   'available_supply': 1.0,
#   'id': 'bit20',
#   'last_updated': 1518183252,
#   'market_cap_usd': 860533.0,
#   'max_supply': None,
#   'name': 'Bit20',
#   'percent_change_1h': -0.48,
#   'percent_change_24h': -1.23,
#   'percent_change_7d': 1.83,
#   'price_btc': 102.871,
#   'price_usd': 846981.0,
#   'rank': 968,
#   'symbol': 'BTWTY',
#   'total_supply': 1.0},
#  {'24h_volume_usd': 493.678,
#   'available_supply': 75000000.0,
#   'id': 'bitpark-coin',
#   'last_updated': 1518183248,
#   'market_cap_usd': 837720.0,
#   'max_supply': None,
#   'name': 'Bitpark Coin',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': 2.27,
#   'percent_change_7d': -34.6,
#   'price_btc': 1.36e-06,
#   'price_usd': 0.0111696,
#   'rank': 969,
#   'symbol': 'BPC',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 487.456,
#   'available_supply': 50936231.0,
#   'id': 'visio',
#   'last_updated': 1518183249,
#   'market_cap_usd': 797239.0,
#   'max_supply': None,
#   'name': 'Visio',
#   'percent_change_1h': -2.07,
#   'percent_change_24h': -3.05,
#   'percent_change_7d': -22.67,
#   'price_btc': 1.9e-06,
#   'price_usd': 0.0156517,
#   'rank': 970,
#   'symbol': 'VISIO',
#   'total_supply': 62936231.0},
#  {'24h_volume_usd': 43.9098,
#   'available_supply': 3284266.0,
#   'id': 'btsr',
#   'last_updated': 1518183246,
#   'market_cap_usd': 780959.0,
#   'max_supply': None,
#   'name': 'BTSR',
#   'percent_change_1h': -0.52,
#   'percent_change_24h': 160.05,
#   'percent_change_7d': -3.59,
#   'price_btc': 2.888e-05,
#   'price_usd': 0.237788,
#   'rank': 971,
#   'symbol': 'BTSR',
#   'total_supply': 3284266.0},
#  {'24h_volume_usd': 310.198,
#   'available_supply': 65290635.0,
#   'id': 'btctalkcoin',
#   'last_updated': 1518183242,
#   'market_cap_usd': 779472.0,
#   'max_supply': None,
#   'name': 'BTCtalkcoin',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': None,
#   'percent_change_7d': 10.88,
#   'price_btc': 1.45e-06,
#   'price_usd': 0.0119385,
#   'rank': 972,
#   'symbol': 'TALK',
#   'total_supply': 65290635.0},
#  {'24h_volume_usd': 241.116,
#   'available_supply': 318929301.0,
#   'id': 'nyancoin',
#   'last_updated': 1518183241,
#   'market_cap_usd': 759843.0,
#   'max_supply': 337000000.0,
#   'name': 'Nyancoin',
#   'percent_change_1h': -6.32,
#   'percent_change_24h': -6.72,
#   'percent_change_7d': -15.28,
#   'price_btc': 2.9e-07,
#   'price_usd': 0.00238248,
#   'rank': 973,
#   'symbol': 'NYAN',
#   'total_supply': 318929301.0},
#  {'24h_volume_usd': None,
#   'available_supply': 23020335.0,
#   'id': 'janus',
#   'last_updated': 1517536153,
#   'market_cap_usd': 744390.0,
#   'max_supply': None,
#   'name': 'Janus',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': None,
#   'price_btc': 3.72e-06,
#   'price_usd': 0.0323362,
#   'rank': 974,
#   'symbol': 'JNS',
#   'total_supply': 25201489.0},
#  {'24h_volume_usd': 311.19,
#   'available_supply': 61445805.0,
#   'id': 'maxcoin',
#   'last_updated': 1518183241,
#   'market_cap_usd': 682982.0,
#   'max_supply': None,
#   'name': 'MaxCoin',
#   'percent_change_1h': -3.62,
#   'percent_change_24h': None,
#   'percent_change_7d': 1.23,
#   'price_btc': 1.35e-06,
#   'price_usd': 0.0111152,
#   'rank': 975,
#   'symbol': 'MAX',
#   'total_supply': 61445805.0},
#  {'24h_volume_usd': 385.806,
#   'available_supply': 50201886.0,
#   'id': 'amsterdamcoin',
#   'last_updated': 1518183245,
#   'market_cap_usd': 681255.0,
#   'max_supply': None,
#   'name': 'AmsterdamCoin',
#   'percent_change_1h': 8.15,
#   'percent_change_24h': 34.72,
#   'percent_change_7d': 24.3,
#   'price_btc': 1.65e-06,
#   'price_usd': 0.0135703,
#   'rank': 976,
#   'symbol': 'AMS',
#   'total_supply': 81469427.0},
#  {'24h_volume_usd': 168.027,
#   'available_supply': 107972766.0,
#   'id': 'signatum',
#   'last_updated': 1518183252,
#   'market_cap_usd': 666742.0,
#   'max_supply': None,
#   'name': 'Signatum',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': None,
#   'percent_change_7d': -1.28,
#   'price_btc': 7.5e-07,
#   'price_usd': 0.00617509,
#   'rank': 977,
#   'symbol': 'SIGT',
#   'total_supply': 107972766.0},
#  {'24h_volume_usd': 4.10915,
#   'available_supply': 1990891.0,
#   'id': 'bitz',
#   'last_updated': 1518183244,
#   'market_cap_usd': 655676.0,
#   'max_supply': None,
#   'name': 'Bitz',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': None,
#   'percent_change_7d': -14.79,
#   'price_btc': 4e-05,
#   'price_usd': 0.329338,
#   'rank': 978,
#   'symbol': 'BITZ',
#   'total_supply': 1990891.0},
#  {'24h_volume_usd': 213.865,
#   'available_supply': 196335.0,
#   'id': 'prototanium',
#   'last_updated': 1518183246,
#   'market_cap_usd': 646606.0,
#   'max_supply': None,
#   'name': 'Prototanium',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': -9.43,
#   'percent_change_7d': -3.32,
#   'price_btc': 0.0004,
#   'price_usd': 3.29338,
#   'rank': 979,
#   'symbol': 'PR',
#   'total_supply': 196335.0},
#  {'24h_volume_usd': 292.231,
#   'available_supply': 169161472.0,
#   'id': 'truckcoin',
#   'last_updated': 1518183243,
#   'market_cap_usd': 640680.0,
#   'max_supply': None,
#   'name': 'Truckcoin',
#   'percent_change_1h': 2.17,
#   'percent_change_24h': 14.52,
#   'percent_change_7d': -1.31,
#   'price_btc': 4.6e-07,
#   'price_usd': 0.00378739,
#   'rank': 980,
#   'symbol': 'TRK',
#   'total_supply': 169161472.0},
#  {'24h_volume_usd': 82.3346,
#   'available_supply': 210806.0,
#   'id': 'flycoin',
#   'last_updated': 1518183245,
#   'market_cap_usd': 633030.0,
#   'max_supply': None,
#   'name': 'Flycoin',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': None,
#   'percent_change_7d': 0.87,
#   'price_btc': 0.00036472,
#   'price_usd': 3.00291,
#   'rank': 981,
#   'symbol': 'FLY',
#   'total_supply': 210806.0},
#  {'24h_volume_usd': 235.477,
#   'available_supply': 353562.0,
#   'id': 'swagbucks',
#   'last_updated': 1518183246,
#   'market_cap_usd': 628258.0,
#   'max_supply': None,
#   'name': 'SwagBucks',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': -6.87,
#   'percent_change_7d': -10.45,
#   'price_btc': 0.00021582,
#   'price_usd': 1.77694,
#   'rank': 982,
#   'symbol': 'BUCKS',
#   'total_supply': 353562.0},
#  {'24h_volume_usd': 198.447,
#   'available_supply': 64018545.0,
#   'id': 'phoenixcoin',
#   'last_updated': 1518183241,
#   'market_cap_usd': 621971.0,
#   'max_supply': None,
#   'name': 'Phoenixcoin',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': -7.99,
#   'percent_change_7d': -3.23,
#   'price_btc': 1.18e-06,
#   'price_usd': 0.00971548,
#   'rank': 983,
#   'symbol': 'PXC',
#   'total_supply': 64018545.0},
#  {'24h_volume_usd': 261.445,
#   'available_supply': 77777777.0,
#   'id': 'ammo-rewards',
#   'last_updated': 1518183251,
#   'market_cap_usd': 582746.0,
#   'max_supply': None,
#   'name': 'Ammo Reloaded',
#   'percent_change_1h': -4.82,
#   'percent_change_24h': -9.16,
#   'percent_change_7d': -7.99,
#   'price_btc': 9.1e-07,
#   'price_usd': 0.00749245,
#   'rank': 984,
#   'symbol': 'AMMO',
#   'total_supply': 77777777.0},
#  {'24h_volume_usd': 3.61827,
#   'available_supply': 2358819009.0,
#   'id': 'colossuscoin-v2',
#   'last_updated': 1518183244,
#   'market_cap_usd': 582638.0,
#   'max_supply': None,
#   'name': 'Colossuscoin V2',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': None,
#   'percent_change_7d': 45.1,
#   'price_btc': 3e-08,
#   'price_usd': 0.000247004,
#   'rank': 985,
#   'symbol': 'CV2',
#   'total_supply': 22977351798.0},
#  {'24h_volume_usd': 141.216,
#   'available_supply': 43536800.0,
#   'id': 'tigercoin',
#   'last_updated': 1518183241,
#   'market_cap_usd': 577119.0,
#   'max_supply': None,
#   'name': 'Tigercoin',
#   'percent_change_1h': 23.79,
#   'percent_change_24h': 19.33,
#   'percent_change_7d': -9.69,
#   'price_btc': 1.61e-06,
#   'price_usd': 0.0132559,
#   'rank': 986,
#   'symbol': 'TGC',
#   'total_supply': 43536800.0},
#  {'24h_volume_usd': 68.9895,
#   'available_supply': 169598616.0,
#   'id': 'bitcurrency',
#   'last_updated': 1518183248,
#   'market_cap_usd': 572517.0,
#   'max_supply': None,
#   'name': 'Bitcurrency',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': None,
#   'percent_change_7d': -50.88,
#   'price_btc': 4.1e-07,
#   'price_usd': 0.00337572,
#   'rank': 987,
#   'symbol': 'BTCR',
#   'total_supply': 169598616.0},
#  {'24h_volume_usd': 1.21855,
#   'available_supply': 90421856.0,
#   'id': 'tattoocoin',
#   'last_updated': 1518183249,
#   'market_cap_usd': 550919.0,
#   'max_supply': None,
#   'name': 'Tattoocoin (Standard Edition)',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': -8.83,
#   'percent_change_7d': -5.81,
#   'price_btc': 7.4e-07,
#   'price_usd': 0.00609276,
#   'rank': 988,
#   'symbol': 'TSE',
#   'total_supply': 90421856.0},
#  {'24h_volume_usd': 210.747,
#   'available_supply': 9436367.0,
#   'id': 'mineum',
#   'last_updated': 1518183247,
#   'market_cap_usd': 525277.0,
#   'max_supply': None,
#   'name': 'Mineum',
#   'percent_change_1h': -2.78,
#   'percent_change_24h': -3.92,
#   'percent_change_7d': -0.69,
#   'price_btc': 6.76e-06,
#   'price_usd': 0.0556652,
#   'rank': 989,
#   'symbol': 'MNM',
#   'total_supply': 9586367.0},
#  {'24h_volume_usd': 3.51733,
#   'available_supply': 6097570882.0,
#   'id': 'valorbit',
#   'last_updated': 1518183246,
#   'market_cap_usd': 502041.0,
#   'max_supply': None,
#   'name': 'Valorbit',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': None,
#   'percent_change_7d': -3.27,
#   'price_btc': 1e-08,
#   'price_usd': 8.23346e-05,
#   'rank': 990,
#   'symbol': 'VAL',
#   'total_supply': 922343297570882},
#  {'24h_volume_usd': 9.15152,
#   'available_supply': 21948.0,
#   'id': 'bitsilver',
#   'last_updated': 1518183244,
#   'market_cap_usd': 481666.0,
#   'max_supply': None,
#   'name': 'bitSilver',
#   'percent_change_1h': -1.4,
#   'percent_change_24h': 18.5,
#   'percent_change_7d': 20.5,
#   'price_btc': 0.00266545,
#   'price_usd': 21.9459,
#   'rank': 991,
#   'symbol': 'BITSILVER',
#   'total_supply': 21948.0},
#  {'24h_volume_usd': 81.341,
#   'available_supply': 5428300.0,
#   'id': 'blockpay',
#   'last_updated': 1518183247,
#   'market_cap_usd': 474691.0,
#   'max_supply': None,
#   'name': 'BlockPay',
#   'percent_change_1h': -0.74,
#   'percent_change_24h': -1.9,
#   'percent_change_7d': -30.15,
#   'price_btc': 1.062e-05,
#   'price_usd': 0.0874475,
#   'rank': 992,
#   'symbol': 'BLOCKPAY',
#   'total_supply': 98928316.0},
#  {'24h_volume_usd': 32.6551,
#   'available_supply': 65171010.0,
#   'id': 'globalcoin',
#   'last_updated': 1518183240,
#   'market_cap_usd': 472193.0,
#   'max_supply': None,
#   'name': 'GlobalCoin',
#   'percent_change_1h': -0.0,
#   'percent_change_24h': None,
#   'percent_change_7d': -4.82,
#   'price_btc': 8.8e-07,
#   'price_usd': 0.00724544,
#   'rank': 993,
#   'symbol': 'GLC',
#   'total_supply': 65171010.0},
#  {'24h_volume_usd': 156.176,
#   'available_supply': 9497141.0,
#   'id': 'bitquark',
#   'last_updated': 1518183243,
#   'market_cap_usd': 466038.0,
#   'max_supply': None,
#   'name': 'BitQuark',
#   'percent_change_1h': 61.0,
#   'percent_change_24h': 57.25,
#   'percent_change_7d': -42.66,
#   'price_btc': 5.96e-06,
#   'price_usd': 0.0490714,
#   'rank': 994,
#   'symbol': 'BTQ',
#   'total_supply': 9497141.0},
#  {'24h_volume_usd': 346.876,
#   'available_supply': 73729962.0,
#   'id': 'chronos',
#   'last_updated': 1518183247,
#   'market_cap_usd': 461482.0,
#   'max_supply': None,
#   'name': 'Chronos',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': -13.0,
#   'percent_change_7d': -15.93,
#   'price_btc': 7.6e-07,
#   'price_usd': 0.00625909,
#   'rank': 995,
#   'symbol': 'CRX',
#   'total_supply': 73729962.0},
#  {'24h_volume_usd': 280.22,
#   'available_supply': 7089137.0,
#   'id': 'sativacoin',
#   'last_updated': 1518183244,
#   'market_cap_usd': 451769.0,
#   'max_supply': None,
#   'name': 'Sativacoin',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': -7.9,
#   'percent_change_7d': -12.16,
#   'price_btc': 7.74e-06,
#   'price_usd': 0.063727,
#   'rank': 996,
#   'symbol': 'STV',
#   'total_supply': 7089137.0},
#  {'24h_volume_usd': 64.0411,
#   'available_supply': 10291781.0,
#   'id': 'bankcoin',
#   'last_updated': 1518183250,
#   'market_cap_usd': 451761.0,
#   'max_supply': None,
#   'name': 'Bankcoin',
#   'percent_change_1h': 0.56,
#   'percent_change_24h': 6.75,
#   'percent_change_7d': None,
#   'price_btc': 5.33e-06,
#   'price_usd': 0.0438953,
#   'rank': 997,
#   'symbol': 'B@',
#   'total_supply': 25000000.0},
#  {'24h_volume_usd': 351.523,
#   'available_supply': 12480424.0,
#   'id': 'gapcoin',
#   'last_updated': 1518183243,
#   'market_cap_usd': 440827.0,
#   'max_supply': None,
#   'name': 'Gapcoin',
#   'percent_change_1h': 3.68,
#   'percent_change_24h': -1.1,
#   'percent_change_7d': -0.5,
#   'price_btc': 4.29e-06,
#   'price_usd': 0.0353215,
#   'rank': 998,
#   'symbol': 'GAP',
#   'total_supply': 12480424.0},
#  {'24h_volume_usd': 87.5995,
#   'available_supply': 3052017.0,
#   'id': 'joincoin',
#   'last_updated': 1518183243,
#   'market_cap_usd': 427438.0,
#   'max_supply': None,
#   'name': 'Joincoin',
#   'percent_change_1h': -0.06,
#   'percent_change_24h': -15.82,
#   'percent_change_7d': -10.46,
#   'price_btc': 1.701e-05,
#   'price_usd': 0.140051,
#   'rank': 999,
#   'symbol': 'J',
#   'total_supply': 3052017.0},
#  {'24h_volume_usd': 383.405,
#   'available_supply': 17171382.0,
#   'id': 'goldreserve',
#   'last_updated': 1518183244,
#   'market_cap_usd': 424140.0,
#   'max_supply': 40000000.0,
#   'name': 'GoldReserve',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': 19.87,
#   'percent_change_7d': -24.44,
#   'price_btc': 3e-06,
#   'price_usd': 0.0247004,
#   'rank': 1000,
#   'symbol': 'XGR',
#   'total_supply': 17171382.0},
#  ...]

# %% [markdown]
# You can pass a currency through symbol or coin slug:

# %%
data_from_symbol = cmc.ticker("BTC")
data_from_slug = cmc.ticker("bitcoin")

data_from_slug
# Out:
# {'24h_volume_usd': 8107680000.0,
#  'available_supply': 16854700.0,
#  'id': 'bitcoin',
#  'last_updated': 1518183267,
#  'market_cap_usd': 139667651379,
#  'max_supply': 21000000.0,
#  'name': 'Bitcoin',
#  'percent_change_1h': 0.13,
#  'percent_change_24h': -1.93,
#  'percent_change_7d': -2.73,
#  'price_btc': 1.0,
#  'price_usd': 8286.57,
#  'rank': 1,
#  'symbol': 'BTC',
#  'total_supply': 16854700.0}

# %% [markdown]
# To get all symbols and slugs you can use the next attributes:

# %%
all_symbols = cmc.symbols
all_slugs = cmc.coins

all_symbols
# Out:
# ['TAGR',
#  'HEAT',
#  'TKN',
#  'VLT',
#  'BXT',
#  'GAIN',
#  'CWXT',
#  'BTPL',
#  'PRC',
#  'MED',
#  'NMC',
#  'RIYA',
#  'ACT',
#  'DMD',
#  'VUC',
#  'LBC',
#  'GAS',
#  'GRC',
#  'GBYTE',
#  'XJO',
#  'SHORTY',
#  'POLL',
#  'XQN',
#  'EXP',
#  'TGC',
#  'LCP',
#  'RCN',
#  'AIX',
#  'XTO',
#  'VAL',
#  'ENG',
#  'LTH',
#  'ALTC',
#  'ATX',
#  'NEWB',
#  'CC',
#  'GMT',
#  'ALTCOM',
#  'EUSD',
#  'BBP',
#  'STORJ',
#  'XSPEC',
#  'IFT',
#  'AMMO',
#  'POP',
#  'ADX',
#  'ETC',
#  'DBTC',
#  'SBD',
#  'PUT',
#  'NXT',
#  'LA',
#  'WETH',
#  'CNT',
#  'WINGS',
#  'SMC',
#  'DENT',
#  'URC',
#  'PURA',
#  'TEAM',
#  'EGAS',
#  'DOPE',
#  'DEUS',
#  'DOT',
#  'BOT',
#  'RDD',
#  'AUR',
#  'BTB',
#  'XVC',
#  'MTL',
#  'DGB',
#  'SALT',
#  'BLX',
#  'BRAT',
#  'EXRN',
#  'TIT',
#  'BSR',
#  'NGC',
#  'DIX',
#  'ALIS',
#  'ITT',
#  'MND',
#  'SENSE',
#  'EFL',
#  'MRJA',
#  'PRES',
#  'DIBC',
#  'WCT',
#  'ZPT',
#  'IDXM',
#  'NETKO',
#  'EQT',
#  'ADCN',
#  'EKT',
#  'AAC',
#  'LCT',
#  'ARI',
#  'RNT',
#  'ONION',
#  'SIC',
#  'VOX',
#  'OCT',
#  'TSL',
#  'TRAC',
#  'UET',
#  'MTNC',
#  'XGOX',
#  'VOYA',
#  'SKY',
#  'ETBS',
#  'BTCA',
#  'ELTCOIN',
#  'NYAN',
#  'COAL',
#  'VULC',
#  'SIGT',
#  'TOR',
#  'ADT',
#  'BITZ',
#  'B@',
#  'FLAP',
#  'SHDW',
#  'HTC',
#  'BAR',
#  'GXS',
#  'DCT',
#  'MTN',
#  'BNTY',
#  'TEK',
#  'BIOS',
#  'ELE',
#  'TLE',
#  'OF',
#  'PIZZA',
#  'MEME',
#  'GUP',
#  'NTRN',
#  'CRW',
#  'WGR',
#  'KICK',
#  'STN',
#  'BCPT',
#  'POS',
#  'XOT',
#  'DSR',
#  'UQC',
#  'SLS',
#  'CME',
#  'LIR',
#  'SLEVIN',
#  'EGOLD',
#  'XTZ',
#  'RMC',
#  'CREDO',
#  'PAY',
#  'SUB',
#  'EDR',
#  'EFYT',
#  'MGM',
#  'HERO',
#  'STRAT',
#  'MBI',
#  'MAGN',
#  'BLC',
#  'FRST',
#  'HPY',
#  'CVCOIN',
#  '1ST',
#  'PTC',
#  'DMC',
#  'VRM',
#  'TRC',
#  'TNT',
#  'PRS',
#  'HKN',
#  'TOKC',
#  'EPC',
#  'ZENGOLD',
#  'NAV',
#  'OPC',
#  'MUE',
#  'KRB',
#  'PGL',
#  'DCR',
#  'ADC',
#  'ATN',
#  'LEV',
#  'ASN',
#  'OCN',
#  'DRM',
#  'ZUR',
#  'NEOG',
#  'ATMC',
#  'BBR',
#  'TIE',
#  'EBT',
#  'BITUSD',
#  'EVC',
#  'ARG',
#  'USC',
#  'SCORE',
#  'DGPT',
#  'GAIA',
#  'TCR',
#  'HMP',
#  'POLY',
#  'PROC',
#  'BON',
#  'HUSH',
#  'JET',
#  'MVC',
#  'LRC',
#  'FLIXX',
#  'EAG',
#  'XPD',
#  'ONX',
#  'GRWI',
#  'BLZ',
#  'TOK',
#  'MARX',
#  'CANDY',
#  'EDRC',
#  'ECN',
#  'REGA',
#  'CANN',
#  'XMG',
#  'MDA',
#  'CCN',
#  'SSS',
#  'ATB',
#  'EXCL',
#  'CRC',
#  'ETHOS',
#  'KASHH',
#  'THC',
#  'EMC2',
#  'FRC',
#  'BLU',
#  'GRX',
#  'HIGH',
#  'CUBE',
#  'MDS',
#  'IDT',
#  'ARGUS',
#  'PIPL',
#  'CMP',
#  'UNIT',
#  'CARBON',
#  'KRM',
#  'TFL',
#  'ASAFE2',
#  'IVZ',
#  'BTG',
#  'POWR',
#  'KIN',
#  'INPAY',
#  'MAC',
#  'SPF',
#  'DRGN',
#  'VEC2',
#  'BUN',
#  'STEPS',
#  'ERC',
#  'STORM',
#  'NVST',
#  'DUBI',
#  'ACE',
#  'FC',
#  'BSD',
#  'CRED',
#  'POE',
#  'BCDN',
#  'XCP',
#  'RBBT',
#  'CHC',
#  'LUX',
#  'SFE',
#  'BBT',
#  'KAYI',
#  'BENJI',
#  'BLITZ',
#  'HAL',
#  'MONEY',
#  'ELITE',
#  'ELA',
#  'CESC',
#  'FLASH',
#  'KEY',
#  'ORME',
#  'ARY',
#  'UGC',
#  'PCS',
#  'TRF',
#  'BLT',
#  'NMS',
#  'CTX',
#  'ADZ',
#  'ZEN',
#  'MTX',
#  'SLR',
#  'XEM',
#  'HYTV',
#  'BLRY',
#  'NDC',
#  'STC',
#  'EBTC',
#  'SWING',
#  'GP',
#  'XCPO',
#  'XDE2',
#  'VIU',
#  'WGO',
#  'CND',
#  'UKG',
#  'ACC',
#  'CDN',
#  'ADA',
#  'EBST',
#  'CV',
#  'ZRX',
#  'FST',
#  'NAMO',
#  'UNY',
#  'STEX',
#  'ITI',
#  'BMC',
#  'XNN',
#  '1337',
#  'BCX',
#  'DAT',
#  'IND',
#  'RLT',
#  'ZZC',
#  'CFUN',
#  'PEPECASH',
#  'TCC',
#  'XFT',
#  'CAPP',
#  'MAR',
#  'DUTCH',
#  'BLN',
#  'SFC',
#  'BLK',
#  'RKC',
#  'SUMO',
#  'OFF',
#  'SHA',
#  'SPHR',
#  'MLN',
#  'ONG',
#  'ZMC',
#  'DIVX',
#  'RIDE',
#  'SPRTS',
#  'SNGLS',
#  'CCM100',
#  'MAN',
#  'ELTC2',
#  'GTC',
#  'AMB',
#  'BERN',
#  'ACES',
#  'HOT',
#  'FOR',
#  'LET',
#  'CTIC3',
#  'BDL',
#  'PR',
#  'ODN',
#  'B2B',
#  'SMART',
#  'WORM',
#  'OPAL',
#  'PRN',
#  'MINEX',
#  '611',
#  'BLOCKPAY',
#  'PRA',
#  'GLT',
#  'BITS',
#  'HTML',
#  'NBIT',
#  'BTO',
#  'LTCU',
#  'SRN',
#  'EBIT',
#  'TAU',
#  'PEX',
#  'LEPEN',
#  'STU',
#  'OMNI',
#  'CAN',
#  'ALL',
#  'PIVX',
#  'PCOIN',
#  'OAX',
#  'DBET',
#  'CCRB',
#  'UTK',
#  'UNITY',
#  'ATOM',
#  'MONK',
#  'AC',
#  'PKB',
#  'ARCT',
#  'DXT',
#  'XMCC',
#  'QBIC',
#  'CRX',
#  'SMS',
#  'TRUMP',
#  'IPL',
#  'EMV',
#  'PLR',
#  'SOAR',
#  'LDCN',
#  'SHOW',
#  'COB',
#  'HDLB',
#  'PIX',
#  'NTO',
#  'RICHX',
#  'WAX',
#  'GSR',
#  'CEFS',
#  'LVPS',
#  'CCO',
#  'SANDG',
#  'NKA',
#  'JOBS',
#  'CRB',
#  'UNIFY',
#  'SAFEX',
#  'BAS',
#  'TIME',
#  'MBL',
#  'RDN',
#  'MOON',
#  'DRS',
#  'RUP',
#  'I0C',
#  'GMX',
#  'SIB',
#  'SMLY',
#  'XAU',
#  'PCN',
#  'BSTY',
#  'MAID',
#  'BSN',
#  'PTOY',
#  'TCOIN',
#  'YOC',
#  'VSX',
#  'PPP',
#  'STX',
#  'RIC',
#  'TEL',
#  'PLBT',
#  'VEE',
#  'GLD',
#  'KCASH',
#  'XLM',
#  'CAT',
#  'DBC',
#  'GTO',
#  'MOT',
#  'OMC',
#  'MNE',
#  'GB',
#  'ELC',
#  'EOS',
#  'FAP',
#  'LOG',
#  'DNR',
#  'JNS',
#  'BTCD',
#  'KDC',
#  'BAT',
#  'WAND',
#  'AST',
#  'PRX',
#  'SKIN',
#  'EDT',
#  'XOC',
#  'START',
#  'INN',
#  'XPM',
#  'KLN',
#  'FCN',
#  'ECOB',
#  '10MT',
#  'QTUM',
#  'JWL',
#  'MAY',
#  'PARETO',
#  'AERM',
#  'SIGMA',
#  'GNT',
#  'REC',
#  'IGNIS',
#  'ABC',
#  'PAK',
#  'POSW',
#  'EVIL',
#  'IMPS',
#  'OBITS',
#  'HBN',
#  'HTML5',
#  'KMD',
#  'ROC',
#  'X2',
#  'INCNT',
#  'INT',
#  'PND',
#  'ACN',
#  'BOS',
#  'CMT',
#  'FXE',
#  'TIX',
#  'IXC',
#  'AMS',
#  'XVE',
#  'XHI',
#  'HC',
#  'PULSE',
#  'EGO',
#  'DMT',
#  'LAZ',
#  'C20',
#  'FUN',
#  'TIPS',
#  'DASH',
#  'INF',
#  'HONEY',
#  'NKC',
#  'HPC',
#  'SPORT',
#  'ABY',
#  'DTB',
#  'ICE',
#  'WARP',
#  'SJCX',
#  'TRK',
#  'KEK',
#  'PXI',
#  'ARN',
#  'TCT',
#  'TRUE',
#  'MOBI',
#  'CHSB',
#  'METAL',
#  'DAR',
#  'BTA',
#  'PLC',
#  'RBIES',
#  'SWTC',
#  'OP',
#  'TER',
#  'TOP',
#  'MCI',
#  'WABI',
#  'MBRS',
#  'MCRN',
#  'PASC',
#  'GOOD',
#  'KRONE',
#  'SPR',
#  'VLTC',
#  'DRT',
#  'APPC',
#  'ZER',
#  'STA',
#  'HMQ',
#  'SBC',
#  'XST',
#  'TZC',
#  'STARS',
#  'VTC',
#  'ECASH',
#  'QTL',
#  'RCT',
#  'NYC',
#  'ZOI',
#  'MKR',
#  'ITC',
#  'PLNC',
#  'BUZZ',
#  'NOTE',
#  'APC',
#  'CNO',
#  'GAT',
#  'J',
#  'SXC',
#  'BTCS',
#  'STRC',
#  'CFI',
#  'DBIX',
#  'ARK',
#  'FTC',
#  'ROOFS',
#  'TTC',
#  'BIT',
#  'JIYO',
#  'NRO',
#  'HVN',
#  'GIM',
#  'SKR',
#  'ZSC',
#  'BITOK',
#  'COV',
#  'CL',
#  'HBC',
#  'DLT',
#  'AMP',
#  'BTSR',
#  'TIO',
#  'HWC',
#  'TNB',
#  'BQ',
#  'GJC',
#  'CREVA',
#  'DES',
#  'FIRE',
#  '300',
#  'CV2',
#  'LINDA',
#  'ASTRO',
#  'WAVES',
#  'SHND',
#  'MMXVI',
#  'XLR',
#  'HODL',
#  'XPTX',
#  'RED',
#  'UTA',
#  'UNI',
#  'AWR',
#  'FUZZ',
#  'WA',
#  'MNM',
#  'DIME',
#  'XLC',
#  'CPN',
#  'CAB',
#  'RBT',
#  'ICOB',
#  'GRS',
#  'CBX',
#  'STK',
#  'PXS',
#  'AGLC',
#  'WINK',
#  'BRAIN',
#  'UFO',
#  'EREAL',
#  'XBC',
#  'PAYP',
#  'GCR',
#  'DFT',
#  'ADB',
#  'FFC',
#  'HORSE',
#  'FRN',
#  'JINN',
#  'CYP',
#  'NXS',
#  'DRP',
#  'CHAT',
#  'SH',
#  'FLY',
#  'IXT',
#  'ICN',
#  'CXT',
#  'OC',
#  'CRT',
#  'FUCK',
#  'OPT',
#  'CAG',
#  'LINX',
#  'BUB',
#  'WPR',
#  'VTR',
#  'BLAS',
#  'REAL',
#  'GAME',
#  'QRL',
#  'KARMA',
#  'BASH',
#  'ETH',
#  'DCN',
#  'INFX',
#  'USDT',
#  'CDT',
#  'BWK',
#  'CRAVE',
#  'VLC',
#  'UNIC',
#  'THETA',
#  'SYNX',
#  'EOT',
#  'CURE',
#  'DYN',
#  'TKR',
#  'GARY',
#  'ANTI',
#  'HLC',
#  'XCS',
#  'CREA',
#  'GEERT',
#  'BCH',
#  'QBT',
#  'HT',
#  'DAI',
#  'XCT',
#  'TRI',
#  'AION',
#  'AKY',
#  'ICX',
#  'BTC2X',
#  'TRIG',
#  'MARS',
#  'IPC',
#  'QUN',
#  'VASH',
#  'IBTC',
#  'QVT',
#  'FRGC',
#  'VRS',
#  'NEVA',
#  'COFI',
#  'LKK',
#  'BCF',
#  'XRA',
#  'CRM',
#  'XBTC21',
#  'WILD',
#  'ZYD',
#  'DUO',
#  'BAY',
#  'BELA',
#  'BXC',
#  'GBG',
#  'LANA',
#  'CLUB',
#  'HPB',
#  'OTX',
#  'INSN',
#  'BTCZ',
#  'DLISK',
#  'ADK',
#  'CPC',
#  'MYB',
#  'FUTC',
#  'Q2C',
#  'SYS',
#  'LUNA',
#  'BIG',
#  'B2X',
#  'REP',
#  'LBTC',
#  'CFT',
#  'FAZZ',
#  'ENRG',
#  'SOCC',
#  'MCAP',
#  'SSC',
#  'PIRL',
#  'RISE',
#  'MER',
#  'OXY',
#  'BOLI',
#  'TRICK',
#  'PURE',
#  'TODAY',
#  'LIFE',
#  'SBTC',
#  'ORB',
#  'PHO',
#  'FRWC',
#  'XBTS',
#  'BPT',
#  '42',
#  'OMG',
#  'VIDZ',
#  'HDG',
#  'DRPU',
#  'BITBTC',
#  'RAIN',
#  'SOON',
#  'SC',
#  'XMY',
#  'IDH',
#  'BLOCK',
#  'GET',
#  'ICON',
#  'VIBE',
#  'LNK',
#  'ALQO',
#  'VZT',
#  'LTC',
#  'PRE',
#  'VIB',
#  'XGR',
#  'ZSE',
#  'HNC',
#  'UGT',
#  'XRP',
#  'EKO',
#  'GVT',
#  'LDOGE',
#  'MILO',
#  'BCAP',
#  '8BIT',
#  'R',
#  'XNG',
#  'LTB',
#  'COVAL',
#  'ATMS',
#  'QBC',
#  'PHR',
#  'GDC',
#  'IFC',
#  'XIN',
#  'ETT',
#  'SAN',
#  'WTT',
#  'FRCT',
#  'IOC',
#  'BCC',
#  'MONA',
#  'VSL',
#  'AIT',
#  'VPRC',
#  'QAU',
#  'STEEM',
#  'REBL',
#  'XP',
#  'VIA',
#  'RLC',
#  'SDP',
#  'WOW',
#  'CNNC',
#  'SUR',
#  'ICOS',
#  'WDC',
#  'CNX',
#  'VRC',
#  'ETHD',
#  'CRTM',
#  'APW',
#  'ESZ',
#  'AIDOC',
#  'P7C',
#  'MAO',
#  'USNBT',
#  'PRG',
#  'RVT',
#  'HAC',
#  'DCRE',
#  'BCA',
#  'HOLD',
#  'PIE',
#  'TRCT',
#  'DCY',
#  'FLDC',
#  'DSH',
#  'PRL',
#  'LTG',
#  'PDC',
#  'HGT',
#  'BITEUR',
#  'TMC',
#  'DUB',
#  'GRLC',
#  'UTT',
#  'FOTA',
#  'HMC',
#  'ECA',
#  'IMX',
#  'XSH',
#  'DFS',
#  'INXT',
#  'SISA',
#  'PRO',
#  'SOC',
#  'ION',
#  'ICOO',
#  'EVO',
#  'BRIT',
#  'ERY',
#  'BTCR',
#  'IC',
#  'ACOIN',
#  'CASH',
#  'NLC2',
#  'AIB',
#  'TRIA',
#  'SKULL',
#  'ARCO',
#  'GLS',
#  'SPT',
#  'WTC',
#  'IPY',
#  'FIL',
#  'NTWK',
#  'ISL',
#  'MDC',
#  'CDX',
#  'SAK',
#  'NULS',
#  'STV',
#  'INK',
#  'EPY',
#  'PZM',
#  'MCO',
#  'LUN',
#  'DDF',
#  'ATL',
#  'SEXC',
#  'RBX',
#  'KUSH',
#  'BDG',
#  'VOLT',
#  'DNT',
#  'EMD',
#  'KOBO',
#  'HXX',
#  'GPU',
#  'PST',
#  'BIX',
#  'TGT',
#  'AGRS',
#  'SOJ',
#  'GAP',
#  'SGR',
#  'ZLA',
#  'GOLOS',
#  'COXST',
#  'MNX',
#  'TRST',
#  'DICE',
#  'YAC',
#  'XPY',
#  'DTA',
#  'APX',
#  'TROLL',
#  'KNC',
#  'ING',
#  'KBR',
#  'BCN',
#  'WC',
#  'XCN',
#  'BIGUP',
#  'UAHPAY',
#  'IFLT',
#  'NTC',
#  'UFR',
#  'VEN',
#  'GNO',
#  'SPC',
#  'TAAS',
#  'OST',
#  'EQL',
#  'RPX',
#  'EMC',
#  'INS',
#  'LEA',
#  'CLOAK',
#  'OK',
#  'QSP',
#  'MOIN',
#  'BRX',
#  'SHIFT',
#  'SONG',
#  'ESP',
#  'ADL',
#  'MTLMC3',
#  'TERA',
#  'MXT',
#  'ARB',
#  'NANOX',
#  'UNB',
#  'LEND',
#  'XDN',
#  'WAY',
#  'SLG',
#  'RNS',
#  'FDX',
#  'TESLA',
#  'XUC',
#  'TKY',
#  'SCL',
#  'XMR',
#  'DNA',
#  'MAGE',
#  'XAUR',
#  'NIMFA',
#  'PRIX',
#  'SPANK',
#  'ATS',
#  ...]

# %% [markdown]
# Other parameters:

# %%
print(cmc.ticker.__doc__)
# Out:
# Get currencies with other aditional data.
#
#         Args:
#             currency (str, optional): Specify a currency to return,
#                 in this case the method returns a dict, otherwise
#                 returns a list. If you dont specify a currency,
#                 returns data for all in coinmarketcap. As default, None.
#             limit (int, optional): Limit amount of coins on response.
#                 if limit == 0, returns all coins in coinmarketcap.
#                 Only works if currency == None. As default 0.
#             start (int, optional): Rank of first currency to retrieve.
#                 The count starts at 0 for the first currency ranked.
#                 Only works if currency == None. As default 0.
#             convert (str, optional): As default, "USD". Allow to
#                 convert price, 24h volume and market cap in terms
#                 of one of next badges:
#                    ["AUD", "BRL", "CAD", "CHF", "CLP", "CNY", "CZK", "DKK",
#                     "EUR", "GBP", "HKD", "HUF", "IDR", "ILS", "INR", "JPY",
#                     "KRW", "MXN", "MYR", "NOK", "NZD", "PHP", "PKR", "PLN",
#                     "RUB", "SEK", "SGD", "THB", "TRY", "TWD", "ZAR"]
#
#         Returns:
#             dict/list: If currency param is provided or not.

# %% [markdown]
# If you want to get the valid badges that can be passed to `convert` param programatically, use this:

# %%
cmc.ticker_badges
# Out:
# ['AUD',
#  'BRL',
#  'CAD',
#  'CHF',
#  'CLP',
#  'CNY',
#  'CZK',
#  'DKK',
#  'EUR',
#  'GBP',
#  'HKD',
#  'HUF',
#  'IDR',
#  'ILS',
#  'INR',
#  'JPY',
#  'KRW',
#  'MXN',
#  'MYR',
#  'NOK',
#  'NZD',
#  'PHP',
#  'PKR',
#  'PLN',
#  'RUB',
#  'SEK',
#  'SGD',
#  'THB',
#  'TRY',
#  'TWD',
#  'ZAR']

# %% [markdown]
# #### `stats()`

# %%
cmc.stats()
# Out:
# {'active_assets': 594,
#  'active_currencies': 888,
#  'active_markets': 8655,
#  'bitcoin_percentage_of_market_cap': 34.84,
#  'last_updated': 1518183267,
#  'total_24h_volume_usd': 22611793303.0,
#  'total_market_cap_usd': 400915454728.0}

# %% [markdown]
# _____________________________________________
#
# ## Web scraper
# #### `markets(currency, [convert="USD"])`
# Get all markets for a exchange in coinmarketcap. You can convert the response fields `"volume_24h"` and `"price"` between `"USD"` and `"BTC"`.

# %%
cmc.markets("BTC")
# Out:
# []
