# %% [markdown]
# # <center>Synchronous Pymarketcap Interface</center>
#
# > See also: [Asynchronous Pymarketcap Scraper](async_live.ipynb)

# %%
from IPython.display import IFrame
show_page = lambda endpoint: IFrame("https://coinmarketcap.com/%s" % endpoint, "100%", 400)

# %% [markdown]
# ## Basic usage
#
# #### `Pymarketcap([timeout=20, debug=False, cache=True])`
#
# The first response takes a long time because some data is cached at instantiation of the wrapper.

# %%
from pymarketcap import Pymarketcap
cmc = Pymarketcap(timeout=10)

cmc.exchanges()
# Out:
# [{'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BitMEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'ICON',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'TRON',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'NEO',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Verge',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Qtum',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Ripple',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Binance'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'EOS',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'OKEx'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'TRON',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Huobi Token',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Arcblock',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Dash',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Huobi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'EOS',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'NEO',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Bitfinex'},
#  {'markets': [{'name': 'EOS',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ripple',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Qtum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Monero',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Bithumb'},
#  {'markets': [{'name': 'EOS',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Cardano',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Qtum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'TRON',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'NEM',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Status',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'NEO',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Upbit'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Ripple',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'EOS',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'EOS',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Kraken'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'GDAX'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Qtum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'TRON',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'EDUCare',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Nano',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'OceanChain',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Bit-Z'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'}],
#   'name': 'bitFlyer'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Ripple',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Ripple',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Bitstamp'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Verge',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Cardano',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'TRON',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Cardano',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'NEM',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Stellar',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Ripple',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Bittrex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Dash',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Zcash',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Noah Coin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bytecoin',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Monero',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'W3Coin',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'HitBTC'},
#  {'markets': [{'name': 'Qtum',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'VeChain',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Zcash',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Zcash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'NEO',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bodhi',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Profile Utility Token',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Lbank'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'QASH',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'NEO',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'QASH',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Quoine'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEM',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'NEM',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'COMSA [ETH]',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'COMSA [XEM]',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Counterparty',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Pepe Cash',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Zaif'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'MonaCoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'}],
#   'name': 'Fisco'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'}],
#   'name': 'Gemini'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Stellar',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'NEM',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Monero',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Lisk',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Poloniex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'}],
#   'name': 'BTCC'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BTCBOX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Arcblock',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Medicalchain',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Pundi X [NEW]',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'CoinBene'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Qtum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'IOTA',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'}],
#   'name': 'Coinone'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Dash',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Dash',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'WEX'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEO',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'TRON',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Lisk',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Qtum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Achain',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bytom',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Qbao',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'CoinEgg'},
#  {'markets': [{'name': 'Banyan Network',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Banyan Network',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'High Performance Blockchain',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'High Performance Blockchain',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'CPChain',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Gifto',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'CPChain',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'BitClave',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'BitClave',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'CRYPTO20',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Bibox'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'MonaCoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'MonaCoin',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'}],
#   'name': 'Bitbank'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'}],
#   'name': 'CoinsBank'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Qtum',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Hshare',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'BitShares',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'ZB.COM'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
# ...
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Golem',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Lunyr',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'SingularDTV',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'TokenCard',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Swarm City',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Etheroll',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Melon',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Numeraire',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Edgeless',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'CryptoDerivatives'},
#  {'markets': [{'name': 'GBCGoldCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'BriaCoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'}],
#   'name': 'Ore.Bz'},
#  {'markets': [{'name': 'Litecoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Photon',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Blakecoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Blakecoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Photon',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'ColossusCoinXT',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'}],
#   'name': 'C-Patex'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Rippex'},
#  {'markets': [{'name': 'SuperNET',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'CHIPS',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Zcash',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Crown',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Hush',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Denarius',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'}],
#   'name': 'BarterDEX'},
#  {'markets': [{'name': 'Karma',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Steem',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Peerplays',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Steem',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Peerplays',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Golos',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'}],
#   'name': 'RuDEX'},
#  {'markets': [{'name': 'Datacoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Anoncoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Cryptonite',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Freicoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'WhiteCoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'}],
#   'name': 'FreiExchange'},
#  {'markets': [{'name': 'GoldMint',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Revain',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'}],
#   'name': 'Simex'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Lisk',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'PIVX',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Waves',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'NEM',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Dash',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Coinbe'},
#  {'markets': [{'name': 'SnakeEyes',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Burst Asset Exchange'},
#  {'markets': [{'name': 'Siacoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'}],
#   'name': 'BITHOLIC'},
#  {'markets': [{'name': 'YashCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'SACoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'DC-Ex'},
#  {'markets': [{'name': 'CRTCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'}],
#   'name': 'NIX-E'},
#  {'markets': [{'name': 'LEOcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'LEOcoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'LEOcoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'LEOcoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'}],
#   'name': 'LEOxChange'},
#  {'markets': [{'name': 'HEAT',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bismuth',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Golem',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'FIMKrypto',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Elastic',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Elastic',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'HEAT',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'}],
#   'name': 'Heat Wallet'}]

# %% [markdown]
# > All methods are self explained in docstrings:

# %%
print(cmc.exchanges.__doc__)
# Out:
# Get all the exchanges in coinmarketcap ranked by volumes
#         along with other metadata.
#
#         Args:
#             convert (str, optional): Convert volumes and prices
#                 between USD and BTC. As default ``"USD"``.
#
#         Returns (list):
#             Exchanges with markets and other data included.

# %% [markdown]
# ___________________________________
#
# ## Coinmarketcap API

# %%
show_page("api")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/api"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `ticker(currency=None, limit=0, start=0, convert="USD")`
# If `currency == None`, you will obtain data for all currencies in coinmarketcap:

# %%
cmc.ticker()
# Out:
# [{'24h_volume_usd': 5159310000.0,
#   'available_supply': 16934937.0,
#   'id': 'bitcoin',
#   'last_updated': 1521811167,
#   'market_cap_usd': 141888014860,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin',
#   'percent_change_1h': -1.63,
#   'percent_change_24h': -3.84,
#   'percent_change_7d': 0.06,
#   'price_btc': 1.0,
#   'price_usd': 8378.42,
#   'rank': 1,
#   'symbol': 'BTC',
#   'total_supply': 16934937.0},
#  {'24h_volume_usd': 1533530000.0,
#   'available_supply': 98365916.0,
#   'id': 'ethereum',
#   'last_updated': 1521811153,
#   'market_cap_usd': 50539423981.0,
#   'max_supply': None,
#   'name': 'Ethereum',
#   'percent_change_1h': -1.69,
#   'percent_change_24h': -4.53,
#   'percent_change_7d': -16.03,
#   'price_btc': 0.0615822,
#   'price_usd': 513.79,
#   'rank': 2,
#   'symbol': 'ETH',
#   'total_supply': 98365916.0},
#  {'24h_volume_usd': 401697000.0,
#   'available_supply': 39094227299.0,
#   'id': 'ripple',
#   'last_updated': 1521811141,
#   'market_cap_usd': 24583192916.0,
#   'max_supply': 100000000000,
#   'name': 'Ripple',
#   'percent_change_1h': -1.27,
#   'percent_change_24h': -3.78,
#   'percent_change_7d': -9.72,
#   'price_btc': 7.537e-05,
#   'price_usd': 0.628819,
#   'rank': 3,
#   'symbol': 'XRP',
#   'total_supply': 99992434971.0},
#  {'24h_volume_usd': 319800000.0,
#   'available_supply': 17033463.0,
#   'id': 'bitcoin-cash',
#   'last_updated': 1521811152,
#   'market_cap_usd': 16522373458.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Cash',
#   'percent_change_1h': -1.89,
#   'percent_change_24h': -3.55,
#   'percent_change_7d': 0.56,
#   'price_btc': 0.116262,
#   'price_usd': 969.995,
#   'rank': 4,
#   'symbol': 'BCH',
#   'total_supply': 17033463.0},
#  {'24h_volume_usd': 374826000.0,
#   'available_supply': 55755639.0,
#   'id': 'litecoin',
#   'last_updated': 1521811141,
#   'market_cap_usd': 8786252439.0,
#   'max_supply': 84000000.0,
#   'name': 'Litecoin',
#   'percent_change_1h': -1.68,
#   'percent_change_24h': -4.56,
#   'percent_change_7d': -4.42,
#   'price_btc': 0.018888,
#   'price_usd': 157.585,
#   'rank': 5,
#   'symbol': 'LTC',
#   'total_supply': 55755639.0},
#  {'24h_volume_usd': 980808000.0,
#   'available_supply': 746598237.0,
#   'id': 'eos',
#   'last_updated': 1521811151,
#   'market_cap_usd': 5048915376.0,
#   'max_supply': 1000000000.0,
#   'name': 'EOS',
#   'percent_change_1h': -0.49,
#   'percent_change_24h': 2.26,
#   'percent_change_7d': 31.45,
#   'price_btc': 0.00081055,
#   'price_usd': 6.76256,
#   'rank': 6,
#   'symbol': 'EOS',
#   'total_supply': 900000000.0},
#  {'24h_volume_usd': 149603000.0,
#   'available_supply': 25927070538.0,
#   'id': 'cardano',
#   'last_updated': 1521811153,
#   'market_cap_usd': 4866303723.0,
#   'max_supply': 45000000000.0,
#   'name': 'Cardano',
#   'percent_change_1h': -1.35,
#   'percent_change_24h': -5.23,
#   'percent_change_7d': 3.99,
#   'price_btc': 2.25e-05,
#   'price_usd': 0.187692,
#   'rank': 7,
#   'symbol': 'ADA',
#   'total_supply': 31112483745.0},
#  {'24h_volume_usd': 48542100.0,
#   'available_supply': 18548941024.0,
#   'id': 'stellar',
#   'last_updated': 1521811143,
#   'market_cap_usd': 4246780047.0,
#   'max_supply': None,
#   'name': 'Stellar',
#   'percent_change_1h': -0.86,
#   'percent_change_24h': -3.87,
#   'percent_change_7d': -2.68,
#   'price_btc': 2.744e-05,
#   'price_usd': 0.22895,
#   'rank': 8,
#   'symbol': 'XLM',
#   'total_supply': 103788040162},
#  {'24h_volume_usd': 140615000.0,
#   'available_supply': 65000000.0,
#   'id': 'neo',
#   'last_updated': 1521811147,
#   'market_cap_usd': 4186357500.0,
#   'max_supply': 100000000.0,
#   'name': 'NEO',
#   'percent_change_1h': -1.69,
#   'percent_change_24h': -7.42,
#   'percent_change_7d': -6.49,
#   'price_btc': 0.00771955,
#   'price_usd': 64.4055,
#   'rank': 9,
#   'symbol': 'NEO',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 32794800.0,
#   'available_supply': 2779530283.0,
#   'id': 'iota',
#   'last_updated': 1521811150,
#   'market_cap_usd': 3513076120.0,
#   'max_supply': 2779530283.0,
#   'name': 'IOTA',
#   'percent_change_1h': -2.61,
#   'percent_change_24h': -3.19,
#   'percent_change_7d': 13.67,
#   'price_btc': 0.00015149,
#   'price_usd': 1.26391,
#   'rank': 10,
#   'symbol': 'MIOTA',
#   'total_supply': 2779530283.0},
#  {'24h_volume_usd': 33001800.0,
#   'available_supply': 15855493.0,
#   'id': 'monero',
#   'last_updated': 1521811142,
#   'market_cap_usd': 3161268209.0,
#   'max_supply': None,
#   'name': 'Monero',
#   'percent_change_1h': -1.74,
#   'percent_change_24h': -5.74,
#   'percent_change_7d': -5.83,
#   'price_btc': 0.0238974,
#   'price_usd': 199.38,
#   'rank': 11,
#   'symbol': 'XMR',
#   'total_supply': 15855493.0},
#  {'24h_volume_usd': 94960800.0,
#   'available_supply': 7963061.0,
#   'id': 'dash',
#   'last_updated': 1521811142,
#   'market_cap_usd': 3135479351.0,
#   'max_supply': 18900000.0,
#   'name': 'Dash',
#   'percent_change_1h': -1.76,
#   'percent_change_24h': -4.98,
#   'percent_change_7d': -6.03,
#   'price_btc': 0.0471947,
#   'price_usd': 393.753,
#   'rank': 12,
#   'symbol': 'DASH',
#   'total_supply': 7963061.0},
#  {'24h_volume_usd': 49718100.0,
#   'available_supply': 8999999999.0,
#   'id': 'nem',
#   'last_updated': 1521811145,
#   'market_cap_usd': 2458530000.0,
#   'max_supply': None,
#   'name': 'NEM',
#   'percent_change_1h': -2.0,
#   'percent_change_24h': -6.11,
#   'percent_change_7d': -21.09,
#   'price_btc': 3.274e-05,
#   'price_usd': 0.27317,
#   'rank': 13,
#   'symbol': 'XEM',
#   'total_supply': 8999999999.0},
#  {'24h_volume_usd': 199154000.0,
#   'available_supply': 65748192475.0,
#   'id': 'tron',
#   'last_updated': 1521811153,
#   'market_cap_usd': 2357881403.0,
#   'max_supply': None,
#   'name': 'TRON',
#   'percent_change_1h': -1.5,
#   'percent_change_24h': -0.68,
#   'percent_change_7d': 19.24,
#   'price_btc': 4.3e-06,
#   'price_usd': 0.0358623,
#   'rank': 14,
#   'symbol': 'TRX',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 2048860000.0,
#   'available_supply': 2287140814.0,
#   'id': 'tether',
#   'last_updated': 1521811145,
#   'market_cap_usd': 2289999740.0,
#   'max_supply': None,
#   'name': 'Tether',
#   'percent_change_1h': 0.02,
#   'percent_change_24h': 0.02,
#   'percent_change_7d': 0.13,
#   'price_btc': 0.00012001,
#   'price_usd': 1.00125,
#   'rank': 15,
#   'symbol': 'USDT',
#   'total_supply': 2580109970.0},
#  {'24h_volume_usd': 213099000.0,
#   'available_supply': 100700947.0,
#   'id': 'ethereum-classic',
#   'last_updated': 1521811147,
#   'market_cap_usd': 1837107516.0,
#   'max_supply': None,
#   'name': 'Ethereum Classic',
#   'percent_change_1h': -1.39,
#   'percent_change_24h': -4.7,
#   'percent_change_7d': 0.86,
#   'price_btc': 0.0021866,
#   'price_usd': 18.2432,
#   'rank': 16,
#   'symbol': 'ETC',
#   'total_supply': 100700947.0},
#  {'24h_volume_usd': 56726900.0,
#   'available_supply': 517784185.0,
#   'id': 'vechain',
#   'last_updated': 1521811153,
#   'market_cap_usd': 1684900804.0,
#   'max_supply': None,
#   'name': 'VeChain',
#   'percent_change_1h': -1.96,
#   'percent_change_24h': -7.08,
#   'percent_change_7d': -17.13,
#   'price_btc': 0.00039003,
#   'price_usd': 3.25406,
#   'rank': 17,
#   'symbol': 'VEN',
#   'total_supply': 873378637.0},
#  {'24h_volume_usd': 224966000.0,
#   'available_supply': 88469520.0,
#   'id': 'qtum',
#   'last_updated': 1521811151,
#   'market_cap_usd': 1593919954.0,
#   'max_supply': None,
#   'name': 'Qtum',
#   'percent_change_1h': -1.48,
#   'percent_change_24h': -3.15,
#   'percent_change_7d': 18.13,
#   'price_btc': 0.00215944,
#   'price_usd': 18.0166,
#   'rank': 18,
#   'symbol': 'QTUM',
#   'total_supply': 100469520.0},
#  {'24h_volume_usd': 158823000.0,
#   'available_supply': 387042512.0,
#   'id': 'icon',
#   'last_updated': 1521811155,
#   'market_cap_usd': 1513649727.0,
#   'max_supply': None,
#   'name': 'ICON',
#   'percent_change_1h': -0.68,
#   'percent_change_24h': 11.4,
#   'percent_change_7d': 70.79,
#   'price_btc': 0.00046874,
#   'price_usd': 3.91081,
#   'rank': 19,
#   'symbol': 'ICX',
#   'total_supply': 400230000.0},
#  {'24h_volume_usd': 22708800.0,
#   'available_supply': 103117648.0,
#   'id': 'lisk',
#   'last_updated': 1521811146,
#   'market_cap_usd': 1196752482.0,
#   'max_supply': None,
#   'name': 'Lisk',
#   'percent_change_1h': -1.0,
#   'percent_change_24h': -6.15,
#   'percent_change_7d': -11.52,
#   'price_btc': 0.00139104,
#   'price_usd': 11.6057,
#   'rank': 20,
#   'symbol': 'LSK',
#   'total_supply': 119334276.0},
#  {'24h_volume_usd': 28735100.0,
#   'available_supply': 102042552.0,
#   'id': 'omisego',
#   'last_updated': 1521811151,
#   'market_cap_usd': 1086314393.0,
#   'max_supply': None,
#   'name': 'OmiseGO',
#   'percent_change_1h': -3.09,
#   'percent_change_24h': -5.46,
#   'percent_change_7d': -6.42,
#   'price_btc': 0.00127598,
#   'price_usd': 10.6457,
#   'rank': 21,
#   'symbol': 'OMG',
#   'total_supply': 140245398.0},
#  {'24h_volume_usd': 23269900.0,
#   'available_supply': 16897811.0,
#   'id': 'bitcoin-gold',
#   'last_updated': 1521811155,
#   'market_cap_usd': 992859617.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Gold',
#   'percent_change_1h': -1.74,
#   'percent_change_24h': -4.16,
#   'percent_change_7d': -9.79,
#   'price_btc': 0.0070425,
#   'price_usd': 58.7567,
#   'rank': 22,
#   'symbol': 'BTG',
#   'total_supply': 16997811.0},
#  {'24h_volume_usd': 40179000.0,
#   'available_supply': 133248289.0,
#   'id': 'nano',
#   'last_updated': 1521811149,
#   'market_cap_usd': 987316524.0,
#   'max_supply': 133248290.0,
#   'name': 'Nano',
#   'percent_change_1h': -3.35,
#   'percent_change_24h': -8.52,
#   'percent_change_7d': -17.56,
#   'price_btc': 0.00088811,
#   'price_usd': 7.4096,
#   'rank': 23,
#   'symbol': 'NANO',
#   'total_supply': 133248289.0},
#  {'24h_volume_usd': 79773000.0,
#   'available_supply': 99014000.0,
#   'id': 'binance-coin',
#   'last_updated': 1521811152,
#   'market_cap_usd': 983899148.0,
#   'max_supply': None,
#   'name': 'Binance Coin',
#   'percent_change_1h': -0.55,
#   'percent_change_24h': -0.18,
#   'percent_change_7d': 9.49,
#   'price_btc': 0.00119103,
#   'price_usd': 9.93697,
#   'rank': 24,
#   'symbol': 'BNB',
#   'total_supply': 197192382.0},
#  {'24h_volume_usd': 43604400.0,
#   'available_supply': 3541869.0,
#   'id': 'zcash',
#   'last_updated': 1521811148,
#   'market_cap_usd': 819039439.0,
#   'max_supply': None,
#   'name': 'Zcash',
#   'percent_change_1h': -1.58,
#   'percent_change_24h': -6.16,
#   'percent_change_7d': -3.98,
#   'price_btc': 0.0277167,
#   'price_usd': 231.245,
#   'rank': 25,
#   'symbol': 'ZEC',
#   'total_supply': 3541869.0},
#  {'24h_volume_usd': 25505900.0,
#   'available_supply': 2000000.0,
#   'id': 'digixdao',
#   'last_updated': 1521811146,
#   'market_cap_usd': 690894000.0,
#   'max_supply': None,
#   'name': 'DigixDAO',
#   'percent_change_1h': -1.32,
#   'percent_change_24h': -5.64,
#   'percent_change_7d': -14.94,
#   'price_btc': 0.0414048,
#   'price_usd': 345.447,
#   'rank': 26,
#   'symbol': 'DGD',
#   'total_supply': 2000000.0},
#  {'24h_volume_usd': 66952200.0,
#   'available_supply': 14744672688.0,
#   'id': 'verge',
#   'last_updated': 1521811143,
#   'market_cap_usd': 519895685.0,
#   'max_supply': 16555000000.0,
#   'name': 'Verge',
#   'percent_change_1h': -3.52,
#   'percent_change_24h': 8.88,
#   'percent_change_7d': 9.17,
#   'price_btc': 4.23e-06,
#   'price_usd': 0.0352599,
#   'rank': 27,
#   'symbol': 'XVG',
#   'total_supply': 14744672688.0},
#  {'24h_volume_usd': 1398720.0,
#   'available_supply': 37004027.0,
#   'id': 'populous',
#   'last_updated': 1521811151,
#   'market_cap_usd': 518122984.0,
#   'max_supply': 53252246.0,
#   'name': 'Populous',
#   'percent_change_1h': -4.69,
#   'percent_change_24h': -6.27,
#   'percent_change_7d': -13.91,
#   'price_btc': 0.00167824,
#   'price_usd': 14.0018,
#   'rank': 28,
#   'symbol': 'PPT',
#   'total_supply': 53252246.0},
#  {'24h_volume_usd': 2172090.0,
#   'available_supply': 254034253.0,
#   'id': 'steem',
#   'last_updated': 1521811146,
#   'market_cap_usd': 491449585.0,
#   'max_supply': None,
#   'name': 'Steem',
#   'percent_change_1h': -2.29,
#   'percent_change_24h': -7.58,
#   'percent_change_7d': -6.13,
#   'price_btc': 0.00023188,
#   'price_usd': 1.93458,
#   'rank': 29,
#   'symbol': 'STEEM',
#   'total_supply': 271008347.0},
#  {'24h_volume_usd': 8051820.0,
#   'available_supply': 98787979.0,
#   'id': 'stratis',
#   'last_updated': 1521811147,
#   'market_cap_usd': 484604432.0,
#   'max_supply': None,
#   'name': 'Stratis',
#   'percent_change_1h': -1.72,
#   'percent_change_24h': -2.88,
#   'percent_change_7d': 5.45,
#   'price_btc': 0.00058797,
#   'price_usd': 4.9055,
#   'rank': 30,
#   'symbol': 'STRAT',
#   'total_supply': 98787979.0},
#  {'24h_volume_usd': 4250240.0,
#   'available_supply': 183798050773,
#   'id': 'bytecoin-bcn',
#   'last_updated': 1521811142,
#   'market_cap_usd': 467764201.0,
#   'max_supply': 184470000000,
#   'name': 'Bytecoin',
#   'percent_change_1h': -1.92,
#   'percent_change_24h': -3.54,
#   'percent_change_7d': -4.86,
#   'price_btc': 3.1e-07,
#   'price_usd': 0.00254499,
#   'rank': 31,
#   'symbol': 'BCN',
#   'total_supply': 183798050773},
#  {'24h_volume_usd': 19354100.0,
#   'available_supply': 100000000.0,
#   'id': 'waves',
#   'last_updated': 1521811147,
#   'market_cap_usd': 457737000.0,
#   'max_supply': None,
#   'name': 'Waves',
#   'percent_change_1h': -1.75,
#   'percent_change_24h': -3.83,
#   'percent_change_7d': -9.06,
#   'price_btc': 0.00054864,
#   'price_usd': 4.57737,
#   'rank': 32,
#   'symbol': 'WAVES',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 150150.0,
#   'available_supply': 618228.0,
#   'id': 'maker',
#   'last_updated': 1521811148,
#   'market_cap_usd': 415103472.0,
#   'max_supply': None,
#   'name': 'Maker',
#   'percent_change_1h': -1.88,
#   'percent_change_24h': -3.22,
#   'percent_change_7d': -7.32,
#   'price_btc': 0.080478,
#   'price_usd': 671.441,
#   'rank': 33,
#   'symbol': 'MKR',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 6167930.0,
#   'available_supply': 2611640000.0,
#   'id': 'bitshares',
#   'last_updated': 1521811144,
#   'market_cap_usd': 408651146.0,
#   'max_supply': 3600570502.0,
#   'name': 'BitShares',
#   'percent_change_1h': -2.31,
#   'percent_change_24h': -0.91,
#   'percent_change_7d': 3.01,
#   'price_btc': 1.875e-05,
#   'price_usd': 0.156473,
#   'rank': 34,
#   'symbol': 'BTS',
#   'total_supply': 2611640000.0},
#  {'24h_volume_usd': 3862790.0,
#   'available_supply': 33303222275.0,
#   'id': 'siacoin',
#   'last_updated': 1521811145,
#   'market_cap_usd': 405639908.0,
#   'max_supply': None,
#   'name': 'Siacoin',
#   'percent_change_1h': -1.97,
#   'percent_change_24h': -3.8,
#   'percent_change_7d': 3.82,
#   'price_btc': 1.46e-06,
#   'price_usd': 0.0121802,
#   'rank': 35,
#   'symbol': 'SC',
#   'total_supply': 33303222275.0},
#  {'24h_volume_usd': 538598.0,
#   'available_supply': 359478523.0,
#   'id': 'rchain',
#   'last_updated': 1521811154,
#   'market_cap_usd': 384516202.0,
#   'max_supply': 1000000000.0,
#   'name': 'RChain',
#   'percent_change_1h': -0.69,
#   'percent_change_24h': -6.33,
#   'percent_change_7d': -7.54,
#   'price_btc': 0.00012821,
#   'price_usd': 1.06965,
#   'rank': 36,
#   'symbol': 'RHOC',
#   'total_supply': 870663574.0},
#  {'24h_volume_usd': 5556960.0,
#   'available_supply': 113711691262,
#   'id': 'dogecoin',
#   'last_updated': 1521811141,
#   'market_cap_usd': 384176086.0,
#   'max_supply': None,
#   'name': 'Dogecoin',
#   'percent_change_1h': -0.97,
#   'percent_change_24h': -4.62,
#   'percent_change_7d': -5.33,
#   'price_btc': 4e-07,
#   'price_usd': 0.00337851,
#   'rank': 37,
#   'symbol': 'DOGE',
#   'total_supply': 113711691262},
#  {'24h_volume_usd': 2585730.0,
#   'available_supply': 233020472.0,
#   'id': 'aeternity',
#   'last_updated': 1521811150,
#   'market_cap_usd': 368354102.0,
#   'max_supply': None,
#   'name': 'Aeternity',
#   'percent_change_1h': -2.76,
#   'percent_change_24h': -2.38,
#   'percent_change_7d': -2.22,
#   'price_btc': 0.00018947,
#   'price_usd': 1.58078,
#   'rank': 38,
#   'symbol': 'AE',
#   'total_supply': 273685830.0},
#  {'24h_volume_usd': 1939310.0,
#   'available_supply': 11000000.0,
#   'id': 'augur',
#   'last_updated': 1521811145,
#   'market_cap_usd': 365388100.0,
#   'max_supply': None,
#   'name': 'Augur',
#   'percent_change_1h': -1.24,
#   'percent_change_24h': -4.95,
#   'percent_change_7d': -0.63,
#   'price_btc': 0.00398136,
#   'price_usd': 33.2171,
#   'rank': 39,
#   'symbol': 'REP',
#   'total_supply': 11000000.0},
#  {'24h_volume_usd': 22103700.0,
#   'available_supply': 3470483788.0,
#   'id': 'status',
#   'last_updated': 1521811151,
#   'market_cap_usd': 357373068.0,
#   'max_supply': None,
#   'name': 'Status',
#   'percent_change_1h': -1.0,
#   'percent_change_24h': -6.28,
#   'percent_change_7d': -4.27,
#   'price_btc': 1.234e-05,
#   'price_usd': 0.102975,
#   'rank': 40,
#   'symbol': 'SNT',
#   'total_supply': 6804870174.0},
#  {'24h_volume_usd': 13542000.0,
#   'available_supply': 987000000.0,
#   'id': 'bytom',
#   'last_updated': 1521811151,
#   'market_cap_usd': 347075589.0,
#   'max_supply': None,
#   'name': 'Bytom',
#   'percent_change_1h': -0.78,
#   'percent_change_24h': 2.24,
#   'percent_change_7d': -1.7,
#   'price_btc': 4.215e-05,
#   'price_usd': 0.351647,
#   'rank': 41,
#   'symbol': 'BTM',
#   'total_supply': 1407000000.0},
#  {'24h_volume_usd': 394748.0,
#   'available_supply': 6988948.0,
#   'id': 'decred',
#   'last_updated': 1521811145,
#   'market_cap_usd': 344922071.0,
#   'max_supply': 21000000.0,
#   'name': 'Decred',
#   'percent_change_1h': -1.25,
#   'percent_change_24h': -2.06,
#   'percent_change_7d': -10.46,
#   'price_btc': 0.00591533,
#   'price_usd': 49.3525,
#   'rank': 42,
#   'symbol': 'DCR',
#   'total_supply': 7408948.0},
#  {'24h_volume_usd': 23569600.0,
#   'available_supply': 241236451.0,
#   'id': 'ontology',
#   'last_updated': 1521811160,
#   'market_cap_usd': 304795019.0,
#   'max_supply': None,
#   'name': 'Ontology',
#   'percent_change_1h': -2.19,
#   'percent_change_24h': -1.53,
#   'percent_change_7d': -27.86,
#   'price_btc': 0.00015144,
#   'price_usd': 1.26347,
#   'rank': 43,
#   'symbol': 'ONT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 3355430.0,
#   'available_supply': 24898178.0,
#   'id': 'waltonchain',
#   'last_updated': 1521811152,
#   'market_cap_usd': 304395165.0,
#   'max_supply': 100000000.0,
#   'name': 'Waltonchain',
#   'percent_change_1h': -2.27,
#   'percent_change_24h': -4.99,
#   'percent_change_7d': -8.71,
#   'price_btc': 0.00146535,
#   'price_usd': 12.2256,
#   'rank': 44,
#   'symbol': 'WTC',
#   'total_supply': 70000000.0},
#  {'24h_volume_usd': 11751500.0,
#   'available_supply': 115319871.0,
#   'id': 'aion',
#   'last_updated': 1521811155,
#   'market_cap_usd': 303980873.0,
#   'max_supply': None,
#   'name': 'Aion',
#   'percent_change_1h': -3.76,
#   'percent_change_24h': -11.83,
#   'percent_change_7d': -4.97,
#   'price_btc': 0.00031594,
#   'price_usd': 2.63598,
#   'rank': 45,
#   'symbol': 'AION',
#   'total_supply': 465934587.0},
#  {'24h_volume_usd': 959536.0,
#   'available_supply': 104030534.0,
#   'id': 'komodo',
#   'last_updated': 1521811149,
#   'market_cap_usd': 293615779.0,
#   'max_supply': None,
#   'name': 'Komodo',
#   'percent_change_1h': -1.77,
#   'percent_change_24h': -3.75,
#   'percent_change_7d': -4.91,
#   'price_btc': 0.00033829,
#   'price_usd': 2.8224,
#   'rank': 46,
#   'symbol': 'KMD',
#   'total_supply': 104030534.0},
#  {'24h_volume_usd': 13708600.0,
#   'available_supply': 6605326966.0,
#   'id': 'zilliqa',
#   'last_updated': 1521811160,
#   'market_cap_usd': 286803297.0,
#   'max_supply': None,
#   'name': 'Zilliqa',
#   'percent_change_1h': -3.89,
#   'percent_change_24h': -5.5,
#   'percent_change_7d': -0.37,
#   'price_btc': 5.2e-06,
#   'price_usd': 0.04342,
#   'rank': 47,
#   'symbol': 'ZIL',
#   'total_supply': 12600000000.0},
#  {'24h_volume_usd': 2310870.0,
#   'available_supply': 998999495.0,
#   'id': 'ardor',
#   'last_updated': 1521811147,
#   'market_cap_usd': 281907667.0,
#   'max_supply': 998999495.0,
#   'name': 'Ardor',
#   'percent_change_1h': -1.5,
#   'percent_change_24h': -6.22,
#   'percent_change_7d': -8.14,
#   'price_btc': 3.382e-05,
#   'price_usd': 0.28219,
#   'rank': 48,
#   'symbol': 'ARDR',
#   'total_supply': 998999495.0},
#  {'24h_volume_usd': 23877300.0,
#   'available_supply': 42772823.0,
#   'id': 'hshare',
#   'last_updated': 1521811153,
#   'market_cap_usd': 280276623.0,
#   'max_supply': 84000000.0,
#   'name': 'Hshare',
#   'percent_change_1h': -0.91,
#   'percent_change_24h': -2.01,
#   'percent_change_7d': 17.69,
#   'price_btc': 0.0007854,
#   'price_usd': 6.55268,
#   'rank': 49,
#   'symbol': 'HSR',
#   'total_supply': 42772823.0},
#  {'24h_volume_usd': 684658.0,
#   'available_supply': 2036645.0,
#   'id': 'veritaseum',
#   'last_updated': 1521811150,
#   'market_cap_usd': 276898241.0,
#   'max_supply': None,
#   'name': 'Veritaseum',
#   'percent_change_1h': 4.19,
#   'percent_change_24h': 27.39,
#   'percent_change_7d': 9.82,
#   'price_btc': 0.0162957,
#   'price_usd': 135.958,
#   'rank': 50,
#   'symbol': 'VERI',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 6422300.0,
#   'available_supply': 519515849.0,
#   'id': '0x',
#   'last_updated': 1521811153,
#   'market_cap_usd': 275228587.0,
#   'max_supply': None,
#   'name': '0x',
#   'percent_change_1h': -3.22,
#   'percent_change_24h': -12.39,
#   'percent_change_7d': 6.98,
#   'price_btc': 6.35e-05,
#   'price_usd': 0.529779,
#   'rank': 51,
#   'symbol': 'ZRX',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 2166490.0,
#   'available_supply': 101420940.0,
#   'id': 'ark',
#   'last_updated': 1521811149,
#   'market_cap_usd': 270717844.0,
#   'max_supply': None,
#   'name': 'Ark',
#   'percent_change_1h': -1.64,
#   'percent_change_24h': -0.39,
#   'percent_change_7d': -7.49,
#   'price_btc': 0.00031993,
#   'price_usd': 2.66925,
#   'rank': 52,
#   'symbol': 'ARK',
#   'total_supply': 132670940.0},
#  {'24h_volume_usd': 199553.0,
#   'available_supply': 45177604.0,
#   'id': 'cryptonex',
#   'last_updated': 1521811154,
#   'market_cap_usd': 259947866.0,
#   'max_supply': 210000000.0,
#   'name': 'Cryptonex',
#   'percent_change_1h': -0.28,
#   'percent_change_24h': -1.33,
#   'percent_change_7d': 0.34,
#   'price_btc': 0.00068965,
#   'price_usd': 5.75391,
#   'rank': 53,
#   'symbol': 'CNX',
#   'total_supply': 106615230.0},
#  {'24h_volume_usd': 11242700.0,
#   'available_supply': 572074043.0,
#   'id': 'loopring',
#   'last_updated': 1521811153,
#   'market_cap_usd': 244411770.0,
#   'max_supply': None,
#   'name': 'Loopring',
#   'percent_change_1h': -1.21,
#   'percent_change_24h': 4.94,
#   'percent_change_7d': 33.75,
#   'price_btc': 5.121e-05,
#   'price_usd': 0.427238,
#   'rank': 54,
#   'symbol': 'LRC',
#   'total_supply': 1374956262.0},
#  {'24h_volume_usd': 458917.0,
#   'available_supply': 91043076.0,
#   'id': 'kucoin-shares',
#   'last_updated': 1521811154,
#   'market_cap_usd': 239015387.0,
#   'max_supply': None,
#   'name': 'KuCoin Shares',
#   'percent_change_1h': -1.2,
#   'percent_change_24h': -8.93,
#   'percent_change_7d': 8.73,
#   'price_btc': 0.00031466,
#   'price_usd': 2.6253,
#   'rank': 55,
#   'symbol': 'KCS',
#   'total_supply': 181043076.0},
#  {'24h_volume_usd': 1274650.0,
#   'available_supply': 10012803898.0,
#   'id': 'digibyte',
#   'last_updated': 1521811441,
#   'market_cap_usd': 219355501.0,
#   'max_supply': 21000000000.0,
#   'name': 'DigiByte',
#   'percent_change_1h': -1.59,
#   'percent_change_24h': -5.56,
#   'percent_change_7d': -0.88,
#   'price_btc': 2.63e-06,
#   'price_usd': 0.0219075,
#   'rank': 56,
#   'symbol': 'DGB',
#   'total_supply': 10012803898.0},
#  {'24h_volume_usd': 4631180.0,
#   'available_supply': 350000000.0,
#   'id': 'qash',
#   'last_updated': 1521811156,
#   'market_cap_usd': 218784300.0,
#   'max_supply': None,
#   'name': 'QASH',
#   'percent_change_1h': -1.48,
#   'percent_change_24h': -0.55,
#   'percent_change_7d': 10.26,
#   'price_btc': 7.492e-05,
#   'price_usd': 0.625098,
#   'rank': 57,
#   'symbol': 'QASH',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 1463770.0,
#   'available_supply': 58263700.0,
#   'id': 'monacoin',
#   'last_updated': 1521811441,
#   'market_cap_usd': 214727370.0,
#   'max_supply': None,
#   'name': 'MonaCoin',
#   'percent_change_1h': -1.06,
#   'percent_change_24h': -3.09,
#   'percent_change_7d': -4.19,
#   'price_btc': 0.00044191,
#   'price_usd': 3.68544,
#   'rank': 58,
#   'symbol': 'MONA',
#   'total_supply': 58263700.0},
#  {'24h_volume_usd': 1042560.0,
#   'available_supply': 55831630.0,
#   'id': 'pivx',
#   'last_updated': 1521811146,
#   'market_cap_usd': 207623315.0,
#   'max_supply': None,
#   'name': 'PIVX',
#   'percent_change_1h': -1.2,
#   'percent_change_24h': -5.44,
#   'percent_change_7d': -5.84,
#   'price_btc': 0.00044572,
#   'price_usd': 3.71874,
#   'rank': 59,
#   'symbol': 'PIVX',
#   'total_supply': 55831630.0},
#  {'24h_volume_usd': 4686560.0,
#   'available_supply': 9954248.0,
#   'id': 'gas',
#   'last_updated': 1521811151,
#   'market_cap_usd': 205739379.0,
#   'max_supply': 100000000.0,
#   'name': 'Gas',
#   'percent_change_1h': -2.22,
#   'percent_change_24h': -8.29,
#   'percent_change_7d': 0.31,
#   'price_btc': 0.0024773,
#   'price_usd': 20.6685,
#   'rank': 60,
#   'symbol': 'GAS',
#   'total_supply': 16395766.0},
#  {'24h_volume_usd': 9000890.0,
#   'available_supply': 35500000.0,
#   'id': 'nebulas-token',
#   'last_updated': 1521811153,
#   'market_cap_usd': 203977320.0,
#   'max_supply': 100000000.0,
#   'name': 'Nebulas',
#   'percent_change_1h': -2.4,
#   'percent_change_24h': 1.09,
#   'percent_change_7d': 11.38,
#   'price_btc': 0.00068869,
#   'price_usd': 5.74584,
#   'rank': 61,
#   'symbol': 'NAS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 656735.0,
#   'available_supply': 531788130.0,
#   'id': 'syscoin',
#   'last_updated': 1521811143,
#   'market_cap_usd': 203798760.0,
#   'max_supply': 888000000.0,
#   'name': 'Syscoin',
#   'percent_change_1h': -3.53,
#   'percent_change_24h': -6.38,
#   'percent_change_7d': 2.82,
#   'price_btc': 4.593e-05,
#   'price_usd': 0.383233,
#   'rank': 62,
#   'symbol': 'SYS',
#   'total_supply': 531788130.0},
#  {'24h_volume_usd': 3949880.0,
#   'available_supply': 1000000000.0,
#   'id': 'basic-attention-token',
#   'last_updated': 1521811150,
#   'market_cap_usd': 196569000.0,
#   'max_supply': None,
#   'name': 'Basic Attention Token',
#   'percent_change_1h': -2.17,
#   'percent_change_24h': -1.76,
#   'percent_change_7d': -1.98,
#   'price_btc': 2.356e-05,
#   'price_usd': 0.196569,
#   'rank': 63,
#   'symbol': 'BAT',
#   'total_supply': 1500000000.0},
#  {'24h_volume_usd': 5951780.0,
#   'available_supply': 834262000.0,
#   'id': 'golem-network-tokens',
#   'last_updated': 1521811148,
#   'market_cap_usd': 195051290.0,
#   'max_supply': None,
#   'name': 'Golem',
#   'percent_change_1h': -1.79,
#   'percent_change_24h': -5.13,
#   'percent_change_7d': -6.31,
#   'price_btc': 2.802e-05,
#   'price_usd': 0.233801,
#   'rank': 64,
#   'symbol': 'GNT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 2592620.0,
#   'available_supply': 8745102.0,
#   'id': 'factom',
#   'last_updated': 1521811145,
#   'market_cap_usd': 194311794.0,
#   'max_supply': None,
#   'name': 'Factom',
#   'percent_change_1h': -1.68,
#   'percent_change_24h': -6.98,
#   'percent_change_7d': -5.42,
#   'price_btc': 0.0026632,
#   'price_usd': 22.2195,
#   'rank': 65,
#   'symbol': 'FCT',
#   'total_supply': 8745102.0},
#  {'24h_volume_usd': 1376290.0,
#   'available_supply': 238421940.0,
#   'id': 'dragonchain',
#   'last_updated': 1521811157,
#   'market_cap_usd': 192783928.0,
#   'max_supply': None,
#   'name': 'Dragonchain',
#   'percent_change_1h': -0.47,
#   'percent_change_24h': -5.27,
#   'percent_change_7d': -0.29,
#   'price_btc': 9.692e-05,
#   'price_usd': 0.808583,
#   'rank': 66,
#   'symbol': 'DRGN',
#   'total_supply': 433494437.0},
#  {'24h_volume_usd': 2665600.0,
#   'available_supply': 6505299403.0,
#   'id': 'electroneum',
#   'last_updated': 1521811156,
#   'market_cap_usd': 184855889.0,
#   'max_supply': 21000000000.0,
#   'name': 'Electroneum',
#   'percent_change_1h': -0.6,
#   'percent_change_24h': -2.83,
#   'percent_change_7d': -20.71,
#   'price_btc': 3.41e-06,
#   'price_usd': 0.0284162,
#   'rank': 67,
#   'symbol': 'ETN',
#   'total_supply': 6505299403.0},
#  {'24h_volume_usd': 6217290.0,
#   'available_supply': 75975162.0,
#   'id': 'ethos',
#   'last_updated': 1521811151,
#   'market_cap_usd': 181047292.0,
#   'max_supply': None,
#   'name': 'Ethos',
#   'percent_change_1h': -3.01,
#   'percent_change_24h': -12.5,
#   'percent_change_7d': -10.43,
#   'price_btc': 0.00028562,
#   'price_usd': 2.38298,
#   'rank': 68,
#   'symbol': 'ETHOS',
#   'total_supply': 222295208.0},
#  {'24h_volume_usd': 4089880.0,
#   'available_supply': 184450000.0,
#   'id': 'revain',
#   'last_updated': 1521811155,
#   'market_cap_usd': 175816264.0,
#   'max_supply': 484450000.0,
#   'name': 'Revain',
#   'percent_change_1h': -2.0,
#   'percent_change_24h': -7.84,
#   'percent_change_7d': -11.6,
#   'price_btc': 0.00011425,
#   'price_usd': 0.953192,
#   'rank': 69,
#   'symbol': 'R',
#   'total_supply': 484450000.0},
#  {'24h_volume_usd': 1337370.0,
#   'available_supply': 4605074689.0,
#   'id': 'funfair',
#   'last_updated': 1521811151,
#   'market_cap_usd': 174437006.0,
#   'max_supply': None,
#   'name': 'FunFair',
#   'percent_change_1h': -2.18,
#   'percent_change_24h': -3.64,
#   'percent_change_7d': -1.42,
#   'price_btc': 4.54e-06,
#   'price_usd': 0.0378793,
#   'rank': 70,
#   'symbol': 'FUN',
#   'total_supply': 10999873621.0},
#  {'24h_volume_usd': 841330.0,
#   'available_supply': 4369245.0,
#   'id': 'zcoin',
#   'last_updated': 1521811147,
#   'market_cap_usd': 162664788.0,
#   'max_supply': 21400000.0,
#   'name': 'ZCoin',
#   'percent_change_1h': -1.93,
#   'percent_change_24h': -6.95,
#   'percent_change_7d': 3.62,
#   'price_btc': 0.00446228,
#   'price_usd': 37.2295,
#   'rank': 71,
#   'symbol': 'XZC',
#   'total_supply': 4369245.0},
#  {'24h_volume_usd': 5812930.0,
#   'available_supply': 134132697.0,
#   'id': 'kyber-network',
#   'last_updated': 1521811153,
#   'market_cap_usd': 159329524.0,
#   'max_supply': None,
#   'name': 'Kyber Network',
#   'percent_change_1h': -2.21,
#   'percent_change_24h': -9.07,
#   'percent_change_7d': 5.81,
#   'price_btc': 0.00014237,
#   'price_usd': 1.18785,
#   'rank': 72,
#   'symbol': 'KNC',
#   'total_supply': 215625349.0},
#  {'24h_volume_usd': 24798400.0,
#   'available_supply': 8400000000.0,
#   'id': 'iostoken',
#   'last_updated': 1521811158,
#   'market_cap_usd': 157117800.0,
#   'max_supply': None,
#   'name': 'IOStoken',
#   'percent_change_1h': -3.87,
#   'percent_change_24h': -8.97,
#   'percent_change_7d': 2.89,
#   'price_btc': 2.24e-06,
#   'price_usd': 0.0187045,
#   'rank': 73,
#   'symbol': 'IOST',
#   'total_supply': 21000000000.0},
#  {'24h_volume_usd': 2328190.0,
#   'available_supply': 60000000.0,
#   'id': 'gxchain',
#   'last_updated': 1521811150,
#   'market_cap_usd': 153577200.0,
#   'max_supply': 100000000.0,
#   'name': 'GXChain',
#   'percent_change_1h': -2.05,
#   'percent_change_24h': -14.79,
#   'percent_change_7d': -6.64,
#   'price_btc': 0.00030679,
#   'price_usd': 2.55962,
#   'rank': 74,
#   'symbol': 'GXS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 9827130.0,
#   'available_supply': 55798538.0,
#   'id': 'salt',
#   'last_updated': 1521811153,
#   'market_cap_usd': 153164198.0,
#   'max_supply': None,
#   'name': 'SALT',
#   'percent_change_1h': -3.44,
#   'percent_change_24h': -0.58,
#   'percent_change_7d': 0.59,
#   'price_btc': 0.00032901,
#   'price_usd': 2.74495,
#   'rank': 75,
#   'symbol': 'SALT',
#   'total_supply': 120000000.0},
#  {'24h_volume_usd': 15206200.0,
#   'available_supply': 250000000.0,
#   'id': 'aelf',
#   'last_updated': 1521811157,
#   'market_cap_usd': 146826250.0,
#   'max_supply': 1000000000.0,
#   'name': 'aelf',
#   'percent_change_1h': -2.62,
#   'percent_change_24h': -8.53,
#   'percent_change_7d': -9.01,
#   'price_btc': 7.039e-05,
#   'price_usd': 0.587305,
#   'rank': 76,
#   'symbol': 'ELF',
#   'total_supply': 280000000.0},
#  {'24h_volume_usd': 2148690.0,
#   'available_supply': 28797786814.0,
#   'id': 'reddcoin',
#   'last_updated': 1521811441,
#   'market_cap_usd': 146449129.0,
#   'max_supply': None,
#   'name': 'ReddCoin',
#   'percent_change_1h': -1.89,
#   'percent_change_24h': -4.64,
#   'percent_change_7d': -6.97,
#   'price_btc': 6.1e-07,
#   'price_usd': 0.00508543,
#   'rank': 77,
#   'symbol': 'RDD',
#   'total_supply': 28797786814.0},
#  {'24h_volume_usd': 767902.0,
#   'available_supply': 41513032.0,
#   'id': 'emercoin',
#   'last_updated': 1521811143,
#   'market_cap_usd': 136508549.0,
#   'max_supply': None,
#   'name': 'Emercoin',
#   'percent_change_1h': 0.39,
#   'percent_change_24h': -4.14,
#   'percent_change_7d': -4.17,
#   'price_btc': 0.00039413,
#   'price_usd': 3.28833,
#   'rank': 78,
#   'symbol': 'EMC',
#   'total_supply': 41513032.0},
#  {'24h_volume_usd': 14262400.0,
#   'available_supply': 74836171.0,
#   'id': 'enigma-project',
#   'last_updated': 1521811154,
#   'market_cap_usd': 136382935.0,
#   'max_supply': None,
#   'name': 'Enigma',
#   'percent_change_1h': 1.16,
#   'percent_change_24h': 13.59,
#   'percent_change_7d': 25.75,
#   'price_btc': 0.00021843,
#   'price_usd': 1.82242,
#   'rank': 79,
#   'symbol': 'ENG',
#   'total_supply': 150000000.0},
#  {'24h_volume_usd': 9681860.0,
#   'available_supply': 350000000.0,
#   'id': 'chainlink',
#   'last_updated': 1521811154,
#   'market_cap_usd': 135073750.0,
#   'max_supply': None,
#   'name': 'ChainLink',
#   'percent_change_1h': -1.68,
#   'percent_change_24h': -5.57,
#   'percent_change_7d': -10.73,
#   'price_btc': 4.626e-05,
#   'price_usd': 0.385925,
#   'rank': 80,
#   'symbol': 'LINK',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 5676460.0,
#   'available_supply': 662706996.0,
#   'id': 'request-network',
#   'last_updated': 1521811154,
#   'market_cap_usd': 133573234.0,
#   'max_supply': None,
#   'name': 'Request Network',
#   'percent_change_1h': -3.91,
#   'percent_change_24h': -10.64,
#   'percent_change_7d': 12.05,
#   'price_btc': 2.416e-05,
#   'price_usd': 0.201557,
#   'rank': 81,
#   'symbol': 'REQ',
#   'total_supply': 999999999.0},
#  {'24h_volume_usd': 1299760.0,
#   'available_supply': 998999942.0,
#   'id': 'nxt',
#   'last_updated': 1521811441,
#   'market_cap_usd': 132116743.0,
#   'max_supply': 1000000000.0,
#   'name': 'Nxt',
#   'percent_change_1h': -1.66,
#   'percent_change_24h': -4.52,
#   'percent_change_7d': -3.39,
#   'price_btc': 1.586e-05,
#   'price_usd': 0.132249,
#   'rank': 82,
#   'symbol': 'NXT',
#   'total_supply': 998999942.0},
#  {'24h_volume_usd': 308654.0,
#   'available_supply': 645222.0,
#   'id': 'byteball',
#   'last_updated': 1521811148,
#   'market_cap_usd': 130803286.0,
#   'max_supply': None,
#   'name': 'Byteball Bytes',
#   'percent_change_1h': -2.64,
#   'percent_change_24h': -6.94,
#   'percent_change_7d': 0.97,
#   'price_btc': 0.0242984,
#   'price_usd': 202.726,
#   'rank': 83,
#   'symbol': 'GBYTE',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 1097390.0,
#   'available_supply': 452552412.0,
#   'id': 'maidsafecoin',
#   'last_updated': 1521811142,
#   'market_cap_usd': 130594860.0,
#   'max_supply': None,
#   'name': 'MaidSafeCoin',
#   'percent_change_1h': -1.72,
#   'percent_change_24h': -7.36,
#   'percent_change_7d': -0.95,
#   'price_btc': 3.459e-05,
#   'price_usd': 0.288574,
#   'rank': 84,
#   'symbol': 'MAID',
#   'total_supply': 452552412.0},
#  {'24h_volume_usd': 339224.0,
#   'available_supply': 756097560976,
#   'id': 'kin',
#   'last_updated': 1521811154,
#   'market_cap_usd': 125362488.0,
#   'max_supply': None,
#   'name': 'Kin',
#   'percent_change_1h': -2.05,
#   'percent_change_24h': -6.33,
#   'percent_change_7d': -12.84,
#   'price_btc': 2e-08,
#   'price_usd': 0.000165802,
#   'rank': 85,
#   'symbol': 'KIN',
#   'total_supply': 10000000000000},
#  {'24h_volume_usd': 6773420.0,
#   'available_supply': 363932947.0,
#   'id': 'power-ledger',
#   'last_updated': 1521811156,
#   'market_cap_usd': 124429402.0,
#   'max_supply': None,
#   'name': 'Power Ledger',
#   'percent_change_1h': -2.08,
#   'percent_change_24h': -5.3,
#   'percent_change_7d': -12.2,
#   'price_btc': 4.098e-05,
#   'price_usd': 0.341902,
#   'rank': 86,
#   'symbol': 'POWR',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 14174000.0,
#   'available_supply': 3983937436.0,
#   'id': 'nucleus-vision',
#   'last_updated': 1521811160,
#   'market_cap_usd': 122476197.0,
#   'max_supply': None,
#   'name': 'Nucleus Vision',
#   'percent_change_1h': -1.81,
#   'percent_change_24h': -6.59,
#   'percent_change_7d': -7.11,
#   'price_btc': 3.68e-06,
#   'price_usd': 0.0307425,
#   'rank': 87,
#   'symbol': 'NCASH',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 55385.2,
#   'available_supply': 325226613094,
#   'id': 'dentacoin',
#   'last_updated': 1521811152,
#   'market_cap_usd': 121598653.0,
#   'max_supply': 8000000000000,
#   'name': 'Dentacoin',
#   'percent_change_1h': -1.01,
#   'percent_change_24h': -2.88,
#   'percent_change_7d': -22.25,
#   'price_btc': 4e-08,
#   'price_usd': 0.000373889,
#   'rank': 88,
#   'symbol': 'DCN',
#   'total_supply': 1963173416169},
#  {'24h_volume_usd': 240742.0,
#   'available_supply': 8911321.0,
#   'id': 'particl',
#   'last_updated': 1521811152,
#   'market_cap_usd': 118982173.0,
#   'max_supply': None,
#   'name': 'Particl',
#   'percent_change_1h': -2.5,
#   'percent_change_24h': -4.08,
#   'percent_change_7d': -10.91,
#   'price_btc': 0.00160033,
#   'price_usd': 13.3518,
#   'rank': 89,
#   'symbol': 'PART',
#   'total_supply': 8911321.0},
#  {'24h_volume_usd': 673507.0,
#   'available_supply': 239999750.0,
#   'id': 'polymath-network',
#   'last_updated': 1521811159,
#   'market_cap_usd': 117786837.0,
#   'max_supply': None,
#   'name': 'Polymath',
#   'percent_change_1h': -1.77,
#   'percent_change_24h': -10.83,
#   'percent_change_7d': -15.14,
#   'price_btc': 5.882e-05,
#   'price_usd': 0.490779,
#   'rank': 90,
#   'symbol': 'POLY',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 4570030.0,
#   'available_supply': 104661310.0,
#   'id': 'tenx',
#   'last_updated': 1521811151,
#   'market_cap_usd': 116948548.0,
#   'max_supply': None,
#   'name': 'TenX',
#   'percent_change_1h': -1.12,
#   'percent_change_24h': -1.25,
#   'percent_change_7d': -5.72,
#   'price_btc': 0.00013393,
#   'price_usd': 1.1174,
#   'rank': 91,
#   'symbol': 'PAY',
#   'total_supply': 205218256.0},
#  {'24h_volume_usd': 6268800.0,
#   'available_supply': 40670871.0,
#   'id': 'bancor',
#   'last_updated': 1521811150,
#   'market_cap_usd': 116186105.0,
#   'max_supply': None,
#   'name': 'Bancor',
#   'percent_change_1h': -1.65,
#   'percent_change_24h': -4.38,
#   'percent_change_7d': -12.79,
#   'price_btc': 0.0003424,
#   'price_usd': 2.85674,
#   'rank': 92,
#   'symbol': 'BNT',
#   'total_supply': 74311585.0},
#  {'24h_volume_usd': 11751200.0,
#   'available_supply': 12931016.0,
#   'id': 'neblio',
#   'last_updated': 1521811153,
#   'market_cap_usd': 113895742.0,
#   'max_supply': None,
#   'name': 'Neblio',
#   'percent_change_1h': -0.81,
#   'percent_change_24h': -3.54,
#   'percent_change_7d': -14.13,
#   'price_btc': 0.00105571,
#   'price_usd': 8.80795,
#   'rank': 93,
#   'symbol': 'NEBL',
#   'total_supply': 13684967.0},
#  {'24h_volume_usd': 8022360.0,
#   'available_supply': 133425493.0,
#   'id': 'storj',
#   'last_updated': 1521811151,
#   'market_cap_usd': 111458987.0,
#   'max_supply': None,
#   'name': 'Storj',
#   'percent_change_1h': -1.19,
#   'percent_change_24h': 0.99,
#   'percent_change_7d': 5.45,
#   'price_btc': 0.00010013,
#   'price_usd': 0.835365,
#   'rank': 94,
#   'symbol': 'STORJ',
#   'total_supply': 424999998.0},
#  {'24h_volume_usd': 1425460.0,
#   'available_supply': 1445976590.0,
#   'id': 'cindicator',
#   'last_updated': 1521811154,
#   'market_cap_usd': 110341028.0,
#   'max_supply': None,
#   'name': 'Cindicator',
#   'percent_change_1h': -2.18,
#   'percent_change_24h': -5.77,
#   'percent_change_7d': 1.52,
#   'price_btc': 9.15e-06,
#   'price_usd': 0.076309,
#   'rank': 95,
#   'symbol': 'CND',
#   'total_supply': 2000000005.0},
#  {'24h_volume_usd': 13876500.0,
#   'available_supply': 4088853037.0,
#   'id': 'storm',
#   'last_updated': 1521811157,
#   'market_cap_usd': 108614248.0,
#   'max_supply': None,
#   'name': 'Storm',
#   'percent_change_1h': -0.14,
#   'percent_change_24h': 2.21,
#   'percent_change_7d': 29.3,
#   'price_btc': 3.18e-06,
#   'price_usd': 0.0265635,
#   'rank': 96,
#   'symbol': 'STORM',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 974576.0,
#   'available_supply': 56159782.0,
#   'id': 'nexus',
#   'last_updated': 1521811144,
#   'market_cap_usd': 106769292.0,
#   'max_supply': None,
#   'name': 'Nexus',
#   'percent_change_1h': -2.6,
#   'percent_change_24h': -6.68,
#   'percent_change_7d': -14.15,
#   'price_btc': 0.00022787,
#   'price_usd': 1.90117,
#   'rank': 97,
#   'symbol': 'NXS',
#   'total_supply': 56159782.0},
#  {'24h_volume_usd': 238019.0,
#   'available_supply': 1288862.0,
#   'id': 'bitcoindark',
#   'last_updated': 1521811142,
#   'market_cap_usd': 106287824.0,
#   'max_supply': None,
#   'name': 'BitcoinDark',
#   'percent_change_1h': -1.18,
#   'percent_change_24h': 2.27,
#   'percent_change_7d': 8.67,
#   'price_btc': 0.00988431,
#   'price_usd': 82.4664,
#   'rank': 98,
#   'symbol': 'BTCD',
#   'total_supply': 1288862.0},
#  {'24h_volume_usd': 3041610.0,
#   'available_supply': 43460500.0,
#   'id': 'vertcoin',
#   'last_updated': 1521811441,
#   'market_cap_usd': 103978812.0,
#   'max_supply': 84000000.0,
#   'name': 'Vertcoin',
#   'percent_change_1h': -1.53,
#   'percent_change_24h': -4.27,
#   'percent_change_7d': 10.66,
#   'price_btc': 0.00028688,
#   'price_usd': 2.39249,
#   'rank': 99,
#   'symbol': 'VTC',
#   'total_supply': 43460500.0},
#  {'24h_volume_usd': 102395.0,
#   'available_supply': 818679549.0,
#   'id': 'smartcash',
#   'last_updated': 1521811152,
#   'market_cap_usd': 101409017.0,
#   'max_supply': 5000000000.0,
#   'name': 'SmartCash',
#   'percent_change_1h': -2.49,
#   'percent_change_24h': -4.7,
#   'percent_change_7d': -31.74,
#   'price_btc': 1.485e-05,
#   'price_usd': 0.123869,
#   'rank': 100,
#   'symbol': 'SMART',
#   'total_supply': 1419723828.0},
#  {'24h_volume_usd': 9681280.0,
#   'available_supply': 40000000.0,
#   'id': 'nuls',
#   'last_updated': 1521811155,
#   'market_cap_usd': 101182400.0,
#   'max_supply': None,
#   'name': 'Nuls',
#   'percent_change_1h': -2.93,
#   'percent_change_24h': -6.7,
#   'percent_change_7d': 0.09,
#   'price_btc': 0.00030319,
#   'price_usd': 2.52956,
#   'rank': 101,
#   'symbol': 'NULS',
#   'total_supply': 40000000.0},
#  {'24h_volume_usd': 159033.0,
#   'available_supply': 3511510.0,
#   'id': 'minexcoin',
#   'last_updated': 1521811155,
#   'market_cap_usd': 99657006.0,
#   'max_supply': 19000000.0,
#   'name': 'MinexCoin',
#   'percent_change_1h': -0.39,
#   'percent_change_24h': -10.03,
#   'percent_change_7d': 6.72,
#   'price_btc': 0.0034016,
#   'price_usd': 28.3801,
#   'rank': 102,
#   'symbol': 'MNX',
#   'total_supply': 5787358.0},
#  {'24h_volume_usd': 1072620.0,
#   'available_supply': 99735687.0,
#   'id': 'iconomi',
#   'last_updated': 1521811147,
#   'market_cap_usd': 99619694.0,
#   'max_supply': None,
#   'name': 'Iconomi',
#   'percent_change_1h': -1.7,
#   'percent_change_24h': -8.39,
#   'percent_change_7d': -15.08,
#   'price_btc': 0.00011972,
#   'price_usd': 0.998837,
#   'rank': 103,
#   'symbol': 'ICN',
#   'total_supply': 99735687.0},
#  {'24h_volume_usd': 323330.0,
#   'available_supply': 5066684.0,
#   'id': 'blocknet',
#   'last_updated': 1521811144,
#   'market_cap_usd': 98432490.0,
#   'max_supply': None,
#   'name': 'Blocknet',
#   'percent_change_1h': 0.24,
#   'percent_change_24h': -11.94,
#   'percent_change_7d': -7.48,
#   'price_btc': 0.00232854,
#   'price_usd': 19.4274,
#   'rank': 104,
#   'symbol': 'BLOCK',
#   'total_supply': 5066684.0},
#  {'24h_volume_usd': 5142540.0,
#   'available_supply': 464031018.0,
#   'id': 'achain',
#   'last_updated': 1521811153,
#   'market_cap_usd': 95493407.0,
#   'max_supply': 1000000000.0,
#   'name': 'Achain',
#   'percent_change_1h': -0.88,
#   'percent_change_24h': -2.33,
#   'percent_change_7d': 4.02,
#   'price_btc': 2.467e-05,
#   'price_usd': 0.205791,
#   'rank': 105,
#   'symbol': 'ACT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 1245970.0,
#   'available_supply': 10614760961.0,
#   'id': 'dent',
#   'last_updated': 1521811153,
#   'market_cap_usd': 95270239.0,
#   'max_supply': None,
#   'name': 'Dent',
#   'percent_change_1h': -1.32,
#   'percent_change_24h': -9.16,
#   'percent_change_7d': -20.23,
#   'price_btc': 1.08e-06,
#   'price_usd': 0.00897526,
#   'rank': 106,
#   'symbol': 'DENT',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 581960.0,
#   'available_supply': 26341131.0,
#   'id': 'aragon',
#   'last_updated': 1521811150,
#   'market_cap_usd': 94460876.0,
#   'max_supply': None,
#   'name': 'Aragon',
#   'percent_change_1h': -0.73,
#   'percent_change_24h': -10.94,
#   'percent_change_7d': 10.17,
#   'price_btc': 0.00042982,
#   'price_usd': 3.58606,
#   'rank': 107,
#   'symbol': 'ANT',
#   'total_supply': 39609524.0},
#  {'24h_volume_usd': 890544.0,
#   'available_supply': 5961115777.0,
#   'id': 'thekey',
#   'last_updated': 1521811160,
#   'market_cap_usd': 94089655.0,
#   'max_supply': None,
#   'name': 'THEKEY',
#   'percent_change_1h': -1.44,
#   'percent_change_24h': -0.89,
#   'percent_change_7d': 22.88,
#   'price_btc': 1.89e-06,
#   'price_usd': 0.0157839,
#   'rank': 108,
#   'symbol': 'TKY',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 51145.6,
#   'available_supply': 227384800.0,
#   'id': 'pillar',
#   'last_updated': 1521811152,
#   'market_cap_usd': 93732790.0,
#   'max_supply': None,
#   'name': 'Pillar',
#   'percent_change_1h': -1.37,
#   'percent_change_24h': -2.21,
#   'percent_change_7d': -16.88,
#   'price_btc': 4.941e-05,
#   'price_usd': 0.412221,
#   'rank': 109,
#   'symbol': 'PLR',
#   'total_supply': 800000000.0},
#  {'24h_volume_usd': 2337720.0,
#   'available_supply': 12636023.0,
#   'id': 'bitcore',
#   'last_updated': 1521811150,
#   'market_cap_usd': 92099929.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcore',
#   'percent_change_1h': -1.37,
#   'percent_change_24h': -1.9,
#   'percent_change_7d': -18.77,
#   'price_btc': 0.00087361,
#   'price_usd': 7.28868,
#   'rank': 110,
#   'symbol': 'BTX',
#   'total_supply': 16869244.0},
#  {'24h_volume_usd': 428631.0,
#   'available_supply': 64355352.0,
#   'id': 'gamecredits',
#   'last_updated': 1521811143,
#   'market_cap_usd': 90447586.0,
#   'max_supply': 84000000.0,
#   'name': 'GameCredits',
#   'percent_change_1h': -2.03,
#   'percent_change_24h': -4.5,
#   'percent_change_7d': 8.92,
#   'price_btc': 0.00016845,
#   'price_usd': 1.40544,
#   'rank': 111,
#   'symbol': 'GAME',
#   'total_supply': 64355352.0},
#  {'24h_volume_usd': 6972250.0,
#   'available_supply': 229258029.0,
#   'id': 'sirin-labs-token',
#   'last_updated': 1521811157,
#   'market_cap_usd': 89449147.0,
#   'max_supply': None,
#   'name': 'SIRIN LABS Token',
#   'percent_change_1h': -0.98,
#   'percent_change_24h': -4.63,
#   'percent_change_7d': -26.89,
#   'price_btc': 4.676e-05,
#   'price_usd': 0.390168,
#   'rank': 112,
#   'symbol': 'SRN',
#   'total_supply': 573145073.0},
#  {'24h_volume_usd': 10650400.0,
#   'available_supply': 22342464.0,
#   'id': 'metal',
#   'last_updated': 1521811151,
#   'market_cap_usd': 88673889.0,
#   'max_supply': None,
#   'name': 'Metal',
#   'percent_change_1h': -4.5,
#   'percent_change_24h': -11.77,
#   'percent_change_7d': 7.24,
#   'price_btc': 0.0004757,
#   'price_usd': 3.96885,
#   'rank': 113,
#   'symbol': 'MTL',
#   'total_supply': 66588888.0},
#  {'24h_volume_usd': 241149.0,
#   'available_supply': 1104590.0,
#   'id': 'gnosis-gno',
#   'last_updated': 1521811150,
#   'market_cap_usd': 88070839.0,
#   'max_supply': None,
#   'name': 'Gnosis',
#   'percent_change_1h': -1.55,
#   'percent_change_24h': -7.86,
#   'percent_change_7d': -6.96,
#   'price_btc': 0.00955653,
#   'price_usd': 79.7317,
#   'rank': 114,
#   'symbol': 'GNO',
#   'total_supply': 10000000.0},
#  {'24h_volume_usd': 8491970.0,
#   'available_supply': 3726781.0,
#   'id': 'genesis-vision',
#   'last_updated': 1521811156,
#   'market_cap_usd': 87675875.0,
#   'max_supply': None,
#   'name': 'Genesis Vision',
#   'percent_change_1h': 0.56,
#   'percent_change_24h': -4.71,
#   'percent_change_7d': -0.7,
#   'price_btc': 0.00281978,
#   'price_usd': 23.5259,
#   'rank': 115,
#   'symbol': 'GVT',
#   'total_supply': 4436644.0},
#  {'24h_volume_usd': 4992260.0,
#   'available_supply': 226091449.0,
#   'id': 'substratum',
#   'last_updated': 1521811153,
#   'market_cap_usd': 87453755.0,
#   'max_supply': None,
#   'name': 'Substratum',
#   'percent_change_1h': -1.18,
#   'percent_change_24h': -8.59,
#   'percent_change_7d': -12.45,
#   'price_btc': 4.636e-05,
#   'price_usd': 0.386807,
#   'rank': 116,
#   'symbol': 'SUB',
#   'total_supply': 352000000.0},
#  {'24h_volume_usd': 6350280.0,
#   'available_supply': 1050141509.0,
#   'id': 'decentraland',
#   'last_updated': 1521811153,
#   'market_cap_usd': 86423496.0,
#   'max_supply': None,
#   'name': 'Decentraland',
#   'percent_change_1h': -2.4,
#   'percent_change_24h': -6.77,
#   'percent_change_7d': -14.02,
#   'price_btc': 9.86e-06,
#   'price_usd': 0.082297,
#   'rank': 117,
#   'symbol': 'MANA',
#   'total_supply': 2644403343.0},
#  {'24h_volume_usd': 1177150.0,
#   'available_supply': 80070793.0,
#   'id': 'rlc',
#   'last_updated': 1521811150,
#   'market_cap_usd': 85236961.0,
#   'max_supply': None,
#   'name': 'iExec RLC',
#   'percent_change_1h': 1.01,
#   'percent_change_24h': 0.77,
#   'percent_change_7d': -0.77,
#   'price_btc': 0.00012759,
#   'price_usd': 1.06452,
#   'rank': 118,
#   'symbol': 'RLC',
#   'total_supply': 86999785.0},
#  {'24h_volume_usd': 1118800.0,
#   'available_supply': 521710040.0,
#   'id': 'singularitynet',
#   'last_updated': 1521811159,
#   'market_cap_usd': 84658410.0,
#   'max_supply': None,
#   'name': 'SingularityNET',
#   'percent_change_1h': 0.56,
#   'percent_change_24h': -8.82,
#   'percent_change_7d': -16.33,
#   'price_btc': 1.945e-05,
#   'price_usd': 0.162271,
#   'rank': 119,
#   'symbol': 'AGI',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 9723.49,
#   'available_supply': 1189228953.0,
#   'id': 'dynamic-trading-rights',
#   'last_updated': 1521811157,
#   'market_cap_usd': 83841236.0,
#   'max_supply': None,
#   'name': 'Dynamic Trading Rights',
#   'percent_change_1h': 0.96,
# ...
#   'symbol': 'STRC',
#   'total_supply': 20000000.0},
#  {'24h_volume_usd': 34.8807,
#   'available_supply': 10000305.0,
#   'id': 'yashcoin',
#   'last_updated': 1521811148,
#   'market_cap_usd': 1568558.0,
#   'max_supply': None,
#   'name': 'YashCoin',
#   'percent_change_1h': -1.69,
#   'percent_change_24h': -35.49,
#   'percent_change_7d': -5.75,
#   'price_btc': 1.88e-05,
#   'price_usd': 0.156851,
#   'rank': 961,
#   'symbol': 'YASH',
#   'total_supply': 10000305.0},
#  {'24h_volume_usd': 281.458,
#   'available_supply': 25960250000.0,
#   'id': 'smileycoin',
#   'last_updated': 1521811144,
#   'market_cap_usd': 1533477.0,
#   'max_supply': None,
#   'name': 'SmileyCoin',
#   'percent_change_1h': -1.07,
#   'percent_change_24h': -4.95,
#   'percent_change_7d': -7.43,
#   'price_btc': 7e-09,
#   'price_usd': 5.90702e-05,
#   'rank': 962,
#   'symbol': 'SMLY',
#   'total_supply': 25960250000.0},
#  {'24h_volume_usd': 19.0437,
#   'available_supply': 8000000.0,
#   'id': 'bowhead',
#   'last_updated': 1521811153,
#   'market_cap_usd': 1523496.0,
#   'max_supply': None,
#   'name': 'Bowhead',
#   'percent_change_1h': -1.75,
#   'percent_change_24h': -26.97,
#   'percent_change_7d': -15.66,
#   'price_btc': 2.283e-05,
#   'price_usd': 0.190437,
#   'rank': 963,
#   'symbol': 'AHT',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': None,
#   'available_supply': 58144264.0,
#   'id': 'fucktoken',
#   'last_updated': 1521784451,
#   'market_cap_usd': 1504704.0,
#   'max_supply': None,
#   'name': 'FuckToken',
#   'percent_change_1h': None,
#   'percent_change_24h': -3.61,
#   'percent_change_7d': 23.8,
#   'price_btc': 3.08e-06,
#   'price_usd': 0.0258788,
#   'rank': 964,
#   'symbol': 'FUCK',
#   'total_supply': 70856019.0},
#  {'24h_volume_usd': 11.4928,
#   'available_supply': 644053.0,
#   'id': 'chronologic',
#   'last_updated': 1521811154,
#   'market_cap_usd': 1496497.0,
#   'max_supply': None,
#   'name': 'Chronologic',
#   'percent_change_1h': -1.67,
#   'percent_change_24h': 3.36,
#   'percent_change_7d': -13.04,
#   'price_btc': 0.0002785,
#   'price_usd': 2.32356,
#   'rank': 965,
#   'symbol': 'DAY',
#   'total_supply': 941258.0},
#  {'24h_volume_usd': 5.07998,
#   'available_supply': 487604170.0,
#   'id': 'version',
#   'last_updated': 1521811151,
#   'market_cap_usd': 1484140.0,
#   'max_supply': None,
#   'name': 'Version',
#   'percent_change_1h': -1.65,
#   'percent_change_24h': 9.45,
#   'percent_change_7d': -8.86,
#   'price_btc': 3.6e-07,
#   'price_usd': 0.00304374,
#   'rank': 966,
#   'symbol': 'V',
#   'total_supply': 487604170.0},
#  {'24h_volume_usd': 184.761,
#   'available_supply': 33356077.0,
#   'id': 'renos',
#   'last_updated': 1521811149,
#   'market_cap_usd': 1405392.0,
#   'max_supply': None,
#   'name': 'Renos',
#   'percent_change_1h': -1.65,
#   'percent_change_24h': 15.03,
#   'percent_change_7d': 12.16,
#   'price_btc': 5.05e-06,
#   'price_usd': 0.042133,
#   'rank': 967,
#   'symbol': 'RNS',
#   'total_supply': 33356077.0},
#  {'24h_volume_usd': 470.973,
#   'available_supply': 118544993.0,
#   'id': 'worldcoin',
#   'last_updated': 1521811440,
#   'market_cap_usd': 1372419.0,
#   'max_supply': None,
#   'name': 'WorldCoin',
#   'percent_change_1h': -1.65,
#   'percent_change_24h': -7.78,
#   'percent_change_7d': -3.44,
#   'price_btc': 1.39e-06,
#   'price_usd': 0.0115772,
#   'rank': 968,
#   'symbol': 'WDC',
#   'total_supply': 118544993.0},
#  {'24h_volume_usd': 29.9494,
#   'available_supply': 18590521.0,
#   'id': 'universe',
#   'last_updated': 1521811150,
#   'market_cap_usd': 1262138.0,
#   'max_supply': None,
#   'name': 'Universe',
#   'percent_change_1h': -1.65,
#   'percent_change_24h': -1.11,
#   'percent_change_7d': -4.14,
#   'price_btc': 8.14e-06,
#   'price_usd': 0.0678915,
#   'rank': 969,
#   'symbol': 'UNI',
#   'total_supply': 29790521.0},
#  {'24h_volume_usd': 369.914,
#   'available_supply': 41004200.0,
#   'id': 'neverdie',
#   'last_updated': 1521811152,
#   'market_cap_usd': 1218259.0,
#   'max_supply': None,
#   'name': 'NEVERDIE',
#   'percent_change_1h': -0.66,
#   'percent_change_24h': 27.43,
#   'percent_change_7d': -5.32,
#   'price_btc': 3.56e-06,
#   'price_usd': 0.0297106,
#   'rank': 970,
#   'symbol': 'NDC',
#   'total_supply': 400000000.0},
#  {'24h_volume_usd': 46.5916,
#   'available_supply': 18474130.0,
#   'id': 'insanecoin-insn',
#   'last_updated': 1521811149,
#   'market_cap_usd': 1149183.0,
#   'max_supply': 30000000.0,
#   'name': 'InsaneCoin',
#   'percent_change_1h': -4.44,
#   'percent_change_24h': -8.63,
#   'percent_change_7d': -5.12,
#   'price_btc': 7.46e-06,
#   'price_usd': 0.062205,
#   'rank': 971,
#   'symbol': 'INSN',
#   'total_supply': 18724130.0},
#  {'24h_volume_usd': 2.423,
#   'available_supply': 465952.0,
#   'id': 'ico-openledger',
#   'last_updated': 1521811146,
#   'market_cap_usd': 1129001.0,
#   'max_supply': None,
#   'name': 'ICO OpenLedger',
#   'percent_change_1h': -2.57,
#   'percent_change_24h': -2.45,
#   'percent_change_7d': -0.76,
#   'price_btc': 0.00029042,
#   'price_usd': 2.423,
#   'rank': 972,
#   'symbol': 'ICOO',
#   'total_supply': 465952.0},
#  {'24h_volume_usd': 272.841,
#   'available_supply': 674589.0,
#   'id': 'platinumbar',
#   'last_updated': 1521811146,
#   'market_cap_usd': 1127561.0,
#   'max_supply': None,
#   'name': 'PlatinumBAR',
#   'percent_change_1h': -1.69,
#   'percent_change_24h': 1.41,
#   'percent_change_7d': 10.76,
#   'price_btc': 0.00020034,
#   'price_usd': 1.67148,
#   'rank': 973,
#   'symbol': 'XPTX',
#   'total_supply': 674589.0},
#  {'24h_volume_usd': 211.88,
#   'available_supply': 167766494.0,
#   'id': 'zetacoin',
#   'last_updated': 1521811440,
#   'market_cap_usd': 1126648.0,
#   'max_supply': None,
#   'name': 'Zetacoin',
#   'percent_change_1h': -4.45,
#   'percent_change_24h': -5.19,
#   'percent_change_7d': 2.17,
#   'price_btc': 8.1e-07,
#   'price_usd': 0.00671557,
#   'rank': 974,
#   'symbol': 'ZET',
#   'total_supply': 167766494.0},
#  {'24h_volume_usd': 55.8795,
#   'available_supply': 10585464.0,
#   'id': 'kekcoin',
#   'last_updated': 1521811152,
#   'market_cap_usd': 1122504.0,
#   'max_supply': 21000000.0,
#   'name': 'KekCoin',
#   'percent_change_1h': -1.69,
#   'percent_change_24h': -10.89,
#   'percent_change_7d': -5.91,
#   'price_btc': 1.271e-05,
#   'price_usd': 0.106042,
#   'rank': 975,
#   'symbol': 'KEK',
#   'total_supply': 11585464.0},
#  {'24h_volume_usd': 64.028,
#   'available_supply': 156913424.0,
#   'id': 'fastcoin',
#   'last_updated': 1521811440,
#   'market_cap_usd': 1073067.0,
#   'max_supply': 165888000.0,
#   'name': 'Fastcoin',
#   'percent_change_1h': -1.66,
#   'percent_change_24h': 3.67,
#   'percent_change_7d': -23.15,
#   'price_btc': 8.2e-07,
#   'price_usd': 0.00683859,
#   'rank': 976,
#   'symbol': 'FST',
#   'total_supply': 156913424.0},
#  {'24h_volume_usd': 2.06869,
#   'available_supply': 75000000.0,
#   'id': 'bitpark-coin',
#   'last_updated': 1521811148,
#   'market_cap_usd': 1070010.0,
#   'max_supply': None,
#   'name': 'Bitpark Coin',
#   'percent_change_1h': -1.69,
#   'percent_change_24h': 11.77,
#   'percent_change_7d': 14.43,
#   'price_btc': 1.71e-06,
#   'price_usd': 0.0142668,
#   'rank': 977,
#   'symbol': 'BPC',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 274.469,
#   'available_supply': 32550000.0,
#   'id': 'commodity-ad-network',
#   'last_updated': 1521811158,
#   'market_cap_usd': 1065811.0,
#   'max_supply': None,
#   'name': 'Commodity Ad Network',
#   'percent_change_1h': -1.73,
#   'percent_change_24h': 16.73,
#   'percent_change_7d': -21.32,
#   'price_btc': 3.92e-06,
#   'price_usd': 0.0327438,
#   'rank': 978,
#   'symbol': 'CDX',
#   'total_supply': 120000000.0},
#  {'24h_volume_usd': None,
#   'available_supply': 100000000.0,
#   'id': 'shorty',
#   'last_updated': 1521732548,
#   'market_cap_usd': 1061890.0,
#   'max_supply': None,
#   'name': 'Shorty',
#   'percent_change_1h': None,
#   'percent_change_24h': -1.38,
#   'percent_change_7d': -10.96,
#   'price_btc': 1.24e-06,
#   'price_usd': 0.0106189,
#   'rank': 979,
#   'symbol': 'SHORTY',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 108.75,
#   'available_supply': 61445805.0,
#   'id': 'maxcoin',
#   'last_updated': 1521811441,
#   'market_cap_usd': 1029770.0,
#   'max_supply': None,
#   'name': 'MaxCoin',
#   'percent_change_1h': -1.66,
#   'percent_change_24h': -4.63,
#   'percent_change_7d': -9.89,
#   'price_btc': 2.01e-06,
#   'price_usd': 0.016759,
#   'rank': 980,
#   'symbol': 'MAX',
#   'total_supply': 61445805.0},
#  {'24h_volume_usd': None,
#   'available_supply': 6695133.0,
#   'id': 'shadowcash',
#   'last_updated': 1521739443,
#   'market_cap_usd': 992433.0,
#   'max_supply': None,
#   'name': 'ShadowCash',
#   'percent_change_1h': None,
#   'percent_change_24h': -1.05,
#   'percent_change_7d': -25.49,
#   'price_btc': 1.726e-05,
#   'price_usd': 0.148232,
#   'rank': 981,
#   'symbol': 'SDC',
#   'total_supply': 6695133.0},
#  {'24h_volume_usd': 1.66863,
#   'available_supply': 10996318099.0,
#   'id': 'hitcoin',
#   'last_updated': 1521811146,
#   'market_cap_usd': 917440.0,
#   'max_supply': None,
#   'name': 'HitCoin',
#   'percent_change_1h': -1.69,
#   'percent_change_24h': -3.92,
#   'percent_change_7d': 1.92,
#   'price_btc': 1e-08,
#   'price_usd': 8.34316e-05,
#   'rank': 982,
#   'symbol': 'HTC',
#   'total_supply': 20996318099.0},
#  {'24h_volume_usd': 98.4011,
#   'available_supply': 2110317.0,
#   'id': 'anoncoin',
#   'last_updated': 1521811141,
#   'market_cap_usd': 915550.0,
#   'max_supply': None,
#   'name': 'Anoncoin',
#   'percent_change_1h': -1.65,
#   'percent_change_24h': -1.99,
#   'percent_change_7d': -37.59,
#   'price_btc': 5.2e-05,
#   'price_usd': 0.433845,
#   'rank': 983,
#   'symbol': 'ANC',
#   'total_supply': 2110317.0},
#  {'24h_volume_usd': 150.38,
#   'available_supply': 11124608.0,
#   'id': 'leviarcoin',
#   'last_updated': 1521811150,
#   'market_cap_usd': 903085.0,
#   'max_supply': 54000000.0,
#   'name': 'LeviarCoin',
#   'percent_change_1h': -1.8,
#   'percent_change_24h': -5.38,
#   'percent_change_7d': -6.07,
#   'price_btc': 9.73e-06,
#   'price_usd': 0.081179,
#   'rank': 984,
#   'symbol': 'XLC',
#   'total_supply': 11124608.0},
#  {'24h_volume_usd': 309.743,
#   'available_supply': 4773.0,
#   'id': 'sovereign-hero',
#   'last_updated': 1521811151,
#   'market_cap_usd': 877941.0,
#   'max_supply': None,
#   'name': 'Sovereign Hero',
#   'percent_change_1h': -1.23,
#   'percent_change_24h': 2.66,
#   'percent_change_7d': 4.17,
#   'price_btc': 0.0220466,
#   'price_usd': 183.939,
#   'rank': 985,
#   'symbol': 'HERO',
#   'total_supply': 4773.0},
#  {'24h_volume_usd': 302.097,
#   'available_supply': 24700248.0,
#   'id': 'kobocoin',
#   'last_updated': 1521811143,
#   'market_cap_usd': 877269.0,
#   'max_supply': None,
#   'name': 'Kobocoin',
#   'percent_change_1h': -3.76,
#   'percent_change_24h': 9.76,
#   'percent_change_7d': 12.39,
#   'price_btc': 4.26e-06,
#   'price_usd': 0.0355166,
#   'rank': 986,
#   'symbol': 'KOBO',
#   'total_supply': 24700248.0},
#  {'24h_volume_usd': 145.766,
#   'available_supply': 10343113.0,
#   'id': 'ultimate-secure-cash',
#   'last_updated': 1521811149,
#   'market_cap_usd': 868984.0,
#   'max_supply': 200084200.0,
#   'name': 'Ultimate Secure Cash',
#   'percent_change_1h': -2.56,
#   'percent_change_24h': -28.84,
#   'percent_change_7d': -40.95,
#   'price_btc': 1.007e-05,
#   'price_usd': 0.0840157,
#   'rank': 987,
#   'symbol': 'USC',
#   'total_supply': 38602656.0},
#  {'24h_volume_usd': 363.475,
#   'available_supply': 3429437309.0,
#   'id': 'popularcoin',
#   'last_updated': 1521811442,
#   'market_cap_usd': 858018.0,
#   'max_supply': 4999999999.0,
#   'name': 'PopularCoin',
#   'percent_change_1h': -1.66,
#   'percent_change_24h': -3.87,
#   'percent_change_7d': -1.58,
#   'price_btc': 3e-08,
#   'price_usd': 0.000250192,
#   'rank': 988,
#   'symbol': 'POP',
#   'total_supply': 3429437309.0},
#  {'24h_volume_usd': 358.989,
#   'available_supply': 787126712.0,
#   'id': 'netcoin',
#   'last_updated': 1521811441,
#   'market_cap_usd': 853379.0,
#   'max_supply': None,
#   'name': 'NetCoin',
#   'percent_change_1h': -1.66,
#   'percent_change_24h': -3.88,
#   'percent_change_7d': 7.64,
#   'price_btc': 1.3e-07,
#   'price_usd': 0.00108417,
#   'rank': 989,
#   'symbol': 'NET',
#   'total_supply': 787126712.0},
#  {'24h_volume_usd': 5.29349,
#   'available_supply': 248541988.0,
#   'id': 'qubitcoin',
#   'last_updated': 1521811441,
#   'market_cap_usd': 849840.0,
#   'max_supply': None,
#   'name': 'QubitCoin',
#   'percent_change_1h': -1.69,
#   'percent_change_24h': -10.52,
#   'percent_change_7d': -4.51,
#   'price_btc': 4.1e-07,
#   'price_usd': 0.0034193,
#   'rank': 990,
#   'symbol': 'Q2C',
#   'total_supply': 248541988.0},
#  {'24h_volume_usd': 222.575,
#   'available_supply': 1581531.0,
#   'id': 'etheriya',
#   'last_updated': 1521811153,
#   'market_cap_usd': 842368.0,
#   'max_supply': 100000000.0,
#   'name': 'Etheriya',
#   'percent_change_1h': -1.65,
#   'percent_change_24h': -21.18,
#   'percent_change_7d': -20.68,
#   'price_btc': 6.384e-05,
#   'price_usd': 0.532628,
#   'rank': 991,
#   'symbol': 'RIYA',
#   'total_supply': 1861531.0},
#  {'24h_volume_usd': 20.6174,
#   'available_supply': 7068507.0,
#   'id': 'fantomcoin',
#   'last_updated': 1521811442,
#   'market_cap_usd': 825291.0,
#   'max_supply': None,
#   'name': 'Fantomcoin',
#   'percent_change_1h': 5.91,
#   'percent_change_24h': -3.88,
#   'percent_change_7d': -17.8,
#   'price_btc': 1.4e-05,
#   'price_usd': 0.116756,
#   'rank': 992,
#   'symbol': 'FCN',
#   'total_supply': 7068507.0},
#  {'24h_volume_usd': 304.669,
#   'available_supply': 64151405.0,
#   'id': 'hobonickels',
#   'last_updated': 1521811441,
#   'market_cap_usd': 770407.0,
#   'max_supply': 120000000.0,
#   'name': 'HoboNickels',
#   'percent_change_1h': -1.66,
#   'percent_change_24h': -6.44,
#   'percent_change_7d': 2.05,
#   'price_btc': 1.44e-06,
#   'price_usd': 0.0120092,
#   'rank': 993,
#   'symbol': 'HBN',
#   'total_supply': 64151405.0},
#  {'24h_volume_usd': 16.5921,
#   'available_supply': 23079737.0,
#   'id': 'bitstar',
#   'last_updated': 1521811442,
#   'market_cap_usd': 767992.0,
#   'max_supply': None,
#   'name': 'Bitstar',
#   'percent_change_1h': -1.66,
#   'percent_change_24h': None,
#   'percent_change_7d': 6.37,
#   'price_btc': 3.99e-06,
#   'price_usd': 0.0332756,
#   'rank': 994,
#   'symbol': 'BITS',
#   'total_supply': 23079737.0},
#  {'24h_volume_usd': None,
#   'available_supply': 2993420.0,
#   'id': 'unicoin',
#   'last_updated': 1521768846,
#   'market_cap_usd': 754069.0,
#   'max_supply': None,
#   'name': 'UniCoin',
#   'percent_change_1h': None,
#   'percent_change_24h': -0.94,
#   'percent_change_7d': 11.93,
#   'price_btc': 2.93e-05,
#   'price_usd': 0.251909,
#   'rank': 995,
#   'symbol': 'UNIC',
#   'total_supply': 2993420.0},
#  {'24h_volume_usd': 364.467,
#   'available_supply': 16898938.0,
#   'id': 'bitcoin-scrypt',
#   'last_updated': 1521811442,
#   'market_cap_usd': 732851.0,
#   'max_supply': None,
#   'name': 'Bitcoin Scrypt',
#   'percent_change_1h': -0.53,
#   'percent_change_24h': -1.94,
#   'percent_change_7d': -12.23,
#   'price_btc': 5.2e-06,
#   'price_usd': 0.0433667,
#   'rank': 996,
#   'symbol': 'BTCS',
#   'total_supply': 16898938.0},
#  {'24h_volume_usd': 128.854,
#   'available_supply': 107648.0,
#   'id': 'triangles',
#   'last_updated': 1521811143,
#   'market_cap_usd': 688862.0,
#   'max_supply': None,
#   'name': 'Triangles',
#   'percent_change_1h': -1.69,
#   'percent_change_24h': -7.72,
#   'percent_change_7d': 39.45,
#   'price_btc': 0.000767,
#   'price_usd': 6.39921,
#   'rank': 997,
#   'symbol': 'TRI',
#   'total_supply': 107648.0},
#  {'24h_volume_usd': 317.887,
#   'available_supply': 20869450.0,
#   'id': 'machinecoin',
#   'last_updated': 1521811144,
#   'market_cap_usd': 672092.0,
#   'max_supply': None,
#   'name': 'Machinecoin',
#   'percent_change_1h': -1.69,
#   'percent_change_24h': -0.31,
#   'percent_change_7d': -16.11,
#   'price_btc': 3.86e-06,
#   'price_usd': 0.0322046,
#   'rank': 998,
#   'symbol': 'MAC',
#   'total_supply': 20869450.0},
#  {'24h_volume_usd': 72.9755,
#   'available_supply': 89063647.0,
#   'id': 'grimcoin',
#   'last_updated': 1521811156,
#   'market_cap_usd': 652906.0,
#   'max_supply': None,
#   'name': 'Grimcoin',
#   'percent_change_1h': -1.19,
#   'percent_change_24h': -0.46,
#   'percent_change_7d': -13.04,
#   'price_btc': 8.8e-07,
#   'price_usd': 0.00733078,
#   'rank': 999,
#   'symbol': 'GRIM',
#   'total_supply': 103230386.0},
#  {'24h_volume_usd': 227.188,
#   'available_supply': 32000.0,
#   'id': 'iticoin',
#   'last_updated': 1521811150,
#   'market_cap_usd': 650086.0,
#   'max_supply': None,
#   'name': 'iTicoin',
#   'percent_change_1h': -0.52,
#   'percent_change_24h': 9.33,
#   'percent_change_7d': -4.43,
#   'price_btc': 0.00243495,
#   'price_usd': 20.3152,
#   'rank': 1000,
#   'symbol': 'ITI',
#   'total_supply': 9999992.0},
#  ...]

# %% [markdown]
# You can pass a currency through symbol or coin slug:

# %%
data_from_symbol = cmc.ticker("BTC")
data_from_slug = cmc.ticker("bitcoin")

data_from_slug
# Out:
# {'24h_volume_usd': 5159310000.0,
#  'available_supply': 16934937.0,
#  'id': 'bitcoin',
#  'last_updated': 1521811167,
#  'market_cap_usd': 141888014860,
#  'max_supply': 21000000.0,
#  'name': 'Bitcoin',
#  'percent_change_1h': -1.63,
#  'percent_change_24h': -3.84,
#  'percent_change_7d': 0.06,
#  'price_btc': 1.0,
#  'price_usd': 8378.42,
#  'rank': 1,
#  'symbol': 'BTC',
#  'total_supply': 16934937.0}

# %% [markdown]
# To get all symbols and slugs you can use the next attributes:

# %%
all_symbols = cmc.symbols
all_slugs = cmc.coins

all_symbols
# Out:
# ['$$$',
#  '$PAC',
#  '1337',
#  '1ST',
#  '1WO',
#  '2GIVE',
#  '300',
#  '42',
#  '611',
#  '808',
#  '888',
#  '8BIT',
#  'AAC',
#  'ABC',
#  'ABJ',
#  'ABN',
#  'ABT',
#  'ABY',
#  'AC',
#  'ACAT',
#  'ACE',
#  'ACES',
#  'ACN',
#  'ACOIN',
#  'ACP',
#  'ACT',
#  'ADA',
#  'ADB',
#  'ADC',
#  'ADCN',
#  'ADK',
#  'ADST',
#  'ADT',
#  'ADX',
#  'ADZ',
#  'AE',
#  'AEON',
#  'AERM',
#  'AGI',
#  'AHT',
#  'AI',
#  'AIB',
#  'AID',
#  'AIDOC',
#  'AION',
#  'AIR',
#  'AIT',
#  'AIX',
#  'AKY',
#  'ALIS',
#  'ALL',
#  'ALQO',
#  'ALT',
#  'ALTC',
#  'ALTCOM',
#  'AMB',
#  'AMBER',
#  'AMM',
#  'AMMO',
#  'AMP',
#  'AMS',
#  'ANC',
#  'ANI',
#  'ANT',
#  'ANTI',
#  'ANTX',
#  'APC',
#  'APPC',
#  'APX',
#  'ARB',
#  'ARC',
#  'ARCO',
#  'ARCT',
#  'ARDR',
#  'ARG',
#  'ARGUS',
#  'ARI',
#  'ARK',
#  'ARN',
#  'ART',
#  'ARY',
#  'ASAFE2',
#  'ASN',
#  'AST',
#  'ASTRO',
#  'ATB',
#  'ATL',
#  'ATM',
#  'ATMC',
#  'ATMS',
#  'ATN',
#  'ATOM',
#  'ATS',
#  'ATX',
#  'AU',
#  'AUR',
#  'AURA',
#  'AUTO',
#  'AV',
#  'AVH',
#  'AVT',
#  'AWR',
#  'AXIOM',
#  'AXP',
#  'B2B',
#  'B2X',
#  'B@',
#  'BAC',
#  'BANCA',
#  'BAR',
#  'BAS',
#  'BASH',
#  'BAX',
#  'BAY',
#  'BBN',
#  'BBP',
#  'BBR',
#  'BBT',
#  'BCA',
#  'BCC',
#  'BCD',
#  'BCDN',
#  'BCF',
#  'BCH',
#  'BCN',
#  'BCO',
#  'BCPT',
#  'BCX',
#  'BCY',
#  'BDG',
#  'BDL',
#  'BEE',
#  'BELA',
#  'BENJI',
#  'BERN',
#  'BEST',
#  'BEZ',
#  'BFT',
#  'BIG',
#  'BIGUP',
#  'BIO',
#  'BIOB',
#  'BIOS',
#  'BIP',
#  'BIRDS',
#  'BIS',
#  'BIT',
#  'BITB',
#  'BITBTC',
#  'BITCF',
#  'BITCNY',
#  'BITEUR',
#  'BITG',
#  'BITGOLD',
#  'BITOK',
#  'BITS',
#  'BITSILVER',
#  'BITUSD',
#  'BITZ',
#  'BIX',
#  'BKX',
#  'BLAZR',
#  'BLC',
#  'BLITZ',
#  'BLK',
#  'BLN',
#  'BLOCK',
#  'BLOCKPAY',
#  'BLRY',
#  'BLT',
#  'BLU',
#  'BLUE',
#  'BMC',
#  'BNB',
#  'BNT',
#  'BNTY',
#  'BNX',
#  'BOAT',
#  'BOLI',
#  'BON',
#  'BOS',
#  'BOST',
#  'BOT',
#  'BPC',
#  'BPL',
#  'BPT',
#  'BQ',
#  'BRAIN',
#  'BRAT',
#  'BRD',
#  'BRIA',
#  'BRIT',
#  'BRK',
#  'BRO',
#  'BRX',
#  'BSC',
#  'BSD',
#  'BSN',
#  'BSR',
#  'BSTAR',
#  'BSTY',
#  'BT2',
#  'BTA',
#  'BTB',
#  'BTBc',
#  'BTC',
#  'BTCA',
#  'BTCD',
#  'BTCM',
#  'BTCP',
#  'BTCR',
#  'BTCRED',
#  'BTCS',
#  'BTCZ',
#  'BTDX',
#  'BTE',
#  'BTO',
#  'BTPL',
#  'BTQ',
#  'BTS',
#  'BTW',
#  'BTWTY',
#  'BTX',
#  'BUB',
#  'BUCKS',
#  'BUMBA',
#  'BUN',
#  'BURST',
#  'BUZZ',
#  'BWK',
#  'BXC',
#  'BXT',
#  'BYC',
#  'C2',
#  'C20',
#  'CAB',
#  'CACH',
#  'CAG',
#  'CALC',
#  'CANDY',
#  'CANN',
#  'CAPP',
#  'CARBON',
#  'CAS',
#  'CASH',
#  'CBX',
#  'CC',
#  'CCM100',
#  'CCN',
#  'CCO',
#  'CCRB',
#  'CCT',
#  'CDN',
#  'CDT',
#  'CDX',
#  'CEFS',
#  'CENNZ',
#  'CESC',
#  'CF',
#  'CFC',
#  'CFD',
#  'CFI',
#  'CFT',
#  'CFUN',
#  'CHAN',
#  'CHAT',
#  'CHC',
#  'CHEAP',
#  'CHESS',
#  'CHIPS',
#  'CHP',
#  'CHSB',
#  'CJ',
#  'CL',
#  'CLAM',
#  'CLD',
#  'CLOAK',
#  'CLUB',
#  'CME',
#  'CMP',
#  'CMPCO',
#  'CND',
#  'CNNC',
#  'CNO',
#  'CNT',
#  'CNX',
#  'COAL',
#  'COB',
#  'COFI',
#  'COLX',
#  'CON',
#  'CONX',
#  'COR',
#  'COSS',
#  'COUPE',
#  'COV',
#  'COVAL',
#  'COXST',
#  'CPAY',
#  'CPN',
#  'CPY',
#  'CRAVE',
#  'CRB',
#  'CRC',
#  'CRDNC',
#  'CREA',
#  'CRED',
#  'CREDO',
#  'CREVA',
#  'CRM',
#  'CRPT',
#  'CRT',
#  'CRW',
#  'CRX',
#  'CRYPT',
#  'CS',
#  'CSC',
#  'CSNO',
#  'CTIC2',
#  'CTIC3',
#  'CTO',
#  'CTR',
#  'CTX',
#  'CUBE',
#  'CURE',
#  'CV',
#  'CV2',
#  'CVC',
#  'CVCOIN',
#  'CWXT',
#  'CXO',
#  'CXT',
#  'CYC',
#  'CYDER',
#  'CYP',
#  'DADI',
#  'DAI',
#  'DALC',
#  'DAR',
#  'DASH',
#  'DASHS',
#  'DAT',
#  'DATA',
#  'DATX',
#  'DAV',
#  'DAXX',
#  'DAY',
#  'DBC',
#  'DBET',
#  'DBG',
#  'DBIX',
#  'DBTC',
#  'DCN',
#  'DCR',
#  'DCRE',
#  'DCT',
#  'DCY',
#  'DDD',
#  'DDF',
#  'DEB',
#  'DEM',
#  'DENT',
#  'DES',
#  'DEUS',
#  'DEW',
#  'DFS',
#  'DFT',
#  'DGB',
#  'DGC',
#  'DGCS',
#  'DGD',
#  'DGPT',
#  'DIBC',
#  'DICE',
#  'DIM',
#  'DIME',
#  'DISK',
#  'DIVX',
#  'DIX',
#  'DLC',
#  'DLISK',
#  'DLT',
#  'DMB',
#  'DMC',
#  'DMD',
#  'DMT',
#  'DNA',
#  'DNR',
#  'DNT',
#  'DOGE',
#  'DOLLAR',
#  'DON',
#  'DOPE',
#  'DOT',
#  'DOVU',
#  'DP',
#  'DPY',
#  'DRG',
#  'DRGN',
#  'DRM',
#  'DROP',
#  'DRP',
#  'DRPU',
#  'DRS',
#  'DRT',
#  'DRXNE',
#  'DSH',
#  'DSR',
#  'DTA',
#  'DTB',
#  'DTC',
#  'DTH',
#  'DTR',
#  'DUB',
#  'DUO',
#  'DUTCH',
#  'DXT',
#  'DYN',
#  'EAC',
#  'EAG',
#  'EAGLE',
#  'EBCH',
#  'EBET',
#  'EBST',
#  'EBT',
#  'EBTC',
#  'ECA',
#  'ECASH',
#  'ECC',
#  'ECH',
#  'ECN',
#  'ECO',
#  'ECOB',
#  'EDG',
#  'EDO',
#  'EDR',
#  'EDRC',
#  'EFL',
#  'EFYT',
#  'EGC',
#  'EGG',
#  'EGO',
#  'EGOLD',
#  'EKO',
#  'EKT',
#  'EL',
#  'ELA',
#  'ELC',
#  'ELE',
#  'ELEC',
#  'ELF',
#  'ELITE',
#  'ELIX',
#  'ELLA',
#  'ELS',
#  'ELTCOIN',
#  'EMC',
#  'EMC2',
#  'EMD',
#  'EMV',
#  'ENG',
#  'ENJ',
#  'ENRG',
#  'EOS',
#  'EOT',
#  'EPC',
#  'EPY',
#  'EQL',
#  'EQT',
#  'ERA',
#  'ERC',
#  'ERC20',
#  'ERO',
#  'ERY',
#  'ESC',
#  'ESP',
#  'ESZ',
#  'ETBS',
#  'ETC',
#  'ETG',
#  'ETH',
#  'ETHD',
#  'ETHOS',
#  'ETN',
#  'ETP',
#  'EUC',
#  'EVC',
#  'EVE',
#  'EVIL',
#  'EVN',
#  'EVO',
#  'EVR',
#  'EVX',
#  'EXCL',
#  'EXN',
#  'EXP',
#  'EXRN',
#  'EXY',
#  'EZT',
#  'FAP',
#  'FAZZ',
#  'FC2',
#  'FCN',
#  'FCT',
#  'FDX',
#  'FID',
#  'FIL',
#  'FIMK',
#  'FIRE',
#  'FJC',
#  'FLAP',
#  'FLASH',
#  'FLAX',
#  'FLDC',
#  'FLIK',
#  'FLIXX',
#  'FLO',
#  'FLT',
#  'FLUZ',
#  'FLY',
#  'FNC',
#  'FONZ',
#  'FOR',
#  'FOTA',
#  'FRC',
#  'FRCT',
#  'FRD',
#  'FRGC',
#  'FRK',
#  'FRN',
#  'FRST',
#  'FRWC',
#  'FSN',
#  'FST',
#  'FTC',
#  'FUCK',
#  'FUEL',
#  'FUN',
#  'FUNC',
#  'FUTC',
#  'FUZZ',
#  'FXE',
#  'FYN',
#  'FYP',
#  'G3N',
#  'GAIA',
#  'GAIN',
#  'GAM',
#  'GAME',
#  'GAP',
#  'GARY',
#  'GAS',
#  'GAT',
#  'GAY',
#  'GB',
#  'GBC',
#  'GBG',
#  'GBX',
#  'GBYTE',
#  'GCN',
#  'GCR',
#  'GCS',
#  'GDC',
#  'GEERT',
#  'GEM',
#  'GEO',
#  'GET',
#  'GETX',
#  'GJC',
#  'GLA',
#  'GLC',
#  'GLD',
#  'GLS',
#  'GLT',
#  'GML',
#  'GMT',
#  'GMX',
#  'GNO',
#  'GNT',
#  'GNX',
#  'GOD',
#  'GOLF',
#  'GOLOS',
#  'GOOD',
#  'GP',
#  'GPL',
#  'GPU',
#  'GRC',
#  'GRE',
#  'GRFT',
#  'GRID',
#  'GRIM',
#  'GRLC',
#  'GRN',
#  'GRS',
#  'GRWI',
#  'GRX',
#  'GSR',
#  'GTO',
#  'GUESS',
#  'GUN',
#  'GUP',
#  'GVT',
#  'GXS',
#  'HAC',
#  'HAL',
#  'HALLO',
#  'HAT',
#  'HAV',
#  'HBC',
#  'HBN',
#  'HBT',
#  'HC',
#  'HCC',
#  'HDG',
#  'HDLB',
#  'HEAT',
#  'HERO',
#  'HGT',
#  'HIGH',
#  'HIRE',
#  'HKN',
#  'HLC',
#  'HMP',
#  'HMQ',
#  'HODL',
#  'HOLD',
#  'HONEY',
#  'HORSE',
#  'HOT',
#  'HPB',
#  'HPC',
#  'HPY',
#  'HQX',
#  'HSR',
#  'HST',
#  'HT',
#  'HTC',
#  'HTML',
#  'HUC',
#  'HUSH',
#  'HVCO',
#  'HVN',
#  'HWC',
#  'HXX',
#  'HYP',
#  'HYPER',
#  'I0C',
#  'IBANK',
#  'IC',
#  'ICE',
#  'ICOB',
#  'ICON',
#  'ICOO',
#  'ICOS',
#  'ICX',
#  'IDH',
#  'IDT',
#  'IDXM',
#  'IETH',
#  'IFC',
#  'IFLT',
#  'IFT',
#  'IGNIS',
#  'IHT',
#  'IMPS',
#  'IMS',
#  'IMX',
#  'INCNT',
#  'IND',
#  'INDI',
#  'INDIA',
#  'INF',
#  'INFX',
#  'ING',
#  'INK',
#  'INN',
#  'INPAY',
#  'INS',
#  'INSN',
#  'INSTAR',
#  'INT',
#  'INXT',
#  'IOC',
#  'ION',
#  'IOP',
#  'IOST',
#  'IPBC',
#  'IPC',
#  'IPL',
#  'IQT',
#  'IRL',
#  'ISL',
#  'ITC',
#  'ITI',
#  'ITNS',
#  'ITT',
#  'IVZ',
#  'IXC',
#  'IXT',
#  'J',
#  'J8T',
#  'JC',
#  'JET',
#  'JEW',
#  'JIN',
#  'JIYO',
#  'JNT',
#  'JOBS',
#  'JS',
#  'JWL',
#  'KARMA',
#  'KASHH',
#  'KAYI',
#  'KB3',
#  'KBR',
#  'KCASH',
#  'KCS',
#  'KDC',
#  'KED',
#  'KEK',
#  'KEY',
#  'KICK',
#  'KIN',
#  'KLC',
#  'KLN',
#  'KMD',
#  'KOBO',
#  'KORE',
#  'KRB',
#  'KRM',
#  'KRONE',
#  'KURT',
#  'KUSH',
#  'KZC',
#  'LA',
#  'LALA',
#  'LANA',
#  'LATX',
#  'LAZ',
#  'LBC',
#  'LCC',
#  'LCP',
#  'LCT',
#  'LDC',
#  'LDCN',
#  'LDOGE',
#  'LEA',
#  'LEAF',
#  'LEDU',
#  'LEND',
#  'LEO',
#  'LEPEN',
#  'LET',
#  'LEV',
#  'LEVO',
#  'LGD',
#  'LGO',
#  'LIFE',
#  'LIGHT',
#  'LINDA',
#  'LINK',
#  'LINX',
#  'LIR',
#  'LKC',
#  'LKK',
#  'LLT',
#  'LMC',
#  'LNK',
#  'LOC',
#  'LOCI',
#  'LOG',
#  'LOOM',
#  'LRC',
#  'LSK',
#  'LTB',
#  'LTC',
#  'LTCR',
#  'LTCU',
#  'LTH',
#  'LUN',
#  'LUNA',
#  'LUX',
#  'LVPS',
#  'LYM',
#  'MAC',
#  'MAD',
#  'MAGE',
#  'MAGN',
#  'MAID',
#  'MAN',
#  'MANA',
#  'MANNA',
#  'MAO',
#  'MAR',
#  'MARS',
#  'MARX',
#  'MAX',
#  'MAY',
#  'MBI',
#  'MBL',
#  'MBRS',
#  'MCAP',
#  'MCI',
#  'MCO',
#  'MCR',
#  'MCRN',
#  'MDA',
#  'MDC',
#  'MDS',
#  'MDT',
#  'MEC',
#  'MED',
#  'MEDIC',
#  'MEE',
#  'MEME',
#  'MER',
#  'METAL',
#  'MGC',
#  'MGM',
#  'MGO',
#  'MILO',
#  'MINEX',
#  'MINT',
#  'MIOTA',
#  'MKR',
#  'MLM',
#  'MLN',
#  'MMXVI',
#  'MNC',
#  'MND',
#  'MNE',
#  'MNM',
#  'MNTP',
#  'MNX',
#  'MOAC',
#  'MOBI',
#  'MOD',
#  'MOF',
#  'MOIN',
#  'MOJO',
#  'MONA',
#  'MONETA',
#  'MONK',
#  'MOON',
#  'MOT',
#  'MOTO',
#  'MRJA',
#  'MRT',
#  'MSCN',
#  'MSD',
#  'MSP',
#  'MST',
#  'MTH',
#  'MTL',
#  'MTLMC3',
#  'MTN',
#  'MTNC',
#  'MTX',
#  'MUE',
#  'MUSE',
#  'MUSIC',
#  'MVC',
#  'MWAT',
#  'MXT',
#  'MYB',
#  'MYST',
#  'MZC',
#  'NAMO',
#  'NANJ',
#  'NANO',
#  'NANOX',
#  'NAS',
#  'NAV',
#  'NBIT',
#  'NCASH',
#  'NDC',
#  'NEBL',
#  'NEO',
#  'NEOG',
#  'NEOS',
#  'NETKO',
#  'NEU',
#  'NEVA',
#  'NEWB',
#  'NGC',
#  'NIO',
#  'NKA',
#  'NKC',
#  'NLC2',
#  'NLG',
#  'NMC',
#  'NMR',
#  'NMS',
#  'NOAH',
#  'NOBL',
#  'NODC',
#  'NOTE',
#  'NOX',
#  'NPX',
#  'NPXS',
#  'NRO',
#  'NSR',
#  'NTC',
#  'NTK',
#  'NTO',
#  'NTRN',
#  'NTWK',
#  'NUKO',
#  'NULS',
#  'NUMUS',
#  'NVC',
#  'NVST',
#  'NXC',
#  'NXS',
#  'NXT',
#  'NYAN',
#  'NYC',
#  'OAX',
#  'OBITS',
#  'OC',
#  'OCC',
#  'OCL',
#  'OCN',
#  'OCOW',
#  'OCT',
#  'ODN',
#  'OF',
#  'OFF',
#  'OK',
#  'OMC',
#  'OMG',
#  'OMNI',
#  'ONG',
#  'ONION',
#  'ONT',
#  'ONX',
#  'OP',
#  'OPAL',
#  'OPC',
#  'OPES',
#  'OPT',
#  'ORB',
#  'ORE',
#  'ORLY',
#  'ORME',
#  'OS76',
#  'OST',
#  'OTN',
#  'OTX',
#  'OX',
#  'OXY',
#  'P7C',
#  'PAK',
#  'PARETO',
#  'PART',
#  'PASC',
#  'PASL',
#  'PAY',
#  'PAYP',
#  'PBL',
#  'PBT',
#  'PCN',
#  'PCOIN',
#  'PCS',
#  'PDC',
#  'PDG',
#  'PEPECASH',
#  'PEX',
#  'PFR',
#  'PGL',
#  'PHO',
#  'PHR',
#  'PHS',
#  'PIE',
#  'PIGGY',
#  'PING',
#  'PINK',
#  'PIPL',
#  'PIRL',
#  'PIVX',
#  'PIX',
#  'PIZZA',
#  'PKB',
#  'PKT',
#  'PLACO',
#  'PLAY',
#  'PLBT',
#  'PLNC',
#  'PLR',
#  'PLU',
#  'PLX',
#  'PND',
#  'PNX',
#  'POA',
#  'POE',
#  'POKE',
#  'POLIS',
#  'POLL',
#  'POLY',
#  ...]

# %% [markdown]
# Other parameters:

# %%
print(cmc.ticker.__doc__)
# Out:
# Get currencies with other aditional data.
#
#         Args:
#             currency (str, optional): Specify a currency to return data,
#                 that can be a symbol or coin slug (see ``symbols`` and ``coins``
#                 properties). In this case the method returns a dict, otherwise
#                 returns a list. If you dont specify a currency,
#                 returns data for all in coinmarketcap. As default, ``None``.
#             limit (int, optional): Limit amount of coins on response.
#                 If ``limit == 0``, returns all coins in coinmarketcap.
#                 Only works if ``currency == None``. As default ``0``.
#             start (int, optional): Rank of first currency to retrieve.
#                 The count starts at 0 for the first currency ranked.
#                 Only works if ``currency == None``. As default ``0``.
#             convert (str, optional): Allows to convert prices, 24h volumes
#                 and market capitalizations in terms of one of badges
#                 returned by ``ticker_badges`` property. As default, ``"USD"``.
#
#         Returns (dict/list):
#             The type depends if currency param is provided or not.

# %% [markdown]
# If you want to get the valid badges that can be passed to `convert` param programatically, use this:

# %%
print(cmc.ticker_badges)
# Out:
# ['AUD', 'BRL', 'CAD', 'CHF', 'CLP', 'CNY', 'CZK', 'DKK', 'EUR', 'GBP', 'HKD', 'HUF', 'IDR', 'ILS', 'INR', 'JPY', 'KRW', 'MXN', 'MYR', 'NOK', 'NZD', 'PHP', 'PKR', 'PLN', 'RUB', 'SEK', 'SGD', 'THB', 'TRY', 'TWD', 'USD', 'ZAR']

# %% [markdown]
# #### `stats([convert="USD"])`
# Get global criptocurrency statistics. The `convert` parameter works just like in previous method.

# %%
cmc.stats()
# Out:
# {'active_assets': 663,
#  'active_currencies': 915,
#  'active_markets': 9592,
#  'bitcoin_percentage_of_market_cap': 44.26,
#  'last_updated': 1521811465,
#  'total_24h_volume_usd': 13787093083.0,
#  'total_market_cap_usd': 320372107262.0}

# %% [markdown]
# _____________________________________________
#
# ## Web scraper

# %% [markdown]
# #### `currency(name, [convert="USD"])`
# Get metadata from a currency passed as first argument.

# %%
cmc.currency("BTC")
# Out:
# {'announcement': None,
#  'chats': [],
#  'circulating_supply': 16934937.0,
#  'explorers': ['http://blockchain.info',
#   'https://live.blockcypher.com/btc/',
#   'https://blockchair.com/bitcoin/blocks'],
#  'markets_cap': 141888014860.0,
#  'markets_volume_24h': 5159310000.0,
#  'max_supply': 21000000.0,
#  'message_boards': ['https://bitcointalk.org', 'https://forum.bitcoin.com/'],
#  'mineable': True,
#  'price': 8378.42,
#  'rank': 1,
#  'slug': 'bitcoin',
#  'source_code': 'https://github.com/bitcoin/',
#  'symbol': 'BTC',
#  'webs': ['https://bitcoin.org/', 'https://bitcoin.com/']}

# %%
show_page("currencies/bitcoin")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/currencies/bitcoin"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `markets(name, [convert="USD"])`
# Get all markets for a exchange in coinmarketcap. Pass a currency symbol or slug as first parameter. You can convert the response fields `"volume_24h"` and `"price"` between `"USD"` and `"BTC"` with `convert` parameter.

# %%
cmc.markets("BTC", convert="BTC")
# Out:
# {'markets': [{'pair': 'BTC/USD',
#    'percent_volume': 7.65788448455,
#    'price': 0.99835,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 47355.4},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 6.82523438212,
#    'price': 1.00026,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 42206.4},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 6.21858349275,
#    'price': 0.998818,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 38455.0},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 3.70375108299,
#    'price': 1.00584,
#    'source': 'bitFlyer',
#    'updated': True,
#    'volume_24h': 22903.5},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 2.70125268689,
#    'price': 0.999896,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 16704.2},
#   {'pair': 'BTC/USD',
#    'percent_volume': 2.47589309423,
#    'price': 0.998433,
#    'source': 'GDAX',
#    'updated': True,
#    'volume_24h': 15310.7},
#   {'pair': 'ICX/BTC',
#    'percent_volume': 2.43726389769,
#    'price': 1.01338,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 15077.9},
#   {'pair': 'BTC/USD',
#    'percent_volume': 2.30806057399,
#    'price': 0.999636,
#    'source': 'Bitstamp',
#    'updated': True,
#    'volume_24h': 14272.8},
#   {'pair': 'BTC/KRW',
#    'percent_volume': 2.15158616172,
#    'price': 1.0353,
#    'source': 'Bithumb',
#    'updated': True,
#    'volume_24h': 13305.1},
#   {'pair': 'BTC/KRW',
#    'percent_volume': 1.9409959859,
#    'price': 1.03585,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 12002.9},
#   {'pair': 'BTC/USD',
#    'percent_volume': 1.55752997978,
#    'price': 0.999021,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 9631.57},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 1.53746721945,
#    'price': 0.999277,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 9507.51},
#   {'pair': 'BTC/USD',
#    'percent_volume': 1.53183080683,
#    'price': 1.06554,
#    'source': 'BTCC',
#    'updated': True,
#    'volume_24h': 9472.66},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 1.48426436868,
#    'price': 1.00061,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 9182.27},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 1.37383681151,
#    'price': 1.0073,
#    'source': 'BTCBOX',
#    'updated': True,
#    'volume_24h': 8495.63},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 1.33951439243,
#    'price': 0.998341,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 8286.78},
#   {'pair': 'BTC/USD',
#    'percent_volume': 1.15759471712,
#    'price': 0.999711,
#    'source': 'Gemini',
#    'updated': True,
#    'volume_24h': 7158.43},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 1.10737869986,
#    'price': 1.00029,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 6850.7},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 1.07343036181,
#    'price': 1.00462,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 6640.69},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.965809381487,
#    'price': 0.994254,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 5974.89},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.942583407471,
#    'price': 1.00454,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 5831.2},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.920811116215,
#    'price': 1.02963,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 5694.18},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.850059407169,
#    'price': 0.999766,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 5258.82},
#   {'pair': 'XVG/BTC',
#    'percent_volume': 0.825594895441,
#    'price': 1.00905,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 5107.46},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.774361300251,
#    'price': 1.00125,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 4790.52},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.761518497629,
#    'price': 1.01259,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 4711.06},
#   {'pair': 'VEN/BTC',
#    'percent_volume': 0.715198350167,
#    'price': 0.996218,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 4424.51},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.656669205766,
#    'price': 1.01175,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 4062.42},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.642025774764,
#    'price': 0.998911,
#    'source': 'CoinBene',
#    'updated': True,
#    'volume_24h': 3970.21},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.631464284953,
#    'price': 1.0023,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 3904.89},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.621162519794,
#    'price': 1.0006,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 3842.77},
#   {'pair': 'BNB/BTC',
#    'percent_volume': 0.61845285513,
#    'price': 0.997728,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 3826.0},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.54882145093,
#    'price': 1.00289,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 3395.24},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.543458330668,
#    'price': 1.001,
#    'source': 'itBit',
#    'updated': True,
#    'volume_24h': 3360.67},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.527911678112,
#    'price': 0.998938,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 3264.54},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.486970156862,
#    'price': 1.00246,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 3012.6},
#   {'pair': 'NANO/BTC',
#    'percent_volume': 0.486128959105,
#    'price': 0.998453,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 3007.4},
#   {'pair': 'ADA/BTC',
#    'percent_volume': 0.482667255893,
#    'price': 1.03194,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 2985.98},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.455072480622,
#    'price': 1.00212,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 2815.26},
#   {'pair': 'BTC/KRW',
#    'percent_volume': 0.397089920939,
#    'price': 1.03574,
#    'source': 'Coinone',
#    'updated': True,
#    'volume_24h': 2455.55},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.391061983095,
#    'price': 0.999301,
#    'source': 'GDAX',
#    'updated': True,
#    'volume_24h': 2418.28},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.384076552872,
#    'price': 1.00485,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 2376.05},
#   {'pair': 'ABT/BTC',
#    'percent_volume': 0.372061380301,
#    'price': 1.00103,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 2301.72},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.370441008584,
#    'price': 0.994254,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 2291.7},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.36292256135,
#    'price': 1.00663,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 2245.18},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.355545605905,
#    'price': 0.998754,
#    'source': 'Bitstamp',
#    'updated': True,
#    'volume_24h': 2198.65},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.351738895317,
#    'price': 1.00131,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 2176.0},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.340842089349,
#    'price': 0.997018,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 2108.58},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.317800248483,
#    'price': 1.0001,
#    'source': 'EXX',
#    'updated': True,
#    'volume_24h': 1966.04},
#   {'pair': 'XLM/BTC',
#    'percent_volume': 0.316137235406,
#    'price': 0.98776,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1955.76},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.312987589426,
#    'price': 0.992045,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 1936.27},
#   {'pair': 'HT/BTC',
#    'percent_volume': 0.304971013566,
#    'price': 0.998629,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 1886.68},
#   {'pair': 'DGD/BTC',
#    'percent_volume': 0.295272042192,
#    'price': 0.998524,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1826.67},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.284906314992,
#    'price': 1.00876,
#    'source': 'CoinsBank',
#    'updated': True,
#    'volume_24h': 1761.82},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.283530161979,
#    'price': 1.01038,
#    'source': 'Bitbank',
#    'updated': True,
#    'volume_24h': 1753.32},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.280876706381,
#    'price': 1.00191,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1737.62},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.274899162873,
#    'price': 0.979145,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 1700.63},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.27100523132,
#    'price': 1.00508,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 1676.55},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.265328115581,
#    'price': 0.998889,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 1641.43},
#   {'pair': 'EKT/BTC',
#    'percent_volume': 0.264310537649,
#    'price': 1.00047,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 1635.13},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.264234946146,
#    'price': 1.00338,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 1634.67},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.247771504329,
#    'price': 0.996365,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 1532.19},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.243856252096,
#    'price': 1.00399,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1508.59},
#   {'pair': 'BTC/KRW',
#    'percent_volume': 0.237814746546,
#    'price': 1.03851,
#    'source': 'Korbit',
#    'updated': True,
#    'volume_24h': 1470.61},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.235349300585,
#    'price': 1.0006,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 1455.96},
#   {'pair': 'NCASH/BTC',
#    'percent_volume': 0.232742362835,
#    'price': 0.998985,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1439.84},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.22163622655,
#    'price': 0.995934,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 1371.13},
#   {'pair': 'STORM/BTC',
#    'percent_volume': 0.220294961923,
#    'price': 1.00162,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1362.84},
#   {'pair': 'CTR/BTC',
#    'percent_volume': 0.219800709785,
#    'price': 0.997213,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1359.78},
#   {'pair': 'IOTA/BTC',
#    'percent_volume': 0.219508034989,
#    'price': 1.00578,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1357.97},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.21695924455,
#    'price': 1.00046,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 1342.2},
#   {'pair': 'XVG/BTC',
#    'percent_volume': 0.215804051317,
#    'price': 1.00426,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 1335.05},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.215119851298,
#    'price': 0.985394,
#    'source': 'CoinsBank',
#    'updated': True,
#    'volume_24h': 1330.27},
#   {'pair': 'IOST/BTC',
#    'percent_volume': 0.214759337973,
#    'price': 0.983689,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1328.58},
#   {'pair': 'AION/BTC',
#    'percent_volume': 0.204835530333,
#    'price': 1.00182,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1267.19},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.199484039532,
#    'price': 1.02983,
#    'source': 'Exmo',
#    'updated': True,
#    'volume_24h': 1233.58},
#   {'pair': 'ADA/BTC',
#    'percent_volume': 0.197487648542,
#    'price': 1.0277,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 1221.74},
#   {'pair': 'NEBL/BTC',
#    'percent_volume': 0.19396779802,
#    'price': 1.00346,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1199.97},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.19241429571,
#    'price': 0.98989,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 1190.35},
#   {'pair': 'ONT/BTC',
#    'percent_volume': 0.19016942188,
#    'price': 0.998643,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 1176.47},
#   {'pair': 'WAVES/BTC',
#    'percent_volume': 0.189622449514,
#    'price': 1.0027,
#    'source': 'Tidex',
#    'updated': True,
#    'volume_24h': 1173.08},
#   {'pair': 'XRB/BTC',
#    'percent_volume': 0.188690154304,
#    'price': 0.998453,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 1167.31},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.184009295817,
#    'price': 0.99878,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 1138.36},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.182616861557,
#    'price': 0.998889,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 1129.74},
#   {'pair': 'DLT/BTC',
#    'percent_volume': 0.176531357875,
#    'price': 1.00589,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1092.1},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.175174587299,
#    'price': 1.04397,
#    'source': 'Livecoin',
#    'updated': True,
#    'volume_24h': 1083.26},
#   {'pair': 'VEN/BTC',
#    'percent_volume': 0.171388228271,
#    'price': 1.00894,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1060.28},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.170296221782,
#    'price': 1.07064,
#    'source': 'LakeBTC',
#    'updated': True,
#    'volume_24h': 1053.09},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.169689745334,
#    'price': 1.00363,
#    'source': 'Livecoin',
#    'updated': True,
#    'volume_24h': 1049.77},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.163389678077,
#    'price': 1.00578,
#    'source': 'CEX.IO',
#    'updated': True,
#    'volume_24h': 1010.38},
#   {'pair': 'ENG/BTC',
#    'percent_volume': 0.162985360445,
#    'price': 1.011,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1008.29},
#   {'pair': 'BTC/GBP',
#    'percent_volume': 0.15642886355,
#    'price': 0.994983,
#    'source': 'CoinsBank',
#    'updated': True,
#    'volume_24h': 967.337},
#   {'pair': 'GVT/BTC',
#    'percent_volume': 0.154475307745,
#    'price': 0.996796,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 955.648},
#   {'pair': 'MTL/BTC',
#    'percent_volume': 0.149478709362,
#    'price': 1.00189,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 924.737},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.148834243339,
#    'price': 0.997562,
#    'source': 'YoBit',
#    'updated': True,
#    'volume_24h': 920.75},
#   {'pair': 'BTC/RUB',
#    'percent_volume': 0.144793780564,
#    'price': 0.972113,
#    'source': 'Exmo',
#    'updated': True,
#    'volume_24h': 895.386},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.144231883721,
#    'price': 1.00087,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 892.277},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.144053759127,
#    'price': 1.00331,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 891.176},
#   {'pair': 'MEE/BTC',
#    'percent_volume': 0.142297322704,
#    'price': 0.999962,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 880.309},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.142078301168,
#    'price': 1.00681,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 878.594},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.140012133405,
#    'price': 1.0082,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 866.172},
#   {'pair': 'BTC/TRY',
#    'percent_volume': 0.138985639553,
#    'price': 1.01222,
#    'source': 'Paribu',
#    'updated': True,
#    'volume_24h': 859.47},
#   {'pair': 'BTC/PLN',
#    'percent_volume': 0.137858357028,
#    'price': 0.999672,
#    'source': 'BitBay',
#    'updated': True,
#    'volume_24h': 852.499},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.135836381222,
#    'price': 1.0006,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 840.34},
#   {'pair': 'ADA/BTC',
#    'percent_volume': 0.135567159174,
#    'price': 1.03005,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 838.674},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.134616063001,
#    'price': 1.03891,
#    'source': 'Trade By Trade',
#    'updated': True,
#    'volume_24h': 832.449},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.133438192316,
#    'price': 1.00361,
#    'source': 'EXX',
#    'updated': True,
#    'volume_24h': 825.504},
#   {'pair': 'LINK/BTC',
#    'percent_volume': 0.133120901826,
#    'price': 1.00446,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 823.541},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.127189100868,
#    'price': 1.02565,
#    'source': 'Neraex',
#    'updated': True,
#    'volume_24h': 786.522},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.127105368741,
#    'price': 1.00144,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 786.326},
#   {'pair': 'XVG/BTC',
#    'percent_volume': 0.12629460141,
#    'price': 1.00426,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 781.31},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0,
#    'price': 1.01752,
#    'source': 'Bitinka',
#    'updated': False,
#    'volume_24h': 716.988},
#   {'pair': 'OCN/BTC',
#    'percent_volume': 0.122149473476,
#    'price': 0.995092,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 755.667},
#   {'pair': 'ELA/BTC',
#    'percent_volume': 0.121238498947,
#    'price': 1.00095,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 750.031},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.117545950912,
#    'price': 1.00147,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 727.188},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.116216121923,
#    'price': 1.00228,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 718.96},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.116054084752,
#    'price': 1.00463,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 717.958},
#   {'pair': 'HSR/BTC',
#    'percent_volume': 0.113035076396,
#    'price': 0.991352,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 699.282},
#   {'pair': 'ENJ/BTC',
#    'percent_volume': 0.112588698876,
#    'price': 1.0028,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 696.519},
#   {'pair': 'XMR/BTC',
#    'percent_volume': 0.112434027031,
#    'price': 1.00141,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 695.563},
#   {'pair': 'OMG/BTC',
#    'percent_volume': 0.111832202368,
#    'price': 0.999076,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 691.84},
#   {'pair': 'ELF/BTC',
#    'percent_volume': 0.111197233739,
#    'price': 1.00441,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 687.911},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.108764544096,
#    'price': 1.00082,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 672.862},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.10868216874,
#    'price': 1.00085,
#    'source': 'EXX',
#    'updated': True,
#    'volume_24h': 672.353},
#   {'pair': 'BQX/BTC',
#    'percent_volume': 0.107278298842,
#    'price': 0.997815,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 663.667},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.107218213288,
#    'price': 0.989361,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 663.296},
#   {'pair': 'ZEC/BTC',
#    'percent_volume': 0.106410547147,
#    'price': 1.0007,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 658.299},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.102619536333,
#    'price': 1.0082,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 634.846},
#   {'pair': 'NULS/BTC',
#    'percent_volume': 0.102406523353,
#    'price': 1.00114,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 633.529},
#   {'pair': 'ZEC/BTC',
#    'percent_volume': 0.102151838133,
#    'price': 0.99214,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 631.953},
#   {'pair': 'NOAH/BTC',
#    'percent_volume': 0.101858194216,
#    'price': 1.00041,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 630.136},
#   {'pair': 'BTC/CNY',
#    'percent_volume': 0.101129026944,
#    'price': 1.0376,
#    'source': 'Fatbtc',
#    'updated': True,
#    'volume_24h': 625.37},
#   {'pair': 'BBN/BTC',
#    'percent_volume': 0.100431646868,
#    'price': 1.0066,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 621.312},
#   {'pair': 'WAVES/BTC',
#    'percent_volume': 0.100078498869,
#    'price': 1.00382,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 619.126},
#   {'pair': 'XEM/BTC',
#    'percent_volume': 0.0988475203079,
#    'price': 1.02168,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 611.511},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0963415650542,
#    'price': 0.999621,
#    'source': 'xBTCe',
#    'updated': True,
#    'volume_24h': 595.764},
#   {'pair': 'BTC/RUB',
#    'percent_volume': 0.0962101521327,
#    'price': 1.01672,
#    'source': 'GetBTC',
#    'updated': True,
#    'volume_24h': 594.952},
#   {'pair': 'EDO/BTC',
#    'percent_volume': 0.09600857479,
#    'price': 0.99712,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 593.948},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0956267407851,
#    'price': 1.00425,
#    'source': 'Gate.io',
#    'updated': True,
#    'volume_24h': 591.345},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0954724565882,
#    'price': 1.00892,
#    'source': 'GetBTC',
#    'updated': True,
#    'volume_24h': 590.39},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.0953544175481,
#    'price': 1.00767,
#    'source': 'GetBTC',
#    'updated': True,
#    'volume_24h': 589.66},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.0,
#    'price': 1.02576,
#    'source': 'Bitinka',
#    'updated': False,
#    'volume_24h': 540.822},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.0940656793253,
#    'price': 1.00721,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 581.929},
#   {'pair': 'SALT/BTC',
#    'percent_volume': 0.0911821542028,
#    'price': 0.996489,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 564.091},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0906574716386,
#    'price': 1.00409,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 560.844},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0893164008365,
#    'price': 0.999299,
#    'source': 'C2CX',
#    'updated': True,
#    'volume_24h': 552.322},
#   {'pair': 'STRAT/BTC',
#    'percent_volume': 0.0887990835984,
#    'price': 1.00824,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 549.347},
#   {'pair': 'SUB/BTC',
#    'percent_volume': 0.0881267068658,
#    'price': 1.00002,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 545.188},
#   {'pair': 'XEM/BTC',
#    'percent_volume': 0.086567196001,
#    'price': 1.01504,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 535.54},
#   {'pair': 'HPB/BTC',
#    'percent_volume': 0.0854552256019,
#    'price': 1.00723,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 528.661},
#   {'pair': 'SNT/BTC',
#    'percent_volume': 0.0852513223668,
#    'price': 1.02799,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 527.4},
#   {'pair': 'BTG/BTC',
#    'percent_volume': 0.0846902008214,
#    'price': 0.987444,
#    'source': 'Exrates',
#    'updated': True,
#    'volume_24h': 523.928},
#   {'pair': 'SWFTC/BTC',
#    'percent_volume': 0.0839005603462,
#    'price': 1.01293,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 519.044},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0826748150431,
#    'price': 0.998377,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 511.46},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0825040557749,
#    'price': 1.00087,
#    'source': 'Tidex',
#    'updated': True,
#    'volume_24h': 510.403},
#   {'pair': 'BCPT/BTC',
#    'percent_volume': 0.0796808100308,
#    'price': 0.998458,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 492.938},
#   {'pair': 'BCN/BTC',
#    'percent_volume': 0.0793856155184,
#    'price': 1.00251,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 491.112},
#   {'pair': 'BTC/ZAR',
#    'percent_volume': 0.0792962624847,
#    'price': 1.03827,
#    'source': 'Luno',
#    'updated': True,
#    'volume_24h': 490.358},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0787176967463,
#    'price': 1.00033,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 486.98},
#   {'pair': 'BTC/BRL',
#    'percent_volume': 0.0786640073963,
#    'price': 1.03573,
#    'source': 'Negocie Coins',
#    'updated': True,
#    'volume_24h': 486.449},
#   {'pair': 'CHAT/BTC',
#    'percent_volume': 0.0761243267026,
#    'price': 1.01151,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 470.937},
#   {'pair': 'LRC/BTC',
#    'percent_volume': 0.0753490292307,
#    'price': 0.991085,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 466.14},
#   {'pair': 'ITC/BTC',
#    'percent_volume': 0.0748755162997,
#    'price': 0.999469,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 463.21},
#   {'pair': 'LSK/BTC',
#    'percent_volume': 0.0747594155032,
#    'price': 1.00576,
#    'source': 'YoBit',
#    'updated': True,
#    'volume_24h': 462.492},
#   {'pair': 'LSK/BTC',
#    'percent_volume': 0.074742940432,
#    'price': 0.984163,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 462.391},
#   {'pair': 'CMT/BTC',
#    'percent_volume': 0.0744500718119,
#    'price': 0.997715,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 460.579},
#   {'pair': 'SNC/BTC',
#    'percent_volume': 0.0739093018252,
#    'price': 0.992864,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 457.234},
#   {'pair': 'DGD/BTC',
#    'percent_volume': 0.0737994034086,
#    'price': 1.00097,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 456.554},
#   {'pair': 'PROPY/BTC',
#    'percent_volume': 0.0735865842525,
#    'price': 0.998264,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 455.237},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.0733101907038,
#    'price': 0.996566,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 453.527},
#   {'pair': 'BTC/ARS',
#    'percent_volume': 0.0,
#    'price': 1.04089,
#    'source': 'Bitinka',
#    'updated': False,
#    'volume_24h': 419.361},
#   {'pair': 'XMR/BTC',
#    'percent_volume': 0.0728012079135,
#    'price': 0.99935,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 450.378},
#   {'pair': 'ZIL/BTC',
#    'percent_volume': 0.0715696478793,
#    'price': 0.998809,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 442.759},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.0712488685503,
#    'price': 1.00365,
#    'source': 'YoBit',
#    'updated': True,
#    'volume_24h': 440.775},
#   {'pair': 'STR/BTC',
#    'percent_volume': 0.071234525547,
#    'price': 0.98776,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 440.686},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.0711558328536,
#    'price': 0.991776,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 440.199},
#   {'pair': 'TDX/BTC',
#    'percent_volume': 0.0711273406715,
#    'price': 1.00856,
#    'source': 'Tidex',
#    'updated': True,
#    'volume_24h': 440.023},
#   {'pair': 'DRG/BTC',
#    'percent_volume': 0.0706026581074,
#    'price': 0.977278,
#    'source': 'Qryptos',
#    'updated': True,
#    'volume_24h': 436.778},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0677435548552,
#    'price': 0.998698,
#    'source': 'GDAX',
#    'updated': True,
#    'volume_24h': 419.089},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.0677406474897,
#    'price': 1.02229,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 419.071},
#   {'pair': 'ICX/BTC',
#    'percent_volume': 0.0671237045264,
#    'price': 0.996395,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 415.255},
#   {'pair': 'BTC/CAD',
#    'percent_volume': 0.0664581116467,
#    'price': 1.02278,
#    'source': 'QuadrigaCX',
#    'updated': True,
#    'volume_24h': 410.969},
#   {'pair': 'NULS/BTC',
#    'percent_volume': 0.0663951187271,
#    'price': 1.00114,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 410.748},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.0661646615536,
#    'price': 1.00083,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 409.322},
#   {'pair': 'W3C/BTC',
#    'percent_volume': 0.0651348726865,
#    'price': 0.989936,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 402.951},
#   {'pair': 'KNC/BTC',
#    'percent_volume': 0.0649416297916,
#    'price': 21.0695,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 401.755},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0649311632757,
#    'price': 0.999838,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 401.691},
#   {'pair': 'NAS/BTC',
#    'percent_volume': 0.0646788039486,
#    'price': 1.00066,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 400.13},
#   {'pair': 'XLM/BTC',
#    'percent_volume': 0.0634389094666,
#    'price': 0.990275,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 392.459},
#   {'pair': 'BTC/IDR',
#    'percent_volume': 0.0632243458912,
#    'price': 1.03404,
#    'source': 'Bitcoin Indonesia',
#    'updated': True,
#    'volume_24h': 390.972},
#   {'pair': 'TRIG/BTC',
#    'percent_volume': 0.0631158042451,
#    'price': 0.994552,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 390.46},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0628514278072,
#    'price': 1.00148,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 388.825},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0625316176,
#    'price': 1.00326,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 386.847},
#   {'pair': 'INS/BTC',
#    'percent_volume': 0.0625197943136,
#    'price': 1.00778,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 386.773},
#   {'pair': 'ZEC/BTC',
#    'percent_volume': 0.0620104238745,
#    'price': 1.00533,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 383.621},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.0610004050929,
#    'price': 0.994254,
#    'source': 'Liqui',
#    'updated': True,
#    'volume_24h': 377.373},
#   {'pair': 'VEN/BTC',
#    'percent_volume': 0.0591191457772,
#    'price': 1.00577,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 365.735},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0580703621221,
#    'price': 1.00182,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 359.247},
#   {'pair': 'MTN/BTC',
#    'percent_volume': 0.0578096683471,
#    'price': 0.999906,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 357.634},
#   {'pair': 'POWR/BTC',
#    'percent_volume': 0.0577687714055,
#    'price': 1.00458,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 357.381},
#   {'pair': 'LSK/BTC',
#    'percent_volume': 0.0572138522399,
#    'price': 1.01123,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 353.949},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0572095881038,
#    'price': 1.00188,
#    'source': 'Exmo',
#    'updated': True,
#    'volume_24h': 353.922},
#   {'pair': 'INS/BTC',
#    'percent_volume': 0.0570250673055,
#    'price': 1.00116,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 352.781},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.0569595546691,
#    'price': 1.01237,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 352.375},
#   {'pair': 'MCO/BTC',
#    'percent_volume': 0.056953158465,
#    'price': 1.00617,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 352.335},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.0568622548364,
#    'price': 1.00236,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 351.773},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0565164721639,
#    'price': 0.965943,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 349.634},
#   {'pair': 'RDN/BTC',
#    'percent_volume': 0.0563311760681,
#    'price': 1.00256,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 348.488},
#   {'pair': 'CPC/BTC',
#    'percent_volume': 0.0559520556043,
#    'price': 1.00165,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 346.142},
#   {'pair': 'MDS/BTC',
#    'percent_volume': 0.054579779079,
#    'price': 0.996216,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 337.653},
#   {'pair': 'DSH/BTC',
#    'percent_volume': 0.0545764840647,
#    'price': 1.00397,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 337.633},
#   {'pair': 'BTC/AUD',
#    'percent_volume': 0.0532295985316,
#    'price': 1.00689,
#    'source': 'BTC Markets',
#    'updated': True,
#    'volume_24h': 329.165},
#   {'pair': 'BTC/TRY',
#    'percent_volume': 0.0529731688927,
#    'price': 1.01368,
#    'source': 'BTCTurk',
#    'updated': True,
#    'volume_24h': 327.579},
#   {'pair': 'AST/BTC',
#    'percent_volume': 0.0522519484195,
#    'price': 1.00121,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 323.252},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.0515161911186,
#    'price': 1.00501,
#    'source': 'ZB.COM',
#    'updated': True,
#    'volume_24h': 318.7},
#   {'pair': 'IOTA/BTC',
#    'percent_volume': 0.0513867164408,
#    'price': 1.00618,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 317.9},
#   {'pair': 'BTC/RUR',
#    'percent_volume': 0.0512942622172,
#    'price': 0.996607,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 317.197},
#   {'pair': 'XEM/BTC',
#    'percent_volume': 0.0509213441332,
#    'price': 1.01284,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 315.02},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.0499985463172,
#    'price': 1.01365,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 309.311},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0495748462488,
#    'price': 1.00362,
#    'source': 'Kucoin',
#    'updated': True,
#    'volume_24h': 306.564},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0492906997254,
#    'price': 1.00006,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 304.932},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.0489933731449,
#    'price': 0.973624,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 303.093},
#   {'pair': 'BTG/BTC',
#    'percent_volume': 0.0488828932551,
#    'price': 1.05534,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 302.409},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0487642727419,
#    'price': 1.0044,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 301.676},
#   {'pair': 'MCO/BTC',
#    'percent_volume': 0.0483275864408,
#    'price': 1.00477,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 298.974},
#   {'pair': 'STORJ/BTC',
#    'percent_volume': 0.0482998695562,
#    'price': 1.00097,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 298.803},
#   {'pair': 'BTC/AUD',
#    'percent_volume': 0.0482457925575,
#    'price': 1.01923,
#    'source': 'ACX',
#    'updated': True,
#    'volume_24h': 298.346},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0479168726051,
#    'price': 1.00191,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 296.434},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.0478298454638,
#    'price': 1.02592,
#    'source': 'Exmo',
#    'updated': True,
#    'volume_24h': 295.774},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0471844103184,
#    'price': 1.00415,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 291.902},
#   {'pair': 'ONT/BTC',
#    'percent_volume': 0.0468487065131,
#    'price': 1.00066,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 289.825},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0466988802766,
#    'price': 0.993212,
#    'source': 'BtcTrade.im',
#    'updated': True,
#    'volume_24h': 288.899},
#   {'pair': 'RCN/BTC',
#    'percent_volume': 0.0458543875053,
#    'price': 0.996383,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 283.674},
#   {'pair': 'LSK/BTC',
#    'percent_volume': 0.0456774258573,
#    'price': 1.01363,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 282.579},
#   {'pair': 'VIB/BTC',
#    'percent_volume': 0.0456458324854,
#    'price': 1.00953,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 282.384},
#   {'pair': 'ICX/BTC',
#    'percent_volume': 0.0452752402938,
#    'price': 0.997084,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 280.091},
#   {'pair': 'ZRX/BTC',
#    'percent_volume': 0.0452624478855,
#    'price': 0.997762,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 280.012},
#   {'pair': 'BTC/MXN',
#    'percent_volume': 0.0452083708868,
#    'price': 0.97806,
#    'source': 'Bitso',
#    'updated': True,
#    'volume_24h': 279.563},
#   {'pair': 'IOST/BTC',
#    'percent_volume': 0.045153712415,
#    'price': 0.998669,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 279.34},
#   {'pair': 'XEM/BTC',
#    'percent_volume': 0.0451508050495,
#    'price': 1.01409,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 279.322},
#   {'pair': 'MTL/BTC',
#    'percent_volume': 0.0450492410807,
#    'price': 1.00183,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 278.694},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.044918797281,
#    'price': 1.00501,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 277.886},
#   {'pair': 'BTM/BTC',
#    'percent_volume': 0.0443429450837,
#    'price': 0.990258,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 274.324},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.0442078494993,
#    'price': 1.00111,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 273.488},
#   {'pair': 'LDC/BTC',
#    'percent_volume': 0.0438986996323,
#    'price': 0.841473,
#    'source': 'Qryptos',
#    'updated': True,
#    'volume_24h': 271.575},
#   {'pair': 'DTA/BTC',
#    'percent_volume': 0.0438709827477,
#    'price': 1.00657,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 271.404},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.0437304600809,
#    'price': 1.01411,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 270.424},
#   {'pair': 'BTC/BRL',
#    'percent_volume': 0.0,
#    'price': 1.04802,
#    'source': 'Bitinka',
#    'updated': False,
#    'volume_24h': 250.013},
#   {'pair': 'NBT/BTC',
#    'percent_volume': 0.0435155088568,
#    'price': 1.00097,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 269.205},
#   {'pair': 'WTC/BTC',
#    'percent_volume': 0.0434771316319,
#    'price': 0.990171,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 268.967},
#   {'pair': 'THETA/BTC',
#    'percent_volume': 0.0430687436886,
#    'price': 0.99869,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 266.441},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.0429749326945,
#    'price': 0.997264,
#    'source': 'RightBTC',
#    'updated': True,
#    'volume_24h': 265.86},
#   {'pair': 'REQ/BTC',
#    'percent_volume': 0.0424965741543,
#    'price': 0.998275,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 262.901},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0419468882467,
#    'price': 0.996659,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 259.395},
#   {'pair': 'WABI/BTC',
#    'percent_volume': 0.0419183960646,
#    'price': 1.0007,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 259.325},
#   {'pair': 'BTC/GBP',
#    'percent_volume': 0.0415305535042,
#    'price': 1.00337,
#    'source': 'GDAX',
#    'updated': True,
#    'volume_24h': 256.82},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.04142298098,
#    'price': 1.02031,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 256.26},
#   {'pair': 'MTX/BTC',
#    'percent_volume': 0.0413086246029,
#    'price': 1.00017,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 255.552},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.0409954044242,
#    'price': 0.999056,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 253.615},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.0409717578513,
#    'price': 1.00249,
#    'source': 'YoBit',
#    'updated': True,
#    'volume_24h': 253.468},
#   {'pair': 'HSR/BTC',
#    'percent_volume': 0.0403317497882,
#    'price': 0.995053,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 249.509},
#   {'pair': 'ZIL/BTC',
#    'percent_volume': 0.0402203007767,
#    'price': 0.999307,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 248.819},
#   {'pair': 'ELF/BTC',
#    'percent_volume': 0.0401445154488,
#    'price': 1.00441,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 248.351},
#   {'pair': 'XMR/BTC',
#    'percent_volume': 0.0400900508014,
#    'price': 1.00098,
#    'source': 'Livecoin',
#    'updated': True,
#    'volume_24h': 248.014},
#   {'pair': 'TUSD/BTC',
#    'percent_volume': 0.0395085776974,
#    'price': 1.00201,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 244.417},
#   {'pair': 'RCN/BTC',
#    'percent_volume': 0.0394890014362,
#    'price': 0.995618,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 244.295},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0393186298168,
#    'price': 0.994632,
#    'source': 'Livecoin',
#    'updated': True,
#    'volume_24h': 243.241},
#   {'pair': 'RUFF/BTC',
#    'percent_volume': 0.0392029166691,
#    'price': 0.999457,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 242.525},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0390005640289,
#    'price': 0.997075,
#    'source': 'bitFlyer',
#    'updated': True,
#    'volume_24h': 241.273},
#   {'pair': 'XMR/BTC',
#    'percent_volume': 0.0389596670873,
#    'price': 1.00276,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 241.02},
#   {'pair': 'AIDOC/BTC',
#    'percent_volume': 0.038808871729,
#    'price': 0.99318,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 240.088},
#   {'pair': 'NBT/BTC',
#    'percent_volume': 0.0387761154108,
#    'price': 1.0011,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 239.885},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0387759215864,
#    'price': 0.999186,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 239.884},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0386344297978,
#    'price': 1.00046,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 239.008},
#   {'pair': 'BTC/GBP',
#    'percent_volume': 0.0383142319419,
#    'price': 0.998974,
#    'source': 'Coinfloor',
#    'updated': True,
#    'volume_24h': 236.93},
#   {'pair': 'XLM/BTC',
#    'percent_volume': 0.0380046944262,
#    'price': 0.999726,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 235.113},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.0379285214496,
#    'price': 1.00202,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 234.641},
#   {'pair': 'SNT/BTC',
#    'percent_volume': 0.0376075482962,
#    'price': 1.03185,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 232.656},
#   {'pair': 'BTC/PEN',
#    'percent_volume': 0.0,
#    'price': 0.975928,
#    'source': 'Bitinka',
#    'updated': False,
#    'volume_24h': 214.401},
#   {'pair': 'OST/BTC',
#    'percent_volume': 0.036890591959,
#    'price': 1.00801,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 228.221},
#   {'pair': 'TNB/BTC',
#    'percent_volume': 0.0366709889501,
#    'price': 1.00109,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 226.862},
#   {'pair': 'GAS/BTC',
#    'percent_volume': 0.0365273650934,
#    'price': 1.00256,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 225.974},
#   {'pair': 'CAT/BTC',
#    'percent_volume': 0.0363521478647,
#    'price': 0.972472,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 224.89},
#   {'pair': 'VIBE/BTC',
#    'percent_volume': 0.0360833134663,
#    'price': 0.998863,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 223.226},
#   {'pair': 'ACT/BTC',
#    'percent_volume': 0.0360780802084,
#    'price': 0.976879,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 223.193},
#   {'pair': 'LRC/BTC',
#    'percent_volume': 0.0359218577678,
#    'price': 0.996482,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 222.228},
#   {'pair': 'QSP/BTC',
#    'percent_volume': 0.0356588381004,
#    'price': 0.99706,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 220.6},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0354119058556,
#    'price': 0.998292,
#    'source': 'Kucoin',
#    'updated': True,
#    'volume_24h': 219.072},
#   {'pair': 'PAY/BTC',
#    'percent_volume': 0.0349915008015,
#    'price': 1.00638,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 216.472},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.0348253933181,
#    'price': 0.994959,
#    'source': 'DSX',
#    'updated': True,
#    'volume_24h': 215.355},
#   {'pair': 'ORME/BTC',
#    'percent_volume': 0.0347317761484,
#    'price': 1.00751,
#    'source': 'Cryptopia',
#    'updated': True,
#    'volume_24h': 214.865},
#   {'pair': 'LSK/BTC',
#    'percent_volume': 0.0347052222099,
#    'price': 1.01123,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 214.701},
#   {'pair': 'BTC/THB',
#    'percent_volume': 0.0344631355743,
#    'price': 1.01732,
#    'source': 'BX Thailand',
#    'updated': True,
#    'volume_24h': 213.116},
#   {'pair': 'QBT/BTC',
#    'percent_volume': 0.0344003364791,
#    'price': 0.913511,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 212.815},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.034357113645,
#    'price': 1.0031,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 212.547},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0341041728448,
#    'price': 0.998444,
#    'source': 'Bitstamp',
#    'updated': True,
#    'volume_24h': 210.983},
#   {'pair': 'LRC/BTC',
#    'percent_volume': 0.0341026222499,
#    'price': 0.996676,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 210.973},
#   {'pair': 'XLM/BTC',
#    'percent_volume': 0.0339950497256,
#    'price': 0.992802,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 210.307},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0339557033789,
#    'price': 0.999044,
#    'source': 'BtcTrade.im',
#    'updated': True,
#    'volume_24h': 210.064},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0338828254166,
#    'price': 1.01379,
#    'source': 'RightBTC',
#    'updated': True,
#    'volume_24h': 209.613},
#   {'pair': 'TNT/BTC',
#    'percent_volume': 0.0337777726091,
#    'price': 1.0028,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 208.963},
#   {'pair': 'BTM/BTC',
#    'percent_volume': 0.0337072205392,
#    'price': 0.994462,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 208.527},
#   {'pair': 'MIOTA/BTC',
#    'percent_volume': 0.0336754333428,
#    'price': 1.00285,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 208.33},
#   {'pair': 'BTC/CAD',
#    'percent_volume': 0.0336219378173,
#    'price': 1.01116,
#    'source': 'Coinsquare',
#    'updated': True,
#    'volume_24h': 207.914},
#   {'pair': 'BTM/BTC',
#    'percent_volume': 0.033607594814,
#    'price': 1.01652,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 207.91},
#   {'pair': 'HSR/BTC',
#    'percent_volume': 0.0334573809288,
#    'price': 0.992328,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 206.982},
#   {'pair': 'XDN/BTC',
#    'percent_volume': 0.0328724189863,
#    'price': 1.00869,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 203.362},
#   {'pair': 'SC/BTC',
#    'percent_volume': 0.0326617318983,
#    'price': 1.00021,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 202.058},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0325778059469,
#    'price': 1.00908,
#    'source': 'TOPBTC',
#    'updated': True,
#    'volume_24h': 201.54},
#   {'pair': 'ADT/BTC',
#    'percent_volume': 0.0325754800545,
#    'price': 1.0003,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 201.525},
#   {'pair': 'WPR/BTC',
#    'percent_volume': 0.0325355522347,
#    'price': 1.00465,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 201.279},
#   {'pair': 'ETN/BTC',
#    'percent_volume': 0.032393478973,
#    'price': 1.00165,
#    'source': 'Kucoin',
#    'updated': True,
#    'volume_24h': 200.399},
#   {'pair': 'BTC/CLP',
#    'percent_volume': 0.0,
#    'price': 1.0303,
#    'source': 'Bitinka',
#    'updated': False,
#    'volume_24h': 184.561},
#   {'pair': 'ENG/BTC',
#    'percent_volume': 0.0321256136964,
#    'price': 1.00221,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 198.742},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.0310056964982,
#    'price': 1.00147,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 191.814},
#   {'pair': 'LET/BTC',
#    'percent_volume': 0.0306128145043,
#    'price': 0.99972,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 189.384},
#   {'pair': 'UP/BTC',
#    'percent_volume': 0.0303684019762,
#    'price': 1.00033,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 187.871},
#   {'pair': 'BLZ/BTC',
#    'percent_volume': 0.030361424299,
#    'price': 1.00065,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 187.828},
#   {'pair': 'WICC/BTC',
#    'percent_volume': 0.0303230470741,
#    'price': 1.01394,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 187.591},
#   {'pair': 'C20/BTC',
#    'percent_volume': 0.0302251657683,
#    'price': 1.00022,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 186.986},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.0301553889958,
#    'price': 1.00147,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 186.553},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0300629347723,
#    'price': 0.999187,
#    'source': 'Bitstamp',
#    'updated': True,
#    'volume_24h': 185.982},
#   {'pair': 'GNT/BTC',
#    'percent_volume': 0.029914271482,
#    'price': 0.999091,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 185.061},
#   {'pair': 'GNX/BTC',
#    'percent_volume': 0.0295638370247,
#    'price': 0.997787,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 182.894},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0294101343009,
#    'price': 0.999895,
#    'source': 'GDAX',
#    'updated': True,
#    'volume_24h': 181.943},
#   {'pair': 'BTX/BTC',
#    'percent_volume': 0.029404901043,
#    'price': 0.992482,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 181.911},
#   {'pair': 'QASH/BTC',
#    'percent_volume': 0.0292539118603,
#    'price': 1.00222,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 180.976},
#   {'pair': 'MANA/BTC',
#    'percent_volume': 0.0292124334456,
#    'price': 0.999809,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 180.72},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0291957645499,
#    'price': 1.00093,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 180.618},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0290542727613,
#    'price': 1.01415,
#    'source': 'Exrates',
#    'updated': True,
#    'volume_24h': 179.742},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0289368151943,
#    'price': 1.00116,
#    'source': 'YoBit',
#    'updated': True,
#    'volume_24h': 179.015},
#   {'pair': 'SPF/BTC',
#    'percent_volume': 0.0288740160991,
#    'price': 1.0009,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 178.627},
#   {'pair': 'OC/BTC',
#    'percent_volume': 0.0287716768328,
#    'price': 0.998596,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 177.993},
#   {'pair': 'OC/BTC',
#    'percent_volume': 0.0286356121264,
#    'price': 1.08468,
#    'source': 'Allcoin',
#    'updated': True,
#    'volume_24h': 177.152},
#   {'pair': 'CVC/BTC',
#    'percent_volume': 0.0284536110449,
#    'price': 0.99452,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 176.026},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0284470210164,
#    'price': 1.04783,
#    'source': 'BtcTrade.im',
#    'updated': True,
#    'volume_24h': 175.985},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.0283642580112,
#    'price': 1.07496,
#    'source': 'LakeBTC',
#    'updated': True,
#    'volume_24h': 175.401},
#   {'pair': 'AWR/BTC',
#    'percent_volume': 0.0283442941013,
#    'price': 1.01283,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 175.35},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0282731605583,
#    'price': 1.00191,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 174.91},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.028221409452,
#    'price': 0.992398,
#    'source': 'Octaex',
#    'updated': True,
#    'volume_24h': 174.589},
#   {'pair': 'SLS/BTC',
#    'percent_volume': 0.0281630683173,
#    'price': 0.988913,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 174.228},
#   {'pair': 'BTC/PLN',
#    'percent_volume': 0.028161323898,
#    'price': 0.997822,
#    'source': 'BitMarket',
#    'updated': True,
#    'volume_24h': 174.146},
#   {'pair': 'SRN/BTC',
#    'percent_volume': 0.0281411661637,
#    'price': 0.994983,
#    'source': 'Liqui',
#    'updated': True,
#    'volume_24h': 174.093},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0280785608928,
#    'price': 0.99772,
#    'source': 'ooobtc',
#    'updated': True,
#    'volume_24h': 173.705},
#   {'pair': 'ZEC/BTC',
#    'percent_volume': 0.0279698254224,
#    'price': 1.00299,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 173.033},
#   {'pair': 'QUN/BTC',
#    'percent_volume': 0.0279388135235,
#    'price': 1.0027,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 172.841},
#   {'pair': 'LSK/BTC',
#    'percent_volume': 0.0278374433791,
#    'price': 1.00586,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 172.213},
#   {'pair': 'BTC/BRL',
#    'percent_volume': 0.0278231003758,
#    'price': 1.02398,
#    'source': 'BitcoinTrade',
#    'updated': True,
#    'volume_24h': 172.055},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0277199858121,
#    'price': 1.0143,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 171.417},
#   {'pair': 'SALT/BTC',
#    'percent_volume': 0.0276259809936,
#    'price': 0.996897,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 170.905},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.027583533457,
#    'price': 1.00159,
#    'source': 'DSX',
#    'updated': True,
#    'volume_24h': 170.573},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0273053954889,
#    'price': 1.007,
#    'source': 'RightBTC',
#    'updated': True,
#    'volume_24h': 168.922},
#   {'pair': 'MCO/BTC',
#    'percent_volume': 0.0271953032479,
#    'price': 1.00269,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 168.241},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.0269886864716,
#    'price': 0.98225,
#    'source': 'Trade By Trade',
#    'updated': True,
#    'volume_24h': 166.964},
#   {'pair': 'ATB/BTC',
#    'percent_volume': 0.026972017576,
#    'price': 0.991497,
#    'source': 'TOPBTC',
#    'updated': True,
#    'volume_24h': 166.86},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0269349971217,
#    'price': 1.01356,
#    'source': 'Trade By Trade',
#    'updated': True,
#    'volume_24h': 166.632},
#   {'pair': 'SNC/BTC',
#    'percent_volume': 0.0269001087355,
#    'price': 1.0065,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 166.415},
#   {'pair': 'XEM/BTC',
#    'percent_volume': 0.0268642512274,
#    'price': 1.0193,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 166.194},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0267448554167,
#    'price': 1.00152,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 165.454},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.0265663431738,
#    'price': 1.00914,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 164.35},
#   {'pair': 'POE/BTC',
#    'percent_volume': 0.0263618584656,
#    'price': 1.03445,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 163.085},
#   {'pair': 'NKC/BTC',
#    'percent_volume': 0.026196720104,
#    'price': 1.02184,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 162.063},
#   {'pair': 'STK/BTC',
#    'percent_volume': 0.0260767428203,
#    'price': 0.997477,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 161.322},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0258398894426,
#    'price': 1.03835,
#    'source': 'Trade By Trade',
#    'updated': True,
#    'volume_24h': 159.856},
#   {'pair': 'OMG/BTC',
#    'percent_volume': 0.0258094590168,
#    'price': 1.00026,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 159.668},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.025799573974,
#    'price': 0.999655,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 159.607},
#   {'pair': 'ITC/BTC',
#    'percent_volume': 0.0257501487602,
#    'price': 0.997141,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 159.301},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.0257396822443,
#    'price': 0.996187,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 159.236},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.0256602142535,
#    'price': 1.00203,
#    'source': 'BL3P',
#    'updated': True,
#    'volume_24h': 158.679},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0255171718699,
#    'price': 0.994844,
#    'source': 'ZB.COM',
#    'updated': True,
#    'volume_24h': 157.859},
#   {'pair': 'AIDOC/BTC',
#    'percent_volume': 0.0255167842211,
#    'price': 0.987244,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 157.857},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.0255165903968,
#    'price': 1.00406,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 157.856},
#   {'pair': 'ZLA/BTC',
#    'percent_volume': 0.025461931925,
#    'price': 0.998334,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 157.518},
#   {'pair': 'APPC/BTC',
#    'percent_volume': 0.0254344088648,
#    'price': 0.999721,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 157.348},
#   {'pair': 'R/BTC',
#    'percent_volume': 0.0253487384941,
#    'price': 1.00692,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 156.818},
#   {'pair': 'VTC/BTC',
#    'percent_volume': 0.0252927232518,
#    'price': 1.00687,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 156.471},
#   {'pair': 'ACT/BTC',
#    'percent_volume': 0.0252029825694,
#    'price': 1.01988,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 155.916},
#   {'pair': 'SMT/BTC',
#    'percent_volume': 0.0251403772985,
#    'price': 0.997783,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 155.529},
#   {'pair': 'SC/BTC',
#    'percent_volume': 0.0250775782033,
#    'price': 1.00711,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 155.14},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.0248622393305,
#    'price': 1.00979,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 153.808},
#   {'pair': 'UP/BTC',
#    'percent_volume': 0.0248157214821,
#    'price': 0.999946,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 153.52},
#   {'pair': 'ADT/BTC',
#    'percent_volume': 0.0246575607979,
#    'price': 1.0003,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 152.542},
#   {'pair': 'SOC/BTC',
#    'percent_volume': 0.0245143245899,
#    'price': 0.99829,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 151.656},
#   {'pair': 'ZEC/BTC',
#    'percent_volume': 0.0243951226036,
#    'price': 1.00299,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 150.918},
#   {'pair': 'HSR/BTC',
#    'percent_volume': 0.0243232137631,
#    'price': 0.995267,
#    'source': 'Allcoin',
#    'updated': True,
#    'volume_24h': 150.473},
#   {'pair': 'BAT/BTC',
#    'percent_volume': 0.0243119719497,
#    'price': 0.997038,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 150.403},
#   {'pair': 'WAVES/BTC',
#    'percent_volume': 0.0242819291727,
#    'price': 0.99664,
#    'source': 'YoBit',
#    'updated': True,
#    'volume_24h': 150.218},
#   {'pair': 'VIB/BTC',
#    'percent_volume': 0.0239462253673,
#    'price': 1.00759,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 148.141},
#   {'pair': 'EKO/BTC',
#    'percent_volume': 0.023851251427,
#    'price': 0.999132,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 147.554},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0235800911362,
#    'price': 1.00133,
#    'source': 'Liqui',
#    'updated': True,
#    'volume_24h': 145.816},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0235457842231,
#    'price': 1.00225,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 145.664},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0,
#    'price': 0.997643,
#    'source': 'BitMEX',
#    'updated': True,
#    'volume_24h': 378860.0},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.0,
#    'price': 1.00811,
#    'source': 'Quoine',
#    'updated': True,
#    'volume_24h': 11967.8},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.0,
#    'price': 1.00809,
#    'source': 'Fisco',
#    'updated': True,
#    'volume_24h': 10277.9},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.0,
#    'price': 1.00809,
#    'source': 'Zaif',
#    'updated': True,
#    'volume_24h': 10274.4},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0,
#    'price': 1.00027,
#    'source': 'ZB.COM',
#    'updated': True,
#    'volume_24h': 1559.42},
#   {'pair': 'BTC/KRW',
#    'percent_volume': 0.0,
#    'price': 1.03735,
#    'source': 'GOPAX',
#    'updated': True,
#    'volume_24h': 1225.55},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0,
#    'price': 0.999021,
#    'source': 'Quoine',
#    'updated': True,
#    'volume_24h': 1160.09},
#   {'pair': 'BTC/SGD',
#    'percent_volume': 0.0,
#    'price': 0.996345,
#    'source': 'Quoine',
#    'updated': True,
#    'volume_24h': 467.112},
#   {'pair': 'B2X/BTC',
#    'percent_volume': 0.0,
#    'price': 0.000295975,
#    'source': 'Negocie Coins',
#    'updated': True,
#    'volume_24h': 1229.97}],
#  'slug': 'bitcoin',
#  'symbol': 'BTC'}

# %%
show_page("currencies/bitcoin/#markets")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/currencies/bitcoin/#markets"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `ranks()`
# Get gainers and losers rankings:

# %%
cmc.ranks()
# Out:
# {'gainers': {'1h': [{'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4},
#    {'name': 'Bounty0x',
#     'percent_change': 21.63,
#     'price': 0.0736277,
#     'symbol': 'BNTY',
#     'volume_24h': 50563.4}],
#   '24h': [{'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0},
#    {'name': 'Desire',
#     'percent_change': 81.72,
#     'price': 0.202824,
#     'symbol': 'DSR',
#     'volume_24h': 98226.0}],
#   '7d': [{'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0},
#    {'name': 'High Voltage',
#     'percent_change': 359.53,
#     'price': 0.467039,
#     'symbol': 'HVCO',
#     'volume_24h': 215270.0}]},
#  'losers': {'1h': [{'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1},
#    {'name': 'Pylon Network',
#     'percent_change': -27.76,
#     'price': 3.65623,
#     'symbol': 'PYLNT',
#     'volume_24h': 85529.1}],
#   '24h': [{'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.58,
#     'price': 0.000725711,
#     'symbol': 'W3C',
#     'volume_24h': 3984210.0}],
#   '7d': [{'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0},
#    {'name': 'Tidex Token',
#     'percent_change': -40.19,
#     'price': 0.193212,
#     'symbol': 'TDX',
#     'volume_24h': 4025230.0}]}}

# %%
show_page("gainers-losers")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/gainers-losers"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `historical(currency, [start=datetime(2008, 8, 18), end=datetime.now(), revert=False])`
# Get historical prices for a currency. You can filter by `start` and `end` datetimes provided in `datetime` objects. With parameter `revert` active, the response will be ordered in chronological order.

# %%
from datetime import datetime

cmc.historical("ETH", start=datetime(2018, 2, 1), revert=True)
# Out:
# {'history': [{'close': 1036.79,
#    'date': datetime.datetime(2018, 2, 1, 0, 0),
#    'high': 1161.35,
#    'low': 984.819,
#    'market_cap': 108952000000.0,
#    'open': 1119.37,
#    'volume': 5261680000.0},
#   {'close': 915.785,
#    'date': datetime.datetime(2018, 2, 2, 0, 0),
#    'high': 1035.77,
#    'low': 757.98,
#    'market_cap': 100836000000.0,
#    'open': 1035.77,
#    'volume': 6713290000.0},
#   {'close': 964.019,
#    'date': datetime.datetime(2018, 2, 3, 0, 0),
#    'high': 991.943,
#    'low': 847.69,
#    'market_cap': 89507600000.0,
#    'open': 919.211,
#    'volume': 3243480000.0},
#   {'close': 834.682,
#    'date': datetime.datetime(2018, 2, 4, 0, 0),
#    'high': 969.032,
#    'low': 805.064,
#    'market_cap': 93953400000.0,
#    'open': 964.667,
#    'volume': 2997090000.0},
#   {'close': 697.951,
#    'date': datetime.datetime(2018, 2, 5, 0, 0),
#    'high': 856.646,
#    'low': 644.599,
#    'market_cap': 81337400000.0,
#    'open': 834.958,
#    'volume': 4269530000.0},
#   {'close': 793.122,
#    'date': datetime.datetime(2018, 2, 6, 0, 0),
#    'high': 796.439,
#    'low': 574.419,
#    'market_cap': 68958700000.0,
#    'open': 707.737,
#    'volume': 6518270000.0},
#   {'close': 757.068,
#    'date': datetime.datetime(2018, 2, 7, 0, 0),
#    'high': 851.2,
#    'low': 723.433,
#    'market_cap': 77032000000.0,
#    'open': 790.428,
#    'volume': 3896180000.0},
#   {'close': 817.807,
#    'date': datetime.datetime(2018, 2, 8, 0, 0),
#    'high': 845.086,
#    'low': 755.843,
#    'market_cap': 73676900000.0,
#    'open': 755.843,
#    'volume': 3708190000.0},
#   {'close': 883.865,
#    'date': datetime.datetime(2018, 2, 9, 0, 0),
#    'high': 884.004,
#    'low': 788.834,
#    'market_cap': 79799300000.0,
#    'open': 818.48,
#    'volume': 2495820000.0},
#   {'close': 860.415,
#    'date': datetime.datetime(2018, 2, 10, 0, 0),
#    'high': 917.4,
#    'low': 825.577,
#    'market_cap': 86055600000.0,
#    'open': 882.467,
#    'volume': 2930530000.0},
#   {'close': 814.66,
#    'date': datetime.datetime(2018, 2, 11, 0, 0),
#    'high': 859.288,
#    'low': 788.222,
#    'market_cap': 83813000000.0,
#    'open': 859.288,
#    'volume': 2486650000.0},
#   {'close': 868.707,
#    'date': datetime.datetime(2018, 2, 12, 0, 0),
#    'high': 875.937,
#    'low': 817.508,
#    'market_cap': 79754400000.0,
#    'open': 817.508,
#    'volume': 2243450000.0},
#   {'close': 845.258,
#    'date': datetime.datetime(2018, 2, 13, 0, 0),
#    'high': 870.709,
#    'low': 828.837,
#    'market_cap': 84824200000.0,
#    'open': 869.293,
#    'volume': 2081170000.0},
#   {'close': 923.561,
#    'date': datetime.datetime(2018, 2, 14, 0, 0),
#    'high': 926.429,
#    'low': 844.279,
#    'market_cap': 82400600000.0,
#    'open': 844.279,
#    'volume': 2818370000.0},
#   {'close': 936.976,
#    'date': datetime.datetime(2018, 2, 15, 0, 0),
#    'high': 951.948,
#    'low': 911.111,
#    'market_cap': 90173300000.0,
#    'open': 923.728,
#    'volume': 2900100000.0},
#   {'close': 944.21,
#    'date': datetime.datetime(2018, 2, 16, 0, 0),
#    'high': 950.005,
#    'low': 917.848,
#    'market_cap': 91272100000.0,
#    'open': 934.786,
#    'volume': 2369450000.0},
#   {'close': 974.115,
#    'date': datetime.datetime(2018, 2, 17, 0, 0),
#    'high': 976.595,
#    'low': 940.754,
#    'market_cap': 92264000000.0,
#    'open': 944.748,
#    'volume': 2525720000.0},
#   {'close': 923.921,
#    'date': datetime.datetime(2018, 2, 18, 0, 0),
#    'high': 982.933,
#    'low': 915.445,
#    'market_cap': 95077100000.0,
#    'open': 973.349,
#    'volume': 2567290000.0},
#   {'close': 943.865,
#    'date': datetime.datetime(2018, 2, 19, 0, 0),
#    'high': 957.777,
#    'low': 921.554,
#    'market_cap': 90047700000.0,
#    'open': 921.668,
#    'volume': 2169020000.0},
#   {'close': 895.371,
#    'date': datetime.datetime(2018, 2, 20, 0, 0),
#    'high': 965.265,
#    'low': 892.954,
#    'market_cap': 92206500000.0,
#    'open': 943.567,
#    'volume': 2545260000.0},
#   {'close': 849.971,
#    'date': datetime.datetime(2018, 2, 21, 0, 0),
#    'high': 912.375,
#    'low': 830.563,
#    'market_cap': 87394200000.0,
#    'open': 894.135,
#    'volume': 2531730000.0},
#   {'close': 812.845,
#    'date': datetime.datetime(2018, 2, 22, 0, 0),
#    'high': 875.926,
#    'low': 802.668,
#    'market_cap': 83025800000.0,
#    'open': 849.262,
#    'volume': 2150370000.0},
#   {'close': 864.189,
#    'date': datetime.datetime(2018, 2, 23, 0, 0),
#    'high': 886.318,
#    'low': 794.791,
#    'market_cap': 79358900000.0,
#    'open': 811.585,
#    'volume': 2334820000.0},
#   {'close': 840.515,
#    'date': datetime.datetime(2018, 2, 24, 0, 0),
#    'high': 879.531,
#    'low': 818.55,
#    'market_cap': 84266700000.0,
#    'open': 861.593,
#    'volume': 1926580000.0},
#   {'close': 844.81,
#    'date': datetime.datetime(2018, 2, 25, 0, 0),
#    'high': 853.146,
#    'low': 822.381,
#    'market_cap': 82119100000.0,
#    'open': 839.459,
#    'volume': 1646960000.0},
#   {'close': 869.315,
#    'date': datetime.datetime(2018, 2, 26, 0, 0),
#    'high': 880.392,
#    'low': 842.319,
#    'market_cap': 82705400000.0,
#    'open': 845.278,
#    'volume': 2044480000.0},
#   {'close': 878.265,
#    'date': datetime.datetime(2018, 2, 27, 0, 0),
#    'high': 896.259,
#    'low': 867.097,
#    'market_cap': 85177800000.0,
#    'open': 870.365,
#    'volume': 2053980000.0},
#   {'close': 855.199,
#    'date': datetime.datetime(2018, 2, 28, 0, 0),
#    'high': 890.108,
#    'low': 855.124,
#    'market_cap': 85936400000.0,
#    'open': 877.934,
#    'volume': 1963980000.0},
#   {'close': 872.2,
#    'date': datetime.datetime(2018, 3, 1, 0, 0),
#    'high': 880.302,
#    'low': 851.92,
#    'market_cap': 83808200000.0,
#    'open': 856.012,
#    'volume': 1868520000.0},
#   {'close': 856.853,
#    'date': datetime.datetime(2018, 3, 2, 0, 0),
#    'high': 876.378,
#    'low': 852.422,
#    'market_cap': 85368100000.0,
#    'open': 871.764,
#    'volume': 1894420000.0},
#   {'close': 857.225,
#    'date': datetime.datetime(2018, 3, 3, 0, 0),
#    'high': 868.454,
#    'low': 855.207,
#    'market_cap': 83911700000.0,
#    'open': 856.711,
#    'volume': 1699370000.0},
#   {'close': 866.678,
#    'date': datetime.datetime(2018, 3, 4, 0, 0),
#    'high': 867.95,
#    'low': 840.28,
#    'market_cap': 83877800000.0,
#    'open': 856.186,
#    'volume': 1697940000.0},
#   {'close': 853.684,
#    'date': datetime.datetime(2018, 3, 5, 0, 0),
#    'high': 869.92,
#    'low': 853.52,
#    'market_cap': 84939700000.0,
#    'open': 866.846,
#    'volume': 1898490000.0},
#   {'close': 816.951,
#    'date': datetime.datetime(2018, 3, 6, 0, 0),
#    'high': 853.817,
#    'low': 809.931,
#    'market_cap': 83680400000.0,
#    'open': 853.817,
#    'volume': 1943070000.0},
#   {'close': 752.831,
#    'date': datetime.datetime(2018, 3, 7, 0, 0),
#    'high': 825.607,
#    'low': 726.547,
#    'market_cap': 80017300000.0,
#    'open': 816.271,
#    'volume': 2175420000.0},
#   {'close': 704.596,
#    'date': datetime.datetime(2018, 3, 8, 0, 0),
#    'high': 773.767,
#    'low': 696.169,
#    'market_cap': 73788400000.0,
#    'open': 752.57,
#    'volume': 1891640000.0},
#   {'close': 728.916,
#    'date': datetime.datetime(2018, 3, 9, 0, 0),
#    'high': 729.156,
#    'low': 648.107,
#    'market_cap': 68863600000.0,
#    'open': 702.197,
#    'volume': 2233020000.0},
#   {'close': 686.89,
#    'date': datetime.datetime(2018, 3, 10, 0, 0),
#    'high': 748.031,
#    'low': 682.695,
#    'market_cap': 71620700000.0,
#    'open': 730.16,
#    'volume': 1532960000.0},
#   {'close': 723.339,
#    'date': datetime.datetime(2018, 3, 11, 0, 0),
#    'high': 735.831,
#    'low': 668.123,
#    'market_cap': 67235700000.0,
#    'open': 685.312,
#    'volume': 1562680000.0},
#   {'close': 699.831,
#    'date': datetime.datetime(2018, 3, 12, 0, 0),
#    'high': 742.514,
#    'low': 683.268,
#    'market_cap': 71086000000.0,
#    'open': 724.406,
#    'volume': 1765000000.0},
#   {'close': 690.827,
#    'date': datetime.datetime(2018, 3, 13, 0, 0),
#    'high': 713.735,
#    'low': 682.35,
#    'market_cap': 68524000000.0,
#    'open': 698.153,
#    'volume': 1425960000.0},
#   {'close': 614.291,
#    'date': datetime.datetime(2018, 3, 14, 0, 0),
#    'high': 702.784,
#    'low': 594.1,
#    'market_cap': 67857600000.0,
#    'open': 691.219,
#    'volume': 1810560000.0},
#   {'close': 611.304,
#    'date': datetime.datetime(2018, 3, 15, 0, 0),
#    'high': 620.616,
#    'low': 579.505,
#    'market_cap': 60371800000.0,
#    'open': 614.839,
#    'volume': 1770460000.0},
#   {'close': 601.666,
#    'date': datetime.datetime(2018, 3, 16, 0, 0),
#    'high': 623.168,
#    'low': 587.862,
#    'market_cap': 60083700000.0,
#    'open': 611.778,
#    'volume': 1417350000.0},
#   {'close': 552.779,
#    'date': datetime.datetime(2018, 3, 17, 0, 0),
#    'high': 609.151,
#    'low': 549.096,
#    'market_cap': 59104200000.0,
#    'open': 601.678,
#    'volume': 1267810000.0},
#   {'close': 538.644,
#    'date': datetime.datetime(2018, 3, 18, 0, 0),
#    'high': 551.64,
#    'low': 460.088,
#    'market_cap': 54200100000.0,
#    'open': 551.64,
#    'volume': 2685500000.0},
#   {'close': 556.726,
#    'date': datetime.datetime(2018, 3, 19, 0, 0),
#    'high': 558.1,
#    'low': 519.123,
#    'market_cap': 53718600000.0,
#    'open': 546.626,
#    'volume': 2046790000.0},
#   {'close': 557.175,
#    'date': datetime.datetime(2018, 3, 20, 0, 0),
#    'high': 567.09,
#    'low': 521.204,
#    'market_cap': 54722100000.0,
#    'open': 556.722,
#    'volume': 1833680000.0},
#   {'close': 561.732,
#    'date': datetime.datetime(2018, 3, 21, 0, 0),
#    'high': 589.607,
#    'low': 550.572,
#    'market_cap': 54967300000.0,
#    'open': 559.1,
#    'volume': 1781270000.0},
#   {'close': 539.702,
#    'date': datetime.datetime(2018, 3, 22, 0, 0),
#    'high': 577.566,
#    'low': 523.089,
#    'market_cap': 55273800000.0,
#    'open': 562.103,
#    'volume': 1523460000.0}],
#  'slug': 'ethereum',
#  'symbol': 'ETH'}

# %%
show_page("currencies/ethereum/historical-data")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/currencies/ethereum/historical-data"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `recently([convert="USD"])`
# Get recently added coins in coinmarketcap along with other metadata.

# %%
list(cmc.recently())
# Out:
# []

# %%
show_page("new")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/new"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `exchange(name, [convert="USD"])`
# Get data about a exchange:

# %%
cmc.exchange("okex")
# Out:
# {'markets': [{'currency': 'Bitcoin',
#    'pair': 'BTC/USDT',
#    'percent_volume': 30.8333598292,
#    'price': 8333.31,
#    'updated': True,
#    'volume_24h': 320836000.0},
#   {'currency': 'Ethereum',
#    'pair': 'ETH/USDT',
#    'percent_volume': 8.95269354107,
#    'price': 512.357,
#    'updated': True,
#    'volume_24h': 93157100.0},
#   {'currency': 'Ethereum',
#    'pair': 'ETH/BTC',
#    'percent_volume': 7.37270921178,
#    'price': 513.636,
#    'updated': True,
#    'volume_24h': 76716600.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/USDT',
#    'percent_volume': 6.67821958217,
#    'price': 157.05,
#    'updated': True,
#    'volume_24h': 69490100.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/BTC',
#    'percent_volume': 5.47987059062,
#    'price': 157.623,
#    'updated': True,
#    'volume_24h': 57020700.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/USDT',
#    'percent_volume': 5.06033215873,
#    'price': 18.1518,
#    'updated': True,
#    'volume_24h': 52655200.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/USDT',
#    'percent_volume': 4.80701378681,
#    'price': 6.59063,
#    'updated': True,
#    'volume_24h': 50019300.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/BTC',
#    'percent_volume': 4.67610203514,
#    'price': 967.742,
#    'updated': True,
#    'volume_24h': 48657100.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/USDT',
#    'percent_volume': 4.33744403946,
#    'price': 967.461,
#    'updated': True,
#    'volume_24h': 45133200.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/BTC',
#    'percent_volume': 3.83429584104,
#    'price': 18.1465,
#    'updated': True,
#    'volume_24h': 39897700.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/BTC',
#    'percent_volume': 1.74370570658,
#    'price': 6.63815,
#    'updated': True,
#    'volume_24h': 18144100.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/USDT',
#    'percent_volume': 1.36630851908,
#    'price': 0.619615,
#    'updated': True,
#    'volume_24h': 14217100.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/ETH',
#    'percent_volume': 1.05332929307,
#    'price': 18.158,
#    'updated': True,
#    'volume_24h': 10960400.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/BTC',
#    'percent_volume': 0.7151249044,
#    'price': 0.618145,
#    'updated': True,
#    'volume_24h': 7441220.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/ETH',
#    'percent_volume': 0.648317817855,
#    'price': 0.503652,
#    'updated': True,
#    'volume_24h': 6746060.0},
#   {'currency': 'Hshare',
#    'pair': 'HSR/BTC',
#    'percent_volume': 0.560797612944,
#    'price': 6.62214,
#    'updated': True,
#    'volume_24h': 5835370.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/USDT',
#    'percent_volume': 0.473717560597,
#    'price': 63.9416,
#    'updated': True,
#    'volume_24h': 4929260.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/USDT',
#    'percent_volume': 0.445379615937,
#    'price': 17.8019,
#    'updated': True,
#    'volume_24h': 4634390.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/BTC',
#    'percent_volume': 0.419335654182,
#    'price': 0.00884375,
#    'updated': True,
#    'volume_24h': 4363390.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/ETH',
#    'percent_volume': 0.403108632254,
#    'price': 6.64597,
#    'updated': True,
#    'volume_24h': 4194540.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/USDT',
#    'percent_volume': 0.402512792539,
#    'price': 0.00130192,
#    'updated': True,
#    'volume_24h': 4188340.0},
#   {'currency': 'SunContract',
#    'pair': 'SNC/BTC',
#    'percent_volume': 0.366612488652,
#    'price': 0.187805,
#    'updated': True,
#    'volume_24h': 3814780.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/BTC',
#    'percent_volume': 0.362573272001,
#    'price': 0.0357087,
#    'updated': True,
#    'volume_24h': 3772750.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/BTC',
#    'percent_volume': 0.350058715913,
#    'price': 64.2087,
#    'updated': True,
#    'volume_24h': 3642530.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/BTC',
#    'percent_volume': 0.282910463079,
#    'price': 1.15945,
#    'updated': True,
#    'volume_24h': 2943820.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/BTC',
#    'percent_volume': 0.281892730404,
#    'price': 17.798,
#    'updated': True,
#    'volume_24h': 2933230.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/BTC',
#    'percent_volume': 0.252725415301,
#    'price': 1.24697,
#    'updated': True,
#    'volume_24h': 2629730.0},
#   {'currency': 'Viberate',
#    'pair': 'VIB/BTC',
#    'percent_volume': 0.226417169801,
#    'price': 0.12982,
#    'updated': True,
#    'volume_24h': 2355980.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/BTC',
#    'percent_volume': 0.225840550722,
#    'price': 3.93772,
#    'updated': True,
#    'volume_24h': 2349980.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/ETH',
#    'percent_volume': 0.204461437319,
#    'price': 0.00126014,
#    'updated': True,
#    'volume_24h': 2127520.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/USDT',
#    'percent_volume': 0.193262533765,
#    'price': 0.352621,
#    'updated': True,
#    'volume_24h': 2010990.0},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/BTC',
#    'percent_volume': 0.191607637007,
#    'price': 0.0460543,
#    'updated': True,
#    'volume_24h': 1993770.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/ETH',
#    'percent_volume': 0.184956335925,
#    'price': 0.0358065,
#    'updated': True,
#    'volume_24h': 1924560.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/USDT',
#    'percent_volume': 0.182884351366,
#    'price': 1.24985,
#    'updated': True,
#    'volume_24h': 1903000.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/ETH',
#    'percent_volume': 0.175756378512,
#    'price': 0.618033,
#    'updated': True,
#    'volume_24h': 1828830.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/BTC',
#    'percent_volume': 0.167393479797,
#    'price': 0.352916,
#    'updated': True,
#    'volume_24h': 1741810.0},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/BTC',
#    'percent_volume': 0.14322353005,
#    'price': 0.164193,
#    'updated': True,
#    'volume_24h': 1490310.0},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/BTC',
#    'percent_volume': 0.127622139823,
#    'price': 1.11148,
#    'updated': True,
#    'volume_24h': 1327970.0},
#   {'currency': 'Game.com',
#    'pair': 'GTC/USDT',
#    'percent_volume': 0.127025339076,
#    'price': 0.0502742,
#    'updated': True,
#    'volume_24h': 1321760.0},
#   {'currency': 'Revain',
#    'pair': 'R/BTC',
#    'percent_volume': 0.126922508674,
#    'price': 0.952122,
#    'updated': True,
#    'volume_24h': 1320690.0},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/USDT',
#    'percent_volume': 0.113217234187,
#    'price': 0.0187277,
#    'updated': True,
#    'volume_24h': 1178080.0},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/BTC',
#    'percent_volume': 0.111468156312,
#    'price': 0.139081,
#    'updated': True,
#    'volume_24h': 1159880.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/BTC',
#    'percent_volume': 0.109493235965,
#    'price': 0.125147,
#    'updated': True,
#    'volume_24h': 1139330.0},
#   {'currency': 'DADI',
#    'pair': 'DADI/BTC',
#    'percent_volume': 0.109477859457,
#    'price': 0.198818,
#    'updated': True,
#    'volume_24h': 1139170.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/BTC',
#    'percent_volume': 0.105251241604,
#    'price': 0.497503,
#    'updated': True,
#    'volume_24h': 1095190.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/USDT',
#    'percent_volume': 0.100264447599,
#    'price': 3.86,
#    'updated': True,
#    'volume_24h': 1043300.0},
#   {'currency': 'Loopring',
#    'pair': 'LRC/BTC',
#    'percent_volume': 0.0964952808827,
#    'price': 0.426586,
#    'updated': True,
#    'volume_24h': 1004080.0},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/ETH',
#    'percent_volume': 0.0956589910112,
#    'price': 0.0205464,
#    'updated': True,
#    'volume_24h': 995378.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/BTC',
#    'percent_volume': 0.0952158592486,
#    'price': 0.00125147,
#    'updated': True,
#    'volume_24h': 990767.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/USDT',
#    'percent_volume': 0.0898420577376,
#    'price': 5.84062,
#    'updated': True,
#    'volume_24h': 934850.0},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/BTC',
#    'percent_volume': 0.0881994621866,
#    'price': 0.0186053,
#    'updated': True,
#    'volume_24h': 917758.0},
#   {'currency': 'ugChain',
#    'pair': 'UGC/BTC',
#    'percent_volume': 0.0860688546881,
#    'price': 0.0367934,
#    'updated': True,
#    'volume_24h': 895588.0},
#   {'currency': 'Hshare',
#    'pair': 'HSR/USDT',
#    'percent_volume': 0.0839173927995,
#    'price': 6.50971,
#    'updated': True,
#    'volume_24h': 873201.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/BTC',
#    'percent_volume': 0.077921034889,
#    'price': 5.799,
#    'updated': True,
#    'volume_24h': 810806.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/ETH',
#    'percent_volume': 0.0760562487861,
#    'price': 0.125195,
#    'updated': True,
#    'volume_24h': 791402.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/USDT',
#    'percent_volume': 0.0740526896914,
#    'price': 0.224131,
#    'updated': True,
#    'volume_24h': 770554.0},
#   {'currency': 'Loopring',
#    'pair': 'LRC/USDT',
#    'percent_volume': 0.073789655288,
#    'price': 0.420821,
#    'updated': True,
#    'volume_24h': 767817.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/USDT',
#    'percent_volume': 0.0725968226189,
#    'price': 0.590873,
#    'updated': True,
#    'volume_24h': 755405.0},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/ETH',
#    'percent_volume': 0.0712287938529,
#    'price': 0.046113,
#    'updated': True,
#    'volume_24h': 741170.0},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/BTC',
#    'percent_volume': 0.0704235453085,
#    'price': 0.0851003,
#    'updated': True,
#    'volume_24h': 732791.0},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/USDT',
#    'percent_volume': 0.0691999596219,
#    'price': 2.75407,
#    'updated': True,
#    'volume_24h': 720059.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/ETH',
#    'percent_volume': 0.0675851378899,
#    'price': 1.15691,
#    'updated': True,
#    'volume_24h': 703256.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/BTC',
#    'percent_volume': 0.0675143098463,
#    'price': 0.58836,
#    'updated': True,
#    'volume_24h': 702519.0},
#   {'currency': 'Revain',
#    'pair': 'R/ETH',
#    'percent_volume': 0.0670555132654,
#    'price': 0.945295,
#    'updated': True,
#    'volume_24h': 697745.0},
#   {'currency': 'Cube',
#    'pair': 'AUTO/BTC',
#    'percent_volume': 0.0650249491771,
#    'price': 0.00884375,
#    'updated': True,
#    'volume_24h': 676616.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/BTC',
#    'percent_volume': 0.0602588080727,
#    'price': 0.0344573,
#    'updated': True,
#    'volume_24h': 627022.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/ETH',
#    'percent_volume': 0.0598327826762,
#    'price': 0.0353557,
#    'updated': True,
#    'volume_24h': 622589.0},
#   {'currency': 'DADI',
#    'pair': 'DADI/USDT',
#    'percent_volume': 0.0590534819903,
#    'price': 0.203801,
#    'updated': True,
#    'volume_24h': 614480.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/USDT',
#    'percent_volume': 0.0589819812244,
#    'price': 0.0829224,
#    'updated': True,
#    'volume_24h': 613736.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/USDT',
#    'percent_volume': 0.0575770488374,
#    'price': 0.0351519,
#    'updated': True,
#    'volume_24h': 599117.0},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/ETH',
#    'percent_volume': 0.0574524991162,
#    'price': 0.138698,
#    'updated': True,
#    'volume_24h': 597821.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/BTC',
#    'percent_volume': 0.0546871301143,
#    'price': 0.0015852,
#    'updated': True,
#    'volume_24h': 569046.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/BTC',
#    'percent_volume': 0.0535928993079,
#    'price': 0.0825973,
#    'updated': True,
#    'volume_24h': 557660.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/ETH',
#    'percent_volume': 0.0511595667926,
#    'price': 64.4309,
#    'updated': True,
#    'volume_24h': 532340.0},
#   {'currency': 'Ace',
#    'pair': 'ACE/BTC',
#    'percent_volume': 0.0506613679079,
#    'price': 0.124397,
#    'updated': True,
#    'volume_24h': 527156.0},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/BTC',
#    'percent_volume': 0.0505881372849,
#    'price': 2.74165,
#    'updated': True,
#    'volume_24h': 526394.0},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/USDT',
#    'percent_volume': 0.0480469770017,
#    'price': 0.0863275,
#    'updated': True,
#    'volume_24h': 499952.0},
#   {'currency': 'DADI',
#    'pair': 'DADI/ETH',
#    'percent_volume': 0.04721914421,
#    'price': 0.204809,
#    'updated': True,
#    'volume_24h': 491338.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/USDT',
#    'percent_volume': 0.046954764362,
#    'price': 0.871587,
#    'updated': True,
#    'volume_24h': 488587.0},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/USDT',
#    'percent_volume': 0.0458748529294,
#    'price': 0.0380562,
#    'updated': True,
#    'volume_24h': 477350.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/BTC',
#    'percent_volume': 0.0457214722543,
#    'price': 0.0352082,
#    'updated': True,
#    'volume_24h': 475754.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/USDT',
#    'percent_volume': 0.0457173398175,
#    'price': 0.0893319,
#    'updated': True,
#    'volume_24h': 475711.0},
#   {'currency': 'Game.com',
#    'pair': 'GTC/BTC',
#    'percent_volume': 0.0452392264975,
#    'price': 0.0485572,
#    'updated': True,
#    'volume_24h': 470736.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/ETH',
#    'percent_volume': 0.0448387645468,
#    'price': 1.25174,
#    'updated': True,
#    'volume_24h': 466569.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/BTC',
#    'percent_volume': 0.04465511137,
#    'price': 0.866771,
#    'updated': True,
#    'volume_24h': 464658.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/ETH',
#    'percent_volume': 0.0444832788843,
#    'price': 17.7948,
#    'updated': True,
#    'volume_24h': 462870.0},
#   {'currency': 'Gifto',
#    'pair': 'GTO/USDT',
#    'percent_volume': 0.0437799958138,
#    'price': 0.240355,
#    'updated': True,
#    'volume_24h': 455552.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/USDT',
#    'percent_volume': 0.0409930035964,
#    'price': 0.498436,
#    'updated': True,
#    'volume_24h': 426552.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/BTC',
#    'percent_volume': 0.0409161210525,
#    'price': 0.225265,
#    'updated': True,
#    'volume_24h': 425752.0},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/ETH',
#    'percent_volume': 0.0409156405366,
#    'price': 0.0895417,
#    'updated': True,
#    'volume_24h': 425747.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/BTC',
#    'percent_volume': 0.0363774561749,
#    'price': 0.204408,
#    'updated': True,
#    'volume_24h': 378525.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/ETH',
#    'percent_volume': 0.0358087175562,
#    'price': 0.0891985,
#    'updated': True,
#    'volume_24h': 372607.0},
#   {'currency': 'ProChain',
#    'pair': 'PRA/USDT',
#    'percent_volume': 0.0351432030354,
#    'price': 0.210911,
#    'updated': True,
#    'volume_24h': 365682.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/USDT',
#    'percent_volume': 0.0350234584732,
#    'price': 0.0351519,
#    'updated': True,
#    'volume_24h': 364436.0},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/BTC',
#    'percent_volume': 0.0342155190397,
#    'price': 0.0428004,
#    'updated': True,
#    'volume_24h': 356029.0},
#   {'currency': 'Arcblock',
#    'pair': 'ABT/ETH',
#    'percent_volume': 0.0340641565314,
#    'price': 0.672157,
#    'updated': True,
#    'volume_24h': 354454.0},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/BTC',
#    'percent_volume': 0.0335382799309,
#    'price': 0.0387957,
#    'updated': True,
#    'volume_24h': 348982.0},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/BTC',
#    'percent_volume': 0.0328454721069,
#    'price': 0.0880204,
#    'updated': True,
#    'volume_24h': 341773.0},
#   {'currency': 'Game.com',
#    'pair': 'GTC/ETH',
#    'percent_volume': 0.0322492479788,
#    'price': 0.0509794,
#    'updated': True,
#    'volume_24h': 335569.0},
#   {'currency': 'Bankex',
#    'pair': 'BKX/ETH',
#    'percent_volume': 0.0320765505645,
#    'price': 0.30624,
#    'updated': True,
#    'volume_24h': 333772.0},
#   {'currency': 'ProChain',
#    'pair': 'PRA/BTC',
#    'percent_volume': 0.031792085152,
#    'price': 0.208829,
#    'updated': True,
#    'volume_24h': 330812.0},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/USDT',
#    'percent_volume': 0.030355727025,
#    'price': 0.0835233,
#    'updated': True,
#    'volume_24h': 315866.0},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/ETH',
#    'percent_volume': 0.0302866288387,
#    'price': 0.0379323,
#    'updated': True,
#    'volume_24h': 315147.0},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/USDT',
#    'percent_volume': 0.0302355980502,
#    'price': 0.0315466,
#    'updated': True,
#    'volume_24h': 314616.0},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/ETH',
#    'percent_volume': 0.0299590130984,
#    'price': 0.0195629,
#    'updated': True,
#    'volume_24h': 311738.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/BTC',
#    'percent_volume': 0.0297960221053,
#    'price': 0.0881872,
#    'updated': True,
#    'volume_24h': 310042.0},
#   {'currency': 'Bankex',
#    'pair': 'BKX/BTC',
#    'percent_volume': 0.0296877138215,
#    'price': 0.304609,
#    'updated': True,
#    'volume_24h': 308915.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/ETH',
#    'percent_volume': 0.0296339921439,
#    'price': 0.0342953,
#    'updated': True,
#    'volume_24h': 308356.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/USDT',
#    'percent_volume': 0.0296004521341,
#    'price': 1.18665,
#    'updated': True,
#    'volume_24h': 308007.0},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/USDT',
#    'percent_volume': 0.0288897691187,
#    'price': 233.99,
#    'updated': True,
#    'volume_24h': 300612.0},
#   {'currency': 'NEM',
#    'pair': 'XEM/USDT',
#    'percent_volume': 0.0275232780036,
#    'price': 0.270399,
#    'updated': True,
#    'volume_24h': 286393.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/USDT',
#    'percent_volume': 0.027343468954,
#    'price': 0.022333,
#    'updated': True,
#    'volume_24h': 284522.0},
#   {'currency': 'Gifto',
#    'pair': 'GTO/BTC',
#    'percent_volume': 0.0271194524416,
#    'price': 0.240116,
#    'updated': True,
#    'volume_24h': 282191.0},
#   {'currency': 'QunQun',
#    'pair': 'QUN/BTC',
#    'percent_volume': 0.0260978756392,
#    'price': 0.0266981,
#    'updated': True,
#    'volume_24h': 271561.0},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/ETH',
#    'percent_volume': 0.0256680061155,
#    'price': 0.240866,
#    'updated': True,
#    'volume_24h': 267088.0},
#   {'currency': 'Hi Mutual Society',
#    'pair': 'HMC/BTC',
#    'percent_volume': 0.0255556614981,
#    'price': 0.0348744,
#    'updated': True,
#    'volume_24h': 265919.0},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/USDT',
#    'percent_volume': 0.0254932905344,
#    'price': 6.17902,
#    'updated': True,
#    'volume_24h': 265270.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/ETH',
#    'percent_volume': 0.0241909002403,
#    'price': 0.354735,
#    'updated': True,
#    'volume_24h': 251718.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/ETH',
#    'percent_volume': 0.0240761530434,
#    'price': 0.0221703,
#    'updated': True,
#    'volume_24h': 250524.0},
#   {'currency': 'Republic Protocol',
#    'pair': 'REN/BTC',
#    'percent_volume': 0.0233352936295,
#    'price': 0.0471389,
#    'updated': True,
#    'volume_24h': 242815.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/USDT',
#    'percent_volume': 0.0229553016562,
#    'price': 0.210311,
#    'updated': True,
#    'volume_24h': 238861.0},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/USDT',
#    'percent_volume': 0.0224485495885,
#    'price': 10.5756,
#    'updated': True,
#    'volume_24h': 233588.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/ETH',
#    'percent_volume': 0.0220865289098,
#    'price': 5.77681,
#    'updated': True,
#    'volume_24h': 229821.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/USDT',
#    'percent_volume': 0.022050298011,
#    'price': 0.00160237,
#    'updated': True,
#    'volume_24h': 229444.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/ETH',
#    'percent_volume': 0.0218449255155,
#    'price': 0.000881074,
#    'updated': True,
#    'volume_24h': 227307.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/ETH',
#    'percent_volume': 0.0217247004374,
#    'price': 3.86027,
#    'updated': True,
#    'volume_24h': 226056.0},
#   {'currency': 'Refereum',
#    'pair': 'RFR/ETH',
#    'percent_volume': 0.0212832024289,
#    'price': 0.00906175,
#    'updated': True,
#    'volume_24h': 221462.0},
#   {'currency': 'NEM',
#    'pair': 'XEM/BTC',
#    'percent_volume': 0.021247452046,
#    'price': 0.268817,
#    'updated': True,
#    'volume_24h': 221090.0},
#   {'currency': 'QunQun',
#    'pair': 'QUN/USDT',
#    'percent_volume': 0.0212240989733,
#    'price': 0.0266393,
#    'updated': True,
#    'volume_24h': 220847.0},
#   {'currency': 'Super Bitcoin',
#    'pair': 'SBTC/BTC',
#    'percent_volume': 0.0201171825471,
#    'price': 9.70911,
#    'updated': True,
#    'volume_24h': 209329.0},
#   {'currency': 'Arcblock',
#    'pair': 'ABT/USDT',
#    'percent_volume': 0.0191040628245,
#    'price': 0.659774,
#    'updated': True,
#    'volume_24h': 198787.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/USDT',
#    'percent_volume': 0.0188194052056,
#    'price': 0.0358529,
#    'updated': True,
#    'volume_24h': 195825.0},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/USDT',
#    'percent_volume': 0.0187439642094,
#    'price': 0.140808,
#    'updated': True,
#    'volume_24h': 195040.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/ETH',
#    'percent_volume': 0.0184817947346,
#    'price': 0.589106,
#    'updated': True,
#    'volume_24h': 192312.0},
#   {'currency': 'ProChain',
#    'pair': 'PRA/ETH',
#    'percent_volume': 0.0179124794968,
#    'price': 0.209972,
#    'updated': True,
#    'volume_24h': 186388.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/BTC',
#    'percent_volume': 0.0173975586589,
#    'price': 0.0216088,
#    'updated': True,
#    'volume_24h': 181030.0},
#   {'currency': 'Loopring',
#    'pair': 'LRC/ETH',
#    'percent_volume': 0.0172515779286,
#    'price': 0.424565,
#    'updated': True,
#    'volume_24h': 179511.0},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/ETH',
#    'percent_volume': 0.0168365082946,
#    'price': 0.042896,
#    'updated': True,
#    'volume_24h': 175192.0},
#   {'currency': 'Arcblock',
#    'pair': 'ABT/BTC',
#    'percent_volume': 0.0168125786028,
#    'price': 0.669873,
#    'updated': True,
#    'volume_24h': 174943.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/USDT',
#    'percent_volume': 0.016657275864,
#    'price': 0.0503744,
#    'updated': True,
#    'volume_24h': 173327.0},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/USDT',
#    'percent_volume': 0.0166045152183,
#    'price': 0.0456674,
#    'updated': True,
#    'volume_24h': 172778.0},
#   {'currency': 'Refereum',
#    'pair': 'RFR/BTC',
#    'percent_volume': 0.0164495968923,
#    'price': 0.00901062,
#    'updated': True,
#    'volume_24h': 171166.0},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/BTC',
#    'percent_volume': 0.0160220338448,
#    'price': 0.337314,
#    'updated': True,
#    'volume_24h': 166717.0},
#   {'currency': 'Cube',
#    'pair': 'AUTO/ETH',
#    'percent_volume': 0.0159486110154,
#    'price': 0.00879538,
#    'updated': True,
#    'volume_24h': 165953.0},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/BTC',
#    'percent_volume': 0.0158033030074,
#    'price': 228.427,
#    'updated': True,
#    'volume_24h': 164441.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/BTC',
#    'percent_volume': 0.0150333243299,
#    'price': 0.0498087,
#    'updated': True,
#    'volume_24h': 156429.0},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/ETH',
#    'percent_volume': 0.0145854835116,
#    'price': 0.0879128,
#    'updated': True,
#    'volume_24h': 151769.0},
#   {'currency': 'Primas',
#    'pair': 'PST/USDT',
#    'percent_volume': 0.0140378875924,
#    'price': 0.178263,
#    'updated': True,
#    'volume_24h': 146071.0},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/BTC',
#    'percent_volume': 0.0136578956191,
#    'price': 10.6321,
#    'updated': True,
#    'volume_24h': 142117.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/USDT',
#    'percent_volume': 0.0135199875559,
#    'price': 0.00871287,
#    'updated': True,
#    'volume_24h': 140682.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/USDT',
#    'percent_volume': 0.0130264977271,
#    'price': 0.125786,
#    'updated': True,
#    'volume_24h': 135547.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/ETH',
#    'percent_volume': 0.0128879169417,
#    'price': 970.028,
#    'updated': True,
#    'volume_24h': 134105.0},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/ETH',
#    'percent_volume': 0.0128004630479,
#    'price': 0.0619774,
#    'updated': True,
#    'volume_24h': 133195.0},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/USDT',
#    'percent_volume': 0.0124531461557,
#    'price': 1.19176,
#    'updated': True,
#    'volume_24h': 129581.0},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/BTC',
#    'percent_volume': 0.0124386345756,
#    'price': 0.0919417,
#    'updated': True,
#    'volume_24h': 129430.0},
#   {'currency': 'RefToken',
#    'pair': 'REF/BTC',
#    'percent_volume': 0.0123462794197,
#    'price': 6.00441,
#    'updated': True,
#    'volume_24h': 128469.0},
#   {'currency': 'Hi Mutual Society',
#    'pair': 'HMC/ETH',
#    'percent_volume': 0.0116379989838,
#    'price': 0.0352532,
#    'updated': True,
#    'volume_24h': 121099.0},
#   {'currency': 'Nuls',
#    'pair': 'NULS/USDT',
#    'percent_volume': 0.0115037428414,
#    'price': 2.60384,
#    'updated': True,
#    'volume_24h': 119702.0},
#   {'currency': 'Status',
#    'pair': 'SNT/USDT',
#    'percent_volume': 0.0114390654014,
#    'price': 0.100448,
#    'updated': True,
#    'volume_24h': 119029.0},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/BTC',
#    'percent_volume': 0.0112912587107,
#    'price': 319.405,
#    'updated': True,
#    'volume_24h': 117491.0},
#   {'currency': 'Bankex',
#    'pair': 'BKX/USDT',
#    'percent_volume': 0.0111871789668,
#    'price': 0.308355,
#    'updated': True,
#    'volume_24h': 116408.0},
#   {'currency': 'ChatCoin',
#    'pair': 'CHAT/BTC',
#    'percent_volume': 0.0110731044923,
#    'price': 0.0855174,
#    'updated': True,
#    'volume_24h': 115221.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/ETH',
#    'percent_volume': 0.0109032901734,
#    'price': 0.868268,
#    'updated': True,
#    'volume_24h': 113454.0},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/USDT',
#    'percent_volume': 0.0105704848613,
#    'price': 1.11144,
#    'updated': True,
#    'volume_24h': 109991.0},
#   {'currency': 'QunQun',
#    'pair': 'QUN/ETH',
#    'percent_volume': 0.0104681349747,
#    'price': 0.0265091,
#    'updated': True,
#    'volume_24h': 108926.0},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/ETH',
#    'percent_volume': 0.0102480586927,
#    'price': 0.0185948,
#    'updated': True,
#    'volume_24h': 106636.0},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/USDT',
#    'percent_volume': 0.00964875926283,
#    'price': 0.188078,
#    'updated': True,
#    'volume_24h': 100400.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/ETH',
#    'percent_volume': 0.00945046957173,
#    'price': 157.774,
#    'updated': True,
#    'volume_24h': 98336.7},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/USDT',
#    'percent_volume': 0.00938642641264,
#    'price': 0.0475702,
#    'updated': True,
#    'volume_24h': 97670.3},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/BTC',
#    'percent_volume': 0.00900400302883,
#    'price': 0.0315372,
#    'updated': True,
#    'volume_24h': 93691.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/ETH',
#    'percent_volume': 0.00897152976433,
#    'price': 0.0829952,
#    'updated': True,
#    'volume_24h': 93353.1},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/ETH',
#    'percent_volume': 0.0089543657364,
#    'price': 0.0186511,
#    'updated': True,
#    'volume_24h': 93174.5},
#   {'currency': 'Show',
#    'pair': 'SHOW/ETH',
#    'percent_volume': 0.00874099745637,
#    'price': 0.00166994,
#    'updated': True,
#    'volume_24h': 90954.3},
#   {'currency': 'Status',
#    'pair': 'SNT/BTC',
#    'percent_volume': 0.00869094692027,
#    'price': 0.100535,
#    'updated': True,
#    'volume_24h': 90433.5},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/USDT',
#    'percent_volume': 0.00866937175638,
#    'price': 0.32538,
#    'updated': True,
#    'volume_24h': 90209.0},
#   {'currency': 'Gifto',
#    'pair': 'GTO/ETH',
#    'percent_volume': 0.00854028596513,
#    'price': 0.240211,
#    'updated': True,
#    'volume_24h': 88865.8},
#   {'currency': 'Leverj',
#    'pair': 'LEV/BTC',
#    'percent_volume': 0.00816614667543,
#    'price': 0.0301188,
#    'updated': True,
#    'volume_24h': 84972.7},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/BTC',
#    'percent_volume': 0.00783258214828,
#    'price': 0.0200236,
#    'updated': True,
#    'volume_24h': 81501.8},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/BTC',
#    'percent_volume': 0.00755998547847,
#    'price': 1.18406,
#    'updated': True,
#    'volume_24h': 78665.3},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/BTC',
#    'percent_volume': 0.00755579537983,
#    'price': 17.1716,
#    'updated': True,
#    'volume_24h': 78621.7},
#   {'currency': 'Centra',
#    'pair': 'CTR/BTC',
#    'percent_volume': 0.00743892430274,
#    'price': 0.434011,
#    'updated': True,
#    'volume_24h': 77405.6},
#   {'currency': 'Maggie',
#    'pair': 'MAG/BTC',
#    'percent_volume': 0.00726765882583,
#    'price': 0.0100118,
#    'updated': True,
#    'volume_24h': 75623.5},
#   {'currency': 'ChatCoin',
#    'pair': 'CHAT/USDT',
#    'percent_volume': 0.00714525220558,
#    'price': 0.0831227,
#    'updated': True,
#    'volume_24h': 74349.8},
#   {'currency': 'Cube',
#    'pair': 'AUTO/USDT',
#    'percent_volume': 0.0069678649561,
#    'price': 0.00891316,
#    'updated': True,
#    'volume_24h': 72504.0},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/BTC',
#    'percent_volume': 0.0068976231419,
#    'price': 13.3824,
#    'updated': True,
#    'volume_24h': 71773.1},
#   {'currency': 'Maggie',
#    'pair': 'MAG/USDT',
#    'percent_volume': 0.00682719873167,
#    'price': 0.0103152,
#    'updated': True,
#    'volume_24h': 71040.3},
#   {'currency': 'Nuls',
#    'pair': 'NULS/BTC',
#    'percent_volume': 0.00671947667731,
#    'price': 2.73205,
#    'updated': True,
#    'volume_24h': 69919.4},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/BTC',
#    'percent_volume': 0.006655154819,
#    'price': 0.000834316,
#    'updated': True,
#    'volume_24h': 69250.1},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/BTC',
#    'percent_volume': 0.0066473031892,
#    'price': 0.0866855,
#    'updated': True,
#    'volume_24h': 69168.4},
#   {'currency': 'Ontology',
#    'pair': 'ONT/BTC',
#    'percent_volume': 0.00633472759654,
#    'price': 1.27884,
#    'updated': True,
#    'volume_24h': 65915.9},
#   {'currency': 'Nano',
#    'pair': 'NANO/USDT',
#    'percent_volume': 0.00617743552199,
#    'price': 7.37269,
#    'updated': True,
#    'volume_24h': 64279.2},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/USDT',
#    'percent_volume': 0.00602909065348,
#    'price': 311.461,
#    'updated': True,
#    'volume_24h': 62735.6},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/ETH',
#    'percent_volume': 0.0059123829518,
#    'price': 0.0317084,
#    'updated': True,
#    'volume_24h': 61521.2},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/USDT',
#    'percent_volume': 0.00588064968179,
#    'price': 0.00100148,
#    'updated': True,
#    'volume_24h': 61191.0},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/BTC',
#    'percent_volume': 0.00568398413443,
#    'price': 0.170201,
#    'updated': True,
#    'volume_24h': 59144.6},
#   {'currency': 'RefToken',
#    'pair': 'REF/USDT',
#    'percent_volume': 0.00567709353643,
#    'price': 5.85995,
#    'updated': True,
#    'volume_24h': 59072.9},
#   {'currency': 'NAGA',
#    'pair': 'NGC/BTC',
#    'percent_volume': 0.00566492687385,
#    'price': 0.752971,
#    'updated': True,
#    'volume_24h': 58946.3},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/USDT',
#    'percent_volume': 0.00561527997111,
#    'price': 0.00911346,
#    'updated': True,
#    'volume_24h': 58429.7},
#   {'currency': 'Ontology',
#    'pair': 'ONT/USDT',
#    'percent_volume': 0.00560763015799,
#    'price': 1.27058,
#    'updated': True,
#    'volume_24h': 58350.1},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/USDT',
#    'percent_volume': 0.00551640901962,
#    'price': 0.0199294,
#    'updated': True,
#    'volume_24h': 57400.9},
#   {'currency': 'Dash',
#    'pair': 'DASH/USDT',
#    'percent_volume': 0.00517241729746,
#    'price': 394.579,
#    'updated': True,
#    'volume_24h': 53821.5},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/BTC',
#    'percent_volume': 0.00517004354891,
#    'price': 57.5341,
#    'updated': True,
#    'volume_24h': 53796.8},
#   {'currency': 'RefToken',
#    'pair': 'REF/ETH',
#    'percent_volume': 0.0049937038241,
#    'price': 6.43893,
#    'updated': True,
#    'volume_24h': 51961.9},
#   {'currency': 'Dash',
#    'pair': 'DASH/BTC',
#    'percent_volume': 0.00499355005901,
#    'price': 396.964,
#    'updated': True,
#    'volume_24h': 51960.3},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/BTC',
#    'percent_volume': 0.00492612406799,
#    'price': 0.0351247,
#    'updated': True,
#    'volume_24h': 51258.7},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/BTC',
#    'percent_volume': 0.00479275207491,
#    'price': 0.176541,
#    'updated': True,
#    'volume_24h': 49870.9},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/USDT',
#    'percent_volume': 0.00471929080419,
#    'price': 13.5062,
#    'updated': True,
#    'volume_24h': 49106.5},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/ETH',
#    'percent_volume': 0.00471857964065,
#    'price': 0.0920723,
#    'updated': True,
#    'volume_24h': 49099.1},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/USDT',
#    'percent_volume': 0.0046781105916,
#    'price': 0.0871287,
#    'updated': True,
#    'volume_24h': 48678.0},
#   {'currency': 'Monaco',
#    'pair': 'MCO/BTC',
#    'percent_volume': 0.00454903441066,
#    'price': 5.95627,
#    'updated': True,
#    'volume_24h': 47334.9},
#   {'currency': 'Leverj',
#    'pair': 'LEV/USDT',
#    'percent_volume': 0.00445911066522,
#    'price': 0.0320473,
#    'updated': True,
#    'volume_24h': 46399.2},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/USDT',
#    'percent_volume': 0.00423434454805,
#    'price': 56.9374,
#    'updated': True,
#    'volume_24h': 44060.4},
#   {'currency': 'YEE',
#    'pair': 'YEE/USDT',
#    'percent_volume': 0.0041938274474,
#    'price': 0.0116172,
#    'updated': True,
#    'volume_24h': 43638.8},
#   {'currency': 'SmartMesh',
#    'pair': 'SMT/USDT',
#    'percent_volume': 0.00415783680652,
#    'price': 0.028442,
#    'updated': True,
#    'volume_24h': 43264.3},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/USDT',
#    'percent_volume': 0.00403494967037,
#    'price': 0.0352521,
#    'updated': True,
#    'volume_24h': 41985.6},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/ETH',
#    'percent_volume': 0.00402735751916,
#    'price': 1.20392,
#    'updated': True,
#    'volume_24h': 41906.6},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/USDT',
#    'percent_volume': 0.00387279477491,
#    'price': 0.169951,
#    'updated': True,
#    'volume_24h': 40298.3},
#   {'currency': 'Gas',
#    'pair': 'GAS/BTC',
#    'percent_volume': 0.00387109374863,
#    'price': 20.6744,
#    'updated': True,
#    'volume_24h': 40280.6},
#   {'currency': 'AirSwap',
#    'pair': 'AST/BTC',
#    'percent_volume': 0.00383838022619,
#    'price': 0.264228,
#    'updated': True,
#    'volume_24h': 39940.2},
#   {'currency': 'BitcoinX',
#    'pair': 'BCX/BTC',
#    'percent_volume': 0.0038066565665,
#    'price': 0.00392129,
#    'updated': True,
#    'volume_24h': 39610.1},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/BTC',
#    'percent_volume': 0.00378345725887,
#    'price': 0.0312034,
#    'updated': True,
#    'volume_24h': 39368.7},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/ETH',
#    'percent_volume': 0.00366047401954,
#    'price': 0.00896442,
#    'updated': True,
#    'volume_24h': 38089.0},
#   {'currency': 'Gas',
#    'pair': 'GAS/USDT',
#    'percent_volume': 0.00362206157853,
#    'price': 20.7323,
#    'updated': True,
#    'volume_24h': 37689.3},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/USDT',
#    'percent_volume': 0.00360302353859,
#    'price': 0.0204302,
#    'updated': True,
#    'volume_24h': 37491.2},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/BTC',
#    'percent_volume': 0.00355283845804,
#    'price': 0.022026,
#    'updated': True,
#    'volume_24h': 36969.0},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/ETH',
#    'percent_volume': 0.00341173015898,
#    'price': 0.0306532,
#    'updated': True,
#    'volume_24h': 35500.7},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/USDT',
#    'percent_volume': 0.00340056296948,
#    'price': 0.017626,
#    'updated': True,
#    'volume_24h': 35384.5},
#   {'currency': 'EOS',
#    'pair': 'EOS/BCH',
#    'percent_volume': 0.00330516134278,
#    'price': 6.76165,
#    'updated': True,
#    'volume_24h': 34391.8},
#   {'currency': 'YEE',
#    'pair': 'YEE/BTC',
#    'percent_volume': 0.00328992898877,
#    'price': 0.0115136,
#    'updated': True,
#    'volume_24h': 34233.3},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/BTC',
#    'percent_volume': 0.00327516754033,
#    'price': 0.0617394,
#    'updated': True,
#    'volume_24h': 34079.7},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/ETH',
#    'percent_volume': 0.00321351735042,
#    'price': 0.0825905,
#    'updated': True,
#    'volume_24h': 33438.2},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/USDT',
#    'percent_volume': 0.00319094271346,
#    'price': 0.0201297,
#    'updated': True,
#    'volume_24h': 33203.3},
#   {'currency': 'Monero',
#    'pair': 'XMR/BTC',
#    'percent_volume': 0.0031849266544,
#    'price': 197.185,
#    'updated': True,
#    'volume_24h': 33140.7},
#   {'currency': 'Dent',
#    'pair': 'DENT/BTC',
#    'percent_volume': 0.00317523945387,
#    'price': 0.00901062,
#    'updated': True,
#    'volume_24h': 33039.9},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/BCH',
#    'percent_volume': 0.00312595774321,
#    'price': 2.93454,
#    'updated': True,
#    'volume_24h': 32527.1},
#   {'currency': 'Maggie',
#    'pair': 'MAG/ETH',
#    'percent_volume': 0.00311471367116,
#    'price': 0.0099838,
#    'updated': True,
#    'volume_24h': 32410.1},
#   {'currency': 'Nano',
#    'pair': 'NANO/BTC',
#    'percent_volume': 0.00309173540084,
#    'price': 7.50217,
#    'updated': True,
#    'volume_24h': 32171.0},
#   {'currency': 'Centra',
#    'pair': 'CTR/USDT',
#    'percent_volume': 0.00298071700741,
#    'price': 0.484315,
#    'updated': True,
#    'volume_24h': 31015.8},
#   {'currency': 'Datum',
#    'pair': 'DAT/BTC',
#    'percent_volume': 0.00296683970823,
#    'price': 0.0235277,
#    'updated': True,
#    'volume_24h': 30871.4},
#   {'currency': 'IPChain',
#    'pair': 'IPC/BTC',
#    'percent_volume': 0.00295885353398,
#    'price': 0.539135,
#    'updated': True,
#    'volume_24h': 30788.3},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/ETH',
#    'percent_volume': 0.00293038777209,
#    'price': 0.335495,
#    'updated': True,
#    'volume_24h': 30492.1},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/USDT',
#    'percent_volume': 0.00286964095207,
#    'price': 0.0638943,
#    'updated': True,
#    'volume_24h': 29860.0},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/ETH',
#    'percent_volume': 0.00286920848776,
#    'price': 6.13935,
#    'updated': True,
#    'volume_24h': 29855.5},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/USDT',
#    'percent_volume': 0.00266916971878,
#    'price': 17.2255,
#    'updated': True,
#    'volume_24h': 27774.0},
#   {'currency': 'Ontology',
#    'pair': 'ONT/ETH',
#    'percent_volume': 0.00265173660195,
#    'price': 1.28063,
#    'updated': True,
#    'volume_24h': 27592.6},
#   {'currency': 'Nuls',
#    'pair': 'NULS/ETH',
#    'percent_volume': 0.00261189222356,
#    'price': 2.66371,
#    'updated': True,
#    'volume_24h': 27178.0},
#   {'currency': 'Read',
#    'pair': 'READ/USDT',
#    'percent_volume': 0.00260130165313,
#    'price': 0.0186275,
#    'updated': True,
#    'volume_24h': 27067.8},
#   {'currency': 'Enigma',
#    'pair': 'ENG/BTC',
#    'percent_volume': 0.00253883458619,
#    'price': 1.81055,
#    'updated': True,
#    'volume_24h': 26417.8},
#   {'currency': 'Storj',
#    'pair': 'STORJ/BTC',
#    'percent_volume': 0.00245333158703,
#    'price': 0.816379,
#    'updated': True,
#    'volume_24h': 25528.1},
#   {'currency': '0x',
#    'pair': 'ZRX/BTC',
#    'percent_volume': 0.00235570036656,
#    'price': 0.515441,
#    'updated': True,
#    'volume_24h': 24512.2},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/ETH',
#    'percent_volume': 0.00230515970424,
#    'price': 1.10326,
#    'updated': True,
#    'volume_24h': 23986.3},
#   {'currency': 'ChatCoin',
#    'pair': 'CHAT/ETH',
#    'percent_volume': 0.00221807100261,
#    'price': 0.0829849,
#    'updated': True,
#    'volume_24h': 23080.1},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/ETH',
#    'percent_volume': 0.00218348346816,
#    'price': 0.00917444,
#    'updated': True,
#    'volume_24h': 22720.2},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/USDT',
#    'percent_volume': 0.00210724481554,
#    'price': 1.46346,
#    'updated': True,
#    'volume_24h': 21926.9},
#   {'currency': 'TenX',
#    'pair': 'PAY/BTC',
#    'percent_volume': 0.002102151347,
#    'price': 1.11073,
#    'updated': True,
#    'volume_24h': 21873.9},
#   {'currency': 'UTRUST',
#    'pair': 'UTK/BTC',
#    'percent_volume': 0.00206482487193,
#    'price': 0.142752,
#    'updated': True,
#    'volume_24h': 21485.5},
#   {'currency': 'AirSwap',
#    'pair': 'AST/USDT',
#    'percent_volume': 0.00205774206757,
#    'price': 0.267695,
#    'updated': True,
#    'volume_24h': 21411.8},
#   {'currency': 'Ace',
#    'pair': 'ACE/USDT',
#    'percent_volume': 0.0020226644069,
#    'price': 0.122681,
#    'updated': True,
#    'volume_24h': 21046.8},
#   {'currency': 'NEM',
#    'pair': 'XEM/ETH',
#    'percent_volume': 0.00201668678911,
#    'price': 0.266453,
#    'updated': True,
#    'volume_24h': 20984.6},
#   {'currency': 'Achain',
#    'pair': 'ACT/ETH',
#    'percent_volume': 0.00201191046107,
#    'price': 0.203615,
#    'updated': True,
#    'volume_24h': 20934.9},
#   {'currency': 'Enigma',
#    'pair': 'ENG/USDT',
#    'percent_volume': 0.00199012387019,
#    'price': 1.81117,
#    'updated': True,
#    'volume_24h': 20708.2},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/USDT',
#    'percent_volume': 0.0018564827882,
#    'price': 0.0312461,
#    'updated': True,
#    'volume_24h': 19317.6},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/USDT',
#    'percent_volume': 0.00184457560421,
#    'price': 0.233244,
#    'updated': True,
#    'volume_24h': 19193.7},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/USDT',
#    'percent_volume': 0.00181263090721,
#    'price': 0.260985,
#    'updated': True,
#    'volume_24h': 18861.3},
#   {'currency': 'Civic',
#    'pair': 'CVC/BTC',
#    'percent_volume': 0.00179341988155,
#    'price': 0.241952,
#    'updated': True,
#    'volume_24h': 18661.4},
#   {'currency': 'Hshare',
#    'pair': 'HSR/ETH',
#    'percent_volume': 0.00179274715929,
#    'price': 6.58546,
#    'updated': True,
#    'volume_24h': 18654.4},
#   {'currency': 'Monero',
#    'pair': 'XMR/USDT',
#    'percent_volume': 0.00178049400385,
#    'price': 196.781,
#    'updated': True,
#    'volume_24h': 18526.9},
#   {'currency': 'BT2 [CST]',
#    'pair': 'BT2/BTC',
#    'percent_volume': 0.00175549756676,
#    'price': 60.2825,
#    'updated': True,
#    'volume_24h': 18266.8},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/BTC',
#    'percent_volume': 0.00173152943369,
#    'price': 1.4578,
#    'updated': True,
#    'volume_24h': 18017.4},
#   {'currency': 'Dash',
#    'pair': 'DASH/ETH',
#    'percent_volume': 0.00172906919228,
#    'price': 391.783,
#    'updated': True,
#    'volume_24h': 17991.8},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/BTC',
#    'percent_volume': 0.00167783658707,
#    'price': 1.5852,
#    'updated': True,
#    'volume_24h': 17458.7},
#   {'currency': 'Datum',
#    'pair': 'DAT/ETH',
#    'percent_volume': 0.00166960054455,
#    'price': 0.0236353,
#    'updated': True,
#    'volume_24h': 17373.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/BCH',
#    'percent_volume': 0.00166690965552,
#    'price': 18.2913,
#    'updated': True,
#    'volume_24h': 17345.0},
#   {'currency': 'Republic Protocol',
#    'pair': 'REN/ETH',
#    'percent_volume': 0.00162278868562,
#    'price': 0.0464254,
#    'updated': True,
#    'volume_24h': 16885.9},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/BTC',
#    'percent_volume': 0.00158772063527,
#    'price': 0.822135,
#    'updated': True,
#    'volume_24h': 16521.0},
#   {'currency': 'ugChain',
#    'pair': 'UGC/ETH',
#    'percent_volume': 0.00155970655833,
#    'price': 0.0364212,
#    'updated': True,
#    'volume_24h': 16229.5},
#   {'currency': 'ugChain',
#    'pair': 'UGC/USDT',
#    'percent_volume': 0.00153727607614,
#    'price': 0.0370547,
#    'updated': True,
#    'volume_24h': 15996.1},
#   {'currency': 'Bancor',
#    'pair': 'BNT/BTC',
#    'percent_volume': 0.00147416511789,
#    'price': 2.83592,
#    'updated': True,
#    'volume_24h': 15339.4},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/ETH',
#    'percent_volume': 0.0014065949721,
#    'price': 0.259871,
#    'updated': True,
#    'volume_24h': 14636.3},
#   {'currency': 'Stellar',
#    'pair': 'XLM/ETH',
#    'percent_volume': 0.00139485116351,
#    'price': 0.225048,
#    'updated': True,
#    'volume_24h': 14514.1},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/BTC',
#    'percent_volume': 0.00137016225659,
#    'price': 0.225933,
#    'updated': True,
#    'volume_24h': 14257.2},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/ETH',
#    'percent_volume': 0.00136458827216,
#    'price': 17.0917,
#    'updated': True,
#    'volume_24h': 14199.2},
#   {'currency': 'Status',
#    'pair': 'SNT/ETH',
#    'percent_volume': 0.00132532051285,
#    'price': 0.100442,
#    'updated': True,
#    'volume_24h': 13790.6},
#   {'currency': 'TenX',
#    'pair': 'PAY/USDT',
#    'percent_volume': 0.0013031783402,
#    'price': 1.09161,
#    'updated': True,
#    'volume_24h': 13560.2},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/BTC',
#    'percent_volume': 0.00129315477853,
#    'price': 0.0480566,
#    'updated': True,
#    'volume_24h': 13455.9},
#   {'currency': 'Waltonchain',
#    'pair': 'WTC/BTC',
#    'percent_volume': 0.00128901273148,
#    'price': 12.1094,
#    'updated': True,
#    'volume_24h': 13412.8},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/BTC',
#    'percent_volume': 0.00128376549786,
#    'price': 0.193144,
#    'updated': True,
#    'volume_24h': 13358.2},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/BTC',
#    'percent_volume': 0.00125156132227,
#    'price': 0.00909405,
#    'updated': True,
#    'volume_24h': 13023.1},
#   {'currency': 'Leverj',
#    'pair': 'LEV/ETH',
#    'percent_volume': 0.00122194232222,
#    'price': 0.0368822,
#    'updated': True,
#    'volume_24h': 12714.9},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/ETH',
#    'percent_volume': 0.00120107832186,
#    'price': 10.6935,
#    'updated': True,
#    'volume_24h': 12497.8},
#   {'currency': 'Storj',
#    'pair': 'STORJ/USDT',
#    'percent_volume': 0.00114862520627,
#    'price': 0.811699,
#    'updated': True,
#    'volume_24h': 11952.0},
#   {'currency': 'IPChain',
#    'pair': 'IPC/ETH',
#    'percent_volume': 0.0011466647014,
#    'price': 0.522518,
#    'updated': True,
#    'volume_24h': 11931.6},
#   {'currency': 'Hi Mutual Society',
#    'pair': 'HMC/USDT',
#    'percent_volume': 0.00114268602975,
#    'price': 0.0339501,
#    'updated': True,
#    'volume_24h': 11890.2},
#   {'currency': 'SALT',
#    'pair': 'SALT/BTC',
#    'percent_volume': 0.00113435388405,
#    'price': 2.75883,
#    'updated': True,
#    'volume_24h': 11803.5},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/BTC',
#    'percent_volume': 0.00113294116731,
#    'price': 0.0196899,
#    'updated': True,
#    'volume_24h': 11788.8},
#   {'currency': 'Datum',
#    'pair': 'DAT/USDT',
#    'percent_volume': 0.00112282150246,
#    'price': 0.0249368,
#    'updated': True,
#    'volume_24h': 11683.5},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/BTC',
#    'percent_volume': 0.00111529662348,
#    'price': 0.0202739,
#    'updated': True,
#    'volume_24h': 11605.2},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/ETH',
#    'percent_volume': 0.00110870394533,
#    'price': 310.937,
#    'updated': True,
#    'volume_24h': 11536.6},
#   {'currency': 'SmartMesh',
#    'pair': 'SMT/BTC',
#    'percent_volume': 0.00109625858354,
#    'price': 0.0287005,
#    'updated': True,
#    'volume_24h': 11407.1},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/BTC',
#    'percent_volume': 0.00107223278856,
#    'price': 6.12597,
#    'updated': True,
#    'volume_24h': 11157.1},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/ETH',
#    'percent_volume': 0.00106145001177,
#    'price': 0.184805,
#    'updated': True,
#    'volume_24h': 11044.9},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/USDT',
#    'percent_volume': 0.000953768320749,
#    'price': 0.0478707,
#    'updated': True,
#    'volume_24h': 9924.42},
#   {'currency': 'IPChain',
#    'pair': 'IPC/USDT',
#    'percent_volume': 0.000938873288895,
#    'price': 0.515461,
#    'updated': True,
#    'volume_24h': 9769.43},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/ETH',
#    'percent_volume': 0.000917541266051,
#    'price': 0.0494068,
# ...
#   {'currency': 'Centra',
#    'pair': 'CTR/ETH',
#    'percent_volume': 0.000283437108505,
#    'price': 0.469218,
#    'updated': True,
#    'volume_24h': 2949.3},
#   {'currency': 'Dent',
#    'pair': 'DENT/ETH',
#    'percent_volume': 0.000282577946076,
#    'price': 0.00860584,
#    'updated': True,
#    'volume_24h': 2940.36},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/ETH',
#    'percent_volume': 0.000280410819369,
#    'price': 13.2225,
#    'updated': True,
#    'volume_24h': 2917.81},
#   {'currency': 'Enigma',
#    'pair': 'ENG/ETH',
#    'percent_volume': 0.000274805120885,
#    'price': 1.84773,
#    'updated': True,
#    'volume_24h': 2859.48},
#   {'currency': 'Aventus',
#    'pair': 'AVT/USDT',
#    'percent_volume': 0.000274232345933,
#    'price': 1.05716,
#    'updated': True,
#    'volume_24h': 2853.52},
#   {'currency': 'Refereum',
#    'pair': 'RFR/USDT',
#    'percent_volume': 0.00026392624092,
#    'price': 0.00891316,
#    'updated': True,
#    'volume_24h': 2746.28},
#   {'currency': 'Achain',
#    'pair': 'ACT/BCH',
#    'percent_volume': 0.000262864300782,
#    'price': 0.196349,
#    'updated': True,
#    'volume_24h': 2735.23},
#   {'currency': 'Civic',
#    'pair': 'CVC/ETH',
#    'percent_volume': 0.000262043579625,
#    'price': 0.241455,
#    'updated': True,
#    'volume_24h': 2726.69},
#   {'currency': 'Monaco',
#    'pair': 'MCO/ETH',
#    'percent_volume': 0.000259671753145,
#    'price': 5.95952,
#    'updated': True,
#    'volume_24h': 2702.01},
#   {'currency': 'Substratum',
#    'pair': 'SUB/BTC',
#    'percent_volume': 0.000251107037752,
#    'price': 0.492747,
#    'updated': True,
#    'volume_24h': 2612.89},
#   {'currency': 'AirSwap',
#    'pair': 'AST/ETH',
#    'percent_volume': 0.000247724205819,
#    'price': 0.266341,
#    'updated': True,
#    'volume_24h': 2577.69},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/BTC',
#    'percent_volume': 0.000247508934696,
#    'price': 0.969058,
#    'updated': True,
#    'volume_24h': 2575.45},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/ETH',
#    'percent_volume': 0.000245551312921,
#    'price': 0.369831,
#    'updated': True,
#    'volume_24h': 2555.08},
#   {'currency': 'OST',
#    'pair': 'OST/USDT',
#    'percent_volume': 0.000242775853085,
#    'price': 0.180667,
#    'updated': True,
#    'volume_24h': 2526.2},
#   {'currency': 'Storj',
#    'pair': 'STORJ/ETH',
#    'percent_volume': 0.000238170588704,
#    'price': 0.802956,
#    'updated': True,
#    'volume_24h': 2478.28},
#   {'currency': 'Metal',
#    'pair': 'MTL/USDT',
#    'percent_volume': 0.000237321036594,
#    'price': 4.08433,
#    'updated': True,
#    'volume_24h': 2469.44},
#   {'currency': 'SunContract',
#    'pair': 'SNC/USDT',
#    'percent_volume': 0.000236518575041,
#    'price': 0.191683,
#    'updated': True,
#    'volume_24h': 2461.09},
#   {'currency': 'Revain',
#    'pair': 'R/USDT',
#    'percent_volume': 0.000235827593178,
#    'price': 0.936483,
#    'updated': True,
#    'volume_24h': 2453.9},
#   {'currency': 'Enjin Coin',
#    'pair': 'ENJ/ETH',
#    'percent_volume': 0.000226341248289,
#    'price': 0.117818,
#    'updated': True,
#    'volume_24h': 2355.19},
#   {'currency': 'Waltonchain',
#    'pair': 'WTC/ETH',
#    'percent_volume': 0.000219200782022,
#    'price': 12.0758,
#    'updated': True,
#    'volume_24h': 2280.89},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/ETH',
#    'percent_volume': 0.000211455826753,
#    'price': 0.0201213,
#    'updated': True,
#    'volume_24h': 2200.3},
#   {'currency': 'Po.et',
#    'pair': 'POE/BTC',
#    'percent_volume': 0.000201246785951,
#    'price': 0.0302023,
#    'updated': True,
#    'volume_24h': 2094.07},
#   {'currency': 'Monaco',
#    'pair': 'MCO/USDT',
#    'percent_volume': 0.000192594616664,
#    'price': 5.8894,
#    'updated': True,
#    'volume_24h': 2004.04},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/USDT',
#    'percent_volume': 0.000175160538797,
#    'price': 0.201598,
#    'updated': True,
#    'volume_24h': 1822.63},
#   {'currency': 'Viuly',
#    'pair': 'VIU/BTC',
#    'percent_volume': 0.000164577656625,
#    'price': 0.00533962,
#    'updated': True,
#    'volume_24h': 1712.51},
#   {'currency': 'Golem',
#    'pair': 'GNT/ETH',
#    'percent_volume': 0.000156233978546,
#    'price': 0.263856,
#    'updated': True,
#    'volume_24h': 1625.69},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/USDT',
#    'percent_volume': 0.00014717144868,
#    'price': 0.389375,
#    'updated': True,
#    'volume_24h': 1531.39},
#   {'currency': 'Republic Protocol',
#    'pair': 'REN/USDT',
#    'percent_volume': 0.000139488960478,
#    'price': 0.0468692,
#    'updated': True,
#    'volume_24h': 1451.45},
#   {'currency': 'Populous',
#    'pair': 'PPT/BTC',
#    'percent_volume': 0.000132224521109,
#    'price': 14.5548,
#    'updated': True,
#    'volume_24h': 1375.86},
#   {'currency': 'Viuly',
#    'pair': 'VIU/ETH',
#    'percent_volume': 0.000121971272845,
#    'price': 0.00547598,
#    'updated': True,
#    'volume_24h': 1269.17},
#   {'currency': 'Enjin Coin',
#    'pair': 'ENJ/USDT',
#    'percent_volume': 0.000120739230078,
#    'price': 0.109161,
#    'updated': True,
#    'volume_24h': 1256.35},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/USDT',
#    'percent_volume': 0.000115605398208,
#    'price': 0.167447,
#    'updated': True,
#    'volume_24h': 1202.93},
#   {'currency': 'Substratum',
#    'pair': 'SUB/ETH',
#    'percent_volume': 0.000113853437238,
#    'price': 0.37063,
#    'updated': True,
#    'volume_24h': 1184.7},
#   {'currency': 'Everex',
#    'pair': 'EVX/BTC',
#    'percent_volume': 0.000111119301769,
#    'price': 1.14393,
#    'updated': True,
#    'volume_24h': 1156.25},
#   {'currency': 'Primas',
#    'pair': 'PST/ETH',
#    'percent_volume': 0.000106846554391,
#    'price': 0.179227,
#    'updated': True,
#    'volume_24h': 1111.79},
#   {'currency': 'district0x',
#    'pair': 'DNT/ETH',
#    'percent_volume': 0.000106160377686,
#    'price': 0.0496526,
#    'updated': True,
#    'volume_24h': 1104.65},
#   {'currency': 'SunContract',
#    'pair': 'SNC/ETH',
#    'percent_volume': 0.000105742328854,
#    'price': 0.198754,
#    'updated': True,
#    'volume_24h': 1100.3},
#   {'currency': 'SmartMesh',
#    'pair': 'SMT/ETH',
#    'percent_volume': 0.000104200833848,
#    'price': 0.0297004,
#    'updated': True,
#    'volume_24h': 1084.26},
#   {'currency': 'Read',
#    'pair': 'READ/ETH',
#    'percent_volume': 0.000101965473883,
#    'price': 0.0180825,
#    'updated': True,
#    'volume_24h': 1061.0},
#   {'currency': '0x',
#    'pair': 'ZRX/USDT',
#    'percent_volume': 9.73198461663e-05,
#    'price': 0.536893,
#    'updated': True,
#    'volume_24h': 1012.66},
#   {'currency': 'Bancor',
#    'pair': 'BNT/ETH',
#    'percent_volume': 9.63655415898e-05,
#    'price': 2.82921,
#    'updated': True,
#    'volume_24h': 1002.73},
#   {'currency': 'Everex',
#    'pair': 'EVX/USDT',
#    'percent_volume': 8.94497645573e-05,
#    'price': 1.30192,
#    'updated': True,
#    'volume_24h': 930.768},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/BTC',
#    'percent_volume': 8.76435052909e-05,
#    'price': 0.37878,
#    'updated': True,
#    'volume_24h': 911.973},
#   {'currency': 'Enjin Coin',
#    'pair': 'ENJ/BTC',
#    'percent_volume': 8.61982095682e-05,
#    'price': 0.105708,
#    'updated': True,
#    'volume_24h': 896.934},
#   {'currency': 'Gas',
#    'pair': 'GAS/ETH',
#    'percent_volume': 8.46432601173e-05,
#    'price': 20.6395,
#    'updated': True,
#    'volume_24h': 880.754},
#   {'currency': 'Viberate',
#    'pair': 'VIB/ETH',
#    'percent_volume': 7.23461855257e-05,
#    'price': 0.131941,
#    'updated': True,
#    'volume_24h': 752.797},
#   {'currency': 'Bread',
#    'pair': 'BRD/ETH',
#    'percent_volume': 7.13740057578e-05,
#    'price': 0.433504,
#    'updated': True,
#    'volume_24h': 742.681},
#   {'currency': 'Maker',
#    'pair': 'MKR/BTC',
#    'percent_volume': 6.95016275036e-05,
#    'price': 654.459,
#    'updated': True,
#    'volume_24h': 723.198},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/ETH',
#    'percent_volume': 6.79209224005e-05,
#    'price': 0.922039,
#    'updated': True,
#    'volume_24h': 706.75},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/ETH',
#    'percent_volume': 6.07623887354e-05,
#    'price': 0.233054,
#    'updated': True,
#    'volume_24h': 632.262},
#   {'currency': 'OST',
#    'pair': 'OST/ETH',
#    'percent_volume': 5.54745034673e-05,
#    'price': 0.166108,
#    'updated': True,
#    'volume_24h': 577.239},
#   {'currency': 'Ace',
#    'pair': 'ACE/ETH',
#    'percent_volume': 5.25272111459e-05,
#    'price': 0.122398,
#    'updated': True,
#    'volume_24h': 546.571},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/ETH',
#    'percent_volume': 5.24251495688e-05,
#    'price': 0.171128,
#    'updated': True,
#    'volume_24h': 545.509},
#   {'currency': 'TenX',
#    'pair': 'PAY/ETH',
#    'percent_volume': 5.08915350238e-05,
#    'price': 1.07552,
#    'updated': True,
#    'volume_24h': 529.551},
#   {'currency': 'Change',
#    'pair': 'CAG/USDT',
#    'percent_volume': 5.04774264216e-05,
#    'price': 0.178764,
#    'updated': True,
#    'volume_24h': 525.242},
#   {'currency': 'BitcoinX',
#    'pair': 'BCX/BCH',
#    'percent_volume': 4.4070707933e-05,
#    'price': 0.00388809,
#    'updated': True,
#    'volume_24h': 458.577},
#   {'currency': 'Request Network',
#    'pair': 'REQ/ETH',
#    'percent_volume': 4.32626723963e-05,
#    'price': 0.207621,
#    'updated': True,
#    'volume_24h': 450.169},
#   {'currency': 'district0x',
#    'pair': 'DNT/USDT',
#    'percent_volume': 4.04288779303e-05,
#    'price': 0.0470695,
#    'updated': True,
#    'volume_24h': 420.682},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/ETH',
#    'percent_volume': 3.96762939285e-05,
#    'price': 0.900591,
#    'updated': True,
#    'volume_24h': 412.851},
#   {'currency': 'Change',
#    'pair': 'CAG/BTC',
#    'percent_volume': 3.58168863265e-05,
#    'price': 0.166947,
#    'updated': True,
#    'volume_24h': 372.692},
#   {'currency': 'Po.et',
#    'pair': 'POE/ETH',
#    'percent_volume': 3.55449143274e-05,
#    'price': 0.0330352,
#    'updated': True,
#    'volume_24h': 369.862},
#   {'currency': 'Everex',
#    'pair': 'EVX/ETH',
#    'percent_volume': 2.81133515282e-05,
#    'price': 1.27062,
#    'updated': True,
#    'volume_24h': 292.533},
#   {'currency': 'Substratum',
#    'pair': 'SUB/USDT',
#    'percent_volume': 2.8041658556e-05,
#    'price': 0.390577,
#    'updated': True,
#    'volume_24h': 291.787},
#   {'currency': 'Change',
#    'pair': 'CAG/ETH',
#    'percent_volume': 2.68686231421e-05,
#    'price': 0.177813,
#    'updated': True,
#    'volume_24h': 279.581},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/ETH',
#    'percent_volume': 2.64128057597e-05,
#    'price': 0.0466047,
#    'updated': True,
#    'volume_24h': 274.838},
#   {'currency': 'Ark',
#    'pair': 'ARK/ETH',
#    'percent_volume': 2.59723648862e-05,
#    'price': 2.64527,
#    'updated': True,
#    'volume_24h': 270.255},
#   {'currency': 'Ark',
#    'pair': 'ARK/USDT',
#    'percent_volume': 2.31443366111e-05,
#    'price': 2.70419,
#    'updated': True,
#    'volume_24h': 240.828},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/ETH',
#    'percent_volume': 2.31280951736e-05,
#    'price': 0.0208333,
#    'updated': True,
#    'volume_24h': 240.659},
#   {'currency': 'Super Bitcoin',
#    'pair': 'SBTC/BCH',
#    'percent_volume': 1.96487756482e-05,
#    'price': 10.0021,
#    'updated': True,
#    'volume_24h': 204.455},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/BCH',
#    'percent_volume': 1.73706497685e-05,
#    'price': 57.155,
#    'updated': True,
#    'volume_24h': 180.75},
#   {'currency': 'Bancor',
#    'pair': 'BNT/USDT',
#    'percent_volume': 1.64572851466e-05,
#    'price': 2.85061,
#    'updated': True,
#    'volume_24h': 171.246},
#   {'currency': 'Request Network',
#    'pair': 'REQ/BTC',
#    'percent_volume': 1.60204000908e-05,
#    'price': 0.206744,
#    'updated': True,
#    'volume_24h': 166.7},
#   {'currency': 'SONM',
#    'pair': 'SNM/USDT',
#    'percent_volume': 1.52891509949e-05,
#    'price': 0.123282,
#    'updated': True,
#    'volume_24h': 159.091},
#   {'currency': 'Maker',
#    'pair': 'MKR/USDT',
#    'percent_volume': 1.49749896997e-05,
#    'price': 653.067,
#    'updated': True,
#    'volume_24h': 155.822},
#   {'currency': 'SALT',
#    'pair': 'SALT/USDT',
#    'percent_volume': 1.44006770966e-05,
#    'price': 2.72062,
#    'updated': True,
#    'volume_24h': 149.846},
#   {'currency': 'Maker',
#    'pair': 'MKR/ETH',
#    'percent_volume': 7.76378188179e-06,
#    'price': 654.614,
#    'updated': True,
#    'volume_24h': 80.7859},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/USDT',
#    'percent_volume': 6.15733073675e-06,
#    'price': 0.164944,
#    'updated': True,
#    'volume_24h': 64.07},
#   {'currency': 'Populous',
#    'pair': 'PPT/ETH',
#    'percent_volume': 5.59963437342e-06,
#    'price': 14.8876,
#    'updated': True,
#    'volume_24h': 58.2669},
#   {'currency': 'LATOKEN',
#    'pair': 'LA/USDT',
#    'percent_volume': 3.66674955719e-06,
#    'price': 0.209209,
#    'updated': True,
#    'volume_24h': 38.1543},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/ETH',
#    'percent_volume': 3.01166223134e-06,
#    'price': 0.183176,
#    'updated': True,
#    'volume_24h': 31.3378},
#   {'currency': 'Request Network',
#    'pair': 'REQ/USDT',
#    'percent_volume': 2.50806234799e-06,
#    'price': 0.200396,
#    'updated': True,
#    'volume_24h': 26.0976},
#   {'currency': 'Aventus',
#    'pair': 'AVT/ETH',
#    'percent_volume': 2.35256740289e-06,
#    'price': 1.11453,
#    'updated': True,
#    'volume_24h': 24.4796},
#   {'currency': 'Aventus',
#    'pair': 'AVT/BCH',
#    'percent_volume': 1.89885468023e-06,
#    'price': 1.31355,
#    'updated': True,
#    'volume_24h': 19.7585},
#   {'currency': 'Metal',
#    'pair': 'MTL/ETH',
#    'percent_volume': 1.85735732714e-06,
#    'price': 3.63845,
#    'updated': True,
#    'volume_24h': 19.3267},
#   {'currency': 'NAGA',
#    'pair': 'NGC/USDT',
#    'percent_volume': 1.36061921083e-06,
#    'price': 0.708747,
#    'updated': True,
#    'volume_24h': 14.1579},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/ETH',
#    'percent_volume': 1.23233107597e-06,
#    'price': 1.62956,
#    'updated': True,
#    'volume_24h': 12.823},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/ETH',
#    'percent_volume': 8.93766300373e-07,
#    'price': 0.172742,
#    'updated': True,
#    'volume_24h': 9.30007},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/BCH',
#    'percent_volume': 8.54437035028e-07,
#    'price': 324.91,
#    'updated': True,
#    'volume_24h': 8.89083},
#   {'currency': 'Monetha',
#    'pair': 'MTH/ETH',
#    'percent_volume': 7.18084882341e-07,
#    'price': 0.107573,
#    'updated': True,
#    'volume_24h': 7.47202},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/USDT',
#    'percent_volume': 3.77952663881e-07,
#    'price': 0.926668,
#    'updated': True,
#    'volume_24h': 3.93278},
#   {'currency': 'SingularDTV',
#    'pair': 'SNGLS/ETH',
#    'percent_volume': 2.3508087147e-07,
#    'price': 0.0564144,
#    'updated': True,
#    'volume_24h': 2.44613},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/ETH',
#    'percent_volume': 1.54443576304e-07,
#    'price': 0.164187,
#    'updated': True,
#    'volume_24h': 1.60706},
#   {'currency': 'SONM',
#    'pair': 'SNM/BTC',
#    'percent_volume': 0.0,
#    'price': 0.127233,
#    'updated': True,
#    'volume_24h': None},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/BTC',
#    'percent_volume': 0.0,
#    'price': 1.35326,
#    'updated': True,
#    'volume_24h': None},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/BCH',
#    'percent_volume': 0.0,
#    'price': 1.72199,
#    'updated': True,
#    'volume_24h': None},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/BCH',
#    'percent_volume': 0.0,
#    'price': 0.0885416,
#    'updated': True,
#    'volume_24h': None},
#   {'currency': 'OAX',
#    'pair': 'OAX/ETH',
#    'percent_volume': 0.0,
#    'price': 0.525095,
#    'updated': True,
#    'volume_24h': None},
#   {'currency': 'SONM',
#    'pair': 'SNM/ETH',
#    'percent_volume': 0.0,
#    'price': 0.118187,
#    'updated': True,
#    'volume_24h': None},
#   {'currency': 'FunFair',
#    'pair': 'FUN/ETH',
#    'percent_volume': 0.0,
#    'price': 0.0368822,
#    'updated': True,
#    'volume_24h': None},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/ETH',
#    'percent_volume': 0.0,
#    'price': 0.345509,
#    'updated': True,
#    'volume_24h': None},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/USDT',
#    'percent_volume': 0.0,
#    'price': 1.51674,
#    'updated': True,
#    'volume_24h': None}],
#  'name': 'OKEx ',
#  'slug': 'okex',
#  'social': {'twitter': {'link': 'https://twitter.com/CoinMarketCap',
#    'username': '@OKEx_'}},
#  'volume': 1040548295.02,
#  'web': 'https://www.okex.com'}

# %%
show_page("exchanges/okex")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/exchanges/okex"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# In order to obtain all available values for the `name` parameter, use:

# %%
cmc.exchange_slugs
# Out:
# ['1szb',
#  'abucoins',
#  'acx',
#  'aex',
#  'aidos-market',
#  'allcoin',
#  'altcoin-trader',
#  'bancor-network',
#  'barterdex',
#  'bcc-exchange',
#  'bcex',
#  'bibox',
#  'bigone',
#  'binance',
#  'bisq',
#  'bit-z',
#  'bit2c',
#  'bit520',
#  'bitbank',
#  'bitbay',
#  'bitbns',
#  'bitcoin-growth-fund-exchange',
#  'bitcoin-indonesia',
#  'bitcoinaverage',
#  'bitcointoyou',
#  'bitcointrade',
#  'bitex-la',
#  'bitfinex',
#  'bitflip',
#  'bitflyer',
#  'bithesap',
#  'bitholic',
#  'bithumb',
#  'bitinka',
#  'bitkonan',
#  'bitlish',
#  'bitmarket',
#  'bitmaszyna',
#  'bitmex',
#  'bitonic',
#  'bits-blockchain',
#  'bitsane',
#  'bitshares-asset-exchange',
#  'bitso',
#  'bitstamp',
#  'bitstamp-ripple-gateway',
#  'bitstar',
#  'bittrex',
#  'bittylicious',
#  'bityes',
#  'bl3p',
#  'bleutrade',
#  'braziliex',
#  'btc-alpha',
#  'btc-markets',
#  'btc-trade-ua',
#  'btcbox',
#  'btcc',
#  'btctrade-im',
#  'btcturk',
#  'btcxindia',
#  'btw18',
#  'burst-asset-exchange',
#  'bx-thailand',
#  'c-cex',
#  'c-patex',
#  'c2cx',
#  'cex-io',
#  'cfinex',
#  'chaoex',
#  'cobinhood',
#  'coinbe',
#  'coinbene',
#  'coincorner',
#  'coinegg',
#  'coinex',
#  'coinexchange',
#  'coinfalcon',
#  'coinfloor',
#  'coingi',
#  'coinhouse',
#  'coinlink',
#  'coinmate',
#  'coinnest',
#  'coinone',
#  'coinrail',
#  'coinrate',
#  'coinroom',
#  'coinsbank',
#  'coinsecure',
#  'coinsquare',
#  'coinut',
#  'coss',
#  'counterparty-dex',
#  'crex24',
#  'crxzone',
#  'cryptobridge',
#  'cryptoderivatives',
#  'cryptohub',
#  'cryptomarket',
#  'cryptomate',
#  'cryptonex',
#  'cryptopia',
#  'cryptox',
#  'dc-ex',
#  'dcexchange',
#  'ddex',
#  'dgtmarket',
#  'dsx',
#  'ethexindia',
#  'ethfinex',
#  'excambriorex',
#  'exmo',
#  'exrates',
#  'exx',
#  'ezbtc',
#  'fargobase',
#  'fatbtc',
#  'fisco',
#  'forkdelta',
#  'foxbit',
#  'freiexchange',
#  'gate-io',
#  'gatecoin',
#  'gatehub',
#  'gdax',
#  'gemini',
#  'getbtc',
#  'gopax',
#  'guldentrader',
#  'heat-wallet',
#  'hitbtc',
#  'huobi',
#  'hypex',
#  'idax',
#  'idex',
#  'independent-reserve',
#  'infinitycoin-exchange',
#  'iquant',
#  'isx',
#  'itbit',
#  'koineks',
#  'koinex',
#  'koinim',
#  'korbit',
#  'kraken',
#  'kucoin',
#  'kuna',
#  'lakebtc',
#  'latoken',
#  'lbank',
#  'lendconnect',
#  'leoxchange',
#  'lhang',
#  'liqui',
#  'litebit',
#  'livecoin',
#  'localtrade',
#  'luno',
#  'lykke-exchange',
#  'mbaex',
#  'mercado-bitcoin',
#  'mercatox',
#  'mr-exchange',
#  'nanex',
#  'negocie-coins',
#  'neraexpro',
#  'nhz-asset-exchange',
#  'nix-e',
#  'nocks',
#  'nxt-asset-exchange',
#  'nxt-monetary-system',
#  'oasisdex',
#  'octaex',
#  'oex',
#  'okcoin-cn',
#  'okcoin-intl',
#  'okex',
#  'omni-dex',
#  'ooobtc',
#  'openledger',
#  'ore-bz',
#  'otcbtc',
#  'ovis',
#  'paradex',
#  'paribu',
#  'paymium',
#  'poloniex',
#  'qbtc',
#  'qryptos',
#  'quadrigacx',
#  'quoine',
#  'radar-relay',
#  'rfinex',
#  'rightbtc',
#  'rippex',
#  'ripple-charts',
#  'ripple-china',
#  'ripplefox',
#  'rudex',
#  'simex',
#  'southxchange',
#  'stellar-decentralized-exchange',
#  'stellarport',
#  'stocks-exchange',
#  'stronghold',
#  'surbtc',
#  'tcc-exchange',
#  'tdax',
#  'therocktrading',
#  'tidebit',
#  'tidex',
#  'token-store',
#  'topbtc',
#  'trade-by-trade',
#  'trade-satoshi',
#  'tradeogre',
#  'triple-dice-exchange',
#  'tux-exchange',
#  'unocoin',
#  'upbit',
#  'vebitcoin',
#  'virtacoinworld',
#  'waves-dex',
#  'wex',
#  'xbtce',
#  'yobit',
#  'yobtc',
#  'zaif',
#  'zb-com',
#  'zebpay']

# %% [markdown]
# If you want to get all formatted exchange names:

# %%
cmc.exchange_names
# Out:
# ['1szb',
#  'ACX',
#  'AEX',
#  'Abucoins',
#  'AidosMarket',
#  'Allcoin',
#  'Altcoin Trader',
#  'BCC Exchange',
#  'BCEX',
#  'BITHOLIC',
#  'BL3P',
#  'BTC Markets',
#  'BTC Trade UA',
#  'BTC-Alpha',
#  'BTCBOX',
#  'BTCC',
#  'BTCTurk',
#  'BTCXIndia',
#  'BX Thailand',
#  'Bancor Network',
#  'BarterDEX',
#  'Bibox',
#  'BigONE',
#  'Binance',
#  'Bisq',
#  'Bit-Z',
#  'Bit2C',
#  'Bit520',
#  'BitBay',
#  'BitFlip',
#  'BitKonan',
#  'BitMEX',
#  'BitMarket',
#  'BitShares Asset Exchange',
#  'BitStar',
#  'BitYes',
#  'Bitbank',
#  'Bitbns',
#  'Bitcoin Growth Fund Exchange',
#  'Bitcoin Indonesia',
#  'BitcoinAverage',
#  'BitcoinToYou',
#  'BitcoinTrade',
#  'Bitex.la',
#  'Bitfinex',
#  'Bithesap',
#  'Bithumb',
#  'Bitinka',
#  'Bitlish',
#  'Bitmaszyna',
#  'Bitonic',
#  'Bits Blockchain',
#  'Bitsane',
#  'Bitso',
#  'Bitstamp',
#  'Bitstamp (Ripple Gateway)',
#  'Bittrex',
#  'Bittylicious',
#  'Bleutrade',
#  'Braziliex',
#  'BtcTrade.im',
#  'Burst Asset Exchange',
#  'C-CEX',
#  'C-Patex',
#  'C2CX',
#  'CEX.IO',
#  'COSS',
#  'CRXzone',
#  'ChaoEX',
#  'Cobinhood',
#  'CoinBene',
#  'CoinCorner',
#  'CoinEgg',
#  'CoinEx',
#  'CoinExchange',
#  'CoinFalcon',
#  'CoinMate',
#  'Coinbe',
#  'Coinfloor',
#  'Coingi',
#  'Coinhouse',
#  'Coinlink',
#  'Coinnest',
#  'Coinone',
#  'Coinrail',
#  'Coinrate',
#  'Coinroom',
#  'CoinsBank',
#  'Coinsecure',
#  'Coinsquare',
#  'Coinut',
#  'Counterparty DEX',
#  'Crex24',
#  'CryptoBridge',
#  'CryptoDerivatives',
#  'CryptoMarket',
#  'Cryptohub',
#  'Cryptomate',
#  'Cryptonex',
#  'Cryptopia',
#  'Cryptox',
#  'DC-Ex',
#  'DCExchange',
#  'DDEX',
#  'DSX',
#  'Dgtmarket',
#  'ETHEXIndia',
#  'EXX',
#  'Ethfinex',
#  'ExcambrioRex',
#  'Exmo',
#  'Exrates',
#  'Fargobase',
#  'Fatbtc',
#  'Fisco',
#  'ForkDelta',
#  'Foxbit',
#  'FreiExchange',
#  'GDAX',
#  'GOPAX',
#  'Gate.io',
#  'Gatecoin',
#  'Gatehub',
#  'Gemini',
#  'GetBTC',
#  'GuldenTrader',
#  'Heat Wallet',
#  'HitBTC',
#  'Huobi',
#  'Hypex',
#  'IDAX',
#  'IDEX',
#  'ISX',
#  'Independent Reserve',
#  'InfinityCoin Exchange',
#  'Iquant',
#  'Koineks',
#  'Koinex',
#  'Koinim',
#  'Korbit',
#  'Kraken',
#  'Kucoin',
#  'Kuna',
#  'LATOKEN',
#  'LEOxChange',
#  'LakeBTC',
#  'Lbank',
#  'Lendconnect',
#  'Lhang',
#  'Liqui',
#  'LiteBit.eu',
#  'Livecoin',
#  'LocalTrade',
#  'Luno',
#  'Lykke Exchange',
#  'MBAex',
#  'Mercado Bitcoin',
#  'Mercatox',
#  'Mr. Exchange',
#  'NHZ Asset Exchange',
#  'NIX-E',
#  'Nanex',
#  'Negocie Coins',
#  'Neraex',
#  'Nocks',
#  'Nxt Asset Exchange',
#  'Nxt Monetary System',
#  'OEX',
#  'OKCoin.cn',
#  'OKEx',
#  'OTCBTC',
#  'OasisDEX',
#  'Octaex',
#  'OkCoin Intl.',
#  'Omni DEX',
#  'OpenLedger DEX',
#  'Ore.Bz',
#  'Ovis',
#  'Paradex',
#  'Paribu',
#  'Paymium',
#  'Poloniex',
#  'QBTC',
#  'Qryptos',
#  'QuadrigaCX',
#  'Quoine',
#  'Radar Relay',
#  'Rfinex',
#  'RightBTC',
#  'Rippex',
#  'Ripple China',
#  'Ripple Gateways',
#  'RippleFox',
#  'RuDEX',
#  'Simex',
#  'SouthXchange',
#  'Stellar Decentralized Exchange',
#  'Stellarport',
#  'Stocks.Exchange',
#  'Stronghold',
#  'SurBTC',
#  'TCC Exchange',
#  'TDAX',
#  'TOPBTC',
#  'The Rock Trading',
#  'Tidebit',
#  'Tidex',
#  'Token Store',
#  'Trade By Trade',
#  'Trade Satoshi',
#  'TradeOgre',
#  'Tripe Dice Exchange',
#  'Tux Exchange',
#  'Unocoin',
#  'Upbit',
#  'Vebitcoin',
#  'VirtacoinWorld',
#  'WEX',
#  'Waves Decentralized Exchange',
#  'YoBit',
#  'Yobtc',
#  'ZB.COM',
#  'Zaif',
#  'Zebpay',
#  'bitFlyer',
#  'btw18.com',
#  'cfinex',
#  'ezBtc',
#  'itBit',
#  'ooobtc',
#  'xBTCe']

# %% [markdown]
# #### `exchanges([convert="USD"])`
# Get all available exchanges in coinmarketcap ranked by volumes with some metadata:

# %%
cmc.exchanges()
# Out:
# [{'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BitMEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'ICON',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'TRON',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'NEO',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Verge',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Qtum',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Ripple',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Binance'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'EOS',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'OKEx'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'TRON',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Huobi Token',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Arcblock',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Dash',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Huobi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'EOS',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'NEO',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Bitfinex'},
#  {'markets': [{'name': 'EOS',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ripple',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Qtum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Monero',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Bithumb'},
#  {'markets': [{'name': 'EOS',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Cardano',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Qtum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'TRON',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'NEM',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Status',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'NEO',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Upbit'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Ripple',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'EOS',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'EOS',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Kraken'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'GDAX'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Qtum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'TRON',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'EDUCare',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Nano',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'OceanChain',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Bit-Z'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'}],
#   'name': 'bitFlyer'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Ripple',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Ripple',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Bitstamp'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Verge',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Cardano',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'TRON',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Cardano',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'NEM',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Stellar',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Ripple',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Bittrex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Dash',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Zcash',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Noah Coin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bytecoin',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Monero',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'W3Coin',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'HitBTC'},
#  {'markets': [{'name': 'Qtum',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'VeChain',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Zcash',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Zcash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'NEO',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bodhi',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Profile Utility Token',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Lbank'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'QASH',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'NEO',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'QASH',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Quoine'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEM',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'NEM',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'COMSA [ETH]',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'COMSA [XEM]',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Counterparty',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Pepe Cash',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Zaif'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'MonaCoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'}],
#   'name': 'Fisco'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'}],
#   'name': 'Gemini'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Stellar',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'NEM',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Monero',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Lisk',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Poloniex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'}],
#   'name': 'BTCC'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BTCBOX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Arcblock',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Medicalchain',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Pundi X [NEW]',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'CoinBene'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Qtum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'IOTA',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'}],
#   'name': 'Coinone'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Dash',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Dash',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'WEX'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEO',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'TRON',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Lisk',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Qtum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Achain',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Bytom',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Qbao',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'CoinEgg'},
#  {'markets': [{'name': 'Banyan Network',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Banyan Network',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'High Performance Blockchain',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'High Performance Blockchain',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'CPChain',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Gifto',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'CPChain',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'BitClave',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'BitClave',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'CRYPTO20',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Bibox'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'MonaCoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'MonaCoin',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'}],
#   'name': 'Bitbank'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'}],
#   'name': 'CoinsBank'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Qtum',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Hshare',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'BitShares',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'ZB.COM'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
# ...
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Golem',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Lunyr',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'SingularDTV',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'TokenCard',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Swarm City',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Etheroll',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Melon',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'Numeraire',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Edgeless',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'CryptoDerivatives'},
#  {'markets': [{'name': 'GBCGoldCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'BriaCoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'}],
#   'name': 'Ore.Bz'},
#  {'markets': [{'name': 'Litecoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Photon',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Blakecoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Blakecoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Photon',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'ColossusCoinXT',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'}],
#   'name': 'C-Patex'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Rippex'},
#  {'markets': [{'name': 'SuperNET',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'CHIPS',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Zcash',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Crown',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Hush',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Denarius',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'}],
#   'name': 'BarterDEX'},
#  {'markets': [{'name': 'Karma',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Steem',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Peerplays',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Steem',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Peerplays',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Golos',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'}],
#   'name': 'RuDEX'},
#  {'markets': [{'name': 'Datacoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Anoncoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Cryptonite',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Freicoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'WhiteCoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'}],
#   'name': 'FreiExchange'},
#  {'markets': [{'name': 'GoldMint',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Revain',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'}],
#   'name': 'Simex'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Lisk',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'PIVX',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Waves',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/USDT',
#     'percent_volume': 2.82,
#     'price': 64.0946,
#     'volume': 43922000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_USDT'},
#    {'name': 'NEM',
#     'pair': 'XVG/BTC',
#     'percent_volume': 2.73,
#     'price': 0.0352082,
#     'volume': 42531300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=XVG_BTC'},
#    {'name': 'Dash',
#     'pair': 'QTUM/BTC',
#     'percent_volume': 2.17,
#     'price': 17.821,
#     'volume': 33762400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=QTUM_BTC'}],
#   'name': 'Coinbe'},
#  {'markets': [{'name': 'SnakeEyes',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Burst Asset Exchange'},
#  {'markets': [{'name': 'Siacoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'}],
#   'name': 'BITHOLIC'},
#  {'markets': [{'name': 'YashCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'SACoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'DC-Ex'},
#  {'markets': [{'name': 'CRTCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'}],
#   'name': 'NIX-E'},
#  {'markets': [{'name': 'LEOcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'LEOcoin',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'LEOcoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'LEOcoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'}],
#   'name': 'LEOxChange'},
#  {'markets': [{'name': 'HEAT',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8323.5,
#     'volume': 3160890000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bismuth',
#     'pair': 'BTC/USDT',
#     'percent_volume': 22.59,
#     'price': 8345.31,
#     'volume': 352135000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Golem',
#     'pair': 'ICX/BTC',
#     'percent_volume': 8.04,
#     'price': 3.91294,
#     'volume': 125337000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ICX_BTC'},
#    {'name': 'FIMKrypto',
#     'pair': 'ETH/BTC',
#     'percent_volume': 4.43,
#     'price': 513.288,
#     'volume': 68973500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Elastic',
#     'pair': 'ETH/USDT',
#     'percent_volume': 3.72,
#     'price': 512.276,
#     'volume': 58023400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Elastic',
#     'pair': 'EOS/BTC',
#     'percent_volume': 3.55,
#     'price': 6.65192,
#     'volume': 55394400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=EOS_BTC'},
#    {'name': 'HEAT',
#     'pair': 'TRX/BTC',
#     'percent_volume': 3.2,
#     'price': 0.035959,
#     'volume': 49852800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=TRX_BTC'}],
#   'name': 'Heat Wallet'}]

# %%
show_page("exchanges/volume/24-hour")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/exchanges/volume/24-hour"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# > If you want to connect with exchanges see [`ccxt` library](https://github.com/ccxt/ccxt).

# %% [markdown]
# #### `tokens([convert="USD"])`
# Get platforms tokens data:

# %%
cmc.tokens()
# Out:
# [{'circulating_supply': 746598237.399,
#   'market_cap': 5048915376.3,
#   'name': 'EOS',
#   'platform': 'Ethereum',
#   'price': 6.76256,
#   'symbol': 'EOS',
#   'volume_24h': 980808000.0},
#  {'circulating_supply': 65748192475.5,
#   'market_cap': 2357881403.01,
#   'name': 'TRON',
#   'platform': 'Ethereum',
#   'price': 0.0358623,
#   'symbol': 'TRX',
#   'volume_24h': 199154000.0},
#  {'circulating_supply': 2287140813.52,
#   'market_cap': 2289999739.54,
#   'name': 'Tether',
#   'platform': 'Omni',
#   'price': 1.00125,
#   'symbol': 'USDT',
#   'volume_24h': 2048860000.0},
#  {'circulating_supply': 517784184.607,
#   'market_cap': 1684900803.76,
#   'name': 'VeChain',
#   'platform': 'Ethereum',
#   'price': 3.25406,
#   'symbol': 'VEN',
#   'volume_24h': 56726900.0},
#  {'circulating_supply': 387042512.048,
#   'market_cap': 1513649726.54,
#   'name': 'ICON',
#   'platform': 'Ethereum',
#   'price': 3.91081,
#   'symbol': 'ICX',
#   'volume_24h': 158823000.0},
#  {'circulating_supply': 102042551.763,
#   'market_cap': 1086314393.31,
#   'name': 'OmiseGO',
#   'platform': 'Ethereum',
#   'price': 10.6457,
#   'symbol': 'OMG',
#   'volume_24h': 28735100.0},
#  {'circulating_supply': 99014000.0,
#   'market_cap': 983899147.58,
#   'name': 'Binance Coin',
#   'platform': 'Ethereum',
#   'price': 9.93697,
#   'symbol': 'BNB',
#   'volume_24h': 79773000.0},
#  {'circulating_supply': 2000000.0,
#   'market_cap': 690894000.0,
#   'name': 'DigixDAO',
#   'platform': 'Ethereum',
#   'price': 345.447,
#   'symbol': 'DGD',
#   'volume_24h': 25505900.0},
#  {'circulating_supply': 37004026.8944,
#   'market_cap': 518122983.77,
#   'name': 'Populous',
#   'platform': 'Ethereum',
#   'price': 14.0018,
#   'symbol': 'PPT',
#   'volume_24h': 1398720.0},
#  {'circulating_supply': 618227.770106,
#   'market_cap': 415103472.188,
#   'name': 'Maker',
#   'platform': 'Ethereum',
#   'price': 671.441,
#   'symbol': 'MKR',
#   'volume_24h': 150150.0},
#  {'circulating_supply': 359478522.92,
#   'market_cap': 384516202.041,
#   'name': 'RChain',
#   'platform': 'Ethereum',
#   'price': 1.06965,
#   'symbol': 'RHOC',
#   'volume_24h': 538598.0},
#  {'circulating_supply': 233020472.114,
#   'market_cap': 368354101.908,
#   'name': 'Aeternity',
#   'platform': 'Ethereum',
#   'price': 1.58078,
#   'symbol': 'AE',
#   'volume_24h': 2585730.0},
#  {'circulating_supply': 11000000.0,
#   'market_cap': 365388100.0,
#   'name': 'Augur',
#   'platform': 'Ethereum',
#   'price': 33.2171,
#   'symbol': 'REP',
#   'volume_24h': 1939310.0},
#  {'circulating_supply': 3470483788.0,
#   'market_cap': 357373068.069,
#   'name': 'Status',
#   'platform': 'Ethereum',
#   'price': 0.102975,
#   'symbol': 'SNT',
#   'volume_24h': 22103700.0},
#  {'circulating_supply': 987000000.0,
#   'market_cap': 347075589.0,
#   'name': 'Bytom',
#   'platform': 'Ethereum',
#   'price': 0.351647,
#   'symbol': 'BTM',
#   'volume_24h': 13542000.0},
#  {'circulating_supply': 241236451.0,
#   'market_cap': 304795018.745,
#   'name': 'Ontology',
#   'platform': 'NEO',
#   'price': 1.26347,
#   'symbol': 'ONT',
#   'volume_24h': 23569600.0},
#  {'circulating_supply': 24898178.0,
#   'market_cap': 304395164.957,
#   'name': 'Waltonchain',
#   'platform': 'Ethereum',
#   'price': 12.2256,
#   'symbol': 'WTC',
#   'volume_24h': 3355430.0},
#  {'circulating_supply': 115319870.955,
#   'market_cap': 303980873.44,
#   'name': 'Aion',
#   'platform': 'Ethereum',
#   'price': 2.63598,
#   'symbol': 'AION',
#   'volume_24h': 11751500.0},
#  {'circulating_supply': 6605326965.64,
#   'market_cap': 286803296.848,
#   'name': 'Zilliqa',
#   'platform': 'Ethereum',
#   'price': 0.04342,
#   'symbol': 'ZIL',
#   'volume_24h': 13708600.0},
#  {'circulating_supply': 2036645.44,
#   'market_cap': 276898240.732,
#   'name': 'Veritaseum',
#   'platform': 'Ethereum',
#   'price': 135.958,
#   'symbol': 'VERI',
#   'volume_24h': 684658.0},
#  {'circulating_supply': 519515848.98,
#   'market_cap': 275228586.957,
#   'name': '0x',
#   'platform': 'Ethereum',
#   'price': 0.529779,
#   'symbol': 'ZRX',
#   'volume_24h': 6422300.0},
#  {'circulating_supply': 572074043.309,
#   'market_cap': 244411770.115,
#   'name': 'Loopring',
#   'platform': 'Ethereum',
#   'price': 0.427238,
#   'symbol': 'LRC',
#   'volume_24h': 11242700.0},
#  {'circulating_supply': 91043076.0001,
#   'market_cap': 239015387.423,
#   'name': 'KuCoin Shares',
#   'platform': 'Ethereum',
#   'price': 2.6253,
#   'symbol': 'KCS',
#   'volume_24h': 458917.0},
#  {'circulating_supply': 350000000.0,
#   'market_cap': 218784300.0,
#   'name': 'QASH',
#   'platform': 'Ethereum',
#   'price': 0.625098,
#   'symbol': 'QASH',
#   'volume_24h': 4631180.0},
#  {'circulating_supply': 9954248.20393,
#   'market_cap': 205739379.003,
#   'name': 'Gas',
#   'platform': 'NEO',
#   'price': 20.6685,
#   'symbol': 'GAS',
#   'volume_24h': 4686560.0},
#  {'circulating_supply': 35500000.0,
#   'market_cap': 203977320.0,
#   'name': 'Nebulas',
#   'platform': 'Ethereum',
#   'price': 5.74584,
#   'symbol': 'NAS',
#   'volume_24h': 9000890.0},
#  {'circulating_supply': 1000000000.0,
#   'market_cap': 196569000.0,
#   'name': 'Basic Attenti...',
#   'platform': 'Ethereum',
#   'price': 0.196569,
#   'symbol': 'BAT',
#   'volume_24h': 3949880.0},
#  {'circulating_supply': 834262000.0,
#   'market_cap': 195051289.862,
#   'name': 'Golem',
#   'platform': 'Ethereum',
#   'price': 0.233801,
#   'symbol': 'GNT',
#   'volume_24h': 5951780.0},
#  {'circulating_supply': 238421940.0,
#   'market_cap': 192783927.511,
#   'name': 'Dragonchain',
#   'platform': 'Ethereum',
#   'price': 0.808583,
#   'symbol': 'DRGN',
#   'volume_24h': 1376290.0},
#  {'circulating_supply': 75975162.3385,
#   'market_cap': 181047292.349,
#   'name': 'Ethos',
#   'platform': 'Ethereum',
#   'price': 2.38298,
#   'symbol': 'ETHOS',
#   'volume_24h': 6217290.0},
#  {'circulating_supply': 184450000.0,
#   'market_cap': 175816264.4,
#   'name': 'Revain',
#   'platform': 'Ethereum',
#   'price': 0.953192,
#   'symbol': 'R',
#   'volume_24h': 4089880.0},
#  {'circulating_supply': 4605074688.66,
#   'market_cap': 174437005.654,
#   'name': 'FunFair',
#   'platform': 'Ethereum',
#   'price': 0.0378793,
#   'symbol': 'FUN',
#   'volume_24h': 1337370.0},
#  {'circulating_supply': 134132696.93,
#   'market_cap': 159329524.048,
#   'name': 'Kyber Network',
#   'platform': 'Ethereum',
#   'price': 1.18785,
#   'symbol': 'KNC',
#   'volume_24h': 5812930.0},
#  {'circulating_supply': 8400000000.0,
#   'market_cap': 157117800.0,
#   'name': 'IOStoken',
#   'platform': 'Ethereum',
#   'price': 0.0187045,
#   'symbol': 'IOST',
#   'volume_24h': 24798400.0},
#  {'circulating_supply': 55798538.4326,
#   'market_cap': 153164198.071,
#   'name': 'SALT',
#   'platform': 'Ethereum',
#   'price': 2.74495,
#   'symbol': 'SALT',
#   'volume_24h': 9827130.0},
#  {'circulating_supply': 250000000.0,
#   'market_cap': 146826250.0,
#   'name': 'aelf',
#   'platform': 'Ethereum',
#   'price': 0.587305,
#   'symbol': 'ELF',
#   'volume_24h': 15206200.0},
#  {'circulating_supply': 74836171.09,
#   'market_cap': 136382934.918,
#   'name': 'Enigma',
#   'platform': 'Ethereum',
#   'price': 1.82242,
#   'symbol': 'ENG',
#   'volume_24h': 14262400.0},
#  {'circulating_supply': 350000000.0,
#   'market_cap': 135073750.0,
#   'name': 'ChainLink',
#   'platform': 'Ethereum',
#   'price': 0.385925,
#   'symbol': 'LINK',
#   'volume_24h': 9681860.0},
#  {'circulating_supply': 662706995.54,
#   'market_cap': 133573233.9,
#   'name': 'Request Network',
#   'platform': 'Ethereum',
#   'price': 0.201557,
#   'symbol': 'REQ',
#   'volume_24h': 5676460.0},
#  {'circulating_supply': 452552412.0,
#   'market_cap': 130594859.74,
#   'name': 'MaidSafeCoin',
#   'platform': 'Omni',
#   'price': 0.288574,
#   'symbol': 'MAID',
#   'volume_24h': 1097390.0},
#  {'circulating_supply': 756097560976.0,
#   'market_cap': 125362487.805,
#   'name': 'Kin',
#   'platform': 'Ethereum',
#   'price': 0.000165802,
#   'symbol': 'KIN',
#   'volume_24h': 339224.0},
#  {'circulating_supply': 363932946.92,
#   'market_cap': 124429402.418,
#   'name': 'Power Ledger',
#   'platform': 'Ethereum',
#   'price': 0.341902,
#   'symbol': 'POWR',
#   'volume_24h': 6773420.0},
#  {'circulating_supply': 3983937436.01,
#   'market_cap': 122476196.627,
#   'name': 'Nucleus Vision',
#   'platform': 'Ethereum',
#   'price': 0.0307425,
#   'symbol': 'NCASH',
#   'volume_24h': 14174000.0},
#  {'circulating_supply': 325226613094.0,
#   'market_cap': 121598653.143,
#   'name': 'Dentacoin',
#   'platform': 'Ethereum',
#   'price': 0.000373889,
#   'symbol': 'DCN',
#   'volume_24h': 55385.2},
#  {'circulating_supply': 239999750.0,
#   'market_cap': 117786837.305,
#   'name': 'Polymath',
#   'platform': 'Ethereum',
#   'price': 0.490779,
#   'symbol': 'POLY',
#   'volume_24h': 673507.0},
#  {'circulating_supply': 104661310.0,
#   'market_cap': 116948547.794,
#   'name': 'TenX',
#   'platform': 'Ethereum',
#   'price': 1.1174,
#   'symbol': 'PAY',
#   'volume_24h': 4570030.0},
#  {'circulating_supply': 40670871.2747,
#   'market_cap': 116186104.805,
#   'name': 'Bancor',
#   'platform': 'Ethereum',
#   'price': 2.85674,
#   'symbol': 'BNT',
#   'volume_24h': 6268800.0},
#  {'circulating_supply': 133425492.59,
#   'market_cap': 111458986.617,
#   'name': 'Storj',
#   'platform': 'Ethereum',
#   'price': 0.835365,
#   'symbol': 'STORJ',
#   'volume_24h': 8022360.0},
#  {'circulating_supply': 1445976590.33,
#   'market_cap': 110341027.631,
#   'name': 'Cindicator',
#   'platform': 'Ethereum',
#   'price': 0.076309,
#   'symbol': 'CND',
#   'volume_24h': 1425460.0},
#  {'circulating_supply': 4088853037.1,
#   'market_cap': 108614247.651,
#   'name': 'Storm',
#   'platform': 'Ethereum',
#   'price': 0.0265635,
#   'symbol': 'STORM',
#   'volume_24h': 13876500.0},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 101182400.0,
#   'name': 'Nuls',
#   'platform': 'Ethereum',
#   'price': 2.52956,
#   'symbol': 'NULS',
#   'volume_24h': 9681280.0},
#  {'circulating_supply': 99735686.8829,
#   'market_cap': 99619694.2791,
#   'name': 'Iconomi',
#   'platform': 'Ethereum',
#   'price': 0.998837,
#   'symbol': 'ICN',
#   'volume_24h': 1072620.0},
#  {'circulating_supply': 10614760961.2,
#   'market_cap': 95270239.4645,
#   'name': 'Dent',
#   'platform': 'Ethereum',
#   'price': 0.00897526,
#   'symbol': 'DENT',
#   'volume_24h': 1245970.0},
#  {'circulating_supply': 26341130.9745,
#   'market_cap': 94460876.1423,
#   'name': 'Aragon',
#   'platform': 'Ethereum',
#   'price': 3.58606,
#   'symbol': 'ANT',
#   'volume_24h': 581960.0},
#  {'circulating_supply': 5961115777.45,
#   'market_cap': 94089655.3196,
#   'name': 'THEKEY',
#   'platform': 'NEO',
#   'price': 0.0157839,
#   'symbol': 'TKY',
#   'volume_24h': 890544.0},
#  {'circulating_supply': 227384800.0,
#   'market_cap': 93732789.6408,
#   'name': 'Pillar',
#   'platform': 'Ethereum',
#   'price': 0.412221,
#   'symbol': 'PLR',
#   'volume_24h': 51145.6},
#  {'circulating_supply': 229258029.0,
#   'market_cap': 89449146.6589,
#   'name': 'SIRIN LABS Token',
#   'platform': 'Ethereum',
#   'price': 0.390168,
#   'symbol': 'SRN',
#   'volume_24h': 6972250.0},
#  {'circulating_supply': 22342464.1598,
#   'market_cap': 88673888.8806,
#   'name': 'Metal',
#   'platform': 'Ethereum',
#   'price': 3.96885,
#   'symbol': 'MTL',
#   'volume_24h': 10650400.0},
#  {'circulating_supply': 1104590.0,
#   'market_cap': 88070838.503,
#   'name': 'Gnosis',
#   'platform': 'Ethereum',
#   'price': 79.7317,
#   'symbol': 'GNO',
#   'volume_24h': 241149.0},
#  {'circulating_supply': 3726780.89997,
#   'market_cap': 87675874.7746,
#   'name': 'Genesis Vision',
#   'platform': 'Ethereum',
#   'price': 23.5259,
#   'symbol': 'GVT',
#   'volume_24h': 8491970.0},
#  {'circulating_supply': 226091448.88,
#   'market_cap': 87453755.0669,
#   'name': 'Substratum',
#   'platform': 'Ethereum',
#   'price': 0.386807,
#   'symbol': 'SUB',
#   'volume_24h': 4992260.0},
#  {'circulating_supply': 1050141509.43,
#   'market_cap': 86423495.8012,
#   'name': 'Decentraland',
#   'platform': 'Ethereum',
#   'price': 0.082297,
#   'symbol': 'MANA',
#   'volume_24h': 6350280.0},
#  {'circulating_supply': 80070793.2388,
#   'market_cap': 85236960.8185,
#   'name': 'iExec RLC',
#   'platform': 'Ethereum',
#   'price': 1.06452,
#   'symbol': 'RLC',
#   'volume_24h': 1177150.0},
#  {'circulating_supply': 521710039.585,
#   'market_cap': 84658409.8336,
#   'name': 'SingularityNET',
#   'platform': 'Ethereum',
#   'price': 0.162271,
#   'symbol': 'AGI',
#   'volume_24h': 1118800.0},
#  {'circulating_supply': 1189228953.0,
#   'market_cap': 83841235.801,
#   'name': 'Dynamic Tradi...',
#   'platform': 'Ethereum',
#   'price': 0.0705005,
#   'symbol': 'DTR',
#   'volume_24h': 9723.49},
#  {'circulating_supply': 617314170.819,
#   'market_cap': 83155922.6943,
#   'name': 'Quantstamp',
#   'platform': 'Ethereum',
#   'price': 0.134706,
#   'symbol': 'QSP',
#   'volume_24h': 4938500.0},
#  {'circulating_supply': 588083732.0,
#   'market_cap': 82017685.7671,
#   'name': 'Theta Token',
#   'platform': 'Ethereum',
#   'price': 0.139466,
#   'symbol': 'THETA',
#   'volume_24h': 9549240.0},
#  {'circulating_supply': 342699966.0,
#   'market_cap': 82006731.0639,
#   'name': 'Civic',
#   'platform': 'Ethereum',
#   'price': 0.239296,
#   'symbol': 'CVC',
#   'volume_24h': 5189900.0},
#  {'circulating_supply': 756192535.064,
#   'market_cap': 80759094.1673,
#   'name': 'Enjin Coin',
#   'platform': 'Ethereum',
#   'price': 0.106797,
#   'symbol': 'ENJ',
#   'volume_24h': 7446480.0},
#  {'circulating_supply': 236481167.798,
#   'market_cap': 79913608.0715,
#   'name': 'Genaro Network',
#   'platform': 'Ethereum',
#   'price': 0.337928,
#   'symbol': 'GNX',
#   'volume_24h': 3350460.0},
#  {'circulating_supply': 13205542.215,
#   'market_cap': 79672865.7901,
#   'name': 'Monaco',
#   'platform': 'Ethereum',
#   'price': 6.03329,
#   'symbol': 'MCO',
#   'volume_24h': 9464130.0},
#  {'circulating_supply': 2261619182.22,
#   'market_cap': 79303902.7864,
#   'name': 'Time New Bank',
#   'platform': 'Ethereum',
#   'price': 0.0350651,
#   'symbol': 'TNB',
#   'volume_24h': 4198930.0},
#  {'circulating_supply': 62660370.957,
#   'market_cap': 76588518.2133,
#   'name': 'Santiment Net...',
#   'platform': 'Ethereum',
#   'price': 1.22228,
#   'symbol': 'SAN',
#   'volume_24h': 2071410.0},
#  {'circulating_supply': 50168936.0,
#   'market_cap': 74262065.8246,
#   'name': 'Raiden Networ...',
#   'platform': 'Ethereum',
#   'price': 1.48024,
#   'symbol': 'RDN',
#   'volume_24h': 6479260.0},
#  {'circulating_supply': 761143950.0,
#   'market_cap': 72950852.4006,
#   'name': 'Ignis',
#   'platform': 'Ardor',
#   'price': 0.0958437,
#   'symbol': 'IGNIS',
#   'volume_24h': 994851.0},
#  {'circulating_supply': 492954537.351,
#   'market_cap': 71168832.4664,
#   'name': 'WAX',
#   'platform': 'Ethereum',
#   'price': 0.144372,
#   'symbol': 'WAX',
#   'volume_24h': 1680110.0},
#  {'circulating_supply': 22216600.0,
#   'market_cap': 70437952.466,
#   'name': 'High Performa...',
#   'platform': 'Ethereum',
#   'price': 3.17051,
#   'symbol': 'HPB',
#   'volume_24h': 9032220.0},
#  {'circulating_supply': 136458571.601,
#   'market_cap': 70145573.5214,
#   'name': 'Credits',
#   'platform': 'Ethereum',
#   'price': 0.514043,
#   'symbol': 'CS',
#   'volume_24h': 1811830.0},
#  {'circulating_supply': 2236813969.0,
#   'market_cap': 69326693.7482,
#   'name': 'Po.et',
#   'platform': 'Ethereum',
#   'price': 0.0309935,
#   'symbol': 'POE',
#   'volume_24h': 3085440.0},
#  {'circulating_supply': 103244552.962,
#   'market_cap': 66557117.2897,
#   'name': 'DEW',
#   'platform': 'Ethereum',
#   'price': 0.644655,
#   'symbol': 'DEW',
#   'volume_24h': 165218.0},
#  {'circulating_supply': 82500000.0,
#   'market_cap': 64628850.0,
#   'name': 'PayPie',
#   'platform': 'Ethereum',
#   'price': 0.78338,
#   'symbol': 'PPP',
#   'volume_24h': 62634.5},
#  {'circulating_supply': 92825625.9878,
#   'market_cap': 62169684.5285,
#   'name': 'Arcblock',
#   'platform': 'Ethereum',
#   'price': 0.669747,
#   'symbol': 'ABT',
#   'volume_24h': 50040000.0},
#  {'circulating_supply': 105918066.049,
#   'market_cap': 61348061.6096,
#   'name': 'Bibox Token',
#   'platform': 'Ethereum',
#   'price': 0.579203,
#   'symbol': 'BIX',
#   'volume_24h': 3555260.0},
#  {'circulating_supply': 388367506.935,
#   'market_cap': 61194291.3328,
#   'name': 'Loom Network',
#   'platform': 'Ethereum',
#   'price': 0.157568,
#   'symbol': 'LOOM',
#   'volume_24h': 2708500.0},
#  {'circulating_supply': 82046297.0,
#   'market_cap': 59248666.7767,
#   'name': 'Edgeless',
#   'platform': 'Ethereum',
#   'price': 0.722137,
#   'symbol': 'EDG',
#   'volume_24h': 693273.0},
#  {'circulating_supply': 107339884.091,
#   'market_cap': 58778354.4692,
#   'name': 'Envion',
#   'platform': 'Ethereum',
#   'price': 0.547591,
#   'symbol': 'EVN',
#   'volume_24h': 48823.4},
#  {'circulating_supply': 71266926.2205,
#   'market_cap': 57923477.0904,
#   'name': 'Oyster',
#   'platform': 'Ethereum',
#   'price': 0.812768,
#   'symbol': 'PRL',
#   'volume_24h': 444526.0},
#  {'circulating_supply': 27648200.0,
#   'market_cap': 56626278.42,
#   'name': 'Fusion',
#   'platform': 'Ethereum',
#   'price': 2.0481,
#   'symbol': 'FSN',
#   'volume_24h': 1056240.0},
#  {'circulating_supply': 73430701.0,
#   'market_cap': 56158404.9415,
#   'name': 'AdEx',
#   'platform': 'Ethereum',
#   'price': 0.764781,
#   'symbol': 'ADX',
#   'volume_24h': 6705230.0},
#  {'circulating_supply': 6274940000.0,
#   'market_cap': 55497075.3456,
#   'name': 'Cube',
#   'platform': 'Ethereum',
#   'price': 0.00884424,
#   'symbol': 'AUTO',
#   'volume_24h': 923862.0},
#  {'circulating_supply': 48602869.08,
#   'market_cap': 53791711.383,
#   'name': 'IoT Chain',
#   'platform': 'Ethereum',
#   'price': 1.10676,
#   'symbol': 'ITC',
#   'volume_24h': 8365140.0},
#  {'circulating_supply': 600149827.253,
#   'market_cap': 52957820.9066,
#   'name': 'CyberMiles',
#   'platform': 'Ethereum',
#   'price': 0.088241,
#   'symbol': 'CMT',
#   'volume_24h': 12723200.0},
#  {'circulating_supply': 2966384100.0,
#   'market_cap': 52604669.0758,
#   'name': 'MediBloc',
#   'platform': 'Qtum',
#   'price': 0.0177336,
#   'symbol': 'MED',
#   'volume_24h': 980388.0},
#  {'circulating_supply': 952176609.766,
#   'market_cap': 52320581.2241,
#   'name': 'Leadcoin',
#   'platform': 'Ethereum',
#   'price': 0.0549484,
#   'symbol': 'LDC',
#   'volume_24h': 6242780.0},
#  {'circulating_supply': 300056960.0,
#   'market_cap': 52057782.1613,
#   'name': 'Scry.info',
#   'platform': 'Ethereum',
#   'price': 0.173493,
#   'symbol': 'DDD',
#   'volume_24h': 193441.0},
#  {'circulating_supply': 191773780.972,
#   'market_cap': 51497588.7258,
#   'name': 'SophiaTX',
#   'platform': 'Ethereum',
#   'price': 0.268533,
#   'symbol': 'SPHTX',
#   'volume_24h': 113349.0},
#  {'circulating_supply': 39528904.9307,
#   'market_cap': 50898208.5669,
#   'name': 'CRYPTO20',
#   'platform': 'Ethereum',
#   'price': 1.28762,
#   'symbol': 'C20',
#   'volume_24h': 2760790.0},
#  {'circulating_supply': 1082449025.85,
#   'market_cap': 50688706.4927,
#   'name': 'ETHLend',
#   'platform': 'Ethereum',
#   'price': 0.0468278,
#   'symbol': 'LEND',
#   'volume_24h': 1718250.0},
#  {'circulating_supply': 483511857.017,
#   'market_cap': 50575340.244,
#   'name': 'MediShares',
#   'platform': 'Ethereum',
#   'price': 0.1046,
#   'symbol': 'MDS',
#   'volume_24h': 5844140.0},
#  {'circulating_supply': 165000000.0,
#   'market_cap': 49473765.0,
#   'name': 'Bluzelle',
#   'platform': 'Ethereum',
#   'price': 0.299841,
#   'symbol': 'BLZ',
#   'volume_24h': 4713580.0},
#  {'circulating_supply': 39614424.814,
#   'market_cap': 48594618.7751,
#   'name': 'Pundi X [OLD]',
#   'platform': 'Ethereum',
#   'price': 1.22669,
#   'symbol': 'PXS',
#   'volume_24h': 264396.0},
#  {'circulating_supply': 1531433921.3,
#   'market_cap': 47926377.7106,
#   'name': 'BLOCKv',
#   'platform': 'Ethereum',
#   'price': 0.0312951,
#   'symbol': 'VEE',
#   'volume_24h': 1624000.0},
#  {'circulating_supply': 288515752.98,
#   'market_cap': 47344281.0011,
#   'name': 'OST',
#   'platform': 'Ethereum',
#   'price': 0.164096,
#   'symbol': 'OST',
#   'volume_24h': 3938480.0},
#  {'circulating_supply': 29261461.2776,
#   'market_cap': 46597999.2407,
#   'name': 'Eidoo',
#   'platform': 'Ethereum',
#   'price': 1.59247,
#   'symbol': 'EDO',
#   'volume_24h': 6398140.0},
#  {'circulating_supply': 28101791527.3,
#   'market_cap': 46467155.3441,
#   'name': 'Telcoin',
#   'platform': 'Ethereum',
#   'price': 0.00165353,
#   'symbol': 'TEL',
#   'volume_24h': 380293.0},
#  {'circulating_supply': 677154514.0,
#   'market_cap': 45450610.9797,
#   'name': 'Streamr DATAcoin',
#   'platform': 'Ethereum',
#   'price': 0.06712,
#   'symbol': 'DATA',
#   'volume_24h': 125362.0},
#  {'circulating_supply': 359600000.0,
#   'market_cap': 45213586.8,
#   'name': 'SONM',
#   'platform': 'Ethereum',
#   'price': 0.125733,
#   'symbol': 'SNM',
#   'volume_24h': 835102.0},
#  {'circulating_supply': 489033039.761,
#   'market_cap': 44944092.4862,
#   'name': 'Ripio Credit ...',
#   'platform': 'Ethereum',
#   'price': 0.091904,
#   'symbol': 'RCN',
#   'volume_24h': 7428950.0},
#  {'circulating_supply': 543348500.0,
#   'market_cap': 43294551.8285,
#   'name': 'Red Pulse',
#   'platform': 'NEO',
#   'price': 0.079681,
#   'symbol': 'RPX',
#   'volume_24h': 1933870.0},
#  {'circulating_supply': 199913906.56,
#   'market_cap': 43198796.3268,
#   'name': 'VIBE',
#   'platform': 'Ethereum',
#   'price': 0.216087,
#   'symbol': 'VIBE',
#   'volume_24h': 2321250.0},
#  {'circulating_supply': 52000000.0,
#   'market_cap': 43155684.0,
#   'name': 'Quantum Resis...',
#   'platform': 'Ethereum',
#   'price': 0.829917,
#   'symbol': 'QRL',
#   'volume_24h': 456979.0},
#  {'circulating_supply': 77981576.9896,
#   'market_cap': 42248156.9472,
#   'name': 'Crypterium',
#   'platform': 'Ethereum',
#   'price': 0.541771,
#   'symbol': 'CRPT',
#   'volume_24h': 103864.0},
#  {'circulating_supply': 57672338.0,
#   'market_cap': 41893070.9785,
#   'name': 'NAGA',
#   'platform': 'Ethereum',
#   'price': 0.726398,
#   'symbol': 'NGC',
#   'volume_24h': 130860.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 41602650.0,
#   'name': 'Jibrel Network',
#   'platform': 'Ethereum',
#   'price': 0.277351,
#   'symbol': 'JNT',
#   'volume_24h': 564753.0},
#  {'circulating_supply': 8146000.7794,
#   'market_cap': 41094781.8119,
#   'name': 'TaaS',
#   'platform': 'Ethereum',
#   'price': 5.04478,
#   'symbol': 'TAAS',
#   'volume_24h': 177122.0},
#  {'circulating_supply': 1413716693.85,
#   'market_cap': 40761834.8054,
#   'name': 'SmartMesh',
#   'platform': 'Ethereum',
#   'price': 0.0288331,
#   'symbol': 'SMT',
#   'volume_24h': 4411140.0},
#  {'circulating_supply': 89708333.0,
#   'market_cap': 40666402.0989,
#   'name': 'Wings',
#   'platform': 'Ethereum',
#   'price': 0.453318,
#   'symbol': 'WINGS',
#   'volume_24h': 1848780.0},
#  {'circulating_supply': 514991706.617,
#   'market_cap': 40610289.0153,
#   'name': 'SpaceChain',
#   'platform': 'Qtum',
#   'price': 0.0788562,
#   'symbol': 'SPC',
#   'volume_24h': 31551.4},
#  {'circulating_supply': 599400.0,
#   'market_cap': 40374145.44,
#   'name': 'Melon',
#   'platform': 'Ethereum',
#   'price': 67.3576,
#   'symbol': 'MLN',
#   'volume_24h': 341838.0},
#  {'circulating_supply': 900000000.0,
#   'market_cap': 40318200.0,
#   'name': 'DeepBrain Chain',
#   'platform': 'NEO',
#   'price': 0.044798,
#   'symbol': 'DBC',
#   'volume_24h': 2666180.0},
#  {'circulating_supply': 4254336773.4,
#   'market_cap': 40252364.8382,
#   'name': 'DATA',
#   'platform': 'Ethereum',
#   'price': 0.00946149,
#   'symbol': 'DTA',
#   'volume_24h': 7361440.0},
#  {'circulating_supply': 285885272.987,
#   'market_cap': 39814384.313,
#   'name': 'UTRUST',
#   'platform': 'Ethereum',
#   'price': 0.139267,
#   'symbol': 'UTK',
#   'volume_24h': 2029560.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 39766200.0,
#   'name': 'AirSwap',
#   'platform': 'Ethereum',
#   'price': 0.265108,
#   'symbol': 'AST',
#   'volume_24h': 3969020.0},
#  {'circulating_supply': 144590975.0,
#   'market_cap': 39400317.7326,
#   'name': 'Ambrosus',
#   'platform': 'Ethereum',
#   'price': 0.272495,
#   'symbol': 'AMB',
#   'volume_24h': 584393.0},
#  {'circulating_supply': 254507605.599,
#   'market_cap': 39126726.7468,
#   'name': 'OriginTrail',
#   'platform': 'Ethereum',
#   'price': 0.153735,
#   'symbol': 'TRAC',
#   'volume_24h': 272834.0},
#  {'circulating_supply': 183000000.0,
#   'market_cap': 38901957.0,
#   'name': 'Wagerr',
#   'platform': 'Waves',
#   'price': 0.212579,
#   'symbol': 'WGR',
#   'volume_24h': 64859.8},
#  {'circulating_supply': 18266200.0,
#   'market_cap': 38323583.572,
#   'name': 'Modum',
#   'platform': 'Ethereum',
#   'price': 2.09806,
#   'symbol': 'MOD',
#   'volume_24h': 935962.0},
#  {'circulating_supply': 157861326.54,
#   'market_cap': 38113880.8185,
#   'name': 'Gifto',
#   'platform': 'Ethereum',
#   'price': 0.241439,
#   'symbol': 'GTO',
#   'volume_24h': 6072640.0},
#  {'circulating_supply': 300043386.0,
#   'market_cap': 37961789.2401,
#   'name': 'SpankChain',
#   'platform': 'Ethereum',
#   'price': 0.126521,
#   'symbol': 'SPANK',
#   'volume_24h': 149607.0},
#  {'circulating_supply': 100054311.845,
#   'market_cap': 37638931.3014,
#   'name': 'AppCoins',
#   'platform': 'Ethereum',
#   'price': 0.376185,
#   'symbol': 'APPC',
#   'volume_24h': 3132550.0},
#  {'circulating_supply': 98028877.0,
#   'market_cap': 37150101.5456,
#   'name': 'MobileGo',
#   'platform': 'Ethereum',
#   'price': 0.378971,
#   'symbol': 'MGO',
#   'volume_24h': 185819.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 36571860.0,
#   'name': 'SingularDTV',
#   'platform': 'Ethereum',
#   'price': 0.0609531,
#   'symbol': 'SNGLS',
#   'volume_24h': 610402.0},
#  {'circulating_supply': 355419546.26,
#   'market_cap': 36536773.936,
#   'name': 'Bottos',
#   'platform': 'Ethereum',
#   'price': 0.102799,
#   'symbol': 'BTO',
#   'volume_24h': 258597.0},
#  {'circulating_supply': 45248032.811,
#   'market_cap': 36047614.5554,
#   'name': 'WaBi',
#   'platform': 'Ethereum',
#   'price': 0.796667,
#   'symbol': 'WABI',
#   'volume_24h': 2660350.0},
#  {'circulating_supply': 1710945602.83,
#   'market_cap': 35051458.1869,
#   'name': 'Universa',
#   'platform': 'Ethereum',
#   'price': 0.0204866,
#   'symbol': 'UTNP',
#   'volume_24h': 6244.4},
#  {'circulating_supply': 1080963623.05,
#   'market_cap': 34902045.3646,
#   'name': 'Soarcoin',
#   'platform': 'Ethereum',
#   'price': 0.0322879,
#   'symbol': 'SOAR',
#   'volume_24h': 9935.72},
#  {'circulating_supply': 74388399.693,
#   'market_cap': 34890539.8848,
#   'name': 'Bread',
#   'platform': 'Ethereum',
#   'price': 0.469032,
#   'symbol': 'BRD',
#   'volume_24h': 1199510.0},
#  {'circulating_supply': 264520250.59,
#   'market_cap': 34765896.535,
#   'name': 'Rock',
#   'platform': 'Ethereum',
#   'price': 0.13143,
#   'symbol': 'RKT',
#   'volume_24h': 81135.9},
#  {'circulating_supply': 333333333.0,
#   'market_cap': 33989999.966,
#   'name': 'Trinity Netwo...',
#   'platform': 'NEO',
#   'price': 0.10197,
#   'symbol': 'TNC',
#   'volume_24h': 325670.0},
#  {'circulating_supply': 399936258.54,
#   'market_cap': 33935431.4032,
#   'name': 'indaHash',
#   'platform': 'Ethereum',
#   'price': 0.0848521,
#   'symbol': 'IDH',
#   'volume_24h': 337828.0},
#  {'circulating_supply': 358695652.008,
#   'market_cap': 33495753.2454,
#   'name': 'Cobinhood',
#   'platform': 'Ethereum',
#   'price': 0.0933821,
#   'symbol': 'COB',
#   'volume_24h': 757.193},
#  {'circulating_supply': 463910526.92,
#   'market_cap': 32905080.8923,
#   'name': 'Ink',
#   'platform': 'Qtum',
#   'price': 0.0709298,
#   'symbol': 'INK',
#   'volume_24h': 924324.0},
#  {'circulating_supply': 37458337.4784,
#   'market_cap': 32554179.5607,
#   'name': 'Delphy',
#   'platform': 'Ethereum',
#   'price': 0.869077,
#   'symbol': 'DPY',
#   'volume_24h': 1072850.0},
#  {'circulating_supply': 28007978.7671,
#   'market_cap': 32437720.6889,
#   'name': 'INS Ecosystem',
#   'platform': 'Ethereum',
#   'price': 1.15816,
#   'symbol': 'INS',
#   'volume_24h': 7474070.0},
#  {'circulating_supply': 69753450.3418,
#   'market_cap': 32352208.2961,
#   'name': 'BlockMason Cr...',
#   'platform': 'Ethereum',
#   'price': 0.463808,
#   'symbol': 'BCPT',
#   'volume_24h': 4893740.0},
#  {'circulating_supply': 402249875.194,
#   'market_cap': 31309843.0855,
#   'name': 'WePower',
#   'platform': 'Ethereum',
#   'price': 0.0778368,
#   'symbol': 'WPR',
#   'volume_24h': 3554890.0},
#  {'circulating_supply': 444809322.646,
#   'market_cap': 30784541.5254,
#   'name': 'KickCoin',
#   'platform': 'Ethereum',
#   'price': 0.0692084,
#   'symbol': 'KICK',
#   'volume_24h': 5149650.0},
#  {'circulating_supply': 100728564.0,
#   'market_cap': 30663890.1814,
#   'name': 'Synereo',
#   'platform': 'Omni',
#   'price': 0.304421,
#   'symbol': 'AMP',
#   'volume_24h': 1354100.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 29351100.0,
#   'name': 'district0x',
#   'platform': 'Ethereum',
#   'price': 0.0489185,
#   'symbol': 'DNT',
#   'volume_24h': 1947860.0},
#  {'circulating_supply': 376657502.4,
#   'market_cap': 29258754.7864,
#   'name': 'Mobius',
#   'platform': 'Stellar',
#   'price': 0.07768,
#   'symbol': 'MOBI',
#   'volume_24h': 112617.0},
#  {'circulating_supply': 68000000.0,
#   'market_cap': 29231908.0,
#   'name': 'Centra',
#   'platform': 'Ethereum',
#   'price': 0.429881,
#   'symbol': 'CTR',
#   'volume_24h': 12849800.0},
#  {'circulating_supply': 285319403.561,
#   'market_cap': 29169914.5424,
#   'name': 'IHT Real Esta...',
#   'platform': 'Ethereum',
#   'price': 0.102236,
#   'symbol': 'IHT',
#   'volume_24h': 6145010.0},
#  {'circulating_supply': 428481269.499,
#   'market_cap': 28989971.4912,
#   'name': 'Tierion',
#   'platform': 'Ethereum',
#   'price': 0.0676575,
#   'symbol': 'TNT',
#   'volume_24h': 3700800.0},
#  {'circulating_supply': 162862944.036,
#   'market_cap': 28667298.2721,
#   'name': 'Humaniq',
#   'platform': 'Ethereum',
#   'price': 0.176021,
#   'symbol': 'HMQ',
#   'volume_24h': 289283.0},
#  {'circulating_supply': 485519252.554,
#   'market_cap': 28581207.4959,
#   'name': 'Etherparty',
#   'platform': 'Ethereum',
#   'price': 0.0588673,
#   'symbol': 'FUEL',
#   'volume_24h': 746390.0},
#  {'circulating_supply': 155000000.0,
#   'market_cap': 28206590.0,
#   'name': 'Presearch',
#   'platform': 'Ethereum',
#   'price': 0.181978,
#   'symbol': 'PRE',
#   'volume_24h': 81957.2},
#  {'circulating_supply': 162441000.0,
#   'market_cap': 28162721.052,
#   'name': 'bitCNY',
#   'platform': 'BitShares',
#   'price': 0.173372,
#   'symbol': 'BITCNY',
#   'volume_24h': 6493050.0},
#  {'circulating_supply': 32105577.5103,
#   'market_cap': 27827669.8349,
#   'name': 'Triggers',
#   'platform': 'Counterparty',
#   'price': 0.866755,
#   'symbol': 'TRIG',
#   'volume_24h': 3423080.0},
#  {'circulating_supply': 551151846.208,
#   'market_cap': 27527885.2259,
#   'name': 'Game.com',
#   'platform': 'Ethereum',
#   'price': 0.0499461,
#   'symbol': 'GTC',
#   'volume_24h': 2637610.0},
#  {'circulating_supply': 60175727.0296,
#   'market_cap': 27417746.155,
#   'name': 'Havven',
#   'platform': 'Ethereum',
#   'price': 0.455628,
#   'symbol': 'HAV',
#   'volume_24h': 674152.0},
#  {'circulating_supply': 226715852.267,
#   'market_cap': 26211299.8281,
#   'name': 'CPChain',
#   'platform': 'Ethereum',
#   'price': 0.115613,
#   'symbol': 'CPC',
#   'volume_24h': 6580340.0},
#  {'circulating_supply': 656923039.17,
#   'market_cap': 25918044.5105,
#   'name': 'Blox',
#   'platform': 'Ethereum',
#   'price': 0.0394537,
#   'symbol': 'CDT',
#   'volume_24h': 503997.0},
#  {'circulating_supply': 24874855.2824,
#   'market_cap': 25134797.5201,
#   'name': 'TokenCard',
#   'platform': 'Ethereum',
#   'price': 1.01045,
#   'symbol': 'TKN',
#   'volume_24h': 169206.0},
#  {'circulating_supply': 141022371.35,
#   'market_cap': 25033022.1607,
#   'name': 'Unikoin Gold',
#   'platform': 'Ethereum',
#   'price': 0.177511,
#   'symbol': 'UKG',
#   'volume_24h': 1105580.0},
#  {'circulating_supply': 375000000.0,
#   'market_cap': 24463312.5,
#   'name': 'Hive Project',
#   'platform': 'Ethereum',
#   'price': 0.0652355,
#   'symbol': 'HVN',
#   'volume_24h': 195974.0},
#  {'circulating_supply': 32025998.4158,
#   'market_cap': 23984142.1096,
#   'name': 'Decision Token',
#   'platform': 'Ethereum',
#   'price': 0.748896,
#   'symbol': 'HST',
#   'volume_24h': 76545.8},
#  {'circulating_supply': 1844678440.94,
#   'market_cap': 23976023.5682,
#   'name': 'U.CASH',
#   'platform': 'Ethereum',
#   'price': 0.0129974,
#   'symbol': 'UCASH',
#   'volume_24h': 5296.31},
#  {'circulating_supply': 701884009.0,
#   'market_cap': 23863915.9292,
#   'name': 'Pepe Cash',
#   'platform': 'Counterparty',
#   'price': 0.0339998,
#   'symbol': 'PEPECASH',
#   'volume_24h': 36899.8},
#  {'circulating_supply': 2297853.07853,
#   'market_cap': 23084002.2416,
#   'name': 'Lunyr',
#   'platform': 'Ethereum',
#   'price': 10.0459,
#   'symbol': 'LUN',
#   'volume_24h': 2870930.0},
#  {'circulating_supply': 240000000.0,
#   'market_cap': 22254072.0,
#   'name': 'QLINK',
#   'platform': 'NEO',
#   'price': 0.0927253,
#   'symbol': 'QLC',
#   'volume_24h': 341350.0},
#  {'circulating_supply': 166499800.432,
#   'market_cap': 21811973.3559,
#   'name': 'Viberate',
#   'platform': 'Ethereum',
#   'price': 0.131003,
#   'symbol': 'VIB',
#   'volume_24h': 4701630.0},
#  {'circulating_supply': 217102677.83,
#   'market_cap': 21565156.3531,
#   'name': 'Monetha',
#   'platform': 'Ethereum',
#   'price': 0.0993316,
#   'symbol': 'MTH',
#   'volume_24h': 443359.0},
#  {'circulating_supply': 455483815.322,
#   'market_cap': 21553494.1411,
#   'name': 'Republic Prot...',
#   'platform': 'Ethereum',
#   'price': 0.04732,
#   'symbol': 'REN',
#   'volume_24h': 431561.0},
#  {'circulating_supply': 115125192.154,
#   'market_cap': 21457954.3153,
#   'name': 'SunContract',
#   'platform': 'Ethereum',
#   'price': 0.186388,
#   'symbol': 'SNC',
#   'volume_24h': 7083410.0},
#  {'circulating_supply': 249999999.108,
#   'market_cap': 21442624.9235,
#   'name': 'YOYOW',
#   'platform': 'BitShares',
#   'price': 0.0857705,
#   'symbol': 'YOYOW',
#   'volume_24h': 3348240.0},
#  {'circulating_supply': 325000000.0,
#   'market_cap': 21339207.5,
#   'name': 'Cofound.it',
#   'platform': 'Ethereum',
#   'price': 0.0656591,
#   'symbol': 'CFI',
#   'volume_24h': 390117.0},
#  {'circulating_supply': 293827778.0,
#   'market_cap': 21175844.7499,
#   'name': 'Zeepin',
#   'platform': 'NEO',
#   'price': 0.0720689,
#   'symbol': 'ZPT',
#   'volume_24h': 352980.0},
#  {'circulating_supply': 69060273.4618,
#   'market_cap': 21123603.9643,
#   'name': 'Bankex',
#   'platform': 'Ethereum',
#   'price': 0.305872,
#   'symbol': 'BKX',
#   'volume_24h': 759657.0},
#  {'circulating_supply': 2335624426.71,
#   'market_cap': 21037973.5299,
#   'name': 'Refereum',
#   'platform': 'Ethereum',
#   'price': 0.00900743,
#   'symbol': 'RFR',
#   'volume_24h': 513597.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 20922300.0,
#   'name': 'adToken',
#   'platform': 'Ethereum',
#   'price': 0.0348705,
#   'symbol': 'ADT',
#   'volume_24h': 3013890.0},
#  {'circulating_supply': 1543157590.0,
#   'market_cap': 20901143.662,
#   'name': 'Safe Exchange...',
#   'platform': 'Omni',
#   'price': 0.0135444,
#   'symbol': 'SAFEX',
#   'volume_24h': 11580.6},
#  {'circulating_supply': 10500000.0,
#   'market_cap': 20632815.0,
#   'name': 'Nimiq Exchang...',
#   'platform': 'Ethereum',
#   'price': 1.96503,
#   'symbol': 'NET',
#   'volume_24h': 205680.0},
#  {'circulating_supply': 82073518.6244,
#   'market_cap': 20507217.6576,
#   'name': 'Spectre.ai Di...',
#   'platform': 'Ethereum',
#   'price': 0.249864,
#   'symbol': 'SXDT',
#   'volume_24h': 29089.7},
#  {'circulating_supply': 16500000.0,
#   'market_cap': 20188740.0,
#   'name': 'Everex',
#   'platform': 'Ethereum',
#   'price': 1.22356,
#   'symbol': 'EVX',
#   'volume_24h': 2603000.0},
#  {'circulating_supply': 4660285459.8,
#   'market_cap': 20019374.6611,
#   'name': 'ATMChain',
#   'platform': 'Ethereum',
#   'price': 0.00429574,
#   'symbol': 'ATM',
#   'volume_24h': 16666.0},
#  {'circulating_supply': 831635544.99,
#   'market_cap': 19924407.5504,
#   'name': 'Datum',
#   'platform': 'Ethereum',
#   'price': 0.0239581,
#   'symbol': 'DAT',
#   'volume_24h': 2251960.0},
#  {'circulating_supply': 399742960.0,
#   'market_cap': 19681824.3272,
#   'name': 'Fortuna',
#   'platform': 'Ethereum',
#   'price': 0.0492362,
#   'symbol': 'FOTA',
#   'volume_24h': 892217.0},
#  {'circulating_supply': 100000000.0,
#   'market_cap': 19608100.0,
#   'name': 'Mercury',
#   'platform': 'Waves',
#   'price': 0.196081,
#   'symbol': 'MER',
#   'volume_24h': 996350.0},
#  {'circulating_supply': 51980933.4494,
#   'market_cap': 19517904.8535,
#   'name': 'Blockport',
#   'platform': 'Ethereum',
#   'price': 0.375482,
#   'symbol': 'BPT',
#   'volume_24h': 262281.0},
#  {'circulating_supply': 185000000.0,
#   'market_cap': 19507510.0,
#   'name': 'Medicalchain',
#   'platform': 'Ethereum',
#   'price': 0.105446,
#   'symbol': 'MTN',
#   'volume_24h': 9261750.0},
#  {'circulating_supply': 17029321.0837,
#   'market_cap': 18815867.1586,
#   'name': 'Ormeus Coin',
#   'platform': 'Ethereum',
#   'price': 1.10491,
#   'symbol': 'ORME',
#   'volume_24h': 2609000.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 18780900.0,
#   'name': 'Internet Node...',
#   'platform': 'Ethereum',
#   'price': 0.125206,
#   'symbol': 'INT',
#   'volume_24h': 2070590.0},
#  {'circulating_supply': 18268713.3635,
#   'market_cap': 18131460.52,
#   'name': 'Dai',
#   'platform': 'Ethereum',
#   'price': 0.992487,
#   'symbol': 'DAI',
#   'volume_24h': 860966.0},
#  {'circulating_supply': 1356003.01735,
#   'market_cap': 18127319.5365,
#   'name': 'Numeraire',
#   'platform': 'Ethereum',
#   'price': 13.3682,
#   'symbol': 'NMR',
#   'volume_24h': 173361.0},
#  {'circulating_supply': 10000000.0,
#   'market_cap': 17970500.0,
#   'name': 'Uquid Coin',
#   'platform': 'Ethereum',
#   'price': 1.79705,
#   'symbol': 'UQC',
#   'volume_24h': 13585.3},
#  {'circulating_supply': 390222225.333,
#   'market_cap': 17789333.7418,
#   'name': 'Datawallet',
#   'platform': 'Ethereum',
#   'price': 0.0455877,
#   'symbol': 'DXT',
#   'volume_24h': 600120.0},
#  {'circulating_supply': 85978873.0,
#   'market_cap': 17685510.2606,
#   'name': 'Agrello',
#   'platform': 'Ethereum',
#   'price': 0.205696,
#   'symbol': 'DLT',
#   'volume_24h': 10895600.0},
#  {'circulating_supply': 92147500.0,
#   'market_cap': 17637400.09,
#   'name': 'WeTrust',
#   'platform': 'Ethereum',
#   'price': 0.191404,
#   'symbol': 'TRST',
#   'volume_24h': 196417.0},
#  {'circulating_supply': 1153170765.0,
#   'market_cap': 17402845.9658,
#   'name': 'Zeusshield',
#   'platform': 'Ethereum',
#   'price': 0.0150913,
#   'symbol': 'ZSC',
#   'volume_24h': 33208.0},
#  {'circulating_supply': 575821132.878,
#   'market_cap': 17309931.8218,
#   'name': 'SwissBorg',
#   'platform': 'Ethereum',
#   'price': 0.0300613,
#   'symbol': 'CHSB',
#   'volume_24h': 203441.0},
#  {'circulating_supply': 51113355.2495,
#   'market_cap': 17283572.1708,
#   'name': 'Swarm',
#   'platform': 'Ethereum',
#   'price': 0.338142,
#   'symbol': 'SWM',
#   'volume_24h': 931.62},
#  {'circulating_supply': 2790428084.0,
#   'market_cap': 17211025.5707,
#   'name': 'Alphacat',
#   'platform': 'NEO',
#   'price': 0.00616788,
#   'symbol': 'ACAT',
#   'volume_24h': 132559.0},
#  {'circulating_supply': 329992098.47,
#   'market_cap': 16922126.8064,
#   'name': 'Cappasity',
#   'platform': 'Ethereum',
#   'price': 0.0512804,
#   'symbol': 'CAPP',
#   'volume_24h': 41750.3},
#  {'circulating_supply': 108135403.316,
#   'market_cap': 16862959.1993,
#   'name': 'Zap',
#   'platform': 'Ethereum',
#   'price': 0.155943,
#   'symbol': 'ZAP',
#   'volume_24h': 24930.7},
#  {'circulating_supply': 140000000.0,
#   'market_cap': 16840600.0,
#   'name': 'Mothership',
#   'platform': 'Ethereum',
#   'price': 0.12029,
#   'symbol': 'MSP',
#   'volume_24h': 70704.4},
#  {'circulating_supply': 1887274878.9,
#   'market_cap': 16750904.5154,
#   'name': 'Selfkey',
#   'platform': 'Ethereum',
#   'price': 0.00887571,
#   'symbol': 'KEY',
#   'volume_24h': 158277.0},
#  {'circulating_supply': 577188.478932,
#   'market_cap': 16729577.1865,
#   'name': 'ICOS',
#   'platform': 'Ethereum',
#   'price': 28.9846,
#   'symbol': 'ICOS',
#   'volume_24h': 17758.8},
#  {'circulating_supply': 6581116221.66,
#   'market_cap': 16377502.5846,
#   'name': 'Storiqa',
#   'platform': 'Ethereum',
#   'price': 0.00248856,
#   'symbol': 'STQ',
#   'volume_24h': 133176.0},
#  {'circulating_supply': 19628888.0,
#   'market_cap': 16371827.3564,
#   'name': 'Moeda Loyalty...',
#   'platform': 'Ethereum',
#   'price': 0.834068,
#   'symbol': 'MDA',
#   'volume_24h': 1027190.0},
#  {'circulating_supply': 341754517.352,
#   'market_cap': 16346733.7231,
#   'name': 'STK',
#   'platform': 'Ethereum',
#   'price': 0.0478318,
#   'symbol': 'STK',
#   'volume_24h': 2685340.0},
#  {'circulating_supply': 13000000.0,
#   'market_cap': 16200990.0,
#   'name': 'Aeron',
#   'platform': 'Ethereum',
#   'price': 1.24623,
#   'symbol': 'ARN',
#   'volume_24h': 1061680.0},
#  {'circulating_supply': 269676560.459,
#   'market_cap': 16056137.8949,
#   'name': 'Electrify.Asia',
#   'platform': 'Ethereum',
#   'price': 0.0595385,
#   'symbol': 'ELEC',
#   'volume_24h': 429044.0},
#  {'circulating_supply': 2000000000.0,
#   'market_cap': 15685480.0,
#   'name': 'Odyssey',
#   'platform': 'Ethereum',
#   'price': 0.00784274,
#   'symbol': 'OCN',
#   'volume_24h': 14301900.0},
#  {'circulating_supply': 1750000000.0,
#   'market_cap': 15670235.0,
#   'name': 'SwftCoin',
#   'platform': 'Ethereum',
#   'price': 0.00895442,
#   'symbol': 'SWFTC',
#   'volume_24h': 6439100.0},
#  {'circulating_supply': 76652327.4268,
#   'market_cap': 15532444.3681,
#   'name': 'DADI',
#   'platform': 'Ethereum',
#   'price': 0.202635,
#   'symbol': 'DADI',
#   'volume_24h': 2622780.0},
#  {'circulating_supply': 84285535.961,
#   'market_cap': 15494041.5046,
#   'name': 'Trade Token',
#   'platform': 'Ethereum',
#   'price': 0.183828,
#   'symbol': 'TIO',
#   'volume_24h': 197148.0},
#  {'circulating_supply': 65047195.1722,
#   'market_cap': 15409485.3947,
#   'name': 'COSS',
#   'platform': 'Ethereum',
#   'price': 0.236897,
#   'symbol': 'COSS',
#   'volume_24h': 810918.0},
#  {'circulating_supply': 39496568.6434,
#   'market_cap': 15395170.0087,
#   'name': 'Bloom',
#   'platform': 'Ethereum',
#   'price': 0.389785,
#   'symbol': 'BLT',
#   'volume_24h': 49724.6},
#  {'circulating_supply': 575451808.4,
#   'market_cap': 15162924.9706,
#   'name': 'QunQun',
#   'platform': 'Ethereum',
#   'price': 0.0263496,
#   'symbol': 'QUN',
#   'volume_24h': 3613840.0},
#  {'circulating_supply': 5398647405.94,
#   'market_cap': 14966886.1494,
#   'name': 'carVertical',
#   'platform': 'Ethereum',
#   'price': 0.00277234,
#   'symbol': 'CV',
#   'volume_24h': 119016.0},
#  {'circulating_supply': 77839404.0,
#   'market_cap': 14761075.3775,
#   'name': 'LATOKEN',
#   'platform': 'Ethereum',
#   'price': 0.189635,
#   'symbol': 'LA',
#   'volume_24h': 1261050.0},
#  {'circulating_supply': 421040206.297,
#   'market_cap': 14607568.9173,
#   'name': 'All Sports',
#   'platform': 'Ethereum',
#   'price': 0.034694,
#   'symbol': 'SOC',
#   'volume_24h': 3842290.0},
#  {'circulating_supply': 85558370.5,
#   'market_cap': 14514635.3218,
#   'name': 'FirstBlood',
#   'platform': 'Ethereum',
#   'price': 0.169646,
#   'symbol': '1ST',
#   'volume_24h': 101725.0},
#  {'circulating_supply': 1260000000.0,
#   'market_cap': 14477148.0,
#   'name': 'YEE',
#   'platform': 'Ethereum',
#   'price': 0.0114898,
#   'symbol': 'YEE',
#   'volume_24h': 1783050.0},
#  {'circulating_supply': 582029028.5,
#   'market_cap': 14323326.9711,
#   'name': 'Energo',
#   'platform': 'Ethereum',
#   'price': 0.0246093,
#   'symbol': 'TSL',
#   'volume_24h': 865890.0},
#  {'circulating_supply': 12756500.0,
#   'market_cap': 14245566.245,
#   'name': 'bitUSD',
#   'platform': 'BitShares',
#   'price': 1.11673,
#   'symbol': 'BITUSD',
#   'volume_24h': 622401.0},
#  {'circulating_supply': 403600000.0,
#   'market_cap': 14196105.32,
#   'name': 'Hi Mutual Soc...',
#   'platform': 'Ethereum',
#   'price': 0.0351737,
#   'symbol': 'HMC',
#   'volume_24h': 430996.0},
#  {'circulating_supply': 39236491.0,
#   'market_cap': 14069303.2333,
#   'name': 'Grid+',
#   'platform': 'Ethereum',
#   'price': 0.358577,
#   'symbol': 'GRID',
#   'volume_24h': 1009.3},
#  {'circulating_supply': 21227827.4593,
#   'market_cap': 13999200.2859,
#   'name': 'Blackmoon',
#   'platform': 'Ethereum',
#   'price': 0.659474,
#   'symbol': 'BMC',
#   'volume_24h': 980967.0},
#  {'circulating_supply': 75000000.0,
#   'market_cap': 13989150.0,
#   'name': 'Matchpool',
#   'platform': 'Ethereum',
#   'price': 0.186522,
#   'symbol': 'GUP',
#   'volume_24h': 2466390.0},
#  {'circulating_supply': 40339392.5906,
#   'market_cap': 13988249.1323,
#   'name': 'CanYaCoin',
#   'platform': 'Ethereum',
#   'price': 0.346764,
#   'symbol': 'CAN',
#   'volume_24h': 174449.0},
#  {'circulating_supply': 25009249.58,
#   'market_cap': 13976644.211,
#   'name': 'OAX',
#   'platform': 'Ethereum',
#   'price': 0.558859,
#   'symbol': 'OAX',
#   'volume_24h': 990171.0},
#  {'circulating_supply': 64936603.2047,
#   'market_cap': 13931823.5346,
#   'name': 'Paragon',
#   'platform': 'Ethereum',
#   'price': 0.214545,
#   'symbol': 'PRG',
#   'volume_24h': 77308.3},
#  {'circulating_supply': 353869198.325,
#   'market_cap': 13926593.0739,
#   'name': 'BitDegree',
#   'platform': 'Ethereum',
#   'price': 0.0393552,
#   'symbol': 'BDG',
#   'volume_24h': 45913.0},
#  {'circulating_supply': 61939166.1729,
#   'market_cap': 13673938.081,
#   'name': 'EncrypGen',
#   'platform': 'Ethereum',
#   'price': 0.220764,
#   'symbol': 'DNA',
#   'volume_24h': 41383.1},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 13613920.0,
#   'name': 'Bodhi',
#   'platform': 'Qtum',
#   'price': 0.340348,
#   'symbol': 'BOT',
#   'volume_24h': 1032290.0},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 13574520.0,
#   'name': 'Blocktix',
#   'platform': 'Ethereum',
#   'price': 0.339363,
#   'symbol': 'TIX',
#   'volume_24h': 789552.0},
#  {'circulating_supply': 65351403.0,
#   'market_cap': 13472518.4855,
#   'name': 'Qbao',
#   'platform': 'Qtum',
#   'price': 0.206155,
#   'symbol': 'QBT',
#   'volume_24h': 1835320.0},
#  {'circulating_supply': 17431790.3911,
#   'market_cap': 13382646.9601,
#   'name': 'Propy',
#   'platform': 'Ethereum',
#   'price': 0.767715,
#   'symbol': 'PRO',
#   'volume_24h': 5797840.0},
#  {'circulating_supply': 551050063.763,
#   'market_cap': 13200294.0674,
#   'name': 'Lympo',
#   'platform': 'Ethereum',
#   'price': 0.0239548,
#   'symbol': 'LYM',
#   'volume_24h': 97596.6},
#  {'circulating_supply': 127133907.724,
#   'market_cap': 13199677.9694,
#   'name': 'Xaurum',
#   'platform': 'Ethereum',
#   'price': 0.103825,
#   'symbol': 'XAUR',
#   'volume_24h': 160860.0},
#  {'circulating_supply': 142215728.19,
#   'market_cap': 12873225.5,
#   'name': 'Lamden',
#   'platform': 'Ethereum',
#   'price': 0.090519,
#   'symbol': 'TAU',
#   'volume_24h': 96212.5},
#  {'circulating_supply': 17500000.0,
#   'market_cap': 12642787.5,
#   'name': 'Covesting',
#   'platform': 'Ethereum',
#   'price': 0.722445,
#   'symbol': 'COV',
#   'volume_24h': 56903.4},
#  {'circulating_supply': 46016602.0,
#   'market_cap': 12597643.0133,
#   'name': 'Incent',
#   'platform': 'Waves',
#   'price': 0.273763,
#   'symbol': 'INCNT',
#   'volume_24h': 65000.4},
#  {'circulating_supply': 415000000.0,
#   'market_cap': 12577571.0,
#   'name': 'Restart Energ...',
#   'platform': 'Ethereum',
#   'price': 0.0303074,
#   'symbol': 'MWAT',
#   'volume_24h': 39064.7},
#  {'circulating_supply': 25000000.0,
#   'market_cap': 12563475.0,
#   'name': 'True Chain',
#   'platform': 'Ethereum',
#   'price': 0.502539,
#   'symbol': 'TRUE',
#   'volume_24h': 8281910.0},
#  {'circulating_supply': 2000000.0,
#   'market_cap': 12346000.0,
#   'name': 'Exchange Union',
#   'platform': 'Ethereum',
#   'price': 6.173,
#   'symbol': 'XUC',
#   'volume_24h': 306770.0},
#  {'circulating_supply': 30000000.0,
#   'market_cap': 12318270.0,
#   'name': 'OracleChain',
#   'platform': 'BitShares',
#   'price': 0.410609,
#   'symbol': 'OCT',
#   'volume_24h': 79122.3},
#  {'circulating_supply': 22747808.5,
#   'market_cap': 12271737.5037,
#   'name': 'Databits',
#   'platform': 'Counterparty',
#   'price': 0.539469,
#   'symbol': 'DTB',
#   'volume_24h': 13014.4},
#  {'circulating_supply': 591500000.0,
#   'market_cap': 12151302.8,
#   'name': 'DomRaider',
#   'platform': 'Ethereum',
#   'price': 0.0205432,
#   'symbol': 'DRT',
#   'volume_24h': 149272.0},
#  {'circulating_supply': 35778843.8312,
#   'market_cap': 12089850.2248,
#   'name': 'iXledger',
#   'platform': 'Ethereum',
#   'price': 0.337905,
#   'symbol': 'IXT',
#   'volume_24h': 13790.5},
#  {'circulating_supply': 404993611.0,
#   'market_cap': 12067959.1212,
#   'name': 'Snovio',
#   'platform': 'Ethereum',
#   'price': 0.0297979,
#   'symbol': 'SNOV',
#   'volume_24h': 41938.3},
#  {'circulating_supply': 1050000000.0,
#   'market_cap': 12061560.0,
#   'name': 'AirToken',
#   'platform': 'Ethereum',
#   'price': 0.0114872,
#   'symbol': 'AIR',
#   'volume_24h': 210210.0},
#  {'circulating_supply': 952429892.0,
#   'market_cap': 12009664.7232,
#   'name': 'Target Coin',
#   'platform': 'Ethereum',
#   'price': 0.0126095,
#   'symbol': 'TGT',
#   'volume_24h': 6368.63},
#  {'circulating_supply': 9969597.0,
#   'market_cap': 11936100.0082,
#   'name': 'Waves Communi...',
#   'platform': 'Waves',
#   'price': 1.19725,
#   'symbol': 'WCT',
#   'volume_24h': 52598.1},
#  {'circulating_supply': 501394405.74,
#   'market_cap': 11711219.5532,
#   'name': 'BitClave',
#   'platform': 'Ethereum',
#   'price': 0.0233573,
#   'symbol': 'CAT',
#   'volume_24h': 3933270.0},
#  {'circulating_supply': 38538647.0864,
#   'market_cap': 11710661.6129,
#   'name': 'ALIS',
#   'platform': 'Ethereum',
#   'price': 0.303868,
#   'symbol': 'ALIS',
#   'volume_24h': 16796.4},
#  {'circulating_supply': 26244468.18,
#   'market_cap': 11627244.2046,
#   'name': 'Rivetz',
#   'platform': 'Ethereum',
#   'price': 0.443036,
#   'symbol': 'RVT',
#   'volume_24h': 8474.14},
#  {'circulating_supply': 28722537.9371,
#   'market_cap': 11451245.0375,
#   'name': 'Neumark',
#   'platform': 'Ethereum',
#   'price': 0.398685,
#   'symbol': 'NEU',
#   'volume_24h': 124112.0},
#  {'circulating_supply': 120222448.767,
#   'market_cap': 11324473.784,
#   'name': 'DecentBet',
#   'platform': 'Ethereum',
#   'price': 0.094196,
#   'symbol': 'DBET',
#   'volume_24h': 74652.1},
#  {'circulating_supply': 16175575.7965,
#   'market_cap': 11248673.3402,
#   'name': 'B2BX',
#   'platform': 'Ethereum',
#   'price': 0.695411,
#   'symbol': 'B2B',
# ...
#   'volume_24h': 504041.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Animation Vis...',
#   'platform': 'Ethereum',
#   'price': 0.00794626,
#   'symbol': 'AVH',
#   'volume_24h': 471419.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'UG Token',
#   'platform': 'Ethereum',
#   'price': 0.48664,
#   'symbol': 'UGT',
#   'volume_24h': 454094.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Kcash',
#   'platform': 'Achain',
#   'price': 0.0839715,
#   'symbol': 'KCASH',
#   'volume_24h': 418472.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'FairGame',
#   'platform': 'Ethereum',
#   'price': 0.019622,
#   'symbol': 'FAIR',
#   'volume_24h': 381802.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LightChain',
#   'platform': 'Ethereum',
#   'price': 0.000892618,
#   'symbol': 'LIGHT',
#   'volume_24h': 357748.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'iQuant',
#   'platform': 'Ethereum',
#   'price': 0.0794516,
#   'symbol': 'IQT',
#   'volume_24h': 345620.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Neurotoken',
#   'platform': 'Ethereum',
#   'price': 0.352395,
#   'symbol': 'NTK',
#   'volume_24h': 330359.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'NANJCOIN',
#   'platform': 'Ethereum',
#   'price': 0.000417158,
#   'symbol': 'NANJ',
#   'volume_24h': 321161.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Molecular Future',
#   'platform': 'Ethereum',
#   'price': 0.240402,
#   'symbol': 'MOF',
#   'volume_24h': 294152.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'RefToken',
#   'platform': 'Ethereum',
#   'price': 6.06397,
#   'symbol': 'REF',
#   'volume_24h': 240643.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CFun',
#   'platform': 'Qtum',
#   'price': 0.00595082,
#   'symbol': 'CFUN',
#   'volume_24h': 220342.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ValueChain',
#   'platform': 'Ethereum',
#   'price': 0.0455905,
#   'symbol': 'VLC',
#   'volume_24h': 204960.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'InvestDigital',
#   'platform': 'Ethereum',
#   'price': 0.0445946,
#   'symbol': 'IDT',
#   'volume_24h': 200312.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ShareX',
#   'platform': 'Ethereum',
#   'price': 0.00870829,
#   'symbol': 'SEXC',
#   'volume_24h': 199487.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Dropil',
#   'platform': 'Ethereum',
#   'price': 0.0088673,
#   'symbol': 'DROP',
#   'volume_24h': 193127.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Read',
#   'platform': 'Ethereum',
#   'price': 0.0192254,
#   'symbol': 'READ',
#   'volume_24h': 192925.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maggie',
#   'platform': 'Ethereum',
#   'price': 0.0101174,
#   'symbol': 'MAG',
#   'volume_24h': 180349.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Legolas Exchange',
#   'platform': 'Ethereum',
#   'price': 0.24754,
#   'symbol': 'LGO',
#   'volume_24h': 172259.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'COMSA [ETH]',
#   'platform': 'Ethereum',
#   'price': 0.527044,
#   'symbol': 'CMS',
#   'volume_24h': 157119.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Centrality',
#   'platform': 'Ethereum',
#   'price': 0.224765,
#   'symbol': 'CENNZ',
#   'volume_24h': 130502.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Guaranteed Et...',
#   'platform': 'Ethereum',
#   'price': 0.0570137,
#   'symbol': 'GETX',
#   'volume_24h': 128402.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Content and A...',
#   'platform': 'Ethereum',
#   'price': 0.0201904,
#   'symbol': 'CAN',
#   'volume_24h': 122605.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DMarket',
#   'platform': 'Ethereum',
#   'price': 0.288556,
#   'symbol': 'DMT',
#   'volume_24h': 116376.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'MOAC',
#   'platform': 'Ethereum',
#   'price': 11.4469,
#   'symbol': 'MOAC',
#   'volume_24h': 114039.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Gems ',
#   'platform': 'Ethereum',
#   'price': 0.0126422,
#   'symbol': 'GEM',
#   'volume_24h': 104845.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LatiumX',
#   'platform': 'Ethereum',
#   'price': 0.0461312,
#   'symbol': 'LATX',
#   'volume_24h': 102497.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'COMSA [XEM]',
#   'platform': 'NEM',
#   'price': 0.529416,
#   'symbol': 'CMS',
#   'volume_24h': 92275.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sphre AIR ',
#   'platform': 'Ethereum',
#   'price': 0.138286,
#   'symbol': 'XID',
#   'volume_24h': 79677.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BigONE Token',
#   'platform': 'Ethereum',
#   'price': 1.63585,
#   'symbol': 'BIG',
#   'volume_24h': 78329.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'WETH',
#   'platform': 'Ethereum',
#   'price': 508.519,
#   'symbol': 'WETH',
#   'volume_24h': 71868.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bee Token',
#   'platform': 'Ethereum',
#   'price': 0.0845132,
#   'symbol': 'BEE',
#   'volume_24h': 66925.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'UnlimitedIP',
#   'platform': 'Ethereum',
#   'price': 0.0224045,
#   'symbol': 'UIP',
#   'volume_24h': 61784.2},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'HireMatch',
#   'platform': 'Ethereum',
#   'price': 0.0318109,
#   'symbol': 'HIRE',
#   'volume_24h': 55298.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'IPChain',
#   'platform': 'Ethereum',
#   'price': 0.530952,
#   'symbol': 'IPC',
#   'volume_24h': 52489.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Etherecash',
#   'platform': 'Ethereum',
#   'price': 0.492307,
#   'symbol': 'ECH',
#   'volume_24h': 47258.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Fluz Fluz',
#   'platform': 'Ethereum',
#   'price': 0.0906789,
#   'symbol': 'FLUZ',
#   'volume_24h': 46049.4},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'PressOne',
#   'platform': 'Ethereum',
#   'price': 0.157006,
#   'symbol': 'PRS',
#   'volume_24h': 44066.2},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Cashaa',
#   'platform': 'Ethereum',
#   'price': 0.0315042,
#   'symbol': 'CAS',
#   'volume_24h': 42017.4},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BnkToTheFuture',
#   'platform': 'Ethereum',
#   'price': 0.0744745,
#   'symbol': 'BFT',
#   'volume_24h': 40204.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ShipChain',
#   'platform': 'Ethereum',
#   'price': 0.0942275,
#   'symbol': 'SHIP',
#   'volume_24h': 33748.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maverick Chain',
#   'platform': 'Ethereum',
#   'price': 0.0432431,
#   'symbol': 'MVC',
#   'volume_24h': 31509.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Experty',
#   'platform': 'Ethereum',
#   'price': 0.166483,
#   'symbol': 'EXY',
#   'volume_24h': 24393.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ZenGold',
#   'platform': 'BitShares',
#   'price': 0.0267887,
#   'symbol': 'ZENGOLD',
#   'volume_24h': 24013.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BlockCDN',
#   'platform': 'Ethereum',
#   'price': 0.0201955,
#   'symbol': 'BCDN',
#   'volume_24h': 23506.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Mixin',
#   'platform': 'Ethereum',
#   'price': 462.103,
#   'symbol': 'XIN',
#   'volume_24h': 19415.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Titanium Bloc...',
#   'platform': 'Ethereum',
#   'price': 0.0165768,
#   'symbol': 'BAR',
#   'volume_24h': 17966.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LALA World',
#   'platform': 'Ethereum',
#   'price': 0.0418797,
#   'symbol': 'LALA',
#   'volume_24h': 14279.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'NaPoleonX',
#   'platform': 'Ethereum',
#   'price': 0.252028,
#   'symbol': 'NPX',
#   'volume_24h': 12678.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Qube',
#   'platform': 'Ethereum',
#   'price': 0.0298457,
#   'symbol': 'QUBE',
#   'volume_24h': 12354.4},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GameChain System',
#   'platform': 'Ethereum',
#   'price': 0.00658141,
#   'symbol': 'GCS',
#   'volume_24h': 10991.2},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Candy',
#   'platform': 'Ethereum',
#   'price': 0.000256126,
#   'symbol': 'CANDY',
#   'volume_24h': 9699.68},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CORION',
#   'platform': 'Ethereum Classic',
#   'price': 0.417158,
#   'symbol': 'COR',
#   'volume_24h': 7621.79},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'HOQU',
#   'platform': 'Ethereum',
#   'price': 0.0458723,
#   'symbol': 'HQX',
#   'volume_24h': 6118.57},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'IDEX Membership',
#   'platform': 'Ethereum',
#   'price': 2177.07,
#   'symbol': 'IDXM',
#   'volume_24h': 4657.59},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'OX Fina',
#   'platform': 'Ethereum',
#   'price': 0.000333727,
#   'symbol': 'OX',
#   'volume_24h': 3592.96},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'StarterCoin',
#   'platform': 'Ethereum',
#   'price': 0.0226332,
#   'symbol': 'STAC',
#   'volume_24h': 3255.05},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CryptopiaFeeS...',
#   'platform': 'Ubiq',
#   'price': 1157.05,
#   'symbol': 'CEFS',
#   'volume_24h': 3196.83},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DATx',
#   'platform': 'Ethereum',
#   'price': 0.0196757,
#   'symbol': 'DATX',
#   'volume_24h': 2363.18},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Cloud',
#   'platform': 'Ethereum',
#   'price': 0.053046,
#   'symbol': 'CLD',
#   'volume_24h': 2148.46},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Macro',
#   'platform': 'Ethereum',
#   'price': 0.657416,
#   'symbol': 'MCR',
#   'volume_24h': 2093.81},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'President Trump',
#   'platform': 'Omni',
#   'price': 0.0175181,
#   'symbol': 'PRES',
#   'volume_24h': 1795.28},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'First Bitcoin...',
#   'platform': 'Omni',
#   'price': 0.216839,
#   'symbol': 'BITCF',
#   'volume_24h': 1475.03},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Internet of T...',
#   'platform': 'Nxt',
#   'price': 1071.68,
#   'symbol': 'XOT',
#   'volume_24h': 1447.75},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'President Joh...',
#   'platform': 'Omni',
#   'price': 0.137078,
#   'symbol': 'GARY',
#   'volume_24h': 1385.56},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Alphabit',
#   'platform': 'Ethereum',
#   'price': 49.7196,
#   'symbol': 'ABC',
#   'volume_24h': 1244.55},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TeslaCoilCoin',
#   'platform': 'Omni',
#   'price': 1.09754,
#   'symbol': 'TESLA',
#   'volume_24h': 1176.39},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Ethereum Lite',
#   'platform': 'Ethereum',
#   'price': 0.298602,
#   'symbol': 'ELITE',
#   'volume_24h': 1052.03},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Minex',
#   'platform': 'Waves',
#   'price': 0.0137662,
#   'symbol': 'MINEX',
#   'volume_24h': 1039.46},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'NEO GOLD',
#   'platform': 'Ethereum',
#   'price': 0.00315615,
#   'symbol': 'NEOG',
#   'volume_24h': 400.178},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Indicoin',
#   'platform': 'Ethereum',
#   'price': 0.0116804,
#   'symbol': 'INDI',
#   'volume_24h': 362.844},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SuperNET',
#   'platform': 'Nxt',
#   'price': 90.4838,
#   'symbol': 'UNITY',
#   'volume_24h': 360.878},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'United Trader...',
#   'platform': 'Ethereum',
#   'price': 0.386096,
#   'symbol': 'UTT',
#   'volume_24h': 357.197},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Escroco',
#   'platform': 'Waves',
#   'price': 0.0722518,
#   'symbol': 'ESC',
#   'volume_24h': 339.787},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GOLD Reward T...',
#   'platform': 'Ethereum',
#   'price': 0.026135,
#   'symbol': 'GRX',
#   'volume_24h': 208.965},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Storjcoin X',
#   'platform': 'Counterparty',
#   'price': 0.762053,
#   'symbol': 'SJCX',
#   'volume_24h': 177.406},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Nitro',
#   'platform': 'Ethereum',
#   'price': 0.0896894,
#   'symbol': 'NOX',
#   'volume_24h': 156.326},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Wi Coin',
#   'platform': 'Ethereum',
#   'price': 0.00152497,
#   'symbol': 'WIC',
#   'volume_24h': 146.059},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'STEX',
#   'platform': 'Nxt',
#   'price': 0.768254,
#   'symbol': 'STEX',
#   'volume_24h': 122.418},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BTCMoon',
#   'platform': 'Ethereum',
#   'price': 0.0090445,
#   'symbol': 'BTCM',
#   'volume_24h': 115.677},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'PlexCoin',
#   'platform': 'Ethereum',
#   'price': 0.0117109,
#   'symbol': 'PLX',
#   'volume_24h': 95.7199},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BitSerial',
#   'platform': 'Ethereum',
#   'price': 0.0083241,
#   'symbol': 'BTE',
#   'volume_24h': 94.8623},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sand Coin',
#   'platform': 'Ethereum',
#   'price': 0.671708,
#   'symbol': 'SND',
#   'volume_24h': 75.9228},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SnakeEyes',
#   'platform': 'Burst',
#   'price': 0.00289439,
#   'symbol': 'SNAKE',
#   'volume_24h': 65.2222},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'HODL Bucks',
#   'platform': 'Ethereum',
#   'price': 0.0663282,
#   'symbol': 'HDLB',
#   'volume_24h': 54.6263},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'FAPcoin',
#   'platform': 'Ethereum',
#   'price': 0.00114147,
#   'symbol': 'FAP',
#   'volume_24h': 54.1444},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Smoke',
#   'platform': 'BitShares',
#   'price': 0.0624386,
#   'symbol': 'SMOKE',
#   'volume_24h': 40.0581},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ANRYZE',
#   'platform': 'Waves',
#   'price': 0.00742542,
#   'symbol': 'RYZ',
#   'volume_24h': 35.9096},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SISA',
#   'platform': 'Ethereum',
#   'price': 0.00576685,
#   'symbol': 'SISA',
#   'volume_24h': 26.312},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Natcoin',
#   'platform': 'Ethereum',
#   'price': 0.00733546,
#   'symbol': 'NTC',
#   'volume_24h': 12.0904},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EncryptoTel [...',
#   'platform': 'Ethereum',
#   'price': 0.0497251,
#   'symbol': 'ETT',
#   'volume_24h': 1.93122},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LLToken',
#   'platform': 'Ethereum',
#   'price': None,
#   'symbol': 'LLT',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Musiconomi',
#   'platform': 'Ethereum',
#   'price': 0.0432074,
#   'symbol': 'MCI',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eGold',
#   'platform': 'Ethereum',
#   'price': 0.00694441,
#   'symbol': 'EGOLD',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SpherePay',
#   'platform': 'Ethereum',
#   'price': 0.00223544,
#   'symbol': 'SAY',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Monero Gold',
#   'platform': 'Ethereum',
#   'price': 0.000185086,
#   'symbol': 'XMRG',
#   'volume_24h': None}]

# %%
show_page("tokens/views/all")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/tokens/views/all"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# _________________________________
#
# ## Graphs API
# The graphs API is used internally by coinmarketcap for display graphs info. The params `start` and `end` are passed as `datetime` objects.
#
# #### `graphs.currency(name, [start=None, end=None])`
#
# Get graphs data for a currency:

# %%
cmc.graphs.currency("BTC")
# Out:
# {'market_cap_by_available_supply': [[datetime.datetime(2013, 4, 28, 20, 47, 21),
#    1500517590],
#   [datetime.datetime(2013, 4, 29, 20, 45, 1), 1575032004],
#   [datetime.datetime(2013, 4, 30, 20, 45, 2), 1501657492],
#   [datetime.datetime(2013, 5, 1, 20, 45, 2), 1298951550],
#   [datetime.datetime(2013, 5, 2, 21, 20, 1), 1148667722],
#   [datetime.datetime(2013, 5, 3, 21, 20, 1), 1011066494],
#   [datetime.datetime(2013, 5, 4, 21, 20, 1), 1236351843],
#   [datetime.datetime(2013, 5, 5, 21, 25, 1), 1298377788],
#   [datetime.datetime(2013, 5, 6, 21, 25, 3), 1315992303],
#   [datetime.datetime(2013, 5, 7, 21, 25, 1), 1183766500],
#   [datetime.datetime(2013, 5, 8, 21, 25, 1), 1253655040],
#   [datetime.datetime(2013, 5, 9, 21, 50, 1), 1258130700],
#   [datetime.datetime(2013, 5, 10, 21, 55, 2), 1322989457],
#   [datetime.datetime(2013, 5, 11, 22, 25, 1), 1259239352],
#   [datetime.datetime(2013, 5, 12, 22, 25, 1), 1278708678],
#   [datetime.datetime(2013, 5, 13, 22, 25, 1), 1306721052],
#   [datetime.datetime(2013, 5, 14, 22, 25, 1), 1277278987],
#   [datetime.datetime(2013, 5, 15, 22, 35, 1), 1273849680],
#   [datetime.datetime(2013, 5, 16, 22, 35, 1), 1289277412],
#   [datetime.datetime(2013, 5, 17, 22, 35, 1), 1374605382],
#   [datetime.datetime(2013, 5, 18, 22, 35, 1), 1383755085],
#   [datetime.datetime(2013, 5, 19, 22, 35, 2), 1346499261],
#   [datetime.datetime(2013, 5, 20, 22, 35, 2), 1370131821],
#   [datetime.datetime(2013, 5, 21, 22, 35, 2), 1374154117],
#   [datetime.datetime(2013, 5, 22, 22, 35, 4), 1375791900],
#   [datetime.datetime(2013, 5, 23, 22, 35, 2), 1407041527],
#   [datetime.datetime(2013, 5, 24, 22, 35, 1), 1474180657],
#   [datetime.datetime(2013, 5, 25, 22, 35, 2), 1464316690],
#   [datetime.datetime(2013, 5, 26, 22, 45, 2), 1507769010],
#   [datetime.datetime(2013, 5, 27, 22, 45, 1), 1445444605],
#   [datetime.datetime(2013, 5, 28, 22, 45, 7), 1448115966],
#   [datetime.datetime(2013, 5, 29, 23, 15, 1), 1481781794],
#   [datetime.datetime(2013, 5, 30, 23, 15, 1), 1429308633],
#   [datetime.datetime(2013, 5, 31, 23, 40, 2), 1436386729],
#   [datetime.datetime(2013, 6, 1, 23, 40, 2), 1449499974],
#   [datetime.datetime(2013, 6, 3, 1, 25, 1), 1362684200],
#   [datetime.datetime(2013, 6, 4, 1, 25, 2), 1361765704],
#   [datetime.datetime(2013, 6, 5, 2, 45, 2), 1364113639],
#   [datetime.datetime(2013, 6, 6, 2, 45, 2), 1369233814],
#   [datetime.datetime(2013, 6, 7, 2, 45, 1), 1339234925],
#   [datetime.datetime(2013, 6, 8, 2, 45, 2), 1239395972],
#   [datetime.datetime(2013, 6, 9, 2, 45, 1), 1220874392],
#   [datetime.datetime(2013, 6, 10, 2, 45, 2), 1123844957],
#   [datetime.datetime(2013, 6, 11, 2, 55, 5), 1194605340],
#   [datetime.datetime(2013, 6, 12, 3, 0, 2), 1227904672],
#   [datetime.datetime(2013, 6, 13, 3, 0, 1), 1222819750],
#   [datetime.datetime(2013, 6, 14, 3, 0, 2), 1159766149],
#   [datetime.datetime(2013, 6, 15, 3, 5, 1), 1110902570],
#   [datetime.datetime(2013, 6, 16, 3, 5, 2), 1129287060],
#   [datetime.datetime(2013, 6, 17, 3, 15, 2), 1134610433],
#   [datetime.datetime(2013, 6, 18, 3, 20, 4), 1152834600],
#   [datetime.datetime(2013, 6, 19, 3, 25, 2), 1204638317],
#   [datetime.datetime(2013, 6, 20, 3, 25, 10), 1220273470],
#   [datetime.datetime(2013, 6, 21, 3, 30, 2), 1254733148],
#   [datetime.datetime(2013, 6, 22, 3, 30, 1), 1233750008],
#   [datetime.datetime(2013, 6, 23, 3, 30, 2), 1214260368],
#   [datetime.datetime(2013, 6, 24, 3, 30, 2), 1223181000],
#   [datetime.datetime(2013, 6, 25, 3, 30, 3), 1160635651],
#   [datetime.datetime(2013, 6, 26, 3, 35, 2), 1175194909],
#   [datetime.datetime(2013, 6, 27, 3, 50, 1), 1172207387],
#   [datetime.datetime(2013, 6, 28, 3, 50, 1), 1130338737],
#   [datetime.datetime(2013, 6, 29, 3, 50, 1), 1058953326],
#   [datetime.datetime(2013, 6, 30, 4, 0, 2), 1082693996],
#   [datetime.datetime(2013, 7, 1, 4, 0, 1), 1107084792],
#   [datetime.datetime(2013, 7, 2, 4, 0, 4), 1016445145],
#   [datetime.datetime(2013, 7, 3, 4, 0, 1), 1031653673],
#   [datetime.datetime(2013, 7, 4, 4, 50, 2), 895707780],
#   [datetime.datetime(2013, 7, 5, 4, 46, 1), 892405890],
#   [datetime.datetime(2013, 7, 6, 4, 46, 2), 771368060],
#   [datetime.datetime(2013, 7, 7, 4, 46, 1), 774804400],
#   [datetime.datetime(2013, 7, 8, 4, 46, 2), 882356394],
#   [datetime.datetime(2013, 7, 9, 4, 46, 2), 870081996],
#   [datetime.datetime(2013, 7, 10, 4, 46, 2), 877378425],
#   [datetime.datetime(2013, 7, 11, 5, 1, 1), 977479256],
#   [datetime.datetime(2013, 7, 12, 5, 1, 1), 1069724400],
#   [datetime.datetime(2013, 7, 13, 5, 1, 2), 1004551934],
#   [datetime.datetime(2013, 7, 14, 5, 1, 1), 1090715949],
#   [datetime.datetime(2013, 7, 15, 5, 11, 2), 1073073450],
#   [datetime.datetime(2013, 7, 16, 5, 16, 2), 1111179852],
#   [datetime.datetime(2013, 7, 17, 5, 16, 2), 1130735526],
#   [datetime.datetime(2013, 7, 18, 5, 21, 2), 1117707300],
#   [datetime.datetime(2013, 7, 19, 5, 21, 1), 1015062893],
#   [datetime.datetime(2013, 7, 20, 5, 21, 2), 1047311253],
#   [datetime.datetime(2013, 7, 21, 5, 21, 2), 1021492656],
#   [datetime.datetime(2013, 7, 22, 5, 21, 2), 1034399450],
#   [datetime.datetime(2013, 7, 23, 5, 21, 1), 1050054379],
#   [datetime.datetime(2013, 7, 24, 5, 21, 1), 1083333285],
#   [datetime.datetime(2013, 7, 25, 5, 21, 2), 1083076902],
#   [datetime.datetime(2013, 7, 26, 5, 16, 2), 1111232482],
#   [datetime.datetime(2013, 7, 27, 5, 16, 1), 1079278107],
#   [datetime.datetime(2013, 7, 28, 5, 16, 2), 1078286702],
#   [datetime.datetime(2013, 7, 29, 5, 16, 2), 1131111628],
#   [datetime.datetime(2013, 7, 30, 5, 16, 2), 1165105812],
#   [datetime.datetime(2013, 7, 31, 6, 46, 2), 1267183179],
#   [datetime.datetime(2013, 8, 1, 6, 56, 1), 1220481781],
#   [datetime.datetime(2013, 8, 2, 6, 56, 2), 1167849454],
#   [datetime.datetime(2013, 8, 3, 6, 56, 2), 1192378895],
#   [datetime.datetime(2013, 8, 4, 6, 56, 1), 1206152150],
#   [datetime.datetime(2013, 8, 5, 6, 56, 1), 1226188584],
#   [datetime.datetime(2013, 8, 6, 6, 56, 1), 1218425715],
#   [datetime.datetime(2013, 8, 7, 6, 56), 1229098150],
#   [datetime.datetime(2013, 8, 8, 6, 56, 2), 1212383133],
#   [datetime.datetime(2013, 8, 9, 6, 56, 2), 1198290079],
#   [datetime.datetime(2013, 8, 10, 6, 56, 1), 1195703559],
#   [datetime.datetime(2013, 8, 11, 6, 56, 2), 1193835825],
#   [datetime.datetime(2013, 8, 12, 6, 56, 1), 1204979580],
#   [datetime.datetime(2013, 8, 13, 7, 1, 2), 1234277535],
#   [datetime.datetime(2013, 8, 14, 7, 1, 1), 1277045962],
#   [datetime.datetime(2013, 8, 15, 7, 1, 2), 1290791623],
#   [datetime.datetime(2013, 8, 16, 7, 21, 1), 1255999432],
#   [datetime.datetime(2013, 8, 17, 7, 21, 1), 1260549575],
#   [datetime.datetime(2013, 8, 18, 7, 21, 1), 1297725576],
#   [datetime.datetime(2013, 8, 19, 7, 21, 1), 1364305023],
#   [datetime.datetime(2013, 8, 20, 7, 21, 1), 1391744715],
#   [datetime.datetime(2013, 8, 21, 7, 21, 2), 1390017000],
#   [datetime.datetime(2013, 8, 22, 7, 21, 1), 1412622912],
#   [datetime.datetime(2013, 8, 23, 7, 21, 1), 1404948802],
#   [datetime.datetime(2013, 8, 24, 7, 21, 1), 1380248275],
#   [datetime.datetime(2013, 8, 25, 7, 21, 2), 1398134387],
#   [datetime.datetime(2013, 8, 26, 7, 21, 2), 1413720420],
#   [datetime.datetime(2013, 8, 27, 7, 21, 1), 1420013070],
#   [datetime.datetime(2013, 8, 28, 7, 21, 2), 1467696672],
#   [datetime.datetime(2013, 8, 29, 7, 21, 1), 1423401000],
#   [datetime.datetime(2013, 8, 30, 7, 21, 1), 1414493496],
#   [datetime.datetime(2013, 8, 31, 7, 21, 2), 1548720490],
#   [datetime.datetime(2013, 9, 1, 7, 21, 2), 1595008048],
#   [datetime.datetime(2013, 9, 2, 7, 21, 2), 1590732401],
#   [datetime.datetime(2013, 9, 3, 7, 21, 2), 1575707182],
#   [datetime.datetime(2013, 9, 4, 7, 21, 2), 1589775538],
#   [datetime.datetime(2013, 9, 5, 7, 26, 2), 1483451582],
#   [datetime.datetime(2013, 9, 6, 7, 26, 1), 1466648505],
#   [datetime.datetime(2013, 9, 7, 7, 26, 2), 1413398077],
#   [datetime.datetime(2013, 9, 8, 7, 26, 2), 1440475723],
#   [datetime.datetime(2013, 9, 9, 7, 26, 2), 1410546093],
#   [datetime.datetime(2013, 9, 10, 7, 26, 1), 1485885525],
#   [datetime.datetime(2013, 9, 11, 7, 26, 2), 1441952016],
#   [datetime.datetime(2013, 9, 12, 7, 26, 2), 1571991468],
#   [datetime.datetime(2013, 9, 13, 7, 26, 1), 1593705850],
#   [datetime.datetime(2013, 9, 14, 7, 26, 2), 1551266086],
#   [datetime.datetime(2013, 9, 15, 7, 26, 2), 1505159472],
#   [datetime.datetime(2013, 9, 16, 7, 26, 1), 1528329267],
#   [datetime.datetime(2013, 9, 17, 7, 26, 1), 1482235956],
#   [datetime.datetime(2013, 9, 18, 7, 26, 2), 1531472535],
#   [datetime.datetime(2013, 9, 19, 7, 26, 1), 1535810988],
#   [datetime.datetime(2013, 9, 20, 7, 26, 2), 1521198731],
#   [datetime.datetime(2013, 9, 21, 7, 26, 2), 1495076509],
#   [datetime.datetime(2013, 9, 22, 7, 26, 2), 1493833260],
#   [datetime.datetime(2013, 9, 23, 7, 26, 1), 1507154161],
#   [datetime.datetime(2013, 9, 24, 7, 26, 2), 1484371556],
#   [datetime.datetime(2013, 9, 25, 7, 26, 2), 1513805580],
#   [datetime.datetime(2013, 9, 26, 7, 26, 1), 1515403031],
#   [datetime.datetime(2013, 9, 27, 7, 26, 2), 1530763838],
#   [datetime.datetime(2013, 9, 28, 7, 26, 2), 1584338266],
#   [datetime.datetime(2013, 9, 29, 7, 26, 2), 1629791825],
#   [datetime.datetime(2013, 9, 30, 7, 36, 1), 1583038043],
#   [datetime.datetime(2013, 10, 1, 7, 41, 1), 1577869589],
#   [datetime.datetime(2013, 10, 2, 7, 41, 2), 1550425024],
#   [datetime.datetime(2013, 10, 3, 7, 41, 2), 1432992865],
#   [datetime.datetime(2013, 10, 4, 9, 16, 11), 1484790258],
#   [datetime.datetime(2013, 10, 5, 9, 16, 9), 1522400010],
#   [datetime.datetime(2013, 10, 6, 9, 16, 11), 1519707024],
#   [datetime.datetime(2013, 10, 7, 9, 16, 3), 1528242935],
#   [datetime.datetime(2013, 10, 8, 9, 16, 1), 1489210920],
#   [datetime.datetime(2013, 10, 9, 9, 31, 2), 1504666389],
#   [datetime.datetime(2013, 10, 10, 9, 31, 2), 1549185570],
#   [datetime.datetime(2013, 10, 11, 9, 31, 2), 1539049795],
#   [datetime.datetime(2013, 10, 12, 9, 31, 3), 1574653436],
#   [datetime.datetime(2013, 10, 13, 9, 31, 9), 1592076330],
#   [datetime.datetime(2013, 10, 14, 9, 31, 2), 1657780162],
#   [datetime.datetime(2013, 10, 15, 9, 31, 1), 1653892914],
#   [datetime.datetime(2013, 10, 16, 9, 31, 2), 1798515348],
#   [datetime.datetime(2013, 10, 17, 9, 31, 3), 1708762041],
#   [datetime.datetime(2013, 10, 18, 9, 31, 5), 1737727200],
#   [datetime.datetime(2013, 10, 19, 9, 31, 2), 1936429199],
#   [datetime.datetime(2013, 10, 20, 10, 16, 2), 2055254041],
#   [datetime.datetime(2013, 10, 21, 10, 16, 5), 2116153256],
#   [datetime.datetime(2013, 10, 22, 10, 16, 2), 2289446235],
#   [datetime.datetime(2013, 10, 23, 10, 21, 2), 2318122872],
#   [datetime.datetime(2013, 10, 24, 10, 26, 2), 2263880095],
#   [datetime.datetime(2013, 10, 25, 10, 26, 1), 2208910112],
#   [datetime.datetime(2013, 10, 26, 10, 26, 12), 2205330408],
#   [datetime.datetime(2013, 10, 27, 9, 26, 2), 2170590240],
#   [datetime.datetime(2013, 10, 28, 9, 26, 2), 2332560505],
#   [datetime.datetime(2013, 10, 29, 9, 31, 1), 2383514169],
#   [datetime.datetime(2013, 10, 30, 9, 31, 1), 2411927532],
#   [datetime.datetime(2013, 10, 31, 11, 6, 1), 2400527163],
#   [datetime.datetime(2013, 11, 1, 11, 6, 3), 2430860520],
#   [datetime.datetime(2013, 11, 2, 11, 16, 2), 2472401796],
#   [datetime.datetime(2013, 11, 3, 11, 16, 2), 2448338589],
#   [datetime.datetime(2013, 11, 4, 11, 11, 2), 2586286560],
#   [datetime.datetime(2013, 11, 5, 11, 11, 10), 2753961102],
#   [datetime.datetime(2013, 11, 6, 11, 16, 2), 3070437192],
#   [datetime.datetime(2013, 11, 7, 11, 16, 3), 3518670692],
#   [datetime.datetime(2013, 11, 8, 11, 16, 2), 3825919011],
#   [datetime.datetime(2013, 11, 9, 11, 16, 1), 4228079278],
#   [datetime.datetime(2013, 11, 10, 11, 16, 2), 3779710352],
#   [datetime.datetime(2013, 11, 11, 11, 16, 2), 3980634680],
#   [datetime.datetime(2013, 11, 12, 11, 16, 2), 4328310772],
#   [datetime.datetime(2013, 11, 13, 11, 16, 2), 4493672638],
#   [datetime.datetime(2013, 11, 14, 11, 26, 2), 4897827984],
#   [datetime.datetime(2013, 11, 15, 11, 26, 2), 5132926869],
#   [datetime.datetime(2013, 11, 16, 11, 31, 2), 5294532600],
#   [datetime.datetime(2013, 11, 17, 11, 36, 2), 5625255681],
#   [datetime.datetime(2013, 11, 18, 11, 36, 2), 6705789430],
#   [datetime.datetime(2013, 11, 19, 11, 36, 3), 8103857471],
#   [datetime.datetime(2013, 11, 20, 11, 36, 2), 5798258526],
#   [datetime.datetime(2013, 11, 21, 11, 46, 2), 7456358841],
#   [datetime.datetime(2013, 11, 22, 11, 51, 2), 8790506777],
#   [datetime.datetime(2013, 11, 23, 22, 46, 2), 9730337944],
#   [datetime.datetime(2013, 11, 24, 22, 46, 1), 9349295648],
#   [datetime.datetime(2013, 11, 25, 23, 51, 2), 9529002102],
#   [datetime.datetime(2013, 11, 26, 23, 51, 2), 10946018925],
#   [datetime.datetime(2013, 11, 27, 23, 46, 3), 11850638474],
#   [datetime.datetime(2013, 11, 28, 23, 46, 1), 12426552940],
#   [datetime.datetime(2013, 11, 30, 2, 46, 1), 13853313627],
#   [datetime.datetime(2013, 12, 1, 2, 51, 1), 13541896415],
#   [datetime.datetime(2013, 12, 2, 2, 51, 1), 12038665194],
#   [datetime.datetime(2013, 12, 3, 2, 56, 1), 12438459202],
#   [datetime.datetime(2013, 12, 4, 3, 11, 2), 13004931455],
#   [datetime.datetime(2013, 12, 5, 3, 26, 2), 13613383537],
#   [datetime.datetime(2013, 12, 6, 3, 56, 1), 12117660075],
#   [datetime.datetime(2013, 12, 7, 4, 16, 2), 9250920298],
#   [datetime.datetime(2013, 12, 8, 4, 41, 1), 8397879080],
#   [datetime.datetime(2013, 12, 9, 4, 41, 2), 10135632177],
#   [datetime.datetime(2013, 12, 10, 4, 51, 2), 11155612005],
#   [datetime.datetime(2013, 12, 11, 5, 16, 1), 11596135176],
#   [datetime.datetime(2013, 12, 12, 5, 16, 1), 10329286823],
#   [datetime.datetime(2013, 12, 13, 5, 31, 1), 10978301748],
#   [datetime.datetime(2013, 12, 14, 5, 31, 2), 10820630864],
#   [datetime.datetime(2013, 12, 15, 5, 56, 1), 10307643675],
#   [datetime.datetime(2013, 12, 16, 6, 6, 1), 10539143353],
#   [datetime.datetime(2013, 12, 17, 6, 11, 2), 8119114562],
#   [datetime.datetime(2013, 12, 18, 6, 16, 2), 7818203456],
#   [datetime.datetime(2013, 12, 19, 6, 21, 1), 6802839701],
#   [datetime.datetime(2013, 12, 20, 6, 31, 1), 8650071000],
#   [datetime.datetime(2013, 12, 21, 6, 41, 1), 7757993944],
#   [datetime.datetime(2013, 12, 22, 6, 41, 2), 7412626262],
#   [datetime.datetime(2013, 12, 23, 6, 46, 1), 7846531378],
#   [datetime.datetime(2013, 12, 24, 6, 46, 1), 8169016070],
#   [datetime.datetime(2013, 12, 25, 6, 46, 1), 7968482544],
#   [datetime.datetime(2013, 12, 26, 6, 46, 2), 8448510379],
#   [datetime.datetime(2013, 12, 27, 6, 56, 1), 8968234621],
#   [datetime.datetime(2013, 12, 28, 6, 56, 1), 8891737240],
#   [datetime.datetime(2013, 12, 29, 7, 1, 2), 8769072171],
#   [datetime.datetime(2013, 12, 30, 7, 46, 2), 9176209842],
#   [datetime.datetime(2013, 12, 31, 8, 16, 1), 9114650721],
#   [datetime.datetime(2014, 1, 1, 8, 16, 1), 9375027519],
#   [datetime.datetime(2014, 1, 2, 8, 16, 2), 9400260663],
#   [datetime.datetime(2014, 1, 3, 8, 16, 2), 9777538842],
#   [datetime.datetime(2014, 1, 4, 8, 16, 2), 9872620257],
#   [datetime.datetime(2014, 1, 5, 8, 16, 1), 10533192293],
#   [datetime.datetime(2014, 1, 6, 8, 16, 2), 11895294512],
#   [datetime.datetime(2014, 1, 7, 13, 26, 1), 11238639912],
#   [datetime.datetime(2014, 1, 8, 13, 26, 2), 10489937497],
#   [datetime.datetime(2014, 1, 9, 13, 26, 1), 10291198407],
#   [datetime.datetime(2014, 1, 10, 13, 26, 1), 10235909453],
#   [datetime.datetime(2014, 1, 11, 13, 26, 1), 11120838747],
#   [datetime.datetime(2014, 1, 12, 13, 26, 1), 10579385547],
#   [datetime.datetime(2014, 1, 13, 13, 26, 2), 10236131169],
#   [datetime.datetime(2014, 1, 14, 13, 26, 2), 10257005161],
#   [datetime.datetime(2014, 1, 15, 13, 26, 2), 10586901588],
#   [datetime.datetime(2014, 1, 16, 14, 31, 2), 10466816554],
#   [datetime.datetime(2014, 1, 17, 14, 41, 2), 10118464372],
#   [datetime.datetime(2014, 1, 18, 14, 41, 2), 10293545616],
#   [datetime.datetime(2014, 1, 19, 15, 11, 2), 10240441312],
#   [datetime.datetime(2014, 1, 20, 15, 11, 2), 10634404659],
#   [datetime.datetime(2014, 1, 21, 15, 16, 2), 10660106725],
#   [datetime.datetime(2014, 1, 22, 18, 21, 2), 10407022515],
#   [datetime.datetime(2014, 1, 23, 18, 31, 2), 10192103437],
#   [datetime.datetime(2014, 1, 24, 18, 31, 2), 9875571598],
#   [datetime.datetime(2014, 1, 25, 18, 31, 2), 10468361227],
#   [datetime.datetime(2014, 1, 26, 18, 31, 2), 10966151300],
#   [datetime.datetime(2014, 1, 27, 21, 31, 2), 9896706963],
#   [datetime.datetime(2014, 1, 28, 21, 36, 2), 10030077450],
#   [datetime.datetime(2014, 1, 29, 21, 51, 2), 10174460328],
#   [datetime.datetime(2014, 1, 30, 21, 51, 2), 10105458986],
#   [datetime.datetime(2014, 1, 31, 21, 51, 2), 10153617765],
#   [datetime.datetime(2014, 2, 1, 21, 51, 2), 10391760101],
#   [datetime.datetime(2014, 2, 2, 21, 51, 2), 10241496932],
#   [datetime.datetime(2014, 2, 3, 21, 56, 2), 10117201297],
#   [datetime.datetime(2014, 2, 4, 22, 31, 2), 10268668985],
#   [datetime.datetime(2014, 2, 5, 22, 36, 2), 10152548463],
#   [datetime.datetime(2014, 2, 6, 22, 36, 3), 9682805649],
#   [datetime.datetime(2014, 2, 7, 22, 36, 5), 8977470788],
#   [datetime.datetime(2014, 2, 8, 22, 36, 5), 8503248112],
#   [datetime.datetime(2014, 2, 9, 22, 41, 2), 8568588480],
#   [datetime.datetime(2014, 2, 10, 22, 46, 2), 8273521358],
#   [datetime.datetime(2014, 2, 11, 23, 1, 13), 7902678666],
#   [datetime.datetime(2014, 2, 13, 4, 6, 2), 8103210317],
#   [datetime.datetime(2014, 2, 14, 4, 6, 7), 6981872578],
#   [datetime.datetime(2014, 2, 15, 4, 11, 13), 7991142081],
#   [datetime.datetime(2014, 2, 16, 4, 11, 10), 8166740022],
#   [datetime.datetime(2014, 2, 17, 4, 21, 22), 7645657217],
#   [datetime.datetime(2014, 2, 18, 4, 21, 45), 7963598356],
#   [datetime.datetime(2014, 2, 19, 4, 26, 2), 7763582295],
#   [datetime.datetime(2014, 2, 20, 4, 31, 2), 7765481646],
#   [datetime.datetime(2014, 2, 21, 4, 41, 22), 6824404453],
#   [datetime.datetime(2014, 2, 22, 4, 46, 2), 7053173750],
#   [datetime.datetime(2014, 2, 23, 4, 46, 2), 7630472818],
#   [datetime.datetime(2014, 2, 24, 4, 46, 2), 7195562323],
#   [datetime.datetime(2014, 2, 25, 4, 46, 2), 6195879609],
#   [datetime.datetime(2014, 2, 26, 5, 36, 9), 7013767152],
#   [datetime.datetime(2014, 2, 27, 5, 51, 2), 7239905721],
#   [datetime.datetime(2014, 2, 28, 5, 56, 2), 7115937422],
#   [datetime.datetime(2014, 3, 1, 6, 6, 2), 6955268689],
#   [datetime.datetime(2014, 3, 2, 6, 6, 5), 6992425456],
#   [datetime.datetime(2014, 3, 3, 6, 6, 2), 7150284539],
#   [datetime.datetime(2014, 3, 4, 7, 6, 23), 8257065652],
#   [datetime.datetime(2014, 3, 5, 9, 6, 1), 8280089523],
#   [datetime.datetime(2014, 3, 6, 9, 41, 1), 8267403750],
#   [datetime.datetime(2014, 3, 7, 9, 51, 23), 8179264894],
#   [datetime.datetime(2014, 3, 8, 9, 56, 2), 7766677880],
#   [datetime.datetime(2014, 3, 9, 9, 56, 2), 7774864760],
#   [datetime.datetime(2014, 3, 10, 9, 56, 21), 7987727962],
#   [datetime.datetime(2014, 3, 11, 9, 56, 2), 7883390766],
#   [datetime.datetime(2014, 3, 12, 9, 56, 2), 7948515121],
#   [datetime.datetime(2014, 3, 13, 9, 56, 2), 8003678580],
#   [datetime.datetime(2014, 3, 14, 10, 31, 2), 7923870033],
#   [datetime.datetime(2014, 3, 15, 10, 31, 2), 7908582117],
#   [datetime.datetime(2014, 3, 16, 10, 31, 2), 7943849911],
#   [datetime.datetime(2014, 3, 17, 10, 31, 2), 7794370518],
#   [datetime.datetime(2014, 3, 18, 10, 31, 2), 7729983328],
#   [datetime.datetime(2014, 3, 19, 10, 41, 17), 7732059879],
#   [datetime.datetime(2014, 3, 20, 10, 41, 2), 7568383029],
#   [datetime.datetime(2014, 3, 21, 10, 36, 2), 7531941604],
#   [datetime.datetime(2014, 3, 22, 10, 36, 3), 7096672519],
#   [datetime.datetime(2014, 3, 23, 10, 36, 2), 7116284105],
#   [datetime.datetime(2014, 3, 24, 10, 46, 2), 6983197243],
#   [datetime.datetime(2014, 3, 25, 10, 46, 3), 7197165743],
#   [datetime.datetime(2014, 3, 26, 13, 46, 2), 7343002343],
#   [datetime.datetime(2014, 3, 27, 19, 26, 1), 6564587596],
#   [datetime.datetime(2014, 3, 28, 21, 41, 2), 6177467010],
#   [datetime.datetime(2014, 3, 30, 4, 11, 2), 6108104221],
#   [datetime.datetime(2014, 3, 31, 4, 46, 2), 5995761080],
#   [datetime.datetime(2014, 4, 1, 4, 46, 2), 5772747763],
#   [datetime.datetime(2014, 4, 2, 5, 16, 2), 6062248781],
#   [datetime.datetime(2014, 4, 3, 5, 41, 3), 5381332964],
#   [datetime.datetime(2014, 4, 4, 5, 46, 2), 5505654176],
#   [datetime.datetime(2014, 4, 5, 5, 46, 2), 5698723917],
#   [datetime.datetime(2014, 4, 6, 5, 46, 2), 5856585232],
#   [datetime.datetime(2014, 4, 7, 5, 46, 2), 5746822291],
#   [datetime.datetime(2014, 4, 8, 5, 46, 2), 5718542737],
#   [datetime.datetime(2014, 4, 9, 6, 11, 3), 5738904084],
#   [datetime.datetime(2014, 4, 10, 6, 16, 2), 5400810410],
#   [datetime.datetime(2014, 4, 11, 6, 16, 3), 4823150267],
#   [datetime.datetime(2014, 4, 12, 6, 16, 3), 5535166815],
#   [datetime.datetime(2014, 4, 13, 6, 16, 2), 5370397396],
#   [datetime.datetime(2014, 4, 14, 6, 16, 2), 5176894908],
#   [datetime.datetime(2014, 4, 15, 6, 26, 2), 5759489398],
#   [datetime.datetime(2014, 4, 16, 6, 46, 2), 6524134861],
#   [datetime.datetime(2014, 4, 17, 6, 51, 2), 6575226952],
#   [datetime.datetime(2014, 4, 18, 7, 1, 2), 6252223023],
#   [datetime.datetime(2014, 4, 19, 7, 1, 2), 5975968814],
#   [datetime.datetime(2014, 4, 20, 7, 1, 2), 6393006503],
#   [datetime.datetime(2014, 4, 21, 7, 1, 3), 6435488891],
#   [datetime.datetime(2014, 4, 22, 7, 6, 2), 6322029639],
#   [datetime.datetime(2014, 4, 23, 7, 6, 2), 6226287188],
#   [datetime.datetime(2014, 4, 24, 7, 41, 2), 6195771518],
#   [datetime.datetime(2014, 4, 25, 8, 31, 4), 5790307676],
#   [datetime.datetime(2014, 4, 26, 8, 46, 2), 5733379123],
#   [datetime.datetime(2014, 4, 27, 9, 11, 2), 5788410979],
#   [datetime.datetime(2014, 4, 28, 9, 36, 2), 5407456652],
#   [datetime.datetime(2014, 4, 29, 14, 16, 2), 5685695339],
#   [datetime.datetime(2014, 4, 30, 17, 26, 2), 5673077338],
#   [datetime.datetime(2014, 5, 1, 17, 26, 3), 5731664211],
#   [datetime.datetime(2014, 5, 2, 17, 26, 2), 5666988895],
#   [datetime.datetime(2014, 5, 3, 17, 26, 5), 5610505365],
#   [datetime.datetime(2014, 5, 4, 17, 26, 5), 5517588612],
#   [datetime.datetime(2014, 5, 5, 17, 26, 6), 5473840871],
#   [datetime.datetime(2014, 5, 6, 18, 1, 5), 5487874929],
#   [datetime.datetime(2014, 5, 7, 18, 1, 7), 5607924965],
#   [datetime.datetime(2014, 5, 8, 18, 1, 20), 5626345356],
#   [datetime.datetime(2014, 5, 9, 18, 41, 16), 5741033790],
#   [datetime.datetime(2014, 5, 10, 18, 41, 6), 5754552853],
#   [datetime.datetime(2014, 5, 11, 18, 41, 7), 5528484826],
#   [datetime.datetime(2014, 5, 12, 18, 41, 10), 5630703159],
#   [datetime.datetime(2014, 5, 13, 18, 41, 13), 5614371662],
#   [datetime.datetime(2014, 5, 14, 18, 51, 16), 5673690624],
#   [datetime.datetime(2014, 5, 15, 18, 51, 7), 5724581374],
#   [datetime.datetime(2014, 5, 16, 18, 51, 10), 5730560632],
#   [datetime.datetime(2014, 5, 17, 18, 51, 6), 5724920041],
#   [datetime.datetime(2014, 5, 18, 18, 51, 8), 5716510660],
#   [datetime.datetime(2014, 5, 19, 18, 51, 17), 5692061490],
#   [datetime.datetime(2014, 5, 20, 18, 51, 15), 6183365788],
#   [datetime.datetime(2014, 5, 21, 19, 6, 17), 6298351579],
#   [datetime.datetime(2014, 5, 22, 19, 6, 20), 6609931274],
#   [datetime.datetime(2014, 5, 23, 19, 6, 9), 6700336553],
#   [datetime.datetime(2014, 5, 25, 7, 56, 6), 7115204096],
#   [datetime.datetime(2014, 5, 26, 7, 56, 10), 7521273634],
#   [datetime.datetime(2014, 5, 27, 8, 41, 13), 7497455615],
#   [datetime.datetime(2014, 5, 28, 8, 41, 5), 7382028997],
#   [datetime.datetime(2014, 5, 29, 8, 41, 16), 7269497761],
#   [datetime.datetime(2014, 5, 30, 8, 56, 7), 7305732162],
#   [datetime.datetime(2014, 5, 31, 8, 56, 7), 7920661529],
#   [datetime.datetime(2014, 6, 1, 8, 56, 13), 8325584400],
#   [datetime.datetime(2014, 6, 2, 8, 56, 6), 8004231903],
#   [datetime.datetime(2014, 6, 3, 8, 56, 7), 8443853248],
#   [datetime.datetime(2014, 6, 4, 8, 56, 6), 8213918062],
#   [datetime.datetime(2014, 6, 5, 9, 41, 6), 8306258433],
#   [datetime.datetime(2014, 6, 6, 9, 41, 5), 8453788890],
#   [datetime.datetime(2014, 6, 7, 9, 41, 7), 8398066511],
#   [datetime.datetime(2014, 6, 8, 9, 41, 6), 8461802884],
#   [datetime.datetime(2014, 6, 9, 9, 41, 6), 8332939692],
#   [datetime.datetime(2014, 6, 10, 9, 41, 5), 8472890038],
#   [datetime.datetime(2014, 6, 11, 9, 41, 9), 8374495671],
#   [datetime.datetime(2014, 6, 12, 10, 26, 6), 8202725168],
#   [datetime.datetime(2014, 6, 13, 10, 26, 9), 7874556522],
#   [datetime.datetime(2014, 6, 14, 10, 26, 7), 7540155635],
#   [datetime.datetime(2014, 6, 15, 10, 26, 7), 7215495816],
#   [datetime.datetime(2014, 6, 16, 10, 26, 7), 7737782349],
#   [datetime.datetime(2014, 6, 17, 10, 26, 11), 7698607587],
#   [datetime.datetime(2014, 6, 18, 10, 26, 8), 7907048530],
#   [datetime.datetime(2014, 6, 19, 10, 26, 7), 7879526986],
#   [datetime.datetime(2014, 6, 20, 10, 26, 8), 7615404520],
#   [datetime.datetime(2014, 6, 21, 10, 26, 7), 7648148389],
#   [datetime.datetime(2014, 6, 22, 10, 26, 10), 7816412859],
#   [datetime.datetime(2014, 6, 23, 10, 26, 7), 7678243878],
#   [datetime.datetime(2014, 6, 24, 11, 31, 6), 7688879009],
#   [datetime.datetime(2014, 6, 25, 13, 1, 15), 7398086370],
#   [datetime.datetime(2014, 6, 26, 22, 6, 10), 7423820740],
#   [datetime.datetime(2014, 6, 27, 23, 11, 7), 7577314829],
#   [datetime.datetime(2014, 6, 29, 8, 46, 12), 7788118206],
#   [datetime.datetime(2014, 6, 30, 10, 21, 39), 8122165800],
#   [datetime.datetime(2014, 7, 1, 10, 21, 12), 8486436757],
#   [datetime.datetime(2014, 7, 2, 15, 21, 13), 8372715704],
#   [datetime.datetime(2014, 7, 3, 19, 16, 8), 8371823420],
#   [datetime.datetime(2014, 7, 5, 3, 21, 11), 8200025844],
#   [datetime.datetime(2014, 7, 6, 19, 6, 11), 8244355335],
#   [datetime.datetime(2014, 7, 8, 12, 24), 8082395595],
#   [datetime.datetime(2014, 7, 9, 16, 14), 8116882102],
#   [datetime.datetime(2014, 7, 10, 16, 14), 7986870811],
#   [datetime.datetime(2014, 7, 11, 16, 14), 8183210066],
#   [datetime.datetime(2014, 7, 12, 16, 14), 8177509169],
#   [datetime.datetime(2014, 7, 13, 16, 14), 8186803751],
#   [datetime.datetime(2014, 7, 14, 16, 14), 8070258638],
#   [datetime.datetime(2014, 7, 15, 16, 14), 8122773091],
#   [datetime.datetime(2014, 7, 16, 16, 14), 8032529722],
#   [datetime.datetime(2014, 7, 17, 16, 14), 8078882611],
#   [datetime.datetime(2014, 7, 18, 16, 14), 8092787472],
#   [datetime.datetime(2014, 7, 19, 16, 14), 8188922459],
#   [datetime.datetime(2014, 7, 20, 16, 14), 8151474297],
#   [datetime.datetime(2014, 7, 21, 16, 14), 8094123825],
#   [datetime.datetime(2014, 7, 22, 16, 24), 8116705702],
#   [datetime.datetime(2014, 7, 23, 16, 24), 8130867361],
#   [datetime.datetime(2014, 7, 24, 16, 24), 7849214803],
#   [datetime.datetime(2014, 7, 25, 16, 24), 7859391788],
#   [datetime.datetime(2014, 7, 26, 16, 24), 7809989668],
#   [datetime.datetime(2014, 7, 27, 16, 24), 7809272562],
#   [datetime.datetime(2014, 7, 28, 17, 24), 7612339560],
#   [datetime.datetime(2014, 7, 29, 17, 24), 7631643297],
#   [datetime.datetime(2014, 7, 30, 19, 4), 7544687880],
#   [datetime.datetime(2014, 7, 31, 19, 4), 7660237144],
#   [datetime.datetime(2014, 8, 1, 19, 24), 7814990816],
#   [datetime.datetime(2014, 8, 2, 19, 54), 7712307360],
#   [datetime.datetime(2014, 8, 3, 19, 54), 7681992598],
#   [datetime.datetime(2014, 8, 4, 19, 54), 7725064932],
#   [datetime.datetime(2014, 8, 5, 19, 54), 7684065312],
#   [datetime.datetime(2014, 8, 6, 19, 54), 7689070836],
#   [datetime.datetime(2014, 8, 7, 19, 54), 7730980003],
#   [datetime.datetime(2014, 8, 8, 19, 54), 7778019496],
#   [datetime.datetime(2014, 8, 9, 19, 54), 7733676906],
#   [datetime.datetime(2014, 8, 10, 19, 54), 7747817534],
#   [datetime.datetime(2014, 8, 11, 19, 54), 7620587697],
#   [datetime.datetime(2014, 8, 12, 19, 54), 7479211448],
#   [datetime.datetime(2014, 8, 13, 19, 54), 7089371399],
#   [datetime.datetime(2014, 8, 14, 19, 54), 6788369159],
#   [datetime.datetime(2014, 8, 15, 19, 54), 6486612775],
#   [datetime.datetime(2014, 8, 16, 19, 54), 6657817457],
#   [datetime.datetime(2014, 8, 17, 19, 54), 6472897218],
#   [datetime.datetime(2014, 8, 18, 19, 54), 6052765876],
#   [datetime.datetime(2014, 8, 19, 19, 54), 6284411752],
#   [datetime.datetime(2014, 8, 20, 19, 54), 6636746619],
#   [datetime.datetime(2014, 8, 21, 19, 54), 6915078697],
#   [datetime.datetime(2014, 8, 22, 19, 54), 6819752408],
#   [datetime.datetime(2014, 8, 23, 19, 54), 6605512916],
#   [datetime.datetime(2014, 8, 24, 19, 54), 6741579651],
#   [datetime.datetime(2014, 8, 25, 19, 54), 6624449236],
#   [datetime.datetime(2014, 8, 26, 19, 54), 6751116840],
#   [datetime.datetime(2014, 8, 27, 19, 54), 6758242708],
#   [datetime.datetime(2014, 8, 28, 19, 54), 6705996985],
#   [datetime.datetime(2014, 8, 29, 19, 54), 6738232487],
#   [datetime.datetime(2014, 8, 30, 19, 54), 6663734161],
#   [datetime.datetime(2014, 8, 31, 19, 54), 6278177305],
#   [datetime.datetime(2014, 9, 1, 19, 54), 6367932182],
#   [datetime.datetime(2014, 9, 2, 20, 4), 6380356629],
#   [datetime.datetime(2014, 9, 3, 20, 4), 6309823001],
#   [datetime.datetime(2014, 9, 4, 20, 4), 6457360244],
#   [datetime.datetime(2014, 9, 5, 20, 4), 6413157070],
#   [datetime.datetime(2014, 9, 6, 20, 4), 6453564668],
#   [datetime.datetime(2014, 9, 7, 20, 4), 6428513158],
#   [datetime.datetime(2014, 9, 8, 20, 24), 6343771471],
#   [datetime.datetime(2014, 9, 9, 20, 24), 6253035610],
#   [datetime.datetime(2014, 9, 10, 20, 24), 6421968408],
#   [datetime.datetime(2014, 9, 11, 20, 24), 6290813167],
#   [datetime.datetime(2014, 9, 12, 20, 24), 6312730888],
#   [datetime.datetime(2014, 9, 13, 20, 24), 6376536644],
#   [datetime.datetime(2014, 9, 14, 20, 24), 6337916584],
#   [datetime.datetime(2014, 9, 15, 20, 24), 6327753377],
#   [datetime.datetime(2014, 9, 16, 20, 24), 6236932009],
#   [datetime.datetime(2014, 9, 17, 20, 24), 6027243652],
#   [datetime.datetime(2014, 9, 18, 20, 24), 5649055634],
#   [datetime.datetime(2014, 9, 19, 20, 23, 59), 5301224275],
#   [datetime.datetime(2014, 9, 20, 20, 24), 5488274967],
#   [datetime.datetime(2014, 9, 21, 20, 24), 5349780133],
#   [datetime.datetime(2014, 9, 22, 20, 23, 59), 5349470436],
#   [datetime.datetime(2014, 9, 23, 20, 24), 5786438777],
#   [datetime.datetime(2014, 9, 24, 20, 33, 59), 5708169478],
#   [datetime.datetime(2014, 9, 25, 20, 33, 59), 5466497281],
#   [datetime.datetime(2014, 9, 26, 20, 34), 5389223696],
#   [datetime.datetime(2014, 9, 27, 20, 34), 5306694358],
#   [datetime.datetime(2014, 9, 28, 20, 33, 59), 5078204546],
#   [datetime.datetime(2014, 9, 29, 20, 33, 59), 5081242480],
#   [datetime.datetime(2014, 9, 30, 20, 33, 59), 5119427674],
#   [datetime.datetime(2014, 10, 2, 8, 39), 5127402572],
#   [datetime.datetime(2014, 10, 3, 8, 38, 59), 5019403319],
#   [datetime.datetime(2014, 10, 4, 9, 44), 4785192805],
#   [datetime.datetime(2014, 10, 5, 9, 44), 4379135932],
#   [datetime.datetime(2014, 10, 6, 9, 44), 4291300659],
#   [datetime.datetime(2014, 10, 7, 9, 44), 4366348702],
#   [datetime.datetime(2014, 10, 8, 9, 44), 4451575734],
#   [datetime.datetime(2014, 10, 9, 9, 44, 5), 4771503789],
#   [datetime.datetime(2014, 10, 10, 9, 44), 4961717589],
#   [datetime.datetime(2014, 10, 11, 9, 44), 4841471420],
#   [datetime.datetime(2014, 10, 12, 9, 44), 4828147412],
#   [datetime.datetime(2014, 10, 13, 9, 44), 4985678637],
#   [datetime.datetime(2014, 10, 14, 9, 44), 5418971888],
#   [datetime.datetime(2014, 10, 15, 9, 44), 5328846153],
#   [datetime.datetime(2014, 10, 16, 9, 44), 5265674038],
#   [datetime.datetime(2014, 10, 17, 9, 49), 5137917706],
#   [datetime.datetime(2014, 10, 18, 9, 49), 5105109931],
#   [datetime.datetime(2014, 10, 19, 9, 49), 5264196242],
#   [datetime.datetime(2014, 10, 20, 9, 49), 5134201081],
#   [datetime.datetime(2014, 10, 21, 9, 49), 5155910228],
#   [datetime.datetime(2014, 10, 22, 9, 49), 5188468568],
#   [datetime.datetime(2014, 10, 23, 9, 49), 5000114789],
#   [datetime.datetime(2014, 10, 24, 9, 49), 4821642992],
#   [datetime.datetime(2014, 10, 25, 9, 49), 4748461382],
#   [datetime.datetime(2014, 10, 26, 8, 49), 4741037489],
#   [datetime.datetime(2014, 10, 27, 8, 49), 4733130351],
#   [datetime.datetime(2014, 10, 28, 8, 49), 4801110716],
#   [datetime.datetime(2014, 10, 29, 8, 49), 4799952434],
#   [datetime.datetime(2014, 10, 30, 8, 49), 4569673152],
#   [datetime.datetime(2014, 10, 31, 8, 49, 2), 4645027482],
#   [datetime.datetime(2014, 11, 1, 9, 24), 4427422040],
#   [datetime.datetime(2014, 11, 2, 10, 24), 4372078851],
#   [datetime.datetime(2014, 11, 3, 10, 24), 4449114450],
#   [datetime.datetime(2014, 11, 4, 10, 24), 4391372099],
#   [datetime.datetime(2014, 11, 5, 10, 24), 4533581386],
#   [datetime.datetime(2014, 11, 6, 10, 24), 4584887384],
#   [datetime.datetime(2014, 11, 7, 10, 24), 4683921008],
#   [datetime.datetime(2014, 11, 8, 10, 24), 4629267445],
#   [datetime.datetime(2014, 11, 9, 10, 24), 4706558009],
#   [datetime.datetime(2014, 11, 10, 10, 24), 4853718859],
#   [datetime.datetime(2014, 11, 11, 10, 24), 4961414266],
#   [datetime.datetime(2014, 11, 12, 10, 24), 5108311016],
#   [datetime.datetime(2014, 11, 13, 10, 24), 5914680527],
#   [datetime.datetime(2014, 11, 14, 10, 24), 5196704404],
#   [datetime.datetime(2014, 11, 15, 10, 24), 5335673913],
#   [datetime.datetime(2014, 11, 16, 10, 24), 5224946837],
#   [datetime.datetime(2014, 11, 17, 10, 24), 5535651238],
#   [datetime.datetime(2014, 11, 18, 10, 24), 5186840088],
#   [datetime.datetime(2014, 11, 19, 10, 24), 5183709300],
#   [datetime.datetime(2014, 11, 20, 10, 24), 4934113776],
#   [datetime.datetime(2014, 11, 21, 10, 24), 4775347316],
#   [datetime.datetime(2014, 11, 22, 10, 24), 4851718884],
#   [datetime.datetime(2014, 11, 23, 10, 24), 4831481373],
#   [datetime.datetime(2014, 11, 24, 10, 24), 5069710284],
#   [datetime.datetime(2014, 11, 25, 10, 24), 5323052593],
#   [datetime.datetime(2014, 11, 26, 10, 34), 4998261122],
#   [datetime.datetime(2014, 11, 27, 10, 34), 5043398583],
#   [datetime.datetime(2014, 11, 28, 10, 34), 4921394189],
#   [datetime.datetime(2014, 11, 29, 10, 34), 5135280662],
#   [datetime.datetime(2014, 11, 30, 10, 34), 5165277474],
#   [datetime.datetime(2014, 12, 1, 10, 34), 5152575062],
#   [datetime.datetime(2014, 12, 2, 10, 34), 5167497278],
#   [datetime.datetime(2014, 12, 3, 10, 34), 5105225558],
#   [datetime.datetime(2014, 12, 4, 10, 34), 5098196759],
#   [datetime.datetime(2014, 12, 5, 10, 34), 5062365576],
#   [datetime.datetime(2014, 12, 6, 10, 34), 5084317689],
#   [datetime.datetime(2014, 12, 7, 10, 34), 5091085165],
#   [datetime.datetime(2014, 12, 8, 10, 34, 1), 4980925017],
#   [datetime.datetime(2014, 12, 9, 10, 34), 4765826202],
#   [datetime.datetime(2014, 12, 10, 10, 34), 4757842918],
#   [datetime.datetime(2014, 12, 11, 18, 19), 4848542429],
#   [datetime.datetime(2014, 12, 14, 2, 14), 4715148005],
#   [datetime.datetime(2014, 12, 15, 2, 14), 4778612471],
#   [datetime.datetime(2014, 12, 16, 2, 14), 4701943395],
#   [datetime.datetime(2014, 12, 17, 2, 19), 4547100966],
#   [datetime.datetime(2014, 12, 18, 2, 19), 4377434370],
#   [datetime.datetime(2014, 12, 19, 2, 19), 4242268348],
#   [datetime.datetime(2014, 12, 20, 2, 19), 4314356389],
#   [datetime.datetime(2014, 12, 21, 2, 19), 4482512994],
#   [datetime.datetime(2014, 12, 22, 2, 19), 4389948813],
#   [datetime.datetime(2014, 12, 23, 2, 19, 1), 4542880267],
#   [datetime.datetime(2014, 12, 24, 2, 19), 4559253562],
#   [datetime.datetime(2014, 12, 25, 2, 19), 4339886866],
#   [datetime.datetime(2014, 12, 26, 2, 19, 1), 4337524254],
#   [datetime.datetime(2014, 12, 27, 2, 19, 1), 4435289409],
#   [datetime.datetime(2014, 12, 28, 2, 19, 1), 4322830391],
#   [datetime.datetime(2014, 12, 29, 2, 19), 4369189647],
#   [datetime.datetime(2014, 12, 30, 2, 19), 4290788757],
#   [datetime.datetime(2014, 12, 31, 2, 19, 1), 4245280800],
#   [datetime.datetime(2015, 1, 1, 2, 19, 1), 4345601963],
#   [datetime.datetime(2015, 1, 2, 2, 19), 4289287759],
#   [datetime.datetime(2015, 1, 3, 2, 19), 4307374369],
#   [datetime.datetime(2015, 1, 4, 2, 19), 3848549170],
#   [datetime.datetime(2015, 1, 5, 2, 19, 1), 3650984440],
#   [datetime.datetime(2015, 1, 6, 2, 19, 1), 3753949381],
#   [datetime.datetime(2015, 1, 7, 2, 19, 1), 3879255971],
#   [datetime.datetime(2015, 1, 8, 2, 19), 4024290266],
#   [datetime.datetime(2015, 1, 9, 2, 19, 1), 3871292298],
#   [datetime.datetime(2015, 1, 10, 10, 59, 1), 3808946374],
#   [datetime.datetime(2015, 1, 11, 10, 59, 1), 3766686283],
#   [datetime.datetime(2015, 1, 12, 10, 59, 1), 3675616212],
#   [datetime.datetime(2015, 1, 13, 10, 59, 1), 3355188725],
#   [datetime.datetime(2015, 1, 14, 10, 59, 1), 2851633026],
#   [datetime.datetime(2015, 1, 15, 10, 59, 1), 2813068301],
#   [datetime.datetime(2015, 1, 16, 10, 59, 1), 2994329454],
#   [datetime.datetime(2015, 1, 17, 10, 59, 1), 2708756783],
#   [datetime.datetime(2015, 1, 18, 10, 59, 1), 2891839558],
#   [datetime.datetime(2015, 1, 19, 10, 59, 1), 2861871773],
#   [datetime.datetime(2015, 1, 20, 10, 59, 1), 2877924232],
#   [datetime.datetime(2015, 1, 21, 10, 59), 2937610959],
#   [datetime.datetime(2015, 1, 22, 10, 59, 1), 3175391943],
#   [datetime.datetime(2015, 1, 23, 10, 59, 1), 3117289084],
#   [datetime.datetime(2015, 1, 24, 10, 59), 3204386274],
#   [datetime.datetime(2015, 1, 25, 10, 59, 1), 3389816225],
#   [datetime.datetime(2015, 1, 26, 10, 59, 1), 4120903457],
#   [datetime.datetime(2015, 1, 27, 10, 59), 3554872118],
#   [datetime.datetime(2015, 1, 28, 10, 59, 1), 3610527384],
#   [datetime.datetime(2015, 1, 29, 10, 59, 1), 3174116640],
#   [datetime.datetime(2015, 1, 30, 10, 59, 1), 3207876399],
#   [datetime.datetime(2015, 1, 31, 10, 59, 1), 3197785951],
#   [datetime.datetime(2015, 2, 1, 11, 9, 1), 2932754485],
#   [datetime.datetime(2015, 2, 2, 11, 9, 20), 3098862238],
#   [datetime.datetime(2015, 2, 3, 11, 9, 21), 3304247798],
#   [datetime.datetime(2015, 2, 4, 11, 14, 19), 3084186083],
#   [datetime.datetime(2015, 2, 5, 11, 14, 19), 3118027956],
#   [datetime.datetime(2015, 2, 6, 11, 14, 20), 3021929922],
#   [datetime.datetime(2015, 2, 7, 11, 14, 25), 3161297986],
#   [datetime.datetime(2015, 2, 8, 11, 14, 20), 3141965896],
#   [datetime.datetime(2015, 2, 9, 11, 14, 20), 3074677811],
#   [datetime.datetime(2015, 2, 10, 11, 19, 20), 2991226156],
#   [datetime.datetime(2015, 2, 11, 11, 19, 20), 3049515934],
#   [datetime.datetime(2015, 2, 12, 11, 19, 20), 3030286962],
#   [datetime.datetime(2015, 2, 13, 11, 19, 21), 3248286280],
#   [datetime.datetime(2015, 2, 14, 11, 19, 21), 3429086744],
#   [datetime.datetime(2015, 2, 15, 11, 24, 22), 3636040558],
#   [datetime.datetime(2015, 2, 16, 11, 29, 20), 3288133689],
#   [datetime.datetime(2015, 2, 17, 11, 29, 19), 3291510942],
#   [datetime.datetime(2015, 2, 18, 11, 29, 20), 3346731825],
#   [datetime.datetime(2015, 2, 19, 11, 29, 19), 3281224349],
#   [datetime.datetime(2015, 2, 20, 11, 29, 22), 3411751633],
#   [datetime.datetime(2015, 2, 21, 11, 29, 20), 3380093375],
#   [datetime.datetime(2015, 2, 22, 11, 44, 19), 3400132507],
#   [datetime.datetime(2015, 2, 23, 11, 44, 20), 3253406963],
#   [datetime.datetime(2015, 2, 24, 11, 44, 20), 3282405035],
#   [datetime.datetime(2015, 2, 25, 11, 44, 21), 3272446748],
#   [datetime.datetime(2015, 2, 26, 11, 44, 20), 3278060208],
#   [datetime.datetime(2015, 2, 27, 11, 44, 19), 3496113393],
#   [datetime.datetime(2015, 2, 28, 13, 44, 19), 3511637500],
#   [datetime.datetime(2015, 3, 1, 13, 44, 20), 3418854940],
#   [datetime.datetime(2015, 3, 2, 13, 44, 20), 3596686084],
#   [datetime.datetime(2015, 3, 3, 13, 44, 20), 3757039683],
#   [datetime.datetime(2015, 3, 4, 19, 29, 19), 3921472230],
#   [datetime.datetime(2015, 3, 5, 19, 34, 20), 3715418089],
#   [datetime.datetime(2015, 3, 6, 19, 34, 19), 3771089115],
#   [datetime.datetime(2015, 3, 7, 19, 39, 20), 3842565008],
#   [datetime.datetime(2015, 3, 8, 19, 39, 21), 3824308700],
#   [datetime.datetime(2015, 3, 9, 19, 49, 19), 3990421912],
#   [datetime.datetime(2015, 3, 10, 19, 54, 19), 4110333413],
#   [datetime.datetime(2015, 3, 11, 19, 54, 19), 4125292446],
#   [datetime.datetime(2015, 3, 12, 19, 54, 20), 4131676728],
#   [datetime.datetime(2015, 3, 13, 19, 59, 20), 4009506313],
#   [datetime.datetime(2015, 3, 14, 20, 4, 20), 3944860422],
#   [datetime.datetime(2015, 3, 15, 20, 4, 21), 3962828226],
#   [datetime.datetime(2015, 3, 16, 20, 4, 22), 4058871698],
#   [datetime.datetime(2015, 3, 17, 20, 4, 22), 4017292623],
#   [datetime.datetime(2015, 3, 18, 20, 4, 22), 3723705566],
#   [datetime.datetime(2015, 3, 19, 20, 9, 21), 3626492241],
#   [datetime.datetime(2015, 3, 20, 20, 14, 21), 3639131051],
#   [datetime.datetime(2015, 3, 21, 20, 19, 21), 3637526863],
#   [datetime.datetime(2015, 3, 22, 20, 19, 21), 3669968700],
#   [datetime.datetime(2015, 3, 23, 20, 19, 22), 3676053749],
#   [datetime.datetime(2015, 3, 24, 20, 19, 22), 3448861669],
#   [datetime.datetime(2015, 3, 25, 20, 19, 22), 3426432676],
#   [datetime.datetime(2015, 3, 26, 20, 19, 19), 3541436382],
#   [datetime.datetime(2015, 3, 27, 20, 19, 21), 3474922114],
#   [datetime.datetime(2015, 3, 28, 20, 19, 21), 3521673717],
#   [datetime.datetime(2015, 3, 29, 21, 44, 21), 3426239160],
#   [datetime.datetime(2015, 3, 30, 23, 29, 19), 3469694824],
#   [datetime.datetime(2015, 3, 31, 23, 54, 22), 3438997948],
#   [datetime.datetime(2015, 4, 2, 3, 59, 21), 3472729978],
#   [datetime.datetime(2015, 4, 3, 3, 59, 21), 3547549559],
#   [datetime.datetime(2015, 4, 4, 4, 9, 21), 3574913192],
#   [datetime.datetime(2015, 4, 5, 4, 9, 21), 3549704856],
#   [datetime.datetime(2015, 4, 6, 4, 14, 21), 3668097103],
#   [datetime.datetime(2015, 4, 7, 4, 14, 21), 3544201888],
#   [datetime.datetime(2015, 4, 8, 4, 14, 22), 3550136355],
#   [datetime.datetime(2015, 4, 9, 4, 34, 21), 3435976468],
#   [datetime.datetime(2015, 4, 10, 4, 34, 21), 3407562580],
#   [datetime.datetime(2015, 4, 11, 4, 34, 21), 3317215986],
#   [datetime.datetime(2015, 4, 12, 4, 34, 21), 3332846528],
#   [datetime.datetime(2015, 4, 13, 4, 34, 22), 3312552620],
#   [datetime.datetime(2015, 4, 14, 4, 34, 22), 3150265219],
#   [datetime.datetime(2015, 4, 15, 6, 9, 21), 3121110924],
#   [datetime.datetime(2015, 4, 16, 6, 14, 22), 3176590483],
#   [datetime.datetime(2015, 4, 17, 6, 19, 22), 3213681992],
#   [datetime.datetime(2015, 4, 18, 6, 24, 23), 3141396045],
#   [datetime.datetime(2015, 4, 19, 6, 39, 22), 3146724471],
#   [datetime.datetime(2015, 4, 20, 7, 19, 23), 3146493803],
#   [datetime.datetime(2015, 4, 21, 7, 24, 22), 3172533292],
#   [datetime.datetime(2015, 4, 22, 7, 34, 23), 3303065945],
#   [datetime.datetime(2015, 4, 23, 7, 34, 22), 3293427801],
#   [datetime.datetime(2015, 4, 24, 7, 44, 23), 3265078364],
#   [datetime.datetime(2015, 4, 25, 8, 44, 22), 3239046278],
#   [datetime.datetime(2015, 4, 26, 14, 59, 23), 3082924255],
#   [datetime.datetime(2015, 4, 27, 14, 59, 23), 3108026628],
#   [datetime.datetime(2015, 4, 28, 15, 4, 22), 3172247583],
#   [datetime.datetime(2015, 4, 29, 15, 19, 21), 3169000924],
#   [datetime.datetime(2015, 4, 30, 16, 24, 20), 3303850494],
#   [datetime.datetime(2015, 5, 1, 16, 24, 20), 3318464989],
#   [datetime.datetime(2015, 5, 2, 16, 39, 19), 3314728349],
#   [datetime.datetime(2015, 5, 3, 16, 44, 19), 3415504970],
#   [datetime.datetime(2015, 5, 4, 16, 44, 19), 3417049721],
#   [datetime.datetime(2015, 5, 5, 17, 9, 18), 3318757221],
#   [datetime.datetime(2015, 5, 6, 18, 49, 20), 3320275175],
#   [datetime.datetime(2015, 5, 7, 18, 49, 20), 3279491422],
#   [datetime.datetime(2015, 5, 8, 18, 49, 20), 3476741981],
#   [datetime.datetime(2015, 5, 9, 18, 49, 20), 3410996344],
#   [datetime.datetime(2015, 5, 10, 18, 49, 19), 3401965502],
#   [datetime.datetime(2015, 5, 11, 18, 54, 20), 3447508596],
#   [datetime.datetime(2015, 5, 12, 18, 59, 21), 3426188781],
#   [datetime.datetime(2015, 5, 13, 18, 59, 22), 3438268055],
#   [datetime.datetime(2015, 5, 14, 18, 59, 20), 3347749805],
#   [datetime.datetime(2015, 5, 15, 18, 59, 25), 3363986983],
#   [datetime.datetime(2015, 5, 16, 18, 59, 20), 3363167493],
#   [datetime.datetime(2015, 5, 17, 18, 59, 20), 3364091343],
#   [datetime.datetime(2015, 5, 18, 18, 59, 20), 3356103839],
#   [datetime.datetime(2015, 5, 19, 19, 9, 23), 3308309428],
#   [datetime.datetime(2015, 5, 20, 19, 14, 19), 3327909958],
#   [datetime.datetime(2015, 5, 21, 19, 14, 21), 3350546405],
#   [datetime.datetime(2015, 5, 22, 19, 14, 21), 3360738159],
#   [datetime.datetime(2015, 5, 23, 19, 14, 20), 3409088722],
#   [datetime.datetime(2015, 5, 24, 19, 14, 20), 3429956268],
#   [datetime.datetime(2015, 5, 25, 19, 34, 21), 3369803070],
#   [datetime.datetime(2015, 5, 26, 19, 59, 21), 3373050560],
#   [datetime.datetime(2015, 5, 27, 20, 9, 20), 3363816253],
#   [datetime.datetime(2015, 5, 28, 22, 54, 20), 3373675768],
#   [datetime.datetime(2015, 5, 29, 22, 54, 21), 3370190445],
#   [datetime.datetime(2015, 5, 30, 23, 9, 21), 3307068042],
#   [datetime.datetime(2015, 5, 31, 23, 9, 21), 3297894742],
#   [datetime.datetime(2015, 6, 1, 23, 24, 20), 3166420065],
#   [datetime.datetime(2015, 6, 3, 0, 29, 20), 3211363373],
#   [datetime.datetime(2015, 6, 4, 0, 29, 21), 3217797867],
#   [datetime.datetime(2015, 6, 5, 0, 29, 20), 3196874056],
#   [datetime.datetime(2015, 6, 6, 0, 29, 21), 3207088735],
#   [datetime.datetime(2015, 6, 7, 1, 29, 20), 3205253467],
#   [datetime.datetime(2015, 6, 8, 1, 29, 20), 3183902511],
#   [datetime.datetime(2015, 6, 9, 1, 29, 21), 3255937616],
#   [datetime.datetime(2015, 6, 10, 1, 29, 19), 3268406686],
#   [datetime.datetime(2015, 6, 11, 1, 29, 20), 3262359707],
#   [datetime.datetime(2015, 6, 12, 1, 29, 20), 3275768947],
#   [datetime.datetime(2015, 6, 13, 1, 29, 26), 3284984267],
#   [datetime.datetime(2015, 6, 14, 2, 29, 21), 3317671899],
#   [datetime.datetime(2015, 6, 15, 2, 29, 23), 3332954967],
#   [datetime.datetime(2015, 6, 16, 2, 29, 21), 3378059557],
#   [datetime.datetime(2015, 6, 17, 2, 29, 20), 3604399193],
#   [datetime.datetime(2015, 6, 18, 2, 29, 19), 3556041989],
#   [datetime.datetime(2015, 6, 19, 2, 29, 20), 3569721791],
#   [datetime.datetime(2015, 6, 20, 2, 29, 19), 3487268038],
#   [datetime.datetime(2015, 6, 21, 2, 29, 20), 3499099248],
#   [datetime.datetime(2015, 6, 22, 2, 34, 20), 3487360825],
#   [datetime.datetime(2015, 6, 23, 2, 34, 21), 3528441317],
#   [datetime.datetime(2015, 6, 24, 2, 34, 20), 3492940561],
#   [datetime.datetime(2015, 6, 25, 2, 34, 20), 3446189171],
#   [datetime.datetime(2015, 6, 26, 2, 34, 20), 3473639996],
#   [datetime.datetime(2015, 6, 27, 2, 34, 21), 3486208542],
#   [datetime.datetime(2015, 6, 28, 2, 34, 20), 3589623988],
#   [datetime.datetime(2015, 6, 29, 2, 34, 21), 3563321533],
#   [datetime.datetime(2015, 6, 30, 2, 34, 20), 3681402721],
#   [datetime.datetime(2015, 7, 1, 2, 34, 27), 3784372504],
#   [datetime.datetime(2015, 7, 2, 2, 34, 21), 3714048672],
#   [datetime.datetime(2015, 7, 3, 2, 34, 20), 3668022766],
#   [datetime.datetime(2015, 7, 4, 2, 34, 22), 3681165676],
#   [datetime.datetime(2015, 7, 5, 2, 34, 22), 3742137146],
#   [datetime.datetime(2015, 7, 6, 2, 34, 21), 3888172339],
#   [datetime.datetime(2015, 7, 7, 2, 34, 21), 3843241340],
#   [datetime.datetime(2015, 7, 8, 2, 34, 20), 3798502073],
#   [datetime.datetime(2015, 7, 9, 2, 34, 19), 3844791618],
#   [datetime.datetime(2015, 7, 10, 2, 34, 20), 3867029661],
#   [datetime.datetime(2015, 7, 11, 2, 34, 20), 4110352701],
#   [datetime.datetime(2015, 7, 12, 2, 34, 19), 4212905538],
#   [datetime.datetime(2015, 7, 13, 2, 34, 19), 4454664674],
#   [datetime.datetime(2015, 7, 14, 2, 34, 24), 4192223068],
#   [datetime.datetime(2015, 7, 15, 2, 39, 56), 4178565394],
#   [datetime.datetime(2015, 7, 16, 2, 39, 21), 4189402692],
#   [datetime.datetime(2015, 7, 17, 2, 39, 19), 4001980744],
#   [datetime.datetime(2015, 7, 18, 2, 39, 21), 4023355685],
#   [datetime.datetime(2015, 7, 19, 2, 44, 20), 3952584984],
#   [datetime.datetime(2015, 7, 20, 2, 49, 21), 3940416003],
#   [datetime.datetime(2015, 7, 21, 2, 49, 22), 4024532627],
#   [datetime.datetime(2015, 7, 22, 2, 59, 21), 3978914464],
#   [datetime.datetime(2015, 7, 23, 2, 59, 21), 3998474724],
#   [datetime.datetime(2015, 7, 24, 2, 59, 21), 3975213232],
#   [datetime.datetime(2015, 7, 25, 2, 59, 20), 4142634316],
#   [datetime.datetime(2015, 7, 26, 2, 59, 21), 4164345963],
#   [datetime.datetime(2015, 7, 27, 2, 59, 21), 4215400624],
#   [datetime.datetime(2015, 7, 28, 2, 59, 22), 4256097823],
#   [datetime.datetime(2015, 7, 29, 2, 59, 22), 4241127355],
#   [datetime.datetime(2015, 7, 30, 2, 59, 21), 4165297674],
#   [datetime.datetime(2015, 7, 31, 2, 59, 22), 4156876481],
#   [datetime.datetime(2015, 8, 1, 2, 59, 22), 4112500665],
#   [datetime.datetime(2015, 8, 2, 3, 4, 22), 4042133466],
#   [datetime.datetime(2015, 8, 3, 3, 4, 21), 4078449217],
#   [datetime.datetime(2015, 8, 4, 3, 4, 26), 4079086669],
#   [datetime.datetime(2015, 8, 5, 3, 14, 21), 4117595320],
#   [datetime.datetime(2015, 8, 6, 3, 14, 21), 4071191851],
#   [datetime.datetime(2015, 8, 7, 3, 14, 22), 4033878314],
#   [datetime.datetime(2015, 8, 8, 3, 14, 21), 4046202457],
#   [datetime.datetime(2015, 8, 9, 3, 14, 22), 3789713465],
#   [datetime.datetime(2015, 8, 10, 3, 14, 22), 3851303638],
#   [datetime.datetime(2015, 8, 11, 3, 14, 21), 3831151482],
#   [datetime.datetime(2015, 8, 12, 3, 29, 21), 3886143638],
#   [datetime.datetime(2015, 8, 13, 3, 29, 21), 3851673933],
#   [datetime.datetime(2015, 8, 14, 3, 29, 21), 3826343657],
# ...
#   [datetime.datetime(2015, 5, 2, 16, 39, 19), 15939300],
#   [datetime.datetime(2015, 5, 3, 16, 44, 19), 16861500],
#   [datetime.datetime(2015, 5, 4, 16, 44, 19), 16063800],
#   [datetime.datetime(2015, 5, 5, 17, 9, 18), 25902100],
#   [datetime.datetime(2015, 5, 6, 18, 49, 20), 17272400],
#   [datetime.datetime(2015, 5, 7, 18, 49, 20), 32649900],
#   [datetime.datetime(2015, 5, 8, 18, 49, 20), 32948700],
#   [datetime.datetime(2015, 5, 9, 18, 49, 20), 25349500],
#   [datetime.datetime(2015, 5, 10, 18, 49, 19), 15597600],
#   [datetime.datetime(2015, 5, 11, 18, 54, 20), 17472700],
#   [datetime.datetime(2015, 5, 12, 18, 59, 21), 21352400],
#   [datetime.datetime(2015, 5, 13, 18, 59, 22), 17839200],
#   [datetime.datetime(2015, 5, 14, 18, 59, 20), 28772200],
#   [datetime.datetime(2015, 5, 15, 18, 59, 25), 20008000],
#   [datetime.datetime(2015, 5, 16, 18, 59, 20), 12811900],
#   [datetime.datetime(2015, 5, 17, 18, 59, 20), 11257500],
#   [datetime.datetime(2015, 5, 18, 18, 59, 20), 12963900],
#   [datetime.datetime(2015, 5, 19, 19, 9, 23), 17644200],
#   [datetime.datetime(2015, 5, 20, 19, 14, 19), 15952000],
#   [datetime.datetime(2015, 5, 21, 19, 14, 21), 15400400],
#   [datetime.datetime(2015, 5, 22, 19, 14, 21), 19170400],
#   [datetime.datetime(2015, 5, 23, 19, 14, 20), 21821300],
#   [datetime.datetime(2015, 5, 24, 19, 14, 20), 12507600],
#   [datetime.datetime(2015, 5, 25, 19, 34, 21), 13777600],
#   [datetime.datetime(2015, 5, 26, 19, 59, 21), 15536800],
#   [datetime.datetime(2015, 5, 27, 20, 9, 20), 18473500],
#   [datetime.datetime(2015, 5, 28, 22, 54, 20), 13725800],
#   [datetime.datetime(2015, 5, 29, 22, 54, 21), 15242500],
#   [datetime.datetime(2015, 5, 30, 23, 9, 21), 14166700],
#   [datetime.datetime(2015, 5, 31, 23, 9, 21), 12519500],
#   [datetime.datetime(2015, 6, 1, 23, 24, 20), 25922900],
#   [datetime.datetime(2015, 6, 3, 0, 29, 20), 20742500],
#   [datetime.datetime(2015, 6, 4, 0, 29, 21), 17462200],
#   [datetime.datetime(2015, 6, 5, 0, 29, 20), 14461900],
#   [datetime.datetime(2015, 6, 6, 0, 29, 21), 18190200],
#   [datetime.datetime(2015, 6, 7, 1, 29, 20), 10568700],
#   [datetime.datetime(2015, 6, 8, 1, 29, 20), 13654600],
#   [datetime.datetime(2015, 6, 9, 1, 29, 21), 23342800],
#   [datetime.datetime(2015, 6, 10, 1, 29, 19), 28156800],
#   [datetime.datetime(2015, 6, 11, 1, 29, 20), 15904400],
#   [datetime.datetime(2015, 6, 12, 1, 29, 20), 14609500],
#   [datetime.datetime(2015, 6, 13, 1, 29, 26), 14004900],
#   [datetime.datetime(2015, 6, 14, 2, 29, 21), 12714400],
#   [datetime.datetime(2015, 6, 15, 2, 29, 23), 12266200],
#   [datetime.datetime(2015, 6, 16, 2, 29, 21), 20029300],
#   [datetime.datetime(2015, 6, 17, 2, 29, 20), 42924100],
#   [datetime.datetime(2015, 6, 18, 2, 29, 19), 42633100],
#   [datetime.datetime(2015, 6, 19, 2, 29, 20), 31076200],
#   [datetime.datetime(2015, 6, 20, 2, 29, 19), 24655600],
#   [datetime.datetime(2015, 6, 21, 2, 29, 20), 19823200],
#   [datetime.datetime(2015, 6, 22, 2, 34, 20), 10607100],
#   [datetime.datetime(2015, 6, 23, 2, 34, 21), 17576300],
#   [datetime.datetime(2015, 6, 24, 2, 34, 20), 15309800],
#   [datetime.datetime(2015, 6, 25, 2, 34, 20), 17090000],
#   [datetime.datetime(2015, 6, 26, 2, 34, 20), 15904600],
#   [datetime.datetime(2015, 6, 27, 2, 34, 21), 13769300],
#   [datetime.datetime(2015, 6, 28, 2, 34, 20), 20587900],
#   [datetime.datetime(2015, 6, 29, 2, 34, 21), 15025600],
#   [datetime.datetime(2015, 6, 30, 2, 34, 20), 34722300],
#   [datetime.datetime(2015, 7, 1, 2, 34, 27), 44669600],
#   [datetime.datetime(2015, 7, 2, 2, 34, 21), 26947900],
#   [datetime.datetime(2015, 7, 3, 2, 34, 20), 21435300],
#   [datetime.datetime(2015, 7, 4, 2, 34, 22), 19017900],
#   [datetime.datetime(2015, 7, 5, 2, 34, 22), 15464000],
#   [datetime.datetime(2015, 7, 6, 2, 34, 21), 44697100],
#   [datetime.datetime(2015, 7, 7, 2, 34, 21), 49703100],
#   [datetime.datetime(2015, 7, 8, 2, 34, 20), 27847400],
#   [datetime.datetime(2015, 7, 9, 2, 34, 19), 36849400],
#   [datetime.datetime(2015, 7, 10, 2, 34, 20), 40454400],
#   [datetime.datetime(2015, 7, 11, 2, 34, 20), 100412000],
#   [datetime.datetime(2015, 7, 12, 2, 34, 19), 40447000],
#   [datetime.datetime(2015, 7, 13, 2, 34, 19), 56392900],
#   [datetime.datetime(2015, 7, 14, 2, 34, 24), 61330500],
#   [datetime.datetime(2015, 7, 15, 2, 39, 56), 29467300],
#   [datetime.datetime(2015, 7, 16, 2, 39, 21), 29174900],
#   [datetime.datetime(2015, 7, 17, 2, 39, 19), 49482600],
#   [datetime.datetime(2015, 7, 18, 2, 39, 21), 27344700],
#   [datetime.datetime(2015, 7, 19, 2, 44, 20), 25371800],
#   [datetime.datetime(2015, 7, 20, 2, 49, 21), 15558600],
#   [datetime.datetime(2015, 7, 21, 2, 49, 22), 22273800],
#   [datetime.datetime(2015, 7, 22, 2, 59, 21), 23182500],
#   [datetime.datetime(2015, 7, 23, 2, 59, 21), 18615900],
#   [datetime.datetime(2015, 7, 24, 2, 59, 21), 18377800],
#   [datetime.datetime(2015, 7, 25, 2, 59, 20), 37326400],
#   [datetime.datetime(2015, 7, 26, 2, 59, 21), 20062200],
#   [datetime.datetime(2015, 7, 27, 2, 59, 21), 15984000],
#   [datetime.datetime(2015, 7, 28, 2, 59, 22), 31177800],
#   [datetime.datetime(2015, 7, 29, 2, 59, 22), 25193500],
#   [datetime.datetime(2015, 7, 30, 2, 59, 21), 24739600],
#   [datetime.datetime(2015, 7, 31, 2, 59, 22), 21319400],
#   [datetime.datetime(2015, 8, 1, 2, 59, 22), 23205300],
#   [datetime.datetime(2015, 8, 2, 3, 4, 22), 19310000],
#   [datetime.datetime(2015, 8, 3, 3, 4, 21), 17210200],
#   [datetime.datetime(2015, 8, 4, 3, 4, 26), 22122200],
#   [datetime.datetime(2015, 8, 5, 3, 14, 21), 21201300],
#   [datetime.datetime(2015, 8, 6, 3, 14, 21), 20604100],
#   [datetime.datetime(2015, 8, 7, 3, 14, 22), 17952300],
#   [datetime.datetime(2015, 8, 8, 3, 14, 21), 42342900],
#   [datetime.datetime(2015, 8, 9, 3, 14, 22), 58689800],
#   [datetime.datetime(2015, 8, 10, 3, 14, 22), 22285600],
#   [datetime.datetime(2015, 8, 11, 3, 14, 21), 20524000],
#   [datetime.datetime(2015, 8, 12, 3, 29, 21), 24977000],
#   [datetime.datetime(2015, 8, 13, 3, 29, 21), 26974200],
#   [datetime.datetime(2015, 8, 14, 3, 29, 21), 27216500],
#   [datetime.datetime(2015, 8, 15, 3, 29, 23), 27091900],
#   [datetime.datetime(2015, 8, 16, 3, 29, 20), 19510600],
#   [datetime.datetime(2015, 8, 17, 3, 29, 21), 29052400],
#   [datetime.datetime(2015, 8, 18, 3, 29, 20), 22034500],
#   [datetime.datetime(2015, 8, 19, 3, 29, 22), 63601000],
#   [datetime.datetime(2015, 8, 20, 3, 44, 21), 45257000],
#   [datetime.datetime(2015, 8, 21, 3, 44, 22), 30539300],
#   [datetime.datetime(2015, 8, 22, 3, 44, 21), 23355900],
#   [datetime.datetime(2015, 8, 23, 3, 49, 21), 22995600],
#   [datetime.datetime(2015, 8, 24, 3, 49, 21), 19533100],
#   [datetime.datetime(2015, 8, 25, 3, 54, 21), 65919600],
#   [datetime.datetime(2015, 8, 26, 3, 54, 20), 52402700],
#   [datetime.datetime(2015, 8, 27, 3, 54, 21), 31120600],
#   [datetime.datetime(2015, 8, 28, 3, 54, 21), 22965600],
#   [datetime.datetime(2015, 8, 29, 3, 54, 21), 29428400],
#   [datetime.datetime(2015, 8, 30, 4, 4, 21), 17820200],
#   [datetime.datetime(2015, 8, 31, 4, 4, 23), 18923200],
#   [datetime.datetime(2015, 9, 1, 4, 4, 20), 20222800],
#   [datetime.datetime(2015, 9, 2, 4, 4, 24), 20112300],
#   [datetime.datetime(2015, 9, 3, 4, 4, 21), 18480400],
#   [datetime.datetime(2015, 9, 4, 4, 4, 21), 18118800],
#   [datetime.datetime(2015, 9, 5, 4, 4, 23), 17494500],
#   [datetime.datetime(2015, 9, 6, 4, 4, 22), 19369500],
#   [datetime.datetime(2015, 9, 7, 4, 4, 22), 23695600],
#   [datetime.datetime(2015, 9, 8, 4, 4, 21), 19512600],
#   [datetime.datetime(2015, 9, 9, 4, 14, 21), 24843300],
#   [datetime.datetime(2015, 9, 10, 4, 19, 21), 21024500],
#   [datetime.datetime(2015, 9, 11, 4, 19, 23), 19597800],
#   [datetime.datetime(2015, 9, 12, 4, 19, 21), 16826300],
#   [datetime.datetime(2015, 9, 13, 4, 29, 22), 16206200],
#   [datetime.datetime(2015, 9, 14, 4, 29, 21), 17506600],
#   [datetime.datetime(2015, 9, 15, 4, 29, 23), 18772300],
#   [datetime.datetime(2015, 9, 16, 4, 29, 21), 16233700],
#   [datetime.datetime(2015, 9, 17, 4, 29, 21), 18810900],
#   [datetime.datetime(2015, 9, 19, 6, 59, 23), 16217800],
#   [datetime.datetime(2015, 9, 20, 7, 14, 23), 11954800],
#   [datetime.datetime(2015, 9, 21, 10, 24, 27), 14191700],
#   [datetime.datetime(2015, 9, 22, 12, 14, 22), 22857700],
#   [datetime.datetime(2015, 9, 23, 12, 14, 22), 18445900],
#   [datetime.datetime(2015, 9, 24, 12, 14, 40), 18486500],
#   [datetime.datetime(2015, 9, 25, 12, 39, 22), 25172600],
#   [datetime.datetime(2015, 9, 26, 13, 54, 24), 14410300],
#   [datetime.datetime(2015, 9, 27, 13, 59, 22), 13062400],
#   [datetime.datetime(2015, 9, 28, 13, 59, 22), 20202700],
#   [datetime.datetime(2015, 9, 29, 14, 4, 23), 22663000],
#   [datetime.datetime(2015, 9, 30, 14, 4, 23), 20512900],
#   [datetime.datetime(2015, 10, 1, 14, 4, 22), 16936200],
#   [datetime.datetime(2015, 10, 2, 14, 4, 22), 20239100],
#   [datetime.datetime(2015, 10, 3, 14, 19, 21), 17462600],
#   [datetime.datetime(2015, 10, 4, 14, 19, 22), 12642100],
#   [datetime.datetime(2015, 10, 5, 14, 19, 24), 15530500],
#   [datetime.datetime(2015, 10, 6, 14, 24, 23), 22365900],
#   [datetime.datetime(2015, 10, 7, 14, 24, 22), 26893700],
#   [datetime.datetime(2015, 10, 8, 14, 24, 24), 19671700],
#   [datetime.datetime(2015, 10, 9, 14, 24, 21), 18560000],
#   [datetime.datetime(2015, 10, 10, 14, 24, 22), 16000800],
#   [datetime.datetime(2015, 10, 11, 14, 39, 22), 11433600],
#   [datetime.datetime(2015, 10, 12, 14, 39, 22), 18033400],
#   [datetime.datetime(2015, 10, 13, 14, 39, 22), 24721800],
#   [datetime.datetime(2015, 10, 14, 14, 39, 23), 23232600],
#   [datetime.datetime(2015, 10, 15, 14, 44, 24), 26793100],
#   [datetime.datetime(2015, 10, 16, 14, 44, 45), 24415000],
#   [datetime.datetime(2015, 10, 17, 14, 54, 34), 44097300],
#   [datetime.datetime(2015, 10, 18, 14, 54, 24), 29558400],
#   [datetime.datetime(2015, 10, 19, 14, 54, 23), 25714300],
#   [datetime.datetime(2015, 10, 20, 14, 54, 20), 26078800],
#   [datetime.datetime(2015, 10, 21, 14, 54, 21), 29059300],
#   [datetime.datetime(2015, 10, 22, 14, 54, 20), 30156000],
#   [datetime.datetime(2015, 10, 23, 14, 54, 23), 32351800],
#   [datetime.datetime(2015, 10, 24, 14, 54, 22), 24084000],
#   [datetime.datetime(2015, 10, 25, 14, 19, 21), 35526900],
#   [datetime.datetime(2015, 10, 26, 14, 19, 21), 40169900],
#   [datetime.datetime(2015, 10, 27, 14, 19, 22), 35514700],
#   [datetime.datetime(2015, 10, 28, 14, 19, 20), 47347600],
#   [datetime.datetime(2015, 10, 29, 14, 19, 21), 51994800],
#   [datetime.datetime(2015, 10, 30, 14, 19, 20), 89068400],
#   [datetime.datetime(2015, 10, 31, 14, 54, 21), 41206200],
#   [datetime.datetime(2015, 11, 1, 15, 54, 21), 43893300],
#   [datetime.datetime(2015, 11, 2, 15, 54, 21), 56898600],
#   [datetime.datetime(2015, 11, 3, 15, 54, 19), 162207000],
#   [datetime.datetime(2015, 11, 4, 16, 4, 22), 293695000],
#   [datetime.datetime(2015, 11, 5, 16, 4, 20), 221063000],
#   [datetime.datetime(2015, 11, 6, 16, 4, 19), 121795000],
#   [datetime.datetime(2015, 11, 7, 16, 4, 20), 83953100],
#   [datetime.datetime(2015, 11, 8, 16, 39, 20), 44625800],
#   [datetime.datetime(2015, 11, 9, 16, 39, 25), 71774400],
#   [datetime.datetime(2015, 11, 10, 16, 39, 26), 68662800],
#   [datetime.datetime(2015, 11, 11, 16, 39, 21), 124080000],
#   [datetime.datetime(2015, 11, 12, 16, 39, 26), 81853000],
#   [datetime.datetime(2015, 11, 13, 16, 39, 27), 54658200],
#   [datetime.datetime(2015, 11, 14, 17, 14, 20), 38263800],
#   [datetime.datetime(2015, 11, 15, 17, 14, 22), 39008100],
#   [datetime.datetime(2015, 11, 16, 17, 14, 22), 42884200],
#   [datetime.datetime(2015, 11, 17, 17, 14, 20), 59097000],
#   [datetime.datetime(2015, 11, 18, 17, 14, 29), 42213700],
#   [datetime.datetime(2015, 11, 19, 17, 14, 21), 43553200],
#   [datetime.datetime(2015, 11, 20, 17, 14, 21), 53429100],
#   [datetime.datetime(2015, 11, 21, 18, 9, 45), 29623700],
#   [datetime.datetime(2015, 11, 22, 18, 9, 20), 21826600],
#   [datetime.datetime(2015, 11, 23, 18, 9, 25), 24535100],
#   [datetime.datetime(2015, 11, 24, 18, 14, 20), 28723900],
#   [datetime.datetime(2015, 11, 25, 18, 14, 20), 35175500],
#   [datetime.datetime(2015, 11, 26, 18, 14, 21), 97328600],
#   [datetime.datetime(2015, 11, 27, 22, 44, 19), 60590100],
#   [datetime.datetime(2015, 11, 28, 22, 44, 22), 37239800],
#   [datetime.datetime(2015, 11, 29, 22, 44, 22), 32339100],
#   [datetime.datetime(2015, 11, 30, 22, 44, 20), 75583000],
#   [datetime.datetime(2015, 12, 1, 22, 44, 23), 62588000],
#   [datetime.datetime(2015, 12, 2, 22, 44, 33), 52641600],
#   [datetime.datetime(2015, 12, 3, 22, 44, 20), 51221800],
#   [datetime.datetime(2015, 12, 4, 22, 44, 20), 35761100],
#   [datetime.datetime(2015, 12, 5, 22, 44, 24), 53679900],
#   [datetime.datetime(2015, 12, 6, 22, 44, 20), 88056200],
#   [datetime.datetime(2015, 12, 7, 22, 44, 20), 64776800],
#   [datetime.datetime(2015, 12, 8, 22, 44, 24), 42450200],
#   [datetime.datetime(2015, 12, 9, 22, 44, 23), 101683000],
#   [datetime.datetime(2015, 12, 10, 22, 44, 22), 53263400],
#   [datetime.datetime(2015, 12, 11, 22, 44, 21), 104496000],
#   [datetime.datetime(2015, 12, 12, 22, 44, 23), 131176000],
#   [datetime.datetime(2015, 12, 13, 22, 44, 23), 57806600],
#   [datetime.datetime(2015, 12, 14, 22, 44, 24), 128529000],
#   [datetime.datetime(2015, 12, 15, 22, 49, 22), 80492700],
#   [datetime.datetime(2015, 12, 16, 22, 59, 23), 111483000],
#   [datetime.datetime(2015, 12, 17, 22, 59, 20), 48845100],
#   [datetime.datetime(2015, 12, 18, 23, 14, 22), 58257500],
#   [datetime.datetime(2015, 12, 19, 23, 24, 22), 48601100],
#   [datetime.datetime(2015, 12, 20, 23, 24, 20), 74004600],
#   [datetime.datetime(2015, 12, 21, 23, 24, 24), 75809300],
#   [datetime.datetime(2015, 12, 22, 23, 29, 22), 52039000],
#   [datetime.datetime(2015, 12, 23, 23, 29, 22), 47354600],
#   [datetime.datetime(2015, 12, 24, 23, 29, 20), 57236500],
#   [datetime.datetime(2015, 12, 25, 23, 29, 21), 39143500],
#   [datetime.datetime(2015, 12, 26, 23, 29, 22), 114925000],
#   [datetime.datetime(2015, 12, 27, 23, 29, 22), 53393600],
#   [datetime.datetime(2015, 12, 28, 23, 29, 21), 49089900],
#   [datetime.datetime(2015, 12, 29, 23, 29, 22), 50244100],
#   [datetime.datetime(2015, 12, 30, 23, 29, 22), 48589900],
#   [datetime.datetime(2015, 12, 31, 23, 29, 22), 45929800],
#   [datetime.datetime(2016, 1, 1, 23, 29, 21), 35900100],
#   [datetime.datetime(2016, 1, 2, 23, 29, 23), 30177000],
#   [datetime.datetime(2016, 1, 3, 23, 29, 22), 38378900],
#   [datetime.datetime(2016, 1, 4, 23, 29, 23), 38174500],
#   [datetime.datetime(2016, 1, 5, 23, 29, 18), 34971300],
#   [datetime.datetime(2016, 1, 6, 23, 29, 16), 33744600],
#   [datetime.datetime(2016, 1, 7, 23, 34, 18), 81552100],
#   [datetime.datetime(2016, 1, 8, 23, 34, 17), 61907500],
#   [datetime.datetime(2016, 1, 9, 23, 34, 16), 32339500],
#   [datetime.datetime(2016, 1, 10, 23, 39, 17), 35198400],
#   [datetime.datetime(2016, 1, 11, 23, 39, 19), 41045900],
#   [datetime.datetime(2016, 1, 12, 23, 54, 19), 99356700],
#   [datetime.datetime(2016, 1, 13, 23, 54, 19), 180327000],
#   [datetime.datetime(2016, 1, 14, 23, 54, 19), 43258800],
#   [datetime.datetime(2016, 1, 15, 23, 54, 19), 142114000],
#   [datetime.datetime(2016, 1, 16, 23, 54, 19), 129294000],
#   [datetime.datetime(2016, 1, 18, 0, 4, 17), 47441400],
#   [datetime.datetime(2016, 1, 19, 0, 4, 19), 56199800],
#   [datetime.datetime(2016, 1, 20, 0, 4, 19), 46402600],
#   [datetime.datetime(2016, 1, 21, 0, 4, 19), 109001000],
#   [datetime.datetime(2016, 1, 22, 0, 19, 19), 73754000],
#   [datetime.datetime(2016, 1, 23, 0, 19, 23), 88051500],
#   [datetime.datetime(2016, 1, 24, 0, 29, 24), 56582800],
#   [datetime.datetime(2016, 1, 25, 0, 39, 18), 55545300],
#   [datetime.datetime(2016, 1, 26, 0, 39, 19), 58803600],
#   [datetime.datetime(2016, 1, 27, 0, 44, 22), 57754300],
#   [datetime.datetime(2016, 1, 28, 0, 54, 18), 47575500],
#   [datetime.datetime(2016, 1, 29, 0, 54, 18), 59191900],
#   [datetime.datetime(2016, 1, 30, 0, 54, 18), 86293700],
#   [datetime.datetime(2016, 1, 31, 0, 54, 18), 30274600],
#   [datetime.datetime(2016, 2, 1, 0, 54, 19), 37543600],
#   [datetime.datetime(2016, 2, 2, 0, 54, 20), 51821200],
#   [datetime.datetime(2016, 2, 3, 0, 54, 19), 40417700],
#   [datetime.datetime(2016, 2, 4, 0, 54, 20), 45872000],
#   [datetime.datetime(2016, 2, 5, 0, 54, 20), 69224300],
#   [datetime.datetime(2016, 2, 6, 1, 19, 37), 37850800],
#   ...]}

# %% [markdown]
# #### `graphs.global_cap([bitcoin=True, start=None, end=None])`
# Display data from [total market capitalization charts](https://coinmarketcap.com/charts/), including or excluding bitcoin:

# %%
cmc.graphs.global_cap(bitcoin=False)
# Out:
# {'market_cap_by_available_supply': [[datetime.datetime(2013, 4, 28, 20, 47),
#    91346900.0],
#   [datetime.datetime(2013, 4, 29, 20, 47), 94087500.0],
#   [datetime.datetime(2013, 4, 30, 20, 47), 90416200.0],
#   [datetime.datetime(2013, 5, 1, 20, 47), 78877300.0],
#   [datetime.datetime(2013, 5, 2, 20, 47), 72337900.0],
#   [datetime.datetime(2013, 5, 3, 20, 47), 66800000.0],
#   [datetime.datetime(2013, 5, 4, 20, 47), 79306600.0],
#   [datetime.datetime(2013, 5, 5, 20, 47), 82748700.0],
#   [datetime.datetime(2013, 5, 6, 20, 47), 80775900.0],
#   [datetime.datetime(2013, 5, 7, 20, 47), 70380300.0],
#   [datetime.datetime(2013, 5, 8, 20, 47), 78779600.0],
#   [datetime.datetime(2013, 5, 9, 20, 47), 77892400.0],
#   [datetime.datetime(2013, 5, 10, 20, 47), 79292400.0],
#   [datetime.datetime(2013, 5, 11, 20, 47), 75550100.0],
#   [datetime.datetime(2013, 5, 12, 20, 47), 72145100.0],
#   [datetime.datetime(2013, 5, 13, 20, 47), 73187500.0],
#   [datetime.datetime(2013, 5, 14, 20, 47), 72419800.0],
#   [datetime.datetime(2013, 5, 15, 20, 47), 65450200.0],
#   [datetime.datetime(2013, 5, 16, 20, 47), 63753400.0],
#   [datetime.datetime(2013, 5, 17, 20, 47), 70536900.0],
#   [datetime.datetime(2013, 5, 18, 20, 47), 71584400.0],
#   [datetime.datetime(2013, 5, 19, 20, 47), 72028600.0],
#   [datetime.datetime(2013, 5, 20, 20, 47), 71479800.0],
#   [datetime.datetime(2013, 5, 21, 20, 47), 71193200.0],
#   [datetime.datetime(2013, 5, 22, 20, 47), 71162700.0],
#   [datetime.datetime(2013, 5, 23, 20, 47), 71512200.0],
#   [datetime.datetime(2013, 5, 24, 20, 47), 70684600.0],
#   [datetime.datetime(2013, 5, 25, 20, 47), 70411100.0],
#   [datetime.datetime(2013, 5, 26, 20, 47), 73617500.0],
#   [datetime.datetime(2013, 5, 27, 20, 47), 69441300.0],
#   [datetime.datetime(2013, 5, 28, 20, 47), 69415000.0],
#   [datetime.datetime(2013, 5, 29, 20, 47), 68449400.0],
#   [datetime.datetime(2013, 5, 30, 20, 47), 66355500.0],
#   [datetime.datetime(2013, 5, 31, 20, 47), 63016300.0],
#   [datetime.datetime(2013, 6, 1, 20, 47), 63213400.0],
#   [datetime.datetime(2013, 6, 2, 20, 47), 59895000.0],
#   [datetime.datetime(2013, 6, 3, 20, 47), 60090200.0],
#   [datetime.datetime(2013, 6, 4, 20, 47), 63094600.0],
#   [datetime.datetime(2013, 6, 5, 20, 47), 63521200.0],
#   [datetime.datetime(2013, 6, 6, 20, 47), 62039600.0],
#   [datetime.datetime(2013, 6, 7, 20, 47), 58049800.0],
#   [datetime.datetime(2013, 6, 8, 20, 47), 57482400.0],
#   [datetime.datetime(2013, 6, 9, 20, 47), 52057800.0],
#   [datetime.datetime(2013, 6, 10, 20, 47), 54893200.0],
#   [datetime.datetime(2013, 6, 11, 20, 47), 52693800.0],
#   [datetime.datetime(2013, 6, 12, 20, 47), 54045100.0],
#   [datetime.datetime(2013, 6, 13, 20, 47), 53785900.0],
#   [datetime.datetime(2013, 6, 14, 20, 47), 49326300.0],
#   [datetime.datetime(2013, 6, 15, 20, 47), 48439400.0],
#   [datetime.datetime(2013, 6, 16, 20, 47), 46793200.0],
#   [datetime.datetime(2013, 6, 17, 20, 47), 49772100.0],
#   [datetime.datetime(2013, 6, 18, 20, 47), 51298700.0],
#   [datetime.datetime(2013, 6, 19, 20, 47), 52250400.0],
#   [datetime.datetime(2013, 6, 20, 20, 47), 54030600.0],
#   [datetime.datetime(2013, 6, 21, 20, 47), 58291300.0],
#   [datetime.datetime(2013, 6, 22, 20, 47), 70666600.0],
#   [datetime.datetime(2013, 6, 23, 20, 47), 67268700.0],
#   [datetime.datetime(2013, 6, 24, 20, 47), 61286100.0],
#   [datetime.datetime(2013, 6, 25, 20, 47), 62112600.0],
#   [datetime.datetime(2013, 6, 26, 20, 47), 62670600.0],
#   [datetime.datetime(2013, 6, 27, 20, 47), 64751900.0],
#   [datetime.datetime(2013, 6, 28, 20, 47), 61704800.0],
#   [datetime.datetime(2013, 6, 29, 20, 47), 62002900.0],
#   [datetime.datetime(2013, 6, 30, 20, 47), 64914000.0],
#   [datetime.datetime(2013, 7, 1, 20, 47), 65267700.0],
#   [datetime.datetime(2013, 7, 2, 20, 47), 63560800.0],
#   [datetime.datetime(2013, 7, 3, 20, 47), 63311200.0],
#   [datetime.datetime(2013, 7, 4, 20, 47), 60904300.0],
#   [datetime.datetime(2013, 7, 5, 20, 47), 54104500.0],
#   [datetime.datetime(2013, 7, 6, 20, 47), 55867900.0],
#   [datetime.datetime(2013, 7, 7, 20, 47), 57038100.0],
#   [datetime.datetime(2013, 7, 8, 20, 47), 60448000.0],
#   [datetime.datetime(2013, 7, 9, 20, 47), 59211900.0],
#   [datetime.datetime(2013, 7, 10, 20, 47), 59959900.0],
#   [datetime.datetime(2013, 7, 11, 20, 47), 62694500.0],
#   [datetime.datetime(2013, 7, 12, 20, 47), 65547400.0],
#   [datetime.datetime(2013, 7, 13, 20, 47), 65541800.0],
#   [datetime.datetime(2013, 7, 14, 20, 47), 66305200.0],
#   [datetime.datetime(2013, 7, 15, 20, 47), 68775700.0],
#   [datetime.datetime(2013, 7, 16, 20, 47), 71409200.0],
#   [datetime.datetime(2013, 7, 17, 20, 47), 71888600.0],
#   [datetime.datetime(2013, 7, 18, 20, 47), 67383000.0],
#   [datetime.datetime(2013, 7, 19, 20, 47), 70173300.0],
#   [datetime.datetime(2013, 7, 20, 20, 47), 70048200.0],
#   [datetime.datetime(2013, 7, 21, 20, 47), 67061200.0],
#   [datetime.datetime(2013, 7, 22, 20, 47), 68840500.0],
#   [datetime.datetime(2013, 7, 23, 20, 47), 69979800.0],
#   [datetime.datetime(2013, 7, 24, 20, 47), 70408700.0],
#   [datetime.datetime(2013, 7, 25, 20, 47), 71293500.0],
#   [datetime.datetime(2013, 7, 26, 20, 47), 70146100.0],
#   [datetime.datetime(2013, 7, 27, 20, 47), 69775900.0],
#   [datetime.datetime(2013, 7, 28, 20, 47), 70738400.0],
#   [datetime.datetime(2013, 7, 29, 20, 47), 72318200.0],
#   [datetime.datetime(2013, 7, 30, 20, 47), 70811300.0],
#   [datetime.datetime(2013, 7, 31, 20, 47), 70454400.0],
#   [datetime.datetime(2013, 8, 1, 20, 47), 71378500.0],
#   [datetime.datetime(2013, 8, 2, 20, 47), 71961800.0],
#   [datetime.datetime(2013, 8, 3, 20, 47), 72525500.0],
#   [datetime.datetime(2013, 8, 4, 20, 47), 120755000.0],
#   [datetime.datetime(2013, 8, 5, 20, 47), 116002000.0],
#   [datetime.datetime(2013, 8, 6, 20, 47), 107433000.0],
#   [datetime.datetime(2013, 8, 7, 20, 47), 105371000.0],
#   [datetime.datetime(2013, 8, 8, 20, 47), 101976000.0],
#   [datetime.datetime(2013, 8, 9, 20, 47), 102527000.0],
#   [datetime.datetime(2013, 8, 10, 20, 47), 101450000.0],
#   [datetime.datetime(2013, 8, 11, 20, 47), 102650000.0],
#   [datetime.datetime(2013, 8, 12, 20, 47), 102088000.0],
#   [datetime.datetime(2013, 8, 13, 20, 47), 104928000.0],
#   [datetime.datetime(2013, 8, 14, 20, 47), 102750000.0],
#   [datetime.datetime(2013, 8, 15, 20, 47), 98306500.0],
#   [datetime.datetime(2013, 8, 16, 20, 47), 94015300.0],
#   [datetime.datetime(2013, 8, 17, 20, 47), 116082000.0],
#   [datetime.datetime(2013, 8, 18, 20, 47), 122494000.0],
#   [datetime.datetime(2013, 8, 19, 20, 47), 116533000.0],
#   [datetime.datetime(2013, 8, 20, 20, 47), 122173000.0],
#   [datetime.datetime(2013, 8, 21, 20, 47), 120963000.0],
#   [datetime.datetime(2013, 8, 22, 20, 47), 118290000.0],
#   [datetime.datetime(2013, 8, 23, 20, 47), 111822000.0],
#   [datetime.datetime(2013, 8, 24, 20, 47), 115540000.0],
#   [datetime.datetime(2013, 8, 25, 20, 47), 115933000.0],
#   [datetime.datetime(2013, 8, 26, 20, 47), 120281000.0],
#   [datetime.datetime(2013, 8, 27, 20, 47), 117435000.0],
#   [datetime.datetime(2013, 8, 28, 20, 47), 118145000.0],
#   [datetime.datetime(2013, 8, 29, 20, 47), 116302000.0],
#   [datetime.datetime(2013, 8, 30, 20, 47), 118211000.0],
#   [datetime.datetime(2013, 8, 31, 20, 47), 114599000.0],
#   [datetime.datetime(2013, 9, 1, 20, 47), 113722000.0],
#   [datetime.datetime(2013, 9, 2, 20, 47), 113379000.0],
#   [datetime.datetime(2013, 9, 3, 20, 47), 112444000.0],
#   [datetime.datetime(2013, 9, 4, 20, 47), 119650000.0],
#   [datetime.datetime(2013, 9, 5, 20, 47), 120118000.0],
#   [datetime.datetime(2013, 9, 6, 20, 47), 117776000.0],
#   [datetime.datetime(2013, 9, 7, 20, 47), 120145000.0],
#   [datetime.datetime(2013, 9, 8, 20, 47), 120866000.0],
#   [datetime.datetime(2013, 9, 9, 20, 47), 122974000.0],
#   [datetime.datetime(2013, 9, 10, 20, 47), 117252000.0],
#   [datetime.datetime(2013, 9, 11, 20, 47), 121176000.0],
#   [datetime.datetime(2013, 9, 12, 20, 47), 122415000.0],
#   [datetime.datetime(2013, 9, 13, 20, 47), 124787000.0],
#   [datetime.datetime(2013, 9, 14, 20, 47), 120295000.0],
#   [datetime.datetime(2013, 9, 15, 20, 47), 121615000.0],
#   [datetime.datetime(2013, 9, 16, 20, 47), 126221000.0],
#   [datetime.datetime(2013, 9, 17, 20, 47), 145375000.0],
#   [datetime.datetime(2013, 9, 18, 20, 47), 154496000.0],
#   [datetime.datetime(2013, 9, 19, 20, 47), 155768000.0],
#   [datetime.datetime(2013, 9, 20, 20, 47), 147692000.0],
#   [datetime.datetime(2013, 9, 21, 20, 47), 145475000.0],
#   [datetime.datetime(2013, 9, 22, 20, 47), 148859000.0],
#   [datetime.datetime(2013, 9, 23, 20, 47), 147103000.0],
#   [datetime.datetime(2013, 9, 24, 20, 47), 147768000.0],
#   [datetime.datetime(2013, 9, 25, 20, 47), 149735000.0],
#   [datetime.datetime(2013, 9, 26, 20, 47), 157864000.0],
#   [datetime.datetime(2013, 9, 27, 20, 47), 181970000.0],
#   [datetime.datetime(2013, 9, 28, 20, 47), 175348000.0],
#   [datetime.datetime(2013, 9, 29, 20, 47), 171872000.0],
#   [datetime.datetime(2013, 9, 30, 20, 47), 152510000.0],
#   [datetime.datetime(2013, 10, 1, 20, 47), 151984000.0],
#   [datetime.datetime(2013, 10, 2, 20, 47), 122049000.0],
#   [datetime.datetime(2013, 10, 3, 20, 47), 131262000.0],
#   [datetime.datetime(2013, 10, 4, 20, 47), 144173000.0],
#   [datetime.datetime(2013, 10, 5, 20, 47), 142499000.0],
#   [datetime.datetime(2013, 10, 6, 20, 47), 145579000.0],
#   [datetime.datetime(2013, 10, 7, 20, 47), 138501000.0],
#   [datetime.datetime(2013, 10, 8, 20, 47), 138282000.0],
#   [datetime.datetime(2013, 10, 9, 20, 47), 140319000.0],
#   [datetime.datetime(2013, 10, 10, 20, 47), 143336000.0],
#   [datetime.datetime(2013, 10, 11, 20, 47), 137481000.0],
#   [datetime.datetime(2013, 10, 12, 20, 47), 141064000.0],
#   [datetime.datetime(2013, 10, 13, 20, 47), 134396000.0],
#   [datetime.datetime(2013, 10, 14, 20, 47), 131778000.0],
#   [datetime.datetime(2013, 10, 15, 20, 47), 125420000.0],
#   [datetime.datetime(2013, 10, 16, 20, 47), 120186000.0],
#   [datetime.datetime(2013, 10, 17, 20, 47), 126267000.0],
#   [datetime.datetime(2013, 10, 18, 20, 47), 122653000.0],
#   [datetime.datetime(2013, 10, 19, 20, 47), 115056000.0],
#   [datetime.datetime(2013, 10, 20, 20, 47), 113817000.0],
#   [datetime.datetime(2013, 10, 21, 20, 47), 110497000.0],
#   [datetime.datetime(2013, 10, 22, 20, 47), 110310000.0],
#   [datetime.datetime(2013, 10, 23, 20, 47), 128863000.0],
#   [datetime.datetime(2013, 10, 24, 20, 47), 135405000.0],
#   [datetime.datetime(2013, 10, 25, 20, 47), 121996000.0],
#   [datetime.datetime(2013, 10, 26, 20, 47), 116569000.0],
#   [datetime.datetime(2013, 10, 27, 19, 47), 118288000.0],
#   [datetime.datetime(2013, 10, 28, 19, 47), 115291000.0],
#   [datetime.datetime(2013, 10, 29, 19, 47), 115368000.0],
#   [datetime.datetime(2013, 10, 30, 19, 47), 117847000.0],
#   [datetime.datetime(2013, 10, 31, 19, 47), 119052000.0],
#   [datetime.datetime(2013, 11, 1, 19, 47), 122805000.0],
#   [datetime.datetime(2013, 11, 2, 19, 47), 130672000.0],
#   [datetime.datetime(2013, 11, 3, 19, 47), 145194000.0],
#   [datetime.datetime(2013, 11, 4, 19, 47), 149382000.0],
#   [datetime.datetime(2013, 11, 5, 19, 47), 148046000.0],
#   [datetime.datetime(2013, 11, 6, 19, 47), 164656000.0],
#   [datetime.datetime(2013, 11, 7, 19, 47), 194376000.0],
#   [datetime.datetime(2013, 11, 8, 19, 47), 218271000.0],
#   [datetime.datetime(2013, 11, 9, 19, 47), 207404000.0],
#   [datetime.datetime(2013, 11, 10, 19, 47), 171624000.0],
#   [datetime.datetime(2013, 11, 11, 19, 47), 188315000.0],
#   [datetime.datetime(2013, 11, 12, 19, 47), 194546000.0],
#   [datetime.datetime(2013, 11, 13, 19, 47), 214283000.0],
#   [datetime.datetime(2013, 11, 14, 19, 47), 204296000.0],
#   [datetime.datetime(2013, 11, 15, 19, 47), 208820000.0],
#   [datetime.datetime(2013, 11, 16, 19, 47), 210126000.0],
#   [datetime.datetime(2013, 11, 17, 19, 47), 213943000.0],
#   [datetime.datetime(2013, 11, 18, 19, 47), 327716000.0],
#   [datetime.datetime(2013, 11, 19, 19, 47), 299383000.0],
#   [datetime.datetime(2013, 11, 20, 19, 47), 283783000.0],
#   [datetime.datetime(2013, 11, 21, 19, 47), 350201000.0],
#   [datetime.datetime(2013, 11, 22, 19, 47), 384482000.0],
#   [datetime.datetime(2013, 11, 23, 19, 47), 430926000.0],
#   [datetime.datetime(2013, 11, 24, 19, 47), 436831000.0],
#   [datetime.datetime(2013, 11, 25, 19, 47), 500277000.0],
#   [datetime.datetime(2013, 11, 26, 19, 47), 802841000.0],
#   [datetime.datetime(2013, 11, 27, 19, 47), 1047390000.0],
#   [datetime.datetime(2013, 11, 28, 19, 47), 1455110000.0],
#   [datetime.datetime(2013, 11, 29, 19, 47), 1456280000.0],
#   [datetime.datetime(2013, 11, 30, 19, 47), 1678780000.0],
#   [datetime.datetime(2013, 12, 1, 19, 47), 1606220000.0],
#   [datetime.datetime(2013, 12, 2, 19, 47), 1533610000.0],
#   [datetime.datetime(2013, 12, 3, 19, 47), 1643150000.0],
#   [datetime.datetime(2013, 12, 4, 19, 47), 1922280000.0],
#   [datetime.datetime(2013, 12, 5, 19, 47), 1793890000.0],
#   [datetime.datetime(2013, 12, 6, 19, 47), 1391580000.0],
#   [datetime.datetime(2013, 12, 7, 19, 47), 1113350000.0],
#   [datetime.datetime(2013, 12, 8, 19, 47), 1124000000.0],
#   [datetime.datetime(2013, 12, 9, 19, 47), 1405800000.0],
#   [datetime.datetime(2013, 12, 10, 19, 47), 1624970000.0],
#   [datetime.datetime(2013, 12, 11, 19, 47), 1419110000.0],
#   [datetime.datetime(2013, 12, 12, 19, 47), 1389540000.0],
#   [datetime.datetime(2013, 12, 13, 19, 47), 1385360000.0],
#   [datetime.datetime(2013, 12, 14, 19, 47), 1338820000.0],
#   [datetime.datetime(2013, 12, 15, 19, 47), 1329440000.0],
#   [datetime.datetime(2013, 12, 16, 19, 47), 1088160000.0],
#   [datetime.datetime(2013, 12, 17, 19, 47), 964254000.0],
#   [datetime.datetime(2013, 12, 18, 19, 47), 722720000.0],
#   [datetime.datetime(2013, 12, 19, 19, 47), 813604000.0],
#   [datetime.datetime(2013, 12, 20, 19, 47), 877874000.0],
#   [datetime.datetime(2013, 12, 21, 19, 47), 826229000.0],
#   [datetime.datetime(2013, 12, 22, 19, 47), 848677000.0],
#   [datetime.datetime(2013, 12, 23, 19, 47), 853021000.0],
#   [datetime.datetime(2013, 12, 24, 19, 47), 874026000.0],
#   [datetime.datetime(2013, 12, 25, 19, 47), 1059850000.0],
#   [datetime.datetime(2013, 12, 26, 19, 47), 1287890000.0],
#   [datetime.datetime(2013, 12, 27, 19, 47), 1207710000.0],
#   [datetime.datetime(2013, 12, 28, 19, 47), 1195660000.0],
#   [datetime.datetime(2013, 12, 29, 19, 47), 1233030000.0],
#   [datetime.datetime(2013, 12, 30, 19, 47), 1316440000.0],
#   [datetime.datetime(2013, 12, 31, 19, 47), 1306210000.0],
#   [datetime.datetime(2014, 1, 1, 19, 47), 1342220000.0],
#   [datetime.datetime(2014, 1, 2, 19, 47), 1410630000.0],
#   [datetime.datetime(2014, 1, 3, 19, 47), 1373160000.0],
#   [datetime.datetime(2014, 1, 4, 19, 47), 1426020000.0],
#   [datetime.datetime(2014, 1, 5, 19, 47), 1463510000.0],
#   [datetime.datetime(2014, 1, 6, 19, 47), 1485140000.0],
#   [datetime.datetime(2014, 1, 7, 19, 47), 1345630000.0],
#   [datetime.datetime(2014, 1, 8, 19, 47), 1257160000.0],
#   [datetime.datetime(2014, 1, 9, 19, 47), 1208980000.0],
#   [datetime.datetime(2014, 1, 10, 19, 47), 1251870000.0],
#   [datetime.datetime(2014, 1, 11, 19, 47), 1336960000.0],
#   [datetime.datetime(2014, 1, 12, 19, 47), 1270820000.0],
#   [datetime.datetime(2014, 1, 13, 19, 47), 1184550000.0],
#   [datetime.datetime(2014, 1, 14, 19, 47), 1187880000.0],
#   [datetime.datetime(2014, 1, 15, 19, 47), 1262240000.0],
#   [datetime.datetime(2014, 1, 16, 19, 47), 1230020000.0],
#   [datetime.datetime(2014, 1, 17, 19, 47), 1167320000.0],
#   [datetime.datetime(2014, 1, 18, 19, 47), 1223270000.0],
#   [datetime.datetime(2014, 1, 19, 19, 47), 1264300000.0],
#   [datetime.datetime(2014, 1, 20, 19, 47), 1328450000.0],
#   [datetime.datetime(2014, 1, 21, 19, 47), 1357510000.0],
#   [datetime.datetime(2014, 1, 22, 19, 47), 1268330000.0],
#   [datetime.datetime(2014, 1, 23, 19, 47), 1238530000.0],
#   [datetime.datetime(2014, 1, 24, 19, 47), 1158590000.0],
#   [datetime.datetime(2014, 1, 25, 19, 47), 1279390000.0],
#   [datetime.datetime(2014, 1, 26, 19, 47), 1342780000.0],
#   [datetime.datetime(2014, 1, 27, 19, 47), 1192430000.0],
#   [datetime.datetime(2014, 1, 28, 19, 47), 1209400000.0],
#   [datetime.datetime(2014, 1, 29, 19, 47), 1201490000.0],
#   [datetime.datetime(2014, 1, 30, 19, 47), 1202140000.0],
#   [datetime.datetime(2014, 1, 31, 19, 47), 1215780000.0],
#   [datetime.datetime(2014, 2, 1, 19, 47), 1271320000.0],
#   [datetime.datetime(2014, 2, 2, 19, 47), 1273030000.0],
#   [datetime.datetime(2014, 2, 3, 19, 47), 1226850000.0],
#   [datetime.datetime(2014, 2, 4, 19, 47), 1221050000.0],
#   [datetime.datetime(2014, 2, 5, 19, 47), 1197700000.0],
#   [datetime.datetime(2014, 2, 6, 19, 47), 1152770000.0],
#   [datetime.datetime(2014, 2, 7, 19, 47), 1100320000.0],
#   [datetime.datetime(2014, 2, 8, 19, 47), 1036240000.0],
#   [datetime.datetime(2014, 2, 9, 19, 47), 1043400000.0],
#   [datetime.datetime(2014, 2, 10, 19, 47), 989687000.0],
#   [datetime.datetime(2014, 2, 11, 19, 47), 1035210000.0],
#   [datetime.datetime(2014, 2, 12, 19, 47), 1022980000.0],
#   [datetime.datetime(2014, 2, 13, 19, 47), 975399000.0],
#   [datetime.datetime(2014, 2, 14, 19, 47), 1011600000.0],
#   [datetime.datetime(2014, 2, 15, 19, 47), 1017520000.0],
#   [datetime.datetime(2014, 2, 16, 19, 47), 957827000.0],
#   [datetime.datetime(2014, 2, 17, 19, 47), 979692000.0],
#   [datetime.datetime(2014, 2, 18, 19, 47), 974309000.0],
#   [datetime.datetime(2014, 2, 19, 19, 47), 985101000.0],
#   [datetime.datetime(2014, 2, 20, 19, 47), 914285000.0],
#   [datetime.datetime(2014, 2, 21, 19, 47), 867297000.0],
#   [datetime.datetime(2014, 2, 22, 19, 47), 923988000.0],
#   [datetime.datetime(2014, 2, 23, 19, 47), 978744000.0],
#   [datetime.datetime(2014, 2, 24, 19, 47), 890014000.0],
#   [datetime.datetime(2014, 2, 25, 19, 47), 809536000.0],
#   [datetime.datetime(2014, 2, 26, 19, 47), 888840000.0],
#   [datetime.datetime(2014, 2, 27, 19, 47), 952724000.0],
#   [datetime.datetime(2014, 2, 28, 19, 47), 1096310000.0],
#   [datetime.datetime(2014, 3, 1, 19, 47), 1021000000.0],
#   [datetime.datetime(2014, 3, 2, 19, 47), 1114770000.0],
#   [datetime.datetime(2014, 3, 3, 19, 47), 1634700000.0],
#   [datetime.datetime(2014, 3, 4, 19, 47), 1852770000.0],
#   [datetime.datetime(2014, 3, 5, 19, 47), 1382400000.0],
#   [datetime.datetime(2014, 3, 6, 19, 47), 1199190000.0],
#   [datetime.datetime(2014, 3, 7, 19, 47), 1089520000.0],
#   [datetime.datetime(2014, 3, 8, 19, 47), 1084150000.0],
#   [datetime.datetime(2014, 3, 9, 19, 47), 1215770000.0],
#   [datetime.datetime(2014, 3, 10, 19, 47), 1215580000.0],
#   [datetime.datetime(2014, 3, 11, 19, 47), 1161250000.0],
#   [datetime.datetime(2014, 3, 12, 19, 47), 1192490000.0],
#   [datetime.datetime(2014, 3, 13, 19, 47), 1136190000.0],
#   [datetime.datetime(2014, 3, 14, 19, 47), 1127600000.0],
#   [datetime.datetime(2014, 3, 15, 19, 47), 1107150000.0],
#   [datetime.datetime(2014, 3, 16, 19, 47), 1111140000.0],
#   [datetime.datetime(2014, 3, 17, 19, 47), 996599000.0],
#   [datetime.datetime(2014, 3, 18, 19, 47), 1090860000.0],
#   [datetime.datetime(2014, 3, 19, 19, 47), 1077230000.0],
#   [datetime.datetime(2014, 3, 20, 19, 47), 1003680000.0],
#   [datetime.datetime(2014, 3, 21, 19, 47), 985536000.0],
#   [datetime.datetime(2014, 3, 22, 19, 47), 1064970000.0],
#   [datetime.datetime(2014, 3, 23, 19, 47), 1040740000.0],
#   [datetime.datetime(2014, 3, 24, 19, 47), 1001370000.0],
#   [datetime.datetime(2014, 3, 25, 19, 47), 975110000.0],
#   [datetime.datetime(2014, 3, 26, 19, 47), 933401000.0],
#   [datetime.datetime(2014, 3, 27, 19, 47), 793525000.0],
#   [datetime.datetime(2014, 3, 28, 19, 47), 740329000.0],
#   [datetime.datetime(2014, 3, 29, 19, 47), 756473000.0],
#   [datetime.datetime(2014, 3, 30, 20, 47), 698393000.0],
#   [datetime.datetime(2014, 3, 31, 20, 47), 682344000.0],
#   [datetime.datetime(2014, 4, 1, 20, 47), 706656000.0],
#   [datetime.datetime(2014, 4, 2, 20, 47), 617202000.0],
#   [datetime.datetime(2014, 4, 3, 20, 47), 604538000.0],
#   [datetime.datetime(2014, 4, 4, 20, 47), 607909000.0],
#   [datetime.datetime(2014, 4, 5, 20, 47), 624962000.0],
#   [datetime.datetime(2014, 4, 6, 20, 47), 633447000.0],
#   [datetime.datetime(2014, 4, 7, 20, 47), 618673000.0],
#   [datetime.datetime(2014, 4, 8, 20, 47), 613342000.0],
#   [datetime.datetime(2014, 4, 9, 20, 47), 596559000.0],
#   [datetime.datetime(2014, 4, 10, 20, 47), 515132000.0],
#   [datetime.datetime(2014, 4, 11, 20, 47), 583452000.0],
#   [datetime.datetime(2014, 4, 12, 20, 47), 561823000.0],
#   [datetime.datetime(2014, 4, 13, 20, 47), 527411000.0],
#   [datetime.datetime(2014, 4, 14, 20, 47), 620437000.0],
#   [datetime.datetime(2014, 4, 15, 20, 47), 687059000.0],
#   [datetime.datetime(2014, 4, 16, 20, 47), 705751000.0],
#   [datetime.datetime(2014, 4, 17, 20, 47), 685451000.0],
#   [datetime.datetime(2014, 4, 18, 20, 47), 666382000.0],
#   [datetime.datetime(2014, 4, 19, 20, 47), 730495000.0],
#   [datetime.datetime(2014, 4, 20, 20, 47), 712474000.0],
#   [datetime.datetime(2014, 4, 21, 20, 47), 714756000.0],
#   [datetime.datetime(2014, 4, 22, 20, 47), 700481000.0],
#   [datetime.datetime(2014, 4, 23, 20, 47), 689230000.0],
#   [datetime.datetime(2014, 4, 24, 20, 47), 697727000.0],
#   [datetime.datetime(2014, 4, 25, 20, 47), 600398000.0],
#   [datetime.datetime(2014, 4, 26, 20, 47), 595343000.0],
#   [datetime.datetime(2014, 4, 27, 20, 47), 552680000.0],
#   [datetime.datetime(2014, 4, 28, 20, 47), 575230000.0],
#   [datetime.datetime(2014, 4, 29, 20, 47), 588464000.0],
#   [datetime.datetime(2014, 4, 30, 20, 47), 605026000.0],
#   [datetime.datetime(2014, 5, 1, 20, 47), 611189000.0],
#   [datetime.datetime(2014, 5, 2, 20, 47), 582338000.0],
#   [datetime.datetime(2014, 5, 3, 20, 47), 560909000.0],
#   [datetime.datetime(2014, 5, 4, 20, 47), 566299000.0],
#   [datetime.datetime(2014, 5, 5, 20, 47), 562614000.0],
#   [datetime.datetime(2014, 5, 6, 20, 47), 575508000.0],
#   [datetime.datetime(2014, 5, 7, 20, 47), 594605000.0],
#   [datetime.datetime(2014, 5, 8, 20, 47), 592673000.0],
#   [datetime.datetime(2014, 5, 9, 20, 47), 616586000.0],
#   [datetime.datetime(2014, 5, 10, 20, 47), 610311000.0],
#   [datetime.datetime(2014, 5, 11, 20, 47), 589189000.0],
#   [datetime.datetime(2014, 5, 12, 20, 47), 591210000.0],
#   [datetime.datetime(2014, 5, 13, 20, 47), 592089000.0],
#   [datetime.datetime(2014, 5, 14, 20, 47), 604589000.0],
#   [datetime.datetime(2014, 5, 15, 20, 47), 620758000.0],
#   [datetime.datetime(2014, 5, 16, 20, 47), 612342000.0],
#   [datetime.datetime(2014, 5, 17, 20, 47), 607596000.0],
#   [datetime.datetime(2014, 5, 18, 20, 47), 602684000.0],
#   [datetime.datetime(2014, 5, 19, 20, 47), 601875000.0],
#   [datetime.datetime(2014, 5, 20, 20, 47), 635175000.0],
#   [datetime.datetime(2014, 5, 21, 20, 47), 634871000.0],
#   [datetime.datetime(2014, 5, 22, 20, 47), 628673000.0],
#   [datetime.datetime(2014, 5, 23, 20, 47), 664299000.0],
#   [datetime.datetime(2014, 5, 24, 20, 47), 655208000.0],
#   [datetime.datetime(2014, 5, 25, 20, 47), 698268000.0],
#   [datetime.datetime(2014, 5, 26, 20, 47), 685600000.0],
#   [datetime.datetime(2014, 5, 27, 20, 47), 680818000.0],
#   [datetime.datetime(2014, 5, 28, 20, 47), 663656000.0],
#   [datetime.datetime(2014, 5, 29, 20, 47), 652394000.0],
#   [datetime.datetime(2014, 5, 30, 20, 47), 681395000.0],
#   [datetime.datetime(2014, 5, 31, 20, 47), 670109000.0],
#   [datetime.datetime(2014, 6, 1, 20, 47), 700785000.0],
#   [datetime.datetime(2014, 6, 2, 20, 47), 693755000.0],
#   [datetime.datetime(2014, 6, 3, 20, 47), 705081000.0],
#   [datetime.datetime(2014, 6, 4, 20, 47), 689760000.0],
#   [datetime.datetime(2014, 6, 5, 20, 47), 708620000.0],
#   [datetime.datetime(2014, 6, 6, 20, 47), 695716000.0],
#   [datetime.datetime(2014, 6, 7, 20, 47), 689027000.0],
#   [datetime.datetime(2014, 6, 8, 20, 47), 691493000.0],
#   [datetime.datetime(2014, 6, 9, 20, 47), 686162000.0],
#   [datetime.datetime(2014, 6, 10, 20, 47), 704362000.0],
#   [datetime.datetime(2014, 6, 11, 20, 47), 708748000.0],
#   [datetime.datetime(2014, 6, 12, 20, 47), 682532000.0],
#   [datetime.datetime(2014, 6, 13, 20, 47), 671898000.0],
#   [datetime.datetime(2014, 6, 14, 20, 47), 643576000.0],
#   [datetime.datetime(2014, 6, 15, 20, 47), 650489000.0],
#   [datetime.datetime(2014, 6, 16, 20, 47), 664261000.0],
#   [datetime.datetime(2014, 6, 17, 20, 47), 656404000.0],
#   [datetime.datetime(2014, 6, 18, 20, 47), 664856000.0],
#   [datetime.datetime(2014, 6, 19, 20, 47), 672779000.0],
#   [datetime.datetime(2014, 6, 20, 20, 47), 649616000.0],
#   [datetime.datetime(2014, 6, 21, 20, 47), 650796000.0],
#   [datetime.datetime(2014, 6, 22, 20, 47), 659971000.0],
#   [datetime.datetime(2014, 6, 23, 20, 47), 647115000.0],
#   [datetime.datetime(2014, 6, 24, 20, 47), 639966000.0],
#   [datetime.datetime(2014, 6, 25, 20, 47), 606399000.0],
#   [datetime.datetime(2014, 6, 26, 20, 47), 603344000.0],
#   [datetime.datetime(2014, 6, 27, 20, 47), 617470000.0],
#   [datetime.datetime(2014, 6, 28, 20, 47), 612308000.0],
#   [datetime.datetime(2014, 6, 29, 20, 47), 597409000.0],
#   [datetime.datetime(2014, 6, 30, 20, 47), 601306000.0],
#   [datetime.datetime(2014, 7, 1, 20, 47), 608833000.0],
#   [datetime.datetime(2014, 7, 2, 20, 47), 574042000.0],
#   [datetime.datetime(2014, 7, 3, 20, 47), 577853000.0],
#   [datetime.datetime(2014, 7, 4, 20, 47), 566382000.0],
#   [datetime.datetime(2014, 7, 5, 20, 47), 533996000.0],
#   [datetime.datetime(2014, 7, 6, 20, 47), 528296000.0],
#   [datetime.datetime(2014, 7, 7, 20, 47), 526300000.0],
#   [datetime.datetime(2014, 7, 8, 20, 47), 532420000.0],
#   [datetime.datetime(2014, 7, 9, 20, 47), 545351000.0],
#   [datetime.datetime(2014, 7, 10, 20, 47), 540815000.0],
#   [datetime.datetime(2014, 7, 11, 20, 47), 552125000.0],
#   [datetime.datetime(2014, 7, 12, 20, 47), 572436000.0],
#   [datetime.datetime(2014, 7, 13, 20, 47), 577074000.0],
#   [datetime.datetime(2014, 7, 14, 20, 47), 571810000.0],
#   [datetime.datetime(2014, 7, 15, 20, 47), 564758000.0],
#   [datetime.datetime(2014, 7, 16, 20, 47), 558520000.0],
#   [datetime.datetime(2014, 7, 17, 20, 47), 589688000.0],
#   [datetime.datetime(2014, 7, 18, 20, 47), 600588000.0],
#   [datetime.datetime(2014, 7, 19, 20, 47), 588035000.0],
#   [datetime.datetime(2014, 7, 20, 20, 47), 583417000.0],
#   [datetime.datetime(2014, 7, 21, 20, 47), 609956000.0],
#   [datetime.datetime(2014, 7, 22, 20, 47), 598168000.0],
#   [datetime.datetime(2014, 7, 23, 20, 47), 596579000.0],
#   [datetime.datetime(2014, 7, 24, 20, 47), 568136000.0],
#   [datetime.datetime(2014, 7, 25, 20, 47), 554807000.0],
#   [datetime.datetime(2014, 7, 26, 20, 47), 550216000.0],
#   [datetime.datetime(2014, 7, 27, 20, 47), 551306000.0],
#   [datetime.datetime(2014, 7, 28, 20, 47), 536247000.0],
#   [datetime.datetime(2014, 7, 29, 20, 47), 539659000.0],
#   [datetime.datetime(2014, 7, 30, 20, 47), 533659000.0],
#   [datetime.datetime(2014, 7, 31, 20, 47), 549611000.0],
#   [datetime.datetime(2014, 8, 1, 20, 47), 559529000.0],
#   [datetime.datetime(2014, 8, 2, 20, 47), 553647000.0],
#   [datetime.datetime(2014, 8, 3, 20, 47), 549496000.0],
#   [datetime.datetime(2014, 8, 4, 20, 47), 538454000.0],
#   [datetime.datetime(2014, 8, 5, 20, 47), 528170000.0],
#   [datetime.datetime(2014, 8, 6, 20, 47), 525077000.0],
#   [datetime.datetime(2014, 8, 7, 20, 47), 526537000.0],
#   [datetime.datetime(2014, 8, 8, 20, 47), 522997000.0],
#   [datetime.datetime(2014, 8, 9, 20, 47), 507219000.0],
#   [datetime.datetime(2014, 8, 10, 20, 47), 503397000.0],
#   [datetime.datetime(2014, 8, 11, 20, 47), 480863000.0],
#   [datetime.datetime(2014, 8, 12, 20, 47), 440485000.0],
#   [datetime.datetime(2014, 8, 13, 20, 47), 413576000.0],
#   [datetime.datetime(2014, 8, 14, 20, 47), 411230000.0],
#   [datetime.datetime(2014, 8, 15, 20, 47), 399263000.0],
#   [datetime.datetime(2014, 8, 16, 20, 47), 394691000.0],
#   [datetime.datetime(2014, 8, 17, 20, 47), 380833000.0],
#   [datetime.datetime(2014, 8, 18, 20, 47), 325334000.0],
#   [datetime.datetime(2014, 8, 19, 20, 47), 379965000.0],
#   [datetime.datetime(2014, 8, 20, 20, 47), 432706000.0],
#   [datetime.datetime(2014, 8, 21, 20, 47), 458531000.0],
#   [datetime.datetime(2014, 8, 22, 20, 47), 448876000.0],
#   [datetime.datetime(2014, 8, 23, 20, 47), 421314000.0],
#   [datetime.datetime(2014, 8, 24, 20, 47), 459937000.0],
#   [datetime.datetime(2014, 8, 25, 20, 47), 481503000.0],
#   [datetime.datetime(2014, 8, 26, 20, 47), 588487000.0],
#   [datetime.datetime(2014, 8, 27, 20, 47), 577642000.0],
#   [datetime.datetime(2014, 8, 28, 20, 47), 560228000.0],
#   [datetime.datetime(2014, 8, 29, 20, 47), 551812000.0],
#   [datetime.datetime(2014, 8, 30, 20, 47), 555412000.0],
#   [datetime.datetime(2014, 8, 31, 20, 47), 531649000.0],
#   [datetime.datetime(2014, 9, 1, 20, 47), 538868000.0],
#   [datetime.datetime(2014, 9, 2, 20, 47), 521499000.0],
#   [datetime.datetime(2014, 9, 3, 20, 47), 533098000.0],
#   [datetime.datetime(2014, 9, 4, 20, 47), 556120000.0],
#   [datetime.datetime(2014, 9, 5, 20, 47), 557284000.0],
#   [datetime.datetime(2014, 9, 6, 20, 47), 571883000.0],
#   [datetime.datetime(2014, 9, 7, 20, 47), 568487000.0],
#   [datetime.datetime(2014, 9, 8, 20, 47), 572200000.0],
#   [datetime.datetime(2014, 9, 9, 20, 47), 569839000.0],
#   [datetime.datetime(2014, 9, 10, 20, 47), 594090000.0],
#   [datetime.datetime(2014, 9, 11, 20, 47), 594379000.0],
#   [datetime.datetime(2014, 9, 12, 20, 47), 598659000.0],
#   [datetime.datetime(2014, 9, 13, 20, 47), 608282000.0],
#   [datetime.datetime(2014, 9, 14, 20, 47), 631353000.0],
#   [datetime.datetime(2014, 9, 15, 20, 47), 606270000.0],
#   [datetime.datetime(2014, 9, 16, 20, 47), 616408000.0],
#   [datetime.datetime(2014, 9, 17, 20, 47), 608788000.0],
#   [datetime.datetime(2014, 9, 18, 20, 47), 603183000.0],
#   [datetime.datetime(2014, 9, 19, 20, 47), 564351000.0],
#   [datetime.datetime(2014, 9, 20, 20, 47), 566222000.0],
#   [datetime.datetime(2014, 9, 21, 20, 47), 555691000.0],
#   [datetime.datetime(2014, 9, 22, 20, 47), 561185000.0],
#   [datetime.datetime(2014, 9, 23, 20, 47), 586192000.0],
#   [datetime.datetime(2014, 9, 24, 20, 47), 586314000.0],
#   [datetime.datetime(2014, 9, 25, 20, 47), 583209000.0],
#   [datetime.datetime(2014, 9, 26, 20, 47), 586850000.0],
#   [datetime.datetime(2014, 9, 27, 20, 47), 576005000.0],
#   [datetime.datetime(2014, 9, 28, 20, 47), 581236000.0],
#   [datetime.datetime(2014, 9, 29, 20, 47), 561157000.0],
#   [datetime.datetime(2014, 9, 30, 20, 47), 571566000.0],
#   [datetime.datetime(2014, 10, 1, 20, 47), 573030000.0],
#   [datetime.datetime(2014, 10, 2, 20, 47), 565854000.0],
#   [datetime.datetime(2014, 10, 3, 20, 47), 556568000.0],
#   [datetime.datetime(2014, 10, 4, 20, 47), 534145000.0],
#   [datetime.datetime(2014, 10, 5, 20, 47), 494751000.0],
#   [datetime.datetime(2014, 10, 6, 20, 47), 521936000.0],
#   [datetime.datetime(2014, 10, 7, 20, 47), 526810000.0],
#   [datetime.datetime(2014, 10, 8, 20, 47), 531243000.0],
#   [datetime.datetime(2014, 10, 9, 20, 47), 551440000.0],
#   [datetime.datetime(2014, 10, 10, 20, 47), 529961000.0],
#   [datetime.datetime(2014, 10, 11, 20, 47), 528879000.0],
#   [datetime.datetime(2014, 10, 12, 20, 47), 542117000.0],
#   [datetime.datetime(2014, 10, 13, 20, 47), 537068000.0],
#   [datetime.datetime(2014, 10, 14, 20, 47), 565232000.0],
#   [datetime.datetime(2014, 10, 15, 20, 47), 544017000.0],
#   [datetime.datetime(2014, 10, 16, 20, 47), 532542000.0],
#   [datetime.datetime(2014, 10, 17, 20, 47), 544109000.0],
#   [datetime.datetime(2014, 10, 18, 20, 47), 547342000.0],
#   [datetime.datetime(2014, 10, 19, 20, 47), 541591000.0],
#   [datetime.datetime(2014, 10, 20, 20, 47), 536553000.0],
#   [datetime.datetime(2014, 10, 21, 20, 47), 544277000.0],
#   [datetime.datetime(2014, 10, 22, 20, 47), 536643000.0],
#   [datetime.datetime(2014, 10, 23, 20, 47), 518993000.0],
#   [datetime.datetime(2014, 10, 24, 20, 47), 514179000.0],
#   [datetime.datetime(2014, 10, 25, 20, 47), 496838000.0],
#   [datetime.datetime(2014, 10, 26, 19, 47), 491393000.0],
#   [datetime.datetime(2014, 10, 27, 19, 47), 513645000.0],
#   [datetime.datetime(2014, 10, 28, 19, 47), 504513000.0],
#   [datetime.datetime(2014, 10, 29, 19, 47), 488073000.0],
#   [datetime.datetime(2014, 10, 30, 19, 47), 479721000.0],
#   [datetime.datetime(2014, 10, 31, 19, 47), 477236000.0],
#   [datetime.datetime(2014, 11, 1, 19, 47), 455917000.0],
#   [datetime.datetime(2014, 11, 2, 19, 47), 457502000.0],
#   [datetime.datetime(2014, 11, 3, 19, 47), 463106000.0],
#   [datetime.datetime(2014, 11, 4, 19, 47), 466172000.0],
#   [datetime.datetime(2014, 11, 5, 19, 47), 482886000.0],
#   [datetime.datetime(2014, 11, 6, 19, 47), 482788000.0],
#   [datetime.datetime(2014, 11, 7, 19, 47), 477243000.0],
#   [datetime.datetime(2014, 11, 8, 19, 47), 485474000.0],
#   [datetime.datetime(2014, 11, 9, 19, 47), 496568000.0],
#   [datetime.datetime(2014, 11, 10, 19, 47), 505255000.0],
#   [datetime.datetime(2014, 11, 11, 19, 47), 497143000.0],
#   [datetime.datetime(2014, 11, 12, 19, 47), 545380000.0],
#   [datetime.datetime(2014, 11, 13, 19, 47), 529177000.0],
#   [datetime.datetime(2014, 11, 14, 19, 47), 522492000.0],
#   [datetime.datetime(2014, 11, 15, 19, 47), 504986000.0],
#   [datetime.datetime(2014, 11, 16, 19, 47), 514415000.0],
#   [datetime.datetime(2014, 11, 17, 19, 47), 520010000.0],
#   [datetime.datetime(2014, 11, 18, 19, 47), 508211000.0],
#   [datetime.datetime(2014, 11, 19, 19, 47), 521740000.0],
#   [datetime.datetime(2014, 11, 20, 19, 47), 519812000.0],
#   [datetime.datetime(2014, 11, 21, 19, 47), 539952000.0],
#   [datetime.datetime(2014, 11, 22, 19, 47), 568525000.0],
#   [datetime.datetime(2014, 11, 23, 19, 47), 603431000.0],
#   [datetime.datetime(2014, 11, 24, 19, 47), 637356000.0],
#   [datetime.datetime(2014, 11, 25, 19, 47), 664689000.0],
#   [datetime.datetime(2014, 11, 26, 19, 47), 686841000.0],
#   [datetime.datetime(2014, 11, 27, 19, 47), 778758000.0],
#   [datetime.datetime(2014, 11, 28, 19, 47), 831015000.0],
#   [datetime.datetime(2014, 11, 29, 19, 47), 810401000.0],
#   [datetime.datetime(2014, 11, 30, 19, 47), 744676000.0],
#   [datetime.datetime(2014, 12, 1, 19, 47), 731088000.0],
#   [datetime.datetime(2014, 12, 2, 19, 47), 787582000.0],
#   [datetime.datetime(2014, 12, 3, 19, 47), 791545000.0],
#   [datetime.datetime(2014, 12, 4, 19, 47), 786916000.0],
#   [datetime.datetime(2014, 12, 5, 19, 47), 800410000.0],
#   [datetime.datetime(2014, 12, 6, 19, 47), 825195000.0],
#   [datetime.datetime(2014, 12, 7, 19, 47), 839410000.0],
#   [datetime.datetime(2014, 12, 8, 19, 47), 793670000.0],
#   [datetime.datetime(2014, 12, 9, 19, 47), 819539000.0],
#   [datetime.datetime(2014, 12, 10, 19, 47), 842040000.0],
#   [datetime.datetime(2014, 12, 11, 19, 47), 867876000.0],
#   [datetime.datetime(2014, 12, 12, 19, 47), 870226000.0],
#   [datetime.datetime(2014, 12, 13, 19, 47), 886140000.0],
#   [datetime.datetime(2014, 12, 14, 19, 47), 888573000.0],
#   [datetime.datetime(2014, 12, 15, 19, 47), 911661000.0],
#   [datetime.datetime(2014, 12, 16, 19, 47), 1144450000.0],
#   [datetime.datetime(2014, 12, 17, 19, 47), 1178470000.0],
#   [datetime.datetime(2014, 12, 18, 19, 47), 1261210000.0],
#   [datetime.datetime(2014, 12, 19, 19, 47), 1148560000.0],
#   [datetime.datetime(2014, 12, 20, 19, 47), 1162840000.0],
#   [datetime.datetime(2014, 12, 21, 19, 47), 1235220000.0],
#   [datetime.datetime(2014, 12, 22, 19, 47), 1316740000.0],
#   [datetime.datetime(2014, 12, 23, 19, 47), 1238680000.0],
#   [datetime.datetime(2014, 12, 24, 19, 47), 1186090000.0],
#   [datetime.datetime(2014, 12, 25, 19, 47), 1201200000.0],
#   [datetime.datetime(2014, 12, 26, 19, 47), 1255850000.0],
#   [datetime.datetime(2014, 12, 27, 19, 47), 1205410000.0],
#   [datetime.datetime(2014, 12, 28, 19, 47), 1222520000.0],
#   [datetime.datetime(2014, 12, 29, 19, 47), 1244940000.0],
#   [datetime.datetime(2014, 12, 30, 19, 47), 1230690000.0],
#   [datetime.datetime(2014, 12, 31, 19, 47), 1226630000.0],
#   [datetime.datetime(2015, 1, 1, 19, 47), 1197740000.0],
#   [datetime.datetime(2015, 1, 2, 19, 47), 1167090000.0],
#   [datetime.datetime(2015, 1, 3, 19, 47), 1056370000.0],
#   [datetime.datetime(2015, 1, 4, 19, 47), 929329000.0],
#   [datetime.datetime(2015, 1, 5, 19, 47), 964343000.0],
#   [datetime.datetime(2015, 1, 6, 19, 47), 982395000.0],
#   [datetime.datetime(2015, 1, 7, 19, 47), 991633000.0],
#   [datetime.datetime(2015, 1, 8, 19, 47), 995648000.0],
#   [datetime.datetime(2015, 1, 9, 19, 47), 981760000.0],
#   [datetime.datetime(2015, 1, 10, 19, 47), 918681000.0],
#   [datetime.datetime(2015, 1, 11, 19, 47), 894899000.0],
#   [datetime.datetime(2015, 1, 12, 19, 47), 908503000.0],
#   [datetime.datetime(2015, 1, 13, 19, 47), 780680000.0],
#   [datetime.datetime(2015, 1, 14, 19, 47), 678802000.0],
#   [datetime.datetime(2015, 1, 15, 19, 47), 784938000.0],
#   [datetime.datetime(2015, 1, 16, 19, 47), 785764000.0],
#   [datetime.datetime(2015, 1, 17, 19, 47), 738269000.0],
#   [datetime.datetime(2015, 1, 18, 19, 47), 738315000.0],
#   [datetime.datetime(2015, 1, 19, 19, 47), 748796000.0],
#   [datetime.datetime(2015, 1, 20, 19, 47), 755792000.0],
#   [datetime.datetime(2015, 1, 21, 19, 47), 766946000.0],
#   [datetime.datetime(2015, 1, 22, 19, 47), 799918000.0],
#   [datetime.datetime(2015, 1, 23, 19, 47), 789356000.0],
#   [datetime.datetime(2015, 1, 24, 19, 47), 812009000.0],
#   [datetime.datetime(2015, 1, 25, 19, 47), 813913000.0],
#   [datetime.datetime(2015, 1, 26, 19, 47), 803715000.0],
#   [datetime.datetime(2015, 1, 27, 19, 47), 793259000.0],
#   [datetime.datetime(2015, 1, 28, 19, 47), 753885000.0],
#   [datetime.datetime(2015, 1, 29, 19, 47), 732630000.0],
#   [datetime.datetime(2015, 1, 30, 19, 47), 716554000.0],
#   [datetime.datetime(2015, 1, 31, 19, 47), 725233000.0],
#   [datetime.datetime(2015, 2, 1, 19, 47), 702022000.0],
#   [datetime.datetime(2015, 2, 2, 19, 47), 677968000.0],
#   [datetime.datetime(2015, 2, 3, 19, 47), 663962000.0],
#   [datetime.datetime(2015, 2, 4, 19, 47), 664371000.0],
#   [datetime.datetime(2015, 2, 5, 19, 47), 676131000.0],
#   [datetime.datetime(2015, 2, 6, 19, 47), 737186000.0],
#   [datetime.datetime(2015, 2, 7, 19, 47), 714281000.0],
#   [datetime.datetime(2015, 2, 8, 19, 47), 709130000.0],
#   [datetime.datetime(2015, 2, 9, 19, 47), 695826000.0],
#   [datetime.datetime(2015, 2, 10, 19, 47), 685140000.0],
#   [datetime.datetime(2015, 2, 11, 19, 47), 691767000.0],
#   [datetime.datetime(2015, 2, 12, 19, 47), 699809000.0],
#   [datetime.datetime(2015, 2, 13, 19, 47), 733001000.0],
#   [datetime.datetime(2015, 2, 14, 19, 47), 734792000.0],
#   [datetime.datetime(2015, 2, 15, 19, 47), 710621000.0],
#   [datetime.datetime(2015, 2, 16, 19, 47), 697338000.0],
#   [datetime.datetime(2015, 2, 17, 19, 47), 707683000.0],
#   [datetime.datetime(2015, 2, 18, 19, 47), 688987000.0],
#   [datetime.datetime(2015, 2, 19, 19, 47), 697313000.0],
#   [datetime.datetime(2015, 2, 20, 19, 47), 686548000.0],
#   [datetime.datetime(2015, 2, 21, 19, 47), 678598000.0],
#   [datetime.datetime(2015, 2, 22, 19, 47), 661213000.0],
#   [datetime.datetime(2015, 2, 23, 19, 47), 676680000.0],
#   [datetime.datetime(2015, 2, 24, 19, 47), 685071000.0],
#   [datetime.datetime(2015, 2, 25, 19, 47), 689518000.0],
#   [datetime.datetime(2015, 2, 26, 19, 47), 687085000.0],
#   [datetime.datetime(2015, 2, 27, 19, 47), 701451000.0],
#   [datetime.datetime(2015, 2, 28, 19, 47), 689766000.0],
#   [datetime.datetime(2015, 3, 1, 19, 47), 659057000.0],
#   [datetime.datetime(2015, 3, 2, 19, 47), 660104000.0],
#   [datetime.datetime(2015, 3, 3, 19, 47), 623979000.0],
#   [datetime.datetime(2015, 3, 4, 19, 47), 593296000.0],
#   [datetime.datetime(2015, 3, 5, 19, 47), 624609000.0],
#   [datetime.datetime(2015, 3, 6, 19, 47), 614565000.0],
#   [datetime.datetime(2015, 3, 7, 19, 47), 613530000.0],
#   [datetime.datetime(2015, 3, 8, 19, 47), 590230000.0],
#   [datetime.datetime(2015, 3, 9, 19, 47), 620074000.0],
#   [datetime.datetime(2015, 3, 10, 19, 47), 605072000.0],
#   [datetime.datetime(2015, 3, 11, 19, 47), 606489000.0],
#   [datetime.datetime(2015, 3, 12, 19, 47), 609695000.0],
#   [datetime.datetime(2015, 3, 13, 19, 47), 609164000.0],
#   [datetime.datetime(2015, 3, 14, 19, 47), 622586000.0],
#   [datetime.datetime(2015, 3, 15, 19, 47), 616376000.0],
#   [datetime.datetime(2015, 3, 16, 19, 47), 625373000.0],
#   [datetime.datetime(2015, 3, 17, 19, 47), 617453000.0],
#   [datetime.datetime(2015, 3, 18, 19, 47), 601956000.0],
#   [datetime.datetime(2015, 3, 19, 19, 47), 584798000.0],
#   [datetime.datetime(2015, 3, 20, 19, 47), 594318000.0],
#   [datetime.datetime(2015, 3, 21, 19, 47), 583602000.0],
#   [datetime.datetime(2015, 3, 22, 19, 47), 585772000.0],
#   [datetime.datetime(2015, 3, 23, 19, 47), 586476000.0],
#   [datetime.datetime(2015, 3, 24, 19, 47), 566466000.0],
#   [datetime.datetime(2015, 3, 25, 19, 47), 538736000.0],
#   [datetime.datetime(2015, 3, 26, 19, 47), 535806000.0],
#   [datetime.datetime(2015, 3, 27, 19, 47), 535972000.0],
#   [datetime.datetime(2015, 3, 28, 19, 47), 539776000.0],
#   [datetime.datetime(2015, 3, 29, 20, 47), 523321000.0],
#   [datetime.datetime(2015, 3, 30, 20, 47), 517637000.0],
#   [datetime.datetime(2015, 3, 31, 20, 47), 499740000.0],
#   [datetime.datetime(2015, 4, 1, 20, 47), 486166000.0],
#   [datetime.datetime(2015, 4, 2, 20, 47), 503882000.0],
#   [datetime.datetime(2015, 4, 3, 20, 47), 532795000.0],
#   [datetime.datetime(2015, 4, 4, 20, 47), 538041000.0],
#   [datetime.datetime(2015, 4, 5, 20, 47), 526767000.0],
#   [datetime.datetime(2015, 4, 6, 20, 47), 526723000.0],
#   [datetime.datetime(2015, 4, 7, 20, 47), 540462000.0],
#   [datetime.datetime(2015, 4, 8, 20, 47), 533843000.0],
#   [datetime.datetime(2015, 4, 9, 20, 47), 520620000.0],
#   [datetime.datetime(2015, 4, 10, 20, 47), 500201000.0],
#   [datetime.datetime(2015, 4, 11, 20, 47), 491648000.0],
#   [datetime.datetime(2015, 4, 12, 20, 47), 498748000.0],
#   [datetime.datetime(2015, 4, 13, 20, 47), 477420000.0],
#   [datetime.datetime(2015, 4, 14, 20, 47), 467499000.0],
#   [datetime.datetime(2015, 4, 15, 20, 47), 462391000.0],
#   [datetime.datetime(2015, 4, 16, 20, 47), 473225000.0],
#   [datetime.datetime(2015, 4, 17, 20, 47), 473328000.0],
#   [datetime.datetime(2015, 4, 18, 20, 47), 466901000.0],
#   [datetime.datetime(2015, 4, 19, 20, 47), 467161000.0],
#   [datetime.datetime(2015, 4, 20, 20, 47), 466030000.0],
#   [datetime.datetime(2015, 4, 21, 20, 47), 463374000.0],
#   [datetime.datetime(2015, 4, 22, 20, 47), 479166000.0],
#   [datetime.datetime(2015, 4, 23, 20, 47), 479465000.0],
#   [datetime.datetime(2015, 4, 24, 20, 47), 475027000.0],
#   [datetime.datetime(2015, 4, 25, 20, 47), 477749000.0],
#   [datetime.datetime(2015, 4, 26, 20, 47), 449862000.0],
#   [datetime.datetime(2015, 4, 27, 20, 47), 452714000.0],
#   [datetime.datetime(2015, 4, 28, 20, 47), 449089000.0],
#   [datetime.datetime(2015, 4, 29, 20, 47), 454883000.0],
#   [datetime.datetime(2015, 4, 30, 20, 47), 469860000.0],
#   [datetime.datetime(2015, 5, 1, 20, 47), 467535000.0],
#   [datetime.datetime(2015, 5, 2, 20, 47), 467195000.0],
#   [datetime.datetime(2015, 5, 3, 20, 47), 470999000.0],
#   [datetime.datetime(2015, 5, 4, 20, 47), 466106000.0],
#   [datetime.datetime(2015, 5, 5, 20, 47), 461153000.0],
#   [datetime.datetime(2015, 5, 6, 20, 47), 457801000.0],
#   [datetime.datetime(2015, 5, 7, 20, 47), 453693000.0],
#   [datetime.datetime(2015, 5, 8, 20, 47), 453131000.0],
#   [datetime.datetime(2015, 5, 9, 20, 47), 451503000.0],
#   [datetime.datetime(2015, 5, 10, 20, 47), 445702000.0],
#   [datetime.datetime(2015, 5, 11, 20, 47), 449458000.0],
#   [datetime.datetime(2015, 5, 12, 20, 47), 451033000.0],
#   [datetime.datetime(2015, 5, 13, 20, 47), 448926000.0],
#   [datetime.datetime(2015, 5, 14, 20, 47), 431142000.0],
#   [datetime.datetime(2015, 5, 15, 20, 47), 437034000.0],
#   [datetime.datetime(2015, 5, 16, 20, 47), 432200000.0],
#   [datetime.datetime(2015, 5, 17, 20, 47), 424223000.0],
#   [datetime.datetime(2015, 5, 18, 20, 47), 412450000.0],
#   [datetime.datetime(2015, 5, 19, 20, 47), 435607000.0],
#   [datetime.datetime(2015, 5, 20, 20, 47), 447488000.0],
#   [datetime.datetime(2015, 5, 21, 20, 47), 448142000.0],
#   [datetime.datetime(2015, 5, 22, 20, 47), 473257000.0],
#   [datetime.datetime(2015, 5, 23, 20, 47), 482755000.0],
#   [datetime.datetime(2015, 5, 24, 20, 47), 484332000.0],
#   [datetime.datetime(2015, 5, 25, 20, 47), 486747000.0],
#   [datetime.datetime(2015, 5, 26, 20, 47), 486066000.0],
#   [datetime.datetime(2015, 5, 27, 20, 47), 498727000.0],
#   [datetime.datetime(2015, 5, 28, 20, 47), 533866000.0],
#   [datetime.datetime(2015, 5, 29, 20, 47), 567101000.0],
#   [datetime.datetime(2015, 5, 30, 20, 47), 543495000.0],
#   [datetime.datetime(2015, 5, 31, 20, 47), 531531000.0],
#   [datetime.datetime(2015, 6, 1, 20, 47), 497028000.0],
#   [datetime.datetime(2015, 6, 2, 20, 47), 508487000.0],
#   [datetime.datetime(2015, 6, 3, 20, 47), 520109000.0],
#   [datetime.datetime(2015, 6, 4, 20, 47), 516078000.0],
#   [datetime.datetime(2015, 6, 5, 20, 47), 521676000.0],
#   [datetime.datetime(2015, 6, 6, 20, 47), 523497000.0],
#   [datetime.datetime(2015, 6, 7, 20, 47), 519089000.0],
#   [datetime.datetime(2015, 6, 8, 20, 47), 524004000.0],
#   [datetime.datetime(2015, 6, 9, 20, 47), 525282000.0],
#   [datetime.datetime(2015, 6, 10, 20, 47), 525360000.0],
#   [datetime.datetime(2015, 6, 11, 20, 47), 526175000.0],
#   [datetime.datetime(2015, 6, 12, 20, 47), 525903000.0],
#   [datetime.datetime(2015, 6, 13, 20, 47), 535149000.0],
#   [datetime.datetime(2015, 6, 14, 20, 47), 544822000.0],
#   [datetime.datetime(2015, 6, 15, 20, 47), 559669000.0],
#   [datetime.datetime(2015, 6, 16, 20, 47), 618911000.0],
#   [datetime.datetime(2015, 6, 17, 20, 47), 665477000.0],
#   [datetime.datetime(2015, 6, 18, 20, 47), 686062000.0],
#   [datetime.datetime(2015, 6, 19, 20, 47), 705210000.0],
#   [datetime.datetime(2015, 6, 20, 20, 47), 705348000.0],
#   [datetime.datetime(2015, 6, 21, 20, 47), 691628000.0],
#   [datetime.datetime(2015, 6, 22, 20, 47), 688278000.0],
#   [datetime.datetime(2015, 6, 23, 20, 47), 690253000.0],
#   [datetime.datetime(2015, 6, 24, 20, 47), 682725000.0],
#   [datetime.datetime(2015, 6, 25, 20, 47), 693315000.0],
#   [datetime.datetime(2015, 6, 26, 20, 47), 696148000.0],
#   [datetime.datetime(2015, 6, 27, 20, 47), 718839000.0],
#   [datetime.datetime(2015, 6, 28, 20, 47), 719270000.0],
#   [datetime.datetime(2015, 6, 29, 20, 47), 770667000.0],
#   [datetime.datetime(2015, 6, 30, 20, 47), 769913000.0],
#   [datetime.datetime(2015, 7, 1, 20, 47), 751222000.0],
#   [datetime.datetime(2015, 7, 2, 20, 47), 751830000.0],
#   [datetime.datetime(2015, 7, 3, 20, 47), 753960000.0],
#   [datetime.datetime(2015, 7, 4, 20, 47), 748783000.0],
#   [datetime.datetime(2015, 7, 5, 20, 47), 743319000.0],
#   [datetime.datetime(2015, 7, 6, 20, 47), 790896000.0],
#   [datetime.datetime(2015, 7, 7, 20, 47), 763797000.0],
#   [datetime.datetime(2015, 7, 8, 20, 47), 792956000.0],
#   [datetime.datetime(2015, 7, 9, 20, 47), 848990000.0],
#   [datetime.datetime(2015, 7, 10, 20, 47), 779444000.0],
#   [datetime.datetime(2015, 7, 11, 20, 47), 702401000.0],
#   [datetime.datetime(2015, 7, 12, 20, 47), 753937000.0],
#   [datetime.datetime(2015, 7, 13, 20, 47), 719344000.0],
#   [datetime.datetime(2015, 7, 14, 20, 47), 730682000.0],
#   [datetime.datetime(2015, 7, 15, 20, 47), 706520000.0],
#   [datetime.datetime(2015, 7, 16, 20, 47), 625416000.0],
#   [datetime.datetime(2015, 7, 17, 20, 47), 649706000.0],
#   [datetime.datetime(2015, 7, 18, 20, 47), 654796000.0],
#   [datetime.datetime(2015, 7, 19, 20, 47), 649486000.0],
#   [datetime.datetime(2015, 7, 20, 20, 47), 645688000.0],
#   [datetime.datetime(2015, 7, 21, 20, 47), 643181000.0],
#   [datetime.datetime(2015, 7, 22, 20, 47), 638162000.0],
#   [datetime.datetime(2015, 7, 23, 20, 47), 631498000.0],
#   [datetime.datetime(2015, 7, 24, 20, 47), 678916000.0],
#   [datetime.datetime(2015, 7, 25, 20, 47), 688518000.0],
#   [datetime.datetime(2015, 7, 26, 20, 47), 696254000.0],
#   [datetime.datetime(2015, 7, 27, 20, 47), 712204000.0],
#   [datetime.datetime(2015, 7, 28, 20, 47), 729735000.0],
#   [datetime.datetime(2015, 7, 29, 20, 47), 719222000.0],
#   [datetime.datetime(2015, 7, 30, 20, 47), 704284000.0],
#   [datetime.datetime(2015, 7, 31, 20, 47), 704698000.0],
#   [datetime.datetime(2015, 8, 1, 20, 47), 671964000.0],
#   [datetime.datetime(2015, 8, 2, 20, 47), 666681000.0],
#   [datetime.datetime(2015, 8, 3, 20, 47), 680933000.0],
#   [datetime.datetime(2015, 8, 4, 20, 47), 682329000.0],
#   [datetime.datetime(2015, 8, 5, 20, 47), 679000000.0],
#   [datetime.datetime(2015, 8, 6, 20, 47), 661538000.0],
#   [datetime.datetime(2015, 8, 7, 20, 47), 814142000.0],
#   [datetime.datetime(2015, 8, 8, 20, 47), 712758000.0],
#   [datetime.datetime(2015, 8, 9, 20, 47), 699605000.0],
#   [datetime.datetime(2015, 8, 10, 20, 47), 700479000.0],
#   [datetime.datetime(2015, 8, 11, 20, 47), 712598000.0],
#   [datetime.datetime(2015, 8, 12, 20, 47), 724885000.0],
#   [datetime.datetime(2015, 8, 13, 20, 47), 749640000.0],
#   [datetime.datetime(2015, 8, 14, 20, 47), 764350000.0],
#   [datetime.datetime(2015, 8, 15, 20, 47), 757514000.0],
#   [datetime.datetime(2015, 8, 16, 20, 47), 720594000.0],
#   [datetime.datetime(2015, 8, 17, 20, 47), 733599000.0],
# ...
#   [datetime.datetime(2015, 4, 9, 20, 47), 3283100.0],
#   [datetime.datetime(2015, 4, 10, 20, 47), 3688190.0],
#   [datetime.datetime(2015, 4, 11, 20, 47), 2598570.0],
#   [datetime.datetime(2015, 4, 12, 20, 47), 2026160.0],
#   [datetime.datetime(2015, 4, 13, 20, 47), 2425610.0],
#   [datetime.datetime(2015, 4, 14, 20, 47), 3640350.0],
#   [datetime.datetime(2015, 4, 15, 20, 47), 2522860.0],
#   [datetime.datetime(2015, 4, 16, 20, 47), 2646430.0],
#   [datetime.datetime(2015, 4, 17, 20, 47), 2432680.0],
#   [datetime.datetime(2015, 4, 18, 20, 47), 1623340.0],
#   [datetime.datetime(2015, 4, 19, 20, 47), 1767900.0],
#   [datetime.datetime(2015, 4, 20, 20, 47), 2573800.0],
#   [datetime.datetime(2015, 4, 21, 20, 47), 2301130.0],
#   [datetime.datetime(2015, 4, 22, 20, 47), 3081300.0],
#   [datetime.datetime(2015, 4, 23, 20, 47), 2532220.0],
#   [datetime.datetime(2015, 4, 24, 20, 47), 2406700.0],
#   [datetime.datetime(2015, 4, 25, 20, 47), 1870600.0],
#   [datetime.datetime(2015, 4, 26, 20, 47), 2505390.0],
#   [datetime.datetime(2015, 4, 27, 20, 47), 2613800.0],
#   [datetime.datetime(2015, 4, 28, 20, 47), 2937490.0],
#   [datetime.datetime(2015, 4, 29, 20, 47), 2508840.0],
#   [datetime.datetime(2015, 4, 30, 20, 47), 3378740.0],
#   [datetime.datetime(2015, 5, 1, 20, 47), 2899870.0],
#   [datetime.datetime(2015, 5, 2, 20, 47), 1782630.0],
#   [datetime.datetime(2015, 5, 3, 20, 47), 2435460.0],
#   [datetime.datetime(2015, 5, 4, 20, 47), 2698170.0],
#   [datetime.datetime(2015, 5, 5, 20, 47), 2355240.0],
#   [datetime.datetime(2015, 5, 6, 20, 47), 2190860.0],
#   [datetime.datetime(2015, 5, 7, 20, 47), 3904910.0],
#   [datetime.datetime(2015, 5, 8, 20, 47), 2976440.0],
#   [datetime.datetime(2015, 5, 9, 20, 47), 2205550.0],
#   [datetime.datetime(2015, 5, 10, 20, 47), 2299270.0],
#   [datetime.datetime(2015, 5, 11, 20, 47), 1928110.0],
#   [datetime.datetime(2015, 5, 12, 20, 47), 3203130.0],
#   [datetime.datetime(2015, 5, 13, 20, 47), 2460350.0],
#   [datetime.datetime(2015, 5, 14, 20, 47), 3639760.0],
#   [datetime.datetime(2015, 5, 15, 20, 47), 1949320.0],
#   [datetime.datetime(2015, 5, 16, 20, 47), 1541400.0],
#   [datetime.datetime(2015, 5, 17, 20, 47), 1437230.0],
#   [datetime.datetime(2015, 5, 18, 20, 47), 3150440.0],
#   [datetime.datetime(2015, 5, 19, 20, 47), 3710990.0],
#   [datetime.datetime(2015, 5, 20, 20, 47), 2639940.0],
#   [datetime.datetime(2015, 5, 21, 20, 47), 7100350.0],
#   [datetime.datetime(2015, 5, 22, 20, 47), 10566900.0],
#   [datetime.datetime(2015, 5, 23, 20, 47), 9343270.0],
#   [datetime.datetime(2015, 5, 24, 20, 47), 7338150.0],
#   [datetime.datetime(2015, 5, 25, 20, 47), 8225200.0],
#   [datetime.datetime(2015, 5, 26, 20, 47), 8333520.0],
#   [datetime.datetime(2015, 5, 27, 20, 47), 9807410.0],
#   [datetime.datetime(2015, 5, 28, 20, 47), 11085200.0],
#   [datetime.datetime(2015, 5, 29, 20, 47), 10795500.0],
#   [datetime.datetime(2015, 5, 30, 20, 47), 8538810.0],
#   [datetime.datetime(2015, 5, 31, 20, 47), 7318680.0],
#   [datetime.datetime(2015, 6, 1, 20, 47), 7738640.0],
#   [datetime.datetime(2015, 6, 2, 20, 47), 7988830.0],
#   [datetime.datetime(2015, 6, 3, 20, 47), 6552620.0],
#   [datetime.datetime(2015, 6, 4, 20, 47), 5698490.0],
#   [datetime.datetime(2015, 6, 5, 20, 47), 6316350.0],
#   [datetime.datetime(2015, 6, 6, 20, 47), 5681480.0],
#   [datetime.datetime(2015, 6, 7, 20, 47), 5547450.0],
#   [datetime.datetime(2015, 6, 8, 20, 47), 6179490.0],
#   [datetime.datetime(2015, 6, 9, 20, 47), 5837260.0],
#   [datetime.datetime(2015, 6, 10, 20, 47), 6368110.0],
#   [datetime.datetime(2015, 6, 11, 20, 47), 6323470.0],
#   [datetime.datetime(2015, 6, 12, 20, 47), 5831150.0],
#   [datetime.datetime(2015, 6, 13, 20, 47), 7106910.0],
#   [datetime.datetime(2015, 6, 14, 20, 47), 8876940.0],
#   [datetime.datetime(2015, 6, 15, 20, 47), 7005650.0],
#   [datetime.datetime(2015, 6, 16, 20, 47), 15235200.0],
#   [datetime.datetime(2015, 6, 17, 20, 47), 24490300.0],
#   [datetime.datetime(2015, 6, 18, 20, 47), 16313100.0],
#   [datetime.datetime(2015, 6, 19, 20, 47), 14563300.0],
#   [datetime.datetime(2015, 6, 20, 20, 47), 9762870.0],
#   [datetime.datetime(2015, 6, 21, 20, 47), 20360300.0],
#   [datetime.datetime(2015, 6, 22, 20, 47), 20703900.0],
#   [datetime.datetime(2015, 6, 23, 20, 47), 7675070.0],
#   [datetime.datetime(2015, 6, 24, 20, 47), 9571780.0],
#   [datetime.datetime(2015, 6, 25, 20, 47), 9190760.0],
#   [datetime.datetime(2015, 6, 26, 20, 47), 6646040.0],
#   [datetime.datetime(2015, 6, 27, 20, 47), 8286930.0],
#   [datetime.datetime(2015, 6, 28, 20, 47), 8619600.0],
#   [datetime.datetime(2015, 6, 29, 20, 47), 15818500.0],
#   [datetime.datetime(2015, 6, 30, 20, 47), 24948400.0],
#   [datetime.datetime(2015, 7, 1, 20, 47), 13477100.0],
#   [datetime.datetime(2015, 7, 2, 20, 47), 10947900.0],
#   [datetime.datetime(2015, 7, 3, 20, 47), 8256620.0],
#   [datetime.datetime(2015, 7, 4, 20, 47), 7662110.0],
#   [datetime.datetime(2015, 7, 5, 20, 47), 11680200.0],
#   [datetime.datetime(2015, 7, 6, 20, 47), 32931600.0],
#   [datetime.datetime(2015, 7, 7, 20, 47), 22603600.0],
#   [datetime.datetime(2015, 7, 8, 20, 47), 27730400.0],
#   [datetime.datetime(2015, 7, 9, 20, 47), 46974400.0],
#   [datetime.datetime(2015, 7, 10, 20, 47), 75301800.0],
#   [datetime.datetime(2015, 7, 11, 20, 47), 37807100.0],
#   [datetime.datetime(2015, 7, 12, 20, 47), 26557200.0],
#   [datetime.datetime(2015, 7, 13, 20, 47), 20583000.0],
#   [datetime.datetime(2015, 7, 14, 20, 47), 12391400.0],
#   [datetime.datetime(2015, 7, 15, 20, 47), 10808300.0],
#   [datetime.datetime(2015, 7, 16, 20, 47), 22197900.0],
#   [datetime.datetime(2015, 7, 17, 20, 47), 14150600.0],
#   [datetime.datetime(2015, 7, 18, 20, 47), 12114300.0],
#   [datetime.datetime(2015, 7, 19, 20, 47), 6644140.0],
#   [datetime.datetime(2015, 7, 20, 20, 47), 7508540.0],
#   [datetime.datetime(2015, 7, 21, 20, 47), 7983870.0],
#   [datetime.datetime(2015, 7, 22, 20, 47), 6219560.0],
#   [datetime.datetime(2015, 7, 23, 20, 47), 4779830.0],
#   [datetime.datetime(2015, 7, 24, 20, 47), 13374000.0],
#   [datetime.datetime(2015, 7, 25, 20, 47), 17275600.0],
#   [datetime.datetime(2015, 7, 26, 20, 47), 10736400.0],
#   [datetime.datetime(2015, 7, 27, 20, 47), 7946370.0],
#   [datetime.datetime(2015, 7, 28, 20, 47), 13980200.0],
#   [datetime.datetime(2015, 7, 29, 20, 47), 10005100.0],
#   [datetime.datetime(2015, 7, 30, 20, 47), 8035240.0],
#   [datetime.datetime(2015, 7, 31, 20, 47), 7176710.0],
#   [datetime.datetime(2015, 8, 1, 20, 47), 8243480.0],
#   [datetime.datetime(2015, 8, 2, 20, 47), 8297830.0],
#   [datetime.datetime(2015, 8, 3, 20, 47), 7727390.0],
#   [datetime.datetime(2015, 8, 4, 20, 47), 6475910.0],
#   [datetime.datetime(2015, 8, 5, 20, 47), 4755420.0],
#   [datetime.datetime(2015, 8, 6, 20, 47), 5881100.0],
#   [datetime.datetime(2015, 8, 7, 20, 47), 21100300.0],
#   [datetime.datetime(2015, 8, 8, 20, 47), 26509400.0],
#   [datetime.datetime(2015, 8, 9, 20, 47), 21425200.0],
#   [datetime.datetime(2015, 8, 10, 20, 47), 4544300.0],
#   [datetime.datetime(2015, 8, 11, 20, 47), 5199060.0],
#   [datetime.datetime(2015, 8, 12, 20, 47), 8458730.0],
#   [datetime.datetime(2015, 8, 13, 20, 47), 7515730.0],
#   [datetime.datetime(2015, 8, 14, 20, 47), 10450400.0],
#   [datetime.datetime(2015, 8, 15, 20, 47), 6159260.0],
#   [datetime.datetime(2015, 8, 16, 20, 47), 8686960.0],
#   [datetime.datetime(2015, 8, 17, 20, 47), 6463820.0],
#   [datetime.datetime(2015, 8, 18, 20, 47), 5547660.0],
#   [datetime.datetime(2015, 8, 19, 20, 47), 11233200.0],
#   [datetime.datetime(2015, 8, 20, 20, 47), 8824200.0],
#   [datetime.datetime(2015, 8, 21, 20, 47), 6379010.0],
#   [datetime.datetime(2015, 8, 22, 20, 47), 5538370.0],
#   [datetime.datetime(2015, 8, 23, 20, 47), 6045080.0],
#   [datetime.datetime(2015, 8, 24, 20, 47), 10355800.0],
#   [datetime.datetime(2015, 8, 25, 20, 47), 15747000.0],
#   [datetime.datetime(2015, 8, 26, 20, 47), 9905690.0],
#   [datetime.datetime(2015, 8, 27, 20, 47), 5215120.0],
#   [datetime.datetime(2015, 8, 28, 20, 47), 8116100.0],
#   [datetime.datetime(2015, 8, 29, 20, 47), 4902280.0],
#   [datetime.datetime(2015, 8, 30, 20, 47), 5357750.0],
#   [datetime.datetime(2015, 8, 31, 20, 47), 6550860.0],
#   [datetime.datetime(2015, 9, 1, 20, 47), 4886850.0],
#   [datetime.datetime(2015, 9, 2, 20, 47), 5480200.0],
#   [datetime.datetime(2015, 9, 3, 20, 47), 4945740.0],
#   [datetime.datetime(2015, 9, 4, 20, 47), 3314780.0],
#   [datetime.datetime(2015, 9, 5, 20, 47), 4665600.0],
#   [datetime.datetime(2015, 9, 6, 20, 47), 8643830.0],
#   [datetime.datetime(2015, 9, 7, 20, 47), 6146210.0],
#   [datetime.datetime(2015, 9, 8, 20, 47), 5896310.0],
#   [datetime.datetime(2015, 9, 9, 20, 47), 6122040.0],
#   [datetime.datetime(2015, 9, 10, 20, 47), 5241220.0],
#   [datetime.datetime(2015, 9, 11, 20, 47), 6070660.0],
#   [datetime.datetime(2015, 9, 12, 20, 47), 4295760.0],
#   [datetime.datetime(2015, 9, 13, 20, 47), 4070890.0],
#   [datetime.datetime(2015, 9, 14, 20, 47), 4776530.0],
#   [datetime.datetime(2015, 9, 15, 20, 47), 5130730.0],
#   [datetime.datetime(2015, 9, 16, 20, 47), 4976910.0],
#   [datetime.datetime(2015, 9, 17, 20, 47), 5806800.0],
#   [datetime.datetime(2015, 9, 18, 20, 47), 5405620.0],
#   [datetime.datetime(2015, 9, 19, 20, 47), 4133510.0],
#   [datetime.datetime(2015, 9, 20, 20, 47), 4159830.0],
#   [datetime.datetime(2015, 9, 21, 20, 47), 5282360.0],
#   [datetime.datetime(2015, 9, 22, 20, 47), 5423840.0],
#   [datetime.datetime(2015, 9, 23, 20, 47), 4759620.0],
#   [datetime.datetime(2015, 9, 24, 20, 47), 5127170.0],
#   [datetime.datetime(2015, 9, 25, 20, 47), 4818890.0],
#   [datetime.datetime(2015, 9, 26, 20, 47), 2264900.0],
#   [datetime.datetime(2015, 9, 27, 20, 47), 2121740.0],
#   [datetime.datetime(2015, 9, 28, 20, 47), 6394160.0],
#   [datetime.datetime(2015, 9, 29, 20, 47), 7940610.0],
#   [datetime.datetime(2015, 9, 30, 20, 47), 5911260.0],
#   [datetime.datetime(2015, 10, 1, 20, 47), 3768380.0],
#   [datetime.datetime(2015, 10, 2, 20, 47), 3236560.0],
#   [datetime.datetime(2015, 10, 3, 20, 47), 2448510.0],
#   [datetime.datetime(2015, 10, 4, 20, 47), 2514050.0],
#   [datetime.datetime(2015, 10, 5, 20, 47), 2647400.0],
#   [datetime.datetime(2015, 10, 6, 20, 47), 3246900.0],
#   [datetime.datetime(2015, 10, 7, 20, 47), 3199360.0],
#   [datetime.datetime(2015, 10, 8, 20, 47), 4489760.0],
#   [datetime.datetime(2015, 10, 9, 20, 47), 4626570.0],
#   [datetime.datetime(2015, 10, 10, 20, 47), 4015780.0],
#   [datetime.datetime(2015, 10, 11, 20, 47), 3232200.0],
#   [datetime.datetime(2015, 10, 12, 20, 47), 4111410.0],
#   [datetime.datetime(2015, 10, 13, 20, 47), 4795410.0],
#   [datetime.datetime(2015, 10, 14, 20, 47), 5493810.0],
#   [datetime.datetime(2015, 10, 15, 20, 47), 5801270.0],
#   [datetime.datetime(2015, 10, 16, 20, 47), 4458360.0],
#   [datetime.datetime(2015, 10, 17, 20, 47), 5529000.0],
#   [datetime.datetime(2015, 10, 18, 20, 47), 3572030.0],
#   [datetime.datetime(2015, 10, 19, 20, 47), 4211720.0],
#   [datetime.datetime(2015, 10, 20, 20, 47), 4075670.0],
#   [datetime.datetime(2015, 10, 21, 20, 47), 4225020.0],
#   [datetime.datetime(2015, 10, 22, 20, 47), 4446810.0],
#   [datetime.datetime(2015, 10, 23, 20, 47), 4932620.0],
#   [datetime.datetime(2015, 10, 24, 20, 47), 3179140.0],
#   [datetime.datetime(2015, 10, 25, 19, 47), 4124600.0],
#   [datetime.datetime(2015, 10, 26, 19, 47), 4735920.0],
#   [datetime.datetime(2015, 10, 27, 19, 47), 5891000.0],
#   [datetime.datetime(2015, 10, 28, 19, 47), 5296800.0],
#   [datetime.datetime(2015, 10, 29, 19, 47), 14047500.0],
#   [datetime.datetime(2015, 10, 30, 19, 47), 23991900.0],
#   [datetime.datetime(2015, 10, 31, 19, 47), 8665960.0],
#   [datetime.datetime(2015, 11, 1, 19, 47), 6772790.0],
#   [datetime.datetime(2015, 11, 2, 19, 47), 8816170.0],
#   [datetime.datetime(2015, 11, 3, 19, 47), 25027600.0],
#   [datetime.datetime(2015, 11, 4, 19, 47), 33680200.0],
#   [datetime.datetime(2015, 11, 5, 19, 47), 25760900.0],
#   [datetime.datetime(2015, 11, 6, 19, 47), 14525400.0],
#   [datetime.datetime(2015, 11, 7, 19, 47), 8097730.0],
#   [datetime.datetime(2015, 11, 8, 19, 47), 5334450.0],
#   [datetime.datetime(2015, 11, 9, 19, 47), 10227900.0],
#   [datetime.datetime(2015, 11, 10, 19, 47), 8272580.0],
#   [datetime.datetime(2015, 11, 11, 19, 47), 8823090.0],
#   [datetime.datetime(2015, 11, 12, 19, 47), 7619290.0],
#   [datetime.datetime(2015, 11, 13, 19, 47), 5687310.0],
#   [datetime.datetime(2015, 11, 14, 19, 47), 3119610.0],
#   [datetime.datetime(2015, 11, 15, 19, 47), 3897140.0],
#   [datetime.datetime(2015, 11, 16, 19, 47), 3964620.0],
#   [datetime.datetime(2015, 11, 17, 19, 47), 5139330.0],
#   [datetime.datetime(2015, 11, 18, 19, 47), 4093470.0],
#   [datetime.datetime(2015, 11, 19, 19, 47), 5311150.0],
#   [datetime.datetime(2015, 11, 20, 19, 47), 4610550.0],
#   [datetime.datetime(2015, 11, 21, 19, 47), 3626790.0],
#   [datetime.datetime(2015, 11, 22, 19, 47), 2930620.0],
#   [datetime.datetime(2015, 11, 23, 19, 47), 3573840.0],
#   [datetime.datetime(2015, 11, 24, 19, 47), 3846180.0],
#   [datetime.datetime(2015, 11, 25, 19, 47), 5595350.0],
#   [datetime.datetime(2015, 11, 26, 19, 47), 13320400.0],
#   [datetime.datetime(2015, 11, 27, 19, 47), 6113740.0],
#   [datetime.datetime(2015, 11, 28, 19, 47), 4375350.0],
#   [datetime.datetime(2015, 11, 29, 19, 47), 4493190.0],
#   [datetime.datetime(2015, 11, 30, 19, 47), 7075790.0],
#   [datetime.datetime(2015, 12, 1, 19, 47), 6244520.0],
#   [datetime.datetime(2015, 12, 2, 19, 47), 6768930.0],
#   [datetime.datetime(2015, 12, 3, 19, 47), 4711200.0],
#   [datetime.datetime(2015, 12, 4, 19, 47), 4052070.0],
#   [datetime.datetime(2015, 12, 5, 19, 47), 4916020.0],
#   [datetime.datetime(2015, 12, 6, 19, 47), 7409940.0],
#   [datetime.datetime(2015, 12, 7, 19, 47), 7212320.0],
#   [datetime.datetime(2015, 12, 8, 19, 47), 7222160.0],
#   [datetime.datetime(2015, 12, 9, 19, 47), 14818000.0],
#   [datetime.datetime(2015, 12, 10, 19, 47), 9609360.0],
#   [datetime.datetime(2015, 12, 11, 19, 47), 10413400.0],
#   [datetime.datetime(2015, 12, 12, 19, 47), 12817300.0],
#   [datetime.datetime(2015, 12, 13, 19, 47), 6669690.0],
#   [datetime.datetime(2015, 12, 14, 19, 47), 7839280.0],
#   [datetime.datetime(2015, 12, 15, 19, 47), 13369900.0],
#   [datetime.datetime(2015, 12, 16, 19, 47), 7709410.0],
#   [datetime.datetime(2015, 12, 17, 19, 47), 5580560.0],
#   [datetime.datetime(2015, 12, 18, 19, 47), 5757460.0],
#   [datetime.datetime(2015, 12, 19, 19, 47), 4091960.0],
#   [datetime.datetime(2015, 12, 20, 19, 47), 5426570.0],
#   [datetime.datetime(2015, 12, 21, 19, 47), 8035490.0],
#   [datetime.datetime(2015, 12, 22, 19, 47), 4998820.0],
#   [datetime.datetime(2015, 12, 23, 19, 47), 5624820.0],
#   [datetime.datetime(2015, 12, 24, 19, 47), 5701250.0],
#   [datetime.datetime(2015, 12, 25, 19, 47), 5384610.0],
#   [datetime.datetime(2015, 12, 26, 19, 47), 7182870.0],
#   [datetime.datetime(2015, 12, 27, 19, 47), 4475260.0],
#   [datetime.datetime(2015, 12, 28, 19, 47), 4198830.0],
#   [datetime.datetime(2015, 12, 29, 19, 47), 4682520.0],
#   [datetime.datetime(2015, 12, 30, 19, 47), 5124710.0],
#   [datetime.datetime(2015, 12, 31, 19, 47), 5672540.0],
#   [datetime.datetime(2016, 1, 1, 19, 47), 4725940.0],
#   [datetime.datetime(2016, 1, 2, 19, 47), 4975350.0],
#   [datetime.datetime(2016, 1, 3, 19, 47), 4159840.0],
#   [datetime.datetime(2016, 1, 4, 19, 47), 6923430.0],
#   [datetime.datetime(2016, 1, 5, 19, 47), 4230340.0],
#   [datetime.datetime(2016, 1, 6, 19, 47), 4323530.0],
#   [datetime.datetime(2016, 1, 7, 19, 47), 8354300.0],
#   [datetime.datetime(2016, 1, 8, 19, 47), 9507140.0],
#   [datetime.datetime(2016, 1, 9, 19, 47), 10284000.0],
#   [datetime.datetime(2016, 1, 10, 19, 47), 5910190.0],
#   [datetime.datetime(2016, 1, 11, 19, 47), 8666190.0],
#   [datetime.datetime(2016, 1, 12, 19, 47), 26041100.0],
#   [datetime.datetime(2016, 1, 13, 19, 47), 18745000.0],
#   [datetime.datetime(2016, 1, 14, 19, 47), 10497200.0],
#   [datetime.datetime(2016, 1, 15, 19, 47), 15083800.0],
#   [datetime.datetime(2016, 1, 16, 19, 47), 14540000.0],
#   [datetime.datetime(2016, 1, 17, 19, 47), 8212880.0],
#   [datetime.datetime(2016, 1, 18, 19, 47), 11529900.0],
#   [datetime.datetime(2016, 1, 19, 19, 47), 8364360.0],
#   [datetime.datetime(2016, 1, 20, 19, 47), 12673700.0],
#   [datetime.datetime(2016, 1, 21, 19, 47), 17790600.0],
#   [datetime.datetime(2016, 1, 22, 19, 47), 24766200.0],
#   ...]}

# %% [markdown]
# #### `graphs.dominance([start=None, end=None])`
# Get data from percentage of total market capitalization chart:

# %%
from datetime import datetime, timedelta

ten_days_ago = datetime.now() - timedelta(days=10)
cmc.graphs.dominance(start=ten_days_ago)
# Out:
# {'bitcoin': [[datetime.datetime(2018, 3, 13, 19, 47), 41.944],
#   [datetime.datetime(2018, 3, 14, 19, 47), 42.1054],
#   [datetime.datetime(2018, 3, 15, 19, 47), 42.6794],
#   [datetime.datetime(2018, 3, 16, 19, 47), 42.5987],
#   [datetime.datetime(2018, 3, 17, 19, 47), 43.1004],
#   [datetime.datetime(2018, 3, 18, 19, 47), 44.5214],
#   [datetime.datetime(2018, 3, 19, 19, 47), 44.0558],
#   [datetime.datetime(2018, 3, 20, 19, 47), 43.7614],
#   [datetime.datetime(2018, 3, 21, 19, 47), 43.8275],
#   [datetime.datetime(2018, 3, 22, 19, 47), 44.0364],
#   [datetime.datetime(2018, 3, 23, 13, 47), 44.2492]],
#  'bitcoin-cash': [[datetime.datetime(2018, 3, 13, 19, 47), 4.91544],
#   [datetime.datetime(2018, 3, 14, 19, 47), 4.86849],
#   [datetime.datetime(2018, 3, 15, 19, 47), 4.81862],
#   [datetime.datetime(2018, 3, 16, 19, 47), 5.14205],
#   [datetime.datetime(2018, 3, 17, 19, 47), 5.24283],
#   [datetime.datetime(2018, 3, 18, 19, 47), 5.19653],
#   [datetime.datetime(2018, 3, 19, 19, 47), 5.09963],
#   [datetime.datetime(2018, 3, 20, 19, 47), 5.20625],
#   [datetime.datetime(2018, 3, 21, 19, 47), 5.11057],
#   [datetime.datetime(2018, 3, 22, 19, 47), 5.18044],
#   [datetime.datetime(2018, 3, 23, 13, 47), 5.16675]],
#  'dash': [[datetime.datetime(2018, 3, 13, 19, 47), 1.03936],
#   [datetime.datetime(2018, 3, 14, 19, 47), 1.04349],
#   [datetime.datetime(2018, 3, 15, 19, 47), 1.0128],
#   [datetime.datetime(2018, 3, 16, 19, 47), 0.99856],
#   [datetime.datetime(2018, 3, 17, 19, 47), 0.99902],
#   [datetime.datetime(2018, 3, 18, 19, 47), 0.996687],
#   [datetime.datetime(2018, 3, 19, 19, 47), 0.965943],
#   [datetime.datetime(2018, 3, 20, 19, 47), 0.99611],
#   [datetime.datetime(2018, 3, 21, 19, 47), 0.989907],
#   [datetime.datetime(2018, 3, 22, 19, 47), 0.980171],
#   [datetime.datetime(2018, 3, 23, 13, 47), 0.98237]],
#  'ethereum': [[datetime.datetime(2018, 3, 13, 19, 47), 18.2354],
#   [datetime.datetime(2018, 3, 14, 19, 47), 18.1566],
#   [datetime.datetime(2018, 3, 15, 19, 47), 18.2134],
#   [datetime.datetime(2018, 3, 16, 19, 47), 17.9796],
#   [datetime.datetime(2018, 3, 17, 19, 47), 17.932],
#   [datetime.datetime(2018, 3, 18, 19, 47), 17.0805],
#   [datetime.datetime(2018, 3, 19, 19, 47), 16.4116],
#   [datetime.datetime(2018, 3, 20, 19, 47), 15.9473],
#   [datetime.datetime(2018, 3, 21, 19, 47), 16.0064],
#   [datetime.datetime(2018, 3, 22, 19, 47), 15.7522],
#   [datetime.datetime(2018, 3, 23, 13, 47), 15.7914]],
#  'iota': [[datetime.datetime(2018, 3, 13, 19, 47), 0.981143],
#   [datetime.datetime(2018, 3, 14, 19, 47), 0.935522],
#   [datetime.datetime(2018, 3, 15, 19, 47), 0.912422],
#   [datetime.datetime(2018, 3, 16, 19, 47), 0.941524],
#   [datetime.datetime(2018, 3, 17, 19, 47), 0.98689],
#   [datetime.datetime(2018, 3, 18, 19, 47), 1.1343],
#   [datetime.datetime(2018, 3, 19, 19, 47), 1.11206],
#   [datetime.datetime(2018, 3, 20, 19, 47), 1.18941],
#   [datetime.datetime(2018, 3, 21, 19, 47), 1.1111],
#   [datetime.datetime(2018, 3, 22, 19, 47), 1.1046],
#   [datetime.datetime(2018, 3, 23, 13, 47), 1.0964]],
#  'litecoin': [[datetime.datetime(2018, 3, 13, 19, 47), 2.63486],
#   [datetime.datetime(2018, 3, 14, 19, 47), 2.70405],
#   [datetime.datetime(2018, 3, 15, 19, 47), 2.76803],
#   [datetime.datetime(2018, 3, 16, 19, 47), 2.78959],
#   [datetime.datetime(2018, 3, 17, 19, 47), 2.73888],
#   [datetime.datetime(2018, 3, 18, 19, 47), 2.77417],
#   [datetime.datetime(2018, 3, 19, 19, 47), 2.69614],
#   [datetime.datetime(2018, 3, 20, 19, 47), 2.74369],
#   [datetime.datetime(2018, 3, 21, 19, 47), 2.72367],
#   [datetime.datetime(2018, 3, 22, 19, 47), 2.7329],
#   [datetime.datetime(2018, 3, 23, 13, 47), 2.74017]],
#  'monero': [[datetime.datetime(2018, 3, 13, 19, 47), 1.06806],
#   [datetime.datetime(2018, 3, 14, 19, 47), 1.01933],
#   [datetime.datetime(2018, 3, 15, 19, 47), 1.04081],
#   [datetime.datetime(2018, 3, 16, 19, 47), 1.01504],
#   [datetime.datetime(2018, 3, 17, 19, 47), 1.01183],
#   [datetime.datetime(2018, 3, 18, 19, 47), 1.02375],
#   [datetime.datetime(2018, 3, 19, 19, 47), 1.03178],
#   [datetime.datetime(2018, 3, 20, 19, 47), 1.04882],
#   [datetime.datetime(2018, 3, 21, 19, 47), 1.00244],
#   [datetime.datetime(2018, 3, 22, 19, 47), 0.995916],
#   [datetime.datetime(2018, 3, 23, 13, 47), 0.986446]],
#  'nem': [[datetime.datetime(2018, 3, 13, 19, 47), 1.07033],
#   [datetime.datetime(2018, 3, 14, 19, 47), 1.08461],
#   [datetime.datetime(2018, 3, 15, 19, 47), 0.96692],
#   [datetime.datetime(2018, 3, 16, 19, 47), 0.903337],
#   [datetime.datetime(2018, 3, 17, 19, 47), 0.815196],
#   [datetime.datetime(2018, 3, 18, 19, 47), 0.762366],
#   [datetime.datetime(2018, 3, 19, 19, 47), 0.800005],
#   [datetime.datetime(2018, 3, 20, 19, 47), 0.801425],
#   [datetime.datetime(2018, 3, 21, 19, 47), 0.760911],
#   [datetime.datetime(2018, 3, 22, 19, 47), 0.784738],
#   [datetime.datetime(2018, 3, 23, 13, 47), 0.764203]],
#  'neo': [[datetime.datetime(2018, 3, 13, 19, 47), 1.4541],
#   [datetime.datetime(2018, 3, 14, 19, 47), 1.39466],
#   [datetime.datetime(2018, 3, 15, 19, 47), 1.37307],
#   [datetime.datetime(2018, 3, 16, 19, 47), 1.3595],
#   [datetime.datetime(2018, 3, 17, 19, 47), 1.32418],
#   [datetime.datetime(2018, 3, 18, 19, 47), 1.30098],
#   [datetime.datetime(2018, 3, 19, 19, 47), 1.35207],
#   [datetime.datetime(2018, 3, 20, 19, 47), 1.45304],
#   [datetime.datetime(2018, 3, 21, 19, 47), 1.38356],
#   [datetime.datetime(2018, 3, 22, 19, 47), 1.37768],
#   [datetime.datetime(2018, 3, 23, 13, 47), 1.30755]],
#  'others': [[datetime.datetime(2018, 3, 13, 19, 47), 18.377556999999996],
#   [datetime.datetime(2018, 3, 14, 19, 47), 18.393637999999996],
#   [datetime.datetime(2018, 3, 15, 19, 47), 18.032228000000003],
#   [datetime.datetime(2018, 3, 16, 19, 47), 18.185299000000015],
#   [datetime.datetime(2018, 3, 17, 19, 47), 17.814623999999995],
#   [datetime.datetime(2018, 3, 18, 19, 47), 17.22251700000001],
#   [datetime.datetime(2018, 3, 19, 19, 47), 18.151572],
#   [datetime.datetime(2018, 3, 20, 19, 47), 18.746115000000003],
#   [datetime.datetime(2018, 3, 21, 19, 47), 19.31056200000002],
#   [datetime.datetime(2018, 3, 22, 19, 47), 19.318855],
#   [datetime.datetime(2018, 3, 23, 13, 47), 19.296770999999993]],
#  'ripple': [[datetime.datetime(2018, 3, 13, 19, 47), 8.27975],
#   [datetime.datetime(2018, 3, 14, 19, 47), 8.29421],
#   [datetime.datetime(2018, 3, 15, 19, 47), 8.1823],
#   [datetime.datetime(2018, 3, 16, 19, 47), 8.0868],
#   [datetime.datetime(2018, 3, 17, 19, 47), 8.03415],
#   [datetime.datetime(2018, 3, 18, 19, 47), 7.9868],
#   [datetime.datetime(2018, 3, 19, 19, 47), 8.3234],
#   [datetime.datetime(2018, 3, 20, 19, 47), 8.10644],
#   [datetime.datetime(2018, 3, 21, 19, 47), 7.77338],
#   [datetime.datetime(2018, 3, 22, 19, 47), 7.7361],
#   [datetime.datetime(2018, 3, 23, 13, 47), 7.61874]]}

# %% [markdown]
# _________________________________
#
# ## Utils
# #### `convert(value, currency_in, currency_out)`
# This method converts the value passed as first parameter as price of the `currency_in` currency to price of the `currency_out` parameter. Works as [coinmarketcap criptocurrencies calculator](https://coinmarketcap.com/calculator/). For example, if you want to converts $100€$ to dolars, use:

# %%
cmc.convert(100, "EUR", "USD")
# Out:
# 123.30486634985536

# %% [markdown]
# For get all the currencies supported by this method (all currencies; fiat + crypto):

# %%
cmc.currencies_to_convert
# Out:
# ['$$$',
#  '$PAC',
#  '1337',
#  '1ST',
#  '1WO',
#  '2GIVE',
#  '300',
#  '42',
#  '611',
#  '808',
#  '888',
#  '8BIT',
#  'AAC',
#  'ABC',
#  'ABJ',
#  'ABN',
#  'ABT',
#  'ABY',
#  'AC',
#  'ACAT',
#  'ACC',
#  'ACC',
#  'ACC',
#  'ACE',
#  'ACES',
#  'ACN',
#  'ACOIN',
#  'ACP',
#  'ACT',
#  'ADA',
#  'ADB',
#  'ADC',
#  'ADCN',
#  'ADK',
#  'ADST',
#  'ADT',
#  'ADX',
#  'ADZ',
#  'AE',
#  'AEON',
#  'AERM',
#  'AGI',
#  'AHT',
#  'AI',
#  'AIB',
#  'AID',
#  'AIDOC',
#  'AION',
#  'AIR',
#  'AIT',
#  'AIX',
#  'AKY',
#  'ALIS',
#  'ALL',
#  'ALQO',
#  'ALT',
#  'ALTC',
#  'ALTCOM',
#  'AMB',
#  'AMBER',
#  'AMM',
#  'AMMO',
#  'AMP',
#  'AMS',
#  'ANC',
#  'ANI',
#  'ANT',
#  'ANTI',
#  'ANTX',
#  'APC',
#  'APPC',
#  'APX',
#  'ARB',
#  'ARC',
#  'ARCO',
#  'ARCT',
#  'ARDR',
#  'ARG',
#  'ARGUS',
#  'ARI',
#  'ARK',
#  'ARN',
#  'ART',
#  'ARY',
#  'ASAFE2',
#  'ASN',
#  'AST',
#  'ASTRO',
#  'ATB',
#  'ATL',
#  'ATM',
#  'ATMC',
#  'ATMS',
#  'ATN',
#  'ATOM',
#  'ATS',
#  'ATX',
#  'AU',
#  'AUD',
#  'AUR',
#  'AURA',
#  'AUTO',
#  'AV',
#  'AVH',
#  'AVT',
#  'AWR',
#  'AXIOM',
#  'AXP',
#  'B2B',
#  'B2X',
#  'B@',
#  'BAC',
#  'BANCA',
#  'BAR',
#  'BAS',
#  'BASH',
#  'BAT',
#  'BAT',
#  'BAX',
#  'BAY',
#  'BBN',
#  'BBP',
#  'BBR',
#  'BBT',
#  'BCA',
#  'BCC',
#  'BCD',
#  'BCDN',
#  'BCF',
#  'BCH',
#  'BCH',
#  'BCN',
#  'BCO',
#  'BCPT',
#  'BCX',
#  'BCY',
#  'BDG',
#  'BDL',
#  'BEE',
#  'BELA',
#  'BENJI',
#  'BERN',
#  'BEST',
#  'BET',
#  'BET',
#  'BEZ',
#  'BFT',
#  'BIG',
#  'BIGUP',
#  'BIO',
#  'BIOB',
#  'BIOS',
#  'BIP',
#  'BIRDS',
#  'BIS',
#  'BIT',
#  'BITB',
#  'BITBTC',
#  'BITCF',
#  'BITCNY',
#  'BITEUR',
#  'BITG',
#  'BITGOLD',
#  'BITOK',
#  'BITS',
#  'BITSILVER',
#  'BITUSD',
#  'BITZ',
#  'BIX',
#  'BKX',
#  'BLAZR',
#  'BLC',
#  'BLITZ',
#  'BLK',
#  'BLN',
#  'BLOCK',
#  'BLOCKPAY',
#  'BLRY',
#  'BLT',
#  'BLU',
#  'BLUE',
#  'BLZ',
#  'BLZ',
#  'BMC',
#  'BNB',
#  'BNT',
#  'BNTY',
#  'BNX',
#  'BOAT',
#  'BOLI',
#  'BON',
#  'BOS',
#  'BOST',
#  'BOT',
#  'BPC',
#  'BPL',
#  'BPT',
#  'BQ',
#  'BRAIN',
#  'BRAT',
#  'BRD',
#  'BRIA',
#  'BRIT',
#  'BRK',
#  'BRL',
#  'BRO',
#  'BRX',
#  'BSC',
#  'BSD',
#  'BSN',
#  'BSR',
#  'BSTAR',
#  'BSTY',
#  'BT2',
#  'BTA',
#  'BTB',
#  'BTBc',
#  'BTC',
#  'BTC',
#  'BTCA',
#  'BTCD',
#  'BTCM',
#  'BTCP',
#  'BTCR',
#  'BTCRED',
#  'BTCS',
#  'BTCZ',
#  'BTDX',
#  'BTE',
#  'BTG',
#  'BTG',
#  'BTM',
#  'BTM',
#  'BTO',
#  'BTPL',
#  'BTQ',
#  'BTS',
#  'BTW',
#  'BTWTY',
#  'BTX',
#  'BUB',
#  'BUCKS',
#  'BUMBA',
#  'BUN',
#  'BURST',
#  'BUZZ',
#  'BWK',
#  'BXC',
#  'BXT',
#  'BYC',
#  'C2',
#  'C20',
#  'CAB',
#  'CACH',
#  'CAD',
#  'CAG',
#  'CALC',
#  'CAN',
#  'CAN',
#  'CANDY',
#  'CANN',
#  'CAPP',
#  'CARBON',
#  'CAS',
#  'CASH',
#  'CAT',
#  'CAT',
#  'CAT',
#  'CBX',
#  'CC',
#  'CCM100',
#  'CCN',
#  'CCO',
#  'CCRB',
#  'CCT',
#  'CDN',
#  'CDT',
#  'CDX',
#  'CEFS',
#  'CENNZ',
#  'CESC',
#  'CF',
#  'CFC',
#  'CFD',
#  'CFI',
#  'CFT',
#  'CFUN',
#  'CHAN',
#  'CHAT',
#  'CHC',
#  'CHEAP',
#  'CHESS',
#  'CHF',
#  'CHIPS',
#  'CHP',
#  'CHSB',
#  'CJ',
#  'CL',
#  'CLAM',
#  'CLD',
#  'CLOAK',
#  'CLP',
#  'CLUB',
#  'CME',
#  'CMP',
#  'CMPCO',
#  'CMS',
#  'CMS',
#  'CMT',
#  'CMT',
#  'CND',
#  'CNNC',
#  'CNO',
#  'CNT',
#  'CNX',
#  'CNY',
#  'COAL',
#  'COB',
#  'COFI',
#  'COLX',
#  'CON',
#  'CONX',
#  'COR',
#  'COSS',
#  'COUPE',
#  'COV',
#  'COVAL',
#  'COXST',
#  'CPAY',
#  'CPC',
#  'CPC',
#  'CPN',
#  'CPY',
#  'CRAVE',
#  'CRB',
#  'CRC',
#  'CRDNC',
#  'CREA',
#  'CRED',
#  'CREDO',
#  'CREVA',
#  'CRM',
#  'CRPT',
#  'CRT',
#  'CRW',
#  'CRX',
#  'CRYPT',
#  'CS',
#  'CSC',
#  'CSNO',
#  'CTIC2',
#  'CTIC3',
#  'CTO',
#  'CTR',
#  'CTX',
#  'CUBE',
#  'CURE',
#  'CV',
#  'CV2',
#  'CVC',
#  'CVCOIN',
#  'CWXT',
#  'CXO',
#  'CXT',
#  'CYC',
#  'CYDER',
#  'CYP',
#  'CZK',
#  'DADI',
#  'DAI',
#  'DALC',
#  'DAR',
#  'DASH',
#  'DASHS',
#  'DAT',
#  'DATA',
#  'DATX',
#  'DAV',
#  'DAXX',
#  'DAY',
#  'DBC',
#  'DBET',
#  'DBG',
#  'DBIX',
#  'DBTC',
#  'DCN',
#  'DCR',
#  'DCRE',
#  'DCT',
#  'DCY',
#  'DDD',
#  'DDF',
#  'DEB',
#  'DEM',
#  'DENT',
#  'DES',
#  'DEUS',
#  'DEW',
#  'DFS',
#  'DFT',
#  'DGB',
#  'DGC',
#  'DGCS',
#  'DGD',
#  'DGPT',
#  'DIBC',
#  'DICE',
#  'DIM',
#  'DIME',
#  'DISK',
#  'DIVX',
#  'DIX',
#  'DKK',
#  'DLC',
#  'DLISK',
#  'DLT',
#  'DMB',
#  'DMC',
#  'DMD',
#  'DMT',
#  'DNA',
#  'DNR',
#  'DNT',
#  'DOGE',
#  'DOLLAR',
#  'DON',
#  'DOPE',
#  'DOT',
#  'DOVU',
#  'DP',
#  'DPY',
#  'DRG',
#  'DRGN',
#  'DRM',
#  'DROP',
#  'DRP',
#  'DRPU',
#  'DRS',
#  'DRT',
#  'DRXNE',
#  'DSH',
#  'DSR',
#  'DTA',
#  'DTB',
#  'DTC',
#  'DTH',
#  'DTR',
#  'DUB',
#  'DUO',
#  'DUTCH',
#  'DXT',
#  'DYN',
#  'EAC',
#  'EAG',
#  'EAGLE',
#  'EBCH',
#  'EBET',
#  'EBST',
#  'EBT',
#  'EBTC',
#  'ECA',
#  'ECASH',
#  'ECC',
#  'ECH',
#  'ECN',
#  'ECO',
#  'ECOB',
#  'EDG',
#  'EDO',
#  'EDR',
#  'EDRC',
#  'EFL',
#  'EFYT',
#  'EGC',
#  'EGG',
#  'EGO',
#  'EGOLD',
#  'EKO',
#  'EKT',
#  'EL',
#  'ELA',
#  'ELC',
#  'ELE',
#  'ELEC',
#  'ELF',
#  'ELITE',
#  'ELIX',
#  'ELLA',
#  'ELS',
#  'ELTCOIN',
#  'EMC',
#  'EMC2',
#  'EMD',
#  'EMV',
#  'ENG',
#  'ENJ',
#  'ENRG',
#  'ENT',
#  'ENT',
#  'EOS',
#  'EOT',
#  'EPC',
#  'EPY',
#  'EQL',
#  'EQT',
#  'ERA',
#  'ERC',
#  'ERC20',
#  'ERO',
#  'ERY',
#  'ESC',
#  'ESP',
#  'ESZ',
#  'ETBS',
#  'ETC',
#  'ETG',
#  'ETH',
#  'ETH',
#  'ETHD',
#  'ETHOS',
#  'ETN',
#  'ETP',
#  'ETT',
#  'ETT',
#  'EUC',
#  'EUR',
#  'EVC',
#  'EVE',
#  'EVIL',
#  'EVN',
#  'EVO',
#  'EVR',
#  'EVX',
#  'EXCL',
#  'EXN',
#  'EXP',
#  'EXRN',
#  'EXY',
#  'EZT',
#  'FAIR',
#  'FAIR',
#  'FAP',
#  'FAZZ',
#  'FC2',
#  'FCN',
#  'FCT',
#  'FDX',
#  'FID',
#  'FIL',
#  'FIMK',
#  'FIRE',
#  'FJC',
#  'FLAP',
#  'FLASH',
#  'FLAX',
#  'FLDC',
#  'FLIK',
#  'FLIXX',
#  'FLO',
#  'FLT',
#  'FLUZ',
#  'FLY',
#  'FNC',
#  'FONZ',
#  'FOR',
#  'FOTA',
#  'FRC',
#  'FRCT',
#  'FRD',
#  'FRGC',
#  'FRK',
#  'FRN',
#  'FRST',
#  'FRWC',
#  'FSN',
#  'FST',
#  'FTC',
#  'FUCK',
#  'FUEL',
#  'FUN',
#  'FUNC',
#  'FUTC',
#  'FUZZ',
#  'FXE',
#  'FYN',
#  'FYP',
#  'G3N',
#  'GAIA',
#  'GAIN',
#  'GAM',
#  'GAME',
#  'GAP',
#  'GARY',
#  'GAS',
#  'GAT',
#  'GAY',
#  'GB',
#  'GBC',
#  'GBG',
#  'GBP',
#  'GBX',
#  'GBYTE',
#  'GCC',
#  'GCC',
#  'GCN',
#  'GCR',
#  'GCS',
#  'GDC',
#  'GEERT',
#  'GEM',
#  'GEO',
#  'GET',
#  'GETX',
#  'GJC',
#  'GLA',
#  'GLC',
#  'GLD',
#  'GLS',
#  'GLT',
#  'GML',
#  'GMT',
#  'GMX',
#  'GNO',
#  'GNT',
#  'GNX',
#  'GOD',
#  'GOLF',
#  'GOLOS',
#  'GOOD',
#  'GP',
#  'GPL',
#  'GPU',
#  'GRC',
#  'GRE',
#  'GRFT',
#  'GRID',
#  'GRIM',
#  'GRLC',
#  'GRN',
#  'GRS',
#  'GRWI',
#  'GRX',
#  'GSR',
#  'GTC',
#  'GTC',
#  'GTO',
#  'GUESS',
#  'GUN',
#  'GUP',
#  'GVT',
#  'GXS',
#  'HAC',
#  'HAL',
#  'HALLO',
#  'HAT',
#  'HAV',
#  'HBC',
#  'HBN',
#  'HBT',
#  'HC',
#  'HCC',
#  'HDG',
#  'HDLB',
#  'HEAT',
#  'HERO',
#  'HGT',
#  'HIGH',
#  'HIRE',
#  'HKD',
#  'HKN',
#  'HLC',
#  'HMC',
#  'HMC',
#  'HMP',
#  'HMQ',
#  'HNC',
#  'HNC',
#  'HODL',
#  'HOLD',
#  'HONEY',
#  'HORSE',
#  'HOT',
#  'HPB',
#  'HPC',
#  'HPY',
#  'HQX',
#  'HSR',
#  'HST',
#  'HT',
#  'HTC',
#  'HTML',
#  'HUC',
#  'HUF',
#  'HUSH',
#  'HVCO',
#  'HVN',
#  'HWC',
#  'HXX',
#  'HYP',
#  'HYPER',
#  'I0C',
#  'IBANK',
#  'IC',
#  'ICE',
#  'ICN',
#  'ICN',
#  'ICOB',
#  'ICON',
#  'ICOO',
#  'ICOS',
#  'ICX',
#  'IDH',
#  'IDR',
#  'IDT',
#  'IDXM',
#  'IETH',
#  'IFC',
#  'IFLT',
#  'IFT',
#  'IGNIS',
#  'IHT',
#  'ILS',
#  'IMPS',
#  'IMS',
#  'IMX',
#  'INCNT',
#  'IND',
#  'INDI',
#  'INDIA',
#  'INF',
#  'INFX',
#  'ING',
#  'INK',
#  'INN',
#  'INPAY',
#  'INR',
#  'INS',
#  'INSN',
#  'INSTAR',
#  'INT',
#  'INXT',
#  'IOC',
#  'ION',
#  'IOP',
#  'IOST',
#  'IPBC',
#  'IPC',
#  'IPL',
#  'IQT',
#  'IRL',
#  'ISL',
#  'ITC',
#  'ITI',
#  'ITNS',
#  'ITT',
#  'IVZ',
#  'IXC',
#  'IXT',
#  'J',
#  'J8T',
#  'JC',
#  'JET',
#  'JEW',
#  'JIN',
#  'JIYO',
#  'JNT',
#  'JOBS',
#  'JPY',
#  'JS',
#  'JWL',
#  'KARMA',
#  'KASHH',
#  'KAYI',
#  'KB3',
#  'KBR',
#  'KCASH',
#  'KCS',
#  'KDC',
#  'KED',
#  'KEK',
#  'KEY',
#  'KICK',
#  'KIN',
#  'KLC',
#  'KLN',
#  'KMD',
#  'KNC',
#  'KNC',
#  'KOBO',
#  'KORE',
#  'KRB',
#  'KRM',
#  'KRONE',
#  'KRW',
#  'KURT',
#  'KUSH',
#  'KZC',
#  'LA',
#  'LALA',
#  'LANA',
#  'LATX',
#  'LAZ',
#  'LBC',
#  'LBTC',
#  'LBTC',
#  'LCC',
#  'LCP',
#  'LCT',
#  'LDC',
#  'LDCN',
#  'LDOGE',
#  'LEA',
#  'LEAF',
#  'LEDU',
#  'LEND',
#  'LEO',
#  'LEPEN',
#  'LET',
#  'LEV',
#  'LEVO',
#  'LGD',
#  'LGO',
#  'LIFE',
#  'LIGHT',
#  'LINDA',
#  'LINK',
#  'LINX',
#  'LIR',
#  'LKC',
#  'LKK',
#  'LLT',
#  'LMC',
#  'LNK',
#  'LOC',
#  'LOCI',
#  'LOG',
#  'LOOM',
#  'LRC',
#  'LSK',
#  'LTB',
#  'LTC',
#  'LTC',
#  'LTCR',
#  'LTCU',
#  'LTH',
#  'LUN',
#  'LUNA',
#  'LUX',
#  'LVPS',
#  'LYM',
#  'MAC',
#  'MAD',
#  'MAG',
#  'MAG',
#  'MAGE',
#  'MAGN',
#  'MAID',
#  'MAN',
#  'MANA',
#  'MANNA',
#  'MAO',
#  'MAR',
#  'MARS',
#  'MARX',
#  'MAX',
#  'MAY',
#  'MBI',
#  'MBL',
#  'MBRS',
#  'MCAP',
#  'MCI',
#  'MCO',
#  'MCR',
#  'MCRN',
#  'MDA',
#  'MDC',
#  'MDS',
#  'MDT',
#  'MEC',
#  'MED',
#  'MEDIC',
#  'MEE',
#  'MEME',
#  'MER',
#  'METAL',
#  'MGC',
#  'MGM',
#  'MGO',
#  'MILO',
#  'MINEX',
#  'MINT',
#  'MIOTA',
#  'MKR',
#  'MLM',
#  'MLN',
#  'MMXVI',
#  'MNC',
#  'MND',
#  'MNE',
#  'MNM',
#  'MNTP',
#  'MNX',
#  'MOAC',
#  'MOBI',
#  'MOD',
#  'MOF',
#  'MOIN',
#  'MOJO',
#  'MONA',
#  'MONETA',
#  'MONK',
#  'MOON',
#  'MOT',
#  'MOTO',
#  'MRJA',
#  'MRT',
#  'MSCN',
#  'MSD',
#  'MSP',
#  'MST',
#  'MTH',
#  'MTL',
#  'MTLMC3',
#  'MTN',
#  'MTNC',
#  'MTX',
#  'MUE',
#  'MUSE',
#  'MUSIC',
#  'MVC',
#  'MWAT',
#  'MXN',
#  'MXT',
#  'MYB',
#  'MYR',
#  'MYST',
#  'MZC',
#  'NAMO',
#  'NANJ',
#  'NANO',
#  'NANOX',
#  'NAS',
#  'NAV',
#  'NBIT',
#  'NCASH',
#  'NDC',
#  'NEBL',
#  'NEO',
#  'NEOG',
#  'NEOS',
#  'NET',
#  'NET',
#  'NETKO',
#  'NEU',
#  'NEVA',
#  'NEWB',
#  'NGC',
#  'NIO',
#  'NKA',
#  'NKC',
#  'NLC2',
#  'NLG',
#  'NMC',
#  'NMR',
#  'NMS',
#  'NOAH',
#  'NOBL',
#  'NODC',
#  'NOK',
#  'NOTE',
#  'NOX',
#  'NPX',
#  'NPXS',
#  'NRO',
#  'NSR',
#  'NTC',
#  'NTK',
#  'NTO',
#  'NTRN',
#  'NTWK',
#  'NUKO',
#  'NULS',
#  'NUMUS',
#  'NVC',
#  'NVST',
#  'NXC',
#  'NXS',
#  'NXT',
#  'NYAN',
#  'NYC',
#  'NZD',
#  'OAX',
#  'OBITS',
#  'OC',
#  'OCC',
#  'OCL',
#  'OCN',
#  'OCOW',
#  'OCT',
#  'ODN',
#  ...]

# %%
show_page("calculator")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/calculator"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `download_logo(name, [size=128, filename=None])`
# Download a currency image logo in `.png` format. Valid sizes are: `[16, 32, 64, 128, 200]`.

# %%
filename = cmc.download_logo("BTC", size=200)

from IPython.display import Image
Image(filename)

# %%
import os
try:
    os.remove(filename)
except FileNotFoundError:
    pass

# %% [markdown]
# _____________________________
#
# ## Catching HTTP errors
# You can use the nexts class in order to catch some HTTP error:

# %%
from pymarketcap import (
    CoinmarketcapError,      # This class is the parent of all
    CoinmarketcapHTTPError,
    CoinmarketcapTooManyRequestsError
)

# %% [markdown]
# You could prevent errors like this
#
#
# ![error](images/http_error.png)

# %% [markdown]
# This only happens with `Pymarketcap` class. In asynchronous interface, failed requests will be restarted in a queue.
