# %% [markdown]
# # <center>Synchronous Pymarketcap Interface</center>
#
# > See also: [Asynchronous Pymarketcap Scraper](async_live.ipynb)

# %%
from IPython.display import IFrame
show_page = lambda endpoint: IFrame("https://coinmarketcap.com/%s" % endpoint, "100%", 400)

# %% [markdown]
# ## Basic usage
#
# #### `Pymarketcap([timeout=20, debug=False, cache=True])`
#
# The first response takes a long time because some data is cached at instantiation of the wrapper.

# %%
from pymarketcap import Pymarketcap
cmc = Pymarketcap(timeout=10)

cmc.exchanges()
# Out:
# [{'markets': [{'name': '<span data-global-stats-markets></span>',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': '24 Hour Volume Rankings (Exchange)'},
#  {'markets': [{'name': '<span data-global-stats-markets></span>',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': '24 Hour Volume Rankings (Currency)',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Monthly Volume Rankings (Currency)',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': '24 Hour Volume Rankings (Currency)',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Monthly Volume Rankings (Currency)',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'EOS',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': '24 Hour Volume Rankings (Exchange)'},
#  {'markets': [{'name': 'EOS',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'True Chain',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'EOS',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': '24 Hour Volume Rankings (Exchange)'},
#  {'markets': [{'name': 'TRON',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Zilliqa',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Bytecoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'EOS',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'ICON',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'EOS',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Huobi Token',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'All'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'IOStoken',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Ripple',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Cortex',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Cortex',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'EOS',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'TRON',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Cardano',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'Markets with Fees'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Augur',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'ICON',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Ripple',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Zilliqa',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'EOS',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'Markets with No Fees'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'IOTA',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'EOS',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'TRON',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Ripple',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'BitMEX'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Zilliqa',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'ICON',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Mithril',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Qtum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'OKEx'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Augur',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Verge',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'SIRIN LABS Token',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'ReddCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'TRON',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Cardano',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Ripple',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'Binance'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Augur',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Dash',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Bytecoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'EOS',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'VeChain',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Qtum',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'Huobi'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Qtum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'DAEX',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Ripple',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Ripple',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'EOS',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Primas',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'Upbit'},
#  {'markets': [{'name': 'Skrumble Network',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Aeternity',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Cardano',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Bytom',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Zilliqa',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Game.com',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'EOS',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'EOS',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Ethereum Classic',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'BitShares',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Hshare',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'BitShares',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Ethereum',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'TRON',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'EDUCare',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'Bitfinex'},
#  {'markets': [{'name': 'Litecoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'TrustNote',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'GXChain',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'GXChain',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Qtum',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'EOS',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'WaykiChain',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Stellar',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Zcash',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Ethereum',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Bibox Token',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Bibox Token',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'Bithumb'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bibox Token',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Bytom',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Bytom',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Bodhi',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Bodhi',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'QASH',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'NEO',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Augur',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Ripple',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'GDAX'},
#  {'markets': [{'name': 'Bytecoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Stellar',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'BitShares',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Ripple',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'MonaCoin',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'}],
#   'name': 'Bittrex'},
#  {'markets': [{'name': 'MonaCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Ripple',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'EOS',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'IOTA',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Qtum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'OmiseGO',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Ethereum',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'Kraken'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bytom',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'ValueChain',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Qtum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Qtum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Ripple',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Litecoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Pundi X',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Credits',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Ethereum',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'EOS',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'HitBTC'},
#  {'markets': [{'name': 'Litecoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Metaverse ETP',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'},
#    {'name': 'Hshare',
#     'pair': 'ETH/USDT',
#     'percent_volume': 7.33,
#     'price': 677.369,
#     'volume': 189529000.0,
#     'web': 'https://www.okex.com/market?product=eth_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/USDT',
#     'percent_volume': 5.29,
#     'price': 1361.92,
#     'volume': 136748000.0,
#     'web': 'https://www.okex.com/market?product=bch_usdt'},
#    {'name': 'Ink',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.01,
#     'price': 14.8101,
#     'volume': 129542000.0,
#     'web': 'https://www.okex.com/market?product=eos_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'TRUE/BTC',
#     'percent_volume': 3.54,
#     'price': 1.88636,
#     'volume': 91652700.0,
#     'web': 'https://www.okex.com/market?product=true_btc'},
#    {'name': 'NEM',
#     'pair': 'ETH/BTC',
#     'percent_volume': 3.28,
#     'price': 681.273,
#     'volume': 84703500.0,
#     'web': 'https://www.okex.com/market?product=eth_btc'},
#    {'name': 'MonaCoin',
#     'pair': 'LTC/USDT',
#     'percent_volume': 3.13,
#     'price': 138.352,
#     'volume': 80935600.0,
#     'web': 'https://www.okex.com/market?product=ltc_usdt'},
#    {'name': 'COMSA [ETH]',
#     'pair': 'ETC/USDT',
#     'percent_volume': 2.94,
#     'price': 17.561,
#     'volume': 76036600.0,
#     'web': 'https://www.okex.com/market?product=etc_usdt'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'COMSA [XEM]',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/USDT',
#     'percent_volume': 14.53,
#     'price': 14.7227,
#     'volume': 375644000.0,
#     'web': 'https://www.okex.com/market?product=eos_usdt'},
#    {'name': 'NEM',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.42,
#     'price': 8538.94,
#     'volume': 372970000.0,
#     'web': 'https://www.okex.com/market?product=btc_usdt'}],
#   'name': 'Lbank'},
#  {'markets': [{'name': 'Pepe Cash',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
# ...
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'AidosMarket'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'TradeOgre'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Stellar Decentralized Exchange'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Trade Satoshi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Braziliex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Bittylicious'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BTC Trade UA'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'CoinFalcon'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Paradex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Crex24'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Bleutrade'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Mr. Exchange'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Bitsane'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Gatecoin'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Nanex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'CoinCorner'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ezBtc'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Buda'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'cfinex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'InfinityCoin Exchange'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Coinbe'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Bitlish'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Bit2C'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'SouthXchange'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'CryptoMarket'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Paymium'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Cryptox'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Nocks'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Tripe Dice Exchange'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Stronghold'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Bitmaszyna'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Token Store'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Abucoins'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'CRXzone'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Coinrate'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Bisq'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Tux Exchange'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'OKCoin.cn'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Cryptomate'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BitKonan'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Dgtmarket'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'FreiExchange'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'RuDEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ISX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Ore.Bz'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Cryptohub'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'LocalTrade'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'GuldenTrader'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Heat Wallet'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Coingi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'C-Patex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ExcambrioRex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BarterDEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Novaexchange'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Coinlink'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Orionx'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'LEOxChange'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 8528.0,
#     'volume': 3677970000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'TCC Exchange'}]

# %% [markdown]
# > All methods are self explained in docstrings:

# %%
print(cmc.exchanges.__doc__)
# Out:
# Get all exchanges in coinmarketcap ranked by volumes
#         along with other metadata.
#
#         Args:
#             convert (str, optional): Convert volumes and prices
#                 between USD and BTC. As default ``"USD"``.
#
#         Returns (list):
#             Exchanges with markets and other data included.

# %% [markdown]
# ___________________________________
#
# ## Coinmarketcap API

# %%
show_page("api")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/api"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `listings()`
# List all criptocurrencies with their ids, names, symbol and website slug. You can use cached ``cryptocurrencies`` property also.

# %%
cmc.listings()
# Out:
# {'data': [{'id': 1,
#    'name': 'Bitcoin',
#    'symbol': 'BTC',
#    'website_slug': 'bitcoin'},
#   {'id': 2, 'name': 'Litecoin', 'symbol': 'LTC', 'website_slug': 'litecoin'},
#   {'id': 3, 'name': 'Namecoin', 'symbol': 'NMC', 'website_slug': 'namecoin'},
#   {'id': 4, 'name': 'Terracoin', 'symbol': 'TRC', 'website_slug': 'terracoin'},
#   {'id': 5, 'name': 'Peercoin', 'symbol': 'PPC', 'website_slug': 'peercoin'},
#   {'id': 6, 'name': 'Novacoin', 'symbol': 'NVC', 'website_slug': 'novacoin'},
#   {'id': 8,
#    'name': 'Feathercoin',
#    'symbol': 'FTC',
#    'website_slug': 'feathercoin'},
#   {'id': 9, 'name': 'Mincoin', 'symbol': 'MNC', 'website_slug': 'mincoin'},
#   {'id': 10, 'name': 'Freicoin', 'symbol': 'FRC', 'website_slug': 'freicoin'},
#   {'id': 13, 'name': 'Ixcoin', 'symbol': 'IXC', 'website_slug': 'ixcoin'},
#   {'id': 14, 'name': 'BitBar', 'symbol': 'BTB', 'website_slug': 'bitbar'},
#   {'id': 16,
#    'name': 'WorldCoin',
#    'symbol': 'WDC',
#    'website_slug': 'worldcoin'},
#   {'id': 17, 'name': 'Yacoin', 'symbol': 'YAC', 'website_slug': 'yacoin'},
#   {'id': 18,
#    'name': 'Digitalcoin',
#    'symbol': 'DGC',
#    'website_slug': 'digitalcoin'},
#   {'id': 20, 'name': 'Elacoin', 'symbol': 'ELC', 'website_slug': 'elacoin'},
#   {'id': 25, 'name': 'GoldCoin', 'symbol': 'GLD', 'website_slug': 'goldcoin'},
#   {'id': 31, 'name': 'Argentum', 'symbol': 'ARG', 'website_slug': 'argentum'},
#   {'id': 32, 'name': 'Fastcoin', 'symbol': 'FST', 'website_slug': 'fastcoin'},
#   {'id': 34, 'name': 'Bitgem', 'symbol': 'BTG', 'website_slug': 'bitgem'},
#   {'id': 35,
#    'name': 'Phoenixcoin',
#    'symbol': 'PXC',
#    'website_slug': 'phoenixcoin'},
#   {'id': 37, 'name': 'Megacoin', 'symbol': 'MEC', 'website_slug': 'megacoin'},
#   {'id': 41,
#    'name': 'Infinitecoin',
#    'symbol': 'IFC',
#    'website_slug': 'infinitecoin'},
#   {'id': 42,
#    'name': 'Primecoin',
#    'symbol': 'XPM',
#    'website_slug': 'primecoin'},
#   {'id': 43, 'name': 'Anoncoin', 'symbol': 'ANC', 'website_slug': 'anoncoin'},
#   {'id': 45,
#    'name': 'CasinoCoin',
#    'symbol': 'CSC',
#    'website_slug': 'casinocoin'},
#   {'id': 49, 'name': 'Bullion', 'symbol': 'CBX', 'website_slug': 'bullion'},
#   {'id': 50,
#    'name': 'Emerald Crypto',
#    'symbol': 'EMD',
#    'website_slug': 'emerald'},
#   {'id': 51,
#    'name': 'GlobalCoin',
#    'symbol': 'GLC',
#    'website_slug': 'globalcoin'},
#   {'id': 52, 'name': 'Ripple', 'symbol': 'XRP', 'website_slug': 'ripple'},
#   {'id': 53, 'name': 'Quark', 'symbol': 'QRK', 'website_slug': 'quark'},
#   {'id': 56, 'name': 'Zetacoin', 'symbol': 'ZET', 'website_slug': 'zetacoin'},
#   {'id': 57,
#    'name': 'SecureCoin',
#    'symbol': 'SRC',
#    'website_slug': 'securecoin'},
#   {'id': 58, 'name': 'Sexcoin', 'symbol': 'SXC', 'website_slug': 'sexcoin'},
#   {'id': 61, 'name': 'TagCoin', 'symbol': 'TAG', 'website_slug': 'tagcoin'},
#   {'id': 63, 'name': 'I0Coin', 'symbol': 'I0C', 'website_slug': 'i0coin'},
#   {'id': 64,
#    'name': 'FlorinCoin',
#    'symbol': 'FLO',
#    'website_slug': 'florincoin'},
#   {'id': 66, 'name': 'Nxt', 'symbol': 'NXT', 'website_slug': 'nxt'},
#   {'id': 67,
#    'name': 'Unobtanium',
#    'symbol': 'UNO',
#    'website_slug': 'unobtanium'},
#   {'id': 68,
#    'name': 'Joulecoin',
#    'symbol': 'XJO',
#    'website_slug': 'joulecoin'},
#   {'id': 69, 'name': 'Datacoin', 'symbol': 'DTC', 'website_slug': 'datacoin'},
#   {'id': 70, 'name': 'BetaCoin', 'symbol': 'BET', 'website_slug': 'betacoin'},
#   {'id': 71,
#    'name': 'GrandCoin',
#    'symbol': 'GDC',
#    'website_slug': 'grandcoin'},
#   {'id': 72,
#    'name': 'Deutsche eMark',
#    'symbol': 'DEM',
#    'website_slug': 'deutsche-emark'},
#   {'id': 74, 'name': 'Dogecoin', 'symbol': 'DOGE', 'website_slug': 'dogecoin'},
#   {'id': 75, 'name': 'NetCoin', 'symbol': 'NET', 'website_slug': 'netcoin'},
#   {'id': 76,
#    'name': 'Philosopher Stones',
#    'symbol': 'PHS',
#    'website_slug': 'philosopher-stones'},
#   {'id': 77, 'name': 'Diamond', 'symbol': 'DMD', 'website_slug': 'diamond'},
#   {'id': 78,
#    'name': 'HoboNickels',
#    'symbol': 'HBN',
#    'website_slug': 'hobonickels'},
#   {'id': 79,
#    'name': 'Tigercoin',
#    'symbol': 'TGC',
#    'website_slug': 'tigercoin'},
#   {'id': 80,
#    'name': 'Orbitcoin',
#    'symbol': 'ORB',
#    'website_slug': 'orbitcoin'},
#   {'id': 83, 'name': 'Omni', 'symbol': 'OMNI', 'website_slug': 'omni'},
#   {'id': 84, 'name': 'Catcoin', 'symbol': 'CAT', 'website_slug': 'catcoin'},
#   {'id': 87,
#    'name': 'FedoraCoin',
#    'symbol': 'TIPS',
#    'website_slug': 'fedoracoin'},
#   {'id': 88,
#    'name': 'RonPaulCoin',
#    'symbol': 'RPC',
#    'website_slug': 'ronpaulcoin'},
#   {'id': 89, 'name': 'Mooncoin', 'symbol': 'MOON', 'website_slug': 'mooncoin'},
#   {'id': 90, 'name': 'Dimecoin', 'symbol': 'DIME', 'website_slug': 'dimecoin'},
#   {'id': 93, 'name': '42-coin', 'symbol': '42', 'website_slug': '42-coin'},
#   {'id': 99, 'name': 'Vertcoin', 'symbol': 'VTC', 'website_slug': 'vertcoin'},
#   {'id': 101,
#    'name': 'KlondikeCoin',
#    'symbol': 'KDC',
#    'website_slug': 'klondikecoin'},
#   {'id': 103, 'name': 'RedCoin', 'symbol': 'RED', 'website_slug': 'redcoin'},
#   {'id': 107,
#    'name': 'LeafCoin',
#    'symbol': 'LEAF',
#    'website_slug': 'leafcoin'},
#   {'id': 109, 'name': 'DigiByte', 'symbol': 'DGB', 'website_slug': 'digibyte'},
#   {'id': 113,
#    'name': 'SmartCoin',
#    'symbol': 'SMC',
#    'website_slug': 'smartcoin'},
#   {'id': 114,
#    'name': 'TeslaCoin',
#    'symbol': 'TES',
#    'website_slug': 'teslacoin'},
#   {'id': 116,
#    'name': 'Karmacoin',
#    'symbol': 'KARMA',
#    'website_slug': 'karmacoin'},
#   {'id': 117,
#    'name': 'NobleCoin',
#    'symbol': 'NOBL',
#    'website_slug': 'noblecoin'},
#   {'id': 118, 'name': 'ReddCoin', 'symbol': 'RDD', 'website_slug': 'reddcoin'},
#   {'id': 120,
#    'name': 'Nyancoin',
#    'symbol': 'NYAN',
#    'website_slug': 'nyancoin'},
#   {'id': 121,
#    'name': 'UltraCoin',
#    'symbol': 'UTC',
#    'website_slug': 'ultracoin'},
#   {'id': 122, 'name': 'PotCoin', 'symbol': 'POT', 'website_slug': 'potcoin'},
#   {'id': 125,
#    'name': 'Blakecoin',
#    'symbol': 'BLC',
#    'website_slug': 'blakecoin'},
#   {'id': 128, 'name': 'MaxCoin', 'symbol': 'MAX', 'website_slug': 'maxcoin'},
#   {'id': 129,
#    'name': 'QubitCoin',
#    'symbol': 'Q2C',
#    'website_slug': 'qubitcoin'},
#   {'id': 130,
#    'name': 'HunterCoin',
#    'symbol': 'HUC',
#    'website_slug': 'huntercoin'},
#   {'id': 131, 'name': 'Dash', 'symbol': 'DASH', 'website_slug': 'dash'},
#   {'id': 132,
#    'name': 'Counterparty',
#    'symbol': 'XCP',
#    'website_slug': 'counterparty'},
#   {'id': 134,
#    'name': 'CacheCoin',
#    'symbol': 'CACH',
#    'website_slug': 'cachecoin'},
#   {'id': 135, 'name': 'TopCoin', 'symbol': 'TOP', 'website_slug': 'topcoin'},
#   {'id': 138, 'name': 'iCoin', 'symbol': 'ICN', 'website_slug': 'icoin'},
#   {'id': 141,
#    'name': 'Mintcoin',
#    'symbol': 'MINT',
#    'website_slug': 'mintcoin'},
#   {'id': 142, 'name': 'Aricoin', 'symbol': 'ARI', 'website_slug': 'aricoin'},
#   {'id': 145,
#    'name': 'DopeCoin',
#    'symbol': 'DOPE',
#    'website_slug': 'dopecoin'},
#   {'id': 148,
#    'name': 'Auroracoin',
#    'symbol': 'AUR',
#    'website_slug': 'auroracoin'},
#   {'id': 150,
#    'name': 'Animecoin',
#    'symbol': 'ANI',
#    'website_slug': 'animecoin'},
#   {'id': 151,
#    'name': 'Pesetacoin',
#    'symbol': 'PTC',
#    'website_slug': 'pesetacoin'},
#   {'id': 154,
#    'name': 'Marscoin',
#    'symbol': 'MARS',
#    'website_slug': 'marscoin'},
#   {'id': 159,
#    'name': 'Cashcoin',
#    'symbol': 'CASH',
#    'website_slug': 'cashcoin'},
#   {'id': 160, 'name': 'Riecoin', 'symbol': 'RIC', 'website_slug': 'riecoin'},
#   {'id': 161,
#    'name': 'Pandacoin',
#    'symbol': 'PND',
#    'website_slug': 'pandacoin-pnd'},
#   {'id': 164, 'name': 'MAZA', 'symbol': 'MZC', 'website_slug': 'mazacoin'},
#   {'id': 168,
#    'name': 'Uniform Fiscal Object',
#    'symbol': 'UFO',
#    'website_slug': 'uniform-fiscal-object'},
#   {'id': 170,
#    'name': 'BlackCoin',
#    'symbol': 'BLK',
#    'website_slug': 'blackcoin'},
#   {'id': 171, 'name': 'BatCoin', 'symbol': 'BAT', 'website_slug': 'batcoin'},
#   {'id': 174, 'name': 'LiteBar', 'symbol': 'LTB', 'website_slug': 'litebar'},
#   {'id': 175, 'name': 'Photon', 'symbol': 'PHO', 'website_slug': 'photon'},
#   {'id': 181,
#    'name': 'Zeitcoin',
#    'symbol': 'ZEIT',
#    'website_slug': 'zeitcoin'},
#   {'id': 182, 'name': 'Myriad', 'symbol': 'XMY', 'website_slug': 'myriad'},
#   {'id': 199,
#    'name': 'Skeincoin',
#    'symbol': 'SKC',
#    'website_slug': 'skeincoin'},
#   {'id': 201,
#    'name': 'Einsteinium',
#    'symbol': 'EMC2',
#    'website_slug': 'einsteinium'},
#   {'id': 205,
#    'name': 'Bitcoin Scrypt',
#    'symbol': 'BTCS',
#    'website_slug': 'bitcoin-scrypt'},
#   {'id': 206, 'name': 'Coin(O)', 'symbol': 'CNO', 'website_slug': 'coin'},
#   {'id': 212, 'name': 'ECC', 'symbol': 'ECC', 'website_slug': 'eccoin'},
#   {'id': 213,
#    'name': 'MonaCoin',
#    'symbol': 'MONA',
#    'website_slug': 'monacoin'},
#   {'id': 215, 'name': 'Rubycoin', 'symbol': 'RBY', 'website_slug': 'rubycoin'},
#   {'id': 217, 'name': 'Bela', 'symbol': 'BELA', 'website_slug': 'belacoin'},
#   {'id': 218,
#    'name': 'FlutterCoin',
#    'symbol': 'FLT',
#    'website_slug': 'fluttercoin'},
#   {'id': 221, 'name': 'OctoCoin', 'symbol': '888', 'website_slug': 'octocoin'},
#   {'id': 224,
#    'name': 'FairCoin',
#    'symbol': 'FAIR',
#    'website_slug': 'faircoin'},
#   {'id': 233,
#    'name': 'SolarCoin',
#    'symbol': 'SLR',
#    'website_slug': 'solarcoin'},
#   {'id': 234, 'name': 'e-Gulden', 'symbol': 'EFL', 'website_slug': 'e-gulden'},
#   {'id': 249,
#    'name': 'CryptoEscudo',
#    'symbol': 'CESC',
#    'website_slug': 'cryptoescudo'},
#   {'id': 254, 'name': 'Gulden', 'symbol': 'NLG', 'website_slug': 'gulden'},
#   {'id': 257, 'name': 'Polcoin', 'symbol': 'PLC', 'website_slug': 'polcoin'},
#   {'id': 258,
#    'name': 'Groestlcoin',
#    'symbol': 'GRS',
#    'website_slug': 'groestlcoin'},
#   {'id': 260,
#    'name': 'PetroDollar',
#    'symbol': 'XPD',
#    'website_slug': 'petrodollar'},
#   {'id': 263, 'name': 'PLNcoin', 'symbol': 'PLNC', 'website_slug': 'plncoin'},
#   {'id': 268,
#    'name': 'WhiteCoin',
#    'symbol': 'XWC',
#    'website_slug': 'whitecoin'},
#   {'id': 269, 'name': 'AsiaCoin', 'symbol': 'AC', 'website_slug': 'asiacoin'},
#   {'id': 275,
#    'name': 'PopularCoin',
#    'symbol': 'POP',
#    'website_slug': 'popularcoin'},
#   {'id': 276, 'name': 'Bitstar', 'symbol': 'BITS', 'website_slug': 'bitstar'},
#   {'id': 278,
#    'name': 'Quebecoin',
#    'symbol': 'QBC',
#    'website_slug': 'quebecoin'},
#   {'id': 279,
#    'name': 'CannaCoin',
#    'symbol': 'CCN',
#    'website_slug': 'cannacoin'},
#   {'id': 287,
#    'name': 'Slothcoin',
#    'symbol': 'SLOTH',
#    'website_slug': 'slothcoin'},
#   {'id': 290, 'name': 'BlueCoin', 'symbol': 'BLU', 'website_slug': 'bluecoin'},
#   {'id': 291,
#    'name': 'MaidSafeCoin',
#    'symbol': 'MAID',
#    'website_slug': 'maidsafecoin'},
#   {'id': 293,
#    'name': 'Bitcoin Plus',
#    'symbol': 'XBC',
#    'website_slug': 'bitcoin-plus'},
#   {'id': 295,
#    'name': 'BTCtalkcoin',
#    'symbol': 'TALK',
#    'website_slug': 'btctalkcoin'},
#   {'id': 298,
#    'name': 'NewYorkCoin',
#    'symbol': 'NYC',
#    'website_slug': 'newyorkcoin'},
#   {'id': 304,
#    'name': 'Canada eCoin',
#    'symbol': 'CDN',
#    'website_slug': 'canada-ecoin'},
#   {'id': 312, 'name': 'Guncoin', 'symbol': 'GUN', 'website_slug': 'guncoin'},
#   {'id': 313,
#    'name': 'PinkCoin',
#    'symbol': 'PINK',
#    'website_slug': 'pinkcoin'},
#   {'id': 316,
#    'name': 'Dreamcoin',
#    'symbol': 'DRM',
#    'website_slug': 'dreamcoin'},
#   {'id': 317,
#    'name': 'CoffeeCoin',
#    'symbol': 'CFC',
#    'website_slug': 'coffeecoin'},
#   {'id': 322,
#    'name': 'Energycoin',
#    'symbol': 'ENRG',
#    'website_slug': 'energycoin'},
#   {'id': 323, 'name': 'VeriCoin', 'symbol': 'VRC', 'website_slug': 'vericoin'},
#   {'id': 325, 'name': 'TEKcoin', 'symbol': 'TEK', 'website_slug': 'tekcoin'},
#   {'id': 328, 'name': 'Monero', 'symbol': 'XMR', 'website_slug': 'monero'},
#   {'id': 331,
#    'name': 'Litecoin Plus',
#    'symbol': 'LCP',
#    'website_slug': 'litecoin-plus'},
#   {'id': 333,
#    'name': 'Curecoin',
#    'symbol': 'CURE',
#    'website_slug': 'curecoin'},
#   {'id': 334,
#    'name': 'UnbreakableCoin',
#    'symbol': 'UNB',
#    'website_slug': 'unbreakablecoin'},
#   {'id': 337,
#    'name': 'CryptCoin',
#    'symbol': 'CRYPT',
#    'website_slug': 'cryptcoin'},
#   {'id': 338,
#    'name': 'QuazarCoin',
#    'symbol': 'QCN',
#    'website_slug': 'quazarcoin'},
#   {'id': 341,
#    'name': 'SuperCoin',
#    'symbol': 'SUPER',
#    'website_slug': 'supercoin'},
#   {'id': 344, 'name': 'Qora', 'symbol': 'QORA', 'website_slug': 'qora'},
#   {'id': 350,
#    'name': 'BoostCoin',
#    'symbol': 'BOST',
#    'website_slug': 'boostcoin'},
#   {'id': 353, 'name': 'Hyper', 'symbol': 'HYPER', 'website_slug': 'hyper'},
#   {'id': 356, 'name': 'BitQuark', 'symbol': 'BTQ', 'website_slug': 'bitquark'},
#   {'id': 360,
#    'name': 'Motocoin',
#    'symbol': 'MOTO',
#    'website_slug': 'motocoin'},
#   {'id': 362,
#    'name': 'CloakCoin',
#    'symbol': 'CLOAK',
#    'website_slug': 'cloakcoin'},
#   {'id': 366, 'name': 'BitSend', 'symbol': 'BSD', 'website_slug': 'bitsend'},
#   {'id': 367, 'name': 'Coin2.1', 'symbol': 'C2', 'website_slug': 'coin2-1'},
#   {'id': 370,
#    'name': 'Fantomcoin',
#    'symbol': 'FCN',
#    'website_slug': 'fantomcoin'},
#   {'id': 372,
#    'name': 'Bytecoin',
#    'symbol': 'BCN',
#    'website_slug': 'bytecoin-bcn'},
#   {'id': 374, 'name': 'ArtByte', 'symbol': 'ABY', 'website_slug': 'artbyte'},
#   {'id': 377, 'name': 'NavCoin', 'symbol': 'NAV', 'website_slug': 'nav-coin'},
#   {'id': 380, 'name': 'Uro', 'symbol': 'URO', 'website_slug': 'uro'},
#   {'id': 382,
#    'name': 'Granite',
#    'symbol': 'GRN',
#    'website_slug': 'granitecoin'},
#   {'id': 385,
#    'name': 'Donationcoin',
#    'symbol': 'DON',
#    'website_slug': 'donationcoin'},
#   {'id': 386,
#    'name': 'Piggycoin',
#    'symbol': 'PIGGY',
#    'website_slug': 'piggycoin'},
#   {'id': 389,
#    'name': 'Startcoin',
#    'symbol': 'START',
#    'website_slug': 'startcoin'},
#   {'id': 400, 'name': 'Kore', 'symbol': 'KORE', 'website_slug': 'korecoin'},
#   {'id': 405,
#    'name': 'DigitalNote',
#    'symbol': 'XDN',
#    'website_slug': 'digitalnote'},
#   {'id': 406,
#    'name': 'Boolberry',
#    'symbol': 'BBR',
#    'website_slug': 'boolberry'},
#   {'id': 411, 'name': 'SHACoin', 'symbol': 'SHA', 'website_slug': 'shacoin'},
#   {'id': 415,
#    'name': 'BlazeCoin',
#    'symbol': 'BLZ',
#    'website_slug': 'blazecoin'},
#   {'id': 416, 'name': 'HempCoin', 'symbol': 'THC', 'website_slug': 'hempcoin'},
#   {'id': 426,
#    'name': 'BritCoin',
#    'symbol': 'BRIT',
#    'website_slug': 'britcoin'},
#   {'id': 448, 'name': 'Stealth', 'symbol': 'XST', 'website_slug': 'stealth'},
#   {'id': 450,
#    'name': 'TrustPlus',
#    'symbol': 'TRUST',
#    'website_slug': 'trustplus'},
#   {'id': 460, 'name': 'Clams', 'symbol': 'CLAM', 'website_slug': 'clams'},
#   {'id': 461, 'name': 'Quatloo', 'symbol': 'QTL', 'website_slug': 'quatloo'},
#   {'id': 463,
#    'name': 'BitShares',
#    'symbol': 'BTS',
#    'website_slug': 'bitshares'},
#   {'id': 467,
#    'name': 'BitcoinDark',
#    'symbol': 'BTCD',
#    'website_slug': 'bitcoindark'},
#   {'id': 468,
#    'name': 'Truckcoin',
#    'symbol': 'TRK',
#    'website_slug': 'truckcoin'},
#   {'id': 470, 'name': 'Viacoin', 'symbol': 'VIA', 'website_slug': 'viacoin'},
#   {'id': 476,
#    'name': 'Firecoin',
#    'symbol': 'FIRE',
#    'website_slug': 'firecoin'},
#   {'id': 477,
#    'name': 'Triangles',
#    'symbol': 'TRI',
#    'website_slug': 'triangles'},
#   {'id': 493,
#    'name': 'ShadowCash',
#    'symbol': 'SDC',
#    'website_slug': 'shadowcash'},
#   {'id': 495, 'name': 'I/O Coin', 'symbol': 'IOC', 'website_slug': 'iocoin'},
#   {'id': 501,
#    'name': 'Cryptonite',
#    'symbol': 'XCN',
#    'website_slug': 'cryptonite'},
#   {'id': 502,
#    'name': 'Carboncoin',
#    'symbol': 'CARBON',
#    'website_slug': 'carboncoin'},
#   {'id': 506,
#    'name': 'CannabisCoin',
#    'symbol': 'CANN',
#    'website_slug': 'cannabiscoin'},
#   {'id': 512, 'name': 'Stellar', 'symbol': 'XLM', 'website_slug': 'stellar'},
#   {'id': 513, 'name': 'Titcoin', 'symbol': 'TIT', 'website_slug': 'titcoin'},
#   {'id': 519,
#    'name': 'VirtualCoin',
#    'symbol': 'VC',
#    'website_slug': 'virtualcoin'},
#   {'id': 520,
#    'name': 'Virtacoin',
#    'symbol': 'VTA',
#    'website_slug': 'virtacoin'},
#   {'id': 525,
#    'name': 'HyperStake',
#    'symbol': 'HYP',
#    'website_slug': 'hyperstake'},
#   {'id': 536, 'name': 'Joincoin', 'symbol': 'J', 'website_slug': 'joincoin'},
#   {'id': 541, 'name': 'Syscoin', 'symbol': 'SYS', 'website_slug': 'syscoin'},
#   {'id': 543, 'name': 'Bitmark', 'symbol': 'BTM', 'website_slug': 'bitmark'},
#   {'id': 545, 'name': 'Halcyon', 'symbol': 'HAL', 'website_slug': 'halcyon'},
#   {'id': 549,
#    'name': 'Storjcoin X',
#    'symbol': 'SJCX',
#    'website_slug': 'storjcoin-x'},
#   {'id': 551,
#    'name': 'NeosCoin',
#    'symbol': 'NEOS',
#    'website_slug': 'neoscoin'},
#   {'id': 558, 'name': 'Emercoin', 'symbol': 'EMC', 'website_slug': 'emercoin'},
#   {'id': 572,
#    'name': 'RabbitCoin',
#    'symbol': 'RBBT',
#    'website_slug': 'rabbitcoin'},
#   {'id': 573, 'name': 'Burst', 'symbol': 'BURST', 'website_slug': 'burst'},
#   {'id': 576,
#    'name': 'GameCredits',
#    'symbol': 'GAME',
#    'website_slug': 'gamecredits'},
#   {'id': 584,
#    'name': 'WeAreSatoshi',
#    'symbol': 'WSX',
#    'website_slug': 'wearesatoshi'},
#   {'id': 588, 'name': 'Ubiq', 'symbol': 'UBQ', 'website_slug': 'ubiq'},
#   {'id': 594,
#    'name': 'BunnyCoin',
#    'symbol': 'BUN',
#    'website_slug': 'bunnycoin'},
#   {'id': 597, 'name': 'Opal', 'symbol': 'OPAL', 'website_slug': 'opal'},
#   {'id': 601, 'name': 'Acoin', 'symbol': 'ACOIN', 'website_slug': 'acoin'},
#   {'id': 606,
#    'name': 'FoldingCoin',
#    'symbol': 'FLDC',
#    'website_slug': 'foldingcoin'},
#   {'id': 623, 'name': 'bitUSD', 'symbol': 'BITUSD', 'website_slug': 'bitusd'},
#   {'id': 624, 'name': 'bitCNY', 'symbol': 'BITCNY', 'website_slug': 'bitcny'},
#   {'id': 625, 'name': 'bitBTC', 'symbol': 'BITBTC', 'website_slug': 'bitbtc'},
#   {'id': 626, 'name': 'NuBits', 'symbol': 'USNBT', 'website_slug': 'nubits'},
#   {'id': 627,
#    'name': 'Sterlingcoin',
#    'symbol': 'SLG',
#    'website_slug': 'sterlingcoin'},
#   {'id': 629, 'name': 'Magi', 'symbol': 'XMG', 'website_slug': 'magi'},
#   {'id': 633,
#    'name': 'ExclusiveCoin',
#    'symbol': 'EXCL',
#    'website_slug': 'exclusivecoin'},
#   {'id': 638,
#    'name': 'Trollcoin',
#    'symbol': 'TROLL',
#    'website_slug': 'trollcoin'},
#   {'id': 643,
#    'name': 'SuperNET',
#    'symbol': 'UNITY',
#    'website_slug': 'supernet-unity'},
#   {'id': 644,
#    'name': 'GlobalBoost-Y',
#    'symbol': 'BSTY',
#    'website_slug': 'globalboost-y'},
#   {'id': 654,
#    'name': 'DigitalPrice',
#    'symbol': 'DP',
#    'website_slug': 'digitalprice'},
#   {'id': 656, 'name': 'Prime-XI', 'symbol': 'PXI', 'website_slug': 'prime-xi'},
#   {'id': 659,
#    'name': 'Bitswift',
#    'symbol': 'SWIFT',
#    'website_slug': 'bitswift'},
#   {'id': 660, 'name': 'Dashcoin', 'symbol': 'DSH', 'website_slug': 'dashcoin'},
#   {'id': 666,
#    'name': 'AurumCoin',
#    'symbol': 'AU',
#    'website_slug': 'aurumcoin'},
#   {'id': 671, 'name': 'GAIA', 'symbol': 'GAIA', 'website_slug': 'gaia'},
#   {'id': 680,
#    'name': 'Sativacoin',
#    'symbol': 'STV',
#    'website_slug': 'sativacoin'},
#   {'id': 692,
#    'name': 'GanjaCoin',
#    'symbol': 'MRJA',
#    'website_slug': 'ganjacoin'},
#   {'id': 693, 'name': 'Verge', 'symbol': 'XVG', 'website_slug': 'verge'},
#   {'id': 699, 'name': 'NuShares', 'symbol': 'NSR', 'website_slug': 'nushares'},
#   {'id': 702,
#    'name': 'SpreadCoin',
#    'symbol': 'SPR',
#    'website_slug': 'spreadcoin'},
#   {'id': 703, 'name': 'Rimbit', 'symbol': 'RBT', 'website_slug': 'rimbit'},
#   {'id': 706,
#    'name': 'MonetaryUnit',
#    'symbol': 'MUE',
#    'website_slug': 'monetaryunit'},
#   {'id': 707,
#    'name': 'Blocknet',
#    'symbol': 'BLOCK',
#    'website_slug': 'blocknet'},
#   {'id': 708, 'name': 'Gapcoin', 'symbol': 'GAP', 'website_slug': 'gapcoin'},
#   {'id': 719,
#    'name': 'TittieCoin',
#    'symbol': 'TTC',
#    'website_slug': 'tittiecoin'},
#   {'id': 720, 'name': 'Crown', 'symbol': 'CRW', 'website_slug': 'crown'},
#   {'id': 723, 'name': 'BitBay', 'symbol': 'BAY', 'website_slug': 'bitbay'},
#   {'id': 729,
#    'name': 'Blitzcash',
#    'symbol': 'BLITZ',
#    'website_slug': 'blitzcash'},
#   {'id': 730, 'name': 'GCN Coin', 'symbol': 'GCN', 'website_slug': 'gcn-coin'},
#   {'id': 733, 'name': 'Quotient', 'symbol': 'XQN', 'website_slug': 'quotient'},
#   {'id': 734, 'name': 'Bytecent', 'symbol': 'BYC', 'website_slug': 'bytecent'},
#   {'id': 747,
#    'name': 'Bitcoin Fast',
#    'symbol': 'BCF',
#    'website_slug': 'bitcoinfast'},
#   {'id': 760, 'name': 'OKCash', 'symbol': 'OK', 'website_slug': 'okcash'},
#   {'id': 764, 'name': 'PayCoin', 'symbol': 'XPY', 'website_slug': 'paycoin2'},
#   {'id': 766, 'name': 'vTorrent', 'symbol': 'VTR', 'website_slug': 'vtorrent'},
#   {'id': 778,
#    'name': 'bitGold',
#    'symbol': 'BITGOLD',
#    'website_slug': 'bitgold'},
#   {'id': 781, 'name': 'Unitus', 'symbol': 'UIS', 'website_slug': 'unitus'},
#   {'id': 785,
#    'name': 'GoldPieces',
#    'symbol': 'GP',
#    'website_slug': 'goldpieces'},
#   {'id': 788,
#    'name': 'Circuits of Value',
#    'symbol': 'COVAL',
#    'website_slug': 'circuits-of-value'},
#   {'id': 789, 'name': 'Nexus', 'symbol': 'NXS', 'website_slug': 'nexus'},
#   {'id': 795,
#    'name': 'SoonCoin',
#    'symbol': 'SOON',
#    'website_slug': 'sooncoin'},
#   {'id': 796,
#    'name': 'MetalCoin',
#    'symbol': 'METAL',
#    'website_slug': 'metalcoin'},
#   {'id': 797, 'name': 'IncaKoin', 'symbol': 'NKA', 'website_slug': 'incakoin'},
#   {'id': 799,
#    'name': 'SmileyCoin',
#    'symbol': 'SMLY',
#    'website_slug': 'smileycoin'},
#   {'id': 804,
#    'name': 'AmberCoin',
#    'symbol': 'AMBER',
#    'website_slug': 'ambercoin'},
#   {'id': 812,
#    'name': 'Machinecoin',
#    'symbol': 'MAC',
#    'website_slug': 'machinecoin'},
#   {'id': 813,
#    'name': 'bitSilver',
#    'symbol': 'BITSILVER',
#    'website_slug': 'bitsilver'},
#   {'id': 814, 'name': 'Dotcoin', 'symbol': 'DOT', 'website_slug': 'dotcoin'},
#   {'id': 815,
#    'name': 'Kobocoin',
#    'symbol': 'KOBO',
#    'website_slug': 'kobocoin'},
#   {'id': 818, 'name': 'PayCon', 'symbol': 'CON', 'website_slug': 'paycon'},
#   {'id': 819,
#    'name': 'Bean Cash',
#    'symbol': 'BITB',
#    'website_slug': 'bean-cash'},
#   {'id': 823, 'name': 'GeoCoin', 'symbol': 'GEO', 'website_slug': 'geocoin'},
#   {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'website_slug': 'tether'},
#   {'id': 831,
#    'name': 'Wild Beast Block',
#    'symbol': 'WBB',
#    'website_slug': 'wild-beast-block'},
#   {'id': 833, 'name': 'GridCoin', 'symbol': 'GRC', 'website_slug': 'gridcoin'},
#   {'id': 836, 'name': 'Vcash', 'symbol': 'XVC', 'website_slug': 'vcash'},
#   {'id': 837, 'name': 'X-Coin', 'symbol': 'XCO', 'website_slug': 'x-coin'},
#   {'id': 841,
#    'name': 'Sharkcoin',
#    'symbol': 'SAK',
#    'website_slug': 'sharkcoin'},
#   {'id': 842, 'name': 'Bitz', 'symbol': 'BITZ', 'website_slug': 'bitz'},
#   {'id': 853,
#    'name': 'LiteDoge',
#    'symbol': 'LDOGE',
#    'website_slug': 'litedoge'},
#   {'id': 855, 'name': 'UNCoin', 'symbol': 'UNC', 'website_slug': 'uncoin'},
#   {'id': 857,
#    'name': 'SongCoin',
#    'symbol': 'SONG',
#    'website_slug': 'songcoin'},
#   {'id': 859, 'name': 'Woodcoin', 'symbol': 'LOG', 'website_slug': 'woodcoin'},
#   {'id': 865,
#    'name': 'Selfiecoin',
#    'symbol': 'SLFI',
#    'website_slug': 'selfiecoin'},
#   {'id': 869, 'name': 'Crave', 'symbol': 'CRAVE', 'website_slug': 'crave'},
#   {'id': 870, 'name': 'Pura', 'symbol': 'PURA', 'website_slug': 'pura'},
#   {'id': 873, 'name': 'NEM', 'symbol': 'XEM', 'website_slug': 'nem'},
#   {'id': 876,
#    'name': 'TrickyCoin',
#    'symbol': 'TRICK',
#    'website_slug': 'trickycoin'},
#   {'id': 878,
#    'name': 'CyberCoin',
#    'symbol': 'CC',
#    'website_slug': 'cybercoin'},
#   {'id': 884, 'name': 'P7Coin', 'symbol': 'P7C', 'website_slug': 'p7coin'},
#   {'id': 890, 'name': '8Bit', 'symbol': '8BIT', 'website_slug': '8bit'},
#   {'id': 892, 'name': 'LeaCoin', 'symbol': 'LEA', 'website_slug': 'leacoin'},
#   {'id': 894, 'name': 'Neutron', 'symbol': 'NTRN', 'website_slug': 'neutron'},
#   {'id': 895, 'name': 'Xaurum', 'symbol': 'XAUR', 'website_slug': 'xaurum'},
#   {'id': 898,
#    'name': 'Californium',
#    'symbol': 'CF',
#    'website_slug': 'californium'},
#   {'id': 911,
#    'name': 'Advanced Internet Blocks',
#    'symbol': 'AIB',
#    'website_slug': 'advanced-internet-blocks'},
#   {'id': 912, 'name': 'EggCoin', 'symbol': 'EGG', 'website_slug': 'eggcoin'},
#   {'id': 914, 'name': 'Sphere', 'symbol': 'SPHR', 'website_slug': 'sphere'},
#   {'id': 916,
#    'name': 'MedicCoin',
#    'symbol': 'MEDIC',
#    'website_slug': 'mediccoin'},
#   {'id': 918, 'name': 'Bubble', 'symbol': 'BUB', 'website_slug': 'bubble'},
#   {'id': 920,
#    'name': 'MUSE',
#    'symbol': 'MUSE',
#    'website_slug': 'bitshares-music'},
#   {'id': 921,
#    'name': 'Universal Currency',
#    'symbol': 'UNIT',
#    'website_slug': 'universal-currency'},
#   {'id': 924,
#    'name': 'ShellCoin',
#    'symbol': 'SHELL',
#    'website_slug': 'shellcoin'},
#   {'id': 933, 'name': 'Crypto', 'symbol': 'CTO', 'website_slug': 'crypto'},
#   {'id': 934, 'name': 'ParkByte', 'symbol': 'PKB', 'website_slug': 'parkbyte'},
#   {'id': 938, 'name': 'ARbit', 'symbol': 'ARB', 'website_slug': 'arbit'},
#   {'id': 939, 'name': 'Gambit', 'symbol': 'GAM', 'website_slug': 'gambit'},
#   {'id': 945, 'name': 'Bata', 'symbol': 'BTA', 'website_slug': 'bata'},
#   {'id': 948,
#    'name': 'AudioCoin',
#    'symbol': 'ADC',
#    'website_slug': 'audiocoin'},
#   {'id': 951, 'name': 'Synergy', 'symbol': 'SNRG', 'website_slug': 'synergy'},
#   {'id': 954, 'name': 'bitEUR', 'symbol': 'BITEUR', 'website_slug': 'biteur'},
#   {'id': 959, 'name': 'UniCoin', 'symbol': 'UNIC', 'website_slug': 'unicoin'},
#   {'id': 960, 'name': 'FujiCoin', 'symbol': 'FJC', 'website_slug': 'fujicoin'},
#   {'id': 964,
#    'name': 'EuropeCoin',
#    'symbol': 'ERC',
#    'website_slug': 'europecoin'},
#   {'id': 965,
#    'name': 'The Cypherfunks',
#    'symbol': 'FUNK',
#    'website_slug': 'the-cypherfunks'},
#   {'id': 977, 'name': 'Hexx', 'symbol': 'HXX', 'website_slug': 'hexx'},
#   {'id': 978, 'name': 'Ratecoin', 'symbol': 'XRA', 'website_slug': 'ratecoin'},
#   {'id': 983,
#    'name': 'Metal Music Coin',
#    'symbol': 'MTLMC3',
#    'website_slug': 'metal-music-coin'},
#   {'id': 986,
#    'name': 'CrevaCoin',
#    'symbol': 'CREVA',
#    'website_slug': 'crevacoin'},
#   {'id': 988,
#    'name': 'IrishCoin',
#    'symbol': 'IRL',
#    'website_slug': 'irishcoin'},
#   {'id': 990, 'name': 'Bitzeny', 'symbol': 'ZNY', 'website_slug': 'bitzeny'},
#   {'id': 992,
#    'name': 'Cycling Coin',
#    'symbol': 'CYC',
#    'website_slug': 'cycling-coin'},
#   {'id': 993, 'name': 'BowsCoin', 'symbol': 'BSC', 'website_slug': 'bowscoin'},
#   {'id': 994,
#    'name': 'AnarchistsPrime',
#    'symbol': 'ACP',
#    'website_slug': 'anarchistsprime'},
#   {'id': 997,
#    'name': 'TAGRcoin',
#    'symbol': 'TAGR',
#    'website_slug': 'tagrcoin'},
#   {'id': 998,
#    'name': 'CompuCoin',
#    'symbol': 'CPN',
#    'website_slug': 'compucoin'},
#   {'id': 999,
#    'name': 'ChainCoin',
#    'symbol': 'CHC',
#    'website_slug': 'chaincoin'},
#   {'id': 1002,
#    'name': 'Sprouts',
#    'symbol': 'SPRTS',
#    'website_slug': 'sprouts'},
#   {'id': 1004,
#    'name': 'Helleniccoin',
#    'symbol': 'HNC',
#    'website_slug': 'helleniccoin'},
#   {'id': 1006, 'name': 'FutCoin', 'symbol': 'FUTC', 'website_slug': 'futcoin'},
#   {'id': 1008,
#    'name': 'Capricoin',
#    'symbol': 'CPC',
#    'website_slug': 'capricoin'},
#   {'id': 1010,
#    'name': 'Flaxscript',
#    'symbol': 'FLAX',
#    'website_slug': 'flaxscript'},
#   {'id': 1011,
#    'name': 'Cthulhu Offerings',
#    'symbol': 'OFF',
#    'website_slug': 'cthulhu-offerings'},
#   {'id': 1018,
#    'name': 'BiosCrypto',
#    'symbol': 'BIOS',
#    'website_slug': 'bios-crypto'},
#   {'id': 1019, 'name': 'Manna', 'symbol': 'MANNA', 'website_slug': 'manna'},
#   {'id': 1020, 'name': 'Axiom', 'symbol': 'AXIOM', 'website_slug': 'axiom'},
#   {'id': 1022, 'name': 'LEOcoin', 'symbol': 'LEO', 'website_slug': 'leocoin'},
#   {'id': 1026, 'name': 'Aeon', 'symbol': 'AEON', 'website_slug': 'aeon'},
#   {'id': 1027,
#    'name': 'Ethereum',
#    'symbol': 'ETH',
#    'website_slug': 'ethereum'},
#   {'id': 1028, 'name': 'SJWCoin', 'symbol': 'SJW', 'website_slug': 'sjwcoin'},
#   {'id': 1032,
#    'name': 'TransferCoin',
#    'symbol': 'TX',
#    'website_slug': 'transfercoin'},
#   {'id': 1033,
#    'name': 'GuccioneCoin',
#    'symbol': 'GCC',
#    'website_slug': 'guccionecoin'},
#   {'id': 1035,
#    'name': 'AmsterdamCoin',
#    'symbol': 'AMS',
#    'website_slug': 'amsterdamcoin'},
#   {'id': 1038,
#    'name': 'Eurocoin',
#    'symbol': 'EUC',
#    'website_slug': 'eurocoin'},
#   {'id': 1042, 'name': 'Siacoin', 'symbol': 'SC', 'website_slug': 'siacoin'},
#   {'id': 1044,
#    'name': 'Global Currency Reserve',
#    'symbol': 'GCR',
#    'website_slug': 'global-currency-reserve'},
#   {'id': 1045,
#    'name': 'DeltaCredits',
#    'symbol': 'DCRE',
#    'website_slug': 'deltacredits'},
#   {'id': 1048,
#    'name': 'SatoshiMadness',
#    'symbol': 'MAD',
#    'website_slug': 'satoshimadness'},
#   {'id': 1050, 'name': 'Shift', 'symbol': 'SHIFT', 'website_slug': 'shift'},
#   {'id': 1052, 'name': 'VectorAI', 'symbol': 'VEC2', 'website_slug': 'vector'},
#   {'id': 1053,
#    'name': 'Bolivarcoin',
#    'symbol': 'BOLI',
#    'website_slug': 'bolivarcoin'},
#   {'id': 1058,
#    'name': 'SpaceCoin',
#    'symbol': 'SPACE',
#    'website_slug': 'spacecoin'},
#   {'id': 1062, 'name': 'Flycoin', 'symbol': 'FLY', 'website_slug': 'flycoin'},
#   {'id': 1063,
#    'name': 'Bitcrystals',
#    'symbol': 'BCY',
#    'website_slug': 'bitcrystals'},
#   {'id': 1065,
#    'name': 'Fonziecoin',
#    'symbol': 'FONZ',
#    'website_slug': 'fonziecoin'},
#   {'id': 1066, 'name': 'Pakcoin', 'symbol': 'PAK', 'website_slug': 'pakcoin'},
#   {'id': 1069,
#    'name': 'Influxcoin',
#    'symbol': 'INFX',
#    'website_slug': 'influxcoin'},
#   {'id': 1070, 'name': 'Expanse', 'symbol': 'EXP', 'website_slug': 'expanse'},
#   {'id': 1073, 'name': 'Steps', 'symbol': 'STEPS', 'website_slug': 'steps'},
#   {'id': 1082, 'name': 'SIBCoin', 'symbol': 'SIB', 'website_slug': 'sibcoin'},
#   {'id': 1084,
#    'name': 'IslaCoin',
#    'symbol': 'ISL',
#    'website_slug': 'islacoin'},
#   {'id': 1085, 'name': 'Swing', 'symbol': 'SWING', 'website_slug': 'swing'},
#   {'id': 1087, 'name': 'Factom', 'symbol': 'FCT', 'website_slug': 'factom'},
#   {'id': 1089,
#    'name': 'ParallelCoin',
#    'symbol': 'DUO',
#    'website_slug': 'parallelcoin'},
#   {'id': 1090,
#    'name': 'Save and Gain',
#    'symbol': 'SANDG',
#    'website_slug': 'save-and-gain'},
#   {'id': 1093,
#    'name': 'Prototanium',
#    'symbol': 'PR',
#    'website_slug': 'prototanium'},
#   {'id': 1096,
#    'name': 'OsmiumCoin',
#    'symbol': 'OS76',
#    'website_slug': 'osmiumcoin'},
#   {'id': 1099,
#    'name': 'Moneta',
#    'symbol': 'MONETA',
#    'website_slug': 'moneta2'},
#   {'id': 1100,
#    'name': 'DigiCube',
#    'symbol': 'CUBE',
#    'website_slug': 'digicube'},
#   {'id': 1104, 'name': 'Augur', 'symbol': 'REP', 'website_slug': 'augur'},
#   {'id': 1106,
#    'name': 'StrongHands',
#    'symbol': 'SHND',
#    'website_slug': 'stronghands'},
#   {'id': 1107, 'name': 'PACcoin', 'symbol': '$PAC', 'website_slug': 'paccoin'},
#   {'id': 1109, 'name': 'Elite', 'symbol': '1337', 'website_slug': '1337coin'},
#   {'id': 1110, 'name': 'Money', 'symbol': '$$$', 'website_slug': 'money'},
#   {'id': 1111,
#    'name': 'SOILcoin',
#    'symbol': 'SOIL',
#    'website_slug': 'soilcoin'},
#   {'id': 1113,
#    'name': 'SecretCoin',
#    'symbol': 'SCRT',
#    'website_slug': 'secretcoin'},
#   {'id': 1120,
#    'name': 'DraftCoin',
#    'symbol': 'DFT',
#    'website_slug': 'draftcoin'},
#   {'id': 1123, 'name': 'OBITS', 'symbol': 'OBITS', 'website_slug': 'obits'},
#   {'id': 1125, 'name': 'Synereo', 'symbol': 'AMP', 'website_slug': 'synereo'},
#   {'id': 1128,
#    'name': 'GBCGoldCoin',
#    'symbol': 'GBC',
#    'website_slug': 'gbcgoldcoin'},
#   {'id': 1131, 'name': 'X2', 'symbol': 'X2', 'website_slug': 'x2'},
#   {'id': 1135,
#    'name': 'ClubCoin',
#    'symbol': 'CLUB',
#    'website_slug': 'clubcoin'},
#   {'id': 1136, 'name': 'Adzcoin', 'symbol': 'ADZ', 'website_slug': 'adzcoin'},
#   {'id': 1139,
#    'name': 'MindCoin',
#    'symbol': 'MND',
#    'website_slug': 'mindcoin'},
#   {'id': 1141, 'name': 'Moin', 'symbol': 'MOIN', 'website_slug': 'moin'},
#   {'id': 1146,
#    'name': 'AvatarCoin',
#    'symbol': 'AV',
#    'website_slug': 'avatarcoin'},
#   {'id': 1147,
#    'name': 'RussiaCoin',
#    'symbol': 'RC',
#    'website_slug': 'russiacoin'},
#   {'id': 1148,
#    'name': 'EverGreenCoin',
#    'symbol': 'EGC',
#    'website_slug': 'evergreencoin'},
#   {'id': 1151,
#    'name': 'Opescoin',
#    'symbol': 'OPES',
#    'website_slug': 'opescoin'},
#   {'id': 1153,
#    'name': 'Creditbit',
#    'symbol': 'CRB',
#    'website_slug': 'creditbit'},
#   {'id': 1154, 'name': 'Radium', 'symbol': 'RADS', 'website_slug': 'radium'},
#   {'id': 1155,
#    'name': 'Litecred',
#    'symbol': 'LTCR',
#    'website_slug': 'litecred'},
#   {'id': 1156, 'name': 'Yocoin', 'symbol': 'YOC', 'website_slug': 'yocoin'},
#   {'id': 1157,
#    'name': 'AlpaCoin',
#    'symbol': 'APC',
#    'website_slug': 'alpacoin'},
#   {'id': 1159, 'name': 'SaluS', 'symbol': 'SLS', 'website_slug': 'salus'},
#   {'id': 1164, 'name': 'Francs', 'symbol': 'FRN', 'website_slug': 'francs'},
#   {'id': 1165,
#    'name': 'Evil Coin',
#    'symbol': 'EVIL',
#    'website_slug': 'evil-coin'},
#   {'id': 1166, 'name': 'WARP', 'symbol': 'WARP', 'website_slug': 'warp'},
#   {'id': 1168, 'name': 'Decred', 'symbol': 'DCR', 'website_slug': 'decred'},
#   {'id': 1169, 'name': 'PIVX', 'symbol': 'PIVX', 'website_slug': 'pivx'},
#   {'id': 1172,
#    'name': 'Safe Exchange Coin',
#    'symbol': 'SAFEX',
#    'website_slug': 'safe-exchange-coin'},
#   {'id': 1173,
#    'name': 'HempCoin',
#    'symbol': 'HMP',
#    'website_slug': 'hempcoin-hmp'},
#   {'id': 1175, 'name': 'Rubies', 'symbol': 'RBIES', 'website_slug': 'rubies'},
#   {'id': 1176,
#    'name': 'Asiadigicoin',
#    'symbol': 'ADCN',
#    'website_slug': 'asiadigicoin'},
#   {'id': 1180, 'name': 'Destiny', 'symbol': 'DES', 'website_slug': 'destiny'},
#   {'id': 1182,
#    'name': 'KiloCoin',
#    'symbol': 'KLC',
#    'website_slug': 'kilocoin'},
#   {'id': 1184,
#    'name': 'SproutsExtreme',
#    'symbol': 'SPEX',
#    'website_slug': 'sproutsextreme'},
#   {'id': 1185,
#    'name': 'TrumpCoin',
#    'symbol': 'TRUMP',
#    'website_slug': 'trumpcoin'},
#   {'id': 1187,
#    'name': 'VIP Tokens',
#    'symbol': 'VIP',
#    'website_slug': 'vip-tokens'},
#   {'id': 1191,
#    'name': 'Memetic / PepeCoin',
#    'symbol': 'MEME',
#    'website_slug': 'memetic'},
#   {'id': 1192, 'name': 'Pulse', 'symbol': 'PULSE', 'website_slug': 'pulse'},
#   {'id': 1193, 'name': 'C-Bit', 'symbol': 'XCT', 'website_slug': 'c-bit'},
#   {'id': 1194,
#    'name': 'Independent Money System',
#    'symbol': 'IMS',
#    'website_slug': 'independent-money-system'},
#   {'id': 1195,
#    'name': 'HOdlcoin',
#    'symbol': 'HODL',
#    'website_slug': 'hodlcoin'},
#   {'id': 1198, 'name': 'BigUp', 'symbol': 'BIGUP', 'website_slug': 'bigup'},
#   {'id': 1200,
#    'name': 'NevaCoin',
#    'symbol': 'NEVA',
#    'website_slug': 'nevacoin'},
#   {'id': 1206,
#    'name': 'BumbaCoin',
#    'symbol': 'BUMBA',
#    'website_slug': 'bumbacoin'},
#   {'id': 1208,
#    'name': 'RevolutionVR',
#    'symbol': 'RVR',
#    'website_slug': 'revolutionvr'},
#   {'id': 1209, 'name': 'PosEx', 'symbol': 'PEX', 'website_slug': 'posex'},
#   {'id': 1210, 'name': 'Cabbage', 'symbol': 'CAB', 'website_slug': 'cabbage'},
#   {'id': 1212,
#    'name': 'MojoCoin',
#    'symbol': 'MOJO',
#    'website_slug': 'mojocoin'},
#   {'id': 1213,
#    'name': 'GoldMaxCoin',
#    'symbol': 'GMX',
#    'website_slug': 'goldmaxcoin'},
#   {'id': 1214, 'name': 'Lisk', 'symbol': 'LSK', 'website_slug': 'lisk'},
#   {'id': 1216, 'name': 'EDRCoin', 'symbol': 'EDRC', 'website_slug': 'edrcoin'},
#   {'id': 1218,
#    'name': 'PostCoin',
#    'symbol': 'POST',
#    'website_slug': 'postcoin'},
#   {'id': 1220, 'name': 'HitCoin', 'symbol': 'HTC', 'website_slug': 'hitcoin'},
#   {'id': 1222, 'name': 'Operand', 'symbol': 'OP', 'website_slug': 'operand'},
#   {'id': 1223,
#    'name': 'BERNcash',
#    'symbol': 'BERN',
#    'website_slug': 'berncash'},
#   {'id': 1226, 'name': 'Qwark', 'symbol': 'QWARK', 'website_slug': 'qwark'},
#   {'id': 1229,
#    'name': 'DigixDAO',
#    'symbol': 'DGD',
#    'website_slug': 'digixdao'},
#   {'id': 1230, 'name': 'Steem', 'symbol': 'STEEM', 'website_slug': 'steem'},
#   {'id': 1234,
#    'name': 'Fantasy Cash',
#    'symbol': 'FANS',
#    'website_slug': 'fantasy-cash'},
#   {'id': 1238, 'name': 'Espers', 'symbol': 'ESP', 'website_slug': 'espers'},
#   {'id': 1241,
#    'name': 'FuzzBalls',
#    'symbol': 'FUZZ',
#    'website_slug': 'fuzzballs'},
#   {'id': 1243,
#    'name': 'DarkLisk',
#    'symbol': 'DISK',
#    'website_slug': 'darklisk'},
#   {'id': 1244, 'name': 'HiCoin', 'symbol': 'XHI', 'website_slug': 'hicoin'},
#   {'id': 1247,
#    'name': 'AquariusCoin',
#    'symbol': 'ARCO',
#    'website_slug': 'aquariuscoin'},
#   {'id': 1248,
#    'name': 'Bitcoin 21',
#    'symbol': 'XBTC21',
#    'website_slug': 'bitcoin-21'},
#   {'id': 1249, 'name': 'Elcoin', 'symbol': 'EL', 'website_slug': 'elcoin-el'},
#   {'id': 1250, 'name': 'Zurcoin', 'symbol': 'ZUR', 'website_slug': 'zurcoin'},
#   {'id': 1251,
#    'name': 'SixEleven',
#    'symbol': '611',
#    'website_slug': 'sixeleven'},
#   {'id': 1252, 'name': '2GIVE', 'symbol': '2GIVE', 'website_slug': '2give'},
#   {'id': 1254,
#    'name': 'PlatinumBAR',
#    'symbol': 'XPTX',
#    'website_slug': 'platinumbar'},
#   {'id': 1256,
#    'name': 'Alphabit',
#    'symbol': 'ABC',
#    'website_slug': 'alphabitcoinfund'},
#   {'id': 1257,
#    'name': 'LanaCoin',
#    'symbol': 'LANA',
#    'website_slug': 'lanacoin'},
#   {'id': 1259,
#    'name': 'PonziCoin',
#    'symbol': 'PONZI',
#    'website_slug': 'ponzicoin'},
#   {'id': 1264,
#    'name': 'TeslaCoilCoin',
#    'symbol': 'TESLA',
#    'website_slug': 'teslacoilcoin'},
#   {'id': 1266,
#    'name': 'MarteXcoin',
#    'symbol': 'MXT',
#    'website_slug': 'martexcoin'},
#   {'id': 1268, 'name': 'Nullex', 'symbol': 'NLX', 'website_slug': 'nullex'},
#   {'id': 1269,
#    'name': 'RichCoin',
#    'symbol': 'RICHX',
#    'website_slug': 'richcoin'},
#   {'id': 1271,
#    'name': 'PrismChain',
#    'symbol': 'PRM',
#    'website_slug': 'prismchain'},
#   {'id': 1274, 'name': 'Waves', 'symbol': 'WAVES', 'website_slug': 'waves'},
#   {'id': 1275, 'name': 'Newbium', 'symbol': 'NEWB', 'website_slug': 'newbium'},
#   {'id': 1276,
#    'name': 'ICO OpenLedger',
#    'symbol': 'ICOO',
#    'website_slug': 'ico-openledger'},
#   {'id': 1281, 'name': 'ION', 'symbol': 'ION', 'website_slug': 'ion'},
#   {'id': 1282,
#    'name': 'High Voltage',
#    'symbol': 'HVCO',
#    'website_slug': 'high-voltage'},
#   {'id': 1283, 'name': 'Mineum', 'symbol': 'MNM', 'website_slug': 'mineum'},
#   {'id': 1284,
#    'name': 'RevolverCoin',
#    'symbol': 'XRE',
#    'website_slug': 'revolvercoin'},
#   {'id': 1285,
#    'name': 'GoldBlocks',
#    'symbol': 'GB',
#    'website_slug': 'goldblocks'},
#   {'id': 1286,
#    'name': 'Breakout',
#    'symbol': 'BRK',
#    'website_slug': 'breakout'},
#   {'id': 1288,
#    'name': 'Debitcoin',
#    'symbol': 'DBTC',
#    'website_slug': 'debitcoin'},
#   {'id': 1291, 'name': 'Comet', 'symbol': 'CMT', 'website_slug': 'comet'},
#   {'id': 1294, 'name': 'Rise', 'symbol': 'RISE', 'website_slug': 'rise'},
#   {'id': 1297,
#    'name': 'ChessCoin',
#    'symbol': 'CHESS',
#    'website_slug': 'chesscoin'},
#   {'id': 1298,
#    'name': 'LBRY Credits',
#    'symbol': 'LBC',
#    'website_slug': 'library-credit'},
#   {'id': 1299,
#    'name': 'PutinCoin',
#    'symbol': 'PUT',
#    'website_slug': 'putincoin'},
#   {'id': 1301,
#    'name': 'Happy Creator Coin',
#    'symbol': 'HCC',
#    'website_slug': 'happy-creator-coin'},
#   {'id': 1303,
#    'name': 'Breakout Stake',
#    'symbol': 'BRX',
#    'website_slug': 'breakout-stake'},
#   {'id': 1304,
#    'name': 'Syndicate',
#    'symbol': 'SYNX',
#    'website_slug': 'syndicate'},
#   {'id': 1306,
#    'name': 'Cryptojacks',
#    'symbol': 'CJ',
#    'website_slug': 'cryptojacks'},
#   {'id': 1307, 'name': 'ReeCoin', 'symbol': 'REE', 'website_slug': 'reecoin'},
#   {'id': 1308,
#    'name': 'HEAT',
#    'symbol': 'HEAT',
#    'website_slug': 'heat-ledger'},
#   {'id': 1309,
#    'name': 'LetItRide',
#    'symbol': 'LIR',
#    'website_slug': 'letitride'},
#   {'id': 1310,
#    'name': 'DAPPSTER',
#    'symbol': 'DLISK',
#    'website_slug': 'dappster'},
#   {'id': 1312,
#    'name': 'Steem Dollars',
#    'symbol': 'SBD',
#    'website_slug': 'steem-dollars'},
#   {'id': 1313,
#    'name': 'LinkedCoin',
#    'symbol': 'LKC',
#    'website_slug': 'linkedcoin'},
#   {'id': 1315, 'name': 'Chronos', 'symbol': 'CRX', 'website_slug': 'chronos'},
#   {'id': 1320, 'name': 'Ardor', 'symbol': 'ARDR', 'website_slug': 'ardor'},
#   {'id': 1321,
#    'name': 'Ethereum Classic',
#    'symbol': 'ETC',
#    'website_slug': 'ethereum-classic'},
#   {'id': 1322, 'name': '808Coin', 'symbol': '808', 'website_slug': '808coin'},
#   {'id': 1323,
#    'name': 'First Bitcoin',
#    'symbol': 'BIT',
#    'website_slug': 'first-bitcoin'},
#   {'id': 1330,
#    'name': 'PokeCoin',
#    'symbol': 'POKE',
#    'website_slug': 'pokecoin'},
#   {'id': 1334,
#    'name': 'Elementrem',
#    'symbol': 'ELE',
#    'website_slug': 'elementrem'},
#   {'id': 1336, 'name': 'UGAIN', 'symbol': 'GAIN', 'website_slug': 'ugain'},
#   {'id': 1340, 'name': 'Karbo', 'symbol': 'KRB', 'website_slug': 'karbo'},
#   {'id': 1341,
#    'name': 'VapersCoin',
#    'symbol': 'VPRC',
#    'website_slug': 'vaperscoin'},
#   {'id': 1343,
#    'name': 'Stratis',
#    'symbol': 'STRAT',
#    'website_slug': 'stratis'},
#   {'id': 1347,
#    'name': 'Zonecoin',
#    'symbol': 'ZNE',
#    'website_slug': 'zonecoin'},
#   {'id': 1348,
#    'name': 'President Trump',
#    'symbol': 'PRES',
#    'website_slug': 'president-trump'},
#   {'id': 1351, 'name': 'Aces', 'symbol': 'ACES', 'website_slug': 'aces'},
#   {'id': 1352,
#    'name': 'President Johnson',
#    'symbol': 'GARY',
#    'website_slug': 'president-johnson'},
#   {'id': 1353, 'name': 'TajCoin', 'symbol': 'TAJ', 'website_slug': 'tajcoin'},
#   {'id': 1355,
#    'name': 'PizzaCoin',
#    'symbol': 'PIZZA',
#    'website_slug': 'pizzacoin'},
#   {'id': 1356,
#    'name': 'TodayCoin',
#    'symbol': 'TODAY',
#    'website_slug': 'todaycoin'},
#   {'id': 1357, 'name': 'PX', 'symbol': 'PX', 'website_slug': 'px'},
#   {'id': 1358,
#    'name': 'E-Dinar Coin',
#    'symbol': 'EDR',
#    'website_slug': 'e-dinar-coin'},
#   {'id': 1359,
#    'name': 'BitTokens',
#    'symbol': 'BXT',
#    'website_slug': 'bittokens'},
#   {'id': 1360,
#    'name': 'TechShares',
#    'symbol': 'THS',
#    'website_slug': 'techshares'},
#   {'id': 1361,
#    'name': 'Artex Coin',
#    'symbol': 'ATX',
#    'website_slug': 'artex-coin'},
#   {'id': 1366,
#    'name': 'AgrolifeCoin',
#    'symbol': 'AGLC',
#    'website_slug': 'agrolifecoin'},
#   {'id': 1367,
#    'name': 'Experience Points',
#    'symbol': 'XP',
#    'website_slug': 'experience-points'},
#   {'id': 1368, 'name': 'Veltor', 'symbol': 'VLT', 'website_slug': 'veltor'},
#   {'id': 1371, 'name': 'B3Coin', 'symbol': 'KB3', 'website_slug': 'b3coin'},
#   {'id': 1374,
#    'name': 'BlockPay',
#    'symbol': 'BLOCKPAY',
#    'website_slug': 'blockpay'},
#   {'id': 1375,
#    'name': 'Golfcoin',
#    'symbol': 'GOLF',
#    'website_slug': 'golfcoin'},
#   {'id': 1376, 'name': 'NEO', 'symbol': 'NEO', 'website_slug': 'neo'},
#   {'id': 1379, 'name': 'Jewels', 'symbol': 'JWL', 'website_slug': 'jewels'},
#   {'id': 1380,
#    'name': 'LoMoCoin',
#    'symbol': 'LMC',
#    'website_slug': 'lomocoin'},
#   {'id': 1381,
#    'name': 'Bitcloud',
#    'symbol': 'BTDX',
#    'website_slug': 'bitcloud'},
#   {'id': 1382,
#    'name': 'NoLimitCoin',
#    'symbol': 'NLC2',
#    'website_slug': 'nolimitcoin'},
#   {'id': 1385,
#    'name': 'SportsCoin',
#    'symbol': 'SPORT',
#    'website_slug': 'sportscoin'},
#   {'id': 1387,
#    'name': 'VeriumReserve',
#    'symbol': 'VRM',
#    'website_slug': 'veriumreserve'},
#   {'id': 1389,
#    'name': 'Zayedcoin',
#    'symbol': 'ZYD',
#    'website_slug': 'zayedcoin'},
#   {'id': 1390,
#    'name': 'Jin Coin',
#    'symbol': 'JIN',
#    'website_slug': 'jin-coin'},
#   {'id': 1391, 'name': 'Tao', 'symbol': 'XTO', 'website_slug': 'tao'},
#   {'id': 1392, 'name': 'Pluton', 'symbol': 'PLU', 'website_slug': 'pluton'},
#   {'id': 1393,
#    'name': 'Tellurion',
#    'symbol': 'TELL',
#    'website_slug': 'tellurion'},
#   {'id': 1394, 'name': 'Shilling', 'symbol': 'SH', 'website_slug': 'shilling'},
#   {'id': 1395,
#    'name': 'Dollarcoin',
#    'symbol': 'DLC',
#    'website_slug': 'dollarcoin'},
#   {'id': 1396,
#    'name': 'MustangCoin',
#    'symbol': 'MST',
#    'website_slug': 'mustangcoin'},
#   {'id': 1397,
#    'name': 'Beatcoin',
#    'symbol': 'XBTS',
#    'website_slug': 'beatcoin'},
#   {'id': 1398,
#    'name': 'PROUD Money',
#    'symbol': 'PROUD',
#    'website_slug': 'proud-money'},
#   {'id': 1399,
#    'name': 'Sequence',
#    'symbol': 'SEQ',
#    'website_slug': 'sequence'},
#   {'id': 1400, 'name': 'Omicron', 'symbol': 'OMC', 'website_slug': 'omicron'},
#   {'id': 1402,
#    'name': 'Lazaruscoin',
#    'symbol': 'LAZ',
#    'website_slug': 'lazaruscoin'},
#   {'id': 1403,
#    'name': 'FirstBlood',
#    'symbol': '1ST',
#    'website_slug': 'firstblood'},
#   {'id': 1405,
#    'name': 'Pepe Cash',
#    'symbol': 'PEPECASH',
#    'website_slug': 'pepe-cash'},
#   {'id': 1408, 'name': 'Iconomi', 'symbol': 'ICN', 'website_slug': 'iconomi'},
#   {'id': 1409,
#    'name': 'SingularDTV',
#    'symbol': 'SNGLS',
#    'website_slug': 'singulardtv'},
#   {'id': 1411,
#    'name': 'CaliphCoin',
#    'symbol': 'CALC',
#    'website_slug': 'caliphcoin'},
#   {'id': 1414, 'name': 'ZCoin', 'symbol': 'XZC', 'website_slug': 'zcoin'},
#   {'id': 1416,
#    'name': 'MobileCash',
#    'symbol': 'MBL',
#    'website_slug': 'mobilecash'},
#   {'id': 1418, 'name': 'Rcoin', 'symbol': 'RCN', 'website_slug': 'rcoin'},
#   {'id': 1420,
#    'name': 'Atomic Coin',
#    'symbol': 'ATOM',
#    'website_slug': 'atomic-coin'},
#   {'id': 1421,
#    'name': 'JobsCoin',
#    'symbol': 'JOBS',
#    'website_slug': 'jobscoin'},
#   {'id': 1423,
#    'name': 'Triggers',
#    'symbol': 'TRIG',
#    'website_slug': 'triggers'},
#   {'id': 1425,
#    'name': 'Sakuracoin',
#    'symbol': 'SKR',
#    'website_slug': 'sakuracoin'},
#   {'id': 1428,
#    'name': 'RoyalCoin',
#    'symbol': 'ROYAL',
#    'website_slug': 'royalcoin'},
#   {'id': 1429,
#    'name': 'Levocoin',
#    'symbol': 'LEVO',
#    'website_slug': 'levocoin'},
#   {'id': 1434,
#    'name': 'ArcticCoin',
#    'symbol': 'ARC',
#    'website_slug': 'arcticcoin'},
#   {'id': 1435, 'name': 'Cubits', 'symbol': 'QBT', 'website_slug': 'cubits'},
#   {'id': 1436,
#    'name': 'DynamicCoin',
#    'symbol': 'DMC',
#    'website_slug': 'dynamiccoin'},
#   {'id': 1437, 'name': 'Zcash', 'symbol': 'ZEC', 'website_slug': 'zcash'},
#   {'id': 1438,
#    'name': 'ImpulseCoin',
#    'symbol': 'IMPS',
#    'website_slug': 'impulsecoin'},
#   {'id': 1439,
#    'name': 'AllSafe',
#    'symbol': 'ASAFE2',
#    'website_slug': 'allsafe'},
#   {'id': 1442, 'name': 'BipCoin', 'symbol': 'BIP', 'website_slug': 'bipcoin'},
#   {'id': 1447,
#    'name': 'ZClassic',
#    'symbol': 'ZCL',
#    'website_slug': 'zclassic'},
#   {'id': 1448, 'name': 'Zoin', 'symbol': 'ZOI', 'website_slug': 'zoin'},
#   {'id': 1449, 'name': 'WA Space', 'symbol': 'WA', 'website_slug': 'wa-space'},
#   {'id': 1452, 'name': 'netBit', 'symbol': 'NBIT', 'website_slug': 'netbit'},
#   {'id': 1454, 'name': 'Lykke', 'symbol': 'LKK', 'website_slug': 'lykke'},
#   {'id': 1455,
#    'name': 'Golem',
#    'symbol': 'GNT',
#    'website_slug': 'golem-network-tokens'},
#   {'id': 1456,
#    'name': 'ZetaMicron',
#    'symbol': 'ZMC',
#    'website_slug': 'zetamicron'},
#   {'id': 1457,
#    'name': 'Bitcurrency',
#    'symbol': 'BTCR',
#    'website_slug': 'bitcurrency'},
#   {'id': 1459,
#    'name': 'Regacoin',
#    'symbol': 'REGA',
#    'website_slug': 'regacoin'},
#   {'id': 1463,
#    'name': 'LuckChain',
#    'symbol': 'BASH',
#    'website_slug': 'luckchain'},
#   {'id': 1464,
#    'name': 'Internet of People',
#    'symbol': 'IOP',
#    'website_slug': 'internet-of-people'},
#   {'id': 1465, 'name': 'Veros', 'symbol': 'VRS', 'website_slug': 'veros'},
#   {'id': 1466, 'name': 'Hush', 'symbol': 'HUSH', 'website_slug': 'hush'},
#   {'id': 1468, 'name': 'Kurrent', 'symbol': 'KURT', 'website_slug': 'kurrent'},
#   {'id': 1469, 'name': 'Creatio', 'symbol': 'XCRE', 'website_slug': 'creatio'},
#   {'id': 1472, 'name': 'Rawcoin', 'symbol': 'XRC', 'website_slug': 'rawcoin2'},
#   {'id': 1473,
#    'name': 'Pascal Coin',
#    'symbol': 'PASC',
#    'website_slug': 'pascal-coin'},
#   {'id': 1474,
#    'name': 'Eternity',
#    'symbol': 'ENT',
#    'website_slug': 'eternity'},
#   {'id': 1475, 'name': 'Incent', 'symbol': 'INCNT', 'website_slug': 'incent'},
#   {'id': 1478, 'name': 'DECENT', 'symbol': 'DCT', 'website_slug': 'decent'},
#   {'id': 1479,
#    'name': 'NodeCoin',
#    'symbol': 'NODC',
#    'website_slug': 'nodecoin'},
#   {'id': 1480, 'name': 'Golos', 'symbol': 'GOLOS', 'website_slug': 'golos'},
# ...
#    'name': 'Primalbase Token',
#    'symbol': 'PBT',
#    'website_slug': 'primalbase'},
#   {'id': 1842,
#    'name': 'CampusCoin',
#    'symbol': 'CMPCO',
#    'website_slug': 'campuscoin'},
#   {'id': 1843,
#    'name': 'EmberCoin',
#    'symbol': 'EMB',
#    'website_slug': 'embercoin'},
#   {'id': 1845,
#    'name': 'iXledger',
#    'symbol': 'IXT',
#    'website_slug': 'ixledger'},
#   {'id': 1846,
#    'name': 'GeyserCoin',
#    'symbol': 'GSR',
#    'website_slug': 'geysercoin'},
#   {'id': 1847,
#    'name': 'Mothership',
#    'symbol': 'MSP',
#    'website_slug': 'mothership'},
#   {'id': 1848,
#    'name': 'Aseancoin',
#    'symbol': 'ASN',
#    'website_slug': 'aseancoin'},
#   {'id': 1849, 'name': 'Birds', 'symbol': 'BIRDS', 'website_slug': 'birds'},
#   {'id': 1850, 'name': 'Cream', 'symbol': 'CRM', 'website_slug': 'cream'},
#   {'id': 1851, 'name': 'ERA', 'symbol': 'ERA', 'website_slug': 'blakestar'},
#   {'id': 1852, 'name': 'KekCoin', 'symbol': 'KEK', 'website_slug': 'kekcoin'},
#   {'id': 1853, 'name': 'OAX', 'symbol': 'OAX', 'website_slug': 'oax'},
#   {'id': 1856,
#    'name': 'district0x',
#    'symbol': 'DNT',
#    'website_slug': 'district0x'},
#   {'id': 1857,
#    'name': 'FundYourselfNow',
#    'symbol': 'FYN',
#    'website_slug': 'fundyourselfnow'},
#   {'id': 1861, 'name': 'Stox', 'symbol': 'STX', 'website_slug': 'stox'},
#   {'id': 1863, 'name': 'Minex', 'symbol': 'MINEX', 'website_slug': 'minex'},
#   {'id': 1864, 'name': 'Blox', 'symbol': 'CDT', 'website_slug': 'blox'},
#   {'id': 1865, 'name': 'Wink', 'symbol': 'WINK', 'website_slug': 'wink'},
#   {'id': 1866, 'name': 'Bytom', 'symbol': 'BTM', 'website_slug': 'bytom'},
#   {'id': 1867, 'name': 'Centra', 'symbol': 'CTR', 'website_slug': 'centra'},
#   {'id': 1869,
#    'name': 'Mao Zedong',
#    'symbol': 'MAO',
#    'website_slug': 'mao-zedong'},
#   {'id': 1871,
#    'name': 'First Bitcoin Capital',
#    'symbol': 'BITCF',
#    'website_slug': 'first-bitcoin-capital'},
#   {'id': 1872,
#    'name': 'NEVERDIE',
#    'symbol': 'NDC',
#    'website_slug': 'neverdie'},
#   {'id': 1873,
#    'name': 'Blocktix',
#    'symbol': 'TIX',
#    'website_slug': 'blocktix'},
#   {'id': 1876,
#    'name': 'Dentacoin',
#    'symbol': 'DCN',
#    'website_slug': 'dentacoin'},
#   {'id': 1877, 'name': 'Rupaya', 'symbol': 'RUPX', 'website_slug': 'rupaya'},
#   {'id': 1878,
#    'name': 'Shadow Token',
#    'symbol': 'SHDW',
#    'website_slug': 'shadow-token'},
#   {'id': 1881,
#    'name': 'DeepOnion',
#    'symbol': 'ONION',
#    'website_slug': 'deeponion'},
#   {'id': 1882,
#    'name': 'BlockCAT',
#    'symbol': 'CAT',
#    'website_slug': 'blockcat'},
#   {'id': 1883,
#    'name': 'AdShares',
#    'symbol': 'ADST',
#    'website_slug': 'adshares'},
#   {'id': 1884,
#    'name': 'DigitalDevelopersFund',
#    'symbol': 'DDF',
#    'website_slug': 'digital-developers-fund'},
#   {'id': 1885,
#    'name': 'BitAsean',
#    'symbol': 'BAS',
#    'website_slug': 'bitasean'},
#   {'id': 1886, 'name': 'Dent', 'symbol': 'DENT', 'website_slug': 'dent'},
#   {'id': 1887,
#    'name': 'Monster Byte',
#    'symbol': 'MBI',
#    'website_slug': 'monster-byte'},
#   {'id': 1888,
#    'name': 'InvestFeed',
#    'symbol': 'IFT',
#    'website_slug': 'investfeed'},
#   {'id': 1889,
#    'name': 'CoinonatX',
#    'symbol': 'XCXT',
#    'website_slug': 'coinonatx'},
#   {'id': 1890,
#    'name': 'Etheriya',
#    'symbol': 'RIYA',
#    'website_slug': 'etheriya'},
#   {'id': 1894,
#    'name': 'The ChampCoin',
#    'symbol': 'TCC',
#    'website_slug': 'the-champcoin'},
#   {'id': 1896, 'name': '0x', 'symbol': 'ZRX', 'website_slug': '0x'},
#   {'id': 1897, 'name': 'Bolenum', 'symbol': 'BLN', 'website_slug': 'bolenum'},
#   {'id': 1898, 'name': 'Smoke', 'symbol': 'SMOKE', 'website_slug': 'smoke'},
#   {'id': 1899, 'name': 'YOYOW', 'symbol': 'YOYOW', 'website_slug': 'yoyow'},
#   {'id': 1900,
#    'name': 'Growers International',
#    'symbol': 'GRWI',
#    'website_slug': 'growers-international'},
#   {'id': 1902,
#    'name': 'MyBit Token',
#    'symbol': 'MYB',
#    'website_slug': 'mybit-token'},
#   {'id': 1903, 'name': 'Hshare', 'symbol': 'HSR', 'website_slug': 'hshare'},
#   {'id': 1904, 'name': 'VeChain', 'symbol': 'VEN', 'website_slug': 'vechain'},
#   {'id': 1905,
#    'name': 'TrueFlip',
#    'symbol': 'TFL',
#    'website_slug': 'trueflip'},
#   {'id': 1907,
#    'name': 'XTD Coin',
#    'symbol': 'XTD',
#    'website_slug': 'xtd-coin'},
#   {'id': 1908,
#    'name': 'Nebulas',
#    'symbol': 'NAS',
#    'website_slug': 'nebulas-token'},
#   {'id': 1910, 'name': 'ATMCoin', 'symbol': 'ATMC', 'website_slug': 'atmcoin'},
#   {'id': 1912,
#    'name': 'Dalecoin',
#    'symbol': 'DALC',
#    'website_slug': 'dalecoin'},
#   {'id': 1913, 'name': 'Protean', 'symbol': 'PRN', 'website_slug': 'protean'},
#   {'id': 1914, 'name': 'OX Fina', 'symbol': 'OX', 'website_slug': 'ox-fina'},
#   {'id': 1915, 'name': 'AdCoin', 'symbol': 'ACC', 'website_slug': 'adcoin'},
#   {'id': 1916,
#    'name': 'BiblePay',
#    'symbol': 'BBP',
#    'website_slug': 'biblepay'},
#   {'id': 1917, 'name': 'bitqy', 'symbol': 'BQ', 'website_slug': 'bitqy'},
#   {'id': 1918, 'name': 'Achain', 'symbol': 'ACT', 'website_slug': 'achain'},
#   {'id': 1920,
#    'name': 'NamoCoin',
#    'symbol': 'NAMO',
#    'website_slug': 'namocoin'},
#   {'id': 1921,
#    'name': 'SIGMAcoin',
#    'symbol': 'SIGMA',
#    'website_slug': 'sigmacoin'},
#   {'id': 1922,
#    'name': 'Monoeci',
#    'symbol': 'XMCC',
#    'website_slug': 'monacocoin'},
#   {'id': 1923, 'name': 'Tierion', 'symbol': 'TNT', 'website_slug': 'tierion'},
#   {'id': 1925,
#    'name': 'Waltonchain',
#    'symbol': 'WTC',
#    'website_slug': 'waltonchain'},
#   {'id': 1926, 'name': 'BROTHER', 'symbol': 'BRAT', 'website_slug': 'brat'},
#   {'id': 1927, 'name': 'Ulatech', 'symbol': 'ULA', 'website_slug': 'ulatech'},
#   {'id': 1930, 'name': 'Primas', 'symbol': 'PST', 'website_slug': 'primas'},
#   {'id': 1931, 'name': 'Opus', 'symbol': 'OPT', 'website_slug': 'opus'},
#   {'id': 1933, 'name': 'Suretly', 'symbol': 'SUR', 'website_slug': 'suretly'},
#   {'id': 1934,
#    'name': 'Loopring',
#    'symbol': 'LRC',
#    'website_slug': 'loopring'},
#   {'id': 1935,
#    'name': 'LiteCoin Ultra',
#    'symbol': 'LTCU',
#    'website_slug': 'litecoin-ultra'},
#   {'id': 1937, 'name': 'Po.et', 'symbol': 'POE', 'website_slug': 'poet'},
#   {'id': 1938, 'name': 'Fujinto', 'symbol': 'NTO', 'website_slug': 'fujinto'},
#   {'id': 1942,
#    'name': 'StarCredits',
#    'symbol': 'STRC',
#    'website_slug': 'starcredits'},
#   {'id': 1943,
#    'name': 'Kronecoin',
#    'symbol': 'KRONE',
#    'website_slug': 'kronecoin'},
#   {'id': 1945, 'name': 'Cyder', 'symbol': 'CYDER', 'website_slug': 'cyder'},
#   {'id': 1946,
#    'name': 'Masternodecoin',
#    'symbol': 'MTNC',
#    'website_slug': 'masternodecoin'},
#   {'id': 1947, 'name': 'Monetha', 'symbol': 'MTH', 'website_slug': 'monetha'},
#   {'id': 1948, 'name': 'Aventus', 'symbol': 'AVT', 'website_slug': 'aventus'},
#   {'id': 1949,
#    'name': 'Agrello',
#    'symbol': 'DLT',
#    'website_slug': 'agrello-delta'},
#   {'id': 1950,
#    'name': 'Hive Project',
#    'symbol': 'HVN',
#    'website_slug': 'hive-project'},
#   {'id': 1951, 'name': 'Vsync', 'symbol': 'VSX', 'website_slug': 'vsync-vsx'},
#   {'id': 1952,
#    'name': 'Magnetcoin',
#    'symbol': 'MAGN',
#    'website_slug': 'magnetcoin'},
#   {'id': 1954,
#    'name': 'Moeda Loyalty Points',
#    'symbol': 'MDA',
#    'website_slug': 'moeda-loyalty-points'},
#   {'id': 1955, 'name': 'Neblio', 'symbol': 'NEBL', 'website_slug': 'neblio'},
#   {'id': 1956, 'name': 'VIVO', 'symbol': 'VIVO', 'website_slug': 'vivo'},
#   {'id': 1958, 'name': 'TRON', 'symbol': 'TRX', 'website_slug': 'tron'},
#   {'id': 1959,
#    'name': 'Oceanlab',
#    'symbol': 'OCL',
#    'website_slug': 'oceanlab'},
#   {'id': 1961, 'name': 'imbrex', 'symbol': 'REX', 'website_slug': 'imbrex'},
#   {'id': 1962,
#    'name': 'BuzzCoin',
#    'symbol': 'BUZZ',
#    'website_slug': 'buzzcoin'},
#   {'id': 1963, 'name': 'Credo', 'symbol': 'CREDO', 'website_slug': 'credo'},
#   {'id': 1964, 'name': 'DROXNE', 'symbol': 'DRXNE', 'website_slug': 'droxne'},
#   {'id': 1965, 'name': 'Bowhead', 'symbol': 'AHT', 'website_slug': 'bowhead'},
#   {'id': 1966,
#    'name': 'Decentraland',
#    'symbol': 'MANA',
#    'website_slug': 'decentraland'},
#   {'id': 1967,
#    'name': 'Indorse Token',
#    'symbol': 'IND',
#    'website_slug': 'indorse-token'},
#   {'id': 1968, 'name': 'XPA', 'symbol': 'XPA', 'website_slug': 'xpa'},
#   {'id': 1969, 'name': 'Sociall', 'symbol': 'SCL', 'website_slug': 'sociall'},
#   {'id': 1970, 'name': 'ATBCoin', 'symbol': 'ATB', 'website_slug': 'atbcoin'},
#   {'id': 1971, 'name': 'iQuant', 'symbol': 'IQT', 'website_slug': 'iquant'},
#   {'id': 1973,
#    'name': 'Ethereum Dark',
#    'symbol': 'ETHD',
#    'website_slug': 'ethereum-dark'},
#   {'id': 1974, 'name': 'Propy', 'symbol': 'PRO', 'website_slug': 'propy'},
#   {'id': 1975,
#    'name': 'ChainLink',
#    'symbol': 'LINK',
#    'website_slug': 'chainlink'},
#   {'id': 1976,
#    'name': 'Blackmoon',
#    'symbol': 'BMC',
#    'website_slug': 'blackmoon'},
#   {'id': 1979, 'name': 'Wi Coin', 'symbol': 'WIC', 'website_slug': 'wi-coin'},
#   {'id': 1980, 'name': 'Elixir', 'symbol': 'ELIX', 'website_slug': 'elixir'},
#   {'id': 1981,
#    'name': 'Billionaire Token',
#    'symbol': 'XBL',
#    'website_slug': 'billionaire-token'},
#   {'id': 1982,
#    'name': 'Kyber Network',
#    'symbol': 'KNC',
#    'website_slug': 'kyber-network'},
#   {'id': 1983, 'name': 'VIBE', 'symbol': 'VIBE', 'website_slug': 'vibe'},
#   {'id': 1984,
#    'name': 'Substratum',
#    'symbol': 'SUB',
#    'website_slug': 'substratum'},
#   {'id': 1985,
#    'name': 'Chronologic',
#    'symbol': 'DAY',
#    'website_slug': 'chronologic'},
#   {'id': 1986, 'name': 'CHIPS', 'symbol': 'CHIPS', 'website_slug': 'chips'},
#   {'id': 1987,
#    'name': 'CryptoInsight',
#    'symbol': 'TKR',
#    'website_slug': 'trackr'},
#   {'id': 1988, 'name': 'Lampix', 'symbol': 'PIX', 'website_slug': 'lampix'},
#   {'id': 1989, 'name': 'COSS', 'symbol': 'COSS', 'website_slug': 'coss'},
#   {'id': 1990, 'name': 'BitDice', 'symbol': 'CSNO', 'website_slug': 'bitdice'},
#   {'id': 1991, 'name': 'Rivetz', 'symbol': 'RVT', 'website_slug': 'rivetz'},
#   {'id': 1993, 'name': 'Kin', 'symbol': 'KIN', 'website_slug': 'kin'},
#   {'id': 1994,
#    'name': 'Interzone',
#    'symbol': 'ITZ',
#    'website_slug': 'interzone'},
#   {'id': 1995,
#    'name': 'Target Coin',
#    'symbol': 'TGT',
#    'website_slug': 'target-coin'},
#   {'id': 1996, 'name': 'SALT', 'symbol': 'SALT', 'website_slug': 'salt'},
#   {'id': 1997,
#    'name': 'India Coin',
#    'symbol': 'INDIA',
#    'website_slug': 'india-coin'},
#   {'id': 1998,
#    'name': 'Ormeus Coin',
#    'symbol': 'ORME',
#    'website_slug': 'ormeus-coin'},
#   {'id': 1999, 'name': 'Kolion', 'symbol': 'KLN', 'website_slug': 'kolion'},
#   {'id': 2000,
#    'name': 'Musiconomi',
#    'symbol': 'MCI',
#    'website_slug': 'musiconomi'},
#   {'id': 2001,
#    'name': 'ColossusXT',
#    'symbol': 'COLX',
#    'website_slug': 'colossusxt'},
#   {'id': 2002,
#    'name': 'TrezarCoin',
#    'symbol': 'TZC',
#    'website_slug': 'trezarcoin'},
#   {'id': 2004,
#    'name': 'HODL Bucks',
#    'symbol': 'HDLB',
#    'website_slug': 'hodl-bucks'},
#   {'id': 2005,
#    'name': 'Obsidian',
#    'symbol': 'ODN',
#    'website_slug': 'obsidian'},
#   {'id': 2006,
#    'name': 'Cobinhood',
#    'symbol': 'COB',
#    'website_slug': 'cobinhood'},
#   {'id': 2007,
#    'name': 'Regalcoin',
#    'symbol': 'REC',
#    'website_slug': 'regalcoin'},
#   {'id': 2008, 'name': 'MSD', 'symbol': 'MSD', 'website_slug': 'msd'},
#   {'id': 2009, 'name': 'Bismuth', 'symbol': 'BIS', 'website_slug': 'bismuth'},
#   {'id': 2010, 'name': 'Cardano', 'symbol': 'ADA', 'website_slug': 'cardano'},
#   {'id': 2011,
#    'name': 'Tezos (Pre-Launch)',
#    'symbol': 'XTZ',
#    'website_slug': 'tezos'},
#   {'id': 2012, 'name': 'Voise', 'symbol': 'VOISE', 'website_slug': 'voisecom'},
#   {'id': 2013,
#    'name': 'Infinity Economics',
#    'symbol': 'XIN',
#    'website_slug': 'infinity-economics'},
#   {'id': 2015,
#    'name': 'ATMChain',
#    'symbol': 'ATM',
#    'website_slug': 'attention-token-of-media'},
#   {'id': 2016, 'name': 'Macro', 'symbol': 'MCR', 'website_slug': 'macro1'},
#   {'id': 2017,
#    'name': 'KickCoin',
#    'symbol': 'KICK',
#    'website_slug': 'kickico'},
#   {'id': 2018,
#    'name': 'EncryptoTel [ETH]',
#    'symbol': 'ETT',
#    'website_slug': 'encryptotel-eth'},
#   {'id': 2019,
#    'name': 'Viberate',
#    'symbol': 'VIB',
#    'website_slug': 'viberate'},
#   {'id': 2021, 'name': 'RChain', 'symbol': 'RHOC', 'website_slug': 'rchain'},
#   {'id': 2022,
#    'name': 'Internxt',
#    'symbol': 'INXT',
#    'website_slug': 'internxt'},
#   {'id': 2024,
#    'name': 'WhaleCoin',
#    'symbol': 'WHL',
#    'website_slug': 'whalecoin'},
#   {'id': 2025, 'name': 'FLiK', 'symbol': 'FLIK', 'website_slug': 'flik'},
#   {'id': 2026, 'name': 'EthBet', 'symbol': 'EBET', 'website_slug': 'ethbet'},
#   {'id': 2027,
#    'name': 'Cryptonex',
#    'symbol': 'CNX',
#    'website_slug': 'cryptonex'},
#   {'id': 2029,
#    'name': 'Wild Crypto',
#    'symbol': 'WILD',
#    'website_slug': 'wild-crypto'},
#   {'id': 2030, 'name': 'REAL', 'symbol': 'REAL', 'website_slug': 'real'},
#   {'id': 2031,
#    'name': 'Hubii Network',
#    'symbol': 'HBT',
#    'website_slug': 'hubii-network'},
#   {'id': 2032,
#    'name': 'Crystal Clear ',
#    'symbol': 'CCT',
#    'website_slug': 'crystal-clear'},
#   {'id': 2033,
#    'name': 'BridgeCoin',
#    'symbol': 'BCO',
#    'website_slug': 'bridgecoin'},
#   {'id': 2034, 'name': 'Everex', 'symbol': 'EVX', 'website_slug': 'everex'},
#   {'id': 2036, 'name': 'PayPie', 'symbol': 'PPP', 'website_slug': 'paypie'},
#   {'id': 2037,
#    'name': 'AirToken',
#    'symbol': 'AIR',
#    'website_slug': 'airtoken'},
#   {'id': 2038,
#    'name': 'PoSToken',
#    'symbol': 'POS',
#    'website_slug': 'postoken'},
#   {'id': 2039,
#    'name': 'Senderon',
#    'symbol': 'SDRN',
#    'website_slug': 'senderon'},
#   {'id': 2040, 'name': 'ALIS', 'symbol': 'ALIS', 'website_slug': 'alis'},
#   {'id': 2041,
#    'name': 'BitcoinZ',
#    'symbol': 'BTCZ',
#    'website_slug': 'bitcoinz'},
#   {'id': 2042,
#    'name': 'HelloGold',
#    'symbol': 'HGT',
#    'website_slug': 'hellogold'},
#   {'id': 2043,
#    'name': 'Cindicator',
#    'symbol': 'CND',
#    'website_slug': 'cindicator'},
#   {'id': 2044,
#    'name': 'Enigma',
#    'symbol': 'ENG',
#    'website_slug': 'enigma-project'},
#   {'id': 2045,
#    'name': 'Coimatic 3.0',
#    'symbol': 'CTIC3',
#    'website_slug': 'coimatic-3'},
#   {'id': 2046,
#    'name': 'Bastonet',
#    'symbol': 'BSN',
#    'website_slug': 'bastonet'},
#   {'id': 2047,
#    'name': 'Zeusshield',
#    'symbol': 'ZSC',
#    'website_slug': 'zeusshield'},
#   {'id': 2048,
#    'name': 'Ethereum Cash',
#    'symbol': 'ECASH',
#    'website_slug': 'ethereumcash'},
#   {'id': 2049, 'name': 'CORION', 'symbol': 'COR', 'website_slug': 'corion'},
#   {'id': 2050,
#    'name': 'Swisscoin',
#    'symbol': 'SIC',
#    'website_slug': 'swisscoin'},
#   {'id': 2051,
#    'name': 'Authorship',
#    'symbol': 'ATS',
#    'website_slug': 'authorship'},
#   {'id': 2053,
#    'name': 'Royal Kingdom Coin',
#    'symbol': 'RKC',
#    'website_slug': 'royal-kingdom-coin'},
#   {'id': 2054,
#    'name': 'Akuya Coin',
#    'symbol': 'AKY',
#    'website_slug': 'akuya-coin'},
#   {'id': 2055,
#    'name': 'ExchangeN',
#    'symbol': 'EXN',
#    'website_slug': 'exchangen'},
#   {'id': 2056,
#    'name': 'PiplCoin',
#    'symbol': 'PIPL',
#    'website_slug': 'piplcoin'},
#   {'id': 2057, 'name': 'Eidoo', 'symbol': 'EDO', 'website_slug': 'eidoo'},
#   {'id': 2058, 'name': 'AirSwap', 'symbol': 'AST', 'website_slug': 'airswap'},
#   {'id': 2060, 'name': 'Change', 'symbol': 'CAG', 'website_slug': 'change'},
#   {'id': 2061,
#    'name': 'BlockMason Credit Protocol',
#    'symbol': 'BCPT',
#    'website_slug': 'blockmason'},
#   {'id': 2062, 'name': 'Aion', 'symbol': 'AION', 'website_slug': 'aion'},
#   {'id': 2063, 'name': 'Tracto', 'symbol': 'TRCT', 'website_slug': 'tracto'},
#   {'id': 2064,
#    'name': 'Maecenas',
#    'symbol': 'ART',
#    'website_slug': 'maecenas'},
#   {'id': 2065, 'name': 'XGOX', 'symbol': 'XGOX', 'website_slug': 'xgox'},
#   {'id': 2066, 'name': 'Everus', 'symbol': 'EVR', 'website_slug': 'everus'},
#   {'id': 2067,
#    'name': 'Dutch Coin',
#    'symbol': 'DUTCH',
#    'website_slug': 'dutch-coin'},
#   {'id': 2069,
#    'name': 'Open Trading Network',
#    'symbol': 'OTN',
#    'website_slug': 'open-trading-network'},
#   ...],
#  'metadata': {'error': None,
#   'num_cryptocurrencies': 1604,
#   'timestamp': 1526043545}}

# %% [markdown]
# #### `ticker(currency=None, limit=0, start=0, convert="USD")`
# If `currency == None`, you will obtain data for all currencies in coinmarketcap:

# %%
cmc.ticker()
# Out:
# [{'24h_volume_usd': 7902030000.0,
#   'available_supply': 17003537.0,
#   'id': 'bitcoin',
#   'last_updated': 1524932675,
#   'market_cap_usd': 158980350384,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin',
#   'percent_change_1h': 0.67,
#   'percent_change_24h': 0.79,
#   'percent_change_7d': 6.63,
#   'price_btc': 1.0,
#   'price_usd': 9349.84,
#   'rank': 1,
#   'symbol': 'BTC',
#   'total_supply': 17003537.0},
#  {'24h_volume_usd': 2627390000.0,
#   'available_supply': 99103312.0,
#   'id': 'ethereum',
#   'last_updated': 1524932661,
#   'market_cap_usd': 67901526125.0,
#   'max_supply': None,
#   'name': 'Ethereum',
#   'percent_change_1h': 0.73,
#   'percent_change_24h': 1.08,
#   'percent_change_7d': 14.23,
#   'price_btc': 0.073316,
#   'price_usd': 685.159,
#   'rank': 2,
#   'symbol': 'ETH',
#   'total_supply': 99103312.0},
#  {'24h_volume_usd': 821343000.0,
#   'available_supply': 39146203398.0,
#   'id': 'ripple',
#   'last_updated': 1524932642,
#   'market_cap_usd': 34113919805.0,
#   'max_supply': 100000000000,
#   'name': 'Ripple',
#   'percent_change_1h': 0.91,
#   'percent_change_24h': 2.68,
#   'percent_change_7d': 1.98,
#   'price_btc': 9.325e-05,
#   'price_usd': 0.871449,
#   'rank': 3,
#   'symbol': 'XRP',
#   'total_supply': 99992334929.0},
#  {'24h_volume_usd': 867119000.0,
#   'available_supply': 17098700.0,
#   'id': 'bitcoin-cash',
#   'last_updated': 1524932655,
#   'market_cap_usd': 23917832547.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Cash',
#   'percent_change_1h': 0.41,
#   'percent_change_24h': -0.49,
#   'percent_change_7d': 26.08,
#   'price_btc': 0.149681,
#   'price_usd': 1398.81,
#   'rank': 4,
#   'symbol': 'BCH',
#   'total_supply': 17098700.0},
#  {'24h_volume_usd': 3165720000.0,
#   'available_supply': 822649000.0,
#   'id': 'eos',
#   'last_updated': 1524932654,
#   'market_cap_usd': 15693263652.0,
#   'max_supply': 1000000000.0,
#   'name': 'EOS',
#   'percent_change_1h': 1.73,
#   'percent_change_24h': 10.16,
#   'percent_change_7d': 76.26,
#   'price_btc': 0.00204129,
#   'price_usd': 19.0765,
#   'rank': 5,
#   'symbol': 'EOS',
#   'total_supply': 900000000.0},
#  {'24h_volume_usd': 469155000.0,
#   'available_supply': 25927070538.0,
#   'id': 'cardano',
#   'last_updated': 1524932658,
#   'market_cap_usd': 9368358033.0,
#   'max_supply': 45000000000.0,
#   'name': 'Cardano',
#   'percent_change_1h': 6.59,
#   'percent_change_24h': 19.47,
#   'percent_change_7d': 27.39,
#   'price_btc': 3.866e-05,
#   'price_usd': 0.361335,
#   'rank': 6,
#   'symbol': 'ADA',
#   'total_supply': 31112483745.0},
#  {'24h_volume_usd': 360977000.0,
#   'available_supply': 56289263.0,
#   'id': 'litecoin',
#   'last_updated': 1524932643,
#   'market_cap_usd': 8539081144.0,
#   'max_supply': 84000000.0,
#   'name': 'Litecoin',
#   'percent_change_1h': 0.72,
#   'percent_change_24h': 0.05,
#   'percent_change_7d': 3.35,
#   'price_btc': 0.0162328,
#   'price_usd': 151.7,
#   'rank': 7,
#   'symbol': 'LTC',
#   'total_supply': 56289263.0},
#  {'24h_volume_usd': 98224500.0,
#   'available_supply': 18571153618.0,
#   'id': 'stellar',
#   'last_updated': 1524932645,
#   'market_cap_usd': 7840499632.0,
#   'max_supply': None,
#   'name': 'Stellar',
#   'percent_change_1h': 0.83,
#   'percent_change_24h': 2.55,
#   'percent_change_7d': 14.87,
#   'price_btc': 4.518e-05,
#   'price_usd': 0.422187,
#   'rank': 8,
#   'symbol': 'XLM',
#   'total_supply': 103887050716},
#  {'24h_volume_usd': 77166800.0,
#   'available_supply': 2779530283.0,
#   'id': 'iota',
#   'last_updated': 1524932653,
#   'market_cap_usd': 5720857024.0,
#   'max_supply': 2779530283.0,
#   'name': 'IOTA',
#   'percent_change_1h': 0.89,
#   'percent_change_24h': 2.19,
#   'percent_change_7d': 9.66,
#   'price_btc': 0.00022024,
#   'price_usd': 2.05821,
#   'rank': 9,
#   'symbol': 'MIOTA',
#   'total_supply': 2779530283.0},
#  {'24h_volume_usd': 792552000.0,
#   'available_supply': 65748111645.0,
#   'id': 'tron',
#   'last_updated': 1524932659,
#   'market_cap_usd': 5437506904.0,
#   'max_supply': None,
#   'name': 'TRON',
#   'percent_change_1h': 0.6,
#   'percent_change_24h': 6.44,
#   'percent_change_7d': 58.53,
#   'price_btc': 8.85e-06,
#   'price_usd': 0.0827021,
#   'rank': 10,
#   'symbol': 'TRX',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 137783000.0,
#   'available_supply': 65000000.0,
#   'id': 'neo',
#   'last_updated': 1524932650,
#   'market_cap_usd': 5010518500.0,
#   'max_supply': 100000000.0,
#   'name': 'NEO',
#   'percent_change_1h': 1.05,
#   'percent_change_24h': 1.38,
#   'percent_change_7d': 4.22,
#   'price_btc': 0.00824853,
#   'price_usd': 77.0849,
#   'rank': 11,
#   'symbol': 'NEO',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 81971500.0,
#   'available_supply': 15976858.0,
#   'id': 'monero',
#   'last_updated': 1524932644,
#   'market_cap_usd': 4101754635.0,
#   'max_supply': None,
#   'name': 'Monero',
#   'percent_change_1h': 0.41,
#   'percent_change_24h': -1.6,
#   'percent_change_7d': 2.4,
#   'price_btc': 0.0274717,
#   'price_usd': 256.731,
#   'rank': 12,
#   'symbol': 'XMR',
#   'total_supply': 15976858.0},
#  {'24h_volume_usd': 119268000.0,
#   'available_supply': 8035277.0,
#   'id': 'dash',
#   'last_updated': 1524932643,
#   'market_cap_usd': 3962267336.0,
#   'max_supply': 18900000.0,
#   'name': 'Dash',
#   'percent_change_1h': 0.41,
#   'percent_change_24h': 0.66,
#   'percent_change_7d': 12.7,
#   'price_btc': 0.0527655,
#   'price_usd': 493.109,
#   'rank': 13,
#   'symbol': 'DASH',
#   'total_supply': 8035277.0},
#  {'24h_volume_usd': 28508300.0,
#   'available_supply': 8999999999.0,
#   'id': 'nem',
#   'last_updated': 1524932645,
#   'market_cap_usd': 3664854000.0,
#   'max_supply': None,
#   'name': 'NEM',
#   'percent_change_1h': 1.17,
#   'percent_change_24h': 1.53,
#   'percent_change_7d': 7.71,
#   'price_btc': 4.357e-05,
#   'price_usd': 0.407206,
#   'rank': 14,
#   'symbol': 'XEM',
#   'total_supply': 8999999999.0},
#  {'24h_volume_usd': 4355900000.0,
#   'available_supply': 2417140814.0,
#   'id': 'tether',
#   'last_updated': 1524932648,
#   'market_cap_usd': 2409127992.0,
#   'max_supply': None,
#   'name': 'Tether',
#   'percent_change_1h': -0.38,
#   'percent_change_24h': -0.35,
#   'percent_change_7d': -0.37,
#   'price_btc': 0.00010665,
#   'price_usd': 0.996685,
#   'rank': 15,
#   'symbol': 'USDT',
#   'total_supply': 2580109970.0},
#  {'24h_volume_usd': 298144000.0,
#   'available_supply': 101420335.0,
#   'id': 'ethereum-classic',
#   'last_updated': 1524932649,
#   'market_cap_usd': 2215902473.0,
#   'max_supply': None,
#   'name': 'Ethereum Classic',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': 2.29,
#   'percent_change_7d': 18.6,
#   'price_btc': 0.00233793,
#   'price_usd': 21.8487,
#   'rank': 16,
#   'symbol': 'ETC',
#   'total_supply': 101420335.0},
#  {'24h_volume_usd': 81026000.0,
#   'available_supply': 525779138.0,
#   'id': 'vechain',
#   'last_updated': 1524932658,
#   'market_cap_usd': 2134705361.0,
#   'max_supply': None,
#   'name': 'VeChain',
#   'percent_change_1h': 0.55,
#   'percent_change_24h': 2.24,
#   'percent_change_7d': 7.57,
#   'price_btc': 0.00043445,
#   'price_usd': 4.06008,
#   'rank': 17,
#   'symbol': 'VEN',
#   'total_supply': 873378637.0},
#  {'24h_volume_usd': 234050000.0,
#   'available_supply': 88556208.0,
#   'id': 'qtum',
#   'last_updated': 1524932653,
#   'market_cap_usd': 1911246648.0,
#   'max_supply': None,
#   'name': 'Qtum',
#   'percent_change_1h': 2.87,
#   'percent_change_24h': 3.9,
#   'percent_change_7d': 14.22,
#   'price_btc': 0.00230943,
#   'price_usd': 21.5823,
#   'rank': 18,
#   'symbol': 'QTUM',
#   'total_supply': 100556208.0},
#  {'24h_volume_usd': 85185100.0,
#   'available_supply': 102042552.0,
#   'id': 'omisego',
#   'last_updated': 1524932655,
#   'market_cap_usd': 1850245753.0,
#   'max_supply': None,
#   'name': 'OmiseGO',
#   'percent_change_1h': 0.71,
#   'percent_change_24h': -0.74,
#   'percent_change_7d': 19.5,
#   'price_btc': 0.00194024,
#   'price_usd': 18.1321,
#   'rank': 19,
#   'symbol': 'OMG',
#   'total_supply': 140245398.0},
#  {'24h_volume_usd': 140784000.0,
#   'available_supply': 387231348.0,
#   'id': 'icon',
#   'last_updated': 1524932660,
#   'market_cap_usd': 1836762200.0,
#   'max_supply': None,
#   'name': 'ICON',
#   'percent_change_1h': 0.5,
#   'percent_change_24h': 4.24,
#   'percent_change_7d': 40.42,
#   'price_btc': 0.00050756,
#   'price_usd': 4.74332,
#   'rank': 20,
#   'symbol': 'ICX',
#   'total_supply': 400228740.0},
#  {'24h_volume_usd': 114094000.0,
#   'available_supply': 114041290.0,
#   'id': 'binance-coin',
#   'last_updated': 1524932656,
#   'market_cap_usd': 1727531675.0,
#   'max_supply': None,
#   'name': 'Binance Coin',
#   'percent_change_1h': 0.82,
#   'percent_change_24h': 3.65,
#   'percent_change_7d': 15.52,
#   'price_btc': 0.00162096,
#   'price_usd': 15.1483,
#   'rank': 21,
#   'symbol': 'BNB',
#   'total_supply': 194972068.0},
#  {'24h_volume_usd': 25817900.0,
#   'available_supply': 16970986.0,
#   'id': 'bitcoin-gold',
#   'last_updated': 1524932661,
#   'market_cap_usd': 1292442417.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Gold',
#   'percent_change_1h': 0.56,
#   'percent_change_24h': 0.58,
#   'percent_change_7d': 18.48,
#   'price_btc': 0.00814913,
#   'price_usd': 76.156,
#   'rank': 22,
#   'symbol': 'BTG',
#   'total_supply': 17070986.0},
#  {'24h_volume_usd': 20609900.0,
#   'available_supply': 105330522.0,
#   'id': 'lisk',
#   'last_updated': 1524932648,
#   'market_cap_usd': 1243289888.0,
#   'max_supply': None,
#   'name': 'Lisk',
#   'percent_change_1h': 0.62,
#   'percent_change_24h': 1.1,
#   'percent_change_7d': 3.01,
#   'price_btc': 0.00126307,
#   'price_usd': 11.8037,
#   'rank': 23,
#   'symbol': 'LSK',
#   'total_supply': 120580916.0},
#  {'24h_volume_usd': 63030600.0,
#   'available_supply': 3800619.0,
#   'id': 'zcash',
#   'last_updated': 1524932650,
#   'market_cap_usd': 1120274183.0,
#   'max_supply': None,
#   'name': 'Zcash',
#   'percent_change_1h': 0.19,
#   'percent_change_24h': -0.13,
#   'percent_change_7d': 11.82,
#   'price_btc': 0.0315411,
#   'price_usd': 294.761,
#   'rank': 24,
#   'symbol': 'ZEC',
#   'total_supply': 3800619.0},
#  {'24h_volume_usd': 109581000.0,
#   'available_supply': 253852506.0,
#   'id': 'steem',
#   'last_updated': 1524932648,
#   'market_cap_usd': 1092002404.0,
#   'max_supply': None,
#   'name': 'Steem',
#   'percent_change_1h': 1.39,
#   'percent_change_24h': 4.49,
#   'percent_change_7d': 42.32,
#   'price_btc': 0.00046031,
#   'price_usd': 4.30172,
#   'rank': 25,
#   'symbol': 'STEEM',
#   'total_supply': 270826600.0},
#  {'24h_volume_usd': 74566800.0,
#   'available_supply': 14931874700.0,
#   'id': 'verge',
#   'last_updated': 1524932645,
#   'market_cap_usd': 1072172811.0,
#   'max_supply': 16555000000.0,
#   'name': 'Verge',
#   'percent_change_1h': 0.19,
#   'percent_change_24h': 1.11,
#   'percent_change_7d': 6.92,
#   'price_btc': 7.68e-06,
#   'price_usd': 0.0718043,
#   'rank': 26,
#   'symbol': 'XVG',
#   'total_supply': 14931874700.0},
#  {'24h_volume_usd': 7175590.0,
#   'available_supply': 183862379570,
#   'id': 'bytecoin-bcn',
#   'last_updated': 1524932644,
#   'market_cap_usd': 1047844572.0,
#   'max_supply': 184470000000,
#   'name': 'Bytecoin',
#   'percent_change_1h': 1.13,
#   'percent_change_24h': 3.21,
#   'percent_change_7d': 22.4,
#   'price_btc': 6.1e-07,
#   'price_usd': 0.00569907,
#   'rank': 27,
#   'symbol': 'BCN',
#   'total_supply': 183862379570},
#  {'24h_volume_usd': 76312900.0,
#   'available_supply': 34084601619.0,
#   'id': 'siacoin',
#   'last_updated': 1524932647,
#   'market_cap_usd': 1014310026.0,
#   'max_supply': None,
#   'name': 'Siacoin',
#   'percent_change_1h': 0.57,
#   'percent_change_24h': -1.85,
#   'percent_change_7d': 58.74,
#   'price_btc': 3.18e-06,
#   'price_usd': 0.0297586,
#   'rank': 28,
#   'symbol': 'SC',
#   'total_supply': 34084601619.0},
#  {'24h_volume_usd': 93998000.0,
#   'available_supply': 233020472.0,
#   'id': 'aeternity',
#   'last_updated': 1524932653,
#   'market_cap_usd': 1010838148.0,
#   'max_supply': None,
#   'name': 'Aeternity',
#   'percent_change_1h': 3.29,
#   'percent_change_24h': 45.24,
#   'percent_change_7d': 123.9,
#   'price_btc': 0.00046419,
#   'price_usd': 4.33798,
#   'rank': 29,
#   'symbol': 'AE',
#   'total_supply': 273685830.0},
#  {'24h_volume_usd': 18275000.0,
#   'available_supply': 133248289.0,
#   'id': 'nano',
#   'last_updated': 1524932652,
#   'market_cap_usd': 985099272.0,
#   'max_supply': 133248290.0,
#   'name': 'Nano',
#   'percent_change_1h': 1.1,
#   'percent_change_24h': 0.4,
#   'percent_change_7d': 4.59,
#   'price_btc': 0.00079109,
#   'price_usd': 7.39296,
#   'rank': 30,
#   'symbol': 'NANO',
#   'total_supply': 133248289.0},
#  {'24h_volume_usd': 130535000.0,
#   'available_supply': 987000000.0,
#   'id': 'bytom',
#   'last_updated': 1524932656,
#   'market_cap_usd': 973781109.0,
#   'max_supply': None,
#   'name': 'Bytom',
#   'percent_change_1h': 0.48,
#   'percent_change_24h': -1.92,
#   'percent_change_7d': 10.22,
#   'price_btc': 0.00010557,
#   'price_usd': 0.986607,
#   'rank': 31,
#   'symbol': 'BTM',
#   'total_supply': 1407000000.0},
#  {'24h_volume_usd': 20089600.0,
#   'available_supply': 153346375.0,
#   'id': 'bitcoin-diamond',
#   'last_updated': 1524932662,
#   'market_cap_usd': 908071229.0,
#   'max_supply': 210000000.0,
#   'name': 'Bitcoin Diamond',
#   'percent_change_1h': 0.36,
#   'percent_change_24h': -3.8,
#   'percent_change_7d': 47.8,
#   'price_btc': 0.00063366,
#   'price_usd': 5.9217,
#   'rank': 32,
#   'symbol': 'BCD',
#   'total_supply': 156346375.0},
#  {'24h_volume_usd': 5149440.0,
#   'available_supply': 37004027.0,
#   'id': 'populous',
#   'last_updated': 1524932654,
#   'market_cap_usd': 896840697.0,
#   'max_supply': 53252246.0,
#   'name': 'Populous',
#   'percent_change_1h': 2.71,
#   'percent_change_24h': 6.74,
#   'percent_change_7d': -11.53,
#   'price_btc': 0.00259342,
#   'price_usd': 24.2363,
#   'rank': 33,
#   'symbol': 'PPT',
#   'total_supply': 53252246.0},
#  {'24h_volume_usd': 20349100.0,
#   'available_supply': 106152493.0,
#   'id': 'wanchain',
#   'last_updated': 1524932667,
#   'market_cap_usd': 893863433.0,
#   'max_supply': None,
#   'name': 'Wanchain',
#   'percent_change_1h': 0.98,
#   'percent_change_24h': 1.55,
#   'percent_change_7d': 35.44,
#   'price_btc': 0.00090105,
#   'price_usd': 8.42056,
#   'rank': 34,
#   'symbol': 'WAN',
#   'total_supply': 210000000.0},
#  {'24h_volume_usd': 141141000.0,
#   'available_supply': 112619658.0,
#   'id': 'ontology',
#   'last_updated': 1524932667,
#   'market_cap_usd': 770697988.0,
#   'max_supply': None,
#   'name': 'Ontology',
#   'percent_change_1h': 8.0,
#   'percent_change_24h': 25.35,
#   'percent_change_7d': 67.44,
#   'price_btc': 0.00073228,
#   'price_usd': 6.84337,
#   'rank': 35,
#   'symbol': 'ONT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 39989400.0,
#   'available_supply': 7284013186.0,
#   'id': 'zilliqa',
#   'last_updated': 1524932665,
#   'market_cap_usd': 757187739.0,
#   'max_supply': None,
#   'name': 'Zilliqa',
#   'percent_change_1h': 0.78,
#   'percent_change_24h': 9.48,
#   'percent_change_7d': 18.38,
#   'price_btc': 1.112e-05,
#   'price_usd': 0.103952,
#   'rank': 36,
#   'symbol': 'ZIL',
#   'total_supply': 12600000000.0},
#  {'24h_volume_usd': 19506500.0,
#   'available_supply': 2619740000.0,
#   'id': 'bitshares',
#   'last_updated': 1524932644,
#   'market_cap_usd': 731551916.0,
#   'max_supply': 3600570502.0,
#   'name': 'BitShares',
#   'percent_change_1h': 1.21,
#   'percent_change_24h': 0.18,
#   'percent_change_7d': 7.6,
#   'price_btc': 2.988e-05,
#   'price_usd': 0.279246,
#   'rank': 37,
#   'symbol': 'BTS',
#   'total_supply': 2619740000.0},
#  {'24h_volume_usd': 2265590.0,
#   'available_supply': 20418516.0,
#   'id': 'bitcoin-private',
#   'last_updated': 1524932667,
#   'market_cap_usd': 665082113.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Private',
#   'percent_change_1h': -2.03,
#   'percent_change_24h': -27.67,
#   'percent_change_7d': -25.96,
#   'price_btc': 0.00348544,
#   'price_usd': 32.5725,
#   'rank': 38,
#   'symbol': 'BTCP',
#   'total_supply': 20418516.0},
#  {'24h_volume_usd': 128507.0,
#   'available_supply': 618228.0,
#   'id': 'maker',
#   'last_updated': 1524932651,
#   'market_cap_usd': 651593523.0,
#   'max_supply': None,
#   'name': 'Maker',
#   'percent_change_1h': 0.62,
#   'percent_change_24h': 1.31,
#   'percent_change_7d': 17.44,
#   'price_btc': 0.112781,
#   'price_usd': 1053.97,
#   'rank': 39,
#   'symbol': 'MKR',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 42830700.0,
#   'available_supply': 114211775050,
#   'id': 'dogecoin',
#   'last_updated': 1524932642,
#   'market_cap_usd': 621927658.0,
#   'max_supply': None,
#   'name': 'Dogecoin',
#   'percent_change_1h': -0.48,
#   'percent_change_24h': -2.78,
#   'percent_change_7d': 1.25,
#   'price_btc': 5.8e-07,
#   'price_usd': 0.00544539,
#   'rank': 40,
#   'symbol': 'DOGE',
#   'total_supply': 114211775050},
#  {'24h_volume_usd': 8933510.0,
#   'available_supply': 98834575.0,
#   'id': 'stratis',
#   'last_updated': 1524932649,
#   'market_cap_usd': 621478727.0,
#   'max_supply': None,
#   'name': 'Stratis',
#   'percent_change_1h': 0.63,
#   'percent_change_24h': -0.65,
#   'percent_change_7d': 10.44,
#   'price_btc': 0.00067286,
#   'price_usd': 6.28807,
#   'rank': 41,
#   'symbol': 'STRAT',
#   'total_supply': 98834575.0},
#  {'24h_volume_usd': 5713020.0,
#   'available_supply': 7145743.0,
#   'id': 'decred',
#   'last_updated': 1524932647,
#   'market_cap_usd': 618134630.0,
#   'max_supply': 21000000.0,
#   'name': 'Decred',
#   'percent_change_1h': 0.83,
#   'percent_change_24h': -2.12,
#   'percent_change_7d': 31.32,
#   'price_btc': 0.00925641,
#   'price_usd': 86.5039,
#   'rank': 42,
#   'symbol': 'DCR',
#   'total_supply': 7565743.0},
#  {'24h_volume_usd': 10917900.0,
#   'available_supply': 525137802.0,
#   'id': '0x',
#   'last_updated': 1524932656,
#   'market_cap_usd': 612126879.0,
#   'max_supply': None,
#   'name': '0x',
#   'percent_change_1h': 0.2,
#   'percent_change_24h': 2.42,
#   'percent_change_7d': 27.5,
#   'price_btc': 0.00012473,
#   'price_usd': 1.16565,
#   'rank': 43,
#   'symbol': 'ZRX',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 965203.0,
#   'available_supply': 415971.0,
#   'id': 'mixin',
#   'last_updated': 1524932664,
#   'market_cap_usd': 593486141.0,
#   'max_supply': None,
#   'name': 'Mixin',
#   'percent_change_1h': 0.59,
#   'percent_change_24h': 1.31,
#   'percent_change_7d': 179.6,
#   'price_btc': 0.15267,
#   'price_usd': 1426.75,
#   'rank': 44,
#   'symbol': 'XIN',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 52158800.0,
#   'available_supply': 100000000.0,
#   'id': 'waves',
#   'last_updated': 1524932648,
#   'market_cap_usd': 576663000.0,
#   'max_supply': None,
#   'name': 'Waves',
#   'percent_change_1h': 1.22,
#   'percent_change_24h': 0.78,
#   'percent_change_7d': 14.03,
#   'price_btc': 0.00061706,
#   'price_usd': 5.76663,
#   'rank': 45,
#   'symbol': 'WAVES',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 114397000.0,
#   'available_supply': 42918700.0,
#   'id': 'hshare',
#   'last_updated': 1524932658,
#   'market_cap_usd': 572895976.0,
#   'max_supply': 84000000.0,
#   'name': 'Hshare',
#   'percent_change_1h': 3.97,
#   'percent_change_24h': 12.22,
#   'percent_change_7d': 75.77,
#   'price_btc': 0.00142836,
#   'price_usd': 13.3484,
#   'rank': 46,
#   'symbol': 'HSR',
#   'total_supply': 42918700.0},
#  {'24h_volume_usd': 65276000.0,
#   'available_supply': 3470483788.0,
#   'id': 'status',
#   'last_updated': 1524932654,
#   'market_cap_usd': 550613076.0,
#   'max_supply': None,
#   'name': 'Status',
#   'percent_change_1h': 2.81,
#   'percent_change_24h': 9.56,
#   'percent_change_7d': 7.63,
#   'price_btc': 1.698e-05,
#   'price_usd': 0.158656,
#   'rank': 47,
#   'symbol': 'SNT',
#   'total_supply': 6804870174.0},
#  {'24h_volume_usd': 5656260.0,
#   'available_supply': 2000000.0,
#   'id': 'digixdao',
#   'last_updated': 1524932648,
#   'market_cap_usd': 547954000.0,
#   'max_supply': None,
#   'name': 'DigixDAO',
#   'percent_change_1h': 0.56,
#   'percent_change_24h': 1.16,
#   'percent_change_7d': -3.25,
#   'price_btc': 0.0293171,
#   'price_usd': 273.977,
#   'rank': 48,
#   'symbol': 'DGD',
#   'total_supply': 2000000.0},
#  {'24h_volume_usd': 974588.0,
#   'available_supply': 359816354.0,
#   'id': 'rchain',
#   'last_updated': 1524932660,
#   'market_cap_usd': 537824701.0,
#   'max_supply': 1000000000.0,
#   'name': 'RChain',
#   'percent_change_1h': 1.41,
#   'percent_change_24h': 0.93,
#   'percent_change_7d': 2.83,
#   'price_btc': 0.00015994,
#   'price_usd': 1.49472,
#   'rank': 49,
#   'symbol': 'RHOC',
#   'total_supply': 870663574.0},
#  {'24h_volume_usd': 7010330.0,
#   'available_supply': 133073439.0,
#   'id': 'aion',
#   'last_updated': 1524932659,
#   'market_cap_usd': 512730630.0,
#   'max_supply': None,
#   'name': 'Aion',
#   'percent_change_1h': 1.86,
#   'percent_change_24h': 3.81,
#   'percent_change_7d': 10.94,
#   'price_btc': 0.00041229,
#   'price_usd': 3.85299,
#   'rank': 50,
#   'symbol': 'AION',
#   'total_supply': 465934587.0},
#  {'24h_volume_usd': 13002300.0,
#   'available_supply': 31144099.0,
#   'id': 'waltonchain',
#   'last_updated': 1524932657,
#   'market_cap_usd': 507393439.0,
#   'max_supply': 100000000.0,
#   'name': 'Waltonchain',
#   'percent_change_1h': -0.53,
#   'percent_change_24h': 9.46,
#   'percent_change_7d': 34.81,
#   'price_btc': 0.00174331,
#   'price_usd': 16.2918,
#   'rank': 51,
#   'symbol': 'WTC',
#   'total_supply': 70000000.0},
#  {'24h_volume_usd': 28730200.0,
#   'available_supply': 834262000.0,
#   'id': 'golem-network-tokens',
#   'last_updated': 1524932651,
#   'market_cap_usd': 504351424.0,
#   'max_supply': None,
#   'name': 'Golem',
#   'percent_change_1h': 0.71,
#   'percent_change_24h': -0.41,
#   'percent_change_7d': 21.56,
#   'price_btc': 6.469e-05,
#   'price_usd': 0.604548,
#   'rank': 52,
#   'symbol': 'GNT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 27131100.0,
#   'available_supply': 572074043.0,
#   'id': 'loopring',
#   'last_updated': 1524932660,
#   'market_cap_usd': 482042747.0,
#   'max_supply': None,
#   'name': 'Loopring',
#   'percent_change_1h': 0.77,
#   'percent_change_24h': 7.28,
#   'percent_change_7d': 13.69,
#   'price_btc': 9.017e-05,
#   'price_usd': 0.842623,
#   'rank': 53,
#   'symbol': 'LRC',
#   'total_supply': 1374956262.0},
#  {'24h_volume_usd': 5081470.0,
#   'available_supply': 11000000.0,
#   'id': 'augur',
#   'last_updated': 1524932647,
#   'market_cap_usd': 455805900.0,
#   'max_supply': None,
#   'name': 'Augur',
#   'percent_change_1h': 0.52,
#   'percent_change_24h': -0.93,
#   'percent_change_7d': 8.57,
#   'price_btc': 0.00443399,
#   'price_usd': 41.4369,
#   'rank': 54,
#   'symbol': 'REP',
#   'total_supply': 11000000.0},
#  {'24h_volume_usd': 74542600.0,
#   'available_supply': 8400000000.0,
#   'id': 'iostoken',
#   'last_updated': 1524932665,
#   'market_cap_usd': 455151480.0,
#   'max_supply': None,
#   'name': 'IOStoken',
#   'percent_change_1h': 0.47,
#   'percent_change_24h': 5.36,
#   'percent_change_7d': 34.16,
#   'price_btc': 5.8e-06,
#   'price_usd': 0.0541847,
#   'rank': 55,
#   'symbol': 'IOST',
#   'total_supply': 21000000000.0},
#  {'24h_volume_usd': 10205200.0,
#   'available_supply': 10178317242.0,
#   'id': 'digibyte',
#   'last_updated': 1524932649,
#   'market_cap_usd': 450236845.0,
#   'max_supply': 21000000000.0,
#   'name': 'DigiByte',
#   'percent_change_1h': 0.4,
#   'percent_change_24h': 0.53,
#   'percent_change_7d': 32.39,
#   'price_btc': 4.73e-06,
#   'price_usd': 0.0442349,
#   'rank': 56,
#   'symbol': 'DGB',
#   'total_supply': 10178317242.0},
#  {'24h_volume_usd': 7834490.0,
#   'available_supply': 1000000000.0,
#   'id': 'basic-attention-token',
#   'last_updated': 1524932653,
#   'market_cap_usd': 444254000.0,
#   'max_supply': None,
#   'name': 'Basic Attention Token',
#   'percent_change_1h': 2.76,
#   'percent_change_24h': 1.06,
#   'percent_change_7d': 13.58,
#   'price_btc': 4.754e-05,
#   'price_usd': 0.444254,
#   'rank': 57,
#   'symbol': 'BAT',
#   'total_supply': 1500000000.0},
#  {'24h_volume_usd': 2284950.0,
#   'available_supply': 104053280.0,
#   'id': 'komodo',
#   'last_updated': 1524932651,
#   'market_cap_usd': 404545626.0,
#   'max_supply': None,
#   'name': 'Komodo',
#   'percent_change_1h': 0.3,
#   'percent_change_24h': 0.32,
#   'percent_change_7d': 3.9,
#   'price_btc': 0.00041602,
#   'price_usd': 3.88787,
#   'rank': 58,
#   'symbol': 'KMD',
#   'total_supply': 104053280.0},
#  {'24h_volume_usd': 4955220.0,
#   'available_supply': 102197696.0,
#   'id': 'ark',
#   'last_updated': 1524932652,
#   'market_cap_usd': 394505590.0,
#   'max_supply': None,
#   'name': 'Ark',
#   'percent_change_1h': 1.88,
#   'percent_change_24h': 9.14,
#   'percent_change_7d': 27.24,
#   'price_btc': 0.00041307,
#   'price_usd': 3.86022,
#   'rank': 59,
#   'symbol': 'ARK',
#   'total_supply': 133447696.0},
#  {'24h_volume_usd': 4898520.0,
#   'available_supply': 998999495.0,
#   'id': 'ardor',
#   'last_updated': 1524932649,
#   'market_cap_usd': 394482923.0,
#   'max_supply': 998999495.0,
#   'name': 'Ardor',
#   'percent_change_1h': 0.87,
#   'percent_change_24h': 1.44,
#   'percent_change_7d': 7.17,
#   'price_btc': 4.225e-05,
#   'price_usd': 0.394878,
#   'rank': 60,
#   'symbol': 'ARDR',
#   'total_supply': 998999495.0},
#  {'24h_volume_usd': 282103000.0,
#   'available_supply': 305054520.0,
#   'id': 'mithril',
#   'last_updated': 1524932667,
#   'market_cap_usd': 365702409.0,
#   'max_supply': None,
#   'name': 'Mithril',
#   'percent_change_1h': -0.92,
#   'percent_change_24h': -1.21,
#   'percent_change_7d': 23.97,
#   'price_btc': 0.00012828,
#   'price_usd': 1.19881,
#   'rank': 61,
#   'symbol': 'MITH',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 35579300.0,
#   'available_supply': 134132697.0,
#   'id': 'kyber-network',
#   'last_updated': 1524932658,
#   'market_cap_usd': 359274429.0,
#   'max_supply': None,
#   'name': 'Kyber Network',
#   'percent_change_1h': 0.47,
#   'percent_change_24h': -1.25,
#   'percent_change_7d': 69.95,
#   'price_btc': 0.00028661,
#   'price_usd': 2.6785,
#   'rank': 62,
#   'symbol': 'KNC',
#   'total_supply': 215625349.0},
#  {'24h_volume_usd': 96912700.0,
#   'available_supply': 250000000.0,
#   'id': 'aelf',
#   'last_updated': 1524932662,
#   'market_cap_usd': 349410000.0,
#   'max_supply': 1000000000.0,
#   'name': 'aelf',
#   'percent_change_1h': 2.89,
#   'percent_change_24h': 19.91,
#   'percent_change_7d': 32.44,
#   'price_btc': 0.00014956,
#   'price_usd': 1.39764,
#   'rank': 63,
#   'symbol': 'ELF',
#   'total_supply': 280000000.0},
#  {'24h_volume_usd': 800557.0,
#   'available_supply': 75730576.0,
#   'id': 'kucoin-shares',
#   'last_updated': 1524932660,
#   'market_cap_usd': 334528460.0,
#   'max_supply': None,
#   'name': 'KuCoin Shares',
#   'percent_change_1h': 0.35,
#   'percent_change_24h': -2.51,
#   'percent_change_7d': 29.19,
#   'price_btc': 0.00047268,
#   'price_usd': 4.41735,
#   'rank': 64,
#   'symbol': 'KCS',
#   'total_supply': 180730576.0},
#  {'24h_volume_usd': 8612160.0,
#   'available_supply': 59088775.0,
#   'id': 'monacoin',
#   'last_updated': 1524932642,
#   'market_cap_usd': 329922175.0,
#   'max_supply': None,
#   'name': 'MonaCoin',
#   'percent_change_1h': 3.3,
#   'percent_change_24h': -0.93,
#   'percent_change_7d': 41.66,
#   'price_btc': 0.00059747,
#   'price_usd': 5.5835,
#   'rank': 65,
#   'symbol': 'MONA',
#   'total_supply': 59088775.0},
#  {'24h_volume_usd': 238745.0,
#   'available_supply': 686528275.0,
#   'id': 'centrality',
#   'last_updated': 1524932667,
#   'market_cap_usd': 327270089.0,
#   'max_supply': None,
#   'name': 'Centrality',
#   'percent_change_1h': 1.45,
#   'percent_change_24h': 3.55,
#   'percent_change_7d': 26.61,
#   'price_btc': 5.101e-05,
#   'price_usd': 0.476703,
#   'rank': 66,
#   'symbol': 'CENNZ',
#   'total_supply': 1200000000.0},
#  {'24h_volume_usd': 25629800.0,
#   'available_supply': 532611630.0,
#   'id': 'syscoin',
#   'last_updated': 1524932645,
#   'market_cap_usd': 311403640.0,
#   'max_supply': 888000000.0,
#   'name': 'Syscoin',
#   'percent_change_1h': 0.24,
#   'percent_change_24h': 4.04,
#   'percent_change_7d': 33.3,
#   'price_btc': 6.256e-05,
#   'price_usd': 0.584673,
#   'rank': 67,
#   'symbol': 'SYS',
#   'total_supply': 532611630.0},
#  {'24h_volume_usd': 2814210.0,
#   'available_supply': 56085692.0,
#   'id': 'pivx',
#   'last_updated': 1524932648,
#   'market_cap_usd': 305374813.0,
#   'max_supply': None,
#   'name': 'PIVX',
#   'percent_change_1h': 0.79,
#   'percent_change_24h': 0.83,
#   'percent_change_7d': 3.02,
#   'price_btc': 0.00058262,
#   'price_usd': 5.44479,
#   'rank': 68,
#   'symbol': 'PIVX',
#   'total_supply': 56085692.0},
#  {'24h_volume_usd': 10329200.0,
#   'available_supply': 383021000.0,
#   'id': 'substratum',
#   'last_updated': 1524932657,
#   'market_cap_usd': 297089473.0,
#   'max_supply': None,
#   'name': 'Substratum',
#   'percent_change_1h': 2.62,
#   'percent_change_24h': 3.46,
#   'percent_change_7d': 13.94,
#   'price_btc': 8.3e-05,
#   'price_usd': 0.775648,
#   'rank': 69,
#   'symbol': 'SUB',
#   'total_supply': 472000000.0},
#  {'24h_volume_usd': 44289200.0,
#   'available_supply': 35500000.0,
#   'id': 'nebulas-token',
#   'last_updated': 1524932656,
#   'market_cap_usd': 294827145.0,
#   'max_supply': 100000000.0,
#   'name': 'Nebulas',
#   'percent_change_1h': 0.12,
#   'percent_change_24h': 15.22,
#   'percent_change_7d': 41.02,
#   'price_btc': 0.00088868,
#   'price_usd': 8.30499,
#   'rank': 70,
#   'symbol': 'NAS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 1705610.0,
#   'available_supply': 45238183.0,
#   'id': 'cryptonex',
#   'last_updated': 1524932659,
#   'market_cap_usd': 290635418.0,
#   'max_supply': 210000000.0,
#   'name': 'Cryptonex',
#   'percent_change_1h': 1.56,
#   'percent_change_24h': 4.48,
#   'percent_change_7d': 7.93,
#   'price_btc': 0.00068746,
#   'price_usd': 6.42456,
#   'rank': 71,
#   'symbol': 'CNX',
#   'total_supply': 106675808.0},
#  {'24h_volume_usd': 3996540.0,
#   'available_supply': 238421940.0,
#   'id': 'dragonchain',
#   'last_updated': 1524932662,
#   'market_cap_usd': 280310291.0,
#   'max_supply': None,
#   'name': 'Dragonchain',
#   'percent_change_1h': 2.6,
#   'percent_change_24h': -2.43,
#   'percent_change_7d': -2.65,
#   'price_btc': 0.00012581,
#   'price_usd': 1.17569,
#   'rank': 72,
#   'symbol': 'DRGN',
#   'total_supply': 433494437.0},
#  {'24h_volume_usd': 85072700.0,
#   'available_supply': 4091706234.0,
#   'id': 'storm',
#   'last_updated': 1524932663,
#   'market_cap_usd': 280308064.0,
#   'max_supply': None,
#   'name': 'Storm',
#   'percent_change_1h': 1.63,
#   'percent_change_24h': 3.75,
#   'percent_change_7d': 22.77,
#   'price_btc': 7.33e-06,
#   'price_usd': 0.0685064,
#   'rank': 73,
#   'symbol': 'STORM',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 2647880.0,
#   'available_supply': 10128375.0,
#   'id': 'gas',
#   'last_updated': 1524932654,
#   'market_cap_usd': 276307137.0,
#   'max_supply': 100000000.0,
#   'name': 'Gas',
#   'percent_change_1h': 0.59,
#   'percent_change_24h': 0.36,
#   'percent_change_7d': 13.05,
#   'price_btc': 0.00291917,
#   'price_usd': 27.2805,
#   'rank': 74,
#   'symbol': 'GAS',
#   'total_supply': 17190378.0},
#  {'24h_volume_usd': 566743.0,
#   'available_supply': 325226613094,
#   'id': 'dentacoin',
#   'last_updated': 1524932657,
#   'market_cap_usd': 274895193.0,
#   'max_supply': 8000000000000,
#   'name': 'Dentacoin',
#   'percent_change_1h': 1.74,
#   'percent_change_24h': -5.2,
#   'percent_change_7d': 11.15,
#   'price_btc': 9e-08,
#   'price_usd': 0.000845242,
#   'rank': 75,
#   'symbol': 'DCN',
#   'total_supply': 1963173416169},
#  {'24h_volume_usd': 3277080.0,
#   'available_supply': 56864567422.0,
#   'id': 'pundi-x',
#   'last_updated': 1524932667,
#   'market_cap_usd': 270068027.0,
#   'max_supply': None,
#   'name': 'Pundi X',
#   'percent_change_1h': 0.14,
#   'percent_change_24h': 1.48,
#   'percent_change_7d': 15.25,
#   'price_btc': 5.1e-07,
#   'price_usd': 0.00474932,
#   'rank': 76,
#   'symbol': 'NPXS',
#   'total_supply': 62769055127.0},
#  {'24h_volume_usd': 9625560.0,
#   'available_supply': 76404704.0,
#   'id': 'ethos',
#   'last_updated': 1524932655,
#   'market_cap_usd': 266425495.0,
#   'max_supply': None,
#   'name': 'Ethos',
#   'percent_change_1h': -0.36,
#   'percent_change_24h': 1.32,
#   'percent_change_7d': 20.83,
#   'price_btc': 0.00037313,
#   'price_usd': 3.48703,
#   'rank': 77,
#   'symbol': 'ETHOS',
#   'total_supply': 222295208.0},
#  {'24h_volume_usd': 46176600.0,
#   'available_supply': 149792458.0,
#   'id': 'cortex',
#   'last_updated': 1524932667,
#   'market_cap_usd': 264813593.0,
#   'max_supply': None,
#   'name': 'Cortex',
#   'percent_change_1h': 3.21,
#   'percent_change_24h': 11.67,
#   'percent_change_7d': 39.54,
#   'price_btc': 0.00018917,
#   'price_usd': 1.76787,
#   'rank': 78,
#   'symbol': 'CTXC',
#   'total_supply': 299792458.0},
#  {'24h_volume_usd': 3500990.0,
#   'available_supply': 350000000.0,
#   'id': 'qash',
#   'last_updated': 1524932662,
#   'market_cap_usd': 261919350.0,
#   'max_supply': None,
#   'name': 'QASH',
#   'percent_change_1h': -0.09,
#   'percent_change_24h': -1.88,
#   'percent_change_7d': 0.04,
#   'price_btc': 8.008e-05,
#   'price_usd': 0.748341,
#   'rank': 79,
#   'symbol': 'QASH',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 20884700.0,
#   'available_supply': 28808713174.0,
#   'id': 'reddcoin',
#   'last_updated': 1524932650,
#   'market_cap_usd': 258347033.0,
#   'max_supply': None,
#   'name': 'ReddCoin',
#   'percent_change_1h': 1.07,
#   'percent_change_24h': 2.08,
#   'percent_change_7d': 20.51,
#   'price_btc': 9.6e-07,
#   'price_usd': 0.00896767,
#   'rank': 80,
#   'symbol': 'RDD',
#   'total_supply': 28808713174.0},
#  {'24h_volume_usd': 2497920.0,
#   'available_supply': 8745102.0,
#   'id': 'factom',
#   'last_updated': 1524932647,
#   'market_cap_usd': 249313238.0,
#   'max_supply': None,
#   'name': 'Factom',
#   'percent_change_1h': -1.27,
#   'percent_change_24h': -2.71,
#   'percent_change_7d': -3.76,
#   'price_btc': 0.00305061,
#   'price_usd': 28.5089,
#   'rank': 81,
#   'symbol': 'FCT',
#   'total_supply': 8745102.0},
#  {'24h_volume_usd': 11172700.0,
#   'available_supply': 51865401.0,
#   'id': 'bancor',
#   'last_updated': 1524932654,
#   'market_cap_usd': 247332614.0,
#   'max_supply': None,
#   'name': 'Bancor',
#   'percent_change_1h': 0.55,
#   'percent_change_24h': 1.69,
#   'percent_change_7d': 26.22,
#   'price_btc': 0.00051028,
#   'price_usd': 4.76874,
#   'rank': 82,
#   'symbol': 'BNT',
#   'total_supply': 76168262.0},
#  {'24h_volume_usd': 79944200.0,
#   'available_supply': 429699461.0,
#   'id': 'gifto',
#   'last_updated': 1524932662,
#   'market_cap_usd': 243483613.0,
#   'max_supply': None,
#   'name': 'Gifto',
#   'percent_change_1h': 0.45,
#   'percent_change_24h': -0.29,
#   'percent_change_7d': 104.52,
#   'price_btc': 6.063e-05,
#   'price_usd': 0.566637,
#   'rank': 83,
#   'symbol': 'GTO',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 11461300.0,
#   'available_supply': 57953451.0,
#   'id': 'salt',
#   'last_updated': 1524932658,
#   'market_cap_usd': 239330944.0,
#   'max_supply': None,
#   'name': 'SALT',
#   'percent_change_1h': 1.12,
#   'percent_change_24h': 7.8,
#   'percent_change_7d': 25.21,
#   'price_btc': 0.0004419,
#   'price_usd': 4.12971,
#   'rank': 84,
#   'symbol': 'SALT',
#   'total_supply': 120000000.0},
#  {'24h_volume_usd': 14211900.0,
#   'available_supply': 60000000.0,
#   'id': 'gxchain',
#   'last_updated': 1524932654,
#   'market_cap_usd': 229859400.0,
#   'max_supply': 100000000.0,
#   'name': 'GXChain',
#   'percent_change_1h': 1.21,
#   'percent_change_24h': 4.27,
#   'percent_change_7d': 5.96,
#   'price_btc': 0.00040994,
#   'price_usd': 3.83099,
#   'rank': 85,
#   'symbol': 'GXS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 17276000.0,
#   'available_supply': 5122572.0,
#   'id': 'elastos',
#   'last_updated': 1524932665,
#   'market_cap_usd': 225503807.0,
#   'max_supply': None,
#   'name': 'Elastos',
#   'percent_change_1h': 1.46,
#   'percent_change_24h': 5.56,
#   'percent_change_7d': 0.89,
#   'price_btc': 0.00471057,
#   'price_usd': 44.0216,
#   'rank': 86,
#   'symbol': 'ELA',
#   'total_supply': 33457751.0},
#  {'24h_volume_usd': 3508750.0,
#   'available_supply': 4723473189.0,
#   'id': 'funfair',
#   'last_updated': 1524932658,
#   'market_cap_usd': 222648939.0,
#   'max_supply': None,
#   'name': 'FunFair',
#   'percent_change_1h': 1.45,
#   'percent_change_24h': 1.78,
#   'percent_change_7d': 6.95,
#   'price_btc': 5.04e-06,
#   'price_usd': 0.0471367,
#   'rank': 87,
#   'symbol': 'FUN',
#   'total_supply': 10999873621.0},
#  {'24h_volume_usd': 1056130.0,
#   'available_supply': 2036645.0,
#   'id': 'veritaseum',
#   'last_updated': 1524932654,
#   'market_cap_usd': 220876235.0,
#   'max_supply': None,
#   'name': 'Veritaseum',
#   'percent_change_1h': 3.95,
#   'percent_change_24h': -5.77,
#   'percent_change_7d': -9.7,
#   'price_btc': 0.0116049,
#   'price_usd': 108.451,
#   'rank': 88,
#   'symbol': 'VERI',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 4260450.0,
#   'available_supply': 621779038.0,
#   'id': 'wax',
#   'last_updated': 1524932663,
#   'market_cap_usd': 219509141.0,
#   'max_supply': None,
#   'name': 'WAX',
#   'percent_change_1h': -0.1,
#   'percent_change_24h': -1.95,
#   'percent_change_7d': 6.36,
#   'price_btc': 3.778e-05,
#   'price_usd': 0.353034,
#   'rank': 89,
#   'symbol': 'WAX',
#   'total_supply': 1850000000.0},
#  {'24h_volume_usd': 2621260.0,
#   'available_supply': 4633470.0,
#   'id': 'zcoin',
#   'last_updated': 1524932651,
#   'market_cap_usd': 215341898.0,
#   'max_supply': 21400000.0,
#   'name': 'ZCoin',
#   'percent_change_1h': 1.77,
#   'percent_change_24h': 3.16,
#   'percent_change_7d': 11.94,
#   'price_btc': 0.00497313,
#   'price_usd': 46.4753,
#   'rank': 90,
#   'symbol': 'XZC',
#   'total_supply': 4633470.0},
#  {'24h_volume_usd': 3798380.0,
#   'available_supply': 998999942.0,
#   'id': 'nxt',
#   'last_updated': 1524932648,
#   'market_cap_usd': 210644133.0,
#   'max_supply': 1000000000.0,
#   'name': 'Nxt',
#   'percent_change_1h': 0.59,
#   'percent_change_24h': 0.49,
#   'percent_change_7d': 6.38,
#   'price_btc': 2.256e-05,
#   'price_usd': 0.210855,
#   'rank': 91,
#   'symbol': 'NXT',
#   'total_supply': 998999942.0},
#  {'24h_volume_usd': 9770680.0,
#   'available_supply': 366344076.0,
#   'id': 'power-ledger',
#   'last_updated': 1524932660,
#   'market_cap_usd': 203149147.0,
#   'max_supply': None,
#   'name': 'Power Ledger',
#   'percent_change_1h': 1.31,
#   'percent_change_24h': 1.95,
#   'percent_change_7d': 15.44,
#   'price_btc': 5.934e-05,
#   'price_usd': 0.554531,
#   'rank': 92,
#   'symbol': 'POWR',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 877348.0,
#   'available_supply': 756097560976,
#   'id': 'kin',
#   'last_updated': 1524932659,
#   'market_cap_usd': 196353244.0,
#   'max_supply': None,
#   'name': 'Kin',
#   'percent_change_1h': 0.1,
#   'percent_change_24h': -1.32,
#   'percent_change_7d': 20.92,
#   'price_btc': 3e-08,
#   'price_usd': 0.000259693,
#   'rank': 93,
#   'symbol': 'KIN',
#   'total_supply': 10000000000000},
#  {'24h_volume_usd': 13740700.0,
#   'available_supply': 74836171.0,
#   'id': 'enigma-project',
#   'last_updated': 1524932659,
#   'market_cap_usd': 191954779.0,
#   'max_supply': None,
#   'name': 'Enigma',
#   'percent_change_1h': 0.41,
#   'percent_change_24h': -3.15,
#   'percent_change_7d': 8.67,
#   'price_btc': 0.00027447,
#   'price_usd': 2.565,
#   'rank': 94,
#   'symbol': 'ENG',
#   'total_supply': 150000000.0},
#  {'24h_volume_usd': 28611000.0,
#   'available_supply': 15793831.0,
#   'id': 'monaco',
#   'last_updated': 1524932654,
#   'market_cap_usd': 190241434.0,
#   'max_supply': None,
#   'name': 'Monaco',
#   'percent_change_1h': 1.3,
#   'percent_change_24h': 1.35,
#   'percent_change_7d': -3.35,
#   'price_btc': 0.00128892,
#   'price_usd': 12.0453,
#   'rank': 95,
#   'symbol': 'MCO',
#   'total_supply': 31587682.0},
#  {'24h_volume_usd': 2590150.0,
#   'available_supply': 551500133.0,
#   'id': 'loom-network',
#   'last_updated': 1524932666,
#   'market_cap_usd': 185819146.0,
#   'max_supply': None,
#   'name': 'Loom Network',
#   'percent_change_1h': 2.01,
#   'percent_change_24h': 7.16,
#   'percent_change_7d': 15.07,
#   'price_btc': 3.605e-05,
#   'price_usd': 0.336934,
#   'rank': 96,
#   'symbol': 'LOOM',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 4234600.0,
#   'available_supply': 186450000.0,
#   'id': 'revain',
#   'last_updated': 1524932660,
#   'market_cap_usd': 177511587.0,
#   'max_supply': 484450000.0,
#   'name': 'Revain',
#   'percent_change_1h': -0.03,
#   'percent_change_24h': -6.36,
#   'percent_change_7d': -9.5,
#   'price_btc': 0.00010188,
#   'price_usd': 0.95206,
#   'rank': 97,
#   'symbol': 'R',
#   'total_supply': 484450000.0},
#  {'24h_volume_usd': 5992480.0,
#   'available_supply': 29684331.0,
#   'id': 'fusion',
#   'last_updated': 1524932666,
#   'market_cap_usd': 177461837.0,
#   'max_supply': None,
#   'name': 'Fusion',
#   'percent_change_1h': 1.03,
#   'percent_change_24h': 5.87,
#   'percent_change_7d': 20.71,
#   'price_btc': 0.00063971,
#   'price_usd': 5.9783,
#   'rank': 98,
#   'symbol': 'FSN',
#   'total_supply': 57344000.0},
#  {'24h_volume_usd': 16179400.0,
#   'available_supply': 4112034633.0,
#   'id': 'nucleus-vision',
#   'last_updated': 1524932666,
#   'market_cap_usd': 177057221.0,
#   'max_supply': None,
#   'name': 'Nucleus Vision',
#   'percent_change_1h': 0.14,
#   'percent_change_24h': 1.79,
#   'percent_change_7d': 9.42,
#   'price_btc': 4.61e-06,
#   'price_usd': 0.0430583,
#   'rank': 99,
#   'symbol': 'NCASH',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 5149650.0,
#   'available_supply': 662961247.0,
#   'id': 'request-network',
#   'last_updated': 1524932659,
#   'market_cap_usd': 174803655.0,
#   'max_supply': None,
#   'name': 'Request Network',
#   'percent_change_1h': 0.85,
#   'percent_change_24h': -0.61,
#   'percent_change_7d': 20.8,
#   'price_btc': 2.821e-05,
#   'price_usd': 0.263671,
#   'rank': 100,
#   'symbol': 'REQ',
#   'total_supply': 999999743.0},
#  {'24h_volume_usd': 965658.0,
#   'available_supply': 6836551754.0,
#   'id': 'electroneum',
#   'last_updated': 1524932660,
#   'market_cap_usd': 174197390.0,
#   'max_supply': 21000000000.0,
#   'name': 'Electroneum',
#   'percent_change_1h': 0.32,
#   'percent_change_24h': -0.12,
#   'percent_change_7d': 4.74,
#   'price_btc': 2.73e-06,
#   'price_usd': 0.0254803,
#   'rank': 101,
#   'symbol': 'ETN',
#   'total_supply': 6836551754.0},
#  {'24h_volume_usd': 329199.0,
#   'available_supply': 645946.0,
#   'id': 'byteball',
#   'last_updated': 1524932650,
#   'market_cap_usd': 172450145.0,
#   'max_supply': None,
#   'name': 'Byteball Bytes',
#   'percent_change_1h': 0.55,
#   'percent_change_24h': -3.49,
#   'percent_change_7d': 0.33,
#   'price_btc': 0.0285677,
#   'price_usd': 266.973,
#   'rank': 102,
#   'symbol': 'GBYTE',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 1514060.0,
#   'available_supply': 452552412.0,
#   'id': 'maidsafecoin',
#   'last_updated': 1524932654,
#   'market_cap_usd': 171892078.0,
#   'max_supply': None,
#   'name': 'MaidSafeCoin',
#   'percent_change_1h': 0.4,
#   'percent_change_24h': -0.91,
#   'percent_change_7d': 4.16,
#   'price_btc': 4.064e-05,
#   'price_usd': 0.379828,
#   'rank': 103,
#   'symbol': 'MAID',
#   'total_supply': 452552412.0},
#  {'24h_volume_usd': 12539100.0,
#   'available_supply': 13044562.0,
#   'id': 'neblio',
#   'last_updated': 1524932657,
#   'market_cap_usd': 171541209.0,
#   'max_supply': None,
#   'name': 'Neblio',
#   'percent_change_1h': 1.11,
#   'percent_change_24h': 1.71,
#   'percent_change_7d': 17.05,
#   'price_btc': 0.00140717,
#   'price_usd': 13.1504,
#   'rank': 104,
#   'symbol': 'NEBL',
#   'total_supply': 13805220.0},
#  {'24h_volume_usd': 10879200.0,
#   'available_supply': 350000000.0,
#   'id': 'chainlink',
#   'last_updated': 1524932657,
#   'market_cap_usd': 167883100.0,
#   'max_supply': None,
#   'name': 'ChainLink',
#   'percent_change_1h': 0.89,
#   'percent_change_24h': 0.59,
#   'percent_change_7d': 1.94,
#   'price_btc': 5.133e-05,
#   'price_usd': 0.479666,
#   'rank': 105,
#   'symbol': 'LINK',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 2476770.0,
#   'available_supply': 109004761.0,
#   'id': 'tenx',
#   'last_updated': 1524932654,
#   'market_cap_usd': 163099463.0,
#   'max_supply': None,
#   'name': 'TenX',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': -0.87,
#   'percent_change_7d': -1.48,
#   'price_btc': 0.00016011,
#   'price_usd': 1.49626,
#   'rank': 106,
#   'symbol': 'PAY',
#   'total_supply': 205218256.0},
#  {'24h_volume_usd': 2802010.0,
#   'available_supply': 1500000000.0,
#   'id': 'deepbrain-chain',
#   'last_updated': 1524932662,
#   'market_cap_usd': 161889000.0,
#   'max_supply': 10000000000.0,
#   'name': 'DeepBrain Chain',
#   'percent_change_1h': 1.3,
#   'percent_change_24h': -0.89,
#   'percent_change_7d': 44.28,
#   'price_btc': 1.155e-05,
#   'price_usd': 0.107926,
#   'rank': 107,
#   'symbol': 'DBC',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 12315000.0,
#   'available_supply': 135787539.0,
#   'id': 'storj',
#   'last_updated': 1524932654,
#   'market_cap_usd': 160834908.0,
#   'max_supply': None,
#   'name': 'Storj',
#   'percent_change_1h': 2.59,
#   'percent_change_24h': 2.63,
#   'percent_change_7d': 14.12,
#   'price_btc': 0.00012674,
#   'price_usd': 1.18446,
#   'rank': 108,
#   'symbol': 'STORJ',
#   'total_supply': 424999998.0},
#  {'24h_volume_usd': 14853800.0,
#   'available_supply': 1050141509.0,
#   'id': 'decentraland',
#   'last_updated': 1524932657,
#   'market_cap_usd': 158352938.0,
#   'max_supply': None,
#   'name': 'Decentraland',
#   'percent_change_1h': 0.75,
#   'percent_change_24h': 4.87,
#   'percent_change_7d': 33.87,
#   'price_btc': 1.614e-05,
#   'price_usd': 0.150792,
#   'rank': 109,
#   'symbol': 'MANA',
#   'total_supply': 2644403343.0},
#  {'24h_volume_usd': 1854150.0,
#   'available_supply': 8951446.0,
#   'id': 'particl',
#   'last_updated': 1524932655,
#   'market_cap_usd': 157659142.0,
#   'max_supply': None,
#   'name': 'Particl',
#   'percent_change_1h': 0.83,
#   'percent_change_24h': -1.39,
#   'percent_change_7d': 14.24,
#   'price_btc': 0.00188466,
#   'price_usd': 17.6127,
#   'rank': 110,
#   'symbol': 'PART',
#   'total_supply': 8951446.0},
#  {'24h_volume_usd': 1827650.0,
#   'available_supply': 3728913.0,
#   'id': 'zencash',
#   'last_updated': 1524932653,
#   'market_cap_usd': 157092744.0,
#   'max_supply': 21000000.0,
#   'name': 'ZenCash',
#   'percent_change_1h': -1.7,
#   'percent_change_24h': 5.82,
#   'percent_change_7d': 18.1,
#   'price_btc': 0.00450797,
#   'price_usd': 42.1283,
#   'rank': 111,
#   'symbol': 'ZEN',
#   'total_supply': 3728913.0},
#  {'24h_volume_usd': 3661710.0,
#   'available_supply': 1445976590.0,
#   'id': 'cindicator',
#   'last_updated': 1524932659,
#   'market_cap_usd': 154806254.0,
#   'max_supply': None,
#   'name': 'Cindicator',
#   'percent_change_1h': 1.58,
#   'percent_change_24h': 6.67,
#   'percent_change_7d': 15.38,
#   'price_btc': 1.146e-05,
#   'price_usd': 0.10706,
#   'rank': 112,
#   'symbol': 'CND',
#   'total_supply': 2000000005.0},
#  {'24h_volume_usd': 1375560.0,
#   'available_supply': 8057879.0,
#   'id': 'skycoin',
#   'last_updated': 1524932652,
#   'market_cap_usd': 154487268.0,
#   'max_supply': 100000000.0,
#   'name': 'Skycoin',
#   'percent_change_1h': -0.21,
#   'percent_change_24h': -0.06,
#   'percent_change_7d': 14.4,
#   'price_btc': 0.00205154,
#   'price_usd': 19.1722,
#   'rank': 113,
#   'symbol': 'SKY',
#   'total_supply': 25000000.0},
#  {'24h_volume_usd': 3525470.0,
#   'available_supply': 1413716694.0,
#   'id': 'smartmesh',
#   'last_updated': 1524932662,
#   'market_cap_usd': 153533874.0,
#   'max_supply': None,
#   'name': 'SmartMesh',
#   'percent_change_1h': 0.33,
#   'percent_change_24h': -3.89,
#   'percent_change_7d': 58.25,
#   'price_btc': 1.162e-05,
#   'price_usd': 0.108603,
#   'rank': 114,
#   'symbol': 'SMT',
#   'total_supply': 3141592653.0},
#  {'24h_volume_usd': 1402310.0,
#   'available_supply': 99735687.0,
#   'id': 'iconomi',
#   'last_updated': 1524932650,
#   'market_cap_usd': 151726903.0,
#   'max_supply': None,
#   'name': 'Iconomi',
#   'percent_change_1h': -0.49,
#   'percent_change_24h': 1.07,
#   'percent_change_7d': 7.15,
#   'price_btc': 0.00016279,
#   'price_usd': 1.52129,
#   'rank': 115,
#   'symbol': 'ICN',
#   'total_supply': 99735687.0},
#  {'24h_volume_usd': 58192300.0,
#   'available_supply': 474399718.0,
#   'id': 'achain',
#   'last_updated': 1524932658,
#   'market_cap_usd': 148579145.0,
#   'max_supply': 1000000000.0,
#   'name': 'Achain',
#   'percent_change_1h': 0.55,
#   'percent_change_24h': 5.79,
#   'percent_change_7d': 21.73,
#   'price_btc': 3.351e-05,
#   'price_usd': 0.313194,
#   'rank': 116,
#   'symbol': 'ACT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 168066.0,
#   'available_supply': 918206576.0,
#   'id': 'smartcash',
#   'last_updated': 1524932655,
#   'market_cap_usd': 147988272.0,
#   'max_supply': 5000000000.0,
#   'name': 'SmartCash',
#   'percent_change_1h': -0.24,
#   'percent_change_24h': -2.73,
#   'percent_change_7d': -20.57,
#   'price_btc': 1.725e-05,
#   'price_usd': 0.161171,
#   'rank': 117,
#   'symbol': 'SMART',
#   'total_supply': 1519250855.0},
#  {'24h_volume_usd': 1102180.0,
#   'available_supply': 150000000.0,
#   'id': 'matrix-ai-network',
#   'last_updated': 1524932665,
#   'market_cap_usd': 144680250.0,
#   'max_supply': 1000000000.0,
#   'name': 'Matrix AI Network',
#   'percent_change_1h': 1.42,
#   'percent_change_24h': -0.2,
#   'percent_change_7d': 18.44,
#   'price_btc': 0.00010321,
#   'price_usd': 0.964535,
#   'rank': 118,
#   'symbol': 'MAN',
#   'total_supply': 250000000.0},
#  {'24h_volume_usd': 2912420.0,
#   'available_supply': 56963708.0,
#   'id': 'nexus',
#   'last_updated': 1524932646,
#   'market_cap_usd': 143245496.0,
#   'max_supply': None,
#   'name': 'Nexus',
#   'percent_change_1h': -0.63,
#   'percent_change_24h': 4.46,
#   'percent_change_7d': 15.31,
#   'price_btc': 0.00026909,
#   'price_usd': 2.51468,
#   'rank': 119,
#   'symbol': 'NXS',
#   'total_supply': 56963708.0},
#  {'24h_volume_usd': 20942500.0,
#   'available_supply': 40000000.0,
#   'id': 'nuls',
#   'last_updated': 1524932660,
#   'market_cap_usd': 143154800.0,
#   'max_supply': None,
#   'name': 'Nuls',
#   'percent_change_1h': 1.32,
#   'percent_change_24h': 8.13,
#   'percent_change_7d': 41.79,
#   'price_btc': 0.00038296,
#   'price_usd': 3.57887,
# ...
#   'percent_change_7d': 2.6,
#   'price_btc': 1.88e-05,
#   'price_usd': 0.175706,
#   'rank': 960,
#   'symbol': 'ECO',
#   'total_supply': 1161297.0},
#  {'24h_volume_usd': 15268.9,
#   'available_supply': 5000000.0,
#   'id': 'homeblockcoin',
#   'last_updated': 1524932663,
#   'market_cap_usd': 201643.0,
#   'max_supply': 28000000.0,
#   'name': 'HomeBlockCoin',
#   'percent_change_1h': 6.2,
#   'percent_change_24h': 42.74,
#   'percent_change_7d': 146.38,
#   'price_btc': 4.32e-06,
#   'price_usd': 0.0403286,
#   'rank': 961,
#   'symbol': 'HBC',
#   'total_supply': 9529146.0},
#  {'24h_volume_usd': 2317.2,
#   'available_supply': 2560000000.0,
#   'id': 'reecoin',
#   'last_updated': 1524932649,
#   'market_cap_usd': 198294.0,
#   'max_supply': None,
#   'name': 'ReeCoin',
#   'percent_change_1h': -0.62,
#   'percent_change_24h': -6.43,
#   'percent_change_7d': 39.32,
#   'price_btc': 8e-09,
#   'price_usd': 7.74586e-05,
#   'rank': 962,
#   'symbol': 'REE',
#   'total_supply': 6650666335.0},
#  {'24h_volume_usd': 2562.69,
#   'available_supply': 51679470.0,
#   'id': 'neuro',
#   'last_updated': 1524932653,
#   'market_cap_usd': 198014.0,
#   'max_supply': None,
#   'name': 'Neuro',
#   'percent_change_1h': 3.05,
#   'percent_change_24h': -17.35,
#   'percent_change_7d': 118.78,
#   'price_btc': 4.1e-07,
#   'price_usd': 0.00383157,
#   'rank': 963,
#   'symbol': 'NRO',
#   'total_supply': 53679470.0},
#  {'24h_volume_usd': 2775.81,
#   'available_supply': 7000000.0,
#   'id': 'shadow-token',
#   'last_updated': 1524932656,
#   'market_cap_usd': 196858.0,
#   'max_supply': None,
#   'name': 'Shadow Token',
#   'percent_change_1h': 0.58,
#   'percent_change_24h': -3.01,
#   'percent_change_7d': -36.92,
#   'price_btc': 3.01e-06,
#   'price_usd': 0.0281225,
#   'rank': 964,
#   'symbol': 'SHDW',
#   'total_supply': 10000000.0},
#  {'24h_volume_usd': 662.952,
#   'available_supply': 16347235.0,
#   'id': 'phantomx',
#   'last_updated': 1524932661,
#   'market_cap_usd': 187117.0,
#   'max_supply': None,
#   'name': 'Phantomx',
#   'percent_change_1h': 0.55,
#   'percent_change_24h': -4.46,
#   'percent_change_7d': 0.21,
#   'price_btc': 1.22e-06,
#   'price_usd': 0.0114464,
#   'rank': 965,
#   'symbol': 'PNX',
#   'total_supply': 16347235.0},
#  {'24h_volume_usd': 685.436,
#   'available_supply': 741819.0,
#   'id': 'briacoin',
#   'last_updated': 1524932654,
#   'market_cap_usd': 185232.0,
#   'max_supply': 3000000.0,
#   'name': 'BriaCoin',
#   'percent_change_1h': 0.0,
#   'percent_change_24h': 61.34,
#   'percent_change_7d': -21.65,
#   'price_btc': 2.672e-05,
#   'price_usd': 0.2497,
#   'rank': 966,
#   'symbol': 'BRIA',
#   'total_supply': 741819.0},
#  {'24h_volume_usd': 1597.22,
#   'available_supply': 20202180.0,
#   'id': 'prime-xi',
#   'last_updated': 1524932645,
#   'market_cap_usd': 185030.0,
#   'max_supply': None,
#   'name': 'Prime-XI',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': -12.0,
#   'percent_change_7d': -7.81,
#   'price_btc': 9.8e-07,
#   'price_usd': 0.00915891,
#   'rank': 967,
#   'symbol': 'PXI',
#   'total_supply': 20202180.0},
#  {'24h_volume_usd': 1463.71,
#   'available_supply': 78245975.0,
#   'id': 'coin2-1',
#   'last_updated': 1524932646,
#   'market_cap_usd': 182905.0,
#   'max_supply': None,
#   'name': 'Coin2.1',
#   'percent_change_1h': 3.28,
#   'percent_change_24h': -3.45,
#   'percent_change_7d': -23.72,
#   'price_btc': 2.5e-07,
#   'price_usd': 0.00233757,
#   'rank': 968,
#   'symbol': 'C2',
#   'total_supply': 133273764.0},
#  {'24h_volume_usd': 2958.21,
#   'available_supply': 444352.0,
#   'id': 'sixeleven',
#   'last_updated': 1524932648,
#   'market_cap_usd': 181819.0,
#   'max_supply': None,
#   'name': 'SixEleven',
#   'percent_change_1h': 15.73,
#   'percent_change_24h': 1.37,
#   'percent_change_7d': 31.58,
#   'price_btc': 4.378e-05,
#   'price_usd': 0.409179,
#   'rank': 969,
#   'symbol': '611',
#   'total_supply': 444352.0},
#  {'24h_volume_usd': 528.406,
#   'available_supply': 8265187.0,
#   'id': 'abjcoin',
#   'last_updated': 1524932661,
#   'market_cap_usd': 179462.0,
#   'max_supply': None,
#   'name': 'Abjcoin',
#   'percent_change_1h': 0.46,
#   'percent_change_24h': -3.33,
#   'percent_change_7d': -19.32,
#   'price_btc': 2.32e-06,
#   'price_usd': 0.021713,
#   'rank': 970,
#   'symbol': 'ABJ',
#   'total_supply': 9265207.0},
#  {'24h_volume_usd': 1636.57,
#   'available_supply': 1500000.0,
#   'id': 'ethereum-dark',
#   'last_updated': 1524932657,
#   'market_cap_usd': 173262.0,
#   'max_supply': 4200000.0,
#   'name': 'Ethereum Dark',
#   'percent_change_1h': 0.9,
#   'percent_change_24h': 1.87,
#   'percent_change_7d': 22.89,
#   'price_btc': 1.236e-05,
#   'price_usd': 0.115508,
#   'rank': 971,
#   'symbol': 'ETHD',
#   'total_supply': 3019862.0},
#  {'24h_volume_usd': 5949.95,
#   'available_supply': 1494171.0,
#   'id': 'high-voltage',
#   'last_updated': 1524932649,
#   'market_cap_usd': 173004.0,
#   'max_supply': None,
#   'name': 'High Voltage',
#   'percent_change_1h': 0.57,
#   'percent_change_24h': -1.18,
#   'percent_change_7d': -83.04,
#   'price_btc': 1.239e-05,
#   'price_usd': 0.115786,
#   'rank': 972,
#   'symbol': 'HVCO',
#   'total_supply': 1694171.0},
#  {'24h_volume_usd': 1238.58,
#   'available_supply': 27971200.0,
#   'id': 'globaltoken',
#   'last_updated': 1524932654,
#   'market_cap_usd': 163570.0,
#   'max_supply': 168000000.0,
#   'name': 'GlobalToken',
#   'percent_change_1h': 1.49,
#   'percent_change_24h': -11.44,
#   'percent_change_7d': -36.53,
#   'price_btc': 6.3e-07,
#   'price_usd': 0.00584779,
#   'rank': 973,
#   'symbol': 'GLT',
#   'total_supply': 27971200.0},
#  {'24h_volume_usd': 26516.1,
#   'available_supply': 1012637.0,
#   'id': 'desire',
#   'last_updated': 1524932661,
#   'market_cap_usd': 163214.0,
#   'max_supply': None,
#   'name': 'Desire',
#   'percent_change_1h': 6.45,
#   'percent_change_24h': 29.89,
#   'percent_change_7d': 18.84,
#   'price_btc': 1.725e-05,
#   'price_usd': 0.161177,
#   'rank': 974,
#   'symbol': 'DSR',
#   'total_supply': 1772559.0},
#  {'24h_volume_usd': 4621.03,
#   'available_supply': 12384976.0,
#   'id': 'x-coin',
#   'last_updated': 1524932646,
#   'market_cap_usd': 158278.0,
#   'max_supply': None,
#   'name': 'X-Coin',
#   'percent_change_1h': -14.23,
#   'percent_change_24h': -19.79,
#   'percent_change_7d': 95.35,
#   'price_btc': 1.37e-06,
#   'price_usd': 0.0127798,
#   'rank': 975,
#   'symbol': 'XCO',
#   'total_supply': 12384976.0},
#  {'24h_volume_usd': 955.89,
#   'available_supply': 40951200.0,
#   'id': 'theresa-may-coin',
#   'last_updated': 1524932653,
#   'market_cap_usd': 157855.0,
#   'max_supply': 100000000.0,
#   'name': 'Theresa May Coin',
#   'percent_change_1h': 5.64,
#   'percent_change_24h': -5.04,
#   'percent_change_7d': -11.38,
#   'price_btc': 4.1e-07,
#   'price_usd': 0.0038547,
#   'rank': 976,
#   'symbol': 'MAY',
#   'total_supply': 40951200.0},
#  {'24h_volume_usd': 552.688,
#   'available_supply': 12462620.0,
#   'id': 'sooncoin',
#   'last_updated': 1524932645,
#   'market_cap_usd': 157230.0,
#   'max_supply': None,
#   'name': 'SoonCoin',
#   'percent_change_1h': 0.01,
#   'percent_change_24h': -1.03,
#   'percent_change_7d': 39.25,
#   'price_btc': 1.35e-06,
#   'price_usd': 0.0126161,
#   'rank': 977,
#   'symbol': 'SOON',
#   'total_supply': 12462620.0},
#  {'24h_volume_usd': 3322.01,
#   'available_supply': 963024.0,
#   'id': 'trident',
#   'last_updated': 1524932662,
#   'market_cap_usd': 156376.0,
#   'max_supply': None,
#   'name': 'Trident Group',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 14.55,
#   'percent_change_7d': -11.02,
#   'price_btc': 1.738e-05,
#   'price_usd': 0.16238,
#   'rank': 978,
#   'symbol': 'TRDT',
#   'total_supply': 3000000.0},
#  {'24h_volume_usd': 1088.9,
#   'available_supply': 455955.0,
#   'id': 'honey',
#   'last_updated': 1524932652,
#   'market_cap_usd': 150472.0,
#   'max_supply': None,
#   'name': 'Honey',
#   'percent_change_1h': 0.42,
#   'percent_change_24h': -3.36,
#   'percent_change_7d': -2.05,
#   'price_btc': 3.531e-05,
#   'price_usd': 0.330015,
#   'rank': 979,
#   'symbol': 'HONEY',
#   'total_supply': 455955.0},
#  {'24h_volume_usd': 1064.4,
#   'available_supply': 73729962.0,
#   'id': 'chronos',
#   'last_updated': 1524932649,
#   'market_cap_usd': 150211.0,
#   'max_supply': None,
#   'name': 'Chronos',
#   'percent_change_1h': -8.03,
#   'percent_change_24h': 30.72,
#   'percent_change_7d': -50.2,
#   'price_btc': 2.2e-07,
#   'price_usd': 0.00203731,
#   'rank': 980,
#   'symbol': 'CRX',
#   'total_supply': 73729962.0},
#  {'24h_volume_usd': 885.905,
#   'available_supply': 29887402.0,
#   'id': 'global-tour-coin',
#   'last_updated': 1524932655,
#   'market_cap_usd': 145239.0,
#   'max_supply': None,
#   'name': 'Global Tour Coin',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': -20.58,
#   'percent_change_7d': -27.35,
#   'price_btc': 5.2e-07,
#   'price_usd': 0.00485955,
#   'rank': 981,
#   'symbol': 'GTC',
#   'total_supply': 89786652.0},
#  {'24h_volume_usd': 1162.05,
#   'available_supply': 14083450.0,
#   'id': 'solarflarecoin',
#   'last_updated': 1524932651,
#   'market_cap_usd': 140547.0,
#   'max_supply': None,
#   'name': 'Solarflarecoin',
#   'percent_change_1h': -4.38,
#   'percent_change_24h': -4.68,
#   'percent_change_7d': 67.14,
#   'price_btc': 1.07e-06,
#   'price_usd': 0.00997962,
#   'rank': 982,
#   'symbol': 'SFC',
#   'total_supply': 14083450.0},
#  {'24h_volume_usd': 583.731,
#   'available_supply': 464267.0,
#   'id': 'dalecoin',
#   'last_updated': 1524932657,
#   'market_cap_usd': 136440.0,
#   'max_supply': 1000000.0,
#   'name': 'Dalecoin',
#   'percent_change_1h': 4.69,
#   'percent_change_24h': 12.11,
#   'percent_change_7d': 15.24,
#   'price_btc': 3.145e-05,
#   'price_usd': 0.293882,
#   'rank': 983,
#   'symbol': 'DALC',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 20844.4,
#   'available_supply': 107706.0,
#   'id': 'biteur',
#   'last_updated': 1524932646,
#   'market_cap_usd': 135137.0,
#   'max_supply': None,
#   'name': 'bitEUR',
#   'percent_change_1h': 2.11,
#   'percent_change_24h': -1.26,
#   'percent_change_7d': -6.34,
#   'price_btc': 0.00013426,
#   'price_usd': 1.25468,
#   'rank': 984,
#   'symbol': 'BITEUR',
#   'total_supply': 107706.0},
#  {'24h_volume_usd': 597.566,
#   'available_supply': 23042604.0,
#   'id': 'paycon',
#   'last_updated': 1524932645,
#   'market_cap_usd': 132172.0,
#   'max_supply': None,
#   'name': 'PayCon',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 0.03,
#   'percent_change_7d': -41.96,
#   'price_btc': 6.1e-07,
#   'price_usd': 0.005736,
#   'rank': 985,
#   'symbol': 'CON',
#   'total_supply': 23042604.0},
#  {'24h_volume_usd': 1731.48,
#   'available_supply': 160000000.0,
#   'id': 'brat',
#   'last_updated': 1524932659,
#   'market_cap_usd': 131779.0,
#   'max_supply': None,
#   'name': 'BROTHER',
#   'percent_change_1h': 0.57,
#   'percent_change_24h': -0.73,
#   'percent_change_7d': -5.95,
#   'price_btc': 9e-08,
#   'price_usd': 0.00082362,
#   'rank': 986,
#   'symbol': 'BRAT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 1061.35,
#   'available_supply': 3055450.0,
#   'id': 'glasscoin',
#   'last_updated': 1524932662,
#   'market_cap_usd': 125067.0,
#   'max_supply': None,
#   'name': 'GlassCoin',
#   'percent_change_1h': 0.57,
#   'percent_change_24h': 0.94,
#   'percent_change_7d': -47.25,
#   'price_btc': 4.38e-06,
#   'price_usd': 0.0409324,
#   'rank': 987,
#   'symbol': 'GLS',
#   'total_supply': 5507089.0},
#  {'24h_volume_usd': 4255.48,
#   'available_supply': 189729990.0,
#   'id': 'hicoin',
#   'last_updated': 1524932648,
#   'market_cap_usd': 124209.0,
#   'max_supply': None,
#   'name': 'HiCoin',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 1.08,
#   'percent_change_7d': -15.48,
#   'price_btc': 7e-08,
#   'price_usd': 0.000654662,
#   'rank': 988,
#   'symbol': 'XHI',
#   'total_supply': 10000244678.0},
#  {'24h_volume_usd': 723.547,
#   'available_supply': 4500000.0,
#   'id': 'bitcoal',
#   'last_updated': 1524932655,
#   'market_cap_usd': 123498.0,
#   'max_supply': 12500000.0,
#   'name': 'BitCoal',
#   'percent_change_1h': 0.14,
#   'percent_change_24h': 5.07,
#   'percent_change_7d': 33.81,
#   'price_btc': 2.94e-06,
#   'price_usd': 0.0274439,
#   'rank': 989,
#   'symbol': 'COAL',
#   'total_supply': 4500000.0},
#  {'24h_volume_usd': 515.542,
#   'available_supply': 9106714.0,
#   'id': 'dollarcoin',
#   'last_updated': 1524932657,
#   'market_cap_usd': 123402.0,
#   'max_supply': None,
#   'name': 'Dollarcoin',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 0.79,
#   'percent_change_7d': -25.48,
#   'price_btc': 1.45e-06,
#   'price_usd': 0.0135507,
#   'rank': 990,
#   'symbol': 'DLC',
#   'total_supply': 9106714.0},
#  {'24h_volume_usd': 13936.6,
#   'available_supply': 50000000.0,
#   'id': 'newbium',
#   'last_updated': 1524932649,
#   'market_cap_usd': 121489.0,
#   'max_supply': None,
#   'name': 'Newbium',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 45.59,
#   'percent_change_7d': -18.36,
#   'price_btc': 2.6e-07,
#   'price_usd': 0.00242978,
#   'rank': 991,
#   'symbol': 'NEWB',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 11542.4,
#   'available_supply': 28940333.0,
#   'id': 'litebitcoin',
#   'last_updated': 1524932655,
#   'market_cap_usd': 119153.0,
#   'max_supply': 1000000000.0,
#   'name': 'LiteBitcoin',
#   'percent_change_1h': 3.02,
#   'percent_change_24h': -2.7,
#   'percent_change_7d': 9.67,
#   'price_btc': 4.4e-07,
#   'price_usd': 0.00411719,
#   'rank': 992,
#   'symbol': 'LBTC',
#   'total_supply': 172585874.0},
#  {'24h_volume_usd': 842.143,
#   'available_supply': 872830.0,
#   'id': 'comet',
#   'last_updated': 1524932649,
#   'market_cap_usd': 116493.0,
#   'max_supply': None,
#   'name': 'Comet',
#   'percent_change_1h': 6.72,
#   'percent_change_24h': 10.56,
#   'percent_change_7d': 25.34,
#   'price_btc': 1.428e-05,
#   'price_usd': 0.133466,
#   'rank': 993,
#   'symbol': 'CMT',
#   'total_supply': 872830.0},
#  {'24h_volume_usd': 1298.33,
#   'available_supply': 600344291.0,
#   'id': 'zetamicron',
#   'last_updated': 1524932651,
#   'market_cap_usd': 112208.0,
#   'max_supply': None,
#   'name': 'ZetaMicron',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 17.1,
#   'percent_change_7d': 6.79,
#   'price_btc': 2e-08,
#   'price_usd': 0.000186906,
#   'rank': 994,
#   'symbol': 'ZMC',
#   'total_supply': 600344291.0},
#  {'24h_volume_usd': 2101.77,
#   'available_supply': 1627261.0,
#   'id': 'bipcoin',
#   'last_updated': 1524932650,
#   'market_cap_usd': 108884.0,
#   'max_supply': None,
#   'name': 'BipCoin',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 33.23,
#   'percent_change_7d': 84.12,
#   'price_btc': 7.16e-06,
#   'price_usd': 0.0669123,
#   'rank': 995,
#   'symbol': 'BIP',
#   'total_supply': 1627261.0},
#  {'24h_volume_usd': 543.942,
#   'available_supply': 8623200.0,
#   'id': 'coinonat',
#   'last_updated': 1524932652,
#   'market_cap_usd': 100102.0,
#   'max_supply': None,
#   'name': 'Coinonat',
#   'percent_change_1h': 5.33,
#   'percent_change_24h': 10.43,
#   'percent_change_7d': 0.9,
#   'price_btc': 1.24e-06,
#   'price_usd': 0.0116085,
#   'rank': 996,
#   'symbol': 'CXT',
#   'total_supply': 10123200.0},
#  {'24h_volume_usd': 731.941,
#   'available_supply': 4195132.0,
#   'id': 'cachecoin',
#   'last_updated': 1524932651,
#   'market_cap_usd': 95459.0,
#   'max_supply': 10000000.0,
#   'name': 'CacheCoin',
#   'percent_change_1h': -3.95,
#   'percent_change_24h': -7.7,
#   'percent_change_7d': 1.7,
#   'price_btc': 2.43e-06,
#   'price_usd': 0.0227547,
#   'rank': 997,
#   'symbol': 'CACH',
#   'total_supply': 4195132.0},
#  {'24h_volume_usd': 3354.92,
#   'available_supply': 61876500.0,
#   'id': 'virta-unique-coin',
#   'last_updated': 1524932654,
#   'market_cap_usd': 91187.0,
#   'max_supply': 120000000.0,
#   'name': 'Virta Unique Coin',
#   'percent_change_1h': -2.51,
#   'percent_change_24h': -11.95,
#   'percent_change_7d': -19.86,
#   'price_btc': 1.6e-07,
#   'price_usd': 0.00147369,
#   'rank': 998,
#   'symbol': 'VUC',
#   'total_supply': 61876500.0},
#  {'24h_volume_usd': 948.84,
#   'available_supply': 2619083.0,
#   'id': 'pioneer-coin',
#   'last_updated': 1524932662,
#   'market_cap_usd': 91051.0,
#   'max_supply': 23000000.0,
#   'name': 'Pioneer Coin',
#   'percent_change_1h': -0.04,
#   'percent_change_24h': -6.72,
#   'percent_change_7d': -12.52,
#   'price_btc': 3.72e-06,
#   'price_usd': 0.0347645,
#   'rank': 999,
#   'symbol': 'PCOIN',
#   'total_supply': 3514516.0},
#  {'24h_volume_usd': 2903.63,
#   'available_supply': 1220161.0,
#   'id': 'goldpieces',
#   'last_updated': 1524932645,
#   'market_cap_usd': 90039.0,
#   'max_supply': None,
#   'name': 'GoldPieces',
#   'percent_change_1h': 0.53,
#   'percent_change_24h': -18.97,
#   'percent_change_7d': -4.23,
#   'price_btc': 7.9e-06,
#   'price_usd': 0.073793,
#   'rank': 1000,
#   'symbol': 'GP',
#   'total_supply': 1220161.0},
#  ...]

# %% [markdown]
# You can pass a currency through `name`, `symbol`, `website_slug` or `id`:

# %%
data_from_symbol = cmc.ticker("BTC")
data_from_slug = cmc.ticker("bitcoin")

data_from_slug
# Out:
# {'data': {'circulating_supply': 17027500.0,
#   'id': 1,
#   'last_updated': 1526043271,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin',
#   'quotes': {'USD': {'market_cap': 145679797900.0,
#     'percent_change_1h': -1.58,
#     'percent_change_24h': -8.56,
#     'percent_change_7d': -11.69,
#     'price': 8555.56,
#     'volume_24h': 8525980000.0}},
#   'rank': 1,
#   'symbol': 'BTC',
#   'total_supply': 17027500.0,
#   'website_slug': 'bitcoin'},
#  'metadata': {'error': None, 'timestamp': 1526043353}}

# %% [markdown]
# To get all cryptocurrencies fields you can use the next property:

# %%
cmc.cryptocurrencies
# Out:
# [{'id': 1, 'name': 'Bitcoin', 'symbol': 'BTC', 'website_slug': 'bitcoin'},
#  {'id': 2, 'name': 'Litecoin', 'symbol': 'LTC', 'website_slug': 'litecoin'},
#  {'id': 3, 'name': 'Namecoin', 'symbol': 'NMC', 'website_slug': 'namecoin'},
#  {'id': 4, 'name': 'Terracoin', 'symbol': 'TRC', 'website_slug': 'terracoin'},
#  {'id': 5, 'name': 'Peercoin', 'symbol': 'PPC', 'website_slug': 'peercoin'},
#  {'id': 6, 'name': 'Novacoin', 'symbol': 'NVC', 'website_slug': 'novacoin'},
#  {'id': 8,
#   'name': 'Feathercoin',
#   'symbol': 'FTC',
#   'website_slug': 'feathercoin'},
#  {'id': 9, 'name': 'Mincoin', 'symbol': 'MNC', 'website_slug': 'mincoin'},
#  {'id': 10, 'name': 'Freicoin', 'symbol': 'FRC', 'website_slug': 'freicoin'},
#  {'id': 13, 'name': 'Ixcoin', 'symbol': 'IXC', 'website_slug': 'ixcoin'},
#  {'id': 14, 'name': 'BitBar', 'symbol': 'BTB', 'website_slug': 'bitbar'},
#  {'id': 16, 'name': 'WorldCoin', 'symbol': 'WDC', 'website_slug': 'worldcoin'},
#  {'id': 17, 'name': 'Yacoin', 'symbol': 'YAC', 'website_slug': 'yacoin'},
#  {'id': 18,
#   'name': 'Digitalcoin',
#   'symbol': 'DGC',
#   'website_slug': 'digitalcoin'},
#  {'id': 20, 'name': 'Elacoin', 'symbol': 'ELC', 'website_slug': 'elacoin'},
#  {'id': 25, 'name': 'GoldCoin', 'symbol': 'GLD', 'website_slug': 'goldcoin'},
#  {'id': 31, 'name': 'Argentum', 'symbol': 'ARG', 'website_slug': 'argentum'},
#  {'id': 32, 'name': 'Fastcoin', 'symbol': 'FST', 'website_slug': 'fastcoin'},
#  {'id': 34, 'name': 'Bitgem', 'symbol': 'BTG', 'website_slug': 'bitgem'},
#  {'id': 35,
#   'name': 'Phoenixcoin',
#   'symbol': 'PXC',
#   'website_slug': 'phoenixcoin'},
#  {'id': 37, 'name': 'Megacoin', 'symbol': 'MEC', 'website_slug': 'megacoin'},
#  {'id': 41,
#   'name': 'Infinitecoin',
#   'symbol': 'IFC',
#   'website_slug': 'infinitecoin'},
#  {'id': 42, 'name': 'Primecoin', 'symbol': 'XPM', 'website_slug': 'primecoin'},
#  {'id': 43, 'name': 'Anoncoin', 'symbol': 'ANC', 'website_slug': 'anoncoin'},
#  {'id': 45,
#   'name': 'CasinoCoin',
#   'symbol': 'CSC',
#   'website_slug': 'casinocoin'},
#  {'id': 49, 'name': 'Bullion', 'symbol': 'CBX', 'website_slug': 'bullion'},
#  {'id': 50,
#   'name': 'Emerald Crypto',
#   'symbol': 'EMD',
#   'website_slug': 'emerald'},
#  {'id': 51,
#   'name': 'GlobalCoin',
#   'symbol': 'GLC',
#   'website_slug': 'globalcoin'},
#  {'id': 52, 'name': 'Ripple', 'symbol': 'XRP', 'website_slug': 'ripple'},
#  {'id': 53, 'name': 'Quark', 'symbol': 'QRK', 'website_slug': 'quark'},
#  {'id': 56, 'name': 'Zetacoin', 'symbol': 'ZET', 'website_slug': 'zetacoin'},
#  {'id': 57,
#   'name': 'SecureCoin',
#   'symbol': 'SRC',
#   'website_slug': 'securecoin'},
#  {'id': 58, 'name': 'Sexcoin', 'symbol': 'SXC', 'website_slug': 'sexcoin'},
#  {'id': 61, 'name': 'TagCoin', 'symbol': 'TAG', 'website_slug': 'tagcoin'},
#  {'id': 63, 'name': 'I0Coin', 'symbol': 'I0C', 'website_slug': 'i0coin'},
#  {'id': 64,
#   'name': 'FlorinCoin',
#   'symbol': 'FLO',
#   'website_slug': 'florincoin'},
#  {'id': 66, 'name': 'Nxt', 'symbol': 'NXT', 'website_slug': 'nxt'},
#  {'id': 67,
#   'name': 'Unobtanium',
#   'symbol': 'UNO',
#   'website_slug': 'unobtanium'},
#  {'id': 68, 'name': 'Joulecoin', 'symbol': 'XJO', 'website_slug': 'joulecoin'},
#  {'id': 69, 'name': 'Datacoin', 'symbol': 'DTC', 'website_slug': 'datacoin'},
#  {'id': 70, 'name': 'BetaCoin', 'symbol': 'BET', 'website_slug': 'betacoin'},
#  {'id': 71, 'name': 'GrandCoin', 'symbol': 'GDC', 'website_slug': 'grandcoin'},
#  {'id': 72,
#   'name': 'Deutsche eMark',
#   'symbol': 'DEM',
#   'website_slug': 'deutsche-emark'},
#  {'id': 74, 'name': 'Dogecoin', 'symbol': 'DOGE', 'website_slug': 'dogecoin'},
#  {'id': 75, 'name': 'NetCoin', 'symbol': 'NET', 'website_slug': 'netcoin'},
#  {'id': 76,
#   'name': 'Philosopher Stones',
#   'symbol': 'PHS',
#   'website_slug': 'philosopher-stones'},
#  {'id': 77, 'name': 'Diamond', 'symbol': 'DMD', 'website_slug': 'diamond'},
#  {'id': 78,
#   'name': 'HoboNickels',
#   'symbol': 'HBN',
#   'website_slug': 'hobonickels'},
#  {'id': 79, 'name': 'Tigercoin', 'symbol': 'TGC', 'website_slug': 'tigercoin'},
#  {'id': 80, 'name': 'Orbitcoin', 'symbol': 'ORB', 'website_slug': 'orbitcoin'},
#  {'id': 83, 'name': 'Omni', 'symbol': 'OMNI', 'website_slug': 'omni'},
#  {'id': 84, 'name': 'Catcoin', 'symbol': 'CAT', 'website_slug': 'catcoin'},
#  {'id': 87,
#   'name': 'FedoraCoin',
#   'symbol': 'TIPS',
#   'website_slug': 'fedoracoin'},
#  {'id': 88,
#   'name': 'RonPaulCoin',
#   'symbol': 'RPC',
#   'website_slug': 'ronpaulcoin'},
#  {'id': 89, 'name': 'Mooncoin', 'symbol': 'MOON', 'website_slug': 'mooncoin'},
#  {'id': 90, 'name': 'Dimecoin', 'symbol': 'DIME', 'website_slug': 'dimecoin'},
#  {'id': 93, 'name': '42-coin', 'symbol': '42', 'website_slug': '42-coin'},
#  {'id': 99, 'name': 'Vertcoin', 'symbol': 'VTC', 'website_slug': 'vertcoin'},
#  {'id': 101,
#   'name': 'KlondikeCoin',
#   'symbol': 'KDC',
#   'website_slug': 'klondikecoin'},
#  {'id': 103, 'name': 'RedCoin', 'symbol': 'RED', 'website_slug': 'redcoin'},
#  {'id': 107, 'name': 'LeafCoin', 'symbol': 'LEAF', 'website_slug': 'leafcoin'},
#  {'id': 109, 'name': 'DigiByte', 'symbol': 'DGB', 'website_slug': 'digibyte'},
#  {'id': 113,
#   'name': 'SmartCoin',
#   'symbol': 'SMC',
#   'website_slug': 'smartcoin'},
#  {'id': 114,
#   'name': 'TeslaCoin',
#   'symbol': 'TES',
#   'website_slug': 'teslacoin'},
#  {'id': 116,
#   'name': 'Karmacoin',
#   'symbol': 'KARMA',
#   'website_slug': 'karmacoin'},
#  {'id': 117,
#   'name': 'NobleCoin',
#   'symbol': 'NOBL',
#   'website_slug': 'noblecoin'},
#  {'id': 118, 'name': 'ReddCoin', 'symbol': 'RDD', 'website_slug': 'reddcoin'},
#  {'id': 120, 'name': 'Nyancoin', 'symbol': 'NYAN', 'website_slug': 'nyancoin'},
#  {'id': 121,
#   'name': 'UltraCoin',
#   'symbol': 'UTC',
#   'website_slug': 'ultracoin'},
#  {'id': 122, 'name': 'PotCoin', 'symbol': 'POT', 'website_slug': 'potcoin'},
#  {'id': 125,
#   'name': 'Blakecoin',
#   'symbol': 'BLC',
#   'website_slug': 'blakecoin'},
#  {'id': 128, 'name': 'MaxCoin', 'symbol': 'MAX', 'website_slug': 'maxcoin'},
#  {'id': 129,
#   'name': 'QubitCoin',
#   'symbol': 'Q2C',
#   'website_slug': 'qubitcoin'},
#  {'id': 130,
#   'name': 'HunterCoin',
#   'symbol': 'HUC',
#   'website_slug': 'huntercoin'},
#  {'id': 131, 'name': 'Dash', 'symbol': 'DASH', 'website_slug': 'dash'},
#  {'id': 132,
#   'name': 'Counterparty',
#   'symbol': 'XCP',
#   'website_slug': 'counterparty'},
#  {'id': 134,
#   'name': 'CacheCoin',
#   'symbol': 'CACH',
#   'website_slug': 'cachecoin'},
#  {'id': 135, 'name': 'TopCoin', 'symbol': 'TOP', 'website_slug': 'topcoin'},
#  {'id': 138, 'name': 'iCoin', 'symbol': 'ICN', 'website_slug': 'icoin'},
#  {'id': 141, 'name': 'Mintcoin', 'symbol': 'MINT', 'website_slug': 'mintcoin'},
#  {'id': 142, 'name': 'Aricoin', 'symbol': 'ARI', 'website_slug': 'aricoin'},
#  {'id': 145, 'name': 'DopeCoin', 'symbol': 'DOPE', 'website_slug': 'dopecoin'},
#  {'id': 148,
#   'name': 'Auroracoin',
#   'symbol': 'AUR',
#   'website_slug': 'auroracoin'},
#  {'id': 150,
#   'name': 'Animecoin',
#   'symbol': 'ANI',
#   'website_slug': 'animecoin'},
#  {'id': 151,
#   'name': 'Pesetacoin',
#   'symbol': 'PTC',
#   'website_slug': 'pesetacoin'},
#  {'id': 154, 'name': 'Marscoin', 'symbol': 'MARS', 'website_slug': 'marscoin'},
#  {'id': 159, 'name': 'Cashcoin', 'symbol': 'CASH', 'website_slug': 'cashcoin'},
#  {'id': 160, 'name': 'Riecoin', 'symbol': 'RIC', 'website_slug': 'riecoin'},
#  {'id': 161,
#   'name': 'Pandacoin',
#   'symbol': 'PND',
#   'website_slug': 'pandacoin-pnd'},
#  {'id': 164, 'name': 'MAZA', 'symbol': 'MZC', 'website_slug': 'mazacoin'},
#  {'id': 168,
#   'name': 'Uniform Fiscal Object',
#   'symbol': 'UFO',
#   'website_slug': 'uniform-fiscal-object'},
#  {'id': 170,
#   'name': 'BlackCoin',
#   'symbol': 'BLK',
#   'website_slug': 'blackcoin'},
#  {'id': 171, 'name': 'BatCoin', 'symbol': 'BAT', 'website_slug': 'batcoin'},
#  {'id': 174, 'name': 'LiteBar', 'symbol': 'LTB', 'website_slug': 'litebar'},
#  {'id': 175, 'name': 'Photon', 'symbol': 'PHO', 'website_slug': 'photon'},
#  {'id': 181, 'name': 'Zeitcoin', 'symbol': 'ZEIT', 'website_slug': 'zeitcoin'},
#  {'id': 182, 'name': 'Myriad', 'symbol': 'XMY', 'website_slug': 'myriad'},
#  {'id': 199,
#   'name': 'Skeincoin',
#   'symbol': 'SKC',
#   'website_slug': 'skeincoin'},
#  {'id': 201,
#   'name': 'Einsteinium',
#   'symbol': 'EMC2',
#   'website_slug': 'einsteinium'},
#  {'id': 205,
#   'name': 'Bitcoin Scrypt',
#   'symbol': 'BTCS',
#   'website_slug': 'bitcoin-scrypt'},
#  {'id': 206, 'name': 'Coin(O)', 'symbol': 'CNO', 'website_slug': 'coin'},
#  {'id': 212, 'name': 'ECC', 'symbol': 'ECC', 'website_slug': 'eccoin'},
#  {'id': 213, 'name': 'MonaCoin', 'symbol': 'MONA', 'website_slug': 'monacoin'},
#  {'id': 215, 'name': 'Rubycoin', 'symbol': 'RBY', 'website_slug': 'rubycoin'},
#  {'id': 217, 'name': 'Bela', 'symbol': 'BELA', 'website_slug': 'belacoin'},
#  {'id': 218,
#   'name': 'FlutterCoin',
#   'symbol': 'FLT',
#   'website_slug': 'fluttercoin'},
#  {'id': 221, 'name': 'OctoCoin', 'symbol': '888', 'website_slug': 'octocoin'},
#  {'id': 224, 'name': 'FairCoin', 'symbol': 'FAIR', 'website_slug': 'faircoin'},
#  {'id': 233,
#   'name': 'SolarCoin',
#   'symbol': 'SLR',
#   'website_slug': 'solarcoin'},
#  {'id': 234, 'name': 'e-Gulden', 'symbol': 'EFL', 'website_slug': 'e-gulden'},
#  {'id': 249,
#   'name': 'CryptoEscudo',
#   'symbol': 'CESC',
#   'website_slug': 'cryptoescudo'},
#  {'id': 254, 'name': 'Gulden', 'symbol': 'NLG', 'website_slug': 'gulden'},
#  {'id': 257, 'name': 'Polcoin', 'symbol': 'PLC', 'website_slug': 'polcoin'},
#  {'id': 258,
#   'name': 'Groestlcoin',
#   'symbol': 'GRS',
#   'website_slug': 'groestlcoin'},
#  {'id': 260,
#   'name': 'PetroDollar',
#   'symbol': 'XPD',
#   'website_slug': 'petrodollar'},
#  {'id': 263, 'name': 'PLNcoin', 'symbol': 'PLNC', 'website_slug': 'plncoin'},
#  {'id': 268,
#   'name': 'WhiteCoin',
#   'symbol': 'XWC',
#   'website_slug': 'whitecoin'},
#  {'id': 269, 'name': 'AsiaCoin', 'symbol': 'AC', 'website_slug': 'asiacoin'},
#  {'id': 275,
#   'name': 'PopularCoin',
#   'symbol': 'POP',
#   'website_slug': 'popularcoin'},
#  {'id': 276, 'name': 'Bitstar', 'symbol': 'BITS', 'website_slug': 'bitstar'},
#  {'id': 278,
#   'name': 'Quebecoin',
#   'symbol': 'QBC',
#   'website_slug': 'quebecoin'},
#  {'id': 279,
#   'name': 'CannaCoin',
#   'symbol': 'CCN',
#   'website_slug': 'cannacoin'},
#  {'id': 287,
#   'name': 'Slothcoin',
#   'symbol': 'SLOTH',
#   'website_slug': 'slothcoin'},
#  {'id': 290, 'name': 'BlueCoin', 'symbol': 'BLU', 'website_slug': 'bluecoin'},
#  {'id': 291,
#   'name': 'MaidSafeCoin',
#   'symbol': 'MAID',
#   'website_slug': 'maidsafecoin'},
#  {'id': 293,
#   'name': 'Bitcoin Plus',
#   'symbol': 'XBC',
#   'website_slug': 'bitcoin-plus'},
#  {'id': 295,
#   'name': 'BTCtalkcoin',
#   'symbol': 'TALK',
#   'website_slug': 'btctalkcoin'},
#  {'id': 298,
#   'name': 'NewYorkCoin',
#   'symbol': 'NYC',
#   'website_slug': 'newyorkcoin'},
#  {'id': 304,
#   'name': 'Canada eCoin',
#   'symbol': 'CDN',
#   'website_slug': 'canada-ecoin'},
#  {'id': 312, 'name': 'Guncoin', 'symbol': 'GUN', 'website_slug': 'guncoin'},
#  {'id': 313, 'name': 'PinkCoin', 'symbol': 'PINK', 'website_slug': 'pinkcoin'},
#  {'id': 316,
#   'name': 'Dreamcoin',
#   'symbol': 'DRM',
#   'website_slug': 'dreamcoin'},
#  {'id': 317,
#   'name': 'CoffeeCoin',
#   'symbol': 'CFC',
#   'website_slug': 'coffeecoin'},
#  {'id': 322,
#   'name': 'Energycoin',
#   'symbol': 'ENRG',
#   'website_slug': 'energycoin'},
#  {'id': 323, 'name': 'VeriCoin', 'symbol': 'VRC', 'website_slug': 'vericoin'},
#  {'id': 325, 'name': 'TEKcoin', 'symbol': 'TEK', 'website_slug': 'tekcoin'},
#  {'id': 328, 'name': 'Monero', 'symbol': 'XMR', 'website_slug': 'monero'},
#  {'id': 331,
#   'name': 'Litecoin Plus',
#   'symbol': 'LCP',
#   'website_slug': 'litecoin-plus'},
#  {'id': 333, 'name': 'Curecoin', 'symbol': 'CURE', 'website_slug': 'curecoin'},
#  {'id': 334,
#   'name': 'UnbreakableCoin',
#   'symbol': 'UNB',
#   'website_slug': 'unbreakablecoin'},
#  {'id': 337,
#   'name': 'CryptCoin',
#   'symbol': 'CRYPT',
#   'website_slug': 'cryptcoin'},
#  {'id': 338,
#   'name': 'QuazarCoin',
#   'symbol': 'QCN',
#   'website_slug': 'quazarcoin'},
#  {'id': 341,
#   'name': 'SuperCoin',
#   'symbol': 'SUPER',
#   'website_slug': 'supercoin'},
#  {'id': 344, 'name': 'Qora', 'symbol': 'QORA', 'website_slug': 'qora'},
#  {'id': 350,
#   'name': 'BoostCoin',
#   'symbol': 'BOST',
#   'website_slug': 'boostcoin'},
#  {'id': 353, 'name': 'Hyper', 'symbol': 'HYPER', 'website_slug': 'hyper'},
#  {'id': 356, 'name': 'BitQuark', 'symbol': 'BTQ', 'website_slug': 'bitquark'},
#  {'id': 360, 'name': 'Motocoin', 'symbol': 'MOTO', 'website_slug': 'motocoin'},
#  {'id': 362,
#   'name': 'CloakCoin',
#   'symbol': 'CLOAK',
#   'website_slug': 'cloakcoin'},
#  {'id': 366, 'name': 'BitSend', 'symbol': 'BSD', 'website_slug': 'bitsend'},
#  {'id': 367, 'name': 'Coin2.1', 'symbol': 'C2', 'website_slug': 'coin2-1'},
#  {'id': 370,
#   'name': 'Fantomcoin',
#   'symbol': 'FCN',
#   'website_slug': 'fantomcoin'},
#  {'id': 372,
#   'name': 'Bytecoin',
#   'symbol': 'BCN',
#   'website_slug': 'bytecoin-bcn'},
#  {'id': 374, 'name': 'ArtByte', 'symbol': 'ABY', 'website_slug': 'artbyte'},
#  {'id': 377, 'name': 'NavCoin', 'symbol': 'NAV', 'website_slug': 'nav-coin'},
#  {'id': 380, 'name': 'Uro', 'symbol': 'URO', 'website_slug': 'uro'},
#  {'id': 382,
#   'name': 'Granite',
#   'symbol': 'GRN',
#   'website_slug': 'granitecoin'},
#  {'id': 385,
#   'name': 'Donationcoin',
#   'symbol': 'DON',
#   'website_slug': 'donationcoin'},
#  {'id': 386,
#   'name': 'Piggycoin',
#   'symbol': 'PIGGY',
#   'website_slug': 'piggycoin'},
#  {'id': 389,
#   'name': 'Startcoin',
#   'symbol': 'START',
#   'website_slug': 'startcoin'},
#  {'id': 400, 'name': 'Kore', 'symbol': 'KORE', 'website_slug': 'korecoin'},
#  {'id': 405,
#   'name': 'DigitalNote',
#   'symbol': 'XDN',
#   'website_slug': 'digitalnote'},
#  {'id': 406,
#   'name': 'Boolberry',
#   'symbol': 'BBR',
#   'website_slug': 'boolberry'},
#  {'id': 411, 'name': 'SHACoin', 'symbol': 'SHA', 'website_slug': 'shacoin'},
#  {'id': 415,
#   'name': 'BlazeCoin',
#   'symbol': 'BLZ',
#   'website_slug': 'blazecoin'},
#  {'id': 416, 'name': 'HempCoin', 'symbol': 'THC', 'website_slug': 'hempcoin'},
#  {'id': 426, 'name': 'BritCoin', 'symbol': 'BRIT', 'website_slug': 'britcoin'},
#  {'id': 448, 'name': 'Stealth', 'symbol': 'XST', 'website_slug': 'stealth'},
#  {'id': 450,
#   'name': 'TrustPlus',
#   'symbol': 'TRUST',
#   'website_slug': 'trustplus'},
#  {'id': 460, 'name': 'Clams', 'symbol': 'CLAM', 'website_slug': 'clams'},
#  {'id': 461, 'name': 'Quatloo', 'symbol': 'QTL', 'website_slug': 'quatloo'},
#  {'id': 463,
#   'name': 'BitShares',
#   'symbol': 'BTS',
#   'website_slug': 'bitshares'},
#  {'id': 467,
#   'name': 'BitcoinDark',
#   'symbol': 'BTCD',
#   'website_slug': 'bitcoindark'},
#  {'id': 468,
#   'name': 'Truckcoin',
#   'symbol': 'TRK',
#   'website_slug': 'truckcoin'},
#  {'id': 470, 'name': 'Viacoin', 'symbol': 'VIA', 'website_slug': 'viacoin'},
#  {'id': 476, 'name': 'Firecoin', 'symbol': 'FIRE', 'website_slug': 'firecoin'},
#  {'id': 477,
#   'name': 'Triangles',
#   'symbol': 'TRI',
#   'website_slug': 'triangles'},
#  {'id': 493,
#   'name': 'ShadowCash',
#   'symbol': 'SDC',
#   'website_slug': 'shadowcash'},
#  {'id': 495, 'name': 'I/O Coin', 'symbol': 'IOC', 'website_slug': 'iocoin'},
#  {'id': 501,
#   'name': 'Cryptonite',
#   'symbol': 'XCN',
#   'website_slug': 'cryptonite'},
#  {'id': 502,
#   'name': 'Carboncoin',
#   'symbol': 'CARBON',
#   'website_slug': 'carboncoin'},
#  {'id': 506,
#   'name': 'CannabisCoin',
#   'symbol': 'CANN',
#   'website_slug': 'cannabiscoin'},
#  {'id': 512, 'name': 'Stellar', 'symbol': 'XLM', 'website_slug': 'stellar'},
#  {'id': 513, 'name': 'Titcoin', 'symbol': 'TIT', 'website_slug': 'titcoin'},
#  {'id': 519,
#   'name': 'VirtualCoin',
#   'symbol': 'VC',
#   'website_slug': 'virtualcoin'},
#  {'id': 520,
#   'name': 'Virtacoin',
#   'symbol': 'VTA',
#   'website_slug': 'virtacoin'},
#  {'id': 525,
#   'name': 'HyperStake',
#   'symbol': 'HYP',
#   'website_slug': 'hyperstake'},
#  {'id': 536, 'name': 'Joincoin', 'symbol': 'J', 'website_slug': 'joincoin'},
#  {'id': 541, 'name': 'Syscoin', 'symbol': 'SYS', 'website_slug': 'syscoin'},
#  {'id': 543, 'name': 'Bitmark', 'symbol': 'BTM', 'website_slug': 'bitmark'},
#  {'id': 545, 'name': 'Halcyon', 'symbol': 'HAL', 'website_slug': 'halcyon'},
#  {'id': 549,
#   'name': 'Storjcoin X',
#   'symbol': 'SJCX',
#   'website_slug': 'storjcoin-x'},
#  {'id': 551, 'name': 'NeosCoin', 'symbol': 'NEOS', 'website_slug': 'neoscoin'},
#  {'id': 558, 'name': 'Emercoin', 'symbol': 'EMC', 'website_slug': 'emercoin'},
#  {'id': 572,
#   'name': 'RabbitCoin',
#   'symbol': 'RBBT',
#   'website_slug': 'rabbitcoin'},
#  {'id': 573, 'name': 'Burst', 'symbol': 'BURST', 'website_slug': 'burst'},
#  {'id': 576,
#   'name': 'GameCredits',
#   'symbol': 'GAME',
#   'website_slug': 'gamecredits'},
#  {'id': 584,
#   'name': 'WeAreSatoshi',
#   'symbol': 'WSX',
#   'website_slug': 'wearesatoshi'},
#  {'id': 588, 'name': 'Ubiq', 'symbol': 'UBQ', 'website_slug': 'ubiq'},
#  {'id': 594,
#   'name': 'BunnyCoin',
#   'symbol': 'BUN',
#   'website_slug': 'bunnycoin'},
#  {'id': 597, 'name': 'Opal', 'symbol': 'OPAL', 'website_slug': 'opal'},
#  {'id': 601, 'name': 'Acoin', 'symbol': 'ACOIN', 'website_slug': 'acoin'},
#  {'id': 606,
#   'name': 'FoldingCoin',
#   'symbol': 'FLDC',
#   'website_slug': 'foldingcoin'},
#  {'id': 623, 'name': 'bitUSD', 'symbol': 'BITUSD', 'website_slug': 'bitusd'},
#  {'id': 624, 'name': 'bitCNY', 'symbol': 'BITCNY', 'website_slug': 'bitcny'},
#  {'id': 625, 'name': 'bitBTC', 'symbol': 'BITBTC', 'website_slug': 'bitbtc'},
#  {'id': 626, 'name': 'NuBits', 'symbol': 'USNBT', 'website_slug': 'nubits'},
#  {'id': 627,
#   'name': 'Sterlingcoin',
#   'symbol': 'SLG',
#   'website_slug': 'sterlingcoin'},
#  {'id': 629, 'name': 'Magi', 'symbol': 'XMG', 'website_slug': 'magi'},
#  {'id': 633,
#   'name': 'ExclusiveCoin',
#   'symbol': 'EXCL',
#   'website_slug': 'exclusivecoin'},
#  {'id': 638,
#   'name': 'Trollcoin',
#   'symbol': 'TROLL',
#   'website_slug': 'trollcoin'},
#  {'id': 643,
#   'name': 'SuperNET',
#   'symbol': 'UNITY',
#   'website_slug': 'supernet-unity'},
#  {'id': 644,
#   'name': 'GlobalBoost-Y',
#   'symbol': 'BSTY',
#   'website_slug': 'globalboost-y'},
#  {'id': 654,
#   'name': 'DigitalPrice',
#   'symbol': 'DP',
#   'website_slug': 'digitalprice'},
#  {'id': 656, 'name': 'Prime-XI', 'symbol': 'PXI', 'website_slug': 'prime-xi'},
#  {'id': 659,
#   'name': 'Bitswift',
#   'symbol': 'SWIFT',
#   'website_slug': 'bitswift'},
#  {'id': 660, 'name': 'Dashcoin', 'symbol': 'DSH', 'website_slug': 'dashcoin'},
#  {'id': 666, 'name': 'AurumCoin', 'symbol': 'AU', 'website_slug': 'aurumcoin'},
#  {'id': 671, 'name': 'GAIA', 'symbol': 'GAIA', 'website_slug': 'gaia'},
#  {'id': 680,
#   'name': 'Sativacoin',
#   'symbol': 'STV',
#   'website_slug': 'sativacoin'},
#  {'id': 692,
#   'name': 'GanjaCoin',
#   'symbol': 'MRJA',
#   'website_slug': 'ganjacoin'},
#  {'id': 693, 'name': 'Verge', 'symbol': 'XVG', 'website_slug': 'verge'},
#  {'id': 699, 'name': 'NuShares', 'symbol': 'NSR', 'website_slug': 'nushares'},
#  {'id': 702,
#   'name': 'SpreadCoin',
#   'symbol': 'SPR',
#   'website_slug': 'spreadcoin'},
#  {'id': 703, 'name': 'Rimbit', 'symbol': 'RBT', 'website_slug': 'rimbit'},
#  {'id': 706,
#   'name': 'MonetaryUnit',
#   'symbol': 'MUE',
#   'website_slug': 'monetaryunit'},
#  {'id': 707,
#   'name': 'Blocknet',
#   'symbol': 'BLOCK',
#   'website_slug': 'blocknet'},
#  {'id': 708, 'name': 'Gapcoin', 'symbol': 'GAP', 'website_slug': 'gapcoin'},
#  {'id': 719,
#   'name': 'TittieCoin',
#   'symbol': 'TTC',
#   'website_slug': 'tittiecoin'},
#  {'id': 720, 'name': 'Crown', 'symbol': 'CRW', 'website_slug': 'crown'},
#  {'id': 723, 'name': 'BitBay', 'symbol': 'BAY', 'website_slug': 'bitbay'},
#  {'id': 729,
#   'name': 'Blitzcash',
#   'symbol': 'BLITZ',
#   'website_slug': 'blitzcash'},
#  {'id': 730, 'name': 'GCN Coin', 'symbol': 'GCN', 'website_slug': 'gcn-coin'},
#  {'id': 733, 'name': 'Quotient', 'symbol': 'XQN', 'website_slug': 'quotient'},
#  {'id': 734, 'name': 'Bytecent', 'symbol': 'BYC', 'website_slug': 'bytecent'},
#  {'id': 747,
#   'name': 'Bitcoin Fast',
#   'symbol': 'BCF',
#   'website_slug': 'bitcoinfast'},
#  {'id': 760, 'name': 'OKCash', 'symbol': 'OK', 'website_slug': 'okcash'},
#  {'id': 764, 'name': 'PayCoin', 'symbol': 'XPY', 'website_slug': 'paycoin2'},
#  {'id': 766, 'name': 'vTorrent', 'symbol': 'VTR', 'website_slug': 'vtorrent'},
#  {'id': 778,
#   'name': 'bitGold',
#   'symbol': 'BITGOLD',
#   'website_slug': 'bitgold'},
#  {'id': 781, 'name': 'Unitus', 'symbol': 'UIS', 'website_slug': 'unitus'},
#  {'id': 785,
#   'name': 'GoldPieces',
#   'symbol': 'GP',
#   'website_slug': 'goldpieces'},
#  {'id': 788,
#   'name': 'Circuits of Value',
#   'symbol': 'COVAL',
#   'website_slug': 'circuits-of-value'},
#  {'id': 789, 'name': 'Nexus', 'symbol': 'NXS', 'website_slug': 'nexus'},
#  {'id': 795, 'name': 'SoonCoin', 'symbol': 'SOON', 'website_slug': 'sooncoin'},
#  {'id': 796,
#   'name': 'MetalCoin',
#   'symbol': 'METAL',
#   'website_slug': 'metalcoin'},
#  {'id': 797, 'name': 'IncaKoin', 'symbol': 'NKA', 'website_slug': 'incakoin'},
#  {'id': 799,
#   'name': 'SmileyCoin',
#   'symbol': 'SMLY',
#   'website_slug': 'smileycoin'},
#  {'id': 804,
#   'name': 'AmberCoin',
#   'symbol': 'AMBER',
#   'website_slug': 'ambercoin'},
#  {'id': 812,
#   'name': 'Machinecoin',
#   'symbol': 'MAC',
#   'website_slug': 'machinecoin'},
#  {'id': 813,
#   'name': 'bitSilver',
#   'symbol': 'BITSILVER',
#   'website_slug': 'bitsilver'},
#  {'id': 814, 'name': 'Dotcoin', 'symbol': 'DOT', 'website_slug': 'dotcoin'},
#  {'id': 815, 'name': 'Kobocoin', 'symbol': 'KOBO', 'website_slug': 'kobocoin'},
#  {'id': 818, 'name': 'PayCon', 'symbol': 'CON', 'website_slug': 'paycon'},
#  {'id': 819,
#   'name': 'Bean Cash',
#   'symbol': 'BITB',
#   'website_slug': 'bean-cash'},
#  {'id': 823, 'name': 'GeoCoin', 'symbol': 'GEO', 'website_slug': 'geocoin'},
#  {'id': 825, 'name': 'Tether', 'symbol': 'USDT', 'website_slug': 'tether'},
#  {'id': 831,
#   'name': 'Wild Beast Block',
#   'symbol': 'WBB',
#   'website_slug': 'wild-beast-block'},
#  {'id': 833, 'name': 'GridCoin', 'symbol': 'GRC', 'website_slug': 'gridcoin'},
#  {'id': 836, 'name': 'Vcash', 'symbol': 'XVC', 'website_slug': 'vcash'},
#  {'id': 837, 'name': 'X-Coin', 'symbol': 'XCO', 'website_slug': 'x-coin'},
#  {'id': 841,
#   'name': 'Sharkcoin',
#   'symbol': 'SAK',
#   'website_slug': 'sharkcoin'},
#  {'id': 842, 'name': 'Bitz', 'symbol': 'BITZ', 'website_slug': 'bitz'},
#  {'id': 853,
#   'name': 'LiteDoge',
#   'symbol': 'LDOGE',
#   'website_slug': 'litedoge'},
#  {'id': 855, 'name': 'UNCoin', 'symbol': 'UNC', 'website_slug': 'uncoin'},
#  {'id': 857, 'name': 'SongCoin', 'symbol': 'SONG', 'website_slug': 'songcoin'},
#  {'id': 859, 'name': 'Woodcoin', 'symbol': 'LOG', 'website_slug': 'woodcoin'},
#  {'id': 865,
#   'name': 'Selfiecoin',
#   'symbol': 'SLFI',
#   'website_slug': 'selfiecoin'},
#  {'id': 869, 'name': 'Crave', 'symbol': 'CRAVE', 'website_slug': 'crave'},
#  {'id': 870, 'name': 'Pura', 'symbol': 'PURA', 'website_slug': 'pura'},
#  {'id': 873, 'name': 'NEM', 'symbol': 'XEM', 'website_slug': 'nem'},
#  {'id': 876,
#   'name': 'TrickyCoin',
#   'symbol': 'TRICK',
#   'website_slug': 'trickycoin'},
#  {'id': 878, 'name': 'CyberCoin', 'symbol': 'CC', 'website_slug': 'cybercoin'},
#  {'id': 884, 'name': 'P7Coin', 'symbol': 'P7C', 'website_slug': 'p7coin'},
#  {'id': 890, 'name': '8Bit', 'symbol': '8BIT', 'website_slug': '8bit'},
#  {'id': 892, 'name': 'LeaCoin', 'symbol': 'LEA', 'website_slug': 'leacoin'},
#  {'id': 894, 'name': 'Neutron', 'symbol': 'NTRN', 'website_slug': 'neutron'},
#  {'id': 895, 'name': 'Xaurum', 'symbol': 'XAUR', 'website_slug': 'xaurum'},
#  {'id': 898,
#   'name': 'Californium',
#   'symbol': 'CF',
#   'website_slug': 'californium'},
#  {'id': 911,
#   'name': 'Advanced Internet Blocks',
#   'symbol': 'AIB',
#   'website_slug': 'advanced-internet-blocks'},
#  {'id': 912, 'name': 'EggCoin', 'symbol': 'EGG', 'website_slug': 'eggcoin'},
#  {'id': 914, 'name': 'Sphere', 'symbol': 'SPHR', 'website_slug': 'sphere'},
#  {'id': 916,
#   'name': 'MedicCoin',
#   'symbol': 'MEDIC',
#   'website_slug': 'mediccoin'},
#  {'id': 918, 'name': 'Bubble', 'symbol': 'BUB', 'website_slug': 'bubble'},
#  {'id': 920,
#   'name': 'MUSE',
#   'symbol': 'MUSE',
#   'website_slug': 'bitshares-music'},
#  {'id': 921,
#   'name': 'Universal Currency',
#   'symbol': 'UNIT',
#   'website_slug': 'universal-currency'},
#  {'id': 924,
#   'name': 'ShellCoin',
#   'symbol': 'SHELL',
#   'website_slug': 'shellcoin'},
#  {'id': 933, 'name': 'Crypto', 'symbol': 'CTO', 'website_slug': 'crypto'},
#  {'id': 934, 'name': 'ParkByte', 'symbol': 'PKB', 'website_slug': 'parkbyte'},
#  {'id': 938, 'name': 'ARbit', 'symbol': 'ARB', 'website_slug': 'arbit'},
#  {'id': 939, 'name': 'Gambit', 'symbol': 'GAM', 'website_slug': 'gambit'},
#  {'id': 945, 'name': 'Bata', 'symbol': 'BTA', 'website_slug': 'bata'},
#  {'id': 948,
#   'name': 'AudioCoin',
#   'symbol': 'ADC',
#   'website_slug': 'audiocoin'},
#  {'id': 951, 'name': 'Synergy', 'symbol': 'SNRG', 'website_slug': 'synergy'},
#  {'id': 954, 'name': 'bitEUR', 'symbol': 'BITEUR', 'website_slug': 'biteur'},
#  {'id': 959, 'name': 'UniCoin', 'symbol': 'UNIC', 'website_slug': 'unicoin'},
#  {'id': 960, 'name': 'FujiCoin', 'symbol': 'FJC', 'website_slug': 'fujicoin'},
#  {'id': 964,
#   'name': 'EuropeCoin',
#   'symbol': 'ERC',
#   'website_slug': 'europecoin'},
#  {'id': 965,
#   'name': 'The Cypherfunks',
#   'symbol': 'FUNK',
#   'website_slug': 'the-cypherfunks'},
#  {'id': 977, 'name': 'Hexx', 'symbol': 'HXX', 'website_slug': 'hexx'},
#  {'id': 978, 'name': 'Ratecoin', 'symbol': 'XRA', 'website_slug': 'ratecoin'},
#  {'id': 983,
#   'name': 'Metal Music Coin',
#   'symbol': 'MTLMC3',
#   'website_slug': 'metal-music-coin'},
#  {'id': 986,
#   'name': 'CrevaCoin',
#   'symbol': 'CREVA',
#   'website_slug': 'crevacoin'},
#  {'id': 988,
#   'name': 'IrishCoin',
#   'symbol': 'IRL',
#   'website_slug': 'irishcoin'},
#  {'id': 990, 'name': 'Bitzeny', 'symbol': 'ZNY', 'website_slug': 'bitzeny'},
#  {'id': 992,
#   'name': 'Cycling Coin',
#   'symbol': 'CYC',
#   'website_slug': 'cycling-coin'},
#  {'id': 993, 'name': 'BowsCoin', 'symbol': 'BSC', 'website_slug': 'bowscoin'},
#  {'id': 994,
#   'name': 'AnarchistsPrime',
#   'symbol': 'ACP',
#   'website_slug': 'anarchistsprime'},
#  {'id': 997, 'name': 'TAGRcoin', 'symbol': 'TAGR', 'website_slug': 'tagrcoin'},
#  {'id': 998,
#   'name': 'CompuCoin',
#   'symbol': 'CPN',
#   'website_slug': 'compucoin'},
#  {'id': 999,
#   'name': 'ChainCoin',
#   'symbol': 'CHC',
#   'website_slug': 'chaincoin'},
#  {'id': 1002, 'name': 'Sprouts', 'symbol': 'SPRTS', 'website_slug': 'sprouts'},
#  {'id': 1004,
#   'name': 'Helleniccoin',
#   'symbol': 'HNC',
#   'website_slug': 'helleniccoin'},
#  {'id': 1006, 'name': 'FutCoin', 'symbol': 'FUTC', 'website_slug': 'futcoin'},
#  {'id': 1008,
#   'name': 'Capricoin',
#   'symbol': 'CPC',
#   'website_slug': 'capricoin'},
#  {'id': 1010,
#   'name': 'Flaxscript',
#   'symbol': 'FLAX',
#   'website_slug': 'flaxscript'},
#  {'id': 1011,
#   'name': 'Cthulhu Offerings',
#   'symbol': 'OFF',
#   'website_slug': 'cthulhu-offerings'},
#  {'id': 1018,
#   'name': 'BiosCrypto',
#   'symbol': 'BIOS',
#   'website_slug': 'bios-crypto'},
#  {'id': 1019, 'name': 'Manna', 'symbol': 'MANNA', 'website_slug': 'manna'},
#  {'id': 1020, 'name': 'Axiom', 'symbol': 'AXIOM', 'website_slug': 'axiom'},
#  {'id': 1022, 'name': 'LEOcoin', 'symbol': 'LEO', 'website_slug': 'leocoin'},
#  {'id': 1026, 'name': 'Aeon', 'symbol': 'AEON', 'website_slug': 'aeon'},
#  {'id': 1027, 'name': 'Ethereum', 'symbol': 'ETH', 'website_slug': 'ethereum'},
#  {'id': 1028, 'name': 'SJWCoin', 'symbol': 'SJW', 'website_slug': 'sjwcoin'},
#  {'id': 1032,
#   'name': 'TransferCoin',
#   'symbol': 'TX',
#   'website_slug': 'transfercoin'},
#  {'id': 1033,
#   'name': 'GuccioneCoin',
#   'symbol': 'GCC',
#   'website_slug': 'guccionecoin'},
#  {'id': 1035,
#   'name': 'AmsterdamCoin',
#   'symbol': 'AMS',
#   'website_slug': 'amsterdamcoin'},
#  {'id': 1038, 'name': 'Eurocoin', 'symbol': 'EUC', 'website_slug': 'eurocoin'},
#  {'id': 1042, 'name': 'Siacoin', 'symbol': 'SC', 'website_slug': 'siacoin'},
#  {'id': 1044,
#   'name': 'Global Currency Reserve',
#   'symbol': 'GCR',
#   'website_slug': 'global-currency-reserve'},
#  {'id': 1045,
#   'name': 'DeltaCredits',
#   'symbol': 'DCRE',
#   'website_slug': 'deltacredits'},
#  {'id': 1048,
#   'name': 'SatoshiMadness',
#   'symbol': 'MAD',
#   'website_slug': 'satoshimadness'},
#  {'id': 1050, 'name': 'Shift', 'symbol': 'SHIFT', 'website_slug': 'shift'},
#  {'id': 1052, 'name': 'VectorAI', 'symbol': 'VEC2', 'website_slug': 'vector'},
#  {'id': 1053,
#   'name': 'Bolivarcoin',
#   'symbol': 'BOLI',
#   'website_slug': 'bolivarcoin'},
#  {'id': 1058,
#   'name': 'SpaceCoin',
#   'symbol': 'SPACE',
#   'website_slug': 'spacecoin'},
#  {'id': 1062, 'name': 'Flycoin', 'symbol': 'FLY', 'website_slug': 'flycoin'},
#  {'id': 1063,
#   'name': 'Bitcrystals',
#   'symbol': 'BCY',
#   'website_slug': 'bitcrystals'},
#  {'id': 1065,
#   'name': 'Fonziecoin',
#   'symbol': 'FONZ',
#   'website_slug': 'fonziecoin'},
#  {'id': 1066, 'name': 'Pakcoin', 'symbol': 'PAK', 'website_slug': 'pakcoin'},
#  {'id': 1069,
#   'name': 'Influxcoin',
#   'symbol': 'INFX',
#   'website_slug': 'influxcoin'},
#  {'id': 1070, 'name': 'Expanse', 'symbol': 'EXP', 'website_slug': 'expanse'},
#  {'id': 1073, 'name': 'Steps', 'symbol': 'STEPS', 'website_slug': 'steps'},
#  {'id': 1082, 'name': 'SIBCoin', 'symbol': 'SIB', 'website_slug': 'sibcoin'},
#  {'id': 1084, 'name': 'IslaCoin', 'symbol': 'ISL', 'website_slug': 'islacoin'},
#  {'id': 1085, 'name': 'Swing', 'symbol': 'SWING', 'website_slug': 'swing'},
#  {'id': 1087, 'name': 'Factom', 'symbol': 'FCT', 'website_slug': 'factom'},
#  {'id': 1089,
#   'name': 'ParallelCoin',
#   'symbol': 'DUO',
#   'website_slug': 'parallelcoin'},
#  {'id': 1090,
#   'name': 'Save and Gain',
#   'symbol': 'SANDG',
#   'website_slug': 'save-and-gain'},
#  {'id': 1093,
#   'name': 'Prototanium',
#   'symbol': 'PR',
#   'website_slug': 'prototanium'},
#  {'id': 1096,
#   'name': 'OsmiumCoin',
#   'symbol': 'OS76',
#   'website_slug': 'osmiumcoin'},
#  {'id': 1099, 'name': 'Moneta', 'symbol': 'MONETA', 'website_slug': 'moneta2'},
#  {'id': 1100,
#   'name': 'DigiCube',
#   'symbol': 'CUBE',
#   'website_slug': 'digicube'},
#  {'id': 1104, 'name': 'Augur', 'symbol': 'REP', 'website_slug': 'augur'},
#  {'id': 1106,
#   'name': 'StrongHands',
#   'symbol': 'SHND',
#   'website_slug': 'stronghands'},
#  {'id': 1107, 'name': 'PACcoin', 'symbol': '$PAC', 'website_slug': 'paccoin'},
#  {'id': 1109, 'name': 'Elite', 'symbol': '1337', 'website_slug': '1337coin'},
#  {'id': 1110, 'name': 'Money', 'symbol': '$$$', 'website_slug': 'money'},
#  {'id': 1111,
#   'name': 'SOILcoin',
#   'symbol': 'SOIL',
#   'website_slug': 'soilcoin'},
#  {'id': 1113,
#   'name': 'SecretCoin',
#   'symbol': 'SCRT',
#   'website_slug': 'secretcoin'},
#  {'id': 1120,
#   'name': 'DraftCoin',
#   'symbol': 'DFT',
#   'website_slug': 'draftcoin'},
#  {'id': 1123, 'name': 'OBITS', 'symbol': 'OBITS', 'website_slug': 'obits'},
#  {'id': 1125, 'name': 'Synereo', 'symbol': 'AMP', 'website_slug': 'synereo'},
#  {'id': 1128,
#   'name': 'GBCGoldCoin',
#   'symbol': 'GBC',
#   'website_slug': 'gbcgoldcoin'},
#  {'id': 1131, 'name': 'X2', 'symbol': 'X2', 'website_slug': 'x2'},
#  {'id': 1135,
#   'name': 'ClubCoin',
#   'symbol': 'CLUB',
#   'website_slug': 'clubcoin'},
#  {'id': 1136, 'name': 'Adzcoin', 'symbol': 'ADZ', 'website_slug': 'adzcoin'},
#  {'id': 1139, 'name': 'MindCoin', 'symbol': 'MND', 'website_slug': 'mindcoin'},
#  {'id': 1141, 'name': 'Moin', 'symbol': 'MOIN', 'website_slug': 'moin'},
#  {'id': 1146,
#   'name': 'AvatarCoin',
#   'symbol': 'AV',
#   'website_slug': 'avatarcoin'},
#  {'id': 1147,
#   'name': 'RussiaCoin',
#   'symbol': 'RC',
#   'website_slug': 'russiacoin'},
#  {'id': 1148,
#   'name': 'EverGreenCoin',
#   'symbol': 'EGC',
#   'website_slug': 'evergreencoin'},
#  {'id': 1151,
#   'name': 'Opescoin',
#   'symbol': 'OPES',
#   'website_slug': 'opescoin'},
#  {'id': 1153,
#   'name': 'Creditbit',
#   'symbol': 'CRB',
#   'website_slug': 'creditbit'},
#  {'id': 1154, 'name': 'Radium', 'symbol': 'RADS', 'website_slug': 'radium'},
#  {'id': 1155,
#   'name': 'Litecred',
#   'symbol': 'LTCR',
#   'website_slug': 'litecred'},
#  {'id': 1156, 'name': 'Yocoin', 'symbol': 'YOC', 'website_slug': 'yocoin'},
#  {'id': 1157, 'name': 'AlpaCoin', 'symbol': 'APC', 'website_slug': 'alpacoin'},
#  {'id': 1159, 'name': 'SaluS', 'symbol': 'SLS', 'website_slug': 'salus'},
#  {'id': 1164, 'name': 'Francs', 'symbol': 'FRN', 'website_slug': 'francs'},
#  {'id': 1165,
#   'name': 'Evil Coin',
#   'symbol': 'EVIL',
#   'website_slug': 'evil-coin'},
#  {'id': 1166, 'name': 'WARP', 'symbol': 'WARP', 'website_slug': 'warp'},
#  {'id': 1168, 'name': 'Decred', 'symbol': 'DCR', 'website_slug': 'decred'},
#  {'id': 1169, 'name': 'PIVX', 'symbol': 'PIVX', 'website_slug': 'pivx'},
#  {'id': 1172,
#   'name': 'Safe Exchange Coin',
#   'symbol': 'SAFEX',
#   'website_slug': 'safe-exchange-coin'},
#  {'id': 1173,
#   'name': 'HempCoin',
#   'symbol': 'HMP',
#   'website_slug': 'hempcoin-hmp'},
#  {'id': 1175, 'name': 'Rubies', 'symbol': 'RBIES', 'website_slug': 'rubies'},
#  {'id': 1176,
#   'name': 'Asiadigicoin',
#   'symbol': 'ADCN',
#   'website_slug': 'asiadigicoin'},
#  {'id': 1180, 'name': 'Destiny', 'symbol': 'DES', 'website_slug': 'destiny'},
#  {'id': 1182, 'name': 'KiloCoin', 'symbol': 'KLC', 'website_slug': 'kilocoin'},
#  {'id': 1184,
#   'name': 'SproutsExtreme',
#   'symbol': 'SPEX',
#   'website_slug': 'sproutsextreme'},
#  {'id': 1185,
#   'name': 'TrumpCoin',
#   'symbol': 'TRUMP',
#   'website_slug': 'trumpcoin'},
#  {'id': 1187,
#   'name': 'VIP Tokens',
#   'symbol': 'VIP',
#   'website_slug': 'vip-tokens'},
#  {'id': 1191,
#   'name': 'Memetic / PepeCoin',
#   'symbol': 'MEME',
#   'website_slug': 'memetic'},
#  {'id': 1192, 'name': 'Pulse', 'symbol': 'PULSE', 'website_slug': 'pulse'},
#  {'id': 1193, 'name': 'C-Bit', 'symbol': 'XCT', 'website_slug': 'c-bit'},
#  {'id': 1194,
#   'name': 'Independent Money System',
#   'symbol': 'IMS',
#   'website_slug': 'independent-money-system'},
#  {'id': 1195,
#   'name': 'HOdlcoin',
#   'symbol': 'HODL',
#   'website_slug': 'hodlcoin'},
#  {'id': 1198, 'name': 'BigUp', 'symbol': 'BIGUP', 'website_slug': 'bigup'},
#  {'id': 1200,
#   'name': 'NevaCoin',
#   'symbol': 'NEVA',
#   'website_slug': 'nevacoin'},
#  {'id': 1206,
#   'name': 'BumbaCoin',
#   'symbol': 'BUMBA',
#   'website_slug': 'bumbacoin'},
#  {'id': 1208,
#   'name': 'RevolutionVR',
#   'symbol': 'RVR',
#   'website_slug': 'revolutionvr'},
#  {'id': 1209, 'name': 'PosEx', 'symbol': 'PEX', 'website_slug': 'posex'},
#  {'id': 1210, 'name': 'Cabbage', 'symbol': 'CAB', 'website_slug': 'cabbage'},
#  {'id': 1212,
#   'name': 'MojoCoin',
#   'symbol': 'MOJO',
#   'website_slug': 'mojocoin'},
#  {'id': 1213,
#   'name': 'GoldMaxCoin',
#   'symbol': 'GMX',
#   'website_slug': 'goldmaxcoin'},
#  {'id': 1214, 'name': 'Lisk', 'symbol': 'LSK', 'website_slug': 'lisk'},
#  {'id': 1216, 'name': 'EDRCoin', 'symbol': 'EDRC', 'website_slug': 'edrcoin'},
#  {'id': 1218,
#   'name': 'PostCoin',
#   'symbol': 'POST',
#   'website_slug': 'postcoin'},
#  {'id': 1220, 'name': 'HitCoin', 'symbol': 'HTC', 'website_slug': 'hitcoin'},
#  {'id': 1222, 'name': 'Operand', 'symbol': 'OP', 'website_slug': 'operand'},
#  {'id': 1223,
#   'name': 'BERNcash',
#   'symbol': 'BERN',
#   'website_slug': 'berncash'},
#  {'id': 1226, 'name': 'Qwark', 'symbol': 'QWARK', 'website_slug': 'qwark'},
#  {'id': 1229, 'name': 'DigixDAO', 'symbol': 'DGD', 'website_slug': 'digixdao'},
#  {'id': 1230, 'name': 'Steem', 'symbol': 'STEEM', 'website_slug': 'steem'},
#  {'id': 1234,
#   'name': 'Fantasy Cash',
#   'symbol': 'FANS',
#   'website_slug': 'fantasy-cash'},
#  {'id': 1238, 'name': 'Espers', 'symbol': 'ESP', 'website_slug': 'espers'},
#  {'id': 1241,
#   'name': 'FuzzBalls',
#   'symbol': 'FUZZ',
#   'website_slug': 'fuzzballs'},
#  {'id': 1243,
#   'name': 'DarkLisk',
#   'symbol': 'DISK',
#   'website_slug': 'darklisk'},
#  {'id': 1244, 'name': 'HiCoin', 'symbol': 'XHI', 'website_slug': 'hicoin'},
#  {'id': 1247,
#   'name': 'AquariusCoin',
#   'symbol': 'ARCO',
#   'website_slug': 'aquariuscoin'},
#  {'id': 1248,
#   'name': 'Bitcoin 21',
#   'symbol': 'XBTC21',
#   'website_slug': 'bitcoin-21'},
#  {'id': 1249, 'name': 'Elcoin', 'symbol': 'EL', 'website_slug': 'elcoin-el'},
#  {'id': 1250, 'name': 'Zurcoin', 'symbol': 'ZUR', 'website_slug': 'zurcoin'},
#  {'id': 1251,
#   'name': 'SixEleven',
#   'symbol': '611',
#   'website_slug': 'sixeleven'},
#  {'id': 1252, 'name': '2GIVE', 'symbol': '2GIVE', 'website_slug': '2give'},
#  {'id': 1254,
#   'name': 'PlatinumBAR',
#   'symbol': 'XPTX',
#   'website_slug': 'platinumbar'},
#  {'id': 1256,
#   'name': 'Alphabit',
#   'symbol': 'ABC',
#   'website_slug': 'alphabitcoinfund'},
#  {'id': 1257,
#   'name': 'LanaCoin',
#   'symbol': 'LANA',
#   'website_slug': 'lanacoin'},
#  {'id': 1259,
#   'name': 'PonziCoin',
#   'symbol': 'PONZI',
#   'website_slug': 'ponzicoin'},
#  {'id': 1264,
#   'name': 'TeslaCoilCoin',
#   'symbol': 'TESLA',
#   'website_slug': 'teslacoilcoin'},
#  {'id': 1266,
#   'name': 'MarteXcoin',
#   'symbol': 'MXT',
#   'website_slug': 'martexcoin'},
#  {'id': 1268, 'name': 'Nullex', 'symbol': 'NLX', 'website_slug': 'nullex'},
#  {'id': 1269,
#   'name': 'RichCoin',
#   'symbol': 'RICHX',
#   'website_slug': 'richcoin'},
#  {'id': 1271,
#   'name': 'PrismChain',
#   'symbol': 'PRM',
#   'website_slug': 'prismchain'},
#  {'id': 1274, 'name': 'Waves', 'symbol': 'WAVES', 'website_slug': 'waves'},
#  {'id': 1275, 'name': 'Newbium', 'symbol': 'NEWB', 'website_slug': 'newbium'},
#  {'id': 1276,
#   'name': 'ICO OpenLedger',
#   'symbol': 'ICOO',
#   'website_slug': 'ico-openledger'},
#  {'id': 1281, 'name': 'ION', 'symbol': 'ION', 'website_slug': 'ion'},
#  {'id': 1282,
#   'name': 'High Voltage',
#   'symbol': 'HVCO',
#   'website_slug': 'high-voltage'},
#  {'id': 1283, 'name': 'Mineum', 'symbol': 'MNM', 'website_slug': 'mineum'},
#  {'id': 1284,
#   'name': 'RevolverCoin',
#   'symbol': 'XRE',
#   'website_slug': 'revolvercoin'},
#  {'id': 1285,
#   'name': 'GoldBlocks',
#   'symbol': 'GB',
#   'website_slug': 'goldblocks'},
#  {'id': 1286, 'name': 'Breakout', 'symbol': 'BRK', 'website_slug': 'breakout'},
#  {'id': 1288,
#   'name': 'Debitcoin',
#   'symbol': 'DBTC',
#   'website_slug': 'debitcoin'},
#  {'id': 1291, 'name': 'Comet', 'symbol': 'CMT', 'website_slug': 'comet'},
#  {'id': 1294, 'name': 'Rise', 'symbol': 'RISE', 'website_slug': 'rise'},
#  {'id': 1297,
#   'name': 'ChessCoin',
#   'symbol': 'CHESS',
#   'website_slug': 'chesscoin'},
#  {'id': 1298,
#   'name': 'LBRY Credits',
#   'symbol': 'LBC',
#   'website_slug': 'library-credit'},
#  {'id': 1299,
#   'name': 'PutinCoin',
#   'symbol': 'PUT',
#   'website_slug': 'putincoin'},
#  {'id': 1301,
#   'name': 'Happy Creator Coin',
#   'symbol': 'HCC',
#   'website_slug': 'happy-creator-coin'},
#  {'id': 1303,
#   'name': 'Breakout Stake',
#   'symbol': 'BRX',
#   'website_slug': 'breakout-stake'},
#  {'id': 1304,
#   'name': 'Syndicate',
#   'symbol': 'SYNX',
#   'website_slug': 'syndicate'},
#  {'id': 1306,
#   'name': 'Cryptojacks',
#   'symbol': 'CJ',
#   'website_slug': 'cryptojacks'},
#  {'id': 1307, 'name': 'ReeCoin', 'symbol': 'REE', 'website_slug': 'reecoin'},
#  {'id': 1308, 'name': 'HEAT', 'symbol': 'HEAT', 'website_slug': 'heat-ledger'},
#  {'id': 1309,
#   'name': 'LetItRide',
#   'symbol': 'LIR',
#   'website_slug': 'letitride'},
#  {'id': 1310,
#   'name': 'DAPPSTER',
#   'symbol': 'DLISK',
#   'website_slug': 'dappster'},
#  {'id': 1312,
#   'name': 'Steem Dollars',
#   'symbol': 'SBD',
#   'website_slug': 'steem-dollars'},
#  {'id': 1313,
#   'name': 'LinkedCoin',
#   'symbol': 'LKC',
#   'website_slug': 'linkedcoin'},
#  {'id': 1315, 'name': 'Chronos', 'symbol': 'CRX', 'website_slug': 'chronos'},
#  {'id': 1320, 'name': 'Ardor', 'symbol': 'ARDR', 'website_slug': 'ardor'},
#  {'id': 1321,
#   'name': 'Ethereum Classic',
#   'symbol': 'ETC',
#   'website_slug': 'ethereum-classic'},
#  {'id': 1322, 'name': '808Coin', 'symbol': '808', 'website_slug': '808coin'},
#  {'id': 1323,
#   'name': 'First Bitcoin',
#   'symbol': 'BIT',
#   'website_slug': 'first-bitcoin'},
#  {'id': 1330,
#   'name': 'PokeCoin',
#   'symbol': 'POKE',
#   'website_slug': 'pokecoin'},
#  {'id': 1334,
#   'name': 'Elementrem',
#   'symbol': 'ELE',
#   'website_slug': 'elementrem'},
#  {'id': 1336, 'name': 'UGAIN', 'symbol': 'GAIN', 'website_slug': 'ugain'},
#  {'id': 1340, 'name': 'Karbo', 'symbol': 'KRB', 'website_slug': 'karbo'},
#  {'id': 1341,
#   'name': 'VapersCoin',
#   'symbol': 'VPRC',
#   'website_slug': 'vaperscoin'},
#  {'id': 1343, 'name': 'Stratis', 'symbol': 'STRAT', 'website_slug': 'stratis'},
#  {'id': 1347, 'name': 'Zonecoin', 'symbol': 'ZNE', 'website_slug': 'zonecoin'},
#  {'id': 1348,
#   'name': 'President Trump',
#   'symbol': 'PRES',
#   'website_slug': 'president-trump'},
#  {'id': 1351, 'name': 'Aces', 'symbol': 'ACES', 'website_slug': 'aces'},
#  {'id': 1352,
#   'name': 'President Johnson',
#   'symbol': 'GARY',
#   'website_slug': 'president-johnson'},
#  {'id': 1353, 'name': 'TajCoin', 'symbol': 'TAJ', 'website_slug': 'tajcoin'},
#  {'id': 1355,
#   'name': 'PizzaCoin',
#   'symbol': 'PIZZA',
#   'website_slug': 'pizzacoin'},
#  {'id': 1356,
#   'name': 'TodayCoin',
#   'symbol': 'TODAY',
#   'website_slug': 'todaycoin'},
#  {'id': 1357, 'name': 'PX', 'symbol': 'PX', 'website_slug': 'px'},
#  {'id': 1358,
#   'name': 'E-Dinar Coin',
#   'symbol': 'EDR',
#   'website_slug': 'e-dinar-coin'},
#  {'id': 1359,
#   'name': 'BitTokens',
#   'symbol': 'BXT',
#   'website_slug': 'bittokens'},
#  {'id': 1360,
#   'name': 'TechShares',
#   'symbol': 'THS',
#   'website_slug': 'techshares'},
#  {'id': 1361,
#   'name': 'Artex Coin',
#   'symbol': 'ATX',
#   'website_slug': 'artex-coin'},
#  {'id': 1366,
#   'name': 'AgrolifeCoin',
#   'symbol': 'AGLC',
#   'website_slug': 'agrolifecoin'},
#  {'id': 1367,
#   'name': 'Experience Points',
#   'symbol': 'XP',
#   'website_slug': 'experience-points'},
#  {'id': 1368, 'name': 'Veltor', 'symbol': 'VLT', 'website_slug': 'veltor'},
#  {'id': 1371, 'name': 'B3Coin', 'symbol': 'KB3', 'website_slug': 'b3coin'},
#  {'id': 1374,
#   'name': 'BlockPay',
#   'symbol': 'BLOCKPAY',
#   'website_slug': 'blockpay'},
#  {'id': 1375,
#   'name': 'Golfcoin',
#   'symbol': 'GOLF',
#   'website_slug': 'golfcoin'},
#  {'id': 1376, 'name': 'NEO', 'symbol': 'NEO', 'website_slug': 'neo'},
#  {'id': 1379, 'name': 'Jewels', 'symbol': 'JWL', 'website_slug': 'jewels'},
#  {'id': 1380, 'name': 'LoMoCoin', 'symbol': 'LMC', 'website_slug': 'lomocoin'},
#  {'id': 1381,
#   'name': 'Bitcloud',
#   'symbol': 'BTDX',
#   'website_slug': 'bitcloud'},
#  {'id': 1382,
#   'name': 'NoLimitCoin',
#   'symbol': 'NLC2',
#   'website_slug': 'nolimitcoin'},
#  {'id': 1385,
#   'name': 'SportsCoin',
#   'symbol': 'SPORT',
#   'website_slug': 'sportscoin'},
#  {'id': 1387,
#   'name': 'VeriumReserve',
#   'symbol': 'VRM',
#   'website_slug': 'veriumreserve'},
#  {'id': 1389,
#   'name': 'Zayedcoin',
#   'symbol': 'ZYD',
#   'website_slug': 'zayedcoin'},
#  {'id': 1390, 'name': 'Jin Coin', 'symbol': 'JIN', 'website_slug': 'jin-coin'},
#  {'id': 1391, 'name': 'Tao', 'symbol': 'XTO', 'website_slug': 'tao'},
#  {'id': 1392, 'name': 'Pluton', 'symbol': 'PLU', 'website_slug': 'pluton'},
#  {'id': 1393,
#   'name': 'Tellurion',
#   'symbol': 'TELL',
#   'website_slug': 'tellurion'},
#  {'id': 1394, 'name': 'Shilling', 'symbol': 'SH', 'website_slug': 'shilling'},
#  {'id': 1395,
#   'name': 'Dollarcoin',
#   'symbol': 'DLC',
#   'website_slug': 'dollarcoin'},
#  {'id': 1396,
#   'name': 'MustangCoin',
#   'symbol': 'MST',
#   'website_slug': 'mustangcoin'},
#  {'id': 1397,
#   'name': 'Beatcoin',
#   'symbol': 'XBTS',
#   'website_slug': 'beatcoin'},
#  {'id': 1398,
#   'name': 'PROUD Money',
#   'symbol': 'PROUD',
#   'website_slug': 'proud-money'},
#  {'id': 1399, 'name': 'Sequence', 'symbol': 'SEQ', 'website_slug': 'sequence'},
#  {'id': 1400, 'name': 'Omicron', 'symbol': 'OMC', 'website_slug': 'omicron'},
#  {'id': 1402,
#   'name': 'Lazaruscoin',
#   'symbol': 'LAZ',
#   'website_slug': 'lazaruscoin'},
#  {'id': 1403,
#   'name': 'FirstBlood',
#   'symbol': '1ST',
#   'website_slug': 'firstblood'},
#  {'id': 1405,
#   'name': 'Pepe Cash',
#   'symbol': 'PEPECASH',
#   'website_slug': 'pepe-cash'},
#  {'id': 1408, 'name': 'Iconomi', 'symbol': 'ICN', 'website_slug': 'iconomi'},
#  {'id': 1409,
#   'name': 'SingularDTV',
#   'symbol': 'SNGLS',
#   'website_slug': 'singulardtv'},
#  {'id': 1411,
#   'name': 'CaliphCoin',
#   'symbol': 'CALC',
#   'website_slug': 'caliphcoin'},
#  {'id': 1414, 'name': 'ZCoin', 'symbol': 'XZC', 'website_slug': 'zcoin'},
#  {'id': 1416,
#   'name': 'MobileCash',
#   'symbol': 'MBL',
#   'website_slug': 'mobilecash'},
#  {'id': 1418, 'name': 'Rcoin', 'symbol': 'RCN', 'website_slug': 'rcoin'},
#  {'id': 1420,
#   'name': 'Atomic Coin',
#   'symbol': 'ATOM',
#   'website_slug': 'atomic-coin'},
#  {'id': 1421,
#   'name': 'JobsCoin',
#   'symbol': 'JOBS',
#   'website_slug': 'jobscoin'},
#  {'id': 1423,
#   'name': 'Triggers',
#   'symbol': 'TRIG',
#   'website_slug': 'triggers'},
#  {'id': 1425,
#   'name': 'Sakuracoin',
#   'symbol': 'SKR',
#   'website_slug': 'sakuracoin'},
#  {'id': 1428,
#   'name': 'RoyalCoin',
#   'symbol': 'ROYAL',
#   'website_slug': 'royalcoin'},
#  {'id': 1429,
#   'name': 'Levocoin',
#   'symbol': 'LEVO',
#   'website_slug': 'levocoin'},
#  {'id': 1434,
#   'name': 'ArcticCoin',
#   'symbol': 'ARC',
#   'website_slug': 'arcticcoin'},
#  {'id': 1435, 'name': 'Cubits', 'symbol': 'QBT', 'website_slug': 'cubits'},
#  {'id': 1436,
#   'name': 'DynamicCoin',
#   'symbol': 'DMC',
#   'website_slug': 'dynamiccoin'},
#  {'id': 1437, 'name': 'Zcash', 'symbol': 'ZEC', 'website_slug': 'zcash'},
#  {'id': 1438,
#   'name': 'ImpulseCoin',
#   'symbol': 'IMPS',
#   'website_slug': 'impulsecoin'},
#  {'id': 1439,
#   'name': 'AllSafe',
#   'symbol': 'ASAFE2',
#   'website_slug': 'allsafe'},
#  {'id': 1442, 'name': 'BipCoin', 'symbol': 'BIP', 'website_slug': 'bipcoin'},
#  {'id': 1447, 'name': 'ZClassic', 'symbol': 'ZCL', 'website_slug': 'zclassic'},
#  {'id': 1448, 'name': 'Zoin', 'symbol': 'ZOI', 'website_slug': 'zoin'},
#  {'id': 1449, 'name': 'WA Space', 'symbol': 'WA', 'website_slug': 'wa-space'},
#  {'id': 1452, 'name': 'netBit', 'symbol': 'NBIT', 'website_slug': 'netbit'},
#  {'id': 1454, 'name': 'Lykke', 'symbol': 'LKK', 'website_slug': 'lykke'},
#  {'id': 1455,
#   'name': 'Golem',
#   'symbol': 'GNT',
#   'website_slug': 'golem-network-tokens'},
#  {'id': 1456,
#   'name': 'ZetaMicron',
#   'symbol': 'ZMC',
#   'website_slug': 'zetamicron'},
#  {'id': 1457,
#   'name': 'Bitcurrency',
#   'symbol': 'BTCR',
#   'website_slug': 'bitcurrency'},
#  {'id': 1459,
#   'name': 'Regacoin',
#   'symbol': 'REGA',
#   'website_slug': 'regacoin'},
#  {'id': 1463,
#   'name': 'LuckChain',
#   'symbol': 'BASH',
#   'website_slug': 'luckchain'},
#  {'id': 1464,
#   'name': 'Internet of People',
#   'symbol': 'IOP',
#   'website_slug': 'internet-of-people'},
#  {'id': 1465, 'name': 'Veros', 'symbol': 'VRS', 'website_slug': 'veros'},
#  {'id': 1466, 'name': 'Hush', 'symbol': 'HUSH', 'website_slug': 'hush'},
#  {'id': 1468, 'name': 'Kurrent', 'symbol': 'KURT', 'website_slug': 'kurrent'},
#  {'id': 1469, 'name': 'Creatio', 'symbol': 'XCRE', 'website_slug': 'creatio'},
#  {'id': 1472, 'name': 'Rawcoin', 'symbol': 'XRC', 'website_slug': 'rawcoin2'},
#  {'id': 1473,
#   'name': 'Pascal Coin',
#   'symbol': 'PASC',
#   'website_slug': 'pascal-coin'},
#  {'id': 1474, 'name': 'Eternity', 'symbol': 'ENT', 'website_slug': 'eternity'},
#  {'id': 1475, 'name': 'Incent', 'symbol': 'INCNT', 'website_slug': 'incent'},
#  {'id': 1478, 'name': 'DECENT', 'symbol': 'DCT', 'website_slug': 'decent'},
#  {'id': 1479,
#   'name': 'NodeCoin',
#   'symbol': 'NODC',
#   'website_slug': 'nodecoin'},
#  {'id': 1480, 'name': 'Golos', 'symbol': 'GOLOS', 'website_slug': 'golos'},
#  {'id': 1481, 'name': 'Nexium', 'symbol': 'NXC', 'website_slug': 'nexium'},
#  {'id': 1482, 'name': 'Shorty', 'symbol': 'SHORTY', 'website_slug': 'shorty'},
#  {'id': 1483, 'name': 'vSlice', 'symbol': 'VSL', 'website_slug': 'vslice'},
#  {'id': 1485,
#   'name': 'Dollar Online',
#   'symbol': 'DOLLAR',
#   'website_slug': 'dollar-online'},
#  {'id': 1486,
#   'name': 'Vault Coin',
#   'symbol': 'VLTC',
#   'website_slug': 'vault-coin'},
#  {'id': 1487,
#   'name': 'Pabyosi Coin (Special)',
#   'symbol': 'PCS',
#   'website_slug': 'pabyosi-coin-special'},
#  {'id': 1489, 'name': 'T-coin', 'symbol': 'TCOIN', 'website_slug': 't-coin'},
#  {'id': 1491,
#   'name': 'Blackstar',
#   'symbol': 'BSTAR',
#   'website_slug': 'blackstar'},
#  {'id': 1492,
#   'name': 'Byteball Bytes',
#   'symbol': 'GBYTE',
#   'website_slug': 'byteball'},
#  {'id': 1494,
#   'name': 'Bitpark Coin',
#   'symbol': 'BPC',
#   'website_slug': 'bitpark-coin'},
#  {'id': 1495,
#   'name': 'PoSW Coin',
#   'symbol': 'POSW',
#   'website_slug': 'posw-coin'},
#  {'id': 1496,
#   'name': 'Luna Coin',
#   'symbol': 'LUNA',
#   'website_slug': 'luna-coin'},
#  {'id': 1497,
#   'name': 'Fargocoin',
#   'symbol': 'FRGC',
#   'website_slug': 'fargocoin'},
#  {'id': 1500, 'name': 'Wings', 'symbol': 'WINGS', 'website_slug': 'wings'},
#  {'id': 1501,
#   'name': 'Dix Asset',
#   'symbol': 'DIX',
#   'website_slug': 'dix-asset'},
#  {'id': 1502,
#   'name': 'GameUnits',
#   'symbol': 'UNITS',
#   'website_slug': 'gameunits'},
#  {'id': 1503, 'name': 'Darcrus', 'symbol': 'DAR', 'website_slug': 'darcrus'},
#  {'id': 1504,
#   'name': 'InflationCoin',
#   'symbol': 'IFLT',
#   'website_slug': 'inflationcoin'},
#  {'id': 1505,
#   'name': 'Spectrecoin',
#   'symbol': 'XSPEC',
#   'website_slug': 'spectrecoin'},
#  {'id': 1506,
#   'name': 'Safe Trade Coin',
#   'symbol': 'XSTC',
# ...
#  {'id': 1834, 'name': 'Pillar', 'symbol': 'PLR', 'website_slug': 'pillar'},
#  {'id': 1835,
#   'name': 'Royalties',
#   'symbol': 'XRY',
#   'website_slug': 'royalties'},
#  {'id': 1836,
#   'name': 'Signatum',
#   'symbol': 'SIGT',
#   'website_slug': 'signatum'},
#  {'id': 1837,
#   'name': 'Coimatic 2.0',
#   'symbol': 'CTIC2',
#   'website_slug': 'coimatic-2'},
#  {'id': 1838,
#   'name': 'OracleChain',
#   'symbol': 'OCT',
#   'website_slug': 'oraclechain'},
#  {'id': 1839,
#   'name': 'Binance Coin',
#   'symbol': 'BNB',
#   'website_slug': 'binance-coin'},
#  {'id': 1840,
#   'name': '300 Token',
#   'symbol': '300',
#   'website_slug': '300-token'},
#  {'id': 1841,
#   'name': 'Primalbase Token',
#   'symbol': 'PBT',
#   'website_slug': 'primalbase'},
#  {'id': 1842,
#   'name': 'CampusCoin',
#   'symbol': 'CMPCO',
#   'website_slug': 'campuscoin'},
#  {'id': 1843,
#   'name': 'EmberCoin',
#   'symbol': 'EMB',
#   'website_slug': 'embercoin'},
#  {'id': 1845, 'name': 'iXledger', 'symbol': 'IXT', 'website_slug': 'ixledger'},
#  {'id': 1846,
#   'name': 'GeyserCoin',
#   'symbol': 'GSR',
#   'website_slug': 'geysercoin'},
#  {'id': 1847,
#   'name': 'Mothership',
#   'symbol': 'MSP',
#   'website_slug': 'mothership'},
#  {'id': 1848,
#   'name': 'Aseancoin',
#   'symbol': 'ASN',
#   'website_slug': 'aseancoin'},
#  {'id': 1849, 'name': 'Birds', 'symbol': 'BIRDS', 'website_slug': 'birds'},
#  {'id': 1850, 'name': 'Cream', 'symbol': 'CRM', 'website_slug': 'cream'},
#  {'id': 1851, 'name': 'ERA', 'symbol': 'ERA', 'website_slug': 'blakestar'},
#  {'id': 1852, 'name': 'KekCoin', 'symbol': 'KEK', 'website_slug': 'kekcoin'},
#  {'id': 1853, 'name': 'OAX', 'symbol': 'OAX', 'website_slug': 'oax'},
#  {'id': 1856,
#   'name': 'district0x',
#   'symbol': 'DNT',
#   'website_slug': 'district0x'},
#  {'id': 1857,
#   'name': 'FundYourselfNow',
#   'symbol': 'FYN',
#   'website_slug': 'fundyourselfnow'},
#  {'id': 1861, 'name': 'Stox', 'symbol': 'STX', 'website_slug': 'stox'},
#  {'id': 1863, 'name': 'Minex', 'symbol': 'MINEX', 'website_slug': 'minex'},
#  {'id': 1864, 'name': 'Blox', 'symbol': 'CDT', 'website_slug': 'blox'},
#  {'id': 1865, 'name': 'Wink', 'symbol': 'WINK', 'website_slug': 'wink'},
#  {'id': 1866, 'name': 'Bytom', 'symbol': 'BTM', 'website_slug': 'bytom'},
#  {'id': 1867, 'name': 'Centra', 'symbol': 'CTR', 'website_slug': 'centra'},
#  {'id': 1869,
#   'name': 'Mao Zedong',
#   'symbol': 'MAO',
#   'website_slug': 'mao-zedong'},
#  {'id': 1871,
#   'name': 'First Bitcoin Capital',
#   'symbol': 'BITCF',
#   'website_slug': 'first-bitcoin-capital'},
#  {'id': 1872, 'name': 'NEVERDIE', 'symbol': 'NDC', 'website_slug': 'neverdie'},
#  {'id': 1873, 'name': 'Blocktix', 'symbol': 'TIX', 'website_slug': 'blocktix'},
#  {'id': 1876,
#   'name': 'Dentacoin',
#   'symbol': 'DCN',
#   'website_slug': 'dentacoin'},
#  {'id': 1877, 'name': 'Rupaya', 'symbol': 'RUPX', 'website_slug': 'rupaya'},
#  {'id': 1878,
#   'name': 'Shadow Token',
#   'symbol': 'SHDW',
#   'website_slug': 'shadow-token'},
#  {'id': 1881,
#   'name': 'DeepOnion',
#   'symbol': 'ONION',
#   'website_slug': 'deeponion'},
#  {'id': 1882, 'name': 'BlockCAT', 'symbol': 'CAT', 'website_slug': 'blockcat'},
#  {'id': 1883,
#   'name': 'AdShares',
#   'symbol': 'ADST',
#   'website_slug': 'adshares'},
#  {'id': 1884,
#   'name': 'DigitalDevelopersFund',
#   'symbol': 'DDF',
#   'website_slug': 'digital-developers-fund'},
#  {'id': 1885, 'name': 'BitAsean', 'symbol': 'BAS', 'website_slug': 'bitasean'},
#  {'id': 1886, 'name': 'Dent', 'symbol': 'DENT', 'website_slug': 'dent'},
#  {'id': 1887,
#   'name': 'Monster Byte',
#   'symbol': 'MBI',
#   'website_slug': 'monster-byte'},
#  {'id': 1888,
#   'name': 'InvestFeed',
#   'symbol': 'IFT',
#   'website_slug': 'investfeed'},
#  {'id': 1889,
#   'name': 'CoinonatX',
#   'symbol': 'XCXT',
#   'website_slug': 'coinonatx'},
#  {'id': 1890,
#   'name': 'Etheriya',
#   'symbol': 'RIYA',
#   'website_slug': 'etheriya'},
#  {'id': 1894,
#   'name': 'The ChampCoin',
#   'symbol': 'TCC',
#   'website_slug': 'the-champcoin'},
#  {'id': 1896, 'name': '0x', 'symbol': 'ZRX', 'website_slug': '0x'},
#  {'id': 1897, 'name': 'Bolenum', 'symbol': 'BLN', 'website_slug': 'bolenum'},
#  {'id': 1898, 'name': 'Smoke', 'symbol': 'SMOKE', 'website_slug': 'smoke'},
#  {'id': 1899, 'name': 'YOYOW', 'symbol': 'YOYOW', 'website_slug': 'yoyow'},
#  {'id': 1900,
#   'name': 'Growers International',
#   'symbol': 'GRWI',
#   'website_slug': 'growers-international'},
#  {'id': 1902,
#   'name': 'MyBit Token',
#   'symbol': 'MYB',
#   'website_slug': 'mybit-token'},
#  {'id': 1903, 'name': 'Hshare', 'symbol': 'HSR', 'website_slug': 'hshare'},
#  {'id': 1904, 'name': 'VeChain', 'symbol': 'VEN', 'website_slug': 'vechain'},
#  {'id': 1905, 'name': 'TrueFlip', 'symbol': 'TFL', 'website_slug': 'trueflip'},
#  {'id': 1907, 'name': 'XTD Coin', 'symbol': 'XTD', 'website_slug': 'xtd-coin'},
#  {'id': 1908,
#   'name': 'Nebulas',
#   'symbol': 'NAS',
#   'website_slug': 'nebulas-token'},
#  {'id': 1910, 'name': 'ATMCoin', 'symbol': 'ATMC', 'website_slug': 'atmcoin'},
#  {'id': 1912,
#   'name': 'Dalecoin',
#   'symbol': 'DALC',
#   'website_slug': 'dalecoin'},
#  {'id': 1913, 'name': 'Protean', 'symbol': 'PRN', 'website_slug': 'protean'},
#  {'id': 1914, 'name': 'OX Fina', 'symbol': 'OX', 'website_slug': 'ox-fina'},
#  {'id': 1915, 'name': 'AdCoin', 'symbol': 'ACC', 'website_slug': 'adcoin'},
#  {'id': 1916, 'name': 'BiblePay', 'symbol': 'BBP', 'website_slug': 'biblepay'},
#  {'id': 1917, 'name': 'bitqy', 'symbol': 'BQ', 'website_slug': 'bitqy'},
#  {'id': 1918, 'name': 'Achain', 'symbol': 'ACT', 'website_slug': 'achain'},
#  {'id': 1920,
#   'name': 'NamoCoin',
#   'symbol': 'NAMO',
#   'website_slug': 'namocoin'},
#  {'id': 1921,
#   'name': 'SIGMAcoin',
#   'symbol': 'SIGMA',
#   'website_slug': 'sigmacoin'},
#  {'id': 1922,
#   'name': 'Monoeci',
#   'symbol': 'XMCC',
#   'website_slug': 'monacocoin'},
#  {'id': 1923, 'name': 'Tierion', 'symbol': 'TNT', 'website_slug': 'tierion'},
#  {'id': 1925,
#   'name': 'Waltonchain',
#   'symbol': 'WTC',
#   'website_slug': 'waltonchain'},
#  {'id': 1926, 'name': 'BROTHER', 'symbol': 'BRAT', 'website_slug': 'brat'},
#  {'id': 1927, 'name': 'Ulatech', 'symbol': 'ULA', 'website_slug': 'ulatech'},
#  {'id': 1930, 'name': 'Primas', 'symbol': 'PST', 'website_slug': 'primas'},
#  {'id': 1931, 'name': 'Opus', 'symbol': 'OPT', 'website_slug': 'opus'},
#  {'id': 1933, 'name': 'Suretly', 'symbol': 'SUR', 'website_slug': 'suretly'},
#  {'id': 1934, 'name': 'Loopring', 'symbol': 'LRC', 'website_slug': 'loopring'},
#  {'id': 1935,
#   'name': 'LiteCoin Ultra',
#   'symbol': 'LTCU',
#   'website_slug': 'litecoin-ultra'},
#  {'id': 1937, 'name': 'Po.et', 'symbol': 'POE', 'website_slug': 'poet'},
#  {'id': 1938, 'name': 'Fujinto', 'symbol': 'NTO', 'website_slug': 'fujinto'},
#  {'id': 1942,
#   'name': 'StarCredits',
#   'symbol': 'STRC',
#   'website_slug': 'starcredits'},
#  {'id': 1943,
#   'name': 'Kronecoin',
#   'symbol': 'KRONE',
#   'website_slug': 'kronecoin'},
#  {'id': 1945, 'name': 'Cyder', 'symbol': 'CYDER', 'website_slug': 'cyder'},
#  {'id': 1946,
#   'name': 'Masternodecoin',
#   'symbol': 'MTNC',
#   'website_slug': 'masternodecoin'},
#  {'id': 1947, 'name': 'Monetha', 'symbol': 'MTH', 'website_slug': 'monetha'},
#  {'id': 1948, 'name': 'Aventus', 'symbol': 'AVT', 'website_slug': 'aventus'},
#  {'id': 1949,
#   'name': 'Agrello',
#   'symbol': 'DLT',
#   'website_slug': 'agrello-delta'},
#  {'id': 1950,
#   'name': 'Hive Project',
#   'symbol': 'HVN',
#   'website_slug': 'hive-project'},
#  {'id': 1951, 'name': 'Vsync', 'symbol': 'VSX', 'website_slug': 'vsync-vsx'},
#  {'id': 1952,
#   'name': 'Magnetcoin',
#   'symbol': 'MAGN',
#   'website_slug': 'magnetcoin'},
#  {'id': 1954,
#   'name': 'Moeda Loyalty Points',
#   'symbol': 'MDA',
#   'website_slug': 'moeda-loyalty-points'},
#  {'id': 1955, 'name': 'Neblio', 'symbol': 'NEBL', 'website_slug': 'neblio'},
#  {'id': 1956, 'name': 'VIVO', 'symbol': 'VIVO', 'website_slug': 'vivo'},
#  {'id': 1958, 'name': 'TRON', 'symbol': 'TRX', 'website_slug': 'tron'},
#  {'id': 1959, 'name': 'Oceanlab', 'symbol': 'OCL', 'website_slug': 'oceanlab'},
#  {'id': 1961, 'name': 'imbrex', 'symbol': 'REX', 'website_slug': 'imbrex'},
#  {'id': 1962,
#   'name': 'BuzzCoin',
#   'symbol': 'BUZZ',
#   'website_slug': 'buzzcoin'},
#  {'id': 1963, 'name': 'Credo', 'symbol': 'CREDO', 'website_slug': 'credo'},
#  {'id': 1964, 'name': 'DROXNE', 'symbol': 'DRXNE', 'website_slug': 'droxne'},
#  {'id': 1965, 'name': 'Bowhead', 'symbol': 'AHT', 'website_slug': 'bowhead'},
#  {'id': 1966,
#   'name': 'Decentraland',
#   'symbol': 'MANA',
#   'website_slug': 'decentraland'},
#  {'id': 1967,
#   'name': 'Indorse Token',
#   'symbol': 'IND',
#   'website_slug': 'indorse-token'},
#  {'id': 1968, 'name': 'XPA', 'symbol': 'XPA', 'website_slug': 'xpa'},
#  {'id': 1969, 'name': 'Sociall', 'symbol': 'SCL', 'website_slug': 'sociall'},
#  {'id': 1970, 'name': 'ATBCoin', 'symbol': 'ATB', 'website_slug': 'atbcoin'},
#  {'id': 1971, 'name': 'iQuant', 'symbol': 'IQT', 'website_slug': 'iquant'},
#  {'id': 1973,
#   'name': 'Ethereum Dark',
#   'symbol': 'ETHD',
#   'website_slug': 'ethereum-dark'},
#  {'id': 1974, 'name': 'Propy', 'symbol': 'PRO', 'website_slug': 'propy'},
#  {'id': 1975,
#   'name': 'ChainLink',
#   'symbol': 'LINK',
#   'website_slug': 'chainlink'},
#  {'id': 1976,
#   'name': 'Blackmoon',
#   'symbol': 'BMC',
#   'website_slug': 'blackmoon'},
#  {'id': 1979, 'name': 'Wi Coin', 'symbol': 'WIC', 'website_slug': 'wi-coin'},
#  {'id': 1980, 'name': 'Elixir', 'symbol': 'ELIX', 'website_slug': 'elixir'},
#  {'id': 1981,
#   'name': 'Billionaire Token',
#   'symbol': 'XBL',
#   'website_slug': 'billionaire-token'},
#  {'id': 1982,
#   'name': 'Kyber Network',
#   'symbol': 'KNC',
#   'website_slug': 'kyber-network'},
#  {'id': 1983, 'name': 'VIBE', 'symbol': 'VIBE', 'website_slug': 'vibe'},
#  {'id': 1984,
#   'name': 'Substratum',
#   'symbol': 'SUB',
#   'website_slug': 'substratum'},
#  {'id': 1985,
#   'name': 'Chronologic',
#   'symbol': 'DAY',
#   'website_slug': 'chronologic'},
#  {'id': 1986, 'name': 'CHIPS', 'symbol': 'CHIPS', 'website_slug': 'chips'},
#  {'id': 1987,
#   'name': 'CryptoInsight',
#   'symbol': 'TKR',
#   'website_slug': 'trackr'},
#  {'id': 1988, 'name': 'Lampix', 'symbol': 'PIX', 'website_slug': 'lampix'},
#  {'id': 1989, 'name': 'COSS', 'symbol': 'COSS', 'website_slug': 'coss'},
#  {'id': 1990, 'name': 'BitDice', 'symbol': 'CSNO', 'website_slug': 'bitdice'},
#  {'id': 1991, 'name': 'Rivetz', 'symbol': 'RVT', 'website_slug': 'rivetz'},
#  {'id': 1993, 'name': 'Kin', 'symbol': 'KIN', 'website_slug': 'kin'},
#  {'id': 1994,
#   'name': 'Interzone',
#   'symbol': 'ITZ',
#   'website_slug': 'interzone'},
#  {'id': 1995,
#   'name': 'Target Coin',
#   'symbol': 'TGT',
#   'website_slug': 'target-coin'},
#  {'id': 1996, 'name': 'SALT', 'symbol': 'SALT', 'website_slug': 'salt'},
#  {'id': 1997,
#   'name': 'India Coin',
#   'symbol': 'INDIA',
#   'website_slug': 'india-coin'},
#  {'id': 1998,
#   'name': 'Ormeus Coin',
#   'symbol': 'ORME',
#   'website_slug': 'ormeus-coin'},
#  {'id': 1999, 'name': 'Kolion', 'symbol': 'KLN', 'website_slug': 'kolion'},
#  {'id': 2000,
#   'name': 'Musiconomi',
#   'symbol': 'MCI',
#   'website_slug': 'musiconomi'},
#  {'id': 2001,
#   'name': 'ColossusXT',
#   'symbol': 'COLX',
#   'website_slug': 'colossusxt'},
#  {'id': 2002,
#   'name': 'TrezarCoin',
#   'symbol': 'TZC',
#   'website_slug': 'trezarcoin'},
#  {'id': 2004,
#   'name': 'HODL Bucks',
#   'symbol': 'HDLB',
#   'website_slug': 'hodl-bucks'},
#  {'id': 2005, 'name': 'Obsidian', 'symbol': 'ODN', 'website_slug': 'obsidian'},
#  {'id': 2006,
#   'name': 'Cobinhood',
#   'symbol': 'COB',
#   'website_slug': 'cobinhood'},
#  {'id': 2007,
#   'name': 'Regalcoin',
#   'symbol': 'REC',
#   'website_slug': 'regalcoin'},
#  {'id': 2008, 'name': 'MSD', 'symbol': 'MSD', 'website_slug': 'msd'},
#  {'id': 2009, 'name': 'Bismuth', 'symbol': 'BIS', 'website_slug': 'bismuth'},
#  {'id': 2010, 'name': 'Cardano', 'symbol': 'ADA', 'website_slug': 'cardano'},
#  {'id': 2011,
#   'name': 'Tezos (Pre-Launch)',
#   'symbol': 'XTZ',
#   'website_slug': 'tezos'},
#  {'id': 2012, 'name': 'Voise', 'symbol': 'VOISE', 'website_slug': 'voisecom'},
#  {'id': 2013,
#   'name': 'Infinity Economics',
#   'symbol': 'XIN',
#   'website_slug': 'infinity-economics'},
#  {'id': 2015,
#   'name': 'ATMChain',
#   'symbol': 'ATM',
#   'website_slug': 'attention-token-of-media'},
#  {'id': 2016, 'name': 'Macro', 'symbol': 'MCR', 'website_slug': 'macro1'},
#  {'id': 2017, 'name': 'KickCoin', 'symbol': 'KICK', 'website_slug': 'kickico'},
#  {'id': 2018,
#   'name': 'EncryptoTel [ETH]',
#   'symbol': 'ETT',
#   'website_slug': 'encryptotel-eth'},
#  {'id': 2019, 'name': 'Viberate', 'symbol': 'VIB', 'website_slug': 'viberate'},
#  {'id': 2021, 'name': 'RChain', 'symbol': 'RHOC', 'website_slug': 'rchain'},
#  {'id': 2022,
#   'name': 'Internxt',
#   'symbol': 'INXT',
#   'website_slug': 'internxt'},
#  {'id': 2024,
#   'name': 'WhaleCoin',
#   'symbol': 'WHL',
#   'website_slug': 'whalecoin'},
#  {'id': 2025, 'name': 'FLiK', 'symbol': 'FLIK', 'website_slug': 'flik'},
#  {'id': 2026, 'name': 'EthBet', 'symbol': 'EBET', 'website_slug': 'ethbet'},
#  {'id': 2027,
#   'name': 'Cryptonex',
#   'symbol': 'CNX',
#   'website_slug': 'cryptonex'},
#  {'id': 2029,
#   'name': 'Wild Crypto',
#   'symbol': 'WILD',
#   'website_slug': 'wild-crypto'},
#  {'id': 2030, 'name': 'REAL', 'symbol': 'REAL', 'website_slug': 'real'},
#  {'id': 2031,
#   'name': 'Hubii Network',
#   'symbol': 'HBT',
#   'website_slug': 'hubii-network'},
#  {'id': 2032,
#   'name': 'Crystal Clear ',
#   'symbol': 'CCT',
#   'website_slug': 'crystal-clear'},
#  {'id': 2033,
#   'name': 'BridgeCoin',
#   'symbol': 'BCO',
#   'website_slug': 'bridgecoin'},
#  {'id': 2034, 'name': 'Everex', 'symbol': 'EVX', 'website_slug': 'everex'},
#  {'id': 2036, 'name': 'PayPie', 'symbol': 'PPP', 'website_slug': 'paypie'},
#  {'id': 2037, 'name': 'AirToken', 'symbol': 'AIR', 'website_slug': 'airtoken'},
#  {'id': 2038, 'name': 'PoSToken', 'symbol': 'POS', 'website_slug': 'postoken'},
#  {'id': 2039,
#   'name': 'Senderon',
#   'symbol': 'SDRN',
#   'website_slug': 'senderon'},
#  {'id': 2040, 'name': 'ALIS', 'symbol': 'ALIS', 'website_slug': 'alis'},
#  {'id': 2041,
#   'name': 'BitcoinZ',
#   'symbol': 'BTCZ',
#   'website_slug': 'bitcoinz'},
#  {'id': 2042,
#   'name': 'HelloGold',
#   'symbol': 'HGT',
#   'website_slug': 'hellogold'},
#  {'id': 2043,
#   'name': 'Cindicator',
#   'symbol': 'CND',
#   'website_slug': 'cindicator'},
#  {'id': 2044,
#   'name': 'Enigma',
#   'symbol': 'ENG',
#   'website_slug': 'enigma-project'},
#  {'id': 2045,
#   'name': 'Coimatic 3.0',
#   'symbol': 'CTIC3',
#   'website_slug': 'coimatic-3'},
#  {'id': 2046, 'name': 'Bastonet', 'symbol': 'BSN', 'website_slug': 'bastonet'},
#  {'id': 2047,
#   'name': 'Zeusshield',
#   'symbol': 'ZSC',
#   'website_slug': 'zeusshield'},
#  {'id': 2048,
#   'name': 'Ethereum Cash',
#   'symbol': 'ECASH',
#   'website_slug': 'ethereumcash'},
#  {'id': 2049, 'name': 'CORION', 'symbol': 'COR', 'website_slug': 'corion'},
#  {'id': 2050,
#   'name': 'Swisscoin',
#   'symbol': 'SIC',
#   'website_slug': 'swisscoin'},
#  {'id': 2051,
#   'name': 'Authorship',
#   'symbol': 'ATS',
#   'website_slug': 'authorship'},
#  {'id': 2053,
#   'name': 'Royal Kingdom Coin',
#   'symbol': 'RKC',
#   'website_slug': 'royal-kingdom-coin'},
#  {'id': 2054,
#   'name': 'Akuya Coin',
#   'symbol': 'AKY',
#   'website_slug': 'akuya-coin'},
#  {'id': 2055,
#   'name': 'ExchangeN',
#   'symbol': 'EXN',
#   'website_slug': 'exchangen'},
#  {'id': 2056,
#   'name': 'PiplCoin',
#   'symbol': 'PIPL',
#   'website_slug': 'piplcoin'},
#  {'id': 2057, 'name': 'Eidoo', 'symbol': 'EDO', 'website_slug': 'eidoo'},
#  {'id': 2058, 'name': 'AirSwap', 'symbol': 'AST', 'website_slug': 'airswap'},
#  {'id': 2060, 'name': 'Change', 'symbol': 'CAG', 'website_slug': 'change'},
#  {'id': 2061,
#   'name': 'BlockMason Credit Protocol',
#   'symbol': 'BCPT',
#   'website_slug': 'blockmason'},
#  {'id': 2062, 'name': 'Aion', 'symbol': 'AION', 'website_slug': 'aion'},
#  {'id': 2063, 'name': 'Tracto', 'symbol': 'TRCT', 'website_slug': 'tracto'},
#  {'id': 2064, 'name': 'Maecenas', 'symbol': 'ART', 'website_slug': 'maecenas'},
#  {'id': 2065, 'name': 'XGOX', 'symbol': 'XGOX', 'website_slug': 'xgox'},
#  {'id': 2066, 'name': 'Everus', 'symbol': 'EVR', 'website_slug': 'everus'},
#  {'id': 2067,
#   'name': 'Dutch Coin',
#   'symbol': 'DUTCH',
#   'website_slug': 'dutch-coin'},
#  {'id': 2069,
#   'name': 'Open Trading Network',
#   'symbol': 'OTN',
#   'website_slug': 'open-trading-network'},
#  ...]

# %% [markdown]
# Other parameters:

# %%
print(cmc.ticker.__doc__)
# Out:
# Get currencies with other aditional data.
#
#         Args:
#             currency (str, optional): Specify a currency to return data,
#                 that can be a ``name``, ``symbol``, ``id`` or
#                 ``website_slug`` fields from
#                 :py:class:`pymarketcap.core.Pymarketcap.cryptocurrencies`
#                 property. If you dont specify a currency, returns data
#                 for all in coinmarketcap. As default, ``None``.
#             convert (str, optional): Allows to convert prices, 24h volumes
#                 and market capitalizations in terms of one of badges
#                 returned by ``ticker_badges`` property.
#                 As default, ``"USD"``.
#
#         Returns (dict/list):
#             The type depends if currency param is provided or not.

# %% [markdown]
# If you want to get the valid badges that can be passed to `convert` param programatically, use this:

# %%
print(cmc.ticker_badges)
# Out:
# ['AUD', 'BCH', 'BRL', 'BTC', 'CAD', 'CHF', 'CLP', 'CNY', 'CZK', 'DKK', 'ETH', 'EUR', 'GBP', 'HKD', 'HUF', 'IDR', 'ILS', 'INR', 'JPY', 'KRW', 'LTC', 'MXN', 'MYR', 'NOK', 'NZD', 'PHP', 'PKR', 'PLN', 'RUB', 'SEK', 'SGD', 'THB', 'TRY', 'TWD', 'USD', 'XRP', 'ZAR']

# %% [markdown]
# #### `ticker_all(convert="USD")`
# Obtain all currencies from `ticker` method navigating through all API paginated responses.

# %%
cmc.ticker_all()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-083db0d9fe7b> in <module>()
# ----> 1 cmc.ticker_all()
#
# NameError: name 'cmc' is not defined

# %% [markdown]
# #### `stats(convert="USD")`
# Get global criptocurrency statistics. The `convert` parameter works just like in previous method.

# %%
cmc.stats()
# Out:
# {'data': {'active_cryptocurrencies': 1604,
#   'active_markets': 10840,
#   'bitcoin_percentage_of_market_cap': 38.01,
#   'last_updated': 1526043573,
#   'quotes': {'USD': {'total_market_cap': 383122849051.0,
#     'total_volume_24h': 29636130130.0}}},
#  'metadata': {'error': None, 'timestamp': 1526043474},
#  'status': {'error': None, 'timestamp': 1526043474}}

# %% [markdown]
# _____________________________________________
#
# ## Web scraper

# %% [markdown]
# #### `currency(name, [convert="USD"])`
# Get metadata from a cryptocurrency passed as first argument.

# %%
cmc.currency("BTC")
# Out:
# {'announcement': None,
#  'chats': [],
#  'circulating_supply': 17003537.0,
#  'explorers': [],
#  'markets_cap': 158870507535.0,
#  'markets_volume_24h': 7900690000.0,
#  'max_supply': 21000000.0,
#  'message_boards': [],
#  'mineable': True,
#  'price': 9343.38,
#  'rank': 1,
#  'slug': 'bitcoin',
#  'source_code': None,
#  'symbol': 'BTC',
#  'webs': []}

# %%
show_page("currencies/bitcoin")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/currencies/bitcoin"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `markets(name, [convert="USD"])`
# Get all markets for a exchange in coinmarketcap. Pass a currency symbol or slug as first parameter. You can convert the response fields `"volume_24h"` and `"price"` between `"USD"` and `"BTC"` with `convert` parameter.

# %%
cmc.markets("BTC", convert="BTC")
# Out:
# {'markets': [{'pair': 'BTC/USD',
#    'percent_volume': 5.2487820684,
#    'price': 1.0014,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 44414.0},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 4.89738238053,
#    'price': 1.00085,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 41440.6},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 4.39150251434,
#    'price': 1.00161,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 37160.0},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 2.52600722215,
#    'price': 0.996883,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 21374.5},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 2.15164751433,
#    'price': 0.994343,
#    'source': 'bitFlyer',
#    'updated': True,
#    'volume_24h': 18206.8},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 2.07953988829,
#    'price': 1.0,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 17596.6},
#   {'pair': 'BTC/USD',
#    'percent_volume': 1.93824843147,
#    'price': 0.999031,
#    'source': 'Bitstamp',
#    'updated': True,
#    'volume_24h': 16401.0},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 1.9198070042,
#    'price': 0.999415,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 16245.0},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 1.74097452248,
#    'price': 0.995625,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 14731.8},
#   {'pair': 'BTC/KRW',
#    'percent_volume': 1.56845794481,
#    'price': 1.01202,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 13272.0},
#   {'pair': 'BTC/USD',
#    'percent_volume': 1.37423440231,
#    'price': 0.999582,
#    'source': 'GDAX',
#    'updated': True,
#    'volume_24h': 11628.5},
#   {'pair': 'BTC/CKUSD',
#    'percent_volume': 1.214726815,
#    'price': 1.01736,
#    'source': 'BCEX',
#    'updated': True,
#    'volume_24h': 10278.8},
#   {'pair': 'BTC/USD',
#    'percent_volume': 1.11838333108,
#    'price': 1.00676,
#    'source': 'BTCC',
#    'updated': True,
#    'volume_24h': 9463.51},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 1.10629577923,
#    'price': 1.00055,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 9361.24},
#   {'pair': 'BTC/KRW',
#    'percent_volume': 1.10268090509,
#    'price': 1.01121,
#    'source': 'Bithumb',
#    'updated': True,
#    'volume_24h': 9330.65},
#   {'pair': 'ADA/BTC',
#    'percent_volume': 1.08883654466,
#    'price': 0.989549,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 9213.5},
#   {'pair': 'MITH/BTC',
#    'percent_volume': 0.952194048874,
#    'price': 0.961083,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 8057.25},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.904183052366,
#    'price': 1.00041,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 7651.0},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.874560323212,
#    'price': 0.992847,
#    'source': 'BTCBOX',
#    'updated': True,
#    'volume_24h': 7400.34},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.864266285603,
#    'price': 1.00261,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 7313.23},
#   {'pair': 'ICX/BTC',
#    'percent_volume': 0.846776673936,
#    'price': 1.00664,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 7165.23},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.834053734547,
#    'price': 1.00272,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 7057.58},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.823068618057,
#    'price': 0.999415,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 6964.63},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.796508912513,
#    'price': 0.995917,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 6739.89},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.752627935028,
#    'price': 0.998585,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 6368.58},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.711849218233,
#    'price': 0.999552,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 6023.51},
#   {'pair': 'VET/BTC',
#    'percent_volume': 0.699119950283,
#    'price': 1.0007,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 5915.8},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.684500973966,
#    'price': 1.00054,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 5792.1},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.663638239192,
#    'price': 0.935921,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 5615.56},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.612900898529,
#    'price': 0.997112,
#    'source': 'EXX',
#    'updated': True,
#    'volume_24h': 5186.23},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.610215057166,
#    'price': 0.999386,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 5163.51},
#   {'pair': 'TRUE/BTC',
#    'percent_volume': 0.591188870845,
#    'price': 0.961263,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 5002.51},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.568751590051,
#    'price': 0.995198,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 4812.65},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.56820733379,
#    'price': 1.0016,
#    'source': 'EXX',
#    'updated': True,
#    'volume_24h': 4808.05},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.558446161032,
#    'price': 1.0003,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 4725.45},
#   {'pair': 'ONT/BTC',
#    'percent_volume': 0.539047855314,
#    'price': 1.04139,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 4561.3},
#   {'pair': 'AE/BTC',
#    'percent_volume': 0.532059858063,
#    'price': 1.00919,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 4502.17},
#   {'pair': 'BNB/BTC',
#    'percent_volume': 0.527772890722,
#    'price': 0.999673,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 4465.9},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.511366728729,
#    'price': 0.993447,
#    'source': 'BCEX',
#    'updated': True,
#    'volume_24h': 4327.07},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.510042793731,
#    'price': 0.999303,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 4315.87},
#   {'pair': 'HSR/BTC',
#    'percent_volume': 0.509621311556,
#    'price': 1.00126,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 4312.31},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.501692890115,
#    'price': 0.996597,
#    'source': 'Simex',
#    'updated': True,
#    'volume_24h': 4245.22},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.498842506161,
#    'price': 1.00279,
#    'source': 'OOOBTC',
#    'updated': True,
#    'volume_24h': 4221.1},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.494326444905,
#    'price': 0.997169,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 4182.88},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.48528039956,
#    'price': 1.0015,
#    'source': 'CoinBene',
#    'updated': True,
#    'volume_24h': 4106.33},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.480623844247,
#    'price': 0.995017,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 4066.94},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.469736187599,
#    'price': 1.00093,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 3974.8},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.4647707985,
#    'price': 0.992777,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 3932.79},
#   {'pair': 'XVG/BTC',
#    'percent_volume': 0.409223751343,
#    'price': 1.00464,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 3462.77},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.397645015815,
#    'price': 1.00039,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 3364.79},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.393398551266,
#    'price': 0.999336,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 3328.85},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.389626728805,
#    'price': 0.999674,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 3296.93},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.363530273938,
#    'price': 0.999632,
#    'source': 'Gemini',
#    'updated': True,
#    'volume_24h': 3076.12},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.34886573198,
#    'price': 0.999535,
#    'source': 'RightBTC',
#    'updated': True,
#    'volume_24h': 2952.03},
#   {'pair': 'DOGE/BTC',
#    'percent_volume': 0.345922951033,
#    'price': 1.01693,
#    'source': 'fex',
#    'updated': True,
#    'volume_24h': 2927.12},
#   {'pair': 'BTM/BTC',
#    'percent_volume': 0.345801442659,
#    'price': 0.998903,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 2926.1},
#   {'pair': 'XLM/BTC',
#    'percent_volume': 0.32841815082,
#    'price': 0.994618,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 2779.01},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.328181462632,
#    'price': 1.00242,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 2777.0},
#   {'pair': 'ADA/BTC',
#    'percent_volume': 0.32631200566,
#    'price': 0.992447,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 2761.19},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.323731218413,
#    'price': 1.00131,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 2739.35},
#   {'pair': 'BTC/CNY',
#    'percent_volume': 0.323627430009,
#    'price': 1.01141,
#    'source': 'TOPBTC',
#    'updated': True,
#    'volume_24h': 2738.47},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.310362765784,
#    'price': 1.00055,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 2626.22},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.288727946546,
#    'price': 0.994738,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 2443.15},
#   {'pair': 'GTO/BTC',
#    'percent_volume': 0.285585183066,
#    'price': 1.01407,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 2416.55},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.276274603864,
#    'price': 0.99905,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 2337.77},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.274627912246,
#    'price': 0.999931,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 2323.84},
#   {'pair': 'XMR/BTC',
#    'percent_volume': 0.27276731526,
#    'price': 0.999734,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 2308.09},
#   {'pair': 'ONT/BTC',
#    'percent_volume': 0.262499857607,
#    'price': 1.01672,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 2221.21},
#   {'pair': 'BIX/BTC',
#    'percent_volume': 0.261751821676,
#    'price': 0.999609,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 2214.89},
#   {'pair': 'ELF/BTC',
#    'percent_volume': 0.26160120192,
#    'price': 0.97473,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 2213.61},
#   {'pair': 'CTXC/BTC',
#    'percent_volume': 0.257873679387,
#    'price': 1.00117,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 2182.07},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.248154275133,
#    'price': 1.00037,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 2099.83},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.247197396683,
#    'price': 0.999453,
#    'source': 'Coinhub',
#    'updated': True,
#    'volume_24h': 2091.73},
#   {'pair': 'STORM/BTC',
#    'percent_volume': 0.245159599984,
#    'price': 1.00538,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 2074.48},
#   {'pair': 'IOTA/BTC',
#    'percent_volume': 0.243731876583,
#    'price': 0.999416,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 2062.41},
#   {'pair': 'ZCL/BTC',
#    'percent_volume': 0.243572396841,
#    'price': 0.991162,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 2061.05},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.233227730743,
#    'price': 0.998862,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 1973.52},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.23158989911,
#    'price': 0.993827,
#    'source': 'Bitbank',
#    'updated': True,
#    'volume_24h': 1959.66},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.231320302404,
#    'price': 0.996454,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 1957.38},
#   {'pair': 'XVG/BTC',
#    'percent_volume': 0.229360979864,
#    'price': 0.999425,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 1940.81},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.227904145081,
#    'price': 1.01473,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 1928.47},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.227261163265,
#    'price': 0.995596,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1923.03},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.224938581314,
#    'price': 0.999419,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1903.38},
#   {'pair': 'STEEM/BTC',
#    'percent_volume': 0.224724675946,
#    'price': 1.00345,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1901.57},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.224351290837,
#    'price': 0.999415,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 1898.41},
#   {'pair': 'EKT/BTC',
#    'percent_volume': 0.221773035013,
#    'price': 1.00222,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 1876.6},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.221481921199,
#    'price': 0.993615,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 1874.13},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.220884505024,
#    'price': 1.00878,
#    'source': 'Simex',
#    'updated': True,
#    'volume_24h': 1869.08},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.220211146115,
#    'price': 0.996096,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 1863.38},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.216188712631,
#    'price': 1.0028,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 1829.35},
#   {'pair': 'WAN/BTC',
#    'percent_volume': 0.212567509926,
#    'price': 1.00165,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1798.7},
#   {'pair': 'POA/BTC',
#    'percent_volume': 0.210057602564,
#    'price': 1.00492,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1777.47},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.20683889635,
#    'price': 1.00387,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 1750.22},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.205714943885,
#    'price': 1.00548,
#    'source': 'B2BX',
#    'updated': True,
#    'volume_24h': 1740.72},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.203816375532,
#    'price': 0.967191,
#    'source': 'CoinsBank',
#    'updated': True,
#    'volume_24h': 1724.65},
#   {'pair': 'ADA/BTC',
#    'percent_volume': 0.20179376738,
#    'price': 0.992447,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 1707.53},
#   {'pair': 'SRN/BTC',
#    'percent_volume': 0.201582393437,
#    'price': 0.999945,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 1705.75},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.201489996443,
#    'price': 1.01007,
#    'source': 'Livecoin',
#    'updated': True,
#    'volume_24h': 1704.96},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.195566463182,
#    'price': 0.984909,
#    'source': 'CoinsBank',
#    'updated': True,
#    'volume_24h': 1654.84},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.195113338202,
#    'price': 0.997472,
#    'source': 'RightBTC',
#    'updated': True,
#    'volume_24h': 1651.0},
#   {'pair': 'XVG/BTC',
#    'percent_volume': 0.193581826397,
#    'price': 0.999425,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 1638.05},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.190826370861,
#    'price': 1.00018,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 1614.73},
#   {'pair': 'NAS/BTC',
#    'percent_volume': 0.190351728773,
#    'price': 1.00586,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 1610.72},
#   {'pair': 'ACT/BTC',
#    'percent_volume': 0.185849590352,
#    'price': 0.981881,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 1572.62},
#   {'pair': 'IOST/BTC',
#    'percent_volume': 0.185135728652,
#    'price': 1.01105,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1566.57},
#   {'pair': 'HT/BTC',
#    'percent_volume': 0.183409297163,
#    'price': 1.00325,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 1551.97},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.182587849922,
#    'price': 1.00271,
#    'source': 'Bitstamp',
#    'updated': True,
#    'volume_24h': 1545.02},
#   {'pair': 'ZIL/BTC',
#    'percent_volume': 0.182058782208,
#    'price': 0.999029,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1540.55},
#   {'pair': 'MTL/BTC',
#    'percent_volume': 0.179515966327,
#    'price': 0.99934,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1519.02},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.178480613719,
#    'price': 0.992474,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 1510.26},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.175845400845,
#    'price': 0.986934,
#    'source': 'DragonEX',
#    'updated': True,
#    'volume_24h': 1487.96},
#   {'pair': 'NCASH/BTC',
#    'percent_volume': 0.17406454373,
#    'price': 1.00151,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1472.9},
#   {'pair': 'NANO/BTC',
#    'percent_volume': 0.173507630346,
#    'price': 1.00041,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1468.18},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.173287396417,
#    'price': 1.00145,
#    'source': 'GDAX',
#    'updated': True,
#    'volume_24h': 1466.32},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.169645942316,
#    'price': 0.996667,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 1435.51},
#   {'pair': 'OCN/BTC',
#    'percent_volume': 0.165404540616,
#    'price': 1.0026,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 1399.62},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.16526531227,
#    'price': 0.997767,
#    'source': 'CoinTiger',
#    'updated': True,
#    'volume_24h': 1398.44},
#   {'pair': 'BTC/CNY',
#    'percent_volume': 0.165040015492,
#    'price': 0.992541,
#    'source': 'OEX',
#    'updated': True,
#    'volume_24h': 1396.53},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.162717433541,
#    'price': 1.0356,
#    'source': 'Trade By Trade',
#    'updated': True,
#    'volume_24h': 1376.87},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.162693385008,
#    'price': 1.00128,
#    'source': 'CoinTiger',
#    'updated': True,
#    'volume_24h': 1376.67},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.16102391057,
#    'price': 1.00041,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 1362.54},
#   {'pair': 'WAVES/BTC',
#    'percent_volume': 0.159246850592,
#    'price': 1.00108,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1347.51},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.158439326185,
#    'price': 1.00206,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 1340.68},
#   {'pair': 'BTC/KRW',
#    'percent_volume': 0.157511559117,
#    'price': 1.01141,
#    'source': 'Coinone',
#    'updated': True,
#    'volume_24h': 1332.82},
#   {'pair': 'OMG/BTC',
#    'percent_volume': 0.156390138077,
#    'price': 1.00295,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1323.34},
#   {'pair': 'HSR/BTC',
#    'percent_volume': 0.156087632852,
#    'price': 1.00336,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1320.78},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.155601599354,
#    'price': 1.00145,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 1316.66},
#   {'pair': 'BTC/CKUSD',
#    'percent_volume': 0.152489212967,
#    'price': 1.00082,
#    'source': 'Allcoin',
#    'updated': True,
#    'volume_24h': 1290.33},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.151304506315,
#    'price': 0.999415,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 1280.3},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.146554288296,
#    'price': 0.993905,
#    'source': 'Exmo',
#    'updated': True,
#    'volume_24h': 1240.11},
#   {'pair': 'RDD/BTC',
#    'percent_volume': 0.146104960453,
#    'price': 1.01197,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 1236.31},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.145969529244,
#    'price': 0.999985,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 1235.16},
#   {'pair': 'XMR/BTC',
#    'percent_volume': 0.145958137834,
#    'price': 0.997513,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1235.07},
#   {'pair': 'ARN/BTC',
#    'percent_volume': 0.145306296032,
#    'price': 1.00054,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1229.54},
#   {'pair': 'SYS/BTC',
#    'percent_volume': 0.144862031038,
#    'price': 1.00298,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 1225.79},
#   {'pair': 'NULS/BTC',
#    'percent_volume': 0.144208923524,
#    'price': 1.00669,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1220.26},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.143493796111,
#    'price': 1.0028,
#    'source': 'Gate.io',
#    'updated': True,
#    'volume_24h': 1214.22},
#   {'pair': 'STR/BTC',
#    'percent_volume': 0.142820437202,
#    'price': 0.992862,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 1208.52},
#   {'pair': 'CMT/BTC',
#    'percent_volume': 0.137475334433,
#    'price': 1.0083,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 1163.29},
#   {'pair': 'NEBL/BTC',
#    'percent_volume': 0.136829821193,
#    'price': 0.999477,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1157.83},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.136543770228,
#    'price': 0.998435,
#    'source': 'EXX',
#    'updated': True,
#    'volume_24h': 1155.4},
#   {'pair': 'WTC/BTC',
#    'percent_volume': 0.134411045111,
#    'price': 1.00073,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1137.36},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.133327595438,
#    'price': 0.994037,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 1128.19},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.133171912833,
#    'price': 0.994111,
#    'source': 'IDAX',
#    'updated': True,
#    'volume_24h': 1126.87},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.133080781552,
#    'price': 0.999909,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 1126.1},
#   {'pair': 'SNT/BTC',
#    'percent_volume': 0.13118854176,
#    'price': 1.00281,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1110.08},
#   {'pair': 'WAVES/BTC',
#    'percent_volume': 0.130989824939,
#    'price': 1.00727,
#    'source': 'Tidex',
#    'updated': True,
#    'volume_24h': 1108.41},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.129987380849,
#    'price': 1.05577,
#    'source': 'LakeBTC',
#    'updated': True,
#    'volume_24h': 1099.93},
#   {'pair': 'WAVES/BTC',
#    'percent_volume': 0.129901312417,
#    'price': 0.997017,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 1099.19},
#   {'pair': 'BTC/KRW',
#    'percent_volume': 0.126409971787,
#    'price': 1.01272,
#    'source': 'Korbit',
#    'updated': True,
#    'volume_24h': 1069.65},
#   {'pair': 'LINK/BTC',
#    'percent_volume': 0.123447825443,
#    'price': 1.00187,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1044.59},
#   {'pair': 'GVT/BTC',
#    'percent_volume': 0.122472847308,
#    'price': 1.00435,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1036.34},
#   {'pair': 'SUB/BTC',
#    'percent_volume': 0.1211995408,
#    'price': 1.00341,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1025.56},
#   {'pair': 'NANJ/BTC',
#    'percent_volume': 0.120363537868,
#    'price': 1.00206,
#    'source': 'CoinExchange',
#    'updated': True,
#    'volume_24h': 1018.49},
#   {'pair': 'BTC/PLN',
#    'percent_volume': 0.120095333446,
#    'price': 0.999286,
#    'source': 'BitBay',
#    'updated': True,
#    'volume_24h': 1016.22},
#   {'pair': 'BTC/GBP',
#    'percent_volume': 0.119980153632,
#    'price': 1.00089,
#    'source': 'CoinsBank',
#    'updated': True,
#    'volume_24h': 1015.25},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.119854594978,
#    'price': 0.996868,
#    'source': 'CoinTiger',
#    'updated': True,
#    'volume_24h': 1014.18},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.0,
#    'price': 1.00687,
#    'source': 'YoBit',
#    'updated': False,
#    'volume_24h': 1009.84},
#   {'pair': 'QLC/BTC',
#    'percent_volume': 0.118932397044,
#    'price': 1.00193,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1006.38},
#   {'pair': 'EDO/BTC',
#    'percent_volume': 0.116949405685,
#    'price': 1.00614,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 989.6},
#   {'pair': 'BQX/BTC',
#    'percent_volume': 0.115323598319,
#    'price': 1.00608,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 975.843},
#   {'pair': 'RDD/BTC',
#    'percent_volume': 0.113620202792,
#    'price': 1.00153,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 961.43},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0,
#    'price': 1.00293,
#    'source': 'YoBit',
#    'updated': False,
#    'volume_24h': 941.654},
#   {'pair': 'HSR/BTC',
#    'percent_volume': 0.110889428645,
#    'price': 1.00477,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 938.322},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.109079333577,
#    'price': 0.996776,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 923.005},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.108838088825,
#    'price': 0.995703,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 920.964},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.106891170265,
#    'price': 0.998847,
#    'source': 'RightBTC',
#    'updated': True,
#    'volume_24h': 904.49},
#   {'pair': 'STEEM/BTC',
#    'percent_volume': 0.104441257662,
#    'price': 1.00643,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 883.759},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.10392788478,
#    'price': 0.99796,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 879.415},
#   {'pair': 'VEN/BTC',
#    'percent_volume': 0.103622848131,
#    'price': 1.00109,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 876.833},
#   {'pair': 'ENG/BTC',
#    'percent_volume': 0.103081249866,
#    'price': 1.00431,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 872.251},
#   {'pair': 'SC/BTC',
#    'percent_volume': 0.100552103677,
#    'price': 1.00406,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 850.85},
#   {'pair': 'ZEC/BTC',
#    'percent_volume': 0.100328578896,
#    'price': 0.998724,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 848.959},
#   {'pair': 'SYS/BTC',
#    'percent_volume': 0.100269470135,
#    'price': 1.00586,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 848.459},
#   {'pair': 'IOST/BTC',
#    'percent_volume': 0.0998521648109,
#    'price': 1.01105,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 844.927},
#   {'pair': 'BTM/BTC',
#    'percent_volume': 0.0998506459562,
#    'price': 1.00755,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 844.915},
#   {'pair': 'MCO/BTC',
#    'percent_volume': 0.0990499563962,
#    'price': 0.985827,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 838.139},
#   {'pair': 'IOTA/BTC',
#    'percent_volume': 0.0982024354835,
#    'price': 0.999371,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 830.967},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.0971532866117,
#    'price': 0.997968,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 822.09},
#   {'pair': 'APPC/BTC',
#    'percent_volume': 0.0966070052109,
#    'price': 1.00301,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 817.467},
#   {'pair': 'CMT/BTC',
#    'percent_volume': 0.0960504715411,
#    'price': 1.01425,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 812.758},
#   {'pair': 'STEEM/BTC',
#    'percent_volume': 0.0960151581697,
#    'price': 1.00645,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 812.459},
#   {'pair': 'BTC/RUB',
#    'percent_volume': 0.0957107543771,
#    'price': 0.921618,
#    'source': 'Exmo',
#    'updated': True,
#    'volume_24h': 809.883},
#   {'pair': 'ADA/BTC',
#    'percent_volume': 0.0933684273146,
#    'price': 0.948134,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 790.064},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.0930798449249,
#    'price': 0.999338,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 787.621},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.093029469578,
#    'price': 1.00972,
#    'source': 'Bitinka',
#    'updated': True,
#    'volume_24h': 787.195},
#   {'pair': 'SALT/BTC',
#    'percent_volume': 0.0927835416907,
#    'price': 0.997399,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 785.113},
#   {'pair': 'ELA/BTC',
#    'percent_volume': 0.0927626574388,
#    'price': 0.9981,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 784.937},
#   {'pair': 'PROPY/BTC',
#    'percent_volume': 0.0927617714402,
#    'price': 1.01336,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 784.93},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0921224601902,
#    'price': 1.0265,
#    'source': 'TOPBTC',
#    'updated': True,
#    'volume_24h': 779.52},
#   {'pair': 'BTM/BTC',
#    'percent_volume': 0.090805233467,
#    'price': 1.00612,
#    'source': 'RightBTC',
#    'updated': True,
#    'volume_24h': 768.375},
#   {'pair': 'IQT/BTC',
#    'percent_volume': 0.0907376444336,
#    'price': 1.00199,
#    'source': 'Iquant',
#    'updated': True,
#    'volume_24h': 767.802},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0902181961322,
#    'price': 0.999763,
#    'source': 'CEX.IO',
#    'updated': True,
#    'volume_24h': 763.407},
#   {'pair': 'SWFTC/BTC',
#    'percent_volume': 0.0894692742026,
#    'price': 1.00422,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 757.069},
#   {'pair': 'ENJ/BTC',
#    'percent_volume': 0.0893916860426,
#    'price': 1.00332,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 756.413},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0889050196882,
#    'price': 1.00039,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 752.294},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0885439119874,
#    'price': 1.0027,
#    'source': 'Livecoin',
#    'updated': True,
#    'volume_24h': 749.239},
#   {'pair': 'ZEC/BTC',
#    'percent_volume': 0.0878463779746,
#    'price': 1.00879,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 743.337},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0864146042941,
#    'price': 1.00515,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 731.221},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0859828698506,
#    'price': 0.999453,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 727.568},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0854389933031,
#    'price': 1.00009,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 722.966},
#   {'pair': 'INT/BTC',
#    'percent_volume': 0.0852935629673,
#    'price': 1.0062,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 721.736},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0836650976054,
#    'price': 0.995703,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 707.955},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.0834567613715,
#    'price': 1.00023,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 706.192},
#   {'pair': 'BCN/BTC',
#    'percent_volume': 0.0832691828182,
#    'price': 1.00371,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 704.605},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.0808620512892,
#    'price': 1.00905,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 684.237},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0797429085308,
#    'price': 1.00181,
#    'source': 'EXX',
#    'updated': True,
#    'volume_24h': 674.767},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.0789544963794,
#    'price': 1.00194,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 668.096},
#   {'pair': 'ZIL/BTC',
#    'percent_volume': 0.0783212605481,
#    'price': 1.00265,
#    'source': 'OOOBTC',
#    'updated': True,
#    'volume_24h': 662.738},
#   {'pair': 'MIOTA/BTC',
#    'percent_volume': 0.077476903916,
#    'price': 0.998007,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 655.593},
#   {'pair': 'SOC/BTC',
#    'percent_volume': 0.0756881993851,
#    'price': 1.05549,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 640.457},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0754661934591,
#    'price': 0.999726,
#    'source': 'GDAX',
#    'updated': True,
#    'volume_24h': 638.579},
#   {'pair': 'XPM/BTC',
#    'percent_volume': 0.0750102839119,
#    'price': 1.04184,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 634.721},
#   {'pair': 'VIA/BTC',
#    'percent_volume': 0.0746099391319,
#    'price': 1.0017,
#    'source': 'OOOBTC',
#    'updated': True,
#    'volume_24h': 631.332},
#   {'pair': 'TRIG/BTC',
#    'percent_volume': 0.0737452045328,
#    'price': 0.996008,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 624.016},
#   {'pair': 'BTC/BITCNY',
#    'percent_volume': 0.0735602839752,
#    'price': 1.01106,
#    'source': 'CoinTiger',
#    'updated': True,
#    'volume_24h': 622.451},
#   {'pair': 'SOC/BTC',
#    'percent_volume': 0.073325747498,
#    'price': 1.00572,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 620.467},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.0729281872849,
#    'price': 1.04183,
#    'source': 'Exrates',
#    'updated': True,
#    'volume_24h': 617.102},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0728102229046,
#    'price': 0.999809,
#    'source': 'itBit',
#    'updated': True,
#    'volume_24h': 616.104},
#   {'pair': 'ONT/BTC',
#    'percent_volume': 0.0726571982953,
#    'price': 0.949057,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 614.81},
#   {'pair': 'BTM/BTC',
#    'percent_volume': 0.0726107466563,
#    'price': 1.00607,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 614.416},
#   {'pair': 'ELF/BTC',
#    'percent_volume': 0.0725275893624,
#    'price': 0.964753,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 613.712},
#   {'pair': 'STRAT/BTC',
#    'percent_volume': 0.0716737398885,
#    'price': 1.00174,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 606.487},
#   {'pair': 'BTC/CNY',
#    'percent_volume': 0.0698175728955,
#    'price': 1.01823,
#    'source': 'Fatbtc',
#    'updated': True,
#    'volume_24h': 590.781},
#   {'pair': 'BANCA/BTC',
#    'percent_volume': 0.0697616284147,
#    'price': 0.996347,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 590.307},
#   {'pair': 'NULS/BTC',
#    'percent_volume': 0.0683517515559,
#    'price': 1.00671,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 578.378},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.0668766905169,
#    'price': 1.00139,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 565.896},
#   {'pair': 'POE/BTC',
#    'percent_volume': 0.0667437907322,
#    'price': 1.02549,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 564.772},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0664038204258,
#    'price': 1.00471,
#    'source': 'Exrates',
#    'updated': True,
#    'volume_24h': 561.894},
#   {'pair': 'CLOAK/BTC',
#    'percent_volume': 0.0662485175345,
#    'price': 0.99948,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 560.581},
#   {'pair': 'IOST/BTC',
#    'percent_volume': 0.0659352537563,
#    'price': 1.0153,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 557.93},
#   {'pair': 'BTG/BTC',
#    'percent_volume': 0.0656727450387,
#    'price': 1.00308,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 555.708},
#   {'pair': 'GNT/BTC',
#    'percent_volume': 0.0651048199588,
#    'price': 1.00377,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 550.902},
#   {'pair': 'BTM/BTC',
#    'percent_volume': 0.0644238667762,
#    'price': 0.990677,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 545.14},
#   {'pair': 'SC/BTC',
#    'percent_volume': 0.0636260883543,
#    'price': 1.00406,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 538.39},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.0635395136374,
#    'price': 1.0125,
#    'source': 'Bitinka',
#    'updated': True,
#    'volume_24h': 537.658},
#   {'pair': 'ACT/BTC',
#    'percent_volume': 0.0623070896339,
#    'price': 0.983185,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 527.229},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.0622945590828,
#    'price': 1.00316,
#    'source': 'OTCBTC',
#    'updated': True,
#    'volume_24h': 527.122},
#   {'pair': 'BTC/GBP',
#    'percent_volume': 0.0,
#    'price': 0.995908,
#    'source': 'Coinfloor',
#    'updated': False,
#    'volume_24h': 526.477},
#   {'pair': 'HSR/BTC',
#    'percent_volume': 0.0622081109371,
#    'price': 0.998871,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 526.391},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.062003065555,
#    'price': 0.998908,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 524.656},
#   {'pair': 'ABT/BTC',
#    'percent_volume': 0.0618111835802,
#    'price': 1.01074,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 523.033},
#   {'pair': 'GXS/BTC',
#    'percent_volume': 0.0614147625081,
#    'price': 1.01024,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 519.678},
#   {'pair': 'DGB/BTC',
#    'percent_volume': 0.0608178526179,
#    'price': 1.0025,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 514.627},
#   {'pair': 'WICC/BTC',
#    'percent_volume': 0.060393206163,
#    'price': 0.99834,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 511.034},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0601701876672,
#    'price': 0.996851,
#    'source': 'Exrates',
#    'updated': True,
#    'volume_24h': 509.147},
#   {'pair': 'ELF/BTC',
#    'percent_volume': 0.0601252548828,
#    'price': 0.966963,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 508.766},
#   {'pair': 'ABT/BTC',
#    'percent_volume': 0.0599238800662,
#    'price': 1.01162,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 507.063},
#   {'pair': 'ZEC/BTC',
#    'percent_volume': 0.0,
#    'price': 1.01068,
#    'source': 'YoBit',
#    'updated': False,
#    'volume_24h': 507.002},
#   {'pair': 'POWR/BTC',
#    'percent_volume': 0.0596397276694,
#    'price': 1.00182,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 504.658},
#   {'pair': 'PRA/BTC',
#    'percent_volume': 0.059574416918,
#    'price': 1.00204,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 504.106},
#   {'pair': 'BCPT/BTC',
#    'percent_volume': 0.0589786461689,
#    'price': 1.00075,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 499.065},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0589034628621,
#    'price': 1.00173,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 498.428},
#   {'pair': 'AION/BTC',
#    'percent_volume': 0.0583484480469,
#    'price': 1.0025,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 493.732},
#   {'pair': 'AE/BTC',
#    'percent_volume': 0.0580326528442,
#    'price': 1.00743,
#    'source': 'OOOBTC',
#    'updated': True,
#    'volume_24h': 491.059},
#   {'pair': 'SYS/BTC',
#    'percent_volume': 0.0572325961403,
#    'price': 1.00474,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 484.289},
#   {'pair': 'OMG/BTC',
#    'percent_volume': 0.057093114652,
#    'price': 0.99885,
#    'source': 'IDAX',
#    'updated': True,
#    'volume_24h': 483.11},
#   {'pair': 'BTC/GBP',
#    'percent_volume': 0.0570046413668,
#    'price': 1.00048,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 482.36},
#   {'pair': 'ZIL/BTC',
#    'percent_volume': 0.0563640644045,
#    'price': 0.998278,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 476.94},
#   {'pair': 'WAVES/BTC',
#    'percent_volume': 0.0562555928659,
#    'price': 0.997195,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 476.022},
#   {'pair': 'SWFTC/BTC',
#    'percent_volume': 0.0553569371789,
#    'price': 0.997293,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 468.419},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.054748256165,
#    'price': 1.00191,
#    'source': 'Tidex',
#    'updated': True,
#    'volume_24h': 463.267},
#   {'pair': 'RCN/BTC',
#    'percent_volume': 0.0545556147628,
#    'price': 0.996765,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 461.638},
#   {'pair': 'BTC/TRY',
#    'percent_volume': 0.0543341151216,
#    'price': 0.988123,
#    'source': 'Paribu',
#    'updated': True,
#    'volume_24h': 459.764},
#   {'pair': 'BTC/TRY',
#    'percent_volume': 0.0531614327356,
#    'price': 0.99024,
#    'source': 'Sistemkoin',
#    'updated': True,
#    'volume_24h': 449.84},
#   {'pair': 'XLM/BTC',
#    'percent_volume': 0.0531515601802,
#    'price': 0.998815,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 449.756},
#   {'pair': 'PPT/BTC',
#    'percent_volume': 0.052734128285,
#    'price': 1.00264,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 446.224},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.0521234221315,
#    'price': 0.995809,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 441.056},
#   {'pair': 'KNC/BTC',
#    'percent_volume': 0.0518254734713,
#    'price': 1.00724,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 438.536},
#   {'pair': 'BTC/ARS',
#    'percent_volume': 0.0512189441682,
#    'price': 1.04473,
#    'source': 'Bitinka',
#    'updated': True,
#    'volume_24h': 433.404},
#   {'pair': 'SC/BTC',
#    'percent_volume': 0.0512108436099,
#    'price': 1.02349,
#    'source': 'fex',
#    'updated': True,
#    'volume_24h': 433.335},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.0506934204481,
#    'price': 1.03725,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 428.957},
#   {'pair': 'LSK/BTC',
#    'percent_volume': 0.0,
#    'price': 1.01751,
#    'source': 'YoBit',
#    'updated': False,
#    'volume_24h': 426.532},
#   {'pair': 'AUTO/BTC',
#    'percent_volume': 0.0503183899128,
#    'price': 1.00081,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 425.783},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0501515690402,
#    'price': 1.00523,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 424.371},
#   {'pair': 'LRC/BTC',
#    'percent_volume': 0.0493065795519,
#    'price': 1.00389,
#    'source': 'IDAX',
#    'updated': True,
#    'volume_24h': 417.222},
#   {'pair': 'GTC/BTC',
#    'percent_volume': 0.04856879589,
#    'price': 1.01045,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 410.978},
#   {'pair': 'BTC/BRL',
#    'percent_volume': 0.0478883489923,
#    'price': 1.04057,
#    'source': 'Negocie Coins',
#    'updated': True,
#    'volume_24h': 405.221},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.0478113936884,
#    'price': 1.00242,
#    'source': 'ZB.COM',
#    'updated': True,
#    'volume_24h': 404.569},
#   {'pair': 'ZRX/BTC',
#    'percent_volume': 0.0473058682216,
#    'price': 1.00367,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 400.292},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.047149805903,
#    'price': 0.998157,
#    'source': 'CoinTiger',
#    'updated': True,
#    'volume_24h': 398.971},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0469450136634,
#    'price': 0.996884,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 397.239},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0468862846156,
#    'price': 1.00012,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 396.741},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.0466975669214,
#    'price': 0.997718,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 395.144},
#   {'pair': 'SNT/BTC',
#    'percent_volume': 0.0458862453786,
#    'price': 1.00221,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 388.279},
#   {'pair': 'BOT/BTC',
#    'percent_volume': 0.0458637157008,
#    'price': 0.995628,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 388.089},
#   {'pair': 'LSK/BTC',
#    'percent_volume': 0.0454713449078,
#    'price': 0.996895,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 384.768},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.0453322431332,
#    'price': 0.998291,
#    'source': 'Liqui',
#    'updated': True,
#    'volume_24h': 383.591},
#   {'pair': 'SNT/BTC',
#    'percent_volume': 0.0450899858114,
#    'price': 0.998633,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 381.542},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0448472222046,
#    'price': 0.998009,
#    'source': 'CoinBene',
#    'updated': True,
#    'volume_24h': 379.487},
#   {'pair': 'BTM/BTC',
#    'percent_volume': 0.0445187698796,
#    'price': 0.980674,
#    'source': 'EXX',
#    'updated': True,
#    'volume_24h': 376.708},
#   {'pair': 'TRUE/BTC',
#    'percent_volume': 0.0444208037526,
#    'price': 2.18563,
#    'source': 'OEX',
#    'updated': True,
#    'volume_24h': 375.879},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0443523287207,
#    'price': 1.00173,
#    'source': 'xBTCe',
#    'updated': True,
#    'volume_24h': 375.3},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0443523287207,
#    'price': 1.00173,
#    'source': 'Omicrex',
#    'updated': True,
#    'volume_24h': 375.3},
#   {'pair': 'HSR/BTC',
#    'percent_volume': 0.0442530968814,
#    'price': 1.13487,
#    'source': 'TOPBTC',
#    'updated': True,
#    'volume_24h': 374.46},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0435261983447,
#    'price': 0.985345,
#    'source': 'BtcTrade.im',
#    'updated': True,
#    'volume_24h': 368.309},
#   {'pair': 'BTC/IDR',
#    'percent_volume': 0.0431873671793,
#    'price': 0.987613,
#    'source': 'Indodax',
#    'updated': True,
#    'volume_24h': 365.443},
#   {'pair': 'NKC/BTC',
#    'percent_volume': 0.0431749631994,
#    'price': 1.00695,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 365.338},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.0423033937542,
#    'price': 1.00067,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 357.962},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.0415723183671,
#    'price': 0.997473,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 351.776},
#   {'pair': 'WPR/BTC',
#    'percent_volume': 0.0414494177091,
#    'price': 1.00302,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 350.736},
#   {'pair': 'LRC/BTC',
#    'percent_volume': 0.0414224580385,
#    'price': 1.00154,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 350.507},
#   {'pair': 'BTC/CNY',
#    'percent_volume': 0.0409056677328,
#    'price': 0.98299,
#    'source': 'Octaex',
#    'updated': True,
#    'volume_24h': 346.135},
#   {'pair': 'DCR/BTC',
#    'percent_volume': 0.0407146717565,
#    'price': 0.99464,
#    'source': 'fex',
#    'updated': True,
#    'volume_24h': 344.519},
#   {'pair': 'XLM/BTC',
#    'percent_volume': 0.0404455813353,
#    'price': 0.995939,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 342.241},
#   {'pair': 'XMR/BTC',
#    'percent_volume': 0.0403879914286,
#    'price': 1.00088,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 341.754},
#   {'pair': 'BTC/GBP',
#    'percent_volume': 0.0402134497114,
#    'price': 1.00373,
#    'source': 'GDAX',
#    'updated': True,
#    'volume_24h': 340.278},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.0402040834408,
#    'price': 0.997304,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 340.198},
#   {'pair': 'INS/BTC',
#    'percent_volume': 0.0400123280372,
#    'price': 1.00044,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 338.576},
#   {'pair': 'QBT/BTC',
#    'percent_volume': 0.0399484095693,
#    'price': 0.930495,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 338.035},
#   {'pair': 'HPB/BTC',
#    'percent_volume': 0.0399186653318,
#    'price': 0.999379,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 337.782},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0398450008797,
#    'price': 1.00272,
#    'source': 'CoinEx',
#    'updated': True,
#    'volume_24h': 337.16},
#   {'pair': 'XEM/BTC',
#    'percent_volume': 0.0396913434143,
#    'price': 0.996105,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 335.86},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0396046421262,
#    'price': 0.997024,
#    'source': 'Coinhub',
#    'updated': True,
#    'volume_24h': 335.126},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0394857917473,
#    'price': 0.996714,
#    'source': 'TOPBTC',
#    'updated': True,
#    'volume_24h': 334.12},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.0391601239892,
#    'price': 1.00151,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 331.364},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.0389400166315,
#    'price': 1.00288,
#    'source': 'Exmo',
#    'updated': True,
#    'volume_24h': 329.502},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.0388759715924,
#    'price': 1.00968,
#    'source': 'Coinroom',
#    'updated': True,
#    'volume_24h': 328.96},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0382796945583,
#    'price': 1.00096,
#    'source': 'Exmo',
#    'updated': True,
#    'volume_24h': 323.915},
#   {'pair': 'TIX/BTC',
#    'percent_volume': 0.0380861671576,
#    'price': 1.007,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 322.277},
#   {'pair': 'XDN/BTC',
#    'percent_volume': 0.0378091027493,
#    'price': 1.00339,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 319.932},
#   {'pair': 'AST/BTC',
#    'percent_volume': 0.0377584742598,
#    'price': 1.00696,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 319.504},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.0373986322714,
#    'price': 0.997169,
#    'source': 'Ethfinex',
#    'updated': True,
#    'volume_24h': 316.459},
#   {'pair': 'BLZ/BTC',
#    'percent_volume': 0.0372830727443,
#    'price': 1.00534,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 315.482},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.0372577584996,
#    'price': 0.999415,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 315.267},
#   {'pair': 'MDA/BTC',
#    'percent_volume': 0.0372276345484,
#    'price': 0.999335,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 315.012},
#   {'pair': 'ZEC/BTC',
#    'percent_volume': 0.0369525952797,
#    'price': 1.00912,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 312.685},
#   {'pair': 'INS/BTC',
#    'percent_volume': 0.0368700708419,
#    'price': 0.999409,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 311.986},
#   {'pair': 'LRC/BTC',
#    'percent_volume': 0.0368658939915,
#    'price': 1.00154,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 311.951},
#   {'pair': 'XPM/BTC',
#    'percent_volume': 0.0366274338064,
#    'price': 0.925607,
#    'source': 'Cryptopia',
#    'updated': True,
#    'volume_24h': 309.934},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0364760546231,
#    'price': 1.00041,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 308.652},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0363493568283,
#    'price': 0.999015,
#    'source': 'Kucoin',
#    'updated': True,
#    'volume_24h': 307.58},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0362184821832,
#    'price': 0.995303,
#    'source': 'Hotbit',
#    'updated': True,
#    'volume_24h': 306.473},
#   {'pair': 'STC/BTC',
#    'percent_volume': 0.0361624111312,
#    'price': 0.997913,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 305.999},
#   {'pair': 'MANA/BTC',
#    'percent_volume': 0.0359664788772,
#    'price': 1.08401,
#    'source': 'TOPBTC',
#    'updated': True,
#    'volume_24h': 304.34},
#   {'pair': 'DADI/BTC',
#    'percent_volume': 0.0357645977756,
#    'price': 0.998189,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 302.632},
#   {'pair': 'STORJ/BTC',
#    'percent_volume': 0.0355894232023,
#    'price': 1.00587,
#    'source': 'IDAX',
#    'updated': True,
#    'volume_24h': 301.15},
#   {'pair': 'MCO/BTC',
#    'percent_volume': 0.03553436472,
#    'price': 0.980623,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 300.684},
#   {'pair': 'ZEC/BTC',
#    'percent_volume': 0.0354145017714,
#    'price': 1.00865,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 299.67},
#   {'pair': 'BTC/BRL',
#    'percent_volume': 0.0354141220577,
#    'price': 1.02903,
#    'source': 'Bitinka',
#    'updated': True,
#    'volume_24h': 299.666},
#   {'pair': 'ITC/BTC',
#    'percent_volume': 0.0350379523814,
#    'price': 1.0033,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 296.484},
#   {'pair': 'ACT/BTC',
#    'percent_volume': 0.0348340461403,
#    'price': 1.00818,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 294.758},
#   {'pair': 'MTN/BTC',
#    'percent_volume': 0.0347878476437,
#    'price': 1.01214,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 294.368},
#   {'pair': 'IHT/BTC',
#    'percent_volume': 0.0347856959329,
#    'price': 1.00718,
#    'source': 'OEX',
#    'updated': True,
#    'volume_24h': 294.349},
#   {'pair': 'XLM/BTC',
#    'percent_volume': 0.0347760765199,
#    'price': 0.998815,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 294.268},
#   {'pair': 'CND/BTC',
#    'percent_volume': 0.034538882047,
#    'price': 1.00079,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 292.26},
#   {'pair': 'BTS/BTC',
#    'percent_volume': 0.034183849765,
#    'price': 1.00159,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 289.256},
#   {'pair': 'TCT/BTC',
#    'percent_volume': 0.0341115775964,
#    'price': 0.980731,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 288.645},
#   {'pair': 'REQ/BTC',
#    'percent_volume': 0.0340815802164,
#    'price': 1.00402,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 288.391},
#   {'pair': 'CMT/BTC',
#    'percent_volume': 0.0340775299373,
#    'price': 1.00512,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 288.357},
#   {'pair': 'VIBE/BTC',
#    'percent_volume': 0.0337190802322,
#    'price': 0.997186,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 285.323},
#   {'pair': 'XMR/BTC',
#    'percent_volume': 0.0336897157084,
#    'price': 0.998568,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 285.075},
#   {'pair': 'LSK/BTC',
#    'percent_volume': 0.033503782581,
#    'price': 0.99793,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 283.502},
#   {'pair': 'LSK/BTC',
#    'percent_volume': 0.0333437965545,
#    'price': 1.00823,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 282.148},
#   {'pair': 'DGD/BTC',
#    'percent_volume': 0.0331229297694,
#    'price': 1.00027,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 280.279},
#   {'pair': 'OCN/BTC',
#    'percent_volume': 0.0331182466342,
#    'price': 1.00339,
#    'source': 'Kucoin',
#    'updated': True,
#    'volume_24h': 280.24},
#   {'pair': 'CMT/BTC',
#    'percent_volume': 0.0330191413661,
#    'price': 0.978238,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 279.401},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.0328720656044,
#    'price': 1.00076,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 278.157},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.0325357658635,
#    'price': 1.00039,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 275.31},
#   {'pair': 'BTC/ZAR',
#    'percent_volume': 0.0316878652371,
#    'price': 1.02995,
#    'source': 'Luno',
#    'updated': True,
#    'volume_24h': 268.136},
#   {'pair': 'SC/BTC',
#    'percent_volume': 0.0315253477861,
#    'price': 1.01045,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 266.76},
#   {'pair': 'TIX/BTC',
#    'percent_volume': 0.0314571258966,
#    'price': 1.00871,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 266.184},
#   {'pair': 'CAN/BTC',
#    'percent_volume': 0.0313816894474,
#    'price': 1.0217,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 265.545},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0312424611015,
#    'price': 1.00065,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 264.367},
#   {'pair': 'XAS/BTC',
#    'percent_volume': 0.0311937311804,
#    'price': 0.99573,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 263.954},
#   {'pair': 'ARK/BTC',
#    'percent_volume': 0.0310314668719,
#    'price': 0.999381,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 262.582},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0305861893075,
#    'price': 0.998068,
#    'source': 'Bitstamp',
#    'updated': True,
#    'volume_24h': 258.813},
#   {'pair': 'BCD/BTC',
#    'percent_volume': 0.030484552615,
#    'price': 1.20012,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 257.953},
#   {'pair': 'DOGE/BTC',
#    'percent_volume': 0.0303931681916,
#    'price': 1.0724,
#    'source': 'BtcTrade.im',
#    'updated': True,
#    'volume_24h': 257.181},
#   {'pair': 'OMG/BTC',
#    'percent_volume': 0.0303189974547,
#    'price': 1.00064,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 256.553},
#   {'pair': 'BTC/RUR',
#    'percent_volume': 0.0302225501823,
#    'price': 0.971177,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 255.736},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.0301531891518,
#    'price': 1.00317,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 255.149},
#   {'pair': 'SNT/BTC',
#    'percent_volume': 0.0300678801472,
#    'price': 0.996558,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 254.428},
#   {'pair': 'BTC/THB',
#    'percent_volume': 0.0299926968404,
#    'price': 0.980197,
#    'source': 'BX Thailand',
#    'updated': True,
#    'volume_24h': 253.792},
#   {'pair': 'TNB/BTC',
#    'percent_volume': 0.0299424480647,
#    'price': 0.992728,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 253.367},
#   {'pair': 'OMG/BTC',
#    'percent_volume': 0.0295503304142,
#    'price': 0.997338,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 250.049},
#   {'pair': 'DGB/BTC',
#    'percent_volume': 0.0294726156829,
#    'price': 1.00462,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 249.391},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0290354386769,
#    'price': 1.00176,
#    'source': 'Kucoin',
#    'updated': True,
#    'volume_24h': 245.692},
#   {'pair': 'DOGE/BTC',
#    'percent_volume': 0.0290013910177,
#    'price': 0.999694,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 245.403},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.0288957040461,
#    'price': 0.996401,
#    'source': 'BigONE',
#    'updated': True,
#    'volume_24h': 244.509},
#   {'pair': 'BTC/PEN',
#    'percent_volume': 0.0285776305614,
#    'price': 0.975605,
#    'source': 'Bitinka',
#    'updated': True,
#    'volume_24h': 241.818},
#   {'pair': 'BTC/KRW',
#    'percent_volume': 0.0285449751857,
#    'price': 1.00956,
#    'source': 'GOPAX',
#    'updated': True,
#    'volume_24h': 241.541},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.0,
#    'price': 0.991091,
#    'source': 'YoBit',
#    'updated': False,
#    'volume_24h': 239.614},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0283047430035,
#    'price': 0.999974,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 239.509},
#   {'pair': 'FUN/BTC',
#    'percent_volume': 0.028304489861,
#    'price': 1.00084,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 239.506},
#   {'pair': 'DSH/BTC',
#    'percent_volume': 0.0283042367186,
#    'price': 0.99798,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 239.504},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0282915795962,
#    'price': 0.978375,
#    'source': 'Trade By Trade',
#    'updated': True,
#    'volume_24h': 239.398},
#   {'pair': 'BAT/BTC',
#    'percent_volume': 0.0282832258955,
#    'price': 0.990144,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 239.326},
#   {'pair': 'SRN/BTC',
#    'percent_volume': 0.0279950232195,
#    'price': 1.00322,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 236.888},
#   {'pair': 'KCASH/BTC',
#    'percent_volume': 0.0276834048672,
#    'price': 1.0002,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 234.251},
#   {'pair': 'MANA/BTC',
#    'percent_volume': 0.0276810000139,
#    'price': 0.988283,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 234.231},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0,
#    'price': 1.00076,
#    'source': 'BitMEX',
#    'updated': True,
#    'volume_24h': 359568.0},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.0,
#    'price': 0.995196,
#    'source': 'Zaif',
#    'updated': True,
#    'volume_24h': 13772.5},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.0,
#    'price': 0.994616,
#    'source': 'Fisco',
#    'updated': True,
#    'volume_24h': 13762.5},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.0,
#    'price': 0.994621,
#    'source': 'Quoine',
#    'updated': True,
#    'volume_24h': 13494.3},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0,
#    'price': 0.996977,
#    'source': 'Quoine',
#    'updated': True,
#    'volume_24h': 2407.66},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0,
#    'price': 1.02023,
#    'source': 'Neraex',
#    'updated': True,
#    'volume_24h': 2147.04},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0,
#    'price': 1.00301,
#    'source': 'ZB.COM',
#    'updated': True,
#    'volume_24h': 458.805},
#   {'pair': 'MFG/BTC',
#    'percent_volume': 0.0,
#    'price': 1.00282,
#    'source': 'Cobinhood',
#    'updated': True,
#    'volume_24h': 395.281},
#   {'pair': 'B2X/BTC',
#    'percent_volume': 0.0,
#    'price': 2.69129e-05,
#    'source': 'Negocie Coins',
#    'updated': True,
#    'volume_24h': 2068.16}],
#  'slug': 'bitcoin',
#  'symbol': 'BTC'}

# %%
show_page("currencies/bitcoin/#markets")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/currencies/bitcoin/#markets"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `ranks()`
# Get gainers and losers rankings:

# %%
cmc.ranks()
# Out:
# {'gainers': {'1h': [{'name': '<span data-global-stats-markets></span>',
#     'percent_change': 29.1,
#     'price': 0.000256015,
#     'slug': 'volume/24-hour',
#     'symbol': 'CUBE',
#     'volume_24h': 413131.0},
#    {'name': '<span data-global-stats-markets></span>',
#     'percent_change': 23.24,
#     'price': 0.000426692,
#     'slug': 'volume/24-hour',
#     'symbol': 'BIRDS',
#     'volume_24h': 131343.0},
#    {'name': '24 Hour Volume Rankings (Currency)',
#     'percent_change': 21.27,
#     'price': 0.169219,
#     'slug': 'volume/24-hour',
#     'symbol': 'ODE',
#     'volume_24h': 83188.7},
#    {'name': 'Monthly Volume Rankings (Currency)',
#     'percent_change': 16.71,
#     'price': 0.000421171,
#     'slug': 'volume/monthly',
#     'symbol': 'HTML',
#     'volume_24h': 111832.0},
#    {'name': '24 Hour Volume Rankings (Currency)',
#     'percent_change': 16.46,
#     'price': 0.123741,
#     'slug': 'volume/24-hour',
#     'symbol': 'BELA',
#     'volume_24h': 586062.0},
#    {'name': 'Monthly Volume Rankings (Currency)',
#     'percent_change': 13.13,
#     'price': 2325.74,
#     'slug': 'volume/monthly',
#     'symbol': 'PBT',
#     'volume_24h': 593484.0},
#    {'name': 'DigiCube',
#     'percent_change': 12.29,
#     'price': 8.77178,
#     'slug': 'digicube',
#     'symbol': 'FRGC',
#     'volume_24h': 932147.0},
#    {'name': 'Birds',
#     'percent_change': 10.35,
#     'price': 0.00123997,
#     'slug': 'birds',
#     'symbol': 'SRCOIN',
#     'volume_24h': 110013.0},
#    {'name': 'ODEM',
#     'percent_change': 10.2,
#     'price': 0.0541413,
#     'slug': 'odem',
#     'symbol': 'RNTB',
#     'volume_24h': 902854.0},
#    {'name': 'HTMLCOIN',
#     'percent_change': 8.85,
#     'price': 0.000342101,
#     'slug': 'html-coin',
#     'symbol': 'LIFE',
#     'volume_24h': 97770.4},
#    {'name': 'Bela',
#     'percent_change': 7.91,
#     'price': 1.89989,
#     'slug': 'belacoin',
#     'symbol': 'PHR',
#     'volume_24h': 185824.0},
#    {'name': 'Primalbase Token',
#     'percent_change': 6.82,
#     'price': 0.844625,
#     'slug': 'primalbase',
#     'symbol': 'B2B',
#     'volume_24h': 378258.0},
#    {'name': 'Fargocoin',
#     'percent_change': 6.72,
#     'price': 5.33728,
#     'slug': 'fargocoin',
#     'symbol': 'PIVX',
#     'volume_24h': 19420700.0},
#    {'name': 'SRCOIN',
#     'percent_change': 6.07,
#     'price': 3.97391,
#     'slug': 'srcoin',
#     'symbol': 'ICX',
#     'volume_24h': 190260000.0},
#    {'name': 'BitRent',
#     'percent_change': 5.75,
#     'price': 0.0112114,
#     'slug': 'bitrent',
#     'symbol': 'NCT',
#     'volume_24h': 162054.0},
#    {'name': 'LIFE',
#     'percent_change': 4.57,
#     'price': 0.100273,
#     'slug': 'life',
#     'symbol': 'ATC',
#     'volume_24h': 141816.0},
#    {'name': 'Phore',
#     'percent_change': 4.42,
#     'price': 0.00725376,
#     'slug': 'phore',
#     'symbol': 'COVAL',
#     'volume_24h': 60275.3},
#    {'name': 'B2BX',
#     'percent_change': 4.32,
#     'price': 0.176478,
#     'slug': 'b2bx',
#     'symbol': 'CROP',
#     'volume_24h': 53303.2},
#    {'name': 'PIVX',
#     'percent_change': 3.77,
#     'price': 0.291943,
#     'slug': 'pivx',
#     'symbol': 'BLITZ',
#     'volume_24h': 319540.0},
#    {'name': 'ICON',
#     'percent_change': 3.67,
#     'price': 0.0540285,
#     'slug': 'icon',
#     'symbol': 'BRM',
#     'volume_24h': 110069.0},
#    {'name': 'PolySwarm',
#     'percent_change': 3.57,
#     'price': 1.05051,
#     'slug': 'polyswarm',
#     'symbol': 'BITUSD',
#     'volume_24h': 6020590.0},
#    {'name': 'Arbitracoin',
#     'percent_change': 3.17,
#     'price': 0.379563,
#     'slug': 'arbitracoin',
#     'symbol': 'QBT',
#     'volume_24h': 3547670.0},
#    {'name': 'Circuits of Value',
#     'percent_change': 3.17,
#     'price': 2.96986,
#     'slug': 'circuits-of-value',
#     'symbol': 'DIVX',
#     'volume_24h': 1451560.0},
#    {'name': 'Cropcoin',
#     'percent_change': 3.14,
#     'price': 0.00528503,
#     'slug': 'cropcoin',
#     'symbol': 'XBP',
#     'volume_24h': 63446.2},
#    {'name': 'Blitzcash',
#     'percent_change': 2.81,
#     'price': 0.000189661,
#     'slug': 'blitzcash',
#     'symbol': 'KIN',
#     'volume_24h': 3399860.0},
#    {'name': 'BrahmaOS',
#     'percent_change': 2.69,
#     'price': 0.924934,
#     'slug': 'brahmaos',
#     'symbol': 'GRS',
#     'volume_24h': 28908700.0},
#    {'name': 'bitUSD',
#     'percent_change': 2.68,
#     'price': 0.164927,
#     'slug': 'bitusd',
#     'symbol': 'BITCNY',
#     'volume_24h': 37370000.0},
#    {'name': 'Qbao',
#     'percent_change': 2.68,
#     'price': 0.174306,
#     'slug': 'qbao',
#     'symbol': 'SPF',
#     'volume_24h': 1349680.0},
#    {'name': 'Divi',
#     'percent_change': 2.61,
#     'price': 0.0601139,
#     'slug': 'divi',
#     'symbol': 'BERRY',
#     'volume_24h': 88144.3},
#    {'name': 'BlitzPredict',
#     'percent_change': 2.48,
#     'price': 0.00196251,
#     'slug': 'blitzpredict',
#     'symbol': 'TEL',
#     'volume_24h': 547107.0}],
#   '24h': [{'name': 'Haven Protocol',
#     'percent_change': 135.59,
#     'price': 0.000256015,
#     'slug': 'haven-protocol',
#     'symbol': 'CUBE',
#     'volume_24h': 413131.0},
#    {'name': 'Dentacoin',
#     'percent_change': 39.93,
#     'price': 0.0540285,
#     'slug': 'dentacoin',
#     'symbol': 'BRM',
#     'volume_24h': 110069.0},
#    {'name': 'LinkEye',
#     'percent_change': 27.95,
#     'price': 0.100273,
#     'slug': 'linkeye',
#     'symbol': 'ATC',
#     'volume_24h': 141816.0},
#    {'name': 'AdHive',
#     'percent_change': 27.74,
#     'price': 0.0203465,
#     'slug': 'adhive',
#     'symbol': 'LNC',
#     'volume_24h': 52391.3},
#    {'name': 'FairGame',
#     'percent_change': 26.04,
#     'price': 0.00307496,
#     'slug': 'fairgame',
#     'symbol': 'HYDRO',
#     'volume_24h': 559444.0},
#    {'name': 'Skycoin',
#     'percent_change': 23.03,
#     'price': 0.169219,
#     'slug': 'skycoin',
#     'symbol': 'ODE',
#     'volume_24h': 83188.7},
#    {'name': 'DigiCube',
#     'percent_change': 19.86,
#     'price': 58.3279,
#     'slug': 'digicube',
#     'symbol': 'REP',
#     'volume_24h': 180700000.0},
#    {'name': 'BrahmaOS',
#     'percent_change': 17.46,
#     'price': 0.135728,
#     'slug': 'brahmaos',
#     'symbol': 'DBET',
#     'volume_24h': 277410.0},
#    {'name': 'Arbitracoin',
#     'percent_change': 13.74,
#     'price': 0.143001,
#     'slug': 'arbitracoin',
#     'symbol': 'MDS',
#     'volume_24h': 20889300.0},
#    {'name': 'Blocklancer',
#     'percent_change': 12.3,
#     'price': 0.0247672,
#     'slug': 'blocklancer',
#     'symbol': 'GRFT',
#     'volume_24h': 109143.0},
#    {'name': 'Hydrogen',
#     'percent_change': 11.31,
#     'price': 0.380513,
#     'slug': 'hydrogen',
#     'symbol': 'RBLX',
#     'volume_24h': 299667.0},
#    {'name': 'ODEM',
#     'percent_change': 10.35,
#     'price': 0.000942106,
#     'slug': 'odem',
#     'symbol': 'LANA',
#     'volume_24h': 272773.0},
#    {'name': 'Augur',
#     'percent_change': 9.9,
#     'price': 0.685439,
#     'slug': 'augur',
#     'symbol': 'PST',
#     'volume_24h': 16500000.0},
#    {'name': 'DecentBet',
#     'percent_change': 7.97,
#     'price': 0.0543756,
#     'slug': 'decent-bet',
#     'symbol': 'DXT',
#     'volume_24h': 773631.0},
#    {'name': 'MediShares',
#     'percent_change': 7.27,
#     'price': 0.000189661,
#     'slug': 'medishares',
#     'symbol': 'KIN',
#     'volume_24h': 3399860.0},
#    {'name': 'Graft',
#     'percent_change': 7.15,
#     'price': 2.42015,
#     'slug': 'graft',
#     'symbol': 'OCC',
#     'volume_24h': 1013310.0},
#    {'name': 'Rublix',
#     'percent_change': 5.93,
#     'price': 0.844625,
#     'slug': 'rublix',
#     'symbol': 'B2B',
#     'volume_24h': 378258.0},
#    {'name': 'LanaCoin',
#     'percent_change': 5.59,
#     'price': 0.00435226,
#     'slug': 'lanacoin',
#     'symbol': 'OPC',
#     'volume_24h': 428893.0},
#    {'name': 'Primas',
#     'percent_change': 5.45,
#     'price': 0.164927,
#     'slug': 'primas',
#     'symbol': 'BITCNY',
#     'volume_24h': 37370000.0},
#    {'name': 'Datawallet',
#     'percent_change': 5.3,
#     'price': 1.05051,
#     'slug': 'datawallet',
#     'symbol': 'BITUSD',
#     'volume_24h': 6020590.0},
#    {'name': 'Kin',
#     'percent_change': 5.27,
#     'price': 1.54112,
#     'slug': 'kin',
#     'symbol': 'UQC',
#     'volume_24h': 2399830.0},
#    {'name': 'Octoin Coin',
#     'percent_change': 3.2,
#     'price': 0.0532818,
#     'slug': 'octoin-coin',
#     'symbol': 'IND',
#     'volume_24h': 203210.0},
#    {'name': 'B2BX',
#     'percent_change': 2.68,
#     'price': 8.77178,
#     'slug': 'b2bx',
#     'symbol': 'FRGC',
#     'volume_24h': 932147.0},
#    {'name': 'OP Coin',
#     'percent_change': 2.61,
#     'price': 0.0169364,
#     'slug': 'op-coin',
#     'symbol': 'HBZ',
#     'volume_24h': 2308560.0},
#    {'name': 'bitCNY',
#     'percent_change': 1.49,
#     'price': 1.01114,
#     'slug': 'bitcny',
#     'symbol': 'DAI',
#     'volume_24h': 1894990.0},
#    {'name': 'bitUSD',
#     'percent_change': 1.28,
#     'price': 0.510764,
#     'slug': 'bitusd',
#     'symbol': 'PIRL',
#     'volume_24h': 61949.9},
#    {'name': 'Uquid Coin',
#     'percent_change': 1.23,
#     'price': 0.0532512,
#     'slug': 'uquid-coin',
#     'symbol': 'WHL',
#     'volume_24h': 60225.0},
#    {'name': 'Indorse Token',
#     'percent_change': 1.21,
#     'price': 1.89989,
#     'slug': 'indorse-token',
#     'symbol': 'PHR',
#     'volume_24h': 185824.0},
#    {'name': 'Fargocoin',
#     'percent_change': 0.29,
#     'price': 0.998611,
#     'slug': 'fargocoin',
#     'symbol': 'TUSD',
#     'volume_24h': 1619550.0},
#    {'name': 'Helbiz',
#     'percent_change': 0.18,
#     'price': 1.00075,
#     'slug': 'helbiz',
#     'symbol': 'USDT',
#     'volume_24h': 4798610000.0}],
#   '7d': [{'name': 'Kin',
#     'percent_change': 113.25,
#     'price': 0.0355481,
#     'slug': 'kin',
#     'symbol': 'MAG',
#     'volume_24h': 4280520.0},
#    {'name': 'Groestlcoin',
#     'percent_change': 102.02,
#     'price': 0.0363892,
#     'slug': 'groestlcoin',
#     'symbol': 'ADI',
#     'volume_24h': 1473560.0},
#    {'name': 'bitCNY',
#     'percent_change': 101.16,
#     'price': 0.844625,
#     'slug': 'bitcny',
#     'symbol': 'B2B',
#     'volume_24h': 378258.0},
#    {'name': 'SportyCo',
#     'percent_change': 86.39,
#     'price': 0.685439,
#     'slug': 'sportyco',
#     'symbol': 'PST',
#     'volume_24h': 16500000.0},
#    {'name': 'Rentberry',
#     'percent_change': 82.24,
#     'price': 0.00763351,
#     'slug': 'rentberry',
#     'symbol': 'NPXS',
#     'volume_24h': 23481400.0},
#    {'name': 'Telcoin',
#     'percent_change': 71.07,
#     'price': 0.000256015,
#     'slug': 'telcoin',
#     'symbol': 'CUBE',
#     'volume_24h': 413131.0},
#    {'name': 'Maggie',
#     'percent_change': 63.16,
#     'price': 0.0247672,
#     'slug': 'maggie',
#     'symbol': 'GRFT',
#     'volume_24h': 109143.0},
#    {'name': 'Aditus',
#     'percent_change': 49.87,
#     'price': 0.00417154,
#     'slug': 'aditus',
#     'symbol': 'STQ',
#     'volume_24h': 1866800.0},
#    {'name': 'B2BX',
#     'percent_change': 46.9,
#     'price': 0.000426692,
#     'slug': 'b2bx',
#     'symbol': 'BIRDS',
#     'volume_24h': 131343.0},
#    {'name': 'Primas',
#     'percent_change': 44.2,
#     'price': 0.00315919,
#     'slug': 'primas',
#     'symbol': 'COLX',
#     'volume_24h': 1015570.0},
#    {'name': 'Pundi X',
#     'percent_change': 43.12,
#     'price': 0.00994661,
#     'slug': 'pundi-x',
#     'symbol': 'BCN',
#     'volume_24h': 93385000.0},
#    {'name': 'DigiCube',
#     'percent_change': 41.47,
#     'price': 6.47144,
#     'slug': 'digicube',
#     'symbol': 'HXX',
#     'volume_24h': 256727.0},
#    {'name': 'Graft',
#     'percent_change': 38.48,
#     'price': 0.195596,
#     'slug': 'graft',
#     'symbol': 'SOC',
#     'volume_24h': 57638600.0},
#    {'name': 'Storiqa',
#     'percent_change': 36.14,
#     'price': 0.143001,
#     'slug': 'storiqa',
#     'symbol': 'MDS',
#     'volume_24h': 20889300.0},
#    {'name': 'Birds',
#     'percent_change': 33.87,
#     'price': 58.3279,
#     'slug': 'birds',
#     'symbol': 'REP',
#     'volume_24h': 180700000.0},
#    {'name': 'ColossusXT',
#     'percent_change': 33.07,
#     'price': 2.19158,
#     'slug': 'colossusxt',
#     'symbol': 'DPY',
#     'volume_24h': 25717600.0},
#    {'name': 'Bytecoin',
#     'percent_change': 31.93,
#     'price': 0.00269454,
#     'slug': 'bytecoin-bcn',
#     'symbol': 'ECA',
#     'volume_24h': 1512640.0},
#    {'name': 'Hexx',
#     'percent_change': 31.88,
#     'price': 0.000942106,
#     'slug': 'hexx',
#     'symbol': 'LANA',
#     'volume_24h': 272773.0},
#    {'name': 'All Sports',
#     'percent_change': 29.95,
#     'price': 0.905736,
#     'slug': 'all-sports',
#     'symbol': 'BOT',
#     'volume_24h': 12773900.0},
#    {'name': 'MediShares',
#     'percent_change': 29.81,
#     'price': 0.00484831,
#     'slug': 'medishares',
#     'symbol': 'SHOW',
#     'volume_24h': 2359590.0},
#    {'name': 'Augur',
#     'percent_change': 28.41,
#     'price': 0.86108,
#     'slug': 'augur',
#     'symbol': 'IPC',
#     'volume_24h': 4507210.0},
#    {'name': 'Delphy',
#     'percent_change': 27.44,
#     'price': 3.42093,
#     'slug': 'delphy',
#     'symbol': 'HT',
#     'volume_24h': 179687000.0},
#    {'name': 'Electra',
#     'percent_change': 24.4,
#     'price': 0.325877,
#     'slug': 'electra',
#     'symbol': 'APH',
#     'volume_24h': 426228.0},
#    {'name': 'LanaCoin',
#     'percent_change': 24.32,
#     'price': 0.0203465,
#     'slug': 'lanacoin',
#     'symbol': 'LNC',
#     'volume_24h': 52391.3},
#    {'name': 'Bodhi',
#     'percent_change': 23.16,
#     'price': 3.31157,
#     'slug': 'bodhi',
#     'symbol': 'XHV',
#     'volume_24h': 151219.0},
#    {'name': 'Show',
#     'percent_change': 22.77,
#     'price': 0.000965681,
#     'slug': 'show',
#     'symbol': 'DCN',
#     'volume_24h': 4603370.0},
#    {'name': 'IPChain',
#     'percent_change': 21.5,
#     'price': 0.0760899,
#     'slug': 'ipchain',
#     'symbol': 'LET',
#     'volume_24h': 11896100.0},
#    {'name': 'Huobi Token',
#     'percent_change': 20.1,
#     'price': 0.0751553,
#     'slug': 'huobi-token',
#     'symbol': 'ADH',
#     'volume_24h': 964884.0},
#    {'name': 'Aphelion',
#     'percent_change': 20.08,
#     'price': 0.0363463,
#     'slug': 'aphelion',
#     'symbol': 'FAIR',
#     'volume_24h': 1123000.0},
#    {'name': 'Blocklancer',
#     'percent_change': 20.06,
#     'price': 23.0915,
#     'slug': 'blocklancer',
#     'symbol': 'SKY',
#     'volume_24h': 1683490.0}]},
#  'losers': {'1h': [{'name': 'Dai',
#     'percent_change': -28.84,
#     'price': 0.000109392,
#     'slug': 'dai',
#     'symbol': 'PCN',
#     'volume_24h': 760337.0},
#    {'name': 'Pirl',
#     'percent_change': -21.93,
#     'price': 0.089347,
#     'slug': 'pirl',
#     'symbol': 'TNS',
#     'volume_24h': 61021.6},
#    {'name': 'WhaleCoin',
#     'percent_change': -13.65,
#     'price': 0.0363892,
#     'slug': 'whalecoin',
#     'symbol': 'ADI',
#     'volume_24h': 1473560.0},
#    {'name': 'Phore',
#     'percent_change': -13.56,
#     'price': 2.11803,
#     'slug': 'phore',
#     'symbol': 'SHIFT',
#     'volume_24h': 1542700.0},
#    {'name': 'TrueUSD',
#     'percent_change': -13.41,
#     'price': 0.00051203,
#     'slug': 'trueusd',
#     'symbol': 'VIPS',
#     'volume_24h': 181067.0},
#    {'name': 'Tether',
#     'percent_change': -10.72,
#     'price': 0.00484831,
#     'slug': 'tether',
#     'symbol': 'SHOW',
#     'volume_24h': 2359590.0},
#    {'name': 'PeepCoin',
#     'percent_change': -9.8,
#     'price': 13.7743,
#     'slug': 'peepcoin',
#     'symbol': 'SBTC',
#     'volume_24h': 7698690.0},
#    {'name': 'Transcodium',
#     'percent_change': -9.56,
#     'price': 0.561847,
#     'slug': 'transcodium',
#     'symbol': 'STX',
#     'volume_24h': 2476510.0},
#    {'name': 'Aditus',
#     'percent_change': -9.11,
#     'price': 2.19158,
#     'slug': 'aditus',
#     'symbol': 'DPY',
#     'volume_24h': 25717600.0},
#    {'name': 'Shift',
#     'percent_change': -8.91,
#     'price': 0.606873,
#     'slug': 'shift',
#     'symbol': 'PKT',
#     'volume_24h': 366454.0},
#    {'name': 'Vipstar Coin',
#     'percent_change': -8.68,
#     'price': 0.0810529,
#     'slug': 'vipstar-coin',
#     'symbol': 'VLC',
#     'volume_24h': 1452300.0},
#    {'name': 'Show',
#     'percent_change': -8.57,
#     'price': 0.302951,
#     'slug': 'show',
#     'symbol': 'WC',
#     'volume_24h': 112100.0},
#    {'name': 'Super Bitcoin',
#     'percent_change': -8.45,
#     'price': 0.00399736,
#     'slug': 'super-bitcoin',
#     'symbol': 'DOGE',
#     'volume_24h': 27834800.0},
#    {'name': 'Stox',
#     'percent_change': -8.34,
#     'price': 0.649126,
#     'slug': 'stox',
#     'symbol': 'HST',
#     'volume_24h': 82004.3},
#    {'name': 'Delphy',
#     'percent_change': -8.34,
#     'price': 0.112939,
#     'slug': 'delphy',
#     'symbol': 'PFR',
#     'volume_24h': 113988.0},
#    {'name': 'Playkey',
#     'percent_change': -8.33,
#     'price': 0.0938159,
#     'slug': 'playkey',
#     'symbol': 'STC',
#     'volume_24h': 4564550.0},
#    {'name': 'ValueChain',
#     'percent_change': -8.23,
#     'price': 0.0817594,
#     'slug': 'valuechain',
#     'symbol': 'LIVE',
#     'volume_24h': 164254.0},
#    {'name': 'WINCOIN',
#     'percent_change': -7.96,
#     'price': 3.59606,
#     'slug': 'win-coin',
#     'symbol': 'DEV',
#     'volume_24h': 405867.0},
#    {'name': 'Dogecoin',
#     'percent_change': -7.22,
#     'price': 0.0412395,
#     'slug': 'dogecoin',
#     'symbol': 'QUN',
#     'volume_24h': 1793020.0},
#    {'name': 'Decision Token',
#     'percent_change': -7.07,
#     'price': 0.0109167,
#     'slug': 'decision-token',
#     'symbol': 'MLM',
#     'volume_24h': 58960.3},
#    {'name': 'Payfair',
#     'percent_change': -6.69,
#     'price': 0.234362,
#     'slug': 'payfair',
#     'symbol': 'SNC',
#     'volume_24h': 4199280.0},
#    {'name': 'StarChain',
#     'percent_change': -6.66,
#     'price': 4.61599e-07,
#     'slug': 'starchain',
#     'symbol': 'SHND',
#     'volume_24h': 61718.9},
#    {'name': 'Live Stars',
#     'percent_change': -6.66,
#     'price': 1.91364,
#     'slug': 'live-stars',
#     'symbol': 'TRUE',
#     'volume_24h': 152309000.0},
#    {'name': 'DeviantCoin',
#     'percent_change': -6.61,
#     'price': 6.47144,
#     'slug': 'deviantcoin',
#     'symbol': 'HXX',
#     'volume_24h': 256727.0},
#    {'name': 'QunQun',
#     'percent_change': -6.54,
#     'price': 0.615161,
#     'slug': 'qunqun',
#     'symbol': 'MTX',
#     'volume_24h': 442807.0},
#    {'name': 'MktCoin',
#     'percent_change': -6.42,
#     'price': 0.177982,
#     'slug': 'mktcoin',
#     'symbol': 'ARY',
#     'volume_24h': 201649.0},
#    {'name': 'SunContract',
#     'percent_change': -6.41,
#     'price': 0.00269454,
#     'slug': 'suncontract',
#     'symbol': 'ECA',
#     'volume_24h': 1512640.0},
#    {'name': 'StrongHands',
#     'percent_change': -6.4,
#     'price': 0.0363463,
#     'slug': 'stronghands',
#     'symbol': 'FAIR',
#     'volume_24h': 1123000.0},
#    {'name': 'True Chain',
#     'percent_change': -6.35,
#     'price': 0.0394852,
#     'slug': 'true-chain',
#     'symbol': 'RCT',
#     'volume_24h': 1451600.0},
#    {'name': 'Hexx',
#     'percent_change': -6.27,
#     'price': 0.0015165,
#     'slug': 'hexx',
#     'symbol': 'LIGHT',
#     'volume_24h': 2799880.0}],
#   '24h': [{'name': 'Matryx',
#     'percent_change': -85.52,
#     'price': 0.00855091,
#     'slug': 'matryx',
#     'symbol': 'SCC',
#     'volume_24h': 478293.0},
#    {'name': 'Block Array',
#     'percent_change': -73.87,
#     'price': 0.291943,
#     'slug': 'block-array',
#     'symbol': 'BLITZ',
#     'volume_24h': 319540.0},
#    {'name': 'Electra',
#     'percent_change': -67.61,
#     'price': 0.0167253,
#     'slug': 'electra',
#     'symbol': 'PIPL',
#     'volume_24h': 167492.0},
#    {'name': 'FairGame',
#     'percent_change': -62.62,
#     'price': 0.0230968,
#     'slug': 'fairgame',
#     'symbol': 'AMN',
#     'volume_24h': 101268.0},
#    {'name': 'RealChain',
#     'percent_change': -61.97,
#     'price': 7.56018,
#     'slug': 'realchain',
#     'symbol': 'BCI',
#     'volume_24h': 298897.0},
#    {'name': 'LightChain',
#     'percent_change': -59.18,
#     'price': 0.0532973,
#     'slug': 'lightchain',
#     'symbol': 'VME',
#     'volume_24h': 76327.5},
#    {'name': 'StockChain',
#     'percent_change': -57.44,
#     'price': 0.110994,
#     'slug': 'stockchain',
#     'symbol': 'ECH',
#     'volume_24h': 74613.9},
#    {'name': 'Blitzcash',
#     'percent_change': -54.18,
#     'price': 0.089347,
#     'slug': 'blitzcash',
#     'symbol': 'TNS',
#     'volume_24h': 61021.6},
#    {'name': 'PiplCoin',
#     'percent_change': -53.42,
#     'price': 0.0177641,
#     'slug': 'piplcoin',
#     'symbol': 'CVH',
#     'volume_24h': 118604.0},
#    {'name': 'Amon',
#     'percent_change': -52.54,
#     'price': 0.176478,
#     'slug': 'amon',
#     'symbol': 'CROP',
#     'volume_24h': 53303.2},
#    {'name': 'Bitcoin Interest',
#     'percent_change': -50.34,
#     'price': 0.00503331,
#     'slug': 'bitcoin-interest',
#     'symbol': 'OC',
#     'volume_24h': 2808040.0},
#    {'name': 'VeriME',
#     'percent_change': -48.84,
#     'price': 0.0118404,
#     'slug': 'verime',
#     'symbol': 'EARTH',
#     'volume_24h': 91971.7},
#    {'name': 'Etherecash',
#     'percent_change': -48.74,
#     'price': 0.302951,
#     'slug': 'etherecash',
#     'symbol': 'WC',
#     'volume_24h': 112100.0},
#    {'name': 'Transcodium',
#     'percent_change': -47.45,
#     'price': 0.0629407,
#     'slug': 'transcodium',
#     'symbol': 'MRK',
#     'volume_24h': 563796.0},
#    {'name': 'Curriculum Vitae',
#     'percent_change': -46.03,
#     'price': 0.00051203,
#     'slug': 'curriculum-vitae',
#     'symbol': 'VIPS',
#     'volume_24h': 181067.0},
#    {'name': 'Cropcoin',
#     'percent_change': -45.96,
#     'price': 0.0545823,
#     'slug': 'cropcoin',
#     'symbol': 'HOT',
#     'volume_24h': 1021120.0},
#    {'name': 'OceanChain',
#     'percent_change': -45.44,
#     'price': 27.1355,
#     'slug': 'oceanchain',
#     'symbol': 'LBTC',
#     'volume_24h': 2930970.0},
#    {'name': 'Earth Token',
#     'percent_change': -44.82,
#     'price': 0.0394135,
#     'slug': 'earth-token',
#     'symbol': 'CAPP',
#     'volume_24h': 398779.0},
#    {'name': 'WINCOIN',
#     'percent_change': -43.51,
#     'price': 0.0453198,
#     'slug': 'win-coin',
#     'symbol': 'XBY',
#     'volume_24h': 195995.0},
#    {'name': 'MARK.SPACE',
#     'percent_change': -43.34,
#     'price': 0.00222897,
#     'slug': 'mark-space',
#     'symbol': 'NANJ',
#     'volume_24h': 1032060.0},
#    {'name': 'Vipstar Coin',
#     'percent_change': -42.71,
#     'price': 0.372054,
#     'slug': 'vipstar-coin',
#     'symbol': 'GNX',
#     'volume_24h': 4665590.0},
#    {'name': 'Hydro Protocol',
#     'percent_change': -41.71,
#     'price': 0.315526,
#     'slug': 'hydro-protocol',
#     'symbol': 'GTO',
#     'volume_24h': 30750200.0},
#    {'name': 'Lightning Bitcoin',
#     'percent_change': -41.61,
#     'price': 11.9787,
#     'slug': 'lightning-bitcoin',
#     'symbol': 'ZCL',
#     'volume_24h': 5301370.0},
#    {'name': 'Cappasity',
#     'percent_change': -41.32,
#     'price': 0.112939,
#     'slug': 'cappasity',
#     'symbol': 'PFR',
#     'volume_24h': 113988.0},
#    {'name': 'XTRABYTES',
#     'percent_change': -40.98,
#     'price': 0.0388476,
#     'slug': 'xtrabytes',
#     'symbol': 'DOPE',
#     'volume_24h': 196158.0},
#    {'name': 'NANJCOIN',
#     'percent_change': -40.39,
#     'price': 0.773521,
#     'slug': 'nanjcoin',
#     'symbol': 'PPP',
#     'volume_24h': 318711.0},
#    {'name': 'Genaro Network',
#     'percent_change': -40.13,
#     'price': 0.268385,
#     'slug': 'genaro-network',
#     'symbol': 'GUP',
#     'volume_24h': 2557940.0},
#    {'name': 'Gifto',
#     'percent_change': -40.11,
#     'price': 0.0323516,
#     'slug': 'gifto',
#     'symbol': 'PLAY',
#     'volume_24h': 92298.7},
#    {'name': 'ZClassic',
#     'percent_change': -39.99,
#     'price': 0.690778,
#     'slug': 'zclassic',
#     'symbol': 'CPC',
#     'volume_24h': 107544.0},
#    {'name': 'Payfair',
#     'percent_change': -39.97,
#     'price': 1.15929,
#     'slug': 'payfair',
#     'symbol': 'ARN',
#     'volume_24h': 5581790.0}],
#   '7d': [{'name': 'DopeCoin',
#     'percent_change': -57.59,
#     'price': 0.0167253,
#     'slug': 'dopecoin',
#     'symbol': 'PIPL',
#     'volume_24h': 167492.0},
#    {'name': 'PayPie',
#     'percent_change': -57.56,
#     'price': 0.000109392,
#     'slug': 'paypie',
#     'symbol': 'PCN',
#     'volume_24h': 760337.0},
#    {'name': 'Matchpool',
#     'percent_change': -45.72,
#     'price': 0.291943,
#     'slug': 'guppy',
#     'symbol': 'BLITZ',
#     'volume_24h': 319540.0},
#    {'name': 'HEROcoin',
#     'percent_change': -33.91,
#     'price': 0.112939,
#     'slug': 'herocoin',
#     'symbol': 'PFR',
#     'volume_24h': 113988.0},
#    {'name': 'Capricoin',
#     'percent_change': -33.28,
#     'price': 3697.39,
#     'slug': 'capricoin',
#     'symbol': 'IDXM',
#     'volume_24h': 122350.0},
#    {'name': 'Aeron',
#     'percent_change': -30.13,
#     'price': 0.00528503,
#     'slug': 'aeron',
#     'symbol': 'XBP',
#     'volume_24h': 63446.2},
#    {'name': 'PiplCoin',
#     'percent_change': -29.95,
#     'price': 7.56018,
#     'slug': 'piplcoin',
#     'symbol': 'BCI',
#     'volume_24h': 298897.0},
#    {'name': 'PeepCoin',
#     'percent_change': -29.31,
#     'price': 0.0686417,
#     'slug': 'peepcoin',
#     'symbol': 'ZPT',
#     'volume_24h': 628911.0},
#    {'name': 'Blitzcash',
#     'percent_change': -29.24,
#     'price': 0.148551,
#     'slug': 'blitzcash',
#     'symbol': 'MTN',
#     'volume_24h': 4982310.0},
#    {'name': 'Payfair',
#     'percent_change': -28.46,
#     'price': 0.0278617,
#     'slug': 'payfair',
#     'symbol': 'YEE',
#     'volume_24h': 10137200.0},
#    {'name': 'IDEX Membership',
#     'percent_change': -27.72,
#     'price': 0.0109167,
#     'slug': 'idex-membership',
#     'symbol': 'MLM',
#     'volume_24h': 58960.3},
#    {'name': 'BlitzPredict',
#     'percent_change': -27.56,
#     'price': 0.723189,
#     'slug': 'blitzpredict',
#     'symbol': 'BLT',
#     'volume_24h': 15094200.0},
#    {'name': 'Bitcoin Interest',
#     'percent_change': -27.51,
#     'price': 0.0453198,
#     'slug': 'bitcoin-interest',
#     'symbol': 'XBY',
#     'volume_24h': 195995.0},
#    {'name': 'Zeepin',
#     'percent_change': -27.26,
#     'price': 0.00120041,
#     'slug': 'zeepin',
#     'symbol': 'ECC',
#     'volume_24h': 82101.3},
#    {'name': 'Medicalchain',
#     'percent_change': -27.14,
#     'price': 0.584478,
#     'slug': 'medical-chain',
#     'symbol': 'LGD',
#     'volume_24h': 111174.0},
#    {'name': 'YEE',
#     'percent_change': -27.09,
#     'price': 0.4552,
#     'slug': 'yee',
#     'symbol': 'TIX',
#     'volume_24h': 6454490.0},
#    {'name': 'MktCoin',
#     'percent_change': -27.06,
#     'price': 13.7743,
#     'slug': 'mktcoin',
#     'symbol': 'SBTC',
#     'volume_24h': 7698690.0},
#    {'name': 'Bloom',
#     'percent_change': -26.94,
#     'price': 0.195596,
#     'slug': 'bloomtoken',
#     'symbol': 'SOC',
#     'volume_24h': 57638600.0},
#    {'name': 'XTRABYTES',
#     'percent_change': -26.86,
#     'price': 0.0230968,
#     'slug': 'xtrabytes',
#     'symbol': 'AMN',
#     'volume_24h': 101268.0},
#    {'name': 'ECC',
#     'percent_change': -26.55,
#     'price': 0.176478,
#     'slug': 'eccoin',
#     'symbol': 'CROP',
#     'volume_24h': 53303.2},
#    {'name': 'Legends Room',
#     'percent_change': -26.33,
#     'price': 0.0433468,
#     'slug': 'legends-room',
#     'symbol': 'TNB',
#     'volume_24h': 17860200.0},
#    {'name': 'Blocktix',
#     'percent_change': -26.19,
#     'price': 0.0391046,
#     'slug': 'blocktix',
#     'symbol': 'TOPC',
#     'volume_24h': 2047590.0},
#    {'name': 'Super Bitcoin',
#     'percent_change': -26.14,
#     'price': 0.0391657,
#     'slug': 'super-bitcoin',
#     'symbol': 'STORM',
#     'volume_24h': 64813800.0},
#    {'name': 'All Sports',
#     'percent_change': -25.93,
#     'price': 0.000965681,
#     'slug': 'all-sports',
#     'symbol': 'DCN',
#     'volume_24h': 4603370.0},
#    {'name': 'Amon',
#     'percent_change': -25.88,
#     'price': 0.22342,
#     'slug': 'amon',
#     'symbol': 'BFT',
#     'volume_24h': 4708980.0},
#    {'name': 'Cropcoin',
#     'percent_change': -25.87,
#     'price': 3.6824,
#     'slug': 'cropcoin',
#     'symbol': 'BCD',
#     'volume_24h': 5976210.0},
#    {'name': 'Time New Bank',
#     'percent_change': -25.83,
#     'price': 0.0133238,
#     'slug': 'time-new-bank',
#     'symbol': 'XDN',
#     'volume_24h': 6048800.0},
#    {'name': 'TopChain',
#     'percent_change': -25.82,
#     'price': 0.64846,
#     'slug': 'topchain',
#     'symbol': 'POA',
#     'volume_24h': 21328400.0},
#    {'name': 'Storm',
#     'percent_change': -25.71,
#     'price': 0.0874056,
#     'slug': 'storm',
#     'symbol': 'STK',
#     'volume_24h': 2923790.0},
#    {'name': 'Dentacoin',
#     'percent_change': -25.52,
#     'price': 0.0388476,
#     'slug': 'dentacoin',
#     'symbol': 'DOPE',
#     'volume_24h': 196158.0}]}}

# %%
show_page("gainers-losers")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/gainers-losers"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `historical(currency, [start=datetime(2008, 8, 18), end=datetime.now(), revert=False])`
# Get historical prices for a currency. You can filter by `start` and `end` datetimes provided in `datetime` objects. With parameter `revert` active, the response will be ordered in chronological order.

# %%
from datetime import datetime

cmc.historical("ETH", start=datetime(2018, 2, 1), revert=True)
# Out:
# {'history': [{'close': 1036.79,
#    'date': datetime.datetime(2018, 2, 1, 0, 0),
#    'high': 1161.35,
#    'low': 984.819,
#    'market_cap': 108952000000.0,
#    'open': 1119.37,
#    'volume': 5261680000.0},
#   {'close': 915.785,
#    'date': datetime.datetime(2018, 2, 2, 0, 0),
#    'high': 1035.77,
#    'low': 757.98,
#    'market_cap': 100836000000.0,
#    'open': 1035.77,
#    'volume': 6713290000.0},
#   {'close': 964.019,
#    'date': datetime.datetime(2018, 2, 3, 0, 0),
#    'high': 991.943,
#    'low': 847.69,
#    'market_cap': 89507600000.0,
#    'open': 919.211,
#    'volume': 3243480000.0},
#   {'close': 834.682,
#    'date': datetime.datetime(2018, 2, 4, 0, 0),
#    'high': 969.032,
#    'low': 805.064,
#    'market_cap': 93953400000.0,
#    'open': 964.667,
#    'volume': 2997090000.0},
#   {'close': 697.951,
#    'date': datetime.datetime(2018, 2, 5, 0, 0),
#    'high': 856.646,
#    'low': 644.599,
#    'market_cap': 81337400000.0,
#    'open': 834.958,
#    'volume': 4269530000.0},
#   {'close': 793.122,
#    'date': datetime.datetime(2018, 2, 6, 0, 0),
#    'high': 796.439,
#    'low': 574.419,
#    'market_cap': 68958700000.0,
#    'open': 707.737,
#    'volume': 6518270000.0},
#   {'close': 757.068,
#    'date': datetime.datetime(2018, 2, 7, 0, 0),
#    'high': 851.2,
#    'low': 723.433,
#    'market_cap': 77032000000.0,
#    'open': 790.428,
#    'volume': 3896180000.0},
#   {'close': 817.807,
#    'date': datetime.datetime(2018, 2, 8, 0, 0),
#    'high': 845.086,
#    'low': 755.843,
#    'market_cap': 73676900000.0,
#    'open': 755.843,
#    'volume': 3708190000.0},
#   {'close': 883.865,
#    'date': datetime.datetime(2018, 2, 9, 0, 0),
#    'high': 884.004,
#    'low': 788.834,
#    'market_cap': 79799300000.0,
#    'open': 818.48,
#    'volume': 2495820000.0},
#   {'close': 860.415,
#    'date': datetime.datetime(2018, 2, 10, 0, 0),
#    'high': 917.4,
#    'low': 825.577,
#    'market_cap': 86055600000.0,
#    'open': 882.467,
#    'volume': 2930530000.0},
#   {'close': 814.66,
#    'date': datetime.datetime(2018, 2, 11, 0, 0),
#    'high': 859.288,
#    'low': 788.222,
#    'market_cap': 83813000000.0,
#    'open': 859.288,
#    'volume': 2486650000.0},
#   {'close': 868.707,
#    'date': datetime.datetime(2018, 2, 12, 0, 0),
#    'high': 875.937,
#    'low': 817.508,
#    'market_cap': 79754400000.0,
#    'open': 817.508,
#    'volume': 2243450000.0},
#   {'close': 845.258,
#    'date': datetime.datetime(2018, 2, 13, 0, 0),
#    'high': 870.709,
#    'low': 828.837,
#    'market_cap': 84824200000.0,
#    'open': 869.293,
#    'volume': 2081170000.0},
#   {'close': 923.561,
#    'date': datetime.datetime(2018, 2, 14, 0, 0),
#    'high': 926.429,
#    'low': 844.279,
#    'market_cap': 82400600000.0,
#    'open': 844.279,
#    'volume': 2818370000.0},
#   {'close': 936.976,
#    'date': datetime.datetime(2018, 2, 15, 0, 0),
#    'high': 951.948,
#    'low': 911.111,
#    'market_cap': 90173300000.0,
#    'open': 923.728,
#    'volume': 2900100000.0},
#   {'close': 944.21,
#    'date': datetime.datetime(2018, 2, 16, 0, 0),
#    'high': 950.005,
#    'low': 917.848,
#    'market_cap': 91272100000.0,
#    'open': 934.786,
#    'volume': 2369450000.0},
#   {'close': 974.115,
#    'date': datetime.datetime(2018, 2, 17, 0, 0),
#    'high': 976.595,
#    'low': 940.754,
#    'market_cap': 92264000000.0,
#    'open': 944.748,
#    'volume': 2525720000.0},
#   {'close': 923.921,
#    'date': datetime.datetime(2018, 2, 18, 0, 0),
#    'high': 982.933,
#    'low': 915.445,
#    'market_cap': 95077100000.0,
#    'open': 973.349,
#    'volume': 2567290000.0},
#   {'close': 943.865,
#    'date': datetime.datetime(2018, 2, 19, 0, 0),
#    'high': 957.777,
#    'low': 921.554,
#    'market_cap': 90047700000.0,
#    'open': 921.668,
#    'volume': 2169020000.0},
#   {'close': 895.371,
#    'date': datetime.datetime(2018, 2, 20, 0, 0),
#    'high': 965.265,
#    'low': 892.954,
#    'market_cap': 92206500000.0,
#    'open': 943.567,
#    'volume': 2545260000.0},
#   {'close': 849.971,
#    'date': datetime.datetime(2018, 2, 21, 0, 0),
#    'high': 912.375,
#    'low': 830.563,
#    'market_cap': 87394200000.0,
#    'open': 894.135,
#    'volume': 2531730000.0},
#   {'close': 812.845,
#    'date': datetime.datetime(2018, 2, 22, 0, 0),
#    'high': 875.926,
#    'low': 802.668,
#    'market_cap': 83025800000.0,
#    'open': 849.262,
#    'volume': 2150370000.0},
#   {'close': 864.189,
#    'date': datetime.datetime(2018, 2, 23, 0, 0),
#    'high': 886.318,
#    'low': 794.791,
#    'market_cap': 79358900000.0,
#    'open': 811.585,
#    'volume': 2334820000.0},
#   {'close': 840.515,
#    'date': datetime.datetime(2018, 2, 24, 0, 0),
#    'high': 879.531,
#    'low': 818.55,
#    'market_cap': 84266700000.0,
#    'open': 861.593,
#    'volume': 1926580000.0},
#   {'close': 844.81,
#    'date': datetime.datetime(2018, 2, 25, 0, 0),
#    'high': 853.146,
#    'low': 822.381,
#    'market_cap': 82119100000.0,
#    'open': 839.459,
#    'volume': 1646960000.0},
#   {'close': 869.315,
#    'date': datetime.datetime(2018, 2, 26, 0, 0),
#    'high': 880.392,
#    'low': 842.319,
#    'market_cap': 82705400000.0,
#    'open': 845.278,
#    'volume': 2044480000.0},
#   {'close': 878.265,
#    'date': datetime.datetime(2018, 2, 27, 0, 0),
#    'high': 896.259,
#    'low': 867.097,
#    'market_cap': 85177800000.0,
#    'open': 870.365,
#    'volume': 2053980000.0},
#   {'close': 855.199,
#    'date': datetime.datetime(2018, 2, 28, 0, 0),
#    'high': 890.108,
#    'low': 855.124,
#    'market_cap': 85936400000.0,
#    'open': 877.934,
#    'volume': 1963980000.0},
#   {'close': 872.2,
#    'date': datetime.datetime(2018, 3, 1, 0, 0),
#    'high': 880.302,
#    'low': 851.92,
#    'market_cap': 83808200000.0,
#    'open': 856.012,
#    'volume': 1868520000.0},
#   {'close': 856.853,
#    'date': datetime.datetime(2018, 3, 2, 0, 0),
#    'high': 876.378,
#    'low': 852.422,
#    'market_cap': 85368100000.0,
#    'open': 871.764,
#    'volume': 1894420000.0},
#   {'close': 857.225,
#    'date': datetime.datetime(2018, 3, 3, 0, 0),
#    'high': 868.454,
#    'low': 855.207,
#    'market_cap': 83911700000.0,
#    'open': 856.711,
#    'volume': 1699370000.0},
#   {'close': 866.678,
#    'date': datetime.datetime(2018, 3, 4, 0, 0),
#    'high': 867.95,
#    'low': 840.28,
#    'market_cap': 83877800000.0,
#    'open': 856.186,
#    'volume': 1697940000.0},
#   {'close': 853.684,
#    'date': datetime.datetime(2018, 3, 5, 0, 0),
#    'high': 869.92,
#    'low': 853.52,
#    'market_cap': 84939700000.0,
#    'open': 866.846,
#    'volume': 1898490000.0},
#   {'close': 816.951,
#    'date': datetime.datetime(2018, 3, 6, 0, 0),
#    'high': 853.817,
#    'low': 809.931,
#    'market_cap': 83680400000.0,
#    'open': 853.817,
#    'volume': 1943070000.0},
#   {'close': 752.831,
#    'date': datetime.datetime(2018, 3, 7, 0, 0),
#    'high': 825.607,
#    'low': 726.547,
#    'market_cap': 80017300000.0,
#    'open': 816.271,
#    'volume': 2175420000.0},
#   {'close': 704.596,
#    'date': datetime.datetime(2018, 3, 8, 0, 0),
#    'high': 773.767,
#    'low': 696.169,
#    'market_cap': 73788400000.0,
#    'open': 752.57,
#    'volume': 1891640000.0},
#   {'close': 728.916,
#    'date': datetime.datetime(2018, 3, 9, 0, 0),
#    'high': 729.156,
#    'low': 648.107,
#    'market_cap': 68863600000.0,
#    'open': 702.197,
#    'volume': 2233020000.0},
#   {'close': 686.89,
#    'date': datetime.datetime(2018, 3, 10, 0, 0),
#    'high': 748.031,
#    'low': 682.695,
#    'market_cap': 71620700000.0,
#    'open': 730.16,
#    'volume': 1532960000.0},
#   {'close': 723.339,
#    'date': datetime.datetime(2018, 3, 11, 0, 0),
#    'high': 735.831,
#    'low': 668.123,
#    'market_cap': 67235700000.0,
#    'open': 685.312,
#    'volume': 1562680000.0},
#   {'close': 699.831,
#    'date': datetime.datetime(2018, 3, 12, 0, 0),
#    'high': 742.514,
#    'low': 683.268,
#    'market_cap': 71086000000.0,
#    'open': 724.406,
#    'volume': 1765000000.0},
#   {'close': 690.827,
#    'date': datetime.datetime(2018, 3, 13, 0, 0),
#    'high': 713.735,
#    'low': 682.35,
#    'market_cap': 68524000000.0,
#    'open': 698.153,
#    'volume': 1425960000.0},
#   {'close': 614.291,
#    'date': datetime.datetime(2018, 3, 14, 0, 0),
#    'high': 702.784,
#    'low': 594.1,
#    'market_cap': 67857600000.0,
#    'open': 691.219,
#    'volume': 1810560000.0},
#   {'close': 611.304,
#    'date': datetime.datetime(2018, 3, 15, 0, 0),
#    'high': 620.616,
#    'low': 579.505,
#    'market_cap': 60371800000.0,
#    'open': 614.839,
#    'volume': 1770460000.0},
#   {'close': 601.666,
#    'date': datetime.datetime(2018, 3, 16, 0, 0),
#    'high': 623.168,
#    'low': 587.862,
#    'market_cap': 60083700000.0,
#    'open': 611.778,
#    'volume': 1417350000.0},
#   {'close': 552.779,
#    'date': datetime.datetime(2018, 3, 17, 0, 0),
#    'high': 609.151,
#    'low': 549.096,
#    'market_cap': 59104200000.0,
#    'open': 601.678,
#    'volume': 1267810000.0},
#   {'close': 538.644,
#    'date': datetime.datetime(2018, 3, 18, 0, 0),
#    'high': 551.64,
#    'low': 460.088,
#    'market_cap': 54200100000.0,
#    'open': 551.64,
#    'volume': 2685500000.0},
#   {'close': 556.726,
#    'date': datetime.datetime(2018, 3, 19, 0, 0),
#    'high': 558.1,
#    'low': 519.123,
#    'market_cap': 53718600000.0,
#    'open': 546.626,
#    'volume': 2046790000.0},
#   {'close': 557.175,
#    'date': datetime.datetime(2018, 3, 20, 0, 0),
#    'high': 567.09,
#    'low': 521.204,
#    'market_cap': 54722100000.0,
#    'open': 556.722,
#    'volume': 1833680000.0},
#   {'close': 561.732,
#    'date': datetime.datetime(2018, 3, 21, 0, 0),
#    'high': 589.607,
#    'low': 550.572,
#    'market_cap': 54967300000.0,
#    'open': 559.1,
#    'volume': 1781270000.0},
#   {'close': 539.702,
#    'date': datetime.datetime(2018, 3, 22, 0, 0),
#    'high': 577.566,
#    'low': 523.089,
#    'market_cap': 55273800000.0,
#    'open': 562.103,
#    'volume': 1523460000.0},
#   {'close': 539.619,
#    'date': datetime.datetime(2018, 3, 23, 0, 0),
#    'high': 540.487,
#    'low': 512.127,
#    'market_cap': 53098100000.0,
#    'open': 539.864,
#    'volume': 1596350000.0},
#   {'close': 526.439,
#    'date': datetime.datetime(2018, 3, 24, 0, 0),
#    'high': 545.382,
#    'low': 526.08,
#    'market_cap': 53375400000.0,
#    'open': 542.572,
#    'volume': 1300010000.0},
#   {'close': 524.287,
#    'date': datetime.datetime(2018, 3, 25, 0, 0),
#    'high': 535.821,
#    'low': 515.659,
#    'market_cap': 51431600000.0,
#    'open': 522.703,
#    'volume': 1151170000.0},
#   {'close': 489.951,
#    'date': datetime.datetime(2018, 3, 26, 0, 0),
#    'high': 526.379,
#    'low': 470.44,
#    'market_cap': 51598000000.0,
#    'open': 524.287,
#    'volume': 1638880000.0},
#   {'close': 450.116,
#    'date': datetime.datetime(2018, 3, 27, 0, 0),
#    'high': 491.459,
#    'low': 449.971,
#    'market_cap': 48193300000.0,
#    'open': 489.59,
#    'volume': 1617940000.0},
#   {'close': 446.279,
#    'date': datetime.datetime(2018, 3, 28, 0, 0),
#    'high': 466.211,
#    'low': 444.861,
#    'market_cap': 44334000000.0,
#    'open': 450.291,
#    'volume': 1514180000.0},
#   {'close': 385.968,
#    'date': datetime.datetime(2018, 3, 29, 0, 0),
#    'high': 450.813,
#    'low': 385.813,
#    'market_cap': 44125000000.0,
#    'open': 448.075,
#    'volume': 1970230000.0},
#   {'close': 394.645,
#    'date': datetime.datetime(2018, 3, 30, 0, 0),
#    'high': 409.929,
#    'low': 368.633,
#    'market_cap': 38010600000.0,
#    'open': 385.905,
#    'volume': 1878130000.0},
#   {'close': 396.457,
#    'date': datetime.datetime(2018, 3, 31, 0, 0),
#    'high': 418.468,
#    'low': 392.953,
#    'market_cap': 38914900000.0,
#    'open': 395.004,
#    'volume': 1323920000.0},
#   {'close': 379.607,
#    'date': datetime.datetime(2018, 4, 1, 0, 0),
#    'high': 400.528,
#    'low': 363.805,
#    'market_cap': 39144700000.0,
#    'open': 397.254,
#    'volume': 1256930000.0},
#   {'close': 386.425,
#    'date': datetime.datetime(2018, 4, 2, 0, 0),
#    'high': 395.171,
#    'low': 377.593,
#    'market_cap': 37422500000.0,
#    'open': 379.699,
#    'volume': 1102260000.0},
#   {'close': 416.893,
#    'date': datetime.datetime(2018, 4, 3, 0, 0),
#    'high': 418.968,
#    'low': 383.532,
#    'market_cap': 38180800000.0,
#    'open': 387.312,
#    'volume': 1363400000.0},
#   {'close': 380.543,
#    'date': datetime.datetime(2018, 4, 4, 0, 0),
#    'high': 417.472,
#    'low': 375.31,
#    'market_cap': 41065100000.0,
#    'open': 416.485,
#    'volume': 1287730000.0},
#   {'close': 383.232,
#    'date': datetime.datetime(2018, 4, 5, 0, 0),
#    'high': 387.716,
#    'low': 369.816,
#    'market_cap': 37470200000.0,
#    'open': 379.947,
#    'volume': 1210680000.0},
#   {'close': 370.285,
#    'date': datetime.datetime(2018, 4, 6, 0, 0),
#    'high': 385.195,
#    'low': 366.911,
#    'market_cap': 37752600000.0,
#    'open': 382.731,
#    'volume': 967106000.0},
#   {'close': 385.314,
#    'date': datetime.datetime(2018, 4, 7, 0, 0),
#    'high': 393.059,
#    'low': 369.936,
#    'market_cap': 36541900000.0,
#    'open': 370.38,
#    'volume': 951475000.0},
#   {'close': 400.508,
#    'date': datetime.datetime(2018, 4, 8, 0, 0),
#    'high': 402.59,
#    'low': 385.602,
#    'market_cap': 38065400000.0,
#    'open': 385.743,
#    'volume': 948488000.0},
#   {'close': 398.526,
#    'date': datetime.datetime(2018, 4, 9, 0, 0),
#    'high': 429.251,
#    'low': 390.61,
#    'market_cap': 39565100000.0,
#    'open': 400.857,
#    'volume': 1478390000.0},
#   {'close': 414.243,
#    'date': datetime.datetime(2018, 4, 10, 0, 0),
#    'high': 415.888,
#    'low': 393.879,
#    'market_cap': 39430400000.0,
#    'open': 399.411,
#    'volume': 1196000000.0},
#   {'close': 430.54,
#    'date': datetime.datetime(2018, 4, 11, 0, 0),
#    'high': 430.54,
#    'low': 412.471,
#    'market_cap': 40980200000.0,
#    'open': 415.024,
#    'volume': 1439040000.0},
#   {'close': 492.941,
#    'date': datetime.datetime(2018, 4, 12, 0, 0),
#    'high': 493.058,
#    'low': 417.413,
#    'market_cap': 42483600000.0,
#    'open': 430.161,
#    'volume': 2519360000.0},
#   {'close': 492.735,
#    'date': datetime.datetime(2018, 4, 13, 0, 0),
#    'high': 526.47,
#    'low': 482.659,
#    'market_cap': 48715400000.0,
#    'open': 493.16,
#    'volume': 2419250000.0},
#   {'close': 501.478,
#    'date': datetime.datetime(2018, 4, 14, 0, 0),
#    'high': 512.024,
#    'low': 488.279,
#    'market_cap': 48668400000.0,
#    'open': 492.58,
#    'volume': 1519080000.0},
#   {'close': 531.702,
#    'date': datetime.datetime(2018, 4, 15, 0, 0),
#    'high': 531.702,
#    'low': 502.88,
#    'market_cap': 49696300000.0,
#    'open': 502.88,
#    'volume': 1726090000.0},
#   {'close': 511.147,
#    'date': datetime.datetime(2018, 4, 16, 0, 0),
#    'high': 534.197,
#    'low': 500.25,
#    'market_cap': 52592200000.0,
#    'open': 532.074,
#    'volume': 1758980000.0},
#   {'close': 502.894,
#    'date': datetime.datetime(2018, 4, 17, 0, 0),
#    'high': 518.031,
#    'low': 502.564,
#    'market_cap': 50534000000.0,
#    'open': 511.145,
#    'volume': 1760360000.0},
#   {'close': 524.789,
#    'date': datetime.datetime(2018, 4, 18, 0, 0),
#    'high': 525.092,
#    'low': 503.045,
#    'market_cap': 49769600000.0,
#    'open': 503.309,
#    'volume': 1762940000.0},
#   {'close': 567.889,
#    'date': datetime.datetime(2018, 4, 19, 0, 0),
#    'high': 567.889,
#    'low': 523.262,
#    'market_cap': 51829900000.0,
#    'open': 524.038,
#    'volume': 2256870000.0},
#   {'close': 615.718,
#    'date': datetime.datetime(2018, 4, 20, 0, 0),
#    'high': 618.715,
#    'low': 560.283,
#    'market_cap': 56188700000.0,
#    'open': 567.989,
#    'volume': 2849470000.0},
#   {'close': 605.395,
#    'date': datetime.datetime(2018, 4, 21, 0, 0),
#    'high': 621.888,
#    'low': 578.55,
#    'market_cap': 60951100000.0,
#    'open': 616.004,
#    'volume': 2612460000.0},
#   {'close': 621.86,
#    'date': datetime.datetime(2018, 4, 22, 0, 0),
#    'high': 640.767,
#    'low': 593.869,
#    'market_cap': 59985500000.0,
#    'open': 606.119,
#    'volume': 2426270000.0},
#   {'close': 642.548,
#    'date': datetime.datetime(2018, 4, 23, 0, 0),
#    'high': 646.7,
#    'low': 621.035,
#    'market_cap': 61490600000.0,
#    'open': 621.199,
#    'volume': 2386830000.0},
#   {'close': 708.158,
#    'date': datetime.datetime(2018, 4, 24, 0, 0),
#    'high': 708.875,
#    'low': 643.398,
#    'market_cap': 63701200000.0,
#    'open': 643.398,
#    'volume': 3581860000.0},
#   {'close': 615.416,
#    'date': datetime.datetime(2018, 4, 25, 0, 0),
#    'high': 707.062,
#    'low': 600.212,
#    'market_cap': 70018900000.0,
#    'open': 707.062,
#    'volume': 4216140000.0},
#   {'close': 662.809,
#    'date': datetime.datetime(2018, 4, 26, 0, 0),
#    'high': 663.181,
#    'low': 604.007,
#    'market_cap': 61219700000.0,
#    'open': 618.079,
#    'volume': 2984010000.0},
#   {'close': 647.032,
#    'date': datetime.datetime(2018, 4, 27, 0, 0),
#    'high': 684.868,
#    'low': 647.032,
#    'market_cap': 65594600000.0,
#    'open': 662.109,
#    'volume': 2598130000.0}],
#  'slug': 'ethereum',
#  'symbol': 'ETH'}

# %%
show_page("currencies/ethereum/historical-data")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/currencies/ethereum/historical-data"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `recently([convert="USD"])`
# Get recently added coins in coinmarketcap along with other metadata.

# %%
list(cmc.recently())
# Out:
# [{'added': '3 days ago',
#   'circulating_supply': 112776150.004,
#   'market_cap': 12214559.2546,
#   'name': 'Linker Coin',
#   'percent_change': 1.0,
#   'price': 0.108308,
#   'symbol': 'LNC',
#   'volume_24h': 71322.0},
#  {'added': '3 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'PHI Token',
#   'percent_change': None,
#   'price': 0.499389,
#   'symbol': 'PHI',
#   'volume_24h': 56438.6},
#  {'added': '3 days ago',
#   'circulating_supply': 212221521.567,
#   'market_cap': 31438496.2049,
#   'name': 'Dock',
#   'percent_change': 8.0,
#   'price': 0.14814,
#   'symbol': 'DOCK',
#   'volume_24h': 8579340.0},
#  {'added': '4 days ago',
#   'circulating_supply': 5045423.19075,
#   'market_cap': 6211824.12399,
#   'name': 'Masari',
#   'percent_change': None,
#   'price': 1.23118,
#   'symbol': 'MSR',
#   'volume_24h': 138802.0},
#  {'added': '4 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Chainium',
#   'percent_change': 1.0,
#   'price': 0.0975946,
#   'symbol': 'CHX',
#   'volume_24h': 69216.8},
#  {'added': '4 days ago',
#   'circulating_supply': 5052048083.95,
#   'market_cap': 17199546.1404,
#   'name': 'SRCOIN',
#   'percent_change': None,
#   'price': 0.00340447,
#   'symbol': 'SRCOIN',
#   'volume_24h': 110889.0},
#  {'added': '4 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Cropcoin',
#   'percent_change': None,
#   'price': 0.517676,
#   'symbol': 'CROP',
#   'volume_24h': 108153.0},
#  {'added': '4 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Pixie Coin',
#   'percent_change': 1.0,
#   'price': 0.00413572,
#   'symbol': 'PXC',
#   'volume_24h': 447667.0},
#  {'added': '5 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'MARK.SPACE',
#   'percent_change': 2.0,
#   'price': 0.110316,
#   'symbol': 'MRK',
#   'volume_24h': 344965.0},
#  {'added': '5 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Earth Token',
#   'percent_change': None,
#   'price': 0.0249679,
#   'symbol': 'EARTH',
#   'volume_24h': 394526.0},
#  {'added': '5 days ago',
#   'circulating_supply': 49503157.2631,
#   'market_cap': 12516526.7919,
#   'name': 'FintruX Network',
#   'percent_change': 5.0,
#   'price': 0.252843,
#   'symbol': 'FTX',
#   'volume_24h': 186838.0},
#  {'added': '5 days ago',
#   'circulating_supply': 193668526.316,
#   'market_cap': 12854825.9016,
#   'name': 'Effect.AI',
#   'percent_change': None,
#   'price': 0.0663754,
#   'symbol': 'EFX',
#   'volume_24h': 91130.4},
#  {'added': '5 days ago',
#   'circulating_supply': 1991384.0,
#   'market_cap': 5958439.98024,
#   'name': 'Dero',
#   'percent_change': 2.0,
#   'price': 2.99211,
#   'symbol': 'DERO',
#   'volume_24h': 43380.6},
#  {'added': '5 days ago',
#   'circulating_supply': 4528335.95792,
#   'market_cap': 2518062.71945,
#   'name': 'CryCash',
#   'percent_change': 1.0,
#   'price': 0.556068,
#   'symbol': 'CRC',
#   'volume_24h': 13681.4},
#  {'added': '5 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'StarCoin',
#   'percent_change': 3.0,
#   'price': 0.0581368,
#   'symbol': 'KST',
#   'volume_24h': 1685620.0},
#  {'added': '5 days ago',
#   'circulating_supply': 1863777.92934,
#   'market_cap': 6568643.02082,
#   'name': 'Haven Protocol',
#   'percent_change': None,
#   'price': 3.52437,
#   'symbol': 'XHV',
#   'volume_24h': 324623.0},
#  {'added': '7 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Aditus',
#   'percent_change': 0.0,
#   'price': 0.0153201,
#   'symbol': 'ADI',
#   'volume_24h': 312723.0},
#  {'added': '8 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Dignity',
#   'percent_change': 8.0,
#   'price': 0.0673449,
#   'symbol': 'DIG',
#   'volume_24h': 291885.0},
#  {'added': '8 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SyncFab',
#   'percent_change': 1.0,
#   'price': 0.0401075,
#   'symbol': 'MFG',
#   'volume_24h': 16401.1},
#  {'added': '8 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BrahmaOS',
#   'percent_change': None,
#   'price': 0.0796353,
#   'symbol': 'BRM',
#   'volume_24h': 167231.0},
#  {'added': '8 days ago',
#   'circulating_supply': 28395149.4225,
#   'market_cap': 10221231.5667,
#   'name': 'Daneel',
#   'percent_change': 1.0,
#   'price': 0.359964,
#   'symbol': 'DAN',
#   'volume_24h': 2149050.0},
#  {'added': '8 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Monero Classic',
#   'percent_change': None,
#   'price': 16.3973,
#   'symbol': 'XMC',
#   'volume_24h': 11773000.0},
#  {'added': '8 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Budbo',
#   'percent_change': 2.0,
#   'price': 0.053891,
#   'symbol': 'BUBO',
#   'volume_24h': 50843.2},
#  {'added': '8 days ago',
#   'circulating_supply': 16344757.737,
#   'market_cap': 19993234.5591,
#   'name': 'Auctus',
#   'percent_change': 3.0,
#   'price': 1.22322,
#   'symbol': 'AUC',
#   'volume_24h': 763031.0},
#  {'added': '8 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GreenMed',
#   'percent_change': 1.0,
#   'price': 0.168064,
#   'symbol': 'GRMD',
#   'volume_24h': 37061.7},
#  {'added': '8 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BelugaPay',
#   'percent_change': 4.0,
#   'price': 0.514507,
#   'symbol': 'BBI',
#   'volume_24h': 285198.0},
#  {'added': '8 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Monero Original',
#   'percent_change': None,
#   'price': 13.3007,
#   'symbol': 'XMO',
#   'volume_24h': 2371080.0},
#  {'added': '9 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Curriculum Vitae',
#   'percent_change': 1.0,
#   'price': 0.0334349,
#   'symbol': 'CVH',
#   'volume_24h': 191889.0},
#  {'added': '11 days ago',
#   'circulating_supply': 173256686.0,
#   'market_cap': 10033779.805,
#   'name': 'CommerceBlock',
#   'percent_change': None,
#   'price': 0.0579128,
#   'symbol': 'CBT',
#   'volume_24h': 111493.0},
#  {'added': '11 days ago',
#   'circulating_supply': 2435050.87415,
#   'market_cap': 5198760.56478,
#   'name': 'DeviantCoin',
#   'percent_change': None,
#   'price': 2.13497,
#   'symbol': 'DEV',
#   'volume_24h': 111206.0},
#  {'added': '11 days ago',
#   'circulating_supply': 728939512.0,
#   'market_cap': 1115073.3503,
#   'name': 'Bitsum',
#   'percent_change': 1.0,
#   'price': 0.00152972,
#   'symbol': 'BSM',
#   'volume_24h': 28564.0},
#  {'added': '11 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SnipCoin',
#   'percent_change': 2.0,
#   'price': 0.0012786,
#   'symbol': 'SNIP',
#   'volume_24h': 89289.2},
#  {'added': '11 days ago',
#   'circulating_supply': 102421214.28,
#   'market_cap': 8084772.18102,
#   'name': 'AdHive',
#   'percent_change': 1.0,
#   'price': 0.0789365,
#   'symbol': 'ADH',
#   'volume_24h': 740994.0},
#  {'added': '11 days ago',
#   'circulating_supply': 5721787903.0,
#   'market_cap': 29279132.5321,
#   'name': 'U Network',
#   'percent_change': 6.0,
#   'price': 0.00511713,
#   'symbol': 'UUU',
#   'volume_24h': 2988300.0},
#  {'added': '11 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eosDAC',
#   'percent_change': None,
#   'price': 0.160668,
#   'symbol': 'EOSDAC',
#   'volume_24h': 2150030.0},
#  {'added': '11 days ago',
#   'circulating_supply': 1899999999.15,
#   'market_cap': 30180929.9866,
#   'name': 'Sentinel',
#   'percent_change': 2.0,
#   'price': 0.0158847,
#   'symbol': 'SENT',
#   'volume_24h': 484793.0},
#  {'added': '11 days ago',
#   'circulating_supply': 279172874.0,
#   'market_cap': 14297559.569,
#   'name': 'CyberVein',
#   'percent_change': 5.0,
#   'price': 0.051214,
#   'symbol': 'CVT',
#   'volume_24h': 1331250.0},
#  {'added': '12 days ago',
#   'circulating_supply': 407036833.0,
#   'market_cap': 106440538.866,
#   'name': 'Apex',
#   'percent_change': 2.0,
#   'price': 0.261501,
#   'symbol': 'CPX',
#   'volume_24h': 1783350.0},
#  {'added': '12 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'WCOIN',
#   'percent_change': 3.0,
#   'price': 0.13723,
#   'symbol': 'WIN',
#   'volume_24h': 138856.0},
#  {'added': '12 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Arbitracoin',
#   'percent_change': None,
#   'price': 0.205505,
#   'symbol': 'ATC',
#   'volume_24h': 489772.0},
#  {'added': '12 days ago',
#   'circulating_supply': 149792458.0,
#   'market_cap': 260459125.97,
#   'name': 'Cortex',
#   'percent_change': 9.0,
#   'price': 1.7388,
#   'symbol': 'CTXC',
#   'volume_24h': 45822100.0},
#  {'added': '12 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Fidelium',
#   'percent_change': 1.0,
#   'price': 0.234462,
#   'symbol': 'FID',
#   'volume_24h': 385045.0},
#  {'added': '16 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TokenDesk',
#   'percent_change': 0.0,
#   'price': 0.3973,
#   'symbol': 'TDS',
#   'volume_24h': 142072.0},
#  {'added': '16 days ago',
#   'circulating_supply': 3361218448.95,
#   'market_cap': 32363256.5504,
#   'name': 'XinFin Network',
#   'percent_change': None,
#   'price': 0.00962843,
#   'symbol': 'XDCE',
#   'volume_24h': 479219.0},
#  {'added': '17 days ago',
#   'circulating_supply': 57082485.7285,
#   'market_cap': 25177942.8051,
#   'name': 'StakeNet',
#   'percent_change': None,
#   'price': 0.44108,
#   'symbol': 'XSN',
#   'volume_24h': 122832.0},
#  {'added': '18 days ago',
#   'circulating_supply': 177479000.832,
#   'market_cap': 34586930.2032,
#   'name': 'ODEM',
#   'percent_change': 0.0,
#   'price': 0.194879,
#   'symbol': 'ODE',
#   'volume_24h': 97255.3},
#  {'added': '18 days ago',
#   'circulating_supply': 1468214569.51,
#   'market_cap': 15620922.0908,
#   'name': 'PolySwarm',
#   'percent_change': None,
#   'price': 0.0106394,
#   'symbol': 'NCT',
#   'volume_24h': 77309.9},
#  {'added': '19 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Stellite',
#   'percent_change': None,
#   'price': 0.00130717,
#   'symbol': 'XTL',
#   'volume_24h': 50372.3},
#  {'added': '22 days ago',
#   'circulating_supply': 255628294.061,
#   'market_cap': 24639832.3247,
#   'name': 'Rentberry',
#   'percent_change': 4.0,
#   'price': 0.0963893,
#   'symbol': 'BERRY',
#   'volume_24h': 1025890.0},
#  {'added': '23 days ago',
#   'circulating_supply': 15327270.5328,
#   'market_cap': 134321454.95,
#   'name': 'TokenPay',
#   'percent_change': 4.0,
#   'price': 8.76356,
#   'symbol': 'TPAY',
#   'volume_24h': 1343920.0},
#  {'added': '24 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Friendz',
#   'percent_change': 0.0,
#   'price': 0.024394,
#   'symbol': 'FDZ',
#   'volume_24h': 46409.9},
#  {'added': '26 days ago',
#   'circulating_supply': 198057915.895,
#   'market_cap': 6289309.31345,
#   'name': 'Vice Industry Token',
#   'percent_change': None,
#   'price': 0.0317549,
#   'symbol': 'VIT',
#   'volume_24h': 150616.0},
#  {'added': '26 days ago',
#   'circulating_supply': 159219129.364,
#   'market_cap': 27305443.8095,
#   'name': 'Sentinel Chain',
#   'percent_change': None,
#   'price': 0.171496,
#   'symbol': 'SENC',
#   'volume_24h': 3024820.0},
#  {'added': '26 days ago',
#   'circulating_supply': 800000000.0,
#   'market_cap': 9529680.0,
#   'name': 'ClearCoin',
#   'percent_change': 1.0,
#   'price': 0.0119121,
#   'symbol': 'CLR',
#   'volume_24h': 13766.6},
#  {'added': '28 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Consensus',
#   'percent_change': None,
#   'price': 0.0260664,
#   'symbol': 'SEN',
#   'volume_24h': 89379.1},
#  {'added': '28 days ago',
#   'circulating_supply': 490610995.087,
#   'market_cap': 24816526.9034,
#   'name': 'Switcheo',
#   'percent_change': None,
#   'price': 0.0505829,
#   'symbol': 'SWH',
#   'volume_24h': 561051.0}]

# %%
show_page("new")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/new"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `exchange(name, [convert="USD"])`
# Get data about a exchange:

# %%
cmc.exchange("okex")
# Out:
# {'markets': [{'currency': 'EOS',
#    'pair': 'EOS/USDT',
#    'percent_volume': 23.6547515878,
#    'price': 18.9762,
#    'updated': True,
#    'volume_24h': 651305000.0},
#   {'currency': 'Bitcoin',
#    'pair': 'BTC/USDT',
#    'percent_volume': 14.0528048574,
#    'price': 9344.8,
#    'updated': True,
#    'volume_24h': 386927000.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/BTC',
#    'percent_volume': 4.9956432488,
#    'price': 18.9424,
#    'updated': True,
#    'volume_24h': 137549000.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/USDT',
#    'percent_volume': 4.87698904925,
#    'price': 1400.36,
#    'updated': True,
#    'volume_24h': 134282000.0},
#   {'currency': 'Ethereum',
#    'pair': 'ETH/USDT',
#    'percent_volume': 4.76701509264,
#    'price': 685.255,
#    'updated': True,
#    'volume_24h': 131254000.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/USDT',
#    'percent_volume': 3.01247286525,
#    'price': 21.8892,
#    'updated': True,
#    'volume_24h': 82944800.0},
#   {'currency': 'Mithril',
#    'pair': 'MITH/USDT',
#    'percent_volume': 2.96461530825,
#    'price': 1.26421,
#    'updated': True,
#    'volume_24h': 81627100.0},
#   {'currency': 'Mithril',
#    'pair': 'MITH/BTC',
#    'percent_volume': 2.73227534946,
#    'price': 1.26515,
#    'updated': True,
#    'volume_24h': 75229900.0},
#   {'currency': 'Ethereum',
#    'pair': 'ETH/BTC',
#    'percent_volume': 2.59451008783,
#    'price': 683.461,
#    'updated': True,
#    'volume_24h': 71436700.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/USDT',
#    'percent_volume': 2.4696961845,
#    'price': 151.577,
#    'updated': True,
#    'volume_24h': 68000100.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/BTC',
#    'percent_volume': 1.75098296459,
#    'price': 1395.4,
#    'updated': True,
#    'volume_24h': 48211200.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/BTC',
#    'percent_volume': 1.69638823157,
#    'price': 1.22706,
#    'updated': True,
#    'volume_24h': 46708000.0},
#   {'currency': 'Hshare',
#    'pair': 'HSR/BTC',
#    'percent_volume': 1.4623340156,
#    'price': 13.3517,
#    'updated': True,
#    'volume_24h': 40263600.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/USDT',
#    'percent_volume': 1.44097117502,
#    'price': 0.866784,
#    'updated': True,
#    'volume_24h': 39675400.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/BTC',
#    'percent_volume': 1.41844612618,
#    'price': 0.0830985,
#    'updated': True,
#    'volume_24h': 39055200.0},
#   {'currency': 'Mithril',
#    'pair': 'MITH/ETH',
#    'percent_volume': 1.4180756723,
#    'price': 1.26971,
#    'updated': True,
#    'volume_24h': 39045000.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/BTC',
#    'percent_volume': 1.33363761031,
#    'price': 21.8636,
#    'updated': True,
#    'volume_24h': 36720100.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/USDT',
#    'percent_volume': 1.21956323768,
#    'price': 0.0831273,
#    'updated': True,
#    'volume_24h': 33579200.0},
#   {'currency': 'Ontology',
#    'pair': 'ONT/USDT',
#    'percent_volume': 1.16294916781,
#    'price': 6.85195,
#    'updated': True,
#    'volume_24h': 32020400.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/BTC',
#    'percent_volume': 1.12883835538,
#    'price': 151.551,
#    'updated': True,
#    'volume_24h': 31081200.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/ETH',
#    'percent_volume': 0.846221993646,
#    'price': 18.9697,
#    'updated': True,
#    'volume_24h': 23299700.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/BTC',
#    'percent_volume': 0.828491053878,
#    'price': 0.867679,
#    'updated': True,
#    'volume_24h': 22811500.0},
#   {'currency': 'Ontology',
#    'pair': 'ONT/BTC',
#    'percent_volume': 0.753230805239,
#    'price': 6.74218,
#    'updated': True,
#    'volume_24h': 20739300.0},
#   {'currency': 'Hshare',
#    'pair': 'HSR/USDT',
#    'percent_volume': 0.659433334851,
#    'price': 13.4544,
#    'updated': True,
#    'volume_24h': 18156700.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/USDT',
#    'percent_volume': 0.62282740656,
#    'price': 0.986724,
#    'updated': True,
#    'volume_24h': 17148800.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/ETH',
#    'percent_volume': 0.604282921011,
#    'price': 0.0827669,
#    'updated': True,
#    'volume_24h': 16638200.0},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/USDT',
#    'percent_volume': 0.603694553079,
#    'price': 0.0538177,
#    'updated': True,
#    'volume_24h': 16622000.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/USDT',
#    'percent_volume': 0.454027552491,
#    'price': 1.219,
#    'updated': True,
#    'volume_24h': 12501100.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/USDT',
#    'percent_volume': 0.447976805737,
#    'price': 21.2547,
#    'updated': True,
#    'volume_24h': 12334500.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/BTC',
#    'percent_volume': 0.381868947145,
#    'price': 21.163,
#    'updated': True,
#    'volume_24h': 10514300.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/USDT',
#    'percent_volume': 0.327713310937,
#    'price': 77.2422,
#    'updated': True,
#    'volume_24h': 9023190.0},
#   {'currency': 'Game.com',
#    'pair': 'GTC/USDT',
#    'percent_volume': 0.324365424768,
#    'price': 0.208068,
#    'updated': True,
#    'volume_24h': 8931010.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/ETH',
#    'percent_volume': 0.303076674965,
#    'price': 21.7362,
#    'updated': True,
#    'volume_24h': 8344850.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/USDT',
#    'percent_volume': 0.288259609219,
#    'price': 1.46488,
#    'updated': True,
#    'volume_24h': 7936880.0},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/BTC',
#    'percent_volume': 0.2865210183,
#    'price': 0.0535939,
#    'updated': True,
#    'volume_24h': 7889010.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/BTC',
#    'percent_volume': 0.286516660019,
#    'price': 0.981029,
#    'updated': True,
#    'volume_24h': 7888890.0},
#   {'currency': 'Monaco',
#    'pair': 'MCO/BTC',
#    'percent_volume': 0.284219119565,
#    'price': 12.2098,
#    'updated': True,
#    'volume_24h': 7825630.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/BTC',
#    'percent_volume': 0.281787198781,
#    'price': 2.04945,
#    'updated': True,
#    'volume_24h': 7758670.0},
#   {'currency': 'Loopring',
#    'pair': 'LRC/USDT',
#    'percent_volume': 0.279451523368,
#    'price': 0.85378,
#    'updated': True,
#    'volume_24h': 7694360.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/USDT',
#    'percent_volume': 0.276417070239,
#    'price': 0.0779256,
#    'updated': True,
#    'volume_24h': 7610810.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/USDT',
#    'percent_volume': 0.275690326887,
#    'price': 0.318004,
#    'updated': True,
#    'volume_24h': 7590800.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/ETH',
#    'percent_volume': 0.274270253669,
#    'price': 0.0155825,
#    'updated': True,
#    'volume_24h': 7551700.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/BTC',
#    'percent_volume': 0.267088169812,
#    'price': 76.929,
#    'updated': True,
#    'volume_24h': 7353950.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/BTC',
#    'percent_volume': 0.256727809554,
#    'price': 0.0155926,
#    'updated': True,
#    'volume_24h': 7068690.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/BTC',
#    'percent_volume': 0.244745805583,
#    'price': 0.372916,
#    'updated': True,
#    'volume_24h': 6738780.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/USDT',
#    'percent_volume': 0.227874173548,
#    'price': 2.05487,
#    'updated': True,
#    'volume_24h': 6274240.0},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/USDT',
#    'percent_volume': 0.221121017177,
#    'price': 0.0176058,
#    'updated': True,
#    'volume_24h': 6088300.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/BTC',
#    'percent_volume': 0.210404730639,
#    'price': 0.0759091,
#    'updated': True,
#    'volume_24h': 5793240.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/BTC',
#    'percent_volume': 0.208114453986,
#    'price': 1.4504,
#    'updated': True,
#    'volume_24h': 5730180.0},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/USDT',
#    'percent_volume': 0.203296011178,
#    'price': 0.145848,
#    'updated': True,
#    'volume_24h': 5597510.0},
#   {'currency': 'Dash',
#    'pair': 'DASH/USDT',
#    'percent_volume': 0.202468664173,
#    'price': 496.379,
#    'updated': True,
#    'volume_24h': 5574730.0},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/USDT',
#    'percent_volume': 0.184053111103,
#    'price': 5.85182,
#    'updated': True,
#    'volume_24h': 5067680.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/BTC',
#    'percent_volume': 0.178787218114,
#    'price': 0.316335,
#    'updated': True,
#    'volume_24h': 4922690.0},
#   {'currency': 'ProChain',
#    'pair': 'PRA/BTC',
#    'percent_volume': 0.17094594426,
#    'price': 0.369648,
#    'updated': True,
#    'volume_24h': 4706790.0},
#   {'currency': 'ProChain',
#    'pair': 'PRA/USDT',
#    'percent_volume': 0.168139574502,
#    'price': 0.369421,
#    'updated': True,
#    'volume_24h': 4629520.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/ETH',
#    'percent_volume': 0.161777210658,
#    'price': 0.863545,
#    'updated': True,
#    'volume_24h': 4454340.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/USDT',
#    'percent_volume': 0.14444323765,
#    'price': 0.135544,
#    'updated': True,
#    'volume_24h': 3977070.0},
#   {'currency': 'Cube',
#    'pair': 'AUTO/BTC',
#    'percent_volume': 0.144386216807,
#    'price': 0.015686,
#    'updated': True,
#    'volume_24h': 3975500.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/USDT',
#    'percent_volume': 0.143337687042,
#    'price': 8.31903,
#    'updated': True,
#    'volume_24h': 3946630.0},
#   {'currency': 'Ontology',
#    'pair': 'ONT/ETH',
#    'percent_volume': 0.140393305054,
#    'price': 6.81151,
#    'updated': True,
#    'volume_24h': 3865560.0},
#   {'currency': 'Game.com',
#    'pair': 'GTC/BTC',
#    'percent_volume': 0.139365840314,
#    'price': 0.206346,
#    'updated': True,
#    'volume_24h': 3837270.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/ETH',
#    'percent_volume': 0.139271047702,
#    'price': 0.134984,
#    'updated': True,
#    'volume_24h': 3834660.0},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/USDT',
#    'percent_volume': 0.128248591926,
#    'price': 18.262,
#    'updated': True,
#    'volume_24h': 3531170.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/USDT',
#    'percent_volume': 0.126278648925,
#    'price': 0.374323,
#    'updated': True,
#    'volume_24h': 3476930.0},
#   {'currency': 'Loopring',
#    'pair': 'LRC/BTC',
#    'percent_volume': 0.118859765135,
#    'price': 0.839575,
#    'updated': True,
#    'volume_24h': 3272660.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/BTC',
#    'percent_volume': 0.116056664088,
#    'price': 0.421655,
#    'updated': True,
#    'volume_24h': 3195480.0},
#   {'currency': 'Status',
#    'pair': 'SNT/USDT',
#    'percent_volume': 0.110504214126,
#    'price': 0.158152,
#    'updated': True,
#    'volume_24h': 3042600.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/USDT',
#    'percent_volume': 0.109603865914,
#    'price': 0.422038,
#    'updated': True,
#    'volume_24h': 3017810.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/BTC',
#    'percent_volume': 0.105796907482,
#    'price': 2.08708,
#    'updated': True,
#    'volume_24h': 2912990.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/BTC',
#    'percent_volume': 0.103766311738,
#    'price': 0.137066,
#    'updated': True,
#    'volume_24h': 2857080.0},
#   {'currency': 'DADI',
#    'pair': 'DADI/BTC',
#    'percent_volume': 0.102624805313,
#    'price': 0.317268,
#    'updated': True,
#    'volume_24h': 2825650.0},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/USDT',
#    'percent_volume': 0.100772899088,
#    'price': 0.21237,
#    'updated': True,
#    'volume_24h': 2774660.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/USDT',
#    'percent_volume': 0.0991628774581,
#    'price': 1.14568,
#    'updated': True,
#    'volume_24h': 2730330.0},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/BTC',
#    'percent_volume': 0.0978815428514,
#    'price': 0.046031,
#    'updated': True,
#    'volume_24h': 2695050.0},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/BTC',
#    'percent_volume': 0.09474684926,
#    'price': 0.212975,
#    'updated': True,
#    'volume_24h': 2608740.0},
#   {'currency': 'Arcblock',
#    'pair': 'ABT/USDT',
#    'percent_volume': 0.0933768962735,
#    'price': 1.20239,
#    'updated': True,
#    'volume_24h': 2571020.0},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/BTC',
#    'percent_volume': 0.0900482591787,
#    'price': 0.01746,
#    'updated': True,
#    'volume_24h': 2479370.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/USDT',
#    'percent_volume': 0.0882653590697,
#    'price': 0.15325,
#    'updated': True,
#    'volume_24h': 2430280.0},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/BTC',
#    'percent_volume': 0.0874739678827,
#    'price': 5.87012,
#    'updated': True,
#    'volume_24h': 2408490.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/ETH',
#    'percent_volume': 0.0869397152731,
#    'price': 1.21553,
#    'updated': True,
#    'volume_24h': 2393780.0},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/BTC',
#    'percent_volume': 0.0794362081942,
#    'price': 0.144722,
#    'updated': True,
#    'volume_24h': 2187180.0},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/BTC',
#    'percent_volume': 0.078563825619,
#    'price': 18.2832,
#    'updated': True,
#    'volume_24h': 2163160.0},
#   {'currency': 'Arcblock',
#    'pair': 'ABT/BTC',
#    'percent_volume': 0.0772153008472,
#    'price': 1.20026,
#    'updated': True,
#    'volume_24h': 2126030.0},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/ETH',
#    'percent_volume': 0.0729111351942,
#    'price': 0.352052,
#    'updated': True,
#    'volume_24h': 2007520.0},
#   {'currency': 'Super Bitcoin',
#    'pair': 'SBTC/BTC',
#    'percent_volume': 0.0716929956616,
#    'price': 20.6444,
#    'updated': True,
#    'volume_24h': 1973980.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/BTC',
#    'percent_volume': 0.0716701146865,
#    'price': 0.153125,
#    'updated': True,
#    'volume_24h': 1973350.0},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/BTC',
#    'percent_volume': 0.0715121270011,
#    'price': 0.142575,
#    'updated': True,
#    'volume_24h': 1969000.0},
#   {'currency': 'Game.com',
#    'pair': 'GTC/ETH',
#    'percent_volume': 0.0684290064013,
#    'price': 0.209909,
#    'updated': True,
#    'volume_24h': 1884110.0},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/BTC',
#    'percent_volume': 0.0650923791247,
#    'price': 0.429498,
#    'updated': True,
#    'volume_24h': 1792240.0},
#   {'currency': 'Monaco',
#    'pair': 'MCO/USDT',
#    'percent_volume': 0.064503648003,
#    'price': 12.2908,
#    'updated': True,
#    'volume_24h': 1776030.0},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/BTC',
#    'percent_volume': 0.0623386719285,
#    'price': 1.41352,
#    'updated': True,
#    'volume_24h': 1716420.0},
#   {'currency': 'YEE',
#    'pair': 'YEE/USDT',
#    'percent_volume': 0.0616932831541,
#    'price': 0.0168055,
#    'updated': True,
#    'volume_24h': 1698650.0},
#   {'currency': 'Hshare',
#    'pair': 'HSR/ETH',
#    'percent_volume': 0.0593590605018,
#    'price': 13.3058,
#    'updated': True,
#    'volume_24h': 1634380.0},
#   {'currency': 'Dash',
#    'pair': 'DASH/BTC',
#    'percent_volume': 0.0593361795267,
#    'price': 497.116,
#    'updated': True,
#    'volume_24h': 1633750.0},
#   {'currency': 'Revain',
#    'pair': 'R/BTC',
#    'percent_volume': 0.0582549626548,
#    'price': 0.959368,
#    'updated': True,
#    'volume_24h': 1603980.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/BTC',
#    'percent_volume': 0.0541792435628,
#    'price': 8.27614,
#    'updated': True,
#    'volume_24h': 1491760.0},
#   {'currency': 'Status',
#    'pair': 'SNT/BTC',
#    'percent_volume': 0.0537949884569,
#    'price': 0.156953,
#    'updated': True,
#    'volume_24h': 1481180.0},
#   {'currency': 'ProChain',
#    'pair': 'PRA/ETH',
#    'percent_volume': 0.0534078278302,
#    'price': 0.36855,
#    'updated': True,
#    'volume_24h': 1470520.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/ETH',
#    'percent_volume': 0.0531594058146,
#    'price': 0.374943,
#    'updated': True,
#    'volume_24h': 1463680.0},
#   {'currency': 'Viberate',
#    'pair': 'VIB/BTC',
#    'percent_volume': 0.0518853350096,
#    'price': 0.215683,
#    'updated': True,
#    'volume_24h': 1428600.0},
#   {'currency': 'Nuls',
#    'pair': 'NULS/BTC',
#    'percent_volume': 0.0508001230467,
#    'price': 3.64943,
#    'updated': True,
#    'volume_24h': 1398720.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/ETH',
#    'percent_volume': 0.0498703564387,
#    'price': 2.04298,
#    'updated': True,
#    'volume_24h': 1373120.0},
#   {'currency': 'Hi Mutual Society',
#    'pair': 'HMC/USDT',
#    'percent_volume': 0.0498184202571,
#    'price': 0.0589193,
#    'updated': True,
#    'volume_24h': 1371690.0},
#   {'currency': 'Hi Mutual Society',
#    'pair': 'HMC/BTC',
#    'percent_volume': 0.0494087418454,
#    'price': 0.0594761,
#    'updated': True,
#    'volume_24h': 1360410.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/ETH',
#    'percent_volume': 0.0492896154988,
#    'price': 0.984717,
#    'updated': True,
#    'volume_24h': 1357130.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/ETH',
#    'percent_volume': 0.0475492086293,
#    'price': 1397.62,
#    'updated': True,
#    'volume_24h': 1309210.0},
#   {'currency': 'Gifto',
#    'pair': 'GTO/BTC',
#    'percent_volume': 0.0451986424234,
#    'price': 0.557694,
#    'updated': True,
#    'volume_24h': 1244490.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/USDT',
#    'percent_volume': 0.0449389615153,
#    'price': 4.71835,
#    'updated': True,
#    'volume_24h': 1237340.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/USDT',
#    'percent_volume': 0.0448020388546,
#    'price': 0.0156051,
#    'updated': True,
#    'volume_24h': 1233570.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/ETH',
#    'percent_volume': 0.0444987751368,
#    'price': 76.6435,
#    'updated': True,
#    'volume_24h': 1225220.0},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/USDT',
#    'percent_volume': 0.0441261421134,
#    'price': 0.0970318,
#    'updated': True,
#    'volume_24h': 1214960.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/ETH',
#    'percent_volume': 0.0435239729587,
#    'price': 21.1107,
#    'updated': True,
#    'volume_24h': 1198380.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/BTC',
#    'percent_volume': 0.0430779755389,
#    'price': 4.7058,
#    'updated': True,
#    'volume_24h': 1186100.0},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/USDT',
#    'percent_volume': 0.0426287094084,
#    'price': 0.0463152,
#    'updated': True,
#    'volume_24h': 1173730.0},
#   {'currency': 'ugChain',
#    'pair': 'UGC/ETH',
#    'percent_volume': 0.0420003905678,
#    'price': 0.0516088,
#    'updated': True,
#    'volume_24h': 1156430.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/ETH',
#    'percent_volume': 0.0410197773483,
#    'price': 0.0774269,
#    'updated': True,
#    'volume_24h': 1129430.0},
#   {'currency': 'SunContract',
#    'pair': 'SNC/BTC',
#    'percent_volume': 0.0408592473324,
#    'price': 0.225393,
#    'updated': True,
#    'volume_24h': 1125010.0},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/USDT',
#    'percent_volume': 0.0390614564302,
#    'price': 6.9961,
#    'updated': True,
#    'volume_24h': 1075510.0},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/BTC',
#    'percent_volume': 0.0387247792248,
#    'price': 0.350601,
#    'updated': True,
#    'volume_24h': 1066240.0},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/USDT',
#    'percent_volume': 0.0380005782028,
#    'price': 0.133144,
#    'updated': True,
#    'volume_24h': 1046300.0},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/USDT',
#    'percent_volume': 0.0362340579665,
#    'price': 0.0359118,
#    'updated': True,
#    'volume_24h': 997661.0},
#   {'currency': 'Arcblock',
#    'pair': 'ABT/ETH',
#    'percent_volume': 0.0362112496294,
#    'price': 1.19008,
#    'updated': True,
#    'volume_24h': 997033.0},
#   {'currency': 'Hi Mutual Society',
#    'pair': 'HMC/ETH',
#    'percent_volume': 0.0357005680562,
#    'price': 0.0594855,
#    'updated': True,
#    'volume_24h': 982972.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/USDT',
#    'percent_volume': 0.0354920243115,
#    'price': 0.12304,
#    'updated': True,
#    'volume_24h': 977230.0},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/USDT',
#    'percent_volume': 0.03496699673,
#    'price': 0.422439,
#    'updated': True,
#    'volume_24h': 962774.0},
#   {'currency': 'YEE',
#    'pair': 'YEE/BTC',
#    'percent_volume': 0.0344435671849,
#    'price': 0.0169932,
#    'updated': True,
#    'volume_24h': 948362.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/USDT',
#    'percent_volume': 0.0339989498874,
#    'price': 0.00430141,
#    'updated': True,
#    'volume_24h': 936120.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/ETH',
#    'percent_volume': 0.0338879226796,
#    'price': 1.44183,
#    'updated': True,
#    'volume_24h': 933063.0},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/ETH',
#    'percent_volume': 0.0335337397123,
#    'price': 0.0535575,
#    'updated': True,
#    'volume_24h': 923311.0},
#   {'currency': 'Nuls',
#    'pair': 'NULS/USDT',
#    'percent_volume': 0.0331647385897,
#    'price': 3.647,
#    'updated': True,
#    'volume_24h': 913151.0},
#   {'currency': 'Po.et',
#    'pair': 'POE/USDT',
#    'percent_volume': 0.0330391111406,
#    'price': 0.064121,
#    'updated': True,
#    'volume_24h': 909692.0},
#   {'currency': 'Gifto',
#    'pair': 'GTO/USDT',
#    'percent_volume': 0.032870881495,
#    'price': 0.560084,
#    'updated': True,
#    'volume_24h': 905060.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/ETH',
#    'percent_volume': 0.0324512879941,
#    'price': 0.0454756,
#    'updated': True,
#    'volume_24h': 893507.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/BTC',
#    'percent_volume': 0.0323831898539,
#    'price': 0.122033,
#    'updated': True,
#    'volume_24h': 891632.0},
#   {'currency': 'Republic Protocol',
#    'pair': 'REN/BTC',
#    'percent_volume': 0.0319980994107,
#    'price': 0.0802041,
#    'updated': True,
#    'volume_24h': 881029.0},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/BTC',
#    'percent_volume': 0.0319832086174,
#    'price': 0.155926,
#    'updated': True,
#    'volume_24h': 880619.0},
#   {'currency': 'Bankex',
#    'pair': 'BKX/BTC',
#    'percent_volume': 0.0308714837786,
#    'price': 0.567404,
#    'updated': True,
#    'volume_24h': 850009.0},
#   {'currency': 'Primas',
#    'pair': 'PST/USDT',
#    'percent_volume': 0.0300522722313,
#    'price': 0.240079,
#    'updated': True,
#    'volume_24h': 827453.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/USDT',
#    'percent_volume': 0.0295563361754,
#    'price': 0.0460151,
#    'updated': True,
#    'volume_24h': 813798.0},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/ETH',
#    'percent_volume': 0.0287842667006,
#    'price': 0.142574,
#    'updated': True,
#    'volume_24h': 792540.0},
#   {'currency': 'Revain',
#    'pair': 'R/ETH',
#    'percent_volume': 0.0282286585143,
#    'price': 0.96093,
#    'updated': True,
#    'volume_24h': 777242.0},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/ETH',
#    'percent_volume': 0.0278258443951,
#    'price': 0.0799977,
#    'updated': True,
#    'volume_24h': 766151.0},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/USDT',
#    'percent_volume': 0.0257404432675,
#    'price': 0.415236,
#    'updated': True,
#    'volume_24h': 708732.0},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/USDT',
#    'percent_volume': 0.0252833685503,
#    'price': 2.66938,
#    'updated': True,
#    'volume_24h': 696147.0},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/BTC',
#    'percent_volume': 0.025246577395,
#    'price': 0.419881,
#    'updated': True,
#    'volume_24h': 695134.0},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/ETH',
#    'percent_volume': 0.0250415929132,
#    'price': 0.434743,
#    'updated': True,
#    'volume_24h': 689490.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/BTC',
#    'percent_volume': 0.0244457069468,
#    'price': 0.0458442,
#    'updated': True,
#    'volume_24h': 673083.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/ETH',
#    'percent_volume': 0.0240590184673,
#    'price': 0.00153158,
#    'updated': True,
#    'volume_24h': 662436.0},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/USDT',
#    'percent_volume': 0.0231068067122,
#    'price': 1.42037,
#    'updated': True,
#    'volume_24h': 636218.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/USDT',
#    'percent_volume': 0.0216940699341,
#    'price': 0.00150049,
#    'updated': True,
#    'volume_24h': 597320.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/USDT',
#    'percent_volume': 0.0214675482805,
#    'price': 0.00150049,
#    'updated': True,
#    'volume_24h': 591083.0},
#   {'currency': 'Po.et',
#    'pair': 'POE/BTC',
#    'percent_volume': 0.0214143046145,
#    'price': 0.0635844,
#    'updated': True,
#    'volume_24h': 589617.0},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/BTC',
#    'percent_volume': 0.0212453122697,
#    'price': 0.06097,
#    'updated': True,
#    'volume_24h': 584964.0},
#   {'currency': 'Refereum',
#    'pair': 'RFR/BTC',
#    'percent_volume': 0.0211097334124,
#    'price': 0.0137253,
#    'updated': True,
#    'volume_24h': 581231.0},
#   {'currency': 'ChatCoin',
#    'pair': 'CHAT/USDT',
#    'percent_volume': 0.0205757713549,
#    'price': 0.131543,
#    'updated': True,
#    'volume_24h': 566529.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/BTC',
#    'percent_volume': 0.0205587740591,
#    'price': 1.14162,
#    'updated': True,
#    'volume_24h': 566061.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/BTC',
#    'percent_volume': 0.020285618799,
#    'price': 0.00149391,
#    'updated': True,
#    'volume_24h': 558540.0},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/USDT',
#    'percent_volume': 0.0201143383567,
#    'price': 0.0626205,
#    'updated': True,
#    'volume_24h': 553824.0},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/BTC',
#    'percent_volume': 0.0200632738312,
#    'price': 0.132584,
#    'updated': True,
#    'volume_24h': 552418.0},
#   {'currency': 'Loopring',
#    'pair': 'LRC/ETH',
#    'percent_volume': 0.0200540851222,
#    'price': 0.841768,
#    'updated': True,
#    'volume_24h': 552165.0},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/BTC',
#    'percent_volume': 0.0198683860336,
#    'price': 0.0359471,
#    'updated': True,
#    'volume_24h': 547052.0},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/USDT',
#    'percent_volume': 0.0191936515007,
#    'price': 0.0525172,
#    'updated': True,
#    'volume_24h': 528474.0},
#   {'currency': 'IPChain',
#    'pair': 'IPC/USDT',
#    'percent_volume': 0.0187279328595,
#    'price': 0.507466,
#    'updated': True,
#    'volume_24h': 515651.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/ETH',
#    'percent_volume': 0.018323702299,
#    'price': 0.12161,
#    'updated': True,
#    'volume_24h': 504521.0},
#   {'currency': 'QunQun',
#    'pair': 'QUN/USDT',
#    'percent_volume': 0.0178227905389,
#    'price': 0.0472155,
#    'updated': True,
#    'volume_24h': 490729.0},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/ETH',
#    'percent_volume': 0.0174347582561,
#    'price': 0.143928,
#    'updated': True,
#    'volume_24h': 480045.0},
#   {'currency': 'ChatCoin',
#    'pair': 'CHAT/BTC',
#    'percent_volume': 0.0172811288517,
#    'price': 0.132491,
#    'updated': True,
#    'volume_24h': 475815.0},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/BTC',
#    'percent_volume': 0.0169767392446,
#    'price': 76.1659,
#    'updated': True,
#    'volume_24h': 467434.0},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/ETH',
#    'percent_volume': 0.0168193326634,
#    'price': 0.211276,
#    'updated': True,
#    'volume_24h': 463100.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/USDT',
#    'percent_volume': 0.0163655266569,
#    'price': 2.08328,
#    'updated': True,
#    'volume_24h': 450605.0},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/BTC',
#    'percent_volume': 0.0161779752989,
#    'price': 0.0505127,
#    'updated': True,
#    'volume_24h': 445441.0},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/BTC',
#    'percent_volume': 0.0160684008514,
#    'price': 2.63628,
#    'updated': True,
#    'volume_24h': 442424.0},
#   {'currency': 'Bankex',
#    'pair': 'BKX/USDT',
#    'percent_volume': 0.0158687189447,
#    'price': 0.558283,
#    'updated': True,
#    'volume_24h': 436926.0},
#   {'currency': 'QunQun',
#    'pair': 'QUN/BTC',
#    'percent_volume': 0.0158427871729,
#    'price': 0.0471514,
#    'updated': True,
#    'volume_24h': 436212.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/ETH',
#    'percent_volume': 0.0157087700329,
#    'price': 8.30956,
#    'updated': True,
#    'volume_24h': 432522.0},
#   {'currency': 'QunQun',
#    'pair': 'QUN/ETH',
#    'percent_volume': 0.0154089203018,
#    'price': 0.0472944,
#    'updated': True,
#    'volume_24h': 424266.0},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/USDT',
#    'percent_volume': 0.0153434734492,
#    'price': 0.0805264,
#    'updated': True,
#    'volume_24h': 422464.0},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/ETH',
#    'percent_volume': 0.0147059295805,
#    'price': 0.418388,
#    'updated': True,
#    'volume_24h': 404910.0},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/ETH',
#    'percent_volume': 0.0145584744075,
#    'price': 0.0357528,
#    'updated': True,
#    'volume_24h': 400850.0},
#   {'currency': 'BitcoinX',
#    'pair': 'BCX/BTC',
#    'percent_volume': 0.0142890963242,
#    'price': 0.00774964,
#    'updated': True,
#    'volume_24h': 393433.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/ETH',
#    'percent_volume': 0.013903570053,
#    'price': 151.294,
#    'updated': True,
#    'volume_24h': 382818.0},
#   {'currency': 'Viberate',
#    'pair': 'VIB/ETH',
#    'percent_volume': 0.0136216982309,
#    'price': 0.213143,
#    'updated': True,
#    'volume_24h': 375057.0},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/ETH',
#    'percent_volume': 0.0134991578975,
#    'price': 0.0455919,
#    'updated': True,
#    'volume_24h': 371683.0},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/USDT',
#    'percent_volume': 0.0133758548649,
#    'price': 0.142547,
#    'updated': True,
#    'volume_24h': 368288.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/ETH',
#    'percent_volume': 0.0133376109493,
#    'price': 4.72701,
#    'updated': True,
#    'volume_24h': 367235.0},
#   {'currency': 'Golem',
#    'pair': 'GNT/USDT',
#    'percent_volume': 0.0132659172273,
#    'price': 0.606499,
#    'updated': True,
#    'volume_24h': 365261.0},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/BTC',
#    'percent_volume': 0.0127691821532,
#    'price': 0.051353,
#    'updated': True,
#    'volume_24h': 351584.0},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/USDT',
#    'percent_volume': 0.0127219674426,
#    'price': 0.0505166,
#    'updated': True,
#    'volume_24h': 350284.0},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/USDT',
#    'percent_volume': 0.012683541932,
#    'price': 292.968,
#    'updated': True,
#    'volume_24h': 349226.0},
#   {'currency': 'Golem',
#    'pair': 'GNT/BTC',
#    'percent_volume': 0.0125769093241,
#    'price': 0.604939,
#    'updated': True,
#    'volume_24h': 346290.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/ETH',
#    'percent_volume': 0.0125323822202,
#    'price': 0.00149739,
#    'updated': True,
#    'volume_24h': 345064.0},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/BTC',
#    'percent_volume': 0.0123231847334,
#    'price': 0.149297,
#    'updated': True,
#    'volume_24h': 339304.0},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/BTC',
#    'percent_volume': 0.0122235616941,
#    'price': 292.79,
#    'updated': True,
#    'volume_24h': 336561.0},
#   {'currency': 'ugChain',
#    'pair': 'UGC/BTC',
#    'percent_volume': 0.0121949059967,
#    'price': 0.0500458,
#    'updated': True,
#    'volume_24h': 335772.0},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/ETH',
#    'percent_volume': 0.0117071417175,
#    'price': 0.0174764,
#    'updated': True,
#    'volume_24h': 322342.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/ETH',
#    'percent_volume': 0.0117028560746,
#    'price': 0.317208,
#    'updated': True,
#    'volume_24h': 322224.0},
#   {'currency': 'Viberate',
#    'pair': 'VIB/USDT',
#    'percent_volume': 0.0116503751078,
#    'price': 0.211369,
#    'updated': True,
#    'volume_24h': 320779.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/ETH',
#    'percent_volume': 0.0114222190988,
#    'price': 0.153438,
#    'updated': True,
#    'volume_24h': 314497.0},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/USDT',
#    'percent_volume': 0.0112753813489,
#    'price': 0.450048,
#    'updated': True,
#    'volume_24h': 310454.0},
#   {'currency': 'Dent',
#    'pair': 'DENT/BTC',
#    'percent_volume': 0.0110492955233,
#    'price': 0.0115778,
#    'updated': True,
#    'volume_24h': 304229.0},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/USDT',
#    'percent_volume': 0.0110046957813,
#    'price': 0.06102,
#    'updated': True,
#    'volume_24h': 303001.0},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/BTC',
#    'percent_volume': 0.0109856646211,
#    'price': 0.0992514,
#    'updated': True,
#    'volume_24h': 302477.0},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/USDT',
#    'percent_volume': 0.0105389771401,
#    'price': 0.085328,
#    'updated': True,
#    'volume_24h': 290178.0},
#   {'currency': 'Nuls',
#    'pair': 'NULS/ETH',
#    'percent_volume': 0.0104870772775,
#    'price': 3.63801,
#    'updated': True,
#    'volume_24h': 288749.0},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/USDT',
#    'percent_volume': 0.0101446979879,
#    'price': 76.2921,
#    'updated': True,
#    'volume_24h': 279322.0},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/ETH',
#    'percent_volume': 0.00995750982003,
#    'price': 0.0605179,
#    'updated': True,
#    'volume_24h': 274168.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/BTC',
#    'percent_volume': 0.00968827701279,
#    'price': 0.00429498,
#    'updated': True,
#    'volume_24h': 266755.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/BTC',
#    'percent_volume': 0.00967494793681,
#    'price': 0.0675059,
#    'updated': True,
#    'volume_24h': 266388.0},
#   {'currency': 'Cube',
#    'pair': 'AUTO/USDT',
#    'percent_volume': 0.00957623287272,
#    'price': 0.0156051,
#    'updated': True,
#    'volume_24h': 263670.0},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/BTC',
#    'percent_volume': 0.00951677865642,
#    'price': 0.0445371,
#    'updated': True,
#    'volume_24h': 262033.0},
#   {'currency': 'NEM',
#    'pair': 'XEM/USDT',
#    'percent_volume': 0.00951434528287,
#    'price': 0.401932,
#    'updated': True,
#    'volume_24h': 261966.0},
#   {'currency': 'Bankex',
#    'pair': 'BKX/ETH',
#    'percent_volume': 0.00935098238432,
#    'price': 0.564121,
#    'updated': True,
#    'volume_24h': 257468.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/ETH',
#    'percent_volume': 0.00917636059325,
#    'price': 0.420521,
#    'updated': True,
#    'volume_24h': 252660.0},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/USDT',
#    'percent_volume': 0.00899342174932,
#    'price': 0.15125,
#    'updated': True,
#    'volume_24h': 247623.0},
#   {'currency': '0x',
#    'pair': 'ZRX/BTC',
#    'percent_volume': 0.0088548284143,
#    'price': 1.17701,
#    'updated': True,
#    'volume_24h': 243807.0},
#   {'currency': 'district0x',
#    'pair': 'DNT/USDT',
#    'percent_volume': 0.00852548764861,
#    'price': 0.0982322,
#    'updated': True,
#    'volume_24h': 234739.0},
#   {'currency': 'Refereum',
#    'pair': 'RFR/USDT',
#    'percent_volume': 0.00844268031008,
#    'price': 0.0144047,
#    'updated': True,
#    'volume_24h': 232459.0},
#   {'currency': 'Dent',
#    'pair': 'DENT/USDT',
#    'percent_volume': 0.00819847129944,
#    'price': 0.0116038,
#    'updated': True,
#    'volume_24h': 225735.0},
#   {'currency': 'ugChain',
#    'pair': 'UGC/USDT',
#    'percent_volume': 0.00787697543951,
#    'price': 0.0508167,
#    'updated': True,
#    'volume_24h': 216883.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/ETH',
#    'percent_volume': 0.00776039142342,
#    'price': 2.07805,
#    'updated': True,
#    'volume_24h': 213673.0},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/USDT',
#    'percent_volume': 0.00762513943716,
#    'price': 0.328708,
#    'updated': True,
#    'volume_24h': 209949.0},
#   {'currency': 'Monero',
#    'pair': 'XMR/BTC',
#    'percent_volume': 0.00758718607366,
#    'price': 256.353,
#    'updated': True,
#    'volume_24h': 208904.0},
#   {'currency': 'Storj',
#    'pair': 'STORJ/USDT',
#    'percent_volume': 0.00757164153819,
#    'price': 1.18819,
#    'updated': True,
#    'volume_24h': 208476.0},
#   {'currency': 'SALT',
#    'pair': 'SALT/USDT',
#    'percent_volume': 0.00752860351356,
#    'price': 4.08134,
#    'updated': True,
#    'volume_24h': 207291.0},
#   {'currency': 'Nano',
#    'pair': 'NANO/USDT',
#    'percent_volume': 0.0073299385391,
#    'price': 7.52247,
#    'updated': True,
#    'volume_24h': 201821.0},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/BTC',
#    'percent_volume': 0.00726677978397,
#    'price': 41.7547,
#    'updated': True,
#    'volume_24h': 200082.0},
#   {'currency': 'Nano',
#    'pair': 'NANO/BTC',
#    'percent_volume': 0.00720104237926,
#    'price': 7.3855,
#    'updated': True,
#    'volume_24h': 198272.0},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/BTC',
#    'percent_volume': 0.00716988067029,
#    'price': 0.0803908,
#    'updated': True,
#    'volume_24h': 197414.0},
#   {'currency': '0x',
#    'pair': 'ZRX/USDT',
#    'percent_volume': 0.00700495605439,
#    'price': 1.17779,
#    'updated': True,
#    'volume_24h': 192873.0},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/USDT',
#    'percent_volume': 0.00697430281153,
#    'price': 2.38968,
#    'updated': True,
#    'volume_24h': 192029.0},
#   {'currency': 'Storj',
#    'pair': 'STORJ/BTC',
#    'percent_volume': 0.00694241472239,
#    'price': 1.18028,
#    'updated': True,
#    'volume_24h': 191151.0},
#   {'currency': 'SALT',
#    'pair': 'SALT/BTC',
#    'percent_volume': 0.0068213271493,
#    'price': 4.08042,
#    'updated': True,
#    'volume_24h': 187817.0},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/BTC',
#    'percent_volume': 0.00680087954773,
#    'price': 0.0612501,
#    'updated': True,
#    'volume_24h': 187254.0},
#   {'currency': 'Maggie',
#    'pair': 'MAG/BTC',
#    'percent_volume': 0.00672243049017,
#    'price': 0.0176468,
#    'updated': True,
#    'volume_24h': 185094.0},
#   {'currency': 'Waltonchain',
#    'pair': 'WTC/BTC',
#    'percent_volume': 0.00655786906435,
#    'price': 16.3043,
#    'updated': True,
#    'volume_24h': 180563.0},
#   {'currency': 'Status',
#    'pair': 'SNT/ETH',
#    'percent_volume': 0.0065388742231,
#    'price': 0.157254,
#    'updated': True,
#    'volume_24h': 180040.0},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/ETH',
#    'percent_volume': 0.00650992797362,
#    'price': 0.423523,
#    'updated': True,
#    'volume_24h': 179243.0},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/ETH',
#    'percent_volume': 0.00641277462689,
#    'price': 18.2179,
#    'updated': True,
#    'volume_24h': 176568.0},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/BTC',
#    'percent_volume': 0.00632037907021,
#    'price': 0.0853394,
#    'updated': True,
#    'volume_24h': 174024.0},
#   {'currency': 'NEM',
#    'pair': 'XEM/BTC',
#    'percent_volume': 0.00594255242867,
#    'price': 0.403168,
#    'updated': True,
#    'volume_24h': 163621.0},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/BTC',
#    'percent_volume': 0.00575333039633,
#    'price': 13.3051,
#    'updated': True,
#    'volume_24h': 158411.0},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/USDT',
#    'percent_volume': 0.00572126071216,
#    'price': 0.0412135,
#    'updated': True,
#    'volume_24h': 157528.0},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/USDT',
#    'percent_volume': 0.00558190467797,
#    'price': 0.0445146,
#    'updated': True,
#    'volume_24h': 153691.0},
#   {'currency': 'Monero',
#    'pair': 'XMR/USDT',
#    'percent_volume': 0.0055395567145,
#    'price': 255.844,
#    'updated': True,
#    'volume_24h': 152525.0},
#   {'currency': 'TenX',
#    'pair': 'PAY/BTC',
#    'percent_volume': 0.00550766862536,
#    'price': 1.494,
#    'updated': True,
#    'volume_24h': 151647.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/USDT',
#    'percent_volume': 0.00550407304356,
#    'price': 0.0650213,
#    'updated': True,
#    'volume_24h': 151548.0},
#   {'currency': 'Ace',
#    'pair': 'ACE/USDT',
#    'percent_volume': 0.00541080583069,
#    'price': 0.348114,
#    'updated': True,
#    'volume_24h': 148980.0},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/ETH',
#    'percent_volume': 0.00534659382432,
#    'price': 0.132988,
#    'updated': True,
#    'volume_24h': 147212.0},
#   {'currency': 'Monaco',
#    'pair': 'MCO/ETH',
#    'percent_volume': 0.00534212658632,
#    'price': 12.1247,
#    'updated': True,
#    'volume_24h': 147089.0},
#   {'currency': 'IPChain',
#    'pair': 'IPC/ETH',
#    'percent_volume': 0.00532117051863,
#    'price': 0.493456,
#    'updated': True,
#    'volume_24h': 146512.0},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/BTC',
#    'percent_volume': 0.00522408980991,
#    'price': 2.36457,
#    'updated': True,
#    'volume_24h': 143839.0},
#   {'currency': 'OST',
#    'pair': 'OST/BTC',
#    'percent_volume': 0.00510009671617,
#    'price': 0.247148,
#    'updated': True,
#    'volume_24h': 140425.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/ETH',
#    'percent_volume': 0.00485080304439,
#    'price': 0.0041845,
#    'updated': True,
#    'volume_24h': 133561.0},
#   {'currency': 'Cube',
#    'pair': 'AUTO/ETH',
#    'percent_volume': 0.00484659003944,
#    'price': 0.015562,
#    'updated': True,
#    'volume_24h': 133445.0},
#   {'currency': 'Gifto',
#    'pair': 'GTO/ETH',
#    'percent_volume': 0.00483616648411,
#    'price': 0.555,
#    'updated': True,
#    'volume_24h': 133158.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/ETH',
#    'percent_volume': 0.00468751278385,
#    'price': 1.13807,
#    'updated': True,
#    'volume_24h': 129065.0},
#   {'currency': 'Ace',
#    'pair': 'ACE/BTC',
#    'percent_volume': 0.00466702886327,
#    'price': 0.334168,
#    'updated': True,
#    'volume_24h': 128501.0},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/ETH',
#    'percent_volume': 0.00460307108996,
#    'price': 2.64608,
#    'updated': True,
#    'volume_24h': 126740.0},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/ETH',
#    'percent_volume': 0.00459428188999,
#    'price': 0.0632256,
#    'updated': True,
#    'volume_24h': 126498.0},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/ETH',
#    'percent_volume': 0.00456925809339,
#    'price': 0.0403271,
#    'updated': True,
#    'volume_24h': 125809.0},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/BTC',
#    'percent_volume': 0.00452799970016,
#    'price': 0.331647,
#    'updated': True,
#    'volume_24h': 124673.0},
#   {'currency': 'Maggie',
#    'pair': 'MAG/USDT',
#    'percent_volume': 0.00445873935166,
#    'price': 0.0180059,
#    'updated': True,
#    'volume_24h': 122766.0},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/ETH',
#    'percent_volume': 0.00440738427417,
#    'price': 0.0516772,
#    'updated': True,
#    'volume_24h': 121352.0},
#   {'currency': 'Viuly',
#    'pair': 'VIU/BTC',
#    'percent_volume': 0.00439717863289,
#    'price': 0.0111109,
#    'updated': True,
#    'volume_24h': 121071.0},
#   {'currency': 'Request Network',
#    'pair': 'REQ/BTC',
#    'percent_volume': 0.00417574164034,
#    'price': 0.264048,
#    'updated': True,
#    'volume_24h': 114974.0},
#   {'currency': 'Enigma',
#    'pair': 'ENG/BTC',
#    'percent_volume': 0.0041621583313,
#    'price': 2.56858,
#    'updated': True,
#    'volume_24h': 114600.0},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/BTC',
#    'percent_volume': 0.00416114139907,
#    'price': 2.43488,
#    'updated': True,
#    'volume_24h': 114572.0},
#   {'currency': 'TenX',
#    'pair': 'PAY/USDT',
#    'percent_volume': 0.00388940258027,
#    'price': 1.50029,
#    'updated': True,
#    'volume_24h': 107090.0},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/BTC',
#    'percent_volume': 0.00382468210779,
#    'price': 1.22052,
#    'updated': True,
#    'volume_24h': 105308.0},
#   {'currency': 'Enjin Coin',
#    'pair': 'ENJ/BTC',
#    'percent_volume': 0.00376076065349,
#    'price': 0.152472,
#    'updated': True,
#    'volume_24h': 103548.0},
#   {'currency': 'Refereum',
#    'pair': 'RFR/ETH',
#    'percent_volume': 0.00374194740728,
#    'price': 0.0137295,
#    'updated': True,
#    'volume_24h': 103030.0},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/USDT',
#    'percent_volume': 0.00356222279556,
#    'price': 0.300198,
#    'updated': True,
#    'volume_24h': 98081.5},
#   {'currency': 'Primas',
#    'pair': 'PST/ETH',
#    'percent_volume': 0.00340545906079,
#    'price': 0.246147,
#    'updated': True,
#    'volume_24h': 93765.2},
#   {'currency': 'Dash',
#    'pair': 'DASH/ETH',
#    'percent_volume': 0.00336955045745,
#    'price': 495.045,
#    'updated': True,
#    'volume_24h': 92776.5},
#   {'currency': 'AirSwap',
#    'pair': 'AST/BTC',
#    'percent_volume': 0.0033250887277,
#    'price': 0.560775,
#    'updated': True,
#    'volume_24h': 91552.3},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/USDT',
#    'percent_volume': 0.00325716855061,
#    'price': 0.160053,
#    'updated': True,
#    'volume_24h': 89682.2},
#   {'currency': 'Substratum',
#    'pair': 'SUB/USDT',
#    'percent_volume': 0.00322609763915,
#    'price': 0.827471,
#    'updated': True,
#    'volume_24h': 88826.7},
#   {'currency': 'IPChain',
#    'pair': 'IPC/BTC',
#    'percent_volume': 0.00321144655127,
#    'price': 0.507181,
#    'updated': True,
#    'volume_24h': 88423.3},
#   {'currency': 'Po.et',
#    'pair': 'POE/ETH',
#    'percent_volume': 0.0031945908996,
#    'price': 0.0660494,
#    'updated': True,
#    'volume_24h': 87959.2},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/BTC',
#    'percent_volume': 0.00319417323101,
#    'price': 0.058169,
#    'updated': True,
#    'volume_24h': 87947.7},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/USDT',
#    'percent_volume': 0.0031646168222,
#    'price': 0.349015,
#    'updated': True,
#    'volume_24h': 87133.9},
#   {'currency': 'Substratum',
#    'pair': 'SUB/BTC',
#    'percent_volume': 0.0029796114267,
#    'price': 0.764226,
#    'updated': True,
#    'volume_24h': 82040.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/BTC',
#    'percent_volume': 0.00293546204042,
#    'price': 0.00149391,
#    'updated': True,
#    'volume_24h': 80824.4},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/BTC',
#    'percent_volume': 0.00287808163948,
#    'price': 0.439488,
#    'updated': True,
#    'volume_24h': 79244.5},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/ETH',
#    'percent_volume': 0.00286506127507,
#    'price': 1.43442,
#    'updated': True,
#    'volume_24h': 78886.0},
#   {'currency': 'Metal',
#    'pair': 'MTL/BTC',
#    'percent_volume': 0.00285972238087,
#    'price': 5.01411,
#    'updated': True,
#    'volume_24h': 78739.0},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/ETH',
#    'percent_volume': 0.00280258168539,
#    'price': 0.102554,
#    'updated': True,
#    'volume_24h': 77165.7},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/USDT',
#    'percent_volume': 0.00279001894048,
#    'price': 1.2178,
#    'updated': True,
#    'volume_24h': 76819.8},
#   {'currency': 'SALT',
#    'pair': 'SALT/ETH',
#    'percent_volume': 0.00277328677343,
#    'price': 4.11375,
#    'updated': True,
#    'volume_24h': 76359.1},
#   {'currency': 'Monetha',
#    'pair': 'MTH/BTC',
#    'percent_volume': 0.00277085703179,
#    'price': 0.126609,
#    'updated': True,
#    'volume_24h': 76292.2},
#   {'currency': 'Datum',
#    'pair': 'DAT/BTC',
#    'percent_volume': 0.00268386574353,
#    'price': 0.047805,
#    'updated': True,
#    'volume_24h': 73897.0},
#   {'currency': 'district0x',
#    'pair': 'DNT/BTC',
#    'percent_volume': 0.00265181058695,
#    'price': 0.0978508,
#    'updated': True,
#    'volume_24h': 73014.4},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/BTC',
#    'percent_volume': 0.00263599365891,
#    'price': 0.0401487,
#    'updated': True,
#    'volume_24h': 72578.9},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/BTC',
#    'percent_volume': 0.00258058174822,
#    'price': 7.27215,
#    'updated': True,
#    'volume_24h': 71053.2},
#   {'currency': 'Viuly',
#    'pair': 'VIU/USDT',
#    'percent_volume': 0.00257241360329,
#    'price': 0.0111036,
#    'updated': True,
#    'volume_24h': 70828.3},
#   {'currency': 'RefToken',
#    'pair': 'REF/USDT',
#    'percent_volume': 0.00255006651759,
#    'price': 5.76579,
#    'updated': True,
#    'volume_24h': 70213.0},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/BTC',
#    'percent_volume': 0.00242459887211,
#    'price': 0.486546,
#    'updated': True,
#    'volume_24h': 66758.4},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/USDT',
#    'percent_volume': 0.00235691840047,
#    'price': 0.0571187,
#    'updated': True,
#    'volume_24h': 64894.9},
#   {'currency': 'OST',
#    'pair': 'OST/USDT',
#    'percent_volume': 0.00230885382512,
#    'price': 0.255684,
#    'updated': True,
#    'volume_24h': 63571.5},
#   {'currency': 'Gas',
#    'pair': 'GAS/BTC',
#    'percent_volume': 0.00226332794843,
#    'price': 27.4189,
#    'updated': True,
#    'volume_24h': 62318.0},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/USDT',
#    'percent_volume': 0.0022394990472,
#    'price': 0.255384,
#    'updated': True,
#    'volume_24h': 61661.9},
#   {'currency': 'FunFair',
#    'pair': 'FUN/USDT',
#    'percent_volume': 0.00217628944545,
#    'price': 0.0490161,
#    'updated': True,
#    'volume_24h': 59921.5},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/BTC',
#    'percent_volume': 0.00216829563177,
#    'price': 0.25191,
#    'updated': True,
#    'volume_24h': 59701.4},
#   {'currency': 'Civic',
# ...
#    'price': 0.0979321,
#    'updated': True,
#    'volume_24h': 25070.9},
#   {'currency': 'ChatCoin',
#    'pair': 'CHAT/ETH',
#    'percent_volume': 0.000883249222431,
#    'price': 0.131278,
#    'updated': True,
#    'volume_24h': 24319.2},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/ETH',
#    'percent_volume': 0.00088293324706,
#    'price': 292.107,
#    'updated': True,
#    'volume_24h': 24310.5},
#   {'currency': 'SONM',
#    'pair': 'SNM/USDT',
#    'percent_volume': 0.00087216466115,
#    'price': 0.238778,
#    'updated': True,
#    'volume_24h': 24014.0},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/USDT',
#    'percent_volume': 0.000864196270768,
#    'price': 44.0144,
#    'updated': True,
#    'volume_24h': 23794.6},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/BTC',
#    'percent_volume': 0.000838358928386,
#    'price': 1.539,
#    'updated': True,
#    'volume_24h': 23083.2},
#   {'currency': 'Ark',
#    'pair': 'ARK/BTC',
#    'percent_volume': 0.000807418765363,
#    'price': 3.84158,
#    'updated': True,
#    'volume_24h': 22231.3},
#   {'currency': 'Ark',
#    'pair': 'ARK/USDT',
#    'percent_volume': 0.000805250520578,
#    'price': 3.80175,
#    'updated': True,
#    'volume_24h': 22171.6},
#   {'currency': 'NEM',
#    'pair': 'XEM/ETH',
#    'percent_volume': 0.000778094798202,
#    'price': 0.403551,
#    'updated': True,
#    'volume_24h': 21423.9},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/ETH',
#    'percent_volume': 0.000772970186155,
#    'price': 0.335033,
#    'updated': True,
#    'volume_24h': 21282.8},
#   {'currency': 'Populous',
#    'pair': 'PPT/USDT',
#    'percent_volume': 0.000766614359733,
#    'price': 25.6284,
#    'updated': True,
#    'volume_24h': 21107.8},
#   {'currency': 'Waltonchain',
#    'pair': 'WTC/ETH',
#    'percent_volume': 0.000764184618089,
#    'price': 17.2634,
#    'updated': True,
#    'volume_24h': 21040.9},
#   {'currency': 'SONM',
#    'pair': 'SNM/BTC',
#    'percent_volume': 0.00069656952066,
#    'price': 0.242666,
#    'updated': True,
#    'volume_24h': 19179.2},
#   {'currency': 'UTRUST',
#    'pair': 'UTK/USDT',
#    'percent_volume': 0.000689520001183,
#    'price': 0.198565,
#    'updated': True,
#    'volume_24h': 18985.1},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/BTC',
#    'percent_volume': 0.000685978897891,
#    'price': 0.362739,
#    'updated': True,
#    'volume_24h': 18887.6},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/USDT',
#    'percent_volume': 0.000669715246052,
#    'price': 2.42079,
#    'updated': True,
#    'volume_24h': 18439.8},
#   {'currency': 'Read',
#    'pair': 'READ/BTC',
#    'percent_volume': 0.000666744351187,
#    'price': 0.0238091,
#    'updated': True,
#    'volume_24h': 18358.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/ETH',
#    'percent_volume': 0.000647818516052,
#    'price': 0.0650375,
#    'updated': True,
#    'volume_24h': 17836.9},
#   {'currency': 'NAGA',
#    'pair': 'NGC/USDT',
#    'percent_volume': 0.000643489290283,
#    'price': 0.720236,
#    'updated': True,
#    'volume_24h': 17717.7},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/USDT',
#    'percent_volume': 0.000618036929388,
#    'price': 2.28495,
#    'updated': True,
#    'volume_24h': 17016.9},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/USDT',
#    'percent_volume': 0.000611688366768,
#    'price': 0.48906,
#    'updated': True,
#    'volume_24h': 16842.1},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/ETH',
#    'percent_volume': 0.000607613374056,
#    'price': 0.0452226,
#    'updated': True,
#    'volume_24h': 16729.9},
#   {'currency': 'Leverj',
#    'pair': 'LEV/USDT',
#    'percent_volume': 0.00059855904533,
#    'price': 0.0601197,
#    'updated': True,
#    'volume_24h': 16480.6},
#   {'currency': 'OAX',
#    'pair': 'OAX/USDT',
#    'percent_volume': 0.000598261229463,
#    'price': 0.781957,
#    'updated': True,
#    'volume_24h': 16472.4},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/BTC',
#    'percent_volume': 0.000587924839751,
#    'price': 0.257232,
#    'updated': True,
#    'volume_24h': 16187.8},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/BTC',
#    'percent_volume': 0.000559479792586,
#    'price': 0.0133518,
#    'updated': True,
#    'volume_24h': 15404.6},
#   {'currency': 'Populous',
#    'pair': 'PPT/ETH',
#    'percent_volume': 0.000530802303769,
#    'price': 25.2473,
#    'updated': True,
#    'volume_24h': 14615.0},
#   {'currency': 'SingularDTV',
#    'pair': 'SNGLS/ETH',
#    'percent_volume': 0.000516870332252,
#    'price': 0.0984724,
#    'updated': True,
#    'volume_24h': 14231.4},
#   {'currency': 'Maggie',
#    'pair': 'MAG/ETH',
#    'percent_volume': 0.000494298068701,
#    'price': 0.0160953,
#    'updated': True,
#    'volume_24h': 13609.9},
#   {'currency': 'Revain',
#    'pair': 'R/USDT',
#    'percent_volume': 0.000475873435879,
#    'price': 0.950312,
#    'updated': True,
#    'volume_24h': 13102.6},
#   {'currency': 'RefToken',
#    'pair': 'REF/BTC',
#    'percent_volume': 0.000475873435879,
#    'price': 5.88225,
#    'updated': True,
#    'volume_24h': 13102.6},
#   {'currency': 'Monero',
#    'pair': 'XMR/ETH',
#    'percent_volume': 0.000457982692476,
#    'price': 255.705,
#    'updated': True,
#    'volume_24h': 12610.0},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/BTC',
#    'percent_volume': 0.000438911581308,
#    'price': 0.289258,
#    'updated': True,
#    'volume_24h': 12084.9},
#   {'currency': 'Viuly',
#    'pair': 'VIU/ETH',
#    'percent_volume': 0.000431952859351,
#    'price': 0.010345,
#    'updated': True,
#    'volume_24h': 11893.3},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/ETH',
#    'percent_volume': 0.00042828100763,
#    'price': 1.51946,
#    'updated': True,
#    'volume_24h': 11792.2},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/USDT',
#    'percent_volume': 0.00041701848321,
#    'price': 0.24368,
#    'updated': True,
#    'volume_24h': 11482.1},
#   {'currency': 'NAGA',
#    'pair': 'NGC/ETH',
#    'percent_volume': 0.000409271638776,
#    'price': 0.707118,
#    'updated': True,
#    'volume_24h': 11268.8},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/ETH',
#    'percent_volume': 0.000365078669688,
#    'price': 7.22081,
#    'updated': True,
#    'volume_24h': 10052.0},
#   {'currency': 'Metal',
#    'pair': 'MTL/USDT',
#    'percent_volume': 0.000360943750613,
#    'price': 4.8803,
#    'updated': True,
#    'volume_24h': 9938.15},
#   {'currency': 'Aventus',
#    'pair': 'AVT/USDT',
#    'percent_volume': 0.000340755103565,
#    'price': 1.61143,
#    'updated': True,
#    'volume_24h': 9382.28},
#   {'currency': 'SunContract',
#    'pair': 'SNC/USDT',
#    'percent_volume': 0.000324367240719,
#    'price': 0.227075,
#    'updated': True,
#    'volume_24h': 8931.06},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/USDT',
#    'percent_volume': 0.000322331923503,
#    'price': 0.257184,
#    'updated': True,
#    'volume_24h': 8875.02},
#   {'currency': 'Aventus',
#    'pair': 'AVT/BTC',
#    'percent_volume': 0.000314225520889,
#    'price': 1.63415,
#    'updated': True,
#    'volume_24h': 8651.82},
#   {'currency': 'Everex',
#    'pair': 'EVX/USDT',
#    'percent_volume': 0.00031212846136,
#    'price': 1.60053,
#    'updated': True,
#    'volume_24h': 8594.08},
#   {'currency': 'TenX',
#    'pair': 'PAY/ETH',
#    'percent_volume': 0.00030788204293,
#    'price': 1.4843,
#    'updated': True,
#    'volume_24h': 8477.16},
#   {'currency': 'AirSwap',
#    'pair': 'AST/ETH',
#    'percent_volume': 0.000305042986065,
#    'price': 0.604284,
#    'updated': True,
#    'volume_24h': 8398.99},
#   {'currency': 'Monetha',
#    'pair': 'MTH/ETH',
#    'percent_volume': 0.000285175399049,
#    'price': 0.122458,
#    'updated': True,
#    'volume_24h': 7851.96},
#   {'currency': 'Leverj',
#    'pair': 'LEV/ETH',
#    'percent_volume': 0.000274267711339,
#    'price': 0.0546925,
#    'updated': True,
#    'volume_24h': 7551.63},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/USDT',
#    'percent_volume': 0.00026158329775,
#    'price': 1.5365,
#    'updated': True,
#    'volume_24h': 7202.38},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/BTC',
#    'percent_volume': 0.000255357856567,
#    'price': 1.80184,
#    'updated': True,
#    'volume_24h': 7030.97},
#   {'currency': 'Bancor',
#    'pair': 'BNT/ETH',
#    'percent_volume': 0.000249078663252,
#    'price': 4.76342,
#    'updated': True,
#    'volume_24h': 6858.08},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/USDT',
#    'percent_volume': 0.000211641392866,
#    'price': 273.09,
#    'updated': True,
#    'volume_24h': 5827.29},
#   {'currency': 'SunContract',
#    'pair': 'SNC/ETH',
#    'percent_volume': 0.000205015716213,
#    'price': 0.209307,
#    'updated': True,
#    'volume_24h': 5644.86},
#   {'currency': 'Leverj',
#    'pair': 'LEV/BTC',
#    'percent_volume': 0.00020464417276,
#    'price': 0.0560215,
#    'updated': True,
#    'volume_24h': 5634.63},
#   {'currency': 'Enjin Coin',
#    'pair': 'ENJ/ETH',
#    'percent_volume': 0.000193463366108,
#    'price': 0.164091,
#    'updated': True,
#    'volume_24h': 5326.78},
#   {'currency': 'Change',
#    'pair': 'CAG/BTC',
#    'percent_volume': 0.000192963616556,
#    'price': 0.213442,
#    'updated': True,
#    'volume_24h': 5313.02},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/ETH',
#    'percent_volume': 0.000191543906529,
#    'price': 0.155517,
#    'updated': True,
#    'volume_24h': 5273.93},
#   {'currency': 'Request Network',
#    'pair': 'REQ/ETH',
#    'percent_volume': 0.000189998169543,
#    'price': 0.28032,
#    'updated': True,
#    'volume_24h': 5231.37},
#   {'currency': 'DADI',
#    'pair': 'DADI/USDT',
#    'percent_volume': 0.000178216283307,
#    'price': 0.312102,
#    'updated': True,
#    'volume_24h': 4906.97},
#   {'currency': 'Republic Protocol',
#    'pair': 'REN/USDT',
#    'percent_volume': 0.00017653435004,
#    'price': 0.0812266,
#    'updated': True,
#    'volume_24h': 4860.66},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/ETH',
#    'percent_volume': 0.000175825403002,
#    'price': 0.294009,
#    'updated': True,
#    'volume_24h': 4841.14},
#   {'currency': 'Ace',
#    'pair': 'ACE/ETH',
#    'percent_volume': 0.000173285251573,
#    'price': 0.358116,
#    'updated': True,
#    'volume_24h': 4771.2},
#   {'currency': 'Everex',
#    'pair': 'EVX/BTC',
#    'percent_volume': 0.00016549555071,
#    'price': 1.69586,
#    'updated': True,
#    'volume_24h': 4556.72},
#   {'currency': 'Ark',
#    'pair': 'ARK/ETH',
#    'percent_volume': 0.000153936299994,
#    'price': 3.7523,
#    'updated': True,
#    'volume_24h': 4238.45},
#   {'currency': 'Change',
#    'pair': 'CAG/USDT',
#    'percent_volume': 0.000152365502892,
#    'price': 0.219172,
#    'updated': True,
#    'volume_24h': 4195.2},
#   {'currency': 'Datum',
#    'pair': 'DAT/ETH',
#    'percent_volume': 0.000143674364248,
#    'price': 0.0471371,
#    'updated': True,
#    'volume_24h': 3955.9},
#   {'currency': 'Enigma',
#    'pair': 'ENG/ETH',
#    'percent_volume': 0.000142322207575,
#    'price': 3.28196,
#    'updated': True,
#    'volume_24h': 3918.67},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/ETH',
#    'percent_volume': 0.000133452742601,
#    'price': 0.239494,
#    'updated': True,
#    'volume_24h': 3674.46},
#   {'currency': 'DADI',
#    'pair': 'DADI/ETH',
#    'percent_volume': 0.000131518392228,
#    'price': 0.314521,
#    'updated': True,
#    'volume_24h': 3621.2},
#   {'currency': 'FunFair',
#    'pair': 'FUN/ETH',
#    'percent_volume': 0.000125903110381,
#    'price': 0.0473491,
#    'updated': True,
#    'volume_24h': 3466.59},
#   {'currency': 'Civic',
#    'pair': 'CVC/ETH',
#    'percent_volume': 0.000123895032422,
#    'price': 0.409123,
#    'updated': True,
#    'volume_24h': 3411.3},
#   {'currency': 'district0x',
#    'pair': 'DNT/ETH',
#    'percent_volume': 0.000122562488014,
#    'price': 0.097563,
#    'updated': True,
#    'volume_24h': 3374.61},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/ETH',
#    'percent_volume': 0.000117949973982,
#    'price': 42.119,
#    'updated': True,
#    'volume_24h': 3247.61},
#   {'currency': 'LATOKEN',
#    'pair': 'LA/BTC',
#    'percent_volume': 0.000116548786648,
#    'price': 0.227634,
#    'updated': True,
#    'volume_24h': 3209.03},
#   {'currency': 'Substratum',
#    'pair': 'SUB/ETH',
#    'percent_volume': 0.000108853878397,
#    'price': 0.785441,
#    'updated': True,
#    'volume_24h': 2997.16},
#   {'currency': 'LATOKEN',
#    'pair': 'LA/USDT',
#    'percent_volume': 0.000106839626206,
#    'price': 0.228275,
#    'updated': True,
#    'volume_24h': 2941.7},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/ETH',
#    'percent_volume': 0.000106676917049,
#    'price': 0.341782,
#    'updated': True,
#    'volume_24h': 2937.22},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/ETH',
#    'percent_volume': 9.67781713845e-05,
#    'price': 0.0144406,
#    'updated': True,
#    'volume_24h': 2664.67},
#   {'currency': 'LATOKEN',
#    'pair': 'LA/ETH',
#    'percent_volume': 9.40357230809e-05,
#    'price': 0.23118,
#    'updated': True,
#    'volume_24h': 2589.16},
#   {'currency': 'Metal',
#    'pair': 'MTL/ETH',
#    'percent_volume': 9.35831882396e-05,
#    'price': 5.11581,
#    'updated': True,
#    'volume_24h': 2576.7},
#   {'currency': 'Aventus',
#    'pair': 'AVT/ETH',
#    'percent_volume': 9.32635809681e-05,
#    'price': 1.63266,
#    'updated': True,
#    'volume_24h': 2567.9},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/BTC',
#    'percent_volume': 9.1220636761e-05,
#    'price': 0.242853,
#    'updated': True,
#    'volume_24h': 2511.65},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/ETH',
#    'percent_volume': 8.63411780192e-05,
#    'price': 12.9979,
#    'updated': True,
#    'volume_24h': 2377.3},
#   {'currency': 'OAX',
#    'pair': 'OAX/ETH',
#    'percent_volume': 7.43141384781e-05,
#    'price': 0.885787,
#    'updated': True,
#    'volume_24h': 2046.15},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/ETH',
#    'percent_volume': 5.14698455566e-05,
#    'price': 1.18745,
#    'updated': True,
#    'volume_24h': 1417.16},
#   {'currency': 'BT2 [CST]',
#    'pair': 'BT2/BTC',
#    'percent_volume': 4.2139855559e-05,
#    'price': 44.8301,
#    'updated': True,
#    'volume_24h': 1160.27},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/ETH',
#    'percent_volume': 1.99535904267e-05,
#    'price': 0.491672,
#    'updated': True,
#    'volume_24h': 549.398},
#   {'currency': 'SONM',
#    'pair': 'SNM/ETH',
#    'percent_volume': 1.86158160814e-05,
#    'price': 0.238154,
#    'updated': True,
#    'volume_24h': 512.564},
#   {'currency': 'UTRUST',
#    'pair': 'UTK/ETH',
#    'percent_volume': 1.58586948984e-05,
#    'price': 0.189314,
#    'updated': True,
#    'volume_24h': 436.65},
#   {'currency': 'Nano',
#    'pair': 'NANO/ETH',
#    'percent_volume': 1.41198860654e-05,
#    'price': 7.35068,
#    'updated': True,
#    'volume_24h': 388.774},
#   {'currency': 'Gas',
#    'pair': 'GAS/ETH',
#    'percent_volume': 7.65670065522e-06,
#    'price': 27.2295,
#    'updated': True,
#    'volume_24h': 210.818},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/ETH',
#    'percent_volume': 7.13189098779e-06,
#    'price': 2.01321,
#    'updated': True,
#    'volume_24h': 196.368},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/ETH',
#    'percent_volume': 5.70858537832e-06,
#    'price': 0.327232,
#    'updated': True,
#    'volume_24h': 157.179},
#   {'currency': 'Everex',
#    'pair': 'EVX/ETH',
#    'percent_volume': 3.12324584004e-06,
#    'price': 1.88693,
#    'updated': True,
#    'volume_24h': 85.9948},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/ETH',
#    'percent_volume': 1.96861009318e-06,
#    'price': 273.652,
#    'updated': True,
#    'volume_24h': 54.2033},
#   {'currency': 'Maker',
#    'pair': 'MKR/USDT',
#    'percent_volume': 1.51970352084e-06,
#    'price': 1046.08,
#    'updated': True,
#    'volume_24h': 41.8432},
#   {'currency': 'Bread',
#    'pair': 'BRD/ETH',
#    'percent_volume': 1.44997465714e-06,
#    'price': 0.694414,
#    'updated': True,
#    'volume_24h': 39.9233},
#   {'currency': 'Maker',
#    'pair': 'MKR/BTC',
#    'percent_volume': 1.12843158249e-06,
#    'price': 1047.47,
#    'updated': True,
#    'volume_24h': 31.07},
#   {'currency': 'Maker',
#    'pair': 'MKR/ETH',
#    'percent_volume': 3.52669190991e-07,
#    'price': 1041.43,
#    'updated': True,
#    'volume_24h': 9.71032},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/ETH',
#    'percent_volume': 1.15714539032e-07,
#    'price': 0.235029,
#    'updated': True,
#    'volume_24h': 3.18606},
#   {'currency': 'Change',
#    'pair': 'CAG/ETH',
#    'percent_volume': 0.0,
#    'price': 0.178094,
#    'updated': True,
#    'volume_24h': None}],
#  'name': 'OKEx',
#  'slug': 'okex',
#  'social': {'twitter': {'link': 'https://twitter.com/CoinMarketCap',
#    'username': '@OKEx_'}},
#  'volume': 2753379157.59,
#  'web': 'https://www.okex.com'}

# %%
show_page("exchanges/okex")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/exchanges/okex"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# In order to obtain all available values for the `name` parameter, use:

# %%
cmc.exchange_slugs
# Out:
# ['abucoins',
#  'acx',
#  'aidos-market',
#  'allcoin',
#  'altcoin-trader',
#  'b2bx',
#  'bancor-network',
#  'barterdex',
#  'bcex',
#  'bibox',
#  'bigone',
#  'binance',
#  'bisq',
#  'bit-z',
#  'bit2c',
#  'bitbank',
#  'bitbay',
#  'bitbns',
#  'bitcointoyou',
#  'bitcointrade',
#  'bitex-la',
#  'bitfinex',
#  'bitflip',
#  'bitflyer',
#  'bithesap',
#  'bithumb',
#  'bitinka',
#  'bitkonan',
#  'bitlish',
#  'bitmarket',
#  'bitmaszyna',
#  'bitmex',
#  'bitonic',
#  'bits-blockchain',
#  'bitsane',
#  'bitshares-asset-exchange',
#  'bitso',
#  'bitstamp',
#  'bitstamp-ripple-gateway',
#  'bittrex',
#  'bittylicious',
#  'bl3p',
#  'bleutrade',
#  'braziliex',
#  'btc-alpha',
#  'btc-markets',
#  'btc-trade-ua',
#  'btcbox',
#  'btcc',
#  'btctrade-im',
#  'btcturk',
#  'buybitcoin',
#  'buyucoin',
#  'bx-thailand',
#  'c-cex',
#  'c-patex',
#  'c2cx',
#  'cex-io',
#  'cfinex',
#  'chaoex',
#  'cobinhood',
#  'coinbe',
#  'coinbene',
#  'coincorner',
#  'coinegg',
#  'coinex',
#  'coinexchange',
#  'coinexmarket',
#  'coinfalcon',
#  'coinfloor',
#  'coingi',
#  'coinhouse',
#  'coinhub',
#  'coinlink',
#  'coinmate',
#  'coinnest',
#  'coinone',
#  'coinrail',
#  'coinrate',
#  'coinroom',
#  'coinsbank',
#  'coinsquare',
#  'cointiger',
#  'coinut',
#  'coss',
#  'counterparty-dex',
#  'crex24',
#  'crxzone',
#  'cryptobridge',
#  'cryptohub',
#  'cryptomarket',
#  'cryptomate',
#  'cryptonex',
#  'cryptopia',
#  'cryptox',
#  'dc-ex',
#  'ddex',
#  'dgtmarket',
#  'dragonex',
#  'dsx',
#  'ethfinex',
#  'excambriorex',
#  'exmo',
#  'exrates',
#  'exx',
#  'ezbtc',
#  'fargobase',
#  'fatbtc',
#  'fexpro',
#  'fisco',
#  'forkdelta',
#  'foxbit',
#  'freiexchange',
#  'gate-io',
#  'gatecoin',
#  'gatehub',
#  'gdax',
#  'gemini',
#  'gopax',
#  'guldentrader',
#  'heat-wallet',
#  'hitbtc',
#  'hotbit',
#  'huobi',
#  'idax',
#  'idex',
#  'independent-reserve',
#  'indodax',
#  'infinitycoin-exchange',
#  'iquant',
#  'isx',
#  'itbit',
#  'koineks',
#  'koinex',
#  'koinim',
#  'korbit',
#  'kraken',
#  'kucoin',
#  'kuna',
#  'lakebtc',
#  'latoken',
#  'lbank',
#  'leoxchange',
#  'liqui',
#  'litebit',
#  'livecoin',
#  'localtrade',
#  'luno',
#  'lykke-exchange',
#  'mbaex',
#  'mercado-bitcoin',
#  'mercatox',
#  'mr-exchange',
#  'nanex',
#  'negocie-coins',
#  'neraexpro',
#  'nocks',
#  'novaexchange',
#  'oasisdex',
#  'octaex',
#  'oex',
#  'okcoin-cn',
#  'okcoin-intl',
#  'okex',
#  'omicrex',
#  'ooobtc',
#  'openledger',
#  'ore-bz',
#  'orionx',
#  'otcbtc',
#  'ovis',
#  'paradex',
#  'paribu',
#  'paymium',
#  'poloniex',
#  'qryptos',
#  'quadrigacx',
#  'quoine',
#  'radar-relay',
#  'rfinex',
#  'rightbtc',
#  'ripple-china',
#  'ripplefox',
#  'rudex',
#  'simex',
#  'sistemkoin',
#  'southxchange',
#  'stellar-decentralized-exchange',
#  'stellarport',
#  'stocks-exchange',
#  'stronghold',
#  'surbtc',
#  'switcheo',
#  'tcc-exchange',
#  'tdax',
#  'therocktrading',
#  'tidebit',
#  'tidex',
#  'token-store',
#  'topbtc',
#  'trade-by-trade',
#  'trade-satoshi',
#  'tradeogre',
#  'triple-dice-exchange',
#  'tux-exchange',
#  'unocoin',
#  'upbit',
#  'vebitcoin',
#  'waves-dex',
#  'wex',
#  'xbtce',
#  'yobit',
#  'zaif',
#  'zb-com',
#  'zebpay']

# %% [markdown]
# If you want to get all formatted exchange names:

# %%
cmc.exchange_names
# Out:
# ['ACX',
#  'Abucoins',
#  'AidosMarket',
#  'Allcoin',
#  'Altcoin Trader',
#  'B2BX',
#  'BCEX',
#  'BL3P',
#  'BTC Markets',
#  'BTC Trade UA',
#  'BTC-Alpha',
#  'BTCBOX',
#  'BTCC',
#  'BTCTurk',
#  'BX Thailand',
#  'Bancor Network',
#  'BarterDEX',
#  'Bibox',
#  'BigONE',
#  'Binance',
#  'Bisq',
#  'Bit-Z',
#  'Bit2C',
#  'BitBay',
#  'BitFlip',
#  'BitKonan',
#  'BitMEX',
#  'BitMarket',
#  'BitShares Asset Exchange',
#  'Bitbank',
#  'Bitbns',
#  'BitcoinToYou',
#  'BitcoinTrade',
#  'Bitex.la',
#  'Bitfinex',
#  'Bithesap',
#  'Bithumb',
#  'Bitinka',
#  'Bitlish',
#  'Bitmaszyna',
#  'Bitonic',
#  'Bits Blockchain',
#  'Bitsane',
#  'Bitso',
#  'Bitstamp',
#  'Bitstamp (Ripple Gateway)',
#  'Bittrex',
#  'Bittylicious',
#  'Bleutrade',
#  'Braziliex',
#  'BtcTrade.im',
#  'Buda',
#  'BuyBitcoin',
#  'BuyUcoin',
#  'C-CEX',
#  'C-Patex',
#  'C2CX',
#  'CEX.IO',
#  'COSS',
#  'CRXzone',
#  'ChaoEX',
#  'Cobinhood',
#  'CoinBene',
#  'CoinCorner',
#  'CoinEgg',
#  'CoinEx',
#  'CoinEx Market',
#  'CoinExchange',
#  'CoinFalcon',
#  'CoinMate',
#  'CoinTiger',
#  'Coinbe',
#  'Coinfloor',
#  'Coingi',
#  'Coinhouse',
#  'Coinhub',
#  'Coinlink',
#  'Coinnest',
#  'Coinone',
#  'Coinrail',
#  'Coinrate',
#  'Coinroom',
#  'CoinsBank',
#  'Coinsquare',
#  'Coinut',
#  'Counterparty DEX',
#  'Crex24',
#  'CryptoBridge',
#  'CryptoMarket',
#  'Cryptohub',
#  'Cryptomate',
#  'Cryptonex',
#  'Cryptopia',
#  'Cryptox',
#  'DC-Ex',
#  'DDEX',
#  'DSX',
#  'Dgtmarket',
#  'DragonEX',
#  'EXX',
#  'EtherDelta (ForkDelta)',
#  'Ethfinex',
#  'ExcambrioRex',
#  'Exmo',
#  'Exrates',
#  'Fargobase',
#  'Fatbtc',
#  'Fisco',
#  'Foxbit',
#  'FreiExchange',
#  'GDAX',
#  'GOPAX',
#  'Gate.io',
#  'Gatecoin',
#  'Gatehub',
#  'Gemini',
#  'GuldenTrader',
#  'Heat Wallet',
#  'HitBTC',
#  'Hotbit',
#  'Huobi',
#  'IDAX',
#  'IDEX',
#  'ISX',
#  'Independent Reserve',
#  'Indodax',
#  'InfinityCoin Exchange',
#  'Iquant',
#  'Koineks',
#  'Koinex',
#  'Koinim',
#  'Korbit',
#  'Kraken',
#  'Kucoin',
#  'Kuna',
#  'LATOKEN',
#  'LEOxChange',
#  'LakeBTC',
#  'Lbank',
#  'Liqui',
#  'LiteBit.eu',
#  'Livecoin',
#  'LocalTrade',
#  'Luno',
#  'Lykke Exchange',
#  'MBAex',
#  'Mercado Bitcoin',
#  'Mercatox',
#  'Mr. Exchange',
#  'Nanex',
#  'Negocie Coins',
#  'Neraex',
#  'Nocks',
#  'Novaexchange',
#  'OEX',
#  'OKCoin.cn',
#  'OKEx',
#  'OOOBTC',
#  'OTCBTC',
#  'OasisDEX',
#  'Octaex',
#  'OkCoin Intl.',
#  'Omicrex',
#  'OpenLedger DEX',
#  'Ore.Bz',
#  'Orionx',
#  'Ovis',
#  'Paradex',
#  'Paribu',
#  'Paymium',
#  'Poloniex',
#  'Qryptos',
#  'QuadrigaCX',
#  'Quoine',
#  'Radar Relay',
#  'Rfinex',
#  'RightBTC',
#  'Ripple China',
#  'RippleFox',
#  'RuDEX',
#  'Simex',
#  'Sistemkoin',
#  'SouthXchange',
#  'Stellar Decentralized Exchange',
#  'Stellarport',
#  'Stocks.Exchange',
#  'Stronghold',
#  'Switcheo Network',
#  'TCC Exchange',
#  'TDAX',
#  'TOPBTC',
#  'The Rock Trading',
#  'Tidebit',
#  'Tidex',
#  'Token Store',
#  'Trade By Trade',
#  'Trade Satoshi',
#  'TradeOgre',
#  'Tripe Dice Exchange',
#  'Tux Exchange',
#  'Unocoin',
#  'Upbit',
#  'Vebitcoin',
#  'WEX',
#  'Waves Decentralized Exchange',
#  'YoBit',
#  'ZB.COM',
#  'Zaif',
#  'Zebpay',
#  'bitFlyer',
#  'cfinex',
#  'ezBtc',
#  'fex',
#  'itBit',
#  'xBTCe']

# %% [markdown]
# #### `exchanges([convert="USD"])`
# Get all available exchanges in coinmarketcap ranked by volumes with some metadata:

# %%
cmc.exchanges()
# Out:
# [{'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': '24 Hour Volume Rankings (Exchange)'},
#  {'markets': [{'name': 'EOS',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Ethereum',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Mithril',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'Mithril',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'All'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'TRON',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Ethereum',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Cardano',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'EOS',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'ICON',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Ripple',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Binance Coin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'Markets with Fees'},
#  {'markets': [{'name': 'EOS',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Ripple',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Huobi Token',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'EOS',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'IOStoken',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'Markets with No Fees'},
#  {'markets': [{'name': 'EOS',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Cardano',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'TRON',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Ripple',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Steem',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Storm',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'Siacoin',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Gifto',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'BitMEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Ripple',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'IOTA',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'OKEx'},
#  {'markets': [{'name': 'EOS',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'TRON',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Mithril',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'ICON',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'aelf',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Kyber Network',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Qtum',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'VeChain',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Qtum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'Mithril',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Mithril',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'Binance'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Monero',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Dash',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Ripple',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'EOS',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'EOS',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Zcash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Cardano',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'ZClassic',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'TRON',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'SIRIN LABS Token',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Verge',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Waves',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'ReddCoin',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Ripple',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Steem',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'Huobi'},
#  {'markets': [{'name': 'TRON',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Litecoin',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'EDUCare',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'Hshare',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'TRON',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'GXChain',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'EOS',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'EOS',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'Ripple',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Ripple',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'Upbit'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Qtum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'EOS',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Stellar',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'Ripple',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'WaykiChain',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Zcash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'Bitfinex'},
#  {'markets': [{'name': 'EOS',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Aeternity',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Monero Classic',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Cardano',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Bytom',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'TRON',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Game.com',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Ontology',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Ethereum',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ripple',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Ripple',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'Bithumb'},
#  {'markets': [{'name': 'Bytom',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Bibox Token',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bytom',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Ethereum',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Bibox Token',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'Bibox Token',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Bodhi',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Fusion',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'}],
#   'name': 'Lbank'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Ethereum',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Ripple',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'QASH',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'QASH',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEM',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'MonaCoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'COMSA [ETH]',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'COMSA [XEM]',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Pepe Cash',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'NEM',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'MonaCoin',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Counterparty',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'HitBTC'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Ethereum',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Bytom',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'Qtum',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Qtum',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'MonaCoin',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'MonaCoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'}],
#   'name': 'Bittrex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'MOAC',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'EOS',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Credits',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Arcblock',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'MonaCoin',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Ethereum',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'MonaCoin',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'}],
#   'name': 'Bit-Z'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Stellar',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ripple',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Ethereum',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Primecoin',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'Ripple',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Monero',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'EOS',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'Metaverse ETP',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Hshare',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'Decentraland',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'Kraken'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'},
#    {'name': 'IOTA',
#     'pair': 'BCH/USDT',
#     'percent_volume': 4.88,
#     'price': 1400.36,
#     'volume': 134282000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Qtum',
#     'pair': 'ETH/USDT',
#     'percent_volume': 4.77,
#     'price': 685.255,
#     'volume': 131254000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETC/USDT',
#     'percent_volume': 3.01,
#     'price': 21.8892,
#     'volume': 82944800.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_usdt'},
#    {'name': 'OmiseGO',
#     'pair': 'MITH/USDT',
#     'percent_volume': 2.96,
#     'price': 1.26421,
#     'volume': 81627100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'MITH/BTC',
#     'percent_volume': 2.73,
#     'price': 1.26515,
#     'volume': 75229900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#mith_btc'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'percent_volume': 2.59,
#     'price': 683.461,
#     'volume': 71436700.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum Classic',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'EOS/BTC',
#     'percent_volume': 5.0,
#     'price': 18.9424,
#     'volume': 137549000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_btc'}],
#   'name': 'GDAX'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'TRON',
#     'pair': 'EOS/USDT',
#     'percent_volume': 23.65,
#     'price': 18.9762,
#     'volume': 651305000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eos_usdt'},
#    {'name': 'NEO',
#     'pair': 'BTC/USDT',
#     'percent_volume': 14.05,
#     'price': 9344.8,
#     'volume': 386927000.0,
# ...
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Coinrate'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'TDAX'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BTC Trade UA'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BitFlip'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Gatecoin'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Bleutrade'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'CoinFalcon'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Braziliex'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Stellarport'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'SouthXchange'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Crex24'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'CoinCorner'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Bitlish'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Bitex.la'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Bitsane'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'CRXzone'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Buda'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Coinut'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Token Store'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Abucoins'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Bit2C'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Bitmaszyna'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'CryptoMarket'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Cryptohub'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Coinbe'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Nocks'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Mr. Exchange'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Cryptomate'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Paymium'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'cfinex'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Coinlink'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BitKonan'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'OKCoin.cn'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Bisq'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ezBtc'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Tripe Dice Exchange'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Tux Exchange'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Stronghold'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Dgtmarket'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Paradex'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'RuDEX'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Cryptox'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Counterparty DEX'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'GuldenTrader'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Heat Wallet'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Coingi'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'LocalTrade'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Ore.Bz'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'FreiExchange'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Coinhouse'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ISX'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'LEOxChange'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BarterDEX'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ExcambrioRex'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Novaexchange'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Orionx'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'C-Patex'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'View More'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'percent_volume': 100.0,
#     'price': 9344.0,
#     'volume': 3357250000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'TCC Exchange'}]

# %%
show_page("exchanges/volume/24-hour")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/exchanges/volume/24-hour"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# > If you want to connect with exchanges see [`ccxt` library](https://github.com/ccxt/ccxt).

# %% [markdown]
# #### `tokens([convert="USD"])`
# Get platforms tokens data:

# %%
cmc.tokens()
# Out:
# [{'circulating_supply': 822649000.203,
#   'market_cap': 15635266897.9,
#   'name': 'EOS',
#   'platform': 'Ethereum',
#   'price': 19.006,
#   'symbol': 'EOS',
#   'volume_24h': 3160350000.0},
#  {'circulating_supply': 65748111645.1,
#   'market_cap': 5443450533.38,
#   'name': 'TRON',
#   'platform': 'Ethereum',
#   'price': 0.0827925,
#   'symbol': 'TRX',
#   'volume_24h': 794753000.0},
#  {'circulating_supply': 2417140813.52,
#   'market_cap': 2410515430.55,
#   'name': 'Tether',
#   'platform': 'Omni',
#   'price': 0.997259,
#   'symbol': 'USDT',
#   'volume_24h': 4357290000.0},
#  {'circulating_supply': 525779137.697,
#   'market_cap': 2131356148.27,
#   'name': 'VeChain',
#   'platform': 'Ethereum',
#   'price': 4.05371,
#   'symbol': 'VEN',
#   'volume_24h': 80914600.0},
#  {'circulating_supply': 102042551.763,
#   'market_cap': 1849031446.46,
#   'name': 'OmiseGO',
#   'platform': 'Ethereum',
#   'price': 18.1202,
#   'symbol': 'OMG',
#   'volume_24h': 85339600.0},
#  {'circulating_supply': 387231348.457,
#   'market_cap': 1830884027.89,
#   'name': 'ICON',
#   'platform': 'Ethereum',
#   'price': 4.72814,
#   'symbol': 'ICX',
#   'volume_24h': 140979000.0},
#  {'circulating_supply': 114041290.11,
#   'market_cap': 1728694896.12,
#   'name': 'Binance Coin',
#   'platform': 'Ethereum',
#   'price': 15.1585,
#   'symbol': 'BNB',
#   'volume_24h': 113984000.0},
#  {'circulating_supply': 233020472.114,
#   'market_cap': 1008932040.16,
#   'name': 'Aeternity',
#   'platform': 'Ethereum',
#   'price': 4.3298,
#   'symbol': 'AE',
#   'volume_24h': 93830600.0},
#  {'circulating_supply': 987000000.0,
#   'market_cap': 972746733.0,
#   'name': 'Bytom',
#   'platform': 'Ethereum',
#   'price': 0.985559,
#   'symbol': 'BTM',
#   'volume_24h': 130127000.0},
#  {'circulating_supply': 37004026.8944,
#   'market_cap': 895667669.368,
#   'name': 'Populous',
#   'platform': 'Ethereum',
#   'price': 24.2046,
#   'symbol': 'PPT',
#   'volume_24h': 5139670.0},
#  {'circulating_supply': 112619657.893,
#   'market_cap': 763813548.548,
#   'name': 'Ontology',
#   'platform': 'NEO',
#   'price': 6.78224,
#   'symbol': 'ONT',
#   'volume_24h': 138487000.0},
#  {'circulating_supply': 7284013186.24,
#   'market_cap': 753909932.802,
#   'name': 'Zilliqa',
#   'platform': 'Ethereum',
#   'price': 0.103502,
#   'symbol': 'ZIL',
#   'volume_24h': 39902600.0},
#  {'circulating_supply': 618227.770106,
#   'market_cap': 650864014.09,
#   'name': 'Maker',
#   'platform': 'Ethereum',
#   'price': 1052.79,
#   'symbol': 'MKR',
#   'volume_24h': 127314.0},
#  {'circulating_supply': 525137801.873,
#   'market_cap': 611412691.342,
#   'name': '0x',
#   'platform': 'Ethereum',
#   'price': 1.16429,
#   'symbol': 'ZRX',
#   'volume_24h': 10887800.0},
#  {'circulating_supply': 415970.661165,
#   'market_cap': 590582665.603,
#   'name': 'Mixin',
#   'platform': 'Ethereum',
#   'price': 1419.77,
#   'symbol': 'XIN',
#   'volume_24h': 945811.0},
#  {'circulating_supply': 2000000.0,
#   'market_cap': 547464000.0,
#   'name': 'DigixDAO',
#   'platform': 'Ethereum',
#   'price': 273.732,
#   'symbol': 'DGD',
#   'volume_24h': 5654360.0},
#  {'circulating_supply': 3470483788.0,
#   'market_cap': 546455436.291,
#   'name': 'Status',
#   'platform': 'Ethereum',
#   'price': 0.157458,
#   'symbol': 'SNT',
#   'volume_24h': 64568900.0},
#  {'circulating_supply': 359816353.988,
#   'market_cap': 534773457.952,
#   'name': 'RChain',
#   'platform': 'Ethereum',
#   'price': 1.48624,
#   'symbol': 'RHOC',
#   'volume_24h': 969425.0},
#  {'circulating_supply': 133073438.978,
#   'market_cap': 512033324.829,
#   'name': 'Aion',
#   'platform': 'Ethereum',
#   'price': 3.84775,
#   'symbol': 'AION',
#   'volume_24h': 6997870.0},
#  {'circulating_supply': 31144099.4107,
#   'market_cap': 508125325.115,
#   'name': 'Waltonchain',
#   'platform': 'Ethereum',
#   'price': 16.3153,
#   'symbol': 'WTC',
#   'volume_24h': 12998200.0},
#  {'circulating_supply': 834262000.0,
#   'market_cap': 505381737.146,
#   'name': 'Golem',
#   'platform': 'Ethereum',
#   'price': 0.605783,
#   'symbol': 'GNT',
#   'volume_24h': 29010400.0},
#  {'circulating_supply': 572074043.309,
#   'market_cap': 483007835.506,
#   'name': 'Loopring',
#   'platform': 'Ethereum',
#   'price': 0.84431,
#   'symbol': 'LRC',
#   'volume_24h': 27156000.0},
#  {'circulating_supply': 11000000.0,
#   'market_cap': 455431900.0,
#   'name': 'Augur',
#   'platform': 'Ethereum',
#   'price': 41.4029,
#   'symbol': 'REP',
#   'volume_24h': 5067780.0},
#  {'circulating_supply': 8400000000.0,
#   'market_cap': 453883080.0,
#   'name': 'IOStoken',
#   'platform': 'Ethereum',
#   'price': 0.0540337,
#   'symbol': 'IOST',
#   'volume_24h': 74480700.0},
#  {'circulating_supply': 1000000000.0,
#   'market_cap': 442386000.0,
#   'name': 'Basic Attenti...',
#   'platform': 'Ethereum',
#   'price': 0.442386,
#   'symbol': 'BAT',
#   'volume_24h': 7748190.0},
#  {'circulating_supply': 305054520.126,
#   'market_cap': 366587067.381,
#   'name': 'Mithril',
#   'platform': 'Ethereum',
#   'price': 1.20171,
#   'symbol': 'MITH',
#   'volume_24h': 282841000.0},
#  {'circulating_supply': 134132696.93,
#   'market_cap': 358961899.543,
#   'name': 'Kyber Network',
#   'platform': 'Ethereum',
#   'price': 2.67617,
#   'symbol': 'KNC',
#   'volume_24h': 35534000.0},
#  {'circulating_supply': 250000000.0,
#   'market_cap': 349027500.0,
#   'name': 'aelf',
#   'platform': 'Ethereum',
#   'price': 1.39611,
#   'symbol': 'ELF',
#   'volume_24h': 96638300.0},
#  {'circulating_supply': 75730576.0001,
#   'market_cap': 333310712.232,
#   'name': 'KuCoin Shares',
#   'platform': 'Ethereum',
#   'price': 4.40127,
#   'symbol': 'KCS',
#   'volume_24h': 799896.0},
#  {'circulating_supply': 686528275.473,
#   'market_cap': 327040788.059,
#   'name': 'Centrality',
#   'platform': 'Ethereum',
#   'price': 0.476369,
#   'symbol': 'CENNZ',
#   'volume_24h': 238673.0},
#  {'circulating_supply': 383020999.96,
#   'market_cap': 296185159.996,
#   'name': 'Substratum',
#   'platform': 'Ethereum',
#   'price': 0.773287,
#   'symbol': 'SUB',
#   'volume_24h': 10318500.0},
#  {'circulating_supply': 35500000.0,
#   'market_cap': 295833215.0,
#   'name': 'Nebulas',
#   'platform': 'Ethereum',
#   'price': 8.33333,
#   'symbol': 'NAS',
#   'volume_24h': 44248100.0},
#  {'circulating_supply': 238421940.0,
#   'market_cap': 280548712.579,
#   'name': 'Dragonchain',
#   'platform': 'Ethereum',
#   'price': 1.17669,
#   'symbol': 'DRGN',
#   'volume_24h': 3986490.0},
#  {'circulating_supply': 4091706233.6,
#   'market_cap': 278514259.909,
#   'name': 'Storm',
#   'platform': 'Ethereum',
#   'price': 0.068068,
#   'symbol': 'STORM',
#   'volume_24h': 84473000.0},
#  {'circulating_supply': 10128375.1058,
#   'market_cap': 276590731.576,
#   'name': 'Gas',
#   'platform': 'NEO',
#   'price': 27.3085,
#   'symbol': 'GAS',
#   'volume_24h': 2646590.0},
#  {'circulating_supply': 325226613094.0,
#   'market_cap': 272405257.955,
#   'name': 'Dentacoin',
#   'platform': 'Ethereum',
#   'price': 0.000837586,
#   'symbol': 'DCN',
#   'volume_24h': 563508.0},
#  {'circulating_supply': 56864567421.7,
#   'market_cap': 270237483.758,
#   'name': 'Pundi X',
#   'platform': 'Ethereum',
#   'price': 0.0047523,
#   'symbol': 'NPXS',
#   'volume_24h': 3285010.0},
#  {'circulating_supply': 76404704.0385,
#   'market_cap': 266165719.129,
#   'name': 'Ethos',
#   'platform': 'Ethereum',
#   'price': 3.48363,
#   'symbol': 'ETHOS',
#   'volume_24h': 9600890.0},
#  {'circulating_supply': 350000000.0,
#   'market_cap': 262826200.0,
#   'name': 'QASH',
#   'platform': 'Ethereum',
#   'price': 0.750932,
#   'symbol': 'QASH',
#   'volume_24h': 3523410.0},
#  {'circulating_supply': 149792458.0,
#   'market_cap': 260459125.97,
#   'name': 'Cortex',
#   'platform': 'Ethereum',
#   'price': 1.7388,
#   'symbol': 'CTXC',
#   'volume_24h': 45822100.0},
#  {'circulating_supply': 51865401.2471,
#   'market_cap': 247376180.48,
#   'name': 'Bancor',
#   'platform': 'Ethereum',
#   'price': 4.76958,
#   'symbol': 'BNT',
#   'volume_24h': 11141700.0},
#  {'circulating_supply': 429699460.993,
#   'market_cap': 243326343.476,
#   'name': 'Gifto',
#   'platform': 'Ethereum',
#   'price': 0.566271,
#   'symbol': 'GTO',
#   'volume_24h': 80158000.0},
#  {'circulating_supply': 57953450.5019,
#   'market_cap': 239468293.75,
#   'name': 'SALT',
#   'platform': 'Ethereum',
#   'price': 4.13208,
#   'symbol': 'SALT',
#   'volume_24h': 11464200.0},
#  {'circulating_supply': 4723473188.66,
#   'market_cap': 221965924.429,
#   'name': 'FunFair',
#   'platform': 'Ethereum',
#   'price': 0.0469921,
#   'symbol': 'FUN',
#   'volume_24h': 3495600.0},
#  {'circulating_supply': 621779038.012,
#   'market_cap': 220114753.689,
#   'name': 'WAX',
#   'platform': 'Ethereum',
#   'price': 0.354008,
#   'symbol': 'WAX',
#   'volume_24h': 4311640.0},
#  {'circulating_supply': 2036645.44,
#   'market_cap': 219185818.898,
#   'name': 'Veritaseum',
#   'platform': 'Ethereum',
#   'price': 107.621,
#   'symbol': 'VERI',
#   'volume_24h': 1035430.0},
#  {'circulating_supply': 366344075.92,
#   'market_cap': 202746168.28,
#   'name': 'Power Ledger',
#   'platform': 'Ethereum',
#   'price': 0.553431,
#   'symbol': 'POWR',
#   'volume_24h': 9778370.0},
#  {'circulating_supply': 756097560976.0,
#   'market_cap': 196718439.024,
#   'name': 'Kin',
#   'platform': 'Ethereum',
#   'price': 0.000260176,
#   'symbol': 'KIN',
#   'volume_24h': 904520.0},
#  {'circulating_supply': 74836171.09,
#   'market_cap': 190929523.302,
#   'name': 'Enigma',
#   'platform': 'Ethereum',
#   'price': 2.5513,
#   'symbol': 'ENG',
#   'volume_24h': 13721700.0},
#  {'circulating_supply': 15793831.095,
#   'market_cap': 189480171.029,
#   'name': 'Monaco',
#   'platform': 'Ethereum',
#   'price': 11.9971,
#   'symbol': 'MCO',
#   'volume_24h': 28387000.0},
#  {'circulating_supply': 551500132.777,
#   'market_cap': 186587936.922,
#   'name': 'Loom Network',
#   'platform': 'Ethereum',
#   'price': 0.338328,
#   'symbol': 'LOOM',
#   'volume_24h': 2592180.0},
#  {'circulating_supply': 186450000.0,
#   'market_cap': 177371935.95,
#   'name': 'Revain',
#   'platform': 'Ethereum',
#   'price': 0.951311,
#   'symbol': 'R',
#   'volume_24h': 4229830.0},
#  {'circulating_supply': 29684331.2,
#   'market_cap': 176972936.278,
#   'name': 'Fusion',
#   'platform': 'Ethereum',
#   'price': 5.96183,
#   'symbol': 'FSN',
#   'volume_24h': 5978710.0},
#  {'circulating_supply': 4112034633.5,
#   'market_cap': 176863544.028,
#   'name': 'Nucleus Vision',
#   'platform': 'Ethereum',
#   'price': 0.0430112,
#   'symbol': 'NCASH',
#   'volume_24h': 16151800.0},
#  {'circulating_supply': 662961247.025,
#   'market_cap': 174574933.334,
#   'name': 'Request Network',
#   'platform': 'Ethereum',
#   'price': 0.263326,
#   'symbol': 'REQ',
#   'volume_24h': 5164100.0},
#  {'circulating_supply': 452552412.0,
#   'market_cap': 172441476.173,
#   'name': 'MaidSafeCoin',
#   'platform': 'Omni',
#   'price': 0.381042,
#   'symbol': 'MAID',
#   'volume_24h': 1519270.0},
#  {'circulating_supply': 350000000.0,
#   'market_cap': 167661550.0,
#   'name': 'ChainLink',
#   'platform': 'Ethereum',
#   'price': 0.479033,
#   'symbol': 'LINK',
#   'volume_24h': 10870900.0},
#  {'circulating_supply': 109004760.534,
#   'market_cap': 162934865.808,
#   'name': 'TenX',
#   'platform': 'Ethereum',
#   'price': 1.49475,
#   'symbol': 'PAY',
#   'volume_24h': 2481240.0},
#  {'circulating_supply': 1500000000.0,
#   'market_cap': 161577000.0,
#   'name': 'DeepBrain Chain',
#   'platform': 'NEO',
#   'price': 0.107718,
#   'symbol': 'DBC',
#   'volume_24h': 2784740.0},
#  {'circulating_supply': 135787538.7,
#   'market_cap': 158990913.313,
#   'name': 'Storj',
#   'platform': 'Ethereum',
#   'price': 1.17088,
#   'symbol': 'STORJ',
#   'volume_24h': 12032600.0},
#  {'circulating_supply': 1050141509.43,
#   'market_cap': 158046297.169,
#   'name': 'Decentraland',
#   'platform': 'Ethereum',
#   'price': 0.1505,
#   'symbol': 'MANA',
#   'volume_24h': 14837900.0},
#  {'circulating_supply': 1445976590.33,
#   'market_cap': 154745522.744,
#   'name': 'Cindicator',
#   'platform': 'Ethereum',
#   'price': 0.107018,
#   'symbol': 'CND',
#   'volume_24h': 3657470.0},
#  {'circulating_supply': 1413716693.85,
#   'market_cap': 152720987.003,
#   'name': 'SmartMesh',
#   'platform': 'Ethereum',
#   'price': 0.108028,
#   'symbol': 'SMT',
#   'volume_24h': 3536050.0},
#  {'circulating_supply': 99735686.8829,
#   'market_cap': 151822649.358,
#   'name': 'Iconomi',
#   'platform': 'Ethereum',
#   'price': 1.52225,
#   'symbol': 'ICN',
#   'volume_24h': 1403810.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 143619750.0,
#   'name': 'Matrix AI Net...',
#   'platform': 'Ethereum',
#   'price': 0.957465,
#   'symbol': 'MAN',
#   'volume_24h': 1100460.0},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 142279600.0,
#   'name': 'Nuls',
#   'platform': 'Ethereum',
#   'price': 3.55699,
#   'symbol': 'NULS',
#   'volume_24h': 20899800.0},
#  {'circulating_supply': 342699966.0,
#   'market_cap': 139946328.916,
#   'name': 'Civic',
#   'platform': 'Ethereum',
#   'price': 0.408364,
#   'symbol': 'CVC',
#   'volume_24h': 4869280.0},
#  {'circulating_supply': 2256920162.0,
#   'market_cap': 132949073.059,
#   'name': 'Po.et',
#   'platform': 'Ethereum',
#   'price': 0.0589073,
#   'symbol': 'POE',
#   'volume_24h': 8398520.0},
#  {'circulating_supply': 633879773.727,
#   'market_cap': 131120566.715,
#   'name': 'CyberMiles',
#   'platform': 'Ethereum',
#   'price': 0.206854,
#   'symbol': 'CMT',
#   'volume_24h': 59409500.0},
#  {'circulating_supply': 68428768.29,
#   'market_cap': 126331139.154,
#   'name': 'Paypex',
#   'platform': 'Ethereum',
#   'price': 1.84617,
#   'symbol': 'PAYX',
#   'volume_24h': 61639.6},
#  {'circulating_supply': 80070793.2388,
#   'market_cap': 125072180.455,
#   'name': 'iExec RLC',
#   'platform': 'Ethereum',
#   'price': 1.56202,
#   'symbol': 'RLC',
#   'volume_24h': 2469230.0},
#  {'circulating_supply': 598168165.41,
#   'market_cap': 124176720.298,
#   'name': 'Game.com',
#   'platform': 'Ethereum',
#   'price': 0.207595,
#   'symbol': 'GTC',
#   'volume_24h': 24335800.0},
#  {'circulating_supply': 239999750.0,
#   'market_cap': 124106510.722,
#   'name': 'Polymath',
#   'platform': 'Ethereum',
#   'price': 0.517111,
#   'symbol': 'POLY',
#   'volume_24h': 2196390.0},
#  {'circulating_supply': 62660370.957,
#   'market_cap': 123125749.119,
#   'name': 'Santiment Net...',
#   'platform': 'Ethereum',
#   'price': 1.96497,
#   'symbol': 'SAN',
#   'volume_24h': 2090410.0},
#  {'circulating_supply': 24212368.2058,
#   'market_cap': 122610221.976,
#   'name': 'Metal',
#   'platform': 'Ethereum',
#   'price': 5.06395,
#   'symbol': 'MTL',
#   'volume_24h': 16124600.0},
#  {'circulating_supply': 1104590.0,
#   'market_cap': 121781047.5,
#   'name': 'Gnosis',
#   'platform': 'Ethereum',
#   'price': 110.25,
#   'symbol': 'GNO',
#   'volume_24h': 636261.0},
#  {'circulating_supply': 10614760961.2,
#   'market_cap': 120358651.587,
#   'name': 'Dent',
#   'platform': 'Ethereum',
#   'price': 0.0113388,
#   'symbol': 'DENT',
#   'volume_24h': 3255090.0},
#  {'circulating_supply': 617314170.819,
#   'market_cap': 119853398.207,
#   'name': 'Quantstamp',
#   'platform': 'Ethereum',
#   'price': 0.194153,
#   'symbol': 'QSP',
#   'volume_24h': 3880060.0},
#  {'circulating_supply': 103244552.962,
#   'market_cap': 119836985.069,
#   'name': 'DEW',
#   'platform': 'Ethereum',
#   'price': 1.16071,
#   'symbol': 'DEW',
#   'volume_24h': 704626.0},
#  {'circulating_supply': 1202053264.0,
#   'market_cap': 119835214.2,
#   'name': 'Dynamic Tradi...',
#   'platform': 'Ethereum',
#   'price': 0.0996921,
#   'symbol': 'DTR',
#   'volume_24h': 74278.2},
#  {'circulating_supply': 2361679677.22,
#   'market_cap': 119289149.0,
#   'name': 'Time New Bank',
#   'platform': 'Ethereum',
#   'price': 0.0505103,
#   'symbol': 'TNB',
#   'volume_24h': 6150060.0},
#  {'circulating_supply': 756192535.064,
#   'market_cap': 117535005.725,
#   'name': 'Enjin Coin',
#   'platform': 'Ethereum',
#   'price': 0.15543,
#   'symbol': 'ENJ',
#   'volume_24h': 12324200.0},
#  {'circulating_supply': 50168936.0,
#   'market_cap': 115763314.752,
#   'name': 'Raiden Networ...',
#   'platform': 'Ethereum',
#   'price': 2.30747,
#   'symbol': 'RDN',
#   'volume_24h': 6257380.0},
#  {'circulating_supply': 26369501.7345,
#   'market_cap': 114922771.374,
#   'name': 'Aragon',
#   'platform': 'Ethereum',
#   'price': 4.35817,
#   'symbol': 'ANT',
#   'volume_24h': 520076.0},
#  {'circulating_supply': 93080732.3672,
#   'market_cap': 109998155.475,
#   'name': 'Arcblock',
#   'platform': 'Ethereum',
#   'price': 1.18175,
#   'symbol': 'ABT',
#   'volume_24h': 47000900.0},
#  {'circulating_supply': 2966384100.0,
#   'market_cap': 108244245.724,
#   'name': 'MediBloc',
#   'platform': 'Qtum',
#   'price': 0.0364903,
#   'symbol': 'MED',
#   'volume_24h': 2118840.0},
#  {'circulating_supply': 18726326623.0,
#   'market_cap': 107591360.559,
#   'name': 'Dropil',
#   'platform': 'Ethereum',
#   'price': 0.00574546,
#   'symbol': 'DROP',
#   'volume_24h': 110979.0},
#  {'circulating_supply': 539673260.161,
#   'market_cap': 107377709.228,
#   'name': 'SingularityNET',
#   'platform': 'Ethereum',
#   'price': 0.198968,
#   'symbol': 'AGI',
#   'volume_24h': 354412.0},
#  {'circulating_supply': 82500000.0,
#   'market_cap': 107176575.0,
#   'name': 'PayPie',
#   'platform': 'Ethereum',
#   'price': 1.29911,
#   'symbol': 'PPP',
#   'volume_24h': 76359.6},
#  {'circulating_supply': 191925166.65,
#   'market_cap': 106573358.088,
#   'name': 'SophiaTX',
#   'platform': 'Ethereum',
#   'price': 0.555286,
#   'symbol': 'SPHTX',
#   'volume_24h': 963188.0},
#  {'circulating_supply': 407036833.0,
#   'market_cap': 106440538.866,
#   'name': 'Apex',
#   'platform': 'NEO',
#   'price': 0.261501,
#   'symbol': 'CPX',
#   'volume_24h': 1783350.0},
#  {'circulating_supply': 29702631.937,
#   'market_cap': 102112896.178,
#   'name': 'High Performa...',
#   'platform': 'Ethereum',
#   'price': 3.43784,
#   'symbol': 'HPB',
#   'volume_24h': 7834120.0},
#  {'circulating_supply': 240188887.798,
#   'market_cap': 100654035.698,
#   'name': 'Genaro Network',
#   'platform': 'Ethereum',
#   'price': 0.419062,
#   'symbol': 'GNX',
#   'volume_24h': 4494470.0},
#  {'circulating_supply': 144590975.0,
#   'market_cap': 99582840.893,
#   'name': 'Ambrosus',
#   'platform': 'Ethereum',
#   'price': 0.688721,
#   'symbol': 'AMB',
#   'volume_24h': 2171620.0},
#  {'circulating_supply': 6274940000.0,
#   'market_cap': 98328937.294,
#   'name': 'Cube',
#   'platform': 'Ethereum',
#   'price': 0.0156701,
#   'symbol': 'AUTO',
#   'volume_24h': 4407860.0},
#  {'circulating_supply': 229258029.0,
#   'market_cap': 97865667.4195,
#   'name': 'SIRIN LABS Token',
#   'platform': 'Ethereum',
#   'price': 0.42688,
#   'symbol': 'SRN',
#   'volume_24h': 32797500.0},
#  {'circulating_supply': 921800000.0,
#   'market_cap': 96388017.0,
#   'name': 'Ruff',
#   'platform': 'Ethereum',
#   'price': 0.104565,
#   'symbol': 'RUFF',
#   'volume_24h': 9034310.0},
#  {'circulating_supply': 165000000.0,
#   'market_cap': 95976705.0,
#   'name': 'Bluzelle',
#   'platform': 'Ethereum',
#   'price': 0.581677,
#   'symbol': 'BLZ',
#   'volume_24h': 7881120.0},
#  {'circulating_supply': 4626502186.4,
#   'market_cap': 94799805.7007,
#   'name': 'DATA',
#   'platform': 'Ethereum',
#   'price': 0.0204906,
#   'symbol': 'DTA',
#   'volume_24h': 5790150.0},
#  {'circulating_supply': 4504993287.0,
#   'market_cap': 91920333.5273,
#   'name': 'THEKEY',
#   'platform': 'NEO',
#   'price': 0.0204041,
#   'symbol': 'TKY',
#   'volume_24h': 1854310.0},
#  {'circulating_supply': 55000000.0,
#   'market_cap': 91537600.0,
#   'name': 'TomoChain',
#   'platform': 'Ethereum',
#   'price': 1.66432,
#   'symbol': 'TOMO',
#   'volume_24h': 1497110.0},
#  {'circulating_supply': 805454814.5,
#   'market_cap': 91186345.0044,
#   'name': 'Red Pulse',
#   'platform': 'NEO',
#   'price': 0.113211,
#   'symbol': 'RPX',
#   'volume_24h': 1758410.0},
#  {'circulating_supply': 137508658.018,
#   'market_cap': 90927050.0796,
#   'name': 'Credits',
#   'platform': 'Ethereum',
#   'price': 0.661246,
#   'symbol': 'CS',
#   'volume_24h': 4465090.0},
#  {'circulating_supply': 227384800.0,
#   'market_cap': 89487970.1944,
#   'name': 'Pillar',
#   'platform': 'Ethereum',
#   'price': 0.393553,
#   'symbol': 'PLR',
#   'volume_24h': 69966.8},
#  {'circulating_supply': 1531433921.3,
#   'market_cap': 87500314.8144,
#   'name': 'BLOCKv',
#   'platform': 'Ethereum',
#   'price': 0.0571362,
#   'symbol': 'VEE',
#   'volume_24h': 516521.0},
#  {'circulating_supply': 359600000.0,
#   'market_cap': 87370573.6,
#   'name': 'SONM',
#   'platform': 'Ethereum',
#   'price': 0.242966,
#   'symbol': 'SNM',
#   'volume_24h': 2143560.0},
#  {'circulating_supply': 613211464.0,
#   'market_cap': 87202349.4496,
#   'name': 'Theta Token',
#   'platform': 'Ethereum',
#   'price': 0.142206,
#   'symbol': 'THETA',
#   'volume_24h': 8515710.0},
#  {'circulating_supply': 1086339145.85,
#   'market_cap': 87098870.5272,
#   'name': 'ETHLend',
#   'platform': 'Ethereum',
#   'price': 0.0801765,
#   'symbol': 'LEND',
#   'volume_24h': 3402770.0},
#  {'circulating_supply': 761143950.0,
#   'market_cap': 84554720.2615,
#   'name': 'Ignis',
#   'platform': 'Ardor',
#   'price': 0.111089,
#   'symbol': 'IGNIS',
#   'volume_24h': 1576830.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 81752400.0,
#   'name': 'AirSwap',
#   'platform': 'Ethereum',
#   'price': 0.545016,
#   'symbol': 'AST',
#   'volume_24h': 4908890.0},
#  {'circulating_supply': 3726780.89997,
#   'market_cap': 81607184.757,
#   'name': 'Genesis Vision',
#   'platform': 'Ethereum',
#   'price': 21.8975,
#   'symbol': 'GVT',
#   'volume_24h': 10053700.0},
#  {'circulating_supply': 463910526.92,
#   'market_cap': 80015751.5937,
#   'name': 'Ink',
#   'platform': 'Qtum',
#   'price': 0.172481,
#   'symbol': 'INK',
#   'volume_24h': 3823530.0},
#  {'circulating_supply': 73430701.0,
#   'market_cap': 77336479.9862,
#   'name': 'AdEx',
#   'platform': 'Ethereum',
#   'price': 1.05319,
#   'symbol': 'ADX',
#   'volume_24h': 6141070.0},
#  {'circulating_supply': 305788520.321,
#   'market_cap': 77018037.2477,
#   'name': 'OST',
#   'platform': 'Ethereum',
#   'price': 0.251867,
#   'symbol': 'OST',
#   'volume_24h': 3321460.0},
#  {'circulating_supply': 104342466.049,
#   'market_cap': 76118455.0373,
#   'name': 'Bibox Token',
#   'platform': 'Ethereum',
#   'price': 0.729506,
#   'symbol': 'BIX',
#   'volume_24h': 40715700.0},
#  {'circulating_supply': 300056960.0,
#   'market_cap': 75750579.7798,
#   'name': 'Scry.info',
#   'platform': 'Ethereum',
#   'price': 0.252454,
#   'symbol': 'DDD',
#   'volume_24h': 543368.0},
#  {'circulating_supply': 39631641.9307,
#   'market_cap': 73915390.0993,
#   'name': 'CRYPTO20',
#   'platform': 'Ethereum',
#   'price': 1.86506,
#   'symbol': 'C20',
#   'volume_24h': 1790310.0},
#  {'circulating_supply': 491280790.761,
#   'market_cap': 73687205.8063,
#   'name': 'Ripio Credit ...',
#   'platform': 'Ethereum',
#   'price': 0.14999,
#   'symbol': 'RCN',
#   'volume_24h': 10045500.0},
#  {'circulating_supply': 29261461.2776,
#   'market_cap': 70716173.4696,
#   'name': 'Eidoo',
#   'platform': 'Ethereum',
#   'price': 2.4167,
#   'symbol': 'EDO',
#   'volume_24h': 10168600.0},
#  {'circulating_supply': 52000000.0,
#   'market_cap': 70343520.0,
#   'name': 'Quantum Resis...',
#   'platform': 'Ethereum',
#   'price': 1.35276,
#   'symbol': 'QRL',
#   'volume_24h': 592375.0},
#  {'circulating_supply': 48603729.08,
#   'market_cap': 68809757.3704,
#   'name': 'IoT Chain',
#   'platform': 'Ethereum',
#   'price': 1.41573,
#   'symbol': 'ITC',
#   'volume_24h': 8643810.0},
#  {'circulating_supply': 677154514.0,
#   'market_cap': 68449486.8932,
#   'name': 'Streamr DATAcoin',
#   'platform': 'Ethereum',
#   'price': 0.101084,
#   'symbol': 'DATA',
#   'volume_24h': 446985.0},
#  {'circulating_supply': 88862717.693,
#   'market_cap': 68010725.5355,
#   'name': 'Bread',
#   'platform': 'Ethereum',
#   'price': 0.765346,
#   'symbol': 'BRD',
#   'volume_24h': 1293950.0},
#  {'circulating_supply': 474465294.26,
#   'market_cap': 66483974.8929,
#   'name': 'Bottos',
#   'platform': 'Ethereum',
#   'price': 0.140124,
#   'symbol': 'BTO',
#   'volume_24h': 1844840.0},
#  {'circulating_supply': 356577333.428,
#   'market_cap': 65559951.9467,
#   'name': 'IHT Real Esta...',
#   'platform': 'Ethereum',
#   'price': 0.183859,
#   'symbol': 'IHT',
#   'volume_24h': 7764890.0},
#  {'circulating_supply': 407377897.244,
#   'market_cap': 65167020.0884,
#   'name': 'WePower',
#   'platform': 'Ethereum',
#   'price': 0.159967,
#   'symbol': 'WPR',
#   'volume_24h': 6434290.0},
#  {'circulating_supply': 29060868833.7,
#   'market_cap': 65094311.9267,
#   'name': 'Telcoin',
#   'platform': 'Ethereum',
#   'price': 0.00223993,
#   'symbol': 'TEL',
#   'volume_24h': 629828.0},
#  {'circulating_supply': 19361889557.3,
#   'market_cap': 65085378.9847,
#   'name': 'NANJCOIN',
#   'platform': 'Ethereum',
#   'price': 0.00336152,
#   'symbol': 'NANJ',
#   'volume_24h': 9551080.0},
#  {'circulating_supply': 100054311.845,
#   'market_cap': 64653995.7168,
#   'name': 'AppCoins',
#   'platform': 'Ethereum',
#   'price': 0.646189,
#   'symbol': 'APPC',
#   'volume_24h': 10905800.0},
#  {'circulating_supply': 199913906.56,
#   'market_cap': 63549432.2729,
#   'name': 'VIBE',
#   'platform': 'Ethereum',
#   'price': 0.317884,
#   'symbol': 'VIBE',
#   'volume_24h': 2953190.0},
#  {'circulating_supply': 30300918.1344,
#   'market_cap': 63197715.9253,
#   'name': 'INS Ecosystem',
#   'platform': 'Ethereum',
#   'price': 2.08567,
#   'symbol': 'INS',
#   'volume_24h': 7345500.0},
#  {'circulating_supply': 78706576.9896,
#   'market_cap': 61613712.2516,
#   'name': 'Crypterium',
#   'platform': 'Ethereum',
#   'price': 0.782828,
#   'symbol': 'CRPT',
#   'volume_24h': 246518.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 60141000.0,
#   'name': 'SingularDTV',
#   'platform': 'Ethereum',
#   'price': 0.100235,
#   'symbol': 'SNGLS',
#   'volume_24h': 1707900.0},
#  {'circulating_supply': 45248032.811,
#   'market_cap': 59317003.6529,
#   'name': 'WaBi',
#   'platform': 'Ethereum',
#   'price': 1.31093,
#   'symbol': 'WABI',
#   'volume_24h': 1048970.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 59097360.0,
#   'name': 'district0x',
#   'platform': 'Ethereum',
#   'price': 0.0984956,
#   'symbol': 'DNT',
#   'volume_24h': 3355560.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 58329600.0,
#   'name': 'Jibrel Network',
#   'platform': 'Ethereum',
#   'price': 0.388864,
#   'symbol': 'JNT',
#   'volume_24h': 787682.0},
#  {'circulating_supply': 82046297.0,
#   'market_cap': 57457596.1132,
#   'name': 'Edgeless',
#   'platform': 'Ethereum',
#   'price': 0.700307,
#   'symbol': 'EDG',
#   'volume_24h': 1614780.0},
#  {'circulating_supply': 356614878.709,
#   'market_cap': 57222780.0526,
#   'name': 'Electrify.Asia',
#   'platform': 'Ethereum',
#   'price': 0.160461,
#   'symbol': 'ELEC',
#   'volume_24h': 1133550.0},
#  {'circulating_supply': 287227524.588,
#   'market_cap': 56042685.6876,
#   'name': 'UTRUST',
#   'platform': 'Ethereum',
#   'price': 0.195116,
#   'symbol': 'UTK',
#   'volume_24h': 579741.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 56040150.0,
#   'name': 'Internet Node...',
#   'platform': 'Ethereum',
#   'price': 0.373601,
#   'symbol': 'INT',
#   'volume_24h': 11714300.0},
#  {'circulating_supply': 745190105.297,
#   'market_cap': 56028384.89,
#   'name': 'All Sports',
#   'platform': 'Ethereum',
#   'price': 0.0751867,
#   'symbol': 'SOC',
#   'volume_24h': 23339200.0},
#  {'circulating_supply': 18266200.0,
#   'market_cap': 54754030.472,
#   'name': 'Modum',
#   'platform': 'Ethereum',
#   'price': 2.99756,
#   'symbol': 'MOD',
#   'volume_24h': 1104440.0},
#  {'circulating_supply': 428481269.499,
#   'market_cap': 54392269.3128,
#   'name': 'Tierion',
#   'platform': 'Ethereum',
#   'price': 0.126942,
#   'symbol': 'TNT',
#   'volume_24h': 3507080.0},
#  {'circulating_supply': 89708333.0,
#   'market_cap': 54308886.5482,
#   'name': 'Wings',
#   'platform': 'Ethereum',
#   'price': 0.605394,
#   'symbol': 'WINGS',
#   'volume_24h': 2716240.0},
#  {'circulating_supply': 300043386.0,
#   'market_cap': 53837384.8368,
#   'name': 'SpankChain',
#   'platform': 'Ethereum',
#   'price': 0.179432,
#   'symbol': 'SPANK',
#   'volume_24h': 46420.4},
#  {'circulating_supply': 841500002.0,
#   'market_cap': 53594293.6274,
#   'name': 'BitRent',
#   'platform': 'Ethereum',
#   'price': 0.063689,
#   'symbol': 'RNTB',
#   'volume_24h': 349283.0},
#  {'circulating_supply': 506750987.455,
#   'market_cap': 52340789.2413,
#   'name': 'MediShares',
#   'platform': 'Ethereum',
#   'price': 0.103287,
#   'symbol': 'MDS',
#   'volume_24h': 4752230.0},
#  {'circulating_supply': 240000000.0,
#   'market_cap': 51330000.0,
#   'name': 'QLINK',
#   'platform': 'NEO',
#   'price': 0.213875,
#   'symbol': 'QLC',
#   'volume_24h': 9972090.0},
#  {'circulating_supply': 254507605.599,
#   'market_cap': 51234417.0679,
#   'name': 'OriginTrail',
#   'platform': 'Ethereum',
#   'price': 0.201308,
#   'symbol': 'TRAC',
#   'volume_24h': 536669.0},
#  {'circulating_supply': 32105577.5103,
#   'market_cap': 49301324.8248,
#   'name': 'Triggers',
#   'platform': 'Counterparty',
#   'price': 1.5356,
#   'symbol': 'TRIG',
#   'volume_24h': 6085640.0},
#  {'circulating_supply': 107492219.576,
#   'market_cap': 49018386.9868,
#   'name': 'Envion',
#   'platform': 'Ethereum',
#   'price': 0.456018,
#   'symbol': 'EVN',
#   'volume_24h': 165949.0},
#  {'circulating_supply': 11675255731.8,
#   'market_cap': 48742441.3921,
#   'name': 'Banca',
#   'platform': 'Ethereum',
#   'price': 0.00417485,
#   'symbol': 'BANCA',
#   'volume_24h': 10565800.0},
#  {'circulating_supply': 2000000000.0,
#   'market_cap': 48180800.0,
#   'name': 'Odyssey',
#   'platform': 'Ethereum',
#   'price': 0.0240904,
#   'symbol': 'OCN',
#   'volume_24h': 27306300.0},
#  {'circulating_supply': 77966926.2205,
#   'market_cap': 48146214.2466,
#   'name': 'Oyster',
#   'platform': 'Ethereum',
#   'price': 0.617521,
#   'symbol': 'PRL',
#   'volume_24h': 818365.0},
#  {'circulating_supply': 183000000.0,
#   'market_cap': 47916171.0,
#   'name': 'Wagerr',
#   'platform': 'Waves',
#   'price': 0.261837,
#   'symbol': 'WGR',
#   'volume_24h': 139181.0},
#  {'circulating_supply': 1292868388.26,
#   'market_cap': 47799154.3297,
#   'name': 'DATx',
#   'platform': 'Ethereum',
#   'price': 0.0369714,
#   'symbol': 'DATX',
#   'volume_24h': 78631.4},
#  {'circulating_supply': 485675392.554,
#   'market_cap': 47016340.6191,
#   'name': 'Etherparty',
#   'platform': 'Ethereum',
#   'price': 0.0968061,
#   'symbol': 'FUEL',
#   'volume_24h': 1971000.0},
#  {'circulating_supply': 599400.0,
#   'market_cap': 45666128.16,
#   'name': 'Melon',
#   'platform': 'Ethereum',
#   'price': 76.1864,
#   'symbol': 'MLN',
#   'volume_24h': 318219.0},
#  {'circulating_supply': 23944379.8047,
#   'market_cap': 44990771.3217,
#   'name': 'TokenCard',
#   'platform': 'Ethereum',
#   'price': 1.87897,
#   'symbol': 'TKN',
#   'volume_24h': 261220.0},
#  {'circulating_supply': 38750005.0184,
#   'market_cap': 44348218.2434,
#   'name': 'Delphy',
#   'platform': 'Ethereum',
#   'price': 1.14447,
#   'symbol': 'DPY',
#   'volume_24h': 3488600.0},
#  {'circulating_supply': 333333333.0,
#   'market_cap': 43719333.2896,
#   'name': 'Trinity Netwo...',
#   'platform': 'NEO',
#   'price': 0.131158,
#   'symbol': 'TNC',
#   'volume_24h': 953207.0},
#  {'circulating_supply': 8146000.7794,
#   'market_cap': 43641221.6555,
#   'name': 'TaaS',
#   'platform': 'Ethereum',
#   'price': 5.35738,
#   'symbol': 'TAAS',
#   'volume_24h': 306656.0},
#  {'circulating_supply': 376657502.4,
#   'market_cap': 42778875.8351,
#   'name': 'Mobius',
#   'platform': 'Stellar',
#   'price': 0.113575,
#   'symbol': 'MOBI',
#   'volume_24h': 960287.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 42646860.0,
#   'name': 'adToken',
#   'platform': 'Ethereum',
#   'price': 0.0710781,
#   'symbol': 'ADT',
#   'volume_24h': 2800610.0},
#  {'circulating_supply': 155000000.0,
#   'market_cap': 42603455.0,
#   'name': 'Presearch',
#   'platform': 'Ethereum',
#   'price': 0.274861,
#   'symbol': 'PRE',
#   'volume_24h': 118654.0},
#  {'circulating_supply': 82073518.6244,
#   'market_cap': 42173395.4716,
#   'name': 'Spectre.ai Di...',
#   'platform': 'Ethereum',
#   'price': 0.513849,
#   'symbol': 'SXDT',
#   'volume_24h': 39749.4},
#  {'circulating_supply': 71574646.3418,
#   'market_cap': 41839031.0937,
#   'name': 'BlockMason Cr...',
#   'platform': 'Ethereum',
#   'price': 0.584551,
#   'symbol': 'BCPT',
#   'volume_24h': 5517120.0},
#  {'circulating_supply': 880811506.299,
#   'market_cap': 41414788.1335,
#   'name': 'Datum',
#   'platform': 'Ethereum',
#   'price': 0.0470189,
#   'symbol': 'DAT',
#   'volume_24h': 1203200.0},
#  {'circulating_supply': 302887021.143,
#   'market_cap': 40948205.0494,
#   'name': 'Rock',
#   'platform': 'Ethereum',
#   'price': 0.135193,
#   'symbol': 'RKT',
#   'volume_24h': 27340.9},
#  {'circulating_supply': 1757773856.93,
#   'market_cap': 40827110.2654,
#   'name': 'Universa',
#   'platform': 'Ethereum',
#   'price': 0.0232266,
#   'symbol': 'UTNP',
#   'volume_24h': 254265.0},
#  {'circulating_supply': 657023039.17,
#   'market_cap': 40398244.2048,
#   'name': 'Blox',
#   'platform': 'Ethereum',
#   'price': 0.0614868,
#   'symbol': 'CDT',
#   'volume_24h': 2460570.0},
#  {'circulating_supply': 1081269353.05,
#   'market_cap': 40382815.2898,
#   'name': 'Soarcoin',
#   'platform': 'Ethereum',
#   'price': 0.0373476,
#   'symbol': 'SOAR',
#   'volume_24h': 17939.2},
#  {'circulating_supply': 57672338.0,
#   'market_cap': 40341742.7587,
#   'name': 'NAGA',
#   'platform': 'Ethereum',
#   'price': 0.699499,
#   'symbol': 'NGC',
#   'volume_24h': 176505.0},
#  {'circulating_supply': 118810621.886,
#   'market_cap': 40118188.6391,
#   'name': 'COSS',
#   'platform': 'Ethereum',
#   'price': 0.337665,
#   'symbol': 'COSS',
#   'volume_24h': 152547.0},
#  {'circulating_supply': 1543157590.0,
#   'market_cap': 39519185.6696,
#   'name': 'Safe Exchange...',
#   'platform': 'Omni',
#   'price': 0.0256093,
#   'symbol': 'SAFEX',
#   'volume_24h': 37042.7},
#  {'circulating_supply': 69310369.7779,
#   'market_cap': 39099435.1095,
#   'name': 'Bankex',
#   'platform': 'Ethereum',
#   'price': 0.564121,
#   'symbol': 'BKX',
#   'volume_24h': 1813560.0},
#  {'circulating_supply': 89921436.0103,
#   'market_cap': 38405265.4771,
#   'name': 'Trade Token',
#   'platform': 'Ethereum',
#   'price': 0.427098,
#   'symbol': 'TIO',
#   'volume_24h': 4745260.0},
#  {'circulating_supply': 119635679.45,
#   'market_cap': 38365128.5931,
#   'name': 'Legolas Exchange',
#   'platform': 'Ethereum',
#   'price': 0.320683,
#   'symbol': 'LGO',
#   'volume_24h': 161186.0},
#  {'circulating_supply': 141022371.35,
#   'market_cap': 38035566.8439,
#   'name': 'Unikoin Gold',
#   'platform': 'Ethereum',
#   'price': 0.269713,
#   'symbol': 'UKG',
#   'volume_24h': 862401.0},
#  {'circulating_supply': 804304194.098,
#   'market_cap': 38032569.4134,
#   'name': 'QunQun',
#   'platform': 'Ethereum',
#   'price': 0.0472863,
#   'symbol': 'QUN',
#   'volume_24h': 2900270.0},
#  {'circulating_supply': 231089000.0,
#   'market_cap': 37510135.391,
#   'name': 'bitCNY',
#   'platform': 'BitShares',
#   'price': 0.162319,
#   'symbol': 'BITCNY',
#   'volume_24h': 18858300.0},
#  {'circulating_supply': 466953693.06,
#   'market_cap': 37479851.392,
#   'name': 'Republic Prot...',
#   'platform': 'Ethereum',
#   'price': 0.0802646,
#   'symbol': 'REN',
#   'volume_24h': 1356060.0},
#  {'circulating_supply': 452073531.344,
#   'market_cap': 37331418.4861,
#   'name': 'KickCoin',
#   'platform': 'Ethereum',
#   'price': 0.0825782,
#   'symbol': 'KICK',
#   'volume_24h': 557846.0},
#  {'circulating_supply': 293827778.0,
#   'market_cap': 37280280.8171,
#   'name': 'Zeepin',
#   'platform': 'NEO',
#   'price': 0.126878,
#   'symbol': 'ZPT',
#   'volume_24h': 1803020.0},
#  {'circulating_supply': 362246647.008,
#   'market_cap': 36744850.8859,
#   'name': 'Cobinhood',
#   'platform': 'Ethereum',
#   'price': 0.101436,
#   'symbol': 'COB',
#   'volume_24h': 6878.8},
#  {'circulating_supply': 14248907134.9,
#   'market_cap': 36217302.1992,
#   'name': 'BABB',
#   'platform': 'Ethereum',
#   'price': 0.00254176,
#   'symbol': 'BAX',
#   'volume_24h': 770247.0},
#  {'circulating_supply': 168053133.432,
#   'market_cap': 36089074.2982,
#   'name': 'Viberate',
#   'platform': 'Ethereum',
#   'price': 0.214748,
#   'symbol': 'VIB',
#   'volume_24h': 4818460.0},
#  {'circulating_supply': 75000000.0,
#   'market_cap': 35815575.0,
#   'name': 'Matchpool',
#   'platform': 'Ethereum',
#   'price': 0.477541,
#   'symbol': 'GUP',
#   'volume_24h': 4674560.0},
#  {'circulating_supply': 124607147.91,
#   'market_cap': 35178466.9622,
#   'name': 'Tokenomy',
#   'platform': 'Ethereum',
#   'price': 0.282315,
#   'symbol': 'TEN',
#   'volume_24h': 956377.0},
#  {'circulating_supply': 263343445.107,
#   'market_cap': 34925134.377,
#   'name': 'YOYOW',
#   'platform': 'BitShares',
#   'price': 0.132622,
#   'symbol': 'YOYOW',
#   'volume_24h': 3033890.0},
#  {'circulating_supply': 226765852.267,
#   'market_cap': 34672045.2799,
#   'name': 'CPChain',
#   'platform': 'Ethereum',
#   'price': 0.152898,
#   'symbol': 'CPC',
#   'volume_24h': 3776270.0},
#  {'circulating_supply': 177479000.832,
#   'market_cap': 34586930.2032,
#   'name': 'ODEM',
#   'platform': 'Ethereum',
#   'price': 0.194879,
#   'symbol': 'ODE',
#   'volume_24h': 97255.3},
#  {'circulating_supply': 341834575.352,
#   'market_cap': 34506833.0435,
#   'name': 'STK',
#   'platform': 'Ethereum',
#   'price': 0.100946,
#   'symbol': 'STK',
#   'volume_24h': 2020650.0},
#  {'circulating_supply': 2353890557.32,
#   'market_cap': 32618332.2309,
#   'name': 'Refereum',
#   'platform': 'Ethereum',
#   'price': 0.0138572,
#   'symbol': 'RFR',
#   'volume_24h': 1105750.0},
#  {'circulating_supply': 3361218448.95,
#   'market_cap': 32363256.5504,
#   'name': 'XinFin Network',
#   'platform': 'Ethereum',
#   'price': 0.00962843,
#   'symbol': 'XDCE',
#   'volume_24h': 479219.0},
#  {'circulating_supply': 325000000.0,
#   'market_cap': 32085820.0,
#   'name': 'Cofound.it',
#   'platform': 'Ethereum',
#   'price': 0.0987256,
#   'symbol': 'CFI',
#   'volume_24h': 578946.0},
#  {'circulating_supply': 60470766.0554,
#   'market_cap': 31979480.8623,
#   'name': 'Havven',
#   'platform': 'Ethereum',
#   'price': 0.528842,
#   'symbol': 'HAV',
#   'volume_24h': 650230.0},
#  {'circulating_supply': 160714979.435,
#   'market_cap': 31583707.7586,
#   'name': 'ShipChain',
#   'platform': 'Ethereum',
#   'price': 0.19652,
#   'symbol': 'SHIP',
#   'volume_24h': 216486.0},
#  {'circulating_supply': 2790428084.0,
#   'market_cap': 31514815.7379,
#   'name': 'Alphacat',
#   'platform': 'NEO',
#   'price': 0.0112939,
#   'symbol': 'ACAT',
#   'volume_24h': 1989190.0},
#  {'circulating_supply': 212221521.567,
#   'market_cap': 31438496.2049,
#   'name': 'Dock',
#   'platform': 'Ethereum',
#   'price': 0.14814,
#   'symbol': 'DOCK',
#   'volume_24h': 8579340.0},
#  {'circulating_supply': 100000000.0,
#   'market_cap': 31095800.0,
#   'name': 'Mercury',
#   'platform': 'Waves',
#   'price': 0.310958,
#   'symbol': 'MER',
#   'volume_24h': 3781490.0},
#  {'circulating_supply': 98028877.0,
#   'market_cap': 31022120.3865,
#   'name': 'MobileGo',
#   'platform': 'Ethereum',
#   'price': 0.316459,
#   'symbol': 'MGO',
#   'volume_24h': 1321530.0},
#  {'circulating_supply': 162862944.036,
#   'market_cap': 30793962.5953,
#   'name': 'Humaniq',
#   'platform': 'Ethereum',
#   'price': 0.189079,
#   'symbol': 'HMQ',
#   'volume_24h': 192779.0},
#  {'circulating_supply': 2297853.07853,
#   'market_cap': 30387268.6811,
#   'name': 'Lunyr',
#   'platform': 'Ethereum',
#   'price': 13.2242,
#   'symbol': 'LUN',
#   'volume_24h': 2186220.0},
#  {'circulating_supply': 32025998.4158,
#   'market_cap': 30284360.5699,
#   'name': 'Decision Token',
#   'platform': 'Ethereum',
#   'price': 0.945618,
#   'symbol': 'HST',
#   'volume_24h': 243012.0},
#  {'circulating_supply': 1899999999.15,
#   'market_cap': 30180929.9866,
#   'name': 'Sentinel',
#   'platform': 'Ethereum',
#   'price': 0.0158847,
#   'symbol': 'SENT',
#   'volume_24h': 484793.0},
#  {'circulating_supply': 701884009.0,
#   'market_cap': 30087872.379,
#   'name': 'Pepe Cash',
#   'platform': 'Counterparty',
#   'price': 0.0428673,
#   'symbol': 'PEPECASH',
#   'volume_24h': 185501.0},
#  {'circulating_supply': 17459665.3911,
#   'market_cap': 30062226.467,
#   'name': 'Propy',
#   'platform': 'Ethereum',
#   'price': 1.72181,
#   'symbol': 'PRO',
#   'volume_24h': 14205000.0},
#  {'circulating_supply': 50216064.1985,
#   'market_cap': 30052556.8605,
#   'name': 'DMarket',
#   'platform': 'Ethereum',
#   'price': 0.598465,
#   'symbol': 'DMT',
#   'volume_24h': 219454.0},
#  {'circulating_supply': 30329679.6073,
#   'market_cap': 29654176.9831,
#   'name': 'Dai',
#   'platform': 'Ethereum',
#   'price': 0.977728,
#   'symbol': 'DAI',
#   'volume_24h': 1416610.0},
#  {'circulating_supply': 25000000.0,
#   'market_cap': 29590250.0,
#   'name': 'True Chain',
#   'platform': 'Ethereum',
#   'price': 1.18361,
#   'symbol': 'TRUE',
#   'volume_24h': 68134200.0},
#  {'circulating_supply': 415000000.0,
#   'market_cap': 29514094.5,
#   'name': 'Restart Energ...',
#   'platform': 'Ethereum',
#   'price': 0.0711183,
#   'symbol': 'MWAT',
#   'volume_24h': 379882.0},
#  {'circulating_supply': 100728564.0,
#   'market_cap': 29427849.9726,
#   'name': 'Synereo',
#   'platform': 'Omni',
#   'price': 0.29215,
#   'symbol': 'AMP',
#   'volume_24h': 352678.0},
#  {'circulating_supply': 1153170765.0,
#   'market_cap': 29331244.359,
#   'name': 'Zeusshield',
#   'platform': 'Ethereum',
#   'price': 0.0254353,
#   'symbol': 'ZSC',
#   'volume_24h': 1559830.0},
#  {'circulating_supply': 5721787903.0,
#   'market_cap': 29279132.5321,
#   'name': 'U Network',
#   'platform': 'Ethereum',
#   'price': 0.00511713,
#   'symbol': 'UUU',
#   'volume_24h': 2988300.0},
#  {'circulating_supply': 350000000.0,
#   'market_cap': 29253805.0,
#   'name': 'EDUCare',
#   'platform': 'Ethereum',
#   'price': 0.0835823,
#   'symbol': 'EKT',
#   'volume_24h': 18067400.0},
#  {'circulating_supply': 141959175.941,
#   'market_cap': 29163809.187,
#   'name': 'UpToken',
#   'platform': 'Ethereum',
#   'price': 0.205438,
#   'symbol': 'UP',
#   'volume_24h': 1329410.0},
#  {'circulating_supply': 142215728.19,
#   'market_cap': 29140856.0005,
#   'name': 'Lamden',
#   'platform': 'Ethereum',
#   'price': 0.204906,
#   'symbol': 'TAU',
#   'volume_24h': 484443.0},
#  {'circulating_supply': 568842039.121,
#   'market_cap': 29125395.0134,
#   'name': 'ugChain',
#   'platform': 'Ethereum',
#   'price': 0.0512012,
#   'symbol': 'UGC',
#   'volume_24h': 1709080.0},
#  {'circulating_supply': 92147500.0,
#   'market_cap': 28952928.795,
#   'name': 'WeTrust',
#   'platform': 'Ethereum',
#   'price': 0.314202,
#   'symbol': 'TRST',
#   'volume_24h': 247233.0},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 28725760.0,
#   'name': 'Blocktix',
#   'platform': 'Ethereum',
#   'price': 0.718144,
#   'symbol': 'TIX',
#   'volume_24h': 28250900.0},
#  {'circulating_supply': 13000000.0,
#   'market_cap': 28644070.0,
#   'name': 'Aeron',
#   'platform': 'Ethereum',
#   'price': 2.20339,
#   'symbol': 'ARN',
#   'volume_24h': 12812500.0},
#  {'circulating_supply': 582029028.5,
#   'market_cap': 28619123.9691,
#   'name': 'Energo',
#   'platform': 'Ethereum',
#   'price': 0.0491713,
#   'symbol': 'TSL',
#   'volume_24h': 2187390.0},
#  {'circulating_supply': 85558370.5,
#   'market_cap': 28230069.9048,
#   'name': 'FirstBlood',
#   'platform': 'Ethereum',
#   'price': 0.329951,
#   'symbol': '1ST',
#   'volume_24h': 376947.0},
#  {'circulating_supply': 16500000.0,
#   'market_cap': 28027725.0,
#   'name': 'Everex',
#   'platform': 'Ethereum',
#   'price': 1.69865,
#   'symbol': 'EVX',
#   'volume_24h': 1501630.0},
#  {'circulating_supply': 443330795.695,
#   'market_cap': 27822997.4071,
#   'name': 'AI Doctor',
#   'platform': 'Ethereum',
#   'price': 0.062759,
#   'symbol': 'AIDOC',
#   'volume_24h': 4632060.0},
#  {'circulating_supply': 413948998.65,
#   'market_cap': 27790714.3938,
#   'name': 'Cappasity',
#   'platform': 'Ethereum',
#   'price': 0.0671356,
#   'symbol': 'CAPP',
#   'volume_24h': 203751.0},
#  {'circulating_supply': 1750000000.0,
#   'market_cap': 27345675.0,
#   'name': 'SwftCoin',
#   'platform': 'Ethereum',
#   'price': 0.0156261,
#   'symbol': 'SWFTC',
#   'volume_24h': 23058700.0},
#  {'circulating_supply': 159219129.364,
#   'market_cap': 27305443.8095,
#   'name': 'Sentinel Chain',
#   'platform': 'Ethereum',
#   'price': 0.171496,
#   'symbol': 'SENC',
#   'volume_24h': 3024820.0},
#  {'circulating_supply': 400416066.971,
#   'market_cap': 27187049.6991,
#   'name': 'Fortuna',
#   'platform': 'Ethereum',
#   'price': 0.067897,
#   'symbol': 'FOTA',
#   'volume_24h': 1535550.0},
#  {'circulating_supply': 185000000.0,
#   'market_cap': 27140795.0,
#   'name': 'Medicalchain',
#   'platform': 'Ethereum',
#   'price': 0.146707,
#   'symbol': 'MTN',
#   'volume_24h': 7351850.0},
#  {'circulating_supply': 217515566.83,
#   'market_cap': 27051758.4999,
#   'name': 'Monetha',
#   'platform': 'Ethereum',
#   'price': 0.124367,
#   'symbol': 'MTH',
#   'volume_24h': 1018960.0},
#  {'circulating_supply': 119665373.154,
#   'market_cap': 26485178.0441,
#   'name': 'SunContract',
#   'platform': 'Ethereum',
#   'price': 0.221327,
#   'symbol': 'SNC',
#   'volume_24h': 2924640.0},
#  {'circulating_supply': 140000000.0,
#   'market_cap': 26050640.0,
#   'name': 'Mothership',
#   'platform': 'Ethereum',
#   'price': 0.186076,
#   'symbol': 'MSP',
#   'volume_24h': 169926.0},
#  {'circulating_supply': 611623175.003,
#   'market_cap': 25774412.2178,
#   'name': 'Lympo',
#   'platform': 'Ethereum',
#   'price': 0.042141,
#   'symbol': 'LYM',
#   'volume_24h': 1022740.0},
#  {'circulating_supply': 65351403.0,
#   'market_cap': 25255049.6894,
#   'name': 'Qbao',
#   'platform': 'Qtum',
#   'price': 0.38645,
#   'symbol': 'QBT',
#   'volume_24h': 3308520.0},
#  {'circulating_supply': 85978873.0,
#   'market_cap': 24934131.1066,
#   'name': 'Agrello',
#   'platform': 'Ethereum',
#   'price': 0.290003,
#   'symbol': 'DLT',
#   'volume_24h': 820286.0},
#  {'circulating_supply': 1912447545.56,
#   'market_cap': 24838868.7218,
#   'name': 'Selfkey',
#   'platform': 'Ethereum',
#   'price': 0.012988,
#   'symbol': 'KEY',
#   'volume_24h': 167051.0},
#  {'circulating_supply': 490610995.087,
#   'market_cap': 24816526.9034,
#   'name': 'Switcheo',
#   'platform': 'NEO',
#   'price': 0.0505829,
#   'symbol': 'SWH',
#   'volume_24h': 561051.0},
#  {'circulating_supply': 255628294.061,
#   'market_cap': 24639832.3247,
#   'name': 'Rentberry',
#   'platform': 'Ethereum',
#   'price': 0.0963893,
#   'symbol': 'BERRY',
#   'volume_24h': 1025890.0},
#  {'circulating_supply': 1351973.08735,
#   'market_cap': 24503430.6297,
#   'name': 'Numeraire',
#   'platform': 'Ethereum',
#   'price': 18.1242,
#   'symbol': 'NMR',
#   'volume_24h': 141172.0},
#  {'circulating_supply': 77349832.1356,
#   'market_cap': 24431099.1797,
#   'name': 'DADI',
#   'platform': 'Ethereum',
#   'price': 0.315852,
#   'symbol': 'DADI',
#   'volume_24h': 2986110.0},
#  {'circulating_supply': 535067071.156,
#   'market_cap': 24350741.8882,
#   'name': 'AICHAIN',
#   'platform': 'Ethereum',
#   'price': 0.0455097,
#   'symbol': 'AIT',
#   'volume_24h': 926398.0},
#  {'circulating_supply': 5579008239.61,
#   'market_cap': 24279230.1679,
#   'name': 'carVertical',
#   'platform': 'Ethereum',
#   'price': 0.00435189,
#   'symbol': 'CV',
#   'volume_24h': 175058.0},
#  {'circulating_supply': 47674793.963,
#   'market_cap': 23989765.623,
#   'name': 'Bloom',
#   'platform': 'Ethereum',
#   'price': 0.503196,
#   'symbol': 'BLT',
#   'volume_24h': 27856.4},
#  {'circulating_supply': 19628888.0,
#   'market_cap': 23972760.9144,
#   'name': 'Moeda Loyalty...',
#   'platform': 'Ethereum',
#   'price': 1.2213,
#   'symbol': 'MDA',
#   'volume_24h': 5560350.0},
#  {'circulating_supply': 404100000.0,
#   'market_cap': 23904980.01,
#   'name': 'Hi Mutual Soc...',
#   'platform': 'Ethereum',
#   'price': 0.0591561,
#   'symbol': 'HMC',
#   'volume_24h': 3883550.0},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 23563680.0,
#   'name': 'Bodhi',
#   'platform': 'Qtum',
#   'price': 0.589092,
#   'symbol': 'BOT',
#   'volume_24h': 8986880.0},
#  {'circulating_supply': 1365218125.0,
#   'market_cap': 23033141.0741,
#   'name': 'YEE',
#   'platform': 'Ethereum',
#   'price': 0.0168714,
#   'symbol': 'YEE',
#   'volume_24h': 4363630.0},
#  {'circulating_supply': 235424687.891,
#   'market_cap': 23005724.0432,
#   'name': 'OneRoot Network',
#   'platform': 'Ethereum',
#   'price': 0.0977201,
#   'symbol': 'RNT',
#   'volume_24h': 1594610.0},
#  {'circulating_supply': 514991706.617,
#   'market_cap': 22882369.0043,
#   'name': 'SpaceChain',
#   'platform': 'Qtum',
#   'price': 0.0444325,
#   'symbol': 'SPC',
#   'volume_24h': 25798.1},
#  {'circulating_supply': 390222225.333,
#   'market_cap': 22538962.5797,
#   'name': 'Datawallet',
#   'platform': 'Ethereum',
#   'price': 0.0577593,
#   'symbol': 'DXT',
#   'volume_24h': 1222010.0},
#  {'circulating_supply': 481425335.174,
#   'market_cap': 22124286.4182,
#   'name': 'TokenClub',
#   'platform': 'Ethereum',
#   'price': 0.0459558,
#   'symbol': 'TCT',
#   'volume_24h': 4338170.0},
#  {'circulating_supply': 265000000.0,
#   'market_cap': 21233893.5,
#   'name': 'aXpire',
#   'platform': 'Ethereum',
#   'price': 0.0801279,
#   'symbol': 'AXP',
#   'volume_24h': 137472.0},
#  {'circulating_supply': 4660285459.8,
#   'market_cap': 21094316.1052,
#   'name': 'ATMChain',
#   'platform': 'Ethereum',
#   'price': 0.0045264,
#   'symbol': 'ATM',
#   'volume_24h': 523515.0},
#  {'circulating_supply': 375000000.0,
#   'market_cap': 20715750.0,
#   'name': 'Hive Project',
#   'platform': 'Ethereum',
#   'price': 0.055242,
#   'symbol': 'HVN',
#   'volume_24h': 42129.5},
#  {'circulating_supply': 501394405.74,
#   'market_cap': 20490786.016,
#   'name': 'BitClave',
#   'platform': 'Ethereum',
#   'price': 0.0408676,
#   'symbol': 'CAT',
#   'volume_24h': 1739440.0},
#  {'circulating_supply': 17500000.0,
#   'market_cap': 20407800.0,
#   'name': 'Covesting',
#   'platform': 'Ethereum',
#   'price': 1.16616,
#   'symbol': 'COV',
#   'volume_24h': 84351.0},
#  {'circulating_supply': 252998051.199,
#   'market_cap': 20245663.0511,
#   'name': 'Measurable Da...',
#   'platform': 'Ethereum',
#   'price': 0.080023,
#   'symbol': 'MDT',
#   'volume_24h': 1565420.0},
#  {'circulating_supply': 23224303.1,
#   'market_cap': 20156558.4549,
#   'name': 'Matryx',
#   'platform': 'Ethereum',
#   'price': 0.867908,
#   'symbol': 'MTX',
#   'volume_24h': 1685580.0},
#  {'circulating_supply': 16344757.737,
# ...
#   'market_cap': None,
#   'name': 'RealChain',
#   'platform': 'Ethereum',
#   'price': 0.0457375,
#   'symbol': 'RCT',
#   'volume_24h': 2428620.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eosDAC',
#   'platform': 'Ethereum',
#   'price': 0.160668,
#   'symbol': 'EOSDAC',
#   'volume_24h': 2150030.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BitStation',
#   'platform': 'Ethereum',
#   'price': 0.00337019,
#   'symbol': 'BSTN',
#   'volume_24h': 1898980.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BnkToTheFuture',
#   'platform': 'Ethereum',
#   'price': 0.294796,
#   'symbol': 'BFT',
#   'volume_24h': 1884270.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Noah Coin',
#   'platform': 'Ethereum',
#   'price': 0.0103411,
#   'symbol': 'NOAH',
#   'volume_24h': 1838530.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Electronic PK...',
#   'platform': 'Qtum',
#   'price': 0.0958138,
#   'symbol': 'EPC',
#   'volume_24h': 1832840.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Gems ',
#   'platform': 'Ethereum',
#   'price': 0.0256231,
#   'symbol': 'GEM',
#   'volume_24h': 1637200.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Show',
#   'platform': 'Ethereum',
#   'price': 0.00426761,
#   'symbol': 'SHOW',
#   'volume_24h': 1416880.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Neurotoken',
#   'platform': 'Ethereum',
#   'price': 0.683426,
#   'symbol': 'NTK',
#   'volume_24h': 1366100.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maggie',
#   'platform': 'Ethereum',
#   'price': 0.0172426,
#   'symbol': 'MAG',
#   'volume_24h': 1241070.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'AWARE',
#   'platform': 'Qtum',
#   'price': 0.0299265,
#   'symbol': 'AWR',
#   'volume_24h': 1236300.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SelfSell',
#   'platform': 'Ethereum',
#   'price': 0.0608764,
#   'symbol': 'SSC',
#   'volume_24h': 1162130.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Exchange Union',
#   'platform': 'Ethereum',
#   'price': 7.01509,
#   'symbol': 'XUC',
#   'volume_24h': 1156920.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ValueChain',
#   'platform': 'Ethereum',
#   'price': 0.0964075,
#   'symbol': 'VLC',
#   'volume_24h': 1053320.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LightChain',
#   'platform': 'Ethereum',
#   'price': 0.00149892,
#   'symbol': 'LIGHT',
#   'volume_24h': 1016970.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'IPChain',
#   'platform': 'Ethereum',
#   'price': 0.504698,
#   'symbol': 'IPC',
#   'volume_24h': 750586.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'StockChain',
#   'platform': 'Ethereum',
#   'price': 0.0569365,
#   'symbol': 'SCC',
#   'volume_24h': 698730.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'HalalChain',
#   'platform': 'Qtum',
#   'price': 0.169836,
#   'symbol': 'HLC',
#   'volume_24h': 630187.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'COMSA [ETH]',
#   'platform': 'Ethereum',
#   'price': 0.692819,
#   'symbol': 'CMS',
#   'volume_24h': 570098.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Pixie Coin',
#   'platform': 'Ethereum',
#   'price': 0.00413572,
#   'symbol': 'PXC',
#   'volume_24h': 447667.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BigONE Token',
#   'platform': 'Ethereum',
#   'price': 2.1436,
#   'symbol': 'BIG',
#   'volume_24h': 420479.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Earth Token',
#   'platform': 'Ethereum',
#   'price': 0.0249679,
#   'symbol': 'EARTH',
#   'volume_24h': 394526.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BlockCDN',
#   'platform': 'Ethereum',
#   'price': 0.0460095,
#   'symbol': 'BCDN',
#   'volume_24h': 391319.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Fidelium',
#   'platform': 'Ethereum',
#   'price': 0.234462,
#   'symbol': 'FID',
#   'volume_24h': 385045.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Qube',
#   'platform': 'Ethereum',
#   'price': 0.0379194,
#   'symbol': 'QUBE',
#   'volume_24h': 369288.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'WETH',
#   'platform': 'Ethereum',
#   'price': 660.879,
#   'symbol': 'WETH',
#   'volume_24h': 368739.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'FairGame',
#   'platform': 'Ethereum',
#   'price': 0.040665,
#   'symbol': 'FAIR',
#   'volume_24h': 358251.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'COMSA [XEM]',
#   'platform': 'NEM',
#   'price': 0.699105,
#   'symbol': 'CMS',
#   'volume_24h': 349898.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'MARK.SPACE',
#   'platform': 'Ethereum',
#   'price': 0.110316,
#   'symbol': 'MRK',
#   'volume_24h': 344965.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'AMLT Token',
#   'platform': 'Ethereum',
#   'price': 0.0479512,
#   'symbol': 'AMLT',
#   'volume_24h': 321073.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'PressOne',
#   'platform': 'Ethereum',
#   'price': 0.37395,
#   'symbol': 'PRS',
#   'volume_24h': 318224.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'UnlimitedIP',
#   'platform': 'Ethereum',
#   'price': 0.0471257,
#   'symbol': 'UIP',
#   'volume_24h': 314478.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Aditus',
#   'platform': 'Ethereum',
#   'price': 0.0153201,
#   'symbol': 'ADI',
#   'volume_24h': 312723.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Dignity',
#   'platform': 'Ethereum',
#   'price': 0.0673449,
#   'symbol': 'DIG',
#   'volume_24h': 291885.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BelugaPay',
#   'platform': 'Ethereum',
#   'price': 0.514507,
#   'symbol': 'BBI',
#   'volume_24h': 285198.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Read',
#   'platform': 'Ethereum',
#   'price': 0.0224161,
#   'symbol': 'READ',
#   'volume_24h': 239396.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Curriculum Vitae',
#   'platform': 'Ethereum',
#   'price': 0.0334349,
#   'symbol': 'CVH',
#   'volume_24h': 191889.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Etherecash',
#   'platform': 'Ethereum',
#   'price': 0.296541,
#   'symbol': 'ECH',
#   'volume_24h': 176448.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BrahmaOS',
#   'platform': 'Ethereum',
#   'price': 0.0796353,
#   'symbol': 'BRM',
#   'volume_24h': 167231.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TokenDesk',
#   'platform': 'Ethereum',
#   'price': 0.3973,
#   'symbol': 'TDS',
#   'volume_24h': 142072.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'WCOIN',
#   'platform': 'Ethereum',
#   'price': 0.13723,
#   'symbol': 'WIN',
#   'volume_24h': 138856.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Internet of T...',
#   'platform': 'Nxt',
#   'price': 1162.88,
#   'symbol': 'XOT',
#   'volume_24h': 127856.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sphre AIR ',
#   'platform': 'Ethereum',
#   'price': 0.138311,
#   'symbol': 'XID',
#   'volume_24h': 92465.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Consensus',
#   'platform': 'Ethereum',
#   'price': 0.0260664,
#   'symbol': 'SEN',
#   'volume_24h': 89379.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SnipCoin',
#   'platform': 'Ethereum',
#   'price': 0.0012786,
#   'symbol': 'SNIP',
#   'volume_24h': 89289.2},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Alphabit',
#   'platform': 'Ethereum',
#   'price': 56.0411,
#   'symbol': 'ABC',
#   'volume_24h': 77753.4},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Chainium',
#   'platform': 'Ethereum',
#   'price': 0.0975946,
#   'symbol': 'CHX',
#   'volume_24h': 69216.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'PHI Token',
#   'platform': 'Ethereum',
#   'price': 0.499389,
#   'symbol': 'PHI',
#   'volume_24h': 56438.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Animation Vis...',
#   'platform': 'Ethereum',
#   'price': 0.00821181,
#   'symbol': 'AVH',
#   'volume_24h': 55944.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Candy',
#   'platform': 'Ethereum',
#   'price': 0.000273497,
#   'symbol': 'CANDY',
#   'volume_24h': 53156.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Budbo',
#   'platform': 'Ethereum',
#   'price': 0.053891,
#   'symbol': 'BUBO',
#   'volume_24h': 50843.2},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Friendz',
#   'platform': 'Ethereum',
#   'price': 0.024394,
#   'symbol': 'FDZ',
#   'volume_24h': 46409.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'InvestDigital',
#   'platform': 'Ethereum',
#   'price': 0.0497823,
#   'symbol': 'IDT',
#   'volume_24h': 46078.2},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CFun',
#   'platform': 'Qtum',
#   'price': 0.0098699,
#   'symbol': 'CFUN',
#   'volume_24h': 39662.4},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Titanium Bloc...',
#   'platform': 'Ethereum',
#   'price': 0.00768952,
#   'symbol': 'BAR',
#   'volume_24h': 38725.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GreenMed',
#   'platform': 'Ethereum',
#   'price': 0.168064,
#   'symbol': 'GRMD',
#   'volume_24h': 37061.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bela',
#   'platform': 'Ethereum',
#   'price': 0.177215,
#   'symbol': 'BELA',
#   'volume_24h': 36162.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Hyper Pay',
#   'platform': 'Qtum',
#   'price': 0.0237978,
#   'symbol': 'HPY',
#   'volume_24h': 35464.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Peculium',
#   'platform': 'Ethereum',
#   'price': 0.00407199,
#   'symbol': 'PCL',
#   'volume_24h': 24534.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SyncFab',
#   'platform': 'Ethereum',
#   'price': 0.0401075,
#   'symbol': 'MFG',
#   'volume_24h': 16401.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CryptopiaFeeS...',
#   'platform': 'Ubiq',
#   'price': 2071.96,
#   'symbol': 'CEFS',
#   'volume_24h': 12408.2},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GameChain System',
#   'platform': 'Ethereum',
#   'price': 0.00901069,
#   'symbol': 'GCS',
#   'volume_24h': 12284.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'First Bitcoin...',
#   'platform': 'Omni',
#   'price': 0.159661,
#   'symbol': 'BITCF',
#   'volume_24h': 10829.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'OX Fina',
#   'platform': 'Ethereum',
#   'price': 0.000537281,
#   'symbol': 'OX',
#   'volume_24h': 4634.89},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Macro',
#   'platform': 'Ethereum',
#   'price': 0.64987,
#   'symbol': 'MCR',
#   'volume_24h': 4031.94},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EtherDelta Token',
#   'platform': 'Ethereum',
#   'price': 0.00806815,
#   'symbol': 'EDT',
#   'volume_24h': 3918.66},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Lendroid Supp...',
#   'platform': 'Ethereum',
#   'price': 0.00977379,
#   'symbol': 'LST',
#   'volume_24h': 3806.52},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'President Joh...',
#   'platform': 'Omni',
#   'price': 0.0742285,
#   'symbol': 'GARY',
#   'volume_24h': 3368.44},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'President Trump',
#   'platform': 'Omni',
#   'price': 0.0187515,
#   'symbol': 'PRES',
#   'volume_24h': 3250.82},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TeslaCoilCoin',
#   'platform': 'Omni',
#   'price': 1.21258,
#   'symbol': 'TESLA',
#   'volume_24h': 2964.95},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Cloud',
#   'platform': 'Ethereum',
#   'price': 0.0514447,
#   'symbol': 'CLD',
#   'volume_24h': 2632.83},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'United Trader...',
#   'platform': 'Ethereum',
#   'price': 0.469635,
#   'symbol': 'UTT',
#   'volume_24h': 2483.76},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'HODL Bucks',
#   'platform': 'Ethereum',
#   'price': 0.0732948,
#   'symbol': 'HDLB',
#   'volume_24h': 2359.04},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Storjcoin X',
#   'platform': 'Counterparty',
#   'price': 0.848226,
#   'symbol': 'SJCX',
#   'volume_24h': 1824.79},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Musiconomi',
#   'platform': 'Ethereum',
#   'price': 0.0520066,
#   'symbol': 'MCI',
#   'volume_24h': 1397.23},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CORION',
#   'platform': 'Ethereum Classic',
#   'price': 0.163303,
#   'symbol': 'COR',
#   'volume_24h': 1297.22},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ZenGold',
#   'platform': 'BitShares',
#   'price': 0.0314295,
#   'symbol': 'ZENGOLD',
#   'volume_24h': 885.364},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BTCMoon',
#   'platform': 'Ethereum',
#   'price': 0.00560008,
#   'symbol': 'BTCM',
#   'volume_24h': 862.783},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Indicoin',
#   'platform': 'Ethereum',
#   'price': 0.0102706,
#   'symbol': 'INDI',
#   'volume_24h': 410.171},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'PlexCoin',
#   'platform': 'Ethereum',
#   'price': 0.0130684,
#   'symbol': 'PLX',
#   'volume_24h': 334.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SuperNET',
#   'platform': 'Nxt',
#   'price': 136.782,
#   'symbol': 'UNITY',
#   'volume_24h': 308.178},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Ethereum Lite',
#   'platform': 'Ethereum',
#   'price': 0.312787,
#   'symbol': 'ELITE',
#   'volume_24h': 242.665},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ANRYZE',
#   'platform': 'Waves',
#   'price': 0.00662921,
#   'symbol': 'RYZ',
#   'volume_24h': 203.418},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eREAL',
#   'platform': 'Ethereum',
#   'price': 0.0012909,
#   'symbol': 'EREAL',
#   'volume_24h': 185.296},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GOLD Reward T...',
#   'platform': 'Ethereum',
#   'price': 0.0111117,
#   'symbol': 'GRX',
#   'volume_24h': 161.616},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Minex',
#   'platform': 'Waves',
#   'price': 0.0122561,
#   'symbol': 'MINEX',
#   'volume_24h': 106.191},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Wi Coin',
#   'platform': 'Ethereum',
#   'price': 0.00147171,
#   'symbol': 'WIC',
#   'volume_24h': 105.083},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Smoke',
#   'platform': 'BitShares',
#   'price': 0.0981616,
#   'symbol': 'SMOKE',
#   'volume_24h': 71.5999},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BitSerial',
#   'platform': 'Ethereum',
#   'price': 0.00715405,
#   'symbol': 'BTE',
#   'volume_24h': 58.3866},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'FAPcoin',
#   'platform': 'Ethereum',
#   'price': 0.00130717,
#   'symbol': 'FAP',
#   'volume_24h': 54.8479},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EncryptoTel [...',
#   'platform': 'Ethereum',
#   'price': 0.0506061,
#   'symbol': 'ETT',
#   'volume_24h': 22.8712},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'NEO GOLD',
#   'platform': 'Ethereum',
#   'price': 0.00308118,
#   'symbol': 'NEOG',
#   'volume_24h': 7.46953},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Nitro',
#   'platform': 'Ethereum',
#   'price': 0.106877,
#   'symbol': 'NOX',
#   'volume_24h': 6.37025},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SISA',
#   'platform': 'Ethereum',
#   'price': 0.00933691,
#   'symbol': 'SISA',
#   'volume_24h': 3.36129},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'STEX',
#   'platform': 'Nxt',
#   'price': 1.12043,
#   'symbol': 'STEX',
#   'volume_24h': 0.335457}]

# %%
show_page("tokens/views/all")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/tokens/views/all"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# _________________________________
#
# ## Graphs API
# The graphs API is used internally by coinmarketcap for display graphs info. The params `start` and `end` are passed as `datetime` objects.
#
# #### `graphs.currency(name, [start=None, end=None])`
#
# Get graphs data for a currency:

# %%
cmc.graphs.currency("BTC")
# Out:
# {'market_cap_by_available_supply': [[datetime.datetime(2013, 4, 28, 20, 47, 21),
#    1500517590],
#   [datetime.datetime(2013, 4, 29, 20, 45, 1), 1575032004],
#   [datetime.datetime(2013, 4, 30, 20, 45, 2), 1501657492],
#   [datetime.datetime(2013, 5, 1, 20, 45, 2), 1298951550],
#   [datetime.datetime(2013, 5, 2, 21, 20, 1), 1148667722],
#   [datetime.datetime(2013, 5, 3, 21, 20, 1), 1011066494],
#   [datetime.datetime(2013, 5, 4, 21, 20, 1), 1236351843],
#   [datetime.datetime(2013, 5, 5, 21, 25, 1), 1298377788],
#   [datetime.datetime(2013, 5, 6, 21, 25, 3), 1315992303],
#   [datetime.datetime(2013, 5, 7, 21, 25, 1), 1183766500],
#   [datetime.datetime(2013, 5, 8, 21, 25, 1), 1253655040],
#   [datetime.datetime(2013, 5, 9, 21, 50, 1), 1258130700],
#   [datetime.datetime(2013, 5, 10, 21, 55, 2), 1322989457],
#   [datetime.datetime(2013, 5, 11, 22, 25, 1), 1259239352],
#   [datetime.datetime(2013, 5, 12, 22, 25, 1), 1278708678],
#   [datetime.datetime(2013, 5, 13, 22, 25, 1), 1306721052],
#   [datetime.datetime(2013, 5, 14, 22, 25, 1), 1277278987],
#   [datetime.datetime(2013, 5, 15, 22, 35, 1), 1273849680],
#   [datetime.datetime(2013, 5, 16, 22, 35, 1), 1289277412],
#   [datetime.datetime(2013, 5, 17, 22, 35, 1), 1374605382],
#   [datetime.datetime(2013, 5, 18, 22, 35, 1), 1383755085],
#   [datetime.datetime(2013, 5, 19, 22, 35, 2), 1346499261],
#   [datetime.datetime(2013, 5, 20, 22, 35, 2), 1370131821],
#   [datetime.datetime(2013, 5, 21, 22, 35, 2), 1374154117],
#   [datetime.datetime(2013, 5, 22, 22, 35, 4), 1375791900],
#   [datetime.datetime(2013, 5, 23, 22, 35, 2), 1407041527],
#   [datetime.datetime(2013, 5, 24, 22, 35, 1), 1474180657],
#   [datetime.datetime(2013, 5, 25, 22, 35, 2), 1464316690],
#   [datetime.datetime(2013, 5, 26, 22, 45, 2), 1507769010],
#   [datetime.datetime(2013, 5, 27, 22, 45, 1), 1445444605],
#   [datetime.datetime(2013, 5, 28, 22, 45, 7), 1448115966],
#   [datetime.datetime(2013, 5, 29, 23, 15, 1), 1481781794],
#   [datetime.datetime(2013, 5, 30, 23, 15, 1), 1429308633],
#   [datetime.datetime(2013, 5, 31, 23, 40, 2), 1436386729],
#   [datetime.datetime(2013, 6, 1, 23, 40, 2), 1449499974],
#   [datetime.datetime(2013, 6, 3, 1, 25, 1), 1362684200],
#   [datetime.datetime(2013, 6, 4, 1, 25, 2), 1361765704],
#   [datetime.datetime(2013, 6, 5, 2, 45, 2), 1364113639],
#   [datetime.datetime(2013, 6, 6, 2, 45, 2), 1369233814],
#   [datetime.datetime(2013, 6, 7, 2, 45, 1), 1339234925],
#   [datetime.datetime(2013, 6, 8, 2, 45, 2), 1239395972],
#   [datetime.datetime(2013, 6, 9, 2, 45, 1), 1220874392],
#   [datetime.datetime(2013, 6, 10, 2, 45, 2), 1123844957],
#   [datetime.datetime(2013, 6, 11, 2, 55, 5), 1194605340],
#   [datetime.datetime(2013, 6, 12, 3, 0, 2), 1227904672],
#   [datetime.datetime(2013, 6, 13, 3, 0, 1), 1222819750],
#   [datetime.datetime(2013, 6, 14, 3, 0, 2), 1159766149],
#   [datetime.datetime(2013, 6, 15, 3, 5, 1), 1110902570],
#   [datetime.datetime(2013, 6, 16, 3, 5, 2), 1129287060],
#   [datetime.datetime(2013, 6, 17, 3, 15, 2), 1134610433],
#   [datetime.datetime(2013, 6, 18, 3, 20, 4), 1152834600],
#   [datetime.datetime(2013, 6, 19, 3, 25, 2), 1204638317],
#   [datetime.datetime(2013, 6, 20, 3, 25, 10), 1220273470],
#   [datetime.datetime(2013, 6, 21, 3, 30, 2), 1254733148],
#   [datetime.datetime(2013, 6, 22, 3, 30, 1), 1233750008],
#   [datetime.datetime(2013, 6, 23, 3, 30, 2), 1214260368],
#   [datetime.datetime(2013, 6, 24, 3, 30, 2), 1223181000],
#   [datetime.datetime(2013, 6, 25, 3, 30, 3), 1160635651],
#   [datetime.datetime(2013, 6, 26, 3, 35, 2), 1175194909],
#   [datetime.datetime(2013, 6, 27, 3, 50, 1), 1172207387],
#   [datetime.datetime(2013, 6, 28, 3, 50, 1), 1130338737],
#   [datetime.datetime(2013, 6, 29, 3, 50, 1), 1058953326],
#   [datetime.datetime(2013, 6, 30, 4, 0, 2), 1082693996],
#   [datetime.datetime(2013, 7, 1, 4, 0, 1), 1107084792],
#   [datetime.datetime(2013, 7, 2, 4, 0, 4), 1016445145],
#   [datetime.datetime(2013, 7, 3, 4, 0, 1), 1031653673],
#   [datetime.datetime(2013, 7, 4, 4, 50, 2), 895707780],
#   [datetime.datetime(2013, 7, 5, 4, 46, 1), 892405890],
#   [datetime.datetime(2013, 7, 6, 4, 46, 2), 771368060],
#   [datetime.datetime(2013, 7, 7, 4, 46, 1), 774804400],
#   [datetime.datetime(2013, 7, 8, 4, 46, 2), 882356394],
#   [datetime.datetime(2013, 7, 9, 4, 46, 2), 870081996],
#   [datetime.datetime(2013, 7, 10, 4, 46, 2), 877378425],
#   [datetime.datetime(2013, 7, 11, 5, 1, 1), 977479256],
#   [datetime.datetime(2013, 7, 12, 5, 1, 1), 1069724400],
#   [datetime.datetime(2013, 7, 13, 5, 1, 2), 1004551934],
#   [datetime.datetime(2013, 7, 14, 5, 1, 1), 1090715949],
#   [datetime.datetime(2013, 7, 15, 5, 11, 2), 1073073450],
#   [datetime.datetime(2013, 7, 16, 5, 16, 2), 1111179852],
#   [datetime.datetime(2013, 7, 17, 5, 16, 2), 1130735526],
#   [datetime.datetime(2013, 7, 18, 5, 21, 2), 1117707300],
#   [datetime.datetime(2013, 7, 19, 5, 21, 1), 1015062893],
#   [datetime.datetime(2013, 7, 20, 5, 21, 2), 1047311253],
#   [datetime.datetime(2013, 7, 21, 5, 21, 2), 1021492656],
#   [datetime.datetime(2013, 7, 22, 5, 21, 2), 1034399450],
#   [datetime.datetime(2013, 7, 23, 5, 21, 1), 1050054379],
#   [datetime.datetime(2013, 7, 24, 5, 21, 1), 1083333285],
#   [datetime.datetime(2013, 7, 25, 5, 21, 2), 1083076902],
#   [datetime.datetime(2013, 7, 26, 5, 16, 2), 1111232482],
#   [datetime.datetime(2013, 7, 27, 5, 16, 1), 1079278107],
#   [datetime.datetime(2013, 7, 28, 5, 16, 2), 1078286702],
#   [datetime.datetime(2013, 7, 29, 5, 16, 2), 1131111628],
#   [datetime.datetime(2013, 7, 30, 5, 16, 2), 1165105812],
#   [datetime.datetime(2013, 7, 31, 6, 46, 2), 1267183179],
#   [datetime.datetime(2013, 8, 1, 6, 56, 1), 1220481781],
#   [datetime.datetime(2013, 8, 2, 6, 56, 2), 1167849454],
#   [datetime.datetime(2013, 8, 3, 6, 56, 2), 1192378895],
#   [datetime.datetime(2013, 8, 4, 6, 56, 1), 1206152150],
#   [datetime.datetime(2013, 8, 5, 6, 56, 1), 1226188584],
#   [datetime.datetime(2013, 8, 6, 6, 56, 1), 1218425715],
#   [datetime.datetime(2013, 8, 7, 6, 56), 1229098150],
#   [datetime.datetime(2013, 8, 8, 6, 56, 2), 1212383133],
#   [datetime.datetime(2013, 8, 9, 6, 56, 2), 1198290079],
#   [datetime.datetime(2013, 8, 10, 6, 56, 1), 1195703559],
#   [datetime.datetime(2013, 8, 11, 6, 56, 2), 1193835825],
#   [datetime.datetime(2013, 8, 12, 6, 56, 1), 1204979580],
#   [datetime.datetime(2013, 8, 13, 7, 1, 2), 1234277535],
#   [datetime.datetime(2013, 8, 14, 7, 1, 1), 1277045962],
#   [datetime.datetime(2013, 8, 15, 7, 1, 2), 1290791623],
#   [datetime.datetime(2013, 8, 16, 7, 21, 1), 1255999432],
#   [datetime.datetime(2013, 8, 17, 7, 21, 1), 1260549575],
#   [datetime.datetime(2013, 8, 18, 7, 21, 1), 1297725576],
#   [datetime.datetime(2013, 8, 19, 7, 21, 1), 1364305023],
#   [datetime.datetime(2013, 8, 20, 7, 21, 1), 1391744715],
#   [datetime.datetime(2013, 8, 21, 7, 21, 2), 1390017000],
#   [datetime.datetime(2013, 8, 22, 7, 21, 1), 1412622912],
#   [datetime.datetime(2013, 8, 23, 7, 21, 1), 1404948802],
#   [datetime.datetime(2013, 8, 24, 7, 21, 1), 1380248275],
#   [datetime.datetime(2013, 8, 25, 7, 21, 2), 1398134387],
#   [datetime.datetime(2013, 8, 26, 7, 21, 2), 1413720420],
#   [datetime.datetime(2013, 8, 27, 7, 21, 1), 1420013070],
#   [datetime.datetime(2013, 8, 28, 7, 21, 2), 1467696672],
#   [datetime.datetime(2013, 8, 29, 7, 21, 1), 1423401000],
#   [datetime.datetime(2013, 8, 30, 7, 21, 1), 1414493496],
#   [datetime.datetime(2013, 8, 31, 7, 21, 2), 1548720490],
#   [datetime.datetime(2013, 9, 1, 7, 21, 2), 1595008048],
#   [datetime.datetime(2013, 9, 2, 7, 21, 2), 1590732401],
#   [datetime.datetime(2013, 9, 3, 7, 21, 2), 1575707182],
#   [datetime.datetime(2013, 9, 4, 7, 21, 2), 1589775538],
#   [datetime.datetime(2013, 9, 5, 7, 26, 2), 1483451582],
#   [datetime.datetime(2013, 9, 6, 7, 26, 1), 1466648505],
#   [datetime.datetime(2013, 9, 7, 7, 26, 2), 1413398077],
#   [datetime.datetime(2013, 9, 8, 7, 26, 2), 1440475723],
#   [datetime.datetime(2013, 9, 9, 7, 26, 2), 1410546093],
#   [datetime.datetime(2013, 9, 10, 7, 26, 1), 1485885525],
#   [datetime.datetime(2013, 9, 11, 7, 26, 2), 1441952016],
#   [datetime.datetime(2013, 9, 12, 7, 26, 2), 1571991468],
#   [datetime.datetime(2013, 9, 13, 7, 26, 1), 1593705850],
#   [datetime.datetime(2013, 9, 14, 7, 26, 2), 1551266086],
#   [datetime.datetime(2013, 9, 15, 7, 26, 2), 1505159472],
#   [datetime.datetime(2013, 9, 16, 7, 26, 1), 1528329267],
#   [datetime.datetime(2013, 9, 17, 7, 26, 1), 1482235956],
#   [datetime.datetime(2013, 9, 18, 7, 26, 2), 1531472535],
#   [datetime.datetime(2013, 9, 19, 7, 26, 1), 1535810988],
#   [datetime.datetime(2013, 9, 20, 7, 26, 2), 1521198731],
#   [datetime.datetime(2013, 9, 21, 7, 26, 2), 1495076509],
#   [datetime.datetime(2013, 9, 22, 7, 26, 2), 1493833260],
#   [datetime.datetime(2013, 9, 23, 7, 26, 1), 1507154161],
#   [datetime.datetime(2013, 9, 24, 7, 26, 2), 1484371556],
#   [datetime.datetime(2013, 9, 25, 7, 26, 2), 1513805580],
#   [datetime.datetime(2013, 9, 26, 7, 26, 1), 1515403031],
#   [datetime.datetime(2013, 9, 27, 7, 26, 2), 1530763838],
#   [datetime.datetime(2013, 9, 28, 7, 26, 2), 1584338266],
#   [datetime.datetime(2013, 9, 29, 7, 26, 2), 1629791825],
#   [datetime.datetime(2013, 9, 30, 7, 36, 1), 1583038043],
#   [datetime.datetime(2013, 10, 1, 7, 41, 1), 1577869589],
#   [datetime.datetime(2013, 10, 2, 7, 41, 2), 1550425024],
#   [datetime.datetime(2013, 10, 3, 7, 41, 2), 1432992865],
#   [datetime.datetime(2013, 10, 4, 9, 16, 11), 1484790258],
#   [datetime.datetime(2013, 10, 5, 9, 16, 9), 1522400010],
#   [datetime.datetime(2013, 10, 6, 9, 16, 11), 1519707024],
#   [datetime.datetime(2013, 10, 7, 9, 16, 3), 1528242935],
#   [datetime.datetime(2013, 10, 8, 9, 16, 1), 1489210920],
#   [datetime.datetime(2013, 10, 9, 9, 31, 2), 1504666389],
#   [datetime.datetime(2013, 10, 10, 9, 31, 2), 1549185570],
#   [datetime.datetime(2013, 10, 11, 9, 31, 2), 1539049795],
#   [datetime.datetime(2013, 10, 12, 9, 31, 3), 1574653436],
#   [datetime.datetime(2013, 10, 13, 9, 31, 9), 1592076330],
#   [datetime.datetime(2013, 10, 14, 9, 31, 2), 1657780162],
#   [datetime.datetime(2013, 10, 15, 9, 31, 1), 1653892914],
#   [datetime.datetime(2013, 10, 16, 9, 31, 2), 1798515348],
#   [datetime.datetime(2013, 10, 17, 9, 31, 3), 1708762041],
#   [datetime.datetime(2013, 10, 18, 9, 31, 5), 1737727200],
#   [datetime.datetime(2013, 10, 19, 9, 31, 2), 1936429199],
#   [datetime.datetime(2013, 10, 20, 10, 16, 2), 2055254041],
#   [datetime.datetime(2013, 10, 21, 10, 16, 5), 2116153256],
#   [datetime.datetime(2013, 10, 22, 10, 16, 2), 2289446235],
#   [datetime.datetime(2013, 10, 23, 10, 21, 2), 2318122872],
#   [datetime.datetime(2013, 10, 24, 10, 26, 2), 2263880095],
#   [datetime.datetime(2013, 10, 25, 10, 26, 1), 2208910112],
#   [datetime.datetime(2013, 10, 26, 10, 26, 12), 2205330408],
#   [datetime.datetime(2013, 10, 27, 9, 26, 2), 2170590240],
#   [datetime.datetime(2013, 10, 28, 9, 26, 2), 2332560505],
#   [datetime.datetime(2013, 10, 29, 9, 31, 1), 2383514169],
#   [datetime.datetime(2013, 10, 30, 9, 31, 1), 2411927532],
#   [datetime.datetime(2013, 10, 31, 11, 6, 1), 2400527163],
#   [datetime.datetime(2013, 11, 1, 11, 6, 3), 2430860520],
#   [datetime.datetime(2013, 11, 2, 11, 16, 2), 2472401796],
#   [datetime.datetime(2013, 11, 3, 11, 16, 2), 2448338589],
#   [datetime.datetime(2013, 11, 4, 11, 11, 2), 2586286560],
#   [datetime.datetime(2013, 11, 5, 11, 11, 10), 2753961102],
#   [datetime.datetime(2013, 11, 6, 11, 16, 2), 3070437192],
#   [datetime.datetime(2013, 11, 7, 11, 16, 3), 3518670692],
#   [datetime.datetime(2013, 11, 8, 11, 16, 2), 3825919011],
#   [datetime.datetime(2013, 11, 9, 11, 16, 1), 4228079278],
#   [datetime.datetime(2013, 11, 10, 11, 16, 2), 3779710352],
#   [datetime.datetime(2013, 11, 11, 11, 16, 2), 3980634680],
#   [datetime.datetime(2013, 11, 12, 11, 16, 2), 4328310772],
#   [datetime.datetime(2013, 11, 13, 11, 16, 2), 4493672638],
#   [datetime.datetime(2013, 11, 14, 11, 26, 2), 4897827984],
#   [datetime.datetime(2013, 11, 15, 11, 26, 2), 5132926869],
#   [datetime.datetime(2013, 11, 16, 11, 31, 2), 5294532600],
#   [datetime.datetime(2013, 11, 17, 11, 36, 2), 5625255681],
#   [datetime.datetime(2013, 11, 18, 11, 36, 2), 6705789430],
#   [datetime.datetime(2013, 11, 19, 11, 36, 3), 8103857471],
#   [datetime.datetime(2013, 11, 20, 11, 36, 2), 5798258526],
#   [datetime.datetime(2013, 11, 21, 11, 46, 2), 7456358841],
#   [datetime.datetime(2013, 11, 22, 11, 51, 2), 8790506777],
#   [datetime.datetime(2013, 11, 23, 22, 46, 2), 9730337944],
#   [datetime.datetime(2013, 11, 24, 22, 46, 1), 9349295648],
#   [datetime.datetime(2013, 11, 25, 23, 51, 2), 9529002102],
#   [datetime.datetime(2013, 11, 26, 23, 51, 2), 10946018925],
#   [datetime.datetime(2013, 11, 27, 23, 46, 3), 11850638474],
#   [datetime.datetime(2013, 11, 28, 23, 46, 1), 12426552940],
#   [datetime.datetime(2013, 11, 30, 2, 46, 1), 13853313627],
#   [datetime.datetime(2013, 12, 1, 2, 51, 1), 13541896415],
#   [datetime.datetime(2013, 12, 2, 2, 51, 1), 12038665194],
#   [datetime.datetime(2013, 12, 3, 2, 56, 1), 12438459202],
#   [datetime.datetime(2013, 12, 4, 3, 11, 2), 13004931455],
#   [datetime.datetime(2013, 12, 5, 3, 26, 2), 13613383537],
#   [datetime.datetime(2013, 12, 6, 3, 56, 1), 12117660075],
#   [datetime.datetime(2013, 12, 7, 4, 16, 2), 9250920298],
#   [datetime.datetime(2013, 12, 8, 4, 41, 1), 8397879080],
#   [datetime.datetime(2013, 12, 9, 4, 41, 2), 10135632177],
#   [datetime.datetime(2013, 12, 10, 4, 51, 2), 11155612005],
#   [datetime.datetime(2013, 12, 11, 5, 16, 1), 11596135176],
#   [datetime.datetime(2013, 12, 12, 5, 16, 1), 10329286823],
#   [datetime.datetime(2013, 12, 13, 5, 31, 1), 10978301748],
#   [datetime.datetime(2013, 12, 14, 5, 31, 2), 10820630864],
#   [datetime.datetime(2013, 12, 15, 5, 56, 1), 10307643675],
#   [datetime.datetime(2013, 12, 16, 6, 6, 1), 10539143353],
#   [datetime.datetime(2013, 12, 17, 6, 11, 2), 8119114562],
#   [datetime.datetime(2013, 12, 18, 6, 16, 2), 7818203456],
#   [datetime.datetime(2013, 12, 19, 6, 21, 1), 6802839701],
#   [datetime.datetime(2013, 12, 20, 6, 31, 1), 8650071000],
#   [datetime.datetime(2013, 12, 21, 6, 41, 1), 7757993944],
#   [datetime.datetime(2013, 12, 22, 6, 41, 2), 7412626262],
#   [datetime.datetime(2013, 12, 23, 6, 46, 1), 7846531378],
#   [datetime.datetime(2013, 12, 24, 6, 46, 1), 8169016070],
#   [datetime.datetime(2013, 12, 25, 6, 46, 1), 7968482544],
#   [datetime.datetime(2013, 12, 26, 6, 46, 2), 8448510379],
#   [datetime.datetime(2013, 12, 27, 6, 56, 1), 8968234621],
#   [datetime.datetime(2013, 12, 28, 6, 56, 1), 8891737240],
#   [datetime.datetime(2013, 12, 29, 7, 1, 2), 8769072171],
#   [datetime.datetime(2013, 12, 30, 7, 46, 2), 9176209842],
#   [datetime.datetime(2013, 12, 31, 8, 16, 1), 9114650721],
#   [datetime.datetime(2014, 1, 1, 8, 16, 1), 9375027519],
#   [datetime.datetime(2014, 1, 2, 8, 16, 2), 9400260663],
#   [datetime.datetime(2014, 1, 3, 8, 16, 2), 9777538842],
#   [datetime.datetime(2014, 1, 4, 8, 16, 2), 9872620257],
#   [datetime.datetime(2014, 1, 5, 8, 16, 1), 10533192293],
#   [datetime.datetime(2014, 1, 6, 8, 16, 2), 11895294512],
#   [datetime.datetime(2014, 1, 7, 13, 26, 1), 11238639912],
#   [datetime.datetime(2014, 1, 8, 13, 26, 2), 10489937497],
#   [datetime.datetime(2014, 1, 9, 13, 26, 1), 10291198407],
#   [datetime.datetime(2014, 1, 10, 13, 26, 1), 10235909453],
#   [datetime.datetime(2014, 1, 11, 13, 26, 1), 11120838747],
#   [datetime.datetime(2014, 1, 12, 13, 26, 1), 10579385547],
#   [datetime.datetime(2014, 1, 13, 13, 26, 2), 10236131169],
#   [datetime.datetime(2014, 1, 14, 13, 26, 2), 10257005161],
#   [datetime.datetime(2014, 1, 15, 13, 26, 2), 10586901588],
#   [datetime.datetime(2014, 1, 16, 14, 31, 2), 10466816554],
#   [datetime.datetime(2014, 1, 17, 14, 41, 2), 10118464372],
#   [datetime.datetime(2014, 1, 18, 14, 41, 2), 10293545616],
#   [datetime.datetime(2014, 1, 19, 15, 11, 2), 10240441312],
#   [datetime.datetime(2014, 1, 20, 15, 11, 2), 10634404659],
#   [datetime.datetime(2014, 1, 21, 15, 16, 2), 10660106725],
#   [datetime.datetime(2014, 1, 22, 18, 21, 2), 10407022515],
#   [datetime.datetime(2014, 1, 23, 18, 31, 2), 10192103437],
#   [datetime.datetime(2014, 1, 24, 18, 31, 2), 9875571598],
#   [datetime.datetime(2014, 1, 25, 18, 31, 2), 10468361227],
#   [datetime.datetime(2014, 1, 26, 18, 31, 2), 10966151300],
#   [datetime.datetime(2014, 1, 27, 21, 31, 2), 9896706963],
#   [datetime.datetime(2014, 1, 28, 21, 36, 2), 10030077450],
#   [datetime.datetime(2014, 1, 29, 21, 51, 2), 10174460328],
#   [datetime.datetime(2014, 1, 30, 21, 51, 2), 10105458986],
#   [datetime.datetime(2014, 1, 31, 21, 51, 2), 10153617765],
#   [datetime.datetime(2014, 2, 1, 21, 51, 2), 10391760101],
#   [datetime.datetime(2014, 2, 2, 21, 51, 2), 10241496932],
#   [datetime.datetime(2014, 2, 3, 21, 56, 2), 10117201297],
#   [datetime.datetime(2014, 2, 4, 22, 31, 2), 10268668985],
#   [datetime.datetime(2014, 2, 5, 22, 36, 2), 10152548463],
#   [datetime.datetime(2014, 2, 6, 22, 36, 3), 9682805649],
#   [datetime.datetime(2014, 2, 7, 22, 36, 5), 8977470788],
#   [datetime.datetime(2014, 2, 8, 22, 36, 5), 8503248112],
#   [datetime.datetime(2014, 2, 9, 22, 41, 2), 8568588480],
#   [datetime.datetime(2014, 2, 10, 22, 46, 2), 8273521358],
#   [datetime.datetime(2014, 2, 11, 23, 1, 13), 7902678666],
#   [datetime.datetime(2014, 2, 13, 4, 6, 2), 8103210317],
#   [datetime.datetime(2014, 2, 14, 4, 6, 7), 6981872578],
#   [datetime.datetime(2014, 2, 15, 4, 11, 13), 7991142081],
#   [datetime.datetime(2014, 2, 16, 4, 11, 10), 8166740022],
#   [datetime.datetime(2014, 2, 17, 4, 21, 22), 7645657217],
#   [datetime.datetime(2014, 2, 18, 4, 21, 45), 7963598356],
#   [datetime.datetime(2014, 2, 19, 4, 26, 2), 7763582295],
#   [datetime.datetime(2014, 2, 20, 4, 31, 2), 7765481646],
#   [datetime.datetime(2014, 2, 21, 4, 41, 22), 6824404453],
#   [datetime.datetime(2014, 2, 22, 4, 46, 2), 7053173750],
#   [datetime.datetime(2014, 2, 23, 4, 46, 2), 7630472818],
#   [datetime.datetime(2014, 2, 24, 4, 46, 2), 7195562323],
#   [datetime.datetime(2014, 2, 25, 4, 46, 2), 6195879609],
#   [datetime.datetime(2014, 2, 26, 5, 36, 9), 7013767152],
#   [datetime.datetime(2014, 2, 27, 5, 51, 2), 7239905721],
#   [datetime.datetime(2014, 2, 28, 5, 56, 2), 7115937422],
#   [datetime.datetime(2014, 3, 1, 6, 6, 2), 6955268689],
#   [datetime.datetime(2014, 3, 2, 6, 6, 5), 6992425456],
#   [datetime.datetime(2014, 3, 3, 6, 6, 2), 7150284539],
#   [datetime.datetime(2014, 3, 4, 7, 6, 23), 8257065652],
#   [datetime.datetime(2014, 3, 5, 9, 6, 1), 8280089523],
#   [datetime.datetime(2014, 3, 6, 9, 41, 1), 8267403750],
#   [datetime.datetime(2014, 3, 7, 9, 51, 23), 8179264894],
#   [datetime.datetime(2014, 3, 8, 9, 56, 2), 7766677880],
#   [datetime.datetime(2014, 3, 9, 9, 56, 2), 7774864760],
#   [datetime.datetime(2014, 3, 10, 9, 56, 21), 7987727962],
#   [datetime.datetime(2014, 3, 11, 9, 56, 2), 7883390766],
#   [datetime.datetime(2014, 3, 12, 9, 56, 2), 7948515121],
#   [datetime.datetime(2014, 3, 13, 9, 56, 2), 8003678580],
#   [datetime.datetime(2014, 3, 14, 10, 31, 2), 7923870033],
#   [datetime.datetime(2014, 3, 15, 10, 31, 2), 7908582117],
#   [datetime.datetime(2014, 3, 16, 10, 31, 2), 7943849911],
#   [datetime.datetime(2014, 3, 17, 10, 31, 2), 7794370518],
#   [datetime.datetime(2014, 3, 18, 10, 31, 2), 7729983328],
#   [datetime.datetime(2014, 3, 19, 10, 41, 17), 7732059879],
#   [datetime.datetime(2014, 3, 20, 10, 41, 2), 7568383029],
#   [datetime.datetime(2014, 3, 21, 10, 36, 2), 7531941604],
#   [datetime.datetime(2014, 3, 22, 10, 36, 3), 7096672519],
#   [datetime.datetime(2014, 3, 23, 10, 36, 2), 7116284105],
#   [datetime.datetime(2014, 3, 24, 10, 46, 2), 6983197243],
#   [datetime.datetime(2014, 3, 25, 10, 46, 3), 7197165743],
#   [datetime.datetime(2014, 3, 26, 13, 46, 2), 7343002343],
#   [datetime.datetime(2014, 3, 27, 19, 26, 1), 6564587596],
#   [datetime.datetime(2014, 3, 28, 21, 41, 2), 6177467010],
#   [datetime.datetime(2014, 3, 30, 4, 11, 2), 6108104221],
#   [datetime.datetime(2014, 3, 31, 4, 46, 2), 5995761080],
#   [datetime.datetime(2014, 4, 1, 4, 46, 2), 5772747763],
#   [datetime.datetime(2014, 4, 2, 5, 16, 2), 6062248781],
#   [datetime.datetime(2014, 4, 3, 5, 41, 3), 5381332964],
#   [datetime.datetime(2014, 4, 4, 5, 46, 2), 5505654176],
#   [datetime.datetime(2014, 4, 5, 5, 46, 2), 5698723917],
#   [datetime.datetime(2014, 4, 6, 5, 46, 2), 5856585232],
#   [datetime.datetime(2014, 4, 7, 5, 46, 2), 5746822291],
#   [datetime.datetime(2014, 4, 8, 5, 46, 2), 5718542737],
#   [datetime.datetime(2014, 4, 9, 6, 11, 3), 5738904084],
#   [datetime.datetime(2014, 4, 10, 6, 16, 2), 5400810410],
#   [datetime.datetime(2014, 4, 11, 6, 16, 3), 4823150267],
#   [datetime.datetime(2014, 4, 12, 6, 16, 3), 5535166815],
#   [datetime.datetime(2014, 4, 13, 6, 16, 2), 5370397396],
#   [datetime.datetime(2014, 4, 14, 6, 16, 2), 5176894908],
#   [datetime.datetime(2014, 4, 15, 6, 26, 2), 5759489398],
#   [datetime.datetime(2014, 4, 16, 6, 46, 2), 6524134861],
#   [datetime.datetime(2014, 4, 17, 6, 51, 2), 6575226952],
#   [datetime.datetime(2014, 4, 18, 7, 1, 2), 6252223023],
#   [datetime.datetime(2014, 4, 19, 7, 1, 2), 5975968814],
#   [datetime.datetime(2014, 4, 20, 7, 1, 2), 6393006503],
#   [datetime.datetime(2014, 4, 21, 7, 1, 3), 6435488891],
#   [datetime.datetime(2014, 4, 22, 7, 6, 2), 6322029639],
#   [datetime.datetime(2014, 4, 23, 7, 6, 2), 6226287188],
#   [datetime.datetime(2014, 4, 24, 7, 41, 2), 6195771518],
#   [datetime.datetime(2014, 4, 25, 8, 31, 4), 5790307676],
#   [datetime.datetime(2014, 4, 26, 8, 46, 2), 5733379123],
#   [datetime.datetime(2014, 4, 27, 9, 11, 2), 5788410979],
#   [datetime.datetime(2014, 4, 28, 9, 36, 2), 5407456652],
#   [datetime.datetime(2014, 4, 29, 14, 16, 2), 5685695339],
#   [datetime.datetime(2014, 4, 30, 17, 26, 2), 5673077338],
#   [datetime.datetime(2014, 5, 1, 17, 26, 3), 5731664211],
#   [datetime.datetime(2014, 5, 2, 17, 26, 2), 5666988895],
#   [datetime.datetime(2014, 5, 3, 17, 26, 5), 5610505365],
#   [datetime.datetime(2014, 5, 4, 17, 26, 5), 5517588612],
#   [datetime.datetime(2014, 5, 5, 17, 26, 6), 5473840871],
#   [datetime.datetime(2014, 5, 6, 18, 1, 5), 5487874929],
#   [datetime.datetime(2014, 5, 7, 18, 1, 7), 5607924965],
#   [datetime.datetime(2014, 5, 8, 18, 1, 20), 5626345356],
#   [datetime.datetime(2014, 5, 9, 18, 41, 16), 5741033790],
#   [datetime.datetime(2014, 5, 10, 18, 41, 6), 5754552853],
#   [datetime.datetime(2014, 5, 11, 18, 41, 7), 5528484826],
#   [datetime.datetime(2014, 5, 12, 18, 41, 10), 5630703159],
#   [datetime.datetime(2014, 5, 13, 18, 41, 13), 5614371662],
#   [datetime.datetime(2014, 5, 14, 18, 51, 16), 5673690624],
#   [datetime.datetime(2014, 5, 15, 18, 51, 7), 5724581374],
#   [datetime.datetime(2014, 5, 16, 18, 51, 10), 5730560632],
#   [datetime.datetime(2014, 5, 17, 18, 51, 6), 5724920041],
#   [datetime.datetime(2014, 5, 18, 18, 51, 8), 5716510660],
#   [datetime.datetime(2014, 5, 19, 18, 51, 17), 5692061490],
#   [datetime.datetime(2014, 5, 20, 18, 51, 15), 6183365788],
#   [datetime.datetime(2014, 5, 21, 19, 6, 17), 6298351579],
#   [datetime.datetime(2014, 5, 22, 19, 6, 20), 6609931274],
#   [datetime.datetime(2014, 5, 23, 19, 6, 9), 6700336553],
#   [datetime.datetime(2014, 5, 25, 7, 56, 6), 7115204096],
#   [datetime.datetime(2014, 5, 26, 7, 56, 10), 7521273634],
#   [datetime.datetime(2014, 5, 27, 8, 41, 13), 7497455615],
#   [datetime.datetime(2014, 5, 28, 8, 41, 5), 7382028997],
#   [datetime.datetime(2014, 5, 29, 8, 41, 16), 7269497761],
#   [datetime.datetime(2014, 5, 30, 8, 56, 7), 7305732162],
#   [datetime.datetime(2014, 5, 31, 8, 56, 7), 7920661529],
#   [datetime.datetime(2014, 6, 1, 8, 56, 13), 8325584400],
#   [datetime.datetime(2014, 6, 2, 8, 56, 6), 8004231903],
#   [datetime.datetime(2014, 6, 3, 8, 56, 7), 8443853248],
#   [datetime.datetime(2014, 6, 4, 8, 56, 6), 8213918062],
#   [datetime.datetime(2014, 6, 5, 9, 41, 6), 8306258433],
#   [datetime.datetime(2014, 6, 6, 9, 41, 5), 8453788890],
#   [datetime.datetime(2014, 6, 7, 9, 41, 7), 8398066511],
#   [datetime.datetime(2014, 6, 8, 9, 41, 6), 8461802884],
#   [datetime.datetime(2014, 6, 9, 9, 41, 6), 8332939692],
#   [datetime.datetime(2014, 6, 10, 9, 41, 5), 8472890038],
#   [datetime.datetime(2014, 6, 11, 9, 41, 9), 8374495671],
#   [datetime.datetime(2014, 6, 12, 10, 26, 6), 8202725168],
#   [datetime.datetime(2014, 6, 13, 10, 26, 9), 7874556522],
#   [datetime.datetime(2014, 6, 14, 10, 26, 7), 7540155635],
#   [datetime.datetime(2014, 6, 15, 10, 26, 7), 7215495816],
#   [datetime.datetime(2014, 6, 16, 10, 26, 7), 7737782349],
#   [datetime.datetime(2014, 6, 17, 10, 26, 11), 7698607587],
#   [datetime.datetime(2014, 6, 18, 10, 26, 8), 7907048530],
#   [datetime.datetime(2014, 6, 19, 10, 26, 7), 7879526986],
#   [datetime.datetime(2014, 6, 20, 10, 26, 8), 7615404520],
#   [datetime.datetime(2014, 6, 21, 10, 26, 7), 7648148389],
#   [datetime.datetime(2014, 6, 22, 10, 26, 10), 7816412859],
#   [datetime.datetime(2014, 6, 23, 10, 26, 7), 7678243878],
#   [datetime.datetime(2014, 6, 24, 11, 31, 6), 7688879009],
#   [datetime.datetime(2014, 6, 25, 13, 1, 15), 7398086370],
#   [datetime.datetime(2014, 6, 26, 22, 6, 10), 7423820740],
#   [datetime.datetime(2014, 6, 27, 23, 11, 7), 7577314829],
#   [datetime.datetime(2014, 6, 29, 8, 46, 12), 7788118206],
#   [datetime.datetime(2014, 6, 30, 10, 21, 39), 8122165800],
#   [datetime.datetime(2014, 7, 1, 10, 21, 12), 8486436757],
#   [datetime.datetime(2014, 7, 2, 15, 21, 13), 8372715704],
#   [datetime.datetime(2014, 7, 3, 19, 16, 8), 8371823420],
#   [datetime.datetime(2014, 7, 5, 3, 21, 11), 8200025844],
#   [datetime.datetime(2014, 7, 6, 19, 6, 11), 8244355335],
#   [datetime.datetime(2014, 7, 8, 12, 24), 8082395595],
#   [datetime.datetime(2014, 7, 9, 16, 14), 8116882102],
#   [datetime.datetime(2014, 7, 10, 16, 14), 7986870811],
#   [datetime.datetime(2014, 7, 11, 16, 14), 8183210066],
#   [datetime.datetime(2014, 7, 12, 16, 14), 8177509169],
#   [datetime.datetime(2014, 7, 13, 16, 14), 8186803751],
#   [datetime.datetime(2014, 7, 14, 16, 14), 8070258638],
#   [datetime.datetime(2014, 7, 15, 16, 14), 8122773091],
#   [datetime.datetime(2014, 7, 16, 16, 14), 8032529722],
#   [datetime.datetime(2014, 7, 17, 16, 14), 8078882611],
#   [datetime.datetime(2014, 7, 18, 16, 14), 8092787472],
#   [datetime.datetime(2014, 7, 19, 16, 14), 8188922459],
#   [datetime.datetime(2014, 7, 20, 16, 14), 8151474297],
#   [datetime.datetime(2014, 7, 21, 16, 14), 8094123825],
#   [datetime.datetime(2014, 7, 22, 16, 24), 8116705702],
#   [datetime.datetime(2014, 7, 23, 16, 24), 8130867361],
#   [datetime.datetime(2014, 7, 24, 16, 24), 7849214803],
#   [datetime.datetime(2014, 7, 25, 16, 24), 7859391788],
#   [datetime.datetime(2014, 7, 26, 16, 24), 7809989668],
#   [datetime.datetime(2014, 7, 27, 16, 24), 7809272562],
#   [datetime.datetime(2014, 7, 28, 17, 24), 7612339560],
#   [datetime.datetime(2014, 7, 29, 17, 24), 7631643297],
#   [datetime.datetime(2014, 7, 30, 19, 4), 7544687880],
#   [datetime.datetime(2014, 7, 31, 19, 4), 7660237144],
#   [datetime.datetime(2014, 8, 1, 19, 24), 7814990816],
#   [datetime.datetime(2014, 8, 2, 19, 54), 7712307360],
#   [datetime.datetime(2014, 8, 3, 19, 54), 7681992598],
#   [datetime.datetime(2014, 8, 4, 19, 54), 7725064932],
#   [datetime.datetime(2014, 8, 5, 19, 54), 7684065312],
#   [datetime.datetime(2014, 8, 6, 19, 54), 7689070836],
#   [datetime.datetime(2014, 8, 7, 19, 54), 7730980003],
#   [datetime.datetime(2014, 8, 8, 19, 54), 7778019496],
#   [datetime.datetime(2014, 8, 9, 19, 54), 7733676906],
#   [datetime.datetime(2014, 8, 10, 19, 54), 7747817534],
#   [datetime.datetime(2014, 8, 11, 19, 54), 7620587697],
#   [datetime.datetime(2014, 8, 12, 19, 54), 7479211448],
#   [datetime.datetime(2014, 8, 13, 19, 54), 7089371399],
#   [datetime.datetime(2014, 8, 14, 19, 54), 6788369159],
#   [datetime.datetime(2014, 8, 15, 19, 54), 6486612775],
#   [datetime.datetime(2014, 8, 16, 19, 54), 6657817457],
#   [datetime.datetime(2014, 8, 17, 19, 54), 6472897218],
#   [datetime.datetime(2014, 8, 18, 19, 54), 6052765876],
#   [datetime.datetime(2014, 8, 19, 19, 54), 6284411752],
#   [datetime.datetime(2014, 8, 20, 19, 54), 6636746619],
#   [datetime.datetime(2014, 8, 21, 19, 54), 6915078697],
#   [datetime.datetime(2014, 8, 22, 19, 54), 6819752408],
#   [datetime.datetime(2014, 8, 23, 19, 54), 6605512916],
#   [datetime.datetime(2014, 8, 24, 19, 54), 6741579651],
#   [datetime.datetime(2014, 8, 25, 19, 54), 6624449236],
#   [datetime.datetime(2014, 8, 26, 19, 54), 6751116840],
#   [datetime.datetime(2014, 8, 27, 19, 54), 6758242708],
#   [datetime.datetime(2014, 8, 28, 19, 54), 6705996985],
#   [datetime.datetime(2014, 8, 29, 19, 54), 6738232487],
#   [datetime.datetime(2014, 8, 30, 19, 54), 6663734161],
#   [datetime.datetime(2014, 8, 31, 19, 54), 6278177305],
#   [datetime.datetime(2014, 9, 1, 19, 54), 6367932182],
#   [datetime.datetime(2014, 9, 2, 20, 4), 6380356629],
#   [datetime.datetime(2014, 9, 3, 20, 4), 6309823001],
#   [datetime.datetime(2014, 9, 4, 20, 4), 6457360244],
#   [datetime.datetime(2014, 9, 5, 20, 4), 6413157070],
#   [datetime.datetime(2014, 9, 6, 20, 4), 6453564668],
#   [datetime.datetime(2014, 9, 7, 20, 4), 6428513158],
#   [datetime.datetime(2014, 9, 8, 20, 24), 6343771471],
#   [datetime.datetime(2014, 9, 9, 20, 24), 6253035610],
#   [datetime.datetime(2014, 9, 10, 20, 24), 6421968408],
#   [datetime.datetime(2014, 9, 11, 20, 24), 6290813167],
#   [datetime.datetime(2014, 9, 12, 20, 24), 6312730888],
#   [datetime.datetime(2014, 9, 13, 20, 24), 6376536644],
#   [datetime.datetime(2014, 9, 14, 20, 24), 6337916584],
#   [datetime.datetime(2014, 9, 15, 20, 24), 6327753377],
#   [datetime.datetime(2014, 9, 16, 20, 24), 6236932009],
#   [datetime.datetime(2014, 9, 17, 20, 24), 6027243652],
#   [datetime.datetime(2014, 9, 18, 20, 24), 5649055634],
#   [datetime.datetime(2014, 9, 19, 20, 23, 59), 5301224275],
#   [datetime.datetime(2014, 9, 20, 20, 24), 5488274967],
#   [datetime.datetime(2014, 9, 21, 20, 24), 5349780133],
#   [datetime.datetime(2014, 9, 22, 20, 23, 59), 5349470436],
#   [datetime.datetime(2014, 9, 23, 20, 24), 5786438777],
#   [datetime.datetime(2014, 9, 24, 20, 33, 59), 5708169478],
#   [datetime.datetime(2014, 9, 25, 20, 33, 59), 5466497281],
#   [datetime.datetime(2014, 9, 26, 20, 34), 5389223696],
#   [datetime.datetime(2014, 9, 27, 20, 34), 5306694358],
#   [datetime.datetime(2014, 9, 28, 20, 33, 59), 5078204546],
#   [datetime.datetime(2014, 9, 29, 20, 33, 59), 5081242480],
#   [datetime.datetime(2014, 9, 30, 20, 33, 59), 5119427674],
#   [datetime.datetime(2014, 10, 2, 8, 39), 5127402572],
#   [datetime.datetime(2014, 10, 3, 8, 38, 59), 5019403319],
#   [datetime.datetime(2014, 10, 4, 9, 44), 4785192805],
#   [datetime.datetime(2014, 10, 5, 9, 44), 4379135932],
#   [datetime.datetime(2014, 10, 6, 9, 44), 4291300659],
#   [datetime.datetime(2014, 10, 7, 9, 44), 4366348702],
#   [datetime.datetime(2014, 10, 8, 9, 44), 4451575734],
#   [datetime.datetime(2014, 10, 9, 9, 44, 5), 4771503789],
#   [datetime.datetime(2014, 10, 10, 9, 44), 4961717589],
#   [datetime.datetime(2014, 10, 11, 9, 44), 4841471420],
#   [datetime.datetime(2014, 10, 12, 9, 44), 4828147412],
#   [datetime.datetime(2014, 10, 13, 9, 44), 4985678637],
#   [datetime.datetime(2014, 10, 14, 9, 44), 5418971888],
#   [datetime.datetime(2014, 10, 15, 9, 44), 5328846153],
#   [datetime.datetime(2014, 10, 16, 9, 44), 5265674038],
#   [datetime.datetime(2014, 10, 17, 9, 49), 5137917706],
#   [datetime.datetime(2014, 10, 18, 9, 49), 5105109931],
#   [datetime.datetime(2014, 10, 19, 9, 49), 5264196242],
#   [datetime.datetime(2014, 10, 20, 9, 49), 5134201081],
#   [datetime.datetime(2014, 10, 21, 9, 49), 5155910228],
#   [datetime.datetime(2014, 10, 22, 9, 49), 5188468568],
#   [datetime.datetime(2014, 10, 23, 9, 49), 5000114789],
#   [datetime.datetime(2014, 10, 24, 9, 49), 4821642992],
#   [datetime.datetime(2014, 10, 25, 9, 49), 4748461382],
#   [datetime.datetime(2014, 10, 26, 8, 49), 4741037489],
#   [datetime.datetime(2014, 10, 27, 8, 49), 4733130351],
#   [datetime.datetime(2014, 10, 28, 8, 49), 4801110716],
#   [datetime.datetime(2014, 10, 29, 8, 49), 4799952434],
#   [datetime.datetime(2014, 10, 30, 8, 49), 4569673152],
#   [datetime.datetime(2014, 10, 31, 8, 49, 2), 4645027482],
#   [datetime.datetime(2014, 11, 1, 9, 24), 4427422040],
#   [datetime.datetime(2014, 11, 2, 10, 24), 4372078851],
#   [datetime.datetime(2014, 11, 3, 10, 24), 4449114450],
#   [datetime.datetime(2014, 11, 4, 10, 24), 4391372099],
#   [datetime.datetime(2014, 11, 5, 10, 24), 4533581386],
#   [datetime.datetime(2014, 11, 6, 10, 24), 4584887384],
#   [datetime.datetime(2014, 11, 7, 10, 24), 4683921008],
#   [datetime.datetime(2014, 11, 8, 10, 24), 4629267445],
#   [datetime.datetime(2014, 11, 9, 10, 24), 4706558009],
#   [datetime.datetime(2014, 11, 10, 10, 24), 4853718859],
#   [datetime.datetime(2014, 11, 11, 10, 24), 4961414266],
#   [datetime.datetime(2014, 11, 12, 10, 24), 5108311016],
#   [datetime.datetime(2014, 11, 13, 10, 24), 5914680527],
#   [datetime.datetime(2014, 11, 14, 10, 24), 5196704404],
#   [datetime.datetime(2014, 11, 15, 10, 24), 5335673913],
#   [datetime.datetime(2014, 11, 16, 10, 24), 5224946837],
#   [datetime.datetime(2014, 11, 17, 10, 24), 5535651238],
#   [datetime.datetime(2014, 11, 18, 10, 24), 5186840088],
#   [datetime.datetime(2014, 11, 19, 10, 24), 5183709300],
#   [datetime.datetime(2014, 11, 20, 10, 24), 4934113776],
#   [datetime.datetime(2014, 11, 21, 10, 24), 4775347316],
#   [datetime.datetime(2014, 11, 22, 10, 24), 4851718884],
#   [datetime.datetime(2014, 11, 23, 10, 24), 4831481373],
#   [datetime.datetime(2014, 11, 24, 10, 24), 5069710284],
#   [datetime.datetime(2014, 11, 25, 10, 24), 5323052593],
#   [datetime.datetime(2014, 11, 26, 10, 34), 4998261122],
#   [datetime.datetime(2014, 11, 27, 10, 34), 5043398583],
#   [datetime.datetime(2014, 11, 28, 10, 34), 4921394189],
#   [datetime.datetime(2014, 11, 29, 10, 34), 5135280662],
#   [datetime.datetime(2014, 11, 30, 10, 34), 5165277474],
#   [datetime.datetime(2014, 12, 1, 10, 34), 5152575062],
#   [datetime.datetime(2014, 12, 2, 10, 34), 5167497278],
#   [datetime.datetime(2014, 12, 3, 10, 34), 5105225558],
#   [datetime.datetime(2014, 12, 4, 10, 34), 5098196759],
#   [datetime.datetime(2014, 12, 5, 10, 34), 5062365576],
#   [datetime.datetime(2014, 12, 6, 10, 34), 5084317689],
#   [datetime.datetime(2014, 12, 7, 10, 34), 5091085165],
#   [datetime.datetime(2014, 12, 8, 10, 34, 1), 4980925017],
#   [datetime.datetime(2014, 12, 9, 10, 34), 4765826202],
#   [datetime.datetime(2014, 12, 10, 10, 34), 4757842918],
#   [datetime.datetime(2014, 12, 11, 18, 19), 4848542429],
#   [datetime.datetime(2014, 12, 14, 2, 14), 4715148005],
#   [datetime.datetime(2014, 12, 15, 2, 14), 4778612471],
#   [datetime.datetime(2014, 12, 16, 2, 14), 4701943395],
#   [datetime.datetime(2014, 12, 17, 2, 19), 4547100966],
#   [datetime.datetime(2014, 12, 18, 2, 19), 4377434370],
#   [datetime.datetime(2014, 12, 19, 2, 19), 4242268348],
#   [datetime.datetime(2014, 12, 20, 2, 19), 4314356389],
#   [datetime.datetime(2014, 12, 21, 2, 19), 4482512994],
#   [datetime.datetime(2014, 12, 22, 2, 19), 4389948813],
#   [datetime.datetime(2014, 12, 23, 2, 19, 1), 4542880267],
#   [datetime.datetime(2014, 12, 24, 2, 19), 4559253562],
#   [datetime.datetime(2014, 12, 25, 2, 19), 4339886866],
#   [datetime.datetime(2014, 12, 26, 2, 19, 1), 4337524254],
#   [datetime.datetime(2014, 12, 27, 2, 19, 1), 4435289409],
#   [datetime.datetime(2014, 12, 28, 2, 19, 1), 4322830391],
#   [datetime.datetime(2014, 12, 29, 2, 19), 4369189647],
#   [datetime.datetime(2014, 12, 30, 2, 19), 4290788757],
#   [datetime.datetime(2014, 12, 31, 2, 19, 1), 4245280800],
#   [datetime.datetime(2015, 1, 1, 2, 19, 1), 4345601963],
#   [datetime.datetime(2015, 1, 2, 2, 19), 4289287759],
#   [datetime.datetime(2015, 1, 3, 2, 19), 4307374369],
#   [datetime.datetime(2015, 1, 4, 2, 19), 3848549170],
#   [datetime.datetime(2015, 1, 5, 2, 19, 1), 3650984440],
#   [datetime.datetime(2015, 1, 6, 2, 19, 1), 3753949381],
#   [datetime.datetime(2015, 1, 7, 2, 19, 1), 3879255971],
#   [datetime.datetime(2015, 1, 8, 2, 19), 4024290266],
#   [datetime.datetime(2015, 1, 9, 2, 19, 1), 3871292298],
#   [datetime.datetime(2015, 1, 10, 10, 59, 1), 3808946374],
#   [datetime.datetime(2015, 1, 11, 10, 59, 1), 3766686283],
#   [datetime.datetime(2015, 1, 12, 10, 59, 1), 3675616212],
#   [datetime.datetime(2015, 1, 13, 10, 59, 1), 3355188725],
#   [datetime.datetime(2015, 1, 14, 10, 59, 1), 2851633026],
#   [datetime.datetime(2015, 1, 15, 10, 59, 1), 2813068301],
#   [datetime.datetime(2015, 1, 16, 10, 59, 1), 2994329454],
#   [datetime.datetime(2015, 1, 17, 10, 59, 1), 2708756783],
#   [datetime.datetime(2015, 1, 18, 10, 59, 1), 2891839558],
#   [datetime.datetime(2015, 1, 19, 10, 59, 1), 2861871773],
#   [datetime.datetime(2015, 1, 20, 10, 59, 1), 2877924232],
#   [datetime.datetime(2015, 1, 21, 10, 59), 2937610959],
#   [datetime.datetime(2015, 1, 22, 10, 59, 1), 3175391943],
#   [datetime.datetime(2015, 1, 23, 10, 59, 1), 3117289084],
#   [datetime.datetime(2015, 1, 24, 10, 59), 3204386274],
#   [datetime.datetime(2015, 1, 25, 10, 59, 1), 3389816225],
#   [datetime.datetime(2015, 1, 26, 10, 59, 1), 4120903457],
#   [datetime.datetime(2015, 1, 27, 10, 59), 3554872118],
#   [datetime.datetime(2015, 1, 28, 10, 59, 1), 3610527384],
#   [datetime.datetime(2015, 1, 29, 10, 59, 1), 3174116640],
#   [datetime.datetime(2015, 1, 30, 10, 59, 1), 3207876399],
#   [datetime.datetime(2015, 1, 31, 10, 59, 1), 3197785951],
#   [datetime.datetime(2015, 2, 1, 11, 9, 1), 2932754485],
#   [datetime.datetime(2015, 2, 2, 11, 9, 20), 3098862238],
#   [datetime.datetime(2015, 2, 3, 11, 9, 21), 3304247798],
#   [datetime.datetime(2015, 2, 4, 11, 14, 19), 3084186083],
#   [datetime.datetime(2015, 2, 5, 11, 14, 19), 3118027956],
#   [datetime.datetime(2015, 2, 6, 11, 14, 20), 3021929922],
#   [datetime.datetime(2015, 2, 7, 11, 14, 25), 3161297986],
#   [datetime.datetime(2015, 2, 8, 11, 14, 20), 3141965896],
#   [datetime.datetime(2015, 2, 9, 11, 14, 20), 3074677811],
#   [datetime.datetime(2015, 2, 10, 11, 19, 20), 2991226156],
#   [datetime.datetime(2015, 2, 11, 11, 19, 20), 3049515934],
#   [datetime.datetime(2015, 2, 12, 11, 19, 20), 3030286962],
#   [datetime.datetime(2015, 2, 13, 11, 19, 21), 3248286280],
#   [datetime.datetime(2015, 2, 14, 11, 19, 21), 3429086744],
#   [datetime.datetime(2015, 2, 15, 11, 24, 22), 3636040558],
#   [datetime.datetime(2015, 2, 16, 11, 29, 20), 3288133689],
#   [datetime.datetime(2015, 2, 17, 11, 29, 19), 3291510942],
#   [datetime.datetime(2015, 2, 18, 11, 29, 20), 3346731825],
#   [datetime.datetime(2015, 2, 19, 11, 29, 19), 3281224349],
#   [datetime.datetime(2015, 2, 20, 11, 29, 22), 3411751633],
#   [datetime.datetime(2015, 2, 21, 11, 29, 20), 3380093375],
#   [datetime.datetime(2015, 2, 22, 11, 44, 19), 3400132507],
#   [datetime.datetime(2015, 2, 23, 11, 44, 20), 3253406963],
#   [datetime.datetime(2015, 2, 24, 11, 44, 20), 3282405035],
#   [datetime.datetime(2015, 2, 25, 11, 44, 21), 3272446748],
#   [datetime.datetime(2015, 2, 26, 11, 44, 20), 3278060208],
#   [datetime.datetime(2015, 2, 27, 11, 44, 19), 3496113393],
#   [datetime.datetime(2015, 2, 28, 13, 44, 19), 3511637500],
#   [datetime.datetime(2015, 3, 1, 13, 44, 20), 3418854940],
#   [datetime.datetime(2015, 3, 2, 13, 44, 20), 3596686084],
#   [datetime.datetime(2015, 3, 3, 13, 44, 20), 3757039683],
#   [datetime.datetime(2015, 3, 4, 19, 29, 19), 3921472230],
#   [datetime.datetime(2015, 3, 5, 19, 34, 20), 3715418089],
#   [datetime.datetime(2015, 3, 6, 19, 34, 19), 3771089115],
#   [datetime.datetime(2015, 3, 7, 19, 39, 20), 3842565008],
#   [datetime.datetime(2015, 3, 8, 19, 39, 21), 3824308700],
#   [datetime.datetime(2015, 3, 9, 19, 49, 19), 3990421912],
#   [datetime.datetime(2015, 3, 10, 19, 54, 19), 4110333413],
#   [datetime.datetime(2015, 3, 11, 19, 54, 19), 4125292446],
#   [datetime.datetime(2015, 3, 12, 19, 54, 20), 4131676728],
#   [datetime.datetime(2015, 3, 13, 19, 59, 20), 4009506313],
#   [datetime.datetime(2015, 3, 14, 20, 4, 20), 3944860422],
#   [datetime.datetime(2015, 3, 15, 20, 4, 21), 3962828226],
#   [datetime.datetime(2015, 3, 16, 20, 4, 22), 4058871698],
#   [datetime.datetime(2015, 3, 17, 20, 4, 22), 4017292623],
#   [datetime.datetime(2015, 3, 18, 20, 4, 22), 3723705566],
#   [datetime.datetime(2015, 3, 19, 20, 9, 21), 3626492241],
#   [datetime.datetime(2015, 3, 20, 20, 14, 21), 3639131051],
#   [datetime.datetime(2015, 3, 21, 20, 19, 21), 3637526863],
#   [datetime.datetime(2015, 3, 22, 20, 19, 21), 3669968700],
#   [datetime.datetime(2015, 3, 23, 20, 19, 22), 3676053749],
#   [datetime.datetime(2015, 3, 24, 20, 19, 22), 3448861669],
#   [datetime.datetime(2015, 3, 25, 20, 19, 22), 3426432676],
#   [datetime.datetime(2015, 3, 26, 20, 19, 19), 3541436382],
#   [datetime.datetime(2015, 3, 27, 20, 19, 21), 3474922114],
#   [datetime.datetime(2015, 3, 28, 20, 19, 21), 3521673717],
#   [datetime.datetime(2015, 3, 29, 21, 44, 21), 3426239160],
#   [datetime.datetime(2015, 3, 30, 23, 29, 19), 3469694824],
#   [datetime.datetime(2015, 3, 31, 23, 54, 22), 3438997948],
#   [datetime.datetime(2015, 4, 2, 3, 59, 21), 3472729978],
#   [datetime.datetime(2015, 4, 3, 3, 59, 21), 3547549559],
#   [datetime.datetime(2015, 4, 4, 4, 9, 21), 3574913192],
#   [datetime.datetime(2015, 4, 5, 4, 9, 21), 3549704856],
#   [datetime.datetime(2015, 4, 6, 4, 14, 21), 3668097103],
#   [datetime.datetime(2015, 4, 7, 4, 14, 21), 3544201888],
#   [datetime.datetime(2015, 4, 8, 4, 14, 22), 3550136355],
#   [datetime.datetime(2015, 4, 9, 4, 34, 21), 3435976468],
#   [datetime.datetime(2015, 4, 10, 4, 34, 21), 3407562580],
#   [datetime.datetime(2015, 4, 11, 4, 34, 21), 3317215986],
#   [datetime.datetime(2015, 4, 12, 4, 34, 21), 3332846528],
#   [datetime.datetime(2015, 4, 13, 4, 34, 22), 3312552620],
#   [datetime.datetime(2015, 4, 14, 4, 34, 22), 3150265219],
#   [datetime.datetime(2015, 4, 15, 6, 9, 21), 3121110924],
#   [datetime.datetime(2015, 4, 16, 6, 14, 22), 3176590483],
#   [datetime.datetime(2015, 4, 17, 6, 19, 22), 3213681992],
#   [datetime.datetime(2015, 4, 18, 6, 24, 23), 3141396045],
#   [datetime.datetime(2015, 4, 19, 6, 39, 22), 3146724471],
#   [datetime.datetime(2015, 4, 20, 7, 19, 23), 3146493803],
#   [datetime.datetime(2015, 4, 21, 7, 24, 22), 3172533292],
#   [datetime.datetime(2015, 4, 22, 7, 34, 23), 3303065945],
#   [datetime.datetime(2015, 4, 23, 7, 34, 22), 3293427801],
#   [datetime.datetime(2015, 4, 24, 7, 44, 23), 3265078364],
#   [datetime.datetime(2015, 4, 25, 8, 44, 22), 3239046278],
#   [datetime.datetime(2015, 4, 26, 14, 59, 23), 3082924255],
#   [datetime.datetime(2015, 4, 27, 14, 59, 23), 3108026628],
#   [datetime.datetime(2015, 4, 28, 15, 4, 22), 3172247583],
#   [datetime.datetime(2015, 4, 29, 15, 19, 21), 3169000924],
#   [datetime.datetime(2015, 4, 30, 16, 24, 20), 3303850494],
#   [datetime.datetime(2015, 5, 1, 16, 24, 20), 3318464989],
#   [datetime.datetime(2015, 5, 2, 16, 39, 19), 3314728349],
#   [datetime.datetime(2015, 5, 3, 16, 44, 19), 3415504970],
#   [datetime.datetime(2015, 5, 4, 16, 44, 19), 3417049721],
#   [datetime.datetime(2015, 5, 5, 17, 9, 18), 3318757221],
#   [datetime.datetime(2015, 5, 6, 18, 49, 20), 3320275175],
#   [datetime.datetime(2015, 5, 7, 18, 49, 20), 3279491422],
#   [datetime.datetime(2015, 5, 8, 18, 49, 20), 3476741981],
#   [datetime.datetime(2015, 5, 9, 18, 49, 20), 3410996344],
#   [datetime.datetime(2015, 5, 10, 18, 49, 19), 3401965502],
#   [datetime.datetime(2015, 5, 11, 18, 54, 20), 3447508596],
#   [datetime.datetime(2015, 5, 12, 18, 59, 21), 3426188781],
#   [datetime.datetime(2015, 5, 13, 18, 59, 22), 3438268055],
#   [datetime.datetime(2015, 5, 14, 18, 59, 20), 3347749805],
#   [datetime.datetime(2015, 5, 15, 18, 59, 25), 3363986983],
#   [datetime.datetime(2015, 5, 16, 18, 59, 20), 3363167493],
#   [datetime.datetime(2015, 5, 17, 18, 59, 20), 3364091343],
#   [datetime.datetime(2015, 5, 18, 18, 59, 20), 3356103839],
#   [datetime.datetime(2015, 5, 19, 19, 9, 23), 3308309428],
#   [datetime.datetime(2015, 5, 20, 19, 14, 19), 3327909958],
#   [datetime.datetime(2015, 5, 21, 19, 14, 21), 3350546405],
#   [datetime.datetime(2015, 5, 22, 19, 14, 21), 3360738159],
#   [datetime.datetime(2015, 5, 23, 19, 14, 20), 3409088722],
#   [datetime.datetime(2015, 5, 24, 19, 14, 20), 3429956268],
#   [datetime.datetime(2015, 5, 25, 19, 34, 21), 3369803070],
#   [datetime.datetime(2015, 5, 26, 19, 59, 21), 3373050560],
#   [datetime.datetime(2015, 5, 27, 20, 9, 20), 3363816253],
#   [datetime.datetime(2015, 5, 28, 22, 54, 20), 3373675768],
#   [datetime.datetime(2015, 5, 29, 22, 54, 21), 3370190445],
#   [datetime.datetime(2015, 5, 30, 23, 9, 21), 3307068042],
#   [datetime.datetime(2015, 5, 31, 23, 9, 21), 3297894742],
#   [datetime.datetime(2015, 6, 1, 23, 24, 20), 3166420065],
#   [datetime.datetime(2015, 6, 3, 0, 29, 20), 3211363373],
#   [datetime.datetime(2015, 6, 4, 0, 29, 21), 3217797867],
#   [datetime.datetime(2015, 6, 5, 0, 29, 20), 3196874056],
#   [datetime.datetime(2015, 6, 6, 0, 29, 21), 3207088735],
#   [datetime.datetime(2015, 6, 7, 1, 29, 20), 3205253467],
#   [datetime.datetime(2015, 6, 8, 1, 29, 20), 3183902511],
#   [datetime.datetime(2015, 6, 9, 1, 29, 21), 3255937616],
#   [datetime.datetime(2015, 6, 10, 1, 29, 19), 3268406686],
#   [datetime.datetime(2015, 6, 11, 1, 29, 20), 3262359707],
#   [datetime.datetime(2015, 6, 12, 1, 29, 20), 3275768947],
#   [datetime.datetime(2015, 6, 13, 1, 29, 26), 3284984267],
#   [datetime.datetime(2015, 6, 14, 2, 29, 21), 3317671899],
#   [datetime.datetime(2015, 6, 15, 2, 29, 23), 3332954967],
#   [datetime.datetime(2015, 6, 16, 2, 29, 21), 3378059557],
#   [datetime.datetime(2015, 6, 17, 2, 29, 20), 3604399193],
#   [datetime.datetime(2015, 6, 18, 2, 29, 19), 3556041989],
#   [datetime.datetime(2015, 6, 19, 2, 29, 20), 3569721791],
#   [datetime.datetime(2015, 6, 20, 2, 29, 19), 3487268038],
#   [datetime.datetime(2015, 6, 21, 2, 29, 20), 3499099248],
#   [datetime.datetime(2015, 6, 22, 2, 34, 20), 3487360825],
#   [datetime.datetime(2015, 6, 23, 2, 34, 21), 3528441317],
#   [datetime.datetime(2015, 6, 24, 2, 34, 20), 3492940561],
#   [datetime.datetime(2015, 6, 25, 2, 34, 20), 3446189171],
#   [datetime.datetime(2015, 6, 26, 2, 34, 20), 3473639996],
#   [datetime.datetime(2015, 6, 27, 2, 34, 21), 3486208542],
#   [datetime.datetime(2015, 6, 28, 2, 34, 20), 3589623988],
#   [datetime.datetime(2015, 6, 29, 2, 34, 21), 3563321533],
#   [datetime.datetime(2015, 6, 30, 2, 34, 20), 3681402721],
#   [datetime.datetime(2015, 7, 1, 2, 34, 27), 3784372504],
#   [datetime.datetime(2015, 7, 2, 2, 34, 21), 3714048672],
#   [datetime.datetime(2015, 7, 3, 2, 34, 20), 3668022766],
#   [datetime.datetime(2015, 7, 4, 2, 34, 22), 3681165676],
#   [datetime.datetime(2015, 7, 5, 2, 34, 22), 3742137146],
#   [datetime.datetime(2015, 7, 6, 2, 34, 21), 3888172339],
#   [datetime.datetime(2015, 7, 7, 2, 34, 21), 3843241340],
#   [datetime.datetime(2015, 7, 8, 2, 34, 20), 3798502073],
#   [datetime.datetime(2015, 7, 9, 2, 34, 19), 3844791618],
#   [datetime.datetime(2015, 7, 10, 2, 34, 20), 3867029661],
#   [datetime.datetime(2015, 7, 11, 2, 34, 20), 4110352701],
#   [datetime.datetime(2015, 7, 12, 2, 34, 19), 4212905538],
#   [datetime.datetime(2015, 7, 13, 2, 34, 19), 4454664674],
#   [datetime.datetime(2015, 7, 14, 2, 34, 24), 4192223068],
#   [datetime.datetime(2015, 7, 15, 2, 39, 56), 4178565394],
#   [datetime.datetime(2015, 7, 16, 2, 39, 21), 4189402692],
#   [datetime.datetime(2015, 7, 17, 2, 39, 19), 4001980744],
#   [datetime.datetime(2015, 7, 18, 2, 39, 21), 4023355685],
#   [datetime.datetime(2015, 7, 19, 2, 44, 20), 3952584984],
#   [datetime.datetime(2015, 7, 20, 2, 49, 21), 3940416003],
#   [datetime.datetime(2015, 7, 21, 2, 49, 22), 4024532627],
#   [datetime.datetime(2015, 7, 22, 2, 59, 21), 3978914464],
#   [datetime.datetime(2015, 7, 23, 2, 59, 21), 3998474724],
#   [datetime.datetime(2015, 7, 24, 2, 59, 21), 3975213232],
#   [datetime.datetime(2015, 7, 25, 2, 59, 20), 4142634316],
#   [datetime.datetime(2015, 7, 26, 2, 59, 21), 4164345963],
#   [datetime.datetime(2015, 7, 27, 2, 59, 21), 4215400624],
#   [datetime.datetime(2015, 7, 28, 2, 59, 22), 4256097823],
#   [datetime.datetime(2015, 7, 29, 2, 59, 22), 4241127355],
#   [datetime.datetime(2015, 7, 30, 2, 59, 21), 4165297674],
#   [datetime.datetime(2015, 7, 31, 2, 59, 22), 4156876481],
#   [datetime.datetime(2015, 8, 1, 2, 59, 22), 4112500665],
#   [datetime.datetime(2015, 8, 2, 3, 4, 22), 4042133466],
#   [datetime.datetime(2015, 8, 3, 3, 4, 21), 4078449217],
#   [datetime.datetime(2015, 8, 4, 3, 4, 26), 4079086669],
#   [datetime.datetime(2015, 8, 5, 3, 14, 21), 4117595320],
#   [datetime.datetime(2015, 8, 6, 3, 14, 21), 4071191851],
#   [datetime.datetime(2015, 8, 7, 3, 14, 22), 4033878314],
#   [datetime.datetime(2015, 8, 8, 3, 14, 21), 4046202457],
#   [datetime.datetime(2015, 8, 9, 3, 14, 22), 3789713465],
#   [datetime.datetime(2015, 8, 10, 3, 14, 22), 3851303638],
#   [datetime.datetime(2015, 8, 11, 3, 14, 21), 3831151482],
#   [datetime.datetime(2015, 8, 12, 3, 29, 21), 3886143638],
#   [datetime.datetime(2015, 8, 13, 3, 29, 21), 3851673933],
#   [datetime.datetime(2015, 8, 14, 3, 29, 21), 3826343657],
# ...
#   [datetime.datetime(2015, 5, 2, 16, 39, 19), 15939300],
#   [datetime.datetime(2015, 5, 3, 16, 44, 19), 16861500],
#   [datetime.datetime(2015, 5, 4, 16, 44, 19), 16063800],
#   [datetime.datetime(2015, 5, 5, 17, 9, 18), 25902100],
#   [datetime.datetime(2015, 5, 6, 18, 49, 20), 17272400],
#   [datetime.datetime(2015, 5, 7, 18, 49, 20), 32649900],
#   [datetime.datetime(2015, 5, 8, 18, 49, 20), 32948700],
#   [datetime.datetime(2015, 5, 9, 18, 49, 20), 25349500],
#   [datetime.datetime(2015, 5, 10, 18, 49, 19), 15597600],
#   [datetime.datetime(2015, 5, 11, 18, 54, 20), 17472700],
#   [datetime.datetime(2015, 5, 12, 18, 59, 21), 21352400],
#   [datetime.datetime(2015, 5, 13, 18, 59, 22), 17839200],
#   [datetime.datetime(2015, 5, 14, 18, 59, 20), 28772200],
#   [datetime.datetime(2015, 5, 15, 18, 59, 25), 20008000],
#   [datetime.datetime(2015, 5, 16, 18, 59, 20), 12811900],
#   [datetime.datetime(2015, 5, 17, 18, 59, 20), 11257500],
#   [datetime.datetime(2015, 5, 18, 18, 59, 20), 12963900],
#   [datetime.datetime(2015, 5, 19, 19, 9, 23), 17644200],
#   [datetime.datetime(2015, 5, 20, 19, 14, 19), 15952000],
#   [datetime.datetime(2015, 5, 21, 19, 14, 21), 15400400],
#   [datetime.datetime(2015, 5, 22, 19, 14, 21), 19170400],
#   [datetime.datetime(2015, 5, 23, 19, 14, 20), 21821300],
#   [datetime.datetime(2015, 5, 24, 19, 14, 20), 12507600],
#   [datetime.datetime(2015, 5, 25, 19, 34, 21), 13777600],
#   [datetime.datetime(2015, 5, 26, 19, 59, 21), 15536800],
#   [datetime.datetime(2015, 5, 27, 20, 9, 20), 18473500],
#   [datetime.datetime(2015, 5, 28, 22, 54, 20), 13725800],
#   [datetime.datetime(2015, 5, 29, 22, 54, 21), 15242500],
#   [datetime.datetime(2015, 5, 30, 23, 9, 21), 14166700],
#   [datetime.datetime(2015, 5, 31, 23, 9, 21), 12519500],
#   [datetime.datetime(2015, 6, 1, 23, 24, 20), 25922900],
#   [datetime.datetime(2015, 6, 3, 0, 29, 20), 20742500],
#   [datetime.datetime(2015, 6, 4, 0, 29, 21), 17462200],
#   [datetime.datetime(2015, 6, 5, 0, 29, 20), 14461900],
#   [datetime.datetime(2015, 6, 6, 0, 29, 21), 18190200],
#   [datetime.datetime(2015, 6, 7, 1, 29, 20), 10568700],
#   [datetime.datetime(2015, 6, 8, 1, 29, 20), 13654600],
#   [datetime.datetime(2015, 6, 9, 1, 29, 21), 23342800],
#   [datetime.datetime(2015, 6, 10, 1, 29, 19), 28156800],
#   [datetime.datetime(2015, 6, 11, 1, 29, 20), 15904400],
#   [datetime.datetime(2015, 6, 12, 1, 29, 20), 14609500],
#   [datetime.datetime(2015, 6, 13, 1, 29, 26), 14004900],
#   [datetime.datetime(2015, 6, 14, 2, 29, 21), 12714400],
#   [datetime.datetime(2015, 6, 15, 2, 29, 23), 12266200],
#   [datetime.datetime(2015, 6, 16, 2, 29, 21), 20029300],
#   [datetime.datetime(2015, 6, 17, 2, 29, 20), 42924100],
#   [datetime.datetime(2015, 6, 18, 2, 29, 19), 42633100],
#   [datetime.datetime(2015, 6, 19, 2, 29, 20), 31076200],
#   [datetime.datetime(2015, 6, 20, 2, 29, 19), 24655600],
#   [datetime.datetime(2015, 6, 21, 2, 29, 20), 19823200],
#   [datetime.datetime(2015, 6, 22, 2, 34, 20), 10607100],
#   [datetime.datetime(2015, 6, 23, 2, 34, 21), 17576300],
#   [datetime.datetime(2015, 6, 24, 2, 34, 20), 15309800],
#   [datetime.datetime(2015, 6, 25, 2, 34, 20), 17090000],
#   [datetime.datetime(2015, 6, 26, 2, 34, 20), 15904600],
#   [datetime.datetime(2015, 6, 27, 2, 34, 21), 13769300],
#   [datetime.datetime(2015, 6, 28, 2, 34, 20), 20587900],
#   [datetime.datetime(2015, 6, 29, 2, 34, 21), 15025600],
#   [datetime.datetime(2015, 6, 30, 2, 34, 20), 34722300],
#   [datetime.datetime(2015, 7, 1, 2, 34, 27), 44669600],
#   [datetime.datetime(2015, 7, 2, 2, 34, 21), 26947900],
#   [datetime.datetime(2015, 7, 3, 2, 34, 20), 21435300],
#   [datetime.datetime(2015, 7, 4, 2, 34, 22), 19017900],
#   [datetime.datetime(2015, 7, 5, 2, 34, 22), 15464000],
#   [datetime.datetime(2015, 7, 6, 2, 34, 21), 44697100],
#   [datetime.datetime(2015, 7, 7, 2, 34, 21), 49703100],
#   [datetime.datetime(2015, 7, 8, 2, 34, 20), 27847400],
#   [datetime.datetime(2015, 7, 9, 2, 34, 19), 36849400],
#   [datetime.datetime(2015, 7, 10, 2, 34, 20), 40454400],
#   [datetime.datetime(2015, 7, 11, 2, 34, 20), 100412000],
#   [datetime.datetime(2015, 7, 12, 2, 34, 19), 40447000],
#   [datetime.datetime(2015, 7, 13, 2, 34, 19), 56392900],
#   [datetime.datetime(2015, 7, 14, 2, 34, 24), 61330500],
#   [datetime.datetime(2015, 7, 15, 2, 39, 56), 29467300],
#   [datetime.datetime(2015, 7, 16, 2, 39, 21), 29174900],
#   [datetime.datetime(2015, 7, 17, 2, 39, 19), 49482600],
#   [datetime.datetime(2015, 7, 18, 2, 39, 21), 27344700],
#   [datetime.datetime(2015, 7, 19, 2, 44, 20), 25371800],
#   [datetime.datetime(2015, 7, 20, 2, 49, 21), 15558600],
#   [datetime.datetime(2015, 7, 21, 2, 49, 22), 22273800],
#   [datetime.datetime(2015, 7, 22, 2, 59, 21), 23182500],
#   [datetime.datetime(2015, 7, 23, 2, 59, 21), 18615900],
#   [datetime.datetime(2015, 7, 24, 2, 59, 21), 18377800],
#   [datetime.datetime(2015, 7, 25, 2, 59, 20), 37326400],
#   [datetime.datetime(2015, 7, 26, 2, 59, 21), 20062200],
#   [datetime.datetime(2015, 7, 27, 2, 59, 21), 15984000],
#   [datetime.datetime(2015, 7, 28, 2, 59, 22), 31177800],
#   [datetime.datetime(2015, 7, 29, 2, 59, 22), 25193500],
#   [datetime.datetime(2015, 7, 30, 2, 59, 21), 24739600],
#   [datetime.datetime(2015, 7, 31, 2, 59, 22), 21319400],
#   [datetime.datetime(2015, 8, 1, 2, 59, 22), 23205300],
#   [datetime.datetime(2015, 8, 2, 3, 4, 22), 19310000],
#   [datetime.datetime(2015, 8, 3, 3, 4, 21), 17210200],
#   [datetime.datetime(2015, 8, 4, 3, 4, 26), 22122200],
#   [datetime.datetime(2015, 8, 5, 3, 14, 21), 21201300],
#   [datetime.datetime(2015, 8, 6, 3, 14, 21), 20604100],
#   [datetime.datetime(2015, 8, 7, 3, 14, 22), 17952300],
#   [datetime.datetime(2015, 8, 8, 3, 14, 21), 42342900],
#   [datetime.datetime(2015, 8, 9, 3, 14, 22), 58689800],
#   [datetime.datetime(2015, 8, 10, 3, 14, 22), 22285600],
#   [datetime.datetime(2015, 8, 11, 3, 14, 21), 20524000],
#   [datetime.datetime(2015, 8, 12, 3, 29, 21), 24977000],
#   [datetime.datetime(2015, 8, 13, 3, 29, 21), 26974200],
#   [datetime.datetime(2015, 8, 14, 3, 29, 21), 27216500],
#   [datetime.datetime(2015, 8, 15, 3, 29, 23), 27091900],
#   [datetime.datetime(2015, 8, 16, 3, 29, 20), 19510600],
#   [datetime.datetime(2015, 8, 17, 3, 29, 21), 29052400],
#   [datetime.datetime(2015, 8, 18, 3, 29, 20), 22034500],
#   [datetime.datetime(2015, 8, 19, 3, 29, 22), 63601000],
#   [datetime.datetime(2015, 8, 20, 3, 44, 21), 45257000],
#   [datetime.datetime(2015, 8, 21, 3, 44, 22), 30539300],
#   [datetime.datetime(2015, 8, 22, 3, 44, 21), 23355900],
#   [datetime.datetime(2015, 8, 23, 3, 49, 21), 22995600],
#   [datetime.datetime(2015, 8, 24, 3, 49, 21), 19533100],
#   [datetime.datetime(2015, 8, 25, 3, 54, 21), 65919600],
#   [datetime.datetime(2015, 8, 26, 3, 54, 20), 52402700],
#   [datetime.datetime(2015, 8, 27, 3, 54, 21), 31120600],
#   [datetime.datetime(2015, 8, 28, 3, 54, 21), 22965600],
#   [datetime.datetime(2015, 8, 29, 3, 54, 21), 29428400],
#   [datetime.datetime(2015, 8, 30, 4, 4, 21), 17820200],
#   [datetime.datetime(2015, 8, 31, 4, 4, 23), 18923200],
#   [datetime.datetime(2015, 9, 1, 4, 4, 20), 20222800],
#   [datetime.datetime(2015, 9, 2, 4, 4, 24), 20112300],
#   [datetime.datetime(2015, 9, 3, 4, 4, 21), 18480400],
#   [datetime.datetime(2015, 9, 4, 4, 4, 21), 18118800],
#   [datetime.datetime(2015, 9, 5, 4, 4, 23), 17494500],
#   [datetime.datetime(2015, 9, 6, 4, 4, 22), 19369500],
#   [datetime.datetime(2015, 9, 7, 4, 4, 22), 23695600],
#   [datetime.datetime(2015, 9, 8, 4, 4, 21), 19512600],
#   [datetime.datetime(2015, 9, 9, 4, 14, 21), 24843300],
#   [datetime.datetime(2015, 9, 10, 4, 19, 21), 21024500],
#   [datetime.datetime(2015, 9, 11, 4, 19, 23), 19597800],
#   [datetime.datetime(2015, 9, 12, 4, 19, 21), 16826300],
#   [datetime.datetime(2015, 9, 13, 4, 29, 22), 16206200],
#   [datetime.datetime(2015, 9, 14, 4, 29, 21), 17506600],
#   [datetime.datetime(2015, 9, 15, 4, 29, 23), 18772300],
#   [datetime.datetime(2015, 9, 16, 4, 29, 21), 16233700],
#   [datetime.datetime(2015, 9, 17, 4, 29, 21), 18810900],
#   [datetime.datetime(2015, 9, 19, 6, 59, 23), 16217800],
#   [datetime.datetime(2015, 9, 20, 7, 14, 23), 11954800],
#   [datetime.datetime(2015, 9, 21, 10, 24, 27), 14191700],
#   [datetime.datetime(2015, 9, 22, 12, 14, 22), 22857700],
#   [datetime.datetime(2015, 9, 23, 12, 14, 22), 18445900],
#   [datetime.datetime(2015, 9, 24, 12, 14, 40), 18486500],
#   [datetime.datetime(2015, 9, 25, 12, 39, 22), 25172600],
#   [datetime.datetime(2015, 9, 26, 13, 54, 24), 14410300],
#   [datetime.datetime(2015, 9, 27, 13, 59, 22), 13062400],
#   [datetime.datetime(2015, 9, 28, 13, 59, 22), 20202700],
#   [datetime.datetime(2015, 9, 29, 14, 4, 23), 22663000],
#   [datetime.datetime(2015, 9, 30, 14, 4, 23), 20512900],
#   [datetime.datetime(2015, 10, 1, 14, 4, 22), 16936200],
#   [datetime.datetime(2015, 10, 2, 14, 4, 22), 20239100],
#   [datetime.datetime(2015, 10, 3, 14, 19, 21), 17462600],
#   [datetime.datetime(2015, 10, 4, 14, 19, 22), 12642100],
#   [datetime.datetime(2015, 10, 5, 14, 19, 24), 15530500],
#   [datetime.datetime(2015, 10, 6, 14, 24, 23), 22365900],
#   [datetime.datetime(2015, 10, 7, 14, 24, 22), 26893700],
#   [datetime.datetime(2015, 10, 8, 14, 24, 24), 19671700],
#   [datetime.datetime(2015, 10, 9, 14, 24, 21), 18560000],
#   [datetime.datetime(2015, 10, 10, 14, 24, 22), 16000800],
#   [datetime.datetime(2015, 10, 11, 14, 39, 22), 11433600],
#   [datetime.datetime(2015, 10, 12, 14, 39, 22), 18033400],
#   [datetime.datetime(2015, 10, 13, 14, 39, 22), 24721800],
#   [datetime.datetime(2015, 10, 14, 14, 39, 23), 23232600],
#   [datetime.datetime(2015, 10, 15, 14, 44, 24), 26793100],
#   [datetime.datetime(2015, 10, 16, 14, 44, 45), 24415000],
#   [datetime.datetime(2015, 10, 17, 14, 54, 34), 44097300],
#   [datetime.datetime(2015, 10, 18, 14, 54, 24), 29558400],
#   [datetime.datetime(2015, 10, 19, 14, 54, 23), 25714300],
#   [datetime.datetime(2015, 10, 20, 14, 54, 20), 26078800],
#   [datetime.datetime(2015, 10, 21, 14, 54, 21), 29059300],
#   [datetime.datetime(2015, 10, 22, 14, 54, 20), 30156000],
#   [datetime.datetime(2015, 10, 23, 14, 54, 23), 32351800],
#   [datetime.datetime(2015, 10, 24, 14, 54, 22), 24084000],
#   [datetime.datetime(2015, 10, 25, 14, 19, 21), 35526900],
#   [datetime.datetime(2015, 10, 26, 14, 19, 21), 40169900],
#   [datetime.datetime(2015, 10, 27, 14, 19, 22), 35514700],
#   [datetime.datetime(2015, 10, 28, 14, 19, 20), 47347600],
#   [datetime.datetime(2015, 10, 29, 14, 19, 21), 51994800],
#   [datetime.datetime(2015, 10, 30, 14, 19, 20), 89068400],
#   [datetime.datetime(2015, 10, 31, 14, 54, 21), 41206200],
#   [datetime.datetime(2015, 11, 1, 15, 54, 21), 43893300],
#   [datetime.datetime(2015, 11, 2, 15, 54, 21), 56898600],
#   [datetime.datetime(2015, 11, 3, 15, 54, 19), 162207000],
#   [datetime.datetime(2015, 11, 4, 16, 4, 22), 293695000],
#   [datetime.datetime(2015, 11, 5, 16, 4, 20), 221063000],
#   [datetime.datetime(2015, 11, 6, 16, 4, 19), 121795000],
#   [datetime.datetime(2015, 11, 7, 16, 4, 20), 83953100],
#   [datetime.datetime(2015, 11, 8, 16, 39, 20), 44625800],
#   [datetime.datetime(2015, 11, 9, 16, 39, 25), 71774400],
#   [datetime.datetime(2015, 11, 10, 16, 39, 26), 68662800],
#   [datetime.datetime(2015, 11, 11, 16, 39, 21), 124080000],
#   [datetime.datetime(2015, 11, 12, 16, 39, 26), 81853000],
#   [datetime.datetime(2015, 11, 13, 16, 39, 27), 54658200],
#   [datetime.datetime(2015, 11, 14, 17, 14, 20), 38263800],
#   [datetime.datetime(2015, 11, 15, 17, 14, 22), 39008100],
#   [datetime.datetime(2015, 11, 16, 17, 14, 22), 42884200],
#   [datetime.datetime(2015, 11, 17, 17, 14, 20), 59097000],
#   [datetime.datetime(2015, 11, 18, 17, 14, 29), 42213700],
#   [datetime.datetime(2015, 11, 19, 17, 14, 21), 43553200],
#   [datetime.datetime(2015, 11, 20, 17, 14, 21), 53429100],
#   [datetime.datetime(2015, 11, 21, 18, 9, 45), 29623700],
#   [datetime.datetime(2015, 11, 22, 18, 9, 20), 21826600],
#   [datetime.datetime(2015, 11, 23, 18, 9, 25), 24535100],
#   [datetime.datetime(2015, 11, 24, 18, 14, 20), 28723900],
#   [datetime.datetime(2015, 11, 25, 18, 14, 20), 35175500],
#   [datetime.datetime(2015, 11, 26, 18, 14, 21), 97328600],
#   [datetime.datetime(2015, 11, 27, 22, 44, 19), 60590100],
#   [datetime.datetime(2015, 11, 28, 22, 44, 22), 37239800],
#   [datetime.datetime(2015, 11, 29, 22, 44, 22), 32339100],
#   [datetime.datetime(2015, 11, 30, 22, 44, 20), 75583000],
#   [datetime.datetime(2015, 12, 1, 22, 44, 23), 62588000],
#   [datetime.datetime(2015, 12, 2, 22, 44, 33), 52641600],
#   [datetime.datetime(2015, 12, 3, 22, 44, 20), 51221800],
#   [datetime.datetime(2015, 12, 4, 22, 44, 20), 35761100],
#   [datetime.datetime(2015, 12, 5, 22, 44, 24), 53679900],
#   [datetime.datetime(2015, 12, 6, 22, 44, 20), 88056200],
#   [datetime.datetime(2015, 12, 7, 22, 44, 20), 64776800],
#   [datetime.datetime(2015, 12, 8, 22, 44, 24), 42450200],
#   [datetime.datetime(2015, 12, 9, 22, 44, 23), 101683000],
#   [datetime.datetime(2015, 12, 10, 22, 44, 22), 53263400],
#   [datetime.datetime(2015, 12, 11, 22, 44, 21), 104496000],
#   [datetime.datetime(2015, 12, 12, 22, 44, 23), 131176000],
#   [datetime.datetime(2015, 12, 13, 22, 44, 23), 57806600],
#   [datetime.datetime(2015, 12, 14, 22, 44, 24), 128529000],
#   [datetime.datetime(2015, 12, 15, 22, 49, 22), 80492700],
#   [datetime.datetime(2015, 12, 16, 22, 59, 23), 111483000],
#   [datetime.datetime(2015, 12, 17, 22, 59, 20), 48845100],
#   [datetime.datetime(2015, 12, 18, 23, 14, 22), 58257500],
#   [datetime.datetime(2015, 12, 19, 23, 24, 22), 48601100],
#   [datetime.datetime(2015, 12, 20, 23, 24, 20), 74004600],
#   [datetime.datetime(2015, 12, 21, 23, 24, 24), 75809300],
#   [datetime.datetime(2015, 12, 22, 23, 29, 22), 52039000],
#   [datetime.datetime(2015, 12, 23, 23, 29, 22), 47354600],
#   [datetime.datetime(2015, 12, 24, 23, 29, 20), 57236500],
#   [datetime.datetime(2015, 12, 25, 23, 29, 21), 39143500],
#   [datetime.datetime(2015, 12, 26, 23, 29, 22), 114925000],
#   [datetime.datetime(2015, 12, 27, 23, 29, 22), 53393600],
#   [datetime.datetime(2015, 12, 28, 23, 29, 21), 49089900],
#   [datetime.datetime(2015, 12, 29, 23, 29, 22), 50244100],
#   [datetime.datetime(2015, 12, 30, 23, 29, 22), 48589900],
#   [datetime.datetime(2015, 12, 31, 23, 29, 22), 45929800],
#   [datetime.datetime(2016, 1, 1, 23, 29, 21), 35900100],
#   [datetime.datetime(2016, 1, 2, 23, 29, 23), 30177000],
#   [datetime.datetime(2016, 1, 3, 23, 29, 22), 38378900],
#   [datetime.datetime(2016, 1, 4, 23, 29, 23), 38174500],
#   [datetime.datetime(2016, 1, 5, 23, 29, 18), 34971300],
#   [datetime.datetime(2016, 1, 6, 23, 29, 16), 33744600],
#   [datetime.datetime(2016, 1, 7, 23, 34, 18), 81552100],
#   [datetime.datetime(2016, 1, 8, 23, 34, 17), 61907500],
#   [datetime.datetime(2016, 1, 9, 23, 34, 16), 32339500],
#   [datetime.datetime(2016, 1, 10, 23, 39, 17), 35198400],
#   [datetime.datetime(2016, 1, 11, 23, 39, 19), 41045900],
#   [datetime.datetime(2016, 1, 12, 23, 54, 19), 99356700],
#   [datetime.datetime(2016, 1, 13, 23, 54, 19), 180327000],
#   [datetime.datetime(2016, 1, 14, 23, 54, 19), 43258800],
#   [datetime.datetime(2016, 1, 15, 23, 54, 19), 142114000],
#   [datetime.datetime(2016, 1, 16, 23, 54, 19), 129294000],
#   [datetime.datetime(2016, 1, 18, 0, 4, 17), 47441400],
#   [datetime.datetime(2016, 1, 19, 0, 4, 19), 56199800],
#   [datetime.datetime(2016, 1, 20, 0, 4, 19), 46402600],
#   [datetime.datetime(2016, 1, 21, 0, 4, 19), 109001000],
#   [datetime.datetime(2016, 1, 22, 0, 19, 19), 73754000],
#   [datetime.datetime(2016, 1, 23, 0, 19, 23), 88051500],
#   [datetime.datetime(2016, 1, 24, 0, 29, 24), 56582800],
#   [datetime.datetime(2016, 1, 25, 0, 39, 18), 55545300],
#   [datetime.datetime(2016, 1, 26, 0, 39, 19), 58803600],
#   [datetime.datetime(2016, 1, 27, 0, 44, 22), 57754300],
#   [datetime.datetime(2016, 1, 28, 0, 54, 18), 47575500],
#   [datetime.datetime(2016, 1, 29, 0, 54, 18), 59191900],
#   [datetime.datetime(2016, 1, 30, 0, 54, 18), 86293700],
#   [datetime.datetime(2016, 1, 31, 0, 54, 18), 30274600],
#   [datetime.datetime(2016, 2, 1, 0, 54, 19), 37543600],
#   [datetime.datetime(2016, 2, 2, 0, 54, 20), 51821200],
#   [datetime.datetime(2016, 2, 3, 0, 54, 19), 40417700],
#   [datetime.datetime(2016, 2, 4, 0, 54, 20), 45872000],
#   [datetime.datetime(2016, 2, 5, 0, 54, 20), 69224300],
#   [datetime.datetime(2016, 2, 6, 1, 19, 37), 37850800],
#   ...]}

# %% [markdown]
# #### `graphs.global_cap([bitcoin=True, start=None, end=None])`
# Display data from [total market capitalization charts](https://coinmarketcap.com/charts/), including or excluding bitcoin:

# %%
cmc.graphs.global_cap(bitcoin=False)
# Out:
# {'market_cap_by_available_supply': [[datetime.datetime(2013, 4, 28, 20, 47),
#    91346900.0],
#   [datetime.datetime(2013, 4, 29, 20, 47), 94087500.0],
#   [datetime.datetime(2013, 4, 30, 20, 47), 90416200.0],
#   [datetime.datetime(2013, 5, 1, 20, 47), 78877300.0],
#   [datetime.datetime(2013, 5, 2, 20, 47), 72337900.0],
#   [datetime.datetime(2013, 5, 3, 20, 47), 66800000.0],
#   [datetime.datetime(2013, 5, 4, 20, 47), 79306600.0],
#   [datetime.datetime(2013, 5, 5, 20, 47), 82748700.0],
#   [datetime.datetime(2013, 5, 6, 20, 47), 80775900.0],
#   [datetime.datetime(2013, 5, 7, 20, 47), 70380300.0],
#   [datetime.datetime(2013, 5, 8, 20, 47), 78779600.0],
#   [datetime.datetime(2013, 5, 9, 20, 47), 77892400.0],
#   [datetime.datetime(2013, 5, 10, 20, 47), 79292400.0],
#   [datetime.datetime(2013, 5, 11, 20, 47), 75550100.0],
#   [datetime.datetime(2013, 5, 12, 20, 47), 72145100.0],
#   [datetime.datetime(2013, 5, 13, 20, 47), 73187500.0],
#   [datetime.datetime(2013, 5, 14, 20, 47), 72419800.0],
#   [datetime.datetime(2013, 5, 15, 20, 47), 65450200.0],
#   [datetime.datetime(2013, 5, 16, 20, 47), 63753400.0],
#   [datetime.datetime(2013, 5, 17, 20, 47), 70536900.0],
#   [datetime.datetime(2013, 5, 18, 20, 47), 71584400.0],
#   [datetime.datetime(2013, 5, 19, 20, 47), 72028600.0],
#   [datetime.datetime(2013, 5, 20, 20, 47), 71479800.0],
#   [datetime.datetime(2013, 5, 21, 20, 47), 71193200.0],
#   [datetime.datetime(2013, 5, 22, 20, 47), 71162700.0],
#   [datetime.datetime(2013, 5, 23, 20, 47), 71512200.0],
#   [datetime.datetime(2013, 5, 24, 20, 47), 70684600.0],
#   [datetime.datetime(2013, 5, 25, 20, 47), 70411100.0],
#   [datetime.datetime(2013, 5, 26, 20, 47), 73617500.0],
#   [datetime.datetime(2013, 5, 27, 20, 47), 69441300.0],
#   [datetime.datetime(2013, 5, 28, 20, 47), 69415000.0],
#   [datetime.datetime(2013, 5, 29, 20, 47), 68449400.0],
#   [datetime.datetime(2013, 5, 30, 20, 47), 66355500.0],
#   [datetime.datetime(2013, 5, 31, 20, 47), 63016300.0],
#   [datetime.datetime(2013, 6, 1, 20, 47), 63213400.0],
#   [datetime.datetime(2013, 6, 2, 20, 47), 59895000.0],
#   [datetime.datetime(2013, 6, 3, 20, 47), 60090200.0],
#   [datetime.datetime(2013, 6, 4, 20, 47), 63094600.0],
#   [datetime.datetime(2013, 6, 5, 20, 47), 63521200.0],
#   [datetime.datetime(2013, 6, 6, 20, 47), 62039600.0],
#   [datetime.datetime(2013, 6, 7, 20, 47), 58049800.0],
#   [datetime.datetime(2013, 6, 8, 20, 47), 57482400.0],
#   [datetime.datetime(2013, 6, 9, 20, 47), 52057800.0],
#   [datetime.datetime(2013, 6, 10, 20, 47), 54893200.0],
#   [datetime.datetime(2013, 6, 11, 20, 47), 52693800.0],
#   [datetime.datetime(2013, 6, 12, 20, 47), 54045100.0],
#   [datetime.datetime(2013, 6, 13, 20, 47), 53785900.0],
#   [datetime.datetime(2013, 6, 14, 20, 47), 49326300.0],
#   [datetime.datetime(2013, 6, 15, 20, 47), 48439400.0],
#   [datetime.datetime(2013, 6, 16, 20, 47), 46793200.0],
#   [datetime.datetime(2013, 6, 17, 20, 47), 49772100.0],
#   [datetime.datetime(2013, 6, 18, 20, 47), 51298700.0],
#   [datetime.datetime(2013, 6, 19, 20, 47), 52250400.0],
#   [datetime.datetime(2013, 6, 20, 20, 47), 54030600.0],
#   [datetime.datetime(2013, 6, 21, 20, 47), 58291300.0],
#   [datetime.datetime(2013, 6, 22, 20, 47), 70666600.0],
#   [datetime.datetime(2013, 6, 23, 20, 47), 67268700.0],
#   [datetime.datetime(2013, 6, 24, 20, 47), 61286100.0],
#   [datetime.datetime(2013, 6, 25, 20, 47), 62112600.0],
#   [datetime.datetime(2013, 6, 26, 20, 47), 62670600.0],
#   [datetime.datetime(2013, 6, 27, 20, 47), 64751900.0],
#   [datetime.datetime(2013, 6, 28, 20, 47), 61704800.0],
#   [datetime.datetime(2013, 6, 29, 20, 47), 62002900.0],
#   [datetime.datetime(2013, 6, 30, 20, 47), 64914000.0],
#   [datetime.datetime(2013, 7, 1, 20, 47), 65267700.0],
#   [datetime.datetime(2013, 7, 2, 20, 47), 63560800.0],
#   [datetime.datetime(2013, 7, 3, 20, 47), 63311200.0],
#   [datetime.datetime(2013, 7, 4, 20, 47), 60904300.0],
#   [datetime.datetime(2013, 7, 5, 20, 47), 54104500.0],
#   [datetime.datetime(2013, 7, 6, 20, 47), 55867900.0],
#   [datetime.datetime(2013, 7, 7, 20, 47), 57038100.0],
#   [datetime.datetime(2013, 7, 8, 20, 47), 60448000.0],
#   [datetime.datetime(2013, 7, 9, 20, 47), 59211900.0],
#   [datetime.datetime(2013, 7, 10, 20, 47), 59959900.0],
#   [datetime.datetime(2013, 7, 11, 20, 47), 62694500.0],
#   [datetime.datetime(2013, 7, 12, 20, 47), 65547400.0],
#   [datetime.datetime(2013, 7, 13, 20, 47), 65541800.0],
#   [datetime.datetime(2013, 7, 14, 20, 47), 66305200.0],
#   [datetime.datetime(2013, 7, 15, 20, 47), 68775700.0],
#   [datetime.datetime(2013, 7, 16, 20, 47), 71409200.0],
#   [datetime.datetime(2013, 7, 17, 20, 47), 71888600.0],
#   [datetime.datetime(2013, 7, 18, 20, 47), 67383000.0],
#   [datetime.datetime(2013, 7, 19, 20, 47), 70173300.0],
#   [datetime.datetime(2013, 7, 20, 20, 47), 70048200.0],
#   [datetime.datetime(2013, 7, 21, 20, 47), 67061200.0],
#   [datetime.datetime(2013, 7, 22, 20, 47), 68840500.0],
#   [datetime.datetime(2013, 7, 23, 20, 47), 69979800.0],
#   [datetime.datetime(2013, 7, 24, 20, 47), 70408700.0],
#   [datetime.datetime(2013, 7, 25, 20, 47), 71293500.0],
#   [datetime.datetime(2013, 7, 26, 20, 47), 70146100.0],
#   [datetime.datetime(2013, 7, 27, 20, 47), 69775900.0],
#   [datetime.datetime(2013, 7, 28, 20, 47), 70738400.0],
#   [datetime.datetime(2013, 7, 29, 20, 47), 72318200.0],
#   [datetime.datetime(2013, 7, 30, 20, 47), 70811300.0],
#   [datetime.datetime(2013, 7, 31, 20, 47), 70454400.0],
#   [datetime.datetime(2013, 8, 1, 20, 47), 71378500.0],
#   [datetime.datetime(2013, 8, 2, 20, 47), 71961800.0],
#   [datetime.datetime(2013, 8, 3, 20, 47), 72525500.0],
#   [datetime.datetime(2013, 8, 4, 20, 47), 120755000.0],
#   [datetime.datetime(2013, 8, 5, 20, 47), 116002000.0],
#   [datetime.datetime(2013, 8, 6, 20, 47), 107433000.0],
#   [datetime.datetime(2013, 8, 7, 20, 47), 105371000.0],
#   [datetime.datetime(2013, 8, 8, 20, 47), 101976000.0],
#   [datetime.datetime(2013, 8, 9, 20, 47), 102527000.0],
#   [datetime.datetime(2013, 8, 10, 20, 47), 101450000.0],
#   [datetime.datetime(2013, 8, 11, 20, 47), 102650000.0],
#   [datetime.datetime(2013, 8, 12, 20, 47), 102088000.0],
#   [datetime.datetime(2013, 8, 13, 20, 47), 104928000.0],
#   [datetime.datetime(2013, 8, 14, 20, 47), 102750000.0],
#   [datetime.datetime(2013, 8, 15, 20, 47), 98306500.0],
#   [datetime.datetime(2013, 8, 16, 20, 47), 94015300.0],
#   [datetime.datetime(2013, 8, 17, 20, 47), 116082000.0],
#   [datetime.datetime(2013, 8, 18, 20, 47), 122494000.0],
#   [datetime.datetime(2013, 8, 19, 20, 47), 116533000.0],
#   [datetime.datetime(2013, 8, 20, 20, 47), 122173000.0],
#   [datetime.datetime(2013, 8, 21, 20, 47), 120963000.0],
#   [datetime.datetime(2013, 8, 22, 20, 47), 118290000.0],
#   [datetime.datetime(2013, 8, 23, 20, 47), 111822000.0],
#   [datetime.datetime(2013, 8, 24, 20, 47), 115540000.0],
#   [datetime.datetime(2013, 8, 25, 20, 47), 115933000.0],
#   [datetime.datetime(2013, 8, 26, 20, 47), 120281000.0],
#   [datetime.datetime(2013, 8, 27, 20, 47), 117435000.0],
#   [datetime.datetime(2013, 8, 28, 20, 47), 118145000.0],
#   [datetime.datetime(2013, 8, 29, 20, 47), 116302000.0],
#   [datetime.datetime(2013, 8, 30, 20, 47), 118211000.0],
#   [datetime.datetime(2013, 8, 31, 20, 47), 114599000.0],
#   [datetime.datetime(2013, 9, 1, 20, 47), 113722000.0],
#   [datetime.datetime(2013, 9, 2, 20, 47), 113379000.0],
#   [datetime.datetime(2013, 9, 3, 20, 47), 112444000.0],
#   [datetime.datetime(2013, 9, 4, 20, 47), 119650000.0],
#   [datetime.datetime(2013, 9, 5, 20, 47), 120118000.0],
#   [datetime.datetime(2013, 9, 6, 20, 47), 117776000.0],
#   [datetime.datetime(2013, 9, 7, 20, 47), 120145000.0],
#   [datetime.datetime(2013, 9, 8, 20, 47), 120866000.0],
#   [datetime.datetime(2013, 9, 9, 20, 47), 122974000.0],
#   [datetime.datetime(2013, 9, 10, 20, 47), 117252000.0],
#   [datetime.datetime(2013, 9, 11, 20, 47), 121176000.0],
#   [datetime.datetime(2013, 9, 12, 20, 47), 122415000.0],
#   [datetime.datetime(2013, 9, 13, 20, 47), 124787000.0],
#   [datetime.datetime(2013, 9, 14, 20, 47), 120295000.0],
#   [datetime.datetime(2013, 9, 15, 20, 47), 121615000.0],
#   [datetime.datetime(2013, 9, 16, 20, 47), 126221000.0],
#   [datetime.datetime(2013, 9, 17, 20, 47), 145375000.0],
#   [datetime.datetime(2013, 9, 18, 20, 47), 154496000.0],
#   [datetime.datetime(2013, 9, 19, 20, 47), 155768000.0],
#   [datetime.datetime(2013, 9, 20, 20, 47), 147692000.0],
#   [datetime.datetime(2013, 9, 21, 20, 47), 145475000.0],
#   [datetime.datetime(2013, 9, 22, 20, 47), 148859000.0],
#   [datetime.datetime(2013, 9, 23, 20, 47), 147103000.0],
#   [datetime.datetime(2013, 9, 24, 20, 47), 147768000.0],
#   [datetime.datetime(2013, 9, 25, 20, 47), 149735000.0],
#   [datetime.datetime(2013, 9, 26, 20, 47), 157864000.0],
#   [datetime.datetime(2013, 9, 27, 20, 47), 181970000.0],
#   [datetime.datetime(2013, 9, 28, 20, 47), 175348000.0],
#   [datetime.datetime(2013, 9, 29, 20, 47), 171872000.0],
#   [datetime.datetime(2013, 9, 30, 20, 47), 152510000.0],
#   [datetime.datetime(2013, 10, 1, 20, 47), 151984000.0],
#   [datetime.datetime(2013, 10, 2, 20, 47), 122049000.0],
#   [datetime.datetime(2013, 10, 3, 20, 47), 131262000.0],
#   [datetime.datetime(2013, 10, 4, 20, 47), 144173000.0],
#   [datetime.datetime(2013, 10, 5, 20, 47), 142499000.0],
#   [datetime.datetime(2013, 10, 6, 20, 47), 145579000.0],
#   [datetime.datetime(2013, 10, 7, 20, 47), 138501000.0],
#   [datetime.datetime(2013, 10, 8, 20, 47), 138282000.0],
#   [datetime.datetime(2013, 10, 9, 20, 47), 140319000.0],
#   [datetime.datetime(2013, 10, 10, 20, 47), 143336000.0],
#   [datetime.datetime(2013, 10, 11, 20, 47), 137481000.0],
#   [datetime.datetime(2013, 10, 12, 20, 47), 141064000.0],
#   [datetime.datetime(2013, 10, 13, 20, 47), 134396000.0],
#   [datetime.datetime(2013, 10, 14, 20, 47), 131778000.0],
#   [datetime.datetime(2013, 10, 15, 20, 47), 125420000.0],
#   [datetime.datetime(2013, 10, 16, 20, 47), 120186000.0],
#   [datetime.datetime(2013, 10, 17, 20, 47), 126267000.0],
#   [datetime.datetime(2013, 10, 18, 20, 47), 122653000.0],
#   [datetime.datetime(2013, 10, 19, 20, 47), 115056000.0],
#   [datetime.datetime(2013, 10, 20, 20, 47), 113817000.0],
#   [datetime.datetime(2013, 10, 21, 20, 47), 110497000.0],
#   [datetime.datetime(2013, 10, 22, 20, 47), 110310000.0],
#   [datetime.datetime(2013, 10, 23, 20, 47), 128863000.0],
#   [datetime.datetime(2013, 10, 24, 20, 47), 135405000.0],
#   [datetime.datetime(2013, 10, 25, 20, 47), 121996000.0],
#   [datetime.datetime(2013, 10, 26, 20, 47), 116569000.0],
#   [datetime.datetime(2013, 10, 27, 19, 47), 118288000.0],
#   [datetime.datetime(2013, 10, 28, 19, 47), 115291000.0],
#   [datetime.datetime(2013, 10, 29, 19, 47), 115368000.0],
#   [datetime.datetime(2013, 10, 30, 19, 47), 117847000.0],
#   [datetime.datetime(2013, 10, 31, 19, 47), 119052000.0],
#   [datetime.datetime(2013, 11, 1, 19, 47), 122805000.0],
#   [datetime.datetime(2013, 11, 2, 19, 47), 130672000.0],
#   [datetime.datetime(2013, 11, 3, 19, 47), 145194000.0],
#   [datetime.datetime(2013, 11, 4, 19, 47), 149382000.0],
#   [datetime.datetime(2013, 11, 5, 19, 47), 148046000.0],
#   [datetime.datetime(2013, 11, 6, 19, 47), 164656000.0],
#   [datetime.datetime(2013, 11, 7, 19, 47), 194376000.0],
#   [datetime.datetime(2013, 11, 8, 19, 47), 218271000.0],
#   [datetime.datetime(2013, 11, 9, 19, 47), 207404000.0],
#   [datetime.datetime(2013, 11, 10, 19, 47), 171624000.0],
#   [datetime.datetime(2013, 11, 11, 19, 47), 188315000.0],
#   [datetime.datetime(2013, 11, 12, 19, 47), 194546000.0],
#   [datetime.datetime(2013, 11, 13, 19, 47), 214283000.0],
#   [datetime.datetime(2013, 11, 14, 19, 47), 204296000.0],
#   [datetime.datetime(2013, 11, 15, 19, 47), 208820000.0],
#   [datetime.datetime(2013, 11, 16, 19, 47), 210126000.0],
#   [datetime.datetime(2013, 11, 17, 19, 47), 213943000.0],
#   [datetime.datetime(2013, 11, 18, 19, 47), 327716000.0],
#   [datetime.datetime(2013, 11, 19, 19, 47), 299383000.0],
#   [datetime.datetime(2013, 11, 20, 19, 47), 283783000.0],
#   [datetime.datetime(2013, 11, 21, 19, 47), 350201000.0],
#   [datetime.datetime(2013, 11, 22, 19, 47), 384482000.0],
#   [datetime.datetime(2013, 11, 23, 19, 47), 430926000.0],
#   [datetime.datetime(2013, 11, 24, 19, 47), 436831000.0],
#   [datetime.datetime(2013, 11, 25, 19, 47), 500277000.0],
#   [datetime.datetime(2013, 11, 26, 19, 47), 802841000.0],
#   [datetime.datetime(2013, 11, 27, 19, 47), 1047390000.0],
#   [datetime.datetime(2013, 11, 28, 19, 47), 1455110000.0],
#   [datetime.datetime(2013, 11, 29, 19, 47), 1456280000.0],
#   [datetime.datetime(2013, 11, 30, 19, 47), 1678780000.0],
#   [datetime.datetime(2013, 12, 1, 19, 47), 1606220000.0],
#   [datetime.datetime(2013, 12, 2, 19, 47), 1533610000.0],
#   [datetime.datetime(2013, 12, 3, 19, 47), 1643150000.0],
#   [datetime.datetime(2013, 12, 4, 19, 47), 1922280000.0],
#   [datetime.datetime(2013, 12, 5, 19, 47), 1793890000.0],
#   [datetime.datetime(2013, 12, 6, 19, 47), 1391580000.0],
#   [datetime.datetime(2013, 12, 7, 19, 47), 1113350000.0],
#   [datetime.datetime(2013, 12, 8, 19, 47), 1124000000.0],
#   [datetime.datetime(2013, 12, 9, 19, 47), 1405800000.0],
#   [datetime.datetime(2013, 12, 10, 19, 47), 1624970000.0],
#   [datetime.datetime(2013, 12, 11, 19, 47), 1419110000.0],
#   [datetime.datetime(2013, 12, 12, 19, 47), 1389540000.0],
#   [datetime.datetime(2013, 12, 13, 19, 47), 1385360000.0],
#   [datetime.datetime(2013, 12, 14, 19, 47), 1338820000.0],
#   [datetime.datetime(2013, 12, 15, 19, 47), 1329440000.0],
#   [datetime.datetime(2013, 12, 16, 19, 47), 1088160000.0],
#   [datetime.datetime(2013, 12, 17, 19, 47), 964254000.0],
#   [datetime.datetime(2013, 12, 18, 19, 47), 722720000.0],
#   [datetime.datetime(2013, 12, 19, 19, 47), 813604000.0],
#   [datetime.datetime(2013, 12, 20, 19, 47), 877874000.0],
#   [datetime.datetime(2013, 12, 21, 19, 47), 826229000.0],
#   [datetime.datetime(2013, 12, 22, 19, 47), 848677000.0],
#   [datetime.datetime(2013, 12, 23, 19, 47), 853021000.0],
#   [datetime.datetime(2013, 12, 24, 19, 47), 874026000.0],
#   [datetime.datetime(2013, 12, 25, 19, 47), 1059850000.0],
#   [datetime.datetime(2013, 12, 26, 19, 47), 1287890000.0],
#   [datetime.datetime(2013, 12, 27, 19, 47), 1207710000.0],
#   [datetime.datetime(2013, 12, 28, 19, 47), 1195660000.0],
#   [datetime.datetime(2013, 12, 29, 19, 47), 1233030000.0],
#   [datetime.datetime(2013, 12, 30, 19, 47), 1316440000.0],
#   [datetime.datetime(2013, 12, 31, 19, 47), 1306210000.0],
#   [datetime.datetime(2014, 1, 1, 19, 47), 1342220000.0],
#   [datetime.datetime(2014, 1, 2, 19, 47), 1410630000.0],
#   [datetime.datetime(2014, 1, 3, 19, 47), 1373160000.0],
#   [datetime.datetime(2014, 1, 4, 19, 47), 1426020000.0],
#   [datetime.datetime(2014, 1, 5, 19, 47), 1463510000.0],
#   [datetime.datetime(2014, 1, 6, 19, 47), 1485140000.0],
#   [datetime.datetime(2014, 1, 7, 19, 47), 1345630000.0],
#   [datetime.datetime(2014, 1, 8, 19, 47), 1257160000.0],
#   [datetime.datetime(2014, 1, 9, 19, 47), 1208980000.0],
#   [datetime.datetime(2014, 1, 10, 19, 47), 1251870000.0],
#   [datetime.datetime(2014, 1, 11, 19, 47), 1336960000.0],
#   [datetime.datetime(2014, 1, 12, 19, 47), 1270820000.0],
#   [datetime.datetime(2014, 1, 13, 19, 47), 1184550000.0],
#   [datetime.datetime(2014, 1, 14, 19, 47), 1187880000.0],
#   [datetime.datetime(2014, 1, 15, 19, 47), 1262240000.0],
#   [datetime.datetime(2014, 1, 16, 19, 47), 1230020000.0],
#   [datetime.datetime(2014, 1, 17, 19, 47), 1167320000.0],
#   [datetime.datetime(2014, 1, 18, 19, 47), 1223270000.0],
#   [datetime.datetime(2014, 1, 19, 19, 47), 1264300000.0],
#   [datetime.datetime(2014, 1, 20, 19, 47), 1328450000.0],
#   [datetime.datetime(2014, 1, 21, 19, 47), 1357510000.0],
#   [datetime.datetime(2014, 1, 22, 19, 47), 1268330000.0],
#   [datetime.datetime(2014, 1, 23, 19, 47), 1238530000.0],
#   [datetime.datetime(2014, 1, 24, 19, 47), 1158590000.0],
#   [datetime.datetime(2014, 1, 25, 19, 47), 1279390000.0],
#   [datetime.datetime(2014, 1, 26, 19, 47), 1342780000.0],
#   [datetime.datetime(2014, 1, 27, 19, 47), 1192430000.0],
#   [datetime.datetime(2014, 1, 28, 19, 47), 1209400000.0],
#   [datetime.datetime(2014, 1, 29, 19, 47), 1201490000.0],
#   [datetime.datetime(2014, 1, 30, 19, 47), 1202140000.0],
#   [datetime.datetime(2014, 1, 31, 19, 47), 1215780000.0],
#   [datetime.datetime(2014, 2, 1, 19, 47), 1271320000.0],
#   [datetime.datetime(2014, 2, 2, 19, 47), 1273030000.0],
#   [datetime.datetime(2014, 2, 3, 19, 47), 1226850000.0],
#   [datetime.datetime(2014, 2, 4, 19, 47), 1221050000.0],
#   [datetime.datetime(2014, 2, 5, 19, 47), 1197700000.0],
#   [datetime.datetime(2014, 2, 6, 19, 47), 1152770000.0],
#   [datetime.datetime(2014, 2, 7, 19, 47), 1100320000.0],
#   [datetime.datetime(2014, 2, 8, 19, 47), 1036240000.0],
#   [datetime.datetime(2014, 2, 9, 19, 47), 1043400000.0],
#   [datetime.datetime(2014, 2, 10, 19, 47), 989687000.0],
#   [datetime.datetime(2014, 2, 11, 19, 47), 1035210000.0],
#   [datetime.datetime(2014, 2, 12, 19, 47), 1022980000.0],
#   [datetime.datetime(2014, 2, 13, 19, 47), 975399000.0],
#   [datetime.datetime(2014, 2, 14, 19, 47), 1011600000.0],
#   [datetime.datetime(2014, 2, 15, 19, 47), 1017520000.0],
#   [datetime.datetime(2014, 2, 16, 19, 47), 957827000.0],
#   [datetime.datetime(2014, 2, 17, 19, 47), 979692000.0],
#   [datetime.datetime(2014, 2, 18, 19, 47), 974309000.0],
#   [datetime.datetime(2014, 2, 19, 19, 47), 985101000.0],
#   [datetime.datetime(2014, 2, 20, 19, 47), 914285000.0],
#   [datetime.datetime(2014, 2, 21, 19, 47), 867297000.0],
#   [datetime.datetime(2014, 2, 22, 19, 47), 923988000.0],
#   [datetime.datetime(2014, 2, 23, 19, 47), 978744000.0],
#   [datetime.datetime(2014, 2, 24, 19, 47), 890014000.0],
#   [datetime.datetime(2014, 2, 25, 19, 47), 809536000.0],
#   [datetime.datetime(2014, 2, 26, 19, 47), 888840000.0],
#   [datetime.datetime(2014, 2, 27, 19, 47), 952724000.0],
#   [datetime.datetime(2014, 2, 28, 19, 47), 1096310000.0],
#   [datetime.datetime(2014, 3, 1, 19, 47), 1021000000.0],
#   [datetime.datetime(2014, 3, 2, 19, 47), 1114770000.0],
#   [datetime.datetime(2014, 3, 3, 19, 47), 1634700000.0],
#   [datetime.datetime(2014, 3, 4, 19, 47), 1852770000.0],
#   [datetime.datetime(2014, 3, 5, 19, 47), 1382400000.0],
#   [datetime.datetime(2014, 3, 6, 19, 47), 1199190000.0],
#   [datetime.datetime(2014, 3, 7, 19, 47), 1089520000.0],
#   [datetime.datetime(2014, 3, 8, 19, 47), 1084150000.0],
#   [datetime.datetime(2014, 3, 9, 19, 47), 1215770000.0],
#   [datetime.datetime(2014, 3, 10, 19, 47), 1215580000.0],
#   [datetime.datetime(2014, 3, 11, 19, 47), 1161250000.0],
#   [datetime.datetime(2014, 3, 12, 19, 47), 1192490000.0],
#   [datetime.datetime(2014, 3, 13, 19, 47), 1136190000.0],
#   [datetime.datetime(2014, 3, 14, 19, 47), 1127600000.0],
#   [datetime.datetime(2014, 3, 15, 19, 47), 1107150000.0],
#   [datetime.datetime(2014, 3, 16, 19, 47), 1111140000.0],
#   [datetime.datetime(2014, 3, 17, 19, 47), 996599000.0],
#   [datetime.datetime(2014, 3, 18, 19, 47), 1090860000.0],
#   [datetime.datetime(2014, 3, 19, 19, 47), 1077230000.0],
#   [datetime.datetime(2014, 3, 20, 19, 47), 1003680000.0],
#   [datetime.datetime(2014, 3, 21, 19, 47), 985536000.0],
#   [datetime.datetime(2014, 3, 22, 19, 47), 1064970000.0],
#   [datetime.datetime(2014, 3, 23, 19, 47), 1040740000.0],
#   [datetime.datetime(2014, 3, 24, 19, 47), 1001370000.0],
#   [datetime.datetime(2014, 3, 25, 19, 47), 975110000.0],
#   [datetime.datetime(2014, 3, 26, 19, 47), 933401000.0],
#   [datetime.datetime(2014, 3, 27, 19, 47), 793525000.0],
#   [datetime.datetime(2014, 3, 28, 19, 47), 740329000.0],
#   [datetime.datetime(2014, 3, 29, 19, 47), 756473000.0],
#   [datetime.datetime(2014, 3, 30, 20, 47), 698393000.0],
#   [datetime.datetime(2014, 3, 31, 20, 47), 682344000.0],
#   [datetime.datetime(2014, 4, 1, 20, 47), 706656000.0],
#   [datetime.datetime(2014, 4, 2, 20, 47), 617202000.0],
#   [datetime.datetime(2014, 4, 3, 20, 47), 604538000.0],
#   [datetime.datetime(2014, 4, 4, 20, 47), 607909000.0],
#   [datetime.datetime(2014, 4, 5, 20, 47), 624962000.0],
#   [datetime.datetime(2014, 4, 6, 20, 47), 633447000.0],
#   [datetime.datetime(2014, 4, 7, 20, 47), 618673000.0],
#   [datetime.datetime(2014, 4, 8, 20, 47), 613342000.0],
#   [datetime.datetime(2014, 4, 9, 20, 47), 596559000.0],
#   [datetime.datetime(2014, 4, 10, 20, 47), 515132000.0],
#   [datetime.datetime(2014, 4, 11, 20, 47), 583452000.0],
#   [datetime.datetime(2014, 4, 12, 20, 47), 561823000.0],
#   [datetime.datetime(2014, 4, 13, 20, 47), 527411000.0],
#   [datetime.datetime(2014, 4, 14, 20, 47), 620437000.0],
#   [datetime.datetime(2014, 4, 15, 20, 47), 687059000.0],
#   [datetime.datetime(2014, 4, 16, 20, 47), 705751000.0],
#   [datetime.datetime(2014, 4, 17, 20, 47), 685451000.0],
#   [datetime.datetime(2014, 4, 18, 20, 47), 666382000.0],
#   [datetime.datetime(2014, 4, 19, 20, 47), 730495000.0],
#   [datetime.datetime(2014, 4, 20, 20, 47), 712474000.0],
#   [datetime.datetime(2014, 4, 21, 20, 47), 714756000.0],
#   [datetime.datetime(2014, 4, 22, 20, 47), 700481000.0],
#   [datetime.datetime(2014, 4, 23, 20, 47), 689230000.0],
#   [datetime.datetime(2014, 4, 24, 20, 47), 697727000.0],
#   [datetime.datetime(2014, 4, 25, 20, 47), 600398000.0],
#   [datetime.datetime(2014, 4, 26, 20, 47), 595343000.0],
#   [datetime.datetime(2014, 4, 27, 20, 47), 552680000.0],
#   [datetime.datetime(2014, 4, 28, 20, 47), 575230000.0],
#   [datetime.datetime(2014, 4, 29, 20, 47), 588464000.0],
#   [datetime.datetime(2014, 4, 30, 20, 47), 605026000.0],
#   [datetime.datetime(2014, 5, 1, 20, 47), 611189000.0],
#   [datetime.datetime(2014, 5, 2, 20, 47), 582338000.0],
#   [datetime.datetime(2014, 5, 3, 20, 47), 560909000.0],
#   [datetime.datetime(2014, 5, 4, 20, 47), 566299000.0],
#   [datetime.datetime(2014, 5, 5, 20, 47), 562614000.0],
#   [datetime.datetime(2014, 5, 6, 20, 47), 575508000.0],
#   [datetime.datetime(2014, 5, 7, 20, 47), 594605000.0],
#   [datetime.datetime(2014, 5, 8, 20, 47), 592673000.0],
#   [datetime.datetime(2014, 5, 9, 20, 47), 616586000.0],
#   [datetime.datetime(2014, 5, 10, 20, 47), 610311000.0],
#   [datetime.datetime(2014, 5, 11, 20, 47), 589189000.0],
#   [datetime.datetime(2014, 5, 12, 20, 47), 591210000.0],
#   [datetime.datetime(2014, 5, 13, 20, 47), 592089000.0],
#   [datetime.datetime(2014, 5, 14, 20, 47), 604589000.0],
#   [datetime.datetime(2014, 5, 15, 20, 47), 620758000.0],
#   [datetime.datetime(2014, 5, 16, 20, 47), 612342000.0],
#   [datetime.datetime(2014, 5, 17, 20, 47), 607596000.0],
#   [datetime.datetime(2014, 5, 18, 20, 47), 602684000.0],
#   [datetime.datetime(2014, 5, 19, 20, 47), 601875000.0],
#   [datetime.datetime(2014, 5, 20, 20, 47), 635175000.0],
#   [datetime.datetime(2014, 5, 21, 20, 47), 634871000.0],
#   [datetime.datetime(2014, 5, 22, 20, 47), 628673000.0],
#   [datetime.datetime(2014, 5, 23, 20, 47), 664299000.0],
#   [datetime.datetime(2014, 5, 24, 20, 47), 655208000.0],
#   [datetime.datetime(2014, 5, 25, 20, 47), 698268000.0],
#   [datetime.datetime(2014, 5, 26, 20, 47), 685600000.0],
#   [datetime.datetime(2014, 5, 27, 20, 47), 680818000.0],
#   [datetime.datetime(2014, 5, 28, 20, 47), 663656000.0],
#   [datetime.datetime(2014, 5, 29, 20, 47), 652394000.0],
#   [datetime.datetime(2014, 5, 30, 20, 47), 681395000.0],
#   [datetime.datetime(2014, 5, 31, 20, 47), 670109000.0],
#   [datetime.datetime(2014, 6, 1, 20, 47), 700785000.0],
#   [datetime.datetime(2014, 6, 2, 20, 47), 693755000.0],
#   [datetime.datetime(2014, 6, 3, 20, 47), 705081000.0],
#   [datetime.datetime(2014, 6, 4, 20, 47), 689760000.0],
#   [datetime.datetime(2014, 6, 5, 20, 47), 708620000.0],
#   [datetime.datetime(2014, 6, 6, 20, 47), 695716000.0],
#   [datetime.datetime(2014, 6, 7, 20, 47), 689027000.0],
#   [datetime.datetime(2014, 6, 8, 20, 47), 691493000.0],
#   [datetime.datetime(2014, 6, 9, 20, 47), 686162000.0],
#   [datetime.datetime(2014, 6, 10, 20, 47), 704362000.0],
#   [datetime.datetime(2014, 6, 11, 20, 47), 708748000.0],
#   [datetime.datetime(2014, 6, 12, 20, 47), 682532000.0],
#   [datetime.datetime(2014, 6, 13, 20, 47), 671898000.0],
#   [datetime.datetime(2014, 6, 14, 20, 47), 643576000.0],
#   [datetime.datetime(2014, 6, 15, 20, 47), 650489000.0],
#   [datetime.datetime(2014, 6, 16, 20, 47), 664261000.0],
#   [datetime.datetime(2014, 6, 17, 20, 47), 656404000.0],
#   [datetime.datetime(2014, 6, 18, 20, 47), 664856000.0],
#   [datetime.datetime(2014, 6, 19, 20, 47), 672779000.0],
#   [datetime.datetime(2014, 6, 20, 20, 47), 649616000.0],
#   [datetime.datetime(2014, 6, 21, 20, 47), 650796000.0],
#   [datetime.datetime(2014, 6, 22, 20, 47), 659971000.0],
#   [datetime.datetime(2014, 6, 23, 20, 47), 647115000.0],
#   [datetime.datetime(2014, 6, 24, 20, 47), 639966000.0],
#   [datetime.datetime(2014, 6, 25, 20, 47), 606399000.0],
#   [datetime.datetime(2014, 6, 26, 20, 47), 603344000.0],
#   [datetime.datetime(2014, 6, 27, 20, 47), 617470000.0],
#   [datetime.datetime(2014, 6, 28, 20, 47), 612308000.0],
#   [datetime.datetime(2014, 6, 29, 20, 47), 597409000.0],
#   [datetime.datetime(2014, 6, 30, 20, 47), 601306000.0],
#   [datetime.datetime(2014, 7, 1, 20, 47), 608833000.0],
#   [datetime.datetime(2014, 7, 2, 20, 47), 574042000.0],
#   [datetime.datetime(2014, 7, 3, 20, 47), 577853000.0],
#   [datetime.datetime(2014, 7, 4, 20, 47), 566382000.0],
#   [datetime.datetime(2014, 7, 5, 20, 47), 533996000.0],
#   [datetime.datetime(2014, 7, 6, 20, 47), 528296000.0],
#   [datetime.datetime(2014, 7, 7, 20, 47), 526300000.0],
#   [datetime.datetime(2014, 7, 8, 20, 47), 532420000.0],
#   [datetime.datetime(2014, 7, 9, 20, 47), 545351000.0],
#   [datetime.datetime(2014, 7, 10, 20, 47), 540815000.0],
#   [datetime.datetime(2014, 7, 11, 20, 47), 552125000.0],
#   [datetime.datetime(2014, 7, 12, 20, 47), 572436000.0],
#   [datetime.datetime(2014, 7, 13, 20, 47), 577074000.0],
#   [datetime.datetime(2014, 7, 14, 20, 47), 571810000.0],
#   [datetime.datetime(2014, 7, 15, 20, 47), 564758000.0],
#   [datetime.datetime(2014, 7, 16, 20, 47), 558520000.0],
#   [datetime.datetime(2014, 7, 17, 20, 47), 589688000.0],
#   [datetime.datetime(2014, 7, 18, 20, 47), 600588000.0],
#   [datetime.datetime(2014, 7, 19, 20, 47), 588035000.0],
#   [datetime.datetime(2014, 7, 20, 20, 47), 583417000.0],
#   [datetime.datetime(2014, 7, 21, 20, 47), 609956000.0],
#   [datetime.datetime(2014, 7, 22, 20, 47), 598168000.0],
#   [datetime.datetime(2014, 7, 23, 20, 47), 596579000.0],
#   [datetime.datetime(2014, 7, 24, 20, 47), 568136000.0],
#   [datetime.datetime(2014, 7, 25, 20, 47), 554807000.0],
#   [datetime.datetime(2014, 7, 26, 20, 47), 550216000.0],
#   [datetime.datetime(2014, 7, 27, 20, 47), 551306000.0],
#   [datetime.datetime(2014, 7, 28, 20, 47), 536247000.0],
#   [datetime.datetime(2014, 7, 29, 20, 47), 539659000.0],
#   [datetime.datetime(2014, 7, 30, 20, 47), 533659000.0],
#   [datetime.datetime(2014, 7, 31, 20, 47), 549611000.0],
#   [datetime.datetime(2014, 8, 1, 20, 47), 559529000.0],
#   [datetime.datetime(2014, 8, 2, 20, 47), 553647000.0],
#   [datetime.datetime(2014, 8, 3, 20, 47), 549496000.0],
#   [datetime.datetime(2014, 8, 4, 20, 47), 538454000.0],
#   [datetime.datetime(2014, 8, 5, 20, 47), 528170000.0],
#   [datetime.datetime(2014, 8, 6, 20, 47), 525077000.0],
#   [datetime.datetime(2014, 8, 7, 20, 47), 526537000.0],
#   [datetime.datetime(2014, 8, 8, 20, 47), 522997000.0],
#   [datetime.datetime(2014, 8, 9, 20, 47), 507219000.0],
#   [datetime.datetime(2014, 8, 10, 20, 47), 503397000.0],
#   [datetime.datetime(2014, 8, 11, 20, 47), 480863000.0],
#   [datetime.datetime(2014, 8, 12, 20, 47), 440485000.0],
#   [datetime.datetime(2014, 8, 13, 20, 47), 413576000.0],
#   [datetime.datetime(2014, 8, 14, 20, 47), 411230000.0],
#   [datetime.datetime(2014, 8, 15, 20, 47), 399263000.0],
#   [datetime.datetime(2014, 8, 16, 20, 47), 394691000.0],
#   [datetime.datetime(2014, 8, 17, 20, 47), 380833000.0],
#   [datetime.datetime(2014, 8, 18, 20, 47), 325334000.0],
#   [datetime.datetime(2014, 8, 19, 20, 47), 379965000.0],
#   [datetime.datetime(2014, 8, 20, 20, 47), 432706000.0],
#   [datetime.datetime(2014, 8, 21, 20, 47), 458531000.0],
#   [datetime.datetime(2014, 8, 22, 20, 47), 448876000.0],
#   [datetime.datetime(2014, 8, 23, 20, 47), 421314000.0],
#   [datetime.datetime(2014, 8, 24, 20, 47), 459937000.0],
#   [datetime.datetime(2014, 8, 25, 20, 47), 481503000.0],
#   [datetime.datetime(2014, 8, 26, 20, 47), 588487000.0],
#   [datetime.datetime(2014, 8, 27, 20, 47), 577642000.0],
#   [datetime.datetime(2014, 8, 28, 20, 47), 560228000.0],
#   [datetime.datetime(2014, 8, 29, 20, 47), 551812000.0],
#   [datetime.datetime(2014, 8, 30, 20, 47), 555412000.0],
#   [datetime.datetime(2014, 8, 31, 20, 47), 531649000.0],
#   [datetime.datetime(2014, 9, 1, 20, 47), 538868000.0],
#   [datetime.datetime(2014, 9, 2, 20, 47), 521499000.0],
#   [datetime.datetime(2014, 9, 3, 20, 47), 533098000.0],
#   [datetime.datetime(2014, 9, 4, 20, 47), 556120000.0],
#   [datetime.datetime(2014, 9, 5, 20, 47), 557284000.0],
#   [datetime.datetime(2014, 9, 6, 20, 47), 571883000.0],
#   [datetime.datetime(2014, 9, 7, 20, 47), 568487000.0],
#   [datetime.datetime(2014, 9, 8, 20, 47), 572200000.0],
#   [datetime.datetime(2014, 9, 9, 20, 47), 569839000.0],
#   [datetime.datetime(2014, 9, 10, 20, 47), 594090000.0],
#   [datetime.datetime(2014, 9, 11, 20, 47), 594379000.0],
#   [datetime.datetime(2014, 9, 12, 20, 47), 598659000.0],
#   [datetime.datetime(2014, 9, 13, 20, 47), 608282000.0],
#   [datetime.datetime(2014, 9, 14, 20, 47), 631353000.0],
#   [datetime.datetime(2014, 9, 15, 20, 47), 606270000.0],
#   [datetime.datetime(2014, 9, 16, 20, 47), 616408000.0],
#   [datetime.datetime(2014, 9, 17, 20, 47), 608788000.0],
#   [datetime.datetime(2014, 9, 18, 20, 47), 603183000.0],
#   [datetime.datetime(2014, 9, 19, 20, 47), 564351000.0],
#   [datetime.datetime(2014, 9, 20, 20, 47), 566222000.0],
#   [datetime.datetime(2014, 9, 21, 20, 47), 555691000.0],
#   [datetime.datetime(2014, 9, 22, 20, 47), 561185000.0],
#   [datetime.datetime(2014, 9, 23, 20, 47), 586192000.0],
#   [datetime.datetime(2014, 9, 24, 20, 47), 586314000.0],
#   [datetime.datetime(2014, 9, 25, 20, 47), 583209000.0],
#   [datetime.datetime(2014, 9, 26, 20, 47), 586850000.0],
#   [datetime.datetime(2014, 9, 27, 20, 47), 576005000.0],
#   [datetime.datetime(2014, 9, 28, 20, 47), 581236000.0],
#   [datetime.datetime(2014, 9, 29, 20, 47), 561157000.0],
#   [datetime.datetime(2014, 9, 30, 20, 47), 571566000.0],
#   [datetime.datetime(2014, 10, 1, 20, 47), 573030000.0],
#   [datetime.datetime(2014, 10, 2, 20, 47), 565854000.0],
#   [datetime.datetime(2014, 10, 3, 20, 47), 556568000.0],
#   [datetime.datetime(2014, 10, 4, 20, 47), 534145000.0],
#   [datetime.datetime(2014, 10, 5, 20, 47), 494751000.0],
#   [datetime.datetime(2014, 10, 6, 20, 47), 521936000.0],
#   [datetime.datetime(2014, 10, 7, 20, 47), 526810000.0],
#   [datetime.datetime(2014, 10, 8, 20, 47), 531243000.0],
#   [datetime.datetime(2014, 10, 9, 20, 47), 551440000.0],
#   [datetime.datetime(2014, 10, 10, 20, 47), 529961000.0],
#   [datetime.datetime(2014, 10, 11, 20, 47), 528879000.0],
#   [datetime.datetime(2014, 10, 12, 20, 47), 542117000.0],
#   [datetime.datetime(2014, 10, 13, 20, 47), 537068000.0],
#   [datetime.datetime(2014, 10, 14, 20, 47), 565232000.0],
#   [datetime.datetime(2014, 10, 15, 20, 47), 544017000.0],
#   [datetime.datetime(2014, 10, 16, 20, 47), 532542000.0],
#   [datetime.datetime(2014, 10, 17, 20, 47), 544109000.0],
#   [datetime.datetime(2014, 10, 18, 20, 47), 547342000.0],
#   [datetime.datetime(2014, 10, 19, 20, 47), 541591000.0],
#   [datetime.datetime(2014, 10, 20, 20, 47), 536553000.0],
#   [datetime.datetime(2014, 10, 21, 20, 47), 544277000.0],
#   [datetime.datetime(2014, 10, 22, 20, 47), 536643000.0],
#   [datetime.datetime(2014, 10, 23, 20, 47), 518993000.0],
#   [datetime.datetime(2014, 10, 24, 20, 47), 514179000.0],
#   [datetime.datetime(2014, 10, 25, 20, 47), 496838000.0],
#   [datetime.datetime(2014, 10, 26, 19, 47), 491393000.0],
#   [datetime.datetime(2014, 10, 27, 19, 47), 513645000.0],
#   [datetime.datetime(2014, 10, 28, 19, 47), 504513000.0],
#   [datetime.datetime(2014, 10, 29, 19, 47), 488073000.0],
#   [datetime.datetime(2014, 10, 30, 19, 47), 479721000.0],
#   [datetime.datetime(2014, 10, 31, 19, 47), 477236000.0],
#   [datetime.datetime(2014, 11, 1, 19, 47), 455917000.0],
#   [datetime.datetime(2014, 11, 2, 19, 47), 457502000.0],
#   [datetime.datetime(2014, 11, 3, 19, 47), 463106000.0],
#   [datetime.datetime(2014, 11, 4, 19, 47), 466172000.0],
#   [datetime.datetime(2014, 11, 5, 19, 47), 482886000.0],
#   [datetime.datetime(2014, 11, 6, 19, 47), 482788000.0],
#   [datetime.datetime(2014, 11, 7, 19, 47), 477243000.0],
#   [datetime.datetime(2014, 11, 8, 19, 47), 485474000.0],
#   [datetime.datetime(2014, 11, 9, 19, 47), 496568000.0],
#   [datetime.datetime(2014, 11, 10, 19, 47), 505255000.0],
#   [datetime.datetime(2014, 11, 11, 19, 47), 497143000.0],
#   [datetime.datetime(2014, 11, 12, 19, 47), 545380000.0],
#   [datetime.datetime(2014, 11, 13, 19, 47), 529177000.0],
#   [datetime.datetime(2014, 11, 14, 19, 47), 522492000.0],
#   [datetime.datetime(2014, 11, 15, 19, 47), 504986000.0],
#   [datetime.datetime(2014, 11, 16, 19, 47), 514415000.0],
#   [datetime.datetime(2014, 11, 17, 19, 47), 520010000.0],
#   [datetime.datetime(2014, 11, 18, 19, 47), 508211000.0],
#   [datetime.datetime(2014, 11, 19, 19, 47), 521740000.0],
#   [datetime.datetime(2014, 11, 20, 19, 47), 519812000.0],
#   [datetime.datetime(2014, 11, 21, 19, 47), 539952000.0],
#   [datetime.datetime(2014, 11, 22, 19, 47), 568525000.0],
#   [datetime.datetime(2014, 11, 23, 19, 47), 603431000.0],
#   [datetime.datetime(2014, 11, 24, 19, 47), 637356000.0],
#   [datetime.datetime(2014, 11, 25, 19, 47), 664689000.0],
#   [datetime.datetime(2014, 11, 26, 19, 47), 686841000.0],
#   [datetime.datetime(2014, 11, 27, 19, 47), 778758000.0],
#   [datetime.datetime(2014, 11, 28, 19, 47), 831015000.0],
#   [datetime.datetime(2014, 11, 29, 19, 47), 810401000.0],
#   [datetime.datetime(2014, 11, 30, 19, 47), 744676000.0],
#   [datetime.datetime(2014, 12, 1, 19, 47), 731088000.0],
#   [datetime.datetime(2014, 12, 2, 19, 47), 787582000.0],
#   [datetime.datetime(2014, 12, 3, 19, 47), 791545000.0],
#   [datetime.datetime(2014, 12, 4, 19, 47), 786916000.0],
#   [datetime.datetime(2014, 12, 5, 19, 47), 800410000.0],
#   [datetime.datetime(2014, 12, 6, 19, 47), 825195000.0],
#   [datetime.datetime(2014, 12, 7, 19, 47), 839410000.0],
#   [datetime.datetime(2014, 12, 8, 19, 47), 793670000.0],
#   [datetime.datetime(2014, 12, 9, 19, 47), 819539000.0],
#   [datetime.datetime(2014, 12, 10, 19, 47), 842040000.0],
#   [datetime.datetime(2014, 12, 11, 19, 47), 867876000.0],
#   [datetime.datetime(2014, 12, 12, 19, 47), 870226000.0],
#   [datetime.datetime(2014, 12, 13, 19, 47), 886140000.0],
#   [datetime.datetime(2014, 12, 14, 19, 47), 888573000.0],
#   [datetime.datetime(2014, 12, 15, 19, 47), 911661000.0],
#   [datetime.datetime(2014, 12, 16, 19, 47), 1144450000.0],
#   [datetime.datetime(2014, 12, 17, 19, 47), 1178470000.0],
#   [datetime.datetime(2014, 12, 18, 19, 47), 1261210000.0],
#   [datetime.datetime(2014, 12, 19, 19, 47), 1148560000.0],
#   [datetime.datetime(2014, 12, 20, 19, 47), 1162840000.0],
#   [datetime.datetime(2014, 12, 21, 19, 47), 1235220000.0],
#   [datetime.datetime(2014, 12, 22, 19, 47), 1316740000.0],
#   [datetime.datetime(2014, 12, 23, 19, 47), 1238680000.0],
#   [datetime.datetime(2014, 12, 24, 19, 47), 1186090000.0],
#   [datetime.datetime(2014, 12, 25, 19, 47), 1201200000.0],
#   [datetime.datetime(2014, 12, 26, 19, 47), 1255850000.0],
#   [datetime.datetime(2014, 12, 27, 19, 47), 1205410000.0],
#   [datetime.datetime(2014, 12, 28, 19, 47), 1222520000.0],
#   [datetime.datetime(2014, 12, 29, 19, 47), 1244940000.0],
#   [datetime.datetime(2014, 12, 30, 19, 47), 1230690000.0],
#   [datetime.datetime(2014, 12, 31, 19, 47), 1226630000.0],
#   [datetime.datetime(2015, 1, 1, 19, 47), 1197740000.0],
#   [datetime.datetime(2015, 1, 2, 19, 47), 1167090000.0],
#   [datetime.datetime(2015, 1, 3, 19, 47), 1056370000.0],
#   [datetime.datetime(2015, 1, 4, 19, 47), 929329000.0],
#   [datetime.datetime(2015, 1, 5, 19, 47), 964343000.0],
#   [datetime.datetime(2015, 1, 6, 19, 47), 982395000.0],
#   [datetime.datetime(2015, 1, 7, 19, 47), 991633000.0],
#   [datetime.datetime(2015, 1, 8, 19, 47), 995648000.0],
#   [datetime.datetime(2015, 1, 9, 19, 47), 981760000.0],
#   [datetime.datetime(2015, 1, 10, 19, 47), 918681000.0],
#   [datetime.datetime(2015, 1, 11, 19, 47), 894899000.0],
#   [datetime.datetime(2015, 1, 12, 19, 47), 908503000.0],
#   [datetime.datetime(2015, 1, 13, 19, 47), 780680000.0],
#   [datetime.datetime(2015, 1, 14, 19, 47), 678802000.0],
#   [datetime.datetime(2015, 1, 15, 19, 47), 784938000.0],
#   [datetime.datetime(2015, 1, 16, 19, 47), 785764000.0],
#   [datetime.datetime(2015, 1, 17, 19, 47), 738269000.0],
#   [datetime.datetime(2015, 1, 18, 19, 47), 738315000.0],
#   [datetime.datetime(2015, 1, 19, 19, 47), 748796000.0],
#   [datetime.datetime(2015, 1, 20, 19, 47), 755792000.0],
#   [datetime.datetime(2015, 1, 21, 19, 47), 766946000.0],
#   [datetime.datetime(2015, 1, 22, 19, 47), 799918000.0],
#   [datetime.datetime(2015, 1, 23, 19, 47), 789356000.0],
#   [datetime.datetime(2015, 1, 24, 19, 47), 812009000.0],
#   [datetime.datetime(2015, 1, 25, 19, 47), 813913000.0],
#   [datetime.datetime(2015, 1, 26, 19, 47), 803715000.0],
#   [datetime.datetime(2015, 1, 27, 19, 47), 793259000.0],
#   [datetime.datetime(2015, 1, 28, 19, 47), 753885000.0],
#   [datetime.datetime(2015, 1, 29, 19, 47), 732630000.0],
#   [datetime.datetime(2015, 1, 30, 19, 47), 716554000.0],
#   [datetime.datetime(2015, 1, 31, 19, 47), 725233000.0],
#   [datetime.datetime(2015, 2, 1, 19, 47), 702022000.0],
#   [datetime.datetime(2015, 2, 2, 19, 47), 677968000.0],
#   [datetime.datetime(2015, 2, 3, 19, 47), 663962000.0],
#   [datetime.datetime(2015, 2, 4, 19, 47), 664371000.0],
#   [datetime.datetime(2015, 2, 5, 19, 47), 676131000.0],
#   [datetime.datetime(2015, 2, 6, 19, 47), 737186000.0],
#   [datetime.datetime(2015, 2, 7, 19, 47), 714281000.0],
#   [datetime.datetime(2015, 2, 8, 19, 47), 709130000.0],
#   [datetime.datetime(2015, 2, 9, 19, 47), 695826000.0],
#   [datetime.datetime(2015, 2, 10, 19, 47), 685140000.0],
#   [datetime.datetime(2015, 2, 11, 19, 47), 691767000.0],
#   [datetime.datetime(2015, 2, 12, 19, 47), 699809000.0],
#   [datetime.datetime(2015, 2, 13, 19, 47), 733001000.0],
#   [datetime.datetime(2015, 2, 14, 19, 47), 734792000.0],
#   [datetime.datetime(2015, 2, 15, 19, 47), 710621000.0],
#   [datetime.datetime(2015, 2, 16, 19, 47), 697338000.0],
#   [datetime.datetime(2015, 2, 17, 19, 47), 707683000.0],
#   [datetime.datetime(2015, 2, 18, 19, 47), 688987000.0],
#   [datetime.datetime(2015, 2, 19, 19, 47), 697313000.0],
#   [datetime.datetime(2015, 2, 20, 19, 47), 686548000.0],
#   [datetime.datetime(2015, 2, 21, 19, 47), 678598000.0],
#   [datetime.datetime(2015, 2, 22, 19, 47), 661213000.0],
#   [datetime.datetime(2015, 2, 23, 19, 47), 676680000.0],
#   [datetime.datetime(2015, 2, 24, 19, 47), 685071000.0],
#   [datetime.datetime(2015, 2, 25, 19, 47), 689518000.0],
#   [datetime.datetime(2015, 2, 26, 19, 47), 687085000.0],
#   [datetime.datetime(2015, 2, 27, 19, 47), 701451000.0],
#   [datetime.datetime(2015, 2, 28, 19, 47), 689766000.0],
#   [datetime.datetime(2015, 3, 1, 19, 47), 659057000.0],
#   [datetime.datetime(2015, 3, 2, 19, 47), 660104000.0],
#   [datetime.datetime(2015, 3, 3, 19, 47), 623979000.0],
#   [datetime.datetime(2015, 3, 4, 19, 47), 593296000.0],
#   [datetime.datetime(2015, 3, 5, 19, 47), 624609000.0],
#   [datetime.datetime(2015, 3, 6, 19, 47), 614565000.0],
#   [datetime.datetime(2015, 3, 7, 19, 47), 613530000.0],
#   [datetime.datetime(2015, 3, 8, 19, 47), 590230000.0],
#   [datetime.datetime(2015, 3, 9, 19, 47), 620074000.0],
#   [datetime.datetime(2015, 3, 10, 19, 47), 605072000.0],
#   [datetime.datetime(2015, 3, 11, 19, 47), 606489000.0],
#   [datetime.datetime(2015, 3, 12, 19, 47), 609695000.0],
#   [datetime.datetime(2015, 3, 13, 19, 47), 609164000.0],
#   [datetime.datetime(2015, 3, 14, 19, 47), 622586000.0],
#   [datetime.datetime(2015, 3, 15, 19, 47), 616376000.0],
#   [datetime.datetime(2015, 3, 16, 19, 47), 625373000.0],
#   [datetime.datetime(2015, 3, 17, 19, 47), 617453000.0],
#   [datetime.datetime(2015, 3, 18, 19, 47), 601956000.0],
#   [datetime.datetime(2015, 3, 19, 19, 47), 584798000.0],
#   [datetime.datetime(2015, 3, 20, 19, 47), 594318000.0],
#   [datetime.datetime(2015, 3, 21, 19, 47), 583602000.0],
#   [datetime.datetime(2015, 3, 22, 19, 47), 585772000.0],
#   [datetime.datetime(2015, 3, 23, 19, 47), 586476000.0],
#   [datetime.datetime(2015, 3, 24, 19, 47), 566466000.0],
#   [datetime.datetime(2015, 3, 25, 19, 47), 538736000.0],
#   [datetime.datetime(2015, 3, 26, 19, 47), 535806000.0],
#   [datetime.datetime(2015, 3, 27, 19, 47), 535972000.0],
#   [datetime.datetime(2015, 3, 28, 19, 47), 539776000.0],
#   [datetime.datetime(2015, 3, 29, 20, 47), 523321000.0],
#   [datetime.datetime(2015, 3, 30, 20, 47), 517637000.0],
#   [datetime.datetime(2015, 3, 31, 20, 47), 499740000.0],
#   [datetime.datetime(2015, 4, 1, 20, 47), 486166000.0],
#   [datetime.datetime(2015, 4, 2, 20, 47), 503882000.0],
#   [datetime.datetime(2015, 4, 3, 20, 47), 532795000.0],
#   [datetime.datetime(2015, 4, 4, 20, 47), 538041000.0],
#   [datetime.datetime(2015, 4, 5, 20, 47), 526767000.0],
#   [datetime.datetime(2015, 4, 6, 20, 47), 526723000.0],
#   [datetime.datetime(2015, 4, 7, 20, 47), 540462000.0],
#   [datetime.datetime(2015, 4, 8, 20, 47), 533843000.0],
#   [datetime.datetime(2015, 4, 9, 20, 47), 520620000.0],
#   [datetime.datetime(2015, 4, 10, 20, 47), 500201000.0],
#   [datetime.datetime(2015, 4, 11, 20, 47), 491648000.0],
#   [datetime.datetime(2015, 4, 12, 20, 47), 498748000.0],
#   [datetime.datetime(2015, 4, 13, 20, 47), 477420000.0],
#   [datetime.datetime(2015, 4, 14, 20, 47), 467499000.0],
#   [datetime.datetime(2015, 4, 15, 20, 47), 462391000.0],
#   [datetime.datetime(2015, 4, 16, 20, 47), 473225000.0],
#   [datetime.datetime(2015, 4, 17, 20, 47), 473328000.0],
#   [datetime.datetime(2015, 4, 18, 20, 47), 466901000.0],
#   [datetime.datetime(2015, 4, 19, 20, 47), 467161000.0],
#   [datetime.datetime(2015, 4, 20, 20, 47), 466030000.0],
#   [datetime.datetime(2015, 4, 21, 20, 47), 463374000.0],
#   [datetime.datetime(2015, 4, 22, 20, 47), 479166000.0],
#   [datetime.datetime(2015, 4, 23, 20, 47), 479465000.0],
#   [datetime.datetime(2015, 4, 24, 20, 47), 475027000.0],
#   [datetime.datetime(2015, 4, 25, 20, 47), 477749000.0],
#   [datetime.datetime(2015, 4, 26, 20, 47), 449862000.0],
#   [datetime.datetime(2015, 4, 27, 20, 47), 452714000.0],
#   [datetime.datetime(2015, 4, 28, 20, 47), 449089000.0],
#   [datetime.datetime(2015, 4, 29, 20, 47), 454883000.0],
#   [datetime.datetime(2015, 4, 30, 20, 47), 469860000.0],
#   [datetime.datetime(2015, 5, 1, 20, 47), 467535000.0],
#   [datetime.datetime(2015, 5, 2, 20, 47), 467195000.0],
#   [datetime.datetime(2015, 5, 3, 20, 47), 470999000.0],
#   [datetime.datetime(2015, 5, 4, 20, 47), 466106000.0],
#   [datetime.datetime(2015, 5, 5, 20, 47), 461153000.0],
#   [datetime.datetime(2015, 5, 6, 20, 47), 457801000.0],
#   [datetime.datetime(2015, 5, 7, 20, 47), 453693000.0],
#   [datetime.datetime(2015, 5, 8, 20, 47), 453131000.0],
#   [datetime.datetime(2015, 5, 9, 20, 47), 451503000.0],
#   [datetime.datetime(2015, 5, 10, 20, 47), 445702000.0],
#   [datetime.datetime(2015, 5, 11, 20, 47), 449458000.0],
#   [datetime.datetime(2015, 5, 12, 20, 47), 451033000.0],
#   [datetime.datetime(2015, 5, 13, 20, 47), 448926000.0],
#   [datetime.datetime(2015, 5, 14, 20, 47), 431142000.0],
#   [datetime.datetime(2015, 5, 15, 20, 47), 437034000.0],
#   [datetime.datetime(2015, 5, 16, 20, 47), 432200000.0],
#   [datetime.datetime(2015, 5, 17, 20, 47), 424223000.0],
#   [datetime.datetime(2015, 5, 18, 20, 47), 412450000.0],
#   [datetime.datetime(2015, 5, 19, 20, 47), 435607000.0],
#   [datetime.datetime(2015, 5, 20, 20, 47), 447488000.0],
#   [datetime.datetime(2015, 5, 21, 20, 47), 448142000.0],
#   [datetime.datetime(2015, 5, 22, 20, 47), 473257000.0],
#   [datetime.datetime(2015, 5, 23, 20, 47), 482755000.0],
#   [datetime.datetime(2015, 5, 24, 20, 47), 484332000.0],
#   [datetime.datetime(2015, 5, 25, 20, 47), 486747000.0],
#   [datetime.datetime(2015, 5, 26, 20, 47), 486066000.0],
#   [datetime.datetime(2015, 5, 27, 20, 47), 498727000.0],
#   [datetime.datetime(2015, 5, 28, 20, 47), 533866000.0],
#   [datetime.datetime(2015, 5, 29, 20, 47), 567101000.0],
#   [datetime.datetime(2015, 5, 30, 20, 47), 543495000.0],
#   [datetime.datetime(2015, 5, 31, 20, 47), 531531000.0],
#   [datetime.datetime(2015, 6, 1, 20, 47), 497028000.0],
#   [datetime.datetime(2015, 6, 2, 20, 47), 508487000.0],
#   [datetime.datetime(2015, 6, 3, 20, 47), 520109000.0],
#   [datetime.datetime(2015, 6, 4, 20, 47), 516078000.0],
#   [datetime.datetime(2015, 6, 5, 20, 47), 521676000.0],
#   [datetime.datetime(2015, 6, 6, 20, 47), 523497000.0],
#   [datetime.datetime(2015, 6, 7, 20, 47), 519089000.0],
#   [datetime.datetime(2015, 6, 8, 20, 47), 524004000.0],
#   [datetime.datetime(2015, 6, 9, 20, 47), 525282000.0],
#   [datetime.datetime(2015, 6, 10, 20, 47), 525360000.0],
#   [datetime.datetime(2015, 6, 11, 20, 47), 526175000.0],
#   [datetime.datetime(2015, 6, 12, 20, 47), 525903000.0],
#   [datetime.datetime(2015, 6, 13, 20, 47), 535149000.0],
#   [datetime.datetime(2015, 6, 14, 20, 47), 544822000.0],
#   [datetime.datetime(2015, 6, 15, 20, 47), 559669000.0],
#   [datetime.datetime(2015, 6, 16, 20, 47), 618911000.0],
#   [datetime.datetime(2015, 6, 17, 20, 47), 665477000.0],
#   [datetime.datetime(2015, 6, 18, 20, 47), 686062000.0],
#   [datetime.datetime(2015, 6, 19, 20, 47), 705210000.0],
#   [datetime.datetime(2015, 6, 20, 20, 47), 705348000.0],
#   [datetime.datetime(2015, 6, 21, 20, 47), 691628000.0],
#   [datetime.datetime(2015, 6, 22, 20, 47), 688278000.0],
#   [datetime.datetime(2015, 6, 23, 20, 47), 690253000.0],
#   [datetime.datetime(2015, 6, 24, 20, 47), 682725000.0],
#   [datetime.datetime(2015, 6, 25, 20, 47), 693315000.0],
#   [datetime.datetime(2015, 6, 26, 20, 47), 696148000.0],
#   [datetime.datetime(2015, 6, 27, 20, 47), 718839000.0],
#   [datetime.datetime(2015, 6, 28, 20, 47), 719270000.0],
#   [datetime.datetime(2015, 6, 29, 20, 47), 770667000.0],
#   [datetime.datetime(2015, 6, 30, 20, 47), 769913000.0],
#   [datetime.datetime(2015, 7, 1, 20, 47), 751222000.0],
#   [datetime.datetime(2015, 7, 2, 20, 47), 751830000.0],
#   [datetime.datetime(2015, 7, 3, 20, 47), 753960000.0],
#   [datetime.datetime(2015, 7, 4, 20, 47), 748783000.0],
#   [datetime.datetime(2015, 7, 5, 20, 47), 743319000.0],
#   [datetime.datetime(2015, 7, 6, 20, 47), 790896000.0],
#   [datetime.datetime(2015, 7, 7, 20, 47), 763797000.0],
#   [datetime.datetime(2015, 7, 8, 20, 47), 792956000.0],
#   [datetime.datetime(2015, 7, 9, 20, 47), 848990000.0],
#   [datetime.datetime(2015, 7, 10, 20, 47), 779444000.0],
#   [datetime.datetime(2015, 7, 11, 20, 47), 702401000.0],
#   [datetime.datetime(2015, 7, 12, 20, 47), 753937000.0],
#   [datetime.datetime(2015, 7, 13, 20, 47), 719344000.0],
#   [datetime.datetime(2015, 7, 14, 20, 47), 730682000.0],
#   [datetime.datetime(2015, 7, 15, 20, 47), 706520000.0],
#   [datetime.datetime(2015, 7, 16, 20, 47), 625416000.0],
#   [datetime.datetime(2015, 7, 17, 20, 47), 649706000.0],
#   [datetime.datetime(2015, 7, 18, 20, 47), 654796000.0],
#   [datetime.datetime(2015, 7, 19, 20, 47), 649486000.0],
#   [datetime.datetime(2015, 7, 20, 20, 47), 645688000.0],
#   [datetime.datetime(2015, 7, 21, 20, 47), 643181000.0],
#   [datetime.datetime(2015, 7, 22, 20, 47), 638162000.0],
#   [datetime.datetime(2015, 7, 23, 20, 47), 631498000.0],
#   [datetime.datetime(2015, 7, 24, 20, 47), 678916000.0],
#   [datetime.datetime(2015, 7, 25, 20, 47), 688518000.0],
#   [datetime.datetime(2015, 7, 26, 20, 47), 696254000.0],
#   [datetime.datetime(2015, 7, 27, 20, 47), 712204000.0],
#   [datetime.datetime(2015, 7, 28, 20, 47), 729735000.0],
#   [datetime.datetime(2015, 7, 29, 20, 47), 719222000.0],
#   [datetime.datetime(2015, 7, 30, 20, 47), 704284000.0],
#   [datetime.datetime(2015, 7, 31, 20, 47), 704698000.0],
#   [datetime.datetime(2015, 8, 1, 20, 47), 671964000.0],
#   [datetime.datetime(2015, 8, 2, 20, 47), 666681000.0],
#   [datetime.datetime(2015, 8, 3, 20, 47), 680933000.0],
#   [datetime.datetime(2015, 8, 4, 20, 47), 682329000.0],
#   [datetime.datetime(2015, 8, 5, 20, 47), 679000000.0],
#   [datetime.datetime(2015, 8, 6, 20, 47), 661538000.0],
#   [datetime.datetime(2015, 8, 7, 20, 47), 814142000.0],
#   [datetime.datetime(2015, 8, 8, 20, 47), 712758000.0],
#   [datetime.datetime(2015, 8, 9, 20, 47), 699605000.0],
#   [datetime.datetime(2015, 8, 10, 20, 47), 700479000.0],
#   [datetime.datetime(2015, 8, 11, 20, 47), 712598000.0],
#   [datetime.datetime(2015, 8, 12, 20, 47), 724885000.0],
#   [datetime.datetime(2015, 8, 13, 20, 47), 749640000.0],
#   [datetime.datetime(2015, 8, 14, 20, 47), 764350000.0],
#   [datetime.datetime(2015, 8, 15, 20, 47), 757514000.0],
#   [datetime.datetime(2015, 8, 16, 20, 47), 720594000.0],
#   [datetime.datetime(2015, 8, 17, 20, 47), 733599000.0],
# ...
#   [datetime.datetime(2015, 4, 9, 20, 47), 3283100.0],
#   [datetime.datetime(2015, 4, 10, 20, 47), 3688190.0],
#   [datetime.datetime(2015, 4, 11, 20, 47), 2598570.0],
#   [datetime.datetime(2015, 4, 12, 20, 47), 2026160.0],
#   [datetime.datetime(2015, 4, 13, 20, 47), 2425610.0],
#   [datetime.datetime(2015, 4, 14, 20, 47), 3640350.0],
#   [datetime.datetime(2015, 4, 15, 20, 47), 2522860.0],
#   [datetime.datetime(2015, 4, 16, 20, 47), 2646430.0],
#   [datetime.datetime(2015, 4, 17, 20, 47), 2432680.0],
#   [datetime.datetime(2015, 4, 18, 20, 47), 1623340.0],
#   [datetime.datetime(2015, 4, 19, 20, 47), 1767900.0],
#   [datetime.datetime(2015, 4, 20, 20, 47), 2573800.0],
#   [datetime.datetime(2015, 4, 21, 20, 47), 2301130.0],
#   [datetime.datetime(2015, 4, 22, 20, 47), 3081300.0],
#   [datetime.datetime(2015, 4, 23, 20, 47), 2532220.0],
#   [datetime.datetime(2015, 4, 24, 20, 47), 2406700.0],
#   [datetime.datetime(2015, 4, 25, 20, 47), 1870600.0],
#   [datetime.datetime(2015, 4, 26, 20, 47), 2505390.0],
#   [datetime.datetime(2015, 4, 27, 20, 47), 2613800.0],
#   [datetime.datetime(2015, 4, 28, 20, 47), 2937490.0],
#   [datetime.datetime(2015, 4, 29, 20, 47), 2508840.0],
#   [datetime.datetime(2015, 4, 30, 20, 47), 3378740.0],
#   [datetime.datetime(2015, 5, 1, 20, 47), 2899870.0],
#   [datetime.datetime(2015, 5, 2, 20, 47), 1782630.0],
#   [datetime.datetime(2015, 5, 3, 20, 47), 2435460.0],
#   [datetime.datetime(2015, 5, 4, 20, 47), 2698170.0],
#   [datetime.datetime(2015, 5, 5, 20, 47), 2355240.0],
#   [datetime.datetime(2015, 5, 6, 20, 47), 2190860.0],
#   [datetime.datetime(2015, 5, 7, 20, 47), 3904910.0],
#   [datetime.datetime(2015, 5, 8, 20, 47), 2976440.0],
#   [datetime.datetime(2015, 5, 9, 20, 47), 2205550.0],
#   [datetime.datetime(2015, 5, 10, 20, 47), 2299270.0],
#   [datetime.datetime(2015, 5, 11, 20, 47), 1928110.0],
#   [datetime.datetime(2015, 5, 12, 20, 47), 3203130.0],
#   [datetime.datetime(2015, 5, 13, 20, 47), 2460350.0],
#   [datetime.datetime(2015, 5, 14, 20, 47), 3639760.0],
#   [datetime.datetime(2015, 5, 15, 20, 47), 1949320.0],
#   [datetime.datetime(2015, 5, 16, 20, 47), 1541400.0],
#   [datetime.datetime(2015, 5, 17, 20, 47), 1437230.0],
#   [datetime.datetime(2015, 5, 18, 20, 47), 3150440.0],
#   [datetime.datetime(2015, 5, 19, 20, 47), 3710990.0],
#   [datetime.datetime(2015, 5, 20, 20, 47), 2639940.0],
#   [datetime.datetime(2015, 5, 21, 20, 47), 7100350.0],
#   [datetime.datetime(2015, 5, 22, 20, 47), 10566900.0],
#   [datetime.datetime(2015, 5, 23, 20, 47), 9343270.0],
#   [datetime.datetime(2015, 5, 24, 20, 47), 7338150.0],
#   [datetime.datetime(2015, 5, 25, 20, 47), 8225200.0],
#   [datetime.datetime(2015, 5, 26, 20, 47), 8333520.0],
#   [datetime.datetime(2015, 5, 27, 20, 47), 9807410.0],
#   [datetime.datetime(2015, 5, 28, 20, 47), 11085200.0],
#   [datetime.datetime(2015, 5, 29, 20, 47), 10795500.0],
#   [datetime.datetime(2015, 5, 30, 20, 47), 8538810.0],
#   [datetime.datetime(2015, 5, 31, 20, 47), 7318680.0],
#   [datetime.datetime(2015, 6, 1, 20, 47), 7738640.0],
#   [datetime.datetime(2015, 6, 2, 20, 47), 7988830.0],
#   [datetime.datetime(2015, 6, 3, 20, 47), 6552620.0],
#   [datetime.datetime(2015, 6, 4, 20, 47), 5698490.0],
#   [datetime.datetime(2015, 6, 5, 20, 47), 6316350.0],
#   [datetime.datetime(2015, 6, 6, 20, 47), 5681480.0],
#   [datetime.datetime(2015, 6, 7, 20, 47), 5547450.0],
#   [datetime.datetime(2015, 6, 8, 20, 47), 6179490.0],
#   [datetime.datetime(2015, 6, 9, 20, 47), 5837260.0],
#   [datetime.datetime(2015, 6, 10, 20, 47), 6368110.0],
#   [datetime.datetime(2015, 6, 11, 20, 47), 6323470.0],
#   [datetime.datetime(2015, 6, 12, 20, 47), 5831150.0],
#   [datetime.datetime(2015, 6, 13, 20, 47), 7106910.0],
#   [datetime.datetime(2015, 6, 14, 20, 47), 8876940.0],
#   [datetime.datetime(2015, 6, 15, 20, 47), 7005650.0],
#   [datetime.datetime(2015, 6, 16, 20, 47), 15235200.0],
#   [datetime.datetime(2015, 6, 17, 20, 47), 24490300.0],
#   [datetime.datetime(2015, 6, 18, 20, 47), 16313100.0],
#   [datetime.datetime(2015, 6, 19, 20, 47), 14563300.0],
#   [datetime.datetime(2015, 6, 20, 20, 47), 9762870.0],
#   [datetime.datetime(2015, 6, 21, 20, 47), 20360300.0],
#   [datetime.datetime(2015, 6, 22, 20, 47), 20703900.0],
#   [datetime.datetime(2015, 6, 23, 20, 47), 7675070.0],
#   [datetime.datetime(2015, 6, 24, 20, 47), 9571780.0],
#   [datetime.datetime(2015, 6, 25, 20, 47), 9190760.0],
#   [datetime.datetime(2015, 6, 26, 20, 47), 6646040.0],
#   [datetime.datetime(2015, 6, 27, 20, 47), 8286930.0],
#   [datetime.datetime(2015, 6, 28, 20, 47), 8619600.0],
#   [datetime.datetime(2015, 6, 29, 20, 47), 15818500.0],
#   [datetime.datetime(2015, 6, 30, 20, 47), 24948400.0],
#   [datetime.datetime(2015, 7, 1, 20, 47), 13477100.0],
#   [datetime.datetime(2015, 7, 2, 20, 47), 10947900.0],
#   [datetime.datetime(2015, 7, 3, 20, 47), 8256620.0],
#   [datetime.datetime(2015, 7, 4, 20, 47), 7662110.0],
#   [datetime.datetime(2015, 7, 5, 20, 47), 11680200.0],
#   [datetime.datetime(2015, 7, 6, 20, 47), 32931600.0],
#   [datetime.datetime(2015, 7, 7, 20, 47), 22603600.0],
#   [datetime.datetime(2015, 7, 8, 20, 47), 27730400.0],
#   [datetime.datetime(2015, 7, 9, 20, 47), 46974400.0],
#   [datetime.datetime(2015, 7, 10, 20, 47), 75301800.0],
#   [datetime.datetime(2015, 7, 11, 20, 47), 37807100.0],
#   [datetime.datetime(2015, 7, 12, 20, 47), 26557200.0],
#   [datetime.datetime(2015, 7, 13, 20, 47), 20583000.0],
#   [datetime.datetime(2015, 7, 14, 20, 47), 12391400.0],
#   [datetime.datetime(2015, 7, 15, 20, 47), 10808300.0],
#   [datetime.datetime(2015, 7, 16, 20, 47), 22197900.0],
#   [datetime.datetime(2015, 7, 17, 20, 47), 14150600.0],
#   [datetime.datetime(2015, 7, 18, 20, 47), 12114300.0],
#   [datetime.datetime(2015, 7, 19, 20, 47), 6644140.0],
#   [datetime.datetime(2015, 7, 20, 20, 47), 7508540.0],
#   [datetime.datetime(2015, 7, 21, 20, 47), 7983870.0],
#   [datetime.datetime(2015, 7, 22, 20, 47), 6219560.0],
#   [datetime.datetime(2015, 7, 23, 20, 47), 4779830.0],
#   [datetime.datetime(2015, 7, 24, 20, 47), 13374000.0],
#   [datetime.datetime(2015, 7, 25, 20, 47), 17275600.0],
#   [datetime.datetime(2015, 7, 26, 20, 47), 10736400.0],
#   [datetime.datetime(2015, 7, 27, 20, 47), 7946370.0],
#   [datetime.datetime(2015, 7, 28, 20, 47), 13980200.0],
#   [datetime.datetime(2015, 7, 29, 20, 47), 10005100.0],
#   [datetime.datetime(2015, 7, 30, 20, 47), 8035240.0],
#   [datetime.datetime(2015, 7, 31, 20, 47), 7176710.0],
#   [datetime.datetime(2015, 8, 1, 20, 47), 8243480.0],
#   [datetime.datetime(2015, 8, 2, 20, 47), 8297830.0],
#   [datetime.datetime(2015, 8, 3, 20, 47), 7727390.0],
#   [datetime.datetime(2015, 8, 4, 20, 47), 6475910.0],
#   [datetime.datetime(2015, 8, 5, 20, 47), 4755420.0],
#   [datetime.datetime(2015, 8, 6, 20, 47), 5881100.0],
#   [datetime.datetime(2015, 8, 7, 20, 47), 21100300.0],
#   [datetime.datetime(2015, 8, 8, 20, 47), 26509400.0],
#   [datetime.datetime(2015, 8, 9, 20, 47), 21425200.0],
#   [datetime.datetime(2015, 8, 10, 20, 47), 4544300.0],
#   [datetime.datetime(2015, 8, 11, 20, 47), 5199060.0],
#   [datetime.datetime(2015, 8, 12, 20, 47), 8458730.0],
#   [datetime.datetime(2015, 8, 13, 20, 47), 7515730.0],
#   [datetime.datetime(2015, 8, 14, 20, 47), 10450400.0],
#   [datetime.datetime(2015, 8, 15, 20, 47), 6159260.0],
#   [datetime.datetime(2015, 8, 16, 20, 47), 8686960.0],
#   [datetime.datetime(2015, 8, 17, 20, 47), 6463820.0],
#   [datetime.datetime(2015, 8, 18, 20, 47), 5547660.0],
#   [datetime.datetime(2015, 8, 19, 20, 47), 11233200.0],
#   [datetime.datetime(2015, 8, 20, 20, 47), 8824200.0],
#   [datetime.datetime(2015, 8, 21, 20, 47), 6379010.0],
#   [datetime.datetime(2015, 8, 22, 20, 47), 5538370.0],
#   [datetime.datetime(2015, 8, 23, 20, 47), 6045080.0],
#   [datetime.datetime(2015, 8, 24, 20, 47), 10355800.0],
#   [datetime.datetime(2015, 8, 25, 20, 47), 15747000.0],
#   [datetime.datetime(2015, 8, 26, 20, 47), 9905690.0],
#   [datetime.datetime(2015, 8, 27, 20, 47), 5215120.0],
#   [datetime.datetime(2015, 8, 28, 20, 47), 8116100.0],
#   [datetime.datetime(2015, 8, 29, 20, 47), 4902280.0],
#   [datetime.datetime(2015, 8, 30, 20, 47), 5357750.0],
#   [datetime.datetime(2015, 8, 31, 20, 47), 6550860.0],
#   [datetime.datetime(2015, 9, 1, 20, 47), 4886850.0],
#   [datetime.datetime(2015, 9, 2, 20, 47), 5480200.0],
#   [datetime.datetime(2015, 9, 3, 20, 47), 4945740.0],
#   [datetime.datetime(2015, 9, 4, 20, 47), 3314780.0],
#   [datetime.datetime(2015, 9, 5, 20, 47), 4665600.0],
#   [datetime.datetime(2015, 9, 6, 20, 47), 8643830.0],
#   [datetime.datetime(2015, 9, 7, 20, 47), 6146210.0],
#   [datetime.datetime(2015, 9, 8, 20, 47), 5896310.0],
#   [datetime.datetime(2015, 9, 9, 20, 47), 6122040.0],
#   [datetime.datetime(2015, 9, 10, 20, 47), 5241220.0],
#   [datetime.datetime(2015, 9, 11, 20, 47), 6070660.0],
#   [datetime.datetime(2015, 9, 12, 20, 47), 4295760.0],
#   [datetime.datetime(2015, 9, 13, 20, 47), 4070890.0],
#   [datetime.datetime(2015, 9, 14, 20, 47), 4776530.0],
#   [datetime.datetime(2015, 9, 15, 20, 47), 5130730.0],
#   [datetime.datetime(2015, 9, 16, 20, 47), 4976910.0],
#   [datetime.datetime(2015, 9, 17, 20, 47), 5806800.0],
#   [datetime.datetime(2015, 9, 18, 20, 47), 5405620.0],
#   [datetime.datetime(2015, 9, 19, 20, 47), 4133510.0],
#   [datetime.datetime(2015, 9, 20, 20, 47), 4159830.0],
#   [datetime.datetime(2015, 9, 21, 20, 47), 5282360.0],
#   [datetime.datetime(2015, 9, 22, 20, 47), 5423840.0],
#   [datetime.datetime(2015, 9, 23, 20, 47), 4759620.0],
#   [datetime.datetime(2015, 9, 24, 20, 47), 5127170.0],
#   [datetime.datetime(2015, 9, 25, 20, 47), 4818890.0],
#   [datetime.datetime(2015, 9, 26, 20, 47), 2264900.0],
#   [datetime.datetime(2015, 9, 27, 20, 47), 2121740.0],
#   [datetime.datetime(2015, 9, 28, 20, 47), 6394160.0],
#   [datetime.datetime(2015, 9, 29, 20, 47), 7940610.0],
#   [datetime.datetime(2015, 9, 30, 20, 47), 5911260.0],
#   [datetime.datetime(2015, 10, 1, 20, 47), 3768380.0],
#   [datetime.datetime(2015, 10, 2, 20, 47), 3236560.0],
#   [datetime.datetime(2015, 10, 3, 20, 47), 2448510.0],
#   [datetime.datetime(2015, 10, 4, 20, 47), 2514050.0],
#   [datetime.datetime(2015, 10, 5, 20, 47), 2647400.0],
#   [datetime.datetime(2015, 10, 6, 20, 47), 3246900.0],
#   [datetime.datetime(2015, 10, 7, 20, 47), 3199360.0],
#   [datetime.datetime(2015, 10, 8, 20, 47), 4489760.0],
#   [datetime.datetime(2015, 10, 9, 20, 47), 4626570.0],
#   [datetime.datetime(2015, 10, 10, 20, 47), 4015780.0],
#   [datetime.datetime(2015, 10, 11, 20, 47), 3232200.0],
#   [datetime.datetime(2015, 10, 12, 20, 47), 4111410.0],
#   [datetime.datetime(2015, 10, 13, 20, 47), 4795410.0],
#   [datetime.datetime(2015, 10, 14, 20, 47), 5493810.0],
#   [datetime.datetime(2015, 10, 15, 20, 47), 5801270.0],
#   [datetime.datetime(2015, 10, 16, 20, 47), 4458360.0],
#   [datetime.datetime(2015, 10, 17, 20, 47), 5529000.0],
#   [datetime.datetime(2015, 10, 18, 20, 47), 3572030.0],
#   [datetime.datetime(2015, 10, 19, 20, 47), 4211720.0],
#   [datetime.datetime(2015, 10, 20, 20, 47), 4075670.0],
#   [datetime.datetime(2015, 10, 21, 20, 47), 4225020.0],
#   [datetime.datetime(2015, 10, 22, 20, 47), 4446810.0],
#   [datetime.datetime(2015, 10, 23, 20, 47), 4932620.0],
#   [datetime.datetime(2015, 10, 24, 20, 47), 3179140.0],
#   [datetime.datetime(2015, 10, 25, 19, 47), 4124600.0],
#   [datetime.datetime(2015, 10, 26, 19, 47), 4735920.0],
#   [datetime.datetime(2015, 10, 27, 19, 47), 5891000.0],
#   [datetime.datetime(2015, 10, 28, 19, 47), 5296800.0],
#   [datetime.datetime(2015, 10, 29, 19, 47), 14047500.0],
#   [datetime.datetime(2015, 10, 30, 19, 47), 23991900.0],
#   [datetime.datetime(2015, 10, 31, 19, 47), 8665960.0],
#   [datetime.datetime(2015, 11, 1, 19, 47), 6772790.0],
#   [datetime.datetime(2015, 11, 2, 19, 47), 8816170.0],
#   [datetime.datetime(2015, 11, 3, 19, 47), 25027600.0],
#   [datetime.datetime(2015, 11, 4, 19, 47), 33680200.0],
#   [datetime.datetime(2015, 11, 5, 19, 47), 25760900.0],
#   [datetime.datetime(2015, 11, 6, 19, 47), 14525400.0],
#   [datetime.datetime(2015, 11, 7, 19, 47), 8097730.0],
#   [datetime.datetime(2015, 11, 8, 19, 47), 5334450.0],
#   [datetime.datetime(2015, 11, 9, 19, 47), 10227900.0],
#   [datetime.datetime(2015, 11, 10, 19, 47), 8272580.0],
#   [datetime.datetime(2015, 11, 11, 19, 47), 8823090.0],
#   [datetime.datetime(2015, 11, 12, 19, 47), 7619290.0],
#   [datetime.datetime(2015, 11, 13, 19, 47), 5687310.0],
#   [datetime.datetime(2015, 11, 14, 19, 47), 3119610.0],
#   [datetime.datetime(2015, 11, 15, 19, 47), 3897140.0],
#   [datetime.datetime(2015, 11, 16, 19, 47), 3964620.0],
#   [datetime.datetime(2015, 11, 17, 19, 47), 5139330.0],
#   [datetime.datetime(2015, 11, 18, 19, 47), 4093470.0],
#   [datetime.datetime(2015, 11, 19, 19, 47), 5311150.0],
#   [datetime.datetime(2015, 11, 20, 19, 47), 4610550.0],
#   [datetime.datetime(2015, 11, 21, 19, 47), 3626790.0],
#   [datetime.datetime(2015, 11, 22, 19, 47), 2930620.0],
#   [datetime.datetime(2015, 11, 23, 19, 47), 3573840.0],
#   [datetime.datetime(2015, 11, 24, 19, 47), 3846180.0],
#   [datetime.datetime(2015, 11, 25, 19, 47), 5595350.0],
#   [datetime.datetime(2015, 11, 26, 19, 47), 13320400.0],
#   [datetime.datetime(2015, 11, 27, 19, 47), 6113740.0],
#   [datetime.datetime(2015, 11, 28, 19, 47), 4375350.0],
#   [datetime.datetime(2015, 11, 29, 19, 47), 4493190.0],
#   [datetime.datetime(2015, 11, 30, 19, 47), 7075790.0],
#   [datetime.datetime(2015, 12, 1, 19, 47), 6244520.0],
#   [datetime.datetime(2015, 12, 2, 19, 47), 6768930.0],
#   [datetime.datetime(2015, 12, 3, 19, 47), 4711200.0],
#   [datetime.datetime(2015, 12, 4, 19, 47), 4052070.0],
#   [datetime.datetime(2015, 12, 5, 19, 47), 4916020.0],
#   [datetime.datetime(2015, 12, 6, 19, 47), 7409940.0],
#   [datetime.datetime(2015, 12, 7, 19, 47), 7212320.0],
#   [datetime.datetime(2015, 12, 8, 19, 47), 7222160.0],
#   [datetime.datetime(2015, 12, 9, 19, 47), 14818000.0],
#   [datetime.datetime(2015, 12, 10, 19, 47), 9609360.0],
#   [datetime.datetime(2015, 12, 11, 19, 47), 10413400.0],
#   [datetime.datetime(2015, 12, 12, 19, 47), 12817300.0],
#   [datetime.datetime(2015, 12, 13, 19, 47), 6669690.0],
#   [datetime.datetime(2015, 12, 14, 19, 47), 7839280.0],
#   [datetime.datetime(2015, 12, 15, 19, 47), 13369900.0],
#   [datetime.datetime(2015, 12, 16, 19, 47), 7709410.0],
#   [datetime.datetime(2015, 12, 17, 19, 47), 5580560.0],
#   [datetime.datetime(2015, 12, 18, 19, 47), 5757460.0],
#   [datetime.datetime(2015, 12, 19, 19, 47), 4091960.0],
#   [datetime.datetime(2015, 12, 20, 19, 47), 5426570.0],
#   [datetime.datetime(2015, 12, 21, 19, 47), 8035490.0],
#   [datetime.datetime(2015, 12, 22, 19, 47), 4998820.0],
#   [datetime.datetime(2015, 12, 23, 19, 47), 5624820.0],
#   [datetime.datetime(2015, 12, 24, 19, 47), 5701250.0],
#   [datetime.datetime(2015, 12, 25, 19, 47), 5384610.0],
#   [datetime.datetime(2015, 12, 26, 19, 47), 7182870.0],
#   [datetime.datetime(2015, 12, 27, 19, 47), 4475260.0],
#   [datetime.datetime(2015, 12, 28, 19, 47), 4198830.0],
#   [datetime.datetime(2015, 12, 29, 19, 47), 4682520.0],
#   [datetime.datetime(2015, 12, 30, 19, 47), 5124710.0],
#   [datetime.datetime(2015, 12, 31, 19, 47), 5672540.0],
#   [datetime.datetime(2016, 1, 1, 19, 47), 4725940.0],
#   [datetime.datetime(2016, 1, 2, 19, 47), 4975350.0],
#   [datetime.datetime(2016, 1, 3, 19, 47), 4159840.0],
#   [datetime.datetime(2016, 1, 4, 19, 47), 6923430.0],
#   [datetime.datetime(2016, 1, 5, 19, 47), 4230340.0],
#   [datetime.datetime(2016, 1, 6, 19, 47), 4323530.0],
#   [datetime.datetime(2016, 1, 7, 19, 47), 8354300.0],
#   [datetime.datetime(2016, 1, 8, 19, 47), 9507140.0],
#   [datetime.datetime(2016, 1, 9, 19, 47), 10284000.0],
#   [datetime.datetime(2016, 1, 10, 19, 47), 5910190.0],
#   [datetime.datetime(2016, 1, 11, 19, 47), 8666190.0],
#   [datetime.datetime(2016, 1, 12, 19, 47), 26041100.0],
#   [datetime.datetime(2016, 1, 13, 19, 47), 18745000.0],
#   [datetime.datetime(2016, 1, 14, 19, 47), 10497200.0],
#   [datetime.datetime(2016, 1, 15, 19, 47), 15083800.0],
#   [datetime.datetime(2016, 1, 16, 19, 47), 14540000.0],
#   [datetime.datetime(2016, 1, 17, 19, 47), 8212880.0],
#   [datetime.datetime(2016, 1, 18, 19, 47), 11529900.0],
#   [datetime.datetime(2016, 1, 19, 19, 47), 8364360.0],
#   [datetime.datetime(2016, 1, 20, 19, 47), 12673700.0],
#   [datetime.datetime(2016, 1, 21, 19, 47), 17790600.0],
#   [datetime.datetime(2016, 1, 22, 19, 47), 24766200.0],
#   ...]}

# %% [markdown]
# #### `graphs.dominance([start=None, end=None])`
# Get data from percentage of total market capitalization chart:

# %%
from datetime import datetime, timedelta

ten_days_ago = datetime.now() - timedelta(days=10)
cmc.graphs.dominance(start=ten_days_ago)
# Out:
# {'bitcoin': [[datetime.datetime(2018, 4, 18, 20, 47), 40.7479],
#   [datetime.datetime(2018, 4, 19, 20, 47), 39.4514],
#   [datetime.datetime(2018, 4, 20, 20, 47), 38.3002],
#   [datetime.datetime(2018, 4, 21, 20, 47), 39.046],
#   [datetime.datetime(2018, 4, 22, 20, 47), 38.3516],
#   [datetime.datetime(2018, 4, 23, 20, 47), 37.8976],
#   [datetime.datetime(2018, 4, 24, 20, 47), 37.0822],
#   [datetime.datetime(2018, 4, 25, 20, 47), 38.5762],
#   [datetime.datetime(2018, 4, 26, 20, 47), 37.9008],
#   [datetime.datetime(2018, 4, 27, 20, 47), 37.4468],
#   [datetime.datetime(2018, 4, 28, 17, 47), 37.1345]],
#  'bitcoin-cash': [[datetime.datetime(2018, 4, 18, 20, 47), 4.45244],
#   [datetime.datetime(2018, 4, 19, 20, 47), 4.60085],
#   [datetime.datetime(2018, 4, 20, 20, 47), 5.09174],
#   [datetime.datetime(2018, 4, 21, 20, 47), 5.14417],
#   [datetime.datetime(2018, 4, 22, 20, 47), 5.36713],
#   [datetime.datetime(2018, 4, 23, 20, 47), 5.94756],
#   [datetime.datetime(2018, 4, 24, 20, 47), 5.87009],
#   [datetime.datetime(2018, 4, 25, 20, 47), 5.71494],
#   [datetime.datetime(2018, 4, 26, 20, 47), 5.71351],
#   [datetime.datetime(2018, 4, 27, 20, 47), 5.68913],
#   [datetime.datetime(2018, 4, 28, 17, 47), 5.61092]],
#  'dash': [[datetime.datetime(2018, 4, 18, 20, 47), 0.954077],
#   [datetime.datetime(2018, 4, 19, 20, 47), 0.953327],
#   [datetime.datetime(2018, 4, 20, 20, 47), 0.943485],
#   [datetime.datetime(2018, 4, 21, 20, 47), 0.921119],
#   [datetime.datetime(2018, 4, 22, 20, 47), 0.949096],
#   [datetime.datetime(2018, 4, 23, 20, 47), 1.01598],
#   [datetime.datetime(2018, 4, 24, 20, 47), 0.996444],
#   [datetime.datetime(2018, 4, 25, 20, 47), 0.96808],
#   [datetime.datetime(2018, 4, 26, 20, 47), 0.964737],
#   [datetime.datetime(2018, 4, 27, 20, 47), 0.931916],
#   [datetime.datetime(2018, 4, 28, 17, 47), 0.926691]],
#  'ethereum': [[datetime.datetime(2018, 4, 18, 20, 47), 15.0898],
#   [datetime.datetime(2018, 4, 19, 20, 47), 15.5413],
#   [datetime.datetime(2018, 4, 20, 20, 47), 15.5249],
#   [datetime.datetime(2018, 4, 21, 20, 47), 15.7265],
#   [datetime.datetime(2018, 4, 22, 20, 47), 15.9411],
#   [datetime.datetime(2018, 4, 23, 20, 47), 15.873],
#   [datetime.datetime(2018, 4, 24, 20, 47), 16.2293],
#   [datetime.datetime(2018, 4, 25, 20, 47), 15.7167],
#   [datetime.datetime(2018, 4, 26, 20, 47), 15.7263],
#   [datetime.datetime(2018, 4, 27, 20, 47), 15.9354],
#   [datetime.datetime(2018, 4, 28, 17, 47), 15.8598]],
#  'iota': [[datetime.datetime(2018, 4, 18, 20, 47), 1.33336],
#   [datetime.datetime(2018, 4, 19, 20, 47), 1.36453],
#   [datetime.datetime(2018, 4, 20, 20, 47), 1.4328],
#   [datetime.datetime(2018, 4, 21, 20, 47), 1.37342],
#   [datetime.datetime(2018, 4, 22, 20, 47), 1.43535],
#   [datetime.datetime(2018, 4, 23, 20, 47), 1.46551],
#   [datetime.datetime(2018, 4, 24, 20, 47), 1.40731],
#   [datetime.datetime(2018, 4, 25, 20, 47), 1.31261],
#   [datetime.datetime(2018, 4, 26, 20, 47), 1.33039],
#   [datetime.datetime(2018, 4, 27, 20, 47), 1.31605],
#   [datetime.datetime(2018, 4, 28, 17, 47), 1.33427]],
#  'litecoin': [[datetime.datetime(2018, 4, 18, 20, 47), 2.28754],
#   [datetime.datetime(2018, 4, 19, 20, 47), 2.30099],
#   [datetime.datetime(2018, 4, 20, 20, 47), 2.2356],
#   [datetime.datetime(2018, 4, 21, 20, 47), 2.18504],
#   [datetime.datetime(2018, 4, 22, 20, 47), 2.13188],
#   [datetime.datetime(2018, 4, 23, 20, 47), 2.12406],
#   [datetime.datetime(2018, 4, 24, 20, 47), 2.14134],
#   [datetime.datetime(2018, 4, 25, 20, 47), 2.08076],
#   [datetime.datetime(2018, 4, 26, 20, 47), 2.07616],
#   [datetime.datetime(2018, 4, 27, 20, 47), 2.02866],
#   [datetime.datetime(2018, 4, 28, 17, 47), 1.99263]],
#  'monero': [[datetime.datetime(2018, 4, 18, 20, 47), 1.06093],
#   [datetime.datetime(2018, 4, 19, 20, 47), 1.06162],
#   [datetime.datetime(2018, 4, 20, 20, 47), 1.07073],
#   [datetime.datetime(2018, 4, 21, 20, 47), 1.05515],
#   [datetime.datetime(2018, 4, 22, 20, 47), 1.11457],
#   [datetime.datetime(2018, 4, 23, 20, 47), 1.12438],
#   [datetime.datetime(2018, 4, 24, 20, 47), 1.09951],
#   [datetime.datetime(2018, 4, 25, 20, 47), 1.06882],
#   [datetime.datetime(2018, 4, 26, 20, 47), 1.06724],
#   [datetime.datetime(2018, 4, 27, 20, 47), 0.997771],
#   [datetime.datetime(2018, 4, 28, 17, 47), 0.958455]],
#  'nem': [[datetime.datetime(2018, 4, 18, 20, 47), 0.969603],
#   [datetime.datetime(2018, 4, 19, 20, 47), 0.968257],
#   [datetime.datetime(2018, 4, 20, 20, 47), 0.932969],
#   [datetime.datetime(2018, 4, 21, 20, 47), 0.893876],
#   [datetime.datetime(2018, 4, 22, 20, 47), 0.897621],
#   [datetime.datetime(2018, 4, 23, 20, 47), 0.877821],
#   [datetime.datetime(2018, 4, 24, 20, 47), 0.871131],
#   [datetime.datetime(2018, 4, 25, 20, 47), 0.865232],
#   [datetime.datetime(2018, 4, 26, 20, 47), 0.861907],
#   [datetime.datetime(2018, 4, 27, 20, 47), 0.861356],
#   [datetime.datetime(2018, 4, 28, 17, 47), 0.85192]],
#  'neo': [[datetime.datetime(2018, 4, 18, 20, 47), 1.3634],
#   [datetime.datetime(2018, 4, 19, 20, 47), 1.33854],
#   [datetime.datetime(2018, 4, 20, 20, 47), 1.32213],
#   [datetime.datetime(2018, 4, 21, 20, 47), 1.267],
#   [datetime.datetime(2018, 4, 22, 20, 47), 1.24135],
#   [datetime.datetime(2018, 4, 23, 20, 47), 1.2365],
#   [datetime.datetime(2018, 4, 24, 20, 47), 1.26135],
#   [datetime.datetime(2018, 4, 25, 20, 47), 1.20116],
#   [datetime.datetime(2018, 4, 26, 20, 47), 1.18622],
#   [datetime.datetime(2018, 4, 27, 20, 47), 1.17747],
#   [datetime.datetime(2018, 4, 28, 17, 47), 1.16728]],
#  'others': [[datetime.datetime(2018, 4, 18, 20, 47), 23.796850000000006],
#   [datetime.datetime(2018, 4, 19, 20, 47), 24.222586000000007],
#   [datetime.datetime(2018, 4, 20, 20, 47), 24.12145600000001],
#   [datetime.datetime(2018, 4, 21, 20, 47), 23.551045000000002],
#   [datetime.datetime(2018, 4, 22, 20, 47), 23.813463],
#   [datetime.datetime(2018, 4, 23, 20, 47), 23.880559000000005],
#   [datetime.datetime(2018, 4, 24, 20, 47), 24.578985000000017],
#   [datetime.datetime(2018, 4, 25, 20, 47), 24.37418799999999],
#   [datetime.datetime(2018, 4, 26, 20, 47), 25.109055999999995],
#   [datetime.datetime(2018, 4, 27, 20, 47), 25.680806999999987],
#   [datetime.datetime(2018, 4, 28, 17, 47), 26.19242399999999]],
#  'ripple': [[datetime.datetime(2018, 4, 18, 20, 47), 7.9441],
#   [datetime.datetime(2018, 4, 19, 20, 47), 8.1966],
#   [datetime.datetime(2018, 4, 20, 20, 47), 9.02399],
#   [datetime.datetime(2018, 4, 21, 20, 47), 8.83668],
#   [datetime.datetime(2018, 4, 22, 20, 47), 8.75684],
#   [datetime.datetime(2018, 4, 23, 20, 47), 8.55703],
#   [datetime.datetime(2018, 4, 24, 20, 47), 8.46234],
#   [datetime.datetime(2018, 4, 25, 20, 47), 8.12131],
#   [datetime.datetime(2018, 4, 26, 20, 47), 8.06368],
#   [datetime.datetime(2018, 4, 27, 20, 47), 7.93464],
#   [datetime.datetime(2018, 4, 28, 17, 47), 7.97111]]}

# %% [markdown]
# _________________________________
#
# ## Utils
# #### `convert(value, currency_in, currency_out)`
# This method converts the value passed as first parameter as price of the `currency_in` currency to price of the `currency_out` parameter. Works as [coinmarketcap criptocurrencies calculator](https://coinmarketcap.com/calculator/). For example, if you want to converts $100€$ to dolars, use:

# %%
cmc.convert(100, "EUR", "USD")
# Out:
# 121.46535807987561

# %% [markdown]
# For get all the currencies supported by this method (all currencies; fiat + crypto):

# %%
cmc.currencies_to_convert
# Out:
# ['$$$',
#  '$PAC',
#  '1337',
#  '1ST',
#  '1WO',
#  '2GIVE',
#  '300',
#  '42',
#  '611',
#  '808',
#  '888',
#  '8BIT',
#  'AAC',
#  'ABC',
#  'ABJ',
#  'ABT',
#  'ABY',
#  'AC',
#  'ACAT',
#  'ACC',
#  'ACC',
#  'ACC',
#  'ACE',
#  'ACES',
#  'ACN',
#  'ACOIN',
#  'ACP',
#  'ACT',
#  'ADA',
#  'ADB',
#  'ADC',
#  'ADCN',
#  'ADH',
#  'ADI',
#  'ADK',
#  'ADST',
#  'ADT',
#  'ADX',
#  'ADZ',
#  'AE',
#  'AEON',
#  'AERM',
#  'AGI',
#  'AGLC',
#  'AHT',
#  'AI',
#  'AIB',
#  'AID',
#  'AIDOC',
#  'AION',
#  'AIR',
#  'AIT',
#  'AIX',
#  'AKY',
#  'ALIS',
#  'ALL',
#  'ALQO',
#  'ALT',
#  'AMB',
#  'AMBER',
#  'AMLT',
#  'AMM',
#  'AMMO',
#  'AMP',
#  'AMS',
#  'ANC',
#  'ANI',
#  'ANT',
#  'ANTX',
#  'APC',
#  'APPC',
#  'APX',
#  'ARB',
#  'ARC',
#  'ARCO',
#  'ARCT',
#  'ARDR',
#  'ARG',
#  'ARGUS',
#  'ARI',
#  'ARK',
#  'ARN',
#  'ART',
#  'ARY',
#  'ASAFE2',
#  'ASN',
#  'AST',
#  'ASTRO',
#  'ATB',
#  'ATC',
#  'ATL',
#  'ATM',
#  'ATMC',
#  'ATN',
#  'ATOM',
#  'ATS',
#  'ATX',
#  'AU',
#  'AUC',
#  'AUD',
#  'AUR',
#  'AURA',
#  'AUTO',
#  'AV',
#  'AVH',
#  'AVT',
#  'AWR',
#  'AXIOM',
#  'AXP',
#  'B2B',
#  'B2X',
#  'B@',
#  'BANCA',
#  'BAR',
#  'BAS',
#  'BASH',
#  'BAT',
#  'BAT',
#  'BAX',
#  'BAY',
#  'BBI',
#  'BBN',
#  'BBP',
#  'BBR',
#  'BBT',
#  'BCA',
#  'BCC',
#  'BCD',
#  'BCDN',
#  'BCF',
#  'BCH',
#  'BCH',
#  'BCN',
#  'BCO',
#  'BCPT',
#  'BCX',
#  'BCY',
#  'BDG',
#  'BDL',
#  'BEE',
#  'BELA',
#  'BENJI',
#  'BERN',
#  'BERRY',
#  'BEST',
#  'BET',
#  'BET',
#  'BEZ',
#  'BFT',
#  'BIG',
#  'BIGUP',
#  'BIO',
#  'BIOB',
#  'BIOS',
#  'BIP',
#  'BIRDS',
#  'BIS',
#  'BIT',
#  'BITB',
#  'BITBTC',
#  'BITCF',
#  'BITCNY',
#  'BITEUR',
#  'BITG',
#  'BITGOLD',
#  'BITOK',
#  'BITS',
#  'BITSILVER',
#  'BITUSD',
#  'BITZ',
#  'BIX',
#  'BKX',
#  'BLAZR',
#  'BLC',
#  'BLITZ',
#  'BLK',
#  'BLN',
#  'BLOCK',
#  'BLOCKPAY',
#  'BLRY',
#  'BLT',
#  'BLU',
#  'BLUE',
#  'BLZ',
#  'BLZ',
#  'BMC',
#  'BNB',
#  'BNT',
#  'BNTY',
#  'BNX',
#  'BOAT',
#  'BOLI',
#  'BON',
#  'BOS',
#  'BOST',
#  'BOT',
#  'BPC',
#  'BPL',
#  'BPT',
#  'BQ',
#  'BRAT',
#  'BRD',
#  'BRIA',
#  'BRIT',
#  'BRK',
#  'BRL',
#  'BRM',
#  'BRO',
#  'BRX',
#  'BSC',
#  'BSD',
#  'BSM',
#  'BSN',
#  'BSR',
#  'BSTAR',
#  'BSTN',
#  'BSTY',
#  'BT2',
#  'BTA',
#  'BTB',
#  'BTBc',
#  'BTC',
#  'BTC',
#  'BTCA',
#  'BTCD',
#  'BTCM',
#  'BTCP',
#  'BTCR',
#  'BTCRED',
#  'BTCS',
#  'BTCZ',
#  'BTDX',
#  'BTE',
#  'BTG',
#  'BTG',
#  'BTM',
#  'BTM',
#  'BTO',
#  'BTPL',
#  'BTQ',
#  'BTS',
#  'BTW',
#  'BTWTY',
#  'BTX',
#  'BUB',
#  'BUBO',
#  'BUCKS',
#  'BUMBA',
#  'BUN',
#  'BURST',
#  'BUZZ',
#  'BWK',
#  'BXC',
#  'BXT',
#  'BYC',
#  'C2',
#  'C20',
#  'CAB',
#  'CACH',
#  'CAD',
#  'CAG',
#  'CALC',
#  'CAN',
#  'CAN',
#  'CANDY',
#  'CANN',
#  'CAPP',
#  'CARBON',
#  'CAS',
#  'CASH',
#  'CAT',
#  'CAT',
#  'CAT',
#  'CBT',
#  'CBX',
#  'CC',
#  'CCN',
#  'CCO',
#  'CCRB',
#  'CCT',
#  'CDN',
#  'CDT',
#  'CDX',
#  'CEFS',
#  'CENNZ',
#  'CESC',
#  'CF',
#  'CFC',
#  'CFI',
#  'CFUN',
#  'CHAN',
#  'CHAT',
#  'CHC',
#  'CHEAP',
#  'CHESS',
#  'CHF',
#  'CHIPS',
#  'CHP',
#  'CHSB',
#  'CHX',
#  'CJ',
#  'CKUSD',
#  'CL',
#  'CLAM',
#  'CLD',
#  'CLOAK',
#  'CLP',
#  'CLR',
#  'CLUB',
#  'CME',
#  'CMPCO',
#  'CMS',
#  'CMS',
#  'CMT',
#  'CMT',
#  'CND',
#  'CNNC',
#  'CNO',
#  'CNT',
#  'CNX',
#  'CNY',
#  'COAL',
#  'COB',
#  'COFI',
#  'COLX',
#  'CON',
#  'CONX',
#  'COR',
#  'COSS',
#  'COUPE',
#  'COV',
#  'COVAL',
#  'CPAY',
#  'CPC',
#  'CPC',
#  'CPN',
#  'CPX',
#  'CPY',
#  'CRAVE',
#  'CRB',
#  'CRC',
#  'CRC',
#  'CRDNC',
#  'CREA',
#  'CRED',
#  'CREDO',
#  'CREVA',
#  'CRM',
#  'CROP',
#  'CRPT',
#  'CRW',
#  'CRX',
#  'CRYPT',
#  'CS',
#  'CSC',
#  'CSNO',
#  'CTIC2',
#  'CTIC3',
#  'CTO',
#  'CTR',
#  'CTX',
#  'CTXC',
#  'CUBE',
#  'CURE',
#  'CV',
#  'CVC',
#  'CVCOIN',
#  'CVH',
#  'CVT',
#  'CWXT',
#  'CXO',
#  'CXT',
#  'CYC',
#  'CYDER',
#  'CYP',
#  'CZK',
#  'DADI',
#  'DAI',
#  'DALC',
#  'DAN',
#  'DAR',
#  'DASH',
#  'DASHS',
#  'DAT',
#  'DATA',
#  'DATX',
#  'DAV',
#  'DAXX',
#  'DAY',
#  'DBC',
#  'DBET',
#  'DBG',
#  'DBIX',
#  'DBTC',
#  'DCN',
#  'DCR',
#  'DCRE',
#  'DCT',
#  'DCY',
#  'DDD',
#  'DDF',
#  'DEB',
#  'DEM',
#  'DENT',
#  'DERO',
#  'DES',
#  'DEUS',
#  'DEV',
#  'DEW',
#  'DFS',
#  'DFT',
#  'DGB',
#  'DGC',
#  'DGCS',
#  'DGD',
#  'DGPT',
#  'DICE',
#  'DIG',
#  'DIM',
#  'DIME',
#  'DISK',
#  'DIVX',
#  'DIX',
#  'DKK',
#  'DLC',
#  'DLISK',
#  'DLT',
#  'DMB',
#  'DMC',
#  'DMD',
#  'DMT',
#  'DNA',
#  'DNR',
#  'DNT',
#  'DOCK',
#  'DOGE',
#  'DOLLAR',
#  'DON',
#  'DOPE',
#  'DOT',
#  'DOVU',
#  'DP',
#  'DPY',
#  'DRG',
#  'DRGN',
#  'DRM',
#  'DROP',
#  'DRP',
#  'DRPU',
#  'DRS',
#  'DRT',
#  'DRXNE',
#  'DSH',
#  'DSR',
#  'DTA',
#  'DTB',
#  'DTC',
#  'DTH',
#  'DTR',
#  'DUO',
#  'DUTCH',
#  'DXT',
#  'DYN',
#  'EAG',
#  'EAGLE',
#  'EARTH',
#  'EBCH',
#  'EBET',
#  'EBST',
#  'EBT',
#  'EBTC',
#  'ECA',
#  'ECASH',
#  'ECC',
#  'ECH',
#  'ECN',
#  'ECO',
#  'ECOB',
#  'EDG',
#  'EDO',
#  'EDR',
#  'EDRC',
#  'EDT',
#  'EFL',
#  'EFX',
#  'EFYT',
#  'EGC',
#  'EGG',
#  'EKO',
#  'EKT',
#  'EL',
#  'ELA',
#  'ELC',
#  'ELE',
#  'ELEC',
#  'ELF',
#  'ELITE',
#  'ELIX',
#  'ELLA',
#  'ELS',
#  'ELTCOIN',
#  'EMB',
#  'EMC',
#  'EMC2',
#  'EMD',
#  'EMV',
#  'ENG',
#  'ENJ',
#  'ENRG',
#  'ENT',
#  'ENT',
#  'EOS',
#  'EOSDAC',
#  'EPC',
#  'EPY',
#  'EQL',
#  'EQT',
#  'ERA',
#  'ERC',
#  'ERC20',
#  'EREAL',
#  'ERO',
#  'ERY',
#  'ESC',
#  'ESP',
#  'ESZ',
#  'ETBS',
#  'ETC',
#  'ETG',
#  'ETH',
#  'ETH',
#  'ETHD',
#  'ETHOS',
#  'ETN',
#  'ETP',
#  'ETT',
#  'ETT',
#  'EUC',
#  'EUR',
#  'EVC',
#  'EVE',
#  'EVIL',
#  'EVN',
#  'EVO',
#  'EVR',
#  'EVX',
#  'EXCL',
#  'EXN',
#  'EXP',
#  'EXRN',
#  'EXY',
#  'EZT',
#  'FAIR',
#  'FAIR',
#  'FAP',
#  'FAZZ',
#  'FCN',
#  'FCT',
#  'FDX',
#  'FDZ',
#  'FID',
#  'FIL',
#  'FIRE',
#  'FJC',
#  'FLAP',
#  'FLASH',
#  'FLAX',
#  'FLDC',
#  'FLIK',
#  'FLIXX',
#  'FLO',
#  'FLT',
#  'FLUZ',
#  'FLY',
#  'FNC',
#  'FONZ',
#  'FOR',
#  'FOTA',
#  'FRC',
#  'FRCT',
#  'FRD',
#  'FRGC',
#  'FRN',
#  'FRST',
#  'FRWC',
#  'FSN',
#  'FST',
#  'FTC',
#  'FTX',
#  'FUCK',
#  'FUEL',
#  'FUN',
#  'FUNC',
#  'FUNK',
#  'FUTC',
#  'FUZZ',
#  'FXE',
#  'FYN',
#  'FYP',
#  'GAIA',
#  'GAIN',
#  'GAM',
#  'GAME',
#  'GAP',
#  'GARY',
#  'GAS',
#  'GAT',
#  'GAY',
#  'GB',
#  'GBC',
#  'GBG',
#  'GBP',
#  'GBX',
#  'GBYTE',
#  'GCC',
#  'GCC',
#  'GCN',
#  'GCR',
#  'GCS',
#  'GDC',
#  'GEERT',
#  'GEM',
#  'GEO',
#  'GET',
#  'GETX',
#  'GJC',
#  'GLA',
#  'GLC',
#  'GLD',
#  'GLS',
#  'GLT',
#  'GML',
#  'GMT',
#  'GMX',
#  'GNO',
#  'GNT',
#  'GNX',
#  'GOD',
#  'GOLF',
#  'GOLOS',
#  'GOOD',
#  'GP',
#  'GPL',
#  'GPU',
#  'GRC',
#  'GRE',
#  'GRFT',
#  'GRID',
#  'GRIM',
#  'GRLC',
#  'GRMD',
#  'GRN',
#  'GRS',
#  'GRWI',
#  'GRX',
#  'GSR',
#  'GTC',
#  'GTC',
#  'GTO',
#  'GUESS',
#  'GUN',
#  'GUP',
#  'GVT',
#  'GXS',
#  'HAC',
#  'HAL',
#  'HALLO',
#  'HAT',
#  'HAV',
#  'HBC',
#  'HBN',
#  'HBT',
#  'HC',
#  'HCC',
#  'HDG',
#  'HDLB',
#  'HEAT',
#  'HERO',
#  'HGT',
#  'HIGH',
#  'HIRE',
#  'HKD',
#  'HKN',
#  'HLC',
#  'HMC',
#  'HMC',
#  'HMP',
#  'HMQ',
#  'HNC',
#  'HNC',
#  'HODL',
#  'HOLD',
#  'HONEY',
#  'HORSE',
#  'HOT',
#  'HPB',
#  'HPC',
#  'HPY',
#  'HQX',
#  'HSR',
#  'HST',
#  'HT',
#  'HTC',
#  'HTML',
#  'HUC',
#  'HUF',
#  'HUSH',
#  'HVCO',
#  'HVN',
#  'HWC',
#  'HXX',
#  'HYP',
#  'HYPER',
#  'I0C',
#  'IBANK',
#  'IC',
#  'ICN',
#  'ICN',
#  'ICOB',
#  'ICON',
#  'ICOO',
#  'ICOS',
#  'ICX',
#  'IDH',
#  'IDR',
#  'IDT',
#  'IDXM',
#  'IETH',
#  'IFC',
#  'IFLT',
#  'IFT',
#  'IGNIS',
#  'IHT',
#  'ILS',
#  'IMPS',
#  'IMS',
#  'IMX',
#  'INCNT',
#  'IND',
#  'INDI',
#  'INDIA',
#  'INFX',
#  'ING',
#  'INK',
#  'INN',
#  'INPAY',
#  'INR',
#  'INS',
#  'INSN',
#  'INSTAR',
#  'INT',
#  'INXT',
#  'IOC',
#  'ION',
#  'IOP',
#  'IOST',
#  'IPBC',
#  'IPC',
#  'IPL',
#  'IPSX',
#  'IQT',
#  'IRL',
#  'ISL',
#  'ITC',
#  'ITI',
#  'ITNS',
#  'ITT',
#  'ITZ',
#  'IXC',
#  'IXT',
#  'J',
#  'J8T',
#  'JC',
#  'JET',
#  'JEW',
#  'JIN',
#  'JIYO',
#  'JNT',
#  'JOBS',
#  'JPY',
#  'JS',
#  'JWL',
#  'KARMA',
#  'KASHH',
#  'KB3',
#  'KBR',
#  'KCASH',
#  'KCS',
#  'KDC',
#  'KED',
#  'KEK',
#  'KEY',
#  'KICK',
#  'KIN',
#  'KLC',
#  'KLN',
#  'KMD',
#  'KNC',
#  'KNC',
#  'KOBO',
#  'KORE',
#  'KRB',
#  'KRM',
#  'KRONE',
#  'KRW',
#  'KST',
#  'KURT',
#  'KUSH',
#  'KZC',
#  'LA',
#  'LALA',
#  'LANA',
#  'LATX',
#  'LAZ',
#  'LBC',
#  'LBTC',
#  'LBTC',
#  'LCC',
#  'LCP',
#  'LDC',
#  'LDCN',
#  'LDOGE',
#  'LEA',
#  'LEAF',
#  'LEDU',
#  'LEND',
#  'LEO',
#  'LEPEN',
#  'LET',
#  'LEV',
#  'LEVO',
#  'LGD',
#  'LGO',
#  'LIFE',
#  'LIGHT',
#  'LINDA',
#  'LINK',
#  'LINX',
#  'LIR',
#  'LKC',
#  'LKK',
#  'LMC',
#  'LNC',
#  'LNC',
#  'LOC',
#  'LOCI',
#  'LOG',
#  'LOOM',
#  'LRC',
#  'LSK',
#  'LST',
#  'LTB',
#  'LTC',
#  'LTC',
#  'LTCR',
#  'LTCU',
#  'LUN',
#  'LUNA',
#  'LUX',
#  'LVPS',
#  'LYM',
#  'MAC',
#  'MAD',
#  'MAG',
#  'MAG',
#  'MAGE',
#  'MAGN',
#  'MAID',
#  'MAN',
#  'MANA',
#  'MANNA',
#  'MAO',
#  'MAR',
#  'MARS',
#  'MARX',
#  'MAX',
#  'MAY',
#  'MBI',
#  'MBL',
#  'MBRS',
#  'MCAP',
#  'MCI',
#  'MCO',
#  'MCR',
#  'MCRN',
#  'MDA',
#  'MDC',
#  'MDS',
#  'MDT',
#  'MEC',
#  'MED',
#  'MEDIC',
#  'MEET',
#  'MEME',
#  'MER',
#  'METAL',
#  'MFG',
#  'MGM',
#  'MGO',
#  'MILO',
#  'MINEX',
#  'MINT',
#  'MIOTA',
#  'MITH',
#  'MKR',
#  'MLM',
#  'MLN',
#  'MNC',
#  'MND',
#  'MNE',
#  'MNM',
#  'MNTP',
#  'MNX',
#  'MOAC',
#  'MOBI',
#  'MOD',
#  'MOF',
#  'MOIN',
#  'MOJO',
#  'MONA',
#  'MONETA',
#  'MONK',
#  'MOON',
#  'MOT',
#  'MOTO',
#  'MRJA',
#  'MRK',
#  'MRT',
#  'MSCN',
#  'MSD',
#  'MSP',
#  'MSR',
#  'MST',
#  'MTH',
#  'MTL',
#  'MTLMC3',
#  'MTN',
#  'MTNC',
#  'MTX',
#  'MUE',
#  'MUSE',
#  'MUSIC',
#  'MVC',
#  'MWAT',
#  'MXN',
#  'MXT',
#  'MYB',
#  'MYR',
#  'MYST',
#  'MZC',
#  'NAMO',
#  'NANJ',
#  'NANO',
#  'NANOX',
#  'NAS',
#  'NAV',
#  'NBIT',
#  'NCASH',
#  'NCT',
#  'NDC',
#  'NEBL',
#  'NEO',
#  'NEOG',
#  'NEOS',
#  'NET',
#  'NET',
#  'NETKO',
#  'NEU',
#  'NEVA',
#  'NEWB',
#  'NGC',
#  'NIO',
#  'NKA',
#  'NKC',
#  'NLC2',
#  'NLG',
#  'NMC',
#  'NMR',
#  'NMS',
#  'NOAH',
#  'NOBL',
#  'NODC',
#  'NOK',
#  'NOTE',
#  'NOX',
#  'NPX',
#  'NPXS',
#  'NRO',
#  'NSR',
#  'NTK',
#  'NTO',
#  'NTRN',
#  'NTWK',
#  'NUKO',
#  'NULS',
#  'NUMUS',
#  'NVC',
#  'NVST',
#  'NXC',
#  'NXS',
#  ...]

# %%
show_page("calculator")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/calculator"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `download_logo(name, [size=64, filename=None])`
# Download a currency image logo in `.png` format. Valid sizes are: `[16, 32, 64, 128, 200]`.

# %%
from random import choice

currency = choice([curr["name"] for curr in cmc.cryptocurrencies])

filename = cmc.download_logo(currency, size=200)

from IPython.display import Image
Image(filename)

# %%
# Clean downloaded logo
import os
try:
    os.remove(filename)
except FileNotFoundError:
    pass

# %% [markdown]
# #### `download_exchange_logo(name, [size=64, filename=None])`
# Download a exchange image logo in `.png` format. Valid sizes are: `[16, 32, 64, 128, 200]`.

# %%
exchange = choice([str(exc["website_slug"]) for exc in cmc.cryptoexchanges])

filename = cmc.download_exchange_logo(exchange, size=128)
Image(filename)

# %%
try:
    os.remove(filename)
except FileNotFoundError:
    pass

# %% [markdown]
# _____________________________
#
# ## Catching HTTP errors
# You can use the nexts class in order to catch some HTTP error:

# %%
from pymarketcap import (
    CoinmarketcapError,      # This class is the parent of all
    CoinmarketcapHTTPError,
    CoinmarketcapTooManyRequestsError
)

# %% [markdown]
# You could prevent errors like this
#
#
# ![error](images/http_error.png)

# %% [markdown]
# This only happens with `Pymarketcap` class. In asynchronous interface, failed requests will be restarted in a queue.
