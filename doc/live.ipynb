# %% [markdown]
# # <center>Pymarketcap live documentation</center>

# %% [markdown]
# ## Basic usage
#
# #### `Pymarketcap([timeout=20, debug=False, cache=True])`
#
# The first response takes a long time because some data is cached at instantiation of the wrapper.

# %%
from pymarketcap import Pymarketcap
cmc = Pymarketcap(timeout=10)

cmc.exchanges()
# Out:
# [{'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BitMEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Litecoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'OFCOIN',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'OKEx'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'NEO',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Gifto',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'ICON',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'TRON',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Ripple',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'NEO',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Nano',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Binance'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Cardano',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'NEO',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Qtum',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Status',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Stellar',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Steem Dollars',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Upbit'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Qtum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Zcash',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Bithumb'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Tether',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'EOS',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Bitfinex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Huobi Token',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'TRON',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Huobi Token',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Elastos',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Huobi Token',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'EOS',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Elastos',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'WaykiChain',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Huobi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ripple',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ripple',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Ripple',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Kraken'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Litecoin',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'GDAX'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Monero',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Dash',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ripple',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Zcash',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Litecoin',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'HitBTC'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NuBits',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ripple',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Cardano',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ripple',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'NEO',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Siacoin',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Bittrex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ripple',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Ripple',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Bitstamp'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'TRON',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'EDUCare',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ink',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ink',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Lisk',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Hshare',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Bit-Z'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'bitFlyer'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Qtum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'IOTA',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'}],
#   'name': 'Coinone'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEM',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'MonaCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Counterparty',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'NEM',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Pepe Cash',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'COMSA [XEM]',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'COMSA [ETH]',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Zaif'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ripple',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Monero',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Stellar',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Poloniex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'MonaCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'MonaCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'}],
#   'name': 'Fisco'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BTCBOX'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEO',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'TRON',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Lisk',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ruff',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Qtum',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ripple',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Qbao',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Achain',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'CoinEgg'},
#  {'markets': [{'name': 'ATMCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'ATMCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ripple',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Litecoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Dogecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'ATMCoin',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'ATMCoin',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Bits Blockchain'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'QASH',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'QASH',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Ripple',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Ethereum',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Quoine'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ink',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Lightning Bitcoin [Futures]',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Hyper Pay',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Ink',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'EXX'},
#  {'markets': [{'name': 'Bibox Token',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bibox Token',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bibox Token',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Jibrel Network',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Jibrel Network',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Spectre.ai Utility Token',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Spectre.ai Utility Token',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Bytom',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Gifto',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Gifto',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Bibox'},
#  {'markets': [{'name': 'Stellar',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Status',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Qtum',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'EOS',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Cindicator',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Civic',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': '0x',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'GOPAX'},
#  {'markets': [{'name': 'Ink',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'BitShares',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Hshare',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Ripple',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'QunQun',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'ZB.COM'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Litecoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Zcash',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Dash',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Zcash',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'WEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'}],
#   'name': 'Gemini'},
#  {'markets': [{'name': 'TRON',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'TRON',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'TRON',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'SIRIN LABS Token',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'SIRIN LABS Token',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'AdEx',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Matchpool',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'SIRIN LABS Token',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'AdEx',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Ethereum',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Liqui'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'BTCC'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum Classic',
# ...
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'}],
#   'name': 'Heat Wallet'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'TCC Exchange'},
#  {'markets': [{'name': 'Centurion',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ExcambrioRex'},
#  {'markets': [{'name': 'Auroracoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ISX'},
#  {'markets': [{'name': 'Litecoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Electroneum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'BitCoal',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Monero',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Aeon',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Verge',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Sumokoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'}],
#   'name': 'TradeOgre'},
#  {'markets': [{'name': 'Anoncoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'WhiteCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Freicoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'FreiExchange'},
#  {'markets': [{'name': 'Pepe Cash',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Dogecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'PotCoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Zcash',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Litecoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Bitcrystals',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Iconomi',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Namecoin',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'BlackCoin',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Tux Exchange'},
#  {'markets': [{'name': 'Gulden',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'GuldenTrader'},
#  {'markets': [{'name': 'BriaCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Litecoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'}],
#   'name': 'Ore.Bz'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Siacoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'}],
#   'name': 'BITHOLIC'},
#  {'markets': [{'name': 'SnakeEyes',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'CCMiner',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'}],
#   'name': 'Burst Asset Exchange'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'}],
#   'name': 'CoinCorner'},
#  {'markets': [{'name': 'CRTCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Dogecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'NIX-E'},
#  {'markets': [{'name': 'LEOcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'LEOcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'LEOcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'LEOcoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'}],
#   'name': 'LEOxChange'},
#  {'markets': [{'name': 'MaidSafeCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Omni DEX'},
#  {'markets': [{'name': 'Golem',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Lunyr',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'SingularDTV',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'TokenCard',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Swarm City',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Etheroll',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Melon',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Numeraire',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Edgeless',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Ethereum Movie Venture',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'CryptoDerivatives'},
#  {'markets': [{'name': 'Virtacoinplus',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Virtacoinplus',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'}],
#   'name': 'VirtacoinWorld'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Filecoin [Futures]',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'NEO',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'VeChain',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'ChatCoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'WhiteCoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Primas',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Zcash',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'BitShares',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Profile Utility Token',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Lbank'},
#  {'markets': [{'name': 'Raiden Network Token',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'RChain',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'TRON',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'ChainLink',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Aion',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'SALT',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Dragonchain',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Populous',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Global Jobcoin',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Bounty0x',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Token Store'}]

# %% [markdown]
# > All methods are self explained in docstrings:

# %%
print(cmc.exchanges.__doc__)
# Out:
# Get all the exchanges in coninmarketcap ranked by volumes
#         along with other metadata.
#
#         Args:
#             convert (str, optional): Convert volumes and prices
#                 between "USD" and "BTC". As default "USD".
#
#         Returns (list):
#             Exchanges with markets and other data included.

# %% [markdown]
# ___________________________________
#
# ## Coinmarketcap API
# #### `ticker(currency=None, limit=0, start=0, convert="USD")`
# If `currency == None`, you will obtain data for all currencies in coinmarketcap:

# %%
cmc.ticker()
# Out:
# [{'24h_volume_usd': 5811790000.0,
#   'available_supply': 16860625.0,
#   'id': 'bitcoin',
#   'last_updated': 1518461667,
#   'market_cap_usd': 146630111375,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin',
#   'percent_change_1h': -0.72,
#   'percent_change_24h': 4.4,
#   'percent_change_7d': 19.8,
#   'price_btc': 1.0,
#   'price_usd': 8696.6,
#   'rank': 1,
#   'symbol': 'BTC',
#   'total_supply': 16860625.0},
#  {'24h_volume_usd': 2170270000.0,
#   'available_supply': 97573749.0,
#   'id': 'ethereum',
#   'last_updated': 1518461651,
#   'market_cap_usd': 83789310679.0,
#   'max_supply': None,
#   'name': 'Ethereum',
#   'percent_change_1h': -0.72,
#   'percent_change_24h': 2.79,
#   'percent_change_7d': 19.24,
#   'price_btc': 0.0994407,
#   'price_usd': 858.728,
#   'rank': 2,
#   'symbol': 'ETH',
#   'total_supply': 97573749.0},
#  {'24h_volume_usd': 1792390000.0,
#   'available_supply': 39009215838.0,
#   'id': 'ripple',
#   'last_updated': 1518461641,
#   'market_cap_usd': 41428567404.0,
#   'max_supply': 100000000000,
#   'name': 'Ripple',
#   'percent_change_1h': -0.44,
#   'percent_change_24h': 4.35,
#   'percent_change_7d': 47.45,
#   'price_btc': 0.00012298,
#   'price_usd': 1.06202,
#   'rank': 3,
#   'symbol': 'XRP',
#   'total_supply': 99992725510.0},
#  {'24h_volume_usd': 423130000.0,
#   'available_supply': 16963988.0,
#   'id': 'bitcoin-cash',
#   'last_updated': 1518461653,
#   'market_cap_usd': 21402614829.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Cash',
#   'percent_change_1h': -0.54,
#   'percent_change_24h': 0.5,
#   'percent_change_7d': 34.14,
#   'price_btc': 0.1461,
#   'price_usd': 1261.65,
#   'rank': 4,
#   'symbol': 'BCH',
#   'total_supply': 16963988.0},
#  {'24h_volume_usd': 222848000.0,
#   'available_supply': 25927070538.0,
#   'id': 'cardano',
#   'last_updated': 1518461656,
#   'market_cap_usd': 9768075679.0,
#   'max_supply': 45000000000.0,
#   'name': 'Cardano',
#   'percent_change_1h': -0.48,
#   'percent_change_24h': 0.13,
#   'percent_change_7d': 12.82,
#   'price_btc': 4.363e-05,
#   'price_usd': 0.376752,
#   'rank': 5,
#   'symbol': 'ADA',
#   'total_supply': 31112483745.0},
#  {'24h_volume_usd': 507940000.0,
#   'available_supply': 55186958.0,
#   'id': 'litecoin',
#   'last_updated': 1518461641,
#   'market_cap_usd': 8801216086.0,
#   'max_supply': 84000000.0,
#   'name': 'Litecoin',
#   'percent_change_1h': 0.46,
#   'percent_change_24h': 4.45,
#   'percent_change_7d': 22.73,
#   'price_btc': 0.0184677,
#   'price_usd': 159.48,
#   'rank': 6,
#   'symbol': 'LTC',
#   'total_supply': 55186958.0},
#  {'24h_volume_usd': 59198400.0,
#   'available_supply': 18432260591.0,
#   'id': 'stellar',
#   'last_updated': 1518461642,
#   'market_cap_usd': 7228469043.0,
#   'max_supply': None,
#   'name': 'Stellar',
#   'percent_change_1h': -0.24,
#   'percent_change_24h': 3.63,
#   'percent_change_7d': 14.61,
#   'price_btc': 4.541e-05,
#   'price_usd': 0.392164,
#   'rank': 7,
#   'symbol': 'XLM',
#   'total_supply': 103669352049},
#  {'24h_volume_usd': 271223000.0,
#   'available_supply': 65000000.0,
#   'id': 'neo',
#   'last_updated': 1518461647,
#   'market_cap_usd': 7225855000.0,
#   'max_supply': None,
#   'name': 'NEO',
#   'percent_change_1h': -0.91,
#   'percent_change_24h': 3.22,
#   'percent_change_7d': 28.64,
#   'price_btc': 0.0128731,
#   'price_usd': 111.167,
#   'rank': 8,
#   'symbol': 'NEO',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 321466000.0,
#   'available_supply': 665480070.0,
#   'id': 'eos',
#   'last_updated': 1518461651,
#   'market_cap_usd': 5954422853.0,
#   'max_supply': 1000000000.0,
#   'name': 'EOS',
#   'percent_change_1h': -0.9,
#   'percent_change_24h': 2.96,
#   'percent_change_7d': 18.15,
#   'price_btc': 0.00103613,
#   'price_usd': 8.94756,
#   'rank': 9,
#   'symbol': 'EOS',
#   'total_supply': 900000000.0},
#  {'24h_volume_usd': 35835300.0,
#   'available_supply': 2779530283.0,
#   'id': 'iota',
#   'last_updated': 1518461650,
#   'market_cap_usd': 5066527800.0,
#   'max_supply': 2779530283.0,
#   'name': 'IOTA',
#   'percent_change_1h': -0.67,
#   'percent_change_24h': 3.89,
#   'percent_change_7d': 21.9,
#   'price_btc': 0.00021108,
#   'price_usd': 1.8228,
#   'rank': 10,
#   'symbol': 'MIOTA',
#   'total_supply': 2779530283.0},
#  {'24h_volume_usd': 21556400.0,
#   'available_supply': 8999999999.0,
#   'id': 'nem',
#   'last_updated': 1518461644,
#   'market_cap_usd': 4861106999.0,
#   'max_supply': None,
#   'name': 'NEM',
#   'percent_change_1h': -0.6,
#   'percent_change_24h': 0.3,
#   'percent_change_7d': 14.73,
#   'price_btc': 6.255e-05,
#   'price_usd': 0.540123,
#   'rank': 11,
#   'symbol': 'XEM',
#   'total_supply': 8999999999.0},
#  {'24h_volume_usd': 76948300.0,
#   'available_supply': 7880240.0,
#   'id': 'dash',
#   'last_updated': 1518461641,
#   'market_cap_usd': 4822194569.0,
#   'max_supply': 18900000.0,
#   'name': 'Dash',
#   'percent_change_1h': -0.94,
#   'percent_change_24h': 1.68,
#   'percent_change_7d': 29.11,
#   'price_btc': 0.0708621,
#   'price_usd': 611.935,
#   'rank': 12,
#   'symbol': 'DASH',
#   'total_supply': 7880240.0},
#  {'24h_volume_usd': 44327500.0,
#   'available_supply': 15713822.0,
#   'id': 'monero',
#   'last_updated': 1518461642,
#   'market_cap_usd': 3853233443.0,
#   'max_supply': None,
#   'name': 'Monero',
#   'percent_change_1h': -0.37,
#   'percent_change_24h': 5.01,
#   'percent_change_7d': 32.41,
#   'price_btc': 0.0283957,
#   'price_usd': 245.213,
#   'rank': 13,
#   'symbol': 'XMR',
#   'total_supply': 15713822.0},
#  {'24h_volume_usd': 53817500.0,
#   'available_supply': 117996156.0,
#   'id': 'lisk',
#   'last_updated': 1518461646,
#   'market_cap_usd': 3214215289.0,
#   'max_supply': None,
#   'name': 'Lisk',
#   'percent_change_1h': -1.09,
#   'percent_change_24h': 5.3,
#   'percent_change_7d': 68.18,
#   'price_btc': 0.0031544,
#   'price_usd': 27.24,
#   'rank': 14,
#   'symbol': 'LSK',
#   'total_supply': 117996156.0},
#  {'24h_volume_usd': 220709000.0,
#   'available_supply': 65748192475.0,
#   'id': 'tron',
#   'last_updated': 1518461653,
#   'market_cap_usd': 2996631668.0,
#   'max_supply': None,
#   'name': 'TRON',
#   'percent_change_1h': -0.97,
#   'percent_change_24h': 4.41,
#   'percent_change_7d': 43.75,
#   'price_btc': 5.28e-06,
#   'price_usd': 0.0455774,
#   'rank': 15,
#   'symbol': 'TRX',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 464988000.0,
#   'available_supply': 99808351.0,
#   'id': 'ethereum-classic',
#   'last_updated': 1518461648,
#   'market_cap_usd': 2863641322.0,
#   'max_supply': None,
#   'name': 'Ethereum Classic',
#   'percent_change_1h': -0.45,
#   'percent_change_24h': 14.37,
#   'percent_change_7d': 62.96,
#   'price_btc': 0.00332246,
#   'price_usd': 28.6914,
#   'rank': 16,
#   'symbol': 'ETC',
#   'total_supply': 99808351.0},
#  {'24h_volume_usd': 2303030000.0,
#   'available_supply': 2217140814.0,
#   'id': 'tether',
#   'last_updated': 1518461645,
#   'market_cap_usd': 2216670780.0,
#   'max_supply': None,
#   'name': 'Tether',
#   'percent_change_1h': -0.17,
#   'percent_change_24h': -0.22,
#   'percent_change_7d': 0.08,
#   'price_btc': 0.00011578,
#   'price_usd': 0.999788,
#   'rank': 17,
#   'symbol': 'USDT',
#   'total_supply': 2280109970.0},
#  {'24h_volume_usd': 191537000.0,
#   'available_supply': 73876776.0,
#   'id': 'qtum',
#   'last_updated': 1518461650,
#   'market_cap_usd': 2169288100.0,
#   'max_supply': None,
#   'name': 'Qtum',
#   'percent_change_1h': -1.48,
#   'percent_change_24h': 3.29,
#   'percent_change_7d': 35.2,
#   'price_btc': 0.00340031,
#   'price_usd': 29.3636,
#   'rank': 18,
#   'symbol': 'QTUM',
#   'total_supply': 100376776.0},
#  {'24h_volume_usd': 26708200.0,
#   'available_supply': 470791178.0,
#   'id': 'vechain',
#   'last_updated': 1518461653,
#   'market_cap_usd': 1978815356.0,
#   'max_supply': None,
#   'name': 'VeChain',
#   'percent_change_1h': -1.19,
#   'percent_change_24h': 2.22,
#   'percent_change_7d': 17.08,
#   'price_btc': 0.00048673,
#   'price_usd': 4.20317,
#   'rank': 19,
#   'symbol': 'VEN',
#   'total_supply': 873378637.0},
#  {'24h_volume_usd': 29154400.0,
#   'available_supply': 16819936.0,
#   'id': 'bitcoin-gold',
#   'last_updated': 1518461655,
#   'market_cap_usd': 1898600746.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Gold',
#   'percent_change_1h': -12.24,
#   'percent_change_24h': -10.44,
#   'percent_change_7d': 26.92,
#   'price_btc': 0.0130712,
#   'price_usd': 112.878,
#   'rank': 20,
#   'symbol': 'BTG',
#   'total_supply': 16919936.0},
#  {'24h_volume_usd': 4378680.0,
#   'available_supply': 8632313657.0,
#   'id': 'ucash',
#   'last_updated': 1518461660,
#   'market_cap_usd': 1776745958.0,
#   'max_supply': 21000000000.0,
#   'name': 'U.CASH',
#   'percent_change_1h': 7.61,
#   'percent_change_24h': 167.85,
#   'percent_change_7d': None,
#   'price_btc': 2.383e-05,
#   'price_usd': 0.205825,
#   'rank': 21,
#   'symbol': 'UCASH',
#   'total_supply': 21000000000.0},
#  {'24h_volume_usd': 65438900.0,
#   'available_supply': 381495014.0,
#   'id': 'icon',
#   'last_updated': 1518461655,
#   'market_cap_usd': 1580209572.0,
#   'max_supply': None,
#   'name': 'ICON',
#   'percent_change_1h': -2.12,
#   'percent_change_24h': 7.34,
#   'percent_change_7d': 31.16,
#   'price_btc': 0.00047966,
#   'price_usd': 4.14215,
#   'rank': 22,
#   'symbol': 'ICX',
#   'total_supply': 400230000.0},
#  {'24h_volume_usd': 69631100.0,
#   'available_supply': 3264131.0,
#   'id': 'zcash',
#   'last_updated': 1518461648,
#   'market_cap_usd': 1487875891.0,
#   'max_supply': None,
#   'name': 'Zcash',
#   'percent_change_1h': -1.26,
#   'percent_change_24h': -0.21,
#   'percent_change_7d': 48.88,
#   'price_btc': 0.0527847,
#   'price_usd': 455.826,
#   'rank': 23,
#   'symbol': 'ZEC',
#   'total_supply': 3264131.0},
#  {'24h_volume_usd': 23711300.0,
#   'available_supply': 102042552.0,
#   'id': 'omisego',
#   'last_updated': 1518461652,
#   'market_cap_usd': 1274746169.0,
#   'max_supply': None,
#   'name': 'OmiseGO',
#   'percent_change_1h': -0.21,
#   'percent_change_24h': 2.48,
#   'percent_change_7d': 28.27,
#   'price_btc': 0.0014466,
#   'price_usd': 12.4923,
#   'rank': 24,
#   'symbol': 'OMG',
#   'total_supply': 140245398.0},
#  {'24h_volume_usd': 34928000.0,
#   'available_supply': 133248289.0,
#   'id': 'raiblocks',
#   'last_updated': 1518461649,
#   'market_cap_usd': 1264700820.0,
#   'max_supply': 133248290.0,
#   'name': 'Nano',
#   'percent_change_1h': -1.95,
#   'percent_change_24h': 8.31,
#   'percent_change_7d': 7.1,
#   'price_btc': 0.00109909,
#   'price_usd': 9.49131,
#   'rank': 25,
#   'symbol': 'XRB',
#   'total_supply': 133248289.0},
#  {'24h_volume_usd': 21251600.0,
#   'available_supply': 37004027.0,
#   'id': 'populous',
#   'last_updated': 1518461651,
#   'market_cap_usd': 1043491356.0,
#   'max_supply': 53252246.0,
#   'name': 'Populous',
#   'percent_change_1h': -0.49,
#   'percent_change_24h': 21.12,
#   'percent_change_7d': -24.83,
#   'price_btc': 0.00326549,
#   'price_usd': 28.1994,
#   'rank': 26,
#   'symbol': 'PPT',
#   'total_supply': 53252246.0},
#  {'24h_volume_usd': 19431200.0,
#   'available_supply': 249241445.0,
#   'id': 'steem',
#   'last_updated': 1518461646,
#   'market_cap_usd': 1017022240.0,
#   'max_supply': None,
#   'name': 'Steem',
#   'percent_change_1h': -0.49,
#   'percent_change_24h': 1.12,
#   'percent_change_7d': 21.01,
#   'price_btc': 0.00047252,
#   'price_usd': 4.08047,
#   'rank': 27,
#   'symbol': 'STEEM',
#   'total_supply': 266215539.0},
#  {'24h_volume_usd': 57417200.0,
#   'available_supply': 99014000.0,
#   'id': 'binance-coin',
#   'last_updated': 1518461652,
#   'market_cap_usd': 907457369.0,
#   'max_supply': None,
#   'name': 'Binance Coin',
#   'percent_change_1h': -0.73,
#   'percent_change_24h': 3.03,
#   'percent_change_7d': 31.93,
#   'price_btc': 0.0010613,
#   'price_usd': 9.16494,
#   'rank': 28,
#   'symbol': 'BNB',
#   'total_supply': 197192382.0},
#  {'24h_volume_usd': 2546100.0,
#   'available_supply': 183723412001,
#   'id': 'bytecoin-bcn',
#   'last_updated': 1518461642,
#   'market_cap_usd': 858714042.0,
#   'max_supply': 184470000000,
#   'name': 'Bytecoin',
#   'percent_change_1h': -0.97,
#   'percent_change_24h': 3.79,
#   'percent_change_7d': 27.77,
#   'price_btc': 5.4e-07,
#   'price_usd': 0.00467395,
#   'rank': 29,
#   'symbol': 'BCN',
#   'total_supply': 183723412001},
#  {'24h_volume_usd': 13147900.0,
#   'available_supply': 14587648734.0,
#   'id': 'verge',
#   'last_updated': 1518461643,
#   'market_cap_usd': 802206897.0,
#   'max_supply': 16555000000.0,
#   'name': 'Verge',
#   'percent_change_1h': -0.58,
#   'percent_change_24h': 3.95,
#   'percent_change_7d': 24.29,
#   'price_btc': 6.37e-06,
#   'price_usd': 0.0549922,
#   'rank': 30,
#   'symbol': 'XVG',
#   'total_supply': 14587648734.0},
#  {'24h_volume_usd': 10948700.0,
#   'available_supply': 32430860924.0,
#   'id': 'siacoin',
#   'last_updated': 1518461645,
#   'market_cap_usd': 768890309.0,
#   'max_supply': None,
#   'name': 'Siacoin',
#   'percent_change_1h': -1.04,
#   'percent_change_24h': 3.5,
#   'percent_change_7d': 24.96,
#   'price_btc': 2.75e-06,
#   'price_usd': 0.0237086,
#   'rank': 31,
#   'symbol': 'SC',
#   'total_supply': 32430860924.0},
#  {'24h_volume_usd': 66422000.0,
#   'available_supply': 3470483788.0,
#   'id': 'status',
#   'last_updated': 1518461651,
#   'market_cap_usd': 761951657.0,
#   'max_supply': None,
#   'name': 'Status',
#   'percent_change_1h': -0.47,
#   'percent_change_24h': -0.35,
#   'percent_change_7d': 15.97,
#   'price_btc': 2.542e-05,
#   'price_usd': 0.219552,
#   'rank': 32,
#   'symbol': 'SNT',
#   'total_supply': 6804870174.0},
#  {'24h_volume_usd': 7581520.0,
#   'available_supply': 98737959.0,
#   'id': 'stratis',
#   'last_updated': 1518461648,
#   'market_cap_usd': 730415041.0,
#   'max_supply': None,
#   'name': 'Stratis',
#   'percent_change_1h': -1.15,
#   'percent_change_24h': 2.22,
#   'percent_change_7d': 16.52,
#   'price_btc': 0.00085663,
#   'price_usd': 7.39751,
#   'rank': 33,
#   'symbol': 'STRAT',
#   'total_supply': 98737959.0},
#  {'24h_volume_usd': 879639.0,
#   'available_supply': 618228.0,
#   'id': 'maker',
#   'last_updated': 1518461648,
#   'market_cap_usd': 644304617.0,
#   'max_supply': None,
#   'name': 'Maker',
#   'percent_change_1h': -0.9,
#   'percent_change_24h': 1.65,
#   'percent_change_7d': 22.66,
#   'price_btc': 0.120684,
#   'price_usd': 1042.18,
#   'rank': 34,
#   'symbol': 'MKR',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 14422900.0,
#   'available_supply': 2608610000.0,
#   'id': 'bitshares',
#   'last_updated': 1518461642,
#   'market_cap_usd': 638882501.0,
#   'max_supply': 3600570502.0,
#   'name': 'BitShares',
#   'percent_change_1h': -0.84,
#   'percent_change_24h': 0.62,
#   'percent_change_7d': 15.67,
#   'price_btc': 2.836e-05,
#   'price_usd': 0.244913,
#   'rank': 35,
#   'symbol': 'BTS',
#   'total_supply': 2608610000.0},
#  {'24h_volume_usd': 951662.0,
#   'available_supply': 344166289.0,
#   'id': 'rchain',
#   'last_updated': 1518461654,
#   'market_cap_usd': 636184502.0,
#   'max_supply': 1000000000.0,
#   'name': 'RChain',
#   'percent_change_1h': 4.86,
#   'percent_change_24h': 23.35,
#   'percent_change_7d': 53.71,
#   'price_btc': 0.00021405,
#   'price_usd': 1.84848,
#   'rank': 36,
#   'symbol': 'RHOC',
#   'total_supply': 870663574.0},
#  {'24h_volume_usd': 3436230.0,
#   'available_supply': 233020472.0,
#   'id': 'aeternity',
#   'last_updated': 1518461650,
#   'market_cap_usd': 606957745.0,
#   'max_supply': None,
#   'name': 'Aeternity',
#   'percent_change_1h': -1.53,
#   'percent_change_24h': -0.44,
#   'percent_change_7d': 19.6,
#   'price_btc': 0.00030163,
#   'price_usd': 2.60474,
#   'rank': 37,
#   'symbol': 'AE',
#   'total_supply': 273685830.0},
#  {'24h_volume_usd': 10360200.0,
#   'available_supply': 113174969242,
#   'id': 'dogecoin',
#   'last_updated': 1518461641,
#   'market_cap_usd': 601242024.0,
#   'max_supply': None,
#   'name': 'Dogecoin',
#   'percent_change_1h': -0.18,
#   'percent_change_24h': 4.74,
#   'percent_change_7d': 43.1,
#   'price_btc': 6.2e-07,
#   'price_usd': 0.0053125,
#   'rank': 38,
#   'symbol': 'DOGE',
#   'total_supply': 113174969242},
#  {'24h_volume_usd': 10569300.0,
#   'available_supply': 11000000.0,
#   'id': 'augur',
#   'last_updated': 1518461645,
#   'market_cap_usd': 581879100.0,
#   'max_supply': None,
#   'name': 'Augur',
#   'percent_change_1h': -0.49,
#   'percent_change_24h': 4.48,
#   'percent_change_7d': 18.25,
#   'price_btc': 0.00612561,
#   'price_usd': 52.8981,
#   'rank': 39,
#   'symbol': 'REP',
#   'total_supply': 11000000.0},
#  {'24h_volume_usd': 21715300.0,
#   'available_supply': 100000000.0,
#   'id': 'waves',
#   'last_updated': 1518461647,
#   'market_cap_usd': 556351000.0,
#   'max_supply': None,
#   'name': 'Waves',
#   'percent_change_1h': -2.84,
#   'percent_change_24h': -0.23,
#   'percent_change_7d': 14.48,
#   'price_btc': 0.00064426,
#   'price_usd': 5.56351,
#   'rank': 40,
#   'symbol': 'WAVES',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 97697.7,
#   'available_supply': 2036645.0,
#   'id': 'veritaseum',
#   'last_updated': 1518461650,
#   'market_cap_usd': 553250660.0,
#   'max_supply': None,
#   'name': 'Veritaseum',
#   'percent_change_1h': -1.13,
#   'percent_change_24h': 3.3,
#   'percent_change_7d': 8.88,
#   'price_btc': 0.0314568,
#   'price_usd': 271.648,
#   'rank': 41,
#   'symbol': 'VERI',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 6668200.0,
#   'available_supply': 24898178.0,
#   'id': 'walton',
#   'last_updated': 1518461652,
#   'market_cap_usd': 540377606.0,
#   'max_supply': 100000000.0,
#   'name': 'Walton',
#   'percent_change_1h': -0.74,
#   'percent_change_24h': 3.88,
#   'percent_change_7d': 19.66,
#   'price_btc': 0.00251327,
#   'price_usd': 21.7035,
#   'rank': 42,
#   'symbol': 'WTC',
#   'total_supply': 70000000.0},
#  {'24h_volume_usd': 5533920.0,
#   'available_supply': 507683814.0,
#   'id': '0x',
#   'last_updated': 1518461653,
#   'market_cap_usd': 521543583.0,
#   'max_supply': None,
#   'name': '0x',
#   'percent_change_1h': -1.25,
#   'percent_change_24h': 1.71,
#   'percent_change_7d': 21.06,
#   'price_btc': 0.00011896,
#   'price_usd': 1.0273,
#   'rank': 43,
#   'symbol': 'ZRX',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 800982.0,
#   'available_supply': 6742928.0,
#   'id': 'decred',
#   'last_updated': 1518461645,
#   'market_cap_usd': 517753031.0,
#   'max_supply': 21000000.0,
#   'name': 'Decred',
#   'percent_change_1h': -1.49,
#   'percent_change_24h': 5.44,
#   'percent_change_7d': 23.31,
#   'price_btc': 0.00889167,
#   'price_usd': 76.7846,
#   'rank': 44,
#   'symbol': 'DCR',
#   'total_supply': 7162928.0},
#  {'24h_volume_usd': 10376700.0,
#   'available_supply': 998999495.0,
#   'id': 'ardor',
#   'last_updated': 1518461648,
#   'market_cap_usd': 516038184.0,
#   'max_supply': 998999495.0,
#   'name': 'Ardor',
#   'percent_change_1h': -0.79,
#   'percent_change_24h': 2.07,
#   'percent_change_7d': 34.35,
#   'price_btc': 5.982e-05,
#   'price_usd': 0.516555,
#   'rank': 45,
#   'symbol': 'ARDR',
#   'total_supply': 998999495.0},
#  {'24h_volume_usd': 2078330.0,
#   'available_supply': 91043076.0,
#   'id': 'kucoin-shares',
#   'last_updated': 1518461655,
#   'market_cap_usd': 514576376.0,
#   'max_supply': None,
#   'name': 'KuCoin Shares',
#   'percent_change_1h': -2.01,
#   'percent_change_24h': 3.5,
#   'percent_change_7d': 18.73,
#   'price_btc': 0.0006545,
#   'price_usd': 5.65201,
#   'rank': 46,
#   'symbol': 'KCS',
#   'total_supply': 181043076.0},
#  {'24h_volume_usd': 60985900.0,
#   'available_supply': 42615549.0,
#   'id': 'hshare',
#   'last_updated': 1518461652,
#   'market_cap_usd': 511476078.0,
#   'max_supply': 84000000.0,
#   'name': 'Hshare',
#   'percent_change_1h': -0.28,
#   'percent_change_24h': 1.4,
#   'percent_change_7d': 35.55,
#   'price_btc': 0.00138984,
#   'price_usd': 12.0021,
#   'rank': 47,
#   'symbol': 'HSR',
#   'total_supply': 42615549.0},
#  {'24h_volume_usd': 18071300.0,
#   'available_supply': 184450000.0,
#   'id': 'revain',
#   'last_updated': 1518461655,
#   'market_cap_usd': 501338789.0,
#   'max_supply': 484450000.0,
#   'name': 'Revain',
#   'percent_change_1h': 0.94,
#   'percent_change_24h': 8.73,
#   'percent_change_7d': 96.8,
#   'price_btc': 0.00031475,
#   'price_usd': 2.71802,
#   'rank': 48,
#   'symbol': 'R',
#   'total_supply': 484450000.0},
#  {'24h_volume_usd': 6878580.0,
#   'available_supply': 2000000.0,
#   'id': 'digixdao',
#   'last_updated': 1518461646,
#   'market_cap_usd': 473368000.0,
#   'max_supply': None,
#   'name': 'DigixDAO',
#   'percent_change_1h': -1.94,
#   'percent_change_24h': 2.38,
#   'percent_change_7d': 8.01,
#   'price_btc': 0.027408,
#   'price_usd': 236.684,
#   'rank': 49,
#   'symbol': 'DGD',
#   'total_supply': 2000000.0},
#  {'24h_volume_usd': 1925810.0,
#   'available_supply': 103254000.0,
#   'id': 'komodo',
#   'last_updated': 1518461650,
#   'market_cap_usd': 433364266.0,
#   'max_supply': None,
#   'name': 'Komodo',
#   'percent_change_1h': 0.09,
#   'percent_change_24h': 3.2,
#   'percent_change_7d': 21.61,
#   'price_btc': 0.00048602,
#   'price_usd': 4.19707,
#   'rank': 50,
#   'symbol': 'KMD',
#   'total_supply': 103254000.0},
#  {'24h_volume_usd': 2122030.0,
#   'available_supply': 6134452185.0,
#   'id': 'electroneum',
#   'last_updated': 1518461655,
#   'market_cap_usd': 423106663.0,
#   'max_supply': 21000000000.0,
#   'name': 'Electroneum',
#   'percent_change_1h': -1.3,
#   'percent_change_24h': 4.64,
#   'percent_change_7d': 38.93,
#   'price_btc': 7.99e-06,
#   'price_usd': 0.0689722,
#   'rank': 51,
#   'symbol': 'ETN',
#   'total_supply': 6134452185.0},
#  {'24h_volume_usd': 1643170.0,
#   'available_supply': 100589122.0,
#   'id': 'ark',
#   'last_updated': 1518461649,
#   'market_cap_usd': 403962896.0,
#   'max_supply': None,
#   'name': 'Ark',
#   'percent_change_1h': -1.27,
#   'percent_change_24h': 2.47,
#   'percent_change_7d': 20.17,
#   'price_btc': 0.00046505,
#   'price_usd': 4.01597,
#   'rank': 52,
#   'symbol': 'ARK',
#   'total_supply': 131839122.0},
#  {'24h_volume_usd': 2680980.0,
#   'available_supply': 238421940.0,
#   'id': 'dragonchain',
#   'last_updated': 1518461657,
#   'market_cap_usd': 384123972.0,
#   'max_supply': None,
#   'name': 'Dragonchain',
#   'percent_change_1h': 1.3,
#   'percent_change_24h': 14.87,
#   'percent_change_7d': 28.27,
#   'price_btc': 0.00018657,
#   'price_usd': 1.61111,
#   'rank': 53,
#   'symbol': 'DRGN',
#   'total_supply': 433494437.0},
#  {'24h_volume_usd': 4185030.0,
#   'available_supply': 9694015.0,
#   'id': 'gas',
#   'last_updated': 1518461652,
#   'market_cap_usd': 379519727.0,
#   'max_supply': 100000000.0,
#   'name': 'Gas',
#   'percent_change_1h': -0.97,
#   'percent_change_24h': -0.5,
#   'percent_change_7d': 19.69,
#   'price_btc': 0.00453356,
#   'price_usd': 39.1499,
#   'rank': 54,
#   'symbol': 'GAS',
#   'total_supply': 15342016.0},
#  {'24h_volume_usd': 9137180.0,
#   'available_supply': 134132697.0,
#   'id': 'kyber-network',
#   'last_updated': 1518461653,
#   'market_cap_usd': 374672862.0,
#   'max_supply': None,
#   'name': 'Kyber Network',
#   'percent_change_1h': -1.38,
#   'percent_change_24h': -3.83,
#   'percent_change_7d': 3.39,
#   'price_btc': 0.00032346,
#   'price_usd': 2.7933,
#   'rank': 55,
#   'symbol': 'KNC',
#   'total_supply': 215625349.0},
#  {'24h_volume_usd': 142377.0,
#   'available_supply': 4981227.0,
#   'id': 'e-coin',
#   'last_updated': 1518461649,
#   'market_cap_usd': 365817349.0,
#   'max_supply': None,
#   'name': 'E-coin',
#   'percent_change_1h': 11.41,
#   'percent_change_24h': 287.46,
#   'percent_change_7d': 1137.67,
#   'price_btc': 0.00850427,
#   'price_usd': 73.4392,
#   'rank': 56,
#   'symbol': 'ECN',
#   'total_supply': 213270119.0},
#  {'24h_volume_usd': 1536670.0,
#   'available_supply': 561202251.0,
#   'id': 'loopring',
#   'last_updated': 1518461652,
#   'market_cap_usd': 363911039.0,
#   'max_supply': None,
#   'name': 'Loopring',
#   'percent_change_1h': -0.43,
#   'percent_change_24h': 2.88,
#   'percent_change_7d': 14.68,
#   'price_btc': 7.509e-05,
#   'price_usd': 0.648449,
#   'rank': 57,
#   'symbol': 'LRC',
#   'total_supply': 1374956357.0},
#  {'24h_volume_usd': 3044030.0,
#   'available_supply': 1000000000.0,
#   'id': 'basic-attention-token',
#   'last_updated': 1518461650,
#   'market_cap_usd': 362707000.0,
#   'max_supply': None,
#   'name': 'Basic Attention Token',
#   'percent_change_1h': -1.2,
#   'percent_change_24h': 5.47,
#   'percent_change_7d': 13.59,
#   'price_btc': 4.2e-05,
#   'price_usd': 0.362707,
#   'rank': 58,
#   'symbol': 'BAT',
#   'total_supply': 1500000000.0},
#  {'24h_volume_usd': 11376700.0,
#   'available_supply': 987000000.0,
#   'id': 'bytom',
#   'last_updated': 1518461652,
#   'market_cap_usd': 360083262.0,
#   'max_supply': None,
#   'name': 'Bytom',
#   'percent_change_1h': -0.75,
#   'percent_change_24h': 0.79,
#   'percent_change_7d': 42.96,
#   'price_btc': 4.225e-05,
#   'price_usd': 0.364826,
#   'rank': 59,
#   'symbol': 'BTM',
#   'total_supply': 1407000000.0},
#  {'24h_volume_usd': 3254810.0,
#   'available_supply': 9832526186.0,
#   'id': 'digibyte',
#   'last_updated': 1518461641,
#   'market_cap_usd': 358527335.0,
#   'max_supply': 21000000000.0,
#   'name': 'DigiByte',
#   'percent_change_1h': -1.39,
#   'percent_change_24h': 5.66,
#   'percent_change_7d': 27.17,
#   'price_btc': 4.22e-06,
#   'price_usd': 0.0364634,
#   'rank': 60,
#   'symbol': 'DGB',
#   'total_supply': 9832526186.0},
#  {'24h_volume_usd': 487451.0,
#   'available_supply': 325226613094,
#   'id': 'dentacoin',
#   'last_updated': 1518461653,
#   'market_cap_usd': 352906650.0,
#   'max_supply': 8000000000000,
#   'name': 'Dentacoin',
#   'percent_change_1h': -1.24,
#   'percent_change_24h': -1.51,
#   'percent_change_7d': 12.75,
#   'price_btc': 1.3e-07,
#   'price_usd': 0.00108511,
#   'rank': 61,
#   'symbol': 'DCN',
#   'total_supply': 1963173416169},
#  {'24h_volume_usd': 3880680.0,
#   'available_supply': 3298813.0,
#   'id': 'zclassic',
#   'last_updated': 1518461647,
#   'market_cap_usd': 350241521.0,
#   'max_supply': 21000000.0,
#   'name': 'ZClassic',
#   'percent_change_1h': -0.53,
#   'percent_change_24h': 8.73,
#   'percent_change_7d': 38.94,
#   'price_btc': 0.0122947,
#   'price_usd': 106.172,
#   'rank': 62,
#   'symbol': 'ZCL',
#   'total_supply': 3298813.0},
#  {'24h_volume_usd': 444030.0,
#   'available_supply': 645222.0,
#   'id': 'byteball',
#   'last_updated': 1518461649,
#   'market_cap_usd': 340139774.0,
#   'max_supply': None,
#   'name': 'Byteball Bytes',
#   'percent_change_1h': -1.15,
#   'percent_change_24h': 8.07,
#   'percent_change_7d': 29.42,
#   'price_btc': 0.061046,
#   'price_usd': 527.167,
#   'rank': 63,
#   'symbol': 'GBYTE',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 9655590.0,
#   'available_supply': 6511228178.0,
#   'id': 'zilliqa',
#   'last_updated': 1518461660,
#   'market_cap_usd': 331572575.0,
#   'max_supply': None,
#   'name': 'Zilliqa',
#   'percent_change_1h': -1.61,
#   'percent_change_24h': -0.25,
#   'percent_change_7d': 0.92,
#   'price_btc': 5.9e-06,
#   'price_usd': 0.0509232,
#   'rank': 64,
#   'symbol': 'ZIL',
#   'total_supply': 12600000000.0},
#  {'24h_volume_usd': 6078610.0,
#   'available_supply': 55545643.0,
#   'id': 'pivx',
#   'last_updated': 1518461656,
#   'market_cap_usd': 330531017.0,
#   'max_supply': None,
#   'name': 'PIVX',
#   'percent_change_1h': -0.2,
#   'percent_change_24h': 6.08,
#   'percent_change_7d': 16.69,
#   'price_btc': 0.00068908,
#   'price_usd': 5.95062,
#   'rank': 65,
#   'symbol': 'PIVX',
#   'total_supply': 55545643.0},
#  {'24h_volume_usd': 4251260.0,
#   'available_supply': 350000000.0,
#   'id': 'qash',
#   'last_updated': 1518461657,
#   'market_cap_usd': 309751050.0,
#   'max_supply': None,
#   'name': 'QASH',
#   'percent_change_1h': -0.68,
#   'percent_change_24h': 2.6,
#   'percent_change_7d': 25.41,
#   'price_btc': 0.00010248,
#   'price_usd': 0.885003,
#   'rank': 66,
#   'symbol': 'QASH',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 1296430.0,
#   'available_supply': 75633252.0,
#   'id': 'ethos',
#   'last_updated': 1518461652,
#   'market_cap_usd': 305261855.0,
#   'max_supply': None,
#   'name': 'Ethos',
#   'percent_change_1h': -0.8,
#   'percent_change_24h': 6.05,
#   'percent_change_7d': 46.8,
#   'price_btc': 0.00046738,
#   'price_usd': 4.03608,
#   'rank': 67,
#   'symbol': 'ETHOS',
#   'total_supply': 222295208.0},
#  {'24h_volume_usd': 4670780.0,
#   'available_supply': 834262000.0,
#   'id': 'golem-network-tokens',
#   'last_updated': 1518461648,
#   'market_cap_usd': 304656631.0,
#   'max_supply': None,
#   'name': 'Golem',
#   'percent_change_1h': -0.51,
#   'percent_change_24h': 6.65,
#   'percent_change_7d': 26.36,
#   'price_btc': 4.229e-05,
#   'price_usd': 0.365181,
#   'rank': 68,
#   'symbol': 'GNT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 242506.0,
#   'available_supply': 45112697.0,
#   'id': 'cryptonex',
#   'last_updated': 1518461657,
#   'market_cap_usd': 300361691.0,
#   'max_supply': 210000000.0,
#   'name': 'Cryptonex',
#   'percent_change_1h': -3.54,
#   'percent_change_24h': 1.6,
#   'percent_change_7d': 23.17,
#   'price_btc': 0.000771,
#   'price_usd': 6.65803,
#   'rank': 69,
#   'symbol': 'CNX',
#   'total_supply': 106550323.0},
#  {'24h_volume_usd': 33310400.0,
#   'available_supply': 250000000.0,
#   'id': 'aelf',
#   'last_updated': 1518461658,
#   'market_cap_usd': 297302500.0,
#   'max_supply': None,
#   'name': 'aelf',
#   'percent_change_1h': -0.77,
#   'percent_change_24h': 1.59,
#   'percent_change_7d': 5.54,
#   'price_btc': 0.00013771,
#   'price_usd': 1.18921,
#   'rank': 70,
#   'symbol': 'ELF',
#   'total_supply': 260000000.0},
#  {'24h_volume_usd': 9207130.0,
#   'available_supply': 35500000.0,
#   'id': 'nebulas-token',
#   'last_updated': 1518461652,
#   'market_cap_usd': 296835025.0,
#   'max_supply': 100000000.0,
#   'name': 'Nebulas',
#   'percent_change_1h': -0.36,
#   'percent_change_24h': 1.06,
#   'percent_change_7d': 33.97,
#   'price_btc': 0.00096827,
#   'price_usd': 8.36155,
#   'rank': 71,
#   'symbol': 'NAS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 11319800.0,
#   'available_supply': 60000000.0,
#   'id': 'gxshares',
#   'last_updated': 1518461651,
#   'market_cap_usd': 282763800.0,
#   'max_supply': 100000000.0,
#   'name': 'GXShares',
#   'percent_change_1h': -0.72,
#   'percent_change_24h': -0.54,
#   'percent_change_7d': 24.57,
#   'price_btc': 0.00054573,
#   'price_usd': 4.71273,
#   'rank': 72,
#   'symbol': 'GXS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 1511090.0,
#   'available_supply': 530904763.0,
#   'id': 'syscoin',
#   'last_updated': 1518461643,
#   'market_cap_usd': 280982408.0,
#   'max_supply': 888000000.0,
#   'name': 'Syscoin',
#   'percent_change_1h': -1.04,
#   'percent_change_24h': 5.29,
#   'percent_change_7d': 37.35,
#   'price_btc': 6.129e-05,
#   'price_usd': 0.529252,
#   'rank': 73,
#   'symbol': 'SYS',
#   'total_supply': 530904763.0},
#  {'24h_volume_usd': 1745960.0,
#   'available_supply': 11351430.0,
#   'id': 'bitcore',
#   'last_updated': 1518461650,
#   'market_cap_usd': 275182499.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcore',
#   'percent_change_1h': -1.91,
#   'percent_change_24h': -5.5,
#   'percent_change_7d': 15.74,
#   'price_btc': 0.00280723,
#   'price_usd': 24.2421,
#   'rank': 74,
#   'symbol': 'BTX',
#   'total_supply': 16800628.0},
#  {'24h_volume_usd': 7909310.0,
#   'available_supply': 363837589.0,
#   'id': 'power-ledger',
#   'last_updated': 1518461655,
#   'market_cap_usd': 271707362.0,
#   'max_supply': None,
#   'name': 'Power Ledger',
#   'percent_change_1h': -0.69,
#   'percent_change_24h': 4.05,
#   'percent_change_7d': 48.54,
#   'price_btc': 8.648e-05,
#   'price_usd': 0.746782,
#   'rank': 75,
#   'symbol': 'POWR',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 375917.0,
#   'available_supply': 227384800.0,
#   'id': 'pillar',
#   'last_updated': 1518461652,
#   'market_cap_usd': 269300914.0,
#   'max_supply': None,
#   'name': 'Pillar',
#   'percent_change_1h': -3.77,
#   'percent_change_24h': -2.93,
#   'percent_change_7d': 19.32,
#   'price_btc': 0.00013715,
#   'price_usd': 1.18434,
#   'rank': 76,
#   'symbol': 'PLR',
#   'total_supply': 800000000.0},
#  {'24h_volume_usd': 4290910.0,
#   'available_supply': 1445976590.0,
#   'id': 'cindicator',
#   'last_updated': 1518461654,
#   'market_cap_usd': 259698842.0,
#   'max_supply': None,
#   'name': 'Cindicator',
#   'percent_change_1h': 0.47,
#   'percent_change_24h': 6.87,
#   'percent_change_7d': 24.02,
#   'price_btc': 2.08e-05,
#   'price_usd': 0.179601,
#   'rank': 77,
#   'symbol': 'CND',
#   'total_supply': 2000000005.0},
#  {'24h_volume_usd': 3903060.0,
#   'available_supply': 8745102.0,
#   'id': 'factom',
#   'last_updated': 1518461646,
#   'market_cap_usd': 254071448.0,
#   'max_supply': None,
#   'name': 'Factom',
#   'percent_change_1h': 0.62,
#   'percent_change_24h': 9.8,
#   'percent_change_7d': 29.23,
#   'price_btc': 0.00336433,
#   'price_usd': 29.053,
#   'rank': 78,
#   'symbol': 'FCT',
#   'total_supply': 8745102.0},
#  {'24h_volume_usd': 42518100.0,
#   'available_supply': 6794109922.0,
#   'id': 'iostoken',
#   'last_updated': 1518461659,
#   'market_cap_usd': 253516097.0,
#   'max_supply': None,
#   'name': 'IOStoken',
#   'percent_change_1h': -1.71,
#   'percent_change_24h': 1.37,
#   'percent_change_7d': 18.83,
#   'price_btc': 4.32e-06,
#   'price_usd': 0.0373141,
#   'rank': 79,
#   'symbol': 'IOST',
#   'total_supply': 21000000000.0},
#  {'24h_volume_usd': 2151950.0,
#   'available_supply': 10614760961.0,
#   'id': 'dent',
#   'last_updated': 1518461652,
#   'market_cap_usd': 252827684.0,
#   'max_supply': None,
#   'name': 'Dent',
#   'percent_change_1h': -1.94,
#   'percent_change_24h': 2.18,
#   'percent_change_7d': 20.34,
#   'price_btc': 2.76e-06,
#   'price_usd': 0.0238185,
#   'rank': 80,
#   'symbol': 'DENT',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 5762090.0,
#   'available_supply': 57376950.0,
#   'id': 'monacoin',
#   'last_updated': 1518461642,
#   'market_cap_usd': 250780878.0,
#   'max_supply': None,
#   'name': 'MonaCoin',
#   'percent_change_1h': 0.66,
#   'percent_change_24h': 12.3,
#   'percent_change_7d': 25.27,
#   'price_btc': 0.00050613,
#   'price_usd': 4.37076,
#   'rank': 81,
#   'symbol': 'MONA',
#   'total_supply': 57376950.0},
#  {'24h_volume_usd': 5716940.0,
#   'available_supply': 4503688789.0,
#   'id': 'funfair',
#   'last_updated': 1518461651,
#   'market_cap_usd': 240143892.0,
#   'max_supply': None,
#   'name': 'FunFair',
#   'percent_change_1h': -1.68,
#   'percent_change_24h': -1.25,
#   'percent_change_7d': 31.62,
#   'price_btc': 6.17e-06,
#   'price_usd': 0.0533216,
#   'rank': 82,
#   'symbol': 'FUN',
#   'total_supply': 10999873621.0},
#  {'24h_volume_usd': 3133440.0,
#   'available_supply': 79265735.0,
#   'id': 'aion',
#   'last_updated': 1518461655,
#   'market_cap_usd': 237774218.0,
#   'max_supply': None,
#   'name': 'Aion',
#   'percent_change_1h': -0.43,
#   'percent_change_24h': 7.03,
#   'percent_change_7d': 26.49,
#   'price_btc': 0.00034737,
#   'price_usd': 2.99971,
#   'rank': 83,
#   'symbol': 'AION',
#   'total_supply': 465934587.0},
#  {'24h_volume_usd': 12315000.0,
#   'available_supply': 74836171.0,
#   'id': 'enigma-project',
#   'last_updated': 1518461654,
#   'market_cap_usd': 234723651.0,
#   'max_supply': None,
#   'name': 'Enigma',
#   'percent_change_1h': -0.77,
#   'percent_change_24h': 9.71,
#   'percent_change_7d': 66.08,
#   'price_btc': 0.00036321,
#   'price_usd': 3.1365,
#   'rank': 84,
#   'symbol': 'ENG',
#   'total_supply': 150000000.0},
#  {'24h_volume_usd': 5380240.0,
#   'available_supply': 4089384.0,
#   'id': 'zcoin',
#   'last_updated': 1518461647,
#   'market_cap_usd': 220208004.0,
#   'max_supply': None,
#   'name': 'ZCoin',
#   'percent_change_1h': -1.24,
#   'percent_change_24h': 2.96,
#   'percent_change_7d': 31.09,
#   'price_btc': 0.00623568,
#   'price_usd': 53.8487,
#   'rank': 85,
#   'symbol': 'XZC',
#   'total_supply': 4089384.0},
#  {'24h_volume_usd': 3216410.0,
#   'available_supply': 53005985.0,
#   'id': 'salt',
#   'last_updated': 1518461653,
#   'market_cap_usd': 219841793.0,
#   'max_supply': None,
#   'name': 'SALT',
#   'percent_change_1h': -1.86,
#   'percent_change_24h': 1.47,
#   'percent_change_7d': 19.74,
#   'price_btc': 0.00048028,
#   'price_usd': 4.14749,
#   'rank': 86,
#   'symbol': 'SALT',
#   'total_supply': 120000000.0},
#  {'24h_volume_usd': 194497.0,
#   'available_supply': 756097560976,
#   'id': 'kin',
#   'last_updated': 1518461654,
#   'market_cap_usd': 214215293.0,
#   'max_supply': None,
#   'name': 'Kin',
#   'percent_change_1h': -1.03,
#   'percent_change_24h': 11.86,
#   'percent_change_7d': 15.97,
#   'price_btc': 3e-08,
#   'price_usd': 0.000283317,
#   'rank': 87,
#   'symbol': 'KIN',
#   'total_supply': 10000000000000},
#  {'24h_volume_usd': 196638.0,
#   'available_supply': 8868968.0,
#   'id': 'particl',
#   'last_updated': 1518461651,
#   'market_cap_usd': 209507204.0,
#   'max_supply': None,
#   'name': 'Particl',
#   'percent_change_1h': -0.2,
#   'percent_change_24h': 2.21,
#   'percent_change_7d': 56.51,
#   'price_btc': 0.00273548,
#   'price_usd': 23.6225,
#   'rank': 88,
#   'symbol': 'PART',
#   'total_supply': 8868968.0},
#  {'24h_volume_usd': 224156.0,
#   'available_supply': 692823009.0,
#   'id': 'smartcash',
#   'last_updated': 1518461652,
#   'market_cap_usd': 205697073.0,
#   'max_supply': 5000000000.0,
#   'name': 'SmartCash',
#   'percent_change_1h': -1.81,
#   'percent_change_24h': -5.85,
#   'percent_change_7d': -5.86,
#   'price_btc': 3.438e-05,
#   'price_usd': 0.296897,
#   'rank': 89,
#   'symbol': 'SMART',
#   'total_supply': 1293867288.0},
#  {'24h_volume_usd': 3709340.0,
#   'available_supply': 38744502.0,
#   'id': 'bancor',
#   'last_updated': 1518461650,
#   'market_cap_usd': 197616335.0,
#   'max_supply': None,
#   'name': 'Bancor',
#   'percent_change_1h': -0.69,
#   'percent_change_24h': 1.92,
#   'percent_change_7d': 16.46,
#   'price_btc': 0.00059064,
#   'price_usd': 5.1005,
#   'rank': 90,
#   'symbol': 'BNT',
#   'total_supply': 74897107.0},
#  {'24h_volume_usd': 3820600.0,
#   'available_supply': 104661310.0,
#   'id': 'tenx',
#   'last_updated': 1518461651,
#   'market_cap_usd': 196551847.0,
#   'max_supply': None,
#   'name': 'TenX',
#   'percent_change_1h': -1.53,
#   'percent_change_24h': 6.0,
#   'percent_change_7d': 33.95,
#   'price_btc': 0.00021747,
#   'price_usd': 1.87798,
#   'rank': 91,
#   'symbol': 'PAY',
#   'total_supply': 205218256.0},
#  {'24h_volume_usd': 2806970.0,
#   'available_supply': 452552412.0,
#   'id': 'maidsafecoin',
#   'last_updated': 1518461642,
#   'market_cap_usd': 194419684.0,
#   'max_supply': None,
#   'name': 'MaidSafeCoin',
#   'percent_change_1h': -1.29,
#   'percent_change_24h': 5.57,
#   'percent_change_7d': 26.56,
#   'price_btc': 4.975e-05,
#   'price_usd': 0.429607,
#   'rank': 92,
#   'symbol': 'MAID',
#   'total_supply': 452552412.0},
#  {'24h_volume_usd': 4156360.0,
#   'available_supply': 998999942.0,
#   'id': 'nxt',
#   'last_updated': 1518461640,
#   'market_cap_usd': 192685111.0,
#   'max_supply': 1000000000.0,
#   'name': 'Nxt',
#   'percent_change_1h': -0.82,
#   'percent_change_24h': 4.42,
#   'percent_change_7d': 17.87,
#   'price_btc': 2.234e-05,
#   'price_usd': 0.192878,
#   'rank': 93,
#   'symbol': 'NXT',
#   'total_supply': 998999942.0},
#  {'24h_volume_usd': 948884.0,
#   'available_supply': 28751126770.0,
#   'id': 'reddcoin',
#   'last_updated': 1518461641,
#   'market_cap_usd': 188881677.0,
#   'max_supply': None,
#   'name': 'ReddCoin',
#   'percent_change_1h': -0.38,
#   'percent_change_24h': 4.71,
#   'percent_change_7d': 23.82,
#   'price_btc': 7.6e-07,
#   'price_usd': 0.00656954,
#   'rank': 94,
#   'symbol': 'RDD',
#   'total_supply': 28751126770.0},
#  {'24h_volume_usd': 4091330.0,
#   'available_supply': 617314171.0,
#   'id': 'quantstamp',
#   'last_updated': 1518461657,
#   'market_cap_usd': 187127062.0,
#   'max_supply': None,
#   'name': 'Quantstamp',
#   'percent_change_1h': 1.92,
#   'percent_change_24h': 5.48,
#   'percent_change_7d': 52.52,
#   'price_btc': 3.51e-05,
#   'price_usd': 0.303131,
#   'rank': 95,
#   'symbol': 'QSP',
#   'total_supply': 976442388.0},
#  {'24h_volume_usd': 173152.0,
#   'available_supply': 239570250.0,
#   'id': 'polymath-network',
#   'last_updated': 1518461660,
#   'market_cap_usd': 186909115.0,
#   'max_supply': None,
#   'name': 'Polymath',
#   'percent_change_1h': -6.33,
#   'percent_change_24h': 5.8,
#   'percent_change_7d': 5.45,
#   'price_btc': 9.035e-05,
#   'price_usd': 0.780185,
#   'rank': 96,
#   'symbol': 'POLY',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 1138640.0,
#   'available_supply': 214078179083,
#   'id': 'experience-points',
#   'last_updated': 1518461647,
#   'market_cap_usd': 185053245.0,
#   'max_supply': None,
#   'name': 'Experience Points',
#   'percent_change_1h': 2.54,
#   'percent_change_24h': -0.5,
#   'percent_change_7d': 67.78,
#   'price_btc': 1e-07,
#   'price_usd': 0.000864419,
#   'rank': 97,
#   'symbol': 'XP',
#   'total_supply': 249109946949},
#  {'24h_volume_usd': 3225780.0,
#   'available_supply': 641462769.0,
#   'id': 'request-network',
#   'last_updated': 1518461655,
#   'market_cap_usd': 182648826.0,
#   'max_supply': None,
#   'name': 'Request Network',
#   'percent_change_1h': -0.93,
#   'percent_change_24h': 6.07,
#   'percent_change_7d': 32.48,
#   'price_btc': 3.297e-05,
#   'price_usd': 0.284738,
#   'rank': 98,
#   'symbol': 'REQ',
#   'total_supply': 999999999.0},
#  {'24h_volume_usd': 1371880.0,
#   'available_supply': 455552782.0,
#   'id': 'singularitynet',
#   'last_updated': 1518461659,
#   'market_cap_usd': 182139569.0,
#   'max_supply': None,
#   'name': 'SingularityNET',
#   'percent_change_1h': -0.78,
#   'percent_change_24h': 2.46,
#   'percent_change_7d': 11.06,
#   'price_btc': 4.63e-05,
#   'price_usd': 0.399821,
#   'rank': 99,
#   'symbol': 'AGI',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 1213140.0,
#   'available_supply': 41333409.0,
#   'id': 'emercoin',
#   'last_updated': 1518461643,
#   'market_cap_usd': 178178405.0,
#   'max_supply': None,
#   'name': 'Emercoin',
#   'percent_change_1h': -2.12,
#   'percent_change_24h': 14.16,
#   'percent_change_7d': 57.72,
#   'price_btc': 0.00049919,
#   'price_usd': 4.31076,
#   'rank': 100,
#   'symbol': 'EMC',
#   'total_supply': 41333409.0},
#  {'24h_volume_usd': 4733570.0,
#   'available_supply': 761143950.0,
#   'id': 'ignis',
#   'last_updated': 1518461657,
#   'market_cap_usd': 175904173.0,
#   'max_supply': 999449694.0,
#   'name': 'Ignis',
#   'percent_change_1h': -0.86,
#   'percent_change_24h': 1.83,
#   'percent_change_7d': 23.27,
#   'price_btc': 2.676e-05,
#   'price_usd': 0.231105,
#   'rank': 101,
#   'symbol': 'IGNIS',
#   'total_supply': 999449694.0},
#  {'24h_volume_usd': 3374930.0,
#   'available_supply': 12810473.0,
#   'id': 'neblio',
#   'last_updated': 1518461653,
#   'market_cap_usd': 169326273.0,
#   'max_supply': None,
#   'name': 'Neblio',
#   'percent_change_1h': 0.09,
#   'percent_change_24h': 19.68,
#   'percent_change_7d': 41.42,
#   'price_btc': 0.00153062,
#   'price_usd': 13.2178,
#   'rank': 102,
#   'symbol': 'NEBL',
#   'total_supply': 13557395.0},
#  {'24h_volume_usd': 4351810.0,
#   'available_supply': 350000000.0,
#   'id': 'chainlink',
#   'last_updated': 1518461653,
#   'market_cap_usd': 161530250.0,
#   'max_supply': None,
#   'name': 'ChainLink',
#   'percent_change_1h': 2.33,
#   'percent_change_24h': 11.57,
#   'percent_change_7d': 32.15,
#   'price_btc': 5.344e-05,
#   'price_usd': 0.461515,
#   'rank': 103,
#   'symbol': 'LINK',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 988524.0,
#   'available_supply': 55519477.0,
#   'id': 'nexus',
#   'last_updated': 1518461643,
#   'market_cap_usd': 160879344.0,
#   'max_supply': None,
#   'name': 'Nexus',
#   'percent_change_1h': -1.67,
#   'percent_change_24h': -0.65,
#   'percent_change_7d': 8.95,
#   'price_btc': 0.00033556,
#   'price_usd': 2.89771,
#   'rank': 104,
#   'symbol': 'NXS',
#   'total_supply': 55519477.0},
#  {'24h_volume_usd': 3148510.0,
#   'available_supply': 226091449.0,
#   'id': 'substratum',
#   'last_updated': 1518461654,
#   'market_cap_usd': 160800308.0,
#   'max_supply': None,
#   'name': 'Substratum',
#   'percent_change_1h': -1.63,
#   'percent_change_24h': 7.34,
#   'percent_change_7d': 44.21,
#   'price_btc': 8.236e-05,
#   'price_usd': 0.711218,
#   'rank': 105,
#   'symbol': 'SUB',
#   'total_supply': 352000000.0},
#  {'24h_volume_usd': 786784.0,
#   'available_supply': 5011748.0,
#   'id': 'blocknet',
#   'last_updated': 1518461644,
#   'market_cap_usd': 160575911.0,
#   'max_supply': None,
#   'name': 'Blocknet',
#   'percent_change_1h': -1.11,
#   'percent_change_24h': 17.84,
#   'percent_change_7d': 33.06,
#   'price_btc': 0.00371023,
#   'price_usd': 32.0399,
#   'rank': 106,
#   'symbol': 'BLOCK',
#   'total_supply': 5011748.0},
#  {'24h_volume_usd': 860724.0,
#   'available_supply': 99735687.0,
#   'id': 'iconomi',
#   'last_updated': 1518461647,
#   'market_cap_usd': 159419517.0,
#   'max_supply': None,
#   'name': 'Iconomi',
#   'percent_change_1h': -0.14,
#   'percent_change_24h': 1.34,
#   'percent_change_7d': 16.39,
#   'price_btc': 0.0001851,
#   'price_usd': 1.59842,
#   'rank': 107,
#   'symbol': 'ICN',
#   'total_supply': 99735687.0},
#  {'24h_volume_usd': 872471.0,
#   'available_supply': 1000000000.0,
#   'id': 'xplay',
#   'last_updated': 1518461653,
#   'market_cap_usd': 158599000.0,
#   'max_supply': None,
#   'name': 'XPlay',
#   'percent_change_1h': -0.65,
#   'percent_change_24h': 0.83,
#   'percent_change_7d': -10.36,
#   'price_btc': 1.837e-05,
#   'price_usd': 0.158599,
#   'rank': 108,
#   'symbol': 'XPA',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 308908.0,
#   'available_supply': 1104590.0,
#   'id': 'gnosis-gno',
#   'last_updated': 1518461649,
#   'market_cap_usd': 158516397.0,
#   'max_supply': None,
#   'name': 'Gnosis',
#   'percent_change_1h': -0.4,
#   'percent_change_24h': 3.25,
#   'percent_change_7d': 22.23,
#   'price_btc': 0.0166181,
#   'price_usd': 143.507,
#   'rank': 109,
#   'symbol': 'GNO',
#   'total_supply': 10000000.0},
#  {'24h_volume_usd': 3353000.0,
#   'available_supply': 492954537.0,
#   'id': 'wax',
#   'last_updated': 1518461658,
#   'market_cap_usd': 158502630.0,
#   'max_supply': None,
#   'name': 'WAX',
#   'percent_change_1h': -1.14,
#   'percent_change_24h': 2.29,
#   'percent_change_7d': 22.7,
#   'price_btc': 3.723e-05,
#   'price_usd': 0.321536,
#   'rank': 110,
#   'symbol': 'WAX',
#   'total_supply': 1850000000.0},
#  {'24h_volume_usd': 982248.0,
#   'available_supply': 64355352.0,
#   'id': 'gamecredits',
#   'last_updated': 1518461643,
#   'market_cap_usd': 151727396.0,
#   'max_supply': 84000000.0,
#   'name': 'GameCredits',
#   'percent_change_1h': -1.62,
#   'percent_change_24h': 5.18,
#   'percent_change_7d': 11.41,
#   'price_btc': 0.00027302,
#   'price_usd': 2.35765,
#   'rank': 111,
#   'symbol': 'GAME',
#   'total_supply': 64355352.0},
#  {'24h_volume_usd': 4511760.0,
#   'available_supply': 342699966.0,
#   'id': 'civic',
#   'last_updated': 1518461652,
#   'market_cap_usd': 148230758.0,
#   'max_supply': None,
#   'name': 'Civic',
#   'percent_change_1h': 2.15,
#   'percent_change_24h': 4.15,
#   'percent_change_7d': 43.9,
#   'price_btc': 5.009e-05,
#   'price_usd': 0.432538,
#   'rank': 112,
#   'symbol': 'CVC',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 4225880.0,
#   'available_supply': 6895600590.0,
#   'id': 'digitalnote',
#   'last_updated': 1518461643,
#   'market_cap_usd': 146570128.0,
#   'max_supply': None,
#   'name': 'DigitalNote',
#   'percent_change_1h': -0.94,
#   'percent_change_24h': 3.83,
#   'percent_change_7d': 50.97,
#   'price_btc': 2.46e-06,
#   'price_usd': 0.0212556,
#   'rank': 113,
#   'symbol': 'XDN',
#   'total_supply': 6895600590.0},
#  {'24h_volume_usd': 22514200.0,
#   'available_supply': 2216707776.0,
#   'id': 'poet',
#   'last_updated': 1518461653,
#   'market_cap_usd': 146424189.0,
#   'max_supply': None,
#   'name': 'Po.et',
#   'percent_change_1h': -2.12,
#   'percent_change_24h': 3.08,
#   'percent_change_7d': 41.9,
#   'price_btc': 7.65e-06,
#   'price_usd': 0.0660548,
#   'rank': 114,
#   'symbol': 'POE',
#   'total_supply': 3141592653.0},
#  {'24h_volume_usd': 3601570.0,
#   'available_supply': 22216600.0,
#   'id': 'high-performance-blockchain',
#   'last_updated': 1518461658,
#   'market_cap_usd': 138792432.0,
#   'max_supply': None,
#   'name': 'High Performance Blockchain',
#   'percent_change_1h': -1.17,
#   'percent_change_24h': 6.57,
#   'percent_change_7d': 10.75,
#   'price_btc': 0.00072343,
#   'price_usd': 6.24724,
#   'rank': 115,
#   'symbol': 'HPB',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 2000430.0,
#   'available_supply': 42900175.0,
#   'id': 'vertcoin',
#   'last_updated': 1518461655,
#   'market_cap_usd': 137827537.0,
#   'max_supply': 84000000.0,
#   'name': 'Vertcoin',
#   'percent_change_1h': -1.87,
#   'percent_change_24h': 3.75,
#   'percent_change_7d': 33.9,
#   'price_btc': 0.00037204,
#   'price_usd': 3.21275,
#   'rank': 116,
#   'symbol': 'VTC',
#   'total_supply': 42900175.0},
#  {'24h_volume_usd': 5522050.0,
#   'available_supply': 133425493.0,
#   'id': 'storj',
#   'last_updated': 1518461651,
#   'market_cap_usd': 137385561.0,
#   'max_supply': None,
#   'name': 'Storj',
#   'percent_change_1h': -0.29,
#   'percent_change_24h': 7.71,
#   'percent_change_7d': 30.76,
#   'price_btc': 0.00011924,
#   'price_usd': 1.02968,
#   'rank': 117,
#   'symbol': 'STORJ',
#   'total_supply': 424999998.0},
#  {'24h_volume_usd': 2695890.0,
#   'available_supply': 50148936.0,
#   'id': 'raiden-network-token',
#   'last_updated': 1518461656,
#   'market_cap_usd': 136939694.0,
#   'max_supply': None,
#   'name': 'Raiden Network Token',
#   'percent_change_1h': -0.35,
#   'percent_change_24h': 5.62,
#   'percent_change_7d': 14.85,
#   'price_btc': 0.00031621,
#   'price_usd': 2.73066,
#   'rank': 118,
#   'symbol': 'RDN',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 43662.6,
#   'available_supply': 1288862.0,
#   'id': 'bitcoindark',
#   'last_updated': 1518461642,
#   'market_cap_usd': 134344550.0,
#   'max_supply': None,
#   'name': 'BitcoinDark',
#   'percent_change_1h': 0.1,
#   'percent_change_24h': 2.94,
#   'percent_change_7d': 29.58,
#   'price_btc': 0.0120705,
#   'price_usd': 104.235,
#   'rank': 119,
#   'symbol': 'BTCD',
#   'total_supply': 1288862.0},
#  {'24h_volume_usd': 33414400.0,
#   'available_supply': 543348500.0,
#   'id': 'red-pulse',
#   'last_updated': 1518461656,
#   'market_cap_usd': 132970418.0,
#   'max_supply': None,
#   'name': 'Red Pulse',
#   'percent_change_1h': -1.79,
#   'percent_change_24h': 35.54,
#   'percent_change_7d': 131.16,
#   'price_btc': 2.834e-05,
# ...
#   'price_usd': 3.36826,
#   'rank': 960,
#   'symbol': 'FYN',
#   'total_supply': 12500000.0},
#  {'24h_volume_usd': 330.599,
#   'available_supply': 480603195.0,
#   'id': 'version',
#   'last_updated': 1518461650,
#   'market_cap_usd': 2780688.0,
#   'max_supply': None,
#   'name': 'Version',
#   'percent_change_1h': 3.6,
#   'percent_change_24h': 7.46,
#   'percent_change_7d': 18.32,
#   'price_btc': 6.7e-07,
#   'price_usd': 0.00578583,
#   'rank': 961,
#   'symbol': 'V',
#   'total_supply': 480603195.0},
#  {'24h_volume_usd': 47.6341,
#   'available_supply': 397300.0,
#   'id': 'ergo',
#   'last_updated': 1518461651,
#   'market_cap_usd': 2598123.0,
#   'max_supply': 5000000.0,
#   'name': 'Ergo',
#   'percent_change_1h': -3.05,
#   'percent_change_24h': -14.38,
#   'percent_change_7d': 3.48,
#   'price_btc': 0.00075727,
#   'price_usd': 6.53945,
#   'rank': 962,
#   'symbol': 'EFYT',
#   'total_supply': 5000000.0},
#  {'24h_volume_usd': None,
#   'available_supply': 80000000.0,
#   'id': 'gimli',
#   'last_updated': 1518253755,
#   'market_cap_usd': 2422944.0,
#   'max_supply': 150000000.0,
#   'name': 'Gimli',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': 32.18,
#   'price_btc': 3.49e-06,
#   'price_usd': 0.0302868,
#   'rank': 963,
#   'symbol': 'GIM',
#   'total_supply': 150000000.0},
#  {'24h_volume_usd': 229.944,
#   'available_supply': 1391604.0,
#   'id': 'ethbits',
#   'last_updated': 1518461650,
#   'market_cap_usd': 2357752.0,
#   'max_supply': None,
#   'name': 'Ethbits',
#   'percent_change_1h': -1.04,
#   'percent_change_24h': -11.05,
#   'percent_change_7d': -19.73,
#   'price_btc': 0.0001962,
#   'price_usd': 1.69427,
#   'rank': 964,
#   'symbol': 'ETBS',
#   'total_supply': 1634691.0},
#  {'24h_volume_usd': None,
#   'available_supply': 6566666.0,
#   'id': 'ethereum-movie-venture',
#   'last_updated': 1518140653,
#   'market_cap_usd': 2292134.0,
#   'max_supply': None,
#   'name': 'Ethereum Movie Venture',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': 19.3,
#   'price_btc': 4.396e-05,
#   'price_usd': 0.349056,
#   'rank': 965,
#   'symbol': 'EMV',
#   'total_supply': 6666666.0},
#  {'24h_volume_usd': 128.868,
#   'available_supply': 273281.0,
#   'id': 'accelerator-network',
#   'last_updated': 1518461657,
#   'market_cap_usd': 2183621.0,
#   'max_supply': None,
#   'name': 'Accelerator Network',
#   'percent_change_1h': -0.68,
#   'percent_change_24h': None,
#   'percent_change_7d': 20.2,
#   'price_btc': 0.00092529,
#   'price_usd': 7.99038,
#   'rank': 966,
#   'symbol': 'ACC',
#   'total_supply': 357644.0},
#  {'24h_volume_usd': 412.629,
#   'available_supply': 465952.0,
#   'id': 'ico-openledger',
#   'last_updated': 1518461646,
#   'market_cap_usd': 1915126.0,
#   'max_supply': None,
#   'name': 'ICO OpenLedger',
#   'percent_change_1h': -0.82,
#   'percent_change_24h': -2.86,
#   'percent_change_7d': -17.43,
#   'price_btc': 0.00047595,
#   'price_usd': 4.11014,
#   'rank': 967,
#   'symbol': 'ICOO',
#   'total_supply': 465952.0},
#  {'24h_volume_usd': 285.301,
#   'available_supply': 76925527.0,
#   'id': 'metalcoin',
#   'last_updated': 1518461644,
#   'market_cap_usd': 1813527.0,
#   'max_supply': None,
#   'name': 'MetalCoin',
#   'percent_change_1h': -1.04,
#   'percent_change_24h': 59.91,
#   'percent_change_7d': 67.09,
#   'price_btc': 2.73e-06,
#   'price_usd': 0.0235751,
#   'rank': 968,
#   'symbol': 'METAL',
#   'total_supply': 76925527.0},
#  {'24h_volume_usd': 416.011,
#   'available_supply': 297601.0,
#   'id': 'aurumcoin',
#   'last_updated': 1518461644,
#   'market_cap_usd': 1791233.0,
#   'max_supply': 300000.0,
#   'name': 'AurumCoin',
#   'percent_change_1h': -1.07,
#   'percent_change_24h': 2.68,
#   'percent_change_7d': 3.29,
#   'price_btc': 0.00069699,
#   'price_usd': 6.01891,
#   'rank': 969,
#   'symbol': 'AU',
#   'total_supply': 297601.0},
#  {'24h_volume_usd': 63.108,
#   'available_supply': 16415.0,
#   'id': 'link-platform',
#   'last_updated': 1518461651,
#   'market_cap_usd': 1686881.0,
#   'max_supply': None,
#   'name': 'Link Platform',
#   'percent_change_1h': -1.04,
#   'percent_change_24h': 65.42,
#   'percent_change_7d': 61.62,
#   'price_btc': 0.0119,
#   'price_usd': 102.763,
#   'rank': 970,
#   'symbol': 'LNK',
#   'total_supply': 34047.0},
#  {'24h_volume_usd': 107.019,
#   'available_supply': 10532142.0,
#   'id': 'kekcoin',
#   'last_updated': 1518461652,
#   'market_cap_usd': 1664405.0,
#   'max_supply': 21000000.0,
#   'name': 'KekCoin',
#   'percent_change_1h': -1.04,
#   'percent_change_24h': 7.74,
#   'percent_change_7d': 20.33,
#   'price_btc': 1.83e-05,
#   'price_usd': 0.158031,
#   'rank': 971,
#   'symbol': 'KEK',
#   'total_supply': 11532142.0},
#  {'24h_volume_usd': 209.881,
#   'available_supply': 4500000.0,
#   'id': 'starcredits',
#   'last_updated': 1518461653,
#   'market_cap_usd': 1500386.0,
#   'max_supply': 20000000.0,
#   'name': 'StarCredits',
#   'percent_change_1h': -1.04,
#   'percent_change_24h': 31.81,
#   'percent_change_7d': 37.42,
#   'price_btc': 3.861e-05,
#   'price_usd': 0.333419,
#   'rank': 972,
#   'symbol': 'STRC',
#   'total_supply': 20000000.0},
#  {'24h_volume_usd': 125.064,
#   'available_supply': 35300866.0,
#   'id': 'rustbits',
#   'last_updated': 1518461652,
#   'market_cap_usd': 1486618.0,
#   'max_supply': None,
#   'name': 'Rustbits',
#   'percent_change_1h': -2.18,
#   'percent_change_24h': None,
#   'percent_change_7d': -8.16,
#   'price_btc': 4.88e-06,
#   'price_usd': 0.0421128,
#   'rank': 973,
#   'symbol': 'RUSTBITS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': None,
#   'available_supply': 722935.0,
#   'id': 'smart-investment-fund-token',
#   'last_updated': 1518194055,
#   'market_cap_usd': 1467341.0,
#   'max_supply': 722935.0,
#   'name': 'Smart Investment Fund Token',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': -23.46,
#   'price_btc': 0.00024117,
#   'price_usd': 2.0297,
#   'rank': 974,
#   'symbol': 'SIFT',
#   'total_supply': 722935.0},
#  {'24h_volume_usd': None,
#   'available_supply': 1083638.0,
#   'id': 'rasputin-online-coin',
#   'last_updated': 1518160756,
#   'market_cap_usd': 1418721.0,
#   'max_supply': 5000000.0,
#   'name': 'Rasputin Online Coin',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': 13.17,
#   'price_btc': 0.00016259,
#   'price_usd': 1.30922,
#   'rank': 975,
#   'symbol': 'ROC',
#   'total_supply': 5000000.0},
#  {'24h_volume_usd': 352.078,
#   'available_supply': 164342925.0,
#   'id': 'hodlcoin',
#   'last_updated': 1518461645,
#   'market_cap_usd': 1405004.0,
#   'max_supply': None,
#   'name': 'HOdlcoin',
#   'percent_change_1h': -1.04,
#   'percent_change_24h': 13.22,
#   'percent_change_7d': 47.48,
#   'price_btc': 9.9e-07,
#   'price_usd': 0.00854922,
#   'rank': 976,
#   'symbol': 'HODL',
#   'total_supply': 250000000.0},
#  {'24h_volume_usd': 8.56174,
#   'available_supply': 6695133.0,
#   'id': 'shadowcash',
#   'last_updated': 1518461642,
#   'market_cap_usd': 1361576.0,
#   'max_supply': None,
#   'name': 'ShadowCash',
#   'percent_change_1h': -1.04,
#   'percent_change_24h': 4.35,
#   'percent_change_7d': -3.11,
#   'price_btc': 2.355e-05,
#   'price_usd': 0.203368,
#   'rank': 977,
#   'symbol': 'SDC',
#   'total_supply': 6695133.0},
#  {'24h_volume_usd': 331.597,
#   'available_supply': 3141900.0,
#   'id': 'orbitcoin',
#   'last_updated': 1518461641,
#   'market_cap_usd': 1347652.0,
#   'max_supply': None,
#   'name': 'Orbitcoin',
#   'percent_change_1h': -1.07,
#   'percent_change_24h': 11.2,
#   'percent_change_7d': 20.14,
#   'price_btc': 4.967e-05,
#   'price_usd': 0.428929,
#   'rank': 978,
#   'symbol': 'ORB',
#   'total_supply': 3141900.0},
#  {'24h_volume_usd': 146.651,
#   'available_supply': 10343113.0,
#   'id': 'ultimate-secure-cash',
#   'last_updated': 1518461651,
#   'market_cap_usd': 1324601.0,
#   'max_supply': 200084200.0,
#   'name': 'Ultimate Secure Cash',
#   'percent_change_1h': -1.13,
#   'percent_change_24h': None,
#   'percent_change_7d': -33.34,
#   'price_btc': 1.483e-05,
#   'price_usd': 0.128066,
#   'rank': 979,
#   'symbol': 'USC',
#   'total_supply': 38602656.0},
#  {'24h_volume_usd': None,
#   'available_supply': 7656898.0,
#   'id': 'emphy',
#   'last_updated': 1518193757,
#   'market_cap_usd': 1300930.0,
#   'max_supply': None,
#   'name': 'Emphy',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': -39.44,
#   'price_btc': 2.029e-05,
#   'price_usd': 0.169903,
#   'rank': 980,
#   'symbol': 'EPY',
#   'total_supply': 15375000.0},
#  {'24h_volume_usd': 118.833,
#   'available_supply': 10000000.0,
#   'id': 'inpay',
#   'last_updated': 1518461649,
#   'market_cap_usd': 1184800.0,
#   'max_supply': None,
#   'name': 'InPay',
#   'percent_change_1h': -1.04,
#   'percent_change_24h': None,
#   'percent_change_7d': 13.14,
#   'price_btc': 1.372e-05,
#   'price_usd': 0.11848,
#   'rank': 981,
#   'symbol': 'INPAY',
#   'total_supply': 10000000.0},
#  {'24h_volume_usd': None,
#   'available_supply': 100000000.0,
#   'id': 'shorty',
#   'last_updated': 1518421748,
#   'market_cap_usd': 1149030.0,
#   'max_supply': None,
#   'name': 'Shorty',
#   'percent_change_1h': None,
#   'percent_change_24h': 2.77,
#   'percent_change_7d': -5.47,
#   'price_btc': 1.35e-06,
#   'price_usd': 0.0114903,
#   'rank': 982,
#   'symbol': 'SHORTY',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 288.853,
#   'available_supply': 24700248.0,
#   'id': 'kobocoin',
#   'last_updated': 1518461644,
#   'market_cap_usd': 1124970.0,
#   'max_supply': None,
#   'name': 'Kobocoin',
#   'percent_change_1h': -0.15,
#   'percent_change_24h': -2.77,
#   'percent_change_7d': 15.75,
#   'price_btc': 5.27e-06,
#   'price_usd': 0.0455449,
#   'rank': 983,
#   'symbol': 'KOBO',
#   'total_supply': 24700248.0},
#  {'24h_volume_usd': None,
#   'available_supply': 900000.0,
#   'id': 'giga-watt-token',
#   'last_updated': 1518292153,
#   'market_cap_usd': 1115019.0,
#   'max_supply': None,
#   'name': 'Giga Watt Token',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': 5.93,
#   'price_btc': 0.0001472,
#   'price_usd': 1.23891,
#   'rank': 984,
#   'symbol': 'WTT',
#   'total_supply': 17300000.0},
#  {'24h_volume_usd': 229.926,
#   'available_supply': 45710709.0,
#   'id': 'ultracoin',
#   'last_updated': 1518461641,
#   'market_cap_usd': 1113161.0,
#   'max_supply': None,
#   'name': 'UltraCoin',
#   'percent_change_1h': -1.04,
#   'percent_change_24h': -1.47,
#   'percent_change_7d': 50.28,
#   'price_btc': 2.82e-06,
#   'price_usd': 0.0243523,
#   'rank': 985,
#   'symbol': 'UTC',
#   'total_supply': 45710709.0},
#  {'24h_volume_usd': 351.15,
#   'available_supply': 10291781.0,
#   'id': 'bankcoin',
#   'last_updated': 1518461649,
#   'market_cap_usd': 1095231.0,
#   'max_supply': None,
#   'name': 'Bankcoin',
#   'percent_change_1h': -0.75,
#   'percent_change_24h': -15.07,
#   'percent_change_7d': 20.93,
#   'price_btc': 1.232e-05,
#   'price_usd': 0.106418,
#   'rank': 986,
#   'symbol': 'B@',
#   'total_supply': 25000000.0},
#  {'24h_volume_usd': 487.418,
#   'available_supply': 4135615.0,
#   'id': 'eternity',
#   'last_updated': 1518461648,
#   'market_cap_usd': 1041761.0,
#   'max_supply': None,
#   'name': 'Eternity',
#   'percent_change_1h': -1.04,
#   'percent_change_24h': 3.2,
#   'percent_change_7d': 41.36,
#   'price_btc': 2.917e-05,
#   'price_usd': 0.2519,
#   'rank': 987,
#   'symbol': 'ENT',
#   'total_supply': 4135615.0},
#  {'24h_volume_usd': 381.712,
#   'available_supply': 562073.0,
#   'id': 'platinumbar',
#   'last_updated': 1518461646,
#   'market_cap_usd': 1016088.0,
#   'max_supply': None,
#   'name': 'PlatinumBAR',
#   'percent_change_1h': -5.75,
#   'percent_change_24h': 1.51,
#   'percent_change_7d': 44.45,
#   'price_btc': 0.00020934,
#   'price_usd': 1.80775,
#   'rank': 988,
#   'symbol': 'XPTX',
#   'total_supply': 562073.0},
#  {'24h_volume_usd': 424.662,
#   'available_supply': 4791315.0,
#   'id': 'netko',
#   'last_updated': 1518461649,
#   'market_cap_usd': 994447.0,
#   'max_supply': None,
#   'name': 'Netko',
#   'percent_change_1h': -1.24,
#   'percent_change_24h': -0.09,
#   'percent_change_7d': 23.26,
#   'price_btc': 2.403e-05,
#   'price_usd': 0.207552,
#   'rank': 989,
#   'symbol': 'NETKO',
#   'total_supply': 4791315.0},
#  {'24h_volume_usd': None,
#   'available_supply': 448692.0,
#   'id': 'nimfamoney',
#   'last_updated': 1518198259,
#   'market_cap_usd': 977210.0,
#   'max_supply': None,
#   'name': 'Nimfamoney',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': 11.85,
#   'price_btc': 0.00025302,
#   'price_usd': 2.17791,
#   'rank': 990,
#   'symbol': 'NIMFA',
#   'total_supply': 1542580.0},
#  {'24h_volume_usd': 396.151,
#   'available_supply': 569212340.0,
#   'id': 'trollcoin',
#   'last_updated': 1518461643,
#   'market_cap_usd': 976239.0,
#   'max_supply': None,
#   'name': 'Trollcoin',
#   'percent_change_1h': -0.68,
#   'percent_change_24h': 2.33,
#   'percent_change_7d': 24.58,
#   'price_btc': 2e-07,
#   'price_usd': 0.00171507,
#   'rank': 991,
#   'symbol': 'TROLL',
#   'total_supply': 569212340.0},
#  {'24h_volume_usd': 186.899,
#   'available_supply': 12529747.0,
#   'id': 'trackr',
#   'last_updated': 1518461653,
#   'market_cap_usd': 966799.0,
#   'max_supply': None,
#   'name': 'CryptoInsight',
#   'percent_change_1h': -0.65,
#   'percent_change_24h': 0.82,
#   'percent_change_7d': 54.17,
#   'price_btc': 8.94e-06,
#   'price_usd': 0.0771603,
#   'rank': 992,
#   'symbol': 'TKR',
#   'total_supply': 12529747.0},
#  {'24h_volume_usd': 310.81,
#   'available_supply': 75000000.0,
#   'id': 'bitpark-coin',
#   'last_updated': 1518461648,
#   'market_cap_usd': 938648.0,
#   'max_supply': None,
#   'name': 'Bitpark Coin',
#   'percent_change_1h': -0.13,
#   'percent_change_24h': 17.56,
#   'percent_change_7d': 33.26,
#   'price_btc': 1.45e-06,
#   'price_usd': 0.0125153,
#   'rank': 993,
#   'symbol': 'BPC',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 108.15,
#   'available_supply': 8035193.0,
#   'id': 'woodcoin',
#   'last_updated': 1518461644,
#   'market_cap_usd': 937442.0,
#   'max_supply': None,
#   'name': 'Woodcoin',
#   'percent_change_1h': -1.07,
#   'percent_change_24h': -12.99,
#   'percent_change_7d': 19.35,
#   'price_btc': 1.351e-05,
#   'price_usd': 0.116667,
#   'rank': 994,
#   'symbol': 'LOG',
#   'total_supply': 8035193.0},
#  {'24h_volume_usd': 397.679,
#   'available_supply': 1.0,
#   'id': 'bit20',
#   'last_updated': 1518461651,
#   'market_cap_usd': 881532.0,
#   'max_supply': None,
#   'name': 'Bit20',
#   'percent_change_1h': -0.9,
#   'percent_change_24h': 3.66,
#   'percent_change_7d': 25.67,
#   'price_btc': 100.474,
#   'price_usd': 867650.0,
#   'rank': 995,
#   'symbol': 'BTWTY',
#   'total_supply': 1.0},
#  {'24h_volume_usd': 268.072,
#   'available_supply': 64151405.0,
#   'id': 'hobonickels',
#   'last_updated': 1518461641,
#   'market_cap_usd': 869752.0,
#   'max_supply': 120000000.0,
#   'name': 'HoboNickels',
#   'percent_change_1h': -2.13,
#   'percent_change_24h': 2.96,
#   'percent_change_7d': 2.18,
#   'price_btc': 1.57e-06,
#   'price_usd': 0.0135578,
#   'rank': 996,
#   'symbol': 'HBN',
#   'total_supply': 64151405.0},
#  {'24h_volume_usd': 284.918,
#   'available_supply': 4773.0,
#   'id': 'sovereign-hero',
#   'last_updated': 1518461651,
#   'market_cap_usd': 855193.0,
#   'max_supply': None,
#   'name': 'Sovereign Hero',
#   'percent_change_1h': -0.79,
#   'percent_change_24h': -3.68,
#   'percent_change_7d': 4.4,
#   'price_btc': 0.0207482,
#   'price_usd': 179.173,
#   'rank': 997,
#   'symbol': 'HERO',
#   'total_supply': 4773.0},
#  {'24h_volume_usd': 441.14,
#   'available_supply': 15145369.0,
#   'id': 'opal',
#   'last_updated': 1518461643,
#   'market_cap_usd': 812467.0,
#   'max_supply': None,
#   'name': 'Opal',
#   'percent_change_1h': -2.39,
#   'percent_change_24h': 0.88,
#   'percent_change_7d': 21.87,
#   'price_btc': 6.21e-06,
#   'price_usd': 0.0536446,
#   'rank': 998,
#   'symbol': 'OPAL',
#   'total_supply': 15145369.0},
#  {'24h_volume_usd': 127.516,
#   'available_supply': 61445805.0,
#   'id': 'maxcoin',
#   'last_updated': 1518461641,
#   'market_cap_usd': 811847.0,
#   'max_supply': None,
#   'name': 'MaxCoin',
#   'percent_change_1h': 4.42,
#   'percent_change_24h': 11.37,
#   'percent_change_7d': 35.43,
#   'price_btc': 1.53e-06,
#   'price_usd': 0.0132124,
#   'rank': 999,
#   'symbol': 'MAX',
#   'total_supply': 61445805.0},
#  {'24h_volume_usd': 211.55,
#   'available_supply': 50201886.0,
#   'id': 'amsterdamcoin',
#   'last_updated': 1518461645,
#   'market_cap_usd': 767426.0,
#   'max_supply': None,
#   'name': 'AmsterdamCoin',
#   'percent_change_1h': -1.13,
#   'percent_change_24h': 8.81,
#   'percent_change_7d': 50.2,
#   'price_btc': 1.77e-06,
#   'price_usd': 0.0152868,
#   'rank': 1000,
#   'symbol': 'AMS',
#   'total_supply': 81469427.0},
#  ...]

# %% [markdown]
# You can pass a currency through symbol or coin slug:

# %%
data_from_symbol = cmc.ticker("BTC")
data_from_slug = cmc.ticker("bitcoin")

data_from_slug
# Out:
# {'24h_volume_usd': 5811790000.0,
#  'available_supply': 16860625.0,
#  'id': 'bitcoin',
#  'last_updated': 1518461667,
#  'market_cap_usd': 146630111375,
#  'max_supply': 21000000.0,
#  'name': 'Bitcoin',
#  'percent_change_1h': -0.72,
#  'percent_change_24h': 4.4,
#  'percent_change_7d': 19.8,
#  'price_btc': 1.0,
#  'price_usd': 8696.6,
#  'rank': 1,
#  'symbol': 'BTC',
#  'total_supply': 16860625.0}

# %% [markdown]
# To get all symbols and slugs you can use the next attributes:

# %%
all_symbols = cmc.symbols
all_slugs = cmc.coins

all_symbols
# Out:
# ['CANDY',
#  'PYLNT',
#  'DSR',
#  'NEU',
#  'GUP',
#  'POLIS',
#  'DOT',
#  'LEND',
#  'FJC',
#  'HMQ',
#  'PHS',
#  'GRC',
#  'SMART',
#  'INN',
#  'TCC',
#  'ZENI',
#  'DGPT',
#  'APPC',
#  'PRN',
#  'BTC2X',
#  'MLM',
#  'FYN',
#  'HYP',
#  'CF',
#  'MAX',
#  'NETKO',
#  'HUC',
#  'BCX',
#  'MYST',
#  'CAT',
#  'KEY',
#  'GAS',
#  'LGD',
#  'SRC',
#  'AEON',
#  'CMP',
#  'MMXVI',
#  'XPY',
#  'ZIL',
#  'PAK',
#  'HDG',
#  'QRL',
#  'KRM',
#  'DRT',
#  'AST',
#  'ORME',
#  'PLC',
#  'Q2C',
#  'FUZZ',
#  'DALC',
#  'BTB',
#  'NLG',
#  'SPR',
#  'MAGE',
#  'UNITY',
#  'TOKC',
#  'WORM',
#  '1ST',
#  'CCN',
#  'DTR',
#  'CFT',
#  'PZM',
#  'BTA',
#  'GCR',
#  'RC',
#  'IMPS',
#  'QASH',
#  'FRD',
#  'ZCL',
#  'NMS',
#  'SBC',
#  'DENT',
#  'BPT',
#  'LTCR',
#  'PLAY',
#  'VOX',
#  'BIGUP',
#  'MOBI',
#  'PFR',
#  'XCPO',
#  'STORJ',
#  'SWP',
#  'HVN',
#  'NSR',
#  'ERC20',
#  'ION',
#  'MAN',
#  'AI',
#  'KICK',
#  'BCO',
#  'ALL',
#  'WIC',
#  'LIR',
#  'IVZ',
#  'LCP',
#  'SNOV',
#  'XST',
#  'CLOAK',
#  'CXO',
#  'LEAF',
#  'FLIK',
#  'BTX',
#  'DBET',
#  'SHOW',
#  'ZEIT',
#  'GOLF',
#  'TIT',
#  'UGT',
#  'ELLA',
#  'DRPU',
#  'IDT',
#  'SDP',
#  'ZENGOLD',
#  'DEUS',
#  'ARC',
#  'EXN',
#  'CAB',
#  'TKR',
#  'EMC',
#  'CV2',
#  'NEWB',
#  'ADCN',
#  'PTC',
#  'ATB',
#  'BNX',
#  'CRW',
#  'TAJ',
#  'XNG',
#  'HYTV',
#  'ABJ',
#  'FUN',
#  'EQL',
#  'BLX',
#  'ZSE',
#  'PRM',
#  'FRWC',
#  'JNT',
#  'LBTC',
#  'MOD',
#  'RBX',
#  'PONZI',
#  'ECO',
#  'UIP',
#  'BUZZ',
#  'CLAM',
#  'HSR',
#  'BDL',
#  'CDX',
#  'PEPECASH',
#  'CHC',
#  'DRP',
#  'TNB',
#  'VIBE',
#  'REQ',
#  'FLO',
#  'QUN',
#  'OCN',
#  'CLUB',
#  'VLC',
#  'DLISK',
#  'DFT',
#  'SIB',
#  'REF',
#  '42',
#  'SEND',
#  'MSD',
#  'POKE',
#  'ASTRO',
#  'KNC',
#  'XPM',
#  'LSK',
#  'NXC',
#  'EREAL',
#  'OST',
#  'NAV',
#  'WINGS',
#  'BOS',
#  'ADK',
#  'ZRX',
#  'SLT',
#  'UET',
#  'DGCS',
#  'GAME',
#  'ERY',
#  'PRA',
#  'INFX',
#  'BIG',
#  'ONG',
#  'IPC',
#  'EPC',
#  'ECOB',
#  'OMG',
#  'SHIFT',
#  'HAT',
#  'JS',
#  'LOG',
#  'IDH',
#  'BTCZ',
#  'EAG',
#  'BTPL',
#  'EUSD',
#  'BUB',
#  'LEV',
#  'MOF',
#  'MXT',
#  'TRST',
#  'DNT',
#  'CYDER',
#  'SHORTY',
#  'VLT',
#  'TRIG',
#  'ELTC2',
#  'XSPEC',
#  'XFT',
#  'MER',
#  'FRST',
#  'BCDN',
#  'BITEUR',
#  'CYP',
#  'KEK',
#  'ICX',
#  'ISL',
#  'BT2',
#  'VEN',
#  'LDOGE',
#  'HALLO',
#  'ATL',
#  '2GIVE',
#  'BAR',
#  'MOT',
#  'IBANK',
#  'SPHR',
#  'BASH',
#  'SIGMA',
#  'FRCT',
#  'SOIL',
#  'DOGE',
#  'P7C',
#  'PPC',
#  'SGR',
#  'SKULL',
#  'FIRE',
#  'TRUE',
#  'STRC',
#  'FLIXX',
#  'IXC',
#  'BTCA',
#  'BCY',
#  'UTK',
#  'ZMC',
#  'PRL',
#  'NYC',
#  'GJC',
#  'GXS',
#  'BKX',
#  'TCT',
#  'VIP',
#  'ELITE',
#  'GRN',
#  'RED',
#  'LBC',
#  'MCI',
#  'MCRN',
#  'EBTC',
#  'PCOIN',
#  'TEAM',
#  'SUPER',
#  'SXC',
#  'FC',
#  'BMC',
#  'CESC',
#  'FLY',
#  'SHND',
#  'HVCO',
#  'GMT',
#  'CTIC2',
#  'CFI',
#  'READ',
#  'TAG',
#  'SEQ',
#  'CRX',
#  'SLEVIN',
#  'OX',
#  'DYN',
#  'NET',
#  'MAID',
#  'ARCO',
#  'FYP',
#  'XCO',
#  'GCN',
#  'KB3',
#  'BTE',
#  'AIT',
#  'FAIR',
#  'PBL',
#  'BUMBA',
#  'R',
#  'SAN',
#  'DIBC',
#  'MAY',
#  'CNNC',
#  'AVT',
#  'USDT',
#  'EPY',
#  'TRX',
#  'DIX',
#  'TEK',
#  'VOT',
#  'FLT',
#  'LOCI',
#  'SCS',
#  'STA',
#  'XRA',
#  'ARN',
#  'FAZZ',
#  'ART',
#  'PST',
#  'SAC',
#  'GMX',
#  'ARCT',
#  'YOYOW',
#  'GAY',
#  'EMV',
#  'LCT',
#  'EGG',
#  'BLAS',
#  'SNRG',
#  'HPY',
#  'ALTC',
#  'KIN',
#  'XCXT',
#  'PR',
#  'LUNA',
#  'SOAR',
#  'VZT',
#  'EOS',
#  'GVT',
#  'BXC',
#  'MCAP',
#  'CURE',
#  'MCO',
#  'SPACE',
#  'SALT',
#  'LTC',
#  'BOLI',
#  'GLD',
#  'CRDNC',
#  'CCRB',
#  'CHESS',
#  'SPHTX',
#  'APX',
#  'ZRC',
#  'RIC',
#  'BENJI',
#  'FST',
#  'LDCN',
#  'BON',
#  'QRK',
#  'EDRC',
#  'PROC',
#  'XBC',
#  'IXT',
#  'XRB',
#  'GAP',
#  'ENRG',
#  'TEL',
#  'MTNC',
#  'COXST',
#  'SPANK',
#  'ZAP',
#  'LEA',
#  'ZYD',
#  'YEL',
#  'MINT',
#  'DNR',
#  'KUSH',
#  'CALC',
#  'ITC',
#  'UNITS',
#  'SUR',
#  'VLTC',
#  'SWM',
#  'CVCOIN',
#  'PXI',
#  'WOW',
#  'SWFTC',
#  'BIOB',
#  'DIME',
#  'BLN',
#  'HTML',
#  'RUP',
#  'ADZ',
#  'EVX',
#  'WBB',
#  'CSC',
#  'DDD',
#  'TRUMP',
#  'XGR',
#  'FRK',
#  'MIOTA',
#  'XMG',
#  'RIDE',
#  'ATS',
#  'LTG',
#  'KDC',
#  'XBTS',
#  'MEE',
#  'AIDOC',
#  'CCT',
#  'RPX',
#  'REE',
#  'COAL',
#  'RPC',
#  'CPN',
#  'DOVU',
#  'QWARK',
#  'WISH',
#  'I0C',
#  'RDN',
#  'XTD',
#  'QAU',
#  'HPC',
#  'TOA',
#  'CFUN',
#  'NULS',
#  'HAC',
#  'BCC',
#  'CRPT',
#  'DP',
#  'AUR',
#  'TRCT',
#  'RUPX',
#  'ETN',
#  'BBR',
#  'MARX',
#  'UFR',
#  'PHR',
#  'SBTC',
#  'SHA',
#  'YAC',
#  'MGO',
#  'VPRC',
#  'FDX',
#  'BAY',
#  'WARP',
#  'CHAT',
#  'MDT',
#  'SONG',
#  'REBL',
#  'RBBT',
#  'LRC',
#  'GB',
#  'THC',
#  '808',
#  'GTO',
#  'RAIN',
#  'ZNY',
#  'DIM',
#  'EDR',
#  'MEME',
#  'ZPT',
#  'MST',
#  'MONETA',
#  'RBY',
#  'LTB',
#  'BRIA',
#  'OK',
#  'XVG',
#  'ELIX',
#  'KCS',
#  'CRM',
#  'AION',
#  'ACT',
#  'BNTY',
#  'REGA',
#  'CRB',
#  'BUN',
#  'RSGP',
#  'DRGN',
#  'WAY',
#  'WGO',
#  'SKR',
#  'VIVO',
#  'XMCC',
#  'SNC',
#  'WC',
#  'PKT',
#  'AIB',
#  'NLC2',
#  'BTG',
#  'QBC',
#  'ALQO',
#  'BBP',
#  'TOPAZ',
#  'YTN',
#  'BITB',
#  'RADS',
#  'TAAS',
#  'ETC',
#  'CME',
#  'INCNT',
#  'SCT',
#  'PAC',
#  'SWTC',
#  'GSR',
#  'THETA',
#  'CMS',
#  'PIRL',
#  'OC',
#  'LINX',
#  'CYC',
#  'IMX',
#  'ARDR',
#  'ZNE',
#  'RHOC',
#  'ANT',
#  'XAS',
#  'HTML5',
#  'BTW',
#  'CHAN',
#  'WOMEN',
#  'AKY',
#  'BTCRED',
#  'XVP',
#  'HNC',
#  'SAK',
#  'TERA',
#  'XLM',
#  'OP',
#  'CHIPS',
#  'QBT',
#  'DAI',
#  'MONA',
#  'ODN',
#  'RMC',
#  'PND',
#  'DUTCH',
#  'PAYP',
#  'DCY',
#  'GLC',
#  'FLDC',
#  'BAC',
#  'OXY',
#  'V',
#  'SXUT',
#  'UQC',
#  'SOON',
#  'ETBS',
#  'POP',
#  'ERC',
#  'ICOS',
#  'MANNA',
#  'HOT',
#  'ETP',
#  'ZET',
#  'NMR',
#  'ECN',
#  'CCO',
#  'CHSB',
#  'EGO',
#  'GRE',
#  'AWR',
#  'TIME',
#  'POE',
#  'XRE',
#  'PURE',
#  'NGC',
#  'BTM',
#  'URO',
#  'XBL',
#  'VULC',
#  'GRID',
#  'NTO',
#  'DOLLAR',
#  'WHL',
#  'PCS',
#  'ENT',
#  'SJCX',
#  'OCT',
#  'AU',
#  'ENG',
#  'BITCNY',
#  'NEO',
#  'STAK',
#  'AGLC',
#  'DASHS',
#  'BSR',
#  'XLC',
#  'TRAC',
#  'EUC',
#  'ETHD',
#  'ALTCOM',
#  'HXX',
#  'GCC',
#  'IRL',
#  'VIDZ',
#  'SNAKE',
#  'ALIS',
#  'NAS',
#  'GLS',
#  'MAD',
#  'ORB',
#  'IOST',
#  'OMNI',
#  'DGB',
#  'ABC',
#  'SNGLS',
#  'URC',
#  'STEEM',
#  'MKR',
#  'CC',
#  'HGT',
#  'ATOM',
#  'RUSTBITS',
#  'RLC',
#  'DCT',
#  'MOJO',
#  'CNO',
#  'XIOS',
#  'QTL',
#  'PIZZA',
#  'XQN',
#  'CWXT',
#  'VC',
#  'MED',
#  'TRIA',
#  'CBX',
#  'AXP',
#  'IETH',
#  'ELA',
#  'PINK',
#  'IDXM',
#  'AMP',
#  'MTL',
#  'LOC',
#  'BIOS',
#  'MEC',
#  'DOPE',
#  'BCH',
#  'LINDA',
#  'VIU',
#  'AC',
#  'PRX',
#  'MAO',
#  'PRE',
#  'EBET',
#  'AAC',
#  'MTH',
#  'VASH',
#  'GAIA',
#  'B2X',
#  'POSW',
#  'GNT',
#  'ATN',
#  'MOTO',
#  'SOC',
#  'CCM100',
#  'INK',
#  'NVC',
#  'GOD',
#  'FLAP',
#  'MUE',
#  'EFYT',
#  'XTZ',
#  'SPEX',
#  'ABY',
#  'PIX',
#  'MBL',
#  'RNS',
#  'BOST',
#  'SYNX',
#  'TAGR',
#  'XVC',
#  'CRT',
#  'XDE2',
#  'DAR',
#  'OTN',
#  'ETHOS',
#  'PX',
#  'IOC',
#  'LLT',
#  'AMM',
#  'SAFEX',
#  'MDS',
#  'NOX',
#  'IGNIS',
#  'MINEX',
#  'TRI',
#  'MGC',
#  'MAR',
#  'BTO',
#  'GARY',
#  'CON',
#  'DLC',
#  'QLC',
#  'AIR',
#  'NKA',
#  'FLAX',
#  'GOOD',
#  'LEO',
#  'TRICK',
#  'WSX',
#  'IBTC',
#  'TIO',
#  'PHO',
#  'SYS',
#  'COV',
#  'POWR',
#  'ECASH',
#  'ICE',
#  'XBTC21',
#  'IPY',
#  'ANTI',
#  'RUBIT',
#  'EKO',
#  'SANDG',
#  'SUB',
#  'RDD',
#  'WTT',
#  'SOJ',
#  'VOISE',
#  'XAUR',
#  'PSY',
#  'ATMS',
#  'UIS',
#  'TALK',
#  'XVE',
#  'PULSE',
#  'UNC',
#  'CASH',
#  'DATA',
#  'STX',
#  'XSH',
#  'XMY',
#  'BOT',
#  'MTN',
#  'NUMUS',
#  'ROOFS',
#  'BIT',
#  'DIVX',
#  'DRXNE',
#  'STK',
#  'FIMK',
#  'PTOY',
#  'VTA',
#  'BLRY',
#  'ESP',
#  'ANC',
#  'NUKO',
#  'ERO',
#  'AHT',
#  'EDO',
#  'GNO',
#  'VOYA',
#  'MSP',
#  'ENJ',
#  'ADT',
#  'XLR',
#  'LA',
#  'BTBc',
#  'XCS',
#  'FAP',
#  'DLT',
#  'MAGN',
#  'JNS',
#  'ELC',
#  'BLT',
#  'CTX',
#  'KCASH',
#  'ECC',
#  'DBG',
#  'VUC',
#  'DRS',
#  'GRLC',
#  'NDC',
#  'MDA',
#  'BIS',
#  'RBT',
#  'MGM',
#  'XJO',
#  'BTSR',
#  'SHDW',
#  'ITT',
#  'ACC',
#  'CMPCO',
#  'KRONE',
#  'STRAT',
#  'MARS',
#  'SSS',
#  'ASN',
#  'GAT',
#  'OPT',
#  'HMP',
#  'EXRN',
#  'USNBT',
#  'AID',
#  'SBD',
#  'PLACO',
#  'SIGT',
#  'SMT',
#  'TFL',
#  'TER',
#  'BITOK',
#  'PRO',
#  'DES',
#  'TOR',
#  'PRIMU',
#  'GAIN',
#  'ADC',
#  'BERN',
#  'OCL',
#  'SOCC',
#  'CONX',
#  'TKS',
#  'PASL',
#  'REAL',
#  'UTT',
#  'PURA',
#  'SCRT',
#  'XPTX',
#  'REC',
#  'CTIC3',
#  'DMB',
#  'KOBO',
#  'EDT',
#  'ARY',
#  'GUN',
#  'NMC',
#  'EGAS',
#  'MEN',
#  'DAT',
#  'BLAZR',
#  'CNX',
#  'EFL',
#  'FOR',
#  'RBIES',
#  'TGT',
#  'ZEC',
#  'SCL',
#  'XUC',
#  'GRS',
#  'IOP',
#  'BITZ',
#  'PLR',
#  'POST',
#  'BCPT',
#  'BEST',
#  'SWING',
#  'UFO',
#  'ESZ',
#  'CVC',
#  'VERI',
#  'MYB',
#  'CMT',
#  'SIC',
#  'CPAY',
#  'KZC',
#  'BLITZ',
#  'FRGC',
#  'XCN',
#  'KASHH',
#  'PDC',
#  'WRC',
#  'KORE',
#  'C20',
#  'MILO',
#  'PKB',
#  'BIRDS',
#  'TCOIN',
#  'NTRN',
#  'LUX',
#  'HPB',
#  'EQT',
#  'ZLA',
#  'RNT',
#  'AXIOM',
#  'NEOS',
#  'BNT',
#  'ATMC',
#  'EL',
#  'AGRS',
#  'TKN',
#  'BTCR',
#  'EVC',
#  'DDF',
#  'HLC',
#  'BRK',
#  'SKY',
#  'FONZ',
#  'FBL',
#  'NANOX',
#  'WABI',
#  'X2',
#  'TOK',
#  'JIN',
#  'BPC',
#  'TGC',
#  'CFD',
#  'POLL',
#  'TAU',
#  'SIFT',
#  'XOC',
#  'XBY',
#  'BNB',
#  'FXE',
#  'UNY',
#  'DAV',
#  'J',
#  'XCRE',
#  'GRIM',
#  'UTC',
#  'PPP',
#  'DTB',
#  'BLUE',
#  'HONEY',
#  'BXT',
#  'SUMO',
#  'XRY',
#  'EBIT',
#  'BITCF',
#  'EOT',
#  'OPAL',
#  'HIGH',
#  'BITGOLD',
#  'ZUR',
#  'OBITS',
#  'FUEL',
#  'ZBC',
#  'JINN',
#  'MAC',
#  'THS',
#  'ORLY',
#  'DCN',
#  'PRIX',
#  'HCC',
#  'PIPL',
#  'VTR',
#  'HAL',
#  'EGC',
#  'COLX',
#  'COB',
#  'XSTC',
#  'BUCKS',
#  'MNX',
#  'HUSH',
#  'DCRE',
#  'SH',
#  'DON',
#  'SPORT',
#  'ANTX',
#  'COR',
#  'POT',
#  'MOON',
#  'C2',
#  'TOP',
#  'KURT',
#  'CACH',
#  'NBIT',
#  'CRED',
#  '$$$',
#  'UNIT',
#  'FTC',
#  'ETT',
#  'QCN',
#  'ESC',
#  'FRN',
#  'REX',
#  'GOLOS',
#  'UNO',
#  'PRG',
#  'GEERT',
#  'WDC',
#  'ONX',
#  'BIP',
#  'ACP',
#  'DAXX',
#  'BITS',
#  'BAT',
#  'SPT',
#  'EKT',
#  'KARMA',
#  'PASC',
#  'MTX',
#  'SSC',
#  'HORSE',
#  'MUSIC',
#  'NIO',
#  'AMS',
#  'LTCU',
#  'JOBS',
#  'GPU',
#  'CRC',
#  'MCR',
#  'SDC',
#  'DPY',
#  'KLC',
#  'GRWI',
#  'YES',
#  'OTX',
#  'OAX',
#  ...]

# %% [markdown]
# Other parameters:

# %%
print(cmc.ticker.__doc__)
# Out:
# Get currencies with other aditional data.
#
#         Args:
#             currency (str, optional): Specify a currency to return,
#                 in this case the method returns a dict, otherwise
#                 returns a list. If you dont specify a currency,
#                 returns data for all in coinmarketcap. As default, None.
#             limit (int, optional): Limit amount of coins on response.
#                 if limit == 0, returns all coins in coinmarketcap.
#                 Only works if currency == None. As default 0.
#             start (int, optional): Rank of first currency to retrieve.
#                 The count starts at 0 for the first currency ranked.
#                 Only works if currency == None. As default 0.
#             convert (str, optional): As default, "USD". Allow to
#                 convert price, 24h volume and market cap in terms
#                 of one of next badges:
#                    ["AUD", "BRL", "CAD", "CHF", "CLP", "CNY", "CZK", "DKK",
#                     "EUR", "GBP", "HKD", "HUF", "IDR", "ILS", "INR", "JPY",
#                     "KRW", "MXN", "MYR", "NOK", "NZD", "PHP", "PKR", "PLN",
#                     "RUB", "SEK", "SGD", "THB", "TRY", "TWD", "ZAR"]
#
#         Returns:
#             dict/list: If currency param is provided or not.

# %% [markdown]
# If you want to get the valid badges that can be passed to `convert` param programatically, use this:

# %%
cmc.ticker_badges
# Out:
# ['AUD',
#  'BRL',
#  'CAD',
#  'CHF',
#  'CLP',
#  'CNY',
#  'CZK',
#  'DKK',
#  'EUR',
#  'GBP',
#  'HKD',
#  'HUF',
#  'IDR',
#  'ILS',
#  'INR',
#  'JPY',
#  'KRW',
#  'MXN',
#  'MYR',
#  'NOK',
#  'NZD',
#  'PHP',
#  'PKR',
#  'PLN',
#  'RUB',
#  'SEK',
#  'SGD',
#  'THB',
#  'TRY',
#  'TWD',
#  'ZAR']

# %% [markdown]
# #### `stats([convert="USD"])`
# Get global criptocurrency statistics. The `convert` parameter works just like in previous method.

# %%
cmc.stats()
# Out:
# {'active_assets': 598,
#  'active_currencies': 896,
#  'active_markets': 8686,
#  'bitcoin_percentage_of_market_cap': 34.6,
#  'last_updated': 1518461667,
#  'total_24h_volume_usd': 17330961898.0,
#  'total_market_cap_usd': 423804242353.0}

# %% [markdown]
# _____________________________________________
#
# ## Web scraper

# %% [markdown]
# #### `currency(name, [convert="USD"])`
# Get metadata from a currency passed as first argument.

# %%
cmc.currency("BTC")

# %% [markdown]
# #### `markets(name, [convert="USD"])`
# Get all markets for a exchange in coinmarketcap. Pass a currency symbol or slug as first parameter. You can convert the response fields `"volume_24h"` and `"price"` between `"USD"` and `"BTC"` with `convert` parameter.

# %%
cmc.markets("BTC", convert="BTC")
# Out:
# [{'pair': 'BTC/USDT',
#   'percent_volume': 7.45572362387,
#   'price': 1.00124,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 50177.4},
#  {'pair': 'BTC/USD',
#   'percent_volume': 7.04609079131,
#   'price': 1.00484,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 47420.6},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 5.75855287269,
#   'price': 1.00322,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 38755.4},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 3.31095927417,
#   'price': 1.00648,
#   'source': 'bitFlyer',
#   'updated': True,
#   'volume_24h': 22283.0},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 3.27224486776,
#   'price': 1.00387,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 22022.4},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 2.64612107457,
#   'price': 1.00416,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 17808.5},
#  {'pair': 'BTC/USD',
#   'percent_volume': 2.55224294064,
#   'price': 1.00283,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 17176.8},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 2.1899105095,
#   'price': 1.05398,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 14738.2},
#  {'pair': 'BTC/USD',
#   'percent_volume': 2.04384535573,
#   'price': 1.00338,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 13755.2},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 1.72184473286,
#   'price': 1.05195,
#   'source': 'Bithumb',
#   'updated': True,
#   'volume_24h': 11588.1},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 1.69220670396,
#   'price': 1.00278,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 11388.6},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 1.56799540245,
#   'price': 1.004,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 10552.7},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 1.55984128814,
#   'price': 0.998602,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 10497.8},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 1.5246490324,
#   'price': 0.999988,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 10261.0},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 1.41704707156,
#   'price': 1.00892,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 9536.8},
#  {'pair': 'BTC/USD',
#   'percent_volume': 1.2490196652,
#   'price': 0.986617,
#   'source': 'BTCC',
#   'updated': True,
#   'volume_24h': 8405.97},
#  {'pair': 'BTC/USD',
#   'percent_volume': 1.11668177962,
#   'price': 1.00369,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 7515.33},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.972158319554,
#   'price': 1.00248,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 6542.69},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.968827159963,
#   'price': 1.01001,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 6520.26},
#  {'pair': 'GTO/BTC',
#   'percent_volume': 0.900054888425,
#   'price': 1.0051,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 6057.42},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.880243436187,
#   'price': 1.005,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 5924.09},
#  {'pair': 'ICX/BTC',
#   'percent_volume': 0.816898064108,
#   'price': 1.00031,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 5497.77},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.765444037035,
#   'price': 1.01023,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 5151.49},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.751004423766,
#   'price': 0.999558,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 5054.31},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.699435113795,
#   'price': 1.00283,
#   'source': 'Gemini',
#   'updated': True,
#   'volume_24h': 4707.24},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.606210823172,
#   'price': 1.00007,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 4079.83},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.599075327911,
#   'price': 1.00368,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 4031.81},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.584281262743,
#   'price': 1.00403,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 3932.24},
#  {'pair': 'ELA/BTC',
#   'percent_volume': 0.568683658563,
#   'price': 0.998961,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 3827.28},
#  {'pair': 'HT/BTC',
#   'percent_volume': 0.542048146956,
#   'price': 1.00271,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 3648.02},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.524470085808,
#   'price': 1.00288,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 3529.71},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.523191650077,
#   'price': 0.999292,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 3521.11},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.49057175156,
#   'price': 0.997648,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 3301.58},
#  {'pair': 'WICC/BTC',
#   'percent_volume': 0.470681149869,
#   'price': 1.00115,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 3167.71},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.449796018094,
#   'price': 0.998257,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 3027.15},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.448777399046,
#   'price': 1.00273,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 3020.3},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.427861295745,
#   'price': 1.00284,
#   'source': 'itBit',
#   'updated': True,
#   'volume_24h': 2879.53},
#  {'pair': 'NANO/BTC',
#   'percent_volume': 0.411429181027,
#   'price': 1.00148,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 2768.94},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.408442149493,
#   'price': 0.996075,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 2748.84},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.407115535833,
#   'price': 1.00596,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 2739.91},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.394532493431,
#   'price': 0.995761,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 2655.22},
#  {'pair': 'BNB/BTC',
#   'percent_volume': 0.393593023836,
#   'price': 0.999917,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 2648.91},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.36387756612,
#   'price': 1.00831,
#   'source': 'Liqui',
#   'updated': True,
#   'volume_24h': 2448.91},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.340416635839,
#   'price': 1.07344,
#   'source': 'LakeBTC',
#   'updated': True,
#   'volume_24h': 2291.03},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.33981957366,
#   'price': 1.00184,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 2287.0},
#  {'pair': 'ELF/BTC',
#   'percent_volume': 0.333047133499,
#   'price': 1.00124,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 2241.42},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.332651386234,
#   'price': 1.00432,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 2238.76},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.317360056024,
#   'price': 1.00384,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 2135.85},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.315916438825,
#   'price': 1.06567,
#   'source': 'ZB.COM',
#   'updated': True,
#   'volume_24h': 2126.13},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.314906422978,
#   'price': 1.00426,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 2119.34},
#  {'pair': 'EKT/BTC',
#   'percent_volume': 0.305916077491,
#   'price': 0.991824,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 2058.83},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.304501711177,
#   'price': 1.00296,
#   'source': 'CoinsBank',
#   'updated': True,
#   'volume_24h': 2049.31},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.303510622373,
#   'price': 1.01216,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 2042.64},
#  {'pair': 'POE/BTC',
#   'percent_volume': 0.302331983778,
#   'price': 1.00476,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 2034.71},
#  {'pair': 'RPX/BTC',
#   'percent_volume': 0.297278463262,
#   'price': 1.00042,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 2000.7},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.296390612875,
#   'price': 1.01277,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1994.73},
#  {'pair': 'NBT/BTC',
#   'percent_volume': 0.294332727094,
#   'price': 1.00174,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1980.87},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.293666839304,
#   'price': 1.01484,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 1976.4},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.287851075142,
#   'price': 1.00974,
#   'source': 'CoinsBank',
#   'updated': True,
#   'volume_24h': 1937.26},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.282628931878,
#   'price': 1.01648,
#   'source': 'CEX.IO',
#   'updated': True,
#   'volume_24h': 1902.11},
#  {'pair': 'RISE/BTC',
#   'percent_volume': 0.0,
#   'price': 1.90029,
#   'source': 'Upbit',
#   'updated': False,
#   'volume_24h': 2017.95},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.277336242363,
#   'price': 1.00091,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1866.48},
#  {'pair': 'ADA/BTC',
#   'percent_volume': 0.274639999036,
#   'price': 1.04511,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1848.34},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.272583833896,
#   'price': 0.998797,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1834.5},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.270818456964,
#   'price': 1.00025,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 1822.62},
#  {'pair': 'PPT/BTC',
#   'percent_volume': 0.270572405403,
#   'price': 0.997675,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1820.97},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.269261277507,
#   'price': 1.05355,
#   'source': 'Coinone',
#   'updated': True,
#   'volume_24h': 1812.14},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.267475252891,
#   'price': 0.998842,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 1800.12},
#  {'pair': 'ADA/BTC',
#   'percent_volume': 0.265123137622,
#   'price': 1.04511,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1784.3},
#  {'pair': 'BLZ/BTC',
#   'percent_volume': 0.25791537547,
#   'price': 1.01204,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1735.79},
#  {'pair': 'VEN/BTC',
#   'percent_volume': 0.256762546479,
#   'price': 1.0034,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1728.02},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.25211337643,
#   'price': 1.00158,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 1696.74},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.24050765771,
#   'price': 1.01604,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1618.62},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.238487626015,
#   'price': 0.999741,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 1605.03},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.232381073645,
#   'price': 0.999982,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1563.94},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.23120071441,
#   'price': 1.01294,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 1556.0},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.227971072596,
#   'price': 1.00309,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 1534.26},
#  {'pair': 'BTC/GBP',
#   'percent_volume': 0.224743151422,
#   'price': 1.00071,
#   'source': 'CoinsBank',
#   'updated': True,
#   'volume_24h': 1512.54},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.217242880421,
#   'price': 1.00243,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 1462.06},
#  {'pair': 'WAVES/BTC',
#   'percent_volume': 0.208245652372,
#   'price': 1.02549,
#   'source': 'Tidex',
#   'updated': True,
#   'volume_24h': 1401.51},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.204627145854,
#   'price': 1.00485,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1377.15},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.200950137565,
#   'price': 1.00841,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 1352.41},
#  {'pair': 'AIDOC/BTC',
#   'percent_volume': 0.200667952559,
#   'price': 1.00273,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1350.5},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.198164420944,
#   'price': 1.05366,
#   'source': 'Korbit',
#   'updated': True,
#   'volume_24h': 1333.66},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.196572828681,
#   'price': 0.925268,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 1322.94},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.195562812834,
#   'price': 1.00623,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1316.15},
#  {'pair': 'BTC/BITCNY',
#   'percent_volume': 0.194248243656,
#   'price': 1.00578,
#   'source': 'AEX',
#   'updated': True,
#   'volume_24h': 1307.3},
#  {'pair': 'EPC/BTC',
#   'percent_volume': 0.192766772371,
#   'price': 0.988186,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 1297.33},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.191182062669,
#   'price': 1.02471,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 1286.66},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.189279034514,
#   'price': 1.00831,
#   'source': 'Coinbene',
#   'updated': True,
#   'volume_24h': 1273.85},
#  {'pair': 'RISE/BTC',
#   'percent_volume': 0.0,
#   'price': 1.92429,
#   'source': 'Bittrex',
#   'updated': False,
#   'volume_24h': 1340.6},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.18327055864,
#   'price': 1.0026,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1233.42},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.179729480934,
#   'price': 1.00175,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1209.59},
#  {'pair': 'DLT/BTC',
#   'percent_volume': 0.175235168511,
#   'price': 1.01221,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1179.34},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.174571001361,
#   'price': 0.998991,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1174.87},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.174090942722,
#   'price': 1.05421,
#   'source': 'Gate.io',
#   'updated': True,
#   'volume_24h': 1171.64},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.172495909178,
#   'price': 1.01672,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 1160.9},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.166196989224,
#   'price': 1.00831,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1118.52},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.163381333462,
#   'price': 1.01316,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 1099.57},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.159748889757,
#   'price': 1.00167,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 1075.12},
#  {'pair': 'ADA/BTC',
#   'percent_volume': 0.159747513245,
#   'price': 1.04536,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 1075.11},
#  {'pair': 'BTC/TRY',
#   'percent_volume': 0.157580710934,
#   'price': 0.99317,
#   'source': 'Paribu',
#   'updated': True,
#   'volume_24h': 1060.53},
#  {'pair': 'SWFTC/BTC',
#   'percent_volume': 0.14867209586,
#   'price': 1.0001,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 1000.57},
#  {'pair': 'OAX/BTC',
#   'percent_volume': 0.145079398946,
#   'price': 0.981017,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 976.392},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.143626662354,
#   'price': 1.01,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 966.616},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.142920511581,
#   'price': 0.998842,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 961.863},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.142876979382,
#   'price': 0.97124,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 961.57},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.140960874361,
#   'price': 1.00765,
#   'source': 'Bitbank',
#   'updated': True,
#   'volume_24h': 948.675},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.137434766225,
#   'price': 1.00285,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 924.944},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.136404446823,
#   'price': 0.998797,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 918.01},
#  {'pair': 'BTC/RUB',
#   'percent_volume': 0.132549008137,
#   'price': 0.982001,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 892.062},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.131192799465,
#   'price': 1.02136,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 882.935},
#  {'pair': 'OC/BTC',
#   'percent_volume': 0.129874616942,
#   'price': 1.00264,
#   'source': 'Allcoin',
#   'updated': True,
#   'volume_24h': 874.064},
#  {'pair': 'INS/BTC',
#   'percent_volume': 0.129333303509,
#   'price': 1.00669,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 870.42},
#  {'pair': 'ENG/BTC',
#   'percent_volume': 0.128579663064,
#   'price': 0.999988,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 865.349},
#  {'pair': 'INS/BTC',
#   'percent_volume': 0.125287562008,
#   'price': 1.00351,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 843.193},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.125273968949,
#   'price': 1.00536,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 843.101},
#  {'pair': 'BTC/PLN',
#   'percent_volume': 0.125099668088,
#   'price': 1.0018,
#   'source': 'BitBay',
#   'updated': True,
#   'volume_24h': 841.928},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.124488668723,
#   'price': 1.00975,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 837.815},
#  {'pair': 'BTC/ZAR',
#   'percent_volume': 0.123195091357,
#   'price': 1.04313,
#   'source': 'Luno',
#   'updated': True,
#   'volume_24h': 829.11},
#  {'pair': 'MTL/BTC',
#   'percent_volume': 0.11815688454,
#   'price': 1.01505,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 795.202},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.117722250804,
#   'price': 1.01778,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 792.277},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.116449493185,
#   'price': 1.01182,
#   'source': 'Neraex',
#   'updated': True,
#   'volume_24h': 783.712},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.116249554784,
#   'price': 1.00836,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 782.366},
#  {'pair': 'ITC/BTC',
#   'percent_volume': 0.115459952958,
#   'price': 1.00372,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 777.052},
#  {'pair': 'PROPY/BTC',
#   'percent_volume': 0.11431108144,
#   'price': 1.00387,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 769.32},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.114084989306,
#   'price': 0.998999,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 767.799},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.112761472799,
#   'price': 1.009,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 758.892},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.112101951378,
#   'price': 1.00764,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 754.452},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.110894233962,
#   'price': 1.03888,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 746.325},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.108291593468,
#   'price': 0.993082,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 728.808},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.105097913035,
#   'price': 1.01325,
#   'source': 'Simex',
#   'updated': True,
#   'volume_24h': 707.315},
#  {'pair': 'RUFF/BTC',
#   'percent_volume': 0.104028535098,
#   'price': 0.964645,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 700.118},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.102039646993,
#   'price': 1.00556,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 686.733},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.101206340904,
#   'price': 1.00543,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 681.125},
#  {'pair': 'BIX/BTC',
#   'percent_volume': 0.0994609233988,
#   'price': 1.00697,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 669.377},
#  {'pair': 'NAV/BTC',
#   'percent_volume': 0.0981936718292,
#   'price': 1.0027,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 660.849},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0970831705894,
#   'price': 1.00039,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 653.375},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0964484263884,
#   'price': 1.00241,
#   'source': 'Tidex',
#   'updated': True,
#   'volume_24h': 649.104},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0964069589576,
#   'price': 1.00722,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 648.824},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0943661075159,
#   'price': 1.01218,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 635.089},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0938110289601,
#   'price': 0.999178,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 631.354},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0915294599426,
#   'price': 1.00236,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 615.998},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0914805937585,
#   'price': 1.01602,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 615.67},
#  {'pair': 'BRD/BTC',
#   'percent_volume': 0.0900297498705,
#   'price': 0.992545,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 605.906},
#  {'pair': 'BTC/IDR',
#   'percent_volume': 0.0897513502725,
#   'price': 1.0174,
#   'source': 'Bitcoin Indonesia',
#   'updated': True,
#   'volume_24h': 604.032},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0874050851803,
#   'price': 1.01046,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 588.241},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0857133516524,
#   'price': 1.00242,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 576.856},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0852921389107,
#   'price': 1.00539,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 574.021},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0852363901655,
#   'price': 0.995113,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 573.646},
#  {'pair': 'BTC/RUB',
#   'percent_volume': 0.0851954389267,
#   'price': 1.01636,
#   'source': 'GetBTC',
#   'updated': True,
#   'volume_24h': 573.37},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0849805309552,
#   'price': 1.0138,
#   'source': 'GetBTC',
#   'updated': True,
#   'volume_24h': 571.924},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0846434575234,
#   'price': 1.00978,
#   'source': 'GetBTC',
#   'updated': True,
#   'volume_24h': 569.656},
#  {'pair': 'IOST/BTC',
#   'percent_volume': 0.0834281692904,
#   'price': 1.00073,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 561.476},
#  {'pair': 'QBT/BTC',
#   'percent_volume': 0.0832595465425,
#   'price': 0.981251,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 560.341},
#  {'pair': 'SC/BTC',
#   'percent_volume': 0.0829358941049,
#   'price': 0.995425,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 558.164},
#  {'pair': 'RPX/BTC',
#   'percent_volume': 0.0814637142774,
#   'price': 1.00859,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 548.255},
#  {'pair': 'NKC/BTC',
#   'percent_volume': 0.0811574403067,
#   'price': 1.0129,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 546.194},
#  {'pair': 'R/BTC',
#   'percent_volume': 0.0810922280399,
#   'price': 1.01767,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 545.755},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.080089438882,
#   'price': 1.00424,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 539.006},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0800777385281,
#   'price': 1.04285,
#   'source': 'CoolCoin',
#   'updated': True,
#   'volume_24h': 538.927},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0800684470705,
#   'price': 1.00353,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 538.865},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.079364361066,
#   'price': 1.01025,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 534.127},
#  {'pair': 'IOTA/BTC',
#   'percent_volume': 0.0792186228339,
#   'price': 1.00068,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 533.146},
#  {'pair': 'SRN/BTC',
#   'percent_volume': 0.0787444143715,
#   'price': 0.99704,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 529.955},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0785066218841,
#   'price': 0.999711,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 528.355},
#  {'pair': 'IOTA/BTC',
#   'percent_volume': 0.0782593658752,
#   'price': 1.0003,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 526.69},
#  {'pair': 'KNC/BTC',
#   'percent_volume': 0.078215661612,
#   'price': 1.01112,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 526.395},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0776359779001,
#   'price': 1.029,
#   'source': 'BtcTrade.im',
#   'updated': True,
#   'volume_24h': 522.495},
#  {'pair': 'SC/BTC',
#   'percent_volume': 0.077200139716,
#   'price': 0.995425,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 519.562},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0763088480485,
#   'price': 1.0066,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 513.563},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0759839911628,
#   'price': 1.00205,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 511.377},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0734993865917,
#   'price': 1.00102,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 494.655},
#  {'pair': 'ADX/BTC',
#   'percent_volume': 0.0724947047295,
#   'price': 1.0035,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 487.893},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0719583811528,
#   'price': 1.00285,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 484.284},
#  {'pair': 'BTC/GBP',
#   'percent_volume': 0.0716256093217,
#   'price': 1.00078,
#   'source': 'Coinfloor',
#   'updated': True,
#   'volume_24h': 482.044},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0710720793422,
#   'price': 1.00225,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 478.319},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0704505840713,
#   'price': 1.00558,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 474.136},
#  {'pair': 'GXS/BTC',
#   'percent_volume': 0.0701455145489,
#   'price': 1.00476,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 472.084},
#  {'pair': 'XVG/BTC',
#   'percent_volume': 0.0696554761958,
#   'price': 1.00148,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 468.785},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0686310069703,
#   'price': 1.00397,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 461.89},
#  {'pair': 'WTC/BTC',
#   'percent_volume': 0.0683214637831,
#   'price': 1.00283,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 459.807},
#  {'pair': 'BTC/AUD',
#   'percent_volume': 0.067812842515,
#   'price': 1.0157,
#   'source': 'BTC Markets',
#   'updated': True,
#   'volume_24h': 456.384},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0675848576772,
#   'price': 1.00709,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 454.85},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0667396791694,
#   'price': 1.00183,
#   'source': 'Gate.io',
#   'updated': True,
#   'volume_24h': 449.161},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0666457322099,
#   'price': 1.01339,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 448.529},
#  {'pair': 'BTC/GBP',
#   'percent_volume': 0.0663413509435,
#   'price': 1.01251,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 446.481},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0662923126954,
#   'price': 1.00156,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 446.151},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.0652470237225,
#   'price': 0.997924,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 439.116},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 1.0068,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 435.283},
#  {'pair': 'ZIL/BTC',
#   'percent_volume': 0.0646539190163,
#   'price': 1.00634,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 435.124},
#  {'pair': 'RPX/BTC',
#   'percent_volume': 0.0643123719198,
#   'price': 1.00342,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 432.825},
#  {'pair': 'BTC/BRL',
#   'percent_volume': 0.0638569184365,
#   'price': 1.01395,
#   'source': 'Negocie Coins',
#   'updated': True,
#   'volume_24h': 429.761},
#  {'pair': 'LA/BTC',
#   'percent_volume': 0.0637963518985,
#   'price': 1.0176,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 429.353},
#  {'pair': 'XVG/BTC',
#   'percent_volume': 0.0633042487771,
#   'price': 1.00148,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 426.041},
#  {'pair': 'BTC/CAD',
#   'percent_volume': 0.0633023560727,
#   'price': 0.987077,
#   'source': 'QuadrigaCX',
#   'updated': True,
#   'volume_24h': 426.029},
#  {'pair': 'WAVES/BTC',
#   'percent_volume': 0.0631844922132,
#   'price': 0.972416,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 425.235},
#  {'pair': 'JNT/BTC',
#   'percent_volume': 0.0621347295756,
#   'price': 0.995041,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 418.17},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.061671705275,
#   'price': 1.04053,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 415.054},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0588400475585,
#   'price': 1.00216,
#   'source': 'BL3P',
#   'updated': True,
#   'volume_24h': 395.997},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0583185214882,
#   'price': 1.00065,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 392.487},
#  {'pair': 'FUN/BTC',
#   'percent_volume': 0.0572912992383,
#   'price': 1.00581,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 385.574},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0565431648425,
#   'price': 1.00329,
#   'source': 'xBTCe',
#   'updated': True,
#   'volume_24h': 380.539},
#  {'pair': 'BTC/AUD',
#   'percent_volume': 0.0563359997522,
#   'price': 1.01075,
#   'source': 'ACX',
#   'updated': True,
#   'volume_24h': 379.145},
#  {'pair': 'ACT/BTC',
#   'percent_volume': 0.0563205139897,
#   'price': 1.00119,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 379.041},
#  {'pair': 'FCT/BTC',
#   'percent_volume': 0.056219512405,
#   'price': 0.994572,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 378.36},
#  {'pair': 'ION/BTC',
#   'percent_volume': 0.0560462439283,
#   'price': 1.00603,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 377.195},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0557533909518,
#   'price': 1.00449,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 375.224},
#  {'pair': 'ZCL/BTC',
#   'percent_volume': 0.0554758516739,
#   'price': 1.00209,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 373.355},
#  {'pair': 'STR/BTC',
#   'percent_volume': 0.0545074753217,
#   'price': 1.0356,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 366.838},
#  {'pair': 'QUN/BTC',
#   'percent_volume': 0.0541738431705,
#   'price': 0.999422,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 364.593},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0538760003372,
#   'price': 1.00846,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 362.588},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.053832296074,
#   'price': 0.999465,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 362.295},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0537830857619,
#   'price': 1.04122,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 361.963},
#  {'pair': 'AMB/BTC',
#   'percent_volume': 0.0536471551794,
#   'price': 1.00517,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 361.048},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0532693025729,
#   'price': 0.995708,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 358.506},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0529793746849,
#   'price': 1.00653,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 356.555},
#  {'pair': 'OF/BTC',
#   'percent_volume': 0.0528262376996,
#   'price': 1.00563,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 355.523},
#  {'pair': 'NAS/BTC',
#   'percent_volume': 0.0523835169543,
#   'price': 1.0035,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 352.544},
#  {'pair': 'DGD/BTC',
#   'percent_volume': 0.0516173158356,
#   'price': 1.00275,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 347.387},
#  {'pair': 'CND/BTC',
#   'percent_volume': 0.0516021742011,
#   'price': 1.00669,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 347.285},
#  {'pair': 'DSH/BTC',
#   'percent_volume': 0.0514677921948,
#   'price': 1.01582,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 346.382},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0504431509053,
#   'price': 0.998478,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 339.485},
#  {'pair': 'BTC/THB',
#   'percent_volume': 0.0500141952823,
#   'price': 1.01252,
#   'source': 'BX Thailand',
#   'updated': True,
#   'volume_24h': 336.598},
#  {'pair': 'IOST/BTC',
#   'percent_volume': 0.0490203534539,
#   'price': 1.00189,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 329.91},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0485002038959,
#   'price': 1.01339,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 326.409},
#  {'pair': 'R/BTC',
#   'percent_volume': 0.0483811355882,
#   'price': 0.987636,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 325.608},
#  {'pair': 'AST/BTC',
#   'percent_volume': 0.0481741425619,
#   'price': 0.992191,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 324.215},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0480227262169,
#   'price': 1.00379,
#   'source': 'C2CX',
#   'updated': True,
#   'volume_24h': 323.195},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0479163906473,
#   'price': 1.00843,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 322.48},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0477866543698,
#   'price': 0.999845,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 321.607},
#  {'pair': 'SRN/BTC',
#   'percent_volume': 0.0477340027771,
#   'price': 1.01199,
#   'source': 'Liqui',
#   'updated': True,
#   'volume_24h': 321.252},
#  {'pair': 'HMQ/BTC',
#   'percent_volume': 0.0474994795063,
#   'price': 1.00074,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 319.674},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.047400886818,
#   'price': 1.00194,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 319.01},
#  {'pair': 'ADK/BTC',
#   'percent_volume': 0.0469667692742,
#   'price': 1.00113,
#   'source': 'AidosMarket',
#   'updated': True,
#   'volume_24h': 316.089},
#  {'pair': 'MIOTA/BTC',
#   'percent_volume': 0.0464593524542,
#   'price': 1.00049,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 312.674},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0464405974751,
#   'price': 1.00192,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 312.548},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0463784823609,
#   'price': 1.01102,
#   'source': 'BtcTrade.im',
#   'updated': True,
#   'volume_24h': 312.13},
#  {'pair': 'THETA/BTC',
#   'percent_volume': 0.0461098904124,
#   'price': 0.993963,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 310.323},
#  {'pair': 'LBTC/BTC',
#   'percent_volume': 0.0457926043439,
#   'price': 1.03135,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 308.187},
#  {'pair': 'BTC/TRY',
#   'percent_volume': 0.045738748303,
#   'price': 0.999203,
#   'source': 'BTCTurk',
#   'updated': True,
#   'volume_24h': 307.824},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.045424559387,
#   'price': 1.01515,
#   'source': 'Allcoin',
#   'updated': True,
#   'volume_24h': 305.71},
#  {'pair': 'UCASH/BTC',
#   'percent_volume': 0.045394276118,
#   'price': 0.931343,
#   'source': 'BTC-Alpha',
#   'updated': True,
#   'volume_24h': 305.506},
#  {'pair': 'XVG/BTC',
#   'percent_volume': 0.0451015952056,
#   'price': 1.00148,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 303.536},
#  {'pair': 'STK/BTC',
#   'percent_volume': 0.0448730941758,
#   'price': 1.00589,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 301.999},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.0448001390277,
#   'price': 1.04089,
#   'source': 'Coinnest',
#   'updated': True,
#   'volume_24h': 301.507},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0440915793585,
#   'price': 1.01518,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 296.739},
#  {'pair': 'NBT/BTC',
#   'percent_volume': 0.0438642827769,
#   'price': 1.00174,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 295.209},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0437297287066,
#   'price': 1.00105,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 294.303},
#  {'pair': 'BTC/PEN',
#   'percent_volume': 0.0,
#   'price': 0.998719,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 293.332},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0428730219089,
#   'price': 1.01154,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 288.538},
#  {'pair': 'BTC/PLN',
#   'percent_volume': 0.0426221525554,
#   'price': 1.01227,
#   'source': 'Coinroom',
#   'updated': True,
#   'volume_24h': 286.849},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0424366675327,
#   'price': 1.01087,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 285.602},
#  {'pair': 'ELF/BTC',
#   'percent_volume': 0.0422067899907,
#   'price': 1.00547,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 284.054},
#  {'pair': 'HMQ/BTC',
#   'percent_volume': 0.0421734095692,
#   'price': 1.00111,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 283.829},
#  {'pair': 'XRB/BTC',
#   'percent_volume': 0.04210596047,
#   'price': 1.00735,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 283.376},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0410973211351,
#   'price': 1.00093,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 276.587},
#  {'pair': 'XDN/BTC',
#   'percent_volume': 0.0407728083775,
#   'price': 1.01652,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 274.403},
#  {'pair': 'BTC/RUR',
#   'percent_volume': 0.0407082843668,
#   'price': 1.01503,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 273.969},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0405723537843,
#   'price': 1.00475,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 273.054},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.0402877598812,
#   'price': 1.03888,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 271.139},
#  {'pair': 'SUB/BTC',
#   'percent_volume': 0.0402629826611,
#   'price': 1.00329,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 270.973},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.0399835506789,
#   'price': 0.994334,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 269.091},
#  {'pair': 'ION/BTC',
#   'percent_volume': 0.0398502010568,
#   'price': 0.994315,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 268.194},
#  {'pair': 'BTC/CAD',
#   'percent_volume': 0.0398183692116,
#   'price': 1.02071,
#   'source': 'Coinsquare',
#   'updated': True,
#   'volume_24h': 267.98},
#  {'pair': 'ARN/BTC',
#   'percent_volume': 0.0396438962867,
#   'price': 1.0052,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 266.806},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0395373886531,
#   'price': 1.0048,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 266.089},
#  {'pair': 'RUFF/BTC',
#   'percent_volume': 0.0394549699834,
#   'price': 1.0232,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 265.534},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0389860955059,
#   'price': 0.997881,
#   'source': 'Bitonic',
#   'updated': True,
#   'volume_24h': 262.379},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0388699522866,
#   'price': 1.07325,
#   'source': 'BTC-Alpha',
#   'updated': True,
#   'volume_24h': 261.597},
#  {'pair': 'FOTA/BTC',
#   'percent_volume': 0.0387169873653,
#   'price': 1.00171,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 260.567},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0386343966317,
#   'price': 1.04794,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 260.011},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0385645386361,
#   'price': 1.00508,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 259.542},
#  {'pair': 'LBTC/BTC',
#   'percent_volume': 0.0382832139496,
#   'price': 1.01201,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 257.648},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0382589529216,
#   'price': 1.01327,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 257.485},
#  {'pair': 'SXUT/BTC',
#   'percent_volume': 0.0382532748086,
#   'price': 1.00406,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 257.446},
#  {'pair': 'DTA/BTC',
#   'percent_volume': 0.0376221439522,
#   'price': 0.999323,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 253.2},
#  {'pair': 'SOC/BTC',
#   'percent_volume': 0.0374683187108,
#   'price': 1.0299,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 252.164},
#  {'pair': 'REBL/BTC',
#   'percent_volume': 0.0374678025187,
#   'price': 1.00178,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 252.161},
#  {'pair': 'BCN/BTC',
#   'percent_volume': 0.0373907178339,
#   'price': 1.00121,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 251.641},
#  {'pair': 'BTC/TRY',
#   'percent_volume': 0.0373884810016,
#   'price': 1.00831,
#   'source': 'Vebitcoin',
#   'updated': True,
#   'volume_24h': 251.627},
#  {'pair': 'LET/BTC',
#   'percent_volume': 0.0373631875894,
#   'price': 1.00471,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 251.456},
#  {'pair': 'MANA/BTC',
#   'percent_volume': 0.0372752628708,
#   'price': 0.99848,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 250.864},
#  {'pair': 'VEN/BTC',
#   'percent_volume': 0.0372227833421,
#   'price': 0.999976,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 250.512},
#  {'pair': 'UNY/BTC',
#   'percent_volume': 0.0371878543444,
#   'price': 1.00936,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 250.277},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0,
#   'price': 1.00834,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 249.402},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0369855070469,
#   'price': 1.0111,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 248.914},
#  {'pair': 'VIB/BTC',
#   'percent_volume': 0.0369039486974,
#   'price': 1.00418,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 248.365},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0368001940882,
#   'price': 1.00721,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 247.667},
#  {'pair': 'ADX/BTC',
#   'percent_volume': 0.036653939664,
#   'price': 0.99625,
#   'source': 'Liqui',
#   'updated': True,
#   'volume_24h': 246.683},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0366387980295,
#   'price': 1.00503,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 246.581},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0359269691438,
#   'price': 1.00642,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 241.79},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0358691556302,
#   'price': 1.06899,
#   'source': 'LakeBTC',
#   'updated': True,
#   'volume_24h': 241.401},
#  {'pair': 'HLC/BTC',
#   'percent_volume': 0.0358335383763,
#   'price': 0.978901,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 241.162},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0357074154434,
#   'price': 0.999026,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 240.313},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.035632395527,
#   'price': 1.01306,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 239.808},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0347789579458,
#   'price': 1.01025,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 234.065},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0346932700597,
#   'price': 1.00525,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 233.488},
#  {'pair': 'WPR/BTC',
#   'percent_volume': 0.0346364889303,
#   'price': 1.00276,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 233.105},
#  {'pair': 'QUN/BTC',
#   'percent_volume': 0.0346031085087,
#   'price': 1.01544,
#   'source': 'ZB.COM',
#   'updated': True,
#   'volume_24h': 232.881},
#  {'pair': 'NEBL/BTC',
#   'percent_volume': 0.0341010256737,
#   'price': 1.14,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 229.502},
#  {'pair': 'GTO/BTC',
#   'percent_volume': 0.0340951754967,
#   'price': 0.992417,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 229.462},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0339026358489,
#   'price': 1.00604,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 228.167},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0335445706056,
#   'price': 0.990387,
#   'source': 'RightBTC',
#   'updated': True,
#   'volume_24h': 225.757},
#  {'pair': 'AION/BTC',
#   'percent_volume': 0.0331013336683,
#   'price': 0.995758,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 222.774},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.033069329759,
#   'price': 0.996645,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 222.559},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0329791682081,
#   'price': 1.02669,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 221.952},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0329736621592,
#   'price': 1.02138,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 221.914},
#  {'pair': 'EKT/BTC',
#   'percent_volume': 0.0328310210796,
#   'price': 1.05325,
#   'source': 'BigONE',
#   'updated': True,
#   'volume_24h': 220.955},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0327164264366,
#   'price': 1.00144,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 220.183},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0326964670093,
#   'price': 1.00575,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 220.05},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0325030670413,
#   'price': 1.00353,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 218.747},
#  {'pair': 'MANA/BTC',
#   'percent_volume': 0.0321950724304,
#   'price': 0.997035,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 216.675},
#  {'pair': 'ZLA/BTC',
#   'percent_volume': 0.031963474248,
#   'price': 1.00525,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 215.116},
#  {'pair': 'R/BTC',
#   'percent_volume': 0.031933018915,
#   'price': 1.01664,
#   'source': 'BTC-Alpha',
#   'updated': True,
#   'volume_24h': 214.911},
#  {'pair': 'BTC/BRL',
#   'percent_volume': 0.031848191349,
#   'price': 1.01064,
#   'source': 'Foxbit',
#   'updated': True,
#   'volume_24h': 214.34},
#  {'pair': 'BTM/BTC',
#   'percent_volume': 0.0317709346002,
#   'price': 0.994164,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 213.821},
#  {'pair': 'DNT/BTC',
#   'percent_volume': 0.0316924734032,
#   'price': 1.00595,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 213.292},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0,
#   'price': 0.658557,
#   'source': 'HitBTC',
#   'updated': False,
#   'volume_24h': 234.1},
#  {'pair': 'LINK/BTC',
#   'percent_volume': 0.0316449837313,
#   'price': 0.987756,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 212.973},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0313418069132,
#   'price': 1.00368,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 210.932},
#  {'pair': 'VIB/BTC',
#   'percent_volume': 0.0313173738211,
#   'price': 1.00218,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 210.768},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0312454510572,
#   'price': 1.01537,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 210.284},
#  {'pair': 'MDS/BTC',
#   'percent_volume': 0.0311859169034,
#   'price': 1.00295,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 209.883},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0311420405761,
#   'price': 1.00664,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 209.587},
#  {'pair': 'TNT/BTC',
#   'percent_volume': 0.0309534584009,
#   'price': 1.01822,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 208.319},
#  {'pair': 'LEND/BTC',
#   'percent_volume': 0.0307865562933,
#   'price': 0.998392,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 207.195},
#  {'pair': 'ORME/BTC',
#   'percent_volume': 0.0307517993596,
#   'price': 0.991203,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 206.961},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0305929842613,
#   'price': 1.01973,
#   'source': 'BtcTrade.im',
#   'updated': True,
#   'volume_24h': 205.892},
#  {'pair': 'ZRX/BTC',
#   'percent_volume': 0.0304737438896,
#   'price': 1.01049,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 205.089},
#  {'pair': 'NAV/BTC',
#   'percent_volume': 0.030464452432,
#   'price': 0.994775,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 205.028},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0303264570812,
#   'price': 1.0128,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 204.099},
#  {'pair': 'VIBE/BTC',
#   'percent_volume': 0.030288775059,
#   'price': 1.00538,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 203.845},
#  {'pair': 'STRAT/BTC',
#   'percent_volume': 0.0302306174174,
#   'price': 1.0153,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 203.453},
#  {'pair': 'STRAT/BTC',
#   'percent_volume': 0.0302211538958,
#   'price': 1.01408,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 203.391},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.0301793423369,
#   'price': 1.0166,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 203.109},
#  {'pair': 'QSP/BTC',
#   'percent_volume': 0.0301340894974,
#   'price': 0.998084,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 202.804},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0300735229594,
#   'price': 1.00807,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 202.397},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0298813274396,
#   'price': 0.999507,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 201.103},
#  {'pair': 'CDT/BTC',
#   'percent_volume': 0.0298443336734,
#   'price': 1.00635,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 200.854},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0298245463102,
#   'price': 0.99803,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 200.721},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.0297257815578,
#   'price': 1.03888,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 200.056},
#  {'pair': 'MOD/BTC',
#   'percent_volume': 0.0296170370918,
#   'price': 1.00063,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 199.324},
#  {'pair': 'BTC/ARS',
#   'percent_volume': 0.0,
#   'price': 1.02308,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 197.776},
#  {'pair': 'VIU/BTC',
#   'percent_volume': 0.0291266546107,
#   'price': 0.994483,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 196.024},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0291147821927,
#   'price': 1.00746,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 195.944},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0290989523021,
#   'price': 1.01305,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 195.837},
#  {'pair': 'XRB/BTC',
#   'percent_volume': 0.029073830954,
#   'price': 1.00443,
#   'source': 'RightBTC',
#   'updated': True,
#   'volume_24h': 195.669},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0290550759749,
#   'price': 1.00714,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 195.542},
#  {'pair': 'ETN/BTC',
#   'percent_volume': 0.028964914424,
#   'price': 0.997794,
#   'source': 'Cryptopia',
#   'updated': True,
#   'volume_24h': 194.936},
#  {'pair': 'DOGE/BTC',
#   'percent_volume': 0.0286927091309,
#   'price': 0.992116,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 193.103},
#  {'pair': 'GAS/BTC',
#   'percent_volume': 0.0285080844284,
#   'price': 1.00597,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 191.861},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0283933177214,
#   'price': 1.01956,
#   'source': 'Exrates',
#   'updated': True,
#   'volume_24h': 191.089},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0282162638361,
#   'price': 1.00508,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 189.898},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.0278418525102,
#   'price': 0.982313,
#   'source': 'Exrates',
#   'updated': True,
#   'volume_24h': 187.378},
#  {'pair': 'DGB/BTC',
#   'percent_volume': 0.0277836948685,
#   'price': 0.998784,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 186.986},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0277513468312,
#   'price': 1.01208,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 186.768},
#  {'pair': 'RCN/BTC',
#   'percent_volume': 0.0277023085831,
#   'price': 1.00099,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 186.438},
#  {'pair': 'DOGE/BTC',
#   'percent_volume': 0.0276828653479,
#   'price': 1.00838,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 186.308},
#  {'pair': 'CTR/BTC',
#   'percent_volume': 0.0275975215897,
#   'price': 1.00253,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 185.733},
#  {'pair': 'NULS/BTC',
#   'percent_volume': 0.0274839593309,
#   'price': 1.01324,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 184.968},
#  {'pair': 'BTM/BTC',
#   'percent_volume': 0.0274450728605,
#   'price': 1.00457,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 184.707},
#  {'pair': 'BTS/BTC',
#   'percent_volume': 0.0273065613176,
#   'price': 1.00156,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 183.775},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0272084848214,
#   'price': 1.0137,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 183.114},
#  {'pair': 'HPB/BTC',
#   'percent_volume': 0.026988586993,
#   'price': 1.00844,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 181.634},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0269335265039,
#   'price': 1.0074,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 181.264},
#  {'pair': 'BTC/MXN',
#   'percent_volume': 0.0268452576573,
#   'price': 1.01511,
#   'source': 'Bitso',
#   'updated': True,
#   'volume_24h': 180.671},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0266817968302,
#   'price': 1.00327,
#   'source': 'RightBTC',
#   'updated': True,
#   'volume_24h': 179.57},
#  {'pair': 'MONA/BTC',
#   'percent_volume': 0.026342142438,
#   'price': 1.00431,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 177.284},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0262543897835,
#   'price': 1.0468,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 176.693},
#  {'pair': 'WAVES/BTC',
#   'percent_volume': 0.026196920398,
#   'price': 0.980911,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 176.307},
#  {'pair': 'MONA/BTC',
#   'percent_volume': 0.0260649472882,
#   'price': 1.00759,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 175.419},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0258510717008,
#   'price': 1.01518,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 173.979},
#  {'pair': 'ENG/BTC',
#   'percent_volume': 0.0256939772428,
#   'price': 1.00654,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 172.922},
#  {'pair': 'IGNIS/BTC',
#   'percent_volume': 0.0255965890027,
#   'price': 1.01636,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 172.267},
#  {'pair': 'BTS/BTC',
#   'percent_volume': 0.0253844340556,
#   'price': 0.99979,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 170.839},
#  {'pair': 'BTM/BTC',
#   'percent_volume': 0.0251144655949,
#   'price': 1.00445,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 169.022},
#  {'pair': 'XAS/BTC',
#   'percent_volume': 0.0251134332108,
#   'price': 0.997266,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 169.015},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0250957106158,
#   'price': 0.998617,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 168.896},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0248885455256,
#   'price': 1.00331,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 167.501},
#  {'pair': 'APPC/BTC',
#   'percent_volume': 0.024745904446,
#   'price': 1.00075,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 166.542},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0246387085562,
#   'price': 1.01065,
#   'source': 'TOPBTC',
#   'updated': True,
#   'volume_24h': 165.82},
#  {'pair': 'PUT/BTC',
#   'percent_volume': 0.0246261478821,
#   'price': 0.984917,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 165.735},
#  {'pair': 'BTC/CLP',
#   'percent_volume': 0.0,
#   'price': 1.01716,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 164.782},
#  {'pair': '1ST/BTC',
#   'percent_volume': 0.0243876671387,
#   'price': 0.99695,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 164.13},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.0243708048639,
#   'price': 1.0795,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 164.016},
#  {'pair': 'R/BTC',
#   'percent_volume': 0.0243203901036,
#   'price': 0.911653,
#   'source': 'Cryptopia',
#   'updated': True,
#   'volume_24h': 163.677},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 1.00132,
#   'source': 'BitMEX',
#   'updated': True,
#   'volume_24h': 196753.0},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 1.00786,
#   'source': 'Zaif',
#   'updated': True,
#   'volume_24h': 15949.1},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 1.00642,
#   'source': 'Fisco',
#   'updated': True,
#   'volume_24h': 15928.2},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 1.00057,
#   'source': 'BTCBOX',
#   'updated': True,
#   'volume_24h': 15310.2},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 1.0043,
#   'source': 'Quoine',
#   'updated': True,
#   'volume_24h': 10000.4},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 1.00286,
#   'source': 'Quoine',
#   'updated': True,
#   'volume_24h': 1696.84},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0,
#   'price': 1.00055,
#   'source': 'ZB.COM',
#   'updated': True,
#   'volume_24h': 1435.61},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.0,
#   'price': 1.04821,
#   'source': 'GOPAX',
#   'updated': True,
#   'volume_24h': 1265.27},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 1.0016,
#   'source': 'bitFlyer',
#   'updated': True,
#   'volume_24h': 269.736},
#  {'pair': 'BTC/SGD',
#   'percent_volume': 0.0,
#   'price': 1.00585,
#   'source': 'Quoine',
#   'updated': True,
#   'volume_24h': 218.034},
#  {'pair': 'BTC/ETH',
#   'percent_volume': 0.0,
#   'price': 0.00957214,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 367.867},
#  {'pair': 'BTC/LTC',
#   'percent_volume': 0.0,
#   'price': 0.000333633,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 322.693},
#  {'pair': 'BTC/XRP',
#   'percent_volume': 0.0,
#   'price': 1.37289e-08,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 319.534}]

# %% [markdown]
# #### `ranks()`
# Get gainers and losers rankings:

# %%
cmc.ranks()
# Out:
# {'gainers': {'1h': [{'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8},
#    {'name': 'LIFE',
#     'percent_change': 31.65,
#     'price': 0.00134462,
#     'symbol': 'LIFE',
#     'volume_24h': 74539.8}],
#   '24h': [{'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0},
#    {'name': 'E-coin',
#     'percent_change': 287.46,
#     'price': 73.4392,
#     'symbol': 'ECN',
#     'volume_24h': 142377.0}],
#   '7d': [{'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 3072.45,
#     'price': 0.0673639,
#     'symbol': 'UNY',
#     'volume_24h': 3113430.0}]},
#  'losers': {'1h': [{'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0},
#    {'name': 'Bitcoin Gold',
#     'percent_change': -12.24,
#     'price': 112.878,
#     'symbol': 'BTG',
#     'volume_24h': 29154400.0}],
#   '24h': [{'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2},
#    {'name': 'DavorCoin',
#     'percent_change': -97.81,
#     'price': 0.0388601,
#     'symbol': 'DAV',
#     'volume_24h': 52605.2}],
#   '7d': [{'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0},
#    {'name': 'TerraNova',
#     'percent_change': -27.18,
#     'price': 26.4332,
#     'symbol': 'TER',
#     'volume_24h': 144181.0}]}}

# %% [markdown]
# #### `historical(currency, [start=datetime(2008, 8, 18), end=datetime.now(), revert=False])`
# Get historical prices for a currency. You can filter by `start` and `end` datetimes provided in `datetime` objects. With parameter `revert` active, the response will be ordered in chronological order.

# %%
from datetime import datetime

cmc.historical("ETH", start=datetime(2018, 2, 1), revert=True)
# Out:
# [{'close': 1036.79,
#   'date': datetime.datetime(2018, 2, 1, 0, 0),
#   'high': 1161.35,
#   'low': 984.819,
#   'market_cap': 796.439,
#   'open': 1119.37,
#   'volume': 707.737},
#  {'close': 915.785,
#   'date': datetime.datetime(2018, 2, 2, 0, 0),
#   'high': 1035.77,
#   'low': 757.98,
#   'market_cap': 757.068,
#   'open': 1035.77,
#   'volume': 723.433},
#  {'close': 964.019,
#   'date': datetime.datetime(2018, 2, 3, 0, 0),
#   'high': 991.943,
#   'low': 847.69,
#   'market_cap': 851.2,
#   'open': 919.211,
#   'volume': 790.428},
#  {'close': 834.682,
#   'date': datetime.datetime(2018, 2, 4, 0, 0),
#   'high': 969.032,
#   'low': 805.064,
#   'market_cap': 817.807,
#   'open': 964.667,
#   'volume': 755.843},
#  {'close': 697.951,
#   'date': datetime.datetime(2018, 2, 5, 0, 0),
#   'high': 856.646,
#   'low': 644.599,
#   'market_cap': 845.086,
#   'open': 834.958,
#   'volume': 755.843},
#  {'close': 793.122,
#   'date': datetime.datetime(2018, 2, 6, 0, 0),
#   'high': 796.439,
#   'low': 574.419,
#   'market_cap': 883.865,
#   'open': 707.737,
#   'volume': 788.834},
#  {'close': 757.068,
#   'date': datetime.datetime(2018, 2, 7, 0, 0),
#   'high': 851.2,
#   'low': 723.433,
#   'market_cap': 884.004,
#   'open': 790.428,
#   'volume': 818.48},
#  {'close': 817.807,
#   'date': datetime.datetime(2018, 2, 8, 0, 0),
#   'high': 845.086,
#   'low': 755.843,
#   'market_cap': 860.415,
#   'open': 755.843,
#   'volume': 825.577},
#  {'close': 883.865,
#   'date': datetime.datetime(2018, 2, 9, 0, 0),
#   'high': 884.004,
#   'low': 788.834,
#   'market_cap': 917.4,
#   'open': 818.48,
#   'volume': 882.467},
#  {'close': 860.415,
#   'date': datetime.datetime(2018, 2, 10, 0, 0),
#   'high': 917.4,
#   'low': 825.577,
#   'market_cap': 814.66,
#   'open': 882.467,
#   'volume': 788.222},
#  {'close': 814.66,
#   'date': datetime.datetime(2018, 2, 11, 0, 0),
#   'high': 859.288,
#   'low': 788.222,
#   'market_cap': 859.288,
#   'open': 859.288,
#   'volume': 859.288}]

# %% [markdown]
# #### `recently([convert="USD"])`
# Get recently added coins in coinmarketcap along with other metadata. This method returns a `generator` object.

# %%
list(cmc.recently())
# Out:
# [{'added': '2 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Indicoin',
#   'percent_change': None,
#   'price': 0.0354058,
#   'symbol': 'INDI',
#   'volume_24h': 37782.4},
#  {'added': '2 days ago',
#   'circulating_supply': 66000000.0,
#   'market_cap': 44643456.0,
#   'name': 'LOCIcoin',
#   'percent_change': None,
#   'price': 0.676416,
#   'symbol': 'LOCI',
#   'volume_24h': 365561.0},
#  {'added': '2 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Animation Vision Cash',
#   'percent_change': None,
#   'price': 0.0344002,
#   'symbol': 'AVH',
#   'volume_24h': 738029.0},
#  {'added': '2 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'MktCoin',
#   'percent_change': None,
#   'price': 0.0273599,
#   'symbol': 'MLM',
#   'volume_24h': 186108.0}]

# %% [markdown]
# #### `exchange(name [convert="USD"])`
# Get data about a exchange:

# %%
cmc.exchange("okex")
# Out:
# {'markets': [{'currency': 'Bitcoin',
#    'pair': 'BTC/USDT',
#    'perc_volume': 25.6864214819,
#    'price': 8646.28,
#    'updated': True,
#    'vol_24h': 433311000.0},
#   {'currency': 'Ethereum',
#    'pair': 'ETH/USDT',
#    'perc_volume': 12.3151793747,
#    'price': 854.428,
#    'updated': True,
#    'vol_24h': 207748000.0},
#   {'currency': 'Ethereum',
#    'pair': 'ETH/BTC',
#    'perc_volume': 11.2735215393,
#    'price': 854.032,
#    'updated': True,
#    'vol_24h': 190176000.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/BTC',
#    'perc_volume': 9.11640300023,
#    'price': 159.033,
#    'updated': True,
#    'vol_24h': 153787000.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/BTC',
#    'perc_volume': 5.37395735052,
#    'price': 28.3302,
#    'updated': True,
#    'vol_24h': 90654700.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/USDT',
#    'perc_volume': 5.13865957874,
#    'price': 159.568,
#    'updated': True,
#    'vol_24h': 86685400.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/USDT',
#    'perc_volume': 4.91013151586,
#    'price': 1252.81,
#    'updated': True,
#    'vol_24h': 82830300.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/BTC',
#    'perc_volume': 4.88200343466,
#    'price': 1253.49,
#    'updated': True,
#    'vol_24h': 82355800.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/USDT',
#    'perc_volume': 4.14531446456,
#    'price': 0.00400016,
#    'updated': True,
#    'vol_24h': 69928400.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/USDT',
#    'perc_volume': 2.55610455246,
#    'price': 28.2743,
#    'updated': True,
#    'vol_24h': 43119600.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/USDT',
#    'perc_volume': 1.60703523142,
#    'price': 8.90225,
#    'updated': True,
#    'vol_24h': 27109500.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/ETH',
#    'perc_volume': 1.44051343395,
#    'price': 28.4516,
#    'updated': True,
#    'vol_24h': 24300400.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/BTC',
#    'perc_volume': 0.933022384088,
#    'price': 8.91813,
#    'updated': True,
#    'vol_24h': 15739400.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/USDT',
#    'perc_volume': 0.854607577318,
#    'price': 1.02144,
#    'updated': True,
#    'vol_24h': 14416600.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/BTC',
#    'perc_volume': 0.748444077587,
#    'price': 1.02167,
#    'updated': True,
#    'vol_24h': 12625700.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/BTC',
#    'perc_volume': 0.512204355943,
#    'price': 0.0189983,
#    'updated': True,
#    'vol_24h': 8640510.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/BTC',
#    'perc_volume': 0.431640077679,
#    'price': 2.40656,
#    'updated': True,
#    'vol_24h': 7281450.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/ETH',
#    'perc_volume': 0.394121544754,
#    'price': 0.0190071,
#    'updated': True,
#    'vol_24h': 6648540.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/USDT',
#    'perc_volume': 0.374637587475,
#    'price': 109.832,
#    'updated': True,
#    'vol_24h': 6319860.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/BTC',
#    'perc_volume': 0.373085652457,
#    'price': 109.812,
#    'updated': True,
#    'vol_24h': 6293680.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/USDT',
#    'perc_volume': 0.342042209753,
#    'price': 1.04134,
#    'updated': True,
#    'vol_24h': 5770000.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/BTC',
#    'perc_volume': 0.334470450403,
#    'price': 28.3163,
#    'updated': True,
#    'vol_24h': 5642270.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/ETH',
#    'perc_volume': 0.298787208087,
#    'price': 8.92112,
#    'updated': True,
#    'vol_24h': 5040320.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/USDT',
#    'perc_volume': 0.288074232672,
#    'price': 28.4016,
#    'updated': True,
#    'vol_24h': 4859600.0},
#   {'currency': 'Revain',
#    'pair': 'R/BTC',
#    'perc_volume': 0.279378535662,
#    'price': 2.65561,
#    'updated': True,
#    'vol_24h': 4712910.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/BTC',
#    'perc_volume': 0.269618773198,
#    'price': 1.80535,
#    'updated': True,
#    'vol_24h': 4548270.0},
#   {'currency': 'Revain',
#    'pair': 'R/ETH',
#    'perc_volume': 0.263816504309,
#    'price': 2.66602,
#    'updated': True,
#    'vol_24h': 4450390.0},
#   {'currency': 'LAToken',
#    'pair': 'LA/BTC',
#    'perc_volume': 0.219790870281,
#    'price': 0.381951,
#    'updated': True,
#    'vol_24h': 3707710.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/BTC',
#    'perc_volume': 0.181996688089,
#    'price': 0.00397236,
#    'updated': True,
#    'vol_24h': 3070150.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/USDT',
#    'perc_volume': 0.175926476256,
#    'price': 1.81577,
#    'updated': True,
#    'vol_24h': 2967750.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/ETH',
#    'perc_volume': 0.172086355918,
#    'price': 1.02413,
#    'updated': True,
#    'vol_24h': 2902970.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/BTC',
#    'perc_volume': 0.128420547924,
#    'price': 0.119171,
#    'updated': True,
#    'vol_24h': 2166360.0},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/ETH',
#    'perc_volume': 0.114766720858,
#    'price': 0.0520146,
#    'updated': True,
#    'vol_24h': 1936030.0},
#   {'currency': 'Viberate',
#    'pair': 'VIB/BTC',
#    'perc_volume': 0.107894458574,
#    'price': 0.260276,
#    'updated': True,
#    'vol_24h': 1820100.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/ETH',
#    'perc_volume': 0.106284429732,
#    'price': 2.41583,
#    'updated': True,
#    'vol_24h': 1792940.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/BTC',
#    'perc_volume': 0.0945536268053,
#    'price': 0.363126,
#    'updated': True,
#    'vol_24h': 1595050.0},
#   {'currency': 'Hshare',
#    'pair': 'HSR/BTC',
#    'perc_volume': 0.0937385348843,
#    'price': 11.8493,
#    'updated': True,
#    'vol_24h': 1581300.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/USDT',
#    'perc_volume': 0.0816834735714,
#    'price': 1.24445,
#    'updated': True,
#    'vol_24h': 1377940.0},
#   {'currency': 'LAToken',
#    'pair': 'LA/ETH',
#    'perc_volume': 0.076113579979,
#    'price': 0.39206,
#    'updated': True,
#    'vol_24h': 1283980.0},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/ETH',
#    'perc_volume': 0.076080383508,
#    'price': 0.0553582,
#    'updated': True,
#    'vol_24h': 1283420.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/ETH',
#    'perc_volume': 0.0746416721682,
#    'price': 0.00400376,
#    'updated': True,
#    'vol_24h': 1259150.0},
#   {'currency': 'Hshare',
#    'pair': 'HSR/USDT',
#    'perc_volume': 0.0741864062807,
#    'price': 12.0105,
#    'updated': True,
#    'vol_24h': 1251470.0},
#   {'currency': 'SunContract',
#    'pair': 'SNC/BTC',
#    'perc_volume': 0.0713955315432,
#    'price': 0.251727,
#    'updated': True,
#    'vol_24h': 1204390.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/BTC',
#    'perc_volume': 0.0706675803585,
#    'price': 8.3145,
#    'updated': True,
#    'vol_24h': 1192110.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/ETH',
#    'perc_volume': 0.068791386955,
#    'price': 110.593,
#    'updated': True,
#    'vol_24h': 1160460.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/BTC',
#    'perc_volume': 0.0662856461913,
#    'price': 0.382815,
#    'updated': True,
#    'vol_24h': 1118190.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/BTC',
#    'perc_volume': 0.0659270057461,
#    'price': 1.18385,
#    'updated': True,
#    'vol_24h': 1112140.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/USDT',
#    'perc_volume': 0.0609623549546,
#    'price': 1.18945,
#    'updated': True,
#    'vol_24h': 1028390.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/USDT',
#    'perc_volume': 0.0547544963255,
#    'price': 0.364814,
#    'updated': True,
#    'vol_24h': 923668.0},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/BTC',
#    'perc_volume': 0.0496167496497,
#    'price': 0.174525,
#    'updated': True,
#    'vol_24h': 836998.0},
#   {'currency': 'ugChain',
#    'pair': 'UGC/BTC',
#    'perc_volume': 0.0487435046251,
#    'price': 0.0824697,
#    'updated': True,
#    'vol_24h': 822267.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/BTC',
#    'perc_volume': 0.0480967069561,
#    'price': 4.14412,
#    'updated': True,
#    'vol_24h': 811356.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/BTC',
#    'perc_volume': 0.046404991084,
#    'price': 0.366321,
#    'updated': True,
#    'vol_24h': 782818.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/ETH',
#    'perc_volume': 0.0462204542731,
#    'price': 28.4685,
#    'updated': True,
#    'vol_24h': 779705.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/BTC',
#    'perc_volume': 0.0456500084872,
#    'price': 0.32392,
#    'updated': True,
#    'vol_24h': 770082.0},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/USDT',
#    'perc_volume': 0.0456234513104,
#    'price': 0.176807,
#    'updated': True,
#    'vol_24h': 769634.0},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/USDT',
#    'perc_volume': 0.0456206058986,
#    'price': 0.0377015,
#    'updated': True,
#    'vol_24h': 769586.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/USDT',
#    'perc_volume': 0.0447884415069,
#    'price': 8.32232,
#    'updated': True,
#    'vol_24h': 755548.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/ETH',
#    'perc_volume': 0.044497261033,
#    'price': 1.8143,
#    'updated': True,
#    'vol_24h': 750636.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/USDT',
#    'perc_volume': 0.044252496339,
#    'price': 0.00470018,
#    'updated': True,
#    'vol_24h': 746507.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/ETH',
#    'perc_volume': 0.0439477408797,
#    'price': 0.00457818,
#    'updated': True,
#    'vol_24h': 741366.0},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/ETH',
#    'perc_volume': 0.0432279702539,
#    'price': 0.389728,
#    'updated': True,
#    'vol_24h': 729224.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/ETH',
#    'perc_volume': 0.0417346625752,
#    'price': 0.364394,
#    'updated': True,
#    'vol_24h': 704033.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/BTC',
#    'perc_volume': 0.041725000031,
#    'price': 0.175216,
#    'updated': True,
#    'vol_24h': 703870.0},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/BTC',
#    'perc_volume': 0.0411508789216,
#    'price': 0.22228,
#    'updated': True,
#    'vol_24h': 694185.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/USDT',
#    'perc_volume': 0.0372002024798,
#    'price': 0.119305,
#    'updated': True,
#    'vol_24h': 627540.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/BTC',
#    'perc_volume': 0.0370391995956,
#    'price': 0.00518134,
#    'updated': True,
#    'vol_24h': 624824.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/BTC',
#    'perc_volume': 0.0340254935468,
#    'price': 1.25622,
#    'updated': True,
#    'vol_24h': 573985.0},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/BTC',
#    'perc_volume': 0.0332565210087,
#    'price': 2.30458,
#    'updated': True,
#    'vol_24h': 561013.0},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/BTC',
#    'perc_volume': 0.0329025636371,
#    'price': 114.097,
#    'updated': True,
#    'vol_24h': 555042.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/ETH',
#    'perc_volume': 0.0312481345154,
#    'price': 1249.48,
#    'updated': True,
#    'vol_24h': 527133.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/USDT',
#    'perc_volume': 0.0305136625953,
#    'price': 0.0051002,
#    'updated': True,
#    'vol_24h': 514743.0},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/BTC',
#    'perc_volume': 0.0301878036652,
#    'price': 0.0544905,
#    'updated': True,
#    'vol_24h': 509246.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/USDT',
#    'perc_volume': 0.0289518279159,
#    'price': 0.370014,
#    'updated': True,
#    'vol_24h': 488396.0},
#   {'currency': 'Super Bitcoin',
#    'pair': 'SBTC/BTC',
#    'perc_volume': 0.028789283767,
#    'price': 22.3103,
#    'updated': True,
#    'vol_24h': 485654.0},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/BTC',
#    'perc_volume': 0.0287013131189,
#    'price': 0.49076,
#    'updated': True,
#    'vol_24h': 484170.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/USDT',
#    'perc_volume': 0.0276495185041,
#    'price': 0.0189007,
#    'updated': True,
#    'vol_24h': 466427.0},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/USDT',
#    'perc_volume': 0.0273153604562,
#    'price': 0.427817,
#    'updated': True,
#    'vol_24h': 460790.0},
#   {'currency': 'NEM',
#    'pair': 'XEM/BTC',
#    'perc_volume': 0.0271687031898,
#    'price': 0.496805,
#    'updated': True,
#    'vol_24h': 458316.0},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/USDT',
#    'perc_volume': 0.0265888319774,
#    'price': 0.490919,
#    'updated': True,
#    'vol_24h': 448534.0},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/BTC',
#    'perc_volume': 0.0256819755259,
#    'price': 0.0683937,
#    'updated': True,
#    'vol_24h': 433236.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/USDT',
#    'perc_volume': 0.0254648350382,
#    'price': 2.39599,
#    'updated': True,
#    'vol_24h': 429573.0},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/USDT',
#    'perc_volume': 0.0253759159195,
#    'price': 6.96607,
#    'updated': True,
#    'vol_24h': 428073.0},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/BTC',
#    'perc_volume': 0.0241810800825,
#    'price': 52.841,
#    'updated': True,
#    'vol_24h': 407917.0},
#   {'currency': 'Gifto',
#    'pair': 'GTO/ETH',
#    'perc_volume': 0.0238885954615,
#    'price': 0.335673,
#    'updated': True,
#    'vol_24h': 402983.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/ETH',
#    'perc_volume': 0.0236470318558,
#    'price': 0.17704,
#    'updated': True,
#    'vol_24h': 398908.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/BTC',
#    'perc_volume': 0.0229086474945,
#    'price': 0.00457685,
#    'updated': True,
#    'vol_24h': 386452.0},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/USDT',
#    'perc_volume': 0.0227866504637,
#    'price': 6.41015,
#    'updated': True,
#    'vol_24h': 384394.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/BTC',
#    'perc_volume': 0.0226536867417,
#    'price': 0.115889,
#    'updated': True,
#    'vol_24h': 382151.0},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/BTC',
#    'perc_volume': 0.0223084434436,
#    'price': 0.0374784,
#    'updated': True,
#    'vol_24h': 376327.0},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/BTC',
#    'perc_volume': 0.0220313121905,
#    'price': 6.40751,
#    'updated': True,
#    'vol_24h': 371652.0},
#   {'currency': 'Datum',
#    'pair': 'DAT/BTC',
#    'perc_volume': 0.0218941396301,
#    'price': 0.0518134,
#    'updated': True,
#    'vol_24h': 369338.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/USDT',
#    'perc_volume': 0.0197786352385,
#    'price': 0.0454018,
#    'updated': True,
#    'vol_24h': 333651.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/USDT',
#    'perc_volume': 0.0196478055753,
#    'price': 0.171907,
#    'updated': True,
#    'vol_24h': 331444.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/USDT',
#    'perc_volume': 0.0191997124967,
#    'price': 0.325313,
#    'updated': True,
#    'vol_24h': 323885.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/BTC',
#    'perc_volume': 0.0186340683432,
#    'price': 0.172711,
#    'updated': True,
#    'vol_24h': 314343.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/ETH',
#    'perc_volume': 0.0184185283996,
#    'price': 8.3204,
#    'updated': True,
#    'vol_24h': 310707.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/ETH',
#    'perc_volume': 0.0178843616142,
#    'price': 0.364942,
#    'updated': True,
#    'vol_24h': 301696.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/BTC',
#    'perc_volume': 0.0174967928157,
#    'price': 0.0455095,
#    'updated': True,
#    'vol_24h': 295158.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/ETH',
#    'perc_volume': 0.0164598180539,
#    'price': 0.0808125,
#    'updated': True,
#    'vol_24h': 277665.0},
#   {'currency': 'BitcoinX',
#    'pair': 'BCX/BTC',
#    'perc_volume': 0.0156568191331,
#    'price': 0.00967184,
#    'updated': True,
#    'vol_24h': 264119.0},
#   {'currency': 'Loopring',
#    'pair': 'LRC/USDT',
#    'perc_volume': 0.0153238466734,
#    'price': 0.648025,
#    'updated': True,
#    'vol_24h': 258502.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/ETH',
#    'perc_volume': 0.0150961544502,
#    'price': 0.113914,
#    'updated': True,
#    'vol_24h': 254661.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/ETH',
#    'perc_volume': 0.0149653840664,
#    'price': 1.18987,
#    'updated': True,
#    'vol_24h': 252455.0},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/BTC',
#    'perc_volume': 0.0146335379156,
#    'price': 457.685,
#    'updated': True,
#    'vol_24h': 246857.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/USDT',
#    'perc_volume': 0.0144133741778,
#    'price': 0.116505,
#    'updated': True,
#    'vol_24h': 243143.0},
#   {'currency': 'Loopring',
#    'pair': 'LRC/BTC',
#    'perc_volume': 0.0139060016868,
#    'price': 0.6462,
#    'updated': True,
#    'vol_24h': 234584.0},
#   {'currency': 'Dash',
#    'pair': 'DASH/USDT',
#    'perc_volume': 0.013785012406,
#    'price': 611.371,
#    'updated': True,
#    'vol_24h': 232543.0},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/ETH',
#    'perc_volume': 0.0134561895052,
#    'price': 0.0959531,
#    'updated': True,
#    'vol_24h': 226996.0},
#   {'currency': 'Datum',
#    'pair': 'DAT/USDT',
#    'perc_volume': 0.0133435586216,
#    'price': 0.052002,
#    'updated': True,
#    'vol_24h': 225096.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/ETH',
#    'perc_volume': 0.0132697557531,
#    'price': 0.327348,
#    'updated': True,
#    'vol_24h': 223851.0},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/BTC',
#    'perc_volume': 0.0129356569846,
#    'price': 0.0154577,
#    'updated': True,
#    'vol_24h': 218215.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/USDT',
#    'perc_volume': 0.0127671256151,
#    'price': 0.391515,
#    'updated': True,
#    'vol_24h': 215372.0},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/BTC',
#    'perc_volume': 0.012728593997,
#    'price': 2.79274,
#    'updated': True,
#    'vol_24h': 214722.0},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/USDT',
#    'perc_volume': 0.0114527232031,
#    'price': 0.100004,
#    'updated': True,
#    'vol_24h': 193199.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/USDT',
#    'perc_volume': 0.0111701975235,
#    'price': 0.112404,
#    'updated': True,
#    'vol_24h': 188433.0},
#   {'currency': 'Status',
#    'pair': 'SNT/BTC',
#    'perc_volume': 0.0108735040642,
#    'price': 0.210708,
#    'updated': True,
#    'vol_24h': 183428.0},
#   {'currency': 'Dent',
#    'pair': 'DENT/BTC',
#    'perc_volume': 0.0106430849881,
#    'price': 0.0238342,
#    'updated': True,
#    'vol_24h': 179541.0},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/USDT',
#    'perc_volume': 0.0104973169129,
#    'price': 12.3794,
#    'updated': True,
#    'vol_24h': 177082.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/USDT',
#    'perc_volume': 0.0101256942764,
#    'price': 0.0800031,
#    'updated': True,
#    'vol_24h': 170813.0},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/USDT',
#    'perc_volume': 0.00990867234743,
#    'price': 0.0567022,
#    'updated': True,
#    'vol_24h': 167152.0},
#   {'currency': 'ugChain',
#    'pair': 'UGC/USDT',
#    'perc_volume': 0.00985028212618,
#    'price': 0.0824032,
#    'updated': True,
#    'vol_24h': 166167.0},
#   {'currency': 'Monero',
#    'pair': 'XMR/USDT',
#    'perc_volume': 0.00978531189015,
#    'price': 245.609,
#    'updated': True,
#    'vol_24h': 165071.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/BCH',
#    'perc_volume': 0.00976735022818,
#    'price': 9.12922,
#    'updated': True,
#    'vol_24h': 164768.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/ETH',
#    'perc_volume': 0.00974778802208,
#    'price': 158.993,
#    'updated': True,
#    'vol_24h': 164438.0},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/ETH',
#    'perc_volume': 0.00971779263938,
#    'price': 0.178412,
#    'updated': True,
#    'vol_24h': 163932.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/BCH',
#    'perc_volume': 0.00948950762209,
#    'price': 28.6233,
#    'updated': True,
#    'vol_24h': 160081.0},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/BTC',
#    'perc_volume': 0.00920259526591,
#    'price': 0.08981,
#    'updated': True,
#    'vol_24h': 155241.0},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/BTC',
#    'perc_volume': 0.00905161060243,
#    'price': 0.111485,
#    'updated': True,
#    'vol_24h': 152694.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/USDT',
#    'perc_volume': 0.00893625286583,
#    'price': 0.174007,
#    'updated': True,
#    'vol_24h': 150748.0},
#   {'currency': 'Ace',
#    'pair': 'ACE/BTC',
#    'perc_volume': 0.00883684129118,
#    'price': 0.363817,
#    'updated': True,
#    'vol_24h': 149071.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/BTC',
#    'perc_volume': 0.00872859708407,
#    'price': 0.0791882,
#    'updated': True,
#    'vol_24h': 147245.0},
#   {'currency': 'Health Mutual Society',
#    'pair': 'HMC/BTC',
#    'perc_volume': 0.00862882983294,
#    'price': 0.0722797,
#    'updated': True,
#    'vol_24h': 145562.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/ETH',
#    'perc_volume': 0.00860701500917,
#    'price': 0.120036,
#    'updated': True,
#    'vol_24h': 145194.0},
#   {'currency': 'Gifto',
#    'pair': 'GTO/USDT',
#    'perc_volume': 0.00860416959737,
#    'price': 0.354114,
#    'updated': True,
#    'vol_24h': 145146.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/ETH',
#    'perc_volume': 0.00849586611085,
#    'price': 1.02898,
#    'updated': True,
#    'vol_24h': 143319.0},
#   {'currency': 'Primas',
#    'pair': 'PST/USDT',
#    'perc_volume': 0.00842099621294,
#    'price': 0.320112,
#    'updated': True,
#    'vol_24h': 142056.0},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/BTC',
#    'perc_volume': 0.00805067772346,
#    'price': 12.2711,
#    'updated': True,
#    'vol_24h': 135809.0},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/BTC',
#    'perc_volume': 0.00801101979654,
#    'price': 0.0734024,
#    'updated': True,
#    'vol_24h': 135140.0},
#   {'currency': 'Yee',
#    'pair': 'YEE/USDT',
#    'perc_volume': 0.0079655524872,
#    'price': 0.0240009,
#    'updated': True,
#    'vol_24h': 134373.0},
#   {'currency': 'Nuls',
#    'pair': 'NULS/BTC',
#    'perc_volume': 0.00768356032225,
#    'price': 2.42357,
#    'updated': True,
#    'vol_24h': 129616.0},
#   {'currency': 'Read',
#    'pair': 'READ/USDT',
#    'perc_volume': 0.00754443154126,
#    'price': 0.0355014,
#    'updated': True,
#    'vol_24h': 127269.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/ETH',
#    'perc_volume': 0.00735983545094,
#    'price': 0.117515,
#    'updated': True,
#    'vol_24h': 124155.0},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/USDT',
#    'perc_volume': 0.00731164128863,
#    'price': 114.03,
#    'updated': True,
#    'vol_24h': 123342.0},
#   {'currency': 'SmartMesh',
#    'pair': 'SMT/BTC',
#    'perc_volume': 0.00718199721363,
#    'price': 0.0626943,
#    'updated': True,
#    'vol_24h': 121155.0},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/BTC',
#    'perc_volume': 0.00708211140367,
#    'price': 0.515889,
#    'updated': True,
#    'vol_24h': 119470.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/ETH',
#    'perc_volume': 0.00689745603394,
#    'price': 0.380392,
#    'updated': True,
#    'vol_24h': 116355.0},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/USDT',
#    'perc_volume': 0.00683058885671,
#    'price': 0.0907035,
#    'updated': True,
#    'vol_24h': 115227.0},
#   {'currency': 'Status',
#    'pair': 'SNT/USDT',
#    'perc_volume': 0.00678701848857,
#    'price': 0.212108,
#    'updated': True,
#    'vol_24h': 114492.0},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/ETH',
#    'perc_volume': 0.00675595607645,
#    'price': 0.491862,
#    'updated': True,
#    'vol_24h': 113968.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/ETH',
#    'perc_volume': 0.00662156964846,
#    'price': 1.24964,
#    'updated': True,
#    'vol_24h': 111701.0},
#   {'currency': 'Dash',
#    'pair': 'DASH/BTC',
#    'perc_volume': 0.00650390001478,
#    'price': 613.865,
#    'updated': True,
#    'vol_24h': 109716.0},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/USDT',
#    'perc_volume': 0.00649044358816,
#    'price': 2.77051,
#    'updated': True,
#    'vol_24h': 109489.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/ETH',
#    'perc_volume': 0.00649026574992,
#    'price': 0.170833,
#    'updated': True,
#    'vol_24h': 109486.0},
#   {'currency': 'Monero',
#    'pair': 'XMR/BTC',
#    'perc_volume': 0.00645944045545,
#    'price': 246.083,
#    'updated': True,
#    'vol_24h': 108966.0},
#   {'currency': 'Dent',
#    'pair': 'DENT/USDT',
#    'perc_volume': 0.00645582441129,
#    'price': 0.0239009,
#    'updated': True,
#    'vol_24h': 108905.0},
#   {'currency': 'Datum',
#    'pair': 'DAT/ETH',
#    'perc_volume': 0.00641456594024,
#    'price': 0.0515602,
#    'updated': True,
#    'vol_24h': 108209.0},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/BTC',
#    'perc_volume': 0.0063457425424,
#    'price': 6.95207,
#    'updated': True,
#    'vol_24h': 107048.0},
#   {'currency': 'Viuly',
#    'pair': 'VIU/USDT',
#    'perc_volume': 0.00615960518735,
#    'price': 0.0220009,
#    'updated': True,
#    'vol_24h': 103908.0},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/USDT',
#    'perc_volume': 0.00615913095205,
#    'price': 0.0687027,
#    'updated': True,
#    'vol_24h': 103900.0},
#   {'currency': 'Gas',
#    'pair': 'GAS/BTC',
#    'perc_volume': 0.00609054467187,
#    'price': 39.4271,
#    'updated': True,
#    'vol_24h': 102743.0},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/USDT',
#    'perc_volume': 0.00605426567145,
#    'price': 53.3006,
#    'updated': True,
#    'vol_24h': 102131.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/ETH',
#    'perc_volume': 0.00604466240664,
#    'price': 0.00518689,
#    'updated': True,
#    'vol_24h': 101969.0},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/USDT',
#    'perc_volume': 0.00596327177337,
#    'price': 2.34479,
#    'updated': True,
#    'vol_24h': 100596.0},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/BTC',
#    'perc_volume': 0.00594240542019,
#    'price': 0.0972366,
#    'updated': True,
#    'vol_24h': 100244.0},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/ETH',
#    'perc_volume': 0.00593825586132,
#    'price': 0.428171,
#    'updated': True,
#    'vol_24h': 100174.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/USDT',
#    'perc_volume': 0.00590813006392,
#    'price': 4.19826,
#    'updated': True,
#    'vol_24h': 99665.8},
#   {'currency': 'SmartMesh',
#    'pair': 'SMT/USDT',
#    'perc_volume': 0.00588856785781,
#    'price': 0.0641025,
#    'updated': True,
#    'vol_24h': 99335.8},
#   {'currency': 'ICON',
#    'pair': 'ICX/ETH',
#    'perc_volume': 0.00584803259559,
#    'price': 4.16266,
#    'updated': True,
#    'vol_24h': 98652.0},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/ETH',
#    'perc_volume': 0.00573448880901,
#    'price': 0.0686812,
#    'updated': True,
#    'vol_24h': 96736.6},
#   {'currency': 'TenX',
#    'pair': 'PAY/USDT',
#    'perc_volume': 0.00570793163224,
#    'price': 1.89807,
#    'updated': True,
#    'vol_24h': 96288.6},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/ETH',
#    'perc_volume': 0.0056345377917,
#    'price': 0.03816,
#    'updated': True,
#    'vol_24h': 95050.5},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/BTC',
#    'perc_volume': 0.00560827108405,
#    'price': 234.888,
#    'updated': True,
#    'vol_24h': 94607.4},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/BTC',
#    'perc_volume': 0.00555638381435,
#    'price': 0.384197,
#    'updated': True,
#    'vol_24h': 93732.1},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/BTC',
#    'perc_volume': 0.00532592324262,
#    'price': 0.422625,
#    'updated': True,
#    'vol_24h': 89844.4},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/BTC',
#    'perc_volume': 0.00517813373948,
#    'price': 0.334974,
#    'updated': True,
#    'vol_24h': 87351.3},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/USDT',
#    'perc_volume': 0.00513697011549,
#    'price': 455.944,
#    'updated': True,
#    'vol_24h': 86656.9},
#   {'currency': 'Yee',
#    'pair': 'YEE/BTC',
#    'perc_volume': 0.00512408277122,
#    'price': 0.0240069,
#    'updated': True,
#    'vol_24h': 86439.5},
#   {'currency': 'Enigma',
#    'pair': 'ENG/USDT',
#    'perc_volume': 0.00504094932322,
#    'price': 3.24593,
#    'updated': True,
#    'vol_24h': 85037.1},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/USDT',
#    'perc_volume': 0.00476329641126,
#    'price': 0.0360014,
#    'updated': True,
#    'vol_24h': 80353.3},
#   {'currency': 'ProChain',
#    'pair': 'PRA/BTC',
#    'perc_volume': 0.00471705254162,
#    'price': 0.350518,
#    'updated': True,
#    'vol_24h': 79573.2},
#   {'currency': 'RefToken',
#    'pair': 'REF/BTC',
#    'perc_volume': 0.0045126511996,
#    'price': 26.3626,
#    'updated': True,
#    'vol_24h': 76125.1},
#   {'currency': 'Maker',
#    'pair': 'MKR/BTC',
#    'perc_volume': 0.00441325740877,
#    'price': 1032.33,
#    'updated': True,
#    'vol_24h': 74448.4},
#   {'currency': 'Read',
#    'pair': 'READ/BTC',
#    'perc_volume': 0.00438065373193,
#    'price': 0.035924,
#    'updated': True,
#    'vol_24h': 73898.4},
#   {'currency': 'Hshare',
#    'pair': 'HSR/ETH',
#    'perc_volume': 0.00432681024161,
#    'price': 11.8997,
#    'updated': True,
#    'vol_24h': 72990.1},
#   {'currency': 'ugChain',
#    'pair': 'UGC/ETH',
#    'perc_volume': 0.00431406516794,
#    'price': 0.0805468,
#    'updated': True,
#    'vol_24h': 72775.1},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/USDT',
#    'perc_volume': 0.00430817872228,
#    'price': 0.0747029,
#    'updated': True,
#    'vol_24h': 72675.8},
#   {'currency': 'NEM',
#    'pair': 'XEM/USDT',
#    'perc_volume': 0.00424348117155,
#    'price': 0.51652,
#    'updated': True,
#    'vol_24h': 71584.4},
#   {'currency': 'ProChain',
#    'pair': 'PRA/USDT',
#    'perc_volume': 0.00413007965556,
#    'price': 0.360714,
#    'updated': True,
#    'vol_24h': 69671.4},
#   {'currency': 'Populous',
#    'pair': 'PPT/BTC',
#    'perc_volume': 0.00406659140484,
#    'price': 27.8011,
#    'updated': True,
#    'vol_24h': 68600.4},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/USDT',
#    'perc_volume': 0.00403791795305,
#    'price': 0.0149006,
#    'updated': True,
#    'vol_24h': 68116.7},
#   {'currency': 'Viuly',
#    'pair': 'VIU/BTC',
#    'perc_volume': 0.00392964410623,
#    'price': 0.023057,
#    'updated': True,
#    'vol_24h': 66290.2},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/BTC',
#    'perc_volume': 0.00383726899784,
#    'price': 0.446373,
#    'updated': True,
#    'vol_24h': 64731.9},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/ETH',
#    'perc_volume': 0.00371135359788,
#    'price': 0.123722,
#    'updated': True,
#    'vol_24h': 62607.8},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/ETH',
#    'perc_volume': 0.0037023727669,
#    'price': 0.341434,
#    'updated': True,
#    'vol_24h': 62456.3},
#   {'currency': 'Po.et',
#    'pair': 'POE/USDT',
#    'perc_volume': 0.00366357439146,
#    'price': 0.0687027,
#    'updated': True,
#    'vol_24h': 61801.8},
#   {'currency': 'Po.et',
#    'pair': 'POE/BTC',
#    'perc_volume': 0.00362918640431,
#    'price': 0.0657167,
#    'updated': True,
#    'vol_24h': 61221.7},
#   {'currency': 'Gifto',
#    'pair': 'GTO/BTC',
#    'perc_volume': 0.00356430508739,
#    'price': 0.386615,
#    'updated': True,
#    'vol_24h': 60127.2},
#   {'currency': 'Populous',
#    'pair': 'PPT/USDT',
#    'perc_volume': 0.00352241232663,
#    'price': 28.5011,
#    'updated': True,
#    'vol_24h': 59420.5},
#   {'currency': 'UTRUST',
#    'pair': 'UTK/BTC',
#    'perc_volume': 0.003482623985,
#    'price': 0.267875,
#    'updated': True,
#    'vol_24h': 58749.3},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/BTC',
#    'perc_volume': 0.00347032350692,
#    'price': 1.07098,
#    'updated': True,
#    'vol_24h': 58541.8},
#   {'currency': 'Walton',
#    'pair': 'WTC/ETH',
#    'perc_volume': 0.00341182065479,
#    'price': 21.8291,
#    'updated': True,
#    'vol_24h': 57554.9},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/ETH',
#    'perc_volume': 0.00329895858145,
#    'price': 6.99668,
#    'updated': True,
#    'vol_24h': 55651.0},
#   {'currency': 'Yee',
#    'pair': 'YEE/ETH',
#    'perc_volume': 0.00322002211585,
#    'price': 0.0240226,
#    'updated': True,
#    'vol_24h': 54319.4},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/BTC',
#    'perc_volume': 0.00321133768193,
#    'price': 0.115458,
#    'updated': True,
#    'vol_24h': 54172.9},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/ETH',
#    'perc_volume': 0.00319938695238,
#    'price': 51.7917,
#    'updated': True,
#    'vol_24h': 53971.3},
#   {'currency': 'FunFair',
#    'pair': 'FUN/BTC',
#    'perc_volume': 0.00305556916987,
#    'price': 0.0535406,
#    'updated': True,
#    'vol_24h': 51545.2},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/BTC',
#    'perc_volume': 0.00300863765905,
#    'price': 0.0350604,
#    'updated': True,
#    'vol_24h': 50753.5},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/USDT',
#    'perc_volume': 0.00300080684866,
#    'price': 0.0361014,
#    'updated': True,
#    'vol_24h': 50621.4},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/USDT',
#    'perc_volume': 0.0029979377251,
#    'price': 0.341713,
#    'updated': True,
#    'vol_24h': 50573.0},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/USDT',
#    'perc_volume': 0.00291874635803,
#    'price': 236.262,
#    'updated': True,
#    'vol_24h': 49237.1},
#   {'currency': '0x',
#    'pair': 'ZRX/BTC',
#    'perc_volume': 0.00290809977556,
#    'price': 1.0285,
#    'updated': True,
#    'vol_24h': 49057.5},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/USDT',
#    'perc_volume': 0.0029017094549,
#    'price': 0.0723028,
#    'updated': True,
#    'vol_24h': 48949.7},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/BCH',
#    'perc_volume': 0.00284724945869,
#    'price': 160.487,
#    'updated': True,
#    'vol_24h': 48031.0},
#   {'currency': 'RefToken',
#    'pair': 'REF/USDT',
#    'perc_volume': 0.00280704616118,
#    'price': 28.3208,
#    'updated': True,
#    'vol_24h': 47352.8},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/USDT',
#    'perc_volume': 0.00280545154498,
#    'price': 0.111704,
#    'updated': True,
#    'vol_24h': 47325.9},
#   {'currency': 'TRON',
#    'pair': 'TRX/ETH',
#    'perc_volume': 0.00277951680204,
#    'price': 0.0454474,
#    'updated': True,
#    'vol_24h': 46888.4},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/USDT',
#    'perc_volume': 0.0027294494103,
#    'price': 0.378015,
#    'updated': True,
#    'vol_24h': 46043.8},
#   {'currency': '0x',
#    'pair': 'ZRX/USDT',
#    'perc_volume': 0.00270784206447,
#    'price': 1.05284,
#    'updated': True,
#    'vol_24h': 45679.3},
#   {'currency': 'UTRUST',
#    'pair': 'UTK/USDT',
#    'perc_volume': 0.00268859403925,
#    'price': 0.274711,
#    'updated': True,
#    'vol_24h': 45354.6},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/ETH',
#    'perc_volume': 0.00263048243124,
#    'price': 0.0320387,
#    'updated': True,
#    'vol_24h': 44374.3},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/ETH',
#    'perc_volume': 0.00262197583555,
#    'price': 0.090329,
#    'updated': True,
#    'vol_24h': 44230.8},
#   {'currency': 'NAGA',
#    'pair': 'NGC/BTC',
#    'perc_volume': 0.00259097863079,
#    'price': 0.911571,
#    'updated': True,
#    'vol_24h': 43707.9},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/BTC',
#    'perc_volume': 0.00256855322907,
#    'price': 0.0735751,
#    'updated': True,
#    'vol_24h': 43329.6},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/ETH',
#    'perc_volume': 0.00256096546428,
#    'price': 0.112328,
#    'updated': True,
#    'vol_24h': 43201.6},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/BTC',
#    'perc_volume': 0.00246420367936,
#    'price': 0.178929,
#    'updated': True,
#    'vol_24h': 41569.3},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/USDT',
#    'perc_volume': 0.00243985762467,
#    'price': 0.740029,
#    'updated': True,
#    'vol_24h': 41158.6},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/ETH',
#    'perc_volume': 0.00232703111898,
#    'price': 456.168,
#    'updated': True,
#    'vol_24h': 39255.3},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/BTC',
#    'perc_volume': 0.00232005393214,
#    'price': 0.710103,
#    'updated': True,
#    'vol_24h': 39137.6},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/BTC',
#    'perc_volume': 0.0022691388448,
#    'price': 37.3421,
#    'updated': True,
#    'vol_24h': 38278.7},
#   {'currency': 'Walton',
#    'pair': 'WTC/BTC',
#    'perc_volume': 0.00223574082383,
#    'price': 21.645,
#    'updated': True,
#    'vol_24h': 37715.3},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/BTC',
#    'perc_volume': 0.00217855397465,
#    'price': 0.0282383,
#    'updated': True,
#    'vol_24h': 36750.6},
#   {'currency': 'district0x',
#    'pair': 'DNT/BTC',
#    'perc_volume': 0.00217165977899,
#    'price': 0.086183,
#    'updated': True,
#    'vol_24h': 36634.3},
#   {'currency': 'ProChain',
#    'pair': 'PRA/ETH',
#    'perc_volume': 0.00208699692215,
#    'price': 0.360167,
#    'updated': True,
#    'vol_24h': 35206.1},
#   {'currency': 'LAToken',
#    'pair': 'LA/USDT',
#    'perc_volume': 0.00206812828517,
#    'price': 0.388615,
#    'updated': True,
#    'vol_24h': 34887.8},
#   {'currency': 'RefToken',
#    'pair': 'REF/ETH',
#    'perc_volume': 0.00206729244545,
#    'price': 26.5774,
#    'updated': True,
#    'vol_24h': 34873.7},
#   {'currency': 'OAX',
#    'pair': 'OAX/BTC',
#    'perc_volume': 0.00206556148661,
#    'price': 0.934887,
#    'updated': True,
#    'vol_24h': 34844.5},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/USDT',
#    'perc_volume': 0.00206426919542,
#    'price': 0.182207,
#    'updated': True,
#    'vol_24h': 34822.7},
#   {'currency': 'QunQun',
#    'pair': 'QUN/BTC',
#    'perc_volume': 0.00202229344347,
#    'price': 0.0687392,
#    'updated': True,
#    'vol_24h': 34114.6},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/ETH',
#    'perc_volume': 0.00200125518,
#    'price': 0.0738595,
#    'updated': True,
#    'vol_24h': 33759.7},
#   {'currency': 'Metal',
#    'pair': 'MTL/BTC',
#    'perc_volume': 0.00197473357088,
#    'price': 3.6658,
#    'updated': True,
#    'vol_24h': 33312.3},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/ETH',
#    'perc_volume': 0.00194742947351,
#    'price': 0.0157064,
#    'updated': True,
#    'vol_24h': 32851.7},
#   {'currency': 'Leverj',
#    'pair': 'LEV/BTC',
#    'perc_volume': 0.00193394340718,
#    'price': 0.10285,
#    'updated': True,
#    'vol_24h': 32624.2},
#   {'currency': 'Enigma',
#    'pair': 'ENG/ETH',
#    'perc_volume': 0.00192074780997,
#    'price': 3.24239,
#    'updated': True,
#    'vol_24h': 32401.6},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/BTC',
#    'perc_volume': 0.00186242279608,
#    'price': 0.0507772,
#    'updated': True,
#    'vol_24h': 31417.7},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/USDT',
#    'perc_volume': 0.00184406988999,
#    'price': 0.0844033,
#    'updated': True,
#    'vol_24h': 31108.1},
#   {'currency': 'Maker',
#    'pair': 'MKR/ETH',
#    'perc_volume': 0.00183072609425,
#    'price': 1058.54,
#    'updated': True,
#    'vol_24h': 30883.0},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/USDT',
#    'perc_volume': 0.00180546713661,
#    'price': 0.51872,
#    'updated': True,
#    'vol_24h': 30456.9},
#   {'currency': 'NAGA',
#    'pair': 'NGC/USDT',
#    'perc_volume': 0.00178344483489,
#    'price': 0.930136,
#    'updated': True,
#    'vol_24h': 30085.4},
#   {'currency': 'Nuls',
#    'pair': 'NULS/USDT',
#    'perc_volume': 0.00175165921394,
#    'price': 2.42929,
#    'updated': True,
#    'vol_24h': 29549.2},
#   {'currency': 'SunContract',
#    'pair': 'SNC/ETH',
#    'perc_volume': 0.0017202055577,
#    'price': 0.26057,
#    'updated': True,
#    'vol_24h': 29018.6},
#   {'currency': 'Dash',
#    'pair': 'DASH/ETH',
#    'perc_volume': 0.00171359590322,
#    'price': 611.211,
#    'updated': True,
#    'vol_24h': 28907.1},
#   {'currency': 'Centra',
#    'pair': 'CTR/BTC',
#    'perc_volume': 0.00170437202664,
#    'price': 0.908808,
#    'updated': True,
#    'vol_24h': 28751.5},
#   {'currency': 'Nano',
#    'pair': 'NANO/BTC',
#    'perc_volume': 0.00168522477642,
#    'price': 9.59507,
#    'updated': True,
#    'vol_24h': 28428.5},
#   {'currency': 'Enigma',
#    'pair': 'ENG/BTC',
#    'perc_volume': 0.00165675880257,
#    'price': 3.15432,
#    'updated': True,
#    'vol_24h': 27948.3},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/USDT',
#    'perc_volume': 0.00163776567883,
#    'price': 0.0811032,
#    'updated': True,
#    'vol_24h': 27627.9},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/BTC',
#    'perc_volume': 0.00158150951643,
#    'price': 0.42133,
#    'updated': True,
#    'vol_24h': 26678.9},
#   {'currency': 'Ark',
#    'pair': 'ARK/USDT',
#    'perc_volume': 0.00157955922376,
#    'price': 4.00436,
#    'updated': True,
#    'vol_24h': 26646.0},
#   {'currency': 'AirSwap',
#    'pair': 'AST/BTC',
#    'perc_volume': 0.00157129567366,
#    'price': 0.617616,
#    'updated': True,
#    'vol_24h': 26506.6},
#   {'currency': 'Aventus',
#    'pair': 'AVT/BTC',
#    'perc_volume': 0.00153748862475,
#    'price': 2.22193,
#    'updated': True,
#    'vol_24h': 25936.3},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/BTC',
#    'perc_volume': 0.00153585251297,
#    'price': 0.713298,
#    'updated': True,
#    'vol_24h': 25908.7},
#   {'currency': 'TenX',
#    'pair': 'PAY/BTC',
#    'perc_volume': 0.00150426251408,
#    'price': 1.88256,
#    'updated': True,
#    'vol_24h': 25375.8},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/BTC',
#    'perc_volume': 0.00147571354905,
#    'price': 0.315112,
#    'updated': True,
#    'vol_24h': 24894.2},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/USDT',
#    'perc_volume': 0.00144698081785,
#    'price': 0.0283011,
#    'updated': True,
#    'vol_24h': 24409.5},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/USDT',
#    'perc_volume': 0.00141447198807,
#    'price': 0.116005,
#    'updated': True,
#    'vol_24h': 23861.1},
#   {'currency': 'Golem',
#    'pair': 'GNT/USDT',
#    'perc_volume': 0.00141313227334,
#    'price': 0.362514,
#    'updated': True,
#    'vol_24h': 23838.5},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/ETH',
#    'perc_volume': 0.00137521123321,
#    'price': 2.31338,
#    'updated': True,
#    'vol_24h': 23198.8},
#   {'currency': 'Ark',
#    'pair': 'ARK/BTC',
#    'perc_volume': 0.00136509223751,
#    'price': 3.96364,
#    'updated': True,
#    'vol_24h': 23028.1},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/USDT',
#    'perc_volume': 0.00135457606974,
#    'price': 0.745129,
#    'updated': True,
#    'vol_24h': 22850.7},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/BTC',
#    'perc_volume': 0.00134622952847,
#    'price': 0.151468,
#    'updated': True,
#    'vol_24h': 22709.9},
#   {'currency': 'Golem',
#    'pair': 'GNT/BTC',
#    'perc_volume': 0.00134305215196,
#    'price': 0.360708,
#    'updated': True,
#    'vol_24h': 22656.3},
#   {'currency': 'Request Network',
#    'pair': 'REQ/BTC',
#    'perc_volume': 0.00131591996489,
#    'price': 0.285319,
#    'updated': True,
#    'vol_24h': 22198.6},
#   {'currency': 'Substratum',
#    'pair': 'SUB/BTC',
#    'perc_volume': 0.00129175174844,
#    'price': 0.707944,
#    'updated': True,
#    'vol_24h': 21790.9},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/USDT',
#    'perc_volume': 0.00128786894693,
#    'price': 0.322013,
#    'updated': True,
#    'vol_24h': 21725.4},
#   {'currency': 'Health Mutual Society',
#    'pair': 'HMC/USDT',
#    'perc_volume': 0.00127121735997,
#    'price': 0.0723028,
#    'updated': True,
#    'vol_24h': 21444.5},
#   {'currency': 'Viberate',
#    'pair': 'VIB/USDT',
#    'perc_volume': 0.0012385366199,
#    'price': 0.26031,
#    'updated': True,
#    'vol_24h': 20893.2},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/BTC',
#    'perc_volume': 0.00123764150077,
#    'price': 0.0835923,
#    'updated': True,
#    'vol_24h': 20878.1},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/BTC',
#    'perc_volume': 0.00117583678537,
#    'price': 0.186615,
#    'updated': True,
#    'vol_24h': 19835.5},
#   {'currency': 'Ace',
#    'pair': 'ACE/USDT',
#    'perc_volume': 0.00117479346771,
#    'price': 0.357814,
#    'updated': True,
#    'vol_24h': 19817.9},
#   {'currency': 'BitcoinX',
#    'pair': 'BCX/BCH',
#    'perc_volume': 0.0011545554763,
#    'price': 0.00970005,
#    'updated': True,
#    'vol_24h': 19476.5},
#   {'currency': 'Monaco',
#    'pair': 'MCO/USDT',
#    'perc_volume': 0.00114475066148,
#    'price': 7.52209,
#    'updated': True,
#    'vol_24h': 19311.1},
#   {'currency': 'FunFair',
#    'pair': 'FUN/USDT',
#    'perc_volume': 0.00113008493485,
#    'price': 0.0541021,
#    'updated': True,
#    'vol_24h': 19063.7},
#   {'currency': 'Populous',
#    'pair': 'PPT/ETH',
#    'perc_volume': 0.0011139372229,
#    'price': 27.7777,
#    'updated': True,
#    'vol_24h': 18791.3},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/ETH',
#    'perc_volume': 0.00110259114336,
#    'price': 2.73427,
#    'updated': True,
#    'vol_24h': 18599.9},
#   {'currency': 'OAX',
#    'pair': 'OAX/USDT',
#    'perc_volume': 0.00109110872117,
#    'price': 0.863834,
#    'updated': True,
#    'vol_24h': 18406.2},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/BTC',
#    'perc_volume': 0.00107855926956,
#    'price': 2.10406,
#    'updated': True,
#    'vol_24h': 18194.5},
#   {'currency': 'Request Network',
#    'pair': 'REQ/USDT',
#    'perc_volume': 0.0010763659313,
#    'price': 0.288811,
#    'updated': True,
#    'vol_24h': 18157.5},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/BCH',
#    'perc_volume': 0.0010698985474,
#    'price': 6.5244,
#    'updated': True,
#    'vol_24h': 18048.4},
#   {'currency': 'district0x',
#    'pair': 'DNT/ETH',
#    'perc_volume': 0.00106196103408,
#    'price': 0.0882628,
#    'updated': True,
#    'vol_24h': 17914.5},
#   {'currency': 'IPChain',
#    'pair': 'IPC/BTC',
#    'perc_volume': 0.00105691635608,
#    'price': 0.708549,
#    'updated': True,
#    'vol_24h': 17829.4},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/BTC',
#    'perc_volume': 0.00105123738837,
#    'price': 0.0358376,
#    'updated': True,
#    'vol_24h': 17733.6},
#   {'currency': 'AirSwap',
#    'pair': 'AST/USDT',
#    'perc_volume': 0.00102476320277,
#    'price': 0.623224,
#    'updated': True,
#    'vol_24h': 17287.0},
#   {'currency': 'Status',
#    'pair': 'SNT/ETH',
#    'perc_volume': 0.00102294925275,
#    'price': 0.214334,
#    'updated': True,
#    'vol_24h': 17256.4},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/ETH',
#    'perc_volume': 0.00102270620716,
#    'price': 12.4286,
#    'updated': True,
#    'vol_24h': 17252.3},
#   {'currency': 'NEM',
#    'pair': 'XEM/ETH',
#    'perc_volume': 0.000990647900917,
#    'price': 0.514591,
#    'updated': True,
#    'vol_24h': 16711.5},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/BTC',
#    'perc_volume': 0.000987292686173,
#    'price': 1.27634,
#    'updated': True,
#    'vol_24h': 16654.9},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/USDT',
#    'perc_volume': 0.000979853119912,
#    'price': 33.7041,
#    'updated': True,
#    'vol_24h': 16529.4},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/ETH',
#    'perc_volume': 0.00097231277865,
#    'price': 0.699029,
#    'updated': True,
#    'vol_24h': 16402.2},
#   {'currency': 'Civic',
#    'pair': 'CVC/BTC',
#    'perc_volume': 0.000946099422471,
#    'price': 0.433247,
#    'updated': True,
#    'vol_24h': 15960.0},
#   {'currency': 'Civic',
#    'pair': 'CVC/ETH',
#    'perc_volume': 0.000921439186898,
#    'price': 0.435938,
#    'updated': True,
#    'vol_24h': 15544.0},
#   {'currency': 'Leverj',
#    'pair': 'LEV/USDT',
#    'perc_volume': 0.000900744744017,
#    'price': 0.102904,
#    'updated': True,
#    'vol_24h': 15194.9},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/BTC',
#    'perc_volume': 0.000884336202655,
#    'price': 0.52133,
#    'updated': True,
#    'vol_24h': 14918.1},
#   {'currency': 'Viuly',
#    'pair': 'VIU/ETH',
#    'perc_volume': 0.000873167961352,
#    'price': 0.0218449,
#    'updated': True,
#    'vol_24h': 14729.7},
#   {'currency': 'Bread',
#    'pair': 'BRD/BTC',
#    'perc_volume': 0.000848507725779,
#    'price': 0.851986,
#    'updated': True,
#    'vol_24h': 14313.7},
#   {'currency': 'QunQun',
#    'pair': 'QUN/ETH',
#    'perc_volume': 0.00084751183165,
#    'price': 0.0682783,
#    'updated': True,
#    'vol_24h': 14296.9},
#   {'currency': 'StarChain',
#    'pair': 'STC/BTC',
#    'perc_volume': 0.000829520529976,
#    'price': 0.111831,
#    'updated': True,
#    'vol_24h': 13993.4},
#   {'currency': 'Substratum',
#    'pair': 'SUB/USDT',
#    'perc_volume': 0.000827238272597,
#    'price': 0.718128,
#    'updated': True,
#    'vol_24h': 13954.9},
#   {'currency': 'Achain',
#    'pair': 'ACT/BCH',
#    'perc_volume': 0.000809401097395,
#    'price': 0.367932,
#    'updated': True,
#    'vol_24h': 13654.0},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/USDT',
#    'perc_volume': 0.000808025815026,
#    'price': 2.02248,
#    'updated': True,
#    'vol_24h': 13630.8},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/ETH',
#    'perc_volume': 0.000793632773687,
#    'price': 0.0804953,
#    'updated': True,
#    'vol_24h': 13388.0},
#   {'currency': 'Monetha',
#    'pair': 'MTH/USDT',
#    'perc_volume': 0.000793484575156,
#    'price': 0.151106,
#    'updated': True,
#    'vol_24h': 13385.5},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/ETH',
#    'perc_volume': 0.000791036335422,
#    'price': 0.0704988,
#    'updated': True,
#    'vol_24h': 13344.2},
#   {'currency': 'Nano',
#    'pair': 'NANO/USDT',
#    'perc_volume': 0.000786951983906,
#    'price': 9.87118,
#    'updated': True,
#    'vol_24h': 13275.3},
#   {'currency': 'Po.et',
#    'pair': 'POE/ETH',
#    'perc_volume': 0.000784171779462,
#    'price': 0.0653719,
#    'updated': True,
#    'vol_24h': 13228.4},
#   {'currency': 'Centra',
#    'pair': 'CTR/USDT',
#    'perc_volume': 0.000782298550029,
#    'price': 0.935636,
#    'updated': True,
#    'vol_24h': 13196.8},
#   {'currency': 'SunContract',
#    'pair': 'SNC/USDT',
#    'perc_volume': 0.000778546163222,
#    'price': 0.25481,
#    'updated': True,
#    'vol_24h': 13133.5},
# ...
#   {'currency': '0x',
#    'pair': 'ZRX/ETH',
#    'perc_volume': 0.000657011511847,
#    'price': 0.98586,
#    'updated': True,
#    'vol_24h': 11083.3},
#   {'currency': 'Maker',
#    'pair': 'MKR/USDT',
#    'perc_volume': 0.000648487132339,
#    'price': 1019.19,
#    'updated': True,
#    'vol_24h': 10939.5},
#   {'currency': 'Civic',
#    'pair': 'CVC/USDT',
#    'perc_volume': 0.000644361285233,
#    'price': 0.431617,
#    'updated': True,
#    'vol_24h': 10869.9},
#   {'currency': 'QunQun',
#    'pair': 'QUN/USDT',
#    'perc_volume': 0.000636400060143,
#    'price': 0.0698027,
#    'updated': True,
#    'vol_24h': 10735.6},
#   {'currency': 'Monetha',
#    'pair': 'MTH/BTC',
#    'perc_volume': 0.000613281089293,
#    'price': 0.154404,
#    'updated': True,
#    'vol_24h': 10345.6},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/USDT',
#    'perc_volume': 0.000595046742028,
#    'price': 1.29855,
#    'updated': True,
#    'vol_24h': 10038.0},
#   {'currency': 'Monaco',
#    'pair': 'MCO/BTC',
#    'perc_volume': 0.000587388434735,
#    'price': 7.44101,
#    'updated': True,
#    'vol_24h': 9908.81},
#   {'currency': 'Simple Token',
#    'pair': 'OST/USDT',
#    'perc_volume': 0.000585499199861,
#    'price': 0.299612,
#    'updated': True,
#    'vol_24h': 9876.94},
#   {'currency': 'OAX',
#    'pair': 'OAX/ETH',
#    'perc_volume': 0.000582110195852,
#    'price': 0.884343,
#    'updated': True,
#    'vol_24h': 9819.77},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/USDT',
#    'perc_volume': 0.000576940438294,
#    'price': 0.456718,
#    'updated': True,
#    'vol_24h': 9732.56},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/USDT',
#    'perc_volume': 0.000570598726751,
#    'price': 2.71631,
#    'updated': True,
#    'vol_24h': 9625.58},
#   {'currency': 'Leverj',
#    'pair': 'LEV/ETH',
#    'perc_volume': 0.000566775204649,
#    'price': 0.103995,
#    'updated': True,
#    'vol_24h': 9561.08},
#   {'currency': 'NAGA',
#    'pair': 'NGC/ETH',
#    'perc_volume': 0.000564479313006,
#    'price': 0.925923,
#    'updated': True,
#    'vol_24h': 9522.35},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/USDT',
#    'perc_volume': 0.000561786842093,
#    'price': 0.219909,
#    'updated': True,
#    'vol_24h': 9476.93},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/USDT',
#    'perc_volume': 0.000560787983993,
#    'price': 0.156306,
#    'updated': True,
#    'vol_24h': 9460.08},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/ETH',
#    'perc_volume': 0.00055890171309,
#    'price': 0.516091,
#    'updated': True,
#    'vol_24h': 9428.26},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/BTC',
#    'perc_volume': 0.000553432001704,
#    'price': 2.7278,
#    'updated': True,
#    'vol_24h': 9335.99},
#   {'currency': 'Bread',
#    'pair': 'BRD/USDT',
#    'perc_volume': 0.000549012128713,
#    'price': 0.861834,
#    'updated': True,
#    'vol_24h': 9261.43},
#   {'currency': 'AirSwap',
#    'pair': 'AST/ETH',
#    'perc_volume': 0.000482615037226,
#    'price': 0.618988,
#    'updated': True,
#    'vol_24h': 8141.36},
#   {'currency': 'Maggie',
#    'pair': 'MAG/USDT',
#    'perc_volume': 0.000472717746526,
#    'price': 0.0325013,
#    'updated': True,
#    'vol_24h': 7974.4},
#   {'currency': 'Loopring',
#    'pair': 'LRC/ETH',
#    'perc_volume': 0.000462135185818,
#    'price': 0.642599,
#    'updated': True,
#    'vol_24h': 7795.88},
#   {'currency': 'Revain',
#    'pair': 'R/USDT',
#    'perc_volume': 0.00045610884075,
#    'price': 2.6909,
#    'updated': True,
#    'vol_24h': 7694.22},
#   {'currency': 'SmartMesh',
#    'pair': 'SMT/ETH',
#    'perc_volume': 0.000438200530253,
#    'price': 0.065329,
#    'updated': True,
#    'vol_24h': 7392.12},
#   {'currency': 'Aventus',
#    'pair': 'AVT/ETH',
#    'perc_volume': 0.000425742368936,
#    'price': 2.25194,
#    'updated': True,
#    'vol_24h': 7181.96},
#   {'currency': 'Storj',
#    'pair': 'STORJ/USDT',
#    'perc_volume': 0.000401621576016,
#    'price': 1.01324,
#    'updated': True,
#    'vol_24h': 6775.06},
#   {'currency': 'SALT',
#    'pair': 'SALT/ETH',
#    'perc_volume': 0.00039789823612,
#    'price': 4.21705,
#    'updated': True,
#    'vol_24h': 6712.25},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/BTC',
#    'perc_volume': 0.00038495101965,
#    'price': 1.75242,
#    'updated': True,
#    'vol_24h': 6493.84},
#   {'currency': 'Simple Token',
#    'pair': 'OST/BTC',
#    'perc_volume': 0.000383199313013,
#    'price': 0.28506,
#    'updated': True,
#    'vol_24h': 6464.29},
#   {'currency': 'Centra',
#    'pair': 'CTR/ETH',
#    'perc_volume': 0.000376450944701,
#    'price': 0.91128,
#    'updated': True,
#    'vol_24h': 6350.45},
#   {'currency': 'Everex',
#    'pair': 'EVX/USDT',
#    'perc_volume': 0.00037641478426,
#    'price': 1.78297,
#    'updated': True,
#    'vol_24h': 6349.84},
#   {'currency': 'Walton',
#    'pair': 'WTC/USDT',
#    'perc_volume': 0.00037188880112,
#    'price': 21.8921,
#    'updated': True,
#    'vol_24h': 6273.49},
#   {'currency': 'Maggie',
#    'pair': 'MAG/BTC',
#    'perc_volume': 0.000369094962412,
#    'price': 0.0323834,
#    'updated': True,
#    'vol_24h': 6226.36},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/USDT',
#    'perc_volume': 0.000368269792991,
#    'price': 0.416116,
#    'updated': True,
#    'vol_24h': 6212.44},
#   {'currency': 'district0x',
#    'pair': 'DNT/USDT',
#    'perc_volume': 0.000357063612864,
#    'price': 0.0900035,
#    'updated': True,
#    'vol_24h': 6023.4},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/ETH',
#    'perc_volume': 0.000356191612707,
#    'price': 0.231481,
#    'updated': True,
#    'vol_24h': 6008.69},
#   {'currency': 'Read',
#    'pair': 'READ/ETH',
#    'perc_volume': 0.000350584373085,
#    'price': 0.0357338,
#    'updated': True,
#    'vol_24h': 5914.1},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/ETH',
#    'perc_volume': 0.000345269380966,
#    'price': 0.453377,
#    'updated': True,
#    'vol_24h': 5824.44},
#   {'currency': 'Health Mutual Society',
#    'pair': 'HMC/ETH',
#    'perc_volume': 0.000332654722,
#    'price': 0.0730536,
#    'updated': True,
#    'vol_24h': 5611.64},
#   {'currency': 'SALT',
#    'pair': 'SALT/BTC',
#    'perc_volume': 0.000330940361392,
#    'price': 4.19957,
#    'updated': True,
#    'vol_24h': 5582.72},
#   {'currency': 'Viberate',
#    'pair': 'VIB/ETH',
#    'perc_volume': 0.000330469090063,
#    'price': 0.26123,
#    'updated': True,
#    'vol_24h': 5574.77},
#   {'currency': 'Request Network',
#    'pair': 'REQ/ETH',
#    'perc_volume': 0.000329007259753,
#    'price': 0.286085,
#    'updated': True,
#    'vol_24h': 5550.11},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/ETH',
#    'perc_volume': 0.000323426103072,
#    'price': 0.0344221,
#    'updated': True,
#    'vol_24h': 5455.96},
#   {'currency': 'Everex',
#    'pair': 'EVX/BTC',
#    'perc_volume': 0.000313723248844,
#    'price': 1.74231,
#    'updated': True,
#    'vol_24h': 5292.28},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/ETH',
#    'perc_volume': 0.000292080928158,
#    'price': 38.5797,
#    'updated': True,
#    'vol_24h': 4927.19},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/ETH',
#    'perc_volume': 0.000288795663121,
#    'price': 0.0366854,
#    'updated': True,
#    'vol_24h': 4871.77},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/ETH',
#    'perc_volume': 0.000273288761622,
#    'price': 237.117,
#    'updated': True,
#    'vol_24h': 4610.18},
#   {'currency': 'Gas',
#    'pair': 'GAS/USDT',
#    'perc_volume': 0.000262718649591,
#    'price': 39.8276,
#    'updated': True,
#    'vol_24h': 4431.87},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/USDT',
#    'perc_volume': 0.000261489194577,
#    'price': 0.195908,
#    'updated': True,
#    'vol_24h': 4411.13},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/USDT',
#    'perc_volume': 0.000257773561005,
#    'price': 1.61866,
#    'updated': True,
#    'vol_24h': 4348.45},
#   {'currency': 'SONM',
#    'pair': 'SNM/BTC',
#    'perc_volume': 0.000241954257003,
#    'price': 0.223834,
#    'updated': True,
#    'vol_24h': 4081.59},
#   {'currency': 'Everex',
#    'pair': 'EVX/ETH',
#    'perc_volume': 0.000238563474611,
#    'price': 1.7452,
#    'updated': True,
#    'vol_24h': 4024.39},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/BTC',
#    'perc_volume': 0.000237486367688,
#    'price': 1.59447,
#    'updated': True,
#    'vol_24h': 4006.22},
#   {'currency': 'Nano',
#    'pair': 'NANO/ETH',
#    'perc_volume': 0.000231769461152,
#    'price': 9.16125,
#    'updated': True,
#    'vol_24h': 3909.78},
#   {'currency': 'Maggie',
#    'pair': 'MAG/ETH',
#    'perc_volume': 0.000231329607912,
#    'price': 0.0337019,
#    'updated': True,
#    'vol_24h': 3902.36},
#   {'currency': 'Primas',
#    'pair': 'PST/BTC',
#    'perc_volume': 0.000230883233936,
#    'price': 0.316235,
#    'updated': True,
#    'vol_24h': 3894.83},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/ETH',
#    'perc_volume': 0.000221745312509,
#    'price': 0.0879456,
#    'updated': True,
#    'vol_24h': 3740.68},
#   {'currency': 'UTRUST',
#    'pair': 'UTK/ETH',
#    'perc_volume': 0.000220202269404,
#    'price': 0.277837,
#    'updated': True,
#    'vol_24h': 3714.65},
#   {'currency': 'SingularDTV',
#    'pair': 'SNGLS/USDT',
#    'perc_volume': 0.000214075742128,
#    'price': 0.148106,
#    'updated': True,
#    'vol_24h': 3611.3},
#   {'currency': 'SingularDTV',
#    'pair': 'SNGLS/BTC',
#    'perc_volume': 0.000213969039186,
#    'price': 0.149914,
#    'updated': True,
#    'vol_24h': 3609.5},
#   {'currency': 'Simple Token',
#    'pair': 'OST/ETH',
#    'perc_volume': 0.000192121018939,
#    'price': 0.285759,
#    'updated': True,
#    'vol_24h': 3240.94},
#   {'currency': 'Storj',
#    'pair': 'STORJ/ETH',
#    'perc_volume': 0.000190701277011,
#    'price': 1.00906,
#    'updated': True,
#    'vol_24h': 3216.99},
#   {'currency': 'Ark',
#    'pair': 'ARK/ETH',
#    'perc_volume': 0.000182520718095,
#    'price': 3.96602,
#    'updated': True,
#    'vol_24h': 3078.99},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/BCH',
#    'perc_volume': 0.000171184123261,
#    'price': 2.10396,
#    'updated': True,
#    'vol_24h': 2887.75},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/ETH',
#    'perc_volume': 0.000169252800004,
#    'price': 2.10466,
#    'updated': True,
#    'vol_24h': 2855.17},
#   {'currency': 'Change',
#    'pair': 'CAG/USDT',
#    'perc_volume': 0.000164163069652,
#    'price': 0.271611,
#    'updated': True,
#    'vol_24h': 2769.31},
#   {'currency': 'SALT',
#    'pair': 'SALT/USDT',
#    'perc_volume': 0.000161337812855,
#    'price': 4.10936,
#    'updated': True,
#    'vol_24h': 2721.65},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/ETH',
#    'perc_volume': 0.000142212496021,
#    'price': 0.190612,
#    'updated': True,
#    'vol_24h': 2399.02},
#   {'currency': 'IPChain',
#    'pair': 'IPC/ETH',
#    'perc_volume': 0.000137269185818,
#    'price': 0.702999,
#    'updated': True,
#    'vol_24h': 2315.63},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/ETH',
#    'perc_volume': 0.000134948989615,
#    'price': 1.32168,
#    'updated': True,
#    'vol_24h': 2276.49},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/BCH',
#    'perc_volume': 0.000131714704873,
#    'price': 0.182075,
#    'updated': True,
#    'vol_24h': 2221.93},
#   {'currency': 'Primas',
#    'pair': 'PST/ETH',
#    'perc_volume': 0.000129040017784,
#    'price': 0.32355,
#    'updated': True,
#    'vol_24h': 2176.81},
#   {'currency': 'Change',
#    'pair': 'CAG/BTC',
#    'perc_volume': 0.000128712795427,
#    'price': 0.272884,
#    'updated': True,
#    'vol_24h': 2171.29},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/ETH',
#    'perc_volume': 0.000125709107599,
#    'price': 0.313211,
#    'updated': True,
#    'vol_24h': 2120.62},
#   {'currency': 'Gas',
#    'pair': 'GAS/ETH',
#    'perc_volume': 0.000124367021702,
#    'price': 39.5662,
#    'updated': True,
#    'vol_24h': 2097.98},
#   {'currency': 'TenX',
#    'pair': 'PAY/ETH',
#    'perc_volume': 0.000114884094094,
#    'price': 1.87661,
#    'updated': True,
#    'vol_24h': 1938.01},
#   {'currency': 'Ace',
#    'pair': 'ACE/ETH',
#    'perc_volume': 0.000110079497716,
#    'price': 0.357552,
#    'updated': True,
#    'vol_24h': 1856.96},
#   {'currency': 'Bread',
#    'pair': 'BRD/ETH',
#    'perc_volume': 0.000104379782211,
#    'price': 0.879953,
#    'updated': True,
#    'vol_24h': 1760.81},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/ETH',
#    'perc_volume': 0.000101843808947,
#    'price': 0.413596,
#    'updated': True,
#    'vol_24h': 1718.03},
#   {'currency': 'Nuls',
#    'pair': 'NULS/ETH',
#    'perc_volume': 0.000101243308499,
#    'price': 2.45461,
#    'updated': True,
#    'vol_24h': 1707.9},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/ETH',
#    'perc_volume': 8.73138321646e-05,
#    'price': 0.180041,
#    'updated': True,
#    'vol_24h': 1472.92},
#   {'currency': 'Metal',
#    'pair': 'MTL/ETH',
#    'perc_volume': 7.8663780302e-05,
#    'price': 3.60081,
#    'updated': True,
#    'vol_24h': 1327.0},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/USDT',
#    'perc_volume': 7.45948414324e-05,
#    'price': 1.72687,
#    'updated': True,
#    'vol_24h': 1258.36},
#   {'currency': 'Substratum',
#    'pair': 'SUB/ETH',
#    'perc_volume': 7.40150887788e-05,
#    'price': 0.714264,
#    'updated': True,
#    'vol_24h': 1248.58},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/ETH',
#    'perc_volume': 6.77302854724e-05,
#    'price': 0.571741,
#    'updated': True,
#    'vol_24h': 1142.56},
#   {'currency': 'Super Bitcoin',
#    'pair': 'SBTC/BCH',
#    'perc_volume': 6.06600299512e-05,
#    'price': 22.7515,
#    'updated': True,
#    'vol_24h': 1023.29},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/ETH',
#    'perc_volume': 4.76899316279e-05,
#    'price': 2.81206,
#    'updated': True,
#    'vol_24h': 804.494},
#   {'currency': 'Monaco',
#    'pair': 'MCO/ETH',
#    'perc_volume': 4.3685192362e-05,
#    'price': 7.55726,
#    'updated': True,
#    'vol_24h': 736.937},
#   {'currency': 'Dent',
#    'pair': 'DENT/ETH',
#    'perc_volume': 4.00440137326e-05,
#    'price': 0.0235682,
#    'updated': True,
#    'vol_24h': 675.513},
#   {'currency': 'SONM',
#    'pair': 'SNM/ETH',
#    'perc_volume': 3.73780999965e-05,
#    'price': 0.218132,
#    'updated': True,
#    'vol_24h': 630.541},
#   {'currency': 'Golem',
#    'pair': 'GNT/ETH',
#    'perc_volume': 3.42111566666e-05,
#    'price': 0.36069,
#    'updated': True,
#    'vol_24h': 577.117},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/ETH',
#    'perc_volume': 3.39488452665e-05,
#    'price': 0.153026,
#    'updated': True,
#    'vol_24h': 572.692},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/BCH',
#    'perc_volume': 3.39162415897e-05,
#    'price': 115.351,
#    'updated': True,
#    'vol_24h': 572.142},
#   {'currency': 'Monero',
#    'pair': 'XMR/ETH',
#    'perc_volume': 3.29502835641e-05,
#    'price': 245.219,
#    'updated': True,
#    'vol_24h': 555.847},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/ETH',
#    'perc_volume': 2.87921884582e-05,
#    'price': 1.73127,
#    'updated': True,
#    'vol_24h': 485.703},
#   {'currency': 'SONM',
#    'pair': 'SNM/USDT',
#    'perc_volume': 2.83744464387e-05,
#    'price': 0.225709,
#    'updated': True,
#    'vol_24h': 478.656},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/ETH',
#    'perc_volume': 2.80988564503e-05,
#    'price': 1.59555,
#    'updated': True,
#    'vol_24h': 474.007},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/ETH',
#    'perc_volume': 2.35226636485e-05,
#    'price': 0.704868,
#    'updated': True,
#    'vol_24h': 396.81},
#   {'currency': 'Monetha',
#    'pair': 'MTH/ETH',
#    'perc_volume': 1.66309577176e-05,
#    'price': 0.14687,
#    'updated': True,
#    'vol_24h': 280.552},
#   {'currency': 'Dash',
#    'pair': 'DASH/BCH',
#    'perc_volume': 1.35694724624e-05,
#    'price': 622.322,
#    'updated': True,
#    'vol_24h': 228.907},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/BCH',
#    'perc_volume': 1.29985524412e-05,
#    'price': 238.476,
#    'updated': True,
#    'vol_24h': 219.276},
#   {'currency': 'SingularDTV',
#    'pair': 'SNGLS/ETH',
#    'perc_volume': 9.40450094466e-06,
#    'price': 0.150008,
#    'updated': True,
#    'vol_24h': 158.647},
#   {'currency': 'Bancor',
#    'pair': 'BNT/ETH',
#    'perc_volume': 3.26887427964e-07,
#    'price': 5.11086,
#    'updated': True,
#    'vol_24h': 5.51435},
#   {'currency': 'Change',
#    'pair': 'CAG/ETH',
#    'perc_volume': 3.18066651394e-08,
#    'price': 0.268278,
#    'updated': True,
#    'vol_24h': 0.536555},
#   {'currency': 'Aventus',
#    'pair': 'AVT/BCH',
#    'perc_volume': 0.0,
#    'price': 2.22063,
#    'updated': True,
#    'vol_24h': None}],
#  'name': 'OKEx ',
#  'social': {'twitter': {'link': 'https://twitter.com/CoinMarketCap',
#    'username': '@OKEx_'}},
#  'volume': 1686926301.92,
#  'web': 'https://www.okex.com'}

# %% [markdown]
# In order to obtain all available values for the `name` parameter, use:

# %%
cmc.exchange_slugs
# Out:
# ['abucoins',
#  'acx',
#  'aex',
#  'aidos-market',
#  'alcurex',
#  'allcoin',
#  'altcoin-trader',
#  'bancor-network',
#  'barterdex',
#  'bcex',
#  'bibox',
#  'bigone',
#  'binance',
#  'bisq',
#  'bit-z',
#  'bit2c',
#  'bitbank',
#  'bitbay',
#  'bitcoin-indonesia',
#  'bitcointoyou',
#  'bitcointrade',
#  'bitex-la',
#  'bitfinex',
#  'bitflip',
#  'bitflyer',
#  'bitholic',
#  'bithumb',
#  'bitinka',
#  'bitkonan',
#  'bitlish',
#  'bitmarket',
#  'bitmaszyna',
#  'bitmex',
#  'bitonic',
#  'bits-blockchain',
#  'bitsane',
#  'bitshares-asset-exchange',
#  'bitso',
#  'bitstamp',
#  'bitstamp-ripple-gateway',
#  'bittrex',
#  'bittylicious',
#  'bl3p',
#  'bleutrade',
#  'braziliex',
#  'btc-alpha',
#  'btc-markets',
#  'btc-trade-ua',
#  'btcbox',
#  'btcc',
#  'btctrade-im',
#  'btcturk',
#  'burst-asset-exchange',
#  'bx-thailand',
#  'c-cex',
#  'c2cx',
#  'cex-io',
#  'chaoex',
#  'cobinhood',
#  'coinbene',
#  'coincorner',
#  'coinegg',
#  'coinex',
#  'coinexchange',
#  'coinfalcon',
#  'coinfloor',
#  'coingi',
#  'coinhouse',
#  'coinlink',
#  'coinmate',
#  'coinnest',
#  'coinone',
#  'coinrail',
#  'coinrate',
#  'coinroom',
#  'coinsbank',
#  'coinsecure',
#  'coinsquare',
#  'coinut',
#  'coolcoin',
#  'coss',
#  'counterparty-dex',
#  'cryptobridge',
#  'cryptoderivatives',
#  'cryptomarket',
#  'cryptomate',
#  'cryptopia',
#  'cryptox',
#  'dgtmarket',
#  'dsx',
#  'ethexindia',
#  'excambriorex',
#  'exmo',
#  'exrates',
#  'exx',
#  'ezbtc',
#  'fargobase',
#  'fatbtc',
#  'fisco',
#  'foxbit',
#  'freiexchange',
#  'gate-io',
#  'gatecoin',
#  'gatehub',
#  'gdax',
#  'gemini',
#  'getbtc',
#  'gopax',
#  'guldentrader',
#  'heat-wallet',
#  'hitbtc',
#  'huobi',
#  'idex',
#  'independent-reserve',
#  'infinitycoin-exchange',
#  'iquant',
#  'isx',
#  'itbit',
#  'koineks',
#  'koinex',
#  'koinim',
#  'korbit',
#  'kraken',
#  'kucoin',
#  'kuna',
#  'lakebtc',
#  'lbank',
#  'leoxchange',
#  'liqui',
#  'litebit',
#  'livecoin',
#  'localtrade',
#  'luno',
#  'lykke-exchange',
#  'mercado-bitcoin',
#  'mercatox',
#  'mr-exchange',
#  'negocie-coins',
#  'neraexpro',
#  'nix-e',
#  'nocks',
#  'oasisdex',
#  'oex',
#  'okcoin-cn',
#  'okcoin-intl',
#  'okex',
#  'omni-dex',
#  'openledger',
#  'ore-bz',
#  'paribu',
#  'paymium',
#  'poloniex',
#  'qbtc',
#  'qryptos',
#  'quadrigacx',
#  'quoine',
#  'radar-relay',
#  'rfinex',
#  'rightbtc',
#  'rippex',
#  'ripple-china',
#  'ripplefox',
#  'simex',
#  'southxchange',
#  'stellar-decentralized-exchange',
#  'stocks-exchange',
#  'stronghold',
#  'surbtc',
#  'tcc-exchange',
#  'tdax',
#  'therocktrading',
#  'tidebit',
#  'tidex',
#  'token-store',
#  'topbtc',
#  'trade-by-trade',
#  'trade-satoshi',
#  'tradeogre',
#  'triple-dice-exchange',
#  'tux-exchange',
#  'upbit',
#  'vebitcoin',
#  'virtacoinworld',
#  'waves-dex',
#  'wex',
#  'xbtce',
#  'yobit',
#  'zaif',
#  'zb-com']

# %% [markdown]
# If you want to get all formatted exchange names:

# %%
cmc.exchange_names
# Out:
# ['ACX',
#  'AEX',
#  'Abucoins',
#  'AidosMarket',
#  'Allcoin',
#  'Altcoin Trader',
#  'BCEX',
#  'BITHOLIC',
#  'BL3P',
#  'BTC Markets',
#  'BTC Trade UA',
#  'BTC-Alpha',
#  'BTCBOX',
#  'BTCC',
#  'BTCTurk',
#  'BX Thailand',
#  'Bancor Network',
#  'BarterDEX',
#  'Bibox',
#  'BigONE',
#  'Binance',
#  'Bisq',
#  'Bit-Z',
#  'Bit2C',
#  'BitBay',
#  'BitFlip',
#  'BitKonan',
#  'BitMEX',
#  'BitMarket',
#  'BitShares Asset Exchange',
#  'Bitbank',
#  'Bitcoin Indonesia',
#  'BitcoinToYou',
#  'BitcoinTrade',
#  'Bitex.la',
#  'Bitfinex',
#  'Bithumb',
#  'Bitinka',
#  'Bitlish',
#  'Bitmaszyna',
#  'Bitonic',
#  'Bits Blockchain',
#  'Bitsane',
#  'Bitso',
#  'Bitstamp',
#  'Bitstamp (Ripple Gateway)',
#  'Bittrex',
#  'Bittylicious',
#  'Bleutrade',
#  'Braziliex',
#  'BtcTrade.im',
#  'Burst Asset Exchange',
#  'C-CEX',
#  'C2CX',
#  'CEX.IO',
#  'COSS',
#  'ChaoEX',
#  'Cobinhood',
#  'CoinCorner',
#  'CoinEgg',
#  'CoinEx',
#  'CoinExchange',
#  'CoinFalcon',
#  'CoinMate',
#  'Coinbene',
#  'Coinfloor',
#  'Coingi',
#  'Coinhouse',
#  'Coinlink',
#  'Coinnest',
#  'Coinone',
#  'Coinrail',
#  'Coinrate',
#  'Coinroom',
#  'CoinsBank',
#  'Coinsecure',
#  'Coinsquare',
#  'Coinut',
#  'CoolCoin',
#  'Counterparty DEX',
#  'CryptoBridge',
#  'CryptoDerivatives',
#  'CryptoMarket',
#  'Cryptomate',
#  'Cryptopia',
#  'Cryptox',
#  'DSX',
#  'Dgtmarket',
#  'ETHEXIndia',
#  'EXX',
#  'ExcambrioRex',
#  'Exmo',
#  'Exrates',
#  'Fargobase',
#  'Fatbtc',
#  'Fisco',
#  'Foxbit',
#  'FreiExchange',
#  'GDAX',
#  'GOPAX',
#  'Gate.io',
#  'Gatecoin',
#  'Gatehub',
#  'Gemini',
#  'GetBTC',
#  'GuldenTrader',
#  'Heat Wallet',
#  'HitBTC',
#  'Huobi',
#  'IDEX',
#  'ISX',
#  'Independent Reserve',
#  'InfinityCoin Exchange',
#  'Iquant',
#  'Koineks',
#  'Koinex',
#  'Koinim',
#  'Korbit',
#  'Kraken',
#  'Kucoin',
#  'Kuna',
#  'LEOxChange',
#  'LakeBTC',
#  'Lbank',
#  'Liqui',
#  'LiteBit.eu',
#  'Livecoin',
#  'LocalTrade',
#  'Luno',
#  'Lykke Exchange',
#  'Mercado Bitcoin',
#  'Mercatox',
#  'Mr. Exchange',
#  'NIX-E',
#  'Negocie Coins',
#  'Neraex',
#  'Nocks',
#  'OEX',
#  'OKCoin.cn',
#  'OKEx',
#  'OasisDEX',
#  'OkCoin Intl.',
#  'Omni DEX',
#  'OpenLedger DEX',
#  'Ore.Bz',
#  'Paribu',
#  'Paymium',
#  'Poloniex',
#  'QBTC',
#  'Qryptos',
#  'QuadrigaCX',
#  'Quoine',
#  'Radar Relay',
#  'Rfinex',
#  'RightBTC',
#  'Rippex',
#  'Ripple China',
#  'RippleFox',
#  'Simex',
#  'SouthXchange',
#  'Stellar Decentralized Exchange',
#  'Stocks.Exchange',
#  'Stronghold',
#  'SurBTC',
#  'TCC Exchange',
#  'TDAX',
#  'TOPBTC',
#  'The Rock Trading',
#  'Tidebit',
#  'Tidex',
#  'Token Store',
#  'Trade By Trade',
#  'Trade Satoshi',
#  'TradeOgre',
#  'Tripe Dice Exchange',
#  'Tux Exchange',
#  'Upbit',
#  'Vebitcoin',
#  'VirtacoinWorld',
#  'WEX',
#  'Waves Decentralized Exchange',
#  'YoBit',
#  'ZB.COM',
#  'Zaif',
#  'alcurEX',
#  'bitFlyer',
#  'ezBtc',
#  'itBit',
#  'xBTCe']

# %% [markdown]
# #### `exchanges([convert="USD"])`
# Get all available exchanges in coinmarketcap ranked by volumes with some metadata:

# %%
cmc.exchanges()
# Out:
# [{'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BitMEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Litecoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'OFCOIN',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'OKEx'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'NEO',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Gifto',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'ICON',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'TRON',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Ripple',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'NEO',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Nano',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Binance'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Cardano',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'NEO',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Qtum',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Status',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Stellar',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Steem Dollars',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Upbit'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Qtum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Zcash',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Bithumb'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Tether',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'EOS',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Bitfinex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Huobi Token',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'TRON',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Huobi Token',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Elastos',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Huobi Token',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'EOS',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Elastos',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'WaykiChain',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Huobi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ripple',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ripple',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Ripple',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Kraken'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Litecoin',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'GDAX'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Monero',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Dash',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ripple',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Zcash',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Litecoin',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'HitBTC'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NuBits',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ripple',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Cardano',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ripple',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'NEO',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Siacoin',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Bittrex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ripple',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Ripple',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Bitstamp'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'TRON',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'EDUCare',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ink',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ink',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Lisk',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Hshare',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Bit-Z'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'bitFlyer'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Qtum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'IOTA',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'}],
#   'name': 'Coinone'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEM',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'MonaCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Counterparty',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'NEM',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Pepe Cash',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'COMSA [XEM]',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'COMSA [ETH]',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Zaif'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ripple',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Monero',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Stellar',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Poloniex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'MonaCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'MonaCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'}],
#   'name': 'Fisco'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BTCBOX'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEO',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'TRON',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Lisk',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ruff',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Qtum',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ripple',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Qbao',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Achain',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'CoinEgg'},
#  {'markets': [{'name': 'ATMCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'ATMCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ripple',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Litecoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Dogecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'ATMCoin',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'ATMCoin',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Bits Blockchain'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'QASH',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'QASH',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Ripple',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Ethereum',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Quoine'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ink',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Lightning Bitcoin [Futures]',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Hyper Pay',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Ink',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'EXX'},
#  {'markets': [{'name': 'Bibox Token',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bibox Token',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bibox Token',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Jibrel Network',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Jibrel Network',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Spectre.ai Utility Token',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Spectre.ai Utility Token',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Bytom',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Gifto',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Gifto',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Bibox'},
#  {'markets': [{'name': 'Stellar',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Status',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Qtum',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'EOS',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Cindicator',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Civic',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': '0x',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'GOPAX'},
#  {'markets': [{'name': 'Ink',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'BitShares',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Hshare',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Ripple',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'QunQun',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'ZB.COM'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Litecoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Zcash',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Dash',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Zcash',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'WEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'}],
#   'name': 'Gemini'},
#  {'markets': [{'name': 'TRON',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'TRON',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'TRON',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'SIRIN LABS Token',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'SIRIN LABS Token',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'AdEx',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Matchpool',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'SIRIN LABS Token',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'AdEx',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Ethereum',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Liqui'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'BTCC'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum Classic',
# ...
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'}],
#   'name': 'Heat Wallet'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'TCC Exchange'},
#  {'markets': [{'name': 'Centurion',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ExcambrioRex'},
#  {'markets': [{'name': 'Auroracoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ISX'},
#  {'markets': [{'name': 'Litecoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Electroneum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'BitCoal',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Monero',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Aeon',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Verge',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Sumokoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'}],
#   'name': 'TradeOgre'},
#  {'markets': [{'name': 'Anoncoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'WhiteCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Freicoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'FreiExchange'},
#  {'markets': [{'name': 'Pepe Cash',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Dogecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'PotCoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Zcash',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Litecoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Bitcrystals',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Iconomi',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Namecoin',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'BlackCoin',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Tux Exchange'},
#  {'markets': [{'name': 'Gulden',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'GuldenTrader'},
#  {'markets': [{'name': 'BriaCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Litecoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'}],
#   'name': 'Ore.Bz'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Siacoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'}],
#   'name': 'BITHOLIC'},
#  {'markets': [{'name': 'SnakeEyes',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'CCMiner',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'}],
#   'name': 'Burst Asset Exchange'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'}],
#   'name': 'CoinCorner'},
#  {'markets': [{'name': 'CRTCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Dogecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'}],
#   'name': 'NIX-E'},
#  {'markets': [{'name': 'LEOcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'LEOcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'LEOcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'LEOcoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Bitcoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'}],
#   'name': 'LEOxChange'},
#  {'markets': [{'name': 'MaidSafeCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Omni DEX'},
#  {'markets': [{'name': 'Golem',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Lunyr',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'SingularDTV',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'TokenCard',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Swarm City',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'Etheroll',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Melon',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Numeraire',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Edgeless',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Ethereum Movie Venture',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'CryptoDerivatives'},
#  {'markets': [{'name': 'Virtacoinplus',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Virtacoinplus',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'}],
#   'name': 'VirtacoinWorld'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Filecoin [Futures]',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'NEO',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'VeChain',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'ChatCoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'WhiteCoin',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Primas',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Zcash',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'BitShares',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Profile Utility Token',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Lbank'},
#  {'markets': [{'name': 'Raiden Network Token',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 8619.5,
#     'volume': 1694260000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'RChain',
#     'pair': 'BTC/USDT',
#     'perc_volume': 25.68,
#     'price': 8631.95,
#     'volume': 432406000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#btc_usdt'},
#    {'name': 'TRON',
#     'pair': 'ETH/USDT',
#     'perc_volume': 12.26,
#     'price': 852.632,
#     'volume': 206451000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_usdt'},
#    {'name': 'ChainLink',
#     'pair': 'ETH/BTC',
#     'perc_volume': 11.32,
#     'price': 855.948,
#     'volume': 190573000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#eth_btc'},
#    {'name': 'Aion',
#     'pair': 'LTC/BTC',
#     'perc_volume': 9.14,
#     'price': 159.213,
#     'volume': 153869000.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_btc'},
#    {'name': 'SALT',
#     'pair': 'ETC/BTC',
#     'perc_volume': 5.37,
#     'price': 28.246,
#     'volume': 90396200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#etc_btc'},
#    {'name': 'Dragonchain',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.13,
#     'price': 159.27,
#     'volume': 86306900.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#ltc_usdt'},
#    {'name': 'Populous',
#     'pair': 'BCH/USDT',
#     'perc_volume': 4.91,
#     'price': 1251.92,
#     'volume': 82759100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_usdt'},
#    {'name': 'Global Jobcoin',
#     'pair': 'BCH/BTC',
#     'perc_volume': 4.9,
#     'price': 1254.9,
#     'volume': 82546200.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#bch_btc'},
#    {'name': 'Bounty0x',
#     'pair': 'OF/USDT',
#     'perc_volume': 4.12,
#     'price': 0.00400012,
#     'volume': 69423100.0,
#     'web': 'https://www.okex.com/spot/trade/index.do#of_usdt'}],
#   'name': 'Token Store'}]

# %% [markdown]
# #### `tokens([convert="USD"])`
# Get platforms tokens data:

# %%
cmc.tokens()
# Out:
# [{'circulating_supply': 665480069.8,
#   'market_cap': 5954422853.34,
#   'name': 'EOS',
#   'platform': 'Ethereum',
#   'price': 8.94756,
#   'symbol': 'EOS',
#   'volume_24h': 321466000.0},
#  {'circulating_supply': 65748192475.5,
#   'market_cap': 2996631667.73,
#   'name': 'TRON',
#   'platform': 'Ethereum',
#   'price': 0.0455774,
#   'symbol': 'TRX',
#   'volume_24h': 220709000.0},
#  {'circulating_supply': 2217140813.52,
#   'market_cap': 2216670779.67,
#   'name': 'Tether',
#   'platform': 'Omni',
#   'price': 0.999788,
#   'symbol': 'USDT',
#   'volume_24h': 2303030000.0},
#  {'circulating_supply': 470791178.115,
#   'market_cap': 1978815356.12,
#   'name': 'VeChain',
#   'platform': 'Ethereum',
#   'price': 4.20317,
#   'symbol': 'VEN',
#   'volume_24h': 26708200.0},
#  {'circulating_supply': 8632313657.16,
#   'market_cap': 1776745958.48,
#   'name': 'U.CASH',
#   'platform': 'Ethereum',
#   'price': 0.205825,
#   'symbol': 'UCASH',
#   'volume_24h': 4378680.0},
#  {'circulating_supply': 381495014.0,
#   'market_cap': 1580209572.24,
#   'name': 'ICON',
#   'platform': 'Ethereum',
#   'price': 4.14215,
#   'symbol': 'ICX',
#   'volume_24h': 65438900.0},
#  {'circulating_supply': 102042551.763,
#   'market_cap': 1274746169.39,
#   'name': 'OmiseGO',
#   'platform': 'Ethereum',
#   'price': 12.4923,
#   'symbol': 'OMG',
#   'volume_24h': 23711300.0},
#  {'circulating_supply': 37004026.8944,
#   'market_cap': 1043491356.01,
#   'name': 'Populous',
#   'platform': 'Ethereum',
#   'price': 28.1994,
#   'symbol': 'PPT',
#   'volume_24h': 21251600.0},
#  {'circulating_supply': 99014000.0,
#   'market_cap': 907457369.16,
#   'name': 'Binance Coin',
#   'platform': 'Ethereum',
#   'price': 9.16494,
#   'symbol': 'BNB',
#   'volume_24h': 57417200.0},
#  {'circulating_supply': 3470483788.0,
#   'market_cap': 761951656.623,
#   'name': 'Status',
#   'platform': 'Ethereum',
#   'price': 0.219552,
#   'symbol': 'SNT',
#   'volume_24h': 66422000.0},
#  {'circulating_supply': 618227.770106,
#   'market_cap': 644304617.449,
#   'name': 'Maker',
#   'platform': 'Ethereum',
#   'price': 1042.18,
#   'symbol': 'MKR',
#   'volume_24h': 879639.0},
#  {'circulating_supply': 344166288.9,
#   'market_cap': 636184501.706,
#   'name': 'RChain',
#   'platform': 'Ethereum',
#   'price': 1.84848,
#   'symbol': 'RHOC',
#   'volume_24h': 951662.0},
#  {'circulating_supply': 233020472.114,
#   'market_cap': 606957744.534,
#   'name': 'Aeternity',
#   'platform': 'Ethereum',
#   'price': 2.60474,
#   'symbol': 'AE',
#   'volume_24h': 3436230.0},
#  {'circulating_supply': 11000000.0,
#   'market_cap': 581879100.0,
#   'name': 'Augur',
#   'platform': 'Ethereum',
#   'price': 52.8981,
#   'symbol': 'REP',
#   'volume_24h': 10569300.0},
#  {'circulating_supply': 2036645.44,
#   'market_cap': 553250660.485,
#   'name': 'Veritaseum',
#   'platform': 'Ethereum',
#   'price': 271.648,
#   'symbol': 'VERI',
#   'volume_24h': 97697.7},
#  {'circulating_supply': 24898178.0,
#   'market_cap': 540377606.223,
#   'name': 'Walton',
#   'platform': 'Ethereum',
#   'price': 21.7035,
#   'symbol': 'WTC',
#   'volume_24h': 6668200.0},
#  {'circulating_supply': 507683814.423,
#   'market_cap': 521543582.557,
#   'name': '0x',
#   'platform': 'Ethereum',
#   'price': 1.0273,
#   'symbol': 'ZRX',
#   'volume_24h': 5533920.0},
#  {'circulating_supply': 91043076.0001,
#   'market_cap': 514576375.983,
#   'name': 'KuCoin Shares',
#   'platform': 'Ethereum',
#   'price': 5.65201,
#   'symbol': 'KCS',
#   'volume_24h': 2078330.0},
#  {'circulating_supply': 184450000.0,
#   'market_cap': 501338789.0,
#   'name': 'Revain',
#   'platform': 'Ethereum',
#   'price': 2.71802,
#   'symbol': 'R',
#   'volume_24h': 18071300.0},
#  {'circulating_supply': 2000000.0,
#   'market_cap': 473368000.0,
#   'name': 'DigixDAO',
#   'platform': 'Ethereum',
#   'price': 236.684,
#   'symbol': 'DGD',
#   'volume_24h': 6878580.0},
#  {'circulating_supply': 238421940.0,
#   'market_cap': 384123971.753,
#   'name': 'Dragonchain',
#   'platform': 'Ethereum',
#   'price': 1.61111,
#   'symbol': 'DRGN',
#   'volume_24h': 2680980.0},
#  {'circulating_supply': 9694015.24264,
#   'market_cap': 379519727.348,
#   'name': 'Gas',
#   'platform': 'NEO',
#   'price': 39.1499,
#   'symbol': 'GAS',
#   'volume_24h': 4185030.0},
#  {'circulating_supply': 134132696.93,
#   'market_cap': 374672862.335,
#   'name': 'Kyber Network',
#   'platform': 'Ethereum',
#   'price': 2.7933,
#   'symbol': 'KNC',
#   'volume_24h': 9137180.0},
#  {'circulating_supply': 561202251.418,
#   'market_cap': 363911038.73,
#   'name': 'Loopring',
#   'platform': 'Ethereum',
#   'price': 0.648449,
#   'symbol': 'LRC',
#   'volume_24h': 1536670.0},
#  {'circulating_supply': 1000000000.0,
#   'market_cap': 362707000.0,
#   'name': 'Basic Attenti...',
#   'platform': 'Ethereum',
#   'price': 0.362707,
#   'symbol': 'BAT',
#   'volume_24h': 3044030.0},
#  {'circulating_supply': 987000000.0,
#   'market_cap': 360083262.0,
#   'name': 'Bytom',
#   'platform': 'Ethereum',
#   'price': 0.364826,
#   'symbol': 'BTM',
#   'volume_24h': 11376700.0},
#  {'circulating_supply': 325226613094.0,
#   'market_cap': 352906650.134,
#   'name': 'Dentacoin',
#   'platform': 'Ethereum',
#   'price': 0.00108511,
#   'symbol': 'DCN',
#   'volume_24h': 487451.0},
#  {'circulating_supply': 6511228178.4,
#   'market_cap': 331572574.774,
#   'name': 'Zilliqa',
#   'platform': 'Ethereum',
#   'price': 0.0509232,
#   'symbol': 'ZIL',
#   'volume_24h': 9655590.0},
#  {'circulating_supply': 350000000.0,
#   'market_cap': 309751050.0,
#   'name': 'QASH',
#   'platform': 'Ethereum',
#   'price': 0.885003,
#   'symbol': 'QASH',
#   'volume_24h': 4251260.0},
#  {'circulating_supply': 75633251.7085,
#   'market_cap': 305261854.555,
#   'name': 'Ethos',
#   'platform': 'Ethereum',
#   'price': 4.03608,
#   'symbol': 'ETHOS',
#   'volume_24h': 1296430.0},
#  {'circulating_supply': 834262000.0,
#   'market_cap': 304656631.422,
#   'name': 'Golem',
#   'platform': 'Ethereum',
#   'price': 0.365181,
#   'symbol': 'GNT',
#   'volume_24h': 4670780.0},
#  {'circulating_supply': 250000000.0,
#   'market_cap': 297302500.0,
#   'name': 'aelf',
#   'platform': 'Ethereum',
#   'price': 1.18921,
#   'symbol': 'ELF',
#   'volume_24h': 33310400.0},
#  {'circulating_supply': 35500000.0,
#   'market_cap': 296835025.0,
#   'name': 'Nebulas',
#   'platform': 'Ethereum',
#   'price': 8.36155,
#   'symbol': 'NAS',
#   'volume_24h': 9207130.0},
#  {'circulating_supply': 363837588.92,
#   'market_cap': 271707362.329,
#   'name': 'Power Ledger',
#   'platform': 'Ethereum',
#   'price': 0.746782,
#   'symbol': 'POWR',
#   'volume_24h': 7909310.0},
#  {'circulating_supply': 227384800.0,
#   'market_cap': 269300914.032,
#   'name': 'Pillar',
#   'platform': 'Ethereum',
#   'price': 1.18434,
#   'symbol': 'PLR',
#   'volume_24h': 375917.0},
#  {'circulating_supply': 1445976590.33,
#   'market_cap': 259698841.599,
#   'name': 'Cindicator',
#   'platform': 'Ethereum',
#   'price': 0.179601,
#   'symbol': 'CND',
#   'volume_24h': 4290910.0},
#  {'circulating_supply': 6794109921.69,
#   'market_cap': 253516097.029,
#   'name': 'IOStoken',
#   'platform': 'Ethereum',
#   'price': 0.0373141,
#   'symbol': 'IOST',
#   'volume_24h': 42518100.0},
#  {'circulating_supply': 10614760961.2,
#   'market_cap': 252827683.954,
#   'name': 'Dent',
#   'platform': 'Ethereum',
#   'price': 0.0238185,
#   'symbol': 'DENT',
#   'volume_24h': 2151950.0},
#  {'circulating_supply': 4503688788.66,
#   'market_cap': 240143892.114,
#   'name': 'FunFair',
#   'platform': 'Ethereum',
#   'price': 0.0533216,
#   'symbol': 'FUN',
#   'volume_24h': 5716940.0},
#  {'circulating_supply': 79265734.9086,
#   'market_cap': 237774217.663,
#   'name': 'Aion',
#   'platform': 'Ethereum',
#   'price': 2.99971,
#   'symbol': 'AION',
#   'volume_24h': 3133440.0},
#  {'circulating_supply': 74836171.09,
#   'market_cap': 234723650.624,
#   'name': 'Enigma',
#   'platform': 'Ethereum',
#   'price': 3.1365,
#   'symbol': 'ENG',
#   'volume_24h': 12315000.0},
#  {'circulating_supply': 53005985.1339,
#   'market_cap': 219841793.283,
#   'name': 'SALT',
#   'platform': 'Ethereum',
#   'price': 4.14749,
#   'symbol': 'SALT',
#   'volume_24h': 3216410.0},
#  {'circulating_supply': 756097560976.0,
#   'market_cap': 214215292.683,
#   'name': 'Kin',
#   'platform': 'Ethereum',
#   'price': 0.000283317,
#   'symbol': 'KIN',
#   'volume_24h': 194497.0},
#  {'circulating_supply': 38744502.4445,
#   'market_cap': 197616334.718,
#   'name': 'Bancor',
#   'platform': 'Ethereum',
#   'price': 5.1005,
#   'symbol': 'BNT',
#   'volume_24h': 3709340.0},
#  {'circulating_supply': 104661310.0,
#   'market_cap': 196551846.954,
#   'name': 'TenX',
#   'platform': 'Ethereum',
#   'price': 1.87798,
#   'symbol': 'PAY',
#   'volume_24h': 3820600.0},
#  {'circulating_supply': 452552412.0,
#   'market_cap': 194419684.062,
#   'name': 'MaidSafeCoin',
#   'platform': 'Omni',
#   'price': 0.429607,
#   'symbol': 'MAID',
#   'volume_24h': 2806970.0},
#  {'circulating_supply': 617314170.819,
#   'market_cap': 187127061.914,
#   'name': 'Quantstamp',
#   'platform': 'Ethereum',
#   'price': 0.303131,
#   'symbol': 'QSP',
#   'volume_24h': 4091330.0},
#  {'circulating_supply': 239570250.0,
#   'market_cap': 186909115.496,
#   'name': 'Polymath',
#   'platform': 'Ethereum',
#   'price': 0.780185,
#   'symbol': 'POLY',
#   'volume_24h': 173152.0},
#  {'circulating_supply': 641462768.585,
#   'market_cap': 182648825.801,
#   'name': 'Request Network',
#   'platform': 'Ethereum',
#   'price': 0.284738,
#   'symbol': 'REQ',
#   'volume_24h': 3225780.0},
#  {'circulating_supply': 455552782.0,
#   'market_cap': 182139568.852,
#   'name': 'SingularityNET',
#   'platform': 'Ethereum',
#   'price': 0.399821,
#   'symbol': 'AGI',
#   'volume_24h': 1371880.0},
#  {'circulating_supply': 761143950.0,
#   'market_cap': 175904172.565,
#   'name': 'Ignis',
#   'platform': 'Ardor',
#   'price': 0.231105,
#   'symbol': 'IGNIS',
#   'volume_24h': 4733570.0},
#  {'circulating_supply': 350000000.0,
#   'market_cap': 161530250.0,
#   'name': 'ChainLink',
#   'platform': 'Ethereum',
#   'price': 0.461515,
#   'symbol': 'LINK',
#   'volume_24h': 4351810.0},
#  {'circulating_supply': 226091448.88,
#   'market_cap': 160800308.09,
#   'name': 'Substratum',
#   'platform': 'Ethereum',
#   'price': 0.711218,
#   'symbol': 'SUB',
#   'volume_24h': 3148510.0},
#  {'circulating_supply': 99735686.8829,
#   'market_cap': 159419516.627,
#   'name': 'Iconomi',
#   'platform': 'Ethereum',
#   'price': 1.59842,
#   'symbol': 'ICN',
#   'volume_24h': 860724.0},
#  {'circulating_supply': 1000000000.0,
#   'market_cap': 158599000.0,
#   'name': 'XPlay',
#   'platform': 'Ethereum',
#   'price': 0.158599,
#   'symbol': 'XPA',
#   'volume_24h': 872471.0},
#  {'circulating_supply': 1104590.0,
#   'market_cap': 158516397.13,
#   'name': 'Gnosis',
#   'platform': 'Ethereum',
#   'price': 143.507,
#   'symbol': 'GNO',
#   'volume_24h': 308908.0},
#  {'circulating_supply': 492954537.351,
#   'market_cap': 158502630.122,
#   'name': 'WAX',
#   'platform': 'Ethereum',
#   'price': 0.321536,
#   'symbol': 'WAX',
#   'volume_24h': 3353000.0},
#  {'circulating_supply': 342699966.0,
#   'market_cap': 148230757.894,
#   'name': 'Civic',
#   'platform': 'Ethereum',
#   'price': 0.432538,
#   'symbol': 'CVC',
#   'volume_24h': 4511760.0},
#  {'circulating_supply': 2216707776.0,
#   'market_cap': 146424188.802,
#   'name': 'Po.et',
#   'platform': 'Ethereum',
#   'price': 0.0660548,
#   'symbol': 'POE',
#   'volume_24h': 22514200.0},
#  {'circulating_supply': 133425492.59,
#   'market_cap': 137385561.21,
#   'name': 'Storj',
#   'platform': 'Ethereum',
#   'price': 1.02968,
#   'symbol': 'STORJ',
#   'volume_24h': 5522050.0},
#  {'circulating_supply': 50148936.0,
#   'market_cap': 136939693.578,
#   'name': 'Raiden Networ...',
#   'platform': 'Ethereum',
#   'price': 2.73066,
#   'symbol': 'RDN',
#   'volume_24h': 2695890.0},
#  {'circulating_supply': 543348500.0,
#   'market_cap': 132970418.314,
#   'name': 'Red Pulse',
#   'platform': 'NEO',
#   'price': 0.244724,
#   'symbol': 'RPX',
#   'volume_24h': 33414400.0},
#  {'circulating_supply': 816060.7785,
#   'market_cap': 129389700.674,
#   'name': 'SuperNET',
#   'platform': 'Nxt',
#   'price': 158.554,
#   'symbol': 'UNITY',
#   'volume_24h': 5346.96},
#  {'circulating_supply': 1186310945.0,
#   'market_cap': 125072762.931,
#   'name': 'Dynamic Tradi...',
#   'platform': 'Ethereum',
#   'price': 0.10543,
#   'symbol': 'DTR',
#   'volume_24h': 136273.0},
#  {'circulating_supply': 1051043445.16,
#   'market_cap': 124882880.067,
#   'name': 'Decentraland',
#   'platform': 'Ethereum',
#   'price': 0.118818,
#   'symbol': 'MANA',
#   'volume_24h': 10691600.0},
#  {'circulating_supply': 26680106.3681,
#   'market_cap': 121022296.491,
#   'name': 'Aragon',
#   'platform': 'Ethereum',
#   'price': 4.53605,
#   'symbol': 'ANT',
#   'volume_24h': 329374.0},
#  {'circulating_supply': 103244552.962,
#   'market_cap': 120509107.108,
#   'name': 'DEW',
#   'platform': 'Ethereum',
#   'price': 1.16722,
#   'symbol': 'DEW',
#   'volume_24h': 198328.0},
#  {'circulating_supply': 1631622325.37,
#   'market_cap': 120132762.248,
#   'name': 'Time New Bank',
#   'platform': 'Ethereum',
#   'price': 0.0736278,
#   'symbol': 'TNB',
#   'volume_24h': 13980100.0},
#  {'circulating_supply': 79070793.2388,
#   'market_cap': 109401558.817,
#   'name': 'iExec RLC',
#   'platform': 'Ethereum',
#   'price': 1.38359,
#   'symbol': 'RLC',
#   'volume_24h': 1158240.0},
#  {'circulating_supply': 756192535.064,
#   'market_cap': 109021033.973,
#   'name': 'Enjin Coin',
#   'platform': 'Ethereum',
#   'price': 0.144171,
#   'symbol': 'ENJ',
#   'volume_24h': 1077080.0},
#  {'circulating_supply': 82500000.0,
#   'market_cap': 109002300.0,
#   'name': 'PayPie',
#   'platform': 'Ethereum',
#   'price': 1.32124,
#   'symbol': 'PPP',
#   'volume_24h': 335258.0},
#  {'circulating_supply': 62660370.957,
#   'market_cap': 108178744.231,
#   'name': 'Santiment Net...',
#   'platform': 'Ethereum',
#   'price': 1.72643,
#   'symbol': 'SAN',
#   'volume_24h': 1797560.0},
#  {'circulating_supply': 165000000.0,
#   'market_cap': 107623395.0,
#   'name': 'Bluzelle',
#   'platform': 'Ethereum',
#   'price': 0.652263,
#   'symbol': 'BLZ',
#   'volume_24h': 21972400.0},
#  {'circulating_supply': 98939459.119,
#   'market_cap': 104646287.121,
#   'name': 'SIRIN LABS Token',
#   'platform': 'Ethereum',
#   'price': 1.05768,
#   'symbol': 'SRN',
#   'volume_24h': 16710300.0},
#  {'circulating_supply': 2734798357.25,
#   'market_cap': 103938199.406,
#   'name': 'Storm',
#   'platform': 'Ethereum',
#   'price': 0.0380058,
#   'symbol': 'STORM',
#   'volume_24h': 1275410.0},
#  {'circulating_supply': 1494971208.89,
#   'market_cap': 102423168.469,
#   'name': 'BLOCKv',
#   'platform': 'Ethereum',
#   'price': 0.0685118,
#   'symbol': 'VEE',
#   'volume_24h': 634885.0},
#  {'circulating_supply': 13195542.215,
#   'market_cap': 100594368.7,
#   'name': 'Monaco',
#   'platform': 'Ethereum',
#   'price': 7.62336,
#   'symbol': 'MCO',
#   'volume_24h': 3501610.0},
#  {'circulating_supply': 42000000.0,
#   'market_cap': 97434120.0,
#   'name': 'Agoras Tokens',
#   'platform': 'Omni',
#   'price': 2.31986,
#   'symbol': 'AGRS',
#   'volume_24h': 255468.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 93375600.0,
#   'name': 'AirSwap',
#   'platform': 'Ethereum',
#   'price': 0.622504,
#   'symbol': 'AST',
#   'volume_24h': 4770930.0},
#  {'circulating_supply': 900000000.0,
#   'market_cap': 92022300.0,
#   'name': 'DeepBrain Chain',
#   'platform': 'NEO',
#   'price': 0.102247,
#   'symbol': 'DBC',
#   'volume_24h': 3944390.0},
#  {'circulating_supply': 490533008.753,
#   'market_cap': 91230800.5669,
#   'name': 'Ripio Credit ...',
#   'platform': 'Ethereum',
#   'price': 0.185983,
#   'symbol': 'RCN',
#   'volume_24h': 5475080.0},
#  {'circulating_supply': 39335007.2487,
#   'market_cap': 91147472.1468,
#   'name': 'CRYPTO20',
#   'platform': 'Ethereum',
#   'price': 2.31721,
#   'symbol': 'C20',
#   'volume_24h': 2901580.0},
#  {'circulating_supply': 199902472.36,
#   'market_cap': 89696839.0553,
#   'name': 'VIBE',
#   'platform': 'Ethereum',
#   'price': 0.448703,
#   'symbol': 'VIBE',
#   'volume_24h': 2187870.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 89338500.0,
#   'name': 'Jibrel Network',
#   'platform': 'Ethereum',
#   'price': 0.59559,
#   'symbol': 'JNT',
#   'volume_24h': 10130500.0},
#  {'circulating_supply': 105378066.049,
#   'market_cap': 88930762.8779,
#   'name': 'Bibox Token',
#   'platform': 'Ethereum',
#   'price': 0.843921,
#   'symbol': 'BIX',
#   'volume_24h': 24100100.0},
#  {'circulating_supply': 189600317.903,
#   'market_cap': 88644405.4302,
#   'name': 'SophiaTX',
#   'platform': 'Ethereum',
#   'price': 0.467533,
#   'symbol': 'SPHTX',
#   'volume_24h': 516960.0},
#  {'circulating_supply': 38327424.5,
#   'market_cap': 88399521.6895,
#   'name': 'IoT Chain',
#   'platform': 'Ethereum',
#   'price': 2.30643,
#   'symbol': 'ITC',
#   'volume_24h': 11558000.0},
#  {'circulating_supply': 1042852948.02,
#   'market_cap': 87918134.9243,
#   'name': 'ETHLend',
#   'platform': 'Ethereum',
#   'price': 0.0843054,
#   'symbol': 'LEND',
#   'volume_24h': 3558760.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 86450400.0,
#   'name': 'SingularDTV',
#   'platform': 'Ethereum',
#   'price': 0.144084,
#   'symbol': 'SNGLS',
#   'volume_24h': 1246440.0},
#  {'circulating_supply': 482511957.017,
#   'market_cap': 84680848.4566,
#   'name': 'MediShares',
#   'platform': 'Ethereum',
#   'price': 0.1755,
#   'symbol': 'MDS',
#   'volume_24h': 2783490.0},
#  {'circulating_supply': 358169121.008,
#   'market_cap': 83541872.9678,
#   'name': 'Cobinhood',
#   'platform': 'Ethereum',
#   'price': 0.233247,
#   'symbol': 'COB',
#   'volume_24h': 1116.58},
#  {'circulating_supply': 300043386.0,
#   'market_cap': 82897186.8576,
#   'name': 'SpankChain',
#   'platform': 'Ethereum',
#   'price': 0.276284,
#   'symbol': 'SPANK',
#   'volume_24h': 224895.0},
#  {'circulating_supply': 443411828.912,
#   'market_cap': 80842844.6473,
#   'name': 'CyberMiles',
#   'platform': 'Ethereum',
#   'price': 0.18232,
#   'symbol': 'CMT',
#   'volume_24h': 5595020.0},
#  {'circulating_supply': 359600000.0,
#   'market_cap': 80817223.2,
#   'name': 'SONM',
#   'platform': 'Ethereum',
#   'price': 0.224742,
#   'symbol': 'SNM',
#   'volume_24h': 1227560.0},
#  {'circulating_supply': 144590975.0,
#   'market_cap': 77822911.2923,
#   'name': 'Ambrosus',
#   'platform': 'Ethereum',
#   'price': 0.538228,
#   'symbol': 'AMB',
#   'volume_24h': 4926150.0},
#  {'circulating_supply': 272889439.003,
#   'market_cap': 77601569.7694,
#   'name': 'Simple Token',
#   'platform': 'Ethereum',
#   'price': 0.28437,
#   'symbol': 'OST',
#   'volume_24h': 2099570.0},
#  {'circulating_supply': 60248315.0,
#   'market_cap': 77307625.3923,
#   'name': 'AdEx',
#   'platform': 'Ethereum',
#   'price': 1.28315,
#   'symbol': 'ADX',
#   'volume_24h': 13329500.0},
#  {'circulating_supply': 183000000.0,
#   'market_cap': 75561798.0,
#   'name': 'Wagerr',
#   'platform': 'Waves',
#   'price': 0.412906,
#   'symbol': 'WGR',
#   'volume_24h': 298902.0},
#  {'circulating_supply': 19300994.0,
#   'market_cap': 73926860.2287,
#   'name': 'Metal',
#   'platform': 'Ethereum',
#   'price': 3.83021,
#   'symbol': 'MTL',
#   'volume_24h': 9940540.0},
#  {'circulating_supply': 52000000.0,
#   'market_cap': 73521760.0,
#   'name': 'Quantum Resis...',
#   'platform': 'Ethereum',
#   'price': 1.41388,
#   'symbol': 'QRL',
#   'volume_24h': 867614.0},
#  {'circulating_supply': 69966926.2205,
#   'market_cap': 72864256.6353,
#   'name': 'Oyster',
#   'platform': 'Ethereum',
#   'price': 1.04141,
#   'symbol': 'PRL',
#   'volume_24h': 2270820.0},
#  {'circulating_supply': 20970629778.4,
#   'market_cap': 71404155.5704,
#   'name': 'Telcoin',
#   'platform': 'Ethereum',
#   'price': 0.00340496,
#   'symbol': 'TEL',
#   'volume_24h': 994290.0},
#  {'circulating_supply': 265118238.708,
#   'market_cap': 71215265.927,
#   'name': 'UTRUST',
#   'platform': 'Ethereum',
#   'price': 0.268617,
#   'symbol': 'UTK',
#   'volume_24h': 1924710.0},
#  {'circulating_supply': 45248032.811,
#   'market_cap': 69882419.3143,
#   'name': 'WaBi',
#   'platform': 'Ethereum',
#   'price': 1.54443,
#   'symbol': 'WABI',
#   'volume_24h': 1428140.0},
#  {'circulating_supply': 333333333.0,
#   'market_cap': 69814666.5969,
#   'name': 'Trinity Netwo...',
#   'platform': 'NEO',
#   'price': 0.209444,
#   'symbol': 'TNC',
#   'volume_24h': 3411380.0},
#  {'circulating_supply': 82046276.0,
#   'market_cap': 69146878.441,
#   'name': 'Edgeless',
#   'platform': 'Ethereum',
#   'price': 0.842779,
#   'symbol': 'EDG',
#   'volume_24h': 707075.0},
#  {'circulating_supply': 18266200.0,
#   'market_cap': 68942849.308,
#   'name': 'Modum',
#   'platform': 'Ethereum',
#   'price': 3.77434,
#   'symbol': 'MOD',
#   'volume_24h': 2382880.0},
#  {'circulating_supply': 28173693.3685,
#   'market_cap': 67737729.229,
#   'name': 'INS Ecosystem',
#   'platform': 'Ethereum',
#   'price': 2.40429,
#   'symbol': 'INS',
#   'volume_24h': 17730100.0},
#  {'circulating_supply': 98028877.0,
#   'market_cap': 66162826.0114,
#   'name': 'MobileGo',
#   'platform': 'Ethereum',
#   'price': 0.674932,
#   'symbol': 'MGO',
#   'volume_24h': 425362.0},
#  {'circulating_supply': 599400.0,
#   'market_cap': 66076057.8,
#   'name': 'Melon',
#   'platform': 'Ethereum',
#   'price': 110.237,
#   'symbol': 'MLN',
#   'volume_24h': 246443.0},
#  {'circulating_supply': 428481269.499,
#   'market_cap': 64189493.5399,
#   'name': 'Tierion',
#   'platform': 'Ethereum',
#   'price': 0.149807,
#   'symbol': 'TNT',
#   'volume_24h': 4293240.0},
#  {'circulating_supply': 677154514.0,
#   'market_cap': 64045612.5114,
#   'name': 'Streamr DATAcoin',
#   'platform': 'Ethereum',
#   'price': 0.0945805,
#   'symbol': 'DATA',
#   'volume_24h': 411596.0},
#  {'circulating_supply': 563264706.0,
#   'market_cap': 63088463.3955,
#   'name': 'Theta Token',
#   'platform': 'Ethereum',
#   'price': 0.112005,
#   'symbol': 'THETA',
#   'volume_24h': 8148350.0},
#  {'circulating_supply': 100054311.845,
#   'market_cap': 62325631.8258,
#   'name': 'AppCoins',
#   'platform': 'Ethereum',
#   'price': 0.622918,
#   'symbol': 'APPC',
#   'volume_24h': 2771090.0},
#  {'circulating_supply': 240000000.0,
#   'market_cap': 62215200.0,
#   'name': 'QLINK',
#   'platform': 'NEO',
#   'price': 0.25923,
#   'symbol': 'QLC',
#   'volume_24h': 1707250.0},
#  {'circulating_supply': 29261461.2776,
#   'market_cap': 62068533.8182,
#   'name': 'Eidoo',
#   'platform': 'Ethereum',
#   'price': 2.12117,
#   'symbol': 'EDO',
#   'volume_24h': 2207620.0},
#  {'circulating_supply': 68000000.0,
#   'market_cap': 61221828.0,
#   'name': 'Centra',
#   'platform': 'Ethereum',
#   'price': 0.900321,
#   'symbol': 'CTR',
#   'volume_24h': 2254930.0},
#  {'circulating_supply': 140423304.35,
#   'market_cap': 61031899.923,
#   'name': 'Unikoin Gold',
#   'platform': 'Ethereum',
#   'price': 0.434628,
#   'symbol': 'UKG',
#   'volume_24h': 1902280.0},
#  {'circulating_supply': 89708333.0,
#   'market_cap': 60486920.0252,
#   'name': 'Wings',
#   'platform': 'Ethereum',
#   'price': 0.674262,
#   'symbol': 'WINGS',
#   'volume_24h': 974191.0},
#  {'circulating_supply': 157861326.54,
#   'market_cap': 59776559.2143,
#   'name': 'Gifto',
#   'platform': 'Ethereum',
#   'price': 0.378665,
#   'symbol': 'GTO',
#   'volume_24h': 79596000.0},
#  {'circulating_supply': 32105577.5103,
#   'market_cap': 59328217.7371,
#   'name': 'Triggers',
#   'platform': 'Counterparty',
#   'price': 1.84791,
#   'symbol': 'TRIG',
#   'volume_24h': 1635430.0},
#  {'circulating_supply': 651246649.17,
#   'market_cap': 57498566.6552,
#   'name': 'CoinDash',
#   'platform': 'Ethereum',
#   'price': 0.08829,
#   'symbol': 'CDT',
#   'volume_24h': 2320850.0},
#  {'circulating_supply': 23564882.3,
#   'market_cap': 57299189.5566,
#   'name': 'Nuls',
#   'platform': 'Ethereum',
#   'price': 2.43155,
#   'symbol': 'NULS',
#   'volume_24h': 4794960.0},
#  {'circulating_supply': 3726780.89997,
#   'market_cap': 56874030.6363,
#   'name': 'Genesis Vision',
#   'platform': 'Ethereum',
#   'price': 15.2609,
#   'symbol': 'GVT',
#   'volume_24h': 1136330.0},
#  {'circulating_supply': 485146252.554,
#   'market_cap': 54691022.1967,
#   'name': 'Etherparty',
#   'platform': 'Ethereum',
#   'price': 0.112731,
#   'symbol': 'FUEL',
#   'volume_24h': 723902.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 52950060.0,
#   'name': 'district0x',
#   'platform': 'Ethereum',
#   'price': 0.0882501,
#   'symbol': 'DNT',
#   'volume_24h': 3178440.0},
#  {'circulating_supply': 375000000.0,
#   'market_cap': 52702875.0,
#   'name': 'Hive',
#   'platform': 'Ethereum',
#   'price': 0.140541,
#   'symbol': 'HVN',
#   'volume_24h': 228067.0},
#  {'circulating_supply': 57672338.0,
#   'market_cap': 52431075.9226,
#   'name': 'NAGA',
#   'platform': 'Ethereum',
#   'price': 0.90912,
#   'symbol': 'NGC',
#   'volume_24h': 260088.0},
#  {'circulating_supply': 59888398.693,
#   'market_cap': 50963829.5198,
#   'name': 'Bread',
#   'platform': 'Ethereum',
#   'price': 0.85098,
#   'symbol': 'BRD',
#   'volume_24h': 5579430.0},
#  {'circulating_supply': 4660285459.8,
#   'market_cap': 50192672.4877,
#   'name': 'ATMChain',
#   'platform': 'Ethereum',
#   'price': 0.0107703,
#   'symbol': 'ATM',
#   'volume_24h': 43901.7},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 48730050.0,
#   'name': 'Internet Node...',
#   'platform': 'Ethereum',
#   'price': 0.324867,
#   'symbol': 'INT',
#   'volume_24h': 1347030.0},
#  {'circulating_supply': 100000000.0,
#   'market_cap': 48693100.0,
#   'name': 'Mercury',
#   'platform': 'Waves',
#   'price': 0.486931,
#   'symbol': 'MER',
#   'volume_24h': 6345700.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 47588280.0,
#   'name': 'adToken',
#   'platform': 'Ethereum',
#   'price': 0.0793138,
#   'symbol': 'ADT',
#   'volume_24h': 1387380.0},
#  {'circulating_supply': 399934364.226,
#   'market_cap': 46375589.0069,
#   'name': 'indaHash',
#   'platform': 'Ethereum',
#   'price': 0.115958,
#   'symbol': 'IDH',
#   'volume_24h': 201140.0},
#  {'circulating_supply': 254507605.599,
#   'market_cap': 46046279.5278,
#   'name': 'OriginTrail',
#   'platform': 'Ethereum',
#   'price': 0.180923,
#   'symbol': 'TRAC',
#   'volume_24h': 367249.0},
#  {'circulating_supply': 1543157590.0,
#   'market_cap': 45756011.3853,
#   'name': 'Safe Exchange...',
#   'platform': 'Omni',
#   'price': 0.0296509,
#   'symbol': 'SAFEX',
#   'volume_24h': 17289.8},
#  {'circulating_supply': 582029028.5,
#   'market_cap': 44727475.7677,
#   'name': 'Energo',
#   'platform': 'Ethereum',
#   'price': 0.0768475,
#   'symbol': 'TSL',
#   'volume_24h': 1453170.0},
#  {'circulating_supply': 66000000.0,
#   'market_cap': 44643456.0,
#   'name': 'LOCIcoin',
#   'platform': 'Ethereum',
#   'price': 0.676416,
#   'symbol': 'LOCI',
#   'volume_24h': 365561.0},
#  {'circulating_supply': 31432398.8758,
#   'market_cap': 44127316.1337,
#   'name': 'Decision Token',
#   'platform': 'Ethereum',
#   'price': 1.40388,
#   'symbol': 'HST',
#   'volume_24h': 234783.0},
#  {'circulating_supply': 8146000.7794,
#   'market_cap': 43963477.4464,
#   'name': 'TaaS',
#   'platform': 'Ethereum',
#   'price': 5.39694,
#   'symbol': 'TAAS',
#   'volume_24h': 290942.0},
#  {'circulating_supply': 65001234.0554,
#   'market_cap': 43911908.6723,
#   'name': 'COSS',
#   'platform': 'Ethereum',
#   'price': 0.675555,
#   'symbol': 'COSS',
#   'volume_24h': 263075.0},
#  {'circulating_supply': 155000000.0,
#   'market_cap': 43894760.0,
#   'name': 'Presearch',
#   'platform': 'Ethereum',
#   'price': 0.283192,
#   'symbol': 'PRE',
#   'volume_24h': 34018.2},
#  {'circulating_supply': 85558370.5,
#   'market_cap': 43688414.0533,
#   'name': 'FirstBlood',
#   'platform': 'Ethereum',
#   'price': 0.510627,
#   'symbol': '1ST',
#   'volume_24h': 2803670.0},
#  {'circulating_supply': 164966467.432,
#   'market_cap': 42879733.8795,
#   'name': 'Viberate',
#   'platform': 'Ethereum',
#   'price': 0.25993,
#   'symbol': 'VIB',
#   'volume_24h': 5582300.0},
#  {'circulating_supply': 806408544.994,
#   'market_cap': 41611326.0485,
#   'name': 'Datum',
#   'platform': 'Ethereum',
#   'price': 0.0516008,
#   'symbol': 'DAT',
#   'volume_24h': 2008980.0},
#  {'circulating_supply': 329118078.46,
#   'market_cap': 41523511.487,
#   'name': 'Cappasity',
#   'platform': 'Ethereum',
#   'price': 0.126166,
#   'symbol': 'CAPP',
#   'volume_24h': 142892.0},
#  {'circulating_supply': 2297853.07853,
#   'market_cap': 41365951.1197,
#   'name': 'Lunyr',
#   'platform': 'Ethereum',
#   'price': 18.002,
#   'symbol': 'LUN',
#   'volume_24h': 1721330.0},
#  {'circulating_supply': 2000000000.0,
#   'market_cap': 40931400.0,
#   'name': 'Odyssey',
#   'platform': 'Ethereum',
#   'price': 0.0204657,
#   'symbol': 'OCN',
#   'volume_24h': 4896460.0},
#  {'circulating_supply': 24463326.5123,
#   'market_cap': 40040349.669,
#   'name': 'TokenCard',
#   'platform': 'Ethereum',
#   'price': 1.63675,
#   'symbol': 'TKN',
#   'volume_24h': 114791.0},
#  {'circulating_supply': 65351403.0,
#   'market_cap': 39115101.9946,
#   'name': 'Qbao',
#   'platform': 'Qtum',
#   'price': 0.598535,
#   'symbol': 'QBT',
#   'volume_24h': 5759630.0},
#  {'circulating_supply': 346139198.325,
#   'market_cap': 38644364.6578,
#   'name': 'BitDegree',
#   'platform': 'Ethereum',
#   'price': 0.111644,
#   'symbol': 'BDG',
#   'volume_24h': 123765.0},
#  {'circulating_supply': 178250000.0,
#   'market_cap': 38501287.0,
#   'name': 'Ink',
#   'platform': 'Qtum',
#   'price': 0.215996,
#   'symbol': 'INK',
#   'volume_24h': 64790400.0},
#  {'circulating_supply': 162862944.036,
#   'market_cap': 38456501.2492,
#   'name': 'Humaniq',
#   'platform': 'Ethereum',
#   'price': 0.236128,
#   'symbol': 'HMQ',
#   'volume_24h': 5334120.0},
#  {'circulating_supply': 5171589622.24,
#   'market_cap': 37890375.3899,
#   'name': 'carVertical',
#   'platform': 'Ethereum',
#   'price': 0.00732664,
#   'symbol': 'CV',
#   'volume_24h': 771810.0},
#  {'circulating_supply': 30333338.8577,
#   'market_cap': 37856916.8946,
#   'name': 'Delphy',
#   'platform': 'Ethereum',
#   'price': 1.24803,
#   'symbol': 'DPY',
#   'volume_24h': 2077290.0},
#  {'circulating_supply': 85978873.0,
#   'market_cap': 37136940.5938,
#   'name': 'Agrello',
#   'platform': 'Ethereum',
#   'price': 0.431931,
#   'symbol': 'DLT',
#   'volume_24h': 13245400.0},
#  {'circulating_supply': 10500000.0,
#   'market_cap': 35823585.0,
#   'name': 'Nimiq',
#   'platform': 'Ethereum',
#   'price': 3.41177,
#   'symbol': 'NET',
#   'volume_24h': 343606.0},
#  {'circulating_supply': 142215728.19,
#   'market_cap': 35796552.0798,
#   'name': 'Lamden',
#   'platform': 'Ethereum',
#   'price': 0.251706,
#   'symbol': 'TAU',
#   'volume_24h': 166440.0},
#  {'circulating_supply': 213193000.0,
#   'market_cap': 34835736.2,
#   'name': 'bitCNY',
#   'platform': 'BitShares',
#   'price': 0.1634,
#   'symbol': 'BITCNY',
#   'volume_24h': 43409500.0},
#  {'circulating_supply': 231436247.173,
#   'market_cap': 34779544.9164,
#   'name': 'YOYOW',
#   'platform': 'BitShares',
#   'price': 0.150277,
#   'symbol': 'YOYOW',
#   'volume_24h': 1720530.0},
#  {'circulating_supply': 325000000.0,
#   'market_cap': 34094450.0,
#   'name': 'Cofound.it',
#   'platform': 'Ethereum',
#   'price': 0.104906,
#   'symbol': 'CFI',
#   'volume_24h': 272738.0},
#  {'circulating_supply': 216973356.3,
#   'market_cap': 33685981.459,
#   'name': 'Monetha',
#   'platform': 'Ethereum',
#   'price': 0.155254,
#   'symbol': 'MTH',
#   'volume_24h': 661248.0},
#  {'circulating_supply': 701884009.0,
#   'market_cap': 33594835.83,
#   'name': 'Pepe Cash',
#   'platform': 'Counterparty',
#   'price': 0.0478638,
#   'symbol': 'PEPECASH',
#   'volume_24h': 253317.0},
#  {'circulating_supply': 1750000000.0,
#   'market_cap': 33248425.0,
#   'name': 'SwftCoin',
#   'platform': 'Ethereum',
#   'price': 0.0189991,
#   'symbol': 'SWFTC',
#   'volume_24h': 16815700.0},
#  {'circulating_supply': 201000000.0,
#   'market_cap': 32169648.0,
#   'name': 'InsurePal',
#   'platform': 'Ethereum',
#   'price': 0.160048,
#   'symbol': 'IPL',
#   'volume_24h': 61882.9},
#  {'circulating_supply': 39483257.6434,
#   'market_cap': 32088872.6352,
#   'name': 'Bloom',
#   'platform': 'Ethereum',
#   'price': 0.812721,
#   'symbol': 'BLT',
#   'volume_24h': 772594.0},
#  {'circulating_supply': 92147500.0,
#   'market_cap': 32068067.18,
#   'name': 'WeTrust',
#   'platform': 'Ethereum',
#   'price': 0.348008,
#   'symbol': 'TRST',
#   'volume_24h': 225422.0},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 31352320.0,
#   'name': 'Blocktix',
#   'platform': 'Ethereum',
#   'price': 0.783808,
#   'symbol': 'TIX',
#   'volume_24h': 2251420.0},
#  {'circulating_supply': 175109299.0,
#   'market_cap': 30692632.6008,
#   'name': 'Worldcore',
#   'platform': 'Ethereum',
#   'price': 0.175277,
#   'symbol': 'WRC',
#   'volume_24h': 1407640.0},
#  {'circulating_supply': 77839404.0,
#   'market_cap': 30084696.1278,
#   'name': 'LAToken',
#   'platform': 'Ethereum',
#   'price': 0.386497,
#   'symbol': 'LA',
#   'volume_24h': 5318040.0},
#  {'circulating_supply': 1153170765.0,
#   'market_cap': 29800700.1774,
#   'name': 'Zeusshield',
#   'platform': 'Ethereum',
#   'price': 0.0258424,
#   'symbol': 'ZSC',
#   'volume_24h': 831913.0},
#  {'circulating_supply': 114378947.154,
#   'market_cap': 28991059.8405,
#   'name': 'SunContract',
#   'platform': 'Ethereum',
#   'price': 0.253465,
#   'symbol': 'SNC',
#   'volume_24h': 3902870.0},
#  {'circulating_supply': 16500000.0,
#   'market_cap': 28935720.0,
#   'name': 'Everex',
#   'platform': 'Ethereum',
#   'price': 1.75368,
#   'symbol': 'EVX',
#   'volume_24h': 2220110.0},
#  {'circulating_supply': 30150150.1476,
#   'market_cap': 28900396.2739,
#   'name': 'Maecenas',
#   'platform': 'Ethereum',
#   'price': 0.958549,
#   'symbol': 'ART',
#   'volume_24h': 6923.92},
#  {'circulating_supply': 84285535.961,
#   'market_cap': 28885580.3147,
#   'name': 'Trade Token',
#   'platform': 'Ethereum',
#   'price': 0.342711,
#   'symbol': 'TIO',
#   'volume_24h': 304987.0},
#  {'circulating_supply': 1877455408.41,
#   'market_cap': 28719435.3825,
#   'name': 'Selfkey',
#   'platform': 'Ethereum',
#   'price': 0.015297,
#   'symbol': 'KEY',
#   'volume_24h': 612377.0},
#  {'circulating_supply': 501394405.74,
#   'market_cap': 28487425.1143,
#   'name': 'BitClave',
#   'platform': 'Ethereum',
#   'price': 0.0568164,
#   'symbol': 'CAT',
#   'volume_24h': 677670.0},
#  {'circulating_supply': 2913286556.81,
#   'market_cap': 28317116.1993,
#   'name': 'bitqy',
#   'platform': 'Ethereum',
#   'price': 0.00971999,
#   'symbol': 'BQ',
#   'volume_24h': 1926.04},
#  {'circulating_supply': 1292802.22735,
#   'market_cap': 27945859.3474,
#   'name': 'Numeraire',
#   'platform': 'Ethereum',
#   'price': 21.6165,
#   'symbol': 'NMR',
#   'volume_24h': 1275180.0},
#  {'circulating_supply': 35778843.8312,
#   'market_cap': 27930289.3119,
#   'name': 'iXledger',
#   'platform': 'Ethereum',
#   'price': 0.780637,
#   'symbol': 'IXT',
#   'volume_24h': 553052.0},
#  {'circulating_supply': 1005414013.0,
#   'market_cap': 27843533.5104,
#   'name': 'Karma',
#   'platform': 'BitShares',
#   'price': 0.0276936,
#   'symbol': 'KRM',
#   'volume_24h': 74455.6},
#  {'circulating_supply': 82256324.0,
#   'market_cap': 27817937.1883,
#   'name': 'Synereo',
#   'platform': 'Omni',
#   'price': 0.338186,
#   'symbol': 'AMP',
#   'volume_24h': 875210.0},
#  {'circulating_supply': 15000000.0,
#   'market_cap': 27067950.0,
#   'name': 'NVO',
#   'platform': 'Counterparty',
#   'price': 1.80453,
#   'symbol': 'NVST',
#   'volume_24h': 7404.59},
#  {'circulating_supply': 26244468.18,
#   'market_cap': 27056209.5808,
#   'name': 'Rivetz',
#   'platform': 'Ethereum',
#   'price': 1.03093,
#   'symbol': 'RVT',
#   'volume_24h': 164749.0},
#  {'circulating_supply': 234565044.0,
#   'market_cap': 26626416.4046,
#   'name': 'Zeepin',
#   'platform': 'NEO',
#   'price': 0.113514,
#   'symbol': 'ZPT',
#   'volume_24h': 2259180.0},
#  {'circulating_supply': 36768687.5503,
#   'market_cap': 26317849.9505,
#   'name': 'Olympus Labs',
#   'platform': 'Ethereum',
#   'price': 0.715768,
#   'symbol': 'MOT',
#   'volume_24h': 862257.0},
#  {'circulating_supply': 17029321.0837,
#   'market_cap': 26153971.9068,
#   'name': 'Ormeus Coin',
#   'platform': 'Ethereum',
#   'price': 1.53582,
#   'symbol': 'ORME',
#   'volume_24h': 3174040.0},
#  {'circulating_supply': 100000000.0,
#   'market_cap': 25934400.0,
#   'name': 'Aurora DAO',
#   'platform': 'Ethereum',
#   'price': 0.259344,
#   'symbol': 'AURA',
#   'volume_24h': 146515.0},
#  {'circulating_supply': 28728253.2784,
#   'market_cap': 25718767.6497,
#   'name': 'Neumark',
#   'platform': 'Ethereum',
#   'price': 0.895243,
#   'symbol': 'NEU',
#   'volume_24h': 122714.0},
#  {'circulating_supply': 19628888.0,
#   'market_cap': 25681455.6148,
#   'name': 'Moeda Loyalty...',
#   'platform': 'Ethereum',
#   'price': 1.30835,
#   'symbol': 'MDA',
#   'volume_24h': 833533.0},
#  {'circulating_supply': 75000000.0,
#   'market_cap': 25524825.0,
#   'name': 'Matchpool',
#   'platform': 'Ethereum',
#   'price': 0.340331,
#   'symbol': 'GUP',
#   'volume_24h': 3859490.0},
#  {'circulating_supply': 263034654.051,
#   'market_cap': 24681620.0317,
#   'name': 'HelloGold',
#   'platform': 'Ethereum',
#   'price': 0.0938341,
#   'symbol': 'HGT',
#   'volume_24h': 83473.0},
#  {'circulating_supply': 3592379.31019,
#   'market_cap': 24320515.7013,
#   'name': 'Open Trading ...',
#   'platform': 'Ethereum',
#   'price': 6.77003,
#   'symbol': 'OTN',
#   'volume_24h': 67018.9},
#  {'circulating_supply': 16681759.3911,
#   'market_cap': 23980029.1246,
#   'name': 'Propy',
#   'platform': 'Ethereum',
#   'price': 1.4375,
#   'symbol': 'PRO',
#   'volume_24h': 9649400.0},
#  {'circulating_supply': 987831611.047,
#   'market_cap': 23971117.0063,
#   'name': 'Soarcoin',
#   'platform': 'Ethereum',
#   'price': 0.0242664,
#   'symbol': 'SOAR',
#   'volume_24h': 258599.0},
#  {'circulating_supply': 25009249.58,
#   'market_cap': 23947481.8891,
#   'name': 'OAX',
#   'platform': 'Ethereum',
#   'price': 0.957545,
#   'symbol': 'OAX',
#   'volume_24h': 10541800.0},
#  {'circulating_supply': 349367127.0,
#   'market_cap': 23859923.1283,
#   'name': 'QunQun',
#   'platform': 'Ethereum',
#   'price': 0.0682947,
#   'symbol': 'QUN',
#   'volume_24h': 9579610.0},
#  {'circulating_supply': 300000000.0,
#   'market_cap': 23136780.0,
#   'name': 'Game.com',
#   'platform': 'Ethereum',
#   'price': 0.0771226,
#   'symbol': 'GTC',
#   'volume_24h': 1039160.0},
#  {'circulating_supply': 13000000.0,
#   'market_cap': 22939540.0,
#   'name': 'Aeron',
#   'platform': 'Ethereum',
#   'price': 1.76458,
#   'symbol': 'ARN',
#   'volume_24h': 2788460.0},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 22790040.0,
#   'name': 'Bodhi',
#   'platform': 'Qtum',
#   'price': 0.569751,
#   'symbol': 'BOT',
#   'volume_24h': 1134330.0},
#  {'circulating_supply': 37886425.0906,
#   'market_cap': 22424217.2826,
#   'name': 'CanYaCoin',
#   'platform': 'Ethereum',
#   'price': 0.59188,
#   'symbol': 'CAN',
#   'volume_24h': 318782.0},
#  {'circulating_supply': 229389301.0,
#   'market_cap': 22412275.2038,
#   'name': 'Hydro Protocol',
#   'platform': 'Ethereum',
#   'price': 0.0977041,
#   'symbol': 'HOT',
#   'volume_24h': 520439.0},
#  {'circulating_supply': 8049000.11223,
#   'market_cap': 22180227.1593,
#   'name': 'Swarm City',
#   'platform': 'Ethereum',
#   'price': 2.75565,
#   'symbol': 'SWT',
#   'volume_24h': 1630460.0},
#  {'circulating_supply': 45166200.0,
#   'market_cap': 21795627.303,
#   'name': 'BlockMason Cr...',
#   'platform': 'Ethereum',
#   'price': 0.482565,
#   'symbol': 'BCPT',
#   'volume_24h': 600643.0},
#  {'circulating_supply': 591500000.0,
#   'market_cap': 21095374.3,
#   'name': 'DomRaider',
#   'platform': 'Ethereum',
#   'price': 0.0356642,
#   'symbol': 'DRT',
#   'volume_24h': 972.747},
#  {'circulating_supply': 140000000.0,
#   'market_cap': 20870640.0,
#   'name': 'Mothership',
#   'platform': 'Ethereum',
#   'price': 0.149076,
#   'symbol': 'MSP',
#   'volume_24h': 107435.0},
#  {'circulating_supply': 2799476.19933,
#   'market_cap': 20411428.8855,
#   'name': 'MyBit Token',
#   'platform': 'Ethereum',
#   'price': 7.29116,
#   'symbol': 'MYB',
#   'volume_24h': 1080110.0},
#  {'circulating_supply': 42186587.0561,
#   'market_cap': 19997707.8622,
#   'name': 'Stox',
#   'platform': 'Ethereum',
#   'price': 0.47403,
#   'symbol': 'STX',
#   'volume_24h': 736648.0},
#  {'circulating_supply': 62166377.609,
#   'market_cap': 19866944.4572,
#   'name': 'EncrypGen',
#   'platform': 'Ethereum',
#   'price': 0.319577,
#   'symbol': 'DNA',
#   'volume_24h': 128228.0},
#  {'circulating_supply': 10000000.0,
#   'market_cap': 19360800.0,
#   'name': 'Uquid Coin',
#   'platform': 'Ethereum',
#   'price': 1.93608,
#   'symbol': 'UQC',
#   'volume_24h': 67114.7},
#  {'circulating_supply': 13631512.4213,
#   'market_cap': 19245514.4969,
#   'name': 'Playkey',
#   'platform': 'Ethereum',
#   'price': 1.41184,
#   'symbol': 'PKT',
#   'volume_24h': 2771.71},
#  {'circulating_supply': 17500000.0,
#   'market_cap': 19217100.0,
#   'name': 'Covesting',
#   'platform': 'Ethereum',
#   'price': 1.09812,
#   'symbol': 'COV',
#   'volume_24h': 66471.7},
#  {'circulating_supply': 405001426.0,
#   'market_cap': 19184634.0486,
#   'name': 'Snovio',
#   'platform': 'Ethereum',
#   'price': 0.0473693,
#   'symbol': 'SNOV',
#   'volume_24h': 654584.0},
#  {'circulating_supply': 3798358.94793,
#   'market_cap': 19092147.3831,
#   'name': 'Hacken',
#   'platform': 'Ethereum',
#   'price': 5.02642,
#   'symbol': 'HKN',
#   'volume_24h': 84923.4},
#  {'circulating_supply': 6999991.0,
#   'market_cap': 18978305.5993,
#   'name': 'ClearPoll',
#   'platform': 'Ethereum',
#   'price': 2.71119,
#   'symbol': 'POLL',
#   'volume_24h': 420561.0},
#  {'circulating_supply': 1050000000.0,
#   'market_cap': 18726645.0,
#   'name': 'AirToken',
#   'platform': 'Ethereum',
#   'price': 0.0178349,
#   'symbol': 'AIR',
#   'volume_24h': 337510.0},
#  {'circulating_supply': 9973579.0,
#   'market_cap': 18634834.4752,
#   'name': 'Waves Communi...',
#   'platform': 'Waves',
#   'price': 1.86842,
#   'symbol': 'WCT',
#   'volume_24h': 67646.0},
#  {'circulating_supply': 13853582587.9,
#   'market_cap': 18627804.2194,
#   'name': 'LIFE',
#   'platform': 'Ethereum',
#   'price': 0.00134462,
#   'symbol': 'LIFE',
#   'volume_24h': 74539.8},
#  {'circulating_supply': 321137782.25,
#   'market_cap': 18576247.128,
#   'name': 'KickCoin',
#   'platform': 'Ethereum',
#   'price': 0.0578451,
#   'symbol': 'KICK',
#   'volume_24h': 525077.0},
#  {'circulating_supply': 122873786.567,
#   'market_cap': 18256587.2082,
#   'name': 'Bounty0x',
#   'platform': 'Ethereum',
#   'price': 0.14858,
#   'symbol': 'BNTY',
#   'volume_24h': 260414.0},
#  {'circulating_supply': 2777600756.0,
#   'market_cap': 18229504.8657,
#   'name': 'NuShares',
#   'platform': 'NuBits',
#   'price': 0.00656304,
#   'symbol': 'NSR',
#   'volume_24h': 10288.8},
#  {'circulating_supply': 498887536.723,
#   'market_cap': 18217975.956,
#   'name': 'Voise',
#   'platform': 'Ethereum',
#   'price': 0.0365172,
#   'symbol': 'VOISE',
#   'volume_24h': 578017.0},
#  {'circulating_supply': 30000000.0,
#   'market_cap': 17930280.0,
#   'name': 'OracleChain',
#   'platform': 'BitShares',
#   'price': 0.597676,
#   'symbol': 'OCT',
#   'volume_24h': 41908.4},
#  {'circulating_supply': 7001622.64879,
#   'market_cap': 17866600.6427,
#   'name': 'Etheroll',
#   'platform': 'Ethereum',
#   'price': 2.55178,
#   'symbol': 'DICE',
#   'volume_24h': 102542.0},
#  {'circulating_supply': 20941493.2783,
#   'market_cap': 17301945.5125,
#   'name': 'Blackmoon',
#   'platform': 'Ethereum',
#   'price': 0.826204,
#   'symbol': 'BMC',
#   'volume_24h': 525233.0},
#  {'circulating_supply': 3820953.60641,
#   'market_cap': 17262418.8316,
#   'name': 'Polybius',
#   'platform': 'Ethereum',
#   'price': 4.51783,
#   'symbol': 'PLBT',
#   'volume_24h': 29595.8},
#  {'circulating_supply': 18897126.0,
#   'market_cap': 17162521.0102,
#   'name': 'eBitcoin',
#   'platform': 'Ethereum',
#   'price': 0.908208,
#   'symbol': 'EBTC',
#   'volume_24h': 114399.0},
#  {'circulating_supply': 20923342.6892,
#   'market_cap': 17067714.6385,
#   'name': 'Profile Utili...',
#   'platform': 'Qtum',
#   'price': 0.815726,
#   'symbol': 'PUT',
#   'volume_24h': 2818370.0},
#  {'circulating_supply': 194929698.0,
#   'market_cap': 16917695.0808,
#   'name': 'CoinMeet',
#   'platform': 'Ethereum',
#   'price': 0.0867887,
#   'symbol': 'MEE',
#   'volume_24h': 1682190.0},
#  {'circulating_supply': 9292966.0,
#   'market_cap': 16883925.2771,
#   'name': 'LockChain',
#   'platform': 'Ethereum',
#   'price': 1.81685,
#   'symbol': 'LOC',
#   'volume_24h': 19067.3},
#  {'circulating_supply': 952429892.0,
#   'market_cap': 16520848.9066,
#   'name': 'Target Coin',
#   'platform': 'Ethereum',
#   'price': 0.017346,
#   'symbol': 'TGT',
#   'volume_24h': 1161.4},
#  {'circulating_supply': 51200000.0,
#   'market_cap': 16443187.2,
#   'name': 'Primas',
#   'platform': 'Ethereum',
#   'price': 0.321156,
#   'symbol': 'PST',
#   'volume_24h': 163505.0},
#  {'circulating_supply': 70000000.0,
#   'market_cap': 16321200.0,
#   'name': 'BitDice',
#   'platform': 'Ethereum',
#   'price': 0.23316,
#   'symbol': 'CSNO',
#   'volume_24h': 14866.7},
#  {'circulating_supply': 46648224.09,
#   'market_cap': 16314143.4663,
#   'name': 'ProChain',
#   'platform': 'Ethereum',
#   'price': 0.349727,
#   'symbol': 'PRA',
#   'volume_24h': 659409.0},
#  {'circulating_supply': 64936616.6361,
#   'market_cap': 16081163.4902,
#   'name': 'Paragon',
#   'platform': 'Ethereum',
#   'price': 0.247644,
#   'symbol': 'PRG',
#   'volume_24h': 70693.3},
#  {'circulating_supply': 127134633.224,
#   'market_cap': 16032567.1919,
#   'name': 'Xaurum',
#   'platform': 'Ethereum',
#   'price': 0.126107,
#   'symbol': 'XAUR',
#   'volume_24h': 75522.0},
#  {'circulating_supply': 3709674.34,
#   'market_cap': 16018744.7676,
#   'name': 'Hedge',
#   'platform': 'Ethereum',
#   'price': 4.3181,
#   'symbol': 'HDG',
#   'volume_24h': 47541.1},
#  {'circulating_supply': 66521026.0,
#   'market_cap': 16004227.1243,
#   'name': 'Nexium',
#   'platform': 'Ethereum',
#   'price': 0.240589,
#   'symbol': 'NXC',
#   'volume_24h': 38988.7},
#  {'circulating_supply': 300000000.0,
#   'market_cap': 15945750.0,
#   'name': 'Xenon',
#   'platform': 'Ethereum',
#   'price': 0.0531525,
#   'symbol': 'XNN',
#   'volume_24h': 723.814},
#  {'circulating_supply': 14851500.0,
#   'market_cap': 15780164.295,
#   'name': 'bitUSD',
#   'platform': 'BitShares',
#   'price': 1.06253,
#   'symbol': 'BITUSD',
#   'volume_24h': 1332720.0},
#  {'circulating_supply': 104693145.124,
#   'market_cap': 15228664.8898,
#   'name': 'DecentBet',
#   'platform': 'Ethereum',
#   'price': 0.14546,
#   'symbol': 'DBET',
#   'volume_24h': 52032.2},
#  {'circulating_supply': 22747808.5,
#   'market_cap': 15027679.9991,
#   'name': 'Databits',
#   'platform': 'Counterparty',
#   'price': 0.660621,
#   'symbol': 'DTB',
#   'volume_24h': 15693.5},
#  {'circulating_supply': 49596285.4494,
#   'market_cap': 14988543.022,
#   'name': 'Blockport',
#   'platform': 'Ethereum',
#   'price': 0.302211,
#   'symbol': 'BPT',
#   'volume_24h': 144675.0},
#  {'circulating_supply': 619212216.98,
#   'market_cap': 14958433.368,
#   'name': 'Viuly',
#   'platform': 'Ethereum',
#   'price': 0.0241572,
#   'symbol': 'VIU',
#   'volume_24h': 1877760.0},
#  {'circulating_supply': 185501578.891,
#   'market_cap': 14936921.0351,
#   'name': 'OneRoot Network',
#   'platform': 'Ethereum',
#   'price': 0.0805218,
#   'symbol': 'RNT',
#   'volume_24h': 53608.7},
#  {'circulating_supply': 574512758.0,
#   'market_cap': 14855004.0298,
#   'name': 'FoldingCoin',
#   'platform': 'Counterparty',
#   'price': 0.0258567,
#   'symbol': 'FLDC',
#   'volume_24h': 94533.5},
#  {'circulating_supply': 36645278.3876,
#   'market_cap': 14766654.6696,
#   'name': 'BLUE',
#   'platform': 'Ethereum',
#   'price': 0.402962,
#   'symbol': 'BLUE',
#   'volume_24h': 15833.0},
#  {'circulating_supply': 76091017.5262,
#   'market_cap': 14766146.7701,
#   'name': 'Quantum',
#   'platform': 'Ethereum',
#   'price': 0.194059,
#   'symbol': 'QAU',
#   'volume_24h': 12778.6},
#  {'circulating_supply': 444444444.4,
#   'market_cap': 14740355.5541,
#   'name': 'Ecobit',
#   'platform': 'NEM',
#   'price': 0.0331658,
#   'symbol': 'ECOB',
#   'volume_24h': 1026.55},
#  {'circulating_supply': 581656.675065,
#   'market_cap': 14724580.5636,
#   'name': 'ICOS',
#   'platform': 'Ethereum',
#   'price': 25.3149,
#   'symbol': 'ICOS',
#   'volume_24h': 246115.0},
#  {'circulating_supply': 14420100.4411,
#   'market_cap': 14378931.0544,
#   'name': 'Dai',
#   'platform': 'Ethereum',
#   'price': 0.997145,
#   'symbol': 'DAI',
#   'volume_24h': 1870550.0},
#  {'circulating_supply': 1000000000.0,
#   'market_cap': 14335100.0,
#   'name': 'Circuits of V...',
#   'platform': 'Counterparty',
#   'price': 0.0143351,
#   'symbol': 'COVAL',
#   'volume_24h': 109927.0},
#  {'circulating_supply': 191381257.0,
#   'market_cap': 14333059.0661,
#   'name': 'InvestFeed',
#   'platform': 'Ethereum',
#   'price': 0.0748927,
#   'symbol': 'IFT',
#   'volume_24h': 19283.7},
#  {'circulating_supply': 193535756.218,
#   'market_cap': 14239412.6173,
#   'name': 'AICHAIN',
#   'platform': 'Ethereum',
#   'price': 0.0735751,
#   'symbol': 'AIT',
#   'volume_24h': 54076.3},
#  {'circulating_supply': 710112.8108,
#   'market_cap': 14183438.2265,
#   'name': 'Chronobank',
#   'platform': 'Ethereum',
#   'price': 19.9735,
#   'symbol': 'TIME',
#   'volume_24h': 352893.0},
#  {'circulating_supply': 38538648.0864,
#   'market_cap': 13987872.0935,
#   'name': 'ALIS',
#   'platform': 'Ethereum',
#   'price': 0.362957,
#   'symbol': 'ALIS',
#   'volume_24h': 49072.4},
#  {'circulating_supply': 2000000.0,
#   'market_cap': 13936500.0,
#   'name': 'Exchange Union',
#   'platform': 'Ethereum',
#   'price': 6.96825,
#   'symbol': 'XUC',
#   'volume_24h': 603584.0},
#  {'circulating_supply': 5143006.61546,
#   'market_cap': 13832373.4426,
#   'name': 'Divi',
#   'platform': 'Ethereum',
#   'price': 2.68955,
#   'symbol': 'DIVX',
#   'volume_24h': 100823.0},
#  {'circulating_supply': 10384393.4012,
#   'market_cap': 13800443.4545,
#   'name': 'GET Protocol',
#   'platform': 'Ethereum',
#   'price': 1.32896,
#   'symbol': 'GET',
#   'volume_24h': 1501.43},
#  {'circulating_supply': 70000000.0,
#   'market_cap': 13775650.0,
#   'name': 'Patientory',
#   'platform': 'Ethereum',
#   'price': 0.196795,
#   'symbol': 'PTOY',
#   'volume_24h': 287564.0},
#  {'circulating_supply': 19429024.2167,
#   'market_cap': 13626818.1407,
#   'name': 'Mysterium',
#   'platform': 'Ethereum',
#   'price': 0.701364,
#   'symbol': 'MYST',
#   'volume_24h': 157781.0},
#  {'circulating_supply': 46016602.0,
#   'market_cap': 13612769.2534,
#   'name': 'Incent',
# ...
#   'name': 'Pundi X',
#   'platform': 'Ethereum',
#   'price': 1.62894,
#   'symbol': 'PXS',
#   'volume_24h': 340259.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Speed Mining ...',
#   'platform': None,
#   'price': 70.0034,
#   'symbol': 'SMS',
#   'volume_24h': 324850.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'POLY AI',
#   'platform': 'Ethereum',
#   'price': 3.21926,
#   'symbol': 'AI',
#   'volume_24h': 321680.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Nitro',
#   'platform': 'Ethereum',
#   'price': 0.391629,
#   'symbol': 'NOX',
#   'volume_24h': 319407.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CoinFi',
#   'platform': 'Ethereum',
#   'price': 0.0910026,
#   'symbol': 'COFI',
#   'volume_24h': 292286.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Vezt',
#   'platform': 'Ethereum',
#   'price': 0.241296,
#   'symbol': 'VZT',
#   'volume_24h': 275279.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'aXpire',
#   'platform': 'Ethereum',
#   'price': 0.0552078,
#   'symbol': 'AXP',
#   'volume_24h': 272226.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CargoX',
#   'platform': 'Ethereum',
#   'price': 0.0981654,
#   'symbol': 'CXO',
#   'volume_24h': 256377.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CryptopiaFeeS...',
#   'platform': 'Ubiq',
#   'price': 1830.02,
#   'symbol': 'CEFS',
#   'volume_24h': 255609.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'COMSA [ETH]',
#   'platform': 'Ethereum',
#   'price': 1.18357,
#   'symbol': 'CMS',
#   'volume_24h': 243712.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'COMSA [XEM]',
#   'platform': 'NEM',
#   'price': 1.18189,
#   'symbol': 'CMS',
#   'volume_24h': 242527.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Mixin',
#   'platform': 'Ethereum',
#   'price': 799.782,
#   'symbol': 'XIN',
#   'volume_24h': 210909.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'WETH',
#   'platform': 'Ethereum',
#   'price': 881.272,
#   'symbol': 'WETH',
#   'volume_24h': 193585.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TokenClub',
#   'platform': 'Ethereum',
#   'price': 0.0291349,
#   'symbol': 'TCT',
#   'volume_24h': 179050.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'RefToken',
#   'platform': 'Ethereum',
#   'price': 27.105,
#   'symbol': 'REF',
#   'volume_24h': 164364.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Content and A...',
#   'platform': 'Ethereum',
#   'price': 0.0356124,
#   'symbol': 'CAN',
#   'volume_24h': 137657.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'adbank',
#   'platform': 'Ethereum',
#   'price': 0.0215623,
#   'symbol': 'ADB',
#   'volume_24h': 130195.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'MOAC',
#   'platform': 'Ethereum',
#   'price': 13.4805,
#   'symbol': 'MOAC',
#   'volume_24h': 91995.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EtherSportz',
#   'platform': 'Ethereum',
#   'price': 0.351508,
#   'symbol': 'ESZ',
#   'volume_24h': 87908.2},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'iQuant',
#   'platform': 'Ethereum',
#   'price': 0.142357,
#   'symbol': 'IQT',
#   'volume_24h': 73797.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BlockCDN',
#   'platform': 'Ethereum',
#   'price': 0.116907,
#   'symbol': 'BCDN',
#   'volume_24h': 66344.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DIMCOIN',
#   'platform': 'NEM',
#   'price': 0.00551656,
#   'symbol': 'DIM',
#   'volume_24h': 65917.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Crypterium',
#   'platform': 'Ethereum',
#   'price': 0.683704,
#   'symbol': 'CRPT',
#   'volume_24h': 63574.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Tokenbox',
#   'platform': 'Ethereum',
#   'price': 0.770676,
#   'symbol': 'TBX',
#   'volume_24h': 61698.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'President Trump',
#   'platform': 'Omni',
#   'price': 0.0459564,
#   'symbol': 'PRES',
#   'volume_24h': 56557.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sphre AIR ',
#   'platform': 'Ethereum',
#   'price': 0.237398,
#   'symbol': 'XID',
#   'volume_24h': 56015.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Datawallet',
#   'platform': 'Ethereum',
#   'price': 0.115758,
#   'symbol': 'DXT',
#   'volume_24h': 51825.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maggie',
#   'platform': 'Ethereum',
#   'price': 0.0322552,
#   'symbol': 'MAG',
#   'volume_24h': 47774.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Wi Coin',
#   'platform': 'Ethereum',
#   'price': 0.0058722,
#   'symbol': 'WIC',
#   'volume_24h': 41942.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Indicoin',
#   'platform': 'Ethereum',
#   'price': 0.0354058,
#   'symbol': 'INDI',
#   'volume_24h': 37782.4},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Smartlands',
#   'platform': 'Stellar',
#   'price': 0.499292,
#   'symbol': 'SLT',
#   'volume_24h': 33555.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Zap',
#   'platform': 'Ethereum',
#   'price': 0.264074,
#   'symbol': 'ZAP',
#   'volume_24h': 32072.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'IPChain',
#   'platform': 'Ethereum',
#   'price': 0.701931,
#   'symbol': 'IPC',
#   'volume_24h': 31722.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GameChain System',
#   'platform': 'Ethereum',
#   'price': 0.0207683,
#   'symbol': 'GCS',
#   'volume_24h': 28396.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DRP Utility',
#   'platform': 'Ethereum',
#   'price': 0.783893,
#   'symbol': 'DRPU',
#   'volume_24h': 22520.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'IDEX Membership',
#   'platform': 'Ethereum',
#   'price': 6009.93,
#   'symbol': 'IDXM',
#   'volume_24h': 18956.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bankex',
#   'platform': 'Ethereum',
#   'price': 0.728736,
#   'symbol': 'BKX',
#   'volume_24h': 17252.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bitair',
#   'platform': 'Ethereum',
#   'price': 0.00368741,
#   'symbol': 'BTCA',
#   'volume_24h': 16031.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Swarm',
#   'platform': 'Ethereum',
#   'price': 1.13959,
#   'symbol': 'SWM',
#   'volume_24h': 14234.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maverick Chain',
#   'platform': 'Ethereum',
#   'price': 0.103627,
#   'symbol': 'MVC',
#   'volume_24h': 13638.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ZenGold',
#   'platform': 'BitShares',
#   'price': 0.0238344,
#   'symbol': 'ZENGOLD',
#   'volume_24h': 12617.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BitSerial',
#   'platform': 'Ethereum',
#   'price': 0.101339,
#   'symbol': 'BTE',
#   'volume_24h': 10962.4},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'STEX',
#   'platform': 'Nxt',
#   'price': 1.72751,
#   'symbol': 'STEX',
#   'volume_24h': 10519.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sense',
#   'platform': 'Ethereum',
#   'price': 0.0445427,
#   'symbol': 'SENSE',
#   'volume_24h': 10339.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ArbitrageCT',
#   'platform': 'Ethereum',
#   'price': 0.016994,
#   'symbol': 'ARCT',
#   'volume_24h': 8747.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Equal',
#   'platform': 'Ethereum',
#   'price': 0.00388338,
#   'symbol': 'EQL',
#   'volume_24h': 7817.76},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'OX Fina',
#   'platform': 'Ethereum',
#   'price': 0.00103006,
#   'symbol': 'OX',
#   'volume_24h': 7095.62},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'PlexCoin',
#   'platform': 'Ethereum',
#   'price': 0.0280197,
#   'symbol': 'PLX',
#   'volume_24h': 7024.28},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'United Trader...',
#   'platform': 'Ethereum',
#   'price': 0.671196,
#   'symbol': 'UTT',
#   'volume_24h': 6083.02},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'NEO GOLD',
#   'platform': 'Ethereum',
#   'price': 0.00481797,
#   'symbol': 'NEOG',
#   'volume_24h': 5358.69},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GOLD Reward T...',
#   'platform': 'Ethereum',
#   'price': 0.0566522,
#   'symbol': 'GRX',
#   'volume_24h': 4806.59},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'President Joh...',
#   'platform': 'Omni',
#   'price': 0.146977,
#   'symbol': 'GARY',
#   'volume_24h': 4409.67},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Alphabit',
#   'platform': 'Ethereum',
#   'price': 115.668,
#   'symbol': 'ABC',
#   'volume_24h': 4380.65},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Macro',
#   'platform': 'Ethereum',
#   'price': 0.610599,
#   'symbol': 'MCR',
#   'volume_24h': 3990.21},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Musiconomi',
#   'platform': 'Ethereum',
#   'price': 0.116321,
#   'symbol': 'MCI',
#   'volume_24h': 3843.11},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Cloud',
#   'platform': 'Ethereum',
#   'price': 0.0505781,
#   'symbol': 'CLD',
#   'volume_24h': 3207.96},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Monero Gold',
#   'platform': 'Ethereum',
#   'price': 0.000172711,
#   'symbol': 'XMRG',
#   'volume_24h': 2431.89},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Escroco',
#   'platform': 'Waves',
#   'price': 0.747495,
#   'symbol': 'ESC',
#   'volume_24h': 2161.75},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Minex',
#   'platform': 'Waves',
#   'price': 0.020636,
#   'symbol': 'MINEX',
#   'volume_24h': 1981.85},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'FidentiaX',
#   'platform': 'Ethereum',
#   'price': 0.225437,
#   'symbol': 'FDX',
#   'volume_24h': 1934.57},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Internet of T...',
#   'platform': 'Nxt',
#   'price': 595.855,
#   'symbol': 'XOT',
#   'volume_24h': 1874.74},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Storjcoin X',
#   'platform': 'Counterparty',
#   'price': 1.05705,
#   'symbol': 'SJCX',
#   'volume_24h': 1811.93},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BTCMoon',
#   'platform': 'Ethereum',
#   'price': 0.00977717,
#   'symbol': 'BTCM',
#   'volume_24h': 980.418},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SISA',
#   'platform': 'Ethereum',
#   'price': 0.0121234,
#   'symbol': 'SISA',
#   'volume_24h': 919.592},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sand Coin',
#   'platform': 'Ethereum',
#   'price': 2.15889,
#   'symbol': 'SND',
#   'volume_24h': 817.789},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EncryptoTel [...',
#   'platform': 'Ethereum',
#   'price': 0.0841327,
#   'symbol': 'ETT',
#   'volume_24h': 714.642},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Natcoin',
#   'platform': 'Ethereum',
#   'price': 0.0142386,
#   'symbol': 'NTC',
#   'volume_24h': 655.738},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CORION',
#   'platform': 'Ethereum Classic',
#   'price': 0.414508,
#   'symbol': 'COR',
#   'volume_24h': 513.318},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TeslaCoilCoin',
#   'platform': 'Omni',
#   'price': 1.03411,
#   'symbol': 'TESLA',
#   'volume_24h': 404.455},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'HODL Bucks',
#   'platform': 'Ethereum',
#   'price': 0.142487,
#   'symbol': 'HDLB',
#   'volume_24h': 383.516},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'First Bitcoin...',
#   'platform': 'Omni',
#   'price': 0.239292,
#   'symbol': 'BITCF',
#   'volume_24h': 363.936},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Ethereum Lite',
#   'platform': 'Ethereum',
#   'price': 0.359413,
#   'symbol': 'ELITE',
#   'volume_24h': 342.459},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ANRYZE',
#   'platform': 'Waves',
#   'price': 0.00768566,
#   'symbol': 'RYZ',
#   'volume_24h': 145.448},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SnakeEyes',
#   'platform': 'Burst',
#   'price': 0.0225374,
#   'symbol': 'SNAKE',
#   'volume_24h': 48.4328},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eGold',
#   'platform': 'Ethereum',
#   'price': 0.025577,
#   'symbol': 'EGOLD',
#   'volume_24h': 35.9865},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'FAPcoin',
#   'platform': 'Ethereum',
#   'price': 0.00425845,
#   'symbol': 'FAP',
#   'volume_24h': 25.0427},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LLToken',
#   'platform': 'Ethereum',
#   'price': None,
#   'symbol': 'LLT',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Blockchain Index',
#   'platform': 'Ethereum',
#   'price': 4.21102,
#   'symbol': 'BLX',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Facecoin',
#   'platform': 'Ethereum',
#   'price': 0.00182733,
#   'symbol': 'FC',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eLTC',
#   'platform': 'Ethereum',
#   'price': 0.000650587,
#   'symbol': 'ELTC2',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Swapcoin',
#   'platform': 'Ethereum',
#   'price': 0.259564,
#   'symbol': 'SWP',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eUSD',
#   'platform': 'Ethereum',
#   'price': 0.0005738,
#   'symbol': 'EUSD',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': '10M Token',
#   'platform': 'Ethereum',
#   'price': 0.00519545,
#   'symbol': '10MT',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LiteCoin Gold',
#   'platform': 'Ethereum',
#   'price': 0.00613188,
#   'symbol': 'LTG',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bitcoin Silver',
#   'platform': 'Ethereum',
#   'price': 0.00480626,
#   'symbol': 'BTCS',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Cash Poker Pro',
#   'platform': 'Ethereum',
#   'price': 0.0542897,
#   'symbol': 'CASH',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'iBTC',
#   'platform': 'Ethereum',
#   'price': 0.00480388,
#   'symbol': 'IBTC',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eBIT',
#   'platform': 'Ethereum',
#   'price': 0.00419491,
#   'symbol': 'EBIT',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Faceblock',
#   'platform': 'Ethereum',
#   'price': 0.00323005,
#   'symbol': 'FBL',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Infinity Pay',
#   'platform': 'Ethereum',
#   'price': 0.00120303,
#   'symbol': 'IPY',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bitcoin2x',
#   'platform': 'Ethereum',
#   'price': 0.00578223,
#   'symbol': 'BTC2X',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Hyper TV',
#   'platform': 'Ethereum',
#   'price': 0.00118039,
#   'symbol': 'HYTV',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'UAHPay',
#   'platform': 'Ethereum',
#   'price': 0.000108135,
#   'symbol': 'UAHPAY',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EtherDelta Token',
#   'platform': 'Ethereum',
#   'price': 0.0395089,
#   'symbol': 'EDT',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Decentralized...',
#   'platform': 'Ethereum',
#   'price': 123.813,
#   'symbol': 'DUBI',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DMarket',
#   'platform': 'Ethereum',
#   'price': 0.671872,
#   'symbol': 'DMT',
#   'volume_24h': None}]

# %% [markdown]
# _________________________________
#
# ## Graphs API
# The graphs API is used internally by coinmarketcap for display graphs info. The params `start` and `end` are passed in unix microseconds timestamps and only are valid those that returns the methods, not whatever.
#
# #### `graphs.currency(name, [start=None, end=None])`
#
# Get graphs data for a currency:

# %%
cmc.graphs.currency("BTC")
# Out:
# {'market_cap_by_available_supply': [[1367174841000, 1500517590],
#   [1367261101000, 1575032004],
#   [1367347502000, 1501657492],
#   [1367433902000, 1298951550],
#   [1367522401000, 1148667722],
#   [1367608801000, 1011066494],
#   [1367695201000, 1236351843],
#   [1367781901000, 1298377788],
#   [1367868303000, 1315992303],
#   [1367954701000, 1183766500],
#   [1368041101000, 1253655040],
#   [1368129001000, 1258130700],
#   [1368215702000, 1322989457],
#   [1368303901000, 1259239352],
#   [1368390301000, 1278708678],
#   [1368476701000, 1306721052],
#   [1368563101000, 1277278987],
#   [1368650101000, 1273849680],
#   [1368736501000, 1289277412],
#   [1368822901000, 1374605382],
#   [1368909301000, 1383755085],
#   [1368995702000, 1346499261],
#   [1369082102000, 1370131821],
#   [1369168502000, 1374154117],
#   [1369254904000, 1375791900],
#   [1369341302000, 1407041527],
#   [1369427701000, 1474180657],
#   [1369514102000, 1464316690],
#   [1369601102000, 1507769010],
#   [1369687501000, 1445444605],
#   [1369773907000, 1448115966],
#   [1369862101000, 1481781794],
#   [1369948501000, 1429308633],
#   [1370036402000, 1436386729],
#   [1370122802000, 1449499974],
#   [1370215501000, 1362684200],
#   [1370301902000, 1361765704],
#   [1370393102000, 1364113639],
#   [1370479502000, 1369233814],
#   [1370565901000, 1339234925],
#   [1370652302000, 1239395972],
#   [1370738701000, 1220874392],
#   [1370825102000, 1123844957],
#   [1370912105000, 1194605340],
#   [1370998802000, 1227904672],
#   [1371085201000, 1222819750],
#   [1371171602000, 1159766149],
#   [1371258301000, 1110902570],
#   [1371344702000, 1129287060],
#   [1371431702000, 1134610433],
#   [1371518404000, 1152834600],
#   [1371605102000, 1204638317],
#   [1371691510000, 1220273470],
#   [1448477220000, 2.67064],
#   [1448563620000, 2.47447],
#   [1448650020000, 2.42116],
#   [1448736420000, 2.40517],
#   [1448822820000, 2.41075],
#   [1448909220000, 2.29957],
#   [1448995620000, 2.31534],
#   [1449082020000, 2.37006],
#   [1449168420000, 2.42363],
#   [1449254820000, 2.68543],
#   [1449341220000, 2.80114],
#   [1449427620000, 2.76701],
#   [1449514020000, 2.83668],
#   [1449600420000, 3.36759],
#   [1449686820000, 4.17683],
#   [1449773220000, 4.22222],
#   [1449859620000, 3.72718],
#   [1449946020000, 4.03463],
#   [1450032420000, 4.07886],
#   [1450118820000, 3.94028],
#   [1450205220000, 2.95189],
#   [1450291620000, 3.04037],
#   [1450378020000, 3.02888],
#   [1450464420000, 2.86055],
#   [1450550820000, 2.79682],
#   [1450637220000, 2.89138],
#   [1450723620000, 2.92987],
#   [1450810020000, 2.9081],
#   [1450896420000, 2.83729],
#   [1450982820000, 2.69942],
#   [1451069220000, 2.90029],
#   [1451155620000, 3.03088],
#   [1451242020000, 3.06213],
#   [1451328420000, 3.06205],
#   [1451414820000, 2.97601],
#   [1451501220000, 2.95556],
#   [1451587620000, 2.87197],
#   [1451674020000, 2.79942],
#   [1451760420000, 2.84764],
#   [1451846820000, 2.86418],
#   [1451933220000, 2.84008],
#   [1452019620000, 2.84627],
#   [1452106020000, 2.83942],
#   [1452192420000, 2.70616],
#   [1452278820000, 2.68785],
#   [1452365220000, 2.71813],
#   [1452451620000, 2.72047],
#   [1452538020000, 2.67799],
#   [1452624420000, 2.66291],
#   [1452710820000, 2.72607],
#   [1452797220000, 2.60392],
#   [1452883620000, 2.76879],
#   [1452970020000, 2.76424],
#   [1453056420000, 2.73863],
#   [1453142820000, 2.75981],
#   [1453229220000, 2.77219],
#   [1453315620000, 2.61743],
#   [1453402020000, 2.6124],
#   [1453488420000, 2.66862],
#   ...]}

# %% [markdown]
# ## Utils (advanced usage)
# #### `convert(value, currency_in, currency_out)`
# This method converts the value passed as first parameter as price of the `currency_in` currency to price of the `currency_out` parameter. For example, if you want to converts $100€$ to dolars, use:

# %%
cmc.convert(100, "EUR", "USD")
# Out:
# 122.66853122834134

# %% [markdown]
# For get all the currencies supported by this method:

# %%
cmc.currencies_to_convert
# Out:
# ['USD',
#  'EUR',
#  'CNY',
#  'GBP',
#  'CAD',
#  'RUB',
#  'HKD',
#  'JPY',
#  'AUD',
#  'BRL',
#  'INR',
#  'KRW',
#  'MXN',
#  'IDR',
#  'CHF',
#  'CLP',
#  'CZK',
#  'DKK',
#  'HUF',
#  'ILS',
#  'MYR',
#  'NOK',
#  'NZD',
#  'PHP',
#  'PKR',
#  'PLN',
#  'SEK',
#  'SGD',
#  'THB',
#  'TRY',
#  'TWD',
#  'ZAR',
#  'BTC',
#  'ETH',
#  'LTC',
#  'XRP',
#  'BCH',
#  'XRP7D',
#  'BCH7D',
#  'XRP24H',
#  'LTC7D',
#  'BCH24H',
#  'LTC24H',
#  'ETH24H',
#  'LTC1H',
#  'BTC24H',
#  'BTC7D',
#  'ETH7D']
