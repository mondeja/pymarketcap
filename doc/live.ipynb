# %% [markdown]
# # <center>Pymarketcap live demo</center>

# %% [markdown]
# ## Basic usage
# The first response takes a long time because some data is cached at instantiation of the wrapper.

# %%
from pymarketcap import Pymarketcap
cmc = Pymarketcap()

cmc.exchanges()
# Out:
# [{'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Cardano',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Qtum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Status',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'NEO',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Stellar',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Steem',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Upbit'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'NEO',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'ICON',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'NEO',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bluzelle',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'TRON',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Binance Coin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'VeChain',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Binance'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ethereum Classic',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum Classic',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'OKEx'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'BitMEX'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'EOS',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Qtum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Monero',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bithumb'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ripple',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'EOS',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Tether',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bitfinex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Huobi Token',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Huobi Token',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Huobi Token',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'EOS',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'TRON',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Elastos',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Elastos',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Huobi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Litecoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'GDAX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ripple',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ripple',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ethereum',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Kraken'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ripple',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Cardano',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'NuBits',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Lisk',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'NEO',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Stellar',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bittrex'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Monero',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Dash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ripple',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Zcash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'EOS',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'HitBTC'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ripple',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ripple',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bitstamp'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Qtum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'IOTA',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'}],
#   'name': 'Coinone'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ripple',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ripple',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Stellar',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Monero',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Litecoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Poloniex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'}],
#   'name': 'bitFlyer'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'NEM',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'MonaCoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'NEM',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'COMSA [ETH]',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Counterparty',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'COMSA [XEM]',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Pepe Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Zaif'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Litecoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'EDUCare',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'TRON',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Hshare',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Zcash',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Lisk',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Factom',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bit-Z'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'QASH',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ethereum',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Quoine'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'}],
#   'name': 'Gemini'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'MonaCoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'MonaCoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'}],
#   'name': 'Fisco'},
#  {'markets': [{'name': 'ATMCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'ATMCoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ripple',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Litecoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Dogecoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'ATMCoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'ATMCoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bits Blockchain'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'BTCBOX'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'NEO',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'TRON',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Lisk',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ruff',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Qtum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Qbao',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ripple',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Achain',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Lightning Bitcoin [Futures]',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'CoinEgg'},
#  {'markets': [{'name': 'Stellar',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Status',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Civic',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': '0x',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Enigma',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Zcash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'GOPAX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'EOS',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'BitShares',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Qtum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Hshare',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ripple',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ink',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Qtum',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'ZB.COM'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'}],
#   'name': 'Korbit'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ink',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Lightning Bitcoin [Futures]',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Hyper Pay',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'EXX'},
#  {'markets': [{'name': 'TRON',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Hshare',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Qtum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Energo',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Profile Utility Token',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Storm',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin Diamond',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Walton',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Coinnest'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'MonaCoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'MonaCoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'}],
#   'name': 'Bitbank'},
#  {'markets': [{'name': 'Jibrel Network',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Jibrel Network',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bibox Token',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bibox Token',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bibox Token',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
# ...
#    {'name': 'E-Dinar Coin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'DigiByte',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'alcurEX'},
#  {'markets': [{'name': 'E-Dinar Coin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'}],
#   'name': 'LocalTrade'},
#  {'markets': [{'name': 'Litecoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Electroneum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Monero',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Verge',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Aeon',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'BitCoal',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Sumokoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'TradeOgre'},
#  {'markets': [{'name': 'NVO',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Pepe Cash',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Counterparty',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Storjcoin X',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Rustbits',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Storjcoin X',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'FoldingCoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Bitcrystals',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'}],
#   'name': 'Counterparty DEX'},
#  {'markets': [{'name': 'Peercoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Dogecoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Dogecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Vertcoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Dash',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Litecoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Coingi'},
#  {'markets': [{'name': 'Centurion',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'ExcambrioRex'},
#  {'markets': [{'name': 'Gulden',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'GuldenTrader'},
#  {'markets': [{'name': 'LEOcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'LEOcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'LEOcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'LEOcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'LEOxChange'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'TCC Exchange'},
#  {'markets': [{'name': 'SACoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'DC-Ex'},
#  {'markets': [{'name': 'BriaCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Litecoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'}],
#   'name': 'Ore.Bz'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'}],
#   'name': 'CoinCorner'},
#  {'markets': [{'name': 'CRTCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Dogecoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'}],
#   'name': 'NIX-E'},
#  {'markets': [{'name': 'HEAT',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bismuth',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Golem',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'FIMKrypto',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Elastic',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Elastic',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'HEAT',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'Heat Wallet'},
#  {'markets': [{'name': 'SnakeEyes',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'CCMiner',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'}],
#   'name': 'Burst Asset Exchange'},
#  {'markets': [{'name': 'MaidSafeCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'Omni DEX'},
#  {'markets': [{'name': 'Golem',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Lunyr',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'SingularDTV',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'TokenCard',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Swarm City',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Etheroll',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.14,
#     'price': 0.22363,
#     'volume': 143738000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Melon',
#     'pair': 'ETH/KRW',
#     'perc_volume': 4.97,
#     'price': 892.77,
#     'volume': 116182000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Numeraire',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.77,
#     'price': 118.303,
#     'volume': 111506000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Edgeless',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.69,
#     'price': 0.397564,
#     'volume': 86363800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum Movie Venture',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.52,
#     'price': 4.26093,
#     'volume': 59033400.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'CryptoDerivatives'},
#  {'markets': [{'name': 'Virtacoinplus',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Virtacoinplus',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'}],
#   'name': 'VirtacoinWorld'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.37,
#     'price': 0.924888,
#     'volume': 336167000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.24,
#     'price': 0.380078,
#     'volume': 309650000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.75,
#     'price': 30.0013,
#     'volume': 274790000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Siacoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.06,
#     'price': 8780.45,
#     'volume': 258831000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 7.8,
#     'price': 1345.46,
#     'volume': 182391000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'}],
#   'name': 'BITHOLIC'}]

# %% [markdown]
# All methods are self explained in docstrings:

# %%
print(cmc.exchanges.__doc__)
# Out:
# Get all the exchanges in coninmarketcap ranked by volumes
#         along with other metadata.
#
#         Args:
#             convert (str, optional): Convert volumes and prices
#                 between "USD" and "BTC". As default "USD".
#
#         Returns (list):
#             Exchanges with markets and other data included.

# %% [markdown]
# ___________________________________
#
# ## Coinmarketcap API
# #### `ticker(currency=None, limit=0, start=0, convert="USD")`
# If `currency == None`, you will obtain data for all currencies in coinmarketcap:

# %%
cmc.ticker()
# Out:
# [{'24h_volume_usd': 7991580000.0,
#   'available_supply': 16854937.0,
#   'id': 'bitcoin',
#   'last_updated': 1518196468,
#   'market_cap_usd': 142301008061,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin',
#   'percent_change_1h': 0.44,
#   'percent_change_24h': 2.8,
#   'percent_change_7d': -1.97,
#   'price_btc': 1.0,
#   'price_usd': 8442.69,
#   'rank': 1,
#   'symbol': 'BTC',
#   'total_supply': 16854937.0},
#  {'24h_volume_usd': 3038210000.0,
#   'available_supply': 97511235.0,
#   'id': 'ethereum',
#   'last_updated': 1518196452,
#   'market_cap_usd': 83116918729.0,
#   'max_supply': None,
#   'name': 'Ethereum',
#   'percent_change_1h': 0.37,
#   'percent_change_24h': 6.15,
#   'percent_change_7d': -4.93,
#   'price_btc': 0.101494,
#   'price_usd': 852.383,
#   'rank': 2,
#   'symbol': 'ETH',
#   'total_supply': 97511235.0},
#  {'24h_volume_usd': 1598740000.0,
#   'available_supply': 39009215838.0,
#   'id': 'ripple',
#   'last_updated': 1518196441,
#   'market_cap_usd': 35806286153.0,
#   'max_supply': 100000000000,
#   'name': 'Ripple',
#   'percent_change_1h': 1.05,
#   'percent_change_24h': 21.44,
#   'percent_change_7d': 10.78,
#   'price_btc': 0.0001093,
#   'price_usd': 0.917893,
#   'rank': 3,
#   'symbol': 'XRP',
#   'total_supply': 99992725510.0},
#  {'24h_volume_usd': 1441510000.0,
#   'available_supply': 16958238.0,
#   'id': 'bitcoin-cash',
#   'last_updated': 1518196453,
#   'market_cap_usd': 21903598720.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Cash',
#   'percent_change_1h': 0.31,
#   'percent_change_24h': 3.77,
#   'percent_change_7d': 12.04,
#   'price_btc': 0.153794,
#   'price_usd': 1291.62,
#   'rank': 4,
#   'symbol': 'BCH',
#   'total_supply': 16958238.0},
#  {'24h_volume_usd': 391720000.0,
#   'available_supply': 25927070538.0,
#   'id': 'cardano',
#   'last_updated': 1518196455,
#   'market_cap_usd': 9838415822.0,
#   'max_supply': 45000000000.0,
#   'name': 'Cardano',
#   'percent_change_1h': 0.98,
#   'percent_change_24h': 9.7,
#   'percent_change_7d': 9.28,
#   'price_btc': 4.518e-05,
#   'price_usd': 0.379465,
#   'rank': 5,
#   'symbol': 'ADA',
#   'total_supply': 31112483745.0},
#  {'24h_volume_usd': 706976000.0,
#   'available_supply': 55142808.0,
#   'id': 'litecoin',
#   'last_updated': 1518196441,
#   'market_cap_usd': 8466571621.0,
#   'max_supply': 84000000.0,
#   'name': 'Litecoin',
#   'percent_change_1h': 0.84,
#   'percent_change_24h': 6.88,
#   'percent_change_7d': 21.45,
#   'price_btc': 0.0182821,
#   'price_usd': 153.539,
#   'rank': 6,
#   'symbol': 'LTC',
#   'total_supply': 55142808.0},
#  {'24h_volume_usd': 422820000.0,
#   'available_supply': 65000000.0,
#   'id': 'neo',
#   'last_updated': 1518196447,
#   'market_cap_usd': 7440095000.0,
#   'max_supply': None,
#   'name': 'NEO',
#   'percent_change_1h': 0.38,
#   'percent_change_24h': 3.82,
#   'percent_change_7d': -0.84,
#   'price_btc': 0.0136292,
#   'price_usd': 114.463,
#   'rank': 7,
#   'symbol': 'NEO',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 162493000.0,
#   'available_supply': 18432187942.0,
#   'id': 'stellar',
#   'last_updated': 1518196443,
#   'market_cap_usd': 7202451167.0,
#   'max_supply': None,
#   'name': 'Stellar',
#   'percent_change_1h': 0.46,
#   'percent_change_24h': 10.9,
#   'percent_change_7d': 1.98,
#   'price_btc': 4.653e-05,
#   'price_usd': 0.390754,
#   'rank': 8,
#   'symbol': 'XLM',
#   'total_supply': 103669352049},
#  {'24h_volume_usd': 520775000.0,
#   'available_supply': 657691061.0,
#   'id': 'eos',
#   'last_updated': 1518196451,
#   'market_cap_usd': 6066470003.0,
#   'max_supply': 1000000000.0,
#   'name': 'EOS',
#   'percent_change_1h': 2.21,
#   'percent_change_24h': 13.25,
#   'percent_change_7d': -1.5,
#   'price_btc': 0.0010983,
#   'price_usd': 9.22389,
#   'rank': 9,
#   'symbol': 'EOS',
#   'total_supply': 900000000.0},
#  {'24h_volume_usd': 57810900.0,
#   'available_supply': 2779530283.0,
#   'id': 'iota',
#   'last_updated': 1518196452,
#   'market_cap_usd': 5273130286.0,
#   'max_supply': 2779530283.0,
#   'name': 'IOTA',
#   'percent_change_1h': 1.25,
#   'percent_change_24h': 6.23,
#   'percent_change_7d': 9.51,
#   'price_btc': 0.00022589,
#   'price_usd': 1.89713,
#   'rank': 10,
#   'symbol': 'MIOTA',
#   'total_supply': 2779530283.0},
#  {'24h_volume_usd': 52080600.0,
#   'available_supply': 8999999999.0,
#   'id': 'nem',
#   'last_updated': 1518196444,
#   'market_cap_usd': 5037722999.0,
#   'max_supply': None,
#   'name': 'NEM',
#   'percent_change_1h': -0.61,
#   'percent_change_24h': 2.4,
#   'percent_change_7d': 2.33,
#   'price_btc': 6.665e-05,
#   'price_usd': 0.559747,
#   'rank': 11,
#   'symbol': 'XEM',
#   'total_supply': 8999999999.0},
#  {'24h_volume_usd': 98808300.0,
#   'available_supply': 7874184.0,
#   'id': 'dash',
#   'last_updated': 1518196443,
#   'market_cap_usd': 4822693520.0,
#   'max_supply': 18900000.0,
#   'name': 'Dash',
#   'percent_change_1h': 0.11,
#   'percent_change_24h': 7.1,
#   'percent_change_7d': 10.87,
#   'price_btc': 0.0729273,
#   'price_usd': 612.469,
#   'rank': 12,
#   'symbol': 'DASH',
#   'total_supply': 7874184.0},
#  {'24h_volume_usd': 89285500.0,
#   'available_supply': 15702369.0,
#   'id': 'monero',
#   'last_updated': 1518196442,
#   'market_cap_usd': 3893386725.0,
#   'max_supply': None,
#   'name': 'Monero',
#   'percent_change_1h': 0.6,
#   'percent_change_24h': 4.1,
#   'percent_change_7d': 8.43,
#   'price_btc': 0.0295235,
#   'price_usd': 247.949,
#   'rank': 13,
#   'symbol': 'XMR',
#   'total_supply': 15702369.0},
#  {'24h_volume_usd': 86561100.0,
#   'available_supply': 117890488.0,
#   'id': 'lisk',
#   'last_updated': 1518196447,
#   'market_cap_usd': 3069302433.0,
#   'max_supply': None,
#   'name': 'Lisk',
#   'percent_change_1h': 1.8,
#   'percent_change_24h': 15.6,
#   'percent_change_7d': 31.75,
#   'price_btc': 0.00310003,
#   'price_usd': 26.0352,
#   'rank': 14,
#   'symbol': 'LSK',
#   'total_supply': 117890488.0},
#  {'24h_volume_usd': 239997000.0,
#   'available_supply': 65748192475.0,
#   'id': 'tron',
#   'last_updated': 1518196453,
#   'market_cap_usd': 2754776942.0,
#   'max_supply': None,
#   'name': 'TRON',
#   'percent_change_1h': 1.72,
#   'percent_change_24h': 15.93,
#   'percent_change_7d': 8.77,
#   'price_btc': 4.99e-06,
#   'price_usd': 0.0418989,
#   'rank': 15,
#   'symbol': 'TRX',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 110806000.0,
#   'available_supply': 16814311.0,
#   'id': 'bitcoin-gold',
#   'last_updated': 1518196456,
#   'market_cap_usd': 2653516876.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Gold',
#   'percent_change_1h': 3.36,
#   'percent_change_24h': 55.7,
#   'percent_change_7d': 49.57,
#   'price_btc': 0.0187909,
#   'price_usd': 157.813,
#   'rank': 16,
#   'symbol': 'BTG',
#   'total_supply': 16914311.0},
#  {'24h_volume_usd': 379871000.0,
#   'available_supply': 99733850.0,
#   'id': 'ethereum-classic',
#   'last_updated': 1518196447,
#   'market_cap_usd': 2514549667.0,
#   'max_supply': None,
#   'name': 'Ethereum Classic',
#   'percent_change_1h': 1.31,
#   'percent_change_24h': 24.28,
#   'percent_change_7d': 14.68,
#   'price_btc': 0.00300209,
#   'price_usd': 25.2126,
#   'rank': 17,
#   'symbol': 'ETC',
#   'total_supply': 99733850.0},
#  {'24h_volume_usd': 2516340000.0,
#   'available_supply': 2217140814.0,
#   'id': 'tether',
#   'last_updated': 1518196444,
#   'market_cap_usd': 2283854581.0,
#   'max_supply': None,
#   'name': 'Tether',
#   'percent_change_1h': 0.11,
#   'percent_change_24h': 1.55,
#   'percent_change_7d': 4.12,
#   'price_btc': 0.00012265,
#   'price_usd': 1.03009,
#   'rank': 18,
#   'symbol': 'USDT',
#   'total_supply': 2280109970.0},
#  {'24h_volume_usd': 602216000.0,
#   'available_supply': 73869412.0,
#   'id': 'qtum',
#   'last_updated': 1518196450,
#   'market_cap_usd': 2201736920.0,
#   'max_supply': None,
#   'name': 'Qtum',
#   'percent_change_1h': 1.11,
#   'percent_change_24h': 23.6,
#   'percent_change_7d': 4.32,
#   'price_btc': 0.00354901,
#   'price_usd': 29.8058,
#   'rank': 19,
#   'symbol': 'QTUM',
#   'total_supply': 100369412.0},
#  {'24h_volume_usd': 63193400.0,
#   'available_supply': 466139235.0,
#   'id': 'vechain',
#   'last_updated': 1518196452,
#   'market_cap_usd': 2048653968.0,
#   'max_supply': None,
#   'name': 'VeChain',
#   'percent_change_1h': 0.53,
#   'percent_change_24h': 3.7,
#   'percent_change_7d': -6.72,
#   'price_btc': 0.00052331,
#   'price_usd': 4.39494,
#   'rank': 20,
#   'symbol': 'VEN',
#   'total_supply': 873378637.0},
#  {'24h_volume_usd': 101959000.0,
#   'available_supply': 381495014.0,
#   'id': 'icon',
#   'last_updated': 1518196456,
#   'market_cap_usd': 1668113653.0,
#   'max_supply': None,
#   'name': 'ICON',
#   'percent_change_1h': 0.48,
#   'percent_change_24h': 1.69,
#   'percent_change_7d': -14.78,
#   'price_btc': 0.00052065,
#   'price_usd': 4.37257,
#   'rank': 21,
#   'symbol': 'ICX',
#   'total_supply': 400230000.0},
#  {'24h_volume_usd': 30756300.0,
#   'available_supply': 133248289.0,
#   'id': 'raiblocks',
#   'last_updated': 1518196449,
#   'market_cap_usd': 1543947927.0,
#   'max_supply': 133248290.0,
#   'name': 'Nano',
#   'percent_change_1h': 0.6,
#   'percent_change_24h': 4.13,
#   'percent_change_7d': -30.3,
#   'price_btc': 0.00137968,
#   'price_usd': 11.587,
#   'rank': 22,
#   'symbol': 'XRB',
#   'total_supply': 133248289.0},
#  {'24h_volume_usd': 111105000.0,
#   'available_supply': 3242256.0,
#   'id': 'zcash',
#   'last_updated': 1518196448,
#   'market_cap_usd': 1399374009.0,
#   'max_supply': None,
#   'name': 'Zcash',
#   'percent_change_1h': 0.51,
#   'percent_change_24h': 7.33,
#   'percent_change_7d': 19.6,
#   'price_btc': 0.0513917,
#   'price_usd': 431.605,
#   'rank': 23,
#   'symbol': 'ZEC',
#   'total_supply': 3242256.0},
#  {'24h_volume_usd': 45318100.0,
#   'available_supply': 102042552.0,
#   'id': 'omisego',
#   'last_updated': 1518196451,
#   'market_cap_usd': 1303318084.0,
#   'max_supply': None,
#   'name': 'OmiseGO',
#   'percent_change_1h': 1.52,
#   'percent_change_24h': 9.55,
#   'percent_change_7d': 1.51,
#   'price_btc': 0.00152081,
#   'price_usd': 12.7723,
#   'rank': 24,
#   'symbol': 'OMG',
#   'total_supply': 140245398.0},
#  {'24h_volume_usd': 12207300.0,
#   'available_supply': 37004027.0,
#   'id': 'populous',
#   'last_updated': 1518196451,
#   'market_cap_usd': 1295496180.0,
#   'max_supply': 53252246.0,
#   'name': 'Populous',
#   'percent_change_1h': 0.44,
#   'percent_change_24h': -1.09,
#   'percent_change_7d': -35.21,
#   'price_btc': 0.00416863,
#   'price_usd': 35.0096,
#   'rank': 25,
#   'symbol': 'PPT',
#   'total_supply': 53252246.0},
#  {'24h_volume_usd': 67837400.0,
#   'available_supply': 249201302.0,
#   'id': 'steem',
#   'last_updated': 1518196446,
#   'market_cap_usd': 1056937482.0,
#   'max_supply': None,
#   'name': 'Steem',
#   'percent_change_1h': 0.47,
#   'percent_change_24h': 13.24,
#   'percent_change_7d': 6.7,
#   'price_btc': 0.00050502,
#   'price_usd': 4.2413,
#   'rank': 26,
#   'symbol': 'STEEM',
#   'total_supply': 266175396.0},
#  {'24h_volume_usd': 83981800.0,
#   'available_supply': 99014000.0,
#   'id': 'binance-coin',
#   'last_updated': 1518196452,
#   'market_cap_usd': 860192046.0,
#   'max_supply': None,
#   'name': 'Binance Coin',
#   'percent_change_1h': 0.01,
#   'percent_change_24h': 2.38,
#   'percent_change_7d': -4.79,
#   'price_btc': 0.00103444,
#   'price_usd': 8.68758,
#   'rank': 27,
#   'symbol': 'BNB',
#   'total_supply': 197192382.0},
#  {'24h_volume_usd': 4987260.0,
#   'available_supply': 183717044666,
#   'id': 'bytecoin-bcn',
#   'last_updated': 1518196442,
#   'market_cap_usd': 843353094.0,
#   'max_supply': 184470000000,
#   'name': 'Bytecoin',
#   'percent_change_1h': 0.34,
#   'percent_change_24h': 3.77,
#   'percent_change_7d': 2.11,
#   'price_btc': 5.5e-07,
#   'price_usd': 0.0045905,
#   'rank': 28,
#   'symbol': 'BCN',
#   'total_supply': 183717044666},
#  {'24h_volume_usd': 22345400.0,
#   'available_supply': 14575147200.0,
#   'id': 'verge',
#   'last_updated': 1518196443,
#   'market_cap_usd': 801560220.0,
#   'max_supply': 16555000000.0,
#   'name': 'Verge',
#   'percent_change_1h': 1.1,
#   'percent_change_24h': 6.84,
#   'percent_change_7d': 6.52,
#   'price_btc': 6.55e-06,
#   'price_usd': 0.054995,
#   'rank': 29,
#   'symbol': 'XVG',
#   'total_supply': 14575147200.0},
#  {'24h_volume_usd': 160560000.0,
#   'available_supply': 3470483788.0,
#   'id': 'status',
#   'last_updated': 1518196451,
#   'market_cap_usd': 777523717.0,
#   'max_supply': None,
#   'name': 'Status',
#   'percent_change_1h': 0.44,
#   'percent_change_24h': 5.28,
#   'percent_change_7d': 36.71,
#   'price_btc': 2.668e-05,
#   'price_usd': 0.224039,
#   'rank': 30,
#   'symbol': 'SNT',
#   'total_supply': 6804870174.0},
#  {'24h_volume_usd': 15205900.0,
#   'available_supply': 32363386224.0,
#   'id': 'siacoin',
#   'last_updated': 1518196445,
#   'market_cap_usd': 776653306.0,
#   'max_supply': None,
#   'name': 'Siacoin',
#   'percent_change_1h': 1.12,
#   'percent_change_24h': 10.63,
#   'percent_change_7d': -3.63,
#   'price_btc': 2.86e-06,
#   'price_usd': 0.0239979,
#   'rank': 31,
#   'symbol': 'SC',
#   'total_supply': 32363386224.0},
#  {'24h_volume_usd': 16844700.0,
#   'available_supply': 98734004.0,
#   'id': 'stratis',
#   'last_updated': 1518196447,
#   'market_cap_usd': 772326014.0,
#   'max_supply': None,
#   'name': 'Stratis',
#   'percent_change_1h': 0.24,
#   'percent_change_24h': 11.94,
#   'percent_change_7d': -10.46,
#   'price_btc': 0.00093141,
#   'price_usd': 7.82229,
#   'rank': 32,
#   'symbol': 'STRAT',
#   'total_supply': 98734004.0},
#  {'24h_volume_usd': 21322600.0,
#   'available_supply': 233020472.0,
#   'id': 'aeternity',
#   'last_updated': 1518196450,
#   'market_cap_usd': 685790900.0,
#   'max_supply': None,
#   'name': 'Aeternity',
#   'percent_change_1h': 0.28,
#   'percent_change_24h': 3.83,
#   'percent_change_7d': 16.17,
#   'price_btc': 0.00035043,
#   'price_usd': 2.94305,
#   'rank': 33,
#   'symbol': 'AE',
#   'total_supply': 273685830.0},
#  {'24h_volume_usd': 27715500.0,
#   'available_supply': 2608390000.0,
#   'id': 'bitshares',
#   'last_updated': 1518196443,
#   'market_cap_usd': 657987245.0,
#   'max_supply': 3600570502.0,
#   'name': 'BitShares',
#   'percent_change_1h': 1.24,
#   'percent_change_24h': 8.86,
#   'percent_change_7d': -16.84,
#   'price_btc': 3.004e-05,
#   'price_usd': 0.252258,
#   'rank': 34,
#   'symbol': 'BTS',
#   'total_supply': 2608390000.0},
#  {'24h_volume_usd': 631158.0,
#   'available_supply': 618228.0,
#   'id': 'maker',
#   'last_updated': 1518196449,
#   'market_cap_usd': 656650626.0,
#   'max_supply': None,
#   'name': 'Maker',
#   'percent_change_1h': 0.96,
#   'percent_change_24h': 6.49,
#   'percent_change_7d': -5.93,
#   'price_btc': 0.126471,
#   'price_usd': 1062.15,
#   'rank': 35,
#   'symbol': 'MKR',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 6114750.0,
#   'available_supply': 11000000.0,
#   'id': 'augur',
#   'last_updated': 1518196446,
#   'market_cap_usd': 608413300.0,
#   'max_supply': None,
#   'name': 'Augur',
#   'percent_change_1h': 1.5,
#   'percent_change_24h': 7.34,
#   'percent_change_7d': 0.19,
#   'price_btc': 0.00658585,
#   'price_usd': 55.3103,
#   'rank': 36,
#   'symbol': 'REP',
#   'total_supply': 11000000.0},
#  {'24h_volume_usd': 24944500.0,
#   'available_supply': 2000000.0,
#   'id': 'digixdao',
#   'last_updated': 1518196446,
#   'market_cap_usd': 596384000.0,
#   'max_supply': None,
#   'name': 'DigixDAO',
#   'percent_change_1h': 0.44,
#   'percent_change_24h': 3.34,
#   'percent_change_7d': -14.39,
#   'price_btc': 0.0355061,
#   'price_usd': 298.192,
#   'rank': 37,
#   'symbol': 'DGD',
#   'total_supply': 2000000.0},
#  {'24h_volume_usd': 26747900.0,
#   'available_supply': 100000000.0,
#   'id': 'waves',
#   'last_updated': 1518196446,
#   'market_cap_usd': 579818000.0,
#   'max_supply': None,
#   'name': 'Waves',
#   'percent_change_1h': 0.86,
#   'percent_change_24h': 7.62,
#   'percent_change_7d': -4.56,
#   'price_btc': 0.0006904,
#   'price_usd': 5.79818,
#   'rank': 38,
#   'symbol': 'WAVES',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 16810500.0,
#   'available_supply': 24898178.0,
#   'id': 'walton',
#   'last_updated': 1518196453,
#   'market_cap_usd': 578907537.0,
#   'max_supply': 100000000.0,
#   'name': 'Walton',
#   'percent_change_1h': 0.43,
#   'percent_change_24h': 3.35,
#   'percent_change_7d': -2.66,
#   'price_btc': 0.00276852,
#   'price_usd': 23.251,
#   'rank': 39,
#   'symbol': 'WTC',
#   'total_supply': 70000000.0},
#  {'24h_volume_usd': 13077100.0,
#   'available_supply': 507188082.0,
#   'id': '0x',
#   'last_updated': 1518196453,
#   'market_cap_usd': 568902728.0,
#   'max_supply': None,
#   'name': '0x',
#   'percent_change_1h': -0.02,
#   'percent_change_24h': 5.64,
#   'percent_change_7d': -12.42,
#   'price_btc': 0.00013356,
#   'price_usd': 1.12168,
#   'rank': 40,
#   'symbol': 'ZRX',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 179749.0,
#   'available_supply': 2036645.0,
#   'id': 'veritaseum',
#   'last_updated': 1518196450,
#   'market_cap_usd': 560067313.0,
#   'max_supply': None,
#   'name': 'Veritaseum',
#   'percent_change_1h': -5.97,
#   'percent_change_24h': -0.85,
#   'percent_change_7d': -14.18,
#   'price_btc': 0.0327439,
#   'price_usd': 274.995,
#   'rank': 41,
#   'symbol': 'VERI',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 9836060.0,
#   'available_supply': 113132925740,
#   'id': 'dogecoin',
#   'last_updated': 1518196454,
#   'market_cap_usd': 539507165.0,
#   'max_supply': None,
#   'name': 'Dogecoin',
#   'percent_change_1h': 0.8,
#   'percent_change_24h': 4.73,
#   'percent_change_7d': 10.3,
#   'price_btc': 5.7e-07,
#   'price_usd': 0.00476879,
#   'rank': 42,
#   'symbol': 'DOGE',
#   'total_supply': 113132925740},
#  {'24h_volume_usd': 1761810.0,
#   'available_supply': 6723151.0,
#   'id': 'decred',
#   'last_updated': 1518196445,
#   'market_cap_usd': 535571557.0,
#   'max_supply': 21000000.0,
#   'name': 'Decred',
#   'percent_change_1h': 0.42,
#   'percent_change_24h': 6.96,
#   'percent_change_7d': 4.15,
#   'price_btc': 0.0094853,
#   'price_usd': 79.6608,
#   'rank': 43,
#   'symbol': 'DCR',
#   'total_supply': 7143151.0},
#  {'24h_volume_usd': 78461700.0,
#   'available_supply': 42603018.0,
#   'id': 'hshare',
#   'last_updated': 1518196453,
#   'market_cap_usd': 517166551.0,
#   'max_supply': 84000000.0,
#   'name': 'Hshare',
#   'percent_change_1h': 2.66,
#   'percent_change_24h': 13.61,
#   'percent_change_7d': 9.11,
#   'price_btc': 0.00144543,
#   'price_usd': 12.1392,
#   'rank': 44,
#   'symbol': 'HSR',
#   'total_supply': 42603018.0},
#  {'24h_volume_usd': 2798790.0,
#   'available_supply': 91043076.0,
#   'id': 'kucoin-shares',
#   'last_updated': 1518196455,
#   'market_cap_usd': 514751179.0,
#   'max_supply': None,
#   'name': 'KuCoin Shares',
#   'percent_change_1h': -2.29,
#   'percent_change_24h': -1.98,
#   'percent_change_7d': -11.31,
#   'price_btc': 0.00067322,
#   'price_usd': 5.65393,
#   'rank': 45,
#   'symbol': 'KCS',
#   'total_supply': 181043076.0},
#  {'24h_volume_usd': 67512000.0,
#   'available_supply': 998999495.0,
#   'id': 'ardor',
#   'last_updated': 1518196447,
#   'market_cap_usd': 492743514.0,
#   'max_supply': 998999495.0,
#   'name': 'Ardor',
#   'percent_change_1h': 0.95,
#   'percent_change_24h': 12.34,
#   'percent_change_7d': 3.9,
#   'price_btc': 5.873e-05,
#   'price_usd': 0.493237,
#   'rank': 46,
#   'symbol': 'ARDR',
#   'total_supply': 998999495.0},
#  {'24h_volume_usd': 715378.0,
#   'available_supply': 344166289.0,
#   'id': 'rchain',
#   'last_updated': 1518196454,
#   'market_cap_usd': 481722671.0,
#   'max_supply': 1000000000.0,
#   'name': 'RChain',
#   'percent_change_1h': -3.36,
#   'percent_change_24h': 4.86,
#   'percent_change_7d': -13.39,
#   'price_btc': 0.00016666,
#   'price_usd': 1.39968,
#   'rank': 47,
#   'symbol': 'RHOC',
#   'total_supply': 870663574.0},
#  {'24h_volume_usd': 4773750.0,
#   'available_supply': 103149407.0,
#   'id': 'komodo',
#   'last_updated': 1518196449,
#   'market_cap_usd': 443721930.0,
#   'max_supply': None,
#   'name': 'Komodo',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 10.23,
#   'percent_change_7d': 0.9,
#   'price_btc': 0.00051221,
#   'price_usd': 4.30174,
#   'rank': 48,
#   'symbol': 'KMD',
#   'total_supply': 103149407.0},
#  {'24h_volume_usd': 5193660.0,
#   'available_supply': 184450000.0,
#   'id': 'revain',
#   'last_updated': 1518196456,
#   'market_cap_usd': 439029735.0,
#   'max_supply': 484450000.0,
#   'name': 'Revain',
#   'percent_change_1h': 1.64,
#   'percent_change_24h': 14.23,
#   'percent_change_7d': 61.9,
#   'price_btc': 0.00028342,
#   'price_usd': 2.38021,
#   'rank': 49,
#   'symbol': 'R',
#   'total_supply': 484450000.0},
#  {'24h_volume_usd': 7307200.0,
#   'available_supply': 134132697.0,
#   'id': 'kyber-network',
#   'last_updated': 1518196454,
#   'market_cap_usd': 432344557.0,
#   'max_supply': None,
#   'name': 'Kyber Network',
#   'percent_change_1h': -0.92,
#   'percent_change_24h': 4.77,
#   'percent_change_7d': -1.59,
#   'price_btc': 0.0003838,
#   'price_usd': 3.22326,
#   'rank': 50,
#   'symbol': 'KNC',
#   'total_supply': 215625349.0},
#  {'24h_volume_usd': 2514440.0,
#   'available_supply': 6104472864.0,
#   'id': 'electroneum',
#   'last_updated': 1518196456,
#   'market_cap_usd': 429298886.0,
#   'max_supply': 21000000000.0,
#   'name': 'Electroneum',
#   'percent_change_1h': 1.67,
#   'percent_change_24h': 3.67,
#   'percent_change_7d': 9.77,
#   'price_btc': 8.37e-06,
#   'price_usd': 0.0703253,
#   'rank': 51,
#   'symbol': 'ETN',
#   'total_supply': 6104472864.0},
#  {'24h_volume_usd': 9033060.0,
#   'available_supply': 100525098.0,
#   'id': 'ark',
#   'last_updated': 1518196449,
#   'market_cap_usd': 426045470.0,
#   'max_supply': None,
#   'name': 'Ark',
#   'percent_change_1h': 0.27,
#   'percent_change_24h': 10.95,
#   'percent_change_7d': -1.66,
#   'price_btc': 0.00050465,
#   'price_usd': 4.2382,
#   'rank': 52,
#   'symbol': 'ARK',
#   'total_supply': 131775098.0},
#  {'24h_volume_usd': 8766290.0,
#   'available_supply': 9674948.0,
#   'id': 'gas',
#   'last_updated': 1518196452,
#   'market_cap_usd': 407586213.0,
#   'max_supply': 100000000.0,
#   'name': 'Gas',
#   'percent_change_1h': 0.69,
#   'percent_change_24h': 3.43,
#   'percent_change_7d': -7.62,
#   'price_btc': 0.00501622,
#   'price_usd': 42.128,
#   'rank': 53,
#   'symbol': 'GAS',
#   'total_supply': 15257048.0},
#  {'24h_volume_usd': 11673300.0,
#   'available_supply': 6508988220.0,
#   'id': 'zilliqa',
#   'last_updated': 1518196460,
#   'market_cap_usd': 380876700.0,
#   'max_supply': None,
#   'name': 'Zilliqa',
#   'percent_change_1h': 0.37,
#   'percent_change_24h': 2.32,
#   'percent_change_7d': -11.91,
#   'price_btc': 6.97e-06,
#   'price_usd': 0.0585155,
#   'rank': 54,
#   'symbol': 'ZIL',
#   'total_supply': 12600000000.0},
#  {'24h_volume_usd': 5550040.0,
#   'available_supply': 1000000000.0,
#   'id': 'basic-attention-token',
#   'last_updated': 1518196450,
#   'market_cap_usd': 378475000.0,
#   'max_supply': None,
#   'name': 'Basic Attention Token',
#   'percent_change_1h': 0.88,
#   'percent_change_24h': 1.48,
#   'percent_change_7d': -5.67,
#   'price_btc': 4.507e-05,
#   'price_usd': 0.378475,
#   'rank': 55,
#   'symbol': 'BAT',
#   'total_supply': 1500000000.0},
#  {'24h_volume_usd': 2224850.0,
#   'available_supply': 238421940.0,
#   'id': 'dragonchain',
#   'last_updated': 1518196457,
#   'market_cap_usd': 378459066.0,
#   'max_supply': None,
#   'name': 'Dragonchain',
#   'percent_change_1h': 2.74,
#   'percent_change_24h': 5.56,
#   'percent_change_7d': -3.77,
#   'price_btc': 0.00018901,
#   'price_usd': 1.58735,
#   'rank': 56,
#   'symbol': 'DRGN',
#   'total_supply': 433494437.0},
#  {'24h_volume_usd': 6298390.0,
#   'available_supply': 9818221892.0,
#   'id': 'digibyte',
#   'last_updated': 1518196441,
#   'market_cap_usd': 374808657.0,
#   'max_supply': 21000000000.0,
#   'name': 'DigiByte',
#   'percent_change_1h': 1.59,
#   'percent_change_24h': 16.49,
#   'percent_change_7d': -4.66,
#   'price_btc': 4.55e-06,
#   'price_usd': 0.0381748,
#   'rank': 57,
#   'symbol': 'DGB',
#   'total_supply': 9818221892.0},
#  {'24h_volume_usd': 2906350.0,
#   'available_supply': 561202251.0,
#   'id': 'loopring',
#   'last_updated': 1518196454,
#   'market_cap_usd': 371707260.0,
#   'max_supply': None,
#   'name': 'Loopring',
#   'percent_change_1h': 0.47,
#   'percent_change_24h': 5.47,
#   'percent_change_7d': -11.5,
#   'price_btc': 7.887e-05,
#   'price_usd': 0.662341,
#   'rank': 58,
#   'symbol': 'LRC',
#   'total_supply': 1374956357.0},
#  {'24h_volume_usd': 601262.0,
#   'available_supply': 325226613094,
#   'id': 'dentacoin',
#   'last_updated': 1518196453,
#   'market_cap_usd': 359476228.0,
#   'max_supply': 8000000000000,
#   'name': 'Dentacoin',
#   'percent_change_1h': 1.28,
#   'percent_change_24h': 4.13,
#   'percent_change_7d': 7.13,
#   'price_btc': 1.3e-07,
#   'price_usd': 0.00110531,
#   'rank': 59,
#   'symbol': 'DCN',
#   'total_supply': 1963173416169},
#  {'24h_volume_usd': 43619300.0,
#   'available_supply': 250000000.0,
#   'id': 'aelf',
#   'last_updated': 1518196457,
#   'market_cap_usd': 335222500.0,
#   'max_supply': None,
#   'name': 'aelf',
#   'percent_change_1h': 1.77,
#   'percent_change_24h': 5.34,
#   'percent_change_7d': -12.96,
#   'price_btc': 0.00015966,
#   'price_usd': 1.34089,
#   'rank': 60,
#   'symbol': 'ELF',
#   'total_supply': 260000000.0},
#  {'24h_volume_usd': 16461000.0,
#   'available_supply': 987000000.0,
#   'id': 'bytom',
#   'last_updated': 1518196452,
#   'market_cap_usd': 334722297.0,
#   'max_supply': None,
#   'name': 'Bytom',
#   'percent_change_1h': 0.79,
#   'percent_change_24h': 15.66,
#   'percent_change_7d': 4.54,
#   'price_btc': 4.038e-05,
#   'price_usd': 0.339131,
#   'rank': 61,
#   'symbol': 'BTM',
#   'total_supply': 1407000000.0},
#  {'24h_volume_usd': 14227200.0,
#   'available_supply': 55525983.0,
#   'id': 'pivx',
#   'last_updated': 1518196446,
#   'market_cap_usd': 332481811.0,
#   'max_supply': None,
#   'name': 'PIVX',
#   'percent_change_1h': 0.6,
#   'percent_change_24h': 11.71,
#   'percent_change_7d': 6.8,
#   'price_btc': 0.00071298,
#   'price_usd': 5.98786,
#   'rank': 62,
#   'symbol': 'PIVX',
#   'total_supply': 55525983.0},
#  {'24h_volume_usd': 6922360.0,
#   'available_supply': 75601200.0,
#   'id': 'ethos',
#   'last_updated': 1518196452,
#   'market_cap_usd': 328676215.0,
#   'max_supply': None,
#   'name': 'Ethos',
#   'percent_change_1h': 0.46,
#   'percent_change_24h': 3.44,
#   'percent_change_7d': 18.61,
#   'price_btc': 0.00051766,
#   'price_usd': 4.3475,
#   'rank': 63,
#   'symbol': 'ETHOS',
#   'total_supply': 222295208.0},
#  {'24h_volume_usd': 461890.0,
#   'available_supply': 4981227.0,
#   'id': 'e-coin',
#   'last_updated': 1518196450,
#   'market_cap_usd': 324981746.0,
#   'max_supply': None,
#   'name': 'E-coin',
#   'percent_change_1h': -2.04,
#   'percent_change_24h': 1141.68,
#   'percent_change_7d': 1245.64,
#   'price_btc': 0.00776836,
#   'price_usd': 65.2413,
#   'rank': 64,
#   'symbol': 'ECN',
#   'total_supply': 213270119.0},
#  {'24h_volume_usd': 4751980.0,
#   'available_supply': 3264950.0,
#   'id': 'zclassic',
#   'last_updated': 1518196447,
#   'market_cap_usd': 322060871.0,
#   'max_supply': 21000000.0,
#   'name': 'ZClassic',
#   'percent_change_1h': 1.09,
#   'percent_change_24h': 0.48,
#   'percent_change_7d': 2.6,
#   'price_btc': 0.0117454,
#   'price_usd': 98.6419,
#   'rank': 65,
#   'symbol': 'ZCL',
#   'total_supply': 3264950.0},
#  {'24h_volume_usd': 746244.0,
#   'available_supply': 645222.0,
#   'id': 'byteball',
#   'last_updated': 1518196448,
#   'market_cap_usd': 317799606.0,
#   'max_supply': None,
#   'name': 'Byteball Bytes',
#   'percent_change_1h': 1.55,
#   'percent_change_24h': 7.69,
#   'percent_change_7d': -6.09,
#   'price_btc': 0.0586476,
#   'price_usd': 492.543,
#   'rank': 66,
#   'symbol': 'GBYTE',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 296545.0,
#   'available_supply': 227384800.0,
#   'id': 'pillar',
#   'last_updated': 1518196452,
#   'market_cap_usd': 313734178.0,
#   'max_supply': None,
#   'name': 'Pillar',
#   'percent_change_1h': -1.11,
#   'percent_change_24h': 0.2,
#   'percent_change_7d': 7.25,
#   'price_btc': 0.00016429,
#   'price_usd': 1.37975,
#   'rank': 67,
#   'symbol': 'PLR',
#   'total_supply': 800000000.0},
#  {'24h_volume_usd': 2982340.0,
#   'available_supply': 350000000.0,
#   'id': 'qash',
#   'last_updated': 1518196457,
#   'market_cap_usd': 309459500.0,
#   'max_supply': None,
#   'name': 'QASH',
#   'percent_change_1h': 0.75,
#   'percent_change_24h': 4.96,
#   'percent_change_7d': -2.21,
#   'price_btc': 0.00010528,
#   'price_usd': 0.88417,
#   'rank': 68,
#   'symbol': 'QASH',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 6943180.0,
#   'available_supply': 35500000.0,
#   'id': 'nebulas-token',
#   'last_updated': 1518196453,
#   'market_cap_usd': 300141140.0,
#   'max_supply': 100000000.0,
#   'name': 'Nebulas',
#   'percent_change_1h': 0.49,
#   'percent_change_24h': 8.69,
#   'percent_change_7d': -3.8,
#   'price_btc': 0.00100671,
#   'price_usd': 8.45468,
#   'rank': 69,
#   'symbol': 'NAS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 29533100.0,
#   'available_supply': 4503688789.0,
#   'id': 'funfair',
#   'last_updated': 1518196451,
#   'market_cap_usd': 290966219.0,
#   'max_supply': None,
#   'name': 'FunFair',
#   'percent_change_1h': 0.52,
#   'percent_change_24h': 4.57,
#   'percent_change_7d': 8.3,
#   'price_btc': 7.69e-06,
#   'price_usd': 0.0646062,
#   'rank': 70,
#   'symbol': 'FUN',
#   'total_supply': 10999873621.0},
#  {'24h_volume_usd': 6979030.0,
#   'available_supply': 834262000.0,
#   'id': 'golem-network-tokens',
#   'last_updated': 1518196448,
#   'market_cap_usd': 286512267.0,
#   'max_supply': None,
#   'name': 'Golem',
#   'percent_change_1h': 3.07,
#   'percent_change_24h': 5.82,
#   'percent_change_7d': -2.89,
#   'price_btc': 4.089e-05,
#   'price_usd': 0.343432,
#   'rank': 71,
#   'symbol': 'GNT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 224560.0,
#   'available_supply': 45106492.0,
#   'id': 'cryptonex',
#   'last_updated': 1518196454,
#   'market_cap_usd': 283860568.0,
#   'max_supply': 210000000.0,
#   'name': 'Cryptonex',
#   'percent_change_1h': 0.57,
#   'percent_change_24h': 1.17,
#   'percent_change_7d': 0.45,
#   'price_btc': 0.00074933,
#   'price_usd': 6.29312,
#   'rank': 72,
#   'symbol': 'CNX',
#   'total_supply': 106544118.0},
#  {'24h_volume_usd': 12079400.0,
#   'available_supply': 1445976590.0,
#   'id': 'cindicator',
#   'last_updated': 1518196455,
#   'market_cap_usd': 282284996.0,
#   'max_supply': None,
#   'name': 'Cindicator',
#   'percent_change_1h': 0.42,
#   'percent_change_24h': 3.48,
#   'percent_change_7d': 2.78,
#   'price_btc': 2.325e-05,
#   'price_usd': 0.195221,
#   'rank': 73,
#   'symbol': 'CND',
#   'total_supply': 2000000005.0},
#  {'24h_volume_usd': 2758120.0,
#   'available_supply': 10614760961.0,
#   'id': 'dent',
#   'last_updated': 1518196452,
#   'market_cap_usd': 280784841.0,
#   'max_supply': None,
#   'name': 'Dent',
#   'percent_change_1h': 0.32,
#   'percent_change_24h': 3.21,
#   'percent_change_7d': 21.24,
#   'price_btc': 3.15e-06,
#   'price_usd': 0.0264523,
#   'rank': 74,
#   'symbol': 'DENT',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 3874520.0,
#   'available_supply': 530834602.0,
#   'id': 'syscoin',
#   'last_updated': 1518196443,
#   'market_cap_usd': 276096631.0,
#   'max_supply': 888000000.0,
#   'name': 'Syscoin',
#   'percent_change_1h': 0.56,
#   'percent_change_24h': 0.44,
#   'percent_change_7d': 12.58,
#   'price_btc': 6.193e-05,
#   'price_usd': 0.520118,
#   'rank': 75,
#   'symbol': 'SYS',
#   'total_supply': 530834602.0},
#  {'24h_volume_usd': 1355250.0,
#   'available_supply': 11168193.0,
#   'id': 'bitcore',
#   'last_updated': 1518196450,
#   'market_cap_usd': 273350467.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcore',
#   'percent_change_1h': -0.12,
#   'percent_change_24h': 0.54,
#   'percent_change_7d': 9.91,
#   'price_btc': 0.00291436,
#   'price_usd': 24.4758,
#   'rank': 76,
#   'symbol': 'BTX',
#   'total_supply': 16795131.0},
#  {'24h_volume_usd': 39548000.0,
#   'available_supply': 6794109922.0,
#   'id': 'iostoken',
#   'last_updated': 1518196459,
#   'market_cap_usd': 268056851.0,
#   'max_supply': None,
#   'name': 'IOStoken',
#   'percent_change_1h': -1.25,
#   'percent_change_24h': 3.3,
#   'percent_change_7d': -11.93,
#   'price_btc': 4.7e-06,
#   'price_usd': 0.0394543,
#   'rank': 77,
#   'symbol': 'IOST',
#   'total_supply': 21000000000.0},
#  {'24h_volume_usd': 17381000.0,
#   'available_supply': 60000000.0,
#   'id': 'gxshares',
#   'last_updated': 1518196451,
#   'market_cap_usd': 264427800.0,
#   'max_supply': 100000000.0,
#   'name': 'GXShares',
#   'percent_change_1h': 0.56,
#   'percent_change_24h': 6.14,
#   'percent_change_7d': 2.44,
#   'price_btc': 0.00052476,
#   'price_usd': 4.40713,
#   'rank': 78,
#   'symbol': 'GXS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 18173100.0,
#   'available_supply': 363837589.0,
#   'id': 'power-ledger',
#   'last_updated': 1518196455,
#   'market_cap_usd': 258284302.0,
#   'max_supply': None,
#   'name': 'Power Ledger',
#   'percent_change_1h': 0.89,
#   'percent_change_24h': 6.31,
#   'percent_change_7d': 9.61,
#   'price_btc': 8.453e-05,
#   'price_usd': 0.709889,
#   'rank': 79,
#   'symbol': 'POWR',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 6530980.0,
#   'available_supply': 52847204.0,
#   'id': 'salt',
#   'last_updated': 1518196454,
#   'market_cap_usd': 240792998.0,
#   'max_supply': None,
#   'name': 'SALT',
#   'percent_change_1h': 0.41,
#   'percent_change_24h': 3.49,
#   'percent_change_7d': 2.01,
#   'price_btc': 0.00054254,
#   'price_usd': 4.5564,
#   'rank': 80,
#   'symbol': 'SALT',
#   'total_supply': 120000000.0},
#  {'24h_volume_usd': 5148610.0,
#   'available_supply': 8745102.0,
#   'id': 'factom',
#   'last_updated': 1518196445,
#   'market_cap_usd': 240659085.0,
#   'max_supply': None,
#   'name': 'Factom',
#   'percent_change_1h': 3.56,
#   'percent_change_24h': 8.97,
#   'percent_change_7d': 0.88,
#   'price_btc': 0.00327675,
#   'price_usd': 27.5193,
#   'rank': 81,
#   'symbol': 'FCT',
#   'total_supply': 8745102.0},
#  {'24h_volume_usd': 4994720.0,
#   'available_supply': 79265735.0,
#   'id': 'aion',
#   'last_updated': 1518196454,
#   'market_cap_usd': 229468754.0,
#   'max_supply': None,
#   'name': 'Aion',
#   'percent_change_1h': 0.48,
#   'percent_change_24h': 3.31,
#   'percent_change_7d': -8.83,
#   'price_btc': 0.0003447,
#   'price_usd': 2.89493,
#   'rank': 82,
#   'symbol': 'AION',
#   'total_supply': 465934587.0},
#  {'24h_volume_usd': 150904.0,
#   'available_supply': 756097560976,
#   'id': 'kin',
#   'last_updated': 1518196454,
#   'market_cap_usd': 225773756.0,
#   'max_supply': None,
#   'name': 'Kin',
#   'percent_change_1h': 3.33,
#   'percent_change_24h': 11.62,
#   'percent_change_7d': 4.35,
#   'price_btc': 4e-08,
#   'price_usd': 0.000298604,
#   'rank': 83,
#   'symbol': 'KIN',
#   'total_supply': 10000000000000},
#  {'24h_volume_usd': 3086850.0,
#   'available_supply': 57307200.0,
#   'id': 'monacoin',
#   'last_updated': 1518196442,
#   'market_cap_usd': 220472833.0,
#   'max_supply': None,
#   'name': 'MonaCoin',
#   'percent_change_1h': 0.77,
#   'percent_change_24h': 4.57,
#   'percent_change_7d': 2.25,
#   'price_btc': 0.00045809,
#   'price_usd': 3.84721,
#   'rank': 84,
#   'symbol': 'MONA',
#   'total_supply': 57307200.0},
#  {'24h_volume_usd': 278666.0,
#   'available_supply': 682428721.0,
#   'id': 'smartcash',
#   'last_updated': 1518196453,
#   'market_cap_usd': 218638561.0,
#   'max_supply': 5000000000.0,
#   'name': 'SmartCash',
#   'percent_change_1h': 0.82,
#   'percent_change_24h': 0.02,
#   'percent_change_7d': -8.16,
#   'price_btc': 3.815e-05,
#   'price_usd': 0.320383,
#   'rank': 85,
#   'symbol': 'SMART',
#   'total_supply': 1283473000.0},
#  {'24h_volume_usd': 7150430.0,
#   'available_supply': 4068562.0,
#   'id': 'zcoin',
#   'last_updated': 1518196447,
#   'market_cap_usd': 211456592.0,
#   'max_supply': None,
#   'name': 'ZCoin',
#   'percent_change_1h': 1.85,
#   'percent_change_24h': 6.22,
#   'percent_change_7d': -0.5,
#   'price_btc': 0.00618852,
#   'price_usd': 51.9733,
#   'rank': 86,
#   'symbol': 'XZC',
#   'total_supply': 4068562.0},
#  {'24h_volume_usd': 370832.0,
#   'available_supply': 8865486.0,
#   'id': 'particl',
#   'last_updated': 1518196452,
#   'market_cap_usd': 204898230.0,
#   'max_supply': None,
#   'name': 'Particl',
#   'percent_change_1h': 0.94,
#   'percent_change_24h': 14.17,
#   'percent_change_7d': 9.16,
#   'price_btc': 0.00275196,
#   'price_usd': 23.1119,
#   'rank': 87,
#   'symbol': 'PART',
#   'total_supply': 8865486.0},
#  {'24h_volume_usd': 7421990.0,
#   'available_supply': 74836171.0,
#   'id': 'enigma-project',
#   'last_updated': 1518196455,
#   'market_cap_usd': 204836329.0,
#   'max_supply': None,
#   'name': 'Enigma',
#   'percent_change_1h': 2.63,
#   'percent_change_24h': 12.34,
#   'percent_change_7d': 6.1,
#   'price_btc': 0.00032591,
#   'price_usd': 2.73713,
#   'rank': 88,
#   'symbol': 'ENG',
#   'total_supply': 150000000.0},
#  {'24h_volume_usd': 6632460.0,
#   'available_supply': 38986587.0,
#   'id': 'bancor',
#   'last_updated': 1518196451,
#   'market_cap_usd': 200210160.0,
#   'max_supply': None,
#   'name': 'Bancor',
#   'percent_change_1h': 0.68,
#   'percent_change_24h': 5.91,
#   'percent_change_7d': -9.76,
#   'price_btc': 0.00061147,
#   'price_usd': 5.13536,
#   'rank': 89,
#   'symbol': 'BNT',
#   'total_supply': 74985159.0},
#  {'24h_volume_usd': 19285300.0,
#   'available_supply': 617314171.0,
#   'id': 'quantstamp',
#   'last_updated': 1518196457,
#   'market_cap_usd': 199511619.0,
#   'max_supply': None,
#   'name': 'Quantstamp',
#   'percent_change_1h': 0.27,
#   'percent_change_24h': 6.46,
#   'percent_change_7d': 23.63,
#   'price_btc': 3.848e-05,
#   'price_usd': 0.323193,
#   'rank': 90,
#   'symbol': 'QSP',
#   'total_supply': 976442388.0},
#  {'24h_volume_usd': 1865700.0,
#   'available_supply': 452552412.0,
#   'id': 'maidsafecoin',
#   'last_updated': 1518196442,
#   'market_cap_usd': 196118566.0,
#   'max_supply': None,
#   'name': 'MaidSafeCoin',
#   'percent_change_1h': 1.72,
#   'percent_change_24h': 5.44,
#   'percent_change_7d': 6.44,
#   'price_btc': 5.16e-05,
#   'price_usd': 0.433361,
#   'rank': 91,
#   'symbol': 'MAID',
#   'total_supply': 452552412.0},
#  {'24h_volume_usd': 9815260.0,
#   'available_supply': 998999942.0,
#   'id': 'nxt',
#   'last_updated': 1518196441,
#   'market_cap_usd': 195965827.0,
#   'max_supply': 1000000000.0,
#   'name': 'Nxt',
#   'percent_change_1h': 1.44,
#   'percent_change_24h': 10.62,
#   'percent_change_7d': -7.82,
#   'price_btc': 2.336e-05,
#   'price_usd': 0.196162,
#   'rank': 92,
#   'symbol': 'NXT',
#   'total_supply': 998999942.0},
#  {'24h_volume_usd': 945391.0,
#   'available_supply': 454443782.0,
#   'id': 'singularitynet',
#   'last_updated': 1518196459,
#   'market_cap_usd': 194527842.0,
#   'max_supply': None,
#   'name': 'SingularityNET',
#   'percent_change_1h': -0.75,
#   'percent_change_24h': 2.27,
#   'percent_change_7d': -17.98,
#   'price_btc': 5.097e-05,
#   'price_usd': 0.428057,
#   'rank': 93,
#   'symbol': 'AGI',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 6229170.0,
#   'available_supply': 641462769.0,
#   'id': 'request-network',
#   'last_updated': 1518196454,
#   'market_cap_usd': 188084581.0,
#   'max_supply': None,
#   'name': 'Request Network',
#   'percent_change_1h': 0.76,
#   'percent_change_24h': 2.17,
#   'percent_change_7d': -5.22,
#   'price_btc': 3.491e-05,
#   'price_usd': 0.293212,
#   'rank': 94,
#   'symbol': 'REQ',
#   'total_supply': 999999999.0},
#  {'24h_volume_usd': 1527530.0,
#   'available_supply': 1000000000.0,
#   'id': 'xplay',
#   'last_updated': 1518196454,
#   'market_cap_usd': 186387000.0,
#   'max_supply': None,
#   'name': 'XPlay',
#   'percent_change_1h': 0.22,
#   'percent_change_24h': 3.88,
#   'percent_change_7d': 32.19,
#   'price_btc': 2.219e-05,
#   'price_usd': 0.186387,
#   'rank': 95,
#   'symbol': 'XPA',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 1897440.0,
#   'available_supply': 28740055495.0,
#   'id': 'reddcoin',
#   'last_updated': 1518196441,
#   'market_cap_usd': 185933214.0,
#   'max_supply': None,
#   'name': 'ReddCoin',
#   'percent_change_1h': 0.93,
#   'percent_change_24h': 8.07,
#   'percent_change_7d': -4.52,
#   'price_btc': 7.7e-07,
#   'price_usd': 0.00646948,
#   'rank': 96,
#   'symbol': 'RDD',
#   'total_supply': 28740055495.0},
#  {'24h_volume_usd': 14734000.0,
#   'available_supply': 761143950.0,
#   'id': 'ignis',
#   'last_updated': 1518196458,
#   'market_cap_usd': 185324090.0,
#   'max_supply': 999449694.0,
#   'name': 'Ignis',
#   'percent_change_1h': 4.6,
#   'percent_change_24h': 24.34,
#   'percent_change_7d': -8.04,
#   'price_btc': 2.899e-05,
#   'price_usd': 0.243481,
#   'rank': 97,
#   'symbol': 'IGNIS',
#   'total_supply': 999449694.0},
#  {'24h_volume_usd': 622580.0,
#   'available_supply': 55514082.0,
#   'id': 'nexus',
#   'last_updated': 1518196444,
#   'market_cap_usd': 178893020.0,
#   'max_supply': None,
#   'name': 'Nexus',
#   'percent_change_1h': 0.42,
#   'percent_change_24h': 1.89,
#   'percent_change_7d': -9.3,
#   'price_btc': 0.0003837,
#   'price_usd': 3.22248,
#   'rank': 98,
#   'symbol': 'NXS',
#   'total_supply': 55514082.0},
#  {'24h_volume_usd': 3678460.0,
#   'available_supply': 104661310.0,
#   'id': 'tenx',
#   'last_updated': 1518196451,
#   'market_cap_usd': 177271140.0,
#   'max_supply': None,
#   'name': 'TenX',
#   'percent_change_1h': 1.37,
#   'percent_change_24h': 9.29,
#   'percent_change_7d': -7.0,
#   'price_btc': 0.00020168,
#   'price_usd': 1.69376,
#   'rank': 99,
#   'symbol': 'PAY',
#   'total_supply': 205218256.0},
#  {'24h_volume_usd': 743226.0,
#   'available_supply': 213749826479,
#   'id': 'experience-points',
#   'last_updated': 1518196447,
#   'market_cap_usd': 176733487.0,
#   'max_supply': None,
#   'name': 'Experience Points',
#   'percent_change_1h': 3.23,
#   'percent_change_24h': 13.83,
#   'percent_change_7d': 63.55,
#   'price_btc': 1e-07,
#   'price_usd': 0.000826824,
#   'rank': 100,
#   'symbol': 'XP',
#   'total_supply': 248781594344},
#  {'24h_volume_usd': 1313940.0,
#   'available_supply': 99735687.0,
#   'id': 'iconomi',
#   'last_updated': 1518196447,
#   'market_cap_usd': 168683965.0,
#   'max_supply': None,
#   'name': 'Iconomi',
#   'percent_change_1h': 0.56,
#   'percent_change_24h': 6.62,
#   'percent_change_7d': -11.22,
#   'price_btc': 0.00020139,
#   'price_usd': 1.69131,
#   'rank': 101,
#   'symbol': 'ICN',
#   'total_supply': 99735687.0},
#  {'24h_volume_usd': 3840730.0,
#   'available_supply': 492954537.0,
#   'id': 'wax',
#   'last_updated': 1518196458,
#   'market_cap_usd': 163478020.0,
#   'max_supply': None,
#   'name': 'WAX',
#   'percent_change_1h': -0.76,
#   'percent_change_24h': 5.68,
#   'percent_change_7d': 0.14,
#   'price_btc': 3.949e-05,
#   'price_usd': 0.331629,
#   'rank': 102,
#   'symbol': 'WAX',
#   'total_supply': 1850000000.0},
#  {'24h_volume_usd': 12890500.0,
#   'available_supply': 342699966.0,
#   'id': 'civic',
#   'last_updated': 1518196452,
#   'market_cap_usd': 159509014.0,
#   'max_supply': None,
#   'name': 'Civic',
#   'percent_change_1h': -0.57,
#   'percent_change_24h': -3.7,
#   'percent_change_7d': 11.57,
#   'price_btc': 5.542e-05,
#   'price_usd': 0.465448,
#   'rank': 103,
#   'symbol': 'CVC',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 904703.0,
#   'available_supply': 41282282.0,
#   'id': 'emercoin',
#   'last_updated': 1518196443,
#   'market_cap_usd': 157668593.0,
#   'max_supply': None,
#   'name': 'Emercoin',
#   'percent_change_1h': 0.66,
#   'percent_change_24h': -1.42,
#   'percent_change_7d': -2.96,
#   'price_btc': 0.00045477,
#   'price_usd': 3.81928,
#   'rank': 104,
#   'symbol': 'EMC',
#   'total_supply': 41282282.0},
#  {'24h_volume_usd': 472066.0,
#   'available_supply': 1104590.0,
#   'id': 'gnosis-gno',
#   'last_updated': 1518196450,
#   'market_cap_usd': 156163620.0,
#   'max_supply': None,
#   'name': 'Gnosis',
#   'percent_change_1h': -0.3,
#   'percent_change_24h': 0.7,
#   'percent_change_7d': -8.62,
#   'price_btc': 0.0168339,
#   'price_usd': 141.377,
#   'rank': 105,
#   'symbol': 'GNO',
#   'total_supply': 10000000.0},
#  {'24h_volume_usd': 3331750.0,
#   'available_supply': 12801321.0,
#   'id': 'neblio',
#   'last_updated': 1518196454,
#   'market_cap_usd': 152310118.0,
#   'max_supply': None,
#   'name': 'Neblio',
#   'percent_change_1h': 0.76,
#   'percent_change_24h': 4.46,
#   'percent_change_7d': -5.44,
#   'price_btc': 0.00141671,
#   'price_usd': 11.898,
#   'rank': 106,
#   'symbol': 'NEBL',
#   'total_supply': 13547622.0},
#  {'24h_volume_usd': 1962400.0,
#   'available_supply': 64355352.0,
#   'id': 'gamecredits',
#   'last_updated': 1518196444,
#   'market_cap_usd': 151847097.0,
#   'max_supply': 84000000.0,
#   'name': 'GameCredits',
#   'percent_change_1h': 0.18,
#   'percent_change_24h': 1.45,
#   'percent_change_7d': -9.71,
#   'price_btc': 0.00028095,
#   'price_usd': 2.35951,
#   'rank': 107,
#   'symbol': 'GAME',
#   'total_supply': 64355352.0},
#  {'24h_volume_usd': 4497900.0,
#   'available_supply': 226091449.0,
#   'id': 'substratum',
#   'last_updated': 1518196453,
#   'market_cap_usd': 151694475.0,
#   'max_supply': None,
#   'name': 'Substratum',
#   'percent_change_1h': 1.19,
#   'percent_change_24h': 4.34,
#   'percent_change_7d': 6.6,
#   'price_btc': 7.989e-05,
#   'price_usd': 0.670943,
#   'rank': 108,
#   'symbol': 'SUB',
#   'total_supply': 352000000.0},
#  {'24h_volume_usd': 5412720.0,
#   'available_supply': 350000000.0,
#   'id': 'chainlink',
#   'last_updated': 1518196453,
#   'market_cap_usd': 148919750.0,
#   'max_supply': None,
#   'name': 'ChainLink',
#   'percent_change_1h': -0.39,
#   'percent_change_24h': 3.72,
#   'percent_change_7d': -7.12,
#   'price_btc': 5.066e-05,
#   'price_usd': 0.425485,
#   'rank': 109,
#   'symbol': 'LINK',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 4357550.0,
#   'available_supply': 50148936.0,
#   'id': 'raiden-network-token',
#   'last_updated': 1518196456,
#   'market_cap_usd': 147956913.0,
#   'max_supply': None,
#   'name': 'Raiden Network Token',
#   'percent_change_1h': 1.38,
#   'percent_change_24h': 6.88,
#   'percent_change_7d': -4.63,
#   'price_btc': 0.0003513,
#   'price_usd': 2.95035,
#   'rank': 110,
#   'symbol': 'RDN',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 2150950.0,
#   'available_supply': 42855575.0,
#   'id': 'vertcoin',
#   'last_updated': 1518196441,
#   'market_cap_usd': 139355616.0,
#   'max_supply': 84000000.0,
#   'name': 'Vertcoin',
#   'percent_change_1h': 0.3,
#   'percent_change_24h': 8.74,
#   'percent_change_7d': 7.24,
#   'price_btc': 0.00038719,
#   'price_usd': 3.25175,
#   'rank': 111,
#   'symbol': 'VTC',
#   'total_supply': 42855575.0},
#  {'24h_volume_usd': 42290.0,
#   'available_supply': 1288862.0,
#   'id': 'bitcoindark',
#   'last_updated': 1518196443,
#   'market_cap_usd': 137658214.0,
#   'max_supply': None,
#   'name': 'BitcoinDark',
#   'percent_change_1h': 0.19,
#   'percent_change_24h': 2.57,
#   'percent_change_7d': 2.82,
#   'price_btc': 0.0127176,
#   'price_usd': 106.806,
#   'rank': 112,
#   'symbol': 'BTCD',
#   'total_supply': 1288862.0},
#  {'24h_volume_usd': 6938790.0,
#   'available_supply': 22216600.0,
#   'id': 'high-performance-blockchain',
#   'last_updated': 1518196459,
#   'market_cap_usd': 137640279.0,
#   'max_supply': None,
#   'name': 'High Performance Blockchain',
#   'percent_change_1h': 2.03,
#   'percent_change_24h': 0.87,
#   'percent_change_7d': -12.21,
#   'price_btc': 0.00073769,
#   'price_usd': 6.19538,
#   'rank': 113,
#   'symbol': 'HPB',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 268971.0,
#   'available_supply': 5007388.0,
#   'id': 'blocknet',
#   'last_updated': 1518196443,
#   'market_cap_usd': 137175887.0,
#   'max_supply': None,
#   'name': 'Blocknet',
#   'percent_change_1h': 1.15,
#   'percent_change_24h': 3.36,
#   'percent_change_7d': -4.39,
#   'price_btc': 0.00326191,
#   'price_usd': 27.3947,
#   'rank': 114,
#   'symbol': 'BLOCK',
#   'total_supply': 5007388.0},
#  {'24h_volume_usd': 1689050.0,
#   'available_supply': 2966384100.0,
#   'id': 'medibloc',
#   'last_updated': 1518196458,
#   'market_cap_usd': 136044604.0,
#   'max_supply': 10000000000.0,
#   'name': 'MediBloc',
#   'percent_change_1h': 1.1,
#   'percent_change_24h': 5.37,
#   'percent_change_7d': -9.37,
#   'price_btc': 5.46e-06,
#   'price_usd': 0.0458621,
#   'rank': 115,
#   'symbol': 'MED',
#   'total_supply': 4097545844.0},
#  {'24h_volume_usd': 11250800.0,
#   'available_supply': 133425493.0,
#   'id': 'storj',
#   'last_updated': 1518196451,
#   'market_cap_usd': 135720411.0,
#   'max_supply': None,
#   'name': 'Storj',
#   'percent_change_1h': 1.82,
#   'percent_change_24h': 9.18,
#   'percent_change_7d': 4.79,
#   'price_btc': 0.00012112,
#   'price_usd': 1.0172,
#   'rank': 116,
#   'symbol': 'STORJ',
#   'total_supply': 424999998.0},
#  {'24h_volume_usd': 80251700.0,
#   'available_supply': 165000000.0,
#   'id': 'bluzelle',
#   'last_updated': 1518196460,
#   'market_cap_usd': 133059135.0,
#   'max_supply': None,
#   'name': 'Bluzelle',
#   'percent_change_1h': 0.39,
#   'percent_change_24h': 3.54,
#   'percent_change_7d': None,
#   'price_btc': 9.602e-05,
#   'price_usd': 0.806419,
#   'rank': 117,
#   'symbol': 'BLZ',
#   'total_supply': 500000000.0},
#  {'24h_volume_usd': 30715.9,
#   'available_supply': 816061.0,
#   'id': 'supernet-unity',
#   'last_updated': 1518196444,
#   'market_cap_usd': 131343350.0,
#   'max_supply': None,
#   'name': 'SuperNET',
#   'percent_change_1h': 0.79,
#   'percent_change_24h': 10.31,
#   'percent_change_7d': 50.69,
#   'price_btc': 0.0191642,
#   'price_usd': 160.948,
#   'rank': 118,
#   'symbol': 'UNITY',
#   'total_supply': 816061.0},
#  {'24h_volume_usd': 10768400.0,
#   'available_supply': 300000000.0,
#   'id': 'achain',
#   'last_updated': 1518196453,
#   'market_cap_usd': 127967400.0,
#   'max_supply': 1000000000.0,
#   'name': 'Achain',
#   'percent_change_1h': 1.35,
#   'percent_change_24h': 16.02,
#   'percent_change_7d': 11.58,
#   'price_btc': 5.079e-05,
#   'price_usd': 0.426558,
#   'rank': 119,
#   'symbol': 'ACT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 6305470.0,
#   'available_supply': 6895431733.0,
#   'id': 'digitalnote',
#   'last_updated': 1518196443,
#   'market_cap_usd': 127429647.0,
#   'max_supply': None,
#   'name': 'DigitalNote',
#   'percent_change_1h': 1.34,
#   'percent_change_24h': 8.99,
#   'percent_change_7d': 0.23,
#   'price_btc': 2.2e-06,
#   'price_usd': 0.0184803,
#   'rank': 120,
#   'symbol': 'XDN',
#   'total_supply': 6895431733.0},
# ...
#   'name': 'Universe',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 7.18,
#   'percent_change_7d': -24.48,
#   'price_btc': 7.55e-06,
#   'price_usd': 0.0634075,
#   'rank': 960,
#   'symbol': 'UNI',
#   'total_supply': 26750777.0},
#  {'24h_volume_usd': 273.435,
#   'available_supply': 569058229.0,
#   'id': 'trollcoin',
#   'last_updated': 1518196444,
#   'market_cap_usd': 953008.0,
#   'max_supply': None,
#   'name': 'Trollcoin',
#   'percent_change_1h': -5.21,
#   'percent_change_24h': -5.98,
#   'percent_change_7d': 11.83,
#   'price_btc': 2e-07,
#   'price_usd': 0.00167471,
#   'rank': 961,
#   'symbol': 'TROLL',
#   'total_supply': 569058229.0},
#  {'24h_volume_usd': 369.769,
#   'available_supply': 2136565464.0,
#   'id': 'bigup',
#   'last_updated': 1518196446,
#   'market_cap_usd': 945845.0,
#   'max_supply': None,
#   'name': 'BigUp',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': 3.64,
#   'percent_change_7d': 14.4,
#   'price_btc': 5e-08,
#   'price_usd': 0.000442694,
#   'rank': 962,
#   'symbol': 'BIGUP',
#   'total_supply': 2136565464.0},
#  {'24h_volume_usd': 67.209,
#   'available_supply': 23079737.0,
#   'id': 'bitstar',
#   'last_updated': 1518196442,
#   'market_cap_usd': 944564.0,
#   'max_supply': None,
#   'name': 'Bitstar',
#   'percent_change_1h': 4.75,
#   'percent_change_24h': 5.19,
#   'percent_change_7d': -11.28,
#   'price_btc': 4.87e-06,
#   'price_usd': 0.0409261,
#   'rank': 963,
#   'symbol': 'BITS',
#   'total_supply': 23079737.0},
#  {'24h_volume_usd': 56.9303,
#   'available_supply': 24101381.0,
#   'id': 'gaia',
#   'last_updated': 1518196443,
#   'market_cap_usd': 931094.0,
#   'max_supply': None,
#   'name': 'GAIA',
#   'percent_change_1h': 0.58,
#   'percent_change_24h': -3.34,
#   'percent_change_7d': 9.28,
#   'price_btc': 4.6e-06,
#   'price_usd': 0.0386324,
#   'rank': 964,
#   'symbol': 'GAIA',
#   'total_supply': 24101381.0},
#  {'24h_volume_usd': 25.5947,
#   'available_supply': 8035193.0,
#   'id': 'woodcoin',
#   'last_updated': 1518196444,
#   'market_cap_usd': 917081.0,
#   'max_supply': None,
#   'name': 'Woodcoin',
#   'percent_change_1h': 0.58,
#   'percent_change_24h': -15.77,
#   'percent_change_7d': -1.82,
#   'price_btc': 1.359e-05,
#   'price_usd': 0.114133,
#   'rank': 965,
#   'symbol': 'LOG',
#   'total_supply': 8035193.0},
#  {'24h_volume_usd': 318.325,
#   'available_supply': 64151405.0,
#   'id': 'hobonickels',
#   'last_updated': 1518196441,
#   'market_cap_usd': 910514.0,
#   'max_supply': 120000000.0,
#   'name': 'HoboNickels',
#   'percent_change_1h': 0.58,
#   'percent_change_24h': 6.76,
#   'percent_change_7d': -16.96,
#   'price_btc': 1.69e-06,
#   'price_usd': 0.0141932,
#   'rank': 966,
#   'symbol': 'HBN',
#   'total_supply': 64151405.0},
#  {'24h_volume_usd': 243.166,
#   'available_supply': 1.0,
#   'id': 'bit20',
#   'last_updated': 1518196452,
#   'market_cap_usd': 901391.0,
#   'max_supply': None,
#   'name': 'Bit20',
#   'percent_change_1h': 1.69,
#   'percent_change_24h': 6.45,
#   'percent_change_7d': 1.32,
#   'price_btc': 105.639,
#   'price_usd': 887196.0,
#   'rank': 967,
#   'symbol': 'BTWTY',
#   'total_supply': 1.0},
#  {'24h_volume_usd': 464.163,
#   'available_supply': 75000000.0,
#   'id': 'bitpark-coin',
#   'last_updated': 1518196448,
#   'market_cap_usd': 855908.0,
#   'max_supply': None,
#   'name': 'Bitpark Coin',
#   'percent_change_1h': 0.5,
#   'percent_change_24h': 11.02,
#   'percent_change_7d': -34.1,
#   'price_btc': 1.36e-06,
#   'price_usd': 0.0114121,
#   'rank': 968,
#   'symbol': 'BPC',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 242.595,
#   'available_supply': 318929301.0,
#   'id': 'nyancoin',
#   'last_updated': 1518196441,
#   'market_cap_usd': 827086.0,
#   'max_supply': 337000000.0,
#   'name': 'Nyancoin',
#   'percent_change_1h': 2.75,
#   'percent_change_24h': -1.18,
#   'percent_change_7d': -7.96,
#   'price_btc': 3.1e-07,
#   'price_usd': 0.00259332,
#   'rank': 969,
#   'symbol': 'NYAN',
#   'total_supply': 318929301.0},
#  {'24h_volume_usd': 433.695,
#   'available_supply': 50936430.0,
#   'id': 'visio',
#   'last_updated': 1518196449,
#   'market_cap_usd': 813037.0,
#   'max_supply': None,
#   'name': 'Visio',
#   'percent_change_1h': 0.58,
#   'percent_change_24h': -9.88,
#   'percent_change_7d': -19.65,
#   'price_btc': 1.9e-06,
#   'price_usd': 0.0159618,
#   'rank': 970,
#   'symbol': 'VISIO',
#   'total_supply': 62936430.0},
#  {'24h_volume_usd': 316.41,
#   'available_supply': 65290635.0,
#   'id': 'btctalkcoin',
#   'last_updated': 1518196442,
#   'market_cap_usd': 795083.0,
#   'max_supply': None,
#   'name': 'BTCtalkcoin',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 22.27,
#   'percent_change_7d': 9.78,
#   'price_btc': 1.45e-06,
#   'price_usd': 0.0121776,
#   'rank': 971,
#   'symbol': 'TALK',
#   'total_supply': 65290635.0},
#  {'24h_volume_usd': 148.008,
#   'available_supply': 9503724.0,
#   'id': 'wavesgo',
#   'last_updated': 1518196450,
#   'market_cap_usd': 793964.0,
#   'max_supply': None,
#   'name': 'WavesGo',
#   'percent_change_1h': 1.27,
#   'percent_change_24h': 9.16,
#   'percent_change_7d': -10.37,
#   'price_btc': 9.95e-06,
#   'price_usd': 0.0835424,
#   'rank': 972,
#   'symbol': 'WGO',
#   'total_supply': 9503724.0},
#  {'24h_volume_usd': None,
#   'available_supply': 23020335.0,
#   'id': 'janus',
#   'last_updated': 1517536153,
#   'market_cap_usd': 744390.0,
#   'max_supply': None,
#   'name': 'Janus',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': None,
#   'price_btc': 3.72e-06,
#   'price_usd': 0.0323362,
#   'rank': 973,
#   'symbol': 'JNS',
#   'total_supply': 25201489.0},
#  {'24h_volume_usd': 459.108,
#   'available_supply': 61445805.0,
#   'id': 'maxcoin',
#   'last_updated': 1518196441,
#   'market_cap_usd': 696660.0,
#   'max_supply': None,
#   'name': 'MaxCoin',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 0.04,
#   'percent_change_7d': 2.14,
#   'price_btc': 1.35e-06,
#   'price_usd': 0.0113378,
#   'rank': 974,
#   'symbol': 'MAX',
#   'total_supply': 61445805.0},
#  {'24h_volume_usd': 4.19145,
#   'available_supply': 1990891.0,
#   'id': 'bitz',
#   'last_updated': 1518196444,
#   'market_cap_usd': 668808.0,
#   'max_supply': None,
#   'name': 'Bitz',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': None,
#   'percent_change_7d': -14.0,
#   'price_btc': 4e-05,
#   'price_usd': 0.335934,
#   'rank': 975,
#   'symbol': 'BITZ',
#   'total_supply': 1990891.0},
#  {'24h_volume_usd': 218.148,
#   'available_supply': 196336.0,
#   'id': 'prototanium',
#   'last_updated': 1518196445,
#   'market_cap_usd': 659559.0,
#   'max_supply': None,
#   'name': 'Prototanium',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': -4.61,
#   'percent_change_7d': -6.29,
#   'price_btc': 0.0004,
#   'price_usd': 3.35934,
#   'rank': 976,
#   'symbol': 'PR',
#   'total_supply': 196336.0},
#  {'24h_volume_usd': 176.205,
#   'available_supply': 353620.0,
#   'id': 'swagbucks',
#   'last_updated': 1518196445,
#   'market_cap_usd': 640947.0,
#   'max_supply': None,
#   'name': 'SwagBucks',
#   'percent_change_1h': 0.58,
#   'percent_change_24h': 1.03,
#   'percent_change_7d': -9.35,
#   'price_btc': 0.00021582,
#   'price_usd': 1.81253,
#   'rank': 977,
#   'symbol': 'BUCKS',
#   'total_supply': 353620.0},
#  {'24h_volume_usd': 201.925,
#   'available_supply': 21268092.0,
#   'id': 'britcoin',
#   'last_updated': 1518196443,
#   'market_cap_usd': 633659.0,
#   'max_supply': None,
#   'name': 'BritCoin',
#   'percent_change_1h': -0.8,
#   'percent_change_24h': -14.99,
#   'percent_change_7d': 3.4,
#   'price_btc': 3.55e-06,
#   'price_usd': 0.0297939,
#   'rank': 978,
#   'symbol': 'BRIT',
#   'total_supply': 21268092.0},
#  {'24h_volume_usd': 357.184,
#   'available_supply': 169191043.0,
#   'id': 'truckcoin',
#   'last_updated': 1518196443,
#   'market_cap_usd': 625207.0,
#   'max_supply': None,
#   'name': 'Truckcoin',
#   'percent_change_1h': -6.17,
#   'percent_change_24h': 15.37,
#   'percent_change_7d': -5.02,
#   'price_btc': 4.4e-07,
#   'price_usd': 0.00369527,
#   'rank': 979,
#   'symbol': 'TRK',
#   'total_supply': 169191043.0},
#  {'24h_volume_usd': 277.086,
#   'available_supply': 18696748.0,
#   'id': 'motocoin',
#   'last_updated': 1518196442,
#   'market_cap_usd': 621805.0,
#   'max_supply': None,
#   'name': 'Motocoin',
#   'percent_change_1h': 0.32,
#   'percent_change_24h': 18.28,
#   'percent_change_7d': -17.13,
#   'price_btc': 3.96e-06,
#   'price_usd': 0.0332574,
#   'rank': 980,
#   'symbol': 'MOTO',
#   'total_supply': 31227378.0},
#  {'24h_volume_usd': 128.772,
#   'available_supply': 107972766.0,
#   'id': 'signatum',
#   'last_updated': 1518196452,
#   'market_cap_usd': 616618.0,
#   'max_supply': None,
#   'name': 'Signatum',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 6.17,
#   'percent_change_7d': -9.32,
#   'price_btc': 6.8e-07,
#   'price_usd': 0.00571087,
#   'rank': 981,
#   'symbol': 'SIGT',
#   'total_supply': 107972766.0},
#  {'24h_volume_usd': 109.899,
#   'available_supply': 77777777.0,
#   'id': 'ammo-rewards',
#   'last_updated': 1518196450,
#   'market_cap_usd': 594416.0,
#   'max_supply': None,
#   'name': 'Ammo Reloaded',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 0.23,
#   'percent_change_7d': -11.17,
#   'price_btc': 9.1e-07,
#   'price_usd': 0.00764249,
#   'rank': 982,
#   'symbol': 'AMMO',
#   'total_supply': 77777777.0},
#  {'24h_volume_usd': 3.69074,
#   'available_supply': 2358819009.0,
#   'id': 'colossuscoin-v2',
#   'last_updated': 1518196444,
#   'market_cap_usd': 594304.0,
#   'max_supply': None,
#   'name': 'Colossuscoin V2',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 53.39,
#   'percent_change_7d': 46.41,
#   'price_btc': 3e-08,
#   'price_usd': 0.00025195,
#   'rank': 983,
#   'symbol': 'CV2',
#   'total_supply': 22977351798.0},
#  {'24h_volume_usd': 54.7294,
#   'available_supply': 169598616.0,
#   'id': 'bitcurrency',
#   'last_updated': 1518196448,
#   'market_cap_usd': 583982.0,
#   'max_supply': None,
#   'name': 'Bitcurrency',
#   'percent_change_1h': 0.58,
#   'percent_change_24h': 2.26,
#   'percent_change_7d': -49.69,
#   'price_btc': 4.1e-07,
#   'price_usd': 0.00344332,
#   'rank': 984,
#   'symbol': 'BTCR',
#   'total_supply': 169598616.0},
#  {'24h_volume_usd': 176.738,
#   'available_supply': 9436367.0,
#   'id': 'mineum',
#   'last_updated': 1518196447,
#   'market_cap_usd': 580062.0,
#   'max_supply': None,
#   'name': 'Mineum',
#   'percent_change_1h': 9.4,
#   'percent_change_24h': -19.74,
#   'percent_change_7d': 10.33,
#   'price_btc': 7.32e-06,
#   'price_usd': 0.0614709,
#   'rank': 985,
#   'symbol': 'MNM',
#   'total_supply': 9586367.0},
#  {'24h_volume_usd': 1.24295,
#   'available_supply': 90421856.0,
#   'id': 'tattoocoin',
#   'last_updated': 1518196448,
#   'market_cap_usd': 561952.0,
#   'max_supply': None,
#   'name': 'Tattoocoin (Standard Edition)',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': -3.88,
#   'percent_change_7d': -4.96,
#   'price_btc': 7.4e-07,
#   'price_usd': 0.00621478,
#   'rank': 986,
#   'symbol': 'TSE',
#   'total_supply': 90421856.0},
#  {'24h_volume_usd': 9.38095,
#   'available_supply': 6097644882.0,
#   'id': 'valorbit',
#   'last_updated': 1518196446,
#   'market_cap_usd': 512101.0,
#   'max_supply': None,
#   'name': 'Valorbit',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 2.26,
#   'percent_change_7d': -2.4,
#   'price_btc': 1e-08,
#   'price_usd': 8.39834e-05,
#   'rank': 987,
#   'symbol': 'VAL',
#   'total_supply': 922343297644882},
#  {'24h_volume_usd': 85.5815,
#   'available_supply': 5428300.0,
#   'id': 'blockpay',
#   'last_updated': 1518196447,
#   'market_cap_usd': 501442.0,
#   'max_supply': None,
#   'name': 'BlockPay',
#   'percent_change_1h': 0.62,
#   'percent_change_24h': 3.94,
#   'percent_change_7d': -25.55,
#   'price_btc': 1.1e-05,
#   'price_usd': 0.0923756,
#   'rank': 988,
#   'symbol': 'BLOCKPAY',
#   'total_supply': 98928316.0},
#  {'24h_volume_usd': 15.6444,
#   'available_supply': 21948.0,
#   'id': 'bitsilver',
#   'last_updated': 1518196444,
#   'market_cap_usd': 490487.0,
#   'max_supply': None,
#   'name': 'bitSilver',
#   'percent_change_1h': -0.89,
#   'percent_change_24h': 23.0,
#   'percent_change_7d': 20.15,
#   'price_btc': 0.00266098,
#   'price_usd': 22.3478,
#   'rank': 989,
#   'symbol': 'BITSILVER',
#   'total_supply': 21948.0},
#  {'24h_volume_usd': 352.472,
#   'available_supply': 7089142.0,
#   'id': 'sativacoin',
#   'last_updated': 1518196443,
#   'market_cap_usd': 485919.0,
#   'max_supply': None,
#   'name': 'Sativacoin',
#   'percent_change_1h': 6.06,
#   'percent_change_24h': 2.28,
#   'percent_change_7d': -2.52,
#   'price_btc': 8.16e-06,
#   'price_usd': 0.0685441,
#   'rank': 990,
#   'symbol': 'STV',
#   'total_supply': 7089142.0},
#  {'24h_volume_usd': 228.675,
#   'available_supply': 43536800.0,
#   'id': 'tigercoin',
#   'last_updated': 1518196441,
#   'market_cap_usd': 482640.0,
#   'max_supply': None,
#   'name': 'Tigercoin',
#   'percent_change_1h': 1.31,
#   'percent_change_24h': 3.05,
#   'percent_change_7d': -25.63,
#   'price_btc': 1.32e-06,
#   'price_usd': 0.0110858,
#   'rank': 991,
#   'symbol': 'TGC',
#   'total_supply': 43536800.0},
#  {'24h_volume_usd': 33.3091,
#   'available_supply': 65171010.0,
#   'id': 'globalcoin',
#   'last_updated': 1518196440,
#   'market_cap_usd': 481649.0,
#   'max_supply': None,
#   'name': 'GlobalCoin',
#   'percent_change_1h': 0.58,
#   'percent_change_24h': 28.99,
#   'percent_change_7d': -3.64,
#   'price_btc': 8.8e-07,
#   'price_usd': 0.00739054,
#   'rank': 992,
#   'symbol': 'GLC',
#   'total_supply': 65171010.0},
#  {'24h_volume_usd': 175.0,
#   'available_supply': 210806.0,
#   'id': 'flycoin',
#   'last_updated': 1518196445,
#   'market_cap_usd': 478031.0,
#   'max_supply': None,
#   'name': 'Flycoin',
#   'percent_change_1h': -25.57,
#   'percent_change_24h': 3.98,
#   'percent_change_7d': -24.66,
#   'price_btc': 0.00027001,
#   'price_usd': 2.26764,
#   'rank': 993,
#   'symbol': 'FLY',
#   'total_supply': 210806.0},
#  {'24h_volume_usd': 367.117,
#   'available_supply': 73729962.0,
#   'id': 'chronos',
#   'last_updated': 1518196448,
#   'market_cap_usd': 464404.0,
#   'max_supply': None,
#   'name': 'Chronos',
#   'percent_change_1h': -6.42,
#   'percent_change_24h': 17.96,
#   'percent_change_7d': -17.28,
#   'price_btc': 7.5e-07,
#   'price_usd': 0.00629872,
#   'rank': 994,
#   'symbol': 'CRX',
#   'total_supply': 73729962.0},
#  {'24h_volume_usd': 64.7152,
#   'available_supply': 10291781.0,
#   'id': 'bankcoin',
#   'last_updated': 1518196449,
#   'market_cap_usd': 460181.0,
#   'max_supply': None,
#   'name': 'Bankcoin',
#   'percent_change_1h': 0.92,
#   'percent_change_24h': 41.77,
#   'percent_change_7d': None,
#   'price_btc': 5.32e-06,
#   'price_usd': 0.0447134,
#   'rank': 995,
#   'symbol': 'B@',
#   'total_supply': 25000000.0},
#  {'24h_volume_usd': 498.367,
#   'available_supply': 22508734.0,
#   'id': 'revolvercoin',
#   'last_updated': 1518196447,
#   'market_cap_usd': 457468.0,
#   'max_supply': None,
#   'name': 'RevolverCoin',
#   'percent_change_1h': 0.53,
#   'percent_change_24h': 8.54,
#   'percent_change_7d': -18.47,
#   'price_btc': 2.42e-06,
#   'price_usd': 0.020324,
#   'rank': 996,
#   'symbol': 'XRE',
#   'total_supply': 22508734.0},
#  {'24h_volume_usd': 278.578,
#   'available_supply': 1583294.0,
#   'id': 'aquariuscoin',
#   'last_updated': 1518196446,
#   'market_cap_usd': 440762.0,
#   'max_supply': None,
#   'name': 'AquariusCoin',
#   'percent_change_1h': -1.9,
#   'percent_change_24h': -3.72,
#   'percent_change_7d': 55.76,
#   'price_btc': 3.315e-05,
#   'price_usd': 0.278383,
#   'rank': 997,
#   'symbol': 'ARCO',
#   'total_supply': 1583294.0},
#  {'24h_volume_usd': 21.8985,
#   'available_supply': 3052052.0,
#   'id': 'joincoin',
#   'last_updated': 1518196443,
#   'market_cap_usd': 436004.0,
#   'max_supply': None,
#   'name': 'Joincoin',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 5.36,
#   'percent_change_7d': -5.13,
#   'price_btc': 1.701e-05,
#   'price_usd': 0.142856,
#   'rank': 998,
#   'symbol': 'J',
#   'total_supply': 3052052.0},
#  {'24h_volume_usd': 400.972,
#   'available_supply': 12481316.0,
#   'id': 'gapcoin',
#   'last_updated': 1518196443,
#   'market_cap_usd': 428723.0,
#   'max_supply': None,
#   'name': 'Gapcoin',
#   'percent_change_1h': 0.58,
#   'percent_change_24h': -0.33,
#   'percent_change_7d': -3.74,
#   'price_btc': 4.09e-06,
#   'price_usd': 0.0343492,
#   'rank': 999,
#   'symbol': 'GAP',
#   'total_supply': 12481316.0},
#  {'24h_volume_usd': 23.4966,
#   'available_supply': 98341177.0,
#   'id': 'px',
#   'last_updated': 1518196447,
#   'market_cap_usd': 421211.0,
#   'max_supply': None,
#   'name': 'PX',
#   'percent_change_1h': 0.54,
#   'percent_change_24h': 27.2,
#   'percent_change_7d': -0.44,
#   'price_btc': 5.1e-07,
#   'price_usd': 0.00428316,
#   'rank': 1000,
#   'symbol': 'PX',
#   'total_supply': 98341177.0},
#  ...]

# %% [markdown]
# You can pass a currency through symbol or coin slug:

# %%
data_from_symbol = cmc.ticker("BTC")
data_from_slug = cmc.ticker("bitcoin")

data_from_slug
# Out:
# {'24h_volume_usd': 7991580000.0,
#  'available_supply': 16854937.0,
#  'id': 'bitcoin',
#  'last_updated': 1518196468,
#  'market_cap_usd': 142301008061,
#  'max_supply': 21000000.0,
#  'name': 'Bitcoin',
#  'percent_change_1h': 0.44,
#  'percent_change_24h': 2.8,
#  'percent_change_7d': -1.97,
#  'price_btc': 1.0,
#  'price_usd': 8442.69,
#  'rank': 1,
#  'symbol': 'BTC',
#  'total_supply': 16854937.0}

# %% [markdown]
# To get all symbols and slugs you can use the next attributes:

# %%
all_symbols = cmc.symbols
all_slugs = cmc.coins

all_symbols
# Out:
# ['ARI',
#  'THS',
#  'EPC',
#  'TSTR',
#  'XAU',
#  'DBG',
#  'SCL',
#  'ADC',
#  'SKIN',
#  'TRF',
#  'DNA',
#  'SKR',
#  'SMT',
#  'QLC',
#  'QTL',
#  'TBX',
#  'MOT',
#  'ETP',
#  'DIX',
#  'EBET',
#  'CVCOIN',
#  'PULSE',
#  'VERI',
#  'XFT',
#  'BRAIN',
#  'BET',
#  'OST',
#  'HCC',
#  'SPACE',
#  'DP',
#  'SAN',
#  'XEM',
#  'KEY',
#  'LKK',
#  'X2',
#  'EAG',
#  'WOW',
#  'NVST',
#  'NEVA',
#  'STORM',
#  'BTCS',
#  'XTD',
#  'UNC',
#  'BIG',
#  'CRPT',
#  'WINK',
#  'SJCX',
#  'CSNO',
#  'SAK',
#  'BIS',
#  'PCOIN',
#  'YOYOW',
#  'DOVU',
#  'DGD',
#  'SHOW',
#  'HNC',
#  'B@',
#  'ZSE',
#  'JOBS',
#  'ECA',
#  'OPT',
#  'QASH',
#  'READ',
#  'POST',
#  'XMG',
#  'TER',
#  'QBC',
#  'EFYT',
#  'HWC',
#  'GMX',
#  'NGC',
#  'NODC',
#  'CF',
#  'DCRE',
#  'QUBE',
#  'SUR',
#  'SONG',
#  'UNIC',
#  '10MT',
#  'ABJ',
#  'TRCT',
#  'XLC',
#  'PRM',
#  'UGC',
#  'SNAKE',
#  'CXO',
#  'QORA',
#  'FC',
#  'NRO',
#  'USC',
#  'TRI',
#  'RNS',
#  'IDXM',
#  'POLL',
#  'XIOS',
#  'MYB',
#  'BLZ',
#  'LEPEN',
#  'BQ',
#  'ADT',
#  'OC',
#  'STEPS',
#  'QRK',
#  'EOS',
#  'PONZI',
#  'EDR',
#  'DNT',
#  'BOT',
#  'TERA',
#  'AMB',
#  'DON',
#  'NTWK',
#  'INDIA',
#  'XLR',
#  'OPAL',
#  'TEAM',
#  'CDT',
#  'MOIN',
#  'KDC',
#  'SUPER',
#  'ITC',
#  'SEQ',
#  'CDN',
#  'BAR',
#  'XJO',
#  'XTZ',
#  'BNTY',
#  'JET',
#  'SLEVIN',
#  'FUTC',
#  'NEOS',
#  'VOLT',
#  'PKB',
#  'ATMC',
#  'PXI',
#  'XQN',
#  'GCN',
#  'ACN',
#  'RBIES',
#  'AMS',
#  'BRIT',
#  'BCDN',
#  'PRIX',
#  'OK',
#  'DMT',
#  'CACH',
#  'VASH',
#  'MYST',
#  'ALQO',
#  'XCT',
#  'GTO',
#  'AKY',
#  'ARK',
#  'BDG',
#  'SSS',
#  'NVC',
#  'SPF',
#  'SXC',
#  'XRC',
#  'CNX',
#  'MOD',
#  'PRA',
#  'SIB',
#  'PLC',
#  'GRX',
#  'XMR',
#  'SPHR',
#  'ESZ',
#  'HEAT',
#  'TSL',
#  'PRX',
#  'ESC',
#  'FRN',
#  'PPC',
#  'EXN',
#  'ATL',
#  'SKC',
#  'XCS',
#  'MDT',
#  'PX',
#  'CCO',
#  'WRC',
#  'REE',
#  'AGLC',
#  'XRB',
#  'SDRN',
#  'CRB',
#  'KZC',
#  '1337',
#  'NET',
#  'TRUMP',
#  'HALLO',
#  'LOC',
#  'VEC2',
#  'STV',
#  'LIR',
#  'BTC',
#  'AGRS',
#  'TEL',
#  'BLAZR',
#  'CFC',
#  'RICHX',
#  'BTA',
#  'ARY',
#  'POP',
#  'LRC',
#  'AXIOM',
#  'BLAS',
#  'BTB',
#  'AMMO',
#  'LINDA',
#  'SMART',
#  'STORJ',
#  '8BIT',
#  'TIE',
#  'R',
#  'MONETA',
#  'PFR',
#  'BUZZ',
#  'XNG',
#  'FUNC',
#  'PPT',
#  'AERM',
#  'AC',
#  'AU',
#  'NXC',
#  'FDX',
#  'BITCNY',
#  'BNX',
#  'MCAP',
#  'ARG',
#  'SFC',
#  'DIME',
#  'NMR',
#  'JWL',
#  'SPORT',
#  'DRT',
#  'NXT',
#  'ICE',
#  'OXY',
#  'VSL',
#  'EMC2',
#  'XIN',
#  'RIDE',
#  'NUKO',
#  'TNB',
#  'CRDNC',
#  'ANI',
#  'LNK',
#  'TOPAZ',
#  'Q2C',
#  'SDC',
#  'ROC',
#  'ZEN',
#  'KICK',
#  'DFT',
#  'PEC',
#  'BOAT',
#  'PUT',
#  'NOTE',
#  'QCN',
#  'CME',
#  'XAUR',
#  'ETC',
#  'EMD',
#  'BTDX',
#  'NYC',
#  'TCOIN',
#  'ARCT',
#  'SPC',
#  'ARCO',
#  'ELA',
#  'GNX',
#  'BTM',
#  'PLU',
#  'RDD',
#  'MVC',
#  'STAK',
#  'DOGE',
#  '300',
#  'PRG',
#  'PURE',
#  'XRP',
#  'BPC',
#  'DCY',
#  'MAY',
#  'XVP',
#  'KMD',
#  'SPK',
#  'WAVES',
#  'INSN',
#  'XVC',
#  'BAY',
#  'FOR',
#  'XRL',
#  'XGOX',
#  'VIVO',
#  'UNITS',
#  'TEK',
#  'SOJ',
#  'XOT',
#  'WIC',
#  'DRS',
#  'IC',
#  'LINX',
#  'GAIA',
#  'OS76',
#  'XCN',
#  'CND',
#  'PAYX',
#  'COLX',
#  'FLT',
#  'POSW',
#  'DBIX',
#  'MAGE',
#  'USDT',
#  'EBTC',
#  'PIZZA',
#  'CRTM',
#  'MINT',
#  'ZER',
#  'SMC',
#  'QWARK',
#  'GAME',
#  'HDG',
#  'GUP',
#  'ORLY',
#  'HPC',
#  'EOT',
#  'IRL',
#  'CREVA',
#  'BIOS',
#  'EAGLE',
#  'MAD',
#  'LTG',
#  'BSD',
#  'ICN',
#  'CASH',
#  'CMP',
#  'EVR',
#  'FIL',
#  'SNT',
#  'FRWC',
#  'REAL',
#  'SISA',
#  'QSP',
#  'NEO',
#  'CREDO',
#  'JIN',
#  'TAAS',
#  'PIGGY',
#  'SWTC',
#  'HORSE',
#  'CANDY',
#  '1ST',
#  'BOLI',
#  'SPHTX',
#  'NKA',
#  'HERO',
#  'FST',
#  'KUSH',
#  'ACOIN',
#  'LLT',
#  'ETHD',
#  'WC',
#  'KRM',
#  'GRN',
#  'MLN',
#  'VSX',
#  'ALTCOM',
#  'ESP',
#  'CUBE',
#  'ATX',
#  'HGT',
#  'CYDER',
#  'ZEIT',
#  'DNR',
#  'C20',
#  'GAM',
#  'NETKO',
#  'BRD',
#  'GMT',
#  'FRGC',
#  'VOISE',
#  'GAY',
#  'BAT',
#  'PLBT',
#  'METAL',
#  'TESLA',
#  'NMS',
#  'GPL',
#  'LA',
#  'BTCR',
#  'ELE',
#  'RCN',
#  'FRD',
#  'ICOO',
#  'MANA',
#  'AMM',
#  'TCC',
#  'COB',
#  'SPT',
#  'PCS',
#  'PTOY',
#  'AMBER',
#  'IETH',
#  'CPC',
#  'PPP',
#  'XCP',
#  'KASHH',
#  'MBL',
#  'VIDZ',
#  'FJC',
#  'ION',
#  'DOT',
#  'BON',
#  'DGPT',
#  'EPY',
#  'RUSTBITS',
#  'IPL',
#  'GLD',
#  'DATA',
#  'TOPC',
#  'APW',
#  'GAIN',
#  'START',
#  'XBL',
#  'DLISK',
#  'REX',
#  'DGB',
#  'BDL',
#  'SIGMA',
#  'BWK',
#  'COV',
#  'SAC',
#  'TAU',
#  'FAP',
#  'YEL',
#  'CREA',
#  'ISL',
#  'XGR',
#  'CV2',
#  'IBANK',
#  'NDC',
#  'HAT',
#  'PBT',
#  'UIS',
#  'MINEX',
#  'MONEY',
#  'LTB',
#  'MRJA',
#  'MDS',
#  'SAGA',
#  'ICOB',
#  'ACES',
#  'HTML',
#  'DAY',
#  'CDX',
#  'GML',
#  'SNC',
#  'SNM',
#  'LCT',
#  'OAX',
#  'HUC',
#  'MNC',
#  'GOLOS',
#  'GARY',
#  'CTO',
#  'BBR',
#  'NSR',
#  'INS',
#  'SXUT',
#  'SBC',
#  'REBL',
#  'HOLD',
#  'IXT',
#  '$$$',
#  'MKR',
#  'VOT',
#  'BUB',
#  'IGNIS',
#  'GBX',
#  'GAS',
#  'ATN',
#  'TES',
#  'YEE',
#  'CMT',
#  'OBITS',
#  'VRS',
#  'GET',
#  'NANOX',
#  'BCC',
#  'INPAY',
#  'DGCS',
#  'STEX',
#  'PAY',
#  'FLIXX',
#  'XMY',
#  'QBT',
#  'HBN',
#  'BLC',
#  'EL',
#  'HXX',
#  'CANN',
#  'DIM',
#  'ETHOS',
#  'CWXT',
#  'FC2',
#  'ECO',
#  'OF',
#  'GXS',
#  'G3N',
#  'SHELL',
#  'JIYO',
#  'MNX',
#  'DTR',
#  'MAX',
#  'PLACO',
#  'LET',
#  'XTO',
#  'IMS',
#  'TOP',
#  'GLC',
#  'DMC',
#  'MDC',
#  'IOP',
#  'MGO',
#  'PIVX',
#  'MSCN',
#  'EXCL',
#  'CAT',
#  'PLX',
#  'ORB',
#  'DUBI',
#  'SOCC',
#  'PAK',
#  'TAGR',
#  'INF',
#  'STRC',
#  'BTWTY',
#  'TRICK',
#  'SWM',
#  'BAC',
#  'DEW',
#  'EFL',
#  'ARDR',
#  'PRN',
#  'PRL',
#  'TIX',
#  'GB',
#  'TSE',
#  'AION',
#  'GCR',
#  'DSR',
#  'DALC',
#  'XRA',
#  'RAIN',
#  'KIN',
#  'BLRY',
#  'JNS',
#  'DDF',
#  'COAL',
#  'XSTC',
#  'XSH',
#  'DXT',
#  'CURE',
#  'EREAL',
#  'FUEL',
#  'RCT',
#  'RYZ',
#  'BLT',
#  'VIP',
#  'OMG',
#  'CESC',
#  'REF',
#  'SWFTC',
#  'RDN',
#  'SHORTY',
#  'CRED',
#  'POLIS',
#  'REP',
#  'MMXVI',
#  'MGC',
#  'HTML5',
#  'RLT',
#  'ORME',
#  'MONA',
#  'ZENI',
#  'SLG',
#  'NAS',
#  'EBCH',
#  'WA',
#  'ADZ',
#  'CPN',
#  'SPR',
#  'PIPL',
#  'CTIC2',
#  'SLS',
#  'PLR',
#  'PDC',
#  'BUCKS',
#  'DLC',
#  'SUMO',
#  'CNO',
#  'KLC',
#  'TAJ',
#  'VOX',
#  'IOST',
#  'TCR',
#  'MAG',
#  'POKE',
#  'FCN',
#  'MONK',
#  'COFI',
#  'CPAY',
#  'BUMBA',
#  'BIT',
#  'XPY',
#  'HIGH',
#  'ORE',
#  'GOOD',
#  'EDT',
#  'BIP',
#  'BITZ',
#  'PAYP',
#  'MIOTA',
#  'SKY',
#  'YTN',
#  'BERN',
#  'GOLF',
#  'ENG',
#  'ATM',
#  'CAPP',
#  'PASL',
#  'TOKC',
#  'ATOM',
#  'TRIG',
#  'HAL',
#  'ELLA',
#  'SYS',
#  'NAMO',
#  'IBTC',
#  'ALT',
#  'BITS',
#  'THC',
#  'KNC',
#  'MND',
#  'OCN',
#  'OTX',
#  'IFC',
#  'BTCM',
#  'OX',
#  'SWP',
#  'BIX',
#  'HT',
#  'NEOG',
#  'TRIA',
#  'SFE',
#  'PURA',
#  'VPRC',
#  'SBTC',
#  'ZCG',
#  'GDC',
#  'CHAN',
#  'CONX',
#  'ABC',
#  'J',
#  'ZSC',
#  'WDC',
#  'OTN',
#  'RLC',
#  'HONEY',
#  'PHO',
#  'CTX',
#  'EGO',
#  'VEE',
#  'XCO',
#  'THETA',
#  'XID',
#  'NTRN',
#  'HMC',
#  'KBR',
#  'SPRTS',
#  'SCS',
#  'MAGN',
#  'EDRC',
#  'MSD',
#  'P7C',
#  'BSTAR',
#  'BLITZ',
#  'PCN',
#  'DTA',
#  'KB3',
#  'DES',
#  'UFR',
#  'DCR',
#  'FTC',
#  'MOF',
#  'WORM',
#  'XBY',
#  'ACE',
#  'NOX',
#  'CFI',
#  'XPTX',
#  'ARB',
#  'PR',
#  'BLU',
#  'VLT',
#  'WETH',
#  'APC',
#  'IFLT',
#  'XAS',
#  'VUC',
#  'ARC',
#  'SSC',
#  'STRAT',
#  'TURBO',
#  'TFL',
#  'HYPER',
#  'UTA',
#  'ZRC',
#  'BLOCK',
#  'XP',
#  'IQT',
#  'EGAS',
#  'VZT',
#  'MZC',
#  'INK',
#  'GAT',
#  'TODAY',
#  'SPANK',
#  'EQL',
#  'GTC',
#  'EAC',
#  'VAL',
#  'PAC',
#  '2GIVE',
#  'BXC',
#  'TYCHO',
#  'RUFF',
#  'WINGS',
#  'SWT',
#  'IPY',
#  'SEND',
#  'MCR',
#  'SMS',
#  'OCL',
#  'GRE',
#  'HTC',
#  'SRC',
#  'DRM',
#  'TLE',
#  'LBC',
#  'LKC',
#  'IDH',
#  'DAXX',
#  'ELF',
#  'MEC',
#  'XPA',
#  'OP',
#  '808',
#  'ETH',
#  'ASN',
#  'KORE',
#  'TGT',
#  'ATMS',
#  'LTCR',
#  'TOK',
#  'STEEM',
#  'SANDG',
#  'GRID',
#  'SOIL',
#  'SXDT',
#  'PRO',
#  'LDOGE',
#  'IND',
#  'AI',
#  'ADST',
#  'DAI',
#  'LUN',
#  'UNRC',
#  'SIFT',
#  'DRPU',
#  'ITT',
#  'NXS',
#  'XPM',
#  'VC',
#  'IPC',
#  'BYC',
#  'DFS',
#  'BRIA',
#  'TELL',
#  'CRX',
#  '888',
#  'PIX',
#  'SLT',
#  'LMC',
#  'BASH',
#  'IOC',
#  'EVC',
#  'ETN',
#  'MAO',
#  'SMLY',
#  'CHAT',
#  'VTC',
#  'ANT',
#  'VLC',
#  'HKN',
#  'TRDT',
#  'STA',
#  'ADX',
#  'BT2',
#  'CARBON',
#  'QBIC',
#  'TIT',
#  'RUPX',
#  'REGA',
#  'EDO',
#  'ZIL',
#  'DUB',
#  'PSY',
#  'NIMFA',
#  'CNNC',
#  'URO',
#  'GIM',
#  'FLDC',
#  'CFUN',
#  'TRK',
#  'WABI',
#  'TTC',
#  'ACT',
#  'PART',
#  'POE',
#  'DPY',
#  'LTC',
#  'GP',
#  'NEU',
#  'RBT',
#  'SUB',
#  'KRONE',
#  'BITSILVER',
#  'ADK',
#  'PST',
#  'BTBc',
#  'LBTC',
#  'WCT',
#  'TKN',
#  'PIRL',
#  'ARN',
#  'WTT',
#  'TALK',
#  'GRC',
#  'EKO',
#  'QAU',
#  'INCNT',
#  'TRX',
#  'DOPE',
#  'WHL',
#  'BPT',
#  'BTW',
#  'CLAM',
#  'RIYA',
#  'EUSD',
#  'RHOC',
#  'ACP',
#  'B2X',
#  'BTX',
#  'ZNE',
#  'UKG',
#  'WILD',
#  'LINK',
#  'CTIC3',
#  'PLAY',
#  'RPX',
#  'SIGT',
#  'DISK',
#  'MNM',
#  'GSR',
#  'FIMK',
#  'TZC',
#  'VULC',
#  'FONZ',
#  'BCAP',
#  'AST',
#  'ELITE',
#  'UNITY',
#  'AURA',
#  'JINN',
#  'XWC',
#  'LIGHT',
#  'GBG',
#  'HVCO',
#  'EUC',
#  'GBC',
#  'ATB',
#  'ATS',
#  'ZNY',
#  'IVZ',
#  'LAZ',
#  'BPL',
#  'XDN',
#  'KURT',
#  'NBIT',
#  'HDLB',
#  'DDD',
#  'DAT',
#  'ERY',
#  'INN',
#  'TRST',
#  'BRX',
#  'WGO',
#  'CC',
#  'ZCL',
#  'TRUE',
#  'ENJ',
#  'XCXT',
#  'RBBT',
#  'CCN',
#  'ERC20',
#  'UAHPAY',
#  'LDCN',
#  'BCX',
#  'EGC',
#  'ADB',
#  'WTC',
#  'UTT',
#  'XSPEC',
#  'TNC',
#  'UR',
#  'AVT',
#  'SOAR',
#  'APPC',
#  'B2B',
#  'FLY',
#  'AWR',
#  'ZUR',
#  'MDA',
#  'HLC',
#  'SENSE',
#  'AV',
#  'BTCRED',
#  'KAYI',
#  'VTR',
#  'MEE',
#  'FUN',
#  'DOLLAR',
#  'BOS',
#  'PHS',
#  'SHND',
#  'KEK',
#  'BCY',
#  'RBX',
#  'SRN',
#  'NYAN',
#  'TKS',
#  'XZC',
#  'ZRX',
#  'CNT',
#  'CLOAK',
#  'BITCF',
#  'MOAC',
#  'COVAL',
#  'HYP',
#  'PROC',
#  'DSH',
#  'PGL',
#  'CRM',
#  'HPB',
#  'ELTCOIN',
#  'USNBT',
#  'KOBO',
#  'DUTCH',
#  'ICX',
#  'BTSR',
#  'INXT',
#  'VEN',
#  'WPR',
#  'FLO',
#  'AE',
#  'ITNS',
#  'BKX',
#  '611',
#  'GEERT',
#  'ADCN',
#  'ZLA',
#  'BTG',
#  'NEBL',
#  'AIX',
#  'REC',
#  'FLAP',
#  'GNO',
#  'SCORE',
#  'CMPCO',
#  'CRC',
#  'BEST',
#  'BNT',
#  'NEWB',
#  'MED',
#  'HMQ',
#  'MCO',
#  ...]

# %% [markdown]
# Other parameters:

# %%
print(cmc.ticker.__doc__)
# Out:
# Get currencies with other aditional data.
#
#         Args:
#             currency (str, optional): Specify a currency to return,
#                 in this case the method returns a dict, otherwise
#                 returns a list. If you dont specify a currency,
#                 returns data for all in coinmarketcap. As default, None.
#             limit (int, optional): Limit amount of coins on response.
#                 if limit == 0, returns all coins in coinmarketcap.
#                 Only works if currency == None. As default 0.
#             start (int, optional): Rank of first currency to retrieve.
#                 The count starts at 0 for the first currency ranked.
#                 Only works if currency == None. As default 0.
#             convert (str, optional): As default, "USD". Allow to
#                 convert price, 24h volume and market cap in terms
#                 of one of next badges:
#                    ["AUD", "BRL", "CAD", "CHF", "CLP", "CNY", "CZK", "DKK",
#                     "EUR", "GBP", "HKD", "HUF", "IDR", "ILS", "INR", "JPY",
#                     "KRW", "MXN", "MYR", "NOK", "NZD", "PHP", "PKR", "PLN",
#                     "RUB", "SEK", "SGD", "THB", "TRY", "TWD", "ZAR"]
#
#         Returns:
#             dict/list: If currency param is provided or not.

# %% [markdown]
# If you want to get the valid badges that can be passed to `convert` param programatically, use this:

# %%
cmc.ticker_badges
# Out:
# ['AUD',
#  'BRL',
#  'CAD',
#  'CHF',
#  'CLP',
#  'CNY',
#  'CZK',
#  'DKK',
#  'EUR',
#  'GBP',
#  'HKD',
#  'HUF',
#  'IDR',
#  'ILS',
#  'INR',
#  'JPY',
#  'KRW',
#  'MXN',
#  'MYR',
#  'NOK',
#  'NZD',
#  'PHP',
#  'PKR',
#  'PLN',
#  'RUB',
#  'SEK',
#  'SGD',
#  'THB',
#  'TRY',
#  'TWD',
#  'ZAR']

# %% [markdown]
# #### `stats()`

# %%
cmc.stats()
# Out:
# {'active_assets': 594,
#  'active_currencies': 888,
#  'active_markets': 8659,
#  'bitcoin_percentage_of_market_cap': 34.45,
#  'last_updated': 1518196468,
#  'total_24h_volume_usd': 23515735486.0,
#  'total_market_cap_usd': 413069685415.0}

# %% [markdown]
# _____________________________________________
#
# ## Web scraper
# #### `markets(currency, [convert="USD"])`
# Get all markets for a exchange in coinmarketcap. You can convert the response fields `"volume_24h"` and `"price"` between `"USD"` and `"BTC"`.

# %%
cmc.markets("BTC", convert="BTC")
# Out:
# []

# %% [markdown]
# #### `ranks([convert="USD"])`
# Get gainers and losers rankings:

# %%
cmc.ranks()
# Out:
# {'gainers': {'1h': [{'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 62.92,
#     'price': 0.0292651,
#     'symbol': 'UNY',
#     'volume_24h': 1653670.0}],
#   '24h': [{'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1141.68,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0}],
#   '7d': [{'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0},
#    {'name': 'E-coin',
#     'percent_change': 1245.64,
#     'price': 65.2413,
#     'symbol': 'ECN',
#     'volume_24h': 461890.0}]},
#  'losers': {'1h': [{'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0},
#    {'name': 'Coinlancer',
#     'percent_change': -12.77,
#     'price': 0.0932384,
#     'symbol': 'CL',
#     'volume_24h': 110354.0}],
#   '24h': [{'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.85,
#     'price': 0.0713019,
#     'symbol': 'DAV',
#     'volume_24h': 425897.0}],
#   '7d': [{'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4},
#    {'name': 'Global Jobcoin',
#     'percent_change': -65.62,
#     'price': 0.254144,
#     'symbol': 'GJC',
#     'volume_24h': 57279.4}]}}

# %% [markdown]
# #### `historical(currency, [start=datetime(2008, 8, 18), end=datetime.now(), revert=False])`
# Get historical prices for a currency. You can filter by `start` and `end` datetimes provided in `datetime` objects. With parameter `revert` active, the response will be ordered in chronological order. This method returns a `generator`object.

# %%
from datetime import datetime

list(cmc.historical("ETH", revert=True))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-18-88aa5edc2cef> in <module>()
#       1 from datetime import datetime
#       2
# ----> 3 list(cmc.historical("ETH", revert=True))
#
# /usr/local/lib/python3.5/dist-packages/pymarketcap-3.9.5-py3.5-linux-x86_64.egg/pymarketcap/core.pyx in historical()
#
# IndexError: list index out of range
