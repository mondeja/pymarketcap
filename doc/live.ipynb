# %% [markdown]
# # <center>Pymarketcap live documentation</center>

# %% [markdown]
# ## Basic usage
#
# #### `Pymarketcap([timeout=20, debug=False])`
#
# The first response takes a long time because some data is cached at instantiation of the wrapper.

# %%
from pymarketcap import Pymarketcap
cmc = Pymarketcap(timeout=10)

cmc.exchanges()
# Out:
# [{'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Cardano',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Qtum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Status',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'NEO',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Stellar',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Steem',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Upbit'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'NEO',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'ICON',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'NEO',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bluzelle',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'TRON',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'VeChain',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Binance Coin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Binance'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ethereum Classic',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum Classic',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'OKEx'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'BitMEX'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'EOS',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Qtum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Monero',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bithumb'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ripple',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'EOS',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Tether',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bitfinex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Huobi Token',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Huobi Token',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Huobi Token',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'EOS',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'TRON',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Elastos',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Elastos',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Huobi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'GDAX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ripple',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ripple',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ripple',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Kraken'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ripple',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Cardano',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'NuBits',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Lisk',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'NEO',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bittrex'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Monero',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Dash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ripple',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Zcash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'EOS',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'HitBTC'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ripple',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ripple',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ethereum',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bitstamp'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Qtum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'IOTA',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'}],
#   'name': 'Coinone'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'}],
#   'name': 'bitFlyer'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ripple',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ripple',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Stellar',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Monero',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum Classic',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Poloniex'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Litecoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'EDUCare',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'TRON',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Hshare',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Lisk',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Zcash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Factom',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bit-Z'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'NEM',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'MonaCoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'NEM',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'COMSA [ETH]',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Counterparty',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'COMSA [XEM]',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Pepe Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Zaif'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'QASH',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ethereum',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Quoine'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'MonaCoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'MonaCoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'}],
#   'name': 'Fisco'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'}],
#   'name': 'Gemini'},
#  {'markets': [{'name': 'ATMCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'ATMCoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ripple',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Dogecoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'ATMCoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'ATMCoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bits Blockchain'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'BTCBOX'},
#  {'markets': [{'name': 'Stellar',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Status',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Civic',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': '0x',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Enigma',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'GOPAX'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'NEO',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'TRON',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Lisk',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ruff',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Qtum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Qbao',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ripple',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Achain',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Lightning Bitcoin [Futures]',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'CoinEgg'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'EOS',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'BitShares',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Qtum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Hshare',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ink',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ripple',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Qtum',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'ZB.COM'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'}],
#   'name': 'Korbit'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'MonaCoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'MonaCoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'}],
#   'name': 'Bitbank'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ink',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Lightning Bitcoin [Futures]',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Hyper Pay',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'EXX'},
#  {'markets': [{'name': 'TRON',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Hshare',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Qtum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Energo',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Profile Utility Token',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Storm',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'ENTCash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin Diamond',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Coinnest'},
#  {'markets': [{'name': 'Jibrel Network',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Jibrel Network',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bibox Token',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bibox Token',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bibox Token',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
# ...
#    {'name': 'E-Dinar Coin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'DigiByte',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'alcurEX'},
#  {'markets': [{'name': 'Electroneum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Litecoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Monero',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Verge',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Aeon',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'BitCoal',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Sumokoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'TradeOgre'},
#  {'markets': [{'name': 'E-Dinar Coin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'}],
#   'name': 'LocalTrade'},
#  {'markets': [{'name': 'NVO',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Pepe Cash',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Counterparty',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Storjcoin X',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Rustbits',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Storjcoin X',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'FoldingCoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Bitcrystals',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'}],
#   'name': 'Counterparty DEX'},
#  {'markets': [{'name': 'Peercoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Dogecoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Dogecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Vertcoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Dash',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Litecoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Coingi'},
#  {'markets': [{'name': 'Centurion',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'ExcambrioRex'},
#  {'markets': [{'name': 'Gulden',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'GuldenTrader'},
#  {'markets': [{'name': 'LEOcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'LEOcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'LEOcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'LEOcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'LEOxChange'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'TCC Exchange'},
#  {'markets': [{'name': 'BriaCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Litecoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'}],
#   'name': 'Ore.Bz'},
#  {'markets': [{'name': 'SACoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'DC-Ex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'}],
#   'name': 'CoinCorner'},
#  {'markets': [{'name': 'CRTCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Dogecoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'}],
#   'name': 'NIX-E'},
#  {'markets': [{'name': 'HEAT',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bismuth',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Golem',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'FIMKrypto',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Elastic',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Elastic',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'HEAT',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'Heat Wallet'},
#  {'markets': [{'name': 'SnakeEyes',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'CCMiner',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'}],
#   'name': 'Burst Asset Exchange'},
#  {'markets': [{'name': 'MaidSafeCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'Omni DEX'},
#  {'markets': [{'name': 'Golem',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Lunyr',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'SingularDTV',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'TokenCard',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Swarm City',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Etheroll',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.23,
#     'price': 0.224388,
#     'volume': 148915000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Melon',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.15,
#     'price': 903.161,
#     'volume': 123130000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Numeraire',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.67,
#     'price': 118.125,
#     'volume': 111748000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Edgeless',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.77,
#     'price': 0.404634,
#     'volume': 90207800.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum Movie Venture',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.24865,
#     'volume': 59475000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'CryptoDerivatives'},
#  {'markets': [{'name': 'Virtacoinplus',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Virtacoinplus',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'}],
#   'name': 'VirtacoinWorld'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.6,
#     'price': 0.928818,
#     'volume': 349152000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.96,
#     'price': 0.385322,
#     'volume': 333946000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.51,
#     'price': 29.9521,
#     'volume': 275356000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Siacoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.31,
#     'price': 8938.73,
#     'volume': 270572000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.29,
#     'price': 1344.95,
#     'volume': 150336000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'}],
#   'name': 'BITHOLIC'}]

# %% [markdown]
# > All methods are self explained in docstrings:

# %%
print(cmc.exchanges.__doc__)
# Out:
# Get all the exchanges in coninmarketcap ranked by volumes
#         along with other metadata.
#
#         Args:
#             convert (str, optional): Convert volumes and prices
#                 between "USD" and "BTC". As default "USD".
#
#         Returns (list):
#             Exchanges with markets and other data included.

# %% [markdown]
# ___________________________________
#
# ## Coinmarketcap API
# #### `ticker(currency=None, limit=0, start=0, convert="USD")`
# If `currency == None`, you will obtain data for all currencies in coinmarketcap:

# %%
cmc.ticker()
# Out:
# [{'24h_volume_usd': 8309900000.0,
#   'available_supply': 16855075.0,
#   'id': 'bitcoin',
#   'last_updated': 1518200366,
#   'market_cap_usd': 146717865700,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin',
#   'percent_change_1h': 2.84,
#   'percent_change_24h': 5.94,
#   'percent_change_7d': 0.32,
#   'price_btc': 1.0,
#   'price_usd': 8704.67,
#   'rank': 1,
#   'symbol': 'BTC',
#   'total_supply': 16855075.0},
#  {'24h_volume_usd': 3175860000.0,
#   'available_supply': 97512468.0,
#   'id': 'ethereum',
#   'last_updated': 1518200652,
#   'market_cap_usd': 85167584603.0,
#   'max_supply': None,
#   'name': 'Ethereum',
#   'percent_change_1h': 2.17,
#   'percent_change_24h': 8.73,
#   'percent_change_7d': -3.47,
#   'price_btc': 0.100405,
#   'price_usd': 873.402,
#   'rank': 2,
#   'symbol': 'ETH',
#   'total_supply': 97512468.0},
#  {'24h_volume_usd': 1688380000.0,
#   'available_supply': 39009215838.0,
#   'id': 'ripple',
#   'last_updated': 1518200641,
#   'market_cap_usd': 35848533134.0,
#   'max_supply': 100000000000,
#   'name': 'Ripple',
#   'percent_change_1h': -0.74,
#   'percent_change_24h': 21.39,
#   'percent_change_7d': 8.71,
#   'price_btc': 0.00010564,
#   'price_usd': 0.918976,
#   'rank': 3,
#   'symbol': 'XRP',
#   'total_supply': 99992725510.0},
#  {'24h_volume_usd': 1376020000.0,
#   'available_supply': 16958338.0,
#   'id': 'bitcoin-cash',
#   'last_updated': 1518200652,
#   'market_cap_usd': 22313441316.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Cash',
#   'percent_change_1h': 1.67,
#   'percent_change_24h': 2.53,
#   'percent_change_7d': 12.94,
#   'price_btc': 0.15126,
#   'price_usd': 1315.78,
#   'rank': 4,
#   'symbol': 'BCH',
#   'total_supply': 16958338.0},
#  {'24h_volume_usd': 418154000.0,
#   'available_supply': 25927070538.0,
#   'id': 'cardano',
#   'last_updated': 1518200654,
#   'market_cap_usd': 9966780748.0,
#   'max_supply': 45000000000.0,
#   'name': 'Cardano',
#   'percent_change_1h': 0.49,
#   'percent_change_24h': 10.94,
#   'percent_change_7d': 7.99,
#   'price_btc': 4.419e-05,
#   'price_usd': 0.384416,
#   'rank': 5,
#   'symbol': 'ADA',
#   'total_supply': 31112483745.0},
#  {'24h_volume_usd': 752757000.0,
#   'available_supply': 55143583.0,
#   'id': 'litecoin',
#   'last_updated': 1518200641,
#   'market_cap_usd': 8785641099.0,
#   'max_supply': 84000000.0,
#   'name': 'Litecoin',
#   'percent_change_1h': 3.22,
#   'percent_change_24h': 10.18,
#   'percent_change_7d': 24.48,
#   'price_btc': 0.0183155,
#   'price_usd': 159.323,
#   'rank': 6,
#   'symbol': 'LTC',
#   'total_supply': 55143583.0},
#  {'24h_volume_usd': 433042000.0,
#   'available_supply': 65000000.0,
#   'id': 'neo',
#   'last_updated': 1518200648,
#   'market_cap_usd': 7537920000.0,
#   'max_supply': None,
#   'name': 'NEO',
#   'percent_change_1h': 1.02,
#   'percent_change_24h': 5.08,
#   'percent_change_7d': -1.18,
#   'price_btc': 0.0133315,
#   'price_usd': 115.968,
#   'rank': 7,
#   'symbol': 'NEO',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 168265000.0,
#   'available_supply': 18432190642.0,
#   'id': 'stellar',
#   'last_updated': 1518200643,
#   'market_cap_usd': 7399308018.0,
#   'max_supply': None,
#   'name': 'Stellar',
#   'percent_change_1h': 2.28,
#   'percent_change_24h': 13.98,
#   'percent_change_7d': 2.77,
#   'price_btc': 4.615e-05,
#   'price_usd': 0.401434,
#   'rank': 8,
#   'symbol': 'XLM',
#   'total_supply': 103669352049},
#  {'24h_volume_usd': 551708000.0,
#   'available_supply': 657693007.0,
#   'id': 'eos',
#   'last_updated': 1518200651,
#   'market_cap_usd': 6210193871.0,
#   'max_supply': 1000000000.0,
#   'name': 'EOS',
#   'percent_change_1h': 1.97,
#   'percent_change_24h': 15.04,
#   'percent_change_7d': -0.59,
#   'price_btc': 0.00108548,
#   'price_usd': 9.44239,
#   'rank': 9,
#   'symbol': 'EOS',
#   'total_supply': 900000000.0},
#  {'24h_volume_usd': 62549300.0,
#   'available_supply': 2779530283.0,
#   'id': 'iota',
#   'last_updated': 1518200651,
#   'market_cap_usd': 5421612794.0,
#   'max_supply': 2779530283.0,
#   'name': 'IOTA',
#   'percent_change_1h': 2.29,
#   'percent_change_24h': 9.44,
#   'percent_change_7d': 10.82,
#   'price_btc': 0.00022423,
#   'price_usd': 1.95055,
#   'rank': 10,
#   'symbol': 'MIOTA',
#   'total_supply': 2779530283.0},
#  {'24h_volume_usd': 55653800.0,
#   'available_supply': 8999999999.0,
#   'id': 'nem',
#   'last_updated': 1518200644,
#   'market_cap_usd': 5095700999.0,
#   'max_supply': None,
#   'name': 'NEM',
#   'percent_change_1h': 0.93,
#   'percent_change_24h': 4.35,
#   'percent_change_7d': 1.7,
#   'price_btc': 6.509e-05,
#   'price_usd': 0.566189,
#   'rank': 11,
#   'symbol': 'XEM',
#   'total_supply': 8999999999.0},
#  {'24h_volume_usd': 102632000.0,
#   'available_supply': 7874296.0,
#   'id': 'dash',
#   'last_updated': 1518200641,
#   'market_cap_usd': 5009697705.0,
#   'max_supply': 18900000.0,
#   'name': 'Dash',
#   'percent_change_1h': 3.38,
#   'percent_change_24h': 11.04,
#   'percent_change_7d': 13.61,
#   'price_btc': 0.0731375,
#   'price_usd': 636.209,
#   'rank': 12,
#   'symbol': 'DASH',
#   'total_supply': 7874296.0},
#  {'24h_volume_usd': 93060600.0,
#   'available_supply': 15702568.0,
#   'id': 'monero',
#   'last_updated': 1518200642,
#   'market_cap_usd': 4017172279.0,
#   'max_supply': None,
#   'name': 'Monero',
#   'percent_change_1h': 2.54,
#   'percent_change_24h': 5.91,
#   'percent_change_7d': 10.1,
#   'price_btc': 0.0294096,
#   'price_usd': 255.829,
#   'rank': 13,
#   'symbol': 'XMR',
#   'total_supply': 15702568.0},
#  {'24h_volume_usd': 90124600.0,
#   'available_supply': 117892408.0,
#   'id': 'lisk',
#   'last_updated': 1518200647,
#   'market_cap_usd': 3074952310.0,
#   'max_supply': None,
#   'name': 'Lisk',
#   'percent_change_1h': -0.42,
#   'percent_change_24h': 15.59,
#   'percent_change_7d': 29.31,
#   'price_btc': 0.00299843,
#   'price_usd': 26.0827,
#   'rank': 14,
#   'symbol': 'LSK',
#   'total_supply': 117892408.0},
#  {'24h_volume_usd': 254119000.0,
#   'available_supply': 65748192475.0,
#   'id': 'tron',
#   'last_updated': 1518200654,
#   'market_cap_usd': 2895399176.0,
#   'max_supply': None,
#   'name': 'TRON',
#   'percent_change_1h': 4.31,
#   'percent_change_24h': 21.82,
#   'percent_change_7d': 12.0,
#   'price_btc': 5.06e-06,
#   'price_usd': 0.0440377,
#   'rank': 15,
#   'symbol': 'TRX',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 113198000.0,
#   'available_supply': 16814349.0,
#   'id': 'bitcoin-gold',
#   'last_updated': 1518200656,
#   'market_cap_usd': 2687386892.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Gold',
#   'percent_change_1h': -0.3,
#   'percent_change_24h': 56.18,
#   'percent_change_7d': 49.78,
#   'price_btc': 0.0183735,
#   'price_usd': 159.827,
#   'rank': 16,
#   'symbol': 'BTG',
#   'total_supply': 16914349.0},
#  {'24h_volume_usd': 399434000.0,
#   'available_supply': 99736250.0,
#   'id': 'ethereum-classic',
#   'last_updated': 1518200647,
#   'market_cap_usd': 2605729215.0,
#   'max_supply': None,
#   'name': 'Ethereum Classic',
#   'percent_change_1h': 2.67,
#   'percent_change_24h': 27.54,
#   'percent_change_7d': 17.21,
#   'price_btc': 0.00300343,
#   'price_usd': 26.1262,
#   'rank': 17,
#   'symbol': 'ETC',
#   'total_supply': 99736250.0},
#  {'24h_volume_usd': 2588690000.0,
#   'available_supply': 2217140814.0,
#   'id': 'tether',
#   'last_updated': 1518200645,
#   'market_cap_usd': 2323962658.0,
#   'max_supply': None,
#   'name': 'Tether',
#   'percent_change_1h': 1.57,
#   'percent_change_24h': 3.27,
#   'percent_change_7d': 5.78,
#   'price_btc': 0.0001205,
#   'price_usd': 1.04818,
#   'rank': 18,
#   'symbol': 'USDT',
#   'total_supply': 2280109970.0},
#  {'24h_volume_usd': 612969000.0,
#   'available_supply': 73869556.0,
#   'id': 'qtum',
#   'last_updated': 1518200651,
#   'market_cap_usd': 2214941702.0,
#   'max_supply': None,
#   'name': 'Qtum',
#   'percent_change_1h': 0.41,
#   'percent_change_24h': 23.93,
#   'percent_change_7d': 3.34,
#   'price_btc': 0.00344697,
#   'price_usd': 29.9845,
#   'rank': 19,
#   'symbol': 'QTUM',
#   'total_supply': 100369556.0},
#  {'24h_volume_usd': 67371300.0,
#   'available_supply': 466139235.0,
#   'id': 'vechain',
#   'last_updated': 1518200653,
#   'market_cap_usd': 2122275999.0,
#   'max_supply': None,
#   'name': 'VeChain',
#   'percent_change_1h': 2.9,
#   'percent_change_24h': 7.33,
#   'percent_change_7d': -5.14,
#   'price_btc': 0.00052339,
#   'price_usd': 4.55288,
#   'rank': 20,
#   'symbol': 'VEN',
#   'total_supply': 873378637.0},
#  {'24h_volume_usd': 105274000.0,
#   'available_supply': 381495014.0,
#   'id': 'icon',
#   'last_updated': 1518200655,
#   'market_cap_usd': 1727897737.0,
#   'max_supply': None,
#   'name': 'ICON',
#   'percent_change_1h': 3.13,
#   'percent_change_24h': 5.33,
#   'percent_change_7d': -13.05,
#   'price_btc': 0.00052068,
#   'price_usd': 4.52928,
#   'rank': 21,
#   'symbol': 'ICX',
#   'total_supply': 400230000.0},
#  {'24h_volume_usd': 32065100.0,
#   'available_supply': 133248289.0,
#   'id': 'raiblocks',
#   'last_updated': 1518200649,
#   'market_cap_usd': 1597060695.0,
#   'max_supply': 133248290.0,
#   'name': 'Nano',
#   'percent_change_1h': 3.03,
#   'percent_change_24h': 7.84,
#   'percent_change_7d': -29.06,
#   'price_btc': 0.00137785,
#   'price_usd': 11.9856,
#   'rank': 22,
#   'symbol': 'XRB',
#   'total_supply': 133248289.0},
#  {'24h_volume_usd': 116831000.0,
#   'available_supply': 3242644.0,
#   'id': 'zcash',
#   'last_updated': 1518200648,
#   'market_cap_usd': 1465175608.0,
#   'max_supply': None,
#   'name': 'Zcash',
#   'percent_change_1h': 3.05,
#   'percent_change_24h': 11.16,
#   'percent_change_7d': 23.73,
#   'price_btc': 0.0519435,
#   'price_usd': 451.846,
#   'rank': 23,
#   'symbol': 'ZEC',
#   'total_supply': 3242644.0},
#  {'24h_volume_usd': 12259000.0,
#   'available_supply': 37004027.0,
#   'id': 'populous',
#   'last_updated': 1518200652,
#   'market_cap_usd': 1358388224.0,
#   'max_supply': 53252246.0,
#   'name': 'Populous',
#   'percent_change_1h': 3.65,
#   'percent_change_24h': 4.6,
#   'percent_change_7d': -32.92,
#   'price_btc': 0.00422003,
#   'price_usd': 36.7092,
#   'rank': 24,
#   'symbol': 'PPT',
#   'total_supply': 53252246.0},
#  {'24h_volume_usd': 47643600.0,
#   'available_supply': 102042552.0,
#   'id': 'omisego',
#   'last_updated': 1518200652,
#   'market_cap_usd': 1336206398.0,
#   'max_supply': None,
#   'name': 'OmiseGO',
#   'percent_change_1h': 2.08,
#   'percent_change_24h': 12.29,
#   'percent_change_7d': 2.64,
#   'price_btc': 0.00150534,
#   'price_usd': 13.0946,
#   'rank': 25,
#   'symbol': 'OMG',
#   'total_supply': 140245398.0},
#  {'24h_volume_usd': 68506800.0,
#   'available_supply': 249204938.0,
#   'id': 'steem',
#   'last_updated': 1518200647,
#   'market_cap_usd': 1056793410.0,
#   'max_supply': None,
#   'name': 'Steem',
#   'percent_change_1h': -0.18,
#   'percent_change_24h': 12.83,
#   'percent_change_7d': 4.47,
#   'price_btc': 0.0004875,
#   'price_usd': 4.24066,
#   'rank': 26,
#   'symbol': 'STEEM',
#   'total_supply': 266179032.0},
#  {'24h_volume_usd': 85832000.0,
#   'available_supply': 99014000.0,
#   'id': 'binance-coin',
#   'last_updated': 1518200653,
#   'market_cap_usd': 878372997.0,
#   'max_supply': None,
#   'name': 'Binance Coin',
#   'percent_change_1h': 1.8,
#   'percent_change_24h': 4.57,
#   'percent_change_7d': -4.66,
#   'price_btc': 0.00101982,
#   'price_usd': 8.8712,
#   'rank': 27,
#   'symbol': 'BNB',
#   'total_supply': 197192382.0},
#  {'24h_volume_usd': 5850260.0,
#   'available_supply': 183717179194,
#   'id': 'bytecoin-bcn',
#   'last_updated': 1518200643,
#   'market_cap_usd': 876992327.0,
#   'max_supply': 184470000000,
#   'name': 'Bytecoin',
#   'percent_change_1h': 3.28,
#   'percent_change_24h': 7.95,
#   'percent_change_7d': 4.84,
#   'price_btc': 5.5e-07,
#   'price_usd': 0.0047736,
#   'rank': 28,
#   'symbol': 'BCN',
#   'total_supply': 183717179194},
#  {'24h_volume_usd': 23769400.0,
#   'available_supply': 14575372881.0,
#   'id': 'verge',
#   'last_updated': 1518200644,
#   'market_cap_usd': 833604929.0,
#   'max_supply': 16555000000.0,
#   'name': 'Verge',
#   'percent_change_1h': 3.14,
#   'percent_change_24h': 10.84,
#   'percent_change_7d': 8.55,
#   'price_btc': 6.57e-06,
#   'price_usd': 0.0571927,
#   'rank': 29,
#   'symbol': 'XVG',
#   'total_supply': 14575372881.0},
#  {'24h_volume_usd': 16218800.0,
#   'available_supply': 32364499035.0,
#   'id': 'siacoin',
#   'last_updated': 1518200645,
#   'market_cap_usd': 805765987.0,
#   'max_supply': None,
#   'name': 'Siacoin',
#   'percent_change_1h': 2.72,
#   'percent_change_24h': 14.34,
#   'percent_change_7d': -2.25,
#   'price_btc': 2.86e-06,
#   'price_usd': 0.0248966,
#   'rank': 30,
#   'symbol': 'SC',
#   'total_supply': 32364499035.0},
#  {'24h_volume_usd': 17492700.0,
#   'available_supply': 98734078.0,
#   'id': 'stratis',
#   'last_updated': 1518200648,
#   'market_cap_usd': 791114701.0,
#   'max_supply': None,
#   'name': 'Stratis',
#   'percent_change_1h': 1.77,
#   'percent_change_24h': 14.09,
#   'percent_change_7d': -9.72,
#   'price_btc': 0.00092111,
#   'price_usd': 8.01258,
#   'rank': 31,
#   'symbol': 'STRAT',
#   'total_supply': 98734078.0},
#  {'24h_volume_usd': 166952000.0,
#   'available_supply': 3470483788.0,
#   'id': 'status',
#   'last_updated': 1518200651,
#   'market_cap_usd': 785051197.0,
#   'max_supply': None,
#   'name': 'Status',
#   'percent_change_1h': 0.45,
#   'percent_change_24h': 6.1,
#   'percent_change_7d': 35.54,
#   'price_btc': 2.6e-05,
#   'price_usd': 0.226208,
#   'rank': 32,
#   'symbol': 'SNT',
#   'total_supply': 6804870174.0},
#  {'24h_volume_usd': 22062500.0,
#   'available_supply': 233020472.0,
#   'id': 'aeternity',
#   'last_updated': 1518200650,
#   'market_cap_usd': 707109943.0,
#   'max_supply': None,
#   'name': 'Aeternity',
#   'percent_change_1h': 2.61,
#   'percent_change_24h': 7.03,
#   'percent_change_7d': 18.32,
#   'price_btc': 0.00034885,
#   'price_usd': 3.03454,
#   'rank': 33,
#   'symbol': 'AE',
#   'total_supply': 273685830.0},
#  {'24h_volume_usd': 28862600.0,
#   'available_supply': 2608390000.0,
#   'id': 'bitshares',
#   'last_updated': 1518200644,
#   'market_cap_usd': 683601634.0,
#   'max_supply': 3600570502.0,
#   'name': 'BitShares',
#   'percent_change_1h': 2.91,
#   'percent_change_24h': 12.98,
#   'percent_change_7d': -15.19,
#   'price_btc': 3.013e-05,
#   'price_usd': 0.262078,
#   'rank': 34,
#   'symbol': 'BTS',
#   'total_supply': 2608390000.0},
#  {'24h_volume_usd': 642286.0,
#   'available_supply': 618228.0,
#   'id': 'maker',
#   'last_updated': 1518200649,
#   'market_cap_usd': 677015049.0,
#   'max_supply': None,
#   'name': 'Maker',
#   'percent_change_1h': 2.74,
#   'percent_change_24h': 9.63,
#   'percent_change_7d': -3.52,
#   'price_btc': 0.125889,
#   'price_usd': 1095.09,
#   'rank': 35,
#   'symbol': 'MKR',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 6527380.0,
#   'available_supply': 11000000.0,
#   'id': 'augur',
#   'last_updated': 1518200646,
#   'market_cap_usd': 622743000.0,
#   'max_supply': None,
#   'name': 'Augur',
#   'percent_change_1h': 1.88,
#   'percent_change_24h': 10.0,
#   'percent_change_7d': 0.67,
#   'price_btc': 0.00650814,
#   'price_usd': 56.613,
#   'rank': 36,
#   'symbol': 'REP',
#   'total_supply': 11000000.0},
#  {'24h_volume_usd': 25843400.0,
#   'available_supply': 2000000.0,
#   'id': 'digixdao',
#   'last_updated': 1518200646,
#   'market_cap_usd': 617100000.0,
#   'max_supply': None,
#   'name': 'DigixDAO',
#   'percent_change_1h': 3.05,
#   'percent_change_24h': 6.9,
#   'percent_change_7d': -13.56,
#   'price_btc': 0.0354704,
#   'price_usd': 308.55,
#   'rank': 37,
#   'symbol': 'DGD',
#   'total_supply': 2000000.0},
#  {'24h_volume_usd': 27627300.0,
#   'available_supply': 100000000.0,
#   'id': 'waves',
#   'last_updated': 1518200647,
#   'market_cap_usd': 604889000.0,
#   'max_supply': None,
#   'name': 'Waves',
#   'percent_change_1h': 3.52,
#   'percent_change_24h': 12.17,
#   'percent_change_7d': -1.18,
#   'price_btc': 0.00069537,
#   'price_usd': 6.04889,
#   'rank': 38,
#   'symbol': 'WAVES',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 17455300.0,
#   'available_supply': 24898178.0,
#   'id': 'walton',
#   'last_updated': 1518200654,
#   'market_cap_usd': 598569628.0,
#   'max_supply': 100000000.0,
#   'name': 'Walton',
#   'percent_change_1h': 2.81,
#   'percent_change_24h': 6.82,
#   'percent_change_7d': -1.42,
#   'price_btc': 0.00276368,
#   'price_usd': 24.0407,
#   'rank': 39,
#   'symbol': 'WTC',
#   'total_supply': 70000000.0},
#  {'24h_volume_usd': 168745.0,
#   'available_supply': 2036645.0,
#   'id': 'veritaseum',
#   'last_updated': 1518200651,
#   'market_cap_usd': 585910307.0,
#   'max_supply': None,
#   'name': 'Veritaseum',
#   'percent_change_1h': 4.49,
#   'percent_change_24h': 4.91,
#   'percent_change_7d': -11.67,
#   'price_btc': 0.0330717,
#   'price_usd': 287.684,
#   'rank': 40,
#   'symbol': 'VERI',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 13846200.0,
#   'available_supply': 507188082.0,
#   'id': '0x',
#   'last_updated': 1518200653,
#   'market_cap_usd': 581404914.0,
#   'max_supply': None,
#   'name': '0x',
#   'percent_change_1h': 1.58,
#   'percent_change_24h': 7.87,
#   'percent_change_7d': -11.3,
#   'price_btc': 0.00013178,
#   'price_usd': 1.14633,
#   'rank': 41,
#   'symbol': 'ZRX',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 10153500.0,
#   'available_supply': 113132925740,
#   'id': 'dogecoin',
#   'last_updated': 1518200642,
#   'market_cap_usd': 560174288.0,
#   'max_supply': None,
#   'name': 'Dogecoin',
#   'percent_change_1h': 3.3,
#   'percent_change_24h': 9.25,
#   'percent_change_7d': 13.64,
#   'price_btc': 5.7e-07,
#   'price_usd': 0.00495147,
#   'rank': 42,
#   'symbol': 'DOGE',
#   'total_supply': 113132925740},
#  {'24h_volume_usd': 1873280.0,
#   'available_supply': 6723613.0,
#   'id': 'decred',
#   'last_updated': 1518200646,
#   'market_cap_usd': 546438135.0,
#   'max_supply': 21000000.0,
#   'name': 'Decred',
#   'percent_change_1h': 1.65,
#   'percent_change_24h': 8.71,
#   'percent_change_7d': 4.98,
#   'price_btc': 0.00934284,
#   'price_usd': 81.2715,
#   'rank': 43,
#   'symbol': 'DCR',
#   'total_supply': 7143613.0},
#  {'24h_volume_usd': 2929230.0,
#   'available_supply': 91043076.0,
#   'id': 'kucoin-shares',
#   'last_updated': 1518200656,
#   'market_cap_usd': 541041688.0,
#   'max_supply': None,
#   'name': 'KuCoin Shares',
#   'percent_change_1h': 4.18,
#   'percent_change_24h': 3.97,
#   'percent_change_7d': -8.34,
#   'price_btc': 0.00068316,
#   'price_usd': 5.9427,
#   'rank': 44,
#   'symbol': 'KCS',
#   'total_supply': 181043076.0},
#  {'24h_volume_usd': 79197500.0,
#   'available_supply': 42603248.0,
#   'id': 'hshare',
#   'last_updated': 1518200653,
#   'market_cap_usd': 527879805.0,
#   'max_supply': 84000000.0,
#   'name': 'Hshare',
#   'percent_change_1h': 1.57,
#   'percent_change_24h': 16.04,
#   'percent_change_7d': 10.52,
#   'price_btc': 0.00142441,
#   'price_usd': 12.3906,
#   'rank': 45,
#   'symbol': 'HSR',
#   'total_supply': 42603248.0},
#  {'24h_volume_usd': 752055.0,
#   'available_supply': 344166289.0,
#   'id': 'rchain',
#   'last_updated': 1518200655,
#   'market_cap_usd': 523129317.0,
#   'max_supply': 1000000000.0,
#   'name': 'RChain',
#   'percent_change_1h': 8.5,
#   'percent_change_24h': 13.87,
#   'percent_change_7d': -7.2,
#   'price_btc': 0.00017473,
#   'price_usd': 1.51999,
#   'rank': 46,
#   'symbol': 'RHOC',
#   'total_supply': 870663574.0},
#  {'24h_volume_usd': 71827600.0,
#   'available_supply': 998999495.0,
#   'id': 'ardor',
#   'last_updated': 1518200647,
#   'market_cap_usd': 512966261.0,
#   'max_supply': 998999495.0,
#   'name': 'Ardor',
#   'percent_change_1h': 4.24,
#   'percent_change_24h': 16.98,
#   'percent_change_7d': 5.74,
#   'price_btc': 5.903e-05,
#   'price_usd': 0.51348,
#   'rank': 47,
#   'symbol': 'ARDR',
#   'total_supply': 998999495.0},
#  {'24h_volume_usd': 4922930.0,
#   'available_supply': 103155445.0,
#   'id': 'komodo',
#   'last_updated': 1518200649,
#   'market_cap_usd': 453546641.0,
#   'max_supply': None,
#   'name': 'Komodo',
#   'percent_change_1h': 1.62,
#   'percent_change_24h': 12.75,
#   'percent_change_7d': 1.63,
#   'price_btc': 0.00050544,
#   'price_usd': 4.39673,
#   'rank': 48,
#   'symbol': 'KMD',
#   'total_supply': 103155445.0},
#  {'24h_volume_usd': 7626860.0,
#   'available_supply': 134132697.0,
#   'id': 'kyber-network',
#   'last_updated': 1518200654,
#   'market_cap_usd': 448503523.0,
#   'max_supply': None,
#   'name': 'Kyber Network',
#   'percent_change_1h': 2.81,
#   'percent_change_24h': 8.67,
#   'percent_change_7d': 0.79,
#   'price_btc': 0.00038439,
#   'price_usd': 3.34373,
#   'rank': 49,
#   'symbol': 'KNC',
#   'total_supply': 215625349.0},
#  {'24h_volume_usd': 5579480.0,
#   'available_supply': 184450000.0,
#   'id': 'revain',
#   'last_updated': 1518200656,
#   'market_cap_usd': 448005072.0,
#   'max_supply': 484450000.0,
#   'name': 'Revain',
#   'percent_change_1h': 1.52,
#   'percent_change_24h': 19.03,
#   'percent_change_7d': 64.84,
#   'price_btc': 0.00027922,
#   'price_usd': 2.42887,
#   'rank': 50,
#   'symbol': 'R',
#   'total_supply': 484450000.0},
#  {'24h_volume_usd': 2600610.0,
#   'available_supply': 6105013037.0,
#   'id': 'electroneum',
#   'last_updated': 1518200656,
#   'market_cap_usd': 441111001.0,
#   'max_supply': 21000000000.0,
#   'name': 'Electroneum',
#   'percent_change_1h': 1.89,
#   'percent_change_24h': 6.9,
#   'percent_change_7d': 9.57,
#   'price_btc': 8.31e-06,
#   'price_usd': 0.0722539,
#   'rank': 51,
#   'symbol': 'ETN',
#   'total_supply': 6105013037.0},
#  {'24h_volume_usd': 9380150.0,
#   'available_supply': 100526296.0,
#   'id': 'ark',
#   'last_updated': 1518200649,
#   'market_cap_usd': 432711420.0,
#   'max_supply': None,
#   'name': 'Ark',
#   'percent_change_1h': 1.21,
#   'percent_change_24h': 12.85,
#   'percent_change_7d': -1.49,
#   'price_btc': 0.00049483,
#   'price_usd': 4.30446,
#   'rank': 52,
#   'symbol': 'ARK',
#   'total_supply': 131776296.0},
#  {'24h_volume_usd': 9194870.0,
#   'available_supply': 9675198.0,
#   'id': 'gas',
#   'last_updated': 1518200652,
#   'market_cap_usd': 423318959.0,
#   'max_supply': 100000000.0,
#   'name': 'Gas',
#   'percent_change_1h': 3.16,
#   'percent_change_24h': 7.08,
#   'percent_change_7d': -5.34,
#   'price_btc': 0.00502978,
#   'price_usd': 43.753,
#   'rank': 53,
#   'symbol': 'GAS',
#   'total_supply': 15257384.0},
#  {'24h_volume_usd': 5927610.0,
#   'available_supply': 1000000000.0,
#   'id': 'basic-attention-token',
#   'last_updated': 1518200651,
#   'market_cap_usd': 397901000.0,
#   'max_supply': None,
#   'name': 'Basic Attention Token',
#   'percent_change_1h': 4.57,
#   'percent_change_24h': 6.02,
#   'percent_change_7d': -2.38,
#   'price_btc': 4.574e-05,
#   'price_usd': 0.397901,
#   'rank': 54,
#   'symbol': 'BAT',
#   'total_supply': 1500000000.0},
#  {'24h_volume_usd': 2383720.0,
#   'available_supply': 238421940.0,
#   'id': 'dragonchain',
#   'last_updated': 1518200657,
#   'market_cap_usd': 397053594.0,
#   'max_supply': None,
#   'name': 'Dragonchain',
#   'percent_change_1h': 4.28,
#   'percent_change_24h': 12.45,
#   'percent_change_7d': -1.54,
#   'price_btc': 0.00019144,
#   'price_usd': 1.66534,
#   'rank': 55,
#   'symbol': 'DRGN',
#   'total_supply': 433494437.0},
#  {'24h_volume_usd': 12325400.0,
#   'available_supply': 6508988220.0,
#   'id': 'zilliqa',
#   'last_updated': 1518200660,
#   'market_cap_usd': 392460747.0,
#   'max_supply': None,
#   'name': 'Zilliqa',
#   'percent_change_1h': 2.68,
#   'percent_change_24h': 4.6,
#   'percent_change_7d': -10.91,
#   'price_btc': 6.93e-06,
#   'price_usd': 0.0602952,
#   'rank': 56,
#   'symbol': 'ZIL',
#   'total_supply': 12600000000.0},
#  {'24h_volume_usd': 7135950.0,
#   'available_supply': 9818473226.0,
#   'id': 'digibyte',
#   'last_updated': 1518200641,
#   'market_cap_usd': 390766398.0,
#   'max_supply': 21000000000.0,
#   'name': 'DigiByte',
#   'percent_change_1h': 3.06,
#   'percent_change_24h': 21.26,
#   'percent_change_7d': -2.21,
#   'price_btc': 4.58e-06,
#   'price_usd': 0.0397991,
#   'rank': 57,
#   'symbol': 'DGB',
#   'total_supply': 9818473226.0},
#  {'24h_volume_usd': 3017500.0,
#   'available_supply': 561202251.0,
#   'id': 'loopring',
#   'last_updated': 1518200654,
#   'market_cap_usd': 385870322.0,
#   'max_supply': None,
#   'name': 'Loopring',
#   'percent_change_1h': 3.28,
#   'percent_change_24h': 9.28,
#   'percent_change_7d': -9.54,
#   'price_btc': 7.904e-05,
#   'price_usd': 0.687578,
#   'rank': 58,
#   'symbol': 'LRC',
#   'total_supply': 1374956357.0},
#  {'24h_volume_usd': 586538.0,
#   'available_supply': 325226613094,
#   'id': 'dentacoin',
#   'last_updated': 1518200653,
#   'market_cap_usd': 375838379.0,
#   'max_supply': 8000000000000,
#   'name': 'Dentacoin',
#   'percent_change_1h': 4.43,
#   'percent_change_24h': 8.57,
#   'percent_change_7d': 8.08,
#   'price_btc': 1.3e-07,
#   'price_usd': 0.00115562,
#   'rank': 59,
#   'symbol': 'DCN',
#   'total_supply': 1963173416169},
#  {'24h_volume_usd': 45873100.0,
#   'available_supply': 250000000.0,
#   'id': 'aelf',
#   'last_updated': 1518200658,
#   'market_cap_usd': 344665000.0,
#   'max_supply': None,
#   'name': 'aelf',
#   'percent_change_1h': 2.25,
#   'percent_change_24h': 8.01,
#   'percent_change_7d': -11.73,
#   'price_btc': 0.00015849,
#   'price_usd': 1.37866,
#   'rank': 60,
#   'symbol': 'ELF',
#   'total_supply': 260000000.0},
#  {'24h_volume_usd': 16937800.0,
#   'available_supply': 987000000.0,
#   'id': 'bytom',
#   'last_updated': 1518200653,
#   'market_cap_usd': 341537532.0,
#   'max_supply': None,
#   'name': 'Bytom',
#   'percent_change_1h': 1.75,
#   'percent_change_24h': 18.1,
#   'percent_change_7d': 5.63,
#   'price_btc': 3.978e-05,
#   'price_usd': 0.346036,
#   'rank': 61,
#   'symbol': 'BTM',
#   'total_supply': 1407000000.0},
#  {'24h_volume_usd': 14813400.0,
#   'available_supply': 55526365.0,
#   'id': 'pivx',
#   'last_updated': 1518200646,
#   'market_cap_usd': 340744756.0,
#   'max_supply': None,
#   'name': 'PIVX',
#   'percent_change_1h': 2.22,
#   'percent_change_24h': 14.33,
#   'percent_change_7d': 7.2,
#   'price_btc': 0.00070546,
#   'price_usd': 6.13663,
#   'rank': 62,
#   'symbol': 'PIVX',
#   'total_supply': 55526365.0},
#  {'24h_volume_usd': 7169740.0,
#   'available_supply': 75601200.0,
#   'id': 'ethos',
#   'last_updated': 1518200652,
#   'market_cap_usd': 340398181.0,
#   'max_supply': None,
#   'name': 'Ethos',
#   'percent_change_1h': 2.86,
#   'percent_change_24h': 7.11,
#   'percent_change_7d': 20.62,
#   'price_btc': 0.00051761,
#   'price_usd': 4.50255,
#   'rank': 63,
#   'symbol': 'ETHOS',
#   'total_supply': 222295208.0},
#  {'24h_volume_usd': 843654.0,
#   'available_supply': 645222.0,
#   'id': 'byteball',
#   'last_updated': 1518200648,
#   'market_cap_usd': 340033958.0,
#   'max_supply': None,
#   'name': 'Byteball Bytes',
#   'percent_change_1h': 5.73,
#   'percent_change_24h': 13.87,
#   'percent_change_7d': -1.33,
#   'price_btc': 0.0605834,
#   'price_usd': 527.003,
#   'rank': 64,
#   'symbol': 'GBYTE',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 4825200.0,
#   'available_supply': 3264950.0,
#   'id': 'zclassic',
#   'last_updated': 1518200648,
#   'market_cap_usd': 333674625.0,
#   'max_supply': 21000000.0,
#   'name': 'ZClassic',
#   'percent_change_1h': 3.04,
#   'percent_change_24h': 4.5,
#   'percent_change_7d': 4.33,
#   'price_btc': 0.0117486,
#   'price_usd': 102.199,
#   'rank': 65,
#   'symbol': 'ZCL',
#   'total_supply': 3264950.0},
#  {'24h_volume_usd': 3174570.0,
#   'available_supply': 350000000.0,
#   'id': 'qash',
#   'last_updated': 1518200657,
#   'market_cap_usd': 324091600.0,
#   'max_supply': None,
#   'name': 'QASH',
#   'percent_change_1h': 3.99,
#   'percent_change_24h': 10.85,
#   'percent_change_7d': 1.07,
#   'price_btc': 0.00010645,
#   'price_usd': 0.925976,
#   'rank': 66,
#   'symbol': 'QASH',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 279251.0,
#   'available_supply': 227384800.0,
#   'id': 'pillar',
#   'last_updated': 1518200652,
#   'market_cap_usd': 317388252.0,
#   'max_supply': None,
#   'name': 'Pillar',
#   'percent_change_1h': 0.41,
#   'percent_change_24h': 3.34,
#   'percent_change_7d': 6.82,
#   'price_btc': 0.00016046,
#   'price_usd': 1.39582,
#   'rank': 67,
#   'symbol': 'PLR',
#   'total_supply': 800000000.0},
#  {'24h_volume_usd': 7451740.0,
#   'available_supply': 35500000.0,
#   'id': 'nebulas-token',
#   'last_updated': 1518200653,
#   'market_cap_usd': 310113800.0,
#   'max_supply': 100000000.0,
#   'name': 'Nebulas',
#   'percent_change_1h': 2.62,
#   'percent_change_24h': 11.71,
#   'percent_change_7d': -2.33,
#   'price_btc': 0.00100423,
#   'price_usd': 8.7356,
#   'rank': 68,
#   'symbol': 'NAS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 491137.0,
#   'available_supply': 4981227.0,
#   'id': 'e-coin',
#   'last_updated': 1518200650,
#   'market_cap_usd': 306758922.0,
#   'max_supply': None,
#   'name': 'E-coin',
#   'percent_change_1h': -8.02,
#   'percent_change_24h': 798.13,
#   'percent_change_7d': 1127.97,
#   'price_btc': 0.00707948,
#   'price_usd': 61.583,
#   'rank': 69,
#   'symbol': 'ECN',
#   'total_supply': 213270119.0},
#  {'24h_volume_usd': 30495000.0,
#   'available_supply': 4503688789.0,
#   'id': 'funfair',
#   'last_updated': 1518200651,
#   'market_cap_usd': 300877487.0,
#   'max_supply': None,
#   'name': 'FunFair',
#   'percent_change_1h': 2.76,
#   'percent_change_24h': 8.19,
#   'percent_change_7d': 11.53,
#   'price_btc': 7.68e-06,
#   'price_usd': 0.0668069,
#   'rank': 70,
#   'symbol': 'FUN',
#   'total_supply': 10999873621.0},
#  {'24h_volume_usd': 6910330.0,
#   'available_supply': 834262000.0,
#   'id': 'golem-network-tokens',
#   'last_updated': 1518200649,
#   'market_cap_usd': 298548165.0,
#   'max_supply': None,
#   'name': 'Golem',
#   'percent_change_1h': 3.5,
#   'percent_change_24h': 10.22,
#   'percent_change_7d': -0.02,
#   'price_btc': 4.114e-05,
#   'price_usd': 0.357859,
#   'rank': 71,
#   'symbol': 'GNT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 232586.0,
#   'available_supply': 45106571.0,
#   'id': 'cryptonex',
#   'last_updated': 1518200655,
#   'market_cap_usd': 293966287.0,
#   'max_supply': 210000000.0,
#   'name': 'Cryptonex',
#   'percent_change_1h': 2.85,
#   'percent_change_24h': 4.73,
#   'percent_change_7d': 3.32,
#   'price_btc': 0.0007492,
#   'price_usd': 6.51715,
#   'rank': 72,
#   'symbol': 'CNX',
#   'total_supply': 106544196.0},
#  {'24h_volume_usd': 12517600.0,
#   'available_supply': 1445976590.0,
#   'id': 'cindicator',
#   'last_updated': 1518200655,
#   'market_cap_usd': 292497929.0,
#   'max_supply': None,
#   'name': 'Cindicator',
#   'percent_change_1h': 3.17,
#   'percent_change_24h': 7.19,
#   'percent_change_7d': 4.88,
#   'price_btc': 2.325e-05,
#   'price_usd': 0.202284,
#   'rank': 73,
#   'symbol': 'CND',
#   'total_supply': 2000000005.0},
#  {'24h_volume_usd': 3096570.0,
#   'available_supply': 10614760961.0,
#   'id': 'dent',
#   'last_updated': 1518200653,
#   'market_cap_usd': 291021717.0,
#   'max_supply': None,
#   'name': 'Dent',
#   'percent_change_1h': 2.94,
#   'percent_change_24h': 6.76,
#   'percent_change_7d': 22.36,
#   'price_btc': 3.15e-06,
#   'price_usd': 0.0274167,
#   'rank': 74,
#   'symbol': 'DENT',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 3945310.0,
#   'available_supply': 530835833.0,
#   'id': 'syscoin',
#   'last_updated': 1518200643,
#   'market_cap_usd': 286344526.0,
#   'max_supply': 888000000.0,
#   'name': 'Syscoin',
#   'percent_change_1h': 2.88,
#   'percent_change_24h': 3.72,
#   'percent_change_7d': 15.04,
#   'price_btc': 6.201e-05,
#   'price_usd': 0.539422,
#   'rank': 75,
#   'symbol': 'SYS',
#   'total_supply': 530835833.0},
#  {'24h_volume_usd': 1470850.0,
#   'available_supply': 11168272.0,
#   'id': 'bitcore',
#   'last_updated': 1518200650,
#   'market_cap_usd': 282866630.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcore',
#   'percent_change_1h': 3.36,
#   'percent_change_24h': 4.34,
#   'percent_change_7d': 12.29,
#   'price_btc': 0.00291164,
#   'price_usd': 25.3277,
#   'rank': 76,
#   'symbol': 'BTX',
#   'total_supply': 16795209.0},
#  {'24h_volume_usd': 40486600.0,
#   'available_supply': 6794109922.0,
#   'id': 'iostoken',
#   'last_updated': 1518200660,
#   'market_cap_usd': 276429912.0,
#   'max_supply': None,
#   'name': 'IOStoken',
#   'percent_change_1h': 2.4,
#   'percent_change_24h': 4.53,
#   'percent_change_7d': -10.5,
#   'price_btc': 4.68e-06,
#   'price_usd': 0.0406867,
#   'rank': 77,
#   'symbol': 'IOST',
#   'total_supply': 21000000000.0},
#  {'24h_volume_usd': 17918900.0,
#   'available_supply': 60000000.0,
#   'id': 'gxshares',
#   'last_updated': 1518200651,
#   'market_cap_usd': 271825800.0,
#   'max_supply': 100000000.0,
#   'name': 'GXShares',
#   'percent_change_1h': 2.66,
#   'percent_change_24h': 9.03,
#   'percent_change_7d': 4.34,
#   'price_btc': 0.00052081,
#   'price_usd': 4.53043,
#   'rank': 78,
#   'symbol': 'GXS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 19100300.0,
#   'available_supply': 363837589.0,
#   'id': 'power-ledger',
#   'last_updated': 1518200656,
#   'market_cap_usd': 266988389.0,
#   'max_supply': None,
#   'name': 'Power Ledger',
#   'percent_change_1h': 2.96,
#   'percent_change_24h': 9.24,
#   'percent_change_7d': 10.72,
#   'price_btc': 8.436e-05,
#   'price_usd': 0.733812,
#   'rank': 79,
#   'symbol': 'POWR',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 6806790.0,
#   'available_supply': 52847204.0,
#   'id': 'salt',
#   'last_updated': 1518200655,
#   'market_cap_usd': 250488875.0,
#   'max_supply': None,
#   'name': 'SALT',
#   'percent_change_1h': 3.22,
#   'percent_change_24h': 7.29,
#   'percent_change_7d': 4.26,
#   'price_btc': 0.00054489,
#   'price_usd': 4.73987,
#   'rank': 80,
#   'symbol': 'SALT',
#   'total_supply': 120000000.0},
#  {'24h_volume_usd': 5553940.0,
#   'available_supply': 8745102.0,
#   'id': 'factom',
#   'last_updated': 1518200645,
#   'market_cap_usd': 247893034.0,
#   'max_supply': None,
#   'name': 'Factom',
#   'percent_change_1h': 2.66,
#   'percent_change_24h': 12.36,
#   'percent_change_7d': 2.16,
#   'price_btc': 0.00325866,
#   'price_usd': 28.3465,
#   'rank': 81,
#   'symbol': 'FCT',
#   'total_supply': 8745102.0},
#  {'24h_volume_usd': 5178240.0,
#   'available_supply': 79265735.0,
#   'id': 'aion',
#   'last_updated': 1518200655,
#   'market_cap_usd': 237150396.0,
#   'max_supply': None,
#   'name': 'Aion',
#   'percent_change_1h': 2.77,
#   'percent_change_24h': 6.66,
#   'percent_change_7d': -7.14,
#   'price_btc': 0.00034394,
#   'price_usd': 2.99184,
#   'rank': 82,
#   'symbol': 'AION',
#   'total_supply': 465934587.0},
#  {'24h_volume_usd': 3488110.0,
#   'available_supply': 57308425.0,
#   'id': 'monacoin',
#   'last_updated': 1518200642,
#   'market_cap_usd': 235866004.0,
#   'max_supply': None,
#   'name': 'MonaCoin',
#   'percent_change_1h': 6.46,
#   'percent_change_24h': 11.82,
#   'percent_change_7d': 6.65,
#   'price_btc': 0.00047314,
#   'price_usd': 4.11573,
#   'rank': 83,
#   'symbol': 'MONA',
#   'total_supply': 57308425.0},
#  {'24h_volume_usd': 286747.0,
#   'available_supply': 682616009.0,
#   'id': 'smartcash',
#   'last_updated': 1518200652,
#   'market_cap_usd': 222111645.0,
#   'max_supply': 5000000000.0,
#   'name': 'SmartCash',
#   'percent_change_1h': 1.86,
#   'percent_change_24h': 1.22,
#   'percent_change_7d': -7.21,
#   'price_btc': 3.741e-05,
#   'price_usd': 0.325383,
#   'rank': 84,
#   'symbol': 'SMART',
#   'total_supply': 1283660288.0},
#  {'24h_volume_usd': 7433770.0,
#   'available_supply': 4068812.0,
#   'id': 'zcoin',
#   'last_updated': 1518200648,
#   'market_cap_usd': 220837620.0,
#   'max_supply': None,
#   'name': 'ZCoin',
#   'percent_change_1h': 3.48,
#   'percent_change_24h': 10.2,
#   'percent_change_7d': 2.01,
#   'price_btc': 0.00623944,
#   'price_usd': 54.2757,
#   'rank': 85,
#   'symbol': 'XZC',
#   'total_supply': 4068812.0},
#  {'24h_volume_usd': 161220.0,
#   'available_supply': 756097560976,
#   'id': 'kin',
#   'last_updated': 1518200654,
#   'market_cap_usd': 220202829.0,
#   'max_supply': None,
#   'name': 'Kin',
#   'percent_change_1h': -2.19,
#   'percent_change_24h': 7.63,
#   'percent_change_7d': -0.59,
#   'price_btc': 3e-08,
#   'price_usd': 0.000291236,
#   'rank': 86,
#   'symbol': 'KIN',
#   'total_supply': 10000000000000},
#  {'24h_volume_usd': 8161730.0,
#   'available_supply': 74836171.0,
#   'id': 'enigma-project',
#   'last_updated': 1518200655,
#   'market_cap_usd': 213890757.0,
#   'max_supply': None,
#   'name': 'Enigma',
#   'percent_change_1h': 2.73,
#   'percent_change_24h': 17.07,
#   'percent_change_7d': 8.85,
#   'price_btc': 0.00032857,
#   'price_usd': 2.85812,
#   'rank': 87,
#   'symbol': 'ENG',
#   'total_supply': 150000000.0},
#  {'24h_volume_usd': 386913.0,
#   'available_supply': 8865563.0,
#   'id': 'particl',
#   'last_updated': 1518200652,
#   'market_cap_usd': 211855933.0,
#   'max_supply': None,
#   'name': 'Particl',
#   'percent_change_1h': 3.01,
#   'percent_change_24h': 17.94,
#   'percent_change_7d': 10.91,
#   'price_btc': 0.0027471,
#   'price_usd': 23.8965,
#   'rank': 88,
#   'symbol': 'PART',
#   'total_supply': 8865563.0},
#  {'24h_volume_usd': 997526.0,
#   'available_supply': 454443782.0,
#   'id': 'singularitynet',
#   'last_updated': 1518200659,
#   'market_cap_usd': 209858957.0,
#   'max_supply': None,
#   'name': 'SingularityNET',
#   'percent_change_1h': 6.18,
#   'percent_change_24h': 10.52,
#   'percent_change_7d': -12.88,
#   'price_btc': 5.309e-05,
#   'price_usd': 0.461793,
#   'rank': 89,
#   'symbol': 'AGI',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 7037300.0,
#   'available_supply': 38986587.0,
#   'id': 'bancor',
#   'last_updated': 1518200651,
#   'market_cap_usd': 207764981.0,
#   'max_supply': None,
#   'name': 'Bancor',
#   'percent_change_1h': 3.06,
#   'percent_change_24h': 9.69,
#   'percent_change_7d': -7.31,
#   'price_btc': 0.00061263,
#   'price_usd': 5.32914,
#   'rank': 90,
#   'symbol': 'BNT',
#   'total_supply': 74985159.0},
#  {'24h_volume_usd': 20053200.0,
#   'available_supply': 617314171.0,
#   'id': 'quantstamp',
#   'last_updated': 1518200657,
#   'market_cap_usd': 207653993.0,
#   'max_supply': None,
#   'name': 'Quantstamp',
#   'percent_change_1h': 3.68,
#   'percent_change_24h': 10.38,
#   'percent_change_7d': 25.55,
#   'price_btc': 3.867e-05,
#   'price_usd': 0.336383,
#   'rank': 91,
#   'symbol': 'QSP',
#   'total_supply': 976442388.0},
#  {'24h_volume_usd': 10616600.0,
#   'available_supply': 998999942.0,
#   'id': 'nxt',
#   'last_updated': 1518200641,
#   'market_cap_usd': 201943842.0,
#   'max_supply': 1000000000.0,
#   'name': 'Nxt',
#   'percent_change_1h': 2.48,
#   'percent_change_24h': 14.03,
#   'percent_change_7d': -6.35,
#   'price_btc': 2.324e-05,
#   'price_usd': 0.202146,
#   'rank': 92,
#   'symbol': 'NXT',
#   'total_supply': 998999942.0},
#  {'24h_volume_usd': 1996880.0,
#   'available_supply': 452552412.0,
#   'id': 'maidsafecoin',
#   'last_updated': 1518200643,
#   'market_cap_usd': 197592076.0,
#   'max_supply': None,
#   'name': 'MaidSafeCoin',
#   'percent_change_1h': 0.55,
#   'percent_change_24h': 6.65,
#   'percent_change_7d': 5.66,
#   'price_btc': 5.019e-05,
#   'price_usd': 0.436617,
#   'rank': 93,
#   'symbol': 'MAID',
#   'total_supply': 452552412.0},
#  {'24h_volume_usd': 17290400.0,
#   'available_supply': 761143950.0,
#   'id': 'ignis',
#   'last_updated': 1518200658,
#   'market_cap_usd': 195705332.0,
#   'max_supply': 999449694.0,
#   'name': 'Ignis',
#   'percent_change_1h': 4.79,
#   'percent_change_24h': 31.69,
#   'percent_change_7d': -4.92,
#   'price_btc': 2.956e-05,
#   'price_usd': 0.25712,
#   'rank': 94,
#   'symbol': 'IGNIS',
#   'total_supply': 999449694.0},
#  {'24h_volume_usd': 6492180.0,
#   'available_supply': 641462769.0,
#   'id': 'request-network',
#   'last_updated': 1518200656,
#   'market_cap_usd': 195592903.0,
#   'max_supply': None,
#   'name': 'Request Network',
#   'percent_change_1h': 3.21,
#   'percent_change_24h': 5.89,
#   'percent_change_7d': -2.71,
#   'price_btc': 3.505e-05,
#   'price_usd': 0.304917,
#   'rank': 95,
#   'symbol': 'REQ',
#   'total_supply': 999999999.0},
#  {'24h_volume_usd': 1974460.0,
#   'available_supply': 28740055495.0,
#   'id': 'reddcoin',
#   'last_updated': 1518200641,
#   'market_cap_usd': 194654959.0,
#   'max_supply': None,
#   'name': 'ReddCoin',
#   'percent_change_1h': 3.14,
#   'percent_change_24h': 13.53,
#   'percent_change_7d': -2.37,
#   'price_btc': 7.8e-07,
#   'price_usd': 0.00677295,
#   'rank': 96,
#   'symbol': 'RDD',
#   'total_supply': 28740055495.0},
#  {'24h_volume_usd': 1582120.0,
#   'available_supply': 1000000000.0,
#   'id': 'xplay',
#   'last_updated': 1518200654,
#   'market_cap_usd': 192843000.0,
#   'max_supply': None,
#   'name': 'XPlay',
#   'percent_change_1h': 2.81,
#   'percent_change_24h': 7.55,
#   'percent_change_7d': 35.56,
#   'price_btc': 2.217e-05,
#   'price_usd': 0.192843,
#   'rank': 97,
#   'symbol': 'XPA',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 673139.0,
#   'available_supply': 55514868.0,
#   'id': 'nexus',
#   'last_updated': 1518200645,
#   'market_cap_usd': 188508505.0,
#   'max_supply': None,
#   'name': 'Nexus',
#   'percent_change_1h': 3.95,
#   'percent_change_24h': 9.2,
#   'percent_change_7d': -6.51,
#   'price_btc': 0.00039036,
#   'price_usd': 3.39564,
#   'rank': 98,
#   'symbol': 'NXS',
#   'total_supply': 55514868.0},
#  {'24h_volume_usd': 795608.0,
#   'available_supply': 213754140562,
#   'id': 'experience-points',
#   'last_updated': 1518200647,
#   'market_cap_usd': 185322061.0,
#   'max_supply': None,
#   'name': 'Experience Points',
#   'percent_change_1h': 4.61,
#   'percent_change_24h': 21.09,
#   'percent_change_7d': 67.17,
#   'price_btc': 1e-07,
#   'price_usd': 0.000866987,
#   'rank': 99,
#   'symbol': 'XP',
#   'total_supply': 248785908427},
#  {'24h_volume_usd': 3833600.0,
#   'available_supply': 104661310.0,
#   'id': 'tenx',
#   'last_updated': 1518200651,
#   'market_cap_usd': 182490600.0,
#   'max_supply': None,
#   'name': 'TenX',
#   'percent_change_1h': 2.64,
#   'percent_change_24h': 12.73,
#   'percent_change_7d': -5.63,
#   'price_btc': 0.00020044,
#   'price_usd': 1.74363,
#   'rank': 100,
#   'symbol': 'PAY',
#   'total_supply': 205218256.0},
#  {'24h_volume_usd': 1396760.0,
#   'available_supply': 99735687.0,
#   'id': 'iconomi',
#   'last_updated': 1518200648,
#   'market_cap_usd': 175643521.0,
#   'max_supply': None,
#   'name': 'Iconomi',
#   'percent_change_1h': 3.4,
#   'percent_change_24h': 11.58,
#   'percent_change_7d': -8.59,
#   'price_btc': 0.00020245,
#   'price_usd': 1.76109,
#   'rank': 101,
#   'symbol': 'ICN',
#   'total_supply': 99735687.0},
#  {'24h_volume_usd': 4108640.0,
#   'available_supply': 492954537.0,
#   'id': 'wax',
#   'last_updated': 1518200658,
#   'market_cap_usd': 167680458.0,
#   'max_supply': None,
#   'name': 'WAX',
#   'percent_change_1h': 1.85,
#   'percent_change_24h': 7.73,
#   'percent_change_7d': 1.9,
#   'price_btc': 3.91e-05,
#   'price_usd': 0.340154,
#   'rank': 102,
#   'symbol': 'WAX',
#   'total_supply': 1850000000.0},
#  {'24h_volume_usd': 13335400.0,
#   'available_supply': 342699966.0,
#   'id': 'civic',
#   'last_updated': 1518200652,
#   'market_cap_usd': 166313322.0,
#   'max_supply': None,
#   'name': 'Civic',
#   'percent_change_1h': 3.76,
#   'percent_change_24h': 3.35,
#   'percent_change_7d': 14.8,
#   'price_btc': 5.579e-05,
#   'price_usd': 0.485303,
#   'rank': 103,
#   'symbol': 'CVC',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 483948.0,
#   'available_supply': 1104590.0,
#   'id': 'gnosis-gno',
#   'last_updated': 1518200650,
#   'market_cap_usd': 161839004.0,
#   'max_supply': None,
#   'name': 'Gnosis',
#   'percent_change_1h': 2.96,
#   'percent_change_24h': 4.45,
#   'percent_change_7d': -6.57,
#   'price_btc': 0.0168432,
#   'price_usd': 146.515,
#   'rank': 104,
#   'symbol': 'GNO',
#   'total_supply': 10000000.0},
#  {'24h_volume_usd': 978167.0,
#   'available_supply': 41282549.0,
#   'id': 'emercoin',
#   'last_updated': 1518200643,
#   'market_cap_usd': 161484122.0,
#   'max_supply': None,
#   'name': 'Emercoin',
#   'percent_change_1h': 2.25,
#   'percent_change_24h': 1.65,
#   'percent_change_7d': -2.38,
#   'price_btc': 0.00044968,
#   'price_usd': 3.91168,
#   'rank': 105,
#   'symbol': 'EMC',
#   'total_supply': 41282549.0},
#  {'24h_volume_usd': 3446800.0,
#   'available_supply': 12801502.0,
#   'id': 'neblio',
#   'last_updated': 1518200653,
#   'market_cap_usd': 156792800.0,
#   'max_supply': None,
#   'name': 'Neblio',
#   'percent_change_1h': 2.64,
#   'percent_change_24h': 7.45,
#   'percent_change_7d': -3.74,
#   'price_btc': 0.00140801,
#   'price_usd': 12.248,
#   'rank': 106,
#   'symbol': 'NEBL',
#   'total_supply': 13547808.0},
#  {'24h_volume_usd': 4671870.0,
#   'available_supply': 226091449.0,
#   'id': 'substratum',
#   'last_updated': 1518200654,
#   'market_cap_usd': 156676400.0,
#   'max_supply': None,
#   'name': 'Substratum',
#   'percent_change_1h': 2.67,
#   'percent_change_24h': 7.73,
#   'percent_change_7d': 6.72,
#   'price_btc': 7.966e-05,
#   'price_usd': 0.692978,
#   'rank': 107,
#   'symbol': 'SUB',
#   'total_supply': 352000000.0},
#  {'24h_volume_usd': 4606570.0,
#   'available_supply': 50148936.0,
#   'id': 'raiden-network-token',
#   'last_updated': 1518200657,
#   'market_cap_usd': 155632208.0,
#   'max_supply': None,
#   'name': 'Raiden Network Token',
#   'percent_change_1h': 4.42,
#   'percent_change_24h': 12.15,
#   'percent_change_7d': -0.83,
#   'price_btc': 0.00035676,
#   'price_usd': 3.1034,
#   'rank': 108,
#   'symbol': 'RDN',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 2076490.0,
#   'available_supply': 64355352.0,
#   'id': 'gamecredits',
#   'last_updated': 1518200644,
#   'market_cap_usd': 155553321.0,
#   'max_supply': 84000000.0,
#   'name': 'GameCredits',
#   'percent_change_1h': 1.77,
#   'percent_change_24h': 3.5,
#   'percent_change_7d': -9.4,
#   'price_btc': 0.00027787,
#   'price_usd': 2.4171,
#   'rank': 109,
#   'symbol': 'GAME',
#   'total_supply': 64355352.0},
#  {'24h_volume_usd': 5594960.0,
#   'available_supply': 350000000.0,
#   'id': 'chainlink',
#   'last_updated': 1518200654,
#   'market_cap_usd': 153638450.0,
#   'max_supply': None,
#   'name': 'ChainLink',
#   'percent_change_1h': 2.5,
#   'percent_change_24h': 6.99,
#   'percent_change_7d': -6.32,
#   'price_btc': 5.046e-05,
#   'price_usd': 0.438967,
#   'rank': 110,
#   'symbol': 'LINK',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 2302680.0,
#   'available_supply': 42856200.0,
#   'id': 'vertcoin',
#   'last_updated': 1518200641,
#   'market_cap_usd': 144217113.0,
#   'max_supply': 84000000.0,
#   'name': 'Vertcoin',
#   'percent_change_1h': 2.98,
#   'percent_change_24h': 11.82,
#   'percent_change_7d': 9.03,
#   'price_btc': 0.00038685,
#   'price_usd': 3.36514,
#   'rank': 111,
#   'symbol': 'VTC',
#   'total_supply': 42856200.0},
#  {'24h_volume_usd': 7414900.0,
#   'available_supply': 22216600.0,
#   'id': 'high-performance-blockchain',
#   'last_updated': 1518200659,
#   'market_cap_usd': 142076046.0,
#   'max_supply': None,
#   'name': 'High Performance Blockchain',
#   'percent_change_1h': 2.5,
#   'percent_change_24h': 4.54,
#   'percent_change_7d': -11.08,
#   'price_btc': 0.00073516,
#   'price_usd': 6.39504,
#   'rank': 112,
#   'symbol': 'HPB',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 1766010.0,
#   'available_supply': 2966384100.0,
#   'id': 'medibloc',
#   'last_updated': 1518200658,
#   'market_cap_usd': 141912409.0,
#   'max_supply': 10000000000.0,
#   'name': 'MediBloc',
#   'percent_change_1h': 3.77,
#   'percent_change_24h': 9.59,
#   'percent_change_7d': -8.18,
#   'price_btc': 5.5e-06,
#   'price_usd': 0.0478402,
#   'rank': 113,
#   'symbol': 'MED',
#   'total_supply': 4097545844.0},
#  {'24h_volume_usd': 45516.3,
#   'available_supply': 1288862.0,
#   'id': 'bitcoindark',
#   'last_updated': 1518200643,
#   'market_cap_usd': 141880527.0,
#   'max_supply': None,
#   'name': 'BitcoinDark',
#   'percent_change_1h': 2.21,
#   'percent_change_24h': 4.86,
#   'percent_change_7d': 4.64,
#   'price_btc': 0.0126549,
#   'price_usd': 110.082,
#   'rank': 114,
#   'symbol': 'BTCD',
#   'total_supply': 1288862.0},
#  {'24h_volume_usd': 270129.0,
#   'available_supply': 5007457.0,
#   'id': 'blocknet',
#   'last_updated': 1518200643,
#   'market_cap_usd': 141315439.0,
#   'max_supply': None,
#   'name': 'Blocknet',
#   'percent_change_1h': 2.78,
#   'percent_change_24h': 5.22,
#   'percent_change_7d': -2.49,
#   'price_btc': 0.00324424,
#   'price_usd': 28.221,
#   'rank': 115,
#   'symbol': 'BLOCK',
#   'total_supply': 5007457.0},
#  {'24h_volume_usd': 11660700.0,
#   'available_supply': 133425493.0,
#   'id': 'storj',
#   'last_updated': 1518200652,
#   'market_cap_usd': 138218136.0,
#   'max_supply': None,
#   'name': 'Storj',
#   'percent_change_1h': 1.44,
#   'percent_change_24h': 11.08,
#   'percent_change_7d': 4.53,
#   'price_btc': 0.00011909,
#   'price_usd': 1.03592,
#   'rank': 116,
#   'symbol': 'STORJ',
#   'total_supply': 424999998.0},
#  {'24h_volume_usd': 83109800.0,
#   'available_supply': 165000000.0,
#   'id': 'bluzelle',
#   'last_updated': 1518200661,
#   'market_cap_usd': 137792490.0,
#   'max_supply': None,
#   'name': 'Bluzelle',
#   'percent_change_1h': 2.86,
#   'percent_change_24h': 7.19,
#   'percent_change_7d': None,
#   'price_btc': 9.6e-05,
#   'price_usd': 0.835106,
#   'rank': 117,
#   'symbol': 'BLZ',
#   'total_supply': 500000000.0},
#  {'24h_volume_usd': 11610000.0,
#   'available_supply': 300000000.0,
#   'id': 'achain',
#   'last_updated': 1518200653,
#   'market_cap_usd': 135564300.0,
#   'max_supply': 1000000000.0,
#   'name': 'Achain',
#   'percent_change_1h': 5.04,
#   'percent_change_24h': 22.45,
#   'percent_change_7d': 17.05,
#   'price_btc': 5.195e-05,
#   'price_usd': 0.451881,
#   'rank': 118,
#   'symbol': 'ACT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 6617380.0,
#   'available_supply': 6895434680.0,
#   'id': 'digitalnote',
#   'last_updated': 1518200642,
#   'market_cap_usd': 134045871.0,
#   'max_supply': None,
#   'name': 'DigitalNote',
#   'percent_change_1h': 4.63,
#   'percent_change_24h': 15.03,
#   'percent_change_7d': 3.27,
#   'price_btc': 2.23e-06,
#   'price_usd': 0.0194398,
#   'rank': 119,
#   'symbol': 'XDN',
#   'total_supply': 6895434680.0},
#  {'24h_volume_usd': 30584.6,
#   'available_supply': 816061.0,
#   'id': 'supernet-unity',
#   'last_updated': 1518200644,
#   'market_cap_usd': 133533657.0,
#   'max_supply': None,
#   'name': 'SuperNET',
#   'percent_change_1h': 1.4,
#   'percent_change_24h': 12.79,
#   'percent_change_7d': 50.63,
#   'price_btc': 0.0188109,
#   'price_usd': 163.632,
#   'rank': 120,
#   'symbol': 'UNITY',
# ...
#   'max_supply': None,
#   'name': 'iTicoin',
#   'percent_change_1h': 1.97,
#   'percent_change_24h': 17.56,
#   'percent_change_7d': -9.88,
#   'price_btc': 0.00369718,
#   'price_usd': 32.1611,
#   'rank': 960,
#   'symbol': 'ITI',
#   'total_supply': 9999992.0},
#  {'24h_volume_usd': 345.768,
#   'available_supply': 15554686.0,
#   'id': 'universe',
#   'last_updated': 1518200650,
#   'market_cap_usd': 1021570.0,
#   'max_supply': None,
#   'name': 'Universe',
#   'percent_change_1h': 2.77,
#   'percent_change_24h': 10.9,
#   'percent_change_7d': -22.4,
#   'price_btc': 7.55e-06,
#   'price_usd': 0.065676,
#   'rank': 961,
#   'symbol': 'UNI',
#   'total_supply': 26754686.0},
#  {'24h_volume_usd': 380.566,
#   'available_supply': 2136616133.0,
#   'id': 'bigup',
#   'last_updated': 1518200646,
#   'market_cap_usd': 973002.0,
#   'max_supply': None,
#   'name': 'BigUp',
#   'percent_change_1h': 2.9,
#   'percent_change_24h': 1.25,
#   'percent_change_7d': 14.3,
#   'price_btc': 5e-08,
#   'price_usd': 0.000455394,
#   'rank': 962,
#   'symbol': 'BIGUP',
#   'total_supply': 2136616133.0},
#  {'24h_volume_usd': None,
#   'available_supply': 445371.0,
#   'id': 'nimfamoney',
#   'last_updated': 1518198259,
#   'market_cap_usd': 969978.0,
#   'max_supply': None,
#   'name': 'Nimfamoney',
#   'percent_change_1h': 1.2,
#   'percent_change_24h': 1.9,
#   'percent_change_7d': -35.01,
#   'price_btc': 0.00025302,
#   'price_usd': 2.17791,
#   'rank': 963,
#   'symbol': 'NIMFA',
#   'total_supply': 1542580.0},
#  {'24h_volume_usd': 57.2108,
#   'available_supply': 24101381.0,
#   'id': 'gaia',
#   'last_updated': 1518200643,
#   'market_cap_usd': 964405.0,
#   'max_supply': None,
#   'name': 'GAIA',
#   'percent_change_1h': 2.77,
#   'percent_change_24h': 3.14,
#   'percent_change_7d': 12.69,
#   'price_btc': 4.6e-06,
#   'price_usd': 0.0400145,
#   'rank': 964,
#   'symbol': 'GAIA',
#   'total_supply': 24101381.0},
#  {'24h_volume_usd': 26.5104,
#   'available_supply': 8035193.0,
#   'id': 'woodcoin',
#   'last_updated': 1518200644,
#   'market_cap_usd': 949896.0,
#   'max_supply': None,
#   'name': 'Woodcoin',
#   'percent_change_1h': 3.13,
#   'percent_change_24h': -12.8,
#   'percent_change_7d': 0.84,
#   'price_btc': 1.359e-05,
#   'price_usd': 0.118217,
#   'rank': 965,
#   'symbol': 'LOG',
#   'total_supply': 8035193.0},
#  {'24h_volume_usd': 44.3238,
#   'available_supply': 23079737.0,
#   'id': 'bitstar',
#   'last_updated': 1518200643,
#   'market_cap_usd': 937157.0,
#   'max_supply': None,
#   'name': 'Bitstar',
#   'percent_change_1h': 1.42,
#   'percent_change_24h': 3.63,
#   'percent_change_7d': -10.7,
#   'price_btc': 4.67e-06,
#   'price_usd': 0.0406052,
#   'rank': 966,
#   'symbol': 'BITS',
#   'total_supply': 23079737.0},
#  {'24h_volume_usd': 252.275,
#   'available_supply': 1.0,
#   'id': 'bit20',
#   'last_updated': 1518200652,
#   'market_cap_usd': 935159.0,
#   'max_supply': None,
#   'name': 'Bit20',
#   'percent_change_1h': 3.03,
#   'percent_change_24h': 10.33,
#   'percent_change_7d': 2.93,
#   'price_btc': 105.811,
#   'price_usd': 920432.0,
#   'rank': 967,
#   'symbol': 'BTWTY',
#   'total_supply': 1.0},
#  {'24h_volume_usd': 306.295,
#   'available_supply': 64151405.0,
#   'id': 'hobonickels',
#   'last_updated': 1518200641,
#   'market_cap_usd': 909603.0,
#   'max_supply': 120000000.0,
#   'name': 'HoboNickels',
#   'percent_change_1h': -0.79,
#   'percent_change_24h': 6.07,
#   'percent_change_7d': -17.6,
#   'price_btc': 1.63e-06,
#   'price_usd': 0.014179,
#   'rank': 968,
#   'symbol': 'HBN',
#   'total_supply': 64151405.0},
#  {'24h_volume_usd': 462.457,
#   'available_supply': 75000000.0,
#   'id': 'bitpark-coin',
#   'last_updated': 1518200649,
#   'market_cap_usd': 894990.0,
#   'max_supply': None,
#   'name': 'Bitpark Coin',
#   'percent_change_1h': 3.85,
#   'percent_change_24h': 26.46,
#   'percent_change_7d': -31.77,
#   'price_btc': 1.37e-06,
#   'price_usd': 0.0119332,
#   'rank': 969,
#   'symbol': 'BPC',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 161.835,
#   'available_supply': 10291781.0,
#   'id': 'bankcoin',
#   'last_updated': 1518200650,
#   'market_cap_usd': 886196.0,
#   'max_supply': None,
#   'name': 'Bankcoin',
#   'percent_change_1h': 91.56,
#   'percent_change_24h': 196.11,
#   'percent_change_7d': 67.92,
#   'price_btc': 9.9e-06,
#   'price_usd': 0.0861072,
#   'rank': 970,
#   'symbol': 'B@',
#   'total_supply': 25000000.0},
#  {'24h_volume_usd': 444.776,
#   'available_supply': 50936499.0,
#   'id': 'visio',
#   'last_updated': 1518200650,
#   'market_cap_usd': 841863.0,
#   'max_supply': None,
#   'name': 'Visio',
#   'percent_change_1h': 2.85,
#   'percent_change_24h': -6.7,
#   'percent_change_7d': -16.73,
#   'price_btc': 1.9e-06,
#   'price_usd': 0.0165277,
#   'rank': 971,
#   'symbol': 'VISIO',
#   'total_supply': 62936499.0},
#  {'24h_volume_usd': 256.869,
#   'available_supply': 318929301.0,
#   'id': 'nyancoin',
#   'last_updated': 1518200641,
#   'market_cap_usd': 829825.0,
#   'max_supply': 337000000.0,
#   'name': 'Nyancoin',
#   'percent_change_1h': -3.85,
#   'percent_change_24h': -0.75,
#   'percent_change_7d': -8.17,
#   'price_btc': 3e-07,
#   'price_usd': 0.00260191,
#   'rank': 972,
#   'symbol': 'NYAN',
#   'total_supply': 318929301.0},
#  {'24h_volume_usd': 201.834,
#   'available_supply': 9503724.0,
#   'id': 'wavesgo',
#   'last_updated': 1518200650,
#   'market_cap_usd': 823553.0,
#   'max_supply': None,
#   'name': 'WavesGo',
#   'percent_change_1h': 3.22,
#   'percent_change_24h': 12.21,
#   'percent_change_7d': -8.35,
#   'price_btc': 9.96e-06,
#   'price_usd': 0.0866558,
#   'rank': 973,
#   'symbol': 'WGO',
#   'total_supply': 9503724.0},
#  {'24h_volume_usd': 327.73,
#   'available_supply': 65290635.0,
#   'id': 'btctalkcoin',
#   'last_updated': 1518200642,
#   'market_cap_usd': 823530.0,
#   'max_supply': None,
#   'name': 'BTCtalkcoin',
#   'percent_change_1h': 2.86,
#   'percent_change_24h': 7.66,
#   'percent_change_7d': 12.12,
#   'price_btc': 1.45e-06,
#   'price_usd': 0.0126133,
#   'rank': 974,
#   'symbol': 'TALK',
#   'total_supply': 65290635.0},
#  {'24h_volume_usd': None,
#   'available_supply': 23020335.0,
#   'id': 'janus',
#   'last_updated': 1517536153,
#   'market_cap_usd': 744390.0,
#   'max_supply': None,
#   'name': 'Janus',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': None,
#   'price_btc': 3.72e-06,
#   'price_usd': 0.0323362,
#   'rank': 975,
#   'symbol': 'JNS',
#   'total_supply': 25201489.0},
#  {'24h_volume_usd': 483.857,
#   'available_supply': 61445805.0,
#   'id': 'maxcoin',
#   'last_updated': 1518200642,
#   'market_cap_usd': 721583.0,
#   'max_supply': None,
#   'name': 'MaxCoin',
#   'percent_change_1h': 2.86,
#   'percent_change_24h': 3.5,
#   'percent_change_7d': 4.91,
#   'price_btc': 1.35e-06,
#   'price_usd': 0.0117434,
#   'rank': 976,
#   'symbol': 'MAX',
#   'total_supply': 61445805.0},
#  {'24h_volume_usd': 249.132,
#   'available_supply': 196336.0,
#   'id': 'prototanium',
#   'last_updated': 1518200646,
#   'market_cap_usd': 719398.0,
#   'max_supply': None,
#   'name': 'Prototanium',
#   'percent_change_1h': 8.32,
#   'percent_change_24h': 4.0,
#   'percent_change_7d': -0.42,
#   'price_btc': 0.00042122,
#   'price_usd': 3.66411,
#   'rank': 977,
#   'symbol': 'PR',
#   'total_supply': 196336.0},
#  {'24h_volume_usd': 4.3414,
#   'available_supply': 1990891.0,
#   'id': 'bitz',
#   'last_updated': 1518200645,
#   'market_cap_usd': 692734.0,
#   'max_supply': None,
#   'name': 'Bitz',
#   'percent_change_1h': 2.86,
#   'percent_change_24h': 50.38,
#   'percent_change_7d': -11.66,
#   'price_btc': 4e-05,
#   'price_usd': 0.347952,
#   'rank': 978,
#   'symbol': 'BITZ',
#   'total_supply': 1990891.0},
#  {'24h_volume_usd': 182.74,
#   'available_supply': 210806.0,
#   'id': 'flycoin',
#   'last_updated': 1518200645,
#   'market_cap_usd': 668458.0,
#   'max_supply': None,
#   'name': 'Flycoin',
#   'percent_change_1h': 38.87,
#   'percent_change_24h': 45.71,
#   'percent_change_7d': 4.47,
#   'price_btc': 0.00036453,
#   'price_usd': 3.17097,
#   'rank': 979,
#   'symbol': 'FLY',
#   'total_supply': 210806.0},
#  {'24h_volume_usd': 193.677,
#   'available_supply': 353643.0,
#   'id': 'swagbucks',
#   'last_updated': 1518200646,
#   'market_cap_usd': 664382.0,
#   'max_supply': None,
#   'name': 'SwagBucks',
#   'percent_change_1h': 2.9,
#   'percent_change_24h': 5.87,
#   'percent_change_7d': -6.87,
#   'price_btc': 0.00021597,
#   'price_usd': 1.87868,
#   'rank': 980,
#   'symbol': 'BUCKS',
#   'total_supply': 353643.0},
#  {'24h_volume_usd': 209.149,
#   'available_supply': 21268092.0,
#   'id': 'britcoin',
#   'last_updated': 1518200644,
#   'market_cap_usd': 656329.0,
#   'max_supply': None,
#   'name': 'BritCoin',
#   'percent_change_1h': 2.77,
#   'percent_change_24h': 12.46,
#   'percent_change_7d': 9.64,
#   'price_btc': 3.55e-06,
#   'price_usd': 0.0308598,
#   'rank': 981,
#   'symbol': 'BRIT',
#   'total_supply': 21268092.0},
#  {'24h_volume_usd': 393.089,
#   'available_supply': 169201608.0,
#   'id': 'truckcoin',
#   'last_updated': 1518200643,
#   'market_cap_usd': 647614.0,
#   'max_supply': None,
#   'name': 'Truckcoin',
#   'percent_change_1h': 2.86,
#   'percent_change_24h': 19.45,
#   'percent_change_7d': -3.24,
#   'price_btc': 4.4e-07,
#   'price_usd': 0.00382747,
#   'rank': 982,
#   'symbol': 'TRK',
#   'total_supply': 169201608.0},
#  {'24h_volume_usd': 126.81,
#   'available_supply': 107972766.0,
#   'id': 'signatum',
#   'last_updated': 1518200652,
#   'market_cap_usd': 638678.0,
#   'max_supply': None,
#   'name': 'Signatum',
#   'percent_change_1h': 2.86,
#   'percent_change_24h': 8.63,
#   'percent_change_7d': -6.74,
#   'price_btc': 6.8e-07,
#   'price_usd': 0.00591518,
#   'rank': 983,
#   'symbol': 'SIGT',
#   'total_supply': 107972766.0},
#  {'24h_volume_usd': 113.831,
#   'available_supply': 77777777.0,
#   'id': 'ammo-rewards',
#   'last_updated': 1518200651,
#   'market_cap_usd': 615682.0,
#   'max_supply': None,
#   'name': 'Ammo Reloaded',
#   'percent_change_1h': 2.86,
#   'percent_change_24h': 6.45,
#   'percent_change_7d': -10.21,
#   'price_btc': 9.1e-07,
#   'price_usd': 0.00791591,
#   'rank': 984,
#   'symbol': 'AMMO',
#   'total_supply': 77777777.0},
#  {'24h_volume_usd': 3.82278,
#   'available_supply': 2358819009.0,
#   'id': 'colossuscoin-v2',
#   'last_updated': 1518200644,
#   'market_cap_usd': 615567.0,
#   'max_supply': None,
#   'name': 'Colossuscoin V2',
#   'percent_change_1h': 2.86,
#   'percent_change_24h': 58.81,
#   'percent_change_7d': 50.37,
#   'price_btc': 3e-08,
#   'price_usd': 0.000260964,
#   'rank': 985,
#   'symbol': 'CV2',
#   'total_supply': 22977351798.0},
#  {'24h_volume_usd': 56.6874,
#   'available_supply': 169598616.0,
#   'id': 'bitcurrency',
#   'last_updated': 1518200648,
#   'market_cap_usd': 604875.0,
#   'max_supply': None,
#   'name': 'Bitcurrency',
#   'percent_change_1h': 2.86,
#   'percent_change_24h': 5.87,
#   'percent_change_7d': -48.09,
#   'price_btc': 4.1e-07,
#   'price_usd': 0.00356651,
#   'rank': 986,
#   'symbol': 'BTCR',
#   'total_supply': 169598616.0},
#  {'24h_volume_usd': 174.478,
#   'available_supply': 9436367.0,
#   'id': 'mineum',
#   'last_updated': 1518200647,
#   'market_cap_usd': 599722.0,
#   'max_supply': None,
#   'name': 'Mineum',
#   'percent_change_1h': 2.68,
#   'percent_change_24h': -9.32,
#   'percent_change_7d': 14.16,
#   'price_btc': 7.31e-06,
#   'price_usd': 0.0635543,
#   'rank': 987,
#   'symbol': 'MNM',
#   'total_supply': 9586367.0},
#  {'24h_volume_usd': 327.305,
#   'available_supply': 868103.0,
#   'id': 'litebar',
#   'last_updated': 1518200642,
#   'market_cap_usd': 596489.0,
#   'max_supply': None,
#   'name': 'LiteBar',
#   'percent_change_1h': 1.94,
#   'percent_change_24h': 5.46,
#   'percent_change_7d': 13.95,
#   'price_btc': 7.899e-05,
#   'price_usd': 0.687118,
#   'rank': 988,
#   'symbol': 'LTB',
#   'total_supply': 868103.0},
#  {'24h_volume_usd': 250.635,
#   'available_supply': 18697413.0,
#   'id': 'motocoin',
#   'last_updated': 1518200643,
#   'market_cap_usd': 595281.0,
#   'max_supply': None,
#   'name': 'Motocoin',
#   'percent_change_1h': -4.93,
#   'percent_change_24h': 1.78,
#   'percent_change_7d': -22.32,
#   'price_btc': 3.66e-06,
#   'price_usd': 0.0318376,
#   'rank': 989,
#   'symbol': 'MOTO',
#   'total_supply': 31228043.0},
#  {'24h_volume_usd': 1.28742,
#   'available_supply': 90421856.0,
#   'id': 'tattoocoin',
#   'last_updated': 1518200649,
#   'market_cap_usd': 582055.0,
#   'max_supply': None,
#   'name': 'Tattoocoin (Standard Edition)',
#   'percent_change_1h': 2.86,
#   'percent_change_24h': 2.05,
#   'percent_change_7d': -2.39,
#   'price_btc': 7.4e-07,
#   'price_usd': 0.00643711,
#   'rank': 990,
#   'symbol': 'TSE',
#   'total_supply': 90421856.0},
#  {'24h_volume_usd': 8.6988,
#   'available_supply': 6097666267.0,
#   'id': 'valorbit',
#   'last_updated': 1518200646,
#   'market_cap_usd': 530424.0,
#   'max_supply': None,
#   'name': 'Valorbit',
#   'percent_change_1h': 2.86,
#   'percent_change_24h': 5.87,
#   'percent_change_7d': 0.25,
#   'price_btc': 1e-08,
#   'price_usd': 8.6988e-05,
#   'rank': 991,
#   'symbol': 'VAL',
#   'total_supply': 922343297666267},
#  {'24h_volume_usd': 88.9699,
#   'available_supply': 5428300.0,
#   'id': 'blockpay',
#   'last_updated': 1518200648,
#   'market_cap_usd': 521082.0,
#   'max_supply': None,
#   'name': 'BlockPay',
#   'percent_change_1h': 3.16,
#   'percent_change_24h': 8.01,
#   'percent_change_7d': -23.78,
#   'price_btc': 1.104e-05,
#   'price_usd': 0.0959936,
#   'rank': 992,
#   'symbol': 'BLOCKPAY',
#   'total_supply': 98928316.0},
#  {'24h_volume_usd': 293.339,
#   'available_supply': 590751.0,
#   'id': 'zozocoin',
#   'last_updated': 1518200657,
#   'market_cap_usd': 516554.0,
#   'max_supply': 27000000.0,
#   'name': 'ZoZoCoin',
#   'percent_change_1h': 3.4,
#   'percent_change_24h': 7.54,
#   'percent_change_7d': -6.12,
#   'price_btc': 0.00010052,
#   'price_usd': 0.874403,
#   'rank': 993,
#   'symbol': 'ZZC',
#   'total_supply': 7296311.0},
#  {'24h_volume_usd': 16.1412,
#   'available_supply': 21948.0,
#   'id': 'bitsilver',
#   'last_updated': 1518200644,
#   'market_cap_usd': 506066.0,
#   'max_supply': None,
#   'name': 'bitSilver',
#   'percent_change_1h': 2.93,
#   'percent_change_24h': 26.52,
#   'percent_change_7d': 22.92,
#   'price_btc': 0.00265066,
#   'price_usd': 23.0576,
#   'rank': 994,
#   'symbol': 'BITSILVER',
#   'total_supply': 21948.0},
#  {'24h_volume_usd': 365.082,
#   'available_supply': 7089144.0,
#   'id': 'sativacoin',
#   'last_updated': 1518200644,
#   'market_cap_usd': 503303.0,
#   'max_supply': None,
#   'name': 'Sativacoin',
#   'percent_change_1h': 3.02,
#   'percent_change_24h': 5.89,
#   'percent_change_7d': -1.34,
#   'price_btc': 8.16e-06,
#   'price_usd': 0.0709963,
#   'rank': 995,
#   'symbol': 'STV',
#   'total_supply': 7089144.0},
#  {'24h_volume_usd': 236.856,
#   'available_supply': 43536800.0,
#   'id': 'tigercoin',
#   'last_updated': 1518200641,
#   'market_cap_usd': 499907.0,
#   'max_supply': None,
#   'name': 'Tigercoin',
#   'percent_change_1h': 2.86,
#   'percent_change_24h': 6.68,
#   'percent_change_7d': -23.82,
#   'price_btc': 1.32e-06,
#   'price_usd': 0.0114824,
#   'rank': 996,
#   'symbol': 'TGC',
#   'total_supply': 43536800.0},
#  {'24h_volume_usd': 34.5008,
#   'available_supply': 65171010.0,
#   'id': 'globalcoin',
#   'last_updated': 1518200641,
#   'market_cap_usd': 498880.0,
#   'max_supply': None,
#   'name': 'GlobalCoin',
#   'percent_change_1h': 2.86,
#   'percent_change_24h': 34.0,
#   'percent_change_7d': -0.93,
#   'price_btc': 8.8e-07,
#   'price_usd': 0.00765494,
#   'rank': 997,
#   'symbol': 'GLC',
#   'total_supply': 65171010.0},
#  {'24h_volume_usd': 30.6525,
#   'available_supply': 43699481.0,
#   'id': 'ambercoin',
#   'last_updated': 1518200645,
#   'market_cap_usd': 471364.0,
#   'max_supply': None,
#   'name': 'AmberCoin',
#   'percent_change_1h': 48.32,
#   'percent_change_24h': -1.29,
#   'percent_change_7d': -38.15,
#   'price_btc': 1.24e-06,
#   'price_usd': 0.0107865,
#   'rank': 998,
#   'symbol': 'AMBER',
#   'total_supply': 43699481.0},
#  {'24h_volume_usd': 22.6819,
#   'available_supply': 3052076.0,
#   'id': 'joincoin',
#   'last_updated': 1518200643,
#   'market_cap_usd': 451606.0,
#   'max_supply': None,
#   'name': 'Joincoin',
#   'percent_change_1h': 2.86,
#   'percent_change_24h': 9.08,
#   'percent_change_7d': -2.08,
#   'price_btc': 1.701e-05,
#   'price_usd': 0.147967,
#   'rank': 999,
#   'symbol': 'J',
#   'total_supply': 3052076.0},
#  {'24h_volume_usd': 337.148,
#   'available_supply': 73729962.0,
#   'id': 'chronos',
#   'last_updated': 1518200647,
#   'market_cap_usd': 450801.0,
#   'max_supply': None,
#   'name': 'Chronos',
#   'percent_change_1h': -3.34,
#   'percent_change_24h': 7.27,
#   'percent_change_7d': -20.4,
#   'price_btc': 7e-07,
#   'price_usd': 0.00611422,
#   'rank': 1000,
#   'symbol': 'CRX',
#   'total_supply': 73729962.0},
#  ...]

# %% [markdown]
# You can pass a currency through symbol or coin slug:

# %%
data_from_symbol = cmc.ticker("BTC")
data_from_slug = cmc.ticker("bitcoin")

data_from_slug
# Out:
# {'24h_volume_usd': 8309900000.0,
#  'available_supply': 16855075.0,
#  'id': 'bitcoin',
#  'last_updated': 1518200366,
#  'market_cap_usd': 146717865700,
#  'max_supply': 21000000.0,
#  'name': 'Bitcoin',
#  'percent_change_1h': 2.84,
#  'percent_change_24h': 5.94,
#  'percent_change_7d': 0.32,
#  'price_btc': 1.0,
#  'price_usd': 8704.67,
#  'rank': 1,
#  'symbol': 'BTC',
#  'total_supply': 16855075.0}

# %% [markdown]
# To get all symbols and slugs you can use the next attributes:

# %%
all_symbols = cmc.symbols
all_slugs = cmc.coins

all_symbols
# Out:
# ['XWC',
#  'YTN',
#  'LKC',
#  'BLX',
#  'SLFI',
#  'VIDZ',
#  'ARK',
#  'XCXT',
#  'SLG',
#  '1337',
#  'XBC',
#  'GAP',
#  'PROC',
#  'PTOY',
#  'XEL',
#  'AIT',
#  'DRGN',
#  'XMR',
#  'PING',
#  'XGR',
#  'VIVO',
#  'FUCK',
#  'BCAP',
#  'XMY',
#  'ITC',
#  'WHL',
#  'QAU',
#  'CPAY',
#  'REP',
#  'GMT',
#  'CAPP',
#  'SKIN',
#  'ERC20',
#  'BTWTY',
#  'SONG',
#  'QLC',
#  'NMR',
#  'EBTC',
#  'IBANK',
#  'TAG',
#  'RUNNERS',
#  'DUTCH',
#  'TRAC',
#  'RICHX',
#  'CC',
#  'ACC',
#  'SKULL',
#  'FC2',
#  'MDT',
#  'DDD',
#  'XVG',
#  'ADK',
#  'CAT',
#  'BAY',
#  'HSR',
#  'CTIC3',
#  'MCO',
#  'PLX',
#  'BCC',
#  'LBC',
#  'INSN',
#  'QUBE',
#  'R',
#  'CRX',
#  'RUP',
#  'IQT',
#  'BLITZ',
#  'REX',
#  'VEE',
#  'SOON',
#  'BIP',
#  'KCASH',
#  'KASHH',
#  'NOBL',
#  'EGG',
#  'DTR',
#  'TES',
#  'WTT',
#  'XLR',
#  'WPR',
#  'THETA',
#  'BPL',
#  'CBX',
#  'IMX',
#  'BLU',
#  'VSX',
#  'KUSH',
#  'VRS',
#  'EVX',
#  'SBTC',
#  'BCH',
#  'TIX',
#  'CFI',
#  'ATX',
#  'TSTR',
#  'DICE',
#  'SIGMA',
#  'ION',
#  'GML',
#  'VERI',
#  'POP',
#  'BDG',
#  'CCT',
#  '$$$',
#  'MTNC',
#  'WGO',
#  'SOCC',
#  'MINT',
#  'UFR',
#  'UET',
#  'SRC',
#  'EVC',
#  'SYNX',
#  'SOJ',
#  'VLT',
#  'TAAS',
#  'BLK',
#  'EGOLD',
#  'BLUE',
#  'CRW',
#  'DUBI',
#  'ACE',
#  'NUKO',
#  'NEOG',
#  'ZRX',
#  'POKE',
#  'XLC',
#  'PAY',
#  'MNC',
#  'PLNC',
#  'TERA',
#  'BYC',
#  'XSPEC',
#  'EXP',
#  'EKT',
#  'FUN',
#  'FLAX',
#  'XPM',
#  'ERO',
#  'CTIC2',
#  '300',
#  'DTA',
#  'STORM',
#  'INXT',
#  'THC',
#  'GARY',
#  'BRD',
#  'ETT',
#  'AVT',
#  'FIL',
#  'FFC',
#  'UBTC',
#  'LUNA',
#  'HC',
#  'TEAM',
#  'X2',
#  'HIGH',
#  'G3N',
#  'ICOB',
#  'XRL',
#  'SPK',
#  'TFL',
#  'BIG',
#  'NYC',
#  'NTRN',
#  'ITI',
#  'TROLL',
#  'PXS',
#  'EOT',
#  'XCT',
#  'LOC',
#  'VOYA',
#  'TRUST',
#  'CV',
#  'FLDC',
#  'PPT',
#  'PRM',
#  'IVZ',
#  'ETP',
#  'BRIT',
#  'DBC',
#  'SRN',
#  'IFT',
#  'NKC',
#  'AU',
#  'ABC',
#  'DAY',
#  'KDC',
#  'SIB',
#  'LOG',
#  'CYP',
#  '42',
#  'SKC',
#  'DBET',
#  'NKA',
#  'EOS',
#  'YOYOW',
#  'QORA',
#  'CV2',
#  'HLC',
#  'QTL',
#  'UNO',
#  'AUR',
#  'HVCO',
#  'RBIES',
#  'STEEM',
#  'LDOGE',
#  'PIZZA',
#  'SNRG',
#  'MAID',
#  'TCOIN',
#  'NMS',
#  'ARCO',
#  'MBI',
#  'BIX',
#  'STV',
#  'IXC',
#  'FIRE',
#  'ELLA',
#  'WOW',
#  'GAIA',
#  'BAR',
#  'DIX',
#  'GRE',
#  'MNX',
#  'UTT',
#  'ECASH',
#  'BT2',
#  'HTML',
#  'TZC',
#  'ORLY',
#  'AMBER',
#  'XJO',
#  'CTO',
#  'NAS',
#  'SDC',
#  'RDD',
#  'SNGLS',
#  'XDE2',
#  'SPACE',
#  'ADL',
#  'VIU',
#  'SAC',
#  'BTCZ',
#  'XBTC21',
#  'XVE',
#  'ALT',
#  'ALTCOM',
#  'NETKO',
#  'MOIN',
#  'B2B',
#  'WOMEN',
#  'OP',
#  'OPC',
#  'SALT',
#  'ETH',
#  'ODN',
#  'MXT',
#  'FCT',
#  'UIS',
#  'ZYD',
#  'GAY',
#  'XCS',
#  'ONION',
#  'SCT',
#  'NOTE',
#  'XTZ',
#  'BUN',
#  'ARN',
#  'COFI',
#  'TKN',
#  'DNA',
#  'XPA',
#  'ENJ',
#  'MUSIC',
#  'RIDE',
#  'ENT',
#  'CUBE',
#  'LCT',
#  'ATOM',
#  'GBX',
#  'GLD',
#  'XRA',
#  'SPR',
#  'SPHR',
#  'FC',
#  'CFT',
#  'FST',
#  'PPY',
#  'BRAT',
#  'HGT',
#  'XAUR',
#  'INS',
#  'KARMA',
#  'LBTC',
#  'XOT',
#  'NEOS',
#  'DGB',
#  'SCRT',
#  'REE',
#  'KRONE',
#  'ARC',
#  'PTC',
#  'VPRC',
#  'BITCF',
#  'AERM',
#  'BOS',
#  'LIGHT',
#  'GPL',
#  'START',
#  'SBD',
#  'XBL',
#  'PKT',
#  'CHC',
#  'FUTC',
#  'STORJ',
#  'ASAFE2',
#  'DOLLAR',
#  'CCM100',
#  'CRED',
#  'SHORTY',
#  'CASH',
#  'AMMO',
#  'EAG',
#  'DMD',
#  'SXC',
#  'BLC',
#  'SPC',
#  'AXP',
#  'EPC',
#  'ELTC2',
#  'VRC',
#  'GAT',
#  'CJ',
#  'WAX',
#  'TNB',
#  'CRAVE',
#  'SAGA',
#  'UAHPAY',
#  'CF',
#  'QBC',
#  'RBX',
#  'MEME',
#  'CXT',
#  'MAGE',
#  'HMC',
#  'NDC',
#  'BAS',
#  'EPY',
#  'MNM',
#  'ADCN',
#  'ZNE',
#  'XMG',
#  'EBIT',
#  'ELE',
#  'HDG',
#  'GOLOS',
#  'ADST',
#  'ABN',
#  'HUSH',
#  'GOD',
#  'NRO',
#  'BIS',
#  'FJC',
#  'WDC',
#  'SUPER',
#  'ZER',
#  'CLUB',
#  'SPEX',
#  'CCN',
#  'CSNO',
#  'EFL',
#  'GRID',
#  'DBIX',
#  'EVO',
#  'KIN',
#  'LNK',
#  'CDT',
#  'DENT',
#  'WISH',
#  'XCRE',
#  'OF',
#  'SPORT',
#  'YES',
#  'UTK',
#  'INF',
#  'PRS',
#  'TOP',
#  'ISL',
#  'RIYA',
#  'XDN',
#  'QVT',
#  'HPC',
#  'NIMFA',
#  'GAME',
#  'YEE',
#  'CON',
#  'VSL',
#  'TRC',
#  'EVIL',
#  'ITNS',
#  'DCY',
#  'UNIT',
#  'EVE',
#  'EXN',
#  'VEC2',
#  'HODL',
#  'AE',
#  'GOLF',
#  'XRC',
#  'CHAT',
#  'JIN',
#  'CNT',
#  'BCO',
#  'STA',
#  'EBT',
#  'PAC',
#  'AMS',
#  'HBC',
#  'PIGGY',
#  'ORB',
#  'ZOI',
#  'ELS',
#  'GEERT',
#  'MTH',
#  'MEN',
#  'AWR',
#  'THS',
#  'ZCG',
#  'GCN',
#  'TRUMP',
#  'PASL',
#  'HORSE',
#  'WC',
#  'GRIM',
#  'BTPL',
#  'POS',
#  'WSX',
#  'PART',
#  'TSE',
#  'ZAP',
#  'INFX',
#  'GBG',
#  'EUSD',
#  'J',
#  'STC',
#  'CRT',
#  'GRC',
#  'IFLT',
#  'DLISK',
#  'PONZI',
#  'BITOK',
#  'BITBTC',
#  'MSP',
#  'UFO',
#  'BTM',
#  'REGA',
#  'AION',
#  'BQ',
#  'NAV',
#  'PRG',
#  'ERC',
#  'STN',
#  'XHI',
#  'EKO',
#  'AKY',
#  'TESLA',
#  'HBN',
#  'SHA',
#  'POLIS',
#  'SSC',
#  'RUFF',
#  'KOBO',
#  'TRX',
#  'DATA',
#  'NVC',
#  'CHIPS',
#  'REBL',
#  'EDT',
#  'IC',
#  'CONX',
#  'SNOV',
#  'FYP',
#  'USDT',
#  'DCRE',
#  'CND',
#  'DGD',
#  'GDC',
#  'PLBT',
#  'BBT',
#  'RNS',
#  'TEK',
#  '2GIVE',
#  'AMP',
#  'INN',
#  'MTLMC3',
#  'BITCNY',
#  'KED',
#  'BELA',
#  'FAP',
#  'INDIA',
#  'ZSE',
#  'BRAIN',
#  'TOR',
#  'TIT',
#  'SXDT',
#  'CNNC',
#  'XMRG',
#  'XCP',
#  'CXO',
#  'ATM',
#  'ALQO',
#  'SLT',
#  'WAY',
#  'DON',
#  'NODC',
#  'BASH',
#  'USNBT',
#  'MONETA',
#  'SWP',
#  'ROC',
#  'FRK',
#  'RAIN',
#  'BLZ',
#  'HMQ',
#  'SHOW',
#  'REF',
#  'ESP',
#  'MGC',
#  'B2X',
#  'GTO',
#  'AIR',
#  'FNC',
#  'QTUM',
#  'PDG',
#  'XFT',
#  'XOC',
#  'MYST',
#  'NTWK',
#  'FRC',
#  'PRO',
#  'XVC',
#  'XAU',
#  'ICON',
#  'PRX',
#  'XBY',
#  'ANI',
#  'MNE',
#  'BTQ',
#  'MEC',
#  'EGC',
#  'ALTC',
#  'PIPL',
#  'RBBT',
#  'WETH',
#  'ACN',
#  'POT',
#  'DCR',
#  'ESZ',
#  'BWK',
#  'LUX',
#  'RNT',
#  'BRIA',
#  'SLR',
#  'TCC',
#  'ACP',
#  'ACOIN',
#  'DRP',
#  'LINK',
#  'NMC',
#  'ICN',
#  'RBT',
#  'TRI',
#  'GXS',
#  'ECC',
#  'IFC',
#  'NBIT',
#  'DUO',
#  'NIO',
#  'EAGLE',
#  'BSD',
#  'KLC',
#  'PAK',
#  'BET',
#  'UTC',
#  'VIBE',
#  'LMC',
#  'GNX',
#  'EGAS',
#  'MAGN',
#  'TGC',
#  'XRB',
#  'FRN',
#  'NEVA',
#  'XTO',
#  'KEY',
#  'PRIMU',
#  'NSR',
#  'RC',
#  'XMCC',
#  'OPT',
#  'BIOS',
#  'CYC',
#  'CFD',
#  'BTCD',
#  'BURST',
#  'MANA',
#  'PEC',
#  'SGR',
#  'WORM',
#  'VC',
#  'BNTY',
#  'COV',
#  'KRB',
#  'HPB',
#  'MST',
#  'EVR',
#  'OST',
#  'STK',
#  'SANDG',
#  'VIA',
#  'IPY',
#  'RLT',
#  'WRC',
#  'MUE',
#  'XCPO',
#  'ABY',
#  'LET',
#  'DES',
#  'HT',
#  'ARDR',
#  'CEFS',
#  'MOJO',
#  'GUN',
#  'BTX',
#  'SPHTX',
#  'TRUE',
#  'ETHOS',
#  'MAC',
#  'RUBIT',
#  'VRM',
#  'UR',
#  'DOGE',
#  'BITB',
#  'BBR',
#  'PKB',
#  'PULSE',
#  'SCORE',
#  'BCD',
#  'CREA',
#  'FLO',
#  'PHR',
#  'BLN',
#  'BTW',
#  'EDRC',
#  'ERY',
#  'HNC',
#  'VLTC',
#  'NET',
#  'DSR',
#  'CESC',
#  'BSTAR',
#  'ATN',
#  'SAK',
#  'DGCS',
#  'MCAP',
#  'MLN',
#  'UGT',
#  'QSP',
#  'NTO',
#  'MONK',
#  'CFUN',
#  'HAT',
#  'ENG',
#  'KMD',
#  'APW',
#  'TOPAZ',
#  'HERO',
#  'RPC',
#  'BAT',
#  'CTR',
#  'LAZ',
#  'IRL',
#  'ELIX',
#  'GP',
#  'EQT',
#  'OFF',
#  'UTA',
#  'PCS',
#  'BTCA',
#  'PDC',
#  'PURA',
#  'BCDN',
#  'DAR',
#  'CME',
#  'DCN',
#  'FUEL',
#  'KCS',
#  'PXI',
#  'XCN',
#  'COUPE',
#  'SDP',
#  'TURBO',
#  'XCO',
#  'FAIR',
#  'YEL',
#  'TEL',
#  'STU',
#  'NGC',
#  'PIX',
#  'TOKC',
#  'VAL',
#  'NEWB',
#  'MSD',
#  'OS76',
#  'KBR',
#  'CNX',
#  'UBQ',
#  'XID',
#  'TOPC',
#  'NYAN',
#  'TRF',
#  'PCOIN',
#  'TIE',
#  'COR',
#  'OPAL',
#  'IDXM',
#  'MOON',
#  'DOT',
#  'POWR',
#  'VZT',
#  'QUN',
#  'DCT',
#  'SWTC',
#  'EREAL',
#  'OTX',
#  'CANDY',
#  'GMX',
#  'OXY',
#  'XSTC',
#  'VOLT',
#  'RADS',
#  'TLE',
#  'ANC',
#  'IETH',
#  'ARCT',
#  'DFT',
#  'BTE',
#  'BDL',
#  'BIRDS',
#  'MTN',
#  'GBC',
#  'QCN',
#  'XZC',
#  'EXCL',
#  'DAV',
#  'OBITS',
#  'MRT',
#  'BTCRED',
#  'REC',
#  'ATB',
#  'PCN',
#  'SHELL',
#  'CMT',
#  'AHT',
#  'BTB',
#  'BUMBA',
#  'TIME',
#  'MARS',
#  'GLT',
#  'DGPT',
#  'NXS',
#  'ZCL',
#  'ORME',
#  'PRIX',
#  'CYDER',
#  'GRWI',
#  'LTG',
#  'SBC',
#  'SLEVIN',
#  'RPX',
#  'SEQ',
#  'KORE',
#  'SWT',
#  'NEU',
#  'CRTM',
#  'CPN',
#  'LTC',
#  'HWC',
#  'GJC',
#  'AGLC',
#  'CCRB',
#  'SHIFT',
#  'TMC',
#  'IXT',
#  'MBL',
#  'NLC2',
#  'PSY',
#  'V',
#  'ELF',
#  'SUR',
#  'IOP',
#  'NUMUS',
#  'BITSILVER',
#  'EMC2',
#  'CRB',
#  'C20',
#  'MAR',
#  '808',
#  'OMG',
#  'ZEIT',
#  'PIRL',
#  'BCA',
#  'CNO',
#  'BTG',
#  'FLIXX',
#  'BLOCK',
#  'HOLD',
#  'LTCR',
#  'POLL',
#  'ZLA',
#  'TRIG',
#  'OC',
#  'DRXNE',
#  'XPD',
#  'NEBL',
#  'APPC',
#  'SSS',
#  'ZEN',
#  'STX',
#  'LEO',
#  'INK',
#  '8BIT',
#  'SEND',
#  'TX',
#  'MTX',
#  'VOISE',
#  'SKR',
#  'DLT',
#  'BTCR',
#  'GIM',
#  'DDF',
#  'NXC',
#  'ACT',
#  'SCL',
#  'GNT',
#  'NOX',
#  'VASH',
#  'SPT',
#  'STRC',
#  'DIME',
#  'SLS',
#  'SWFTC',
#  'EBET',
#  'BNT',
#  'CARBON',
#  'UNRC',
#  'BXC',
#  'XRP',
#  'MSCN',
#  'BRO',
#  'TGT',
#  'XLM',
#  'FAZZ',
#  'HST',
#  'FLT',
#  'UNIFY',
#  'SMART',
#  'TRIA',
#  'BTDX',
#  'UNI',
#  'QRL',
#  'JS',
#  'BIOB',
#  'VOT',
#  'ITT',
#  'EXRN',
#  'METAL',
#  'TOK',
#  'WAND',
#  'COVAL',
#  'OPES',
#  'ENRG',
#  'MCI',
#  'PAYP',
#  'INT',
#  'MDA',
#  'DSH',
#  'DYN',
#  'BTO',
#  'EBST',
#  'LANA',
#  'TAJ',
#  'PGL',
#  'MONA',
#  'POSW',
#  'CAB',
#  'ANTX',
#  'GNO',
#  'ETG',
#  'ZIL',
#  'MAN',
#  'SHND',
#  'SOC',
#  'DISK',
#  'WCT',
#  'ANT',
#  'DPY',
#  'ECA',
#  'TAGR',
#  'CVC',
#  'EUC',
#  'RBY',
#  'GAS',
#  'BCX',
#  'GSR',
#  'PLC',
#  'DBTC',
#  'MAG',
#  'QWARK',
#  'PLR',
#  'ZRC',
#  'CRDNC',
#  'CL',
#  'UIP',
#  'DBG',
#  'MCR',
#  'KNC',
#  'SND',
#  'UNB',
#  'DASH',
#  'SDRN',
#  'WILD',
#  'OAX',
#  'UNIC',
#  'FLAP',
#  'BSTY',
#  'BRX',
#  'HMP',
#  'UQC',
#  'TYCHO',
#  'KEK',
#  'CHSB',
#  'LVPS',
#  'VUC',
#  'SIC',
#  'JET',
#  'WAVES',
#  'PPC',
#  'HONEY',
#  'PEX',
#  'ART',
#  'MYB',
#  'TSL',
#  'ELTCOIN',
#  'HYP',
#  'DTB',
#  'FRCT',
#  'INCNT',
#  'NVST',
#  'EBCH',
#  'DMC',
#  'OTN',
#  'PZM',
#  'DALC',
#  'WINK',
#  'PYLNT',
#  'ADX',
#  'CACH',
#  'ASTRO',
#  'FRGC',
#  'RHFC',
#  'IMS',
#  'DOPE',
#  'BEST',
#  'HTML5',
#  'EFYT',
#  'PLU',
#  'IMPS',
#  'ARG',
#  'TELL',
#  'MGM',
#  'ATL',
#  'TODAY',
#  'PND',
#  'ATMS',
#  'GLC',
#  'ING',
#  'LIR',
#  'YAC',
#  'MND',
#  'ASN',
#  'MTL',
#  'CLD',
#  'OK',
#  'RLC',
#  'BITUSD',
#  'ETC',
#  'CANN',
#  'ETHD',
#  ...]

# %% [markdown]
# Other parameters:

# %%
print(cmc.ticker.__doc__)
# Out:
# Get currencies with other aditional data.
#
#         Args:
#             currency (str, optional): Specify a currency to return,
#                 in this case the method returns a dict, otherwise
#                 returns a list. If you dont specify a currency,
#                 returns data for all in coinmarketcap. As default, None.
#             limit (int, optional): Limit amount of coins on response.
#                 if limit == 0, returns all coins in coinmarketcap.
#                 Only works if currency == None. As default 0.
#             start (int, optional): Rank of first currency to retrieve.
#                 The count starts at 0 for the first currency ranked.
#                 Only works if currency == None. As default 0.
#             convert (str, optional): As default, "USD". Allow to
#                 convert price, 24h volume and market cap in terms
#                 of one of next badges:
#                    ["AUD", "BRL", "CAD", "CHF", "CLP", "CNY", "CZK", "DKK",
#                     "EUR", "GBP", "HKD", "HUF", "IDR", "ILS", "INR", "JPY",
#                     "KRW", "MXN", "MYR", "NOK", "NZD", "PHP", "PKR", "PLN",
#                     "RUB", "SEK", "SGD", "THB", "TRY", "TWD", "ZAR"]
#
#         Returns:
#             dict/list: If currency param is provided or not.

# %% [markdown]
# If you want to get the valid badges that can be passed to `convert` param programatically, use this:

# %%
cmc.ticker_badges
# Out:
# ['AUD',
#  'BRL',
#  'CAD',
#  'CHF',
#  'CLP',
#  'CNY',
#  'CZK',
#  'DKK',
#  'EUR',
#  'GBP',
#  'HKD',
#  'HUF',
#  'IDR',
#  'ILS',
#  'INR',
#  'JPY',
#  'KRW',
#  'MXN',
#  'MYR',
#  'NOK',
#  'NZD',
#  'PHP',
#  'PKR',
#  'PLN',
#  'RUB',
#  'SEK',
#  'SGD',
#  'THB',
#  'TRY',
#  'TWD',
#  'ZAR']

# %% [markdown]
# #### `stats()`

# %%
cmc.stats()
# Out:
# {'active_assets': 593,
#  'active_currencies': 888,
#  'active_markets': 8659,
#  'bitcoin_percentage_of_market_cap': 34.63,
#  'last_updated': 1518200366,
#  'total_24h_volume_usd': 24383674732.0,
#  'total_market_cap_usd': 423626964192.0}

# %% [markdown]
# _____________________________________________
#
# ## Web scraper
# #### `markets(currency, [convert="USD"])`
# Get all markets for a exchange in coinmarketcap. You can convert the response fields `"volume_24h"` and `"price"` between `"USD"` and `"BTC"`.

# %%
cmc.markets("BTC", convert="BTC")
# Out:
# [{'pair': 'BTC/USD',
#   'percent_volume': 7.05636650261,
#   'price': 1.00354,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 67568.6},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 5.788493243,
#   'price': 1.00273,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 55428.1},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0,
#   'price': 0.897044,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 55294.8},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 4.48596252662,
#   'price': 1.00073,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 42955.6},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 3.82597865197,
#   'price': 1.00283,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 36635.8},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 3.2682703763,
#   'price': 1.03955,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 31295.5},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 3.12257668564,
#   'price': 1.00272,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 29900.4},
#  {'pair': 'BTC/USD',
#   'percent_volume': 3.06797915739,
#   'price': 0.999338,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 29377.6},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 2.90616012226,
#   'price': 0.999736,
#   'source': 'bitFlyer',
#   'updated': True,
#   'volume_24h': 27828.1},
#  {'pair': 'BTC/USD',
#   'percent_volume': 2.15063959855,
#   'price': 1.00288,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 20593.5},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 1.60082552137,
#   'price': 1.00215,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 15328.7},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 1.59083743487,
#   'price': 1.03108,
#   'source': 'Bithumb',
#   'updated': True,
#   'volume_24h': 15233.2},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 1.43539633449,
#   'price': 0.999931,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 13744.8},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 1.42664773343,
#   'price': 1.01092,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 13661.0},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 1.26260243806,
#   'price': 0.993612,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 12090.1},
#  {'pair': 'BTC/USD',
#   'percent_volume': 1.1570777025,
#   'price': 1.00251,
#   'source': 'Gemini',
#   'updated': True,
#   'volume_24h': 11079.7},
#  {'pair': 'BTC/USD',
#   'percent_volume': 1.13520379307,
#   'price': 1.00163,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 10870.2},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0,
#   'price': 1.00568,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 10717.8},
#  {'pair': 'HT/BTC',
#   'percent_volume': 1.04256850263,
#   'price': 1.00431,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 9983.17},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.873229521414,
#   'price': 1.00467,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 8361.66},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.869424421473,
#   'price': 0.97945,
#   'source': 'BTCC',
#   'updated': True,
#   'volume_24h': 8325.22},
#  {'pair': 'ICX/BTC',
#   'percent_volume': 0.0,
#   'price': 1.03033,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 8227.62},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.0,
#   'price': 0.946985,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 6502.58},
#  {'pair': 'BLZ/BTC',
#   'percent_volume': 0.0,
#   'price': 0.964168,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 6472.01},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.0,
#   'price': 1.22779,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 6330.83},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.582093647336,
#   'price': 1.00015,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 5573.87},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.538969181338,
#   'price': 1.00283,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 5160.93},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.532977532822,
#   'price': 0.999851,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 5103.56},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.492569104321,
#   'price': 1.00049,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 4716.63},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.486055187186,
#   'price': 1.00169,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 4654.25},
#  {'pair': 'VEN/BTC',
#   'percent_volume': 0.0,
#   'price': 1.00098,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 4387.33},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.44743980072,
#   'price': 0.999485,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 4284.49},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.441525168775,
#   'price': 1.00071,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 4227.84},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.441060662583,
#   'price': 1.0034,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 4223.4},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.404911009759,
#   'price': 1.00068,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 3877.25},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.403221458742,
#   'price': 1.00424,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 3861.07},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.387031131542,
#   'price': 1.00193,
#   'source': 'itBit',
#   'updated': True,
#   'volume_24h': 3706.04},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.37718985788,
#   'price': 1.00276,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 3611.8},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.370260773295,
#   'price': 1.03849,
#   'source': 'Coinone',
#   'updated': True,
#   'volume_24h': 3545.46},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.357976630284,
#   'price': 1.00751,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 3427.82},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0,
#   'price': 1.11234,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 3218.95},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.32573917857,
#   'price': 0.990009,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 3119.14},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.322381737446,
#   'price': 1.00975,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 3086.98},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.32086186356,
#   'price': 0.999683,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 3072.43},
#  {'pair': 'ELA/BTC',
#   'percent_volume': 0.309861731188,
#   'price': 1.00569,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 2967.1},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.296854354445,
#   'price': 1.00645,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 2842.55},
#  {'pair': 'ADA/BTC',
#   'percent_volume': 0.294039639466,
#   'price': 1.02635,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 2815.6},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.289294696687,
#   'price': 1.01403,
#   'source': 'CEX.IO',
#   'updated': True,
#   'volume_24h': 2770.16},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.281507599369,
#   'price': 1.0029,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 2695.59},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.280926364938,
#   'price': 1.07483,
#   'source': 'LakeBTC',
#   'updated': True,
#   'volume_24h': 2690.03},
#  {'pair': 'BNB/BTC',
#   'percent_volume': 0.0,
#   'price': 1.08879,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 2673.89},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.273341436118,
#   'price': 0.998121,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 2617.4},
#  {'pair': 'ADA/BTC',
#   'percent_volume': 0.0,
#   'price': 1.0202,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 2550.15},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.262918928026,
#   'price': 0.999941,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 2517.59},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.261437562426,
#   'price': 1.03738,
#   'source': 'Korbit',
#   'updated': True,
#   'volume_24h': 2503.41},
#  {'pair': 'ELF/BTC',
#   'percent_volume': 0.255071661512,
#   'price': 1.00271,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 2442.45},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.254986221254,
#   'price': 1.0034,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 2441.63},
#  {'pair': 'FUN/BTC',
#   'percent_volume': 0.0,
#   'price': 0.934619,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 2417.35},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.251028291556,
#   'price': 0.998565,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 2403.74},
#  {'pair': 'NANO/BTC',
#   'percent_volume': 0.0,
#   'price': 0.976529,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 2381.65},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0,
#   'price': 1.01242,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 2380.18},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.2436780226,
#   'price': 1.00717,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 2333.36},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.241438525133,
#   'price': 1.00751,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 2311.9},
#  {'pair': 'TRUE/BTC',
#   'percent_volume': 0.241377152553,
#   'price': 0.997346,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 2311.32},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0,
#   'price': 1.07536,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 2300.72},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0,
#   'price': 1.11605,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 2261.91},
#  {'pair': 'DGD/BTC',
#   'percent_volume': 0.0,
#   'price': 0.897678,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 2206.94},
#  {'pair': 'ADA/BTC',
#   'percent_volume': 0.221298691922,
#   'price': 1.02611,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 2119.06},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.206655916437,
#   'price': 0.998855,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 1978.85},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.206485035921,
#   'price': 0.999493,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1977.21},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.204729298788,
#   'price': 0.974791,
#   'source': 'CoinsBank',
#   'updated': True,
#   'volume_24h': 1960.39},
#  {'pair': 'NBT/BTC',
#   'percent_volume': 0.204163708348,
#   'price': 1.00428,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1954.99},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.202655868302,
#   'price': 1.0025,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 1940.54},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.201292434325,
#   'price': 1.0033,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1927.49},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.195419920817,
#   'price': 1.01015,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 1871.26},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.191156331604,
#   'price': 0.990392,
#   'source': 'CoinsBank',
#   'updated': True,
#   'volume_24h': 1830.43},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.183719419006,
#   'price': 1.02373,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1759.22},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.176837266393,
#   'price': 1.00838,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 1693.32},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.0,
#   'price': 1.04714,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 1670.53},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.172281254889,
#   'price': 1.01645,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 1649.69},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.162020000241,
#   'price': 1.01436,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 1551.43},
#  {'pair': 'SWFTC/BTC',
#   'percent_volume': 0.161953814125,
#   'price': 1.00709,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 1550.8},
#  {'pair': 'CTR/BTC',
#   'percent_volume': 0.0,
#   'price': 0.998212,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 1548.64},
#  {'pair': 'BTC/GBP',
#   'percent_volume': 0.16111625892,
#   'price': 1.00232,
#   'source': 'CoinsBank',
#   'updated': True,
#   'volume_24h': 1542.77},
#  {'pair': 'BTC/BITCNY',
#   'percent_volume': 0.158921286658,
#   'price': 1.05744,
#   'source': 'AEX',
#   'updated': True,
#   'volume_24h': 1521.76},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.15693329643,
#   'price': 1.00318,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1502.72},
#  {'pair': 'AE/BTC',
#   'percent_volume': 0.0,
#   'price': 0.950063,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 1488.33},
#  {'pair': 'WTC/BTC',
#   'percent_volume': 0.0,
#   'price': 1.01342,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 1459.8},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.152231675471,
#   'price': 0.993384,
#   'source': 'Coinbene',
#   'updated': True,
#   'volume_24h': 1457.7},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.148443422905,
#   'price': 0.998397,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 1421.43},
#  {'pair': 'BTC/TRY',
#   'percent_volume': 0.145672029748,
#   'price': 0.978923,
#   'source': 'Paribu',
#   'updated': True,
#   'volume_24h': 1394.9},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.145633521462,
#   'price': 1.00131,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 1394.52},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.145568538731,
#   'price': 1.0221,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1393.9},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.144968050157,
#   'price': 0.999201,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1388.15},
#  {'pair': 'AIDOC/BTC',
#   'percent_volume': 0.144733390294,
#   'price': 1.00396,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1385.9},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.137242325419,
#   'price': 0.994322,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 1314.17},
#  {'pair': 'EKT/BTC',
#   'percent_volume': 0.136166500199,
#   'price': 0.989393,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 1303.87},
#  {'pair': 'BTC/PLN',
#   'percent_volume': 0.135698383855,
#   'price': 0.997663,
#   'source': 'BitBay',
#   'updated': True,
#   'volume_24h': 1299.38},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.135084658058,
#   'price': 0.999215,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 1293.51},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.134991997497,
#   'price': 0.998544,
#   'source': 'Bitbank',
#   'updated': True,
#   'volume_24h': 1292.62},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.133975138088,
#   'price': 0.998199,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 1282.89},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.129230195309,
#   'price': 0.998695,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 1237.45},
#  {'pair': 'IOST/BTC',
#   'percent_volume': 0.0,
#   'price': 1.07813,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 1235.85},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.12739262807,
#   'price': 0.996085,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1219.85},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.124120627204,
#   'price': 0.999683,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 1188.52},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.124076101999,
#   'price': 1.01436,
#   'source': 'Liqui',
#   'updated': True,
#   'volume_24h': 1188.09},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.121580283758,
#   'price': 1.01153,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1164.2},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0,
#   'price': 1.21236,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 1142.87},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.117629694702,
#   'price': 1.00871,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 1126.37},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.116720297477,
#   'price': 1.00116,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 1117.66},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.111611812417,
#   'price': 0.999737,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 1068.75},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.111439848855,
#   'price': 1.0013,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 1067.1},
#  {'pair': 'EPC/BTC',
#   'percent_volume': 0.110137546782,
#   'price': 0.997862,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 1054.63},
#  {'pair': 'STR/BTC',
#   'percent_volume': 0.1097890468,
#   'price': 1.02076,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 1051.29},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.109573400402,
#   'price': 0.998044,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1049.23},
#  {'pair': 'CND/BTC',
#   'percent_volume': 0.0,
#   'price': 1.0291,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 1036.73},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.108042696061,
#   'price': 1.00331,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 1034.57},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.10791934921,
#   'price': 1.00527,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 1033.39},
#  {'pair': 'WAVES/BTC',
#   'percent_volume': 0.107903103527,
#   'price': 1.0105,
#   'source': 'Tidex',
#   'updated': True,
#   'volume_24h': 1033.23},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.107444493917,
#   'price': 0.999383,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 1028.84},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.107240159328,
#   'price': 1.01176,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 1026.88},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.102029627312,
#   'price': 1.00318,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 976.99},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.100334300052,
#   'price': 1.0018,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 960.757},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0992029988327,
#   'price': 0.998698,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 949.924},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.0991285093683,
#   'price': 1.0221,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 949.21},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0973555638455,
#   'price': 0.99653,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 932.234},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0962515794414,
#   'price': 1.00682,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 921.663},
#  {'pair': 'MTL/BTC',
#   'percent_volume': 0.0,
#   'price': 0.980268,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 914.385},
#  {'pair': 'IOTA/BTC',
#   'percent_volume': 0.0,
#   'price': 1.06948,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 913.959},
#  {'pair': 'IGNIS/BTC',
#   'percent_volume': 0.0950828529826,
#   'price': 1.01055,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 910.472},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0943544446985,
#   'price': 1.00289,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 903.497},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0941669574844,
#   'price': 1.00646,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 901.701},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0938825978652,
#   'price': 0.999474,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 898.978},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0938333794631,
#   'price': 1.00526,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 898.507},
#  {'pair': 'XVG/BTC',
#   'percent_volume': 0.0,
#   'price': 1.03842,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 889.324},
#  {'pair': 'BTC/RUB',
#   'percent_volume': 0.0926517767964,
#   'price': 0.948469,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 887.193},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0923715086824,
#   'price': 1.00397,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 884.508},
#  {'pair': 'QSP/BTC',
#   'percent_volume': 0.0,
#   'price': 1.02072,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 872.231},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0905923055632,
#   'price': 1.01481,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 867.472},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0901291230941,
#   'price': 1.00541,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 863.037},
#  {'pair': 'BTC/BRL',
#   'percent_volume': 0.0888424650116,
#   'price': 0.998578,
#   'source': 'Negocie Coins',
#   'updated': True,
#   'volume_24h': 850.716},
#  {'pair': 'INS/BTC',
#   'percent_volume': 0.0,
#   'price': 1.03234,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 837.187},
#  {'pair': 'SC/BTC',
#   'percent_volume': 0.0863105452533,
#   'price': 1.00427,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 826.472},
#  {'pair': 'BTC/ZAR',
#   'percent_volume': 0.0862129508177,
#   'price': 1.03726,
#   'source': 'Luno',
#   'updated': True,
#   'volume_24h': 825.537},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.0850865834727,
#   'price': 0.987346,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 814.751},
#  {'pair': 'ARDR/BTC',
#   'percent_volume': 0.084909325022,
#   'price': 1.02555,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 813.054},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0840922273433,
#   'price': 0.993832,
#   'source': 'Neraex',
#   'updated': True,
#   'volume_24h': 805.23},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0840264022431,
#   'price': 1.00485,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 804.599},
#  {'pair': 'MIOTA/BTC',
#   'percent_volume': 0.0838807927893,
#   'price': 1.00125,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 803.206},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0837680357164,
#   'price': 1.02006,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 802.126},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0834254323157,
#   'price': 1.00237,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 798.844},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0825364926172,
#   'price': 1.00029,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 790.333},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0820125392604,
#   'price': 1.00015,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 785.316},
#  {'pair': 'STK/BTC',
#   'percent_volume': 0.0812083177896,
#   'price': 0.992436,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 777.615},
#  {'pair': 'ARDR/BTC',
#   'percent_volume': 0.0811930348139,
#   'price': 1.02555,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 777.469},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0,
#   'price': 1.29083,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 776.515},
#  {'pair': 'RUFF/BTC',
#   'percent_volume': 0.0799131156813,
#   'price': 1.0143,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 765.213},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0790786892742,
#   'price': 0.998206,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 757.222},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0,
#   'price': 0.95581,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 750.414},
#  {'pair': 'PROPY/BTC',
#   'percent_volume': 0.0777720550187,
#   'price': 1.00427,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 744.711},
#  {'pair': 'SC/BTC',
#   'percent_volume': 0.0775358307561,
#   'price': 1.00777,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 742.449},
#  {'pair': 'XVG/BTC',
#   'percent_volume': 0.0773958772067,
#   'price': 1.00261,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 741.109},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0770929854752,
#   'price': 1.00008,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 738.208},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0767601294841,
#   'price': 1.00007,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 735.021},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0758973032166,
#   'price': 1.00883,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 726.759},
#  {'pair': 'INS/BTC',
#   'percent_volume': 0.075852537335,
#   'price': 0.99697,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 726.33},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0757253396551,
#   'price': 1.00252,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 725.113},
#  {'pair': 'IOST/BTC',
#   'percent_volume': 0.075236645447,
#   'price': 1.00056,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 720.433},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0742381978122,
#   'price': 1.00167,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 710.872},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0740102768986,
#   'price': 0.997188,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 708.689},
#  {'pair': 'RUFF/BTC',
#   'percent_volume': 0.0737507069881,
#   'price': 1.04679,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 706.204},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.0729118280605,
#   'price': 1.01255,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 698.172},
#  {'pair': 'BTC/AUD',
#   'percent_volume': 0.072292085344,
#   'price': 0.99403,
#   'source': 'BTC Markets',
#   'updated': True,
#   'volume_24h': 692.237},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0713254070446,
#   'price': 0.981523,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 682.981},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.071317224034,
#   'price': 0.994905,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 682.902},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0710287729094,
#   'price': 1.01041,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 680.14},
#  {'pair': 'BTC/IDR',
#   'percent_volume': 0.0709492292326,
#   'price': 0.99181,
#   'source': 'Bitcoin Indonesia',
#   'updated': True,
#   'volume_24h': 679.378},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.07029627312,
#   'price': 0.999445,
#   'source': 'Tidex',
#   'updated': True,
#   'volume_24h': 673.126},
#  {'pair': 'IGNIS/BTC',
#   'percent_volume': 0.0701388705039,
#   'price': 1.01055,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 671.618},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0700120338392,
#   'price': 0.995444,
#   'source': 'Gate.io',
#   'updated': True,
#   'volume_24h': 670.405},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0691191229738,
#   'price': 1.00053,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 661.854},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0685195971071,
#   'price': 0.98929,
#   'source': 'bitFlyer',
#   'updated': True,
#   'volume_24h': 656.114},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.067868325732,
#   'price': 1.00757,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 649.877},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.0678235598503,
#   'price': 0.999071,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 649.448},
#  {'pair': 'MDS/BTC',
#   'percent_volume': 0.067499849577,
#   'price': 1.0042,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 646.348},
#  {'pair': 'BRD/BTC',
#   'percent_volume': 0.0,
#   'price': 1.0392,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 642.48},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0665598864006,
#   'price': 1.09367,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 637.348},
#  {'pair': 'PPT/BTC',
#   'percent_volume': 0.0,
#   'price': 0.9324,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 635.969},
#  {'pair': 'BTC/GBP',
#   'percent_volume': 0.0661359342471,
#   'price': 1.0107,
#   'source': 'Coinfloor',
#   'updated': True,
#   'volume_24h': 633.289},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0653191975836,
#   'price': 1.02373,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 625.468},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0650976546047,
#   'price': 1.00982,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 623.346},
#  {'pair': 'ZIL/BTC',
#   'percent_volume': 0.0649799636578,
#   'price': 1.00291,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 622.219},
#  {'pair': 'BCN/BTC',
#   'percent_volume': 0.0648295406684,
#   'price': 1.0031,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 620.779},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0646167823921,
#   'price': 0.999383,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 618.742},
#  {'pair': 'LET/BTC',
#   'percent_volume': 0.0643945173829,
#   'price': 0.998179,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 616.613},
#  {'pair': 'BTC/CAD',
#   'percent_volume': 0.0635217030289,
#   'price': 1.01549,
#   'source': 'Coinsquare',
#   'updated': True,
#   'volume_24h': 608.256},
#  {'pair': 'POWR/BTC',
#   'percent_volume': 0.0,
#   'price': 1.03149,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 604.889},
#  {'pair': 'POE/BTC',
#   'percent_volume': 0.0,
#   'price': 1.10595,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 597.68},
#  {'pair': 'THETA/BTC',
#   'percent_volume': 0.0623311953212,
#   'price': 1.00121,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 596.856},
#  {'pair': 'ZRX/BTC',
#   'percent_volume': 0.0,
#   'price': 1.00949,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 595.246},
#  {'pair': 'QBT/BTC',
#   'percent_volume': 0.0620005054212,
#   'price': 1.02665,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 593.69},
#  {'pair': 'JNT/BTC',
#   'percent_volume': 0.0614210760659,
#   'price': 1.01101,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 588.141},
#  {'pair': 'BTS/BTC',
#   'percent_volume': 0.0,
#   'price': 1.0784,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 587.611},
#  {'pair': 'OC/BTC',
#   'percent_volume': 0.060700730454,
#   'price': 0.984805,
#   'source': 'Allcoin',
#   'updated': True,
#   'volume_24h': 581.243},
#  {'pair': 'BTC/CAD',
#   'percent_volume': 0.0605949530079,
#   'price': 0.951022,
#   'source': 'QuadrigaCX',
#   'updated': True,
#   'volume_24h': 580.231},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.059843560091,
#   'price': 0.988737,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 573.035},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0598381448634,
#   'price': 1.00776,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 572.983},
#  {'pair': 'BTC/GBP',
#   'percent_volume': 0.0597838722488,
#   'price': 1.00742,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 572.464},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0595354938086,
#   'price': 1.01538,
#   'source': 'GetBTC',
#   'updated': True,
#   'volume_24h': 570.086},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0593684641211,
#   'price': 1.01253,
#   'source': 'GetBTC',
#   'updated': True,
#   'volume_24h': 568.486},
#  {'pair': 'BQX/BTC',
#   'percent_volume': 0.0,
#   'price': 1.08618,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 565.733},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0589957761225,
#   'price': 1.0129,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 564.918},
#  {'pair': 'BTC/RUB',
#   'percent_volume': 0.0587157486853,
#   'price': 1.0014,
#   'source': 'GetBTC',
#   'updated': True,
#   'volume_24h': 562.236},
#  {'pair': 'ICX/BTC',
#   'percent_volume': 0.0585599104682,
#   'price': 1.00111,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 560.744},
#  {'pair': 'VIBE/BTC',
#   'percent_volume': 0.0,
#   'price': 0.997138,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 560.52},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0585299462087,
#   'price': 1.00521,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 560.457},
#  {'pair': 'XVG/BTC',
#   'percent_volume': 0.0573677180231,
#   'price': 1.00412,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 549.328},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0570771008075,
#   'price': 1.00732,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 546.545},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0567542329029,
#   'price': 1.01064,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 543.453},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0567011636722,
#   'price': 0.995244,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 542.946},
#  {'pair': 'SRN/BTC',
#   'percent_volume': 0.0565986353626,
#   'price': 1.00367,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 541.963},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0,
#   'price': 1.18004,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 534.487},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0549146199112,
#   'price': 1.00516,
#   'source': 'xBTCe',
#   'updated': True,
#   'volume_24h': 525.838},
#  {'pair': 'BTC/BRL',
#   'percent_volume': 0.0546323060446,
#   'price': 1.00944,
#   'source': 'Foxbit',
#   'updated': True,
#   'volume_24h': 523.135},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0542576926317,
#   'price': 1.10838,
#   'source': 'CoolCoin',
#   'updated': True,
#   'volume_24h': 519.548},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0540976425709,
#   'price': 1.00956,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 518.015},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0540353072841,
#   'price': 0.996224,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 517.418},
#  {'pair': 'VEN/BTC',
#   'percent_volume': 0.054022070061,
#   'price': 1.00087,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 517.291},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0537905389957,
#   'price': 0.998984,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 515.075},
#  {'pair': 'ADX/BTC',
#   'percent_volume': 0.0,
#   'price': 1.02998,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 514.43},
#  {'pair': 'WAVES/BTC',
#   'percent_volume': 0.0533747698528,
#   'price': 1.0234,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 511.093},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.05328969061,
#   'price': 0.998367,
#   'source': 'Lbank',
#   'updated': True,
#   'volume_24h': 510.279},
#  {'pair': 'ZCL/BTC',
#   'percent_volume': 0.053249738264,
#   'price': 1.01649,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 509.896},
#  {'pair': 'BTC/ETH',
#   'percent_volume': 0.0527408272061,
#   'price': 1.03342,
#   'source': 'Mr. Exchange',
#   'updated': True,
#   'volume_24h': 505.022},
#  {'pair': 'DTA/BTC',
#   'percent_volume': 0.0525100181711,
#   'price': 1.00979,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 502.813},
#  {'pair': 'FCT/BTC',
#   'percent_volume': 0.0519745123287,
#   'price': 1.00939,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 497.685},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0511035030506,
#   'price': 1.00008,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 489.344},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0510577744618,
#   'price': 1.01015,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 488.906},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0,
#   'price': 1.1074,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 483.268},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0493263456841,
#   'price': 1.00277,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 472.328},
#  {'pair': 'MANA/BTC',
#   'percent_volume': 0.0492956593942,
#   'price': 0.986935,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 472.034},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0492418681332,
#   'price': 1.00114,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 471.519},
#  {'pair': 'GXS/BTC',
#   'percent_volume': 0.0488196007172,
#   'price': 0.993605,
#   'source': 'Gate.io',
#   'updated': True,
#   'volume_24h': 467.475},
#  {'pair': 'ACT/BTC',
#   'percent_volume': 0.0488168329342,
#   'price': 1.0042,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 467.448},
#  {'pair': 'WAVES/BTC',
#   'percent_volume': 0.048304432063,
#   'price': 1.00756,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 462.542},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0,
#   'price': 1.04115,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 455.06},
#  {'pair': 'BIX/BTC',
#   'percent_volume': 0.0474248787591,
#   'price': 1.00658,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 454.119},
#  {'pair': 'MANA/BTC',
#   'percent_volume': 0.0471933476937,
#   'price': 0.988301,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 451.902},
#  {'pair': 'STRAT/BTC',
#   'percent_volume': 0.0469140422869,
#   'price': 1.02505,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 449.228},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0466233047329,
#   'price': 1.00627,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 446.444},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.0465408729347,
#   'price': 1.00061,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 445.655},
#  {'pair': 'RISE/BTC',
#   'percent_volume': 0.0460590380149,
#   'price': 1.0048,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 441.041},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0458870744534,
#   'price': 1.00772,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 439.395},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0452926027991,
#   'price': 1.00866,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 433.702},
#  {'pair': 'BTC/THB',
#   'percent_volume': 0.0450199160038,
#   'price': 1.00492,
#   'source': 'BX Thailand',
#   'updated': True,
#   'volume_24h': 431.091},
#  {'pair': 'PIVX/BTC',
#   'percent_volume': 0.0449598671464,
#   'price': 1.02231,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 430.515},
#  {'pair': 'CTR/BTC',
#   'percent_volume': 0.0448844149749,
#   'price': 1.00529,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 429.794},
#  {'pair': 'VEN/BTC',
#   'percent_volume': 0.0447773138064,
#   'price': 0.995958,
#   'source': 'Lbank',
#   'updated': True,
#   'volume_24h': 428.768},
#  {'pair': 'MANA/BTC',
#   'percent_volume': 0.0,
#   'price': 1.10448,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 427.532},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0,
#   'price': 1.07009,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 427.471},
#  {'pair': 'ENG/BTC',
#   'percent_volume': 0.0,
#   'price': 1.28105,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 427.244},
#  {'pair': 'STRAT/BTC',
#   'percent_volume': 0.0,
#   'price': 1.1306,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 424.817},
#  {'pair': 'BTC/TRY',
#   'percent_volume': 0.0443351905558,
#   'price': 0.980427,
#   'source': 'BTCTurk',
#   'updated': True,
#   'volume_24h': 424.535},
#  {'pair': 'GXS/BTC',
#   'percent_volume': 0.0,
#   'price': 1.03532,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 421.966},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0440029362568,
#   'price': 0.996337,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 421.353},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.0438289269426,
#   'price': 1.03053,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 419.686},
#  {'pair': 'NKC/BTC',
#   'percent_volume': 0.0431884860227,
#   'price': 0.999889,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 413.553},
#  {'pair': 'GAS/BTC',
#   'percent_volume': 0.0,
#   'price': 0.98578,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 413.336},
#  {'pair': 'GNT/BTC',
#   'percent_volume': 0.0419668106716,
#   'price': 1.00176,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 401.855},
#  {'pair': 'ADK/BTC',
#   'percent_volume': 0.0414842537215,
#   'price': 1.00485,
#   'source': 'AidosMarket',
#   'updated': True,
#   'volume_24h': 397.235},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 0.960116,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 397.21},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.0414181879445,
#   'price': 0.981337,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 396.602},
#  {'pair': 'SUB/BTC',
#   'percent_volume': 0.0,
#   'price': 1.1658,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 383.505},
#  {'pair': 'AION/BTC',
#   'percent_volume': 0.0,
#   'price': 1.00237,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 381.612},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0397085404156,
#   'price': 1.03585,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 380.232},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0393677420908,
#   'price': 1.00702,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 376.968},
#  {'pair': 'ITC/BTC',
#   'percent_volume': 0.0393449981348,
#   'price': 1.00853,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 376.751},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0391894005945,
#   'price': 1.01158,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 375.261},
#  {'pair': 'NBT/BTC',
#   'percent_volume': 0.039176644725,
#   'price': 1.00428,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 375.138},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.039147161819,
#   'price': 1.00547,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 374.856},
#  {'pair': 'CVC/BTC',
#   'percent_volume': 0.0388755580693,
#   'price': 1.00267,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 372.255},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0387957737157,
#   'price': 0.999233,
#   'source': 'BtcTrade.im',
#   'updated': True,
#   'volume_24h': 371.491},
#  {'pair': 'RISE/BTC',
#   'percent_volume': 0.0387248944031,
#   'price': 1.01168,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 370.812},
#  {'pair': 'BTC/PEN',
#   'percent_volume': 0.0,
#   'price': 0.963109,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 370.784},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0386836183348,
#   'price': 1.00341,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 370.417},
#  {'pair': 'RLC/BTC',
#   'percent_volume': 0.0384392110615,
#   'price': 1.00533,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 368.077},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0380919144635,
#   'price': 0.99325,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 364.752},
#  {'pair': 'MEE/BTC',
#   'percent_volume': 0.037993116644,
#   'price': 1.00416,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 363.805},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0378813222782,
#   'price': 1.20272,
#   'source': 'BtcTrade.im',
#   'updated': True,
#   'volume_24h': 362.734},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.0378460631295,
#   'price': 0.980669,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 362.398},
#  {'pair': 'WINGS/BTC',
#   'percent_volume': 0.0,
#   'price': 1.04187,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 361.252},
#  {'pair': 'VIB/BTC',
#   'percent_volume': 0.0374567684328,
#   'price': 1.00684,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 358.67},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.0,
#   'price': 1.20957,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 358.487},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0371201819516,
#   'price': 1.0041,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 355.447},
#  {'pair': 'MTN/BTC',
#   'percent_volume': 0.0368973152505,
#   'price': 1.00176,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 353.312},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0368045343506,
#   'price': 0.985872,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 352.425},
#  {'pair': 'STEEM/BTC',
#   'percent_volume': 0.0367609718529,
#   'price': 1.0295,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 352.007},
#  {'pair': 'NAS/BTC',
#   'percent_volume': 0.0366014031456,
#   'price': 1.00056,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 350.479},
#  {'pair': 'KNC/BTC',
#   'percent_volume': 0.0,
#   'price': 1.03077,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 349.976},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.036456756399,
#   'price': 0.996945,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 349.093},
#  {'pair': 'PIVX/BTC',
#   'percent_volume': 0.036456154707,
#   'price': 1.02231,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 349.088},
#  {'pair': 'STEEM/BTC',
#   'percent_volume': 0.0361930949831,
#   'price': 1.02952,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 346.569},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0361762476083,
#   'price': 1.03802,
#   'source': 'Allcoin',
#   'updated': True,
#   'volume_24h': 346.408},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0360704701621,
#   'price': 0.991747,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 345.395},
#  {'pair': 'LBTC/BTC',
#   'percent_volume': 0.0358500102288,
#   'price': 0.989016,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 343.284},
#  {'pair': 'SNT/BTC',
#   'percent_volume': 0.0,
#   'price': 0.970235,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 342.784},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0357912850937,
#   'price': 0.99962,
#   'source': 'BtcTrade.im',
#   'updated': True,
#   'volume_24h': 342.722},
#  {'pair': 'ELF/BTC',
#   'percent_volume': 0.0,
#   'price': 1.01823,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 342.687},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0357616818494,
#   'price': 0.997043,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 342.438},
#  {'pair': 'DGB/BTC',
#   'percent_volume': 0.0354959746808,
#   'price': 0.999726,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 339.893},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0352017473134,
#   'price': 1.00246,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 337.076},
#  {'pair': 'ORME/BTC',
#   'percent_volume': 0.0350000601692,
#   'price': 1.00341,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 335.145},
#  {'pair': 'BTC/MXN',
#   'percent_volume': 0.0345992129869,
#   'price': 0.995603,
#   'source': 'Bitso',
#   'updated': True,
#   'volume_24h': 331.307},
#  {'pair': 'SRN/BTC',
#   'percent_volume': 0.0343925919686,
#   'price': 1.01116,
#   'source': 'Liqui',
#   'updated': True,
#   'volume_24h': 329.329},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0343420498442,
#   'price': 0.997055,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 328.844},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0340823595952,
#   'price': 1.00459,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 326.358},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.0338276032203,
#   'price': 0.999853,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 323.918},
#  {'pair': 'BTM/BTC',
#   'percent_volume': 0.033807867724,
#   'price': 0.994829,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 323.729},
#  {'pair': 'BCD/BTC',
#   'percent_volume': 0.0,
#   'price': 0.933929,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 322.449},
#  {'pair': 'ELF/BTC',
#   'percent_volume': 0.0335158064477,
#   'price': 1.00044,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 320.932},
#  {'pair': 'BTC/BRL',
#   'percent_volume': 0.0,
#   'price': 0.975753,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 320.137},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.0332456467587,
#   'price': 1.03795,
#   'source': 'ZB.COM',
#   'updated': True,
#   'volume_24h': 318.345},
#  {'pair': 'SNC/BTC',
#   'percent_volume': 0.0331174863717,
#   'price': 1.00239,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 317.118},
#  {'pair': 'MANA/BTC',
#   'percent_volume': 0.0330440799528,
#   'price': 0.999367,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 316.415},
#  {'pair': 'XRB/BTC',
#   'percent_volume': 0.0,
#   'price': 1.14408,
#   'source': 'BitGrail',
#   'updated': False,
#   'volume_24h': 326.189},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.0328338487828,
#   'price': 1.03288,
#   'source': 'Coinnest',
#   'updated': True,
#   'volume_24h': 314.403},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0327265069375,
#   'price': 1.00192,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 313.374},
#  {'pair': 'RLC/BTC',
#   'percent_volume': 0.0325468417189,
#   'price': 1.00127,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 311.655},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0323472003273,
#   'price': 1.07281,
#   'source': 'BTC-Alpha',
#   'updated': True,
#   'volume_24h': 309.743},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0322102552377,
#   'price': 1.00513,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 308.432},
#  {'pair': 'BTC/CNY',
#   'percent_volume': 0.0,
#   'price': 0.962291,
#   'source': 'Bitinka',
#   'updated': False,
#   'volume_24h': 308.342},
#  {'pair': 'ADT/BTC',
#   'percent_volume': 0.0320859456793,
#   'price': 1.00125,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 307.241},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0319935257945,
#   'price': 1.00732,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 306.355},
#  {'pair': 'SOC/BTC',
#   'percent_volume': 0.0319656072877,
#   'price': 1.0033,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 306.088},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.0318301062588,
#   'price': 1.01211,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 304.791},
#  {'pair': 'BTC/BRL',
#   'percent_volume': 0.0316023056836,
#   'price': 0.995166,
#   'source': 'Mercado Bitcoin',
#   'updated': True,
#   'volume_24h': 302.61},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0316011022997,
#   'price': 0.955205,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 302.599},
#  {'pair': 'HPB/BTC',
#   'percent_volume': 0.0314878638732,
#   'price': 1.00594,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 301.514},
#  {'pair': 'LBTC/BTC',
#   'percent_volume': 0.0314152998231,
#   'price': 0.985762,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 300.819},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0312263685484,
#   'price': 1.02154,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 299.01},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0308038604556,
#   'price': 1.00664,
#   'source': 'BL3P',
#   'updated': True,
#   'volume_24h': 294.964},
#  {'pair': 'SXUT/BTC',
#   'percent_volume': 0.0307692029988,
#   'price': 1.00236,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 294.632},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0304882128545,
#   'price': 1.00942,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 291.942},
#  {'pair': 'WABI/BTC',
#   'percent_volume': 0.0,
#   'price': 1.59962,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 286.814},
#  {'pair': 'XDN/BTC',
#   'percent_volume': 0.0298998784582,
#   'price': 0.962938,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 286.308},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.0298651006631,
#   'price': 1.00159,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 285.975},
#  {'pair': 'DSH/BTC',
#   'percent_volume': 0.0295830274733,
#   'price': 1.00841,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 283.274},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0292324817386,
#   'price': 0.998438,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 279.917},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0292034801863,
#   'price': 0.985892,
#   'source': 'ZB.COM',
#   'updated': True,
#   'volume_24h': 279.639},
#  {'pair': 'GAS/BTC',
#   'percent_volume': 0.0290487250147,
#   'price': 1.00485,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 278.157},
#  {'pair': 'SNC/BTC',
#   'percent_volume': 0.029014067558,
#   'price': 1.01691,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 277.826},
#  {'pair': 'MANA/BTC',
#   'percent_volume': 0.0288614784775,
#   'price': 1.00147,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 276.364},
#  {'pair': 'ADX/BTC',
#   'percent_volume': 0.02874607396,
#   'price': 1.00577,
#   'source': 'Liqui',
#   'updated': True,
#   'volume_24h': 275.26},
#  {'pair': 'QUN/BTC',
#   'percent_volume': 0.0285753137824,
#   'price': 1.00269,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 273.624},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0284650838157,
#   'price': 1.00283,
#   'source': 'C2CX',
#   'updated': True,
#   'volume_24h': 272.569},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.0284117739082,
#   'price': 1.02726,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 272.058},
#  {'pair': 'TKY/BTC',
#   'percent_volume': 0.0283512436973,
#   'price': 1.00567,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 271.479},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0282890287488,
#   'price': 0.99745,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 270.884},
#  {'pair': 'LEND/BTC',
#   'percent_volume': 0.0,
#   'price': 1.04465,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 270.382},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0282197138353,
#   'price': 1.00187,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 270.219},
#  {'pair': 'APPC/BTC',
#   'percent_volume': 0.0,
#   'price': 1.10466,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 267.231},
#  {'pair': 'ICX/BTC',
#   'percent_volume': 0.0276382387273,
#   'price': 1.00642,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 264.652},
#  {'pair': 'NXT/BTC',
#   'percent_volume': 0.0275369138016,
#   'price': 1.00664,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 263.681},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0274740971612,
#   'price': 0.997582,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 263.08},
#  {'pair': 'OST/BTC',
#   'percent_volume': 0.0,
#   'price': 1.02734,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 263.055},
#  {'pair': 'TRIG/BTC',
#   'percent_volume': 0.0,
#   'price': 0.951387,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 260.754},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0271395564327,
#   'price': 1.00247,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 259.876},
#  {'pair': 'NEBL/BTC',
#   'percent_volume': 0.0,
#   'price': 1.16848,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 259.816},
#  {'pair': 'IOTA/BTC',
#   'percent_volume': 0.0268875678408,
#   'price': 1.00906,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 257.463},
#  {'pair': 'ENJ/BTC',
#   'percent_volume': 0.0,
#   'price': 1.03126,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 257.024},
#  {'pair': 'NULS/BTC',
#   'percent_volume': 0.0,
#   'price': 0.987663,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 256.636},
#  {'pair': 'STORJ/BTC',
#   'percent_volume': 0.0265131951046,
#   'price': 1.01218,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 253.879},
#  {'pair': 'REQ/BTC',
#   'percent_volume': 0.0,
#   'price': 1.06794,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 253.378},
#  {'pair': 'SYS/BTC',
#   'percent_volume': 0.0264295599225,
#   'price': 0.995632,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 253.078},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0262750454277,
#   'price': 1.00842,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 251.598},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0,
#   'price': 1.07543,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 251.465},
#  {'pair': 'SNT/BTC',
#   'percent_volume': 0.0262406286478,
#   'price': 1.03008,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 251.269},
#  {'pair': 'BTC/PLN',
#   'percent_volume': 0.026071673546,
#   'price': 1.00106,
#   'source': 'BitMarket',
#   'updated': True,
#   'volume_24h': 249.651},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.0260443567311,
#   'price': 0.993926,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 249.389},
#  {'pair': 'VIB/BTC',
#   'percent_volume': 0.0,
#   'price': 1.07046,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 249.151},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0257798529465,
#   'price': 1.0015,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 246.856},
#  {'pair': 'ACT/BTC',
#   'percent_volume': 0.025661680646,
#   'price': 1.00545,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 245.725},
#  {'pair': 'ADX/BTC',
#   'percent_volume': 0.0256378536444,
#   'price': 1.00524,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 245.497},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0256142673197,
#   'price': 0.995153,
#   'source': 'Bitonic',
#   'updated': True,
#   'volume_24h': 245.271},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0255793691862,
#   'price': 1.00137,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 244.937},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 1.00205,
#   'source': 'BitMEX',
#   'updated': True,
#   'volume_24h': 209858.0},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 0.998688,
#   'source': 'Zaif',
#   'updated': True,
#   'volume_24h': 16507.2},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 0.997621,
#   'source': 'Fisco',
#   'updated': True,
#   'volume_24h': 16491.0},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 1.0026,
#   'source': 'Quoine',
#   'updated': True,
#   'volume_24h': 15045.5},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 0.982654,
#   'source': 'BTCBOX',
#   'updated': True,
#   'volume_24h': 14811.7},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0,
#   'price': 0.993469,
#   'source': 'ZB.COM',
#   'updated': True,
#   'volume_24h': 3024.95},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 1.00347,
#   'source': 'Quoine',
#   'updated': True,
#   'volume_24h': 1857.09},
#  {'pair': 'BTC/AUD',
#   'percent_volume': 0.0,
#   'price': 1.00276,
#   'source': 'ACX',
#   'updated': True,
#   'volume_24h': 620.528},
#  {'pair': 'BTC/SGD',
#   'percent_volume': 0.0,
#   'price': 1.00334,
#   'source': 'Quoine',
#   'updated': True,
#   'volume_24h': 470.84},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.0,
#   'price': 1.03325,
#   'source': 'GOPAX',
#   'updated': True,
#   'volume_24h': 463.825},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 0.996885,
#   'source': 'bitFlyer',
#   'updated': True,
#   'volume_24h': 448.249},
#  {'pair': 'BTC/XRP',
#   'percent_volume': 0.0,
#   'price': 1.01502e-08,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 1869.26},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0,
#   'price': 1.23652,
#   'source': 'Binance',
#   'updated': False,
#   'volume_24h': 650.887},
#  {'pair': 'BTC/LTC',
#   'percent_volume': 0.0,
#   'price': 0.000326988,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 349.913},
#  {'pair': 'BTC/ETH',
#   'percent_volume': 0.0,
#   'price': 0.00991433,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 327.375}]

# %% [markdown]
# #### `ranks([convert="USD"])`
# Get gainers and losers rankings:

# %%
cmc.ranks()
# Out:
# {'gainers': {'1h': [{'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0},
#    {'name': 'Global Jobcoin',
#     'percent_change': 131.03,
#     'price': 0.590621,
#     'symbol': 'GJC',
#     'volume_24h': 57251.0}],
#   '24h': [{'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0},
#    {'name': 'E-coin',
#     'percent_change': 824.62,
#     'price': 62.4147,
#     'symbol': 'ECN',
#     'volume_24h': 489519.0}],
#   '7d': [{'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0},
#    {'name': 'Unity Ingot',
#     'percent_change': 1159.91,
#     'price': 0.0342185,
#     'symbol': 'UNY',
#     'volume_24h': 2177590.0}]},
#  'losers': {'1h': [{'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5},
#    {'name': 'onG.social',
#     'percent_change': -24.65,
#     'price': 0.504395,
#     'symbol': 'ONG',
#     'volume_24h': 73274.5}],
#   '24h': [{'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -98.83,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0}],
#   '7d': [{'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0},
#    {'name': 'DavorCoin',
#     'percent_change': -28.21,
#     'price': 0.0731576,
#     'symbol': 'DAV',
#     'volume_24h': 430791.0}]}}

# %% [markdown]
# #### `historical(currency, [start=datetime(2008, 8, 18), end=datetime.now(), revert=False])`
# Get historical prices for a currency. You can filter by `start` and `end` datetimes provided in `datetime` objects. With parameter `revert` active, the response will be ordered in chronological order.

# %%
from datetime import datetime

list(cmc.historical("ETH", start=datetime(2018, 2, 1), revert=True))
# Out:
# [{'close': 1036.79,
#   'date': datetime.datetime(2018, 2, 1, 0, 0),
#   'high': 1161.35,
#   'low': 984.819,
#   'market_cap': 697.951,
#   'open': 1119.37,
#   'volume': 644.599},
#  {'close': 915.785,
#   'date': datetime.datetime(2018, 2, 2, 0, 0),
#   'high': 1035.77,
#   'low': 757.98,
#   'market_cap': 856.646,
#   'open': 1035.77,
#   'volume': 834.958},
#  {'close': 964.019,
#   'date': datetime.datetime(2018, 2, 3, 0, 0),
#   'high': 991.943,
#   'low': 847.69,
#   'market_cap': 793.122,
#   'open': 919.211,
#   'volume': 574.419},
#  {'close': 834.682,
#   'date': datetime.datetime(2018, 2, 4, 0, 0),
#   'high': 969.032,
#   'low': 805.064,
#   'market_cap': 796.439,
#   'open': 964.667,
#   'volume': 707.737},
#  {'close': 697.951,
#   'date': datetime.datetime(2018, 2, 5, 0, 0),
#   'high': 856.646,
#   'low': 644.599,
#   'market_cap': 757.068,
#   'open': 834.958,
#   'volume': 723.433},
#  {'close': 793.122,
#   'date': datetime.datetime(2018, 2, 6, 0, 0),
#   'high': 796.439,
#   'low': 574.419,
#   'market_cap': 851.2,
#   'open': 707.737,
#   'volume': 790.428},
#  {'close': 757.068,
#   'date': datetime.datetime(2018, 2, 7, 0, 0),
#   'high': 851.2,
#   'low': 723.433,
#   'market_cap': 817.807,
#   'open': 790.428,
#   'volume': 755.843},
#  {'close': 817.807,
#   'date': datetime.datetime(2018, 2, 8, 0, 0),
#   'high': 845.086,
#   'low': 755.843,
#   'market_cap': 845.086,
#   'open': 755.843,
#   'volume': 755.843}]

# %% [markdown]
# #### `recently([convert="USD"])`
# Get recently added coins in coinmarketcap along with other metadata. This method returns a `generator` object.

# %%
list(cmc.recently())
# Out:
# [{'added': 'Today',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'WePower',
#   'percent_change': None,
#   'price': 0.177794,
#   'symbol': 'WPR',
#   'volume_24h': 796149.0},
#  {'added': 'Today',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Datawallet',
#   'percent_change': None,
#   'price': 0.13568,
#   'symbol': 'DXT',
#   'volume_24h': 135082.0},
#  {'added': 'Today',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EtherSportz',
#   'percent_change': None,
#   'price': 0.610903,
#   'symbol': 'ESZ',
#   'volume_24h': 62939.5},
#  {'added': '2 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DRP Utility',
#   'percent_change': None,
#   'price': 0.787426,
#   'symbol': 'DRPU',
#   'volume_24h': 250390.0},
#  {'added': '2 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'THEKEY',
#   'percent_change': -7.1,
#   'price': 0.0327143,
#   'symbol': 'TKY',
#   'volume_24h': 4690410.0},
#  {'added': '2 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Swarm',
#   'percent_change': 16.54,
#   'price': 1.09772,
#   'symbol': 'SWM',
#   'volume_24h': 16053.6},
#  {'added': '3 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Medicalchain',
#   'percent_change': 7.77,
#   'price': 0.370173,
#   'symbol': 'MTN',
#   'volume_24h': 7836840.0},
#  {'added': '5 days ago',
#   'circulating_supply': 165000000.0,
#   'market_cap': 137401935.0,
#   'name': 'Bluzelle',
#   'percent_change': 6.94,
#   'price': 0.832739,
#   'symbol': 'BLZ',
#   'volume_24h': 82874600.0},
#  {'added': '6 days ago',
#   'circulating_supply': 40000000.0,
#   'market_cap': 10777120.0,
#   'name': 'Iungo',
#   'percent_change': -5.83,
#   'price': 0.269428,
#   'symbol': 'ING',
#   'volume_24h': 222159.0},
#  {'added': '6 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DMarket',
#   'percent_change': 13.09,
#   'price': 0.700198,
#   'symbol': 'DMT',
#   'volume_24h': 111.17},
#  {'added': '6 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Huobi Token',
#   'percent_change': 10.82,
#   'price': 1.57455,
#   'symbol': 'HT',
#   'volume_24h': 263217000.0},
#  {'added': '6 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'adbank',
#   'percent_change': -0.88,
#   'price': 0.0267062,
#   'symbol': 'ADB',
#   'volume_24h': 164739.0},
#  {'added': '7 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Zilla',
#   'percent_change': 3.83,
#   'price': 0.319225,
#   'symbol': 'ZLA',
#   'volume_24h': 3974510.0},
#  {'added': '7 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SwissBorg',
#   'percent_change': 0.78,
#   'price': 0.0692823,
#   'symbol': 'CHSB',
#   'volume_24h': 629508.0},
#  {'added': '7 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Jibrel Network',
#   'percent_change': 5.23,
#   'price': 0.605189,
#   'symbol': 'JNT',
#   'volume_24h': 12770200.0},
#  {'added': '7 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Polymath Network',
#   'percent_change': 15.1,
#   'price': 0.902127,
#   'symbol': 'POLY',
#   'volume_24h': 162889.0},
#  {'added': '7 days ago',
#   'circulating_supply': 200000000.0,
#   'market_cap': 9505000.0,
#   'name': 'Pareto Network',
#   'percent_change': 14.18,
#   'price': 0.047525,
#   'symbol': 'PARETO',
#   'volume_24h': 53087.9},
#  {'added': '8 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Monero Gold',
#   'percent_change': 39.27,
#   'price': 0.000260347,
#   'symbol': 'XMRG',
#   'volume_24h': 13057.4},
#  {'added': '9 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'STK',
#   'percent_change': 9.53,
#   'price': 0.218004,
#   'symbol': 'STK',
#   'volume_24h': 13786900.0},
#  {'added': '9 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Elastos',
#   'percent_change': 9.05,
#   'price': 57.1872,
#   'symbol': 'ELA',
#   'volume_24h': 49995600.0},
#  {'added': '9 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Travelflex',
#   'percent_change': -5.76,
#   'price': 0.132812,
#   'symbol': 'TRF',
#   'volume_24h': 22739.5},
#  {'added': '10 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CargoX',
#   'percent_change': 7.77,
#   'price': 0.118573,
#   'symbol': 'CXO',
#   'volume_24h': 294519.0},
#  {'added': '10 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bitcoin White',
#   'percent_change': 4.26,
#   'price': 0.310498,
#   'symbol': 'BTW',
#   'volume_24h': 199317.0},
#  {'added': '10 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ValueChain',
#   'percent_change': -6.5,
#   'price': 0.0875357,
#   'symbol': 'VLC',
#   'volume_24h': 563520.0},
#  {'added': '10 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Electronic PK Chain',
#   'percent_change': 0.57,
#   'price': 0.136028,
#   'symbol': 'EPC',
#   'volume_24h': 11934200.0},
#  {'added': '10 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Speed Mining Service',
#   'percent_change': 0.09,
#   'price': 50.4772,
#   'symbol': 'SMS',
#   'volume_24h': 42906.1},
#  {'added': '10 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Candy',
#   'percent_change': 28.26,
#   'price': 0.000875357,
#   'symbol': 'CANDY',
#   'volume_24h': 644544.0},
#  {'added': '10 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Health Mutual Society',
#   'percent_change': 27.83,
#   'price': 0.0733758,
#   'symbol': 'HMC',
#   'volume_24h': 127589.0},
#  {'added': '10 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'OceanChain',
#   'percent_change': 8.5,
#   'price': 0.0125749,
#   'symbol': 'OC',
#   'volume_24h': 10540100.0},
#  {'added': '10 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CPChain',
#   'percent_change': 7.17,
#   'price': 0.287184,
#   'symbol': 'CPC',
#   'volume_24h': 609605.0},
#  {'added': '11 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Zeepin',
#   'percent_change': 10.67,
#   'price': 0.0935621,
#   'symbol': 'ZPT',
#   'volume_24h': 774912.0},
#  {'added': '11 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'HalalChain',
#   'percent_change': 14.84,
#   'price': 0.384714,
#   'symbol': 'HLC',
#   'volume_24h': 2638830.0},
#  {'added': '11 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Equal',
#   'percent_change': 18.5,
#   'price': 0.00471165,
#   'symbol': 'EQL',
#   'volume_24h': 17605.1},
#  {'added': '11 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CoinFi',
#   'percent_change': -3.09,
#   'price': 0.110006,
#   'symbol': 'COFI',
#   'volume_24h': 346858.0},
#  {'added': '12 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Nework',
#   'percent_change': 7.07,
#   'price': 0.0587766,
#   'symbol': 'NKC',
#   'volume_24h': 6380880.0},
#  {'added': '13 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Ruff',
#   'percent_change': 36.85,
#   'price': 0.149449,
#   'symbol': 'RUFF',
#   'volume_24h': 21763500.0},
#  {'added': '13 days ago',
#   'circulating_supply': 2012949.70476,
#   'market_cap': 525663.698852,
#   'name': 'Garlicoin',
#   'percent_change': -13.14,
#   'price': 0.261141,
#   'symbol': 'GRLC',
#   'volume_24h': 17564.7},
#  {'added': '13 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Matrix AI Network',
#   'percent_change': 17.79,
#   'price': 0.685795,
#   'symbol': 'MAN',
#   'volume_24h': 146399.0},
#  {'added': '14 days ago',
#   'circulating_supply': 439951479.697,
#   'market_cap': 49971888.8214,
#   'name': 'All Sports',
#   'percent_change': 19.09,
#   'price': 0.113585,
#   'symbol': 'SOC',
#   'volume_24h': 5238670.0},
#  {'added': '15 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Fortuna',
#   'percent_change': 6.72,
#   'price': 0.0949913,
#   'symbol': 'FOTA',
#   'volume_24h': 970285.0},
#  {'added': '15 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Smartlands',
#   'percent_change': -20.42,
#   'price': 1.01074,
#   'symbol': 'SLT',
#   'volume_24h': 12003.7},
#  {'added': '15 days ago',
#   'circulating_supply': 192929698.0,
#   'market_cap': 17614616.4782,
#   'name': 'CoinMeet',
#   'percent_change': 16.43,
#   'price': 0.0913007,
#   'symbol': 'MEE',
#   'volume_24h': 4774760.0},
#  {'added': '15 days ago',
#   'circulating_supply': 6508988220.4,
#   'market_cap': 392153522.303,
#   'name': 'Zilliqa',
#   'percent_change': 4.6,
#   'price': 0.060248,
#   'symbol': 'ZIL',
#   'volume_24h': 12256500.0},
#  {'added': '15 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LinkEye',
#   'percent_change': 12.17,
#   'price': 0.0764714,
#   'symbol': 'LET',
#   'volume_24h': 16701400.0},
#  {'added': '15 days ago',
#   'circulating_supply': 254507605.599,
#   'market_cap': 54326938.9836,
#   'name': 'OriginTrail',
#   'percent_change': 4.38,
#   'price': 0.213459,
#   'symbol': 'TRAC',
#   'volume_24h': 207292.0},
#  {'added': '15 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'aXpire',
#   'percent_change': -0.62,
#   'price': 0.0658146,
#   'symbol': 'AXP',
#   'volume_24h': 64565.1},
#  {'added': '16 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Pundi X',
#   'percent_change': 8.34,
#   'price': 1.58116,
#   'symbol': 'PXS',
#   'volume_24h': 128919.0},
#  {'added': '16 days ago',
#   'circulating_supply': 49596285.4494,
#   'market_cap': 15023210.8255,
#   'name': 'Blockport',
#   'percent_change': 13.59,
#   'price': 0.30291,
#   'symbol': 'BPT',
#   'volume_24h': 60833.9},
#  {'added': '16 days ago',
#   'circulating_supply': 60523400.0,
#   'market_cap': 8016384.8534,
#   'name': 'Devery',
#   'percent_change': 23.45,
#   'price': 0.132451,
#   'symbol': 'EVE',
#   'volume_24h': 11574.9},
#  {'added': '16 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bitcoin Lightning',
#   'percent_change': 22.57,
#   'price': 8.6792,
#   'symbol': 'BLT',
#   'volume_24h': 350892.0},
#  {'added': '16 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'AidCoin',
#   'percent_change': 7.63,
#   'price': 0.276167,
#   'symbol': 'AID',
#   'volume_24h': 352328.0},
#  {'added': '16 days ago',
#   'circulating_supply': 206729.959584,
#   'market_cap': 1967744.6492,
#   'name': 'Qbic',
#   'percent_change': -5.08,
#   'price': 9.51843,
#   'symbol': 'QBIC',
#   'volume_24h': 155859.0},
#  {'added': '16 days ago',
#   'circulating_supply': 399934364.226,
#   'market_cap': 54382674.9131,
#   'name': 'indaHash',
#   'percent_change': 0.94,
#   'price': 0.135979,
#   'symbol': 'IDH',
#   'volume_24h': 192443.0},
#  {'added': '16 days ago',
#   'circulating_supply': 2000000000.0,
#   'market_cap': 49598600.0,
#   'name': 'Odyssey',
#   'percent_change': 2.18,
#   'price': 0.0247993,
#   'symbol': 'OCN',
#   'volume_24h': 10077900.0},
#  {'added': '16 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'True Chain',
#   'percent_change': 63.83,
#   'price': 1.20151,
#   'symbol': 'TRUE',
#   'volume_24h': 40957900.0},
#  {'added': '16 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'OFCOIN',
#   'percent_change': 4.94,
#   'price': 0.00400278,
#   'symbol': 'OF',
#   'volume_24h': 20420600.0},
#  {'added': '16 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'PressOne',
#   'percent_change': 14.72,
#   'price': 0.745607,
#   'symbol': 'PRS',
#   'volume_24h': 245580.0},
#  {'added': '17 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'UnlimitedIP',
#   'percent_change': 18.55,
#   'price': 0.0639983,
#   'symbol': 'UIP',
#   'volume_24h': 405908.0},
#  {'added': '17 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EDUCare',
#   'percent_change': 4.93,
#   'price': 0.135218,
#   'symbol': 'EKT',
#   'volume_24h': 13395600.0},
#  {'added': '17 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Tokenbox',
#   'percent_change': -11.33,
#   'price': 0.736819,
#   'symbol': 'TBX',
#   'volume_24h': 78848.8},
#  {'added': '17 days ago',
#   'circulating_supply': 68430738.22,
#   'market_cap': 10837307.5812,
#   'name': 'Block Array',
#   'percent_change': -6.39,
#   'price': 0.158369,
#   'symbol': 'ARY',
#   'volume_24h': 267426.0},
#  {'added': '18 days ago',
#   'circulating_supply': 17500000.0,
#   'market_cap': 23162300.0,
#   'name': 'Covesting',
#   'percent_change': 14.73,
#   'price': 1.32356,
#   'symbol': 'COV',
#   'volume_24h': 46725.6},
#  {'added': '18 days ago',
#   'circulating_supply': 5171589622.24,
#   'market_cap': 47549094.7479,
#   'name': 'carVertical',
#   'percent_change': 3.17,
#   'price': 0.00919429,
#   'symbol': 'CV',
#   'volume_24h': 1016810.0},
#  {'added': '18 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Decentralized Universa...',
#   'percent_change': 9.4,
#   'price': 122.638,
#   'symbol': 'DUBI',
#   'volume_24h': 1019.79},
#  {'added': '18 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sparks',
#   'percent_change': 8.67,
#   'price': 3.81929,
#   'symbol': 'SPK',
#   'volume_24h': 45076.4},
#  {'added': '18 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Crypterium',
#   'percent_change': 4.03,
#   'price': 0.800507,
#   'symbol': 'CRPT',
#   'volume_24h': 44221.4},
#  {'added': '18 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DATA',
#   'percent_change': 6.28,
#   'price': 0.0230612,
#   'symbol': 'DTA',
#   'volume_24h': 15241100.0},
#  {'added': '18 days ago',
#   'circulating_supply': 39335007.2487,
#   'market_cap': 95014496.7094,
#   'name': 'CRYPTO20',
#   'percent_change': 12.86,
#   'price': 2.41552,
#   'symbol': 'C20',
#   'volume_24h': 2875930.0},
#  {'added': '18 days ago',
#   'circulating_supply': 333333333.0,
#   'market_cap': 75844999.9242,
#   'name': 'Trinity Network Credit',
#   'percent_change': 10.66,
#   'price': 0.227535,
#   'symbol': 'TNC',
#   'volume_24h': 3870450.0},
#  {'added': '20 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TimesCoin',
#   'percent_change': 9.11,
#   'price': 1.10214,
#   'symbol': 'TMC',
#   'volume_24h': 35462.7},
#  {'added': '20 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Molecular Future',
#   'percent_change': 10.42,
#   'price': 0.319061,
#   'symbol': 'MOF',
#   'volume_24h': 414009.0},
#  {'added': '20 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Read',
#   'percent_change': 4.1,
#   'price': 0.0363584,
#   'symbol': 'READ',
#   'volume_24h': 482021.0},
#  {'added': '20 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SelfSell',
#   'percent_change': 12.65,
#   'price': 0.105799,
#   'symbol': 'SSC',
#   'volume_24h': 305340.0},
#  {'added': '20 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Acute Angle Cloud',
#   'percent_change': -1.32,
#   'price': 0.181754,
#   'symbol': 'AAC',
#   'volume_24h': 1400640.0},
#  {'added': '20 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Yee',
#   'percent_change': 3.32,
#   'price': 0.0255711,
#   'symbol': 'YEE',
#   'volume_24h': 3201680.0},
#  {'added': '20 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'RefToken',
#   'percent_change': 17.45,
#   'price': 24.1672,
#   'symbol': 'REF',
#   'volume_24h': 241045.0},
#  {'added': '20 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LightChain',
#   'percent_change': 8.89,
#   'price': 0.00432511,
#   'symbol': 'LIGHT',
#   'volume_24h': 1641280.0},
#  {'added': '20 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maggie',
#   'percent_change': 6.99,
#   'price': 0.0344672,
#   'symbol': 'MAG',
#   'volume_24h': 37769.7},
#  {'added': '20 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'IPChain',
#   'percent_change': 6.2,
#   'price': 0.722576,
#   'symbol': 'IPC',
#   'volume_24h': 58418.2},
#  {'added': '20 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'StarChain',
#   'percent_change': 16.0,
#   'price': 0.125678,
#   'symbol': 'STC',
#   'volume_24h': 1447740.0},
#  {'added': '21 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Titanium Blockchain',
#   'percent_change': 20.11,
#   'price': 1.40755,
#   'symbol': 'BAR',
#   'volume_24h': 1148180.0},
#  {'added': '21 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Hydro Protocol',
#   'percent_change': 12.92,
#   'price': 0.0809582,
#   'symbol': 'HOT',
#   'volume_24h': 507310.0},
#  {'added': '21 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Mobius',
#   'percent_change': 17.79,
#   'price': 0.202295,
#   'symbol': 'MOBI',
#   'volume_24h': 312402.0},
#  {'added': '21 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Scry.info',
#   'percent_change': 12.74,
#   'price': 0.290606,
#   'symbol': 'DDD',
#   'volume_24h': 852086.0},
#  {'added': '21 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ChatCoin',
#   'percent_change': 4.88,
#   'price': 0.292999,
#   'symbol': 'CHAT',
#   'volume_24h': 6920160.0},
#  {'added': '21 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ShareX',
#   'percent_change': -0.26,
#   'price': 0.0271361,
#   'symbol': 'SEXC',
#   'volume_24h': 809354.0},
#  {'added': '22 days ago',
#   'circulating_supply': 529861448.67,
#   'market_cap': 14716053.9585,
#   'name': 'Gatcoin',
#   'percent_change': 6.16,
#   'price': 0.0277734,
#   'symbol': 'GAT',
#   'volume_24h': 66821.8},
#  {'added': '22 days ago',
#   'circulating_supply': 454443782.0,
#   'market_cap': 209211829.476,
#   'name': 'SingularityNET',
#   'percent_change': 10.23,
#   'price': 0.460369,
#   'symbol': 'AGI',
#   'volume_24h': 994738.0},
#  {'added': '22 days ago',
#   'circulating_supply': 100000000.0,
#   'market_cap': 18819300.0,
#   'name': 'Aurora DAO',
#   'percent_change': 28.64,
#   'price': 0.188193,
#   'symbol': 'AURA',
#   'volume_24h': 32887.4},
#  {'added': '22 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'IDEX Membership',
#   'percent_change': 23.8,
#   'price': 5250.39,
#   'symbol': 'IDXM',
#   'volume_24h': 23930.8},
#  {'added': '22 days ago',
#   'circulating_supply': 201000000.0,
#   'market_cap': 35861616.0,
#   'name': 'InsurePal',
#   'percent_change': 7.72,
#   'price': 0.178416,
#   'symbol': 'IPL',
#   'volume_24h': 46693.6},
#  {'added': '23 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Nitro',
#   'percent_change': 10.19,
#   'price': 0.341298,
#   'symbol': 'NOX',
#   'volume_24h': 30789.4},
#  {'added': '23 days ago',
#   'circulating_supply': 20923342.6892,
#   'market_cap': 19621680.6172,
#   'name': 'Profile Utility Token',
#   'percent_change': 8.56,
#   'price': 0.937789,
#   'symbol': 'PUT',
#   'volume_24h': 3502210.0},
#  {'added': '23 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maverick Chain',
#   'percent_change': 14.58,
#   'price': 0.0859146,
#   'symbol': 'MVC',
#   'volume_24h': 16200.8},
#  {'added': '23 days ago',
#   'circulating_supply': 563264706.0,
#   'market_cap': 81875031.1347,
#   'name': 'Theta Token',
#   'percent_change': 13.02,
#   'price': 0.145358,
#   'symbol': 'THETA',
#   'volume_24h': 15882400.0},
#  {'added': '24 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ArbitrageCT',
#   'percent_change': 7.86,
#   'price': 0.0207155,
#   'symbol': 'ARCT',
#   'volume_24h': 23025.6},
#  {'added': '24 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'RealChain',
#   'percent_change': 9.36,
#   'price': 0.091632,
#   'symbol': 'RCT',
#   'volume_24h': 1185150.0},
#  {'added': '24 days ago',
#   'circulating_supply': 100336600.0,
#   'market_cap': 9364545.31558,
#   'name': 'Ethorse',
#   'percent_change': -0.31,
#   'price': 0.0933313,
#   'symbol': 'HORSE',
#   'volume_24h': 31229.5},
#  {'added': '24 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Harvest Masternode Coin',
#   'percent_change': 1.98,
#   'price': 1.53978,
#   'symbol': 'HC',
#   'volume_24h': 23253.0},
#  {'added': '24 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Galactrum',
#   'percent_change': -9.26,
#   'price': 3.21529,
#   'symbol': 'ORE',
#   'volume_24h': 26239.1},
#  {'added': '24 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SpaceChain',
#   'percent_change': 14.43,
#   'price': 0.2132,
#   'symbol': 'SPC',
#   'volume_24h': 601548.0},
#  {'added': '24 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EtherDelta Token',
#   'percent_change': 12.73,
#   'price': 0.0412249,
#   'symbol': 'EDT',
#   'volume_24h': 385.157},
#  {'added': '24 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Qube',
#   'percent_change': -1.2,
#   'price': 0.0633438,
#   'symbol': 'QUBE',
#   'volume_24h': 452699.0},
#  {'added': '24 days ago',
#   'circulating_supply': 193535756.218,
#   'market_cap': 14528109.9049,
#   'name': 'AICHAIN',
#   'percent_change': 11.47,
#   'price': 0.0750668,
#   'symbol': 'AIT',
#   'volume_24h': 96252.1},
#  {'added': '24 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'InvestDigital',
#   'percent_change': -5.18,
#   'price': 0.0704368,
#   'symbol': 'IDT',
#   'volume_24h': 621554.0},
#  {'added': '24 days ago',
#   'circulating_supply': 6794109921.69,
#   'market_cap': 275985577.362,
#   'name': 'IOStoken',
#   'percent_change': 4.43,
#   'price': 0.0406213,
#   'symbol': 'IOST',
#   'volume_24h': 40403800.0},
#  {'added': '25 days ago',
#   'circulating_supply': 117297297.554,
#   'market_cap': 1131326.57005,
#   'name': 'TOKYO',
#   'percent_change': 7.84,
#   'price': 0.00964495,
#   'symbol': 'TOKC',
#   'volume_24h': 194870.0},
#  {'added': '25 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'MOAC',
#   'percent_change': 5.52,
#   'price': 12.8012,
#   'symbol': 'MOAC',
#   'volume_24h': 143513.0},
#  {'added': '25 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sense',
#   'percent_change': 9.08,
#   'price': 0.0434093,
#   'symbol': 'SENSE',
#   'volume_24h': 1212.79},
#  {'added': '25 days ago',
#   'circulating_supply': 13449994.7564,
#   'market_cap': 7943849.35302,
#   'name': 'Global Jobcoin',
#   'percent_change': -16.05,
#   'price': 0.590621,
#   'symbol': 'GJC',
#   'volume_24h': 57251.0},
#  {'added': '25 days ago',
#   'circulating_supply': 185501578.891,
#   'market_cap': 14948811.6864,
#   'name': 'OneRoot Network',
#   'percent_change': 8.32,
#   'price': 0.0805859,
#   'symbol': 'RNT',
#   'volume_24h': 233636.0},
#  {'added': '25 days ago',
#   'circulating_supply': 150000000.0,
#   'market_cap': 55723350.0,
#   'name': 'Internet Node Token',
#   'percent_change': 2.86,
#   'price': 0.371489,
#   'symbol': 'INT',
#   'volume_24h': 2240410.0},
#  {'added': '25 days ago',
#   'circulating_supply': 1877455408.41,
#   'market_cap': 32434919.6357,
#   'name': 'Selfkey',
#   'percent_change': 15.33,
#   'price': 0.017276,
#   'symbol': 'KEY',
#   'volume_24h': 758480.0},
#  {'added': '25 days ago',
#   'circulating_supply': 324308731.314,
#   'market_cap': 12382950.5643,
#   'name': 'Hackspace Capital',
#   'percent_change': 5.4,
#   'price': 0.0381826,
#   'symbol': 'HAC',
#   'volume_24h': 344408.0},
#  {'added': '26 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EchoLink',
#   'percent_change': 23.59,
#   'price': 0.0983245,
#   'symbol': 'EKO',
#   'volume_24h': 3316520.0},
#  {'added': '26 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'WETH',
#   'percent_change': 14.6,
#   'price': 905.752,
#   'symbol': 'WETH',
#   'volume_24h': 65867.6},
#  {'added': '26 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Ignition',
#   'percent_change': 2.38,
#   'price': 12.8752,
#   'symbol': 'IC',
#   'volume_24h': 48305.7},
#  {'added': '26 days ago',
#   'circulating_supply': 20970629778.4,
#   'market_cap': 79824492.5453,
#   'name': 'Telcoin',
#   'percent_change': 6.56,
#   'price': 0.00380649,
#   'symbol': 'TEL',
#   'volume_24h': 887988.0},
#  {'added': '26 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'AWARE',
#   'percent_change': -12.63,
#   'price': 0.0257583,
#   'symbol': 'AWR',
#   'volume_24h': 719392.0},
#  {'added': '27 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bottos',
#   'percent_change': 12.62,
#   'price': 0.147933,
#   'symbol': 'BTO',
#   'volume_24h': 799383.0},
#  {'added': '27 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bankex',
#   'percent_change': 26.79,
#   'price': 1.07615,
#   'symbol': 'BKX',
#   'volume_24h': 4030.95},
#  {'added': '28 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ugChain',
#   'percent_change': -1.52,
#   'price': 0.0919271,
#   'symbol': 'UGC',
#   'volume_24h': 610139.0},
#  {'added': '28 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bitcoin Atom',
#   'percent_change': 22.11,
#   'price': 33.8294,
#   'symbol': 'BCA',
#   'volume_24h': 7383.95},
#  {'added': '28 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Kzcash',
#   'percent_change': 6.53,
#   'price': 3.48906,
#   'symbol': 'KZC',
#   'volume_24h': 28151.3},
#  {'added': '28 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Cloud',
#   'percent_change': 0.88,
#   'price': 0.0748733,
#   'symbol': 'CLD',
#   'volume_24h': 5151.35},
#  {'added': '28 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Vezt',
#   'percent_change': -0.07,
#   'price': 0.238458,
#   'symbol': 'VZT',
#   'volume_24h': 61909.3},
#  {'added': '28 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Jingtum Tech',
#   'percent_change': -2.22,
#   'price': 0.0114371,
#   'symbol': 'SWTC',
#   'volume_24h': 73525.3},
#  {'added': '28 days ago',
#   'circulating_supply': 23676581.5131,
#   'market_cap': 9559869.64094,
#   'name': 'Spectre.ai Utility Token',
#   'percent_change': 9.19,
#   'price': 0.403769,
#   'symbol': 'SXUT',
#   'volume_24h': 5677880.0},
#  {'added': '28 days ago',
#   'circulating_supply': 79191383.6244,
#   'market_cap': 42978826.912,
#   'name': 'Spectre.ai Dividend Token',
#   'percent_change': 16.52,
#   'price': 0.542721,
#   'symbol': 'SXDT',
#   'volume_24h': 1050.43},
#  {'added': '28 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ATN',
#   'percent_change': 9.05,
#   'price': 1.43919,
#   'symbol': 'ATN',
#   'volume_24h': 611046.0},
#  {'added': '28 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Kcash',
#   'percent_change': 3.77,
#   'price': 0.192378,
#   'symbol': 'KCASH',
#   'volume_24h': 2244880.0},
#  {'added': '28 days ago',
#   'circulating_supply': 1005414013.0,
#   'market_cap': 29644230.0077,
#   'name': 'Karma',
#   'percent_change': 12.08,
#   'price': 0.0294846,
#   'symbol': 'KRM',
#   'volume_24h': 101256.0},
#  {'added': '28 days ago',
#   'circulating_supply': 118090510.577,
#   'market_cap': 13042860.7122,
#   'name': 'Leverj',
#   'percent_change': 14.45,
#   'price': 0.110448,
#   'symbol': 'LEV',
#   'volume_24h': 34138.7},
#  {'added': '28 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TopChain',
#   'percent_change': 7.67,
#   'price': 0.0623786,
#   'symbol': 'TOPC',
#   'volume_24h': 9343060.0},
#  {'added': '28 days ago',
#   'circulating_supply': 349367127.0,
#   'market_cap': 24351587.4862,
#   'name': 'QunQun',
#   'percent_change': 6.47,
#   'price': 0.069702,
#   'symbol': 'QUN',
#   'volume_24h': 7099760.0},
#  {'added': '28 days ago',
#   'circulating_supply': 346139198.325,
#   'market_cap': 46816364.9911,
#   'name': 'BitDegree',
#   'percent_change': 5.97,
#   'price': 0.135253,
#   'symbol': 'BDG',
#   'volume_24h': 110156.0},
#  {'added': '29 days ago',
#   'circulating_supply': 84285535.961,
#   'market_cap': 30556793.9218,
#   'name': 'Trade Token',
#   'percent_change': 11.27,
#   'price': 0.362539,
#   'symbol': 'TIO',
#   'volume_24h': 601390.0},
#  {'added': '29 days ago',
#   'circulating_supply': 32550000.0,
#   'market_cap': 3786053.25,
#   'name': 'Commodity Ad Network',
#   'percent_change': 49.9,
#   'price': 0.116315,
#   'symbol': 'CDX',
#   'volume_24h': 758.854},
#  {'added': '29 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'United Traders Token',
#   'percent_change': 12.2,
#   'price': 0.827134,
#   'symbol': 'UTT',
#   'volume_24h': 5441.61},
#  {'added': '29 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bitcoin God',
#   'percent_change': 2.9,
#   'price': 49.4644,
#   'symbol': 'GOD',
#   'volume_24h': 18579.5},
#  {'added': '29 days ago',
#   'circulating_supply': 28003971.7665,
#   'market_cap': 69704406.0844,
#   'name': 'INS Ecosystem',
#   'percent_change': 11.28,
#   'price': 2.48909,
#   'symbol': 'INS',
#   'volume_24h': 15746900.0},
#  {'added': '29 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Rebellious',
#   'percent_change': 23.73,
#   'price': 0.0860265,
#   'symbol': 'REBL',
#   'volume_24h': 1624440.0},
#  {'added': '29 days ago',
#   'circulating_supply': 17857485.7019,
#   'market_cap': 10094140.2254,
#   'name': 'Aigang',
#   'percent_change': 0.63,
#   'price': 0.565261,
#   'symbol': 'AIX',
#   'volume_24h': 131746.0},
#  {'added': '29 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'FairGame',
#   'percent_change': 3.84,
#   'price': 0.0497862,
#   'symbol': 'FAIR',
#   'volume_24h': 462259.0},
#  {'added': '29 days ago',
#   'circulating_supply': 2161058.821,
#   'market_cap': 2472035.18534,
#   'name': 'LendConnect',
#   'percent_change': 12.74,
#   'price': 1.1439,
#   'symbol': 'LCT',
#   'volume_24h': 281000.0},
#  {'added': '29 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TokenClub',
#   'percent_change': 1.84,
#   'price': 0.0285871,
#   'symbol': 'TCT',
#   'volume_24h': 131611.0},
#  {'added': '29 days ago',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Zap',
#   'percent_change': 6.31,
#   'price': 0.291264,
#   'symbol': 'ZAP',
#   'volume_24h': 79696.5},
#  {'added': '29 days ago',
#   'circulating_supply': 2146854.86097,
#   'market_cap': 912170.721314,
#   'name': 'Steneum Coin',
#   'percent_change': 4.34,
#   'price': 0.424887,
#   'symbol': 'STN',
#   'volume_24h': 20425.9}]

# %% [markdown]
# #### `exchange(name [convert="USD"])`
# Get data about a exchange:

# %%
cmc.exchange("okex")
# Out:
# {'markets': [{'currency': 'Bitcoin Cash',
#    'pair': 'BCH/BTC',
#    'perc_volume': 23.1061963383,
#    'price': 1311.28,
#    'updated': True,
#    'vol_24h': 481018000.0},
#   {'currency': 'Ethereum',
#    'pair': 'ETH/BTC',
#    'perc_volume': 17.9068242037,
#    'price': 874.722,
#    'updated': True,
#    'vol_24h': 372779000.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/BTC',
#    'perc_volume': 15.3063455418,
#    'price': 160.183,
#    'updated': True,
#    'vol_24h': 318643000.0},
#   {'currency': 'Bitcoin',
#    'pair': 'BTC/USDT',
#    'perc_volume': 12.4645338521,
#    'price': 8701.83,
#    'updated': True,
#    'vol_24h': 259483000.0},
#   {'currency': 'Ethereum',
#    'pair': 'ETH/USDT',
#    'perc_volume': 6.12728417674,
#    'price': 878.084,
#    'updated': True,
#    'vol_24h': 127556000.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/BTC',
#    'perc_volume': 5.72973797079,
#    'price': 25.9382,
#    'updated': True,
#    'vol_24h': 119280000.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/USDT',
#    'perc_volume': 2.20426305401,
#    'price': 1314.56,
#    'updated': True,
#    'vol_24h': 45887700.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/USDT',
#    'perc_volume': 1.88840692513,
#    'price': 159.26,
#    'updated': True,
#    'vol_24h': 39312300.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/USDT',
#    'perc_volume': 1.66895911371,
#    'price': 26.1091,
#    'updated': True,
#    'vol_24h': 34743900.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/ETH',
#    'perc_volume': 1.09765697057,
#    'price': 25.9815,
#    'updated': True,
#    'vol_24h': 22850700.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/USDT',
#    'perc_volume': 1.05460707813,
#    'price': 9.60992,
#    'updated': True,
#    'vol_24h': 21954500.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/BTC',
#    'perc_volume': 0.963516349478,
#    'price': 1.21027,
#    'updated': True,
#    'vol_24h': 20058200.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/USDT',
#    'perc_volume': 0.854796396851,
#    'price': 0.00400038,
#    'updated': True,
#    'vol_24h': 17794900.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/BTC',
#    'perc_volume': 0.646478534192,
#    'price': 0.0203071,
#    'updated': True,
#    'vol_24h': 13458200.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/USDT',
#    'perc_volume': 0.545679723345,
#    'price': 1.18061,
#    'updated': True,
#    'vol_24h': 11359800.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/ETH',
#    'perc_volume': 0.458260388663,
#    'price': 1.20799,
#    'updated': True,
#    'vol_24h': 9539930.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/BTC',
#    'perc_volume': 0.428891158319,
#    'price': 9.58078,
#    'updated': True,
#    'vol_24h': 8928530.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/ETH',
#    'perc_volume': 0.417521990119,
#    'price': 0.0203345,
#    'updated': True,
#    'vol_24h': 8691850.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/USDT',
#    'perc_volume': 0.317278956169,
#    'price': 0.889855,
#    'updated': True,
#    'vol_24h': 6605020.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/BTC',
#    'perc_volume': 0.302784083326,
#    'price': 2.53318,
#    'updated': True,
#    'vol_24h': 6303270.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/BTC',
#    'perc_volume': 0.233756304453,
#    'price': 4.62385,
#    'updated': True,
#    'vol_24h': 4866270.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/BTC',
#    'perc_volume': 0.196561043675,
#    'price': 29.2445,
#    'updated': True,
#    'vol_24h': 4091950.0},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/ETH',
#    'perc_volume': 0.182200671724,
#    'price': 0.0623342,
#    'updated': True,
#    'vol_24h': 3793000.0},
#   {'currency': 'Centra',
#    'pair': 'CTR/BTC',
#    'perc_volume': 0.179167196264,
#    'price': 1.06482,
#    'updated': True,
#    'vol_24h': 3729850.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/ETH',
#    'perc_volume': 0.176136602966,
#    'price': 9.62979,
#    'updated': True,
#    'vol_24h': 3666760.0},
#   {'currency': 'Golem',
#    'pair': 'GNT/BTC',
#    'perc_volume': 0.167520860155,
#    'price': 0.357457,
#    'updated': True,
#    'vol_24h': 3487400.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/BTC',
#    'perc_volume': 0.156974068834,
#    'price': 0.895977,
#    'updated': True,
#    'vol_24h': 3267840.0},
#   {'currency': 'Hshare',
#    'pair': 'HSR/BTC',
#    'perc_volume': 0.156434143827,
#    'price': 12.5714,
#    'updated': True,
#    'vol_24h': 3256600.0},
#   {'currency': 'Viberate',
#    'pair': 'VIB/BTC',
#    'perc_volume': 0.14951791585,
#    'price': 0.271629,
#    'updated': True,
#    'vol_24h': 3112620.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/USDT',
#    'perc_volume': 0.136095687616,
#    'price': 29.2086,
#    'updated': True,
#    'vol_24h': 2833200.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/BTC',
#    'perc_volume': 0.135031209133,
#    'price': 115.326,
#    'updated': True,
#    'vol_24h': 2811040.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/BTC',
#    'perc_volume': 0.133786595528,
#    'price': 1.38045,
#    'updated': True,
#    'vol_24h': 2785130.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/BTC',
#    'perc_volume': 0.131903583049,
#    'price': 0.124012,
#    'updated': True,
#    'vol_24h': 2745930.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/BTC',
#    'perc_volume': 0.126901590973,
#    'price': 0.400406,
#    'updated': True,
#    'vol_24h': 2641800.0},
#   {'currency': 'SunContract',
#    'pair': 'SNC/BTC',
#    'perc_volume': 0.115816796086,
#    'price': 0.257657,
#    'updated': True,
#    'vol_24h': 2411040.0},
#   {'currency': 'Hshare',
#    'pair': 'HSR/USDT',
#    'perc_volume': 0.114254664305,
#    'price': 12.6212,
#    'updated': True,
#    'vol_24h': 2378520.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/USDT',
#    'perc_volume': 0.111153458039,
#    'price': 0.346033,
#    'updated': True,
#    'vol_24h': 2313960.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/BTC',
#    'perc_volume': 0.107328348762,
#    'price': 1.95694,
#    'updated': True,
#    'vol_24h': 2234330.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/BTC',
#    'perc_volume': 0.103962463956,
#    'price': 0.0473832,
#    'updated': True,
#    'vol_24h': 2164260.0},
#   {'currency': 'Monero',
#    'pair': 'XMR/BTC',
#    'perc_volume': 0.102310504794,
#    'price': 259.742,
#    'updated': True,
#    'vol_24h': 2129870.0},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/USDT',
#    'perc_volume': 0.101490529717,
#    'price': 0.041804,
#    'updated': True,
#    'vol_24h': 2112800.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/USDT',
#    'perc_volume': 0.0880615764384,
#    'price': 1.39013,
#    'updated': True,
#    'vol_24h': 1833240.0},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/BTC',
#    'perc_volume': 0.0777367115873,
#    'price': 2.5731,
#    'updated': True,
#    'vol_24h': 1618300.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/BTC',
#    'perc_volume': 0.0771636417181,
#    'price': 0.00399199,
#    'updated': True,
#    'vol_24h': 1606370.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/ETH',
#    'perc_volume': 0.0726617047411,
#    'price': 2.52024,
#    'updated': True,
#    'vol_24h': 1512650.0},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/BTC',
#    'perc_volume': 0.0721222600948,
#    'price': 0.499693,
#    'updated': True,
#    'vol_24h': 1501420.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/BTC',
#    'perc_volume': 0.0712148594386,
#    'price': 0.447797,
#    'updated': True,
#    'vol_24h': 1482530.0},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/BTC',
#    'perc_volume': 0.068812097087,
#    'price': 456.422,
#    'updated': True,
#    'vol_24h': 1432510.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/USDT',
#    'perc_volume': 0.0644220840659,
#    'price': 115.794,
#    'updated': True,
#    'vol_24h': 1341120.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/USDT',
#    'perc_volume': 0.0638965698691,
#    'price': 0.125912,
#    'updated': True,
#    'vol_24h': 1330180.0},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/USDT',
#    'perc_volume': 0.0638821590593,
#    'price': 0.192218,
#    'updated': True,
#    'vol_24h': 1329880.0},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/BTC',
#    'perc_volume': 0.0629281634515,
#    'price': 127.483,
#    'updated': True,
#    'vol_24h': 1310020.0},
#   {'currency': 'Dash',
#    'pair': 'DASH/BTC',
#    'perc_volume': 0.0608899945875,
#    'price': 638.787,
#    'updated': True,
#    'vol_24h': 1267590.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/USDT',
#    'perc_volume': 0.0587927414033,
#    'price': 0.450243,
#    'updated': True,
#    'vol_24h': 1223930.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/BTC',
#    'perc_volume': 0.0530682873961,
#    'price': 0.372557,
#    'updated': True,
#    'vol_24h': 1104760.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/BTC',
#    'perc_volume': 0.0530183299222,
#    'price': 0.345481,
#    'updated': True,
#    'vol_24h': 1103720.0},
#   {'currency': 'Centra',
#    'pair': 'CTR/ETH',
#    'perc_volume': 0.0520138964801,
#    'price': 1.07723,
#    'updated': True,
#    'vol_24h': 1082810.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/ETH',
#    'perc_volume': 0.0499502685188,
#    'price': 1323.19,
#    'updated': True,
#    'vol_24h': 1039850.0},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/BTC',
#    'perc_volume': 0.0494137060345,
#    'price': 0.242991,
#    'updated': True,
#    'vol_24h': 1028680.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/ETH',
#    'perc_volume': 0.0489688923724,
#    'price': 0.00406166,
#    'updated': True,
#    'vol_24h': 1019420.0},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/USDT',
#    'perc_volume': 0.0,
#    'price': 6.71094,
#    'updated': True,
#    'vol_24h': 1013730.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/BTC',
#    'perc_volume': 0.0477321566766,
#    'price': 0.17747,
#    'updated': True,
#    'vol_24h': 993674.0},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/BTC',
#    'perc_volume': 0.0,
#    'price': 6.74317,
#    'updated': True,
#    'vol_24h': 975304.0},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/BTC',
#    'perc_volume': 0.044597517332,
#    'price': 0.0420895,
#    'updated': True,
#    'vol_24h': 928418.0},
#   {'currency': 'NEM',
#    'pair': 'XEM/BTC',
#    'perc_volume': 0.0424085153256,
#    'price': 0.562464,
#    'updated': True,
#    'vol_24h': 882848.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/USDT',
#    'perc_volume': 0.0417716055691,
#    'price': 0.00430041,
#    'updated': True,
#    'vol_24h': 869589.0},
#   {'currency': 'NEM',
#    'pair': 'XEM/USDT',
#    'perc_volume': 0.0411408444248,
#    'price': 0.570035,
#    'updated': True,
#    'vol_24h': 856458.0},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/USDT',
#    'perc_volume': 0.0400486011151,
#    'price': 0.500748,
#    'updated': True,
#    'vol_24h': 833720.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/USDT',
#    'perc_volume': 0.0400149758922,
#    'price': 0.00540052,
#    'updated': True,
#    'vol_24h': 833020.0},
#   {'currency': 'Dash',
#    'pair': 'DASH/USDT',
#    'perc_volume': 0.0392432289922,
#    'price': 631.439,
#    'updated': True,
#    'vol_24h': 816954.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/USDT',
#    'perc_volume': 0.0384401625989,
#    'price': 1.33323,
#    'updated': True,
#    'vol_24h': 800236.0},
#   {'currency': 'BitcoinX',
#    'pair': 'BCX/BTC',
#    'perc_volume': 0.0373881254485,
#    'price': 0.010761,
#    'updated': True,
#    'vol_24h': 778335.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/BTC',
#    'perc_volume': 0.0346171188708,
#    'price': 0.00555407,
#    'updated': True,
#    'vol_24h': 720649.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/USDT',
#    'perc_volume': 0.0341683182181,
#    'price': 1.95659,
#    'updated': True,
#    'vol_24h': 711306.0},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/BTC',
#    'perc_volume': 0.0317757395054,
#    'price': 0.191616,
#    'updated': True,
#    'vol_24h': 661498.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/USDT',
#    'perc_volume': 0.0316758725936,
#    'price': 0.372036,
#    'updated': True,
#    'vol_24h': 659419.0},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/BTC',
#    'perc_volume': 0.0313425025272,
#    'price': 13.1831,
#    'updated': True,
#    'vol_24h': 652479.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/USDT',
#    'perc_volume': 0.0298962816931,
#    'price': 0.0460044,
#    'updated': True,
#    'vol_24h': 622372.0},
#   {'currency': 'Super Bitcoin',
#    'pair': 'SBTC/BTC',
#    'perc_volume': 0.0294001175122,
#    'price': 21.9855,
#    'updated': True,
#    'vol_24h': 612043.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/ETH',
#    'perc_volume': 0.0292382841183,
#    'price': 4.57984,
#    'updated': True,
#    'vol_24h': 608674.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/BTC',
#    'perc_volume': 0.0291918332748,
#    'price': 0.181549,
#    'updated': True,
#    'vol_24h': 607707.0},
#   {'currency': 'Ace',
#    'pair': 'ACE/BTC',
#    'perc_volume': 0.0283195949945,
#    'price': 0.380975,
#    'updated': True,
#    'vol_24h': 589549.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/USDT',
#    'perc_volume': 0.0279686437402,
#    'price': 0.0201019,
#    'updated': True,
#    'vol_24h': 582243.0},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/ETH',
#    'perc_volume': 0.0274535533624,
#    'price': 0.50059,
#    'updated': True,
#    'vol_24h': 571520.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/USDT',
#    'perc_volume': 0.0247325042587,
#    'price': 0.182017,
#    'updated': True,
#    'vol_24h': 514874.0},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/BTC',
#    'perc_volume': 0.0232478545985,
#    'price': 0.452136,
#    'updated': True,
#    'vol_24h': 483967.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/USDT',
#    'perc_volume': 0.022393005362,
#    'price': 0.0909087,
#    'updated': True,
#    'vol_24h': 466171.0},
#   {'currency': 'Loopring',
#    'pair': 'LRC/BTC',
#    'perc_volume': 0.0222852605408,
#    'price': 0.705541,
#    'updated': True,
#    'vol_24h': 463928.0},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/USDT',
#    'perc_volume': 0.0218092234576,
#    'price': 126.095,
#    'updated': True,
#    'vol_24h': 454018.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/ETH',
#    'perc_volume': 0.0216115071473,
#    'price': 1.38523,
#    'updated': True,
#    'vol_24h': 449902.0},
#   {'currency': 'Gas',
#    'pair': 'GAS/BTC',
#    'perc_volume': 0.0214447260421,
#    'price': 44.4814,
#    'updated': True,
#    'vol_24h': 446430.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/ETH',
#    'perc_volume': 0.0203645397766,
#    'price': 0.366144,
#    'updated': True,
#    'vol_24h': 423943.0},
#   {'currency': 'ugChain',
#    'pair': 'UGC/BTC',
#    'perc_volume': 0.020259196757,
#    'price': 0.0919026,
#    'updated': True,
#    'vol_24h': 421750.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/ETH',
#    'perc_volume': 0.0201791206907,
#    'price': 0.899251,
#    'updated': True,
#    'vol_24h': 420083.0},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/USDT',
#    'perc_volume': 0.0201715309975,
#    'price': 2.59065,
#    'updated': True,
#    'vol_24h': 419925.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/USDT',
#    'perc_volume': 0.0197322895152,
#    'price': 4.52423,
#    'updated': True,
#    'vol_24h': 410781.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/ETH',
#    'perc_volume': 0.0194739036958,
#    'price': 0.177549,
#    'updated': True,
#    'vol_24h': 405402.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/BTC',
#    'perc_volume': 0.0193487217948,
#    'price': 0.00433912,
#    'updated': True,
#    'vol_24h': 402796.0},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/ETH',
#    'perc_volume': 0.0191083014515,
#    'price': 0.319286,
#    'updated': True,
#    'vol_24h': 397791.0},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/BTC',
#    'perc_volume': 0.0185548302837,
#    'price': 0.148832,
#    'updated': True,
#    'vol_24h': 386269.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/USDT',
#    'perc_volume': 0.0178084464089,
#    'price': 0.123512,
#    'updated': True,
#    'vol_24h': 370731.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/ETH',
#    'perc_volume': 0.0177203963611,
#    'price': 0.00436803,
#    'updated': True,
#    'vol_24h': 368898.0},
#   {'currency': 'Status',
#    'pair': 'SNT/USDT',
#    'perc_volume': 0.0173265489296,
#    'price': 0.220021,
#    'updated': True,
#    'vol_24h': 360699.0},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/USDT',
#    'perc_volume': 0.0171736982738,
#    'price': 7.06248,
#    'updated': True,
#    'vol_24h': 357517.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/ETH',
#    'perc_volume': 0.0162990581919,
#    'price': 0.34665,
#    'updated': True,
#    'vol_24h': 339309.0},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/USDT',
#    'perc_volume': 0.0162458823038,
#    'price': 0.451643,
#    'updated': True,
#    'vol_24h': 338202.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/ETH',
#    'perc_volume': 0.0157520718885,
#    'price': 29.2508,
#    'updated': True,
#    'vol_24h': 327922.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/ETH',
#    'perc_volume': 0.0146714052626,
#    'price': 0.124572,
#    'updated': True,
#    'vol_24h': 305425.0},
#   {'currency': '0x',
#    'pair': 'ZRX/BTC',
#    'perc_volume': 0.01458498844,
#    'price': 1.13911,
#    'updated': True,
#    'vol_24h': 303626.0},
#   {'currency': 'Primas',
#    'pair': 'PST/USDT',
#    'perc_volume': 0.0143517735016,
#    'price': 0.360034,
#    'updated': True,
#    'vol_24h': 298771.0},
#   {'currency': 'QunQun',
#    'pair': 'QUN/BTC',
#    'perc_volume': 0.0141544895156,
#    'price': 0.0714219,
#    'updated': True,
#    'vol_24h': 294664.0},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/BTC',
#    'perc_volume': 0.01414910948,
#    'price': 0.0724633,
#    'updated': True,
#    'vol_24h': 294552.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/ETH',
#    'perc_volume': 0.0140717234314,
#    'price': 1.95297,
#    'updated': True,
#    'vol_24h': 292941.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/ETH',
#    'perc_volume': 0.0138530634109,
#    'price': 0.0915536,
#    'updated': True,
#    'vol_24h': 288389.0},
#   {'currency': 'LAToken',
#    'pair': 'LA/BTC',
#    'perc_volume': 0.0136021231765,
#    'price': 0.372904,
#    'updated': True,
#    'vol_24h': 283165.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/ETH',
#    'perc_volume': 0.0133566110138,
#    'price': 0.181715,
#    'updated': True,
#    'vol_24h': 278054.0},
#   {'currency': 'Loopring',
#    'pair': 'LRC/USDT',
#    'perc_volume': 0.0129884628598,
#    'price': 0.698167,
#    'updated': True,
#    'vol_24h': 270390.0},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/USDT',
#    'perc_volume': 0.0128563157341,
#    'price': 453.683,
#    'updated': True,
#    'vol_24h': 267639.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/USDT',
#    'perc_volume': 0.0126049431754,
#    'price': 0.178917,
#    'updated': True,
#    'vol_24h': 262406.0},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/ETH',
#    'perc_volume': 0.0121774705211,
#    'price': 0.195205,
#    'updated': True,
#    'vol_24h': 253507.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/ETH',
#    'perc_volume': 0.0117374124263,
#    'price': 0.4508,
#    'updated': True,
#    'vol_24h': 244346.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/USDT',
#    'perc_volume': 0.0115581419526,
#    'price': 0.393024,
#    'updated': True,
#    'vol_24h': 240614.0},
#   {'currency': 'Status',
#    'pair': 'SNT/BTC',
#    'perc_volume': 0.0111873998528,
#    'price': 0.219212,
#    'updated': True,
#    'vol_24h': 232896.0},
#   {'currency': 'Hshare',
#    'pair': 'HSR/ETH',
#    'perc_volume': 0.0111064111018,
#    'price': 12.5317,
#    'updated': True,
#    'vol_24h': 231210.0},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/BTC',
#    'perc_volume': 0.010765019018,
#    'price': 0.0173565,
#    'updated': True,
#    'vol_24h': 224103.0},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/USDT',
#    'perc_volume': 0.0107540187665,
#    'price': 0.361535,
#    'updated': True,
#    'vol_24h': 223874.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/ETH',
#    'perc_volume': 0.0104788683717,
#    'price': 0.393015,
#    'updated': True,
#    'vol_24h': 218146.0},
#   {'currency': 'QunQun',
#    'pair': 'QUN/ETH',
#    'perc_volume': 0.0103410529941,
#    'price': 0.0711403,
#    'updated': True,
#    'vol_24h': 215277.0},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/USDT',
#    'perc_volume': 0.0103292841661,
#    'price': 0.0800076,
#    'updated': True,
#    'vol_24h': 215032.0},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/ETH',
#    'perc_volume': 0.0102581428018,
#    'price': 0.0498953,
#    'updated': True,
#    'vol_24h': 213551.0},
#   {'currency': 'ProChain',
#    'pair': 'PRA/USDT',
#    'perc_volume': 0.0102064560307,
#    'price': 0.360034,
#    'updated': True,
#    'vol_24h': 212475.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/ETH',
#    'perc_volume': 0.0101970409683,
#    'price': 160.252,
#    'updated': True,
#    'vol_24h': 212279.0},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/BTC',
#    'perc_volume': 0.0100900647237,
#    'price': 3.34503,
#    'updated': True,
#    'vol_24h': 210052.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/BCH',
#    'perc_volume': 0.0100190194314,
#    'price': 25.9554,
#    'updated': True,
#    'vol_24h': 208573.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/BTC',
#    'perc_volume': 0.00969511246348,
#    'price': 8.61732,
#    'updated': True,
#    'vol_24h': 201830.0},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/USDT',
#    'perc_volume': 0.00951824379138,
#    'price': 47.7089,
#    'updated': True,
#    'vol_24h': 198148.0},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/BTC',
#    'perc_volume': 0.00950416923382,
#    'price': 0.0617891,
#    'updated': True,
#    'vol_24h': 197855.0},
#   {'currency': 'Datum',
#    'pair': 'DAT/BTC',
#    'perc_volume': 0.00915984695201,
#    'price': 0.0597063,
#    'updated': True,
#    'vol_24h': 190687.0},
#   {'currency': 'district0x',
#    'pair': 'DNT/BTC',
#    'perc_volume': 0.00913919145799,
#    'price': 0.0848732,
#    'updated': True,
#    'vol_24h': 190257.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/ETH',
#    'perc_volume': 0.00909197203792,
#    'price': 0.0464027,
#    'updated': True,
#    'vol_24h': 189274.0},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/BTC',
#    'perc_volume': 0.00904648191503,
#    'price': 0.0394056,
#    'updated': True,
#    'vol_24h': 188327.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/BTC',
#    'perc_volume': 0.00876792096187,
#    'price': 0.0926836,
#    'updated': True,
#    'vol_24h': 182528.0},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/USDT',
#    'perc_volume': 0.00848056941475,
#    'price': 13.0012,
#    'updated': True,
#    'vol_24h': 176546.0},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/BTC',
#    'perc_volume': 0.0082710842765,
#    'price': 0.0860014,
#    'updated': True,
#    'vol_24h': 172185.0},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/BTC',
#    'perc_volume': 0.00804685207623,
#    'price': 270.201,
#    'updated': True,
#    'vol_24h': 167517.0},
#   {'currency': '0x',
#    'pair': 'ZRX/USDT',
#    'perc_volume': 0.00791739496832,
#    'price': 1.16611,
#    'updated': True,
#    'vol_24h': 164822.0},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/BTC',
#    'perc_volume': 0.00790841223022,
#    'price': 0.360407,
#    'updated': True,
#    'vol_24h': 164635.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/BCH',
#    'perc_volume': 0.00775339995296,
#    'price': 161.068,
#    'updated': True,
#    'vol_24h': 161408.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/ETH',
#    'perc_volume': 0.00758407293798,
#    'price': 115.991,
#    'updated': True,
#    'vol_24h': 157883.0},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/BTC',
#    'perc_volume': 0.00757811646993,
#    'price': 0.5049,
#    'updated': True,
#    'vol_24h': 157759.0},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/USDT',
#    'perc_volume': 0.00742853226436,
#    'price': 0.10601,
#    'updated': True,
#    'vol_24h': 154645.0},
#   {'currency': 'Nuls',
#    'pair': 'NULS/BTC',
#    'perc_volume': 0.00719157051545,
#    'price': 3.03278,
#    'updated': True,
#    'vol_24h': 149712.0},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/ETH',
#    'perc_volume': 0.00718465332675,
#    'price': 0.0415795,
#    'updated': True,
#    'vol_24h': 149568.0},
#   {'currency': 'Populous',
#    'pair': 'PPT/BTC',
#    'perc_volume': 0.00713738587066,
#    'price': 35.7642,
#    'updated': True,
#    'vol_24h': 148584.0},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/BTC',
#    'perc_volume': 0.00713608889777,
#    'price': 41.2216,
#    'updated': True,
#    'vol_24h': 148557.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/USDT',
#    'perc_volume': 0.00710207938668,
#    'price': 0.111011,
#    'updated': True,
#    'vol_24h': 147849.0},
#   {'currency': 'RefToken',
#    'pair': 'REF/USDT',
#    'perc_volume': 0.00691276938213,
#    'price': 23.9861,
#    'updated': True,
#    'vol_24h': 143908.0},
#   {'currency': 'Yee',
#    'pair': 'YEE/BTC',
#    'perc_volume': 0.00670275584752,
#    'price': 0.0256876,
#    'updated': True,
#    'vol_24h': 139536.0},
#   {'currency': 'ProChain',
#    'pair': 'PRA/BTC',
#    'perc_volume': 0.00665961949023,
#    'price': 0.363965,
#    'updated': True,
#    'vol_24h': 138638.0},
#   {'currency': 'ugChain',
#    'pair': 'UGC/USDT',
#    'perc_volume': 0.00654476533624,
#    'price': 0.0920088,
#    'updated': True,
#    'vol_24h': 136247.0},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/ETH',
#    'perc_volume': 0.00647876382742,
#    'price': 0.814371,
#    'updated': True,
#    'vol_24h': 134873.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/BTC',
#    'perc_volume': 0.00634378257576,
#    'price': 0.111776,
#    'updated': True,
#    'vol_24h': 132063.0},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/USDT',
#    'perc_volume': 0.0060474002545,
#    'price': 0.0499048,
#    'updated': True,
#    'vol_24h': 125893.0},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/BTC',
#    'perc_volume': 0.00603539124634,
#    'price': 0.106135,
#    'updated': True,
#    'vol_24h': 125643.0},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/USDT',
#    'perc_volume': 0.00594916656779,
#    'price': 0.0619059,
#    'updated': True,
#    'vol_24h': 123848.0},
#   {'currency': 'FunFair',
#    'pair': 'FUN/USDT',
#    'perc_volume': 0.00584905947581,
#    'price': 0.0621059,
#    'updated': True,
#    'vol_24h': 121764.0},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/ETH',
#    'perc_volume': 0.00581235994689,
#    'price': 0.0701949,
#    'updated': True,
#    'vol_24h': 121000.0},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/ETH',
#    'perc_volume': 0.00576883930134,
#    'price': 0.0754295,
#    'updated': True,
#    'vol_24h': 120094.0},
#   {'currency': 'Dent',
#    'pair': 'DENT/BTC',
#    'perc_volume': 0.00568083728958,
#    'price': 0.026729,
#    'updated': True,
#    'vol_24h': 118262.0},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/BTC',
#    'perc_volume': 0.00566998114621,
#    'price': 47.7304,
#    'updated': True,
#    'vol_24h': 118036.0},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/BTC',
#    'perc_volume': 0.00560263462848,
#    'price': 0.049466,
#    'updated': True,
#    'vol_24h': 116634.0},
#   {'currency': 'Dent',
#    'pair': 'DENT/USDT',
#    'perc_volume': 0.00553615275933,
#    'price': 0.0270026,
#    'updated': True,
#    'vol_24h': 115250.0},
#   {'currency': 'Read',
#    'pair': 'READ/USDT',
#    'perc_volume': 0.00549940519438,
#    'price': 0.0360034,
#    'updated': True,
#    'vol_24h': 114485.0},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/USDT',
#    'perc_volume': 0.00540467813806,
#    'price': 273.478,
#    'updated': True,
#    'vol_24h': 112513.0},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/USDT',
#    'perc_volume': 0.00535986051962,
#    'price': 0.0789075,
#    'updated': True,
#    'vol_24h': 111580.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/ETH',
#    'perc_volume': 0.00528463609254,
#    'price': 0.00542721,
#    'updated': True,
#    'vol_24h': 110014.0},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/BTC',
#    'perc_volume': 0.00523712845628,
#    'price': 0.0750668,
#    'updated': True,
#    'vol_24h': 109025.0},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/USDT',
#    'perc_volume': 0.00521570438573,
#    'price': 0.0801077,
#    'updated': True,
#    'vol_24h': 108579.0},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/ETH',
#    'perc_volume': 0.00520969988166,
#    'price': 3.34085,
#    'updated': True,
#    'vol_24h': 108454.0},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/USDT',
#    'perc_volume': 0.00509085873696,
#    'price': 0.0382023,
#    'updated': True,
#    'vol_24h': 105980.0},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/USDT',
#    'perc_volume': 0.00508610316973,
#    'price': 0.742471,
#    'updated': True,
#    'vol_24h': 105881.0},
#   {'currency': 'LAToken',
#    'pair': 'LA/ETH',
#    'perc_volume': 0.00505478367646,
#    'price': 0.367422,
#    'updated': True,
#    'vol_24h': 105229.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/BCH',
#    'perc_volume': 0.00498628429395,
#    'price': 9.59851,
#    'updated': True,
#    'vol_24h': 103803.0},
#   {'currency': 'QunQun',
#    'pair': 'QUN/USDT',
#    'perc_volume': 0.00497067258334,
#    'price': 0.0724069,
#    'updated': True,
#    'vol_24h': 103478.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/USDT',
#    'perc_volume': 0.00468488701088,
#    'price': 8.56422,
#    'updated': True,
#    'vol_24h': 97528.6},
#   {'currency': 'Yee',
#    'pair': 'YEE/USDT',
#    'perc_volume': 0.00461337576912,
#    'price': 0.0262025,
#    'updated': True,
#    'vol_24h': 96039.9},
#   {'currency': 'SmartMesh',
#    'pair': 'SMT/BTC',
#    'perc_volume': 0.00454372832543,
#    'price': 0.0735915,
#    'updated': True,
#    'vol_24h': 94590.0},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/USDT',
#    'perc_volume': 0.00447625211041,
#    'price': 0.0176017,
#    'updated': True,
#    'vol_24h': 93185.3},
#   {'currency': 'SmartMesh',
#    'pair': 'SMT/USDT',
#    'perc_volume': 0.00443071875509,
#    'price': 0.0700067,
#    'updated': True,
#    'vol_24h': 92237.4},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/USDT',
#    'perc_volume': 0.00429235096313,
#    'price': 0.191618,
#    'updated': True,
#    'vol_24h': 89356.9},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/USDT',
#    'perc_volume': 0.00425427280007,
#    'price': 0.122712,
#    'updated': True,
#    'vol_24h': 88564.2},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/BTC',
#    'perc_volume': 0.00415923831314,
#    'price': 7.07919,
#    'updated': True,
#    'vol_24h': 86585.8},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/USDT',
#    'perc_volume': 0.00413468229326,
#    'price': 0.149914,
#    'updated': True,
#    'vol_24h': 86074.6},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/ETH',
#    'perc_volume': 0.00401431840633,
#    'price': 0.0812331,
#    'updated': True,
#    'vol_24h': 83568.9},
#   {'currency': 'RefToken',
#    'pair': 'REF/BTC',
#    'perc_volume': 0.00396392860811,
#    'price': 24.2906,
#    'updated': True,
#    'vol_24h': 82519.9},
#   {'currency': 'StarChain',
#    'pair': 'STC/ETH',
#    'perc_volume': 0.00392485609918,
#    'price': 0.124423,
#    'updated': True,
#    'vol_24h': 81706.5},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/USDT',
#    'perc_volume': 0.00392425564877,
#    'price': 0.0708068,
#    'updated': True,
#    'vol_24h': 81694.0},
#   {'currency': 'Viuly',
#    'pair': 'VIU/BTC',
#    'perc_volume': 0.00378314499935,
#    'price': 0.0280307,
#    'updated': True,
#    'vol_24h': 78756.4},
#   {'currency': 'Monero',
#    'pair': 'XMR/USDT',
#    'perc_volume': 0.00365722814705,
#    'price': 254.768,
#    'updated': True,
#    'vol_24h': 76135.1},
#   {'currency': 'Populous',
#    'pair': 'PPT/USDT',
#    'perc_volume': 0.00364564665958,
#    'price': 33.5032,
#    'updated': True,
#    'vol_24h': 75894.0},
#   {'currency': 'Po.et',
#    'pair': 'POE/BTC',
#    'perc_volume': 0.00346046775384,
#    'price': 0.0631776,
#    'updated': True,
#    'vol_24h': 72039.0},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/USDT',
#    'perc_volume': 0.00333481990332,
#    'price': 0.0934089,
#    'updated': True,
#    'vol_24h': 69423.3},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/ETH',
#    'perc_volume': 0.00331926583595,
#    'price': 8.78359,
#    'updated': True,
#    'vol_24h': 69099.5},
#   {'currency': 'NEM',
#    'pair': 'XEM/ETH',
#    'perc_volume': 0.0033091686619,
#    'price': 0.56883,
#    'updated': True,
#    'vol_24h': 68889.3},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/BTC',
#    'perc_volume': 0.00330099773275,
#    'price': 0.771322,
#    'updated': True,
#    'vol_24h': 68719.2},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/BTC',
#    'perc_volume': 0.00329476745932,
#    'price': 0.768285,
#    'updated': True,
#    'vol_24h': 68589.5},
#   {'currency': 'ProChain',
#    'pair': 'PRA/ETH',
#    'perc_volume': 0.0032047575414,
#    'price': 0.363063,
#    'updated': True,
#    'vol_24h': 66715.7},
#   {'currency': 'Centra',
#    'pair': 'CTR/USDT',
#    'perc_volume': 0.00319456429527,
#    'price': 1.0689,
#    'updated': True,
#    'vol_24h': 66503.5},
#   {'currency': 'Simple Token',
#    'pair': 'OST/BTC',
#    'perc_volume': 0.00318647022378,
#    'price': 0.314586,
#    'updated': True,
#    'vol_24h': 66335.0},
#   {'currency': 'Nuls',
#    'pair': 'NULS/USDT',
#    'perc_volume': 0.00310721557356,
#    'price': 2.95808,
#    'updated': True,
#    'vol_24h': 64685.1},
#   {'currency': 'Bancor',
#    'pair': 'BNT/BTC',
#    'perc_volume': 0.00307381131648,
#    'price': 5.24253,
#    'updated': True,
#    'vol_24h': 63989.7},
#   {'currency': 'Ark',
#    'pair': 'ARK/BTC',
#    'perc_volume': 0.0030190598465,
#    'price': 4.25815,
#    'updated': True,
#    'vol_24h': 62849.9},
#   {'currency': 'TenX',
#    'pair': 'PAY/BTC',
#    'perc_volume': 0.00295026744418,
#    'price': 1.71473,
#    'updated': True,
#    'vol_24h': 61417.8},
#   {'currency': 'Civic',
#    'pair': 'CVC/USDT',
#    'perc_volume': 0.00284117761411,
#    'price': 0.499548,
#    'updated': True,
#    'vol_24h': 59146.8},
#   {'currency': 'district0x',
#    'pair': 'DNT/USDT',
#    'perc_volume': 0.00281679932755,
#    'price': 0.0850081,
#    'updated': True,
#    'vol_24h': 58639.3},
#   {'currency': 'Civic',
#    'pair': 'CVC/BTC',
#    'perc_volume': 0.00278613792793,
#    'price': 0.490321,
#    'updated': True,
#    'vol_24h': 58001.0},
#   {'currency': 'Monaco',
#    'pair': 'MCO/BTC',
#    'perc_volume': 0.00278268894079,
#    'price': 7.77267,
#    'updated': True,
#    'vol_24h': 57929.2},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/BTC',
#    'perc_volume': 0.00275940587578,
#    'price': 0.189706,
#    'updated': True,
#    'vol_24h': 57444.5},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/USDT',
#    'perc_volume': 0.00275826742181,
#    'price': 3.31492,
#    'updated': True,
#    'vol_24h': 57420.8},
#   {'currency': 'Walton',
#    'pair': 'WTC/BTC',
#    'perc_volume': 0.00272897985272,
#    'price': 23.8106,
#    'updated': True,
#    'vol_24h': 56811.1},
#   {'currency': 'Dash',
#    'pair': 'DASH/ETH',
#    'perc_volume': 0.00268959030597,
#    'price': 636.276,
#    'updated': True,
#    'vol_24h': 55991.1},
#   {'currency': 'Populous',
#    'pair': 'PPT/ETH',
#    'perc_volume': 0.00255986899988,
#    'price': 33.0437,
#    'updated': True,
#    'vol_24h': 53290.6},
#   {'currency': 'LAToken',
#    'pair': 'LA/USDT',
#    'perc_volume': 0.0025513570149,
#    'price': 0.360134,
#    'updated': True,
#    'vol_24h': 53113.4},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/ETH',
#    'perc_volume': 0.00254541976127,
#    'price': 0.357496,
#    'updated': True,
#    'vol_24h': 52989.8},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/USDT',
#    'perc_volume': 0.00252540795008,
#    'price': 0.0764073,
#    'updated': True,
#    'vol_24h': 52573.2},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/ETH',
#    'perc_volume': 0.00251431162655,
#    'price': 452.159,
#    'updated': True,
#    'vol_24h': 52342.2},
#   {'currency': 'ugChain',
#    'pair': 'UGC/ETH',
#    'perc_volume': 0.00250470922363,
#    'price': 0.0919125,
#    'updated': True,
#    'vol_24h': 52142.3},
#   {'currency': 'TenX',
#    'pair': 'PAY/USDT',
#    'perc_volume': 0.00243520588803,
#    'price': 1.71236,
#    'updated': True,
#    'vol_24h': 50695.4},
#   {'currency': 'FunFair',
#    'pair': 'FUN/BTC',
#    'perc_volume': 0.00236297410578,
#    'price': 0.0623966,
#    'updated': True,
#    'vol_24h': 49191.7},
#   {'currency': 'Enigma',
#    'pair': 'ENG/BTC',
#    'perc_volume': 0.00229463804578,
#    'price': 3.25929,
#    'updated': True,
#    'vol_24h': 47769.1},
#   {'currency': 'NAGA',
#    'pair': 'NGC/BTC',
#    'perc_volume': 0.00227726821638,
#    'price': 0.961549,
#    'updated': True,
#    'vol_24h': 47407.5},
#   {'currency': 'Delphy',
#    'pair': 'DPY/ETH',
#    'perc_volume': 0.0022750873805,
#    'price': 1.45308,
#    'updated': True,
#    'vol_24h': 47362.1},
#   {'currency': 'Viuly',
#    'pair': 'VIU/USDT',
#    'perc_volume': 0.00223615897967,
#    'price': 0.0276026,
#    'updated': True,
#    'vol_24h': 46551.7},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/USDT',
#    'perc_volume': 0.00219171123869,
#    'price': 0.0281027,
#    'updated': True,
#    'vol_24h': 45626.4},
#   {'currency': 'Super Bitcoin',
#    'pair': 'SBTC/BCH',
#    'perc_volume': 0.00217327500937,
#    'price': 22.6682,
#    'updated': True,
#    'vol_24h': 45242.6},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/BCH',
#    'perc_volume': 0.00216700630711,
#    'price': 6.88857,
#    'updated': True,
#    'vol_24h': 45112.1},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/BTC',
#    'perc_volume': 0.00212208781301,
#    'price': 0.0293325,
#    'updated': True,
#    'vol_24h': 44177.0},
#   {'currency': 'UTRUST',
#    'pair': 'UTK/BTC',
#    'perc_volume': 0.00203863961714,
#    'price': 0.328732,
#    'updated': True,
#    'vol_24h': 42439.8},
#   {'currency': 'Health Mutual Society',
#    'pair': 'HMC/BTC',
#    'perc_volume': 0.00202144752107,
#    'price': 0.0747197,
#    'updated': True,
#    'vol_24h': 42081.9},
#   {'currency': 'Yee',
#    'pair': 'YEE/ETH',
#    'perc_volume': 0.00201961254462,
#    'price': 0.025718,
#    'updated': True,
#    'vol_24h': 42043.7},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/BTC',
#    'perc_volume': 0.00199294293931,
#    'price': 0.0805341,
#    'updated': True,
#    'vol_24h': 41488.5},
#   {'currency': 'Substratum',
#    'pair': 'SUB/BTC',
#    'perc_volume': 0.00196937165811,
#    'price': 0.775141,
#    'updated': True,
#    'vol_24h': 40997.8},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/USDT',
#    'perc_volume': 0.00190237099981,
#    'price': 0.0342033,
#    'updated': True,
#    'vol_24h': 39603.0},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/ETH',
#    'perc_volume': 0.00189817745416,
#    'price': 0.144977,
#    'updated': True,
#    'vol_24h': 39515.7},
#   {'currency': 'Enigma',
#    'pair': 'ENG/USDT',
#    'perc_volume': 0.00183921802772,
#    'price': 3.33892,
#    'updated': True,
#    'vol_24h': 38288.3},
#   {'currency': 'Read',
#    'pair': 'READ/BTC',
#    'perc_volume': 0.00182229493343,
#    'price': 0.0361883,
#    'updated': True,
#    'vol_24h': 37936.0},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/ETH',
#    'perc_volume': 0.0017877858476,
#    'price': 0.124301,
#    'updated': True,
#    'vol_24h': 37217.6},
#   {'currency': 'Walton',
#    'pair': 'WTC/USDT',
#    'perc_volume': 0.00174957318365,
#    'price': 23.5461,
#    'updated': True,
#    'vol_24h': 36422.1},
#   {'currency': 'Monetha',
#    'pair': 'MTH/BTC',
#    'perc_volume': 0.001741844186,
#    'price': 0.156208,
#    'updated': True,
#    'vol_24h': 36261.2},
#   {'currency': 'StarChain',
#    'pair': 'STC/BTC',
#    'perc_volume': 0.00172251929008,
#    'price': 0.119847,
#    'updated': True,
#    'vol_24h': 35858.9},
#   {'currency': 'Viberate',
#    'pair': 'VIB/USDT',
#    'perc_volume': 0.00166711933366,
#    'price': 0.272426,
#    'updated': True,
#    'vol_24h': 34705.6},
#   {'currency': 'Datum',
#    'pair': 'DAT/USDT',
#    'perc_volume': 0.00166529396442,
#    'price': 0.0600057,
#    'updated': True,
#    'vol_24h': 34667.6},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/BTC',
#    'perc_volume': 0.00163762520963,
#    'price': 0.186322,
#    'updated': True,
#    'vol_24h': 34091.6},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/BTC',
#    'perc_volume': 0.0015991483475,
#    'price': 0.397203,
#    'updated': True,
#    'vol_24h': 33290.6},
#   {'currency': 'Golem',
#    'pair': 'GNT/USDT',
#    'perc_volume': 0.00159800989353,
#    'price': 0.353134,
#    'updated': True,
#    'vol_24h': 33266.9},
#   {'currency': 'Aventus',
#    'pair': 'AVT/BTC',
#    'perc_volume': 0.00152984676325,
#    'price': 2.53274,
#    'updated': True,
#    'vol_24h': 31847.9},
#   {'currency': 'Loopring',
#    'pair': 'LRC/ETH',
#    'perc_volume': 0.00152012907385,
#    'price': 0.701248,
#    'updated': True,
#    'vol_24h': 31645.6},
#   {'currency': 'Aventus',
#    'pair': 'AVT/USDT',
#    'perc_volume': 0.00150366232186,
#    'price': 2.48394,
#    'updated': True,
#    'vol_24h': 31302.8},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/USDT',
#    'perc_volume': 0.00144477494948,
#    'price': 0.401738,
#    'updated': True,
#    'vol_24h': 30076.9},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/BTC',
#    'perc_volume': 0.00141465635703,
#    'price': 0.54239,
#    'updated': True,
#    'vol_24h': 29449.9},
#   {'currency': 'Maker',
#    'pair': 'MKR/USDT',
#    'perc_volume': 0.00138998505067,
#    'price': 1078.44,
#    'updated': True,
#    'vol_24h': 28936.3},
#   {'currency': 'Health Mutual Society',
#    'pair': 'HMC/USDT',
#    'perc_volume': 0.00138403338623,
#    'price': 0.0739071,
#    'updated': True,
#    'vol_24h': 28812.4},
#   {'currency': 'Gas',
#    'pair': 'GAS/USDT',
#    'perc_volume': 0.00136641857307,
#    'price': 43.3637,
#    'updated': True,
#    'vol_24h': 28445.7},
#   {'currency': 'NAGA',
#    'pair': 'NGC/ETH',
#    'perc_volume': 0.00134770853836,
#    'price': 0.975025,
#    'updated': True,
#    'vol_24h': 28056.2},
#   {'currency': 'Enigma',
#    'pair': 'ENG/ETH',
#    'perc_volume': 0.00133335537182,
#    'price': 3.20951,
#    'updated': True,
#    'vol_24h': 27757.4},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/ETH',
#    'perc_volume': 0.0012458481312,
#    'price': 2.5752,
#    'updated': True,
#    'vol_24h': 25935.7},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/USDT',
#    'perc_volume': 0.00122659528932,
#    'price': 0.768273,
#    'updated': True,
#    'vol_24h': 25534.9},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/ETH',
#    'perc_volume': 0.001225231066,
#    'price': 7.0115,
#    'updated': True,
#    'vol_24h': 25506.5},
#   {'currency': 'IPChain',
#    'pair': 'IPC/BTC',
#    'perc_volume': 0.00121046959317,
#    'price': 0.730014,
#    'updated': True,
#    'vol_24h': 25199.2},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/ETH',
#    'perc_volume': 0.00120343231439,
#    'price': 0.102811,
#    'updated': True,
#    'vol_24h': 25052.7},
#   {'currency': 'Read',
#    'pair': 'READ/ETH',
#    'perc_volume': 0.00120267334508,
#    'price': 0.0359772,
#    'updated': True,
#    'vol_24h': 25036.9},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/ETH',
#    'perc_volume': 0.00117970251428,
#    'price': 0.454328,
#    'updated': True,
#    'vol_24h': 24558.7},
#   {'currency': 'Maker',
#    'pair': 'MKR/BTC',
#    'perc_volume': 0.00115038612357,
#    'price': 1075.36,
#    'updated': True,
#    'vol_24h': 23948.4},
#   {'currency': 'IPChain',
#    'pair': 'IPC/USDT',
#    'perc_volume': 0.00115016515782,
#    'price': 0.700067,
#    'updated': True,
#    'vol_24h': 23943.8},
#   {'currency': 'Storj',
#    'pair': 'STORJ/USDT',
#    'perc_volume': 0.0011414418143,
#    'price': 1.03,
#    'updated': True,
#    'vol_24h': 23762.2},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/BTC',
#    'perc_volume': 0.0011364412633,
#    'price': 0.077757,
#    'updated': True,
#    'vol_24h': 23658.1},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/BTC',
#    'perc_volume': 0.00111115029213,
#    'price': 0.154473,
#    'updated': True,
#    'vol_24h': 23131.6},
#   {'currency': 'Simple Token',
#    'pair': 'OST/USDT',
#    'perc_volume': 0.00110739867798,
#    'price': 0.289128,
#    'updated': True,
#    'vol_24h': 23053.5},
#   {'currency': 'SONM',
#    'pair': 'SNM/BTC',
#    'perc_volume': 0.00109781068587,
#    'price': 0.223291,
#    'updated': True,
#    'vol_24h': 22853.9},
#   {'currency': 'Achain',
#    'pair': 'ACT/BCH',
#    'perc_volume': 0.0010857824633,
#    'price': 0.444634,
#    'updated': True,
#    'vol_24h': 22603.5},
#   {'currency': 'Change',
#    'pair': 'CAG/BTC',
#    'perc_volume': 0.00106342649372,
#    'price': 0.348171,
#    'updated': True,
#    'vol_24h': 22138.1},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/USDT',
#    'perc_volume': 0.0010492606677,
#    'price': 0.153615,
#    'updated': True,
#    'vol_24h': 21843.2},
#   {'currency': 'Status',
#    'pair': 'SNT/ETH',
#    'perc_volume': 0.00103863990089,
#    'price': 0.218988,
#    'updated': True,
#    'vol_24h': 21622.1},
#   {'currency': 'Po.et',
#    'pair': 'POE/USDT',
#    'perc_volume': 0.00102280242094,
#    'price': 0.062606,
#    'updated': True,
#    'vol_24h': 21292.4},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/USDT',
#    'perc_volume': 0.00101990584817,
#    'price': 0.240123,
#    'updated': True,
#    'vol_24h': 21232.1},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/ETH',
#    'perc_volume': 0.00100377054481,
#    'price': 0.0789484,
#    'updated': True,
#    'vol_24h': 20896.2},
#   {'currency': 'Leverj',
#    'pair': 'LEV/BTC',
#    'perc_volume': 0.000984051753422,
#    'price': 0.105875,
#    'updated': True,
#    'vol_24h': 20485.7},
#   {'currency': '0x',
#    'pair': 'ZRX/ETH',
#    'perc_volume': 0.000974295635197,
#    'price': 1.16894,
#    'updated': True,
#    'vol_24h': 20282.6},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/BTC',
#    'perc_volume': 0.000971475920083,
#    'price': 0.0910348,
#    'updated': True,
#    'vol_24h': 20223.9},
#   {'currency': 'OAX',
#    'pair': 'OAX/USDT',
#    'perc_volume': 0.000966153527668,
#    'price': 0.73247,
#    'updated': True,
#    'vol_24h': 20113.1},
#   {'currency': 'Monaco',
#    'pair': 'MCO/USDT',
#    'perc_volume': 0.000948538714507,
#    'price': 7.72194,
#    'updated': True,
#    'vol_24h': 19746.4},
#   {'currency': 'UTRUST',
#    'pair': 'UTK/ETH',
#    'perc_volume': 0.000947443492963,
#    'price': 0.298278,
#    'updated': True,
#    'vol_24h': 19723.6},
#   {'currency': 'SunContract',
#    'pair': 'SNC/USDT',
#    'perc_volume': 0.000939652048472,
#    'price': 0.240823,
#    'updated': True,
#    'vol_24h': 19561.4},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/USDT',
#    'perc_volume': 0.000910297228939,
#    'price': 0.490647,
#    'updated': True,
#    'vol_24h': 18950.3},
#   {'currency': 'Datum',
#    'pair': 'DAT/ETH',
#    'perc_volume': 0.000907059600341,
#    'price': 0.0591829,
#    'updated': True,
#    'vol_24h': 18882.9},
#   {'currency': 'All Sports',
#    'pair': 'SOC/ETH',
#    'perc_volume': 0.000899205709007,
#    'price': 0.112028,
#    'updated': True,
#    'vol_24h': 18719.4},
#   {'currency': 'district0x',
#    'pair': 'DNT/ETH',
#    'perc_volume': 0.000892999453593,
#    'price': 0.0857237,
#    'updated': True,
#    'vol_24h': 18590.2},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/ETH',
#    'perc_volume': 0.000884266502863,
#    'price': 0.0192053,
#    'updated': True,
#    'vol_24h': 18408.4},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/USDT',
#    'perc_volume': 0.000836778081016,
#    'price': 0.504748,
#    'updated': True,
#    'vol_24h': 17419.8},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/USDT',
#    'perc_volume': 0.000818610853479,
#    'price': 2.50024,
#    'updated': True,
#    'vol_24h': 17041.6},
#   {'currency': 'BitcoinX',
#    'pair': 'BCX/BCH',
#    'perc_volume': 0.000799386833225,
#    'price': 0.0106767,
#    'updated': True,
#    'vol_24h': 16641.4},
#   {'currency': 'SALT',
#    'pair': 'SALT/USDT',
#    'perc_volume': 0.000787329789038,
#    'price': 4.59294,
#    'updated': True,
#    'vol_24h': 16390.4},
#   {'currency': 'Request Network',
#    'pair': 'REQ/USDT',
#    'perc_volume': 0.000773615501725,
#    'price': 0.30943,
#    'updated': True,
#    'vol_24h': 16104.9},
#   {'currency': 'Delphy',
#    'pair': 'DPY/BTC',
#    'perc_volume': 0.000755698061558,
#    'price': 1.38982,
#    'updated': True,
#    'vol_24h': 15731.9},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/ETH',
#    'perc_volume': 0.000751384425829,
#    'price': 0.0762348,
#    'updated': True,
#    'vol_24h': 15642.1},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/ETH',
#    'perc_volume': 0.000740629158126,
#    'price': 12.9835,
#    'updated': True,
#    'vol_24h': 15418.2},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/BTC',
#    'perc_volume': 0.00073786708625,
#    'price': 0.435648,
#    'updated': True,
#    'vol_24h': 15360.7},
#   {'currency': 'RefToken',
#    'pair': 'REF/ETH',
#    'perc_volume': 0.000702171510411,
#    'price': 25.254,
#    'updated': True,
#    'vol_24h': 14617.6},
#   {'currency': 'Storj',
#    'pair': 'STORJ/BTC',
#    'perc_volume': 0.000701441362715,
#    'price': 1.03505,
#    'updated': True,
#    'vol_24h': 14602.4},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/USDT',
#    'perc_volume': 0.000681636106466,
#    'price': 0.186318,
#    'updated': True,
#    'vol_24h': 14190.1},
#   {'currency': 'Metal',
#    'pair': 'MTL/BTC',
#    'perc_volume': 0.000663401628484,
#    'price': 4.23672,
#    'updated': True,
#    'vol_24h': 13810.5},
#   {'currency': 'Maker',
#    'pair': 'MKR/ETH',
#    'perc_volume': 0.000662176709652,
#    'price': 1071.76,
#    'updated': True,
#    'vol_24h': 13785.0},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/BTC',
#    'perc_volume': 0.000649754591617,
#    'price': 0.442937,
#    'updated': True,
#    'vol_24h': 13526.4},
#   {'currency': 'AirSwap',
#    'pair': 'AST/BTC',
#    'perc_volume': 0.000630794769542,
#    'price': 0.694173,
#    'updated': True,
#    'vol_24h': 13131.7},
#   {'currency': 'Substratum',
#    'pair': 'SUB/ETH',
#    'perc_volume': 0.00062649074102,
#    'price': 0.78088,
#    'updated': True,
#    'vol_24h': 13042.1},
#   {'currency': 'Bancor',
#    'pair': 'BNT/USDT',
#    'perc_volume': 0.000609044053973,
#    'price': 5.2254,
#    'updated': True,
#    'vol_24h': 12678.9},
#   {'currency': 'SmartMesh',
# ...
#    'pair': 'CAN/ETH',
#    'perc_volume': 0.000575923209482,
#    'price': 0.0346641,
#    'updated': True,
#    'vol_24h': 11989.4},
#   {'currency': 'Civic',
#    'pair': 'CVC/ETH',
#    'perc_volume': 0.000552462411151,
#    'price': 0.497851,
#    'updated': True,
#    'vol_24h': 11501.0},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/USDT',
#    'perc_volume': 0.000545703741361,
#    'price': 1.83428,
#    'updated': True,
#    'vol_24h': 11360.3},
#   {'currency': 'Po.et',
#    'pair': 'POE/ETH',
#    'perc_volume': 0.000544382750464,
#    'price': 0.0673325,
#    'updated': True,
#    'vol_24h': 11332.8},
#   {'currency': 'Change',
#    'pair': 'CAG/USDT',
#    'perc_volume': 0.00054042938498,
#    'price': 0.348033,
#    'updated': True,
#    'vol_24h': 11250.5},
#   {'currency': 'Dent',
#    'pair': 'DENT/ETH',
#    'perc_volume': 0.000532186401782,
#    'price': 0.0271361,
#    'updated': True,
#    'vol_24h': 11078.9},
#   {'currency': 'BT2 [CST]',
#    'pair': 'BT2/BTC',
#    'perc_volume': 0.000527181047183,
#    'price': 61.9494,
#    'updated': True,
#    'vol_24h': 10974.7},
#   {'currency': 'Leverj',
#    'pair': 'LEV/USDT',
#    'perc_volume': 0.000526787151716,
#    'price': 0.10601,
#    'updated': True,
#    'vol_24h': 10966.5},
#   {'currency': 'Ark',
#    'pair': 'ARK/USDT',
#    'perc_volume': 0.000523933811378,
#    'price': 4.29511,
#    'updated': True,
#    'vol_24h': 10907.1},
#   {'currency': 'Dash',
#    'pair': 'DASH/BCH',
#    'perc_volume': 0.000519841141399,
#    'price': 633.378,
#    'updated': True,
#    'vol_24h': 10821.9},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/USDT',
#    'perc_volume': 0.000509105088109,
#    'price': 0.434342,
#    'updated': True,
#    'vol_24h': 10598.4},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/USDT',
#    'perc_volume': 0.000500612317542,
#    'price': 0.31003,
#    'updated': True,
#    'vol_24h': 10421.6},
#   {'currency': 'SONM',
#    'pair': 'SNM/USDT',
#    'perc_volume': 0.000495861553916,
#    'price': 0.223221,
#    'updated': True,
#    'vol_24h': 10322.7},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/BTC',
#    'perc_volume': 0.000473569952619,
#    'price': 1.83354,
#    'updated': True,
#    'vol_24h': 9858.64},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/ETH',
#    'perc_volume': 0.000467425663686,
#    'price': 0.225177,
#    'updated': True,
#    'vol_24h': 9730.73},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/USDT',
#    'perc_volume': 0.000453715219256,
#    'price': 0.439742,
#    'updated': True,
#    'vol_24h': 9445.31},
#   {'currency': 'NAGA',
#    'pair': 'NGC/USDT',
#    'perc_volume': 0.000452295274132,
#    'price': 0.964092,
#    'updated': True,
#    'vol_24h': 9415.75},
#   {'currency': 'SingularDTV',
#    'pair': 'SNGLS/BTC',
#    'perc_volume': 0.000447257735391,
#    'price': 0.154473,
#    'updated': True,
#    'vol_24h': 9310.88},
#   {'currency': 'IPChain',
#    'pair': 'IPC/ETH',
#    'perc_volume': 0.000445539966865,
#    'price': 0.760475,
#    'updated': True,
#    'vol_24h': 9275.12},
#   {'currency': 'Bread',
#    'pair': 'BRD/BTC',
#    'perc_volume': 0.000425682831701,
#    'price': 0.950181,
#    'updated': True,
#    'vol_24h': 8861.74},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/ETH',
#    'perc_volume': 0.000395009903432,
#    'price': 0.190723,
#    'updated': True,
#    'vol_24h': 8223.2},
#   {'currency': 'Substratum',
#    'pair': 'SUB/USDT',
#    'perc_volume': 0.000365962034147,
#    'price': 0.779575,
#    'updated': True,
#    'vol_24h': 7618.49},
#   {'currency': 'Request Network',
#    'pair': 'REQ/ETH',
#    'perc_volume': 0.000360478721024,
#    'price': 0.31505,
#    'updated': True,
#    'vol_24h': 7504.34},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/ETH',
#    'perc_volume': 0.000348075817402,
#    'price': 271.123,
#    'updated': True,
#    'vol_24h': 7246.14},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/BTC',
#    'perc_volume': 0.0003459824071,
#    'price': 1.38852,
#    'updated': True,
#    'vol_24h': 7202.56},
#   {'currency': 'Viberate',
#    'pair': 'VIB/ETH',
#    'perc_volume': 0.000341309942207,
#    'price': 0.269785,
#    'updated': True,
#    'vol_24h': 7105.29},
#   {'currency': 'SunContract',
#    'pair': 'SNC/ETH',
#    'perc_volume': 0.00033969401007,
#    'price': 0.237686,
#    'updated': True,
#    'vol_24h': 7071.65},
#   {'currency': 'Primas',
#    'pair': 'PST/BTC',
#    'perc_volume': 0.000338149171261,
#    'price': 0.333331,
#    'updated': True,
#    'vol_24h': 7039.49},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/ETH',
#    'perc_volume': 0.000322987077925,
#    'price': 0.761561,
#    'updated': True,
#    'vol_24h': 6723.85},
#   {'currency': 'Request Network',
#    'pair': 'REQ/BTC',
#    'perc_volume': 0.000320132776867,
#    'price': 0.31745,
#    'updated': True,
#    'vol_24h': 6664.43},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/BCH',
#    'perc_volume': 0.000318618200758,
#    'price': 126.214,
#    'updated': True,
#    'vol_24h': 6632.9},
#   {'currency': 'Ace',
#    'pair': 'ACE/USDT',
#    'perc_volume': 0.000309692145177,
#    'price': 0.384137,
#    'updated': True,
#    'vol_24h': 6447.08},
#   {'currency': 'Viuly',
#    'pair': 'VIU/ETH',
#    'perc_volume': 0.000301911748974,
#    'price': 0.0271361,
#    'updated': True,
#    'vol_24h': 6285.11},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/ETH',
#    'perc_volume': 0.000294473369323,
#    'price': 0.0904331,
#    'updated': True,
#    'vol_24h': 6130.26},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/ETH',
#    'perc_volume': 0.000288724416939,
#    'price': 0.518947,
#    'updated': True,
#    'vol_24h': 6010.58},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/USDT',
#    'perc_volume': 0.000283806487919,
#    'price': 1.34593,
#    'updated': True,
#    'vol_24h': 5908.2},
#   {'currency': 'UTRUST',
#    'pair': 'UTK/USDT',
#    'perc_volume': 0.000282112257049,
#    'price': 0.319631,
#    'updated': True,
#    'vol_24h': 5872.93},
#   {'currency': 'OAX',
#    'pair': 'OAX/BTC',
#    'perc_volume': 0.000282081994348,
#    'price': 0.750147,
#    'updated': True,
#    'vol_24h': 5872.3},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/BTC',
#    'perc_volume': 0.000278439902355,
#    'price': 0.319793,
#    'updated': True,
#    'vol_24h': 5796.48},
#   {'currency': 'Nano',
#    'pair': 'NANO/USDT',
#    'perc_volume': 0.00027554525103,
#    'price': 12.1018,
#    'updated': True,
#    'vol_24h': 5736.22},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/BTC',
#    'perc_volume': 0.000266555787885,
#    'price': 2.11662,
#    'updated': True,
#    'vol_24h': 5549.08},
#   {'currency': 'Monero',
#    'pair': 'XMR/ETH',
#    'perc_volume': 0.000241919067476,
#    'price': 257.125,
#    'updated': True,
#    'vol_24h': 5036.2},
#   {'currency': 'Bread',
#    'pair': 'BRD/USDT',
#    'perc_volume': 0.000241196605545,
#    'price': 0.929989,
#    'updated': True,
#    'vol_24h': 5021.16},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/BCH',
#    'perc_volume': 0.00022067561241,
#    'price': 273.311,
#    'updated': True,
#    'vol_24h': 4593.96},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/ETH',
#    'perc_volume': 0.000218236823034,
#    'price': 0.0402065,
#    'updated': True,
#    'vol_24h': 4543.19},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/BTC',
#    'perc_volume': 0.000206553499181,
#    'price': 2.97499,
#    'updated': True,
#    'vol_24h': 4299.97},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/USDT',
#    'perc_volume': 0.000202426723618,
#    'price': 3.0913,
#    'updated': True,
#    'vol_24h': 4214.06},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/BCH',
#    'perc_volume': 0.000199129049979,
#    'price': 0.187986,
#    'updated': True,
#    'vol_24h': 4145.41},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/BTC',
#    'perc_volume': 0.000188221988412,
#    'price': 0.0341055,
#    'updated': True,
#    'vol_24h': 3918.35},
#   {'currency': 'Everex',
#    'pair': 'EVX/BTC',
#    'perc_volume': 0.000187388082886,
#    'price': 2.02012,
#    'updated': True,
#    'vol_24h': 3900.99},
#   {'currency': 'Walton',
#    'pair': 'WTC/ETH',
#    'perc_volume': 0.000183986651416,
#    'price': 23.494,
#    'updated': True,
#    'vol_24h': 3830.18},
#   {'currency': 'Maggie',
#    'pair': 'MAG/USDT',
#    'perc_volume': 0.000182449498373,
#    'price': 0.0332032,
#    'updated': True,
#    'vol_24h': 3798.18},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/BTC',
#    'perc_volume': 0.000174877578551,
#    'price': 1.70675,
#    'updated': True,
#    'vol_24h': 3640.55},
#   {'currency': 'Metal',
#    'pair': 'MTL/USDT',
#    'perc_volume': 0.000174219965264,
#    'price': 4.1856,
#    'updated': True,
#    'vol_24h': 3626.86},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/ETH',
#    'perc_volume': 0.000172835086444,
#    'price': 0.517844,
#    'updated': True,
#    'vol_24h': 3598.03},
#   {'currency': 'SingularDTV',
#    'pair': 'SNGLS/USDT',
#    'perc_volume': 0.000169737723061,
#    'price': 0.153815,
#    'updated': True,
#    'vol_24h': 3533.55},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/ETH',
#    'perc_volume': 0.000168125153446,
#    'price': 0.183825,
#    'updated': True,
#    'vol_24h': 3499.98},
#   {'currency': 'Golem',
#    'pair': 'GNT/ETH',
#    'perc_volume': 0.000167507410066,
#    'price': 0.353574,
#    'updated': True,
#    'vol_24h': 3487.12},
#   {'currency': 'Nano',
#    'pair': 'NANO/ETH',
#    'perc_volume': 0.000153471761695,
#    'price': 11.3459,
#    'updated': True,
#    'vol_24h': 3194.93},
#   {'currency': 'Health Mutual Society',
#    'pair': 'HMC/ETH',
#    'perc_volume': 0.000146935979097,
#    'price': 0.0675513,
#    'updated': True,
#    'vol_24h': 3058.87},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/ETH',
#    'perc_volume': 0.000145259041198,
#    'price': 0.0294558,
#    'updated': True,
#    'vol_24h': 3023.96},
#   {'currency': 'Monetha',
#    'pair': 'MTH/USDT',
#    'perc_volume': 0.000144249323793,
#    'price': 0.150414,
#    'updated': True,
#    'vol_24h': 3002.94},
#   {'currency': 'Everex',
#    'pair': 'EVX/USDT',
#    'perc_volume': 0.000143401007457,
#    'price': 1.90008,
#    'updated': True,
#    'vol_24h': 2985.28},
#   {'currency': 'Aventus',
#    'pair': 'AVT/ETH',
#    'perc_volume': 0.000139629698536,
#    'price': 2.60073,
#    'updated': True,
#    'vol_24h': 2906.77},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/ETH',
#    'perc_volume': 0.000136638014424,
#    'price': 3.10507,
#    'updated': True,
#    'vol_24h': 2844.49},
#   {'currency': 'Maggie',
#    'pair': 'MAG/ETH',
#    'perc_volume': 0.000135479865678,
#    'price': 0.03378,
#    'updated': True,
#    'vol_24h': 2820.38},
#   {'currency': 'SALT',
#    'pair': 'SALT/BTC',
#    'perc_volume': 0.000128069346926,
#    'price': 4.5953,
#    'updated': True,
#    'vol_24h': 2666.11},
#   {'currency': 'FunFair',
#    'pair': 'FUN/ETH',
#    'perc_volume': 0.000124295155843,
#    'price': 0.0621854,
#    'updated': True,
#    'vol_24h': 2587.54},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/ETH',
#    'perc_volume': 0.000123919994428,
#    'price': 1.83714,
#    'updated': True,
#    'vol_24h': 2579.73},
#   {'currency': 'OAX',
#    'pair': 'OAX/ETH',
#    'perc_volume': 0.000123558283102,
#    'price': 0.749157,
#    'updated': True,
#    'vol_24h': 2572.2},
#   {'currency': 'Nuls',
#    'pair': 'NULS/ETH',
#    'perc_volume': 0.000120058377766,
#    'price': 2.97621,
#    'updated': True,
#    'vol_24h': 2499.34},
#   {'currency': 'AirSwap',
#    'pair': 'AST/USDT',
#    'perc_volume': 0.000114565457436,
#    'price': 0.662263,
#    'updated': True,
#    'vol_24h': 2384.99},
#   {'currency': 'Maggie',
#    'pair': 'MAG/BTC',
#    'perc_volume': 0.000113706573173,
#    'price': 0.0342791,
#    'updated': True,
#    'vol_24h': 2367.11},
#   {'currency': 'Primas',
#    'pair': 'PST/ETH',
#    'perc_volume': 0.000108573442727,
#    'price': 0.382689,
#    'updated': True,
#    'vol_24h': 2260.25},
#   {'currency': 'Metal',
#    'pair': 'MTL/ETH',
#    'perc_volume': 0.000108293873017,
#    'price': 4.38107,
#    'updated': True,
#    'vol_24h': 2254.43},
#   {'currency': 'Storj',
#    'pair': 'STORJ/ETH',
#    'perc_volume': 9.79656456438e-05,
#    'price': 1.04189,
#    'updated': True,
#    'vol_24h': 2039.42},
#   {'currency': 'Change',
#    'pair': 'CAG/ETH',
#    'perc_volume': 9.18391300435e-05,
#    'price': 0.364061,
#    'updated': True,
#    'vol_24h': 1911.88},
#   {'currency': 'TenX',
#    'pair': 'PAY/ETH',
#    'perc_volume': 8.47139453252e-05,
#    'price': 1.72631,
#    'updated': True,
#    'vol_24h': 1763.55},
#   {'currency': 'AirSwap',
#    'pair': 'AST/ETH',
#    'perc_volume': 6.89879089664e-05,
#    'price': 0.69169,
#    'updated': True,
#    'vol_24h': 1436.17},
#   {'currency': 'Gas',
#    'pair': 'GAS/ETH',
#    'perc_volume': 6.86506960174e-05,
#    'price': 42.7702,
#    'updated': True,
#    'vol_24h': 1429.15},
#   {'currency': 'Leverj',
#    'pair': 'LEV/ETH',
#    'perc_volume': 6.73152943106e-05,
#    'price': 0.10998,
#    'updated': True,
#    'vol_24h': 1401.35},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/USDT',
#    'perc_volume': 6.5965481794e-05,
#    'price': 1.81387,
#    'updated': True,
#    'vol_24h': 1373.25},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/USDT',
#    'perc_volume': 6.53371704873e-05,
#    'price': 2.1063,
#    'updated': True,
#    'vol_24h': 1360.17},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/ETH',
#    'perc_volume': 6.44874130703e-05,
#    'price': 0.43507,
#    'updated': True,
#    'vol_24h': 1342.48},
#   {'currency': 'Ace',
#    'pair': 'ACE/ETH',
#    'perc_volume': 6.18953887502e-05,
#    'price': 0.391871,
#    'updated': True,
#    'vol_24h': 1288.52},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/ETH',
#    'perc_volume': 4.62827654644e-05,
#    'price': 0.152969,
#    'updated': True,
#    'vol_24h': 963.501},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/ETH',
#    'perc_volume': 4.08565671837e-05,
#    'price': 0.362065,
#    'updated': True,
#    'vol_24h': 850.54},
#   {'currency': 'Monaco',
#    'pair': 'MCO/ETH',
#    'perc_volume': 3.57803594367e-05,
#    'price': 7.68574,
#    'updated': True,
#    'vol_24h': 744.865},
#   {'currency': 'Everex',
#    'pair': 'EVX/ETH',
#    'perc_volume': 3.53960711758e-05,
#    'price': 2.01048,
#    'updated': True,
#    'vol_24h': 736.865},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/ETH',
#    'perc_volume': 3.29483470976e-05,
#    'price': 1.76722,
#    'updated': True,
#    'vol_24h': 685.909},
#   {'currency': 'Monetha',
#    'pair': 'MTH/ETH',
#    'perc_volume': 2.41526613089e-05,
#    'price': 0.158571,
#    'updated': True,
#    'vol_24h': 502.803},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/USDT',
#    'perc_volume': 2.16928801866e-05,
#    'price': 39.2071,
#    'updated': True,
#    'vol_24h': 451.596},
#   {'currency': 'Simple Token',
#    'pair': 'OST/ETH',
#    'perc_volume': 1.99596440576e-05,
#    'price': 0.343639,
#    'updated': True,
#    'vol_24h': 415.514},
#   {'currency': 'SONM',
#    'pair': 'SNM/ETH',
#    'perc_volume': 1.91268913962e-05,
#    'price': 0.226464,
#    'updated': True,
#    'vol_24h': 398.178},
#   {'currency': 'SALT',
#    'pair': 'SALT/ETH',
#    'perc_volume': 1.71907510654e-05,
#    'price': 4.7074,
#    'updated': True,
#    'vol_24h': 357.872},
#   {'currency': 'SingularDTV',
#    'pair': 'SNGLS/ETH',
#    'perc_volume': 1.63191372535e-05,
#    'price': 0.153739,
#    'updated': True,
#    'vol_24h': 339.727},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/ETH',
#    'perc_volume': 1.35197413806e-05,
#    'price': 2.17539,
#    'updated': True,
#    'vol_24h': 281.45},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/ETH',
#    'perc_volume': 1.06263870279e-05,
#    'price': 1.37631,
#    'updated': True,
#    'vol_24h': 221.217},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/ETH',
#    'perc_volume': 7.76430413237e-06,
#    'price': 0.397517,
#    'updated': True,
#    'vol_24h': 161.635},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/BCH',
#    'perc_volume': 6.37169151071e-06,
#    'price': 2.09454,
#    'updated': True,
#    'vol_24h': 132.644},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/ETH',
#    'perc_volume': 2.86940358687e-06,
#    'price': 36.9346,
#    'updated': True,
#    'vol_24h': 59.7344},
#   {'currency': 'Bancor',
#    'pair': 'BNT/ETH',
#    'perc_volume': 3.59257645075e-07,
#    'price': 5.26084,
#    'updated': True,
#    'vol_24h': 7.47892},
#   {'currency': 'Aventus',
#    'pair': 'AVT/BCH',
#    'perc_volume': 2.49579853958e-08,
#    'price': 2.47747,
#    'updated': True,
#    'vol_24h': 0.519568},
#   {'currency': 'Bread',
#    'pair': 'BRD/ETH',
#    'perc_volume': 0.0,
#    'price': 1.03411,
#    'updated': True,
#    'vol_24h': None}],
#  'name': 'OKEx ',
#  'social': {'twitter': {'link': 'https://twitter.com/CoinMarketCap',
#    'username': '@OKEx_'}},
#  'volume': 2081770590.7,
#  'web': 'https://www.okex.com'}

# %% [markdown]
# In order to obtain all available values for the `name` parameter, use:

# %%
cmc.exchange_slugs
# Out:
# ['abucoins',
#  'acx',
#  'aex',
#  'aidos-market',
#  'alcurex',
#  'allcoin',
#  'altcoin-trader',
#  'bancor-network',
#  'barterdex',
#  'bcex',
#  'bibox',
#  'bigone',
#  'binance',
#  'bisq',
#  'bit-z',
#  'bit2c',
#  'bitbank',
#  'bitbay',
#  'bitcoin-indonesia',
#  'bitcointoyou',
#  'bitcointrade',
#  'bitex-la',
#  'bitfinex',
#  'bitflip',
#  'bitflyer',
#  'bitgrail',
#  'bitholic',
#  'bithumb',
#  'bitinka',
#  'bitkonan',
#  'bitlish',
#  'bitmarket',
#  'bitmaszyna',
#  'bitmex',
#  'bitonic',
#  'bits-blockchain',
#  'bitsane',
#  'bitshares-asset-exchange',
#  'bitso',
#  'bitstamp',
#  'bitstamp-ripple-gateway',
#  'bittrex',
#  'bittylicious',
#  'bl3p',
#  'bleutrade',
#  'braziliex',
#  'btc-alpha',
#  'btc-markets',
#  'btc-trade-ua',
#  'btcbox',
#  'btcc',
#  'btctrade-im',
#  'btcturk',
#  'burst-asset-exchange',
#  'bx-thailand',
#  'c-cex',
#  'c2cx',
#  'cex-io',
#  'chaoex',
#  'cobinhood',
#  'coinbene',
#  'coincorner',
#  'coinegg',
#  'coinex',
#  'coinexchange',
#  'coinfalcon',
#  'coinfloor',
#  'coingi',
#  'coinhouse',
#  'coinlink',
#  'coinmate',
#  'coinnest',
#  'coinone',
#  'coinrail',
#  'coinrate',
#  'coinroom',
#  'coinsbank',
#  'coinsecure',
#  'coinsquare',
#  'coinut',
#  'coolcoin',
#  'coss',
#  'counterparty-dex',
#  'cryptobridge',
#  'cryptoderivatives',
#  'cryptomarket',
#  'cryptomate',
#  'cryptopia',
#  'cryptox',
#  'dc-ex',
#  'dgtmarket',
#  'dsx',
#  'etherdelta',
#  'ethexindia',
#  'excambriorex',
#  'exmo',
#  'exrates',
#  'exx',
#  'ezbtc',
#  'fargobase',
#  'fatbtc',
#  'fisco',
#  'foxbit',
#  'freiexchange',
#  'gate-io',
#  'gatecoin',
#  'gatehub',
#  'gdax',
#  'gemini',
#  'getbtc',
#  'gopax',
#  'guldentrader',
#  'heat-wallet',
#  'hitbtc',
#  'huobi',
#  'idex',
#  'independent-reserve',
#  'infinitycoin-exchange',
#  'iquant',
#  'isx',
#  'itbit',
#  'koineks',
#  'koinex',
#  'koinim',
#  'korbit',
#  'kraken',
#  'kucoin',
#  'kuna',
#  'lakebtc',
#  'lbank',
#  'leoxchange',
#  'liqui',
#  'litebit',
#  'livecoin',
#  'localtrade',
#  'luno',
#  'lykke-exchange',
#  'mercado-bitcoin',
#  'mercatox',
#  'mr-exchange',
#  'negocie-coins',
#  'neraexpro',
#  'nix-e',
#  'nocks',
#  'oasisdex',
#  'oex',
#  'okcoin-cn',
#  'okcoin-intl',
#  'okex',
#  'omni-dex',
#  'openledger',
#  'ore-bz',
#  'paribu',
#  'paymium',
#  'poloniex',
#  'qbtc',
#  'qryptos',
#  'quadrigacx',
#  'quoine',
#  'radar-relay',
#  'rfinex',
#  'rightbtc',
#  'rippex',
#  'ripple-china',
#  'ripplefox',
#  'simex',
#  'southxchange',
#  'stellar-decentralized-exchange',
#  'stocks-exchange',
#  'stronghold',
#  'surbtc',
#  'tcc-exchange',
#  'tdax',
#  'therocktrading',
#  'tidebit',
#  'tidex',
#  'token-store',
#  'topbtc',
#  'trade-by-trade',
#  'trade-satoshi',
#  'tradeogre',
#  'triple-dice-exchange',
#  'tux-exchange',
#  'upbit',
#  'vebitcoin',
#  'virtacoinworld',
#  'waves-dex',
#  'wex',
#  'xbtce',
#  'yobit',
#  'zaif',
#  'zb-com']

# %% [markdown]
# If you want to get all formatted exchange names:

# %%
cmc.exchange_names
# Out:
# ['ACX',
#  'AEX',
#  'Abucoins',
#  'AidosMarket',
#  'Allcoin',
#  'Altcoin Trader',
#  'BCEX',
#  'BITHOLIC',
#  'BL3P',
#  'BTC Markets',
#  'BTC Trade UA',
#  'BTC-Alpha',
#  'BTCBOX',
#  'BTCC',
#  'BTCTurk',
#  'BX Thailand',
#  'Bancor Network',
#  'BarterDEX',
#  'Bibox',
#  'BigONE',
#  'Binance',
#  'Bisq',
#  'Bit-Z',
#  'Bit2C',
#  'BitBay',
#  'BitFlip',
#  'BitGrail',
#  'BitKonan',
#  'BitMEX',
#  'BitMarket',
#  'BitShares Asset Exchange',
#  'Bitbank',
#  'Bitcoin Indonesia',
#  'BitcoinToYou',
#  'BitcoinTrade',
#  'Bitex.la',
#  'Bitfinex',
#  'Bithumb',
#  'Bitinka',
#  'Bitlish',
#  'Bitmaszyna',
#  'Bitonic',
#  'Bits Blockchain',
#  'Bitsane',
#  'Bitso',
#  'Bitstamp',
#  'Bitstamp (Ripple Gateway)',
#  'Bittrex',
#  'Bittylicious',
#  'Bleutrade',
#  'Braziliex',
#  'BtcTrade.im',
#  'Burst Asset Exchange',
#  'C-CEX',
#  'C2CX',
#  'CEX.IO',
#  'COSS',
#  'ChaoEX',
#  'Cobinhood',
#  'CoinCorner',
#  'CoinEgg',
#  'CoinEx',
#  'CoinExchange',
#  'CoinFalcon',
#  'CoinMate',
#  'Coinbene',
#  'Coinfloor',
#  'Coingi',
#  'Coinhouse',
#  'Coinlink',
#  'Coinnest',
#  'Coinone',
#  'Coinrail',
#  'Coinrate',
#  'Coinroom',
#  'CoinsBank',
#  'Coinsecure',
#  'Coinsquare',
#  'Coinut',
#  'CoolCoin',
#  'Counterparty DEX',
#  'CryptoBridge',
#  'CryptoDerivatives',
#  'CryptoMarket',
#  'Cryptomate',
#  'Cryptopia',
#  'Cryptox',
#  'DC-Ex',
#  'DSX',
#  'Dgtmarket',
#  'ETHEXIndia',
#  'EXX',
#  'EtherDelta',
#  'ExcambrioRex',
#  'Exmo',
#  'Exrates',
#  'Fargobase',
#  'Fatbtc',
#  'Fisco',
#  'Foxbit',
#  'FreiExchange',
#  'GDAX',
#  'GOPAX',
#  'Gate.io',
#  'Gatecoin',
#  'Gatehub',
#  'Gemini',
#  'GetBTC',
#  'GuldenTrader',
#  'Heat Wallet',
#  'HitBTC',
#  'Huobi',
#  'IDEX',
#  'ISX',
#  'Independent Reserve',
#  'InfinityCoin Exchange',
#  'Iquant',
#  'Koineks',
#  'Koinex',
#  'Koinim',
#  'Korbit',
#  'Kraken',
#  'Kucoin',
#  'Kuna',
#  'LEOxChange',
#  'LakeBTC',
#  'Lbank',
#  'Liqui',
#  'LiteBit.eu',
#  'Livecoin',
#  'LocalTrade',
#  'Luno',
#  'Lykke Exchange',
#  'Mercado Bitcoin',
#  'Mercatox',
#  'Mr. Exchange',
#  'NIX-E',
#  'Negocie Coins',
#  'Neraex',
#  'Nocks',
#  'OEX',
#  'OKCoin.cn',
#  'OKEx',
#  'OasisDEX',
#  'OkCoin Intl.',
#  'Omni DEX',
#  'OpenLedger DEX',
#  'Ore.Bz',
#  'Paribu',
#  'Paymium',
#  'Poloniex',
#  'QBTC',
#  'Qryptos',
#  'QuadrigaCX',
#  'Quoine',
#  'Radar Relay',
#  'Rfinex',
#  'RightBTC',
#  'Rippex',
#  'Ripple China',
#  'RippleFox',
#  'Simex',
#  'SouthXchange',
#  'Stellar Decentralized Exchange',
#  'Stocks.Exchange',
#  'Stronghold',
#  'SurBTC',
#  'TCC Exchange',
#  'TDAX',
#  'TOPBTC',
#  'The Rock Trading',
#  'Tidebit',
#  'Tidex',
#  'Token Store',
#  'Trade By Trade',
#  'Trade Satoshi',
#  'TradeOgre',
#  'Tripe Dice Exchange',
#  'Tux Exchange',
#  'Upbit',
#  'Vebitcoin',
#  'VirtacoinWorld',
#  'WEX',
#  'Waves Decentralized Exchange',
#  'YoBit',
#  'ZB.COM',
#  'Zaif',
#  'alcurEX',
#  'bitFlyer',
#  'ezBtc',
#  'itBit',
#  'xBTCe']

# %% [markdown]
# #### `exchanges([convert="USD"])`
# Get all available exchanges in coinmarketcap ranked by volumes with some metadata:

# %%
cmc.exchanges()
# Out:
# [{'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Cardano',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Qtum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Status',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'NEO',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Stellar',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Steem',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Upbit'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'NEO',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'ICON',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'NEO',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bluzelle',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'TRON',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'VeChain',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Binance Coin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Binance'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ethereum Classic',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum Classic',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'OKEx'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'BitMEX'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'EOS',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Qtum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Monero',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bithumb'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ripple',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'EOS',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Tether',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bitfinex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Huobi Token',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Huobi Token',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Huobi Token',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'EOS',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'TRON',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Elastos',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Elastos',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Huobi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'GDAX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ripple',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ripple',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ripple',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Kraken'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ripple',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Cardano',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'NuBits',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Lisk',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'NEO',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Stellar',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bittrex'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Monero',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Dash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ripple',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Zcash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bytecoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'HitBTC'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ripple',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ripple',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ethereum',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bitstamp'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Qtum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'IOTA',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'}],
#   'name': 'Coinone'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'}],
#   'name': 'bitFlyer'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ripple',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ripple',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Monero',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Stellar',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum Classic',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Poloniex'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Litecoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'EDUCare',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'TRON',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Hshare',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Lisk',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Zcash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Factom',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bit-Z'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'NEM',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'MonaCoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'NEM',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'COMSA [ETH]',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Counterparty',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'COMSA [XEM]',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Pepe Cash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Zaif'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'QASH',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ethereum',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Quoine'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'MonaCoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'MonaCoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'}],
#   'name': 'Fisco'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'}],
#   'name': 'Gemini'},
#  {'markets': [{'name': 'ATMCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'ATMCoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ripple',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Ethereum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Dogecoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'ATMCoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'ATMCoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Bits Blockchain'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'BTCBOX'},
#  {'markets': [{'name': 'Stellar',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Status',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Civic',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': '0x',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Enigma',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Zcash',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'GOPAX'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'NEO',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'TRON',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Lisk',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ruff',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Qtum',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Qbao',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ripple',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Achain',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Lightning Bitcoin [Futures]',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'CoinEgg'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'EOS',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'BitShares',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Qtum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Hshare',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Ripple',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Ink',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Qtum',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'ZB.COM'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'}],
#   'name': 'Korbit'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'MonaCoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'MonaCoin',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'}],
#   'name': 'Bitbank'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ink',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Electronic PK Chain',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Lightning Bitcoin [Futures]',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Hyper Pay',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'EXX'},
#  {'markets': [{'name': 'TRON',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Hshare',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Ethereum',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Qtum',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Energo',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Profile Utility Token',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Storm',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'ENTCash',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Bitcoin Diamond',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Coinnest'},
#  {'markets': [{'name': 'Jibrel Network',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Jibrel Network',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bibox Token',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bibox Token',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bibox Token',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
# ...
#    {'name': 'E-Dinar Coin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'DigiByte',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'alcurEX'},
#  {'markets': [{'name': 'E-Dinar Coin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'}],
#   'name': 'LocalTrade'},
#  {'markets': [{'name': 'Litecoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Electroneum',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Monero',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Verge',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Aeon',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'BitCoal',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Sumokoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'TradeOgre'},
#  {'markets': [{'name': 'NVO',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Pepe Cash',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Counterparty',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Storjcoin X',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Rustbits',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Storjcoin X',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'FoldingCoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Bitcrystals',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'}],
#   'name': 'Counterparty DEX'},
#  {'markets': [{'name': 'Peercoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Dogecoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Bitcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Dogecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Vertcoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Dash',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Litecoin',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Litecoin',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'Coingi'},
#  {'markets': [{'name': 'Centurion',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'ExcambrioRex'},
#  {'markets': [{'name': 'Gulden',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'GuldenTrader'},
#  {'markets': [{'name': 'LEOcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'LEOcoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'LEOcoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'LEOcoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Bitcoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'LEOxChange'},
#  {'markets': [{'name': 'The ChampCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'TCC Exchange'},
#  {'markets': [{'name': 'BriaCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Litecoin',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Litecoin',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'}],
#   'name': 'Ore.Bz'},
#  {'markets': [{'name': 'SACoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'DC-Ex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bitcoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'}],
#   'name': 'CoinCorner'},
#  {'markets': [{'name': 'CRTCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Dogecoin',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'}],
#   'name': 'NIX-E'},
#  {'markets': [{'name': 'HEAT',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Bismuth',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Golem',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'FIMKrypto',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Elastic',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Elastic',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'HEAT',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'}],
#   'name': 'Heat Wallet'},
#  {'markets': [{'name': 'SnakeEyes',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'CCMiner',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'}],
#   'name': 'Burst Asset Exchange'},
#  {'markets': [{'name': 'MaidSafeCoin',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'}],
#   'name': 'Omni DEX'},
#  {'markets': [{'name': 'Golem',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Lunyr',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'SingularDTV',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'TokenCard',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Swarm City',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'},
#    {'name': 'Etheroll',
#     'pair': 'SNT/KRW',
#     'perc_volume': 6.24,
#     'price': 0.227147,
#     'volume': 150104000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-SNT'},
#    {'name': 'Melon',
#     'pair': 'ETH/KRW',
#     'perc_volume': 5.14,
#     'price': 910.426,
#     'volume': 123467000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ETH'},
#    {'name': 'Numeraire',
#     'pair': 'NEO/KRW',
#     'perc_volume': 4.68,
#     'price': 119.137,
#     'volume': 112552000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-NEO'},
#    {'name': 'Edgeless',
#     'pair': 'XLM/KRW',
#     'perc_volume': 3.79,
#     'price': 0.409232,
#     'volume': 91052000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XLM'},
#    {'name': 'Ethereum Movie Venture',
#     'pair': 'STEEM/KRW',
#     'perc_volume': 2.49,
#     'price': 4.28084,
#     'volume': 59809500.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-STEEM'}],
#   'name': 'CryptoDerivatives'},
#  {'markets': [{'name': 'Virtacoinplus',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Virtacoinplus',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'}],
#   'name': 'VirtacoinWorld'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'XRP/KRW',
#     'perc_volume': 14.5,
#     'price': 0.928818,
#     'volume': 348623000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-XRP'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ADA/KRW',
#     'perc_volume': 13.95,
#     'price': 0.38808,
#     'volume': 335405000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-ADA'},
#    {'name': 'Litecoin',
#     'pair': 'QTUM/KRW',
#     'perc_volume': 11.55,
#     'price': 30.2188,
#     'volume': 277639000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-QTUM'},
#    {'name': 'Siacoin',
#     'pair': 'BTC/KRW',
#     'perc_volume': 11.3,
#     'price': 9021.49,
#     'volume': 271590000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BCC/KRW',
#     'perc_volume': 6.37,
#     'price': 1356.44,
#     'volume': 153257000.0,
#     'web': 'https://upbit.com/exchange?code=CRIX.UPBIT.KRW-BCC'}],
#   'name': 'BITHOLIC'}]

# %% [markdown]
# #### `tokens([convert="USD"])`
# Get platforms tokens data:

# %%
cmc.tokens()
# Out:
# [{'circulating_supply': 657693006.82,
#   'market_cap': 6210193870.67,
#   'name': 'EOS',
#   'platform': 'Ethereum',
#   'price': 9.44239,
#   'symbol': 'EOS',
#   'volume_24h': 551708000.0},
#  {'circulating_supply': 65748192475.5,
#   'market_cap': 2895399175.78,
#   'name': 'TRON',
#   'platform': 'Ethereum',
#   'price': 0.0440377,
#   'symbol': 'TRX',
#   'volume_24h': 254119000.0},
#  {'circulating_supply': 2217140813.52,
#   'market_cap': 2323962657.92,
#   'name': 'Tether',
#   'platform': 'Omni',
#   'price': 1.04818,
#   'symbol': 'USDT',
#   'volume_24h': 2588690000.0},
#  {'circulating_supply': 466139234.665,
#   'market_cap': 2122275998.72,
#   'name': 'VeChain',
#   'platform': 'Ethereum',
#   'price': 4.55288,
#   'symbol': 'VEN',
#   'volume_24h': 67371300.0},
#  {'circulating_supply': 381495014.0,
#   'market_cap': 1727897737.01,
#   'name': 'ICON',
#   'platform': 'Ethereum',
#   'price': 4.52928,
#   'symbol': 'ICX',
#   'volume_24h': 105274000.0},
#  {'circulating_supply': 37004026.8944,
#   'market_cap': 1358388224.07,
#   'name': 'Populous',
#   'platform': 'Ethereum',
#   'price': 36.7092,
#   'symbol': 'PPT',
#   'volume_24h': 12259000.0},
#  {'circulating_supply': 102042551.763,
#   'market_cap': 1336206398.32,
#   'name': 'OmiseGO',
#   'platform': 'Ethereum',
#   'price': 13.0946,
#   'symbol': 'OMG',
#   'volume_24h': 47643600.0},
#  {'circulating_supply': 99014000.0,
#   'market_cap': 878372996.8,
#   'name': 'Binance Coin',
#   'platform': 'Ethereum',
#   'price': 8.8712,
#   'symbol': 'BNB',
#   'volume_24h': 85832000.0},
#  {'circulating_supply': 3470483788.0,
#   'market_cap': 785051196.716,
#   'name': 'Status',
#   'platform': 'Ethereum',
#   'price': 0.226208,
#   'symbol': 'SNT',
#   'volume_24h': 166952000.0},
#  {'circulating_supply': 233020472.114,
#   'market_cap': 707109943.449,
#   'name': 'Aeternity',
#   'platform': 'Ethereum',
#   'price': 3.03454,
#   'symbol': 'AE',
#   'volume_24h': 22062500.0},
#  {'circulating_supply': 618227.770106,
#   'market_cap': 677015048.765,
#   'name': 'Maker',
#   'platform': 'Ethereum',
#   'price': 1095.09,
#   'symbol': 'MKR',
#   'volume_24h': 642286.0},
#  {'circulating_supply': 11000000.0,
#   'market_cap': 622743000.0,
#   'name': 'Augur',
#   'platform': 'Ethereum',
#   'price': 56.613,
#   'symbol': 'REP',
#   'volume_24h': 6527380.0},
#  {'circulating_supply': 2000000.0,
#   'market_cap': 617100000.0,
#   'name': 'DigixDAO',
#   'platform': 'Ethereum',
#   'price': 308.55,
#   'symbol': 'DGD',
#   'volume_24h': 25843400.0},
#  {'circulating_supply': 24898178.0,
#   'market_cap': 598569627.845,
#   'name': 'Walton',
#   'platform': 'Ethereum',
#   'price': 24.0407,
#   'symbol': 'WTC',
#   'volume_24h': 17455300.0},
#  {'circulating_supply': 2036645.44,
#   'market_cap': 585910306.761,
#   'name': 'Veritaseum',
#   'platform': 'Ethereum',
#   'price': 287.684,
#   'symbol': 'VERI',
#   'volume_24h': 168745.0},
#  {'circulating_supply': 507188082.128,
#   'market_cap': 581404914.186,
#   'name': '0x',
#   'platform': 'Ethereum',
#   'price': 1.14633,
#   'symbol': 'ZRX',
#   'volume_24h': 13846200.0},
#  {'circulating_supply': 91043076.0001,
#   'market_cap': 541041687.746,
#   'name': 'KuCoin Shares',
#   'platform': 'Ethereum',
#   'price': 5.9427,
#   'symbol': 'KCS',
#   'volume_24h': 2929230.0},
#  {'circulating_supply': 344166288.9,
#   'market_cap': 523129317.465,
#   'name': 'RChain',
#   'platform': 'Ethereum',
#   'price': 1.51999,
#   'symbol': 'RHOC',
#   'volume_24h': 752055.0},
#  {'circulating_supply': 134132696.93,
#   'market_cap': 448503522.706,
#   'name': 'Kyber Network',
#   'platform': 'Ethereum',
#   'price': 3.34373,
#   'symbol': 'KNC',
#   'volume_24h': 7626860.0},
#  {'circulating_supply': 184450000.0,
#   'market_cap': 448005071.5,
#   'name': 'Revain',
#   'platform': 'Ethereum',
#   'price': 2.42887,
#   'symbol': 'R',
#   'volume_24h': 5579480.0},
#  {'circulating_supply': 9675198.48521,
#   'market_cap': 423318959.323,
#   'name': 'Gas',
#   'platform': 'NEO',
#   'price': 43.753,
#   'symbol': 'GAS',
#   'volume_24h': 9194870.0},
#  {'circulating_supply': 1000000000.0,
#   'market_cap': 397901000.0,
#   'name': 'Basic Attenti...',
#   'platform': 'Ethereum',
#   'price': 0.397901,
#   'symbol': 'BAT',
#   'volume_24h': 5927610.0},
#  {'circulating_supply': 238421940.0,
#   'market_cap': 397053593.56,
#   'name': 'Dragonchain',
#   'platform': 'Ethereum',
#   'price': 1.66534,
#   'symbol': 'DRGN',
#   'volume_24h': 2383720.0},
#  {'circulating_supply': 6508988220.4,
#   'market_cap': 392460746.547,
#   'name': 'Zilliqa',
#   'platform': 'Ethereum',
#   'price': 0.0602952,
#   'symbol': 'ZIL',
#   'volume_24h': 12325400.0},
#  {'circulating_supply': 561202251.418,
#   'market_cap': 385870321.625,
#   'name': 'Loopring',
#   'platform': 'Ethereum',
#   'price': 0.687578,
#   'symbol': 'LRC',
#   'volume_24h': 3017500.0},
#  {'circulating_supply': 325226613094.0,
#   'market_cap': 375838378.624,
#   'name': 'Dentacoin',
#   'platform': 'Ethereum',
#   'price': 0.00115562,
#   'symbol': 'DCN',
#   'volume_24h': 586538.0},
#  {'circulating_supply': 250000000.0,
#   'market_cap': 344665000.0,
#   'name': 'aelf',
#   'platform': 'Ethereum',
#   'price': 1.37866,
#   'symbol': 'ELF',
#   'volume_24h': 45873100.0},
#  {'circulating_supply': 987000000.0,
#   'market_cap': 341537532.0,
#   'name': 'Bytom',
#   'platform': 'Ethereum',
#   'price': 0.346036,
#   'symbol': 'BTM',
#   'volume_24h': 16937800.0},
#  {'circulating_supply': 75601199.5585,
#   'market_cap': 340398181.072,
#   'name': 'Ethos',
#   'platform': 'Ethereum',
#   'price': 4.50255,
#   'symbol': 'ETHOS',
#   'volume_24h': 7169740.0},
#  {'circulating_supply': 350000000.0,
#   'market_cap': 324091600.0,
#   'name': 'QASH',
#   'platform': 'Ethereum',
#   'price': 0.925976,
#   'symbol': 'QASH',
#   'volume_24h': 3174570.0},
#  {'circulating_supply': 227384800.0,
#   'market_cap': 317388251.536,
#   'name': 'Pillar',
#   'platform': 'Ethereum',
#   'price': 1.39582,
#   'symbol': 'PLR',
#   'volume_24h': 279251.0},
#  {'circulating_supply': 35500000.0,
#   'market_cap': 310113800.0,
#   'name': 'Nebulas',
#   'platform': 'Ethereum',
#   'price': 8.7356,
#   'symbol': 'NAS',
#   'volume_24h': 7451740.0},
#  {'circulating_supply': 4503688788.66,
#   'market_cap': 300877486.535,
#   'name': 'FunFair',
#   'platform': 'Ethereum',
#   'price': 0.0668069,
#   'symbol': 'FUN',
#   'volume_24h': 30495000.0},
#  {'circulating_supply': 834262000.0,
#   'market_cap': 298548165.058,
#   'name': 'Golem',
#   'platform': 'Ethereum',
#   'price': 0.357859,
#   'symbol': 'GNT',
#   'volume_24h': 6910330.0},
#  {'circulating_supply': 1445976590.33,
#   'market_cap': 292497928.598,
#   'name': 'Cindicator',
#   'platform': 'Ethereum',
#   'price': 0.202284,
#   'symbol': 'CND',
#   'volume_24h': 12517600.0},
#  {'circulating_supply': 10614760961.2,
#   'market_cap': 291021716.845,
#   'name': 'Dent',
#   'platform': 'Ethereum',
#   'price': 0.0274167,
#   'symbol': 'DENT',
#   'volume_24h': 3096570.0},
#  {'circulating_supply': 6794109921.69,
#   'market_cap': 276429912.151,
#   'name': 'IOStoken',
#   'platform': 'Ethereum',
#   'price': 0.0406867,
#   'symbol': 'IOST',
#   'volume_24h': 40486600.0},
#  {'circulating_supply': 363837588.92,
#   'market_cap': 266988388.8,
#   'name': 'Power Ledger',
#   'platform': 'Ethereum',
#   'price': 0.733812,
#   'symbol': 'POWR',
#   'volume_24h': 19100300.0},
#  {'circulating_supply': 52847203.5896,
#   'market_cap': 250488874.878,
#   'name': 'SALT',
#   'platform': 'Ethereum',
#   'price': 4.73987,
#   'symbol': 'SALT',
#   'volume_24h': 6806790.0},
#  {'circulating_supply': 79265734.9086,
#   'market_cap': 237150396.329,
#   'name': 'Aion',
#   'platform': 'Ethereum',
#   'price': 2.99184,
#   'symbol': 'AION',
#   'volume_24h': 5178240.0},
#  {'circulating_supply': 756097560976.0,
#   'market_cap': 220202829.268,
#   'name': 'Kin',
#   'platform': 'Ethereum',
#   'price': 0.000291236,
#   'symbol': 'KIN',
#   'volume_24h': 161220.0},
#  {'circulating_supply': 74836171.09,
#   'market_cap': 213890757.316,
#   'name': 'Enigma',
#   'platform': 'Ethereum',
#   'price': 2.85812,
#   'symbol': 'ENG',
#   'volume_24h': 8161730.0},
#  {'circulating_supply': 454443782.0,
#   'market_cap': 209858957.421,
#   'name': 'SingularityNET',
#   'platform': 'Ethereum',
#   'price': 0.461793,
#   'symbol': 'AGI',
#   'volume_24h': 997526.0},
#  {'circulating_supply': 38986587.1985,
#   'market_cap': 207764981.303,
#   'name': 'Bancor',
#   'platform': 'Ethereum',
#   'price': 5.32914,
#   'symbol': 'BNT',
#   'volume_24h': 7037300.0},
#  {'circulating_supply': 617314170.819,
#   'market_cap': 207653992.722,
#   'name': 'Quantstamp',
#   'platform': 'Ethereum',
#   'price': 0.336383,
#   'symbol': 'QSP',
#   'volume_24h': 20053200.0},
#  {'circulating_supply': 452552412.0,
#   'market_cap': 197592076.47,
#   'name': 'MaidSafeCoin',
#   'platform': 'Omni',
#   'price': 0.436617,
#   'symbol': 'MAID',
#   'volume_24h': 1996880.0},
#  {'circulating_supply': 761143950.0,
#   'market_cap': 195705332.424,
#   'name': 'Ignis',
#   'platform': 'Ardor',
#   'price': 0.25712,
#   'symbol': 'IGNIS',
#   'volume_24h': 17290400.0},
#  {'circulating_supply': 641462768.585,
#   'market_cap': 195592903.009,
#   'name': 'Request Network',
#   'platform': 'Ethereum',
#   'price': 0.304917,
#   'symbol': 'REQ',
#   'volume_24h': 6492180.0},
#  {'circulating_supply': 1000000000.0,
#   'market_cap': 192843000.0,
#   'name': 'XPlay',
#   'platform': 'Ethereum',
#   'price': 0.192843,
#   'symbol': 'XPA',
#   'volume_24h': 1582120.0},
#  {'circulating_supply': 104661310.0,
#   'market_cap': 182490599.955,
#   'name': 'TenX',
#   'platform': 'Ethereum',
#   'price': 1.74363,
#   'symbol': 'PAY',
#   'volume_24h': 3833600.0},
#  {'circulating_supply': 99735686.8829,
#   'market_cap': 175643520.813,
#   'name': 'Iconomi',
#   'platform': 'Ethereum',
#   'price': 1.76109,
#   'symbol': 'ICN',
#   'volume_24h': 1396760.0},
#  {'circulating_supply': 492954537.351,
#   'market_cap': 167680457.698,
#   'name': 'WAX',
#   'platform': 'Ethereum',
#   'price': 0.340154,
#   'symbol': 'WAX',
#   'volume_24h': 4108640.0},
#  {'circulating_supply': 342699966.0,
#   'market_cap': 166313321.6,
#   'name': 'Civic',
#   'platform': 'Ethereum',
#   'price': 0.485303,
#   'symbol': 'CVC',
#   'volume_24h': 13335400.0},
#  {'circulating_supply': 1104590.0,
#   'market_cap': 161839003.85,
#   'name': 'Gnosis',
#   'platform': 'Ethereum',
#   'price': 146.515,
#   'symbol': 'GNO',
#   'volume_24h': 483948.0},
#  {'circulating_supply': 226091448.88,
#   'market_cap': 156676400.062,
#   'name': 'Substratum',
#   'platform': 'Ethereum',
#   'price': 0.692978,
#   'symbol': 'SUB',
#   'volume_24h': 4671870.0},
#  {'circulating_supply': 50148936.0,
#   'market_cap': 155632207.982,
#   'name': 'Raiden Networ...',
#   'platform': 'Ethereum',
#   'price': 3.1034,
#   'symbol': 'RDN',
#   'volume_24h': 4606570.0},
#  {'circulating_supply': 350000000.0,
#   'market_cap': 153638450.0,
#   'name': 'ChainLink',
#   'platform': 'Ethereum',
#   'price': 0.438967,
#   'symbol': 'LINK',
#   'volume_24h': 5594960.0},
#  {'circulating_supply': 133425492.59,
#   'market_cap': 138218136.283,
#   'name': 'Storj',
#   'platform': 'Ethereum',
#   'price': 1.03592,
#   'symbol': 'STORJ',
#   'volume_24h': 11660700.0},
#  {'circulating_supply': 165000000.0,
#   'market_cap': 137792490.0,
#   'name': 'Bluzelle',
#   'platform': 'Ethereum',
#   'price': 0.835106,
#   'symbol': 'BLZ',
#   'volume_24h': 83109800.0},
#  {'circulating_supply': 816060.7785,
#   'market_cap': 133533657.308,
#   'name': 'SuperNET',
#   'platform': 'Nxt',
#   'price': 163.632,
#   'symbol': 'UNITY',
#   'volume_24h': 30584.6},
#  {'circulating_supply': 103244552.962,
#   'market_cap': 130013800.654,
#   'name': 'DEW',
#   'platform': 'Ethereum',
#   'price': 1.25928,
#   'symbol': 'DEW',
#   'volume_24h': 405168.0},
#  {'circulating_supply': 26676926.3581,
#   'market_cap': 128579050.277,
#   'name': 'Aragon',
#   'platform': 'Ethereum',
#   'price': 4.81986,
#   'symbol': 'ANT',
#   'volume_24h': 844458.0},
#  {'circulating_supply': 1051043445.16,
#   'market_cap': 128243065.961,
#   'name': 'Decentraland',
#   'platform': 'Ethereum',
#   'price': 0.122015,
#   'symbol': 'MANA',
#   'volume_24h': 24321200.0},
#  {'circulating_supply': 2216707776.0,
#   'market_cap': 127388875.788,
#   'name': 'Po.et',
#   'platform': 'Ethereum',
#   'price': 0.0574676,
#   'symbol': 'POE',
#   'volume_24h': 7346160.0},
#  {'circulating_supply': 1631622325.37,
#   'market_cap': 121604485.585,
#   'name': 'Time New Bank',
#   'platform': 'Ethereum',
#   'price': 0.0745298,
#   'symbol': 'TNB',
#   'volume_24h': 5966060.0},
#  {'circulating_supply': 756192535.064,
#   'market_cap': 121292526.432,
#   'name': 'Enjin Coin',
#   'platform': 'Ethereum',
#   'price': 0.160399,
#   'symbol': 'ENJ',
#   'volume_24h': 3225550.0},
#  {'circulating_supply': 2554565966.25,
#   'market_cap': 119766993.479,
#   'name': 'Storm',
#   'platform': 'Ethereum',
#   'price': 0.0468835,
#   'symbol': 'STORM',
#   'volume_24h': 1690680.0},
#  {'circulating_supply': 82500000.0,
#   'market_cap': 118144125.0,
#   'name': 'PayPie',
#   'platform': 'Ethereum',
#   'price': 1.43205,
#   'symbol': 'PPP',
#   'volume_24h': 409862.0},
#  {'circulating_supply': 997237841.0,
#   'market_cap': 117893457.563,
#   'name': 'Dynamic Tradi...',
#   'platform': 'Ethereum',
#   'price': 0.11822,
#   'symbol': 'DTR',
#   'volume_24h': 35400.5},
#  {'circulating_supply': 79070793.2388,
#   'market_cap': 116414347.47,
#   'name': 'iExec RLC',
#   'platform': 'Ethereum',
#   'price': 1.47228,
#   'symbol': 'RLC',
#   'volume_24h': 7609870.0},
#  {'circulating_supply': 98939459.119,
#   'market_cap': 113015575.968,
#   'name': 'SIRIN LABS Token',
#   'platform': 'Ethereum',
#   'price': 1.14227,
#   'symbol': 'SRN',
#   'volume_24h': 17711000.0},
#  {'circulating_supply': 62660370.957,
#   'market_cap': 112714101.881,
#   'name': 'Santiment Net...',
#   'platform': 'Ethereum',
#   'price': 1.79881,
#   'symbol': 'SAN',
#   'volume_24h': 7468970.0},
#  {'circulating_supply': 105253066.049,
#   'market_cap': 110802007.691,
#   'name': 'Bibox Token',
#   'platform': 'Ethereum',
#   'price': 1.05272,
#   'symbol': 'BIX',
#   'volume_24h': 13090200.0},
#  {'circulating_supply': 543348500.0,
#   'market_cap': 107941613.01,
#   'name': 'Red Pulse',
#   'platform': 'NEO',
#   'price': 0.19866,
#   'symbol': 'RPX',
#   'volume_24h': 3302260.0},
#  {'circulating_supply': 1494971208.89,
#   'market_cap': 107047562.91,
#   'name': 'BLOCKv',
#   'platform': 'Ethereum',
#   'price': 0.0716051,
#   'symbol': 'VEE',
#   'volume_24h': 515778.0},
#  {'circulating_supply': 42000000.0,
#   'market_cap': 104194020.0,
#   'name': 'Agoras Tokens',
#   'platform': 'Omni',
#   'price': 2.48081,
#   'symbol': 'AGRS',
#   'volume_24h': 162288.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 102041850.0,
#   'name': 'AirSwap',
#   'platform': 'Ethereum',
#   'price': 0.680279,
#   'symbol': 'AST',
#   'volume_24h': 3207860.0},
#  {'circulating_supply': 199902472.36,
#   'market_cap': 101322767.043,
#   'name': 'VIBE',
#   'platform': 'Ethereum',
#   'price': 0.506861,
#   'symbol': 'VIBE',
#   'volume_24h': 6128020.0},
#  {'circulating_supply': 357315269.838,
#   'market_cap': 101257787.743,
#   'name': 'Cobinhood',
#   'platform': 'Ethereum',
#   'price': 0.283385,
#   'symbol': 'COB',
#   'volume_24h': 1450.44},
#  {'circulating_supply': 13195542.215,
#   'market_cap': 100823047.446,
#   'name': 'Monaco',
#   'platform': 'Ethereum',
#   'price': 7.64069,
#   'symbol': 'MCO',
#   'volume_24h': 4052750.0},
#  {'circulating_supply': 189600317.903,
#   'market_cap': 99546802.9102,
#   'name': 'SophiaTX',
#   'platform': 'Ethereum',
#   'price': 0.525035,
#   'symbol': 'SPHTX',
#   'volume_24h': 294002.0},
#  {'circulating_supply': 38327424.5,
#   'market_cap': 98933814.3134,
#   'name': 'IoT Chain',
#   'platform': 'Ethereum',
#   'price': 2.58128,
#   'symbol': 'ITC',
#   'volume_24h': 8834020.0},
#  {'circulating_supply': 39335007.2487,
#   'market_cap': 95451901.99,
#   'name': 'CRYPTO20',
#   'platform': 'Ethereum',
#   'price': 2.42664,
#   'symbol': 'C20',
#   'volume_24h': 2870950.0},
#  {'circulating_supply': 1042852948.02,
#   'market_cap': 94826827.1343,
#   'name': 'ETHLend',
#   'platform': 'Ethereum',
#   'price': 0.0909302,
#   'symbol': 'LEND',
#   'volume_24h': 5347490.0},
#  {'circulating_supply': 490533008.753,
#   'market_cap': 91675223.4729,
#   'name': 'Ripio Credit ...',
#   'platform': 'Ethereum',
#   'price': 0.186889,
#   'symbol': 'RCN',
#   'volume_24h': 5232720.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 90697200.0,
#   'name': 'SingularDTV',
#   'platform': 'Ethereum',
#   'price': 0.151162,
#   'symbol': 'SNGLS',
#   'volume_24h': 2081830.0},
#  {'circulating_supply': 482511957.017,
#   'market_cap': 90662066.6758,
#   'name': 'MediShares',
#   'platform': 'Ethereum',
#   'price': 0.187896,
#   'symbol': 'MDS',
#   'volume_24h': 8603630.0},
#  {'circulating_supply': 900000000.0,
#   'market_cap': 89255340.0,
#   'name': 'DeepBrain Chain',
#   'platform': 'NEO',
#   'price': 0.0991726,
#   'symbol': 'DBC',
#   'volume_24h': 3100650.0},
#  {'circulating_supply': 272889439.003,
#   'market_cap': 85385741.0169,
#   'name': 'Simple Token',
#   'platform': 'Ethereum',
#   'price': 0.312895,
#   'symbol': 'OST',
#   'volume_24h': 6085540.0},
#  {'circulating_supply': 19300994.0,
#   'market_cap': 85287618.3071,
#   'name': 'Metal',
#   'platform': 'Ethereum',
#   'price': 4.41882,
#   'symbol': 'MTL',
#   'volume_24h': 20912200.0},
#  {'circulating_supply': 144590975.0,
#   'market_cap': 85181146.01,
#   'name': 'Ambrosus',
#   'platform': 'Ethereum',
#   'price': 0.589118,
#   'symbol': 'AMB',
#   'volume_24h': 1216500.0},
#  {'circulating_supply': 443411828.912,
#   'market_cap': 83389358.7807,
#   'name': 'CyberMiles',
#   'platform': 'Ethereum',
#   'price': 0.188063,
#   'symbol': 'CMT',
#   'volume_24h': 8286360.0},
#  {'circulating_supply': 265118238.708,
#   'market_cap': 82601829.1613,
#   'name': 'UTRUST',
#   'platform': 'Ethereum',
#   'price': 0.311566,
#   'symbol': 'UTK',
#   'volume_24h': 3654940.0},
#  {'circulating_supply': 563264706.0,
#   'market_cap': 82366197.9584,
#   'name': 'Theta Token',
#   'platform': 'Ethereum',
#   'price': 0.14623,
#   'symbol': 'THETA',
#   'volume_24h': 15933500.0},
#  {'circulating_supply': 20970629778.4,
#   'market_cap': 81479914.06,
#   'name': 'Telcoin',
#   'platform': 'Ethereum',
#   'price': 0.00388543,
#   'symbol': 'TEL',
#   'volume_24h': 886972.0},
#  {'circulating_supply': 359600000.0,
#   'market_cap': 81128996.4,
#   'name': 'SONM',
#   'platform': 'Ethereum',
#   'price': 0.225609,
#   'symbol': 'SNM',
#   'volume_24h': 1454940.0},
#  {'circulating_supply': 82046276.0,
#   'market_cap': 80588231.6292,
#   'name': 'Edgeless',
#   'platform': 'Ethereum',
#   'price': 0.982229,
#   'symbol': 'EDG',
#   'volume_24h': 1373290.0},
#  {'circulating_supply': 52000000.0,
#   'market_cap': 78369720.0,
#   'name': 'Quantum Resis...',
#   'platform': 'Ethereum',
#   'price': 1.50711,
#   'symbol': 'QRL',
#   'volume_24h': 668130.0},
#  {'circulating_supply': 333333333.0,
#   'market_cap': 76172333.2572,
#   'name': 'Trinity Netwo...',
#   'platform': 'NEO',
#   'price': 0.228517,
#   'symbol': 'TNC',
#   'volume_24h': 3874240.0},
#  {'circulating_supply': 45248032.811,
#   'market_cap': 75058794.2679,
#   'name': 'WaBi',
#   'platform': 'Ethereum',
#   'price': 1.65883,
#   'symbol': 'WABI',
#   'volume_24h': 3315550.0},
#  {'circulating_supply': 60248315.0,
#   'market_cap': 74531383.037,
#   'name': 'AdEx',
#   'platform': 'Ethereum',
#   'price': 1.23707,
#   'symbol': 'ADX',
#   'volume_24h': 16429100.0},
#  {'circulating_supply': 23564882.3,
#   'market_cap': 73417097.7521,
#   'name': 'Nuls',
#   'platform': 'Ethereum',
#   'price': 3.11553,
#   'symbol': 'NULS',
#   'volume_24h': 4641770.0},
#  {'circulating_supply': 68000000.0,
#   'market_cap': 73106800.0,
#   'name': 'Centra',
#   'platform': 'Ethereum',
#   'price': 1.0751,
#   'symbol': 'CTR',
#   'volume_24h': 22373600.0},
#  {'circulating_supply': 28003971.7665,
#   'market_cap': 69940199.5267,
#   'name': 'INS Ecosystem',
#   'platform': 'Ethereum',
#   'price': 2.49751,
#   'symbol': 'INS',
#   'volume_24h': 15782000.0},
#  {'circulating_supply': 599400.0,
#   'market_cap': 67353379.2,
#   'name': 'Melon',
#   'platform': 'Ethereum',
#   'price': 112.368,
#   'symbol': 'MLN',
#   'volume_24h': 194995.0},
#  {'circulating_supply': 100054311.845,
#   'market_cap': 67229493.758,
#   'name': 'AppCoins',
#   'platform': 'Ethereum',
#   'price': 0.67193,
#   'symbol': 'APPC',
#   'volume_24h': 4779170.0},
#  {'circulating_supply': 300043386.0,
#   'market_cap': 66995787.5298,
#   'name': 'SpankChain',
#   'platform': 'Ethereum',
#   'price': 0.223287,
#   'symbol': 'SPANK',
#   'volume_24h': 514768.0},
#  {'circulating_supply': 98028877.0,
#   'market_cap': 65573868.5183,
#   'name': 'MobileGo',
#   'platform': 'Ethereum',
#   'price': 0.668924,
#   'symbol': 'MGO',
#   'volume_24h': 195967.0},
#  {'circulating_supply': 677154514.0,
#   'market_cap': 64871741.0185,
#   'name': 'Streamr DATAcoin',
#   'platform': 'Ethereum',
#   'price': 0.0958005,
#   'symbol': 'DATA',
#   'volume_24h': 854188.0},
#  {'circulating_supply': 29261461.2776,
#   'market_cap': 62469123.2231,
#   'name': 'Eidoo',
#   'platform': 'Ethereum',
#   'price': 2.13486,
#   'symbol': 'EDO',
#   'volume_24h': 1798710.0},
#  {'circulating_supply': 4660285459.8,
#   'market_cap': 62463670.1319,
#   'name': 'ATMChain',
#   'platform': 'Ethereum',
#   'price': 0.0134034,
#   'symbol': 'ATM',
#   'volume_24h': 192153.0},
#  {'circulating_supply': 183000000.0,
#   'market_cap': 61114680.0,
#   'name': 'Wagerr',
#   'platform': 'Waves',
#   'price': 0.33396,
#   'symbol': 'WGR',
#   'volume_24h': 92173.6},
#  {'circulating_supply': 134886304.35,
#   'market_cap': 61078137.2453,
#   'name': 'Unikoin Gold',
#   'platform': 'Ethereum',
#   'price': 0.452812,
#   'symbol': 'UKG',
#   'volume_24h': 808620.0},
#  {'circulating_supply': 485146252.554,
#   'market_cap': 60456985.4083,
#   'name': 'Etherparty',
#   'platform': 'Ethereum',
#   'price': 0.124616,
#   'symbol': 'FUEL',
#   'volume_24h': 1213340.0},
#  {'circulating_supply': 428481269.499,
#   'market_cap': 60046508.1451,
#   'name': 'Tierion',
#   'platform': 'Ethereum',
#   'price': 0.140138,
#   'symbol': 'TNT',
#   'volume_24h': 4748060.0},
#  {'circulating_supply': 18266200.0,
#   'market_cap': 59624895.364,
#   'name': 'Modum',
#   'platform': 'Ethereum',
#   'price': 3.26422,
#   'symbol': 'MOD',
#   'volume_24h': 817105.0},
#  {'circulating_supply': 240000000.0,
#   'market_cap': 59278560.0,
#   'name': 'QLINK',
#   'platform': 'NEO',
#   'price': 0.246994,
#   'symbol': 'QLC',
#   'volume_24h': 1035720.0},
#  {'circulating_supply': 89708333.0,
#   'market_cap': 57783469.702,
#   'name': 'Wings',
#   'platform': 'Ethereum',
#   'price': 0.644126,
#   'symbol': 'WINGS',
#   'volume_24h': 3750910.0},
#  {'circulating_supply': 68666926.2205,
#   'market_cap': 57693058.7405,
#   'name': 'Oyster',
#   'platform': 'Ethereum',
#   'price': 0.840187,
#   'symbol': 'PRL',
#   'volume_24h': 2001170.0},
#  {'circulating_supply': 254507605.599,
#   'market_cap': 56385396.4976,
#   'name': 'OriginTrail',
#   'platform': 'Ethereum',
#   'price': 0.221547,
#   'symbol': 'TRAC',
#   'volume_24h': 208215.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 55677900.0,
#   'name': 'Internet Node...',
#   'platform': 'Ethereum',
#   'price': 0.371186,
#   'symbol': 'INT',
#   'volume_24h': 2233730.0},
#  {'circulating_supply': 57672338.0,
#   'market_cap': 55671569.2501,
#   'name': 'NAGA',
#   'platform': 'Ethereum',
#   'price': 0.965308,
#   'symbol': 'NGC',
#   'volume_24h': 303836.0},
#  {'circulating_supply': 3726780.89997,
#   'market_cap': 55487295.4634,
#   'name': 'Genesis Vision',
#   'platform': 'Ethereum',
#   'price': 14.8888,
#   'symbol': 'GVT',
#   'volume_24h': 1782910.0},
#  {'circulating_supply': 32105577.5103,
#   'market_cap': 55390468.6554,
#   'name': 'Triggers',
#   'platform': 'Counterparty',
#   'price': 1.72526,
#   'symbol': 'TRIG',
#   'volume_24h': 3102100.0},
#  {'circulating_supply': 59888398.693,
#   'market_cap': 54741589.7093,
#   'name': 'Bread',
#   'platform': 'Ethereum',
#   'price': 0.91406,
#   'symbol': 'BRD',
#   'volume_24h': 5974040.0},
#  {'circulating_supply': 399934364.226,
#   'market_cap': 54330283.5114,
#   'name': 'indaHash',
#   'platform': 'Ethereum',
#   'price': 0.135848,
#   'symbol': 'IDH',
#   'volume_24h': 194761.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 52711500.0,
#   'name': 'district0x',
#   'platform': 'Ethereum',
#   'price': 0.0878525,
#   'symbol': 'DNT',
#   'volume_24h': 2854720.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 52416240.0,
#   'name': 'adToken',
#   'platform': 'Ethereum',
#   'price': 0.0873604,
#   'symbol': 'ADT',
#   'volume_24h': 4879650.0},
#  {'circulating_supply': 651246649.17,
#   'market_cap': 51488732.3273,
#   'name': 'CoinDash',
#   'platform': 'Ethereum',
#   'price': 0.0790618,
#   'symbol': 'CDT',
#   'volume_24h': 1467570.0},
#  {'circulating_supply': 31432398.8758,
#   'market_cap': 51410202.9532,
#   'name': 'Decision Token',
#   'platform': 'Ethereum',
#   'price': 1.63558,
#   'symbol': 'HST',
#   'volume_24h': 179924.0},
#  {'circulating_supply': 2000000000.0,
#   'market_cap': 49904000.0,
#   'name': 'Odyssey',
#   'platform': 'Ethereum',
#   'price': 0.024952,
#   'symbol': 'OCN',
#   'volume_24h': 10173200.0},
#  {'circulating_supply': 5171589622.24,
#   'market_cap': 49643536.829,
#   'name': 'carVertical',
#   'platform': 'Ethereum',
#   'price': 0.00959928,
#   'symbol': 'CV',
#   'volume_24h': 1021550.0},
#  {'circulating_supply': 329118078.46,
#   'market_cap': 48669981.4427,
#   'name': 'Cappasity',
#   'platform': 'Ethereum',
#   'price': 0.14788,
#   'symbol': 'CAPP',
#   'volume_24h': 197019.0},
#  {'circulating_supply': 806408544.994,
#   'market_cap': 48396931.3912,
#   'name': 'Datum',
#   'platform': 'Ethereum',
#   'price': 0.0600154,
#   'symbol': 'DAT',
#   'volume_24h': 5549040.0},
#  {'circulating_supply': 100000000.0,
#   'market_cap': 47940800.0,
#   'name': 'Mercury',
#   'platform': 'Waves',
#   'price': 0.479408,
#   'symbol': 'MER',
#   'volume_24h': 16460000.0},
#  {'circulating_supply': 346139198.325,
#   'market_cap': 46985627.0591,
#   'name': 'BitDegree',
#   'platform': 'Ethereum',
#   'price': 0.135742,
#   'symbol': 'BDG',
#   'volume_24h': 110556.0},
#  {'circulating_supply': 63576278.0915,
#   'market_cap': 46764930.0283,
#   'name': 'COSS',
#   'platform': 'Ethereum',
#   'price': 0.735572,
#   'symbol': 'COSS',
#   'volume_24h': 549925.0},
#  {'circulating_supply': 157861326.54,
#   'market_cap': 46738318.6714,
#   'name': 'Gifto',
#   'platform': 'Ethereum',
#   'price': 0.296072,
#   'symbol': 'GTO',
#   'volume_24h': 6949390.0},
#  {'circulating_supply': 375000000.0,
#   'market_cap': 46673625.0,
#   'name': 'Hive',
#   'platform': 'Ethereum',
#   'price': 0.124463,
#   'symbol': 'HVN',
#   'volume_24h': 72737.1},
#  {'circulating_supply': 24454155.3359,
#   'market_cap': 45366126.2713,
#   'name': 'TokenCard',
#   'platform': 'Ethereum',
#   'price': 1.85515,
#   'symbol': 'TKN',
#   'volume_24h': 117681.0},
#  {'circulating_supply': 155000000.0,
#   'market_cap': 45220630.0,
#   'name': 'Presearch',
#   'platform': 'Ethereum',
#   'price': 0.291746,
#   'symbol': 'PRE',
#   'volume_24h': 30521.5},
#  {'circulating_supply': 2297853.07853,
#   'market_cap': 45092609.2425,
#   'name': 'Lunyr',
#   'platform': 'Ethereum',
#   'price': 19.6238,
#   'symbol': 'LUN',
#   'volume_24h': 4944270.0},
#  {'circulating_supply': 164966467.432,
#   'market_cap': 43659035.4716,
#   'name': 'Viberate',
#   'platform': 'Ethereum',
#   'price': 0.264654,
#   'symbol': 'VIB',
#   'volume_24h': 8319960.0},
#  {'circulating_supply': 39236491.0,
#   'market_cap': 43479132.7718,
#   'name': 'Grid+',
#   'platform': 'Ethereum',
#   'price': 1.10813,
#   'symbol': 'GRID',
#   'volume_24h': 3377.48},
#  {'circulating_supply': 65351403.0,
#   'market_cap': 43199630.0335,
#   'name': 'Qbao',
#   'platform': 'Qtum',
#   'price': 0.661036,
#   'symbol': 'QBT',
#   'volume_24h': 6483790.0},
#  {'circulating_supply': 79191383.6244,
#   'market_cap': 43139902.1863,
#   'name': 'Spectre.ai Di...',
#   'platform': 'Ethereum',
#   'price': 0.544755,
#   'symbol': 'SXDT',
#   'volume_24h': 1054.37},
#  {'circulating_supply': 85558370.5,
#   'market_cap': 43029614.6005,
#   'name': 'FirstBlood',
#   'platform': 'Ethereum',
#   'price': 0.502927,
#   'symbol': '1ST',
#   'volume_24h': 1153190.0},
#  {'circulating_supply': 8146000.7794,
#   'market_cap': 43019600.3361,
#   'name': 'TaaS',
#   'platform': 'Ethereum',
#   'price': 5.28107,
#   'symbol': 'TAAS',
#   'volume_24h': 220236.0},
#  {'circulating_supply': 582029028.5,
#   'market_cap': 41506992.7472,
#   'name': 'Energo',
#   'platform': 'Ethereum',
#   'price': 0.0713143,
#   'symbol': 'TSL',
#   'volume_24h': 2571900.0},
#  {'circulating_supply': 1543157590.0,
#   'market_cap': 40942594.2306,
#   'name': 'Safe Exchange...',
#   'platform': 'Omni',
#   'price': 0.0265317,
#   'symbol': 'SAFEX',
#   'volume_24h': 82055.0},
#  {'circulating_supply': 30333338.8577,
#   'market_cap': 40763154.0905,
#   'name': 'Delphy',
#   'platform': 'Ethereum',
#   'price': 1.34384,
#   'symbol': 'DPY',
#   'volume_24h': 901067.0},
#  {'circulating_supply': 178250000.0,
#   'market_cap': 39550644.75,
#   'name': 'Ink',
#   'platform': 'Qtum',
#   'price': 0.221883,
#   'symbol': 'INK',
#   'volume_24h': 17628900.0},
#  {'circulating_supply': 92147500.0,
#   'market_cap': 36568827.5225,
#   'name': 'WeTrust',
#   'platform': 'Ethereum',
#   'price': 0.396851,
#   'symbol': 'TRST',
#   'volume_24h': 300918.0},
#  {'circulating_supply': 325000000.0,
#   'market_cap': 36245625.0,
#   'name': 'Cofound.it',
#   'platform': 'Ethereum',
#   'price': 0.111525,
#   'symbol': 'CFI',
#   'volume_24h': 472873.0},
#  {'circulating_supply': 207162000.0,
#   'market_cap': 36160748.586,
#   'name': 'bitCNY',
#   'platform': 'BitShares',
#   'price': 0.174553,
#   'symbol': 'BITCNY',
#   'volume_24h': 55695700.0},
#  {'circulating_supply': 201000000.0,
#   'market_cap': 35965332.0,
#   'name': 'InsurePal',
#   'platform': 'Ethereum',
#   'price': 0.178932,
#   'symbol': 'IPL',
#   'volume_24h': 46831.0},
#  {'circulating_supply': 1750000000.0,
#   'market_cap': 35646450.0,
#   'name': 'SwftCoin',
#   'platform': 'Ethereum',
#   'price': 0.0203694,
#   'symbol': 'SWFTC',
#   'volume_24h': 24975400.0},
#  {'circulating_supply': 231436247.173,
#   'market_cap': 35007972.4924,
#   'name': 'YOYOW',
#   'platform': 'BitShares',
#   'price': 0.151264,
#   'symbol': 'YOYOW',
#   'volume_24h': 1081940.0},
#  {'circulating_supply': 39483257.6434,
#   'market_cap': 34307160.4994,
#   'name': 'Bloom',
#   'platform': 'Ethereum',
#   'price': 0.868904,
#   'symbol': 'BLT',
#   'volume_24h': 1046120.0},
#  {'circulating_supply': 216973356.3,
#   'market_cap': 34301317.8975,
#   'name': 'Monetha',
#   'platform': 'Ethereum',
#   'price': 0.15809,
#   'symbol': 'MTH',
#   'volume_24h': 860199.0},
#  {'circulating_supply': 10500000.0,
#   'market_cap': 33820080.0,
#   'name': 'Nimiq',
#   'platform': 'Ethereum',
#   'price': 3.22096,
#   'symbol': 'NET',
#   'volume_24h': 120942.0},
#  {'circulating_supply': 701884009.0,
#   'market_cap': 32925168.297,
#   'name': 'Pepe Cash',
#   'platform': 'Counterparty',
#   'price': 0.0469097,
#   'symbol': 'PEPECASH',
#   'volume_24h': 179744.0},
#  {'circulating_supply': 1877455408.41,
#   'market_cap': 32631489.217,
#   'name': 'Selfkey',
#   'platform': 'Ethereum',
#   'price': 0.0173807,
#   'symbol': 'KEY',
#   'volume_24h': 751071.0},
#  {'circulating_supply': 162862944.036,
#   'market_cap': 32418683.325,
#   'name': 'Humaniq',
#   'platform': 'Ethereum',
#   'price': 0.199055,
#   'symbol': 'HMQ',
#   'volume_24h': 525114.0},
#  {'circulating_supply': 142215728.19,
#   'market_cap': 32417648.5937,
#   'name': 'Lamden',
#   'platform': 'Ethereum',
#   'price': 0.227947,
#   'symbol': 'TAU',
#   'volume_24h': 124740.0},
#  {'circulating_supply': 1153170765.0,
#   'market_cap': 32227432.7353,
#   'name': 'Zeusshield',
#   'platform': 'Ethereum',
#   'price': 0.0279468,
#   'symbol': 'ZSC',
#   'volume_24h': 1179500.0},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 32149000.0,
#   'name': 'Blocktix',
#   'platform': 'Ethereum',
#   'price': 0.803725,
#   'symbol': 'TIX',
#   'volume_24h': 9241700.0},
#  {'circulating_supply': 16500000.0,
#   'market_cap': 31746660.0,
#   'name': 'Everex',
#   'platform': 'Ethereum',
#   'price': 1.92404,
#   'symbol': 'EVX',
#   'volume_24h': 4460060.0},
#  {'circulating_supply': 175109299.0,
#   'market_cap': 31011156.4157,
#   'name': 'Worldcore',
#   'platform': 'Ethereum',
#   'price': 0.177096,
#   'symbol': 'WRC',
#   'volume_24h': 1804000.0},
#  {'circulating_supply': 85978873.0,
#   'market_cap': 30483895.401,
#   'name': 'Agrello',
#   'platform': 'Ethereum',
#   'price': 0.354551,
#   'symbol': 'DLT',
#   'volume_24h': 963863.0},
#  {'circulating_supply': 84285535.961,
#   'market_cap': 30403309.9608,
#   'name': 'Trade Token',
#   'platform': 'Ethereum',
#   'price': 0.360718,
#   'symbol': 'TIO',
#   'volume_24h': 585690.0},
#  {'circulating_supply': 30150150.1476,
#   'market_cap': 30161004.2017,
#   'name': 'Maecenas',
#   'platform': 'Ethereum',
#   'price': 1.00036,
#   'symbol': 'ART',
#   'volume_24h': 1632.77},
#  {'circulating_supply': 114378947.154,
#   'market_cap': 29802921.6074,
#   'name': 'SunContract',
#   'platform': 'Ethereum',
#   'price': 0.260563,
#   'symbol': 'SNC',
#   'volume_24h': 7652250.0},
#  {'circulating_supply': 82256324.0,
#   'market_cap': 29786166.5089,
#   'name': 'Synereo',
#   'platform': 'Omni',
#   'price': 0.362114,
#   'symbol': 'AMP',
#   'volume_24h': 630554.0},
#  {'circulating_supply': 35778843.8312,
#   'market_cap': 29648103.1619,
#   'name': 'iXledger',
#   'platform': 'Ethereum',
#   'price': 0.828649,
#   'symbol': 'IXT',
#   'volume_24h': 645084.0},
#  {'circulating_supply': 1005414013.0,
#   'market_cap': 29643626.7593,
#   'name': 'Karma',
#   'platform': 'BitShares',
#   'price': 0.029484,
#   'symbol': 'KRM',
#   'volume_24h': 101254.0},
#  {'circulating_supply': 77839404.0,
#   'market_cap': 28795986.9552,
#   'name': 'LAToken',
#   'platform': 'Ethereum',
#   'price': 0.369941,
#   'symbol': 'LA',
#   'volume_24h': 472353.0},
#  {'circulating_supply': 501394405.74,
#   'market_cap': 27237749.6974,
#   'name': 'BitClave',
#   'platform': 'Ethereum',
#   'price': 0.054324,
#   'symbol': 'CAT',
#   'volume_24h': 481473.0},
#  {'circulating_supply': 35670586.1094,
#   'market_cap': 27188406.0973,
#   'name': 'Olympus Labs',
#   'platform': 'Ethereum',
#   'price': 0.762208,
#   'symbol': 'MOT',
#   'volume_24h': 1419610.0},
#  {'circulating_supply': 19628888.0,
#   'market_cap': 26821501.4298,
#   'name': 'Moeda Loyalty...',
#   'platform': 'Ethereum',
#   'price': 1.36643,
#   'symbol': 'MDA',
#   'volume_24h': 1634470.0},
#  {'circulating_supply': 17029321.0837,
#   'market_cap': 26704700.1506,
#   'name': 'Ormeus Coin',
#   'platform': 'Ethereum',
#   'price': 1.56816,
#   'symbol': 'ORME',
#   'volume_24h': 3961490.0},
#  {'circulating_supply': 591500000.0,
#   'market_cap': 26046051.85,
#   'name': 'DomRaider',
#   'platform': 'Ethereum',
#   'price': 0.0440339,
#   'symbol': 'DRT',
#   'volume_24h': 4404.92},
#  {'circulating_supply': 16681759.3911,
#   'market_cap': 25956483.9773,
#   'name': 'Propy',
#   'platform': 'Ethereum',
#   'price': 1.55598,
#   'symbol': 'PRO',
#   'volume_24h': 9493500.0},
#  {'circulating_supply': 75000000.0,
#   'market_cap': 24687750.0,
#   'name': 'Matchpool',
#   'platform': 'Ethereum',
#   'price': 0.32917,
#   'symbol': 'GUP',
#   'volume_24h': 4132160.0},
#  {'circulating_supply': 28728253.2784,
#   'market_cap': 24534301.767,
#   'name': 'Neumark',
#   'platform': 'Ethereum',
#   'price': 0.854013,
#   'symbol': 'NEU',
#   'volume_24h': 111518.0},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 24497080.0,
#   'name': 'Bodhi',
#   'platform': 'Qtum',
#   'price': 0.612427,
#   'symbol': 'BOT',
#   'volume_24h': 126143.0},
#  {'circulating_supply': 349367127.0,
#   'market_cap': 24490950.0331,
#   'name': 'QunQun',
#   'platform': 'Ethereum',
#   'price': 0.0701009,
#   'symbol': 'QUN',
#   'volume_24h': 7146430.0},
#  {'circulating_supply': 13631512.4213,
#   'market_cap': 24265182.6309,
#   'name': 'Playkey',
#   'platform': 'Ethereum',
#   'price': 1.78008,
#   'symbol': 'PKT',
#   'volume_24h': 62108.7},
#  {'circulating_supply': 36849888.0906,
#   'market_cap': 23807680.8985,
#   'name': 'CanYaCoin',
#   'platform': 'Ethereum',
#   'price': 0.646072,
#   'symbol': 'CAN',
#   'volume_24h': 520875.0},
#  {'circulating_supply': 62487457.459,
#   'market_cap': 23696243.6678,
#   'name': 'EncrypGen',
#   'platform': 'Ethereum',
#   'price': 0.379216,
#   'symbol': 'DNA',
#   'volume_24h': 143808.0},
#  {'circulating_supply': 140000000.0,
#   'market_cap': 23663780.0,
#   'name': 'Mothership',
#   'platform': 'Ethereum',
#   'price': 0.169027,
#   'symbol': 'MSP',
#   'volume_24h': 221922.0},
#  {'circulating_supply': 300000000.0,
#   'market_cap': 23501820.0,
#   'name': 'Game.com',
#   'platform': 'Ethereum',
#   'price': 0.0783394,
#   'symbol': 'GTC',
#   'volume_24h': 1163480.0},
#  {'circulating_supply': 2799476.19933,
#   'market_cap': 23493008.3015,
#   'name': 'MyBit Token',
#   'platform': 'Ethereum',
#   'price': 8.39193,
#   'symbol': 'MYB',
#   'volume_24h': 18802.4},
#  {'circulating_supply': 17500000.0,
#   'market_cap': 23454025.0,
#   'name': 'Covesting',
#   'platform': 'Ethereum',
#   'price': 1.34023,
#   'symbol': 'COV',
#   'volume_24h': 46928.3},
#  {'circulating_supply': 263034654.051,
#   'market_cap': 23177850.9145,
#   'name': 'HelloGold',
#   'platform': 'Ethereum',
#   'price': 0.0881171,
#   'symbol': 'HGT',
#   'volume_24h': 35170.2},
#  {'circulating_supply': 45166200.0,
#   'market_cap': 23177848.5216,
#   'name': 'BlockMason Cr...',
#   'platform': 'Ethereum',
#   'price': 0.513168,
#   'symbol': 'BCPT',
#   'volume_24h': 1289490.0},
#  {'circulating_supply': 13000000.0,
#   'market_cap': 23158460.0,
#   'name': 'Aeron',
#   'platform': 'Ethereum',
#   'price': 1.78142,
#   'symbol': 'ARN',
#   'volume_24h': 2291540.0},
#  {'circulating_supply': 987831611.047,
#   'market_cap': 22944562.3961,
#   'name': 'Soarcoin',
#   'platform': 'Ethereum',
#   'price': 0.0232272,
#   'symbol': 'SOAR',
#   'volume_24h': 22624.0},
#  {'circulating_supply': 8049000.11223,
#   'market_cap': 22416706.7826,
#   'name': 'Swarm City',
#   'platform': 'Ethereum',
#   'price': 2.78503,
#   'symbol': 'SWT',
#   'volume_24h': 2793040.0},
#  {'circulating_supply': 15000000.0,
#   'market_cap': 21329550.0,
#   'name': 'NVO',
#   'platform': 'Counterparty',
#   'price': 1.42197,
#   'symbol': 'NVST',
#   'volume_24h': 1539.25},
#  {'circulating_supply': 1294932.34235,
#   'market_cap': 21181855.7899,
#   'name': 'Numeraire',
#   'platform': 'Ethereum',
#   'price': 16.3575,
#   'symbol': 'NMR',
#   'volume_24h': 290627.0},
#  {'circulating_supply': 3592379.31019,
#   'market_cap': 21130518.7977,
#   'name': 'Open Trading ...',
#   'platform': 'Ethereum',
#   'price': 5.88204,
#   'symbol': 'OTN',
#   'volume_24h': 61374.6},
#  {'circulating_supply': 122873786.567,
#   'market_cap': 20878468.0659,
#   'name': 'Bounty0x',
#   'platform': 'Ethereum',
#   'price': 0.169918,
#   'symbol': 'BNTY',
#   'volume_24h': 281617.0},
#  {'circulating_supply': 42142604.233,
#   'market_cap': 20086092.3147,
#   'name': 'Stox',
#   'platform': 'Ethereum',
#   'price': 0.476622,
#   'symbol': 'STX',
#   'volume_24h': 749571.0},
#  {'circulating_supply': 1050000000.0,
#   'market_cap': 20049015.0,
#   'name': 'AirToken',
#   'platform': 'Ethereum',
#   'price': 0.0190943,
#   'symbol': 'AIR',
#   'volume_24h': 390860.0},
#  {'circulating_supply': 20923342.6892,
#   'market_cap': 19668946.4483,
#   'name': 'Profile Utili...',
#   'platform': 'Qtum',
#   'price': 0.940048,
#   'symbol': 'PUT',
#   'volume_24h': 3515150.0},
#  {'circulating_supply': 13853582587.9,
#   'market_cap': 19654077.6175,
#   'name': 'LIFE',
#   'platform': 'Ethereum',
#   'price': 0.0014187,
#   'symbol': 'LIFE',
#   'volume_24h': 51664.1},
#  {'circulating_supply': 18897126.0,
#   'market_cap': 19378057.8567,
#   'name': 'eBitcoin',
#   'platform': 'Ethereum',
#   'price': 1.02545,
#   'symbol': 'EBTC',
#   'volume_24h': 238968.0},
#  {'circulating_supply': 3716164.94793,
#   'market_cap': 19220190.919,
#   'name': 'Hacken',
#   'platform': 'Ethereum',
#   'price': 5.17205,
#   'symbol': 'HKN',
#   'volume_24h': 151295.0},
#  {'circulating_supply': 405001426.0,
#   'market_cap': 19069006.1415,
#   'name': 'Snovio',
#   'platform': 'Ethereum',
#   'price': 0.0470838,
#   'symbol': 'SNOV',
#   'volume_24h': 669578.0},
#  {'circulating_supply': 952429892.0,
#   'market_cap': 19055455.3352,
#   'name': 'Target Coin',
#   'platform': 'Ethereum',
#   'price': 0.0200072,
#   'symbol': 'TGT',
#   'volume_24h': 641.972},
#  {'circulating_supply': 9973579.0,
#   'market_cap': 18999269.0518,
#   'name': 'Waves Communi...',
#   'platform': 'Waves',
#   'price': 1.90496,
#   'symbol': 'WCT',
#   'volume_24h': 131972.0},
#  {'circulating_supply': 321137782.25,
#   'market_cap': 18426885.9455,
#   'name': 'KickCoin',
#   'platform': 'Ethereum',
#   'price': 0.05738,
#   'symbol': 'KICK',
#   'volume_24h': 565677.0},
#  {'circulating_supply': 51200000.0,
#   'market_cap': 18368563.2,
#   'name': 'Primas',
#   'platform': 'Ethereum',
#   'price': 0.358761,
#   'symbol': 'PST',
#   'volume_24h': 373952.0},
#  {'circulating_supply': 25009249.58,
#   'market_cap': 18290489.6711,
#   'name': 'OAX',
#   'platform': 'Ethereum',
#   'price': 0.731349,
#   'symbol': 'OAX',
#   'volume_24h': 570333.0},
#  {'circulating_supply': 70000000.0,
#   'market_cap': 18267480.0,
#   'name': 'BitDice',
#   'platform': 'Ethereum',
#   'price': 0.260964,
#   'symbol': 'CSNO',
#   'volume_24h': 72521.2},
#  {'circulating_supply': 30000000.0,
#   'market_cap': 18159660.0,
#   'name': 'OracleChain',
#   'platform': 'BitShares',
#   'price': 0.605322,
#   'symbol': 'OCT',
#   'volume_24h': 64442.8},
#  {'circulating_supply': 7001622.64879,
#   'market_cap': 18043881.7282,
#   'name': 'Etheroll',
#   'platform': 'Ethereum',
#   'price': 2.5771,
#   'symbol': 'DICE',
#   'volume_24h': 64454.5},
#  {'circulating_supply': 192929698.0,
#   'market_cap': 17665299.1099,
#   'name': 'CoinMeet',
#   'platform': 'Ethereum',
#   'price': 0.0915634,
#   'symbol': 'MEE',
#   'volume_24h': 4788650.0},
#  {'circulating_supply': 100000000.0,
#   'market_cap': 17583300.0,
#   'name': 'Aurora DAO',
#   'platform': 'Ethereum',
#   'price': 0.175833,
#   'symbol': 'AURA',
#   'volume_24h': 33159.9},
#  {'circulating_supply': 66521026.0,
#   'market_cap': 17456780.2481,
#   'name': 'Nexium',
#   'platform': 'Ethereum',
#   'price': 0.262425,
#   'symbol': 'NXC',
#   'volume_24h': 47284.9},
#  {'circulating_supply': 104544591.138,
#   'market_cap': 17257280.2037,
#   'name': 'DecentBet',
#   'platform': 'Ethereum',
#   'price': 0.165071,
#   'symbol': 'DBET',
#   'volume_24h': 12278.5},
#  {'circulating_supply': 20960880.7867,
#   'market_cap': 17253424.9976,
#   'name': 'Blackmoon',
#   'platform': 'Ethereum',
#   'price': 0.823125,
#   'symbol': 'BMC',
#   'volume_24h': 574132.0},
#  {'circulating_supply': 14679100.0,
#   'market_cap': 17248382.873,
#   'name': 'bitUSD',
#   'platform': 'BitShares',
#   'price': 1.17503,
#   'symbol': 'BITUSD',
#   'volume_24h': 2522500.0},
#  {'circulating_supply': 2777600756.0,
#   'market_cap': 17227846.481,
#   'name': 'NuShares',
#   'platform': 'NuBits',
#   'price': 0.00620242,
#   'symbol': 'NSR',
#   'volume_24h': 6775.16},
#  {'circulating_supply': 36645278.3876,
#   'market_cap': 17212763.6473,
#   'name': 'BLUE',
#   'platform': 'Ethereum',
#   'price': 0.469713,
#   'symbol': 'BLUE',
#   'volume_24h': 44656.3},
#  {'circulating_supply': 3820953.60641,
#   'market_cap': 17129755.3224,
#   'name': 'Polybius',
#   'platform': 'Ethereum',
#   'price': 4.48311,
#   'symbol': 'PLBT',
#   'volume_24h': 30076.8},
#  {'circulating_supply': 46448224.09,
#   'market_cap': 17056763.2986,
#   'name': 'ProChain',
#   'platform': 'Ethereum',
#   'price': 0.367221,
#   'symbol': 'PRA',
#   'volume_24h': 922154.0},
#  {'circulating_supply': 1000000000.0,
#   'market_cap': 17049600.0,
#   'name': 'Circuits of V...',
#   'platform': 'Counterparty',
#   'price': 0.0170496,
#   'symbol': 'COVAL',
#   'volume_24h': 440492.0},
#  {'circulating_supply': 10000000.0,
#   'market_cap': 17044800.0,
#   'name': 'Uquid Coin',
#   'platform': 'Ethereum',
#   'price': 1.70448,
#   'symbol': 'UQC',
#   'volume_24h': 54378.6},
#  {'circulating_supply': 618262216.98,
#   'market_cap': 16912439.293,
#   'name': 'Viuly',
#   'platform': 'Ethereum',
#   'price': 0.0273548,
#   'symbol': 'VIU',
#   'volume_24h': 1912780.0},
#  {'circulating_supply': 127112546.475,
#   'market_cap': 16901646.8546,
#   'name': 'Xaurum',
#   'platform': 'Ethereum',
#   'price': 0.132966,
#   'symbol': 'XAUR',
#   'volume_24h': 103065.0},
#  {'circulating_supply': 38538648.0864,
#   'market_cap': 16807513.7421,
#   'name': 'ALIS',
#   'platform': 'Ethereum',
#   'price': 0.436121,
#   'symbol': 'ALIS',
#   'volume_24h': 28240.1},
#  {'circulating_supply': 64936617.3841,
#   'market_cap': 15825962.7692,
#   'name': 'Paragon',
#   'platform': 'Ethereum',
#   'price': 0.243714,
#   'symbol': 'PRG',
#   'volume_24h': 121431.0},
#  {'circulating_supply': 22747808.5,
#   'market_cap': 15668030.8084,
#   'name': 'Databits',
#   'platform': 'Counterparty',
#   'price': 0.688771,
#   'symbol': 'DTB',
#   'volume_24h': 35733.9},
#  {'circulating_supply': 710112.8108,
#   'market_cap': 15332826.8221,
#   'name': 'Chronobank',
#   'platform': 'Ethereum',
#   'price': 21.5921,
#   'symbol': 'TIME',
#   'volume_24h': 259023.0},
#  {'circulating_supply': 6000000.0,
#   'market_cap': 15288600.0,
#   'name': 'Aventus',
#   'platform': 'Ethereum',
#   'price': 2.5481,
#   'symbol': 'AVT',
#   'volume_24h': 306002.0},
#  {'circulating_supply': 529861448.67,
#   'market_cap': 15240881.7234,
#   'name': 'Gatcoin',
#   'platform': 'Ethereum',
#   'price': 0.0287639,
#   'symbol': 'GAT',
#   'volume_24h': 70089.5},
#  {'circulating_supply': 574512758.0,
#   'market_cap': 15142949.8241,
#   'name': 'FoldingCoin',
#   'platform': 'Counterparty',
#   'price': 0.0263579,
#   'symbol': 'FLDC',
#   'volume_24h': 92401.6},
#  {'circulating_supply': 31057491.9601,
#   'market_cap': 15136800.4315,
#   'name': 'Elixir',
#   'platform': 'Ethereum',
#   'price': 0.48738,
#   'symbol': 'ELIX',
#   'volume_24h': 98288.9},
#  {'circulating_supply': 49596285.4494,
#   'market_cap': 15079205.0318,
#   'name': 'Blockport',
#   'platform': 'Ethereum',
#   'price': 0.304039,
#   'symbol': 'BPT',
#   'volume_24h': 61495.8},
#  {'circulating_supply': 3709674.34,
#   'market_cap': 15032342.3605,
#   'name': 'Hedge',
#   'platform': 'Ethereum',
#   'price': 4.0522,
#   'symbol': 'HDG',
#   'volume_24h': 16430.6},
#  {'circulating_supply': 13516418.1379,
#   'market_cap': 15023228.4319,
#   'name': 'Hubii Network',
#   'platform': 'Ethereum',
#   'price': 1.11148,
#   'symbol': 'HBT',
#   'volume_24h': 1315.32},
#  {'circulating_supply': 185501578.891,
#   'market_cap': 14975264.2115,
#   'name': 'OneRoot Network',
#   'platform': 'Ethereum',
#   'price': 0.0807285,
#   'symbol': 'RNT',
#   'volume_24h': 234044.0},
#  {'circulating_supply': 76091017.5262,
#   'market_cap': 14917035.2579,
#   'name': 'Quantum',
#   'platform': 'Ethereum',
#   'price': 0.196042,
#   'symbol': 'QAU',
#   'volume_24h': 8865.87},
#  {'circulating_supply': 498887536.723,
#   'market_cap': 14904714.1584,
#   'name': 'Voise',
#   'platform': 'Ethereum',
#   'price': 0.0298759,
#   'symbol': 'VOISE',
#   'volume_24h': 774654.0},
#  {'circulating_supply': 10384393.4012,
#   'market_cap': 14812921.8111,
#   'name': 'GET Protocol',
#   'platform': 'Ethereum',
#   'price': 1.42646,
#   'symbol': 'GET',
#   'volume_24h': 8605.33},
#  {'circulating_supply': 26244468.18,
#   'market_cap': 14625727.1831,
#   'name': 'Rivetz',
#   'platform': 'Ethereum',
#   'price': 0.557288,
#   'symbol': 'RVT',
#   'volume_24h': 4990.55},
#  {'circulating_supply': 193535756.218,
#   'market_cap': 14545682.9515,
#   'name': 'AICHAIN',
#   'platform': 'Ethereum',
#   'price': 0.0751576,
#   'symbol': 'AIT',
#   'volume_24h': 96859.7},
#  {'circulating_supply': 581633.665065,
#   'market_cap': 14540725.2999,
#   'name': 'ICOS',
#   'platform': 'Ethereum',
#   'price': 24.9998,
#   'symbol': 'ICOS',
#   'volume_24h': 201117.0},
#  {'circulating_supply': 9292966.0,
#   'market_cap': 14489871.3762,
#   'name': 'LockChain',
#   'platform': 'Ethereum',
#   'price': 1.55923,
#   'symbol': 'LOC',
#   'volume_24h': 49509.0},
#  {'circulating_supply': 70000000.0,
#   'market_cap': 14334810.0,
#   'name': 'Patientory',
#   'platform': 'Ethereum',
#   'price': 0.204783,
#   'symbol': 'PTOY',
#   'volume_24h': 550347.0},
#  {'circulating_supply': 191381257.0,
#   'market_cap': 14204986.7289,
#   'name': 'InvestFeed',
#   'platform': 'Ethereum',
#   'price': 0.0742235,
#   'symbol': 'IFT',
#   'volume_24h': 24553.9},
#  {'circulating_supply': 2000000.0,
#   'market_cap': 14142540.0,
#   'name': 'Exchange Union',
#   'platform': 'Ethereum',
#   'price': 7.07127,
#   'symbol': 'XUC',
#   'volume_24h': 483383.0},
#  {'circulating_supply': 13900637.7524,
#   'market_cap': 14040756.181,
#   'name': 'Dai',
#   'platform': 'Ethereum',
#   'price': 1.01008,
#   'symbol': 'DAI',
#   'volume_24h': 1010460.0},
#  {'circulating_supply': 5143006.61546,
#   'market_cap': 13992063.798,
#   'name': 'Divi',
#   'platform': 'Ethereum',
#   'price': 2.7206,
#   'symbol': 'DIVX',
#   'volume_24h': 106766.0},
#  {'circulating_supply': 6999991.0,
#   'market_cap': 13978772.0273,
#   'name': 'ClearPoll',
#   'platform': 'Ethereum',
#   'price': 1.99697,
#   'symbol': 'POLL',
#   'volume_24h': 352276.0},
#  {'circulating_supply': 2913286556.81,
#   'market_cap': 13898561.8409,
#   'name': 'bitqy',
#   'platform': 'Ethereum',
#   'price': 0.00477075,
#   'symbol': 'BQ',
#   'volume_24h': 1134.21},
#  {'circulating_supply': 72531860.377,
#   'market_cap': 13870267.6599,
#   'name': 'Rialto',
#   'platform': 'Ethereum',
#   'price': 0.19123,
#   'symbol': 'XRL',
#   'volume_24h': 12451.2},
#  {'circulating_supply': 118090510.577,
#   'market_cap': 13067305.4479,
#   'name': 'Leverj',
#   'platform': 'Ethereum',
#   'price': 0.110655,
#   'symbol': 'LEV',
#   'volume_24h': 34197.0},
#  {'circulating_supply': 19429024.2167,
#   'market_cap': 12970175.4092,
#   'name': 'Mysterium',
#   'platform': 'Ethereum',
#   'price': 0.667567,
#   'symbol': 'MYST',
#   'volume_24h': 166174.0},
#  {'circulating_supply': 444444444.4,
#   'market_cap': 12919155.5543,
#   'name': 'Ecobit',
# ...
#   'platform': 'Ethereum',
#   'price': 0.118248,
#   'symbol': 'CXO',
#   'volume_24h': 296129.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'POLY AI',
#   'platform': 'Ethereum',
#   'price': 4.25478,
#   'symbol': 'AI',
#   'volume_24h': 257700.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'RefToken',
#   'platform': 'Ethereum',
#   'price': 24.9596,
#   'symbol': 'REF',
#   'volume_24h': 253968.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DRP Utility',
#   'platform': 'Ethereum',
#   'price': 0.789616,
#   'symbol': 'DRPU',
#   'volume_24h': 253946.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'iQuant',
#   'platform': 'Ethereum',
#   'price': 0.139939,
#   'symbol': 'IQT',
#   'volume_24h': 208841.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'COMSA [XEM]',
#   'platform': 'NEM',
#   'price': 1.2354,
#   'symbol': 'CMS',
#   'volume_24h': 199814.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'adbank',
#   'platform': 'Ethereum',
#   'price': 0.0267898,
#   'symbol': 'ADB',
#   'volume_24h': 165251.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Polymath Network',
#   'platform': 'Ethereum',
#   'price': 0.905857,
#   'symbol': 'POLY',
#   'volume_24h': 162209.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Matrix AI Net...',
#   'platform': 'Ethereum',
#   'price': 0.688367,
#   'symbol': 'MAN',
#   'volume_24h': 147242.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'MOAC',
#   'platform': 'Ethereum',
#   'price': 12.8008,
#   'symbol': 'MOAC',
#   'volume_24h': 143508.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Datawallet',
#   'platform': 'Ethereum',
#   'price': 0.136189,
#   'symbol': 'DXT',
#   'volume_24h': 135588.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TokenClub',
#   'platform': 'Ethereum',
#   'price': 0.0287593,
#   'symbol': 'TCT',
#   'volume_24h': 132549.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Pundi X',
#   'platform': 'Ethereum',
#   'price': 1.58541,
#   'symbol': 'PXS',
#   'volume_24h': 126385.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Content and A...',
#   'platform': 'Ethereum',
#   'price': 0.038904,
#   'symbol': 'CAN',
#   'volume_24h': 125009.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BlockCDN',
#   'platform': 'Ethereum',
#   'price': 0.117603,
#   'symbol': 'BCDN',
#   'volume_24h': 115996.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Mixin',
#   'platform': 'Ethereum',
#   'price': 1023.32,
#   'symbol': 'XIN',
#   'volume_24h': 93156.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CryptopiaFeeS...',
#   'platform': 'Ubiq',
#   'price': 2715.17,
#   'symbol': 'CEFS',
#   'volume_24h': 91570.4},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Zap',
#   'platform': 'Ethereum',
#   'price': 0.291954,
#   'symbol': 'ZAP',
#   'volume_24h': 79885.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Tokenbox',
#   'platform': 'Ethereum',
#   'price': 0.747875,
#   'symbol': 'TBX',
#   'volume_24h': 78719.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DIMCOIN',
#   'platform': 'NEM',
#   'price': 0.00652727,
#   'symbol': 'DIM',
#   'volume_24h': 69038.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'WETH',
#   'platform': 'Ethereum',
#   'price': 903.127,
#   'symbol': 'WETH',
#   'volume_24h': 65946.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'aXpire',
#   'platform': 'Ethereum',
#   'price': 0.0660613,
#   'symbol': 'AXP',
#   'volume_24h': 64807.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EtherSportz',
#   'platform': 'Ethereum',
#   'price': 0.613193,
#   'symbol': 'ESZ',
#   'volume_24h': 63175.4},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Vezt',
#   'platform': 'Ethereum',
#   'price': 0.239349,
#   'symbol': 'VZT',
#   'volume_24h': 62085.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'IPChain',
#   'platform': 'Ethereum',
#   'price': 0.723796,
#   'symbol': 'IPC',
#   'volume_24h': 58511.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'President Trump',
#   'platform': 'Omni',
#   'price': 0.084085,
#   'symbol': 'PRES',
#   'volume_24h': 48878.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sphre AIR ',
#   'platform': 'Ethereum',
#   'price': 0.23736,
#   'symbol': 'XID',
#   'volume_24h': 47018.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Crypterium',
#   'platform': 'Ethereum',
#   'price': 0.803026,
#   'symbol': 'CRPT',
#   'volume_24h': 44054.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Speed Mining ...',
#   'platform': None,
#   'price': 49.6735,
#   'symbol': 'SMS',
#   'volume_24h': 42888.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maggie',
#   'platform': 'Ethereum',
#   'price': 0.0345457,
#   'symbol': 'MAG',
#   'volume_24h': 38938.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'FidentiaX',
#   'platform': 'Ethereum',
#   'price': 0.293314,
#   'symbol': 'FDX',
#   'volume_24h': 32437.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Nitro',
#   'platform': 'Ethereum',
#   'price': 0.342568,
#   'symbol': 'NOX',
#   'volume_24h': 30904.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'IDEX Membership',
#   'platform': 'Ethereum',
#   'price': 5270.07,
#   'symbol': 'IDXM',
#   'volume_24h': 24020.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Escroco',
#   'platform': 'Waves',
#   'price': 1.04386,
#   'symbol': 'ESC',
#   'volume_24h': 23617.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ArbitrageCT',
#   'platform': 'Ethereum',
#   'price': 0.0208541,
#   'symbol': 'ARCT',
#   'volume_24h': 23081.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ZenGold',
#   'platform': 'BitShares',
#   'price': 0.051149,
#   'symbol': 'ZENGOLD',
#   'volume_24h': 18302.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Equal',
#   'platform': 'Ethereum',
#   'price': 0.00487301,
#   'symbol': 'EQL',
#   'volume_24h': 17912.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maverick Chain',
#   'platform': 'Ethereum',
#   'price': 0.0861181,
#   'symbol': 'MVC',
#   'volume_24h': 16239.2},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Swarm',
#   'platform': 'Ethereum',
#   'price': 1.09564,
#   'symbol': 'SWM',
#   'volume_24h': 16025.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GameChain System',
#   'platform': 'Ethereum',
#   'price': 0.0219376,
#   'symbol': 'GCS',
#   'volume_24h': 14354.2},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Monero Gold',
#   'platform': 'Ethereum',
#   'price': 0.000260964,
#   'symbol': 'XMRG',
#   'volume_24h': 13085.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Smartlands',
#   'platform': 'Stellar',
#   'price': 1.01477,
#   'symbol': 'SLT',
#   'volume_24h': 12051.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bitair',
#   'platform': 'Ethereum',
#   'price': 0.00351096,
#   'symbol': 'BTCA',
#   'volume_24h': 7830.06},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'OX Fina',
#   'platform': 'Ethereum',
#   'price': 0.00111475,
#   'symbol': 'OX',
#   'volume_24h': 7352.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'United Trader...',
#   'platform': 'Ethereum',
#   'price': 0.829569,
#   'symbol': 'UTT',
#   'volume_24h': 5457.93},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Cloud',
#   'platform': 'Ethereum',
#   'price': 0.0749681,
#   'symbol': 'CLD',
#   'volume_24h': 5156.22},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SISA',
#   'platform': 'Ethereum',
#   'price': 0.0128937,
#   'symbol': 'SISA',
#   'volume_24h': 4445.36},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bankex',
#   'platform': 'Ethereum',
#   'price': 1.08018,
#   'symbol': 'BKX',
#   'volume_24h': 4046.06},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GOLD Reward T...',
#   'platform': 'Ethereum',
#   'price': 0.0764292,
#   'symbol': 'GRX',
#   'volume_24h': 3984.56},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BitSerial',
#   'platform': 'Ethereum',
#   'price': 0.0693055,
#   'symbol': 'BTE',
#   'volume_24h': 3211.86},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Macro',
#   'platform': 'Ethereum',
#   'price': 0.850794,
#   'symbol': 'MCR',
#   'volume_24h': 3054.26},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CORION',
#   'platform': 'Ethereum Classic',
#   'price': 0.465995,
#   'symbol': 'COR',
#   'volume_24h': 2846.47},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'NEO GOLD',
#   'platform': 'Ethereum',
#   'price': 0.00732757,
#   'symbol': 'NEOG',
#   'volume_24h': 2301.92},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Musiconomi',
#   'platform': 'Ethereum',
#   'price': 0.11552,
#   'symbol': 'MCI',
#   'volume_24h': 2210.65},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Blockchain Index',
#   'platform': 'Ethereum',
#   'price': 4.25261,
#   'symbol': 'BLX',
#   'volume_24h': 2110.49},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Storjcoin X',
#   'platform': 'Counterparty',
#   'price': 1.05323,
#   'symbol': 'SJCX',
#   'volume_24h': 2078.26},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Wi Coin',
#   'platform': 'Ethereum',
#   'price': 0.0033559,
#   'symbol': 'WIC',
#   'volume_24h': 1851.49},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'First Bitcoin...',
#   'platform': 'Omni',
#   'price': 0.362335,
#   'symbol': 'BITCF',
#   'volume_24h': 1691.21},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BTCMoon',
#   'platform': 'Ethereum',
#   'price': 0.00973387,
#   'symbol': 'BTCM',
#   'volume_24h': 1623.44},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Ethereum Lite',
#   'platform': 'Ethereum',
#   'price': 0.309274,
#   'symbol': 'ELITE',
#   'volume_24h': 1502.29},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TeslaCoilCoin',
#   'platform': 'Omni',
#   'price': 0.774193,
#   'symbol': 'TESLA',
#   'volume_24h': 1481.17},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'STEX',
#   'platform': 'Nxt',
#   'price': 1.93215,
#   'symbol': 'STEX',
#   'volume_24h': 1377.49},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sand Coin',
#   'platform': 'Ethereum',
#   'price': 2.01455,
#   'symbol': 'SND',
#   'volume_24h': 1234.53},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sense',
#   'platform': 'Ethereum',
#   'price': 0.0432989,
#   'symbol': 'SENSE',
#   'volume_24h': 1209.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'PlexCoin',
#   'platform': 'Ethereum',
#   'price': 0.026962,
#   'symbol': 'PLX',
#   'volume_24h': 1184.92},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Decentralized...',
#   'platform': 'Ethereum',
#   'price': 123.097,
#   'symbol': 'DUBI',
#   'volume_24h': 1023.61},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Alphabit',
#   'platform': 'Ethereum',
#   'price': 74.6355,
#   'symbol': 'ABC',
#   'volume_24h': 993.066},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'HODL Bucks',
#   'platform': 'Ethereum',
#   'price': 0.124654,
#   'symbol': 'HDLB',
#   'volume_24h': 759.444},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Minex',
#   'platform': 'Waves',
#   'price': 0.0207876,
#   'symbol': 'MINEX',
#   'volume_24h': 528.242},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EncryptoTel [...',
#   'platform': 'Ethereum',
#   'price': 0.0758511,
#   'symbol': 'ETT',
#   'volume_24h': 477.374},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LiteCoin Gold',
#   'platform': 'Ethereum',
#   'price': 0.00623833,
#   'symbol': 'LTG',
#   'volume_24h': 386.601},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EtherDelta Token',
#   'platform': 'Ethereum',
#   'price': 0.0413794,
#   'symbol': 'EDT',
#   'volume_24h': 386.601},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'FAPcoin',
#   'platform': 'Ethereum',
#   'price': 0.00383615,
#   'symbol': 'FAP',
#   'volume_24h': 299.676},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Natcoin',
#   'platform': 'Ethereum',
#   'price': 0.0142263,
#   'symbol': 'NTC',
#   'volume_24h': 200.64},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ANRYZE',
#   'platform': 'Waves',
#   'price': 0.0135701,
#   'symbol': 'RYZ',
#   'volume_24h': 155.588},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DMarket',
#   'platform': 'Ethereum',
#   'price': 0.702822,
#   'symbol': 'DMT',
#   'volume_24h': 111.587},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Cash Poker Pro',
#   'platform': 'Ethereum',
#   'price': 0.0527183,
#   'symbol': 'CASH',
#   'volume_24h': 26.3591},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eLTC',
#   'platform': 'Ethereum',
#   'price': 0.000658978,
#   'symbol': 'ELTC2',
#   'volume_24h': 19.33},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'iBTC',
#   'platform': 'Ethereum',
#   'price': 0.00483163,
#   'symbol': 'IBTC',
#   'volume_24h': 12.3009},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Hyper TV',
#   'platform': 'Ethereum',
#   'price': 0.00123009,
#   'symbol': 'HYTV',
#   'volume_24h': 7.90774},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'President Joh...',
#   'platform': 'Omni',
#   'price': 0.0758535,
#   'symbol': 'GARY',
#   'volume_24h': 7.58535},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': '10M Token',
#   'platform': 'Ethereum',
#   'price': 0.00535969,
#   'symbol': '10MT',
#   'volume_24h': 6.15047},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bitcoin2x',
#   'platform': 'Ethereum',
#   'price': 0.00615046,
#   'symbol': 'BTC2X',
#   'volume_24h': 0.878638},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'UAHPay',
#   'platform': 'Ethereum',
#   'price': 0.00010983,
#   'symbol': 'UAHPAY',
#   'volume_24h': 0.878638},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Matryx',
#   'platform': 'Ethereum',
#   'price': 0.901571,
#   'symbol': 'MTX',
#   'volume_24h': 0.878638},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SnakeEyes',
#   'platform': 'Burst',
#   'price': 0.0239283,
#   'symbol': 'SNAKE',
#   'volume_24h': 0.717848},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Internet of T...',
#   'platform': 'Nxt',
#   'price': 793.569,
#   'symbol': 'XOT',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LLToken',
#   'platform': 'Ethereum',
#   'price': None,
#   'symbol': 'LLT',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Swapcoin',
#   'platform': 'Ethereum',
#   'price': 0.259564,
#   'symbol': 'SWP',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bitcoin Silver',
#   'platform': 'Ethereum',
#   'price': 0.00480626,
#   'symbol': 'BTCS',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eGold',
#   'platform': 'Ethereum',
#   'price': 0.0244562,
#   'symbol': 'EGOLD',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Infinity Pay',
#   'platform': 'Ethereum',
#   'price': 0.00120303,
#   'symbol': 'IPY',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Facecoin',
#   'platform': 'Ethereum',
#   'price': 0.00182733,
#   'symbol': 'FC',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eUSD',
#   'platform': 'Ethereum',
#   'price': 0.0005738,
#   'symbol': 'EUSD',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eBIT',
#   'platform': 'Ethereum',
#   'price': 0.00419491,
#   'symbol': 'EBIT',
#   'volume_24h': None},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Faceblock',
#   'platform': 'Ethereum',
#   'price': 0.00323005,
#   'symbol': 'FBL',
#   'volume_24h': None}]

# %% [markdown]
# _________________________________
#
# ## Graphs API
# The graphs API is used internally by coinmarketcap for display graphs info. The params `start` and `end` are passed in unix microseconds timestamps and only are valid those that returns the methods, not whatever.
#
# #### `graphs.currency(name, [start=None, end=None])`
#
# Get graphs data for a currency:

# %%
cmc.graphs.currency("BTC")
# Out:
# {'market_cap_by_available_supply': [[1367174841000, 1500517590],
#   [1367261101000, 1575032004],
#   [1367347502000, 1501657492],
#   [1367433902000, 1298951550],
#   [1367522401000, 1148667722],
#   [1367608801000, 1011066494],
#   [1367695201000, 1236351843],
#   [1367781901000, 1298377788],
#   [1367868303000, 1315992303],
#   [1367954701000, 1183766500],
#   [1368041101000, 1253655040],
#   [1368129001000, 1258130700],
#   [1368215702000, 1322989457],
#   [1368303901000, 1259239352],
#   [1368390301000, 1278708678],
#   [1368476701000, 1306721052],
#   [1368563101000, 1277278987],
#   [1368650101000, 1273849680],
#   [1368736501000, 1289277412],
#   [1368822901000, 1374605382],
#   [1368909301000, 1383755085],
#   [1368995702000, 1346499261],
#   [1369082102000, 1370131821],
#   [1369168502000, 1374154117],
#   [1369254904000, 1375791900],
#   [1369341302000, 1407041527],
#   [1369427701000, 1474180657],
#   [1369514102000, 1464316690],
#   [1369601102000, 1507769010],
#   [1369687501000, 1445444605],
#   [1369773907000, 1448115966],
#   [1369862101000, 1481781794],
#   [1369948501000, 1429308633],
#   [1370036402000, 1436386729],
#   [1370122802000, 1449499974],
#   [1370215501000, 1362684200],
#   [1370301902000, 1361765704],
