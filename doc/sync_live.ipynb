# %% [markdown]
# # <center>Synchronous Pymarketcap Interface</center>
#
# > See also: [Asynchronous Pymarketcap Scraper](async_live.ipynb)

# %%
from IPython.display import IFrame
show_page = lambda endpoint: IFrame("https://coinmarketcap.com/%s" % endpoint, "100%", 400)

# %% [markdown]
# ## Basic usage
#
# #### `Pymarketcap([timeout=20, debug=False, cache=True])`
#
# The first response takes a long time because some data is cached at instantiation of the wrapper.

# %%
from pymarketcap import Pymarketcap
cmc = Pymarketcap(timeout=10)

cmc.exchanges()
# Out:
# []

# %% [markdown]
# > All methods are self explained in docstrings:

# %%
print(cmc.exchanges.__doc__)
# Out:
# Get all the exchanges in coinmarketcap ranked by volumes
#         along with other metadata.
#
#         Args:
#             convert (str, optional): Convert volumes and prices
#                 between USD and BTC. As default ``"USD"``.
#
#         Returns (list):
#             Exchanges with markets and other data included.

# %% [markdown]
# ___________________________________
#
# ## Coinmarketcap API

# %%
show_page("api")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/api"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `ticker(currency=None, limit=0, start=0, convert="USD")`
# If `currency == None`, you will obtain data for all currencies in coinmarketcap:

# %%
cmc.ticker()
# Out:
# [{'24h_volume_usd': 5182320000.0,
#   'available_supply': 16935025.0,
#   'id': 'bitcoin',
#   'last_updated': 1521812364,
#   'market_cap_usd': 141712966601,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin',
#   'percent_change_1h': -1.37,
#   'percent_change_24h': -3.78,
#   'percent_change_7d': -0.13,
#   'price_btc': 1.0,
#   'price_usd': 8368.04,
#   'rank': 1,
#   'symbol': 'BTC',
#   'total_supply': 16935025.0},
#  {'24h_volume_usd': 1536550000.0,
#   'available_supply': 98366201.0,
#   'id': 'ethereum',
#   'last_updated': 1521812353,
#   'market_cap_usd': 50460090617.0,
#   'max_supply': None,
#   'name': 'Ethereum',
#   'percent_change_1h': -1.35,
#   'percent_change_24h': -4.38,
#   'percent_change_7d': -16.2,
#   'price_btc': 0.0614902,
#   'price_usd': 512.982,
#   'rank': 2,
#   'symbol': 'ETH',
#   'total_supply': 98366201.0},
#  {'24h_volume_usd': 397008000.0,
#   'available_supply': 39094227299.0,
#   'id': 'ripple',
#   'last_updated': 1521812341,
#   'market_cap_usd': 24486043761.0,
#   'max_supply': 100000000000,
#   'name': 'Ripple',
#   'percent_change_1h': -1.07,
#   'percent_change_24h': -3.87,
#   'percent_change_7d': -10.08,
#   'price_btc': 7.508e-05,
#   'price_usd': 0.626334,
#   'rank': 3,
#   'symbol': 'XRP',
#   'total_supply': 99992434971.0},
#  {'24h_volume_usd': 319482000.0,
#   'available_supply': 17033463.0,
#   'id': 'bitcoin-cash',
#   'last_updated': 1521812353,
#   'market_cap_usd': 16518455761.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Cash',
#   'percent_change_1h': -1.32,
#   'percent_change_24h': -3.4,
#   'percent_change_7d': 0.19,
#   'price_btc': 0.116244,
#   'price_usd': 969.765,
#   'rank': 4,
#   'symbol': 'BCH',
#   'total_supply': 17033463.0},
#  {'24h_volume_usd': 375100000.0,
#   'available_supply': 55755864.0,
#   'id': 'litecoin',
#   'last_updated': 1521812340,
#   'market_cap_usd': 8782998299.0,
#   'max_supply': 84000000.0,
#   'name': 'Litecoin',
#   'percent_change_1h': -1.27,
#   'percent_change_24h': -4.41,
#   'percent_change_7d': -4.54,
#   'price_btc': 0.0188824,
#   'price_usd': 157.526,
#   'rank': 5,
#   'symbol': 'LTC',
#   'total_supply': 55755864.0},
#  {'24h_volume_usd': 975780000.0,
#   'available_supply': 746598237.0,
#   'id': 'eos',
#   'last_updated': 1521812351,
#   'market_cap_usd': 5000931508.0,
#   'max_supply': 1000000000.0,
#   'name': 'EOS',
#   'percent_change_1h': -1.28,
#   'percent_change_24h': 1.79,
#   'percent_change_7d': 30.09,
#   'price_btc': 0.00080291,
#   'price_usd': 6.69829,
#   'rank': 6,
#   'symbol': 'EOS',
#   'total_supply': 900000000.0},
#  {'24h_volume_usd': 148820000.0,
#   'available_supply': 25927070538.0,
#   'id': 'cardano',
#   'last_updated': 1521812354,
#   'market_cap_usd': 4796274706.0,
#   'max_supply': 45000000000.0,
#   'name': 'Cardano',
#   'percent_change_1h': -1.85,
#   'percent_change_24h': -6.26,
#   'percent_change_7d': 2.47,
#   'price_btc': 2.217e-05,
#   'price_usd': 0.184991,
#   'rank': 7,
#   'symbol': 'ADA',
#   'total_supply': 31112483745.0},
#  {'24h_volume_usd': 49400200.0,
#   'available_supply': 18548941024.0,
#   'id': 'stellar',
#   'last_updated': 1521812343,
#   'market_cap_usd': 4229177102.0,
#   'max_supply': None,
#   'name': 'Stellar',
#   'percent_change_1h': -0.85,
#   'percent_change_24h': -3.81,
#   'percent_change_7d': -3.12,
#   'price_btc': 2.733e-05,
#   'price_usd': 0.228001,
#   'rank': 8,
#   'symbol': 'XLM',
#   'total_supply': 103788040162},
#  {'24h_volume_usd': 140868000.0,
#   'available_supply': 65000000.0,
#   'id': 'neo',
#   'last_updated': 1521812348,
#   'market_cap_usd': 4158238500.0,
#   'max_supply': 100000000.0,
#   'name': 'NEO',
#   'percent_change_1h': -1.73,
#   'percent_change_24h': -7.58,
#   'percent_change_7d': -7.2,
#   'price_btc': 0.00766831,
#   'price_usd': 63.9729,
#   'rank': 9,
#   'symbol': 'NEO',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 32819800.0,
#   'available_supply': 2779530283.0,
#   'id': 'iota',
#   'last_updated': 1521812350,
#   'market_cap_usd': 3510129818.0,
#   'max_supply': 2779530283.0,
#   'name': 'IOTA',
#   'percent_change_1h': -1.96,
#   'percent_change_24h': -2.97,
#   'percent_change_7d': 13.51,
#   'price_btc': 0.00015138,
#   'price_usd': 1.26285,
#   'rank': 10,
#   'symbol': 'MIOTA',
#   'total_supply': 2779530283.0},
#  {'24h_volume_usd': 33354900.0,
#   'available_supply': 15855557.0,
#   'id': 'monero',
#   'last_updated': 1521812342,
#   'market_cap_usd': 3169161231.0,
#   'max_supply': None,
#   'name': 'Monero',
#   'percent_change_1h': -0.92,
#   'percent_change_24h': -5.11,
#   'percent_change_7d': -5.72,
#   'price_btc': 0.0239589,
#   'price_usd': 199.877,
#   'rank': 11,
#   'symbol': 'XMR',
#   'total_supply': 15855557.0},
#  {'24h_volume_usd': 94650400.0,
#   'available_supply': 7963078.0,
#   'id': 'dash',
#   'last_updated': 1521812341,
#   'market_cap_usd': 3135900017.0,
#   'max_supply': 18900000.0,
#   'name': 'Dash',
#   'percent_change_1h': -1.53,
#   'percent_change_24h': -4.68,
#   'percent_change_7d': -6.1,
#   'price_btc': 0.0472046,
#   'price_usd': 393.805,
#   'rank': 12,
#   'symbol': 'DASH',
#   'total_supply': 7963078.0},
#  {'24h_volume_usd': 49951600.0,
#   'available_supply': 8999999999.0,
#   'id': 'nem',
#   'last_updated': 1521812344,
#   'market_cap_usd': 2425923000.0,
#   'max_supply': None,
#   'name': 'NEM',
#   'percent_change_1h': -2.59,
#   'percent_change_24h': -7.0,
#   'percent_change_7d': -22.02,
#   'price_btc': 3.231e-05,
#   'price_usd': 0.269547,
#   'rank': 13,
#   'symbol': 'XEM',
#   'total_supply': 8999999999.0},
#  {'24h_volume_usd': 198109000.0,
#   'available_supply': 65748192475.0,
#   'id': 'tron',
#   'last_updated': 1521812353,
#   'market_cap_usd': 2346723935.0,
#   'max_supply': None,
#   'name': 'TRON',
#   'percent_change_1h': -1.72,
#   'percent_change_24h': -0.69,
#   'percent_change_7d': 18.62,
#   'price_btc': 4.28e-06,
#   'price_usd': 0.0356926,
#   'rank': 14,
#   'symbol': 'TRX',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 2062030000.0,
#   'available_supply': 2287140814.0,
#   'id': 'tether',
#   'last_updated': 1521812345,
#   'market_cap_usd': 2289999740.0,
#   'max_supply': None,
#   'name': 'Tether',
#   'percent_change_1h': -0.2,
#   'percent_change_24h': 0.03,
#   'percent_change_7d': 0.13,
#   'price_btc': 0.00012002,
#   'price_usd': 1.00125,
#   'rank': 15,
#   'symbol': 'USDT',
#   'total_supply': 2580109970.0},
#  {'24h_volume_usd': 213304000.0,
#   'available_supply': 100701239.0,
#   'id': 'ethereum-classic',
#   'last_updated': 1521812347,
#   'market_cap_usd': 1835874218.0,
#   'max_supply': None,
#   'name': 'Ethereum Classic',
#   'percent_change_1h': -0.72,
#   'percent_change_24h': -4.45,
#   'percent_change_7d': 0.77,
#   'price_btc': 0.00218531,
#   'price_usd': 18.2309,
#   'rank': 16,
#   'symbol': 'ETC',
#   'total_supply': 100701239.0},
#  {'24h_volume_usd': 56041100.0,
#   'available_supply': 517784185.0,
#   'id': 'vechain',
#   'last_updated': 1521812353,
#   'market_cap_usd': 1683264606.0,
#   'max_supply': None,
#   'name': 'VeChain',
#   'percent_change_1h': -1.49,
#   'percent_change_24h': -6.7,
#   'percent_change_7d': -17.29,
#   'price_btc': 0.00038968,
#   'price_usd': 3.2509,
#   'rank': 17,
#   'symbol': 'VEN',
#   'total_supply': 873378637.0},
#  {'24h_volume_usd': 224290000.0,
#   'available_supply': 88469552.0,
#   'id': 'qtum',
#   'last_updated': 1521812350,
#   'market_cap_usd': 1585993659.0,
#   'max_supply': None,
#   'name': 'Qtum',
#   'percent_change_1h': -1.32,
#   'percent_change_24h': -3.38,
#   'percent_change_7d': 17.56,
#   'price_btc': 0.00214888,
#   'price_usd': 17.927,
#   'rank': 18,
#   'symbol': 'QTUM',
#   'total_supply': 100469552.0},
#  {'24h_volume_usd': 160879000.0,
#   'available_supply': 387042512.0,
#   'id': 'icon',
#   'last_updated': 1521812355,
#   'market_cap_usd': 1483324946.0,
#   'max_supply': None,
#   'name': 'ICON',
#   'percent_change_1h': -3.55,
#   'percent_change_24h': 9.79,
#   'percent_change_7d': 67.22,
#   'price_btc': 0.00045939,
#   'price_usd': 3.83246,
#   'rank': 19,
#   'symbol': 'ICX',
#   'total_supply': 400230000.0},
#  {'24h_volume_usd': 22614600.0,
#   'available_supply': 103118128.0,
#   'id': 'lisk',
#   'last_updated': 1521812347,
#   'market_cap_usd': 1195035980.0,
#   'max_supply': None,
#   'name': 'Lisk',
#   'percent_change_1h': -0.63,
#   'percent_change_24h': -6.01,
#   'percent_change_7d': -11.83,
#   'price_btc': 0.00138915,
#   'price_usd': 11.589,
#   'rank': 20,
#   'symbol': 'LSK',
#   'total_supply': 119334756.0},
#  {'24h_volume_usd': 28602500.0,
#   'available_supply': 102042552.0,
#   'id': 'omisego',
#   'last_updated': 1521812351,
#   'market_cap_usd': 1085549074.0,
#   'max_supply': None,
#   'name': 'OmiseGO',
#   'percent_change_1h': -1.95,
#   'percent_change_24h': -5.09,
#   'percent_change_7d': -6.6,
#   'price_btc': 0.00127518,
#   'price_usd': 10.6382,
#   'rank': 21,
#   'symbol': 'OMG',
#   'total_supply': 140245398.0},
#  {'24h_volume_usd': 40471400.0,
#   'available_supply': 133248289.0,
#   'id': 'nano',
#   'last_updated': 1521812349,
#   'market_cap_usd': 992558511.0,
#   'max_supply': 133248290.0,
#   'name': 'Nano',
#   'percent_change_1h': -1.74,
#   'percent_change_24h': -7.42,
#   'percent_change_7d': -17.25,
#   'price_btc': 0.00089289,
#   'price_usd': 7.44894,
#   'rank': 22,
#   'symbol': 'NANO',
#   'total_supply': 133248289.0},
#  {'24h_volume_usd': 23099500.0,
#   'available_supply': 16897836.0,
#   'id': 'bitcoin-gold',
#   'last_updated': 1521812355,
#   'market_cap_usd': 985929593.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Gold',
#   'percent_change_1h': -1.73,
#   'percent_change_24h': -4.48,
#   'percent_change_7d': -10.43,
#   'price_btc': 0.00699389,
#   'price_usd': 58.3465,
#   'rank': 23,
#   'symbol': 'BTG',
#   'total_supply': 16997836.0},
#  {'24h_volume_usd': 78910700.0,
#   'available_supply': 99014000.0,
#   'id': 'binance-coin',
#   'last_updated': 1521812352,
#   'market_cap_usd': 985462579.0,
#   'max_supply': None,
#   'name': 'Binance Coin',
#   'percent_change_1h': -0.3,
#   'percent_change_24h': 0.52,
#   'percent_change_7d': 9.55,
#   'price_btc': 0.00119302,
#   'price_usd': 9.95276,
#   'rank': 24,
#   'symbol': 'BNB',
#   'total_supply': 197192382.0},
#  {'24h_volume_usd': 43811600.0,
#   'available_supply': 3542056.0,
#   'id': 'zcash',
#   'last_updated': 1521812348,
#   'market_cap_usd': 825423078.0,
#   'max_supply': None,
#   'name': 'Zcash',
#   'percent_change_1h': -0.48,
#   'percent_change_24h': -5.1,
#   'percent_change_7d': -3.27,
#   'price_btc': 0.0279334,
#   'price_usd': 233.035,
#   'rank': 25,
#   'symbol': 'ZEC',
#   'total_supply': 3542056.0},
#  {'24h_volume_usd': 25434500.0,
#   'available_supply': 2000000.0,
#   'id': 'digixdao',
#   'last_updated': 1521812346,
#   'market_cap_usd': 689544000.0,
#   'max_supply': None,
#   'name': 'DigixDAO',
#   'percent_change_1h': -1.23,
#   'percent_change_24h': -5.59,
#   'percent_change_7d': -15.25,
#   'price_btc': 0.0413272,
#   'price_usd': 344.772,
#   'rank': 26,
#   'symbol': 'DGD',
#   'total_supply': 2000000.0},
#  {'24h_volume_usd': 67190900.0,
#   'available_supply': 14744730405.0,
#   'id': 'verge',
#   'last_updated': 1521812344,
#   'market_cap_usd': 516120120.0,
#   'max_supply': 16555000000.0,
#   'name': 'Verge',
#   'percent_change_1h': -2.42,
#   'percent_change_24h': 8.8,
#   'percent_change_7d': 8.31,
#   'price_btc': 4.2e-06,
#   'price_usd': 0.0350037,
#   'rank': 27,
#   'symbol': 'XVG',
#   'total_supply': 14744730405.0},
#  {'24h_volume_usd': 1545840.0,
#   'available_supply': 37004027.0,
#   'id': 'populous',
#   'last_updated': 1521812351,
#   'market_cap_usd': 511943311.0,
#   'max_supply': 53252246.0,
#   'name': 'Populous',
#   'percent_change_1h': -3.77,
#   'percent_change_24h': -7.07,
#   'percent_change_7d': -14.97,
#   'price_btc': 0.00165835,
#   'price_usd': 13.8348,
#   'rank': 28,
#   'symbol': 'PPT',
#   'total_supply': 53252246.0},
#  {'24h_volume_usd': 2192540.0,
#   'available_supply': 254035175.0,
#   'id': 'steem',
#   'last_updated': 1521812346,
#   'market_cap_usd': 483759185.0,
#   'max_supply': None,
#   'name': 'Steem',
#   'percent_change_1h': -3.22,
#   'percent_change_24h': -8.44,
#   'percent_change_7d': -7.67,
#   'price_btc': 0.00022827,
#   'price_usd': 1.9043,
#   'rank': 29,
#   'symbol': 'STEEM',
#   'total_supply': 271009269.0},
#  {'24h_volume_usd': 7988510.0,
#   'available_supply': 98787999.0,
#   'id': 'stratis',
#   'last_updated': 1521812347,
#   'market_cap_usd': 483242244.0,
#   'max_supply': None,
#   'name': 'Stratis',
#   'percent_change_1h': -1.73,
#   'percent_change_24h': -2.79,
#   'percent_change_7d': 5.07,
#   'price_btc': 0.00058636,
#   'price_usd': 4.89171,
#   'rank': 30,
#   'symbol': 'STRAT',
#   'total_supply': 98787999.0},
#  {'24h_volume_usd': 4244110.0,
#   'available_supply': 183798050773,
#   'id': 'bytecoin-bcn',
#   'last_updated': 1521812343,
#   'market_cap_usd': 467365359.0,
#   'max_supply': 184470000000,
#   'name': 'Bytecoin',
#   'percent_change_1h': -1.54,
#   'percent_change_24h': -3.3,
#   'percent_change_7d': -5.0,
#   'price_btc': 3e-07,
#   'price_usd': 0.00254282,
#   'rank': 31,
#   'symbol': 'BCN',
#   'total_supply': 183798050773},
#  {'24h_volume_usd': 19233700.0,
#   'available_supply': 100000000.0,
#   'id': 'waves',
#   'last_updated': 1521812347,
#   'market_cap_usd': 456531000.0,
#   'max_supply': None,
#   'name': 'Waves',
#   'percent_change_1h': -1.77,
#   'percent_change_24h': -3.9,
#   'percent_change_7d': -9.42,
#   'price_btc': 0.00054723,
#   'price_usd': 4.56531,
#   'rank': 32,
#   'symbol': 'WAVES',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 111901.0,
#   'available_supply': 618228.0,
#   'id': 'maker',
#   'last_updated': 1521812349,
#   'market_cap_usd': 413104742.0,
#   'max_supply': None,
#   'name': 'Maker',
#   'percent_change_1h': -1.8,
#   'percent_change_24h': -3.47,
#   'percent_change_7d': -7.79,
#   'price_btc': 0.0800969,
#   'price_usd': 668.208,
#   'rank': 33,
#   'symbol': 'MKR',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 6154430.0,
#   'available_supply': 2611640000.0,
#   'id': 'bitshares',
#   'last_updated': 1521812343,
#   'market_cap_usd': 407674392.0,
#   'max_supply': 3600570502.0,
#   'name': 'BitShares',
#   'percent_change_1h': -2.07,
#   'percent_change_24h': -0.86,
#   'percent_change_7d': 2.78,
#   'price_btc': 1.871e-05,
#   'price_usd': 0.156099,
#   'rank': 34,
#   'symbol': 'BTS',
#   'total_supply': 2611640000.0},
#  {'24h_volume_usd': 3840680.0,
#   'available_supply': 33303528174.0,
#   'id': 'siacoin',
#   'last_updated': 1521812345,
#   'market_cap_usd': 403359012.0,
#   'max_supply': None,
#   'name': 'Siacoin',
#   'percent_change_1h': -1.83,
#   'percent_change_24h': -4.0,
#   'percent_change_7d': 3.16,
#   'price_btc': 1.45e-06,
#   'price_usd': 0.0121116,
#   'rank': 35,
#   'symbol': 'SC',
#   'total_supply': 33303528174.0},
#  {'24h_volume_usd': 537523.0,
#   'available_supply': 359478523.0,
#   'id': 'rchain',
#   'last_updated': 1521812354,
#   'market_cap_usd': 384081233.0,
#   'max_supply': 1000000000.0,
#   'name': 'RChain',
#   'percent_change_1h': -1.04,
#   'percent_change_24h': -6.12,
#   'percent_change_7d': -7.65,
#   'price_btc': 0.00012807,
#   'price_usd': 1.06844,
#   'rank': 36,
#   'symbol': 'RHOC',
#   'total_supply': 870663574.0},
#  {'24h_volume_usd': 5621580.0,
#   'available_supply': 113711691262,
#   'id': 'dogecoin',
#   'last_updated': 1521812341,
#   'market_cap_usd': 383139035.0,
#   'max_supply': None,
#   'name': 'Dogecoin',
#   'percent_change_1h': -0.98,
#   'percent_change_24h': -4.5,
#   'percent_change_7d': -5.64,
#   'price_btc': 4e-07,
#   'price_usd': 0.00336939,
#   'rank': 37,
#   'symbol': 'DOGE',
#   'total_supply': 113711691262},
#  {'24h_volume_usd': 2595900.0,
#   'available_supply': 233020472.0,
#   'id': 'aeternity',
#   'last_updated': 1521812350,
#   'market_cap_usd': 370928978.0,
#   'max_supply': None,
#   'name': 'Aeternity',
#   'percent_change_1h': -2.02,
#   'percent_change_24h': -1.52,
#   'percent_change_7d': -1.55,
#   'price_btc': 0.00019081,
#   'price_usd': 1.59183,
#   'rank': 38,
#   'symbol': 'AE',
#   'total_supply': 273685830.0},
#  {'24h_volume_usd': 1936770.0,
#   'available_supply': 11000000.0,
#   'id': 'augur',
#   'last_updated': 1521812346,
#   'market_cap_usd': 363830500.0,
#   'max_supply': None,
#   'name': 'Augur',
#   'percent_change_1h': -1.29,
#   'percent_change_24h': -5.12,
#   'percent_change_7d': -0.96,
#   'price_btc': 0.0039647,
#   'price_usd': 33.0755,
#   'rank': 39,
#   'symbol': 'REP',
#   'total_supply': 11000000.0},
#  {'24h_volume_usd': 22412900.0,
#   'available_supply': 3470483788.0,
#   'id': 'status',
#   'last_updated': 1521812351,
#   'market_cap_usd': 351709239.0,
#   'max_supply': None,
#   'name': 'Status',
#   'percent_change_1h': -2.02,
#   'percent_change_24h': -7.55,
#   'percent_change_7d': -5.78,
#   'price_btc': 1.215e-05,
#   'price_usd': 0.101343,
#   'rank': 40,
#   'symbol': 'SNT',
#   'total_supply': 6804870174.0},
#  {'24h_volume_usd': 13679000.0,
#   'available_supply': 987000000.0,
#   'id': 'bytom',
#   'last_updated': 1521812352,
#   'market_cap_usd': 349591452.0,
#   'max_supply': None,
#   'name': 'Bytom',
#   'percent_change_1h': -0.7,
#   'percent_change_24h': 3.24,
#   'percent_change_7d': -1.06,
#   'price_btc': 4.246e-05,
#   'price_usd': 0.354196,
#   'rank': 41,
#   'symbol': 'BTM',
#   'total_supply': 1407000000.0},
#  {'24h_volume_usd': 411101.0,
#   'available_supply': 6989014.0,
#   'id': 'decred',
#   'last_updated': 1521812346,
#   'market_cap_usd': 344695360.0,
#   'max_supply': 21000000.0,
#   'name': 'Decred',
#   'percent_change_1h': -1.21,
#   'percent_change_24h': -1.9,
#   'percent_change_7d': -10.54,
#   'price_btc': 0.00591185,
#   'price_usd': 49.3196,
#   'rank': 42,
#   'symbol': 'DCR',
#   'total_supply': 7409014.0},
#  {'24h_volume_usd': 3286940.0,
#   'available_supply': 24898178.0,
#   'id': 'waltonchain',
#   'last_updated': 1521812353,
#   'market_cap_usd': 304557003.0,
#   'max_supply': 100000000.0,
#   'name': 'Waltonchain',
#   'percent_change_1h': -1.85,
#   'percent_change_24h': -4.45,
#   'percent_change_7d': -8.77,
#   'price_btc': 0.00146624,
#   'price_usd': 12.2321,
#   'rank': 43,
#   'symbol': 'WTC',
#   'total_supply': 70000000.0},
#  {'24h_volume_usd': 11751700.0,
#   'available_supply': 115319871.0,
#   'id': 'aion',
#   'last_updated': 1521812355,
#   'market_cap_usd': 304540175.0,
#   'max_supply': None,
#   'name': 'Aion',
#   'percent_change_1h': -2.58,
#   'percent_change_24h': -11.15,
#   'percent_change_7d': -4.99,
#   'price_btc': 0.00031655,
#   'price_usd': 2.64083,
#   'rank': 44,
#   'symbol': 'AION',
#   'total_supply': 465934587.0},
#  {'24h_volume_usd': 23463300.0,
#   'available_supply': 241236451.0,
#   'id': 'ontology',
#   'last_updated': 1521812361,
#   'market_cap_usd': 303612960.0,
#   'max_supply': None,
#   'name': 'Ontology',
#   'percent_change_1h': -1.87,
#   'percent_change_24h': -1.48,
#   'percent_change_7d': -28.07,
#   'price_btc': 0.00015086,
#   'price_usd': 1.25857,
#   'rank': 45,
#   'symbol': 'ONT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 974867.0,
#   'available_supply': 104030534.0,
#   'id': 'komodo',
#   'last_updated': 1521812349,
#   'market_cap_usd': 293117473.0,
#   'max_supply': None,
#   'name': 'Komodo',
#   'percent_change_1h': -1.52,
#   'percent_change_24h': -3.61,
#   'percent_change_7d': -5.13,
#   'price_btc': 0.00033774,
#   'price_usd': 2.81761,
#   'rank': 46,
#   'symbol': 'KMD',
#   'total_supply': 104030534.0},
#  {'24h_volume_usd': 13800700.0,
#   'available_supply': 6605326966.0,
#   'id': 'zilliqa',
#   'last_updated': 1521812359,
#   'market_cap_usd': 285860056.0,
#   'max_supply': None,
#   'name': 'Zilliqa',
#   'percent_change_1h': -3.64,
#   'percent_change_24h': -5.48,
#   'percent_change_7d': -0.94,
#   'price_btc': 5.19e-06,
#   'price_usd': 0.0432772,
#   'rank': 47,
#   'symbol': 'ZIL',
#   'total_supply': 12600000000.0},
#  {'24h_volume_usd': 24035300.0,
#   'available_supply': 42772874.0,
#   'id': 'hshare',
#   'last_updated': 1521812352,
#   'market_cap_usd': 281945525.0,
#   'max_supply': 84000000.0,
#   'name': 'Hshare',
#   'percent_change_1h': -0.16,
#   'percent_change_24h': -0.98,
#   'percent_change_7d': 18.32,
#   'price_btc': 0.00079013,
#   'price_usd': 6.59169,
#   'rank': 48,
#   'symbol': 'HSR',
#   'total_supply': 42772874.0},
#  {'24h_volume_usd': 2341830.0,
#   'available_supply': 998999495.0,
#   'id': 'ardor',
#   'last_updated': 1521812347,
#   'market_cap_usd': 277251331.0,
#   'max_supply': 998999495.0,
#   'name': 'Ardor',
#   'percent_change_1h': -2.63,
#   'percent_change_24h': -7.43,
#   'percent_change_7d': -9.6,
#   'price_btc': 3.327e-05,
#   'price_usd': 0.277529,
#   'rank': 49,
#   'symbol': 'ARDR',
#   'total_supply': 998999495.0},
#  {'24h_volume_usd': 683971.0,
#   'available_supply': 2036645.0,
#   'id': 'veritaseum',
#   'last_updated': 1521812351,
#   'market_cap_usd': 276629404.0,
#   'max_supply': None,
#   'name': 'Veritaseum',
#   'percent_change_1h': 1.5,
#   'percent_change_24h': 28.62,
#   'percent_change_7d': 9.85,
#   'price_btc': 0.0162812,
#   'price_usd': 135.826,
#   'rank': 50,
#   'symbol': 'VERI',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 6393620.0,
#   'available_supply': 519515849.0,
#   'id': '0x',
#   'last_updated': 1521812352,
#   'market_cap_usd': 273021684.0,
#   'max_supply': None,
#   'name': '0x',
#   'percent_change_1h': -3.66,
#   'percent_change_24h': -12.28,
#   'percent_change_7d': 5.95,
#   'price_btc': 6.299e-05,
#   'price_usd': 0.525531,
#   'rank': 51,
#   'symbol': 'ZRX',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 2186680.0,
#   'available_supply': 101421240.0,
#   'id': 'ark',
#   'last_updated': 1521812349,
#   'market_cap_usd': 270632437.0,
#   'max_supply': None,
#   'name': 'Ark',
#   'percent_change_1h': -1.28,
#   'percent_change_24h': -0.25,
#   'percent_change_7d': -7.57,
#   'price_btc': 0.00031986,
#   'price_usd': 2.6684,
#   'rank': 52,
#   'symbol': 'ARK',
#   'total_supply': 132671240.0},
#  {'24h_volume_usd': 199537.0,
#   'available_supply': 45177622.0,
#   'id': 'cryptonex',
#   'last_updated': 1521812354,
#   'market_cap_usd': 259927190.0,
#   'max_supply': 210000000.0,
#   'name': 'Cryptonex',
#   'percent_change_1h': 0.13,
#   'percent_change_24h': -1.3,
#   'percent_change_7d': 0.23,
#   'price_btc': 0.00068966,
#   'price_usd': 5.75345,
#   'rank': 53,
#   'symbol': 'CNX',
#   'total_supply': 106615248.0},
#  {'24h_volume_usd': 11202700.0,
#   'available_supply': 572074043.0,
#   'id': 'loopring',
#   'last_updated': 1521812353,
#   'market_cap_usd': 244976979.0,
#   'max_supply': None,
#   'name': 'Loopring',
#   'percent_change_1h': -0.3,
#   'percent_change_24h': 5.42,
#   'percent_change_7d': 34.03,
#   'price_btc': 5.133e-05,
#   'price_usd': 0.428226,
#   'rank': 54,
#   'symbol': 'LRC',
#   'total_supply': 1374956262.0},
#  {'24h_volume_usd': 464244.0,
#   'available_supply': 91043076.0,
#   'id': 'kucoin-shares',
#   'last_updated': 1521812355,
#   'market_cap_usd': 238223313.0,
#   'max_supply': None,
#   'name': 'KuCoin Shares',
#   'percent_change_1h': -1.3,
#   'percent_change_24h': -9.01,
#   'percent_change_7d': 8.54,
#   'price_btc': 0.00031365,
#   'price_usd': 2.6166,
#   'rank': 55,
#   'symbol': 'KCS',
#   'total_supply': 181043076.0},
#  {'24h_volume_usd': 4685690.0,
#   'available_supply': 350000000.0,
#   'id': 'qash',
#   'last_updated': 1521812356,
#   'market_cap_usd': 221120900.0,
#   'max_supply': None,
#   'name': 'QASH',
#   'percent_change_1h': 0.02,
#   'percent_change_24h': 0.73,
#   'percent_change_7d': 11.42,
#   'price_btc': 7.573e-05,
#   'price_usd': 0.631774,
#   'rank': 56,
#   'symbol': 'QASH',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 1271550.0,
#   'available_supply': 10012861251.0,
#   'id': 'digibyte',
#   'last_updated': 1521812341,
#   'market_cap_usd': 219391803.0,
#   'max_supply': 21000000000.0,
#   'name': 'DigiByte',
#   'percent_change_1h': -1.28,
#   'percent_change_24h': -5.35,
#   'percent_change_7d': -0.9,
#   'price_btc': 2.63e-06,
#   'price_usd': 0.021911,
#   'rank': 57,
#   'symbol': 'DGB',
#   'total_supply': 10012861251.0},
#  {'24h_volume_usd': 1465720.0,
#   'available_supply': 58263825.0,
#   'id': 'monacoin',
#   'last_updated': 1521812342,
#   'market_cap_usd': 214994096.0,
#   'max_supply': None,
#   'name': 'MonaCoin',
#   'percent_change_1h': -0.74,
#   'percent_change_24h': -2.66,
#   'percent_change_7d': -4.08,
#   'price_btc': 0.00044231,
#   'price_usd': 3.69001,
#   'rank': 58,
#   'symbol': 'MONA',
#   'total_supply': 58263825.0},
#  {'24h_volume_usd': 1048070.0,
#   'available_supply': 55831711.0,
#   'id': 'pivx',
#   'last_updated': 1521812345,
#   'market_cap_usd': 206302637.0,
#   'max_supply': None,
#   'name': 'PIVX',
#   'percent_change_1h': -1.76,
#   'percent_change_24h': -5.74,
#   'percent_change_7d': -6.46,
#   'price_btc': 0.00044292,
#   'price_usd': 3.69508,
#   'rank': 59,
#   'symbol': 'PIVX',
#   'total_supply': 55831711.0},
#  {'24h_volume_usd': 4619950.0,
#   'available_supply': 9954285.0,
#   'id': 'gas',
#   'last_updated': 1521812351,
#   'market_cap_usd': 205335009.0,
#   'max_supply': 100000000.0,
#   'name': 'Gas',
#   'percent_change_1h': -1.77,
#   'percent_change_24h': -8.24,
#   'percent_change_7d': -0.05,
#   'price_btc': 0.00247261,
#   'price_usd': 20.6278,
#   'rank': 60,
#   'symbol': 'GAS',
#   'total_supply': 16396172.0},
#  {'24h_volume_usd': 689472.0,
#   'available_supply': 531788529.0,
#   'id': 'syscoin',
#   'last_updated': 1521812343,
#   'market_cap_usd': 203860601.0,
#   'max_supply': 888000000.0,
#   'name': 'Syscoin',
#   'percent_change_1h': -2.83,
#   'percent_change_24h': -6.18,
#   'percent_change_7d': 2.26,
#   'price_btc': 4.595e-05,
#   'price_usd': 0.383349,
#   'rank': 61,
#   'symbol': 'SYS',
#   'total_supply': 531788529.0},
#  {'24h_volume_usd': 8982980.0,
#   'available_supply': 35500000.0,
#   'id': 'nebulas-token',
#   'last_updated': 1521812352,
#   'market_cap_usd': 203810825.0,
#   'max_supply': 100000000.0,
#   'name': 'Nebulas',
#   'percent_change_1h': -1.97,
#   'percent_change_24h': 1.74,
#   'percent_change_7d': 11.23,
#   'price_btc': 0.00068818,
#   'price_usd': 5.74115,
#   'rank': 62,
#   'symbol': 'NAS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 3940470.0,
#   'available_supply': 1000000000.0,
#   'id': 'basic-attention-token',
#   'last_updated': 1521812350,
#   'market_cap_usd': 195623000.0,
#   'max_supply': None,
#   'name': 'Basic Attention Token',
#   'percent_change_1h': -1.99,
#   'percent_change_24h': -1.96,
#   'percent_change_7d': -2.51,
#   'price_btc': 2.345e-05,
#   'price_usd': 0.195623,
#   'rank': 63,
#   'symbol': 'BAT',
#   'total_supply': 1500000000.0},
#  {'24h_volume_usd': 5931460.0,
#   'available_supply': 834262000.0,
#   'id': 'golem-network-tokens',
#   'last_updated': 1521812348,
#   'market_cap_usd': 194837719.0,
#   'max_supply': None,
#   'name': 'Golem',
#   'percent_change_1h': -1.55,
#   'percent_change_24h': -4.97,
#   'percent_change_7d': -6.49,
#   'price_btc': 2.799e-05,
#   'price_usd': 0.233545,
#   'rank': 64,
#   'symbol': 'GNT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 2550570.0,
#   'available_supply': 8745102.0,
#   'id': 'factom',
#   'last_updated': 1521812346,
#   'market_cap_usd': 193099723.0,
#   'max_supply': None,
#   'name': 'Factom',
#   'percent_change_1h': -1.72,
#   'percent_change_24h': -7.31,
#   'percent_change_7d': -6.32,
#   'price_btc': 0.0026468,
#   'price_usd': 22.0809,
#   'rank': 65,
#   'symbol': 'FCT',
#   'total_supply': 8745102.0},
#  {'24h_volume_usd': 1384870.0,
#   'available_supply': 238421940.0,
#   'id': 'dragonchain',
#   'last_updated': 1521812357,
#   'market_cap_usd': 191802106.0,
#   'max_supply': None,
#   'name': 'Dragonchain',
#   'percent_change_1h': 0.36,
#   'percent_change_24h': -5.34,
#   'percent_change_7d': -0.89,
#   'price_btc': 9.643e-05,
#   'price_usd': 0.804465,
#   'rank': 66,
#   'symbol': 'DRGN',
#   'total_supply': 433494437.0},
#  {'24h_volume_usd': 2652960.0,
#   'available_supply': 6505463369.0,
#   'id': 'electroneum',
#   'last_updated': 1521812355,
#   'market_cap_usd': 183815771.0,
#   'max_supply': 21000000000.0,
#   'name': 'Electroneum',
#   'percent_change_1h': -0.94,
#   'percent_change_24h': -3.16,
#   'percent_change_7d': -21.23,
#   'price_btc': 3.39e-06,
#   'price_usd': 0.0282556,
#   'rank': 67,
#   'symbol': 'ETN',
#   'total_supply': 6505463369.0},
#  {'24h_volume_usd': 6214260.0,
#   'available_supply': 75975162.0,
#   'id': 'ethos',
#   'last_updated': 1521812352,
#   'market_cap_usd': 180732755.0,
#   'max_supply': None,
#   'name': 'Ethos',
#   'percent_change_1h': -3.03,
#   'percent_change_24h': -12.32,
#   'percent_change_7d': -10.84,
#   'price_btc': 0.00028515,
#   'price_usd': 2.37884,
#   'rank': 68,
#   'symbol': 'ETHOS',
#   'total_supply': 222295208.0},
#  {'24h_volume_usd': 4058760.0,
#   'available_supply': 184450000.0,
#   'id': 'revain',
#   'last_updated': 1521812355,
#   'market_cap_usd': 175377458.0,
#   'max_supply': 484450000.0,
#   'name': 'Revain',
#   'percent_change_1h': -1.8,
#   'percent_change_24h': -8.01,
#   'percent_change_7d': -11.84,
#   'price_btc': 0.00011397,
#   'price_usd': 0.950813,
#   'rank': 69,
#   'symbol': 'R',
#   'total_supply': 484450000.0},
#  {'24h_volume_usd': 1313190.0,
#   'available_supply': 4605074689.0,
#   'id': 'funfair',
#   'last_updated': 1521812351,
#   'market_cap_usd': 174506542.0,
#   'max_supply': None,
#   'name': 'FunFair',
#   'percent_change_1h': -1.59,
#   'percent_change_24h': -3.23,
#   'percent_change_7d': -1.51,
#   'price_btc': 4.54e-06,
#   'price_usd': 0.0378944,
#   'rank': 70,
#   'symbol': 'FUN',
#   'total_supply': 10999873621.0},
#  {'24h_volume_usd': 852035.0,
#   'available_supply': 4369295.0,
#   'id': 'zcoin',
#   'last_updated': 1521812348,
#   'market_cap_usd': 163012261.0,
#   'max_supply': 21400000.0,
#   'name': 'ZCoin',
#   'percent_change_1h': -1.6,
#   'percent_change_24h': -6.54,
#   'percent_change_7d': 3.65,
#   'price_btc': 0.00447211,
#   'price_usd': 37.3086,
#   'rank': 71,
#   'symbol': 'XZC',
#   'total_supply': 4369295.0},
#  {'24h_volume_usd': 5813880.0,
#   'available_supply': 134132697.0,
#   'id': 'kyber-network',
#   'last_updated': 1521812354,
#   'market_cap_usd': 159726557.0,
#   'max_supply': None,
#   'name': 'Kyber Network',
#   'percent_change_1h': -1.36,
#   'percent_change_24h': -8.25,
#   'percent_change_7d': 5.96,
#   'price_btc': 0.00014274,
#   'price_usd': 1.19081,
#   'rank': 72,
#   'symbol': 'KNC',
#   'total_supply': 215625349.0},
#  {'24h_volume_usd': 24540600.0,
#   'available_supply': 8400000000.0,
#   'id': 'iostoken',
#   'last_updated': 1521812359,
#   'market_cap_usd': 157977960.0,
#   'max_supply': None,
#   'name': 'IOStoken',
#   'percent_change_1h': -2.61,
#   'percent_change_24h': -8.23,
#   'percent_change_7d': 3.23,
#   'price_btc': 2.25e-06,
#   'price_usd': 0.0188069,
#   'rank': 73,
#   'symbol': 'IOST',
#   'total_supply': 21000000000.0},
#  {'24h_volume_usd': 2329820.0,
#   'available_supply': 60000000.0,
#   'id': 'gxchain',
#   'last_updated': 1521812351,
#   'market_cap_usd': 155892600.0,
#   'max_supply': 100000000.0,
#   'name': 'GXChain',
#   'percent_change_1h': 1.38,
#   'percent_change_24h': -13.28,
#   'percent_change_7d': -5.25,
#   'price_btc': 0.00031144,
#   'price_usd': 2.59821,
#   'rank': 74,
#   'symbol': 'GXS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 9742610.0,
#   'available_supply': 55798538.0,
#   'id': 'salt',
#   'last_updated': 1521812354,
#   'market_cap_usd': 153393530.0,
#   'max_supply': None,
#   'name': 'SALT',
#   'percent_change_1h': -2.38,
#   'percent_change_24h': 0.13,
#   'percent_change_7d': 0.59,
#   'price_btc': 0.00032952,
#   'price_usd': 2.74906,
#   'rank': 75,
#   'symbol': 'SALT',
#   'total_supply': 120000000.0},
#  {'24h_volume_usd': 2243530.0,
#   'available_supply': 28797861497.0,
#   'id': 'reddcoin',
#   'last_updated': 1521812341,
#   'market_cap_usd': 146485218.0,
#   'max_supply': None,
#   'name': 'ReddCoin',
#   'percent_change_1h': -1.74,
#   'percent_change_24h': -4.35,
#   'percent_change_7d': -7.01,
#   'price_btc': 6.1e-07,
#   'price_usd': 0.00508667,
#   'rank': 76,
#   'symbol': 'RDD',
#   'total_supply': 28797861497.0},
#  {'24h_volume_usd': 15182700.0,
#   'available_supply': 250000000.0,
#   'id': 'aelf',
#   'last_updated': 1521812357,
#   'market_cap_usd': 146131250.0,
#   'max_supply': 1000000000.0,
#   'name': 'aelf',
#   'percent_change_1h': -2.12,
#   'percent_change_24h': -8.43,
#   'percent_change_7d': -9.66,
#   'price_btc': 7.007e-05,
#   'price_usd': 0.584525,
#   'rank': 77,
#   'symbol': 'ELF',
#   'total_supply': 280000000.0},
#  {'24h_volume_usd': 796996.0,
#   'available_supply': 41513032.0,
#   'id': 'emercoin',
#   'last_updated': 1521812343,
#   'market_cap_usd': 137837381.0,
#   'max_supply': None,
#   'name': 'Emercoin',
#   'percent_change_1h': 2.01,
#   'percent_change_24h': -2.88,
#   'percent_change_7d': -3.38,
#   'price_btc': 0.000398,
#   'price_usd': 3.32034,
#   'rank': 78,
#   'symbol': 'EMC',
#   'total_supply': 41513032.0},
#  {'24h_volume_usd': 14437200.0,
#   'available_supply': 74836171.0,
#   'id': 'enigma-project',
#   'last_updated': 1521812354,
#   'market_cap_usd': 135330738.0,
#   'max_supply': None,
#   'name': 'Enigma',
#   'percent_change_1h': -2.0,
#   'percent_change_24h': 12.93,
#   'percent_change_7d': 24.63,
#   'price_btc': 0.00021677,
#   'price_usd': 1.80836,
#   'rank': 79,
#   'symbol': 'ENG',
#   'total_supply': 150000000.0},
#  {'24h_volume_usd': 9620820.0,
#   'available_supply': 350000000.0,
#   'id': 'chainlink',
#   'last_updated': 1521812354,
#   'market_cap_usd': 134908900.0,
#   'max_supply': None,
#   'name': 'ChainLink',
#   'percent_change_1h': -1.1,
#   'percent_change_24h': -5.21,
#   'percent_change_7d': -10.87,
#   'price_btc': 4.62e-05,
#   'price_usd': 0.385454,
#   'rank': 80,
#   'symbol': 'LINK',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 5563090.0,
#   'available_supply': 662706996.0,
#   'id': 'request-network',
#   'last_updated': 1521812355,
#   'market_cap_usd': 134557354.0,
#   'max_supply': None,
#   'name': 'Request Network',
#   'percent_change_1h': -2.05,
#   'percent_change_24h': -8.87,
#   'percent_change_7d': 12.69,
#   'price_btc': 2.434e-05,
#   'price_usd': 0.203042,
#   'rank': 81,
#   'symbol': 'REQ',
#   'total_supply': 999999999.0},
#  {'24h_volume_usd': 1292910.0,
#   'available_supply': 998999942.0,
#   'id': 'nxt',
#   'last_updated': 1521812341,
#   'market_cap_usd': 132368491.0,
#   'max_supply': 1000000000.0,
#   'name': 'Nxt',
#   'percent_change_1h': -1.1,
#   'percent_change_24h': -4.12,
#   'percent_change_7d': -3.23,
#   'price_btc': 1.588e-05,
#   'price_usd': 0.132501,
#   'rank': 82,
#   'symbol': 'NXT',
#   'total_supply': 998999942.0},
#  {'24h_volume_usd': 1106640.0,
#   'available_supply': 452552412.0,
#   'id': 'maidsafecoin',
#   'last_updated': 1521812342,
#   'market_cap_usd': 129060255.0,
#   'max_supply': None,
#   'name': 'MaidSafeCoin',
#   'percent_change_1h': -2.81,
#   'percent_change_24h': -8.25,
#   'percent_change_7d': -2.22,
#   'price_btc': 3.418e-05,
#   'price_usd': 0.285183,
#   'rank': 83,
#   'symbol': 'MAID',
#   'total_supply': 452552412.0},
#  {'24h_volume_usd': 319005.0,
#   'available_supply': 645222.0,
#   'id': 'byteball',
#   'last_updated': 1521812348,
#   'market_cap_usd': 127680411.0,
#   'max_supply': None,
#   'name': 'Byteball Bytes',
#   'percent_change_1h': -2.75,
#   'percent_change_24h': -9.09,
#   'percent_change_7d': -1.63,
#   'price_btc': 0.0237202,
#   'price_usd': 197.886,
#   'rank': 84,
#   'symbol': 'GBYTE',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 340372.0,
#   'available_supply': 756097560976,
#   'id': 'kin',
#   'last_updated': 1521812353,
#   'market_cap_usd': 125261171.0,
#   'max_supply': None,
#   'name': 'Kin',
#   'percent_change_1h': -1.58,
#   'percent_change_24h': -6.35,
#   'percent_change_7d': -13.03,
#   'price_btc': 2e-08,
#   'price_usd': 0.000165668,
#   'rank': 85,
#   'symbol': 'KIN',
#   'total_supply': 10000000000000},
#  {'24h_volume_usd': 6682910.0,
#   'available_supply': 363932947.0,
#   'id': 'power-ledger',
#   'last_updated': 1521812355,
#   'market_cap_usd': 124293291.0,
#   'max_supply': None,
#   'name': 'Power Ledger',
#   'percent_change_1h': -1.53,
#   'percent_change_24h': -5.06,
#   'percent_change_7d': -12.23,
#   'price_btc': 4.094e-05,
#   'price_usd': 0.341528,
#   'rank': 86,
#   'symbol': 'POWR',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 17104500.0,
#   'available_supply': 4088853037.0,
#   'id': 'storm',
#   'last_updated': 1521812357,
#   'market_cap_usd': 123486224.0,
#   'max_supply': None,
#   'name': 'Storm',
#   'percent_change_1h': 11.67,
#   'percent_change_24h': 17.13,
#   'percent_change_7d': 46.66,
#   'price_btc': 3.62e-06,
#   'price_usd': 0.0302007,
#   'rank': 87,
#   'symbol': 'STORM',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 55051.1,
#   'available_supply': 325226613094,
#   'id': 'dentacoin',
#   'last_updated': 1521812352,
#   'market_cap_usd': 122208778.0,
#   'max_supply': 8000000000000,
#   'name': 'Dentacoin',
#   'percent_change_1h': -0.64,
#   'percent_change_24h': -2.43,
#   'percent_change_7d': -21.76,
#   'price_btc': 5e-08,
#   'price_usd': 0.000375765,
#   'rank': 88,
#   'symbol': 'DCN',
#   'total_supply': 1963173416169},
#  {'24h_volume_usd': 14133700.0,
#   'available_supply': 3983937436.0,
#   'id': 'nucleus-vision',
#   'last_updated': 1521812360,
#   'market_cap_usd': 122091747.0,
#   'max_supply': None,
#   'name': 'Nucleus Vision',
#   'percent_change_1h': -1.53,
#   'percent_change_24h': -6.52,
#   'percent_change_7d': -7.35,
#   'price_btc': 3.67e-06,
#   'price_usd': 0.030646,
#   'rank': 89,
#   'symbol': 'NCASH',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 662910.0,
#   'available_supply': 239999750.0,
#   'id': 'polymath-network',
#   'last_updated': 1521812360,
#   'market_cap_usd': 118551237.0,
#   'max_supply': None,
#   'name': 'Polymath',
#   'percent_change_1h': -0.58,
#   'percent_change_24h': -9.38,
#   'percent_change_7d': -14.59,
#   'price_btc': 5.921e-05,
#   'price_usd': 0.493964,
#   'rank': 90,
#   'symbol': 'POLY',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 242140.0,
#   'available_supply': 8911321.0,
#   'id': 'particl',
#   'last_updated': 1521812352,
#   'market_cap_usd': 117968064.0,
#   'max_supply': None,
#   'name': 'Particl',
#   'percent_change_1h': -3.02,
#   'percent_change_24h': -4.08,
#   'percent_change_7d': -11.89,
#   'price_btc': 0.00158682,
#   'price_usd': 13.238,
#   'rank': 91,
#   'symbol': 'PART',
#   'total_supply': 8911321.0},
#  {'24h_volume_usd': 4580950.0,
#   'available_supply': 104661310.0,
#   'id': 'tenx',
#   'last_updated': 1521812351,
#   'market_cap_usd': 116612585.0,
#   'max_supply': None,
#   'name': 'TenX',
#   'percent_change_1h': -1.18,
#   'percent_change_24h': -1.21,
#   'percent_change_7d': -6.3,
#   'price_btc': 0.00013356,
#   'price_usd': 1.11419,
#   'rank': 92,
#   'symbol': 'PAY',
#   'total_supply': 205218256.0},
#  {'24h_volume_usd': 6241320.0,
#   'available_supply': 40670871.0,
#   'id': 'bancor',
#   'last_updated': 1521812350,
#   'market_cap_usd': 115888801.0,
#   'max_supply': None,
#   'name': 'Bancor',
#   'percent_change_1h': -1.48,
#   'percent_change_24h': -4.17,
#   'percent_change_7d': -13.07,
#   'price_btc': 0.00034156,
#   'price_usd': 2.84943,
#   'rank': 93,
#   'symbol': 'BNT',
#   'total_supply': 74311585.0},
#  {'24h_volume_usd': 11606000.0,
#   'available_supply': 12931058.0,
#   'id': 'neblio',
#   'last_updated': 1521812353,
#   'market_cap_usd': 113319904.0,
#   'max_supply': None,
#   'name': 'Neblio',
#   'percent_change_1h': -1.1,
#   'percent_change_24h': -3.81,
#   'percent_change_7d': -14.64,
#   'price_btc': 0.00105045,
#   'price_usd': 8.76339,
#   'rank': 94,
#   'symbol': 'NEBL',
#   'total_supply': 13685009.0},
#  {'24h_volume_usd': 8065980.0,
#   'available_supply': 133425493.0,
#   'id': 'storj',
#   'last_updated': 1521812351,
#   'market_cap_usd': 110277237.0,
#   'max_supply': None,
#   'name': 'Storj',
#   'percent_change_1h': -1.86,
#   'percent_change_24h': -0.05,
#   'percent_change_7d': 4.16,
#   'price_btc': 9.907e-05,
#   'price_usd': 0.826508,
#   'rank': 95,
#   'symbol': 'STORJ',
#   'total_supply': 424999998.0},
#  {'24h_volume_usd': 1416790.0,
#   'available_supply': 1445976590.0,
#   'id': 'cindicator',
#   'last_updated': 1521812354,
#   'market_cap_usd': 110072654.0,
#   'max_supply': None,
#   'name': 'Cindicator',
#   'percent_change_1h': -1.67,
#   'percent_change_24h': -5.73,
#   'percent_change_7d': 0.95,
#   'price_btc': 9.12e-06,
#   'price_usd': 0.0761234,
#   'rank': 96,
#   'symbol': 'CND',
#   'total_supply': 2000000005.0},
#  {'24h_volume_usd': 974059.0,
#   'available_supply': 56159782.0,
#   'id': 'nexus',
#   'last_updated': 1521812344,
#   'market_cap_usd': 106363257.0,
#   'max_supply': None,
#   'name': 'Nexus',
#   'percent_change_1h': -2.24,
#   'percent_change_24h': -6.81,
#   'percent_change_7d': -14.44,
#   'price_btc': 0.00022702,
#   'price_usd': 1.89394,
#   'rank': 97,
#   'symbol': 'NXS',
#   'total_supply': 56159782.0},
#  {'24h_volume_usd': 238045.0,
#   'available_supply': 1288862.0,
#   'id': 'bitcoindark',
#   'last_updated': 1521812343,
#   'market_cap_usd': 106283571.0,
#   'max_supply': None,
#   'name': 'BitcoinDark',
#   'percent_change_1h': -0.89,
#   'percent_change_24h': 2.34,
#   'percent_change_7d': 8.54,
#   'price_btc': 0.00988469,
#   'price_usd': 82.4631,
#   'rank': 98,
#   'symbol': 'BTCD',
#   'total_supply': 1288862.0},
#  {'24h_volume_usd': 3023460.0,
#   'available_supply': 43460650.0,
#   'id': 'vertcoin',
#   'last_updated': 1521812341,
#   'market_cap_usd': 103651912.0,
#   'max_supply': 84000000.0,
#   'name': 'Vertcoin',
#   'percent_change_1h': -1.4,
#   'percent_change_24h': -4.65,
#   'percent_change_7d': 10.19,
#   'price_btc': 0.00028588,
#   'price_usd': 2.38496,
#   'rank': 99,
#   'symbol': 'VTC',
#   'total_supply': 43460650.0},
#  {'24h_volume_usd': 101498.0,
#   'available_supply': 818726774.0,
#   'id': 'smartcash',
#   'last_updated': 1521812352,
#   'market_cap_usd': 101911015.0,
#   'max_supply': 5000000000.0,
#   'name': 'SmartCash',
#   'percent_change_1h': -1.41,
#   'percent_change_24h': -4.09,
#   'percent_change_7d': -31.39,
#   'price_btc': 1.492e-05,
#   'price_usd': 0.124475,
#   'rank': 100,
#   'symbol': 'SMART',
#   'total_supply': 1419771053.0},
#  {'24h_volume_usd': 9658670.0,
#   'available_supply': 40000000.0,
#   'id': 'nuls',
#   'last_updated': 1521812356,
#   'market_cap_usd': 101311200.0,
#   'max_supply': None,
#   'name': 'Nuls',
#   'percent_change_1h': -1.77,
#   'percent_change_24h': -6.04,
#   'percent_change_7d': 0.17,
#   'price_btc': 0.0003036,
#   'price_usd': 2.53278,
#   'rank': 101,
#   'symbol': 'NULS',
#   'total_supply': 40000000.0},
#  {'24h_volume_usd': 1071160.0,
#   'available_supply': 99735687.0,
#   'id': 'iconomi',
#   'last_updated': 1521812347,
#   'market_cap_usd': 99550079.0,
#   'max_supply': None,
#   'name': 'Iconomi',
#   'percent_change_1h': -1.43,
#   'percent_change_24h': -8.15,
#   'percent_change_7d': -15.24,
#   'price_btc': 0.00011964,
#   'price_usd': 0.998139,
#   'rank': 102,
#   'symbol': 'ICN',
#   'total_supply': 99735687.0},
#  {'24h_volume_usd': 158089.0,
#   'available_supply': 3511529.0,
#   'id': 'minexcoin',
#   'last_updated': 1521812356,
#   'market_cap_usd': 98789854.0,
#   'max_supply': 19000000.0,
#   'name': 'MinexCoin',
#   'percent_change_1h': -1.14,
#   'percent_change_24h': -10.74,
#   'percent_change_7d': 5.45,
#   'price_btc': 0.00337225,
#   'price_usd': 28.133,
#   'rank': 103,
#   'symbol': 'MNX',
#   'total_supply': 5787373.0},
#  {'24h_volume_usd': 277142.0,
#   'available_supply': 5066704.0,
#   'id': 'blocknet',
#   'last_updated': 1521812344,
#   'market_cap_usd': 98417172.0,
#   'max_supply': None,
#   'name': 'Blocknet',
#   'percent_change_1h': 0.15,
#   'percent_change_24h': -11.8,
#   'percent_change_7d': -7.66,
#   'price_btc': 0.00232836,
#   'price_usd': 19.4243,
#   'rank': 104,
#   'symbol': 'BLOCK',
#   'total_supply': 5066704.0},
#  {'24h_volume_usd': 1243200.0,
#   'available_supply': 10614760961.0,
#   'id': 'dent',
#   'last_updated': 1521812352,
#   'market_cap_usd': 95207931.0,
#   'max_supply': None,
#   'name': 'Dent',
#   'percent_change_1h': -0.98,
#   'percent_change_24h': -8.64,
#   'percent_change_7d': -20.38,
#   'price_btc': 1.08e-06,
#   'price_usd': 0.00896939,
#   'rank': 105,
#   'symbol': 'DENT',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 4940480.0,
#   'available_supply': 464031018.0,
#   'id': 'achain',
#   'last_updated': 1521812353,
#   'market_cap_usd': 93957001.0,
#   'max_supply': 1000000000.0,
#   'name': 'Achain',
#   'percent_change_1h': -1.88,
#   'percent_change_24h': -3.63,
#   'percent_change_7d': 2.13,
#   'price_btc': 2.427e-05,
#   'price_usd': 0.20248,
#   'rank': 106,
#   'symbol': 'ACT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 881344.0,
#   'available_supply': 5961115777.0,
#   'id': 'thekey',
#   'last_updated': 1521812360,
#   'market_cap_usd': 93774908.0,
#   'max_supply': None,
#   'name': 'THEKEY',
#   'percent_change_1h': -1.53,
#   'percent_change_24h': -0.95,
#   'percent_change_7d': 22.26,
#   'price_btc': 1.89e-06,
#   'price_usd': 0.0157311,
#   'rank': 107,
#   'symbol': 'TKY',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 581048.0,
#   'available_supply': 26341131.0,
#   'id': 'aragon',
#   'last_updated': 1521812350,
#   'market_cap_usd': 93684076.0,
#   'max_supply': None,
#   'name': 'Aragon',
#   'percent_change_1h': -1.13,
#   'percent_change_24h': -11.35,
#   'percent_change_7d': 9.22,
#   'price_btc': 0.00042632,
#   'price_usd': 3.55657,
#   'rank': 108,
#   'symbol': 'ANT',
#   'total_supply': 39609524.0},
#  {'24h_volume_usd': 52048.0,
#   'available_supply': 227384800.0,
#   'id': 'pillar',
#   'last_updated': 1521812352,
#   'market_cap_usd': 93668212.0,
#   'max_supply': None,
#   'name': 'Pillar',
#   'percent_change_1h': -0.67,
#   'percent_change_24h': -2.09,
#   'percent_change_7d': -16.98,
#   'price_btc': 4.938e-05,
#   'price_usd': 0.411937,
#   'rank': 109,
#   'symbol': 'PLR',
#   'total_supply': 800000000.0},
#  {'24h_volume_usd': 2320380.0,
#   'available_supply': 12636048.0,
#   'id': 'bitcore',
#   'last_updated': 1521812350,
#   'market_cap_usd': 91624490.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcore',
#   'percent_change_1h': -1.46,
#   'percent_change_24h': -2.14,
#   'percent_change_7d': -19.32,
#   'price_btc': 0.00086917,
#   'price_usd': 7.25104,
#   'rank': 110,
#   'symbol': 'BTX',
#   'total_supply': 16869269.0},
#  {'24h_volume_usd': 1189080.0,
#   'available_supply': 86999785.0,
#   'id': 'rlc',
#   'last_updated': 1521812349,
#   'market_cap_usd': 90977415.0,
#   'max_supply': None,
#   'name': 'iExec RLC',
#   'percent_change_1h': -2.42,
#   'percent_change_24h': -1.04,
#   'percent_change_7d': -2.63,
#   'price_btc': 0.00012535,
#   'price_usd': 1.04572,
#   'rank': 111,
#   'symbol': 'RLC',
#   'total_supply': 86999785.0},
#  {'24h_volume_usd': 425965.0,
#   'available_supply': 64355352.0,
#   'id': 'gamecredits',
#   'last_updated': 1521812343,
#   'market_cap_usd': 89833636.0,
#   'max_supply': 84000000.0,
#   'name': 'GameCredits',
#   'percent_change_1h': -2.38,
#   'percent_change_24h': -5.01,
#   'percent_change_7d': 8.08,
#   'price_btc': 0.00016732,
#   'price_usd': 1.3959,
#   'rank': 112,
#   'symbol': 'GAME',
#   'total_supply': 64355352.0},
#  {'24h_volume_usd': 10679500.0,
#   'available_supply': 22342464.0,
#   'id': 'metal',
#   'last_updated': 1521812351,
#   'market_cap_usd': 89710132.0,
#   'max_supply': None,
#   'name': 'Metal',
#   'percent_change_1h': -1.79,
#   'percent_change_24h': -10.22,
#   'percent_change_7d': 8.42,
#   'price_btc': 0.0004813,
#   'price_usd': 4.01523,
#   'rank': 113,
#   'symbol': 'MTL',
#   'total_supply': 66588888.0},
#  {'24h_volume_usd': 6961990.0,
#   'available_supply': 229258029.0,
#   'id': 'sirin-labs-token',
#   'last_updated': 1521812358,
#   'market_cap_usd': 89455337.0,
#   'max_supply': None,
#   'name': 'SIRIN LABS Token',
#   'percent_change_1h': -0.57,
#   'percent_change_24h': -3.98,
#   'percent_change_7d': -26.86,
#   'price_btc': 4.677e-05,
#   'price_usd': 0.390195,
#   'rank': 114,
#   'symbol': 'SRN',
#   'total_supply': 573145073.0},
#  {'24h_volume_usd': 245153.0,
#   'available_supply': 1104590.0,
#   'id': 'gnosis-gno',
#   'last_updated': 1521812350,
#   'market_cap_usd': 87599179.0,
#   'max_supply': None,
#   'name': 'Gnosis',
#   'percent_change_1h': -1.75,
#   'percent_change_24h': -8.07,
#   'percent_change_7d': -7.47,
#   'price_btc': 0.0095061,
#   'price_usd': 79.3047,
#   'rank': 115,
#   'symbol': 'GNO',
#   'total_supply': 10000000.0},
#  {'24h_volume_usd': 5054190.0,
#   'available_supply': 226091449.0,
#   'id': 'substratum',
#   'last_updated': 1521812354,
#   'market_cap_usd': 87478625.0,
#   'max_supply': None,
#   'name': 'Substratum',
#   'percent_change_1h': -1.2,
#   'percent_change_24h': -7.93,
#   'percent_change_7d': -12.53,
#   'price_btc': 4.638e-05,
#   'price_usd': 0.386917,
#   'rank': 116,
#   'symbol': 'SUB',
#   'total_supply': 352000000.0},
#  {'24h_volume_usd': 8546780.0,
#   'available_supply': 3726781.0,
#   'id': 'genesis-vision',
#   'last_updated': 1521812355,
#   'market_cap_usd': 87173505.0,
#   'max_supply': None,
#   'name': 'Genesis Vision',
#   'percent_change_1h': 0.3,
#   'percent_change_24h': -4.87,
#   'percent_change_7d': -1.39,
#   'price_btc': 0.00280385,
#   'price_usd': 23.3911,
#   'rank': 117,
#   'symbol': 'GVT',
#   'total_supply': 4436644.0},
#  {'24h_volume_usd': 6273490.0,
#   'available_supply': 1050141509.0,
#   'id': 'decentraland',
#   'last_updated': 1521812354,
#   'market_cap_usd': 86680360.0,
#   'max_supply': None,
#   'name': 'Decentraland',
#   'percent_change_1h': -1.57,
#   'percent_change_24h': -5.91,
#   'percent_change_7d': -14.21,
#   'price_btc': 9.89e-06,
#   'price_usd': 0.0825416,
#   'rank': 118,
#   'symbol': 'MANA',
#   'total_supply': 2644403343.0},
#  {'24h_volume_usd': 9764.75,
#   'available_supply': 1189228953.0,
#   'id': 'dynamic-trading-rights',
#   'last_updated': 1521812357,
#   'market_cap_usd': 83813170.0,
#   'max_supply': None,
#   'name': 'Dynamic Trading Rights',
#   'percent_change_1h': 1.36,
#   'percent_change_24h': -3.03,
#   'percent_change_7d': -1.83,
#   'price_btc': 8.45e-06,
#   'price_usd': 0.0704769,
#   'rank': 119,
#   'symbol': 'DTR',
#   'total_supply': 3750000000.0},
#  {'24h_volume_usd': 4948870.0,
#   'available_supply': 617314171.0,
#   'id': 'quantstamp',
#   'last_updated': 1521812356,
#   'market_cap_usd': 82957765.0,
#   'max_supply': None,
#   'name': 'Quantstamp',
#   'percent_change_1h': -1.4,
# ...
#   'symbol': 'LEAF',
#   'total_supply': 21080296750.0},
#  {'24h_volume_usd': None,
#   'available_supply': 4500000.0,
#   'id': 'starcredits',
#   'last_updated': 1521808153,
#   'market_cap_usd': 1675580.0,
#   'max_supply': 20000000.0,
#   'name': 'StarCredits',
#   'percent_change_1h': None,
#   'percent_change_24h': -0.51,
#   'percent_change_7d': 3.47,
#   'price_btc': 4.405e-05,
#   'price_usd': 0.372351,
#   'rank': 961,
#   'symbol': 'STRC',
#   'total_supply': 20000000.0},
#  {'24h_volume_usd': 34.8779,
#   'available_supply': 10000305.0,
#   'id': 'yashcoin',
#   'last_updated': 1521812348,
#   'market_cap_usd': 1568438.0,
#   'max_supply': None,
#   'name': 'YashCoin',
#   'percent_change_1h': -1.36,
#   'percent_change_24h': -35.35,
#   'percent_change_7d': -5.18,
#   'price_btc': 1.88e-05,
#   'price_usd': 0.156839,
#   'rank': 962,
#   'symbol': 'YASH',
#   'total_supply': 10000305.0},
#  {'24h_volume_usd': 279.904,
#   'available_supply': 25960250000.0,
#   'id': 'smileycoin',
#   'last_updated': 1521812344,
#   'market_cap_usd': 1526904.0,
#   'max_supply': None,
#   'name': 'SmileyCoin',
#   'percent_change_1h': -1.15,
#   'percent_change_24h': -4.78,
#   'percent_change_7d': -7.92,
#   'price_btc': 7e-09,
#   'price_usd': 5.8817e-05,
#   'rank': 963,
#   'symbol': 'SMLY',
#   'total_supply': 25960250000.0},
#  {'24h_volume_usd': None,
#   'available_supply': 58144264.0,
#   'id': 'fucktoken',
#   'last_updated': 1521784451,
#   'market_cap_usd': 1504704.0,
#   'max_supply': None,
#   'name': 'FuckToken',
#   'percent_change_1h': None,
#   'percent_change_24h': -3.19,
#   'percent_change_7d': 22.7,
#   'price_btc': 3.08e-06,
#   'price_usd': 0.0258788,
#   'rank': 964,
#   'symbol': 'FUCK',
#   'total_supply': 70856019.0},
#  {'24h_volume_usd': 11.4865,
#   'available_supply': 644053.0,
#   'id': 'chronologic',
#   'last_updated': 1521812354,
#   'market_cap_usd': 1495981.0,
#   'max_supply': None,
#   'name': 'Chronologic',
#   'percent_change_1h': -1.25,
#   'percent_change_24h': 3.69,
#   'percent_change_7d': -13.16,
#   'price_btc': 0.00027843,
#   'price_usd': 2.32276,
#   'rank': 965,
#   'symbol': 'DAY',
#   'total_supply': 941258.0},
#  {'24h_volume_usd': 5.07957,
#   'available_supply': 487606932.0,
#   'id': 'version',
#   'last_updated': 1521812350,
#   'market_cap_usd': 1484027.0,
#   'max_supply': None,
#   'name': 'Version',
#   'percent_change_1h': -1.28,
#   'percent_change_24h': 9.67,
#   'percent_change_7d': -9.04,
#   'price_btc': 3.6e-07,
#   'price_usd': 0.00304349,
#   'rank': 966,
#   'symbol': 'V',
#   'total_supply': 487606932.0},
#  {'24h_volume_usd': 184.746,
#   'available_supply': 33356077.0,
#   'id': 'renos',
#   'last_updated': 1521812349,
#   'market_cap_usd': 1405278.0,
#   'max_supply': None,
#   'name': 'Renos',
#   'percent_change_1h': -1.28,
#   'percent_change_24h': 15.22,
#   'percent_change_7d': 11.53,
#   'price_btc': 5.05e-06,
#   'price_usd': 0.0421296,
#   'rank': 967,
#   'symbol': 'RNS',
#   'total_supply': 33356077.0},
#  {'24h_volume_usd': 470.806,
#   'available_supply': 118545050.0,
#   'id': 'worldcoin',
#   'last_updated': 1521812340,
#   'market_cap_usd': 1372787.0,
#   'max_supply': None,
#   'name': 'WorldCoin',
#   'percent_change_1h': -1.36,
#   'percent_change_24h': -7.41,
#   'percent_change_7d': -3.51,
#   'price_btc': 1.39e-06,
#   'price_usd': 0.0115803,
#   'rank': 968,
#   'symbol': 'WDC',
#   'total_supply': 118545050.0},
#  {'24h_volume_usd': 28.622,
#   'available_supply': 18590521.0,
#   'id': 'universe',
#   'last_updated': 1521812349,
#   'market_cap_usd': 1263384.0,
#   'max_supply': None,
#   'name': 'Universe',
#   'percent_change_1h': -1.18,
#   'percent_change_24h': -0.84,
#   'percent_change_7d': -3.81,
#   'price_btc': 8.15e-06,
#   'price_usd': 0.0679585,
#   'rank': 969,
#   'symbol': 'UNI',
#   'total_supply': 29790521.0},
#  {'24h_volume_usd': 369.705,
#   'available_supply': 41004200.0,
#   'id': 'neverdie',
#   'last_updated': 1521812353,
#   'market_cap_usd': 1172687.0,
#   'max_supply': None,
#   'name': 'NEVERDIE',
#   'percent_change_1h': -4.87,
#   'percent_change_24h': 22.22,
#   'percent_change_7d': -9.41,
#   'price_btc': 3.43e-06,
#   'price_usd': 0.0285992,
#   'rank': 970,
#   'symbol': 'NDC',
#   'total_supply': 400000000.0},
#  {'24h_volume_usd': 46.5879,
#   'available_supply': 18474130.0,
#   'id': 'insanecoin-insn',
#   'last_updated': 1521812350,
#   'market_cap_usd': 1149095.0,
#   'max_supply': 30000000.0,
#   'name': 'InsaneCoin',
#   'percent_change_1h': -1.75,
#   'percent_change_24h': -8.1,
#   'percent_change_7d': -5.09,
#   'price_btc': 7.46e-06,
#   'price_usd': 0.0622002,
#   'rank': 971,
#   'symbol': 'INSN',
#   'total_supply': 18724130.0},
#  {'24h_volume_usd': 2.42487,
#   'available_supply': 465952.0,
#   'id': 'ico-openledger',
#   'last_updated': 1521812347,
#   'market_cap_usd': 1129872.0,
#   'max_supply': None,
#   'name': 'ICO OpenLedger',
#   'percent_change_1h': -2.14,
#   'percent_change_24h': -2.07,
#   'percent_change_7d': -0.66,
#   'price_btc': 0.00029067,
#   'price_usd': 2.42487,
#   'rank': 972,
#   'symbol': 'ICOO',
#   'total_supply': 465952.0},
#  {'24h_volume_usd': 211.934,
#   'available_supply': 167766700.0,
#   'id': 'zetacoin',
#   'last_updated': 1521812341,
#   'market_cap_usd': 1126894.0,
#   'max_supply': None,
#   'name': 'Zetacoin',
#   'percent_change_1h': -3.59,
#   'percent_change_24h': -5.02,
#   'percent_change_7d': 2.08,
#   'price_btc': 8.1e-07,
#   'price_usd': 0.00671703,
#   'rank': 973,
#   'symbol': 'ZET',
#   'total_supply': 167766700.0},
#  {'24h_volume_usd': 55.875,
#   'available_supply': 10585464.0,
#   'id': 'kekcoin',
#   'last_updated': 1521812356,
#   'market_cap_usd': 1122409.0,
#   'max_supply': 21000000.0,
#   'name': 'KekCoin',
#   'percent_change_1h': -1.22,
#   'percent_change_24h': -10.74,
#   'percent_change_7d': -6.02,
#   'price_btc': 1.271e-05,
#   'price_usd': 0.106033,
#   'rank': 974,
#   'symbol': 'KEK',
#   'total_supply': 11585464.0},
#  {'24h_volume_usd': 273.587,
#   'available_supply': 674616.0,
#   'id': 'platinumbar',
#   'last_updated': 1521812347,
#   'market_cap_usd': 1097156.0,
#   'max_supply': None,
#   'name': 'PlatinumBAR',
#   'percent_change_1h': -3.88,
#   'percent_change_24h': -1.1,
#   'percent_change_7d': 7.37,
#   'price_btc': 0.00019495,
#   'price_usd': 1.62634,
#   'rank': 975,
#   'symbol': 'XPTX',
#   'total_supply': 674616.0},
#  {'24h_volume_usd': 64.0491,
#   'available_supply': 156913424.0,
#   'id': 'fastcoin',
#   'last_updated': 1521812340,
#   'market_cap_usd': 1073421.0,
#   'max_supply': 165888000.0,
#   'name': 'Fastcoin',
#   'percent_change_1h': -1.36,
#   'percent_change_24h': 3.85,
#   'percent_change_7d': -23.07,
#   'price_btc': 8.2e-07,
#   'price_usd': 0.00684085,
#   'rank': 976,
#   'symbol': 'FST',
#   'total_supply': 156913424.0},
#  {'24h_volume_usd': 2.06852,
#   'available_supply': 75000000.0,
#   'id': 'bitpark-coin',
#   'last_updated': 1521812348,
#   'market_cap_usd': 1069928.0,
#   'max_supply': None,
#   'name': 'Bitpark Coin',
#   'percent_change_1h': -1.28,
#   'percent_change_24h': 12.01,
#   'percent_change_7d': 14.36,
#   'price_btc': 1.71e-06,
#   'price_usd': 0.0142657,
#   'rank': 977,
#   'symbol': 'BPC',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 242.739,
#   'available_supply': 32550000.0,
#   'id': 'commodity-ad-network',
#   'last_updated': 1521812358,
#   'market_cap_usd': 1063317.0,
#   'max_supply': None,
#   'name': 'Commodity Ad Network',
#   'percent_change_1h': -1.52,
#   'percent_change_24h': 11.84,
#   'percent_change_7d': -20.39,
#   'price_btc': 3.92e-06,
#   'price_usd': 0.0326672,
#   'rank': 978,
#   'symbol': 'CDX',
#   'total_supply': 120000000.0},
#  {'24h_volume_usd': None,
#   'available_supply': 100000000.0,
#   'id': 'shorty',
#   'last_updated': 1521732548,
#   'market_cap_usd': 1061890.0,
#   'max_supply': None,
#   'name': 'Shorty',
#   'percent_change_1h': None,
#   'percent_change_24h': -1.2,
#   'percent_change_7d': -10.96,
#   'price_btc': 1.24e-06,
#   'price_usd': 0.0106189,
#   'rank': 979,
#   'symbol': 'SHORTY',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 108.786,
#   'available_supply': 61445805.0,
#   'id': 'maxcoin',
#   'last_updated': 1521812341,
#   'market_cap_usd': 1030108.0,
#   'max_supply': None,
#   'name': 'MaxCoin',
#   'percent_change_1h': -1.36,
#   'percent_change_24h': -4.48,
#   'percent_change_7d': -10.28,
#   'price_btc': 2.01e-06,
#   'price_usd': 0.0167645,
#   'rank': 980,
#   'symbol': 'MAX',
#   'total_supply': 61445805.0},
#  {'24h_volume_usd': None,
#   'available_supply': 6695133.0,
#   'id': 'shadowcash',
#   'last_updated': 1521739443,
#   'market_cap_usd': 992433.0,
#   'max_supply': None,
#   'name': 'ShadowCash',
#   'percent_change_1h': None,
#   'percent_change_24h': -0.88,
#   'percent_change_7d': -25.58,
#   'price_btc': 1.726e-05,
#   'price_usd': 0.148232,
#   'rank': 981,
#   'symbol': 'SDC',
#   'total_supply': 6695133.0},
#  {'24h_volume_usd': 1.6685,
#   'available_supply': 10996318099.0,
#   'id': 'hitcoin',
#   'last_updated': 1521812346,
#   'market_cap_usd': 917368.0,
#   'max_supply': None,
#   'name': 'HitCoin',
#   'percent_change_1h': -1.28,
#   'percent_change_24h': -3.71,
#   'percent_change_7d': 1.94,
#   'price_btc': 1e-08,
#   'price_usd': 8.3425e-05,
#   'rank': 982,
#   'symbol': 'HTC',
#   'total_supply': 20996318099.0},
#  {'24h_volume_usd': 150.368,
#   'available_supply': 11124783.0,
#   'id': 'leviarcoin',
#   'last_updated': 1521812351,
#   'market_cap_usd': 903026.0,
#   'max_supply': 54000000.0,
#   'name': 'LeviarCoin',
#   'percent_change_1h': -1.22,
#   'percent_change_24h': -5.18,
#   'percent_change_7d': -6.17,
#   'price_btc': 9.73e-06,
#   'price_usd': 0.0811725,
#   'rank': 983,
#   'symbol': 'XLC',
#   'total_supply': 11124783.0},
#  {'24h_volume_usd': 123.254,
#   'available_supply': 2110317.0,
#   'id': 'anoncoin',
#   'last_updated': 1521812340,
#   'market_cap_usd': 898047.0,
#   'max_supply': None,
#   'name': 'Anoncoin',
#   'percent_change_1h': -3.16,
#   'percent_change_24h': -3.73,
#   'percent_change_7d': -38.84,
#   'price_btc': 5.101e-05,
#   'price_usd': 0.425551,
#   'rank': 984,
#   'symbol': 'ANC',
#   'total_supply': 2110317.0},
#  {'24h_volume_usd': 310.029,
#   'available_supply': 4773.0,
#   'id': 'sovereign-hero',
#   'last_updated': 1521812352,
#   'market_cap_usd': 878747.0,
#   'max_supply': None,
#   'name': 'Sovereign Hero',
#   'percent_change_1h': -0.9,
#   'percent_change_24h': 2.86,
#   'percent_change_7d': 4.26,
#   'price_btc': 0.0220687,
#   'price_usd': 184.108,
#   'rank': 985,
#   'symbol': 'HERO',
#   'total_supply': 4773.0},
#  {'24h_volume_usd': 145.754,
#   'available_supply': 10343113.0,
#   'id': 'ultimate-secure-cash',
#   'last_updated': 1521812350,
#   'market_cap_usd': 868915.0,
#   'max_supply': 200084200.0,
#   'name': 'Ultimate Secure Cash',
#   'percent_change_1h': -1.5,
#   'percent_change_24h': -30.09,
#   'percent_change_7d': -41.03,
#   'price_btc': 1.007e-05,
#   'price_usd': 0.084009,
#   'rank': 986,
#   'symbol': 'USC',
#   'total_supply': 38602656.0},
#  {'24h_volume_usd': 308.913,
#   'available_supply': 24700248.0,
#   'id': 'kobocoin',
#   'last_updated': 1521812344,
#   'market_cap_usd': 862417.0,
#   'max_supply': None,
#   'name': 'Kobocoin',
#   'percent_change_1h': -2.94,
#   'percent_change_24h': 5.04,
#   'percent_change_7d': 9.8,
#   'price_btc': 4.19e-06,
#   'price_usd': 0.0349153,
#   'rank': 987,
#   'symbol': 'KOBO',
#   'total_supply': 24700248.0},
#  {'24h_volume_usd': 380.338,
#   'available_supply': 3429440774.0,
#   'id': 'popularcoin',
#   'last_updated': 1521812342,
#   'market_cap_usd': 858303.0,
#   'max_supply': 4999999999.0,
#   'name': 'PopularCoin',
#   'percent_change_1h': -1.28,
#   'percent_change_24h': -3.72,
#   'percent_change_7d': -1.63,
#   'price_btc': 3e-08,
#   'price_usd': 0.000250275,
#   'rank': 988,
#   'symbol': 'POP',
#   'total_supply': 3429440774.0},
#  {'24h_volume_usd': 359.107,
#   'available_supply': 787126712.0,
#   'id': 'netcoin',
#   'last_updated': 1521812341,
#   'market_cap_usd': 853663.0,
#   'max_supply': None,
#   'name': 'NetCoin',
#   'percent_change_1h': -1.28,
#   'percent_change_24h': -3.71,
#   'percent_change_7d': 7.58,
#   'price_btc': 1.3e-07,
#   'price_usd': 0.00108453,
#   'rank': 989,
#   'symbol': 'NET',
#   'total_supply': 787126712.0},
#  {'24h_volume_usd': 5.29524,
#   'available_supply': 248542036.0,
#   'id': 'qubitcoin',
#   'last_updated': 1521812341,
#   'market_cap_usd': 850118.0,
#   'max_supply': None,
#   'name': 'QubitCoin',
#   'percent_change_1h': -1.36,
#   'percent_change_24h': -11.2,
#   'percent_change_7d': -4.6,
#   'price_btc': 4.1e-07,
#   'price_usd': 0.00342042,
#   'rank': 990,
#   'symbol': 'Q2C',
#   'total_supply': 248542036.0},
#  {'24h_volume_usd': 222.557,
#   'available_supply': 1581531.0,
#   'id': 'etheriya',
#   'last_updated': 1521812352,
#   'market_cap_usd': 842300.0,
#   'max_supply': 100000000.0,
#   'name': 'Etheriya',
#   'percent_change_1h': -1.22,
#   'percent_change_24h': -19.35,
#   'percent_change_7d': -20.52,
#   'price_btc': 6.384e-05,
#   'price_usd': 0.532585,
#   'rank': 991,
#   'symbol': 'RIYA',
#   'total_supply': 1861531.0},
#  {'24h_volume_usd': 304.769,
#   'available_supply': 64151405.0,
#   'id': 'hobonickels',
#   'last_updated': 1521812341,
#   'market_cap_usd': 770664.0,
#   'max_supply': 120000000.0,
#   'name': 'HoboNickels',
#   'percent_change_1h': -1.28,
#   'percent_change_24h': -6.18,
#   'percent_change_7d': 1.96,
#   'price_btc': 1.44e-06,
#   'price_usd': 0.0120132,
#   'rank': 992,
#   'symbol': 'HBN',
#   'total_supply': 64151405.0},
#  {'24h_volume_usd': 16.5976,
#   'available_supply': 23079737.0,
#   'id': 'bitstar',
#   'last_updated': 1521812342,
#   'market_cap_usd': 768246.0,
#   'max_supply': None,
#   'name': 'Bitstar',
#   'percent_change_1h': -1.28,
#   'percent_change_24h': None,
#   'percent_change_7d': 6.33,
#   'price_btc': 3.99e-06,
#   'price_usd': 0.0332866,
#   'rank': 993,
#   'symbol': 'BITS',
#   'total_supply': 23079737.0},
#  {'24h_volume_usd': 20.84,
#   'available_supply': 7068694.0,
#   'id': 'fantomcoin',
#   'last_updated': 1521812343,
#   'market_cap_usd': 766614.0,
#   'max_supply': None,
#   'name': 'Fantomcoin',
#   'percent_change_1h': -1.22,
#   'percent_change_24h': -10.59,
#   'percent_change_7d': -23.54,
#   'price_btc': 1.3e-05,
#   'price_usd': 0.108452,
#   'rank': 994,
#   'symbol': 'FCN',
#   'total_supply': 7068694.0},
#  {'24h_volume_usd': None,
#   'available_supply': 2993420.0,
#   'id': 'unicoin',
#   'last_updated': 1521768846,
#   'market_cap_usd': 754069.0,
#   'max_supply': None,
#   'name': 'UniCoin',
#   'percent_change_1h': None,
#   'percent_change_24h': -0.81,
#   'percent_change_7d': 11.83,
#   'price_btc': 2.93e-05,
#   'price_usd': 0.251909,
#   'rank': 995,
#   'symbol': 'UNIC',
#   'total_supply': 2993420.0},
#  {'24h_volume_usd': 364.587,
#   'available_supply': 16898938.0,
#   'id': 'bitcoin-scrypt',
#   'last_updated': 1521812342,
#   'market_cap_usd': 733093.0,
#   'max_supply': None,
#   'name': 'Bitcoin Scrypt',
#   'percent_change_1h': -1.22,
#   'percent_change_24h': -1.77,
#   'percent_change_7d': -12.01,
#   'price_btc': 5.2e-06,
#   'price_usd': 0.043381,
#   'rank': 996,
#   'symbol': 'BTCS',
#   'total_supply': 16898938.0},
#  {'24h_volume_usd': 128.844,
#   'available_supply': 107648.0,
#   'id': 'triangles',
#   'last_updated': 1521812343,
#   'market_cap_usd': 688810.0,
#   'max_supply': None,
#   'name': 'Triangles',
#   'percent_change_1h': -1.28,
#   'percent_change_24h': -7.95,
#   'percent_change_7d': 39.77,
#   'price_btc': 0.000767,
#   'price_usd': 6.3987,
#   'rank': 997,
#   'symbol': 'TRI',
#   'total_supply': 107648.0},
#  {'24h_volume_usd': 317.083,
#   'available_supply': 20869700.0,
#   'id': 'machinecoin',
#   'last_updated': 1521812344,
#   'market_cap_usd': 673789.0,
#   'max_supply': None,
#   'name': 'Machinecoin',
#   'percent_change_1h': -1.03,
#   'percent_change_24h': -0.05,
#   'percent_change_7d': -16.38,
#   'price_btc': 3.87e-06,
#   'price_usd': 0.0322855,
#   'rank': 998,
#   'symbol': 'MAC',
#   'total_supply': 20869700.0},
#  {'24h_volume_usd': 72.9722,
#   'available_supply': 89069687.0,
#   'id': 'grimcoin',
#   'last_updated': 1521812356,
#   'market_cap_usd': 652927.0,
#   'max_supply': None,
#   'name': 'Grimcoin',
#   'percent_change_1h': -0.86,
#   'percent_change_24h': -0.25,
#   'percent_change_7d': -12.93,
#   'price_btc': 8.8e-07,
#   'price_usd': 0.00733052,
#   'rank': 999,
#   'symbol': 'GRIM',
#   'total_supply': 103236426.0},
#  {'24h_volume_usd': 227.173,
#   'available_supply': 32000.0,
#   'id': 'iticoin',
#   'last_updated': 1521812350,
#   'market_cap_usd': 650042.0,
#   'max_supply': None,
#   'name': 'iTicoin',
#   'percent_change_1h': -0.72,
#   'percent_change_24h': 9.61,
#   'percent_change_7d': -4.16,
#   'price_btc': 0.00243498,
#   'price_usd': 20.3138,
#   'rank': 1000,
#   'symbol': 'ITI',
#   'total_supply': 9999992.0},
#  ...]

# %% [markdown]
# You can pass a currency through symbol or coin slug:

# %%
data_from_symbol = cmc.ticker("BTC")
data_from_slug = cmc.ticker("bitcoin")

data_from_slug
# Out:
# {'24h_volume_usd': 5182320000.0,
#  'available_supply': 16935025.0,
#  'id': 'bitcoin',
#  'last_updated': 1521812364,
#  'market_cap_usd': 141712966601,
#  'max_supply': 21000000.0,
#  'name': 'Bitcoin',
#  'percent_change_1h': -1.37,
#  'percent_change_24h': -3.78,
#  'percent_change_7d': -0.13,
#  'price_btc': 1.0,
#  'price_usd': 8368.04,
#  'rank': 1,
#  'symbol': 'BTC',
#  'total_supply': 16935025.0}

# %% [markdown]
# To get all symbols and slugs you can use the next attributes:

# %%
all_symbols = cmc.symbols
all_slugs = cmc.coins

all_symbols
all_slugs
# Out:
# ['0x',
#  '1337coin',
#  '1world',
#  '2give',
#  '300-token',
#  '42-coin',
#  '808coin',
#  '8bit',
#  'abjcoin',
#  'abncoin',
#  'accelerator-network',
#  'ace',
#  'aces',
#  'achain',
#  'acoin',
#  'acute-angle-cloud',
#  'adbank',
#  'adshares',
#  'adtoken',
#  'advanced-internet-blocks',
#  'adx-net',
#  'adzcoin',
#  'aelf',
#  'aeon',
#  'aerium',
#  'aeron',
#  'aeternity',
#  'agrello-delta',
#  'aichain',
#  'aidcoin',
#  'aidoc',
#  'aidos-kuneen',
#  'aigang',
#  'aion',
#  'airswap',
#  'airtoken',
#  'akuya-coin',
#  'alis',
#  'all-sports',
#  'allion',
#  'allsafe',
#  'alpacoin',
#  'alphabitcoinfund',
#  'alphacat',
#  'alqo',
#  'altcoin-alt',
#  'altcommunity-coin',
#  'amber',
#  'ambercoin',
#  'ammo-reloaded',
#  'amsterdamcoin',
#  'anarchistsprime',
#  'animation-vision-cash',
#  'animecoin',
#  'anoncoin',
#  'anryze',
#  'antibitcoin',
#  'antilitecoin',
#  'antimatter',
#  'appcoins',
#  'apx',
#  'aquariuscoin',
#  'aragon',
#  'arbit',
#  'arbitragect',
#  'arcblock',
#  'arcticcoin',
#  'ardor',
#  'argentum',
#  'argus',
#  'aricoin',
#  'ark',
#  'artbyte',
#  'artex-coin',
#  'asch',
#  'aseancoin',
#  'asiacoin',
#  'asiadigicoin',
#  'astro',
#  'atbcoin',
#  'atlant',
#  'atmcoin',
#  'atmos',
#  'atn',
#  'atomic-coin',
#  'attention-token-of-media',
#  'audiocoin',
#  'augur',
#  'aurora-dao',
#  'auroracoin',
#  'aurumcoin',
#  'authorship',
#  'autonio',
#  'avatarcoin',
#  'aventus',
#  'avoncoin',
#  'aware',
#  'axiom',
#  'axpire',
#  'b2bx',
#  'b3coin',
#  'babb',
#  'banca',
#  'bancor',
#  'bankcoin',
#  'bankex',
#  'banyan-network',
#  'basic-attention-token',
#  'bastonet',
#  'bata',
#  'bean-cash',
#  'beatcoin',
#  'bee-token',
#  'belacoin',
#  'benjirolls',
#  'berncash',
#  'bestchain',
#  'bezop',
#  'biblepay',
#  'bibox-token',
#  'bigone-token',
#  'bigup',
#  'billarycoin',
#  'billionaire-token',
#  'binance-coin',
#  'biobar',
#  'biocoin',
#  'bios-crypto',
#  'bipcoin',
#  'birds',
#  'bismuth',
#  'bit20',
#  'bitair',
#  'bitalphacoin',
#  'bitasean',
#  'bitbar',
#  'bitbase',
#  'bitbay',
#  'bitboost',
#  'bitbtc',
#  'bitcedi',
#  'bitclave',
#  'bitcloud',
#  'bitcny',
#  'bitcoal',
#  'bitcoin',
#  'bitcoin-21',
#  'bitcoin-atom',
#  'bitcoin-cash',
#  'bitcoin-diamond',
#  'bitcoin-god',
#  'bitcoin-gold',
#  'bitcoin-green',
#  'bitcoin-planet',
#  'bitcoin-plus',
#  'bitcoin-private',
#  'bitcoin-red',
#  'bitcoin-scrypt',
#  'bitcoindark',
#  'bitcoinfast',
#  'bitcoinx',
#  'bitcoinz',
#  'bitconnect',
#  'bitcore',
#  'bitcrystals',
#  'bitcurrency',
#  'bitdeal',
#  'bitdegree',
#  'bitdice',
#  'biteur',
#  'bitfid',
#  'bitgold',
#  'bitok',
#  'bitpark-coin',
#  'bitquark',
#  'bitqy',
#  'bitradio',
#  'bitsend',
#  'bitserial',
#  'bitshares',
#  'bitshares-music',
#  'bitsilver',
#  'bitsoar',
#  'bitstar',
#  'bitswift',
#  'bittokens',
#  'bitusd',
#  'bitvolt',
#  'bitwhite',
#  'bitz',
#  'bitzeny',
#  'blackcoin',
#  'blackmoon',
#  'blackstar',
#  'blakecoin',
#  'blakestar',
#  'blazercoin',
#  'blitzcash',
#  'block-array',
#  'blockcdn',
#  'blockmason',
#  'blocknet',
#  'blockpay',
#  'blockpool',
#  'blockport',
#  'blocktix',
#  'blockv',
#  'bloomtoken',
#  'blox',
#  'bluecoin',
#  'bluzelle',
#  'bnktothefuture',
#  'bnrtxcoin',
#  'bodhi',
#  'bolenum',
#  'bolivarcoin',
#  'bonpay',
#  'boolberry',
#  'boostcoin',
#  'boscoin',
#  'bottos',
#  'bounty0x',
#  'bowhead',
#  'bowscoin',
#  'braincoin',
#  'brat',
#  'bread',
#  'breakout',
#  'breakout-stake',
#  'briacoin',
#  'bridgecoin',
#  'britcoin',
#  'bt2-cst',
#  'btcmoon',
#  'btctalkcoin',
#  'bubble',
#  'bullion',
#  'bulwark',
#  'bumbacoin',
#  'bunnycoin',
#  'burst',
#  'buzzcoin',
#  'byteball',
#  'bytecent',
#  'bytecoin-bcn',
#  'bytom',
#  'c-bit',
#  'c20',
#  'cabbage',
#  'cachecoin',
#  'californium',
#  'caliphcoin',
#  'campuscoin',
#  'canada-ecoin',
#  'candy',
#  'cannabiscoin',
#  'cannacoin',
#  'cannation',
#  'canyacoin',
#  'cappasity',
#  'carboncoin',
#  'cardano',
#  'cargox',
#  'cartaxi-token',
#  'carvertical',
#  'cashaa',
#  'cashcoin',
#  'cashme',
#  'casinocoin',
#  'ccminer',
#  'ccore',
#  'centra',
#  'centrality',
#  'centurion',
#  'cfun',
#  'chaincoin',
#  'chainlink',
#  'chancoin',
#  'change',
#  'chatcoin',
#  'cheapcoin',
#  'chesscoin',
#  'chips',
#  'chronobank',
#  'chronologic',
#  'chronos',
#  'cindicator',
#  'circuits-of-value',
#  'civic',
#  'clams',
#  'clearpoll',
#  'cloakcoin',
#  'cloud',
#  'clubcoin',
#  'cobinhood',
#  'coexistcoin',
#  'coffeecoin',
#  'cofound-it',
#  'coimatic-2',
#  'coimatic-3',
#  'coin',
#  'coin2-1',
#  'coinfi',
#  'coinlancer',
#  'coinmeet',
#  'coinonat',
#  'coinonatx',
#  'coinpoker',
#  'colossuscoin-v2',
#  'colossuscoinxt',
#  'commodity-ad-network',
#  'compcoin',
#  'compucoin',
#  'comsa-eth',
#  'concoin',
#  'condensate',
#  'confido',
#  'copico',
#  'copytrack',
#  'corion',
#  'coss',
#  'counterparty',
#  'coupecoin',
#  'covesting',
#  'cpchain',
#  'crave',
#  'cream',
#  'creatio',
#  'creativecoin',
#  'credence-coin',
#  'creditbit',
#  'credits',
#  'credo',
#  'crevacoin',
#  'crowdcoin',
#  'crown',
#  'crtcoin',
#  'cryptcoin',
#  'crypterium',
#  'crypto',
#  'cryptocarbon',
#  'cryptoescudo',
#  'cryptoforecast',
#  'cryptojacks',
#  'cryptonex',
#  'cryptonite',
#  'cryptopay',
#  'cryptopiafeeshares',
#  'cryptoping',
#  'cryptoworldx-token',
#  'crystal-clear',
#  'cthulhu-offerings',
#  'cube',
#  'curecoin',
#  'cvcoin',
#  'cybercoin',
#  'cybermiles',
#  'cycling-coin',
#  'cyder',
#  'cypher',
#  'dadi',
#  'dai',
#  'dalecoin',
#  'dao-casino',
#  'dappster',
#  'darcrus',
#  'darklisk',
#  'darsek',
#  'dash',
#  'dashcoin',
#  'dashs',
#  'data',
#  'databits',
#  'datacoin',
#  'datawallet',
#  'datum',
#  'datx',
#  'davorcoin',
#  'daxxcoin',
#  'dcorp',
#  'debitcoin',
#  'debitum-network',
#  'decent',
#  'decent-bet',
#  'decentraland',
#  'decision-token',
#  'decred',
#  'deepbrain-chain',
#  'deeponion',
#  'delphy',
#  'deltacredits',
#  'denarius-dnr',
#  'dent',
#  'dentacoin',
#  'desire',
#  'destiny',
#  'dether',
#  'deuscoin',
#  'deutsche-emark',
#  'devery',
#  'dew',
#  'dfscoin',
#  'diamond',
#  'dibcoin',
#  'digibyte',
#  'digicube',
#  'digipulse',
#  'digital-bullion-gold',
#  'digital-credits',
#  'digital-developers-fund',
#  'digital-money-bits',
#  'digital-rupees',
#  'digitalcoin',
#  'digitalnote',
#  'digitalprice',
#  'digixdao',
#  'dimcoin',
#  'dimecoin',
#  'dinastycoin',
#  'district0x',
#  'divi',
#  'dix-asset',
#  'dmarket',
#  'dnotes',
#  'dogecoin',
#  'dollar-online',
#  'dollarcoin',
#  'domraider',
#  'donationcoin',
#  'dopecoin',
#  'dotcoin',
#  'doubloon',
#  'dovu',
#  'draftcoin',
#  'dragon-coins',
#  'dragonchain',
#  'dreamcoin',
#  'dropil',
#  'droxne',
#  'drp-utility',
#  'dubaicoin-dbix',
#  'dubstep',
#  'dutch-coin',
#  'dynamic',
#  'dynamic-trading-rights',
#  'dynamiccoin',
#  'e-coin',
#  'e-dinar-coin',
#  'e-gulden',
#  'ea-coin',
#  'eaglecoin',
#  'earthcoin',
#  'ebitcoin-cash',
#  'ebittree-coin',
#  'eboostcoin',
#  'ebtcnew',
#  'eccoin',
#  'echolink',
#  'ecobit',
#  'ecocoin',
#  'edgeless',
#  'edrcoin',
#  'educare',
#  'education-ecosystem',
#  'eggcoin',
#  'ego',
#  'egold',
#  'eidoo',
#  'einsteinium',
#  'elacoin',
#  'elastic',
#  'elastos',
#  'elcoin-el',
#  'electra',
#  'electrifyasia',
#  'electroneum',
#  'electronic-pk-chain',
#  'elementrem',
#  'elixir',
#  'ellaism',
#  'eltcoin',
#  'elysium',
#  'embers',
#  'emerald',
#  'emercoin',
#  'emphy',
#  'encrypgen',
#  'encryptotel',
#  'energo',
#  'energycoin',
#  'enigma',
#  'enigma-project',
#  'enjin-coin',
#  'envion',
#  'eos',
#  'eot-token',
#  'equal',
#  'equitrader',
#  'erc20',
#  'ergo',
#  'eroscoin',
#  'eryllium',
#  'escoro',
#  'espers',
#  'eternity',
#  'ethbet',
#  'ethbits',
#  'etherecash',
#  'ethereum',
#  'ethereum-blue',
#  'ethereum-classic',
#  'ethereum-dark',
#  'ethereum-gold',
#  'ethereum-lite',
#  'ethereum-movie-venture',
#  'ethereumcash',
#  'etheriya',
#  'etheroll',
#  'etherparty',
#  'ethersportz',
#  'ethlend',
#  'ethorse',
#  'ethos',
#  'eurocoin',
#  'europecoin',
#  'eventchain',
#  'everex',
#  'evergreencoin',
#  'everus',
#  'evil-coin',
#  'evotion',
#  'exchange-union',
#  'exchangen',
#  'exclusivecoin',
#  'expanse',
#  'experience-points',
#  'experty',
#  'exrnchain',
#  'eztoken',
#  'factom',
#  'faircoin',
#  'fantomcoin',
#  'fapcoin',
#  'farad',
#  'fargocoin',
#  'farstcoin',
#  'fastcoin',
#  'fazzcoin',
#  'feathercoin',
#  'fedoracoin',
#  'fidentiax',
#  'filecoin',
#  'fimkrypto',
#  'fincoin',
#  'firecoin',
#  'first-bitcoin',
#  'first-bitcoin-capital',
#  'firstblood',
#  'firstcoin',
#  'flappycoin',
#  'flash',
#  'flaxscript',
#  'flik',
#  'flixxo',
#  'florincoin',
#  'fluttercoin',
#  'fluz-fluz',
#  'flycoin',
#  'flypme',
#  'foldingcoin',
#  'fonziecoin',
#  'footy-cash',
#  'force',
#  'fortuna',
#  'francs',
#  'franko',
#  'frankywillcoin',
#  'freicoin',
#  'fucktoken',
#  'fuelcoin',
#  'fujicoin',
#  'fujinto',
#  'funcoin',
#  'fundyourselfnow',
#  'funfair',
#  'fusion',
#  'futcoin',
#  'futurexe',
#  'fuzzballs',
#  'gaia',
#  'galactrum',
#  'gambit',
#  'game',
#  'gamechain',
#  'gamecredits',
#  'gameleaguecoin',
#  'gameunits',
#  'ganjacoin',
#  'gapcoin',
#  'garlicoin',
#  'gas',
#  'gatcoin',
#  'gaycoin',
#  'gbcgoldcoin',
#  'gcn-coin',
#  'geertcoin',
#  'gems-protocol',
#  'genaro-network',
#  'genesis-vision',
#  'genstake',
#  'geocoin',
#  'get-protocol',
#  'geysercoin',
#  'gifto',
#  'giga-watt-token',
#  'gladius-token',
#  'glasscoin',
#  'global-cryptocurrency',
#  'global-currency-reserve',
#  'global-jobcoin',
#  'globalboost-y',
#  'globalcoin',
#  'globaltoken',
#  'gnosis-gno',
#  'gobyte',
#  'gold-pressed-latinum',
#  'gold-reward-token',
#  'goldblocks',
#  'goldcoin',
#  'goldmaxcoin',
#  'goldmint',
#  'goldpieces',
#  'goldreserve',
#  'golem-network-tokens',
#  'golfcoin',
#  'golos',
#  'golos-gold',
#  'goodomy',
#  'gpu-coin',
#  'graft',
#  'grandcoin',
#  'granitecoin',
#  'greencoin',
#  'grid',
#  'gridcoin',
#  'grimcoin',
#  'groestlcoin',
#  'growers-international',
#  'guaranteed-ethurance-token-extra',
#  'guess',
#  'gulden',
#  'guncoin',
#  'guppy',
#  'gxchain',
#  'hacken',
#  'hackspace-capital',
#  'halalchain',
#  'halcyon',
#  'halloween-coin',
#  'happy-creator-coin',
#  'happycoin',
#  'harvest-masternode-coin',
#  'havven',
#  'hawala-today',
#  'healthywormcoin',
#  'heat-ledger',
#  'hedge',
#  'helleniccoin',
#  'hellogold',
#  'hempcoin',
#  'hempcoin-hmp',
#  'herocoin',
#  'hexx',
#  'hi-mutual-society',
#  'hicoin',
#  'high-gain',
#  'high-performance-blockchain',
#  'high-voltage',
#  'hirematch',
#  'hitcoin',
#  'hive-project',
#  'hobonickels',
#  'hodl-bucks',
#  'hodlcoin',
#  'hollywoodcoin',
#  'homeblockcoin',
#  'honey',
#  'hoqu',
#  'hshare',
#  'html-coin',
#  'hubii-network',
#  'humaniq',
#  'huntercoin',
#  'huobi-token',
#  'hush',
#  'hydro-protocol',
#  'hyper',
#  'hyper-pay',
#  'hyperstake',
#  'i0coin',
#  'ibank',
#  'ico-openledger',
#  'icobid',
#  'icon',
#  'iconic',
#  'iconomi',
#  'icos',
#  'idex-membership',
#  'idice',
#  'iethereum',
#  'ignis',
#  'ignition',
#  'iht-real-estate-protocol',
#  'impact',
#  'impulsecoin',
#  'incakoin',
#  'incent',
#  'indahash',
#  'independent-money-system',
#  'india-coin',
#  'indicoin',
#  'indorse-token',
#  'infchain',
#  'infinitecoin',
#  'infinity-economics',
#  'inflationcoin',
#  'influxcoin',
#  'ink',
#  'ink-protocol',
#  'innova',
#  'inpay',
#  'ins-ecosystem',
#  'insanecoin-insn',
#  'insights-network',
#  'insurepal',
#  'intelligent-trading-tech',
#  'intensecoin',
#  'internet-node-token',
#  'internet-of-people',
#  'internet-of-things',
#  'internxt',
#  'interplanetary-broadcast-coin',
#  'interstellar-holdings',
#  'investdigital',
#  'investfeed',
#  'invisiblecoin',
#  'iocoin',
#  'ion',
#  'iostoken',
#  'iot-chain',
#  'iota',
#  'ipchain',
#  'iquant',
#  'irishcoin',
#  'islacoin',
#  'iticoin',
#  'iungo',
#  'ixcoin',
#  'ixledger',
#  'javascript-token',
#  'jesus-coin',
#  'jet8',
#  'jetcoin',
#  'jewels',
#  'jibrel-network',
#  'jin-coin',
#  'jingtum-tech',
#  'jiyo',
#  'jobscoin',
#  'joincoin',
#  'joulecoin',
#  'karbo',
#  'karma',
#  'karmacoin',
#  'kashhcoin',
#  'kayicoin',
#  'kcash',
#  'kekcoin',
#  'kickico',
#  'kilocoin',
#  'kin',
#  'klondikecoin',
#  'kobocoin',
#  'kolion',
#  'komodo',
#  'korecoin',
#  'kronecoin',
#  'kubera-coin',
#  'kucoin-shares',
#  'kurrent',
#  'kushcoin',
#  'kyber-network',
#  'kzcash',
#  'lala-world',
#  'lamden',
#  'lampix',
#  'lanacoin',
#  'landcoin',
#  'lathaan',
#  'latiumx',
#  'latoken',
#  'lazaruscoin',
#  'leacoin',
#  'leadcoin',
#  'leafcoin',
#  'legends-room',
#  'legolas-exchange',
#  'lendconnect',
#  'leocoin',
#  'lepen',
#  'letitride',
#  'leverj',
#  'leviarcoin',
#  'levocoin',
#  'levoplus',
#  'library-credit',
#  'life',
#  'lightchain',
#  'linda',
#  'link-platform',
#  'linkedcoin',
#  'linkeye',
#  'linx',
#  'lisk',
#  'litebar',
#  'litebitcoin',
#  'litecoin',
#  'litecoin-cash',
#  'litecoin-plus',
#  'litecoin-ultra',
#  'litecred',
#  'litedoge',
#  'lltoken',
#  'locicoin',
#  'lockchain',
#  'lomocoin',
#  'loom-network',
#  'loopring',
#  'luckchain',
#  'luna-coin',
#  'lunyr',
#  'luxcoin',
#  'lykke',
#  'lympo',
#  'machinecoin',
#  'macro1',
#  'macron',
#  'madcoin',
#  'maecenas',
#  'magi',
#  'magiccoin',
#  'magnet',
#  'magnetcoin',
#  'magnum',
#  'maidsafecoin',
#  'maker',
#  'manna',
#  'mao-zedong',
#  'marijuanacoin',
#  'marscoin',
#  'martexcoin',
#  'marxcoin',
#  'master-swiscoin',
#  'masternodecoin',
#  'matrix-ai-network',
#  'matryx',
#  'maverick-chain',
#  'maxcoin',
#  'mazacoin',
#  'mcap',
#  'measurable-data-token',
#  'medibloc',
#  'medical-chain',
#  'mediccoin',
#  'medishares',
#  'megacoin',
#  'melon',
#  'memetic',
#  'mercury',
#  'mercury-protocol',
#  'mergecoin',
#  'metal',
#  'metal-music-coin',
#  'metalcoin',
#  'metaverse',
#  'micromoney',
#  'milocoin',
#  'mincoin',
#  'mindcoin',
#  'minereum',
#  'miners-reward-token',
#  'mineum',
#  'minex',
#  'minexcoin',
#  'mintcoin',
#  'mktcoin',
#  'mmxvi',
#  'moac',
#  'mobilecash',
#  'mobilego',
#  'mobius',
#  'modum',
#  'moeda-loyalty-points',
#  'moin',
#  'mojocoin',
#  'molecular-future',
#  'monaco',
#  'monacocoin',
#  'monacoin',
#  'monero',
#  'monero-gold',
#  'moneta2',
#  'monetaryunit',
#  'monetha',
#  'money',
#  'monkey-project',
#  'monster-byte',
#  'mooncoin',
#  'mothership',
#  'motocoin',
#  'msd',
#  'musicoin',
#  'musiconomi',
#  'mustangcoin',
#  'mybit-token',
#  'myriad',
#  'mysterium',
#  'mywish',
#  'naga',
#  'namecoin',
#  'namocoin',
#  'nanjcoin',
#  'nano',
#  'napoleonx',
#  'natcoin',
#  'nav-coin',
#  'neblio',
#  'nebulas-token',
#  'nekonium',
#  'nem',
#  'neo',
#  'neo-gold',
#  'neoscoin',
#  'netbit',
#  'netko',
#  'network-token',
#  'neumark',
#  'neuro',
#  'neurotoken',
#  'neutron',
#  'nevacoin',
#  'neverdie',
#  'newbium',
#  'nework',
#  'newyorkcoin',
#  'nexium',
#  'nexus',
#  'nimiq',
#  'nitro',
#  'noah-coin',
#  'noblecoin',
#  'nodecoin',
#  'nolimitcoin',
#  'novacoin',
#  'nubits',
#  'nucleus-vision',
#  'nuls',
#  'numeraire',
#  'numus',
#  'numuscash',
#  'nushares',
#  'nvo',
#  'nxt',
#  'nyancoin',
#  'oax',
#  'obits',
#  'obsidian',
#  'oceanchain',
#  'oceanlab',
#  'ocow',
#  'octanox',
#  'octocoin',
#  'octoin-coin',
#  'odyssey',
#  'ofcoin',
#  'okcash',
#  'olympus-labs',
#  'omicron',
#  'omisego',
#  'omni',
#  'oneroot-network',
#  'ongsocial',
#  'onix',
#  'ontology',
#  'op-coin',
#  'opal',
#  'open-trading-network',
#  'operand',
#  'opescoin',
#  'opus',
#  ...]

# %% [markdown]
# Other parameters:

# %%
print(cmc.ticker.__doc__)
# Out:
# Get currencies with other aditional data.
#
#         Args:
#             currency (str, optional): Specify a currency to return data,
#                 that can be a symbol or coin slug (see ``symbols`` and ``coins``
#                 properties). In this case the method returns a dict, otherwise
#                 returns a list. If you dont specify a currency,
#                 returns data for all in coinmarketcap. As default, ``None``.
#             limit (int, optional): Limit amount of coins on response.
#                 If ``limit == 0``, returns all coins in coinmarketcap.
#                 Only works if ``currency == None``. As default ``0``.
#             start (int, optional): Rank of first currency to retrieve.
#                 The count starts at 0 for the first currency ranked.
#                 Only works if ``currency == None``. As default ``0``.
#             convert (str, optional): Allows to convert prices, 24h volumes
#                 and market capitalizations in terms of one of badges
#                 returned by ``ticker_badges`` property. As default, ``"USD"``.
#
#         Returns (dict/list):
#             The type depends if currency param is provided or not.

# %% [markdown]
# If you want to get the valid badges that can be passed to `convert` param programatically, use this:

# %%
print(cmc.ticker_badges)
# Out:
# ['AUD', 'BRL', 'CAD', 'CHF', 'CLP', 'CNY', 'CZK', 'DKK', 'EUR', 'GBP', 'HKD', 'HUF', 'IDR', 'ILS', 'INR', 'JPY', 'KRW', 'MXN', 'MYR', 'NOK', 'NZD', 'PHP', 'PKR', 'PLN', 'RUB', 'SEK', 'SGD', 'THB', 'TRY', 'TWD', 'USD', 'ZAR']

# %% [markdown]
# #### `stats([convert="USD"])`
# Get global criptocurrency statistics. The `convert` parameter works just like in previous method.

# %%
cmc.stats()
# Out:
# {'active_assets': 663,
#  'active_currencies': 915,
#  'active_markets': 9592,
#  'bitcoin_percentage_of_market_cap': 44.28,
#  'last_updated': 1521812364,
#  'total_24h_volume_usd': 13833873286.0,
#  'total_market_cap_usd': 320020499616.0}

# %% [markdown]
# _____________________________________________
#
# ## Web scraper

# %% [markdown]
# #### `currency(name, [convert="USD"])`
# Get metadata from a currency passed as first argument.

# %%
cmc.currency("BTC")
# Out:
# {'announcement': None,
#  'chats': [],
#  'circulating_supply': 16935025.0,
#  'explorers': ['http://blockchain.info',
#   'https://live.blockcypher.com/btc/',
#   'https://blockchair.com/bitcoin/blocks'],
#  'markets_cap': 141712966601.0,
#  'markets_volume_24h': 5182320000.0,
#  'max_supply': 21000000.0,
#  'message_boards': ['https://bitcointalk.org', 'https://forum.bitcoin.com/'],
#  'mineable': True,
#  'price': 8368.04,
#  'rank': 1,
#  'slug': 'bitcoin',
#  'source_code': 'https://github.com/bitcoin/',
#  'symbol': 'BTC',
#  'webs': ['https://bitcoin.org/', 'https://bitcoin.com/']}

# %%
show_page("currencies/bitcoin")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/currencies/bitcoin"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `markets(name, [convert="USD"])`
# Get all markets for a exchange in coinmarketcap. Pass a currency symbol or slug as first parameter. You can convert the response fields `"volume_24h"` and `"price"` between `"USD"` and `"BTC"` with `convert` parameter.

# %%
cmc.markets("BTC", convert="BTC")
# Out:
# {'markets': [{'pair': 'BTC/USD',
#    'percent_volume': 7.68009308572,
#    'price': 0.997321,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 47708.4},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 6.84560196977,
#    'price': 0.995703,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 42524.5},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 6.31093795829,
#    'price': 0.998532,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 39203.2},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 3.70444125411,
#    'price': 1.00454,
#    'source': 'bitFlyer',
#    'updated': True,
#    'volume_24h': 23011.9},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 2.70699223514,
#    'price': 0.998988,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 16815.7},
#   {'pair': 'BTC/USD',
#    'percent_volume': 2.48072291946,
#    'price': 0.995807,
#    'source': 'GDAX',
#    'updated': True,
#    'volume_24h': 15410.1},
#   {'pair': 'ICX/BTC',
#    'percent_volume': 2.45422899396,
#    'price': 0.997596,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 15245.5},
#   {'pair': 'BTC/USD',
#    'percent_volume': 2.30514518594,
#    'price': 0.995757,
#    'source': 'Bitstamp',
#    'updated': True,
#    'volume_24h': 14319.4},
#   {'pair': 'BTC/KRW',
#    'percent_volume': 2.13832800753,
#    'price': 1.03128,
#    'source': 'Bithumb',
#    'updated': True,
#    'volume_24h': 13283.1},
#   {'pair': 'BTC/KRW',
#    'percent_volume': 1.97699100017,
#    'price': 1.03305,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 12281.0},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 1.5681162105,
#    'price': 0.999978,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 9741.06},
#   {'pair': 'BTC/USD',
#    'percent_volume': 1.55639559116,
#    'price': 0.997902,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 9668.25},
#   {'pair': 'BTC/USD',
#    'percent_volume': 1.52502933049,
#    'price': 1.06563,
#    'source': 'BTCC',
#    'updated': True,
#    'volume_24h': 9473.41},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 1.47908272743,
#    'price': 0.997193,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 9187.98},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 1.36343182204,
#    'price': 1.0051,
#    'source': 'BTCBOX',
#    'updated': True,
#    'volume_24h': 8469.58},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 1.33922644684,
#    'price': 0.997145,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 8319.21},
#   {'pair': 'BTC/USD',
#    'percent_volume': 1.1579138301,
#    'price': 0.997652,
#    'source': 'Gemini',
#    'updated': True,
#    'volume_24h': 7192.9},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 1.09478380339,
#    'price': 0.998616,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 6800.74},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 1.0690327884,
#    'price': 0.99817,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 6640.78},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.964591148366,
#    'price': 0.996971,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 5991.99},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.927605782738,
#    'price': 1.00085,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 5762.24},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.919696197842,
#    'price': 1.02709,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 5713.11},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.846281202241,
#    'price': 0.998938,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 5257.06},
#   {'pair': 'XVG/BTC',
#    'percent_volume': 0.823822149153,
#    'price': 1.00352,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 5117.54},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.767270257336,
#    'price': 0.997564,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 4766.24},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.744705074175,
#    'price': 1.00801,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 4626.07},
#   {'pair': 'VEN/BTC',
#    'percent_volume': 0.699512959447,
#    'price': 0.99372,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 4345.34},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.658282390898,
#    'price': 1.01049,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 4089.22},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.647596057364,
#    'price': 0.997517,
#    'source': 'CoinBene',
#    'updated': True,
#    'volume_24h': 4022.84},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.633521280044,
#    'price': 1.00021,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 3935.41},
#   {'pair': 'BNB/BTC',
#    'percent_volume': 0.620766374905,
#    'price': 0.998226,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 3856.18},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.613362355084,
#    'price': 1.00029,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 3810.17},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.54008436376,
#    'price': 0.997902,
#    'source': 'itBit',
#    'updated': True,
#    'volume_24h': 3354.98},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.538799225058,
#    'price': 0.999868,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 3346.99},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.537037465845,
#    'price': 0.998532,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 3336.05},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.486625681162,
#    'price': 0.995489,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 3022.9},
#   {'pair': 'NANO/BTC',
#    'percent_volume': 0.48556631007,
#    'price': 1.00397,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 3016.31},
#   {'pair': 'ADA/BTC',
#    'percent_volume': 0.474694731317,
#    'price': 1.0148,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 2948.78},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.452760539681,
#    'price': 0.999907,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 2812.53},
#   {'pair': 'BTC/KRW',
#    'percent_volume': 0.398275289832,
#    'price': 1.03338,
#    'source': 'Coinone',
#    'updated': True,
#    'volume_24h': 2474.07},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.39152348755,
#    'price': 0.999821,
#    'source': 'GDAX',
#    'updated': True,
#    'volume_24h': 2432.13},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.378386514148,
#    'price': 1.01001,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 2350.51},
#   {'pair': 'ABT/BTC',
#    'percent_volume': 0.372142206579,
#    'price': 1.00101,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 2311.73},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.369211086926,
#    'price': 0.996971,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 2293.52},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.358092514549,
#    'price': 1.00644,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 2224.45},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.356485126353,
#    'price': 0.999502,
#    'source': 'Bitstamp',
#    'updated': True,
#    'volume_24h': 2214.46},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.347892449714,
#    'price': 0.998447,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 2161.09},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.334502693774,
#    'price': 0.997704,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 2077.91},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.315823800923,
#    'price': 0.996106,
#    'source': 'EXX',
#    'updated': True,
#    'volume_24h': 1961.88},
#   {'pair': 'XLM/BTC',
#    'percent_volume': 0.314750922367,
#    'price': 1.00246,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1955.22},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.30829628429,
#    'price': 0.998136,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 1915.12},
#   {'pair': 'HT/BTC',
#    'percent_volume': 0.303726902237,
#    'price': 0.995987,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 1886.74},
#   {'pair': 'DGD/BTC',
#    'percent_volume': 0.29318529153,
#    'price': 0.996467,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1821.25},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.284592614891,
#    'price': 1.00703,
#    'source': 'Bitbank',
#    'updated': True,
#    'volume_24h': 1767.87},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.280854906683,
#    'price': 1.00012,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1744.66},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.279724138996,
#    'price': 0.984928,
#    'source': 'CoinsBank',
#    'updated': True,
#    'volume_24h': 1737.64},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.273055311135,
#    'price': 0.99817,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 1696.21},
#   {'pair': 'STORM/BTC',
#    'percent_volume': 0.271889809969,
#    'price': 0.925967,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1688.97},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.269466185029,
#    'price': 0.984295,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 1673.91},
#   {'pair': 'EKT/BTC',
#    'percent_volume': 0.267139041973,
#    'price': 0.998502,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 1659.46},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.265568316893,
#    'price': 1.00399,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 1649.7},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.26233617376,
#    'price': 1.00044,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 1629.63},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.246499637228,
#    'price': 0.995972,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 1531.25},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.242829466339,
#    'price': 0.997917,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1508.45},
#   {'pair': 'BTC/KRW',
#    'percent_volume': 0.236643047901,
#    'price': 1.04065,
#    'source': 'Korbit',
#    'updated': True,
#    'volume_24h': 1470.02},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.235458250359,
#    'price': 0.996999,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 1462.66},
#   {'pair': 'NCASH/BTC',
#    'percent_volume': 0.230919742509,
#    'price': 0.999663,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1434.46},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.221539773692,
#    'price': 0.996779,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 1376.19},
#   {'pair': 'CTR/BTC',
#    'percent_volume': 0.219365072014,
#    'price': 0.987682,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1362.68},
#   {'pair': 'IOTA/BTC',
#    'percent_volume': 0.218367449328,
#    'price': 1.00107,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1356.49},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.217093888452,
#    'price': 0.996674,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 1348.58},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.216763920406,
#    'price': 0.982577,
#    'source': 'CoinsBank',
#    'updated': True,
#    'volume_24h': 1346.53},
#   {'pair': 'XVG/BTC',
#    'percent_volume': 0.215970839315,
#    'price': 0.998754,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 1341.6},
#   {'pair': 'IOST/BTC',
#    'percent_volume': 0.214766745396,
#    'price': 0.997697,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1334.12},
#   {'pair': 'AION/BTC',
#    'percent_volume': 0.204543524908,
#    'price': 0.992854,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1270.62},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.198831797342,
#    'price': 1.02619,
#    'source': 'Exmo',
#    'updated': True,
#    'volume_24h': 1235.13},
#   {'pair': 'ADA/BTC',
#    'percent_volume': 0.195468438846,
#    'price': 1.0162,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 1214.24},
#   {'pair': 'NEBL/BTC',
#    'percent_volume': 0.192055681625,
#    'price': 0.996711,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1193.04},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.190404297689,
#    'price': 1.00024,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 1182.78},
#   {'pair': 'ONT/BTC',
#    'percent_volume': 0.189198467096,
#    'price': 1.00014,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 1175.29},
#   {'pair': 'XRB/BTC',
#    'percent_volume': 0.188150866793,
#    'price': 1.004,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 1168.78},
#   {'pair': 'WAVES/BTC',
#    'percent_volume': 0.185932169376,
#    'price': 0.997516,
#    'source': 'Tidex',
#    'updated': True,
#    'volume_24h': 1155.0},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.18347496874,
#    'price': 1.00399,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 1139.74},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.18298657744,
#    'price': 0.997652,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 1136.7},
#   {'pair': 'DLT/BTC',
#    'percent_volume': 0.176242300746,
#    'price': 0.998781,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1094.81},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.175581399836,
#    'price': 1.04797,
#    'source': 'Livecoin',
#    'updated': True,
#    'volume_24h': 1090.7},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.173129023295,
#    'price': 1.06967,
#    'source': 'LakeBTC',
#    'updated': True,
#    'volume_24h': 1075.47},
#   {'pair': 'VEN/BTC',
#    'percent_volume': 0.170838350391,
#    'price': 1.00696,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1061.24},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.169424697819,
#    'price': 1.00694,
#    'source': 'Livecoin',
#    'updated': True,
#    'volume_24h': 1052.46},
#   {'pair': 'ENG/BTC',
#    'percent_volume': 0.164754395715,
#    'price': 0.98936,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 1023.45},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.163997398848,
#    'price': 1.00632,
#    'source': 'CEX.IO',
#    'updated': True,
#    'volume_24h': 1018.74},
#   {'pair': 'BTC/GBP',
#    'percent_volume': 0.155483451427,
#    'price': 0.99469,
#    'source': 'CoinsBank',
#    'updated': True,
#    'volume_24h': 965.855},
#   {'pair': 'GVT/BTC',
#    'percent_volume': 0.154155281804,
#    'price': 0.997609,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 957.605},
#   {'pair': 'MTL/BTC',
#    'percent_volume': 0.149244739808,
#    'price': 0.993089,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 927.101},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.148755576653,
#    'price': 0.994117,
#    'source': 'YoBit',
#    'updated': True,
#    'volume_24h': 924.062},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.144133515491,
#    'price': 0.997358,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 895.351},
#   {'pair': 'BTC/PLN',
#    'percent_volume': 0.14324163695,
#    'price': 0.998016,
#    'source': 'BitBay',
#    'updated': True,
#    'volume_24h': 889.81},
#   {'pair': 'BTC/RUB',
#    'percent_volume': 0.142699022831,
#    'price': 0.962439,
#    'source': 'Exmo',
#    'updated': True,
#    'volume_24h': 886.439},
#   {'pair': 'MEE/BTC',
#    'percent_volume': 0.14162845984,
#    'price': 0.998058,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 879.789},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.140709952299,
#    'price': 1.00629,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 874.084},
#   {'pair': 'BTC/TRY',
#    'percent_volume': 0.140038438383,
#    'price': 1.01228,
#    'source': 'Paribu',
#    'updated': True,
#    'volume_24h': 869.912},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.139398184597,
#    'price': 0.999213,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 865.934},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.138483536331,
#    'price': 1.00689,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 860.253},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.134033791815,
#    'price': 1.03911,
#    'source': 'Trade By Trade',
#    'updated': True,
#    'volume_24h': 832.611},
#   {'pair': 'ADA/BTC',
#    'percent_volume': 0.13372890906,
#    'price': 1.01666,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 830.717},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.133167191528,
#    'price': 1.00058,
#    'source': 'EXX',
#    'updated': True,
#    'volume_24h': 827.228},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.132622261844,
#    'price': 0.995394,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 823.843},
#   {'pair': 'LINK/BTC',
#    'percent_volume': 0.131712051745,
#    'price': 0.995109,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 818.188},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.127999621791,
#    'price': 1.02645,
#    'source': 'Neraex',
#    'updated': True,
#    'volume_24h': 795.127},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.126849750691,
#    'price': 0.999046,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 787.985},
#   {'pair': 'XVG/BTC',
#    'percent_volume': 0.126612405255,
#    'price': 1.00113,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 786.51},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0,
#    'price': 1.01752,
#    'source': 'Bitinka',
#    'updated': False,
#    'volume_24h': 716.988},
#   {'pair': 'OCN/BTC',
#    'percent_volume': 0.122839770605,
#    'price': 1.00204,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 763.074},
#   {'pair': 'ELA/BTC',
#    'percent_volume': 0.121525880301,
#    'price': 1.0063,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 754.913},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.117395297859,
#    'price': 0.996436,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 729.254},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.116091634635,
#    'price': 0.99754,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 721.156},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.115903301996,
#    'price': 0.998573,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 719.985},
#   {'pair': 'HSR/BTC',
#    'percent_volume': 0.112459284645,
#    'price': 0.992888,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 698.591},
#   {'pair': 'ENJ/BTC',
#    'percent_volume': 0.112282143905,
#    'price': 1.00042,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 697.492},
#   {'pair': 'XMR/BTC',
#    'percent_volume': 0.111652889054,
#    'price': 0.996138,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 693.583},
#   {'pair': 'ELF/BTC',
#    'percent_volume': 0.110774325013,
#    'price': 1.00393,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 688.125},
#   {'pair': 'OMG/BTC',
#    'percent_volume': 0.110525787678,
#    'price': 0.996018,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 686.581},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.108495615863,
#    'price': 0.998371,
#    'source': 'EXX',
#    'updated': True,
#    'volume_24h': 673.97},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.10844679603,
#    'price': 0.99799,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 673.666},
#   {'pair': 'BQX/BTC',
#    'percent_volume': 0.1066861946,
#    'price': 1.00156,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 662.73},
#   {'pair': 'ZEC/BTC',
#    'percent_volume': 0.105335255252,
#    'price': 0.995071,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 654.338},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.104986569722,
#    'price': 0.987211,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 652.171},
#   {'pair': 'BTC/CNY',
#    'percent_volume': 0.103107874465,
#    'price': 1.04166,
#    'source': 'Fatbtc',
#    'updated': True,
#    'volume_24h': 640.501},
#   {'pair': 'NULS/BTC',
#    'percent_volume': 0.101905710184,
#    'price': 0.998822,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 633.033},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.101898956452,
#    'price': 1.00689,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 632.991},
#   {'pair': 'NOAH/BTC',
#    'percent_volume': 0.10075410241,
#    'price': 0.994754,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 625.879},
#   {'pair': 'BBN/BTC',
#    'percent_volume': 0.100002315565,
#    'price': 0.996404,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 621.209},
#   {'pair': 'ZEC/BTC',
#    'percent_volume': 0.0998548912456,
#    'price': 0.997936,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 620.293},
#   {'pair': 'WAVES/BTC',
#    'percent_volume': 0.0994942419611,
#    'price': 1.00196,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 618.053},
#   {'pair': 'XEM/BTC',
#    'percent_volume': 0.0991580990753,
#    'price': 1.01225,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 615.965},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.096518933605,
#    'price': 1.00189,
#    'source': 'Gate.io',
#    'updated': True,
#    'volume_24h': 599.571},
#   {'pair': 'EDO/BTC',
#    'percent_volume': 0.0955873045277,
#    'price': 0.998937,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 593.783},
#   {'pair': 'BTC/RUB',
#    'percent_volume': 0.0955280646506,
#    'price': 1.01494,
#    'source': 'GetBTC',
#    'updated': True,
#    'volume_24h': 593.416},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.0951815017212,
#    'price': 1.01093,
#    'source': 'GetBTC',
#    'updated': True,
#    'volume_24h': 591.263},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0950070624739,
#    'price': 1.00908,
#    'source': 'GetBTC',
#    'updated': True,
#    'volume_24h': 590.179},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0948235539295,
#    'price': 0.996092,
#    'source': 'xBTCe',
#    'updated': True,
#    'volume_24h': 589.039},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.0,
#    'price': 1.02576,
#    'source': 'Bitinka',
#    'updated': False,
#    'volume_24h': 540.822},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.0935580975316,
#    'price': 1.00521,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 581.178},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0904689405517,
#    'price': 0.999601,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 561.989},
#   {'pair': 'SALT/BTC',
#    'percent_volume': 0.0894140076259,
#    'price': 0.997547,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 555.435},
#   {'pair': 'SUB/BTC',
#    'percent_volume': 0.088731108847,
#    'price': 1.00042,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 551.193},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0886267154479,
#    'price': 0.998652,
#    'source': 'C2CX',
#    'updated': True,
#    'volume_24h': 550.544},
#   {'pair': 'STRAT/BTC',
#    'percent_volume': 0.0884578721499,
#    'price': 1.01065,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 549.496},
#   {'pair': 'XEM/BTC',
#    'percent_volume': 0.0871451396286,
#    'price': 1.0151,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 541.342},
#   {'pair': 'BTG/BTC',
#    'percent_volume': 0.085030256719,
#    'price': 0.988608,
#    'source': 'Exrates',
#    'updated': True,
#    'volume_24h': 528.204},
#   {'pair': 'SNT/BTC',
#    'percent_volume': 0.0849351255808,
#    'price': 1.01323,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 527.613},
#   {'pair': 'HPB/BTC',
#    'percent_volume': 0.0848683601167,
#    'price': 1.00479,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 527.198},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0833312107319,
#    'price': 0.999483,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 517.649},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0824983791043,
#    'price': 0.996606,
#    'source': 'Tidex',
#    'updated': True,
#    'volume_24h': 512.476},
#   {'pair': 'BTC/BRL',
#    'percent_volume': 0.0814770218744,
#    'price': 1.04484,
#    'source': 'Negocie Coins',
#    'updated': True,
#    'volume_24h': 506.132},
#   {'pair': 'BTC/ZAR',
#    'percent_volume': 0.0812190293151,
#    'price': 1.03667,
#    'source': 'Luno',
#    'updated': True,
#    'volume_24h': 504.529},
#   {'pair': 'SWFTC/BTC',
#    'percent_volume': 0.0809060420815,
#    'price': 1.00158,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 502.585},
#   {'pair': 'BCN/BTC',
#    'percent_volume': 0.079285918276,
#    'price': 1.00201,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 492.521},
#   {'pair': 'BCPT/BTC',
#    'percent_volume': 0.0789380046003,
#    'price': 1.00355,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 490.36},
#   {'pair': 'CHAT/BTC',
#    'percent_volume': 0.0758610043378,
#    'price': 1.00314,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 471.245},
#   {'pair': 'LRC/BTC',
#    'percent_volume': 0.0758189382362,
#    'price': 0.995367,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 470.983},
#   {'pair': 'ITC/BTC',
#    'percent_volume': 0.0745822334398,
#    'price': 0.99669,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 463.302},
#   {'pair': 'LSK/BTC',
#    'percent_volume': 0.074457578845,
#    'price': 0.978831,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 462.527},
#   {'pair': 'CMT/BTC',
#    'percent_volume': 0.0740245681471,
#    'price': 0.999889,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 459.837},
#   {'pair': 'LSK/BTC',
#    'percent_volume': 0.0739852035382,
#    'price': 1.01046,
#    'source': 'YoBit',
#    'updated': True,
#    'volume_24h': 459.592},
#   {'pair': 'SNC/BTC',
#    'percent_volume': 0.0736054508406,
#    'price': 0.990542,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 457.234},
#   {'pair': 'PROPY/BTC',
#    'percent_volume': 0.0733860510351,
#    'price': 0.995746,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 455.87},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0731369348091,
#    'price': 0.999213,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 454.323},
#   {'pair': 'DGD/BTC',
#    'percent_volume': 0.0730512588956,
#    'price': 0.998059,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 453.791},
#   {'pair': 'BTC/ARS',
#    'percent_volume': 0.0,
#    'price': 1.04089,
#    'source': 'Bitinka',
#    'updated': False,
#    'volume_24h': 419.361},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.0726676469226,
#    'price': 0.999301,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 451.408},
#   {'pair': 'XMR/BTC',
#    'percent_volume': 0.0722682119205,
#    'price': 0.994804,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 448.927},
#   {'pair': 'STR/BTC',
#    'percent_volume': 0.0715934176199,
#    'price': 1.00099,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 444.735},
#   {'pair': 'ZIL/BTC',
#    'percent_volume': 0.0712707821979,
#    'price': 0.997448,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 442.731},
#   {'pair': 'TDX/BTC',
#    'percent_volume': 0.0708032309854,
#    'price': 1.00138,
#    'source': 'Tidex',
#    'updated': True,
#    'volume_24h': 439.827},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.0706183716945,
#    'price': 0.998398,
#    'source': 'YoBit',
#    'updated': True,
#    'volume_24h': 438.678},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.0700915806048,
#    'price': 0.991829,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 435.406},
#   {'pair': 'DRG/BTC',
#    'percent_volume': 0.0692052980132,
#    'price': 0.991773,
#    'source': 'Qryptos',
#    'updated': True,
#    'volume_24h': 429.9},
#   {'pair': 'ICX/BTC',
#    'percent_volume': 0.0674171027648,
#    'price': 0.996079,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 418.791},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.0673321987064,
#    'price': 1.02056,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 418.265},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0672563639451,
#    'price': 0.997665,
#    'source': 'GDAX',
#    'updated': True,
#    'volume_24h': 417.793},
#   {'pair': 'BTC/CAD',
#    'percent_volume': 0.066664737029,
#    'price': 1.02189,
#    'source': 'QuadrigaCX',
#    'updated': True,
#    'volume_24h': 414.118},
#   {'pair': 'NULS/BTC',
#    'percent_volume': 0.0659650504021,
#    'price': 0.998822,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 409.771},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.0659372636194,
#    'price': 0.997641,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 409.599},
#   {'pair': 'W3C/BTC',
#    'percent_volume': 0.0655470908782,
#    'price': 1.01005,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 407.175},
#   {'pair': 'KNC/BTC',
#    'percent_volume': 0.0653994735948,
#    'price': 0.99618,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 406.259},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0647856558453,
#    'price': 0.997177,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 402.446},
#   {'pair': 'NAS/BTC',
#    'percent_volume': 0.0644101483505,
#    'price': 0.992898,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 400.112},
#   {'pair': 'BTC/IDR',
#    'percent_volume': 0.0635991216289,
#    'price': 1.03065,
#    'source': 'Bitcoin Indonesia',
#    'updated': True,
#    'volume_24h': 395.074},
#   {'pair': 'XLM/BTC',
#    'percent_volume': 0.0635279179981,
#    'price': 1.00653,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 394.632},
#   {'pair': 'TRIG/BTC',
#    'percent_volume': 0.0628220565307,
#    'price': 1.00021,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 390.247},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0626885256024,
#    'price': 0.998477,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 389.418},
#   {'pair': 'INS/BTC',
#    'percent_volume': 0.0624407601229,
#    'price': 1.0026,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 387.879},
#   {'pair': 'ZEC/BTC',
#    'percent_volume': 0.0624403741953,
#    'price': 1.00238,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 387.876},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0622423933682,
#    'price': 1.00141,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 386.647},
#   {'pair': 'TRX/BTC',
#    'percent_volume': 0.0608493879189,
#    'price': 0.994653,
#    'source': 'Liqui',
#    'updated': True,
#    'volume_24h': 377.993},
#   {'pair': 'VEN/BTC',
#    'percent_volume': 0.0586903163062,
#    'price': 1.00793,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 364.581},
#   {'pair': 'LSK/BTC',
#    'percent_volume': 0.0579346701863,
#    'price': 0.995206,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 359.887},
#   {'pair': 'MTN/BTC',
#    'percent_volume': 0.0576577671776,
#    'price': 0.999162,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 358.167},
#   {'pair': 'INS/BTC',
#    'percent_volume': 0.0573198876179,
#    'price': 0.998415,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 356.068},
#   {'pair': 'POWR/BTC',
#    'percent_volume': 0.0569438012319,
#    'price': 1.00113,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 353.732},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0568411445067,
#    'price': 0.999181,
#    'source': 'Exmo',
#    'updated': True,
#    'volume_24h': 353.095},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0567398385279,
#    'price': 0.999618,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 352.465},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.0565881690054,
#    'price': 1.00875,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 351.523},
#   {'pair': 'MCO/BTC',
#    'percent_volume': 0.0564150805045,
#    'price': 0.998888,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 350.447},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.0562495175906,
#    'price': 0.996058,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 349.419},
#   {'pair': 'RDN/BTC',
#    'percent_volume': 0.0560891646984,
#    'price': 1.00044,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 348.424},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0558745889872,
#    'price': 0.970122,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 347.09},
#   {'pair': 'MDS/BTC',
#    'percent_volume': 0.0540923756156,
#    'price': 1.00834,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 336.019},
#   {'pair': 'CPC/BTC',
#    'percent_volume': 0.0539283564118,
#    'price': 1.00161,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 335.0},
#   {'pair': 'DSH/BTC',
#    'percent_volume': 0.0539079022523,
#    'price': 1.0079,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 334.874},
#   {'pair': 'BTC/AUD',
#    'percent_volume': 0.0529776239213,
#    'price': 1.0012,
#    'source': 'BTC Markets',
#    'updated': True,
#    'volume_24h': 329.095},
#   {'pair': 'BTC/TRY',
#    'percent_volume': 0.0529199277544,
#    'price': 1.01149,
#    'source': 'BTCTurk',
#    'updated': True,
#    'volume_24h': 328.736},
#   {'pair': 'AST/BTC',
#    'percent_volume': 0.0519996835394,
#    'price': 1.00484,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 323.019},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.0517113956683,
#    'price': 0.99744,
#    'source': 'ZB.COM',
#    'updated': True,
#    'volume_24h': 321.228},
#   {'pair': 'IOTA/BTC',
#    'percent_volume': 0.051271245311,
#    'price': 1.00326,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 318.494},
#   {'pair': 'XEM/BTC',
#    'percent_volume': 0.0507110714892,
#    'price': 1.0151,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 315.014},
#   {'pair': 'BTC/RUR',
#    'percent_volume': 0.0504569382053,
#    'price': 0.992713,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 313.436},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0504285725312,
#    'price': 1.0049,
#    'source': 'Kucoin',
#    'updated': True,
#    'volume_24h': 313.26},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.0497107473101,
#    'price': 1.00883,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 308.8},
#   {'pair': 'BTG/BTC',
#    'percent_volume': 0.0488628645086,
#    'price': 1.0587,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 303.534},
#   {'pair': 'BTC/AUD',
#    'percent_volume': 0.0481803516572,
#    'price': 1.01878,
#    'source': 'ACX',
#    'updated': True,
#    'volume_24h': 299.294},
#   {'pair': 'STORJ/BTC',
#    'percent_volume': 0.0480834838451,
#    'price': 1.00247,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 298.692},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.0480740286204,
#    'price': 0.964334,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 298.634},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.0479078868152,
#    'price': 1.02612,
#    'source': 'Exmo',
#    'updated': True,
#    'volume_24h': 297.601},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0476421757051,
#    'price': 1.00012,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 295.95},
#   {'pair': 'MCO/BTC',
#    'percent_volume': 0.0476379305022,
#    'price': 0.998888,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 295.924},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0474358974359,
#    'price': 0.998801,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 294.669},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0470032726655,
#    'price': 1.00193,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 291.983},
#   {'pair': 'ONT/BTC',
#    'percent_volume': 0.0466273792433,
#    'price': 0.998257,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 289.647},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0461984207845,
#    'price': 0.99631,
#    'source': 'BtcTrade.im',
#    'updated': True,
#    'volume_24h': 286.982},
#   {'pair': 'RCN/BTC',
#    'percent_volume': 0.0458738557248,
#    'price': 1.00463,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 284.966},
#   {'pair': 'XEM/BTC',
#    'percent_volume': 0.0457169761806,
#    'price': 1.0069,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 283.992},
#   {'pair': 'VIB/BTC',
#    'percent_volume': 0.0454582117662,
#    'price': 1.00347,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 282.384},
#   {'pair': 'BTC/MXN',
#    'percent_volume': 0.0453146467219,
#    'price': 0.996787,
#    'source': 'Bitso',
#    'updated': True,
#    'volume_24h': 281.492},
#   {'pair': 'ZRX/BTC',
#    'percent_volume': 0.0450570400902,
#    'price': 0.998966,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 279.892},
#   {'pair': 'MTL/BTC',
#    'percent_volume': 0.0449186850677,
#    'price': 1.00448,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 279.032},
#   {'pair': 'LSK/BTC',
#    'percent_volume': 0.0447297735377,
#    'price': 0.995816,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 277.859},
#   {'pair': 'EOS/BTC',
#    'percent_volume': 0.0445862084935,
#    'price': 0.99744,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 276.968},
#   {'pair': 'ICX/BTC',
#    'percent_volume': 0.0445723151021,
#    'price': 0.988266,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 276.881},
#   {'pair': 'NBT/BTC',
#    'percent_volume': 0.0444466956884,
#    'price': 0.998387,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 276.1},
#   {'pair': 'IOST/BTC',
#    'percent_volume': 0.0444005773476,
#    'price': 1.00102,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 275.815},
#   {'pair': 'BTM/BTC',
#    'percent_volume': 0.0442828694484,
#    'price': 0.991688,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 275.083},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.0441292702882,
#    'price': 0.991576,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 274.129},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0437313789963,
#    'price': 1.00021,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 271.657},
#   {'pair': 'DTA/BTC',
#    'percent_volume': 0.0437076444527,
#    'price': 0.993105,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 271.51},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.0434897883573,
#    'price': 1.01419,
#    'source': 'WEX',
#    'updated': True,
#    'volume_24h': 270.157},
#   {'pair': 'BTC/BRL',
#    'percent_volume': 0.0,
#    'price': 1.04802,
#    'source': 'Bitinka',
#    'updated': False,
#    'volume_24h': 250.013},
#   {'pair': 'THETA/BTC',
#    'percent_volume': 0.0424817456274,
#    'price': 0.99738,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 263.894},
#   {'pair': 'WTC/BTC',
#    'percent_volume': 0.0423678970037,
#    'price': 0.989597,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 263.188},
#   {'pair': 'WABI/BTC',
#    'percent_volume': 0.0419460782044,
#    'price': 1.00228,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 260.567},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.0418175643341,
#    'price': 1.01529,
#    'source': 'RightBTC',
#    'updated': True,
#    'volume_24h': 259.769},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0417961453557,
#    'price': 0.994166,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 259.635},
#   {'pair': 'BTC/GBP',
#    'percent_volume': 0.041404814832,
#    'price': 1.00227,
#    'source': 'GDAX',
#    'updated': True,
#    'volume_24h': 257.204},
#   {'pair': 'MTX/BTC',
#    'percent_volume': 0.041144892635,
#    'price': 1.00658,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 255.591},
#   {'pair': 'ZIL/BTC',
#    'percent_volume': 0.0410773553158,
#    'price': 1.00073,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 255.17},
#   {'pair': 'XLM/BTC',
#    'percent_volume': 0.0410584448664,
#    'price': 1.00913,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 255.053},
#   {'pair': 'REQ/BTC',
#    'percent_volume': 0.040988591982,
#    'price': 0.991951,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 254.619},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.0409812593587,
#    'price': 0.999472,
#    'source': 'YoBit',
#    'updated': True,
#    'volume_24h': 254.574},
#   {'pair': 'BCC/BTC',
#    'percent_volume': 0.0409407369672,
#    'price': 1.00101,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 254.322},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0406756047485,
#    'price': 0.999618,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 252.675},
#   {'pair': 'HSR/BTC',
#    'percent_volume': 0.0404967273345,
#    'price': 0.990362,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 251.564},
#   {'pair': 'XMR/BTC',
#    'percent_volume': 0.0399477454113,
#    'price': 0.995542,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 248.153},
#   {'pair': 'XMR/BTC',
#    'percent_volume': 0.0399251686503,
#    'price': 0.999393,
#    'source': 'Livecoin',
#    'updated': True,
#    'volume_24h': 248.014},
#   {'pair': 'ELF/BTC',
#    'percent_volume': 0.0398414223745,
#    'price': 0.999138,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 247.493},
#   {'pair': 'RCN/BTC',
#    'percent_volume': 0.0397329767363,
#    'price': 0.997475,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 246.82},
#   {'pair': 'TUSD/BTC',
#    'percent_volume': 0.0394416014449,
#    'price': 0.995402,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 245.009},
#   {'pair': 'RUFF/BTC',
#    'percent_volume': 0.0392555843715,
#    'price': 0.995797,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 243.853},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0392310779728,
#    'price': 0.99742,
#    'source': 'Livecoin',
#    'updated': True,
#    'volume_24h': 243.702},
#   {'pair': 'AIDOC/BTC',
#    'percent_volume': 0.0386423455132,
#    'price': 0.994785,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 240.045},
#   {'pair': 'NBT/BTC',
#    'percent_volume': 0.0386290310131,
#    'price': 0.998387,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 239.962},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0381933188225,
#    'price': 0.994908,
#    'source': 'bitFlyer',
#    'updated': True,
#    'volume_24h': 237.255},
#   {'pair': 'BTC/GBP',
#    'percent_volume': 0.0381852143442,
#    'price': 1.00277,
#    'source': 'Coinfloor',
#    'updated': True,
#    'volume_24h': 237.204},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.0380462804304,
#    'price': 0.996395,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 236.341},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0380001620896,
#    'price': 0.995394,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 236.055},
#   {'pair': 'SNT/BTC',
#    'percent_volume': 0.0374980703623,
#    'price': 1.01069,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 232.936},
#   {'pair': 'BTC/PEN',
#    'percent_volume': 0.0,
#    'price': 0.975928,
#    'source': 'Bitinka',
#    'updated': False,
#    'volume_24h': 214.401},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0372072739622,
#    'price': 0.998809,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 231.129},
#   {'pair': 'OST/BTC',
#    'percent_volume': 0.0363605489433,
#    'price': 1.00388,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 225.87},
#   {'pair': 'GAS/BTC',
#    'percent_volume': 0.0360593324997,
#    'price': 1.00045,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 223.998},
#   {'pair': 'CAT/BTC',
#    'percent_volume': 0.0359271523179,
#    'price': 0.942421,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 223.178},
#   {'pair': 'VIBE/BTC',
#    'percent_volume': 0.0358684913321,
#    'price': 0.995173,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 222.813},
#   {'pair': 'TNB/BTC',
#    'percent_volume': 0.0357544497445,
#    'price': 0.996397,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 222.105},
#   {'pair': 'LRC/BTC',
#    'percent_volume': 0.0357430648821,
#    'price': 1.00177,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 222.034},
#   {'pair': 'QSP/BTC',
#    'percent_volume': 0.0355711341638,
#    'price': 0.996997,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 220.967},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.0354022908659,
#    'price': 0.993528,
#    'source': 'DSX',
#    'updated': True,
#    'volume_24h': 219.917},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0353866608006,
#    'price': 0.996608,
#    'source': 'Kucoin',
#    'updated': True,
#    'volume_24h': 219.82},
#   {'pair': 'PAY/BTC',
#    'percent_volume': 0.0350831287917,
#    'price': 0.993224,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 217.935},
#   {'pair': 'ORME/BTC',
#    'percent_volume': 0.035010188487,
#    'price': 1.01671,
#    'source': 'Cryptopia',
#    'updated': True,
#    'volume_24h': 217.482},
#   {'pair': 'BTC/THB',
#    'percent_volume': 0.0349812439216,
#    'price': 1.0174,
#    'source': 'BX Thailand',
#    'updated': True,
#    'volume_24h': 217.302},
#   {'pair': 'ACT/BTC',
#    'percent_volume': 0.0344559965421,
#    'price': 1.00124,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 214.039},
#   {'pair': 'NEO/BTC',
#    'percent_volume': 0.0341586393739,
#    'price': 0.997393,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 212.192},
#   {'pair': 'BTM/BTC',
#    'percent_volume': 0.0341491841492,
#    'price': 1.00404,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 212.133},
#   {'pair': 'LRC/BTC',
#    'percent_volume': 0.0340664026922,
#    'price': 1.00177,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 211.618},
#   {'pair': 'BTM/BTC',
#    'percent_volume': 0.0338553003288,
#    'price': 0.990643,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 210.308},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0337547662051,
#    'price': 0.994511,
#    'source': 'BtcTrade.im',
#    'updated': True,
#    'volume_24h': 209.683},
#   {'pair': 'XLM/BTC',
#    'percent_volume': 0.0337343120456,
#    'price': 1.0032,
#    'source': 'Kraken',
#    'updated': True,
#    'volume_24h': 209.555},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0337121212121,
#    'price': 1.00398,
#    'source': 'RightBTC',
#    'updated': True,
#    'volume_24h': 209.419},
#   {'pair': 'TNT/BTC',
#    'percent_volume': 0.03364033869,
#    'price': 1.0055,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 208.972},
#   {'pair': 'MIOTA/BTC',
#    'percent_volume': 0.0336399527625,
#    'price': 1.00014,
#    'source': 'Bitfinex',
#    'updated': True,
#    'volume_24h': 208.97},
#   {'pair': 'HSR/BTC',
#    'percent_volume': 0.0335830284506,
#    'price': 0.994062,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 208.616},
#   {'pair': 'XDN/BTC',
#    'percent_volume': 0.0332715849272,
#    'price': 0.995417,
#    'source': 'HitBTC',
#    'updated': True,
#    'volume_24h': 206.682},
#   {'pair': 'BTC/CAD',
#    'percent_volume': 0.0332160113617,
#    'price': 0.99135,
#    'source': 'Coinsquare',
#    'updated': True,
#    'volume_24h': 206.336},
#   {'pair': 'LSK/BTC',
#    'percent_volume': 0.0331046712669,
#    'price': 0.995206,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 205.645},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0324696275027,
#    'price': 1.00345,
#    'source': 'TOPBTC',
#    'updated': True,
#    'volume_24h': 201.7},
#   {'pair': 'SC/BTC',
#    'percent_volume': 0.032275505951,
#    'price': 0.999893,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 200.494},
#   {'pair': 'WPR/BTC',
#    'percent_volume': 0.0322706818568,
#    'price': 0.996337,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 200.463},
#   {'pair': 'ETN/BTC',
#    'percent_volume': 0.0322442458204,
#    'price': 1.00159,
#    'source': 'Kucoin',
#    'updated': True,
#    'volume_24h': 200.3},
#   {'pair': 'LDC/BTC',
#    'percent_volume': 0.0321558684141,
#    'price': 1.12848,
#    'source': 'Qryptos',
#    'updated': True,
#    'volume_24h': 199.751},
#   {'pair': 'BTC/CLP',
#    'percent_volume': 0.0,
#    'price': 1.0303,
#    'source': 'Bitinka',
#    'updated': False,
#    'volume_24h': 184.561},
#   {'pair': 'ENG/BTC',
#    'percent_volume': 0.0320352660584,
#    'price': 0.99789,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 199.001},
#   {'pair': 'ADT/BTC',
#    'percent_volume': 0.0316061146359,
#    'price': 1.00865,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 196.336},
#   {'pair': 'QBT/BTC',
#    'percent_volume': 0.0314596551352,
#    'price': 1.19716,
#    'source': 'CoinEgg',
#    'updated': True,
#    'volume_24h': 195.426},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.0311026721623,
#    'price': 0.998276,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 193.208},
#   {'pair': 'LET/BTC',
#    'percent_volume': 0.0304319301008,
#    'price': 0.994921,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 189.042},
#   {'pair': 'BLZ/BTC',
#    'percent_volume': 0.0302744716652,
#    'price': 0.997871,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 188.064},
#   {'pair': 'C20/BTC',
#    'percent_volume': 0.0300826656787,
#    'price': 0.998053,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 186.872},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.0299981475478,
#    'price': 0.996436,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 186.347},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0298933682212,
#    'price': 0.997827,
#    'source': 'Bitstamp',
#    'updated': True,
#    'volume_24h': 185.697},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0298927893299,
#    'price': 0.999213,
#    'source': 'Bitstamp',
#    'updated': True,
#    'volume_24h': 185.692},
#   {'pair': 'UP/BTC',
#    'percent_volume': 0.0298480217354,
#    'price': 1.01335,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 185.414},
#   {'pair': 'WICC/BTC',
#    'percent_volume': 0.0297853085105,
#    'price': 1.01332,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 185.025},
#   {'pair': 'GNT/BTC',
#    'percent_volume': 0.0297156485898,
#    'price': 0.999792,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 184.592},
#   {'pair': 'GNX/BTC',
#    'percent_volume': 0.0294175195665,
#    'price': 0.997059,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 182.74},
#   {'pair': 'QASH/BTC',
#    'percent_volume': 0.029305986508,
#    'price': 0.9974,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 182.047},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0292965312833,
#    'price': 1.01135,
#    'source': 'Exrates',
#    'updated': True,
#    'volume_24h': 181.989},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0292729897035,
#    'price': 0.997949,
#    'source': 'GDAX',
#    'updated': True,
#    'volume_24h': 181.842},
#   {'pair': 'BTX/BTC',
#    'percent_volume': 0.0291033745504,
#    'price': 0.986053,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 180.789},
#   {'pair': 'OC/BTC',
#    'percent_volume': 0.0290099800861,
#    'price': 1.06807,
#    'source': 'Allcoin',
#    'updated': True,
#    'volume_24h': 180.208},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0289854736875,
#    'price': 0.997156,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 180.056},
#   {'pair': 'MANA/BTC',
#    'percent_volume': 0.028917357477,
#    'price': 1.00068,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 179.633},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0288862903101,
#    'price': 1.00217,
#    'source': 'YoBit',
#    'updated': True,
#    'volume_24h': 179.44},
#   {'pair': 'SPF/BTC',
#    'percent_volume': 0.0287552679109,
#    'price': 0.992306,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 178.627},
#   {'pair': 'OC/BTC',
#    'percent_volume': 0.0286533830408,
#    'price': 1.00025,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 177.993},
#   {'pair': 'ZEC/BTC',
#    'percent_volume': 0.028491100511,
#    'price': 0.996567,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 176.985},
#   {'pair': 'SRN/BTC',
#    'percent_volume': 0.0284739267355,
#    'price': 0.999465,
#    'source': 'Liqui',
#    'updated': True,
#    'volume_24h': 176.879},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0284148798222,
#    'price': 1.04402,
#    'source': 'BtcTrade.im',
#    'updated': True,
#    'volume_24h': 176.512},
#   {'pair': 'BTC/PLN',
#    'percent_volume': 0.0283174331188,
#    'price': 1.00307,
#    'source': 'BitMarket',
#    'updated': True,
#    'volume_24h': 175.906},
#   {'pair': 'CVC/BTC',
#    'percent_volume': 0.0283083638216,
#    'price': 1.00451,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 175.85},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.0282765247997,
#    'price': 1.07609,
#    'source': 'LakeBTC',
#    'updated': True,
#    'volume_24h': 175.652},
#   {'pair': 'AWR/BTC',
#    'percent_volume': 0.0282250034733,
#    'price': 1.01054,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 175.332},
#   {'pair': 'SLS/BTC',
#    'percent_volume': 0.0281291004801,
#    'price': 1.00069,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 174.736},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0281053659365,
#    'price': 0.990241,
#    'source': 'Octaex',
#    'updated': True,
#    'volume_24h': 174.589},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0280411090014,
#    'price': 1.00057,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 174.19},
#   {'pair': 'QUN/BTC',
#    'percent_volume': 0.0277420151592,
#    'price': 0.997237,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 172.333},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0276775652603,
#    'price': 1.0028,
#    'source': 'DSX',
#    'updated': True,
#    'volume_24h': 171.932},
#   {'pair': 'LSK/BTC',
#    'percent_volume': 0.0276752496951,
#    'price': 0.999341,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 171.917},
#   {'pair': 'SALT/BTC',
#    'percent_volume': 0.0274616388027,
#    'price': 0.994575,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 170.59},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0273771206718,
#    'price': 0.995552,
#    'source': 'ooobtc',
#    'updated': True,
#    'volume_24h': 170.066},
#   {'pair': 'BTC/BRL',
#    'percent_volume': 0.0273705599037,
#    'price': 1.02135,
#    'source': 'BitcoinTrade',
#    'updated': True,
#    'volume_24h': 170.025},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.027237414903,
#    'price': 1.00713,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 169.198},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0271608082866,
#    'price': 1.00202,
#    'source': 'RightBTC',
#    'updated': True,
#    'volume_24h': 168.722},
#   {'pair': 'XEM/BTC',
#    'percent_volume': 0.0270606600905,
#    'price': 1.01051,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 168.099},
#   {'pair': 'MCO/BTC',
#    'percent_volume': 0.0269863690393,
#    'price': 0.997495,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 167.638},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.026879660075,
#    'price': 0.998676,
#    'source': 'Bibox',
#    'updated': True,
#    'volume_24h': 166.975},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.0268777304373,
#    'price': 0.980878,
#    'source': 'Trade By Trade',
#    'updated': True,
#    'volume_24h': 166.964},
#   {'pair': 'BCH/BTC',
#    'percent_volume': 0.0268242794733,
#    'price': 1.0105,
#    'source': 'Trade By Trade',
#    'updated': True,
#    'volume_24h': 166.632},
#   {'pair': 'ATB/BTC',
#    'percent_volume': 0.0268225427994,
#    'price': 0.973474,
#    'source': 'TOPBTC',
#    'updated': True,
#    'volume_24h': 166.62},
#   {'pair': 'SNC/BTC',
#    'percent_volume': 0.0266307368129,
#    'price': 1.00641,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 165.428},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.0264260022538,
#    'price': 1.00848,
#    'source': 'Poloniex',
#    'updated': True,
#    'volume_24h': 164.157},
#   {'pair': 'POE/BTC',
#    'percent_volume': 0.0263866376449,
#    'price': 0.995262,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 163.913},
#   {'pair': 'NKC/BTC',
#    'percent_volume': 0.0260888945492,
#    'price': 1.01852,
#    'source': 'Bit-Z',
#    'updated': True,
#    'volume_24h': 162.063},
#   {'pair': 'STK/BTC',
#    'percent_volume': 0.0259924126646,
#    'price': 0.99745,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 161.463},
#   {'pair': 'LTC/BTC',
#    'percent_volume': 0.0257336482502,
#    'price': 1.03578,
#    'source': 'Trade By Trade',
#    'updated': True,
#    'volume_24h': 159.856},
#   {'pair': 'OMG/BTC',
#    'percent_volume': 0.0257232282067,
#    'price': 0.997195,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 159.791},
#   {'pair': 'ZLA/BTC',
#    'percent_volume': 0.0255889254234,
#    'price': 0.999456,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 158.957},
#   {'pair': 'BTC/EUR',
#    'percent_volume': 0.0255312292564,
#    'price': 1.00044,
#    'source': 'BL3P',
#    'updated': True,
#    'volume_24h': 158.598},
#   {'pair': 'APPC/BTC',
#    'percent_volume': 0.0255289136912,
#    'price': 0.99661,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 158.585},
#   {'pair': 'UP/BTC',
#    'percent_volume': 0.0255287207274,
#    'price': 1.01335,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 158.583},
#   {'pair': 'ITC/BTC',
#    'percent_volume': 0.0254660075024,
#    'price': 1.0028,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 158.193},
#   {'pair': 'AIDOC/BTC',
#    'percent_volume': 0.0254582889517,
#    'price': 0.994034,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 158.146},
#   {'pair': 'DASH/BTC',
#    'percent_volume': 0.0253963475818,
#    'price': 1.00262,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 157.761},
#   {'pair': 'SMT/BTC',
#    'percent_volume': 0.0252302057766,
#    'price': 1.00349,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 156.728},
#   {'pair': 'ETC/BTC',
#    'percent_volume': 0.0251530202689,
#    'price': 0.991642,
#    'source': 'Lbank',
#    'updated': True,
#    'volume_24h': 156.25},
#   {'pair': 'SC/BTC',
#    'percent_volume': 0.0251508976675,
#    'price': 0.999893,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 156.236},
#   {'pair': 'R/BTC',
#    'percent_volume': 0.0251128838049,
#    'price': 0.998811,
#    'source': 'OKEx',
#    'updated': True,
#    'volume_24h': 156.0},
#   {'pair': 'ETH/BTC',
#    'percent_volume': 0.0250808518193,
#    'price': 0.997876,
#    'source': 'ZB.COM',
#    'updated': True,
#    'volume_24h': 155.801},
#   {'pair': 'XRP/BTC',
#    'percent_volume': 0.0250742910511,
#    'price': 0.999618,
#    'source': 'Upbit',
#    'updated': True,
#    'volume_24h': 155.76},
#   {'pair': 'VTC/BTC',
#    'percent_volume': 0.0249760724926,
#    'price': 0.997119,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 155.15},
#   {'pair': 'QTUM/BTC',
#    'percent_volume': 0.0249401812316,
#    'price': 1.00769,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 154.927},
#   {'pair': 'ADT/BTC',
#    'percent_volume': 0.0248234381513,
#    'price': 1.00865,
#    'source': 'Bittrex',
#    'updated': True,
#    'volume_24h': 154.201},
#   {'pair': 'ACT/BTC',
#    'percent_volume': 0.0247817579771,
#    'price': 1.00475,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 153.944},
#   {'pair': 'SOC/BTC',
#    'percent_volume': 0.0244712792726,
#    'price': 0.995871,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 152.014},
#   {'pair': 'ZEC/BTC',
#    'percent_volume': 0.0244261257506,
#    'price': 0.995712,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 151.734},
#   {'pair': 'HSR/BTC',
#    'percent_volume': 0.0242231278655,
#    'price': 1.00035,
#    'source': 'Allcoin',
#    'updated': True,
#    'volume_24h': 150.473},
#   {'pair': 'VIB/BTC',
#    'percent_volume': 0.0239626267772,
#    'price': 1.00736,
#    'source': 'Binance',
#    'updated': True,
#    'volume_24h': 148.854},
#   {'pair': 'WAVES/BTC',
#    'percent_volume': 0.0239533645163,
#    'price': 0.993742,
#    'source': 'YoBit',
#    'updated': True,
#    'volume_24h': 148.797},
#   {'pair': 'BAT/BTC',
#    'percent_volume': 0.0239354188858,
#    'price': 0.99918,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 148.686},
#   {'pair': 'EKO/BTC',
#    'percent_volume': 0.0235927152318,
#    'price': 0.996636,
#    'source': 'Huobi',
#    'updated': True,
#    'volume_24h': 146.557},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0234831118109,
#    'price': 1.00344,
#    'source': 'Liqui',
#    'updated': True,
#    'volume_24h': 145.876},
#   {'pair': 'IHT/BTC',
#    'percent_volume': 0.0232820435635,
#    'price': 1.1573,
#    'source': 'OEX',
#    'updated': True,
#    'volume_24h': 144.627},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0,
#    'price': 0.997003,
#    'source': 'BitMEX',
#    'updated': True,
#    'volume_24h': 381101.0},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.0,
#    'price': 1.00647,
#    'source': 'Quoine',
#    'updated': True,
#    'volume_24h': 11948.3},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.0,
#    'price': 1.00698,
#    'source': 'Zaif',
#    'updated': True,
#    'volume_24h': 10263.0},
#   {'pair': 'BTC/JPY',
#    'percent_volume': 0.0,
#    'price': 1.00622,
#    'source': 'Fisco',
#    'updated': True,
#    'volume_24h': 10253.7},
#   {'pair': 'BTC/USDT',
#    'percent_volume': 0.0,
#    'price': 0.999465,
#    'source': 'ZB.COM',
#    'updated': True,
#    'volume_24h': 1564.43},
#   {'pair': 'BTC/KRW',
#    'percent_volume': 0.0,
#    'price': 1.03333,
#    'source': 'GOPAX',
#    'updated': True,
#    'volume_24h': 1232.38},
#   {'pair': 'BTC/USD',
#    'percent_volume': 0.0,
#    'price': 0.9992,
#    'source': 'Quoine',
#    'updated': True,
#    'volume_24h': 1160.3},
#   {'pair': 'BTC/SGD',
#    'percent_volume': 0.0,
#    'price': 0.996347,
#    'source': 'Quoine',
#    'updated': True,
#    'volume_24h': 467.113},
#   {'pair': 'B2X/BTC',
#    'percent_volume': 0.0,
#    'price': 0.000294254,
#    'source': 'Negocie Coins',
#    'updated': True,
#    'volume_24h': 1229.18}],
#  'slug': 'bitcoin',
#  'symbol': 'BTC'}

# %%
show_page("currencies/bitcoin/#markets")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/currencies/bitcoin/#markets"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `ranks()`
# Get gainers and losers rankings:

# %%
cmc.ranks()
# Out:
# {'gainers': {'1h': [{'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0},
#    {'name': 'Storm',
#     'percent_change': 11.67,
#     'price': 0.0302007,
#     'symbol': 'STORM',
#     'volume_24h': 17104500.0}],
#   '24h': [{'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': 58.5,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0}],
#   '7d': [{'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0},
#    {'name': 'High Voltage',
#     'percent_change': 388.9,
#     'price': 0.499821,
#     'symbol': 'HVCO',
#     'volume_24h': 216011.0}]},
#  'losers': {'1h': [{'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0},
#    {'name': 'Dropil',
#     'percent_change': -29.31,
#     'price': 0.00696505,
#     'symbol': 'DROP',
#     'volume_24h': 193676.0}],
#   '24h': [{'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0},
#    {'name': 'W3Coin',
#     'percent_change': -73.07,
#     'price': 0.00071786,
#     'symbol': 'W3C',
#     'volume_24h': 4014450.0}],
#   '7d': [{'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0},
#    {'name': 'Tidex Token',
#     'percent_change': -38.16,
#     'price': 0.199897,
#     'symbol': 'TDX',
#     'volume_24h': 4023200.0}]}}

# %%
show_page("gainers-losers")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/gainers-losers"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `historical(currency, [start=datetime(2008, 8, 18), end=datetime.now(), revert=False])`
# Get historical prices for a currency. You can filter by `start` and `end` datetimes provided in `datetime` objects. With parameter `revert` active, the response will be ordered in chronological order.

# %%
from datetime import datetime

cmc.historical("ETH", start=datetime(2018, 2, 1), revert=True)
# Out:
# {'history': [{'close': 1036.79,
#    'date': datetime.datetime(2018, 2, 1, 0, 0),
#    'high': 1161.35,
#    'low': 984.819,
#    'market_cap': 108952000000.0,
#    'open': 1119.37,
#    'volume': 5261680000.0},
#   {'close': 915.785,
#    'date': datetime.datetime(2018, 2, 2, 0, 0),
#    'high': 1035.77,
#    'low': 757.98,
#    'market_cap': 100836000000.0,
#    'open': 1035.77,
#    'volume': 6713290000.0},
#   {'close': 964.019,
#    'date': datetime.datetime(2018, 2, 3, 0, 0),
#    'high': 991.943,
#    'low': 847.69,
#    'market_cap': 89507600000.0,
#    'open': 919.211,
#    'volume': 3243480000.0},
#   {'close': 834.682,
#    'date': datetime.datetime(2018, 2, 4, 0, 0),
#    'high': 969.032,
#    'low': 805.064,
#    'market_cap': 93953400000.0,
#    'open': 964.667,
#    'volume': 2997090000.0},
#   {'close': 697.951,
#    'date': datetime.datetime(2018, 2, 5, 0, 0),
#    'high': 856.646,
#    'low': 644.599,
#    'market_cap': 81337400000.0,
#    'open': 834.958,
#    'volume': 4269530000.0},
#   {'close': 793.122,
#    'date': datetime.datetime(2018, 2, 6, 0, 0),
#    'high': 796.439,
#    'low': 574.419,
#    'market_cap': 68958700000.0,
#    'open': 707.737,
#    'volume': 6518270000.0},
#   {'close': 757.068,
#    'date': datetime.datetime(2018, 2, 7, 0, 0),
#    'high': 851.2,
#    'low': 723.433,
#    'market_cap': 77032000000.0,
#    'open': 790.428,
#    'volume': 3896180000.0},
#   {'close': 817.807,
#    'date': datetime.datetime(2018, 2, 8, 0, 0),
#    'high': 845.086,
#    'low': 755.843,
#    'market_cap': 73676900000.0,
#    'open': 755.843,
#    'volume': 3708190000.0},
#   {'close': 883.865,
#    'date': datetime.datetime(2018, 2, 9, 0, 0),
#    'high': 884.004,
#    'low': 788.834,
#    'market_cap': 79799300000.0,
#    'open': 818.48,
#    'volume': 2495820000.0},
#   {'close': 860.415,
#    'date': datetime.datetime(2018, 2, 10, 0, 0),
#    'high': 917.4,
#    'low': 825.577,
#    'market_cap': 86055600000.0,
#    'open': 882.467,
#    'volume': 2930530000.0},
#   {'close': 814.66,
#    'date': datetime.datetime(2018, 2, 11, 0, 0),
#    'high': 859.288,
#    'low': 788.222,
#    'market_cap': 83813000000.0,
#    'open': 859.288,
#    'volume': 2486650000.0},
#   {'close': 868.707,
#    'date': datetime.datetime(2018, 2, 12, 0, 0),
#    'high': 875.937,
#    'low': 817.508,
#    'market_cap': 79754400000.0,
#    'open': 817.508,
#    'volume': 2243450000.0},
#   {'close': 845.258,
#    'date': datetime.datetime(2018, 2, 13, 0, 0),
#    'high': 870.709,
#    'low': 828.837,
#    'market_cap': 84824200000.0,
#    'open': 869.293,
#    'volume': 2081170000.0},
#   {'close': 923.561,
#    'date': datetime.datetime(2018, 2, 14, 0, 0),
#    'high': 926.429,
#    'low': 844.279,
#    'market_cap': 82400600000.0,
#    'open': 844.279,
#    'volume': 2818370000.0},
#   {'close': 936.976,
#    'date': datetime.datetime(2018, 2, 15, 0, 0),
#    'high': 951.948,
#    'low': 911.111,
#    'market_cap': 90173300000.0,
#    'open': 923.728,
#    'volume': 2900100000.0},
#   {'close': 944.21,
#    'date': datetime.datetime(2018, 2, 16, 0, 0),
#    'high': 950.005,
#    'low': 917.848,
#    'market_cap': 91272100000.0,
#    'open': 934.786,
#    'volume': 2369450000.0},
#   {'close': 974.115,
#    'date': datetime.datetime(2018, 2, 17, 0, 0),
#    'high': 976.595,
#    'low': 940.754,
#    'market_cap': 92264000000.0,
#    'open': 944.748,
#    'volume': 2525720000.0},
#   {'close': 923.921,
#    'date': datetime.datetime(2018, 2, 18, 0, 0),
#    'high': 982.933,
#    'low': 915.445,
#    'market_cap': 95077100000.0,
#    'open': 973.349,
#    'volume': 2567290000.0},
#   {'close': 943.865,
#    'date': datetime.datetime(2018, 2, 19, 0, 0),
#    'high': 957.777,
#    'low': 921.554,
#    'market_cap': 90047700000.0,
#    'open': 921.668,
#    'volume': 2169020000.0},
#   {'close': 895.371,
#    'date': datetime.datetime(2018, 2, 20, 0, 0),
#    'high': 965.265,
#    'low': 892.954,
#    'market_cap': 92206500000.0,
#    'open': 943.567,
#    'volume': 2545260000.0},
#   {'close': 849.971,
#    'date': datetime.datetime(2018, 2, 21, 0, 0),
#    'high': 912.375,
#    'low': 830.563,
#    'market_cap': 87394200000.0,
#    'open': 894.135,
#    'volume': 2531730000.0},
#   {'close': 812.845,
#    'date': datetime.datetime(2018, 2, 22, 0, 0),
#    'high': 875.926,
#    'low': 802.668,
#    'market_cap': 83025800000.0,
#    'open': 849.262,
#    'volume': 2150370000.0},
#   {'close': 864.189,
#    'date': datetime.datetime(2018, 2, 23, 0, 0),
#    'high': 886.318,
#    'low': 794.791,
#    'market_cap': 79358900000.0,
#    'open': 811.585,
#    'volume': 2334820000.0},
#   {'close': 840.515,
#    'date': datetime.datetime(2018, 2, 24, 0, 0),
#    'high': 879.531,
#    'low': 818.55,
#    'market_cap': 84266700000.0,
#    'open': 861.593,
#    'volume': 1926580000.0},
#   {'close': 844.81,
#    'date': datetime.datetime(2018, 2, 25, 0, 0),
#    'high': 853.146,
#    'low': 822.381,
#    'market_cap': 82119100000.0,
#    'open': 839.459,
#    'volume': 1646960000.0},
#   {'close': 869.315,
#    'date': datetime.datetime(2018, 2, 26, 0, 0),
#    'high': 880.392,
#    'low': 842.319,
#    'market_cap': 82705400000.0,
#    'open': 845.278,
#    'volume': 2044480000.0},
#   {'close': 878.265,
#    'date': datetime.datetime(2018, 2, 27, 0, 0),
#    'high': 896.259,
#    'low': 867.097,
#    'market_cap': 85177800000.0,
#    'open': 870.365,
#    'volume': 2053980000.0},
#   {'close': 855.199,
#    'date': datetime.datetime(2018, 2, 28, 0, 0),
#    'high': 890.108,
#    'low': 855.124,
#    'market_cap': 85936400000.0,
#    'open': 877.934,
#    'volume': 1963980000.0},
#   {'close': 872.2,
#    'date': datetime.datetime(2018, 3, 1, 0, 0),
#    'high': 880.302,
#    'low': 851.92,
#    'market_cap': 83808200000.0,
#    'open': 856.012,
#    'volume': 1868520000.0},
#   {'close': 856.853,
#    'date': datetime.datetime(2018, 3, 2, 0, 0),
#    'high': 876.378,
#    'low': 852.422,
#    'market_cap': 85368100000.0,
#    'open': 871.764,
#    'volume': 1894420000.0},
#   {'close': 857.225,
#    'date': datetime.datetime(2018, 3, 3, 0, 0),
#    'high': 868.454,
#    'low': 855.207,
#    'market_cap': 83911700000.0,
#    'open': 856.711,
#    'volume': 1699370000.0},
#   {'close': 866.678,
#    'date': datetime.datetime(2018, 3, 4, 0, 0),
#    'high': 867.95,
#    'low': 840.28,
#    'market_cap': 83877800000.0,
#    'open': 856.186,
#    'volume': 1697940000.0},
#   {'close': 853.684,
#    'date': datetime.datetime(2018, 3, 5, 0, 0),
#    'high': 869.92,
#    'low': 853.52,
#    'market_cap': 84939700000.0,
#    'open': 866.846,
#    'volume': 1898490000.0},
#   {'close': 816.951,
#    'date': datetime.datetime(2018, 3, 6, 0, 0),
#    'high': 853.817,
#    'low': 809.931,
#    'market_cap': 83680400000.0,
#    'open': 853.817,
#    'volume': 1943070000.0},
#   {'close': 752.831,
#    'date': datetime.datetime(2018, 3, 7, 0, 0),
#    'high': 825.607,
#    'low': 726.547,
#    'market_cap': 80017300000.0,
#    'open': 816.271,
#    'volume': 2175420000.0},
#   {'close': 704.596,
#    'date': datetime.datetime(2018, 3, 8, 0, 0),
#    'high': 773.767,
#    'low': 696.169,
#    'market_cap': 73788400000.0,
#    'open': 752.57,
#    'volume': 1891640000.0},
#   {'close': 728.916,
#    'date': datetime.datetime(2018, 3, 9, 0, 0),
#    'high': 729.156,
#    'low': 648.107,
#    'market_cap': 68863600000.0,
#    'open': 702.197,
#    'volume': 2233020000.0},
#   {'close': 686.89,
#    'date': datetime.datetime(2018, 3, 10, 0, 0),
#    'high': 748.031,
#    'low': 682.695,
#    'market_cap': 71620700000.0,
#    'open': 730.16,
#    'volume': 1532960000.0},
#   {'close': 723.339,
#    'date': datetime.datetime(2018, 3, 11, 0, 0),
#    'high': 735.831,
#    'low': 668.123,
#    'market_cap': 67235700000.0,
#    'open': 685.312,
#    'volume': 1562680000.0},
#   {'close': 699.831,
#    'date': datetime.datetime(2018, 3, 12, 0, 0),
#    'high': 742.514,
#    'low': 683.268,
#    'market_cap': 71086000000.0,
#    'open': 724.406,
#    'volume': 1765000000.0},
#   {'close': 690.827,
#    'date': datetime.datetime(2018, 3, 13, 0, 0),
#    'high': 713.735,
#    'low': 682.35,
#    'market_cap': 68524000000.0,
#    'open': 698.153,
#    'volume': 1425960000.0},
#   {'close': 614.291,
#    'date': datetime.datetime(2018, 3, 14, 0, 0),
#    'high': 702.784,
#    'low': 594.1,
#    'market_cap': 67857600000.0,
#    'open': 691.219,
#    'volume': 1810560000.0},
#   {'close': 611.304,
#    'date': datetime.datetime(2018, 3, 15, 0, 0),
#    'high': 620.616,
#    'low': 579.505,
#    'market_cap': 60371800000.0,
#    'open': 614.839,
#    'volume': 1770460000.0},
#   {'close': 601.666,
#    'date': datetime.datetime(2018, 3, 16, 0, 0),
#    'high': 623.168,
#    'low': 587.862,
#    'market_cap': 60083700000.0,
#    'open': 611.778,
#    'volume': 1417350000.0},
#   {'close': 552.779,
#    'date': datetime.datetime(2018, 3, 17, 0, 0),
#    'high': 609.151,
#    'low': 549.096,
#    'market_cap': 59104200000.0,
#    'open': 601.678,
#    'volume': 1267810000.0},
#   {'close': 538.644,
#    'date': datetime.datetime(2018, 3, 18, 0, 0),
#    'high': 551.64,
#    'low': 460.088,
#    'market_cap': 54200100000.0,
#    'open': 551.64,
#    'volume': 2685500000.0},
#   {'close': 556.726,
#    'date': datetime.datetime(2018, 3, 19, 0, 0),
#    'high': 558.1,
#    'low': 519.123,
#    'market_cap': 53718600000.0,
#    'open': 546.626,
#    'volume': 2046790000.0},
#   {'close': 557.175,
#    'date': datetime.datetime(2018, 3, 20, 0, 0),
#    'high': 567.09,
#    'low': 521.204,
#    'market_cap': 54722100000.0,
#    'open': 556.722,
#    'volume': 1833680000.0},
#   {'close': 561.732,
#    'date': datetime.datetime(2018, 3, 21, 0, 0),
#    'high': 589.607,
#    'low': 550.572,
#    'market_cap': 54967300000.0,
#    'open': 559.1,
#    'volume': 1781270000.0},
#   {'close': 539.702,
#    'date': datetime.datetime(2018, 3, 22, 0, 0),
#    'high': 577.566,
#    'low': 523.089,
#    'market_cap': 55273800000.0,
#    'open': 562.103,
#    'volume': 1523460000.0}],
#  'slug': 'ethereum',
#  'symbol': 'ETH'}

# %%
show_page("currencies/ethereum/historical-data")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/currencies/ethereum/historical-data"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `recently([convert="USD"])`
# Get recently added coins in coinmarketcap along with other metadata.

# %%
list(cmc.recently())
# Out:
# []

# %%
show_page("new")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/new"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `exchange(name, [convert="USD"])`
# Get data about a exchange:

# %%
cmc.exchange("okex")
# Out:
# {'markets': [{'currency': 'Bitcoin',
#    'pair': 'BTC/USDT',
#    'percent_volume': 31.270388553,
#    'price': 8330.26,
#    'updated': True,
#    'volume_24h': 327053000.0},
#   {'currency': 'Ethereum',
#    'pair': 'ETH/USDT',
#    'percent_volume': 8.96100435087,
#    'price': 512.539,
#    'updated': True,
#    'volume_24h': 93722000.0},
#   {'currency': 'Ethereum',
#    'pair': 'ETH/BTC',
#    'percent_volume': 7.32878248754,
#    'price': 512.138,
#    'updated': True,
#    'volume_24h': 76650800.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/USDT',
#    'percent_volume': 6.60181118538,
#    'price': 157.3,
#    'updated': True,
#    'volume_24h': 69047500.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/BTC',
#    'percent_volume': 5.42460013708,
#    'price': 157.484,
#    'updated': True,
#    'volume_24h': 56735200.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/USDT',
#    'percent_volume': 5.04535274844,
#    'price': 18.1679,
#    'updated': True,
#    'volume_24h': 52768700.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/USDT',
#    'percent_volume': 4.81335832924,
#    'price': 6.62044,
#    'updated': True,
#    'volume_24h': 50342300.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/BTC',
#    'percent_volume': 4.59624123101,
#    'price': 967.854,
#    'updated': True,
#    'volume_24h': 48071500.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/USDT',
#    'percent_volume': 4.32454845916,
#    'price': 967.485,
#    'updated': True,
#    'volume_24h': 45229900.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/BTC',
#    'percent_volume': 3.80178655386,
#    'price': 18.1328,
#    'updated': True,
#    'volume_24h': 39762400.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/BTC',
#    'percent_volume': 1.72379005294,
#    'price': 6.60893,
#    'updated': True,
#    'volume_24h': 18028900.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/USDT',
#    'percent_volume': 1.3585499106,
#    'price': 0.617182,
#    'updated': True,
#    'volume_24h': 14208900.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/ETH',
#    'percent_volume': 1.04067625164,
#    'price': 18.0959,
#    'updated': True,
#    'volume_24h': 10884300.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/BTC',
#    'percent_volume': 0.690711178709,
#    'price': 0.617595,
#    'updated': True,
#    'volume_24h': 7224060.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/ETH',
#    'percent_volume': 0.663568673052,
#    'price': 0.5107,
#    'updated': True,
#    'volume_24h': 6940180.0},
#   {'currency': 'Hshare',
#    'pair': 'HSR/BTC',
#    'percent_volume': 0.557230248574,
#    'price': 6.64013,
#    'updated': True,
#    'volume_24h': 5828000.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/USDT',
#    'percent_volume': 0.473042395765,
#    'price': 63.9016,
#    'updated': True,
#    'volume_24h': 4947490.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/USDT',
#    'percent_volume': 0.438030972906,
#    'price': 17.7352,
#    'updated': True,
#    'volume_24h': 4581310.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/ETH',
#    'percent_volume': 0.406439612846,
#    'price': 6.59357,
#    'updated': True,
#    'volume_24h': 4250900.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/BTC',
#    'percent_volume': 0.400885476754,
#    'price': 0.00884305,
#    'updated': True,
#    'volume_24h': 4192810.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/USDT',
#    'percent_volume': 0.36986779231,
#    'price': 0.00120191,
#    'updated': True,
#    'volume_24h': 3868400.0},
#   {'currency': 'SunContract',
#    'pair': 'SNC/BTC',
#    'percent_volume': 0.364711404646,
#    'price': 0.18779,
#    'updated': True,
#    'volume_24h': 3814470.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/BTC',
#    'percent_volume': 0.360064632155,
#    'price': 0.0357059,
#    'updated': True,
#    'volume_24h': 3765870.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/BTC',
#    'percent_volume': 0.347300349693,
#    'price': 64.0556,
#    'updated': True,
#    'volume_24h': 3632370.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/BTC',
#    'percent_volume': 0.28401723634,
#    'price': 1.15861,
#    'updated': True,
#    'volume_24h': 2970500.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/BTC',
#    'percent_volume': 0.280391606445,
#    'price': 17.7835,
#    'updated': True,
#    'volume_24h': 2932580.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/BTC',
#    'percent_volume': 0.254046509896,
#    'price': 1.25663,
#    'updated': True,
#    'volume_24h': 2657040.0},
#   {'currency': 'Viberate',
#    'pair': 'VIB/BTC',
#    'percent_volume': 0.22524321333,
#    'price': 0.129809,
#    'updated': True,
#    'volume_24h': 2355790.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/BTC',
#    'percent_volume': 0.22085363874,
#    'price': 3.87125,
#    'updated': True,
#    'volume_24h': 2309880.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/ETH',
#    'percent_volume': 0.201500691826,
#    'price': 0.00126143,
#    'updated': True,
#    'volume_24h': 2107470.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/USDT',
#    'percent_volume': 0.195381485253,
#    'price': 0.357769,
#    'updated': True,
#    'volume_24h': 2043470.0},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/BTC',
#    'percent_volume': 0.191470929802,
#    'price': 0.0458003,
#    'updated': True,
#    'volume_24h': 2002570.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/ETH',
#    'percent_volume': 0.183291271641,
#    'price': 0.0356877,
#    'updated': True,
#    'volume_24h': 1917020.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/USDT',
#    'percent_volume': 0.182745323679,
#    'price': 1.2589,
#    'updated': True,
#    'volume_24h': 1911310.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/ETH',
#    'percent_volume': 0.173980516389,
#    'price': 0.616569,
#    'updated': True,
#    'volume_24h': 1819640.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/BTC',
#    'percent_volume': 0.167751355323,
#    'price': 0.356392,
#    'updated': True,
#    'volume_24h': 1754490.0},
#   {'currency': 'Game.com',
#    'pair': 'GTC/USDT',
#    'percent_volume': 0.142913113392,
#    'price': 0.0499795,
#    'updated': True,
#    'volume_24h': 1494710.0},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/BTC',
#    'percent_volume': 0.142480944427,
#    'price': 0.16418,
#    'updated': True,
#    'volume_24h': 1490190.0},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/BTC',
#    'percent_volume': 0.12618282017,
#    'price': 1.10897,
#    'updated': True,
#    'volume_24h': 1319730.0},
#   {'currency': 'Revain',
#    'pair': 'R/BTC',
#    'percent_volume': 0.12443310954,
#    'price': 0.94971,
#    'updated': True,
#    'volume_24h': 1301430.0},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/BTC',
#    'percent_volume': 0.111331314592,
#    'price': 0.139153,
#    'updated': True,
#    'volume_24h': 1164400.0},
#   {'currency': 'DADI',
#    'pair': 'DADI/BTC',
#    'percent_volume': 0.109333967321,
#    'price': 0.198468,
#    'updated': True,
#    'volume_24h': 1143510.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/BTC',
#    'percent_volume': 0.109261301743,
#    'price': 0.125972,
#    'updated': True,
#    'volume_24h': 1142750.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/BTC',
#    'percent_volume': 0.108734476302,
#    'price': 0.501384,
#    'updated': True,
#    'volume_24h': 1137240.0},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/USDT',
#    'percent_volume': 0.106866206045,
#    'price': 0.0185295,
#    'updated': True,
#    'volume_24h': 1117700.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/USDT',
#    'percent_volume': 0.0983633772865,
#    'price': 3.79604,
#    'updated': True,
#    'volume_24h': 1028770.0},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/ETH',
#    'percent_volume': 0.0953136220979,
#    'price': 0.0204842,
#    'updated': True,
#    'volume_24h': 996873.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/BTC',
#    'percent_volume': 0.09456612277,
#    'price': 0.00125137,
#    'updated': True,
#    'volume_24h': 989055.0},
#   {'currency': 'Loopring',
#    'pair': 'LRC/BTC',
#    'percent_volume': 0.0922759140974,
#    'price': 0.428638,
#    'updated': True,
#    'volume_24h': 965102.0},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/BTC',
#    'percent_volume': 0.0890526220349,
#    'price': 0.0189375,
#    'updated': True,
#    'volume_24h': 931390.0},
#   {'currency': 'Hshare',
#    'pair': 'HSR/USDT',
#    'percent_volume': 0.0886405317172,
#    'price': 6.61052,
#    'updated': True,
#    'volume_24h': 927080.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/USDT',
#    'percent_volume': 0.0881307253196,
#    'price': 5.82197,
#    'updated': True,
#    'volume_24h': 921748.0},
#   {'currency': 'ugChain',
#    'pair': 'UGC/BTC',
#    'percent_volume': 0.0856226155254,
#    'price': 0.0367904,
#    'updated': True,
#    'volume_24h': 895516.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/BTC',
#    'percent_volume': 0.0778242604235,
#    'price': 5.77902,
#    'updated': True,
#    'volume_24h': 813954.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/ETH',
#    'percent_volume': 0.0754094685295,
#    'price': 0.124815,
#    'updated': True,
#    'volume_24h': 788698.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/USDT',
#    'percent_volume': 0.0744668238794,
#    'price': 0.22636,
#    'updated': True,
#    'volume_24h': 778839.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/USDT',
#    'percent_volume': 0.0716984565806,
#    'price': 0.583829,
#    'updated': True,
#    'volume_24h': 749885.0},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/ETH',
#    'percent_volume': 0.0705220391169,
#    'price': 0.0459273,
#    'updated': True,
#    'volume_24h': 737581.0},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/BTC',
#    'percent_volume': 0.0696384830553,
#    'price': 0.0850935,
#    'updated': True,
#    'volume_24h': 728340.0},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/USDT',
#    'percent_volume': 0.0682777244936,
#    'price': 2.71492,
#    'updated': True,
#    'volume_24h': 714108.0},
#   {'currency': 'Loopring',
#    'pair': 'LRC/USDT',
#    'percent_volume': 0.0680580067326,
#    'price': 0.424175,
#    'updated': True,
#    'volume_24h': 711810.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/BTC',
#    'percent_volume': 0.0674622446051,
#    'price': 0.58506,
#    'updated': True,
#    'volume_24h': 705579.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/ETH',
#    'percent_volume': 0.0671696700408,
#    'price': 1.15282,
#    'updated': True,
#    'volume_24h': 702519.0},
#   {'currency': 'Revain',
#    'pair': 'R/ETH',
#    'percent_volume': 0.0663872721129,
#    'price': 0.942957,
#    'updated': True,
#    'volume_24h': 694336.0},
#   {'currency': 'Cube',
#    'pair': 'AUTO/BTC',
#    'percent_volume': 0.0661510133716,
#    'price': 0.0090099,
#    'updated': True,
#    'volume_24h': 691865.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/ETH',
#    'percent_volume': 0.0608127705373,
#    'price': 0.0360044,
#    'updated': True,
#    'volume_24h': 636033.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/BTC',
#    'percent_volume': 0.0604900780032,
#    'price': 0.0347048,
#    'updated': True,
#    'volume_24h': 632658.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/USDT',
#    'percent_volume': 0.0583084852472,
#    'price': 0.0828318,
#    'updated': True,
#    'volume_24h': 609841.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/USDT',
#    'percent_volume': 0.0573055090448,
#    'price': 0.0351559,
#    'updated': True,
#    'volume_24h': 599351.0},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/ETH',
#    'percent_volume': 0.0572871514251,
#    'price': 0.139033,
#    'updated': True,
#    'volume_24h': 599159.0},
#   {'currency': 'DADI',
#    'pair': 'DADI/USDT',
#    'percent_volume': 0.0563880105092,
#    'price': 0.195611,
#    'updated': True,
#    'volume_24h': 589755.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/BTC',
#    'percent_volume': 0.0545508143482,
#    'price': 0.00158507,
#    'updated': True,
#    'volume_24h': 570540.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/BTC',
#    'percent_volume': 0.0530043761121,
#    'price': 0.0825073,
#    'updated': True,
#    'volume_24h': 554366.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/ETH',
#    'percent_volume': 0.0505083135058,
#    'price': 64.2286,
#    'updated': True,
#    'volume_24h': 528260.0},
#   {'currency': 'Ace',
#    'pair': 'ACE/BTC',
#    'percent_volume': 0.0503612613228,
#    'price': 0.124387,
#    'updated': True,
#    'volume_24h': 526722.0},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/BTC',
#    'percent_volume': 0.0502923246363,
#    'price': 2.74326,
#    'updated': True,
#    'volume_24h': 526001.0},
#   {'currency': 'Gifto',
#    'pair': 'GTO/USDT',
#    'percent_volume': 0.0502582865497,
#    'price': 0.240383,
#    'updated': True,
#    'volume_24h': 525645.0},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/USDT',
#    'percent_volume': 0.0494174693215,
#    'price': 0.0880401,
#    'updated': True,
#    'volume_24h': 516851.0},
#   {'currency': 'DADI',
#    'pair': 'DADI/ETH',
#    'percent_volume': 0.0475927984115,
#    'price': 0.207763,
#    'updated': True,
#    'volume_24h': 497767.0},
#   {'currency': 'Game.com',
#    'pair': 'GTC/BTC',
#    'percent_volume': 0.0464126520563,
#    'price': 0.050055,
#    'updated': True,
#    'volume_24h': 485424.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/USDT',
#    'percent_volume': 0.0459691051923,
#    'price': 0.86728,
#    'updated': True,
#    'volume_24h': 480785.0},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/USDT',
#    'percent_volume': 0.0456459345951,
#    'price': 0.0380606,
#    'updated': True,
#    'volume_24h': 477405.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/BTC',
#    'percent_volume': 0.0449397399116,
#    'price': 0.0352053,
#    'updated': True,
#    'volume_24h': 470019.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/ETH',
#    'percent_volume': 0.0449166016617,
#    'price': 1.25061,
#    'updated': True,
#    'volume_24h': 469777.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/USDT',
#    'percent_volume': 0.0448487167138,
#    'price': 0.0893422,
#    'updated': True,
#    'volume_24h': 469067.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/BTC',
#    'percent_volume': 0.0443721835019,
#    'price': 0.866786,
#    'updated': True,
#    'volume_24h': 464083.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/ETH',
#    'percent_volume': 0.0440053179453,
#    'price': 17.7377,
#    'updated': True,
#    'volume_24h': 460246.0},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/ETH',
#    'percent_volume': 0.0438279565673,
#    'price': 0.0888619,
#    'updated': True,
#    'volume_24h': 458391.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/USDT',
#    'percent_volume': 0.0408219919508,
#    'price': 0.500797,
#    'updated': True,
#    'volume_24h': 426952.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/BTC',
#    'percent_volume': 0.0407698830823,
#    'price': 0.225081,
#    'updated': True,
#    'volume_24h': 426407.0},
#   {'currency': 'Arcblock',
#    'pair': 'ABT/ETH',
#    'percent_volume': 0.0386190775844,
#    'price': 0.673027,
#    'updated': True,
#    'volume_24h': 403912.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/ETH',
#    'percent_volume': 0.0349886670597,
#    'price': 0.0889283,
#    'updated': True,
#    'volume_24h': 365942.0},
#   {'currency': 'ProChain',
#    'pair': 'PRA/USDT',
#    'percent_volume': 0.034888465052,
#    'price': 0.209834,
#    'updated': True,
#    'volume_24h': 364894.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/USDT',
#    'percent_volume': 0.0343586756204,
#    'price': 0.034555,
#    'updated': True,
#    'volume_24h': 359353.0},
#   {'currency': 'Bankex',
#    'pair': 'BKX/ETH',
#    'percent_volume': 0.0343030290857,
#    'price': 0.305006,
#    'updated': True,
#    'volume_24h': 358771.0},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/BTC',
#    'percent_volume': 0.0327255167536,
#    'price': 0.0881802,
#    'updated': True,
#    'volume_24h': 342272.0},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/BTC',
#    'percent_volume': 0.0322865592946,
#    'price': 0.0375412,
#    'updated': True,
#    'volume_24h': 337681.0},
#   {'currency': 'Game.com',
#    'pair': 'GTC/ETH',
#    'percent_volume': 0.0319873874607,
#    'price': 0.0508249,
#    'updated': True,
#    'volume_24h': 334552.0},
#   {'currency': 'ProChain',
#    'pair': 'PRA/BTC',
#    'percent_volume': 0.0319472301676,
#    'price': 0.210314,
#    'updated': True,
#    'volume_24h': 334132.0},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/BTC',
#    'percent_volume': 0.0318991370284,
#    'price': 0.0427136,
#    'updated': True,
#    'volume_24h': 333629.0},
#   {'currency': 'Bankex',
#    'pair': 'BKX/BTC',
#    'percent_volume': 0.030649002248,
#    'price': 0.307004,
#    'updated': True,
#    'volume_24h': 320554.0},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/USDT',
#    'percent_volume': 0.0300489375534,
#    'price': 0.0315502,
#    'updated': True,
#    'volume_24h': 314278.0},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/ETH',
#    'percent_volume': 0.0300407148696,
#    'price': 0.0378174,
#    'updated': True,
#    'volume_24h': 314192.0},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/ETH',
#    'percent_volume': 0.0299646072378,
#    'price': 0.0195854,
#    'updated': True,
#    'volume_24h': 313396.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/ETH',
#    'percent_volume': 0.0296202106429,
#    'price': 0.0344518,
#    'updated': True,
#    'volume_24h': 309794.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/BTC',
#    'percent_volume': 0.0295418083087,
#    'price': 0.0881802,
#    'updated': True,
#    'volume_24h': 308974.0},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/USDT',
#    'percent_volume': 0.0294422755893,
#    'price': 0.0808286,
#    'updated': True,
#    'volume_24h': 307933.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/USDT',
#    'percent_volume': 0.029150657151,
#    'price': 1.17357,
#    'updated': True,
#    'volume_24h': 304883.0},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/USDT',
#    'percent_volume': 0.0284870100756,
#    'price': 230.196,
#    'updated': True,
#    'volume_24h': 297942.0},
#   {'currency': 'NEM',
#    'pair': 'XEM/USDT',
#    'percent_volume': 0.0280902177744,
#    'price': 0.270531,
#    'updated': True,
#    'volume_24h': 293792.0},
#   {'currency': 'Gifto',
#    'pair': 'GTO/BTC',
#    'percent_volume': 0.0274671104425,
#    'price': 0.240097,
#    'updated': True,
#    'volume_24h': 287275.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/USDT',
#    'percent_volume': 0.026980155457,
#    'price': 0.0223355,
#    'updated': True,
#    'volume_24h': 282182.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/BTC',
#    'percent_volume': 0.026867523811,
#    'price': 0.202806,
#    'updated': True,
#    'volume_24h': 281004.0},
#   {'currency': 'Republic Protocol',
#    'pair': 'REN/BTC',
#    'percent_volume': 0.0256393799292,
#    'price': 0.0479694,
#    'updated': True,
#    'volume_24h': 268159.0},
#   {'currency': 'Hi Mutual Society',
#    'pair': 'HMC/BTC',
#    'percent_volume': 0.025413925412,
#    'price': 0.0346214,
#    'updated': True,
#    'volume_24h': 265801.0},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/ETH',
#    'percent_volume': 0.0253886836849,
#    'price': 0.240422,
#    'updated': True,
#    'volume_24h': 265537.0},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/USDT',
#    'percent_volume': 0.0249913177081,
#    'price': 6.13206,
#    'updated': True,
#    'volume_24h': 261381.0},
#   {'currency': 'QunQun',
#    'pair': 'QUN/BTC',
#    'percent_volume': 0.0248491417678,
#    'price': 0.026696,
#    'updated': True,
#    'volume_24h': 259894.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/ETH',
#    'percent_volume': 0.0243343635149,
#    'price': 0.0221031,
#    'updated': True,
#    'volume_24h': 254510.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/ETH',
#    'percent_volume': 0.0240888303511,
#    'price': 0.353241,
#    'updated': True,
#    'volume_24h': 251942.0},
#   {'currency': 'Arcblock',
#    'pair': 'ABT/USDT',
#    'percent_volume': 0.0229655734945,
#    'price': 0.653039,
#    'updated': True,
#    'volume_24h': 240194.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/USDT',
#    'percent_volume': 0.0229377502271,
#    'price': 0.00170271,
#    'updated': True,
#    'volume_24h': 239903.0},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/USDT',
#    'percent_volume': 0.0225072066771,
#    'price': 10.5868,
#    'updated': True,
#    'volume_24h': 235400.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/USDT',
#    'percent_volume': 0.022444197972,
#    'price': 0.204726,
#    'updated': True,
#    'volume_24h': 234741.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/ETH',
#    'percent_volume': 0.0219856399294,
#    'price': 5.7672,
#    'updated': True,
#    'volume_24h': 229945.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/ETH',
#    'percent_volume': 0.0215656137657,
#    'price': 0.000878405,
#    'updated': True,
#    'volume_24h': 225552.0},
#   {'currency': 'QunQun',
#    'pair': 'QUN/USDT',
#    'percent_volume': 0.021479371198,
#    'price': 0.0267426,
#    'updated': True,
#    'volume_24h': 224650.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/ETH',
#    'percent_volume': 0.0211934895159,
#    'price': 3.81249,
#    'updated': True,
#    'volume_24h': 221660.0},
#   {'currency': 'Refereum',
#    'pair': 'RFR/ETH',
#    'percent_volume': 0.0210277928755,
#    'price': 0.00903429,
#    'updated': True,
#    'volume_24h': 219927.0},
#   {'currency': 'NEM',
#    'pair': 'XEM/BTC',
#    'percent_volume': 0.0210163193631,
#    'price': 0.268962,
#    'updated': True,
#    'volume_24h': 219807.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/USDT',
#    'percent_volume': 0.0190403893156,
#    'price': 0.0359572,
#    'updated': True,
#    'volume_24h': 199141.0},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/USDT',
#    'percent_volume': 0.0188935283578,
#    'price': 0.13822,
#    'updated': True,
#    'volume_24h': 197605.0},
#   {'currency': 'Super Bitcoin',
#    'pair': 'SBTC/BTC',
#    'percent_volume': 0.0187436077968,
#    'price': 9.39365,
#    'updated': True,
#    'volume_24h': 196037.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/ETH',
#    'percent_volume': 0.0183468154956,
#    'price': 0.585947,
#    'updated': True,
#    'volume_24h': 191887.0},
#   {'currency': 'ProChain',
#    'pair': 'PRA/ETH',
#    'percent_volume': 0.0178415985029,
#    'price': 0.209408,
#    'updated': True,
#    'volume_24h': 186603.0},
#   {'currency': 'Arcblock',
#    'pair': 'ABT/BTC',
#    'percent_volume': 0.0178074648037,
#    'price': 0.668985,
#    'updated': True,
#    'volume_24h': 186246.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/BTC',
#    'percent_volume': 0.0173074108915,
#    'price': 0.0216071,
#    'updated': True,
#    'volume_24h': 181016.0},
#   {'currency': 'Refereum',
#    'pair': 'RFR/BTC',
#    'percent_volume': 0.0168817435843,
#    'price': 0.0090099,
#    'updated': True,
#    'volume_24h': 176564.0},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/USDT',
#    'percent_volume': 0.0167507543186,
#    'price': 0.0456727,
#    'updated': True,
#    'volume_24h': 175194.0},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/ETH',
#    'percent_volume': 0.0166592530578,
#    'price': 0.0426486,
#    'updated': True,
#    'volume_24h': 174237.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/USDT',
#    'percent_volume': 0.0165736797784,
#    'price': 0.0503802,
#    'updated': True,
#    'volume_24h': 173342.0},
#   {'currency': 'Cube',
#    'pair': 'AUTO/ETH',
#    'percent_volume': 0.0164787364639,
#    'price': 0.00892704,
#    'updated': True,
#    'volume_24h': 172349.0},
#   {'currency': 'Loopring',
#    'pair': 'LRC/ETH',
#    'percent_volume': 0.0161440923544,
#    'price': 0.428018,
#    'updated': True,
#    'volume_24h': 168849.0},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/BTC',
#    'percent_volume': 0.016015684629,
#    'price': 232.073,
#    'updated': True,
#    'volume_24h': 167506.0},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/BTC',
#    'percent_volume': 0.0149598346573,
#    'price': 0.337287,
#    'updated': True,
#    'volume_24h': 156463.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/BTC',
#    'percent_volume': 0.0149458752173,
#    'price': 0.0498047,
#    'updated': True,
#    'volume_24h': 156317.0},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/ETH',
#    'percent_volume': 0.014383768726,
#    'price': 0.0876464,
#    'updated': True,
#    'volume_24h': 150438.0},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/BTC',
#    'percent_volume': 0.0141472231469,
#    'price': 0.0914338,
#    'updated': True,
#    'volume_24h': 147964.0},
#   {'currency': 'Primas',
#    'pair': 'PST/USDT',
#    'percent_volume': 0.0139678539042,
#    'price': 0.178284,
#    'updated': True,
#    'volume_24h': 146088.0},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/BTC',
#    'percent_volume': 0.0136648575662,
#    'price': 10.6639,
#    'updated': True,
#    'volume_24h': 142919.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/USDT',
#    'percent_volume': 0.0134487730841,
#    'price': 0.00871387,
#    'updated': True,
#    'volume_24h': 140659.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/ETH',
#    'percent_volume': 0.0132518111225,
#    'price': 0.00165467,
#    'updated': True,
#    'volume_24h': 138599.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/ETH',
#    'percent_volume': 0.0127526177238,
#    'price': 967.088,
#    'updated': True,
#    'volume_24h': 133378.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/USDT',
#    'percent_volume': 0.0127061499989,
#    'price': 0.1258,
#    'updated': True,
#    'volume_24h': 132892.0},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/ETH',
#    'percent_volume': 0.0126523201036,
#    'price': 0.0617896,
#    'updated': True,
#    'volume_24h': 132329.0},
#   {'currency': 'RefToken',
#    'pair': 'REF/BTC',
#    'percent_volume': 0.0122810563673,
#    'price': 6.00393,
#    'updated': True,
#    'volume_24h': 128446.0},
#   {'currency': 'Status',
#    'pair': 'SNT/USDT',
#    'percent_volume': 0.0116610086387,
#    'price': 0.101662,
#    'updated': True,
#    'volume_24h': 121961.0},
#   {'currency': 'Hi Mutual Society',
#    'pair': 'HMC/ETH',
#    'percent_volume': 0.0115403455341,
#    'price': 0.0348502,
#    'updated': True,
#    'volume_24h': 120699.0},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/BTC',
#    'percent_volume': 0.0114664369922,
#    'price': 325.357,
#    'updated': True,
#    'volume_24h': 119926.0},
#   {'currency': 'Bankex',
#    'pair': 'BKX/USDT',
#    'percent_volume': 0.0113796207489,
#    'price': 0.304485,
#    'updated': True,
#    'volume_24h': 119018.0},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/USDT',
#    'percent_volume': 0.0113045648558,
#    'price': 1.1919,
#    'updated': True,
#    'volume_24h': 118233.0},
#   {'currency': 'Nuls',
#    'pair': 'NULS/USDT',
#    'percent_volume': 0.0112950992081,
#    'price': 2.55406,
#    'updated': True,
#    'volume_24h': 118134.0},
#   {'currency': 'ChatCoin',
#    'pair': 'CHAT/BTC',
#    'percent_volume': 0.0110175358225,
#    'price': 0.0855106,
#    'updated': True,
#    'volume_24h': 115231.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/ETH',
#    'percent_volume': 0.0109716417732,
#    'price': 0.868523,
#    'updated': True,
#    'volume_24h': 114751.0},
#   {'currency': 'QunQun',
#    'pair': 'QUN/ETH',
#    'percent_volume': 0.0106594666253,
#    'price': 0.0264134,
#    'updated': True,
#    'volume_24h': 111486.0},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/USDT',
#    'percent_volume': 0.0103548448731,
#    'price': 1.09274,
#    'updated': True,
#    'volume_24h': 108300.0},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/ETH',
#    'percent_volume': 0.0101647670189,
#    'price': 0.0185384,
#    'updated': True,
#    'volume_24h': 106312.0},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/USDT',
#    'percent_volume': 0.00960055705037,
#    'price': 0.188099,
#    'updated': True,
#    'volume_24h': 100411.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/ETH',
#    'percent_volume': 0.00940208440967,
#    'price': 157.505,
#    'updated': True,
#    'volume_24h': 98335.2},
#   {'currency': 'Status',
#    'pair': 'SNT/BTC',
#    'percent_volume': 0.00894892847915,
#    'price': 0.101195,
#    'updated': True,
#    'volume_24h': 93595.7},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/BTC',
#    'percent_volume': 0.00891684088968,
#    'price': 0.0315346,
#    'updated': True,
#    'volume_24h': 93260.1},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/ETH',
#    'percent_volume': 0.00878713283285,
#    'price': 0.0825854,
#    'updated': True,
#    'volume_24h': 91903.5},
#   {'currency': 'Gifto',
#    'pair': 'GTO/ETH',
#    'percent_volume': 0.00877812612567,
#    'price': 0.245054,
#    'updated': True,
#    'volume_24h': 91809.3},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/USDT',
#    'percent_volume': 0.00852314643677,
#    'price': 0.325418,
#    'updated': True,
#    'volume_24h': 89142.5},
#   {'currency': 'Maggie',
#    'pair': 'MAG/BTC',
#    'percent_volume': 0.00804072348856,
#    'price': 0.0101778,
#    'updated': True,
#    'volume_24h': 84096.9},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/ETH',
#    'percent_volume': 0.00782542302978,
#    'price': 0.0188193,
#    'updated': True,
#    'volume_24h': 81845.1},
#   {'currency': 'Leverj',
#    'pair': 'LEV/BTC',
#    'percent_volume': 0.00768227184101,
#    'price': 0.0284479,
#    'updated': True,
#    'volume_24h': 80347.9},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/BTC',
#    'percent_volume': 0.00764315672524,
#    'price': 17.3632,
#    'updated': True,
#    'volume_24h': 79938.8},
#   {'currency': 'Nano',
#    'pair': 'NANO/USDT',
#    'percent_volume': 0.00747481161566,
#    'price': 8.40337,
#    'updated': True,
#    'volume_24h': 78178.1},
#   {'currency': 'ChatCoin',
#    'pair': 'CHAT/USDT',
#    'percent_volume': 0.0074657284184,
#    'price': 0.0841339,
#    'updated': True,
#    'volume_24h': 78083.1},
#   {'currency': 'Centra',
#    'pair': 'CTR/BTC',
#    'percent_volume': 0.00744728474734,
#    'price': 0.427219,
#    'updated': True,
#    'volume_24h': 77890.2},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/BTC',
#    'percent_volume': 0.00728660776849,
#    'price': 0.000917675,
#    'updated': True,
#    'volume_24h': 76209.7},
#   {'currency': 'Maggie',
#    'pair': 'MAG/USDT',
#    'percent_volume': 0.00720212447274,
#    'price': 0.0102163,
#    'updated': True,
#    'volume_24h': 75326.1},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/BTC',
#    'percent_volume': 0.00715511175599,
#    'price': 0.0179364,
#    'updated': True,
#    'volume_24h': 74834.4},
#   {'currency': 'Cube',
#    'pair': 'AUTO/USDT',
#    'percent_volume': 0.0070065488939,
#    'price': 0.00891419,
#    'updated': True,
#    'volume_24h': 73280.6},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/USDT',
#    'percent_volume': 0.00693497329952,
#    'price': 0.0427681,
#    'updated': True,
#    'volume_24h': 72532.0},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/BTC',
#    'percent_volume': 0.00688242461307,
#    'price': 13.3814,
#    'updated': True,
#    'volume_24h': 71982.4},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/BTC',
#    'percent_volume': 0.00662453830105,
#    'price': 1.18397,
#    'updated': True,
#    'volume_24h': 69285.2},
#   {'currency': 'Nuls',
#    'pair': 'NULS/BTC',
#    'percent_volume': 0.00639157819455,
#    'price': 2.54446,
#    'updated': True,
#    'volume_24h': 66848.7},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/BTC',
#    'percent_volume': 0.00631383558729,
#    'price': 0.0866786,
#    'updated': True,
#    'volume_24h': 66035.6},
#   {'currency': 'Ontology',
#    'pair': 'ONT/BTC',
#    'percent_volume': 0.00630189357321,
#    'price': 1.27874,
#    'updated': True,
#    'volume_24h': 65910.7},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/ETH',
#    'percent_volume': 0.00603664509079,
#    'price': 0.0316124,
#    'updated': True,
#    'volume_24h': 63136.5},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/USDT',
#    'percent_volume': 0.0059990024091,
#    'price': 311.497,
#    'updated': True,
#    'volume_24h': 62742.8},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/BTC',
#    'percent_volume': 0.00565451976281,
#    'price': 0.170187,
#    'updated': True,
#    'volume_24h': 59139.9},
#   {'currency': 'RefToken',
#    'pair': 'REF/USDT',
#    'percent_volume': 0.00564765477793,
#    'price': 5.86063,
#    'updated': True,
#    'volume_24h': 59068.1},
#   {'currency': 'NAGA',
#    'pair': 'NGC/BTC',
#    'percent_volume': 0.00563555978369,
#    'price': 0.752911,
#    'updated': True,
#    'volume_24h': 58941.6},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/USDT',
#    'percent_volume': 0.0055872562968,
#    'price': 0.0091145,
#    'updated': True,
#    'volume_24h': 58436.4},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/USDT',
#    'percent_volume': 0.00548418591109,
#    'price': 0.0199317,
#    'updated': True,
#    'volume_24h': 57358.4},
#   {'currency': 'Ontology',
#    'pair': 'ONT/USDT',
#    'percent_volume': 0.00544398081165,
#    'price': 1.27072,
#    'updated': True,
#    'volume_24h': 56937.9},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/USDT',
#    'percent_volume': 0.00526035680815,
#    'price': 0.000901435,
#    'updated': True,
#    'volume_24h': 55017.4},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/BTC',
#    'percent_volume': 0.00515085169427,
#    'price': 57.5002,
#    'updated': True,
#    'volume_24h': 53872.1},
#   {'currency': 'Dash',
#    'pair': 'DASH/USDT',
#    'percent_volume': 0.00514660649471,
#    'price': 394.625,
#    'updated': True,
#    'volume_24h': 53827.7},
#   {'currency': 'Dash',
#    'pair': 'DASH/BTC',
#    'percent_volume': 0.00496598472694,
#    'price': 396.823,
#    'updated': True,
#    'volume_24h': 51938.6},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/ETH',
#    'percent_volume': 0.00495656688557,
#    'price': 0.0917984,
#    'updated': True,
#    'volume_24h': 51840.1},
#   {'currency': 'RefToken',
#    'pair': 'REF/ETH',
#    'percent_volume': 0.00495315351565,
#    'price': 6.41942,
#    'updated': True,
#    'volume_24h': 51804.4},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/BTC',
#    'percent_volume': 0.00494554275248,
#    'price': 0.0347882,
#    'updated': True,
#    'volume_24h': 51724.8},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/BTC',
#    'percent_volume': 0.00476790409791,
#    'price': 0.176527,
#    'updated': True,
#    'volume_24h': 49866.9},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/USDT',
#    'percent_volume': 0.00471637846631,
#    'price': 13.5077,
#    'updated': True,
#    'volume_24h': 49328.0},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/USDT',
#    'percent_volume': 0.00465476570513,
#    'price': 0.0871387,
#    'updated': True,
#    'volume_24h': 48683.6},
#   {'currency': 'Monaco',
#    'pair': 'MCO/BTC',
#    'percent_volume': 0.00449287444622,
#    'price': 5.911,
#    'updated': True,
#    'volume_24h': 46990.4},
#   {'currency': 'Leverj',
#    'pair': 'LEV/USDT',
#    'percent_volume': 0.00420236511416,
#    'price': 0.030148,
#    'updated': True,
#    'volume_24h': 43952.0},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/USDT',
#    'percent_volume': 0.00416760037182,
#    'price': 56.2989,
#    'updated': True,
#    'volume_24h': 43588.4},
#   {'currency': 'SmartMesh',
#    'pair': 'SMT/USDT',
#    'percent_volume': 0.00413525462832,
#    'price': 0.0288459,
#    'updated': True,
#    'volume_24h': 43250.1},
#   {'currency': 'BitcoinX',
#    'pair': 'BCX/BTC',
#    'percent_volume': 0.0039827047207,
#    'price': 0.00408782,
#    'updated': True,
#    'volume_24h': 41654.6},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/USDT',
#    'percent_volume': 0.00389676811339,
#    'price': 0.0352561,
#    'updated': True,
#    'volume_24h': 40755.8},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/USDT',
#    'percent_volume': 0.00385346516562,
#    'price': 0.16997,
#    'updated': True,
#    'volume_24h': 40302.9},
#   {'currency': 'AirSwap',
#    'pair': 'AST/BTC',
#    'percent_volume': 0.00381848051429,
#    'price': 0.264207,
#    'updated': True,
#    'volume_24h': 39937.0},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/ETH',
#    'percent_volume': 0.00381180675462,
#    'price': 1.20027,
#    'updated': True,
#    'volume_24h': 39867.2},
#   {'currency': 'Gas',
#    'pair': 'GAS/BTC',
#    'percent_volume': 0.00379825844882,
#    'price': 20.6727,
#    'updated': True,
#    'volume_24h': 39725.5},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/BTC',
#    'percent_volume': 0.00376384747311,
#    'price': 0.0312009,
#    'updated': True,
#    'volume_24h': 39365.6},
#   {'currency': 'Gas',
#    'pair': 'GAS/USDT',
#    'percent_volume': 0.00362329694713,
#    'price': 20.8456,
#    'updated': True,
#    'volume_24h': 37895.6},
#   {'currency': 'YEE',
#    'pair': 'YEE/USDT',
#    'percent_volume': 0.00359112330632,
#    'price': 0.0116185,
#    'updated': True,
#    'volume_24h': 37559.1},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/USDT',
#    'percent_volume': 0.00355706609723,
#    'price': 0.0196312,
#    'updated': True,
#    'volume_24h': 37202.9},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/BTC',
#    'percent_volume': 0.00353442503291,
#    'price': 0.0220242,
#    'updated': True,
#    'volume_24h': 36966.1},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/ETH',
#    'percent_volume': 0.0035334402231,
#    'price': 0.00883001,
#    'updated': True,
#    'volume_24h': 36955.8},
#   {'currency': 'Maggie',
#    'pair': 'MAG/ETH',
#    'percent_volume': 0.00346315539886,
#    'price': 0.0102344,
#    'updated': True,
#    'volume_24h': 36220.7},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/USDT',
#    'percent_volume': 0.00338359615214,
#    'price': 0.0176281,
#    'updated': True,
#    'volume_24h': 35388.6},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/ETH',
#    'percent_volume': 0.00336846067713,
#    'price': 0.0303152,
#    'updated': True,
#    'volume_24h': 35230.3},
#   {'currency': 'EOS',
#    'pair': 'EOS/BCH',
#    'percent_volume': 0.00327660564971,
#    'price': 6.66353,
#    'updated': True,
#    'volume_24h': 34269.6},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/BTC',
#    'percent_volume': 0.0032578368958,
#    'price': 0.0617345,
#    'updated': True,
#    'volume_24h': 34073.3},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/USDT',
#    'percent_volume': 0.00317501725934,
#    'price': 0.020132,
#    'updated': True,
#    'volume_24h': 33207.1},
#   {'currency': 'Monero',
#    'pair': 'XMR/BTC',
#    'percent_volume': 0.00316841998975,
#    'price': 197.169,
#    'updated': True,
#    'volume_24h': 33138.1},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/ETH',
#    'percent_volume': 0.00314064452867,
#    'price': 0.0823402,
#    'updated': True,
#    'volume_24h': 32847.6},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/BCH',
#    'percent_volume': 0.00309929207799,
#    'price': 2.92444,
#    'updated': True,
#    'volume_24h': 32415.1},
#   {'currency': 'Dent',
#    'pair': 'DENT/BTC',
#    'percent_volume': 0.00308146032759,
#    'price': 0.0090099,
#    'updated': True,
#    'volume_24h': 32228.6},
#   {'currency': 'YEE',
#    'pair': 'YEE/BTC',
#    'percent_volume': 0.00299204342154,
#    'price': 0.0115127,
#    'updated': True,
#    'volume_24h': 31293.4},
#   {'currency': 'Centra',
#    'pair': 'CTR/USDT',
#    'percent_volume': 0.00296583600714,
#    'price': 0.484371,
#    'updated': True,
#    'volume_24h': 31019.3},
#   {'currency': 'Nano',
#    'pair': 'NANO/BTC',
#    'percent_volume': 0.00294435185531,
#    'price': 7.27983,
#    'updated': True,
#    'volume_24h': 30794.6},
#   {'currency': 'IPChain',
#    'pair': 'IPC/BTC',
#    'percent_volume': 0.00294352002567,
#    'price': 0.539092,
#    'updated': True,
#    'volume_24h': 30785.9},
#   {'currency': 'Datum',
#    'pair': 'DAT/BTC',
#    'percent_volume': 0.00290267432179,
#    'price': 0.0235258,
#    'updated': True,
#    'volume_24h': 30358.7},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/ETH',
#    'percent_volume': 0.00286157046389,
#    'price': 0.334478,
#    'updated': True,
#    'volume_24h': 29928.8},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/ETH',
#    'percent_volume': 0.00285793718498,
#    'price': 6.1284,
#    'updated': True,
#    'volume_24h': 29890.8},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/USDT',
#    'percent_volume': 0.00277475422063,
#    'price': 0.0639017,
#    'updated': True,
#    'volume_24h': 29020.8},
#   {'currency': 'Ontology',
#    'pair': 'ONT/ETH',
#    'percent_volume': 0.00272847772092,
#    'price': 1.29207,
#    'updated': True,
#    'volume_24h': 28536.8},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/USDT',
#    'percent_volume': 0.0026558503879,
#    'price': 17.2275,
#    'updated': True,
#    'volume_24h': 27777.2},
#   {'currency': 'Read',
#    'pair': 'READ/USDT',
#    'percent_volume': 0.00258831920661,
#    'price': 0.0186296,
#    'updated': True,
#    'volume_24h': 27070.9},
#   {'currency': 'Nuls',
#    'pair': 'NULS/ETH',
#    'percent_volume': 0.00255764668366,
#    'price': 2.60457,
#    'updated': True,
#    'volume_24h': 26750.1},
#   {'currency': 'Enigma',
#    'pair': 'ENG/BTC',
#    'percent_volume': 0.00252567382932,
#    'price': 1.81041,
#    'updated': True,
#    'volume_24h': 26415.7},
#   {'currency': 'Storj',
#    'pair': 'STORJ/BTC',
#    'percent_volume': 0.00244061685795,
#    'price': 0.816314,
#    'updated': True,
#    'volume_24h': 25526.1},
#   {'currency': 'Achain',
#    'pair': 'ACT/ETH',
#    'percent_volume': 0.00234791087836,
#    'price': 0.196201,
#    'updated': True,
#    'volume_24h': 24556.5},
#   {'currency': '0x',
#    'pair': 'ZRX/BTC',
#    'percent_volume': 0.00234349357612,
#    'price': 0.5154,
#    'updated': True,
#    'volume_24h': 24510.3},
#   {'currency': 'ChatCoin',
#    'pair': 'CHAT/ETH',
#    'percent_volume': 0.00220005554954,
#    'price': 0.0827335,
#    'updated': True,
#    'volume_24h': 23010.1},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/ETH',
#    'percent_volume': 0.00216575930895,
#    'price': 0.00914664,
#    'updated': True,
#    'volume_24h': 22651.4},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/ETH',
#    'percent_volume': 0.00212762900299,
#    'price': 1.09545,
#    'updated': True,
#    'volume_24h': 22252.6},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/USDT',
#    'percent_volume': 0.00209672700979,
#    'price': 1.46363,
#    'updated': True,
#    'volume_24h': 21929.4},
#   {'currency': 'TenX',
#    'pair': 'PAY/BTC',
#    'percent_volume': 0.00209124840766,
#    'price': 1.11064,
#    'updated': True,
#    'volume_24h': 21872.1},
#   {'currency': 'AirSwap',
#    'pair': 'AST/USDT',
#    'percent_volume': 0.00204746739688,
#    'price': 0.267726,
#    'updated': True,
#    'volume_24h': 21414.2},
#   {'currency': 'Ace',
#    'pair': 'ACE/USDT',
#    'percent_volume': 0.00201117285289,
#    'price': 0.122695,
#    'updated': True,
#    'volume_24h': 21034.6},
#   {'currency': 'NEM',
#    'pair': 'XEM/ETH',
#    'percent_volume': 0.00200031126122,
#    'price': 0.265646,
#    'updated': True,
#    'volume_24h': 20921.0},
#   {'currency': 'UTRUST',
#    'pair': 'UTK/BTC',
#    'percent_volume': 0.00199866672446,
#    'price': 0.14274,
#    'updated': True,
#    'volume_24h': 20903.8},
#   {'currency': 'Enigma',
#    'pair': 'ENG/USDT',
#    'percent_volume': 0.00198019436962,
#    'price': 1.81138,
#    'updated': True,
#    'volume_24h': 20710.6},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/USDT',
#    'percent_volume': 0.00186941760812,
#    'price': 0.030148,
#    'updated': True,
#    'volume_24h': 19552.0},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/USDT',
#    'percent_volume': 0.0018353699603,
#    'price': 0.233271,
#    'updated': True,
#    'volume_24h': 19195.9},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/USDT',
#    'percent_volume': 0.0018035787699,
#    'price': 0.261015,
#    'updated': True,
#    'volume_24h': 18863.4},
#   {'currency': 'Civic',
#    'pair': 'CVC/BTC',
#    'percent_volume': 0.00178412160525,
#    'price': 0.241932,
#    'updated': True,
#    'volume_24h': 18659.9},
#   {'currency': 'Hshare',
#    'pair': 'HSR/ETH',
#    'percent_volume': 0.00177854739051,
#    'price': 6.5655,
#    'updated': True,
#    'volume_24h': 18601.6},
#   {'currency': 'Monero',
#    'pair': 'XMR/USDT',
#    'percent_volume': 0.00177161547681,
#    'price': 196.803,
#    'updated': True,
#    'volume_24h': 18529.1},
#   {'currency': 'Republic Protocol',
#    'pair': 'REN/ETH',
#    'percent_volume': 0.00175676683961,
#    'price': 0.048108,
#    'updated': True,
#    'volume_24h': 18373.8},
#   {'currency': 'BT2 [CST]',
#    'pair': 'BT2/BTC',
#    'percent_volume': 0.00174639287222,
#    'price': 60.2777,
#    'updated': True,
#    'volume_24h': 18265.3},
#   {'currency': 'ugChain',
#    'pair': 'UGC/USDT',
#    'percent_volume': 0.00173370507984,
#    'price': 0.0365582,
#    'updated': True,
#    'volume_24h': 18132.6},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/BTC',
#    'percent_volume': 0.00172255665036,
#    'price': 1.45768,
#    'updated': True,
#    'volume_24h': 18016.0},
#   {'currency': 'Dash',
#    'pair': 'DASH/ETH',
#    'percent_volume': 0.00171503193853,
#    'price': 390.596,
#    'updated': True,
#    'volume_24h': 17937.3},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/BTC',
#    'percent_volume': 0.00166913788923,
#    'price': 1.58508,
#    'updated': True,
#    'volume_24h': 17457.3},
#   {'currency': 'Datum',
#    'pair': 'DAT/ETH',
#    'percent_volume': 0.00165604852392,
#    'price': 0.0235637,
#    'updated': True,
#    'volume_24h': 17320.4},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/BCH',
#    'percent_volume': 0.00163508068015,
#    'price': 17.9973,
#    'updated': True,
#    'volume_24h': 17101.1},
#   {'currency': 'ugChain',
#    'pair': 'UGC/ETH',
#    'percent_volume': 0.0016032512447,
#    'price': 0.0367704,
#    'updated': True,
#    'volume_24h': 16768.2},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/BTC',
#    'percent_volume': 0.00157949151293,
#    'price': 0.82207,
#    'updated': True,
#    'volume_24h': 16519.7},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/ETH',
#    'percent_volume': 0.00149619381345,
#    'price': 0.25535,
#    'updated': True,
#    'volume_24h': 15648.5},
#   {'currency': 'Stellar',
#    'pair': 'XLM/ETH',
#    'percent_volume': 0.00146718494979,
#    'price': 0.227057,
#    'updated': True,
#    'volume_24h': 15345.1},
#   {'currency': 'Bancor',
#    'pair': 'BNT/BTC',
#    'percent_volume': 0.00146651566157,
#    'price': 2.8357,
#    'updated': True,
#    'volume_24h': 15338.1},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/ETH',
#    'percent_volume': 0.00139933824691,
#    'price': 17.5826,
#    'updated': True,
#    'volume_24h': 14635.5},
#   {'currency': 'Status',
#    'pair': 'SNT/ETH',
#    'percent_volume': 0.00136849362128,
#    'price': 0.101297,
#    'updated': True,
#    'volume_24h': 14312.9},
#   {'currency': 'TenX',
#    'pair': 'PAY/USDT',
#    'percent_volume': 0.00129667899539,
#    'price': 1.09174,
#    'updated': True,
#    'volume_24h': 13561.8},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/BTC',
#    'percent_volume': 0.0012864484469,
#    'price': 0.0480528,
#    'updated': True,
#    'volume_24h': 13454.8},
#   {'currency': 'Waltonchain',
#    'pair': 'WTC/BTC',
#    'percent_volume': 0.00128232754372,
#    'price': 12.1085,
#    'updated': True,
#    'volume_24h': 13411.7},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/BTC',
#    'percent_volume': 0.00127710709561,
#    'price': 0.193129,
#    'updated': True,
#    'volume_24h': 13357.1},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/BTC',
#    'percent_volume': 0.00124506731245,
#    'price': 0.00909332,
#    'updated': True,
#    'volume_24h': 13022.0},
#   {'currency': 'Leverj',
#    'pair': 'LEV/ETH',
#    'percent_volume': 0.00121202359695,
#    'price': 0.0367704,
#    'updated': True,
#    'volume_24h': 12676.4},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/ETH',
#    'percent_volume': 0.00118393261427,
#    'price': 10.6611,
#    'updated': True,
#    'volume_24h': 12382.6},
#   {'currency': 'Hi Mutual Society',
#    'pair': 'HMC/USDT',
#    'percent_volume': 0.00115534444607,
#    'price': 0.034555,
#    'updated': True,
#    'volume_24h': 12083.6},
#   {'currency': 'Storj',
#    'pair': 'STORJ/USDT',
#    'percent_volume': 0.00114289568519,
#    'price': 0.811792,
#    'updated': True,
#    'volume_24h': 11953.4},
#   {'currency': 'IPChain',
#    'pair': 'IPC/ETH',
#    'percent_volume': 0.00113735015424,
#    'price': 0.520935,
#    'updated': True,
#    'volume_24h': 11895.4},
#   {'currency': 'SALT',
#    'pair': 'SALT/BTC',
#    'percent_volume': 0.00112837213084,
#    'price': 2.75861,
#    'updated': True,
#    'volume_24h': 11801.5},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/BTC',
#    'percent_volume': 0.00112706223818,
#    'price': 0.0196883,
#    'updated': True,
#    'volume_24h': 11787.8},
#   {'currency': 'Datum',
#    'pair': 'DAT/USDT',
#    'percent_volume': 0.00111721414011,
#    'price': 0.0249397,
#    'updated': True,
#    'volume_24h': 11684.8},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/BTC',
#    'percent_volume': 0.00110951732559,
#    'price': 0.0202723,
#    'updated': True,
#    'volume_24h': 11604.3},
#   {'currency': 'IPChain',
#    'pair': 'IPC/USDT',
#    'percent_volume': 0.00109920072576,
#    'price': 0.510813,
#    'updated': True,
#    'volume_24h': 11496.4},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/ETH',
#    'percent_volume': 0.00109790995562,
#    'price': 309.995,
#    'updated': True,
#    'volume_24h': 11482.9},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/BTC',
#    'percent_volume': 0.00109054778521,
#    'price': 6.1254,
#    'updated': True,
#    'volume_24h': 11405.9},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/ETH',
#    'percent_volume': 0.00108262150045,
#    'price': 0.184695,
#    'updated': True,
#    'volume_24h': 11323.0},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/USDT',
#    'percent_volume': 0.000949008624921,
#    'price': 0.0478762,
#    'updated': True,
#    'volume_24h': 9925.56},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/ETH',
#    'percent_volume': 0.00089670853124,
#    'price': 0.0492571,
#    'updated': True,
#    'volume_24h': 9378.56},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/BCH',
#    'percent_volume': 0.000895805948271,
#    'price': 157.645,
#    'updated': True,
#    'volume_24h': 9369.12},
#   {'currency': 'FunFair',
#    'pair': 'FUN/BTC',
#    'percent_volume': 0.000894303874282,
#    'price': 0.0374578,
#    'updated': True,
# ...
#    'volume_24h': 3220.53},
#   {'currency': 'OST',
#    'pair': 'OST/USDT',
#    'percent_volume': 0.000303253535879,
#    'price': 0.166265,
#    'updated': True,
#    'volume_24h': 3171.69},
#   {'currency': 'Read',
#    'pair': 'READ/BTC',
#    'percent_volume': 0.000297018638056,
#    'price': 0.0181866,
#    'updated': True,
#    'volume_24h': 3106.48},
#   {'currency': 'Centra',
#    'pair': 'CTR/ETH',
#    'percent_volume': 0.00028113642862,
#    'price': 0.467796,
#    'updated': True,
#    'volume_24h': 2940.37},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/ETH',
#    'percent_volume': 0.000278134192895,
#    'price': 13.1825,
#    'updated': True,
#    'volume_24h': 2908.97},
#   {'currency': 'Aventus',
#    'pair': 'AVT/USDT',
#    'percent_volume': 0.000272864026234,
#    'price': 1.05728,
#    'updated': True,
#    'volume_24h': 2853.85},
#   {'currency': 'Enigma',
#    'pair': 'ENG/ETH',
#    'percent_volume': 0.000272573363922,
#    'price': 1.84213,
#    'updated': True,
#    'volume_24h': 2850.81},
#   {'currency': 'Monaco',
#    'pair': 'MCO/ETH',
#    'percent_volume': 0.00026397014193,
#    'price': 5.92255,
#    'updated': True,
#    'volume_24h': 2760.83},
#   {'currency': 'Refereum',
#    'pair': 'RFR/USDT',
#    'percent_volume': 0.000262608618468,
#    'price': 0.00891419,
#    'updated': True,
#    'volume_24h': 2746.59},
#   {'currency': 'Achain',
#    'pair': 'ACT/BCH',
#    'percent_volume': 0.00026062274471,
#    'price': 0.195673,
#    'updated': True,
#    'volume_24h': 2725.82},
#   {'currency': 'Civic',
#    'pair': 'CVC/ETH',
#    'percent_volume': 0.00025991521145,
#    'price': 0.240724,
#    'updated': True,
#    'volume_24h': 2718.42},
#   {'currency': 'Substratum',
#    'pair': 'SUB/BTC',
#    'percent_volume': 0.00024980513484,
#    'price': 0.492708,
#    'updated': True,
#    'volume_24h': 2612.68},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/BTC',
#    'percent_volume': 0.000246225398994,
#    'price': 0.968981,
#    'updated': True,
#    'volume_24h': 2575.24},
#   {'currency': 'AirSwap',
#    'pair': 'AST/ETH',
#    'percent_volume': 0.000245712915444,
#    'price': 0.265534,
#    'updated': True,
#    'volume_24h': 2569.88},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/ETH',
#    'percent_volume': 0.000243556851253,
#    'price': 0.36871,
#    'updated': True,
#    'volume_24h': 2547.33},
#   {'currency': 'Storj',
#    'pair': 'STORJ/ETH',
#    'percent_volume': 0.000236236750389,
#    'price': 0.800523,
#    'updated': True,
#    'volume_24h': 2470.77},
#   {'currency': 'Metal',
#    'pair': 'MTL/USDT',
#    'percent_volume': 0.000236136357157,
#    'price': 4.0848,
#    'updated': True,
#    'volume_24h': 2469.72},
#   {'currency': 'Revain',
#    'pair': 'R/USDT',
#    'percent_volume': 0.000234650537311,
#    'price': 0.93659,
#    'updated': True,
#    'volume_24h': 2454.18},
#   {'currency': 'SunContract',
#    'pair': 'SNC/USDT',
#    'percent_volume': 0.000229904327712,
#    'price': 0.186697,
#    'updated': True,
#    'volume_24h': 2404.54},
#   {'currency': 'Waltonchain',
#    'pair': 'WTC/ETH',
#    'percent_volume': 0.000217421146303,
#    'price': 12.0392,
#    'updated': True,
#    'volume_24h': 2273.98},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/ETH',
#    'percent_volume': 0.000209739629801,
#    'price': 0.0200603,
#    'updated': True,
#    'volume_24h': 2193.64},
#   {'currency': 'Monaco',
#    'pair': 'MCO/USDT',
#    'percent_volume': 0.000202205356708,
#    'price': 5.81846,
#    'updated': True,
#    'volume_24h': 2114.84},
#   {'currency': 'Po.et',
#    'pair': 'POE/BTC',
#    'percent_volume': 0.00019442918373,
#    'price': 0.0301998,
#    'updated': True,
#    'volume_24h': 2033.51},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/USDT',
#    'percent_volume': 0.000174286476718,
#    'price': 0.201621,
#    'updated': True,
#    'volume_24h': 1822.84},
#   {'currency': 'Viuly',
#    'pair': 'VIU/BTC',
#    'percent_volume': 0.000163725108623,
#    'price': 0.0053392,
#    'updated': True,
#    'volume_24h': 1712.38},
#   {'currency': 'Golem',
#    'pair': 'GNT/ETH',
#    'percent_volume': 0.000154966038089,
#    'price': 0.263057,
#    'updated': True,
#    'volume_24h': 1620.77},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/USDT',
#    'percent_volume': 0.000146436437801,
#    'price': 0.38942,
#    'updated': True,
#    'volume_24h': 1531.56},
#   {'currency': 'Republic Protocol',
#    'pair': 'REN/USDT',
#    'percent_volume': 0.000138793166341,
#    'price': 0.0468746,
#    'updated': True,
#    'volume_24h': 1451.62},
#   {'currency': 'Enjin Coin',
#    'pair': 'ENJ/ETH',
#    'percent_volume': 0.000138790297963,
#    'price': 0.117461,
#    'updated': True,
#    'volume_24h': 1451.59},
#   {'currency': 'Populous',
#    'pair': 'PPT/BTC',
#    'percent_volume': 0.000131539038174,
#    'price': 14.5537,
#    'updated': True,
#    'volume_24h': 1375.75},
#   {'currency': 'SmartMesh',
#    'pair': 'SMT/ETH',
#    'percent_volume': 0.000123366072894,
#    'price': 0.0296104,
#    'updated': True,
#    'volume_24h': 1290.27},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/USDT',
#    'percent_volume': 0.000115028653938,
#    'price': 0.167467,
#    'updated': True,
#    'volume_24h': 1203.07},
#   {'currency': 'Substratum',
#    'pair': 'SUB/ETH',
#    'percent_volume': 0.000112929001183,
#    'price': 0.369507,
#    'updated': True,
#    'volume_24h': 1181.11},
#   {'currency': 'Viuly',
#    'pair': 'VIU/ETH',
#    'percent_volume': 0.000112364886827,
#    'price': 0.00545939,
#    'updated': True,
#    'volume_24h': 1175.21},
#   {'currency': 'Everex',
#    'pair': 'EVX/BTC',
#    'percent_volume': 0.000110542510619,
#    'price': 1.14384,
#    'updated': True,
#    'volume_24h': 1156.15},
#   {'currency': 'Primas',
#    'pair': 'PST/ETH',
#    'percent_volume': 0.000105978921092,
#    'price': 0.178684,
#    'updated': True,
#    'volume_24h': 1108.42},
#   {'currency': 'district0x',
#    'pair': 'DNT/ETH',
#    'percent_volume': 0.000105298159361,
#    'price': 0.0495022,
#    'updated': True,
#    'volume_24h': 1101.3},
#   {'currency': 'SunContract',
#    'pair': 'SNC/ETH',
#    'percent_volume': 0.000104883200665,
#    'price': 0.198152,
#    'updated': True,
#    'volume_24h': 1096.96},
#   {'currency': 'Read',
#    'pair': 'READ/ETH',
#    'percent_volume': 0.000101138055017,
#    'price': 0.0180277,
#    'updated': True,
#    'volume_24h': 1057.79},
#   {'currency': '0x',
#    'pair': 'ZRX/USDT',
#    'percent_volume': 9.68345317692e-05,
#    'price': 0.536955,
#    'updated': True,
#    'volume_24h': 1012.78},
#   {'currency': 'Bancor',
#    'pair': 'BNT/ETH',
#    'percent_volume': 9.55829627998e-05,
#    'price': 2.82064,
#    'updated': True,
#    'volume_24h': 999.69},
#   {'currency': 'Everex',
#    'pair': 'EVX/USDT',
#    'percent_volume': 8.90033815445e-05,
#    'price': 1.30207,
#    'updated': True,
#    'volume_24h': 930.875},
#   {'currency': 'Enjin Coin',
#    'pair': 'ENJ/BTC',
#    'percent_volume': 8.57513100887e-05,
#    'price': 0.105699,
#    'updated': True,
#    'volume_24h': 896.862},
#   {'currency': 'Gas',
#    'pair': 'GAS/ETH',
#    'percent_volume': 8.39560878602e-05,
#    'price': 20.577,
#    'updated': True,
#    'volume_24h': 878.086},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/BTC',
#    'percent_volume': 8.18623630862e-05,
#    'price': 0.378749,
#    'updated': True,
#    'volume_24h': 856.188},
#   {'currency': 'Viberate',
#    'pair': 'VIB/ETH',
#    'percent_volume': 7.1758788133e-05,
#    'price': 0.131541,
#    'updated': True,
#    'volume_24h': 750.516},
#   {'currency': 'Bread',
#    'pair': 'BRD/ETH',
#    'percent_volume': 7.07944394221e-05,
#    'price': 0.43219,
#    'updated': True,
#    'volume_24h': 740.43},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/ETH',
#    'percent_volume': 6.73695003805e-05,
#    'price': 0.919245,
#    'updated': True,
#    'volume_24h': 704.609},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/ETH',
#    'percent_volume': 6.02690216657e-05,
#    'price': 0.232348,
#    'updated': True,
#    'volume_24h': 630.346},
#   {'currency': 'Maker',
#    'pair': 'MKR/BTC',
#    'percent_volume': 5.90985321834e-05,
#    'price': 654.407,
#    'updated': True,
#    'volume_24h': 618.104},
#   {'currency': 'OST',
#    'pair': 'OST/ETH',
#    'percent_volume': 5.50240967316e-05,
#    'price': 0.165605,
#    'updated': True,
#    'volume_24h': 575.49},
#   {'currency': 'Ace',
#    'pair': 'ACE/ETH',
#    'percent_volume': 5.21007414039e-05,
#    'price': 0.122027,
#    'updated': True,
#    'volume_24h': 544.915},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/ETH',
#    'percent_volume': 5.19994876576e-05,
#    'price': 0.17061,
#    'updated': True,
#    'volume_24h': 543.856},
#   {'currency': 'TenX',
#    'pair': 'PAY/ETH',
#    'percent_volume': 5.04783867611e-05,
#    'price': 1.07226,
#    'updated': True,
#    'volume_24h': 527.947},
#   {'currency': 'Change',
#    'pair': 'CAG/USDT',
#    'percent_volume': 5.0225491427e-05,
#    'price': 0.178785,
#    'updated': True,
#    'volume_24h': 525.302},
#   {'currency': 'BitcoinX',
#    'pair': 'BCX/BCH',
#    'percent_volume': 4.36948638243e-05,
#    'price': 0.00387471,
#    'updated': True,
#    'volume_24h': 456.999},
#   {'currency': 'Request Network',
#    'pair': 'REQ/ETH',
#    'percent_volume': 4.29114141577e-05,
#    'price': 0.206992,
#    'updated': True,
#    'volume_24h': 448.805},
#   {'currency': 'Enjin Coin',
#    'pair': 'ENJ/USDT',
#    'percent_volume': 4.06067679821e-05,
#    'price': 0.109174,
#    'updated': True,
#    'volume_24h': 424.701},
#   {'currency': 'district0x',
#    'pair': 'DNT/USDT',
#    'percent_volume': 4.02270903368e-05,
#    'price': 0.0470749,
#    'updated': True,
#    'volume_24h': 420.73},
#   {'currency': 'Populous',
#    'pair': 'PPT/ETH',
#    'percent_volume': 3.96973009052e-05,
#    'price': 13.8314,
#    'updated': True,
#    'volume_24h': 415.189},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/ETH',
#    'percent_volume': 3.9354147274e-05,
#    'price': 0.897862,
#    'updated': True,
#    'volume_24h': 411.6},
#   {'currency': 'Change',
#    'pair': 'CAG/BTC',
#    'percent_volume': 3.56312793625e-05,
#    'price': 0.166933,
#    'updated': True,
#    'volume_24h': 372.663},
#   {'currency': 'Po.et',
#    'pair': 'POE/ETH',
#    'percent_volume': 3.52562867346e-05,
#    'price': 0.0329351,
#    'updated': True,
#    'volume_24h': 368.741},
#   {'currency': 'Substratum',
#    'pair': 'SUB/USDT',
#    'percent_volume': 2.79017653344e-05,
#    'price': 0.390622,
#    'updated': True,
#    'volume_24h': 291.821},
#   {'currency': 'Everex',
#    'pair': 'EVX/ETH',
#    'percent_volume': 2.7885033129e-05,
#    'price': 1.26677,
#    'updated': True,
#    'volume_24h': 291.646},
#   {'currency': 'Change',
#    'pair': 'CAG/ETH',
#    'percent_volume': 2.66503875902e-05,
#    'price': 0.177274,
#    'updated': True,
#    'volume_24h': 278.733},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/ETH',
#    'percent_volume': 2.61984268172e-05,
#    'price': 0.0464635,
#    'updated': True,
#    'volume_24h': 274.006},
#   {'currency': 'Ark',
#    'pair': 'ARK/ETH',
#    'percent_volume': 2.57614772229e-05,
#    'price': 2.63726,
#    'updated': True,
#    'volume_24h': 269.436},
#   {'currency': 'Ark',
#    'pair': 'ARK/USDT',
#    'percent_volume': 2.30288690375e-05,
#    'price': 2.7045,
#    'updated': True,
#    'volume_24h': 240.856},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/ETH',
#    'percent_volume': 2.29403317674e-05,
#    'price': 0.0207702,
#    'updated': True,
#    'volume_24h': 239.93},
#   {'currency': 'Super Bitcoin',
#    'pair': 'SBTC/BCH',
#    'percent_volume': 1.94812590267e-05,
#    'price': 9.9677,
#    'updated': True,
#    'volume_24h': 203.752},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/BCH',
#    'percent_volume': 1.72225069003e-05,
#    'price': 56.9583,
#    'updated': True,
#    'volume_24h': 180.128},
#   {'currency': 'Bancor',
#    'pair': 'BNT/USDT',
#    'percent_volume': 1.63750924025e-05,
#    'price': 2.85094,
#    'updated': True,
#    'volume_24h': 171.265},
#   {'currency': 'Request Network',
#    'pair': 'REQ/BTC',
#    'percent_volume': 1.59373779074e-05,
#    'price': 0.206727,
#    'updated': True,
#    'volume_24h': 166.687},
#   {'currency': 'SONM',
#    'pair': 'SNM/USDT',
#    'percent_volume': 1.5212825604e-05,
#    'price': 0.123296,
#    'updated': True,
#    'volume_24h': 159.109},
#   {'currency': 'Maker',
#    'pair': 'MKR/USDT',
#    'percent_volume': 1.49002680058e-05,
#    'price': 653.142,
#    'updated': True,
#    'volume_24h': 155.84},
#   {'currency': 'SALT',
#    'pair': 'SALT/USDT',
#    'percent_volume': 1.43287914794e-05,
#    'price': 2.72093,
#    'updated': True,
#    'volume_24h': 149.863},
#   {'currency': 'Maker',
#    'pair': 'MKR/ETH',
#    'percent_volume': 7.70074419585e-06,
#    'price': 652.63,
#    'updated': True,
#    'volume_24h': 80.5411},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/USDT',
#    'percent_volume': 6.12660698867e-06,
#    'price': 0.164963,
#    'updated': True,
#    'volume_24h': 64.0774},
#   {'currency': 'LATOKEN',
#    'pair': 'LA/USDT',
#    'percent_volume': 3.6484526229e-06,
#    'price': 0.209233,
#    'updated': True,
#    'volume_24h': 38.1587},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/ETH',
#    'percent_volume': 2.9872149851e-06,
#    'price': 0.182621,
#    'updated': True,
#    'volume_24h': 31.2429},
#   {'currency': 'Request Network',
#    'pair': 'REQ/USDT',
#    'percent_volume': 2.4955462982e-06,
#    'price': 0.200419,
#    'updated': True,
#    'volume_24h': 26.1006},
#   {'currency': 'Aventus',
#    'pair': 'AVT/ETH',
#    'percent_volume': 2.3334638141e-06,
#    'price': 1.11116,
#    'updated': True,
#    'volume_24h': 24.4054},
#   {'currency': 'Aventus',
#    'pair': 'AVT/BCH',
#    'percent_volume': 1.88265995359e-06,
#    'price': 1.30903,
#    'updated': True,
#    'volume_24h': 19.6905},
#   {'currency': 'Metal',
#    'pair': 'MTL/ETH',
#    'percent_volume': 1.84228275147e-06,
#    'price': 3.62743,
#    'updated': True,
#    'volume_24h': 19.2682},
#   {'currency': 'NAGA',
#    'pair': 'NGC/USDT',
#    'percent_volume': 1.35382664802e-06,
#    'price': 0.708828,
#    'updated': True,
#    'volume_24h': 14.1595},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/ETH',
#    'percent_volume': 1.22233063552e-06,
#    'price': 1.62462,
#    'updated': True,
#    'volume_24h': 12.7842},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/ETH',
#    'percent_volume': 8.86509534909e-07,
#    'price': 0.172218,
#    'updated': True,
#    'volume_24h': 9.27189},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/BCH',
#    'percent_volume': 8.47149650879e-07,
#    'price': 323.791,
#    'updated': True,
#    'volume_24h': 8.86023},
#   {'currency': 'Monetha',
#    'pair': 'MTH/ETH',
#    'percent_volume': 7.12254610351e-07,
#    'price': 0.107247,
#    'updated': True,
#    'volume_24h': 7.44938},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/USDT',
#    'percent_volume': 3.76066357344e-07,
#    'price': 0.926775,
#    'updated': True,
#    'volume_24h': 3.93323},
#   {'currency': 'SingularDTV',
#    'pair': 'SNGLS/ETH',
#    'percent_volume': 2.33172366473e-07,
#    'price': 0.0562434,
#    'updated': True,
#    'volume_24h': 2.43872},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/ETH',
#    'percent_volume': 1.53189555931e-07,
#    'price': 0.16369,
#    'updated': True,
#    'volume_24h': 1.60219},
#   {'currency': 'SONM',
#    'pair': 'SNM/BTC',
#    'percent_volume': 0.0,
#    'price': 0.127223,
#    'updated': True,
#    'volume_24h': None},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/BTC',
#    'percent_volume': 0.0,
#    'price': 1.35315,
#    'updated': True,
#    'volume_24h': None},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/BCH',
#    'percent_volume': 0.0,
#    'price': 1.71606,
#    'updated': True,
#    'volume_24h': None},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/BCH',
#    'percent_volume': 0.0,
#    'price': 0.0882369,
#    'updated': True,
#    'volume_24h': None},
#   {'currency': 'OAX',
#    'pair': 'OAX/ETH',
#    'percent_volume': 0.0,
#    'price': 0.523504,
#    'updated': True,
#    'volume_24h': None},
#   {'currency': 'SONM',
#    'pair': 'SNM/ETH',
#    'percent_volume': 0.0,
#    'price': 0.117829,
#    'updated': True,
#    'volume_24h': None},
#   {'currency': 'FunFair',
#    'pair': 'FUN/ETH',
#    'percent_volume': 0.0,
#    'price': 0.0367704,
#    'updated': True,
#    'volume_24h': None},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/ETH',
#    'percent_volume': 0.0,
#    'price': 0.344462,
#    'updated': True,
#    'volume_24h': None},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/USDT',
#    'percent_volume': 0.0,
#    'price': 1.51691,
#    'updated': True,
#    'volume_24h': None}],
#  'name': 'OKEx ',
#  'slug': 'okex',
#  'social': {'twitter': {'link': 'https://twitter.com/CoinMarketCap',
#    'username': '@OKEx_'}},
#  'volume': 1045887227.93,
#  'web': 'https://www.okex.com'}

# %%
show_page("exchanges/okex")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/exchanges/okex"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# In order to obtain all available values for the `name` parameter, use:

# %%
cmc.exchange_slugs
# Out:
# ['1szb',
#  'abucoins',
#  'acx',
#  'aex',
#  'aidos-market',
#  'allcoin',
#  'altcoin-trader',
#  'bancor-network',
#  'barterdex',
#  'bcc-exchange',
#  'bcex',
#  'bibox',
#  'bigone',
#  'binance',
#  'bisq',
#  'bit-z',
#  'bit2c',
#  'bit520',
#  'bitbank',
#  'bitbay',
#  'bitbns',
#  'bitcoin-growth-fund-exchange',
#  'bitcoin-indonesia',
#  'bitcoinaverage',
#  'bitcointoyou',
#  'bitcointrade',
#  'bitex-la',
#  'bitfinex',
#  'bitflip',
#  'bitflyer',
#  'bithesap',
#  'bitholic',
#  'bithumb',
#  'bitinka',
#  'bitkonan',
#  'bitlish',
#  'bitmarket',
#  'bitmaszyna',
#  'bitmex',
#  'bitonic',
#  'bits-blockchain',
#  'bitsane',
#  'bitshares-asset-exchange',
#  'bitso',
#  'bitstamp',
#  'bitstamp-ripple-gateway',
#  'bitstar',
#  'bittrex',
#  'bittylicious',
#  'bityes',
#  'bl3p',
#  'bleutrade',
#  'braziliex',
#  'btc-alpha',
#  'btc-markets',
#  'btc-trade-ua',
#  'btcbox',
#  'btcc',
#  'btctrade-im',
#  'btcturk',
#  'btcxindia',
#  'btw18',
#  'burst-asset-exchange',
#  'bx-thailand',
#  'c-cex',
#  'c-patex',
#  'c2cx',
#  'cex-io',
#  'cfinex',
#  'chaoex',
#  'cobinhood',
#  'coinbe',
#  'coinbene',
#  'coincorner',
#  'coinegg',
#  'coinex',
#  'coinexchange',
#  'coinfalcon',
#  'coinfloor',
#  'coingi',
#  'coinhouse',
#  'coinlink',
#  'coinmate',
#  'coinnest',
#  'coinone',
#  'coinrail',
#  'coinrate',
#  'coinroom',
#  'coinsbank',
#  'coinsecure',
#  'coinsquare',
#  'coinut',
#  'coss',
#  'counterparty-dex',
#  'crex24',
#  'crxzone',
#  'cryptobridge',
#  'cryptoderivatives',
#  'cryptohub',
#  'cryptomarket',
#  'cryptomate',
#  'cryptonex',
#  'cryptopia',
#  'cryptox',
#  'dc-ex',
#  'dcexchange',
#  'ddex',
#  'dgtmarket',
#  'dsx',
#  'ethexindia',
#  'ethfinex',
#  'excambriorex',
#  'exmo',
#  'exrates',
#  'exx',
#  'ezbtc',
#  'fargobase',
#  'fatbtc',
#  'fisco',
#  'forkdelta',
#  'foxbit',
#  'freiexchange',
#  'gate-io',
#  'gatecoin',
#  'gatehub',
#  'gdax',
#  'gemini',
#  'getbtc',
#  'gopax',
#  'guldentrader',
#  'heat-wallet',
#  'hitbtc',
#  'huobi',
#  'hypex',
#  'idax',
#  'idex',
#  'independent-reserve',
#  'infinitycoin-exchange',
#  'iquant',
#  'isx',
#  'itbit',
#  'koineks',
#  'koinex',
#  'koinim',
#  'korbit',
#  'kraken',
#  'kucoin',
#  'kuna',
#  'lakebtc',
#  'latoken',
#  'lbank',
#  'lendconnect',
#  'leoxchange',
#  'lhang',
#  'liqui',
#  'litebit',
#  'livecoin',
#  'localtrade',
#  'luno',
#  'lykke-exchange',
#  'mbaex',
#  'mercado-bitcoin',
#  'mercatox',
#  'mr-exchange',
#  'nanex',
#  'negocie-coins',
#  'neraexpro',
#  'nhz-asset-exchange',
#  'nix-e',
#  'nocks',
#  'nxt-asset-exchange',
#  'nxt-monetary-system',
#  'oasisdex',
#  'octaex',
#  'oex',
#  'okcoin-cn',
#  'okcoin-intl',
#  'okex',
#  'omni-dex',
#  'ooobtc',
#  'openledger',
#  'ore-bz',
#  'otcbtc',
#  'ovis',
#  'paradex',
#  'paribu',
#  'paymium',
#  'poloniex',
#  'qbtc',
#  'qryptos',
#  'quadrigacx',
#  'quoine',
#  'radar-relay',
#  'rfinex',
#  'rightbtc',
#  'rippex',
#  'ripple-charts',
#  'ripple-china',
#  'ripplefox',
#  'rudex',
#  'simex',
#  'southxchange',
#  'stellar-decentralized-exchange',
#  'stellarport',
#  'stocks-exchange',
#  'stronghold',
#  'surbtc',
#  'tcc-exchange',
#  'tdax',
#  'therocktrading',
#  'tidebit',
#  'tidex',
#  'token-store',
#  'topbtc',
#  'trade-by-trade',
#  'trade-satoshi',
#  'tradeogre',
#  'triple-dice-exchange',
#  'tux-exchange',
#  'unocoin',
#  'upbit',
#  'vebitcoin',
#  'virtacoinworld',
#  'waves-dex',
#  'wex',
#  'xbtce',
#  'yobit',
#  'yobtc',
#  'zaif',
#  'zb-com',
#  'zebpay']

# %% [markdown]
# If you want to get all formatted exchange names:

# %%
cmc.exchange_names
# Out:
# ['1szb',
#  'ACX',
#  'AEX',
#  'Abucoins',
#  'AidosMarket',
#  'Allcoin',
#  'Altcoin Trader',
#  'BCC Exchange',
#  'BCEX',
#  'BITHOLIC',
#  'BL3P',
#  'BTC Markets',
#  'BTC Trade UA',
#  'BTC-Alpha',
#  'BTCBOX',
#  'BTCC',
#  'BTCTurk',
#  'BTCXIndia',
#  'BX Thailand',
#  'Bancor Network',
#  'BarterDEX',
#  'Bibox',
#  'BigONE',
#  'Binance',
#  'Bisq',
#  'Bit-Z',
#  'Bit2C',
#  'Bit520',
#  'BitBay',
#  'BitFlip',
#  'BitKonan',
#  'BitMEX',
#  'BitMarket',
#  'BitShares Asset Exchange',
#  'BitStar',
#  'BitYes',
#  'Bitbank',
#  'Bitbns',
#  'Bitcoin Growth Fund Exchange',
#  'Bitcoin Indonesia',
#  'BitcoinAverage',
#  'BitcoinToYou',
#  'BitcoinTrade',
#  'Bitex.la',
#  'Bitfinex',
#  'Bithesap',
#  'Bithumb',
#  'Bitinka',
#  'Bitlish',
#  'Bitmaszyna',
#  'Bitonic',
#  'Bits Blockchain',
#  'Bitsane',
#  'Bitso',
#  'Bitstamp',
#  'Bitstamp (Ripple Gateway)',
#  'Bittrex',
#  'Bittylicious',
#  'Bleutrade',
#  'Braziliex',
#  'BtcTrade.im',
#  'Burst Asset Exchange',
#  'C-CEX',
#  'C-Patex',
#  'C2CX',
#  'CEX.IO',
#  'COSS',
#  'CRXzone',
#  'ChaoEX',
#  'Cobinhood',
#  'CoinBene',
#  'CoinCorner',
#  'CoinEgg',
#  'CoinEx',
#  'CoinExchange',
#  'CoinFalcon',
#  'CoinMate',
#  'Coinbe',
#  'Coinfloor',
#  'Coingi',
#  'Coinhouse',
#  'Coinlink',
#  'Coinnest',
#  'Coinone',
#  'Coinrail',
#  'Coinrate',
#  'Coinroom',
#  'CoinsBank',
#  'Coinsecure',
#  'Coinsquare',
#  'Coinut',
#  'Counterparty DEX',
#  'Crex24',
#  'CryptoBridge',
#  'CryptoDerivatives',
#  'CryptoMarket',
#  'Cryptohub',
#  'Cryptomate',
#  'Cryptonex',
#  'Cryptopia',
#  'Cryptox',
#  'DC-Ex',
#  'DCExchange',
#  'DDEX',
#  'DSX',
#  'Dgtmarket',
#  'ETHEXIndia',
#  'EXX',
#  'Ethfinex',
#  'ExcambrioRex',
#  'Exmo',
#  'Exrates',
#  'Fargobase',
#  'Fatbtc',
#  'Fisco',
#  'ForkDelta',
#  'Foxbit',
#  'FreiExchange',
#  'GDAX',
#  'GOPAX',
#  'Gate.io',
#  'Gatecoin',
#  'Gatehub',
#  'Gemini',
#  'GetBTC',
#  'GuldenTrader',
#  'Heat Wallet',
#  'HitBTC',
#  'Huobi',
#  'Hypex',
#  'IDAX',
#  'IDEX',
#  'ISX',
#  'Independent Reserve',
#  'InfinityCoin Exchange',
#  'Iquant',
#  'Koineks',
#  'Koinex',
#  'Koinim',
#  'Korbit',
#  'Kraken',
#  'Kucoin',
#  'Kuna',
#  'LATOKEN',
#  'LEOxChange',
#  'LakeBTC',
#  'Lbank',
#  'Lendconnect',
#  'Lhang',
#  'Liqui',
#  'LiteBit.eu',
#  'Livecoin',
#  'LocalTrade',
#  'Luno',
#  'Lykke Exchange',
#  'MBAex',
#  'Mercado Bitcoin',
#  'Mercatox',
#  'Mr. Exchange',
#  'NHZ Asset Exchange',
#  'NIX-E',
#  'Nanex',
#  'Negocie Coins',
#  'Neraex',
#  'Nocks',
#  'Nxt Asset Exchange',
#  'Nxt Monetary System',
#  'OEX',
#  'OKCoin.cn',
#  'OKEx',
#  'OTCBTC',
#  'OasisDEX',
#  'Octaex',
#  'OkCoin Intl.',
#  'Omni DEX',
#  'OpenLedger DEX',
#  'Ore.Bz',
#  'Ovis',
#  'Paradex',
#  'Paribu',
#  'Paymium',
#  'Poloniex',
#  'QBTC',
#  'Qryptos',
#  'QuadrigaCX',
#  'Quoine',
#  'Radar Relay',
#  'Rfinex',
#  'RightBTC',
#  'Rippex',
#  'Ripple China',
#  'Ripple Gateways',
#  'RippleFox',
#  'RuDEX',
#  'Simex',
#  'SouthXchange',
#  'Stellar Decentralized Exchange',
#  'Stellarport',
#  'Stocks.Exchange',
#  'Stronghold',
#  'SurBTC',
#  'TCC Exchange',
#  'TDAX',
#  'TOPBTC',
#  'The Rock Trading',
#  'Tidebit',
#  'Tidex',
#  'Token Store',
#  'Trade By Trade',
#  'Trade Satoshi',
#  'TradeOgre',
#  'Tripe Dice Exchange',
#  'Tux Exchange',
#  'Unocoin',
#  'Upbit',
#  'Vebitcoin',
#  'VirtacoinWorld',
#  'WEX',
#  'Waves Decentralized Exchange',
#  'YoBit',
#  'Yobtc',
#  'ZB.COM',
#  'Zaif',
#  'Zebpay',
#  'bitFlyer',
#  'btw18.com',
#  'cfinex',
#  'ezBtc',
#  'itBit',
#  'ooobtc',
#  'xBTCe']

# %% [markdown]
# #### `exchanges([convert="USD"])`
# Get all available exchanges in coinmarketcap ranked by volumes with some metadata:

# %%
cmc.exchanges()
# Out:
# []

# %%
show_page("exchanges/volume/24-hour")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/exchanges/volume/24-hour"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# > If you want to connect with exchanges see [`ccxt` library](https://github.com/ccxt/ccxt).

# %% [markdown]
# #### `tokens([convert="USD"])`
# Get platforms tokens data:

# %%
cmc.tokens()
# Out:
# [{'circulating_supply': 746598237.399,
#   'market_cap': 5001394398.49,
#   'name': 'EOS',
#   'platform': 'Ethereum',
#   'price': 6.69891,
#   'symbol': 'EOS',
#   'volume_24h': 975958000.0},
#  {'circulating_supply': 65748192475.5,
#   'market_cap': 2342943413.68,
#   'name': 'TRON',
#   'platform': 'Ethereum',
#   'price': 0.0356351,
#   'symbol': 'TRX',
#   'volume_24h': 198018000.0},
#  {'circulating_supply': 2287140813.52,
#   'market_cap': 2289405082.93,
#   'name': 'Tether',
#   'platform': 'Omni',
#   'price': 1.00099,
#   'symbol': 'USDT',
#   'volume_24h': 2059270000.0},
#  {'circulating_supply': 517784184.607,
#   'market_cap': 1681167579.79,
#   'name': 'VeChain',
#   'platform': 'Ethereum',
#   'price': 3.24685,
#   'symbol': 'VEN',
#   'volume_24h': 56127300.0},
#  {'circulating_supply': 387042512.048,
#   'market_cap': 1480898189.17,
#   'name': 'ICON',
#   'platform': 'Ethereum',
#   'price': 3.82619,
#   'symbol': 'ICX',
#   'volume_24h': 160366000.0},
#  {'circulating_supply': 102042551.763,
#   'market_cap': 1082865355.06,
#   'name': 'OmiseGO',
#   'platform': 'Ethereum',
#   'price': 10.6119,
#   'symbol': 'OMG',
#   'volume_24h': 28708700.0},
#  {'circulating_supply': 99014000.0,
#   'market_cap': 985266530.92,
#   'name': 'Binance Coin',
#   'platform': 'Ethereum',
#   'price': 9.95078,
#   'symbol': 'BNB',
#   'volume_24h': 79172500.0},
#  {'circulating_supply': 2000000.0,
#   'market_cap': 688286000.0,
#   'name': 'DigixDAO',
#   'platform': 'Ethereum',
#   'price': 344.143,
#   'symbol': 'DGD',
#   'volume_24h': 25446800.0},
#  {'circulating_supply': 37004026.8944,
#   'market_cap': 512812905.911,
#   'name': 'Populous',
#   'platform': 'Ethereum',
#   'price': 13.8583,
#   'symbol': 'PPT',
#   'volume_24h': 1545290.0},
#  {'circulating_supply': 618227.770106,
#   'market_cap': 413730388.31,
#   'name': 'Maker',
#   'platform': 'Ethereum',
#   'price': 669.22,
#   'symbol': 'MKR',
#   'volume_24h': 149545.0},
#  {'circulating_supply': 359478522.92,
#   'market_cap': 383610316.164,
#   'name': 'RChain',
#   'platform': 'Ethereum',
#   'price': 1.06713,
#   'symbol': 'RHOC',
#   'volume_24h': 537321.0},
#  {'circulating_supply': 233020472.114,
#   'market_cap': 370828779.322,
#   'name': 'Aeternity',
#   'platform': 'Ethereum',
#   'price': 1.5914,
#   'symbol': 'AE',
#   'volume_24h': 2590320.0},
#  {'circulating_supply': 11000000.0,
#   'market_cap': 363535700.0,
#   'name': 'Augur',
#   'platform': 'Ethereum',
#   'price': 33.0487,
#   'symbol': 'REP',
#   'volume_24h': 1933670.0},
#  {'circulating_supply': 3470483788.0,
#   'market_cap': 349980937.601,
#   'name': 'Status',
#   'platform': 'Ethereum',
#   'price': 0.100845,
#   'symbol': 'SNT',
#   'volume_24h': 22114200.0},
#  {'circulating_supply': 987000000.0,
#   'market_cap': 348467259.0,
#   'name': 'Bytom',
#   'platform': 'Ethereum',
#   'price': 0.353057,
#   'symbol': 'BTM',
#   'volume_24h': 13621100.0},
#  {'circulating_supply': 24898178.0,
#   'market_cap': 304093897.003,
#   'name': 'Waltonchain',
#   'platform': 'Ethereum',
#   'price': 12.2135,
#   'symbol': 'WTC',
#   'volume_24h': 3290490.0},
#  {'circulating_supply': 241236451.0,
#   'market_cap': 304044773.382,
#   'name': 'Ontology',
#   'platform': 'NEO',
#   'price': 1.26036,
#   'symbol': 'ONT',
#   'volume_24h': 23421300.0},
#  {'circulating_supply': 115319870.955,
#   'market_cap': 301837077.039,
#   'name': 'Aion',
#   'platform': 'Ethereum',
#   'price': 2.61739,
#   'symbol': 'AION',
#   'volume_24h': 11727200.0},
#  {'circulating_supply': 6605326965.64,
#   'market_cap': 285651988.358,
#   'name': 'Zilliqa',
#   'platform': 'Ethereum',
#   'price': 0.0432457,
#   'symbol': 'ZIL',
#   'volume_24h': 13773200.0},
#  {'circulating_supply': 2036645.44,
#   'market_cap': 276853434.532,
#   'name': 'Veritaseum',
#   'platform': 'Ethereum',
#   'price': 135.936,
#   'symbol': 'VERI',
#   'volume_24h': 684236.0},
#  {'circulating_supply': 519515848.98,
#   'market_cap': 272099023.483,
#   'name': '0x',
#   'platform': 'Ethereum',
#   'price': 0.523755,
#   'symbol': 'ZRX',
#   'volume_24h': 6398060.0},
#  {'circulating_supply': 572074043.309,
#   'market_cap': 245074231.857,
#   'name': 'Loopring',
#   'platform': 'Ethereum',
#   'price': 0.428396,
#   'symbol': 'LRC',
#   'volume_24h': 11228100.0},
#  {'circulating_supply': 91043076.0001,
#   'market_cap': 238214208.354,
#   'name': 'KuCoin Shares',
#   'platform': 'Ethereum',
#   'price': 2.6165,
#   'symbol': 'KCS',
#   'volume_24h': 463413.0},
#  {'circulating_supply': 350000000.0,
#   'market_cap': 220178350.0,
#   'name': 'QASH',
#   'platform': 'Ethereum',
#   'price': 0.629081,
#   'symbol': 'QASH',
#   'volume_24h': 4643890.0},
#  {'circulating_supply': 9954248.20393,
#   'market_cap': 205126197.314,
#   'name': 'Gas',
#   'platform': 'NEO',
#   'price': 20.6069,
#   'symbol': 'GAS',
#   'volume_24h': 4610400.0},
#  {'circulating_supply': 35500000.0,
#   'market_cap': 202773515.0,
#   'name': 'Nebulas',
#   'platform': 'Ethereum',
#   'price': 5.71193,
#   'symbol': 'NAS',
#   'volume_24h': 8964760.0},
#  {'circulating_supply': 1000000000.0,
#   'market_cap': 195597000.0,
#   'name': 'Basic Attenti...',
#   'platform': 'Ethereum',
#   'price': 0.195597,
#   'symbol': 'BAT',
#   'volume_24h': 3934460.0},
#  {'circulating_supply': 834262000.0,
#   'market_cap': 194625816.242,
#   'name': 'Golem',
#   'platform': 'Ethereum',
#   'price': 0.233291,
#   'symbol': 'GNT',
#   'volume_24h': 5923690.0},
#  {'circulating_supply': 238421940.0,
#   'market_cap': 190127430.256,
#   'name': 'Dragonchain',
#   'platform': 'Ethereum',
#   'price': 0.797441,
#   'symbol': 'DRGN',
#   'volume_24h': 1369270.0},
#  {'circulating_supply': 75975162.3385,
#   'market_cap': 180917374.822,
#   'name': 'Ethos',
#   'platform': 'Ethereum',
#   'price': 2.38127,
#   'symbol': 'ETHOS',
#   'volume_24h': 6189190.0},
#  {'circulating_supply': 184450000.0,
#   'market_cap': 174965765.45,
#   'name': 'Revain',
#   'platform': 'Ethereum',
#   'price': 0.948581,
#   'symbol': 'R',
#   'volume_24h': 4057770.0},
#  {'circulating_supply': 4605074688.66,
#   'market_cap': 174145964.934,
#   'name': 'FunFair',
#   'platform': 'Ethereum',
#   'price': 0.0378161,
#   'symbol': 'FUN',
#   'volume_24h': 1312580.0},
#  {'circulating_supply': 134132696.93,
#   'market_cap': 159144420.927,
#   'name': 'Kyber Network',
#   'platform': 'Ethereum',
#   'price': 1.18647,
#   'symbol': 'KNC',
#   'volume_24h': 5835430.0},
#  {'circulating_supply': 8400000000.0,
#   'market_cap': 158009040.0,
#   'name': 'IOStoken',
#   'platform': 'Ethereum',
#   'price': 0.0188106,
#   'symbol': 'IOST',
#   'volume_24h': 24606000.0},
#  {'circulating_supply': 55798538.4326,
#   'market_cap': 153052043.008,
#   'name': 'SALT',
#   'platform': 'Ethereum',
#   'price': 2.74294,
#   'symbol': 'SALT',
#   'volume_24h': 9736900.0},
#  {'circulating_supply': 250000000.0,
#   'market_cap': 146043750.0,
#   'name': 'aelf',
#   'platform': 'Ethereum',
#   'price': 0.584175,
#   'symbol': 'ELF',
#   'volume_24h': 15156300.0},
#  {'circulating_supply': 74836171.09,
#   'market_cap': 134403518.193,
#   'name': 'Enigma',
#   'platform': 'Ethereum',
#   'price': 1.79597,
#   'symbol': 'ENG',
#   'volume_24h': 14387400.0},
#  {'circulating_supply': 350000000.0,
#   'market_cap': 134209250.0,
#   'name': 'ChainLink',
#   'platform': 'Ethereum',
#   'price': 0.383455,
#   'symbol': 'LINK',
#   'volume_24h': 9626400.0},
#  {'circulating_supply': 662706995.54,
#   'market_cap': 133758129.152,
#   'name': 'Request Network',
#   'platform': 'Ethereum',
#   'price': 0.201836,
#   'symbol': 'REQ',
#   'volume_24h': 5624540.0},
#  {'circulating_supply': 452552412.0,
#   'market_cap': 128872445.26,
#   'name': 'MaidSafeCoin',
#   'platform': 'Omni',
#   'price': 0.284768,
#   'symbol': 'MAID',
#   'volume_24h': 1093220.0},
#  {'circulating_supply': 756097560976.0,
#   'market_cap': 125125829.268,
#   'name': 'Kin',
#   'platform': 'Ethereum',
#   'price': 0.000165489,
#   'symbol': 'KIN',
#   'volume_24h': 339893.0},
#  {'circulating_supply': 363932946.92,
#   'market_cap': 124043269.561,
#   'name': 'Power Ledger',
#   'platform': 'Ethereum',
#   'price': 0.340841,
#   'symbol': 'POWR',
#   'volume_24h': 6694920.0},
#  {'circulating_supply': 325226613094.0,
#   'market_cap': 122019171.154,
#   'name': 'Dentacoin',
#   'platform': 'Ethereum',
#   'price': 0.000375182,
#   'symbol': 'DCN',
#   'volume_24h': 55188.3},
#  {'circulating_supply': 3983937436.01,
#   'market_cap': 121935177.923,
#   'name': 'Nucleus Vision',
#   'platform': 'Ethereum',
#   'price': 0.0306067,
#   'symbol': 'NCASH',
#   'volume_24h': 14126400.0},
#  {'circulating_supply': 239999750.0,
#   'market_cap': 118739636.313,
#   'name': 'Polymath',
#   'platform': 'Ethereum',
#   'price': 0.494749,
#   'symbol': 'POLY',
#   'volume_24h': 663852.0},
#  {'circulating_supply': 104661310.0,
#   'market_cap': 116199172.814,
#   'name': 'TenX',
#   'platform': 'Ethereum',
#   'price': 1.11024,
#   'symbol': 'PAY',
#   'volume_24h': 4568140.0},
#  {'circulating_supply': 40670871.2747,
#   'market_cap': 115985190.701,
#   'name': 'Bancor',
#   'platform': 'Ethereum',
#   'price': 2.8518,
#   'symbol': 'BNT',
#   'volume_24h': 6192440.0},
#  {'circulating_supply': 4088853037.1,
#   'market_cap': 114656754.669,
#   'name': 'Storm',
#   'platform': 'Ethereum',
#   'price': 0.0280413,
#   'symbol': 'STORM',
#   'volume_24h': 15259900.0},
#  {'circulating_supply': 133425492.59,
#   'market_cap': 110407860.587,
#   'name': 'Storj',
#   'platform': 'Ethereum',
#   'price': 0.827487,
#   'symbol': 'STORJ',
#   'volume_24h': 8026990.0},
#  {'circulating_supply': 1445976590.33,
#   'market_cap': 109661563.231,
#   'name': 'Cindicator',
#   'platform': 'Ethereum',
#   'price': 0.0758391,
#   'symbol': 'CND',
#   'volume_24h': 1409770.0},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 101158400.0,
#   'name': 'Nuls',
#   'platform': 'Ethereum',
#   'price': 2.52896,
#   'symbol': 'NULS',
#   'volume_24h': 9667450.0},
#  {'circulating_supply': 99735686.8829,
#   'market_cap': 99438374.8003,
#   'name': 'Iconomi',
#   'platform': 'Ethereum',
#   'price': 0.997019,
#   'symbol': 'ICN',
#   'volume_24h': 1070520.0},
#  {'circulating_supply': 10614760961.2,
#   'market_cap': 95037139.3138,
#   'name': 'Dent',
#   'platform': 'Ethereum',
#   'price': 0.0089533,
#   'symbol': 'DENT',
#   'volume_24h': 1240530.0},
#  {'circulating_supply': 26341130.9745,
#   'market_cap': 93582399.4243,
#   'name': 'Aragon',
#   'platform': 'Ethereum',
#   'price': 3.55271,
#   'symbol': 'ANT',
#   'volume_24h': 580882.0},
#  {'circulating_supply': 227384800.0,
#   'market_cap': 93582033.5184,
#   'name': 'Pillar',
#   'platform': 'Ethereum',
#   'price': 0.411558,
#   'symbol': 'PLR',
#   'volume_24h': 52000.5},
#  {'circulating_supply': 5961115777.45,
#   'market_cap': 93541232.6681,
#   'name': 'THEKEY',
#   'platform': 'NEO',
#   'price': 0.0156919,
#   'symbol': 'TKY',
#   'volume_24h': 881441.0},
#  {'circulating_supply': 229258029.0,
#   'market_cap': 89537411.0,
#   'name': 'SIRIN LABS Token',
#   'platform': 'Ethereum',
#   'price': 0.390553,
#   'symbol': 'SRN',
#   'volume_24h': 6942830.0},
#  {'circulating_supply': 22342464.1598,
#   'market_cap': 89220162.1293,
#   'name': 'Metal',
#   'platform': 'Ethereum',
#   'price': 3.9933,
#   'symbol': 'MTL',
#   'volume_24h': 10679400.0},
#  {'circulating_supply': 226091448.88,
#   'market_cap': 87535826.2629,
#   'name': 'Substratum',
#   'platform': 'Ethereum',
#   'price': 0.38717,
#   'symbol': 'SUB',
#   'volume_24h': 5030020.0},
#  {'circulating_supply': 1104590.0,
#   'market_cap': 87333303.76,
#   'name': 'Gnosis',
#   'platform': 'Ethereum',
#   'price': 79.064,
#   'symbol': 'GNO',
#   'volume_24h': 245118.0},
#  {'circulating_supply': 3726780.89997,
#   'market_cap': 86985302.2738,
#   'name': 'Genesis Vision',
#   'platform': 'Ethereum',
#   'price': 23.3406,
#   'symbol': 'GVT',
#   'volume_24h': 8581020.0},
#  {'circulating_supply': 1050141509.43,
#   'market_cap': 86439878.0088,
#   'name': 'Decentraland',
#   'platform': 'Ethereum',
#   'price': 0.0823126,
#   'symbol': 'MANA',
#   'volume_24h': 6279310.0},
#  {'circulating_supply': 1189228953.0,
#   'market_cap': 83697458.0206,
#   'name': 'Dynamic Tradi...',
#   'platform': 'Ethereum',
#   'price': 0.0703796,
#   'symbol': 'DTR',
#   'volume_24h': 9751.16},
#  {'circulating_supply': 80070793.2388,
#   'market_cap': 83578694.6906,
#   'name': 'iExec RLC',
#   'platform': 'Ethereum',
#   'price': 1.04381,
#   'symbol': 'RLC',
#   'volume_24h': 1185060.0},
#  {'circulating_supply': 521710039.585,
#   'market_cap': 83545080.6091,
#   'name': 'SingularityNET',
#   'platform': 'Ethereum',
#   'price': 0.160137,
#   'symbol': 'AGI',
#   'volume_24h': 1114800.0},
#  {'circulating_supply': 617314170.819,
#   'market_cap': 82947270.5045,
#   'name': 'Quantstamp',
#   'platform': 'Ethereum',
#   'price': 0.134368,
#   'symbol': 'QSP',
#   'volume_24h': 4918080.0},
#  {'circulating_supply': 588083732.0,
#   'market_cap': 81839496.3963,
#   'name': 'Theta Token',
#   'platform': 'Ethereum',
#   'price': 0.139163,
#   'symbol': 'THETA',
#   'volume_24h': 9487910.0},
#  {'circulating_supply': 342699966.0,
#   'market_cap': 81578698.8064,
#   'name': 'Civic',
#   'platform': 'Ethereum',
#   'price': 0.238047,
#   'symbol': 'CVC',
#   'volume_24h': 5181770.0},
#  {'circulating_supply': 756192535.064,
#   'market_cap': 80531480.2142,
#   'name': 'Enjin Coin',
#   'platform': 'Ethereum',
#   'price': 0.106496,
#   'symbol': 'ENJ',
#   'volume_24h': 7425600.0},
#  {'circulating_supply': 236481167.798,
#   'market_cap': 79399734.4938,
#   'name': 'Genaro Network',
#   'platform': 'Ethereum',
#   'price': 0.335755,
#   'symbol': 'GNX',
#   'volume_24h': 3324970.0},
#  {'circulating_supply': 13205542.215,
#   'market_cap': 78792056.1244,
#   'name': 'Monaco',
#   'platform': 'Ethereum',
#   'price': 5.96659,
#   'symbol': 'MCO',
#   'volume_24h': 9296240.0},
#  {'circulating_supply': 2261619182.22,
#   'market_cap': 78582220.1054,
#   'name': 'Time New Bank',
#   'platform': 'Ethereum',
#   'price': 0.034746,
#   'symbol': 'TNB',
#   'volume_24h': 4190000.0},
#  {'circulating_supply': 62660370.957,
#   'market_cap': 77247705.3158,
#   'name': 'Santiment Net...',
#   'platform': 'Ethereum',
#   'price': 1.2328,
#   'symbol': 'SAN',
#   'volume_24h': 2093490.0},
#  {'circulating_supply': 50168936.0,
#   'market_cap': 73878273.4642,
#   'name': 'Raiden Networ...',
#   'platform': 'Ethereum',
#   'price': 1.47259,
#   'symbol': 'RDN',
#   'volume_24h': 6462690.0},
#  {'circulating_supply': 761143950.0,
#   'market_cap': 72576750.1492,
#   'name': 'Ignis',
#   'platform': 'Ardor',
#   'price': 0.0953522,
#   'symbol': 'IGNIS',
#   'volume_24h': 989673.0},
#  {'circulating_supply': 136458571.601,
#   'market_cap': 70483172.0275,
#   'name': 'Credits',
#   'platform': 'Ethereum',
#   'price': 0.516517,
#   'symbol': 'CS',
#   'volume_24h': 1818740.0},
#  {'circulating_supply': 492954537.351,
#   'market_cap': 70308626.7988,
#   'name': 'WAX',
#   'platform': 'Ethereum',
#   'price': 0.142627,
#   'symbol': 'WAX',
#   'volume_24h': 1709370.0},
#  {'circulating_supply': 22216600.0,
#   'market_cap': 70227339.098,
#   'name': 'High Performa...',
#   'platform': 'Ethereum',
#   'price': 3.16103,
#   'symbol': 'HPB',
#   'volume_24h': 8993080.0},
#  {'circulating_supply': 2236813969.0,
#   'market_cap': 69287102.141,
#   'name': 'Po.et',
#   'platform': 'Ethereum',
#   'price': 0.0309758,
#   'symbol': 'POE',
#   'volume_24h': 2965240.0},
#  {'circulating_supply': 103244552.962,
#   'market_cap': 67198678.9418,
#   'name': 'DEW',
#   'platform': 'Ethereum',
#   'price': 0.650869,
#   'symbol': 'DEW',
#   'volume_24h': 192881.0},
#  {'circulating_supply': 82500000.0,
#   'market_cap': 64397850.0,
#   'name': 'PayPie',
#   'platform': 'Ethereum',
#   'price': 0.78058,
#   'symbol': 'PPP',
#   'volume_24h': 66305.3},
#  {'circulating_supply': 92825625.9878,
#   'market_cap': 62429039.3275,
#   'name': 'Arcblock',
#   'platform': 'Ethereum',
#   'price': 0.672541,
#   'symbol': 'ABT',
#   'volume_24h': 50419000.0},
#  {'circulating_supply': 105918066.049,
#   'market_cap': 61636264.6673,
#   'name': 'Bibox Token',
#   'platform': 'Ethereum',
#   'price': 0.581924,
#   'symbol': 'BIX',
#   'volume_24h': 3563440.0},
#  {'circulating_supply': 388367506.935,
#   'market_cap': 59663346.6204,
#   'name': 'Loom Network',
#   'platform': 'Ethereum',
#   'price': 0.153626,
#   'symbol': 'LOOM',
#   'volume_24h': 2698890.0},
#  {'circulating_supply': 82046297.0,
#   'market_cap': 59087035.5716,
#   'name': 'Edgeless',
#   'platform': 'Ethereum',
#   'price': 0.720167,
#   'symbol': 'EDG',
#   'volume_24h': 694537.0},
#  {'circulating_supply': 107339884.091,
#   'market_cap': 58668116.4083,
#   'name': 'Envion',
#   'platform': 'Ethereum',
#   'price': 0.546564,
#   'symbol': 'EVN',
#   'volume_24h': 48732.2},
#  {'circulating_supply': 71266926.2205,
#   'market_cap': 57473141.3836,
#   'name': 'Oyster',
#   'platform': 'Ethereum',
#   'price': 0.806449,
#   'symbol': 'PRL',
#   'volume_24h': 439415.0},
#  {'circulating_supply': 27648200.0,
#   'market_cap': 56447671.048,
#   'name': 'Fusion',
#   'platform': 'Ethereum',
#   'price': 2.04164,
#   'symbol': 'FSN',
#   'volume_24h': 1059210.0},
#  {'circulating_supply': 6274940000.0,
#   'market_cap': 56397842.9826,
#   'name': 'Cube',
#   'platform': 'Ethereum',
#   'price': 0.00898779,
#   'symbol': 'AUTO',
#   'volume_24h': 942749.0},
#  {'circulating_supply': 73430701.0,
#   'market_cap': 55946483.9384,
#   'name': 'AdEx',
#   'platform': 'Ethereum',
#   'price': 0.761895,
#   'symbol': 'ADX',
#   'volume_24h': 6674440.0},
#  {'circulating_supply': 48602869.08,
#   'market_cap': 54049792.6178,
#   'name': 'IoT Chain',
#   'platform': 'Ethereum',
#   'price': 1.11207,
#   'symbol': 'ITC',
#   'volume_24h': 8320710.0},
#  {'circulating_supply': 600149827.253,
#   'market_cap': 53115780.3412,
#   'name': 'CyberMiles',
#   'platform': 'Ethereum',
#   'price': 0.0885042,
#   'symbol': 'CMT',
#   'volume_24h': 12614200.0},
#  {'circulating_supply': 2966384100.0,
#   'market_cap': 52303581.0896,
#   'name': 'MediBloc',
#   'platform': 'Qtum',
#   'price': 0.0176321,
#   'symbol': 'MED',
#   'volume_24h': 982038.0},
#  {'circulating_supply': 952176609.766,
#   'market_cap': 52171089.4963,
#   'name': 'Leadcoin',
#   'platform': 'Ethereum',
#   'price': 0.0547914,
#   'symbol': 'LDC',
#   'volume_24h': 6243780.0},
#  {'circulating_supply': 300056960.0,
#   'market_cap': 52008872.8768,
#   'name': 'Scry.info',
#   'platform': 'Ethereum',
#   'price': 0.17333,
#   'symbol': 'DDD',
#   'volume_24h': 193158.0},
#  {'circulating_supply': 191773780.972,
#   'market_cap': 51511588.2118,
#   'name': 'SophiaTX',
#   'platform': 'Ethereum',
#   'price': 0.268606,
#   'symbol': 'SPHTX',
#   'volume_24h': 113867.0},
#  {'circulating_supply': 39528904.9307,
#   'market_cap': 50817174.3118,
#   'name': 'CRYPTO20',
#   'platform': 'Ethereum',
#   'price': 1.28557,
#   'symbol': 'C20',
#   'volume_24h': 2755050.0},
#  {'circulating_supply': 483511857.017,
#   'market_cap': 50597581.7894,
#   'name': 'MediShares',
#   'platform': 'Ethereum',
#   'price': 0.104646,
#   'symbol': 'MDS',
#   'volume_24h': 5786920.0},
#  {'circulating_supply': 1082449025.85,
#   'market_cap': 50480335.0552,
#   'name': 'ETHLend',
#   'platform': 'Ethereum',
#   'price': 0.0466353,
#   'symbol': 'LEND',
#   'volume_24h': 1712880.0},
#  {'circulating_supply': 165000000.0,
#   'market_cap': 49297875.0,
#   'name': 'Bluzelle',
#   'platform': 'Ethereum',
#   'price': 0.298775,
#   'symbol': 'BLZ',
#   'volume_24h': 4707490.0},
#  {'circulating_supply': 39614424.814,
#   'market_cap': 48563323.3795,
#   'name': 'Pundi X [OLD]',
#   'platform': 'Ethereum',
#   'price': 1.2259,
#   'symbol': 'PXS',
#   'volume_24h': 264045.0},
#  {'circulating_supply': 1531433921.3,
#   'market_cap': 47582111.3651,
#   'name': 'BLOCKv',
#   'platform': 'Ethereum',
#   'price': 0.0310703,
#   'symbol': 'VEE',
#   'volume_24h': 1629700.0},
#  {'circulating_supply': 29261461.2776,
#   'market_cap': 46771227.0915,
#   'name': 'Eidoo',
#   'platform': 'Ethereum',
#   'price': 1.59839,
#   'symbol': 'EDO',
#   'volume_24h': 6397550.0},
#  {'circulating_supply': 288515752.98,
#   'market_cap': 46706661.187,
#   'name': 'OST',
#   'platform': 'Ethereum',
#   'price': 0.161886,
#   'symbol': 'OST',
#   'volume_24h': 3904100.0},
#  {'circulating_supply': 28101791527.3,
#   'market_cap': 46357277.3392,
#   'name': 'Telcoin',
#   'platform': 'Ethereum',
#   'price': 0.00164962,
#   'symbol': 'TEL',
#   'volume_24h': 383224.0},
#  {'circulating_supply': 677154514.0,
#   'market_cap': 44968680.1121,
#   'name': 'Streamr DATAcoin',
#   'platform': 'Ethereum',
#   'price': 0.0664083,
#   'symbol': 'DATA',
#   'volume_24h': 126592.0},
#  {'circulating_supply': 359600000.0,
#   'market_cap': 44907207.6,
#   'name': 'SONM',
#   'platform': 'Ethereum',
#   'price': 0.124881,
#   'symbol': 'SNM',
#   'volume_24h': 835794.0},
#  {'circulating_supply': 489033039.761,
#   'market_cap': 44880175.8679,
#   'name': 'Ripio Credit ...',
#   'platform': 'Ethereum',
#   'price': 0.0917733,
#   'symbol': 'RCN',
#   'volume_24h': 7432000.0},
#  {'circulating_supply': 199913906.56,
#   'market_cap': 43070051.771,
#   'name': 'VIBE',
#   'platform': 'Ethereum',
#   'price': 0.215443,
#   'symbol': 'VIBE',
#   'volume_24h': 2286240.0},
#  {'circulating_supply': 543348500.0,
#   'market_cap': 43048958.3065,
#   'name': 'Red Pulse',
#   'platform': 'NEO',
#   'price': 0.079229,
#   'symbol': 'RPX',
#   'volume_24h': 1906170.0},
#  {'circulating_supply': 52000000.0,
#   'market_cap': 42535688.0,
#   'name': 'Quantum Resis...',
#   'platform': 'Ethereum',
#   'price': 0.817994,
#   'symbol': 'QRL',
#   'volume_24h': 473166.0},
#  {'circulating_supply': 57672338.0,
#   'market_cap': 42420484.5095,
#   'name': 'NAGA',
#   'platform': 'Ethereum',
#   'price': 0.735543,
#   'symbol': 'NGC',
#   'volume_24h': 130492.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 41471550.0,
#   'name': 'Jibrel Network',
#   'platform': 'Ethereum',
#   'price': 0.276477,
#   'symbol': 'JNT',
#   'volume_24h': 561436.0},
#  {'circulating_supply': 8146000.7794,
#   'market_cap': 41023504.3051,
#   'name': 'TaaS',
#   'platform': 'Ethereum',
#   'price': 5.03603,
#   'symbol': 'TAAS',
#   'volume_24h': 175512.0},
#  {'circulating_supply': 89708333.0,
#   'market_cap': 40495776.8495,
#   'name': 'Wings',
#   'platform': 'Ethereum',
#   'price': 0.451416,
#   'symbol': 'WINGS',
#   'volume_24h': 1829420.0},
#  {'circulating_supply': 77981576.9896,
#   'market_cap': 40484759.5467,
#   'name': 'Crypterium',
#   'platform': 'Ethereum',
#   'price': 0.519158,
#   'symbol': 'CRPT',
#   'volume_24h': 106068.0},
#  {'circulating_supply': 514991706.617,
#   'market_cap': 40476700.1666,
#   'name': 'SpaceChain',
#   'platform': 'Qtum',
#   'price': 0.0785968,
#   'symbol': 'SPC',
#   'volume_24h': 31447.1},
#  {'circulating_supply': 1413716693.85,
#   'market_cap': 40416887.9321,
#   'name': 'SmartMesh',
#   'platform': 'Ethereum',
#   'price': 0.0285891,
#   'symbol': 'SMT',
#   'volume_24h': 4400790.0},
#  {'circulating_supply': 599400.0,
#   'market_cap': 40343635.98,
#   'name': 'Melon',
#   'platform': 'Ethereum',
#   'price': 67.3067,
#   'symbol': 'MLN',
#   'volume_24h': 335325.0},
#  {'circulating_supply': 900000000.0,
#   'market_cap': 40203000.0,
#   'name': 'DeepBrain Chain',
#   'platform': 'NEO',
#   'price': 0.04467,
#   'symbol': 'DBC',
#   'volume_24h': 2671620.0},
#  {'circulating_supply': 4254336773.4,
#   'market_cap': 39726996.79,
#   'name': 'DATA',
#   'platform': 'Ethereum',
#   'price': 0.009338,
#   'symbol': 'DTA',
#   'volume_24h': 7377080.0},
#  {'circulating_supply': 285885272.987,
#   'market_cap': 39591679.6854,
#   'name': 'UTRUST',
#   'platform': 'Ethereum',
#   'price': 0.138488,
#   'symbol': 'UTK',
#   'volume_24h': 2008410.0},
#  {'circulating_supply': 254507605.599,
#   'market_cap': 39562952.7828,
#   'name': 'OriginTrail',
#   'platform': 'Ethereum',
#   'price': 0.155449,
#   'symbol': 'TRAC',
#   'volume_24h': 269840.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 39520950.0,
#   'name': 'AirSwap',
#   'platform': 'Ethereum',
#   'price': 0.263473,
#   'symbol': 'AST',
#   'volume_24h': 3963570.0},
#  {'circulating_supply': 144590975.0,
#   'market_cap': 39430826.4284,
#   'name': 'Ambrosus',
#   'platform': 'Ethereum',
#   'price': 0.272706,
#   'symbol': 'AMB',
#   'volume_24h': 593507.0},
#  {'circulating_supply': 183000000.0,
#   'market_cap': 38824914.0,
#   'name': 'Wagerr',
#   'platform': 'Waves',
#   'price': 0.212158,
#   'symbol': 'WGR',
#   'volume_24h': 64666.0},
#  {'circulating_supply': 18266200.0,
#   'market_cap': 38535471.492,
#   'name': 'Modum',
#   'platform': 'Ethereum',
#   'price': 2.10966,
#   'symbol': 'MOD',
#   'volume_24h': 919467.0},
#  {'circulating_supply': 157861326.54,
#   'market_cap': 38070153.231,
#   'name': 'Gifto',
#   'platform': 'Ethereum',
#   'price': 0.241162,
#   'symbol': 'GTO',
#   'volume_24h': 6059670.0},
#  {'circulating_supply': 300043386.0,
#   'market_cap': 37931484.8581,
#   'name': 'SpankChain',
#   'platform': 'Ethereum',
#   'price': 0.12642,
#   'symbol': 'SPANK',
#   'volume_24h': 148780.0},
#  {'circulating_supply': 100054311.845,
#   'market_cap': 37542378.8905,
#   'name': 'AppCoins',
#   'platform': 'Ethereum',
#   'price': 0.37522,
#   'symbol': 'APPC',
#   'volume_24h': 3135260.0},
#  {'circulating_supply': 98028877.0,
#   'market_cap': 37063640.0761,
#   'name': 'MobileGo',
#   'platform': 'Ethereum',
#   'price': 0.378089,
#   'symbol': 'MGO',
#   'volume_24h': 182944.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 36475260.0,
#   'name': 'SingularDTV',
#   'platform': 'Ethereum',
#   'price': 0.0607921,
#   'symbol': 'SNGLS',
#   'volume_24h': 619730.0},
#  {'circulating_supply': 45248032.811,
#   'market_cap': 36161911.0863,
#   'name': 'WaBi',
#   'platform': 'Ethereum',
#   'price': 0.799193,
#   'symbol': 'WABI',
#   'volume_24h': 2663330.0},
#  {'circulating_supply': 355419546.26,
#   'market_cap': 36097475.3768,
#   'name': 'Bottos',
#   'platform': 'Ethereum',
#   'price': 0.101563,
#   'symbol': 'BTO',
#   'volume_24h': 257877.0},
#  {'circulating_supply': 1710945602.83,
#   'market_cap': 34952223.342,
#   'name': 'Universa',
#   'platform': 'Ethereum',
#   'price': 0.0204286,
#   'symbol': 'UTNP',
#   'volume_24h': 6226.83},
#  {'circulating_supply': 1080963623.05,
#   'market_cap': 34843240.9435,
#   'name': 'Soarcoin',
#   'platform': 'Ethereum',
#   'price': 0.0322335,
#   'symbol': 'SOAR',
#   'volume_24h': 9918.98},
#  {'circulating_supply': 264520250.59,
#   'market_cap': 34700560.0331,
#   'name': 'Rock',
#   'platform': 'Ethereum',
#   'price': 0.131183,
#   'symbol': 'RKT',
#   'volume_24h': 86251.4},
#  {'circulating_supply': 74388399.693,
#   'market_cap': 34223945.4352,
#   'name': 'Bread',
#   'platform': 'Ethereum',
#   'price': 0.460071,
#   'symbol': 'BRD',
#   'volume_24h': 1199250.0},
#  {'circulating_supply': 333333333.0,
#   'market_cap': 33721999.9663,
#   'name': 'Trinity Netwo...',
#   'platform': 'NEO',
#   'price': 0.101166,
#   'symbol': 'TNC',
#   'volume_24h': 318092.0},
#  {'circulating_supply': 399936258.54,
#   'market_cap': 33562930.772,
#   'name': 'indaHash',
#   'platform': 'Ethereum',
#   'price': 0.0839207,
#   'symbol': 'IDH',
#   'volume_24h': 328663.0},
#  {'circulating_supply': 358695652.008,
#   'market_cap': 33404393.4628,
#   'name': 'Cobinhood',
#   'platform': 'Ethereum',
#   'price': 0.0931274,
#   'symbol': 'COB',
#   'volume_24h': 755.15},
#  {'circulating_supply': 463910526.92,
#   'market_cap': 32658837.1846,
#   'name': 'Ink',
#   'platform': 'Qtum',
#   'price': 0.070399,
#   'symbol': 'INK',
#   'volume_24h': 911652.0},
#  {'circulating_supply': 37458337.4784,
#   'market_cap': 32424648.6297,
#   'name': 'Delphy',
#   'platform': 'Ethereum',
#   'price': 0.865619,
#   'symbol': 'DPY',
#   'volume_24h': 1064500.0},
#  {'circulating_supply': 28007978.7671,
#   'market_cap': 32398789.5984,
#   'name': 'INS Ecosystem',
#   'platform': 'Ethereum',
#   'price': 1.15677,
#   'symbol': 'INS',
#   'volume_24h': 7493220.0},
#  {'circulating_supply': 60175727.0296,
#   'market_cap': 32275732.5981,
#   'name': 'Havven',
#   'platform': 'Ethereum',
#   'price': 0.536358,
#   'symbol': 'HAV',
#   'volume_24h': 867579.0},
#  {'circulating_supply': 69753450.3418,
#   'market_cap': 32259087.4399,
#   'name': 'BlockMason Cr...',
#   'platform': 'Ethereum',
#   'price': 0.462473,
#   'symbol': 'BCPT',
#   'volume_24h': 4869170.0},
#  {'circulating_supply': 402249875.194,
#   'market_cap': 31244799.2807,
#   'name': 'WePower',
#   'platform': 'Ethereum',
#   'price': 0.0776751,
#   'symbol': 'WPR',
#   'volume_24h': 3548230.0},
#  {'circulating_supply': 444809322.646,
#   'market_cap': 30546568.5378,
#   'name': 'KickCoin',
#   'platform': 'Ethereum',
#   'price': 0.0686734,
#   'symbol': 'KICK',
#   'volume_24h': 5114040.0},
#  {'circulating_supply': 100728564.0,
#   'market_cap': 30211115.2863,
#   'name': 'Synereo',
#   'platform': 'Omni',
#   'price': 0.299926,
#   'symbol': 'AMP',
#   'volume_24h': 1380960.0},
#  {'circulating_supply': 376657502.4,
#   'market_cap': 29365537.1884,
#   'name': 'Mobius',
#   'platform': 'Stellar',
#   'price': 0.0779635,
#   'symbol': 'MOBI',
#   'volume_24h': 113018.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 29206500.0,
#   'name': 'district0x',
#   'platform': 'Ethereum',
#   'price': 0.0486775,
#   'symbol': 'DNT',
#   'volume_24h': 1929540.0},
#  {'circulating_supply': 285319403.561,
#   'market_cap': 29172197.0977,
#   'name': 'IHT Real Esta...',
#   'platform': 'Ethereum',
#   'price': 0.102244,
#   'symbol': 'IHT',
#   'volume_24h': 6128430.0},
#  {'circulating_supply': 428481269.499,
#   'market_cap': 28933754.7486,
#   'name': 'Tierion',
#   'platform': 'Ethereum',
#   'price': 0.0675263,
#   'symbol': 'TNT',
#   'volume_24h': 3708640.0},
#  {'circulating_supply': 162862944.036,
#   'market_cap': 28760618.739,
#   'name': 'Humaniq',
#   'platform': 'Ethereum',
#   'price': 0.176594,
#   'symbol': 'HMQ',
#   'volume_24h': 296446.0},
#  {'circulating_supply': 68000000.0,
#   'market_cap': 28681856.0,
#   'name': 'Centra',
#   'platform': 'Ethereum',
#   'price': 0.421792,
#   'symbol': 'CTR',
#   'volume_24h': 12816500.0},
#  {'circulating_supply': 485519252.554,
#   'market_cap': 28544550.7923,
#   'name': 'Etherparty',
#   'platform': 'Ethereum',
#   'price': 0.0587918,
#   'symbol': 'FUEL',
#   'volume_24h': 768533.0},
#  {'circulating_supply': 162441000.0,
#   'market_cap': 28157685.381,
#   'name': 'bitCNY',
#   'platform': 'BitShares',
#   'price': 0.173341,
#   'symbol': 'BITCNY',
#   'volume_24h': 6468420.0},
#  {'circulating_supply': 32105577.5103,
#   'market_cap': 27968420.6867,
#   'name': 'Triggers',
#   'platform': 'Counterparty',
#   'price': 0.871139,
#   'symbol': 'TRIG',
#   'volume_24h': 3410460.0},
#  {'circulating_supply': 551151846.208,
#   'market_cap': 27920746.2619,
#   'name': 'Game.com',
#   'platform': 'Ethereum',
#   'price': 0.0506589,
#   'symbol': 'GTC',
#   'volume_24h': 2831500.0},
#  {'circulating_supply': 155000000.0,
#   'market_cap': 27405085.0,
#   'name': 'Presearch',
#   'platform': 'Ethereum',
#   'price': 0.176807,
#   'symbol': 'PRE',
#   'volume_24h': 81838.1},
#  {'circulating_supply': 656923039.17,
#   'market_cap': 25613232.2203,
#   'name': 'Blox',
#   'platform': 'Ethereum',
#   'price': 0.0389897,
#   'symbol': 'CDT',
#   'volume_24h': 491126.0},
#  {'circulating_supply': 226715852.267,
#   'market_cap': 25518002.7519,
#   'name': 'CPChain',
#   'platform': 'Ethereum',
#   'price': 0.112555,
#   'symbol': 'CPC',
#   'volume_24h': 6444840.0},
#  {'circulating_supply': 24874855.2824,
#   'market_cap': 25085296.558,
#   'name': 'TokenCard',
#   'platform': 'Ethereum',
#   'price': 1.00846,
#   'symbol': 'TKN',
#   'volume_24h': 169983.0},
#  {'circulating_supply': 141022371.35,
#   'market_cap': 24890589.5656,
#   'name': 'Unikoin Gold',
#   'platform': 'Ethereum',
#   'price': 0.176501,
#   'symbol': 'UKG',
#   'volume_24h': 1109800.0},
#  {'circulating_supply': 375000000.0,
#   'market_cap': 24390525.0,
#   'name': 'Hive Project',
#   'platform': 'Ethereum',
#   'price': 0.0650414,
#   'symbol': 'HVN',
#   'volume_24h': 195594.0},
#  {'circulating_supply': 32025998.4158,
#   'market_cap': 23934149.526,
#   'name': 'Decision Token',
#   'platform': 'Ethereum',
#   'price': 0.747335,
#   'symbol': 'HST',
#   'volume_24h': 76095.8},
#  {'circulating_supply': 1844678440.94,
#   'market_cap': 23933595.9641,
#   'name': 'U.CASH',
#   'platform': 'Ethereum',
#   'price': 0.0129744,
#   'symbol': 'UCASH',
#   'volume_24h': 5299.86},
#  {'circulating_supply': 701884009.0,
#   'market_cap': 23777514.0077,
#   'name': 'Pepe Cash',
#   'platform': 'Counterparty',
#   'price': 0.0338767,
#   'symbol': 'PEPECASH',
#   'volume_24h': 36713.7},
#  {'circulating_supply': 2297853.07853,
#   'market_cap': 23213601.1552,
#   'name': 'Lunyr',
#   'platform': 'Ethereum',
#   'price': 10.1023,
#   'symbol': 'LUN',
#   'volume_24h': 2868560.0},
#  {'circulating_supply': 240000000.0,
#   'market_cap': 21826608.0,
#   'name': 'QLINK',
#   'platform': 'NEO',
#   'price': 0.0909442,
#   'symbol': 'QLC',
#   'volume_24h': 339551.0},
#  {'circulating_supply': 455483815.322,
#   'market_cap': 21716693.9921,
#   'name': 'Republic Prot...',
#   'platform': 'Ethereum',
#   'price': 0.0476783,
#   'symbol': 'REN',
#   'volume_24h': 454905.0},
#  {'circulating_supply': 166499800.432,
#   'market_cap': 21688264.0042,
#   'name': 'Viberate',
#   'platform': 'Ethereum',
#   'price': 0.13026,
#   'symbol': 'VIB',
#   'volume_24h': 4679220.0},
#  {'circulating_supply': 217102677.83,
#   'market_cap': 21436870.3808,
#   'name': 'Monetha',
#   'platform': 'Ethereum',
#   'price': 0.0987407,
#   'symbol': 'MTH',
#   'volume_24h': 437778.0},
#  {'circulating_supply': 249999999.108,
#   'market_cap': 21433724.9236,
#   'name': 'YOYOW',
#   'platform': 'BitShares',
#   'price': 0.0857349,
#   'symbol': 'YOYOW',
#   'volume_24h': 3279110.0},
#  {'circulating_supply': 115125192.154,
#   'market_cap': 21414897.4934,
#   'name': 'SunContract',
#   'platform': 'Ethereum',
#   'price': 0.186014,
#   'symbol': 'SNC',
#   'volume_24h': 7049320.0},
#  {'circulating_supply': 325000000.0,
#   'market_cap': 21282560.0,
#   'name': 'Cofound.it',
#   'platform': 'Ethereum',
#   'price': 0.0654848,
#   'symbol': 'CFI',
#   'volume_24h': 391260.0},
#  {'circulating_supply': 293827778.0,
#   'market_cap': 21119753.0271,
#   'name': 'Zeepin',
#   'platform': 'NEO',
#   'price': 0.071878,
#   'symbol': 'ZPT',
#   'volume_24h': 316642.0},
#  {'circulating_supply': 69060273.4618,
#   'market_cap': 21094115.2275,
#   'name': 'Bankex',
#   'platform': 'Ethereum',
#   'price': 0.305445,
#   'symbol': 'BKX',
#   'volume_24h': 798240.0},
#  {'circulating_supply': 2335624426.71,
#   'market_cap': 20977761.1322,
#   'name': 'Refereum',
#   'platform': 'Ethereum',
#   'price': 0.00898165,
#   'symbol': 'RFR',
#   'volume_24h': 515851.0},
#  {'circulating_supply': 1543157590.0,
#   'market_cap': 20865188.0901,
#   'name': 'Safe Exchange...',
#   'platform': 'Omni',
#   'price': 0.0135211,
#   'symbol': 'SAFEX',
#   'volume_24h': 11560.8},
#  {'circulating_supply': 10500000.0,
#   'market_cap': 20598165.0,
#   'name': 'Nimiq Exchang...',
#   'platform': 'Ethereum',
#   'price': 1.96173,
#   'symbol': 'NET',
#   'volume_24h': 202028.0},
#  {'circulating_supply': 82073518.6244,
#   'market_cap': 20433679.7849,
#   'name': 'Spectre.ai Di...',
#   'platform': 'Ethereum',
#   'price': 0.248968,
#   'symbol': 'SXDT',
#   'volume_24h': 28985.5},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 20296140.0,
#   'name': 'adToken',
#   'platform': 'Ethereum',
#   'price': 0.0338269,
#   'symbol': 'ADT',
#   'volume_24h': 2989060.0},
#  {'circulating_supply': 16500000.0,
#   'market_cap': 20098485.0,
#   'name': 'Everex',
#   'platform': 'Ethereum',
#   'price': 1.21809,
#   'symbol': 'EVX',
#   'volume_24h': 2600440.0},
#  {'circulating_supply': 831635544.99,
#   'market_cap': 20016386.4417,
#   'name': 'Datum',
#   'platform': 'Ethereum',
#   'price': 0.0240687,
#   'symbol': 'DAT',
#   'volume_24h': 2254620.0},
#  {'circulating_supply': 4660285459.8,
#   'market_cap': 19972352.3808,
#   'name': 'ATMChain',
#   'platform': 'Ethereum',
#   'price': 0.00428565,
#   'symbol': 'ATM',
#   'volume_24h': 16626.7},
#  {'circulating_supply': 399742960.0,
#   'market_cap': 19678946.1778,
#   'name': 'Fortuna',
#   'platform': 'Ethereum',
#   'price': 0.049229,
#   'symbol': 'FOTA',
#   'volume_24h': 872444.0},
#  {'circulating_supply': 185000000.0,
#   'market_cap': 19491785.0,
#   'name': 'Medicalchain',
#   'platform': 'Ethereum',
#   'price': 0.105361,
#   'symbol': 'MTN',
#   'volume_24h': 9332580.0},
#  {'circulating_supply': 51980933.4494,
#   'market_cap': 19370850.7927,
#   'name': 'Blockport',
#   'platform': 'Ethereum',
#   'price': 0.372653,
#   'symbol': 'BPT',
#   'volume_24h': 259326.0},
#  {'circulating_supply': 17029321.0837,
#   'market_cap': 19184722.2533,
#   'name': 'Ormeus Coin',
#   'platform': 'Ethereum',
#   'price': 1.12657,
#   'symbol': 'ORME',
#   'volume_24h': 2660420.0},
#  {'circulating_supply': 100000000.0,
#   'market_cap': 19101100.0,
#   'name': 'Mercury',
#   'platform': 'Waves',
#   'price': 0.191011,
#   'symbol': 'MER',
#   'volume_24h': 994605.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 18737250.0,
#   'name': 'Internet Node...',
#   'platform': 'Ethereum',
#   'price': 0.124915,
#   'symbol': 'INT',
#   'volume_24h': 2059370.0},
#  {'circulating_supply': 18268713.3635,
#   'market_cap': 18151592.6422,
#   'name': 'Dai',
#   'platform': 'Ethereum',
#   'price': 0.993589,
#   'symbol': 'DAI',
#   'volume_24h': 864221.0},
#  {'circulating_supply': 1356003.01735,
#   'market_cap': 18100063.8758,
#   'name': 'Numeraire',
#   'platform': 'Ethereum',
#   'price': 13.3481,
#   'symbol': 'NMR',
#   'volume_24h': 182256.0},
#  {'circulating_supply': 10000000.0,
#   'market_cap': 17942100.0,
#   'name': 'Uquid Coin',
#   'platform': 'Ethereum',
#   'price': 1.79421,
#   'symbol': 'UQC',
#   'volume_24h': 13563.5},
#  {'circulating_supply': 390222225.333,
#   'market_cap': 17864685.6535,
#   'name': 'Datawallet',
#   'platform': 'Ethereum',
#   'price': 0.0457808,
#   'symbol': 'DXT',
#   'volume_24h': 591866.0},
#  {'circulating_supply': 92147500.0,
#   'market_cap': 17625328.7675,
#   'name': 'WeTrust',
#   'platform': 'Ethereum',
#   'price': 0.191273,
#   'symbol': 'TRST',
#   'volume_24h': 196221.0},
#  {'circulating_supply': 85978873.0,
#   'market_cap': 17451647.726,
#   'name': 'Agrello',
#   'platform': 'Ethereum',
#   'price': 0.202976,
#   'symbol': 'DLT',
#   'volume_24h': 10902300.0},
#  {'circulating_supply': 1153170765.0,
#   'market_cap': 17384279.9165,
#   'name': 'Zeusshield',
#   'platform': 'Ethereum',
#   'price': 0.0150752,
#   'symbol': 'ZSC',
#   'volume_24h': 33173.2},
#  {'circulating_supply': 575821132.878,
#   'market_cap': 17241466.6891,
#   'name': 'SwissBorg',
#   'platform': 'Ethereum',
#   'price': 0.0299424,
#   'symbol': 'CHSB',
#   'volume_24h': 201118.0},
#  {'circulating_supply': 51113355.2495,
#   'market_cap': 17229136.4474,
#   'name': 'Swarm',
#   'platform': 'Ethereum',
#   'price': 0.337077,
#   'symbol': 'SWM',
#   'volume_24h': 928.676},
#  {'circulating_supply': 2790428084.0,
#   'market_cap': 17159346.8426,
#   'name': 'Alphacat',
#   'platform': 'NEO',
#   'price': 0.00614936,
#   'symbol': 'ACAT',
#   'volume_24h': 132122.0},
#  {'circulating_supply': 577188.478932,
#   'market_cap': 16903484.0752,
#   'name': 'ICOS',
#   'platform': 'Ethereum',
#   'price': 29.2859,
#   'symbol': 'ICOS',
#   'volume_24h': 17734.8},
#  {'circulating_supply': 329992098.47,
#   'market_cap': 16887477.636,
#   'name': 'Cappasity',
#   'platform': 'Ethereum',
#   'price': 0.0511754,
#   'symbol': 'CAPP',
#   'volume_24h': 41716.6},
#  {'circulating_supply': 140000000.0,
#   'market_cap': 16843540.0,
#   'name': 'Mothership',
#   'platform': 'Ethereum',
#   'price': 0.120311,
#   'symbol': 'MSP',
#   'volume_24h': 70132.6},
#  {'circulating_supply': 108135403.316,
#   'market_cap': 16820353.8504,
#   'name': 'Zap',
#   'platform': 'Ethereum',
#   'price': 0.155549,
#   'symbol': 'ZAP',
#   'volume_24h': 24446.1},
#  {'circulating_supply': 1887274878.9,
#   'market_cap': 16724841.2493,
#   'name': 'Selfkey',
#   'platform': 'Ethereum',
#   'price': 0.0088619,
#   'symbol': 'KEY',
#   'volume_24h': 159481.0},
#  {'circulating_supply': 341754517.352,
#   'market_cap': 16494029.9201,
#   'name': 'STK',
#   'platform': 'Ethereum',
#   'price': 0.0482628,
#   'symbol': 'STK',
#   'volume_24h': 2673850.0},
#  {'circulating_supply': 65351403.0,
#   'market_cap': 16330139.2844,
#   'name': 'Qbao',
#   'platform': 'Qtum',
#   'price': 0.249882,
#   'symbol': 'QBT',
#   'volume_24h': 2212200.0},
#  {'circulating_supply': 6581116221.66,
#   'market_cap': 16281089.2319,
#   'name': 'Storiqa',
#   'platform': 'Ethereum',
#   'price': 0.00247391,
#   'symbol': 'STQ',
#   'volume_24h': 132872.0},
#  {'circulating_supply': 19628888.0,
#   'market_cap': 16271877.0587,
#   'name': 'Moeda Loyalty...',
#   'platform': 'Ethereum',
#   'price': 0.828976,
#   'symbol': 'MDA',
#   'volume_24h': 1026680.0},
#  {'circulating_supply': 269676560.459,
#   'market_cap': 16109021.4684,
#   'name': 'Electrify.Asia',
#   'platform': 'Ethereum',
#   'price': 0.0597346,
#   'symbol': 'ELEC',
#   'volume_24h': 432378.0},
#  {'circulating_supply': 13000000.0,
#   'market_cap': 15931110.0,
#   'name': 'Aeron',
#   'platform': 'Ethereum',
#   'price': 1.22547,
#   'symbol': 'ARN',
#   'volume_24h': 1071720.0},
#  {'circulating_supply': 2000000000.0,
#   'market_cap': 15588720.0,
#   'name': 'Odyssey',
#   'platform': 'Ethereum',
#   'price': 0.00779436,
#   'symbol': 'OCN',
#   'volume_24h': 14308000.0},
#  {'circulating_supply': 76652327.4268,
#   'market_cap': 15524012.6121,
#   'name': 'DADI',
#   'platform': 'Ethereum',
#   'price': 0.202525,
#   'symbol': 'DADI',
#   'volume_24h': 2631180.0},
#  {'circulating_supply': 1750000000.0,
#   'market_cap': 15499837.5,
#   'name': 'SwftCoin',
#   'platform': 'Ethereum',
#   'price': 0.00885705,
#   'symbol': 'SWFTC',
#   'volume_24h': 6229360.0},
#  {'circulating_supply': 84285535.961,
#   'market_cap': 15473054.4062,
#   'name': 'Trade Token',
#   'platform': 'Ethereum',
#   'price': 0.183579,
#   'symbol': 'TIO',
#   'volume_24h': 197589.0},
#  {'circulating_supply': 39496568.6434,
#   'market_cap': 15351565.7969,
#   'name': 'Bloom',
#   'platform': 'Ethereum',
#   'price': 0.388681,
#   'symbol': 'BLT',
#   'volume_24h': 49580.4},
#  {'circulating_supply': 65047195.1722,
#   'market_cap': 15258640.9491,
#   'name': 'COSS',
#   'platform': 'Ethereum',
#   'price': 0.234578,
#   'symbol': 'COSS',
#   'volume_24h': 835531.0},
#  {'circulating_supply': 5398647405.94,
#   'market_cap': 15183857.7886,
#   'name': 'carVertical',
#   'platform': 'Ethereum',
#   'price': 0.00281253,
#   'symbol': 'CV',
#   'volume_24h': 119511.0},
#  {'circulating_supply': 575451808.4,
#   'market_cap': 15110846.582,
#   'name': 'QunQun',
#   'platform': 'Ethereum',
#   'price': 0.0262591,
#   'symbol': 'QUN',
#   'volume_24h': 3599740.0},
#  {'circulating_supply': 77839404.0,
#   'market_cap': 14709156.4951,
#   'name': 'LATOKEN',
#   'platform': 'Ethereum',
#   'price': 0.188968,
#   'symbol': 'LA',
#   'volume_24h': 1266130.0},
#  {'circulating_supply': 421040206.297,
#   'market_cap': 14568033.2419,
#   'name': 'All Sports',
#   'platform': 'Ethereum',
#   'price': 0.0346001,
#   'symbol': 'SOC',
#   'volume_24h': 3837660.0},
#  {'circulating_supply': 85558370.5,
#   'market_cap': 14497694.7645,
#   'name': 'FirstBlood',
#   'platform': 'Ethereum',
#   'price': 0.169448,
#   'symbol': '1ST',
#   'volume_24h': 101577.0},
#  {'circulating_supply': 1260000000.0,
#   'market_cap': 14436072.0,
#   'name': 'YEE',
#   'platform': 'Ethereum',
#   'price': 0.0114572,
#   'symbol': 'YEE',
#   'volume_24h': 1778780.0},
#  {'circulating_supply': 582029028.5,
#   'market_cap': 14273272.4746,
#   'name': 'Energo',
#   'platform': 'Ethereum',
#   'price': 0.0245233,
#   'symbol': 'TSL',
#   'volume_24h': 866394.0},
#  {'circulating_supply': 12756500.0,
#   'market_cap': 14265593.95,
#   'name': 'bitUSD',
#   'platform': 'BitShares',
#   'price': 1.1183,
#   'symbol': 'BITUSD',
#   'volume_24h': 620736.0},
#  {'circulating_supply': 21227827.4593,
#   'market_cap': 14081755.3069,
#   'name': 'Blackmoon',
#   'platform': 'Ethereum',
#   'price': 0.663363,
#   'symbol': 'BMC',
#   'volume_24h': 973301.0},
#  {'circulating_supply': 403600000.0,
#   'market_cap': 14033050.92,
#   'name': 'Hi Mutual Soc...',
#   'platform': 'Ethereum',
#   'price': 0.0347697,
#   'symbol': 'HMC',
#   'volume_24h': 429023.0},
#  {'circulating_supply': 39236491.0,
#   'market_cap': 14018845.1059,
#   'name': 'Grid+',
#   'platform': 'Ethereum',
#   'price': 0.357291,
#   'symbol': 'GRID',
#   'volume_24h': 1005.68},
#  {'circulating_supply': 75000000.0,
#   'market_cap': 13963950.0,
#   'name': 'Matchpool',
#   'platform': 'Ethereum',
#   'price': 0.186186,
#   'symbol': 'GUP',
#   'volume_24h': 2448040.0},
#  {'circulating_supply': 25009249.58,
#   'market_cap': 13944032.1496,
#   'name': 'OAX',
#   'platform': 'Ethereum',
#   'price': 0.557555,
#   'symbol': 'OAX',
#   'volume_24h': 997616.0},
#  {'circulating_supply': 40339392.5906,
#   'market_cap': 13886311.4872,
#   'name': 'CanYaCoin',
#   'platform': 'Ethereum',
#   'price': 0.344237,
#   'symbol': 'CAN',
#   'volume_24h': 173966.0},
#  {'circulating_supply': 353869198.325,
#   'market_cap': 13878006.833,
#   'name': 'BitDegree',
#   'platform': 'Ethereum',
#   'price': 0.0392179,
#   'symbol': 'BDG',
#   'volume_24h': 45752.4},
#  {'circulating_supply': 64936603.2047,
#   'market_cap': 13871302.6204,
#   'name': 'Paragon',
#   'platform': 'Ethereum',
#   'price': 0.213613,
#   'symbol': 'PRG',
#   'volume_24h': 78605.3},
#  {'circulating_supply': 61939166.1729,
#   'market_cap': 13599549.1424,
#   'name': 'EncrypGen',
#   'platform': 'Ethereum',
#   'price': 0.219563,
#   'symbol': 'DNA',
#   'volume_24h': 34100.1},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 13571160.0,
#   'name': 'Bodhi',
#   'platform': 'Qtum',
#   'price': 0.339279,
#   'symbol': 'BOT',
#   'volume_24h': 1014290.0},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 13401640.0,
#   'name': 'Blocktix',
#   'platform': 'Ethereum',
#   'price': 0.335041,
#   'symbol': 'TIX',
#   'volume_24h': 779764.0},
#  {'circulating_supply': 17431790.3911,
#   'market_cap': 13353309.2568,
#   'name': 'Propy',
#   'platform': 'Ethereum',
#   'price': 0.766032,
#   'symbol': 'PRO',
#   'volume_24h': 5777820.0},
#  {'circulating_supply': 127133907.724,
#   'market_cap': 13248497.39,
#   'name': 'Xaurum',
#   'platform': 'Ethereum',
#   'price': 0.104209,
#   'symbol': 'XAUR',
#   'volume_24h': 161451.0},
#  {'circulating_supply': 551050063.763,
#   'market_cap': 12817204.0631,
#   'name': 'Lympo',
#   'platform': 'Ethereum',
#   'price': 0.0232596,
#   'symbol': 'LYM',
#   'volume_24h': 82099.8},
#  {'circulating_supply': 142215728.19,
#   'market_cap': 12664196.8227,
#   'name': 'Lamden',
#   'platform': 'Ethereum',
#   'price': 0.0890492,
#   'symbol': 'TAU',
#   'volume_24h': 95017.8},
#  {'circulating_supply': 17500000.0,
#   'market_cap': 12607577.5,
#   'name': 'Covesting',
#   'platform': 'Ethereum',
#   'price': 0.720433,
#   'symbol': 'COV',
#   'volume_24h': 56745.0},
#  {'circulating_supply': 415000000.0,
#   'market_cap': 12539349.5,
#   'name': 'Restart Energ...',
#   'platform': 'Ethereum',
#   'price': 0.0302153,
#   'symbol': 'MWAT',
#   'volume_24h': 38948.5},
#  {'circulating_supply': 25000000.0,
#   'market_cap': 12488425.0,
#   'name': 'True Chain',
#   'platform': 'Ethereum',
#   'price': 0.499537,
#   'symbol': 'TRUE',
#   'volume_24h': 8369500.0},
#  {'circulating_supply': 46016602.0,
#   'market_cap': 12328906.0576,
#   'name': 'Incent',
#   'platform': 'Waves',
#   'price': 0.267923,
#   'symbol': 'INCNT',
#   'volume_24h': 65405.4},
#  {'circulating_supply': 2000000.0,
#   'market_cap': 12257100.0,
#   'name': 'Exchange Union',
#   'platform': 'Ethereum',
#   'price': 6.12855,
#   'symbol': 'XUC',
#   'volume_24h': 302452.0},
#  {'circulating_supply': 22747808.5,
#   'market_cap': 12251264.476,
#   'name': 'Databits',
#   'platform': 'Counterparty',
#   'price': 0.538569,
#   'symbol': 'DTB',
#   'volume_24h': 12992.7},
#  {'circulating_supply': 30000000.0,
#   'market_cap': 12250770.0,
#   'name': 'OracleChain',
#   'platform': 'BitShares',
#   'price': 0.408359,
#   'symbol': 'OCT',
#   'volume_24h': 78689.6},
#  {'circulating_supply': 591500000.0,
#   'market_cap': 12129949.65,
#   'name': 'DomRaider',
#   'platform': 'Ethereum',
#   'price': 0.0205071,
#   'symbol': 'DRT',
#   'volume_24h': 149944.0},
#  {'circulating_supply': 1050000000.0,
#   'market_cap': 12035940.0,
#   'name': 'AirToken',
#   'platform': 'Ethereum',
#   'price': 0.0114628,
#   'symbol': 'AIR',
#   'volume_24h': 208023.0},
#  {'circulating_supply': 952429892.0,
#   'market_cap': 11992901.9571,
#   'name': 'Target Coin',
#   'platform': 'Ethereum',
#   'price': 0.0125919,
#   'symbol': 'TGT',
#   'volume_24h': 6136.37},
#  {'circulating_supply': 404993611.0,
#   'market_cap': 11985745.4182,
#   'name': 'Snovio',
#   'platform': 'Ethereum',
#   'price': 0.0295949,
#   'symbol': 'SNOV',
#   'volume_24h': 41980.0},
#  {'circulating_supply': 35778843.8312,
#   'market_cap': 11897038.0354,
#   'name': 'iXledger',
#   'platform': 'Ethereum',
#   'price': 0.332516,
#   'symbol': 'IXT',
#   'volume_24h': 13408.9},
#  {'circulating_supply': 9969597.0,
#   'market_cap': 11896520.7082,
#   'name': 'Waves Communi...',
#   'platform': 'Waves',
#   'price': 1.19328,
#   'symbol': 'WCT',
#   'volume_24h': 52243.4},
#  {'circulating_supply': 38538647.0864,
#   'market_cap': 11650849.6326,
#   'name': 'ALIS',
#   'platform': 'Ethereum',
#   'price': 0.302316,
#   'symbol': 'ALIS',
#   'volume_24h': 16771.2},
#  {'circulating_supply': 26244468.18,
#   'market_cap': 11633411.6546,
#   'name': 'Rivetz',
#   'platform': 'Ethereum',
#   'price': 0.443271,
#   'symbol': 'RVT',
#   'volume_24h': 3807.65},
#  {'circulating_supply': 28722537.9371,
#   'market_cap': 11423613.956,
#   'name': 'Neumark',
#   'platform': 'Ethereum',
#   'price': 0.397723,
#   'symbol': 'NEU',
#   'volume_24h': 123583.0},
#  {'circulating_supply': 501394405.74,
#   'market_cap': 11392483.1295,
#   'name': 'BitClave',
#   'platform': 'Ethereum',
#   'price': 0.0227216,
#   'symbol': 'CAT',
#   'volume_24h': 3800700.0},
#  {'circulating_supply': 120222448.767,
#   'market_cap': 11287096.6247,
#   'name': 'DecentBet',
#   'platform': 'Ethereum',
#   'price': 0.0938851,
#   'symbol': 'DBET',
#   'volume_24h': 74213.9},
#  {'circulating_supply': 42181007.2457,
#   'market_cap': 11225378.3723,
#   'name': 'Stox',
#   'platform': 'Ethereum',
#   'price': 0.266124,
#   'symbol': 'STX',
# ...
#   'symbol': 'TOMO',
#   'volume_24h': 498965.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Animation Vis...',
#   'platform': 'Ethereum',
#   'price': 0.00790528,
#   'symbol': 'AVH',
#   'volume_24h': 469593.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'UG Token',
#   'platform': 'Ethereum',
#   'price': 0.484896,
#   'symbol': 'UGT',
#   'volume_24h': 452467.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Kcash',
#   'platform': 'Achain',
#   'price': 0.083885,
#   'symbol': 'KCASH',
#   'volume_24h': 415717.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'FairGame',
#   'platform': 'Ethereum',
#   'price': 0.0196288,
#   'symbol': 'FAIR',
#   'volume_24h': 383053.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LightChain',
#   'platform': 'Ethereum',
#   'price': 0.000906694,
#   'symbol': 'LIGHT',
#   'volume_24h': 362609.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'iQuant',
#   'platform': 'Ethereum',
#   'price': 0.0800221,
#   'symbol': 'IQT',
#   'volume_24h': 348438.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Neurotoken',
#   'platform': 'Ethereum',
#   'price': 0.349795,
#   'symbol': 'NTK',
#   'volume_24h': 328706.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'NANJCOIN',
#   'platform': 'Ethereum',
#   'price': 0.000416462,
#   'symbol': 'NANJ',
#   'volume_24h': 319810.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Molecular Future',
#   'platform': 'Ethereum',
#   'price': 0.239823,
#   'symbol': 'MOF',
#   'volume_24h': 293631.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'RefToken',
#   'platform': 'Ethereum',
#   'price': 6.05274,
#   'symbol': 'REF',
#   'volume_24h': 240190.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CFun',
#   'platform': 'Qtum',
#   'price': 0.00592104,
#   'symbol': 'CFUN',
#   'volume_24h': 219112.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ValueChain',
#   'platform': 'Ethereum',
#   'price': 0.0454271,
#   'symbol': 'VLC',
#   'volume_24h': 204226.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'InvestDigital',
#   'platform': 'Ethereum',
#   'price': 0.044475,
#   'symbol': 'IDT',
#   'volume_24h': 199316.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ShareX',
#   'platform': 'Ethereum',
#   'price': 0.00867708,
#   'symbol': 'SEXC',
#   'volume_24h': 198772.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Read',
#   'platform': 'Ethereum',
#   'price': 0.0195474,
#   'symbol': 'READ',
#   'volume_24h': 195812.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maggie',
#   'platform': 'Ethereum',
#   'price': 0.0102547,
#   'symbol': 'MAG',
#   'volume_24h': 195026.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Dropil',
#   'platform': 'Ethereum',
#   'price': 0.00724489,
#   'symbol': 'DROP',
#   'volume_24h': 193309.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DMarket',
#   'platform': 'Ethereum',
#   'price': 0.289258,
#   'symbol': 'DMT',
#   'volume_24h': 186071.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Legolas Exchange',
#   'platform': 'Ethereum',
#   'price': 0.247023,
#   'symbol': 'LGO',
#   'volume_24h': 171899.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'COMSA [ETH]',
#   'platform': 'Ethereum',
#   'price': 0.526373,
#   'symbol': 'CMS',
#   'volume_24h': 157377.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Centrality',
#   'platform': 'Ethereum',
#   'price': 0.224723,
#   'symbol': 'CENNZ',
#   'volume_24h': 130972.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Guaranteed Et...',
#   'platform': 'Ethereum',
#   'price': 0.0563602,
#   'symbol': 'GETX',
#   'volume_24h': 126971.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Content and A...',
#   'platform': 'Ethereum',
#   'price': 0.020607,
#   'symbol': 'CAN',
#   'volume_24h': 125190.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'MOAC',
#   'platform': 'Ethereum',
#   'price': 11.4416,
#   'symbol': 'MOAC',
#   'volume_24h': 113986.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Gems ',
#   'platform': 'Ethereum',
#   'price': 0.0126214,
#   'symbol': 'GEM',
#   'volume_24h': 104670.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LatiumX',
#   'platform': 'Ethereum',
#   'price': 0.0450953,
#   'symbol': 'LATX',
#   'volume_24h': 102441.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'COMSA [XEM]',
#   'platform': 'NEM',
#   'price': 0.528654,
#   'symbol': 'CMS',
#   'volume_24h': 92128.4},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sphre AIR ',
#   'platform': 'Ethereum',
#   'price': 0.138021,
#   'symbol': 'XID',
#   'volume_24h': 79459.2},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BigONE Token',
#   'platform': 'Ethereum',
#   'price': 1.62922,
#   'symbol': 'BIG',
#   'volume_24h': 78012.2},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'WETH',
#   'platform': 'Ethereum',
#   'price': 506.343,
#   'symbol': 'WETH',
#   'volume_24h': 75259.4},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bee Token',
#   'platform': 'Ethereum',
#   'price': 0.0842103,
#   'symbol': 'BEE',
#   'volume_24h': 66126.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'UnlimitedIP',
#   'platform': 'Ethereum',
#   'price': 0.0222861,
#   'symbol': 'UIP',
#   'volume_24h': 61458.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'HireMatch',
#   'platform': 'Ethereum',
#   'price': 0.0334323,
#   'symbol': 'HIRE',
#   'volume_24h': 55737.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'IPChain',
#   'platform': 'Ethereum',
#   'price': 0.528486,
#   'symbol': 'IPC',
#   'volume_24h': 54115.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Etherecash',
#   'platform': 'Ethereum',
#   'price': 0.491486,
#   'symbol': 'ECH',
#   'volume_24h': 47174.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Fluz Fluz',
#   'platform': 'Ethereum',
#   'price': 0.0903539,
#   'symbol': 'FLUZ',
#   'volume_24h': 45884.4},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'PressOne',
#   'platform': 'Ethereum',
#   'price': 0.15636,
#   'symbol': 'PRS',
#   'volume_24h': 43886.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Cashaa',
#   'platform': 'Ethereum',
#   'price': 0.0312522,
#   'symbol': 'CAS',
#   'volume_24h': 41296.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BnkToTheFuture',
#   'platform': 'Ethereum',
#   'price': 0.073465,
#   'symbol': 'BFT',
#   'volume_24h': 40737.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ShipChain',
#   'platform': 'Ethereum',
#   'price': 0.0938898,
#   'symbol': 'SHIP',
#   'volume_24h': 33627.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maverick Chain',
#   'platform': 'Ethereum',
#   'price': 0.0420438,
#   'symbol': 'MVC',
#   'volume_24h': 30625.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Experty',
#   'platform': 'Ethereum',
#   'price': 0.165983,
#   'symbol': 'EXY',
#   'volume_24h': 24235.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ZenGold',
#   'platform': 'BitShares',
#   'price': 0.0266614,
#   'symbol': 'ZENGOLD',
#   'volume_24h': 23764.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BlockCDN',
#   'platform': 'Ethereum',
#   'price': 0.0198014,
#   'symbol': 'BCDN',
#   'volume_24h': 23511.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Mixin',
#   'platform': 'Ethereum',
#   'price': 459.927,
#   'symbol': 'XIN',
#   'volume_24h': 19325.2},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Titanium Bloc...',
#   'platform': 'Ethereum',
#   'price': 0.0166516,
#   'symbol': 'BAR',
#   'volume_24h': 17959.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LALA World',
#   'platform': 'Ethereum',
#   'price': 0.0413294,
#   'symbol': 'LALA',
#   'volume_24h': 14046.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'NaPoleonX',
#   'platform': 'Ethereum',
#   'price': 0.251125,
#   'symbol': 'NPX',
#   'volume_24h': 12633.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Qube',
#   'platform': 'Ethereum',
#   'price': 0.0297453,
#   'symbol': 'QUBE',
#   'volume_24h': 12313.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GameChain System',
#   'platform': 'Ethereum',
#   'price': 0.00656075,
#   'symbol': 'GCS',
#   'volume_24h': 10967.2},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Candy',
#   'platform': 'Ethereum',
#   'price': 0.000255208,
#   'symbol': 'CANDY',
#   'volume_24h': 9622.09},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CORION',
#   'platform': 'Ethereum Classic',
#   'price': 0.42804,
#   'symbol': 'COR',
#   'volume_24h': 7824.88},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'HOQU',
#   'platform': 'Ethereum',
#   'price': 0.0457078,
#   'symbol': 'HQX',
#   'volume_24h': 6096.64},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'IDEX Membership',
#   'platform': 'Ethereum',
#   'price': 2169.27,
#   'symbol': 'IDXM',
#   'volume_24h': 4640.9},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'OX Fina',
#   'platform': 'Ethereum',
#   'price': 0.00033317,
#   'symbol': 'OX',
#   'volume_24h': 3586.97},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'StarterCoin',
#   'platform': 'Ethereum',
#   'price': 0.0225717,
#   'symbol': 'STAC',
#   'volume_24h': 3245.77},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CryptopiaFeeS...',
#   'platform': 'Ubiq',
#   'price': 1155.27,
#   'symbol': 'CEFS',
#   'volume_24h': 3175.02},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DATx',
#   'platform': 'Ethereum',
#   'price': 0.0196138,
#   'symbol': 'DATX',
#   'volume_24h': 2355.76},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Cloud',
#   'platform': 'Ethereum',
#   'price': 0.0530082,
#   'symbol': 'CLD',
#   'volume_24h': 2147.19},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Macro',
#   'platform': 'Ethereum',
#   'price': 0.656319,
#   'symbol': 'MCR',
#   'volume_24h': 2090.32},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'President Trump',
#   'platform': 'Omni',
#   'price': 0.0174889,
#   'symbol': 'PRES',
#   'volume_24h': 1792.28},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'First Bitcoin...',
#   'platform': 'Omni',
#   'price': 0.216477,
#   'symbol': 'BITCF',
#   'volume_24h': 1472.57},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Internet of T...',
#   'platform': 'Nxt',
#   'price': 1069.89,
#   'symbol': 'XOT',
#   'volume_24h': 1445.33},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'President Joh...',
#   'platform': 'Omni',
#   'price': 0.13685,
#   'symbol': 'GARY',
#   'volume_24h': 1383.25},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Alphabit',
#   'platform': 'Ethereum',
#   'price': 49.6366,
#   'symbol': 'ABC',
#   'volume_24h': 1242.47},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TeslaCoilCoin',
#   'platform': 'Omni',
#   'price': 1.09571,
#   'symbol': 'TESLA',
#   'volume_24h': 1174.42},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Ethereum Lite',
#   'platform': 'Ethereum',
#   'price': 0.298104,
#   'symbol': 'ELITE',
#   'volume_24h': 1050.28},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Minex',
#   'platform': 'Waves',
#   'price': 0.0137433,
#   'symbol': 'MINEX',
#   'volume_24h': 1037.73},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'NEO GOLD',
#   'platform': 'Ethereum',
#   'price': 0.00315069,
#   'symbol': 'NEOG',
#   'volume_24h': 399.479},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Indicoin',
#   'platform': 'Ethereum',
#   'price': 0.0116609,
#   'symbol': 'INDI',
#   'volume_24h': 362.239},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SuperNET',
#   'platform': 'Nxt',
#   'price': 90.3859,
#   'symbol': 'UNITY',
#   'volume_24h': 360.487},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'United Trader...',
#   'platform': 'Ethereum',
#   'price': 0.38519,
#   'symbol': 'UTT',
#   'volume_24h': 356.305},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Escroco',
#   'platform': 'Waves',
#   'price': 0.0644684,
#   'symbol': 'ESC',
#   'volume_24h': 318.117},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Storjcoin X',
#   'platform': 'Counterparty',
#   'price': 0.762059,
#   'symbol': 'SJCX',
#   'volume_24h': 242.182},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GOLD Reward T...',
#   'platform': 'Ethereum',
#   'price': 0.0260914,
#   'symbol': 'GRX',
#   'volume_24h': 208.617},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Nitro',
#   'platform': 'Ethereum',
#   'price': 0.08939,
#   'symbol': 'NOX',
#   'volume_24h': 155.825},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Wi Coin',
#   'platform': 'Ethereum',
#   'price': 0.0015222,
#   'symbol': 'WIC',
#   'volume_24h': 145.797},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BTCMoon',
#   'platform': 'Ethereum',
#   'price': 0.00903425,
#   'symbol': 'BTCM',
#   'volume_24h': 115.53},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'PlexCoin',
#   'platform': 'Ethereum',
#   'price': 0.0116913,
#   'symbol': 'PLX',
#   'volume_24h': 95.5602},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'STEX',
#   'platform': 'Nxt',
#   'price': 0.772589,
#   'symbol': 'STEX',
#   'volume_24h': 92.2876},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BitSerial',
#   'platform': 'Ethereum',
#   'price': 0.00830579,
#   'symbol': 'BTE',
#   'volume_24h': 76.8966},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sand Coin',
#   'platform': 'Ethereum',
#   'price': 0.670588,
#   'symbol': 'SND',
#   'volume_24h': 75.7961},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SnakeEyes',
#   'platform': 'Burst',
#   'price': 0.00290062,
#   'symbol': 'SNAKE',
#   'volume_24h': 65.3626},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'HODL Bucks',
#   'platform': 'Ethereum',
#   'price': 0.0662175,
#   'symbol': 'HDLB',
#   'volume_24h': 54.5352},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'FAPcoin',
#   'platform': 'Ethereum',
#   'price': 0.00113955,
#   'symbol': 'FAP',
#   'volume_24h': 54.0487},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Smoke',
#   'platform': 'BitShares',
#   'price': 0.0625959,
#   'symbol': 'SMOKE',
#   'volume_24h': 40.159},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ANRYZE',
#   'platform': 'Waves',
#   'price': 0.00741303,
#   'symbol': 'RYZ',
#   'volume_24h': 35.8497},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SISA',
#   'platform': 'Ethereum',
#   'price': 0.00575023,
#   'symbol': 'SISA',
#   'volume_24h': 26.227},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Natcoin',
#   'platform': 'Ethereum',
#   'price': 0.00730916,
#   'symbol': 'NTC',
#   'volume_24h': 12.047},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EncryptoTel [...',
#   'platform': 'Ethereum',
#   'price': 0.049597,
#   'symbol': 'ETT',
#   'volume_24h': 1.92621},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LLToken',
#   'platform': 'Ethereum',
#   'price': None,
#   'symbol': 'LLT',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Musiconomi',
#   'platform': 'Ethereum',
#   'price': 0.0432074,
#   'symbol': 'MCI',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eGold',
#   'platform': 'Ethereum',
#   'price': 0.00694441,
#   'symbol': 'EGOLD',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SpherePay',
#   'platform': 'Ethereum',
#   'price': 0.00223544,
#   'symbol': 'SAY',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Monero Gold',
#   'platform': 'Ethereum',
#   'price': 0.000185086,
#   'symbol': 'XMRG',
#   'volume_24h': None}]

# %%
show_page("tokens/views/all")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/tokens/views/all"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# _________________________________
#
# ## Graphs API
# The graphs API is used internally by coinmarketcap for display graphs info. The params `start` and `end` are passed as `datetime` objects.
#
# #### `graphs.currency(name, [start=None, end=None])`
#
# Get graphs data for a currency:

# %%
cmc.graphs.currency("BTC")
# Out:
# {'market_cap_by_available_supply': [[datetime.datetime(2013, 4, 28, 20, 47, 21),
#    1500517590],
#   [datetime.datetime(2013, 4, 29, 20, 45, 1), 1575032004],
#   [datetime.datetime(2013, 4, 30, 20, 45, 2), 1501657492],
#   [datetime.datetime(2013, 5, 1, 20, 45, 2), 1298951550],
#   [datetime.datetime(2013, 5, 2, 21, 20, 1), 1148667722],
#   [datetime.datetime(2013, 5, 3, 21, 20, 1), 1011066494],
#   [datetime.datetime(2013, 5, 4, 21, 20, 1), 1236351843],
#   [datetime.datetime(2013, 5, 5, 21, 25, 1), 1298377788],
#   [datetime.datetime(2013, 5, 6, 21, 25, 3), 1315992303],
#   [datetime.datetime(2013, 5, 7, 21, 25, 1), 1183766500],
#   [datetime.datetime(2013, 5, 8, 21, 25, 1), 1253655040],
#   [datetime.datetime(2013, 5, 9, 21, 50, 1), 1258130700],
#   [datetime.datetime(2013, 5, 10, 21, 55, 2), 1322989457],
#   [datetime.datetime(2013, 5, 11, 22, 25, 1), 1259239352],
#   [datetime.datetime(2013, 5, 12, 22, 25, 1), 1278708678],
#   [datetime.datetime(2013, 5, 13, 22, 25, 1), 1306721052],
#   [datetime.datetime(2013, 5, 14, 22, 25, 1), 1277278987],
#   [datetime.datetime(2013, 5, 15, 22, 35, 1), 1273849680],
#   [datetime.datetime(2013, 5, 16, 22, 35, 1), 1289277412],
#   [datetime.datetime(2013, 5, 17, 22, 35, 1), 1374605382],
#   [datetime.datetime(2013, 5, 18, 22, 35, 1), 1383755085],
#   [datetime.datetime(2013, 5, 19, 22, 35, 2), 1346499261],
#   [datetime.datetime(2013, 5, 20, 22, 35, 2), 1370131821],
#   [datetime.datetime(2013, 5, 21, 22, 35, 2), 1374154117],
#   [datetime.datetime(2013, 5, 22, 22, 35, 4), 1375791900],
#   [datetime.datetime(2013, 5, 23, 22, 35, 2), 1407041527],
#   [datetime.datetime(2013, 5, 24, 22, 35, 1), 1474180657],
#   [datetime.datetime(2013, 5, 25, 22, 35, 2), 1464316690],
#   [datetime.datetime(2013, 5, 26, 22, 45, 2), 1507769010],
#   [datetime.datetime(2013, 5, 27, 22, 45, 1), 1445444605],
#   [datetime.datetime(2013, 5, 28, 22, 45, 7), 1448115966],
#   [datetime.datetime(2013, 5, 29, 23, 15, 1), 1481781794],
#   [datetime.datetime(2013, 5, 30, 23, 15, 1), 1429308633],
#   [datetime.datetime(2013, 5, 31, 23, 40, 2), 1436386729],
#   [datetime.datetime(2013, 6, 1, 23, 40, 2), 1449499974],
#   [datetime.datetime(2013, 6, 3, 1, 25, 1), 1362684200],
#   [datetime.datetime(2013, 6, 4, 1, 25, 2), 1361765704],
#   [datetime.datetime(2013, 6, 5, 2, 45, 2), 1364113639],
#   [datetime.datetime(2013, 6, 6, 2, 45, 2), 1369233814],
#   [datetime.datetime(2013, 6, 7, 2, 45, 1), 1339234925],
#   [datetime.datetime(2013, 6, 8, 2, 45, 2), 1239395972],
#   [datetime.datetime(2013, 6, 9, 2, 45, 1), 1220874392],
#   [datetime.datetime(2013, 6, 10, 2, 45, 2), 1123844957],
#   [datetime.datetime(2013, 6, 11, 2, 55, 5), 1194605340],
#   [datetime.datetime(2013, 6, 12, 3, 0, 2), 1227904672],
#   [datetime.datetime(2013, 6, 13, 3, 0, 1), 1222819750],
#   [datetime.datetime(2013, 6, 14, 3, 0, 2), 1159766149],
#   [datetime.datetime(2013, 6, 15, 3, 5, 1), 1110902570],
#   [datetime.datetime(2013, 6, 16, 3, 5, 2), 1129287060],
#   [datetime.datetime(2013, 6, 17, 3, 15, 2), 1134610433],
#   [datetime.datetime(2013, 6, 18, 3, 20, 4), 1152834600],
#   [datetime.datetime(2013, 6, 19, 3, 25, 2), 1204638317],
#   [datetime.datetime(2013, 6, 20, 3, 25, 10), 1220273470],
#   [datetime.datetime(2013, 6, 21, 3, 30, 2), 1254733148],
#   [datetime.datetime(2013, 6, 22, 3, 30, 1), 1233750008],
#   [datetime.datetime(2013, 6, 23, 3, 30, 2), 1214260368],
#   [datetime.datetime(2013, 6, 24, 3, 30, 2), 1223181000],
#   [datetime.datetime(2013, 6, 25, 3, 30, 3), 1160635651],
#   [datetime.datetime(2013, 6, 26, 3, 35, 2), 1175194909],
#   [datetime.datetime(2013, 6, 27, 3, 50, 1), 1172207387],
#   [datetime.datetime(2013, 6, 28, 3, 50, 1), 1130338737],
#   [datetime.datetime(2013, 6, 29, 3, 50, 1), 1058953326],
#   [datetime.datetime(2013, 6, 30, 4, 0, 2), 1082693996],
#   [datetime.datetime(2013, 7, 1, 4, 0, 1), 1107084792],
#   [datetime.datetime(2013, 7, 2, 4, 0, 4), 1016445145],
#   [datetime.datetime(2013, 7, 3, 4, 0, 1), 1031653673],
#   [datetime.datetime(2013, 7, 4, 4, 50, 2), 895707780],
#   [datetime.datetime(2013, 7, 5, 4, 46, 1), 892405890],
#   [datetime.datetime(2013, 7, 6, 4, 46, 2), 771368060],
#   [datetime.datetime(2013, 7, 7, 4, 46, 1), 774804400],
#   [datetime.datetime(2013, 7, 8, 4, 46, 2), 882356394],
#   [datetime.datetime(2013, 7, 9, 4, 46, 2), 870081996],
#   [datetime.datetime(2013, 7, 10, 4, 46, 2), 877378425],
#   [datetime.datetime(2013, 7, 11, 5, 1, 1), 977479256],
#   [datetime.datetime(2013, 7, 12, 5, 1, 1), 1069724400],
#   [datetime.datetime(2013, 7, 13, 5, 1, 2), 1004551934],
#   [datetime.datetime(2013, 7, 14, 5, 1, 1), 1090715949],
#   [datetime.datetime(2013, 7, 15, 5, 11, 2), 1073073450],
#   [datetime.datetime(2013, 7, 16, 5, 16, 2), 1111179852],
#   [datetime.datetime(2013, 7, 17, 5, 16, 2), 1130735526],
#   [datetime.datetime(2013, 7, 18, 5, 21, 2), 1117707300],
#   [datetime.datetime(2013, 7, 19, 5, 21, 1), 1015062893],
#   [datetime.datetime(2013, 7, 20, 5, 21, 2), 1047311253],
#   [datetime.datetime(2013, 7, 21, 5, 21, 2), 1021492656],
#   [datetime.datetime(2013, 7, 22, 5, 21, 2), 1034399450],
#   [datetime.datetime(2013, 7, 23, 5, 21, 1), 1050054379],
#   [datetime.datetime(2013, 7, 24, 5, 21, 1), 1083333285],
#   [datetime.datetime(2013, 7, 25, 5, 21, 2), 1083076902],
#   [datetime.datetime(2013, 7, 26, 5, 16, 2), 1111232482],
#   [datetime.datetime(2013, 7, 27, 5, 16, 1), 1079278107],
#   [datetime.datetime(2013, 7, 28, 5, 16, 2), 1078286702],
#   [datetime.datetime(2013, 7, 29, 5, 16, 2), 1131111628],
#   [datetime.datetime(2013, 7, 30, 5, 16, 2), 1165105812],
#   [datetime.datetime(2013, 7, 31, 6, 46, 2), 1267183179],
#   [datetime.datetime(2013, 8, 1, 6, 56, 1), 1220481781],
#   [datetime.datetime(2013, 8, 2, 6, 56, 2), 1167849454],
#   [datetime.datetime(2013, 8, 3, 6, 56, 2), 1192378895],
#   [datetime.datetime(2013, 8, 4, 6, 56, 1), 1206152150],
#   [datetime.datetime(2013, 8, 5, 6, 56, 1), 1226188584],
#   [datetime.datetime(2013, 8, 6, 6, 56, 1), 1218425715],
#   [datetime.datetime(2013, 8, 7, 6, 56), 1229098150],
#   [datetime.datetime(2013, 8, 8, 6, 56, 2), 1212383133],
#   [datetime.datetime(2013, 8, 9, 6, 56, 2), 1198290079],
#   [datetime.datetime(2013, 8, 10, 6, 56, 1), 1195703559],
#   [datetime.datetime(2013, 8, 11, 6, 56, 2), 1193835825],
#   [datetime.datetime(2013, 8, 12, 6, 56, 1), 1204979580],
#   [datetime.datetime(2013, 8, 13, 7, 1, 2), 1234277535],
#   [datetime.datetime(2013, 8, 14, 7, 1, 1), 1277045962],
#   [datetime.datetime(2013, 8, 15, 7, 1, 2), 1290791623],
#   [datetime.datetime(2013, 8, 16, 7, 21, 1), 1255999432],
#   [datetime.datetime(2013, 8, 17, 7, 21, 1), 1260549575],
#   [datetime.datetime(2013, 8, 18, 7, 21, 1), 1297725576],
#   [datetime.datetime(2013, 8, 19, 7, 21, 1), 1364305023],
#   [datetime.datetime(2013, 8, 20, 7, 21, 1), 1391744715],
#   [datetime.datetime(2013, 8, 21, 7, 21, 2), 1390017000],
#   [datetime.datetime(2013, 8, 22, 7, 21, 1), 1412622912],
#   [datetime.datetime(2013, 8, 23, 7, 21, 1), 1404948802],
#   [datetime.datetime(2013, 8, 24, 7, 21, 1), 1380248275],
#   [datetime.datetime(2013, 8, 25, 7, 21, 2), 1398134387],
#   [datetime.datetime(2013, 8, 26, 7, 21, 2), 1413720420],
#   [datetime.datetime(2013, 8, 27, 7, 21, 1), 1420013070],
#   [datetime.datetime(2013, 8, 28, 7, 21, 2), 1467696672],
#   [datetime.datetime(2013, 8, 29, 7, 21, 1), 1423401000],
#   [datetime.datetime(2013, 8, 30, 7, 21, 1), 1414493496],
#   [datetime.datetime(2013, 8, 31, 7, 21, 2), 1548720490],
#   [datetime.datetime(2013, 9, 1, 7, 21, 2), 1595008048],
#   [datetime.datetime(2013, 9, 2, 7, 21, 2), 1590732401],
#   [datetime.datetime(2013, 9, 3, 7, 21, 2), 1575707182],
#   [datetime.datetime(2013, 9, 4, 7, 21, 2), 1589775538],
#   [datetime.datetime(2013, 9, 5, 7, 26, 2), 1483451582],
#   [datetime.datetime(2013, 9, 6, 7, 26, 1), 1466648505],
#   [datetime.datetime(2013, 9, 7, 7, 26, 2), 1413398077],
#   [datetime.datetime(2013, 9, 8, 7, 26, 2), 1440475723],
#   [datetime.datetime(2013, 9, 9, 7, 26, 2), 1410546093],
#   [datetime.datetime(2013, 9, 10, 7, 26, 1), 1485885525],
#   [datetime.datetime(2013, 9, 11, 7, 26, 2), 1441952016],
#   [datetime.datetime(2013, 9, 12, 7, 26, 2), 1571991468],
#   [datetime.datetime(2013, 9, 13, 7, 26, 1), 1593705850],
#   [datetime.datetime(2013, 9, 14, 7, 26, 2), 1551266086],
#   [datetime.datetime(2013, 9, 15, 7, 26, 2), 1505159472],
#   [datetime.datetime(2013, 9, 16, 7, 26, 1), 1528329267],
#   [datetime.datetime(2013, 9, 17, 7, 26, 1), 1482235956],
#   [datetime.datetime(2013, 9, 18, 7, 26, 2), 1531472535],
#   [datetime.datetime(2013, 9, 19, 7, 26, 1), 1535810988],
#   [datetime.datetime(2013, 9, 20, 7, 26, 2), 1521198731],
#   [datetime.datetime(2013, 9, 21, 7, 26, 2), 1495076509],
#   [datetime.datetime(2013, 9, 22, 7, 26, 2), 1493833260],
#   [datetime.datetime(2013, 9, 23, 7, 26, 1), 1507154161],
#   [datetime.datetime(2013, 9, 24, 7, 26, 2), 1484371556],
#   [datetime.datetime(2013, 9, 25, 7, 26, 2), 1513805580],
#   [datetime.datetime(2013, 9, 26, 7, 26, 1), 1515403031],
#   [datetime.datetime(2013, 9, 27, 7, 26, 2), 1530763838],
#   [datetime.datetime(2013, 9, 28, 7, 26, 2), 1584338266],
#   [datetime.datetime(2013, 9, 29, 7, 26, 2), 1629791825],
#   [datetime.datetime(2013, 9, 30, 7, 36, 1), 1583038043],
#   [datetime.datetime(2013, 10, 1, 7, 41, 1), 1577869589],
#   [datetime.datetime(2013, 10, 2, 7, 41, 2), 1550425024],
#   [datetime.datetime(2013, 10, 3, 7, 41, 2), 1432992865],
#   [datetime.datetime(2013, 10, 4, 9, 16, 11), 1484790258],
#   [datetime.datetime(2013, 10, 5, 9, 16, 9), 1522400010],
#   [datetime.datetime(2013, 10, 6, 9, 16, 11), 1519707024],
#   [datetime.datetime(2013, 10, 7, 9, 16, 3), 1528242935],
#   [datetime.datetime(2013, 10, 8, 9, 16, 1), 1489210920],
#   [datetime.datetime(2013, 10, 9, 9, 31, 2), 1504666389],
#   [datetime.datetime(2013, 10, 10, 9, 31, 2), 1549185570],
#   [datetime.datetime(2013, 10, 11, 9, 31, 2), 1539049795],
#   [datetime.datetime(2013, 10, 12, 9, 31, 3), 1574653436],
#   [datetime.datetime(2013, 10, 13, 9, 31, 9), 1592076330],
#   [datetime.datetime(2013, 10, 14, 9, 31, 2), 1657780162],
#   [datetime.datetime(2013, 10, 15, 9, 31, 1), 1653892914],
#   [datetime.datetime(2013, 10, 16, 9, 31, 2), 1798515348],
#   [datetime.datetime(2013, 10, 17, 9, 31, 3), 1708762041],
#   [datetime.datetime(2013, 10, 18, 9, 31, 5), 1737727200],
#   [datetime.datetime(2013, 10, 19, 9, 31, 2), 1936429199],
#   [datetime.datetime(2013, 10, 20, 10, 16, 2), 2055254041],
#   [datetime.datetime(2013, 10, 21, 10, 16, 5), 2116153256],
#   [datetime.datetime(2013, 10, 22, 10, 16, 2), 2289446235],
#   [datetime.datetime(2013, 10, 23, 10, 21, 2), 2318122872],
#   [datetime.datetime(2013, 10, 24, 10, 26, 2), 2263880095],
#   [datetime.datetime(2013, 10, 25, 10, 26, 1), 2208910112],
#   [datetime.datetime(2013, 10, 26, 10, 26, 12), 2205330408],
#   [datetime.datetime(2013, 10, 27, 9, 26, 2), 2170590240],
#   [datetime.datetime(2013, 10, 28, 9, 26, 2), 2332560505],
#   [datetime.datetime(2013, 10, 29, 9, 31, 1), 2383514169],
#   [datetime.datetime(2013, 10, 30, 9, 31, 1), 2411927532],
#   [datetime.datetime(2013, 10, 31, 11, 6, 1), 2400527163],
#   [datetime.datetime(2013, 11, 1, 11, 6, 3), 2430860520],
#   [datetime.datetime(2013, 11, 2, 11, 16, 2), 2472401796],
#   [datetime.datetime(2013, 11, 3, 11, 16, 2), 2448338589],
#   [datetime.datetime(2013, 11, 4, 11, 11, 2), 2586286560],
#   [datetime.datetime(2013, 11, 5, 11, 11, 10), 2753961102],
#   [datetime.datetime(2013, 11, 6, 11, 16, 2), 3070437192],
#   [datetime.datetime(2013, 11, 7, 11, 16, 3), 3518670692],
#   [datetime.datetime(2013, 11, 8, 11, 16, 2), 3825919011],
#   [datetime.datetime(2013, 11, 9, 11, 16, 1), 4228079278],
#   [datetime.datetime(2013, 11, 10, 11, 16, 2), 3779710352],
#   [datetime.datetime(2013, 11, 11, 11, 16, 2), 3980634680],
#   [datetime.datetime(2013, 11, 12, 11, 16, 2), 4328310772],
#   [datetime.datetime(2013, 11, 13, 11, 16, 2), 4493672638],
#   [datetime.datetime(2013, 11, 14, 11, 26, 2), 4897827984],
#   [datetime.datetime(2013, 11, 15, 11, 26, 2), 5132926869],
#   [datetime.datetime(2013, 11, 16, 11, 31, 2), 5294532600],
#   [datetime.datetime(2013, 11, 17, 11, 36, 2), 5625255681],
#   [datetime.datetime(2013, 11, 18, 11, 36, 2), 6705789430],
#   [datetime.datetime(2013, 11, 19, 11, 36, 3), 8103857471],
#   [datetime.datetime(2013, 11, 20, 11, 36, 2), 5798258526],
#   [datetime.datetime(2013, 11, 21, 11, 46, 2), 7456358841],
#   [datetime.datetime(2013, 11, 22, 11, 51, 2), 8790506777],
#   [datetime.datetime(2013, 11, 23, 22, 46, 2), 9730337944],
#   [datetime.datetime(2013, 11, 24, 22, 46, 1), 9349295648],
#   [datetime.datetime(2013, 11, 25, 23, 51, 2), 9529002102],
#   [datetime.datetime(2013, 11, 26, 23, 51, 2), 10946018925],
#   [datetime.datetime(2013, 11, 27, 23, 46, 3), 11850638474],
#   [datetime.datetime(2013, 11, 28, 23, 46, 1), 12426552940],
#   [datetime.datetime(2013, 11, 30, 2, 46, 1), 13853313627],
#   [datetime.datetime(2013, 12, 1, 2, 51, 1), 13541896415],
#   [datetime.datetime(2013, 12, 2, 2, 51, 1), 12038665194],
#   [datetime.datetime(2013, 12, 3, 2, 56, 1), 12438459202],
#   [datetime.datetime(2013, 12, 4, 3, 11, 2), 13004931455],
#   [datetime.datetime(2013, 12, 5, 3, 26, 2), 13613383537],
#   [datetime.datetime(2013, 12, 6, 3, 56, 1), 12117660075],
#   [datetime.datetime(2013, 12, 7, 4, 16, 2), 9250920298],
#   [datetime.datetime(2013, 12, 8, 4, 41, 1), 8397879080],
#   [datetime.datetime(2013, 12, 9, 4, 41, 2), 10135632177],
#   [datetime.datetime(2013, 12, 10, 4, 51, 2), 11155612005],
#   [datetime.datetime(2013, 12, 11, 5, 16, 1), 11596135176],
#   [datetime.datetime(2013, 12, 12, 5, 16, 1), 10329286823],
#   [datetime.datetime(2013, 12, 13, 5, 31, 1), 10978301748],
#   [datetime.datetime(2013, 12, 14, 5, 31, 2), 10820630864],
#   [datetime.datetime(2013, 12, 15, 5, 56, 1), 10307643675],
#   [datetime.datetime(2013, 12, 16, 6, 6, 1), 10539143353],
#   [datetime.datetime(2013, 12, 17, 6, 11, 2), 8119114562],
#   [datetime.datetime(2013, 12, 18, 6, 16, 2), 7818203456],
#   [datetime.datetime(2013, 12, 19, 6, 21, 1), 6802839701],
#   [datetime.datetime(2013, 12, 20, 6, 31, 1), 8650071000],
#   [datetime.datetime(2013, 12, 21, 6, 41, 1), 7757993944],
#   [datetime.datetime(2013, 12, 22, 6, 41, 2), 7412626262],
#   [datetime.datetime(2013, 12, 23, 6, 46, 1), 7846531378],
#   [datetime.datetime(2013, 12, 24, 6, 46, 1), 8169016070],
#   [datetime.datetime(2013, 12, 25, 6, 46, 1), 7968482544],
#   [datetime.datetime(2013, 12, 26, 6, 46, 2), 8448510379],
#   [datetime.datetime(2013, 12, 27, 6, 56, 1), 8968234621],
#   [datetime.datetime(2013, 12, 28, 6, 56, 1), 8891737240],
#   [datetime.datetime(2013, 12, 29, 7, 1, 2), 8769072171],
#   [datetime.datetime(2013, 12, 30, 7, 46, 2), 9176209842],
#   [datetime.datetime(2013, 12, 31, 8, 16, 1), 9114650721],
#   [datetime.datetime(2014, 1, 1, 8, 16, 1), 9375027519],
#   [datetime.datetime(2014, 1, 2, 8, 16, 2), 9400260663],
#   [datetime.datetime(2014, 1, 3, 8, 16, 2), 9777538842],
#   [datetime.datetime(2014, 1, 4, 8, 16, 2), 9872620257],
#   [datetime.datetime(2014, 1, 5, 8, 16, 1), 10533192293],
#   [datetime.datetime(2014, 1, 6, 8, 16, 2), 11895294512],
#   [datetime.datetime(2014, 1, 7, 13, 26, 1), 11238639912],
#   [datetime.datetime(2014, 1, 8, 13, 26, 2), 10489937497],
#   [datetime.datetime(2014, 1, 9, 13, 26, 1), 10291198407],
#   [datetime.datetime(2014, 1, 10, 13, 26, 1), 10235909453],
#   [datetime.datetime(2014, 1, 11, 13, 26, 1), 11120838747],
#   [datetime.datetime(2014, 1, 12, 13, 26, 1), 10579385547],
#   [datetime.datetime(2014, 1, 13, 13, 26, 2), 10236131169],
#   [datetime.datetime(2014, 1, 14, 13, 26, 2), 10257005161],
#   [datetime.datetime(2014, 1, 15, 13, 26, 2), 10586901588],
#   [datetime.datetime(2014, 1, 16, 14, 31, 2), 10466816554],
#   [datetime.datetime(2014, 1, 17, 14, 41, 2), 10118464372],
#   [datetime.datetime(2014, 1, 18, 14, 41, 2), 10293545616],
#   [datetime.datetime(2014, 1, 19, 15, 11, 2), 10240441312],
#   [datetime.datetime(2014, 1, 20, 15, 11, 2), 10634404659],
#   [datetime.datetime(2014, 1, 21, 15, 16, 2), 10660106725],
#   [datetime.datetime(2014, 1, 22, 18, 21, 2), 10407022515],
#   [datetime.datetime(2014, 1, 23, 18, 31, 2), 10192103437],
#   [datetime.datetime(2014, 1, 24, 18, 31, 2), 9875571598],
#   [datetime.datetime(2014, 1, 25, 18, 31, 2), 10468361227],
#   [datetime.datetime(2014, 1, 26, 18, 31, 2), 10966151300],
#   [datetime.datetime(2014, 1, 27, 21, 31, 2), 9896706963],
#   [datetime.datetime(2014, 1, 28, 21, 36, 2), 10030077450],
#   [datetime.datetime(2014, 1, 29, 21, 51, 2), 10174460328],
#   [datetime.datetime(2014, 1, 30, 21, 51, 2), 10105458986],
#   [datetime.datetime(2014, 1, 31, 21, 51, 2), 10153617765],
#   [datetime.datetime(2014, 2, 1, 21, 51, 2), 10391760101],
#   [datetime.datetime(2014, 2, 2, 21, 51, 2), 10241496932],
#   [datetime.datetime(2014, 2, 3, 21, 56, 2), 10117201297],
#   [datetime.datetime(2014, 2, 4, 22, 31, 2), 10268668985],
#   [datetime.datetime(2014, 2, 5, 22, 36, 2), 10152548463],
#   [datetime.datetime(2014, 2, 6, 22, 36, 3), 9682805649],
#   [datetime.datetime(2014, 2, 7, 22, 36, 5), 8977470788],
#   [datetime.datetime(2014, 2, 8, 22, 36, 5), 8503248112],
#   [datetime.datetime(2014, 2, 9, 22, 41, 2), 8568588480],
#   [datetime.datetime(2014, 2, 10, 22, 46, 2), 8273521358],
#   [datetime.datetime(2014, 2, 11, 23, 1, 13), 7902678666],
#   [datetime.datetime(2014, 2, 13, 4, 6, 2), 8103210317],
#   [datetime.datetime(2014, 2, 14, 4, 6, 7), 6981872578],
#   [datetime.datetime(2014, 2, 15, 4, 11, 13), 7991142081],
#   [datetime.datetime(2014, 2, 16, 4, 11, 10), 8166740022],
#   [datetime.datetime(2014, 2, 17, 4, 21, 22), 7645657217],
#   [datetime.datetime(2014, 2, 18, 4, 21, 45), 7963598356],
#   [datetime.datetime(2014, 2, 19, 4, 26, 2), 7763582295],
#   [datetime.datetime(2014, 2, 20, 4, 31, 2), 7765481646],
#   [datetime.datetime(2014, 2, 21, 4, 41, 22), 6824404453],
#   [datetime.datetime(2014, 2, 22, 4, 46, 2), 7053173750],
#   [datetime.datetime(2014, 2, 23, 4, 46, 2), 7630472818],
#   [datetime.datetime(2014, 2, 24, 4, 46, 2), 7195562323],
#   [datetime.datetime(2014, 2, 25, 4, 46, 2), 6195879609],
#   [datetime.datetime(2014, 2, 26, 5, 36, 9), 7013767152],
#   [datetime.datetime(2014, 2, 27, 5, 51, 2), 7239905721],
#   [datetime.datetime(2014, 2, 28, 5, 56, 2), 7115937422],
#   [datetime.datetime(2014, 3, 1, 6, 6, 2), 6955268689],
#   [datetime.datetime(2014, 3, 2, 6, 6, 5), 6992425456],
#   [datetime.datetime(2014, 3, 3, 6, 6, 2), 7150284539],
#   [datetime.datetime(2014, 3, 4, 7, 6, 23), 8257065652],
#   [datetime.datetime(2014, 3, 5, 9, 6, 1), 8280089523],
#   [datetime.datetime(2014, 3, 6, 9, 41, 1), 8267403750],
#   [datetime.datetime(2014, 3, 7, 9, 51, 23), 8179264894],
#   [datetime.datetime(2014, 3, 8, 9, 56, 2), 7766677880],
#   [datetime.datetime(2014, 3, 9, 9, 56, 2), 7774864760],
#   [datetime.datetime(2014, 3, 10, 9, 56, 21), 7987727962],
#   [datetime.datetime(2014, 3, 11, 9, 56, 2), 7883390766],
#   [datetime.datetime(2014, 3, 12, 9, 56, 2), 7948515121],
#   [datetime.datetime(2014, 3, 13, 9, 56, 2), 8003678580],
#   [datetime.datetime(2014, 3, 14, 10, 31, 2), 7923870033],
#   [datetime.datetime(2014, 3, 15, 10, 31, 2), 7908582117],
#   [datetime.datetime(2014, 3, 16, 10, 31, 2), 7943849911],
#   [datetime.datetime(2014, 3, 17, 10, 31, 2), 7794370518],
#   [datetime.datetime(2014, 3, 18, 10, 31, 2), 7729983328],
#   [datetime.datetime(2014, 3, 19, 10, 41, 17), 7732059879],
#   [datetime.datetime(2014, 3, 20, 10, 41, 2), 7568383029],
#   [datetime.datetime(2014, 3, 21, 10, 36, 2), 7531941604],
#   [datetime.datetime(2014, 3, 22, 10, 36, 3), 7096672519],
#   [datetime.datetime(2014, 3, 23, 10, 36, 2), 7116284105],
#   [datetime.datetime(2014, 3, 24, 10, 46, 2), 6983197243],
#   [datetime.datetime(2014, 3, 25, 10, 46, 3), 7197165743],
#   [datetime.datetime(2014, 3, 26, 13, 46, 2), 7343002343],
#   [datetime.datetime(2014, 3, 27, 19, 26, 1), 6564587596],
#   [datetime.datetime(2014, 3, 28, 21, 41, 2), 6177467010],
#   [datetime.datetime(2014, 3, 30, 4, 11, 2), 6108104221],
#   [datetime.datetime(2014, 3, 31, 4, 46, 2), 5995761080],
#   [datetime.datetime(2014, 4, 1, 4, 46, 2), 5772747763],
#   [datetime.datetime(2014, 4, 2, 5, 16, 2), 6062248781],
#   [datetime.datetime(2014, 4, 3, 5, 41, 3), 5381332964],
#   [datetime.datetime(2014, 4, 4, 5, 46, 2), 5505654176],
#   [datetime.datetime(2014, 4, 5, 5, 46, 2), 5698723917],
#   [datetime.datetime(2014, 4, 6, 5, 46, 2), 5856585232],
#   [datetime.datetime(2014, 4, 7, 5, 46, 2), 5746822291],
#   [datetime.datetime(2014, 4, 8, 5, 46, 2), 5718542737],
#   [datetime.datetime(2014, 4, 9, 6, 11, 3), 5738904084],
#   [datetime.datetime(2014, 4, 10, 6, 16, 2), 5400810410],
#   [datetime.datetime(2014, 4, 11, 6, 16, 3), 4823150267],
#   [datetime.datetime(2014, 4, 12, 6, 16, 3), 5535166815],
#   [datetime.datetime(2014, 4, 13, 6, 16, 2), 5370397396],
#   [datetime.datetime(2014, 4, 14, 6, 16, 2), 5176894908],
#   [datetime.datetime(2014, 4, 15, 6, 26, 2), 5759489398],
#   [datetime.datetime(2014, 4, 16, 6, 46, 2), 6524134861],
#   [datetime.datetime(2014, 4, 17, 6, 51, 2), 6575226952],
#   [datetime.datetime(2014, 4, 18, 7, 1, 2), 6252223023],
#   [datetime.datetime(2014, 4, 19, 7, 1, 2), 5975968814],
#   [datetime.datetime(2014, 4, 20, 7, 1, 2), 6393006503],
#   [datetime.datetime(2014, 4, 21, 7, 1, 3), 6435488891],
#   [datetime.datetime(2014, 4, 22, 7, 6, 2), 6322029639],
#   [datetime.datetime(2014, 4, 23, 7, 6, 2), 6226287188],
#   [datetime.datetime(2014, 4, 24, 7, 41, 2), 6195771518],
#   [datetime.datetime(2014, 4, 25, 8, 31, 4), 5790307676],
#   [datetime.datetime(2014, 4, 26, 8, 46, 2), 5733379123],
#   [datetime.datetime(2014, 4, 27, 9, 11, 2), 5788410979],
#   [datetime.datetime(2014, 4, 28, 9, 36, 2), 5407456652],
#   [datetime.datetime(2014, 4, 29, 14, 16, 2), 5685695339],
#   [datetime.datetime(2014, 4, 30, 17, 26, 2), 5673077338],
#   [datetime.datetime(2014, 5, 1, 17, 26, 3), 5731664211],
#   [datetime.datetime(2014, 5, 2, 17, 26, 2), 5666988895],
#   [datetime.datetime(2014, 5, 3, 17, 26, 5), 5610505365],
#   [datetime.datetime(2014, 5, 4, 17, 26, 5), 5517588612],
#   [datetime.datetime(2014, 5, 5, 17, 26, 6), 5473840871],
#   [datetime.datetime(2014, 5, 6, 18, 1, 5), 5487874929],
#   [datetime.datetime(2014, 5, 7, 18, 1, 7), 5607924965],
#   [datetime.datetime(2014, 5, 8, 18, 1, 20), 5626345356],
#   [datetime.datetime(2014, 5, 9, 18, 41, 16), 5741033790],
#   [datetime.datetime(2014, 5, 10, 18, 41, 6), 5754552853],
#   [datetime.datetime(2014, 5, 11, 18, 41, 7), 5528484826],
#   [datetime.datetime(2014, 5, 12, 18, 41, 10), 5630703159],
#   [datetime.datetime(2014, 5, 13, 18, 41, 13), 5614371662],
#   [datetime.datetime(2014, 5, 14, 18, 51, 16), 5673690624],
#   [datetime.datetime(2014, 5, 15, 18, 51, 7), 5724581374],
#   [datetime.datetime(2014, 5, 16, 18, 51, 10), 5730560632],
#   [datetime.datetime(2014, 5, 17, 18, 51, 6), 5724920041],
#   [datetime.datetime(2014, 5, 18, 18, 51, 8), 5716510660],
#   [datetime.datetime(2014, 5, 19, 18, 51, 17), 5692061490],
#   [datetime.datetime(2014, 5, 20, 18, 51, 15), 6183365788],
#   [datetime.datetime(2014, 5, 21, 19, 6, 17), 6298351579],
#   [datetime.datetime(2014, 5, 22, 19, 6, 20), 6609931274],
#   [datetime.datetime(2014, 5, 23, 19, 6, 9), 6700336553],
#   [datetime.datetime(2014, 5, 25, 7, 56, 6), 7115204096],
#   [datetime.datetime(2014, 5, 26, 7, 56, 10), 7521273634],
#   [datetime.datetime(2014, 5, 27, 8, 41, 13), 7497455615],
#   [datetime.datetime(2014, 5, 28, 8, 41, 5), 7382028997],
#   [datetime.datetime(2014, 5, 29, 8, 41, 16), 7269497761],
#   [datetime.datetime(2014, 5, 30, 8, 56, 7), 7305732162],
#   [datetime.datetime(2014, 5, 31, 8, 56, 7), 7920661529],
#   [datetime.datetime(2014, 6, 1, 8, 56, 13), 8325584400],
#   [datetime.datetime(2014, 6, 2, 8, 56, 6), 8004231903],
#   [datetime.datetime(2014, 6, 3, 8, 56, 7), 8443853248],
#   [datetime.datetime(2014, 6, 4, 8, 56, 6), 8213918062],
#   [datetime.datetime(2014, 6, 5, 9, 41, 6), 8306258433],
#   [datetime.datetime(2014, 6, 6, 9, 41, 5), 8453788890],
#   [datetime.datetime(2014, 6, 7, 9, 41, 7), 8398066511],
#   [datetime.datetime(2014, 6, 8, 9, 41, 6), 8461802884],
#   [datetime.datetime(2014, 6, 9, 9, 41, 6), 8332939692],
#   [datetime.datetime(2014, 6, 10, 9, 41, 5), 8472890038],
#   [datetime.datetime(2014, 6, 11, 9, 41, 9), 8374495671],
#   [datetime.datetime(2014, 6, 12, 10, 26, 6), 8202725168],
#   [datetime.datetime(2014, 6, 13, 10, 26, 9), 7874556522],
#   [datetime.datetime(2014, 6, 14, 10, 26, 7), 7540155635],
#   [datetime.datetime(2014, 6, 15, 10, 26, 7), 7215495816],
#   [datetime.datetime(2014, 6, 16, 10, 26, 7), 7737782349],
#   [datetime.datetime(2014, 6, 17, 10, 26, 11), 7698607587],
#   [datetime.datetime(2014, 6, 18, 10, 26, 8), 7907048530],
#   [datetime.datetime(2014, 6, 19, 10, 26, 7), 7879526986],
#   [datetime.datetime(2014, 6, 20, 10, 26, 8), 7615404520],
#   [datetime.datetime(2014, 6, 21, 10, 26, 7), 7648148389],
#   [datetime.datetime(2014, 6, 22, 10, 26, 10), 7816412859],
#   [datetime.datetime(2014, 6, 23, 10, 26, 7), 7678243878],
#   [datetime.datetime(2014, 6, 24, 11, 31, 6), 7688879009],
#   [datetime.datetime(2014, 6, 25, 13, 1, 15), 7398086370],
#   [datetime.datetime(2014, 6, 26, 22, 6, 10), 7423820740],
#   [datetime.datetime(2014, 6, 27, 23, 11, 7), 7577314829],
#   [datetime.datetime(2014, 6, 29, 8, 46, 12), 7788118206],
#   [datetime.datetime(2014, 6, 30, 10, 21, 39), 8122165800],
#   [datetime.datetime(2014, 7, 1, 10, 21, 12), 8486436757],
#   [datetime.datetime(2014, 7, 2, 15, 21, 13), 8372715704],
#   [datetime.datetime(2014, 7, 3, 19, 16, 8), 8371823420],
#   [datetime.datetime(2014, 7, 5, 3, 21, 11), 8200025844],
#   [datetime.datetime(2014, 7, 6, 19, 6, 11), 8244355335],
#   [datetime.datetime(2014, 7, 8, 12, 24), 8082395595],
#   [datetime.datetime(2014, 7, 9, 16, 14), 8116882102],
#   [datetime.datetime(2014, 7, 10, 16, 14), 7986870811],
#   [datetime.datetime(2014, 7, 11, 16, 14), 8183210066],
#   [datetime.datetime(2014, 7, 12, 16, 14), 8177509169],
#   [datetime.datetime(2014, 7, 13, 16, 14), 8186803751],
#   [datetime.datetime(2014, 7, 14, 16, 14), 8070258638],
#   [datetime.datetime(2014, 7, 15, 16, 14), 8122773091],
#   [datetime.datetime(2014, 7, 16, 16, 14), 8032529722],
#   [datetime.datetime(2014, 7, 17, 16, 14), 8078882611],
#   [datetime.datetime(2014, 7, 18, 16, 14), 8092787472],
#   [datetime.datetime(2014, 7, 19, 16, 14), 8188922459],
#   [datetime.datetime(2014, 7, 20, 16, 14), 8151474297],
#   [datetime.datetime(2014, 7, 21, 16, 14), 8094123825],
#   [datetime.datetime(2014, 7, 22, 16, 24), 8116705702],
#   [datetime.datetime(2014, 7, 23, 16, 24), 8130867361],
#   [datetime.datetime(2014, 7, 24, 16, 24), 7849214803],
#   [datetime.datetime(2014, 7, 25, 16, 24), 7859391788],
#   [datetime.datetime(2014, 7, 26, 16, 24), 7809989668],
#   [datetime.datetime(2014, 7, 27, 16, 24), 7809272562],
#   [datetime.datetime(2014, 7, 28, 17, 24), 7612339560],
#   [datetime.datetime(2014, 7, 29, 17, 24), 7631643297],
#   [datetime.datetime(2014, 7, 30, 19, 4), 7544687880],
#   [datetime.datetime(2014, 7, 31, 19, 4), 7660237144],
#   [datetime.datetime(2014, 8, 1, 19, 24), 7814990816],
#   [datetime.datetime(2014, 8, 2, 19, 54), 7712307360],
#   [datetime.datetime(2014, 8, 3, 19, 54), 7681992598],
#   [datetime.datetime(2014, 8, 4, 19, 54), 7725064932],
#   [datetime.datetime(2014, 8, 5, 19, 54), 7684065312],
#   [datetime.datetime(2014, 8, 6, 19, 54), 7689070836],
#   [datetime.datetime(2014, 8, 7, 19, 54), 7730980003],
#   [datetime.datetime(2014, 8, 8, 19, 54), 7778019496],
#   [datetime.datetime(2014, 8, 9, 19, 54), 7733676906],
#   [datetime.datetime(2014, 8, 10, 19, 54), 7747817534],
#   [datetime.datetime(2014, 8, 11, 19, 54), 7620587697],
#   [datetime.datetime(2014, 8, 12, 19, 54), 7479211448],
#   [datetime.datetime(2014, 8, 13, 19, 54), 7089371399],
#   [datetime.datetime(2014, 8, 14, 19, 54), 6788369159],
#   [datetime.datetime(2014, 8, 15, 19, 54), 6486612775],
#   [datetime.datetime(2014, 8, 16, 19, 54), 6657817457],
#   [datetime.datetime(2014, 8, 17, 19, 54), 6472897218],
#   [datetime.datetime(2014, 8, 18, 19, 54), 6052765876],
#   [datetime.datetime(2014, 8, 19, 19, 54), 6284411752],
#   [datetime.datetime(2014, 8, 20, 19, 54), 6636746619],
#   [datetime.datetime(2014, 8, 21, 19, 54), 6915078697],
#   [datetime.datetime(2014, 8, 22, 19, 54), 6819752408],
#   [datetime.datetime(2014, 8, 23, 19, 54), 6605512916],
#   [datetime.datetime(2014, 8, 24, 19, 54), 6741579651],
#   [datetime.datetime(2014, 8, 25, 19, 54), 6624449236],
#   [datetime.datetime(2014, 8, 26, 19, 54), 6751116840],
#   [datetime.datetime(2014, 8, 27, 19, 54), 6758242708],
#   [datetime.datetime(2014, 8, 28, 19, 54), 6705996985],
#   [datetime.datetime(2014, 8, 29, 19, 54), 6738232487],
#   [datetime.datetime(2014, 8, 30, 19, 54), 6663734161],
#   [datetime.datetime(2014, 8, 31, 19, 54), 6278177305],
#   [datetime.datetime(2014, 9, 1, 19, 54), 6367932182],
#   [datetime.datetime(2014, 9, 2, 20, 4), 6380356629],
#   [datetime.datetime(2014, 9, 3, 20, 4), 6309823001],
#   [datetime.datetime(2014, 9, 4, 20, 4), 6457360244],
#   [datetime.datetime(2014, 9, 5, 20, 4), 6413157070],
#   [datetime.datetime(2014, 9, 6, 20, 4), 6453564668],
#   [datetime.datetime(2014, 9, 7, 20, 4), 6428513158],
#   [datetime.datetime(2014, 9, 8, 20, 24), 6343771471],
#   [datetime.datetime(2014, 9, 9, 20, 24), 6253035610],
#   [datetime.datetime(2014, 9, 10, 20, 24), 6421968408],
#   [datetime.datetime(2014, 9, 11, 20, 24), 6290813167],
#   [datetime.datetime(2014, 9, 12, 20, 24), 6312730888],
#   [datetime.datetime(2014, 9, 13, 20, 24), 6376536644],
#   [datetime.datetime(2014, 9, 14, 20, 24), 6337916584],
#   [datetime.datetime(2014, 9, 15, 20, 24), 6327753377],
#   [datetime.datetime(2014, 9, 16, 20, 24), 6236932009],
#   [datetime.datetime(2014, 9, 17, 20, 24), 6027243652],
#   [datetime.datetime(2014, 9, 18, 20, 24), 5649055634],
#   [datetime.datetime(2014, 9, 19, 20, 23, 59), 5301224275],
#   [datetime.datetime(2014, 9, 20, 20, 24), 5488274967],
#   [datetime.datetime(2014, 9, 21, 20, 24), 5349780133],
#   [datetime.datetime(2014, 9, 22, 20, 23, 59), 5349470436],
#   [datetime.datetime(2014, 9, 23, 20, 24), 5786438777],
#   [datetime.datetime(2014, 9, 24, 20, 33, 59), 5708169478],
#   [datetime.datetime(2014, 9, 25, 20, 33, 59), 5466497281],
#   [datetime.datetime(2014, 9, 26, 20, 34), 5389223696],
#   [datetime.datetime(2014, 9, 27, 20, 34), 5306694358],
#   [datetime.datetime(2014, 9, 28, 20, 33, 59), 5078204546],
#   [datetime.datetime(2014, 9, 29, 20, 33, 59), 5081242480],
#   [datetime.datetime(2014, 9, 30, 20, 33, 59), 5119427674],
#   [datetime.datetime(2014, 10, 2, 8, 39), 5127402572],
#   [datetime.datetime(2014, 10, 3, 8, 38, 59), 5019403319],
#   [datetime.datetime(2014, 10, 4, 9, 44), 4785192805],
#   [datetime.datetime(2014, 10, 5, 9, 44), 4379135932],
#   [datetime.datetime(2014, 10, 6, 9, 44), 4291300659],
#   [datetime.datetime(2014, 10, 7, 9, 44), 4366348702],
#   [datetime.datetime(2014, 10, 8, 9, 44), 4451575734],
#   [datetime.datetime(2014, 10, 9, 9, 44, 5), 4771503789],
#   [datetime.datetime(2014, 10, 10, 9, 44), 4961717589],
#   [datetime.datetime(2014, 10, 11, 9, 44), 4841471420],
#   [datetime.datetime(2014, 10, 12, 9, 44), 4828147412],
#   [datetime.datetime(2014, 10, 13, 9, 44), 4985678637],
#   [datetime.datetime(2014, 10, 14, 9, 44), 5418971888],
#   [datetime.datetime(2014, 10, 15, 9, 44), 5328846153],
#   [datetime.datetime(2014, 10, 16, 9, 44), 5265674038],
#   [datetime.datetime(2014, 10, 17, 9, 49), 5137917706],
#   [datetime.datetime(2014, 10, 18, 9, 49), 5105109931],
#   [datetime.datetime(2014, 10, 19, 9, 49), 5264196242],
#   [datetime.datetime(2014, 10, 20, 9, 49), 5134201081],
#   [datetime.datetime(2014, 10, 21, 9, 49), 5155910228],
#   [datetime.datetime(2014, 10, 22, 9, 49), 5188468568],
#   [datetime.datetime(2014, 10, 23, 9, 49), 5000114789],
#   [datetime.datetime(2014, 10, 24, 9, 49), 4821642992],
#   [datetime.datetime(2014, 10, 25, 9, 49), 4748461382],
#   [datetime.datetime(2014, 10, 26, 8, 49), 4741037489],
#   [datetime.datetime(2014, 10, 27, 8, 49), 4733130351],
#   [datetime.datetime(2014, 10, 28, 8, 49), 4801110716],
#   [datetime.datetime(2014, 10, 29, 8, 49), 4799952434],
#   [datetime.datetime(2014, 10, 30, 8, 49), 4569673152],
#   [datetime.datetime(2014, 10, 31, 8, 49, 2), 4645027482],
#   [datetime.datetime(2014, 11, 1, 9, 24), 4427422040],
#   [datetime.datetime(2014, 11, 2, 10, 24), 4372078851],
#   [datetime.datetime(2014, 11, 3, 10, 24), 4449114450],
#   [datetime.datetime(2014, 11, 4, 10, 24), 4391372099],
#   [datetime.datetime(2014, 11, 5, 10, 24), 4533581386],
#   [datetime.datetime(2014, 11, 6, 10, 24), 4584887384],
#   [datetime.datetime(2014, 11, 7, 10, 24), 4683921008],
#   [datetime.datetime(2014, 11, 8, 10, 24), 4629267445],
#   [datetime.datetime(2014, 11, 9, 10, 24), 4706558009],
#   [datetime.datetime(2014, 11, 10, 10, 24), 4853718859],
#   [datetime.datetime(2014, 11, 11, 10, 24), 4961414266],
#   [datetime.datetime(2014, 11, 12, 10, 24), 5108311016],
#   [datetime.datetime(2014, 11, 13, 10, 24), 5914680527],
#   [datetime.datetime(2014, 11, 14, 10, 24), 5196704404],
#   [datetime.datetime(2014, 11, 15, 10, 24), 5335673913],
#   [datetime.datetime(2014, 11, 16, 10, 24), 5224946837],
#   [datetime.datetime(2014, 11, 17, 10, 24), 5535651238],
#   [datetime.datetime(2014, 11, 18, 10, 24), 5186840088],
#   [datetime.datetime(2014, 11, 19, 10, 24), 5183709300],
#   [datetime.datetime(2014, 11, 20, 10, 24), 4934113776],
#   [datetime.datetime(2014, 11, 21, 10, 24), 4775347316],
#   [datetime.datetime(2014, 11, 22, 10, 24), 4851718884],
#   [datetime.datetime(2014, 11, 23, 10, 24), 4831481373],
#   [datetime.datetime(2014, 11, 24, 10, 24), 5069710284],
#   [datetime.datetime(2014, 11, 25, 10, 24), 5323052593],
#   [datetime.datetime(2014, 11, 26, 10, 34), 4998261122],
#   [datetime.datetime(2014, 11, 27, 10, 34), 5043398583],
#   [datetime.datetime(2014, 11, 28, 10, 34), 4921394189],
#   [datetime.datetime(2014, 11, 29, 10, 34), 5135280662],
#   [datetime.datetime(2014, 11, 30, 10, 34), 5165277474],
#   [datetime.datetime(2014, 12, 1, 10, 34), 5152575062],
#   [datetime.datetime(2014, 12, 2, 10, 34), 5167497278],
#   [datetime.datetime(2014, 12, 3, 10, 34), 5105225558],
#   [datetime.datetime(2014, 12, 4, 10, 34), 5098196759],
#   [datetime.datetime(2014, 12, 5, 10, 34), 5062365576],
#   [datetime.datetime(2014, 12, 6, 10, 34), 5084317689],
#   [datetime.datetime(2014, 12, 7, 10, 34), 5091085165],
#   [datetime.datetime(2014, 12, 8, 10, 34, 1), 4980925017],
#   [datetime.datetime(2014, 12, 9, 10, 34), 4765826202],
#   [datetime.datetime(2014, 12, 10, 10, 34), 4757842918],
#   [datetime.datetime(2014, 12, 11, 18, 19), 4848542429],
#   [datetime.datetime(2014, 12, 14, 2, 14), 4715148005],
#   [datetime.datetime(2014, 12, 15, 2, 14), 4778612471],
#   [datetime.datetime(2014, 12, 16, 2, 14), 4701943395],
#   [datetime.datetime(2014, 12, 17, 2, 19), 4547100966],
#   [datetime.datetime(2014, 12, 18, 2, 19), 4377434370],
#   [datetime.datetime(2014, 12, 19, 2, 19), 4242268348],
#   [datetime.datetime(2014, 12, 20, 2, 19), 4314356389],
#   [datetime.datetime(2014, 12, 21, 2, 19), 4482512994],
#   [datetime.datetime(2014, 12, 22, 2, 19), 4389948813],
#   [datetime.datetime(2014, 12, 23, 2, 19, 1), 4542880267],
#   [datetime.datetime(2014, 12, 24, 2, 19), 4559253562],
#   [datetime.datetime(2014, 12, 25, 2, 19), 4339886866],
#   [datetime.datetime(2014, 12, 26, 2, 19, 1), 4337524254],
#   [datetime.datetime(2014, 12, 27, 2, 19, 1), 4435289409],
#   [datetime.datetime(2014, 12, 28, 2, 19, 1), 4322830391],
#   [datetime.datetime(2014, 12, 29, 2, 19), 4369189647],
#   [datetime.datetime(2014, 12, 30, 2, 19), 4290788757],
#   [datetime.datetime(2014, 12, 31, 2, 19, 1), 4245280800],
#   [datetime.datetime(2015, 1, 1, 2, 19, 1), 4345601963],
#   [datetime.datetime(2015, 1, 2, 2, 19), 4289287759],
#   [datetime.datetime(2015, 1, 3, 2, 19), 4307374369],
#   [datetime.datetime(2015, 1, 4, 2, 19), 3848549170],
#   [datetime.datetime(2015, 1, 5, 2, 19, 1), 3650984440],
#   [datetime.datetime(2015, 1, 6, 2, 19, 1), 3753949381],
#   [datetime.datetime(2015, 1, 7, 2, 19, 1), 3879255971],
#   [datetime.datetime(2015, 1, 8, 2, 19), 4024290266],
#   [datetime.datetime(2015, 1, 9, 2, 19, 1), 3871292298],
#   [datetime.datetime(2015, 1, 10, 10, 59, 1), 3808946374],
#   [datetime.datetime(2015, 1, 11, 10, 59, 1), 3766686283],
#   [datetime.datetime(2015, 1, 12, 10, 59, 1), 3675616212],
#   [datetime.datetime(2015, 1, 13, 10, 59, 1), 3355188725],
#   [datetime.datetime(2015, 1, 14, 10, 59, 1), 2851633026],
#   [datetime.datetime(2015, 1, 15, 10, 59, 1), 2813068301],
#   [datetime.datetime(2015, 1, 16, 10, 59, 1), 2994329454],
#   [datetime.datetime(2015, 1, 17, 10, 59, 1), 2708756783],
#   [datetime.datetime(2015, 1, 18, 10, 59, 1), 2891839558],
#   [datetime.datetime(2015, 1, 19, 10, 59, 1), 2861871773],
#   [datetime.datetime(2015, 1, 20, 10, 59, 1), 2877924232],
#   [datetime.datetime(2015, 1, 21, 10, 59), 2937610959],
#   [datetime.datetime(2015, 1, 22, 10, 59, 1), 3175391943],
#   [datetime.datetime(2015, 1, 23, 10, 59, 1), 3117289084],
#   [datetime.datetime(2015, 1, 24, 10, 59), 3204386274],
#   [datetime.datetime(2015, 1, 25, 10, 59, 1), 3389816225],
#   [datetime.datetime(2015, 1, 26, 10, 59, 1), 4120903457],
#   [datetime.datetime(2015, 1, 27, 10, 59), 3554872118],
#   [datetime.datetime(2015, 1, 28, 10, 59, 1), 3610527384],
#   [datetime.datetime(2015, 1, 29, 10, 59, 1), 3174116640],
#   [datetime.datetime(2015, 1, 30, 10, 59, 1), 3207876399],
#   [datetime.datetime(2015, 1, 31, 10, 59, 1), 3197785951],
#   [datetime.datetime(2015, 2, 1, 11, 9, 1), 2932754485],
#   [datetime.datetime(2015, 2, 2, 11, 9, 20), 3098862238],
#   [datetime.datetime(2015, 2, 3, 11, 9, 21), 3304247798],
#   [datetime.datetime(2015, 2, 4, 11, 14, 19), 3084186083],
#   [datetime.datetime(2015, 2, 5, 11, 14, 19), 3118027956],
#   [datetime.datetime(2015, 2, 6, 11, 14, 20), 3021929922],
#   [datetime.datetime(2015, 2, 7, 11, 14, 25), 3161297986],
#   [datetime.datetime(2015, 2, 8, 11, 14, 20), 3141965896],
#   [datetime.datetime(2015, 2, 9, 11, 14, 20), 3074677811],
#   [datetime.datetime(2015, 2, 10, 11, 19, 20), 2991226156],
#   [datetime.datetime(2015, 2, 11, 11, 19, 20), 3049515934],
#   [datetime.datetime(2015, 2, 12, 11, 19, 20), 3030286962],
#   [datetime.datetime(2015, 2, 13, 11, 19, 21), 3248286280],
#   [datetime.datetime(2015, 2, 14, 11, 19, 21), 3429086744],
#   [datetime.datetime(2015, 2, 15, 11, 24, 22), 3636040558],
#   [datetime.datetime(2015, 2, 16, 11, 29, 20), 3288133689],
#   [datetime.datetime(2015, 2, 17, 11, 29, 19), 3291510942],
#   [datetime.datetime(2015, 2, 18, 11, 29, 20), 3346731825],
#   [datetime.datetime(2015, 2, 19, 11, 29, 19), 3281224349],
#   [datetime.datetime(2015, 2, 20, 11, 29, 22), 3411751633],
#   [datetime.datetime(2015, 2, 21, 11, 29, 20), 3380093375],
#   [datetime.datetime(2015, 2, 22, 11, 44, 19), 3400132507],
#   [datetime.datetime(2015, 2, 23, 11, 44, 20), 3253406963],
#   [datetime.datetime(2015, 2, 24, 11, 44, 20), 3282405035],
#   [datetime.datetime(2015, 2, 25, 11, 44, 21), 3272446748],
#   [datetime.datetime(2015, 2, 26, 11, 44, 20), 3278060208],
#   [datetime.datetime(2015, 2, 27, 11, 44, 19), 3496113393],
#   [datetime.datetime(2015, 2, 28, 13, 44, 19), 3511637500],
#   [datetime.datetime(2015, 3, 1, 13, 44, 20), 3418854940],
#   [datetime.datetime(2015, 3, 2, 13, 44, 20), 3596686084],
#   [datetime.datetime(2015, 3, 3, 13, 44, 20), 3757039683],
#   [datetime.datetime(2015, 3, 4, 19, 29, 19), 3921472230],
#   [datetime.datetime(2015, 3, 5, 19, 34, 20), 3715418089],
#   [datetime.datetime(2015, 3, 6, 19, 34, 19), 3771089115],
#   [datetime.datetime(2015, 3, 7, 19, 39, 20), 3842565008],
#   [datetime.datetime(2015, 3, 8, 19, 39, 21), 3824308700],
#   [datetime.datetime(2015, 3, 9, 19, 49, 19), 3990421912],
#   [datetime.datetime(2015, 3, 10, 19, 54, 19), 4110333413],
#   [datetime.datetime(2015, 3, 11, 19, 54, 19), 4125292446],
#   [datetime.datetime(2015, 3, 12, 19, 54, 20), 4131676728],
#   [datetime.datetime(2015, 3, 13, 19, 59, 20), 4009506313],
#   [datetime.datetime(2015, 3, 14, 20, 4, 20), 3944860422],
#   [datetime.datetime(2015, 3, 15, 20, 4, 21), 3962828226],
#   [datetime.datetime(2015, 3, 16, 20, 4, 22), 4058871698],
#   [datetime.datetime(2015, 3, 17, 20, 4, 22), 4017292623],
#   [datetime.datetime(2015, 3, 18, 20, 4, 22), 3723705566],
#   [datetime.datetime(2015, 3, 19, 20, 9, 21), 3626492241],
#   [datetime.datetime(2015, 3, 20, 20, 14, 21), 3639131051],
#   [datetime.datetime(2015, 3, 21, 20, 19, 21), 3637526863],
#   [datetime.datetime(2015, 3, 22, 20, 19, 21), 3669968700],
#   [datetime.datetime(2015, 3, 23, 20, 19, 22), 3676053749],
#   [datetime.datetime(2015, 3, 24, 20, 19, 22), 3448861669],
#   [datetime.datetime(2015, 3, 25, 20, 19, 22), 3426432676],
#   [datetime.datetime(2015, 3, 26, 20, 19, 19), 3541436382],
#   [datetime.datetime(2015, 3, 27, 20, 19, 21), 3474922114],
#   [datetime.datetime(2015, 3, 28, 20, 19, 21), 3521673717],
#   [datetime.datetime(2015, 3, 29, 21, 44, 21), 3426239160],
#   [datetime.datetime(2015, 3, 30, 23, 29, 19), 3469694824],
#   [datetime.datetime(2015, 3, 31, 23, 54, 22), 3438997948],
#   [datetime.datetime(2015, 4, 2, 3, 59, 21), 3472729978],
#   [datetime.datetime(2015, 4, 3, 3, 59, 21), 3547549559],
#   [datetime.datetime(2015, 4, 4, 4, 9, 21), 3574913192],
#   [datetime.datetime(2015, 4, 5, 4, 9, 21), 3549704856],
#   [datetime.datetime(2015, 4, 6, 4, 14, 21), 3668097103],
#   [datetime.datetime(2015, 4, 7, 4, 14, 21), 3544201888],
#   [datetime.datetime(2015, 4, 8, 4, 14, 22), 3550136355],
#   [datetime.datetime(2015, 4, 9, 4, 34, 21), 3435976468],
#   [datetime.datetime(2015, 4, 10, 4, 34, 21), 3407562580],
#   [datetime.datetime(2015, 4, 11, 4, 34, 21), 3317215986],
#   [datetime.datetime(2015, 4, 12, 4, 34, 21), 3332846528],
#   [datetime.datetime(2015, 4, 13, 4, 34, 22), 3312552620],
#   [datetime.datetime(2015, 4, 14, 4, 34, 22), 3150265219],
#   [datetime.datetime(2015, 4, 15, 6, 9, 21), 3121110924],
#   [datetime.datetime(2015, 4, 16, 6, 14, 22), 3176590483],
#   [datetime.datetime(2015, 4, 17, 6, 19, 22), 3213681992],
#   [datetime.datetime(2015, 4, 18, 6, 24, 23), 3141396045],
#   [datetime.datetime(2015, 4, 19, 6, 39, 22), 3146724471],
#   [datetime.datetime(2015, 4, 20, 7, 19, 23), 3146493803],
#   [datetime.datetime(2015, 4, 21, 7, 24, 22), 3172533292],
#   [datetime.datetime(2015, 4, 22, 7, 34, 23), 3303065945],
#   [datetime.datetime(2015, 4, 23, 7, 34, 22), 3293427801],
#   [datetime.datetime(2015, 4, 24, 7, 44, 23), 3265078364],
#   [datetime.datetime(2015, 4, 25, 8, 44, 22), 3239046278],
#   [datetime.datetime(2015, 4, 26, 14, 59, 23), 3082924255],
#   [datetime.datetime(2015, 4, 27, 14, 59, 23), 3108026628],
#   [datetime.datetime(2015, 4, 28, 15, 4, 22), 3172247583],
#   [datetime.datetime(2015, 4, 29, 15, 19, 21), 3169000924],
#   [datetime.datetime(2015, 4, 30, 16, 24, 20), 3303850494],
#   [datetime.datetime(2015, 5, 1, 16, 24, 20), 3318464989],
#   [datetime.datetime(2015, 5, 2, 16, 39, 19), 3314728349],
#   [datetime.datetime(2015, 5, 3, 16, 44, 19), 3415504970],
#   [datetime.datetime(2015, 5, 4, 16, 44, 19), 3417049721],
#   [datetime.datetime(2015, 5, 5, 17, 9, 18), 3318757221],
#   [datetime.datetime(2015, 5, 6, 18, 49, 20), 3320275175],
#   [datetime.datetime(2015, 5, 7, 18, 49, 20), 3279491422],
#   [datetime.datetime(2015, 5, 8, 18, 49, 20), 3476741981],
#   [datetime.datetime(2015, 5, 9, 18, 49, 20), 3410996344],
#   [datetime.datetime(2015, 5, 10, 18, 49, 19), 3401965502],
#   [datetime.datetime(2015, 5, 11, 18, 54, 20), 3447508596],
#   [datetime.datetime(2015, 5, 12, 18, 59, 21), 3426188781],
#   [datetime.datetime(2015, 5, 13, 18, 59, 22), 3438268055],
#   [datetime.datetime(2015, 5, 14, 18, 59, 20), 3347749805],
#   [datetime.datetime(2015, 5, 15, 18, 59, 25), 3363986983],
#   [datetime.datetime(2015, 5, 16, 18, 59, 20), 3363167493],
#   [datetime.datetime(2015, 5, 17, 18, 59, 20), 3364091343],
#   [datetime.datetime(2015, 5, 18, 18, 59, 20), 3356103839],
#   [datetime.datetime(2015, 5, 19, 19, 9, 23), 3308309428],
#   [datetime.datetime(2015, 5, 20, 19, 14, 19), 3327909958],
#   [datetime.datetime(2015, 5, 21, 19, 14, 21), 3350546405],
#   [datetime.datetime(2015, 5, 22, 19, 14, 21), 3360738159],
#   [datetime.datetime(2015, 5, 23, 19, 14, 20), 3409088722],
#   [datetime.datetime(2015, 5, 24, 19, 14, 20), 3429956268],
#   [datetime.datetime(2015, 5, 25, 19, 34, 21), 3369803070],
#   [datetime.datetime(2015, 5, 26, 19, 59, 21), 3373050560],
#   [datetime.datetime(2015, 5, 27, 20, 9, 20), 3363816253],
#   [datetime.datetime(2015, 5, 28, 22, 54, 20), 3373675768],
#   [datetime.datetime(2015, 5, 29, 22, 54, 21), 3370190445],
#   [datetime.datetime(2015, 5, 30, 23, 9, 21), 3307068042],
#   [datetime.datetime(2015, 5, 31, 23, 9, 21), 3297894742],
#   [datetime.datetime(2015, 6, 1, 23, 24, 20), 3166420065],
#   [datetime.datetime(2015, 6, 3, 0, 29, 20), 3211363373],
#   [datetime.datetime(2015, 6, 4, 0, 29, 21), 3217797867],
#   [datetime.datetime(2015, 6, 5, 0, 29, 20), 3196874056],
#   [datetime.datetime(2015, 6, 6, 0, 29, 21), 3207088735],
#   [datetime.datetime(2015, 6, 7, 1, 29, 20), 3205253467],
#   [datetime.datetime(2015, 6, 8, 1, 29, 20), 3183902511],
#   [datetime.datetime(2015, 6, 9, 1, 29, 21), 3255937616],
#   [datetime.datetime(2015, 6, 10, 1, 29, 19), 3268406686],
#   [datetime.datetime(2015, 6, 11, 1, 29, 20), 3262359707],
#   [datetime.datetime(2015, 6, 12, 1, 29, 20), 3275768947],
#   [datetime.datetime(2015, 6, 13, 1, 29, 26), 3284984267],
#   [datetime.datetime(2015, 6, 14, 2, 29, 21), 3317671899],
#   [datetime.datetime(2015, 6, 15, 2, 29, 23), 3332954967],
#   [datetime.datetime(2015, 6, 16, 2, 29, 21), 3378059557],
#   [datetime.datetime(2015, 6, 17, 2, 29, 20), 3604399193],
#   [datetime.datetime(2015, 6, 18, 2, 29, 19), 3556041989],
#   [datetime.datetime(2015, 6, 19, 2, 29, 20), 3569721791],
#   [datetime.datetime(2015, 6, 20, 2, 29, 19), 3487268038],
#   [datetime.datetime(2015, 6, 21, 2, 29, 20), 3499099248],
#   [datetime.datetime(2015, 6, 22, 2, 34, 20), 3487360825],
#   [datetime.datetime(2015, 6, 23, 2, 34, 21), 3528441317],
#   [datetime.datetime(2015, 6, 24, 2, 34, 20), 3492940561],
#   [datetime.datetime(2015, 6, 25, 2, 34, 20), 3446189171],
#   [datetime.datetime(2015, 6, 26, 2, 34, 20), 3473639996],
#   [datetime.datetime(2015, 6, 27, 2, 34, 21), 3486208542],
#   [datetime.datetime(2015, 6, 28, 2, 34, 20), 3589623988],
#   [datetime.datetime(2015, 6, 29, 2, 34, 21), 3563321533],
#   [datetime.datetime(2015, 6, 30, 2, 34, 20), 3681402721],
#   [datetime.datetime(2015, 7, 1, 2, 34, 27), 3784372504],
#   [datetime.datetime(2015, 7, 2, 2, 34, 21), 3714048672],
#   [datetime.datetime(2015, 7, 3, 2, 34, 20), 3668022766],
#   [datetime.datetime(2015, 7, 4, 2, 34, 22), 3681165676],
#   [datetime.datetime(2015, 7, 5, 2, 34, 22), 3742137146],
#   [datetime.datetime(2015, 7, 6, 2, 34, 21), 3888172339],
#   [datetime.datetime(2015, 7, 7, 2, 34, 21), 3843241340],
#   [datetime.datetime(2015, 7, 8, 2, 34, 20), 3798502073],
#   [datetime.datetime(2015, 7, 9, 2, 34, 19), 3844791618],
#   [datetime.datetime(2015, 7, 10, 2, 34, 20), 3867029661],
#   [datetime.datetime(2015, 7, 11, 2, 34, 20), 4110352701],
#   [datetime.datetime(2015, 7, 12, 2, 34, 19), 4212905538],
#   [datetime.datetime(2015, 7, 13, 2, 34, 19), 4454664674],
#   [datetime.datetime(2015, 7, 14, 2, 34, 24), 4192223068],
#   [datetime.datetime(2015, 7, 15, 2, 39, 56), 4178565394],
#   [datetime.datetime(2015, 7, 16, 2, 39, 21), 4189402692],
#   [datetime.datetime(2015, 7, 17, 2, 39, 19), 4001980744],
#   [datetime.datetime(2015, 7, 18, 2, 39, 21), 4023355685],
#   [datetime.datetime(2015, 7, 19, 2, 44, 20), 3952584984],
#   [datetime.datetime(2015, 7, 20, 2, 49, 21), 3940416003],
#   [datetime.datetime(2015, 7, 21, 2, 49, 22), 4024532627],
#   [datetime.datetime(2015, 7, 22, 2, 59, 21), 3978914464],
#   [datetime.datetime(2015, 7, 23, 2, 59, 21), 3998474724],
#   [datetime.datetime(2015, 7, 24, 2, 59, 21), 3975213232],
#   [datetime.datetime(2015, 7, 25, 2, 59, 20), 4142634316],
#   [datetime.datetime(2015, 7, 26, 2, 59, 21), 4164345963],
#   [datetime.datetime(2015, 7, 27, 2, 59, 21), 4215400624],
#   [datetime.datetime(2015, 7, 28, 2, 59, 22), 4256097823],
#   [datetime.datetime(2015, 7, 29, 2, 59, 22), 4241127355],
#   [datetime.datetime(2015, 7, 30, 2, 59, 21), 4165297674],
#   [datetime.datetime(2015, 7, 31, 2, 59, 22), 4156876481],
#   [datetime.datetime(2015, 8, 1, 2, 59, 22), 4112500665],
#   [datetime.datetime(2015, 8, 2, 3, 4, 22), 4042133466],
#   [datetime.datetime(2015, 8, 3, 3, 4, 21), 4078449217],
#   [datetime.datetime(2015, 8, 4, 3, 4, 26), 4079086669],
#   [datetime.datetime(2015, 8, 5, 3, 14, 21), 4117595320],
#   [datetime.datetime(2015, 8, 6, 3, 14, 21), 4071191851],
#   [datetime.datetime(2015, 8, 7, 3, 14, 22), 4033878314],
#   [datetime.datetime(2015, 8, 8, 3, 14, 21), 4046202457],
#   [datetime.datetime(2015, 8, 9, 3, 14, 22), 3789713465],
#   [datetime.datetime(2015, 8, 10, 3, 14, 22), 3851303638],
#   [datetime.datetime(2015, 8, 11, 3, 14, 21), 3831151482],
#   [datetime.datetime(2015, 8, 12, 3, 29, 21), 3886143638],
#   [datetime.datetime(2015, 8, 13, 3, 29, 21), 3851673933],
#   [datetime.datetime(2015, 8, 14, 3, 29, 21), 3826343657],
# ...
#   [datetime.datetime(2015, 5, 2, 16, 39, 19), 15939300],
#   [datetime.datetime(2015, 5, 3, 16, 44, 19), 16861500],
#   [datetime.datetime(2015, 5, 4, 16, 44, 19), 16063800],
#   [datetime.datetime(2015, 5, 5, 17, 9, 18), 25902100],
#   [datetime.datetime(2015, 5, 6, 18, 49, 20), 17272400],
#   [datetime.datetime(2015, 5, 7, 18, 49, 20), 32649900],
#   [datetime.datetime(2015, 5, 8, 18, 49, 20), 32948700],
#   [datetime.datetime(2015, 5, 9, 18, 49, 20), 25349500],
#   [datetime.datetime(2015, 5, 10, 18, 49, 19), 15597600],
#   [datetime.datetime(2015, 5, 11, 18, 54, 20), 17472700],
#   [datetime.datetime(2015, 5, 12, 18, 59, 21), 21352400],
#   [datetime.datetime(2015, 5, 13, 18, 59, 22), 17839200],
#   [datetime.datetime(2015, 5, 14, 18, 59, 20), 28772200],
#   [datetime.datetime(2015, 5, 15, 18, 59, 25), 20008000],
#   [datetime.datetime(2015, 5, 16, 18, 59, 20), 12811900],
#   [datetime.datetime(2015, 5, 17, 18, 59, 20), 11257500],
#   [datetime.datetime(2015, 5, 18, 18, 59, 20), 12963900],
#   [datetime.datetime(2015, 5, 19, 19, 9, 23), 17644200],
#   [datetime.datetime(2015, 5, 20, 19, 14, 19), 15952000],
#   [datetime.datetime(2015, 5, 21, 19, 14, 21), 15400400],
#   [datetime.datetime(2015, 5, 22, 19, 14, 21), 19170400],
#   [datetime.datetime(2015, 5, 23, 19, 14, 20), 21821300],
#   [datetime.datetime(2015, 5, 24, 19, 14, 20), 12507600],
#   [datetime.datetime(2015, 5, 25, 19, 34, 21), 13777600],
#   [datetime.datetime(2015, 5, 26, 19, 59, 21), 15536800],
#   [datetime.datetime(2015, 5, 27, 20, 9, 20), 18473500],
#   [datetime.datetime(2015, 5, 28, 22, 54, 20), 13725800],
#   [datetime.datetime(2015, 5, 29, 22, 54, 21), 15242500],
#   [datetime.datetime(2015, 5, 30, 23, 9, 21), 14166700],
#   [datetime.datetime(2015, 5, 31, 23, 9, 21), 12519500],
#   [datetime.datetime(2015, 6, 1, 23, 24, 20), 25922900],
#   [datetime.datetime(2015, 6, 3, 0, 29, 20), 20742500],
#   [datetime.datetime(2015, 6, 4, 0, 29, 21), 17462200],
#   [datetime.datetime(2015, 6, 5, 0, 29, 20), 14461900],
#   [datetime.datetime(2015, 6, 6, 0, 29, 21), 18190200],
#   [datetime.datetime(2015, 6, 7, 1, 29, 20), 10568700],
#   [datetime.datetime(2015, 6, 8, 1, 29, 20), 13654600],
#   [datetime.datetime(2015, 6, 9, 1, 29, 21), 23342800],
#   [datetime.datetime(2015, 6, 10, 1, 29, 19), 28156800],
#   [datetime.datetime(2015, 6, 11, 1, 29, 20), 15904400],
#   [datetime.datetime(2015, 6, 12, 1, 29, 20), 14609500],
#   [datetime.datetime(2015, 6, 13, 1, 29, 26), 14004900],
#   [datetime.datetime(2015, 6, 14, 2, 29, 21), 12714400],
#   [datetime.datetime(2015, 6, 15, 2, 29, 23), 12266200],
#   [datetime.datetime(2015, 6, 16, 2, 29, 21), 20029300],
#   [datetime.datetime(2015, 6, 17, 2, 29, 20), 42924100],
#   [datetime.datetime(2015, 6, 18, 2, 29, 19), 42633100],
#   [datetime.datetime(2015, 6, 19, 2, 29, 20), 31076200],
#   [datetime.datetime(2015, 6, 20, 2, 29, 19), 24655600],
#   [datetime.datetime(2015, 6, 21, 2, 29, 20), 19823200],
#   [datetime.datetime(2015, 6, 22, 2, 34, 20), 10607100],
#   [datetime.datetime(2015, 6, 23, 2, 34, 21), 17576300],
#   [datetime.datetime(2015, 6, 24, 2, 34, 20), 15309800],
#   [datetime.datetime(2015, 6, 25, 2, 34, 20), 17090000],
#   [datetime.datetime(2015, 6, 26, 2, 34, 20), 15904600],
#   [datetime.datetime(2015, 6, 27, 2, 34, 21), 13769300],
#   [datetime.datetime(2015, 6, 28, 2, 34, 20), 20587900],
#   [datetime.datetime(2015, 6, 29, 2, 34, 21), 15025600],
#   [datetime.datetime(2015, 6, 30, 2, 34, 20), 34722300],
#   [datetime.datetime(2015, 7, 1, 2, 34, 27), 44669600],
#   [datetime.datetime(2015, 7, 2, 2, 34, 21), 26947900],
#   [datetime.datetime(2015, 7, 3, 2, 34, 20), 21435300],
#   [datetime.datetime(2015, 7, 4, 2, 34, 22), 19017900],
#   [datetime.datetime(2015, 7, 5, 2, 34, 22), 15464000],
#   [datetime.datetime(2015, 7, 6, 2, 34, 21), 44697100],
#   [datetime.datetime(2015, 7, 7, 2, 34, 21), 49703100],
#   [datetime.datetime(2015, 7, 8, 2, 34, 20), 27847400],
#   [datetime.datetime(2015, 7, 9, 2, 34, 19), 36849400],
#   [datetime.datetime(2015, 7, 10, 2, 34, 20), 40454400],
#   [datetime.datetime(2015, 7, 11, 2, 34, 20), 100412000],
#   [datetime.datetime(2015, 7, 12, 2, 34, 19), 40447000],
#   [datetime.datetime(2015, 7, 13, 2, 34, 19), 56392900],
#   [datetime.datetime(2015, 7, 14, 2, 34, 24), 61330500],
#   [datetime.datetime(2015, 7, 15, 2, 39, 56), 29467300],
#   [datetime.datetime(2015, 7, 16, 2, 39, 21), 29174900],
#   [datetime.datetime(2015, 7, 17, 2, 39, 19), 49482600],
#   [datetime.datetime(2015, 7, 18, 2, 39, 21), 27344700],
#   [datetime.datetime(2015, 7, 19, 2, 44, 20), 25371800],
#   [datetime.datetime(2015, 7, 20, 2, 49, 21), 15558600],
#   [datetime.datetime(2015, 7, 21, 2, 49, 22), 22273800],
#   [datetime.datetime(2015, 7, 22, 2, 59, 21), 23182500],
#   [datetime.datetime(2015, 7, 23, 2, 59, 21), 18615900],
#   [datetime.datetime(2015, 7, 24, 2, 59, 21), 18377800],
#   [datetime.datetime(2015, 7, 25, 2, 59, 20), 37326400],
#   [datetime.datetime(2015, 7, 26, 2, 59, 21), 20062200],
#   [datetime.datetime(2015, 7, 27, 2, 59, 21), 15984000],
#   [datetime.datetime(2015, 7, 28, 2, 59, 22), 31177800],
#   [datetime.datetime(2015, 7, 29, 2, 59, 22), 25193500],
#   [datetime.datetime(2015, 7, 30, 2, 59, 21), 24739600],
#   [datetime.datetime(2015, 7, 31, 2, 59, 22), 21319400],
#   [datetime.datetime(2015, 8, 1, 2, 59, 22), 23205300],
#   [datetime.datetime(2015, 8, 2, 3, 4, 22), 19310000],
#   [datetime.datetime(2015, 8, 3, 3, 4, 21), 17210200],
#   [datetime.datetime(2015, 8, 4, 3, 4, 26), 22122200],
#   [datetime.datetime(2015, 8, 5, 3, 14, 21), 21201300],
#   [datetime.datetime(2015, 8, 6, 3, 14, 21), 20604100],
#   [datetime.datetime(2015, 8, 7, 3, 14, 22), 17952300],
#   [datetime.datetime(2015, 8, 8, 3, 14, 21), 42342900],
#   [datetime.datetime(2015, 8, 9, 3, 14, 22), 58689800],
#   [datetime.datetime(2015, 8, 10, 3, 14, 22), 22285600],
#   [datetime.datetime(2015, 8, 11, 3, 14, 21), 20524000],
#   [datetime.datetime(2015, 8, 12, 3, 29, 21), 24977000],
#   [datetime.datetime(2015, 8, 13, 3, 29, 21), 26974200],
#   [datetime.datetime(2015, 8, 14, 3, 29, 21), 27216500],
#   [datetime.datetime(2015, 8, 15, 3, 29, 23), 27091900],
#   [datetime.datetime(2015, 8, 16, 3, 29, 20), 19510600],
#   [datetime.datetime(2015, 8, 17, 3, 29, 21), 29052400],
#   [datetime.datetime(2015, 8, 18, 3, 29, 20), 22034500],
#   [datetime.datetime(2015, 8, 19, 3, 29, 22), 63601000],
#   [datetime.datetime(2015, 8, 20, 3, 44, 21), 45257000],
#   [datetime.datetime(2015, 8, 21, 3, 44, 22), 30539300],
#   [datetime.datetime(2015, 8, 22, 3, 44, 21), 23355900],
#   [datetime.datetime(2015, 8, 23, 3, 49, 21), 22995600],
#   [datetime.datetime(2015, 8, 24, 3, 49, 21), 19533100],
#   [datetime.datetime(2015, 8, 25, 3, 54, 21), 65919600],
#   [datetime.datetime(2015, 8, 26, 3, 54, 20), 52402700],
#   [datetime.datetime(2015, 8, 27, 3, 54, 21), 31120600],
#   [datetime.datetime(2015, 8, 28, 3, 54, 21), 22965600],
#   [datetime.datetime(2015, 8, 29, 3, 54, 21), 29428400],
#   [datetime.datetime(2015, 8, 30, 4, 4, 21), 17820200],
#   [datetime.datetime(2015, 8, 31, 4, 4, 23), 18923200],
#   [datetime.datetime(2015, 9, 1, 4, 4, 20), 20222800],
#   [datetime.datetime(2015, 9, 2, 4, 4, 24), 20112300],
#   [datetime.datetime(2015, 9, 3, 4, 4, 21), 18480400],
#   [datetime.datetime(2015, 9, 4, 4, 4, 21), 18118800],
#   [datetime.datetime(2015, 9, 5, 4, 4, 23), 17494500],
#   [datetime.datetime(2015, 9, 6, 4, 4, 22), 19369500],
#   [datetime.datetime(2015, 9, 7, 4, 4, 22), 23695600],
#   [datetime.datetime(2015, 9, 8, 4, 4, 21), 19512600],
#   [datetime.datetime(2015, 9, 9, 4, 14, 21), 24843300],
#   [datetime.datetime(2015, 9, 10, 4, 19, 21), 21024500],
#   [datetime.datetime(2015, 9, 11, 4, 19, 23), 19597800],
#   [datetime.datetime(2015, 9, 12, 4, 19, 21), 16826300],
#   [datetime.datetime(2015, 9, 13, 4, 29, 22), 16206200],
#   [datetime.datetime(2015, 9, 14, 4, 29, 21), 17506600],
#   [datetime.datetime(2015, 9, 15, 4, 29, 23), 18772300],
#   [datetime.datetime(2015, 9, 16, 4, 29, 21), 16233700],
#   [datetime.datetime(2015, 9, 17, 4, 29, 21), 18810900],
#   [datetime.datetime(2015, 9, 19, 6, 59, 23), 16217800],
#   [datetime.datetime(2015, 9, 20, 7, 14, 23), 11954800],
#   [datetime.datetime(2015, 9, 21, 10, 24, 27), 14191700],
#   [datetime.datetime(2015, 9, 22, 12, 14, 22), 22857700],
#   [datetime.datetime(2015, 9, 23, 12, 14, 22), 18445900],
#   [datetime.datetime(2015, 9, 24, 12, 14, 40), 18486500],
#   [datetime.datetime(2015, 9, 25, 12, 39, 22), 25172600],
#   [datetime.datetime(2015, 9, 26, 13, 54, 24), 14410300],
#   [datetime.datetime(2015, 9, 27, 13, 59, 22), 13062400],
#   [datetime.datetime(2015, 9, 28, 13, 59, 22), 20202700],
#   [datetime.datetime(2015, 9, 29, 14, 4, 23), 22663000],
#   [datetime.datetime(2015, 9, 30, 14, 4, 23), 20512900],
#   [datetime.datetime(2015, 10, 1, 14, 4, 22), 16936200],
#   [datetime.datetime(2015, 10, 2, 14, 4, 22), 20239100],
#   [datetime.datetime(2015, 10, 3, 14, 19, 21), 17462600],
#   [datetime.datetime(2015, 10, 4, 14, 19, 22), 12642100],
#   [datetime.datetime(2015, 10, 5, 14, 19, 24), 15530500],
#   [datetime.datetime(2015, 10, 6, 14, 24, 23), 22365900],
#   [datetime.datetime(2015, 10, 7, 14, 24, 22), 26893700],
#   [datetime.datetime(2015, 10, 8, 14, 24, 24), 19671700],
#   [datetime.datetime(2015, 10, 9, 14, 24, 21), 18560000],
#   [datetime.datetime(2015, 10, 10, 14, 24, 22), 16000800],
#   [datetime.datetime(2015, 10, 11, 14, 39, 22), 11433600],
#   [datetime.datetime(2015, 10, 12, 14, 39, 22), 18033400],
#   [datetime.datetime(2015, 10, 13, 14, 39, 22), 24721800],
#   [datetime.datetime(2015, 10, 14, 14, 39, 23), 23232600],
#   [datetime.datetime(2015, 10, 15, 14, 44, 24), 26793100],
#   [datetime.datetime(2015, 10, 16, 14, 44, 45), 24415000],
#   [datetime.datetime(2015, 10, 17, 14, 54, 34), 44097300],
#   [datetime.datetime(2015, 10, 18, 14, 54, 24), 29558400],
#   [datetime.datetime(2015, 10, 19, 14, 54, 23), 25714300],
#   [datetime.datetime(2015, 10, 20, 14, 54, 20), 26078800],
#   [datetime.datetime(2015, 10, 21, 14, 54, 21), 29059300],
#   [datetime.datetime(2015, 10, 22, 14, 54, 20), 30156000],
#   [datetime.datetime(2015, 10, 23, 14, 54, 23), 32351800],
#   [datetime.datetime(2015, 10, 24, 14, 54, 22), 24084000],
#   [datetime.datetime(2015, 10, 25, 14, 19, 21), 35526900],
#   [datetime.datetime(2015, 10, 26, 14, 19, 21), 40169900],
#   [datetime.datetime(2015, 10, 27, 14, 19, 22), 35514700],
#   [datetime.datetime(2015, 10, 28, 14, 19, 20), 47347600],
#   [datetime.datetime(2015, 10, 29, 14, 19, 21), 51994800],
#   [datetime.datetime(2015, 10, 30, 14, 19, 20), 89068400],
#   [datetime.datetime(2015, 10, 31, 14, 54, 21), 41206200],
#   [datetime.datetime(2015, 11, 1, 15, 54, 21), 43893300],
#   [datetime.datetime(2015, 11, 2, 15, 54, 21), 56898600],
#   [datetime.datetime(2015, 11, 3, 15, 54, 19), 162207000],
#   [datetime.datetime(2015, 11, 4, 16, 4, 22), 293695000],
#   [datetime.datetime(2015, 11, 5, 16, 4, 20), 221063000],
#   [datetime.datetime(2015, 11, 6, 16, 4, 19), 121795000],
#   [datetime.datetime(2015, 11, 7, 16, 4, 20), 83953100],
#   [datetime.datetime(2015, 11, 8, 16, 39, 20), 44625800],
#   [datetime.datetime(2015, 11, 9, 16, 39, 25), 71774400],
#   [datetime.datetime(2015, 11, 10, 16, 39, 26), 68662800],
#   [datetime.datetime(2015, 11, 11, 16, 39, 21), 124080000],
#   [datetime.datetime(2015, 11, 12, 16, 39, 26), 81853000],
#   [datetime.datetime(2015, 11, 13, 16, 39, 27), 54658200],
#   [datetime.datetime(2015, 11, 14, 17, 14, 20), 38263800],
#   [datetime.datetime(2015, 11, 15, 17, 14, 22), 39008100],
#   [datetime.datetime(2015, 11, 16, 17, 14, 22), 42884200],
#   [datetime.datetime(2015, 11, 17, 17, 14, 20), 59097000],
#   [datetime.datetime(2015, 11, 18, 17, 14, 29), 42213700],
#   [datetime.datetime(2015, 11, 19, 17, 14, 21), 43553200],
#   [datetime.datetime(2015, 11, 20, 17, 14, 21), 53429100],
#   [datetime.datetime(2015, 11, 21, 18, 9, 45), 29623700],
#   [datetime.datetime(2015, 11, 22, 18, 9, 20), 21826600],
#   [datetime.datetime(2015, 11, 23, 18, 9, 25), 24535100],
#   [datetime.datetime(2015, 11, 24, 18, 14, 20), 28723900],
#   [datetime.datetime(2015, 11, 25, 18, 14, 20), 35175500],
#   [datetime.datetime(2015, 11, 26, 18, 14, 21), 97328600],
#   [datetime.datetime(2015, 11, 27, 22, 44, 19), 60590100],
#   [datetime.datetime(2015, 11, 28, 22, 44, 22), 37239800],
#   [datetime.datetime(2015, 11, 29, 22, 44, 22), 32339100],
#   [datetime.datetime(2015, 11, 30, 22, 44, 20), 75583000],
#   [datetime.datetime(2015, 12, 1, 22, 44, 23), 62588000],
#   [datetime.datetime(2015, 12, 2, 22, 44, 33), 52641600],
#   [datetime.datetime(2015, 12, 3, 22, 44, 20), 51221800],
#   [datetime.datetime(2015, 12, 4, 22, 44, 20), 35761100],
#   [datetime.datetime(2015, 12, 5, 22, 44, 24), 53679900],
#   [datetime.datetime(2015, 12, 6, 22, 44, 20), 88056200],
#   [datetime.datetime(2015, 12, 7, 22, 44, 20), 64776800],
#   [datetime.datetime(2015, 12, 8, 22, 44, 24), 42450200],
#   [datetime.datetime(2015, 12, 9, 22, 44, 23), 101683000],
#   [datetime.datetime(2015, 12, 10, 22, 44, 22), 53263400],
#   [datetime.datetime(2015, 12, 11, 22, 44, 21), 104496000],
#   [datetime.datetime(2015, 12, 12, 22, 44, 23), 131176000],
#   [datetime.datetime(2015, 12, 13, 22, 44, 23), 57806600],
#   [datetime.datetime(2015, 12, 14, 22, 44, 24), 128529000],
#   [datetime.datetime(2015, 12, 15, 22, 49, 22), 80492700],
#   [datetime.datetime(2015, 12, 16, 22, 59, 23), 111483000],
#   [datetime.datetime(2015, 12, 17, 22, 59, 20), 48845100],
#   [datetime.datetime(2015, 12, 18, 23, 14, 22), 58257500],
#   [datetime.datetime(2015, 12, 19, 23, 24, 22), 48601100],
#   [datetime.datetime(2015, 12, 20, 23, 24, 20), 74004600],
#   [datetime.datetime(2015, 12, 21, 23, 24, 24), 75809300],
#   [datetime.datetime(2015, 12, 22, 23, 29, 22), 52039000],
#   [datetime.datetime(2015, 12, 23, 23, 29, 22), 47354600],
#   [datetime.datetime(2015, 12, 24, 23, 29, 20), 57236500],
#   [datetime.datetime(2015, 12, 25, 23, 29, 21), 39143500],
#   [datetime.datetime(2015, 12, 26, 23, 29, 22), 114925000],
#   [datetime.datetime(2015, 12, 27, 23, 29, 22), 53393600],
#   [datetime.datetime(2015, 12, 28, 23, 29, 21), 49089900],
#   [datetime.datetime(2015, 12, 29, 23, 29, 22), 50244100],
#   [datetime.datetime(2015, 12, 30, 23, 29, 22), 48589900],
#   [datetime.datetime(2015, 12, 31, 23, 29, 22), 45929800],
#   [datetime.datetime(2016, 1, 1, 23, 29, 21), 35900100],
#   [datetime.datetime(2016, 1, 2, 23, 29, 23), 30177000],
#   [datetime.datetime(2016, 1, 3, 23, 29, 22), 38378900],
#   [datetime.datetime(2016, 1, 4, 23, 29, 23), 38174500],
#   [datetime.datetime(2016, 1, 5, 23, 29, 18), 34971300],
#   [datetime.datetime(2016, 1, 6, 23, 29, 16), 33744600],
#   [datetime.datetime(2016, 1, 7, 23, 34, 18), 81552100],
#   [datetime.datetime(2016, 1, 8, 23, 34, 17), 61907500],
#   [datetime.datetime(2016, 1, 9, 23, 34, 16), 32339500],
#   [datetime.datetime(2016, 1, 10, 23, 39, 17), 35198400],
#   [datetime.datetime(2016, 1, 11, 23, 39, 19), 41045900],
#   [datetime.datetime(2016, 1, 12, 23, 54, 19), 99356700],
#   [datetime.datetime(2016, 1, 13, 23, 54, 19), 180327000],
#   [datetime.datetime(2016, 1, 14, 23, 54, 19), 43258800],
#   [datetime.datetime(2016, 1, 15, 23, 54, 19), 142114000],
#   [datetime.datetime(2016, 1, 16, 23, 54, 19), 129294000],
#   [datetime.datetime(2016, 1, 18, 0, 4, 17), 47441400],
#   [datetime.datetime(2016, 1, 19, 0, 4, 19), 56199800],
#   [datetime.datetime(2016, 1, 20, 0, 4, 19), 46402600],
#   [datetime.datetime(2016, 1, 21, 0, 4, 19), 109001000],
#   [datetime.datetime(2016, 1, 22, 0, 19, 19), 73754000],
#   [datetime.datetime(2016, 1, 23, 0, 19, 23), 88051500],
#   [datetime.datetime(2016, 1, 24, 0, 29, 24), 56582800],
#   [datetime.datetime(2016, 1, 25, 0, 39, 18), 55545300],
#   [datetime.datetime(2016, 1, 26, 0, 39, 19), 58803600],
#   [datetime.datetime(2016, 1, 27, 0, 44, 22), 57754300],
#   [datetime.datetime(2016, 1, 28, 0, 54, 18), 47575500],
#   [datetime.datetime(2016, 1, 29, 0, 54, 18), 59191900],
#   [datetime.datetime(2016, 1, 30, 0, 54, 18), 86293700],
#   [datetime.datetime(2016, 1, 31, 0, 54, 18), 30274600],
#   [datetime.datetime(2016, 2, 1, 0, 54, 19), 37543600],
#   [datetime.datetime(2016, 2, 2, 0, 54, 20), 51821200],
#   [datetime.datetime(2016, 2, 3, 0, 54, 19), 40417700],
#   [datetime.datetime(2016, 2, 4, 0, 54, 20), 45872000],
#   [datetime.datetime(2016, 2, 5, 0, 54, 20), 69224300],
#   [datetime.datetime(2016, 2, 6, 1, 19, 37), 37850800],
#   ...]}

# %% [markdown]
# #### `graphs.global_cap([bitcoin=True, start=None, end=None])`
# Display data from [total market capitalization charts](https://coinmarketcap.com/charts/), including or excluding bitcoin:

# %%
cmc.graphs.global_cap(bitcoin=False)
# Out:
# {'market_cap_by_available_supply': [[datetime.datetime(2013, 4, 28, 20, 47),
#    91346900.0],
#   [datetime.datetime(2013, 4, 29, 20, 47), 94087500.0],
#   [datetime.datetime(2013, 4, 30, 20, 47), 90416200.0],
#   [datetime.datetime(2013, 5, 1, 20, 47), 78877300.0],
#   [datetime.datetime(2013, 5, 2, 20, 47), 72337900.0],
#   [datetime.datetime(2013, 5, 3, 20, 47), 66800000.0],
#   [datetime.datetime(2013, 5, 4, 20, 47), 79306600.0],
#   [datetime.datetime(2013, 5, 5, 20, 47), 82748700.0],
#   [datetime.datetime(2013, 5, 6, 20, 47), 80775900.0],
#   [datetime.datetime(2013, 5, 7, 20, 47), 70380300.0],
#   [datetime.datetime(2013, 5, 8, 20, 47), 78779600.0],
#   [datetime.datetime(2013, 5, 9, 20, 47), 77892400.0],
#   [datetime.datetime(2013, 5, 10, 20, 47), 79292400.0],
#   [datetime.datetime(2013, 5, 11, 20, 47), 75550100.0],
#   [datetime.datetime(2013, 5, 12, 20, 47), 72145100.0],
#   [datetime.datetime(2013, 5, 13, 20, 47), 73187500.0],
#   [datetime.datetime(2013, 5, 14, 20, 47), 72419800.0],
#   [datetime.datetime(2013, 5, 15, 20, 47), 65450200.0],
#   [datetime.datetime(2013, 5, 16, 20, 47), 63753400.0],
#   [datetime.datetime(2013, 5, 17, 20, 47), 70536900.0],
#   [datetime.datetime(2013, 5, 18, 20, 47), 71584400.0],
#   [datetime.datetime(2013, 5, 19, 20, 47), 72028600.0],
#   [datetime.datetime(2013, 5, 20, 20, 47), 71479800.0],
#   [datetime.datetime(2013, 5, 21, 20, 47), 71193200.0],
#   [datetime.datetime(2013, 5, 22, 20, 47), 71162700.0],
#   [datetime.datetime(2013, 5, 23, 20, 47), 71512200.0],
#   [datetime.datetime(2013, 5, 24, 20, 47), 70684600.0],
#   [datetime.datetime(2013, 5, 25, 20, 47), 70411100.0],
#   [datetime.datetime(2013, 5, 26, 20, 47), 73617500.0],
#   [datetime.datetime(2013, 5, 27, 20, 47), 69441300.0],
#   [datetime.datetime(2013, 5, 28, 20, 47), 69415000.0],
#   [datetime.datetime(2013, 5, 29, 20, 47), 68449400.0],
#   [datetime.datetime(2013, 5, 30, 20, 47), 66355500.0],
#   [datetime.datetime(2013, 5, 31, 20, 47), 63016300.0],
#   [datetime.datetime(2013, 6, 1, 20, 47), 63213400.0],
#   [datetime.datetime(2013, 6, 2, 20, 47), 59895000.0],
#   [datetime.datetime(2013, 6, 3, 20, 47), 60090200.0],
#   [datetime.datetime(2013, 6, 4, 20, 47), 63094600.0],
#   [datetime.datetime(2013, 6, 5, 20, 47), 63521200.0],
#   [datetime.datetime(2013, 6, 6, 20, 47), 62039600.0],
#   [datetime.datetime(2013, 6, 7, 20, 47), 58049800.0],
#   [datetime.datetime(2013, 6, 8, 20, 47), 57482400.0],
#   [datetime.datetime(2013, 6, 9, 20, 47), 52057800.0],
#   [datetime.datetime(2013, 6, 10, 20, 47), 54893200.0],
#   [datetime.datetime(2013, 6, 11, 20, 47), 52693800.0],
#   [datetime.datetime(2013, 6, 12, 20, 47), 54045100.0],
#   [datetime.datetime(2013, 6, 13, 20, 47), 53785900.0],
#   [datetime.datetime(2013, 6, 14, 20, 47), 49326300.0],
#   [datetime.datetime(2013, 6, 15, 20, 47), 48439400.0],
#   [datetime.datetime(2013, 6, 16, 20, 47), 46793200.0],
#   [datetime.datetime(2013, 6, 17, 20, 47), 49772100.0],
#   [datetime.datetime(2013, 6, 18, 20, 47), 51298700.0],
#   [datetime.datetime(2013, 6, 19, 20, 47), 52250400.0],
#   [datetime.datetime(2013, 6, 20, 20, 47), 54030600.0],
#   [datetime.datetime(2013, 6, 21, 20, 47), 58291300.0],
#   [datetime.datetime(2013, 6, 22, 20, 47), 70666600.0],
#   [datetime.datetime(2013, 6, 23, 20, 47), 67268700.0],
#   [datetime.datetime(2013, 6, 24, 20, 47), 61286100.0],
#   [datetime.datetime(2013, 6, 25, 20, 47), 62112600.0],
#   [datetime.datetime(2013, 6, 26, 20, 47), 62670600.0],
#   [datetime.datetime(2013, 6, 27, 20, 47), 64751900.0],
#   [datetime.datetime(2013, 6, 28, 20, 47), 61704800.0],
#   [datetime.datetime(2013, 6, 29, 20, 47), 62002900.0],
#   [datetime.datetime(2013, 6, 30, 20, 47), 64914000.0],
#   [datetime.datetime(2013, 7, 1, 20, 47), 65267700.0],
#   [datetime.datetime(2013, 7, 2, 20, 47), 63560800.0],
#   [datetime.datetime(2013, 7, 3, 20, 47), 63311200.0],
#   [datetime.datetime(2013, 7, 4, 20, 47), 60904300.0],
#   [datetime.datetime(2013, 7, 5, 20, 47), 54104500.0],
#   [datetime.datetime(2013, 7, 6, 20, 47), 55867900.0],
#   [datetime.datetime(2013, 7, 7, 20, 47), 57038100.0],
#   [datetime.datetime(2013, 7, 8, 20, 47), 60448000.0],
#   [datetime.datetime(2013, 7, 9, 20, 47), 59211900.0],
#   [datetime.datetime(2013, 7, 10, 20, 47), 59959900.0],
#   [datetime.datetime(2013, 7, 11, 20, 47), 62694500.0],
#   [datetime.datetime(2013, 7, 12, 20, 47), 65547400.0],
#   [datetime.datetime(2013, 7, 13, 20, 47), 65541800.0],
#   [datetime.datetime(2013, 7, 14, 20, 47), 66305200.0],
#   [datetime.datetime(2013, 7, 15, 20, 47), 68775700.0],
#   [datetime.datetime(2013, 7, 16, 20, 47), 71409200.0],
#   [datetime.datetime(2013, 7, 17, 20, 47), 71888600.0],
#   [datetime.datetime(2013, 7, 18, 20, 47), 67383000.0],
#   [datetime.datetime(2013, 7, 19, 20, 47), 70173300.0],
#   [datetime.datetime(2013, 7, 20, 20, 47), 70048200.0],
#   [datetime.datetime(2013, 7, 21, 20, 47), 67061200.0],
#   [datetime.datetime(2013, 7, 22, 20, 47), 68840500.0],
#   [datetime.datetime(2013, 7, 23, 20, 47), 69979800.0],
#   [datetime.datetime(2013, 7, 24, 20, 47), 70408700.0],
#   [datetime.datetime(2013, 7, 25, 20, 47), 71293500.0],
#   [datetime.datetime(2013, 7, 26, 20, 47), 70146100.0],
#   [datetime.datetime(2013, 7, 27, 20, 47), 69775900.0],
#   [datetime.datetime(2013, 7, 28, 20, 47), 70738400.0],
#   [datetime.datetime(2013, 7, 29, 20, 47), 72318200.0],
#   [datetime.datetime(2013, 7, 30, 20, 47), 70811300.0],
#   [datetime.datetime(2013, 7, 31, 20, 47), 70454400.0],
#   [datetime.datetime(2013, 8, 1, 20, 47), 71378500.0],
#   [datetime.datetime(2013, 8, 2, 20, 47), 71961800.0],
#   [datetime.datetime(2013, 8, 3, 20, 47), 72525500.0],
#   [datetime.datetime(2013, 8, 4, 20, 47), 120755000.0],
#   [datetime.datetime(2013, 8, 5, 20, 47), 116002000.0],
#   [datetime.datetime(2013, 8, 6, 20, 47), 107433000.0],
#   [datetime.datetime(2013, 8, 7, 20, 47), 105371000.0],
#   [datetime.datetime(2013, 8, 8, 20, 47), 101976000.0],
#   [datetime.datetime(2013, 8, 9, 20, 47), 102527000.0],
#   [datetime.datetime(2013, 8, 10, 20, 47), 101450000.0],
#   [datetime.datetime(2013, 8, 11, 20, 47), 102650000.0],
#   [datetime.datetime(2013, 8, 12, 20, 47), 102088000.0],
#   [datetime.datetime(2013, 8, 13, 20, 47), 104928000.0],
#   [datetime.datetime(2013, 8, 14, 20, 47), 102750000.0],
#   [datetime.datetime(2013, 8, 15, 20, 47), 98306500.0],
#   [datetime.datetime(2013, 8, 16, 20, 47), 94015300.0],
#   [datetime.datetime(2013, 8, 17, 20, 47), 116082000.0],
#   [datetime.datetime(2013, 8, 18, 20, 47), 122494000.0],
#   [datetime.datetime(2013, 8, 19, 20, 47), 116533000.0],
#   [datetime.datetime(2013, 8, 20, 20, 47), 122173000.0],
#   [datetime.datetime(2013, 8, 21, 20, 47), 120963000.0],
#   [datetime.datetime(2013, 8, 22, 20, 47), 118290000.0],
#   [datetime.datetime(2013, 8, 23, 20, 47), 111822000.0],
#   [datetime.datetime(2013, 8, 24, 20, 47), 115540000.0],
#   [datetime.datetime(2013, 8, 25, 20, 47), 115933000.0],
#   [datetime.datetime(2013, 8, 26, 20, 47), 120281000.0],
#   [datetime.datetime(2013, 8, 27, 20, 47), 117435000.0],
#   [datetime.datetime(2013, 8, 28, 20, 47), 118145000.0],
#   [datetime.datetime(2013, 8, 29, 20, 47), 116302000.0],
#   [datetime.datetime(2013, 8, 30, 20, 47), 118211000.0],
#   [datetime.datetime(2013, 8, 31, 20, 47), 114599000.0],
#   [datetime.datetime(2013, 9, 1, 20, 47), 113722000.0],
#   [datetime.datetime(2013, 9, 2, 20, 47), 113379000.0],
#   [datetime.datetime(2013, 9, 3, 20, 47), 112444000.0],
#   [datetime.datetime(2013, 9, 4, 20, 47), 119650000.0],
#   [datetime.datetime(2013, 9, 5, 20, 47), 120118000.0],
#   [datetime.datetime(2013, 9, 6, 20, 47), 117776000.0],
#   [datetime.datetime(2013, 9, 7, 20, 47), 120145000.0],
#   [datetime.datetime(2013, 9, 8, 20, 47), 120866000.0],
#   [datetime.datetime(2013, 9, 9, 20, 47), 122974000.0],
#   [datetime.datetime(2013, 9, 10, 20, 47), 117252000.0],
#   [datetime.datetime(2013, 9, 11, 20, 47), 121176000.0],
#   [datetime.datetime(2013, 9, 12, 20, 47), 122415000.0],
#   [datetime.datetime(2013, 9, 13, 20, 47), 124787000.0],
#   [datetime.datetime(2013, 9, 14, 20, 47), 120295000.0],
#   [datetime.datetime(2013, 9, 15, 20, 47), 121615000.0],
#   [datetime.datetime(2013, 9, 16, 20, 47), 126221000.0],
#   [datetime.datetime(2013, 9, 17, 20, 47), 145375000.0],
#   [datetime.datetime(2013, 9, 18, 20, 47), 154496000.0],
#   [datetime.datetime(2013, 9, 19, 20, 47), 155768000.0],
#   [datetime.datetime(2013, 9, 20, 20, 47), 147692000.0],
#   [datetime.datetime(2013, 9, 21, 20, 47), 145475000.0],
#   [datetime.datetime(2013, 9, 22, 20, 47), 148859000.0],
#   [datetime.datetime(2013, 9, 23, 20, 47), 147103000.0],
#   [datetime.datetime(2013, 9, 24, 20, 47), 147768000.0],
#   [datetime.datetime(2013, 9, 25, 20, 47), 149735000.0],
#   [datetime.datetime(2013, 9, 26, 20, 47), 157864000.0],
#   [datetime.datetime(2013, 9, 27, 20, 47), 181970000.0],
#   [datetime.datetime(2013, 9, 28, 20, 47), 175348000.0],
#   [datetime.datetime(2013, 9, 29, 20, 47), 171872000.0],
#   [datetime.datetime(2013, 9, 30, 20, 47), 152510000.0],
#   [datetime.datetime(2013, 10, 1, 20, 47), 151984000.0],
#   [datetime.datetime(2013, 10, 2, 20, 47), 122049000.0],
#   [datetime.datetime(2013, 10, 3, 20, 47), 131262000.0],
#   [datetime.datetime(2013, 10, 4, 20, 47), 144173000.0],
#   [datetime.datetime(2013, 10, 5, 20, 47), 142499000.0],
#   [datetime.datetime(2013, 10, 6, 20, 47), 145579000.0],
#   [datetime.datetime(2013, 10, 7, 20, 47), 138501000.0],
#   [datetime.datetime(2013, 10, 8, 20, 47), 138282000.0],
#   [datetime.datetime(2013, 10, 9, 20, 47), 140319000.0],
#   [datetime.datetime(2013, 10, 10, 20, 47), 143336000.0],
#   [datetime.datetime(2013, 10, 11, 20, 47), 137481000.0],
#   [datetime.datetime(2013, 10, 12, 20, 47), 141064000.0],
#   [datetime.datetime(2013, 10, 13, 20, 47), 134396000.0],
#   [datetime.datetime(2013, 10, 14, 20, 47), 131778000.0],
#   [datetime.datetime(2013, 10, 15, 20, 47), 125420000.0],
#   [datetime.datetime(2013, 10, 16, 20, 47), 120186000.0],
#   [datetime.datetime(2013, 10, 17, 20, 47), 126267000.0],
#   [datetime.datetime(2013, 10, 18, 20, 47), 122653000.0],
#   [datetime.datetime(2013, 10, 19, 20, 47), 115056000.0],
#   [datetime.datetime(2013, 10, 20, 20, 47), 113817000.0],
#   [datetime.datetime(2013, 10, 21, 20, 47), 110497000.0],
#   [datetime.datetime(2013, 10, 22, 20, 47), 110310000.0],
#   [datetime.datetime(2013, 10, 23, 20, 47), 128863000.0],
#   [datetime.datetime(2013, 10, 24, 20, 47), 135405000.0],
#   [datetime.datetime(2013, 10, 25, 20, 47), 121996000.0],
#   [datetime.datetime(2013, 10, 26, 20, 47), 116569000.0],
#   [datetime.datetime(2013, 10, 27, 19, 47), 118288000.0],
#   [datetime.datetime(2013, 10, 28, 19, 47), 115291000.0],
#   [datetime.datetime(2013, 10, 29, 19, 47), 115368000.0],
#   [datetime.datetime(2013, 10, 30, 19, 47), 117847000.0],
#   [datetime.datetime(2013, 10, 31, 19, 47), 119052000.0],
#   [datetime.datetime(2013, 11, 1, 19, 47), 122805000.0],
#   [datetime.datetime(2013, 11, 2, 19, 47), 130672000.0],
#   [datetime.datetime(2013, 11, 3, 19, 47), 145194000.0],
#   [datetime.datetime(2013, 11, 4, 19, 47), 149382000.0],
#   [datetime.datetime(2013, 11, 5, 19, 47), 148046000.0],
#   [datetime.datetime(2013, 11, 6, 19, 47), 164656000.0],
#   [datetime.datetime(2013, 11, 7, 19, 47), 194376000.0],
#   [datetime.datetime(2013, 11, 8, 19, 47), 218271000.0],
#   [datetime.datetime(2013, 11, 9, 19, 47), 207404000.0],
#   [datetime.datetime(2013, 11, 10, 19, 47), 171624000.0],
#   [datetime.datetime(2013, 11, 11, 19, 47), 188315000.0],
#   [datetime.datetime(2013, 11, 12, 19, 47), 194546000.0],
#   [datetime.datetime(2013, 11, 13, 19, 47), 214283000.0],
#   [datetime.datetime(2013, 11, 14, 19, 47), 204296000.0],
#   [datetime.datetime(2013, 11, 15, 19, 47), 208820000.0],
#   [datetime.datetime(2013, 11, 16, 19, 47), 210126000.0],
#   [datetime.datetime(2013, 11, 17, 19, 47), 213943000.0],
#   [datetime.datetime(2013, 11, 18, 19, 47), 327716000.0],
#   [datetime.datetime(2013, 11, 19, 19, 47), 299383000.0],
#   [datetime.datetime(2013, 11, 20, 19, 47), 283783000.0],
#   [datetime.datetime(2013, 11, 21, 19, 47), 350201000.0],
#   [datetime.datetime(2013, 11, 22, 19, 47), 384482000.0],
#   [datetime.datetime(2013, 11, 23, 19, 47), 430926000.0],
#   [datetime.datetime(2013, 11, 24, 19, 47), 436831000.0],
#   [datetime.datetime(2013, 11, 25, 19, 47), 500277000.0],
#   [datetime.datetime(2013, 11, 26, 19, 47), 802841000.0],
#   [datetime.datetime(2013, 11, 27, 19, 47), 1047390000.0],
#   [datetime.datetime(2013, 11, 28, 19, 47), 1455110000.0],
#   [datetime.datetime(2013, 11, 29, 19, 47), 1456280000.0],
#   [datetime.datetime(2013, 11, 30, 19, 47), 1678780000.0],
#   [datetime.datetime(2013, 12, 1, 19, 47), 1606220000.0],
#   [datetime.datetime(2013, 12, 2, 19, 47), 1533610000.0],
#   [datetime.datetime(2013, 12, 3, 19, 47), 1643150000.0],
#   [datetime.datetime(2013, 12, 4, 19, 47), 1922280000.0],
#   [datetime.datetime(2013, 12, 5, 19, 47), 1793890000.0],
#   [datetime.datetime(2013, 12, 6, 19, 47), 1391580000.0],
#   [datetime.datetime(2013, 12, 7, 19, 47), 1113350000.0],
#   [datetime.datetime(2013, 12, 8, 19, 47), 1124000000.0],
#   [datetime.datetime(2013, 12, 9, 19, 47), 1405800000.0],
#   [datetime.datetime(2013, 12, 10, 19, 47), 1624970000.0],
#   [datetime.datetime(2013, 12, 11, 19, 47), 1419110000.0],
#   [datetime.datetime(2013, 12, 12, 19, 47), 1389540000.0],
#   [datetime.datetime(2013, 12, 13, 19, 47), 1385360000.0],
#   [datetime.datetime(2013, 12, 14, 19, 47), 1338820000.0],
#   [datetime.datetime(2013, 12, 15, 19, 47), 1329440000.0],
#   [datetime.datetime(2013, 12, 16, 19, 47), 1088160000.0],
#   [datetime.datetime(2013, 12, 17, 19, 47), 964254000.0],
#   [datetime.datetime(2013, 12, 18, 19, 47), 722720000.0],
#   [datetime.datetime(2013, 12, 19, 19, 47), 813604000.0],
#   [datetime.datetime(2013, 12, 20, 19, 47), 877874000.0],
#   [datetime.datetime(2013, 12, 21, 19, 47), 826229000.0],
#   [datetime.datetime(2013, 12, 22, 19, 47), 848677000.0],
#   [datetime.datetime(2013, 12, 23, 19, 47), 853021000.0],
#   [datetime.datetime(2013, 12, 24, 19, 47), 874026000.0],
#   [datetime.datetime(2013, 12, 25, 19, 47), 1059850000.0],
#   [datetime.datetime(2013, 12, 26, 19, 47), 1287890000.0],
#   [datetime.datetime(2013, 12, 27, 19, 47), 1207710000.0],
#   [datetime.datetime(2013, 12, 28, 19, 47), 1195660000.0],
#   [datetime.datetime(2013, 12, 29, 19, 47), 1233030000.0],
#   [datetime.datetime(2013, 12, 30, 19, 47), 1316440000.0],
#   [datetime.datetime(2013, 12, 31, 19, 47), 1306210000.0],
#   [datetime.datetime(2014, 1, 1, 19, 47), 1342220000.0],
#   [datetime.datetime(2014, 1, 2, 19, 47), 1410630000.0],
#   [datetime.datetime(2014, 1, 3, 19, 47), 1373160000.0],
#   [datetime.datetime(2014, 1, 4, 19, 47), 1426020000.0],
#   [datetime.datetime(2014, 1, 5, 19, 47), 1463510000.0],
#   [datetime.datetime(2014, 1, 6, 19, 47), 1485140000.0],
#   [datetime.datetime(2014, 1, 7, 19, 47), 1345630000.0],
#   [datetime.datetime(2014, 1, 8, 19, 47), 1257160000.0],
#   [datetime.datetime(2014, 1, 9, 19, 47), 1208980000.0],
#   [datetime.datetime(2014, 1, 10, 19, 47), 1251870000.0],
#   [datetime.datetime(2014, 1, 11, 19, 47), 1336960000.0],
#   [datetime.datetime(2014, 1, 12, 19, 47), 1270820000.0],
#   [datetime.datetime(2014, 1, 13, 19, 47), 1184550000.0],
#   [datetime.datetime(2014, 1, 14, 19, 47), 1187880000.0],
#   [datetime.datetime(2014, 1, 15, 19, 47), 1262240000.0],
#   [datetime.datetime(2014, 1, 16, 19, 47), 1230020000.0],
#   [datetime.datetime(2014, 1, 17, 19, 47), 1167320000.0],
#   [datetime.datetime(2014, 1, 18, 19, 47), 1223270000.0],
#   [datetime.datetime(2014, 1, 19, 19, 47), 1264300000.0],
#   [datetime.datetime(2014, 1, 20, 19, 47), 1328450000.0],
#   [datetime.datetime(2014, 1, 21, 19, 47), 1357510000.0],
#   [datetime.datetime(2014, 1, 22, 19, 47), 1268330000.0],
#   [datetime.datetime(2014, 1, 23, 19, 47), 1238530000.0],
#   [datetime.datetime(2014, 1, 24, 19, 47), 1158590000.0],
#   [datetime.datetime(2014, 1, 25, 19, 47), 1279390000.0],
#   [datetime.datetime(2014, 1, 26, 19, 47), 1342780000.0],
#   [datetime.datetime(2014, 1, 27, 19, 47), 1192430000.0],
#   [datetime.datetime(2014, 1, 28, 19, 47), 1209400000.0],
#   [datetime.datetime(2014, 1, 29, 19, 47), 1201490000.0],
#   [datetime.datetime(2014, 1, 30, 19, 47), 1202140000.0],
#   [datetime.datetime(2014, 1, 31, 19, 47), 1215780000.0],
#   [datetime.datetime(2014, 2, 1, 19, 47), 1271320000.0],
#   [datetime.datetime(2014, 2, 2, 19, 47), 1273030000.0],
#   [datetime.datetime(2014, 2, 3, 19, 47), 1226850000.0],
#   [datetime.datetime(2014, 2, 4, 19, 47), 1221050000.0],
#   [datetime.datetime(2014, 2, 5, 19, 47), 1197700000.0],
#   [datetime.datetime(2014, 2, 6, 19, 47), 1152770000.0],
#   [datetime.datetime(2014, 2, 7, 19, 47), 1100320000.0],
#   [datetime.datetime(2014, 2, 8, 19, 47), 1036240000.0],
#   [datetime.datetime(2014, 2, 9, 19, 47), 1043400000.0],
#   [datetime.datetime(2014, 2, 10, 19, 47), 989687000.0],
#   [datetime.datetime(2014, 2, 11, 19, 47), 1035210000.0],
#   [datetime.datetime(2014, 2, 12, 19, 47), 1022980000.0],
#   [datetime.datetime(2014, 2, 13, 19, 47), 975399000.0],
#   [datetime.datetime(2014, 2, 14, 19, 47), 1011600000.0],
#   [datetime.datetime(2014, 2, 15, 19, 47), 1017520000.0],
#   [datetime.datetime(2014, 2, 16, 19, 47), 957827000.0],
#   [datetime.datetime(2014, 2, 17, 19, 47), 979692000.0],
#   [datetime.datetime(2014, 2, 18, 19, 47), 974309000.0],
#   [datetime.datetime(2014, 2, 19, 19, 47), 985101000.0],
#   [datetime.datetime(2014, 2, 20, 19, 47), 914285000.0],
#   [datetime.datetime(2014, 2, 21, 19, 47), 867297000.0],
#   [datetime.datetime(2014, 2, 22, 19, 47), 923988000.0],
#   [datetime.datetime(2014, 2, 23, 19, 47), 978744000.0],
#   [datetime.datetime(2014, 2, 24, 19, 47), 890014000.0],
#   [datetime.datetime(2014, 2, 25, 19, 47), 809536000.0],
#   [datetime.datetime(2014, 2, 26, 19, 47), 888840000.0],
#   [datetime.datetime(2014, 2, 27, 19, 47), 952724000.0],
#   [datetime.datetime(2014, 2, 28, 19, 47), 1096310000.0],
#   [datetime.datetime(2014, 3, 1, 19, 47), 1021000000.0],
#   [datetime.datetime(2014, 3, 2, 19, 47), 1114770000.0],
#   [datetime.datetime(2014, 3, 3, 19, 47), 1634700000.0],
#   [datetime.datetime(2014, 3, 4, 19, 47), 1852770000.0],
#   [datetime.datetime(2014, 3, 5, 19, 47), 1382400000.0],
#   [datetime.datetime(2014, 3, 6, 19, 47), 1199190000.0],
#   [datetime.datetime(2014, 3, 7, 19, 47), 1089520000.0],
#   [datetime.datetime(2014, 3, 8, 19, 47), 1084150000.0],
#   [datetime.datetime(2014, 3, 9, 19, 47), 1215770000.0],
#   [datetime.datetime(2014, 3, 10, 19, 47), 1215580000.0],
#   [datetime.datetime(2014, 3, 11, 19, 47), 1161250000.0],
#   [datetime.datetime(2014, 3, 12, 19, 47), 1192490000.0],
#   [datetime.datetime(2014, 3, 13, 19, 47), 1136190000.0],
#   [datetime.datetime(2014, 3, 14, 19, 47), 1127600000.0],
#   [datetime.datetime(2014, 3, 15, 19, 47), 1107150000.0],
#   [datetime.datetime(2014, 3, 16, 19, 47), 1111140000.0],
#   [datetime.datetime(2014, 3, 17, 19, 47), 996599000.0],
#   [datetime.datetime(2014, 3, 18, 19, 47), 1090860000.0],
#   [datetime.datetime(2014, 3, 19, 19, 47), 1077230000.0],
#   [datetime.datetime(2014, 3, 20, 19, 47), 1003680000.0],
#   [datetime.datetime(2014, 3, 21, 19, 47), 985536000.0],
#   [datetime.datetime(2014, 3, 22, 19, 47), 1064970000.0],
#   [datetime.datetime(2014, 3, 23, 19, 47), 1040740000.0],
#   [datetime.datetime(2014, 3, 24, 19, 47), 1001370000.0],
#   [datetime.datetime(2014, 3, 25, 19, 47), 975110000.0],
#   [datetime.datetime(2014, 3, 26, 19, 47), 933401000.0],
#   [datetime.datetime(2014, 3, 27, 19, 47), 793525000.0],
#   [datetime.datetime(2014, 3, 28, 19, 47), 740329000.0],
#   [datetime.datetime(2014, 3, 29, 19, 47), 756473000.0],
#   [datetime.datetime(2014, 3, 30, 20, 47), 698393000.0],
#   [datetime.datetime(2014, 3, 31, 20, 47), 682344000.0],
#   [datetime.datetime(2014, 4, 1, 20, 47), 706656000.0],
#   [datetime.datetime(2014, 4, 2, 20, 47), 617202000.0],
#   [datetime.datetime(2014, 4, 3, 20, 47), 604538000.0],
#   [datetime.datetime(2014, 4, 4, 20, 47), 607909000.0],
#   [datetime.datetime(2014, 4, 5, 20, 47), 624962000.0],
#   [datetime.datetime(2014, 4, 6, 20, 47), 633447000.0],
#   [datetime.datetime(2014, 4, 7, 20, 47), 618673000.0],
#   [datetime.datetime(2014, 4, 8, 20, 47), 613342000.0],
#   [datetime.datetime(2014, 4, 9, 20, 47), 596559000.0],
#   [datetime.datetime(2014, 4, 10, 20, 47), 515132000.0],
#   [datetime.datetime(2014, 4, 11, 20, 47), 583452000.0],
#   [datetime.datetime(2014, 4, 12, 20, 47), 561823000.0],
#   [datetime.datetime(2014, 4, 13, 20, 47), 527411000.0],
#   [datetime.datetime(2014, 4, 14, 20, 47), 620437000.0],
#   [datetime.datetime(2014, 4, 15, 20, 47), 687059000.0],
#   [datetime.datetime(2014, 4, 16, 20, 47), 705751000.0],
#   [datetime.datetime(2014, 4, 17, 20, 47), 685451000.0],
#   [datetime.datetime(2014, 4, 18, 20, 47), 666382000.0],
#   [datetime.datetime(2014, 4, 19, 20, 47), 730495000.0],
#   [datetime.datetime(2014, 4, 20, 20, 47), 712474000.0],
#   [datetime.datetime(2014, 4, 21, 20, 47), 714756000.0],
#   [datetime.datetime(2014, 4, 22, 20, 47), 700481000.0],
#   [datetime.datetime(2014, 4, 23, 20, 47), 689230000.0],
#   [datetime.datetime(2014, 4, 24, 20, 47), 697727000.0],
#   [datetime.datetime(2014, 4, 25, 20, 47), 600398000.0],
#   [datetime.datetime(2014, 4, 26, 20, 47), 595343000.0],
#   [datetime.datetime(2014, 4, 27, 20, 47), 552680000.0],
#   [datetime.datetime(2014, 4, 28, 20, 47), 575230000.0],
#   [datetime.datetime(2014, 4, 29, 20, 47), 588464000.0],
#   [datetime.datetime(2014, 4, 30, 20, 47), 605026000.0],
#   [datetime.datetime(2014, 5, 1, 20, 47), 611189000.0],
#   [datetime.datetime(2014, 5, 2, 20, 47), 582338000.0],
#   [datetime.datetime(2014, 5, 3, 20, 47), 560909000.0],
#   [datetime.datetime(2014, 5, 4, 20, 47), 566299000.0],
#   [datetime.datetime(2014, 5, 5, 20, 47), 562614000.0],
#   [datetime.datetime(2014, 5, 6, 20, 47), 575508000.0],
#   [datetime.datetime(2014, 5, 7, 20, 47), 594605000.0],
#   [datetime.datetime(2014, 5, 8, 20, 47), 592673000.0],
#   [datetime.datetime(2014, 5, 9, 20, 47), 616586000.0],
#   [datetime.datetime(2014, 5, 10, 20, 47), 610311000.0],
#   [datetime.datetime(2014, 5, 11, 20, 47), 589189000.0],
#   [datetime.datetime(2014, 5, 12, 20, 47), 591210000.0],
#   [datetime.datetime(2014, 5, 13, 20, 47), 592089000.0],
#   [datetime.datetime(2014, 5, 14, 20, 47), 604589000.0],
#   [datetime.datetime(2014, 5, 15, 20, 47), 620758000.0],
#   [datetime.datetime(2014, 5, 16, 20, 47), 612342000.0],
#   [datetime.datetime(2014, 5, 17, 20, 47), 607596000.0],
#   [datetime.datetime(2014, 5, 18, 20, 47), 602684000.0],
#   [datetime.datetime(2014, 5, 19, 20, 47), 601875000.0],
#   [datetime.datetime(2014, 5, 20, 20, 47), 635175000.0],
#   [datetime.datetime(2014, 5, 21, 20, 47), 634871000.0],
#   [datetime.datetime(2014, 5, 22, 20, 47), 628673000.0],
#   [datetime.datetime(2014, 5, 23, 20, 47), 664299000.0],
#   [datetime.datetime(2014, 5, 24, 20, 47), 655208000.0],
#   [datetime.datetime(2014, 5, 25, 20, 47), 698268000.0],
#   [datetime.datetime(2014, 5, 26, 20, 47), 685600000.0],
#   [datetime.datetime(2014, 5, 27, 20, 47), 680818000.0],
#   [datetime.datetime(2014, 5, 28, 20, 47), 663656000.0],
#   [datetime.datetime(2014, 5, 29, 20, 47), 652394000.0],
#   [datetime.datetime(2014, 5, 30, 20, 47), 681395000.0],
#   [datetime.datetime(2014, 5, 31, 20, 47), 670109000.0],
#   [datetime.datetime(2014, 6, 1, 20, 47), 700785000.0],
#   [datetime.datetime(2014, 6, 2, 20, 47), 693755000.0],
#   [datetime.datetime(2014, 6, 3, 20, 47), 705081000.0],
#   [datetime.datetime(2014, 6, 4, 20, 47), 689760000.0],
#   [datetime.datetime(2014, 6, 5, 20, 47), 708620000.0],
#   [datetime.datetime(2014, 6, 6, 20, 47), 695716000.0],
#   [datetime.datetime(2014, 6, 7, 20, 47), 689027000.0],
#   [datetime.datetime(2014, 6, 8, 20, 47), 691493000.0],
#   [datetime.datetime(2014, 6, 9, 20, 47), 686162000.0],
#   [datetime.datetime(2014, 6, 10, 20, 47), 704362000.0],
#   [datetime.datetime(2014, 6, 11, 20, 47), 708748000.0],
#   [datetime.datetime(2014, 6, 12, 20, 47), 682532000.0],
#   [datetime.datetime(2014, 6, 13, 20, 47), 671898000.0],
#   [datetime.datetime(2014, 6, 14, 20, 47), 643576000.0],
#   [datetime.datetime(2014, 6, 15, 20, 47), 650489000.0],
#   [datetime.datetime(2014, 6, 16, 20, 47), 664261000.0],
#   [datetime.datetime(2014, 6, 17, 20, 47), 656404000.0],
#   [datetime.datetime(2014, 6, 18, 20, 47), 664856000.0],
#   [datetime.datetime(2014, 6, 19, 20, 47), 672779000.0],
#   [datetime.datetime(2014, 6, 20, 20, 47), 649616000.0],
#   [datetime.datetime(2014, 6, 21, 20, 47), 650796000.0],
#   [datetime.datetime(2014, 6, 22, 20, 47), 659971000.0],
#   [datetime.datetime(2014, 6, 23, 20, 47), 647115000.0],
#   [datetime.datetime(2014, 6, 24, 20, 47), 639966000.0],
#   [datetime.datetime(2014, 6, 25, 20, 47), 606399000.0],
#   [datetime.datetime(2014, 6, 26, 20, 47), 603344000.0],
#   [datetime.datetime(2014, 6, 27, 20, 47), 617470000.0],
#   [datetime.datetime(2014, 6, 28, 20, 47), 612308000.0],
#   [datetime.datetime(2014, 6, 29, 20, 47), 597409000.0],
#   [datetime.datetime(2014, 6, 30, 20, 47), 601306000.0],
#   [datetime.datetime(2014, 7, 1, 20, 47), 608833000.0],
#   [datetime.datetime(2014, 7, 2, 20, 47), 574042000.0],
#   [datetime.datetime(2014, 7, 3, 20, 47), 577853000.0],
#   [datetime.datetime(2014, 7, 4, 20, 47), 566382000.0],
#   [datetime.datetime(2014, 7, 5, 20, 47), 533996000.0],
#   [datetime.datetime(2014, 7, 6, 20, 47), 528296000.0],
#   [datetime.datetime(2014, 7, 7, 20, 47), 526300000.0],
#   [datetime.datetime(2014, 7, 8, 20, 47), 532420000.0],
#   [datetime.datetime(2014, 7, 9, 20, 47), 545351000.0],
#   [datetime.datetime(2014, 7, 10, 20, 47), 540815000.0],
#   [datetime.datetime(2014, 7, 11, 20, 47), 552125000.0],
#   [datetime.datetime(2014, 7, 12, 20, 47), 572436000.0],
#   [datetime.datetime(2014, 7, 13, 20, 47), 577074000.0],
#   [datetime.datetime(2014, 7, 14, 20, 47), 571810000.0],
#   [datetime.datetime(2014, 7, 15, 20, 47), 564758000.0],
#   [datetime.datetime(2014, 7, 16, 20, 47), 558520000.0],
#   [datetime.datetime(2014, 7, 17, 20, 47), 589688000.0],
#   [datetime.datetime(2014, 7, 18, 20, 47), 600588000.0],
#   [datetime.datetime(2014, 7, 19, 20, 47), 588035000.0],
#   [datetime.datetime(2014, 7, 20, 20, 47), 583417000.0],
#   [datetime.datetime(2014, 7, 21, 20, 47), 609956000.0],
#   [datetime.datetime(2014, 7, 22, 20, 47), 598168000.0],
#   [datetime.datetime(2014, 7, 23, 20, 47), 596579000.0],
#   [datetime.datetime(2014, 7, 24, 20, 47), 568136000.0],
#   [datetime.datetime(2014, 7, 25, 20, 47), 554807000.0],
#   [datetime.datetime(2014, 7, 26, 20, 47), 550216000.0],
#   [datetime.datetime(2014, 7, 27, 20, 47), 551306000.0],
#   [datetime.datetime(2014, 7, 28, 20, 47), 536247000.0],
#   [datetime.datetime(2014, 7, 29, 20, 47), 539659000.0],
#   [datetime.datetime(2014, 7, 30, 20, 47), 533659000.0],
#   [datetime.datetime(2014, 7, 31, 20, 47), 549611000.0],
#   [datetime.datetime(2014, 8, 1, 20, 47), 559529000.0],
#   [datetime.datetime(2014, 8, 2, 20, 47), 553647000.0],
#   [datetime.datetime(2014, 8, 3, 20, 47), 549496000.0],
#   [datetime.datetime(2014, 8, 4, 20, 47), 538454000.0],
#   [datetime.datetime(2014, 8, 5, 20, 47), 528170000.0],
#   [datetime.datetime(2014, 8, 6, 20, 47), 525077000.0],
#   [datetime.datetime(2014, 8, 7, 20, 47), 526537000.0],
#   [datetime.datetime(2014, 8, 8, 20, 47), 522997000.0],
#   [datetime.datetime(2014, 8, 9, 20, 47), 507219000.0],
#   [datetime.datetime(2014, 8, 10, 20, 47), 503397000.0],
#   [datetime.datetime(2014, 8, 11, 20, 47), 480863000.0],
#   [datetime.datetime(2014, 8, 12, 20, 47), 440485000.0],
#   [datetime.datetime(2014, 8, 13, 20, 47), 413576000.0],
#   [datetime.datetime(2014, 8, 14, 20, 47), 411230000.0],
#   [datetime.datetime(2014, 8, 15, 20, 47), 399263000.0],
#   [datetime.datetime(2014, 8, 16, 20, 47), 394691000.0],
#   [datetime.datetime(2014, 8, 17, 20, 47), 380833000.0],
#   [datetime.datetime(2014, 8, 18, 20, 47), 325334000.0],
#   [datetime.datetime(2014, 8, 19, 20, 47), 379965000.0],
#   [datetime.datetime(2014, 8, 20, 20, 47), 432706000.0],
#   [datetime.datetime(2014, 8, 21, 20, 47), 458531000.0],
#   [datetime.datetime(2014, 8, 22, 20, 47), 448876000.0],
#   [datetime.datetime(2014, 8, 23, 20, 47), 421314000.0],
#   [datetime.datetime(2014, 8, 24, 20, 47), 459937000.0],
#   [datetime.datetime(2014, 8, 25, 20, 47), 481503000.0],
#   [datetime.datetime(2014, 8, 26, 20, 47), 588487000.0],
#   [datetime.datetime(2014, 8, 27, 20, 47), 577642000.0],
#   [datetime.datetime(2014, 8, 28, 20, 47), 560228000.0],
#   [datetime.datetime(2014, 8, 29, 20, 47), 551812000.0],
#   [datetime.datetime(2014, 8, 30, 20, 47), 555412000.0],
#   [datetime.datetime(2014, 8, 31, 20, 47), 531649000.0],
#   [datetime.datetime(2014, 9, 1, 20, 47), 538868000.0],
#   [datetime.datetime(2014, 9, 2, 20, 47), 521499000.0],
#   [datetime.datetime(2014, 9, 3, 20, 47), 533098000.0],
#   [datetime.datetime(2014, 9, 4, 20, 47), 556120000.0],
#   [datetime.datetime(2014, 9, 5, 20, 47), 557284000.0],
#   [datetime.datetime(2014, 9, 6, 20, 47), 571883000.0],
#   [datetime.datetime(2014, 9, 7, 20, 47), 568487000.0],
#   [datetime.datetime(2014, 9, 8, 20, 47), 572200000.0],
#   [datetime.datetime(2014, 9, 9, 20, 47), 569839000.0],
#   [datetime.datetime(2014, 9, 10, 20, 47), 594090000.0],
#   [datetime.datetime(2014, 9, 11, 20, 47), 594379000.0],
#   [datetime.datetime(2014, 9, 12, 20, 47), 598659000.0],
#   [datetime.datetime(2014, 9, 13, 20, 47), 608282000.0],
#   [datetime.datetime(2014, 9, 14, 20, 47), 631353000.0],
#   [datetime.datetime(2014, 9, 15, 20, 47), 606270000.0],
#   [datetime.datetime(2014, 9, 16, 20, 47), 616408000.0],
#   [datetime.datetime(2014, 9, 17, 20, 47), 608788000.0],
#   [datetime.datetime(2014, 9, 18, 20, 47), 603183000.0],
#   [datetime.datetime(2014, 9, 19, 20, 47), 564351000.0],
#   [datetime.datetime(2014, 9, 20, 20, 47), 566222000.0],
#   [datetime.datetime(2014, 9, 21, 20, 47), 555691000.0],
#   [datetime.datetime(2014, 9, 22, 20, 47), 561185000.0],
#   [datetime.datetime(2014, 9, 23, 20, 47), 586192000.0],
#   [datetime.datetime(2014, 9, 24, 20, 47), 586314000.0],
#   [datetime.datetime(2014, 9, 25, 20, 47), 583209000.0],
#   [datetime.datetime(2014, 9, 26, 20, 47), 586850000.0],
#   [datetime.datetime(2014, 9, 27, 20, 47), 576005000.0],
#   [datetime.datetime(2014, 9, 28, 20, 47), 581236000.0],
#   [datetime.datetime(2014, 9, 29, 20, 47), 561157000.0],
#   [datetime.datetime(2014, 9, 30, 20, 47), 571566000.0],
#   [datetime.datetime(2014, 10, 1, 20, 47), 573030000.0],
#   [datetime.datetime(2014, 10, 2, 20, 47), 565854000.0],
#   [datetime.datetime(2014, 10, 3, 20, 47), 556568000.0],
#   [datetime.datetime(2014, 10, 4, 20, 47), 534145000.0],
#   [datetime.datetime(2014, 10, 5, 20, 47), 494751000.0],
#   [datetime.datetime(2014, 10, 6, 20, 47), 521936000.0],
#   [datetime.datetime(2014, 10, 7, 20, 47), 526810000.0],
#   [datetime.datetime(2014, 10, 8, 20, 47), 531243000.0],
#   [datetime.datetime(2014, 10, 9, 20, 47), 551440000.0],
#   [datetime.datetime(2014, 10, 10, 20, 47), 529961000.0],
#   [datetime.datetime(2014, 10, 11, 20, 47), 528879000.0],
#   [datetime.datetime(2014, 10, 12, 20, 47), 542117000.0],
#   [datetime.datetime(2014, 10, 13, 20, 47), 537068000.0],
#   [datetime.datetime(2014, 10, 14, 20, 47), 565232000.0],
#   [datetime.datetime(2014, 10, 15, 20, 47), 544017000.0],
#   [datetime.datetime(2014, 10, 16, 20, 47), 532542000.0],
#   [datetime.datetime(2014, 10, 17, 20, 47), 544109000.0],
#   [datetime.datetime(2014, 10, 18, 20, 47), 547342000.0],
#   [datetime.datetime(2014, 10, 19, 20, 47), 541591000.0],
#   [datetime.datetime(2014, 10, 20, 20, 47), 536553000.0],
#   [datetime.datetime(2014, 10, 21, 20, 47), 544277000.0],
#   [datetime.datetime(2014, 10, 22, 20, 47), 536643000.0],
#   [datetime.datetime(2014, 10, 23, 20, 47), 518993000.0],
#   [datetime.datetime(2014, 10, 24, 20, 47), 514179000.0],
#   [datetime.datetime(2014, 10, 25, 20, 47), 496838000.0],
#   [datetime.datetime(2014, 10, 26, 19, 47), 491393000.0],
#   [datetime.datetime(2014, 10, 27, 19, 47), 513645000.0],
#   [datetime.datetime(2014, 10, 28, 19, 47), 504513000.0],
#   [datetime.datetime(2014, 10, 29, 19, 47), 488073000.0],
#   [datetime.datetime(2014, 10, 30, 19, 47), 479721000.0],
#   [datetime.datetime(2014, 10, 31, 19, 47), 477236000.0],
#   [datetime.datetime(2014, 11, 1, 19, 47), 455917000.0],
#   [datetime.datetime(2014, 11, 2, 19, 47), 457502000.0],
#   [datetime.datetime(2014, 11, 3, 19, 47), 463106000.0],
#   [datetime.datetime(2014, 11, 4, 19, 47), 466172000.0],
#   [datetime.datetime(2014, 11, 5, 19, 47), 482886000.0],
#   [datetime.datetime(2014, 11, 6, 19, 47), 482788000.0],
#   [datetime.datetime(2014, 11, 7, 19, 47), 477243000.0],
#   [datetime.datetime(2014, 11, 8, 19, 47), 485474000.0],
#   [datetime.datetime(2014, 11, 9, 19, 47), 496568000.0],
#   [datetime.datetime(2014, 11, 10, 19, 47), 505255000.0],
#   [datetime.datetime(2014, 11, 11, 19, 47), 497143000.0],
#   [datetime.datetime(2014, 11, 12, 19, 47), 545380000.0],
#   [datetime.datetime(2014, 11, 13, 19, 47), 529177000.0],
#   [datetime.datetime(2014, 11, 14, 19, 47), 522492000.0],
#   [datetime.datetime(2014, 11, 15, 19, 47), 504986000.0],
#   [datetime.datetime(2014, 11, 16, 19, 47), 514415000.0],
#   [datetime.datetime(2014, 11, 17, 19, 47), 520010000.0],
#   [datetime.datetime(2014, 11, 18, 19, 47), 508211000.0],
#   [datetime.datetime(2014, 11, 19, 19, 47), 521740000.0],
#   [datetime.datetime(2014, 11, 20, 19, 47), 519812000.0],
#   [datetime.datetime(2014, 11, 21, 19, 47), 539952000.0],
#   [datetime.datetime(2014, 11, 22, 19, 47), 568525000.0],
#   [datetime.datetime(2014, 11, 23, 19, 47), 603431000.0],
#   [datetime.datetime(2014, 11, 24, 19, 47), 637356000.0],
#   [datetime.datetime(2014, 11, 25, 19, 47), 664689000.0],
#   [datetime.datetime(2014, 11, 26, 19, 47), 686841000.0],
#   [datetime.datetime(2014, 11, 27, 19, 47), 778758000.0],
#   [datetime.datetime(2014, 11, 28, 19, 47), 831015000.0],
#   [datetime.datetime(2014, 11, 29, 19, 47), 810401000.0],
#   [datetime.datetime(2014, 11, 30, 19, 47), 744676000.0],
#   [datetime.datetime(2014, 12, 1, 19, 47), 731088000.0],
#   [datetime.datetime(2014, 12, 2, 19, 47), 787582000.0],
#   [datetime.datetime(2014, 12, 3, 19, 47), 791545000.0],
#   [datetime.datetime(2014, 12, 4, 19, 47), 786916000.0],
#   [datetime.datetime(2014, 12, 5, 19, 47), 800410000.0],
#   [datetime.datetime(2014, 12, 6, 19, 47), 825195000.0],
#   [datetime.datetime(2014, 12, 7, 19, 47), 839410000.0],
#   [datetime.datetime(2014, 12, 8, 19, 47), 793670000.0],
#   [datetime.datetime(2014, 12, 9, 19, 47), 819539000.0],
#   [datetime.datetime(2014, 12, 10, 19, 47), 842040000.0],
#   [datetime.datetime(2014, 12, 11, 19, 47), 867876000.0],
#   [datetime.datetime(2014, 12, 12, 19, 47), 870226000.0],
#   [datetime.datetime(2014, 12, 13, 19, 47), 886140000.0],
#   [datetime.datetime(2014, 12, 14, 19, 47), 888573000.0],
#   [datetime.datetime(2014, 12, 15, 19, 47), 911661000.0],
#   [datetime.datetime(2014, 12, 16, 19, 47), 1144450000.0],
#   [datetime.datetime(2014, 12, 17, 19, 47), 1178470000.0],
#   [datetime.datetime(2014, 12, 18, 19, 47), 1261210000.0],
#   [datetime.datetime(2014, 12, 19, 19, 47), 1148560000.0],
#   [datetime.datetime(2014, 12, 20, 19, 47), 1162840000.0],
#   [datetime.datetime(2014, 12, 21, 19, 47), 1235220000.0],
#   [datetime.datetime(2014, 12, 22, 19, 47), 1316740000.0],
#   [datetime.datetime(2014, 12, 23, 19, 47), 1238680000.0],
#   [datetime.datetime(2014, 12, 24, 19, 47), 1186090000.0],
#   [datetime.datetime(2014, 12, 25, 19, 47), 1201200000.0],
#   [datetime.datetime(2014, 12, 26, 19, 47), 1255850000.0],
#   [datetime.datetime(2014, 12, 27, 19, 47), 1205410000.0],
#   [datetime.datetime(2014, 12, 28, 19, 47), 1222520000.0],
#   [datetime.datetime(2014, 12, 29, 19, 47), 1244940000.0],
#   [datetime.datetime(2014, 12, 30, 19, 47), 1230690000.0],
#   [datetime.datetime(2014, 12, 31, 19, 47), 1226630000.0],
#   [datetime.datetime(2015, 1, 1, 19, 47), 1197740000.0],
#   [datetime.datetime(2015, 1, 2, 19, 47), 1167090000.0],
#   [datetime.datetime(2015, 1, 3, 19, 47), 1056370000.0],
#   [datetime.datetime(2015, 1, 4, 19, 47), 929329000.0],
#   [datetime.datetime(2015, 1, 5, 19, 47), 964343000.0],
#   [datetime.datetime(2015, 1, 6, 19, 47), 982395000.0],
#   [datetime.datetime(2015, 1, 7, 19, 47), 991633000.0],
#   [datetime.datetime(2015, 1, 8, 19, 47), 995648000.0],
#   [datetime.datetime(2015, 1, 9, 19, 47), 981760000.0],
#   [datetime.datetime(2015, 1, 10, 19, 47), 918681000.0],
#   [datetime.datetime(2015, 1, 11, 19, 47), 894899000.0],
#   [datetime.datetime(2015, 1, 12, 19, 47), 908503000.0],
#   [datetime.datetime(2015, 1, 13, 19, 47), 780680000.0],
#   [datetime.datetime(2015, 1, 14, 19, 47), 678802000.0],
#   [datetime.datetime(2015, 1, 15, 19, 47), 784938000.0],
#   [datetime.datetime(2015, 1, 16, 19, 47), 785764000.0],
#   [datetime.datetime(2015, 1, 17, 19, 47), 738269000.0],
#   [datetime.datetime(2015, 1, 18, 19, 47), 738315000.0],
#   [datetime.datetime(2015, 1, 19, 19, 47), 748796000.0],
#   [datetime.datetime(2015, 1, 20, 19, 47), 755792000.0],
#   [datetime.datetime(2015, 1, 21, 19, 47), 766946000.0],
#   [datetime.datetime(2015, 1, 22, 19, 47), 799918000.0],
#   [datetime.datetime(2015, 1, 23, 19, 47), 789356000.0],
#   [datetime.datetime(2015, 1, 24, 19, 47), 812009000.0],
#   [datetime.datetime(2015, 1, 25, 19, 47), 813913000.0],
#   [datetime.datetime(2015, 1, 26, 19, 47), 803715000.0],
#   [datetime.datetime(2015, 1, 27, 19, 47), 793259000.0],
#   [datetime.datetime(2015, 1, 28, 19, 47), 753885000.0],
#   [datetime.datetime(2015, 1, 29, 19, 47), 732630000.0],
#   [datetime.datetime(2015, 1, 30, 19, 47), 716554000.0],
#   [datetime.datetime(2015, 1, 31, 19, 47), 725233000.0],
#   [datetime.datetime(2015, 2, 1, 19, 47), 702022000.0],
#   [datetime.datetime(2015, 2, 2, 19, 47), 677968000.0],
#   [datetime.datetime(2015, 2, 3, 19, 47), 663962000.0],
#   [datetime.datetime(2015, 2, 4, 19, 47), 664371000.0],
#   [datetime.datetime(2015, 2, 5, 19, 47), 676131000.0],
#   [datetime.datetime(2015, 2, 6, 19, 47), 737186000.0],
#   [datetime.datetime(2015, 2, 7, 19, 47), 714281000.0],
#   [datetime.datetime(2015, 2, 8, 19, 47), 709130000.0],
#   [datetime.datetime(2015, 2, 9, 19, 47), 695826000.0],
#   [datetime.datetime(2015, 2, 10, 19, 47), 685140000.0],
#   [datetime.datetime(2015, 2, 11, 19, 47), 691767000.0],
#   [datetime.datetime(2015, 2, 12, 19, 47), 699809000.0],
#   [datetime.datetime(2015, 2, 13, 19, 47), 733001000.0],
#   [datetime.datetime(2015, 2, 14, 19, 47), 734792000.0],
#   [datetime.datetime(2015, 2, 15, 19, 47), 710621000.0],
#   [datetime.datetime(2015, 2, 16, 19, 47), 697338000.0],
#   [datetime.datetime(2015, 2, 17, 19, 47), 707683000.0],
#   [datetime.datetime(2015, 2, 18, 19, 47), 688987000.0],
#   [datetime.datetime(2015, 2, 19, 19, 47), 697313000.0],
#   [datetime.datetime(2015, 2, 20, 19, 47), 686548000.0],
#   [datetime.datetime(2015, 2, 21, 19, 47), 678598000.0],
#   [datetime.datetime(2015, 2, 22, 19, 47), 661213000.0],
#   [datetime.datetime(2015, 2, 23, 19, 47), 676680000.0],
#   [datetime.datetime(2015, 2, 24, 19, 47), 685071000.0],
#   [datetime.datetime(2015, 2, 25, 19, 47), 689518000.0],
#   [datetime.datetime(2015, 2, 26, 19, 47), 687085000.0],
#   [datetime.datetime(2015, 2, 27, 19, 47), 701451000.0],
#   [datetime.datetime(2015, 2, 28, 19, 47), 689766000.0],
#   [datetime.datetime(2015, 3, 1, 19, 47), 659057000.0],
#   [datetime.datetime(2015, 3, 2, 19, 47), 660104000.0],
#   [datetime.datetime(2015, 3, 3, 19, 47), 623979000.0],
#   [datetime.datetime(2015, 3, 4, 19, 47), 593296000.0],
#   [datetime.datetime(2015, 3, 5, 19, 47), 624609000.0],
#   [datetime.datetime(2015, 3, 6, 19, 47), 614565000.0],
#   [datetime.datetime(2015, 3, 7, 19, 47), 613530000.0],
#   [datetime.datetime(2015, 3, 8, 19, 47), 590230000.0],
#   [datetime.datetime(2015, 3, 9, 19, 47), 620074000.0],
#   [datetime.datetime(2015, 3, 10, 19, 47), 605072000.0],
#   [datetime.datetime(2015, 3, 11, 19, 47), 606489000.0],
#   [datetime.datetime(2015, 3, 12, 19, 47), 609695000.0],
#   [datetime.datetime(2015, 3, 13, 19, 47), 609164000.0],
#   [datetime.datetime(2015, 3, 14, 19, 47), 622586000.0],
#   [datetime.datetime(2015, 3, 15, 19, 47), 616376000.0],
#   [datetime.datetime(2015, 3, 16, 19, 47), 625373000.0],
#   [datetime.datetime(2015, 3, 17, 19, 47), 617453000.0],
#   [datetime.datetime(2015, 3, 18, 19, 47), 601956000.0],
#   [datetime.datetime(2015, 3, 19, 19, 47), 584798000.0],
#   [datetime.datetime(2015, 3, 20, 19, 47), 594318000.0],
#   [datetime.datetime(2015, 3, 21, 19, 47), 583602000.0],
#   [datetime.datetime(2015, 3, 22, 19, 47), 585772000.0],
#   [datetime.datetime(2015, 3, 23, 19, 47), 586476000.0],
#   [datetime.datetime(2015, 3, 24, 19, 47), 566466000.0],
#   [datetime.datetime(2015, 3, 25, 19, 47), 538736000.0],
#   [datetime.datetime(2015, 3, 26, 19, 47), 535806000.0],
#   [datetime.datetime(2015, 3, 27, 19, 47), 535972000.0],
#   [datetime.datetime(2015, 3, 28, 19, 47), 539776000.0],
#   [datetime.datetime(2015, 3, 29, 20, 47), 523321000.0],
#   [datetime.datetime(2015, 3, 30, 20, 47), 517637000.0],
#   [datetime.datetime(2015, 3, 31, 20, 47), 499740000.0],
#   [datetime.datetime(2015, 4, 1, 20, 47), 486166000.0],
#   [datetime.datetime(2015, 4, 2, 20, 47), 503882000.0],
#   [datetime.datetime(2015, 4, 3, 20, 47), 532795000.0],
#   [datetime.datetime(2015, 4, 4, 20, 47), 538041000.0],
#   [datetime.datetime(2015, 4, 5, 20, 47), 526767000.0],
#   [datetime.datetime(2015, 4, 6, 20, 47), 526723000.0],
#   [datetime.datetime(2015, 4, 7, 20, 47), 540462000.0],
#   [datetime.datetime(2015, 4, 8, 20, 47), 533843000.0],
#   [datetime.datetime(2015, 4, 9, 20, 47), 520620000.0],
#   [datetime.datetime(2015, 4, 10, 20, 47), 500201000.0],
#   [datetime.datetime(2015, 4, 11, 20, 47), 491648000.0],
#   [datetime.datetime(2015, 4, 12, 20, 47), 498748000.0],
#   [datetime.datetime(2015, 4, 13, 20, 47), 477420000.0],
#   [datetime.datetime(2015, 4, 14, 20, 47), 467499000.0],
#   [datetime.datetime(2015, 4, 15, 20, 47), 462391000.0],
#   [datetime.datetime(2015, 4, 16, 20, 47), 473225000.0],
#   [datetime.datetime(2015, 4, 17, 20, 47), 473328000.0],
#   [datetime.datetime(2015, 4, 18, 20, 47), 466901000.0],
#   [datetime.datetime(2015, 4, 19, 20, 47), 467161000.0],
#   [datetime.datetime(2015, 4, 20, 20, 47), 466030000.0],
#   [datetime.datetime(2015, 4, 21, 20, 47), 463374000.0],
#   [datetime.datetime(2015, 4, 22, 20, 47), 479166000.0],
#   [datetime.datetime(2015, 4, 23, 20, 47), 479465000.0],
#   [datetime.datetime(2015, 4, 24, 20, 47), 475027000.0],
#   [datetime.datetime(2015, 4, 25, 20, 47), 477749000.0],
#   [datetime.datetime(2015, 4, 26, 20, 47), 449862000.0],
#   [datetime.datetime(2015, 4, 27, 20, 47), 452714000.0],
#   [datetime.datetime(2015, 4, 28, 20, 47), 449089000.0],
#   [datetime.datetime(2015, 4, 29, 20, 47), 454883000.0],
#   [datetime.datetime(2015, 4, 30, 20, 47), 469860000.0],
#   [datetime.datetime(2015, 5, 1, 20, 47), 467535000.0],
#   [datetime.datetime(2015, 5, 2, 20, 47), 467195000.0],
#   [datetime.datetime(2015, 5, 3, 20, 47), 470999000.0],
#   [datetime.datetime(2015, 5, 4, 20, 47), 466106000.0],
#   [datetime.datetime(2015, 5, 5, 20, 47), 461153000.0],
#   [datetime.datetime(2015, 5, 6, 20, 47), 457801000.0],
#   [datetime.datetime(2015, 5, 7, 20, 47), 453693000.0],
#   [datetime.datetime(2015, 5, 8, 20, 47), 453131000.0],
#   [datetime.datetime(2015, 5, 9, 20, 47), 451503000.0],
#   [datetime.datetime(2015, 5, 10, 20, 47), 445702000.0],
#   [datetime.datetime(2015, 5, 11, 20, 47), 449458000.0],
#   [datetime.datetime(2015, 5, 12, 20, 47), 451033000.0],
#   [datetime.datetime(2015, 5, 13, 20, 47), 448926000.0],
#   [datetime.datetime(2015, 5, 14, 20, 47), 431142000.0],
#   [datetime.datetime(2015, 5, 15, 20, 47), 437034000.0],
#   [datetime.datetime(2015, 5, 16, 20, 47), 432200000.0],
#   [datetime.datetime(2015, 5, 17, 20, 47), 424223000.0],
#   [datetime.datetime(2015, 5, 18, 20, 47), 412450000.0],
#   [datetime.datetime(2015, 5, 19, 20, 47), 435607000.0],
#   [datetime.datetime(2015, 5, 20, 20, 47), 447488000.0],
#   [datetime.datetime(2015, 5, 21, 20, 47), 448142000.0],
#   [datetime.datetime(2015, 5, 22, 20, 47), 473257000.0],
#   [datetime.datetime(2015, 5, 23, 20, 47), 482755000.0],
#   [datetime.datetime(2015, 5, 24, 20, 47), 484332000.0],
#   [datetime.datetime(2015, 5, 25, 20, 47), 486747000.0],
#   [datetime.datetime(2015, 5, 26, 20, 47), 486066000.0],
#   [datetime.datetime(2015, 5, 27, 20, 47), 498727000.0],
#   [datetime.datetime(2015, 5, 28, 20, 47), 533866000.0],
#   [datetime.datetime(2015, 5, 29, 20, 47), 567101000.0],
#   [datetime.datetime(2015, 5, 30, 20, 47), 543495000.0],
#   [datetime.datetime(2015, 5, 31, 20, 47), 531531000.0],
#   [datetime.datetime(2015, 6, 1, 20, 47), 497028000.0],
#   [datetime.datetime(2015, 6, 2, 20, 47), 508487000.0],
#   [datetime.datetime(2015, 6, 3, 20, 47), 520109000.0],
#   [datetime.datetime(2015, 6, 4, 20, 47), 516078000.0],
#   [datetime.datetime(2015, 6, 5, 20, 47), 521676000.0],
#   [datetime.datetime(2015, 6, 6, 20, 47), 523497000.0],
#   [datetime.datetime(2015, 6, 7, 20, 47), 519089000.0],
#   [datetime.datetime(2015, 6, 8, 20, 47), 524004000.0],
#   [datetime.datetime(2015, 6, 9, 20, 47), 525282000.0],
#   [datetime.datetime(2015, 6, 10, 20, 47), 525360000.0],
#   [datetime.datetime(2015, 6, 11, 20, 47), 526175000.0],
#   [datetime.datetime(2015, 6, 12, 20, 47), 525903000.0],
#   [datetime.datetime(2015, 6, 13, 20, 47), 535149000.0],
#   [datetime.datetime(2015, 6, 14, 20, 47), 544822000.0],
#   [datetime.datetime(2015, 6, 15, 20, 47), 559669000.0],
#   [datetime.datetime(2015, 6, 16, 20, 47), 618911000.0],
#   [datetime.datetime(2015, 6, 17, 20, 47), 665477000.0],
#   [datetime.datetime(2015, 6, 18, 20, 47), 686062000.0],
#   [datetime.datetime(2015, 6, 19, 20, 47), 705210000.0],
#   [datetime.datetime(2015, 6, 20, 20, 47), 705348000.0],
#   [datetime.datetime(2015, 6, 21, 20, 47), 691628000.0],
#   [datetime.datetime(2015, 6, 22, 20, 47), 688278000.0],
#   [datetime.datetime(2015, 6, 23, 20, 47), 690253000.0],
#   [datetime.datetime(2015, 6, 24, 20, 47), 682725000.0],
#   [datetime.datetime(2015, 6, 25, 20, 47), 693315000.0],
#   [datetime.datetime(2015, 6, 26, 20, 47), 696148000.0],
#   [datetime.datetime(2015, 6, 27, 20, 47), 718839000.0],
#   [datetime.datetime(2015, 6, 28, 20, 47), 719270000.0],
#   [datetime.datetime(2015, 6, 29, 20, 47), 770667000.0],
#   [datetime.datetime(2015, 6, 30, 20, 47), 769913000.0],
#   [datetime.datetime(2015, 7, 1, 20, 47), 751222000.0],
#   [datetime.datetime(2015, 7, 2, 20, 47), 751830000.0],
#   [datetime.datetime(2015, 7, 3, 20, 47), 753960000.0],
#   [datetime.datetime(2015, 7, 4, 20, 47), 748783000.0],
#   [datetime.datetime(2015, 7, 5, 20, 47), 743319000.0],
#   [datetime.datetime(2015, 7, 6, 20, 47), 790896000.0],
#   [datetime.datetime(2015, 7, 7, 20, 47), 763797000.0],
#   [datetime.datetime(2015, 7, 8, 20, 47), 792956000.0],
#   [datetime.datetime(2015, 7, 9, 20, 47), 848990000.0],
#   [datetime.datetime(2015, 7, 10, 20, 47), 779444000.0],
#   [datetime.datetime(2015, 7, 11, 20, 47), 702401000.0],
#   [datetime.datetime(2015, 7, 12, 20, 47), 753937000.0],
#   [datetime.datetime(2015, 7, 13, 20, 47), 719344000.0],
#   [datetime.datetime(2015, 7, 14, 20, 47), 730682000.0],
#   [datetime.datetime(2015, 7, 15, 20, 47), 706520000.0],
#   [datetime.datetime(2015, 7, 16, 20, 47), 625416000.0],
#   [datetime.datetime(2015, 7, 17, 20, 47), 649706000.0],
#   [datetime.datetime(2015, 7, 18, 20, 47), 654796000.0],
#   [datetime.datetime(2015, 7, 19, 20, 47), 649486000.0],
#   [datetime.datetime(2015, 7, 20, 20, 47), 645688000.0],
#   [datetime.datetime(2015, 7, 21, 20, 47), 643181000.0],
#   [datetime.datetime(2015, 7, 22, 20, 47), 638162000.0],
#   [datetime.datetime(2015, 7, 23, 20, 47), 631498000.0],
#   [datetime.datetime(2015, 7, 24, 20, 47), 678916000.0],
#   [datetime.datetime(2015, 7, 25, 20, 47), 688518000.0],
#   [datetime.datetime(2015, 7, 26, 20, 47), 696254000.0],
#   [datetime.datetime(2015, 7, 27, 20, 47), 712204000.0],
#   [datetime.datetime(2015, 7, 28, 20, 47), 729735000.0],
#   [datetime.datetime(2015, 7, 29, 20, 47), 719222000.0],
#   [datetime.datetime(2015, 7, 30, 20, 47), 704284000.0],
#   [datetime.datetime(2015, 7, 31, 20, 47), 704698000.0],
#   [datetime.datetime(2015, 8, 1, 20, 47), 671964000.0],
#   [datetime.datetime(2015, 8, 2, 20, 47), 666681000.0],
#   [datetime.datetime(2015, 8, 3, 20, 47), 680933000.0],
#   [datetime.datetime(2015, 8, 4, 20, 47), 682329000.0],
#   [datetime.datetime(2015, 8, 5, 20, 47), 679000000.0],
#   [datetime.datetime(2015, 8, 6, 20, 47), 661538000.0],
#   [datetime.datetime(2015, 8, 7, 20, 47), 814142000.0],
#   [datetime.datetime(2015, 8, 8, 20, 47), 712758000.0],
#   [datetime.datetime(2015, 8, 9, 20, 47), 699605000.0],
#   [datetime.datetime(2015, 8, 10, 20, 47), 700479000.0],
#   [datetime.datetime(2015, 8, 11, 20, 47), 712598000.0],
#   [datetime.datetime(2015, 8, 12, 20, 47), 724885000.0],
#   [datetime.datetime(2015, 8, 13, 20, 47), 749640000.0],
#   [datetime.datetime(2015, 8, 14, 20, 47), 764350000.0],
#   [datetime.datetime(2015, 8, 15, 20, 47), 757514000.0],
#   [datetime.datetime(2015, 8, 16, 20, 47), 720594000.0],
#   [datetime.datetime(2015, 8, 17, 20, 47), 733599000.0],
# ...
#   [datetime.datetime(2015, 4, 9, 20, 47), 3283100.0],
#   [datetime.datetime(2015, 4, 10, 20, 47), 3688190.0],
#   [datetime.datetime(2015, 4, 11, 20, 47), 2598570.0],
#   [datetime.datetime(2015, 4, 12, 20, 47), 2026160.0],
#   [datetime.datetime(2015, 4, 13, 20, 47), 2425610.0],
#   [datetime.datetime(2015, 4, 14, 20, 47), 3640350.0],
#   [datetime.datetime(2015, 4, 15, 20, 47), 2522860.0],
#   [datetime.datetime(2015, 4, 16, 20, 47), 2646430.0],
#   [datetime.datetime(2015, 4, 17, 20, 47), 2432680.0],
#   [datetime.datetime(2015, 4, 18, 20, 47), 1623340.0],
#   [datetime.datetime(2015, 4, 19, 20, 47), 1767900.0],
#   [datetime.datetime(2015, 4, 20, 20, 47), 2573800.0],
#   [datetime.datetime(2015, 4, 21, 20, 47), 2301130.0],
#   [datetime.datetime(2015, 4, 22, 20, 47), 3081300.0],
#   [datetime.datetime(2015, 4, 23, 20, 47), 2532220.0],
#   [datetime.datetime(2015, 4, 24, 20, 47), 2406700.0],
#   [datetime.datetime(2015, 4, 25, 20, 47), 1870600.0],
#   [datetime.datetime(2015, 4, 26, 20, 47), 2505390.0],
#   [datetime.datetime(2015, 4, 27, 20, 47), 2613800.0],
#   [datetime.datetime(2015, 4, 28, 20, 47), 2937490.0],
#   [datetime.datetime(2015, 4, 29, 20, 47), 2508840.0],
#   [datetime.datetime(2015, 4, 30, 20, 47), 3378740.0],
#   [datetime.datetime(2015, 5, 1, 20, 47), 2899870.0],
#   [datetime.datetime(2015, 5, 2, 20, 47), 1782630.0],
#   [datetime.datetime(2015, 5, 3, 20, 47), 2435460.0],
#   [datetime.datetime(2015, 5, 4, 20, 47), 2698170.0],
#   [datetime.datetime(2015, 5, 5, 20, 47), 2355240.0],
#   [datetime.datetime(2015, 5, 6, 20, 47), 2190860.0],
#   [datetime.datetime(2015, 5, 7, 20, 47), 3904910.0],
#   [datetime.datetime(2015, 5, 8, 20, 47), 2976440.0],
#   [datetime.datetime(2015, 5, 9, 20, 47), 2205550.0],
#   [datetime.datetime(2015, 5, 10, 20, 47), 2299270.0],
#   [datetime.datetime(2015, 5, 11, 20, 47), 1928110.0],
#   [datetime.datetime(2015, 5, 12, 20, 47), 3203130.0],
#   [datetime.datetime(2015, 5, 13, 20, 47), 2460350.0],
#   [datetime.datetime(2015, 5, 14, 20, 47), 3639760.0],
#   [datetime.datetime(2015, 5, 15, 20, 47), 1949320.0],
#   [datetime.datetime(2015, 5, 16, 20, 47), 1541400.0],
#   [datetime.datetime(2015, 5, 17, 20, 47), 1437230.0],
#   [datetime.datetime(2015, 5, 18, 20, 47), 3150440.0],
#   [datetime.datetime(2015, 5, 19, 20, 47), 3710990.0],
#   [datetime.datetime(2015, 5, 20, 20, 47), 2639940.0],
#   [datetime.datetime(2015, 5, 21, 20, 47), 7100350.0],
#   [datetime.datetime(2015, 5, 22, 20, 47), 10566900.0],
#   [datetime.datetime(2015, 5, 23, 20, 47), 9343270.0],
#   [datetime.datetime(2015, 5, 24, 20, 47), 7338150.0],
#   [datetime.datetime(2015, 5, 25, 20, 47), 8225200.0],
#   [datetime.datetime(2015, 5, 26, 20, 47), 8333520.0],
#   [datetime.datetime(2015, 5, 27, 20, 47), 9807410.0],
#   [datetime.datetime(2015, 5, 28, 20, 47), 11085200.0],
#   [datetime.datetime(2015, 5, 29, 20, 47), 10795500.0],
#   [datetime.datetime(2015, 5, 30, 20, 47), 8538810.0],
#   [datetime.datetime(2015, 5, 31, 20, 47), 7318680.0],
#   [datetime.datetime(2015, 6, 1, 20, 47), 7738640.0],
#   [datetime.datetime(2015, 6, 2, 20, 47), 7988830.0],
#   [datetime.datetime(2015, 6, 3, 20, 47), 6552620.0],
#   [datetime.datetime(2015, 6, 4, 20, 47), 5698490.0],
#   [datetime.datetime(2015, 6, 5, 20, 47), 6316350.0],
#   [datetime.datetime(2015, 6, 6, 20, 47), 5681480.0],
#   [datetime.datetime(2015, 6, 7, 20, 47), 5547450.0],
#   [datetime.datetime(2015, 6, 8, 20, 47), 6179490.0],
#   [datetime.datetime(2015, 6, 9, 20, 47), 5837260.0],
#   [datetime.datetime(2015, 6, 10, 20, 47), 6368110.0],
#   [datetime.datetime(2015, 6, 11, 20, 47), 6323470.0],
#   [datetime.datetime(2015, 6, 12, 20, 47), 5831150.0],
#   [datetime.datetime(2015, 6, 13, 20, 47), 7106910.0],
#   [datetime.datetime(2015, 6, 14, 20, 47), 8876940.0],
#   [datetime.datetime(2015, 6, 15, 20, 47), 7005650.0],
#   [datetime.datetime(2015, 6, 16, 20, 47), 15235200.0],
#   [datetime.datetime(2015, 6, 17, 20, 47), 24490300.0],
#   [datetime.datetime(2015, 6, 18, 20, 47), 16313100.0],
#   [datetime.datetime(2015, 6, 19, 20, 47), 14563300.0],
#   [datetime.datetime(2015, 6, 20, 20, 47), 9762870.0],
#   [datetime.datetime(2015, 6, 21, 20, 47), 20360300.0],
#   [datetime.datetime(2015, 6, 22, 20, 47), 20703900.0],
#   [datetime.datetime(2015, 6, 23, 20, 47), 7675070.0],
#   [datetime.datetime(2015, 6, 24, 20, 47), 9571780.0],
#   [datetime.datetime(2015, 6, 25, 20, 47), 9190760.0],
#   [datetime.datetime(2015, 6, 26, 20, 47), 6646040.0],
#   [datetime.datetime(2015, 6, 27, 20, 47), 8286930.0],
#   [datetime.datetime(2015, 6, 28, 20, 47), 8619600.0],
#   [datetime.datetime(2015, 6, 29, 20, 47), 15818500.0],
#   [datetime.datetime(2015, 6, 30, 20, 47), 24948400.0],
#   [datetime.datetime(2015, 7, 1, 20, 47), 13477100.0],
#   [datetime.datetime(2015, 7, 2, 20, 47), 10947900.0],
#   [datetime.datetime(2015, 7, 3, 20, 47), 8256620.0],
#   [datetime.datetime(2015, 7, 4, 20, 47), 7662110.0],
#   [datetime.datetime(2015, 7, 5, 20, 47), 11680200.0],
#   [datetime.datetime(2015, 7, 6, 20, 47), 32931600.0],
#   [datetime.datetime(2015, 7, 7, 20, 47), 22603600.0],
#   [datetime.datetime(2015, 7, 8, 20, 47), 27730400.0],
#   [datetime.datetime(2015, 7, 9, 20, 47), 46974400.0],
#   [datetime.datetime(2015, 7, 10, 20, 47), 75301800.0],
#   [datetime.datetime(2015, 7, 11, 20, 47), 37807100.0],
#   [datetime.datetime(2015, 7, 12, 20, 47), 26557200.0],
#   [datetime.datetime(2015, 7, 13, 20, 47), 20583000.0],
#   [datetime.datetime(2015, 7, 14, 20, 47), 12391400.0],
#   [datetime.datetime(2015, 7, 15, 20, 47), 10808300.0],
#   [datetime.datetime(2015, 7, 16, 20, 47), 22197900.0],
#   [datetime.datetime(2015, 7, 17, 20, 47), 14150600.0],
#   [datetime.datetime(2015, 7, 18, 20, 47), 12114300.0],
#   [datetime.datetime(2015, 7, 19, 20, 47), 6644140.0],
#   [datetime.datetime(2015, 7, 20, 20, 47), 7508540.0],
#   [datetime.datetime(2015, 7, 21, 20, 47), 7983870.0],
#   [datetime.datetime(2015, 7, 22, 20, 47), 6219560.0],
#   [datetime.datetime(2015, 7, 23, 20, 47), 4779830.0],
#   [datetime.datetime(2015, 7, 24, 20, 47), 13374000.0],
#   [datetime.datetime(2015, 7, 25, 20, 47), 17275600.0],
#   [datetime.datetime(2015, 7, 26, 20, 47), 10736400.0],
#   [datetime.datetime(2015, 7, 27, 20, 47), 7946370.0],
#   [datetime.datetime(2015, 7, 28, 20, 47), 13980200.0],
#   [datetime.datetime(2015, 7, 29, 20, 47), 10005100.0],
#   [datetime.datetime(2015, 7, 30, 20, 47), 8035240.0],
#   [datetime.datetime(2015, 7, 31, 20, 47), 7176710.0],
#   [datetime.datetime(2015, 8, 1, 20, 47), 8243480.0],
#   [datetime.datetime(2015, 8, 2, 20, 47), 8297830.0],
#   [datetime.datetime(2015, 8, 3, 20, 47), 7727390.0],
#   [datetime.datetime(2015, 8, 4, 20, 47), 6475910.0],
#   [datetime.datetime(2015, 8, 5, 20, 47), 4755420.0],
#   [datetime.datetime(2015, 8, 6, 20, 47), 5881100.0],
#   [datetime.datetime(2015, 8, 7, 20, 47), 21100300.0],
#   [datetime.datetime(2015, 8, 8, 20, 47), 26509400.0],
#   [datetime.datetime(2015, 8, 9, 20, 47), 21425200.0],
#   [datetime.datetime(2015, 8, 10, 20, 47), 4544300.0],
#   [datetime.datetime(2015, 8, 11, 20, 47), 5199060.0],
#   [datetime.datetime(2015, 8, 12, 20, 47), 8458730.0],
#   [datetime.datetime(2015, 8, 13, 20, 47), 7515730.0],
#   [datetime.datetime(2015, 8, 14, 20, 47), 10450400.0],
#   [datetime.datetime(2015, 8, 15, 20, 47), 6159260.0],
#   [datetime.datetime(2015, 8, 16, 20, 47), 8686960.0],
#   [datetime.datetime(2015, 8, 17, 20, 47), 6463820.0],
#   [datetime.datetime(2015, 8, 18, 20, 47), 5547660.0],
#   [datetime.datetime(2015, 8, 19, 20, 47), 11233200.0],
#   [datetime.datetime(2015, 8, 20, 20, 47), 8824200.0],
#   [datetime.datetime(2015, 8, 21, 20, 47), 6379010.0],
#   [datetime.datetime(2015, 8, 22, 20, 47), 5538370.0],
#   [datetime.datetime(2015, 8, 23, 20, 47), 6045080.0],
#   [datetime.datetime(2015, 8, 24, 20, 47), 10355800.0],
#   [datetime.datetime(2015, 8, 25, 20, 47), 15747000.0],
#   [datetime.datetime(2015, 8, 26, 20, 47), 9905690.0],
#   [datetime.datetime(2015, 8, 27, 20, 47), 5215120.0],
#   [datetime.datetime(2015, 8, 28, 20, 47), 8116100.0],
#   [datetime.datetime(2015, 8, 29, 20, 47), 4902280.0],
#   [datetime.datetime(2015, 8, 30, 20, 47), 5357750.0],
#   [datetime.datetime(2015, 8, 31, 20, 47), 6550860.0],
#   [datetime.datetime(2015, 9, 1, 20, 47), 4886850.0],
#   [datetime.datetime(2015, 9, 2, 20, 47), 5480200.0],
#   [datetime.datetime(2015, 9, 3, 20, 47), 4945740.0],
#   [datetime.datetime(2015, 9, 4, 20, 47), 3314780.0],
#   [datetime.datetime(2015, 9, 5, 20, 47), 4665600.0],
#   [datetime.datetime(2015, 9, 6, 20, 47), 8643830.0],
#   [datetime.datetime(2015, 9, 7, 20, 47), 6146210.0],
#   [datetime.datetime(2015, 9, 8, 20, 47), 5896310.0],
#   [datetime.datetime(2015, 9, 9, 20, 47), 6122040.0],
#   [datetime.datetime(2015, 9, 10, 20, 47), 5241220.0],
#   [datetime.datetime(2015, 9, 11, 20, 47), 6070660.0],
#   [datetime.datetime(2015, 9, 12, 20, 47), 4295760.0],
#   [datetime.datetime(2015, 9, 13, 20, 47), 4070890.0],
#   [datetime.datetime(2015, 9, 14, 20, 47), 4776530.0],
#   [datetime.datetime(2015, 9, 15, 20, 47), 5130730.0],
#   [datetime.datetime(2015, 9, 16, 20, 47), 4976910.0],
#   [datetime.datetime(2015, 9, 17, 20, 47), 5806800.0],
#   [datetime.datetime(2015, 9, 18, 20, 47), 5405620.0],
#   [datetime.datetime(2015, 9, 19, 20, 47), 4133510.0],
#   [datetime.datetime(2015, 9, 20, 20, 47), 4159830.0],
#   [datetime.datetime(2015, 9, 21, 20, 47), 5282360.0],
#   [datetime.datetime(2015, 9, 22, 20, 47), 5423840.0],
#   [datetime.datetime(2015, 9, 23, 20, 47), 4759620.0],
#   [datetime.datetime(2015, 9, 24, 20, 47), 5127170.0],
#   [datetime.datetime(2015, 9, 25, 20, 47), 4818890.0],
#   [datetime.datetime(2015, 9, 26, 20, 47), 2264900.0],
#   [datetime.datetime(2015, 9, 27, 20, 47), 2121740.0],
#   [datetime.datetime(2015, 9, 28, 20, 47), 6394160.0],
#   [datetime.datetime(2015, 9, 29, 20, 47), 7940610.0],
#   [datetime.datetime(2015, 9, 30, 20, 47), 5911260.0],
#   [datetime.datetime(2015, 10, 1, 20, 47), 3768380.0],
#   [datetime.datetime(2015, 10, 2, 20, 47), 3236560.0],
#   [datetime.datetime(2015, 10, 3, 20, 47), 2448510.0],
#   [datetime.datetime(2015, 10, 4, 20, 47), 2514050.0],
#   [datetime.datetime(2015, 10, 5, 20, 47), 2647400.0],
#   [datetime.datetime(2015, 10, 6, 20, 47), 3246900.0],
#   [datetime.datetime(2015, 10, 7, 20, 47), 3199360.0],
#   [datetime.datetime(2015, 10, 8, 20, 47), 4489760.0],
#   [datetime.datetime(2015, 10, 9, 20, 47), 4626570.0],
#   [datetime.datetime(2015, 10, 10, 20, 47), 4015780.0],
#   [datetime.datetime(2015, 10, 11, 20, 47), 3232200.0],
#   [datetime.datetime(2015, 10, 12, 20, 47), 4111410.0],
#   [datetime.datetime(2015, 10, 13, 20, 47), 4795410.0],
#   [datetime.datetime(2015, 10, 14, 20, 47), 5493810.0],
#   [datetime.datetime(2015, 10, 15, 20, 47), 5801270.0],
#   [datetime.datetime(2015, 10, 16, 20, 47), 4458360.0],
#   [datetime.datetime(2015, 10, 17, 20, 47), 5529000.0],
#   [datetime.datetime(2015, 10, 18, 20, 47), 3572030.0],
#   [datetime.datetime(2015, 10, 19, 20, 47), 4211720.0],
#   [datetime.datetime(2015, 10, 20, 20, 47), 4075670.0],
#   [datetime.datetime(2015, 10, 21, 20, 47), 4225020.0],
#   [datetime.datetime(2015, 10, 22, 20, 47), 4446810.0],
#   [datetime.datetime(2015, 10, 23, 20, 47), 4932620.0],
#   [datetime.datetime(2015, 10, 24, 20, 47), 3179140.0],
#   [datetime.datetime(2015, 10, 25, 19, 47), 4124600.0],
#   [datetime.datetime(2015, 10, 26, 19, 47), 4735920.0],
#   [datetime.datetime(2015, 10, 27, 19, 47), 5891000.0],
#   [datetime.datetime(2015, 10, 28, 19, 47), 5296800.0],
#   [datetime.datetime(2015, 10, 29, 19, 47), 14047500.0],
#   [datetime.datetime(2015, 10, 30, 19, 47), 23991900.0],
#   [datetime.datetime(2015, 10, 31, 19, 47), 8665960.0],
#   [datetime.datetime(2015, 11, 1, 19, 47), 6772790.0],
#   [datetime.datetime(2015, 11, 2, 19, 47), 8816170.0],
#   [datetime.datetime(2015, 11, 3, 19, 47), 25027600.0],
#   [datetime.datetime(2015, 11, 4, 19, 47), 33680200.0],
#   [datetime.datetime(2015, 11, 5, 19, 47), 25760900.0],
#   [datetime.datetime(2015, 11, 6, 19, 47), 14525400.0],
#   [datetime.datetime(2015, 11, 7, 19, 47), 8097730.0],
#   [datetime.datetime(2015, 11, 8, 19, 47), 5334450.0],
#   [datetime.datetime(2015, 11, 9, 19, 47), 10227900.0],
#   [datetime.datetime(2015, 11, 10, 19, 47), 8272580.0],
#   [datetime.datetime(2015, 11, 11, 19, 47), 8823090.0],
#   [datetime.datetime(2015, 11, 12, 19, 47), 7619290.0],
#   [datetime.datetime(2015, 11, 13, 19, 47), 5687310.0],
#   [datetime.datetime(2015, 11, 14, 19, 47), 3119610.0],
#   [datetime.datetime(2015, 11, 15, 19, 47), 3897140.0],
#   [datetime.datetime(2015, 11, 16, 19, 47), 3964620.0],
#   [datetime.datetime(2015, 11, 17, 19, 47), 5139330.0],
#   [datetime.datetime(2015, 11, 18, 19, 47), 4093470.0],
#   [datetime.datetime(2015, 11, 19, 19, 47), 5311150.0],
#   [datetime.datetime(2015, 11, 20, 19, 47), 4610550.0],
#   [datetime.datetime(2015, 11, 21, 19, 47), 3626790.0],
#   [datetime.datetime(2015, 11, 22, 19, 47), 2930620.0],
#   [datetime.datetime(2015, 11, 23, 19, 47), 3573840.0],
#   [datetime.datetime(2015, 11, 24, 19, 47), 3846180.0],
#   [datetime.datetime(2015, 11, 25, 19, 47), 5595350.0],
#   [datetime.datetime(2015, 11, 26, 19, 47), 13320400.0],
#   [datetime.datetime(2015, 11, 27, 19, 47), 6113740.0],
#   [datetime.datetime(2015, 11, 28, 19, 47), 4375350.0],
#   [datetime.datetime(2015, 11, 29, 19, 47), 4493190.0],
#   [datetime.datetime(2015, 11, 30, 19, 47), 7075790.0],
#   [datetime.datetime(2015, 12, 1, 19, 47), 6244520.0],
#   [datetime.datetime(2015, 12, 2, 19, 47), 6768930.0],
#   [datetime.datetime(2015, 12, 3, 19, 47), 4711200.0],
#   [datetime.datetime(2015, 12, 4, 19, 47), 4052070.0],
#   [datetime.datetime(2015, 12, 5, 19, 47), 4916020.0],
#   [datetime.datetime(2015, 12, 6, 19, 47), 7409940.0],
#   [datetime.datetime(2015, 12, 7, 19, 47), 7212320.0],
#   [datetime.datetime(2015, 12, 8, 19, 47), 7222160.0],
#   [datetime.datetime(2015, 12, 9, 19, 47), 14818000.0],
#   [datetime.datetime(2015, 12, 10, 19, 47), 9609360.0],
#   [datetime.datetime(2015, 12, 11, 19, 47), 10413400.0],
#   [datetime.datetime(2015, 12, 12, 19, 47), 12817300.0],
#   [datetime.datetime(2015, 12, 13, 19, 47), 6669690.0],
#   [datetime.datetime(2015, 12, 14, 19, 47), 7839280.0],
#   [datetime.datetime(2015, 12, 15, 19, 47), 13369900.0],
#   [datetime.datetime(2015, 12, 16, 19, 47), 7709410.0],
#   [datetime.datetime(2015, 12, 17, 19, 47), 5580560.0],
#   [datetime.datetime(2015, 12, 18, 19, 47), 5757460.0],
#   [datetime.datetime(2015, 12, 19, 19, 47), 4091960.0],
#   [datetime.datetime(2015, 12, 20, 19, 47), 5426570.0],
#   [datetime.datetime(2015, 12, 21, 19, 47), 8035490.0],
#   [datetime.datetime(2015, 12, 22, 19, 47), 4998820.0],
#   [datetime.datetime(2015, 12, 23, 19, 47), 5624820.0],
#   [datetime.datetime(2015, 12, 24, 19, 47), 5701250.0],
#   [datetime.datetime(2015, 12, 25, 19, 47), 5384610.0],
#   [datetime.datetime(2015, 12, 26, 19, 47), 7182870.0],
#   [datetime.datetime(2015, 12, 27, 19, 47), 4475260.0],
#   [datetime.datetime(2015, 12, 28, 19, 47), 4198830.0],
#   [datetime.datetime(2015, 12, 29, 19, 47), 4682520.0],
#   [datetime.datetime(2015, 12, 30, 19, 47), 5124710.0],
#   [datetime.datetime(2015, 12, 31, 19, 47), 5672540.0],
#   [datetime.datetime(2016, 1, 1, 19, 47), 4725940.0],
#   [datetime.datetime(2016, 1, 2, 19, 47), 4975350.0],
#   [datetime.datetime(2016, 1, 3, 19, 47), 4159840.0],
#   [datetime.datetime(2016, 1, 4, 19, 47), 6923430.0],
#   [datetime.datetime(2016, 1, 5, 19, 47), 4230340.0],
#   [datetime.datetime(2016, 1, 6, 19, 47), 4323530.0],
#   [datetime.datetime(2016, 1, 7, 19, 47), 8354300.0],
#   [datetime.datetime(2016, 1, 8, 19, 47), 9507140.0],
#   [datetime.datetime(2016, 1, 9, 19, 47), 10284000.0],
#   [datetime.datetime(2016, 1, 10, 19, 47), 5910190.0],
#   [datetime.datetime(2016, 1, 11, 19, 47), 8666190.0],
#   [datetime.datetime(2016, 1, 12, 19, 47), 26041100.0],
#   [datetime.datetime(2016, 1, 13, 19, 47), 18745000.0],
#   [datetime.datetime(2016, 1, 14, 19, 47), 10497200.0],
#   [datetime.datetime(2016, 1, 15, 19, 47), 15083800.0],
#   [datetime.datetime(2016, 1, 16, 19, 47), 14540000.0],
#   [datetime.datetime(2016, 1, 17, 19, 47), 8212880.0],
#   [datetime.datetime(2016, 1, 18, 19, 47), 11529900.0],
#   [datetime.datetime(2016, 1, 19, 19, 47), 8364360.0],
#   [datetime.datetime(2016, 1, 20, 19, 47), 12673700.0],
#   [datetime.datetime(2016, 1, 21, 19, 47), 17790600.0],
#   [datetime.datetime(2016, 1, 22, 19, 47), 24766200.0],
#   ...]}

# %% [markdown]
# #### `graphs.dominance([start=None, end=None])`
# Get data from percentage of total market capitalization chart:

# %%
from datetime import datetime, timedelta

ten_days_ago = datetime.now() - timedelta(days=10)
cmc.graphs.dominance(start=ten_days_ago)
# Out:
# {'bitcoin': [[datetime.datetime(2018, 3, 13, 19, 47), 41.944],
#   [datetime.datetime(2018, 3, 14, 19, 47), 42.1054],
#   [datetime.datetime(2018, 3, 15, 19, 47), 42.6794],
#   [datetime.datetime(2018, 3, 16, 19, 47), 42.5987],
#   [datetime.datetime(2018, 3, 17, 19, 47), 43.1004],
#   [datetime.datetime(2018, 3, 18, 19, 47), 44.5214],
#   [datetime.datetime(2018, 3, 19, 19, 47), 44.0558],
#   [datetime.datetime(2018, 3, 20, 19, 47), 43.7614],
#   [datetime.datetime(2018, 3, 21, 19, 47), 43.8275],
#   [datetime.datetime(2018, 3, 22, 19, 47), 44.0364],
#   [datetime.datetime(2018, 3, 23, 13, 47), 44.2492]],
#  'bitcoin-cash': [[datetime.datetime(2018, 3, 13, 19, 47), 4.91544],
#   [datetime.datetime(2018, 3, 14, 19, 47), 4.86849],
#   [datetime.datetime(2018, 3, 15, 19, 47), 4.81862],
#   [datetime.datetime(2018, 3, 16, 19, 47), 5.14205],
#   [datetime.datetime(2018, 3, 17, 19, 47), 5.24283],
#   [datetime.datetime(2018, 3, 18, 19, 47), 5.19653],
#   [datetime.datetime(2018, 3, 19, 19, 47), 5.09963],
#   [datetime.datetime(2018, 3, 20, 19, 47), 5.20625],
#   [datetime.datetime(2018, 3, 21, 19, 47), 5.11057],
#   [datetime.datetime(2018, 3, 22, 19, 47), 5.18044],
#   [datetime.datetime(2018, 3, 23, 13, 47), 5.16675]],
#  'dash': [[datetime.datetime(2018, 3, 13, 19, 47), 1.03936],
#   [datetime.datetime(2018, 3, 14, 19, 47), 1.04349],
#   [datetime.datetime(2018, 3, 15, 19, 47), 1.0128],
#   [datetime.datetime(2018, 3, 16, 19, 47), 0.99856],
#   [datetime.datetime(2018, 3, 17, 19, 47), 0.99902],
#   [datetime.datetime(2018, 3, 18, 19, 47), 0.996687],
#   [datetime.datetime(2018, 3, 19, 19, 47), 0.965943],
#   [datetime.datetime(2018, 3, 20, 19, 47), 0.99611],
#   [datetime.datetime(2018, 3, 21, 19, 47), 0.989907],
#   [datetime.datetime(2018, 3, 22, 19, 47), 0.980171],
#   [datetime.datetime(2018, 3, 23, 13, 47), 0.98237]],
#  'ethereum': [[datetime.datetime(2018, 3, 13, 19, 47), 18.2354],
#   [datetime.datetime(2018, 3, 14, 19, 47), 18.1566],
#   [datetime.datetime(2018, 3, 15, 19, 47), 18.2134],
#   [datetime.datetime(2018, 3, 16, 19, 47), 17.9796],
#   [datetime.datetime(2018, 3, 17, 19, 47), 17.932],
#   [datetime.datetime(2018, 3, 18, 19, 47), 17.0805],
#   [datetime.datetime(2018, 3, 19, 19, 47), 16.4116],
#   [datetime.datetime(2018, 3, 20, 19, 47), 15.9473],
#   [datetime.datetime(2018, 3, 21, 19, 47), 16.0064],
#   [datetime.datetime(2018, 3, 22, 19, 47), 15.7522],
#   [datetime.datetime(2018, 3, 23, 13, 47), 15.7914]],
#  'iota': [[datetime.datetime(2018, 3, 13, 19, 47), 0.981143],
#   [datetime.datetime(2018, 3, 14, 19, 47), 0.935522],
#   [datetime.datetime(2018, 3, 15, 19, 47), 0.912422],
#   [datetime.datetime(2018, 3, 16, 19, 47), 0.941524],
#   [datetime.datetime(2018, 3, 17, 19, 47), 0.98689],
#   [datetime.datetime(2018, 3, 18, 19, 47), 1.1343],
#   [datetime.datetime(2018, 3, 19, 19, 47), 1.11206],
#   [datetime.datetime(2018, 3, 20, 19, 47), 1.18941],
#   [datetime.datetime(2018, 3, 21, 19, 47), 1.1111],
#   [datetime.datetime(2018, 3, 22, 19, 47), 1.1046],
#   [datetime.datetime(2018, 3, 23, 13, 47), 1.0964]],
#  'litecoin': [[datetime.datetime(2018, 3, 13, 19, 47), 2.63486],
#   [datetime.datetime(2018, 3, 14, 19, 47), 2.70405],
#   [datetime.datetime(2018, 3, 15, 19, 47), 2.76803],
#   [datetime.datetime(2018, 3, 16, 19, 47), 2.78959],
#   [datetime.datetime(2018, 3, 17, 19, 47), 2.73888],
#   [datetime.datetime(2018, 3, 18, 19, 47), 2.77417],
#   [datetime.datetime(2018, 3, 19, 19, 47), 2.69614],
#   [datetime.datetime(2018, 3, 20, 19, 47), 2.74369],
#   [datetime.datetime(2018, 3, 21, 19, 47), 2.72367],
#   [datetime.datetime(2018, 3, 22, 19, 47), 2.7329],
#   [datetime.datetime(2018, 3, 23, 13, 47), 2.74017]],
#  'monero': [[datetime.datetime(2018, 3, 13, 19, 47), 1.06806],
#   [datetime.datetime(2018, 3, 14, 19, 47), 1.01933],
#   [datetime.datetime(2018, 3, 15, 19, 47), 1.04081],
#   [datetime.datetime(2018, 3, 16, 19, 47), 1.01504],
#   [datetime.datetime(2018, 3, 17, 19, 47), 1.01183],
#   [datetime.datetime(2018, 3, 18, 19, 47), 1.02375],
#   [datetime.datetime(2018, 3, 19, 19, 47), 1.03178],
#   [datetime.datetime(2018, 3, 20, 19, 47), 1.04882],
#   [datetime.datetime(2018, 3, 21, 19, 47), 1.00244],
#   [datetime.datetime(2018, 3, 22, 19, 47), 0.995916],
#   [datetime.datetime(2018, 3, 23, 13, 47), 0.986446]],
#  'nem': [[datetime.datetime(2018, 3, 13, 19, 47), 1.07033],
#   [datetime.datetime(2018, 3, 14, 19, 47), 1.08461],
#   [datetime.datetime(2018, 3, 15, 19, 47), 0.96692],
#   [datetime.datetime(2018, 3, 16, 19, 47), 0.903337],
#   [datetime.datetime(2018, 3, 17, 19, 47), 0.815196],
#   [datetime.datetime(2018, 3, 18, 19, 47), 0.762366],
#   [datetime.datetime(2018, 3, 19, 19, 47), 0.800005],
#   [datetime.datetime(2018, 3, 20, 19, 47), 0.801425],
#   [datetime.datetime(2018, 3, 21, 19, 47), 0.760911],
#   [datetime.datetime(2018, 3, 22, 19, 47), 0.784738],
#   [datetime.datetime(2018, 3, 23, 13, 47), 0.764203]],
#  'neo': [[datetime.datetime(2018, 3, 13, 19, 47), 1.4541],
#   [datetime.datetime(2018, 3, 14, 19, 47), 1.39466],
#   [datetime.datetime(2018, 3, 15, 19, 47), 1.37307],
#   [datetime.datetime(2018, 3, 16, 19, 47), 1.3595],
#   [datetime.datetime(2018, 3, 17, 19, 47), 1.32418],
#   [datetime.datetime(2018, 3, 18, 19, 47), 1.30098],
#   [datetime.datetime(2018, 3, 19, 19, 47), 1.35207],
#   [datetime.datetime(2018, 3, 20, 19, 47), 1.45304],
#   [datetime.datetime(2018, 3, 21, 19, 47), 1.38356],
#   [datetime.datetime(2018, 3, 22, 19, 47), 1.37768],
#   [datetime.datetime(2018, 3, 23, 13, 47), 1.30755]],
#  'others': [[datetime.datetime(2018, 3, 13, 19, 47), 18.377556999999996],
#   [datetime.datetime(2018, 3, 14, 19, 47), 18.393637999999996],
#   [datetime.datetime(2018, 3, 15, 19, 47), 18.032228000000003],
#   [datetime.datetime(2018, 3, 16, 19, 47), 18.185299000000015],
#   [datetime.datetime(2018, 3, 17, 19, 47), 17.814623999999995],
#   [datetime.datetime(2018, 3, 18, 19, 47), 17.22251700000001],
#   [datetime.datetime(2018, 3, 19, 19, 47), 18.151572],
#   [datetime.datetime(2018, 3, 20, 19, 47), 18.746115000000003],
#   [datetime.datetime(2018, 3, 21, 19, 47), 19.31056200000002],
#   [datetime.datetime(2018, 3, 22, 19, 47), 19.318855],
#   [datetime.datetime(2018, 3, 23, 13, 47), 19.296770999999993]],
#  'ripple': [[datetime.datetime(2018, 3, 13, 19, 47), 8.27975],
#   [datetime.datetime(2018, 3, 14, 19, 47), 8.29421],
#   [datetime.datetime(2018, 3, 15, 19, 47), 8.1823],
#   [datetime.datetime(2018, 3, 16, 19, 47), 8.0868],
#   [datetime.datetime(2018, 3, 17, 19, 47), 8.03415],
#   [datetime.datetime(2018, 3, 18, 19, 47), 7.9868],
#   [datetime.datetime(2018, 3, 19, 19, 47), 8.3234],
#   [datetime.datetime(2018, 3, 20, 19, 47), 8.10644],
#   [datetime.datetime(2018, 3, 21, 19, 47), 7.77338],
#   [datetime.datetime(2018, 3, 22, 19, 47), 7.7361],
#   [datetime.datetime(2018, 3, 23, 13, 47), 7.61874]]}

# %% [markdown]
# _________________________________
#
# ## Utils
# #### `convert(value, currency_in, currency_out)`
# This method converts the value passed as first parameter as price of the `currency_in` currency to price of the `currency_out` parameter. Works as [coinmarketcap criptocurrencies calculator](https://coinmarketcap.com/calculator/). For example, if you want to converts $100€$ to dolars, use:

# %%
cmc.convert(100, "EUR", "USD")
# Out:
# 123.30486634985536

# %% [markdown]
# For get all the currencies supported by this method (all currencies; fiat + crypto):

# %%
cmc.currencies_to_convert
# Out:
# ['$$$',
#  '$PAC',
#  '1337',
#  '1ST',
#  '1WO',
#  '2GIVE',
#  '300',
#  '42',
#  '611',
#  '808',
#  '888',
#  '8BIT',
#  'AAC',
#  'ABC',
#  'ABJ',
#  'ABN',
#  'ABT',
#  'ABY',
#  'AC',
#  'ACAT',
#  'ACC',
#  'ACC',
#  'ACC',
#  'ACE',
#  'ACES',
#  'ACN',
#  'ACOIN',
#  'ACP',
#  'ACT',
#  'ADA',
#  'ADB',
#  'ADC',
#  'ADCN',
#  'ADK',
#  'ADST',
#  'ADT',
#  'ADX',
#  'ADZ',
#  'AE',
#  'AEON',
#  'AERM',
#  'AGI',
#  'AHT',
#  'AI',
#  'AIB',
#  'AID',
#  'AIDOC',
#  'AION',
#  'AIR',
#  'AIT',
#  'AIX',
#  'AKY',
#  'ALIS',
#  'ALL',
#  'ALQO',
#  'ALT',
#  'ALTC',
#  'ALTCOM',
#  'AMB',
#  'AMBER',
#  'AMM',
#  'AMMO',
#  'AMP',
#  'AMS',
#  'ANC',
#  'ANI',
#  'ANT',
#  'ANTI',
#  'ANTX',
#  'APC',
#  'APPC',
#  'APX',
#  'ARB',
#  'ARC',
#  'ARCO',
#  'ARCT',
#  'ARDR',
#  'ARG',
#  'ARGUS',
#  'ARI',
#  'ARK',
#  'ARN',
#  'ART',
#  'ARY',
#  'ASAFE2',
#  'ASN',
#  'AST',
#  'ASTRO',
#  'ATB',
#  'ATL',
#  'ATM',
#  'ATMC',
#  'ATMS',
#  'ATN',
#  'ATOM',
#  'ATS',
#  'ATX',
#  'AU',
#  'AUD',
#  'AUR',
#  'AURA',
#  'AUTO',
#  'AV',
#  'AVH',
#  'AVT',
#  'AWR',
#  'AXIOM',
#  'AXP',
#  'B2B',
#  'B2X',
#  'B@',
#  'BAC',
#  'BANCA',
#  'BAR',
#  'BAS',
#  'BASH',
#  'BAT',
#  'BAT',
#  'BAX',
#  'BAY',
#  'BBN',
#  'BBP',
#  'BBR',
#  'BBT',
#  'BCA',
#  'BCC',
#  'BCD',
#  'BCDN',
#  'BCF',
#  'BCH',
#  'BCH',
#  'BCN',
#  'BCO',
#  'BCPT',
#  'BCX',
#  'BCY',
#  'BDG',
#  'BDL',
#  'BEE',
#  'BELA',
#  'BENJI',
#  'BERN',
#  'BEST',
#  'BET',
#  'BET',
#  'BEZ',
#  'BFT',
#  'BIG',
#  'BIGUP',
#  'BIO',
#  'BIOB',
#  'BIOS',
#  'BIP',
#  'BIRDS',
#  'BIS',
#  'BIT',
#  'BITB',
#  'BITBTC',
#  'BITCF',
#  'BITCNY',
#  'BITEUR',
#  'BITG',
#  'BITGOLD',
#  'BITOK',
#  'BITS',
#  'BITSILVER',
#  'BITUSD',
#  'BITZ',
#  'BIX',
#  'BKX',
#  'BLAZR',
#  'BLC',
#  'BLITZ',
#  'BLK',
#  'BLN',
#  'BLOCK',
#  'BLOCKPAY',
#  'BLRY',
#  'BLT',
#  'BLU',
#  'BLUE',
#  'BLZ',
#  'BLZ',
#  'BMC',
#  'BNB',
#  'BNT',
#  'BNTY',
#  'BNX',
#  'BOAT',
#  'BOLI',
#  'BON',
#  'BOS',
#  'BOST',
#  'BOT',
#  'BPC',
#  'BPL',
#  'BPT',
#  'BQ',
#  'BRAIN',
#  'BRAT',
#  'BRD',
#  'BRIA',
#  'BRIT',
#  'BRK',
#  'BRL',
#  'BRO',
#  'BRX',
#  'BSC',
#  'BSD',
#  'BSN',
#  'BSR',
#  'BSTAR',
#  'BSTY',
#  'BT2',
#  'BTA',
#  'BTB',
#  'BTBc',
#  'BTC',
#  'BTC',
#  'BTCA',
#  'BTCD',
#  'BTCM',
#  'BTCP',
#  'BTCR',
#  'BTCRED',
#  'BTCS',
#  'BTCZ',
#  'BTDX',
#  'BTE',
#  'BTG',
#  'BTG',
#  'BTM',
#  'BTM',
#  'BTO',
#  'BTPL',
#  'BTQ',
#  'BTS',
#  'BTW',
#  'BTWTY',
#  'BTX',
#  'BUB',
#  'BUCKS',
#  'BUMBA',
#  'BUN',
#  'BURST',
#  'BUZZ',
#  'BWK',
#  'BXC',
#  'BXT',
#  'BYC',
#  'C2',
#  'C20',
#  'CAB',
#  'CACH',
#  'CAD',
#  'CAG',
#  'CALC',
#  'CAN',
#  'CAN',
#  'CANDY',
#  'CANN',
#  'CAPP',
#  'CARBON',
#  'CAS',
#  'CASH',
#  'CAT',
#  'CAT',
#  'CAT',
#  'CBX',
#  'CC',
#  'CCM100',
#  'CCN',
#  'CCO',
#  'CCRB',
#  'CCT',
#  'CDN',
#  'CDT',
#  'CDX',
#  'CEFS',
#  'CENNZ',
#  'CESC',
#  'CF',
#  'CFC',
#  'CFD',
#  'CFI',
#  'CFT',
#  'CFUN',
#  'CHAN',
#  'CHAT',
#  'CHC',
#  'CHEAP',
#  'CHESS',
#  'CHF',
#  'CHIPS',
#  'CHP',
#  'CHSB',
#  'CJ',
#  'CL',
#  'CLAM',
#  'CLD',
#  'CLOAK',
#  'CLP',
#  'CLUB',
#  'CME',
#  'CMP',
#  'CMPCO',
#  'CMS',
#  'CMS',
#  'CMT',
#  'CMT',
#  'CND',
#  'CNNC',
#  'CNO',
#  'CNT',
#  'CNX',
#  'CNY',
#  'COAL',
#  'COB',
#  'COFI',
#  'COLX',
#  'CON',
#  'CONX',
#  'COR',
#  'COSS',
#  'COUPE',
#  'COV',
#  'COVAL',
#  'COXST',
#  'CPAY',
#  'CPC',
#  'CPC',
#  'CPN',
#  'CPY',
#  'CRAVE',
#  'CRB',
#  'CRC',
#  'CRDNC',
#  'CREA',
#  'CRED',
#  'CREDO',
#  'CREVA',
#  'CRM',
#  'CRPT',
#  'CRT',
#  'CRW',
#  'CRX',
#  'CRYPT',
#  'CS',
#  'CSC',
#  'CSNO',
#  'CTIC2',
#  'CTIC3',
#  'CTO',
#  'CTR',
#  'CTX',
#  'CUBE',
#  'CURE',
#  'CV',
#  'CV2',
#  'CVC',
#  'CVCOIN',
#  'CWXT',
#  'CXO',
#  'CXT',
#  'CYC',
#  'CYDER',
#  'CYP',
#  'CZK',
#  'DADI',
#  'DAI',
#  'DALC',
#  'DAR',
#  'DASH',
#  'DASHS',
#  'DAT',
#  'DATA',
#  'DATX',
#  'DAV',
#  'DAXX',
#  'DAY',
#  'DBC',
#  'DBET',
#  'DBG',
#  'DBIX',
#  'DBTC',
#  'DCN',
#  'DCR',
#  'DCRE',
#  'DCT',
#  'DCY',
#  'DDD',
#  'DDF',
#  'DEB',
#  'DEM',
#  'DENT',
#  'DES',
#  'DEUS',
#  'DEW',
#  'DFS',
#  'DFT',
#  'DGB',
#  'DGC',
#  'DGCS',
#  'DGD',
#  'DGPT',
#  'DIBC',
#  'DICE',
#  'DIM',
#  'DIME',
#  'DISK',
#  'DIVX',
#  'DIX',
#  'DKK',
#  'DLC',
#  'DLISK',
#  'DLT',
#  'DMB',
#  'DMC',
#  'DMD',
#  'DMT',
#  'DNA',
#  'DNR',
#  'DNT',
#  'DOGE',
#  'DOLLAR',
#  'DON',
#  'DOPE',
#  'DOT',
#  'DOVU',
#  'DP',
#  'DPY',
#  'DRG',
#  'DRGN',
#  'DRM',
#  'DROP',
#  'DRP',
#  'DRPU',
#  'DRS',
#  'DRT',
#  'DRXNE',
#  'DSH',
#  'DSR',
#  'DTA',
#  'DTB',
#  'DTC',
#  'DTH',
#  'DTR',
#  'DUB',
#  'DUO',
#  'DUTCH',
#  'DXT',
#  'DYN',
#  'EAC',
#  'EAG',
#  'EAGLE',
#  'EBCH',
#  'EBET',
#  'EBST',
#  'EBT',
#  'EBTC',
#  'ECA',
#  'ECASH',
#  'ECC',
#  'ECH',
#  'ECN',
#  'ECO',
#  'ECOB',
#  'EDG',
#  'EDO',
#  'EDR',
#  'EDRC',
#  'EFL',
#  'EFYT',
#  'EGC',
#  'EGG',
#  'EGO',
#  'EGOLD',
#  'EKO',
#  'EKT',
#  'EL',
#  'ELA',
#  'ELC',
#  'ELE',
#  'ELEC',
#  'ELF',
#  'ELITE',
#  'ELIX',
#  'ELLA',
#  'ELS',
#  'ELTCOIN',
#  'EMC',
#  'EMC2',
#  'EMD',
#  'EMV',
#  'ENG',
#  'ENJ',
#  'ENRG',
#  'ENT',
#  'ENT',
#  'EOS',
#  'EOT',
#  'EPC',
#  'EPY',
#  'EQL',
#  'EQT',
#  'ERA',
#  'ERC',
#  'ERC20',
#  'ERO',
#  'ERY',
#  'ESC',
#  'ESP',
#  'ESZ',
#  'ETBS',
#  'ETC',
#  'ETG',
#  'ETH',
#  'ETH',
#  'ETHD',
#  'ETHOS',
#  'ETN',
#  'ETP',
#  'ETT',
#  'ETT',
#  'EUC',
#  'EUR',
#  'EVC',
#  'EVE',
#  'EVIL',
#  'EVN',
#  'EVO',
#  'EVR',
#  'EVX',
#  'EXCL',
#  'EXN',
#  'EXP',
#  'EXRN',
#  'EXY',
#  'EZT',
#  'FAIR',
#  'FAIR',
#  'FAP',
#  'FAZZ',
#  'FC2',
#  'FCN',
#  'FCT',
#  'FDX',
#  'FID',
#  'FIL',
#  'FIMK',
#  'FIRE',
#  'FJC',
#  'FLAP',
#  'FLASH',
#  'FLAX',
#  'FLDC',
#  'FLIK',
#  'FLIXX',
#  'FLO',
#  'FLT',
#  'FLUZ',
#  'FLY',
#  'FNC',
#  'FONZ',
#  'FOR',
#  'FOTA',
#  'FRC',
#  'FRCT',
#  'FRD',
#  'FRGC',
#  'FRK',
#  'FRN',
#  'FRST',
#  'FRWC',
#  'FSN',
#  'FST',
#  'FTC',
#  'FUCK',
#  'FUEL',
#  'FUN',
#  'FUNC',
#  'FUTC',
#  'FUZZ',
#  'FXE',
#  'FYN',
#  'FYP',
#  'G3N',
#  'GAIA',
#  'GAIN',
#  'GAM',
#  'GAME',
#  'GAP',
#  'GARY',
#  'GAS',
#  'GAT',
#  'GAY',
#  'GB',
#  'GBC',
#  'GBG',
#  'GBP',
#  'GBX',
#  'GBYTE',
#  'GCC',
#  'GCC',
#  'GCN',
#  'GCR',
#  'GCS',
#  'GDC',
#  'GEERT',
#  'GEM',
#  'GEO',
#  'GET',
#  'GETX',
#  'GJC',
#  'GLA',
#  'GLC',
#  'GLD',
#  'GLS',
#  'GLT',
#  'GML',
#  'GMT',
#  'GMX',
#  'GNO',
#  'GNT',
#  'GNX',
#  'GOD',
#  'GOLF',
#  'GOLOS',
#  'GOOD',
#  'GP',
#  'GPL',
#  'GPU',
#  'GRC',
#  'GRE',
#  'GRFT',
#  'GRID',
#  'GRIM',
#  'GRLC',
#  'GRN',
#  'GRS',
#  'GRWI',
#  'GRX',
#  'GSR',
#  'GTC',
#  'GTC',
#  'GTO',
#  'GUESS',
#  'GUN',
#  'GUP',
#  'GVT',
#  'GXS',
#  'HAC',
#  'HAL',
#  'HALLO',
#  'HAT',
#  'HAV',
#  'HBC',
#  'HBN',
#  'HBT',
#  'HC',
#  'HCC',
#  'HDG',
#  'HDLB',
#  'HEAT',
#  'HERO',
#  'HGT',
#  'HIGH',
#  'HIRE',
#  'HKD',
#  'HKN',
#  'HLC',
#  'HMC',
#  'HMC',
#  'HMP',
#  'HMQ',
#  'HNC',
#  'HNC',
#  'HODL',
#  'HOLD',
#  'HONEY',
#  'HORSE',
#  'HOT',
#  'HPB',
#  'HPC',
#  'HPY',
#  'HQX',
#  'HSR',
#  'HST',
#  'HT',
#  'HTC',
#  'HTML',
#  'HUC',
#  'HUF',
#  'HUSH',
#  'HVCO',
#  'HVN',
#  'HWC',
#  'HXX',
#  'HYP',
#  'HYPER',
#  'I0C',
#  'IBANK',
#  'IC',
#  'ICE',
#  'ICN',
#  'ICN',
#  'ICOB',
#  'ICON',
#  'ICOO',
#  'ICOS',
#  'ICX',
#  'IDH',
#  'IDR',
#  'IDT',
#  'IDXM',
#  'IETH',
#  'IFC',
#  'IFLT',
#  'IFT',
#  'IGNIS',
#  'IHT',
#  'ILS',
#  'IMPS',
#  'IMS',
#  'IMX',
#  'INCNT',
#  'IND',
#  'INDI',
#  'INDIA',
#  'INF',
#  'INFX',
#  'ING',
#  'INK',
#  'INN',
#  'INPAY',
#  'INR',
#  'INS',
#  'INSN',
#  'INSTAR',
#  'INT',
#  'INXT',
#  'IOC',
#  'ION',
#  'IOP',
#  'IOST',
#  'IPBC',
#  'IPC',
#  'IPL',
#  'IQT',
#  'IRL',
#  'ISL',
#  'ITC',
#  'ITI',
#  'ITNS',
#  'ITT',
#  'IVZ',
#  'IXC',
#  'IXT',
#  'J',
#  'J8T',
#  'JC',
#  'JET',
#  'JEW',
#  'JIN',
#  'JIYO',
#  'JNT',
#  'JOBS',
#  'JPY',
#  'JS',
#  'JWL',
#  'KARMA',
#  'KASHH',
#  'KAYI',
#  'KB3',
#  'KBR',
#  'KCASH',
#  'KCS',
#  'KDC',
#  'KED',
#  'KEK',
#  'KEY',
#  'KICK',
#  'KIN',
#  'KLC',
#  'KLN',
#  'KMD',
#  'KNC',
#  'KNC',
#  'KOBO',
#  'KORE',
#  'KRB',
#  'KRM',
#  'KRONE',
#  'KRW',
#  'KURT',
#  'KUSH',
#  'KZC',
#  'LA',
#  'LALA',
#  'LANA',
#  'LATX',
#  'LAZ',
#  'LBC',
#  'LBTC',
#  'LBTC',
#  'LCC',
#  'LCP',
#  'LCT',
#  'LDC',
#  'LDCN',
#  'LDOGE',
#  'LEA',
#  'LEAF',
#  'LEDU',
#  'LEND',
#  'LEO',
#  'LEPEN',
#  'LET',
#  'LEV',
#  'LEVO',
#  'LGD',
#  'LGO',
#  'LIFE',
#  'LIGHT',
#  'LINDA',
#  'LINK',
#  'LINX',
#  'LIR',
#  'LKC',
#  'LKK',
#  'LLT',
#  'LMC',
#  'LNK',
#  'LOC',
#  'LOCI',
#  'LOG',
#  'LOOM',
#  'LRC',
#  'LSK',
#  'LTB',
#  'LTC',
#  'LTC',
#  'LTCR',
#  'LTCU',
#  'LTH',
#  'LUN',
#  'LUNA',
#  'LUX',
#  'LVPS',
#  'LYM',
#  'MAC',
#  'MAD',
#  'MAG',
#  'MAG',
#  'MAGE',
#  'MAGN',
#  'MAID',
#  'MAN',
#  'MANA',
#  'MANNA',
#  'MAO',
#  'MAR',
#  'MARS',
#  'MARX',
#  'MAX',
#  'MAY',
#  'MBI',
#  'MBL',
#  'MBRS',
#  'MCAP',
#  'MCI',
#  'MCO',
#  'MCR',
#  'MCRN',
#  'MDA',
#  'MDC',
#  'MDS',
#  'MDT',
#  'MEC',
#  'MED',
#  'MEDIC',
#  'MEE',
#  'MEME',
#  'MER',
#  'METAL',
#  'MGC',
#  'MGM',
#  'MGO',
#  'MILO',
#  'MINEX',
#  'MINT',
#  'MIOTA',
#  'MKR',
#  'MLM',
#  'MLN',
#  'MMXVI',
#  'MNC',
#  'MND',
#  'MNE',
#  'MNM',
#  'MNTP',
#  'MNX',
#  'MOAC',
#  'MOBI',
#  'MOD',
#  'MOF',
#  'MOIN',
#  'MOJO',
#  'MONA',
#  'MONETA',
#  'MONK',
#  'MOON',
#  'MOT',
#  'MOTO',
#  'MRJA',
#  'MRT',
#  'MSCN',
#  'MSD',
#  'MSP',
#  'MST',
#  'MTH',
#  'MTL',
#  'MTLMC3',
#  'MTN',
#  'MTNC',
#  'MTX',
#  'MUE',
#  'MUSE',
#  'MUSIC',
#  'MVC',
#  'MWAT',
#  'MXN',
#  'MXT',
#  'MYB',
#  'MYR',
#  'MYST',
#  'MZC',
#  'NAMO',
#  'NANJ',
#  'NANO',
#  'NANOX',
#  'NAS',
#  'NAV',
#  'NBIT',
#  'NCASH',
#  'NDC',
#  'NEBL',
#  'NEO',
#  'NEOG',
#  'NEOS',
#  'NET',
#  'NET',
#  'NETKO',
#  'NEU',
#  'NEVA',
#  'NEWB',
#  'NGC',
#  'NIO',
#  'NKA',
#  'NKC',
#  'NLC2',
#  'NLG',
#  'NMC',
#  'NMR',
#  'NMS',
#  'NOAH',
#  'NOBL',
#  'NODC',
#  'NOK',
#  'NOTE',
#  'NOX',
#  'NPX',
#  'NPXS',
#  'NRO',
#  'NSR',
#  'NTC',
#  'NTK',
#  'NTO',
#  'NTRN',
#  'NTWK',
#  'NUKO',
#  'NULS',
#  'NUMUS',
#  'NVC',
#  'NVST',
#  'NXC',
#  'NXS',
#  'NXT',
#  'NYAN',
#  'NYC',
#  'NZD',
#  'OAX',
#  'OBITS',
#  'OC',
#  'OCC',
#  'OCL',
#  'OCN',
#  'OCOW',
#  'OCT',
#  'ODN',
#  ...]

# %%
show_page("calculator")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/calculator"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `download_logo(name, [size=128, filename=None])`
# Download a currency image logo in `.png` format. Valid sizes are: `[16, 32, 64, 128, 200]`.

# %%
filename = cmc.download_logo("BTC", size=200)

from IPython.display import Image
Image(filename)

# %%
import os
try:
    os.remove(filename)
except FileNotFoundError:
    pass

# %% [markdown]
# _____________________________
#
# ## Catching HTTP errors
# You can use the nexts class in order to catch some HTTP error:

# %%
from pymarketcap import (
    CoinmarketcapError,      # This class is the parent of all
    CoinmarketcapHTTPError,
    CoinmarketcapTooManyRequestsError
)

# %% [markdown]
# You could prevent errors like this
#
#
# ![error](images/http_error.png)

# %% [markdown]
# This only happens with `Pymarketcap` class. In asynchronous interface, failed requests will be restarted in a queue.
