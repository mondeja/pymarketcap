# %% [markdown]
# # <center>Synchronous Pymarketcap Interface</center>
#
# > See also: [Asynchronous Pymarketcap Scraper](async_live.ipynb)

# %%
from IPython.display import IFrame
show_page = lambda endpoint: IFrame("https://coinmarketcap.com/%s" % endpoint, "100%", 400)

# %% [markdown]
# ## Basic usage
#
# #### `Pymarketcap([timeout=20, debug=False, cache=True])`
#
# The first response takes a long time because some data is cached at instantiation of the wrapper.

# %%
from pymarketcap import Pymarketcap
cmc = Pymarketcap(timeout=10)

cmc.exchanges()
# Out:
# [{'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BitMEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Nano',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Nucleus Vision',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'VeChain',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'NEO',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'BlockMason Credit Protocol',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Binance'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'EOS',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'OKEx'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Cardano',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'NEO',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Qtum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Ripple',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Status',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Upbit'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'EOS',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'NEO',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Bitfinex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ripple',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Qtum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'EOS',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Monero',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Bithumb'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Elastos',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Huobi Token',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Huobi Token',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Huobi Token',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'TRON',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Elastos',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'TRON',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Huobi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'GDAX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Ripple',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Kraken'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'ZClassic',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Cardano',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'NEO',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'BlockMason Credit Protocol',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'ReddCoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Bean Cash',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Bittrex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Bitstamp'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Dash',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'W3Coin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Zcash',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Ripple',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'HitBTC'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'}],
#   'name': 'bitFlyer'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'EDUCare',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'TRON',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ink',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Ink',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Hshare',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Lisk',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Bit-Z'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEM',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'COMSA [ETH]',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Counterparty',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'COMSA [XEM]',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'NEM',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Pepe Cash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Zaif'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'MonaCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'}],
#   'name': 'Fisco'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BTCBOX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ripple',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Monero',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Ripple',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Poloniex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Qtum',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'IOTA',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'}],
#   'name': 'Coinone'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'QASH',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'QASH',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Ripple',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Quoine'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEO',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'TRON',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Lisk',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Qtum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ruff',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Qbao',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Ripple',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Achain',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'CoinEgg'},
#  {'markets': [{'name': 'Hyper Pay',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ink',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Qtum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bodhi',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'EXX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'}],
#   'name': 'BTCC'},
#  {'markets': [{'name': 'ATMCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'ATMCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'ATMCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'ATMCoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Bits Blockchain'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Dash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Zcash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Dash',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'WEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'CoinsBank'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'}],
#   'name': 'Gemini'},
#  {'markets': [{'name': 'Bibox Token',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bibox Token',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Jibrel Network',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Bibox Token',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Jibrel Network',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Spectre.ai Utility Token',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Spectre.ai Utility Token',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Gifto',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Gifto',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'High Performance Blockchain',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Bibox'},
#  {'markets': [{'name': 'Zeepin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Revain',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Nano',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Revain',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'NEO',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Dent',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'VeChain',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'SingularityNET',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Kucoin'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'True Chain',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'BitShares',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'QunQun',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Qtum',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'ZB.COM'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ethereum',
# ...
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'CHIPS',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'ZClassic',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'}],
#   'name': 'BarterDEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'}],
#   'name': 'Bit2C'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'}],
#   'name': 'Dgtmarket'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Vertcoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Peercoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Dash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Coingi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'BitKonan'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Rippex'},
#  {'markets': [{'name': 'NEM',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Lisk',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'PIVX',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Waves',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Dash',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Coinbe'},
#  {'markets': [{'name': 'HEAT',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bismuth',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Golem',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'FIMKrypto',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Elastic',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Elastic',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'HEAT',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Heat Wallet'},
#  {'markets': [{'name': 'Photon',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Blakecoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Photon',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'}],
#   'name': 'C-Patex'},
#  {'markets': [{'name': 'Anoncoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'WhiteCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Datacoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Freicoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'}],
#   'name': 'FreiExchange'},
#  {'markets': [{'name': 'E-Dinar Coin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'}],
#   'name': 'LocalTrade'},
#  {'markets': [{'name': 'Gulden',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'GuldenTrader'},
#  {'markets': [{'name': 'Ethereum Movie Venture',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Golem',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Lunyr',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'SingularDTV',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'TokenCard',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Swarm City',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Etheroll',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Melon',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.22,
#     'price': 867.341,
#     'volume': 64682500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Numeraire',
#     'pair': 'NEO/BTC',
#     'perc_volume': 3.1,
#     'price': 134.176,
#     'volume': 62386500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'},
#    {'name': 'Edgeless',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.01,
#     'price': 220.79,
#     'volume': 60563100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'CryptoDerivatives'},
#  {'markets': [{'name': 'Centurion',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ExcambrioRex'},
#  {'markets': [{'name': 'LEOcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'LEOcoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'LEOcoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'LEOcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.17,
#     'price': 869.579,
#     'volume': 104057000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 4.82,
#     'price': 219.986,
#     'volume': 97016800.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.63337,
#     'volume': 92189500.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'LEOxChange'},
#  {'markets': [{'name': 'YashCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'SACoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'DC-Ex'},
#  {'markets': [{'name': 'Auroracoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ISX'},
#  {'markets': [{'name': 'CRTCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.17,
#     'price': 14.1107,
#     'volume': 124041000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 6.08,
#     'price': 0.0399456,
#     'volume': 122330000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'}],
#   'name': 'NIX-E'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'CoinCorner'},
#  {'markets': [{'name': 'CCMiner',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'SnakeEyes',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'Burst Asset Exchange'},
#  {'markets': [{'name': 'MaidSafeCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Omni DEX'},
#  {'markets': [{'name': 'Virtacoinplus',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10339.0,
#     'volume': 2726120000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Virtacoinplus',
#     'pair': 'BTC/USDT',
#     'perc_volume': 17.21,
#     'price': 10335.0,
#     'volume': 346170000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'VirtacoinWorld'}]

# %% [markdown]
# > All methods are self explained in docstrings:

# %%
print(cmc.exchanges.__doc__)
# Out:
# Get all the exchanges in coinmarketcap ranked by volumes
#         along with other metadata.
#
#         Args:
#             convert (str, optional): Convert volumes and prices
#                 between USD and BTC. As default ``"USD"``.
#
#         Returns (list):
#             Exchanges with markets and other data included.

# %% [markdown]
# ___________________________________
#
# ## Coinmarketcap API

# %%
show_page("api")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/api"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `ticker(currency=None, limit=0, start=0, convert="USD")`
# If `currency == None`, you will obtain data for all currencies in coinmarketcap:

# %%
cmc.ticker()
# Out:
# [{'24h_volume_usd': 7289990000.0,
#   'available_supply': 16888112.0,
#   'id': 'bitcoin',
#   'last_updated': 1519683567,
#   'market_cap_usd': 175768092074,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin',
#   'percent_change_1h': 0.26,
#   'percent_change_24h': 7.4,
#   'percent_change_7d': -7.77,
#   'price_btc': 1.0,
#   'price_usd': 10407.8,
#   'rank': 1,
#   'symbol': 'BTC',
#   'total_supply': 16888112.0},
#  {'24h_volume_usd': 2038640000.0,
#   'available_supply': 97862983.0,
#   'id': 'ethereum',
#   'last_updated': 1519683552,
#   'market_cap_usd': 85065146770.0,
#   'max_supply': None,
#   'name': 'Ethereum',
#   'percent_change_1h': -0.09,
#   'percent_change_24h': 2.73,
#   'percent_change_7d': -8.28,
#   'price_btc': 0.0840529,
#   'price_usd': 869.227,
#   'rank': 2,
#   'symbol': 'ETH',
#   'total_supply': 97862983.0},
#  {'24h_volume_usd': 464191000.0,
#   'available_supply': 39094802192.0,
#   'id': 'ripple',
#   'last_updated': 1519683541,
#   'market_cap_usd': 37400863508.0,
#   'max_supply': 100000000000,
#   'name': 'Ripple',
#   'percent_change_1h': -0.16,
#   'percent_change_24h': 1.1,
#   'percent_change_7d': -16.5,
#   'price_btc': 9.251e-05,
#   'price_usd': 0.956671,
#   'rank': 3,
#   'symbol': 'XRP',
#   'total_supply': 99992622540.0},
#  {'24h_volume_usd': 461810000.0,
#   'available_supply': 16989200.0,
#   'id': 'bitcoin-cash',
#   'last_updated': 1519683552,
#   'market_cap_usd': 21364598568.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Cash',
#   'percent_change_1h': -0.02,
#   'percent_change_24h': 6.48,
#   'percent_change_7d': -18.21,
#   'price_btc': 0.121603,
#   'price_usd': 1257.54,
#   'rank': 4,
#   'symbol': 'BCH',
#   'total_supply': 16989200.0},
#  {'24h_volume_usd': 1344070000.0,
#   'available_supply': 55393858.0,
#   'id': 'litecoin',
#   'last_updated': 1519683540,
#   'market_cap_usd': 12332500822.0,
#   'max_supply': 84000000.0,
#   'name': 'Litecoin',
#   'percent_change_1h': -0.95,
#   'percent_change_24h': 0.5,
#   'percent_change_7d': -0.79,
#   'price_btc': 0.0215283,
#   'price_usd': 222.633,
#   'rank': 5,
#   'symbol': 'LTC',
#   'total_supply': 55393858.0},
#  {'24h_volume_usd': 232525000.0,
#   'available_supply': 25927070538.0,
#   'id': 'cardano',
#   'last_updated': 1519683554,
#   'market_cap_usd': 8855416869.0,
#   'max_supply': 45000000000.0,
#   'name': 'Cardano',
#   'percent_change_1h': -0.27,
#   'percent_change_24h': -1.16,
#   'percent_change_7d': -12.64,
#   'price_btc': 3.303e-05,
#   'price_usd': 0.341551,
#   'rank': 6,
#   'symbol': 'ADA',
#   'total_supply': 31112483745.0},
#  {'24h_volume_usd': 385461000.0,
#   'available_supply': 65000000.0,
#   'id': 'neo',
#   'last_updated': 1519683547,
#   'market_cap_usd': 8828885000.0,
#   'max_supply': None,
#   'name': 'NEO',
#   'percent_change_1h': 0.82,
#   'percent_change_24h': 14.12,
#   'percent_change_7d': -1.58,
#   'price_btc': 0.0131345,
#   'price_usd': 135.829,
#   'rank': 7,
#   'symbol': 'NEO',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 46523000.0,
#   'available_supply': 18467835330.0,
#   'id': 'stellar',
#   'last_updated': 1519683543,
#   'market_cap_usd': 6771231824.0,
#   'max_supply': None,
#   'name': 'Stellar',
#   'percent_change_1h': 0.0,
#   'percent_change_24h': 2.78,
#   'percent_change_7d': -18.75,
#   'price_btc': 3.545e-05,
#   'price_usd': 0.36665,
#   'rank': 8,
#   'symbol': 'XLM',
#   'total_supply': 103708899665},
#  {'24h_volume_usd': 252992000.0,
#   'available_supply': 694428784.0,
#   'id': 'eos',
#   'last_updated': 1519683551,
#   'market_cap_usd': 5729731899.0,
#   'max_supply': 1000000000.0,
#   'name': 'EOS',
#   'percent_change_1h': -0.02,
#   'percent_change_24h': 4.08,
#   'percent_change_7d': -15.32,
#   'price_btc': 0.00079786,
#   'price_usd': 8.251,
#   'rank': 9,
#   'symbol': 'EOS',
#   'total_supply': 900000000.0},
#  {'24h_volume_usd': 44962500.0,
#   'available_supply': 2779530283.0,
#   'id': 'iota',
#   'last_updated': 1519683550,
#   'market_cap_usd': 5229630637.0,
#   'max_supply': 2779530283.0,
#   'name': 'IOTA',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': 3.49,
#   'percent_change_7d': -10.24,
#   'price_btc': 0.00018194,
#   'price_usd': 1.88148,
#   'rank': 10,
#   'symbol': 'MIOTA',
#   'total_supply': 2779530283.0},
#  {'24h_volume_usd': 74281300.0,
#   'available_supply': 7908100.0,
#   'id': 'dash',
#   'last_updated': 1519683541,
#   'market_cap_usd': 4932977975.0,
#   'max_supply': 18900000.0,
#   'name': 'Dash',
#   'percent_change_1h': -0.3,
#   'percent_change_24h': 5.04,
#   'percent_change_7d': -14.36,
#   'price_btc': 0.0603194,
#   'price_usd': 623.788,
#   'rank': 11,
#   'symbol': 'DASH',
#   'total_supply': 7908100.0},
#  {'24h_volume_usd': 53549500.0,
#   'available_supply': 15766175.0,
#   'id': 'monero',
#   'last_updated': 1519683542,
#   'market_cap_usd': 4703176031.0,
#   'max_supply': None,
#   'name': 'Monero',
#   'percent_change_1h': 1.0,
#   'percent_change_24h': 6.24,
#   'percent_change_7d': -5.86,
#   'price_btc': 0.0288459,
#   'price_usd': 298.308,
#   'rank': 12,
#   'symbol': 'XMR',
#   'total_supply': 15766175.0},
#  {'24h_volume_usd': 18079000.0,
#   'available_supply': 8999999999.0,
#   'id': 'nem',
#   'last_updated': 1519683544,
#   'market_cap_usd': 3642228000.0,
#   'max_supply': None,
#   'name': 'NEM',
#   'percent_change_1h': -0.01,
#   'percent_change_24h': 1.49,
#   'percent_change_7d': -22.88,
#   'price_btc': 3.913e-05,
#   'price_usd': 0.404692,
#   'rank': 13,
#   'symbol': 'XEM',
#   'total_supply': 8999999999.0},
#  {'24h_volume_usd': 651813000.0,
#   'available_supply': 100142650.0,
#   'id': 'ethereum-classic',
#   'last_updated': 1519683547,
#   'market_cap_usd': 3640025099.0,
#   'max_supply': None,
#   'name': 'Ethereum Classic',
#   'percent_change_1h': -1.34,
#   'percent_change_24h': -0.43,
#   'percent_change_7d': -10.61,
#   'price_btc': 0.00351484,
#   'price_usd': 36.3484,
#   'rank': 14,
#   'symbol': 'ETC',
#   'total_supply': 100142650.0},
#  {'24h_volume_usd': 194268000.0,
#   'available_supply': 65748192475.0,
#   'id': 'tron',
#   'last_updated': 1519683553,
#   'market_cap_usd': 2763021765.0,
#   'max_supply': None,
#   'name': 'TRON',
#   'percent_change_1h': -0.04,
#   'percent_change_24h': 4.85,
#   'percent_change_7d': -18.51,
#   'price_btc': 4.06e-06,
#   'price_usd': 0.0420243,
#   'rank': 15,
#   'symbol': 'TRX',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 143007000.0,
#   'available_supply': 475255118.0,
#   'id': 'vechain',
#   'last_updated': 1519683553,
#   'market_cap_usd': 2668576496.0,
#   'max_supply': None,
#   'name': 'VeChain',
#   'percent_change_1h': -0.12,
#   'percent_change_24h': -4.63,
#   'percent_change_7d': -13.3,
#   'price_btc': 0.00054297,
#   'price_usd': 5.61504,
#   'rank': 16,
#   'symbol': 'VEN',
#   'total_supply': 873378637.0},
#  {'24h_volume_usd': 2375350000.0,
#   'available_supply': 2217140814.0,
#   'id': 'tether',
#   'last_updated': 1519683546,
#   'market_cap_usd': 2217717270.0,
#   'max_supply': None,
#   'name': 'Tether',
#   'percent_change_1h': 0.14,
#   'percent_change_24h': -0.17,
#   'percent_change_7d': 0.01,
#   'price_btc': 9.672e-05,
#   'price_usd': 1.00026,
#   'rank': 17,
#   'symbol': 'USDT',
#   'total_supply': 2280109970.0},
#  {'24h_volume_usd': 42291700.0,
#   'available_supply': 102267192.0,
#   'id': 'lisk',
#   'last_updated': 1519683546,
#   'market_cap_usd': 2146117933.0,
#   'max_supply': None,
#   'name': 'Lisk',
#   'percent_change_1h': -0.19,
#   'percent_change_24h': 4.55,
#   'percent_change_7d': -29.26,
#   'price_btc': 0.00202926,
#   'price_usd': 20.9854,
#   'rank': 18,
#   'symbol': 'LSK',
#   'total_supply': 118483972.0},
#  {'24h_volume_usd': 259232000.0,
#   'available_supply': 73910664.0,
#   'id': 'qtum',
#   'last_updated': 1519683550,
#   'market_cap_usd': 2142817971.0,
#   'max_supply': None,
#   'name': 'Qtum',
#   'percent_change_1h': -0.24,
#   'percent_change_24h': 11.69,
#   'percent_change_7d': -11.47,
#   'price_btc': 0.00280348,
#   'price_usd': 28.992,
#   'rank': 19,
#   'symbol': 'QTUM',
#   'total_supply': 100410664.0},
#  {'24h_volume_usd': 23742700.0,
#   'available_supply': 16848436.0,
#   'id': 'bitcoin-gold',
#   'last_updated': 1519683555,
#   'market_cap_usd': 2006581344.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcoin Gold',
#   'percent_change_1h': 0.41,
#   'percent_change_24h': 3.3,
#   'percent_change_7d': -14.53,
#   'price_btc': 0.0115164,
#   'price_usd': 119.096,
#   'rank': 20,
#   'symbol': 'BTG',
#   'total_supply': 16948436.0},
#  {'24h_volume_usd': 148974000.0,
#   'available_supply': 133248289.0,
#   'id': 'nano',
#   'last_updated': 1519683549,
#   'market_cap_usd': 1873084526.0,
#   'max_supply': 133248290.0,
#   'name': 'Nano',
#   'percent_change_1h': 2.28,
#   'percent_change_24h': 13.45,
#   'percent_change_7d': 63.83,
#   'price_btc': 0.0013593,
#   'price_usd': 14.0571,
#   'rank': 21,
#   'symbol': 'NANO',
#   'total_supply': 133248289.0},
#  {'24h_volume_usd': 37726500.0,
#   'available_supply': 102042552.0,
#   'id': 'omisego',
#   'last_updated': 1519683551,
#   'market_cap_usd': 1843459923.0,
#   'max_supply': None,
#   'name': 'OmiseGO',
#   'percent_change_1h': 0.62,
#   'percent_change_24h': 7.49,
#   'percent_change_7d': 0.55,
#   'price_btc': 0.00174691,
#   'price_usd': 18.0656,
#   'rank': 22,
#   'symbol': 'OMG',
#   'total_supply': 140245398.0},
#  {'24h_volume_usd': 57848900.0,
#   'available_supply': 385966364.0,
#   'id': 'icon',
#   'last_updated': 1519683555,
#   'market_cap_usd': 1564707640.0,
#   'max_supply': None,
#   'name': 'ICON',
#   'percent_change_1h': -0.16,
#   'percent_change_24h': 4.9,
#   'percent_change_7d': -15.35,
#   'price_btc': 0.00039202,
#   'price_usd': 4.054,
#   'rank': 23,
#   'symbol': 'ICX',
#   'total_supply': 400230000.0},
#  {'24h_volume_usd': 56284600.0,
#   'available_supply': 3365706.0,
#   'id': 'zcash',
#   'last_updated': 1519683547,
#   'market_cap_usd': 1373362972.0,
#   'max_supply': None,
#   'name': 'Zcash',
#   'percent_change_1h': -1.06,
#   'percent_change_24h': 3.95,
#   'percent_change_7d': -14.09,
#   'price_btc': 0.0394575,
#   'price_usd': 408.046,
#   'rank': 24,
#   'symbol': 'ZEC',
#   'total_supply': 3365706.0},
#  {'24h_volume_usd': 55309200.0,
#   'available_supply': 99014000.0,
#   'id': 'binance-coin',
#   'last_updated': 1519683552,
#   'market_cap_usd': 974046264.0,
#   'max_supply': None,
#   'name': 'Binance Coin',
#   'percent_change_1h': -0.26,
#   'percent_change_24h': 5.52,
#   'percent_change_7d': -11.25,
#   'price_btc': 0.00095127,
#   'price_usd': 9.83746,
#   'rank': 25,
#   'symbol': 'BNB',
#   'total_supply': 197192382.0},
#  {'24h_volume_usd': 813286.0,
#   'available_supply': 183751326077,
#   'id': 'bytecoin-bcn',
#   'last_updated': 1519683542,
#   'market_cap_usd': 906493067.0,
#   'max_supply': 184470000000,
#   'name': 'Bytecoin',
#   'percent_change_1h': -0.25,
#   'percent_change_24h': 8.57,
#   'percent_change_7d': -17.16,
#   'price_btc': 4.8e-07,
#   'price_usd': 0.00493326,
#   'rank': 26,
#   'symbol': 'BCN',
#   'total_supply': 183751326077},
#  {'24h_volume_usd': 17563400.0,
#   'available_supply': 14644330905.0,
#   'id': 'verge',
#   'last_updated': 1519683544,
#   'market_cap_usd': 901708567.0,
#   'max_supply': 16555000000.0,
#   'name': 'Verge',
#   'percent_change_1h': 0.02,
#   'percent_change_24h': 5.3,
#   'percent_change_7d': -25.35,
#   'price_btc': 5.95e-06,
#   'price_usd': 0.0615739,
#   'rank': 27,
#   'symbol': 'XVG',
#   'total_supply': 14644330905.0},
#  {'24h_volume_usd': 5302540.0,
#   'available_supply': 250621781.0,
#   'id': 'steem',
#   'last_updated': 1519683546,
#   'market_cap_usd': 895263607.0,
#   'max_supply': None,
#   'name': 'Steem',
#   'percent_change_1h': 0.41,
#   'percent_change_24h': 2.85,
#   'percent_change_7d': -19.78,
#   'price_btc': 0.00034542,
#   'price_usd': 3.57217,
#   'rank': 28,
#   'symbol': 'STEEM',
#   'total_supply': 267595875.0},
#  {'24h_volume_usd': 46839400.0,
#   'available_supply': 2000000.0,
#   'id': 'digixdao',
#   'last_updated': 1519683546,
#   'market_cap_usd': 815722000.0,
#   'max_supply': None,
#   'name': 'DigixDAO',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': -0.76,
#   'percent_change_7d': 37.87,
#   'price_btc': 0.0394395,
#   'price_usd': 407.861,
#   'rank': 29,
#   'symbol': 'DGD',
#   'total_supply': 2000000.0},
#  {'24h_volume_usd': 2912130.0,
#   'available_supply': 37004027.0,
#   'id': 'populous',
#   'last_updated': 1519683551,
#   'market_cap_usd': 814355021.0,
#   'max_supply': 53252246.0,
#   'name': 'Populous',
#   'percent_change_1h': 1.16,
#   'percent_change_24h': 1.72,
#   'percent_change_7d': -21.3,
#   'price_btc': 0.00212807,
#   'price_usd': 22.0072,
#   'rank': 30,
#   'symbol': 'PPT',
#   'total_supply': 53252246.0},
#  {'24h_volume_usd': 8446640.0,
#   'available_supply': 98756222.0,
#   'id': 'stratis',
#   'last_updated': 1519683546,
#   'market_cap_usd': 758661100.0,
#   'max_supply': None,
#   'name': 'Stratis',
#   'percent_change_1h': -0.61,
#   'percent_change_24h': 5.2,
#   'percent_change_7d': -22.64,
#   'price_btc': 0.00074285,
#   'price_usd': 7.68216,
#   'rank': 31,
#   'symbol': 'STRAT',
#   'total_supply': 98756222.0},
#  {'24h_volume_usd': 10443600.0,
#   'available_supply': 32748312084.0,
#   'id': 'siacoin',
#   'last_updated': 1519683545,
#   'market_cap_usd': 729910754.0,
#   'max_supply': None,
#   'name': 'Siacoin',
#   'percent_change_1h': -0.19,
#   'percent_change_24h': 5.96,
#   'percent_change_7d': -22.25,
#   'price_btc': 2.16e-06,
#   'price_usd': 0.0222885,
#   'rank': 32,
#   'symbol': 'SC',
#   'total_supply': 32748312084.0},
#  {'24h_volume_usd': 12426300.0,
#   'available_supply': 113363657722,
#   'id': 'dogecoin',
#   'last_updated': 1519683541,
#   'market_cap_usd': 728126838.0,
#   'max_supply': None,
#   'name': 'Dogecoin',
#   'percent_change_1h': 0.4,
#   'percent_change_24h': 3.96,
#   'percent_change_7d': -4.15,
#   'price_btc': 6.2e-07,
#   'price_usd': 0.00642293,
#   'rank': 33,
#   'symbol': 'DOGE',
#   'total_supply': 113363657722},
#  {'24h_volume_usd': 508882.0,
#   'available_supply': 359399272.0,
#   'id': 'rchain',
#   'last_updated': 1519683555,
#   'market_cap_usd': 726220140.0,
#   'max_supply': 1000000000.0,
#   'name': 'RChain',
#   'percent_change_1h': 0.98,
#   'percent_change_24h': 9.0,
#   'percent_change_7d': -14.24,
#   'price_btc': 0.00019539,
#   'price_usd': 2.02065,
#   'rank': 34,
#   'symbol': 'RHOC',
#   'total_supply': 870663574.0},
#  {'24h_volume_usd': 21316800.0,
#   'available_supply': 100000000.0,
#   'id': 'waves',
#   'last_updated': 1519683547,
#   'market_cap_usd': 672378000.0,
#   'max_supply': None,
#   'name': 'Waves',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': 3.75,
#   'percent_change_7d': -16.86,
#   'price_btc': 0.00065018,
#   'price_usd': 6.72378,
#   'rank': 35,
#   'symbol': 'WAVES',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 617880.0,
#   'available_supply': 618228.0,
#   'id': 'maker',
#   'last_updated': 1519683548,
#   'market_cap_usd': 631278558.0,
#   'max_supply': None,
#   'name': 'Maker',
#   'percent_change_1h': -0.36,
#   'percent_change_24h': 2.27,
#   'percent_change_7d': -8.62,
#   'price_btc': 0.0987398,
#   'price_usd': 1021.11,
#   'rank': 36,
#   'symbol': 'MKR',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 25792300.0,
#   'available_supply': 3470483788.0,
#   'id': 'status',
#   'last_updated': 1519683551,
#   'market_cap_usd': 621272126.0,
#   'max_supply': None,
#   'name': 'Status',
#   'percent_change_1h': -0.34,
#   'percent_change_24h': -0.88,
#   'percent_change_7d': -18.88,
#   'price_btc': 1.731e-05,
#   'price_usd': 0.179016,
#   'rank': 37,
#   'symbol': 'SNT',
#   'total_supply': 6804870174.0},
#  {'24h_volume_usd': 6317860.0,
#   'available_supply': 2609330000.0,
#   'id': 'bitshares',
#   'last_updated': 1519683543,
#   'market_cap_usd': 578039656.0,
#   'max_supply': 3600570502.0,
#   'name': 'BitShares',
#   'percent_change_1h': 0.46,
#   'percent_change_24h': 3.18,
#   'percent_change_7d': -16.69,
#   'price_btc': 2.142e-05,
#   'price_usd': 0.221528,
#   'rank': 38,
#   'symbol': 'BTS',
#   'total_supply': 2609330000.0},
#  {'24h_volume_usd': 9558810.0,
#   'available_supply': 24898178.0,
#   'id': 'waltonchain',
#   'last_updated': 1519683553,
#   'market_cap_usd': 536495980.0,
#   'max_supply': 100000000.0,
#   'name': 'Waltonchain',
#   'percent_change_1h': -0.06,
#   'percent_change_24h': -2.34,
#   'percent_change_7d': -15.09,
#   'price_btc': 0.00208362,
#   'price_usd': 21.5476,
#   'rank': 39,
#   'symbol': 'WTC',
#   'total_supply': 70000000.0},
#  {'24h_volume_usd': 8954700.0,
#   'available_supply': 513917158.0,
#   'id': '0x',
#   'last_updated': 1519683552,
#   'market_cap_usd': 524205780.0,
#   'max_supply': None,
#   'name': '0x',
#   'percent_change_1h': -0.32,
#   'percent_change_24h': 3.43,
#   'percent_change_7d': -13.43,
#   'price_btc': 9.863e-05,
#   'price_usd': 1.02002,
#   'rank': 40,
#   'symbol': 'ZRX',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 3059320.0,
#   'available_supply': 233020472.0,
#   'id': 'aeternity',
#   'last_updated': 1519683550,
#   'market_cap_usd': 518316757.0,
#   'max_supply': None,
#   'name': 'Aeternity',
#   'percent_change_1h': -0.53,
#   'percent_change_24h': 3.76,
#   'percent_change_7d': -18.07,
#   'price_btc': 0.00021509,
#   'price_usd': 2.22434,
#   'rank': 41,
#   'symbol': 'AE',
#   'total_supply': 273685830.0},
#  {'24h_volume_usd': 798192.0,
#   'available_supply': 6832759.0,
#   'id': 'decred',
#   'last_updated': 1519683545,
#   'market_cap_usd': 515466073.0,
#   'max_supply': 21000000.0,
#   'name': 'Decred',
#   'percent_change_1h': -0.01,
#   'percent_change_24h': 4.53,
#   'percent_change_7d': -15.68,
#   'price_btc': 0.00729497,
#   'price_usd': 75.4404,
#   'rank': 42,
#   'symbol': 'DCR',
#   'total_supply': 7252759.0},
#  {'24h_volume_usd': 5096510.0,
#   'available_supply': 6269056940.0,
#   'id': 'electroneum',
#   'last_updated': 1519683556,
#   'market_cap_usd': 510637256.0,
#   'max_supply': 21000000000.0,
#   'name': 'Electroneum',
#   'percent_change_1h': -5.31,
#   'percent_change_24h': -5.51,
#   'percent_change_7d': -6.96,
#   'price_btc': 7.88e-06,
#   'price_usd': 0.0814536,
#   'rank': 43,
#   'symbol': 'ETN',
#   'total_supply': 6269056940.0},
#  {'24h_volume_usd': 5170930.0,
#   'available_supply': 11000000.0,
#   'id': 'augur',
#   'last_updated': 1519683545,
#   'market_cap_usd': 510632100.0,
#   'max_supply': None,
#   'name': 'Augur',
#   'percent_change_1h': 0.04,
#   'percent_change_24h': 5.93,
#   'percent_change_7d': -14.51,
#   'price_btc': 0.00448885,
#   'price_usd': 46.4211,
#   'rank': 44,
#   'symbol': 'REP',
#   'total_supply': 11000000.0},
#  {'24h_volume_usd': 231815.0,
#   'available_supply': 2036645.0,
#   'id': 'veritaseum',
#   'last_updated': 1519683551,
#   'market_cap_usd': 502295828.0,
#   'max_supply': None,
#   'name': 'Veritaseum',
#   'percent_change_1h': -0.83,
#   'percent_change_24h': 3.86,
#   'percent_change_7d': -7.85,
#   'price_btc': 0.0238487,
#   'price_usd': 246.629,
#   'rank': 45,
#   'symbol': 'VERI',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 1196900.0,
#   'available_supply': 91043076.0,
#   'id': 'kucoin-shares',
#   'last_updated': 1519683554,
#   'market_cap_usd': 431078040.0,
#   'max_supply': None,
#   'name': 'KuCoin Shares',
#   'percent_change_1h': 0.67,
#   'percent_change_24h': 3.92,
#   'percent_change_7d': -7.22,
#   'price_btc': 0.00045786,
#   'price_usd': 4.73488,
#   'rank': 46,
#   'symbol': 'KCS',
#   'total_supply': 181043076.0},
#  {'24h_volume_usd': 17959300.0,
#   'available_supply': 184450000.0,
#   'id': 'revain',
#   'last_updated': 1519683555,
#   'market_cap_usd': 430954514.0,
#   'max_supply': 484450000.0,
#   'name': 'Revain',
#   'percent_change_1h': -0.17,
#   'percent_change_24h': 2.34,
#   'percent_change_7d': -29.44,
#   'price_btc': 0.00022593,
#   'price_usd': 2.33643,
#   'rank': 47,
#   'symbol': 'R',
#   'total_supply': 484450000.0},
#  {'24h_volume_usd': 3253110.0,
#   'available_supply': 998999495.0,
#   'id': 'ardor',
#   'last_updated': 1519683547,
#   'market_cap_usd': 430090262.0,
#   'max_supply': 998999495.0,
#   'name': 'Ardor',
#   'percent_change_1h': -0.12,
#   'percent_change_24h': 0.07,
#   'percent_change_7d': -18.19,
#   'price_btc': 4.163e-05,
#   'price_usd': 0.430521,
#   'rank': 48,
#   'symbol': 'ARDR',
#   'total_supply': 998999495.0},
#  {'24h_volume_usd': 7874150.0,
#   'available_supply': 9799353.0,
#   'id': 'gas',
#   'last_updated': 1519683551,
#   'market_cap_usd': 419534792.0,
#   'max_supply': 100000000.0,
#   'name': 'Gas',
#   'percent_change_1h': -0.95,
#   'percent_change_24h': 15.04,
#   'percent_change_7d': -11.04,
#   'price_btc': 0.0041399,
#   'price_usd': 42.8125,
#   'rank': 49,
#   'symbol': 'GAS',
#   'total_supply': 15737080.0},
#  {'24h_volume_usd': 1828520.0,
#   'available_supply': 103744640.0,
#   'id': 'komodo',
#   'last_updated': 1519683548,
#   'market_cap_usd': 415119654.0,
#   'max_supply': None,
#   'name': 'Komodo',
#   'percent_change_1h': 0.29,
#   'percent_change_24h': 2.69,
#   'percent_change_7d': -21.27,
#   'price_btc': 0.00038692,
#   'price_usd': 4.00136,
#   'rank': 50,
#   'symbol': 'KMD',
#   'total_supply': 103744640.0},
#  {'24h_volume_usd': 80219500.0,
#   'available_supply': 42673332.0,
#   'id': 'hshare',
#   'last_updated': 1519683553,
#   'market_cap_usd': 402106541.0,
#   'max_supply': 84000000.0,
#   'name': 'Hshare',
#   'percent_change_1h': -2.11,
#   'percent_change_24h': 0.47,
#   'percent_change_7d': -27.91,
#   'price_btc': 0.00091118,
#   'price_usd': 9.4229,
#   'rank': 51,
#   'symbol': 'HSR',
#   'total_supply': 42673332.0},
#  {'24h_volume_usd': 2134530.0,
#   'available_supply': 100893160.0,
#   'id': 'ark',
#   'last_updated': 1519683549,
#   'market_cap_usd': 381200591.0,
#   'max_supply': None,
#   'name': 'Ark',
#   'percent_change_1h': -0.83,
#   'percent_change_24h': 2.07,
#   'percent_change_7d': -19.41,
#   'price_btc': 0.00036535,
#   'price_usd': 3.77826,
#   'rank': 52,
#   'symbol': 'ARK',
#   'total_supply': 132143160.0},
#  {'24h_volume_usd': 2598650.0,
#   'available_supply': 1000000000.0,
#   'id': 'basic-attention-token',
#   'last_updated': 1519683550,
#   'market_cap_usd': 367150000.0,
#   'max_supply': None,
#   'name': 'Basic Attention Token',
#   'percent_change_1h': 0.24,
#   'percent_change_24h': 2.74,
#   'percent_change_7d': -13.27,
#   'price_btc': 3.55e-05,
#   'price_usd': 0.36715,
#   'rank': 53,
#   'symbol': 'BAT',
#   'total_supply': 1500000000.0},
#  {'24h_volume_usd': 31884400.0,
#   'available_supply': 3402250.0,
#   'id': 'zclassic',
#   'last_updated': 1519683548,
#   'market_cap_usd': 366524393.0,
#   'max_supply': 21000000.0,
#   'name': 'ZClassic',
#   'percent_change_1h': -1.65,
#   'percent_change_24h': -11.56,
#   'percent_change_7d': -44.09,
#   'price_btc': 0.0104173,
#   'price_usd': 107.73,
#   'rank': 54,
#   'symbol': 'ZCL',
#   'total_supply': 3402250.0},
#  {'24h_volume_usd': 1942240.0,
#   'available_supply': 561357157.0,
#   'id': 'loopring',
#   'last_updated': 1519683553,
#   'market_cap_usd': 360352561.0,
#   'max_supply': None,
#   'name': 'Loopring',
#   'percent_change_1h': 2.51,
#   'percent_change_24h': 2.72,
#   'percent_change_7d': -12.84,
#   'price_btc': 6.207e-05,
#   'price_usd': 0.641931,
#   'rank': 55,
#   'symbol': 'LRC',
#   'total_supply': 1374956262.0},
#  {'24h_volume_usd': 8083050.0,
#   'available_supply': 6511228178.0,
#   'id': 'zilliqa',
#   'last_updated': 1519683559,
#   'market_cap_usd': 356128370.0,
#   'max_supply': None,
#   'name': 'Zilliqa',
#   'percent_change_1h': -0.14,
#   'percent_change_24h': 7.59,
#   'percent_change_7d': -18.52,
#   'price_btc': 5.29e-06,
#   'price_usd': 0.0546945,
#   'rank': 56,
#   'symbol': 'ZIL',
#   'total_supply': 12600000000.0},
#  {'24h_volume_usd': 3569520.0,
#   'available_supply': 9898619805.0,
#   'id': 'digibyte',
#   'last_updated': 1519683541,
#   'market_cap_usd': 354503231.0,
#   'max_supply': 21000000000.0,
#   'name': 'DigiByte',
#   'percent_change_1h': 0.89,
#   'percent_change_24h': 5.76,
#   'percent_change_7d': -18.89,
#   'price_btc': 3.46e-06,
#   'price_usd': 0.0358134,
#   'rank': 57,
#   'symbol': 'DGB',
#   'total_supply': 9898619805.0},
#  {'24h_volume_usd': 586379.0,
#   'available_supply': 45136952.0,
#   'id': 'cryptonex',
#   'last_updated': 1519683554,
#   'market_cap_usd': 345250741.0,
#   'max_supply': 210000000.0,
#   'name': 'Cryptonex',
#   'percent_change_1h': 0.23,
#   'percent_change_24h': 50.6,
#   'percent_change_7d': -4.21,
#   'price_btc': 0.00073964,
#   'price_usd': 7.64896,
#   'rank': 58,
#   'symbol': 'CNX',
#   'total_supply': 106574578.0},
#  {'24h_volume_usd': 2135020.0,
#   'available_supply': 531228073.0,
#   'id': 'syscoin',
#   'last_updated': 1519683543,
#   'market_cap_usd': 343963803.0,
#   'max_supply': 888000000.0,
#   'name': 'Syscoin',
#   'percent_change_1h': 0.82,
#   'percent_change_24h': 12.64,
#   'percent_change_7d': -10.75,
#   'price_btc': 6.261e-05,
#   'price_usd': 0.647488,
#   'rank': 59,
#   'symbol': 'SYS',
#   'total_supply': 531228073.0},
#  {'24h_volume_usd': 8578270.0,
#   'available_supply': 987000000.0,
#   'id': 'bytom',
#   'last_updated': 1519683552,
#   'market_cap_usd': 340914735.0,
#   'max_supply': None,
#   'name': 'Bytom',
#   'percent_change_1h': -0.21,
#   'percent_change_24h': 6.17,
#   'percent_change_7d': -9.74,
#   'price_btc': 3.34e-05,
#   'price_usd': 0.345405,
#   'rank': 60,
#   'symbol': 'BTM',
#   'total_supply': 1407000000.0},
#  {'24h_volume_usd': 1432210.0,
#   'available_supply': 238421940.0,
#   'id': 'dragonchain',
#   'last_updated': 1519683556,
#   'market_cap_usd': 335762465.0,
#   'max_supply': None,
#   'name': 'Dragonchain',
#   'percent_change_1h': 0.32,
#   'percent_change_24h': 1.63,
#   'percent_change_7d': -23.43,
#   'price_btc': 0.00013618,
#   'price_usd': 1.40827,
#   'rank': 61,
#   'symbol': 'DRGN',
#   'total_supply': 433494437.0},
#  {'24h_volume_usd': 3702500.0,
#   'available_supply': 57700900.0,
#   'id': 'monacoin',
#   'last_updated': 1519683541,
#   'market_cap_usd': 325866986.0,
#   'max_supply': None,
#   'name': 'MonaCoin',
#   'percent_change_1h': 0.78,
#   'percent_change_24h': 3.82,
#   'percent_change_7d': -9.38,
#   'price_btc': 0.00054611,
#   'price_usd': 5.64752,
#   'rank': 62,
#   'symbol': 'MONA',
#   'total_supply': 57700900.0},
#  {'24h_volume_usd': 12458900.0,
#   'available_supply': 834262000.0,
#   'id': 'golem-network-tokens',
#   'last_updated': 1519683548,
#   'market_cap_usd': 309033170.0,
#   'max_supply': None,
#   'name': 'Golem',
#   'percent_change_1h': -2.39,
#   'percent_change_24h': 15.84,
#   'percent_change_7d': -16.07,
#   'price_btc': 3.582e-05,
#   'price_usd': 0.370427,
#   'rank': 63,
#   'symbol': 'GNT',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 9448440.0,
#   'available_supply': 35500000.0,
#   'id': 'nebulas-token',
#   'last_updated': 1519683553,
#   'market_cap_usd': 305744460.0,
#   'max_supply': 100000000.0,
#   'name': 'Nebulas',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': 13.8,
#   'percent_change_7d': -10.66,
#   'price_btc': 0.00083282,
#   'price_usd': 8.61252,
#   'rank': 64,
#   'symbol': 'NAS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 6331400.0,
#   'available_supply': 10614760961.0,
#   'id': 'dent',
#   'last_updated': 1519683552,
#   'market_cap_usd': 305431255.0,
#   'max_supply': None,
#   'name': 'Dent',
#   'percent_change_1h': 0.32,
#   'percent_change_24h': -5.99,
#   'percent_change_7d': 9.88,
#   'price_btc': 2.78e-06,
#   'price_usd': 0.0287742,
#   'rank': 65,
#   'symbol': 'DENT',
#   'total_supply': 100000000000},
#  {'24h_volume_usd': 2176860.0,
#   'available_supply': 55657471.0,
#   'id': 'pivx',
#   'last_updated': 1519683546,
#   'market_cap_usd': 304259914.0,
#   'max_supply': None,
#   'name': 'PIVX',
#   'percent_change_1h': 1.67,
#   'percent_change_24h': 1.03,
#   'percent_change_7d': -11.19,
#   'price_btc': 0.00052862,
#   'price_usd': 5.46665,
#   'rank': 66,
#   'symbol': 'PIVX',
#   'total_supply': 55657471.0},
#  {'24h_volume_usd': 13703200.0,
#   'available_supply': 250000000.0,
#   'id': 'aelf',
#   'last_updated': 1519683557,
#   'market_cap_usd': 298815000.0,
#   'max_supply': 1000000000.0,
#   'name': 'aelf',
#   'percent_change_1h': 0.09,
#   'percent_change_24h': 0.91,
#   'percent_change_7d': -23.38,
#   'price_btc': 0.00011558,
#   'price_usd': 1.19526,
#   'rank': 67,
#   'symbol': 'ELF',
#   'total_supply': 280000000.0},
#  {'24h_volume_usd': 4381330.0,
#   'available_supply': 96154303.0,
#   'id': 'aion',
#   'last_updated': 1519683554,
#   'market_cap_usd': 297314874.0,
#   'max_supply': None,
#   'name': 'Aion',
#   'percent_change_1h': -1.29,
#   'percent_change_24h': -2.18,
#   'percent_change_7d': -19.79,
#   'price_btc': 0.000299,
#   'price_usd': 3.09206,
#   'rank': 68,
#   'symbol': 'AION',
#   'total_supply': 465934587.0},
#  {'24h_volume_usd': 1716830.0,
#   'available_supply': 239570250.0,
#   'id': 'polymath-network',
#   'last_updated': 1519683559,
#   'market_cap_usd': 294601932.0,
#   'max_supply': None,
#   'name': 'Polymath',
#   'percent_change_1h': 0.21,
#   'percent_change_24h': 0.97,
#   'percent_change_7d': -20.95,
#   'price_btc': 0.00011891,
#   'price_usd': 1.22971,
#   'rank': 69,
#   'symbol': 'POLY',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 2935510.0,
#   'available_supply': 350000000.0,
#   'id': 'qash',
#   'last_updated': 1519683556,
#   'market_cap_usd': 293704250.0,
#   'max_supply': None,
#   'name': 'QASH',
#   'percent_change_1h': 0.1,
#   'percent_change_24h': 3.98,
#   'percent_change_7d': -18.37,
#   'price_btc': 8.114e-05,
#   'price_usd': 0.839155,
#   'rank': 70,
#   'symbol': 'QASH',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 3851760.0,
#   'available_supply': 8745102.0,
#   'id': 'factom',
#   'last_updated': 1519683545,
#   'market_cap_usd': 290145869.0,
#   'max_supply': None,
#   'name': 'Factom',
#   'percent_change_1h': 0.88,
#   'percent_change_24h': 12.77,
#   'percent_change_7d': 0.51,
#   'price_btc': 0.00320827,
#   'price_usd': 33.1781,
#   'rank': 71,
#   'symbol': 'FCT',
#   'total_supply': 8745102.0},
#  {'24h_volume_usd': 610851.0,
#   'available_supply': 645222.0,
#   'id': 'byteball',
#   'last_updated': 1519683548,
#   'market_cap_usd': 286912181.0,
#   'max_supply': None,
#   'name': 'Byteball Bytes',
#   'percent_change_1h': 0.49,
#   'percent_change_24h': 0.73,
#   'percent_change_7d': -27.46,
#   'price_btc': 0.0429991,
#   'price_usd': 444.672,
#   'rank': 72,
#   'symbol': 'GBYTE',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 28445900.0,
#   'available_supply': 28768006014.0,
#   'id': 'reddcoin',
#   'last_updated': 1519683541,
#   'market_cap_usd': 285638682.0,
#   'max_supply': None,
#   'name': 'ReddCoin',
#   'percent_change_1h': -1.12,
#   'percent_change_24h': -3.44,
#   'percent_change_7d': 31.27,
#   'price_btc': 9.6e-07,
#   'price_usd': 0.00992904,
#   'rank': 73,
#   'symbol': 'RDD',
#   'total_supply': 28768006014.0},
#  {'24h_volume_usd': 2676000.0,
#   'available_supply': 134132697.0,
#   'id': 'kyber-network',
#   'last_updated': 1519683553,
#   'market_cap_usd': 271059378.0,
#   'max_supply': None,
#   'name': 'Kyber Network',
#   'percent_change_1h': -0.05,
#   'percent_change_24h': 3.4,
#   'percent_change_7d': -21.91,
#   'price_btc': 0.00019541,
#   'price_usd': 2.02083,
#   'rank': 74,
#   'symbol': 'KNC',
#   'total_supply': 215625349.0},
#  {'24h_volume_usd': 1178770.0,
#   'available_supply': 75807919.0,
#   'id': 'ethos',
#   'last_updated': 1519683551,
#   'market_cap_usd': 267212302.0,
#   'max_supply': None,
#   'name': 'Ethos',
#   'percent_change_1h': 1.92,
#   'percent_change_24h': 7.95,
#   'percent_change_7d': -13.01,
#   'price_btc': 0.00034085,
#   'price_usd': 3.52486,
#   'rank': 75,
#   'symbol': 'ETHOS',
#   'total_supply': 222295208.0},
#  {'24h_volume_usd': 224617.0,
#   'available_supply': 325226613094,
#   'id': 'dentacoin',
#   'last_updated': 1519683552,
#   'market_cap_usd': 261153393.0,
#   'max_supply': 8000000000000,
#   'name': 'Dentacoin',
#   'percent_change_1h': -0.0,
#   'percent_change_24h': 1.27,
#   'percent_change_7d': -18.49,
#   'price_btc': 8e-08,
#   'price_usd': 0.000802989,
#   'rank': 76,
#   'symbol': 'DCN',
#   'total_supply': 1963173416169},
#  {'24h_volume_usd': 1622830.0,
#   'available_supply': 11771703.0,
#   'id': 'bitcore',
#   'last_updated': 1519683550,
#   'market_cap_usd': 254616045.0,
#   'max_supply': 21000000.0,
#   'name': 'Bitcore',
#   'percent_change_1h': 0.24,
#   'percent_change_24h': -2.55,
#   'percent_change_7d': -17.67,
#   'price_btc': 0.00209154,
#   'price_usd': 21.6295,
#   'rank': 77,
#   'symbol': 'BTX',
#   'total_supply': 16825691.0},
#  {'24h_volume_usd': 7292480.0,
#   'available_supply': 60000000.0,
#   'id': 'gxshares',
#   'last_updated': 1519683551,
#   'market_cap_usd': 251601600.0,
#   'max_supply': 100000000.0,
#   'name': 'GXShares',
#   'percent_change_1h': 0.77,
#   'percent_change_24h': 6.66,
#   'percent_change_7d': -15.6,
#   'price_btc': 0.00040549,
#   'price_usd': 4.19336,
#   'rank': 78,
#   'symbol': 'GXS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 4295100.0,
#   'available_supply': 350000000.0,
#   'id': 'chainlink',
#   'last_updated': 1519683553,
#   'market_cap_usd': 242219950.0,
#   'max_supply': None,
#   'name': 'ChainLink',
#   'percent_change_1h': 0.65,
#   'percent_change_24h': 1.27,
#   'percent_change_7d': -13.93,
#   'price_btc': 6.692e-05,
#   'price_usd': 0.692057,
#   'rank': 79,
#   'symbol': 'LINK',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 22052600.0,
#   'available_supply': 6794109922.0,
#   'id': 'iostoken',
#   'last_updated': 1519683558,
#   'market_cap_usd': 239040566.0,
#   'max_supply': None,
#   'name': 'IOStoken',
#   'percent_change_1h': -0.11,
#   'percent_change_24h': 2.04,
#   'percent_change_7d': -25.5,
#   'price_btc': 3.4e-06,
#   'price_usd': 0.0351835,
#   'rank': 80,
#   'symbol': 'IOST',
#   'total_supply': 21000000000.0},
#  {'24h_volume_usd': 1797740.0,
#   'available_supply': 4503688789.0,
#   'id': 'funfair',
#   'last_updated': 1519683551,
#   'market_cap_usd': 237751082.0,
#   'max_supply': None,
#   'name': 'FunFair',
#   'percent_change_1h': 1.24,
#   'percent_change_24h': 2.51,
#   'percent_change_7d': -16.37,
#   'price_btc': 5.1e-06,
#   'price_usd': 0.0527903,
#   'rank': 81,
#   'symbol': 'FUN',
#   'total_supply': 10999873621.0},
#  {'24h_volume_usd': 4350230.0,
#   'available_supply': 54237689.0,
#   'id': 'salt',
#   'last_updated': 1519683554,
#   'market_cap_usd': 228055381.0,
#   'max_supply': None,
#   'name': 'SALT',
#   'percent_change_1h': -0.03,
#   'percent_change_24h': -0.76,
#   'percent_change_7d': -12.86,
#   'price_btc': 0.00040659,
#   'price_usd': 4.20474,
#   'rank': 82,
#   'symbol': 'SALT',
#   'total_supply': 120000000.0},
#  {'24h_volume_usd': 4046020.0,
#   'available_supply': 4192169.0,
#   'id': 'zcoin',
#   'last_updated': 1519683547,
#   'market_cap_usd': 222543806.0,
#   'max_supply': 21400000.0,
#   'name': 'ZCoin',
#   'percent_change_1h': 0.97,
#   'percent_change_24h': 0.7,
#   'percent_change_7d': -19.79,
#   'price_btc': 0.0051333,
#   'price_usd': 53.0856,
#   'rank': 83,
#   'symbol': 'XZC',
#   'total_supply': 4192169.0},
#  {'24h_volume_usd': 4219520.0,
#   'available_supply': 363932644.0,
#   'id': 'power-ledger',
#   'last_updated': 1519683555,
#   'market_cap_usd': 221185887.0,
#   'max_supply': None,
#   'name': 'Power Ledger',
#   'percent_change_1h': 0.48,
#   'percent_change_24h': 3.52,
#   'percent_change_7d': -22.06,
#   'price_btc': 5.877e-05,
#   'price_usd': 0.607766,
#   'rank': 84,
#   'symbol': 'POWR',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 3224840.0,
#   'available_supply': 998999942.0,
#   'id': 'nxt',
#   'last_updated': 1519683540,
#   'market_cap_usd': 213918854.0,
#   'max_supply': 1000000000.0,
#   'name': 'Nxt',
#   'percent_change_1h': 0.02,
#   'percent_change_24h': 1.64,
#   'percent_change_7d': -20.06,
#   'price_btc': 2.071e-05,
#   'price_usd': 0.214133,
#   'rank': 85,
#   'symbol': 'NXT',
#   'total_supply': 998999942.0},
#  {'24h_volume_usd': 550750.0,
#   'available_supply': 756097560976,
#   'id': 'kin',
#   'last_updated': 1519683554,
#   'market_cap_usd': 203927073.0,
#   'max_supply': None,
#   'name': 'Kin',
#   'percent_change_1h': -0.16,
#   'percent_change_24h': -4.55,
#   'percent_change_7d': -20.52,
#   'price_btc': 3e-08,
#   'price_usd': 0.00026971,
#   'rank': 86,
#   'symbol': 'KIN',
#   'total_supply': 10000000000000},
#  {'24h_volume_usd': 2522330.0,
#   'available_supply': 1445976590.0,
#   'id': 'cindicator',
#   'last_updated': 1519683554,
#   'market_cap_usd': 200635036.0,
#   'max_supply': None,
#   'name': 'Cindicator',
#   'percent_change_1h': 0.84,
#   'percent_change_24h': 3.38,
#   'percent_change_7d': -18.93,
#   'price_btc': 1.342e-05,
#   'price_usd': 0.138754,
#   'rank': 87,
#   'symbol': 'CND',
#   'total_supply': 2000000005.0},
#  {'24h_volume_usd': 5533230.0,
#   'available_supply': 39180669.0,
#   'id': 'bancor',
#   'last_updated': 1519683550,
#   'market_cap_usd': 196695185.0,
#   'max_supply': None,
#   'name': 'Bancor',
#   'percent_change_1h': -0.18,
#   'percent_change_24h': 2.29,
#   'percent_change_7d': -11.41,
#   'price_btc': 0.00048545,
#   'price_usd': 5.02021,
#   'rank': 88,
#   'symbol': 'BNT',
#   'total_supply': 74620774.0},
#  {'24h_volume_usd': 3371790.0,
#   'available_supply': 641462769.0,
#   'id': 'request-network',
#   'last_updated': 1519683554,
#   'market_cap_usd': 196373563.0,
#   'max_supply': None,
#   'name': 'Request Network',
#   'percent_change_1h': 1.62,
#   'percent_change_24h': 2.4,
#   'percent_change_7d': -4.76,
#   'price_btc': 2.96e-05,
#   'price_usd': 0.306134,
#   'rank': 89,
#   'symbol': 'REQ',
#   'total_supply': 999999999.0},
#  {'24h_volume_usd': 4774940.0,
#   'available_supply': 74836171.0,
#   'id': 'enigma-project',
#   'last_updated': 1519683554,
#   'market_cap_usd': 195270021.0,
#   'max_supply': None,
#   'name': 'Enigma',
#   'percent_change_1h': 0.24,
#   'percent_change_24h': 5.19,
#   'percent_change_7d': -17.51,
#   'price_btc': 0.00025232,
#   'price_usd': 2.6093,
#   'rank': 90,
#   'symbol': 'ENG',
#   'total_supply': 150000000.0},
#  {'24h_volume_usd': 172563.0,
#   'available_supply': 8883489.0,
#   'id': 'particl',
#   'last_updated': 1519683552,
#   'market_cap_usd': 194412488.0,
#   'max_supply': None,
#   'name': 'Particl',
#   'percent_change_1h': 1.51,
#   'percent_change_24h': 1.65,
#   'percent_change_7d': -17.65,
#   'price_btc': 0.00211622,
#   'price_usd': 21.8847,
#   'rank': 91,
#   'symbol': 'PART',
#   'total_supply': 8883489.0},
#  {'24h_volume_usd': 498341.0,
#   'available_supply': 227384800.0,
#   'id': 'pillar',
#   'last_updated': 1519683552,
#   'market_cap_usd': 189535463.0,
#   'max_supply': None,
#   'name': 'Pillar',
#   'percent_change_1h': 1.68,
#   'percent_change_24h': -2.64,
#   'percent_change_7d': -26.14,
#   'price_btc': 8.06e-05,
#   'price_usd': 0.833545,
#   'rank': 92,
#   'symbol': 'PLR',
#   'total_supply': 800000000.0},
#  {'24h_volume_usd': 2489140.0,
#   'available_supply': 460552782.0,
#   'id': 'singularitynet',
#   'last_updated': 1519683559,
#   'market_cap_usd': 180718148.0,
#   'max_supply': None,
#   'name': 'SingularityNET',
#   'percent_change_1h': -0.55,
#   'percent_change_24h': 11.59,
#   'percent_change_7d': 7.36,
#   'price_btc': 3.794e-05,
#   'price_usd': 0.392394,
#   'rank': 93,
#   'symbol': 'AGI',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 141067.0,
#   'available_supply': 738113531.0,
#   'id': 'smartcash',
#   'last_updated': 1519683552,
#   'market_cap_usd': 180637048.0,
#   'max_supply': 5000000000.0,
#   'name': 'SmartCash',
#   'percent_change_1h': 2.74,
#   'percent_change_24h': 6.67,
#   'percent_change_7d': -16.96,
#   'price_btc': 2.366e-05,
#   'price_usd': 0.244728,
#   'rank': 94,
#   'symbol': 'SMART',
#   'total_supply': 1339157811.0},
#  {'24h_volume_usd': 4468030.0,
#   'available_supply': 12853724.0,
#   'id': 'neblio',
#   'last_updated': 1519683553,
#   'market_cap_usd': 180102525.0,
#   'max_supply': None,
#   'name': 'Neblio',
#   'percent_change_1h': 0.79,
#   'percent_change_24h': 2.0,
#   'percent_change_7d': -24.41,
#   'price_btc': 0.00135491,
#   'price_usd': 14.0117,
#   'rank': 95,
#   'symbol': 'NEBL',
#   'total_supply': 13603665.0},
#  {'24h_volume_usd': 2691220.0,
#   'available_supply': 43106425.0,
#   'id': 'vertcoin',
#   'last_updated': 1519683543,
#   'market_cap_usd': 178931322.0,
#   'max_supply': 84000000.0,
#   'name': 'Vertcoin',
#   'percent_change_1h': 0.05,
#   'percent_change_24h': 11.77,
#   'percent_change_7d': -8.83,
#   'price_btc': 0.00040139,
#   'price_usd': 4.15092,
#   'rank': 96,
#   'symbol': 'VTC',
#   'total_supply': 43106425.0},
#  {'24h_volume_usd': 1798030.0,
#   'available_supply': 104661310.0,
#   'id': 'tenx',
#   'last_updated': 1519683551,
#   'market_cap_usd': 169738666.0,
#   'max_supply': None,
#   'name': 'TenX',
#   'percent_change_1h': 0.36,
#   'percent_change_24h': 7.89,
#   'percent_change_7d': -22.03,
#   'price_btc': 0.00015682,
#   'price_usd': 1.62179,
#   'rank': 97,
#   'symbol': 'PAY',
#   'total_supply': 205218256.0},
#  {'24h_volume_usd': 2384050.0,
#   'available_supply': 617314171.0,
#   'id': 'quantstamp',
#   'last_updated': 1519683556,
#   'market_cap_usd': 166687790.0,
#   'max_supply': None,
#   'name': 'Quantstamp',
#   'percent_change_1h': 2.29,
#   'percent_change_24h': 4.76,
#   'percent_change_7d': -16.15,
#   'price_btc': 2.611e-05,
#   'price_usd': 0.270021,
#   'rank': 98,
#   'symbol': 'QSP',
#   'total_supply': 976442388.0},
#  {'24h_volume_usd': 2480140.0,
#   'available_supply': 452552412.0,
#   'id': 'maidsafecoin',
#   'last_updated': 1519683542,
#   'market_cap_usd': 164304584.0,
#   'max_supply': None,
#   'name': 'MaidSafeCoin',
#   'percent_change_1h': -0.14,
#   'percent_change_24h': 4.53,
#   'percent_change_7d': -22.84,
#   'price_btc': 3.511e-05,
#   'price_usd': 0.363062,
#   'rank': 99,
#   'symbol': 'MAID',
#   'total_supply': 452552412.0},
#  {'24h_volume_usd': 9865780.0,
#   'available_supply': 492954537.0,
#   'id': 'wax',
#   'last_updated': 1519683557,
#   'market_cap_usd': 158414884.0,
#   'max_supply': None,
#   'name': 'WAX',
#   'percent_change_1h': 0.79,
#   'percent_change_24h': -3.66,
#   'percent_change_7d': -22.63,
#   'price_btc': 3.107e-05,
#   'price_usd': 0.321358,
#   'rank': 100,
#   'symbol': 'WAX',
#   'total_supply': 1850000000.0},
#  {'24h_volume_usd': 4071060.0,
#   'available_supply': 761143950.0,
#   'id': 'ignis',
#   'last_updated': 1519683557,
#   'market_cap_usd': 157916819.0,
#   'max_supply': 999449694.0,
#   'name': 'Ignis',
#   'percent_change_1h': -0.02,
#   'percent_change_24h': -0.74,
#   'percent_change_7d': -25.31,
#   'price_btc': 2.006e-05,
#   'price_usd': 0.207473,
#   'rank': 101,
#   'symbol': 'IGNIS',
#   'total_supply': 999449694.0},
#  {'24h_volume_usd': 4444530.0,
#   'available_supply': 50168936.0,
#   'id': 'raiden-network-token',
#   'last_updated': 1519683556,
#   'market_cap_usd': 155696784.0,
#   'max_supply': None,
#   'name': 'Raiden Network Token',
#   'percent_change_1h': -0.48,
#   'percent_change_24h': -3.67,
#   'percent_change_7d': -15.74,
#   'price_btc': 0.0003001,
#   'price_usd': 3.10345,
#   'rank': 102,
#   'symbol': 'RDN',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 938898.0,
#   'available_supply': 41365145.0,
#   'id': 'emercoin',
#   'last_updated': 1519683543,
#   'market_cap_usd': 151429524.0,
#   'max_supply': None,
#   'name': 'Emercoin',
#   'percent_change_1h': -0.76,
#   'percent_change_24h': 3.8,
#   'percent_change_7d': -30.54,
#   'price_btc': 0.00035399,
#   'price_usd': 3.6608,
#   'rank': 103,
#   'symbol': 'EMC',
#   'total_supply': 41365145.0},
#  {'24h_volume_usd': 241764.0,
#   'available_supply': 1104590.0,
#   'id': 'gnosis-gno',
#   'last_updated': 1519683550,
#   'market_cap_usd': 148965007.0,
#   'max_supply': None,
#   'name': 'Gnosis',
#   'percent_change_1h': 0.8,
#   'percent_change_24h': 4.44,
#   'percent_change_7d': -16.16,
#   'price_btc': 0.0130408,
#   'price_usd': 134.86,
#   'rank': 104,
#   'symbol': 'GNO',
#   'total_supply': 10000000.0},
#  {'24h_volume_usd': 822789.0,
#   'available_supply': 99735687.0,
#   'id': 'iconomi',
#   'last_updated': 1519683547,
#   'market_cap_usd': 146304274.0,
#   'max_supply': None,
#   'name': 'Iconomi',
#   'percent_change_1h': -0.04,
#   'percent_change_24h': 0.31,
#   'percent_change_7d': -22.34,
#   'price_btc': 0.00014185,
#   'price_usd': 1.46692,
#   'rank': 105,
#   'symbol': 'ICN',
#   'total_supply': 99735687.0},
#  {'24h_volume_usd': 9821930.0,
#   'available_supply': 756192535.0,
#   'id': 'enjin-coin',
#   'last_updated': 1519683555,
#   'market_cap_usd': 144238433.0,
#   'max_supply': None,
#   'name': 'Enjin Coin',
#   'percent_change_1h': 0.09,
#   'percent_change_24h': 5.61,
#   'percent_change_7d': -21.63,
#   'price_btc': 1.844e-05,
#   'price_usd': 0.190743,
#   'rank': 106,
#   'symbol': 'ENJ',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 530511.0,
#   'available_supply': 5031758.0,
#   'id': 'blocknet',
#   'last_updated': 1519683543,
#   'market_cap_usd': 142575864.0,
#   'max_supply': None,
#   'name': 'Blocknet',
#   'percent_change_1h': -4.56,
#   'percent_change_24h': 1.68,
#   'percent_change_7d': -29.43,
#   'price_btc': 0.00273997,
#   'price_usd': 28.3352,
#   'rank': 107,
#   'symbol': 'BLOCK',
#   'total_supply': 5031758.0},
#  {'24h_volume_usd': 3877290.0,
#   'available_supply': 2216707776.0,
#   'id': 'poet',
#   'last_updated': 1519683552,
#   'market_cap_usd': 141316007.0,
#   'max_supply': None,
#   'name': 'Po.et',
#   'percent_change_1h': -0.46,
#   'percent_change_24h': 6.78,
#   'percent_change_7d': -16.74,
#   'price_btc': 6.16e-06,
#   'price_usd': 0.0637504,
#   'rank': 108,
#   'symbol': 'POE',
#   'total_supply': 3141592653.0},
#  {'24h_volume_usd': 2826240.0,
#   'available_supply': 64355352.0,
#   'id': 'gamecredits',
#   'last_updated': 1519683543,
#   'market_cap_usd': 138394254.0,
#   'max_supply': 84000000.0,
#   'name': 'GameCredits',
#   'percent_change_1h': -0.71,
#   'percent_change_24h': 3.37,
#   'percent_change_7d': -29.97,
#   'price_btc': 0.00020795,
#   'price_usd': 2.15047,
#   'rank': 109,
#   'symbol': 'GAME',
#   'total_supply': 64355352.0},
#  {'24h_volume_usd': 1450840.0,
#   'available_supply': 172909618.0,
#   'id': 'pura',
#   'last_updated': 1519683544,
#   'market_cap_usd': 138275475.0,
#   'max_supply': 350000000.0,
#   'name': 'Pura',
#   'percent_change_1h': 2.58,
#   'percent_change_24h': 47.92,
#   'percent_change_7d': 78.91,
#   'price_btc': 7.733e-05,
#   'price_usd': 0.799698,
#   'rank': 110,
#   'symbol': 'PURA',
#   'total_supply': 179692112.0},
#  {'24h_volume_usd': 5163460.0,
#   'available_supply': 6896361042.0,
#   'id': 'digitalnote',
#   'last_updated': 1519683542,
#   'market_cap_usd': 136326575.0,
#   'max_supply': None,
#   'name': 'DigitalNote',
#   'percent_change_1h': 0.24,
#   'percent_change_24h': 1.89,
#   'percent_change_7d': -21.93,
#   'price_btc': 1.91e-06,
#   'price_usd': 0.0197679,
#   'rank': 111,
#   'symbol': 'XDN',
#   'total_supply': 6896361042.0},
#  {'24h_volume_usd': 4727510.0,
#   'available_supply': 62660371.0,
#   'id': 'santiment',
#   'last_updated': 1519683551,
#   'market_cap_usd': 135657197.0,
#   'max_supply': None,
#   'name': 'Santiment Network Token',
#   'percent_change_1h': 1.0,
#   'percent_change_24h': 6.28,
#   'percent_change_7d': -28.7,
#   'price_btc': 0.00020935,
#   'price_usd': 2.16496,
#   'rank': 112,
#   'symbol': 'SAN',
#   'total_supply': 83337000.0},
#  {'24h_volume_usd': 46129.8,
#   'available_supply': 1288862.0,
#   'id': 'bitcoindark',
#   'last_updated': 1519683542,
#   'market_cap_usd': 127605992.0,
#   'max_supply': None,
#   'name': 'BitcoinDark',
#   'percent_change_1h': 0.36,
#   'percent_change_24h': 5.16,
#   'percent_change_7d': -18.27,
#   'price_btc': 0.00957379,
#   'price_usd': 99.0067,
#   'rank': 113,
#   'symbol': 'BTCD',
#   'total_supply': 1288862.0},
#  {'24h_volume_usd': 48835.9,
#   'available_supply': 1000000000.0,
#   'id': 'xpa',
#   'last_updated': 1519683553,
#   'market_cap_usd': 127527000.0,
#   'max_supply': None,
#   'name': 'XPA',
#   'percent_change_1h': 0.12,
#   'percent_change_24h': 4.72,
#   'percent_change_7d': 4.35,
#   'price_btc': 1.233e-05,
#   'price_usd': 0.127527,
#   'rank': 114,
#   'symbol': 'XPA',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 499253.0,
#   'available_supply': 7454676.0,
#   'id': 'skycoin',
#   'last_updated': 1519683549,
#   'market_cap_usd': 124270194.0,
#   'max_supply': 100000000.0,
#   'name': 'Skycoin',
#   'percent_change_1h': 0.44,
#   'percent_change_24h': 5.63,
#   'percent_change_7d': -18.52,
#   'price_btc': 0.00161197,
#   'price_usd': 16.6701,
#   'rank': 115,
#   'symbol': 'SKY',
#   'total_supply': 25000000.0},
#  {'24h_volume_usd': 3379020.0,
#   'available_supply': 133425493.0,
#   'id': 'storj',
#   'last_updated': 1519683551,
#   'market_cap_usd': 124269435.0,
#   'max_supply': None,
#   'name': 'Storj',
#   'percent_change_1h': 0.03,
#   'percent_change_24h': 1.48,
#   'percent_change_7d': -19.53,
#   'price_btc': 9.006e-05,
#   'price_usd': 0.931377,
#   'rank': 116,
#   'symbol': 'STORJ',
#   'total_supply': 424999998.0},
#  {'24h_volume_usd': 2864600.0,
#   'available_supply': 342699966.0,
#   'id': 'civic',
#   'last_updated': 1519683552,
#   'market_cap_usd': 124229423.0,
#   'max_supply': None,
#   'name': 'Civic',
#   'percent_change_1h': 0.28,
#   'percent_change_24h': 3.36,
#   'percent_change_7d': -21.7,
#   'price_btc': 3.505e-05,
#   'price_usd': 0.362502,
#   'rank': 117,
#   'symbol': 'CVC',
#   'total_supply': 1000000000.0},
#  {'24h_volume_usd': 864598.0,
#   'available_supply': 4084706883.0,
#   'id': 'storm',
#   'last_updated': 1519683557,
#   'market_cap_usd': 124168962.0,
#   'max_supply': None,
#   'name': 'Storm',
#   'percent_change_1h': 0.18,
#   'percent_change_24h': 13.97,
#   'percent_change_7d': -26.36,
#   'price_btc': 2.94e-06,
#   'price_usd': 0.0303985,
#   'rank': 118,
#   'symbol': 'STORM',
#   'total_supply': 10000000000.0},
#  {'24h_volume_usd': 4869500.0,
#   'available_supply': 226091449.0,
#   'id': 'substratum',
#   'last_updated': 1519683553,
#   'market_cap_usd': 121565529.0,
#   'max_supply': None,
#   'name': 'Substratum',
#   'percent_change_1h': 0.69,
#   'percent_change_24h': -0.58,
#   'percent_change_7d': -21.17,
#   'price_btc': 5.199e-05,
#   'price_usd': 0.537683,
#   'rank': 119,
#   'symbol': 'SUB',
#   'total_supply': 352000000.0},
#  {'24h_volume_usd': 182964.0,
#   'available_supply': 27000000.0,
#   'id': 'bridgecoin',
#   'last_updated': 1519683554,
#   'market_cap_usd': 121511880.0,
#   'max_supply': 27000000.0,
#   'name': 'BridgeCoin',
#   'percent_change_1h': -10.13,
#   'percent_change_24h': 0.1,
#   'percent_change_7d': -13.99,
# ...
#   'percent_change_7d': -76.7,
#   'price_btc': 4e-08,
#   'price_usd': 0.000362825,
#   'rank': 960,
#   'symbol': 'VTA',
#   'total_supply': 12666916683.0},
#  {'24h_volume_usd': None,
#   'available_supply': 10547845.0,
#   'id': 'kekcoin',
#   'last_updated': 1519674553,
#   'market_cap_usd': 1836812.0,
#   'max_supply': 21000000.0,
#   'name': 'KekCoin',
#   'percent_change_1h': None,
#   'percent_change_24h': 6.48,
#   'percent_change_7d': -23.86,
#   'price_btc': 1.702e-05,
#   'price_usd': 0.174141,
#   'rank': 961,
#   'symbol': 'KEK',
#   'total_supply': 11547845.0},
#  {'24h_volume_usd': None,
#   'available_supply': 6695133.0,
#   'id': 'shadowcash',
#   'last_updated': 1519666143,
#   'market_cap_usd': 1836676.0,
#   'max_supply': None,
#   'name': 'ShadowCash',
#   'percent_change_1h': None,
#   'percent_change_24h': 5.97,
#   'percent_change_7d': None,
#   'price_btc': 2.694e-05,
#   'price_usd': 0.27433,
#   'rank': 962,
#   'symbol': 'SDC',
#   'total_supply': 6695133.0},
#  {'24h_volume_usd': None,
#   'available_supply': 10000000.0,
#   'id': 'inpay',
#   'last_updated': 1519579750,
#   'market_cap_usd': 1798810.0,
#   'max_supply': None,
#   'name': 'InPay',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': 2.53,
#   'price_btc': 1.916e-05,
#   'price_usd': 0.179881,
#   'rank': 963,
#   'symbol': 'INPAY',
#   'total_supply': 10000000.0},
#  {'24h_volume_usd': 175.679,
#   'available_supply': 75000000.0,
#   'id': 'bitpark-coin',
#   'last_updated': 1519683548,
#   'market_cap_usd': 1652820.0,
#   'max_supply': None,
#   'name': 'Bitpark Coin',
#   'percent_change_1h': 2.71,
#   'percent_change_24h': 10.65,
#   'percent_change_7d': 53.33,
#   'price_btc': 2.13e-06,
#   'price_usd': 0.0220376,
#   'rank': 964,
#   'symbol': 'BPC',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 25.809,
#   'available_supply': 4500000.0,
#   'id': 'starcredits',
#   'last_updated': 1519683553,
#   'market_cap_usd': 1596663.0,
#   'max_supply': 20000000.0,
#   'name': 'StarCredits',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': None,
#   'percent_change_7d': -7.79,
#   'price_btc': 3.431e-05,
#   'price_usd': 0.354814,
#   'rank': 965,
#   'symbol': 'STRC',
#   'total_supply': 20000000.0},
#  {'24h_volume_usd': 109.654,
#   'available_supply': 3152242.0,
#   'id': 'orbitcoin',
#   'last_updated': 1519683541,
#   'market_cap_usd': 1578429.0,
#   'max_supply': None,
#   'name': 'Orbitcoin',
#   'percent_change_1h': 0.13,
#   'percent_change_24h': 7.63,
#   'percent_change_7d': -10.82,
#   'price_btc': 4.842e-05,
#   'price_usd': 0.500732,
#   'rank': 966,
#   'symbol': 'ORB',
#   'total_supply': 3152242.0},
#  {'24h_volume_usd': 324.887,
#   'available_supply': 20988898.0,
#   'id': 'i0coin',
#   'last_updated': 1519683540,
#   'market_cap_usd': 1480316.0,
#   'max_supply': None,
#   'name': 'I0Coin',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': -7.09,
#   'percent_change_7d': -2.48,
#   'price_btc': 6.82e-06,
#   'price_usd': 0.0705285,
#   'rank': 967,
#   'symbol': 'I0C',
#   'total_supply': 20988898.0},
#  {'24h_volume_usd': 202.016,
#   'available_supply': 489412013.0,
#   'id': 'piggycoin',
#   'last_updated': 1519683543,
#   'market_cap_usd': 1463533.0,
#   'max_supply': None,
#   'name': 'Piggycoin',
#   'percent_change_1h': 0.18,
#   'percent_change_24h': 2.03,
#   'percent_change_7d': 0.18,
#   'price_btc': 2.9e-07,
#   'price_usd': 0.00299039,
#   'rank': 968,
#   'symbol': 'PIGGY',
#   'total_supply': 489412013.0},
#  {'24h_volume_usd': 24.0972,
#   'available_supply': 16822736.0,
#   'id': 'monster-byte',
#   'last_updated': 1519683552,
#   'market_cap_usd': 1388290.0,
#   'max_supply': None,
#   'name': 'Monster Byte',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': None,
#   'percent_change_7d': -3.33,
#   'price_btc': 7.98e-06,
#   'price_usd': 0.0825246,
#   'rank': 969,
#   'symbol': 'MBI',
#   'total_supply': 40000000.0},
#  {'24h_volume_usd': 415.544,
#   'available_supply': 8035193.0,
#   'id': 'woodcoin',
#   'last_updated': 1519683544,
#   'market_cap_usd': 1371077.0,
#   'max_supply': None,
#   'name': 'Woodcoin',
#   'percent_change_1h': 0.18,
#   'percent_change_24h': 4.63,
#   'percent_change_7d': 1.66,
#   'price_btc': 1.65e-05,
#   'price_usd': 0.170634,
#   'rank': 970,
#   'symbol': 'LOG',
#   'total_supply': 8035193.0},
#  {'24h_volume_usd': 59.5366,
#   'available_supply': 600000.0,
#   'id': 'kolion',
#   'last_updated': 1519683554,
#   'market_cap_usd': 1227162.0,
#   'max_supply': None,
#   'name': 'Kolion',
#   'percent_change_1h': 0.37,
#   'percent_change_24h': 5.95,
#   'percent_change_7d': -17.85,
#   'price_btc': 0.00019777,
#   'price_usd': 2.04527,
#   'rank': 971,
#   'symbol': 'KLN',
#   'total_supply': 1000000.0},
#  {'24h_volume_usd': 430.864,
#   'available_supply': 24004145.0,
#   'id': 'smartcoin',
#   'last_updated': 1519683541,
#   'market_cap_usd': 1187655.0,
#   'max_supply': None,
#   'name': 'SmartCoin',
#   'percent_change_1h': -0.25,
#   'percent_change_24h': 7.85,
#   'percent_change_7d': -17.06,
#   'price_btc': 4.78e-06,
#   'price_usd': 0.0494771,
#   'rank': 972,
#   'symbol': 'SMC',
#   'total_supply': 24004145.0},
#  {'24h_volume_usd': 193.935,
#   'available_supply': 73590685.0,
#   'id': 'grimcoin',
#   'last_updated': 1519683556,
#   'market_cap_usd': 1183154.0,
#   'max_supply': None,
#   'name': 'Grimcoin',
#   'percent_change_1h': 23.49,
#   'percent_change_24h': 36.83,
#   'percent_change_7d': -4.36,
#   'price_btc': 1.55e-06,
#   'price_usd': 0.0160775,
#   'rank': 973,
#   'symbol': 'GRIM',
#   'total_supply': 87757424.0},
#  {'24h_volume_usd': 27.3185,
#   'available_supply': 10996318099.0,
#   'id': 'hitcoin',
#   'last_updated': 1519683546,
#   'market_cap_usd': 1137173.0,
#   'max_supply': None,
#   'name': 'HitCoin',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': 7.62,
#   'percent_change_7d': -31.4,
#   'price_btc': 1e-08,
#   'price_usd': 0.000103414,
#   'rank': 974,
#   'symbol': 'HTC',
#   'total_supply': 20996318099.0},
#  {'24h_volume_usd': None,
#   'available_supply': 35300866.0,
#   'id': 'rustbits',
#   'last_updated': 1519386252,
#   'market_cap_usd': 1085067.0,
#   'max_supply': None,
#   'name': 'Rustbits',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': None,
#   'price_btc': 3.04e-06,
#   'price_usd': 0.0307377,
#   'rank': 975,
#   'symbol': 'RUSTBITS',
#   'total_supply': 100000000.0},
#  {'24h_volume_usd': 197.355,
#   'available_supply': 2987779.0,
#   'id': 'unicoin',
#   'last_updated': 1519683545,
#   'market_cap_usd': 1010670.0,
#   'max_supply': None,
#   'name': 'UniCoin',
#   'percent_change_1h': 0.43,
#   'percent_change_24h': -4.11,
#   'percent_change_7d': -3.91,
#   'price_btc': 3.271e-05,
#   'price_usd': 0.338268,
#   'rank': 976,
#   'symbol': 'UNIC',
#   'total_supply': 2987779.0},
#  {'24h_volume_usd': 215.447,
#   'available_supply': 9042997.0,
#   'id': 'argentum',
#   'last_updated': 1519683540,
#   'market_cap_usd': 950998.0,
#   'max_supply': None,
#   'name': 'Argentum',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': 7.28,
#   'percent_change_7d': -1.04,
#   'price_btc': 1.017e-05,
#   'price_usd': 0.105164,
#   'rank': 977,
#   'symbol': 'ARG',
#   'total_supply': 9042997.0},
#  {'24h_volume_usd': 143.216,
#   'available_supply': 24101381.0,
#   'id': 'gaia',
#   'last_updated': 1519683544,
#   'market_cap_usd': 917212.0,
#   'max_supply': None,
#   'name': 'GAIA',
#   'percent_change_1h': 0.18,
#   'percent_change_24h': -2.22,
#   'percent_change_7d': -16.11,
#   'price_btc': 3.68e-06,
#   'price_usd': 0.0380564,
#   'rank': 978,
#   'symbol': 'GAIA',
#   'total_supply': 24101381.0},
#  {'24h_volume_usd': 4.5494,
#   'available_supply': 10343113.0,
#   'id': 'ultimate-secure-cash',
#   'last_updated': 1519683549,
#   'market_cap_usd': 904903.0,
#   'max_supply': 200084200.0,
#   'name': 'Ultimate Secure Cash',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': 7.62,
#   'percent_change_7d': -22.68,
#   'price_btc': 8.46e-06,
#   'price_usd': 0.0874885,
#   'rank': 979,
#   'symbol': 'USC',
#   'total_supply': 38602656.0},
#  {'24h_volume_usd': None,
#   'available_supply': 76925527.0,
#   'id': 'metalcoin',
#   'last_updated': 1519662844,
#   'market_cap_usd': 885990.0,
#   'max_supply': None,
#   'name': 'MetalCoin',
#   'percent_change_1h': None,
#   'percent_change_24h': 7.01,
#   'percent_change_7d': -42.03,
#   'price_btc': 1.12e-06,
#   'price_usd': 0.0115175,
#   'rank': 980,
#   'symbol': 'METAL',
#   'total_supply': 76925527.0},
#  {'24h_volume_usd': None,
#   'available_supply': 210806.0,
#   'id': 'flycoin',
#   'last_updated': 1519461545,
#   'market_cap_usd': 824437.0,
#   'max_supply': None,
#   'name': 'Flycoin',
#   'percent_change_1h': None,
#   'percent_change_24h': None,
#   'percent_change_7d': 28.73,
#   'price_btc': 0.00038917,
#   'price_usd': 3.91089,
#   'rank': 981,
#   'symbol': 'FLY',
#   'total_supply': 210806.0},
#  {'24h_volume_usd': 47.7354,
#   'available_supply': 65290635.0,
#   'id': 'btctalkcoin',
#   'last_updated': 1519683542,
#   'market_cap_usd': 823739.0,
#   'max_supply': None,
#   'name': 'BTCtalkcoin',
#   'percent_change_1h': 0.18,
#   'percent_change_24h': 35.36,
#   'percent_change_7d': -15.87,
#   'price_btc': 1.22e-06,
#   'price_usd': 0.0126165,
#   'rank': 982,
#   'symbol': 'TALK',
#   'total_supply': 65290635.0},
#  {'24h_volume_usd': 76.0447,
#   'available_supply': 1.0,
#   'id': 'bit20',
#   'last_updated': 1519683553,
#   'market_cap_usd': 772614.0,
#   'max_supply': None,
#   'name': 'Bit20',
#   'percent_change_1h': 0.64,
#   'percent_change_24h': 3.26,
#   'percent_change_7d': -16.61,
#   'price_btc': 73.534,
#   'price_usd': 760447.0,
#   'rank': 983,
#   'symbol': 'BTWTY',
#   'total_supply': 1.0},
#  {'24h_volume_usd': 47.0681,
#   'available_supply': 2358819009.0,
#   'id': 'colossuscoin-v2',
#   'last_updated': 1519683544,
#   'market_cap_usd': 731807.0,
#   'max_supply': None,
#   'name': 'Colossuscoin V2',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': 7.62,
#   'percent_change_7d': 38.25,
#   'price_btc': 3e-08,
#   'price_usd': 0.000310243,
#   'rank': 984,
#   'symbol': 'CV2',
#   'total_supply': 22977351798.0},
#  {'24h_volume_usd': 364.225,
#   'available_supply': 8500001.0,
#   'id': 'octanox',
#   'last_updated': 1519683550,
#   'market_cap_usd': 729587.0,
#   'max_supply': None,
#   'name': 'Octanox',
#   'percent_change_1h': 4.65,
#   'percent_change_24h': 3.87,
#   'percent_change_7d': -27.61,
#   'price_btc': 8.3e-06,
#   'price_usd': 0.0858338,
#   'rank': 985,
#   'symbol': 'OTX',
#   'total_supply': 8500001.0},
#  {'24h_volume_usd': 137.101,
#   'available_supply': 90421856.0,
#   'id': 'tattoocoin',
#   'last_updated': 1519683548,
#   'market_cap_usd': 729371.0,
#   'max_supply': None,
#   'name': 'Tattoocoin (Standard Edition)',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': 16.59,
#   'percent_change_7d': -14.65,
#   'price_btc': 7.8e-07,
#   'price_usd': 0.00806631,
#   'rank': 986,
#   'symbol': 'TSE',
#   'total_supply': 90421856.0},
#  {'24h_volume_usd': 26.3897,
#   'available_supply': 107972766.0,
#   'id': 'signatum',
#   'last_updated': 1519683552,
#   'market_cap_usd': 703453.0,
#   'max_supply': None,
#   'name': 'Signatum',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': 9.36,
#   'percent_change_7d': -8.33,
#   'price_btc': 6.3e-07,
#   'price_usd': 0.0065151,
#   'rank': 987,
#   'symbol': 'SIGT',
#   'total_supply': 107972766.0},
#  {'24h_volume_usd': 31.8953,
#   'available_supply': 11866849.0,
#   'id': 'paycoin2',
#   'last_updated': 1519683544,
#   'market_cap_usd': 702978.0,
#   'max_supply': None,
#   'name': 'PayCoin',
#   'percent_change_1h': 1.06,
#   'percent_change_24h': 5.13,
#   'percent_change_7d': -26.78,
#   'price_btc': 5.73e-06,
#   'price_usd': 0.0592388,
#   'rank': 988,
#   'symbol': 'XPY',
#   'total_supply': 11866849.0},
#  {'24h_volume_usd': 494.444,
#   'available_supply': 4225992.0,
#   'id': 'sterlingcoin',
#   'last_updated': 1519683543,
#   'market_cap_usd': 701008.0,
#   'max_supply': None,
#   'name': 'Sterlingcoin',
#   'percent_change_1h': 3.59,
#   'percent_change_24h': 10.1,
#   'percent_change_7d': -11.69,
#   'price_btc': 1.604e-05,
#   'price_usd': 0.16588,
#   'rank': 989,
#   'symbol': 'SLG',
#   'total_supply': 4225992.0},
#  {'24h_volume_usd': 322.891,
#   'available_supply': 8495891.0,
#   'id': 'securecoin',
#   'last_updated': 1519683540,
#   'market_cap_usd': 695298.0,
#   'max_supply': None,
#   'name': 'SecureCoin',
#   'percent_change_1h': 0.13,
#   'percent_change_24h': 2.87,
#   'percent_change_7d': -35.99,
#   'price_btc': 7.91e-06,
#   'price_usd': 0.0818393,
#   'rank': 990,
#   'symbol': 'SRC',
#   'total_supply': 8495891.0},
#  {'24h_volume_usd': 230.851,
#   'available_supply': 29443544.0,
#   'id': 'icoin',
#   'last_updated': 1519683541,
#   'market_cap_usd': 663784.0,
#   'max_supply': None,
#   'name': 'iCoin',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': 25.54,
#   'percent_change_7d': 53.99,
#   'price_btc': 2.18e-06,
#   'price_usd': 0.0225443,
#   'rank': 991,
#   'symbol': 'ICN',
#   'total_supply': 29443544.0},
#  {'24h_volume_usd': 266.849,
#   'available_supply': 15419952.0,
#   'id': 'goldblocks',
#   'last_updated': 1519683547,
#   'market_cap_usd': 646768.0,
#   'max_supply': None,
#   'name': 'GoldBlocks',
#   'percent_change_1h': 0.45,
#   'percent_change_24h': 7.72,
#   'percent_change_7d': -20.68,
#   'price_btc': 4.06e-06,
#   'price_usd': 0.0419436,
#   'rank': 992,
#   'symbol': 'GB',
#   'total_supply': 15419952.0},
#  {'24h_volume_usd': 1.03414,
#   'available_supply': 6106836540.0,
#   'id': 'valorbit',
#   'last_updated': 1519683546,
#   'market_cap_usd': 631532.0,
#   'max_supply': None,
#   'name': 'Valorbit',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': 7.63,
#   'percent_change_7d': -7.85,
#   'price_btc': 1e-08,
#   'price_usd': 0.000103414,
#   'rank': 993,
#   'symbol': 'VAL',
#   'total_supply': 922343306836540},
#  {'24h_volume_usd': 246.156,
#   'available_supply': 172426805.0,
#   'id': 'truckcoin',
#   'last_updated': 1519683542,
#   'market_cap_usd': 624099.0,
#   'max_supply': None,
#   'name': 'Truckcoin',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': 14.15,
#   'percent_change_7d': 10.9,
#   'price_btc': 3.5e-07,
#   'price_usd': 0.0036195,
#   'rank': 994,
#   'symbol': 'TRK',
#   'total_supply': 172426805.0},
#  {'24h_volume_usd': 325.824,
#   'available_supply': 12598358.0,
#   'id': 'gapcoin',
#   'last_updated': 1519683544,
#   'market_cap_usd': 624065.0,
#   'max_supply': None,
#   'name': 'Gapcoin',
#   'percent_change_1h': 0.18,
#   'percent_change_24h': 8.76,
#   'percent_change_7d': -5.53,
#   'price_btc': 4.79e-06,
#   'price_usd': 0.0495354,
#   'rank': 995,
#   'symbol': 'GAP',
#   'total_supply': 12598358.0},
#  {'24h_volume_usd': 107.316,
#   'available_supply': 5118307.0,
#   'id': 'digital-developers-fund',
#   'last_updated': 1519683552,
#   'market_cap_usd': 622197.0,
#   'max_supply': 6428932.0,
#   'name': 'DigitalDevelopersFund',
#   'percent_change_1h': 0.13,
#   'percent_change_24h': 8.71,
#   'percent_change_7d': -14.67,
#   'price_btc': 1.175e-05,
#   'price_usd': 0.121563,
#   'rank': 996,
#   'symbol': 'DDF',
#   'total_supply': 6428932.0},
#  {'24h_volume_usd': 78.1844,
#   'available_supply': 5428300.0,
#   'id': 'blockpay',
#   'last_updated': 1519683547,
#   'market_cap_usd': 614294.0,
#   'max_supply': None,
#   'name': 'BlockPay',
#   'percent_change_1h': 0.3,
#   'percent_change_24h': -15.96,
#   'percent_change_7d': 8.37,
#   'price_btc': 1.094e-05,
#   'price_usd': 0.113165,
#   'rank': 997,
#   'symbol': 'BLOCKPAY',
#   'total_supply': 98928316.0},
#  {'24h_volume_usd': 33.492,
#   'available_supply': 196447.0,
#   'id': 'prototanium',
#   'last_updated': 1519683546,
#   'market_cap_usd': 574967.0,
#   'max_supply': None,
#   'name': 'Prototanium',
#   'percent_change_1h': 0.18,
#   'percent_change_24h': 25.54,
#   'percent_change_7d': -15.09,
#   'price_btc': 0.00028302,
#   'price_usd': 2.92683,
#   'rank': 998,
#   'symbol': 'PR',
#   'total_supply': 196447.0},
#  {'24h_volume_usd': 487.173,
#   'available_supply': 19012321.0,
#   'id': 'motocoin',
#   'last_updated': 1519683544,
#   'market_cap_usd': 569699.0,
#   'max_supply': None,
#   'name': 'Motocoin',
#   'percent_change_1h': 1.12,
#   'percent_change_24h': -5.08,
#   'percent_change_7d': -21.78,
#   'price_btc': 2.9e-06,
#   'price_usd': 0.0299647,
#   'rank': 999,
#   'symbol': 'MOTO',
#   'total_supply': 31542951.0},
#  {'24h_volume_usd': 4.5919,
#   'available_supply': 100040708.0,
#   'id': 'wayguide',
#   'last_updated': 1519683547,
#   'market_cap_usd': 569010.0,
#   'max_supply': None,
#   'name': 'WayGuide',
#   'percent_change_1h': 0.25,
#   'percent_change_24h': 51.78,
#   'percent_change_7d': 16.19,
#   'price_btc': 5.5e-07,
#   'price_usd': 0.00568778,
#   'rank': 1000,
#   'symbol': 'WAY',
#   'total_supply': 100040708.0},
#  ...]

# %% [markdown]
# You can pass a currency through symbol or coin slug:

# %%
data_from_symbol = cmc.ticker("BTC")
data_from_slug = cmc.ticker("bitcoin")

data_from_slug
# Out:
# {'24h_volume_usd': 7289990000.0,
#  'available_supply': 16888112.0,
#  'id': 'bitcoin',
#  'last_updated': 1519683567,
#  'market_cap_usd': 175768092074,
#  'max_supply': 21000000.0,
#  'name': 'Bitcoin',
#  'percent_change_1h': 0.26,
#  'percent_change_24h': 7.4,
#  'percent_change_7d': -7.77,
#  'price_btc': 1.0,
#  'price_usd': 10407.8,
#  'rank': 1,
#  'symbol': 'BTC',
#  'total_supply': 16888112.0}

# %% [markdown]
# To get all symbols and slugs you can use the next attributes:

# %%
all_symbols = cmc.symbols
all_slugs = cmc.coins

all_symbols
# Out:
# ['$$$',
#  '1337',
#  '1ST',
#  '2GIVE',
#  '300',
#  '42',
#  '611',
#  '808',
#  '888',
#  '8BIT',
#  'AAC',
#  'ABC',
#  'ABJ',
#  'ABN',
#  'ABT',
#  'ABY',
#  'AC',
#  'ACAT',
#  'ACC',
#  'ACE',
#  'ACES',
#  'ACN',
#  'ACOIN',
#  'ACP',
#  'ACT',
#  'ADA',
#  'ADB',
#  'ADC',
#  'ADCN',
#  'ADK',
#  'ADST',
#  'ADT',
#  'ADX',
#  'ADZ',
#  'AE',
#  'AEON',
#  'AERM',
#  'AGI',
#  'AGLC',
#  'AGRS',
#  'AHT',
#  'AI',
#  'AIB',
#  'AID',
#  'AIDOC',
#  'AION',
#  'AIR',
#  'AIT',
#  'AIX',
#  'AKY',
#  'ALIS',
#  'ALL',
#  'ALQO',
#  'ALT',
#  'ALTC',
#  'ALTCOM',
#  'AMB',
#  'AMBER',
#  'AMM',
#  'AMMO',
#  'AMP',
#  'AMS',
#  'ANC',
#  'ANI',
#  'ANT',
#  'ANTI',
#  'ANTX',
#  'APC',
#  'APPC',
#  'APX',
#  'ARB',
#  'ARC',
#  'ARCO',
#  'ARCT',
#  'ARDR',
#  'ARG',
#  'ARGUS',
#  'ARI',
#  'ARK',
#  'ARN',
#  'ART',
#  'ARY',
#  'ASAFE2',
#  'ASN',
#  'AST',
#  'ATB',
#  'ATL',
#  'ATM',
#  'ATMC',
#  'ATMS',
#  'ATN',
#  'ATOM',
#  'ATS',
#  'ATX',
#  'AU',
#  'AUR',
#  'AURA',
#  'AV',
#  'AVH',
#  'AVT',
#  'AWR',
#  'AXIOM',
#  'AXP',
#  'B2B',
#  'B2X',
#  'B@',
#  'BAC',
#  'BAR',
#  'BAS',
#  'BASH',
#  'BAT',
#  'BAY',
#  'BBP',
#  'BBR',
#  'BBT',
#  'BCA',
#  'BCC',
#  'BCD',
#  'BCDN',
#  'BCF',
#  'BCH',
#  'BCN',
#  'BCO',
#  'BCPT',
#  'BCX',
#  'BCY',
#  'BDG',
#  'BDL',
#  'BELA',
#  'BENJI',
#  'BERN',
#  'BEST',
#  'BET',
#  'BIG',
#  'BIGUP',
#  'BIO',
#  'BIOB',
#  'BIOS',
#  'BIP',
#  'BIRDS',
#  'BIS',
#  'BIT',
#  'BITB',
#  'BITBTC',
#  'BITCF',
#  'BITCNY',
#  'BITEUR',
#  'BITGOLD',
#  'BITOK',
#  'BITS',
#  'BITSILVER',
#  'BITUSD',
#  'BITZ',
#  'BIX',
#  'BKX',
#  'BLAZR',
#  'BLC',
#  'BLITZ',
#  'BLK',
#  'BLN',
#  'BLOCK',
#  'BLOCKPAY',
#  'BLRY',
#  'BLT',
#  'BLU',
#  'BLUE',
#  'BLZ',
#  'BMC',
#  'BNB',
#  'BNT',
#  'BNTY',
#  'BNX',
#  'BOAT',
#  'BOLI',
#  'BON',
#  'BOS',
#  'BOST',
#  'BOT',
#  'BPC',
#  'BPL',
#  'BPT',
#  'BQ',
#  'BRAIN',
#  'BRAT',
#  'BRD',
#  'BRIA',
#  'BRIT',
#  'BRK',
#  'BRO',
#  'BRX',
#  'BSC',
#  'BSD',
#  'BSN',
#  'BSR',
#  'BSTAR',
#  'BSTY',
#  'BT2',
#  'BTA',
#  'BTB',
#  'BTBc',
#  'BTC',
#  'BTCA',
#  'BTCD',
#  'BTCM',
#  'BTCR',
#  'BTCRED',
#  'BTCS',
#  'BTCZ',
#  'BTDX',
#  'BTE',
#  'BTG',
#  'BTM',
#  'BTO',
#  'BTPL',
#  'BTQ',
#  'BTS',
#  'BTW',
#  'BTWTY',
#  'BTX',
#  'BUB',
#  'BUCKS',
#  'BUMBA',
#  'BUN',
#  'BURST',
#  'BUZZ',
#  'BWK',
#  'BXC',
#  'BXT',
#  'BYC',
#  'C2',
#  'C20',
#  'CAB',
#  'CACH',
#  'CAG',
#  'CALC',
#  'CAN',
#  'CANDY',
#  'CANN',
#  'CAPP',
#  'CARBON',
#  'CAS',
#  'CASH',
#  'CAT',
#  'CBX',
#  'CC',
#  'CCM100',
#  'CCN',
#  'CCO',
#  'CCRB',
#  'CCT',
#  'CDN',
#  'CDT',
#  'CDX',
#  'CEFS',
#  'CESC',
#  'CF',
#  'CFC',
#  'CFD',
#  'CFI',
#  'CFT',
#  'CFUN',
#  'CHAN',
#  'CHAT',
#  'CHC',
#  'CHEAP',
#  'CHESS',
#  'CHIPS',
#  'CHSB',
#  'CJ',
#  'CL',
#  'CLAM',
#  'CLD',
#  'CLOAK',
#  'CLUB',
#  'CME',
#  'CMP',
#  'CMPCO',
#  'CMS',
#  'CMT',
#  'CND',
#  'CNNC',
#  'CNO',
#  'CNT',
#  'CNX',
#  'COAL',
#  'COB',
#  'COFI',
#  'COLX',
#  'CON',
#  'CONX',
#  'COR',
#  'COSS',
#  'COUPE',
#  'COV',
#  'COVAL',
#  'COXST',
#  'CPAY',
#  'CPC',
#  'CPN',
#  'CPY',
#  'CRAVE',
#  'CRB',
#  'CRC',
#  'CRDNC',
#  'CREA',
#  'CRED',
#  'CREDO',
#  'CREVA',
#  'CRM',
#  'CRPT',
#  'CRT',
#  'CRW',
#  'CRX',
#  'CSC',
#  'CSNO',
#  'CTIC2',
#  'CTIC3',
#  'CTO',
#  'CTR',
#  'CTX',
#  'CUBE',
#  'CURE',
#  'CV',
#  'CV2',
#  'CVC',
#  'CVCOIN',
#  'CWXT',
#  'CXO',
#  'CXT',
#  'CYC',
#  'CYDER',
#  'CYP',
#  'DADI',
#  'DAI',
#  'DALC',
#  'DAR',
#  'DASH',
#  'DASHS',
#  'DAT',
#  'DATA',
#  'DAV',
#  'DAXX',
#  'DAY',
#  'DBC',
#  'DBET',
#  'DBG',
#  'DBIX',
#  'DBTC',
#  'DCN',
#  'DCR',
#  'DCRE',
#  'DCT',
#  'DCY',
#  'DDD',
#  'DDF',
#  'DEM',
#  'DENT',
#  'DES',
#  'DEUS',
#  'DEW',
#  'DFS',
#  'DFT',
#  'DGB',
#  'DGC',
#  'DGCS',
#  'DGD',
#  'DGPT',
#  'DIBC',
#  'DICE',
#  'DIM',
#  'DIME',
#  'DISK',
#  'DIVX',
#  'DIX',
#  'DLC',
#  'DLISK',
#  'DLT',
#  'DMB',
#  'DMC',
#  'DMD',
#  'DMT',
#  'DNA',
#  'DNR',
#  'DNT',
#  'DOGE',
#  'DOLLAR',
#  'DON',
#  'DOPE',
#  'DOT',
#  'DOVU',
#  'DP',
#  'DPY',
#  'DRGN',
#  'DRM',
#  'DRP',
#  'DRPU',
#  'DRS',
#  'DRT',
#  'DRXNE',
#  'DSH',
#  'DSR',
#  'DTA',
#  'DTB',
#  'DTC',
#  'DTH',
#  'DTR',
#  'DUB',
#  'DUO',
#  'DUTCH',
#  'DXT',
#  'DYN',
#  'EAC',
#  'EAG',
#  'EAGLE',
#  'EBCH',
#  'EBET',
#  'EBST',
#  'EBT',
#  'EBTC',
#  'ECA',
#  'ECASH',
#  'ECC',
#  'ECH',
#  'ECN',
#  'ECO',
#  'ECOB',
#  'EDG',
#  'EDO',
#  'EDR',
#  'EDRC',
#  'EFL',
#  'EFYT',
#  'EGC',
#  'EGG',
#  'EGO',
#  'EGOLD',
#  'EKO',
#  'EKT',
#  'EL',
#  'ELA',
#  'ELC',
#  'ELE',
#  'ELF',
#  'ELITE',
#  'ELIX',
#  'ELLA',
#  'ELS',
#  'ELTCOIN',
#  'EMC',
#  'EMC2',
#  'EMD',
#  'EMV',
#  'ENG',
#  'ENJ',
#  'ENRG',
#  'ENT',
#  'EOS',
#  'EOT',
#  'EPC',
#  'EPY',
#  'EQL',
#  'EQT',
#  'ERA',
#  'ERC',
#  'ERC20',
#  'ERO',
#  'ERY',
#  'ESC',
#  'ESP',
#  'ESZ',
#  'ETBS',
#  'ETC',
#  'ETG',
#  'ETH',
#  'ETHD',
#  'ETHOS',
#  'ETN',
#  'ETP',
#  'ETT',
#  'EUC',
#  'EVC',
#  'EVE',
#  'EVIL',
#  'EVN',
#  'EVO',
#  'EVR',
#  'EVX',
#  'EXCL',
#  'EXN',
#  'EXP',
#  'EXRN',
#  'EXY',
#  'FAIR',
#  'FAP',
#  'FAZZ',
#  'FC2',
#  'FCN',
#  'FCT',
#  'FDX',
#  'FFC',
#  'FID',
#  'FIL',
#  'FIMK',
#  'FIRE',
#  'FJC',
#  'FLAP',
#  'FLASH',
#  'FLAX',
#  'FLDC',
#  'FLIK',
#  'FLIXX',
#  'FLO',
#  'FLT',
#  'FLY',
#  'FNC',
#  'FONZ',
#  'FOR',
#  'FOTA',
#  'FRC',
#  'FRCT',
#  'FRD',
#  'FRGC',
#  'FRK',
#  'FRN',
#  'FRST',
#  'FRWC',
#  'FSN',
#  'FST',
#  'FTC',
#  'FUCK',
#  'FUEL',
#  'FUN',
#  'FUNC',
#  'FUTC',
#  'FUZZ',
#  'FXE',
#  'FYN',
#  'FYP',
#  'G3N',
#  'GAIA',
#  'GAIN',
#  'GAM',
#  'GAME',
#  'GAP',
#  'GARY',
#  'GAS',
#  'GAT',
#  'GAY',
#  'GB',
#  'GBC',
#  'GBG',
#  'GBX',
#  'GBYTE',
#  'GCC',
#  'GCN',
#  'GCR',
#  'GCS',
#  'GDC',
#  'GEERT',
#  'GEM',
#  'GEO',
#  'GET',
#  'GJC',
#  'GLA',
#  'GLC',
#  'GLD',
#  'GLS',
#  'GLT',
#  'GML',
#  'GMT',
#  'GMX',
#  'GNO',
#  'GNT',
#  'GNX',
#  'GOD',
#  'GOLF',
#  'GOLOS',
#  'GOOD',
#  'GP',
#  'GPL',
#  'GPU',
#  'GRC',
#  'GRE',
#  'GRID',
#  'GRIM',
#  'GRLC',
#  'GRN',
#  'GRS',
#  'GRWI',
#  'GRX',
#  'GSR',
#  'GTC',
#  'GTO',
#  'GUESS',
#  'GUN',
#  'GUP',
#  'GVT',
#  'GXS',
#  'HAC',
#  'HAL',
#  'HALLO',
#  'HAT',
#  'HBC',
#  'HBN',
#  'HBT',
#  'HC',
#  'HCC',
#  'HDG',
#  'HDLB',
#  'HEAT',
#  'HERO',
#  'HGT',
#  'HIGH',
#  'HKN',
#  'HLC',
#  'HMC',
#  'HMP',
#  'HMQ',
#  'HNC',
#  'HODL',
#  'HOLD',
#  'HONEY',
#  'HORSE',
#  'HOT',
#  'HPB',
#  'HPC',
#  'HPY',
#  'HSR',
#  'HST',
#  'HT',
#  'HTC',
#  'HTML',
#  'HTML5',
#  'HUC',
#  'HUSH',
#  'HVCO',
#  'HVN',
#  'HWC',
#  'HXX',
#  'HYP',
#  'HYPER',
#  'I0C',
#  'IBANK',
#  'IC',
#  'ICE',
#  'ICN',
#  'ICOB',
#  'ICON',
#  'ICOO',
#  'ICOS',
#  'ICX',
#  'IDH',
#  'IDT',
#  'IDXM',
#  'IETH',
#  'IFC',
#  'IFLT',
#  'IFT',
#  'IGNIS',
#  'IMPS',
#  'IMS',
#  'IMX',
#  'INCNT',
#  'IND',
#  'INDI',
#  'INDIA',
#  'INF',
#  'INFX',
#  'ING',
#  'INK',
#  'INN',
#  'INPAY',
#  'INS',
#  'INSN',
#  'INT',
#  'INXT',
#  'IOC',
#  'ION',
#  'IOP',
#  'IOST',
#  'IPC',
#  'IPL',
#  'IQT',
#  'IRL',
#  'ISL',
#  'ITC',
#  'ITI',
#  'ITNS',
#  'ITT',
#  'IVZ',
#  'IXC',
#  'IXT',
#  'J',
#  'JC',
#  'JET',
#  'JEW',
#  'JIN',
#  'JIYO',
#  'JNT',
#  'JOBS',
#  'JS',
#  'JWL',
#  'KARMA',
#  'KASHH',
#  'KAYI',
#  'KB3',
#  'KBR',
#  'KCASH',
#  'KCS',
#  'KDC',
#  'KED',
#  'KEK',
#  'KEY',
#  'KICK',
#  'KIN',
#  'KLC',
#  'KLN',
#  'KMD',
#  'KNC',
#  'KOBO',
#  'KORE',
#  'KRB',
#  'KRM',
#  'KRONE',
#  'KURT',
#  'KUSH',
#  'KZC',
#  'LA',
#  'LANA',
#  'LAZ',
#  'LBC',
#  'LBTC',
#  'LCC',
#  'LCP',
#  'LCT',
#  'LDCN',
#  'LDOGE',
#  'LEA',
#  'LEAF',
#  'LEND',
#  'LEO',
#  'LEPEN',
#  'LET',
#  'LEV',
#  'LEVO',
#  'LGD',
#  'LIFE',
#  'LIGHT',
#  'LINDA',
#  'LINK',
#  'LINX',
#  'LIR',
#  'LKC',
#  'LKK',
#  'LLT',
#  'LMC',
#  'LNK',
#  'LOC',
#  'LOCI',
#  'LOG',
#  'LRC',
#  'LSK',
#  'LTB',
#  'LTC',
#  'LTCR',
#  'LTCU',
#  'LTH',
#  'LUN',
#  'LUNA',
#  'LUX',
#  'LVPS',
#  'MAC',
#  'MAD',
#  'MAG',
#  'MAGE',
#  'MAGN',
#  'MAID',
#  'MAN',
#  'MANA',
#  'MANNA',
#  'MAO',
#  'MAR',
#  'MARS',
#  'MARX',
#  'MAX',
#  'MAY',
#  'MBI',
#  'MBL',
#  'MBRS',
#  'MCAP',
#  'MCI',
#  'MCO',
#  'MCR',
#  'MCRN',
#  'MDA',
#  'MDC',
#  'MDS',
#  'MDT',
#  'MEC',
#  'MED',
#  'MEE',
#  'MEME',
#  'MER',
#  'METAL',
#  'MGC',
#  'MGM',
#  'MGO',
#  'MILO',
#  'MINEX',
#  'MINT',
#  'MIOTA',
#  'MKR',
#  'MLM',
#  'MLN',
#  'MMXVI',
#  'MNC',
#  'MND',
#  'MNE',
#  'MNM',
#  'MNTP',
#  'MNX',
#  'MOAC',
#  'MOBI',
#  'MOD',
#  'MOF',
#  'MOIN',
#  'MOJO',
#  'MONA',
#  'MONETA',
#  'MONEY',
#  'MONK',
#  'MOON',
#  'MOT',
#  'MOTO',
#  'MRJA',
#  'MRT',
#  'MSCN',
#  'MSD',
#  'MSP',
#  'MST',
#  'MTH',
#  'MTL',
#  'MTLMC3',
#  'MTN',
#  'MTNC',
#  'MTX',
#  'MUE',
#  'MUSE',
#  'MUSIC',
#  'MVC',
#  'MWAT',
#  'MXT',
#  'MYB',
#  'MYST',
#  'MZC',
#  'NAMO',
#  'NANO',
#  'NANOX',
#  'NAS',
#  'NAV',
#  'NBIT',
#  'NCASH',
#  'NDC',
#  'NEBL',
#  'NEO',
#  'NEOG',
#  'NEOS',
#  'NET',
#  'NETKO',
#  'NEU',
#  'NEVA',
#  'NEWB',
#  'NGC',
#  'NIO',
#  'NKA',
#  'NKC',
#  'NLC2',
#  'NLG',
#  'NMC',
#  'NMR',
#  'NMS',
#  'NOBL',
#  'NODC',
#  'NOTE',
#  'NOX',
#  'NRO',
#  'NSR',
#  'NTC',
#  'NTK',
#  'NTO',
#  'NTRN',
#  'NUKO',
#  'NULS',
#  'NUMUS',
#  'NVC',
#  'NVST',
#  'NXC',
#  'NXS',
#  'NXT',
#  'NYAN',
#  'NYC',
#  'OAX',
#  'OBITS',
#  'OC',
#  'OCL',
#  'OCN',
#  'OCOW',
#  'OCT',
#  'ODN',
#  'OF',
#  'OFF',
#  'OK',
#  'OMC',
#  'OMG',
#  'OMNI',
#  'ONG',
#  'ONION',
#  'ONX',
#  'OP',
#  'OPAL',
#  'OPC',
#  'OPES',
#  'OPT',
#  'ORB',
#  'ORE',
#  'ORLY',
#  'ORME',
#  'OS76',
#  'OST',
#  'OTN',
#  'OTX',
#  'OX',
#  'OXY',
#  'P7C',
#  'PAC',
#  'PAK',
#  'PARETO',
#  'PART',
#  'PASC',
#  'PASL',
#  'PAY',
#  'PAYP',
#  'PBL',
#  'PBT',
#  'PCN',
#  'PCOIN',
#  'PCS',
#  'PDC',
#  'PDG',
#  'PEPECASH',
#  'PEX',
#  'PFR',
#  'PGL',
#  'PHO',
#  'PHR',
#  'PHS',
#  'PIE',
#  'PIGGY',
#  'PING',
#  'PINK',
#  'PIPL',
#  'PIRL',
#  'PIVX',
#  'PIX',
#  'PIZZA',
#  'PKB',
#  'PKT',
#  'PLACO',
#  'PLAY',
#  'PLBT',
#  'PLC',
#  'PLNC',
#  'PLR',
#  'PLU',
#  'PLX',
#  'PND',
#  'PNX',
#  'POE',
#  'POKE',
#  'POLIS',
#  'POLL',
#  'POLY',
#  'PONZI',
#  'POP',
#  'POS',
#  'POST',
#  'POSW',
#  'POT',
#  'POWR',
#  'PPC',
#  'PPP',
#  'PPT',
#  'PPY',
#  'PR',
#  'PRA',
#  'PRC',
#  'PRE',
#  'PRES',
#  'PRG',
#  'PRIMU',
#  ...]

# %% [markdown]
# Other parameters:

# %%
print(cmc.ticker.__doc__)
# Out:
# Get currencies with other aditional data.
#
#         Args:
#             currency (str, optional): Specify a currency to return data,
#                 that can be a symbol or coin slug (see ``symbols`` and ``coins``
#                 properties). In this case the method returns a dict, otherwise
#                 returns a list. If you dont specify a currency,
#                 returns data for all in coinmarketcap. As default, ``None``.
#             limit (int, optional): Limit amount of coins on response.
#                 If ``limit == 0``, returns all coins in coinmarketcap.
#                 Only works if ``currency == None``. As default ``0``.
#             start (int, optional): Rank of first currency to retrieve.
#                 The count starts at 0 for the first currency ranked.
#                 Only works if ``currency == None``. As default ``0``.
#             convert (str, optional): Allows to convert prices, 24h volumes
#                 and market capitalizations in terms of one of badges
#                 returned by ``ticker_badges`` property. As default, ``"USD"``.
#
#         Returns (dict/list):
#             The type depends if currency param is provided or not.

# %% [markdown]
# If you want to get the valid badges that can be passed to `convert` param programatically, use this:

# %%
print(cmc.ticker_badges)
# Out:
# ['AUD', 'BRL', 'CAD', 'CHF', 'CLP', 'CNY', 'CZK', 'DKK', 'EUR', 'GBP', 'HKD', 'HUF', 'IDR', 'ILS', 'INR', 'JPY', 'KRW', 'MXN', 'MYR', 'NOK', 'NZD', 'PHP', 'PKR', 'PLN', 'RUB', 'SEK', 'SGD', 'THB', 'TRY', 'TWD', 'USD', 'ZAR']

# %% [markdown]
# #### `stats([convert="USD"])`
# Get global criptocurrency statistics. The `convert` parameter works just like in previous method.

# %%
cmc.stats()
# Out:
# {'active_assets': 588,
#  'active_currencies': 902,
#  'active_markets': 8787,
#  'bitcoin_percentage_of_market_cap': 38.78,
#  'last_updated': 1519674869,
#  'total_24h_volume_usd': 18773000578.0,
#  'total_market_cap_usd': 448784568679.0}

# %% [markdown]
# _____________________________________________
#
# ## Web scraper

# %% [markdown]
# #### `currency(name, [convert="USD"])`
# Get metadata from a currency passed as first argument.

# %%
cmc.currency("BTC")
# Out:
# {'announcement': None,
#  'chats': [],
#  'circulating_supply': 16887850.0,
#  'explorers': ['http://blockchain.info',
#   'https://live.blockcypher.com/btc/',
#   'https://blockchair.com/bitcoin/blocks'],
#  'max_supply': 21000000.0,
#  'message_boards': ['https://bitcointalk.org', 'https://forum.bitcoin.com/'],
#  'mineable': True,
#  'price': 10305.2,
#  'rank': 1,
#  'source_code': 'https://github.com/bitcoin/',
#  'total_markets_cap': 174032671820.0,
#  'total_markets_volume_24h': 7151920000.0,
#  'webs': ['https://bitcoin.org/', 'https://bitcoin.com/']}

# %%
show_page("currencies/bitcoin")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/currencies/bitcoin"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `markets(name, [convert="USD"])`
# Get all markets for a exchange in coinmarketcap. Pass a currency symbol or slug as first parameter. You can convert the response fields `"volume_24h"` and `"price"` between `"USD"` and `"BTC"` with `convert` parameter.

# %%
cmc.markets("BTC", convert="BTC")
# Out:
# [{'pair': 'BTC/USDT',
#   'percent_volume': 7.04220684795,
#   'price': 1.00414,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 49290.4},
#  {'pair': 'BTC/USD',
#   'percent_volume': 6.30127294489,
#   'price': 1.00146,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 44104.5},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 4.74254465934,
#   'price': 1.00587,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 33194.4},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 3.73891206837,
#   'price': 1.06875,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 26169.7},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 3.39624883947,
#   'price': 1.00726,
#   'source': 'bitFlyer',
#   'updated': True,
#   'volume_24h': 23771.3},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 3.2200304254,
#   'price': 1.06856,
#   'source': 'Bithumb',
#   'updated': True,
#   'volume_24h': 22537.9},
#  {'pair': 'BTC/USD',
#   'percent_volume': 2.49401559302,
#   'price': 1.00068,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 17456.3},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 2.1067909037,
#   'price': 1.00009,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 14746.1},
#  {'pair': 'BTC/USD',
#   'percent_volume': 2.06011812213,
#   'price': 1.00371,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 14419.4},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 2.04385675455,
#   'price': 0.9994,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 14305.6},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 1.90976688777,
#   'price': 1.00066,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 13367.0},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 1.88076768197,
#   'price': 1.00155,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 13164.0},
#  {'pair': 'NANO/BTC',
#   'percent_volume': 1.87114788756,
#   'price': 1.00969,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 13096.7},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 1.77701931789,
#   'price': 0.999167,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 12437.9},
#  {'pair': 'NCASH/BTC',
#   'percent_volume': 1.60415664605,
#   'price': 1.00662,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 11228.0},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 1.41321491292,
#   'price': 0.999179,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 9891.55},
#  {'pair': 'BTC/USD',
#   'percent_volume': 1.40381883466,
#   'price': 0.980616,
#   'source': 'BTCC',
#   'updated': True,
#   'volume_24h': 9825.77},
#  {'pair': 'VEN/BTC',
#   'percent_volume': 1.28438377387,
#   'price': 1.00511,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 8989.77},
#  {'pair': 'BTC/USD',
#   'percent_volume': 1.23377358807,
#   'price': 1.0034,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 8635.54},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 1.16180270473,
#   'price': 1.0006,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 8131.79},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 1.04093306413,
#   'price': 1.00062,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 7285.79},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.881613608653,
#   'price': 1.00364,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 6170.66},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.82993378002,
#   'price': 1.02323,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 5808.95},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.829465374333,
#   'price': 0.995459,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 5805.67},
#  {'pair': 'BCPT/BTC',
#   'percent_volume': 0.806119195964,
#   'price': 0.997834,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 5642.26},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.77035956778,
#   'price': 1.00007,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 5391.97},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.669992114006,
#   'price': 1.00243,
#   'source': 'Gemini',
#   'updated': True,
#   'volume_24h': 4689.47},
#  {'pair': 'ICX/BTC',
#   'percent_volume': 0.634923209432,
#   'price': 0.996527,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 4444.01},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.622715298829,
#   'price': 1.00502,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 4358.57},
#  {'pair': 'ELA/BTC',
#   'percent_volume': 0.597463338516,
#   'price': 0.999816,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 4181.81},
#  {'pair': 'ADA/BTC',
#   'percent_volume': 0.558182977438,
#   'price': 1.04288,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 3906.89},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.541271434804,
#   'price': 1.00155,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 3788.52},
#  {'pair': 'HT/BTC',
#   'percent_volume': 0.524417219432,
#   'price': 1.00356,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 3670.55},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.515794360116,
#   'price': 1.00604,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 3610.2},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.50229868343,
#   'price': 1.00246,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 3515.74},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.497404892672,
#   'price': 1.00518,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 3481.48},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.495278191031,
#   'price': 1.06792,
#   'source': 'Coinone',
#   'updated': True,
#   'volume_24h': 3466.6},
#  {'pair': 'DGD/BTC',
#   'percent_volume': 0.474961968255,
#   'price': 0.995554,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 3324.39},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.448222295551,
#   'price': 1.00066,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 3137.24},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.431600185684,
#   'price': 1.00033,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 3020.89},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.429411962102,
#   'price': 1.00254,
#   'source': 'itBit',
#   'updated': True,
#   'volume_24h': 3005.57},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.405561024173,
#   'price': 0.990565,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 2838.64},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.396872448238,
#   'price': 1.00333,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 2777.83},
#  {'pair': 'ZCL/BTC',
#   'percent_volume': 0.388986453987,
#   'price': 1.01621,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 2722.63},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.38884103849,
#   'price': 0.998836,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 2721.61},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.374236568642,
#   'price': 1.07094,
#   'source': 'Korbit',
#   'updated': True,
#   'volume_24h': 2619.39},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.366723900715,
#   'price': 0.991602,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 2566.8},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.362304108547,
#   'price': 0.981514,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 2535.87},
#  {'pair': 'ADA/BTC',
#   'percent_volume': 0.360921263101,
#   'price': 1.0442,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 2526.19},
#  {'pair': 'BNB/BTC',
#   'percent_volume': 0.359809673486,
#   'price': 1.00325,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 2518.41},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.330663653956,
#   'price': 1.00014,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 2314.41},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.313033423193,
#   'price': 1.00114,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 2191.01},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.307264343002,
#   'price': 1.00039,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 2150.63},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.294655141556,
#   'price': 1.00038,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 2062.38},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.293715533731,
#   'price': 1.00419,
#   'source': 'Bitbank',
#   'updated': True,
#   'volume_24h': 2055.8},
#  {'pair': 'EKT/BTC',
#   'percent_volume': 0.292075414714,
#   'price': 1.00679,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 2044.32},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.289051052025,
#   'price': 1.00155,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 2023.15},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.282381514335,
#   'price': 0.989375,
#   'source': 'CoinsBank',
#   'updated': True,
#   'volume_24h': 1976.47},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.270223939865,
#   'price': 0.988047,
#   'source': 'CoinsBank',
#   'updated': True,
#   'volume_24h': 1891.38},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.26908158928,
#   'price': 1.00061,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 1883.38},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.267561717693,
#   'price': 1.00024,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1872.74},
#  {'pair': 'ARN/BTC',
#   'percent_volume': 0.267321222832,
#   'price': 1.00615,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1871.06},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.259482768264,
#   'price': 1.00069,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1816.2},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.252811832347,
#   'price': 0.994852,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1769.51},
#  {'pair': 'BCPT/BTC',
#   'percent_volume': 0.252139285674,
#   'price': 0.991032,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 1764.79},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.250711696999,
#   'price': 1.01451,
#   'source': 'CEX.IO',
#   'updated': True,
#   'volume_24h': 1754.8},
#  {'pair': 'ADA/BTC',
#   'percent_volume': 0.24801731563,
#   'price': 1.0419,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 1735.95},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.240429143503,
#   'price': 0.996617,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 1682.83},
#  {'pair': 'BTC/GBP',
#   'percent_volume': 0.229857157239,
#   'price': 1.00295,
#   'source': 'CoinsBank',
#   'updated': True,
#   'volume_24h': 1608.84},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.229177619436,
#   'price': 1.00039,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1604.08},
#  {'pair': 'BCPT/BTC',
#   'percent_volume': 0.224679526617,
#   'price': 0.991119,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1572.6},
#  {'pair': 'ABT/BTC',
#   'percent_volume': 0.215389713531,
#   'price': 0.98711,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1507.57},
#  {'pair': 'BITB/BTC',
#   'percent_volume': 0.20521202698,
#   'price': 0.995722,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 1436.34},
#  {'pair': 'RDD/BTC',
#   'percent_volume': 0.205100168906,
#   'price': 0.996677,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 1435.55},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.205070806161,
#   'price': 0.99834,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1435.35},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.204937974698,
#   'price': 0.998253,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 1434.42},
#  {'pair': 'TRUE/BTC',
#   'percent_volume': 0.195428640141,
#   'price': 1.00212,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 1367.87},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.191647837224,
#   'price': 1.0018,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1341.4},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.18694839987,
#   'price': 0.997458,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1308.5},
#  {'pair': 'RDD/BTC',
#   'percent_volume': 0.180250897661,
#   'price': 1.00706,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1261.62},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.179851005045,
#   'price': 1.02417,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 1258.83},
#  {'pair': 'BTC/PLN',
#   'percent_volume': 0.177139844965,
#   'price': 1.00516,
#   'source': 'BitBay',
#   'updated': True,
#   'volume_24h': 1239.85},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.176538607814,
#   'price': 0.94832,
#   'source': 'Simex',
#   'updated': True,
#   'volume_24h': 1235.64},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.170945704091,
#   'price': 1.00166,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 1196.5},
#  {'pair': 'BTC/TRY',
#   'percent_volume': 0.170312307744,
#   'price': 0.99566,
#   'source': 'Paribu',
#   'updated': True,
#   'volume_24h': 1192.06},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.167100582781,
#   'price': 0.994852,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 1169.59},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.164569793846,
#   'price': 0.99808,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 1151.87},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.160198939585,
#   'price': 1.00122,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 1121.28},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.159442499357,
#   'price': 0.994637,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 1115.99},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.158442767816,
#   'price': 1.01292,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 1108.99},
#  {'pair': 'WAVES/BTC',
#   'percent_volume': 0.153901329993,
#   'price': 1.00291,
#   'source': 'Tidex',
#   'updated': True,
#   'volume_24h': 1077.2},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.153225986868,
#   'price': 1.00023,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 1072.47},
#  {'pair': 'BITB/BTC',
#   'percent_volume': 0.152322732916,
#   'price': 0.995722,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 1066.15},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.152307352431,
#   'price': 0.999646,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 1066.05},
#  {'pair': 'CDT/BTC',
#   'percent_volume': 0.151229320238,
#   'price': 1.02389,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1058.5},
#  {'pair': 'SNGLS/BTC',
#   'percent_volume': 0.147947683979,
#   'price': 1.00519,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1035.53},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.145675566841,
#   'price': 1.00165,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1019.62},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.142890300786,
#   'price': 1.00084,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 1000.13},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.141884976342,
#   'price': 0.98791,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 993.092},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.141640286804,
#   'price': 1.00158,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 991.382},
#  {'pair': 'ADX/BTC',
#   'percent_volume': 0.134554077786,
#   'price': 0.996487,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 941.783},
#  {'pair': 'SWFTC/BTC',
#   'percent_volume': 0.134153066589,
#   'price': 1.00341,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 938.976},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.131726445486,
#   'price': 1.02132,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 921.992},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.129985234734,
#   'price': 1.00585,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 909.804},
#  {'pair': 'IOTA/BTC',
#   'percent_volume': 0.129335898612,
#   'price': 0.996176,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 905.259},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.12816572333,
#   'price': 1.05986,
#   'source': 'LakeBTC',
#   'updated': True,
#   'volume_24h': 897.069},
#  {'pair': 'BTC/RUB',
#   'percent_volume': 0.124119117664,
#   'price': 0.951877,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 868.746},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.119329075269,
#   'price': 1.00063,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 835.219},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.118803342319,
#   'price': 0.983514,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 831.539},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.118582562445,
#   'price': 1.03672,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 829.993},
#  {'pair': 'INS/BTC',
#   'percent_volume': 0.118041169364,
#   'price': 1.00104,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 826.204},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.117752715355,
#   'price': 1.00012,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 824.185},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.116204599604,
#   'price': 0.99991,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 813.349},
#  {'pair': 'VEN/BTC',
#   'percent_volume': 0.115127406347,
#   'price': 0.998025,
#   'source': 'Lbank',
#   'updated': True,
#   'volume_24h': 805.809},
#  {'pair': 'RPX/BTC',
#   'percent_volume': 0.114127814629,
#   'price': 1.00358,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 798.813},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.112108916207,
#   'price': 1.00338,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 784.683},
#  {'pair': 'INS/BTC',
#   'percent_volume': 0.11084030582,
#   'price': 1.0017,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 775.804},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.110839466884,
#   'price': 1.00033,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 775.797},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.10687172116,
#   'price': 1.00234,
#   'source': 'Neraex',
#   'updated': True,
#   'volume_24h': 748.026},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.106076130605,
#   'price': 1.00024,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 742.458},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.10338300764,
#   'price': 0.990528,
#   'source': 'Lbank',
#   'updated': True,
#   'volume_24h': 723.607},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.0998604570521,
#   'price': 0.974041,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 698.952},
#  {'pair': 'RLC/BTC',
#   'percent_volume': 0.0994767838566,
#   'price': 1.00784,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 696.267},
#  {'pair': 'WTC/BTC',
#   'percent_volume': 0.0992290182217,
#   'price': 1.01478,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 694.532},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0987425754203,
#   'price': 1.00272,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 691.128},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0980944977013,
#   'price': 0.992135,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 686.592},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0954809337912,
#   'price': 1.00291,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 668.299},
#  {'pair': 'ITC/BTC',
#   'percent_volume': 0.0936598843388,
#   'price': 1.00204,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 655.552},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0931774963926,
#   'price': 1.00064,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 652.176},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0930250897661,
#   'price': 1.0018,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 651.109},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0929118334657,
#   'price': 0.996617,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 650.317},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0925161355272,
#   'price': 1.00084,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 647.547},
#  {'pair': 'ENJ/BTC',
#   'percent_volume': 0.0916703486616,
#   'price': 0.99075,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 641.627},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0915482835378,
#   'price': 0.998428,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 640.773},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0904092886945,
#   'price': 1.0018,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 632.801},
#  {'pair': 'NBT/BTC',
#   'percent_volume': 0.0903814639985,
#   'price': 1.00317,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 632.606},
#  {'pair': 'PROPY/BTC',
#   'percent_volume': 0.0875455821653,
#   'price': 1.0003,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 612.757},
#  {'pair': 'BTC/BITCNY',
#   'percent_volume': 0.0870152350697,
#   'price': 0.990447,
#   'source': 'AEX',
#   'updated': True,
#   'volume_24h': 609.045},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0865689213526,
#   'price': 1.00312,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 605.921},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0863232530565,
#   'price': 0.995857,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 604.201},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0861207899417,
#   'price': 1.00013,
#   'source': 'Tidex',
#   'updated': True,
#   'volume_24h': 602.784},
#  {'pair': 'BTC/RUB',
#   'percent_volume': 0.0860008221568,
#   'price': 1.04706,
#   'source': 'GetBTC',
#   'updated': True,
#   'volume_24h': 601.945},
#  {'pair': 'VEN/BTC',
#   'percent_volume': 0.0842397565968,
#   'price': 1.00183,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 589.618},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0838295171087,
#   'price': 0.999979,
#   'source': 'Gate.io',
#   'updated': True,
#   'volume_24h': 586.747},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0832970726742,
#   'price': 1.01414,
#   'source': 'GetBTC',
#   'updated': True,
#   'volume_24h': 583.021},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.083232894104,
#   'price': 1.01336,
#   'source': 'GetBTC',
#   'updated': True,
#   'volume_24h': 582.571},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0830516840233,
#   'price': 1.00069,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 581.302},
#  {'pair': 'WICC/BTC',
#   'percent_volume': 0.0813356413383,
#   'price': 1.00478,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 569.292},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0810396369087,
#   'price': 1.00262,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 567.22},
#  {'pair': 'IOST/BTC',
#   'percent_volume': 0.0804061007394,
#   'price': 1.00307,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 562.785},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0801872783812,
#   'price': 1.00135,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 561.253},
#  {'pair': 'BTC/ZAR',
#   'percent_volume': 0.080114151165,
#   'price': 1.03174,
#   'source': 'Luno',
#   'updated': True,
#   'volume_24h': 560.742},
#  {'pair': 'APPC/BTC',
#   'percent_volume': 0.0798409378181,
#   'price': 1.00423,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 558.83},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0792802492198,
#   'price': 0.997458,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 554.905},
#  {'pair': 'XVG/BTC',
#   'percent_volume': 0.0783420396201,
#   'price': 1.00054,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 548.338},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0782447230953,
#   'price': 1.00086,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 547.657},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0778073580241,
#   'price': 0.998794,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 544.596},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0766183066925,
#   'price': 0.990477,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 536.274},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.0754895188984,
#   'price': 1.0382,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 528.372},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0752242754393,
#   'price': 1.01011,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 526.516},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0750138424367,
#   'price': 0.999798,
#   'source': 'xBTCe',
#   'updated': True,
#   'volume_24h': 525.044},
#  {'pair': 'XVG/BTC',
#   'percent_volume': 0.0747350361861,
#   'price': 1.00054,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 523.092},
#  {'pair': 'BTC/TRY',
#   'percent_volume': 0.0741448450206,
#   'price': 0.997158,
#   'source': 'BTCTurk',
#   'updated': True,
#   'volume_24h': 518.961},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0727010369244,
#   'price': 0.987468,
#   'source': 'BtcTrade.im',
#   'updated': True,
#   'volume_24h': 508.855},
#  {'pair': 'BTC/BRL',
#   'percent_volume': 0.0725970089151,
#   'price': 1.0334,
#   'source': 'Negocie Coins',
#   'updated': True,
#   'volume_24h': 508.127},
#  {'pair': 'RUFF/BTC',
#   'percent_volume': 0.072399439591,
#   'price': 0.931054,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 506.745},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0718797190125,
#   'price': 1.00145,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 503.107},
#  {'pair': 'R/BTC',
#   'percent_volume': 0.0718650376402,
#   'price': 0.972868,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 503.004},
#  {'pair': 'BTC/IDR',
#   'percent_volume': 0.0715828756474,
#   'price': 1.02801,
#   'source': 'Bitcoin Indonesia',
#   'updated': True,
#   'volume_24h': 501.029},
#  {'pair': 'BTC/CNY',
#   'percent_volume': 0.0703743889753,
#   'price': 1.02429,
#   'source': 'Fatbtc',
#   'updated': True,
#   'volume_24h': 492.571},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.0702179274936,
#   'price': 0.994653,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 491.476},
#  {'pair': 'BTC/AUD',
#   'percent_volume': 0.0698711674627,
#   'price': 1.00933,
#   'source': 'BTC Markets',
#   'updated': True,
#   'volume_24h': 489.049},
#  {'pair': 'GVT/BTC',
#   'percent_volume': 0.0690457946957,
#   'price': 0.994069,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 483.271},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0688093546908,
#   'price': 0.989796,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 481.616},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0675786362264,
#   'price': 0.998629,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 473.002},
#  {'pair': 'BTC/GBP',
#   'percent_volume': 0.0674803409434,
#   'price': 0.996954,
#   'source': 'Coinfloor',
#   'updated': True,
#   'volume_24h': 472.315},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0671498003333,
#   'price': 1.00259,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 470.001},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.065657893265,
#   'price': 1.00812,
#   'source': 'Coinbene',
#   'updated': True,
#   'volume_24h': 459.559},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0655644917728,
#   'price': 1.00015,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 458.905},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0652847067641,
#   'price': 1.00417,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 456.946},
#  {'pair': 'R/BTC',
#   'percent_volume': 0.065160684124,
#   'price': 1.02302,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 456.078},
#  {'pair': 'BRD/BTC',
#   'percent_volume': 0.0647549189588,
#   'price': 1.00122,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 453.239},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0638476101522,
#   'price': 1.00091,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 446.888},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0637479166434,
#   'price': 1.00446,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 446.19},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0637458193045,
#   'price': 1.00677,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 446.175},
#  {'pair': 'BTC/THB',
#   'percent_volume': 0.0634664537635,
#   'price': 1.01786,
#   'source': 'BX Thailand',
#   'updated': True,
#   'volume_24h': 444.22},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0630311860312,
#   'price': 1.02403,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 441.173},
#  {'pair': 'SC/BTC',
#   'percent_volume': 0.0621887549078,
#   'price': 1.00123,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 435.277},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.0620548048636,
#   'price': 0.995382,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 434.34},
#  {'pair': 'XVG/BTC',
#   'percent_volume': 0.0619277061265,
#   'price': 1.0039,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 433.45},
#  {'pair': 'SC/BTC',
#   'percent_volume': 0.0613489804137,
#   'price': 0.99668,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 429.399},
#  {'pair': 'MIOTA/BTC',
#   'percent_volume': 0.0598147070996,
#   'price': 0.993416,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 418.66},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0594129967897,
#   'price': 1.00191,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 415.849},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0589918511393,
#   'price': 1.00384,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 412.901},
#  {'pair': 'ETN/BTC',
#   'percent_volume': 0.0589178849875,
#   'price': 1.00552,
#   'source': 'Cryptopia',
#   'updated': True,
#   'volume_24h': 412.383},
#  {'pair': 'GAS/BTC',
#   'percent_volume': 0.0586674627233,
#   'price': 1.0058,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 410.63},
#  {'pair': 'QBT/BTC',
#   'percent_volume': 0.05857615857,
#   'price': 0.95015,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 409.991},
#  {'pair': 'IOTA/BTC',
#   'percent_volume': 0.0569135281155,
#   'price': 1.00068,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 398.354},
#  {'pair': 'MTL/BTC',
#   'percent_volume': 0.0551699403796,
#   'price': 1.00589,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 386.15},
#  {'pair': 'MOD/BTC',
#   'percent_volume': 0.0547022338057,
#   'price': 1.00167,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 382.877},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0534273314019,
#   'price': 1.01951,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 373.954},
#  {'pair': 'WAX/BTC',
#   'percent_volume': 0.0533177104889,
#   'price': 1.00394,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 373.186},
#  {'pair': 'SUB/BTC',
#   'percent_volume': 0.0532271054486,
#   'price': 1.00587,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 372.551},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0529112462108,
#   'price': 1.00225,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 370.341},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0527724023759,
#   'price': 1.00158,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 369.369},
#  {'pair': 'ZIL/BTC',
#   'percent_volume': 0.0524365485073,
#   'price': 1.00103,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 367.019},
#  {'pair': 'WAX/BTC',
#   'percent_volume': 0.0509219901789,
#   'price': 1.00588,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 356.418},
#  {'pair': 'UKG/BTC',
#   'percent_volume': 0.0501286367856,
#   'price': 1.00072,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 350.865},
#  {'pair': 'BTC/GBP',
#   'percent_volume': 0.0497114061679,
#   'price': 1.01306,
#   'source': 'GDAX',
#   'updated': True,
#   'volume_24h': 347.944},
#  {'pair': 'ELF/BTC',
#   'percent_volume': 0.0493390586024,
#   'price': 1.00289,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 345.338},
#  {'pair': 'BCD/BTC',
#   'percent_volume': 0.0492115403975,
#   'price': 0.821285,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 344.446},
#  {'pair': 'GTO/BTC',
#   'percent_volume': 0.0490959071131,
#   'price': 0.992293,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 343.636},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0487817257464,
#   'price': 1.03743,
#   'source': 'Exmo',
#   'updated': True,
#   'volume_24h': 341.438},
#  {'pair': 'ACT/BTC',
#   'percent_volume': 0.0480315775344,
#   'price': 1.00492,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 336.187},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0477965357554,
#   'price': 0.995417,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 334.542},
#  {'pair': 'IOST/BTC',
#   'percent_volume': 0.0475775735746,
#   'price': 0.998714,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 333.009},
#  {'pair': 'ADK/BTC',
#   'percent_volume': 0.0,
#   'price': 1.04113,
#   'source': 'AidosMarket',
#   'updated': False,
#   'volume_24h': 345.671},
#  {'pair': 'NEBL/BTC',
#   'percent_volume': 0.0473556751194,
#   'price': 0.99679,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 331.456},
#  {'pair': 'EVX/BTC',
#   'percent_volume': 0.0472347285764,
#   'price': 0.998861,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 330.61},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0470585521091,
#   'price': 1.00268,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 329.376},
#  {'pair': 'TRX/BTC',
#   'percent_volume': 0.0470031823622,
#   'price': 1.004,
#   'source': 'Liqui',
#   'updated': True,
#   'volume_24h': 328.989},
#  {'pair': 'AION/BTC',
#   'percent_volume': 0.0467131903041,
#   'price': 1.00193,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 326.959},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0466291569257,
#   'price': 0.995283,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 326.371},
#  {'pair': 'DGD/BTC',
#   'percent_volume': 0.0464090761642,
#   'price': 0.989929,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 324.83},
#  {'pair': 'TRUE/BTC',
#   'percent_volume': 0.0458186053535,
#   'price': 0.990902,
#   'source': 'ZB.COM',
#   'updated': True,
#   'volume_24h': 320.698},
#  {'pair': 'WINGS/BTC',
#   'percent_volume': 0.0455781104934,
#   'price': 1.00635,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 319.014},
#  {'pair': 'XRB/BTC',
#   'percent_volume': 0.0448148189577,
#   'price': 1.00824,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 313.672},
#  {'pair': 'BIX/BTC',
#   'percent_volume': 0.044315792123,
#   'price': 0.999026,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 310.179},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0442602825535,
#   'price': 1.00565,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 309.791},
#  {'pair': 'STR/BTC',
#   'percent_volume': 0.0438521404043,
#   'price': 1.0391,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 306.934},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0438452890972,
#   'price': 1.00678,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 306.886},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0436015783174,
#   'price': 0.992617,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 305.18},
#  {'pair': 'BTC/CAD',
#   'percent_volume': 0.0434618955469,
#   'price': 1.01191,
#   'source': 'Coinsquare',
#   'updated': True,
#   'volume_24h': 304.203},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0433073915816,
#   'price': 0.998406,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 303.121},
#  {'pair': 'ZRX/BTC',
#   'percent_volume': 0.0433052942427,
#   'price': 1.00077,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 303.106},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0,
#   'price': 1.06804,
#   'source': 'Bitfinex',
#   'updated': False,
#   'volume_24h': 301.476},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.043209655589,
#   'price': 0.952963,
#   'source': 'BtcTrade.im',
#   'updated': True,
#   'volume_24h': 302.437},
#  {'pair': 'NKC/BTC',
#   'percent_volume': 0.0426377811832,
#   'price': 0.995017,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 298.434},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0424651002808,
#   'price': 0.9885,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 297.226},
#  {'pair': 'BTC/BRL',
#   'percent_volume': 0.0422841698453,
#   'price': 1.02748,
#   'source': 'Foxbit',
#   'updated': True,
#   'volume_24h': 295.959},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0422546672782,
#   'price': 0.998052,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 295.753},
#  {'pair': 'UKG/BTC',
#   'percent_volume': 0.0417293537959,
#   'price': 1.00072,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 292.076},
#  {'pair': 'GXS/BTC',
#   'percent_volume': 0.04120599783,
#   'price': 1.00747,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 288.413},
#  {'pair': 'VIBE/BTC',
#   'percent_volume': 0.0410212921845,
#   'price': 0.994729,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 287.12},
#  {'pair': 'POE/BTC',
#   'percent_volume': 0.0410133222967,
#   'price': 1.04755,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 287.064},
#  {'pair': 'RCN/BTC',
#   'percent_volume': 0.0409796250517,
#   'price': 0.998632,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 286.828},
#  {'pair': 'DSH/BTC',
#   'percent_volume': 0.0408488909272,
#   'price': 1.00716,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 285.913},
#  {'pair': 'LUN/BTC',
#   'percent_volume': 0.040816312263,
#   'price': 1.00133,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 285.685},
#  {'pair': 'GNT/BTC',
#   'percent_volume': 0.0407938008255,
#   'price': 0.999837,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 285.527},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0400654649381,
#   'price': 0.999654,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 280.429},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0399642333807,
#   'price': 1.00091,
#   'source': 'BtcTrade.im',
#   'updated': True,
#   'volume_24h': 279.721},
#  {'pair': 'NULS/BTC',
#   'percent_volume': 0.0397234588754,
#   'price': 1.00137,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 278.036},
#  {'pair': 'EKT/BTC',
#   'percent_volume': 0.0396685085963,
#   'price': 0.957188,
#   'source': 'BigONE',
#   'updated': True,
#   'volume_24h': 277.652},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.038921576304,
#   'price': 1.0047,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 272.423},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.0388148916655,
#   'price': 1.0394,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 271.677},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0386051577758,
#   'price': 0.996297,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 270.209},
#  {'pair': 'WAVES/BTC',
#   'percent_volume': 0.0384808554906,
#   'price': 1.00531,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 269.339},
#  {'pair': 'NAS/BTC',
#   'percent_volume': 0.0381529715097,
#   'price': 0.986338,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 267.044},
#  {'pair': 'AIDOC/BTC',
#   'percent_volume': 0.0380970424725,
#   'price': 1.00413,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 266.653},
#  {'pair': 'BTC/CAD',
#   'percent_volume': 0.0380229364982,
#   'price': 0.996716,
#   'source': 'QuadrigaCX',
#   'updated': True,
#   'volume_24h': 266.133},
#  {'pair': 'VIB/BTC',
#   'percent_volume': 0.0379547030727,
#   'price': 1.0086,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 265.656},
#  {'pair': 'LBTC/BTC',
#   'percent_volume': 0.0378706696943,
#   'price': 0.822599,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 265.068},
#  {'pair': 'WPR/BTC',
#   'percent_volume': 0.0377656629269,
#   'price': 0.99244,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 264.333},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0376448562064,
#   'price': 1.00572,
#   'source': 'RightBTC',
#   'updated': True,
#   'volume_24h': 263.487},
#  {'pair': 'OC/BTC',
#   'percent_volume': 0.037475251401,
#   'price': 1.0004,
#   'source': 'Allcoin',
#   'updated': True,
#   'volume_24h': 262.3},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0368850602356,
#   'price': 0.999806,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 258.169},
#  {'pair': 'DENT/BTC',
#   'percent_volume': 0.0367704057092,
#   'price': 0.996653,
#   'source': 'Coinrail',
#   'updated': True,
#   'volume_24h': 257.367},
#  {'pair': 'FCT/BTC',
#   'percent_volume': 0.0367604783051,
#   'price': 1.00188,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 257.297},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0365875177575,
#   'price': 1.0083,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 256.086},
#  {'pair': 'SRN/BTC',
#   'percent_volume': 0.0362511045985,
#   'price': 0.993803,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 253.732},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0361656729941,
#   'price': 0.996749,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 253.134},
#  {'pair': 'LSK/BTC',
#   'percent_volume': 0.0359939708498,
#   'price': 1.00585,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 251.932},
#  {'pair': 'THETA/BTC',
#   'percent_volume': 0.0359654470408,
#   'price': 1.00317,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 251.732},
#  {'pair': 'XDN/BTC',
#   'percent_volume': 0.0355628977953,
#   'price': 1.00516,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 248.915},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.03533722413,
#   'price': 1.00552,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 247.335},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0349176165281,
#   'price': 1.0039,
#   'source': 'C2CX',
#   'updated': True,
#   'volume_24h': 244.398},
#  {'pair': 'BTC/RUR',
#   'percent_volume': 0.0345449893176,
#   'price': 1.00463,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 241.791},
#  {'pair': 'DLT/BTC',
#   'percent_volume': 0.0344643116813,
#   'price': 0.99877,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 241.225},
#  {'pair': 'STRAT/BTC',
#   'percent_volume': 0.0343683933825,
#   'price': 1.01655,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 240.555},
#  {'pair': 'NBT/BTC',
#   'percent_volume': 0.0343154006197,
#   'price': 0.996204,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 240.183},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0342055000615,
#   'price': 1.00152,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 239.414},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0341456559917,
#   'price': 0.995583,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 238.995},
#  {'pair': 'BTC/TRY',
#   'percent_volume': 0.0340677748073,
#   'price': 1.00555,
#   'source': 'Vebitcoin',
#   'updated': True,
#   'volume_24h': 238.451},
#  {'pair': 'JNT/BTC',
#   'percent_volume': 0.0335606382622,
#   'price': 1.00728,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 234.901},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.033386139666,
#   'price': 1.00169,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 233.679},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0333338460162,
#   'price': 0.999301,
#   'source': 'RightBTC',
#   'updated': True,
#   'volume_24h': 233.313},
#  {'pair': 'W3C/BTC',
#   'percent_volume': 0.0332382073625,
#   'price': 1.01099,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 232.644},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0327316301077,
#   'price': 1.02286,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 229.098},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0326586427141,
#   'price': 1.0048,
#   'source': 'Bitstamp',
#   'updated': True,
#   'volume_24h': 228.587},
#  {'pair': 'LET/BTC',
#   'percent_volume': 0.0324694627457,
#   'price': 1.00211,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 227.263},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0324008098525,
#   'price': 0.999687,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 226.783},
#  {'pair': 'BTC/MXN',
#   'percent_volume': 0.0323371905726,
#   'price': 1.00229,
#   'source': 'Bitso',
#   'updated': True,
#   'volume_24h': 226.337},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0321417185875,
#   'price': 0.998369,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 224.969},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0319187015515,
#   'price': 1.0022,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 223.408},
#  {'pair': 'DOGE/BTC',
#   'percent_volume': 0.0318605353527,
#   'price': 0.987906,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 223.001},
#  {'pair': 'QTUM/BTC',
#   'percent_volume': 0.0317499356816,
#   'price': 0.998911,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 222.227},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0315775344243,
#   'price': 1.00554,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 221.02},
#  {'pair': 'SXUT/BTC',
#   'percent_volume': 0.0310568350876,
#   'price': 1.00694,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 217.376},
#  {'pair': 'XLM/BTC',
#   'percent_volume': 0.0308258481638,
#   'price': 1.0397,
#   'source': 'Kraken',
#   'updated': True,
#   'volume_24h': 215.759},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.0307538395284,
#   'price': 1.05594,
#   'source': 'Coinnest',
#   'updated': True,
#   'volume_24h': 215.255},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0306284186624,
#   'price': 1.01442,
#   'source': 'WEX',
#   'updated': True,
#   'volume_24h': 214.377},
#  {'pair': 'MDS/BTC',
#   'percent_volume': 0.0304136511594,
#   'price': 1.00034,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 212.874},
#  {'pair': 'INK/BTC',
#   'percent_volume': 0.030333392991,
#   'price': 0.96209,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 212.312},
#  {'pair': 'BTC/PLN',
#   'percent_volume': 0.0302302039173,
#   'price': 0.99976,
#   'source': 'BitMarket',
#   'updated': True,
#   'volume_24h': 211.59},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0301931509301,
#   'price': 0.993427,
#   'source': 'Bitonic',
#   'updated': True,
#   'volume_24h': 211.331},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0301293918276,
#   'price': 0.998247,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 210.884},
#  {'pair': 'XRP/BTC',
#   'percent_volume': 0.0300227071891,
#   'price': 1.00291,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 210.137},
#  {'pair': 'NEO/BTC',
#   'percent_volume': 0.0299509781989,
#   'price': 0.996282,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 209.635},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0299178402443,
#   'price': 1.00126,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 209.403},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0297792760545,
#   'price': 1.00416,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 208.434},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0297753610219,
#   'price': 0.998557,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 208.407},
#  {'pair': 'PPT/BTC',
#   'percent_volume': 0.0296948232083,
#   'price': 0.994573,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 207.843},
#  {'pair': 'QUN/BTC',
#   'percent_volume': 0.0295315104196,
#   'price': 0.998943,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 206.7},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0295056432399,
#   'price': 0.998593,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 206.518},
#  {'pair': 'XAS/BTC',
#   'percent_volume': 0.0291597221445,
#   'price': 0.990362,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 204.098},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0289285953982,
#   'price': 0.971236,
#   'source': 'TOPBTC',
#   'updated': True,
#   'volume_24h': 202.48},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0287342419938,
#   'price': 1.03191,
#   'source': 'BTC-Alpha',
#   'updated': True,
#   'volume_24h': 201.119},
#  {'pair': 'GNT/BTC',
#   'percent_volume': 0.0286097998859,
#   'price': 0.993136,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 200.248},
#  {'pair': 'VIB/BTC',
#   'percent_volume': 0.0282185762704,
#   'price': 1.01136,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 197.509},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0282175975123,
#   'price': 1.03333,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 197.503},
#  {'pair': 'GTO/BTC',
#   'percent_volume': 0.0281058792604,
#   'price': 1.0084,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 196.721},
#  {'pair': 'VEE/BTC',
#   'percent_volume': 0.0278842604503,
#   'price': 0.994837,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 195.17},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.027851402141,
#   'price': 0.964576,
#   'source': 'AEX',
#   'updated': True,
#   'volume_24h': 194.94},
#  {'pair': 'SALT/BTC',
#   'percent_volume': 0.0274523484603,
#   'price': 1.00276,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 192.147},
#  {'pair': 'BTC/INR',
#   'percent_volume': 0.0273701327755,
#   'price': 1.03903,
#   'source': 'Zebpay',
#   'updated': True,
#   'volume_24h': 191.571},
#  {'pair': 'ELF/BTC',
#   'percent_volume': 0.0271118804461,
#   'price': 0.999356,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 189.764},
#  {'pair': 'BTC/BRL',
#   'percent_volume': 0.0270683956196,
#   'price': 1.01269,
#   'source': 'Mercado Bitcoin',
#   'updated': True,
#   'volume_24h': 189.459},
#  {'pair': 'LINK/BTC',
#   'percent_volume': 0.0270265886643,
#   'price': 0.998465,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 189.167},
#  {'pair': 'EOS/BTC',
#   'percent_volume': 0.0269800277408,
#   'price': 0.996099,
#   'source': 'ZB.COM',
#   'updated': True,
#   'volume_24h': 188.841},
#  {'pair': 'REP/BTC',
#   'percent_volume': 0.0269122137832,
#   'price': 1.00121,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 188.366},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0269024262016,
#   'price': 1.00015,
#   'source': 'Livecoin',
#   'updated': True,
#   'volume_24h': 188.298},
#  {'pair': 'FAIR/BTC',
#   'percent_volume': 0.0268880244745,
#   'price': 1.00579,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 188.197},
#  {'pair': 'VEE/BTC',
#   'percent_volume': 0.026839086567,
#   'price': 0.994837,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 187.855},
#  {'pair': 'LTC/BTC',
#   'percent_volume': 0.0268209096299,
#   'price': 0.934783,
#   'source': 'RightBTC',
#   'updated': True,
#   'volume_24h': 187.727},
#  {'pair': 'ABT/BTC',
#   'percent_volume': 0.026777564626,
#   'price': 0.995443,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 187.424},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0266775914719,
#   'price': 1.00152,
#   'source': 'Bitfinex',
#   'updated': True,
#   'volume_24h': 186.724},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0265903421738,
#   'price': 1.02233,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 186.113},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0264168223358,
#   'price': 1.00054,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 184.899},
#  {'pair': 'STRAT/BTC',
#   'percent_volume': 0.0263400597322,
#   'price': 1.0132,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 184.362},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0262210707055,
#   'price': 1.00412,
#   'source': 'BL3P',
#   'updated': True,
#   'volume_24h': 183.529},
#  {'pair': 'LEND/BTC',
#   'percent_volume': 0.025906469871,
#   'price': 0.996004,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 181.326},
#  {'pair': 'XEM/BTC',
#   'percent_volume': 0.0258891318695,
#   'price': 1.01968,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 181.206},
#  {'pair': 'HLC/BTC',
#   'percent_volume': 0.0257300137585,
#   'price': 0.993582,
#   'source': 'CoinEgg',
#   'updated': True,
#   'volume_24h': 180.091},
#  {'pair': 'BLZ/BTC',
#   'percent_volume': 0.025489658721,
#   'price': 0.998029,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 178.409},
#  {'pair': 'ADX/BTC',
#   'percent_volume': 0.0250088088234,
#   'price': 0.985907,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 175.044},
#  {'pair': 'SPF/BTC',
#   'percent_volume': 0.0246764505196,
#   'price': 1.00212,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 172.718},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.0246160471594,
#   'price': 1.03586,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 172.294},
#  {'pair': 'HPB/BTC',
#   'percent_volume': 0.0242799136456,
#   'price': 0.996803,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 169.942},
#  {'pair': 'ATB/BTC',
#   'percent_volume': 0.0241967192027,
#   'price': 1.02856,
#   'source': 'TOPBTC',
#   'updated': True,
#   'volume_24h': 169.36},
#  {'pair': 'CND/BTC',
#   'percent_volume': 0.0241556113603,
#   'price': 1.00508,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 169.072},
#  {'pair': 'DGB/BTC',
#   'percent_volume': 0.0241385530039,
#   'price': 0.997235,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 168.953},
#  {'pair': 'TNB/BTC',
#   'percent_volume': 0.0240101958635,
#   'price': 1.0038,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 168.054},
#  {'pair': 'PUT/BTC',
#   'percent_volume': 0.0238411503484,
#   'price': 1.02145,
#   'source': 'Bit-Z',
#   'updated': True,
#   'volume_24h': 166.871},
#  {'pair': 'DASH/BTC',
#   'percent_volume': 0.0237979451672,
#   'price': 1.00152,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 166.568},
#  {'pair': 'DENT/BTC',
#   'percent_volume': 0.0237415966622,
#   'price': 1.01987,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 166.175},
#  {'pair': 'ENG/BTC',
#   'percent_volume': 0.0236884640768,
#   'price': 0.998048,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 165.803},
#  {'pair': 'ETH/BTC',
#   'percent_volume': 0.0236493137507,
#   'price': 0.996534,
#   'source': 'Bibox',
#   'updated': True,
#   'volume_24h': 165.528},
#  {'pair': 'XBT/AUD',
#   'percent_volume': 0.0234426559581,
#   'price': 1.00335,
#   'source': 'Independent Reserve',
#   'updated': True,
#   'volume_24h': 164.082},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0232157238895,
#   'price': 1.01706,
#   'source': 'YoBit',
#   'updated': True,
#   'volume_24h': 162.494},
#  {'pair': 'STK/BTC',
#   'percent_volume': 0.0230507332297,
#   'price': 1.00222,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 161.338},
#  {'pair': 'HSR/BTC',
#   'percent_volume': 0.0229360787033,
#   'price': 0.998949,
#   'source': 'Allcoin',
#   'updated': True,
#   'volume_24h': 160.536},
#  {'pair': 'HTML/BTC',
#   'percent_volume': 0.0229142663788,
#   'price': 1.00425,
#   'source': 'Bleutrade',
#   'updated': True,
#   'volume_24h': 160.384},
#  {'pair': 'ZCL/BTC',
#   'percent_volume': 0.0228175091444,
#   'price': 0.933147,
#   'source': 'Cryptopia',
#   'updated': True,
#   'volume_24h': 159.707},
#  {'pair': 'BTC/EUR',
#   'percent_volume': 0.0228010100784,
#   'price': 1.00714,
#   'source': 'CEX.IO',
#   'updated': True,
#   'volume_24h': 159.591},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0227956968199,
#   'price': 1.06374,
#   'source': 'LakeBTC',
#   'updated': True,
#   'volume_24h': 159.554},
#  {'pair': 'BTG/BTC',
#   'percent_volume': 0.0227197731518,
#   'price': 0.946917,
#   'source': 'Exrates',
#   'updated': True,
#   'volume_24h': 159.022},
#  {'pair': 'BTC/PEN',
#   'percent_volume': 0.0227104050381,
#   'price': 0.992032,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 158.956},
#  {'pair': 'ACT/BTC',
#   'percent_volume': 0.0226378371123,
#   'price': 1.00926,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 158.448},
#  {'pair': 'SNC/BTC',
#   'percent_volume': 0.0223644839428,
#   'price': 0.998701,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 156.535},
#  {'pair': 'BCH/BTC',
#   'percent_volume': 0.0221330775512,
#   'price': 1.00388,
#   'source': 'Exrates',
#   'updated': True,
#   'volume_24h': 154.916},
#  {'pair': 'OMG/BTC',
#   'percent_volume': 0.0218538518328,
#   'price': 0.997584,
#   'source': 'Ethfinex',
#   'updated': True,
#   'volume_24h': 152.962},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0215965782615,
#   'price': 1.00718,
#   'source': 'EXX',
#   'updated': True,
#   'volume_24h': 151.16},
#  {'pair': 'RIC/BTC',
#   'percent_volume': 0.021311200349,
#   'price': 1.00879,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 149.164},
#  {'pair': 'QUN/BTC',
#   'percent_volume': 0.0212963791541,
#   'price': 1.00858,
#   'source': 'ZB.COM',
#   'updated': True,
#   'volume_24h': 149.059},
#  {'pair': 'XMR/BTC',
#   'percent_volume': 0.0211509636573,
#   'price': 1.00193,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 148.042},
#  {'pair': 'GAME/BTC',
#   'percent_volume': 0.0210693072629,
#   'price': 1.02743,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 147.471},
#  {'pair': 'ETC/BTC',
#   'percent_volume': 0.0210117003546,
#   'price': 1.00009,
#   'source': 'HitBTC',
#   'updated': True,
#   'volume_24h': 147.067},
#  {'pair': 'BCC/BTC',
#   'percent_volume': 0.0209385731384,
#   'price': 1.00131,
#   'source': 'Lbank',
#   'updated': True,
#   'volume_24h': 146.555},
#  {'pair': 'MEE/BTC',
#   'percent_volume': 0.0208117540465,
#   'price': 0.999941,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 145.668},
#  {'pair': 'BTC/ARS',
#   'percent_volume': 0.0208068602557,
#   'price': 1.01389,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 145.633},
#  {'pair': 'ELF/BTC',
#   'percent_volume': 0.0207660320585,
#   'price': 1.00289,
#   'source': 'OKEx',
#   'updated': True,
#   'volume_24h': 145.347},
#  {'pair': 'ZEC/BTC',
#   'percent_volume': 0.0201969541046,
#   'price': 1.00295,
#   'source': 'Poloniex',
#   'updated': True,
#   'volume_24h': 141.364},
#  {'pair': 'WABI/BTC',
#   'percent_volume': 0.0201849293616,
#   'price': 0.991305,
#   'source': 'Binance',
#   'updated': True,
#   'volume_24h': 141.28},
#  {'pair': 'RUFF/BTC',
#   'percent_volume': 0.0198381693308,
#   'price': 1.01746,
#   'source': 'Huobi',
#   'updated': True,
#   'volume_24h': 138.853},
#  {'pair': 'EDG/BTC',
#   'percent_volume': 0.0196972281569,
#   'price': 1.00096,
#   'source': 'Upbit',
#   'updated': True,
#   'volume_24h': 137.867},
#  {'pair': 'IGNIS/BTC',
#   'percent_volume': 0.0196934529469,
#   'price': 1.01288,
#   'source': 'Bittrex',
#   'updated': True,
#   'volume_24h': 137.84},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 1.0042,
#   'source': 'BitMEX',
#   'updated': True,
#   'volume_24h': 261120.0},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 1.00298,
#   'source': 'Fisco',
#   'updated': True,
#   'volume_24h': 16255.4},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 1.00261,
#   'source': 'Zaif',
#   'updated': True,
#   'volume_24h': 16250.6},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 1.00587,
#   'source': 'BTCBOX',
#   'updated': True,
#   'volume_24h': 15190.2},
#  {'pair': 'BTC/JPY',
#   'percent_volume': 0.0,
#   'price': 1.00316,
#   'source': 'Quoine',
#   'updated': True,
#   'volume_24h': 9786.25},
#  {'pair': 'BTC/USDT',
#   'percent_volume': 0.0,
#   'price': 1.0092,
#   'source': 'ZB.COM',
#   'updated': True,
#   'volume_24h': 2260.96},
#  {'pair': 'BTC/KRW',
#   'percent_volume': 0.0,
#   'price': 1.06614,
#   'source': 'GOPAX',
#   'updated': True,
#   'volume_24h': 1579.1},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 1.00788,
#   'source': 'Quoine',
#   'updated': True,
#   'volume_24h': 865.505},
#  {'pair': 'BTC/SGD',
#   'percent_volume': 0.0,
#   'price': 1.00288,
#   'source': 'Quoine',
#   'updated': True,
#   'volume_24h': 219.062},
#  {'pair': 'BTC/USD',
#   'percent_volume': 0.0,
#   'price': 1.00051,
#   'source': 'bitFlyer',
#   'updated': True,
#   'volume_24h': 188.534},
#  {'pair': 'VEN/BTC',
#   'percent_volume': 0.0,
#   'price': 1.00587,
#   'source': 'Kucoin',
#   'updated': True,
#   'volume_24h': 144.751},
#  {'pair': 'B2X/BTC',
#   'percent_volume': 0.0,
#   'price': 0.000286299,
#   'source': 'Negocie Coins',
#   'updated': True,
#   'volume_24h': 8884.05},
#  {'pair': 'BTC/LTC',
#   'percent_volume': 0.0,
#   'price': 0.0269563,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 211.374},
#  {'pair': 'BTC/ETH',
#   'percent_volume': 0.0,
#   'price': 0.112421,
#   'source': 'Bitinka',
#   'updated': True,
#   'volume_24h': 168.12}]

# %%
show_page("currencies/bitcoin/#markets")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/currencies/bitcoin/#markets"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `ranks()`
# Get gainers and losers rankings:

# %%
cmc.ranks()
# Out:
# {'gainers': {'1h': [{'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4},
#    {'name': 'NuShares',
#     'percent_change': 73.56,
#     'price': 0.00270892,
#     'symbol': 'NSR',
#     'volume_24h': 76098.4}],
#   '24h': [{'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0},
#    {'name': 'MSD',
#     'percent_change': 180.67,
#     'price': 0.0268666,
#     'symbol': 'MSD',
#     'volume_24h': 342015.0}],
#   '7d': [{'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3},
#    {'name': 'LinkedCoin',
#     'percent_change': 406.45,
#     'price': 0.00112399,
#     'symbol': 'LKC',
#     'volume_24h': 51185.3}]},
#  'losers': {'1h': [{'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8},
#    {'name': 'Social Send',
#     'percent_change': -19.83,
#     'price': 0.17377,
#     'symbol': 'SEND',
#     'volume_24h': 74428.8}],
#   '24h': [{'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -87.59,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0}],
#   '7d': [{'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0},
#    {'name': 'Titanium Blockchain',
#     'percent_change': -84.55,
#     'price': 0.104271,
#     'symbol': 'BAR',
#     'volume_24h': 2221680.0}]}}

# %%
show_page("gainers-losers")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/gainers-losers"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `historical(currency, [start=datetime(2008, 8, 18), end=datetime.now(), revert=False])`
# Get historical prices for a currency. You can filter by `start` and `end` datetimes provided in `datetime` objects. With parameter `revert` active, the response will be ordered in chronological order.

# %%
from datetime import datetime

cmc.historical("ETH", start=datetime(2018, 2, 1), revert=True)
# Out:
# {'history': [{'close': 1036.79,
#    'date': datetime.datetime(2018, 2, 1, 0, 0),
#    'high': 1161.35,
#    'low': 984.819,
#    'market_cap': 870.709,
#    'open': 1119.37,
#    'volume': 869.293},
#   {'close': 915.785,
#    'date': datetime.datetime(2018, 2, 2, 0, 0),
#    'high': 1035.77,
#    'low': 757.98,
#    'market_cap': 923.561,
#    'open': 1035.77,
#    'volume': 844.279},
#   {'close': 964.019,
#    'date': datetime.datetime(2018, 2, 3, 0, 0),
#    'high': 991.943,
#    'low': 847.69,
#    'market_cap': 926.429,
#    'open': 919.211,
#    'volume': 844.279},
#   {'close': 834.682,
#    'date': datetime.datetime(2018, 2, 4, 0, 0),
#    'high': 969.032,
#    'low': 805.064,
#    'market_cap': 936.976,
#    'open': 964.667,
#    'volume': 911.111},
#   {'close': 697.951,
#    'date': datetime.datetime(2018, 2, 5, 0, 0),
#    'high': 856.646,
#    'low': 644.599,
#    'market_cap': 951.948,
#    'open': 834.958,
#    'volume': 923.728},
#   {'close': 793.122,
#    'date': datetime.datetime(2018, 2, 6, 0, 0),
#    'high': 796.439,
#    'low': 574.419,
#    'market_cap': 944.21,
#    'open': 707.737,
#    'volume': 917.848},
#   {'close': 757.068,
#    'date': datetime.datetime(2018, 2, 7, 0, 0),
#    'high': 851.2,
#    'low': 723.433,
#    'market_cap': 950.005,
#    'open': 790.428,
#    'volume': 934.786},
#   {'close': 817.807,
#    'date': datetime.datetime(2018, 2, 8, 0, 0),
#    'high': 845.086,
#    'low': 755.843,
#    'market_cap': 974.115,
#    'open': 755.843,
#    'volume': 940.754},
#   {'close': 883.865,
#    'date': datetime.datetime(2018, 2, 9, 0, 0),
#    'high': 884.004,
#    'low': 788.834,
#    'market_cap': 976.595,
#    'open': 818.48,
#    'volume': 944.748},
#   {'close': 860.415,
#    'date': datetime.datetime(2018, 2, 10, 0, 0),
#    'high': 917.4,
#    'low': 825.577,
#    'market_cap': 923.921,
#    'open': 882.467,
#    'volume': 915.445},
#   {'close': 814.66,
#    'date': datetime.datetime(2018, 2, 11, 0, 0),
#    'high': 859.288,
#    'low': 788.222,
#    'market_cap': 982.933,
#    'open': 859.288,
#    'volume': 973.349},
#   {'close': 868.707,
#    'date': datetime.datetime(2018, 2, 12, 0, 0),
#    'high': 875.937,
#    'low': 817.508,
#    'market_cap': 943.865,
#    'open': 817.508,
#    'volume': 921.554},
#   {'close': 845.258,
#    'date': datetime.datetime(2018, 2, 13, 0, 0),
#    'high': 870.709,
#    'low': 828.837,
#    'market_cap': 957.777,
#    'open': 869.293,
#    'volume': 921.668},
#   {'close': 923.561,
#    'date': datetime.datetime(2018, 2, 14, 0, 0),
#    'high': 926.429,
#    'low': 844.279,
#    'market_cap': 895.371,
#    'open': 844.279,
#    'volume': 892.954},
#   {'close': 936.976,
#    'date': datetime.datetime(2018, 2, 15, 0, 0),
#    'high': 951.948,
#    'low': 911.111,
#    'market_cap': 965.265,
#    'open': 923.728,
#    'volume': 943.567},
#   {'close': 944.21,
#    'date': datetime.datetime(2018, 2, 16, 0, 0),
#    'high': 950.005,
#    'low': 917.848,
#    'market_cap': 849.971,
#    'open': 934.786,
#    'volume': 830.563},
#   {'close': 974.115,
#    'date': datetime.datetime(2018, 2, 17, 0, 0),
#    'high': 976.595,
#    'low': 940.754,
#    'market_cap': 912.375,
#    'open': 944.748,
#    'volume': 894.135},
#   {'close': 923.921,
#    'date': datetime.datetime(2018, 2, 18, 0, 0),
#    'high': 982.933,
#    'low': 915.445,
#    'market_cap': 812.845,
#    'open': 973.349,
#    'volume': 802.668},
#   {'close': 943.865,
#    'date': datetime.datetime(2018, 2, 19, 0, 0),
#    'high': 957.777,
#    'low': 921.554,
#    'market_cap': 875.926,
#    'open': 921.668,
#    'volume': 849.262},
#   {'close': 895.371,
#    'date': datetime.datetime(2018, 2, 20, 0, 0),
#    'high': 965.265,
#    'low': 892.954,
#    'market_cap': 864.189,
#    'open': 943.567,
#    'volume': 794.791},
#   {'close': 849.971,
#    'date': datetime.datetime(2018, 2, 21, 0, 0),
#    'high': 912.375,
#    'low': 830.563,
#    'market_cap': 886.318,
#    'open': 894.135,
#    'volume': 811.585},
#   {'close': 812.845,
#    'date': datetime.datetime(2018, 2, 22, 0, 0),
#    'high': 875.926,
#    'low': 802.668,
#    'market_cap': 840.515,
#    'open': 849.262,
#    'volume': 818.55},
#   {'close': 864.189,
#    'date': datetime.datetime(2018, 2, 23, 0, 0),
#    'high': 886.318,
#    'low': 794.791,
#    'market_cap': 879.531,
#    'open': 811.585,
#    'volume': 861.593},
#   {'close': 840.515,
#    'date': datetime.datetime(2018, 2, 24, 0, 0),
#    'high': 879.531,
#    'low': 818.55,
#    'market_cap': 844.81,
#    'open': 861.593,
#    'volume': 822.381},
#   {'close': 844.81,
#    'date': datetime.datetime(2018, 2, 25, 0, 0),
#    'high': 853.146,
#    'low': 822.381,
#    'market_cap': 853.146,
#    'open': 839.459,
#    'volume': 839.459}],
#  'slug': 'ethereum',
#  'symbol': 'ETH'}

# %%
show_page("currencies/ethereum/historical-data")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/currencies/ethereum/historical-data"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `recently([convert="USD"])`
# Get recently added coins in coinmarketcap along with other metadata.

# %%
list(cmc.recently())
# Out:
# [{'added': 'Today',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Remme',
#   'percent_change': None,
#   'price': 0.0292984,
#   'symbol': 'REM',
#   'volume_24h': 656930.0},
#  {'added': 'Today',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Arcblock',
#   'percent_change': None,
#   'price': 1.27214,
#   'symbol': 'ABT',
#   'volume_24h': 76095000.0},
#  {'added': 'Today',
#   'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Nucleus Vision',
#   'percent_change': None,
#   'price': 0.0392334,
#   'symbol': 'NCASH',
#   'volume_24h': 142868000.0}]

# %%
show_page("new")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/new"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `exchange(name, [convert="USD"])`
# Get data about a exchange:

# %%
cmc.exchange("okex")
# Out:
# {'markets': [{'currency': 'Bitcoin',
#    'pair': 'BTC/USDT',
#    'perc_volume': 28.7467555425,
#    'price': 10260.3,
#    'updated': True,
#    'vol_24h': 503653000.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/USDT',
#    'perc_volume': 9.95357259672,
#    'price': 217.492,
#    'updated': True,
#    'vol_24h': 174390000.0},
#   {'currency': 'Ethereum',
#    'pair': 'ETH/USDT',
#    'perc_volume': 9.07236835725,
#    'price': 866.634,
#    'updated': True,
#    'vol_24h': 158951000.0},
#   {'currency': 'Ethereum',
#    'pair': 'ETH/BTC',
#    'perc_volume': 8.60006023616,
#    'price': 861.64,
#    'updated': True,
#    'vol_24h': 150676000.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/BTC',
#    'perc_volume': 8.3500080454,
#    'price': 217.121,
#    'updated': True,
#    'vol_24h': 146295000.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/BTC',
#    'perc_volume': 7.2539107454,
#    'price': 35.6632,
#    'updated': True,
#    'vol_24h': 127091000.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/BTC',
#    'perc_volume': 4.7425557162,
#    'price': 1239.0,
#    'updated': True,
#    'vol_24h': 83091200.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/USDT',
#    'perc_volume': 4.06703238854,
#    'price': 1247.57,
#    'updated': True,
#    'vol_24h': 71255800.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/USDT',
#    'perc_volume': 3.9049293922,
#    'price': 35.7607,
#    'updated': True,
#    'vol_24h': 68415700.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/USDT',
#    'perc_volume': 1.50602079556,
#    'price': 8.10967,
#    'updated': True,
#    'vol_24h': 26386000.0},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/ETH',
#    'perc_volume': 1.28215530763,
#    'price': 35.6071,
#    'updated': True,
#    'vol_24h': 22463800.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/BTC',
#    'perc_volume': 0.797752674047,
#    'price': 0.839619,
#    'updated': True,
#    'vol_24h': 13976900.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/USDT',
#    'perc_volume': 0.75816440664,
#    'price': 0.925583,
#    'updated': True,
#    'vol_24h': 13283300.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/USDT',
#    'perc_volume': 0.634593762269,
#    'price': 133.498,
#    'updated': True,
#    'vol_24h': 11118300.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/BTC',
#    'perc_volume': 0.621728716892,
#    'price': 8.064,
#    'updated': True,
#    'vol_24h': 10892900.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/BTC',
#    'perc_volume': 0.579183886262,
#    'price': 133.345,
#    'updated': True,
#    'vol_24h': 10147500.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/BTC',
#    'perc_volume': 0.578670197671,
#    'price': 0.924436,
#    'updated': True,
#    'vol_24h': 10138500.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/BTC',
#    'perc_volume': 0.547621717706,
#    'price': 0.0177794,
#    'updated': True,
#    'vol_24h': 9594520.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/BTC',
#    'perc_volume': 0.452457481647,
#    'price': 2.33125,
#    'updated': True,
#    'vol_24h': 7927210.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/BTC',
#    'perc_volume': 0.452454057057,
#    'price': 27.56,
#    'updated': True,
#    'vol_24h': 7927150.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/ETH',
#    'perc_volume': 0.448131082181,
#    'price': 0.837409,
#    'updated': True,
#    'vol_24h': 7851410.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/ETH',
#    'perc_volume': 0.409389259419,
#    'price': 0.0178462,
#    'updated': True,
#    'vol_24h': 7172640.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/USDT',
#    'perc_volume': 0.357878850582,
#    'price': 27.6522,
#    'updated': True,
#    'vol_24h': 6270160.0},
#   {'currency': 'Revain',
#    'pair': 'R/BTC',
#    'perc_volume': 0.293357851268,
#    'price': 2.38469,
#    'updated': True,
#    'vol_24h': 5139730.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/BTC',
#    'perc_volume': 0.232324797485,
#    'price': 1.83098,
#    'updated': True,
#    'vol_24h': 4070410.0},
#   {'currency': 'EOS',
#    'pair': 'EOS/ETH',
#    'perc_volume': 0.226261559817,
#    'price': 8.07564,
#    'updated': True,
#    'vol_24h': 3964180.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/USDT',
#    'perc_volume': 0.171870499515,
#    'price': 1.83573,
#    'updated': True,
#    'vol_24h': 3011230.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/USDT',
#    'perc_volume': 0.165992760505,
#    'price': 1.75225,
#    'updated': True,
#    'vol_24h': 2908250.0},
#   {'currency': 'Revain',
#    'pair': 'R/ETH',
#    'perc_volume': 0.155998092821,
#    'price': 2.3866,
#    'updated': True,
#    'vol_24h': 2733140.0},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/ETH',
#    'perc_volume': 0.150813833408,
#    'price': 0.0425861,
#    'updated': True,
#    'vol_24h': 2642310.0},
#   {'currency': 'Ripple',
#    'pair': 'XRP/ETH',
#    'perc_volume': 0.143292290907,
#    'price': 0.923847,
#    'updated': True,
#    'vol_24h': 2510530.0},
#   {'currency': 'Viberate',
#    'pair': 'VIB/BTC',
#    'perc_volume': 0.115190100393,
#    'price': 0.223878,
#    'updated': True,
#    'vol_24h': 2018170.0},
#   {'currency': 'Arcblock',
#    'pair': 'ABT/ETH',
#    'perc_volume': 0.114324249735,
#    'price': 1.25811,
#    'updated': True,
#    'vol_24h': 2003000.0},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/BTC',
#    'perc_volume': 0.109758699692,
#    'price': 0.0332087,
#    'updated': True,
#    'vol_24h': 1923010.0},
#   {'currency': 'Arcblock',
#    'pair': 'ABT/BTC',
#    'perc_volume': 0.109307795262,
#    'price': 1.27705,
#    'updated': True,
#    'vol_24h': 1915110.0},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/BTC',
#    'perc_volume': 0.100730908089,
#    'price': 0.269246,
#    'updated': True,
#    'vol_24h': 1764840.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/BTC',
#    'perc_volume': 0.0924091529158,
#    'price': 0.378069,
#    'updated': True,
#    'vol_24h': 1619040.0},
#   {'currency': 'Arcblock',
#    'pair': 'ABT/USDT',
#    'perc_volume': 0.0922641785802,
#    'price': 1.27453,
#    'updated': True,
#    'vol_24h': 1616500.0},
#   {'currency': 'SunContract',
#    'pair': 'SNC/BTC',
#    'perc_volume': 0.0912933071433,
#    'price': 0.205894,
#    'updated': True,
#    'vol_24h': 1599490.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/BTC',
#    'perc_volume': 0.0847683205085,
#    'price': 1.18519,
#    'updated': True,
#    'vol_24h': 1485170.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/ETH',
#    'perc_volume': 0.0841604556759,
#    'price': 2.33482,
#    'updated': True,
#    'vol_24h': 1474520.0},
#   {'currency': 'NEO',
#    'pair': 'NEO/ETH',
#    'perc_volume': 0.0813425883721,
#    'price': 133.488,
#    'updated': True,
#    'vol_24h': 1425150.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/ETH',
#    'perc_volume': 0.0807581249087,
#    'price': 0.0903253,
#    'updated': True,
#    'vol_24h': 1414910.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/USDT',
#    'perc_volume': 0.0786531432161,
#    'price': 1.19215,
#    'updated': True,
#    'vol_24h': 1378030.0},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/USDT',
#    'perc_volume': 0.0774733717523,
#    'price': 0.0358768,
#    'updated': True,
#    'vol_24h': 1357360.0},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/USDT',
#    'perc_volume': 0.070640742728,
#    'price': 6.62399,
#    'updated': True,
#    'vol_24h': 1237650.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/BTC',
#    'perc_volume': 0.065092905946,
#    'price': 8.33713,
#    'updated': True,
#    'vol_24h': 1140450.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/USDT',
#    'perc_volume': 0.0596655006004,
#    'price': 8.36451,
#    'updated': True,
#    'vol_24h': 1045360.0},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/BTC',
#    'perc_volume': 0.0592950740499,
#    'price': 327.09,
#    'updated': True,
#    'vol_24h': 1038870.0},
#   {'currency': 'Viuly',
#    'pair': 'VIU/USDT',
#    'perc_volume': 0.0587751070428,
#    'price': 0.0101217,
#    'updated': True,
#    'vol_24h': 1029760.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/BTC',
#    'perc_volume': 0.0579212424517,
#    'price': 0.341897,
#    'updated': True,
#    'vol_24h': 1014800.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/BTC',
#    'perc_volume': 0.0548163373786,
#    'price': 1.73329,
#    'updated': True,
#    'vol_24h': 960401.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/USDT',
#    'perc_volume': 0.0525634133719,
#    'price': 0.343436,
#    'updated': True,
#    'vol_24h': 920929.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/BTC',
#    'perc_volume': 0.0516703372183,
#    'price': 0.111173,
#    'updated': True,
#    'vol_24h': 905282.0},
#   {'currency': 'Qtum',
#    'pair': 'QTUM/ETH',
#    'perc_volume': 0.0513466563295,
#    'price': 27.5335,
#    'updated': True,
#    'vol_24h': 899611.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/USDT',
#    'perc_volume': 0.0468012542945,
#    'price': 0.111338,
#    'updated': True,
#    'vol_24h': 819974.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/BCH',
#    'perc_volume': 0.0461887091881,
#    'price': 220.216,
#    'updated': True,
#    'vol_24h': 809242.0},
#   {'currency': 'Viuly',
#    'pair': 'VIU/BTC',
#    'perc_volume': 0.0434353383408,
#    'price': 0.0103202,
#    'updated': True,
#    'vol_24h': 761002.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/USDT',
#    'perc_volume': 0.041281213773,
#    'price': 0.00330708,
#    'updated': True,
#    'vol_24h': 723261.0},
#   {'currency': 'IOTA',
#    'pair': 'IOTA/ETH',
#    'perc_volume': 0.0412004505112,
#    'price': 1.83192,
#    'updated': True,
#    'vol_24h': 721846.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/ETH',
#    'perc_volume': 0.0398191418902,
#    'price': 0.0699801,
#    'updated': True,
#    'vol_24h': 697645.0},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/USDT',
#    'perc_volume': 0.0397676018016,
#    'price': 0.0338725,
#    'updated': True,
#    'vol_24h': 696742.0},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/USDT',
#    'perc_volume': 0.039402654596,
#    'price': 0.097609,
#    'updated': True,
#    'vol_24h': 690348.0},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/BTC',
#    'perc_volume': 0.0390087125233,
#    'price': 2.19688,
#    'updated': True,
#    'vol_24h': 683446.0},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/USDT',
#    'perc_volume': 0.0387280102466,
#    'price': 0.506886,
#    'updated': True,
#    'vol_24h': 678528.0},
#   {'currency': 'Datum',
#    'pair': 'DAT/BTC',
#    'perc_volume': 0.0355888592675,
#    'price': 0.0472075,
#    'updated': True,
#    'vol_24h': 623529.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/BTC',
#    'perc_volume': 0.0341689098492,
#    'price': 0.183925,
#    'updated': True,
#    'vol_24h': 598651.0},
#   {'currency': 'Ace',
#    'pair': 'ACE/BTC',
#    'perc_volume': 0.0334283992071,
#    'price': 0.284982,
#    'updated': True,
#    'vol_24h': 585677.0},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/BTC',
#    'perc_volume': 0.0330732691613,
#    'price': 0.0970716,
#    'updated': True,
#    'vol_24h': 579455.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/BTC',
#    'perc_volume': 0.0330079165572,
#    'price': 0.253919,
#    'updated': True,
#    'vol_24h': 578310.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/USDT',
#    'perc_volume': 0.0327958202457,
#    'price': 0.356063,
#    'updated': True,
#    'vol_24h': 574594.0},
#   {'currency': 'SwftCoin',
#    'pair': 'SWFTC/USDT',
#    'perc_volume': 0.0321106738184,
#    'price': 0.0181388,
#    'updated': True,
#    'vol_24h': 562590.0},
#   {'currency': 'Stellar',
#    'pair': 'XLM/BTC',
#    'perc_volume': 0.0316293476087,
#    'price': 0.355363,
#    'updated': True,
#    'vol_24h': 554157.0},
#   {'currency': 'IPChain',
#    'pair': 'IPC/BTC',
#    'perc_volume': 0.0314827180542,
#    'price': 0.920341,
#    'updated': True,
#    'vol_24h': 551588.0},
#   {'currency': 'FairGame',
#    'pair': 'FAIR/ETH',
#    'perc_volume': 0.0297232204773,
#    'price': 0.0332882,
#    'updated': True,
#    'vol_24h': 520761.0},
#   {'currency': 'LATOKEN',
#    'pair': 'LA/ETH',
#    'perc_volume': 0.0291510855401,
#    'price': 0.307185,
#    'updated': True,
#    'vol_24h': 510737.0},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/BTC',
#    'perc_volume': 0.0288388199533,
#    'price': 0.0352523,
#    'updated': True,
#    'vol_24h': 505266.0},
#   {'currency': 'Litecoin',
#    'pair': 'LTC/ETH',
#    'perc_volume': 0.02880600096,
#    'price': 217.354,
#    'updated': True,
#    'vol_24h': 504691.0},
#   {'currency': 'Bitcoin Cash',
#    'pair': 'BCH/ETH',
#    'perc_volume': 0.0283384301892,
#    'price': 1241.74,
#    'updated': True,
#    'vol_24h': 496499.0},
#   {'currency': 'INS Ecosystem',
#    'pair': 'INS/USDT',
#    'perc_volume': 0.0276069947123,
#    'price': 2.32518,
#    'updated': True,
#    'vol_24h': 483684.0},
#   {'currency': 'True Chain',
#    'pair': 'TRUE/USDT',
#    'perc_volume': 0.0274210394424,
#    'price': 0.851824,
#    'updated': True,
#    'vol_24h': 480426.0},
#   {'currency': 'Hshare',
#    'pair': 'HSR/USDT',
#    'perc_volume': 0.0271615125509,
#    'price': 9.76541,
#    'updated': True,
#    'vol_24h': 475879.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/USDT',
#    'perc_volume': 0.0270055795253,
#    'price': 0.00370794,
#    'updated': True,
#    'vol_24h': 473147.0},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/BTC',
#    'perc_volume': 0.0267727644406,
#    'price': 0.501196,
#    'updated': True,
#    'vol_24h': 469068.0},
#   {'currency': 'aelf',
#    'pair': 'ELF/ETH',
#    'perc_volume': 0.0258521774092,
#    'price': 1.18447,
#    'updated': True,
#    'vol_24h': 452939.0},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/BTC',
#    'perc_volume': 0.0253920836612,
#    'price': 0.00326978,
#    'updated': True,
#    'vol_24h': 444878.0},
#   {'currency': 'Hshare',
#    'pair': 'HSR/BTC',
#    'perc_volume': 0.0252052722437,
#    'price': 9.69899,
#    'updated': True,
#    'vol_24h': 441605.0},
#   {'currency': 'Measurable Data Token',
#    'pair': 'MDT/ETH',
#    'perc_volume': 0.0250686310785,
#    'price': 0.0969432,
#    'updated': True,
#    'vol_24h': 439211.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/USDT',
#    'perc_volume': 0.025065777253,
#    'price': 0.180086,
#    'updated': True,
#    'vol_24h': 439161.0},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/BTC',
#    'perc_volume': 0.0244695560285,
#    'price': 5.79743,
#    'updated': True,
#    'vol_24h': 428715.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/BTC',
#    'perc_volume': 0.0241362292095,
#    'price': 4.06138,
#    'updated': True,
#    'vol_24h': 422875.0},
#   {'currency': 'Gas',
#    'pair': 'GAS/BTC',
#    'perc_volume': 0.0236043902883,
#    'price': 44.1731,
#    'updated': True,
#    'vol_24h': 413557.0},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/BTC',
#    'perc_volume': 0.0233299093512,
#    'price': 0.155928,
#    'updated': True,
#    'vol_24h': 408748.0},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/USDT',
#    'perc_volume': 0.0230397323739,
#    'price': 0.159341,
#    'updated': True,
#    'vol_24h': 403664.0},
#   {'currency': 'Achain',
#    'pair': 'ACT/USDT',
#    'perc_volume': 0.0221639504029,
#    'price': 0.38302,
#    'updated': True,
#    'vol_24h': 388320.0},
#   {'currency': 'Show',
#    'pair': 'SHOW/BTC',
#    'perc_volume': 0.02104582157,
#    'price': 0.00378069,
#    'updated': True,
#    'vol_24h': 368730.0},
#   {'currency': 'Nebulas',
#    'pair': 'NAS/ETH',
#    'perc_volume': 0.0203827637521,
#    'price': 8.32432,
#    'updated': True,
#    'vol_24h': 357113.0},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/USDT',
#    'perc_volume': 0.0200056021734,
#    'price': 324.311,
#    'updated': True,
#    'vol_24h': 350505.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/USDT',
#    'perc_volume': 0.0199881367613,
#    'price': 0.0706513,
#    'updated': True,
#    'vol_24h': 350199.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/USDT',
#    'perc_volume': 0.0197118293759,
#    'price': 0.253844,
#    'updated': True,
#    'vol_24h': 345358.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/BTC',
#    'perc_volume': 0.0193125221112,
#    'price': 0.119551,
#    'updated': True,
#    'vol_24h': 338362.0},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/BTC',
#    'perc_volume': 0.0189479744412,
#    'price': 0.289866,
#    'updated': True,
#    'vol_24h': 331975.0},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/USDT',
#    'perc_volume': 0.0189071076599,
#    'price': 2.18919,
#    'updated': True,
#    'vol_24h': 331259.0},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/BTC',
#    'perc_volume': 0.0188343351096,
#    'price': 0.0764311,
#    'updated': True,
#    'vol_24h': 329984.0},
#   {'currency': 'Dash',
#    'pair': 'DASH/BTC',
#    'perc_volume': 0.0187428985404,
#    'price': 619.503,
#    'updated': True,
#    'vol_24h': 328382.0},
#   {'currency': 'Datum',
#    'pair': 'DAT/ETH',
#    'perc_volume': 0.0185981525108,
#    'price': 0.0473945,
#    'updated': True,
#    'vol_24h': 325846.0},
#   {'currency': 'Hi Mutual Society',
#    'pair': 'HMC/BTC',
#    'perc_volume': 0.0183479290905,
#    'price': 0.0747963,
#    'updated': True,
#    'vol_24h': 321462.0},
#   {'currency': 'Acute Angle Cloud',
#    'pair': 'AAC/ETH',
#    'perc_volume': 0.0176857274203,
#    'price': 0.17941,
#    'updated': True,
#    'vol_24h': 309860.0},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/ETH',
#    'perc_volume': 0.0174526840295,
#    'price': 0.382318,
#    'updated': True,
#    'vol_24h': 305777.0},
#   {'currency': 'BitcoinX',
#    'pair': 'BCX/BTC',
#    'perc_volume': 0.017336818714,
#    'price': 0.00684611,
#    'updated': True,
#    'vol_24h': 303747.0},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/USDT',
#    'perc_volume': 0.0172754043891,
#    'price': 0.075662,
#    'updated': True,
#    'vol_24h': 302671.0},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/USDT',
#    'perc_volume': 0.0172546285395,
#    'price': 0.295032,
#    'updated': True,
#    'vol_24h': 302307.0},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/USDT',
#    'perc_volume': 0.0172134763757,
#    'price': 0.0735575,
#    'updated': True,
#    'vol_24h': 301586.0},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/USDT',
#    'perc_volume': 0.0169095439594,
#    'price': 5.91226,
#    'updated': True,
#    'vol_24h': 296261.0},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/BTC',
#    'perc_volume': 0.016768736209,
#    'price': 0.0756137,
#    'updated': True,
#    'vol_24h': 293794.0},
#   {'currency': 'Viuly',
#    'pair': 'VIU/ETH',
#    'perc_volume': 0.0163958553685,
#    'price': 0.00986667,
#    'updated': True,
#    'vol_24h': 287261.0},
#   {'currency': 'Monero',
#    'pair': 'XMR/BTC',
#    'perc_volume': 0.0162991106838,
#    'price': 292.251,
#    'updated': True,
#    'vol_24h': 285566.0},
#   {'currency': 'Bytom',
#    'pair': 'BTM/ETH',
#    'perc_volume': 0.0161404379858,
#    'price': 0.340439,
#    'updated': True,
#    'vol_24h': 282786.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/USDT',
#    'perc_volume': 0.0156355391774,
#    'price': 0.089191,
#    'updated': True,
#    'vol_24h': 273940.0},
#   {'currency': 'Dash',
#    'pair': 'DASH/USDT',
#    'perc_volume': 0.0153580331853,
#    'price': 619.161,
#    'updated': True,
#    'vol_24h': 269078.0},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/BTC',
#    'perc_volume': 0.0145751146962,
#    'price': 0.271698,
#    'updated': True,
#    'vol_24h': 255361.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/ETH',
#    'perc_volume': 0.0128671572079,
#    'price': 0.0818632,
#    'updated': True,
#    'vol_24h': 225437.0},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/USDT',
#    'perc_volume': 0.012732228338,
#    'price': 0.0349749,
#    'updated': True,
#    'vol_24h': 223073.0},
#   {'currency': 'IPChain',
#    'pair': 'IPC/USDT',
#    'perc_volume': 0.0127027768588,
#    'price': 0.913857,
#    'updated': True,
#    'vol_24h': 222557.0},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/BTC',
#    'perc_volume': 0.0122140307028,
#    'price': 408.796,
#    'updated': True,
#    'vol_24h': 213994.0},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/BTC',
#    'perc_volume': 0.0121677987296,
#    'price': 115.631,
#    'updated': True,
#    'vol_24h': 213184.0},
#   {'currency': 'Internet Node Token',
#    'pair': 'INT/ETH',
#    'perc_volume': 0.0121342377417,
#    'price': 0.252673,
#    'updated': True,
#    'vol_24h': 212596.0},
#   {'currency': 'Loopring',
#    'pair': 'LRC/BTC',
#    'perc_volume': 0.0118128969898,
#    'price': 0.615843,
#    'updated': True,
#    'vol_24h': 206966.0},
#   {'currency': 'Delphy',
#    'pair': 'DPY/ETH',
#    'perc_volume': 0.0115445803158,
#    'price': 1.72088,
#    'updated': True,
#    'vol_24h': 202265.0},
#   {'currency': 'Status',
#    'pair': 'SNT/USDT',
#    'perc_volume': 0.0114429841278,
#    'price': 0.170064,
#    'updated': True,
#    'vol_24h': 200485.0},
#   {'currency': 'MicroMoney',
#    'pair': 'AMM/ETH',
#    'perc_volume': 0.0108386580389,
#    'price': 0.502821,
#    'updated': True,
#    'vol_24h': 189897.0},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/ETH',
#    'perc_volume': 0.0103026525325,
#    'price': 0.27394,
#    'updated': True,
#    'vol_24h': 180506.0},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/USDT',
#    'perc_volume': 0.0101571645083,
#    'price': 0.342834,
#    'updated': True,
#    'vol_24h': 177957.0},
#   {'currency': 'RealChain',
#    'pair': 'RCT/BTC',
#    'perc_volume': 0.00968691114152,
#    'price': 0.0700959,
#    'updated': True,
#    'vol_24h': 169718.0},
#   {'currency': 'TRON',
#    'pair': 'TRX/USDT',
#    'perc_volume': 0.00926300390099,
#    'price': 0.0420901,
#    'updated': True,
#    'vol_24h': 162291.0},
#   {'currency': 'Primas',
#    'pair': 'PST/USDT',
#    'perc_volume': 0.00877562758123,
#    'price': 0.329706,
#    'updated': True,
#    'vol_24h': 153752.0},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/BTC',
#    'perc_volume': 0.00860377020931,
#    'price': 0.123128,
#    'updated': True,
#    'vol_24h': 150741.0},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/ETH',
#    'perc_volume': 0.00826011254199,
#    'price': 0.0787007,
#    'updated': True,
#    'vol_24h': 144720.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/BTC',
#    'perc_volume': 0.00824881139299,
#    'price': 0.0829707,
#    'updated': True,
#    'vol_24h': 144522.0},
#   {'currency': 'Super Bitcoin',
#    'pair': 'SBTC/BTC',
#    'perc_volume': 0.00814972657145,
#    'price': 19.3229,
#    'updated': True,
#    'vol_24h': 142786.0},
#   {'currency': 'Status',
#    'pair': 'SNT/BTC',
#    'perc_volume': 0.00800640745458,
#    'price': 0.169824,
#    'updated': True,
#    'vol_24h': 140275.0},
#   {'currency': 'Bancor',
#    'pair': 'BNT/BTC',
#    'perc_volume': 0.00795595181965,
#    'price': 4.87637,
#    'updated': True,
#    'vol_24h': 139391.0},
#   {'currency': 'Decentraland',
#    'pair': 'MANA/ETH',
#    'perc_volume': 0.00792199129614,
#    'price': 0.110877,
#    'updated': True,
#    'vol_24h': 138796.0},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/USDT',
#    'perc_volume': 0.00789276812297,
#    'price': 0.118153,
#    'updated': True,
#    'vol_24h': 138284.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/USDT',
#    'perc_volume': 0.00788437787599,
#    'price': 0.00430923,
#    'updated': True,
#    'vol_24h': 138137.0},
#   {'currency': 'LATOKEN',
#    'pair': 'LA/BTC',
#    'perc_volume': 0.00784933289878,
#    'price': 0.305929,
#    'updated': True,
#    'vol_24h': 137523.0},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/BTC',
#    'perc_volume': 0.00771343372823,
#    'price': 0.347414,
#    'updated': True,
#    'vol_24h': 135142.0},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/USDT',
#    'perc_volume': 0.00771252050407,
#    'price': 0.0766642,
#    'updated': True,
#    'vol_24h': 135126.0},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/BTC',
#    'perc_volume': 0.0073149255347,
#    'price': 0.127419,
#    'updated': True,
#    'vol_24h': 128160.0},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/BTC',
#    'perc_volume': 0.00730510837496,
#    'price': 17.7899,
#    'updated': True,
#    'vol_24h': 127988.0},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/BTC',
#    'perc_volume': 0.00719654885274,
#    'price': 0.0366829,
#    'updated': True,
#    'vol_24h': 126086.0},
#   {'currency': 'Trade Token',
#    'pair': 'TIO/USDT',
#    'perc_volume': 0.00683148749413,
#    'price': 0.26627,
#    'updated': True,
#    'vol_24h': 119690.0},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/BTC',
#    'perc_volume': 0.00650655092212,
#    'price': 36.785,
#    'updated': True,
#    'vol_24h': 113997.0},
#   {'currency': 'Hi Mutual Society',
#    'pair': 'HMC/ETH',
#    'perc_volume': 0.00649079780533,
#    'price': 0.0751849,
#    'updated': True,
#    'vol_24h': 113721.0},
#   {'currency': 'Yee',
#    'pair': 'YEE/BTC',
#    'perc_volume': 0.00627584766829,
#    'price': 0.0213558,
#    'updated': True,
#    'vol_24h': 109955.0},
#   {'currency': 'ChatCoin',
#    'pair': 'CHAT/USDT',
#    'perc_volume': 0.00626249176492,
#    'price': 0.198225,
#    'updated': True,
#    'vol_24h': 109721.0},
#   {'currency': 'ICON',
#    'pair': 'ICX/USDT',
#    'perc_volume': 0.00611968633665,
#    'price': 4.05869,
#    'updated': True,
#    'vol_24h': 107219.0},
#   {'currency': 'Golem',
#    'pair': 'GNT/BTC',
#    'perc_volume': 0.00602990498626,
#    'price': 0.378273,
#    'updated': True,
#    'vol_24h': 105646.0},
#   {'currency': 'All Sports',
#    'pair': 'SOC/USDT',
#    'perc_volume': 0.0060166061594,
#    'price': 0.0820758,
#    'updated': True,
#    'vol_24h': 105413.0},
#   {'currency': 'Nano',
#    'pair': 'NANO/USDT',
#    'perc_volume': 0.00584566201165,
#    'price': 12.8031,
#    'updated': True,
#    'vol_24h': 102418.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/BTC',
#    'perc_volume': 0.00572968254312,
#    'price': 0.00439377,
#    'updated': True,
#    'vol_24h': 100386.0},
#   {'currency': 'LightChain',
#    'pair': 'LIGHT/ETH',
#    'perc_volume': 0.00565229250307,
#    'price': 0.00430859,
#    'updated': True,
#    'vol_24h': 99030.1},
#   {'currency': 'Nano',
#    'pair': 'NANO/BTC',
#    'perc_volume': 0.00554388137978,
#    'price': 14.1582,
#    'updated': True,
#    'vol_24h': 97130.7},
#   {'currency': 'SmartMesh',
#    'pair': 'SMT/USDT',
#    'perc_volume': 0.00541195473433,
#    'price': 0.055118,
#    'updated': True,
#    'vol_24h': 94819.3},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/USDT',
#    'perc_volume': 0.00535047191765,
#    'price': 17.7618,
#    'updated': True,
#    'vol_24h': 93742.1},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/BTC',
#    'perc_volume': 0.00530325252084,
#    'price': 0.0788835,
#    'updated': True,
#    'vol_24h': 92914.8},
#   {'currency': 'Hi Mutual Society',
#    'pair': 'HMC/USDT',
#    'perc_volume': 0.00517462489768,
#    'price': 0.0738582,
#    'updated': True,
#    'vol_24h': 90661.2},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/USDT',
#    'perc_volume': 0.00514918018947,
#    'price': 0.0338726,
#    'updated': True,
#    'vol_24h': 90215.4},
#   {'currency': 'ugChain',
#    'pair': 'UGC/BTC',
#    'perc_volume': 0.00514480242115,
#    'price': 0.0837882,
#    'updated': True,
#    'vol_24h': 90138.7},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/USDT',
#    'perc_volume': 0.00505885661224,
#    'price': 113.961,
#    'updated': True,
#    'vol_24h': 88632.9},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/ETH',
#    'perc_volume': 0.00495464632009,
#    'price': 331.378,
#    'updated': True,
#    'vol_24h': 86807.1},
#   {'currency': 'IOStoken',
#    'pair': 'IOST/ETH',
#    'perc_volume': 0.00481095049826,
#    'price': 0.0352529,
#    'updated': True,
#    'vol_24h': 84289.5},
#   {'currency': 'Dent',
#    'pair': 'DENT/BTC',
#    'perc_volume': 0.00476889652561,
#    'price': 0.028815,
#    'updated': True,
#    'vol_24h': 83552.7},
#   {'currency': 'Nuls',
#    'pair': 'NULS/USDT',
#    'perc_volume': 0.00471283026974,
#    'price': 2.79589,
#    'updated': True,
#    'vol_24h': 82570.4},
#   {'currency': 'NEM',
#    'pair': 'XEM/BTC',
#    'perc_volume': 0.00458312960819,
#    'price': 0.420757,
#    'updated': True,
#    'vol_24h': 80298.0},
#   {'currency': 'ProChain',
#    'pair': 'PRA/BTC',
#    'perc_volume': 0.00455230258508,
#    'price': 0.349049,
#    'updated': True,
#    'vol_24h': 79757.9},
#   {'currency': 'OneRoot Network',
#    'pair': 'RNT/BTC',
#    'perc_volume': 0.00452843318855,
#    'price': 0.0778617,
#    'updated': True,
#    'vol_24h': 79339.7},
#   {'currency': 'Loopring',
#    'pair': 'LRC/USDT',
#    'perc_volume': 0.00447849694987,
#    'price': 0.622533,
#    'updated': True,
#    'vol_24h': 78464.8},
#   {'currency': 'SingularDTV',
#    'pair': 'SNGLS/BTC',
#    'perc_volume': 0.00447750952624,
#    'price': 0.122383,
#    'updated': True,
#    'vol_24h': 78447.5},
#   {'currency': 'Datum',
#    'pair': 'DAT/USDT',
#    'perc_volume': 0.00445393121992,
#    'price': 0.0476019,
#    'updated': True,
#    'vol_24h': 78034.4},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/USDT',
#    'perc_volume': 0.00444030134931,
#    'price': 0.122162,
#    'updated': True,
#    'vol_24h': 77795.6},
#   {'currency': 'Kcash',
#    'pair': 'KCASH/ETH',
#    'perc_volume': 0.00433613671837,
#    'price': 0.156005,
#    'updated': True,
#    'vol_24h': 75970.6},
#   {'currency': 'Read',
#    'pair': 'READ/BTC',
#    'perc_volume': 0.00432656498762,
#    'price': 0.0382156,
#    'updated': True,
#    'vol_24h': 75802.9},
#   {'currency': 'ProChain',
#    'pair': 'PRA/ETH',
#    'perc_volume': 0.00410261388494,
#    'price': 0.35053,
#    'updated': True,
#    'vol_24h': 71879.2},
#   {'currency': 'TRON',
#    'pair': 'TRX/BTC',
#    'perc_volume': 0.00409921783259,
#    'price': 0.0417919,
#    'updated': True,
#    'vol_24h': 71819.7},
#   {'currency': 'EOS',
#    'pair': 'EOS/BCH',
#    'perc_volume': 0.00404000666101,
#    'price': 8.13275,
#    'updated': True,
#    'vol_24h': 70782.3},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/USDT',
#    'perc_volume': 0.0040179408822,
#    'price': 0.129878,
#    'updated': True,
#    'vol_24h': 70395.7},
#   {'currency': 'BLOCKv',
#    'pair': 'VEE/ETH',
#    'perc_volume': 0.0038879776687,
#    'price': 0.0723843,
#    'updated': True,
#    'vol_24h': 68118.7},
#   {'currency': 'Yee',
#    'pair': 'YEE/USDT',
#    'perc_volume': 0.00378531985763,
#    'price': 0.0217466,
#    'updated': True,
#    'vol_24h': 66320.1},
#   {'currency': 'AI Doctor',
#    'pair': 'AIDOC/ETH',
#    'perc_volume': 0.00376683848366,
#    'price': 0.0758829,
#    'updated': True,
#    'vol_24h': 65996.3},
#   {'currency': 'ChatCoin',
#    'pair': 'CHAT/BTC',
#    'perc_volume': 0.0036605905601,
#    'price': 0.196187,
#    'updated': True,
#    'vol_24h': 64134.8},
#   {'currency': '0x',
#    'pair': 'ZRX/BTC',
#    'perc_volume': 0.0035786857681,
#    'price': 1.02334,
#    'updated': True,
#    'vol_24h': 62699.8},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/BTC',
#    'perc_volume': 0.00357236169079,
#    'price': 0.386447,
#    'updated': True,
#    'vol_24h': 62589.0},
#   {'currency': 'Primas',
#    'pair': 'PST/BTC',
#    'perc_volume': 0.00356808095253,
#    'price': 0.32095,
#    'updated': True,
#    'vol_24h': 62514.0},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/ETH',
#    'perc_volume': 0.00355781288836,
#    'price': 6.56501,
#    'updated': True,
#    'vol_24h': 62334.1},
#   {'currency': 'Stellar',
#    'pair': 'XLM/ETH',
#    'perc_volume': 0.00353279625398,
#    'price': 0.356306,
#    'updated': True,
#    'vol_24h': 61895.8},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/USDT',
#    'perc_volume': 0.0034447271989,
#    'price': 0.0796706,
#    'updated': True,
#    'vol_24h': 60352.8},
#   {'currency': 'Exchange Union',
#    'pair': 'XUC/BTC',
#    'perc_volume': 0.00339441425524,
#    'price': 6.55847,
#    'updated': True,
#    'vol_24h': 59471.3},
#   {'currency': 'Achain',
#    'pair': 'ACT/ETH',
#    'perc_volume': 0.00332993492178,
#    'price': 0.371564,
#    'updated': True,
#    'vol_24h': 58341.6},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/BTC',
#    'perc_volume': 0.00332801715104,
#    'price': 0.153782,
#    'updated': True,
#    'vol_24h': 58308.0},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/BTC',
#    'perc_volume': 0.00327931947262,
#    'price': 0.0535427,
#    'updated': True,
#    'vol_24h': 57454.8},
#   {'currency': 'ProChain',
#    'pair': 'PRA/USDT',
#    'perc_volume': 0.003152678112,
#    'price': 0.349048,
#    'updated': True,
#    'vol_24h': 55236.0},
#   {'currency': 'Dent',
#    'pair': 'DENT/USDT',
#    'perc_volume': 0.00309826136727,
#    'price': 0.0293629,
#    'updated': True,
#    'vol_24h': 54282.6},
#   {'currency': 'ICON',
#    'pair': 'ICX/ETH',
#    'perc_volume': 0.0030775083482,
#    'price': 3.98086,
#    'updated': True,
#    'vol_24h': 53919.0},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/USDT',
#    'perc_volume': 0.00305091640214,
#    'price': 402.994,
#    'updated': True,
#    'vol_24h': 53453.1},
#   {'currency': 'Golem',
#    'pair': 'GNT/USDT',
#    'perc_volume': 0.00296372632531,
#    'price': 0.380415,
#    'updated': True,
#    'vol_24h': 51925.5},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/USDT',
#    'perc_volume': 0.00295410893336,
#    'price': 0.150522,
#    'updated': True,
#    'vol_24h': 51757.0},
#   {'currency': 'StarChain',
#    'pair': 'STC/BTC',
#    'perc_volume': 0.00293517094731,
#    'price': 0.0900212,
#    'updated': True,
#    'vol_24h': 51425.2},
#   {'currency': 'IoT Chain',
#    'pair': 'ITC/ETH',
#    'perc_volume': 0.00292174084448,
#    'price': 2.12982,
#    'updated': True,
#    'vol_24h': 51189.9},
#   {'currency': 'IPChain',
#    'pair': 'IPC/ETH',
#    'perc_volume': 0.00279185183044,
#    'price': 0.912344,
#    'updated': True,
#    'vol_24h': 48914.2},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/BTC',
#    'perc_volume': 0.00276243459713,
#    'price': 0.0416897,
#    'updated': True,
#    'vol_24h': 48398.8},
#   {'currency': 'Enigma',
#    'pair': 'ENG/USDT',
#    'perc_volume': 0.00270032393884,
#    'price': 2.55327,
#    'updated': True,
#    'vol_24h': 47310.6},
#   {'currency': 'Simple Token',
#    'pair': 'OST/BTC',
#    'perc_volume': 0.00267224229587,
#    'price': 0.242373,
#    'updated': True,
#    'vol_24h': 46818.6},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/BTC',
#    'perc_volume': 0.00261312244671,
#    'price': 0.0351571,
#    'updated': True,
#    'vol_24h': 45782.8},
#   {'currency': 'ugChain',
#    'pair': 'UGC/USDT',
#    'perc_volume': 0.00260633604966,
#    'price': 0.0851824,
#    'updated': True,
#    'vol_24h': 45663.9},
#   {'currency': 'Genaro Network',
#    'pair': 'GNX/ETH',
#    'perc_volume': 0.00260309410388,
#    'price': 0.346143,
#    'updated': True,
#    'vol_24h': 45607.1},
#   {'currency': '0x',
#    'pair': 'ZRX/USDT',
#    'perc_volume': 0.00253945379512,
#    'price': 1.0272,
#    'updated': True,
#    'vol_24h': 44492.1},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/BTC',
#    'perc_volume': 0.0024989465959,
#    'price': 2.01664,
#    'updated': True,
#    'vol_24h': 43782.4},
#   {'currency': 'QunQun',
#    'pair': 'QUN/BTC',
#    'perc_volume': 0.00249784501925,
#    'price': 0.0588561,
#    'updated': True,
#    'vol_24h': 43763.1},
#   {'currency': 'Monero',
#    'pair': 'XMR/ETH',
#    'perc_volume': 0.00244269769519,
#    'price': 286.314,
#    'updated': True,
#    'vol_24h': 42796.9},
#   {'currency': 'NEM',
#    'pair': 'XEM/USDT',
#    'perc_volume': 0.00243780053063,
#    'price': 0.423708,
#    'updated': True,
#    'vol_24h': 42711.1},
#   {'currency': 'Show',
#    'pair': 'SHOW/ETH',
#    'perc_volume': 0.00239161421865,
#    'price': 0.00373986,
#    'updated': True,
#    'vol_24h': 41901.9},
#   {'currency': 'OFCOIN',
#    'pair': 'OF/ETH',
#    'perc_volume': 0.00237457117273,
#    'price': 0.003309,
#    'updated': True,
#    'vol_24h': 41603.3},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/USDT',
#    'perc_volume': 0.00236389786535,
#    'price': 0.0166356,
#    'updated': True,
#    'vol_24h': 41416.3},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/BTC',
#    'perc_volume': 0.00220458591035,
#    'price': 0.0167576,
#    'updated': True,
#    'vol_24h': 38625.1},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/USDT',
#    'perc_volume': 0.00218125874067,
#    'price': 0.28461,
#    'updated': True,
#    'vol_24h': 38216.4},
#   {'currency': 'SingularDTV',
#    'pair': 'SNGLS/USDT',
#    'perc_volume': 0.00216987768455,
#    'price': 0.121059,
#    'updated': True,
#    'vol_24h': 38017.0},
#   {'currency': 'RefToken',
#    'pair': 'REF/USDT',
#    'perc_volume': 0.00214560875246,
#    'price': 17.0365,
#    'updated': True,
#    'vol_24h': 37591.8},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/BTC',
#    'perc_volume': 0.00210830925311,
#    'price': 1.31721,
#    'updated': True,
#    'vol_24h': 36938.3},
#   {'currency': 'Nuls',
#    'pair': 'NULS/BTC',
#    'perc_volume': 0.00205748262086,
#    'price': 2.81354,
#    'updated': True,
#    'vol_24h': 36047.8},
#   {'currency': 'Monero',
#    'pair': 'XMR/USDT',
#    'perc_volume': 0.00201260336097,
#    'price': 290.623,
#    'updated': True,
#    'vol_24h': 35261.5},
#   {'currency': 'Worldcore',
#    'pair': 'WRC/ETH',
#    'perc_volume': 0.00197265551155,
#    'price': 0.120063,
#    'updated': True,
#    'vol_24h': 34561.6},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/USDT',
#    'perc_volume': 0.00196160549919,
#    'price': 33.5815,
#    'updated': True,
#    'vol_24h': 34368.0},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/BTC',
#    'perc_volume': 0.0019534492659,
#    'price': 0.0990131,
#    'updated': True,
#    'vol_24h': 34225.1},
#   {'currency': 'Waltonchain',
#    'pair': 'WTC/BTC',
#    'perc_volume': 0.00189861586264,
#    'price': 21.0998,
#    'updated': True,
#    'vol_24h': 33264.4},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/BTC',
#    'perc_volume': 0.00186756624115,
#    'price': 35.2626,
#    'updated': True,
#    'vol_24h': 32720.4},
#   {'currency': 'RefToken',
#    'pair': 'REF/BTC',
#    'perc_volume': 0.00186042596973,
#    'price': 17.4729,
#    'updated': True,
#    'vol_24h': 32595.3},
#   {'currency': 'Molecular Future',
#    'pair': 'MOF/USDT',
#    'perc_volume': 0.00184150510663,
#    'price': 0.386929,
#    'updated': True,
#    'vol_24h': 32263.8},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/ETH',
#    'perc_volume': 0.00183452464945,
#    'price': 0.0803552,
#    'updated': True,
#    'vol_24h': 32141.5},
#   {'currency': 'AirSwap',
#    'pair': 'AST/BTC',
#    'perc_volume': 0.00182397691038,
#    'price': 0.452967,
#    'updated': True,
#    'vol_24h': 31956.7},
#   {'currency': 'Gas',
#    'pair': 'GAS/USDT',
#    'perc_volume': 0.00178933146875,
#    'price': 43.182,
#    'updated': True,
#    'vol_24h': 31349.7},
#   {'currency': 'Nano',
#    'pair': 'NANO/ETH',
#    'perc_volume': 0.0016794477715,
#    'price': 14.6369,
#    'updated': True,
#    'vol_24h': 29424.5},
#   {'currency': 'Content and AD Network',
#    'pair': 'CAN/ETH',
#    'perc_volume': 0.00165017893712,
#    'price': 0.0346324,
#    'updated': True,
#    'vol_24h': 28911.7},
#   {'currency': 'Hshare',
#    'pair': 'HSR/ETH',
#    'perc_volume': 0.00164996775403,
#    'price': 9.7202,
#    'updated': True,
#    'vol_24h': 28908.0},
#   {'currency': 'SportyCo',
#    'pair': 'SPF/ETH',
#    'perc_volume': 0.00158004332151,
#    'price': 0.284358,
#    'updated': True,
#    'vol_24h': 27682.9},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/USDT',
#    'perc_volume': 0.00155921039532,
#    'price': 2.0541,
#    'updated': True,
#    'vol_24h': 27317.9},
#   {'currency': 'SmartMesh',
#    'pair': 'SMT/BTC',
#    'perc_volume': 0.00152963334779,
#    'price': 0.0535427,
#    'updated': True,
#    'vol_24h': 26799.7},
#   {'currency': 'Everex',
#    'pair': 'EVX/BTC',
#    'perc_volume': 0.00151715642268,
#    'price': 2.40084,
#    'updated': True,
#    'vol_24h': 26581.1},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/BTC',
#    'perc_volume': 0.00151360626375,
#    'price': 0.15368,
#    'updated': True,
#    'vol_24h': 26518.9},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/USDT',
#    'perc_volume': 0.00150420005488,
#    'price': 1.33446,
#    'updated': True,
#    'vol_24h': 26354.1},
#   {'currency': 'Revain',
#    'pair': 'R/USDT',
#    'perc_volume': 0.00149857801864,
#    'price': 2.20993,
#    'updated': True,
#    'vol_24h': 26255.6},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/BTC',
#    'perc_volume': 0.00148164341809,
#    'price': 0.708317,
#    'updated': True,
#    'vol_24h': 25958.9},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/BTC',
#    'perc_volume': 0.00147540495554,
#    'price': 0.352319,
#    'updated': True,
#    'vol_24h': 25849.6},
#   {'currency': 'Aventus',
#    'pair': 'AVT/BTC',
#    'perc_volume': 0.00146668937244,
#    'price': 2.13374,
#    'updated': True,
#    'vol_24h': 25696.9},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/USDT',
#    'perc_volume': 0.00143461237377,
#    'price': 0.0271582,
#    'updated': True,
#    'vol_24h': 25134.9},
#   {'currency': 'Loopring',
#    'pair': 'LRC/ETH',
#    'perc_volume': 0.00141155917134,
#    'price': 0.634431,
#    'updated': True,
#    'vol_24h': 24731.0},
#   {'currency': 'UTRUST',
#    'pair': 'UTK/BTC',
#    'perc_volume': 0.00140928752624,
#    'price': 0.218973,
#    'updated': True,
#    'vol_24h': 24691.2},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/USDT',
#    'perc_volume': 0.00140440177697,
#    'price': 0.676549,
#    'updated': True,
#    'vol_24h': 24605.6},
#   {'currency': 'Leverj',
#    'pair': 'LEV/BTC',
#    'perc_volume': 0.00140041212891,
#    'price': 0.089919,
#    'updated': True,
#    'vol_24h': 24535.7},
#   {'currency': 'Ace',
#    'pair': 'ACE/USDT',
#    'perc_volume': 0.00137268436031,
#    'price': 0.286914,
#    'updated': True,
#    'vol_24h': 24049.9},
#   {'currency': 'Status',
#    'pair': 'SNT/ETH',
#    'perc_volume': 0.00134237102579,
#    'price': 0.168638,
#    'updated': True,
#    'vol_24h': 23518.8},
#   {'currency': 'Civic',
#    'pair': 'CVC/USDT',
#    'perc_volume': 0.00131400970792,
#    'price': 0.362276,
#    'updated': True,
#    'vol_24h': 23021.9},
#   {'currency': 'TRON',
#    'pair': 'TRX/ETH',
#    'perc_volume': 0.00130057960509,
#    'price': 0.0416899,
#    'updated': True,
#    'vol_24h': 22786.6},
#   {'currency': 'TenX',
#    'pair': 'PAY/BTC',
#    'perc_volume': 0.00125148809876,
#    'price': 1.61578,
#    'updated': True,
#    'vol_24h': 21926.5},
#   {'currency': 'QunQun',
#    'pair': 'QUN/ETH',
#    'perc_volume': 0.0012443991962,
#    'price': 0.0591397,
#    'updated': True,
#    'vol_24h': 21802.3},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/USDT',
#    'perc_volume': 0.00119882360288,
#    'price': 0.0539155,
#    'updated': True,
#    'vol_24h': 21003.8},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/BTC',
#    'perc_volume': 0.00119597548503,
#    'price': 0.0274866,
#    'updated': True,
#    'vol_24h': 20953.9},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/USDT',
#    'perc_volume': 0.00118074176448,
#    'price': 0.0993127,
#    'updated': True,
#    'vol_24h': 20687.0},
#   {'currency': 'Selfkey',
#    'pair': 'KEY/ETH',
#    'perc_volume': 0.00116888697334,
#    'price': 0.0189578,
#    'updated': True,
#    'vol_24h': 20479.3},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/USDT',
#    'perc_volume': 0.00116287681682,
#    'price': 0.0830779,
#    'updated': True,
#    'vol_24h': 20374.0},
#   {'currency': 'Substratum',
#    'pair': 'SUB/BTC',
#    'perc_volume': 0.00115875018514,
#    'price': 0.576503,
#    'updated': True,
#    'vol_24h': 20301.7},
#   {'currency': 'OmiseGO',
#    'pair': 'OMG/ETH',
#    'perc_volume': 0.00112979527157,
#    'price': 17.541,
#    'updated': True,
#    'vol_24h': 19794.4},
#   {'currency': 'Storj',
#    'pair': 'STORJ/BTC',
#    'perc_volume': 0.00109871140417,
#    'price': 0.910021,
#    'updated': True,
#    'vol_24h': 19249.8},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/USDT',
#    'perc_volume': 0.00109721029195,
#    'price': 3.21258,
#    'updated': True,
#    'vol_24h': 19223.5},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/USDT',
#    'perc_volume': 0.00107156581596,
#    'price': 0.729462,
#    'updated': True,
#    'vol_24h': 18774.2},
#   {'currency': 'RefToken',
#    'pair': 'REF/ETH',
#    'perc_volume': 0.00106086967797,
#    'price': 20.6122,
#    'updated': True,
#    'vol_24h': 18586.8},
#   {'currency': 'Po.et',
#    'pair': 'POE/USDT',
#    'perc_volume': 0.00106057288011,
#    'price': 0.0609305,
#    'updated': True,
#    'vol_24h': 18581.6},
#   {'currency': 'Ethereum Classic',
#    'pair': 'ETC/BCH',
#    'perc_volume': 0.00104625809138,
#    'price': 35.171,
#    'updated': True,
#    'vol_24h': 18330.8},
#   {'currency': 'Waltonchain',
#    'pair': 'WTC/USDT',
#    'perc_volume': 0.00102536238103,
#    'price': 21.4426,
#    'updated': True,
#    'vol_24h': 17964.7},
#   {'currency': 'TopChain',
#    'pair': 'TOPC/USDT',
#    'perc_volume': 0.00102515119795,
#    'price': 0.0432927,
#    'updated': True,
#    'vol_24h': 17961.0},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/USDT',
#    'perc_volume': 0.00102185217566,
#    'price': 36.5783,
#    'updated': True,
#    'vol_24h': 17903.2},
#   {'currency': 'UTRUST',
#    'pair': 'UTK/USDT',
#    'perc_volume': 0.00102170948439,
#    'price': 0.222076,
#    'updated': True,
#    'vol_24h': 17900.7},
#   {'currency': 'Ark',
#    'pair': 'ARK/BTC',
#    'perc_volume': 0.00100196671954,
#    'price': 3.92548,
#    'updated': True,
#    'vol_24h': 17554.8},
#   {'currency': 'SelfSell',
#    'pair': 'SSC/ETH',
#    'perc_volume': 0.000975448972948,
#    'price': 0.0784249,
#    'updated': True,
#    'vol_24h': 17090.2},
#   {'currency': 'Theta Token',
#    'pair': 'THETA/ETH',
#    'perc_volume': 0.000958560033609,
#    'price': 0.124242,
#    'updated': True,
#    'vol_24h': 16794.3},
#   {'currency': 'Read',
#    'pair': 'READ/USDT',
#    'perc_volume': 0.000953040735082,
#    'price': 0.0386828,
#    'updated': True,
#    'vol_24h': 16697.6},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/BTC',
#    'perc_volume': 0.00095020403253,
#    'price': 3.10231,
#    'updated': True,
#    'vol_24h': 16647.9},
#   {'currency': 'Olympus Labs',
#    'pair': 'MOT/ETH',
#    'perc_volume': 0.00095014695602,
#    'price': 0.729582,
#    'updated': True,
#    'vol_24h': 16646.9},
#   {'currency': 'FirstBlood',
#    'pair': '1ST/ETH',
#    'perc_volume': 0.000940398288095,
#    'price': 0.289633,
#    'updated': True,
#    'vol_24h': 16476.1},
#   {'currency': 'Bancor',
#    'pair': 'BNT/USDT',
#    'perc_volume': 0.000938771607557,
#    'price': 5.00151,
#    'updated': True,
#    'vol_24h': 16447.6},
#   {'currency': 'Yee',
#    'pair': 'YEE/ETH',
#    'perc_volume': 0.000900176471426,
#    'price': 0.021069,
#    'updated': True,
#    'vol_24h': 15771.4},
#   {'currency': 'Po.et',
#    'pair': 'POE/BTC',
#    'perc_volume': 0.000889457502828,
#    'price': 0.0605931,
#    'updated': True,
#    'vol_24h': 15583.6},
#   {'currency': 'Aventus',
#    'pair': 'AVT/USDT',
#    'perc_volume': 0.000880941687521,
#    'price': 2.14479,
#    'updated': True,
#    'vol_24h': 15434.4},
#   {'currency': 'Hydro Protocol',
#    'pair': 'HOT/BTC',
#    'perc_volume': 0.000849909188979,
#    'price': 0.0786791,
#    'updated': True,
#    'vol_24h': 14890.7},
#   {'currency': 'Dash',
#    'pair': 'DASH/ETH',
#    'perc_volume': 0.000848231139582,
#    'price': 617.03,
#    'updated': True,
#    'vol_24h': 14861.3},
#   {'currency': 'Request Network',
#    'pair': 'REQ/BTC',
#    'perc_volume': 0.000839943630315,
#    'price': 0.296426,
#    'updated': True,
#    'vol_24h': 14716.1},
#   {'currency': 'BT2 [CST]',
#    'pair': 'BT2/BTC',
#    'perc_volume': 0.00082420763648,
#    'price': 62.2383,
#    'updated': True,
#    'vol_24h': 14440.4},
#   {'currency': 'OAX',
#    'pair': 'OAX/BTC',
#    'perc_volume': 0.000817660960771,
#    'price': 0.769625,
#    'updated': True,
#    'vol_24h': 14325.7},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/BTC',
#    'perc_volume': 0.000804579024655,
#    'price': 0.671429,
#    'updated': True,
#    'vol_24h': 14096.5},
#   {'currency': 'Maker',
#    'pair': 'MKR/ETH',
#    'perc_volume': 0.000790184328808,
#    'price': 1038.42,
#    'updated': True,
#    'vol_24h': 13844.3},
#   {'currency': 'Gifto',
#    'pair': 'GTO/USDT',
#    'perc_volume': 0.000784704983838,
#    'price': 0.400458,
#    'updated': True,
#    'vol_24h': 13748.3},
#   {'currency': 'Zcash',
#    'pair': 'ZEC/ETH',
#    'perc_volume': 0.000777193715108,
#    'price': 399.148,
#    'updated': True,
#    'vol_24h': 13616.7},
#   {'currency': 'Maggie',
#    'pair': 'MAG/BTC',
#    'perc_volume': 0.000772142443964,
#    'price': 0.0264648,
#    'updated': True,
#    'vol_24h': 13528.2},
#   {'currency': 'DigixDAO',
#    'pair': 'DGD/BCH',
#    'perc_volume': 0.00074692033415,
#    'price': 349.565,
#    'updated': True,
#    'vol_24h': 13086.3},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/BTC',
#    'perc_volume': 0.000746908918848,
#    'price': 1.5014,
#    'updated': True,
#    'vol_24h': 13086.1},
#   {'currency': 'Substratum',
#    'pair': 'SUB/ETH',
#    'perc_volume': 0.000719729084738,
#    'price': 0.568734,
#    'updated': True,
#    'vol_24h': 12609.9},
#   {'currency': 'Gifto',
#    'pair': 'GTO/BTC',
#    'perc_volume': 0.000704946268621,
#    'price': 0.369588,
#    'updated': True,
#    'vol_24h': 12350.9},
#   {'currency': 'NAGA',
#    'pair': 'NGC/BTC',
#    'perc_volume': 0.000681636221895,
#    'price': 0.941391,
#    'updated': True,
#    'vol_24h': 11942.5},
#   {'currency': 'Maggie',
#    'pair': 'MAG/USDT',
#    'perc_volume': 0.000677675112094,
#    'price': 0.0265569,
#    'updated': True,
#    'vol_24h': 11873.1},
#   {'currency': 'SingularDTV',
#    'pair': 'SNGLS/ETH',
#    'perc_volume': 0.000661482506178,
#    'price': 0.12138,
#    'updated': True,
#    'vol_24h': 11589.4},
#   {'currency': 'ugChain',
#    'pair': 'UGC/ETH',
#    'perc_volume': 0.000642270552878,
#    'price': 0.0810101,
#    'updated': True,
#    'vol_24h': 11252.8},
#   {'currency': 'Golem',
#    'pair': 'GNT/ETH',
#    'perc_volume': 0.000616266494875,
#    'price': 0.379569,
#    'updated': True,
#    'vol_24h': 10797.2},
#   {'currency': 'NAGA',
#    'pair': 'NGC/ETH',
#    'perc_volume': 0.000610832811114,
#    'price': 0.945132,
#    'updated': True,
#    'vol_24h': 10702.0},
#   {'currency': 'LATOKEN',
#    'pair': 'LA/USDT',
#    'perc_volume': 0.000601609247081,
#    'price': 0.316378,
#    'updated': True,
#    'vol_24h': 10540.4},
#   {'currency': 'Populous',
#    'pair': 'PPT/BTC',
#    'perc_volume': 0.000601232542114,
#    'price': 21.4579,
#    'updated': True,
#    'vol_24h': 10533.8},
#   {'currency': 'ChainLink',
#    'pair': 'LINK/ETH',
# ...
#    'price': 4.06074,
#    'updated': True,
#    'vol_24h': 6998.7},
#   {'currency': 'Metal',
#    'pair': 'MTL/USDT',
#    'perc_volume': 0.000398625200379,
#    'price': 4.06651,
#    'updated': True,
#    'vol_24h': 6984.05},
#   {'currency': 'Kyber Network',
#    'pair': 'KNC/ETH',
#    'perc_volume': 0.00039744371662,
#    'price': 2.00266,
#    'updated': True,
#    'vol_24h': 6963.35},
#   {'currency': 'Enigma',
#    'pair': 'ENG/BTC',
#    'perc_volume': 0.000391148177556,
#    'price': 2.521,
#    'updated': True,
#    'vol_24h': 6853.05},
#   {'currency': 'Everex',
#    'pair': 'EVX/USDT',
#    'perc_volume': 0.000373977280257,
#    'price': 2.40305,
#    'updated': True,
#    'vol_24h': 6552.21},
#   {'currency': 'Gifto',
#    'pair': 'GTO/ETH',
#    'perc_volume': 0.000373848858109,
#    'price': 0.39639,
#    'updated': True,
#    'vol_24h': 6549.96},
#   {'currency': 'Bancor',
#    'pair': 'BNT/ETH',
#    'perc_volume': 0.000345812305582,
#    'price': 4.87422,
#    'updated': True,
#    'vol_24h': 6058.75},
#   {'currency': 'Centra',
#    'pair': 'CTR/BTC',
#    'perc_volume': 0.000343254707164,
#    'price': 0.713732,
#    'updated': True,
#    'vol_24h': 6013.94},
#   {'currency': 'Time New Bank',
#    'pair': 'TNB/ETH',
#    'perc_volume': 0.000339091546517,
#    'price': 0.0540986,
#    'updated': True,
#    'vol_24h': 5941.0},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/USDT',
#    'perc_volume': 0.00033370980238,
#    'price': 0.347244,
#    'updated': True,
#    'vol_24h': 5846.71},
#   {'currency': 'Aventus',
#    'pair': 'AVT/ETH',
#    'perc_volume': 0.000333422136769,
#    'price': 2.12652,
#    'updated': True,
#    'vol_24h': 5841.67},
#   {'currency': 'Monaco',
#    'pair': 'MCO/BTC',
#    'perc_volume': 0.000326798978536,
#    'price': 7.10881,
#    'updated': True,
#    'vol_24h': 5725.63},
#   {'currency': 'ChatCoin',
#    'pair': 'CHAT/ETH',
#    'perc_volume': 0.000320902975043,
#    'price': 0.198195,
#    'updated': True,
#    'vol_24h': 5622.33},
#   {'currency': 'Raiden Network Token',
#    'pair': 'RDN/ETH',
#    'perc_volume': 0.00028619474925,
#    'price': 3.07121,
#    'updated': True,
#    'vol_24h': 5014.23},
#   {'currency': 'Iconomi',
#    'pair': 'ICN/USDT',
#    'perc_volume': 0.000282028164012,
#    'price': 1.48508,
#    'updated': True,
#    'vol_24h': 4941.23},
#   {'currency': 'Request Network',
#    'pair': 'REQ/ETH',
#    'perc_volume': 0.000277407249754,
#    'price': 0.312579,
#    'updated': True,
#    'vol_24h': 4860.27},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/USDT',
#    'perc_volume': 0.000265321869505,
#    'price': 0.550178,
#    'updated': True,
#    'vol_24h': 4648.53},
#   {'currency': 'Substratum',
#    'pair': 'SUB/USDT',
#    'perc_volume': 0.000260175851354,
#    'price': 0.56942,
#    'updated': True,
#    'vol_24h': 4558.37},
#   {'currency': 'BitcoinX',
#    'pair': 'BCX/BCH',
#    'perc_volume': 0.000253819240424,
#    'price': 0.00699218,
#    'updated': True,
#    'vol_24h': 4447.0},
#   {'currency': 'FunFair',
#    'pair': 'FUN/BTC',
#    'perc_volume': 0.000253162289793,
#    'price': 0.0519078,
#    'updated': True,
#    'vol_24h': 4435.49},
#   {'currency': 'Metal',
#    'pair': 'MTL/BTC',
#    'perc_volume': 0.000247839334461,
#    'price': 4.04605,
#    'updated': True,
#    'vol_24h': 4342.23},
#   {'currency': 'Change',
#    'pair': 'CAG/BTC',
#    'perc_volume': 0.000247176676179,
#    'price': 0.235833,
#    'updated': True,
#    'vol_24h': 4330.62},
#   {'currency': 'Maker',
#    'pair': 'MKR/BTC',
#    'perc_volume': 0.000242934749948,
#    'price': 1027.25,
#    'updated': True,
#    'vol_24h': 4256.3},
#   {'currency': 'Dent',
#    'pair': 'DENT/ETH',
#    'perc_volume': 0.000239477054966,
#    'price': 0.0294363,
#    'updated': True,
#    'vol_24h': 4195.72},
#   {'currency': 'SunContract',
#    'pair': 'SNC/ETH',
#    'perc_volume': 0.000238049571448,
#    'price': 0.198436,
#    'updated': True,
#    'vol_24h': 4170.71},
#   {'currency': 'Bread',
#    'pair': 'BRD/BTC',
#    'perc_volume': 0.000237344676549,
#    'price': 0.786791,
#    'updated': True,
#    'vol_24h': 4158.36},
#   {'currency': 'Nuls',
#    'pair': 'NULS/ETH',
#    'perc_volume': 0.000219003140027,
#    'price': 2.82148,
#    'updated': True,
#    'vol_24h': 3837.01},
#   {'currency': 'SALT',
#    'pair': 'SALT/USDT',
#    'perc_volume': 0.00021577203879,
#    'price': 4.17394,
#    'updated': True,
#    'vol_24h': 3780.4},
#   {'currency': 'Dash',
#    'pair': 'DASH/BCH',
#    'perc_volume': 0.00021531999283,
#    'price': 633.738,
#    'updated': True,
#    'vol_24h': 3772.48},
#   {'currency': 'Civic',
#    'pair': 'CVC/BTC',
#    'perc_volume': 0.000210927955378,
#    'price': 0.3655,
#    'updated': True,
#    'vol_24h': 3695.53},
#   {'currency': 'FunFair',
#    'pair': 'FUN/USDT',
#    'perc_volume': 0.000186735505806,
#    'price': 0.051811,
#    'updated': True,
#    'vol_24h': 3271.67},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/BTC',
#    'perc_volume': 0.000185754931362,
#    'price': 0.470031,
#    'updated': True,
#    'vol_24h': 3254.49},
#   {'currency': 'CyberMiles',
#    'pair': 'CMT/BCH',
#    'perc_volume': 0.000183844580569,
#    'price': 0.151485,
#    'updated': True,
#    'vol_24h': 3221.02},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/BTC',
#    'perc_volume': 0.000181510722071,
#    'price': 0.235016,
#    'updated': True,
#    'vol_24h': 3180.13},
#   {'currency': 'Monetha',
#    'pair': 'MTH/USDT',
#    'perc_volume': 0.000181400564407,
#    'price': 0.151124,
#    'updated': True,
#    'vol_24h': 3178.2},
#   {'currency': 'SunContract',
#    'pair': 'SNC/USDT',
#    'perc_volume': 0.000180810964057,
#    'price': 0.202333,
#    'updated': True,
#    'vol_24h': 3167.87},
#   {'currency': 'Bitcoin Diamond',
#    'pair': 'BCD/BCH',
#    'perc_volume': 0.000178941708352,
#    'price': 5.87765,
#    'updated': True,
#    'vol_24h': 3135.12},
#   {'currency': 'Gas',
#    'pair': 'GAS/ETH',
#    'perc_volume': 0.000176753394954,
#    'price': 43.7283,
#    'updated': True,
#    'vol_24h': 3096.78},
#   {'currency': 'Ace',
#    'pair': 'ACE/ETH',
#    'perc_volume': 0.000175568486605,
#    'price': 0.29438,
#    'updated': True,
#    'vol_24h': 3076.02},
#   {'currency': 'Centra',
#    'pair': 'CTR/USDT',
#    'perc_volume': 0.000171289460642,
#    'price': 0.718539,
#    'updated': True,
#    'vol_24h': 3001.05},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/BTC',
#    'perc_volume': 0.000168965305151,
#    'price': 0.563833,
#    'updated': True,
#    'vol_24h': 2960.33},
#   {'currency': 'Monetha',
#    'pair': 'MTH/BTC',
#    'perc_volume': 0.000162315320959,
#    'price': 0.150614,
#    'updated': True,
#    'vol_24h': 2843.82},
#   {'currency': 'DigiByte',
#    'pair': 'DGB/ETH',
#    'perc_volume': 0.000161174361522,
#    'price': 0.0356315,
#    'updated': True,
#    'vol_24h': 2823.83},
#   {'currency': 'Moeda Loyalty Points',
#    'pair': 'MDA/ETH',
#    'perc_volume': 0.000157085400338,
#    'price': 1.35895,
#    'updated': True,
#    'vol_24h': 2752.19},
#   {'currency': 'UTRUST',
#    'pair': 'UTK/ETH',
#    'perc_volume': 0.00014842518146,
#    'price': 0.227252,
#    'updated': True,
#    'vol_24h': 2600.46},
#   {'currency': 'ZenCash',
#    'pair': 'ZEN/ETH',
#    'perc_volume': 0.000148281348655,
#    'price': 36.0943,
#    'updated': True,
#    'vol_24h': 2597.94},
#   {'currency': '0x',
#    'pair': 'ZRX/ETH',
#    'perc_volume': 0.000140406502556,
#    'price': 1.014,
#    'updated': True,
#    'vol_24h': 2459.97},
#   {'currency': 'district0x',
#    'pair': 'DNT/BTC',
#    'perc_volume': 0.000139680489348,
#    'price': 0.0809271,
#    'updated': True,
#    'vol_24h': 2447.25},
#   {'currency': 'Viberate',
#    'pair': 'VIB/ETH',
#    'perc_volume': 0.000138220472219,
#    'price': 0.226296,
#    'updated': True,
#    'vol_24h': 2421.67},
#   {'currency': 'Waltonchain',
#    'pair': 'WTC/ETH',
#    'perc_volume': 0.00013268747533,
#    'price': 21.2548,
#    'updated': True,
#    'vol_24h': 2324.73},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/BTC',
#    'perc_volume': 0.000127268631461,
#    'price': 2.13813,
#    'updated': True,
#    'vol_24h': 2229.79},
#   {'currency': 'Populous',
#    'pair': 'PPT/USDT',
#    'perc_volume': 0.000125699027433,
#    'price': 21.9457,
#    'updated': True,
#    'vol_24h': 2202.29},
#   {'currency': 'Po.et',
#    'pair': 'POE/ETH',
#    'perc_volume': 0.000123814361069,
#    'price': 0.0615611,
#    'updated': True,
#    'vol_24h': 2169.27},
#   {'currency': 'Unikoin Gold',
#    'pair': 'UKG/ETH',
#    'perc_volume': 0.000123146565901,
#    'price': 0.348522,
#    'updated': True,
#    'vol_24h': 2157.57},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/BTC',
#    'perc_volume': 0.000122123184075,
#    'price': 2.69369,
#    'updated': True,
#    'vol_24h': 2139.64},
#   {'currency': 'Achain',
#    'pair': 'ACT/BCH',
#    'perc_volume': 0.000121401736987,
#    'price': 0.376884,
#    'updated': True,
#    'vol_24h': 2127.0},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/USDT',
#    'perc_volume': 0.000118059336556,
#    'price': 0.481531,
#    'updated': True,
#    'vol_24h': 2068.44},
#   {'currency': 'Ripio Credit Network',
#    'pair': 'RCN/ETH',
#    'perc_volume': 0.00011480711701,
#    'price': 0.146992,
#    'updated': True,
#    'vol_24h': 2011.46},
#   {'currency': 'TokenClub',
#    'pair': 'TCT/ETH',
#    'perc_volume': 0.000114304272956,
#    'price': 0.027575,
#    'updated': True,
#    'vol_24h': 2002.65},
#   {'currency': 'Maggie',
#    'pair': 'MAG/ETH',
#    'perc_volume': 0.000113740927801,
#    'price': 0.0264289,
#    'updated': True,
#    'vol_24h': 1992.78},
#   {'currency': 'Monaco',
#    'pair': 'MCO/USDT',
#    'perc_volume': 0.000110587450618,
#    'price': 7.21786,
#    'updated': True,
#    'vol_24h': 1937.53},
#   {'currency': 'YOYOW',
#    'pair': 'YOYO/ETH',
#    'perc_volume': 0.000110174216685,
#    'price': 0.12756,
#    'updated': True,
#    'vol_24h': 1930.29},
#   {'currency': 'United Bitcoin',
#    'pair': 'UBTC/ETH',
#    'perc_volume': 0.000108497879583,
#    'price': 33.2462,
#    'updated': True,
#    'vol_24h': 1900.92},
#   {'currency': 'Populous',
#    'pair': 'PPT/ETH',
#    'perc_volume': 9.97959948533e-05,
#    'price': 21.2855,
#    'updated': True,
#    'vol_24h': 1748.46},
#   {'currency': 'NAGA',
#    'pair': 'NGC/USDT',
#    'perc_volume': 9.87503531882e-05,
#    'price': 0.979297,
#    'updated': True,
#    'vol_24h': 1730.14},
#   {'currency': 'SONM',
#    'pair': 'SNM/BTC',
#    'perc_volume': 9.53149180451e-05,
#    'price': 0.218054,
#    'updated': True,
#    'vol_24h': 1669.95},
#   {'currency': 'ETHLend',
#    'pair': 'LEND/ETH',
#    'perc_volume': 9.0941145076e-05,
#    'price': 0.0972879,
#    'updated': True,
#    'vol_24h': 1593.32},
#   {'currency': 'Leverj',
#    'pair': 'LEV/ETH',
#    'perc_volume': 8.83772682422e-05,
#    'price': 0.102441,
#    'updated': True,
#    'vol_24h': 1548.4},
#   {'currency': 'SALT',
#    'pair': 'SALT/BTC',
#    'perc_volume': 8.6273998845e-05,
#    'price': 4.17122,
#    'updated': True,
#    'vol_24h': 1511.55},
#   {'currency': 'Change',
#    'pair': 'CAG/USDT',
#    'perc_volume': 8.13597113252e-05,
#    'price': 0.251138,
#    'updated': True,
#    'vol_24h': 1425.45},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/USDT',
#    'perc_volume': 8.05811877274e-05,
#    'price': 2.17917,
#    'updated': True,
#    'vol_24h': 1411.81},
#   {'currency': 'AirSwap',
#    'pair': 'AST/ETH',
#    'perc_volume': 7.59973732011e-05,
#    'price': 0.458098,
#    'updated': True,
#    'vol_24h': 1331.5},
#   {'currency': 'Qvolta',
#    'pair': 'QVT/ETH',
#    'perc_volume': 7.56868769861e-05,
#    'price': 0.555067,
#    'updated': True,
#    'vol_24h': 1326.06},
#   {'currency': 'AirSwap',
#    'pair': 'AST/USDT',
#    'perc_volume': 6.72601010346e-05,
#    'price': 0.463493,
#    'updated': True,
#    'vol_24h': 1178.42},
#   {'currency': 'Everex',
#    'pair': 'EVX/ETH',
#    'perc_volume': 6.04834069902e-05,
#    'price': 2.40456,
#    'updated': True,
#    'vol_24h': 1059.69},
#   {'currency': 'FunFair',
#    'pair': 'FUN/ETH',
#    'perc_volume': 5.86409772441e-05,
#    'price': 0.0521856,
#    'updated': True,
#    'vol_24h': 1027.41},
#   {'currency': 'Super Bitcoin',
#    'pair': 'SBTC/BCH',
#    'perc_volume': 5.7386435552e-05,
#    'price': 19.5384,
#    'updated': True,
#    'vol_24h': 1005.43},
#   {'currency': 'Civic',
#    'pair': 'CVC/ETH',
#    'perc_volume': 5.69208053826e-05,
#    'price': 0.360758,
#    'updated': True,
#    'vol_24h': 997.272},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/ETH',
#    'perc_volume': 5.39803948117e-05,
#    'price': 0.229226,
#    'updated': True,
#    'vol_24h': 945.755},
#   {'currency': 'Primas',
#    'pair': 'PST/ETH',
#    'perc_volume': 5.37951244599e-05,
#    'price': 0.30765,
#    'updated': True,
#    'vol_24h': 942.509},
#   {'currency': 'ATLANT',
#    'pair': 'ATL/ETH',
#    'perc_volume': 5.25954903706e-05,
#    'price': 0.467947,
#    'updated': True,
#    'vol_24h': 921.491},
#   {'currency': 'district0x',
#    'pair': 'DNT/USDT',
#    'perc_volume': 4.41002796835e-05,
#    'price': 0.0801717,
#    'updated': True,
#    'vol_24h': 772.652},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/ETH',
#    'perc_volume': 4.37030842497e-05,
#    'price': 2.63102,
#    'updated': True,
#    'vol_24h': 765.693},
#   {'currency': 'Read',
#    'pair': 'READ/ETH',
#    'perc_volume': 3.8046745022e-05,
#    'price': 0.0361404,
#    'updated': True,
#    'vol_24h': 666.592},
#   {'currency': 'Santiment Network Token',
#    'pair': 'SAN/ETH',
#    'perc_volume': 3.63196098263e-05,
#    'price': 2.15175,
#    'updated': True,
#    'vol_24h': 636.332},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/USDT',
#    'perc_volume': 3.18410443847e-05,
#    'price': 2.61109,
#    'updated': True,
#    'vol_24h': 557.866},
#   {'currency': 'Bread',
#    'pair': 'BRD/ETH',
#    'perc_volume': 3.0368470424e-05,
#    'price': 0.801863,
#    'updated': True,
#    'vol_24h': 532.066},
#   {'currency': 'Monetha',
#    'pair': 'MTH/ETH',
#    'perc_volume': 3.00869119997e-05,
#    'price': 0.146251,
#    'updated': True,
#    'vol_24h': 527.133},
#   {'currency': 'Bread',
#    'pair': 'BRD/USDT',
#    'perc_volume': 2.40659680255e-05,
#    'price': 0.770049,
#    'updated': True,
#    'vol_24h': 421.644},
#   {'currency': 'Storj',
#    'pair': 'STORJ/ETH',
#    'perc_volume': 2.38776726187e-05,
#    'price': 0.900995,
#    'updated': True,
#    'vol_24h': 418.345},
#   {'currency': 'Enigma',
#    'pair': 'ENG/ETH',
#    'perc_volume': 2.28834568892e-05,
#    'price': 2.54015,
#    'updated': True,
#    'vol_24h': 400.926},
#   {'currency': 'Change',
#    'pair': 'CAG/ETH',
#    'perc_volume': 2.15554006522e-05,
#    'price': 0.248313,
#    'updated': True,
#    'vol_24h': 377.658},
#   {'currency': 'TenX',
#    'pair': 'PAY/ETH',
#    'perc_volume': 2.0952615629e-05,
#    'price': 1.61433,
#    'updated': True,
#    'vol_24h': 367.097},
#   {'currency': 'Monaco',
#    'pair': 'MCO/ETH',
#    'perc_volume': 2.01866488634e-05,
#    'price': 7.09406,
#    'updated': True,
#    'vol_24h': 353.677},
#   {'currency': 'Centra',
#    'pair': 'CTR/ETH',
#    'perc_volume': 2.01003491801e-05,
#    'price': 0.713942,
#    'updated': True,
#    'vol_24h': 352.165},
#   {'currency': 'Bitcoin Gold',
#    'pair': 'BTG/BCH',
#    'perc_volume': 1.65985911323e-05,
#    'price': 114.565,
#    'updated': True,
#    'vol_24h': 290.813},
#   {'currency': 'SALT',
#    'pair': 'SALT/ETH',
#    'perc_volume': 1.38719320917e-05,
#    'price': 4.15449,
#    'updated': True,
#    'vol_24h': 243.041},
#   {'currency': 'Ark',
#    'pair': 'ARK/USDT',
#    'perc_volume': 1.06967658348e-05,
#    'price': 3.90476,
#    'updated': True,
#    'vol_24h': 187.411},
#   {'currency': 'SONM',
#    'pair': 'SNM/USDT',
#    'perc_volume': 8.0827758251e-06,
#    'price': 0.218969,
#    'updated': True,
#    'vol_24h': 141.613},
#   {'currency': 'EncrypGen',
#    'pair': 'DNA/USDT',
#    'perc_volume': 7.11955264062e-06,
#    'price': 0.253543,
#    'updated': True,
#    'vol_24h': 124.737},
#   {'currency': 'SONM',
#    'pair': 'SNM/ETH',
#    'perc_volume': 6.25438690049e-06,
#    'price': 0.218799,
#    'updated': True,
#    'vol_24h': 109.579},
#   {'currency': 'Ark',
#    'pair': 'ARK/ETH',
#    'perc_volume': 5.27156935008e-06,
#    'price': 3.84832,
#    'updated': True,
#    'vol_24h': 92.3597},
#   {'currency': 'district0x',
#    'pair': 'DNT/ETH',
#    'perc_volume': 5.06058032284e-06,
#    'price': 0.0797347,
#    'updated': True,
#    'vol_24h': 88.6631},
#   {'currency': 'Eidoo',
#    'pair': 'EDO/BCH',
#    'perc_volume': 4.03830007335e-06,
#    'price': 2.66613,
#    'updated': True,
#    'vol_24h': 70.7524},
#   {'currency': 'Aventus',
#    'pair': 'AVT/BCH',
#    'perc_volume': 0.0,
#    'price': 2.09301,
#    'updated': True,
#    'vol_24h': None}],
#  'name': 'OKEx ',
#  'slug': 'okex',
#  'social': {'twitter': {'link': 'https://twitter.com/CoinMarketCap',
#    'username': '@OKEx_'}},
#  'volume': 1752034240.02,
#  'website': 'https://www.okex.com'}

# %%
show_page("exchanges/okex")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/exchanges/okex"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# In order to obtain all available values for the `name` parameter, use:

# %%
cmc.exchange_slugs
# Out:
# ['bitmex',
#  'binance',
#  'okex',
#  'upbit',
#  'bitfinex',
#  'bithumb',
#  'huobi',
#  'gdax',
#  'kraken',
#  'bittrex',
#  'hitbtc',
#  'bitstamp',
#  'bitflyer',
#  'bit-z',
#  'zaif',
#  'fisco',
#  'btcbox',
#  'poloniex',
#  'coinone',
#  'quoine',
#  'coinegg',
#  'exx',
#  'btcc',
#  'bits-blockchain',
#  'wex',
#  'coinsbank',
#  'bibox',
#  'gemini',
#  'kucoin',
#  'zb-com',
#  'bitbank',
#  'korbit',
#  'gopax',
#  'gate-io',
#  'exmo',
#  'coinbene',
#  'livecoin',
#  'yobit',
#  'simex',
#  'aex',
#  'itbit',
#  'cex-io',
#  'liqui',
#  'ethfinex',
#  'xbtce',
#  'tidex',
#  'lbank',
#  'cryptopia',
#  'bitbay',
#  'getbtc',
#  'coinnest',
#  'btctrade-im',
#  'bitcoin-indonesia',
#  'lakebtc',
#  'btc-markets',
#  'paribu',
#  'exrates',
#  'bitinka',
#  'rightbtc',
#  'c2cx',
#  'bx-thailand',
#  'qryptos',
#  'topbtc',
#  'neraexpro',
#  'btcturk',
#  'fatbtc',
#  'idex',
#  'bigone',
#  'quadrigacx',
#  'vebitcoin',
#  'luno',
#  'allcoin',
#  'coinexchange',
#  'coinrail',
#  'koinex',
#  'negocie-coins',
#  'coinfloor',
#  'coinsquare',
#  'coinroom',
#  'bitso',
#  'btc-alpha',
#  'zebpay',
#  'coinex',
#  'therocktrading',
#  'bancor-network',
#  'mercado-bitcoin',
#  'koineks',
#  'foxbit',
#  'oex',
#  'dsx',
#  'bitmarket',
#  'independent-reserve',
#  'bitonic',
#  'coinut',
#  'bl3p',
#  'chaoex',
#  'trade-by-trade',
#  'koinim',
#  'bleutrade',
#  'cobinhood',
#  'qbtc',
#  'mercatox',
#  'okcoin-intl',
#  'litebit',
#  'cryptobridge',
#  'gatehub',
#  'coss',
#  'acx',
#  'tidebit',
#  'altcoin-trader',
#  'forkdelta',
#  'fargobase',
#  'abucoins',
#  'bitcointrade',
#  'stellar-decentralized-exchange',
#  'waves-dex',
#  'trade-satoshi',
#  'stocks-exchange',
#  'tdax',
#  'bitcointoyou',
#  'coinfalcon',
#  'ripple-china',
#  'coinmate',
#  'c-cex',
#  'kuna',
#  'ripplefox',
#  'lykke-exchange',
#  'idax',
#  'bitflip',
#  'bitstamp-ripple-gateway',
#  'gatecoin',
#  'iquant',
#  'surbtc',
#  'oasisdex',
#  'btc-trade-ua',
#  'southxchange',
#  'triple-dice-exchange',
#  'openledger',
#  'mr-exchange',
#  'coinrate',
#  'bitex-la',
#  'bittylicious',
#  'bit2c',
#  'braziliex',
#  'infinitycoin-exchange',
#  'token-store',
#  'bitsane',
#  'ddex',
#  'coinsecure',
#  'ezbtc',
#  'nocks',
#  'rfinex',
#  'radar-relay',
#  'paymium',
#  'tradeogre',
#  'cryptox',
#  'coinlink',
#  'coinhouse',
#  'bitlish',
#  'bitmaszyna',
#  'cryptomarket',
#  'cryptomate',
#  'tcc-exchange',
#  'tux-exchange',
#  'alcurex',
#  'ethexindia',
#  'okcoin-cn',
#  'counterparty-dex',
#  'bisq',
#  'stronghold',
#  'barterdex',
#  'ore-bz',
#  'bcex',
#  'coingi',
#  'dgtmarket',
#  'bitkonan',
#  'rippex',
#  'coinbe',
#  'c-patex',
#  'heat-wallet',
#  'freiexchange',
#  'guldentrader',
#  'localtrade',
#  'cryptoderivatives',
#  'leoxchange',
#  'dc-ex',
#  'isx',
#  'excambriorex',
#  'nix-e',
#  'coincorner',
#  'burst-asset-exchange',
#  'omni-dex',
#  'virtacoinworld']

# %% [markdown]
# If you want to get all formatted exchange names:

# %%
cmc.exchange_names
# Out:
# ['BitMEX',
#  'Binance',
#  'OKEx',
#  'Upbit',
#  'Bitfinex',
#  'Bithumb',
#  'Huobi',
#  'GDAX',
#  'Kraken',
#  'Bittrex',
#  'HitBTC',
#  'Bitstamp',
#  'bitFlyer',
#  'Bit-Z',
#  'Zaif',
#  'Fisco',
#  'BTCBOX',
#  'Poloniex',
#  'Coinone',
#  'Quoine',
#  'CoinEgg',
#  'EXX',
#  'BTCC',
#  'Bits Blockchain',
#  'WEX',
#  'CoinsBank',
#  'Bibox',
#  'Gemini',
#  'Kucoin',
#  'ZB.COM',
#  'Bitbank',
#  'Korbit',
#  'GOPAX',
#  'Gate.io',
#  'Exmo',
#  'Coinbene',
#  'Livecoin',
#  'YoBit',
#  'Simex',
#  'AEX',
#  'itBit',
#  'CEX.IO',
#  'Liqui',
#  'Ethfinex',
#  'xBTCe',
#  'Tidex',
#  'Lbank',
#  'Cryptopia',
#  'BitBay',
#  'GetBTC',
#  'Coinnest',
#  'BtcTrade.im',
#  'Bitcoin Indonesia',
#  'LakeBTC',
#  'BTC Markets',
#  'Paribu',
#  'Exrates',
#  'Bitinka',
#  'RightBTC',
#  'C2CX',
#  'BX Thailand',
#  'Qryptos',
#  'TOPBTC',
#  'Neraex',
#  'BTCTurk',
#  'Fatbtc',
#  'IDEX',
#  'BigONE',
#  'QuadrigaCX',
#  'Vebitcoin',
#  'Luno',
#  'Allcoin',
#  'CoinExchange',
#  'Coinrail',
#  'Koinex',
#  'Negocie Coins',
#  'Coinfloor',
#  'Coinsquare',
#  'Coinroom',
#  'Bitso',
#  'BTC-Alpha',
#  'Zebpay',
#  'CoinEx',
#  'The Rock Trading',
#  'Bancor Network',
#  'Mercado Bitcoin',
#  'Koineks',
#  'Foxbit',
#  'OEX',
#  'DSX',
#  'BitMarket',
#  'Independent Reserve',
#  'Bitonic',
#  'Coinut',
#  'BL3P',
#  'ChaoEX',
#  'Trade By Trade',
#  'Koinim',
#  'Bleutrade',
#  'Cobinhood',
#  'QBTC',
#  'Mercatox',
#  'OkCoin Intl.',
#  'LiteBit.eu',
#  'CryptoBridge',
#  'Gatehub',
#  'COSS',
#  'ACX',
#  'Tidebit',
#  'Altcoin Trader',
#  'ForkDelta',
#  'Fargobase',
#  'Abucoins',
#  'BitcoinTrade',
#  'Stellar Decentralized Exchange',
#  'Waves Decentralized Exchange',
#  'Trade Satoshi',
#  'Stocks.Exchange',
#  'TDAX',
#  'BitcoinToYou',
#  'CoinFalcon',
#  'Ripple China',
#  'CoinMate',
#  'C-CEX',
#  'Kuna',
#  'RippleFox',
#  'Lykke Exchange',
#  'IDAX',
#  'BitFlip',
#  'Bitstamp (Ripple Gateway)',
#  'Gatecoin',
#  'Iquant',
#  'SurBTC',
#  'OasisDEX',
#  'BTC Trade UA',
#  'SouthXchange',
#  'Tripe Dice Exchange',
#  'OpenLedger DEX',
#  'Mr. Exchange',
#  'Coinrate',
#  'Bitex.la',
#  'Bittylicious',
#  'Bit2C',
#  'Braziliex',
#  'InfinityCoin Exchange',
#  'Token Store',
#  'Bitsane',
#  'DDEX',
#  'Coinsecure',
#  'ezBtc',
#  'Nocks',
#  'Rfinex',
#  'Radar Relay',
#  'Paymium',
#  'TradeOgre',
#  'Cryptox',
#  'Coinlink',
#  'Coinhouse',
#  'Bitlish',
#  'Bitmaszyna',
#  'CryptoMarket',
#  'Cryptomate',
#  'TCC Exchange',
#  'Tux Exchange',
#  'alcurEX',
#  'ETHEXIndia',
#  'OKCoin.cn',
#  'Counterparty DEX',
#  'Bisq',
#  'Stronghold',
#  'BarterDEX',
#  'Ore.Bz',
#  'BCEX',
#  'Coingi',
#  'Dgtmarket',
#  'BitKonan',
#  'Rippex',
#  'Coinbe',
#  'C-Patex',
#  'Heat Wallet',
#  'FreiExchange',
#  'GuldenTrader',
#  'LocalTrade',
#  'CryptoDerivatives',
#  'LEOxChange',
#  'DC-Ex',
#  'ISX',
#  'ExcambrioRex',
#  'NIX-E',
#  'CoinCorner',
#  'Burst Asset Exchange',
#  'Omni DEX',
#  'VirtacoinWorld']

# %% [markdown]
# #### `exchanges([convert="USD"])`
# Get all available exchanges in coinmarketcap ranked by volumes with some metadata:

# %%
cmc.exchanges()
# Out:
# [{'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BitMEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Nano',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Nucleus Vision',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'VeChain',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'NEO',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'BlockMason Credit Protocol',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Binance'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'EOS',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'OKEx'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Cardano',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'NEO',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Qtum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ripple',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Status',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Upbit'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'EOS',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'NEO',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bitfinex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Qtum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'EOS',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Monero',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Bitcoin Gold',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bithumb'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Huobi Token',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Huobi Token',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Elastos',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Huobi Token',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'TRON',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Elastos',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'TRON',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Huobi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'GDAX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ripple',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Kraken'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'ZClassic',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Cardano',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'NEO',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'BlockMason Credit Protocol',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'ReddCoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Bean Cash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bittrex'},
#  {'markets': [{'name': 'Bitcoin Cash',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'W3Coin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Dash',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Zcash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'HitBTC'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bitstamp'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'}],
#   'name': 'bitFlyer'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'EDUCare',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'TRON',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Ink',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Ink',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Hshare',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Lisk',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bit-Z'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEM',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'COMSA [ETH]',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'NEM',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'COMSA [XEM]',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Counterparty',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Pepe Cash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Zaif'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'MonaCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'}],
#   'name': 'Fisco'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'BTCBOX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Ripple',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Monero',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Poloniex'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Qtum',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'IOTA',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'}],
#   'name': 'Coinone'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'QASH',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'QASH',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Quoine'},
#  {'markets': [{'name': 'Ethereum',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'NEO',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'TRON',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Lisk',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Qtum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ruff',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Qbao',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Ripple',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Achain',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'CoinEgg'},
#  {'markets': [{'name': 'Hyper Pay',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ink',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Qtum',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bodhi',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'EXX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum Classic',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'}],
#   'name': 'BTCC'},
#  {'markets': [{'name': 'ATMCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'ATMCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ripple',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Dogecoin',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'ATMCoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'ATMCoin',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bits Blockchain'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Dash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Zcash',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Dash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'WEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'CoinsBank'},
#  {'markets': [{'name': 'Bibox Token',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bibox Token',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Bibox Token',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Jibrel Network',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Jibrel Network',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Spectre.ai Utility Token',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Spectre.ai Utility Token',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Gifto',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Gifto',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'High Performance Blockchain',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Bibox'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ethereum',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'}],
#   'name': 'Gemini'},
#  {'markets': [{'name': 'Zeepin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Revain',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Nano',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Ethereum',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Revain',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'NEO',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Dent',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'VeChain',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'SingularityNET',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Kucoin'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'EOS',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'True Chain',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'BitShares',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'EOS',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'QunQun',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Qtum',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'ZB.COM'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'MonaCoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
# ...
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Nebulas',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Ethereum Classic',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Qtum',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Zcash',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'BCEX'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Vertcoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Peercoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Dogecoin',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Dash',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'}],
#   'name': 'Coingi'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Litecoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'}],
#   'name': 'Dgtmarket'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'BitKonan'},
#  {'markets': [{'name': 'Ripple',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Rippex'},
#  {'markets': [{'name': 'NEM',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Ripple',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Ethereum',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'PIVX',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Waves',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Bitcoin Cash',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Dash',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Monero',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'Coinbe'},
#  {'markets': [{'name': 'Photon',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Litecoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Blakecoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Photon',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'}],
#   'name': 'C-Patex'},
#  {'markets': [{'name': 'HEAT',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bismuth',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Golem',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'FIMKrypto',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Elastic',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Elastic',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'HEAT',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'Heat Wallet'},
#  {'markets': [{'name': 'Anoncoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'WhiteCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Datacoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Freicoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'}],
#   'name': 'FreiExchange'},
#  {'markets': [{'name': 'Gulden',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'GuldenTrader'},
#  {'markets': [{'name': 'E-Dinar Coin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'E-Dinar Coin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'}],
#   'name': 'LocalTrade'},
#  {'markets': [{'name': 'Ethereum Movie Venture',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Golem',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Lunyr',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'SingularDTV',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'TokenCard',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Swarm City',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Etheroll',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'},
#    {'name': 'Melon',
#     'pair': 'ETH/USDT',
#     'perc_volume': 3.17,
#     'price': 864.622,
#     'volume': 63938100.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_USDT'},
#    {'name': 'Numeraire',
#     'pair': 'LTC/BTC',
#     'perc_volume': 3.13,
#     'price': 215.898,
#     'volume': 63052300.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_BTC'},
#    {'name': 'Edgeless',
#     'pair': 'NEO/BTC',
#     'perc_volume': 2.94,
#     'price': 132.499,
#     'volume': 59350700.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NEO_BTC'}],
#   'name': 'CryptoDerivatives'},
#  {'markets': [{'name': 'LEOcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'LEOcoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'LEOcoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'},
#    {'name': 'LEOcoin',
#     'pair': 'LTC/USDT',
#     'perc_volume': 5.05,
#     'price': 217.135,
#     'volume': 101800000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=LTC_USDT'},
#    {'name': 'Bitcoin',
#     'pair': 'ETH/BTC',
#     'perc_volume': 5.03,
#     'price': 863.512,
#     'volume': 101311000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=ETH_BTC'},
#    {'name': 'Bitcoin',
#     'pair': 'VEN/BTC',
#     'perc_volume': 4.58,
#     'price': 5.56801,
#     'volume': 92312400.0,
#     'web': 'https://www.binance.com/trade.html?symbol=VEN_BTC'}],
#   'name': 'LEOxChange'},
#  {'markets': [{'name': 'YashCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'SACoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'DC-Ex'},
#  {'markets': [{'name': 'Auroracoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ISX'},
#  {'markets': [{'name': 'Centurion',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'ExcambrioRex'},
#  {'markets': [{'name': 'CRTCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'GBCGoldCoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'},
#    {'name': 'Dogecoin',
#     'pair': 'NANO/BTC',
#     'perc_volume': 6.65,
#     'price': 14.2352,
#     'volume': 134108000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NANO_BTC'},
#    {'name': 'Litecoin',
#     'pair': 'NCASH/BTC',
#     'perc_volume': 5.69,
#     'price': 0.0394938,
#     'volume': 114662000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=NCASH_BTC'}],
#   'name': 'NIX-E'},
#  {'markets': [{'name': 'Bitcoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Bitcoin',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'CoinCorner'},
#  {'markets': [{'name': 'SnakeEyes',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'CCMiner',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'Burst Asset Exchange'},
#  {'markets': [{'name': 'MaidSafeCoin',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'}],
#   'name': 'Omni DEX'},
#  {'markets': [{'name': 'Virtacoinplus',
#     'pair': 'BTC/USD',
#     'perc_volume': 100.0,
#     'price': 10229.5,
#     'volume': 2661040000.0,
#     'web': 'https://www.bitmex.com/'},
#    {'name': 'Virtacoinplus',
#     'pair': 'BTC/USDT',
#     'perc_volume': 16.85,
#     'price': 10239.6,
#     'volume': 339572000.0,
#     'web': 'https://www.binance.com/trade.html?symbol=BTC_USDT'}],
#   'name': 'VirtacoinWorld'}]

# %%
show_page("exchanges/volume/24-hour")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/exchanges/volume/24-hour"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `tokens([convert="USD"])`
# Get platforms tokens data:

# %%
cmc.tokens()
# Out:
# [{'circulating_supply': 694415424.122,
#   'market_cap': 5725969039.3,
#   'name': 'EOS',
#   'platform': 'Ethereum',
#   'price': 8.24574,
#   'symbol': 'EOS',
#   'volume_24h': 252711000.0},
#  {'circulating_supply': 65748192475.5,
#   'market_cap': 2761897470.96,
#   'name': 'TRON',
#   'platform': 'Ethereum',
#   'price': 0.0420072,
#   'symbol': 'TRX',
#   'volume_24h': 187808000.0},
#  {'circulating_supply': 475347275.127,
#   'market_cap': 2638747793.69,
#   'name': 'VeChain',
#   'platform': 'Ethereum',
#   'price': 5.5512,
#   'symbol': 'VEN',
#   'volume_24h': 137493000.0},
#  {'circulating_supply': 2217140813.52,
#   'market_cap': 2210766533.68,
#   'name': 'Tether',
#   'platform': 'Omni',
#   'price': 0.997125,
#   'symbol': 'USDT',
#   'volume_24h': 2369730000.0},
#  {'circulating_supply': 102042551.763,
#   'market_cap': 1824377965.95,
#   'name': 'OmiseGO',
#   'platform': 'Ethereum',
#   'price': 17.8786,
#   'symbol': 'OMG',
#   'volume_24h': 36198400.0},
#  {'circulating_supply': 386442514.0,
#   'market_cap': 1571136142.62,
#   'name': 'ICON',
#   'platform': 'Ethereum',
#   'price': 4.06564,
#   'symbol': 'ICX',
#   'volume_24h': 59128800.0},
#  {'circulating_supply': 99014000.0,
#   'market_cap': 974651239.98,
#   'name': 'Binance Coin',
#   'platform': 'Ethereum',
#   'price': 9.84357,
#   'symbol': 'BNB',
#   'volume_24h': 57190800.0},
#  {'circulating_supply': 2000000.0,
#   'market_cap': 830462000.0,
#   'name': 'DigixDAO',
#   'platform': 'Ethereum',
#   'price': 415.231,
#   'symbol': 'DGD',
#   'volume_24h': 47814200.0},
#  {'circulating_supply': 37004026.8944,
#   'market_cap': 784344754.859,
#   'name': 'Populous',
#   'platform': 'Ethereum',
#   'price': 21.1962,
#   'symbol': 'PPT',
#   'volume_24h': 3012970.0},
#  {'circulating_supply': 359399272.4,
#   'market_cap': 710377819.848,
#   'name': 'RChain',
#   'platform': 'Ethereum',
#   'price': 1.97657,
#   'symbol': 'RHOC',
#   'volume_24h': 495782.0},
#  {'circulating_supply': 618227.770106,
#   'market_cap': 633615459.304,
#   'name': 'Maker',
#   'platform': 'Ethereum',
#   'price': 1024.89,
#   'symbol': 'MKR',
#   'volume_24h': 616816.0},
#  {'circulating_supply': 3470483788.0,
#   'market_cap': 619241892.777,
#   'name': 'Status',
#   'platform': 'Ethereum',
#   'price': 0.178431,
#   'symbol': 'SNT',
#   'volume_24h': 32715100.0},
#  {'circulating_supply': 24898178.0,
#   'market_cap': 531237485.079,
#   'name': 'Waltonchain',
#   'platform': 'Ethereum',
#   'price': 21.3364,
#   'symbol': 'WTC',
#   'volume_24h': 9351070.0},
#  {'circulating_supply': 513812714.087,
#   'market_cap': 523832062.012,
#   'name': '0x',
#   'platform': 'Ethereum',
#   'price': 1.0195,
#   'symbol': 'ZRX',
#   'volume_24h': 8933900.0},
#  {'circulating_supply': 233020472.114,
#   'market_cap': 517682941.258,
#   'name': 'Aeternity',
#   'platform': 'Ethereum',
#   'price': 2.22162,
#   'symbol': 'AE',
#   'volume_24h': 3118310.0},
#  {'circulating_supply': 11000000.0,
#   'market_cap': 499555100.0,
#   'name': 'Augur',
#   'platform': 'Ethereum',
#   'price': 45.4141,
#   'symbol': 'REP',
#   'volume_24h': 4769910.0},
#  {'circulating_supply': 2036645.44,
#   'market_cap': 499452671.188,
#   'name': 'Veritaseum',
#   'platform': 'Ethereum',
#   'price': 245.233,
#   'symbol': 'VERI',
#   'volume_24h': 241023.0},
#  {'circulating_supply': 91043076.0001,
#   'market_cap': 430928729.047,
#   'name': 'KuCoin Shares',
#   'platform': 'Ethereum',
#   'price': 4.73324,
#   'symbol': 'KCS',
#   'volume_24h': 1157810.0},
#  {'circulating_supply': 184450000.0,
#   'market_cap': 429296308.0,
#   'name': 'Revain',
#   'platform': 'Ethereum',
#   'price': 2.32744,
#   'symbol': 'R',
#   'volume_24h': 18398800.0},
#  {'circulating_supply': 9798624.02278,
#   'market_cap': 425708079.706,
#   'name': 'Gas',
#   'platform': 'NEO',
#   'price': 43.4457,
#   'symbol': 'GAS',
#   'volume_24h': 7688240.0},
#  {'circulating_supply': 1000000000.0,
#   'market_cap': 370742000.0,
#   'name': 'Basic Attenti...',
#   'platform': 'Ethereum',
#   'price': 0.370742,
#   'symbol': 'BAT',
#   'volume_24h': 2630080.0},
#  {'circulating_supply': 6511228178.4,
#   'market_cap': 355863362.617,
#   'name': 'Zilliqa',
#   'platform': 'Ethereum',
#   'price': 0.0546538,
#   'symbol': 'ZIL',
#   'volume_24h': 8032510.0},
#  {'circulating_supply': 561357156.618,
#   'market_cap': 348729099.62,
#   'name': 'Loopring',
#   'platform': 'Ethereum',
#   'price': 0.621225,
#   'symbol': 'LRC',
#   'volume_24h': 1858870.0},
#  {'circulating_supply': 987000000.0,
#   'market_cap': 340066902.0,
#   'name': 'Bytom',
#   'platform': 'Ethereum',
#   'price': 0.344546,
#   'symbol': 'BTM',
#   'volume_24h': 8564460.0},
#  {'circulating_supply': 238421940.0,
#   'market_cap': 334451144.774,
#   'name': 'Dragonchain',
#   'platform': 'Ethereum',
#   'price': 1.40277,
#   'symbol': 'DRGN',
#   'volume_24h': 1532770.0},
#  {'circulating_supply': 834262000.0,
#   'market_cap': 316891917.914,
#   'name': 'Golem',
#   'platform': 'Ethereum',
#   'price': 0.379847,
#   'symbol': 'GNT',
#   'volume_24h': 12146300.0},
#  {'circulating_supply': 10614760961.2,
#   'market_cap': 307781362.926,
#   'name': 'Dent',
#   'platform': 'Ethereum',
#   'price': 0.0289956,
#   'symbol': 'DENT',
#   'volume_24h': 6313110.0},
#  {'circulating_supply': 35500000.0,
#   'market_cap': 300097830.0,
#   'name': 'Nebulas',
#   'platform': 'Ethereum',
#   'price': 8.45346,
#   'symbol': 'NAS',
#   'volume_24h': 7868670.0},
#  {'circulating_supply': 96154302.9319,
#   'market_cap': 299971617.314,
#   'name': 'Aion',
#   'platform': 'Ethereum',
#   'price': 3.11969,
#   'symbol': 'AION',
#   'volume_24h': 4574960.0},
#  {'circulating_supply': 250000000.0,
#   'market_cap': 296845000.0,
#   'name': 'aelf',
#   'platform': 'Ethereum',
#   'price': 1.18738,
#   'symbol': 'ELF',
#   'volume_24h': 13602500.0},
#  {'circulating_supply': 350000000.0,
#   'market_cap': 292065200.0,
#   'name': 'QASH',
#   'platform': 'Ethereum',
#   'price': 0.834472,
#   'symbol': 'QASH',
#   'volume_24h': 2824290.0},
#  {'circulating_supply': 239570250.0,
#   'market_cap': 284020114.185,
#   'name': 'Polymath',
#   'platform': 'Ethereum',
#   'price': 1.18554,
#   'symbol': 'POLY',
#   'volume_24h': 1733320.0},
#  {'circulating_supply': 134132696.93,
#   'market_cap': 268915937.44,
#   'name': 'Kyber Network',
#   'platform': 'Ethereum',
#   'price': 2.00485,
#   'symbol': 'KNC',
#   'volume_24h': 2685930.0},
#  {'circulating_supply': 325226613094.0,
#   'market_cap': 259259598.254,
#   'name': 'Dentacoin',
#   'platform': 'Ethereum',
#   'price': 0.000797166,
#   'symbol': 'DCN',
#   'volume_24h': 205073.0},
#  {'circulating_supply': 75807919.1385,
#   'market_cap': 257399724.801,
#   'name': 'Ethos',
#   'platform': 'Ethereum',
#   'price': 3.39542,
#   'symbol': 'ETHOS',
#   'volume_24h': 1182780.0},
#  {'circulating_supply': 6794109921.69,
#   'market_cap': 240308347.341,
#   'name': 'IOStoken',
#   'platform': 'Ethereum',
#   'price': 0.0353701,
#   'symbol': 'IOST',
#   'volume_24h': 24268000.0},
#  {'circulating_supply': 350000000.0,
#   'market_cap': 236806850.0,
#   'name': 'ChainLink',
#   'platform': 'Ethereum',
#   'price': 0.676591,
#   'symbol': 'LINK',
#   'volume_24h': 4321420.0},
#  {'circulating_supply': 4503688788.66,
#   'market_cap': 234672810.973,
#   'name': 'FunFair',
#   'platform': 'Ethereum',
#   'price': 0.0521068,
#   'symbol': 'FUN',
#   'volume_24h': 1808260.0},
#  {'circulating_supply': 54237689.1871,
#   'market_cap': 226086010.738,
#   'name': 'SALT',
#   'platform': 'Ethereum',
#   'price': 4.16843,
#   'symbol': 'SALT',
#   'volume_24h': 4425560.0},
#  {'circulating_supply': 363932643.92,
#   'market_cap': 218724246.861,
#   'name': 'Power Ledger',
#   'platform': 'Ethereum',
#   'price': 0.601002,
#   'symbol': 'POWR',
#   'volume_24h': 4173050.0},
#  {'circulating_supply': 756097560976.0,
#   'market_cap': 199041170.732,
#   'name': 'Kin',
#   'platform': 'Ethereum',
#   'price': 0.000263248,
#   'symbol': 'KIN',
#   'volume_24h': 513250.0},
#  {'circulating_supply': 1445976590.33,
#   'market_cap': 197670783.804,
#   'name': 'Cindicator',
#   'platform': 'Ethereum',
#   'price': 0.136704,
#   'symbol': 'CND',
#   'volume_24h': 2685420.0},
#  {'circulating_supply': 227384800.0,
#   'market_cap': 195924066.457,
#   'name': 'Pillar',
#   'platform': 'Ethereum',
#   'price': 0.861641,
#   'symbol': 'PLR',
#   'volume_24h': 356855.0},
#  {'circulating_supply': 39181011.7249,
#   'market_cap': 195818860.398,
#   'name': 'Bancor',
#   'platform': 'Ethereum',
#   'price': 4.9978,
#   'symbol': 'BNT',
#   'volume_24h': 5600280.0},
#  {'circulating_supply': 641462768.585,
#   'market_cap': 192629986.48,
#   'name': 'Request Network',
#   'platform': 'Ethereum',
#   'price': 0.300298,
#   'symbol': 'REQ',
#   'volume_24h': 3342620.0},
#  {'circulating_supply': 74836171.09,
#   'market_cap': 189133455.196,
#   'name': 'Enigma',
#   'platform': 'Ethereum',
#   'price': 2.5273,
#   'symbol': 'ENG',
#   'volume_24h': 4926850.0},
#  {'circulating_supply': 460552782.0,
#   'market_cap': 176476917.771,
#   'name': 'SingularityNET',
#   'platform': 'Ethereum',
#   'price': 0.383185,
#   'symbol': 'AGI',
#   'volume_24h': 2431130.0},
#  {'circulating_supply': 104661310.0,
#   'market_cap': 166944208.968,
#   'name': 'TenX',
#   'platform': 'Ethereum',
#   'price': 1.59509,
#   'symbol': 'PAY',
#   'volume_24h': 1812840.0},
#  {'circulating_supply': 452552412.0,
#   'market_cap': 162454096.993,
#   'name': 'MaidSafeCoin',
#   'platform': 'Omni',
#   'price': 0.358973,
#   'symbol': 'MAID',
#   'volume_24h': 2433680.0},
#  {'circulating_supply': 617314170.819,
#   'market_cap': 161869035.301,
#   'name': 'Quantstamp',
#   'platform': 'Ethereum',
#   'price': 0.262215,
#   'symbol': 'QSP',
#   'volume_24h': 2338000.0},
#  {'circulating_supply': 761143950.0,
#   'market_cap': 157412941.443,
#   'name': 'Ignis',
#   'platform': 'Ardor',
#   'price': 0.206811,
#   'symbol': 'IGNIS',
#   'volume_24h': 4030270.0},
#  {'circulating_supply': 492954537.351,
#   'market_cap': 156773345.605,
#   'name': 'WAX',
#   'platform': 'Ethereum',
#   'price': 0.318028,
#   'symbol': 'WAX',
#   'volume_24h': 9977070.0},
#  {'circulating_supply': 50168936.0,
#   'market_cap': 155891439.901,
#   'name': 'Raiden Networ...',
#   'platform': 'Ethereum',
#   'price': 3.10733,
#   'symbol': 'RDN',
#   'volume_24h': 4404320.0},
#  {'circulating_supply': 1104590.0,
#   'market_cap': 146433287.12,
#   'name': 'Gnosis',
#   'platform': 'Ethereum',
#   'price': 132.568,
#   'symbol': 'GNO',
#   'volume_24h': 248704.0},
#  {'circulating_supply': 99735686.8829,
#   'market_cap': 146053937.228,
#   'name': 'Iconomi',
#   'platform': 'Ethereum',
#   'price': 1.46441,
#   'symbol': 'ICN',
#   'volume_24h': 817367.0},
#  {'circulating_supply': 756192535.064,
#   'market_cap': 143873191.721,
#   'name': 'Enjin Coin',
#   'platform': 'Ethereum',
#   'price': 0.19026,
#   'symbol': 'ENJ',
#   'volume_24h': 10584800.0},
#  {'circulating_supply': 2216707776.0,
#   'market_cap': 140776904.072,
#   'name': 'Po.et',
#   'platform': 'Ethereum',
#   'price': 0.0635072,
#   'symbol': 'POE',
#   'volume_24h': 3817580.0},
#  {'circulating_supply': 62660370.957,
#   'market_cap': 134062490.266,
#   'name': 'Santiment Net...',
#   'platform': 'Ethereum',
#   'price': 2.13951,
#   'symbol': 'SAN',
#   'volume_24h': 4614230.0},
#  {'circulating_supply': 1000000000.0,
#   'market_cap': 126983000.0,
#   'name': 'XPA',
#   'platform': 'Ethereum',
#   'price': 0.126983,
#   'symbol': 'XPA',
#   'volume_24h': 48627.5},
#  {'circulating_supply': 133425492.59,
#   'market_cap': 123876630.361,
#   'name': 'Storj',
#   'platform': 'Ethereum',
#   'price': 0.928433,
#   'symbol': 'STORJ',
#   'volume_24h': 3638240.0},
#  {'circulating_supply': 342699966.0,
#   'market_cap': 122953208.402,
#   'name': 'Civic',
#   'platform': 'Ethereum',
#   'price': 0.358778,
#   'symbol': 'CVC',
#   'volume_24h': 2835400.0},
#  {'circulating_supply': 226091448.88,
#   'market_cap': 120554673.64,
#   'name': 'Substratum',
#   'platform': 'Ethereum',
#   'price': 0.533212,
#   'symbol': 'SUB',
#   'volume_24h': 4922790.0},
#  {'circulating_supply': 4084706883.25,
#   'market_cap': 119913106.089,
#   'name': 'Storm',
#   'platform': 'Ethereum',
#   'price': 0.0293566,
#   'symbol': 'STORM',
#   'volume_24h': 830226.0},
#  {'circulating_supply': 79070793.2388,
#   'market_cap': 117953855.814,
#   'name': 'iExec RLC',
#   'platform': 'Ethereum',
#   'price': 1.49175,
#   'symbol': 'RLC',
#   'volume_24h': 10620900.0},
#  {'circulating_supply': 1050141509.43,
#   'market_cap': 116296871.32,
#   'name': 'Decentraland',
#   'platform': 'Ethereum',
#   'price': 0.110744,
#   'symbol': 'MANA',
#   'volume_24h': 6930480.0},
#  {'circulating_supply': 1494971208.89,
#   'market_cap': 110035412.368,
#   'name': 'BLOCKv',
#   'platform': 'Ethereum',
#   'price': 0.0736037,
#   'symbol': 'VEE',
#   'volume_24h': 4722430.0},
#  {'circulating_supply': 1076329355.02,
#   'market_cap': 107511740.817,
#   'name': 'ETHLend',
#   'platform': 'Ethereum',
#   'price': 0.0998874,
#   'symbol': 'LEND',
#   'volume_24h': 3887150.0},
#  {'circulating_supply': 73430701.0,
#   'market_cap': 106263770.338,
#   'name': 'AdEx',
#   'platform': 'Ethereum',
#   'price': 1.44713,
#   'symbol': 'ADX',
#   'volume_24h': 19324100.0},
#  {'circulating_supply': 1186310945.0,
#   'market_cap': 102092970.878,
#   'name': 'Dynamic Tradi...',
#   'platform': 'Ethereum',
#   'price': 0.0860592,
#   'symbol': 'DTR',
#   'volume_24h': 29402.4},
#  {'circulating_supply': 70766926.2205,
#   'market_cap': 100997849.433,
#   'name': 'Oyster',
#   'platform': 'Ethereum',
#   'price': 1.42719,
#   'symbol': 'PRL',
#   'volume_24h': 1164480.0},
#  {'circulating_supply': 26694566.7081,
#   'market_cap': 99380134.615,
#   'name': 'Aragon',
#   'platform': 'Ethereum',
#   'price': 3.72286,
#   'symbol': 'ANT',
#   'volume_24h': 586210.0},
#  {'circulating_supply': 543348500.0,
#   'market_cap': 98565591.294,
#   'name': 'Red Pulse',
#   'platform': 'NEO',
#   'price': 0.181404,
#   'symbol': 'RPX',
#   'volume_24h': 12720100.0},
#  {'circulating_supply': 816060.7785,
#   'market_cap': 98427538.6772,
#   'name': 'SuperNET',
#   'platform': 'Nxt',
#   'price': 120.613,
#   'symbol': 'UNITY',
#   'volume_24h': 10075.3},
#  {'circulating_supply': 26451948985.9,
#   'market_cap': 98404953.5004,
#   'name': 'Telcoin',
#   'platform': 'Ethereum',
#   'price': 0.00372014,
#   'symbol': 'TEL',
#   'volume_24h': 837394.0},
#  {'circulating_supply': 103244552.962,
#   'market_cap': 98154286.7673,
#   'name': 'DEW',
#   'platform': 'Ethereum',
#   'price': 0.950697,
#   'symbol': 'DEW',
#   'volume_24h': 279247.0},
#  {'circulating_supply': 3726780.89997,
#   'market_cap': 96183370.213,
#   'name': 'Genesis Vision',
#   'platform': 'Ethereum',
#   'price': 25.8087,
#   'symbol': 'GVT',
#   'volume_24h': 5857920.0},
#  {'circulating_supply': 483511857.017,
#   'market_cap': 93942969.2355,
#   'name': 'MediShares',
#   'platform': 'Ethereum',
#   'price': 0.194293,
#   'symbol': 'MDS',
#   'volume_24h': 3533100.0},
#  {'circulating_supply': 13195542.215,
#   'market_cap': 92728901.8518,
#   'name': 'Monaco',
#   'platform': 'Ethereum',
#   'price': 7.02729,
#   'symbol': 'MCO',
#   'volume_24h': 2939300.0},
#  {'circulating_supply': 82500000.0,
#   'market_cap': 92106300.0,
#   'name': 'PayPie',
#   'platform': 'Ethereum',
#   'price': 1.11644,
#   'symbol': 'PPP',
#   'volume_24h': 107008.0},
#  {'circulating_supply': 463910526.92,
#   'market_cap': 88681136.326,
#   'name': 'Ink',
#   'platform': 'Qtum',
#   'price': 0.19116,
#   'symbol': 'INK',
#   'volume_24h': 21723500.0},
#  {'circulating_supply': 1631622325.37,
#   'market_cap': 87569170.2025,
#   'name': 'Time New Bank',
#   'platform': 'Ethereum',
#   'price': 0.05367,
#   'symbol': 'TNB',
#   'volume_24h': 4615470.0},
#  {'circulating_supply': 190630327.903,
#   'market_cap': 86629664.9516,
#   'name': 'SophiaTX',
#   'platform': 'Ethereum',
#   'price': 0.454438,
#   'symbol': 'SPHTX',
#   'volume_24h': 205702.0},
#  {'circulating_supply': 199908577.06,
#   'market_cap': 85148459.5872,
#   'name': 'VIBE',
#   'platform': 'Ethereum',
#   'price': 0.425937,
#   'symbol': 'VIBE',
#   'volume_24h': 3336000.0},
#  {'circulating_supply': 38325524.5,
#   'market_cap': 83512467.6512,
#   'name': 'IoT Chain',
#   'platform': 'Ethereum',
#   'price': 2.17903,
#   'symbol': 'ITC',
#   'volume_24h': 11776400.0},
#  {'circulating_supply': 39454345.3562,
#   'market_cap': 83215921.5949,
#   'name': 'CRYPTO20',
#   'platform': 'Ethereum',
#   'price': 2.10917,
#   'symbol': 'C20',
#   'volume_24h': 1963130.0},
#  {'circulating_supply': 165000000.0,
#   'market_cap': 82449180.0,
#   'name': 'Bluzelle',
#   'platform': 'Ethereum',
#   'price': 0.499692,
#   'symbol': 'BLZ',
#   'volume_24h': 3107310.0},
#  {'circulating_supply': 105378066.049,
#   'market_cap': 81184105.1084,
#   'name': 'Bibox Token',
#   'platform': 'Ethereum',
#   'price': 0.770408,
#   'symbol': 'BIX',
#   'volume_24h': 9471690.0},
#  {'circulating_supply': 4254336773.4,
#   'market_cap': 80372079.4557,
#   'name': 'DATA',
#   'platform': 'Ethereum',
#   'price': 0.0188918,
#   'symbol': 'DTA',
#   'volume_24h': 5841900.0},
#  {'circulating_supply': 19300994.0,
#   'market_cap': 80080017.1159,
#   'name': 'Metal',
#   'platform': 'Ethereum',
#   'price': 4.14901,
#   'symbol': 'MTL',
#   'volume_24h': 5173870.0},
#  {'circulating_supply': 359600000.0,
#   'market_cap': 78554620.0,
#   'name': 'SONM',
#   'platform': 'Ethereum',
#   'price': 0.21845,
#   'symbol': 'SNM',
#   'volume_24h': 807437.0},
#  {'circulating_supply': 29261461.2776,
#   'market_cap': 76842645.6173,
#   'name': 'Eidoo',
#   'platform': 'Ethereum',
#   'price': 2.62607,
#   'symbol': 'EDO',
#   'volume_24h': 3218790.0},
#  {'circulating_supply': 82046276.0,
#   'market_cap': 76166511.6767,
#   'name': 'Edgeless',
#   'platform': 'Ethereum',
#   'price': 0.928336,
#   'symbol': 'EDG',
#   'volume_24h': 2620580.0},
#  {'circulating_supply': 490533008.753,
#   'market_cap': 76142005.2177,
#   'name': 'Ripio Credit ...',
#   'platform': 'Ethereum',
#   'price': 0.155223,
#   'symbol': 'RCN',
#   'volume_24h': 6929620.0},
#  {'circulating_supply': 900000000.0,
#   'market_cap': 75627000.0,
#   'name': 'DeepBrain Chain',
#   'platform': 'NEO',
#   'price': 0.08403,
#   'symbol': 'DBC',
#   'volume_24h': 2397720.0},
#  {'circulating_supply': 100054311.845,
#   'market_cap': 74217286.8972,
#   'name': 'AppCoins',
#   'platform': 'Ethereum',
#   'price': 0.74177,
#   'symbol': 'APPC',
#   'volume_24h': 7494780.0},
#  {'circulating_supply': 183000000.0,
#   'market_cap': 73709106.0,
#   'name': 'Wagerr',
#   'platform': 'Waves',
#   'price': 0.402782,
#   'symbol': 'WGR',
#   'volume_24h': 230729.0},
#  {'circulating_supply': 144590975.0,
#   'market_cap': 72705258.3231,
#   'name': 'Ambrosus',
#   'platform': 'Ethereum',
#   'price': 0.502834,
#   'symbol': 'AMB',
#   'volume_24h': 1138850.0},
#  {'circulating_supply': 582916565.0,
#   'market_cap': 71333248.8087,
#   'name': 'Theta Token',
#   'platform': 'Ethereum',
#   'price': 0.122373,
#   'symbol': 'THETA',
#   'volume_24h': 7965250.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 70657200.0,
#   'name': 'SingularDTV',
#   'platform': 'Ethereum',
#   'price': 0.117762,
#   'symbol': 'SNGLS',
#   'volume_24h': 13251400.0},
#  {'circulating_supply': 656173039.17,
#   'market_cap': 69196727.8457,
#   'name': 'CoinDash',
#   'platform': 'Ethereum',
#   'price': 0.105455,
#   'symbol': 'CDT',
#   'volume_24h': 13940500.0},
#  {'circulating_supply': 445197758.912,
#   'market_cap': 68725178.0433,
#   'name': 'CyberMiles',
#   'platform': 'Ethereum',
#   'price': 0.15437,
#   'symbol': 'CMT',
#   'volume_24h': 3090060.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 68030250.0,
#   'name': 'AirSwap',
#   'platform': 'Ethereum',
#   'price': 0.453535,
#   'symbol': 'AST',
#   'volume_24h': 1786300.0},
#  {'circulating_supply': 89708333.0,
#   'market_cap': 67459141.3743,
#   'name': 'Wings',
#   'platform': 'Ethereum',
#   'price': 0.751983,
#   'symbol': 'WINGS',
#   'volume_24h': 6601310.0},
#  {'circulating_supply': 272889439.003,
#   'market_cap': 67207756.8166,
#   'name': 'Simple Token',
#   'platform': 'Ethereum',
#   'price': 0.246282,
#   'symbol': 'OST',
#   'volume_24h': 2143110.0},
#  {'circulating_supply': 599400.0,
#   'market_cap': 67038694.2,
#   'name': 'Melon',
#   'platform': 'Ethereum',
#   'price': 111.843,
#   'symbol': 'MLN',
#   'volume_24h': 335163.0},
#  {'circulating_supply': 1844678440.94,
#   'market_cap': 66637901.8718,
#   'name': 'U.CASH',
#   'platform': 'Ethereum',
#   'price': 0.0361244,
#   'symbol': 'UCASH',
#   'volume_24h': 199593.0},
#  {'circulating_supply': 23564882.3,
#   'market_cap': 66283065.2846,
#   'name': 'Nuls',
#   'platform': 'Ethereum',
#   'price': 2.81279,
#   'symbol': 'NULS',
#   'volume_24h': 5067020.0},
#  {'circulating_supply': 28100339.1971,
#   'market_cap': 65528866.994,
#   'name': 'INS Ecosystem',
#   'platform': 'Ethereum',
#   'price': 2.33196,
#   'symbol': 'INS',
#   'volume_24h': 18700800.0},
#  {'circulating_supply': 45248032.811,
#   'market_cap': 65156262.2872,
#   'name': 'WaBi',
#   'platform': 'Ethereum',
#   'price': 1.43998,
#   'symbol': 'WABI',
#   'volume_24h': 1887280.0},
#  {'circulating_supply': 98939459.119,
#   'market_cap': 65108595.1651,
#   'name': 'SIRIN LABS Token',
#   'platform': 'Ethereum',
#   'price': 0.658065,
#   'symbol': 'SRN',
#   'volume_24h': 10384000.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 64668600.0,
#   'name': 'Jibrel Network',
#   'platform': 'Ethereum',
#   'price': 0.431124,
#   'symbol': 'JNT',
#   'volume_24h': 5634360.0},
#  {'circulating_supply': 677154514.0,
#   'market_cap': 64279704.8269,
#   'name': 'Streamr DATAcoin',
#   'platform': 'Ethereum',
#   'price': 0.0949262,
#   'symbol': 'DATA',
#   'volume_24h': 420355.0},
#  {'circulating_supply': 485151252.554,
#   'market_cap': 62941582.9014,
#   'name': 'Etherparty',
#   'platform': 'Ethereum',
#   'price': 0.129736,
#   'symbol': 'FUEL',
#   'volume_24h': 1363300.0},
#  {'circulating_supply': 277269549.817,
#   'market_cap': 61370287.6174,
#   'name': 'UTRUST',
#   'platform': 'Ethereum',
#   'price': 0.221338,
#   'symbol': 'UTK',
#   'volume_24h': 1057760.0},
#  {'circulating_supply': 157861326.54,
#   'market_cap': 61095174.8749,
#   'name': 'Gifto',
#   'platform': 'Ethereum',
#   'price': 0.387018,
#   'symbol': 'GTO',
#   'volume_24h': 8848230.0},
#  {'circulating_supply': 74388399.693,
#   'market_cap': 59928410.6187,
#   'name': 'Bread',
#   'platform': 'Ethereum',
#   'price': 0.805615,
#   'symbol': 'BRD',
#   'volume_24h': 4794310.0},
#  {'circulating_supply': 355695760.02,
#   'market_cap': 59682902.9653,
#   'name': 'WePower',
#   'platform': 'Ethereum',
#   'price': 0.167792,
#   'symbol': 'WPR',
#   'volume_24h': 5630710.0},
#  {'circulating_supply': 98028877.0,
#   'market_cap': 58519710.5294,
#   'name': 'MobileGo',
#   'platform': 'Ethereum',
#   'price': 0.596964,
#   'symbol': 'MGO',
#   'volume_24h': 116575.0},
#  {'circulating_supply': 52000000.0,
#   'market_cap': 58316440.0,
#   'name': 'Quantum Resis...',
#   'platform': 'Ethereum',
#   'price': 1.12147,
#   'symbol': 'QRL',
#   'volume_24h': 480790.0},
#  {'circulating_supply': 57672338.0,
#   'market_cap': 57400297.5817,
#   'name': 'NAGA',
#   'platform': 'Ethereum',
#   'price': 0.995283,
#   'symbol': 'NGC',
#   'volume_24h': 190802.0},
#  {'circulating_supply': 428481269.499,
#   'market_cap': 54467682.0162,
#   'name': 'Tierion',
#   'platform': 'Ethereum',
#   'price': 0.127118,
#   'symbol': 'TNT',
#   'volume_24h': 2074810.0},
#  {'circulating_supply': 18266200.0,
#   'market_cap': 53865562.504,
#   'name': 'Modum',
#   'platform': 'Ethereum',
#   'price': 2.94892,
#   'symbol': 'MOD',
#   'volume_24h': 4852080.0},
#  {'circulating_supply': 32105577.5103,
#   'market_cap': 53832063.9231,
#   'name': 'Triggers',
#   'platform': 'Counterparty',
#   'price': 1.67672,
#   'symbol': 'TRIG',
#   'volume_24h': 792057.0},
#  {'circulating_supply': 355419546.26,
#   'market_cap': 53197065.1669,
#   'name': 'Bottos',
#   'platform': 'Ethereum',
#   'price': 0.149674,
#   'symbol': 'BTO',
#   'volume_24h': 627154.0},
#  {'circulating_supply': 30333338.8577,
#   'market_cap': 52960796.312,
#   'name': 'Delphy',
#   'platform': 'Ethereum',
#   'price': 1.74596,
#   'symbol': 'DPY',
#   'volume_24h': 4089680.0},
#  {'circulating_supply': 45166200.0,
#   'market_cap': 52558100.292,
#   'name': 'BlockMason Cr...',
#   'platform': 'Ethereum',
#   'price': 1.16366,
#   'symbol': 'BCPT',
#   'volume_24h': 103761000.0},
#  {'circulating_supply': 8146000.7794,
#   'market_cap': 51635218.0604,
#   'name': 'TaaS',
#   'platform': 'Ethereum',
#   'price': 6.33872,
#   'symbol': 'TAAS',
#   'volume_24h': 94791.7},
#  {'circulating_supply': 358188457.008,
#   'market_cap': 51579495.9976,
#   'name': 'Cobinhood',
#   'platform': 'Ethereum',
#   'price': 0.144001,
#   'symbol': 'COB',
#   'volume_24h': 299153.0},
#  {'circulating_supply': 333333333.0,
#   'market_cap': 49843333.2835,
#   'name': 'Trinity Netwo...',
#   'platform': 'NEO',
#   'price': 0.14953,
#   'symbol': 'TNC',
#   'volume_24h': 2468900.0},
#  {'circulating_supply': 300043386.0,
#   'market_cap': 49115602.0713,
#   'name': 'SpankChain',
#   'platform': 'Ethereum',
#   'price': 0.163695,
#   'symbol': 'SPANK',
#   'volume_24h': 334805.0},
#  {'circulating_supply': 240000000.0,
#   'market_cap': 48724560.0,
#   'name': 'QLINK',
#   'platform': 'NEO',
#   'price': 0.203019,
#   'symbol': 'QLC',
#   'volume_24h': 766730.0},
#  {'circulating_supply': 375000000.0,
#   'market_cap': 48103125.0,
#   'name': 'Hive Project',
#   'platform': 'Ethereum',
#   'price': 0.128275,
#   'symbol': 'HVN',
#   'volume_24h': 92985.0},
#  {'circulating_supply': 140450804.35,
#   'market_cap': 48062686.601,
#   'name': 'Unikoin Gold',
#   'platform': 'Ethereum',
#   'price': 0.342203,
#   'symbol': 'UKG',
#   'volume_24h': 6794390.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 47873400.0,
#   'name': 'district0x',
#   'platform': 'Ethereum',
#   'price': 0.079789,
#   'symbol': 'DNT',
#   'volume_24h': 1471960.0},
#  {'circulating_supply': 185000000.0,
#   'market_cap': 47597540.0,
#   'name': 'Medicalchain',
#   'platform': 'Ethereum',
#   'price': 0.257284,
#   'symbol': 'MTN',
#   'volume_24h': 5338580.0},
#  {'circulating_supply': 4660285459.8,
#   'market_cap': 47457550.9513,
#   'name': 'ATMChain',
#   'platform': 'Ethereum',
#   'price': 0.0101834,
#   'symbol': 'ATM',
#   'volume_24h': 99992.5},
#  {'circulating_supply': 399936258.54,
#   'market_cap': 47262467.3529,
#   'name': 'indaHash',
#   'platform': 'Ethereum',
#   'price': 0.118175,
#   'symbol': 'IDH',
#   'volume_24h': 133544.0},
#  {'circulating_supply': 68000000.0,
#   'market_cap': 47139436.0,
#   'name': 'Centra',
#   'platform': 'Ethereum',
#   'price': 0.693227,
#   'symbol': 'CTR',
#   'volume_24h': 1243030.0},
#  {'circulating_supply': 2297853.07853,
#   'market_cap': 46478444.4342,
#   'name': 'Lunyr',
#   'platform': 'Ethereum',
#   'price': 20.2269,
#   'symbol': 'LUN',
#   'volume_24h': 5620060.0},
#  {'circulating_supply': 10500000.0,
#   'market_cap': 41859195.0,
#   'name': 'Nimiq',
#   'platform': 'Ethereum',
#   'price': 3.98659,
#   'symbol': 'NET',
#   'volume_24h': 102134.0},
#  {'circulating_supply': 325120976.531,
#   'market_cap': 41427890.1926,
#   'name': 'STK',
#   'platform': 'Ethereum',
#   'price': 0.127423,
#   'symbol': 'STK',
#   'volume_24h': 3535670.0},
#  {'circulating_supply': 831335544.99,
#   'market_cap': 39799773.5486,
#   'name': 'Datum',
#   'platform': 'Ethereum',
#   'price': 0.0478745,
#   'symbol': 'DAT',
#   'volume_24h': 2857830.0},
#  {'circulating_supply': 701884009.0,
#   'market_cap': 39788541.079,
#   'name': 'Pepe Cash',
#   'platform': 'Counterparty',
#   'price': 0.0566882,
#   'symbol': 'PEPECASH',
#   'volume_24h': 196347.0},
#  {'circulating_supply': 16500000.0,
#   'market_cap': 39780015.0,
#   'name': 'Everex',
#   'platform': 'Ethereum',
#   'price': 2.41091,
#   'symbol': 'EVX',
#   'volume_24h': 5975670.0},
#  {'circulating_supply': 64962959.6415,
#   'market_cap': 39610839.8266,
#   'name': 'COSS',
#   'platform': 'Ethereum',
#   'price': 0.609745,
#   'symbol': 'COSS',
#   'volume_24h': 807816.0},
#  {'circulating_supply': 41990795.0,
#   'market_cap': 39395050.0255,
#   'name': 'Agoras Tokens',
#   'platform': 'Omni',
#   'price': 0.938183,
#   'symbol': 'AGRS',
#   'volume_24h': 885728.0},
#  {'circulating_supply': 254507605.599,
#   'market_cap': 39175083.1918,
#   'name': 'OriginTrail',
#   'platform': 'Ethereum',
#   'price': 0.153925,
#   'symbol': 'TRAC',
#   'volume_24h': 283555.0},
#  {'circulating_supply': 155000000.0,
#   'market_cap': 39020165.0,
#   'name': 'Presearch',
#   'platform': 'Ethereum',
#   'price': 0.251743,
#   'symbol': 'PRE',
#   'volume_24h': 59646.9},
#  {'circulating_supply': 330992078.46,
#   'market_cap': 38873033.6627,
#   'name': 'Cappasity',
#   'platform': 'Ethereum',
#   'price': 0.117444,
#   'symbol': 'CAPP',
#   'volume_24h': 173743.0},
#  {'circulating_supply': 150000000.0,
#   'market_cap': 38046000.0,
#   'name': 'Internet Node...',
#   'platform': 'Ethereum',
#   'price': 0.25364,
#   'symbol': 'INT',
#   'volume_24h': 1198980.0},
#  {'circulating_supply': 226606000.0,
#   'market_cap': 37769101.838,
#   'name': 'bitCNY',
#   'platform': 'BitShares',
#   'price': 0.166673,
#   'symbol': 'BITCNY',
#   'volume_24h': 26411700.0},
#  {'circulating_supply': 1543157590.0,
#   'market_cap': 37482217.6508,
#   'name': 'Safe Exchange...',
#   'platform': 'Omni',
#   'price': 0.0242893,
#   'symbol': 'SAFEX',
#   'volume_24h': 8044.55},
#  {'circulating_supply': 82013518.6244,
#   'market_cap': 37430559.8326,
#   'name': 'Spectre.ai Di...',
#   'platform': 'Ethereum',
#   'price': 0.456395,
#   'symbol': 'SXDT',
#   'volume_24h': 75067.1},
#  {'circulating_supply': 164966467.432,
#   'market_cap': 37236066.0622,
#   'name': 'Viberate',
#   'platform': 'Ethereum',
#   'price': 0.225719,
#   'symbol': 'VIB',
#   'volume_24h': 6555700.0},
#  {'circulating_supply': 24505929.2832,
#   'market_cap': 37194364.2882,
#   'name': 'TokenCard',
#   'platform': 'Ethereum',
#   'price': 1.51777,
#   'symbol': 'TKN',
#   'volume_24h': 80922.6},
#  {'circulating_supply': 100000000.0,
#   'market_cap': 37047500.0,
#   'name': 'Mercury',
#   'platform': 'Waves',
#   'price': 0.370475,
#   'symbol': 'MER',
#   'volume_24h': 1093420.0},
#  {'circulating_supply': 600000000.0,
#   'market_cap': 36664320.0,
#   'name': 'adToken',
#   'platform': 'Ethereum',
#   'price': 0.0611072,
#   'symbol': 'ADT',
#   'volume_24h': 258424.0},
#  {'circulating_supply': 85978873.0,
#   'market_cap': 35759988.9427,
#   'name': 'Agrello',
#   'platform': 'Ethereum',
#   'price': 0.415916,
#   'symbol': 'DLT',
#   'volume_24h': 3126500.0},
#  {'circulating_supply': 234565044.0,
#   'market_cap': 34961216.1131,
#   'name': 'Zeepin',
#   'platform': 'NEO',
#   'price': 0.149047,
#   'symbol': 'ZPT',
#   'volume_24h': 6796350.0},
#  {'circulating_supply': 162862944.036,
#   'market_cap': 34552839.3436,
#   'name': 'Humaniq',
#   'platform': 'Ethereum',
#   'price': 0.212159,
#   'symbol': 'HMQ',
#   'volume_24h': 792913.0},
#  {'circulating_supply': 13000000.0,
#   'market_cap': 34535670.0,
#   'name': 'Aeron',
#   'platform': 'Ethereum',
#   'price': 2.65659,
#   'symbol': 'ARN',
#   'volume_24h': 20867500.0},
#  {'circulating_supply': 51113355.2495,
#   'market_cap': 34318375.6416,
#   'name': 'Swarm',
#   'platform': 'Ethereum',
#   'price': 0.671417,
#   'symbol': 'SWM',
#   'volume_24h': 16659.9},
#  {'circulating_supply': 31432598.8758,
#   'market_cap': 33695745.9948,
#   'name': 'Decision Token',
#   'platform': 'Ethereum',
#   'price': 1.072,
#   'symbol': 'HST',
#   'volume_24h': 114505.0},
#  {'circulating_supply': 582029028.5,
#   'market_cap': 33670961.3278,
#   'name': 'Energo',
#   'platform': 'Ethereum',
#   'price': 0.057851,
#   'symbol': 'TSL',
#   'volume_24h': 1350380.0},
#  {'circulating_supply': 217017763.83,
#   'market_cap': 33274248.6392,
#   'name': 'Monetha',
#   'platform': 'Ethereum',
#   'price': 0.153325,
#   'symbol': 'MTH',
#   'volume_24h': 567083.0},
#  {'circulating_supply': 2000000000.0,
#   'market_cap': 32983600.0,
#   'name': 'Odyssey',
#   'platform': 'Ethereum',
#   'price': 0.0164918,
#   'symbol': 'OCN',
#   'volume_24h': 24450900.0},
#  {'circulating_supply': 65351403.0,
#   'market_cap': 32925605.2651,
#   'name': 'Qbao',
#   'platform': 'Qtum',
#   'price': 0.503824,
#   'symbol': 'QBT',
#   'volume_24h': 5360950.0},
#  {'circulating_supply': 1153170765.0,
#   'market_cap': 32499581.0358,
#   'name': 'Zeusshield',
#   'platform': 'Ethereum',
#   'price': 0.0281828,
#   'symbol': 'ZSC',
#   'volume_24h': 580780.0},
#  {'circulating_supply': 142215728.19,
#   'market_cap': 31932124.0977,
#   'name': 'Lamden',
#   'platform': 'Ethereum',
#   'price': 0.224533,
#   'symbol': 'TAU',
#   'volume_24h': 298443.0},
#  {'circulating_supply': 1884883590.81,
#   'market_cap': 31398013.8791,
#   'name': 'Selfkey',
#   'platform': 'Ethereum',
#   'price': 0.0166578,
#   'symbol': 'KEY',
#   'volume_24h': 386655.0},
#  {'circulating_supply': 244409119.108,
#   'market_cap': 31280701.1091,
#   'name': 'YOYOW',
#   'platform': 'BitShares',
#   'price': 0.127985,
#   'symbol': 'YOYOW',
#   'volume_24h': 1727170.0},
#  {'circulating_supply': 1750000000.0,
#   'market_cap': 31192700.0,
#   'name': 'SwftCoin',
#   'platform': 'Ethereum',
#   'price': 0.0178244,
#   'symbol': 'SWFTC',
#   'volume_24h': 18236800.0},
#  {'circulating_supply': 51950656.4494,
#   'market_cap': 30822220.5701,
#   'name': 'Blockport',
#   'platform': 'Ethereum',
#   'price': 0.593298,
#   'symbol': 'BPT',
#   'volume_24h': 1102770.0},
#  {'circulating_supply': 39236491.0,
#   'market_cap': 30133821.2705,
#   'name': 'Grid+',
#   'platform': 'Ethereum',
#   'price': 0.768005,
#   'symbol': 'GRID',
#   'volume_24h': 7774.76},
#  {'circulating_supply': 325000000.0,
#   'market_cap': 28762922.5,
#   'name': 'Cofound.it',
#   'platform': 'Ethereum',
#   'price': 0.0885013,
#   'symbol': 'CFI',
#   'volume_24h': 488275.0},
#  {'circulating_supply': 92147500.0,
#   'market_cap': 28716201.8675,
#   'name': 'WeTrust',
#   'platform': 'Ethereum',
#   'price': 0.311633,
#   'symbol': 'TRST',
#   'volume_24h': 139717.0},
#  {'circulating_supply': 37500780.0906,
#   'market_cap': 27942206.2533,
#   'name': 'CanYaCoin',
#   'platform': 'Ethereum',
#   'price': 0.74511,
#   'symbol': 'CAN',
#   'volume_24h': 723939.0},
#  {'circulating_supply': 30150150.1476,
#   'market_cap': 27726861.9797,
#   'name': 'Maecenas',
#   'platform': 'Ethereum',
#   'price': 0.919626,
#   'symbol': 'ART',
#   'volume_24h': 1635.1},
#  {'circulating_supply': 988181611.047,
#   'market_cap': 27559693.405,
#   'name': 'Soarcoin',
#   'platform': 'Ethereum',
#   'price': 0.0278893,
#   'symbol': 'SOAR',
#   'volume_24h': 14586.4},
#  {'circulating_supply': 70641963.6233,
#   'market_cap': 27248724.6284,
#   'name': 'DADI',
#   'platform': 'Ethereum',
#   'price': 0.38573,
#   'symbol': 'DADI',
#   'volume_24h': 649753.0},
#  {'circulating_supply': 462392281.65,
#   'market_cap': 27117041.5966,
#   'name': 'QunQun',
#   'platform': 'Ethereum',
#   'price': 0.0586451,
#   'symbol': 'QUN',
#   'volume_24h': 7180670.0},
#  {'circulating_supply': 1289036.90735,
#   'market_cap': 26963171.702,
#   'name': 'Numeraire',
#   'platform': 'Ethereum',
#   'price': 20.9173,
#   'symbol': 'NMR',
#   'volume_24h': 137432.0},
#  {'circulating_supply': 36828165.6489,
#   'market_cap': 26564671.4769,
#   'name': 'Olympus Labs',
#   'platform': 'Ethereum',
#   'price': 0.721314,
#   'symbol': 'MOT',
#   'volume_24h': 1118190.0},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 25411400.0,
#   'name': 'Blocktix',
#   'platform': 'Ethereum',
#   'price': 0.635285,
#   'symbol': 'TIX',
#   'volume_24h': 662988.0},
#  {'circulating_supply': 19628888.0,
#   'market_cap': 25210951.1694,
#   'name': 'Moeda Loyalty...',
#   'platform': 'Ethereum',
#   'price': 1.28438,
#   'symbol': 'MDA',
#   'volume_24h': 3585370.0},
#  {'circulating_supply': 82256324.0,
#   'market_cap': 25187462.2031,
#   'name': 'Synereo',
#   'platform': 'Omni',
#   'price': 0.306207,
#   'symbol': 'AMP',
#   'volume_24h': 585276.0},
#  {'circulating_supply': 39496567.6434,
#   'market_cap': 24879322.4208,
#   'name': 'Bloom',
#   'platform': 'Ethereum',
#   'price': 0.629911,
#   'symbol': 'BLT',
#   'volume_24h': 639442.0},
#  {'circulating_supply': 300000000.0,
#   'market_cap': 24601260.0,
#   'name': 'Game.com',
#   'platform': 'Ethereum',
#   'price': 0.0820042,
#   'symbol': 'GTC',
#   'volume_24h': 1061760.0},
#  {'circulating_supply': 101874187.0,
#   'market_cap': 24499926.98,
#   'name': 'Aurora DAO',
#   'platform': 'Ethereum',
#   'price': 0.240492,
#   'symbol': 'AURA',
#   'volume_24h': 82647.0},
#  {'circulating_supply': 10000000.0,
#   'market_cap': 24483700.0,
#   'name': 'Uquid Coin',
#   'platform': 'Ethereum',
#   'price': 2.44837,
#   'symbol': 'UQC',
#   'volume_24h': 43282.6},
#  {'circulating_supply': 85558370.5,
#   'market_cap': 24391065.8205,
#   'name': 'FirstBlood',
#   'platform': 'Ethereum',
#   'price': 0.285081,
#   'symbol': '1ST',
#   'volume_24h': 1556730.0},
#  {'circulating_supply': 77839404.0,
#   'market_cap': 24002325.0992,
#   'name': 'LATOKEN',
#   'platform': 'Ethereum',
#   'price': 0.308357,
#   'symbol': 'LA',
#   'volume_24h': 2082680.0},
#  {'circulating_supply': 114869777.154,
#   'market_cap': 23591265.6133,
#   'name': 'SunContract',
#   'platform': 'Ethereum',
#   'price': 0.205374,
#   'symbol': 'SNC',
#   'volume_24h': 3881430.0},
#  {'circulating_supply': 140000000.0,
#   'market_cap': 23517060.0,
#   'name': 'Mothership',
#   'platform': 'Ethereum',
#   'price': 0.167979,
#   'symbol': 'MSP',
#   'volume_24h': 82707.6},
#  {'circulating_supply': 349869198.325,
#   'market_cap': 23271654.6874,
#   'name': 'BitDegree',
#   'platform': 'Ethereum',
#   'price': 0.0665153,
#   'symbol': 'BDG',
#   'volume_24h': 106693.0},
#  {'circulating_supply': 5253865288.24,
#   'market_cap': 23214729.1626,
#   'name': 'carVertical',
#   'platform': 'Ethereum',
#   'price': 0.0044186,
#   'symbol': 'CV',
#   'volume_24h': 335956.0},
#  {'circulating_supply': 84285535.961,
#   'market_cap': 23003545.6166,
#   'name': 'Trade Token',
#   'platform': 'Ethereum',
#   'price': 0.272924,
#   'symbol': 'TIO',
#   'volume_24h': 659595.0},
#  {'circulating_supply': 17500000.0,
#   'market_cap': 22772050.0,
#   'name': 'Covesting',
#   'platform': 'Ethereum',
#   'price': 1.30126,
#   'symbol': 'COV',
#   'volume_24h': 240842.0},
#  {'circulating_supply': 201000000.0,
#   'market_cap': 22675413.0,
#   'name': 'InsurePal',
#   'platform': 'Ethereum',
#   'price': 0.112813,
#   'symbol': 'IPL',
#   'volume_24h': 11062.4},
#  {'circulating_supply': 16735940.3911,
#   'market_cap': 22525906.3287,
#   'name': 'Propy',
#   'platform': 'Ethereum',
#   'price': 1.34596,
#   'symbol': 'PRO',
#   'volume_24h': 9192000.0},
#  {'circulating_supply': 26244468.18,
#   'market_cap': 22097212.3403,
#   'name': 'Rivetz',
#   'platform': 'Ethereum',
#   'price': 0.841976,
#   'symbol': 'RVT',
#   'volume_24h': 5694.04},
#  {'circulating_supply': 75000000.0,
#   'market_cap': 21840225.0,
#   'name': 'Matchpool',
#   'platform': 'Ethereum',
#   'price': 0.291203,
#   'symbol': 'GUP',
#   'volume_24h': 2097550.0},
#  {'circulating_supply': 9973578.0,
#   'market_cap': 21708090.9317,
#   'name': 'Waves Communi...',
#   'platform': 'Waves',
#   'price': 2.17656,
#   'symbol': 'WCT',
#   'volume_24h': 99281.6},
#  {'circulating_supply': 404999427.0,
#   'market_cap': 21010843.7735,
#   'name': 'Snovio',
#   'platform': 'Ethereum',
#   'price': 0.0518787,
#   'symbol': 'SNOV',
#   'volume_24h': 544082.0},
#  {'circulating_supply': 17029321.0837,
#   'market_cap': 20887484.0684,
#   'name': 'Ormeus Coin',
#   'platform': 'Ethereum',
#   'price': 1.22656,
#   'symbol': 'ORME',
#   'volume_24h': 516105.0},
#  {'circulating_supply': 175109299.0,
#   'market_cap': 20579720.365,
#   'name': 'Worldcore',
#   'platform': 'Ethereum',
#   'price': 0.117525,
#   'symbol': 'WRC',
#   'volume_24h': 781139.0},
#  {'circulating_supply': 501394405.74,
#   'market_cap': 20571209.6787,
#   'name': 'BitClave',
#   'platform': 'Ethereum',
#   'price': 0.041028,
#   'symbol': 'CAT',
#   'volume_24h': 1193500.0},
#  {'circulating_supply': 324308731.314,
#   'market_cap': 20545574.3154,
#   'name': 'Hackspace Cap...',
#   'platform': 'Ethereum',
#   'price': 0.0633519,
#   'symbol': 'HAC',
#   'volume_24h': 995534.0},
#  {'circulating_supply': 13516418.1379,
#   'market_cap': 20521031.5094,
#   'name': 'Hubii Network',
#   'platform': 'Ethereum',
#   'price': 1.51823,
#   'symbol': 'HBT',
#   'volume_24h': 56792.1},
#  {'circulating_supply': 591500000.0,
#   'market_cap': 19712979.65,
#   'name': 'DomRaider',
#   'platform': 'Ethereum',
#   'price': 0.0333271,
#   'symbol': 'DRT',
#   'volume_24h': 4242.76},
#  {'circulating_supply': 3592379.31019,
#   'market_cap': 19674886.7012,
#   'name': 'Open Trading ...',
#   'platform': 'Ethereum',
#   'price': 5.47684,
#   'symbol': 'OTN',
#   'volume_24h': 72358.9},
#  {'circulating_supply': 40000000.0,
#   'market_cap': 19404280.0,
#   'name': 'Bodhi',
#   'platform': 'Qtum',
#   'price': 0.485107,
#   'symbol': 'BOT',
#   'volume_24h': 1498900.0},
#  {'circulating_supply': 321137782.25,
#   'market_cap': 19367980.2164,
#   'name': 'KickCoin',
#   'platform': 'Ethereum',
#   'price': 0.0603105,
#   'symbol': 'KICK',
#   'volume_24h': 3247040.0},
#  {'circulating_supply': 35778843.8312,
#   'market_cap': 19223615.0021,
#   'name': 'iXledger',
#   'platform': 'Ethereum',
#   'price': 0.53729,
#   'symbol': 'IXT',
#   'volume_24h': 295335.0},
#  {'circulating_supply': 19194555.628,
#   'market_cap': 19154093.5048,
#   'name': 'Dai',
#   'platform': 'Ethereum',
#   'price': 0.997892,
#   'symbol': 'DAI',
#   'volume_24h': 1599340.0},
#  {'circulating_supply': 25009249.58,
#   'market_cap': 19079856.6156,
#   'name': 'OAX',
#   'platform': 'Ethereum',
#   'price': 0.762912,
#   'symbol': 'OAX',
#   'volume_24h': 1191990.0},
#  {'circulating_supply': 28728253.2784,
#   'market_cap': 18932493.4755,
#   'name': 'Neumark',
#   'platform': 'Ethereum',
#   'price': 0.65902,
#   'symbol': 'NEU',
#   'volume_24h': 47393.7},
#  {'circulating_supply': 229389301.0,
#   'market_cap': 18570119.1067,
#   'name': 'Hydro Protocol',
#   'platform': 'Ethereum',
#   'price': 0.0809546,
#   'symbol': 'HOT',
#   'volume_24h': 67951.3},
#  {'circulating_supply': 3709674.34,
#   'market_cap': 18372718.62,
#   'name': 'Hedge',
#   'platform': 'Ethereum',
#   'price': 4.95265,
#   'symbol': 'HDG',
#   'volume_24h': 1010.54},
#  {'circulating_supply': 42145263.0692,
#   'market_cap': 18163891.9134,
#   'name': 'Stox',
#   'platform': 'Ethereum',
#   'price': 0.430983,
#   'symbol': 'STX',
#   'volume_24h': 582903.0},
#  {'circulating_supply': 20939024.6894,
#   'market_cap': 17599983.1173,
#   'name': 'Blackmoon',
#   'platform': 'Ethereum',
#   'price': 0.840535,
#   'symbol': 'BMC',
#   'volume_24h': 550687.0},
#  {'circulating_supply': 76091017.5262,
#   'market_cap': 17183558.3969,
#   'name': 'Quantum',
#   'platform': 'Ethereum',
#   'price': 0.225829,
#   'symbol': 'QAU',
#   'volume_24h': 30061.2},
#  {'circulating_supply': 64936612.4139,
#   'market_cap': 17085277.2824,
#   'name': 'Paragon',
#   'platform': 'Ethereum',
#   'price': 0.263107,
#   'symbol': 'PRG',
#   'volume_24h': 93697.2},
#  {'circulating_supply': 51200000.0,
#   'market_cap': 16993843.2,
#   'name': 'Primas',
#   'platform': 'Ethereum',
#   'price': 0.331911,
#   'symbol': 'PST',
#   'volume_24h': 284025.0},
#  {'circulating_supply': 49506089.45,
#   'market_cap': 16992767.1794,
#   'name': 'ProChain',
#   'platform': 'Ethereum',
#   'price': 0.343246,
#   'symbol': 'PRA',
#   'volume_24h': 544865.0},
#  {'circulating_supply': 38538647.0864,
#   'market_cap': 16969221.4692,
#   'name': 'ALIS',
#   'platform': 'Ethereum',
#   'price': 0.440317,
#   'symbol': 'ALIS',
#   'volume_24h': 23024.1},
#  {'circulating_supply': 256338118.651,
#   'market_cap': 16845208.1995,
#   'name': 'aXpire',
#   'platform': 'Ethereum',
#   'price': 0.0657148,
#   'symbol': 'AXP',
#   'volume_24h': 198002.0},
#  {'circulating_supply': 30000000.0,
#   'market_cap': 16464240.0,
#   'name': 'OracleChain',
#   'platform': 'BitShares',
#   'price': 0.548808,
#   'symbol': 'OCT',
#   'volume_24h': 35167.4},
#  {'circulating_supply': 7001622.64879,
#   'market_cap': 16429097.4967,
#   'name': 'Etheroll',
#   'platform': 'Ethereum',
#   'price': 2.34647,
#   'symbol': 'DICE',
#   'volume_24h': 109598.0},
#  {'circulating_supply': 107833692.874,
#   'market_cap': 16327422.9392,
#   'name': 'DecentBet',
#   'platform': 'Ethereum',
#   'price': 0.151413,
#   'symbol': 'DBET',
#   'volume_24h': 14457.3},
#  {'circulating_supply': 1050000000.0,
#   'market_cap': 16077705.0,
#   'name': 'AirToken',
#   'platform': 'Ethereum',
#   'price': 0.0153121,
#   'symbol': 'AIR',
#   'volume_24h': 153473.0},
#  {'circulating_supply': 2799476.19933,
#   'market_cap': 16022046.1683,
#   'name': 'MyBit Token',
#   'platform': 'Ethereum',
#   'price': 5.72323,
#   'symbol': 'MYB',
#   'volume_24h': 91296.9},
#  {'circulating_supply': 575064.760065,
#   'market_cap': 15827622.4042,
#   'name': 'ICOS',
#   'platform': 'Ethereum',
#   'price': 27.5232,
#   'symbol': 'ICOS',
#   'volume_24h': 153196.0},
#  {'circulating_supply': 70000000.0,
#   'market_cap': 15735860.0,
#   'name': 'BitDice',
#   'platform': 'Ethereum',
#   'price': 0.224798,
#   'symbol': 'CSNO',
#   'volume_24h': 9086.21},
#  {'circulating_supply': 22747808.5,
#   'market_cap': 15671010.7713,
#   'name': 'Databits',
#   'platform': 'Counterparty',
#   'price': 0.688902,
#   'symbol': 'DTB',
#   'volume_24h': 53440.6},
#  {'circulating_supply': 574512758.0,
#   'market_cap': 15549992.1131,
#   'name': 'FoldingCoin',
#   'platform': 'Counterparty',
#   'price': 0.0270664,
#   'symbol': 'FLDC',
#   'volume_24h': 174773.0},
#  {'circulating_supply': 3820953.60641,
#   'market_cap': 15471385.0382,
#   'name': 'Polybius',
#   'platform': 'Ethereum',
#   'price': 4.04909,
#   'symbol': 'PLBT',
#   'volume_24h': 37319.0},
#  {'circulating_supply': 209973618.032,
#   'market_cap': 15328788.0266,
#   'name': 'Pareto Network',
#   'platform': 'Ethereum',
#   'price': 0.0730034,
#   'symbol': 'PARETO',
#   'volume_24h': 251540.0},
#  {'circulating_supply': 8143170.61094,
#   'market_cap': 15326098.5434,
#   'name': 'Swarm City',
#   'platform': 'Ethereum',
#   'price': 1.88208,
#   'symbol': 'SWT',
#   'volume_24h': 348283.0},
#  {'circulating_supply': 14550300.0,
#   'market_cap': 15159084.552,
#   'name': 'bitUSD',
#   'platform': 'BitShares',
#   'price': 1.04184,
#   'symbol': 'BITUSD',
#   'volume_24h': 98566.8},
#  {'circulating_supply': 62166377.609,
#   'market_cap': 14943243.0178,
#   'name': 'EncrypGen',
#   'platform': 'Ethereum',
#   'price': 0.240375,
#   'symbol': 'DNA',
#   'volume_24h': 42595.7},
#  {'circulating_supply': 263034654.051,
#   'market_cap': 14786308.9532,
#   'name': 'HelloGold',
#   'platform': 'Ethereum',
#   'price': 0.0562143,
#   'symbol': 'HGT',
#   'volume_24h': 20732.5},
#  {'circulating_supply': 129071409.35,
#   'market_cap': 14654767.8176,
#   'name': 'CargoX',
#   'platform': 'Ethereum',
#   'price': 0.11354,
#   'symbol': 'CXO',
#   'volume_24h': 120943.0},
#  {'circulating_supply': 100336600.0,
#   'market_cap': 14525629.2454,
#   'name': 'Ethorse',
#   'platform': 'Ethereum',
#   'price': 0.144769,
#   'symbol': 'HORSE',
#   'volume_24h': 76173.3},
#  {'circulating_supply': 185501578.891,
#   'market_cap': 14422599.3575,
#   'name': 'OneRoot Network',
#   'platform': 'Ethereum',
#   'price': 0.0777492,
#   'symbol': 'RNT',
#   'volume_24h': 359185.0},
#  {'circulating_supply': 3840958.94793,
#   'market_cap': 14317981.0798,
#   'name': 'Hacken',
#   'platform': 'Ethereum',
#   'price': 3.72771,
#   'symbol': 'HKN',
#   'volume_24h': 132490.0},
#  {'circulating_supply': 194929698.0,
#   'market_cap': 14294136.2754,
#   'name': 'CoinMeet',
#   'platform': 'Ethereum',
#   'price': 0.0733297,
#   'symbol': 'MEE',
#   'volume_24h': 1984930.0},
#  {'circulating_supply': 127134335.724,
#   'market_cap': 14228620.5855,
#   'name': 'Xaurum',
#   'platform': 'Ethereum',
#   'price': 0.111918,
#   'symbol': 'XAUR',
#   'volume_24h': 64756.8},
#  {'circulating_supply': 1005414013.0,
#   'market_cap': 14137025.8954,
#   'name': 'Karma',
#   'platform': 'BitShares',
#   'price': 0.0140609,
#   'symbol': 'KRM',
#   'volume_24h': 41115.9},
#  {'circulating_supply': 498887536.723,
#   'market_cap': 13926695.0314,
#   'name': 'Voise',
#   'platform': 'Ethereum',
#   'price': 0.0279155,
#   'symbol': 'VOISE',
#   'volume_24h': 1033930.0},
#  {'circulating_supply': 51110775.4959,
#   'market_cap': 13785853.9206,
#   'name': 'SportyCo',
#   'platform': 'Ethereum',
#   'price': 0.269725,
#   'symbol': 'SPF',
#   'volume_24h': 2088380.0},
#  {'circulating_supply': 70000000.0,
#   'market_cap': 13713210.0,
#   'name': 'Patientory',
#   'platform': 'Ethereum',
#   'price': 0.195903,
#   'symbol': 'PTOY',
#   'volume_24h': 698918.0},
#  {'circulating_supply': 15000000.0,
#   'market_cap': 13677075.0,
#   'name': 'NVO',
#   'platform': 'Counterparty',
#   'price': 0.911805,
#   'symbol': 'NVST',
#   'volume_24h': 2394.45},
#  {'circulating_supply': 66520988.5,
#   'market_cap': 13607400.3656,
#   'name': 'Nexium',
#   'platform': 'Ethereum',
#   'price': 0.204558,
#   'symbol': 'NXC',
#   'volume_24h': 33455.4},
#  {'circulating_supply': 10384393.4012,
#   'market_cap': 13466481.3627,
#   'name': 'GET Protocol',
#   'platform': 'Ethereum',
#   'price': 1.2968,
#   'symbol': 'GET',
#   'volume_24h': 1700.63},
#  {'circulating_supply': 13631512.4213,
#   'market_cap': 13406824.2021,
#   'name': 'Playkey',
#   'platform': 'Ethereum',
#   'price': 0.983517,
#   'symbol': 'PKT',
#   'volume_24h': 3708.91},
#  {'circulating_supply': 19429024.2167,
#   'market_cap': 13406337.5739,
#   'name': 'Mysterium',
#   'platform': 'Ethereum',
#   'price': 0.690016,
#   'symbol': 'MYST',
#   'volume_24h': 57163.4},
#  {'circulating_supply': 2000000.0,
#   'market_cap': 13235980.0,
#   'name': 'Exchange Union',
#   'platform': 'Ethereum',
#   'price': 6.61799,
#   'symbol': 'XUC',
#   'volume_24h': 1364650.0},
#  {'circulating_supply': 36645278.3876,
#   'market_cap': 13231730.5391,
#   'name': 'BLUE',
#   'platform': 'Ethereum',
#   'price': 0.361076,
#   'symbol': 'BLUE',
#   'volume_24h': 17048.1},
#  {'circulating_supply': 123063760.671,
#   'market_cap': 13033067.5739,
#   'name': 'Bounty0x',
#   'platform': 'Ethereum',
#   'price': 0.105905,
#   'symbol': 'BNTY',
#   'volume_24h': 158258.0},
#  {'circulating_supply': 710112.8108,
#   'market_cap': 12895861.678,
#   'name': 'Chronobank',
#   'platform': 'Ethereum',
#   'price': 18.1603,
#   'symbol': 'TIME',
#   'volume_24h': 177768.0},
#  {'circulating_supply': 1000000000.0,
# ...
#   'name': 'IPChain',
#   'platform': 'Ethereum',
#   'price': 0.918113,
#   'symbol': 'IPC',
#   'volume_24h': 823059.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'UG Token',
#   'platform': 'Ethereum',
#   'price': 0.818406,
#   'symbol': 'UGT',
#   'volume_24h': 764292.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Remme',
#   'platform': 'Ethereum',
#   'price': 0.0292984,
#   'symbol': 'REM',
#   'volume_24h': 656930.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Mobius',
#   'platform': 'Stellar',
#   'price': 0.158356,
#   'symbol': 'MOBI',
#   'volume_24h': 514262.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SwissBorg',
#   'platform': 'Ethereum',
#   'price': 0.0464025,
#   'symbol': 'CHSB',
#   'volume_24h': 500032.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SpaceChain',
#   'platform': 'Qtum',
#   'price': 0.194895,
#   'symbol': 'SPC',
#   'volume_24h': 491270.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Mixin',
#   'platform': 'Ethereum',
#   'price': 571.539,
#   'symbol': 'XIN',
#   'volume_24h': 476327.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Content and A...',
#   'platform': 'Ethereum',
#   'price': 0.0351257,
#   'symbol': 'CAN',
#   'volume_24h': 430027.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Read',
#   'platform': 'Ethereum',
#   'price': 0.0379192,
#   'symbol': 'READ',
#   'volume_24h': 409445.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Envion',
#   'platform': 'Ethereum',
#   'price': 0.747995,
#   'symbol': 'EVN',
#   'volume_24h': 406092.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ATN',
#   'platform': 'Ethereum',
#   'price': 1.24927,
#   'symbol': 'ATN',
#   'volume_24h': 392067.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'RED MWAT',
#   'platform': 'Ethereum',
#   'price': 0.0621346,
#   'symbol': 'MWAT',
#   'volume_24h': 368470.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bankex',
#   'platform': 'Ethereum',
#   'price': 1.31708,
#   'symbol': 'BKX',
#   'volume_24h': 357853.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Republic Prot...',
#   'platform': 'Ethereum',
#   'price': 0.0822032,
#   'symbol': 'REN',
#   'volume_24h': 328876.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ValueChain',
#   'platform': 'Ethereum',
#   'price': 0.0706609,
#   'symbol': 'VLC',
#   'volume_24h': 309455.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'MOAC',
#   'platform': 'Ethereum',
#   'price': 13.5791,
#   'symbol': 'MOAC',
#   'volume_24h': 307278.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'COMSA [ETH]',
#   'platform': 'Ethereum',
#   'price': 1.01228,
#   'symbol': 'CMS',
#   'volume_24h': 290745.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Pundi X',
#   'platform': 'Ethereum',
#   'price': 1.6172,
#   'symbol': 'PXS',
#   'volume_24h': 269829.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Tidex Token',
#   'platform': 'Waves',
#   'price': 0.877722,
#   'symbol': 'TDX',
#   'volume_24h': 262716.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Tigereum',
#   'platform': 'Ethereum',
#   'price': 0.210392,
#   'symbol': 'TIG',
#   'volume_24h': 260016.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'COMSA [XEM]',
#   'platform': 'NEM',
#   'price': 1.03751,
#   'symbol': 'CMS',
#   'volume_24h': 241616.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'iQuant',
#   'platform': 'Ethereum',
#   'price': 0.134298,
#   'symbol': 'IQT',
#   'volume_24h': 237937.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Etherecash',
#   'platform': 'Ethereum',
#   'price': 0.82934,
#   'symbol': 'ECH',
#   'volume_24h': 226009.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CoinFi',
#   'platform': 'Ethereum',
#   'price': 0.0874173,
#   'symbol': 'COFI',
#   'volume_24h': 203973.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Fortuna',
#   'platform': 'Ethereum',
#   'price': 0.0709271,
#   'symbol': 'FOTA',
#   'volume_24h': 197355.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Neurotoken',
#   'platform': 'Ethereum',
#   'price': 0.428012,
#   'symbol': 'NTK',
#   'volume_24h': 148727.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ugChain',
#   'platform': 'Ethereum',
#   'price': 0.0840085,
#   'symbol': 'UGC',
#   'volume_24h': 147055.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Qube',
#   'platform': 'Ethereum',
#   'price': 0.0637195,
#   'symbol': 'QUBE',
#   'volume_24h': 145033.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BigONE Token',
#   'platform': 'Ethereum',
#   'price': 2.91648,
#   'symbol': 'BIG',
#   'volume_24h': 114029.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'RefToken',
#   'platform': 'Ethereum',
#   'price': 18.2224,
#   'symbol': 'REF',
#   'volume_24h': 95330.4},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TokenClub',
#   'platform': 'Ethereum',
#   'price': 0.0273109,
#   'symbol': 'TCT',
#   'volume_24h': 92052.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Cashaa',
#   'platform': 'Ethereum',
#   'price': 0.113453,
#   'symbol': 'CAS',
#   'volume_24h': 81581.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'WETH',
#   'platform': 'Ethereum',
#   'price': 860.954,
#   'symbol': 'WETH',
#   'volume_24h': 80716.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Copytrack',
#   'platform': 'Ethereum',
#   'price': 0.293078,
#   'symbol': 'CPY',
#   'volume_24h': 76439.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Alphacat',
#   'platform': 'NEO',
#   'price': 0.0132368,
#   'symbol': 'ACAT',
#   'volume_24h': 74932.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Escroco',
#   'platform': 'Waves',
#   'price': 0.308075,
#   'symbol': 'ESC',
#   'volume_24h': 58995.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EtherSportz',
#   'platform': 'Ethereum',
#   'price': 0.366058,
#   'symbol': 'ESZ',
#   'volume_24h': 57836.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Tokenbox',
#   'platform': 'Ethereum',
#   'price': 0.58699,
#   'symbol': 'TBX',
#   'volume_24h': 57608.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BlockCDN',
#   'platform': 'Ethereum',
#   'price': 0.0955061,
#   'symbol': 'BCDN',
#   'volume_24h': 55853.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maggie',
#   'platform': 'Ethereum',
#   'price': 0.0260009,
#   'symbol': 'MAG',
#   'volume_24h': 51303.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Crypterium',
#   'platform': 'Ethereum',
#   'price': 0.60201,
#   'symbol': 'CRPT',
#   'volume_24h': 49533.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GameChain System',
#   'platform': 'Ethereum',
#   'price': 0.0210535,
#   'symbol': 'GCS',
#   'volume_24h': 48802.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'InvestDigital',
#   'platform': 'Ethereum',
#   'price': 0.0662892,
#   'symbol': 'IDT',
#   'volume_24h': 43146.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ZenGold',
#   'platform': 'BitShares',
#   'price': 0.0473097,
#   'symbol': 'ZENGOLD',
#   'volume_24h': 40640.1},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DIMCOIN',
#   'platform': 'NEM',
#   'price': 0.00649109,
#   'symbol': 'DIM',
#   'volume_24h': 38970.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Datawallet',
#   'platform': 'Ethereum',
#   'price': 0.0870853,
#   'symbol': 'DXT',
#   'volume_24h': 31261.8},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'IDEX Membership',
#   'platform': 'Ethereum',
#   'price': 4388.85,
#   'symbol': 'IDXM',
#   'volume_24h': 26460.4},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sphre AIR ',
#   'platform': 'Ethereum',
#   'price': 0.209865,
#   'symbol': 'XID',
#   'volume_24h': 21543.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CryptopiaFeeS...',
#   'platform': 'Ubiq',
#   'price': 1868.07,
#   'symbol': 'CEFS',
#   'volume_24h': 18978.3},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Vezt',
#   'platform': 'Ethereum',
#   'price': 0.173297,
#   'symbol': 'VZT',
#   'volume_24h': 18408.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Maverick Chain',
#   'platform': 'Ethereum',
#   'price': 0.0875688,
#   'symbol': 'MVC',
#   'volume_24h': 13101.2},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Gladius Token',
#   'platform': 'Ethereum',
#   'price': 1.08393,
#   'symbol': 'GLA',
#   'volume_24h': 13058.2},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Bitair',
#   'platform': 'Ethereum',
#   'price': 0.00305776,
#   'symbol': 'BTCA',
#   'volume_24h': 11385.5},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DRP Utility',
#   'platform': 'Ethereum',
#   'price': 0.55079,
#   'symbol': 'DRPU',
#   'volume_24h': 10624.7},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'OX Fina',
#   'platform': 'Ethereum',
#   'price': 0.000812664,
#   'symbol': 'OX',
#   'volume_24h': 8139.92},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Dether',
#   'platform': 'Ethereum',
#   'price': 0.127534,
#   'symbol': 'DTH',
#   'volume_24h': 7804.77},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'DMarket',
#   'platform': 'Ethereum',
#   'price': 0.495919,
#   'symbol': 'DMT',
#   'volume_24h': 6925.09},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Indicoin',
#   'platform': 'Ethereum',
#   'price': 0.026567,
#   'symbol': 'INDI',
#   'volume_24h': 6203.08},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Zap',
#   'platform': 'Ethereum',
#   'price': 0.242424,
#   'symbol': 'ZAP',
#   'volume_24h': 5800.13},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Cloud',
#   'platform': 'Ethereum',
#   'price': 0.0871548,
#   'symbol': 'CLD',
#   'volume_24h': 5732.14},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'GOLD Reward T...',
#   'platform': 'Ethereum',
#   'price': 0.0621216,
#   'symbol': 'GRX',
#   'volume_24h': 5710.41},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Storjcoin X',
#   'platform': 'Counterparty',
#   'price': 0.392338,
#   'symbol': 'SJCX',
#   'volume_24h': 4048.22},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'FidentiaX',
#   'platform': 'Ethereum',
#   'price': 0.16064,
#   'symbol': 'FDX',
#   'volume_24h': 3621.31},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Macro',
#   'platform': 'Ethereum',
#   'price': 0.403252,
#   'symbol': 'MCR',
#   'volume_24h': 3330.08},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Alphabit',
#   'platform': 'Ethereum',
#   'price': 91.6299,
#   'symbol': 'ABC',
#   'volume_24h': 3133.68},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'NEO GOLD',
#   'platform': 'Ethereum',
#   'price': 0.00644436,
#   'symbol': 'NEOG',
#   'volume_24h': 2983.13},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SISA',
#   'platform': 'Ethereum',
#   'price': 0.0167355,
#   'symbol': 'SISA',
#   'volume_24h': 2855.88},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'President Trump',
#   'platform': 'Omni',
#   'price': 0.0433611,
#   'symbol': 'PRES',
#   'volume_24h': 2496.6},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sense',
#   'platform': 'Ethereum',
#   'price': 0.0468241,
#   'symbol': 'SENSE',
#   'volume_24h': 2283.57},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Internet of T...',
#   'platform': 'Nxt',
#   'price': 673.91,
#   'symbol': 'XOT',
#   'volume_24h': 1864.19},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Ethereum Lite',
#   'platform': 'Ethereum',
#   'price': 0.408314,
#   'symbol': 'ELITE',
#   'volume_24h': 1613.23},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'ANRYZE',
#   'platform': 'Waves',
#   'price': 0.0111377,
#   'symbol': 'RYZ',
#   'volume_24h': 1386.63},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'President Joh...',
#   'platform': 'Omni',
#   'price': 0.204259,
#   'symbol': 'GARY',
#   'volume_24h': 1357.71},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'PlexCoin',
#   'platform': 'Ethereum',
#   'price': 0.0254376,
#   'symbol': 'PLX',
#   'volume_24h': 1352.96},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BitSerial',
#   'platform': 'Ethereum',
#   'price': 0.0497318,
#   'symbol': 'BTE',
#   'volume_24h': 1264.34},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'TeslaCoilCoin',
#   'platform': 'Omni',
#   'price': 1.19521,
#   'symbol': 'TESLA',
#   'volume_24h': 1059.77},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Nitro',
#   'platform': 'Ethereum',
#   'price': 0.21226,
#   'symbol': 'NOX',
#   'volume_24h': 970.669},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'eGold',
#   'platform': 'Ethereum',
#   'price': 0.0213558,
#   'symbol': 'EGOLD',
#   'volume_24h': 894.177},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Monero Gold',
#   'platform': 'Ethereum',
#   'price': 0.000306542,
#   'symbol': 'XMRG',
#   'volume_24h': 863.265},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Minex',
#   'platform': 'Waves',
#   'price': 0.0173514,
#   'symbol': 'MINEX',
#   'volume_24h': 773.93},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'HODL Bucks',
#   'platform': 'Ethereum',
#   'price': 0.112501,
#   'symbol': 'HDLB',
#   'volume_24h': 772.486},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'United Trader...',
#   'platform': 'Ethereum',
#   'price': 0.813449,
#   'symbol': 'UTT',
#   'volume_24h': 749.807},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'EncryptoTel [...',
#   'platform': 'Ethereum',
#   'price': 0.101328,
#   'symbol': 'ETT',
#   'volume_24h': 749.653},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Peerguess',
#   'platform': 'Ethereum',
#   'price': 0.0274866,
#   'symbol': 'GUESS',
#   'volume_24h': 471.079},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'FAPcoin',
#   'platform': 'Ethereum',
#   'price': 0.00350235,
#   'symbol': 'FAP',
#   'volume_24h': 465.197},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'BTCMoon',
#   'platform': 'Ethereum',
#   'price': 0.00988986,
#   'symbol': 'BTCM',
#   'volume_24h': 399.574},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Wi Coin',
#   'platform': 'Ethereum',
#   'price': 0.00319285,
#   'symbol': 'WIC',
#   'volume_24h': 321.189},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Musiconomi',
#   'platform': 'Ethereum',
#   'price': 0.0903277,
#   'symbol': 'MCI',
#   'volume_24h': 290.693},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Natcoin',
#   'platform': 'Ethereum',
#   'price': 0.0412229,
#   'symbol': 'NTC',
#   'volume_24h': 248.448},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'CORION',
#   'platform': 'Ethereum Classic',
#   'price': 0.53134,
#   'symbol': 'COR',
#   'volume_24h': 224.501},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Smoke',
#   'platform': 'BitShares',
#   'price': 0.0397223,
#   'symbol': 'SMOKE',
#   'volume_24h': 141.742},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'STEX',
#   'platform': 'Nxt',
#   'price': 1.13481,
#   'symbol': 'STEX',
#   'volume_24h': 134.477},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'Sand Coin',
#   'platform': 'Ethereum',
#   'price': 1.9399,
#   'symbol': 'SND',
#   'volume_24h': 28.6106},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'SnakeEyes',
#   'platform': 'Burst',
#   'price': 0.045515,
#   'symbol': 'SNAKE',
#   'volume_24h': 1.18339},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'First Bitcoin...',
#   'platform': 'Omni',
#   'price': 0.285041,
#   'symbol': 'BITCF',
#   'volume_24h': 0.0},
#  {'circulating_supply': None,
#   'market_cap': None,
#   'name': 'LLToken',
#   'platform': 'Ethereum',
#   'price': None,
#   'symbol': 'LLT',
#   'volume_24h': 0.0}]

# %%
show_page("tokens/views/all")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/tokens/views/all"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# _________________________________
#
# ## Graphs API
# The graphs API is used internally by coinmarketcap for display graphs info. The params `start` and `end` are passed as `datetime` objects.
#
# #### `graphs.currency(name, [start=None, end=None])`
#
# Get graphs data for a currency:

# %%
cmc.graphs.currency("BTC")
# Out:
# {'market_cap_by_available_supply': [[datetime.datetime(2013, 4, 28, 20, 47, 21),
#    1500517590],
#   [datetime.datetime(2013, 4, 29, 20, 45, 1), 1575032004],
#   [datetime.datetime(2013, 4, 30, 20, 45, 2), 1501657492],
#   [datetime.datetime(2013, 5, 1, 20, 45, 2), 1298951550],
#   [datetime.datetime(2013, 5, 2, 21, 20, 1), 1148667722],
#   [datetime.datetime(2013, 5, 3, 21, 20, 1), 1011066494],
#   [datetime.datetime(2013, 5, 4, 21, 20, 1), 1236351843],
#   [datetime.datetime(2013, 5, 5, 21, 25, 1), 1298377788],
#   [datetime.datetime(2013, 5, 6, 21, 25, 3), 1315992303],
#   [datetime.datetime(2013, 5, 7, 21, 25, 1), 1183766500],
#   [datetime.datetime(2013, 5, 8, 21, 25, 1), 1253655040],
#   [datetime.datetime(2013, 5, 9, 21, 50, 1), 1258130700],
#   [datetime.datetime(2013, 5, 10, 21, 55, 2), 1322989457],
#   [datetime.datetime(2013, 5, 11, 22, 25, 1), 1259239352],
#   [datetime.datetime(2013, 5, 12, 22, 25, 1), 1278708678],
#   [datetime.datetime(2013, 5, 13, 22, 25, 1), 1306721052],
#   [datetime.datetime(2013, 5, 14, 22, 25, 1), 1277278987],
#   [datetime.datetime(2013, 5, 15, 22, 35, 1), 1273849680],
#   [datetime.datetime(2013, 5, 16, 22, 35, 1), 1289277412],
#   [datetime.datetime(2013, 5, 17, 22, 35, 1), 1374605382],
#   [datetime.datetime(2013, 5, 18, 22, 35, 1), 1383755085],
#   [datetime.datetime(2013, 5, 19, 22, 35, 2), 1346499261],
#   [datetime.datetime(2013, 5, 20, 22, 35, 2), 1370131821],
#   [datetime.datetime(2013, 5, 21, 22, 35, 2), 1374154117],
#   [datetime.datetime(2013, 5, 22, 22, 35, 4), 1375791900],
#   [datetime.datetime(2013, 5, 23, 22, 35, 2), 1407041527],
#   [datetime.datetime(2013, 5, 24, 22, 35, 1), 1474180657],
#   [datetime.datetime(2013, 5, 25, 22, 35, 2), 1464316690],
#   [datetime.datetime(2013, 5, 26, 22, 45, 2), 1507769010],
#   [datetime.datetime(2013, 5, 27, 22, 45, 1), 1445444605],
#   [datetime.datetime(2013, 5, 28, 22, 45, 7), 1448115966],
#   [datetime.datetime(2013, 5, 29, 23, 15, 1), 1481781794],
#   [datetime.datetime(2013, 5, 30, 23, 15, 1), 1429308633],
#   [datetime.datetime(2013, 5, 31, 23, 40, 2), 1436386729],
#   [datetime.datetime(2013, 6, 1, 23, 40, 2), 1449499974],
#   [datetime.datetime(2013, 6, 3, 1, 25, 1), 1362684200],
#   [datetime.datetime(2013, 6, 4, 1, 25, 2), 1361765704],
#   [datetime.datetime(2013, 6, 5, 2, 45, 2), 1364113639],
#   [datetime.datetime(2013, 6, 6, 2, 45, 2), 1369233814],
#   [datetime.datetime(2013, 6, 7, 2, 45, 1), 1339234925],
#   [datetime.datetime(2013, 6, 8, 2, 45, 2), 1239395972],
#   [datetime.datetime(2013, 6, 9, 2, 45, 1), 1220874392],
#   [datetime.datetime(2013, 6, 10, 2, 45, 2), 1123844957],
#   [datetime.datetime(2013, 6, 11, 2, 55, 5), 1194605340],
#   [datetime.datetime(2013, 6, 12, 3, 0, 2), 1227904672],
#   [datetime.datetime(2013, 6, 13, 3, 0, 1), 1222819750],
#   [datetime.datetime(2013, 6, 14, 3, 0, 2), 1159766149],
#   [datetime.datetime(2013, 6, 15, 3, 5, 1), 1110902570],
#   [datetime.datetime(2013, 6, 16, 3, 5, 2), 1129287060],
#   [datetime.datetime(2013, 6, 17, 3, 15, 2), 1134610433],
#   [datetime.datetime(2013, 6, 18, 3, 20, 4), 1152834600],
#   [datetime.datetime(2013, 6, 19, 3, 25, 2), 1204638317],
#   [datetime.datetime(2013, 6, 20, 3, 25, 10), 1220273470],
#   [datetime.datetime(2013, 6, 21, 3, 30, 2), 1254733148],
#   [datetime.datetime(2013, 6, 22, 3, 30, 1), 1233750008],
#   [datetime.datetime(2013, 6, 23, 3, 30, 2), 1214260368],
#   [datetime.datetime(2013, 6, 24, 3, 30, 2), 1223181000],
#   [datetime.datetime(2013, 6, 25, 3, 30, 3), 1160635651],
#   [datetime.datetime(2013, 6, 26, 3, 35, 2), 1175194909],
#   [datetime.datetime(2013, 6, 27, 3, 50, 1), 1172207387],
#   [datetime.datetime(2013, 6, 28, 3, 50, 1), 1130338737],
#   [datetime.datetime(2013, 6, 29, 3, 50, 1), 1058953326],
#   [datetime.datetime(2013, 6, 30, 4, 0, 2), 1082693996],
#   [datetime.datetime(2013, 7, 1, 4, 0, 1), 1107084792],
#   [datetime.datetime(2013, 7, 2, 4, 0, 4), 1016445145],
#   [datetime.datetime(2013, 7, 3, 4, 0, 1), 1031653673],
#   [datetime.datetime(2013, 7, 4, 4, 50, 2), 895707780],
#   [datetime.datetime(2013, 7, 5, 4, 46, 1), 892405890],
#   [datetime.datetime(2013, 7, 6, 4, 46, 2), 771368060],
#   [datetime.datetime(2013, 7, 7, 4, 46, 1), 774804400],
#   [datetime.datetime(2013, 7, 8, 4, 46, 2), 882356394],
#   [datetime.datetime(2013, 7, 9, 4, 46, 2), 870081996],
#   [datetime.datetime(2013, 7, 10, 4, 46, 2), 877378425],
#   [datetime.datetime(2013, 7, 11, 5, 1, 1), 977479256],
#   [datetime.datetime(2013, 7, 12, 5, 1, 1), 1069724400],
#   [datetime.datetime(2013, 7, 13, 5, 1, 2), 1004551934],
#   [datetime.datetime(2013, 7, 14, 5, 1, 1), 1090715949],
#   [datetime.datetime(2013, 7, 15, 5, 11, 2), 1073073450],
#   [datetime.datetime(2013, 7, 16, 5, 16, 2), 1111179852],
#   [datetime.datetime(2013, 7, 17, 5, 16, 2), 1130735526],
#   [datetime.datetime(2013, 7, 18, 5, 21, 2), 1117707300],
#   [datetime.datetime(2013, 7, 19, 5, 21, 1), 1015062893],
#   [datetime.datetime(2013, 7, 20, 5, 21, 2), 1047311253],
#   [datetime.datetime(2013, 7, 21, 5, 21, 2), 1021492656],
#   [datetime.datetime(2013, 7, 22, 5, 21, 2), 1034399450],
#   [datetime.datetime(2013, 7, 23, 5, 21, 1), 1050054379],
#   [datetime.datetime(2013, 7, 24, 5, 21, 1), 1083333285],
#   [datetime.datetime(2013, 7, 25, 5, 21, 2), 1083076902],
#   [datetime.datetime(2013, 7, 26, 5, 16, 2), 1111232482],
#   [datetime.datetime(2013, 7, 27, 5, 16, 1), 1079278107],
#   [datetime.datetime(2013, 7, 28, 5, 16, 2), 1078286702],
#   [datetime.datetime(2013, 7, 29, 5, 16, 2), 1131111628],
#   [datetime.datetime(2013, 7, 30, 5, 16, 2), 1165105812],
#   [datetime.datetime(2013, 7, 31, 6, 46, 2), 1267183179],
#   [datetime.datetime(2013, 8, 1, 6, 56, 1), 1220481781],
#   [datetime.datetime(2013, 8, 2, 6, 56, 2), 1167849454],
#   [datetime.datetime(2013, 8, 3, 6, 56, 2), 1192378895],
#   [datetime.datetime(2013, 8, 4, 6, 56, 1), 1206152150],
#   [datetime.datetime(2013, 8, 5, 6, 56, 1), 1226188584],
#   [datetime.datetime(2013, 8, 6, 6, 56, 1), 1218425715],
#   [datetime.datetime(2013, 8, 7, 6, 56), 1229098150],
#   [datetime.datetime(2013, 8, 8, 6, 56, 2), 1212383133],
#   [datetime.datetime(2013, 8, 9, 6, 56, 2), 1198290079],
#   [datetime.datetime(2013, 8, 10, 6, 56, 1), 1195703559],
#   [datetime.datetime(2013, 8, 11, 6, 56, 2), 1193835825],
#   [datetime.datetime(2013, 8, 12, 6, 56, 1), 1204979580],
#   [datetime.datetime(2013, 8, 13, 7, 1, 2), 1234277535],
#   [datetime.datetime(2013, 8, 14, 7, 1, 1), 1277045962],
#   [datetime.datetime(2013, 8, 15, 7, 1, 2), 1290791623],
#   [datetime.datetime(2013, 8, 16, 7, 21, 1), 1255999432],
#   [datetime.datetime(2013, 8, 17, 7, 21, 1), 1260549575],
#   [datetime.datetime(2013, 8, 18, 7, 21, 1), 1297725576],
#   [datetime.datetime(2013, 8, 19, 7, 21, 1), 1364305023],
#   [datetime.datetime(2013, 8, 20, 7, 21, 1), 1391744715],
#   [datetime.datetime(2013, 8, 21, 7, 21, 2), 1390017000],
#   [datetime.datetime(2013, 8, 22, 7, 21, 1), 1412622912],
#   [datetime.datetime(2013, 8, 23, 7, 21, 1), 1404948802],
#   [datetime.datetime(2013, 8, 24, 7, 21, 1), 1380248275],
#   [datetime.datetime(2013, 8, 25, 7, 21, 2), 1398134387],
#   [datetime.datetime(2013, 8, 26, 7, 21, 2), 1413720420],
#   [datetime.datetime(2013, 8, 27, 7, 21, 1), 1420013070],
#   [datetime.datetime(2013, 8, 28, 7, 21, 2), 1467696672],
#   [datetime.datetime(2013, 8, 29, 7, 21, 1), 1423401000],
#   [datetime.datetime(2013, 8, 30, 7, 21, 1), 1414493496],
#   [datetime.datetime(2013, 8, 31, 7, 21, 2), 1548720490],
#   [datetime.datetime(2013, 9, 1, 7, 21, 2), 1595008048],
#   [datetime.datetime(2013, 9, 2, 7, 21, 2), 1590732401],
#   [datetime.datetime(2013, 9, 3, 7, 21, 2), 1575707182],
#   [datetime.datetime(2013, 9, 4, 7, 21, 2), 1589775538],
#   [datetime.datetime(2013, 9, 5, 7, 26, 2), 1483451582],
#   [datetime.datetime(2013, 9, 6, 7, 26, 1), 1466648505],
#   [datetime.datetime(2013, 9, 7, 7, 26, 2), 1413398077],
#   [datetime.datetime(2013, 9, 8, 7, 26, 2), 1440475723],
#   [datetime.datetime(2013, 9, 9, 7, 26, 2), 1410546093],
#   [datetime.datetime(2013, 9, 10, 7, 26, 1), 1485885525],
#   [datetime.datetime(2013, 9, 11, 7, 26, 2), 1441952016],
#   [datetime.datetime(2013, 9, 12, 7, 26, 2), 1571991468],
#   [datetime.datetime(2013, 9, 13, 7, 26, 1), 1593705850],
#   [datetime.datetime(2013, 9, 14, 7, 26, 2), 1551266086],
#   [datetime.datetime(2013, 9, 15, 7, 26, 2), 1505159472],
#   [datetime.datetime(2013, 9, 16, 7, 26, 1), 1528329267],
#   [datetime.datetime(2013, 9, 17, 7, 26, 1), 1482235956],
#   [datetime.datetime(2013, 9, 18, 7, 26, 2), 1531472535],
#   [datetime.datetime(2013, 9, 19, 7, 26, 1), 1535810988],
#   [datetime.datetime(2013, 9, 20, 7, 26, 2), 1521198731],
#   [datetime.datetime(2013, 9, 21, 7, 26, 2), 1495076509],
#   [datetime.datetime(2013, 9, 22, 7, 26, 2), 1493833260],
#   [datetime.datetime(2013, 9, 23, 7, 26, 1), 1507154161],
#   [datetime.datetime(2013, 9, 24, 7, 26, 2), 1484371556],
#   [datetime.datetime(2013, 9, 25, 7, 26, 2), 1513805580],
#   [datetime.datetime(2013, 9, 26, 7, 26, 1), 1515403031],
#   [datetime.datetime(2013, 9, 27, 7, 26, 2), 1530763838],
#   [datetime.datetime(2013, 9, 28, 7, 26, 2), 1584338266],
#   [datetime.datetime(2013, 9, 29, 7, 26, 2), 1629791825],
#   [datetime.datetime(2013, 9, 30, 7, 36, 1), 1583038043],
#   [datetime.datetime(2013, 10, 1, 7, 41, 1), 1577869589],
#   [datetime.datetime(2013, 10, 2, 7, 41, 2), 1550425024],
#   [datetime.datetime(2013, 10, 3, 7, 41, 2), 1432992865],
#   [datetime.datetime(2013, 10, 4, 9, 16, 11), 1484790258],
#   [datetime.datetime(2013, 10, 5, 9, 16, 9), 1522400010],
#   [datetime.datetime(2013, 10, 6, 9, 16, 11), 1519707024],
#   [datetime.datetime(2013, 10, 7, 9, 16, 3), 1528242935],
#   [datetime.datetime(2013, 10, 8, 9, 16, 1), 1489210920],
#   [datetime.datetime(2013, 10, 9, 9, 31, 2), 1504666389],
#   [datetime.datetime(2013, 10, 10, 9, 31, 2), 1549185570],
#   [datetime.datetime(2013, 10, 11, 9, 31, 2), 1539049795],
#   [datetime.datetime(2013, 10, 12, 9, 31, 3), 1574653436],
#   [datetime.datetime(2013, 10, 13, 9, 31, 9), 1592076330],
#   [datetime.datetime(2013, 10, 14, 9, 31, 2), 1657780162],
#   [datetime.datetime(2013, 10, 15, 9, 31, 1), 1653892914],
#   [datetime.datetime(2013, 10, 16, 9, 31, 2), 1798515348],
#   [datetime.datetime(2013, 10, 17, 9, 31, 3), 1708762041],
#   [datetime.datetime(2013, 10, 18, 9, 31, 5), 1737727200],
#   [datetime.datetime(2013, 10, 19, 9, 31, 2), 1936429199],
#   [datetime.datetime(2013, 10, 20, 10, 16, 2), 2055254041],
#   [datetime.datetime(2013, 10, 21, 10, 16, 5), 2116153256],
#   [datetime.datetime(2013, 10, 22, 10, 16, 2), 2289446235],
#   [datetime.datetime(2013, 10, 23, 10, 21, 2), 2318122872],
#   [datetime.datetime(2013, 10, 24, 10, 26, 2), 2263880095],
#   [datetime.datetime(2013, 10, 25, 10, 26, 1), 2208910112],
#   [datetime.datetime(2013, 10, 26, 10, 26, 12), 2205330408],
#   [datetime.datetime(2013, 10, 27, 9, 26, 2), 2170590240],
#   [datetime.datetime(2013, 10, 28, 9, 26, 2), 2332560505],
#   [datetime.datetime(2013, 10, 29, 9, 31, 1), 2383514169],
#   [datetime.datetime(2013, 10, 30, 9, 31, 1), 2411927532],
#   [datetime.datetime(2013, 10, 31, 11, 6, 1), 2400527163],
#   [datetime.datetime(2013, 11, 1, 11, 6, 3), 2430860520],
#   [datetime.datetime(2013, 11, 2, 11, 16, 2), 2472401796],
#   [datetime.datetime(2013, 11, 3, 11, 16, 2), 2448338589],
#   [datetime.datetime(2013, 11, 4, 11, 11, 2), 2586286560],
#   [datetime.datetime(2013, 11, 5, 11, 11, 10), 2753961102],
#   [datetime.datetime(2013, 11, 6, 11, 16, 2), 3070437192],
#   [datetime.datetime(2013, 11, 7, 11, 16, 3), 3518670692],
#   [datetime.datetime(2013, 11, 8, 11, 16, 2), 3825919011],
#   [datetime.datetime(2013, 11, 9, 11, 16, 1), 4228079278],
#   [datetime.datetime(2013, 11, 10, 11, 16, 2), 3779710352],
#   [datetime.datetime(2013, 11, 11, 11, 16, 2), 3980634680],
#   [datetime.datetime(2013, 11, 12, 11, 16, 2), 4328310772],
#   [datetime.datetime(2013, 11, 13, 11, 16, 2), 4493672638],
#   [datetime.datetime(2013, 11, 14, 11, 26, 2), 4897827984],
#   [datetime.datetime(2013, 11, 15, 11, 26, 2), 5132926869],
#   [datetime.datetime(2013, 11, 16, 11, 31, 2), 5294532600],
#   [datetime.datetime(2013, 11, 17, 11, 36, 2), 5625255681],
#   [datetime.datetime(2013, 11, 18, 11, 36, 2), 6705789430],
#   [datetime.datetime(2013, 11, 19, 11, 36, 3), 8103857471],
#   [datetime.datetime(2013, 11, 20, 11, 36, 2), 5798258526],
#   [datetime.datetime(2013, 11, 21, 11, 46, 2), 7456358841],
#   [datetime.datetime(2013, 11, 22, 11, 51, 2), 8790506777],
#   [datetime.datetime(2013, 11, 23, 22, 46, 2), 9730337944],
#   [datetime.datetime(2013, 11, 24, 22, 46, 1), 9349295648],
#   [datetime.datetime(2013, 11, 25, 23, 51, 2), 9529002102],
#   [datetime.datetime(2013, 11, 26, 23, 51, 2), 10946018925],
#   [datetime.datetime(2013, 11, 27, 23, 46, 3), 11850638474],
#   [datetime.datetime(2013, 11, 28, 23, 46, 1), 12426552940],
#   [datetime.datetime(2013, 11, 30, 2, 46, 1), 13853313627],
#   [datetime.datetime(2013, 12, 1, 2, 51, 1), 13541896415],
#   [datetime.datetime(2013, 12, 2, 2, 51, 1), 12038665194],
#   [datetime.datetime(2013, 12, 3, 2, 56, 1), 12438459202],
#   [datetime.datetime(2013, 12, 4, 3, 11, 2), 13004931455],
#   [datetime.datetime(2013, 12, 5, 3, 26, 2), 13613383537],
#   [datetime.datetime(2013, 12, 6, 3, 56, 1), 12117660075],
#   [datetime.datetime(2013, 12, 7, 4, 16, 2), 9250920298],
#   [datetime.datetime(2013, 12, 8, 4, 41, 1), 8397879080],
#   [datetime.datetime(2013, 12, 9, 4, 41, 2), 10135632177],
#   [datetime.datetime(2013, 12, 10, 4, 51, 2), 11155612005],
#   [datetime.datetime(2013, 12, 11, 5, 16, 1), 11596135176],
#   [datetime.datetime(2013, 12, 12, 5, 16, 1), 10329286823],
#   [datetime.datetime(2013, 12, 13, 5, 31, 1), 10978301748],
#   [datetime.datetime(2013, 12, 14, 5, 31, 2), 10820630864],
#   [datetime.datetime(2013, 12, 15, 5, 56, 1), 10307643675],
#   [datetime.datetime(2013, 12, 16, 6, 6, 1), 10539143353],
#   [datetime.datetime(2013, 12, 17, 6, 11, 2), 8119114562],
#   [datetime.datetime(2013, 12, 18, 6, 16, 2), 7818203456],
#   [datetime.datetime(2013, 12, 19, 6, 21, 1), 6802839701],
#   [datetime.datetime(2013, 12, 20, 6, 31, 1), 8650071000],
#   [datetime.datetime(2013, 12, 21, 6, 41, 1), 7757993944],
#   [datetime.datetime(2013, 12, 22, 6, 41, 2), 7412626262],
#   [datetime.datetime(2013, 12, 23, 6, 46, 1), 7846531378],
#   [datetime.datetime(2013, 12, 24, 6, 46, 1), 8169016070],
#   [datetime.datetime(2013, 12, 25, 6, 46, 1), 7968482544],
#   [datetime.datetime(2013, 12, 26, 6, 46, 2), 8448510379],
#   [datetime.datetime(2013, 12, 27, 6, 56, 1), 8968234621],
#   [datetime.datetime(2013, 12, 28, 6, 56, 1), 8891737240],
#   [datetime.datetime(2013, 12, 29, 7, 1, 2), 8769072171],
#   [datetime.datetime(2013, 12, 30, 7, 46, 2), 9176209842],
#   [datetime.datetime(2013, 12, 31, 8, 16, 1), 9114650721],
#   [datetime.datetime(2014, 1, 1, 8, 16, 1), 9375027519],
#   [datetime.datetime(2014, 1, 2, 8, 16, 2), 9400260663],
#   [datetime.datetime(2014, 1, 3, 8, 16, 2), 9777538842],
#   [datetime.datetime(2014, 1, 4, 8, 16, 2), 9872620257],
#   [datetime.datetime(2014, 1, 5, 8, 16, 1), 10533192293],
#   [datetime.datetime(2014, 1, 6, 8, 16, 2), 11895294512],
#   [datetime.datetime(2014, 1, 7, 13, 26, 1), 11238639912],
#   [datetime.datetime(2014, 1, 8, 13, 26, 2), 10489937497],
#   [datetime.datetime(2014, 1, 9, 13, 26, 1), 10291198407],
#   [datetime.datetime(2014, 1, 10, 13, 26, 1), 10235909453],
#   [datetime.datetime(2014, 1, 11, 13, 26, 1), 11120838747],
#   [datetime.datetime(2014, 1, 12, 13, 26, 1), 10579385547],
#   [datetime.datetime(2014, 1, 13, 13, 26, 2), 10236131169],
#   [datetime.datetime(2014, 1, 14, 13, 26, 2), 10257005161],
#   [datetime.datetime(2014, 1, 15, 13, 26, 2), 10586901588],
#   [datetime.datetime(2014, 1, 16, 14, 31, 2), 10466816554],
#   [datetime.datetime(2014, 1, 17, 14, 41, 2), 10118464372],
#   [datetime.datetime(2014, 1, 18, 14, 41, 2), 10293545616],
#   [datetime.datetime(2014, 1, 19, 15, 11, 2), 10240441312],
#   [datetime.datetime(2014, 1, 20, 15, 11, 2), 10634404659],
#   [datetime.datetime(2014, 1, 21, 15, 16, 2), 10660106725],
#   [datetime.datetime(2014, 1, 22, 18, 21, 2), 10407022515],
#   [datetime.datetime(2014, 1, 23, 18, 31, 2), 10192103437],
#   [datetime.datetime(2014, 1, 24, 18, 31, 2), 9875571598],
#   [datetime.datetime(2014, 1, 25, 18, 31, 2), 10468361227],
#   [datetime.datetime(2014, 1, 26, 18, 31, 2), 10966151300],
#   [datetime.datetime(2014, 1, 27, 21, 31, 2), 9896706963],
#   [datetime.datetime(2014, 1, 28, 21, 36, 2), 10030077450],
#   [datetime.datetime(2014, 1, 29, 21, 51, 2), 10174460328],
#   [datetime.datetime(2014, 1, 30, 21, 51, 2), 10105458986],
#   [datetime.datetime(2014, 1, 31, 21, 51, 2), 10153617765],
#   [datetime.datetime(2014, 2, 1, 21, 51, 2), 10391760101],
#   [datetime.datetime(2014, 2, 2, 21, 51, 2), 10241496932],
#   [datetime.datetime(2014, 2, 3, 21, 56, 2), 10117201297],
#   [datetime.datetime(2014, 2, 4, 22, 31, 2), 10268668985],
#   [datetime.datetime(2014, 2, 5, 22, 36, 2), 10152548463],
#   [datetime.datetime(2014, 2, 6, 22, 36, 3), 9682805649],
#   [datetime.datetime(2014, 2, 7, 22, 36, 5), 8977470788],
#   [datetime.datetime(2014, 2, 8, 22, 36, 5), 8503248112],
#   [datetime.datetime(2014, 2, 9, 22, 41, 2), 8568588480],
#   [datetime.datetime(2014, 2, 10, 22, 46, 2), 8273521358],
#   [datetime.datetime(2014, 2, 11, 23, 1, 13), 7902678666],
#   [datetime.datetime(2014, 2, 13, 4, 6, 2), 8103210317],
#   [datetime.datetime(2014, 2, 14, 4, 6, 7), 6981872578],
#   [datetime.datetime(2014, 2, 15, 4, 11, 13), 7991142081],
#   [datetime.datetime(2014, 2, 16, 4, 11, 10), 8166740022],
#   [datetime.datetime(2014, 2, 17, 4, 21, 22), 7645657217],
#   [datetime.datetime(2014, 2, 18, 4, 21, 45), 7963598356],
#   [datetime.datetime(2014, 2, 19, 4, 26, 2), 7763582295],
#   [datetime.datetime(2014, 2, 20, 4, 31, 2), 7765481646],
#   [datetime.datetime(2014, 2, 21, 4, 41, 22), 6824404453],
#   [datetime.datetime(2014, 2, 22, 4, 46, 2), 7053173750],
#   [datetime.datetime(2014, 2, 23, 4, 46, 2), 7630472818],
#   [datetime.datetime(2014, 2, 24, 4, 46, 2), 7195562323],
#   [datetime.datetime(2014, 2, 25, 4, 46, 2), 6195879609],
#   [datetime.datetime(2014, 2, 26, 5, 36, 9), 7013767152],
#   [datetime.datetime(2014, 2, 27, 5, 51, 2), 7239905721],
#   [datetime.datetime(2014, 2, 28, 5, 56, 2), 7115937422],
#   [datetime.datetime(2014, 3, 1, 6, 6, 2), 6955268689],
#   [datetime.datetime(2014, 3, 2, 6, 6, 5), 6992425456],
#   [datetime.datetime(2014, 3, 3, 6, 6, 2), 7150284539],
#   [datetime.datetime(2014, 3, 4, 7, 6, 23), 8257065652],
#   [datetime.datetime(2014, 3, 5, 9, 6, 1), 8280089523],
#   [datetime.datetime(2014, 3, 6, 9, 41, 1), 8267403750],
#   [datetime.datetime(2014, 3, 7, 9, 51, 23), 8179264894],
#   [datetime.datetime(2014, 3, 8, 9, 56, 2), 7766677880],
#   [datetime.datetime(2014, 3, 9, 9, 56, 2), 7774864760],
#   [datetime.datetime(2014, 3, 10, 9, 56, 21), 7987727962],
#   [datetime.datetime(2014, 3, 11, 9, 56, 2), 7883390766],
#   [datetime.datetime(2014, 3, 12, 9, 56, 2), 7948515121],
#   [datetime.datetime(2014, 3, 13, 9, 56, 2), 8003678580],
#   [datetime.datetime(2014, 3, 14, 10, 31, 2), 7923870033],
#   [datetime.datetime(2014, 3, 15, 10, 31, 2), 7908582117],
#   [datetime.datetime(2014, 3, 16, 10, 31, 2), 7943849911],
#   [datetime.datetime(2014, 3, 17, 10, 31, 2), 7794370518],
#   [datetime.datetime(2014, 3, 18, 10, 31, 2), 7729983328],
#   [datetime.datetime(2014, 3, 19, 10, 41, 17), 7732059879],
#   [datetime.datetime(2014, 3, 20, 10, 41, 2), 7568383029],
#   [datetime.datetime(2014, 3, 21, 10, 36, 2), 7531941604],
#   [datetime.datetime(2014, 3, 22, 10, 36, 3), 7096672519],
#   [datetime.datetime(2014, 3, 23, 10, 36, 2), 7116284105],
#   [datetime.datetime(2014, 3, 24, 10, 46, 2), 6983197243],
#   [datetime.datetime(2014, 3, 25, 10, 46, 3), 7197165743],
#   [datetime.datetime(2014, 3, 26, 13, 46, 2), 7343002343],
#   [datetime.datetime(2014, 3, 27, 19, 26, 1), 6564587596],
#   [datetime.datetime(2014, 3, 28, 21, 41, 2), 6177467010],
#   [datetime.datetime(2014, 3, 30, 4, 11, 2), 6108104221],
#   [datetime.datetime(2014, 3, 31, 4, 46, 2), 5995761080],
#   [datetime.datetime(2014, 4, 1, 4, 46, 2), 5772747763],
#   [datetime.datetime(2014, 4, 2, 5, 16, 2), 6062248781],
#   [datetime.datetime(2014, 4, 3, 5, 41, 3), 5381332964],
#   [datetime.datetime(2014, 4, 4, 5, 46, 2), 5505654176],
#   [datetime.datetime(2014, 4, 5, 5, 46, 2), 5698723917],
#   [datetime.datetime(2014, 4, 6, 5, 46, 2), 5856585232],
#   [datetime.datetime(2014, 4, 7, 5, 46, 2), 5746822291],
#   [datetime.datetime(2014, 4, 8, 5, 46, 2), 5718542737],
#   [datetime.datetime(2014, 4, 9, 6, 11, 3), 5738904084],
#   [datetime.datetime(2014, 4, 10, 6, 16, 2), 5400810410],
#   [datetime.datetime(2014, 4, 11, 6, 16, 3), 4823150267],
#   [datetime.datetime(2014, 4, 12, 6, 16, 3), 5535166815],
#   [datetime.datetime(2014, 4, 13, 6, 16, 2), 5370397396],
#   [datetime.datetime(2014, 4, 14, 6, 16, 2), 5176894908],
#   [datetime.datetime(2014, 4, 15, 6, 26, 2), 5759489398],
#   [datetime.datetime(2014, 4, 16, 6, 46, 2), 6524134861],
#   [datetime.datetime(2014, 4, 17, 6, 51, 2), 6575226952],
#   [datetime.datetime(2014, 4, 18, 7, 1, 2), 6252223023],
#   [datetime.datetime(2014, 4, 19, 7, 1, 2), 5975968814],
#   [datetime.datetime(2014, 4, 20, 7, 1, 2), 6393006503],
#   [datetime.datetime(2014, 4, 21, 7, 1, 3), 6435488891],
#   [datetime.datetime(2014, 4, 22, 7, 6, 2), 6322029639],
#   [datetime.datetime(2014, 4, 23, 7, 6, 2), 6226287188],
#   [datetime.datetime(2014, 4, 24, 7, 41, 2), 6195771518],
#   [datetime.datetime(2014, 4, 25, 8, 31, 4), 5790307676],
#   [datetime.datetime(2014, 4, 26, 8, 46, 2), 5733379123],
#   [datetime.datetime(2014, 4, 27, 9, 11, 2), 5788410979],
#   [datetime.datetime(2014, 4, 28, 9, 36, 2), 5407456652],
#   [datetime.datetime(2014, 4, 29, 14, 16, 2), 5685695339],
#   [datetime.datetime(2014, 4, 30, 17, 26, 2), 5673077338],
#   [datetime.datetime(2014, 5, 1, 17, 26, 3), 5731664211],
#   [datetime.datetime(2014, 5, 2, 17, 26, 2), 5666988895],
#   [datetime.datetime(2014, 5, 3, 17, 26, 5), 5610505365],
#   [datetime.datetime(2014, 5, 4, 17, 26, 5), 5517588612],
#   [datetime.datetime(2014, 5, 5, 17, 26, 6), 5473840871],
#   [datetime.datetime(2014, 5, 6, 18, 1, 5), 5487874929],
#   [datetime.datetime(2014, 5, 7, 18, 1, 7), 5607924965],
#   [datetime.datetime(2014, 5, 8, 18, 1, 20), 5626345356],
#   [datetime.datetime(2014, 5, 9, 18, 41, 16), 5741033790],
#   [datetime.datetime(2014, 5, 10, 18, 41, 6), 5754552853],
#   [datetime.datetime(2014, 5, 11, 18, 41, 7), 5528484826],
#   [datetime.datetime(2014, 5, 12, 18, 41, 10), 5630703159],
#   [datetime.datetime(2014, 5, 13, 18, 41, 13), 5614371662],
#   [datetime.datetime(2014, 5, 14, 18, 51, 16), 5673690624],
#   [datetime.datetime(2014, 5, 15, 18, 51, 7), 5724581374],
#   [datetime.datetime(2014, 5, 16, 18, 51, 10), 5730560632],
#   [datetime.datetime(2014, 5, 17, 18, 51, 6), 5724920041],
#   [datetime.datetime(2014, 5, 18, 18, 51, 8), 5716510660],
#   [datetime.datetime(2014, 5, 19, 18, 51, 17), 5692061490],
#   [datetime.datetime(2014, 5, 20, 18, 51, 15), 6183365788],
#   [datetime.datetime(2014, 5, 21, 19, 6, 17), 6298351579],
#   [datetime.datetime(2014, 5, 22, 19, 6, 20), 6609931274],
#   [datetime.datetime(2014, 5, 23, 19, 6, 9), 6700336553],
#   [datetime.datetime(2014, 5, 25, 7, 56, 6), 7115204096],
#   [datetime.datetime(2014, 5, 26, 7, 56, 10), 7521273634],
#   [datetime.datetime(2014, 5, 27, 8, 41, 13), 7497455615],
#   [datetime.datetime(2014, 5, 28, 8, 41, 5), 7382028997],
#   [datetime.datetime(2014, 5, 29, 8, 41, 16), 7269497761],
#   [datetime.datetime(2014, 5, 30, 8, 56, 7), 7305732162],
#   [datetime.datetime(2014, 5, 31, 8, 56, 7), 7920661529],
#   [datetime.datetime(2014, 6, 1, 8, 56, 13), 8325584400],
#   [datetime.datetime(2014, 6, 2, 8, 56, 6), 8004231903],
#   [datetime.datetime(2014, 6, 3, 8, 56, 7), 8443853248],
#   [datetime.datetime(2014, 6, 4, 8, 56, 6), 8213918062],
#   [datetime.datetime(2014, 6, 5, 9, 41, 6), 8306258433],
#   [datetime.datetime(2014, 6, 6, 9, 41, 5), 8453788890],
#   [datetime.datetime(2014, 6, 7, 9, 41, 7), 8398066511],
#   [datetime.datetime(2014, 6, 8, 9, 41, 6), 8461802884],
#   [datetime.datetime(2014, 6, 9, 9, 41, 6), 8332939692],
#   [datetime.datetime(2014, 6, 10, 9, 41, 5), 8472890038],
#   [datetime.datetime(2014, 6, 11, 9, 41, 9), 8374495671],
#   [datetime.datetime(2014, 6, 12, 10, 26, 6), 8202725168],
#   [datetime.datetime(2014, 6, 13, 10, 26, 9), 7874556522],
#   [datetime.datetime(2014, 6, 14, 10, 26, 7), 7540155635],
#   [datetime.datetime(2014, 6, 15, 10, 26, 7), 7215495816],
#   [datetime.datetime(2014, 6, 16, 10, 26, 7), 7737782349],
#   [datetime.datetime(2014, 6, 17, 10, 26, 11), 7698607587],
#   [datetime.datetime(2014, 6, 18, 10, 26, 8), 7907048530],
#   [datetime.datetime(2014, 6, 19, 10, 26, 7), 7879526986],
#   [datetime.datetime(2014, 6, 20, 10, 26, 8), 7615404520],
#   [datetime.datetime(2014, 6, 21, 10, 26, 7), 7648148389],
#   [datetime.datetime(2014, 6, 22, 10, 26, 10), 7816412859],
#   [datetime.datetime(2014, 6, 23, 10, 26, 7), 7678243878],
#   [datetime.datetime(2014, 6, 24, 11, 31, 6), 7688879009],
#   [datetime.datetime(2014, 6, 25, 13, 1, 15), 7398086370],
#   [datetime.datetime(2014, 6, 26, 22, 6, 10), 7423820740],
#   [datetime.datetime(2014, 6, 27, 23, 11, 7), 7577314829],
#   [datetime.datetime(2014, 6, 29, 8, 46, 12), 7788118206],
#   [datetime.datetime(2014, 6, 30, 10, 21, 39), 8122165800],
#   [datetime.datetime(2014, 7, 1, 10, 21, 12), 8486436757],
#   [datetime.datetime(2014, 7, 2, 15, 21, 13), 8372715704],
#   [datetime.datetime(2014, 7, 3, 19, 16, 8), 8371823420],
#   [datetime.datetime(2014, 7, 5, 3, 21, 11), 8200025844],
#   [datetime.datetime(2014, 7, 6, 19, 6, 11), 8244355335],
#   [datetime.datetime(2014, 7, 8, 12, 24), 8082395595],
#   [datetime.datetime(2014, 7, 9, 16, 14), 8116882102],
#   [datetime.datetime(2014, 7, 10, 16, 14), 7986870811],
#   [datetime.datetime(2014, 7, 11, 16, 14), 8183210066],
#   [datetime.datetime(2014, 7, 12, 16, 14), 8177509169],
#   [datetime.datetime(2014, 7, 13, 16, 14), 8186803751],
#   [datetime.datetime(2014, 7, 14, 16, 14), 8070258638],
#   [datetime.datetime(2014, 7, 15, 16, 14), 8122773091],
#   [datetime.datetime(2014, 7, 16, 16, 14), 8032529722],
#   [datetime.datetime(2014, 7, 17, 16, 14), 8078882611],
#   [datetime.datetime(2014, 7, 18, 16, 14), 8092787472],
#   [datetime.datetime(2014, 7, 19, 16, 14), 8188922459],
#   [datetime.datetime(2014, 7, 20, 16, 14), 8151474297],
#   [datetime.datetime(2014, 7, 21, 16, 14), 8094123825],
#   [datetime.datetime(2014, 7, 22, 16, 24), 8116705702],
#   [datetime.datetime(2014, 7, 23, 16, 24), 8130867361],
#   [datetime.datetime(2014, 7, 24, 16, 24), 7849214803],
#   [datetime.datetime(2014, 7, 25, 16, 24), 7859391788],
#   [datetime.datetime(2014, 7, 26, 16, 24), 7809989668],
#   [datetime.datetime(2014, 7, 27, 16, 24), 7809272562],
#   [datetime.datetime(2014, 7, 28, 17, 24), 7612339560],
#   [datetime.datetime(2014, 7, 29, 17, 24), 7631643297],
#   [datetime.datetime(2014, 7, 30, 19, 4), 7544687880],
#   [datetime.datetime(2014, 7, 31, 19, 4), 7660237144],
#   [datetime.datetime(2014, 8, 1, 19, 24), 7814990816],
#   [datetime.datetime(2014, 8, 2, 19, 54), 7712307360],
#   [datetime.datetime(2014, 8, 3, 19, 54), 7681992598],
#   [datetime.datetime(2014, 8, 4, 19, 54), 7725064932],
#   [datetime.datetime(2014, 8, 5, 19, 54), 7684065312],
#   [datetime.datetime(2014, 8, 6, 19, 54), 7689070836],
#   [datetime.datetime(2014, 8, 7, 19, 54), 7730980003],
#   [datetime.datetime(2014, 8, 8, 19, 54), 7778019496],
#   [datetime.datetime(2014, 8, 9, 19, 54), 7733676906],
#   [datetime.datetime(2014, 8, 10, 19, 54), 7747817534],
#   [datetime.datetime(2014, 8, 11, 19, 54), 7620587697],
#   [datetime.datetime(2014, 8, 12, 19, 54), 7479211448],
#   [datetime.datetime(2014, 8, 13, 19, 54), 7089371399],
#   [datetime.datetime(2014, 8, 14, 19, 54), 6788369159],
#   [datetime.datetime(2014, 8, 15, 19, 54), 6486612775],
#   [datetime.datetime(2014, 8, 16, 19, 54), 6657817457],
#   [datetime.datetime(2014, 8, 17, 19, 54), 6472897218],
#   [datetime.datetime(2014, 8, 18, 19, 54), 6052765876],
#   [datetime.datetime(2014, 8, 19, 19, 54), 6284411752],
#   [datetime.datetime(2014, 8, 20, 19, 54), 6636746619],
#   [datetime.datetime(2014, 8, 21, 19, 54), 6915078697],
#   [datetime.datetime(2014, 8, 22, 19, 54), 6819752408],
#   [datetime.datetime(2014, 8, 23, 19, 54), 6605512916],
#   [datetime.datetime(2014, 8, 24, 19, 54), 6741579651],
#   [datetime.datetime(2014, 8, 25, 19, 54), 6624449236],
#   [datetime.datetime(2014, 8, 26, 19, 54), 6751116840],
#   [datetime.datetime(2014, 8, 27, 19, 54), 6758242708],
#   [datetime.datetime(2014, 8, 28, 19, 54), 6705996985],
#   [datetime.datetime(2014, 8, 29, 19, 54), 6738232487],
#   [datetime.datetime(2014, 8, 30, 19, 54), 6663734161],
#   [datetime.datetime(2014, 8, 31, 19, 54), 6278177305],
#   [datetime.datetime(2014, 9, 1, 19, 54), 6367932182],
#   [datetime.datetime(2014, 9, 2, 20, 4), 6380356629],
#   [datetime.datetime(2014, 9, 3, 20, 4), 6309823001],
#   [datetime.datetime(2014, 9, 4, 20, 4), 6457360244],
#   [datetime.datetime(2014, 9, 5, 20, 4), 6413157070],
#   [datetime.datetime(2014, 9, 6, 20, 4), 6453564668],
#   [datetime.datetime(2014, 9, 7, 20, 4), 6428513158],
#   [datetime.datetime(2014, 9, 8, 20, 24), 6343771471],
#   [datetime.datetime(2014, 9, 9, 20, 24), 6253035610],
#   [datetime.datetime(2014, 9, 10, 20, 24), 6421968408],
#   [datetime.datetime(2014, 9, 11, 20, 24), 6290813167],
#   [datetime.datetime(2014, 9, 12, 20, 24), 6312730888],
#   [datetime.datetime(2014, 9, 13, 20, 24), 6376536644],
#   [datetime.datetime(2014, 9, 14, 20, 24), 6337916584],
#   [datetime.datetime(2014, 9, 15, 20, 24), 6327753377],
#   [datetime.datetime(2014, 9, 16, 20, 24), 6236932009],
#   [datetime.datetime(2014, 9, 17, 20, 24), 6027243652],
#   [datetime.datetime(2014, 9, 18, 20, 24), 5649055634],
#   [datetime.datetime(2014, 9, 19, 20, 23, 59), 5301224275],
#   [datetime.datetime(2014, 9, 20, 20, 24), 5488274967],
#   [datetime.datetime(2014, 9, 21, 20, 24), 5349780133],
#   [datetime.datetime(2014, 9, 22, 20, 23, 59), 5349470436],
#   [datetime.datetime(2014, 9, 23, 20, 24), 5786438777],
#   [datetime.datetime(2014, 9, 24, 20, 33, 59), 5708169478],
#   [datetime.datetime(2014, 9, 25, 20, 33, 59), 5466497281],
#   [datetime.datetime(2014, 9, 26, 20, 34), 5389223696],
#   [datetime.datetime(2014, 9, 27, 20, 34), 5306694358],
#   [datetime.datetime(2014, 9, 28, 20, 33, 59), 5078204546],
#   [datetime.datetime(2014, 9, 29, 20, 33, 59), 5081242480],
#   [datetime.datetime(2014, 9, 30, 20, 33, 59), 5119427674],
#   [datetime.datetime(2014, 10, 2, 8, 39), 5127402572],
#   [datetime.datetime(2014, 10, 3, 8, 38, 59), 5019403319],
#   [datetime.datetime(2014, 10, 4, 9, 44), 4785192805],
#   [datetime.datetime(2014, 10, 5, 9, 44), 4379135932],
#   [datetime.datetime(2014, 10, 6, 9, 44), 4291300659],
#   [datetime.datetime(2014, 10, 7, 9, 44), 4366348702],
#   [datetime.datetime(2014, 10, 8, 9, 44), 4451575734],
#   [datetime.datetime(2014, 10, 9, 9, 44, 5), 4771503789],
#   [datetime.datetime(2014, 10, 10, 9, 44), 4961717589],
#   [datetime.datetime(2014, 10, 11, 9, 44), 4841471420],
#   [datetime.datetime(2014, 10, 12, 9, 44), 4828147412],
#   [datetime.datetime(2014, 10, 13, 9, 44), 4985678637],
#   [datetime.datetime(2014, 10, 14, 9, 44), 5418971888],
#   [datetime.datetime(2014, 10, 15, 9, 44), 5328846153],
#   [datetime.datetime(2014, 10, 16, 9, 44), 5265674038],
#   [datetime.datetime(2014, 10, 17, 9, 49), 5137917706],
#   [datetime.datetime(2014, 10, 18, 9, 49), 5105109931],
#   [datetime.datetime(2014, 10, 19, 9, 49), 5264196242],
#   [datetime.datetime(2014, 10, 20, 9, 49), 5134201081],
#   [datetime.datetime(2014, 10, 21, 9, 49), 5155910228],
#   [datetime.datetime(2014, 10, 22, 9, 49), 5188468568],
#   [datetime.datetime(2014, 10, 23, 9, 49), 5000114789],
#   [datetime.datetime(2014, 10, 24, 9, 49), 4821642992],
#   [datetime.datetime(2014, 10, 25, 9, 49), 4748461382],
#   [datetime.datetime(2014, 10, 26, 8, 49), 4741037489],
#   [datetime.datetime(2014, 10, 27, 8, 49), 4733130351],
#   [datetime.datetime(2014, 10, 28, 8, 49), 4801110716],
#   [datetime.datetime(2014, 10, 29, 8, 49), 4799952434],
#   [datetime.datetime(2014, 10, 30, 8, 49), 4569673152],
#   [datetime.datetime(2014, 10, 31, 8, 49, 2), 4645027482],
#   [datetime.datetime(2014, 11, 1, 9, 24), 4427422040],
#   [datetime.datetime(2014, 11, 2, 10, 24), 4372078851],
#   [datetime.datetime(2014, 11, 3, 10, 24), 4449114450],
#   [datetime.datetime(2014, 11, 4, 10, 24), 4391372099],
#   [datetime.datetime(2014, 11, 5, 10, 24), 4533581386],
#   [datetime.datetime(2014, 11, 6, 10, 24), 4584887384],
#   [datetime.datetime(2014, 11, 7, 10, 24), 4683921008],
#   [datetime.datetime(2014, 11, 8, 10, 24), 4629267445],
#   [datetime.datetime(2014, 11, 9, 10, 24), 4706558009],
#   [datetime.datetime(2014, 11, 10, 10, 24), 4853718859],
#   [datetime.datetime(2014, 11, 11, 10, 24), 4961414266],
#   [datetime.datetime(2014, 11, 12, 10, 24), 5108311016],
#   [datetime.datetime(2014, 11, 13, 10, 24), 5914680527],
#   [datetime.datetime(2014, 11, 14, 10, 24), 5196704404],
#   [datetime.datetime(2014, 11, 15, 10, 24), 5335673913],
#   [datetime.datetime(2014, 11, 16, 10, 24), 5224946837],
#   [datetime.datetime(2014, 11, 17, 10, 24), 5535651238],
#   [datetime.datetime(2014, 11, 18, 10, 24), 5186840088],
#   [datetime.datetime(2014, 11, 19, 10, 24), 5183709300],
#   [datetime.datetime(2014, 11, 20, 10, 24), 4934113776],
#   [datetime.datetime(2014, 11, 21, 10, 24), 4775347316],
#   [datetime.datetime(2014, 11, 22, 10, 24), 4851718884],
#   [datetime.datetime(2014, 11, 23, 10, 24), 4831481373],
#   [datetime.datetime(2014, 11, 24, 10, 24), 5069710284],
#   [datetime.datetime(2014, 11, 25, 10, 24), 5323052593],
#   [datetime.datetime(2014, 11, 26, 10, 34), 4998261122],
#   [datetime.datetime(2014, 11, 27, 10, 34), 5043398583],
#   [datetime.datetime(2014, 11, 28, 10, 34), 4921394189],
#   [datetime.datetime(2014, 11, 29, 10, 34), 5135280662],
#   [datetime.datetime(2014, 11, 30, 10, 34), 5165277474],
#   [datetime.datetime(2014, 12, 1, 10, 34), 5152575062],
#   [datetime.datetime(2014, 12, 2, 10, 34), 5167497278],
#   [datetime.datetime(2014, 12, 3, 10, 34), 5105225558],
#   [datetime.datetime(2014, 12, 4, 10, 34), 5098196759],
#   [datetime.datetime(2014, 12, 5, 10, 34), 5062365576],
#   [datetime.datetime(2014, 12, 6, 10, 34), 5084317689],
#   [datetime.datetime(2014, 12, 7, 10, 34), 5091085165],
#   [datetime.datetime(2014, 12, 8, 10, 34, 1), 4980925017],
#   [datetime.datetime(2014, 12, 9, 10, 34), 4765826202],
#   [datetime.datetime(2014, 12, 10, 10, 34), 4757842918],
#   [datetime.datetime(2014, 12, 11, 18, 19), 4848542429],
#   [datetime.datetime(2014, 12, 14, 2, 14), 4715148005],
#   [datetime.datetime(2014, 12, 15, 2, 14), 4778612471],
#   [datetime.datetime(2014, 12, 16, 2, 14), 4701943395],
#   [datetime.datetime(2014, 12, 17, 2, 19), 4547100966],
#   [datetime.datetime(2014, 12, 18, 2, 19), 4377434370],
#   [datetime.datetime(2014, 12, 19, 2, 19), 4242268348],
#   [datetime.datetime(2014, 12, 20, 2, 19), 4314356389],
#   [datetime.datetime(2014, 12, 21, 2, 19), 4482512994],
#   [datetime.datetime(2014, 12, 22, 2, 19), 4389948813],
#   [datetime.datetime(2014, 12, 23, 2, 19, 1), 4542880267],
#   [datetime.datetime(2014, 12, 24, 2, 19), 4559253562],
#   [datetime.datetime(2014, 12, 25, 2, 19), 4339886866],
#   [datetime.datetime(2014, 12, 26, 2, 19, 1), 4337524254],
#   [datetime.datetime(2014, 12, 27, 2, 19, 1), 4435289409],
#   [datetime.datetime(2014, 12, 28, 2, 19, 1), 4322830391],
#   [datetime.datetime(2014, 12, 29, 2, 19), 4369189647],
#   [datetime.datetime(2014, 12, 30, 2, 19), 4290788757],
#   [datetime.datetime(2014, 12, 31, 2, 19, 1), 4245280800],
#   [datetime.datetime(2015, 1, 1, 2, 19, 1), 4345601963],
#   [datetime.datetime(2015, 1, 2, 2, 19), 4289287759],
#   [datetime.datetime(2015, 1, 3, 2, 19), 4307374369],
#   [datetime.datetime(2015, 1, 4, 2, 19), 3848549170],
#   [datetime.datetime(2015, 1, 5, 2, 19, 1), 3650984440],
#   [datetime.datetime(2015, 1, 6, 2, 19, 1), 3753949381],
#   [datetime.datetime(2015, 1, 7, 2, 19, 1), 3879255971],
#   [datetime.datetime(2015, 1, 8, 2, 19), 4024290266],
#   [datetime.datetime(2015, 1, 9, 2, 19, 1), 3871292298],
#   [datetime.datetime(2015, 1, 10, 10, 59, 1), 3808946374],
#   [datetime.datetime(2015, 1, 11, 10, 59, 1), 3766686283],
#   [datetime.datetime(2015, 1, 12, 10, 59, 1), 3675616212],
#   [datetime.datetime(2015, 1, 13, 10, 59, 1), 3355188725],
#   [datetime.datetime(2015, 1, 14, 10, 59, 1), 2851633026],
#   [datetime.datetime(2015, 1, 15, 10, 59, 1), 2813068301],
#   [datetime.datetime(2015, 1, 16, 10, 59, 1), 2994329454],
#   [datetime.datetime(2015, 1, 17, 10, 59, 1), 2708756783],
#   [datetime.datetime(2015, 1, 18, 10, 59, 1), 2891839558],
#   [datetime.datetime(2015, 1, 19, 10, 59, 1), 2861871773],
#   [datetime.datetime(2015, 1, 20, 10, 59, 1), 2877924232],
#   [datetime.datetime(2015, 1, 21, 10, 59), 2937610959],
#   [datetime.datetime(2015, 1, 22, 10, 59, 1), 3175391943],
#   [datetime.datetime(2015, 1, 23, 10, 59, 1), 3117289084],
#   [datetime.datetime(2015, 1, 24, 10, 59), 3204386274],
#   [datetime.datetime(2015, 1, 25, 10, 59, 1), 3389816225],
#   [datetime.datetime(2015, 1, 26, 10, 59, 1), 4120903457],
#   [datetime.datetime(2015, 1, 27, 10, 59), 3554872118],
#   [datetime.datetime(2015, 1, 28, 10, 59, 1), 3610527384],
#   [datetime.datetime(2015, 1, 29, 10, 59, 1), 3174116640],
#   [datetime.datetime(2015, 1, 30, 10, 59, 1), 3207876399],
#   [datetime.datetime(2015, 1, 31, 10, 59, 1), 3197785951],
#   [datetime.datetime(2015, 2, 1, 11, 9, 1), 2932754485],
#   [datetime.datetime(2015, 2, 2, 11, 9, 20), 3098862238],
#   [datetime.datetime(2015, 2, 3, 11, 9, 21), 3304247798],
#   [datetime.datetime(2015, 2, 4, 11, 14, 19), 3084186083],
#   [datetime.datetime(2015, 2, 5, 11, 14, 19), 3118027956],
#   [datetime.datetime(2015, 2, 6, 11, 14, 20), 3021929922],
#   [datetime.datetime(2015, 2, 7, 11, 14, 25), 3161297986],
#   [datetime.datetime(2015, 2, 8, 11, 14, 20), 3141965896],
#   [datetime.datetime(2015, 2, 9, 11, 14, 20), 3074677811],
#   [datetime.datetime(2015, 2, 10, 11, 19, 20), 2991226156],
#   [datetime.datetime(2015, 2, 11, 11, 19, 20), 3049515934],
#   [datetime.datetime(2015, 2, 12, 11, 19, 20), 3030286962],
#   [datetime.datetime(2015, 2, 13, 11, 19, 21), 3248286280],
#   [datetime.datetime(2015, 2, 14, 11, 19, 21), 3429086744],
#   [datetime.datetime(2015, 2, 15, 11, 24, 22), 3636040558],
#   [datetime.datetime(2015, 2, 16, 11, 29, 20), 3288133689],
#   [datetime.datetime(2015, 2, 17, 11, 29, 19), 3291510942],
#   [datetime.datetime(2015, 2, 18, 11, 29, 20), 3346731825],
#   [datetime.datetime(2015, 2, 19, 11, 29, 19), 3281224349],
#   [datetime.datetime(2015, 2, 20, 11, 29, 22), 3411751633],
#   [datetime.datetime(2015, 2, 21, 11, 29, 20), 3380093375],
#   [datetime.datetime(2015, 2, 22, 11, 44, 19), 3400132507],
#   [datetime.datetime(2015, 2, 23, 11, 44, 20), 3253406963],
#   [datetime.datetime(2015, 2, 24, 11, 44, 20), 3282405035],
#   [datetime.datetime(2015, 2, 25, 11, 44, 21), 3272446748],
#   [datetime.datetime(2015, 2, 26, 11, 44, 20), 3278060208],
#   [datetime.datetime(2015, 2, 27, 11, 44, 19), 3496113393],
#   [datetime.datetime(2015, 2, 28, 13, 44, 19), 3511637500],
#   [datetime.datetime(2015, 3, 1, 13, 44, 20), 3418854940],
#   [datetime.datetime(2015, 3, 2, 13, 44, 20), 3596686084],
#   [datetime.datetime(2015, 3, 3, 13, 44, 20), 3757039683],
#   [datetime.datetime(2015, 3, 4, 19, 29, 19), 3921472230],
#   [datetime.datetime(2015, 3, 5, 19, 34, 20), 3715418089],
#   [datetime.datetime(2015, 3, 6, 19, 34, 19), 3771089115],
#   [datetime.datetime(2015, 3, 7, 19, 39, 20), 3842565008],
#   [datetime.datetime(2015, 3, 8, 19, 39, 21), 3824308700],
#   [datetime.datetime(2015, 3, 9, 19, 49, 19), 3990421912],
#   [datetime.datetime(2015, 3, 10, 19, 54, 19), 4110333413],
#   [datetime.datetime(2015, 3, 11, 19, 54, 19), 4125292446],
#   [datetime.datetime(2015, 3, 12, 19, 54, 20), 4131676728],
#   [datetime.datetime(2015, 3, 13, 19, 59, 20), 4009506313],
#   [datetime.datetime(2015, 3, 14, 20, 4, 20), 3944860422],
#   [datetime.datetime(2015, 3, 15, 20, 4, 21), 3962828226],
#   [datetime.datetime(2015, 3, 16, 20, 4, 22), 4058871698],
#   [datetime.datetime(2015, 3, 17, 20, 4, 22), 4017292623],
#   [datetime.datetime(2015, 3, 18, 20, 4, 22), 3723705566],
#   [datetime.datetime(2015, 3, 19, 20, 9, 21), 3626492241],
#   [datetime.datetime(2015, 3, 20, 20, 14, 21), 3639131051],
#   [datetime.datetime(2015, 3, 21, 20, 19, 21), 3637526863],
#   [datetime.datetime(2015, 3, 22, 20, 19, 21), 3669968700],
#   [datetime.datetime(2015, 3, 23, 20, 19, 22), 3676053749],
#   [datetime.datetime(2015, 3, 24, 20, 19, 22), 3448861669],
#   [datetime.datetime(2015, 3, 25, 20, 19, 22), 3426432676],
#   [datetime.datetime(2015, 3, 26, 20, 19, 19), 3541436382],
#   [datetime.datetime(2015, 3, 27, 20, 19, 21), 3474922114],
#   [datetime.datetime(2015, 3, 28, 20, 19, 21), 3521673717],
#   [datetime.datetime(2015, 3, 29, 21, 44, 21), 3426239160],
#   [datetime.datetime(2015, 3, 30, 23, 29, 19), 3469694824],
#   [datetime.datetime(2015, 3, 31, 23, 54, 22), 3438997948],
#   [datetime.datetime(2015, 4, 2, 3, 59, 21), 3472729978],
#   [datetime.datetime(2015, 4, 3, 3, 59, 21), 3547549559],
#   [datetime.datetime(2015, 4, 4, 4, 9, 21), 3574913192],
#   [datetime.datetime(2015, 4, 5, 4, 9, 21), 3549704856],
#   [datetime.datetime(2015, 4, 6, 4, 14, 21), 3668097103],
#   [datetime.datetime(2015, 4, 7, 4, 14, 21), 3544201888],
#   [datetime.datetime(2015, 4, 8, 4, 14, 22), 3550136355],
#   [datetime.datetime(2015, 4, 9, 4, 34, 21), 3435976468],
#   [datetime.datetime(2015, 4, 10, 4, 34, 21), 3407562580],
#   [datetime.datetime(2015, 4, 11, 4, 34, 21), 3317215986],
#   [datetime.datetime(2015, 4, 12, 4, 34, 21), 3332846528],
#   [datetime.datetime(2015, 4, 13, 4, 34, 22), 3312552620],
#   [datetime.datetime(2015, 4, 14, 4, 34, 22), 3150265219],
#   [datetime.datetime(2015, 4, 15, 6, 9, 21), 3121110924],
#   [datetime.datetime(2015, 4, 16, 6, 14, 22), 3176590483],
#   [datetime.datetime(2015, 4, 17, 6, 19, 22), 3213681992],
#   [datetime.datetime(2015, 4, 18, 6, 24, 23), 3141396045],
#   [datetime.datetime(2015, 4, 19, 6, 39, 22), 3146724471],
#   [datetime.datetime(2015, 4, 20, 7, 19, 23), 3146493803],
#   [datetime.datetime(2015, 4, 21, 7, 24, 22), 3172533292],
#   [datetime.datetime(2015, 4, 22, 7, 34, 23), 3303065945],
#   [datetime.datetime(2015, 4, 23, 7, 34, 22), 3293427801],
#   [datetime.datetime(2015, 4, 24, 7, 44, 23), 3265078364],
#   [datetime.datetime(2015, 4, 25, 8, 44, 22), 3239046278],
#   [datetime.datetime(2015, 4, 26, 14, 59, 23), 3082924255],
#   [datetime.datetime(2015, 4, 27, 14, 59, 23), 3108026628],
#   [datetime.datetime(2015, 4, 28, 15, 4, 22), 3172247583],
#   [datetime.datetime(2015, 4, 29, 15, 19, 21), 3169000924],
#   [datetime.datetime(2015, 4, 30, 16, 24, 20), 3303850494],
#   [datetime.datetime(2015, 5, 1, 16, 24, 20), 3318464989],
#   [datetime.datetime(2015, 5, 2, 16, 39, 19), 3314728349],
#   [datetime.datetime(2015, 5, 3, 16, 44, 19), 3415504970],
#   [datetime.datetime(2015, 5, 4, 16, 44, 19), 3417049721],
#   [datetime.datetime(2015, 5, 5, 17, 9, 18), 3318757221],
#   [datetime.datetime(2015, 5, 6, 18, 49, 20), 3320275175],
#   [datetime.datetime(2015, 5, 7, 18, 49, 20), 3279491422],
#   [datetime.datetime(2015, 5, 8, 18, 49, 20), 3476741981],
#   [datetime.datetime(2015, 5, 9, 18, 49, 20), 3410996344],
#   [datetime.datetime(2015, 5, 10, 18, 49, 19), 3401965502],
#   [datetime.datetime(2015, 5, 11, 18, 54, 20), 3447508596],
#   [datetime.datetime(2015, 5, 12, 18, 59, 21), 3426188781],
#   [datetime.datetime(2015, 5, 13, 18, 59, 22), 3438268055],
#   [datetime.datetime(2015, 5, 14, 18, 59, 20), 3347749805],
#   [datetime.datetime(2015, 5, 15, 18, 59, 25), 3363986983],
#   [datetime.datetime(2015, 5, 16, 18, 59, 20), 3363167493],
#   [datetime.datetime(2015, 5, 17, 18, 59, 20), 3364091343],
#   [datetime.datetime(2015, 5, 18, 18, 59, 20), 3356103839],
#   [datetime.datetime(2015, 5, 19, 19, 9, 23), 3308309428],
#   [datetime.datetime(2015, 5, 20, 19, 14, 19), 3327909958],
#   [datetime.datetime(2015, 5, 21, 19, 14, 21), 3350546405],
#   [datetime.datetime(2015, 5, 22, 19, 14, 21), 3360738159],
#   [datetime.datetime(2015, 5, 23, 19, 14, 20), 3409088722],
#   [datetime.datetime(2015, 5, 24, 19, 14, 20), 3429956268],
#   [datetime.datetime(2015, 5, 25, 19, 34, 21), 3369803070],
#   [datetime.datetime(2015, 5, 26, 19, 59, 21), 3373050560],
#   [datetime.datetime(2015, 5, 27, 20, 9, 20), 3363816253],
#   [datetime.datetime(2015, 5, 28, 22, 54, 20), 3373675768],
#   [datetime.datetime(2015, 5, 29, 22, 54, 21), 3370190445],
#   [datetime.datetime(2015, 5, 30, 23, 9, 21), 3307068042],
#   [datetime.datetime(2015, 5, 31, 23, 9, 21), 3297894742],
#   [datetime.datetime(2015, 6, 1, 23, 24, 20), 3166420065],
#   [datetime.datetime(2015, 6, 3, 0, 29, 20), 3211363373],
#   [datetime.datetime(2015, 6, 4, 0, 29, 21), 3217797867],
#   [datetime.datetime(2015, 6, 5, 0, 29, 20), 3196874056],
#   [datetime.datetime(2015, 6, 6, 0, 29, 21), 3207088735],
#   [datetime.datetime(2015, 6, 7, 1, 29, 20), 3205253467],
#   [datetime.datetime(2015, 6, 8, 1, 29, 20), 3183902511],
#   [datetime.datetime(2015, 6, 9, 1, 29, 21), 3255937616],
#   [datetime.datetime(2015, 6, 10, 1, 29, 19), 3268406686],
#   [datetime.datetime(2015, 6, 11, 1, 29, 20), 3262359707],
#   [datetime.datetime(2015, 6, 12, 1, 29, 20), 3275768947],
#   [datetime.datetime(2015, 6, 13, 1, 29, 26), 3284984267],
#   [datetime.datetime(2015, 6, 14, 2, 29, 21), 3317671899],
#   [datetime.datetime(2015, 6, 15, 2, 29, 23), 3332954967],
#   [datetime.datetime(2015, 6, 16, 2, 29, 21), 3378059557],
#   [datetime.datetime(2015, 6, 17, 2, 29, 20), 3604399193],
#   [datetime.datetime(2015, 6, 18, 2, 29, 19), 3556041989],
#   [datetime.datetime(2015, 6, 19, 2, 29, 20), 3569721791],
#   [datetime.datetime(2015, 6, 20, 2, 29, 19), 3487268038],
#   [datetime.datetime(2015, 6, 21, 2, 29, 20), 3499099248],
#   [datetime.datetime(2015, 6, 22, 2, 34, 20), 3487360825],
#   [datetime.datetime(2015, 6, 23, 2, 34, 21), 3528441317],
#   [datetime.datetime(2015, 6, 24, 2, 34, 20), 3492940561],
#   [datetime.datetime(2015, 6, 25, 2, 34, 20), 3446189171],
#   [datetime.datetime(2015, 6, 26, 2, 34, 20), 3473639996],
#   [datetime.datetime(2015, 6, 27, 2, 34, 21), 3486208542],
#   [datetime.datetime(2015, 6, 28, 2, 34, 20), 3589623988],
#   [datetime.datetime(2015, 6, 29, 2, 34, 21), 3563321533],
#   [datetime.datetime(2015, 6, 30, 2, 34, 20), 3681402721],
#   [datetime.datetime(2015, 7, 1, 2, 34, 27), 3784372504],
#   [datetime.datetime(2015, 7, 2, 2, 34, 21), 3714048672],
#   [datetime.datetime(2015, 7, 3, 2, 34, 20), 3668022766],
#   [datetime.datetime(2015, 7, 4, 2, 34, 22), 3681165676],
#   [datetime.datetime(2015, 7, 5, 2, 34, 22), 3742137146],
#   [datetime.datetime(2015, 7, 6, 2, 34, 21), 3888172339],
#   [datetime.datetime(2015, 7, 7, 2, 34, 21), 3843241340],
#   [datetime.datetime(2015, 7, 8, 2, 34, 20), 3798502073],
#   [datetime.datetime(2015, 7, 9, 2, 34, 19), 3844791618],
#   [datetime.datetime(2015, 7, 10, 2, 34, 20), 3867029661],
#   [datetime.datetime(2015, 7, 11, 2, 34, 20), 4110352701],
#   [datetime.datetime(2015, 7, 12, 2, 34, 19), 4212905538],
#   [datetime.datetime(2015, 7, 13, 2, 34, 19), 4454664674],
#   [datetime.datetime(2015, 7, 14, 2, 34, 24), 4192223068],
#   [datetime.datetime(2015, 7, 15, 2, 39, 56), 4178565394],
#   [datetime.datetime(2015, 7, 16, 2, 39, 21), 4189402692],
#   [datetime.datetime(2015, 7, 17, 2, 39, 19), 4001980744],
#   [datetime.datetime(2015, 7, 18, 2, 39, 21), 4023355685],
#   [datetime.datetime(2015, 7, 19, 2, 44, 20), 3952584984],
#   [datetime.datetime(2015, 7, 20, 2, 49, 21), 3940416003],
#   [datetime.datetime(2015, 7, 21, 2, 49, 22), 4024532627],
#   [datetime.datetime(2015, 7, 22, 2, 59, 21), 3978914464],
#   [datetime.datetime(2015, 7, 23, 2, 59, 21), 3998474724],
#   [datetime.datetime(2015, 7, 24, 2, 59, 21), 3975213232],
#   [datetime.datetime(2015, 7, 25, 2, 59, 20), 4142634316],
#   [datetime.datetime(2015, 7, 26, 2, 59, 21), 4164345963],
#   [datetime.datetime(2015, 7, 27, 2, 59, 21), 4215400624],
#   [datetime.datetime(2015, 7, 28, 2, 59, 22), 4256097823],
#   [datetime.datetime(2015, 7, 29, 2, 59, 22), 4241127355],
#   [datetime.datetime(2015, 7, 30, 2, 59, 21), 4165297674],
#   [datetime.datetime(2015, 7, 31, 2, 59, 22), 4156876481],
#   [datetime.datetime(2015, 8, 1, 2, 59, 22), 4112500665],
#   [datetime.datetime(2015, 8, 2, 3, 4, 22), 4042133466],
#   [datetime.datetime(2015, 8, 3, 3, 4, 21), 4078449217],
#   [datetime.datetime(2015, 8, 4, 3, 4, 26), 4079086669],
#   [datetime.datetime(2015, 8, 5, 3, 14, 21), 4117595320],
#   [datetime.datetime(2015, 8, 6, 3, 14, 21), 4071191851],
#   [datetime.datetime(2015, 8, 7, 3, 14, 22), 4033878314],
#   [datetime.datetime(2015, 8, 8, 3, 14, 21), 4046202457],
#   [datetime.datetime(2015, 8, 9, 3, 14, 22), 3789713465],
#   [datetime.datetime(2015, 8, 10, 3, 14, 22), 3851303638],
#   [datetime.datetime(2015, 8, 11, 3, 14, 21), 3831151482],
#   [datetime.datetime(2015, 8, 12, 3, 29, 21), 3886143638],
#   [datetime.datetime(2015, 8, 13, 3, 29, 21), 3851673933],
#   [datetime.datetime(2015, 8, 14, 3, 29, 21), 3826343657],
# ...
#   [datetime.datetime(2015, 5, 2, 16, 39, 19), 15939300],
#   [datetime.datetime(2015, 5, 3, 16, 44, 19), 16861500],
#   [datetime.datetime(2015, 5, 4, 16, 44, 19), 16063800],
#   [datetime.datetime(2015, 5, 5, 17, 9, 18), 25902100],
#   [datetime.datetime(2015, 5, 6, 18, 49, 20), 17272400],
#   [datetime.datetime(2015, 5, 7, 18, 49, 20), 32649900],
#   [datetime.datetime(2015, 5, 8, 18, 49, 20), 32948700],
#   [datetime.datetime(2015, 5, 9, 18, 49, 20), 25349500],
#   [datetime.datetime(2015, 5, 10, 18, 49, 19), 15597600],
#   [datetime.datetime(2015, 5, 11, 18, 54, 20), 17472700],
#   [datetime.datetime(2015, 5, 12, 18, 59, 21), 21352400],
#   [datetime.datetime(2015, 5, 13, 18, 59, 22), 17839200],
#   [datetime.datetime(2015, 5, 14, 18, 59, 20), 28772200],
#   [datetime.datetime(2015, 5, 15, 18, 59, 25), 20008000],
#   [datetime.datetime(2015, 5, 16, 18, 59, 20), 12811900],
#   [datetime.datetime(2015, 5, 17, 18, 59, 20), 11257500],
#   [datetime.datetime(2015, 5, 18, 18, 59, 20), 12963900],
#   [datetime.datetime(2015, 5, 19, 19, 9, 23), 17644200],
#   [datetime.datetime(2015, 5, 20, 19, 14, 19), 15952000],
#   [datetime.datetime(2015, 5, 21, 19, 14, 21), 15400400],
#   [datetime.datetime(2015, 5, 22, 19, 14, 21), 19170400],
#   [datetime.datetime(2015, 5, 23, 19, 14, 20), 21821300],
#   [datetime.datetime(2015, 5, 24, 19, 14, 20), 12507600],
#   [datetime.datetime(2015, 5, 25, 19, 34, 21), 13777600],
#   [datetime.datetime(2015, 5, 26, 19, 59, 21), 15536800],
#   [datetime.datetime(2015, 5, 27, 20, 9, 20), 18473500],
#   [datetime.datetime(2015, 5, 28, 22, 54, 20), 13725800],
#   [datetime.datetime(2015, 5, 29, 22, 54, 21), 15242500],
#   [datetime.datetime(2015, 5, 30, 23, 9, 21), 14166700],
#   [datetime.datetime(2015, 5, 31, 23, 9, 21), 12519500],
#   [datetime.datetime(2015, 6, 1, 23, 24, 20), 25922900],
#   [datetime.datetime(2015, 6, 3, 0, 29, 20), 20742500],
#   [datetime.datetime(2015, 6, 4, 0, 29, 21), 17462200],
#   [datetime.datetime(2015, 6, 5, 0, 29, 20), 14461900],
#   [datetime.datetime(2015, 6, 6, 0, 29, 21), 18190200],
#   [datetime.datetime(2015, 6, 7, 1, 29, 20), 10568700],
#   [datetime.datetime(2015, 6, 8, 1, 29, 20), 13654600],
#   [datetime.datetime(2015, 6, 9, 1, 29, 21), 23342800],
#   [datetime.datetime(2015, 6, 10, 1, 29, 19), 28156800],
#   [datetime.datetime(2015, 6, 11, 1, 29, 20), 15904400],
#   [datetime.datetime(2015, 6, 12, 1, 29, 20), 14609500],
#   [datetime.datetime(2015, 6, 13, 1, 29, 26), 14004900],
#   [datetime.datetime(2015, 6, 14, 2, 29, 21), 12714400],
#   [datetime.datetime(2015, 6, 15, 2, 29, 23), 12266200],
#   [datetime.datetime(2015, 6, 16, 2, 29, 21), 20029300],
#   [datetime.datetime(2015, 6, 17, 2, 29, 20), 42924100],
#   [datetime.datetime(2015, 6, 18, 2, 29, 19), 42633100],
#   [datetime.datetime(2015, 6, 19, 2, 29, 20), 31076200],
#   [datetime.datetime(2015, 6, 20, 2, 29, 19), 24655600],
#   [datetime.datetime(2015, 6, 21, 2, 29, 20), 19823200],
#   [datetime.datetime(2015, 6, 22, 2, 34, 20), 10607100],
#   [datetime.datetime(2015, 6, 23, 2, 34, 21), 17576300],
#   [datetime.datetime(2015, 6, 24, 2, 34, 20), 15309800],
#   [datetime.datetime(2015, 6, 25, 2, 34, 20), 17090000],
#   [datetime.datetime(2015, 6, 26, 2, 34, 20), 15904600],
#   [datetime.datetime(2015, 6, 27, 2, 34, 21), 13769300],
#   [datetime.datetime(2015, 6, 28, 2, 34, 20), 20587900],
#   [datetime.datetime(2015, 6, 29, 2, 34, 21), 15025600],
#   [datetime.datetime(2015, 6, 30, 2, 34, 20), 34722300],
#   [datetime.datetime(2015, 7, 1, 2, 34, 27), 44669600],
#   [datetime.datetime(2015, 7, 2, 2, 34, 21), 26947900],
#   [datetime.datetime(2015, 7, 3, 2, 34, 20), 21435300],
#   [datetime.datetime(2015, 7, 4, 2, 34, 22), 19017900],
#   [datetime.datetime(2015, 7, 5, 2, 34, 22), 15464000],
#   [datetime.datetime(2015, 7, 6, 2, 34, 21), 44697100],
#   [datetime.datetime(2015, 7, 7, 2, 34, 21), 49703100],
#   [datetime.datetime(2015, 7, 8, 2, 34, 20), 27847400],
#   [datetime.datetime(2015, 7, 9, 2, 34, 19), 36849400],
#   [datetime.datetime(2015, 7, 10, 2, 34, 20), 40454400],
#   [datetime.datetime(2015, 7, 11, 2, 34, 20), 100412000],
#   [datetime.datetime(2015, 7, 12, 2, 34, 19), 40447000],
#   [datetime.datetime(2015, 7, 13, 2, 34, 19), 56392900],
#   [datetime.datetime(2015, 7, 14, 2, 34, 24), 61330500],
#   [datetime.datetime(2015, 7, 15, 2, 39, 56), 29467300],
#   [datetime.datetime(2015, 7, 16, 2, 39, 21), 29174900],
#   [datetime.datetime(2015, 7, 17, 2, 39, 19), 49482600],
#   [datetime.datetime(2015, 7, 18, 2, 39, 21), 27344700],
#   [datetime.datetime(2015, 7, 19, 2, 44, 20), 25371800],
#   [datetime.datetime(2015, 7, 20, 2, 49, 21), 15558600],
#   [datetime.datetime(2015, 7, 21, 2, 49, 22), 22273800],
#   [datetime.datetime(2015, 7, 22, 2, 59, 21), 23182500],
#   [datetime.datetime(2015, 7, 23, 2, 59, 21), 18615900],
#   [datetime.datetime(2015, 7, 24, 2, 59, 21), 18377800],
#   [datetime.datetime(2015, 7, 25, 2, 59, 20), 37326400],
#   [datetime.datetime(2015, 7, 26, 2, 59, 21), 20062200],
#   [datetime.datetime(2015, 7, 27, 2, 59, 21), 15984000],
#   [datetime.datetime(2015, 7, 28, 2, 59, 22), 31177800],
#   [datetime.datetime(2015, 7, 29, 2, 59, 22), 25193500],
#   [datetime.datetime(2015, 7, 30, 2, 59, 21), 24739600],
#   [datetime.datetime(2015, 7, 31, 2, 59, 22), 21319400],
#   [datetime.datetime(2015, 8, 1, 2, 59, 22), 23205300],
#   [datetime.datetime(2015, 8, 2, 3, 4, 22), 19310000],
#   [datetime.datetime(2015, 8, 3, 3, 4, 21), 17210200],
#   [datetime.datetime(2015, 8, 4, 3, 4, 26), 22122200],
#   [datetime.datetime(2015, 8, 5, 3, 14, 21), 21201300],
#   [datetime.datetime(2015, 8, 6, 3, 14, 21), 20604100],
#   [datetime.datetime(2015, 8, 7, 3, 14, 22), 17952300],
#   [datetime.datetime(2015, 8, 8, 3, 14, 21), 42342900],
#   [datetime.datetime(2015, 8, 9, 3, 14, 22), 58689800],
#   [datetime.datetime(2015, 8, 10, 3, 14, 22), 22285600],
#   [datetime.datetime(2015, 8, 11, 3, 14, 21), 20524000],
#   [datetime.datetime(2015, 8, 12, 3, 29, 21), 24977000],
#   [datetime.datetime(2015, 8, 13, 3, 29, 21), 26974200],
#   [datetime.datetime(2015, 8, 14, 3, 29, 21), 27216500],
#   [datetime.datetime(2015, 8, 15, 3, 29, 23), 27091900],
#   [datetime.datetime(2015, 8, 16, 3, 29, 20), 19510600],
#   [datetime.datetime(2015, 8, 17, 3, 29, 21), 29052400],
#   [datetime.datetime(2015, 8, 18, 3, 29, 20), 22034500],
#   [datetime.datetime(2015, 8, 19, 3, 29, 22), 63601000],
#   [datetime.datetime(2015, 8, 20, 3, 44, 21), 45257000],
#   [datetime.datetime(2015, 8, 21, 3, 44, 22), 30539300],
#   [datetime.datetime(2015, 8, 22, 3, 44, 21), 23355900],
#   [datetime.datetime(2015, 8, 23, 3, 49, 21), 22995600],
#   [datetime.datetime(2015, 8, 24, 3, 49, 21), 19533100],
#   [datetime.datetime(2015, 8, 25, 3, 54, 21), 65919600],
#   [datetime.datetime(2015, 8, 26, 3, 54, 20), 52402700],
#   [datetime.datetime(2015, 8, 27, 3, 54, 21), 31120600],
#   [datetime.datetime(2015, 8, 28, 3, 54, 21), 22965600],
#   [datetime.datetime(2015, 8, 29, 3, 54, 21), 29428400],
#   [datetime.datetime(2015, 8, 30, 4, 4, 21), 17820200],
#   [datetime.datetime(2015, 8, 31, 4, 4, 23), 18923200],
#   [datetime.datetime(2015, 9, 1, 4, 4, 20), 20222800],
#   [datetime.datetime(2015, 9, 2, 4, 4, 24), 20112300],
#   [datetime.datetime(2015, 9, 3, 4, 4, 21), 18480400],
#   [datetime.datetime(2015, 9, 4, 4, 4, 21), 18118800],
#   [datetime.datetime(2015, 9, 5, 4, 4, 23), 17494500],
#   [datetime.datetime(2015, 9, 6, 4, 4, 22), 19369500],
#   [datetime.datetime(2015, 9, 7, 4, 4, 22), 23695600],
#   [datetime.datetime(2015, 9, 8, 4, 4, 21), 19512600],
#   [datetime.datetime(2015, 9, 9, 4, 14, 21), 24843300],
#   [datetime.datetime(2015, 9, 10, 4, 19, 21), 21024500],
#   [datetime.datetime(2015, 9, 11, 4, 19, 23), 19597800],
#   [datetime.datetime(2015, 9, 12, 4, 19, 21), 16826300],
#   [datetime.datetime(2015, 9, 13, 4, 29, 22), 16206200],
#   [datetime.datetime(2015, 9, 14, 4, 29, 21), 17506600],
#   [datetime.datetime(2015, 9, 15, 4, 29, 23), 18772300],
#   [datetime.datetime(2015, 9, 16, 4, 29, 21), 16233700],
#   [datetime.datetime(2015, 9, 17, 4, 29, 21), 18810900],
#   [datetime.datetime(2015, 9, 19, 6, 59, 23), 16217800],
#   [datetime.datetime(2015, 9, 20, 7, 14, 23), 11954800],
#   [datetime.datetime(2015, 9, 21, 10, 24, 27), 14191700],
#   [datetime.datetime(2015, 9, 22, 12, 14, 22), 22857700],
#   [datetime.datetime(2015, 9, 23, 12, 14, 22), 18445900],
#   [datetime.datetime(2015, 9, 24, 12, 14, 40), 18486500],
#   [datetime.datetime(2015, 9, 25, 12, 39, 22), 25172600],
#   [datetime.datetime(2015, 9, 26, 13, 54, 24), 14410300],
#   [datetime.datetime(2015, 9, 27, 13, 59, 22), 13062400],
#   [datetime.datetime(2015, 9, 28, 13, 59, 22), 20202700],
#   [datetime.datetime(2015, 9, 29, 14, 4, 23), 22663000],
#   [datetime.datetime(2015, 9, 30, 14, 4, 23), 20512900],
#   [datetime.datetime(2015, 10, 1, 14, 4, 22), 16936200],
#   [datetime.datetime(2015, 10, 2, 14, 4, 22), 20239100],
#   [datetime.datetime(2015, 10, 3, 14, 19, 21), 17462600],
#   [datetime.datetime(2015, 10, 4, 14, 19, 22), 12642100],
#   [datetime.datetime(2015, 10, 5, 14, 19, 24), 15530500],
#   [datetime.datetime(2015, 10, 6, 14, 24, 23), 22365900],
#   [datetime.datetime(2015, 10, 7, 14, 24, 22), 26893700],
#   [datetime.datetime(2015, 10, 8, 14, 24, 24), 19671700],
#   [datetime.datetime(2015, 10, 9, 14, 24, 21), 18560000],
#   [datetime.datetime(2015, 10, 10, 14, 24, 22), 16000800],
#   [datetime.datetime(2015, 10, 11, 14, 39, 22), 11433600],
#   [datetime.datetime(2015, 10, 12, 14, 39, 22), 18033400],
#   [datetime.datetime(2015, 10, 13, 14, 39, 22), 24721800],
#   [datetime.datetime(2015, 10, 14, 14, 39, 23), 23232600],
#   [datetime.datetime(2015, 10, 15, 14, 44, 24), 26793100],
#   [datetime.datetime(2015, 10, 16, 14, 44, 45), 24415000],
#   [datetime.datetime(2015, 10, 17, 14, 54, 34), 44097300],
#   [datetime.datetime(2015, 10, 18, 14, 54, 24), 29558400],
#   [datetime.datetime(2015, 10, 19, 14, 54, 23), 25714300],
#   [datetime.datetime(2015, 10, 20, 14, 54, 20), 26078800],
#   [datetime.datetime(2015, 10, 21, 14, 54, 21), 29059300],
#   [datetime.datetime(2015, 10, 22, 14, 54, 20), 30156000],
#   [datetime.datetime(2015, 10, 23, 14, 54, 23), 32351800],
#   [datetime.datetime(2015, 10, 24, 14, 54, 22), 24084000],
#   [datetime.datetime(2015, 10, 25, 14, 19, 21), 35526900],
#   [datetime.datetime(2015, 10, 26, 14, 19, 21), 40169900],
#   [datetime.datetime(2015, 10, 27, 14, 19, 22), 35514700],
#   [datetime.datetime(2015, 10, 28, 14, 19, 20), 47347600],
#   [datetime.datetime(2015, 10, 29, 14, 19, 21), 51994800],
#   [datetime.datetime(2015, 10, 30, 14, 19, 20), 89068400],
#   [datetime.datetime(2015, 10, 31, 14, 54, 21), 41206200],
#   [datetime.datetime(2015, 11, 1, 15, 54, 21), 43893300],
#   [datetime.datetime(2015, 11, 2, 15, 54, 21), 56898600],
#   [datetime.datetime(2015, 11, 3, 15, 54, 19), 162207000],
#   [datetime.datetime(2015, 11, 4, 16, 4, 22), 293695000],
#   [datetime.datetime(2015, 11, 5, 16, 4, 20), 221063000],
#   [datetime.datetime(2015, 11, 6, 16, 4, 19), 121795000],
#   [datetime.datetime(2015, 11, 7, 16, 4, 20), 83953100],
#   [datetime.datetime(2015, 11, 8, 16, 39, 20), 44625800],
#   [datetime.datetime(2015, 11, 9, 16, 39, 25), 71774400],
#   [datetime.datetime(2015, 11, 10, 16, 39, 26), 68662800],
#   [datetime.datetime(2015, 11, 11, 16, 39, 21), 124080000],
#   [datetime.datetime(2015, 11, 12, 16, 39, 26), 81853000],
#   [datetime.datetime(2015, 11, 13, 16, 39, 27), 54658200],
#   [datetime.datetime(2015, 11, 14, 17, 14, 20), 38263800],
#   [datetime.datetime(2015, 11, 15, 17, 14, 22), 39008100],
#   [datetime.datetime(2015, 11, 16, 17, 14, 22), 42884200],
#   [datetime.datetime(2015, 11, 17, 17, 14, 20), 59097000],
#   [datetime.datetime(2015, 11, 18, 17, 14, 29), 42213700],
#   [datetime.datetime(2015, 11, 19, 17, 14, 21), 43553200],
#   [datetime.datetime(2015, 11, 20, 17, 14, 21), 53429100],
#   [datetime.datetime(2015, 11, 21, 18, 9, 45), 29623700],
#   [datetime.datetime(2015, 11, 22, 18, 9, 20), 21826600],
#   [datetime.datetime(2015, 11, 23, 18, 9, 25), 24535100],
#   [datetime.datetime(2015, 11, 24, 18, 14, 20), 28723900],
#   [datetime.datetime(2015, 11, 25, 18, 14, 20), 35175500],
#   [datetime.datetime(2015, 11, 26, 18, 14, 21), 97328600],
#   [datetime.datetime(2015, 11, 27, 22, 44, 19), 60590100],
#   [datetime.datetime(2015, 11, 28, 22, 44, 22), 37239800],
#   [datetime.datetime(2015, 11, 29, 22, 44, 22), 32339100],
#   [datetime.datetime(2015, 11, 30, 22, 44, 20), 75583000],
#   [datetime.datetime(2015, 12, 1, 22, 44, 23), 62588000],
#   [datetime.datetime(2015, 12, 2, 22, 44, 33), 52641600],
#   [datetime.datetime(2015, 12, 3, 22, 44, 20), 51221800],
#   [datetime.datetime(2015, 12, 4, 22, 44, 20), 35761100],
#   [datetime.datetime(2015, 12, 5, 22, 44, 24), 53679900],
#   [datetime.datetime(2015, 12, 6, 22, 44, 20), 88056200],
#   [datetime.datetime(2015, 12, 7, 22, 44, 20), 64776800],
#   [datetime.datetime(2015, 12, 8, 22, 44, 24), 42450200],
#   [datetime.datetime(2015, 12, 9, 22, 44, 23), 101683000],
#   [datetime.datetime(2015, 12, 10, 22, 44, 22), 53263400],
#   [datetime.datetime(2015, 12, 11, 22, 44, 21), 104496000],
#   [datetime.datetime(2015, 12, 12, 22, 44, 23), 131176000],
#   [datetime.datetime(2015, 12, 13, 22, 44, 23), 57806600],
#   [datetime.datetime(2015, 12, 14, 22, 44, 24), 128529000],
#   [datetime.datetime(2015, 12, 15, 22, 49, 22), 80492700],
#   [datetime.datetime(2015, 12, 16, 22, 59, 23), 111483000],
#   [datetime.datetime(2015, 12, 17, 22, 59, 20), 48845100],
#   [datetime.datetime(2015, 12, 18, 23, 14, 22), 58257500],
#   [datetime.datetime(2015, 12, 19, 23, 24, 22), 48601100],
#   [datetime.datetime(2015, 12, 20, 23, 24, 20), 74004600],
#   [datetime.datetime(2015, 12, 21, 23, 24, 24), 75809300],
#   [datetime.datetime(2015, 12, 22, 23, 29, 22), 52039000],
#   [datetime.datetime(2015, 12, 23, 23, 29, 22), 47354600],
#   [datetime.datetime(2015, 12, 24, 23, 29, 20), 57236500],
#   [datetime.datetime(2015, 12, 25, 23, 29, 21), 39143500],
#   [datetime.datetime(2015, 12, 26, 23, 29, 22), 114925000],
#   [datetime.datetime(2015, 12, 27, 23, 29, 22), 53393600],
#   [datetime.datetime(2015, 12, 28, 23, 29, 21), 49089900],
#   [datetime.datetime(2015, 12, 29, 23, 29, 22), 50244100],
#   [datetime.datetime(2015, 12, 30, 23, 29, 22), 48589900],
#   [datetime.datetime(2015, 12, 31, 23, 29, 22), 45929800],
#   [datetime.datetime(2016, 1, 1, 23, 29, 21), 35900100],
#   [datetime.datetime(2016, 1, 2, 23, 29, 23), 30177000],
#   [datetime.datetime(2016, 1, 3, 23, 29, 22), 38378900],
#   [datetime.datetime(2016, 1, 4, 23, 29, 23), 38174500],
#   [datetime.datetime(2016, 1, 5, 23, 29, 18), 34971300],
#   [datetime.datetime(2016, 1, 6, 23, 29, 16), 33744600],
#   [datetime.datetime(2016, 1, 7, 23, 34, 18), 81552100],
#   [datetime.datetime(2016, 1, 8, 23, 34, 17), 61907500],
#   [datetime.datetime(2016, 1, 9, 23, 34, 16), 32339500],
#   [datetime.datetime(2016, 1, 10, 23, 39, 17), 35198400],
#   [datetime.datetime(2016, 1, 11, 23, 39, 19), 41045900],
#   [datetime.datetime(2016, 1, 12, 23, 54, 19), 99356700],
#   [datetime.datetime(2016, 1, 13, 23, 54, 19), 180327000],
#   [datetime.datetime(2016, 1, 14, 23, 54, 19), 43258800],
#   [datetime.datetime(2016, 1, 15, 23, 54, 19), 142114000],
#   [datetime.datetime(2016, 1, 16, 23, 54, 19), 129294000],
#   [datetime.datetime(2016, 1, 18, 0, 4, 17), 47441400],
#   [datetime.datetime(2016, 1, 19, 0, 4, 19), 56199800],
#   [datetime.datetime(2016, 1, 20, 0, 4, 19), 46402600],
#   [datetime.datetime(2016, 1, 21, 0, 4, 19), 109001000],
#   [datetime.datetime(2016, 1, 22, 0, 19, 19), 73754000],
#   [datetime.datetime(2016, 1, 23, 0, 19, 23), 88051500],
#   [datetime.datetime(2016, 1, 24, 0, 29, 24), 56582800],
#   [datetime.datetime(2016, 1, 25, 0, 39, 18), 55545300],
#   [datetime.datetime(2016, 1, 26, 0, 39, 19), 58803600],
#   [datetime.datetime(2016, 1, 27, 0, 44, 22), 57754300],
#   [datetime.datetime(2016, 1, 28, 0, 54, 18), 47575500],
#   [datetime.datetime(2016, 1, 29, 0, 54, 18), 59191900],
#   [datetime.datetime(2016, 1, 30, 0, 54, 18), 86293700],
#   [datetime.datetime(2016, 1, 31, 0, 54, 18), 30274600],
#   [datetime.datetime(2016, 2, 1, 0, 54, 19), 37543600],
#   [datetime.datetime(2016, 2, 2, 0, 54, 20), 51821200],
#   [datetime.datetime(2016, 2, 3, 0, 54, 19), 40417700],
#   [datetime.datetime(2016, 2, 4, 0, 54, 20), 45872000],
#   [datetime.datetime(2016, 2, 5, 0, 54, 20), 69224300],
#   [datetime.datetime(2016, 2, 6, 1, 19, 37), 37850800],
#   ...]}

# %% [markdown]
# #### `graphs.global_cap([bitcoin=True, start=None, end=None])`
# Display data from [total market capitalization charts](https://coinmarketcap.com/charts/), including or excluding bitcoin:

# %%
cmc.graphs.global_cap(bitcoin=False)
# Out:
# {'market_cap_by_available_supply': [[datetime.datetime(2013, 4, 28, 20, 47),
#    91346900.0],
#   [datetime.datetime(2013, 4, 29, 20, 47), 94087500.0],
#   [datetime.datetime(2013, 4, 30, 20, 47), 90416200.0],
#   [datetime.datetime(2013, 5, 1, 20, 47), 78877300.0],
#   [datetime.datetime(2013, 5, 2, 20, 47), 72337900.0],
#   [datetime.datetime(2013, 5, 3, 20, 47), 66800000.0],
#   [datetime.datetime(2013, 5, 4, 20, 47), 79306600.0],
#   [datetime.datetime(2013, 5, 5, 20, 47), 82748700.0],
#   [datetime.datetime(2013, 5, 6, 20, 47), 80775900.0],
#   [datetime.datetime(2013, 5, 7, 20, 47), 70380300.0],
#   [datetime.datetime(2013, 5, 8, 20, 47), 78779600.0],
#   [datetime.datetime(2013, 5, 9, 20, 47), 77892400.0],
#   [datetime.datetime(2013, 5, 10, 20, 47), 79292400.0],
#   [datetime.datetime(2013, 5, 11, 20, 47), 75550100.0],
#   [datetime.datetime(2013, 5, 12, 20, 47), 72145100.0],
#   [datetime.datetime(2013, 5, 13, 20, 47), 73187500.0],
#   [datetime.datetime(2013, 5, 14, 20, 47), 72419800.0],
#   [datetime.datetime(2013, 5, 15, 20, 47), 65450200.0],
#   [datetime.datetime(2013, 5, 16, 20, 47), 63753400.0],
#   [datetime.datetime(2013, 5, 17, 20, 47), 70536900.0],
#   [datetime.datetime(2013, 5, 18, 20, 47), 71584400.0],
#   [datetime.datetime(2013, 5, 19, 20, 47), 72028600.0],
#   [datetime.datetime(2013, 5, 20, 20, 47), 71479800.0],
#   [datetime.datetime(2013, 5, 21, 20, 47), 71193200.0],
#   [datetime.datetime(2013, 5, 22, 20, 47), 71162700.0],
#   [datetime.datetime(2013, 5, 23, 20, 47), 71512200.0],
#   [datetime.datetime(2013, 5, 24, 20, 47), 70684600.0],
#   [datetime.datetime(2013, 5, 25, 20, 47), 70411100.0],
#   [datetime.datetime(2013, 5, 26, 20, 47), 73617500.0],
#   [datetime.datetime(2013, 5, 27, 20, 47), 69441300.0],
#   [datetime.datetime(2013, 5, 28, 20, 47), 69415000.0],
#   [datetime.datetime(2013, 5, 29, 20, 47), 68449400.0],
#   [datetime.datetime(2013, 5, 30, 20, 47), 66355500.0],
#   [datetime.datetime(2013, 5, 31, 20, 47), 63016300.0],
#   [datetime.datetime(2013, 6, 1, 20, 47), 63213400.0],
#   [datetime.datetime(2013, 6, 2, 20, 47), 59895000.0],
#   [datetime.datetime(2013, 6, 3, 20, 47), 60090200.0],
#   [datetime.datetime(2013, 6, 4, 20, 47), 63094600.0],
#   [datetime.datetime(2013, 6, 5, 20, 47), 63521200.0],
#   [datetime.datetime(2013, 6, 6, 20, 47), 62039600.0],
#   [datetime.datetime(2013, 6, 7, 20, 47), 58049800.0],
#   [datetime.datetime(2013, 6, 8, 20, 47), 57482400.0],
#   [datetime.datetime(2013, 6, 9, 20, 47), 52057800.0],
#   [datetime.datetime(2013, 6, 10, 20, 47), 54893200.0],
#   [datetime.datetime(2013, 6, 11, 20, 47), 52693800.0],
#   [datetime.datetime(2013, 6, 12, 20, 47), 54045100.0],
#   [datetime.datetime(2013, 6, 13, 20, 47), 53785900.0],
#   [datetime.datetime(2013, 6, 14, 20, 47), 49326300.0],
#   [datetime.datetime(2013, 6, 15, 20, 47), 48439400.0],
#   [datetime.datetime(2013, 6, 16, 20, 47), 46793200.0],
#   [datetime.datetime(2013, 6, 17, 20, 47), 49772100.0],
#   [datetime.datetime(2013, 6, 18, 20, 47), 51298700.0],
#   [datetime.datetime(2013, 6, 19, 20, 47), 52250400.0],
#   [datetime.datetime(2013, 6, 20, 20, 47), 54030600.0],
#   [datetime.datetime(2013, 6, 21, 20, 47), 58291300.0],
#   [datetime.datetime(2013, 6, 22, 20, 47), 70666600.0],
#   [datetime.datetime(2013, 6, 23, 20, 47), 67268700.0],
#   [datetime.datetime(2013, 6, 24, 20, 47), 61286100.0],
#   [datetime.datetime(2013, 6, 25, 20, 47), 62112600.0],
#   [datetime.datetime(2013, 6, 26, 20, 47), 62670600.0],
#   [datetime.datetime(2013, 6, 27, 20, 47), 64751900.0],
#   [datetime.datetime(2013, 6, 28, 20, 47), 61704800.0],
#   [datetime.datetime(2013, 6, 29, 20, 47), 62002900.0],
#   [datetime.datetime(2013, 6, 30, 20, 47), 64914000.0],
#   [datetime.datetime(2013, 7, 1, 20, 47), 65267700.0],
#   [datetime.datetime(2013, 7, 2, 20, 47), 63560800.0],
#   [datetime.datetime(2013, 7, 3, 20, 47), 63311200.0],
#   [datetime.datetime(2013, 7, 4, 20, 47), 60904300.0],
#   [datetime.datetime(2013, 7, 5, 20, 47), 54104500.0],
#   [datetime.datetime(2013, 7, 6, 20, 47), 55867900.0],
#   [datetime.datetime(2013, 7, 7, 20, 47), 57038100.0],
#   [datetime.datetime(2013, 7, 8, 20, 47), 60448000.0],
#   [datetime.datetime(2013, 7, 9, 20, 47), 59211900.0],
#   [datetime.datetime(2013, 7, 10, 20, 47), 59959900.0],
#   [datetime.datetime(2013, 7, 11, 20, 47), 62694500.0],
#   [datetime.datetime(2013, 7, 12, 20, 47), 65547400.0],
#   [datetime.datetime(2013, 7, 13, 20, 47), 65541800.0],
#   [datetime.datetime(2013, 7, 14, 20, 47), 66305200.0],
#   [datetime.datetime(2013, 7, 15, 20, 47), 68775700.0],
#   [datetime.datetime(2013, 7, 16, 20, 47), 71409200.0],
#   [datetime.datetime(2013, 7, 17, 20, 47), 71888600.0],
#   [datetime.datetime(2013, 7, 18, 20, 47), 67383000.0],
#   [datetime.datetime(2013, 7, 19, 20, 47), 70173300.0],
#   [datetime.datetime(2013, 7, 20, 20, 47), 70048200.0],
#   [datetime.datetime(2013, 7, 21, 20, 47), 67061200.0],
#   [datetime.datetime(2013, 7, 22, 20, 47), 68840500.0],
#   [datetime.datetime(2013, 7, 23, 20, 47), 69979800.0],
#   [datetime.datetime(2013, 7, 24, 20, 47), 70408700.0],
#   [datetime.datetime(2013, 7, 25, 20, 47), 71293500.0],
#   [datetime.datetime(2013, 7, 26, 20, 47), 70146100.0],
#   [datetime.datetime(2013, 7, 27, 20, 47), 69775900.0],
#   [datetime.datetime(2013, 7, 28, 20, 47), 70738400.0],
#   [datetime.datetime(2013, 7, 29, 20, 47), 72318200.0],
#   [datetime.datetime(2013, 7, 30, 20, 47), 70811300.0],
#   [datetime.datetime(2013, 7, 31, 20, 47), 70454400.0],
#   [datetime.datetime(2013, 8, 1, 20, 47), 71378500.0],
#   [datetime.datetime(2013, 8, 2, 20, 47), 71961800.0],
#   [datetime.datetime(2013, 8, 3, 20, 47), 72525500.0],
#   [datetime.datetime(2013, 8, 4, 20, 47), 120755000.0],
#   [datetime.datetime(2013, 8, 5, 20, 47), 116002000.0],
#   [datetime.datetime(2013, 8, 6, 20, 47), 107433000.0],
#   [datetime.datetime(2013, 8, 7, 20, 47), 105371000.0],
#   [datetime.datetime(2013, 8, 8, 20, 47), 101976000.0],
#   [datetime.datetime(2013, 8, 9, 20, 47), 102527000.0],
#   [datetime.datetime(2013, 8, 10, 20, 47), 101450000.0],
#   [datetime.datetime(2013, 8, 11, 20, 47), 102650000.0],
#   [datetime.datetime(2013, 8, 12, 20, 47), 102088000.0],
#   [datetime.datetime(2013, 8, 13, 20, 47), 104928000.0],
#   [datetime.datetime(2013, 8, 14, 20, 47), 102750000.0],
#   [datetime.datetime(2013, 8, 15, 20, 47), 98306500.0],
#   [datetime.datetime(2013, 8, 16, 20, 47), 94015300.0],
#   [datetime.datetime(2013, 8, 17, 20, 47), 116082000.0],
#   [datetime.datetime(2013, 8, 18, 20, 47), 122494000.0],
#   [datetime.datetime(2013, 8, 19, 20, 47), 116533000.0],
#   [datetime.datetime(2013, 8, 20, 20, 47), 122173000.0],
#   [datetime.datetime(2013, 8, 21, 20, 47), 120963000.0],
#   [datetime.datetime(2013, 8, 22, 20, 47), 118290000.0],
#   [datetime.datetime(2013, 8, 23, 20, 47), 111822000.0],
#   [datetime.datetime(2013, 8, 24, 20, 47), 115540000.0],
#   [datetime.datetime(2013, 8, 25, 20, 47), 115933000.0],
#   [datetime.datetime(2013, 8, 26, 20, 47), 120281000.0],
#   [datetime.datetime(2013, 8, 27, 20, 47), 117435000.0],
#   [datetime.datetime(2013, 8, 28, 20, 47), 118145000.0],
#   [datetime.datetime(2013, 8, 29, 20, 47), 116302000.0],
#   [datetime.datetime(2013, 8, 30, 20, 47), 118211000.0],
#   [datetime.datetime(2013, 8, 31, 20, 47), 114599000.0],
#   [datetime.datetime(2013, 9, 1, 20, 47), 113722000.0],
#   [datetime.datetime(2013, 9, 2, 20, 47), 113379000.0],
#   [datetime.datetime(2013, 9, 3, 20, 47), 112444000.0],
#   [datetime.datetime(2013, 9, 4, 20, 47), 119650000.0],
#   [datetime.datetime(2013, 9, 5, 20, 47), 120118000.0],
#   [datetime.datetime(2013, 9, 6, 20, 47), 117776000.0],
#   [datetime.datetime(2013, 9, 7, 20, 47), 120145000.0],
#   [datetime.datetime(2013, 9, 8, 20, 47), 120866000.0],
#   [datetime.datetime(2013, 9, 9, 20, 47), 122974000.0],
#   [datetime.datetime(2013, 9, 10, 20, 47), 117252000.0],
#   [datetime.datetime(2013, 9, 11, 20, 47), 121176000.0],
#   [datetime.datetime(2013, 9, 12, 20, 47), 122415000.0],
#   [datetime.datetime(2013, 9, 13, 20, 47), 124787000.0],
#   [datetime.datetime(2013, 9, 14, 20, 47), 120295000.0],
#   [datetime.datetime(2013, 9, 15, 20, 47), 121615000.0],
#   [datetime.datetime(2013, 9, 16, 20, 47), 126221000.0],
#   [datetime.datetime(2013, 9, 17, 20, 47), 145375000.0],
#   [datetime.datetime(2013, 9, 18, 20, 47), 154496000.0],
#   [datetime.datetime(2013, 9, 19, 20, 47), 155768000.0],
#   [datetime.datetime(2013, 9, 20, 20, 47), 147692000.0],
#   [datetime.datetime(2013, 9, 21, 20, 47), 145475000.0],
#   [datetime.datetime(2013, 9, 22, 20, 47), 148859000.0],
#   [datetime.datetime(2013, 9, 23, 20, 47), 147103000.0],
#   [datetime.datetime(2013, 9, 24, 20, 47), 147768000.0],
#   [datetime.datetime(2013, 9, 25, 20, 47), 149735000.0],
#   [datetime.datetime(2013, 9, 26, 20, 47), 157864000.0],
#   [datetime.datetime(2013, 9, 27, 20, 47), 181970000.0],
#   [datetime.datetime(2013, 9, 28, 20, 47), 175348000.0],
#   [datetime.datetime(2013, 9, 29, 20, 47), 171872000.0],
#   [datetime.datetime(2013, 9, 30, 20, 47), 152510000.0],
#   [datetime.datetime(2013, 10, 1, 20, 47), 151984000.0],
#   [datetime.datetime(2013, 10, 2, 20, 47), 122049000.0],
#   [datetime.datetime(2013, 10, 3, 20, 47), 131262000.0],
#   [datetime.datetime(2013, 10, 4, 20, 47), 144173000.0],
#   [datetime.datetime(2013, 10, 5, 20, 47), 142499000.0],
#   [datetime.datetime(2013, 10, 6, 20, 47), 145579000.0],
#   [datetime.datetime(2013, 10, 7, 20, 47), 138501000.0],
#   [datetime.datetime(2013, 10, 8, 20, 47), 138282000.0],
#   [datetime.datetime(2013, 10, 9, 20, 47), 140319000.0],
#   [datetime.datetime(2013, 10, 10, 20, 47), 143336000.0],
#   [datetime.datetime(2013, 10, 11, 20, 47), 137481000.0],
#   [datetime.datetime(2013, 10, 12, 20, 47), 141064000.0],
#   [datetime.datetime(2013, 10, 13, 20, 47), 134396000.0],
#   [datetime.datetime(2013, 10, 14, 20, 47), 131778000.0],
#   [datetime.datetime(2013, 10, 15, 20, 47), 125420000.0],
#   [datetime.datetime(2013, 10, 16, 20, 47), 120186000.0],
#   [datetime.datetime(2013, 10, 17, 20, 47), 126267000.0],
#   [datetime.datetime(2013, 10, 18, 20, 47), 122653000.0],
#   [datetime.datetime(2013, 10, 19, 20, 47), 115056000.0],
#   [datetime.datetime(2013, 10, 20, 20, 47), 113817000.0],
#   [datetime.datetime(2013, 10, 21, 20, 47), 110497000.0],
#   [datetime.datetime(2013, 10, 22, 20, 47), 110310000.0],
#   [datetime.datetime(2013, 10, 23, 20, 47), 128863000.0],
#   [datetime.datetime(2013, 10, 24, 20, 47), 135405000.0],
#   [datetime.datetime(2013, 10, 25, 20, 47), 121996000.0],
#   [datetime.datetime(2013, 10, 26, 20, 47), 116569000.0],
#   [datetime.datetime(2013, 10, 27, 19, 47), 118288000.0],
#   [datetime.datetime(2013, 10, 28, 19, 47), 115291000.0],
#   [datetime.datetime(2013, 10, 29, 19, 47), 115368000.0],
#   [datetime.datetime(2013, 10, 30, 19, 47), 117847000.0],
#   [datetime.datetime(2013, 10, 31, 19, 47), 119052000.0],
#   [datetime.datetime(2013, 11, 1, 19, 47), 122805000.0],
#   [datetime.datetime(2013, 11, 2, 19, 47), 130672000.0],
#   [datetime.datetime(2013, 11, 3, 19, 47), 145194000.0],
#   [datetime.datetime(2013, 11, 4, 19, 47), 149382000.0],
#   [datetime.datetime(2013, 11, 5, 19, 47), 148046000.0],
#   [datetime.datetime(2013, 11, 6, 19, 47), 164656000.0],
#   [datetime.datetime(2013, 11, 7, 19, 47), 194376000.0],
#   [datetime.datetime(2013, 11, 8, 19, 47), 218271000.0],
#   [datetime.datetime(2013, 11, 9, 19, 47), 207404000.0],
#   [datetime.datetime(2013, 11, 10, 19, 47), 171624000.0],
#   [datetime.datetime(2013, 11, 11, 19, 47), 188315000.0],
#   [datetime.datetime(2013, 11, 12, 19, 47), 194546000.0],
#   [datetime.datetime(2013, 11, 13, 19, 47), 214283000.0],
#   [datetime.datetime(2013, 11, 14, 19, 47), 204296000.0],
#   [datetime.datetime(2013, 11, 15, 19, 47), 208820000.0],
#   [datetime.datetime(2013, 11, 16, 19, 47), 210126000.0],
#   [datetime.datetime(2013, 11, 17, 19, 47), 213943000.0],
#   [datetime.datetime(2013, 11, 18, 19, 47), 327716000.0],
#   [datetime.datetime(2013, 11, 19, 19, 47), 299383000.0],
#   [datetime.datetime(2013, 11, 20, 19, 47), 283783000.0],
#   [datetime.datetime(2013, 11, 21, 19, 47), 350201000.0],
#   [datetime.datetime(2013, 11, 22, 19, 47), 384482000.0],
#   [datetime.datetime(2013, 11, 23, 19, 47), 430926000.0],
#   [datetime.datetime(2013, 11, 24, 19, 47), 436831000.0],
#   [datetime.datetime(2013, 11, 25, 19, 47), 500277000.0],
#   [datetime.datetime(2013, 11, 26, 19, 47), 802841000.0],
#   [datetime.datetime(2013, 11, 27, 19, 47), 1047390000.0],
#   [datetime.datetime(2013, 11, 28, 19, 47), 1455110000.0],
#   [datetime.datetime(2013, 11, 29, 19, 47), 1456280000.0],
#   [datetime.datetime(2013, 11, 30, 19, 47), 1678780000.0],
#   [datetime.datetime(2013, 12, 1, 19, 47), 1606220000.0],
#   [datetime.datetime(2013, 12, 2, 19, 47), 1533610000.0],
#   [datetime.datetime(2013, 12, 3, 19, 47), 1643150000.0],
#   [datetime.datetime(2013, 12, 4, 19, 47), 1922280000.0],
#   [datetime.datetime(2013, 12, 5, 19, 47), 1793890000.0],
#   [datetime.datetime(2013, 12, 6, 19, 47), 1391580000.0],
#   [datetime.datetime(2013, 12, 7, 19, 47), 1113350000.0],
#   [datetime.datetime(2013, 12, 8, 19, 47), 1124000000.0],
#   [datetime.datetime(2013, 12, 9, 19, 47), 1405800000.0],
#   [datetime.datetime(2013, 12, 10, 19, 47), 1624970000.0],
#   [datetime.datetime(2013, 12, 11, 19, 47), 1419110000.0],
#   [datetime.datetime(2013, 12, 12, 19, 47), 1389540000.0],
#   [datetime.datetime(2013, 12, 13, 19, 47), 1385360000.0],
#   [datetime.datetime(2013, 12, 14, 19, 47), 1338820000.0],
#   [datetime.datetime(2013, 12, 15, 19, 47), 1329440000.0],
#   [datetime.datetime(2013, 12, 16, 19, 47), 1088160000.0],
#   [datetime.datetime(2013, 12, 17, 19, 47), 964254000.0],
#   [datetime.datetime(2013, 12, 18, 19, 47), 722720000.0],
#   [datetime.datetime(2013, 12, 19, 19, 47), 813604000.0],
#   [datetime.datetime(2013, 12, 20, 19, 47), 877874000.0],
#   [datetime.datetime(2013, 12, 21, 19, 47), 826229000.0],
#   [datetime.datetime(2013, 12, 22, 19, 47), 848677000.0],
#   [datetime.datetime(2013, 12, 23, 19, 47), 853021000.0],
#   [datetime.datetime(2013, 12, 24, 19, 47), 874026000.0],
#   [datetime.datetime(2013, 12, 25, 19, 47), 1059850000.0],
#   [datetime.datetime(2013, 12, 26, 19, 47), 1287890000.0],
#   [datetime.datetime(2013, 12, 27, 19, 47), 1207710000.0],
#   [datetime.datetime(2013, 12, 28, 19, 47), 1195660000.0],
#   [datetime.datetime(2013, 12, 29, 19, 47), 1233030000.0],
#   [datetime.datetime(2013, 12, 30, 19, 47), 1316440000.0],
#   [datetime.datetime(2013, 12, 31, 19, 47), 1306210000.0],
#   [datetime.datetime(2014, 1, 1, 19, 47), 1342220000.0],
#   [datetime.datetime(2014, 1, 2, 19, 47), 1410630000.0],
#   [datetime.datetime(2014, 1, 3, 19, 47), 1373160000.0],
#   [datetime.datetime(2014, 1, 4, 19, 47), 1426020000.0],
#   [datetime.datetime(2014, 1, 5, 19, 47), 1463510000.0],
#   [datetime.datetime(2014, 1, 6, 19, 47), 1485140000.0],
#   [datetime.datetime(2014, 1, 7, 19, 47), 1345630000.0],
#   [datetime.datetime(2014, 1, 8, 19, 47), 1257160000.0],
#   [datetime.datetime(2014, 1, 9, 19, 47), 1208980000.0],
#   [datetime.datetime(2014, 1, 10, 19, 47), 1251870000.0],
#   [datetime.datetime(2014, 1, 11, 19, 47), 1336960000.0],
#   [datetime.datetime(2014, 1, 12, 19, 47), 1270820000.0],
#   [datetime.datetime(2014, 1, 13, 19, 47), 1184550000.0],
#   [datetime.datetime(2014, 1, 14, 19, 47), 1187880000.0],
#   [datetime.datetime(2014, 1, 15, 19, 47), 1262240000.0],
#   [datetime.datetime(2014, 1, 16, 19, 47), 1230020000.0],
#   [datetime.datetime(2014, 1, 17, 19, 47), 1167320000.0],
#   [datetime.datetime(2014, 1, 18, 19, 47), 1223270000.0],
#   [datetime.datetime(2014, 1, 19, 19, 47), 1264300000.0],
#   [datetime.datetime(2014, 1, 20, 19, 47), 1328450000.0],
#   [datetime.datetime(2014, 1, 21, 19, 47), 1357510000.0],
#   [datetime.datetime(2014, 1, 22, 19, 47), 1268330000.0],
#   [datetime.datetime(2014, 1, 23, 19, 47), 1238530000.0],
#   [datetime.datetime(2014, 1, 24, 19, 47), 1158590000.0],
#   [datetime.datetime(2014, 1, 25, 19, 47), 1279390000.0],
#   [datetime.datetime(2014, 1, 26, 19, 47), 1342780000.0],
#   [datetime.datetime(2014, 1, 27, 19, 47), 1192430000.0],
#   [datetime.datetime(2014, 1, 28, 19, 47), 1209400000.0],
#   [datetime.datetime(2014, 1, 29, 19, 47), 1201490000.0],
#   [datetime.datetime(2014, 1, 30, 19, 47), 1202140000.0],
#   [datetime.datetime(2014, 1, 31, 19, 47), 1215780000.0],
#   [datetime.datetime(2014, 2, 1, 19, 47), 1271320000.0],
#   [datetime.datetime(2014, 2, 2, 19, 47), 1273030000.0],
#   [datetime.datetime(2014, 2, 3, 19, 47), 1226850000.0],
#   [datetime.datetime(2014, 2, 4, 19, 47), 1221050000.0],
#   [datetime.datetime(2014, 2, 5, 19, 47), 1197700000.0],
#   [datetime.datetime(2014, 2, 6, 19, 47), 1152770000.0],
#   [datetime.datetime(2014, 2, 7, 19, 47), 1100320000.0],
#   [datetime.datetime(2014, 2, 8, 19, 47), 1036240000.0],
#   [datetime.datetime(2014, 2, 9, 19, 47), 1043400000.0],
#   [datetime.datetime(2014, 2, 10, 19, 47), 989687000.0],
#   [datetime.datetime(2014, 2, 11, 19, 47), 1035210000.0],
#   [datetime.datetime(2014, 2, 12, 19, 47), 1022980000.0],
#   [datetime.datetime(2014, 2, 13, 19, 47), 975399000.0],
#   [datetime.datetime(2014, 2, 14, 19, 47), 1011600000.0],
#   [datetime.datetime(2014, 2, 15, 19, 47), 1017520000.0],
#   [datetime.datetime(2014, 2, 16, 19, 47), 957827000.0],
#   [datetime.datetime(2014, 2, 17, 19, 47), 979692000.0],
#   [datetime.datetime(2014, 2, 18, 19, 47), 974309000.0],
#   [datetime.datetime(2014, 2, 19, 19, 47), 985101000.0],
#   [datetime.datetime(2014, 2, 20, 19, 47), 914285000.0],
#   [datetime.datetime(2014, 2, 21, 19, 47), 867297000.0],
#   [datetime.datetime(2014, 2, 22, 19, 47), 923988000.0],
#   [datetime.datetime(2014, 2, 23, 19, 47), 978744000.0],
#   [datetime.datetime(2014, 2, 24, 19, 47), 890014000.0],
#   [datetime.datetime(2014, 2, 25, 19, 47), 809536000.0],
#   [datetime.datetime(2014, 2, 26, 19, 47), 888840000.0],
#   [datetime.datetime(2014, 2, 27, 19, 47), 952724000.0],
#   [datetime.datetime(2014, 2, 28, 19, 47), 1096310000.0],
#   [datetime.datetime(2014, 3, 1, 19, 47), 1021000000.0],
#   [datetime.datetime(2014, 3, 2, 19, 47), 1114770000.0],
#   [datetime.datetime(2014, 3, 3, 19, 47), 1634700000.0],
#   [datetime.datetime(2014, 3, 4, 19, 47), 1852770000.0],
#   [datetime.datetime(2014, 3, 5, 19, 47), 1382400000.0],
#   [datetime.datetime(2014, 3, 6, 19, 47), 1199190000.0],
#   [datetime.datetime(2014, 3, 7, 19, 47), 1089520000.0],
#   [datetime.datetime(2014, 3, 8, 19, 47), 1084150000.0],
#   [datetime.datetime(2014, 3, 9, 19, 47), 1215770000.0],
#   [datetime.datetime(2014, 3, 10, 19, 47), 1215580000.0],
#   [datetime.datetime(2014, 3, 11, 19, 47), 1161250000.0],
#   [datetime.datetime(2014, 3, 12, 19, 47), 1192490000.0],
#   [datetime.datetime(2014, 3, 13, 19, 47), 1136190000.0],
#   [datetime.datetime(2014, 3, 14, 19, 47), 1127600000.0],
#   [datetime.datetime(2014, 3, 15, 19, 47), 1107150000.0],
#   [datetime.datetime(2014, 3, 16, 19, 47), 1111140000.0],
#   [datetime.datetime(2014, 3, 17, 19, 47), 996599000.0],
#   [datetime.datetime(2014, 3, 18, 19, 47), 1090860000.0],
#   [datetime.datetime(2014, 3, 19, 19, 47), 1077230000.0],
#   [datetime.datetime(2014, 3, 20, 19, 47), 1003680000.0],
#   [datetime.datetime(2014, 3, 21, 19, 47), 985536000.0],
#   [datetime.datetime(2014, 3, 22, 19, 47), 1064970000.0],
#   [datetime.datetime(2014, 3, 23, 19, 47), 1040740000.0],
#   [datetime.datetime(2014, 3, 24, 19, 47), 1001370000.0],
#   [datetime.datetime(2014, 3, 25, 19, 47), 975110000.0],
#   [datetime.datetime(2014, 3, 26, 19, 47), 933401000.0],
#   [datetime.datetime(2014, 3, 27, 19, 47), 793525000.0],
#   [datetime.datetime(2014, 3, 28, 19, 47), 740329000.0],
#   [datetime.datetime(2014, 3, 29, 19, 47), 756473000.0],
#   [datetime.datetime(2014, 3, 30, 20, 47), 698393000.0],
#   [datetime.datetime(2014, 3, 31, 20, 47), 682344000.0],
#   [datetime.datetime(2014, 4, 1, 20, 47), 706656000.0],
#   [datetime.datetime(2014, 4, 2, 20, 47), 617202000.0],
#   [datetime.datetime(2014, 4, 3, 20, 47), 604538000.0],
#   [datetime.datetime(2014, 4, 4, 20, 47), 607909000.0],
#   [datetime.datetime(2014, 4, 5, 20, 47), 624962000.0],
#   [datetime.datetime(2014, 4, 6, 20, 47), 633447000.0],
#   [datetime.datetime(2014, 4, 7, 20, 47), 618673000.0],
#   [datetime.datetime(2014, 4, 8, 20, 47), 613342000.0],
#   [datetime.datetime(2014, 4, 9, 20, 47), 596559000.0],
#   [datetime.datetime(2014, 4, 10, 20, 47), 515132000.0],
#   [datetime.datetime(2014, 4, 11, 20, 47), 583452000.0],
#   [datetime.datetime(2014, 4, 12, 20, 47), 561823000.0],
#   [datetime.datetime(2014, 4, 13, 20, 47), 527411000.0],
#   [datetime.datetime(2014, 4, 14, 20, 47), 620437000.0],
#   [datetime.datetime(2014, 4, 15, 20, 47), 687059000.0],
#   [datetime.datetime(2014, 4, 16, 20, 47), 705751000.0],
#   [datetime.datetime(2014, 4, 17, 20, 47), 685451000.0],
#   [datetime.datetime(2014, 4, 18, 20, 47), 666382000.0],
#   [datetime.datetime(2014, 4, 19, 20, 47), 730495000.0],
#   [datetime.datetime(2014, 4, 20, 20, 47), 712474000.0],
#   [datetime.datetime(2014, 4, 21, 20, 47), 714756000.0],
#   [datetime.datetime(2014, 4, 22, 20, 47), 700481000.0],
#   [datetime.datetime(2014, 4, 23, 20, 47), 689230000.0],
#   [datetime.datetime(2014, 4, 24, 20, 47), 697727000.0],
#   [datetime.datetime(2014, 4, 25, 20, 47), 600398000.0],
#   [datetime.datetime(2014, 4, 26, 20, 47), 595343000.0],
#   [datetime.datetime(2014, 4, 27, 20, 47), 552680000.0],
#   [datetime.datetime(2014, 4, 28, 20, 47), 575230000.0],
#   [datetime.datetime(2014, 4, 29, 20, 47), 588464000.0],
#   [datetime.datetime(2014, 4, 30, 20, 47), 605026000.0],
#   [datetime.datetime(2014, 5, 1, 20, 47), 611189000.0],
#   [datetime.datetime(2014, 5, 2, 20, 47), 582338000.0],
#   [datetime.datetime(2014, 5, 3, 20, 47), 560909000.0],
#   [datetime.datetime(2014, 5, 4, 20, 47), 566299000.0],
#   [datetime.datetime(2014, 5, 5, 20, 47), 562614000.0],
#   [datetime.datetime(2014, 5, 6, 20, 47), 575508000.0],
#   [datetime.datetime(2014, 5, 7, 20, 47), 594605000.0],
#   [datetime.datetime(2014, 5, 8, 20, 47), 592673000.0],
#   [datetime.datetime(2014, 5, 9, 20, 47), 616586000.0],
#   [datetime.datetime(2014, 5, 10, 20, 47), 610311000.0],
#   [datetime.datetime(2014, 5, 11, 20, 47), 589189000.0],
#   [datetime.datetime(2014, 5, 12, 20, 47), 591210000.0],
#   [datetime.datetime(2014, 5, 13, 20, 47), 592089000.0],
#   [datetime.datetime(2014, 5, 14, 20, 47), 604589000.0],
#   [datetime.datetime(2014, 5, 15, 20, 47), 620758000.0],
#   [datetime.datetime(2014, 5, 16, 20, 47), 612342000.0],
#   [datetime.datetime(2014, 5, 17, 20, 47), 607596000.0],
#   [datetime.datetime(2014, 5, 18, 20, 47), 602684000.0],
#   [datetime.datetime(2014, 5, 19, 20, 47), 601875000.0],
#   [datetime.datetime(2014, 5, 20, 20, 47), 635175000.0],
#   [datetime.datetime(2014, 5, 21, 20, 47), 634871000.0],
#   [datetime.datetime(2014, 5, 22, 20, 47), 628673000.0],
#   [datetime.datetime(2014, 5, 23, 20, 47), 664299000.0],
#   [datetime.datetime(2014, 5, 24, 20, 47), 655208000.0],
#   [datetime.datetime(2014, 5, 25, 20, 47), 698268000.0],
#   [datetime.datetime(2014, 5, 26, 20, 47), 685600000.0],
#   [datetime.datetime(2014, 5, 27, 20, 47), 680818000.0],
#   [datetime.datetime(2014, 5, 28, 20, 47), 663656000.0],
#   [datetime.datetime(2014, 5, 29, 20, 47), 652394000.0],
#   [datetime.datetime(2014, 5, 30, 20, 47), 681395000.0],
#   [datetime.datetime(2014, 5, 31, 20, 47), 670109000.0],
#   [datetime.datetime(2014, 6, 1, 20, 47), 700785000.0],
#   [datetime.datetime(2014, 6, 2, 20, 47), 693755000.0],
#   [datetime.datetime(2014, 6, 3, 20, 47), 705081000.0],
#   [datetime.datetime(2014, 6, 4, 20, 47), 689760000.0],
#   [datetime.datetime(2014, 6, 5, 20, 47), 708620000.0],
#   [datetime.datetime(2014, 6, 6, 20, 47), 695716000.0],
#   [datetime.datetime(2014, 6, 7, 20, 47), 689027000.0],
#   [datetime.datetime(2014, 6, 8, 20, 47), 691493000.0],
#   [datetime.datetime(2014, 6, 9, 20, 47), 686162000.0],
#   [datetime.datetime(2014, 6, 10, 20, 47), 704362000.0],
#   [datetime.datetime(2014, 6, 11, 20, 47), 708748000.0],
#   [datetime.datetime(2014, 6, 12, 20, 47), 682532000.0],
#   [datetime.datetime(2014, 6, 13, 20, 47), 671898000.0],
#   [datetime.datetime(2014, 6, 14, 20, 47), 643576000.0],
#   [datetime.datetime(2014, 6, 15, 20, 47), 650489000.0],
#   [datetime.datetime(2014, 6, 16, 20, 47), 664261000.0],
#   [datetime.datetime(2014, 6, 17, 20, 47), 656404000.0],
#   [datetime.datetime(2014, 6, 18, 20, 47), 664856000.0],
#   [datetime.datetime(2014, 6, 19, 20, 47), 672779000.0],
#   [datetime.datetime(2014, 6, 20, 20, 47), 649616000.0],
#   [datetime.datetime(2014, 6, 21, 20, 47), 650796000.0],
#   [datetime.datetime(2014, 6, 22, 20, 47), 659971000.0],
#   [datetime.datetime(2014, 6, 23, 20, 47), 647115000.0],
#   [datetime.datetime(2014, 6, 24, 20, 47), 639966000.0],
#   [datetime.datetime(2014, 6, 25, 20, 47), 606399000.0],
#   [datetime.datetime(2014, 6, 26, 20, 47), 603344000.0],
#   [datetime.datetime(2014, 6, 27, 20, 47), 617470000.0],
#   [datetime.datetime(2014, 6, 28, 20, 47), 612308000.0],
#   [datetime.datetime(2014, 6, 29, 20, 47), 597409000.0],
#   [datetime.datetime(2014, 6, 30, 20, 47), 601306000.0],
#   [datetime.datetime(2014, 7, 1, 20, 47), 608833000.0],
#   [datetime.datetime(2014, 7, 2, 20, 47), 574042000.0],
#   [datetime.datetime(2014, 7, 3, 20, 47), 577853000.0],
#   [datetime.datetime(2014, 7, 4, 20, 47), 566382000.0],
#   [datetime.datetime(2014, 7, 5, 20, 47), 533996000.0],
#   [datetime.datetime(2014, 7, 6, 20, 47), 528296000.0],
#   [datetime.datetime(2014, 7, 7, 20, 47), 526300000.0],
#   [datetime.datetime(2014, 7, 8, 20, 47), 532420000.0],
#   [datetime.datetime(2014, 7, 9, 20, 47), 545351000.0],
#   [datetime.datetime(2014, 7, 10, 20, 47), 540815000.0],
#   [datetime.datetime(2014, 7, 11, 20, 47), 552125000.0],
#   [datetime.datetime(2014, 7, 12, 20, 47), 572436000.0],
#   [datetime.datetime(2014, 7, 13, 20, 47), 577074000.0],
#   [datetime.datetime(2014, 7, 14, 20, 47), 571810000.0],
#   [datetime.datetime(2014, 7, 15, 20, 47), 564758000.0],
#   [datetime.datetime(2014, 7, 16, 20, 47), 558520000.0],
#   [datetime.datetime(2014, 7, 17, 20, 47), 589688000.0],
#   [datetime.datetime(2014, 7, 18, 20, 47), 600588000.0],
#   [datetime.datetime(2014, 7, 19, 20, 47), 588035000.0],
#   [datetime.datetime(2014, 7, 20, 20, 47), 583417000.0],
#   [datetime.datetime(2014, 7, 21, 20, 47), 609956000.0],
#   [datetime.datetime(2014, 7, 22, 20, 47), 598168000.0],
#   [datetime.datetime(2014, 7, 23, 20, 47), 596579000.0],
#   [datetime.datetime(2014, 7, 24, 20, 47), 568136000.0],
#   [datetime.datetime(2014, 7, 25, 20, 47), 554807000.0],
#   [datetime.datetime(2014, 7, 26, 20, 47), 550216000.0],
#   [datetime.datetime(2014, 7, 27, 20, 47), 551306000.0],
#   [datetime.datetime(2014, 7, 28, 20, 47), 536247000.0],
#   [datetime.datetime(2014, 7, 29, 20, 47), 539659000.0],
#   [datetime.datetime(2014, 7, 30, 20, 47), 533659000.0],
#   [datetime.datetime(2014, 7, 31, 20, 47), 549611000.0],
#   [datetime.datetime(2014, 8, 1, 20, 47), 559529000.0],
#   [datetime.datetime(2014, 8, 2, 20, 47), 553647000.0],
#   [datetime.datetime(2014, 8, 3, 20, 47), 549496000.0],
#   [datetime.datetime(2014, 8, 4, 20, 47), 538454000.0],
#   [datetime.datetime(2014, 8, 5, 20, 47), 528170000.0],
#   [datetime.datetime(2014, 8, 6, 20, 47), 525077000.0],
#   [datetime.datetime(2014, 8, 7, 20, 47), 526537000.0],
#   [datetime.datetime(2014, 8, 8, 20, 47), 522997000.0],
#   [datetime.datetime(2014, 8, 9, 20, 47), 507219000.0],
#   [datetime.datetime(2014, 8, 10, 20, 47), 503397000.0],
#   [datetime.datetime(2014, 8, 11, 20, 47), 480863000.0],
#   [datetime.datetime(2014, 8, 12, 20, 47), 440485000.0],
#   [datetime.datetime(2014, 8, 13, 20, 47), 413576000.0],
#   [datetime.datetime(2014, 8, 14, 20, 47), 411230000.0],
#   [datetime.datetime(2014, 8, 15, 20, 47), 399263000.0],
#   [datetime.datetime(2014, 8, 16, 20, 47), 394691000.0],
#   [datetime.datetime(2014, 8, 17, 20, 47), 380833000.0],
#   [datetime.datetime(2014, 8, 18, 20, 47), 325334000.0],
#   [datetime.datetime(2014, 8, 19, 20, 47), 379965000.0],
#   [datetime.datetime(2014, 8, 20, 20, 47), 432706000.0],
#   [datetime.datetime(2014, 8, 21, 20, 47), 458531000.0],
#   [datetime.datetime(2014, 8, 22, 20, 47), 448876000.0],
#   [datetime.datetime(2014, 8, 23, 20, 47), 421314000.0],
#   [datetime.datetime(2014, 8, 24, 20, 47), 459937000.0],
#   [datetime.datetime(2014, 8, 25, 20, 47), 481503000.0],
#   [datetime.datetime(2014, 8, 26, 20, 47), 588487000.0],
#   [datetime.datetime(2014, 8, 27, 20, 47), 577642000.0],
#   [datetime.datetime(2014, 8, 28, 20, 47), 560228000.0],
#   [datetime.datetime(2014, 8, 29, 20, 47), 551812000.0],
#   [datetime.datetime(2014, 8, 30, 20, 47), 555412000.0],
#   [datetime.datetime(2014, 8, 31, 20, 47), 531649000.0],
#   [datetime.datetime(2014, 9, 1, 20, 47), 538868000.0],
#   [datetime.datetime(2014, 9, 2, 20, 47), 521499000.0],
#   [datetime.datetime(2014, 9, 3, 20, 47), 533098000.0],
#   [datetime.datetime(2014, 9, 4, 20, 47), 556120000.0],
#   [datetime.datetime(2014, 9, 5, 20, 47), 557284000.0],
#   [datetime.datetime(2014, 9, 6, 20, 47), 571883000.0],
#   [datetime.datetime(2014, 9, 7, 20, 47), 568487000.0],
#   [datetime.datetime(2014, 9, 8, 20, 47), 572200000.0],
#   [datetime.datetime(2014, 9, 9, 20, 47), 569839000.0],
#   [datetime.datetime(2014, 9, 10, 20, 47), 594090000.0],
#   [datetime.datetime(2014, 9, 11, 20, 47), 594379000.0],
#   [datetime.datetime(2014, 9, 12, 20, 47), 598659000.0],
#   [datetime.datetime(2014, 9, 13, 20, 47), 608282000.0],
#   [datetime.datetime(2014, 9, 14, 20, 47), 631353000.0],
#   [datetime.datetime(2014, 9, 15, 20, 47), 606270000.0],
#   [datetime.datetime(2014, 9, 16, 20, 47), 616408000.0],
#   [datetime.datetime(2014, 9, 17, 20, 47), 608788000.0],
#   [datetime.datetime(2014, 9, 18, 20, 47), 603183000.0],
#   [datetime.datetime(2014, 9, 19, 20, 47), 564351000.0],
#   [datetime.datetime(2014, 9, 20, 20, 47), 566222000.0],
#   [datetime.datetime(2014, 9, 21, 20, 47), 555691000.0],
#   [datetime.datetime(2014, 9, 22, 20, 47), 561185000.0],
#   [datetime.datetime(2014, 9, 23, 20, 47), 586192000.0],
#   [datetime.datetime(2014, 9, 24, 20, 47), 586314000.0],
#   [datetime.datetime(2014, 9, 25, 20, 47), 583209000.0],
#   [datetime.datetime(2014, 9, 26, 20, 47), 586850000.0],
#   [datetime.datetime(2014, 9, 27, 20, 47), 576005000.0],
#   [datetime.datetime(2014, 9, 28, 20, 47), 581236000.0],
#   [datetime.datetime(2014, 9, 29, 20, 47), 561157000.0],
#   [datetime.datetime(2014, 9, 30, 20, 47), 571566000.0],
#   [datetime.datetime(2014, 10, 1, 20, 47), 573030000.0],
#   [datetime.datetime(2014, 10, 2, 20, 47), 565854000.0],
#   [datetime.datetime(2014, 10, 3, 20, 47), 556568000.0],
#   [datetime.datetime(2014, 10, 4, 20, 47), 534145000.0],
#   [datetime.datetime(2014, 10, 5, 20, 47), 494751000.0],
#   [datetime.datetime(2014, 10, 6, 20, 47), 521936000.0],
#   [datetime.datetime(2014, 10, 7, 20, 47), 526810000.0],
#   [datetime.datetime(2014, 10, 8, 20, 47), 531243000.0],
#   [datetime.datetime(2014, 10, 9, 20, 47), 551440000.0],
#   [datetime.datetime(2014, 10, 10, 20, 47), 529961000.0],
#   [datetime.datetime(2014, 10, 11, 20, 47), 528879000.0],
#   [datetime.datetime(2014, 10, 12, 20, 47), 542117000.0],
#   [datetime.datetime(2014, 10, 13, 20, 47), 537068000.0],
#   [datetime.datetime(2014, 10, 14, 20, 47), 565232000.0],
#   [datetime.datetime(2014, 10, 15, 20, 47), 544017000.0],
#   [datetime.datetime(2014, 10, 16, 20, 47), 532542000.0],
#   [datetime.datetime(2014, 10, 17, 20, 47), 544109000.0],
#   [datetime.datetime(2014, 10, 18, 20, 47), 547342000.0],
#   [datetime.datetime(2014, 10, 19, 20, 47), 541591000.0],
#   [datetime.datetime(2014, 10, 20, 20, 47), 536553000.0],
#   [datetime.datetime(2014, 10, 21, 20, 47), 544277000.0],
#   [datetime.datetime(2014, 10, 22, 20, 47), 536643000.0],
#   [datetime.datetime(2014, 10, 23, 20, 47), 518993000.0],
#   [datetime.datetime(2014, 10, 24, 20, 47), 514179000.0],
#   [datetime.datetime(2014, 10, 25, 20, 47), 496838000.0],
#   [datetime.datetime(2014, 10, 26, 19, 47), 491393000.0],
#   [datetime.datetime(2014, 10, 27, 19, 47), 513645000.0],
#   [datetime.datetime(2014, 10, 28, 19, 47), 504513000.0],
#   [datetime.datetime(2014, 10, 29, 19, 47), 488073000.0],
#   [datetime.datetime(2014, 10, 30, 19, 47), 479721000.0],
#   [datetime.datetime(2014, 10, 31, 19, 47), 477236000.0],
#   [datetime.datetime(2014, 11, 1, 19, 47), 455917000.0],
#   [datetime.datetime(2014, 11, 2, 19, 47), 457502000.0],
#   [datetime.datetime(2014, 11, 3, 19, 47), 463106000.0],
#   [datetime.datetime(2014, 11, 4, 19, 47), 466172000.0],
#   [datetime.datetime(2014, 11, 5, 19, 47), 482886000.0],
#   [datetime.datetime(2014, 11, 6, 19, 47), 482788000.0],
#   [datetime.datetime(2014, 11, 7, 19, 47), 477243000.0],
#   [datetime.datetime(2014, 11, 8, 19, 47), 485474000.0],
#   [datetime.datetime(2014, 11, 9, 19, 47), 496568000.0],
#   [datetime.datetime(2014, 11, 10, 19, 47), 505255000.0],
#   [datetime.datetime(2014, 11, 11, 19, 47), 497143000.0],
#   [datetime.datetime(2014, 11, 12, 19, 47), 545380000.0],
#   [datetime.datetime(2014, 11, 13, 19, 47), 529177000.0],
#   [datetime.datetime(2014, 11, 14, 19, 47), 522492000.0],
#   [datetime.datetime(2014, 11, 15, 19, 47), 504986000.0],
#   [datetime.datetime(2014, 11, 16, 19, 47), 514415000.0],
#   [datetime.datetime(2014, 11, 17, 19, 47), 520010000.0],
#   [datetime.datetime(2014, 11, 18, 19, 47), 508211000.0],
#   [datetime.datetime(2014, 11, 19, 19, 47), 521740000.0],
#   [datetime.datetime(2014, 11, 20, 19, 47), 519812000.0],
#   [datetime.datetime(2014, 11, 21, 19, 47), 539952000.0],
#   [datetime.datetime(2014, 11, 22, 19, 47), 568525000.0],
#   [datetime.datetime(2014, 11, 23, 19, 47), 603431000.0],
#   [datetime.datetime(2014, 11, 24, 19, 47), 637356000.0],
#   [datetime.datetime(2014, 11, 25, 19, 47), 664689000.0],
#   [datetime.datetime(2014, 11, 26, 19, 47), 686841000.0],
#   [datetime.datetime(2014, 11, 27, 19, 47), 778758000.0],
#   [datetime.datetime(2014, 11, 28, 19, 47), 831015000.0],
#   [datetime.datetime(2014, 11, 29, 19, 47), 810401000.0],
#   [datetime.datetime(2014, 11, 30, 19, 47), 744676000.0],
#   [datetime.datetime(2014, 12, 1, 19, 47), 731088000.0],
#   [datetime.datetime(2014, 12, 2, 19, 47), 787582000.0],
#   [datetime.datetime(2014, 12, 3, 19, 47), 791545000.0],
#   [datetime.datetime(2014, 12, 4, 19, 47), 786916000.0],
#   [datetime.datetime(2014, 12, 5, 19, 47), 800410000.0],
#   [datetime.datetime(2014, 12, 6, 19, 47), 825195000.0],
#   [datetime.datetime(2014, 12, 7, 19, 47), 839410000.0],
#   [datetime.datetime(2014, 12, 8, 19, 47), 793670000.0],
#   [datetime.datetime(2014, 12, 9, 19, 47), 819539000.0],
#   [datetime.datetime(2014, 12, 10, 19, 47), 842040000.0],
#   [datetime.datetime(2014, 12, 11, 19, 47), 867876000.0],
#   [datetime.datetime(2014, 12, 12, 19, 47), 870226000.0],
#   [datetime.datetime(2014, 12, 13, 19, 47), 886140000.0],
#   [datetime.datetime(2014, 12, 14, 19, 47), 888573000.0],
#   [datetime.datetime(2014, 12, 15, 19, 47), 911661000.0],
#   [datetime.datetime(2014, 12, 16, 19, 47), 1144450000.0],
#   [datetime.datetime(2014, 12, 17, 19, 47), 1178470000.0],
#   [datetime.datetime(2014, 12, 18, 19, 47), 1261210000.0],
#   [datetime.datetime(2014, 12, 19, 19, 47), 1148560000.0],
#   [datetime.datetime(2014, 12, 20, 19, 47), 1162840000.0],
#   [datetime.datetime(2014, 12, 21, 19, 47), 1235220000.0],
#   [datetime.datetime(2014, 12, 22, 19, 47), 1316740000.0],
#   [datetime.datetime(2014, 12, 23, 19, 47), 1238680000.0],
#   [datetime.datetime(2014, 12, 24, 19, 47), 1186090000.0],
#   [datetime.datetime(2014, 12, 25, 19, 47), 1201200000.0],
#   [datetime.datetime(2014, 12, 26, 19, 47), 1255850000.0],
#   [datetime.datetime(2014, 12, 27, 19, 47), 1205410000.0],
#   [datetime.datetime(2014, 12, 28, 19, 47), 1222520000.0],
#   [datetime.datetime(2014, 12, 29, 19, 47), 1244940000.0],
#   [datetime.datetime(2014, 12, 30, 19, 47), 1230690000.0],
#   [datetime.datetime(2014, 12, 31, 19, 47), 1226630000.0],
#   [datetime.datetime(2015, 1, 1, 19, 47), 1197740000.0],
#   [datetime.datetime(2015, 1, 2, 19, 47), 1167090000.0],
#   [datetime.datetime(2015, 1, 3, 19, 47), 1056370000.0],
#   [datetime.datetime(2015, 1, 4, 19, 47), 929329000.0],
#   [datetime.datetime(2015, 1, 5, 19, 47), 964343000.0],
#   [datetime.datetime(2015, 1, 6, 19, 47), 982395000.0],
#   [datetime.datetime(2015, 1, 7, 19, 47), 991633000.0],
#   [datetime.datetime(2015, 1, 8, 19, 47), 995648000.0],
#   [datetime.datetime(2015, 1, 9, 19, 47), 981760000.0],
#   [datetime.datetime(2015, 1, 10, 19, 47), 918681000.0],
#   [datetime.datetime(2015, 1, 11, 19, 47), 894899000.0],
#   [datetime.datetime(2015, 1, 12, 19, 47), 908503000.0],
#   [datetime.datetime(2015, 1, 13, 19, 47), 780680000.0],
#   [datetime.datetime(2015, 1, 14, 19, 47), 678802000.0],
#   [datetime.datetime(2015, 1, 15, 19, 47), 784938000.0],
#   [datetime.datetime(2015, 1, 16, 19, 47), 785764000.0],
#   [datetime.datetime(2015, 1, 17, 19, 47), 738269000.0],
#   [datetime.datetime(2015, 1, 18, 19, 47), 738315000.0],
#   [datetime.datetime(2015, 1, 19, 19, 47), 748796000.0],
#   [datetime.datetime(2015, 1, 20, 19, 47), 755792000.0],
#   [datetime.datetime(2015, 1, 21, 19, 47), 766946000.0],
#   [datetime.datetime(2015, 1, 22, 19, 47), 799918000.0],
#   [datetime.datetime(2015, 1, 23, 19, 47), 789356000.0],
#   [datetime.datetime(2015, 1, 24, 19, 47), 812009000.0],
#   [datetime.datetime(2015, 1, 25, 19, 47), 813913000.0],
#   [datetime.datetime(2015, 1, 26, 19, 47), 803715000.0],
#   [datetime.datetime(2015, 1, 27, 19, 47), 793259000.0],
#   [datetime.datetime(2015, 1, 28, 19, 47), 753885000.0],
#   [datetime.datetime(2015, 1, 29, 19, 47), 732630000.0],
#   [datetime.datetime(2015, 1, 30, 19, 47), 716554000.0],
#   [datetime.datetime(2015, 1, 31, 19, 47), 725233000.0],
#   [datetime.datetime(2015, 2, 1, 19, 47), 702022000.0],
#   [datetime.datetime(2015, 2, 2, 19, 47), 677968000.0],
#   [datetime.datetime(2015, 2, 3, 19, 47), 663962000.0],
#   [datetime.datetime(2015, 2, 4, 19, 47), 664371000.0],
#   [datetime.datetime(2015, 2, 5, 19, 47), 676131000.0],
#   [datetime.datetime(2015, 2, 6, 19, 47), 737186000.0],
#   [datetime.datetime(2015, 2, 7, 19, 47), 714281000.0],
#   [datetime.datetime(2015, 2, 8, 19, 47), 709130000.0],
#   [datetime.datetime(2015, 2, 9, 19, 47), 695826000.0],
#   [datetime.datetime(2015, 2, 10, 19, 47), 685140000.0],
#   [datetime.datetime(2015, 2, 11, 19, 47), 691767000.0],
#   [datetime.datetime(2015, 2, 12, 19, 47), 699809000.0],
#   [datetime.datetime(2015, 2, 13, 19, 47), 733001000.0],
#   [datetime.datetime(2015, 2, 14, 19, 47), 734792000.0],
#   [datetime.datetime(2015, 2, 15, 19, 47), 710621000.0],
#   [datetime.datetime(2015, 2, 16, 19, 47), 697338000.0],
#   [datetime.datetime(2015, 2, 17, 19, 47), 707683000.0],
#   [datetime.datetime(2015, 2, 18, 19, 47), 688987000.0],
#   [datetime.datetime(2015, 2, 19, 19, 47), 697313000.0],
#   [datetime.datetime(2015, 2, 20, 19, 47), 686548000.0],
#   [datetime.datetime(2015, 2, 21, 19, 47), 678598000.0],
#   [datetime.datetime(2015, 2, 22, 19, 47), 661213000.0],
#   [datetime.datetime(2015, 2, 23, 19, 47), 676680000.0],
#   [datetime.datetime(2015, 2, 24, 19, 47), 685071000.0],
#   [datetime.datetime(2015, 2, 25, 19, 47), 689518000.0],
#   [datetime.datetime(2015, 2, 26, 19, 47), 687085000.0],
#   [datetime.datetime(2015, 2, 27, 19, 47), 701451000.0],
#   [datetime.datetime(2015, 2, 28, 19, 47), 689766000.0],
#   [datetime.datetime(2015, 3, 1, 19, 47), 659057000.0],
#   [datetime.datetime(2015, 3, 2, 19, 47), 660104000.0],
#   [datetime.datetime(2015, 3, 3, 19, 47), 623979000.0],
#   [datetime.datetime(2015, 3, 4, 19, 47), 593296000.0],
#   [datetime.datetime(2015, 3, 5, 19, 47), 624609000.0],
#   [datetime.datetime(2015, 3, 6, 19, 47), 614565000.0],
#   [datetime.datetime(2015, 3, 7, 19, 47), 613530000.0],
#   [datetime.datetime(2015, 3, 8, 19, 47), 590230000.0],
#   [datetime.datetime(2015, 3, 9, 19, 47), 620074000.0],
#   [datetime.datetime(2015, 3, 10, 19, 47), 605072000.0],
#   [datetime.datetime(2015, 3, 11, 19, 47), 606489000.0],
#   [datetime.datetime(2015, 3, 12, 19, 47), 609695000.0],
#   [datetime.datetime(2015, 3, 13, 19, 47), 609164000.0],
#   [datetime.datetime(2015, 3, 14, 19, 47), 622586000.0],
#   [datetime.datetime(2015, 3, 15, 19, 47), 616376000.0],
#   [datetime.datetime(2015, 3, 16, 19, 47), 625373000.0],
#   [datetime.datetime(2015, 3, 17, 19, 47), 617453000.0],
#   [datetime.datetime(2015, 3, 18, 19, 47), 601956000.0],
#   [datetime.datetime(2015, 3, 19, 19, 47), 584798000.0],
#   [datetime.datetime(2015, 3, 20, 19, 47), 594318000.0],
#   [datetime.datetime(2015, 3, 21, 19, 47), 583602000.0],
#   [datetime.datetime(2015, 3, 22, 19, 47), 585772000.0],
#   [datetime.datetime(2015, 3, 23, 19, 47), 586476000.0],
#   [datetime.datetime(2015, 3, 24, 19, 47), 566466000.0],
#   [datetime.datetime(2015, 3, 25, 19, 47), 538736000.0],
#   [datetime.datetime(2015, 3, 26, 19, 47), 535806000.0],
#   [datetime.datetime(2015, 3, 27, 19, 47), 535972000.0],
#   [datetime.datetime(2015, 3, 28, 19, 47), 539776000.0],
#   [datetime.datetime(2015, 3, 29, 20, 47), 523321000.0],
#   [datetime.datetime(2015, 3, 30, 20, 47), 517637000.0],
#   [datetime.datetime(2015, 3, 31, 20, 47), 499740000.0],
#   [datetime.datetime(2015, 4, 1, 20, 47), 486166000.0],
#   [datetime.datetime(2015, 4, 2, 20, 47), 503882000.0],
#   [datetime.datetime(2015, 4, 3, 20, 47), 532795000.0],
#   [datetime.datetime(2015, 4, 4, 20, 47), 538041000.0],
#   [datetime.datetime(2015, 4, 5, 20, 47), 526767000.0],
#   [datetime.datetime(2015, 4, 6, 20, 47), 526723000.0],
#   [datetime.datetime(2015, 4, 7, 20, 47), 540462000.0],
#   [datetime.datetime(2015, 4, 8, 20, 47), 533843000.0],
#   [datetime.datetime(2015, 4, 9, 20, 47), 520620000.0],
#   [datetime.datetime(2015, 4, 10, 20, 47), 500201000.0],
#   [datetime.datetime(2015, 4, 11, 20, 47), 491648000.0],
#   [datetime.datetime(2015, 4, 12, 20, 47), 498748000.0],
#   [datetime.datetime(2015, 4, 13, 20, 47), 477420000.0],
#   [datetime.datetime(2015, 4, 14, 20, 47), 467499000.0],
#   [datetime.datetime(2015, 4, 15, 20, 47), 462391000.0],
#   [datetime.datetime(2015, 4, 16, 20, 47), 473225000.0],
#   [datetime.datetime(2015, 4, 17, 20, 47), 473328000.0],
#   [datetime.datetime(2015, 4, 18, 20, 47), 466901000.0],
#   [datetime.datetime(2015, 4, 19, 20, 47), 467161000.0],
#   [datetime.datetime(2015, 4, 20, 20, 47), 466030000.0],
#   [datetime.datetime(2015, 4, 21, 20, 47), 463374000.0],
#   [datetime.datetime(2015, 4, 22, 20, 47), 479166000.0],
#   [datetime.datetime(2015, 4, 23, 20, 47), 479465000.0],
#   [datetime.datetime(2015, 4, 24, 20, 47), 475027000.0],
#   [datetime.datetime(2015, 4, 25, 20, 47), 477749000.0],
#   [datetime.datetime(2015, 4, 26, 20, 47), 449862000.0],
#   [datetime.datetime(2015, 4, 27, 20, 47), 452714000.0],
#   [datetime.datetime(2015, 4, 28, 20, 47), 449089000.0],
#   [datetime.datetime(2015, 4, 29, 20, 47), 454883000.0],
#   [datetime.datetime(2015, 4, 30, 20, 47), 469860000.0],
#   [datetime.datetime(2015, 5, 1, 20, 47), 467535000.0],
#   [datetime.datetime(2015, 5, 2, 20, 47), 467195000.0],
#   [datetime.datetime(2015, 5, 3, 20, 47), 470999000.0],
#   [datetime.datetime(2015, 5, 4, 20, 47), 466106000.0],
#   [datetime.datetime(2015, 5, 5, 20, 47), 461153000.0],
#   [datetime.datetime(2015, 5, 6, 20, 47), 457801000.0],
#   [datetime.datetime(2015, 5, 7, 20, 47), 453693000.0],
#   [datetime.datetime(2015, 5, 8, 20, 47), 453131000.0],
#   [datetime.datetime(2015, 5, 9, 20, 47), 451503000.0],
#   [datetime.datetime(2015, 5, 10, 20, 47), 445702000.0],
#   [datetime.datetime(2015, 5, 11, 20, 47), 449458000.0],
#   [datetime.datetime(2015, 5, 12, 20, 47), 451033000.0],
#   [datetime.datetime(2015, 5, 13, 20, 47), 448926000.0],
#   [datetime.datetime(2015, 5, 14, 20, 47), 431142000.0],
#   [datetime.datetime(2015, 5, 15, 20, 47), 437034000.0],
#   [datetime.datetime(2015, 5, 16, 20, 47), 432200000.0],
#   [datetime.datetime(2015, 5, 17, 20, 47), 424223000.0],
#   [datetime.datetime(2015, 5, 18, 20, 47), 412450000.0],
#   [datetime.datetime(2015, 5, 19, 20, 47), 435607000.0],
#   [datetime.datetime(2015, 5, 20, 20, 47), 447488000.0],
#   [datetime.datetime(2015, 5, 21, 20, 47), 448142000.0],
#   [datetime.datetime(2015, 5, 22, 20, 47), 473257000.0],
#   [datetime.datetime(2015, 5, 23, 20, 47), 482755000.0],
#   [datetime.datetime(2015, 5, 24, 20, 47), 484332000.0],
#   [datetime.datetime(2015, 5, 25, 20, 47), 486747000.0],
#   [datetime.datetime(2015, 5, 26, 20, 47), 486066000.0],
#   [datetime.datetime(2015, 5, 27, 20, 47), 498727000.0],
#   [datetime.datetime(2015, 5, 28, 20, 47), 533866000.0],
#   [datetime.datetime(2015, 5, 29, 20, 47), 567101000.0],
#   [datetime.datetime(2015, 5, 30, 20, 47), 543495000.0],
#   [datetime.datetime(2015, 5, 31, 20, 47), 531531000.0],
#   [datetime.datetime(2015, 6, 1, 20, 47), 497028000.0],
#   [datetime.datetime(2015, 6, 2, 20, 47), 508487000.0],
#   [datetime.datetime(2015, 6, 3, 20, 47), 520109000.0],
#   [datetime.datetime(2015, 6, 4, 20, 47), 516078000.0],
#   [datetime.datetime(2015, 6, 5, 20, 47), 521676000.0],
#   [datetime.datetime(2015, 6, 6, 20, 47), 523497000.0],
#   [datetime.datetime(2015, 6, 7, 20, 47), 519089000.0],
#   [datetime.datetime(2015, 6, 8, 20, 47), 524004000.0],
#   [datetime.datetime(2015, 6, 9, 20, 47), 525282000.0],
#   [datetime.datetime(2015, 6, 10, 20, 47), 525360000.0],
#   [datetime.datetime(2015, 6, 11, 20, 47), 526175000.0],
#   [datetime.datetime(2015, 6, 12, 20, 47), 525903000.0],
#   [datetime.datetime(2015, 6, 13, 20, 47), 535149000.0],
#   [datetime.datetime(2015, 6, 14, 20, 47), 544822000.0],
#   [datetime.datetime(2015, 6, 15, 20, 47), 559669000.0],
#   [datetime.datetime(2015, 6, 16, 20, 47), 618911000.0],
#   [datetime.datetime(2015, 6, 17, 20, 47), 665477000.0],
#   [datetime.datetime(2015, 6, 18, 20, 47), 686062000.0],
#   [datetime.datetime(2015, 6, 19, 20, 47), 705210000.0],
#   [datetime.datetime(2015, 6, 20, 20, 47), 705348000.0],
#   [datetime.datetime(2015, 6, 21, 20, 47), 691628000.0],
#   [datetime.datetime(2015, 6, 22, 20, 47), 688278000.0],
#   [datetime.datetime(2015, 6, 23, 20, 47), 690253000.0],
#   [datetime.datetime(2015, 6, 24, 20, 47), 682725000.0],
#   [datetime.datetime(2015, 6, 25, 20, 47), 693315000.0],
#   [datetime.datetime(2015, 6, 26, 20, 47), 696148000.0],
#   [datetime.datetime(2015, 6, 27, 20, 47), 718839000.0],
#   [datetime.datetime(2015, 6, 28, 20, 47), 719270000.0],
#   [datetime.datetime(2015, 6, 29, 20, 47), 770667000.0],
#   [datetime.datetime(2015, 6, 30, 20, 47), 769913000.0],
#   [datetime.datetime(2015, 7, 1, 20, 47), 751222000.0],
#   [datetime.datetime(2015, 7, 2, 20, 47), 751830000.0],
#   [datetime.datetime(2015, 7, 3, 20, 47), 753960000.0],
#   [datetime.datetime(2015, 7, 4, 20, 47), 748783000.0],
#   [datetime.datetime(2015, 7, 5, 20, 47), 743319000.0],
#   [datetime.datetime(2015, 7, 6, 20, 47), 790896000.0],
#   [datetime.datetime(2015, 7, 7, 20, 47), 763797000.0],
#   [datetime.datetime(2015, 7, 8, 20, 47), 792956000.0],
#   [datetime.datetime(2015, 7, 9, 20, 47), 848990000.0],
#   [datetime.datetime(2015, 7, 10, 20, 47), 779444000.0],
#   [datetime.datetime(2015, 7, 11, 20, 47), 702401000.0],
#   [datetime.datetime(2015, 7, 12, 20, 47), 753937000.0],
#   [datetime.datetime(2015, 7, 13, 20, 47), 719344000.0],
#   [datetime.datetime(2015, 7, 14, 20, 47), 730682000.0],
#   [datetime.datetime(2015, 7, 15, 20, 47), 706520000.0],
#   [datetime.datetime(2015, 7, 16, 20, 47), 625416000.0],
#   [datetime.datetime(2015, 7, 17, 20, 47), 649706000.0],
#   [datetime.datetime(2015, 7, 18, 20, 47), 654796000.0],
#   [datetime.datetime(2015, 7, 19, 20, 47), 649486000.0],
#   [datetime.datetime(2015, 7, 20, 20, 47), 645688000.0],
#   [datetime.datetime(2015, 7, 21, 20, 47), 643181000.0],
#   [datetime.datetime(2015, 7, 22, 20, 47), 638162000.0],
#   [datetime.datetime(2015, 7, 23, 20, 47), 631498000.0],
#   [datetime.datetime(2015, 7, 24, 20, 47), 678916000.0],
#   [datetime.datetime(2015, 7, 25, 20, 47), 688518000.0],
#   [datetime.datetime(2015, 7, 26, 20, 47), 696254000.0],
#   [datetime.datetime(2015, 7, 27, 20, 47), 712204000.0],
#   [datetime.datetime(2015, 7, 28, 20, 47), 729735000.0],
#   [datetime.datetime(2015, 7, 29, 20, 47), 719222000.0],
#   [datetime.datetime(2015, 7, 30, 20, 47), 704284000.0],
#   [datetime.datetime(2015, 7, 31, 20, 47), 704698000.0],
#   [datetime.datetime(2015, 8, 1, 20, 47), 671964000.0],
#   [datetime.datetime(2015, 8, 2, 20, 47), 666681000.0],
#   [datetime.datetime(2015, 8, 3, 20, 47), 680933000.0],
#   [datetime.datetime(2015, 8, 4, 20, 47), 682329000.0],
#   [datetime.datetime(2015, 8, 5, 20, 47), 679000000.0],
#   [datetime.datetime(2015, 8, 6, 20, 47), 661538000.0],
#   [datetime.datetime(2015, 8, 7, 20, 47), 814142000.0],
#   [datetime.datetime(2015, 8, 8, 20, 47), 712758000.0],
#   [datetime.datetime(2015, 8, 9, 20, 47), 699605000.0],
#   [datetime.datetime(2015, 8, 10, 20, 47), 700479000.0],
#   [datetime.datetime(2015, 8, 11, 20, 47), 712598000.0],
#   [datetime.datetime(2015, 8, 12, 20, 47), 724885000.0],
#   [datetime.datetime(2015, 8, 13, 20, 47), 749640000.0],
#   [datetime.datetime(2015, 8, 14, 20, 47), 764350000.0],
#   [datetime.datetime(2015, 8, 15, 20, 47), 757514000.0],
#   [datetime.datetime(2015, 8, 16, 20, 47), 720594000.0],
#   [datetime.datetime(2015, 8, 17, 20, 47), 733599000.0],
# ...
#   [datetime.datetime(2015, 4, 9, 20, 47), 3283100.0],
#   [datetime.datetime(2015, 4, 10, 20, 47), 3688190.0],
#   [datetime.datetime(2015, 4, 11, 20, 47), 2598570.0],
#   [datetime.datetime(2015, 4, 12, 20, 47), 2026160.0],
#   [datetime.datetime(2015, 4, 13, 20, 47), 2425610.0],
#   [datetime.datetime(2015, 4, 14, 20, 47), 3640350.0],
#   [datetime.datetime(2015, 4, 15, 20, 47), 2522860.0],
#   [datetime.datetime(2015, 4, 16, 20, 47), 2646430.0],
#   [datetime.datetime(2015, 4, 17, 20, 47), 2432680.0],
#   [datetime.datetime(2015, 4, 18, 20, 47), 1623340.0],
#   [datetime.datetime(2015, 4, 19, 20, 47), 1767900.0],
#   [datetime.datetime(2015, 4, 20, 20, 47), 2573800.0],
#   [datetime.datetime(2015, 4, 21, 20, 47), 2301130.0],
#   [datetime.datetime(2015, 4, 22, 20, 47), 3081300.0],
#   [datetime.datetime(2015, 4, 23, 20, 47), 2532220.0],
#   [datetime.datetime(2015, 4, 24, 20, 47), 2406700.0],
#   [datetime.datetime(2015, 4, 25, 20, 47), 1870600.0],
#   [datetime.datetime(2015, 4, 26, 20, 47), 2505390.0],
#   [datetime.datetime(2015, 4, 27, 20, 47), 2613800.0],
#   [datetime.datetime(2015, 4, 28, 20, 47), 2937490.0],
#   [datetime.datetime(2015, 4, 29, 20, 47), 2508840.0],
#   [datetime.datetime(2015, 4, 30, 20, 47), 3378740.0],
#   [datetime.datetime(2015, 5, 1, 20, 47), 2899870.0],
#   [datetime.datetime(2015, 5, 2, 20, 47), 1782630.0],
#   [datetime.datetime(2015, 5, 3, 20, 47), 2435460.0],
#   [datetime.datetime(2015, 5, 4, 20, 47), 2698170.0],
#   [datetime.datetime(2015, 5, 5, 20, 47), 2355240.0],
#   [datetime.datetime(2015, 5, 6, 20, 47), 2190860.0],
#   [datetime.datetime(2015, 5, 7, 20, 47), 3904910.0],
#   [datetime.datetime(2015, 5, 8, 20, 47), 2976440.0],
#   [datetime.datetime(2015, 5, 9, 20, 47), 2205550.0],
#   [datetime.datetime(2015, 5, 10, 20, 47), 2299270.0],
#   [datetime.datetime(2015, 5, 11, 20, 47), 1928110.0],
#   [datetime.datetime(2015, 5, 12, 20, 47), 3203130.0],
#   [datetime.datetime(2015, 5, 13, 20, 47), 2460350.0],
#   [datetime.datetime(2015, 5, 14, 20, 47), 3639760.0],
#   [datetime.datetime(2015, 5, 15, 20, 47), 1949320.0],
#   [datetime.datetime(2015, 5, 16, 20, 47), 1541400.0],
#   [datetime.datetime(2015, 5, 17, 20, 47), 1437230.0],
#   [datetime.datetime(2015, 5, 18, 20, 47), 3150440.0],
#   [datetime.datetime(2015, 5, 19, 20, 47), 3710990.0],
#   [datetime.datetime(2015, 5, 20, 20, 47), 2639940.0],
#   [datetime.datetime(2015, 5, 21, 20, 47), 7100350.0],
#   [datetime.datetime(2015, 5, 22, 20, 47), 10566900.0],
#   [datetime.datetime(2015, 5, 23, 20, 47), 9343270.0],
#   [datetime.datetime(2015, 5, 24, 20, 47), 7338150.0],
#   [datetime.datetime(2015, 5, 25, 20, 47), 8225200.0],
#   [datetime.datetime(2015, 5, 26, 20, 47), 8333520.0],
#   [datetime.datetime(2015, 5, 27, 20, 47), 9807410.0],
#   [datetime.datetime(2015, 5, 28, 20, 47), 11085200.0],
#   [datetime.datetime(2015, 5, 29, 20, 47), 10795500.0],
#   [datetime.datetime(2015, 5, 30, 20, 47), 8538810.0],
#   [datetime.datetime(2015, 5, 31, 20, 47), 7318680.0],
#   [datetime.datetime(2015, 6, 1, 20, 47), 7738640.0],
#   [datetime.datetime(2015, 6, 2, 20, 47), 7988830.0],
#   [datetime.datetime(2015, 6, 3, 20, 47), 6552620.0],
#   [datetime.datetime(2015, 6, 4, 20, 47), 5698490.0],
#   [datetime.datetime(2015, 6, 5, 20, 47), 6316350.0],
#   [datetime.datetime(2015, 6, 6, 20, 47), 5681480.0],
#   [datetime.datetime(2015, 6, 7, 20, 47), 5547450.0],
#   [datetime.datetime(2015, 6, 8, 20, 47), 6179490.0],
#   [datetime.datetime(2015, 6, 9, 20, 47), 5837260.0],
#   [datetime.datetime(2015, 6, 10, 20, 47), 6368110.0],
#   [datetime.datetime(2015, 6, 11, 20, 47), 6323470.0],
#   [datetime.datetime(2015, 6, 12, 20, 47), 5831150.0],
#   [datetime.datetime(2015, 6, 13, 20, 47), 7106910.0],
#   [datetime.datetime(2015, 6, 14, 20, 47), 8876940.0],
#   [datetime.datetime(2015, 6, 15, 20, 47), 7005650.0],
#   [datetime.datetime(2015, 6, 16, 20, 47), 15235200.0],
#   [datetime.datetime(2015, 6, 17, 20, 47), 24490300.0],
#   [datetime.datetime(2015, 6, 18, 20, 47), 16313100.0],
#   [datetime.datetime(2015, 6, 19, 20, 47), 14563300.0],
#   [datetime.datetime(2015, 6, 20, 20, 47), 9762870.0],
#   [datetime.datetime(2015, 6, 21, 20, 47), 20360300.0],
#   [datetime.datetime(2015, 6, 22, 20, 47), 20703900.0],
#   [datetime.datetime(2015, 6, 23, 20, 47), 7675070.0],
#   [datetime.datetime(2015, 6, 24, 20, 47), 9571780.0],
#   [datetime.datetime(2015, 6, 25, 20, 47), 9190760.0],
#   [datetime.datetime(2015, 6, 26, 20, 47), 6646040.0],
#   [datetime.datetime(2015, 6, 27, 20, 47), 8286930.0],
#   [datetime.datetime(2015, 6, 28, 20, 47), 8619600.0],
#   [datetime.datetime(2015, 6, 29, 20, 47), 15818500.0],
#   [datetime.datetime(2015, 6, 30, 20, 47), 24948400.0],
#   [datetime.datetime(2015, 7, 1, 20, 47), 13477100.0],
#   [datetime.datetime(2015, 7, 2, 20, 47), 10947900.0],
#   [datetime.datetime(2015, 7, 3, 20, 47), 8256620.0],
#   [datetime.datetime(2015, 7, 4, 20, 47), 7662110.0],
#   [datetime.datetime(2015, 7, 5, 20, 47), 11680200.0],
#   [datetime.datetime(2015, 7, 6, 20, 47), 32931600.0],
#   [datetime.datetime(2015, 7, 7, 20, 47), 22603600.0],
#   [datetime.datetime(2015, 7, 8, 20, 47), 27730400.0],
#   [datetime.datetime(2015, 7, 9, 20, 47), 46974400.0],
#   [datetime.datetime(2015, 7, 10, 20, 47), 75301800.0],
#   [datetime.datetime(2015, 7, 11, 20, 47), 37807100.0],
#   [datetime.datetime(2015, 7, 12, 20, 47), 26557200.0],
#   [datetime.datetime(2015, 7, 13, 20, 47), 20583000.0],
#   [datetime.datetime(2015, 7, 14, 20, 47), 12391400.0],
#   [datetime.datetime(2015, 7, 15, 20, 47), 10808300.0],
#   [datetime.datetime(2015, 7, 16, 20, 47), 22197900.0],
#   [datetime.datetime(2015, 7, 17, 20, 47), 14150600.0],
#   [datetime.datetime(2015, 7, 18, 20, 47), 12114300.0],
#   [datetime.datetime(2015, 7, 19, 20, 47), 6644140.0],
#   [datetime.datetime(2015, 7, 20, 20, 47), 7508540.0],
#   [datetime.datetime(2015, 7, 21, 20, 47), 7983870.0],
#   [datetime.datetime(2015, 7, 22, 20, 47), 6219560.0],
#   [datetime.datetime(2015, 7, 23, 20, 47), 4779830.0],
#   [datetime.datetime(2015, 7, 24, 20, 47), 13374000.0],
#   [datetime.datetime(2015, 7, 25, 20, 47), 17275600.0],
#   [datetime.datetime(2015, 7, 26, 20, 47), 10736400.0],
#   [datetime.datetime(2015, 7, 27, 20, 47), 7946370.0],
#   [datetime.datetime(2015, 7, 28, 20, 47), 13980200.0],
#   [datetime.datetime(2015, 7, 29, 20, 47), 10005100.0],
#   [datetime.datetime(2015, 7, 30, 20, 47), 8035240.0],
#   [datetime.datetime(2015, 7, 31, 20, 47), 7176710.0],
#   [datetime.datetime(2015, 8, 1, 20, 47), 8243480.0],
#   [datetime.datetime(2015, 8, 2, 20, 47), 8297830.0],
#   [datetime.datetime(2015, 8, 3, 20, 47), 7727390.0],
#   [datetime.datetime(2015, 8, 4, 20, 47), 6475910.0],
#   [datetime.datetime(2015, 8, 5, 20, 47), 4755420.0],
#   [datetime.datetime(2015, 8, 6, 20, 47), 5881100.0],
#   [datetime.datetime(2015, 8, 7, 20, 47), 21100300.0],
#   [datetime.datetime(2015, 8, 8, 20, 47), 26509400.0],
#   [datetime.datetime(2015, 8, 9, 20, 47), 21425200.0],
#   [datetime.datetime(2015, 8, 10, 20, 47), 4544300.0],
#   [datetime.datetime(2015, 8, 11, 20, 47), 5199060.0],
#   [datetime.datetime(2015, 8, 12, 20, 47), 8458730.0],
#   [datetime.datetime(2015, 8, 13, 20, 47), 7515730.0],
#   [datetime.datetime(2015, 8, 14, 20, 47), 10450400.0],
#   [datetime.datetime(2015, 8, 15, 20, 47), 6159260.0],
#   [datetime.datetime(2015, 8, 16, 20, 47), 8686960.0],
#   [datetime.datetime(2015, 8, 17, 20, 47), 6463820.0],
#   [datetime.datetime(2015, 8, 18, 20, 47), 5547660.0],
#   [datetime.datetime(2015, 8, 19, 20, 47), 11233200.0],
#   [datetime.datetime(2015, 8, 20, 20, 47), 8824200.0],
#   [datetime.datetime(2015, 8, 21, 20, 47), 6379010.0],
#   [datetime.datetime(2015, 8, 22, 20, 47), 5538370.0],
#   [datetime.datetime(2015, 8, 23, 20, 47), 6045080.0],
#   [datetime.datetime(2015, 8, 24, 20, 47), 10355800.0],
#   [datetime.datetime(2015, 8, 25, 20, 47), 15747000.0],
#   [datetime.datetime(2015, 8, 26, 20, 47), 9905690.0],
#   [datetime.datetime(2015, 8, 27, 20, 47), 5215120.0],
#   [datetime.datetime(2015, 8, 28, 20, 47), 8116100.0],
#   [datetime.datetime(2015, 8, 29, 20, 47), 4902280.0],
#   [datetime.datetime(2015, 8, 30, 20, 47), 5357750.0],
#   [datetime.datetime(2015, 8, 31, 20, 47), 6550860.0],
#   [datetime.datetime(2015, 9, 1, 20, 47), 4886850.0],
#   [datetime.datetime(2015, 9, 2, 20, 47), 5480200.0],
#   [datetime.datetime(2015, 9, 3, 20, 47), 4945740.0],
#   [datetime.datetime(2015, 9, 4, 20, 47), 3314780.0],
#   [datetime.datetime(2015, 9, 5, 20, 47), 4665600.0],
#   [datetime.datetime(2015, 9, 6, 20, 47), 8643830.0],
#   [datetime.datetime(2015, 9, 7, 20, 47), 6146210.0],
#   [datetime.datetime(2015, 9, 8, 20, 47), 5896310.0],
#   [datetime.datetime(2015, 9, 9, 20, 47), 6122040.0],
#   [datetime.datetime(2015, 9, 10, 20, 47), 5241220.0],
#   [datetime.datetime(2015, 9, 11, 20, 47), 6070660.0],
#   [datetime.datetime(2015, 9, 12, 20, 47), 4295760.0],
#   [datetime.datetime(2015, 9, 13, 20, 47), 4070890.0],
#   [datetime.datetime(2015, 9, 14, 20, 47), 4776530.0],
#   [datetime.datetime(2015, 9, 15, 20, 47), 5130730.0],
#   [datetime.datetime(2015, 9, 16, 20, 47), 4976910.0],
#   [datetime.datetime(2015, 9, 17, 20, 47), 5806800.0],
#   [datetime.datetime(2015, 9, 18, 20, 47), 5405620.0],
#   [datetime.datetime(2015, 9, 19, 20, 47), 4133510.0],
#   [datetime.datetime(2015, 9, 20, 20, 47), 4159830.0],
#   [datetime.datetime(2015, 9, 21, 20, 47), 5282360.0],
#   [datetime.datetime(2015, 9, 22, 20, 47), 5423840.0],
#   [datetime.datetime(2015, 9, 23, 20, 47), 4759620.0],
#   [datetime.datetime(2015, 9, 24, 20, 47), 5127170.0],
#   [datetime.datetime(2015, 9, 25, 20, 47), 4818890.0],
#   [datetime.datetime(2015, 9, 26, 20, 47), 2264900.0],
#   [datetime.datetime(2015, 9, 27, 20, 47), 2121740.0],
#   [datetime.datetime(2015, 9, 28, 20, 47), 6394160.0],
#   [datetime.datetime(2015, 9, 29, 20, 47), 7940610.0],
#   [datetime.datetime(2015, 9, 30, 20, 47), 5911260.0],
#   [datetime.datetime(2015, 10, 1, 20, 47), 3768380.0],
#   [datetime.datetime(2015, 10, 2, 20, 47), 3236560.0],
#   [datetime.datetime(2015, 10, 3, 20, 47), 2448510.0],
#   [datetime.datetime(2015, 10, 4, 20, 47), 2514050.0],
#   [datetime.datetime(2015, 10, 5, 20, 47), 2647400.0],
#   [datetime.datetime(2015, 10, 6, 20, 47), 3246900.0],
#   [datetime.datetime(2015, 10, 7, 20, 47), 3199360.0],
#   [datetime.datetime(2015, 10, 8, 20, 47), 4489760.0],
#   [datetime.datetime(2015, 10, 9, 20, 47), 4626570.0],
#   [datetime.datetime(2015, 10, 10, 20, 47), 4015780.0],
#   [datetime.datetime(2015, 10, 11, 20, 47), 3232200.0],
#   [datetime.datetime(2015, 10, 12, 20, 47), 4111410.0],
#   [datetime.datetime(2015, 10, 13, 20, 47), 4795410.0],
#   [datetime.datetime(2015, 10, 14, 20, 47), 5493810.0],
#   [datetime.datetime(2015, 10, 15, 20, 47), 5801270.0],
#   [datetime.datetime(2015, 10, 16, 20, 47), 4458360.0],
#   [datetime.datetime(2015, 10, 17, 20, 47), 5529000.0],
#   [datetime.datetime(2015, 10, 18, 20, 47), 3572030.0],
#   [datetime.datetime(2015, 10, 19, 20, 47), 4211720.0],
#   [datetime.datetime(2015, 10, 20, 20, 47), 4075670.0],
#   [datetime.datetime(2015, 10, 21, 20, 47), 4225020.0],
#   [datetime.datetime(2015, 10, 22, 20, 47), 4446810.0],
#   [datetime.datetime(2015, 10, 23, 20, 47), 4932620.0],
#   [datetime.datetime(2015, 10, 24, 20, 47), 3179140.0],
#   [datetime.datetime(2015, 10, 25, 19, 47), 4124600.0],
#   [datetime.datetime(2015, 10, 26, 19, 47), 4735920.0],
#   [datetime.datetime(2015, 10, 27, 19, 47), 5891000.0],
#   [datetime.datetime(2015, 10, 28, 19, 47), 5296800.0],
#   [datetime.datetime(2015, 10, 29, 19, 47), 14047500.0],
#   [datetime.datetime(2015, 10, 30, 19, 47), 23991900.0],
#   [datetime.datetime(2015, 10, 31, 19, 47), 8665960.0],
#   [datetime.datetime(2015, 11, 1, 19, 47), 6772790.0],
#   [datetime.datetime(2015, 11, 2, 19, 47), 8816170.0],
#   [datetime.datetime(2015, 11, 3, 19, 47), 25027600.0],
#   [datetime.datetime(2015, 11, 4, 19, 47), 33680200.0],
#   [datetime.datetime(2015, 11, 5, 19, 47), 25760900.0],
#   [datetime.datetime(2015, 11, 6, 19, 47), 14525400.0],
#   [datetime.datetime(2015, 11, 7, 19, 47), 8097730.0],
#   [datetime.datetime(2015, 11, 8, 19, 47), 5334450.0],
#   [datetime.datetime(2015, 11, 9, 19, 47), 10227900.0],
#   [datetime.datetime(2015, 11, 10, 19, 47), 8272580.0],
#   [datetime.datetime(2015, 11, 11, 19, 47), 8823090.0],
#   [datetime.datetime(2015, 11, 12, 19, 47), 7619290.0],
#   [datetime.datetime(2015, 11, 13, 19, 47), 5687310.0],
#   [datetime.datetime(2015, 11, 14, 19, 47), 3119610.0],
#   [datetime.datetime(2015, 11, 15, 19, 47), 3897140.0],
#   [datetime.datetime(2015, 11, 16, 19, 47), 3964620.0],
#   [datetime.datetime(2015, 11, 17, 19, 47), 5139330.0],
#   [datetime.datetime(2015, 11, 18, 19, 47), 4093470.0],
#   [datetime.datetime(2015, 11, 19, 19, 47), 5311150.0],
#   [datetime.datetime(2015, 11, 20, 19, 47), 4610550.0],
#   [datetime.datetime(2015, 11, 21, 19, 47), 3626790.0],
#   [datetime.datetime(2015, 11, 22, 19, 47), 2930620.0],
#   [datetime.datetime(2015, 11, 23, 19, 47), 3573840.0],
#   [datetime.datetime(2015, 11, 24, 19, 47), 3846180.0],
#   [datetime.datetime(2015, 11, 25, 19, 47), 5595350.0],
#   [datetime.datetime(2015, 11, 26, 19, 47), 13320400.0],
#   [datetime.datetime(2015, 11, 27, 19, 47), 6113740.0],
#   [datetime.datetime(2015, 11, 28, 19, 47), 4375350.0],
#   [datetime.datetime(2015, 11, 29, 19, 47), 4493190.0],
#   [datetime.datetime(2015, 11, 30, 19, 47), 7075790.0],
#   [datetime.datetime(2015, 12, 1, 19, 47), 6244520.0],
#   [datetime.datetime(2015, 12, 2, 19, 47), 6768930.0],
#   [datetime.datetime(2015, 12, 3, 19, 47), 4711200.0],
#   [datetime.datetime(2015, 12, 4, 19, 47), 4052070.0],
#   [datetime.datetime(2015, 12, 5, 19, 47), 4916020.0],
#   [datetime.datetime(2015, 12, 6, 19, 47), 7409940.0],
#   [datetime.datetime(2015, 12, 7, 19, 47), 7212320.0],
#   [datetime.datetime(2015, 12, 8, 19, 47), 7222160.0],
#   [datetime.datetime(2015, 12, 9, 19, 47), 14818000.0],
#   [datetime.datetime(2015, 12, 10, 19, 47), 9609360.0],
#   [datetime.datetime(2015, 12, 11, 19, 47), 10413400.0],
#   [datetime.datetime(2015, 12, 12, 19, 47), 12817300.0],
#   [datetime.datetime(2015, 12, 13, 19, 47), 6669690.0],
#   [datetime.datetime(2015, 12, 14, 19, 47), 7839280.0],
#   [datetime.datetime(2015, 12, 15, 19, 47), 13369900.0],
#   [datetime.datetime(2015, 12, 16, 19, 47), 7709410.0],
#   [datetime.datetime(2015, 12, 17, 19, 47), 5580560.0],
#   [datetime.datetime(2015, 12, 18, 19, 47), 5757460.0],
#   [datetime.datetime(2015, 12, 19, 19, 47), 4091960.0],
#   [datetime.datetime(2015, 12, 20, 19, 47), 5426570.0],
#   [datetime.datetime(2015, 12, 21, 19, 47), 8035490.0],
#   [datetime.datetime(2015, 12, 22, 19, 47), 4998820.0],
#   [datetime.datetime(2015, 12, 23, 19, 47), 5624820.0],
#   [datetime.datetime(2015, 12, 24, 19, 47), 5701250.0],
#   [datetime.datetime(2015, 12, 25, 19, 47), 5384610.0],
#   [datetime.datetime(2015, 12, 26, 19, 47), 7182870.0],
#   [datetime.datetime(2015, 12, 27, 19, 47), 4475260.0],
#   [datetime.datetime(2015, 12, 28, 19, 47), 4198830.0],
#   [datetime.datetime(2015, 12, 29, 19, 47), 4682520.0],
#   [datetime.datetime(2015, 12, 30, 19, 47), 5124710.0],
#   [datetime.datetime(2015, 12, 31, 19, 47), 5672540.0],
#   [datetime.datetime(2016, 1, 1, 19, 47), 4725940.0],
#   [datetime.datetime(2016, 1, 2, 19, 47), 4975350.0],
#   [datetime.datetime(2016, 1, 3, 19, 47), 4159840.0],
#   [datetime.datetime(2016, 1, 4, 19, 47), 6923430.0],
#   [datetime.datetime(2016, 1, 5, 19, 47), 4230340.0],
#   [datetime.datetime(2016, 1, 6, 19, 47), 4323530.0],
#   [datetime.datetime(2016, 1, 7, 19, 47), 8354300.0],
#   [datetime.datetime(2016, 1, 8, 19, 47), 9507140.0],
#   [datetime.datetime(2016, 1, 9, 19, 47), 10284000.0],
#   [datetime.datetime(2016, 1, 10, 19, 47), 5910190.0],
#   [datetime.datetime(2016, 1, 11, 19, 47), 8666190.0],
#   [datetime.datetime(2016, 1, 12, 19, 47), 26041100.0],
#   [datetime.datetime(2016, 1, 13, 19, 47), 18745000.0],
#   [datetime.datetime(2016, 1, 14, 19, 47), 10497200.0],
#   [datetime.datetime(2016, 1, 15, 19, 47), 15083800.0],
#   [datetime.datetime(2016, 1, 16, 19, 47), 14540000.0],
#   [datetime.datetime(2016, 1, 17, 19, 47), 8212880.0],
#   [datetime.datetime(2016, 1, 18, 19, 47), 11529900.0],
#   [datetime.datetime(2016, 1, 19, 19, 47), 8364360.0],
#   [datetime.datetime(2016, 1, 20, 19, 47), 12673700.0],
#   [datetime.datetime(2016, 1, 21, 19, 47), 17790600.0],
#   [datetime.datetime(2016, 1, 22, 19, 47), 24766200.0],
#   ...]}

# %% [markdown]
# #### `graphs.dominance([start=None, end=None])`
# Get data from percentage of total market capitalization chart:

# %%
from datetime import datetime, timedelta

ten_days_ago = datetime.now() - timedelta(days=10)
cmc.graphs.dominance(start=ten_days_ago)
# Out:
# {'bitcoin': [[datetime.datetime(2018, 2, 17, 19, 47), 36.1629],
#   [datetime.datetime(2018, 2, 18, 19, 47), 37.0028],
#   [datetime.datetime(2018, 2, 19, 19, 47), 37.4023],
#   [datetime.datetime(2018, 2, 20, 19, 47), 39.2103],
#   [datetime.datetime(2018, 2, 21, 19, 47), 39.3036],
#   [datetime.datetime(2018, 2, 22, 19, 47), 39.4775],
#   [datetime.datetime(2018, 2, 23, 19, 47), 38.6329],
#   [datetime.datetime(2018, 2, 24, 19, 47), 38.4529],
#   [datetime.datetime(2018, 2, 25, 19, 47), 37.9543],
#   [datetime.datetime(2018, 2, 26, 19, 47), 38.7165]],
#  'bitcoin-cash': [[datetime.datetime(2018, 2, 17, 19, 47), 5.14941],
#   [datetime.datetime(2018, 2, 18, 19, 47), 5.24489],
#   [datetime.datetime(2018, 2, 19, 19, 47), 5.17383],
#   [datetime.datetime(2018, 2, 20, 19, 47), 5.05605],
#   [datetime.datetime(2018, 2, 21, 19, 47), 4.8781],
#   [datetime.datetime(2018, 2, 22, 19, 47), 4.76584],
#   [datetime.datetime(2018, 2, 23, 19, 47), 4.79737],
#   [datetime.datetime(2018, 2, 24, 19, 47), 4.71324],
#   [datetime.datetime(2018, 2, 25, 19, 47), 4.70357],
#   [datetime.datetime(2018, 2, 26, 19, 47), 4.72888]],
#  'dash': [[datetime.datetime(2018, 2, 17, 19, 47), 1.14847],
#   [datetime.datetime(2018, 2, 18, 19, 47), 1.12731],
#   [datetime.datetime(2018, 2, 19, 19, 47), 1.14194],
#   [datetime.datetime(2018, 2, 20, 19, 47), 1.13882],
#   [datetime.datetime(2018, 2, 21, 19, 47), 1.17385],
#   [datetime.datetime(2018, 2, 22, 19, 47), 1.11302],
#   [datetime.datetime(2018, 2, 23, 19, 47), 1.10966],
#   [datetime.datetime(2018, 2, 24, 19, 47), 1.09109],
#   [datetime.datetime(2018, 2, 25, 19, 47), 1.09406],
#   [datetime.datetime(2018, 2, 26, 19, 47), 1.09385]],
#  'ethereum': [[datetime.datetime(2018, 2, 17, 19, 47), 18.722],
#   [datetime.datetime(2018, 2, 18, 19, 47), 18.6611],
#   [datetime.datetime(2018, 2, 19, 19, 47), 18.4608],
#   [datetime.datetime(2018, 2, 20, 19, 47), 17.9257],
#   [datetime.datetime(2018, 2, 21, 19, 47), 18.0036],
#   [datetime.datetime(2018, 2, 22, 19, 47), 18.437],
#   [datetime.datetime(2018, 2, 23, 19, 47), 18.7168],
#   [datetime.datetime(2018, 2, 24, 19, 47), 18.988],
#   [datetime.datetime(2018, 2, 25, 19, 47), 19.3469],
#   [datetime.datetime(2018, 2, 26, 19, 47), 18.895]],
#  'iota': [[datetime.datetime(2018, 2, 17, 19, 47), 1.19825],
#   [datetime.datetime(2018, 2, 18, 19, 47), 1.16787],
#   [datetime.datetime(2018, 2, 19, 19, 47), 1.16251],
#   [datetime.datetime(2018, 2, 20, 19, 47), 1.08517],
#   [datetime.datetime(2018, 2, 21, 19, 47), 1.08112],
#   [datetime.datetime(2018, 2, 22, 19, 47), 1.02193],
#   [datetime.datetime(2018, 2, 23, 19, 47), 1.08683],
#   [datetime.datetime(2018, 2, 24, 19, 47), 1.12583],
#   [datetime.datetime(2018, 2, 25, 19, 47), 1.18627],
#   [datetime.datetime(2018, 2, 26, 19, 47), 1.14804]],
#  'litecoin': [[datetime.datetime(2018, 2, 17, 19, 47), 2.50379],
#   [datetime.datetime(2018, 2, 18, 19, 47), 2.57199],
#   [datetime.datetime(2018, 2, 19, 19, 47), 2.4855],
#   [datetime.datetime(2018, 2, 20, 19, 47), 2.67748],
#   [datetime.datetime(2018, 2, 21, 19, 47), 2.5815],
#   [datetime.datetime(2018, 2, 22, 19, 47), 2.51895],
#   [datetime.datetime(2018, 2, 23, 19, 47), 2.57964],
#   [datetime.datetime(2018, 2, 24, 19, 47), 2.62246],
#   [datetime.datetime(2018, 2, 25, 19, 47), 2.80015],
#   [datetime.datetime(2018, 2, 26, 19, 47), 2.74571]],
#  'monero': [[datetime.datetime(2018, 2, 17, 19, 47), 1.00109],
#   [datetime.datetime(2018, 2, 18, 19, 47), 0.994346],
#   [datetime.datetime(2018, 2, 19, 19, 47), 0.989694],
#   [datetime.datetime(2018, 2, 20, 19, 47), 0.992486],
#   [datetime.datetime(2018, 2, 21, 19, 47), 1.07436],
#   [datetime.datetime(2018, 2, 22, 19, 47), 1.05073],
#   [datetime.datetime(2018, 2, 23, 19, 47), 1.00466],
#   [datetime.datetime(2018, 2, 24, 19, 47), 1.01051],
#   [datetime.datetime(2018, 2, 25, 19, 47), 1.02041],
#   [datetime.datetime(2018, 2, 26, 19, 47), 1.02711]],
#  'nem': [[datetime.datetime(2018, 2, 17, 19, 47), 1.04658],
#   [datetime.datetime(2018, 2, 18, 19, 47), 0.979824],
#   [datetime.datetime(2018, 2, 19, 19, 47), 0.946584],
#   [datetime.datetime(2018, 2, 20, 19, 47), 0.895357],
#   [datetime.datetime(2018, 2, 21, 19, 47), 0.912395],
#   [datetime.datetime(2018, 2, 22, 19, 47), 0.888824],
#   [datetime.datetime(2018, 2, 23, 19, 47), 0.880071],
#   [datetime.datetime(2018, 2, 24, 19, 47), 0.860417],
#   [datetime.datetime(2018, 2, 25, 19, 47), 0.823364],
#   [datetime.datetime(2018, 2, 26, 19, 47), 0.808818]],
#  'neo': [[datetime.datetime(2018, 2, 17, 19, 47), 1.74209],
#   [datetime.datetime(2018, 2, 18, 19, 47), 1.70524],
#   [datetime.datetime(2018, 2, 19, 19, 47), 1.77035],
#   [datetime.datetime(2018, 2, 20, 19, 47), 1.72206],
#   [datetime.datetime(2018, 2, 21, 19, 47), 1.70048],
#   [datetime.datetime(2018, 2, 22, 19, 47), 1.71799],
#   [datetime.datetime(2018, 2, 23, 19, 47), 1.7464],
#   [datetime.datetime(2018, 2, 24, 19, 47), 1.78064],
#   [datetime.datetime(2018, 2, 25, 19, 47), 1.78923],
#   [datetime.datetime(2018, 2, 26, 19, 47), 1.9644]],
#  'others': [[datetime.datetime(2018, 2, 17, 19, 47), 22.16143999999997],
#   [datetime.datetime(2018, 2, 18, 19, 47), 21.52352000000002],
#   [datetime.datetime(2018, 2, 19, 19, 47), 21.551012000000014],
#   [datetime.datetime(2018, 2, 20, 19, 47), 20.673666999999995],
#   [datetime.datetime(2018, 2, 21, 19, 47), 20.667494999999988],
#   [datetime.datetime(2018, 2, 22, 19, 47), 20.563215999999997],
#   [datetime.datetime(2018, 2, 23, 19, 47), 20.766938999999994],
#   [datetime.datetime(2018, 2, 24, 19, 47), 20.76808300000002],
#   [datetime.datetime(2018, 2, 25, 19, 47), 20.681596],
#   [datetime.datetime(2018, 2, 26, 19, 47), 20.52497199999999]],
#  'ripple': [[datetime.datetime(2018, 2, 17, 19, 47), 9.16398],
#   [datetime.datetime(2018, 2, 18, 19, 47), 9.02111],
#   [datetime.datetime(2018, 2, 19, 19, 47), 8.91548],
#   [datetime.datetime(2018, 2, 20, 19, 47), 8.62291],
#   [datetime.datetime(2018, 2, 21, 19, 47), 8.6235],
#   [datetime.datetime(2018, 2, 22, 19, 47), 8.445],
#   [datetime.datetime(2018, 2, 23, 19, 47), 8.67873],
#   [datetime.datetime(2018, 2, 24, 19, 47), 8.58683],
#   [datetime.datetime(2018, 2, 25, 19, 47), 8.60015],
#   [datetime.datetime(2018, 2, 26, 19, 47), 8.34672]]}

# %% [markdown]
# _________________________________
#
# ## Utils
# #### `convert(value, currency_in, currency_out)`
# This method converts the value passed as first parameter as price of the `currency_in` currency to price of the `currency_out` parameter. Works as [coinmarketcap criptocurrencies calculator](https://coinmarketcap.com/calculator/). For example, if you want to converts $100€$ to dolars, use:

# %%
cmc.convert(100, "EUR", "USD")
# Out:
# 123.45877156053122

# %% [markdown]
# For get all the currencies supported by this method (all currencies; fiat + crypto):

# %%
cmc.currencies_to_convert
# Out:
# ['$$$',
#  '1337',
#  '1ST',
#  '2GIVE',
#  '300',
#  '42',
#  '611',
#  '808',
#  '888',
#  '8BIT',
#  'AAC',
#  'ABC',
#  'ABJ',
#  'ABN',
#  'ABY',
#  'AC',
#  'ACAT',
#  'ACC',
#  'ACC',
#  'ACC',
#  'ACE',
#  'ACES',
#  'ACN',
#  'ACOIN',
#  'ACP',
#  'ACT',
#  'ADA',
#  'ADB',
#  'ADC',
#  'ADCN',
#  'ADK',
#  'ADST',
#  'ADT',
#  'ADX',
#  'ADZ',
#  'AE',
#  'AEON',
#  'AERM',
#  'AGI',
#  'AGLC',
#  'AGRS',
#  'AHT',
#  'AI',
#  'AIB',
#  'AID',
#  'AIDOC',
#  'AION',
#  'AIR',
#  'AIT',
#  'AIX',
#  'AKY',
#  'ALIS',
#  'ALL',
#  'ALQO',
#  'ALT',
#  'ALTC',
#  'ALTCOM',
#  'AMB',
#  'AMBER',
#  'AMM',
#  'AMMO',
#  'AMP',
#  'AMS',
#  'ANC',
#  'ANI',
#  'ANT',
#  'ANTI',
#  'ANTX',
#  'APC',
#  'APPC',
#  'APX',
#  'ARB',
#  'ARC',
#  'ARCO',
#  'ARCT',
#  'ARDR',
#  'ARG',
#  'ARGUS',
#  'ARI',
#  'ARK',
#  'ARN',
#  'ART',
#  'ARY',
#  'ASAFE2',
#  'ASN',
#  'AST',
#  'ATB',
#  'ATL',
#  'ATM',
#  'ATMC',
#  'ATMS',
#  'ATN',
#  'ATOM',
#  'ATS',
#  'ATX',
#  'AU',
#  'AUD',
#  'AUR',
#  'AURA',
#  'AV',
#  'AVH',
#  'AVT',
#  'AWR',
#  'AXIOM',
#  'AXP',
#  'B2B',
#  'B2X',
#  'B@',
#  'BAC',
#  'BAR',
#  'BAS',
#  'BASH',
#  'BAT',
#  'BAT',
#  'BAY',
#  'BBP',
#  'BBR',
#  'BBT',
#  'BCA',
#  'BCC',
#  'BCD',
#  'BCDN',
#  'BCF',
#  'BCH',
#  'BCH',
#  'BCN',
#  'BCO',
#  'BCPT',
#  'BCX',
#  'BCY',
#  'BDG',
#  'BDL',
#  'BELA',
#  'BENJI',
#  'BERN',
#  'BEST',
#  'BET',
#  'BET',
#  'BIG',
#  'BIGUP',
#  'BIO',
#  'BIOB',
#  'BIOS',
#  'BIP',
#  'BIRDS',
#  'BIS',
#  'BIT',
#  'BITB',
#  'BITBTC',
#  'BITCF',
#  'BITCNY',
#  'BITEUR',
#  'BITGOLD',
#  'BITOK',
#  'BITS',
#  'BITSILVER',
#  'BITUSD',
#  'BITZ',
#  'BIX',
#  'BKX',
#  'BLAZR',
#  'BLC',
#  'BLITZ',
#  'BLK',
#  'BLN',
#  'BLOCK',
#  'BLOCKPAY',
#  'BLRY',
#  'BLT',
#  'BLU',
#  'BLUE',
#  'BLZ',
#  'BLZ',
#  'BMC',
#  'BNB',
#  'BNT',
#  'BNTY',
#  'BNX',
#  'BOAT',
#  'BOLI',
#  'BON',
#  'BOS',
#  'BOST',
#  'BOT',
#  'BPC',
#  'BPL',
#  'BPT',
#  'BQ',
#  'BRAIN',
#  'BRAT',
#  'BRD',
#  'BRIA',
#  'BRIT',
#  'BRK',
#  'BRL',
#  'BRO',
#  'BRX',
#  'BSC',
#  'BSD',
#  'BSN',
#  'BSR',
#  'BSTAR',
#  'BSTY',
#  'BT2',
#  'BTA',
#  'BTB',
#  'BTBc',
#  'BTC',
#  'BTC',
#  'BTCA',
#  'BTCD',
#  'BTCM',
#  'BTCR',
#  'BTCRED',
#  'BTCS',
#  'BTCZ',
#  'BTDX',
#  'BTE',
#  'BTG',
#  'BTG',
#  'BTM',
#  'BTM',
#  'BTO',
#  'BTPL',
#  'BTQ',
#  'BTS',
#  'BTW',
#  'BTWTY',
#  'BTX',
#  'BUB',
#  'BUCKS',
#  'BUMBA',
#  'BUN',
#  'BURST',
#  'BUZZ',
#  'BWK',
#  'BXC',
#  'BXT',
#  'BYC',
#  'C2',
#  'C20',
#  'CAB',
#  'CACH',
#  'CAD',
#  'CAG',
#  'CALC',
#  'CAN',
#  'CAN',
#  'CANDY',
#  'CANN',
#  'CAPP',
#  'CARBON',
#  'CAS',
#  'CASH',
#  'CAT',
#  'CAT',
#  'CAT',
#  'CBX',
#  'CC',
#  'CCM100',
#  'CCN',
#  'CCO',
#  'CCRB',
#  'CCT',
#  'CDN',
#  'CDT',
#  'CDX',
#  'CEFS',
#  'CESC',
#  'CF',
#  'CFC',
#  'CFD',
#  'CFI',
#  'CFT',
#  'CFUN',
#  'CHAN',
#  'CHAT',
#  'CHC',
#  'CHEAP',
#  'CHESS',
#  'CHF',
#  'CHIPS',
#  'CHSB',
#  'CJ',
#  'CL',
#  'CLAM',
#  'CLD',
#  'CLOAK',
#  'CLP',
#  'CLUB',
#  'CME',
#  'CMP',
#  'CMPCO',
#  'CMS',
#  'CMS',
#  'CMT',
#  'CMT',
#  'CND',
#  'CNNC',
#  'CNO',
#  'CNT',
#  'CNX',
#  'CNY',
#  'COAL',
#  'COB',
#  'COFI',
#  'COLX',
#  'CON',
#  'CONX',
#  'COR',
#  'COSS',
#  'COUPE',
#  'COV',
#  'COVAL',
#  'COXST',
#  'CPAY',
#  'CPC',
#  'CPC',
#  'CPN',
#  'CPY',
#  'CRAVE',
#  'CRB',
#  'CRC',
#  'CRDNC',
#  'CREA',
#  'CRED',
#  'CREDO',
#  'CREVA',
#  'CRM',
#  'CRPT',
#  'CRT',
#  'CRW',
#  'CRX',
#  'CSC',
#  'CSNO',
#  'CTIC2',
#  'CTIC3',
#  'CTO',
#  'CTR',
#  'CTX',
#  'CUBE',
#  'CURE',
#  'CV',
#  'CV2',
#  'CVC',
#  'CVCOIN',
#  'CWXT',
#  'CXO',
#  'CXT',
#  'CYC',
#  'CYDER',
#  'CYP',
#  'CZK',
#  'DADI',
#  'DAI',
#  'DALC',
#  'DAR',
#  'DASH',
#  'DASHS',
#  'DAT',
#  'DATA',
#  'DAV',
#  'DAXX',
#  'DAY',
#  'DBC',
#  'DBET',
#  'DBG',
#  'DBIX',
#  'DBTC',
#  'DCN',
#  'DCR',
#  'DCRE',
#  'DCT',
#  'DCY',
#  'DDD',
#  'DDF',
#  'DEM',
#  'DENT',
#  'DES',
#  'DEUS',
#  'DEW',
#  'DFS',
#  'DFT',
#  'DGB',
#  'DGC',
#  'DGCS',
#  'DGD',
#  'DGPT',
#  'DIBC',
#  'DICE',
#  'DIM',
#  'DIME',
#  'DISK',
#  'DIVX',
#  'DIX',
#  'DKK',
#  'DLC',
#  'DLISK',
#  'DLT',
#  'DMB',
#  'DMC',
#  'DMD',
#  'DMT',
#  'DNA',
#  'DNR',
#  'DNT',
#  'DOGE',
#  'DOLLAR',
#  'DON',
#  'DOPE',
#  'DOT',
#  'DOVU',
#  'DP',
#  'DPY',
#  'DRGN',
#  'DRM',
#  'DRP',
#  'DRPU',
#  'DRS',
#  'DRT',
#  'DRXNE',
#  'DSH',
#  'DSR',
#  'DTA',
#  'DTB',
#  'DTC',
#  'DTH',
#  'DTR',
#  'DUB',
#  'DUO',
#  'DUTCH',
#  'DXT',
#  'DYN',
#  'EAC',
#  'EAG',
#  'EAGLE',
#  'EBCH',
#  'EBET',
#  'EBST',
#  'EBT',
#  'EBTC',
#  'ECA',
#  'ECASH',
#  'ECC',
#  'ECH',
#  'ECN',
#  'ECO',
#  'ECOB',
#  'EDG',
#  'EDO',
#  'EDR',
#  'EDRC',
#  'EFL',
#  'EFYT',
#  'EGC',
#  'EGG',
#  'EGO',
#  'EGOLD',
#  'EKO',
#  'EKT',
#  'EL',
#  'ELA',
#  'ELC',
#  'ELE',
#  'ELF',
#  'ELITE',
#  'ELIX',
#  'ELLA',
#  'ELS',
#  'ELTCOIN',
#  'EMC',
#  'EMC2',
#  'EMD',
#  'EMV',
#  'ENG',
#  'ENJ',
#  'ENRG',
#  'ENT',
#  'ENT',
#  'EOS',
#  'EOT',
#  'EPC',
#  'EPY',
#  'EQL',
#  'EQT',
#  'ERA',
#  'ERC',
#  'ERC20',
#  'ERO',
#  'ERY',
#  'ESC',
#  'ESP',
#  'ESZ',
#  'ETBS',
#  'ETC',
#  'ETG',
#  'ETH',
#  'ETH',
#  'ETHD',
#  'ETHOS',
#  'ETN',
#  'ETP',
#  'ETT',
#  'ETT',
#  'EUC',
#  'EUR',
#  'EVC',
#  'EVE',
#  'EVIL',
#  'EVN',
#  'EVO',
#  'EVR',
#  'EVX',
#  'EXCL',
#  'EXN',
#  'EXP',
#  'EXRN',
#  'FAIR',
#  'FAIR',
#  'FAP',
#  'FAZZ',
#  'FC2',
#  'FCN',
#  'FCT',
#  'FDX',
#  'FFC',
#  'FID',
#  'FIL',
#  'FIMK',
#  'FIRE',
#  'FJC',
#  'FLAP',
#  'FLASH',
#  'FLAX',
#  'FLDC',
#  'FLIK',
#  'FLIXX',
#  'FLO',
#  'FLT',
#  'FLY',
#  'FNC',
#  'FONZ',
#  'FOR',
#  'FOTA',
#  'FRC',
#  'FRCT',
#  'FRD',
#  'FRGC',
#  'FRK',
#  'FRN',
#  'FRST',
#  'FRWC',
#  'FSN',
#  'FST',
#  'FTC',
#  'FUCK',
#  'FUEL',
#  'FUN',
#  'FUNC',
#  'FUTC',
#  'FUZZ',
#  'FXE',
#  'FYN',
#  'FYP',
#  'G3N',
#  'GAIA',
#  'GAIN',
#  'GAM',
#  'GAME',
#  'GAP',
#  'GARY',
#  'GAS',
#  'GAT',
#  'GAY',
#  'GB',
#  'GBC',
#  'GBG',
#  'GBP',
#  'GBX',
#  'GBYTE',
#  'GCC',
#  'GCC',
#  'GCN',
#  'GCR',
#  'GCS',
#  'GDC',
#  'GEERT',
#  'GEM',
#  'GEO',
#  'GET',
#  'GJC',
#  'GLA',
#  'GLC',
#  'GLD',
#  'GLS',
#  'GLT',
#  'GML',
#  'GMT',
#  'GMX',
#  'GNO',
#  'GNT',
#  'GNX',
#  'GOD',
#  'GOLF',
#  'GOLOS',
#  'GOOD',
#  'GP',
#  'GPL',
#  'GPU',
#  'GRC',
#  'GRE',
#  'GRID',
#  'GRIM',
#  'GRLC',
#  'GRN',
#  'GRS',
#  'GRWI',
#  'GRX',
#  'GSR',
#  'GTC',
#  'GTC',
#  'GTO',
#  'GUESS',
#  'GUN',
#  'GUP',
#  'GVT',
#  'GXS',
#  'HAC',
#  'HAL',
#  'HALLO',
#  'HAT',
#  'HBC',
#  'HBN',
#  'HBT',
#  'HC',
#  'HCC',
#  'HDG',
#  'HDLB',
#  'HEAT',
#  'HERO',
#  'HGT',
#  'HIGH',
#  'HKD',
#  'HKN',
#  'HLC',
#  'HMC',
#  'HMC',
#  'HMP',
#  'HMQ',
#  'HNC',
#  'HNC',
#  'HODL',
#  'HOLD',
#  'HONEY',
#  'HORSE',
#  'HOT',
#  'HPB',
#  'HPC',
#  'HPY',
#  'HSR',
#  'HST',
#  'HT',
#  'HTC',
#  'HTML',
#  'HTML5',
#  'HUC',
#  'HUF',
#  'HUSH',
#  'HVCO',
#  'HVN',
#  'HWC',
#  'HXX',
#  'HYP',
#  'HYPER',
#  'I0C',
#  'IBANK',
#  'IC',
#  'ICE',
#  'ICN',
#  'ICN',
#  'ICOB',
#  'ICON',
#  'ICOO',
#  'ICOS',
#  'ICX',
#  'IDH',
#  'IDR',
#  'IDT',
#  'IDXM',
#  'IETH',
#  'IFC',
#  'IFLT',
#  'IFT',
#  'IGNIS',
#  'ILS',
#  'IMPS',
#  'IMS',
#  'IMX',
#  'INCNT',
#  'IND',
#  'INDI',
#  'INDIA',
#  'INF',
#  'INFX',
#  'ING',
#  'INK',
#  'INN',
#  'INPAY',
#  'INR',
#  'INS',
#  'INSN',
#  'INT',
#  'INXT',
#  'IOC',
#  'ION',
#  'IOP',
#  'IOST',
#  'IPC',
#  'IPL',
#  'IQT',
#  'IRL',
#  'ISL',
#  'ITC',
#  'ITI',
#  'ITNS',
#  'ITT',
#  'IVZ',
#  'IXC',
#  'IXT',
#  'J',
#  'JC',
#  'JET',
#  'JEW',
#  'JIN',
#  'JIYO',
#  'JNT',
#  'JOBS',
#  'JPY',
#  'JS',
#  'JWL',
#  'KARMA',
#  'KASHH',
#  'KAYI',
#  'KB3',
#  'KBR',
#  'KCASH',
#  'KCS',
#  'KDC',
#  'KED',
#  'KEK',
#  'KEY',
#  'KICK',
#  'KIN',
#  'KLC',
#  'KLN',
#  'KMD',
#  'KNC',
#  'KNC',
#  'KOBO',
#  'KORE',
#  'KRB',
#  'KRM',
#  'KRONE',
#  'KRW',
#  'KURT',
#  'KUSH',
#  'KZC',
#  'LA',
#  'LANA',
#  'LAZ',
#  'LBC',
#  'LBTC',
#  'LBTC',
#  'LCC',
#  'LCP',
#  'LCT',
#  'LDCN',
#  'LDOGE',
#  'LEA',
#  'LEAF',
#  'LEND',
#  'LEO',
#  'LEPEN',
#  'LET',
#  'LEV',
#  'LEVO',
#  'LGD',
#  'LIFE',
#  'LIGHT',
#  'LINDA',
#  'LINK',
#  'LINX',
#  'LIR',
#  'LKC',
#  'LKK',
#  'LLT',
#  'LMC',
#  'LNK',
#  'LOC',
#  'LOCI',
#  'LOG',
#  'LRC',
#  'LSK',
#  'LTB',
#  'LTC',
#  'LTC',
#  'LTCR',
#  'LTCU',
#  'LTH',
#  'LUN',
#  'LUNA',
#  'LUX',
#  'LVPS',
#  'MAC',
#  'MAD',
#  'MAG',
#  'MAG',
#  'MAGE',
#  'MAGN',
#  'MAID',
#  'MAN',
#  'MANA',
#  'MANNA',
#  'MAO',
#  'MAR',
#  'MARS',
#  'MARX',
#  'MAX',
#  'MAY',
#  'MBI',
#  'MBL',
#  'MBRS',
#  'MCAP',
#  'MCI',
#  'MCO',
#  'MCR',
#  'MCRN',
#  'MDA',
#  'MDC',
#  'MDS',
#  'MDT',
#  'MEC',
#  'MED',
#  'MEE',
#  'MEME',
#  'MER',
#  'METAL',
#  'MGC',
#  'MGM',
#  'MGO',
#  'MILO',
#  'MINEX',
#  'MINT',
#  'MIOTA',
#  'MKR',
#  'MLM',
#  'MLN',
#  'MMXVI',
#  'MNC',
#  'MND',
#  'MNE',
#  'MNM',
#  'MNTP',
#  'MNX',
#  'MOAC',
#  'MOBI',
#  'MOD',
#  'MOF',
#  'MOIN',
#  'MOJO',
#  'MONA',
#  'MONETA',
#  'MONEY',
#  'MONK',
#  'MOON',
#  'MOT',
#  'MOTO',
#  'MRJA',
#  'MRT',
#  'MSCN',
#  'MSD',
#  'MSP',
#  'MST',
#  'MTH',
#  'MTL',
#  'MTLMC3',
#  'MTN',
#  'MTNC',
#  'MTX',
#  'MUE',
#  'MUSE',
#  'MUSIC',
#  'MVC',
#  'MWAT',
#  'MXN',
#  'MXT',
#  'MYB',
#  'MYR',
#  'MYST',
#  'MZC',
#  'NAMO',
#  'NANO',
#  'NANOX',
#  'NAS',
#  'NAV',
#  'NBIT',
#  'NCASH',
#  'NDC',
#  'NEBL',
#  'NEO',
#  'NEOG',
#  'NEOS',
#  'NET',
#  'NET',
#  'NETKO',
#  'NEU',
#  'NEVA',
#  'NEWB',
#  'NGC',
#  'NIO',
#  'NKA',
#  'NKC',
#  'NLC2',
#  'NLG',
#  'NMC',
#  'NMR',
#  'NMS',
#  'NOBL',
#  'NODC',
#  'NOK',
#  'NOTE',
#  'NOX',
#  'NRO',
#  'NSR',
#  'NTC',
#  'NTK',
#  'NTO',
#  'NTRN',
#  'NUKO',
#  'NULS',
#  'NUMUS',
#  'NVC',
#  'NVST',
#  'NXC',
#  'NXS',
#  'NXT',
#  'NYAN',
#  'NYC',
#  'NZD',
#  'OAX',
#  'OBITS',
#  'OC',
#  'OCL',
#  'OCN',
#  'OCOW',
#  'OCT',
#  'ODN',
#  'OF',
#  'OFF',
#  'OK',
#  'OMC',
#  'OMG',
#  'OMNI',
#  'ONG',
#  'ONION',
#  'ONX',
#  'OP',
#  'OPAL',
#  'OPC',
#  'OPES',
#  'OPT',
#  'ORB',
#  'ORE',
#  'ORLY',
#  'ORME',
#  'OS76',
#  'OST',
#  'OTN',
#  'OTX',
#  'OX',
#  'OXY',
#  'P7C',
#  'PAC',
#  'PAK',
#  'PARETO',
#  'PART',
#  'PASC',
#  'PASL',
#  'PAY',
#  'PAYP',
#  'PBL',
#  'PBT',
#  'PCN',
#  'PCOIN',
#  'PCS',
#  'PDC',
#  'PDG',
#  'PEPECASH',
#  'PEX',
#  'PFR',
#  ...]

# %%
show_page("calculator")
# Out:
#         <iframe
#             width="100%"
#             height="400"
#             src="https://coinmarketcap.com/calculator"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# #### `download_logo(name, [size=128, filename=None])`
# Download a currency image logo in `.png` format. Valid sizes are: `[16, 32, 64, 128, 200]`.

# %%
filename = cmc.download_logo("BTC", size=200)

from IPython.display import Image
Image(filename)

# %%
import os
try:
    os.remove(filename)
except FileNotFoundError:
    pass
